# %% [markdown]
# # [ResNet18]

# %% [markdown]
# *KU LeeDongGyu*

# %% [markdown]
# ## Contents
# ---

# %% [markdown]
# 1. Data Preprocessing
# ```
# 1) Data Import
# 2) Data Augmentation
# ```
# 2. Support Functions & Almost Original ResNet
# ```
# 1) Support Functions
# 2) Almost orginal ResNet
# ```
# 3. ResNet18
# ```
# 1) ResNet18
# 2) ResNet18 Evaluate
# ```

# %% [markdown]
# ### Install Packages

# %% [markdown]
# ### Module

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive/

# %%
cd /content/drive/My Drive/Colab Notebooks/Paper
# Out:
# /content/drive/My Drive/Colab Notebooks/Paper

# %%
from f1score import macro_f1score,weighted_f1score

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import cv2
import tensorflow as tf
from tensorflow import keras as ks
from tensorflow.keras import backend as K 
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, Input, Concatenate, ZeroPadding2D ,GlobalMaxPooling2D, Reshape , Lambda , Add, Multiply
from tensorflow.keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D, Activation, BatchNormalization, AveragePooling2D , ZeroPadding2D, SeparableConv2D
from tensorflow.keras.layers import add
from tensorflow.keras.optimizers import Adam, RMSprop , SGD
from tensorflow.keras.callbacks import EarlyStopping , LearningRateScheduler, ModelCheckpoint, CSVLogger, Callback, ReduceLROnPlateau
from tensorflow.keras.regularizers import l1,l2,l1_l2
from tensorflow.keras.models import Model , load_model , Sequential
from tensorflow.keras.utils import plot_model , to_categorical, get_file
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
os.getcwd()
# Out:
# '/content/drive/My Drive/Colab Notebooks/Paper'

# %%
print(tf.__version__)
print(ks.__version__)
# Out:
# 2.3.0
# 2.4.0

# %%
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 7246986354754091418
# , name: "/device:XLA_CPU:0"
# device_type: "XLA_CPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 9467238534618069420
# physical_device_desc: "device: XLA_CPU device"
# , name: "/device:XLA_GPU:0"
# device_type: "XLA_GPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 7872252010289337056
# physical_device_desc: "device: XLA_GPU device"
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 15695549568
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 9591532391630351036
# physical_device_desc: "device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0"
# ]

# %% [markdown]
# ## 1. Data Preprocessing
# ---

# %% [markdown]
# ### 1) Data Import

# %%
# 바꿔서 살펴 볼 것들
# CALTECH, CIFAR100, FER, MIT
data_name = 'CALTECH'
gan_type = 'No_GAN'
number = '1'
size = 224 # sizes after cropping
super_size = 256 # sizes before cropping 
input_sizes = (size,size,3)
batch_sizes = 128
weight_decay = 3e-3
epochs = 70

# %%
# 참고 : https://stackoverflow.com/questions/32419510/how-to-get-reproducible-results-in-keras/52897216#52897216
# setting the seed number for random number generation for reproducibility.

from numpy.random import seed
import random


if number=='1':
    seed_num = 200225
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)
elif number=='2':
    seed_num = 727
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)
elif number=='3':
    seed_num = 115
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)
elif number=='4':
    seed_num = 501
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)
elif number=='5':
    seed_num = 517
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)

# %%
# data import

if data_name=='FER' :
    x_train =  np.zeros(28698)
    x_valid = np.zeros(3589)
    x_test = np.zeros(3588)
    classes = 7 
    tr_center = [0.50793296, 0.50793296, 0.50793296]
elif data_name=='MIT':
    x_train = np.zeros(12466)
    x_valid = np.zeros(1564)
    x_test = np.zeros(1590)
    classes = 67 
    tr_center = [0.47916578, 0.42029615, 0.36046057]
elif data_name=='CALTECH':
    x_train = np.zeros(24510)
    x_valid = np.zeros(2980)
    x_test = np.zeros(3118)
    classes = 257
    tr_center = [0.51397761, 0.49525248, 0.46555727]
elif data_name=='CIFAR100':
    x_train = np.zeros(39941)
    x_valid = np.zeros(10059)
    x_test = np.zeros(10000)
    classes = 100
    tr_center = [0.53393271, 0.51324147, 0.46450563]

# %%
dir = os.path.join(os.getcwd(),data_name,gan_type)

# %% [markdown]
# ### 2) Data Augmentation

# %%
# 참고 : https://jkjung-avt.github.io/keras-image-cropping/

def random_crop(img, random_crop_size):
    # Note: image_data_format is 'channel_last'
    assert img.shape[2] == 3 # img.shape[2] 가 3(rgb)이 아니면 assertion error 발생
    height, width = img.shape[0], img.shape[1]
    dy, dx = random_crop_size
    x = np.random.randint(0, width - dx + 1)
    y = np.random.randint(0, height - dy + 1)
    return img[y:(y+dy), x:(x+dx), :]


def crop_generator(batches, crop_length):
    """Take as input a Keras ImageGen (Iterator) and generate random
    crops from the image batches generated by the original iterator.
    """
    while True:
        batch_x, batch_y = next(batches)
        batch_crops = np.zeros((batch_x.shape[0], crop_length, crop_length, 3))
        for i in range(batch_x.shape[0]):
            batch_crops[i] = random_crop(batch_x[i], (crop_length, crop_length))
        yield (batch_crops, batch_y)

# %%
from tensorflow.keras.preprocessing.image import img_to_array,load_img
import glob

# 데이터 전체에 대해 centering 진행함.

def read_cal_image(img_path): 
    x = img_to_array(load_img(img_path)) # x는 채널별 평균값
    y = x.shape[0] * x.shape[1]# y는 데이터별 픽셀 수 (비중)

    x = 1/255. * x # scaling하고, centering값을 뽑아냄.
    x = np.mean(x, axis=(0,1))
    
    return np.hstack([x,y])

def calculate_centered_mean(dataset_path,x_train=x_train):
    num = len(x_train)
    space = np.empty((num,4))
    i=0

    for p in glob.glob(os.path.join(dataset_path,'*/*.*')) :
        space[i] = read_cal_image(p)
        i += 1

    ratio = space[:,3] / np.sum(space[:,3])

    return np.average(space[:,0:3],axis=0,weights=ratio)


# 아래의 함수를 돌려서 나온 결과값을 중심화 값으로 설정.

# train_mean = calculate_centered_mean(os.path.join(dir,'data/train')).reshape((1,1,3))

# %%
datagen_tr = ImageDataGenerator(
    rescale=1/255.,
    horizontal_flip=True,
    featurewise_center=True,
    featurewise_std_normalization=False,
    rotation_range=10,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=[0.9,1.0],
    fill_mode = 'nearest')
datagen_val = ImageDataGenerator(rescale=1/255.,featurewise_center=True)
datagen_tes = ImageDataGenerator(rescale=1/255.,featurewise_center=True)

# 원래는 이 자리에 fit 매서드를 써야하지만, 그냥 내가 중심화함수를 만들고 적용함. 

# 중심화 설정
datagen_tr.mean = np.array(tr_center, dtype=np.float32).reshape((1,1,3)) # RGB
datagen_val.mean = np.array(tr_center, dtype=np.float32).reshape((1,1,3)) # RGB
datagen_tes.mean = np.array(tr_center, dtype=np.float32).reshape((1,1,3)) # RGB

# %%
train_batches = datagen_tr.flow_from_directory(directory=os.path.join(dir,'data/train'),target_size=(super_size,super_size),batch_size=batch_sizes,class_mode='categorical') # fer : 28698 / mit : 12466 / caltech : 24509 / cifar : 39941
train_generator= crop_generator(train_batches, size)
valid_generator = datagen_val.flow_from_directory(directory=os.path.join(dir,'data/valid'),target_size=(size,size),batch_size=batch_sizes,class_mode='categorical') # fer : 3589 / mit : 1564 / caltech : 2980 / cifar : 10059
test_generator = datagen_tes.flow_from_directory(directory=os.path.join(dir,'data/test'),target_size=(size,size),batch_size=batch_sizes,class_mode='categorical') # fer : 3588 / mit : 1590 / caltech : 3118 / cifar : 10000
# Out:
# Found 24509 images belonging to 257 classes.
# Found 2980 images belonging to 257 classes.
# Found 3118 images belonging to 257 classes.

# %% [markdown]
# ## 2. Support Functions & Almost Original ResNet
# ---

# %% [markdown]
# ### 1) Support Functions

# %%
# def lr_schedule(epoch):
#     init_lr = 1e-4
#     k = 0.04
#     lr = init_lr * np.exp(-k*epoch)
#     print('Learning rate: ', lr)
#     return lr

def lr_schedule(epoch):
    lr = 1e-3
    if epoch < 60:
        lr = lr
    else :
        lr = lr * 0.1
    print('Learning rate: ', lr)
    return lr

# %%
# 편의상 아래와 같은 resnet 묶음의 이름을 resnet_layer이라 하자 
def resnet_layer(inputs, weight_decay=weight_decay, num_filters=16, kernel_size=(3,3), strides=(1,1),activation=None):

    conv = Conv2D(num_filters,kernel_size=kernel_size,strides=strides, padding='same', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))
    x = inputs
    x = conv(x)
    x = BatchNormalization()(x)
    if activation is not None:
        x = Activation(activation)(x) # conv-bn-activation
    return x

# %%
# resnet 코드를 만들기 앞서, 코드가 너무 길어 비효율적이므로 적당한 함수를 만든다.
# block_v1 은 resnet18과 resnet34에 특화된 block이고, block_v2는 resnet50, resnet101, resnet152에 특화된 block이다.
# 이 두개의 block은, 나중에 하나의 모형에서 같이 고려될 것이다.

def block_v1(input_shape, num_filters, identi, half=True):
    # identi : resnet의 존재 이유인, 더하게 될 자기자신값이다.
    if half:
        layer1 = resnet_layer(inputs=input_shape, num_filters=num_filters, strides=(2, 2), activation='relu')
        layer2 = resnet_layer(inputs=layer1, num_filters=num_filters, strides=(1, 1), activation=None)
    else:
        layer1 = resnet_layer(inputs=input_shape, num_filters=num_filters, strides=(1, 1), activation='relu')
        layer2 = resnet_layer(inputs=layer1, num_filters=num_filters, strides=(1, 1), activation=None)
    
    res_2_1 = add([identi, layer2])  # block 1
    output = Activation("relu")(res_2_1)
    return output


def block_v2(input_shape, num_filters, identi, half=True):
    # identi : resnet의 존재 이유인, 더하게 될 자기자신값이다.
    if half:
        layer1 = resnet_layer(inputs=input_shape, num_filters=num_filters, strides=(2, 2), kernel_size=(1, 1), activation='relu')
        layer2 = resnet_layer(inputs=layer1, num_filters=num_filters, strides=(1, 1), kernel_size=(3, 3), activation='relu')
        layer3 = resnet_layer(inputs=layer2, num_filters= 4*num_filters, strides=(1, 1), kernel_size=(1, 1), activation=None)
    else:
        layer1 = resnet_layer(inputs=input_shape, num_filters= num_filters, strides=(1, 1), kernel_size=(1, 1), activation='relu')
        layer2 = resnet_layer(inputs=layer1, num_filters= num_filters, strides=(1, 1), kernel_size=(3, 3), activation='relu')
        layer3 = resnet_layer(inputs=layer2, num_filters= 4*num_filters, strides=(1, 1), kernel_size=(1, 1), activation=None)

    res_3_1 = add([identi, layer3])  # block 1
    output = Activation("relu")(res_3_1)
    return output

# %% [markdown]
# ### 2) Almost Orginial ResNet

# %%
# 좀더 깔끔하게 작성됨. 앞으로의 resnet모형은 다음의 함수에서 해결한다.
def ResNet(input_shape=(224, 224, 3), classes=1000, weight_decay=weight_decay, num_filters=64, num_blocks=[0,0,0,0] ,version=None, name=None):
    # num_blocks 는 list로 받는 인자. conv3_x ~ conv5_x의 block의 수를 앞에서부터 차례로 넣어주면 된다.
    # num_filters 는 초기의 filters를 의미한다.
    
    if len(num_blocks) != 4 :
        raise NameError("Please input the number of blocks from conv2_x to conv5_x in the 'num_blocks' variable.")

    if version == "v1" : # resnet 18, 34에 해당. (블록이 같음)
        block = block_v1
    elif version == "v2": # resnet 50, 101, 152에 해당. (블록이 같음)
        block = block_v2
    else :
        raise NameError("Please input the string 'v1' or 'v2' in the 'version' variable. ")

    inputs = Input(shape=input_shape)

    # conv1
    layer1 = resnet_layer(inputs=inputs, num_filters=num_filters, strides=(2, 2), kernel_size=(7, 7), activation='relu')
    cum_block = MaxPooling2D(pool_size=(3, 3), strides=(2, 2), padding='same', name='pool1/3x3_s2')(layer1)
    
    # cum_block 변수에 하나씩 residual block을 누적시켜보자.

    for stack in range(4):
        if stack == 0 :
            # 우리가 누적시킬 변수, cum_block을 정의하고, 이 변수에 누적시켜가면서 모형을 출력한다.

            # 이 아래 for문은 conv2_x
            # 들어가기 전에, block_v2라면 input과 output의 filter size를 동일하게 해주는 작업을 한다. 덧셈이 가능해야 하므로, 반드시!
            if version == 'v2':
                x = Conv2D(4 * num_filters, kernel_size=(1, 1), strides=(1, 1), padding='same', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(cum_block)
                x = BatchNormalization()(x) # 모든 conv.뒤에는 bn을 적용.
                cum_block = block(input_shape=cum_block, num_filters=num_filters, identi=x, half=False)

            if version != 'v2':
                  new_num_blocks = num_blocks[stack]
            else :
                  new_num_blocks = num_blocks[stack]-1

            for res_block in range(new_num_blocks):
                cum_block = block(input_shape=cum_block, num_filters=num_filters, identi=cum_block, half=False)
        else:

            # 이 아래는 conv3_x ~ conv5_x 까지.
            num_filters *= 2
 
            if version == 'v2':
                x = Conv2D(4 * num_filters, kernel_size=(1, 1), strides=(2, 2), padding='valid', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(cum_block)  # block_v2라면, input에 해당하는 x를 덧셈이 가능하게 맞춰준다.
                x = BatchNormalization()(x) # 모든 conv.뒤에는 bn을 적용.
            else:
                x = Conv2D(num_filters, (1, 1), strides=(2, 2), padding='valid', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(cum_block)  # identi_input 에 해당 // rxc가 각각 반토막남.
                x = BatchNormalization()(x) # 모든 conv.뒤에는 bn을 적용.
                #즉, 위 x는 결국 이어질 conv 층의 input임.

            for res_block in range(num_blocks[stack]):
                if res_block == 0:
                    cum_block = block(input_shape=cum_block , num_filters = num_filters , identi=x, half=True) # block 갱신
                else:
                    cum_block = block(input_shape=cum_block , num_filters = num_filters , identi=cum_block , half=False) # block 갱신

    # 마지막 1층
    y = GlobalAveragePooling2D()(cum_block)
    outputs = Dense(classes, activation='softmax')(y)

    model = Model(inputs=inputs, outputs=outputs, name = name)
    return model

# %% [markdown]
# ## 3. ResNet18
# ---

# %% [markdown]
# ### 1) ResNet18

# %%
# ResNet18
model = ResNet(input_shape=input_sizes, classes=classes, num_blocks=[2,2,2,2], version='v1', name='ResNet18')

# %%
model.summary()
# Out:
# Model: "ResNet18"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 112, 112, 64) 9472        input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 112, 112, 64) 256         conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 112, 112, 64) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# pool1/3x3_s2 (MaxPooling2D)     (None, 56, 56, 64)   0           activation[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 56, 56, 64)   36928       pool1/3x3_s2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 56, 56, 64)   256         conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 56, 56, 64)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 56, 56, 64)   36928       activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 56, 56, 64)   256         conv2d_2[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 56, 56, 64)   0           pool1/3x3_s2[0][0]
#                                                                  batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 56, 56, 64)   0           add[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 56, 56, 64)   36928       activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 56, 56, 64)   256         conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 56, 56, 64)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 56, 56, 64)   36928       activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 56, 56, 64)   256         conv2d_4[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 56, 56, 64)   0           activation_2[0][0]
#                                                                  batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 56, 56, 64)   0           add_1[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 28, 28, 128)  73856       activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 28, 28, 128)  512         conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 28, 28, 128)  0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 28, 28, 128)  8320        activation_4[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 28, 28, 128)  147584      activation_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 28, 28, 128)  512         conv2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 28, 28, 128)  512         conv2d_7[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 28, 28, 128)  0           batch_normalization_5[0][0]
#                                                                  batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 28, 28, 128)  0           add_2[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 28, 28, 128)  147584      activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 28, 28, 128)  512         conv2d_8[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 28, 28, 128)  0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 28, 28, 128)  147584      activation_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 28, 28, 128)  512         conv2d_9[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 28, 28, 128)  0           activation_6[0][0]
#                                                                  batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 28, 28, 128)  0           add_3[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 14, 14, 256)  295168      activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 14, 14, 256)  1024        conv2d_11[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 14, 14, 256)  0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 14, 14, 256)  33024       activation_8[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 14, 14, 256)  590080      activation_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 14, 14, 256)  1024        conv2d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 14, 14, 256)  1024        conv2d_12[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 14, 14, 256)  0           batch_normalization_10[0][0]
#                                                                  batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 14, 14, 256)  0           add_4[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 14, 14, 256)  590080      activation_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 14, 14, 256)  1024        conv2d_13[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 14, 14, 256)  0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 14, 14, 256)  590080      activation_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 14, 14, 256)  1024        conv2d_14[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 14, 14, 256)  0           activation_10[0][0]
#                                                                  batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 14, 14, 256)  0           add_5[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 7, 7, 512)    1180160     activation_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 7, 7, 512)    2048        conv2d_16[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 7, 7, 512)    0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 7, 7, 512)    131584      activation_12[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 7, 7, 512)    2359808     activation_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 7, 7, 512)    2048        conv2d_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 7, 7, 512)    2048        conv2d_17[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 7, 7, 512)    0           batch_normalization_15[0][0]
#                                                                  batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 7, 7, 512)    0           add_6[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 7, 7, 512)    2359808     activation_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 7, 7, 512)    2048        conv2d_18[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 7, 7, 512)    0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 7, 7, 512)    2359808     activation_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 7, 7, 512)    2048        conv2d_19[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 7, 7, 512)    0           activation_14[0][0]
#                                                                  batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 7, 7, 512)    0           add_7[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 512)          0           activation_16[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 257)          131841      global_average_pooling2d[0][0]
# ==================================================================================================
# Total params: 11,322,753
# Trainable params: 11,313,153
# Non-trainable params: 9,600
# __________________________________________________________________________________________________

# %%
plot_model(model)

# %%
# 폴더 생성

os.makedirs(os.path.join(dir,'model_output',number,model.name), exist_ok=True)
os.makedirs(os.path.join(dir,'train_valid_output',number), exist_ok=True)

# %%
# 참고 : https://github.com/OverLordGoldDragon/keras-adamw

import sys
sys.path.append('/content/drive/My Drive/Colab Notebooks/Paper')
import utils
import optimizers_v2
from utils import get_weight_decays, fill_dict_in_order
from utils import reset_seeds, K_eval
from optimizers_v2 import AdamW, NadamW, SGDW

# %%
optimizer = AdamW(model=model, use_cosine_annealing=True, total_iterations = len(x_train) // batch_sizes , eta_min = 1e-2)
#optimizer = Adam()
filepath =  os.path.join(dir,'model_output',number,model.name,'{epoch:03d}.h5')

callbacks_list = [ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_weights_only=False, save_best_only=True, mode='min'),
                  ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_weights_only=False, save_best_only=True, mode='max'),
                  #ReduceLROnPlateau(monitor='val_loss',patience=3,factor=0.1,min_lr=1e-5),
                  LearningRateScheduler(lr_schedule,verbose=1)
                  ]
                  
model.compile(optimizer, loss = 'categorical_crossentropy', metrics=['accuracy',macro_f1score,weighted_f1score])
# Out:
# Using cosine annealing learning rates

# %%
######## flow_from_directory
history = model.fit(train_generator, steps_per_epoch=int(len(x_train)/batch_sizes),  validation_data = valid_generator, epochs=epochs , verbose=1 , callbacks = callbacks_list , validation_steps=int(len(x_valid)/batch_sizes))
# Out:
# Learning rate:  0.001
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 1/70
# 0.0(L1), 0.0002170723834745943(L2) weight decay set for conv2d/kernel:0
# 0.0(L1), 0.0002170723834745943(L2) weight decay set for conv2d_1/kernel:0
# 0.0(L1), 0.0002170723834745943(L2) weight decay set for conv2d_2/kernel:0
# 0.0(L1), 0.0002170723834745943(L2) weight decay set for conv2d_3/kernel:0
# 0.0(L1), 0.0002170723834745943(L2) weight decay set for conv2d_4/kernel:0
# 0.0(L1), 0.0002170723834745943(L2) weight decay set for conv2d_6/kernel:0
# 0.0(L1), 0.0002170723834745943(L2) weight decay set for conv2d_5/kernel:0
# 0.0(L1), 0.0002170723834745943(L2) weight decay set for conv2d_7/kernel:0
# 0.0(L1), 0.0002170723834745943(L2) weight decay set for conv2d_8/kernel:0
# 0.0(L1), 0.0002170723834745943(L2) weight decay set for conv2d_9/kernel:0
# 0.0(L1), 0.0002170723834745943(L2) weight decay set for conv2d_11/kernel:0
# 0.0(L1), 0.0002170723834745943(L2) weight decay set for conv2d_10/kernel:0
# 0.0(L1), 0.0002170723834745943(L2) weight decay set for conv2d_12/kernel:0
# 0.0(L1), 0.0002170723834745943(L2) weight decay set for conv2d_13/kernel:0
# 0.0(L1), 0.0002170723834745943(L2) weight decay set for conv2d_14/kernel:0
# 0.0(L1), 0.0002170723834745943(L2) weight decay set for conv2d_16/kernel:0
# 0.0(L1), 0.0002170723834745943(L2) weight decay set for conv2d_15/kernel:0
# 0.0(L1), 0.0002170723834745943(L2) weight decay set for conv2d_17/kernel:0
# 0.0(L1), 0.0002170723834745943(L2) weight decay set for conv2d_18/kernel:0
# 0.0(L1), 0.0002170723834745943(L2) weight decay set for conv2d_19/kernel:0
# 191/191 [==============================] - ETA: 0s - loss: 4.7728 - accuracy: 0.1144 - macro_f1score: 0.0056 - weighted_f1score: 1.2332e-04
# Epoch 00001: val_loss improved from inf to 5.17953, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/ResNet18/001.h5
#
# Epoch 00001: val_accuracy improved from -inf to 0.07405, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/ResNet18/001.h5
# 191/191 [==============================] - 6928s 36s/step - loss: 4.7728 - accuracy: 0.1144 - macro_f1score: 0.0056 - weighted_f1score: 1.2332e-04 - val_loss: 5.1795 - val_accuracy: 0.0740 - val_macro_f1score: 0.0029 - val_weighted_f1score: 7.6206e-05
# Learning rate:  0.001
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 2/70
# 191/191 [==============================] - ETA: 0s - loss: 4.2225 - accuracy: 0.1694 - macro_f1score: 0.0120 - weighted_f1score: 2.3669e-04
# Epoch 00002: val_loss improved from 5.17953 to 4.08893, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/ResNet18/002.h5
#
# Epoch 00002: val_accuracy improved from 0.07405 to 0.17901, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/ResNet18/002.h5
# 191/191 [==============================] - 439s 2s/step - loss: 4.2225 - accuracy: 0.1694 - macro_f1score: 0.0120 - weighted_f1score: 2.3669e-04 - val_loss: 4.0889 - val_accuracy: 0.1790 - val_macro_f1score: 0.0140 - val_weighted_f1score: 2.7444e-04
# Learning rate:  0.001
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 3/70
# 191/191 [==============================] - ETA: 0s - loss: 3.8960 - accuracy: 0.2095 - macro_f1score: 0.0168 - weighted_f1score: 3.0978e-04
# Epoch 00003: val_loss improved from 4.08893 to 3.72135, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/ResNet18/003.h5
#
# Epoch 00003: val_accuracy improved from 0.17901 to 0.24660, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/ResNet18/003.h5
# 191/191 [==============================] - 432s 2s/step - loss: 3.8960 - accuracy: 0.2095 - macro_f1score: 0.0168 - weighted_f1score: 3.0978e-04 - val_loss: 3.7214 - val_accuracy: 0.2466 - val_macro_f1score: 0.0215 - val_weighted_f1score: 3.6043e-04
# Learning rate:  0.001
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 4/70
# 191/191 [==============================] - ETA: 0s - loss: 3.6071 - accuracy: 0.2499 - macro_f1score: 0.0238 - weighted_f1score: 3.9148e-04
# Epoch 00004: val_loss improved from 3.72135 to 3.53139, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/ResNet18/004.h5
#
# Epoch 00004: val_accuracy improved from 0.24660 to 0.26732, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/ResNet18/004.h5
# 191/191 [==============================] - 433s 2s/step - loss: 3.6071 - accuracy: 0.2499 - macro_f1score: 0.0238 - weighted_f1score: 3.9148e-04 - val_loss: 3.5314 - val_accuracy: 0.2673 - val_macro_f1score: 0.0277 - val_weighted_f1score: 4.3531e-04
# Learning rate:  0.001
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 5/70
# 191/191 [==============================] - ETA: 0s - loss: 3.3706 - accuracy: 0.2849 - macro_f1score: 0.0326 - weighted_f1score: 4.9205e-04
# Epoch 00005: val_loss improved from 3.53139 to 3.34284, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/ResNet18/005.h5
#
# Epoch 00005: val_accuracy improved from 0.26732 to 0.29925, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/ResNet18/005.h5
# 191/191 [==============================] - 428s 2s/step - loss: 3.3706 - accuracy: 0.2849 - macro_f1score: 0.0326 - weighted_f1score: 4.9205e-04 - val_loss: 3.3428 - val_accuracy: 0.2993 - val_macro_f1score: 0.0380 - val_weighted_f1score: 5.6477e-04
# Learning rate:  0.001
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 6/70
# 191/191 [==============================] - ETA: 0s - loss: 3.1436 - accuracy: 0.3176 - macro_f1score: 0.0416 - weighted_f1score: 5.9550e-04
# Epoch 00006: val_loss improved from 3.34284 to 3.14242, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/ResNet18/006.h5
#
# Epoch 00006: val_accuracy improved from 0.29925 to 0.33696, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/ResNet18/006.h5
# 191/191 [==============================] - 428s 2s/step - loss: 3.1436 - accuracy: 0.3176 - macro_f1score: 0.0416 - weighted_f1score: 5.9550e-04 - val_loss: 3.1424 - val_accuracy: 0.3370 - val_macro_f1score: 0.0465 - val_weighted_f1score: 6.6387e-04
# Learning rate:  0.001
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 7/70
# 191/191 [==============================] - ETA: 0s - loss: 2.9681 - accuracy: 0.3475 - macro_f1score: 0.0505 - weighted_f1score: 6.9176e-04
# Epoch 00007: val_loss improved from 3.14242 to 2.99297, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/ResNet18/007.h5
#
# Epoch 00007: val_accuracy improved from 0.33696 to 0.36107, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/ResNet18/007.h5
# 191/191 [==============================] - 425s 2s/step - loss: 2.9681 - accuracy: 0.3475 - macro_f1score: 0.0505 - weighted_f1score: 6.9176e-04 - val_loss: 2.9930 - val_accuracy: 0.3611 - val_macro_f1score: 0.0550 - val_weighted_f1score: 7.4243e-04
# Learning rate:  0.001
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 8/70
# 191/191 [==============================] - ETA: 0s - loss: 2.8072 - accuracy: 0.3772 - macro_f1score: 0.0591 - weighted_f1score: 7.8013e-04
# Epoch 00008: val_loss improved from 2.99297 to 2.85205, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/ResNet18/008.h5
#
# Epoch 00008: val_accuracy improved from 0.36107 to 0.38417, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/ResNet18/008.h5
# 191/191 [==============================] - 428s 2s/step - loss: 2.8072 - accuracy: 0.3772 - macro_f1score: 0.0591 - weighted_f1score: 7.8013e-04 - val_loss: 2.8521 - val_accuracy: 0.3842 - val_macro_f1score: 0.0655 - val_weighted_f1score: 8.4289e-04
# Learning rate:  0.001
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 9/70
# 191/191 [==============================] - ETA: 0s - loss: 2.6493 - accuracy: 0.4010 - macro_f1score: 0.0682 - weighted_f1score: 8.7619e-04
# Epoch 00009: val_loss improved from 2.85205 to 2.76297, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/ResNet18/009.h5
#
# Epoch 00009: val_accuracy improved from 0.38417 to 0.40829, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/ResNet18/009.h5
# 191/191 [==============================] - 426s 2s/step - loss: 2.6493 - accuracy: 0.4010 - macro_f1score: 0.0682 - weighted_f1score: 8.7619e-04 - val_loss: 2.7630 - val_accuracy: 0.4083 - val_macro_f1score: 0.0717 - val_weighted_f1score: 9.2080e-04
# Learning rate:  0.001
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 10/70
# 191/191 [==============================] - ETA: 0s - loss: 2.4995 - accuracy: 0.4321 - macro_f1score: 0.0794 - weighted_f1score: 9.9069e-04
# Epoch 00010: val_loss improved from 2.76297 to 2.63817, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/ResNet18/010.h5
#
# Epoch 00010: val_accuracy improved from 0.40829 to 0.42663, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/ResNet18/010.h5
# 191/191 [==============================] - 427s 2s/step - loss: 2.4995 - accuracy: 0.4321 - macro_f1score: 0.0794 - weighted_f1score: 9.9069e-04 - val_loss: 2.6382 - val_accuracy: 0.4266 - val_macro_f1score: 0.0811 - val_weighted_f1score: 0.0010
# Learning rate:  0.001
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 11/70
# 191/191 [==============================] - ETA: 0s - loss: 2.3606 - accuracy: 0.4586 - macro_f1score: 0.0897 - weighted_f1score: 0.0011
# Epoch 00011: val_loss improved from 2.63817 to 2.57918, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/ResNet18/011.h5
#
# Epoch 00011: val_accuracy improved from 0.42663 to 0.43954, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/ResNet18/011.h5
# 191/191 [==============================] - 427s 2s/step - loss: 2.3606 - accuracy: 0.4586 - macro_f1score: 0.0897 - weighted_f1score: 0.0011 - val_loss: 2.5792 - val_accuracy: 0.4395 - val_macro_f1score: 0.0908 - val_weighted_f1score: 0.0011
# Learning rate:  0.001
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 12/70
# 191/191 [==============================] - ETA: 0s - loss: 2.2519 - accuracy: 0.4780 - macro_f1score: 0.0971 - weighted_f1score: 0.0012
# Epoch 00012: val_loss improved from 2.57918 to 2.49790, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/ResNet18/012.h5
#
# Epoch 00012: val_accuracy improved from 0.43954 to 0.45788, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/ResNet18/012.h5
# 191/191 [==============================] - 423s 2s/step - loss: 2.2519 - accuracy: 0.4780 - macro_f1score: 0.0971 - weighted_f1score: 0.0012 - val_loss: 2.4979 - val_accuracy: 0.4579 - val_macro_f1score: 0.0977 - val_weighted_f1score: 0.0012
# Learning rate:  0.001
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 13/70
# 191/191 [==============================] - ETA: 0s - loss: 2.1377 - accuracy: 0.4996 - macro_f1score: 0.1082 - weighted_f1score: 0.0013
# Epoch 00013: val_loss improved from 2.49790 to 2.40299, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/ResNet18/013.h5
#
# Epoch 00013: val_accuracy improved from 0.45788 to 0.46705, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/ResNet18/013.h5
# 191/191 [==============================] - 421s 2s/step - loss: 2.1377 - accuracy: 0.4996 - macro_f1score: 0.1082 - weighted_f1score: 0.0013 - val_loss: 2.4030 - val_accuracy: 0.4671 - val_macro_f1score: 0.1055 - val_weighted_f1score: 0.0013
# Learning rate:  0.001
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 14/70
# 191/191 [==============================] - ETA: 0s - loss: 2.0430 - accuracy: 0.5185 - macro_f1score: 0.1166 - weighted_f1score: 0.0014
# Epoch 00014: val_loss improved from 2.40299 to 2.35607, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/ResNet18/014.h5
#
# Epoch 00014: val_accuracy improved from 0.46705 to 0.47792, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/ResNet18/014.h5
# 191/191 [==============================] - 419s 2s/step - loss: 2.0430 - accuracy: 0.5185 - macro_f1score: 0.1166 - weighted_f1score: 0.0014 - val_loss: 2.3561 - val_accuracy: 0.4779 - val_macro_f1score: 0.1130 - val_weighted_f1score: 0.0013
# Learning rate:  0.001
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 15/70
# 191/191 [==============================] - ETA: 0s - loss: 1.9376 - accuracy: 0.5373 - macro_f1score: 0.1245 - weighted_f1score: 0.0015
# Epoch 00015: val_loss improved from 2.35607 to 2.28539, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/ResNet18/015.h5
#
# Epoch 00015: val_accuracy improved from 0.47792 to 0.48709, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/ResNet18/015.h5
# 191/191 [==============================] - 423s 2s/step - loss: 1.9376 - accuracy: 0.5373 - macro_f1score: 0.1245 - weighted_f1score: 0.0015 - val_loss: 2.2854 - val_accuracy: 0.4871 - val_macro_f1score: 0.1174 - val_weighted_f1score: 0.0014
# Learning rate:  0.001
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 16/70
# 191/191 [==============================] - ETA: 0s - loss: 1.8425 - accuracy: 0.5587 - macro_f1score: 0.1332 - weighted_f1score: 0.0016
# Epoch 00016: val_loss did not improve from 2.28539
#
# Epoch 00016: val_accuracy improved from 0.48709 to 0.49626, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/ResNet18/016.h5
# 191/191 [==============================] - 427s 2s/step - loss: 1.8425 - accuracy: 0.5587 - macro_f1score: 0.1332 - weighted_f1score: 0.0016 - val_loss: 2.2865 - val_accuracy: 0.4963 - val_macro_f1score: 0.1241 - val_weighted_f1score: 0.0014
# Learning rate:  0.001
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 17/70
# 191/191 [==============================] - ETA: 0s - loss: 1.7367 - accuracy: 0.5755 - macro_f1score: 0.1442 - weighted_f1score: 0.0016
# Epoch 00017: val_loss improved from 2.28539 to 2.21351, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/ResNet18/017.h5
#
# Epoch 00017: val_accuracy improved from 0.49626 to 0.50170, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/ResNet18/017.h5
# 191/191 [==============================] - 423s 2s/step - loss: 1.7367 - accuracy: 0.5755 - macro_f1score: 0.1442 - weighted_f1score: 0.0016 - val_loss: 2.2135 - val_accuracy: 0.5017 - val_macro_f1score: 0.1267 - val_weighted_f1score: 0.0015
# Learning rate:  0.001
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 18/70
# 191/191 [==============================] - ETA: 0s - loss: 1.6542 - accuracy: 0.5984 - macro_f1score: 0.1495 - weighted_f1score: 0.0017
# Epoch 00018: val_loss improved from 2.21351 to 2.15002, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/ResNet18/018.h5
#
# Epoch 00018: val_accuracy improved from 0.50170 to 0.52310, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/ResNet18/018.h5
# 191/191 [==============================] - 425s 2s/step - loss: 1.6542 - accuracy: 0.5984 - macro_f1score: 0.1495 - weighted_f1score: 0.0017 - val_loss: 2.1500 - val_accuracy: 0.5231 - val_macro_f1score: 0.1331 - val_weighted_f1score: 0.0016
# Learning rate:  0.001
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 19/70
# 191/191 [==============================] - ETA: 0s - loss: 1.5659 - accuracy: 0.6151 - macro_f1score: 0.1605 - weighted_f1score: 0.0018
# Epoch 00019: val_loss did not improve from 2.15002
#
# Epoch 00019: val_accuracy did not improve from 0.52310
# 191/191 [==============================] - 426s 2s/step - loss: 1.5659 - accuracy: 0.6151 - macro_f1score: 0.1605 - weighted_f1score: 0.0018 - val_loss: 2.1632 - val_accuracy: 0.5190 - val_macro_f1score: 0.1338 - val_weighted_f1score: 0.0016
# Learning rate:  0.001
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 20/70
# 191/191 [==============================] - ETA: 0s - loss: 1.4885 - accuracy: 0.6292 - macro_f1score: 0.1677 - weighted_f1score: 0.0019
# Epoch 00020: val_loss improved from 2.15002 to 2.13632, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/ResNet18/020.h5
#
# Epoch 00020: val_accuracy did not improve from 0.52310
# 191/191 [==============================] - 421s 2s/step - loss: 1.4885 - accuracy: 0.6292 - macro_f1score: 0.1677 - weighted_f1score: 0.0019 - val_loss: 2.1363 - val_accuracy: 0.5180 - val_macro_f1score: 0.1400 - val_weighted_f1score: 0.0016
# Learning rate:  0.001
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 21/70
# 191/191 [==============================] - ETA: 0s - loss: 1.4001 - accuracy: 0.6501 - macro_f1score: 0.1773 - weighted_f1score: 0.0020
# Epoch 00021: val_loss improved from 2.13632 to 2.09540, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/ResNet18/021.h5
#
# Epoch 00021: val_accuracy improved from 0.52310 to 0.52785, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/ResNet18/021.h5
# 191/191 [==============================] - 422s 2s/step - loss: 1.4001 - accuracy: 0.6501 - macro_f1score: 0.1773 - weighted_f1score: 0.0020 - val_loss: 2.0954 - val_accuracy: 0.5279 - val_macro_f1score: 0.1494 - val_weighted_f1score: 0.0017
# Learning rate:  0.001
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 22/70
# 191/191 [==============================] - ETA: 0s - loss: 1.3393 - accuracy: 0.6597 - macro_f1score: 0.1834 - weighted_f1score: 0.0021
# Epoch 00022: val_loss improved from 2.09540 to 2.03181, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/ResNet18/022.h5
#
# Epoch 00022: val_accuracy improved from 0.52785 to 0.53838, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/ResNet18/022.h5
# 191/191 [==============================] - 421s 2s/step - loss: 1.3393 - accuracy: 0.6597 - macro_f1score: 0.1834 - weighted_f1score: 0.0021 - val_loss: 2.0318 - val_accuracy: 0.5384 - val_macro_f1score: 0.1470 - val_weighted_f1score: 0.0017
# Learning rate:  0.001
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 23/70
# 191/191 [==============================] - ETA: 0s - loss: 1.2722 - accuracy: 0.6789 - macro_f1score: 0.1916 - weighted_f1score: 0.0021
# Epoch 00023: val_loss did not improve from 2.03181
#
# Epoch 00023: val_accuracy improved from 0.53838 to 0.53872, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/ResNet18/023.h5
# 191/191 [==============================] - 424s 2s/step - loss: 1.2722 - accuracy: 0.6789 - macro_f1score: 0.1916 - weighted_f1score: 0.0021 - val_loss: 2.0602 - val_accuracy: 0.5387 - val_macro_f1score: 0.1462 - val_weighted_f1score: 0.0017
# Learning rate:  0.001
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 24/70
# 191/191 [==============================] - ETA: 0s - loss: 1.2043 - accuracy: 0.6936 - macro_f1score: 0.1984 - weighted_f1score: 0.0022
# Epoch 00024: val_loss improved from 2.03181 to 2.01882, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/ResNet18/024.h5
#
# Epoch 00024: val_accuracy improved from 0.53872 to 0.54348, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/ResNet18/024.h5
# 191/191 [==============================] - 426s 2s/step - loss: 1.2043 - accuracy: 0.6936 - macro_f1score: 0.1984 - weighted_f1score: 0.0022 - val_loss: 2.0188 - val_accuracy: 0.5435 - val_macro_f1score: 0.1504 - val_weighted_f1score: 0.0018
# Learning rate:  0.001
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 25/70
# 191/191 [==============================] - ETA: 0s - loss: 1.1445 - accuracy: 0.7092 - macro_f1score: 0.2070 - weighted_f1score: 0.0023
# Epoch 00025: val_loss improved from 2.01882 to 1.99670, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/ResNet18/025.h5
#
# Epoch 00025: val_accuracy improved from 0.54348 to 0.55537, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/ResNet18/025.h5
# 191/191 [==============================] - 427s 2s/step - loss: 1.1445 - accuracy: 0.7092 - macro_f1score: 0.2070 - weighted_f1score: 0.0023 - val_loss: 1.9967 - val_accuracy: 0.5554 - val_macro_f1score: 0.1598 - val_weighted_f1score: 0.0018
# Learning rate:  0.001
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 26/70
# 191/191 [==============================] - ETA: 0s - loss: 1.0771 - accuracy: 0.7251 - macro_f1score: 0.2136 - weighted_f1score: 0.0024
# Epoch 00026: val_loss did not improve from 1.99670
#
# Epoch 00026: val_accuracy did not improve from 0.55537
# 191/191 [==============================] - 426s 2s/step - loss: 1.0771 - accuracy: 0.7251 - macro_f1score: 0.2136 - weighted_f1score: 0.0024 - val_loss: 2.0623 - val_accuracy: 0.5387 - val_macro_f1score: 0.1548 - val_weighted_f1score: 0.0018
# Learning rate:  0.001
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 27/70
# 191/191 [==============================] - ETA: 0s - loss: 1.0247 - accuracy: 0.7320 - macro_f1score: 0.2201 - weighted_f1score: 0.0024
# Epoch 00027: val_loss did not improve from 1.99670
#
# Epoch 00027: val_accuracy did not improve from 0.55537
# 191/191 [==============================] - 427s 2s/step - loss: 1.0247 - accuracy: 0.7320 - macro_f1score: 0.2201 - weighted_f1score: 0.0024 - val_loss: 2.0239 - val_accuracy: 0.5530 - val_macro_f1score: 0.1599 - val_weighted_f1score: 0.0018
# Learning rate:  0.001
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 28/70
# 191/191 [==============================] - ETA: 0s - loss: 0.9550 - accuracy: 0.7491 - macro_f1score: 0.2279 - weighted_f1score: 0.0025
# Epoch 00028: val_loss improved from 1.99670 to 1.99235, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/ResNet18/028.h5
#
# Epoch 00028: val_accuracy improved from 0.55537 to 0.56216, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/ResNet18/028.h5
# 191/191 [==============================] - 425s 2s/step - loss: 0.9550 - accuracy: 0.7491 - macro_f1score: 0.2279 - weighted_f1score: 0.0025 - val_loss: 1.9923 - val_accuracy: 0.5622 - val_macro_f1score: 0.1649 - val_weighted_f1score: 0.0019
# Learning rate:  0.001
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 29/70
# 191/191 [==============================] - ETA: 0s - loss: 0.9115 - accuracy: 0.7628 - macro_f1score: 0.2338 - weighted_f1score: 0.0025
# Epoch 00029: val_loss improved from 1.99235 to 1.97512, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/ResNet18/029.h5
#
# Epoch 00029: val_accuracy improved from 0.56216 to 0.56929, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/ResNet18/029.h5
# 191/191 [==============================] - 424s 2s/step - loss: 0.9115 - accuracy: 0.7628 - macro_f1score: 0.2338 - weighted_f1score: 0.0025 - val_loss: 1.9751 - val_accuracy: 0.5693 - val_macro_f1score: 0.1695 - val_weighted_f1score: 0.0019
# Learning rate:  0.001
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 30/70
# 191/191 [==============================] - ETA: 0s - loss: 0.8431 - accuracy: 0.7771 - macro_f1score: 0.2430 - weighted_f1score: 0.0027
# Epoch 00030: val_loss did not improve from 1.97512
#
# Epoch 00030: val_accuracy did not improve from 0.56929
# 191/191 [==============================] - 424s 2s/step - loss: 0.8431 - accuracy: 0.7771 - macro_f1score: 0.2430 - weighted_f1score: 0.0027 - val_loss: 1.9988 - val_accuracy: 0.5669 - val_macro_f1score: 0.1681 - val_weighted_f1score: 0.0019
# Learning rate:  0.001
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 31/70
# 191/191 [==============================] - ETA: 0s - loss: 0.8084 - accuracy: 0.7833 - macro_f1score: 0.2485 - weighted_f1score: 0.0027
# Epoch 00031: val_loss did not improve from 1.97512
#
# Epoch 00031: val_accuracy did not improve from 0.56929
# 191/191 [==============================] - 423s 2s/step - loss: 0.8084 - accuracy: 0.7833 - macro_f1score: 0.2485 - weighted_f1score: 0.0027 - val_loss: 2.0123 - val_accuracy: 0.5649 - val_macro_f1score: 0.1731 - val_weighted_f1score: 0.0020
# Learning rate:  0.001
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 32/70
# 191/191 [==============================] - ETA: 0s - loss: 0.7580 - accuracy: 0.7999 - macro_f1score: 0.2552 - weighted_f1score: 0.0028
# Epoch 00032: val_loss did not improve from 1.97512
#
# Epoch 00032: val_accuracy did not improve from 0.56929
# 191/191 [==============================] - 422s 2s/step - loss: 0.7580 - accuracy: 0.7999 - macro_f1score: 0.2552 - weighted_f1score: 0.0028 - val_loss: 1.9893 - val_accuracy: 0.5673 - val_macro_f1score: 0.1740 - val_weighted_f1score: 0.0019
# Learning rate:  0.001
#
# Epoch 00033: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 33/70
# 191/191 [==============================] - ETA: 0s - loss: 0.7023 - accuracy: 0.8099 - macro_f1score: 0.2609 - weighted_f1score: 0.0028
# Epoch 00033: val_loss did not improve from 1.97512
#
# Epoch 00033: val_accuracy did not improve from 0.56929
# 191/191 [==============================] - 420s 2s/step - loss: 0.7023 - accuracy: 0.8099 - macro_f1score: 0.2609 - weighted_f1score: 0.0028 - val_loss: 2.0161 - val_accuracy: 0.5628 - val_macro_f1score: 0.1688 - val_weighted_f1score: 0.0019
# Learning rate:  0.001
#
# Epoch 00034: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 34/70
# 191/191 [==============================] - ETA: 0s - loss: 0.7003 - accuracy: 0.8103 - macro_f1score: 0.2633 - weighted_f1score: 0.0028
# Epoch 00034: val_loss improved from 1.97512 to 1.96930, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/ResNet18/034.h5
#
# Epoch 00034: val_accuracy improved from 0.56929 to 0.57031, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/ResNet18/034.h5
# 191/191 [==============================] - 419s 2s/step - loss: 0.7003 - accuracy: 0.8103 - macro_f1score: 0.2633 - weighted_f1score: 0.0028 - val_loss: 1.9693 - val_accuracy: 0.5703 - val_macro_f1score: 0.1694 - val_weighted_f1score: 0.0020
# Learning rate:  0.001
#
# Epoch 00035: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 35/70
# 191/191 [==============================] - ETA: 0s - loss: 0.6236 - accuracy: 0.8334 - macro_f1score: 0.2728 - weighted_f1score: 0.0029
# Epoch 00035: val_loss did not improve from 1.96930
#
# Epoch 00035: val_accuracy did not improve from 0.57031
# 191/191 [==============================] - 421s 2s/step - loss: 0.6236 - accuracy: 0.8334 - macro_f1score: 0.2728 - weighted_f1score: 0.0029 - val_loss: 2.0079 - val_accuracy: 0.5696 - val_macro_f1score: 0.1738 - val_weighted_f1score: 0.0020
# Learning rate:  0.001
#
# Epoch 00036: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 36/70
# 191/191 [==============================] - ETA: 0s - loss: 0.5993 - accuracy: 0.8357 - macro_f1score: 0.2769 - weighted_f1score: 0.0030
# Epoch 00036: val_loss did not improve from 1.96930
#
# Epoch 00036: val_accuracy did not improve from 0.57031
# 191/191 [==============================] - 419s 2s/step - loss: 0.5993 - accuracy: 0.8357 - macro_f1score: 0.2769 - weighted_f1score: 0.0030 - val_loss: 2.0522 - val_accuracy: 0.5618 - val_macro_f1score: 0.1653 - val_weighted_f1score: 0.0019
# Learning rate:  0.001
#
# Epoch 00037: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 37/70
# 191/191 [==============================] - ETA: 0s - loss: 0.5616 - accuracy: 0.8487 - macro_f1score: 0.2826 - weighted_f1score: 0.0030
# Epoch 00037: val_loss did not improve from 1.96930
#
# Epoch 00037: val_accuracy did not improve from 0.57031
# 191/191 [==============================] - 421s 2s/step - loss: 0.5616 - accuracy: 0.8487 - macro_f1score: 0.2826 - weighted_f1score: 0.0030 - val_loss: 2.0416 - val_accuracy: 0.5703 - val_macro_f1score: 0.1774 - val_weighted_f1score: 0.0020
# Learning rate:  0.001
#
# Epoch 00038: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 38/70
# 191/191 [==============================] - ETA: 0s - loss: 0.5262 - accuracy: 0.8564 - macro_f1score: 0.2877 - weighted_f1score: 0.0031
# Epoch 00038: val_loss did not improve from 1.96930
#
# Epoch 00038: val_accuracy improved from 0.57031 to 0.57337, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/ResNet18/038.h5
# 191/191 [==============================] - 425s 2s/step - loss: 0.5262 - accuracy: 0.8564 - macro_f1score: 0.2877 - weighted_f1score: 0.0031 - val_loss: 2.0242 - val_accuracy: 0.5734 - val_macro_f1score: 0.1771 - val_weighted_f1score: 0.0020
# Learning rate:  0.001
#
# Epoch 00039: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 39/70
# 191/191 [==============================] - ETA: 0s - loss: 0.5137 - accuracy: 0.8596 - macro_f1score: 0.2900 - weighted_f1score: 0.0031
# Epoch 00039: val_loss did not improve from 1.96930
#
# Epoch 00039: val_accuracy did not improve from 0.57337
# 191/191 [==============================] - 424s 2s/step - loss: 0.5137 - accuracy: 0.8596 - macro_f1score: 0.2900 - weighted_f1score: 0.0031 - val_loss: 2.0704 - val_accuracy: 0.5703 - val_macro_f1score: 0.1769 - val_weighted_f1score: 0.0020
# Learning rate:  0.001
#
# Epoch 00040: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 40/70
# 191/191 [==============================] - ETA: 0s - loss: 0.4705 - accuracy: 0.8696 - macro_f1score: 0.2958 - weighted_f1score: 0.0032
# Epoch 00040: val_loss did not improve from 1.96930
#
# Epoch 00040: val_accuracy improved from 0.57337 to 0.58594, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/ResNet18/040.h5
# 191/191 [==============================] - 421s 2s/step - loss: 0.4705 - accuracy: 0.8696 - macro_f1score: 0.2958 - weighted_f1score: 0.0032 - val_loss: 2.0245 - val_accuracy: 0.5859 - val_macro_f1score: 0.1841 - val_weighted_f1score: 0.0021
# Learning rate:  0.001
#
# Epoch 00041: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 41/70
# 191/191 [==============================] - ETA: 0s - loss: 0.4644 - accuracy: 0.8726 - macro_f1score: 0.2978 - weighted_f1score: 0.0032
# Epoch 00041: val_loss did not improve from 1.96930
#
# Epoch 00041: val_accuracy did not improve from 0.58594
# 191/191 [==============================] - 421s 2s/step - loss: 0.4644 - accuracy: 0.8726 - macro_f1score: 0.2978 - weighted_f1score: 0.0032 - val_loss: 2.0690 - val_accuracy: 0.5700 - val_macro_f1score: 0.1801 - val_weighted_f1score: 0.0020
# Learning rate:  0.001
#
# Epoch 00042: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 42/70
# 191/191 [==============================] - ETA: 0s - loss: 0.4259 - accuracy: 0.8844 - macro_f1score: 0.3054 - weighted_f1score: 0.0033
# Epoch 00042: val_loss did not improve from 1.96930
#
# Epoch 00042: val_accuracy did not improve from 0.58594
# 191/191 [==============================] - 411s 2s/step - loss: 0.4259 - accuracy: 0.8844 - macro_f1score: 0.3054 - weighted_f1score: 0.0033 - val_loss: 2.0691 - val_accuracy: 0.5812 - val_macro_f1score: 0.1840 - val_weighted_f1score: 0.0021
# Learning rate:  0.001
#
# Epoch 00043: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 43/70
# 191/191 [==============================] - ETA: 0s - loss: 0.4009 - accuracy: 0.8891 - macro_f1score: 0.3076 - weighted_f1score: 0.0033
# Epoch 00043: val_loss did not improve from 1.96930
#
# Epoch 00043: val_accuracy did not improve from 0.58594
# 191/191 [==============================] - 419s 2s/step - loss: 0.4009 - accuracy: 0.8891 - macro_f1score: 0.3076 - weighted_f1score: 0.0033 - val_loss: 2.1231 - val_accuracy: 0.5781 - val_macro_f1score: 0.1842 - val_weighted_f1score: 0.0021
# Learning rate:  0.001
#
# Epoch 00044: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 44/70
# 191/191 [==============================] - ETA: 0s - loss: 0.3897 - accuracy: 0.8901 - macro_f1score: 0.3084 - weighted_f1score: 0.0033
# Epoch 00044: val_loss did not improve from 1.96930
#
# Epoch 00044: val_accuracy did not improve from 0.58594
# 191/191 [==============================] - 422s 2s/step - loss: 0.3897 - accuracy: 0.8901 - macro_f1score: 0.3084 - weighted_f1score: 0.0033 - val_loss: 2.1515 - val_accuracy: 0.5588 - val_macro_f1score: 0.1796 - val_weighted_f1score: 0.0020
# Learning rate:  0.001
#
# Epoch 00045: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 45/70
# 191/191 [==============================] - ETA: 0s - loss: 0.3835 - accuracy: 0.8935 - macro_f1score: 0.3106 - weighted_f1score: 0.0033
# Epoch 00045: val_loss did not improve from 1.96930
#
# Epoch 00045: val_accuracy did not improve from 0.58594
# 191/191 [==============================] - 426s 2s/step - loss: 0.3835 - accuracy: 0.8935 - macro_f1score: 0.3106 - weighted_f1score: 0.0033 - val_loss: 2.0690 - val_accuracy: 0.5764 - val_macro_f1score: 0.1844 - val_weighted_f1score: 0.0021
# Learning rate:  0.001
#
# Epoch 00046: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 46/70
# 191/191 [==============================] - ETA: 0s - loss: 0.3889 - accuracy: 0.8913 - macro_f1score: 0.3106 - weighted_f1score: 0.0033
# Epoch 00046: val_loss did not improve from 1.96930
#
# Epoch 00046: val_accuracy did not improve from 0.58594
# 191/191 [==============================] - 424s 2s/step - loss: 0.3889 - accuracy: 0.8913 - macro_f1score: 0.3106 - weighted_f1score: 0.0033 - val_loss: 2.0601 - val_accuracy: 0.5839 - val_macro_f1score: 0.1841 - val_weighted_f1score: 0.0021
# Learning rate:  0.001
#
# Epoch 00047: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 47/70
# 191/191 [==============================] - ETA: 0s - loss: 0.3729 - accuracy: 0.8940 - macro_f1score: 0.3111 - weighted_f1score: 0.0033
# Epoch 00047: val_loss did not improve from 1.96930
#
# Epoch 00047: val_accuracy improved from 0.58594 to 0.59171, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/ResNet18/047.h5
# 191/191 [==============================] - 422s 2s/step - loss: 0.3729 - accuracy: 0.8940 - macro_f1score: 0.3111 - weighted_f1score: 0.0033 - val_loss: 2.0468 - val_accuracy: 0.5917 - val_macro_f1score: 0.1882 - val_weighted_f1score: 0.0021
# Learning rate:  0.001
#
# Epoch 00048: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 48/70
# 191/191 [==============================] - ETA: 0s - loss: 0.3557 - accuracy: 0.9002 - macro_f1score: 0.3155 - weighted_f1score: 0.0034
# Epoch 00048: val_loss did not improve from 1.96930
#
# Epoch 00048: val_accuracy did not improve from 0.59171
# 191/191 [==============================] - 421s 2s/step - loss: 0.3557 - accuracy: 0.9002 - macro_f1score: 0.3155 - weighted_f1score: 0.0034 - val_loss: 2.1276 - val_accuracy: 0.5819 - val_macro_f1score: 0.1850 - val_weighted_f1score: 0.0021
# Learning rate:  0.001
#
# Epoch 00049: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 49/70
# 191/191 [==============================] - ETA: 0s - loss: 0.3221 - accuracy: 0.9100 - macro_f1score: 0.3229 - weighted_f1score: 0.0034
# Epoch 00049: val_loss did not improve from 1.96930
#
# Epoch 00049: val_accuracy did not improve from 0.59171
# 191/191 [==============================] - 423s 2s/step - loss: 0.3221 - accuracy: 0.9100 - macro_f1score: 0.3229 - weighted_f1score: 0.0034 - val_loss: 2.1699 - val_accuracy: 0.5781 - val_macro_f1score: 0.1866 - val_weighted_f1score: 0.0021
# Learning rate:  0.001
#
# Epoch 00050: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 50/70
# 191/191 [==============================] - ETA: 0s - loss: 0.3219 - accuracy: 0.9101 - macro_f1score: 0.3226 - weighted_f1score: 0.0034
# Epoch 00050: val_loss did not improve from 1.96930
#
# Epoch 00050: val_accuracy did not improve from 0.59171
# 191/191 [==============================] - 422s 2s/step - loss: 0.3219 - accuracy: 0.9101 - macro_f1score: 0.3226 - weighted_f1score: 0.0034 - val_loss: 2.1535 - val_accuracy: 0.5724 - val_macro_f1score: 0.1830 - val_weighted_f1score: 0.0021
# Learning rate:  0.0001
#
# Epoch 00051: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 51/70
# 191/191 [==============================] - ETA: 0s - loss: 0.1144 - accuracy: 0.9766 - macro_f1score: 0.3576 - weighted_f1score: 0.0037
# Epoch 00051: val_loss did not improve from 1.96930
#
# Epoch 00051: val_accuracy did not improve from 0.59171
# 191/191 [==============================] - 423s 2s/step - loss: 0.1144 - accuracy: 0.9766 - macro_f1score: 0.3576 - weighted_f1score: 0.0037 - val_loss: 2.0660 - val_accuracy: 0.5907 - val_macro_f1score: 0.1944 - val_weighted_f1score: 0.0022
# Learning rate:  0.0001
#
# Epoch 00052: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 52/70
# 191/191 [==============================] - ETA: 0s - loss: 0.0847 - accuracy: 0.9861 - macro_f1score: 0.3598 - weighted_f1score: 0.0038
# Epoch 00052: val_loss did not improve from 1.96930
#
# Epoch 00052: val_accuracy improved from 0.59171 to 0.59205, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/ResNet18/052.h5
# 191/191 [==============================] - 426s 2s/step - loss: 0.0847 - accuracy: 0.9861 - macro_f1score: 0.3598 - weighted_f1score: 0.0038 - val_loss: 2.0545 - val_accuracy: 0.5921 - val_macro_f1score: 0.1927 - val_weighted_f1score: 0.0022
# Learning rate:  0.0001
#
# Epoch 00053: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 53/70
# 191/191 [==============================] - ETA: 0s - loss: 0.0729 - accuracy: 0.9885 - macro_f1score: 0.3645 - weighted_f1score: 0.0038
# Epoch 00053: val_loss did not improve from 1.96930
#
# Epoch 00053: val_accuracy improved from 0.59205 to 0.59307, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/ResNet18/053.h5
# 191/191 [==============================] - 424s 2s/step - loss: 0.0729 - accuracy: 0.9885 - macro_f1score: 0.3645 - weighted_f1score: 0.0038 - val_loss: 2.0555 - val_accuracy: 0.5931 - val_macro_f1score: 0.1926 - val_weighted_f1score: 0.0022
# Learning rate:  0.0001
#
# Epoch 00054: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 54/70
# 191/191 [==============================] - ETA: 0s - loss: 0.0675 - accuracy: 0.9896 - macro_f1score: 0.3652 - weighted_f1score: 0.0038
# Epoch 00054: val_loss did not improve from 1.96930
#
# Epoch 00054: val_accuracy did not improve from 0.59307
# 191/191 [==============================] - 424s 2s/step - loss: 0.0675 - accuracy: 0.9896 - macro_f1score: 0.3652 - weighted_f1score: 0.0038 - val_loss: 2.0587 - val_accuracy: 0.5927 - val_macro_f1score: 0.1926 - val_weighted_f1score: 0.0022
# Learning rate:  0.0001
#
# Epoch 00055: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 55/70
# 191/191 [==============================] - ETA: 0s - loss: 0.0600 - accuracy: 0.9916 - macro_f1score: 0.3660 - weighted_f1score: 0.0038
# Epoch 00055: val_loss did not improve from 1.96930
#
# Epoch 00055: val_accuracy improved from 0.59307 to 0.59579, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/ResNet18/055.h5
# 191/191 [==============================] - 427s 2s/step - loss: 0.0600 - accuracy: 0.9916 - macro_f1score: 0.3660 - weighted_f1score: 0.0038 - val_loss: 2.0350 - val_accuracy: 0.5958 - val_macro_f1score: 0.1948 - val_weighted_f1score: 0.0022
# Learning rate:  0.0001
#
# Epoch 00056: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 56/70
# 191/191 [==============================] - ETA: 0s - loss: 0.0557 - accuracy: 0.9927 - macro_f1score: 0.3671 - weighted_f1score: 0.0038
# Epoch 00056: val_loss did not improve from 1.96930
#
# Epoch 00056: val_accuracy improved from 0.59579 to 0.59715, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/ResNet18/056.h5
# 191/191 [==============================] - 423s 2s/step - loss: 0.0557 - accuracy: 0.9927 - macro_f1score: 0.3671 - weighted_f1score: 0.0038 - val_loss: 2.0523 - val_accuracy: 0.5971 - val_macro_f1score: 0.1956 - val_weighted_f1score: 0.0022
# Learning rate:  0.0001
#
# Epoch 00057: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 57/70
# 191/191 [==============================] - ETA: 0s - loss: 0.0520 - accuracy: 0.9933 - macro_f1score: 0.3669 - weighted_f1score: 0.0038
# Epoch 00057: val_loss did not improve from 1.96930
#
# Epoch 00057: val_accuracy did not improve from 0.59715
# 191/191 [==============================] - 421s 2s/step - loss: 0.0520 - accuracy: 0.9933 - macro_f1score: 0.3669 - weighted_f1score: 0.0038 - val_loss: 2.0698 - val_accuracy: 0.5931 - val_macro_f1score: 0.1928 - val_weighted_f1score: 0.0022
# Learning rate:  0.0001
#
# Epoch 00058: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 58/70
# 191/191 [==============================] - ETA: 0s - loss: 0.0473 - accuracy: 0.9940 - macro_f1score: 0.3664 - weighted_f1score: 0.0039
# Epoch 00058: val_loss did not improve from 1.96930
#
# Epoch 00058: val_accuracy did not improve from 0.59715
# 191/191 [==============================] - 422s 2s/step - loss: 0.0473 - accuracy: 0.9940 - macro_f1score: 0.3664 - weighted_f1score: 0.0039 - val_loss: 2.0663 - val_accuracy: 0.5968 - val_macro_f1score: 0.1973 - val_weighted_f1score: 0.0022
# Learning rate:  0.0001
#
# Epoch 00059: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 59/70
# 191/191 [==============================] - ETA: 0s - loss: 0.0446 - accuracy: 0.9944 - macro_f1score: 0.3673 - weighted_f1score: 0.0039
# Epoch 00059: val_loss did not improve from 1.96930
#
# Epoch 00059: val_accuracy did not improve from 0.59715
# 191/191 [==============================] - 425s 2s/step - loss: 0.0446 - accuracy: 0.9944 - macro_f1score: 0.3673 - weighted_f1score: 0.0039 - val_loss: 2.0628 - val_accuracy: 0.5958 - val_macro_f1score: 0.1938 - val_weighted_f1score: 0.0022
# Learning rate:  0.0001
#
# Epoch 00060: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 60/70
# 191/191 [==============================] - ETA: 0s - loss: 0.0416 - accuracy: 0.9949 - macro_f1score: 0.3676 - weighted_f1score: 0.0039
# Epoch 00060: val_loss did not improve from 1.96930
#
# Epoch 00060: val_accuracy improved from 0.59715 to 0.60020, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/ResNet18/060.h5
# 191/191 [==============================] - 430s 2s/step - loss: 0.0416 - accuracy: 0.9949 - macro_f1score: 0.3676 - weighted_f1score: 0.0039 - val_loss: 2.0826 - val_accuracy: 0.6002 - val_macro_f1score: 0.1909 - val_weighted_f1score: 0.0022
# Learning rate:  0.0001
#
# Epoch 00061: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 61/70
# 191/191 [==============================] - ETA: 0s - loss: 0.0376 - accuracy: 0.9960 - macro_f1score: 0.3693 - weighted_f1score: 0.0039
# Epoch 00061: val_loss did not improve from 1.96930
#
# Epoch 00061: val_accuracy did not improve from 0.60020
# 191/191 [==============================] - 427s 2s/step - loss: 0.0376 - accuracy: 0.9960 - macro_f1score: 0.3693 - weighted_f1score: 0.0039 - val_loss: 2.0797 - val_accuracy: 0.5982 - val_macro_f1score: 0.1990 - val_weighted_f1score: 0.0022
# Learning rate:  0.0001
#
# Epoch 00062: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 62/70
# 191/191 [==============================] - ETA: 0s - loss: 0.0375 - accuracy: 0.9957 - macro_f1score: 0.3678 - weighted_f1score: 0.0039
# Epoch 00062: val_loss did not improve from 1.96930
#
# Epoch 00062: val_accuracy did not improve from 0.60020
# 191/191 [==============================] - 422s 2s/step - loss: 0.0375 - accuracy: 0.9957 - macro_f1score: 0.3678 - weighted_f1score: 0.0039 - val_loss: 2.0847 - val_accuracy: 0.5954 - val_macro_f1score: 0.1933 - val_weighted_f1score: 0.0022
# Learning rate:  0.0001
#
# Epoch 00063: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 63/70
# 191/191 [==============================] - ETA: 0s - loss: 0.0357 - accuracy: 0.9957 - macro_f1score: 0.3703 - weighted_f1score: 0.0039
# Epoch 00063: val_loss did not improve from 1.96930
#
# Epoch 00063: val_accuracy did not improve from 0.60020
# 191/191 [==============================] - 426s 2s/step - loss: 0.0357 - accuracy: 0.9957 - macro_f1score: 0.3703 - weighted_f1score: 0.0039 - val_loss: 2.0905 - val_accuracy: 0.5924 - val_macro_f1score: 0.1969 - val_weighted_f1score: 0.0022
# Learning rate:  0.0001
#
# Epoch 00064: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 64/70
# 191/191 [==============================] - ETA: 0s - loss: 0.0339 - accuracy: 0.9965 - macro_f1score: 0.3683 - weighted_f1score: 0.0039
# Epoch 00064: val_loss did not improve from 1.96930
#
# Epoch 00064: val_accuracy improved from 0.60020 to 0.60326, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/ResNet18/064.h5
# 191/191 [==============================] - 423s 2s/step - loss: 0.0339 - accuracy: 0.9965 - macro_f1score: 0.3683 - weighted_f1score: 0.0039 - val_loss: 2.0881 - val_accuracy: 0.6033 - val_macro_f1score: 0.1990 - val_weighted_f1score: 0.0022
# Learning rate:  0.0001
#
# Epoch 00065: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 65/70
# 191/191 [==============================] - ETA: 0s - loss: 0.0334 - accuracy: 0.9960 - macro_f1score: 0.3686 - weighted_f1score: 0.0039
# Epoch 00065: val_loss did not improve from 1.96930
#
# Epoch 00065: val_accuracy did not improve from 0.60326
# 191/191 [==============================] - 421s 2s/step - loss: 0.0334 - accuracy: 0.9960 - macro_f1score: 0.3686 - weighted_f1score: 0.0039 - val_loss: 2.0954 - val_accuracy: 0.5944 - val_macro_f1score: 0.1947 - val_weighted_f1score: 0.0022
# Learning rate:  0.0001
#
# Epoch 00066: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 66/70
# 191/191 [==============================] - ETA: 0s - loss: 0.0320 - accuracy: 0.9965 - macro_f1score: 0.3673 - weighted_f1score: 0.0039
# Epoch 00066: val_loss did not improve from 1.96930
#
# Epoch 00066: val_accuracy did not improve from 0.60326
# 191/191 [==============================] - 429s 2s/step - loss: 0.0320 - accuracy: 0.9965 - macro_f1score: 0.3673 - weighted_f1score: 0.0039 - val_loss: 2.0946 - val_accuracy: 0.5995 - val_macro_f1score: 0.1968 - val_weighted_f1score: 0.0022
# Learning rate:  0.0001
#
# Epoch 00067: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 67/70
# 191/191 [==============================] - ETA: 0s - loss: 0.0300 - accuracy: 0.9966 - macro_f1score: 0.3697 - weighted_f1score: 0.0039
# Epoch 00067: val_loss did not improve from 1.96930
#
# Epoch 00067: val_accuracy did not improve from 0.60326
# 191/191 [==============================] - 424s 2s/step - loss: 0.0300 - accuracy: 0.9966 - macro_f1score: 0.3697 - weighted_f1score: 0.0039 - val_loss: 2.1205 - val_accuracy: 0.5968 - val_macro_f1score: 0.2002 - val_weighted_f1score: 0.0022
# Learning rate:  0.0001
#
# Epoch 00068: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 68/70
# 191/191 [==============================] - ETA: 0s - loss: 0.0291 - accuracy: 0.9968 - macro_f1score: 0.3670 - weighted_f1score: 0.0039
# Epoch 00068: val_loss did not improve from 1.96930
#
# Epoch 00068: val_accuracy did not improve from 0.60326
# 191/191 [==============================] - 413s 2s/step - loss: 0.0291 - accuracy: 0.9968 - macro_f1score: 0.3670 - weighted_f1score: 0.0039 - val_loss: 2.1016 - val_accuracy: 0.6005 - val_macro_f1score: 0.1953 - val_weighted_f1score: 0.0022
# Learning rate:  0.0001
#
# Epoch 00069: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 69/70
# 191/191 [==============================] - ETA: 0s - loss: 0.0287 - accuracy: 0.9968 - macro_f1score: 0.3691 - weighted_f1score: 0.0039
# Epoch 00069: val_loss did not improve from 1.96930
#
# Epoch 00069: val_accuracy did not improve from 0.60326
# 191/191 [==============================] - 405s 2s/step - loss: 0.0287 - accuracy: 0.9968 - macro_f1score: 0.3691 - weighted_f1score: 0.0039 - val_loss: 2.0888 - val_accuracy: 0.6022 - val_macro_f1score: 0.1978 - val_weighted_f1score: 0.0022
# Learning rate:  0.0001
#
# Epoch 00070: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 70/70
# 191/191 [==============================] - ETA: 0s - loss: 0.0291 - accuracy: 0.9963 - macro_f1score: 0.3684 - weighted_f1score: 0.0039
# Epoch 00070: val_loss did not improve from 1.96930
#
# Epoch 00070: val_accuracy did not improve from 0.60326
# 191/191 [==============================] - 407s 2s/step - loss: 0.0291 - accuracy: 0.9963 - macro_f1score: 0.3684 - weighted_f1score: 0.0039 - val_loss: 2.1330 - val_accuracy: 0.5995 - val_macro_f1score: 0.1954 - val_weighted_f1score: 0.0022

# %% [markdown]
# ### 2) ResNet18 Evaluate

# %%
# 1. epoch=maximum
loss , acc, mf1, wf1 = model.evaluate(test_generator,steps=int(len(x_test)/batch_sizes))
print('[Test Loss: %.4f /  Test Accuracy: %.4f / Test Macro f1: %.4f / Test Weighted f1: %.4f]\n' % (loss,acc,mf1,wf1))
# Out:
# 24/24 [==============================] - 742s 31s/step - loss: 2.2116 - accuracy: 0.5866 - macro_f1score: 0.1983 - weighted_f1score: 0.0022
# [Test Loss: 2.2116 /  Test Accuracy: 0.5866 / Test Macro f1: 0.1983 / Test Weighted f1: 0.0022]

# %%
loss=history.history['loss']
val_loss=history.history['val_loss']
acc=history.history['accuracy']
val_acc=history.history['val_accuracy']
f1=history.history['macro_f1score']
val_f1=history.history['val_macro_f1score']
epochs=range(1,len(acc)+1)

data = np.array([epochs,loss,val_loss,acc,val_acc,f1,val_f1]).T

# %%
# data save
# epochs, loss, val_loss, acc, val_acc, f1, val_f1

np.savetxt(os.path.join(dir,'train_valid_output',number,model.name+'.txt'),data)

# %%
# data import
data = np.loadtxt(os.path.join(dir,'train_valid_output',number,'ResNet18.txt'))

# %%
epochs=data[:,0]
loss=data[:,1]
val_loss=data[:,2]
acc=data[:,3]
val_acc=data[:,4]

# %%
plt.plot(epochs[1:],acc[1:],'b',label='Training Acc')
plt.plot(epochs[1:],val_acc[1:],'r',label='Validation Acc')
plt.title('Training and Validation Accuracy')
plt.legend()
plt.figure()
plt.plot(epochs[10:],loss[10:],'b',label='Training Loss')
plt.plot(epochs[10:],val_loss[10:],'r',label='Validation Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()

# %%
# 이 아래는 내가 인위적으로 살펴보고 싶은 epoch에 대해서 결과값 출력 / resnet18

# %%
model=load_model(os.path.join(dir,'model_output',number,'ResNet18','031.h5'),custom_objects={"macro_f1score": macro_f1score,"weighted_f1score":weighted_f1score})

# %%
# 2. epoch=?
loss , acc, mf1, wf1 = model.evaluate(test_generator,steps=int(len(x_test)/batch_sizes))
print('[Test Loss: %.4f /  Test Accuracy: %.4f / Test Macro f1: %.4f / Test Weighted f1: %.4f]\n' % (loss,acc,mf1,wf1))
