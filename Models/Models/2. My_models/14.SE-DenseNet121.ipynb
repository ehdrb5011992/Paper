# %%
### 참고 :  https://sike6054.github.io/blog/paper/sixth-post/ 
### SE block 코드 참고 : https://sike6054.github.io/blog/paper/seventh-post/

# %% [markdown]
# # [SE-DenseNet121]

# %% [markdown]
# *KU LeeDongGyu*

# %% [markdown]
# ## Contents
# ---

# %% [markdown]
# 1. Data Preprocessing
# ```
# 1) Data Import
# 2) Data Augmentation
# ```
# 2. Support Functions & Almost Original SE-DenseNet121
# ```
# 1) Support Functions
# 2) Almost orginal SE-DenseNet121
# ```
# 3. SE-DenseNet121
# ```
# 1) SE-DenseNet121
# 2) SE-DenseNet121 Evaluate
# ```

# %% [markdown]
# ### Install Packages

# %% [markdown]
# ### Module

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
cd /content/drive/My Drive/Colab Notebooks/Paper
# Out:
# /content/drive/My Drive/Colab Notebooks/Paper

# %%
from f1score import macro_f1score,weighted_f1score

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import cv2
import tensorflow as tf
from tensorflow import keras as ks
from tensorflow.keras import backend as K 
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, Input, Concatenate, ZeroPadding2D ,GlobalMaxPooling2D, Reshape , Lambda , Add, Multiply
from tensorflow.keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D, Activation, BatchNormalization, AveragePooling2D , ZeroPadding2D, SeparableConv2D
from tensorflow.keras.layers import add
from tensorflow.keras.optimizers import Adam, RMSprop , SGD
from tensorflow.keras.callbacks import EarlyStopping , LearningRateScheduler, ModelCheckpoint, CSVLogger, Callback, ReduceLROnPlateau
from tensorflow.keras.regularizers import l1,l2,l1_l2
from tensorflow.keras.models import Model , load_model , Sequential
from tensorflow.keras.utils import plot_model , to_categorical, get_file
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
os.getcwd()
# Out:
# '/content/drive/My Drive/Colab Notebooks/Paper'

# %%
print(tf.__version__)
print(ks.__version__)
# Out:
# 2.3.0
# 2.4.0

# %%
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 15393394316623495238
# , name: "/device:XLA_CPU:0"
# device_type: "XLA_CPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 17880747087641440404
# physical_device_desc: "device: XLA_CPU device"
# , name: "/device:XLA_GPU:0"
# device_type: "XLA_GPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 12255544008660514913
# physical_device_desc: "device: XLA_GPU device"
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 15695549568
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 16061877172100707150
# physical_device_desc: "device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0"
# ]

# %% [markdown]
# ## 1. Data Preprocessing
# ---

# %% [markdown]
# ### 1) Data Import

# %%
# 바꿔서 살펴 볼 것들
# CALTECH, CIFAR100, FER, MIT
data_name = 'CALTECH'
gan_type = 'No_GAN'
number = '1'
size = 224 # sizes after cropping
super_size = 256 # sizes before cropping 
input_sizes = (size,size,3)
batch_sizes = 32
weight_decay = 4e-5
epochs = 70

# %%
# 참고 : https://stackoverflow.com/questions/32419510/how-to-get-reproducible-results-in-keras/52897216#52897216
# setting the seed number for random number generation for reproducibility.

from numpy.random import seed
import random


if number=='1':
    seed_num = 200225
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)
elif number=='2':
    seed_num = 727
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)
elif number=='3':
    seed_num = 115
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)
elif number=='4':
    seed_num = 501
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)
elif number=='5':
    seed_num = 517
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)

# %%
# data import

if data_name=='FER' :
    x_train =  np.zeros(28698)
    x_valid = np.zeros(3589)
    x_test = np.zeros(3588)
    classes = 7 
    tr_center = [0.50793296, 0.50793296, 0.50793296]
elif data_name=='MIT':
    x_train = np.zeros(12466)
    x_valid = np.zeros(1564)
    x_test = np.zeros(1590)
    classes = 67 
    tr_center = [0.47916578, 0.42029615, 0.36046057]
elif data_name=='CALTECH':
    x_train = np.zeros(24510)
    x_valid = np.zeros(2980)
    x_test = np.zeros(3118)
    classes = 257
    tr_center = [0.51397761, 0.49525248, 0.46555727]
elif data_name=='CIFAR100':
    x_train = np.zeros(39941)
    x_valid = np.zeros(10059)
    x_test = np.zeros(10000)
    classes = 100
    tr_center = [0.53393271, 0.51324147, 0.46450563]

# %%
dir = os.path.join(os.getcwd(),data_name,gan_type)

# %% [markdown]
# ### 2) Data Augmentation

# %%
# 참고 : https://jkjung-avt.github.io/keras-image-cropping/

def random_crop(img, random_crop_size):
    # Note: image_data_format is 'channel_last'
    assert img.shape[2] == 3 # img.shape[2] 가 3(rgb)이 아니면 assertion error 발생
    height, width = img.shape[0], img.shape[1]
    dy, dx = random_crop_size
    x = np.random.randint(0, width - dx + 1)
    y = np.random.randint(0, height - dy + 1)
    return img[y:(y+dy), x:(x+dx), :]


def crop_generator(batches, crop_length):
    """Take as input a Keras ImageGen (Iterator) and generate random
    crops from the image batches generated by the original iterator.
    """
    while True:
        batch_x, batch_y = next(batches)
        batch_crops = np.zeros((batch_x.shape[0], crop_length, crop_length, 3))
        for i in range(batch_x.shape[0]):
            batch_crops[i] = random_crop(batch_x[i], (crop_length, crop_length))
        yield (batch_crops, batch_y)

# %%
from tensorflow.keras.preprocessing.image import img_to_array,load_img
import glob

# 데이터 전체에 대해 centering 진행함.

def read_cal_image(img_path): 
    x = img_to_array(load_img(img_path)) # x는 채널별 평균값
    y = x.shape[0] * x.shape[1]# y는 데이터별 픽셀 수 (비중)

    x = 1/255. * x # scaling하고, centering값을 뽑아냄.
    x = np.mean(x, axis=(0,1))
    
    return np.hstack([x,y])

def calculate_centered_mean(dataset_path,x_train=x_train):
    num = len(x_train)
    space = np.empty((num,4))
    i=0

    for p in glob.glob(os.path.join(dataset_path,'*/*.*')) :
        space[i] = read_cal_image(p)
        i += 1

    ratio = space[:,3] / np.sum(space[:,3])

    return np.average(space[:,0:3],axis=0,weights=ratio)


# 아래의 함수를 돌려서 나온 결과값을 중심화 값으로 설정.

# train_mean = calculate_centered_mean(os.path.join(dir,'data/train')).reshape((1,1,3))

# %%
datagen_tr = ImageDataGenerator(
    rescale=1/255.,
    horizontal_flip=True,
    featurewise_center=True,
    featurewise_std_normalization=False,
    rotation_range=10,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=[0.9,1.0],
    fill_mode = 'nearest')
datagen_val = ImageDataGenerator(rescale=1/255.,featurewise_center=True)
datagen_tes = ImageDataGenerator(rescale=1/255.,featurewise_center=True)

# 원래는 이 자리에 fit 매서드를 써야하지만, 그냥 내가 중심화함수를 만들고 적용함. 

# 중심화 설정
datagen_tr.mean = np.array(tr_center, dtype=np.float32).reshape((1,1,3)) # RGB
datagen_val.mean = np.array(tr_center, dtype=np.float32).reshape((1,1,3)) # RGB
datagen_tes.mean = np.array(tr_center, dtype=np.float32).reshape((1,1,3)) # RGB

# %%
train_batches = datagen_tr.flow_from_directory(directory=os.path.join(dir,'data/train'),target_size=(super_size,super_size),batch_size=batch_sizes,class_mode='categorical') # fer : 28698 / mit : 12466 / caltech : 24509 / cifar : 39941
train_generator= crop_generator(train_batches, size)
valid_generator = datagen_val.flow_from_directory(directory=os.path.join(dir,'data/valid'),target_size=(size,size),batch_size=batch_sizes,class_mode='categorical') # fer : 3589 / mit : 1564 / caltech : 2980 / cifar : 10059
test_generator = datagen_tes.flow_from_directory(directory=os.path.join(dir,'data/test'),target_size=(size,size),batch_size=batch_sizes,class_mode='categorical') # fer : 3588 / mit : 1590 / caltech : 3118 / cifar : 10000
# Out:
# Found 24509 images belonging to 257 classes.
# Found 2980 images belonging to 257 classes.
# Found 3118 images belonging to 257 classes.

# %% [markdown]
# ## 2. Support Functions & Almost Original SE-DenseNet121
# ---

# %% [markdown]
# ### 1) Support Functions

# %%
# def lr_schedule(epoch):
#     init_lr = 1e-4
#     k = 0.04
#     lr = init_lr * np.exp(-k*epoch)
#     print('Learning rate: ', lr)
#     return lr

def lr_schedule(epoch):
    lr = 1e-3
    if epoch < 60:
        lr = lr
    else :
        lr = lr * 0.1
    print('Learning rate: ', lr)
    return lr

# %%
# SE block을 만들고 붙이자.
def SE_block(input_tensor,reduction_ratio):
    ch_input = K.int_shape(input_tensor)[-1]
    ch_reduced = ch_input//reduction_ratio
    
    # Squeeze
    x = GlobalAveragePooling2D()(input_tensor) 
    
    # Excitation
    x = Dense(ch_reduced, activation='relu', kernel_initializer='he_uniform', use_bias=False)(x) 
    x = Dense(ch_input, activation='sigmoid', use_bias=False)(x) 
    
    x = Reshape( (1, 1, ch_input) )(x)
    x = Multiply()([input_tensor, x]) # broadcasting 
    
    return x

# %%
def Conv_Block(x, growth_rate, activation='relu', weight_decay=weight_decay):
    x_l = BatchNormalization()(x)
    x_l = Activation(activation)(x_l)
    x_l = Conv2D(growth_rate*4, (1, 1), padding='same', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(x_l)
    
    x_l = BatchNormalization()(x_l)
    x_l = Activation(activation)(x_l)
    x_l = Conv2D(growth_rate, (3, 3), padding='same', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(x_l)
    
    x = Concatenate()([x, x_l])
    
    return x

# %%
def Dense_Block(x, layers, reduction_ratio, growth_rate):
    for i in range(layers):
        x = Conv_Block(x, growth_rate)

    # SE block 추가
    x = SE_block(x, reduction_ratio)

    return x

# %%
def Transition_Layer(x, reduction_ratio, compression_factor=0.5, activation='relu', weight_decay=weight_decay):
    reduced_filters = int(K.int_shape(x)[-1] * compression_factor)
    
    x = BatchNormalization()(x)
    x = Activation(activation)(x)
    x = Conv2D(reduced_filters, (1, 1), padding='same', kernel_initializer='he_normal', kernel_regularizer=l2(weight_decay))(x)
    
    x = AveragePooling2D((2, 2), padding='same', strides=2)(x)

    # SE block 추가
    x = SE_block(x, reduction_ratio)
    
    return x

# %% [markdown]
# ### 2) Almost Orginial SE-DenseNet121

# %%
def SE_DenseNet(input_shape, classes, weight_decay=weight_decay, reduction_ratio=16, growth_rate = 32, densenet_type='DenseNet_121', name = 'SE_DenseNet121'):

    model_input = Input(shape=input_shape)
    layers_in_block = {'DenseNet_121' : [6, 12, 24, 16],
                    'DenseNet_169' : [6, 12, 32, 32],
                    'DenseNet_201' : [6, 12, 48, 32],
                    'DenseNet_265' : [6, 12, 64, 48]}

    x = Conv2D(growth_rate*2, (7, 7), padding='same', strides=2, kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(model_input) # (224, 224, 3) -> (112, 112, 64)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    x = MaxPooling2D((3, 3), padding='same', strides=2)(x) # (112, 112, 64) -> (56, 56, 64)

    x = Dense_Block(x, layers_in_block[densenet_type][0], reduction_ratio, growth_rate)
    x = Transition_Layer(x, reduction_ratio)
    x = Dense_Block(x, layers_in_block[densenet_type][1], reduction_ratio, growth_rate)
    x = Transition_Layer(x, reduction_ratio)
    x = Dense_Block(x, layers_in_block[densenet_type][2], reduction_ratio, growth_rate)
    x = Transition_Layer(x, reduction_ratio)
    x = Dense_Block(x, layers_in_block[densenet_type][3], reduction_ratio, growth_rate)

    x = GlobalAveragePooling2D()(x)

    model_output = Dense(classes, activation='softmax')(x)

    model = Model(model_input, model_output, name=name)

    return model

# %% [markdown]
# ## 3. SE-DenseNet121
#
# ---

# %% [markdown]
# ### 1) SE-DenseNet121

# %%
# densenet

model = SE_DenseNet(input_shape=input_sizes, classes = classes, reduction_ratio=16, growth_rate = 32, densenet_type='DenseNet_121', name = 'SE_DenseNet121')

# %%
model.summary()
# Out:
# Model: "SE_DenseNet121"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 112, 112, 64) 9472        input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 112, 112, 64) 256         conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 112, 112, 64) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 56, 56, 64)   0           activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 56, 56, 64)   256         max_pooling2d[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 56, 56, 64)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 56, 56, 128)  8320        activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 56, 56, 128)  512         conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 56, 56, 128)  0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 56, 56, 32)   36896       activation_2[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 56, 56, 96)   0           max_pooling2d[0][0]
#                                                                  conv2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 56, 56, 96)   384         concatenate[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 56, 56, 96)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 56, 56, 128)  12416       activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 56, 56, 128)  512         conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 56, 56, 128)  0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 56, 56, 32)   36896       activation_4[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 56, 56, 128)  0           concatenate[0][0]
#                                                                  conv2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 56, 56, 128)  512         concatenate_1[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 56, 56, 128)  0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 56, 56, 128)  16512       activation_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 56, 56, 128)  512         conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 56, 56, 128)  0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 56, 56, 32)   36896       activation_6[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 56, 56, 160)  0           concatenate_1[0][0]
#                                                                  conv2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 56, 56, 160)  640         concatenate_2[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 56, 56, 160)  0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 56, 56, 128)  20608       activation_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 56, 56, 128)  512         conv2d_7[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 56, 56, 128)  0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 56, 56, 32)   36896       activation_8[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 56, 56, 192)  0           concatenate_2[0][0]
#                                                                  conv2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 56, 56, 192)  768         concatenate_3[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 56, 56, 192)  0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 56, 56, 128)  24704       activation_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 56, 56, 128)  512         conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 56, 56, 128)  0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 56, 56, 32)   36896       activation_10[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 56, 56, 224)  0           concatenate_3[0][0]
#                                                                  conv2d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 56, 56, 224)  896         concatenate_4[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 56, 56, 224)  0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 56, 56, 128)  28800       activation_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 56, 56, 128)  512         conv2d_11[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 56, 56, 128)  0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 56, 56, 32)   36896       activation_12[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 56, 56, 256)  0           concatenate_4[0][0]
#                                                                  conv2d_12[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 256)          0           concatenate_5[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 16)           4096        global_average_pooling2d[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 256)          4096        dense[0][0]
# __________________________________________________________________________________________________
# reshape (Reshape)               (None, 1, 1, 256)    0           dense_1[0][0]
# __________________________________________________________________________________________________
# multiply (Multiply)             (None, 56, 56, 256)  0           concatenate_5[0][0]
#                                                                  reshape[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 56, 56, 256)  1024        multiply[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 56, 56, 256)  0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 56, 56, 128)  32896       activation_13[0][0]
# __________________________________________________________________________________________________
# average_pooling2d (AveragePooli (None, 28, 28, 128)  0           conv2d_13[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_1 (Glo (None, 128)          0           average_pooling2d[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 8)            1024        global_average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 128)          1024        dense_2[0][0]
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, 1, 1, 128)    0           dense_3[0][0]
# __________________________________________________________________________________________________
# multiply_1 (Multiply)           (None, 28, 28, 128)  0           average_pooling2d[0][0]
#                                                                  reshape_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 28, 28, 128)  512         multiply_1[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 28, 28, 128)  0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 28, 28, 128)  16512       activation_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 28, 28, 128)  512         conv2d_14[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 28, 28, 128)  0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 28, 28, 32)   36896       activation_15[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 28, 28, 160)  0           multiply_1[0][0]
#                                                                  conv2d_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 28, 28, 160)  640         concatenate_6[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 28, 28, 160)  0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 28, 28, 128)  20608       activation_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 28, 28, 128)  512         conv2d_16[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 28, 28, 128)  0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 28, 28, 32)   36896       activation_17[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 28, 28, 192)  0           concatenate_6[0][0]
#                                                                  conv2d_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 28, 28, 192)  768         concatenate_7[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 28, 28, 192)  0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 28, 28, 128)  24704       activation_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 28, 28, 128)  512         conv2d_18[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 28, 28, 128)  0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 28, 28, 32)   36896       activation_19[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 28, 28, 224)  0           concatenate_7[0][0]
#                                                                  conv2d_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 28, 28, 224)  896         concatenate_8[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 28, 28, 224)  0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 28, 28, 128)  28800       activation_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 28, 28, 128)  512         conv2d_20[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 28, 28, 128)  0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 28, 28, 32)   36896       activation_21[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 28, 28, 256)  0           concatenate_8[0][0]
#                                                                  conv2d_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 28, 28, 256)  1024        concatenate_9[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 28, 28, 256)  0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 28, 28, 128)  32896       activation_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 28, 28, 128)  512         conv2d_22[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 28, 28, 128)  0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 28, 28, 32)   36896       activation_23[0][0]
# __________________________________________________________________________________________________
# concatenate_10 (Concatenate)    (None, 28, 28, 288)  0           concatenate_9[0][0]
#                                                                  conv2d_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 28, 28, 288)  1152        concatenate_10[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 28, 28, 288)  0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 28, 28, 128)  36992       activation_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 28, 28, 128)  512         conv2d_24[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 28, 28, 128)  0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 28, 28, 32)   36896       activation_25[0][0]
# __________________________________________________________________________________________________
# concatenate_11 (Concatenate)    (None, 28, 28, 320)  0           concatenate_10[0][0]
#                                                                  conv2d_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 28, 28, 320)  1280        concatenate_11[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 28, 28, 320)  0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 28, 28, 128)  41088       activation_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 28, 28, 128)  512         conv2d_26[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 28, 28, 128)  0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 28, 28, 32)   36896       activation_27[0][0]
# __________________________________________________________________________________________________
# concatenate_12 (Concatenate)    (None, 28, 28, 352)  0           concatenate_11[0][0]
#                                                                  conv2d_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 28, 28, 352)  1408        concatenate_12[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 28, 28, 352)  0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 28, 28, 128)  45184       activation_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 28, 28, 128)  512         conv2d_28[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 28, 28, 128)  0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 28, 28, 32)   36896       activation_29[0][0]
# __________________________________________________________________________________________________
# concatenate_13 (Concatenate)    (None, 28, 28, 384)  0           concatenate_12[0][0]
#                                                                  conv2d_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 28, 28, 384)  1536        concatenate_13[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 28, 28, 384)  0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 28, 28, 128)  49280       activation_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 28, 28, 128)  512         conv2d_30[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 28, 28, 128)  0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 28, 28, 32)   36896       activation_31[0][0]
# __________________________________________________________________________________________________
# concatenate_14 (Concatenate)    (None, 28, 28, 416)  0           concatenate_13[0][0]
#                                                                  conv2d_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 28, 28, 416)  1664        concatenate_14[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 28, 28, 416)  0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 28, 28, 128)  53376       activation_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 28, 28, 128)  512         conv2d_32[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 28, 28, 128)  0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 28, 28, 32)   36896       activation_33[0][0]
# __________________________________________________________________________________________________
# concatenate_15 (Concatenate)    (None, 28, 28, 448)  0           concatenate_14[0][0]
#                                                                  conv2d_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 28, 28, 448)  1792        concatenate_15[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 28, 28, 448)  0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 28, 28, 128)  57472       activation_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 28, 28, 128)  512         conv2d_34[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 28, 28, 128)  0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 28, 28, 32)   36896       activation_35[0][0]
# __________________________________________________________________________________________________
# concatenate_16 (Concatenate)    (None, 28, 28, 480)  0           concatenate_15[0][0]
#                                                                  conv2d_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 28, 28, 480)  1920        concatenate_16[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 28, 28, 480)  0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 28, 28, 128)  61568       activation_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 28, 28, 128)  512         conv2d_36[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 28, 28, 128)  0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 28, 28, 32)   36896       activation_37[0][0]
# __________________________________________________________________________________________________
# concatenate_17 (Concatenate)    (None, 28, 28, 512)  0           concatenate_16[0][0]
#                                                                  conv2d_37[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_2 (Glo (None, 512)          0           concatenate_17[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 32)           16384       global_average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 512)          16384       dense_4[0][0]
# __________________________________________________________________________________________________
# reshape_2 (Reshape)             (None, 1, 1, 512)    0           dense_5[0][0]
# __________________________________________________________________________________________________
# multiply_2 (Multiply)           (None, 28, 28, 512)  0           concatenate_17[0][0]
#                                                                  reshape_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 28, 28, 512)  2048        multiply_2[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 28, 28, 512)  0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 28, 28, 256)  131328      activation_38[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, 14, 14, 256)  0           conv2d_38[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_3 (Glo (None, 256)          0           average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 16)           4096        global_average_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 256)          4096        dense_6[0][0]
# __________________________________________________________________________________________________
# reshape_3 (Reshape)             (None, 1, 1, 256)    0           dense_7[0][0]
# __________________________________________________________________________________________________
# multiply_3 (Multiply)           (None, 14, 14, 256)  0           average_pooling2d_1[0][0]
#                                                                  reshape_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 14, 14, 256)  1024        multiply_3[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 14, 14, 256)  0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 14, 14, 128)  32896       activation_39[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 14, 14, 128)  512         conv2d_39[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 14, 14, 128)  0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 14, 14, 32)   36896       activation_40[0][0]
# __________________________________________________________________________________________________
# concatenate_18 (Concatenate)    (None, 14, 14, 288)  0           multiply_3[0][0]
#                                                                  conv2d_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 14, 14, 288)  1152        concatenate_18[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 14, 14, 288)  0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 14, 14, 128)  36992       activation_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 14, 14, 128)  512         conv2d_41[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 14, 14, 128)  0           batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 14, 14, 32)   36896       activation_42[0][0]
# __________________________________________________________________________________________________
# concatenate_19 (Concatenate)    (None, 14, 14, 320)  0           concatenate_18[0][0]
#                                                                  conv2d_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 14, 14, 320)  1280        concatenate_19[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 14, 14, 320)  0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 14, 14, 128)  41088       activation_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 14, 14, 128)  512         conv2d_43[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 14, 14, 128)  0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 14, 14, 32)   36896       activation_44[0][0]
# __________________________________________________________________________________________________
# concatenate_20 (Concatenate)    (None, 14, 14, 352)  0           concatenate_19[0][0]
#                                                                  conv2d_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 14, 14, 352)  1408        concatenate_20[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 14, 14, 352)  0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 14, 14, 128)  45184       activation_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 14, 14, 128)  512         conv2d_45[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 14, 14, 128)  0           batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 14, 14, 32)   36896       activation_46[0][0]
# __________________________________________________________________________________________________
# concatenate_21 (Concatenate)    (None, 14, 14, 384)  0           concatenate_20[0][0]
#                                                                  conv2d_46[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 14, 14, 384)  1536        concatenate_21[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 14, 14, 384)  0           batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 14, 14, 128)  49280       activation_47[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 14, 14, 128)  512         conv2d_47[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 14, 14, 128)  0           batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 14, 14, 32)   36896       activation_48[0][0]
# __________________________________________________________________________________________________
# concatenate_22 (Concatenate)    (None, 14, 14, 416)  0           concatenate_21[0][0]
#                                                                  conv2d_48[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 14, 14, 416)  1664        concatenate_22[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 14, 14, 416)  0           batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 14, 14, 128)  53376       activation_49[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 14, 14, 128)  512         conv2d_49[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, 14, 14, 128)  0           batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 14, 14, 32)   36896       activation_50[0][0]
# __________________________________________________________________________________________________
# concatenate_23 (Concatenate)    (None, 14, 14, 448)  0           concatenate_22[0][0]
#                                                                  conv2d_50[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 14, 14, 448)  1792        concatenate_23[0][0]
# __________________________________________________________________________________________________
# activation_51 (Activation)      (None, 14, 14, 448)  0           batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 14, 14, 128)  57472       activation_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 14, 14, 128)  512         conv2d_51[0][0]
# __________________________________________________________________________________________________
# activation_52 (Activation)      (None, 14, 14, 128)  0           batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 14, 14, 32)   36896       activation_52[0][0]
# __________________________________________________________________________________________________
# concatenate_24 (Concatenate)    (None, 14, 14, 480)  0           concatenate_23[0][0]
#                                                                  conv2d_52[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, 14, 14, 480)  1920        concatenate_24[0][0]
# __________________________________________________________________________________________________
# activation_53 (Activation)      (None, 14, 14, 480)  0           batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 14, 14, 128)  61568       activation_53[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, 14, 14, 128)  512         conv2d_53[0][0]
# __________________________________________________________________________________________________
# activation_54 (Activation)      (None, 14, 14, 128)  0           batch_normalization_54[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 14, 14, 32)   36896       activation_54[0][0]
# __________________________________________________________________________________________________
# concatenate_25 (Concatenate)    (None, 14, 14, 512)  0           concatenate_24[0][0]
#                                                                  conv2d_54[0][0]
# __________________________________________________________________________________________________
# batch_normalization_55 (BatchNo (None, 14, 14, 512)  2048        concatenate_25[0][0]
# __________________________________________________________________________________________________
# activation_55 (Activation)      (None, 14, 14, 512)  0           batch_normalization_55[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 14, 14, 128)  65664       activation_55[0][0]
# __________________________________________________________________________________________________
# batch_normalization_56 (BatchNo (None, 14, 14, 128)  512         conv2d_55[0][0]
# __________________________________________________________________________________________________
# activation_56 (Activation)      (None, 14, 14, 128)  0           batch_normalization_56[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 14, 14, 32)   36896       activation_56[0][0]
# __________________________________________________________________________________________________
# concatenate_26 (Concatenate)    (None, 14, 14, 544)  0           concatenate_25[0][0]
#                                                                  conv2d_56[0][0]
# __________________________________________________________________________________________________
# batch_normalization_57 (BatchNo (None, 14, 14, 544)  2176        concatenate_26[0][0]
# __________________________________________________________________________________________________
# activation_57 (Activation)      (None, 14, 14, 544)  0           batch_normalization_57[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 14, 14, 128)  69760       activation_57[0][0]
# __________________________________________________________________________________________________
# ...
# batch_normalization_101 (BatchN (None, 7, 7, 128)    512         conv2d_100[0][0]
# __________________________________________________________________________________________________
# activation_101 (Activation)     (None, 7, 7, 128)    0           batch_normalization_101[0][0]
# __________________________________________________________________________________________________
# conv2d_101 (Conv2D)             (None, 7, 7, 32)     36896       activation_101[0][0]
# __________________________________________________________________________________________________
# concatenate_48 (Concatenate)    (None, 7, 7, 736)    0           concatenate_47[0][0]
#                                                                  conv2d_101[0][0]
# __________________________________________________________________________________________________
# batch_normalization_102 (BatchN (None, 7, 7, 736)    2944        concatenate_48[0][0]
# __________________________________________________________________________________________________
# activation_102 (Activation)     (None, 7, 7, 736)    0           batch_normalization_102[0][0]
# __________________________________________________________________________________________________
# conv2d_102 (Conv2D)             (None, 7, 7, 128)    94336       activation_102[0][0]
# __________________________________________________________________________________________________
# batch_normalization_103 (BatchN (None, 7, 7, 128)    512         conv2d_102[0][0]
# __________________________________________________________________________________________________
# activation_103 (Activation)     (None, 7, 7, 128)    0           batch_normalization_103[0][0]
# __________________________________________________________________________________________________
# conv2d_103 (Conv2D)             (None, 7, 7, 32)     36896       activation_103[0][0]
# __________________________________________________________________________________________________
# concatenate_49 (Concatenate)    (None, 7, 7, 768)    0           concatenate_48[0][0]
#                                                                  conv2d_103[0][0]
# __________________________________________________________________________________________________
# batch_normalization_104 (BatchN (None, 7, 7, 768)    3072        concatenate_49[0][0]
# __________________________________________________________________________________________________
# activation_104 (Activation)     (None, 7, 7, 768)    0           batch_normalization_104[0][0]
# __________________________________________________________________________________________________
# conv2d_104 (Conv2D)             (None, 7, 7, 128)    98432       activation_104[0][0]
# __________________________________________________________________________________________________
# batch_normalization_105 (BatchN (None, 7, 7, 128)    512         conv2d_104[0][0]
# __________________________________________________________________________________________________
# activation_105 (Activation)     (None, 7, 7, 128)    0           batch_normalization_105[0][0]
# __________________________________________________________________________________________________
# conv2d_105 (Conv2D)             (None, 7, 7, 32)     36896       activation_105[0][0]
# __________________________________________________________________________________________________
# concatenate_50 (Concatenate)    (None, 7, 7, 800)    0           concatenate_49[0][0]
#                                                                  conv2d_105[0][0]
# __________________________________________________________________________________________________
# batch_normalization_106 (BatchN (None, 7, 7, 800)    3200        concatenate_50[0][0]
# __________________________________________________________________________________________________
# activation_106 (Activation)     (None, 7, 7, 800)    0           batch_normalization_106[0][0]
# __________________________________________________________________________________________________
# conv2d_106 (Conv2D)             (None, 7, 7, 128)    102528      activation_106[0][0]
# __________________________________________________________________________________________________
# batch_normalization_107 (BatchN (None, 7, 7, 128)    512         conv2d_106[0][0]
# __________________________________________________________________________________________________
# activation_107 (Activation)     (None, 7, 7, 128)    0           batch_normalization_107[0][0]
# __________________________________________________________________________________________________
# conv2d_107 (Conv2D)             (None, 7, 7, 32)     36896       activation_107[0][0]
# __________________________________________________________________________________________________
# concatenate_51 (Concatenate)    (None, 7, 7, 832)    0           concatenate_50[0][0]
#                                                                  conv2d_107[0][0]
# __________________________________________________________________________________________________
# batch_normalization_108 (BatchN (None, 7, 7, 832)    3328        concatenate_51[0][0]
# __________________________________________________________________________________________________
# activation_108 (Activation)     (None, 7, 7, 832)    0           batch_normalization_108[0][0]
# __________________________________________________________________________________________________
# conv2d_108 (Conv2D)             (None, 7, 7, 128)    106624      activation_108[0][0]
# __________________________________________________________________________________________________
# batch_normalization_109 (BatchN (None, 7, 7, 128)    512         conv2d_108[0][0]
# __________________________________________________________________________________________________
# activation_109 (Activation)     (None, 7, 7, 128)    0           batch_normalization_109[0][0]
# __________________________________________________________________________________________________
# conv2d_109 (Conv2D)             (None, 7, 7, 32)     36896       activation_109[0][0]
# __________________________________________________________________________________________________
# concatenate_52 (Concatenate)    (None, 7, 7, 864)    0           concatenate_51[0][0]
#                                                                  conv2d_109[0][0]
# __________________________________________________________________________________________________
# batch_normalization_110 (BatchN (None, 7, 7, 864)    3456        concatenate_52[0][0]
# __________________________________________________________________________________________________
# activation_110 (Activation)     (None, 7, 7, 864)    0           batch_normalization_110[0][0]
# __________________________________________________________________________________________________
# conv2d_110 (Conv2D)             (None, 7, 7, 128)    110720      activation_110[0][0]
# __________________________________________________________________________________________________
# batch_normalization_111 (BatchN (None, 7, 7, 128)    512         conv2d_110[0][0]
# __________________________________________________________________________________________________
# activation_111 (Activation)     (None, 7, 7, 128)    0           batch_normalization_111[0][0]
# __________________________________________________________________________________________________
# conv2d_111 (Conv2D)             (None, 7, 7, 32)     36896       activation_111[0][0]
# __________________________________________________________________________________________________
# concatenate_53 (Concatenate)    (None, 7, 7, 896)    0           concatenate_52[0][0]
#                                                                  conv2d_111[0][0]
# __________________________________________________________________________________________________
# batch_normalization_112 (BatchN (None, 7, 7, 896)    3584        concatenate_53[0][0]
# __________________________________________________________________________________________________
# activation_112 (Activation)     (None, 7, 7, 896)    0           batch_normalization_112[0][0]
# __________________________________________________________________________________________________
# conv2d_112 (Conv2D)             (None, 7, 7, 128)    114816      activation_112[0][0]
# __________________________________________________________________________________________________
# batch_normalization_113 (BatchN (None, 7, 7, 128)    512         conv2d_112[0][0]
# __________________________________________________________________________________________________
# activation_113 (Activation)     (None, 7, 7, 128)    0           batch_normalization_113[0][0]
# __________________________________________________________________________________________________
# conv2d_113 (Conv2D)             (None, 7, 7, 32)     36896       activation_113[0][0]
# __________________________________________________________________________________________________
# concatenate_54 (Concatenate)    (None, 7, 7, 928)    0           concatenate_53[0][0]
#                                                                  conv2d_113[0][0]
# __________________________________________________________________________________________________
# batch_normalization_114 (BatchN (None, 7, 7, 928)    3712        concatenate_54[0][0]
# __________________________________________________________________________________________________
# activation_114 (Activation)     (None, 7, 7, 928)    0           batch_normalization_114[0][0]
# __________________________________________________________________________________________________
# conv2d_114 (Conv2D)             (None, 7, 7, 128)    118912      activation_114[0][0]
# __________________________________________________________________________________________________
# batch_normalization_115 (BatchN (None, 7, 7, 128)    512         conv2d_114[0][0]
# __________________________________________________________________________________________________
# activation_115 (Activation)     (None, 7, 7, 128)    0           batch_normalization_115[0][0]
# __________________________________________________________________________________________________
# conv2d_115 (Conv2D)             (None, 7, 7, 32)     36896       activation_115[0][0]
# __________________________________________________________________________________________________
# concatenate_55 (Concatenate)    (None, 7, 7, 960)    0           concatenate_54[0][0]
#                                                                  conv2d_115[0][0]
# __________________________________________________________________________________________________
# batch_normalization_116 (BatchN (None, 7, 7, 960)    3840        concatenate_55[0][0]
# __________________________________________________________________________________________________
# activation_116 (Activation)     (None, 7, 7, 960)    0           batch_normalization_116[0][0]
# __________________________________________________________________________________________________
# conv2d_116 (Conv2D)             (None, 7, 7, 128)    123008      activation_116[0][0]
# __________________________________________________________________________________________________
# batch_normalization_117 (BatchN (None, 7, 7, 128)    512         conv2d_116[0][0]
# __________________________________________________________________________________________________
# activation_117 (Activation)     (None, 7, 7, 128)    0           batch_normalization_117[0][0]
# __________________________________________________________________________________________________
# conv2d_117 (Conv2D)             (None, 7, 7, 32)     36896       activation_117[0][0]
# __________________________________________________________________________________________________
# concatenate_56 (Concatenate)    (None, 7, 7, 992)    0           concatenate_55[0][0]
#                                                                  conv2d_117[0][0]
# __________________________________________________________________________________________________
# batch_normalization_118 (BatchN (None, 7, 7, 992)    3968        concatenate_56[0][0]
# __________________________________________________________________________________________________
# activation_118 (Activation)     (None, 7, 7, 992)    0           batch_normalization_118[0][0]
# __________________________________________________________________________________________________
# conv2d_118 (Conv2D)             (None, 7, 7, 128)    127104      activation_118[0][0]
# __________________________________________________________________________________________________
# batch_normalization_119 (BatchN (None, 7, 7, 128)    512         conv2d_118[0][0]
# __________________________________________________________________________________________________
# activation_119 (Activation)     (None, 7, 7, 128)    0           batch_normalization_119[0][0]
# __________________________________________________________________________________________________
# conv2d_119 (Conv2D)             (None, 7, 7, 32)     36896       activation_119[0][0]
# __________________________________________________________________________________________________
# concatenate_57 (Concatenate)    (None, 7, 7, 1024)   0           concatenate_56[0][0]
#                                                                  conv2d_119[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_6 (Glo (None, 1024)         0           concatenate_57[0][0]
# __________________________________________________________________________________________________
# dense_12 (Dense)                (None, 64)           65536       global_average_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# dense_13 (Dense)                (None, 1024)         65536       dense_12[0][0]
# __________________________________________________________________________________________________
# reshape_6 (Reshape)             (None, 1, 1, 1024)   0           dense_13[0][0]
# __________________________________________________________________________________________________
# multiply_6 (Multiply)           (None, 7, 7, 1024)   0           concatenate_57[0][0]
#                                                                  reshape_6[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_7 (Glo (None, 1024)         0           multiply_6[0][0]
# __________________________________________________________________________________________________
# dense_14 (Dense)                (None, 257)          263425      global_average_pooling2d_7[0][0]
# ==================================================================================================
# Total params: 7,653,185
# Trainable params: 7,571,585
# Non-trainable params: 81,600
# __________________________________________________________________________________________________

# %%
plot_model(model)

# %%
# 폴더 생성

os.makedirs(os.path.join(dir,'model_output',number,model.name), exist_ok=True)
os.makedirs(os.path.join(dir,'train_valid_output',number), exist_ok=True)

# %%
# 참고 : https://github.com/OverLordGoldDragon/keras-adamw

import sys
sys.path.append('/content/drive/My Drive/Colab Notebooks/Paper')
import utils
import optimizers_v2
from utils import get_weight_decays, fill_dict_in_order
from utils import reset_seeds, K_eval
from optimizers_v2 import AdamW, NadamW, SGDW

# %%
optimizer = AdamW(model=model, use_cosine_annealing=True, total_iterations = len(x_train) // batch_sizes , eta_min = 1e-2)
#optimizer = Adam()
filepath =  os.path.join(dir,'model_output',number,model.name,'{epoch:03d}.h5')

callbacks_list = [ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_weights_only=False, save_best_only=True, mode='min'),
                  ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_weights_only=False, save_best_only=True, mode='max'),
                  #ReduceLROnPlateau(monitor='val_loss',patience=3,factor=0.1,min_lr=1e-5),
                  LearningRateScheduler(lr_schedule,verbose=1)
                  ]
                  
model.compile(optimizer, loss = 'categorical_crossentropy', metrics=['accuracy',macro_f1score,weighted_f1score])
# Out:
# Using cosine annealing learning rates

# %%
######## flow_from_directory
history = model.fit(train_generator, steps_per_epoch=int(len(x_train)/batch_sizes),  validation_data = valid_generator, epochs=epochs , verbose=1 , callbacks = callbacks_list , validation_steps=int(len(x_valid)/batch_sizes))
# Out:
# Learning rate:  0.001
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 1/70
# 0.0(L1), 1.4462030155902124e-06(L2) weight decay set for conv2d/kernel:0
# 0.0(L1), 1.4462030155902124e-06(L2) weight decay set for conv2d_1/kernel:0
# 0.0(L1), 1.4462030155902124e-06(L2) weight decay set for conv2d_2/kernel:0
# 0.0(L1), 1.4462030155902124e-06(L2) weight decay set for conv2d_3/kernel:0
# 0.0(L1), 1.4462030155902124e-06(L2) weight decay set for conv2d_4/kernel:0
# 0.0(L1), 1.4462030155902124e-06(L2) weight decay set for conv2d_5/kernel:0
# 0.0(L1), 1.4462030155902124e-06(L2) weight decay set for conv2d_6/kernel:0
# 0.0(L1), 1.4462030155902124e-06(L2) weight decay set for conv2d_7/kernel:0
# 0.0(L1), 1.4462030155902124e-06(L2) weight decay set for conv2d_8/kernel:0
# 0.0(L1), 1.4462030155902124e-06(L2) weight decay set for conv2d_9/kernel:0
# 0.0(L1), 1.4462030155902124e-06(L2) weight decay set for conv2d_10/kernel:0
# 0.0(L1), 1.4462030155902124e-06(L2) weight decay set for conv2d_11/kernel:0
# 0.0(L1), 1.4462030155902124e-06(L2) weight decay set for conv2d_12/kernel:0
# 0.0(L1), 1.4462030155902124e-06(L2) weight decay set for conv2d_13/kernel:0
# 0.0(L1), 1.4462030155902124e-06(L2) weight decay set for conv2d_14/kernel:0
# 0.0(L1), 1.4462030155902124e-06(L2) weight decay set for conv2d_15/kernel:0
# 0.0(L1), 1.4462030155902124e-06(L2) weight decay set for conv2d_16/kernel:0
# 0.0(L1), 1.4462030155902124e-06(L2) weight decay set for conv2d_17/kernel:0
# 0.0(L1), 1.4462030155902124e-06(L2) weight decay set for conv2d_18/kernel:0
# 0.0(L1), 1.4462030155902124e-06(L2) weight decay set for conv2d_19/kernel:0
# 0.0(L1), 1.4462030155902124e-06(L2) weight decay set for conv2d_20/kernel:0
# 0.0(L1), 1.4462030155902124e-06(L2) weight decay set for conv2d_21/kernel:0
# 0.0(L1), 1.4462030155902124e-06(L2) weight decay set for conv2d_22/kernel:0
# 0.0(L1), 1.4462030155902124e-06(L2) weight decay set for conv2d_23/kernel:0
# 0.0(L1), 1.4462030155902124e-06(L2) weight decay set for conv2d_24/kernel:0
# 0.0(L1), 1.4462030155902124e-06(L2) weight decay set for conv2d_25/kernel:0
# 0.0(L1), 1.4462030155902124e-06(L2) weight decay set for conv2d_26/kernel:0
# 0.0(L1), 1.4462030155902124e-06(L2) weight decay set for conv2d_27/kernel:0
# 0.0(L1), 1.4462030155902124e-06(L2) weight decay set for conv2d_28/kernel:0
# 0.0(L1), 1.4462030155902124e-06(L2) weight decay set for conv2d_29/kernel:0
# 0.0(L1), 1.4462030155902124e-06(L2) weight decay set for conv2d_30/kernel:0
# 0.0(L1), 1.4462030155902124e-06(L2) weight decay set for conv2d_31/kernel:0
# 0.0(L1), 1.4462030155902124e-06(L2) weight decay set for conv2d_32/kernel:0
# 0.0(L1), 1.4462030155902124e-06(L2) weight decay set for conv2d_33/kernel:0
# 0.0(L1), 1.4462030155902124e-06(L2) weight decay set for conv2d_34/kernel:0
# 0.0(L1), 1.4462030155902124e-06(L2) weight decay set for conv2d_35/kernel:0
# 0.0(L1), 1.4462030155902124e-06(L2) weight decay set for conv2d_36/kernel:0
# 0.0(L1), 1.4462030155902124e-06(L2) weight decay set for conv2d_37/kernel:0
# 0.0(L1), 1.4462030155902124e-06(L2) weight decay set for conv2d_38/kernel:0
# 0.0(L1), 1.4462030155902124e-06(L2) weight decay set for conv2d_39/kernel:0
# 0.0(L1), 1.4462030155902124e-06(L2) weight decay set for conv2d_40/kernel:0
# 0.0(L1), 1.4462030155902124e-06(L2) weight decay set for conv2d_41/kernel:0
# 0.0(L1), 1.4462030155902124e-06(L2) weight decay set for conv2d_42/kernel:0
# 0.0(L1), 1.4462030155902124e-06(L2) weight decay set for conv2d_43/kernel:0
# 0.0(L1), 1.4462030155902124e-06(L2) weight decay set for conv2d_44/kernel:0
# 0.0(L1), 1.4462030155902124e-06(L2) weight decay set for conv2d_45/kernel:0
# 0.0(L1), 1.4462030155902124e-06(L2) weight decay set for conv2d_46/kernel:0
# 0.0(L1), 1.4462030155902124e-06(L2) weight decay set for conv2d_47/kernel:0
# 0.0(L1), 1.4462030155902124e-06(L2) weight decay set for conv2d_48/kernel:0
# 0.0(L1), 1.4462030155902124e-06(L2) weight decay set for conv2d_49/kernel:0
# 0.0(L1), 1.4462030155902124e-06(L2) weight decay set for conv2d_50/kernel:0
# 0.0(L1), 1.4462030155902124e-06(L2) weight decay set for conv2d_51/kernel:0
# 0.0(L1), 1.4462030155902124e-06(L2) weight decay set for conv2d_52/kernel:0
# 0.0(L1), 1.4462030155902124e-06(L2) weight decay set for conv2d_53/kernel:0
# 0.0(L1), 1.4462030155902124e-06(L2) weight decay set for conv2d_54/kernel:0
# 0.0(L1), 1.4462030155902124e-06(L2) weight decay set for conv2d_55/kernel:0
# 0.0(L1), 1.4462030155902124e-06(L2) weight decay set for conv2d_56/kernel:0
# 0.0(L1), 1.4462030155902124e-06(L2) weight decay set for conv2d_57/kernel:0
# 0.0(L1), 1.4462030155902124e-06(L2) weight decay set for conv2d_58/kernel:0
# 0.0(L1), 1.4462030155902124e-06(L2) weight decay set for conv2d_59/kernel:0
# 0.0(L1), 1.4462030155902124e-06(L2) weight decay set for conv2d_60/kernel:0
# 0.0(L1), 1.4462030155902124e-06(L2) weight decay set for conv2d_61/kernel:0
# 0.0(L1), 1.4462030155902124e-06(L2) weight decay set for conv2d_62/kernel:0
# 0.0(L1), 1.4462030155902124e-06(L2) weight decay set for conv2d_63/kernel:0
# 0.0(L1), 1.4462030155902124e-06(L2) weight decay set for conv2d_64/kernel:0
# 0.0(L1), 1.4462030155902124e-06(L2) weight decay set for conv2d_65/kernel:0
# 0.0(L1), 1.4462030155902124e-06(L2) weight decay set for conv2d_66/kernel:0
# 0.0(L1), 1.4462030155902124e-06(L2) weight decay set for conv2d_67/kernel:0
# 0.0(L1), 1.4462030155902124e-06(L2) weight decay set for conv2d_68/kernel:0
# 0.0(L1), 1.4462030155902124e-06(L2) weight decay set for conv2d_69/kernel:0
# 0.0(L1), 1.4462030155902124e-06(L2) weight decay set for conv2d_70/kernel:0
# 0.0(L1), 1.4462030155902124e-06(L2) weight decay set for conv2d_71/kernel:0
# 0.0(L1), 1.4462030155902124e-06(L2) weight decay set for conv2d_72/kernel:0
# 0.0(L1), 1.4462030155902124e-06(L2) weight decay set for conv2d_73/kernel:0
# 0.0(L1), 1.4462030155902124e-06(L2) weight decay set for conv2d_74/kernel:0
# 0.0(L1), 1.4462030155902124e-06(L2) weight decay set for conv2d_75/kernel:0
# 0.0(L1), 1.4462030155902124e-06(L2) weight decay set for conv2d_76/kernel:0
# 0.0(L1), 1.4462030155902124e-06(L2) weight decay set for conv2d_77/kernel:0
# 0.0(L1), 1.4462030155902124e-06(L2) weight decay set for conv2d_78/kernel:0
# 0.0(L1), 1.4462030155902124e-06(L2) weight decay set for conv2d_79/kernel:0
# 0.0(L1), 1.4462030155902124e-06(L2) weight decay set for conv2d_80/kernel:0
# 0.0(L1), 1.4462030155902124e-06(L2) weight decay set for conv2d_81/kernel:0
# 0.0(L1), 1.4462030155902124e-06(L2) weight decay set for conv2d_82/kernel:0
# 0.0(L1), 1.4462030155902124e-06(L2) weight decay set for conv2d_83/kernel:0
# 0.0(L1), 1.4462030155902124e-06(L2) weight decay set for conv2d_84/kernel:0
# 0.0(L1), 1.4462030155902124e-06(L2) weight decay set for conv2d_85/kernel:0
# 0.0(L1), 1.4462030155902124e-06(L2) weight decay set for conv2d_86/kernel:0
# 0.0(L1), 1.4462030155902124e-06(L2) weight decay set for conv2d_87/kernel:0
# 0.0(L1), 1.4462030155902124e-06(L2) weight decay set for conv2d_88/kernel:0
# 0.0(L1), 1.4462030155902124e-06(L2) weight decay set for conv2d_89/kernel:0
# 0.0(L1), 1.4462030155902124e-06(L2) weight decay set for conv2d_90/kernel:0
# 0.0(L1), 1.4462030155902124e-06(L2) weight decay set for conv2d_91/kernel:0
# 0.0(L1), 1.4462030155902124e-06(L2) weight decay set for conv2d_92/kernel:0
# 0.0(L1), 1.4462030155902124e-06(L2) weight decay set for conv2d_93/kernel:0
# 0.0(L1), 1.4462030155902124e-06(L2) weight decay set for conv2d_94/kernel:0
# 0.0(L1), 1.4462030155902124e-06(L2) weight decay set for conv2d_95/kernel:0
# 0.0(L1), 1.4462030155902124e-06(L2) weight decay set for conv2d_96/kernel:0
# 0.0(L1), 1.4462030155902124e-06(L2) weight decay set for conv2d_97/kernel:0
# 0.0(L1), 1.4462030155902124e-06(L2) weight decay set for conv2d_98/kernel:0
# 0.0(L1), 1.4462030155902124e-06(L2) weight decay set for conv2d_99/kernel:0
# 0.0(L1), 1.4462030155902124e-06(L2) weight decay set for conv2d_100/kernel:0
# 0.0(L1), 1.4462030155902124e-06(L2) weight decay set for conv2d_101/kernel:0
# 0.0(L1), 1.4462030155902124e-06(L2) weight decay set for conv2d_102/kernel:0
# 0.0(L1), 1.4462030155902124e-06(L2) weight decay set for conv2d_103/kernel:0
# 0.0(L1), 1.4462030155902124e-06(L2) weight decay set for conv2d_104/kernel:0
# 0.0(L1), 1.4462030155902124e-06(L2) weight decay set for conv2d_105/kernel:0
# 0.0(L1), 1.4462030155902124e-06(L2) weight decay set for conv2d_106/kernel:0
# 0.0(L1), 1.4462030155902124e-06(L2) weight decay set for conv2d_107/kernel:0
# 0.0(L1), 1.4462030155902124e-06(L2) weight decay set for conv2d_108/kernel:0
# 0.0(L1), 1.4462030155902124e-06(L2) weight decay set for conv2d_109/kernel:0
# 0.0(L1), 1.4462030155902124e-06(L2) weight decay set for conv2d_110/kernel:0
# 0.0(L1), 1.4462030155902124e-06(L2) weight decay set for conv2d_111/kernel:0
# 0.0(L1), 1.4462030155902124e-06(L2) weight decay set for conv2d_112/kernel:0
# 0.0(L1), 1.4462030155902124e-06(L2) weight decay set for conv2d_113/kernel:0
# 0.0(L1), 1.4462030155902124e-06(L2) weight decay set for conv2d_114/kernel:0
# 0.0(L1), 1.4462030155902124e-06(L2) weight decay set for conv2d_115/kernel:0
# 0.0(L1), 1.4462030155902124e-06(L2) weight decay set for conv2d_116/kernel:0
# 0.0(L1), 1.4462030155902124e-06(L2) weight decay set for conv2d_117/kernel:0
# 0.0(L1), 1.4462030155902124e-06(L2) weight decay set for conv2d_118/kernel:0
# 0.0(L1), 1.4462030155902124e-06(L2) weight decay set for conv2d_119/kernel:0
# 765/765 [==============================] - ETA: 0s - loss: 4.7985 - accuracy: 0.1046 - macro_f1score: 0.0020 - weighted_f1score: 8.1747e-05
# Epoch 00001: val_loss improved from inf to 4.31169, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/SE_DenseNet121/001.h5
#
# Epoch 00001: val_accuracy improved from -inf to 0.15659, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/SE_DenseNet121/001.h5
# 765/765 [==============================] - 7277s 10s/step - loss: 4.7985 - accuracy: 0.1046 - macro_f1score: 0.0020 - weighted_f1score: 8.1747e-05 - val_loss: 4.3117 - val_accuracy: 0.1566 - val_macro_f1score: 0.0041 - val_weighted_f1score: 1.8248e-04
# Learning rate:  0.001
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 2/70
# 765/765 [==============================] - ETA: 0s - loss: 4.3264 - accuracy: 0.1500 - macro_f1score: 0.0042 - weighted_f1score: 1.7606e-04
# Epoch 00002: val_loss improved from 4.31169 to 3.95936, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/SE_DenseNet121/002.h5
#
# Epoch 00002: val_accuracy improved from 0.15659 to 0.21001, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/SE_DenseNet121/002.h5
# 765/765 [==============================] - 437s 571ms/step - loss: 4.3264 - accuracy: 0.1500 - macro_f1score: 0.0042 - weighted_f1score: 1.7606e-04 - val_loss: 3.9594 - val_accuracy: 0.2100 - val_macro_f1score: 0.0064 - val_weighted_f1score: 2.7073e-04
# Learning rate:  0.001
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 3/70
# 765/765 [==============================] - ETA: 0s - loss: 4.0071 - accuracy: 0.1880 - macro_f1score: 0.0065 - weighted_f1score: 2.6240e-04
# Epoch 00003: val_loss improved from 3.95936 to 3.72743, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/SE_DenseNet121/003.h5
#
# Epoch 00003: val_accuracy improved from 0.21001 to 0.23958, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/SE_DenseNet121/003.h5
# 765/765 [==============================] - 420s 549ms/step - loss: 4.0071 - accuracy: 0.1880 - macro_f1score: 0.0065 - weighted_f1score: 2.6240e-04 - val_loss: 3.7274 - val_accuracy: 0.2396 - val_macro_f1score: 0.0095 - val_weighted_f1score: 3.7015e-04
# Learning rate:  0.001
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 4/70
# 765/765 [==============================] - ETA: 0s - loss: 3.7340 - accuracy: 0.2275 - macro_f1score: 0.0090 - weighted_f1score: 3.5376e-04
# Epoch 00004: val_loss improved from 3.72743 to 3.51348, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/SE_DenseNet121/004.h5
#
# Epoch 00004: val_accuracy improved from 0.23958 to 0.27016, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/SE_DenseNet121/004.h5
# 765/765 [==============================] - 410s 537ms/step - loss: 3.7340 - accuracy: 0.2275 - macro_f1score: 0.0090 - weighted_f1score: 3.5376e-04 - val_loss: 3.5135 - val_accuracy: 0.2702 - val_macro_f1score: 0.0122 - val_weighted_f1score: 4.8600e-04
# Learning rate:  0.001
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 5/70
# 765/765 [==============================] - ETA: 0s - loss: 3.4878 - accuracy: 0.2595 - macro_f1score: 0.0110 - weighted_f1score: 4.2906e-04
# Epoch 00005: val_loss improved from 3.51348 to 3.32388, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/SE_DenseNet121/005.h5
#
# Epoch 00005: val_accuracy improved from 0.27016 to 0.30208, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/SE_DenseNet121/005.h5
# 765/765 [==============================] - 411s 537ms/step - loss: 3.4878 - accuracy: 0.2595 - macro_f1score: 0.0110 - weighted_f1score: 4.2906e-04 - val_loss: 3.3239 - val_accuracy: 0.3021 - val_macro_f1score: 0.0150 - val_weighted_f1score: 5.8027e-04
# Learning rate:  0.001
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 6/70
# 765/765 [==============================] - ETA: 0s - loss: 3.2575 - accuracy: 0.2937 - macro_f1score: 0.0141 - weighted_f1score: 5.4344e-04
# Epoch 00006: val_loss improved from 3.32388 to 3.14021, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/SE_DenseNet121/006.h5
#
# Epoch 00006: val_accuracy improved from 0.30208 to 0.32863, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/SE_DenseNet121/006.h5
# 765/765 [==============================] - 412s 539ms/step - loss: 3.2575 - accuracy: 0.2937 - macro_f1score: 0.0141 - weighted_f1score: 5.4344e-04 - val_loss: 3.1402 - val_accuracy: 0.3286 - val_macro_f1score: 0.0181 - val_weighted_f1score: 6.9057e-04
# Learning rate:  0.001
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 7/70
# 765/765 [==============================] - ETA: 0s - loss: 3.0324 - accuracy: 0.3260 - macro_f1score: 0.0173 - weighted_f1score: 6.4472e-04
# Epoch 00007: val_loss improved from 3.14021 to 2.99122, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/SE_DenseNet121/007.h5
#
# Epoch 00007: val_accuracy improved from 0.32863 to 0.35618, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/SE_DenseNet121/007.h5
# 765/765 [==============================] - 410s 536ms/step - loss: 3.0324 - accuracy: 0.3260 - macro_f1score: 0.0173 - weighted_f1score: 6.4472e-04 - val_loss: 2.9912 - val_accuracy: 0.3562 - val_macro_f1score: 0.0215 - val_weighted_f1score: 7.9503e-04
# Learning rate:  0.001
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 8/70
# 765/765 [==============================] - ETA: 0s - loss: 2.8333 - accuracy: 0.3635 - macro_f1score: 0.0208 - weighted_f1score: 7.6999e-04
# Epoch 00008: val_loss improved from 2.99122 to 2.90023, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/SE_DenseNet121/008.h5
#
# Epoch 00008: val_accuracy improved from 0.35618 to 0.37399, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/SE_DenseNet121/008.h5
# 765/765 [==============================] - 407s 532ms/step - loss: 2.8333 - accuracy: 0.3635 - macro_f1score: 0.0208 - weighted_f1score: 7.6999e-04 - val_loss: 2.9002 - val_accuracy: 0.3740 - val_macro_f1score: 0.0239 - val_weighted_f1score: 8.9009e-04
# Learning rate:  0.001
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 9/70
# 765/765 [==============================] - ETA: 0s - loss: 2.6519 - accuracy: 0.3936 - macro_f1score: 0.0239 - weighted_f1score: 8.7350e-04
# Epoch 00009: val_loss improved from 2.90023 to 2.78834, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/SE_DenseNet121/009.h5
#
# Epoch 00009: val_accuracy improved from 0.37399 to 0.39516, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/SE_DenseNet121/009.h5
# 765/765 [==============================] - 407s 532ms/step - loss: 2.6519 - accuracy: 0.3936 - macro_f1score: 0.0239 - weighted_f1score: 8.7350e-04 - val_loss: 2.7883 - val_accuracy: 0.3952 - val_macro_f1score: 0.0276 - val_weighted_f1score: 9.8601e-04
# Learning rate:  0.001
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 10/70
# 765/765 [==============================] - ETA: 0s - loss: 2.4877 - accuracy: 0.4189 - macro_f1score: 0.0274 - weighted_f1score: 9.9043e-04
# Epoch 00010: val_loss improved from 2.78834 to 2.72673, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/SE_DenseNet121/010.h5
#
# Epoch 00010: val_accuracy improved from 0.39516 to 0.40793, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/SE_DenseNet121/010.h5
# 765/765 [==============================] - 407s 531ms/step - loss: 2.4877 - accuracy: 0.4189 - macro_f1score: 0.0274 - weighted_f1score: 9.9043e-04 - val_loss: 2.7267 - val_accuracy: 0.4079 - val_macro_f1score: 0.0296 - val_weighted_f1score: 0.0011
# Learning rate:  0.001
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 11/70
# 765/765 [==============================] - ETA: 0s - loss: 2.3362 - accuracy: 0.4485 - macro_f1score: 0.0307 - weighted_f1score: 0.0011
# Epoch 00011: val_loss improved from 2.72673 to 2.65804, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/SE_DenseNet121/011.h5
#
# Epoch 00011: val_accuracy improved from 0.40793 to 0.42507, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/SE_DenseNet121/011.h5
# 765/765 [==============================] - 405s 529ms/step - loss: 2.3362 - accuracy: 0.4485 - macro_f1score: 0.0307 - weighted_f1score: 0.0011 - val_loss: 2.6580 - val_accuracy: 0.4251 - val_macro_f1score: 0.0318 - val_weighted_f1score: 0.0012
# Learning rate:  0.001
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 12/70
# 765/765 [==============================] - ETA: 0s - loss: 2.1760 - accuracy: 0.4821 - macro_f1score: 0.0345 - weighted_f1score: 0.0012
# Epoch 00012: val_loss improved from 2.65804 to 2.60236, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/SE_DenseNet121/012.h5
#
# Epoch 00012: val_accuracy improved from 0.42507 to 0.43380, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/SE_DenseNet121/012.h5
# 765/765 [==============================] - 405s 530ms/step - loss: 2.1760 - accuracy: 0.4821 - macro_f1score: 0.0345 - weighted_f1score: 0.0012 - val_loss: 2.6024 - val_accuracy: 0.4338 - val_macro_f1score: 0.0335 - val_weighted_f1score: 0.0012
# Learning rate:  0.001
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 13/70
# 765/765 [==============================] - ETA: 0s - loss: 2.0324 - accuracy: 0.5078 - macro_f1score: 0.0387 - weighted_f1score: 0.0014
# Epoch 00013: val_loss improved from 2.60236 to 2.57852, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/SE_DenseNet121/013.h5
#
# Epoch 00013: val_accuracy improved from 0.43380 to 0.45228, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/SE_DenseNet121/013.h5
# 765/765 [==============================] - 406s 530ms/step - loss: 2.0324 - accuracy: 0.5078 - macro_f1score: 0.0387 - weighted_f1score: 0.0014 - val_loss: 2.5785 - val_accuracy: 0.4523 - val_macro_f1score: 0.0368 - val_weighted_f1score: 0.0013
# Learning rate:  0.001
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 14/70
# 765/765 [==============================] - ETA: 0s - loss: 1.9117 - accuracy: 0.5303 - macro_f1score: 0.0417 - weighted_f1score: 0.0015
# Epoch 00014: val_loss improved from 2.57852 to 2.52879, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/SE_DenseNet121/014.h5
#
# Epoch 00014: val_accuracy improved from 0.45228 to 0.46237, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/SE_DenseNet121/014.h5
# 765/765 [==============================] - 406s 531ms/step - loss: 1.9117 - accuracy: 0.5303 - macro_f1score: 0.0417 - weighted_f1score: 0.0015 - val_loss: 2.5288 - val_accuracy: 0.4624 - val_macro_f1score: 0.0387 - val_weighted_f1score: 0.0014
# Learning rate:  0.001
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 15/70
# 765/765 [==============================] - ETA: 0s - loss: 1.7609 - accuracy: 0.5589 - macro_f1score: 0.0459 - weighted_f1score: 0.0016
# Epoch 00015: val_loss did not improve from 2.52879
#
# Epoch 00015: val_accuracy did not improve from 0.46237
# 765/765 [==============================] - 401s 524ms/step - loss: 1.7609 - accuracy: 0.5589 - macro_f1score: 0.0459 - weighted_f1score: 0.0016 - val_loss: 2.5377 - val_accuracy: 0.4580 - val_macro_f1score: 0.0403 - val_weighted_f1score: 0.0014
# Learning rate:  0.001
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 16/70
# 765/765 [==============================] - ETA: 0s - loss: 1.6604 - accuracy: 0.5822 - macro_f1score: 0.0490 - weighted_f1score: 0.0017
# Epoch 00016: val_loss did not improve from 2.52879
#
# Epoch 00016: val_accuracy improved from 0.46237 to 0.46774, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/SE_DenseNet121/016.h5
# 765/765 [==============================] - 404s 528ms/step - loss: 1.6604 - accuracy: 0.5822 - macro_f1score: 0.0490 - weighted_f1score: 0.0017 - val_loss: 2.5680 - val_accuracy: 0.4677 - val_macro_f1score: 0.0407 - val_weighted_f1score: 0.0015
# Learning rate:  0.001
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 17/70
# 765/765 [==============================] - ETA: 0s - loss: 1.5628 - accuracy: 0.5983 - macro_f1score: 0.0517 - weighted_f1score: 0.0018
# Epoch 00017: val_loss did not improve from 2.52879
#
# Epoch 00017: val_accuracy improved from 0.46774 to 0.47009, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/SE_DenseNet121/017.h5
# 765/765 [==============================] - 403s 526ms/step - loss: 1.5628 - accuracy: 0.5983 - macro_f1score: 0.0517 - weighted_f1score: 0.0018 - val_loss: 2.5637 - val_accuracy: 0.4701 - val_macro_f1score: 0.0429 - val_weighted_f1score: 0.0015
# Learning rate:  0.001
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 18/70
# 765/765 [==============================] - ETA: 0s - loss: 1.4579 - accuracy: 0.6241 - macro_f1score: 0.0551 - weighted_f1score: 0.0019
# Epoch 00018: val_loss did not improve from 2.52879
#
# Epoch 00018: val_accuracy improved from 0.47009 to 0.47480, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/SE_DenseNet121/018.h5
# 765/765 [==============================] - 404s 529ms/step - loss: 1.4579 - accuracy: 0.6241 - macro_f1score: 0.0551 - weighted_f1score: 0.0019 - val_loss: 2.5624 - val_accuracy: 0.4748 - val_macro_f1score: 0.0437 - val_weighted_f1score: 0.0015
# Learning rate:  0.001
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 19/70
# 765/765 [==============================] - ETA: 0s - loss: 1.3590 - accuracy: 0.6466 - macro_f1score: 0.0584 - weighted_f1score: 0.0020
# Epoch 00019: val_loss did not improve from 2.52879
#
# Epoch 00019: val_accuracy improved from 0.47480 to 0.47984, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/SE_DenseNet121/019.h5
# 765/765 [==============================] - 411s 537ms/step - loss: 1.3590 - accuracy: 0.6466 - macro_f1score: 0.0584 - weighted_f1score: 0.0020 - val_loss: 2.6029 - val_accuracy: 0.4798 - val_macro_f1score: 0.0442 - val_weighted_f1score: 0.0016
# Learning rate:  0.001
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 20/70
# 765/765 [==============================] - ETA: 0s - loss: 1.2755 - accuracy: 0.6625 - macro_f1score: 0.0612 - weighted_f1score: 0.0021
# Epoch 00020: val_loss did not improve from 2.52879
#
# Epoch 00020: val_accuracy improved from 0.47984 to 0.48185, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/SE_DenseNet121/020.h5
# 765/765 [==============================] - 413s 540ms/step - loss: 1.2755 - accuracy: 0.6625 - macro_f1score: 0.0612 - weighted_f1score: 0.0021 - val_loss: 2.6172 - val_accuracy: 0.4819 - val_macro_f1score: 0.0452 - val_weighted_f1score: 0.0016
# Learning rate:  0.001
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 21/70
# 765/765 [==============================] - ETA: 0s - loss: 1.1935 - accuracy: 0.6801 - macro_f1score: 0.0638 - weighted_f1score: 0.0022
# Epoch 00021: val_loss did not improve from 2.52879
#
# Epoch 00021: val_accuracy did not improve from 0.48185
# 765/765 [==============================] - 411s 537ms/step - loss: 1.1935 - accuracy: 0.6801 - macro_f1score: 0.0638 - weighted_f1score: 0.0022 - val_loss: 2.6342 - val_accuracy: 0.4772 - val_macro_f1score: 0.0462 - val_weighted_f1score: 0.0016
# Learning rate:  0.001
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 22/70
# 765/765 [==============================] - ETA: 0s - loss: 1.1198 - accuracy: 0.6991 - macro_f1score: 0.0666 - weighted_f1score: 0.0023
# Epoch 00022: val_loss did not improve from 2.52879
#
# Epoch 00022: val_accuracy improved from 0.48185 to 0.48824, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/SE_DenseNet121/022.h5
# 765/765 [==============================] - 416s 543ms/step - loss: 1.1198 - accuracy: 0.6991 - macro_f1score: 0.0666 - weighted_f1score: 0.0023 - val_loss: 2.6899 - val_accuracy: 0.4882 - val_macro_f1score: 0.0464 - val_weighted_f1score: 0.0016
# Learning rate:  0.001
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 23/70
# 765/765 [==============================] - ETA: 0s - loss: 1.0597 - accuracy: 0.7103 - macro_f1score: 0.0684 - weighted_f1score: 0.0024
# Epoch 00023: val_loss did not improve from 2.52879
#
# Epoch 00023: val_accuracy did not improve from 0.48824
# 765/765 [==============================] - 410s 535ms/step - loss: 1.0597 - accuracy: 0.7103 - macro_f1score: 0.0684 - weighted_f1score: 0.0024 - val_loss: 2.6673 - val_accuracy: 0.4866 - val_macro_f1score: 0.0468 - val_weighted_f1score: 0.0016
# Learning rate:  0.001
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 24/70
# 765/765 [==============================] - ETA: 0s - loss: 0.9898 - accuracy: 0.7312 - macro_f1score: 0.0714 - weighted_f1score: 0.0025
# Epoch 00024: val_loss did not improve from 2.52879
#
# Epoch 00024: val_accuracy did not improve from 0.48824
# 765/765 [==============================] - 405s 530ms/step - loss: 0.9898 - accuracy: 0.7312 - macro_f1score: 0.0714 - weighted_f1score: 0.0025 - val_loss: 2.7272 - val_accuracy: 0.4845 - val_macro_f1score: 0.0475 - val_weighted_f1score: 0.0017
# Learning rate:  0.001
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 25/70
# 765/765 [==============================] - ETA: 0s - loss: 0.9239 - accuracy: 0.7437 - macro_f1score: 0.0741 - weighted_f1score: 0.0026
# Epoch 00025: val_loss did not improve from 2.52879
#
# Epoch 00025: val_accuracy did not improve from 0.48824
# 765/765 [==============================] - 404s 528ms/step - loss: 0.9239 - accuracy: 0.7437 - macro_f1score: 0.0741 - weighted_f1score: 0.0026 - val_loss: 2.7686 - val_accuracy: 0.4788 - val_macro_f1score: 0.0478 - val_weighted_f1score: 0.0017
# Learning rate:  0.001
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 26/70
# 765/765 [==============================] - ETA: 0s - loss: 0.8796 - accuracy: 0.7506 - macro_f1score: 0.0762 - weighted_f1score: 0.0026
# Epoch 00026: val_loss did not improve from 2.52879
#
# Epoch 00026: val_accuracy did not improve from 0.48824
# 765/765 [==============================] - 406s 530ms/step - loss: 0.8796 - accuracy: 0.7506 - macro_f1score: 0.0762 - weighted_f1score: 0.0026 - val_loss: 2.8045 - val_accuracy: 0.4849 - val_macro_f1score: 0.0484 - val_weighted_f1score: 0.0017
# Learning rate:  0.001
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 27/70
# 765/765 [==============================] - ETA: 0s - loss: 0.8276 - accuracy: 0.7666 - macro_f1score: 0.0777 - weighted_f1score: 0.0027
# Epoch 00027: val_loss did not improve from 2.52879
#
# Epoch 00027: val_accuracy did not improve from 0.48824
# 765/765 [==============================] - 411s 538ms/step - loss: 0.8276 - accuracy: 0.7666 - macro_f1score: 0.0777 - weighted_f1score: 0.0027 - val_loss: 2.8067 - val_accuracy: 0.4882 - val_macro_f1score: 0.0483 - val_weighted_f1score: 0.0017
# Learning rate:  0.001
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 28/70
# 765/765 [==============================] - ETA: 0s - loss: 0.7744 - accuracy: 0.7807 - macro_f1score: 0.0798 - weighted_f1score: 0.0027
# Epoch 00028: val_loss did not improve from 2.52879
#
# Epoch 00028: val_accuracy did not improve from 0.48824
# 765/765 [==============================] - 407s 532ms/step - loss: 0.7744 - accuracy: 0.7807 - macro_f1score: 0.0798 - weighted_f1score: 0.0027 - val_loss: 2.8473 - val_accuracy: 0.4849 - val_macro_f1score: 0.0488 - val_weighted_f1score: 0.0017
# Learning rate:  0.001
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 29/70
# 765/765 [==============================] - ETA: 0s - loss: 0.7491 - accuracy: 0.7875 - macro_f1score: 0.0814 - weighted_f1score: 0.0028
# Epoch 00029: val_loss did not improve from 2.52879
#
# Epoch 00029: val_accuracy did not improve from 0.48824
# 765/765 [==============================] - 410s 536ms/step - loss: 0.7491 - accuracy: 0.7875 - macro_f1score: 0.0814 - weighted_f1score: 0.0028 - val_loss: 2.8742 - val_accuracy: 0.4872 - val_macro_f1score: 0.0490 - val_weighted_f1score: 0.0017
# Learning rate:  0.001
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 30/70
# 765/765 [==============================] - ETA: 0s - loss: 0.6748 - accuracy: 0.8071 - macro_f1score: 0.0840 - weighted_f1score: 0.0029
# Epoch 00030: val_loss did not improve from 2.52879
#
# Epoch 00030: val_accuracy improved from 0.48824 to 0.49630, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/SE_DenseNet121/030.h5
# 765/765 [==============================] - 414s 541ms/step - loss: 0.6748 - accuracy: 0.8071 - macro_f1score: 0.0840 - weighted_f1score: 0.0029 - val_loss: 2.8576 - val_accuracy: 0.4963 - val_macro_f1score: 0.0496 - val_weighted_f1score: 0.0017
# Learning rate:  0.001
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 31/70
# 765/765 [==============================] - ETA: 0s - loss: 0.6855 - accuracy: 0.8045 - macro_f1score: 0.0843 - weighted_f1score: 0.0029
# Epoch 00031: val_loss did not improve from 2.52879
#
# Epoch 00031: val_accuracy did not improve from 0.49630
# 765/765 [==============================] - 415s 543ms/step - loss: 0.6855 - accuracy: 0.8045 - macro_f1score: 0.0843 - weighted_f1score: 0.0029 - val_loss: 2.8979 - val_accuracy: 0.4913 - val_macro_f1score: 0.0495 - val_weighted_f1score: 0.0017
# Learning rate:  0.001
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 32/70
# 765/765 [==============================] - ETA: 0s - loss: 0.6311 - accuracy: 0.8146 - macro_f1score: 0.0857 - weighted_f1score: 0.0029
# Epoch 00032: val_loss did not improve from 2.52879
#
# Epoch 00032: val_accuracy did not improve from 0.49630
# 765/765 [==============================] - 412s 539ms/step - loss: 0.6311 - accuracy: 0.8146 - macro_f1score: 0.0857 - weighted_f1score: 0.0029 - val_loss: 2.9370 - val_accuracy: 0.4879 - val_macro_f1score: 0.0496 - val_weighted_f1score: 0.0017
# Learning rate:  0.001
#
# Epoch 00033: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 33/70
# 765/765 [==============================] - ETA: 0s - loss: 0.6134 - accuracy: 0.8221 - macro_f1score: 0.0869 - weighted_f1score: 0.0030
# Epoch 00033: val_loss did not improve from 2.52879
#
# Epoch 00033: val_accuracy did not improve from 0.49630
# 765/765 [==============================] - 422s 552ms/step - loss: 0.6134 - accuracy: 0.8221 - macro_f1score: 0.0869 - weighted_f1score: 0.0030 - val_loss: 2.9906 - val_accuracy: 0.4886 - val_macro_f1score: 0.0497 - val_weighted_f1score: 0.0018
# Learning rate:  0.001
#
# Epoch 00034: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 34/70
# 765/765 [==============================] - ETA: 0s - loss: 0.5731 - accuracy: 0.8326 - macro_f1score: 0.0889 - weighted_f1score: 0.0030
# Epoch 00034: val_loss did not improve from 2.52879
#
# Epoch 00034: val_accuracy improved from 0.49630 to 0.49664, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/SE_DenseNet121/034.h5
# 765/765 [==============================] - 422s 552ms/step - loss: 0.5731 - accuracy: 0.8326 - macro_f1score: 0.0889 - weighted_f1score: 0.0030 - val_loss: 3.0140 - val_accuracy: 0.4966 - val_macro_f1score: 0.0502 - val_weighted_f1score: 0.0018
# Learning rate:  0.001
#
# Epoch 00035: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 35/70
# 765/765 [==============================] - ETA: 0s - loss: 0.5581 - accuracy: 0.8364 - macro_f1score: 0.0896 - weighted_f1score: 0.0031
# Epoch 00035: val_loss did not improve from 2.52879
#
# Epoch 00035: val_accuracy did not improve from 0.49664
# 765/765 [==============================] - 423s 553ms/step - loss: 0.5581 - accuracy: 0.8364 - macro_f1score: 0.0896 - weighted_f1score: 0.0031 - val_loss: 3.0228 - val_accuracy: 0.4966 - val_macro_f1score: 0.0516 - val_weighted_f1score: 0.0018
# Learning rate:  0.001
#
# Epoch 00036: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 36/70
# 765/765 [==============================] - ETA: 0s - loss: 0.5253 - accuracy: 0.8470 - macro_f1score: 0.0911 - weighted_f1score: 0.0031
# Epoch 00036: val_loss did not improve from 2.52879
#
# Epoch 00036: val_accuracy improved from 0.49664 to 0.49933, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/SE_DenseNet121/036.h5
# 765/765 [==============================] - 419s 548ms/step - loss: 0.5253 - accuracy: 0.8470 - macro_f1score: 0.0911 - weighted_f1score: 0.0031 - val_loss: 3.0570 - val_accuracy: 0.4993 - val_macro_f1score: 0.0516 - val_weighted_f1score: 0.0018
# Learning rate:  0.001
#
# Epoch 00037: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 37/70
# 765/765 [==============================] - ETA: 0s - loss: 0.5118 - accuracy: 0.8503 - macro_f1score: 0.0919 - weighted_f1score: 0.0031
# Epoch 00037: val_loss did not improve from 2.52879
#
# Epoch 00037: val_accuracy did not improve from 0.49933
# 765/765 [==============================] - 413s 540ms/step - loss: 0.5118 - accuracy: 0.8503 - macro_f1score: 0.0919 - weighted_f1score: 0.0031 - val_loss: 3.0481 - val_accuracy: 0.4903 - val_macro_f1score: 0.0506 - val_weighted_f1score: 0.0018
# Learning rate:  0.001
#
# Epoch 00038: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 38/70
# 765/765 [==============================] - ETA: 0s - loss: 0.5030 - accuracy: 0.8527 - macro_f1score: 0.0922 - weighted_f1score: 0.0032
# Epoch 00038: val_loss did not improve from 2.52879
#
# Epoch 00038: val_accuracy improved from 0.49933 to 0.50269, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/SE_DenseNet121/038.h5
# 765/765 [==============================] - 418s 546ms/step - loss: 0.5030 - accuracy: 0.8527 - macro_f1score: 0.0922 - weighted_f1score: 0.0032 - val_loss: 3.0572 - val_accuracy: 0.5027 - val_macro_f1score: 0.0519 - val_weighted_f1score: 0.0018
# Learning rate:  0.001
#
# Epoch 00039: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 39/70
# 765/765 [==============================] - ETA: 0s - loss: 0.4621 - accuracy: 0.8624 - macro_f1score: 0.0941 - weighted_f1score: 0.0032
# Epoch 00039: val_loss did not improve from 2.52879
#
# Epoch 00039: val_accuracy did not improve from 0.50269
# 765/765 [==============================] - 415s 543ms/step - loss: 0.4621 - accuracy: 0.8624 - macro_f1score: 0.0941 - weighted_f1score: 0.0032 - val_loss: 3.1248 - val_accuracy: 0.4960 - val_macro_f1score: 0.0516 - val_weighted_f1score: 0.0018
# Learning rate:  0.001
#
# Epoch 00040: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 40/70
# 765/765 [==============================] - ETA: 0s - loss: 0.4340 - accuracy: 0.8685 - macro_f1score: 0.0945 - weighted_f1score: 0.0032
# Epoch 00040: val_loss did not improve from 2.52879
#
# Epoch 00040: val_accuracy did not improve from 0.50269
# 765/765 [==============================] - 416s 544ms/step - loss: 0.4340 - accuracy: 0.8685 - macro_f1score: 0.0945 - weighted_f1score: 0.0032 - val_loss: 3.1571 - val_accuracy: 0.4916 - val_macro_f1score: 0.0512 - val_weighted_f1score: 0.0018
# Learning rate:  0.001
#
# Epoch 00041: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 41/70
# 765/765 [==============================] - ETA: 0s - loss: 0.4484 - accuracy: 0.8671 - macro_f1score: 0.0942 - weighted_f1score: 0.0032
# Epoch 00041: val_loss did not improve from 2.52879
#
# Epoch 00041: val_accuracy did not improve from 0.50269
# 765/765 [==============================] - 416s 543ms/step - loss: 0.4484 - accuracy: 0.8671 - macro_f1score: 0.0942 - weighted_f1score: 0.0032 - val_loss: 3.1778 - val_accuracy: 0.4983 - val_macro_f1score: 0.0520 - val_weighted_f1score: 0.0018
# Learning rate:  0.001
#
# Epoch 00042: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 42/70
# 765/765 [==============================] - ETA: 0s - loss: 0.4373 - accuracy: 0.8707 - macro_f1score: 0.0949 - weighted_f1score: 0.0033
# Epoch 00042: val_loss did not improve from 2.52879
#
# Epoch 00042: val_accuracy did not improve from 0.50269
# 765/765 [==============================] - 412s 539ms/step - loss: 0.4373 - accuracy: 0.8707 - macro_f1score: 0.0949 - weighted_f1score: 0.0033 - val_loss: 3.2188 - val_accuracy: 0.4892 - val_macro_f1score: 0.0512 - val_weighted_f1score: 0.0018
# Learning rate:  0.001
#
# Epoch 00043: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 43/70
# 765/765 [==============================] - ETA: 0s - loss: 0.4037 - accuracy: 0.8825 - macro_f1score: 0.0965 - weighted_f1score: 0.0033
# Epoch 00043: val_loss did not improve from 2.52879
#
# Epoch 00043: val_accuracy did not improve from 0.50269
# 765/765 [==============================] - 413s 540ms/step - loss: 0.4037 - accuracy: 0.8825 - macro_f1score: 0.0965 - weighted_f1score: 0.0033 - val_loss: 3.1736 - val_accuracy: 0.5003 - val_macro_f1score: 0.0521 - val_weighted_f1score: 0.0018
# Learning rate:  0.001
#
# Epoch 00044: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 44/70
# 765/765 [==============================] - ETA: 0s - loss: 0.4097 - accuracy: 0.8787 - macro_f1score: 0.0961 - weighted_f1score: 0.0033
# Epoch 00044: val_loss did not improve from 2.52879
#
# Epoch 00044: val_accuracy did not improve from 0.50269
# 765/765 [==============================] - 408s 534ms/step - loss: 0.4097 - accuracy: 0.8787 - macro_f1score: 0.0961 - weighted_f1score: 0.0033 - val_loss: 3.1790 - val_accuracy: 0.4960 - val_macro_f1score: 0.0519 - val_weighted_f1score: 0.0018
# Learning rate:  0.001
#
# Epoch 00045: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 45/70
# 765/765 [==============================] - ETA: 0s - loss: 0.3924 - accuracy: 0.8823 - macro_f1score: 0.0972 - weighted_f1score: 0.0033
# Epoch 00045: val_loss did not improve from 2.52879
#
# Epoch 00045: val_accuracy did not improve from 0.50269
# 765/765 [==============================] - 402s 525ms/step - loss: 0.3924 - accuracy: 0.8823 - macro_f1score: 0.0972 - weighted_f1score: 0.0033 - val_loss: 3.2031 - val_accuracy: 0.4983 - val_macro_f1score: 0.0521 - val_weighted_f1score: 0.0018
# Learning rate:  0.001
#
# Epoch 00046: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 46/70
# 765/765 [==============================] - ETA: 0s - loss: 0.3805 - accuracy: 0.8861 - macro_f1score: 0.0975 - weighted_f1score: 0.0033
# Epoch 00046: val_loss did not improve from 2.52879
#
# Epoch 00046: val_accuracy did not improve from 0.50269
# 765/765 [==============================] - 407s 532ms/step - loss: 0.3805 - accuracy: 0.8861 - macro_f1score: 0.0975 - weighted_f1score: 0.0033 - val_loss: 3.2308 - val_accuracy: 0.4987 - val_macro_f1score: 0.0525 - val_weighted_f1score: 0.0018
# Learning rate:  0.001
#
# Epoch 00047: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 47/70
# 765/765 [==============================] - ETA: 0s - loss: 0.3630 - accuracy: 0.8894 - macro_f1score: 0.0985 - weighted_f1score: 0.0034
# Epoch 00047: val_loss did not improve from 2.52879
#
# Epoch 00047: val_accuracy improved from 0.50269 to 0.50302, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/SE_DenseNet121/047.h5
# 765/765 [==============================] - 405s 529ms/step - loss: 0.3630 - accuracy: 0.8894 - macro_f1score: 0.0985 - weighted_f1score: 0.0034 - val_loss: 3.2827 - val_accuracy: 0.5030 - val_macro_f1score: 0.0521 - val_weighted_f1score: 0.0018
# Learning rate:  0.001
#
# Epoch 00048: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 48/70
# 765/765 [==============================] - ETA: 0s - loss: 0.3673 - accuracy: 0.8905 - macro_f1score: 0.0982 - weighted_f1score: 0.0034
# Epoch 00048: val_loss did not improve from 2.52879
#
# Epoch 00048: val_accuracy did not improve from 0.50302
# 765/765 [==============================] - 402s 525ms/step - loss: 0.3673 - accuracy: 0.8905 - macro_f1score: 0.0982 - weighted_f1score: 0.0034 - val_loss: 3.2278 - val_accuracy: 0.4970 - val_macro_f1score: 0.0523 - val_weighted_f1score: 0.0018
# Learning rate:  0.001
#
# Epoch 00049: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 49/70
# 765/765 [==============================] - ETA: 0s - loss: 0.3365 - accuracy: 0.8971 - macro_f1score: 0.0991 - weighted_f1score: 0.0034
# Epoch 00049: val_loss did not improve from 2.52879
#
# Epoch 00049: val_accuracy did not improve from 0.50302
# 765/765 [==============================] - 401s 524ms/step - loss: 0.3365 - accuracy: 0.8971 - macro_f1score: 0.0991 - weighted_f1score: 0.0034 - val_loss: 3.2803 - val_accuracy: 0.4973 - val_macro_f1score: 0.0524 - val_weighted_f1score: 0.0018
# Learning rate:  0.001
#
# Epoch 00050: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 50/70
# 765/765 [==============================] - ETA: 0s - loss: 0.3360 - accuracy: 0.8997 - macro_f1score: 0.0995 - weighted_f1score: 0.0034
# Epoch 00050: val_loss did not improve from 2.52879
#
# Epoch 00050: val_accuracy did not improve from 0.50302
# 765/765 [==============================] - 402s 525ms/step - loss: 0.3360 - accuracy: 0.8997 - macro_f1score: 0.0995 - weighted_f1score: 0.0034 - val_loss: 3.3545 - val_accuracy: 0.4852 - val_macro_f1score: 0.0510 - val_weighted_f1score: 0.0018
# Learning rate:  0.0001
#
# Epoch 00051: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 51/70
# 765/765 [==============================] - ETA: 0s - loss: 0.1230 - accuracy: 0.9654 - macro_f1score: 0.1090 - weighted_f1score: 0.0037
# Epoch 00051: val_loss did not improve from 2.52879
#
# Epoch 00051: val_accuracy did not improve from 0.50302
# 765/765 [==============================] - 401s 525ms/step - loss: 0.1230 - accuracy: 0.9654 - macro_f1score: 0.1090 - weighted_f1score: 0.0037 - val_loss: 3.3019 - val_accuracy: 0.4983 - val_macro_f1score: 0.0515 - val_weighted_f1score: 0.0018
# Learning rate:  0.0001
#
# Epoch 00052: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 52/70
# 765/765 [==============================] - ETA: 0s - loss: 0.0978 - accuracy: 0.9730 - macro_f1score: 0.1103 - weighted_f1score: 0.0038
# Epoch 00052: val_loss did not improve from 2.52879
#
# Epoch 00052: val_accuracy did not improve from 0.50302
# 765/765 [==============================] - 402s 525ms/step - loss: 0.0978 - accuracy: 0.9730 - macro_f1score: 0.1103 - weighted_f1score: 0.0038 - val_loss: 3.2887 - val_accuracy: 0.4973 - val_macro_f1score: 0.0527 - val_weighted_f1score: 0.0018
# Learning rate:  0.0001
#
# Epoch 00053: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 53/70
# 765/765 [==============================] - ETA: 0s - loss: 0.0877 - accuracy: 0.9773 - macro_f1score: 0.1106 - weighted_f1score: 0.0038
# Epoch 00053: val_loss did not improve from 2.52879
#
# Epoch 00053: val_accuracy did not improve from 0.50302
# 765/765 [==============================] - 401s 524ms/step - loss: 0.0877 - accuracy: 0.9773 - macro_f1score: 0.1106 - weighted_f1score: 0.0038 - val_loss: 3.2770 - val_accuracy: 0.4987 - val_macro_f1score: 0.0522 - val_weighted_f1score: 0.0018
# Learning rate:  0.0001
#
# Epoch 00054: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 54/70
# 765/765 [==============================] - ETA: 0s - loss: 0.0721 - accuracy: 0.9819 - macro_f1score: 0.1117 - weighted_f1score: 0.0038
# Epoch 00054: val_loss did not improve from 2.52879
#
# Epoch 00054: val_accuracy did not improve from 0.50302
# 765/765 [==============================] - 398s 520ms/step - loss: 0.0721 - accuracy: 0.9819 - macro_f1score: 0.1117 - weighted_f1score: 0.0038 - val_loss: 3.2735 - val_accuracy: 0.5013 - val_macro_f1score: 0.0534 - val_weighted_f1score: 0.0019
# Learning rate:  0.0001
#
# Epoch 00055: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 55/70
# 765/765 [==============================] - ETA: 0s - loss: 0.0722 - accuracy: 0.9813 - macro_f1score: 0.1113 - weighted_f1score: 0.0038
# Epoch 00055: val_loss did not improve from 2.52879
#
# Epoch 00055: val_accuracy did not improve from 0.50302
# 765/765 [==============================] - 399s 521ms/step - loss: 0.0722 - accuracy: 0.9813 - macro_f1score: 0.1113 - weighted_f1score: 0.0038 - val_loss: 3.2741 - val_accuracy: 0.4997 - val_macro_f1score: 0.0532 - val_weighted_f1score: 0.0019
# Learning rate:  0.0001
#
# Epoch 00056: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 56/70
# 765/765 [==============================] - ETA: 0s - loss: 0.0658 - accuracy: 0.9835 - macro_f1score: 0.1117 - weighted_f1score: 0.0038
# Epoch 00056: val_loss did not improve from 2.52879
#
# Epoch 00056: val_accuracy improved from 0.50302 to 0.50370, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/SE_DenseNet121/056.h5
# 765/765 [==============================] - 401s 525ms/step - loss: 0.0658 - accuracy: 0.9835 - macro_f1score: 0.1117 - weighted_f1score: 0.0038 - val_loss: 3.2919 - val_accuracy: 0.5037 - val_macro_f1score: 0.0530 - val_weighted_f1score: 0.0019
# Learning rate:  0.0001
#
# Epoch 00057: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 57/70
# 765/765 [==============================] - ETA: 0s - loss: 0.0611 - accuracy: 0.9850 - macro_f1score: 0.1122 - weighted_f1score: 0.0038
# Epoch 00057: val_loss did not improve from 2.52879
#
# Epoch 00057: val_accuracy did not improve from 0.50370
# 765/765 [==============================] - 401s 524ms/step - loss: 0.0611 - accuracy: 0.9850 - macro_f1score: 0.1122 - weighted_f1score: 0.0038 - val_loss: 3.3005 - val_accuracy: 0.4990 - val_macro_f1score: 0.0534 - val_weighted_f1score: 0.0019
# Learning rate:  0.0001
#
# Epoch 00058: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 58/70
# 765/765 [==============================] - ETA: 0s - loss: 0.0556 - accuracy: 0.9855 - macro_f1score: 0.1122 - weighted_f1score: 0.0038
# Epoch 00058: val_loss did not improve from 2.52879
#
# Epoch 00058: val_accuracy improved from 0.50370 to 0.50773, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/SE_DenseNet121/058.h5
# 765/765 [==============================] - 402s 525ms/step - loss: 0.0556 - accuracy: 0.9855 - macro_f1score: 0.1122 - weighted_f1score: 0.0038 - val_loss: 3.2853 - val_accuracy: 0.5077 - val_macro_f1score: 0.0533 - val_weighted_f1score: 0.0019
# Learning rate:  0.0001
#
# Epoch 00059: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 59/70
# 765/765 [==============================] - ETA: 0s - loss: 0.0546 - accuracy: 0.9867 - macro_f1score: 0.1123 - weighted_f1score: 0.0038
# Epoch 00059: val_loss did not improve from 2.52879
#
# Epoch 00059: val_accuracy did not improve from 0.50773
# 765/765 [==============================] - 400s 522ms/step - loss: 0.0546 - accuracy: 0.9867 - macro_f1score: 0.1123 - weighted_f1score: 0.0038 - val_loss: 3.3027 - val_accuracy: 0.5047 - val_macro_f1score: 0.0534 - val_weighted_f1score: 0.0019
# Learning rate:  0.0001
#
# Epoch 00060: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 60/70
# 765/765 [==============================] - ETA: 0s - loss: 0.0477 - accuracy: 0.9897 - macro_f1score: 0.1127 - weighted_f1score: 0.0038
# Epoch 00060: val_loss did not improve from 2.52879
#
# Epoch 00060: val_accuracy did not improve from 0.50773
# 765/765 [==============================] - 400s 522ms/step - loss: 0.0477 - accuracy: 0.9897 - macro_f1score: 0.1127 - weighted_f1score: 0.0038 - val_loss: 3.3399 - val_accuracy: 0.4980 - val_macro_f1score: 0.0529 - val_weighted_f1score: 0.0019
# Learning rate:  0.0001
#
# Epoch 00061: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 61/70
# 765/765 [==============================] - ETA: 0s - loss: 0.0482 - accuracy: 0.9881 - macro_f1score: 0.1127 - weighted_f1score: 0.0038
# Epoch 00061: val_loss did not improve from 2.52879
#
# Epoch 00061: val_accuracy did not improve from 0.50773
# 765/765 [==============================] - 399s 522ms/step - loss: 0.0482 - accuracy: 0.9881 - macro_f1score: 0.1127 - weighted_f1score: 0.0038 - val_loss: 3.3342 - val_accuracy: 0.5013 - val_macro_f1score: 0.0529 - val_weighted_f1score: 0.0019
# Learning rate:  0.0001
#
# Epoch 00062: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 62/70
# 765/765 [==============================] - ETA: 0s - loss: 0.0501 - accuracy: 0.9874 - macro_f1score: 0.1125 - weighted_f1score: 0.0038
# Epoch 00062: val_loss did not improve from 2.52879
#
# Epoch 00062: val_accuracy did not improve from 0.50773
# 765/765 [==============================] - 399s 522ms/step - loss: 0.0501 - accuracy: 0.9874 - macro_f1score: 0.1125 - weighted_f1score: 0.0038 - val_loss: 3.3482 - val_accuracy: 0.5007 - val_macro_f1score: 0.0533 - val_weighted_f1score: 0.0019
# Learning rate:  0.0001
#
# Epoch 00063: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 63/70
# 765/765 [==============================] - ETA: 0s - loss: 0.0397 - accuracy: 0.9908 - macro_f1score: 0.1132 - weighted_f1score: 0.0038
# Epoch 00063: val_loss did not improve from 2.52879
#
# Epoch 00063: val_accuracy did not improve from 0.50773
# 765/765 [==============================] - 398s 521ms/step - loss: 0.0397 - accuracy: 0.9908 - macro_f1score: 0.1132 - weighted_f1score: 0.0038 - val_loss: 3.3499 - val_accuracy: 0.5034 - val_macro_f1score: 0.0536 - val_weighted_f1score: 0.0019
# Learning rate:  0.0001
#
# Epoch 00064: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 64/70
# 765/765 [==============================] - ETA: 0s - loss: 0.0413 - accuracy: 0.9895 - macro_f1score: 0.1130 - weighted_f1score: 0.0038
# Epoch 00064: val_loss did not improve from 2.52879
#
# Epoch 00064: val_accuracy did not improve from 0.50773
# 765/765 [==============================] - 398s 521ms/step - loss: 0.0413 - accuracy: 0.9895 - macro_f1score: 0.1130 - weighted_f1score: 0.0038 - val_loss: 3.3414 - val_accuracy: 0.5067 - val_macro_f1score: 0.0536 - val_weighted_f1score: 0.0019
# Learning rate:  0.0001
#
# Epoch 00065: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 65/70
# 765/765 [==============================] - ETA: 0s - loss: 0.0384 - accuracy: 0.9905 - macro_f1score: 0.1128 - weighted_f1score: 0.0038
# Epoch 00065: val_loss did not improve from 2.52879
#
# Epoch 00065: val_accuracy did not improve from 0.50773
# 765/765 [==============================] - 398s 521ms/step - loss: 0.0384 - accuracy: 0.9905 - macro_f1score: 0.1128 - weighted_f1score: 0.0038 - val_loss: 3.3530 - val_accuracy: 0.5007 - val_macro_f1score: 0.0536 - val_weighted_f1score: 0.0019
# Learning rate:  0.0001
#
# Epoch 00066: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 66/70
# 765/765 [==============================] - ETA: 0s - loss: 0.0383 - accuracy: 0.9909 - macro_f1score: 0.1130 - weighted_f1score: 0.0038
# Epoch 00066: val_loss did not improve from 2.52879
#
# Epoch 00066: val_accuracy did not improve from 0.50773
# 765/765 [==============================] - 398s 521ms/step - loss: 0.0383 - accuracy: 0.9909 - macro_f1score: 0.1130 - weighted_f1score: 0.0038 - val_loss: 3.3509 - val_accuracy: 0.5077 - val_macro_f1score: 0.0540 - val_weighted_f1score: 0.0019
# Learning rate:  0.0001
#
# Epoch 00067: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 67/70
# 765/765 [==============================] - ETA: 0s - loss: 0.0384 - accuracy: 0.9910 - macro_f1score: 0.1131 - weighted_f1score: 0.0038
# Epoch 00067: val_loss did not improve from 2.52879
#
# Epoch 00067: val_accuracy did not improve from 0.50773
# 765/765 [==============================] - 398s 521ms/step - loss: 0.0384 - accuracy: 0.9910 - macro_f1score: 0.1131 - weighted_f1score: 0.0038 - val_loss: 3.3795 - val_accuracy: 0.5057 - val_macro_f1score: 0.0546 - val_weighted_f1score: 0.0019
# Learning rate:  0.0001
#
# Epoch 00068: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 68/70
# 765/765 [==============================] - ETA: 0s - loss: 0.0350 - accuracy: 0.9919 - macro_f1score: 0.1134 - weighted_f1score: 0.0039
# Epoch 00068: val_loss did not improve from 2.52879
#
# Epoch 00068: val_accuracy did not improve from 0.50773
# 765/765 [==============================] - 398s 520ms/step - loss: 0.0350 - accuracy: 0.9919 - macro_f1score: 0.1134 - weighted_f1score: 0.0039 - val_loss: 3.3582 - val_accuracy: 0.5040 - val_macro_f1score: 0.0536 - val_weighted_f1score: 0.0019
# Learning rate:  0.0001
#
# Epoch 00069: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 69/70
# 765/765 [==============================] - ETA: 0s - loss: 0.0355 - accuracy: 0.9917 - macro_f1score: 0.1130 - weighted_f1score: 0.0038
# Epoch 00069: val_loss did not improve from 2.52879
#
# Epoch 00069: val_accuracy improved from 0.50773 to 0.50907, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/SE_DenseNet121/069.h5
# 765/765 [==============================] - 401s 524ms/step - loss: 0.0355 - accuracy: 0.9917 - macro_f1score: 0.1130 - weighted_f1score: 0.0038 - val_loss: 3.3781 - val_accuracy: 0.5091 - val_macro_f1score: 0.0542 - val_weighted_f1score: 0.0019
# Learning rate:  0.0001
#
# Epoch 00070: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 70/70
# 765/765 [==============================] - ETA: 0s - loss: 0.0318 - accuracy: 0.9932 - macro_f1score: 0.1135 - weighted_f1score: 0.0039
# Epoch 00070: val_loss did not improve from 2.52879
#
# Epoch 00070: val_accuracy did not improve from 0.50907
# 765/765 [==============================] - 399s 522ms/step - loss: 0.0318 - accuracy: 0.9932 - macro_f1score: 0.1135 - weighted_f1score: 0.0039 - val_loss: 3.3503 - val_accuracy: 0.5084 - val_macro_f1score: 0.0543 - val_weighted_f1score: 0.0019

# %% [markdown]
# ### 2) SE-DenseNet121 Evaluate

# %%
# 1. epoch=maximum
loss , acc, mf1, wf1 = model.evaluate(test_generator,steps=int(len(x_test)/batch_sizes))
print('[Test Loss: %.4f /  Test Accuracy: %.4f / Test Macro f1: %.4f / Test Weighted f1: %.4f]\n' % (loss,acc,mf1,wf1))
# Out:
# 97/97 [==============================] - 811s 8s/step - loss: 3.3203 - accuracy: 0.5087 - macro_f1score: 0.0541 - weighted_f1score: 0.0019
# [Test Loss: 3.3203 /  Test Accuracy: 0.5087 / Test Macro f1: 0.0541 / Test Weighted f1: 0.0019]

# %%
loss=history.history['loss']
val_loss=history.history['val_loss']
acc=history.history['accuracy']
val_acc=history.history['val_accuracy']
f1=history.history['macro_f1score']
val_f1=history.history['val_macro_f1score']
epochs=range(1,len(acc)+1)

data = np.array([epochs,loss,val_loss,acc,val_acc,f1,val_f1]).T

# %%
# data save
# epochs, loss, val_loss, acc, val_acc, f1, val_f1

np.savetxt(os.path.join(dir,'train_valid_output',number,model.name+'.txt'),data)

# %%
# data import
data = np.loadtxt(os.path.join(dir,'train_valid_output',number,'SE_DenseNet121.txt'))

# %%
epochs=data[:,0]
loss=data[:,1]
val_loss=data[:,2]
acc=data[:,3]
val_acc=data[:,4]

# %%
plt.plot(epochs[1:],acc[1:],'b',label='Training Acc')
plt.plot(epochs[1:],val_acc[1:],'r',label='Validation Acc')
plt.title('Training and Validation Accuracy')
plt.legend()
plt.figure()
plt.plot(epochs[10:],loss[10:],'b',label='Training Loss')
plt.plot(epochs[10:],val_loss[10:],'r',label='Validation Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()

# %%
# 이 아래는 내가 인위적으로 살펴보고 싶은 epoch에 대해서 결과값 출력 / SE-DenseNet121

# %%
model=load_model(os.path.join(dir,'model_output',number,'SE_DenseNet121','026.h5'),custom_objects={"macro_f1score": macro_f1score,"weighted_f1score":weighted_f1score})

# %%
# 2. epoch=?
loss , acc, mf1, wf1 = model.evaluate(test_generator,steps=int(len(x_test)/batch_sizes))
print('[Test Loss: %.4f /  Test Accuracy: %.4f / Test Macro f1: %.4f / Test Weighted f1: %.4f]\n' % (loss,acc,mf1,wf1))
