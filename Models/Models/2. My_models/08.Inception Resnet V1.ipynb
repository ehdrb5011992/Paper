# %%
# 참고 : https://sike6054.github.io/blog/paper/fourth-post/

# %% [markdown]
# # [Inception ResNet V1]

# %% [markdown]
# *KU LeeDongGyu*

# %% [markdown]
# ## Contents
# ---

# %% [markdown]
# 1. Data Preprocessing
# ```
# 1) Data Import
# 2) Data Augmentation
# ```
# 2. Support Functions & Almost Original Inception-ResNet-V1
# ```
# 1) Support Functions
# 2) Almost Original Inception-ResNet-V1
# 3) Inception-ResNet-V1 Evaluate
# ```

# %% [markdown]
# ### Install Packages

# %% [markdown]
# ### Module

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
cd /content/drive/My Drive/Colab Notebooks/Paper
# Out:
# /content/drive/My Drive/Colab Notebooks/Paper

# %%
from f1score import macro_f1score,weighted_f1score

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import cv2
import tensorflow as tf
from tensorflow import keras as ks
from tensorflow.keras import backend as K 
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, Input, Concatenate, ZeroPadding2D ,GlobalMaxPooling2D, Reshape , Lambda , Add, Multiply
from tensorflow.keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D, Activation, BatchNormalization, AveragePooling2D , ZeroPadding2D, SeparableConv2D
from tensorflow.keras.layers import add
from tensorflow.keras.optimizers import Adam, RMSprop , SGD
from tensorflow.keras.callbacks import EarlyStopping , LearningRateScheduler, ModelCheckpoint, CSVLogger, Callback, ReduceLROnPlateau
from tensorflow.keras.regularizers import l1,l2,l1_l2
from tensorflow.keras.models import Model , load_model , Sequential
from tensorflow.keras.utils import plot_model , to_categorical, get_file
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
os.getcwd()
# Out:
# '/content/drive/My Drive/Colab Notebooks/Paper'

# %%
print(tf.__version__)
print(ks.__version__)
# Out:
# 2.3.0
# 2.4.0

# %%
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 11917036442880648247
# , name: "/device:XLA_CPU:0"
# device_type: "XLA_CPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 1153462345819210821
# physical_device_desc: "device: XLA_CPU device"
# , name: "/device:XLA_GPU:0"
# device_type: "XLA_GPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 329822033879997022
# physical_device_desc: "device: XLA_GPU device"
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 15695549568
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 381660589173908230
# physical_device_desc: "device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0"
# ]

# %% [markdown]
# ## 1. Data Preprocessing
# ---

# %% [markdown]
# ### 1) Data Import

# %%
# 바꿔서 살펴 볼 것들
# CALTECH, CIFAR100, FER, MIT
data_name = 'CALTECH'
gan_type = 'No_GAN'
number = '1'
size = 299 # sizes after cropping
super_size = 330 # sizes before cropping 
input_sizes = (size,size,3)
batch_sizes = 64
weight_decay = 1e-3
epochs = 70

# %%
# 참고 : https://stackoverflow.com/questions/32419510/how-to-get-reproducible-results-in-keras/52897216#52897216
# setting the seed number for random number generation for reproducibility.

from numpy.random import seed
import random


if number=='1':
    seed_num = 200225
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)
elif number=='2':
    seed_num = 727
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)
elif number=='3':
    seed_num = 115
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)
elif number=='4':
    seed_num = 501
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)
elif number=='5':
    seed_num = 517
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)

# %%
# data import

if data_name=='FER' :
    x_train =  np.zeros(28698)
    x_valid = np.zeros(3589)
    x_test = np.zeros(3588)
    classes = 7 
    tr_center = [0.50793296, 0.50793296, 0.50793296]
elif data_name=='MIT':
    x_train = np.zeros(12466)
    x_valid = np.zeros(1564)
    x_test = np.zeros(1590)
    classes = 67 
    tr_center = [0.47916578, 0.42029615, 0.36046057]
elif data_name=='CALTECH':
    x_train = np.zeros(24510)
    x_valid = np.zeros(2980)
    x_test = np.zeros(3118)
    classes = 257
    tr_center = [0.51397761, 0.49525248, 0.46555727]
elif data_name=='CIFAR100':
    x_train = np.zeros(39941)
    x_valid = np.zeros(10059)
    x_test = np.zeros(10000)
    classes = 100
    tr_center = [0.53393271, 0.51324147, 0.46450563]

# %%
dir = os.path.join(os.getcwd(),data_name,gan_type)

# %% [markdown]
# ### 2) Data Augmentation

# %%
# 참고 : https://jkjung-avt.github.io/keras-image-cropping/

def random_crop(img, random_crop_size):
    # Note: image_data_format is 'channel_last'
    assert img.shape[2] == 3 # img.shape[2] 가 3(rgb)이 아니면 assertion error 발생
    height, width = img.shape[0], img.shape[1]
    dy, dx = random_crop_size
    x = np.random.randint(0, width - dx + 1)
    y = np.random.randint(0, height - dy + 1)
    return img[y:(y+dy), x:(x+dx), :]


def crop_generator(batches, crop_length):
    """Take as input a Keras ImageGen (Iterator) and generate random
    crops from the image batches generated by the original iterator.
    """
    while True:
        batch_x, batch_y = next(batches)
        batch_crops = np.zeros((batch_x.shape[0], crop_length, crop_length, 3))
        for i in range(batch_x.shape[0]):
            batch_crops[i] = random_crop(batch_x[i], (crop_length, crop_length))
        yield (batch_crops, batch_y)

# %%
from tensorflow.keras.preprocessing.image import img_to_array,load_img
import glob

# 데이터 전체에 대해 centering 진행함.

def read_cal_image(img_path): 
    x = img_to_array(load_img(img_path)) # x는 채널별 평균값
    y = x.shape[0] * x.shape[1]# y는 데이터별 픽셀 수 (비중)

    x = 1/255. * x # scaling하고, centering값을 뽑아냄.
    x = np.mean(x, axis=(0,1))
    
    return np.hstack([x,y])

def calculate_centered_mean(dataset_path,x_train=x_train):
    num = len(x_train)
    space = np.empty((num,4))
    i=0

    for p in glob.glob(os.path.join(dataset_path,'*/*.*')) :
        space[i] = read_cal_image(p)
        i += 1

    ratio = space[:,3] / np.sum(space[:,3])

    return np.average(space[:,0:3],axis=0,weights=ratio)


# 아래의 함수를 돌려서 나온 결과값을 중심화 값으로 설정.

# train_mean = calculate_centered_mean(os.path.join(dir,'data/train')).reshape((1,1,3))

# %%
datagen_tr = ImageDataGenerator(
    rescale=1/255.,
    horizontal_flip=True,
    featurewise_center=True,
    featurewise_std_normalization=False,
    rotation_range=10,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=[0.9,1.0],
    fill_mode = 'nearest')
datagen_val = ImageDataGenerator(rescale=1/255.,featurewise_center=True)
datagen_tes = ImageDataGenerator(rescale=1/255.,featurewise_center=True)

# 원래는 이 자리에 fit 매서드를 써야하지만, 그냥 내가 중심화함수를 만들고 적용함. 

# 중심화 설정
datagen_tr.mean = np.array(tr_center, dtype=np.float32).reshape((1,1,3)) # RGB
datagen_val.mean = np.array(tr_center, dtype=np.float32).reshape((1,1,3)) # RGB
datagen_tes.mean = np.array(tr_center, dtype=np.float32).reshape((1,1,3)) # RGB

# %%
train_batches = datagen_tr.flow_from_directory(directory=os.path.join(dir,'data/train'),target_size=(super_size,super_size),batch_size=batch_sizes,class_mode='categorical') # fer : 28698 / mit : 12466 / caltech : 24509 / cifar : 39941
train_generator= crop_generator(train_batches, size)
valid_generator = datagen_val.flow_from_directory(directory=os.path.join(dir,'data/valid'),target_size=(size,size),batch_size=batch_sizes,class_mode='categorical') # fer : 3589 / mit : 1564 / caltech : 2980 / cifar : 10059
test_generator = datagen_tes.flow_from_directory(directory=os.path.join(dir,'data/test'),target_size=(size,size),batch_size=batch_sizes,class_mode='categorical') # fer : 3588 / mit : 1590 / caltech : 3118 / cifar : 10000
# Out:
# Found 24509 images belonging to 257 classes.
# Found 2980 images belonging to 257 classes.
# Found 3118 images belonging to 257 classes.

# %% [markdown]
# ## 2. Support Functions & Almost Original Inception-ResNet-V1

# %% [markdown]
# ### 1) Support Functions

# %%
# def lr_schedule(epoch):
#     init_lr = 1e-4
#     k = 0.04
#     lr = init_lr * np.exp(-k*epoch)
#     print('Learning rate: ', lr)
#     return lr

def lr_schedule(epoch):
    lr = 1e-3
    if epoch < 60:
        lr = lr
    else :
        lr = lr * 0.1
    print('Learning rate: ', lr)
    return lr

# %%
def Scaling_Residual(Inception, scale):
    x = Lambda(lambda Inception, scale: Inception * scale, arguments={'scale': scale})(Inception)
    x = Activation(activation='relu')(x)
    
    return x

# %%
def conv2d_bn(x, filters, kernel_size, weight_decay=weight_decay, padding='same', strides=1, activation='relu'):
    x = Conv2D(filters, (kernel_size[0], kernel_size[1]), padding=padding, strides=strides, kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(x)    
    x = BatchNormalization()(x)
    
    if activation:
        x = Activation(activation)(x)
    
    return x

# %%
def Stem(input_tensor, version=None, name=None):
    if version == 'Inception-v4' or version == 'Inception-ResNet-v2':
        x = conv2d_bn(input_tensor, 32, (3, 3), padding='valid', strides=2) # 299x299x3 -> 149x149x32
        x = conv2d_bn(x, 32, (3, 3), padding='valid') # 149x149x32 -> 147x147x32
        x = conv2d_bn(x, 64, (3, 3)) # 147x147x32 -> 147x147x64
        
        branch_1 = MaxPooling2D((3, 3), padding='valid', strides=2)(x)
        branch_2 = conv2d_bn(x, 96, (3, 3), padding='valid', strides=2)
        x = Concatenate()([branch_1, branch_2]) # 73x73x160
        
        branch_1 = conv2d_bn(x, 64, (1, 1))
        branch_1 = conv2d_bn(branch_1, 96, (3, 3), padding='valid')
        branch_2 = conv2d_bn(x, 64, (1, 1))
        branch_2 = conv2d_bn(branch_2, 64, (7, 1))
        branch_2 = conv2d_bn(branch_2, 64, (1, 7))
        branch_2 = conv2d_bn(branch_2, 96, (3, 3), padding='valid')
        x = Concatenate()([branch_1, branch_2]) # 71x71x192
        
        branch_1 = conv2d_bn(x, 192, (3, 3), padding='valid', strides=2) # Fig.4 is wrong
        branch_2 = MaxPooling2D((3, 3), padding='valid', strides=2)(x)
        x = Concatenate(name=name)([branch_1, branch_2]) if name else Concatenate()([branch_1, branch_2]) # 35x35x384
        
    elif version == 'Inception-ResNet-v1':
        x = conv2d_bn(input_tensor, 32, (3, 3), padding='valid', strides=2) # 299x299x3 -> 149x149x32
        x = conv2d_bn(x, 32, (3, 3), padding='valid') # 149x149x32 -> 147x147x32
        x = conv2d_bn(x, 64, (3, 3)) # 147x147x32 -> 147x147x64
        
        x = MaxPooling2D((3, 3), strides=2, padding='valid')(x) # 147x147x64 -> 73x73x64
        
        x = conv2d_bn(x, 80, (1, 1)) # 73x73x64 -> 73x73x80
        x = conv2d_bn(x, 192, (3, 3), padding='valid') # 73x73x80 -> 71x71x192U
        x = conv2d_bn(x, 256, (3, 3), padding='valid', strides=2) # 71x71x192 -> 35x35x256
        
    else:
        return None # Kill ^^
    
    return x

# %%
def Inception_ResNet_A(input_tensor, scale=0.1, version=None, name=None):   
    if version == 'Inception-ResNet-v1':
        branch_1 = conv2d_bn(input_tensor, 32, (1, 1))
    
        branch_2 = conv2d_bn(input_tensor, 32, (1, 1))
        branch_2 = conv2d_bn(branch_2, 32, (3, 3))
        
        branch_3 = conv2d_bn(input_tensor, 32, (1, 1))
        branch_3 = conv2d_bn(branch_3, 32, (3, 3))
        branch_3 = conv2d_bn(branch_3, 32, (3, 3))
        
        branches = Concatenate()([branch_1, branch_2, branch_3])
        Inception = conv2d_bn(branches, 256, (1, 1), activation=None)
    
    elif version == 'Inception-ResNet-v2':
        branch_1 = conv2d_bn(input_tensor, 32, (1, 1))
    
        branch_2 = conv2d_bn(input_tensor, 32, (1, 1))
        branch_2 = conv2d_bn(branch_2, 32, (3, 3))
        
        branch_3 = conv2d_bn(input_tensor, 32, (1, 1))
        branch_3 = conv2d_bn(branch_3, 48, (3, 3))
        branch_3 = conv2d_bn(branch_3, 64, (3, 3))
        
        branches = Concatenate()([branch_1, branch_2, branch_3])
        Inception = conv2d_bn(branches, 384, (1, 1), activation=None)
    
    else:
        return None # Kill ^^
    
    scaled_activation = Scaling_Residual(Inception, scale=scale)
    
    residual_connection = Add(name=name)([input_tensor, scaled_activation]) if name else Add()([input_tensor, scaled_activation])
    
    return residual_connection

def Inception_ResNet_B(input_tensor, scale=0.1, version=None, name=None):
    if version == 'Inception-ResNet-v1':
        branch_1 = conv2d_bn(input_tensor, 128, (1, 1))
        
        branch_2 = conv2d_bn(input_tensor, 128, (1, 1))
        branch_2 = conv2d_bn(branch_2, 128, (1, 7))
        branch_2 = conv2d_bn(branch_2, 128, (7, 1))
        
        branches = Concatenate()([branch_1, branch_2])
        Inception = conv2d_bn(branches, 896, (1, 1), activation=None)
    
    elif version == 'Inception-ResNet-v2':
        branch_1 = conv2d_bn(input_tensor, 192, (1, 1))
        
        branch_2 = conv2d_bn(input_tensor, 128, (1, 1))
        branch_2 = conv2d_bn(branch_2, 160, (1, 7))
        branch_2 = conv2d_bn(branch_2, 192, (7, 1))
        
        branches = Concatenate()([branch_1, branch_2])
        Inception = conv2d_bn(branches, 1152, (1, 1), activation=None) # Fig.17 is wrong
    
    else:
        return None # Kill ^^
    
    scaled_activation = Scaling_Residual(Inception, scale=scale)
    
    residual_connection = Add(name=name)([input_tensor, scaled_activation]) if name else Add()([input_tensor, scaled_activation])
    
    return residual_connection

def Inception_ResNet_C(input_tensor, scale=0.1, version=None, name=None):    
    if version == 'Inception-ResNet-v1':
        branch_1 = conv2d_bn(input_tensor, 192, (1, 1))
        
        branch_2 = conv2d_bn(input_tensor, 192, (1, 1))
        branch_2 = conv2d_bn(branch_2, 192, (1, 3))
        branch_2 = conv2d_bn(branch_2, 192, (3, 1))
        
        branches = Concatenate()([branch_1, branch_2])
        Inception = conv2d_bn(branches, 1792, (1, 1), activation=None)
    
    elif version == 'Inception-ResNet-v2':
        branch_1 = conv2d_bn(input_tensor, 192, (1, 1))
        
        branch_2 = conv2d_bn(input_tensor, 192, (1, 1))
        branch_2 = conv2d_bn(branch_2, 224, (1, 3))
        branch_2 = conv2d_bn(branch_2, 256, (3, 1))
        
        branches = Concatenate()([branch_1, branch_2])
        Inception = conv2d_bn(branches, 2144, (1, 1), activation=None) # Fig.19 is wrong
    
    else:
        return None # Kill ^^
    
    scaled_activation = Scaling_Residual(Inception, scale=scale)
    
    residual_connection = Add(name=name)([input_tensor, scaled_activation]) if name else Add()([input_tensor, scaled_activation])
    
    return residual_connection

# %%
reduction_table = {'Inception-v4' : [192, 224, 256, 384],
                   'Inception-ResNet-v1' : [192, 192, 256, 384],
                   'Inception-ResNet-v2' : [256, 256, 384, 384]}

def Reduction_A(input_tensor, version=None, name=None):
    k, l, m, n = reduction_table[version]

    branch_1 = MaxPooling2D((3, 3), padding='valid', strides=2)(input_tensor)

    branch_2 = conv2d_bn(input_tensor, n, (3, 3), padding='valid', strides=2)

    branch_3 = conv2d_bn(input_tensor, k, (1, 1))
    branch_3 = conv2d_bn(branch_3, l, (3, 3))
    branch_3 = conv2d_bn(branch_3, m, (3, 3), padding='valid', strides=2)

    filter_concat = Concatenate(name=name)([branch_1, branch_2, branch_3]) if name else Concatenate()([branch_1, branch_2, branch_3])

    return filter_concat

def Reduction_B(input_tensor, version=None, name=None):
    if version == 'Inception-v4':
        branch_1 = MaxPooling2D((3, 3), padding='valid', strides=2)(input_tensor)
    
        branch_2 = conv2d_bn(input_tensor, 192, (1, 1))
        branch_2 = conv2d_bn(branch_2, 192, (3, 3), padding='valid', strides=2)
    
        branch_3 = conv2d_bn(input_tensor, 256, (1, 1))
        branch_3 = conv2d_bn(branch_3, 256, (1, 7))
        branch_3 = conv2d_bn(branch_3, 320, (7, 1))
        branch_3 = conv2d_bn(branch_3, 320, (3, 3), padding='valid', strides=2)
    
        filter_concat = Concatenate(name=name)([branch_1, branch_2, branch_3]) if name else Concatenate()([branch_1, branch_2, branch_3])

    elif version == 'Inception-ResNet-v1':
        branch_1 = MaxPooling2D((3, 3), padding='valid', strides=2)(input_tensor)
    
        branch_2 = conv2d_bn(input_tensor, 256, (1, 1))
        branch_2 = conv2d_bn(branch_2, 384, (3, 3), padding='valid', strides=2)
    
        branch_3 = conv2d_bn(input_tensor, 256, (1, 1))
        branch_3 = conv2d_bn(branch_3, 256, (3, 3), padding='valid', strides=2)
        
        branch_4 = conv2d_bn(input_tensor, 256, (1, 1))
        branch_4 = conv2d_bn(branch_4, 256, (3, 3))
        branch_4 = conv2d_bn(branch_4, 256, (3, 3), padding='valid', strides=2)
    
        filter_concat = Concatenate(name=name)([branch_1, branch_2, branch_3, branch_4]) if name else Concatenate()([branch_1, branch_2, branch_3, branch_4])

    elif version == 'Inception-ResNet-v2':
        branch_1 = MaxPooling2D((3, 3), padding='valid', strides=2)(input_tensor)
    
        branch_2 = conv2d_bn(input_tensor, 256, (1, 1))
        branch_2 = conv2d_bn(branch_2, 384, (3, 3), padding='valid', strides=2)
    
        branch_3 = conv2d_bn(input_tensor, 256, (1, 1))
        branch_3 = conv2d_bn(branch_3, 288, (3, 3), padding='valid', strides=2)
        
        branch_4 = conv2d_bn(input_tensor, 256, (1, 1))
        branch_4 = conv2d_bn(branch_4, 288, (3, 3))
        branch_4 = conv2d_bn(branch_4, 320, (3, 3), padding='valid', strides=2)
    
        filter_concat = Concatenate(name=name)([branch_1, branch_2, branch_3, branch_4]) if name else Concatenate()([branch_1, branch_2, branch_3, branch_4])
    
    else:
        return None # Kill ^^
    
    return filter_concat

# %%
def Inception_ResNet(model_input, version='Inception-ResNet-v2', classes=1000, name='Inception_ResNet_v2'):    
    x = Stem(model_input, version=version, name='Stem')
    # Inception-ResNet-v1 : (299, 299, 3) -> (35, 35, 256)
    # Inception-ResNet-v2 : (299, 299, 3) -> (35, 35, 384)
    
    for i in range(5):
        x = Inception_ResNet_A(x, scale=0.17, version=version, name='Inception-ResNet-A-'+str(i+1))
        # Inception-ResNet-v1 : (35, 35, 256)
        # Inception-ResNet-v2 : (35, 35, 384)
        
    x = Reduction_A(x, version=version, name='Reduction-A')
    # Inception-ResNet-v1 : (35, 35, 256) -> (17, 17, 896)
    # Inception-ResNet-v2 : (35, 35, 384) -> (17, 17, 1152)
    
    for i in range(10):
        x = Inception_ResNet_B(x, scale=0.1, version=version, name='Inception-ResNet-B-'+str(i+1))
        # Inception-ResNet-v1 : (17, 17, 896)
        # Inception-ResNet-v2 : (17, 17, 1152)

    x = Reduction_B(x, version=version, name='Reduction-B')
    # Inception-ResNet-v1 : (17, 17, 896) -> (8, 8, 1792)
    # Inception-ResNet-v2 : (17, 17, 1152) -> (8, 8, 2144)
    
    for i in range(5):
        x = Inception_ResNet_C(x, scale=0.2, version=version, name='Inception-ResNet-C-'+str(i+1))
        # Inception-ResNet-v1 : (8, 8, 1792)
        # Inception-ResNet-v2 : (8, 8, 2144)
    
    x = GlobalAveragePooling2D()(x)
    # Inception-ResNet-v1 : (1792)
    # Inception-ResNet-v2 : (2144)
    
    x = Dropout(0.2)(x)
    
    model_output = Dense(classes, activation='softmax', name='output')(x)

    model = Model(model_input, model_output, name=name)
    
    return model

# %% [markdown]
# ### 2) Almost Original Inception-ResNet-V1

# %%
# weight_decay는 inception-v3의 weight decay임. - 튜닝해볼 것

model_input = Input(shape=input_sizes)
model = Inception_ResNet(model_input, version='Inception-ResNet-v1', classes=classes, name='Inception_ResNet_v1')

# %%
model.summary()
# Out:
# Model: "Inception_ResNet_v1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 299, 299, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 149, 149, 32) 896         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 149, 149, 32) 128         conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 149, 149, 32) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 147, 147, 32) 9248        activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 147, 147, 32) 128         conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 147, 147, 32) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 147, 147, 64) 18496       activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 147, 147, 64) 256         conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 147, 147, 64) 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 73, 73, 64)   0           activation_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 73, 73, 80)   5200        max_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 73, 73, 80)   320         conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 73, 73, 80)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 71, 71, 192)  138432      activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 71, 71, 192)  768         conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 71, 71, 192)  0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 35, 35, 256)  442624      activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 35, 35, 256)  1024        conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 35, 35, 256)  0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 35, 35, 32)   8224        activation_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 35, 35, 32)   128         conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 35, 35, 32)   0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 35, 35, 32)   8224        activation_5[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 35, 35, 32)   9248        activation_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 35, 35, 32)   128         conv2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 35, 35, 32)   128         conv2d_10[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 35, 35, 32)   0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 35, 35, 32)   0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 35, 35, 32)   8224        activation_5[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 35, 35, 32)   9248        activation_7[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 35, 35, 32)   9248        activation_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 35, 35, 32)   128         conv2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 35, 35, 32)   128         conv2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 35, 35, 32)   128         conv2d_11[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 35, 35, 32)   0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 35, 35, 32)   0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 35, 35, 32)   0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 35, 35, 96)   0           activation_6[0][0]
#                                                                  activation_8[0][0]
#                                                                  activation_11[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 35, 35, 256)  24832       concatenate[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 35, 35, 256)  1024        conv2d_12[0][0]
# __________________________________________________________________________________________________
# lambda (Lambda)                 (None, 35, 35, 256)  0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 35, 35, 256)  0           lambda[0][0]
# __________________________________________________________________________________________________
# Inception-ResNet-A-1 (Add)      (None, 35, 35, 256)  0           activation_5[0][0]
#                                                                  activation_12[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 35, 35, 32)   8224        Inception-ResNet-A-1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 35, 35, 32)   128         conv2d_16[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 35, 35, 32)   0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 35, 35, 32)   8224        Inception-ResNet-A-1[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 35, 35, 32)   9248        activation_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 35, 35, 32)   128         conv2d_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 35, 35, 32)   128         conv2d_17[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 35, 35, 32)   0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 35, 35, 32)   0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 35, 35, 32)   8224        Inception-ResNet-A-1[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 35, 35, 32)   9248        activation_14[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 35, 35, 32)   9248        activation_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 35, 35, 32)   128         conv2d_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 35, 35, 32)   128         conv2d_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 35, 35, 32)   128         conv2d_18[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 35, 35, 32)   0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 35, 35, 32)   0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 35, 35, 32)   0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 35, 35, 96)   0           activation_13[0][0]
#                                                                  activation_15[0][0]
#                                                                  activation_18[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 35, 35, 256)  24832       concatenate_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 35, 35, 256)  1024        conv2d_19[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 35, 35, 256)  0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 35, 35, 256)  0           lambda_1[0][0]
# __________________________________________________________________________________________________
# Inception-ResNet-A-2 (Add)      (None, 35, 35, 256)  0           Inception-ResNet-A-1[0][0]
#                                                                  activation_19[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 35, 35, 32)   8224        Inception-ResNet-A-2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 35, 35, 32)   128         conv2d_23[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 35, 35, 32)   0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 35, 35, 32)   8224        Inception-ResNet-A-2[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 35, 35, 32)   9248        activation_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 35, 35, 32)   128         conv2d_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 35, 35, 32)   128         conv2d_24[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 35, 35, 32)   0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 35, 35, 32)   0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 35, 35, 32)   8224        Inception-ResNet-A-2[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 35, 35, 32)   9248        activation_21[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 35, 35, 32)   9248        activation_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 35, 35, 32)   128         conv2d_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 35, 35, 32)   128         conv2d_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 35, 35, 32)   128         conv2d_25[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 35, 35, 32)   0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 35, 35, 32)   0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 35, 35, 32)   0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 35, 35, 96)   0           activation_20[0][0]
#                                                                  activation_22[0][0]
#                                                                  activation_25[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 35, 35, 256)  24832       concatenate_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 35, 35, 256)  1024        conv2d_26[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 35, 35, 256)  0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 35, 35, 256)  0           lambda_2[0][0]
# __________________________________________________________________________________________________
# Inception-ResNet-A-3 (Add)      (None, 35, 35, 256)  0           Inception-ResNet-A-2[0][0]
#                                                                  activation_26[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 35, 35, 32)   8224        Inception-ResNet-A-3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 35, 35, 32)   128         conv2d_30[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 35, 35, 32)   0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 35, 35, 32)   8224        Inception-ResNet-A-3[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 35, 35, 32)   9248        activation_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 35, 35, 32)   128         conv2d_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 35, 35, 32)   128         conv2d_31[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 35, 35, 32)   0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 35, 35, 32)   0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 35, 35, 32)   8224        Inception-ResNet-A-3[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 35, 35, 32)   9248        activation_28[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 35, 35, 32)   9248        activation_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 35, 35, 32)   128         conv2d_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 35, 35, 32)   128         conv2d_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 35, 35, 32)   128         conv2d_32[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 35, 35, 32)   0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 35, 35, 32)   0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 35, 35, 32)   0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 35, 35, 96)   0           activation_27[0][0]
#                                                                  activation_29[0][0]
#                                                                  activation_32[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 35, 35, 256)  24832       concatenate_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 35, 35, 256)  1024        conv2d_33[0][0]
# __________________________________________________________________________________________________
# lambda_3 (Lambda)               (None, 35, 35, 256)  0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 35, 35, 256)  0           lambda_3[0][0]
# __________________________________________________________________________________________________
# Inception-ResNet-A-4 (Add)      (None, 35, 35, 256)  0           Inception-ResNet-A-3[0][0]
#                                                                  activation_33[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 35, 35, 32)   8224        Inception-ResNet-A-4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 35, 35, 32)   128         conv2d_37[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 35, 35, 32)   0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 35, 35, 32)   8224        Inception-ResNet-A-4[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 35, 35, 32)   9248        activation_37[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 35, 35, 32)   128         conv2d_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 35, 35, 32)   128         conv2d_38[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 35, 35, 32)   0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 35, 35, 32)   0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 35, 35, 32)   8224        Inception-ResNet-A-4[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 35, 35, 32)   9248        activation_35[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 35, 35, 32)   9248        activation_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 35, 35, 32)   128         conv2d_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 35, 35, 32)   128         conv2d_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 35, 35, 32)   128         conv2d_39[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 35, 35, 32)   0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 35, 35, 32)   0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 35, 35, 32)   0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 35, 35, 96)   0           activation_34[0][0]
#                                                                  activation_36[0][0]
#                                                                  activation_39[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 35, 35, 256)  24832       concatenate_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 35, 35, 256)  1024        conv2d_40[0][0]
# __________________________________________________________________________________________________
# lambda_4 (Lambda)               (None, 35, 35, 256)  0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 35, 35, 256)  0           lambda_4[0][0]
# __________________________________________________________________________________________________
# Inception-ResNet-A-5 (Add)      (None, 35, 35, 256)  0           Inception-ResNet-A-4[0][0]
#                                                                  activation_40[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 35, 35, 192)  49344       Inception-ResNet-A-5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 35, 35, 192)  768         conv2d_42[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 35, 35, 192)  0           batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 35, 35, 192)  331968      activation_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 35, 35, 192)  768         conv2d_43[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 35, 35, 192)  0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 17, 17, 384)  885120      Inception-ResNet-A-5[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 17, 17, 256)  442624      activation_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 17, 17, 384)  1536        conv2d_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 17, 17, 256)  1024        conv2d_44[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 17, 17, 256)  0           Inception-ResNet-A-5[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 17, 17, 384)  0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 17, 17, 256)  0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# Reduction-A (Concatenate)       (None, 17, 17, 896)  0           max_pooling2d_1[0][0]
#                                                                  activation_41[0][0]
#                                                                  activation_44[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 17, 17, 128)  114816      Reduction-A[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 17, 17, 128)  512         conv2d_46[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 17, 17, 128)  0           batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 17, 17, 128)  114816      activation_46[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 17, 17, 128)  512         conv2d_47[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 17, 17, 128)  0           batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 17, 17, 128)  114816      Reduction-A[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 17, 17, 128)  114816      activation_47[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 17, 17, 128)  512         conv2d_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 17, 17, 128)  512         conv2d_48[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 17, 17, 128)  0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 17, 17, 128)  0           batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 17, 17, 256)  0           activation_45[0][0]
#                                                                  activation_48[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 17, 17, 896)  230272      concatenate_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 17, 17, 896)  3584        conv2d_49[0][0]
# __________________________________________________________________________________________________
# lambda_5 (Lambda)               (None, 17, 17, 896)  0           batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 17, 17, 896)  0           lambda_5[0][0]
# __________________________________________________________________________________________________
# Inception-ResNet-B-1 (Add)      (None, 17, 17, 896)  0           Reduction-A[0][0]
#                                                                  activation_49[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 17, 17, 128)  114816      Inception-ResNet-B-1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 17, 17, 128)  512         conv2d_51[0][0]
# __________________________________________________________________________________________________
# activation_51 (Activation)      (None, 17, 17, 128)  0           batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 17, 17, 128)  114816      activation_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 17, 17, 128)  512         conv2d_52[0][0]
# __________________________________________________________________________________________________
# activation_52 (Activation)      (None, 17, 17, 128)  0           batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 17, 17, 128)  114816      Inception-ResNet-B-1[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 17, 17, 128)  114816      activation_52[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 17, 17, 128)  512         conv2d_50[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, 17, 17, 128)  512         conv2d_53[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, 17, 17, 128)  0           batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# activation_53 (Activation)      (None, 17, 17, 128)  0           batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 17, 17, 256)  0           activation_50[0][0]
#                                                                  activation_53[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 17, 17, 896)  230272      concatenate_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, 17, 17, 896)  3584        conv2d_54[0][0]
# __________________________________________________________________________________________________
# lambda_6 (Lambda)               (None, 17, 17, 896)  0           batch_normalization_54[0][0]
# __________________________________________________________________________________________________
# activation_54 (Activation)      (None, 17, 17, 896)  0           lambda_6[0][0]
# __________________________________________________________________________________________________
# Inception-ResNet-B-2 (Add)      (None, 17, 17, 896)  0           Inception-ResNet-B-1[0][0]
#                                                                  activation_54[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 17, 17, 128)  114816      Inception-ResNet-B-2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_56 (BatchNo (None, 17, 17, 128)  512         conv2d_56[0][0]
# __________________________________________________________________________________________________
# activation_56 (Activation)      (None, 17, 17, 128)  0           batch_normalization_56[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 17, 17, 128)  114816      activation_56[0][0]
# __________________________________________________________________________________________________
# batch_normalization_57 (BatchNo (None, 17, 17, 128)  512         conv2d_57[0][0]
# __________________________________________________________________________________________________
# activation_57 (Activation)      (None, 17, 17, 128)  0           batch_normalization_57[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 17, 17, 128)  114816      Inception-ResNet-B-2[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, 17, 17, 128)  114816      activation_57[0][0]
# __________________________________________________________________________________________________
# batch_normalization_55 (BatchNo (None, 17, 17, 128)  512         conv2d_55[0][0]
# __________________________________________________________________________________________________
# batch_normalization_58 (BatchNo (None, 17, 17, 128)  512         conv2d_58[0][0]
# __________________________________________________________________________________________________
# activation_55 (Activation)      (None, 17, 17, 128)  0           batch_normalization_55[0][0]
# __________________________________________________________________________________________________
# activation_58 (Activation)      (None, 17, 17, 128)  0           batch_normalization_58[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 17, 17, 256)  0           activation_55[0][0]
#                                                                  activation_58[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, 17, 17, 896)  230272      concatenate_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_59 (BatchNo (None, 17, 17, 896)  3584        conv2d_59[0][0]
# __________________________________________________________________________________________________
# lambda_7 (Lambda)               (None, 17, 17, 896)  0           batch_normalization_59[0][0]
# __________________________________________________________________________________________________
# activation_59 (Activation)      (None, 17, 17, 896)  0           lambda_7[0][0]
# __________________________________________________________________________________________________
# Inception-ResNet-B-3 (Add)      (None, 17, 17, 896)  0           Inception-ResNet-B-2[0][0]
#                                                                  activation_59[0][0]
# __________________________________________________________________________________________________
# conv2d_61 (Conv2D)              (None, 17, 17, 128)  114816      Inception-ResNet-B-3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_61 (BatchNo (None, 17, 17, 128)  512         conv2d_61[0][0]
# __________________________________________________________________________________________________
# activation_61 (Activation)      (None, 17, 17, 128)  0           batch_normalization_61[0][0]
# __________________________________________________________________________________________________
# conv2d_62 (Conv2D)              (None, 17, 17, 128)  114816      activation_61[0][0]
# __________________________________________________________________________________________________
# batch_normalization_62 (BatchNo (None, 17, 17, 128)  512         conv2d_62[0][0]
# __________________________________________________________________________________________________
# activation_62 (Activation)      (None, 17, 17, 128)  0           batch_normalization_62[0][0]
# __________________________________________________________________________________________________
# conv2d_60 (Conv2D)              (None, 17, 17, 128)  114816      Inception-ResNet-B-3[0][0]
# __________________________________________________________________________________________________
# conv2d_63 (Conv2D)              (None, 17, 17, 128)  114816      activation_62[0][0]
# __________________________________________________________________________________________________
# batch_normalization_60 (BatchNo (None, 17, 17, 128)  512         conv2d_60[0][0]
# __________________________________________________________________________________________________
# batch_normalization_63 (BatchNo (None, 17, 17, 128)  512         conv2d_63[0][0]
# __________________________________________________________________________________________________
# activation_60 (Activation)      (None, 17, 17, 128)  0           batch_normalization_60[0][0]
# __________________________________________________________________________________________________
# activation_63 (Activation)      (None, 17, 17, 128)  0           batch_normalization_63[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 17, 17, 256)  0           activation_60[0][0]
#                                                                  activation_63[0][0]
# __________________________________________________________________________________________________
# conv2d_64 (Conv2D)              (None, 17, 17, 896)  230272      concatenate_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_64 (BatchNo (None, 17, 17, 896)  3584        conv2d_64[0][0]
# __________________________________________________________________________________________________
# lambda_8 (Lambda)               (None, 17, 17, 896)  0           batch_normalization_64[0][0]
# __________________________________________________________________________________________________
# activation_64 (Activation)      (None, 17, 17, 896)  0           lambda_8[0][0]
# __________________________________________________________________________________________________
# Inception-ResNet-B-4 (Add)      (None, 17, 17, 896)  0           Inception-ResNet-B-3[0][0]
#                                                                  activation_64[0][0]
# __________________________________________________________________________________________________
# conv2d_66 (Conv2D)              (None, 17, 17, 128)  114816      Inception-ResNet-B-4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_66 (BatchNo (None, 17, 17, 128)  512         conv2d_66[0][0]
# __________________________________________________________________________________________________
# ...
# __________________________________________________________________________________________________
# conv2d_108 (Conv2D)             (None, 8, 8, 192)    344256      Inception-ResNet-C-1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_108 (BatchN (None, 8, 8, 192)    768         conv2d_108[0][0]
# __________________________________________________________________________________________________
# activation_108 (Activation)     (None, 8, 8, 192)    0           batch_normalization_108[0][0]
# __________________________________________________________________________________________________
# conv2d_109 (Conv2D)             (None, 8, 8, 192)    110784      activation_108[0][0]
# __________________________________________________________________________________________________
# batch_normalization_109 (BatchN (None, 8, 8, 192)    768         conv2d_109[0][0]
# __________________________________________________________________________________________________
# activation_109 (Activation)     (None, 8, 8, 192)    0           batch_normalization_109[0][0]
# __________________________________________________________________________________________________
# conv2d_107 (Conv2D)             (None, 8, 8, 192)    344256      Inception-ResNet-C-1[0][0]
# __________________________________________________________________________________________________
# conv2d_110 (Conv2D)             (None, 8, 8, 192)    110784      activation_109[0][0]
# __________________________________________________________________________________________________
# batch_normalization_107 (BatchN (None, 8, 8, 192)    768         conv2d_107[0][0]
# __________________________________________________________________________________________________
# batch_normalization_110 (BatchN (None, 8, 8, 192)    768         conv2d_110[0][0]
# __________________________________________________________________________________________________
# activation_107 (Activation)     (None, 8, 8, 192)    0           batch_normalization_107[0][0]
# __________________________________________________________________________________________________
# activation_110 (Activation)     (None, 8, 8, 192)    0           batch_normalization_110[0][0]
# __________________________________________________________________________________________________
# concatenate_16 (Concatenate)    (None, 8, 8, 384)    0           activation_107[0][0]
#                                                                  activation_110[0][0]
# __________________________________________________________________________________________________
# conv2d_111 (Conv2D)             (None, 8, 8, 1792)   689920      concatenate_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_111 (BatchN (None, 8, 8, 1792)   7168        conv2d_111[0][0]
# __________________________________________________________________________________________________
# lambda_16 (Lambda)              (None, 8, 8, 1792)   0           batch_normalization_111[0][0]
# __________________________________________________________________________________________________
# activation_111 (Activation)     (None, 8, 8, 1792)   0           lambda_16[0][0]
# __________________________________________________________________________________________________
# Inception-ResNet-C-2 (Add)      (None, 8, 8, 1792)   0           Inception-ResNet-C-1[0][0]
#                                                                  activation_111[0][0]
# __________________________________________________________________________________________________
# conv2d_113 (Conv2D)             (None, 8, 8, 192)    344256      Inception-ResNet-C-2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_113 (BatchN (None, 8, 8, 192)    768         conv2d_113[0][0]
# __________________________________________________________________________________________________
# activation_113 (Activation)     (None, 8, 8, 192)    0           batch_normalization_113[0][0]
# __________________________________________________________________________________________________
# conv2d_114 (Conv2D)             (None, 8, 8, 192)    110784      activation_113[0][0]
# __________________________________________________________________________________________________
# batch_normalization_114 (BatchN (None, 8, 8, 192)    768         conv2d_114[0][0]
# __________________________________________________________________________________________________
# activation_114 (Activation)     (None, 8, 8, 192)    0           batch_normalization_114[0][0]
# __________________________________________________________________________________________________
# conv2d_112 (Conv2D)             (None, 8, 8, 192)    344256      Inception-ResNet-C-2[0][0]
# __________________________________________________________________________________________________
# conv2d_115 (Conv2D)             (None, 8, 8, 192)    110784      activation_114[0][0]
# __________________________________________________________________________________________________
# batch_normalization_112 (BatchN (None, 8, 8, 192)    768         conv2d_112[0][0]
# __________________________________________________________________________________________________
# batch_normalization_115 (BatchN (None, 8, 8, 192)    768         conv2d_115[0][0]
# __________________________________________________________________________________________________
# activation_112 (Activation)     (None, 8, 8, 192)    0           batch_normalization_112[0][0]
# __________________________________________________________________________________________________
# activation_115 (Activation)     (None, 8, 8, 192)    0           batch_normalization_115[0][0]
# __________________________________________________________________________________________________
# concatenate_17 (Concatenate)    (None, 8, 8, 384)    0           activation_112[0][0]
#                                                                  activation_115[0][0]
# __________________________________________________________________________________________________
# conv2d_116 (Conv2D)             (None, 8, 8, 1792)   689920      concatenate_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_116 (BatchN (None, 8, 8, 1792)   7168        conv2d_116[0][0]
# __________________________________________________________________________________________________
# lambda_17 (Lambda)              (None, 8, 8, 1792)   0           batch_normalization_116[0][0]
# __________________________________________________________________________________________________
# activation_116 (Activation)     (None, 8, 8, 1792)   0           lambda_17[0][0]
# __________________________________________________________________________________________________
# Inception-ResNet-C-3 (Add)      (None, 8, 8, 1792)   0           Inception-ResNet-C-2[0][0]
#                                                                  activation_116[0][0]
# __________________________________________________________________________________________________
# conv2d_118 (Conv2D)             (None, 8, 8, 192)    344256      Inception-ResNet-C-3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_118 (BatchN (None, 8, 8, 192)    768         conv2d_118[0][0]
# __________________________________________________________________________________________________
# activation_118 (Activation)     (None, 8, 8, 192)    0           batch_normalization_118[0][0]
# __________________________________________________________________________________________________
# conv2d_119 (Conv2D)             (None, 8, 8, 192)    110784      activation_118[0][0]
# __________________________________________________________________________________________________
# batch_normalization_119 (BatchN (None, 8, 8, 192)    768         conv2d_119[0][0]
# __________________________________________________________________________________________________
# activation_119 (Activation)     (None, 8, 8, 192)    0           batch_normalization_119[0][0]
# __________________________________________________________________________________________________
# conv2d_117 (Conv2D)             (None, 8, 8, 192)    344256      Inception-ResNet-C-3[0][0]
# __________________________________________________________________________________________________
# conv2d_120 (Conv2D)             (None, 8, 8, 192)    110784      activation_119[0][0]
# __________________________________________________________________________________________________
# batch_normalization_117 (BatchN (None, 8, 8, 192)    768         conv2d_117[0][0]
# __________________________________________________________________________________________________
# batch_normalization_120 (BatchN (None, 8, 8, 192)    768         conv2d_120[0][0]
# __________________________________________________________________________________________________
# activation_117 (Activation)     (None, 8, 8, 192)    0           batch_normalization_117[0][0]
# __________________________________________________________________________________________________
# activation_120 (Activation)     (None, 8, 8, 192)    0           batch_normalization_120[0][0]
# __________________________________________________________________________________________________
# concatenate_18 (Concatenate)    (None, 8, 8, 384)    0           activation_117[0][0]
#                                                                  activation_120[0][0]
# __________________________________________________________________________________________________
# conv2d_121 (Conv2D)             (None, 8, 8, 1792)   689920      concatenate_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_121 (BatchN (None, 8, 8, 1792)   7168        conv2d_121[0][0]
# __________________________________________________________________________________________________
# lambda_18 (Lambda)              (None, 8, 8, 1792)   0           batch_normalization_121[0][0]
# __________________________________________________________________________________________________
# activation_121 (Activation)     (None, 8, 8, 1792)   0           lambda_18[0][0]
# __________________________________________________________________________________________________
# Inception-ResNet-C-4 (Add)      (None, 8, 8, 1792)   0           Inception-ResNet-C-3[0][0]
#                                                                  activation_121[0][0]
# __________________________________________________________________________________________________
# conv2d_123 (Conv2D)             (None, 8, 8, 192)    344256      Inception-ResNet-C-4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_123 (BatchN (None, 8, 8, 192)    768         conv2d_123[0][0]
# __________________________________________________________________________________________________
# activation_123 (Activation)     (None, 8, 8, 192)    0           batch_normalization_123[0][0]
# __________________________________________________________________________________________________
# conv2d_124 (Conv2D)             (None, 8, 8, 192)    110784      activation_123[0][0]
# __________________________________________________________________________________________________
# batch_normalization_124 (BatchN (None, 8, 8, 192)    768         conv2d_124[0][0]
# __________________________________________________________________________________________________
# activation_124 (Activation)     (None, 8, 8, 192)    0           batch_normalization_124[0][0]
# __________________________________________________________________________________________________
# conv2d_122 (Conv2D)             (None, 8, 8, 192)    344256      Inception-ResNet-C-4[0][0]
# __________________________________________________________________________________________________
# conv2d_125 (Conv2D)             (None, 8, 8, 192)    110784      activation_124[0][0]
# __________________________________________________________________________________________________
# batch_normalization_122 (BatchN (None, 8, 8, 192)    768         conv2d_122[0][0]
# __________________________________________________________________________________________________
# batch_normalization_125 (BatchN (None, 8, 8, 192)    768         conv2d_125[0][0]
# __________________________________________________________________________________________________
# activation_122 (Activation)     (None, 8, 8, 192)    0           batch_normalization_122[0][0]
# __________________________________________________________________________________________________
# activation_125 (Activation)     (None, 8, 8, 192)    0           batch_normalization_125[0][0]
# __________________________________________________________________________________________________
# concatenate_19 (Concatenate)    (None, 8, 8, 384)    0           activation_122[0][0]
#                                                                  activation_125[0][0]
# __________________________________________________________________________________________________
# conv2d_126 (Conv2D)             (None, 8, 8, 1792)   689920      concatenate_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_126 (BatchN (None, 8, 8, 1792)   7168        conv2d_126[0][0]
# __________________________________________________________________________________________________
# lambda_19 (Lambda)              (None, 8, 8, 1792)   0           batch_normalization_126[0][0]
# __________________________________________________________________________________________________
# activation_126 (Activation)     (None, 8, 8, 1792)   0           lambda_19[0][0]
# __________________________________________________________________________________________________
# Inception-ResNet-C-5 (Add)      (None, 8, 8, 1792)   0           Inception-ResNet-C-4[0][0]
#                                                                  activation_126[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 1792)         0           Inception-ResNet-C-5[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 1792)         0           global_average_pooling2d[0][0]
# __________________________________________________________________________________________________
# output (Dense)                  (None, 257)          460801      dropout[0][0]
# ==================================================================================================
# Total params: 21,541,489
# Trainable params: 21,476,049
# Non-trainable params: 65,440
# __________________________________________________________________________________________________

# %%
# 폴더 생성

os.makedirs(os.path.join(dir,'model_output',number,model.name), exist_ok=True)
os.makedirs(os.path.join(dir,'train_valid_output',number), exist_ok=True)

# %%
# 참고 : https://github.com/OverLordGoldDragon/keras-adamw

import sys
sys.path.append('/content/drive/My Drive/Colab Notebooks/Paper')
import utils
import optimizers_v2
from utils import get_weight_decays, fill_dict_in_order
from utils import reset_seeds, K_eval
from optimizers_v2 import AdamW, NadamW, SGDW

# %%
optimizer = AdamW(model=model, use_cosine_annealing=True, total_iterations = len(x_train) // batch_sizes , eta_min = 1e-2)
#optimizer = Adam()
filepath =  os.path.join(dir,'model_output',number,model.name,'{epoch:03d}.h5')

callbacks_list = [ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_weights_only=False, save_best_only=True, mode='min'),
                  ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_weights_only=False, save_best_only=True, mode='max'),
                  #ReduceLROnPlateau(monitor='val_loss',patience=3,factor=0.1,min_lr=1e-5),
                  LearningRateScheduler(lr_schedule,verbose=1)
                  ]
                  
model.compile(optimizer, loss = 'categorical_crossentropy', metrics=['accuracy',macro_f1score,weighted_f1score])
# Out:
# Using cosine annealing learning rates

# %%
######## flow_from_directory
history = model.fit(train_generator, steps_per_epoch=int(len(x_train)/batch_sizes),  validation_data = valid_generator, epochs=epochs , verbose=1 , callbacks = callbacks_list , validation_steps=int(len(x_valid)/batch_sizes))
# Out:
# Learning rate:  0.001
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 1/70
# 0.0(L1), 5.116445343984611e-05(L2) weight decay set for conv2d/kernel:0
# 0.0(L1), 5.116445343984611e-05(L2) weight decay set for conv2d_1/kernel:0
# 0.0(L1), 5.116445343984611e-05(L2) weight decay set for conv2d_2/kernel:0
# 0.0(L1), 5.116445343984611e-05(L2) weight decay set for conv2d_3/kernel:0
# 0.0(L1), 5.116445343984611e-05(L2) weight decay set for conv2d_4/kernel:0
# 0.0(L1), 5.116445343984611e-05(L2) weight decay set for conv2d_5/kernel:0
# 0.0(L1), 5.116445343984611e-05(L2) weight decay set for conv2d_9/kernel:0
# 0.0(L1), 5.116445343984611e-05(L2) weight decay set for conv2d_7/kernel:0
# 0.0(L1), 5.116445343984611e-05(L2) weight decay set for conv2d_10/kernel:0
# 0.0(L1), 5.116445343984611e-05(L2) weight decay set for conv2d_6/kernel:0
# 0.0(L1), 5.116445343984611e-05(L2) weight decay set for conv2d_8/kernel:0
# 0.0(L1), 5.116445343984611e-05(L2) weight decay set for conv2d_11/kernel:0
# 0.0(L1), 5.116445343984611e-05(L2) weight decay set for conv2d_12/kernel:0
# 0.0(L1), 5.116445343984611e-05(L2) weight decay set for conv2d_16/kernel:0
# 0.0(L1), 5.116445343984611e-05(L2) weight decay set for conv2d_14/kernel:0
# 0.0(L1), 5.116445343984611e-05(L2) weight decay set for conv2d_17/kernel:0
# 0.0(L1), 5.116445343984611e-05(L2) weight decay set for conv2d_13/kernel:0
# 0.0(L1), 5.116445343984611e-05(L2) weight decay set for conv2d_15/kernel:0
# 0.0(L1), 5.116445343984611e-05(L2) weight decay set for conv2d_18/kernel:0
# 0.0(L1), 5.116445343984611e-05(L2) weight decay set for conv2d_19/kernel:0
# 0.0(L1), 5.116445343984611e-05(L2) weight decay set for conv2d_23/kernel:0
# 0.0(L1), 5.116445343984611e-05(L2) weight decay set for conv2d_21/kernel:0
# 0.0(L1), 5.116445343984611e-05(L2) weight decay set for conv2d_24/kernel:0
# 0.0(L1), 5.116445343984611e-05(L2) weight decay set for conv2d_20/kernel:0
# 0.0(L1), 5.116445343984611e-05(L2) weight decay set for conv2d_22/kernel:0
# 0.0(L1), 5.116445343984611e-05(L2) weight decay set for conv2d_25/kernel:0
# 0.0(L1), 5.116445343984611e-05(L2) weight decay set for conv2d_26/kernel:0
# 0.0(L1), 5.116445343984611e-05(L2) weight decay set for conv2d_30/kernel:0
# 0.0(L1), 5.116445343984611e-05(L2) weight decay set for conv2d_28/kernel:0
# 0.0(L1), 5.116445343984611e-05(L2) weight decay set for conv2d_31/kernel:0
# 0.0(L1), 5.116445343984611e-05(L2) weight decay set for conv2d_27/kernel:0
# 0.0(L1), 5.116445343984611e-05(L2) weight decay set for conv2d_29/kernel:0
# 0.0(L1), 5.116445343984611e-05(L2) weight decay set for conv2d_32/kernel:0
# 0.0(L1), 5.116445343984611e-05(L2) weight decay set for conv2d_33/kernel:0
# 0.0(L1), 5.116445343984611e-05(L2) weight decay set for conv2d_37/kernel:0
# 0.0(L1), 5.116445343984611e-05(L2) weight decay set for conv2d_35/kernel:0
# 0.0(L1), 5.116445343984611e-05(L2) weight decay set for conv2d_38/kernel:0
# 0.0(L1), 5.116445343984611e-05(L2) weight decay set for conv2d_34/kernel:0
# 0.0(L1), 5.116445343984611e-05(L2) weight decay set for conv2d_36/kernel:0
# 0.0(L1), 5.116445343984611e-05(L2) weight decay set for conv2d_39/kernel:0
# 0.0(L1), 5.116445343984611e-05(L2) weight decay set for conv2d_40/kernel:0
# 0.0(L1), 5.116445343984611e-05(L2) weight decay set for conv2d_42/kernel:0
# 0.0(L1), 5.116445343984611e-05(L2) weight decay set for conv2d_43/kernel:0
# 0.0(L1), 5.116445343984611e-05(L2) weight decay set for conv2d_41/kernel:0
# 0.0(L1), 5.116445343984611e-05(L2) weight decay set for conv2d_44/kernel:0
# 0.0(L1), 5.116445343984611e-05(L2) weight decay set for conv2d_46/kernel:0
# 0.0(L1), 5.116445343984611e-05(L2) weight decay set for conv2d_47/kernel:0
# 0.0(L1), 5.116445343984611e-05(L2) weight decay set for conv2d_45/kernel:0
# 0.0(L1), 5.116445343984611e-05(L2) weight decay set for conv2d_48/kernel:0
# 0.0(L1), 5.116445343984611e-05(L2) weight decay set for conv2d_49/kernel:0
# 0.0(L1), 5.116445343984611e-05(L2) weight decay set for conv2d_51/kernel:0
# 0.0(L1), 5.116445343984611e-05(L2) weight decay set for conv2d_52/kernel:0
# 0.0(L1), 5.116445343984611e-05(L2) weight decay set for conv2d_50/kernel:0
# 0.0(L1), 5.116445343984611e-05(L2) weight decay set for conv2d_53/kernel:0
# 0.0(L1), 5.116445343984611e-05(L2) weight decay set for conv2d_54/kernel:0
# 0.0(L1), 5.116445343984611e-05(L2) weight decay set for conv2d_56/kernel:0
# 0.0(L1), 5.116445343984611e-05(L2) weight decay set for conv2d_57/kernel:0
# 0.0(L1), 5.116445343984611e-05(L2) weight decay set for conv2d_55/kernel:0
# 0.0(L1), 5.116445343984611e-05(L2) weight decay set for conv2d_58/kernel:0
# 0.0(L1), 5.116445343984611e-05(L2) weight decay set for conv2d_59/kernel:0
# 0.0(L1), 5.116445343984611e-05(L2) weight decay set for conv2d_61/kernel:0
# 0.0(L1), 5.116445343984611e-05(L2) weight decay set for conv2d_62/kernel:0
# 0.0(L1), 5.116445343984611e-05(L2) weight decay set for conv2d_60/kernel:0
# 0.0(L1), 5.116445343984611e-05(L2) weight decay set for conv2d_63/kernel:0
# 0.0(L1), 5.116445343984611e-05(L2) weight decay set for conv2d_64/kernel:0
# 0.0(L1), 5.116445343984611e-05(L2) weight decay set for conv2d_66/kernel:0
# 0.0(L1), 5.116445343984611e-05(L2) weight decay set for conv2d_67/kernel:0
# 0.0(L1), 5.116445343984611e-05(L2) weight decay set for conv2d_65/kernel:0
# 0.0(L1), 5.116445343984611e-05(L2) weight decay set for conv2d_68/kernel:0
# 0.0(L1), 5.116445343984611e-05(L2) weight decay set for conv2d_69/kernel:0
# 0.0(L1), 5.116445343984611e-05(L2) weight decay set for conv2d_71/kernel:0
# 0.0(L1), 5.116445343984611e-05(L2) weight decay set for conv2d_72/kernel:0
# 0.0(L1), 5.116445343984611e-05(L2) weight decay set for conv2d_70/kernel:0
# 0.0(L1), 5.116445343984611e-05(L2) weight decay set for conv2d_73/kernel:0
# 0.0(L1), 5.116445343984611e-05(L2) weight decay set for conv2d_74/kernel:0
# 0.0(L1), 5.116445343984611e-05(L2) weight decay set for conv2d_76/kernel:0
# 0.0(L1), 5.116445343984611e-05(L2) weight decay set for conv2d_77/kernel:0
# 0.0(L1), 5.116445343984611e-05(L2) weight decay set for conv2d_75/kernel:0
# 0.0(L1), 5.116445343984611e-05(L2) weight decay set for conv2d_78/kernel:0
# 0.0(L1), 5.116445343984611e-05(L2) weight decay set for conv2d_79/kernel:0
# 0.0(L1), 5.116445343984611e-05(L2) weight decay set for conv2d_81/kernel:0
# 0.0(L1), 5.116445343984611e-05(L2) weight decay set for conv2d_82/kernel:0
# 0.0(L1), 5.116445343984611e-05(L2) weight decay set for conv2d_80/kernel:0
# 0.0(L1), 5.116445343984611e-05(L2) weight decay set for conv2d_83/kernel:0
# 0.0(L1), 5.116445343984611e-05(L2) weight decay set for conv2d_84/kernel:0
# 0.0(L1), 5.116445343984611e-05(L2) weight decay set for conv2d_86/kernel:0
# 0.0(L1), 5.116445343984611e-05(L2) weight decay set for conv2d_87/kernel:0
# 0.0(L1), 5.116445343984611e-05(L2) weight decay set for conv2d_85/kernel:0
# 0.0(L1), 5.116445343984611e-05(L2) weight decay set for conv2d_88/kernel:0
# 0.0(L1), 5.116445343984611e-05(L2) weight decay set for conv2d_89/kernel:0
# 0.0(L1), 5.116445343984611e-05(L2) weight decay set for conv2d_91/kernel:0
# 0.0(L1), 5.116445343984611e-05(L2) weight decay set for conv2d_92/kernel:0
# 0.0(L1), 5.116445343984611e-05(L2) weight decay set for conv2d_90/kernel:0
# 0.0(L1), 5.116445343984611e-05(L2) weight decay set for conv2d_93/kernel:0
# 0.0(L1), 5.116445343984611e-05(L2) weight decay set for conv2d_94/kernel:0
# 0.0(L1), 5.116445343984611e-05(L2) weight decay set for conv2d_99/kernel:0
# 0.0(L1), 5.116445343984611e-05(L2) weight decay set for conv2d_95/kernel:0
# 0.0(L1), 5.116445343984611e-05(L2) weight decay set for conv2d_97/kernel:0
# 0.0(L1), 5.116445343984611e-05(L2) weight decay set for conv2d_100/kernel:0
# 0.0(L1), 5.116445343984611e-05(L2) weight decay set for conv2d_96/kernel:0
# 0.0(L1), 5.116445343984611e-05(L2) weight decay set for conv2d_98/kernel:0
# 0.0(L1), 5.116445343984611e-05(L2) weight decay set for conv2d_101/kernel:0
# 0.0(L1), 5.116445343984611e-05(L2) weight decay set for conv2d_103/kernel:0
# 0.0(L1), 5.116445343984611e-05(L2) weight decay set for conv2d_104/kernel:0
# 0.0(L1), 5.116445343984611e-05(L2) weight decay set for conv2d_102/kernel:0
# 0.0(L1), 5.116445343984611e-05(L2) weight decay set for conv2d_105/kernel:0
# 0.0(L1), 5.116445343984611e-05(L2) weight decay set for conv2d_106/kernel:0
# 0.0(L1), 5.116445343984611e-05(L2) weight decay set for conv2d_108/kernel:0
# 0.0(L1), 5.116445343984611e-05(L2) weight decay set for conv2d_109/kernel:0
# 0.0(L1), 5.116445343984611e-05(L2) weight decay set for conv2d_107/kernel:0
# 0.0(L1), 5.116445343984611e-05(L2) weight decay set for conv2d_110/kernel:0
# 0.0(L1), 5.116445343984611e-05(L2) weight decay set for conv2d_111/kernel:0
# 0.0(L1), 5.116445343984611e-05(L2) weight decay set for conv2d_113/kernel:0
# 0.0(L1), 5.116445343984611e-05(L2) weight decay set for conv2d_114/kernel:0
# 0.0(L1), 5.116445343984611e-05(L2) weight decay set for conv2d_112/kernel:0
# 0.0(L1), 5.116445343984611e-05(L2) weight decay set for conv2d_115/kernel:0
# 0.0(L1), 5.116445343984611e-05(L2) weight decay set for conv2d_116/kernel:0
# 0.0(L1), 5.116445343984611e-05(L2) weight decay set for conv2d_118/kernel:0
# 0.0(L1), 5.116445343984611e-05(L2) weight decay set for conv2d_119/kernel:0
# 0.0(L1), 5.116445343984611e-05(L2) weight decay set for conv2d_117/kernel:0
# 0.0(L1), 5.116445343984611e-05(L2) weight decay set for conv2d_120/kernel:0
# 0.0(L1), 5.116445343984611e-05(L2) weight decay set for conv2d_121/kernel:0
# 0.0(L1), 5.116445343984611e-05(L2) weight decay set for conv2d_123/kernel:0
# 0.0(L1), 5.116445343984611e-05(L2) weight decay set for conv2d_124/kernel:0
# 0.0(L1), 5.116445343984611e-05(L2) weight decay set for conv2d_122/kernel:0
# 0.0(L1), 5.116445343984611e-05(L2) weight decay set for conv2d_125/kernel:0
# 0.0(L1), 5.116445343984611e-05(L2) weight decay set for conv2d_126/kernel:0
# 382/382 [==============================] - ETA: 0s - loss: 5.4522 - accuracy: 0.0768 - macro_f1score: 9.2625e-04 - weighted_f1score: 2.2945e-05
# Epoch 00001: val_loss improved from inf to 4.76718, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_ResNet_v1/001.h5
#
# Epoch 00001: val_accuracy improved from -inf to 0.10632, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_ResNet_v1/001.h5
# 382/382 [==============================] - 6810s 18s/step - loss: 5.4522 - accuracy: 0.0768 - macro_f1score: 9.2625e-04 - weighted_f1score: 2.2945e-05 - val_loss: 4.7672 - val_accuracy: 0.1063 - val_macro_f1score: 6.7952e-04 - val_weighted_f1score: 2.0706e-05
# Learning rate:  0.001
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 2/70
# 382/382 [==============================] - ETA: 0s - loss: 4.8940 - accuracy: 0.1061 - macro_f1score: 0.0026 - weighted_f1score: 7.6347e-05
# Epoch 00002: val_loss improved from 4.76718 to 4.47031, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_ResNet_v1/002.h5
#
# Epoch 00002: val_accuracy improved from 0.10632 to 0.13927, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_ResNet_v1/002.h5
# 382/382 [==============================] - 713s 2s/step - loss: 4.8940 - accuracy: 0.1061 - macro_f1score: 0.0026 - weighted_f1score: 7.6347e-05 - val_loss: 4.4703 - val_accuracy: 0.1393 - val_macro_f1score: 0.0025 - val_weighted_f1score: 6.6239e-05
# Learning rate:  0.001
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 3/70
# 382/382 [==============================] - ETA: 0s - loss: 4.6201 - accuracy: 0.1308 - macro_f1score: 0.0052 - weighted_f1score: 1.4655e-04
# Epoch 00003: val_loss improved from 4.47031 to 4.26425, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_ResNet_v1/003.h5
#
# Epoch 00003: val_accuracy improved from 0.13927 to 0.16644, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_ResNet_v1/003.h5
# 382/382 [==============================] - 705s 2s/step - loss: 4.6201 - accuracy: 0.1308 - macro_f1score: 0.0052 - weighted_f1score: 1.4655e-04 - val_loss: 4.2643 - val_accuracy: 0.1664 - val_macro_f1score: 0.0063 - val_weighted_f1score: 1.8659e-04
# Learning rate:  0.001
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 4/70
# 382/382 [==============================] - ETA: 0s - loss: 4.3834 - accuracy: 0.1545 - macro_f1score: 0.0076 - weighted_f1score: 2.1401e-04
# Epoch 00004: val_loss improved from 4.26425 to 4.12730, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_ResNet_v1/004.h5
#
# Epoch 00004: val_accuracy improved from 0.16644 to 0.18988, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_ResNet_v1/004.h5
# 382/382 [==============================] - 694s 2s/step - loss: 4.3834 - accuracy: 0.1545 - macro_f1score: 0.0076 - weighted_f1score: 2.1401e-04 - val_loss: 4.1273 - val_accuracy: 0.1899 - val_macro_f1score: 0.0087 - val_weighted_f1score: 2.4534e-04
# Learning rate:  0.001
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 5/70
# 382/382 [==============================] - ETA: 0s - loss: 4.1834 - accuracy: 0.1795 - macro_f1score: 0.0097 - weighted_f1score: 2.6430e-04
# Epoch 00005: val_loss improved from 4.12730 to 4.08029, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_ResNet_v1/005.h5
#
# Epoch 00005: val_accuracy improved from 0.18988 to 0.21535, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_ResNet_v1/005.h5
# 382/382 [==============================] - 690s 2s/step - loss: 4.1834 - accuracy: 0.1795 - macro_f1score: 0.0097 - weighted_f1score: 2.6430e-04 - val_loss: 4.0803 - val_accuracy: 0.2154 - val_macro_f1score: 0.0118 - val_weighted_f1score: 3.0508e-04
# Learning rate:  0.001
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 6/70
# 382/382 [==============================] - ETA: 0s - loss: 4.0973 - accuracy: 0.1882 - macro_f1score: 0.0106 - weighted_f1score: 2.8129e-04
# Epoch 00006: val_loss improved from 4.08029 to 3.85010, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_ResNet_v1/006.h5
#
# Epoch 00006: val_accuracy improved from 0.21535 to 0.23234, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_ResNet_v1/006.h5
# 382/382 [==============================] - 692s 2s/step - loss: 4.0973 - accuracy: 0.1882 - macro_f1score: 0.0106 - weighted_f1score: 2.8129e-04 - val_loss: 3.8501 - val_accuracy: 0.2323 - val_macro_f1score: 0.0126 - val_weighted_f1score: 3.2905e-04
# Learning rate:  0.001
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 7/70
# 382/382 [==============================] - ETA: 0s - loss: 3.9380 - accuracy: 0.2059 - macro_f1score: 0.0130 - weighted_f1score: 3.3375e-04
# Epoch 00007: val_loss improved from 3.85010 to 3.63571, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_ResNet_v1/007.h5
#
# Epoch 00007: val_accuracy improved from 0.23234 to 0.25034, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_ResNet_v1/007.h5
# 382/382 [==============================] - 694s 2s/step - loss: 3.9380 - accuracy: 0.2059 - macro_f1score: 0.0130 - weighted_f1score: 3.3375e-04 - val_loss: 3.6357 - val_accuracy: 0.2503 - val_macro_f1score: 0.0157 - val_weighted_f1score: 3.8147e-04
# Learning rate:  0.001
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 8/70
# 382/382 [==============================] - ETA: 0s - loss: 3.7168 - accuracy: 0.2331 - macro_f1score: 0.0158 - weighted_f1score: 3.9307e-04
# Epoch 00008: val_loss improved from 3.63571 to 3.52728, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_ResNet_v1/008.h5
#
# Epoch 00008: val_accuracy improved from 0.25034 to 0.28397, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_ResNet_v1/008.h5
# 382/382 [==============================] - 690s 2s/step - loss: 3.7168 - accuracy: 0.2331 - macro_f1score: 0.0158 - weighted_f1score: 3.9307e-04 - val_loss: 3.5273 - val_accuracy: 0.2840 - val_macro_f1score: 0.0188 - val_weighted_f1score: 4.5235e-04
# Learning rate:  0.001
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 9/70
# 382/382 [==============================] - ETA: 0s - loss: 3.5023 - accuracy: 0.2605 - macro_f1score: 0.0198 - weighted_f1score: 4.6856e-04
# Epoch 00009: val_loss did not improve from 3.52728
#
# Epoch 00009: val_accuracy improved from 0.28397 to 0.31046, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_ResNet_v1/009.h5
# 382/382 [==============================] - 683s 2s/step - loss: 3.5023 - accuracy: 0.2605 - macro_f1score: 0.0198 - weighted_f1score: 4.6856e-04 - val_loss: 3.6758 - val_accuracy: 0.3105 - val_macro_f1score: 0.0246 - val_weighted_f1score: 5.3655e-04
# Learning rate:  0.001
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 10/70
# 382/382 [==============================] - ETA: 0s - loss: 3.3425 - accuracy: 0.2858 - macro_f1score: 0.0221 - weighted_f1score: 5.1636e-04
# Epoch 00010: val_loss improved from 3.52728 to 3.25825, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_ResNet_v1/010.h5
#
# Epoch 00010: val_accuracy improved from 0.31046 to 0.33016, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_ResNet_v1/010.h5
# 382/382 [==============================] - 682s 2s/step - loss: 3.3425 - accuracy: 0.2858 - macro_f1score: 0.0221 - weighted_f1score: 5.1636e-04 - val_loss: 3.2582 - val_accuracy: 0.3302 - val_macro_f1score: 0.0272 - val_weighted_f1score: 6.1939e-04
# Learning rate:  0.001
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 11/70
# 382/382 [==============================] - ETA: 0s - loss: 3.2197 - accuracy: 0.3049 - macro_f1score: 0.0253 - weighted_f1score: 5.7598e-04
# Epoch 00011: val_loss improved from 3.25825 to 3.24642, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_ResNet_v1/011.h5
#
# Epoch 00011: val_accuracy improved from 0.33016 to 0.34511, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_ResNet_v1/011.h5
# 382/382 [==============================] - 682s 2s/step - loss: 3.2197 - accuracy: 0.3049 - macro_f1score: 0.0253 - weighted_f1score: 5.7598e-04 - val_loss: 3.2464 - val_accuracy: 0.3451 - val_macro_f1score: 0.0313 - val_weighted_f1score: 6.8837e-04
# Learning rate:  0.001
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 12/70
# 382/382 [==============================] - ETA: 0s - loss: 3.0518 - accuracy: 0.3281 - macro_f1score: 0.0290 - weighted_f1score: 6.4794e-04
# Epoch 00012: val_loss improved from 3.24642 to 3.01584, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_ResNet_v1/012.h5
#
# Epoch 00012: val_accuracy improved from 0.34511 to 0.36855, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_ResNet_v1/012.h5
# 382/382 [==============================] - 677s 2s/step - loss: 3.0518 - accuracy: 0.3281 - macro_f1score: 0.0290 - weighted_f1score: 6.4794e-04 - val_loss: 3.0158 - val_accuracy: 0.3685 - val_macro_f1score: 0.0344 - val_weighted_f1score: 7.6176e-04
# Learning rate:  0.001
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 13/70
# 382/382 [==============================] - ETA: 0s - loss: 2.8970 - accuracy: 0.3564 - macro_f1score: 0.0344 - weighted_f1score: 7.4548e-04
# Epoch 00013: val_loss improved from 3.01584 to 2.93962, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_ResNet_v1/013.h5
#
# Epoch 00013: val_accuracy improved from 0.36855 to 0.38961, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_ResNet_v1/013.h5
# 382/382 [==============================] - 681s 2s/step - loss: 2.8970 - accuracy: 0.3564 - macro_f1score: 0.0344 - weighted_f1score: 7.4548e-04 - val_loss: 2.9396 - val_accuracy: 0.3896 - val_macro_f1score: 0.0381 - val_weighted_f1score: 8.1797e-04
# Learning rate:  0.001
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 14/70
# 382/382 [==============================] - ETA: 0s - loss: 2.7851 - accuracy: 0.3710 - macro_f1score: 0.0377 - weighted_f1score: 8.0575e-04
# Epoch 00014: val_loss did not improve from 2.93962
#
# Epoch 00014: val_accuracy improved from 0.38961 to 0.39878, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_ResNet_v1/014.h5
# 382/382 [==============================] - 682s 2s/step - loss: 2.7851 - accuracy: 0.3710 - macro_f1score: 0.0377 - weighted_f1score: 8.0575e-04 - val_loss: 3.0601 - val_accuracy: 0.3988 - val_macro_f1score: 0.0435 - val_weighted_f1score: 9.0352e-04
# Learning rate:  0.001
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 15/70
# 382/382 [==============================] - ETA: 0s - loss: 2.6500 - accuracy: 0.3964 - macro_f1score: 0.0429 - weighted_f1score: 8.8993e-04
# Epoch 00015: val_loss improved from 2.93962 to 2.69000, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_ResNet_v1/015.h5
#
# Epoch 00015: val_accuracy improved from 0.39878 to 0.41372, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_ResNet_v1/015.h5
# 382/382 [==============================] - 683s 2s/step - loss: 2.6500 - accuracy: 0.3964 - macro_f1score: 0.0429 - weighted_f1score: 8.8993e-04 - val_loss: 2.6900 - val_accuracy: 0.4137 - val_macro_f1score: 0.0493 - val_weighted_f1score: 0.0010
# Learning rate:  0.001
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 16/70
# 382/382 [==============================] - ETA: 0s - loss: 2.5401 - accuracy: 0.4141 - macro_f1score: 0.0473 - weighted_f1score: 9.7592e-04
# Epoch 00016: val_loss improved from 2.69000 to 2.68938, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_ResNet_v1/016.h5
#
# Epoch 00016: val_accuracy improved from 0.41372 to 0.43274, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_ResNet_v1/016.h5
# 382/382 [==============================] - 686s 2s/step - loss: 2.5401 - accuracy: 0.4141 - macro_f1score: 0.0473 - weighted_f1score: 9.7592e-04 - val_loss: 2.6894 - val_accuracy: 0.4327 - val_macro_f1score: 0.0518 - val_weighted_f1score: 0.0011
# Learning rate:  0.001
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 17/70
# 382/382 [==============================] - ETA: 0s - loss: 2.4178 - accuracy: 0.4406 - macro_f1score: 0.0518 - weighted_f1score: 0.0011
# Epoch 00017: val_loss improved from 2.68938 to 2.59664, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_ResNet_v1/017.h5
#
# Epoch 00017: val_accuracy improved from 0.43274 to 0.45007, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_ResNet_v1/017.h5
# 382/382 [==============================] - 691s 2s/step - loss: 2.4178 - accuracy: 0.4406 - macro_f1score: 0.0518 - weighted_f1score: 0.0011 - val_loss: 2.5966 - val_accuracy: 0.4501 - val_macro_f1score: 0.0566 - val_weighted_f1score: 0.0012
# Learning rate:  0.001
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 18/70
# 382/382 [==============================] - ETA: 0s - loss: 2.3434 - accuracy: 0.4534 - macro_f1score: 0.0555 - weighted_f1score: 0.0011
# Epoch 00018: val_loss did not improve from 2.59664
#
# Epoch 00018: val_accuracy improved from 0.45007 to 0.46162, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_ResNet_v1/018.h5
# 382/382 [==============================] - 684s 2s/step - loss: 2.3434 - accuracy: 0.4534 - macro_f1score: 0.0555 - weighted_f1score: 0.0011 - val_loss: 2.6055 - val_accuracy: 0.4616 - val_macro_f1score: 0.0586 - val_weighted_f1score: 0.0012
# Learning rate:  0.001
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 19/70
# 382/382 [==============================] - ETA: 0s - loss: 2.2152 - accuracy: 0.4801 - macro_f1score: 0.0608 - weighted_f1score: 0.0012
# Epoch 00019: val_loss improved from 2.59664 to 2.44323, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_ResNet_v1/019.h5
#
# Epoch 00019: val_accuracy improved from 0.46162 to 0.47792, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_ResNet_v1/019.h5
# 382/382 [==============================] - 684s 2s/step - loss: 2.2152 - accuracy: 0.4801 - macro_f1score: 0.0608 - weighted_f1score: 0.0012 - val_loss: 2.4432 - val_accuracy: 0.4779 - val_macro_f1score: 0.0633 - val_weighted_f1score: 0.0013
# Learning rate:  0.001
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 20/70
# 382/382 [==============================] - ETA: 0s - loss: 2.1122 - accuracy: 0.4987 - macro_f1score: 0.0661 - weighted_f1score: 0.0013
# Epoch 00020: val_loss did not improve from 2.44323
#
# Epoch 00020: val_accuracy improved from 0.47792 to 0.48370, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_ResNet_v1/020.h5
# 382/382 [==============================] - 680s 2s/step - loss: 2.1122 - accuracy: 0.4987 - macro_f1score: 0.0661 - weighted_f1score: 0.0013 - val_loss: 2.5167 - val_accuracy: 0.4837 - val_macro_f1score: 0.0666 - val_weighted_f1score: 0.0013
# Learning rate:  0.001
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 21/70
# 382/382 [==============================] - ETA: 0s - loss: 2.0528 - accuracy: 0.5071 - macro_f1score: 0.0691 - weighted_f1score: 0.0014
# Epoch 00021: val_loss improved from 2.44323 to 2.36647, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_ResNet_v1/021.h5
#
# Epoch 00021: val_accuracy improved from 0.48370 to 0.49389, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_ResNet_v1/021.h5
# 382/382 [==============================] - 682s 2s/step - loss: 2.0528 - accuracy: 0.5071 - macro_f1score: 0.0691 - weighted_f1score: 0.0014 - val_loss: 2.3665 - val_accuracy: 0.4939 - val_macro_f1score: 0.0688 - val_weighted_f1score: 0.0014
# Learning rate:  0.001
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 22/70
# 382/382 [==============================] - ETA: 0s - loss: 1.9548 - accuracy: 0.5330 - macro_f1score: 0.0742 - weighted_f1score: 0.0015
# Epoch 00022: val_loss improved from 2.36647 to 2.25447, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_ResNet_v1/022.h5
#
# Epoch 00022: val_accuracy improved from 0.49389 to 0.51155, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_ResNet_v1/022.h5
# 382/382 [==============================] - 682s 2s/step - loss: 1.9548 - accuracy: 0.5330 - macro_f1score: 0.0742 - weighted_f1score: 0.0015 - val_loss: 2.2545 - val_accuracy: 0.5115 - val_macro_f1score: 0.0746 - val_weighted_f1score: 0.0015
# Learning rate:  0.001
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 23/70
# 382/382 [==============================] - ETA: 0s - loss: 1.8543 - accuracy: 0.5483 - macro_f1score: 0.0795 - weighted_f1score: 0.0016
# Epoch 00023: val_loss improved from 2.25447 to 2.22563, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_ResNet_v1/023.h5
#
# Epoch 00023: val_accuracy improved from 0.51155 to 0.51427, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_ResNet_v1/023.h5
# 382/382 [==============================] - 681s 2s/step - loss: 1.8543 - accuracy: 0.5483 - macro_f1score: 0.0795 - weighted_f1score: 0.0016 - val_loss: 2.2256 - val_accuracy: 0.5143 - val_macro_f1score: 0.0773 - val_weighted_f1score: 0.0015
# Learning rate:  0.001
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 24/70
# 382/382 [==============================] - ETA: 0s - loss: 1.7962 - accuracy: 0.5601 - macro_f1score: 0.0827 - weighted_f1score: 0.0016
# Epoch 00024: val_loss improved from 2.22563 to 2.13390, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_ResNet_v1/024.h5
#
# Epoch 00024: val_accuracy improved from 0.51427 to 0.52208, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_ResNet_v1/024.h5
# 382/382 [==============================] - 683s 2s/step - loss: 1.7962 - accuracy: 0.5601 - macro_f1score: 0.0827 - weighted_f1score: 0.0016 - val_loss: 2.1339 - val_accuracy: 0.5221 - val_macro_f1score: 0.0793 - val_weighted_f1score: 0.0016
# Learning rate:  0.001
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 25/70
# 382/382 [==============================] - ETA: 0s - loss: 1.7291 - accuracy: 0.5718 - macro_f1score: 0.0859 - weighted_f1score: 0.0017
# Epoch 00025: val_loss improved from 2.13390 to 2.11963, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_ResNet_v1/025.h5
#
# Epoch 00025: val_accuracy improved from 0.52208 to 0.52582, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_ResNet_v1/025.h5
# 382/382 [==============================] - 679s 2s/step - loss: 1.7291 - accuracy: 0.5718 - macro_f1score: 0.0859 - weighted_f1score: 0.0017 - val_loss: 2.1196 - val_accuracy: 0.5258 - val_macro_f1score: 0.0805 - val_weighted_f1score: 0.0016
# Learning rate:  0.001
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 26/70
# 382/382 [==============================] - ETA: 0s - loss: 1.6293 - accuracy: 0.5951 - macro_f1score: 0.0920 - weighted_f1score: 0.0018
# Epoch 00026: val_loss did not improve from 2.11963
#
# Epoch 00026: val_accuracy improved from 0.52582 to 0.53057, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_ResNet_v1/026.h5
# 382/382 [==============================] - 677s 2s/step - loss: 1.6293 - accuracy: 0.5951 - macro_f1score: 0.0920 - weighted_f1score: 0.0018 - val_loss: 2.1676 - val_accuracy: 0.5306 - val_macro_f1score: 0.0829 - val_weighted_f1score: 0.0016
# Learning rate:  0.001
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 27/70
# 382/382 [==============================] - ETA: 0s - loss: 1.5620 - accuracy: 0.6061 - macro_f1score: 0.0959 - weighted_f1score: 0.0018
# Epoch 00027: val_loss did not improve from 2.11963
#
# Epoch 00027: val_accuracy improved from 0.53057 to 0.53601, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_ResNet_v1/027.h5
# 382/382 [==============================] - 679s 2s/step - loss: 1.5620 - accuracy: 0.6061 - macro_f1score: 0.0959 - weighted_f1score: 0.0018 - val_loss: 2.1222 - val_accuracy: 0.5360 - val_macro_f1score: 0.0858 - val_weighted_f1score: 0.0017
# Learning rate:  0.001
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 28/70
# 382/382 [==============================] - ETA: 0s - loss: 1.5198 - accuracy: 0.6179 - macro_f1score: 0.0989 - weighted_f1score: 0.0019
# Epoch 00028: val_loss improved from 2.11963 to 2.08023, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_ResNet_v1/028.h5
#
# Epoch 00028: val_accuracy improved from 0.53601 to 0.54450, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_ResNet_v1/028.h5
# 382/382 [==============================] - 687s 2s/step - loss: 1.5198 - accuracy: 0.6179 - macro_f1score: 0.0989 - weighted_f1score: 0.0019 - val_loss: 2.0802 - val_accuracy: 0.5445 - val_macro_f1score: 0.0838 - val_weighted_f1score: 0.0017
# Learning rate:  0.001
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 29/70
# 382/382 [==============================] - ETA: 0s - loss: 1.4210 - accuracy: 0.6381 - macro_f1score: 0.1048 - weighted_f1score: 0.0020
# Epoch 00029: val_loss did not improve from 2.08023
#
# Epoch 00029: val_accuracy improved from 0.54450 to 0.54586, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_ResNet_v1/029.h5
# 382/382 [==============================] - 682s 2s/step - loss: 1.4210 - accuracy: 0.6381 - macro_f1score: 0.1048 - weighted_f1score: 0.0020 - val_loss: 2.0836 - val_accuracy: 0.5459 - val_macro_f1score: 0.0884 - val_weighted_f1score: 0.0018
# Learning rate:  0.001
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 30/70
# 382/382 [==============================] - ETA: 0s - loss: 1.3578 - accuracy: 0.6505 - macro_f1score: 0.1079 - weighted_f1score: 0.0021
# Epoch 00030: val_loss did not improve from 2.08023
#
# Epoch 00030: val_accuracy improved from 0.54586 to 0.55571, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_ResNet_v1/030.h5
# 382/382 [==============================] - 675s 2s/step - loss: 1.3578 - accuracy: 0.6505 - macro_f1score: 0.1079 - weighted_f1score: 0.0021 - val_loss: 2.1493 - val_accuracy: 0.5557 - val_macro_f1score: 0.0901 - val_weighted_f1score: 0.0018
# Learning rate:  0.001
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 31/70
# 382/382 [==============================] - ETA: 0s - loss: 1.2908 - accuracy: 0.6650 - macro_f1score: 0.1119 - weighted_f1score: 0.0021
# Epoch 00031: val_loss did not improve from 2.08023
#
# Epoch 00031: val_accuracy improved from 0.55571 to 0.55978, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_ResNet_v1/031.h5
# 382/382 [==============================] - 676s 2s/step - loss: 1.2908 - accuracy: 0.6650 - macro_f1score: 0.1119 - weighted_f1score: 0.0021 - val_loss: 2.1262 - val_accuracy: 0.5598 - val_macro_f1score: 0.0942 - val_weighted_f1score: 0.0018
# Learning rate:  0.001
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 32/70
# 382/382 [==============================] - ETA: 0s - loss: 1.2406 - accuracy: 0.6762 - macro_f1score: 0.1155 - weighted_f1score: 0.0022
# Epoch 00032: val_loss did not improve from 2.08023
#
# Epoch 00032: val_accuracy improved from 0.55978 to 0.56488, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_ResNet_v1/032.h5
# 382/382 [==============================] - 679s 2s/step - loss: 1.2406 - accuracy: 0.6762 - macro_f1score: 0.1155 - weighted_f1score: 0.0022 - val_loss: 2.0890 - val_accuracy: 0.5649 - val_macro_f1score: 0.0951 - val_weighted_f1score: 0.0018
# Learning rate:  0.001
#
# Epoch 00033: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 33/70
# 382/382 [==============================] - ETA: 0s - loss: 1.1834 - accuracy: 0.6900 - macro_f1score: 0.1197 - weighted_f1score: 0.0023
# Epoch 00033: val_loss improved from 2.08023 to 2.02982, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_ResNet_v1/033.h5
#
# Epoch 00033: val_accuracy did not improve from 0.56488
# 382/382 [==============================] - 683s 2s/step - loss: 1.1834 - accuracy: 0.6900 - macro_f1score: 0.1197 - weighted_f1score: 0.0023 - val_loss: 2.0298 - val_accuracy: 0.5588 - val_macro_f1score: 0.0958 - val_weighted_f1score: 0.0019
# Learning rate:  0.001
#
# Epoch 00034: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 34/70
# 382/382 [==============================] - ETA: 0s - loss: 1.1319 - accuracy: 0.7022 - macro_f1score: 0.1227 - weighted_f1score: 0.0023
# Epoch 00034: val_loss did not improve from 2.02982
#
# Epoch 00034: val_accuracy did not improve from 0.56488
# 382/382 [==============================] - 675s 2s/step - loss: 1.1319 - accuracy: 0.7022 - macro_f1score: 0.1227 - weighted_f1score: 0.0023 - val_loss: 2.1083 - val_accuracy: 0.5632 - val_macro_f1score: 0.0945 - val_weighted_f1score: 0.0019
# Learning rate:  0.001
#
# Epoch 00035: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 35/70
# 382/382 [==============================] - ETA: 0s - loss: 1.0810 - accuracy: 0.7116 - macro_f1score: 0.1253 - weighted_f1score: 0.0024
# Epoch 00035: val_loss improved from 2.02982 to 1.99267, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_ResNet_v1/035.h5
#
# Epoch 00035: val_accuracy did not improve from 0.56488
# 382/382 [==============================] - 679s 2s/step - loss: 1.0810 - accuracy: 0.7116 - macro_f1score: 0.1253 - weighted_f1score: 0.0024 - val_loss: 1.9927 - val_accuracy: 0.5564 - val_macro_f1score: 0.0969 - val_weighted_f1score: 0.0019
# Learning rate:  0.001
#
# Epoch 00036: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 36/70
# 382/382 [==============================] - ETA: 0s - loss: 1.0762 - accuracy: 0.7128 - macro_f1score: 0.1272 - weighted_f1score: 0.0024
# Epoch 00036: val_loss did not improve from 1.99267
#
# Epoch 00036: val_accuracy improved from 0.56488 to 0.56556, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_ResNet_v1/036.h5
# 382/382 [==============================] - 679s 2s/step - loss: 1.0762 - accuracy: 0.7128 - macro_f1score: 0.1272 - weighted_f1score: 0.0024 - val_loss: 2.2200 - val_accuracy: 0.5656 - val_macro_f1score: 0.0984 - val_weighted_f1score: 0.0019
# Learning rate:  0.001
#
# Epoch 00037: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 37/70
# 382/382 [==============================] - ETA: 0s - loss: 0.9626 - accuracy: 0.7403 - macro_f1score: 0.1335 - weighted_f1score: 0.0025
# Epoch 00037: val_loss did not improve from 1.99267
#
# Epoch 00037: val_accuracy did not improve from 0.56556
# 382/382 [==============================] - 681s 2s/step - loss: 0.9626 - accuracy: 0.7403 - macro_f1score: 0.1335 - weighted_f1score: 0.0025 - val_loss: 2.0411 - val_accuracy: 0.5622 - val_macro_f1score: 0.0995 - val_weighted_f1score: 0.0019
# Learning rate:  0.001
#
# Epoch 00038: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 38/70
# 382/382 [==============================] - ETA: 0s - loss: 0.9171 - accuracy: 0.7494 - macro_f1score: 0.1362 - weighted_f1score: 0.0026
# Epoch 00038: val_loss did not improve from 1.99267
#
# Epoch 00038: val_accuracy improved from 0.56556 to 0.57575, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_ResNet_v1/038.h5
# 382/382 [==============================] - 686s 2s/step - loss: 0.9171 - accuracy: 0.7494 - macro_f1score: 0.1362 - weighted_f1score: 0.0026 - val_loss: 2.0909 - val_accuracy: 0.5757 - val_macro_f1score: 0.0990 - val_weighted_f1score: 0.0019
# Learning rate:  0.001
#
# Epoch 00039: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 39/70
# 382/382 [==============================] - ETA: 0s - loss: 0.8817 - accuracy: 0.7615 - macro_f1score: 0.1404 - weighted_f1score: 0.0026
# Epoch 00039: val_loss did not improve from 1.99267
#
# Epoch 00039: val_accuracy did not improve from 0.57575
# 382/382 [==============================] - 686s 2s/step - loss: 0.8817 - accuracy: 0.7615 - macro_f1score: 0.1404 - weighted_f1score: 0.0026 - val_loss: 2.2062 - val_accuracy: 0.5730 - val_macro_f1score: 0.1005 - val_weighted_f1score: 0.0020
# Learning rate:  0.001
#
# Epoch 00040: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 40/70
# 382/382 [==============================] - ETA: 0s - loss: 0.8607 - accuracy: 0.7649 - macro_f1score: 0.1409 - weighted_f1score: 0.0027
# Epoch 00040: val_loss did not improve from 1.99267
#
# Epoch 00040: val_accuracy did not improve from 0.57575
# 382/382 [==============================] - 678s 2s/step - loss: 0.8607 - accuracy: 0.7649 - macro_f1score: 0.1409 - weighted_f1score: 0.0027 - val_loss: 2.3437 - val_accuracy: 0.5707 - val_macro_f1score: 0.1011 - val_weighted_f1score: 0.0020
# Learning rate:  0.001
#
# Epoch 00041: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 41/70
# 382/382 [==============================] - ETA: 0s - loss: 0.7998 - accuracy: 0.7800 - macro_f1score: 0.1452 - weighted_f1score: 0.0027
# Epoch 00041: val_loss did not improve from 1.99267
#
# Epoch 00041: val_accuracy did not improve from 0.57575
# 382/382 [==============================] - 675s 2s/step - loss: 0.7998 - accuracy: 0.7800 - macro_f1score: 0.1452 - weighted_f1score: 0.0027 - val_loss: 2.2689 - val_accuracy: 0.5754 - val_macro_f1score: 0.1041 - val_weighted_f1score: 0.0020
# Learning rate:  0.001
#
# Epoch 00042: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 42/70
# 382/382 [==============================] - ETA: 0s - loss: 0.7591 - accuracy: 0.7946 - macro_f1score: 0.1481 - weighted_f1score: 0.0028
# Epoch 00042: val_loss did not improve from 1.99267
#
# Epoch 00042: val_accuracy improved from 0.57575 to 0.57982, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_ResNet_v1/042.h5
# 382/382 [==============================] - 677s 2s/step - loss: 0.7591 - accuracy: 0.7946 - macro_f1score: 0.1481 - weighted_f1score: 0.0028 - val_loss: 2.2854 - val_accuracy: 0.5798 - val_macro_f1score: 0.1052 - val_weighted_f1score: 0.0020
# Learning rate:  0.001
#
# Epoch 00043: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 43/70
# 382/382 [==============================] - ETA: 0s - loss: 0.7409 - accuracy: 0.7945 - macro_f1score: 0.1502 - weighted_f1score: 0.0028
# Epoch 00043: val_loss did not improve from 1.99267
#
# Epoch 00043: val_accuracy improved from 0.57982 to 0.58322, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_ResNet_v1/043.h5
# 382/382 [==============================] - 677s 2s/step - loss: 0.7409 - accuracy: 0.7945 - macro_f1score: 0.1502 - weighted_f1score: 0.0028 - val_loss: 2.1603 - val_accuracy: 0.5832 - val_macro_f1score: 0.1064 - val_weighted_f1score: 0.0021
# Learning rate:  0.001
#
# Epoch 00044: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 44/70
# 382/382 [==============================] - ETA: 0s - loss: 0.7142 - accuracy: 0.8016 - macro_f1score: 0.1511 - weighted_f1score: 0.0028
# Epoch 00044: val_loss did not improve from 1.99267
#
# Epoch 00044: val_accuracy did not improve from 0.58322
# 382/382 [==============================] - 675s 2s/step - loss: 0.7142 - accuracy: 0.8016 - macro_f1score: 0.1511 - weighted_f1score: 0.0028 - val_loss: 2.1241 - val_accuracy: 0.5819 - val_macro_f1score: 0.1042 - val_weighted_f1score: 0.0020
# Learning rate:  0.001
#
# Epoch 00045: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 45/70
# 382/382 [==============================] - ETA: 0s - loss: 0.6552 - accuracy: 0.8121 - macro_f1score: 0.1565 - weighted_f1score: 0.0029
# Epoch 00045: val_loss did not improve from 1.99267
#
# Epoch 00045: val_accuracy did not improve from 0.58322
# 382/382 [==============================] - 672s 2s/step - loss: 0.6552 - accuracy: 0.8121 - macro_f1score: 0.1565 - weighted_f1score: 0.0029 - val_loss: 2.3040 - val_accuracy: 0.5798 - val_macro_f1score: 0.1059 - val_weighted_f1score: 0.0020
# Learning rate:  0.001
#
# Epoch 00046: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 46/70
# 382/382 [==============================] - ETA: 0s - loss: 0.6318 - accuracy: 0.8216 - macro_f1score: 0.1590 - weighted_f1score: 0.0029
# Epoch 00046: val_loss did not improve from 1.99267
#
# Epoch 00046: val_accuracy did not improve from 0.58322
# 382/382 [==============================] - 673s 2s/step - loss: 0.6318 - accuracy: 0.8216 - macro_f1score: 0.1590 - weighted_f1score: 0.0029 - val_loss: 2.2663 - val_accuracy: 0.5825 - val_macro_f1score: 0.1065 - val_weighted_f1score: 0.0021
# Learning rate:  0.001
#
# Epoch 00047: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 47/70
# 382/382 [==============================] - ETA: 0s - loss: 0.6233 - accuracy: 0.8234 - macro_f1score: 0.1590 - weighted_f1score: 0.0030
# Epoch 00047: val_loss did not improve from 1.99267
#
# Epoch 00047: val_accuracy improved from 0.58322 to 0.58492, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_ResNet_v1/047.h5
# 382/382 [==============================] - 678s 2s/step - loss: 0.6233 - accuracy: 0.8234 - macro_f1score: 0.1590 - weighted_f1score: 0.0030 - val_loss: 2.1138 - val_accuracy: 0.5849 - val_macro_f1score: 0.1085 - val_weighted_f1score: 0.0021
# Learning rate:  0.001
#
# Epoch 00048: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 48/70
# 382/382 [==============================] - ETA: 0s - loss: 0.5925 - accuracy: 0.8315 - macro_f1score: 0.1611 - weighted_f1score: 0.0030
# Epoch 00048: val_loss did not improve from 1.99267
#
# Epoch 00048: val_accuracy did not improve from 0.58492
# 382/382 [==============================] - 671s 2s/step - loss: 0.5925 - accuracy: 0.8315 - macro_f1score: 0.1611 - weighted_f1score: 0.0030 - val_loss: 2.0725 - val_accuracy: 0.5819 - val_macro_f1score: 0.1085 - val_weighted_f1score: 0.0021
# Learning rate:  0.001
#
# Epoch 00049: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 49/70
# 382/382 [==============================] - ETA: 0s - loss: 0.5290 - accuracy: 0.8470 - macro_f1score: 0.1664 - weighted_f1score: 0.0031
# Epoch 00049: val_loss did not improve from 1.99267
#
# Epoch 00049: val_accuracy did not improve from 0.58492
# 382/382 [==============================] - 669s 2s/step - loss: 0.5290 - accuracy: 0.8470 - macro_f1score: 0.1664 - weighted_f1score: 0.0031 - val_loss: 2.1845 - val_accuracy: 0.5812 - val_macro_f1score: 0.1070 - val_weighted_f1score: 0.0021
# Learning rate:  0.001
#
# Epoch 00050: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 50/70
# 382/382 [==============================] - ETA: 0s - loss: 0.5289 - accuracy: 0.8488 - macro_f1score: 0.1664 - weighted_f1score: 0.0031
# Epoch 00050: val_loss did not improve from 1.99267
#
# Epoch 00050: val_accuracy did not improve from 0.58492
# 382/382 [==============================] - 670s 2s/step - loss: 0.5289 - accuracy: 0.8488 - macro_f1score: 0.1664 - weighted_f1score: 0.0031 - val_loss: 2.3264 - val_accuracy: 0.5842 - val_macro_f1score: 0.1082 - val_weighted_f1score: 0.0021
# Learning rate:  0.0001
#
# Epoch 00051: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 51/70
# 382/382 [==============================] - ETA: 0s - loss: 0.2308 - accuracy: 0.9415 - macro_f1score: 0.1922 - weighted_f1score: 0.0035
# Epoch 00051: val_loss did not improve from 1.99267
#
# Epoch 00051: val_accuracy improved from 0.58492 to 0.59103, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_ResNet_v1/051.h5
# 382/382 [==============================] - 678s 2s/step - loss: 0.2308 - accuracy: 0.9415 - macro_f1score: 0.1922 - weighted_f1score: 0.0035 - val_loss: 2.3718 - val_accuracy: 0.5910 - val_macro_f1score: 0.1092 - val_weighted_f1score: 0.0021
# Learning rate:  0.0001
#
# Epoch 00052: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 52/70
# 382/382 [==============================] - ETA: 0s - loss: 0.1936 - accuracy: 0.9535 - macro_f1score: 0.1953 - weighted_f1score: 0.0036
# Epoch 00052: val_loss did not improve from 1.99267
#
# Epoch 00052: val_accuracy did not improve from 0.59103
# 382/382 [==============================] - 668s 2s/step - loss: 0.1936 - accuracy: 0.9535 - macro_f1score: 0.1953 - weighted_f1score: 0.0036 - val_loss: 2.4344 - val_accuracy: 0.5846 - val_macro_f1score: 0.1101 - val_weighted_f1score: 0.0021
# Learning rate:  0.0001
#
# Epoch 00053: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 53/70
# 382/382 [==============================] - ETA: 0s - loss: 0.1767 - accuracy: 0.9594 - macro_f1score: 0.1961 - weighted_f1score: 0.0036
# Epoch 00053: val_loss did not improve from 1.99267
#
# Epoch 00053: val_accuracy did not improve from 0.59103
# 382/382 [==============================] - 661s 2s/step - loss: 0.1767 - accuracy: 0.9594 - macro_f1score: 0.1961 - weighted_f1score: 0.0036 - val_loss: 2.5280 - val_accuracy: 0.5870 - val_macro_f1score: 0.1102 - val_weighted_f1score: 0.0021
# Learning rate:  0.0001
#
# Epoch 00054: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 54/70
# 382/382 [==============================] - ETA: 0s - loss: 0.1629 - accuracy: 0.9617 - macro_f1score: 0.1981 - weighted_f1score: 0.0037
# Epoch 00054: val_loss did not improve from 1.99267
#
# Epoch 00054: val_accuracy did not improve from 0.59103
# 382/382 [==============================] - 659s 2s/step - loss: 0.1629 - accuracy: 0.9617 - macro_f1score: 0.1981 - weighted_f1score: 0.0037 - val_loss: 2.5588 - val_accuracy: 0.5849 - val_macro_f1score: 0.1103 - val_weighted_f1score: 0.0021
# Learning rate:  0.0001
#
# Epoch 00055: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 55/70
# 382/382 [==============================] - ETA: 0s - loss: 0.1535 - accuracy: 0.9659 - macro_f1score: 0.1997 - weighted_f1score: 0.0037
# Epoch 00055: val_loss did not improve from 1.99267
#
# Epoch 00055: val_accuracy did not improve from 0.59103
# 382/382 [==============================] - 663s 2s/step - loss: 0.1535 - accuracy: 0.9659 - macro_f1score: 0.1997 - weighted_f1score: 0.0037 - val_loss: 2.5443 - val_accuracy: 0.5900 - val_macro_f1score: 0.1110 - val_weighted_f1score: 0.0021
# Learning rate:  0.0001
#
# Epoch 00056: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 56/70
# 382/382 [==============================] - ETA: 0s - loss: 0.1439 - accuracy: 0.9673 - macro_f1score: 0.2007 - weighted_f1score: 0.0037
# Epoch 00056: val_loss did not improve from 1.99267
#
# Epoch 00056: val_accuracy did not improve from 0.59103
# 382/382 [==============================] - 668s 2s/step - loss: 0.1439 - accuracy: 0.9673 - macro_f1score: 0.2007 - weighted_f1score: 0.0037 - val_loss: 2.6013 - val_accuracy: 0.5876 - val_macro_f1score: 0.1102 - val_weighted_f1score: 0.0022
# Learning rate:  0.0001
#
# Epoch 00057: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 57/70
# 382/382 [==============================] - ETA: 0s - loss: 0.1341 - accuracy: 0.9698 - macro_f1score: 0.2010 - weighted_f1score: 0.0037
# Epoch 00057: val_loss did not improve from 1.99267
#
# Epoch 00057: val_accuracy improved from 0.59103 to 0.59477, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_ResNet_v1/057.h5
# 382/382 [==============================] - 670s 2s/step - loss: 0.1341 - accuracy: 0.9698 - macro_f1score: 0.2010 - weighted_f1score: 0.0037 - val_loss: 2.5696 - val_accuracy: 0.5948 - val_macro_f1score: 0.1114 - val_weighted_f1score: 0.0021
# Learning rate:  0.0001
#
# Epoch 00058: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 58/70
# 382/382 [==============================] - ETA: 0s - loss: 0.1226 - accuracy: 0.9737 - macro_f1score: 0.2024 - weighted_f1score: 0.0037
# Epoch 00058: val_loss did not improve from 1.99267
#
# Epoch 00058: val_accuracy did not improve from 0.59477
# 382/382 [==============================] - 663s 2s/step - loss: 0.1226 - accuracy: 0.9737 - macro_f1score: 0.2024 - weighted_f1score: 0.0037 - val_loss: 2.7426 - val_accuracy: 0.5887 - val_macro_f1score: 0.1125 - val_weighted_f1score: 0.0021
# Learning rate:  0.0001
#
# Epoch 00059: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 59/70
# 382/382 [==============================] - ETA: 0s - loss: 0.1167 - accuracy: 0.9748 - macro_f1score: 0.2033 - weighted_f1score: 0.0037
# Epoch 00059: val_loss did not improve from 1.99267
#
# Epoch 00059: val_accuracy did not improve from 0.59477
# 382/382 [==============================] - 665s 2s/step - loss: 0.1167 - accuracy: 0.9748 - macro_f1score: 0.2033 - weighted_f1score: 0.0037 - val_loss: 2.7627 - val_accuracy: 0.5907 - val_macro_f1score: 0.1125 - val_weighted_f1score: 0.0022
# Learning rate:  0.0001
#
# Epoch 00060: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 60/70
# 382/382 [==============================] - ETA: 0s - loss: 0.1146 - accuracy: 0.9755 - macro_f1score: 0.2039 - weighted_f1score: 0.0037
# Epoch 00060: val_loss did not improve from 1.99267
#
# Epoch 00060: val_accuracy did not improve from 0.59477
# 382/382 [==============================] - 660s 2s/step - loss: 0.1146 - accuracy: 0.9755 - macro_f1score: 0.2039 - weighted_f1score: 0.0037 - val_loss: 2.8324 - val_accuracy: 0.5897 - val_macro_f1score: 0.1127 - val_weighted_f1score: 0.0022
# Learning rate:  0.0001
#
# Epoch 00061: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 61/70
# 382/382 [==============================] - ETA: 0s - loss: 0.1015 - accuracy: 0.9800 - macro_f1score: 0.2054 - weighted_f1score: 0.0038
# Epoch 00061: val_loss did not improve from 1.99267
#
# Epoch 00061: val_accuracy did not improve from 0.59477
# 382/382 [==============================] - 682s 2s/step - loss: 0.1015 - accuracy: 0.9800 - macro_f1score: 0.2054 - weighted_f1score: 0.0038 - val_loss: 2.8085 - val_accuracy: 0.5890 - val_macro_f1score: 0.1134 - val_weighted_f1score: 0.0022
# Learning rate:  0.0001
#
# Epoch 00062: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 62/70
# 382/382 [==============================] - ETA: 0s - loss: 0.0993 - accuracy: 0.9795 - macro_f1score: 0.2046 - weighted_f1score: 0.0038
# Epoch 00062: val_loss did not improve from 1.99267
#
# Epoch 00062: val_accuracy did not improve from 0.59477
# 382/382 [==============================] - 664s 2s/step - loss: 0.0993 - accuracy: 0.9795 - macro_f1score: 0.2046 - weighted_f1score: 0.0038 - val_loss: 2.7945 - val_accuracy: 0.5887 - val_macro_f1score: 0.1110 - val_weighted_f1score: 0.0022
# Learning rate:  0.0001
#
# Epoch 00063: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 63/70
# 382/382 [==============================] - ETA: 0s - loss: 0.0951 - accuracy: 0.9807 - macro_f1score: 0.2050 - weighted_f1score: 0.0038
# Epoch 00063: val_loss did not improve from 1.99267
#
# Epoch 00063: val_accuracy did not improve from 0.59477
# 382/382 [==============================] - 668s 2s/step - loss: 0.0951 - accuracy: 0.9807 - macro_f1score: 0.2050 - weighted_f1score: 0.0038 - val_loss: 2.8100 - val_accuracy: 0.5873 - val_macro_f1score: 0.1103 - val_weighted_f1score: 0.0021
# Learning rate:  0.0001
#
# Epoch 00064: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 64/70
# 382/382 [==============================] - ETA: 0s - loss: 0.0884 - accuracy: 0.9817 - macro_f1score: 0.2066 - weighted_f1score: 0.0038
# Epoch 00064: val_loss did not improve from 1.99267
#
# Epoch 00064: val_accuracy did not improve from 0.59477
# 382/382 [==============================] - 674s 2s/step - loss: 0.0884 - accuracy: 0.9817 - macro_f1score: 0.2066 - weighted_f1score: 0.0038 - val_loss: 2.7861 - val_accuracy: 0.5836 - val_macro_f1score: 0.1103 - val_weighted_f1score: 0.0022
# Learning rate:  0.0001
#
# Epoch 00065: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 65/70
# 382/382 [==============================] - ETA: 0s - loss: 0.0849 - accuracy: 0.9841 - macro_f1score: 0.2065 - weighted_f1score: 0.0038
# Epoch 00065: val_loss did not improve from 1.99267
#
# Epoch 00065: val_accuracy did not improve from 0.59477
# 382/382 [==============================] - 682s 2s/step - loss: 0.0849 - accuracy: 0.9841 - macro_f1score: 0.2065 - weighted_f1score: 0.0038 - val_loss: 2.5900 - val_accuracy: 0.5938 - val_macro_f1score: 0.1144 - val_weighted_f1score: 0.0022
# Learning rate:  0.0001
#
# Epoch 00066: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 66/70
# 382/382 [==============================] - ETA: 0s - loss: 0.0812 - accuracy: 0.9832 - macro_f1score: 0.2063 - weighted_f1score: 0.0038
# Epoch 00066: val_loss did not improve from 1.99267
#
# Epoch 00066: val_accuracy did not improve from 0.59477
# 382/382 [==============================] - 673s 2s/step - loss: 0.0812 - accuracy: 0.9832 - macro_f1score: 0.2063 - weighted_f1score: 0.0038 - val_loss: 2.6987 - val_accuracy: 0.5948 - val_macro_f1score: 0.1105 - val_weighted_f1score: 0.0022
# Learning rate:  0.0001
#
# Epoch 00067: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 67/70
# 382/382 [==============================] - ETA: 0s - loss: 0.0759 - accuracy: 0.9854 - macro_f1score: 0.2069 - weighted_f1score: 0.0038
# Epoch 00067: val_loss did not improve from 1.99267
#
# Epoch 00067: val_accuracy improved from 0.59477 to 0.59817, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_ResNet_v1/067.h5
# 382/382 [==============================] - 689s 2s/step - loss: 0.0759 - accuracy: 0.9854 - macro_f1score: 0.2069 - weighted_f1score: 0.0038 - val_loss: 2.7182 - val_accuracy: 0.5982 - val_macro_f1score: 0.1139 - val_weighted_f1score: 0.0022
# Learning rate:  0.0001
#
# Epoch 00068: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 68/70
# 382/382 [==============================] - ETA: 0s - loss: 0.0746 - accuracy: 0.9852 - macro_f1score: 0.2067 - weighted_f1score: 0.0038
# Epoch 00068: val_loss did not improve from 1.99267
#
# Epoch 00068: val_accuracy did not improve from 0.59817
# 382/382 [==============================] - 694s 2s/step - loss: 0.0746 - accuracy: 0.9852 - macro_f1score: 0.2067 - weighted_f1score: 0.0038 - val_loss: 2.8697 - val_accuracy: 0.5900 - val_macro_f1score: 0.1125 - val_weighted_f1score: 0.0022
# Learning rate:  0.0001
#
# Epoch 00069: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 69/70
# 382/382 [==============================] - ETA: 0s - loss: 0.0696 - accuracy: 0.9855 - macro_f1score: 0.2080 - weighted_f1score: 0.0038
# Epoch 00069: val_loss did not improve from 1.99267
#
# Epoch 00069: val_accuracy did not improve from 0.59817
# 382/382 [==============================] - 685s 2s/step - loss: 0.0696 - accuracy: 0.9855 - macro_f1score: 0.2080 - weighted_f1score: 0.0038 - val_loss: 2.8624 - val_accuracy: 0.5927 - val_macro_f1score: 0.1125 - val_weighted_f1score: 0.0022
# Learning rate:  0.0001
#
# Epoch 00070: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 70/70
# 382/382 [==============================] - ETA: 0s - loss: 0.0657 - accuracy: 0.9877 - macro_f1score: 0.2077 - weighted_f1score: 0.0038
# Epoch 00070: val_loss did not improve from 1.99267
#
# Epoch 00070: val_accuracy did not improve from 0.59817
# 382/382 [==============================] - 684s 2s/step - loss: 0.0657 - accuracy: 0.9877 - macro_f1score: 0.2077 - weighted_f1score: 0.0038 - val_loss: 2.7600 - val_accuracy: 0.5938 - val_macro_f1score: 0.1136 - val_weighted_f1score: 0.0022

# %% [markdown]
# ### 3) Inception-ResNet-V1 Evaluate

# %%
# 1. epoch=maximum
loss , acc, mf1, wf1 = model.evaluate(test_generator,steps=int(len(x_test)/batch_sizes))
print('[Test Loss: %.4f /  Test Accuracy: %.4f / Test Macro f1: %.4f / Test Weighted f1: %.4f]\n' % (loss,acc,mf1,wf1))
# Out:
# 48/48 [==============================] - 566s 12s/step - loss: 3.3366 - accuracy: 0.5752 - macro_f1score: 0.1089 - weighted_f1score: 0.0021
# [Test Loss: 3.3366 /  Test Accuracy: 0.5752 / Test Macro f1: 0.1089 / Test Weighted f1: 0.0021]

# %%
loss=history.history['loss']
val_loss=history.history['val_loss']
acc=history.history['accuracy']
val_acc=history.history['val_accuracy']
f1=history.history['macro_f1score']
val_f1=history.history['val_macro_f1score']
epochs=range(1,len(acc)+1)

data = np.array([epochs,loss,val_loss,acc,val_acc,f1,val_f1]).T

# %%
# data save
# epochs, loss, val_loss, acc, val_acc, f1, val_f1

np.savetxt(os.path.join(dir,'train_valid_output',number,model.name+'.txt'),data)

# %%
# data import
data = np.loadtxt(os.path.join(dir,'train_valid_output',number,'Inception_ResNet_v1.txt'))

# %%
epochs=data[:,0]
loss=data[:,1]
val_loss=data[:,2]
acc=data[:,3]
val_acc=data[:,4]

# %%
plt.plot(epochs[1:],acc[1:],'b',label='Training Acc')
plt.plot(epochs[1:],val_acc[1:],'r',label='Validation Acc')
plt.title('Training and Validation Accuracy')
plt.legend()
plt.figure()
plt.plot(epochs[10:],loss[10:],'b',label='Training Loss')
plt.plot(epochs[10:],val_loss[10:],'r',label='Validation Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()

# %%
# 이 아래는 내가 인위적으로 살펴보고 싶은 epoch에 대해서 결과값 출력 / inception_resnet_v1

# %%
model=load_model(os.path.join(dir,'model_output',number,'Inception_ResNet_v1','011.h5'),custom_objects={"macro_f1score": macro_f1score,"weighted_f1score":weighted_f1score})

# %%
# 2. epoch=?
loss , acc, mf1, wf1 = model.evaluate(test_generator,steps=int(len(x_test)/batch_sizes))
print('[Test Loss: %.4f /  Test Accuracy: %.4f / Test Macro f1: %.4f / Test Weighted f1: %.4f]\n' % (loss,acc,mf1,wf1))
