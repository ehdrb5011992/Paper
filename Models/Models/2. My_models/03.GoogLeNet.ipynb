# %% [markdown]
# # [GoogLeNet]

# %% [markdown]
# *KU LeeDongGyu*

# %% [markdown]
# ## Contents
# ---

# %% [markdown]
# 1. Data Preprocessing
# ```
# 1) Data Import
# 2) Data Augmentation
# ```
# 2. Support Functions & Almost Original GoogLeNet
# ```
# 1) Support Functions
# 2) Almost Original GoogLeNet
# 3) GoogLeNet Evaluate
# ```

# %% [markdown]
# ### Install Packages

# %% [markdown]
# ### Module

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
cd /content/drive/My Drive/Colab Notebooks/Paper
# Out:
# /content/drive/My Drive/Colab Notebooks/Paper

# %%
from f1score import macro_f1score,weighted_f1score
from pool_helper import PoolHelper
from lrn import LRN

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import cv2
import tensorflow as tf
from tensorflow import keras as ks
from tensorflow.keras import backend as K 
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, Input, Concatenate, ZeroPadding2D ,GlobalMaxPooling2D, Reshape , Lambda , Add, Multiply
from tensorflow.keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D, Activation, BatchNormalization, AveragePooling2D , ZeroPadding2D, SeparableConv2D
from tensorflow.keras.layers import add
from tensorflow.keras.optimizers import Adam, RMSprop , SGD
from tensorflow.keras.callbacks import EarlyStopping , LearningRateScheduler, ModelCheckpoint, CSVLogger, Callback, ReduceLROnPlateau
from tensorflow.keras.regularizers import l1,l2,l1_l2
from tensorflow.keras.models import Model , load_model , Sequential
from tensorflow.keras.utils import plot_model , to_categorical, get_file
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
os.getcwd()
# Out:
# '/content/drive/My Drive/Colab Notebooks/Paper'

# %%
print(tf.__version__)
print(ks.__version__)
# Out:
# 2.3.0
# 2.4.0

# %%
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 11219184916509504166
# , name: "/device:XLA_CPU:0"
# device_type: "XLA_CPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 1292820583388628124
# physical_device_desc: "device: XLA_CPU device"
# , name: "/device:XLA_GPU:0"
# device_type: "XLA_GPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 14903651195221637242
# physical_device_desc: "device: XLA_GPU device"
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 15695549568
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 14543899273206874862
# physical_device_desc: "device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0"
# ]

# %% [markdown]
# ## 1. Data Preprocessing
# ---

# %% [markdown]
# ### 1) Data Import

# %%
# 바꿔서 살펴 볼 것들
# CALTECH, CIFAR100, FER, MIT
data_name = 'CALTECH'
gan_type = 'No_GAN'
number = '1'
size = 224
super_size = 256
input_sizes = (size,size,3)
batch_sizes = 128
weight_decay = 1e-5
epochs = 70

# %%
# 참고 : https://stackoverflow.com/questions/32419510/how-to-get-reproducible-results-in-keras/52897216#52897216
# setting the seed number for random number generation for reproducibility.

from numpy.random import seed
import random


if number=='1':
    seed_num = 200225
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)
elif number=='2':
    seed_num = 727
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)
elif number=='3':
    seed_num = 115
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)
elif number=='4':
    seed_num = 501
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)
elif number=='5':
    seed_num = 517
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)

# %%
# data import

if data_name=='FER' :
    x_train =  np.zeros(28698)
    x_valid = np.zeros(3589)
    x_test = np.zeros(3588)
    classes = 7 
    tr_center = [0.50793296, 0.50793296, 0.50793296]
elif data_name=='MIT':
    x_train = np.zeros(12466)
    x_valid = np.zeros(1564)
    x_test = np.zeros(1590)
    classes = 67 
    tr_center = [0.47916578, 0.42029615, 0.36046057]
elif data_name=='CALTECH':
    x_train = np.zeros(24510)
    x_valid = np.zeros(2980)
    x_test = np.zeros(3118)
    classes = 257
    tr_center = [0.51397761, 0.49525248, 0.46555727]
elif data_name=='CIFAR100':
    x_train = np.zeros(39941)
    x_valid = np.zeros(10059)
    x_test = np.zeros(10000)
    classes = 100
    tr_center = [0.53393271, 0.51324147, 0.46450563]

# %%
dir = os.path.join(os.getcwd(),data_name,gan_type)

# %% [markdown]
# ### 2) Data Augmentation

# %%
# 참고 : https://jkjung-avt.github.io/keras-image-cropping/

def random_crop(img, random_crop_size):
    # Note: image_data_format is 'channel_last'
    assert img.shape[2] == 3 # img.shape[2] 가 3(rgb)이 아니면 assertion error 발생
    height, width = img.shape[0], img.shape[1]
    dy, dx = random_crop_size
    x = np.random.randint(0, width - dx + 1)
    y = np.random.randint(0, height - dy + 1)
    return img[y:(y+dy), x:(x+dx), :]


def crop_generator(batches, crop_length):
    """Take as input a Keras ImageGen (Iterator) and generate random
    crops from the image batches generated by the original iterator.
    """
    while True:
        batch_x, batch_y = next(batches)
        batch_crops = np.zeros((batch_x.shape[0], crop_length, crop_length, 3))
        for i in range(batch_x.shape[0]):
            batch_crops[i] = random_crop(batch_x[i], (crop_length, crop_length))
        yield (batch_crops, batch_y)

# %%
from tensorflow.keras.preprocessing.image import img_to_array,load_img
import glob

# 데이터 전체에 대해 centering 진행함.

def read_cal_image(img_path): 
    x = img_to_array(load_img(img_path)) # x는 채널별 평균값
    y = x.shape[0] * x.shape[1]# y는 데이터별 픽셀 수 (비중)

    x = 1/255. * x # scaling하고, centering값을 뽑아냄.
    x = np.mean(x, axis=(0,1))
    
    return np.hstack([x,y])

def calculate_centered_mean(dataset_path,x_train=x_train):
    num = len(x_train)
    space = np.empty((num,4))
    i=0

    for p in glob.glob(os.path.join(dataset_path,'*/*.*')) :
        space[i] = read_cal_image(p)
        i += 1

    ratio = space[:,3] / np.sum(space[:,3])

    return np.average(space[:,0:3],axis=0,weights=ratio)


# 아래의 함수를 돌려서 나온 결과값을 중심화 값으로 설정.

# train_mean = calculate_centered_mean(os.path.join(dir,'data/train')).reshape((1,1,3))

# %%
datagen_tr = ImageDataGenerator(
    rescale=1/255.,
    horizontal_flip=True,
    featurewise_center=True,
    featurewise_std_normalization=False,
    rotation_range=10,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=[0.9,1.0],
    fill_mode = 'nearest')
datagen_val = ImageDataGenerator(rescale=1/255.,featurewise_center=True)
datagen_tes = ImageDataGenerator(rescale=1/255.,featurewise_center=True)

# 원래는 이 자리에 fit 매서드를 써야하지만, 그냥 내가 중심화함수를 만들고 적용함. 

# 중심화 설정
datagen_tr.mean = np.array(tr_center, dtype=np.float32).reshape((1,1,3)) # RGB
datagen_val.mean = np.array(tr_center, dtype=np.float32).reshape((1,1,3)) # RGB
datagen_tes.mean = np.array(tr_center, dtype=np.float32).reshape((1,1,3)) # RGB

# %%
# Inception-V2 & V3은 분류기가 2개이므로 imagedatagenerator 사용방법이 다소 다르다.
# model.fit에 다중 input으로 들어갈 함수를 개인이 만들어서 사용해야 하며, 그 함수는 아래와 같다. 
# 매우 간단하다.

#1. train data

def generate_train_for_three(crop_length=size, batch_sizes = batch_sizes, super_size=super_size):

      batches = datagen_tr.flow_from_directory(directory=os.path.join(dir,'data/train'),target_size=(super_size,super_size),batch_size=batch_sizes,class_mode='categorical')

      while True:
          batch_x, batch_y = next(batches)
          batch_crops = np.zeros((batch_x.shape[0], crop_length, crop_length, 3))
          for i in range(batch_x.shape[0]):
              batch_crops[i] = random_crop(batch_x[i], (crop_length, crop_length))
          yield batch_crops, [batch_y,batch_y,batch_y]

# %%
# 2. valid data

def generate_valid_for_three(size=size, batch_sizes = batch_sizes):

      batches_xy = datagen_val.flow_from_directory(directory=os.path.join(dir,'data/valid'),target_size=(size,size),batch_size=batch_sizes,class_mode='categorical')

      while True:

          batch_xy = batches_xy.next()
          yield  batch_xy[0], [ batch_xy[1],batch_xy[1],batch_xy[1] ]

# %%
# 3. test data

def generate_test_for_three(size=size, batch_sizes = batch_sizes):

      batches_xy = datagen_tes.flow_from_directory(directory=os.path.join(dir,'data/test'),target_size=(size,size),batch_size=batch_sizes,class_mode='categorical')

      while True:

          batch_xy = batches_xy.next()
          yield  batch_xy[0], [ batch_xy[1],batch_xy[1],batch_xy[1] ]

# %%
# 위에서 쓰임
# train_batches = datagen_tr.flow_from_directory(directory=os.path.join(dir,'data/train'),target_size=(super_size,super_size),batch_size=batch_sizes,class_mode='categorical') # fer : 28698 / mit : 12466 / caltech : 24509 / cifar : 39941
# train_generator= crop_generator(train_batches, size)

# valid_generator = datagen_val.flow_from_directory(directory=os.path.join(dir,'data/valid'),target_size=(size,size),batch_size=batch_sizes,class_mode='categorical') # fer : 3589 / mit : 1564 / caltech : 2980 / cifar : 10059
# test_generator = datagen_tes.flow_from_directory(directory=os.path.join(dir,'data/test'),target_size=(size,size),batch_size=batch_sizes,class_mode='categorical') # fer : 3588 / mit : 1590 / caltech : 3118 / cifar : 10000

# %% [markdown]
# ## 2. Support Functions & Almost Original GoogLeNet
# ---

# %% [markdown]
# ### 1) Support Functions

# %%
# def lr_schedule(epoch):
#     init_lr = 1e-4
#     k = 0.04
#     lr = init_lr * np.exp(-k*epoch)
#     print('Learning rate: ', lr)
#     return lr

def lr_schedule(epoch):
    lr = 3e-4
    if epoch < 60:
        lr = lr
    else :
        lr = lr * 0.1
    print('Learning rate: ', lr)
    return lr

# %% [markdown]
# ### 3) Almost Original GoogLeNet

# %%
# GoogLeNet를 최대한 논문에 가깝게 맞춰 모형작성.

def googlenet(input_shape=(224,224,3), classes=1000, weight_decay = weight_decay, weights_path = None,name='Inception_v1'):

    input = Input(input_shape)

    conv1_7x7_s2 = Conv2D(64, (7,7), strides=(2,2), padding='same', activation='relu', name='conv1/7x7_s2', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(input)
    pool1_3x3_s2 = MaxPooling2D(pool_size=(3,3), strides=(2,2), padding='same', name='pool1/3x3_s2')(conv1_7x7_s2)
    pool1_norm1 = LRN(name='pool1/norm1')(pool1_3x3_s2)

    conv2_3x3_reduce = Conv2D(64, (1,1), padding='same', activation='relu', name='conv2/3x3_reduce', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(pool1_norm1)
    conv2_3x3 = Conv2D(192, (3,3), padding='same', activation='relu', name='conv2/3x3', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(conv2_3x3_reduce)
    conv2_norm2 = LRN(name='conv2/norm2')(conv2_3x3)
    pool2_3x3_s2 = MaxPooling2D(pool_size=(3,3), strides=(2,2), padding='same', name='pool2/3x3_s2')(conv2_norm2)

    inception_3a_1x1 = Conv2D(64, (1,1), padding='same', activation='relu', name='inception_3a/1x1', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(pool2_3x3_s2)
    inception_3a_3x3_reduce = Conv2D(96, (1,1), padding='same', activation='relu', name='inception_3a/3x3_reduce', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(pool2_3x3_s2)
    inception_3a_3x3_pad = ZeroPadding2D(padding=(1, 1))(inception_3a_3x3_reduce)
    inception_3a_3x3 = Conv2D(128, (3,3), padding='valid', activation='relu', name='inception_3a/3x3', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_3a_3x3_pad)
    inception_3a_5x5_reduce = Conv2D(16, (1,1), padding='same', activation='relu', name='inception_3a/5x5_reduce', kernel_regularizer=l2(weight_decay))(pool2_3x3_s2)
    inception_3a_5x5_pad = ZeroPadding2D(padding=(2, 2))(inception_3a_5x5_reduce)
    inception_3a_5x5 = Conv2D(32, (5,5), padding='valid', activation='relu', name='inception_3a/5x5', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_3a_5x5_pad)
    inception_3a_pool = MaxPooling2D(pool_size=(3,3), strides=(1,1), padding='same', name='inception_3a/pool')(pool2_3x3_s2)
    inception_3a_pool_proj = Conv2D(32, (1,1), padding='same', activation='relu', name='inception_3a/pool_proj', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_3a_pool)
    inception_3a_output = Concatenate(axis=-1, name='inception_3a/output')([inception_3a_1x1,inception_3a_3x3,inception_3a_5x5,inception_3a_pool_proj])
    # Concatenate axis 수정.

    inception_3b_1x1 = Conv2D(128, (1,1), padding='same', activation='relu', name='inception_3b/1x1', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_3a_output)
    inception_3b_3x3_reduce = Conv2D(128, (1,1), padding='same', activation='relu', name='inception_3b/3x3_reduce', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_3a_output)
    inception_3b_3x3_pad = ZeroPadding2D(padding=(1, 1))(inception_3b_3x3_reduce)
    inception_3b_3x3 = Conv2D(192, (3,3), padding='valid', activation='relu', name='inception_3b/3x3', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_3b_3x3_pad)
    inception_3b_5x5_reduce = Conv2D(32, (1,1), padding='same', activation='relu', name='inception_3b/5x5_reduce', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_3a_output)
    inception_3b_5x5_pad = ZeroPadding2D(padding=(2, 2))(inception_3b_5x5_reduce)
    inception_3b_5x5 = Conv2D(96, (5,5), padding='valid', activation='relu', name='inception_3b/5x5', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_3b_5x5_pad)
    inception_3b_pool = MaxPooling2D(pool_size=(3,3), strides=(1,1), padding='same', name='inception_3b/pool')(inception_3a_output)
    inception_3b_pool_proj = Conv2D(64, (1,1), padding='same', activation='relu', name='inception_3b/pool_proj', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_3b_pool)
    inception_3b_output = Concatenate(axis=-1, name='inception_3b/output')([inception_3b_1x1,inception_3b_3x3,inception_3b_5x5,inception_3b_pool_proj])

    pool3_3x3_s2 = MaxPooling2D(pool_size=(3,3), strides=(2,2), padding='same', name='pool3/3x3_s2')(inception_3b_output)

    inception_4a_1x1 = Conv2D(192, (1,1), padding='same', activation='relu', name='inception_4a/1x1', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(pool3_3x3_s2)
    inception_4a_3x3_reduce = Conv2D(96, (1,1), padding='same', activation='relu', name='inception_4a/3x3_reduce', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(pool3_3x3_s2)
    inception_4a_3x3_pad = ZeroPadding2D(padding=(1, 1))(inception_4a_3x3_reduce)
    inception_4a_3x3 = Conv2D(208, (3,3), padding='valid', activation='relu', name='inception_4a/3x3', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_4a_3x3_pad)
    inception_4a_5x5_reduce = Conv2D(16, (1,1), padding='same', activation='relu', name='inception_4a/5x5_reduce', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(pool3_3x3_s2)
    inception_4a_5x5_pad = ZeroPadding2D(padding=(2, 2))(inception_4a_5x5_reduce)
    inception_4a_5x5 = Conv2D(48, (5,5), padding='valid', activation='relu', name='inception_4a/5x5', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_4a_5x5_pad)
    inception_4a_pool = MaxPooling2D(pool_size=(3,3), strides=(1,1), padding='same', name='inception_4a/pool')(pool3_3x3_s2)
    inception_4a_pool_proj = Conv2D(64, (1,1), padding='same', activation='relu', name='inception_4a/pool_proj', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_4a_pool)
    inception_4a_output = Concatenate(axis=-1, name='inception_4a/output')([inception_4a_1x1,inception_4a_3x3,inception_4a_5x5,inception_4a_pool_proj])

    loss1_ave_pool = AveragePooling2D(pool_size=(5,5), strides=(3,3), name='loss1/ave_pool')(inception_4a_output)
    loss1_conv = Conv2D(128, (1,1), padding='same', activation='relu', name='loss1/conv', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(loss1_ave_pool)
    loss1_flat = Flatten()(loss1_conv)
    loss1_fc = Dense(1024, activation='relu', name='loss1/fc', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(loss1_flat)
    loss1_drop_fc = Dropout(rate=0.7)(loss1_fc)
    loss1_classifier = Dense(classes, name='loss1/classifier')(loss1_drop_fc)
    loss1_classifier_act = Activation('softmax')(loss1_classifier)

    inception_4b_1x1 = Conv2D(160, (1,1), padding='same', activation='relu', name='inception_4b/1x1', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_4a_output)
    inception_4b_3x3_reduce = Conv2D(112, (1,1), padding='same', activation='relu', name='inception_4b/3x3_reduce', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_4a_output)
    inception_4b_3x3_pad = ZeroPadding2D(padding=(1, 1))(inception_4b_3x3_reduce)
    inception_4b_3x3 = Conv2D(224, (3,3), padding='valid', activation='relu', name='inception_4b/3x3', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_4b_3x3_pad)
    inception_4b_5x5_reduce = Conv2D(24, (1,1), padding='same', activation='relu', name='inception_4b/5x5_reduce', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_4a_output)
    inception_4b_5x5_pad = ZeroPadding2D(padding=(2, 2))(inception_4b_5x5_reduce)
    inception_4b_5x5 = Conv2D(64, (5,5), padding='valid', activation='relu', name='inception_4b/5x5', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_4b_5x5_pad)
    inception_4b_pool = MaxPooling2D(pool_size=(3,3), strides=(1,1), padding='same', name='inception_4b/pool')(inception_4a_output)
    inception_4b_pool_proj = Conv2D(64, (1,1), padding='same', activation='relu', name='inception_4b/pool_proj', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_4b_pool)
    inception_4b_output = Concatenate(axis=-1, name='inception_4b/output')([inception_4b_1x1,inception_4b_3x3,inception_4b_5x5,inception_4b_pool_proj])

    inception_4c_1x1 = Conv2D(128, (1,1), padding='same', activation='relu', name='inception_4c/1x1', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_4b_output)
    inception_4c_3x3_reduce = Conv2D(128, (1,1), padding='same', activation='relu', name='inception_4c/3x3_reduce', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_4b_output)
    inception_4c_3x3_pad = ZeroPadding2D(padding=(1, 1))(inception_4c_3x3_reduce)
    inception_4c_3x3 = Conv2D(256, (3,3), padding='valid', activation='relu', name='inception_4c/3x3', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_4c_3x3_pad)
    inception_4c_5x5_reduce = Conv2D(24, (1,1), padding='same', activation='relu', name='inception_4c/5x5_reduce', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_4b_output)
    inception_4c_5x5_pad = ZeroPadding2D(padding=(2, 2))(inception_4c_5x5_reduce)
    inception_4c_5x5 = Conv2D(64, (5,5), padding='valid', activation='relu', name='inception_4c/5x5', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_4c_5x5_pad)
    inception_4c_pool = MaxPooling2D(pool_size=(3,3), strides=(1,1), padding='same', name='inception_4c/pool')(inception_4b_output)
    inception_4c_pool_proj = Conv2D(64, (1,1), padding='same', activation='relu', name='inception_4c/pool_proj', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_4c_pool)
    inception_4c_output = Concatenate(axis=-1, name='inception_4c/output')([inception_4c_1x1,inception_4c_3x3,inception_4c_5x5,inception_4c_pool_proj])

    inception_4d_1x1 = Conv2D(112, (1,1), padding='same', activation='relu', name='inception_4d/1x1', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_4c_output)
    inception_4d_3x3_reduce = Conv2D(144, (1,1), padding='same', activation='relu', name='inception_4d/3x3_reduce', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_4c_output)
    inception_4d_3x3_pad = ZeroPadding2D(padding=(1, 1))(inception_4d_3x3_reduce)
    inception_4d_3x3 = Conv2D(288, (3,3), padding='valid', activation='relu', name='inception_4d/3x3', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_4d_3x3_pad)
    inception_4d_5x5_reduce = Conv2D(32, (1,1), padding='same', activation='relu', name='inception_4d/5x5_reduce', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_4c_output)
    inception_4d_5x5_pad = ZeroPadding2D(padding=(2, 2))(inception_4d_5x5_reduce)
    inception_4d_5x5 = Conv2D(64, (5,5), padding='valid', activation='relu', name='inception_4d/5x5', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_4d_5x5_pad)
    inception_4d_pool = MaxPooling2D(pool_size=(3,3), strides=(1,1), padding='same', name='inception_4d/pool')(inception_4c_output)
    inception_4d_pool_proj = Conv2D(64, (1,1), padding='same', activation='relu', name='inception_4d/pool_proj', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_4d_pool)
    inception_4d_output = Concatenate(axis=-1, name='inception_4d/output')([inception_4d_1x1,inception_4d_3x3,inception_4d_5x5,inception_4d_pool_proj])

    loss2_ave_pool = AveragePooling2D(pool_size=(5,5), strides=(3,3), name='loss2/ave_pool')(inception_4d_output)
    loss2_conv = Conv2D(128, (1,1), padding='same', activation='relu', name='loss2/conv', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(loss2_ave_pool)
    loss2_flat = Flatten()(loss2_conv)
    loss2_fc = Dense(1024, activation='relu', name='loss2/fc', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(loss2_flat)
    loss2_drop_fc = Dropout(rate=0.7)(loss2_fc)
    loss2_classifier = Dense(classes, name='loss2/classifier')(loss2_drop_fc)
    loss2_classifier_act = Activation('softmax')(loss2_classifier)

    inception_4e_1x1 = Conv2D(256, (1,1), padding='same', activation='relu', name='inception_4e/1x1', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_4d_output)
    inception_4e_3x3_reduce = Conv2D(160, (1,1), padding='same', activation='relu', name='inception_4e/3x3_reduce', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_4d_output)
    inception_4e_3x3_pad = ZeroPadding2D(padding=(1, 1))(inception_4e_3x3_reduce)
    inception_4e_3x3 = Conv2D(320, (3,3), padding='valid', activation='relu', name='inception_4e/3x3', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_4e_3x3_pad)
    inception_4e_5x5_reduce = Conv2D(32, (1,1), padding='same', activation='relu', name='inception_4e/5x5_reduce', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_4d_output)
    inception_4e_5x5_pad = ZeroPadding2D(padding=(2, 2))(inception_4e_5x5_reduce)
    inception_4e_5x5 = Conv2D(128, (5,5), padding='valid', activation='relu', name='inception_4e/5x5', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_4e_5x5_pad)
    inception_4e_pool = MaxPooling2D(pool_size=(3,3), strides=(1,1), padding='same', name='inception_4e/pool')(inception_4d_output)
    inception_4e_pool_proj = Conv2D(128, (1,1), padding='same', activation='relu', name='inception_4e/pool_proj', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_4e_pool)
    inception_4e_output = Concatenate(axis=-1, name='inception_4e/output')([inception_4e_1x1,inception_4e_3x3,inception_4e_5x5,inception_4e_pool_proj])

    pool4_3x3_s2 = MaxPooling2D(pool_size=(3,3), strides=(2,2), padding='same', name='pool4/3x3_s2')(inception_4e_output)

    inception_5a_1x1 = Conv2D(256, (1,1), padding='same', activation='relu', name='inception_5a/1x1', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(pool4_3x3_s2)
    inception_5a_3x3_reduce = Conv2D(160, (1,1), padding='same', activation='relu', name='inception_5a/3x3_reduce', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(pool4_3x3_s2)
    inception_5a_3x3_pad = ZeroPadding2D(padding=(1, 1))(inception_5a_3x3_reduce)
    inception_5a_3x3 = Conv2D(320, (3,3), padding='valid', activation='relu', name='inception_5a/3x3', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_5a_3x3_pad)
    inception_5a_5x5_reduce = Conv2D(32, (1,1), padding='same', activation='relu', name='inception_5a/5x5_reduce', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(pool4_3x3_s2)
    inception_5a_5x5_pad = ZeroPadding2D(padding=(2, 2))(inception_5a_5x5_reduce)
    inception_5a_5x5 = Conv2D(128, (5,5), padding='valid', activation='relu', name='inception_5a/5x5', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_5a_5x5_pad)
    inception_5a_pool = MaxPooling2D(pool_size=(3,3), strides=(1,1), padding='same', name='inception_5a/pool')(pool4_3x3_s2)
    inception_5a_pool_proj = Conv2D(128, (1,1), padding='same', activation='relu', name='inception_5a/pool_proj', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_5a_pool)
    inception_5a_output = Concatenate(axis=-1, name='inception_5a/output')([inception_5a_1x1,inception_5a_3x3,inception_5a_5x5,inception_5a_pool_proj])

    inception_5b_1x1 = Conv2D(384, (1,1), padding='same', activation='relu', name='inception_5b/1x1', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_5a_output)
    inception_5b_3x3_reduce = Conv2D(192, (1,1), padding='same', activation='relu', name='inception_5b/3x3_reduce', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_5a_output)
    inception_5b_3x3_pad = ZeroPadding2D(padding=(1, 1))(inception_5b_3x3_reduce)
    inception_5b_3x3 = Conv2D(384, (3,3), padding='valid', activation='relu', name='inception_5b/3x3', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_5b_3x3_pad)
    inception_5b_5x5_reduce = Conv2D(48, (1,1), padding='same', activation='relu', name='inception_5b/5x5_reduce', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_5a_output)
    inception_5b_5x5_pad = ZeroPadding2D(padding=(2, 2))(inception_5b_5x5_reduce)
    inception_5b_5x5 = Conv2D(128, (5,5), padding='valid', activation='relu', name='inception_5b/5x5', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_5b_5x5_pad)
    inception_5b_pool = MaxPooling2D(pool_size=(3,3), strides=(1,1), padding='same', name='inception_5b/pool')(inception_5a_output)
    inception_5b_pool_proj = Conv2D(128, (1,1), padding='same', activation='relu', name='inception_5b/pool_proj', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_5b_pool)
    inception_5b_output = Concatenate(axis=-1, name='inception_5b/output')([inception_5b_1x1,inception_5b_3x3,inception_5b_5x5,inception_5b_pool_proj])

    pool5_7x7_s1 = AveragePooling2D(pool_size=(7,7), strides=(1,1), name='pool5/7x7_s2')(inception_5b_output)

    loss3_flat = Flatten()(pool5_7x7_s1)
    pool5_drop_7x7_s1 = Dropout(rate=0.4)(loss3_flat)
    loss3_classifier = Dense(classes, name='loss3/classifier')(pool5_drop_7x7_s1)
    loss3_classifier_act = Activation('softmax', name='prob')(loss3_classifier)

    googlenet = Model(inputs=input, outputs=[loss1_classifier_act,loss2_classifier_act,loss3_classifier_act],name=name)

    if weights_path:
        googlenet.load_weights(weights_path)

    return googlenet

# %%
model = googlenet(input_shape=input_sizes, classes=classes, name='Inception_v1')

# %%
# auxiliary classifier 2개를 포함하기 때문에, 모수의 개수는 1000만개쯤 된다.
# 메인은 670만개 가량의 모수.
model.summary()
# Out:
# Model: "Inception_v1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# conv1/7x7_s2 (Conv2D)           (None, 112, 112, 64) 9472        input_1[0][0]
# __________________________________________________________________________________________________
# pool1/3x3_s2 (MaxPooling2D)     (None, 56, 56, 64)   0           conv1/7x7_s2[0][0]
# __________________________________________________________________________________________________
# pool1/norm1 (LRN)               (None, 56, 56, 64)   0           pool1/3x3_s2[0][0]
# __________________________________________________________________________________________________
# conv2/3x3_reduce (Conv2D)       (None, 56, 56, 64)   4160        pool1/norm1[0][0]
# __________________________________________________________________________________________________
# conv2/3x3 (Conv2D)              (None, 56, 56, 192)  110784      conv2/3x3_reduce[0][0]
# __________________________________________________________________________________________________
# conv2/norm2 (LRN)               (None, 56, 56, 192)  0           conv2/3x3[0][0]
# __________________________________________________________________________________________________
# pool2/3x3_s2 (MaxPooling2D)     (None, 28, 28, 192)  0           conv2/norm2[0][0]
# __________________________________________________________________________________________________
# inception_3a/3x3_reduce (Conv2D (None, 28, 28, 96)   18528       pool2/3x3_s2[0][0]
# __________________________________________________________________________________________________
# inception_3a/5x5_reduce (Conv2D (None, 28, 28, 16)   3088        pool2/3x3_s2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d (ZeroPadding2D)  (None, 30, 30, 96)   0           inception_3a/3x3_reduce[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_1 (ZeroPadding2D (None, 32, 32, 16)   0           inception_3a/5x5_reduce[0][0]
# __________________________________________________________________________________________________
# inception_3a/pool (MaxPooling2D (None, 28, 28, 192)  0           pool2/3x3_s2[0][0]
# __________________________________________________________________________________________________
# inception_3a/1x1 (Conv2D)       (None, 28, 28, 64)   12352       pool2/3x3_s2[0][0]
# __________________________________________________________________________________________________
# inception_3a/3x3 (Conv2D)       (None, 28, 28, 128)  110720      zero_padding2d[0][0]
# __________________________________________________________________________________________________
# inception_3a/5x5 (Conv2D)       (None, 28, 28, 32)   12832       zero_padding2d_1[0][0]
# __________________________________________________________________________________________________
# inception_3a/pool_proj (Conv2D) (None, 28, 28, 32)   6176        inception_3a/pool[0][0]
# __________________________________________________________________________________________________
# inception_3a/output (Concatenat (None, 28, 28, 256)  0           inception_3a/1x1[0][0]
#                                                                  inception_3a/3x3[0][0]
#                                                                  inception_3a/5x5[0][0]
#                                                                  inception_3a/pool_proj[0][0]
# __________________________________________________________________________________________________
# inception_3b/3x3_reduce (Conv2D (None, 28, 28, 128)  32896       inception_3a/output[0][0]
# __________________________________________________________________________________________________
# inception_3b/5x5_reduce (Conv2D (None, 28, 28, 32)   8224        inception_3a/output[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_2 (ZeroPadding2D (None, 30, 30, 128)  0           inception_3b/3x3_reduce[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_3 (ZeroPadding2D (None, 32, 32, 32)   0           inception_3b/5x5_reduce[0][0]
# __________________________________________________________________________________________________
# inception_3b/pool (MaxPooling2D (None, 28, 28, 256)  0           inception_3a/output[0][0]
# __________________________________________________________________________________________________
# inception_3b/1x1 (Conv2D)       (None, 28, 28, 128)  32896       inception_3a/output[0][0]
# __________________________________________________________________________________________________
# inception_3b/3x3 (Conv2D)       (None, 28, 28, 192)  221376      zero_padding2d_2[0][0]
# __________________________________________________________________________________________________
# inception_3b/5x5 (Conv2D)       (None, 28, 28, 96)   76896       zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# inception_3b/pool_proj (Conv2D) (None, 28, 28, 64)   16448       inception_3b/pool[0][0]
# __________________________________________________________________________________________________
# inception_3b/output (Concatenat (None, 28, 28, 480)  0           inception_3b/1x1[0][0]
#                                                                  inception_3b/3x3[0][0]
#                                                                  inception_3b/5x5[0][0]
#                                                                  inception_3b/pool_proj[0][0]
# __________________________________________________________________________________________________
# pool3/3x3_s2 (MaxPooling2D)     (None, 14, 14, 480)  0           inception_3b/output[0][0]
# __________________________________________________________________________________________________
# inception_4a/3x3_reduce (Conv2D (None, 14, 14, 96)   46176       pool3/3x3_s2[0][0]
# __________________________________________________________________________________________________
# inception_4a/5x5_reduce (Conv2D (None, 14, 14, 16)   7696        pool3/3x3_s2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_4 (ZeroPadding2D (None, 16, 16, 96)   0           inception_4a/3x3_reduce[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_5 (ZeroPadding2D (None, 18, 18, 16)   0           inception_4a/5x5_reduce[0][0]
# __________________________________________________________________________________________________
# inception_4a/pool (MaxPooling2D (None, 14, 14, 480)  0           pool3/3x3_s2[0][0]
# __________________________________________________________________________________________________
# inception_4a/1x1 (Conv2D)       (None, 14, 14, 192)  92352       pool3/3x3_s2[0][0]
# __________________________________________________________________________________________________
# inception_4a/3x3 (Conv2D)       (None, 14, 14, 208)  179920      zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# inception_4a/5x5 (Conv2D)       (None, 14, 14, 48)   19248       zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# inception_4a/pool_proj (Conv2D) (None, 14, 14, 64)   30784       inception_4a/pool[0][0]
# __________________________________________________________________________________________________
# inception_4a/output (Concatenat (None, 14, 14, 512)  0           inception_4a/1x1[0][0]
#                                                                  inception_4a/3x3[0][0]
#                                                                  inception_4a/5x5[0][0]
#                                                                  inception_4a/pool_proj[0][0]
# __________________________________________________________________________________________________
# inception_4b/3x3_reduce (Conv2D (None, 14, 14, 112)  57456       inception_4a/output[0][0]
# __________________________________________________________________________________________________
# inception_4b/5x5_reduce (Conv2D (None, 14, 14, 24)   12312       inception_4a/output[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_6 (ZeroPadding2D (None, 16, 16, 112)  0           inception_4b/3x3_reduce[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_7 (ZeroPadding2D (None, 18, 18, 24)   0           inception_4b/5x5_reduce[0][0]
# __________________________________________________________________________________________________
# inception_4b/pool (MaxPooling2D (None, 14, 14, 512)  0           inception_4a/output[0][0]
# __________________________________________________________________________________________________
# inception_4b/1x1 (Conv2D)       (None, 14, 14, 160)  82080       inception_4a/output[0][0]
# __________________________________________________________________________________________________
# inception_4b/3x3 (Conv2D)       (None, 14, 14, 224)  226016      zero_padding2d_6[0][0]
# __________________________________________________________________________________________________
# inception_4b/5x5 (Conv2D)       (None, 14, 14, 64)   38464       zero_padding2d_7[0][0]
# __________________________________________________________________________________________________
# inception_4b/pool_proj (Conv2D) (None, 14, 14, 64)   32832       inception_4b/pool[0][0]
# __________________________________________________________________________________________________
# inception_4b/output (Concatenat (None, 14, 14, 512)  0           inception_4b/1x1[0][0]
#                                                                  inception_4b/3x3[0][0]
#                                                                  inception_4b/5x5[0][0]
#                                                                  inception_4b/pool_proj[0][0]
# __________________________________________________________________________________________________
# inception_4c/3x3_reduce (Conv2D (None, 14, 14, 128)  65664       inception_4b/output[0][0]
# __________________________________________________________________________________________________
# inception_4c/5x5_reduce (Conv2D (None, 14, 14, 24)   12312       inception_4b/output[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_8 (ZeroPadding2D (None, 16, 16, 128)  0           inception_4c/3x3_reduce[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_9 (ZeroPadding2D (None, 18, 18, 24)   0           inception_4c/5x5_reduce[0][0]
# __________________________________________________________________________________________________
# inception_4c/pool (MaxPooling2D (None, 14, 14, 512)  0           inception_4b/output[0][0]
# __________________________________________________________________________________________________
# inception_4c/1x1 (Conv2D)       (None, 14, 14, 128)  65664       inception_4b/output[0][0]
# __________________________________________________________________________________________________
# inception_4c/3x3 (Conv2D)       (None, 14, 14, 256)  295168      zero_padding2d_8[0][0]
# __________________________________________________________________________________________________
# inception_4c/5x5 (Conv2D)       (None, 14, 14, 64)   38464       zero_padding2d_9[0][0]
# __________________________________________________________________________________________________
# inception_4c/pool_proj (Conv2D) (None, 14, 14, 64)   32832       inception_4c/pool[0][0]
# __________________________________________________________________________________________________
# inception_4c/output (Concatenat (None, 14, 14, 512)  0           inception_4c/1x1[0][0]
#                                                                  inception_4c/3x3[0][0]
#                                                                  inception_4c/5x5[0][0]
#                                                                  inception_4c/pool_proj[0][0]
# __________________________________________________________________________________________________
# inception_4d/3x3_reduce (Conv2D (None, 14, 14, 144)  73872       inception_4c/output[0][0]
# __________________________________________________________________________________________________
# inception_4d/5x5_reduce (Conv2D (None, 14, 14, 32)   16416       inception_4c/output[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_10 (ZeroPadding2 (None, 16, 16, 144)  0           inception_4d/3x3_reduce[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_11 (ZeroPadding2 (None, 18, 18, 32)   0           inception_4d/5x5_reduce[0][0]
# __________________________________________________________________________________________________
# inception_4d/pool (MaxPooling2D (None, 14, 14, 512)  0           inception_4c/output[0][0]
# __________________________________________________________________________________________________
# inception_4d/1x1 (Conv2D)       (None, 14, 14, 112)  57456       inception_4c/output[0][0]
# __________________________________________________________________________________________________
# inception_4d/3x3 (Conv2D)       (None, 14, 14, 288)  373536      zero_padding2d_10[0][0]
# __________________________________________________________________________________________________
# inception_4d/5x5 (Conv2D)       (None, 14, 14, 64)   51264       zero_padding2d_11[0][0]
# __________________________________________________________________________________________________
# inception_4d/pool_proj (Conv2D) (None, 14, 14, 64)   32832       inception_4d/pool[0][0]
# __________________________________________________________________________________________________
# inception_4d/output (Concatenat (None, 14, 14, 528)  0           inception_4d/1x1[0][0]
#                                                                  inception_4d/3x3[0][0]
#                                                                  inception_4d/5x5[0][0]
#                                                                  inception_4d/pool_proj[0][0]
# __________________________________________________________________________________________________
# inception_4e/3x3_reduce (Conv2D (None, 14, 14, 160)  84640       inception_4d/output[0][0]
# __________________________________________________________________________________________________
# inception_4e/5x5_reduce (Conv2D (None, 14, 14, 32)   16928       inception_4d/output[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_12 (ZeroPadding2 (None, 16, 16, 160)  0           inception_4e/3x3_reduce[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_13 (ZeroPadding2 (None, 18, 18, 32)   0           inception_4e/5x5_reduce[0][0]
# __________________________________________________________________________________________________
# inception_4e/pool (MaxPooling2D (None, 14, 14, 528)  0           inception_4d/output[0][0]
# __________________________________________________________________________________________________
# inception_4e/1x1 (Conv2D)       (None, 14, 14, 256)  135424      inception_4d/output[0][0]
# __________________________________________________________________________________________________
# inception_4e/3x3 (Conv2D)       (None, 14, 14, 320)  461120      zero_padding2d_12[0][0]
# __________________________________________________________________________________________________
# inception_4e/5x5 (Conv2D)       (None, 14, 14, 128)  102528      zero_padding2d_13[0][0]
# __________________________________________________________________________________________________
# inception_4e/pool_proj (Conv2D) (None, 14, 14, 128)  67712       inception_4e/pool[0][0]
# __________________________________________________________________________________________________
# inception_4e/output (Concatenat (None, 14, 14, 832)  0           inception_4e/1x1[0][0]
#                                                                  inception_4e/3x3[0][0]
#                                                                  inception_4e/5x5[0][0]
#                                                                  inception_4e/pool_proj[0][0]
# __________________________________________________________________________________________________
# pool4/3x3_s2 (MaxPooling2D)     (None, 7, 7, 832)    0           inception_4e/output[0][0]
# __________________________________________________________________________________________________
# inception_5a/3x3_reduce (Conv2D (None, 7, 7, 160)    133280      pool4/3x3_s2[0][0]
# __________________________________________________________________________________________________
# inception_5a/5x5_reduce (Conv2D (None, 7, 7, 32)     26656       pool4/3x3_s2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_14 (ZeroPadding2 (None, 9, 9, 160)    0           inception_5a/3x3_reduce[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_15 (ZeroPadding2 (None, 11, 11, 32)   0           inception_5a/5x5_reduce[0][0]
# __________________________________________________________________________________________________
# inception_5a/pool (MaxPooling2D (None, 7, 7, 832)    0           pool4/3x3_s2[0][0]
# __________________________________________________________________________________________________
# inception_5a/1x1 (Conv2D)       (None, 7, 7, 256)    213248      pool4/3x3_s2[0][0]
# __________________________________________________________________________________________________
# inception_5a/3x3 (Conv2D)       (None, 7, 7, 320)    461120      zero_padding2d_14[0][0]
# __________________________________________________________________________________________________
# inception_5a/5x5 (Conv2D)       (None, 7, 7, 128)    102528      zero_padding2d_15[0][0]
# __________________________________________________________________________________________________
# inception_5a/pool_proj (Conv2D) (None, 7, 7, 128)    106624      inception_5a/pool[0][0]
# __________________________________________________________________________________________________
# inception_5a/output (Concatenat (None, 7, 7, 832)    0           inception_5a/1x1[0][0]
#                                                                  inception_5a/3x3[0][0]
#                                                                  inception_5a/5x5[0][0]
#                                                                  inception_5a/pool_proj[0][0]
# __________________________________________________________________________________________________
# inception_5b/3x3_reduce (Conv2D (None, 7, 7, 192)    159936      inception_5a/output[0][0]
# __________________________________________________________________________________________________
# inception_5b/5x5_reduce (Conv2D (None, 7, 7, 48)     39984       inception_5a/output[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_16 (ZeroPadding2 (None, 9, 9, 192)    0           inception_5b/3x3_reduce[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_17 (ZeroPadding2 (None, 11, 11, 48)   0           inception_5b/5x5_reduce[0][0]
# __________________________________________________________________________________________________
# inception_5b/pool (MaxPooling2D (None, 7, 7, 832)    0           inception_5a/output[0][0]
# __________________________________________________________________________________________________
# loss1/ave_pool (AveragePooling2 (None, 4, 4, 512)    0           inception_4a/output[0][0]
# __________________________________________________________________________________________________
# loss2/ave_pool (AveragePooling2 (None, 4, 4, 528)    0           inception_4d/output[0][0]
# __________________________________________________________________________________________________
# inception_5b/1x1 (Conv2D)       (None, 7, 7, 384)    319872      inception_5a/output[0][0]
# __________________________________________________________________________________________________
# inception_5b/3x3 (Conv2D)       (None, 7, 7, 384)    663936      zero_padding2d_16[0][0]
# __________________________________________________________________________________________________
# inception_5b/5x5 (Conv2D)       (None, 7, 7, 128)    153728      zero_padding2d_17[0][0]
# __________________________________________________________________________________________________
# inception_5b/pool_proj (Conv2D) (None, 7, 7, 128)    106624      inception_5b/pool[0][0]
# __________________________________________________________________________________________________
# loss1/conv (Conv2D)             (None, 4, 4, 128)    65664       loss1/ave_pool[0][0]
# __________________________________________________________________________________________________
# loss2/conv (Conv2D)             (None, 4, 4, 128)    67712       loss2/ave_pool[0][0]
# __________________________________________________________________________________________________
# inception_5b/output (Concatenat (None, 7, 7, 1024)   0           inception_5b/1x1[0][0]
#                                                                  inception_5b/3x3[0][0]
#                                                                  inception_5b/5x5[0][0]
#                                                                  inception_5b/pool_proj[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 2048)         0           loss1/conv[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 2048)         0           loss2/conv[0][0]
# __________________________________________________________________________________________________
# pool5/7x7_s2 (AveragePooling2D) (None, 1, 1, 1024)   0           inception_5b/output[0][0]
# __________________________________________________________________________________________________
# loss1/fc (Dense)                (None, 1024)         2098176     flatten[0][0]
# __________________________________________________________________________________________________
# loss2/fc (Dense)                (None, 1024)         2098176     flatten_1[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 1024)         0           pool5/7x7_s2[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 1024)         0           loss1/fc[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 1024)         0           loss2/fc[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 1024)         0           flatten_2[0][0]
# __________________________________________________________________________________________________
# loss1/classifier (Dense)        (None, 257)          263425      dropout[0][0]
# __________________________________________________________________________________________________
# loss2/classifier (Dense)        (None, 257)          263425      dropout_1[0][0]
# __________________________________________________________________________________________________
# loss3/classifier (Dense)        (None, 257)          263425      dropout_2[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 257)          0           loss1/classifier[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 257)          0           loss2/classifier[0][0]
# __________________________________________________________________________________________________
# prob (Activation)               (None, 257)          0           loss3/classifier[0][0]
# ==================================================================================================
# Total params: 11,093,555
# Trainable params: 11,093,555
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# 폴더 생성

os.makedirs(os.path.join(dir,'model_output',number,model.name), exist_ok=True)
os.makedirs(os.path.join(dir,'train_valid_output',number), exist_ok=True)

# %%
# 참고 : https://github.com/OverLordGoldDragon/keras-adamw

import sys
sys.path.append('/content/drive/My Drive/Colab Notebooks/Paper')
import utils
import optimizers_v2
from utils import get_weight_decays, fill_dict_in_order
from utils import reset_seeds, K_eval
from optimizers_v2 import AdamW, NadamW, SGDW

# %%
optimizer = AdamW(model=model, use_cosine_annealing=True, total_iterations = len(x_train) // batch_sizes , eta_min = 1e-2)
#optimizer = Adam()
filepath =  os.path.join(dir,'model_output',number,model.name,'{epoch:03d}.h5')

callbacks_list = [ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_weights_only=False, save_best_only=True, mode='min'),
                  ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_weights_only=False, save_best_only=True, mode='max')
                  #ReduceLROnPlateau(monitor='val_loss',patience=3,factor=0.1,min_lr=1e-5),
                  LearningRateScheduler(lr_schedule,verbose=1)
                  ]
                  
model.compile(optimizer, loss=['categorical_crossentropy','categorical_crossentropy','categorical_crossentropy'], loss_weights=[0.3,0.3,1],
              metrics=['accuracy',macro_f1score,weighted_f1score])
# Out:
# Using cosine annealing learning rates

# %%
######## flow_from_directory
#history = model.fit_generator(generate_train_for_three(), steps_per_epoch=int(len(x_train)/batch_sizes),  validation_data = generate_valid_for_three(), epochs=epochs , verbose=1 , callbacks = callbacks_list,validation_steps=int(len(x_valid)/batch_sizes))
history = model.fit(generate_train_for_three(), steps_per_epoch=int(len(x_train)/batch_sizes),  validation_data = generate_valid_for_three(), epochs=epochs , verbose=1 , callbacks = callbacks_list , validation_steps=int(len(x_valid)/batch_sizes))
# Out:
# Found 24509 images belonging to 257 classes.
# Epoch 1/60
# 0.0(L1), 7.235745870133897e-07(L2) weight decay set for conv1/7x7_s2/kernel:0
# 0.0(L1), 7.235745870133897e-07(L2) weight decay set for conv2/3x3_reduce/kernel:0
# 0.0(L1), 7.235745870133897e-07(L2) weight decay set for conv2/3x3/kernel:0
# 0.0(L1), 7.235745870133897e-07(L2) weight decay set for inception_3a/3x3_reduce/kernel:0
# 0.0(L1), 7.235745870133897e-07(L2) weight decay set for inception_3a/5x5_reduce/kernel:0
# 0.0(L1), 7.235745870133897e-07(L2) weight decay set for inception_3a/1x1/kernel:0
# 0.0(L1), 7.235745870133897e-07(L2) weight decay set for inception_3a/3x3/kernel:0
# 0.0(L1), 7.235745870133897e-07(L2) weight decay set for inception_3a/5x5/kernel:0
# 0.0(L1), 7.235745870133897e-07(L2) weight decay set for inception_3a/pool_proj/kernel:0
# 0.0(L1), 7.235745870133897e-07(L2) weight decay set for inception_3b/3x3_reduce/kernel:0
# 0.0(L1), 7.235745870133897e-07(L2) weight decay set for inception_3b/5x5_reduce/kernel:0
# 0.0(L1), 7.235745870133897e-07(L2) weight decay set for inception_3b/1x1/kernel:0
# 0.0(L1), 7.235745870133897e-07(L2) weight decay set for inception_3b/3x3/kernel:0
# 0.0(L1), 7.235745870133897e-07(L2) weight decay set for inception_3b/5x5/kernel:0
# 0.0(L1), 7.235745870133897e-07(L2) weight decay set for inception_3b/pool_proj/kernel:0
# 0.0(L1), 7.235745870133897e-07(L2) weight decay set for inception_4a/3x3_reduce/kernel:0
# 0.0(L1), 7.235745870133897e-07(L2) weight decay set for inception_4a/5x5_reduce/kernel:0
# 0.0(L1), 7.235745870133897e-07(L2) weight decay set for inception_4a/1x1/kernel:0
# 0.0(L1), 7.235745870133897e-07(L2) weight decay set for inception_4a/3x3/kernel:0
# 0.0(L1), 7.235745870133897e-07(L2) weight decay set for inception_4a/5x5/kernel:0
# 0.0(L1), 7.235745870133897e-07(L2) weight decay set for inception_4a/pool_proj/kernel:0
# 0.0(L1), 7.235745870133897e-07(L2) weight decay set for inception_4b/3x3_reduce/kernel:0
# 0.0(L1), 7.235745870133897e-07(L2) weight decay set for inception_4b/5x5_reduce/kernel:0
# 0.0(L1), 7.235745870133897e-07(L2) weight decay set for inception_4b/1x1/kernel:0
# 0.0(L1), 7.235745870133897e-07(L2) weight decay set for inception_4b/3x3/kernel:0
# 0.0(L1), 7.235745870133897e-07(L2) weight decay set for inception_4b/5x5/kernel:0
# 0.0(L1), 7.235745870133897e-07(L2) weight decay set for inception_4b/pool_proj/kernel:0
# 0.0(L1), 7.235745870133897e-07(L2) weight decay set for inception_4c/3x3_reduce/kernel:0
# 0.0(L1), 7.235745870133897e-07(L2) weight decay set for inception_4c/5x5_reduce/kernel:0
# 0.0(L1), 7.235745870133897e-07(L2) weight decay set for inception_4c/1x1/kernel:0
# 0.0(L1), 7.235745870133897e-07(L2) weight decay set for inception_4c/3x3/kernel:0
# 0.0(L1), 7.235745870133897e-07(L2) weight decay set for inception_4c/5x5/kernel:0
# 0.0(L1), 7.235745870133897e-07(L2) weight decay set for inception_4c/pool_proj/kernel:0
# 0.0(L1), 7.235745870133897e-07(L2) weight decay set for inception_4d/3x3_reduce/kernel:0
# 0.0(L1), 7.235745870133897e-07(L2) weight decay set for inception_4d/5x5_reduce/kernel:0
# 0.0(L1), 7.235745870133897e-07(L2) weight decay set for inception_4d/1x1/kernel:0
# 0.0(L1), 7.235745870133897e-07(L2) weight decay set for inception_4d/3x3/kernel:0
# 0.0(L1), 7.235745870133897e-07(L2) weight decay set for inception_4d/5x5/kernel:0
# 0.0(L1), 7.235745870133897e-07(L2) weight decay set for inception_4d/pool_proj/kernel:0
# 0.0(L1), 7.235745870133897e-07(L2) weight decay set for inception_4e/3x3_reduce/kernel:0
# 0.0(L1), 7.235745870133897e-07(L2) weight decay set for inception_4e/5x5_reduce/kernel:0
# 0.0(L1), 7.235745870133897e-07(L2) weight decay set for inception_4e/1x1/kernel:0
# 0.0(L1), 7.235745870133897e-07(L2) weight decay set for inception_4e/3x3/kernel:0
# 0.0(L1), 7.235745870133897e-07(L2) weight decay set for inception_4e/5x5/kernel:0
# 0.0(L1), 7.235745870133897e-07(L2) weight decay set for inception_4e/pool_proj/kernel:0
# 0.0(L1), 7.235745870133897e-07(L2) weight decay set for inception_5a/3x3_reduce/kernel:0
# 0.0(L1), 7.235745870133897e-07(L2) weight decay set for inception_5a/5x5_reduce/kernel:0
# 0.0(L1), 7.235745870133897e-07(L2) weight decay set for inception_5a/1x1/kernel:0
# 0.0(L1), 7.235745870133897e-07(L2) weight decay set for inception_5a/3x3/kernel:0
# 0.0(L1), 7.235745870133897e-07(L2) weight decay set for inception_5a/5x5/kernel:0
# 0.0(L1), 7.235745870133897e-07(L2) weight decay set for inception_5a/pool_proj/kernel:0
# 0.0(L1), 7.235745870133897e-07(L2) weight decay set for inception_5b/3x3_reduce/kernel:0
# 0.0(L1), 7.235745870133897e-07(L2) weight decay set for inception_5b/5x5_reduce/kernel:0
# 0.0(L1), 7.235745870133897e-07(L2) weight decay set for inception_5b/1x1/kernel:0
# 0.0(L1), 7.235745870133897e-07(L2) weight decay set for inception_5b/3x3/kernel:0
# 0.0(L1), 7.235745870133897e-07(L2) weight decay set for inception_5b/5x5/kernel:0
# 0.0(L1), 7.235745870133897e-07(L2) weight decay set for inception_5b/pool_proj/kernel:0
# 0.0(L1), 7.235745870133897e-07(L2) weight decay set for loss1/conv/kernel:0
# 0.0(L1), 7.235745870133897e-07(L2) weight decay set for loss2/conv/kernel:0
# 0.0(L1), 7.235745870133897e-07(L2) weight decay set for loss1/fc/kernel:0
# 0.0(L1), 7.235745870133897e-07(L2) weight decay set for loss2/fc/kernel:0
# 191/191 [==============================] - ETA: 0s - loss: 8.6818 - activation_loss: 5.3993 - activation_1_loss: 5.4398 - prob_loss: 5.4301 - activation_accuracy: 0.0389 - activation_macro_f1score: 0.0000e+00 - activation_weighted_f1score: 0.0000e+00 - activation_1_accuracy: 0.0282 - activation_1_macro_f1score: 0.0000e+00 - activation_1_weighted_f1score: 0.0000e+00 - prob_accuracy: 0.0277 - prob_macro_f1score: 0.0000e+00 - prob_weighted_f1score: 0.0000e+00  Found 2980 images belonging to 257 classes.
#
# Epoch 00001: val_loss improved from inf to 8.55394, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_v1/001.h5
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 191/191 [==============================] - 13767s 72s/step - loss: 8.6818 - activation_loss: 5.3993 - activation_1_loss: 5.4398 - prob_loss: 5.4301 - activation_accuracy: 0.0389 - activation_macro_f1score: 0.0000e+00 - activation_weighted_f1score: 0.0000e+00 - activation_1_accuracy: 0.0282 - activation_1_macro_f1score: 0.0000e+00 - activation_1_weighted_f1score: 0.0000e+00 - prob_accuracy: 0.0277 - prob_macro_f1score: 0.0000e+00 - prob_weighted_f1score: 0.0000e+00 - val_loss: 8.5539 - val_activation_loss: 5.2456 - val_activation_1_loss: 5.3709 - val_prob_loss: 5.3690 - val_activation_accuracy: 0.0479 - val_activation_macro_f1score: 0.0000e+00 - val_activation_weighted_f1score: 0.0000e+00 - val_activation_1_accuracy: 0.0397 - val_activation_1_macro_f1score: 0.0000e+00 - val_activation_1_weighted_f1score: 0.0000e+00 - val_prob_accuracy: 0.0245 - val_prob_macro_f1score: 0.0000e+00 - val_prob_weighted_f1score: 0.0000e+00
# Epoch 2/60
# 191/191 [==============================] - ETA: 0s - loss: 8.3840 - activation_loss: 5.1272 - activation_1_loss: 5.2670 - prob_loss: 5.2658 - activation_accuracy: 0.0670 - activation_macro_f1score: 0.0020 - activation_weighted_f1score: 4.9187e-05 - activation_1_accuracy: 0.0539 - activation_1_macro_f1score: 9.9692e-04 - activation_1_weighted_f1score: 2.2175e-05 - prob_accuracy: 0.0520 - prob_macro_f1score: 6.0552e-04 - prob_weighted_f1score: 1.3081e-05
# Epoch 00002: val_loss improved from 8.55394 to 8.10001, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_v1/002.h5
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 191/191 [==============================] - 385s 2s/step - loss: 8.3840 - activation_loss: 5.1272 - activation_1_loss: 5.2670 - prob_loss: 5.2658 - activation_accuracy: 0.0670 - activation_macro_f1score: 0.0020 - activation_weighted_f1score: 4.9187e-05 - activation_1_accuracy: 0.0539 - activation_1_macro_f1score: 9.9692e-04 - activation_1_weighted_f1score: 2.2175e-05 - prob_accuracy: 0.0520 - prob_macro_f1score: 6.0552e-04 - prob_weighted_f1score: 1.3081e-05 - val_loss: 8.1000 - val_activation_loss: 4.8755 - val_activation_1_loss: 5.0966 - val_prob_loss: 5.1084 - val_activation_accuracy: 0.0859 - val_activation_macro_f1score: 0.0045 - val_activation_weighted_f1score: 1.0884e-04 - val_activation_1_accuracy: 0.0622 - val_activation_1_macro_f1score: 9.8203e-04 - val_activation_1_weighted_f1score: 1.7440e-05 - val_prob_accuracy: 0.0581 - val_prob_macro_f1score: 7.2826e-04 - val_prob_weighted_f1score: 1.5457e-05
# Epoch 3/60
# 191/191 [==============================] - ETA: 0s - loss: 8.0431 - activation_loss: 4.8890 - activation_1_loss: 5.0591 - prob_loss: 5.0586 - activation_accuracy: 0.0867 - activation_macro_f1score: 0.0045 - activation_weighted_f1score: 1.0293e-04 - activation_1_accuracy: 0.0705 - activation_1_macro_f1score: 0.0032 - activation_1_weighted_f1score: 7.4713e-05 - prob_accuracy: 0.0651 - prob_macro_f1score: 0.0023 - prob_weighted_f1score: 5.8660e-05
# Epoch 00003: val_loss improved from 8.10001 to 7.70640, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_v1/003.h5
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 191/191 [==============================] - 388s 2s/step - loss: 8.0431 - activation_loss: 4.8890 - activation_1_loss: 5.0591 - prob_loss: 5.0586 - activation_accuracy: 0.0867 - activation_macro_f1score: 0.0045 - activation_weighted_f1score: 1.0293e-04 - activation_1_accuracy: 0.0705 - activation_1_macro_f1score: 0.0032 - activation_1_weighted_f1score: 7.4713e-05 - prob_accuracy: 0.0651 - prob_macro_f1score: 0.0023 - prob_weighted_f1score: 5.8660e-05 - val_loss: 7.7064 - val_activation_loss: 4.6582 - val_activation_1_loss: 4.8383 - val_prob_loss: 4.8574 - val_activation_accuracy: 0.1036 - val_activation_macro_f1score: 0.0062 - val_activation_weighted_f1score: 1.5843e-04 - val_activation_1_accuracy: 0.0832 - val_activation_1_macro_f1score: 0.0060 - val_activation_1_weighted_f1score: 1.5179e-04 - val_prob_accuracy: 0.0778 - val_prob_macro_f1score: 0.0049 - val_prob_weighted_f1score: 1.2761e-04
# Epoch 4/60
# 191/191 [==============================] - ETA: 0s - loss: 7.6534 - activation_loss: 4.6757 - activation_1_loss: 4.8142 - prob_loss: 4.8064 - activation_accuracy: 0.1063 - activation_macro_f1score: 0.0067 - activation_weighted_f1score: 1.5590e-04 - activation_1_accuracy: 0.0922 - activation_1_macro_f1score: 0.0064 - activation_1_weighted_f1score: 1.5103e-04 - prob_accuracy: 0.0882 - prob_macro_f1score: 0.0059 - prob_weighted_f1score: 1.4167e-04
# Epoch 00004: val_loss improved from 7.70640 to 7.36767, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_v1/004.h5
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 191/191 [==============================] - 389s 2s/step - loss: 7.6534 - activation_loss: 4.6757 - activation_1_loss: 4.8142 - prob_loss: 4.8064 - activation_accuracy: 0.1063 - activation_macro_f1score: 0.0067 - activation_weighted_f1score: 1.5590e-04 - activation_1_accuracy: 0.0922 - activation_1_macro_f1score: 0.0064 - activation_1_weighted_f1score: 1.5103e-04 - prob_accuracy: 0.0882 - prob_macro_f1score: 0.0059 - prob_weighted_f1score: 1.4167e-04 - val_loss: 7.3677 - val_activation_loss: 4.4428 - val_activation_1_loss: 4.6021 - val_prob_loss: 4.6542 - val_activation_accuracy: 0.1376 - val_activation_macro_f1score: 0.0078 - val_activation_weighted_f1score: 1.8674e-04 - val_activation_1_accuracy: 0.1135 - val_activation_1_macro_f1score: 0.0077 - val_activation_1_weighted_f1score: 1.8607e-04 - val_prob_accuracy: 0.0985 - val_prob_macro_f1score: 0.0079 - val_prob_weighted_f1score: 1.9200e-04
# Epoch 5/60
# 191/191 [==============================] - ETA: 0s - loss: 7.3980 - activation_loss: 4.5225 - activation_1_loss: 4.6524 - prob_loss: 4.6456 - activation_accuracy: 0.1235 - activation_macro_f1score: 0.0085 - activation_weighted_f1score: 1.8927e-04 - activation_1_accuracy: 0.1044 - activation_1_macro_f1score: 0.0079 - activation_1_weighted_f1score: 1.8004e-04 - prob_accuracy: 0.1024 - prob_macro_f1score: 0.0080 - prob_weighted_f1score: 1.8174e-04
# Epoch 00005: val_loss improved from 7.36767 to 7.14234, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_v1/005.h5
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 191/191 [==============================] - 388s 2s/step - loss: 7.3980 - activation_loss: 4.5225 - activation_1_loss: 4.6524 - prob_loss: 4.6456 - activation_accuracy: 0.1235 - activation_macro_f1score: 0.0085 - activation_weighted_f1score: 1.8927e-04 - activation_1_accuracy: 0.1044 - activation_1_macro_f1score: 0.0079 - activation_1_weighted_f1score: 1.8004e-04 - prob_accuracy: 0.1024 - prob_macro_f1score: 0.0080 - prob_weighted_f1score: 1.8174e-04 - val_loss: 7.1423 - val_activation_loss: 4.3075 - val_activation_1_loss: 4.4559 - val_prob_loss: 4.5133 - val_activation_accuracy: 0.1522 - val_activation_macro_f1score: 0.0080 - val_activation_weighted_f1score: 2.0587e-04 - val_activation_1_accuracy: 0.1247 - val_activation_1_macro_f1score: 0.0087 - val_activation_1_weighted_f1score: 2.0730e-04 - val_prob_accuracy: 0.1124 - val_prob_macro_f1score: 0.0084 - val_prob_weighted_f1score: 2.0642e-04
# Epoch 6/60
# 191/191 [==============================] - ETA: 0s - loss: 7.2070 - activation_loss: 4.4012 - activation_1_loss: 4.5291 - prob_loss: 4.5279 - activation_accuracy: 0.1354 - activation_macro_f1score: 0.0097 - activation_weighted_f1score: 2.1271e-04 - activation_1_accuracy: 0.1165 - activation_1_macro_f1score: 0.0090 - activation_1_weighted_f1score: 2.0279e-04 - prob_accuracy: 0.1126 - prob_macro_f1score: 0.0089 - prob_weighted_f1score: 2.0237e-04
# Epoch 00006: val_loss improved from 7.14234 to 6.93439, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_v1/006.h5
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 191/191 [==============================] - 387s 2s/step - loss: 7.2070 - activation_loss: 4.4012 - activation_1_loss: 4.5291 - prob_loss: 4.5279 - activation_accuracy: 0.1354 - activation_macro_f1score: 0.0097 - activation_weighted_f1score: 2.1271e-04 - activation_1_accuracy: 0.1165 - activation_1_macro_f1score: 0.0090 - activation_1_weighted_f1score: 2.0279e-04 - prob_accuracy: 0.1126 - prob_macro_f1score: 0.0089 - prob_weighted_f1score: 2.0237e-04 - val_loss: 6.9344 - val_activation_loss: 4.1528 - val_activation_1_loss: 4.3199 - val_prob_loss: 4.3926 - val_activation_accuracy: 0.1743 - val_activation_macro_f1score: 0.0115 - val_activation_weighted_f1score: 2.4073e-04 - val_activation_1_accuracy: 0.1461 - val_activation_1_macro_f1score: 0.0104 - val_activation_1_weighted_f1score: 2.2973e-04 - val_prob_accuracy: 0.1338 - val_prob_macro_f1score: 0.0101 - val_prob_weighted_f1score: 2.2019e-04
# Epoch 7/60
# 191/191 [==============================] - ETA: 0s - loss: 6.9986 - activation_loss: 4.2856 - activation_1_loss: 4.4161 - prob_loss: 4.3881 - activation_accuracy: 0.1504 - activation_macro_f1score: 0.0111 - activation_weighted_f1score: 2.3724e-04 - activation_1_accuracy: 0.1298 - activation_1_macro_f1score: 0.0098 - activation_1_weighted_f1score: 2.1868e-04 - prob_accuracy: 0.1317 - prob_macro_f1score: 0.0101 - prob_weighted_f1score: 2.2539e-04
# Epoch 00007: val_loss improved from 6.93439 to 6.69725, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_v1/007.h5
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 191/191 [==============================] - 384s 2s/step - loss: 6.9986 - activation_loss: 4.2856 - activation_1_loss: 4.4161 - prob_loss: 4.3881 - activation_accuracy: 0.1504 - activation_macro_f1score: 0.0111 - activation_weighted_f1score: 2.3724e-04 - activation_1_accuracy: 0.1298 - activation_1_macro_f1score: 0.0098 - activation_1_weighted_f1score: 2.1868e-04 - prob_accuracy: 0.1317 - prob_macro_f1score: 0.0101 - prob_weighted_f1score: 2.2539e-04 - val_loss: 6.6972 - val_activation_loss: 4.0263 - val_activation_1_loss: 4.1945 - val_prob_loss: 4.2310 - val_activation_accuracy: 0.1916 - val_activation_macro_f1score: 0.0137 - val_activation_weighted_f1score: 2.6975e-04 - val_activation_1_accuracy: 0.1647 - val_activation_1_macro_f1score: 0.0114 - val_activation_1_weighted_f1score: 2.4558e-04 - val_prob_accuracy: 0.1637 - val_prob_macro_f1score: 0.0121 - val_prob_weighted_f1score: 2.5721e-04
# Epoch 8/60
# 191/191 [==============================] - ETA: 0s - loss: 6.7709 - activation_loss: 4.1529 - activation_1_loss: 4.2940 - prob_loss: 4.2369 - activation_accuracy: 0.1659 - activation_macro_f1score: 0.0132 - activation_weighted_f1score: 2.6813e-04 - activation_1_accuracy: 0.1434 - activation_1_macro_f1score: 0.0112 - activation_1_weighted_f1score: 2.4533e-04 - prob_accuracy: 0.1472 - prob_macro_f1score: 0.0119 - prob_weighted_f1score: 2.5450e-04
# Epoch 00008: val_loss improved from 6.69725 to 6.46616, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_v1/008.h5
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 191/191 [==============================] - 384s 2s/step - loss: 6.7709 - activation_loss: 4.1529 - activation_1_loss: 4.2940 - prob_loss: 4.2369 - activation_accuracy: 0.1659 - activation_macro_f1score: 0.0132 - activation_weighted_f1score: 2.6813e-04 - activation_1_accuracy: 0.1434 - activation_1_macro_f1score: 0.0112 - activation_1_weighted_f1score: 2.4533e-04 - prob_accuracy: 0.1472 - prob_macro_f1score: 0.0119 - prob_weighted_f1score: 2.5450e-04 - val_loss: 6.4662 - val_activation_loss: 3.8820 - val_activation_1_loss: 4.0666 - val_prob_loss: 4.0816 - val_activation_accuracy: 0.2120 - val_activation_macro_f1score: 0.0187 - val_activation_weighted_f1score: 3.3742e-04 - val_activation_1_accuracy: 0.1855 - val_activation_1_macro_f1score: 0.0134 - val_activation_1_weighted_f1score: 2.7269e-04 - val_prob_accuracy: 0.1793 - val_prob_macro_f1score: 0.0141 - val_prob_weighted_f1score: 2.7915e-04
# Epoch 9/60
# 191/191 [==============================] - ETA: 0s - loss: 6.5656 - activation_loss: 4.0286 - activation_1_loss: 4.1793 - prob_loss: 4.1032 - activation_accuracy: 0.1830 - activation_macro_f1score: 0.0158 - activation_weighted_f1score: 3.0453e-04 - activation_1_accuracy: 0.1595 - activation_1_macro_f1score: 0.0132 - activation_1_weighted_f1score: 2.7365e-04 - prob_accuracy: 0.1649 - prob_macro_f1score: 0.0141 - prob_weighted_f1score: 2.8389e-04
# Epoch 00009: val_loss improved from 6.46616 to 6.24788, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_v1/009.h5
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 191/191 [==============================] - 385s 2s/step - loss: 6.5656 - activation_loss: 4.0286 - activation_1_loss: 4.1793 - prob_loss: 4.1032 - activation_accuracy: 0.1830 - activation_macro_f1score: 0.0158 - activation_weighted_f1score: 3.0453e-04 - activation_1_accuracy: 0.1595 - activation_1_macro_f1score: 0.0132 - activation_1_weighted_f1score: 2.7365e-04 - prob_accuracy: 0.1649 - prob_macro_f1score: 0.0141 - prob_weighted_f1score: 2.8389e-04 - val_loss: 6.2479 - val_activation_loss: 3.7573 - val_activation_1_loss: 3.9406 - val_prob_loss: 3.9385 - val_activation_accuracy: 0.2344 - val_activation_macro_f1score: 0.0217 - val_activation_weighted_f1score: 3.7631e-04 - val_activation_1_accuracy: 0.1940 - val_activation_1_macro_f1score: 0.0163 - val_activation_1_weighted_f1score: 3.1043e-04 - val_prob_accuracy: 0.2007 - val_prob_macro_f1score: 0.0163 - val_prob_weighted_f1score: 3.1322e-04
# Epoch 10/60
# 191/191 [==============================] - ETA: 0s - loss: 6.3627 - activation_loss: 3.9143 - activation_1_loss: 4.0773 - prob_loss: 3.9652 - activation_accuracy: 0.2009 - activation_macro_f1score: 0.0182 - activation_weighted_f1score: 3.2899e-04 - activation_1_accuracy: 0.1733 - activation_1_macro_f1score: 0.0148 - activation_1_weighted_f1score: 2.9468e-04 - prob_accuracy: 0.1814 - prob_macro_f1score: 0.0164 - prob_weighted_f1score: 3.1226e-04
# Epoch 00010: val_loss improved from 6.24788 to 6.04715, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_v1/010.h5
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 191/191 [==============================] - 385s 2s/step - loss: 6.3627 - activation_loss: 3.9143 - activation_1_loss: 4.0773 - prob_loss: 3.9652 - activation_accuracy: 0.2009 - activation_macro_f1score: 0.0182 - activation_weighted_f1score: 3.2899e-04 - activation_1_accuracy: 0.1733 - activation_1_macro_f1score: 0.0148 - activation_1_weighted_f1score: 2.9468e-04 - prob_accuracy: 0.1814 - prob_macro_f1score: 0.0164 - prob_weighted_f1score: 3.1226e-04 - val_loss: 6.0472 - val_activation_loss: 3.6379 - val_activation_1_loss: 3.8217 - val_prob_loss: 3.8093 - val_activation_accuracy: 0.2503 - val_activation_macro_f1score: 0.0247 - val_activation_weighted_f1score: 4.1024e-04 - val_activation_1_accuracy: 0.2137 - val_activation_1_macro_f1score: 0.0193 - val_activation_1_weighted_f1score: 3.4462e-04 - val_prob_accuracy: 0.2174 - val_prob_macro_f1score: 0.0200 - val_prob_weighted_f1score: 3.5718e-04
# Epoch 11/60
# 191/191 [==============================] - ETA: 0s - loss: 6.1802 - activation_loss: 3.8211 - activation_1_loss: 3.9697 - prob_loss: 3.8430 - activation_accuracy: 0.2109 - activation_macro_f1score: 0.0201 - activation_weighted_f1score: 3.5043e-04 - activation_1_accuracy: 0.1860 - activation_1_macro_f1score: 0.0167 - activation_1_weighted_f1score: 3.1411e-04 - prob_accuracy: 0.1991 - prob_macro_f1score: 0.0190 - prob_weighted_f1score: 3.4018e-04
# Epoch 00011: val_loss improved from 6.04715 to 5.89729, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_v1/011.h5
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 191/191 [==============================] - 385s 2s/step - loss: 6.1802 - activation_loss: 3.8211 - activation_1_loss: 3.9697 - prob_loss: 3.8430 - activation_accuracy: 0.2109 - activation_macro_f1score: 0.0201 - activation_weighted_f1score: 3.5043e-04 - activation_1_accuracy: 0.1860 - activation_1_macro_f1score: 0.0167 - activation_1_weighted_f1score: 3.1411e-04 - prob_accuracy: 0.1991 - prob_macro_f1score: 0.0190 - prob_weighted_f1score: 3.4018e-04 - val_loss: 5.8973 - val_activation_loss: 3.5535 - val_activation_1_loss: 3.7320 - val_prob_loss: 3.7116 - val_activation_accuracy: 0.2643 - val_activation_macro_f1score: 0.0277 - val_activation_weighted_f1score: 4.5383e-04 - val_activation_1_accuracy: 0.2344 - val_activation_1_macro_f1score: 0.0209 - val_activation_1_weighted_f1score: 3.6884e-04 - val_prob_accuracy: 0.2289 - val_prob_macro_f1score: 0.0240 - val_prob_weighted_f1score: 4.0193e-04
# Epoch 12/60
# 191/191 [==============================] - ETA: 0s - loss: 5.9678 - activation_loss: 3.7124 - activation_1_loss: 3.8589 - prob_loss: 3.6965 - activation_accuracy: 0.2267 - activation_macro_f1score: 0.0229 - activation_weighted_f1score: 3.9531e-04 - activation_1_accuracy: 0.2029 - activation_1_macro_f1score: 0.0193 - activation_1_weighted_f1score: 3.5479e-04 - prob_accuracy: 0.2209 - prob_macro_f1score: 0.0230 - prob_weighted_f1score: 3.9845e-04
# Epoch 00012: val_loss improved from 5.89729 to 5.70832, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_v1/012.h5
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 191/191 [==============================] - 383s 2s/step - loss: 5.9678 - activation_loss: 3.7124 - activation_1_loss: 3.8589 - prob_loss: 3.6965 - activation_accuracy: 0.2267 - activation_macro_f1score: 0.0229 - activation_weighted_f1score: 3.9531e-04 - activation_1_accuracy: 0.2029 - activation_1_macro_f1score: 0.0193 - activation_1_weighted_f1score: 3.5479e-04 - prob_accuracy: 0.2209 - prob_macro_f1score: 0.0230 - prob_weighted_f1score: 3.9845e-04 - val_loss: 5.7083 - val_activation_loss: 3.4623 - val_activation_1_loss: 3.6142 - val_prob_loss: 3.5854 - val_activation_accuracy: 0.2717 - val_activation_macro_f1score: 0.0330 - val_activation_weighted_f1score: 4.9333e-04 - val_activation_1_accuracy: 0.2514 - val_activation_1_macro_f1score: 0.0262 - val_activation_1_weighted_f1score: 4.2136e-04 - val_prob_accuracy: 0.2490 - val_prob_macro_f1score: 0.0303 - val_prob_weighted_f1score: 4.6578e-04
# Epoch 13/60
# 191/191 [==============================] - ETA: 0s - loss: 5.7901 - activation_loss: 3.6256 - activation_1_loss: 3.7541 - prob_loss: 3.5763 - activation_accuracy: 0.2378 - activation_macro_f1score: 0.0260 - activation_weighted_f1score: 4.2695e-04 - activation_1_accuracy: 0.2172 - activation_1_macro_f1score: 0.0224 - activation_1_weighted_f1score: 3.8793e-04 - prob_accuracy: 0.2369 - prob_macro_f1score: 0.0268 - prob_weighted_f1score: 4.3567e-04
# Epoch 00013: val_loss improved from 5.70832 to 5.56690, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_v1/013.h5
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 191/191 [==============================] - 384s 2s/step - loss: 5.7901 - activation_loss: 3.6256 - activation_1_loss: 3.7541 - prob_loss: 3.5763 - activation_accuracy: 0.2378 - activation_macro_f1score: 0.0260 - activation_weighted_f1score: 4.2695e-04 - activation_1_accuracy: 0.2172 - activation_1_macro_f1score: 0.0224 - activation_1_weighted_f1score: 3.8793e-04 - prob_accuracy: 0.2369 - prob_macro_f1score: 0.0268 - prob_weighted_f1score: 4.3567e-04 - val_loss: 5.5669 - val_activation_loss: 3.3776 - val_activation_1_loss: 3.5299 - val_prob_loss: 3.4947 - val_activation_accuracy: 0.2829 - val_activation_macro_f1score: 0.0360 - val_activation_weighted_f1score: 5.2669e-04 - val_activation_1_accuracy: 0.2585 - val_activation_1_macro_f1score: 0.0301 - val_activation_1_weighted_f1score: 4.6971e-04 - val_prob_accuracy: 0.2643 - val_prob_macro_f1score: 0.0332 - val_prob_weighted_f1score: 4.9598e-04
# Epoch 14/60
# 191/191 [==============================] - ETA: 0s - loss: 5.6002 - activation_loss: 3.5244 - activation_1_loss: 3.6458 - prob_loss: 3.4492 - activation_accuracy: 0.2531 - activation_macro_f1score: 0.0297 - activation_weighted_f1score: 4.5969e-04 - activation_1_accuracy: 0.2311 - activation_1_macro_f1score: 0.0251 - activation_1_weighted_f1score: 4.1628e-04 - prob_accuracy: 0.2540 - prob_macro_f1score: 0.0311 - prob_weighted_f1score: 4.7937e-04
# Epoch 00014: val_loss improved from 5.56690 to 5.43138, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_v1/014.h5
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 191/191 [==============================] - 385s 2s/step - loss: 5.6002 - activation_loss: 3.5244 - activation_1_loss: 3.6458 - prob_loss: 3.4492 - activation_accuracy: 0.2531 - activation_macro_f1score: 0.0297 - activation_weighted_f1score: 4.5969e-04 - activation_1_accuracy: 0.2311 - activation_1_macro_f1score: 0.0251 - activation_1_weighted_f1score: 4.1628e-04 - prob_accuracy: 0.2540 - prob_macro_f1score: 0.0311 - prob_weighted_f1score: 4.7937e-04 - val_loss: 5.4314 - val_activation_loss: 3.2894 - val_activation_1_loss: 3.4424 - val_prob_loss: 3.4118 - val_activation_accuracy: 0.3037 - val_activation_macro_f1score: 0.0388 - val_activation_weighted_f1score: 5.8183e-04 - val_activation_1_accuracy: 0.2748 - val_activation_1_macro_f1score: 0.0334 - val_activation_1_weighted_f1score: 5.2040e-04 - val_prob_accuracy: 0.2809 - val_prob_macro_f1score: 0.0397 - val_prob_weighted_f1score: 5.8168e-04
# Epoch 15/60
# 191/191 [==============================] - ETA: 0s - loss: 5.4185 - activation_loss: 3.4342 - activation_1_loss: 3.5503 - prob_loss: 3.3231 - activation_accuracy: 0.2687 - activation_macro_f1score: 0.0317 - activation_weighted_f1score: 4.9679e-04 - activation_1_accuracy: 0.2445 - activation_1_macro_f1score: 0.0283 - activation_1_weighted_f1score: 4.6036e-04 - prob_accuracy: 0.2752 - prob_macro_f1score: 0.0353 - prob_weighted_f1score: 5.3292e-04
# Epoch 00015: val_loss improved from 5.43138 to 5.27177, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_v1/015.h5
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 191/191 [==============================] - 384s 2s/step - loss: 5.4185 - activation_loss: 3.4342 - activation_1_loss: 3.5503 - prob_loss: 3.3231 - activation_accuracy: 0.2687 - activation_macro_f1score: 0.0317 - activation_weighted_f1score: 4.9679e-04 - activation_1_accuracy: 0.2445 - activation_1_macro_f1score: 0.0283 - activation_1_weighted_f1score: 4.6036e-04 - prob_accuracy: 0.2752 - prob_macro_f1score: 0.0353 - prob_weighted_f1score: 5.3292e-04 - val_loss: 5.2718 - val_activation_loss: 3.2002 - val_activation_1_loss: 3.3442 - val_prob_loss: 3.3084 - val_activation_accuracy: 0.3149 - val_activation_macro_f1score: 0.0430 - val_activation_weighted_f1score: 6.0474e-04 - val_activation_1_accuracy: 0.2894 - val_activation_1_macro_f1score: 0.0387 - val_activation_1_weighted_f1score: 5.5630e-04 - val_prob_accuracy: 0.2989 - val_prob_macro_f1score: 0.0428 - val_prob_weighted_f1score: 6.1185e-04
# Epoch 16/60
# 191/191 [==============================] - ETA: 0s - loss: 5.2490 - activation_loss: 3.3463 - activation_1_loss: 3.4556 - prob_loss: 3.2084 - activation_accuracy: 0.2749 - activation_macro_f1score: 0.0365 - activation_weighted_f1score: 5.4409e-04 - activation_1_accuracy: 0.2568 - activation_1_macro_f1score: 0.0325 - activation_1_weighted_f1score: 5.0478e-04 - prob_accuracy: 0.2943 - prob_macro_f1score: 0.0416 - prob_weighted_f1score: 5.9904e-04
# Epoch 00016: val_loss improved from 5.27177 to 5.13874, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_v1/016.h5
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 191/191 [==============================] - 383s 2s/step - loss: 5.2490 - activation_loss: 3.3463 - activation_1_loss: 3.4556 - prob_loss: 3.2084 - activation_accuracy: 0.2749 - activation_macro_f1score: 0.0365 - activation_weighted_f1score: 5.4409e-04 - activation_1_accuracy: 0.2568 - activation_1_macro_f1score: 0.0325 - activation_1_weighted_f1score: 5.0478e-04 - prob_accuracy: 0.2943 - prob_macro_f1score: 0.0416 - prob_weighted_f1score: 5.9904e-04 - val_loss: 5.1387 - val_activation_loss: 3.1311 - val_activation_1_loss: 3.2637 - val_prob_loss: 3.2203 - val_activation_accuracy: 0.3332 - val_activation_macro_f1score: 0.0456 - val_activation_weighted_f1score: 6.6094e-04 - val_activation_1_accuracy: 0.3050 - val_activation_1_macro_f1score: 0.0403 - val_activation_1_weighted_f1score: 5.9762e-04 - val_prob_accuracy: 0.3081 - val_prob_macro_f1score: 0.0495 - val_prob_weighted_f1score: 6.9311e-04
# Epoch 17/60
# 191/191 [==============================] - ETA: 0s - loss: 5.1176 - activation_loss: 3.2838 - activation_1_loss: 3.3917 - prob_loss: 3.1150 - activation_accuracy: 0.2894 - activation_macro_f1score: 0.0378 - activation_weighted_f1score: 5.6032e-04 - activation_1_accuracy: 0.2669 - activation_1_macro_f1score: 0.0341 - activation_1_weighted_f1score: 5.2156e-04 - prob_accuracy: 0.3072 - prob_macro_f1score: 0.0457 - prob_weighted_f1score: 6.4488e-04
# Epoch 00017: val_loss improved from 5.13874 to 5.03173, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_v1/017.h5
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 191/191 [==============================] - 384s 2s/step - loss: 5.1176 - activation_loss: 3.2838 - activation_1_loss: 3.3917 - prob_loss: 3.1150 - activation_accuracy: 0.2894 - activation_macro_f1score: 0.0378 - activation_weighted_f1score: 5.6032e-04 - activation_1_accuracy: 0.2669 - activation_1_macro_f1score: 0.0341 - activation_1_weighted_f1score: 5.2156e-04 - prob_accuracy: 0.3072 - prob_macro_f1score: 0.0457 - prob_weighted_f1score: 6.4488e-04 - val_loss: 5.0317 - val_activation_loss: 3.0655 - val_activation_1_loss: 3.1908 - val_prob_loss: 3.1548 - val_activation_accuracy: 0.3380 - val_activation_macro_f1score: 0.0510 - val_activation_weighted_f1score: 6.8144e-04 - val_activation_1_accuracy: 0.3217 - val_activation_1_macro_f1score: 0.0470 - val_activation_1_weighted_f1score: 6.3431e-04 - val_prob_accuracy: 0.3230 - val_prob_macro_f1score: 0.0566 - val_prob_weighted_f1score: 7.3801e-04
# Epoch 18/60
# 191/191 [==============================] - ETA: 0s - loss: 4.9501 - activation_loss: 3.2042 - activation_1_loss: 3.2939 - prob_loss: 3.0007 - activation_accuracy: 0.3011 - activation_macro_f1score: 0.0414 - activation_weighted_f1score: 6.0894e-04 - activation_1_accuracy: 0.2838 - activation_1_macro_f1score: 0.0385 - activation_1_weighted_f1score: 5.7555e-04 - prob_accuracy: 0.3255 - prob_macro_f1score: 0.0498 - prob_weighted_f1score: 7.0154e-04
# Epoch 00018: val_loss improved from 5.03173 to 4.94449, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_v1/018.h5
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 191/191 [==============================] - 385s 2s/step - loss: 4.9501 - activation_loss: 3.2042 - activation_1_loss: 3.2939 - prob_loss: 3.0007 - activation_accuracy: 0.3011 - activation_macro_f1score: 0.0414 - activation_weighted_f1score: 6.0894e-04 - activation_1_accuracy: 0.2838 - activation_1_macro_f1score: 0.0385 - activation_1_weighted_f1score: 5.7555e-04 - prob_accuracy: 0.3255 - prob_macro_f1score: 0.0498 - prob_weighted_f1score: 7.0154e-04 - val_loss: 4.9445 - val_activation_loss: 3.0253 - val_activation_1_loss: 3.1389 - val_prob_loss: 3.0952 - val_activation_accuracy: 0.3434 - val_activation_macro_f1score: 0.0562 - val_activation_weighted_f1score: 7.5777e-04 - val_activation_1_accuracy: 0.3308 - val_activation_1_macro_f1score: 0.0501 - val_activation_1_weighted_f1score: 6.9312e-04 - val_prob_accuracy: 0.3359 - val_prob_macro_f1score: 0.0609 - val_prob_weighted_f1score: 7.9763e-04
# Epoch 19/60
# 191/191 [==============================] - ETA: 0s - loss: 4.8198 - activation_loss: 3.1293 - activation_1_loss: 3.2240 - prob_loss: 2.9137 - activation_accuracy: 0.3101 - activation_macro_f1score: 0.0455 - activation_weighted_f1score: 6.4878e-04 - activation_1_accuracy: 0.2958 - activation_1_macro_f1score: 0.0425 - activation_1_weighted_f1score: 6.1893e-04 - prob_accuracy: 0.3419 - prob_macro_f1score: 0.0553 - prob_weighted_f1score: 7.5353e-04
# Epoch 00019: val_loss improved from 4.94449 to 4.86979, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_v1/019.h5
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 191/191 [==============================] - 385s 2s/step - loss: 4.8198 - activation_loss: 3.1293 - activation_1_loss: 3.2240 - prob_loss: 2.9137 - activation_accuracy: 0.3101 - activation_macro_f1score: 0.0455 - activation_weighted_f1score: 6.4878e-04 - activation_1_accuracy: 0.2958 - activation_1_macro_f1score: 0.0425 - activation_1_weighted_f1score: 6.1893e-04 - prob_accuracy: 0.3419 - prob_macro_f1score: 0.0553 - prob_weighted_f1score: 7.5353e-04 - val_loss: 4.8698 - val_activation_loss: 2.9692 - val_activation_1_loss: 3.0963 - val_prob_loss: 3.0502 - val_activation_accuracy: 0.3553 - val_activation_macro_f1score: 0.0589 - val_activation_weighted_f1score: 7.9233e-04 - val_activation_1_accuracy: 0.3376 - val_activation_1_macro_f1score: 0.0525 - val_activation_1_weighted_f1score: 7.1905e-04 - val_prob_accuracy: 0.3448 - val_prob_macro_f1score: 0.0633 - val_prob_weighted_f1score: 8.2291e-04
# Epoch 20/60
# 191/191 [==============================] - ETA: 0s - loss: 4.6598 - activation_loss: 3.0683 - activation_1_loss: 3.1311 - prob_loss: 2.7999 - activation_accuracy: 0.3253 - activation_macro_f1score: 0.0493 - activation_weighted_f1score: 6.8837e-04 - activation_1_accuracy: 0.3087 - activation_1_macro_f1score: 0.0463 - activation_1_weighted_f1score: 6.5557e-04 - prob_accuracy: 0.3628 - prob_macro_f1score: 0.0638 - prob_weighted_f1score: 8.3799e-04
# Epoch 00020: val_loss improved from 4.86979 to 4.71554, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_v1/020.h5
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 191/191 [==============================] - 384s 2s/step - loss: 4.6598 - activation_loss: 3.0683 - activation_1_loss: 3.1311 - prob_loss: 2.7999 - activation_accuracy: 0.3253 - activation_macro_f1score: 0.0493 - activation_weighted_f1score: 6.8837e-04 - activation_1_accuracy: 0.3087 - activation_1_macro_f1score: 0.0463 - activation_1_weighted_f1score: 6.5557e-04 - prob_accuracy: 0.3628 - prob_macro_f1score: 0.0638 - prob_weighted_f1score: 8.3799e-04 - val_loss: 4.7155 - val_activation_loss: 2.8935 - val_activation_1_loss: 2.9926 - val_prob_loss: 2.9497 - val_activation_accuracy: 0.3747 - val_activation_macro_f1score: 0.0625 - val_activation_weighted_f1score: 8.0045e-04 - val_activation_1_accuracy: 0.3492 - val_activation_1_macro_f1score: 0.0589 - val_activation_1_weighted_f1score: 7.6606e-04 - val_prob_accuracy: 0.3607 - val_prob_macro_f1score: 0.0716 - val_prob_weighted_f1score: 8.9169e-04
# Epoch 21/60
# 191/191 [==============================] - ETA: 0s - loss: 4.5363 - activation_loss: 3.0053 - activation_1_loss: 3.0636 - prob_loss: 2.7156 - activation_accuracy: 0.3372 - activation_macro_f1score: 0.0514 - activation_weighted_f1score: 7.1060e-04 - activation_1_accuracy: 0.3200 - activation_1_macro_f1score: 0.0502 - activation_1_weighted_f1score: 6.9974e-04 - prob_accuracy: 0.3773 - prob_macro_f1score: 0.0687 - prob_weighted_f1score: 8.8835e-04
# Epoch 00021: val_loss improved from 4.71554 to 4.65220, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_v1/021.h5
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 191/191 [==============================] - 383s 2s/step - loss: 4.5363 - activation_loss: 3.0053 - activation_1_loss: 3.0636 - prob_loss: 2.7156 - activation_accuracy: 0.3372 - activation_macro_f1score: 0.0514 - activation_weighted_f1score: 7.1060e-04 - activation_1_accuracy: 0.3200 - activation_1_macro_f1score: 0.0502 - activation_1_weighted_f1score: 6.9974e-04 - prob_accuracy: 0.3773 - prob_macro_f1score: 0.0687 - prob_weighted_f1score: 8.8835e-04 - val_loss: 4.6522 - val_activation_loss: 2.8606 - val_activation_1_loss: 2.9578 - val_prob_loss: 2.9067 - val_activation_accuracy: 0.3869 - val_activation_macro_f1score: 0.0656 - val_activation_weighted_f1score: 8.6961e-04 - val_activation_1_accuracy: 0.3655 - val_activation_1_macro_f1score: 0.0614 - val_activation_1_weighted_f1score: 8.2269e-04 - val_prob_accuracy: 0.3794 - val_prob_macro_f1score: 0.0747 - val_prob_weighted_f1score: 9.7529e-04
# Epoch 22/60
# 191/191 [==============================] - ETA: 0s - loss: 4.4186 - activation_loss: 2.9410 - activation_1_loss: 3.0093 - prob_loss: 2.6335 - activation_accuracy: 0.3446 - activation_macro_f1score: 0.0542 - activation_weighted_f1score: 7.4990e-04 - activation_1_accuracy: 0.3270 - activation_1_macro_f1score: 0.0508 - activation_1_weighted_f1score: 7.1701e-04 - prob_accuracy: 0.3914 - prob_macro_f1score: 0.0740 - prob_weighted_f1score: 9.5638e-04
# Epoch 00022: val_loss improved from 4.65220 to 4.57981, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_v1/022.h5
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 191/191 [==============================] - 384s 2s/step - loss: 4.4186 - activation_loss: 2.9410 - activation_1_loss: 3.0093 - prob_loss: 2.6335 - activation_accuracy: 0.3446 - activation_macro_f1score: 0.0542 - activation_weighted_f1score: 7.4990e-04 - activation_1_accuracy: 0.3270 - activation_1_macro_f1score: 0.0508 - activation_1_weighted_f1score: 7.1701e-04 - prob_accuracy: 0.3914 - prob_macro_f1score: 0.0740 - prob_weighted_f1score: 9.5638e-04 - val_loss: 4.5798 - val_activation_loss: 2.8173 - val_activation_1_loss: 2.9089 - val_prob_loss: 2.8619 - val_activation_accuracy: 0.3845 - val_activation_macro_f1score: 0.0697 - val_activation_weighted_f1score: 9.0955e-04 - val_activation_1_accuracy: 0.3692 - val_activation_1_macro_f1score: 0.0640 - val_activation_1_weighted_f1score: 8.5414e-04 - val_prob_accuracy: 0.3838 - val_prob_macro_f1score: 0.0770 - val_prob_weighted_f1score: 9.7737e-04
# Epoch 23/60
# 191/191 [==============================] - ETA: 0s - loss: 4.3064 - activation_loss: 2.8996 - activation_1_loss: 2.9451 - prob_loss: 2.5531 - activation_accuracy: 0.3500 - activation_macro_f1score: 0.0586 - activation_weighted_f1score: 7.8054e-04 - activation_1_accuracy: 0.3412 - activation_1_macro_f1score: 0.0570 - activation_1_weighted_f1score: 7.6421e-04 - prob_accuracy: 0.4050 - prob_macro_f1score: 0.0811 - prob_weighted_f1score: 0.0010
# Epoch 00023: val_loss improved from 4.57981 to 4.56790, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_v1/023.h5
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 191/191 [==============================] - 383s 2s/step - loss: 4.3064 - activation_loss: 2.8996 - activation_1_loss: 2.9451 - prob_loss: 2.5531 - activation_accuracy: 0.3500 - activation_macro_f1score: 0.0586 - activation_weighted_f1score: 7.8054e-04 - activation_1_accuracy: 0.3412 - activation_1_macro_f1score: 0.0570 - activation_1_weighted_f1score: 7.6421e-04 - prob_accuracy: 0.4050 - prob_macro_f1score: 0.0811 - prob_weighted_f1score: 0.0010 - val_loss: 4.5679 - val_activation_loss: 2.8058 - val_activation_1_loss: 2.8921 - val_prob_loss: 2.8585 - val_activation_accuracy: 0.3849 - val_activation_macro_f1score: 0.0698 - val_activation_weighted_f1score: 9.1757e-04 - val_activation_1_accuracy: 0.3719 - val_activation_1_macro_f1score: 0.0675 - val_activation_1_weighted_f1score: 8.9703e-04 - val_prob_accuracy: 0.3947 - val_prob_macro_f1score: 0.0819 - val_prob_weighted_f1score: 0.0010
# Epoch 24/60
# 191/191 [==============================] - ETA: 0s - loss: 4.1472 - activation_loss: 2.8187 - activation_1_loss: 2.8548 - prob_loss: 2.4452 - activation_accuracy: 0.3659 - activation_macro_f1score: 0.0629 - activation_weighted_f1score: 8.2963e-04 - activation_1_accuracy: 0.3592 - activation_1_macro_f1score: 0.0621 - activation_1_weighted_f1score: 8.2226e-04 - prob_accuracy: 0.4279 - prob_macro_f1score: 0.0876 - prob_weighted_f1score: 0.0011
# Epoch 00024: val_loss improved from 4.56790 to 4.49557, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_v1/024.h5
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 191/191 [==============================] - 382s 2s/step - loss: 4.1472 - activation_loss: 2.8187 - activation_1_loss: 2.8548 - prob_loss: 2.4452 - activation_accuracy: 0.3659 - activation_macro_f1score: 0.0629 - activation_weighted_f1score: 8.2963e-04 - activation_1_accuracy: 0.3592 - activation_1_macro_f1score: 0.0621 - activation_1_weighted_f1score: 8.2226e-04 - prob_accuracy: 0.4279 - prob_macro_f1score: 0.0876 - prob_weighted_f1score: 0.0011 - val_loss: 4.4956 - val_activation_loss: 2.7742 - val_activation_1_loss: 2.8356 - val_prob_loss: 2.8126 - val_activation_accuracy: 0.3974 - val_activation_macro_f1score: 0.0736 - val_activation_weighted_f1score: 9.4334e-04 - val_activation_1_accuracy: 0.3736 - val_activation_1_macro_f1score: 0.0685 - val_activation_1_weighted_f1score: 9.0522e-04 - val_prob_accuracy: 0.3957 - val_prob_macro_f1score: 0.0859 - val_prob_weighted_f1score: 0.0011
# Epoch 25/60
# 191/191 [==============================] - ETA: 0s - loss: 4.0617 - activation_loss: 2.7834 - activation_1_loss: 2.8060 - prob_loss: 2.3848 - activation_accuracy: 0.3696 - activation_macro_f1score: 0.0646 - activation_weighted_f1score: 8.5522e-04 - activation_1_accuracy: 0.3622 - activation_1_macro_f1score: 0.0641 - activation_1_weighted_f1score: 8.5026e-04 - prob_accuracy: 0.4378 - prob_macro_f1score: 0.0926 - prob_weighted_f1score: 0.0011
# Epoch 00025: val_loss improved from 4.49557 to 4.44737, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_v1/025.h5
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 191/191 [==============================] - 382s 2s/step - loss: 4.0617 - activation_loss: 2.7834 - activation_1_loss: 2.8060 - prob_loss: 2.3848 - activation_accuracy: 0.3696 - activation_macro_f1score: 0.0646 - activation_weighted_f1score: 8.5522e-04 - activation_1_accuracy: 0.3622 - activation_1_macro_f1score: 0.0641 - activation_1_weighted_f1score: 8.5026e-04 - prob_accuracy: 0.4378 - prob_macro_f1score: 0.0926 - prob_weighted_f1score: 0.0011 - val_loss: 4.4474 - val_activation_loss: 2.7371 - val_activation_1_loss: 2.7951 - val_prob_loss: 2.7877 - val_activation_accuracy: 0.4086 - val_activation_macro_f1score: 0.0799 - val_activation_weighted_f1score: 0.0010 - val_activation_1_accuracy: 0.3899 - val_activation_1_macro_f1score: 0.0759 - val_activation_1_weighted_f1score: 9.6554e-04 - val_prob_accuracy: 0.4103 - val_prob_macro_f1score: 0.0920 - val_prob_weighted_f1score: 0.0011
# Epoch 26/60
# 191/191 [==============================] - ETA: 0s - loss: 3.9807 - activation_loss: 2.7414 - activation_1_loss: 2.7653 - prob_loss: 2.3287 - activation_accuracy: 0.3784 - activation_macro_f1score: 0.0678 - activation_weighted_f1score: 8.7773e-04 - activation_1_accuracy: 0.3735 - activation_1_macro_f1score: 0.0674 - activation_1_weighted_f1score: 8.7322e-04 - prob_accuracy: 0.4497 - prob_macro_f1score: 0.0984 - prob_weighted_f1score: 0.0012
# Epoch 00026: val_loss improved from 4.44737 to 4.32903, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_v1/026.h5
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 191/191 [==============================] - 381s 2s/step - loss: 3.9807 - activation_loss: 2.7414 - activation_1_loss: 2.7653 - prob_loss: 2.3287 - activation_accuracy: 0.3784 - activation_macro_f1score: 0.0678 - activation_weighted_f1score: 8.7773e-04 - activation_1_accuracy: 0.3735 - activation_1_macro_f1score: 0.0674 - activation_1_weighted_f1score: 8.7322e-04 - prob_accuracy: 0.4497 - prob_macro_f1score: 0.0984 - prob_weighted_f1score: 0.0012 - val_loss: 4.3290 - val_activation_loss: 2.6734 - val_activation_1_loss: 2.7428 - val_prob_loss: 2.7042 - val_activation_accuracy: 0.4066 - val_activation_macro_f1score: 0.0859 - val_activation_weighted_f1score: 0.0010 - val_activation_1_accuracy: 0.3920 - val_activation_1_macro_f1score: 0.0824 - val_activation_1_weighted_f1score: 0.0010 - val_prob_accuracy: 0.4198 - val_prob_macro_f1score: 0.0987 - val_prob_weighted_f1score: 0.0012
# Epoch 27/60
# 191/191 [==============================] - ETA: 0s - loss: 3.8425 - activation_loss: 2.6775 - activation_1_loss: 2.6894 - prob_loss: 2.2324 - activation_accuracy: 0.3880 - activation_macro_f1score: 0.0718 - activation_weighted_f1score: 9.2562e-04 - activation_1_accuracy: 0.3846 - activation_1_macro_f1score: 0.0722 - activation_1_weighted_f1score: 9.3214e-04 - prob_accuracy: 0.4676 - prob_macro_f1score: 0.1051 - prob_weighted_f1score: 0.0013
# Epoch 00027: val_loss improved from 4.32903 to 4.28483, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_v1/027.h5
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# ...
# Epoch 00050: val_loss did not improve from 4.09454
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 191/191 [==============================] - 380s 2s/step - loss: 2.2652 - activation_loss: 1.9717 - activation_1_loss: 1.8267 - prob_loss: 1.1257 - activation_accuracy: 0.5146 - activation_macro_f1score: 0.1269 - activation_weighted_f1score: 0.0015 - activation_1_accuracy: 0.5494 - activation_1_macro_f1score: 0.1449 - activation_1_weighted_f1score: 0.0017 - prob_accuracy: 0.6989 - prob_macro_f1score: 0.2172 - prob_weighted_f1score: 0.0024 - val_loss: 4.1997 - val_activation_loss: 2.4496 - val_activation_1_loss: 2.5021 - val_prob_loss: 2.7142 - val_activation_accuracy: 0.4749 - val_activation_macro_f1score: 0.1184 - val_activation_weighted_f1score: 0.0014 - val_activation_1_accuracy: 0.4708 - val_activation_1_macro_f1score: 0.1250 - val_activation_1_weighted_f1score: 0.0015 - val_prob_accuracy: 0.4932 - val_prob_macro_f1score: 0.1501 - val_prob_weighted_f1score: 0.0017
# Epoch 51/60
# 191/191 [==============================] - ETA: 0s - loss: 2.2403 - activation_loss: 1.9703 - activation_1_loss: 1.8241 - prob_loss: 1.1020 - activation_accuracy: 0.5192 - activation_macro_f1score: 0.1260 - activation_weighted_f1score: 0.0015 - activation_1_accuracy: 0.5483 - activation_1_macro_f1score: 0.1436 - activation_1_weighted_f1score: 0.0017 - prob_accuracy: 0.7011 - prob_macro_f1score: 0.2166 - prob_weighted_f1score: 0.0024
# Epoch 00051: val_loss did not improve from 4.09454
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 191/191 [==============================] - 380s 2s/step - loss: 2.2403 - activation_loss: 1.9703 - activation_1_loss: 1.8241 - prob_loss: 1.1020 - activation_accuracy: 0.5192 - activation_macro_f1score: 0.1260 - activation_weighted_f1score: 0.0015 - activation_1_accuracy: 0.5483 - activation_1_macro_f1score: 0.1436 - activation_1_weighted_f1score: 0.0017 - prob_accuracy: 0.7011 - prob_macro_f1score: 0.2166 - prob_weighted_f1score: 0.0024 - val_loss: 4.2094 - val_activation_loss: 2.4431 - val_activation_1_loss: 2.5097 - val_prob_loss: 2.7235 - val_activation_accuracy: 0.4759 - val_activation_macro_f1score: 0.1199 - val_activation_weighted_f1score: 0.0014 - val_activation_1_accuracy: 0.4762 - val_activation_1_macro_f1score: 0.1263 - val_activation_1_weighted_f1score: 0.0015 - val_prob_accuracy: 0.4952 - val_prob_macro_f1score: 0.1540 - val_prob_weighted_f1score: 0.0018
# Epoch 52/60
# 191/191 [==============================] - ETA: 0s - loss: 2.1985 - activation_loss: 1.9455 - activation_1_loss: 1.7882 - prob_loss: 1.0784 - activation_accuracy: 0.5202 - activation_macro_f1score: 0.1274 - activation_weighted_f1score: 0.0015 - activation_1_accuracy: 0.5582 - activation_1_macro_f1score: 0.1465 - activation_1_weighted_f1score: 0.0017 - prob_accuracy: 0.7068 - prob_macro_f1score: 0.2196 - prob_weighted_f1score: 0.0024
# Epoch 00052: val_loss did not improve from 4.09454
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 191/191 [==============================] - 381s 2s/step - loss: 2.1985 - activation_loss: 1.9455 - activation_1_loss: 1.7882 - prob_loss: 1.0784 - activation_accuracy: 0.5202 - activation_macro_f1score: 0.1274 - activation_weighted_f1score: 0.0015 - activation_1_accuracy: 0.5582 - activation_1_macro_f1score: 0.1465 - activation_1_weighted_f1score: 0.0017 - prob_accuracy: 0.7068 - prob_macro_f1score: 0.2196 - prob_weighted_f1score: 0.0024 - val_loss: 4.2701 - val_activation_loss: 2.4641 - val_activation_1_loss: 2.5303 - val_prob_loss: 2.7718 - val_activation_accuracy: 0.4701 - val_activation_macro_f1score: 0.1238 - val_activation_weighted_f1score: 0.0015 - val_activation_1_accuracy: 0.4708 - val_activation_1_macro_f1score: 0.1291 - val_activation_1_weighted_f1score: 0.0015 - val_prob_accuracy: 0.4959 - val_prob_macro_f1score: 0.1532 - val_prob_weighted_f1score: 0.0018
# Epoch 53/60
# 191/191 [==============================] - ETA: 0s - loss: 2.1571 - activation_loss: 1.9263 - activation_1_loss: 1.7872 - prob_loss: 1.0430 - activation_accuracy: 0.5245 - activation_macro_f1score: 0.1307 - activation_weighted_f1score: 0.0015 - activation_1_accuracy: 0.5540 - activation_1_macro_f1score: 0.1461 - activation_1_weighted_f1score: 0.0017 - prob_accuracy: 0.7135 - prob_macro_f1score: 0.2226 - prob_weighted_f1score: 0.0025
# Epoch 00053: val_loss did not improve from 4.09454
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 191/191 [==============================] - 381s 2s/step - loss: 2.1571 - activation_loss: 1.9263 - activation_1_loss: 1.7872 - prob_loss: 1.0430 - activation_accuracy: 0.5245 - activation_macro_f1score: 0.1307 - activation_weighted_f1score: 0.0015 - activation_1_accuracy: 0.5540 - activation_1_macro_f1score: 0.1461 - activation_1_weighted_f1score: 0.0017 - prob_accuracy: 0.7135 - prob_macro_f1score: 0.2226 - prob_weighted_f1score: 0.0025 - val_loss: 4.2862 - val_activation_loss: 2.4596 - val_activation_1_loss: 2.5206 - val_prob_loss: 2.7921 - val_activation_accuracy: 0.4796 - val_activation_macro_f1score: 0.1249 - val_activation_weighted_f1score: 0.0015 - val_activation_1_accuracy: 0.4766 - val_activation_1_macro_f1score: 0.1274 - val_activation_1_weighted_f1score: 0.0015 - val_prob_accuracy: 0.4946 - val_prob_macro_f1score: 0.1535 - val_prob_weighted_f1score: 0.0018
# Epoch 54/60
# 191/191 [==============================] - ETA: 0s - loss: 2.1074 - activation_loss: 1.8903 - activation_1_loss: 1.7469 - prob_loss: 1.0163 - activation_accuracy: 0.5301 - activation_macro_f1score: 0.1342 - activation_weighted_f1score: 0.0016 - activation_1_accuracy: 0.5609 - activation_1_macro_f1score: 0.1507 - activation_1_weighted_f1score: 0.0017 - prob_accuracy: 0.7230 - prob_macro_f1score: 0.2279 - prob_weighted_f1score: 0.0025
# Epoch 00054: val_loss did not improve from 4.09454
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 191/191 [==============================] - 382s 2s/step - loss: 2.1074 - activation_loss: 1.8903 - activation_1_loss: 1.7469 - prob_loss: 1.0163 - activation_accuracy: 0.5301 - activation_macro_f1score: 0.1342 - activation_weighted_f1score: 0.0016 - activation_1_accuracy: 0.5609 - activation_1_macro_f1score: 0.1507 - activation_1_weighted_f1score: 0.0017 - prob_accuracy: 0.7230 - prob_macro_f1score: 0.2279 - prob_weighted_f1score: 0.0025 - val_loss: 4.3002 - val_activation_loss: 2.4589 - val_activation_1_loss: 2.5273 - val_prob_loss: 2.8043 - val_activation_accuracy: 0.4803 - val_activation_macro_f1score: 0.1237 - val_activation_weighted_f1score: 0.0015 - val_activation_1_accuracy: 0.4755 - val_activation_1_macro_f1score: 0.1288 - val_activation_1_weighted_f1score: 0.0015 - val_prob_accuracy: 0.4915 - val_prob_macro_f1score: 0.1509 - val_prob_weighted_f1score: 0.0018
# Epoch 55/60
# 191/191 [==============================] - ETA: 0s - loss: 2.0703 - activation_loss: 1.8835 - activation_1_loss: 1.7305 - prob_loss: 0.9861 - activation_accuracy: 0.5328 - activation_macro_f1score: 0.1358 - activation_weighted_f1score: 0.0016 - activation_1_accuracy: 0.5652 - activation_1_macro_f1score: 0.1530 - activation_1_weighted_f1score: 0.0018 - prob_accuracy: 0.7251 - prob_macro_f1score: 0.2332 - prob_weighted_f1score: 0.0025
# Epoch 00055: val_loss did not improve from 4.09454
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 191/191 [==============================] - 382s 2s/step - loss: 2.0703 - activation_loss: 1.8835 - activation_1_loss: 1.7305 - prob_loss: 0.9861 - activation_accuracy: 0.5328 - activation_macro_f1score: 0.1358 - activation_weighted_f1score: 0.0016 - activation_1_accuracy: 0.5652 - activation_1_macro_f1score: 0.1530 - activation_1_weighted_f1score: 0.0018 - prob_accuracy: 0.7251 - prob_macro_f1score: 0.2332 - prob_weighted_f1score: 0.0025 - val_loss: 4.3136 - val_activation_loss: 2.4571 - val_activation_1_loss: 2.5100 - val_prob_loss: 2.8235 - val_activation_accuracy: 0.4803 - val_activation_macro_f1score: 0.1262 - val_activation_weighted_f1score: 0.0015 - val_activation_1_accuracy: 0.4817 - val_activation_1_macro_f1score: 0.1339 - val_activation_1_weighted_f1score: 0.0016 - val_prob_accuracy: 0.5054 - val_prob_macro_f1score: 0.1564 - val_prob_weighted_f1score: 0.0018
# Epoch 56/60
# 191/191 [==============================] - ETA: 0s - loss: 2.0136 - activation_loss: 1.8431 - activation_1_loss: 1.7075 - prob_loss: 0.9484 - activation_accuracy: 0.5397 - activation_macro_f1score: 0.1396 - activation_weighted_f1score: 0.0016 - activation_1_accuracy: 0.5700 - activation_1_macro_f1score: 0.1546 - activation_1_weighted_f1score: 0.0018 - prob_accuracy: 0.7373 - prob_macro_f1score: 0.2364 - prob_weighted_f1score: 0.0026
# Epoch 00056: val_loss did not improve from 4.09454
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 191/191 [==============================] - 381s 2s/step - loss: 2.0136 - activation_loss: 1.8431 - activation_1_loss: 1.7075 - prob_loss: 0.9484 - activation_accuracy: 0.5397 - activation_macro_f1score: 0.1396 - activation_weighted_f1score: 0.0016 - activation_1_accuracy: 0.5700 - activation_1_macro_f1score: 0.1546 - activation_1_weighted_f1score: 0.0018 - prob_accuracy: 0.7373 - prob_macro_f1score: 0.2364 - prob_weighted_f1score: 0.0026 - val_loss: 4.3413 - val_activation_loss: 2.4646 - val_activation_1_loss: 2.4950 - val_prob_loss: 2.8535 - val_activation_accuracy: 0.4840 - val_activation_macro_f1score: 0.1262 - val_activation_weighted_f1score: 0.0015 - val_activation_1_accuracy: 0.4827 - val_activation_1_macro_f1score: 0.1342 - val_activation_1_weighted_f1score: 0.0016 - val_prob_accuracy: 0.4980 - val_prob_macro_f1score: 0.1541 - val_prob_weighted_f1score: 0.0018
# Epoch 57/60
# 191/191 [==============================] - ETA: 0s - loss: 2.0239 - activation_loss: 1.8438 - activation_1_loss: 1.7118 - prob_loss: 0.9573 - activation_accuracy: 0.5403 - activation_macro_f1score: 0.1379 - activation_weighted_f1score: 0.0016 - activation_1_accuracy: 0.5699 - activation_1_macro_f1score: 0.1547 - activation_1_weighted_f1score: 0.0018 - prob_accuracy: 0.7335 - prob_macro_f1score: 0.2353 - prob_weighted_f1score: 0.0026
# Epoch 00057: val_loss did not improve from 4.09454
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 191/191 [==============================] - 382s 2s/step - loss: 2.0239 - activation_loss: 1.8438 - activation_1_loss: 1.7118 - prob_loss: 0.9573 - activation_accuracy: 0.5403 - activation_macro_f1score: 0.1379 - activation_weighted_f1score: 0.0016 - activation_1_accuracy: 0.5699 - activation_1_macro_f1score: 0.1547 - activation_1_weighted_f1score: 0.0018 - prob_accuracy: 0.7335 - prob_macro_f1score: 0.2353 - prob_weighted_f1score: 0.0026 - val_loss: 4.3419 - val_activation_loss: 2.4447 - val_activation_1_loss: 2.5091 - val_prob_loss: 2.8558 - val_activation_accuracy: 0.4837 - val_activation_macro_f1score: 0.1255 - val_activation_weighted_f1score: 0.0015 - val_activation_1_accuracy: 0.4752 - val_activation_1_macro_f1score: 0.1303 - val_activation_1_weighted_f1score: 0.0016 - val_prob_accuracy: 0.5048 - val_prob_macro_f1score: 0.1560 - val_prob_weighted_f1score: 0.0018
# Epoch 58/60
# 191/191 [==============================] - ETA: 0s - loss: 1.9584 - activation_loss: 1.8340 - activation_1_loss: 1.6689 - prob_loss: 0.9075 - activation_accuracy: 0.5382 - activation_macro_f1score: 0.1384 - activation_weighted_f1score: 0.0016 - activation_1_accuracy: 0.5798 - activation_1_macro_f1score: 0.1583 - activation_1_weighted_f1score: 0.0018 - prob_accuracy: 0.7473 - prob_macro_f1score: 0.2408 - prob_weighted_f1score: 0.0026
# Epoch 00058: val_loss did not improve from 4.09454
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 191/191 [==============================] - 383s 2s/step - loss: 1.9584 - activation_loss: 1.8340 - activation_1_loss: 1.6689 - prob_loss: 0.9075 - activation_accuracy: 0.5382 - activation_macro_f1score: 0.1384 - activation_weighted_f1score: 0.0016 - activation_1_accuracy: 0.5798 - activation_1_macro_f1score: 0.1583 - activation_1_weighted_f1score: 0.0018 - prob_accuracy: 0.7473 - prob_macro_f1score: 0.2408 - prob_weighted_f1score: 0.0026 - val_loss: 4.3594 - val_activation_loss: 2.4285 - val_activation_1_loss: 2.5419 - val_prob_loss: 2.8682 - val_activation_accuracy: 0.4868 - val_activation_macro_f1score: 0.1287 - val_activation_weighted_f1score: 0.0015 - val_activation_1_accuracy: 0.4759 - val_activation_1_macro_f1score: 0.1324 - val_activation_1_weighted_f1score: 0.0015 - val_prob_accuracy: 0.5014 - val_prob_macro_f1score: 0.1576 - val_prob_weighted_f1score: 0.0018
# Epoch 59/60
# 191/191 [==============================] - ETA: 0s - loss: 1.9074 - activation_loss: 1.7889 - activation_1_loss: 1.6355 - prob_loss: 0.8801 - activation_accuracy: 0.5490 - activation_macro_f1score: 0.1445 - activation_weighted_f1score: 0.0017 - activation_1_accuracy: 0.5813 - activation_1_macro_f1score: 0.1617 - activation_1_weighted_f1score: 0.0018 - prob_accuracy: 0.7534 - prob_macro_f1score: 0.2452 - prob_weighted_f1score: 0.0027
# Epoch 00059: val_loss did not improve from 4.09454
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 191/191 [==============================] - 383s 2s/step - loss: 1.9074 - activation_loss: 1.7889 - activation_1_loss: 1.6355 - prob_loss: 0.8801 - activation_accuracy: 0.5490 - activation_macro_f1score: 0.1445 - activation_weighted_f1score: 0.0017 - activation_1_accuracy: 0.5813 - activation_1_macro_f1score: 0.1617 - activation_1_weighted_f1score: 0.0018 - prob_accuracy: 0.7534 - prob_macro_f1score: 0.2452 - prob_weighted_f1score: 0.0027 - val_loss: 4.4167 - val_activation_loss: 2.4593 - val_activation_1_loss: 2.5641 - val_prob_loss: 2.9097 - val_activation_accuracy: 0.4834 - val_activation_macro_f1score: 0.1268 - val_activation_weighted_f1score: 0.0015 - val_activation_1_accuracy: 0.4786 - val_activation_1_macro_f1score: 0.1315 - val_activation_1_weighted_f1score: 0.0016 - val_prob_accuracy: 0.4898 - val_prob_macro_f1score: 0.1531 - val_prob_weighted_f1score: 0.0018
# Epoch 60/60
# 191/191 [==============================] - ETA: 0s - loss: 1.9181 - activation_loss: 1.8143 - activation_1_loss: 1.6396 - prob_loss: 0.8819 - activation_accuracy: 0.5465 - activation_macro_f1score: 0.1416 - activation_weighted_f1score: 0.0016 - activation_1_accuracy: 0.5841 - activation_1_macro_f1score: 0.1617 - activation_1_weighted_f1score: 0.0018 - prob_accuracy: 0.7563 - prob_macro_f1score: 0.2453 - prob_weighted_f1score: 0.0027
# Epoch 00060: val_loss did not improve from 4.09454
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 191/191 [==============================] - 382s 2s/step - loss: 1.9181 - activation_loss: 1.8143 - activation_1_loss: 1.6396 - prob_loss: 0.8819 - activation_accuracy: 0.5465 - activation_macro_f1score: 0.1416 - activation_weighted_f1score: 0.0016 - activation_1_accuracy: 0.5841 - activation_1_macro_f1score: 0.1617 - activation_1_weighted_f1score: 0.0018 - prob_accuracy: 0.7563 - prob_macro_f1score: 0.2453 - prob_weighted_f1score: 0.0027 - val_loss: 4.3204 - val_activation_loss: 2.4304 - val_activation_1_loss: 2.5083 - val_prob_loss: 2.8388 - val_activation_accuracy: 0.4861 - val_activation_macro_f1score: 0.1298 - val_activation_weighted_f1score: 0.0015 - val_activation_1_accuracy: 0.4898 - val_activation_1_macro_f1score: 0.1381 - val_activation_1_weighted_f1score: 0.0016 - val_prob_accuracy: 0.5034 - val_prob_macro_f1score: 0.1593 - val_prob_weighted_f1score: 0.0018

# %% [markdown]
# ### 3) GoogLeNet Evaluate

# %%
# 1. epoch=maximum
#var = model.evaluate_generator(generate_test_for_three(),steps=int(len(x_test)/batch_sizes))
var = model.evaluate(generate_test_for_three(),steps=int(len(x_test)/batch_sizes))
print('[Test Loss: %.4f /  Test Accuracy: %.4f / Test Macro f1: %.4f / Test Weighted f1: %.4f]\n' % (var[0],var[-3],var[-2],var[-1]))
# Out:
# Found 3118 images belonging to 257 classes.
# 24/24 [==============================] - 1484s 62s/step - loss: 4.4521 - activation_loss: 2.4928 - activation_1_loss: 2.5546 - prob_loss: 2.9379 - activation_accuracy: 0.4645 - activation_macro_f1score: 0.1255 - activation_weighted_f1score: 0.0015 - activation_1_accuracy: 0.4880 - activation_1_macro_f1score: 0.1338 - activation_1_weighted_f1score: 0.0016 - prob_accuracy: 0.4788 - prob_macro_f1score: 0.1500 - prob_weighted_f1score: 0.0017
# [Test Loss: 4.4521 /  Test Accuracy: 0.4788 / Test Macro f1: 0.1500 / Test Weighted f1: 0.0017]

# %%
loss=history.history['loss']
val_loss=history.history['val_loss']
acc=history.history['prob_accuracy']
val_acc=history.history['val_prob_accuracy']
f1=history.history['prob_macro_f1score']
val_f1=history.history['val_prob_macro_f1score']
epochs=range(1,len(acc)+1)

data = np.array([epochs,loss,val_loss,acc,val_acc,f1,val_f1]).T

# %%
# data save
# epochs, loss, val_loss, acc, val_acc, f1, val_f1

np.savetxt(os.path.join(dir,'train_valid_output',number,model.name+'.txt'),data)

# %%
# data import
data = np.loadtxt(os.path.join(dir,'train_valid_output',number,'Inception_v1.txt'))

# %%
epochs=data[:,0]
loss=data[:,1]
val_loss=data[:,2]
acc=data[:,3]
val_acc=data[:,4]

# %%
plt.plot(epochs[1:],acc[1:],'b',label='Training Acc')
plt.plot(epochs[1:],val_acc[1:],'r',label='Validation Acc')
plt.title('Training and Validation Accuracy')
plt.legend()
plt.figure()
plt.plot(epochs[1:],loss[1:],'b',label='Training Loss')
plt.plot(epochs[1:],val_loss[1:],'r',label='Validation Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()

# %%
# 이 아래는 내가 인위적으로 살펴보고 싶은 epoch에 대해서 결과값 출력

# %%
model=load_model(os.path.join(dir,'model_output',number,'Inception_v1','027.h5'),custom_objects={"macro_f1score": macro_f1score,"weighted_f1score":weighted_f1score,"LRN":LRN,"PoolHelper":PoolHelper})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-35-70972ff1c11c> in <module>()
# ----> 1 model=load_model(os.path.join(dir,'model_output',number,'Inception_v1','027.h5'),custom_objects={"macro_f1score": macro_f1score,"weighted_f1score":weighted_f1score,"LRN":LRN,"PoolHelper":PoolHelper})
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/saving/save.py in load_model(filepath, custom_objects, compile, options)
#     180     if (h5py is not None and (
#     181         isinstance(filepath, h5py.File) or h5py.is_hdf5(filepath))):
# --> 182       return hdf5_format.load_model_from_hdf5(filepath, custom_objects, compile)
#     183
#     184     filepath = path_to_string(filepath)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/saving/hdf5_format.py in load_model_from_hdf5(filepath, custom_objects, compile)
#     192       # Compile model.
#     193       model.compile(**saving_utils.compile_args_from_training_config(
# --> 194           training_config, custom_objects))
#     195       saving_utils.try_build_compiled_arguments(model)
#     196
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/saving/saving_utils.py in compile_args_from_training_config(training_config, custom_objects)
#     209   with generic_utils.CustomObjectScope(custom_objects):
#     210     optimizer_config = training_config['optimizer_config']
# --> 211     optimizer = optimizers.deserialize(optimizer_config)
#     212
#     213     # Recover losses.
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/optimizers.py in deserialize(config, custom_objects)
#     867       module_objects=all_classes,
#     868       custom_objects=custom_objects,
# --> 869       printable_module_name='optimizer')
#     870
#     871
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/utils/generic_utils.py in deserialize_keras_object(identifier, module_objects, custom_objects, printable_module_name)
#     345     config = identifier
#     346     (cls, cls_config) = class_and_config_for_serialized_keras_object(
# --> 347         config, module_objects, custom_objects, printable_module_name)
#     348
#     349     if hasattr(cls, 'from_config'):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/utils/generic_utils.py in class_and_config_for_serialized_keras_object(config, module_objects, custom_objects, printable_module_name)
#     294   cls = get_registered_object(class_name, custom_objects, module_objects)
#     295   if cls is None:
# --> 296     raise ValueError('Unknown ' + printable_module_name + ': ' + class_name)
#     297
#     298   cls_config = config['config']
#
# ValueError: Unknown optimizer: AdamW

# %%
# 2. epoch=?
var = model.evaluate(generate_test_for_three(),steps=int(len(x_test)/batch_sizes))
print('[Test Loss: %.4f /  Test Accuracy: %.4f / Test Macro f1: %.4f / Test Weighted f1: %.4f]\n' % (var[0],var[-3],var[-2],var[-1]))
