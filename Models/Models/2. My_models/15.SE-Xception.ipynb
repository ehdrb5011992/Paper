# %%
### 참고 : https://sike6054.github.io/blog/paper/fifth-post/
### SE block 코드 참고 : https://sike6054.github.io/blog/paper/seventh-post/

# %% [markdown]
# # [SE-Xception]

# %% [markdown]
# *KU LeeDongGyu*

# %% [markdown]
# ## Contents
# ---

# %% [markdown]
# 1. Data Preprocessing
# ```
# 1) Data Import
# 2) Data Augmentation
# ```
# 2. Support Functions & Almost Original SE-Xception
# ```
# 1) Support Functions
# 2) Almost Original SE-Xception
# 3) SE-Xception Evaluate
# ```

# %% [markdown]
# ### Install Packages

# %% [markdown]
# ### Module

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/My Drive/Colab Notebooks/Paper
# Out:
# /content/drive/My Drive/Colab Notebooks/Paper

# %%
from f1score import macro_f1score,weighted_f1score

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import cv2
import tensorflow as tf
from tensorflow import keras as ks
from tensorflow.keras import backend as K 
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, Input, Concatenate, ZeroPadding2D ,GlobalMaxPooling2D, Reshape , Lambda , Add, Multiply
from tensorflow.keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D, Activation, BatchNormalization, AveragePooling2D , ZeroPadding2D, SeparableConv2D
from tensorflow.keras.layers import add
from tensorflow.keras.optimizers import Adam, RMSprop , SGD
from tensorflow.keras.callbacks import EarlyStopping , LearningRateScheduler, ModelCheckpoint, CSVLogger, Callback, ReduceLROnPlateau
from tensorflow.keras.regularizers import l1,l2,l1_l2
from tensorflow.keras.models import Model , load_model , Sequential
from tensorflow.keras.utils import plot_model , to_categorical, get_file
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
os.getcwd()
# Out:
# '/content/drive/My Drive/Colab Notebooks/Paper'

# %%
print(tf.__version__)
print(ks.__version__)
# Out:
# 2.3.0
# 2.4.0

# %%
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 2350725988282010731
# , name: "/device:XLA_CPU:0"
# device_type: "XLA_CPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 3489813151190079702
# physical_device_desc: "device: XLA_CPU device"
# , name: "/device:XLA_GPU:0"
# device_type: "XLA_GPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 16380942635139897336
# physical_device_desc: "device: XLA_GPU device"
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 15473775744
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 17200807148581507638
# physical_device_desc: "device: 0, name: Tesla V100-SXM2-16GB, pci bus id: 0000:00:04.0, compute capability: 7.0"
# ]

# %% [markdown]
# ## 1. Data Preprocessing
# ---

# %% [markdown]
# ### 1) Data Import

# %%
# 바꿔서 살펴 볼 것들
# CALTECH, CIFAR100, FER, MIT
data_name = 'CALTECH'
gan_type = 'No_GAN'
number = '1'
size = 299 # sizes after cropping
super_size = 330 # sizes before cropping 
input_sizes = (size,size,3)
batch_sizes = 32
weight_decay = 1e-6
epochs = 50

# %%
# 참고 : https://stackoverflow.com/questions/32419510/how-to-get-reproducible-results-in-keras/52897216#52897216
# setting the seed number for random number generation for reproducibility.

from numpy.random import seed
import random


if number=='1':
    seed_num = 200225
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)
elif number=='2':
    seed_num = 727
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)
elif number=='3':
    seed_num = 115
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)
elif number=='4':
    seed_num = 501
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)
elif number=='5':
    seed_num = 517
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)

# %%
# data import

if data_name=='FER' :
    x_train =  np.zeros(28698)
    x_valid = np.zeros(3589)
    x_test = np.zeros(3588)
    classes = 7 
    tr_center = [0.50793296, 0.50793296, 0.50793296]
elif data_name=='MIT':
    x_train = np.zeros(12466)
    x_valid = np.zeros(1564)
    x_test = np.zeros(1590)
    classes = 67 
    tr_center = [0.47916578, 0.42029615, 0.36046057]
elif data_name=='CALTECH':
    x_train = np.zeros(24510)
    x_valid = np.zeros(2980)
    x_test = np.zeros(3118)
    classes = 257
    tr_center = [0.51397761, 0.49525248, 0.46555727]
elif data_name=='CIFAR100':
    x_train = np.zeros(39941)
    x_valid = np.zeros(10059)
    x_test = np.zeros(10000)
    classes = 100
    tr_center = [0.53393271, 0.51324147, 0.46450563]

# %%
dir = os.path.join(os.getcwd(),data_name,gan_type)

# %% [markdown]
# ### 2) Data Augmentation

# %%
# 참고 : https://jkjung-avt.github.io/keras-image-cropping/

def random_crop(img, random_crop_size):
    # Note: image_data_format is 'channel_last'
    assert img.shape[2] == 3 # img.shape[2] 가 3(rgb)이 아니면 assertion error 발생
    height, width = img.shape[0], img.shape[1]
    dy, dx = random_crop_size
    x = np.random.randint(0, width - dx + 1)
    y = np.random.randint(0, height - dy + 1)
    return img[y:(y+dy), x:(x+dx), :]


def crop_generator(batches, crop_length):
    """Take as input a Keras ImageGen (Iterator) and generate random
    crops from the image batches generated by the original iterator.
    """
    while True:
        batch_x, batch_y = next(batches)
        batch_crops = np.zeros((batch_x.shape[0], crop_length, crop_length, 3))
        for i in range(batch_x.shape[0]):
            batch_crops[i] = random_crop(batch_x[i], (crop_length, crop_length))
        yield (batch_crops, batch_y)

# %%
from tensorflow.keras.preprocessing.image import img_to_array,load_img
import glob

# 데이터 전체에 대해 centering 진행함.

def read_cal_image(img_path): 
    x = img_to_array(load_img(img_path)) # x는 채널별 평균값
    y = x.shape[0] * x.shape[1]# y는 데이터별 픽셀 수 (비중)

    x = 1/255. * x # scaling하고, centering값을 뽑아냄.
    x = np.mean(x, axis=(0,1))
    
    return np.hstack([x,y])

def calculate_centered_mean(dataset_path,x_train=x_train):
    num = len(x_train)
    space = np.empty((num,4))
    i=0

    for p in glob.glob(os.path.join(dataset_path,'*/*.*')) :
        space[i] = read_cal_image(p)
        i += 1

    ratio = space[:,3] / np.sum(space[:,3])

    return np.average(space[:,0:3],axis=0,weights=ratio)


# 아래의 함수를 돌려서 나온 결과값을 중심화 값으로 설정.

# train_mean = calculate_centered_mean(os.path.join(dir,'data/train')).reshape((1,1,3))

# %%
datagen_tr = ImageDataGenerator(
    rescale=1/255.,
    horizontal_flip=True,
    featurewise_center=True,
    featurewise_std_normalization=False,
    rotation_range=10,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=[0.9,1.0],
    fill_mode = 'nearest')
datagen_val = ImageDataGenerator(rescale=1/255.,featurewise_center=True)
datagen_tes = ImageDataGenerator(rescale=1/255.,featurewise_center=True)

# 원래는 이 자리에 fit 매서드를 써야하지만, 그냥 내가 중심화함수를 만들고 적용함. 

# 중심화 설정
datagen_tr.mean = np.array(tr_center, dtype=np.float32).reshape((1,1,3)) # RGB
datagen_val.mean = np.array(tr_center, dtype=np.float32).reshape((1,1,3)) # RGB
datagen_tes.mean = np.array(tr_center, dtype=np.float32).reshape((1,1,3)) # RGB

# %%
train_batches = datagen_tr.flow_from_directory(directory=os.path.join(dir,'data/train'),target_size=(super_size,super_size),batch_size=batch_sizes,class_mode='categorical') # fer : 28698 / mit : 12466 / caltech : 24509 / cifar : 39941
train_generator= crop_generator(train_batches, size)
valid_generator = datagen_val.flow_from_directory(directory=os.path.join(dir,'data/valid'),target_size=(size,size),batch_size=batch_sizes,class_mode='categorical') # fer : 3589 / mit : 1564 / caltech : 2980 / cifar : 10059
test_generator = datagen_tes.flow_from_directory(directory=os.path.join(dir,'data/test'),target_size=(size,size),batch_size=batch_sizes,class_mode='categorical') # fer : 3588 / mit : 1590 / caltech : 3118 / cifar : 10000
# Out:
# Found 24509 images belonging to 257 classes.
# Found 2980 images belonging to 257 classes.
# Found 3118 images belonging to 257 classes.

# %% [markdown]
# ## 2. Support Functions & Almost Original SE-Xception
# ---

# %% [markdown]
# ### 1) Support Functions

# %%
# def lr_schedule(epoch):
#     init_lr = 1e-4
#     k = 0.04
#     lr = init_lr * np.exp(-k*epoch)
#     print('Learning rate: ', lr)
#     return lr

def lr_schedule(epoch):
    lr = 1e-3
    if epoch < 30:
        lr = lr
    elif epoch < 45:
        lr = lr * 0.1
    else:
        lr = lr * 0.01
    print('Learning rate: ', lr)
    return lr

# %%
# SE block을 만들고 붙이자.
def SE_block(input_tensor,reduction_ratio):
    ch_input = K.int_shape(input_tensor)[-1]
    ch_reduced = ch_input//reduction_ratio
    
    # Squeeze
    x = GlobalAveragePooling2D()(input_tensor) 
    
    # Excitation
    x = Dense(ch_reduced, activation='relu', kernel_initializer='he_uniform', use_bias=False)(x) 
    x = Dense(ch_input, activation='sigmoid', use_bias=False)(x) 
    
    x = Reshape( (1, 1, ch_input) )(x)
    x = Multiply()([input_tensor, x]) # broadcasting 
    
    return x

# %%
def conv2d_bn(x, filters, kernel_size, padding='same', strides=1, activation='relu', weight_decay=weight_decay):
    x = Conv2D(filters, kernel_size, padding=padding, strides=strides, kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(x)
    x = BatchNormalization()(x)
    
    if activation:
        x = Activation(activation)(x)
    
    return x

# %%
def sepconv2d_bn(x, filters, kernel_size, padding='same', strides=1, activation='relu', weight_decay=weight_decay, depth_multiplier=1):
    x = SeparableConv2D(filters, kernel_size, padding=padding, strides=strides, depth_multiplier=depth_multiplier, 
                        depthwise_initializer='he_uniform', pointwise_initializer='he_uniform',
                        depthwise_regularizer=l2(weight_decay), pointwise_regularizer=l2(weight_decay))(x)
    x = BatchNormalization()(x)
    
    if activation:
        x = Activation(activation)(x)
    
    return x

# %% [markdown]
# ### 2) Almost Original SE-Xception

# %%
def SE_Xception(model_input, classes, reduction_ratio, name = "SE_Xception"):
    ## Entry flow
    x = conv2d_bn(model_input, 32, (3, 3), strides=2) # (299, 299, 3) -> (150, 150, 32)
    x = conv2d_bn(x, 64, (3, 3))

    for fliters in [128, 256, 728]: # (75, 75, 64) -> (75, 75, 128) -> (38, 38, 256) -> (19, 19, 728)
        residual = conv2d_bn(x, fliters, (1, 1), strides=2, activation=None)
        
        x = Activation(activation='relu')(x)
        x = sepconv2d_bn(x, fliters, (3, 3))
        x = sepconv2d_bn(x, fliters, (3, 3), activation=None)
        x = MaxPooling2D((3, 3), padding='same', strides=2)(x)

        # SE block 추가
        x =  SE_block(x, reduction_ratio)
    
        x = Add()([x, residual])
        
        
    ## Middle flow
    for i in range(8): # (19, 19, 728)
        residual = x
        
        x = Activation(activation='relu')(x)
        x = sepconv2d_bn(x, 728, (3, 3))
        x = sepconv2d_bn(x, 728, (3, 3))
        x = sepconv2d_bn(x, 728, (3, 3), activation=None)

        # SE block 추가
        x =  SE_block(x, reduction_ratio)
        
        x = Add()([x, residual])
        
        
    ## Exit flow
    residual = conv2d_bn(x, 1024, (1, 1), strides=2, activation=None) # (19, 19, 728) -> (10, 10, 1024)
        
    x = Activation(activation='relu')(x)
    x = sepconv2d_bn(x, 728, (3, 3))
    x = sepconv2d_bn(x, 1024, (3, 3), activation=None) # (19, 19, 728) -> (19, 19, 1024)
    x = MaxPooling2D((3, 3), padding='same', strides=2)(x) # (19, 19, 1024) -> (10, 10, 1024)

    # SE block 추가
    x =  SE_block(x, reduction_ratio)
    
    x = Add()([x, residual])
    
    x = sepconv2d_bn(x, 1536, (3, 3))
    x = sepconv2d_bn(x, 2048, (3, 3))

    x = GlobalAveragePooling2D()(x)
    
    ## Optinal fully-connected layers
    '''
    x = Dense(4096)(x)
    x = BatchNormalization()(x)
    x = Activation(activation='relu')(x)
    
    x = Dense(4096)(x)
    x = BatchNormalization()(x)
    x = Activation(activation='relu')(x)
    '''
    
    x = Dropout(0.5)(x)
    
    model_output = Dense(classes, activation='softmax')(x)

    model = Model(model_input, model_output, name=name)
    
    return model

# %%
model_input = Input( shape=input_sizes )
model = SE_Xception(model_input, classes=classes, reduction_ratio = 16, name='SE_Xception')

# %%
model.summary()
# Out:
# Model: "SE_Xception"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 299, 299, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 150, 150, 32) 896         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 150, 150, 32) 128         conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 150, 150, 32) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 150, 150, 64) 18496       activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 150, 150, 64) 256         conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 150, 150, 64) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 150, 150, 64) 0           activation_1[0][0]
# __________________________________________________________________________________________________
# separable_conv2d (SeparableConv (None, 150, 150, 128 8896        activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 150, 150, 128 512         separable_conv2d[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 150, 150, 128 0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_1 (SeparableCo (None, 150, 150, 128 17664       activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 150, 150, 128 512         separable_conv2d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 75, 75, 128)  0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 128)          0           max_pooling2d[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 8)            1024        global_average_pooling2d[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 128)          1024        dense[0][0]
# __________________________________________________________________________________________________
# reshape (Reshape)               (None, 1, 1, 128)    0           dense_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 75, 75, 128)  8320        activation_1[0][0]
# __________________________________________________________________________________________________
# multiply (Multiply)             (None, 75, 75, 128)  0           max_pooling2d[0][0]
#                                                                  reshape[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 75, 75, 128)  512         conv2d_2[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 75, 75, 128)  0           multiply[0][0]
#                                                                  batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 75, 75, 128)  0           add[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_2 (SeparableCo (None, 75, 75, 256)  34176       activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 75, 75, 256)  1024        separable_conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 75, 75, 256)  0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_3 (SeparableCo (None, 75, 75, 256)  68096       activation_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 75, 75, 256)  1024        separable_conv2d_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 38, 38, 256)  0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_1 (Glo (None, 256)          0           max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 16)           4096        global_average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 256)          4096        dense_2[0][0]
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, 1, 1, 256)    0           dense_3[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 38, 38, 256)  33024       add[0][0]
# __________________________________________________________________________________________________
# multiply_1 (Multiply)           (None, 38, 38, 256)  0           max_pooling2d_1[0][0]
#                                                                  reshape_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 38, 38, 256)  1024        conv2d_3[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 38, 38, 256)  0           multiply_1[0][0]
#                                                                  batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 38, 38, 256)  0           add_1[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_4 (SeparableCo (None, 38, 38, 728)  189400      activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 38, 38, 728)  2912        separable_conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 38, 38, 728)  0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_5 (SeparableCo (None, 38, 38, 728)  537264      activation_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 38, 38, 728)  2912        separable_conv2d_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 19, 19, 728)  0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_2 (Glo (None, 728)          0           max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 45)           32760       global_average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 728)          32760       dense_4[0][0]
# __________________________________________________________________________________________________
# reshape_2 (Reshape)             (None, 1, 1, 728)    0           dense_5[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 19, 19, 728)  187096      add_1[0][0]
# __________________________________________________________________________________________________
# multiply_2 (Multiply)           (None, 19, 19, 728)  0           max_pooling2d_2[0][0]
#                                                                  reshape_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 19, 19, 728)  2912        conv2d_4[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 19, 19, 728)  0           multiply_2[0][0]
#                                                                  batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 19, 19, 728)  0           add_2[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_6 (SeparableCo (None, 19, 19, 728)  537264      activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 19, 19, 728)  2912        separable_conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 19, 19, 728)  0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_7 (SeparableCo (None, 19, 19, 728)  537264      activation_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 19, 19, 728)  2912        separable_conv2d_7[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 19, 19, 728)  0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_8 (SeparableCo (None, 19, 19, 728)  537264      activation_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 19, 19, 728)  2912        separable_conv2d_8[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_3 (Glo (None, 728)          0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 45)           32760       global_average_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 728)          32760       dense_6[0][0]
# __________________________________________________________________________________________________
# reshape_3 (Reshape)             (None, 1, 1, 728)    0           dense_7[0][0]
# __________________________________________________________________________________________________
# multiply_3 (Multiply)           (None, 19, 19, 728)  0           batch_normalization_13[0][0]
#                                                                  reshape_3[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 19, 19, 728)  0           multiply_3[0][0]
#                                                                  add_2[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 19, 19, 728)  0           add_3[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_9 (SeparableCo (None, 19, 19, 728)  537264      activation_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 19, 19, 728)  2912        separable_conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 19, 19, 728)  0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_10 (SeparableC (None, 19, 19, 728)  537264      activation_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 19, 19, 728)  2912        separable_conv2d_10[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 19, 19, 728)  0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_11 (SeparableC (None, 19, 19, 728)  537264      activation_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 19, 19, 728)  2912        separable_conv2d_11[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_4 (Glo (None, 728)          0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 45)           32760       global_average_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, 728)          32760       dense_8[0][0]
# __________________________________________________________________________________________________
# reshape_4 (Reshape)             (None, 1, 1, 728)    0           dense_9[0][0]
# __________________________________________________________________________________________________
# multiply_4 (Multiply)           (None, 19, 19, 728)  0           batch_normalization_16[0][0]
#                                                                  reshape_4[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 19, 19, 728)  0           multiply_4[0][0]
#                                                                  add_3[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 19, 19, 728)  0           add_4[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_12 (SeparableC (None, 19, 19, 728)  537264      activation_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 19, 19, 728)  2912        separable_conv2d_12[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 19, 19, 728)  0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_13 (SeparableC (None, 19, 19, 728)  537264      activation_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 19, 19, 728)  2912        separable_conv2d_13[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 19, 19, 728)  0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_14 (SeparableC (None, 19, 19, 728)  537264      activation_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 19, 19, 728)  2912        separable_conv2d_14[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_5 (Glo (None, 728)          0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# dense_10 (Dense)                (None, 45)           32760       global_average_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# dense_11 (Dense)                (None, 728)          32760       dense_10[0][0]
# __________________________________________________________________________________________________
# reshape_5 (Reshape)             (None, 1, 1, 728)    0           dense_11[0][0]
# __________________________________________________________________________________________________
# multiply_5 (Multiply)           (None, 19, 19, 728)  0           batch_normalization_19[0][0]
#                                                                  reshape_5[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 19, 19, 728)  0           multiply_5[0][0]
#                                                                  add_4[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 19, 19, 728)  0           add_5[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_15 (SeparableC (None, 19, 19, 728)  537264      activation_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 19, 19, 728)  2912        separable_conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 19, 19, 728)  0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_16 (SeparableC (None, 19, 19, 728)  537264      activation_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 19, 19, 728)  2912        separable_conv2d_16[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 19, 19, 728)  0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_17 (SeparableC (None, 19, 19, 728)  537264      activation_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 19, 19, 728)  2912        separable_conv2d_17[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_6 (Glo (None, 728)          0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# dense_12 (Dense)                (None, 45)           32760       global_average_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# dense_13 (Dense)                (None, 728)          32760       dense_12[0][0]
# __________________________________________________________________________________________________
# reshape_6 (Reshape)             (None, 1, 1, 728)    0           dense_13[0][0]
# __________________________________________________________________________________________________
# multiply_6 (Multiply)           (None, 19, 19, 728)  0           batch_normalization_22[0][0]
#                                                                  reshape_6[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 19, 19, 728)  0           multiply_6[0][0]
#                                                                  add_5[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 19, 19, 728)  0           add_6[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_18 (SeparableC (None, 19, 19, 728)  537264      activation_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 19, 19, 728)  2912        separable_conv2d_18[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 19, 19, 728)  0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_19 (SeparableC (None, 19, 19, 728)  537264      activation_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 19, 19, 728)  2912        separable_conv2d_19[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 19, 19, 728)  0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_20 (SeparableC (None, 19, 19, 728)  537264      activation_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 19, 19, 728)  2912        separable_conv2d_20[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_7 (Glo (None, 728)          0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# dense_14 (Dense)                (None, 45)           32760       global_average_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# dense_15 (Dense)                (None, 728)          32760       dense_14[0][0]
# __________________________________________________________________________________________________
# reshape_7 (Reshape)             (None, 1, 1, 728)    0           dense_15[0][0]
# __________________________________________________________________________________________________
# multiply_7 (Multiply)           (None, 19, 19, 728)  0           batch_normalization_25[0][0]
#                                                                  reshape_7[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 19, 19, 728)  0           multiply_7[0][0]
#                                                                  add_6[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 19, 19, 728)  0           add_7[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_21 (SeparableC (None, 19, 19, 728)  537264      activation_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 19, 19, 728)  2912        separable_conv2d_21[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 19, 19, 728)  0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_22 (SeparableC (None, 19, 19, 728)  537264      activation_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 19, 19, 728)  2912        separable_conv2d_22[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 19, 19, 728)  0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_23 (SeparableC (None, 19, 19, 728)  537264      activation_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 19, 19, 728)  2912        separable_conv2d_23[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_8 (Glo (None, 728)          0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# dense_16 (Dense)                (None, 45)           32760       global_average_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# dense_17 (Dense)                (None, 728)          32760       dense_16[0][0]
# __________________________________________________________________________________________________
# reshape_8 (Reshape)             (None, 1, 1, 728)    0           dense_17[0][0]
# __________________________________________________________________________________________________
# multiply_8 (Multiply)           (None, 19, 19, 728)  0           batch_normalization_28[0][0]
#                                                                  reshape_8[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 19, 19, 728)  0           multiply_8[0][0]
#                                                                  add_7[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 19, 19, 728)  0           add_8[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_24 (SeparableC (None, 19, 19, 728)  537264      activation_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 19, 19, 728)  2912        separable_conv2d_24[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 19, 19, 728)  0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_25 (SeparableC (None, 19, 19, 728)  537264      activation_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 19, 19, 728)  2912        separable_conv2d_25[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 19, 19, 728)  0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_26 (SeparableC (None, 19, 19, 728)  537264      activation_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 19, 19, 728)  2912        separable_conv2d_26[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_9 (Glo (None, 728)          0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# dense_18 (Dense)                (None, 45)           32760       global_average_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# dense_19 (Dense)                (None, 728)          32760       dense_18[0][0]
# __________________________________________________________________________________________________
# reshape_9 (Reshape)             (None, 1, 1, 728)    0           dense_19[0][0]
# __________________________________________________________________________________________________
# multiply_9 (Multiply)           (None, 19, 19, 728)  0           batch_normalization_31[0][0]
#                                                                  reshape_9[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 19, 19, 728)  0           multiply_9[0][0]
#                                                                  add_8[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 19, 19, 728)  0           add_9[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_27 (SeparableC (None, 19, 19, 728)  537264      activation_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 19, 19, 728)  2912        separable_conv2d_27[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 19, 19, 728)  0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_28 (SeparableC (None, 19, 19, 728)  537264      activation_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 19, 19, 728)  2912        separable_conv2d_28[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 19, 19, 728)  0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_29 (SeparableC (None, 19, 19, 728)  537264      activation_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 19, 19, 728)  2912        separable_conv2d_29[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_10 (Gl (None, 728)          0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# dense_20 (Dense)                (None, 45)           32760       global_average_pooling2d_10[0][0]
# __________________________________________________________________________________________________
# dense_21 (Dense)                (None, 728)          32760       dense_20[0][0]
# __________________________________________________________________________________________________
# reshape_10 (Reshape)            (None, 1, 1, 728)    0           dense_21[0][0]
# __________________________________________________________________________________________________
# multiply_10 (Multiply)          (None, 19, 19, 728)  0           batch_normalization_34[0][0]
#                                                                  reshape_10[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 19, 19, 728)  0           multiply_10[0][0]
#                                                                  add_9[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 19, 19, 728)  0           add_10[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_30 (SeparableC (None, 19, 19, 728)  537264      activation_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 19, 19, 728)  2912        separable_conv2d_30[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 19, 19, 728)  0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_31 (SeparableC (None, 19, 19, 1024) 753048      activation_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 19, 19, 1024) 4096        separable_conv2d_31[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 10, 10, 1024) 0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_11 (Gl (None, 1024)         0           max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# dense_22 (Dense)                (None, 64)           65536       global_average_pooling2d_11[0][0]
# __________________________________________________________________________________________________
# dense_23 (Dense)                (None, 1024)         65536       dense_22[0][0]
# __________________________________________________________________________________________________
# reshape_11 (Reshape)            (None, 1, 1, 1024)   0           dense_23[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 10, 10, 1024) 746496      add_10[0][0]
# __________________________________________________________________________________________________
# multiply_11 (Multiply)          (None, 10, 10, 1024) 0           max_pooling2d_3[0][0]
#                                                                  reshape_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 10, 10, 1024) 4096        conv2d_5[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 10, 10, 1024) 0           multiply_11[0][0]
#                                                                  batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_32 (SeparableC (None, 10, 10, 1536) 1583616     add_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 10, 10, 1536) 6144        separable_conv2d_32[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 10, 10, 1536) 0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_33 (SeparableC (None, 10, 10, 2048) 3161600     activation_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 10, 10, 2048) 8192        separable_conv2d_33[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 10, 10, 2048) 0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_12 (Gl (None, 2048)         0           activation_35[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 2048)         0           global_average_pooling2d_12[0][0]
# __________________________________________________________________________________________________
# dense_24 (Dense)                (None, 257)          526593      dropout[0][0]
# ==================================================================================================
# Total params: 22,146,329
# Trainable params: 22,091,801
# Non-trainable params: 54,528
# __________________________________________________________________________________________________

# %%
plot_model(model)

# %%
# 폴더 생성

os.makedirs(os.path.join(dir,'model_output',number,model.name), exist_ok=True)
os.makedirs(os.path.join(dir,'train_valid_output',number), exist_ok=True)

# %%
# 참고 : https://github.com/OverLordGoldDragon/keras-adamw

import sys
sys.path.append('/content/drive/My Drive/Colab Notebooks/Paper')
import utils
import optimizers_v2
from utils import get_weight_decays, fill_dict_in_order
from utils import reset_seeds, K_eval
from optimizers_v2 import AdamW, NadamW, SGDW

# %%
optimizer = AdamW(model=model, use_cosine_annealing=False, total_iterations = len(x_train) // batch_sizes , eta_min = 1e-2)
#optimizer = Adam()
filepath =  os.path.join(dir,'model_output',number,model.name,'{epoch:03d}.h5')

callbacks_list = [ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_weights_only=False, save_best_only=True, mode='min'),
                  ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_weights_only=False, save_best_only=True, mode='max'),
                  #ReduceLROnPlateau(monitor='val_loss',patience=3,factor=0.1,min_lr=1e-5),
                  LearningRateScheduler(lr_schedule,verbose=1)
                  ]
                  
model.compile(optimizer, loss = 'categorical_crossentropy', metrics=['accuracy',macro_f1score,weighted_f1score])

# %%
######## flow_from_directory
history = model.fit(train_generator, steps_per_epoch=int(len(x_train)/batch_sizes),  validation_data = valid_generator, epochs=epochs, verbose=1 , callbacks = callbacks_list , validation_steps=int(len(x_valid)/batch_sizes))
# Out:
# Learning rate:  0.001
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 1/50
# 0.0(L1), 3.615507621182657e-08(L2) weight decay set for conv2d/kernel:0
# 0.0(L1), 3.615507621182657e-08(L2) weight decay set for conv2d_1/kernel:0
# 0.0(L1), 3.615507621182657e-08(L2) weight decay set for conv2d_2/kernel:0
# 0.0(L1), 3.615507621182657e-08(L2) weight decay set for conv2d_3/kernel:0
# 0.0(L1), 3.615507621182657e-08(L2) weight decay set for conv2d_4/kernel:0
# 0.0(L1), 3.615507621182657e-08(L2) weight decay set for conv2d_5/kernel:0
# 765/765 [==============================] - ETA: 0s - loss: 5.2036 - accuracy: 0.0701 - macro_f1score: 4.7763e-04 - weighted_f1score: 1.8646e-05
# Epoch 00001: val_loss improved from inf to 5.25490, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/SE_Xception/001.h5
#
# Epoch 00001: val_accuracy improved from -inf to 0.07325, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/SE_Xception/001.h5
# 765/765 [==============================] - 13291s 17s/step - loss: 5.2036 - accuracy: 0.0701 - macro_f1score: 4.7763e-04 - weighted_f1score: 1.8646e-05 - val_loss: 5.2549 - val_accuracy: 0.0733 - val_macro_f1score: 0.0015 - val_weighted_f1score: 5.7983e-05
# Learning rate:  0.001
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 2/50
# 765/765 [==============================] - ETA: 0s - loss: 4.6435 - accuracy: 0.1213 - macro_f1score: 0.0029 - weighted_f1score: 1.2411e-04
# Epoch 00002: val_loss did not improve from 5.25490
#
# Epoch 00002: val_accuracy improved from 0.07325 to 0.09711, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/SE_Xception/002.h5
# 765/765 [==============================] - 690s 902ms/step - loss: 4.6435 - accuracy: 0.1213 - macro_f1score: 0.0029 - weighted_f1score: 1.2411e-04 - val_loss: 6.1591 - val_accuracy: 0.0971 - val_macro_f1score: 0.0034 - val_weighted_f1score: 1.4615e-04
# Learning rate:  0.001
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 3/50
# 765/765 [==============================] - ETA: 0s - loss: 4.2010 - accuracy: 0.1722 - macro_f1score: 0.0058 - weighted_f1score: 2.4453e-04
# Epoch 00003: val_loss improved from 5.25490 to 4.28870, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/SE_Xception/003.h5
#
# Epoch 00003: val_accuracy improved from 0.09711 to 0.18112, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/SE_Xception/003.h5
# 765/765 [==============================] - 693s 906ms/step - loss: 4.2010 - accuracy: 0.1722 - macro_f1score: 0.0058 - weighted_f1score: 2.4453e-04 - val_loss: 4.2887 - val_accuracy: 0.1811 - val_macro_f1score: 0.0076 - val_weighted_f1score: 3.1680e-04
# Learning rate:  0.001
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 4/50
# 765/765 [==============================] - ETA: 0s - loss: 3.7963 - accuracy: 0.2217 - macro_f1score: 0.0087 - weighted_f1score: 3.5163e-04
# Epoch 00004: val_loss improved from 4.28870 to 3.86010, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/SE_Xception/004.h5
#
# Epoch 00004: val_accuracy improved from 0.18112 to 0.22917, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/SE_Xception/004.h5
# 765/765 [==============================] - 696s 910ms/step - loss: 3.7963 - accuracy: 0.2217 - macro_f1score: 0.0087 - weighted_f1score: 3.5163e-04 - val_loss: 3.8601 - val_accuracy: 0.2292 - val_macro_f1score: 0.0078 - val_weighted_f1score: 3.0982e-04
# Learning rate:  0.001
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 5/50
# 765/765 [==============================] - ETA: 0s - loss: 3.4356 - accuracy: 0.2755 - macro_f1score: 0.0126 - weighted_f1score: 4.8882e-04
# Epoch 00005: val_loss improved from 3.86010 to 3.47654, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/SE_Xception/005.h5
#
# Epoch 00005: val_accuracy improved from 0.22917 to 0.28427, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/SE_Xception/005.h5
# 765/765 [==============================] - 696s 910ms/step - loss: 3.4356 - accuracy: 0.2755 - macro_f1score: 0.0126 - weighted_f1score: 4.8882e-04 - val_loss: 3.4765 - val_accuracy: 0.2843 - val_macro_f1score: 0.0169 - val_weighted_f1score: 6.5178e-04
# Learning rate:  0.001
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 6/50
# 765/765 [==============================] - ETA: 0s - loss: 3.0701 - accuracy: 0.3334 - macro_f1score: 0.0178 - weighted_f1score: 6.6970e-04
# Epoch 00006: val_loss improved from 3.47654 to 3.42337, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/SE_Xception/006.h5
#
# Epoch 00006: val_accuracy improved from 0.28427 to 0.30175, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/SE_Xception/006.h5
# 765/765 [==============================] - 700s 914ms/step - loss: 3.0701 - accuracy: 0.3334 - macro_f1score: 0.0178 - weighted_f1score: 6.6970e-04 - val_loss: 3.4234 - val_accuracy: 0.3017 - val_macro_f1score: 0.0172 - val_weighted_f1score: 6.5133e-04
# Learning rate:  0.001
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 7/50
# 765/765 [==============================] - ETA: 0s - loss: 2.7950 - accuracy: 0.3811 - macro_f1score: 0.0232 - weighted_f1score: 8.5183e-04
# Epoch 00007: val_loss improved from 3.42337 to 3.19091, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/SE_Xception/007.h5
#
# Epoch 00007: val_accuracy improved from 0.30175 to 0.32392, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/SE_Xception/007.h5
# 765/765 [==============================] - 699s 914ms/step - loss: 2.7950 - accuracy: 0.3811 - macro_f1score: 0.0232 - weighted_f1score: 8.5183e-04 - val_loss: 3.1909 - val_accuracy: 0.3239 - val_macro_f1score: 0.0200 - val_weighted_f1score: 7.2553e-04
# Learning rate:  0.001
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 8/50
# 765/765 [==============================] - ETA: 0s - loss: 2.5438 - accuracy: 0.4317 - macro_f1score: 0.0285 - weighted_f1score: 0.0010
# Epoch 00008: val_loss improved from 3.19091 to 2.98457, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/SE_Xception/008.h5
#
# Epoch 00008: val_accuracy improved from 0.32392 to 0.37097, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/SE_Xception/008.h5
# 765/765 [==============================] - 696s 909ms/step - loss: 2.5438 - accuracy: 0.4317 - macro_f1score: 0.0285 - weighted_f1score: 0.0010 - val_loss: 2.9846 - val_accuracy: 0.3710 - val_macro_f1score: 0.0259 - val_weighted_f1score: 9.3461e-04
# Learning rate:  0.001
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 9/50
# 765/765 [==============================] - ETA: 0s - loss: 2.3113 - accuracy: 0.4743 - macro_f1score: 0.0345 - weighted_f1score: 0.0012
# Epoch 00009: val_loss improved from 2.98457 to 2.82357, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/SE_Xception/009.h5
#
# Epoch 00009: val_accuracy improved from 0.37097 to 0.40591, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/SE_Xception/009.h5
# 765/765 [==============================] - 693s 906ms/step - loss: 2.3113 - accuracy: 0.4743 - macro_f1score: 0.0345 - weighted_f1score: 0.0012 - val_loss: 2.8236 - val_accuracy: 0.4059 - val_macro_f1score: 0.0302 - val_weighted_f1score: 0.0011
# Learning rate:  0.001
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 10/50
# 765/765 [==============================] - ETA: 0s - loss: 2.1287 - accuracy: 0.5102 - macro_f1score: 0.0399 - weighted_f1score: 0.0014
# Epoch 00010: val_loss did not improve from 2.82357
#
# Epoch 00010: val_accuracy did not improve from 0.40591
# 765/765 [==============================] - 696s 909ms/step - loss: 2.1287 - accuracy: 0.5102 - macro_f1score: 0.0399 - weighted_f1score: 0.0014 - val_loss: 2.8856 - val_accuracy: 0.3928 - val_macro_f1score: 0.0309 - val_weighted_f1score: 0.0011
# Learning rate:  0.001
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 11/50
# 765/765 [==============================] - ETA: 0s - loss: 1.9403 - accuracy: 0.5469 - macro_f1score: 0.0444 - weighted_f1score: 0.0016
# Epoch 00011: val_loss improved from 2.82357 to 2.31741, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/SE_Xception/011.h5
#
# Epoch 00011: val_accuracy improved from 0.40591 to 0.50067, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/SE_Xception/011.h5
# 765/765 [==============================] - 696s 910ms/step - loss: 1.9403 - accuracy: 0.5469 - macro_f1score: 0.0444 - weighted_f1score: 0.0016 - val_loss: 2.3174 - val_accuracy: 0.5007 - val_macro_f1score: 0.0431 - val_weighted_f1score: 0.0015
# Learning rate:  0.001
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 12/50
# 765/765 [==============================] - ETA: 0s - loss: 1.7882 - accuracy: 0.5754 - macro_f1score: 0.0492 - weighted_f1score: 0.0017
# Epoch 00012: val_loss did not improve from 2.31741
#
# Epoch 00012: val_accuracy did not improve from 0.50067
# 765/765 [==============================] - 690s 902ms/step - loss: 1.7882 - accuracy: 0.5754 - macro_f1score: 0.0492 - weighted_f1score: 0.0017 - val_loss: 2.5738 - val_accuracy: 0.4704 - val_macro_f1score: 0.0415 - val_weighted_f1score: 0.0015
# Learning rate:  0.001
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 13/50
# 765/765 [==============================] - ETA: 0s - loss: 1.6401 - accuracy: 0.6093 - macro_f1score: 0.0538 - weighted_f1score: 0.0019
# Epoch 00013: val_loss did not improve from 2.31741
#
# Epoch 00013: val_accuracy improved from 0.50067 to 0.51243, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/SE_Xception/013.h5
# 765/765 [==============================] - 679s 888ms/step - loss: 1.6401 - accuracy: 0.6093 - macro_f1score: 0.0538 - weighted_f1score: 0.0019 - val_loss: 2.3741 - val_accuracy: 0.5124 - val_macro_f1score: 0.0450 - val_weighted_f1score: 0.0016
# Learning rate:  0.001
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 14/50
# 765/765 [==============================] - ETA: 0s - loss: 1.5022 - accuracy: 0.6376 - macro_f1score: 0.0584 - weighted_f1score: 0.0020
# Epoch 00014: val_loss improved from 2.31741 to 2.22469, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/SE_Xception/014.h5
#
# Epoch 00014: val_accuracy improved from 0.51243 to 0.53629, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/SE_Xception/014.h5
# 765/765 [==============================] - 682s 891ms/step - loss: 1.5022 - accuracy: 0.6376 - macro_f1score: 0.0584 - weighted_f1score: 0.0020 - val_loss: 2.2247 - val_accuracy: 0.5363 - val_macro_f1score: 0.0506 - val_weighted_f1score: 0.0018
# Learning rate:  0.001
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 15/50
# 765/765 [==============================] - ETA: 0s - loss: 1.3794 - accuracy: 0.6654 - macro_f1score: 0.0624 - weighted_f1score: 0.0022
# Epoch 00015: val_loss did not improve from 2.22469
#
# Epoch 00015: val_accuracy did not improve from 0.53629
# 765/765 [==============================] - 677s 885ms/step - loss: 1.3794 - accuracy: 0.6654 - macro_f1score: 0.0624 - weighted_f1score: 0.0022 - val_loss: 2.2987 - val_accuracy: 0.5259 - val_macro_f1score: 0.0489 - val_weighted_f1score: 0.0017
# Learning rate:  0.001
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 16/50
# 765/765 [==============================] - ETA: 0s - loss: 1.2613 - accuracy: 0.6895 - macro_f1score: 0.0660 - weighted_f1score: 0.0023
# Epoch 00016: val_loss improved from 2.22469 to 2.22001, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/SE_Xception/016.h5
#
# Epoch 00016: val_accuracy improved from 0.53629 to 0.53999, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/SE_Xception/016.h5
# 765/765 [==============================] - 690s 901ms/step - loss: 1.2613 - accuracy: 0.6895 - macro_f1score: 0.0660 - weighted_f1score: 0.0023 - val_loss: 2.2200 - val_accuracy: 0.5400 - val_macro_f1score: 0.0522 - val_weighted_f1score: 0.0018
# Learning rate:  0.001
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 17/50
# 765/765 [==============================] - ETA: 0s - loss: 1.1449 - accuracy: 0.7175 - macro_f1score: 0.0708 - weighted_f1score: 0.0024
# Epoch 00017: val_loss did not improve from 2.22001
#
# Epoch 00017: val_accuracy did not improve from 0.53999
# 765/765 [==============================] - 694s 907ms/step - loss: 1.1449 - accuracy: 0.7175 - macro_f1score: 0.0708 - weighted_f1score: 0.0024 - val_loss: 2.3371 - val_accuracy: 0.5326 - val_macro_f1score: 0.0518 - val_weighted_f1score: 0.0018
# Learning rate:  0.001
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 18/50
# 765/765 [==============================] - ETA: 0s - loss: 1.0555 - accuracy: 0.7378 - macro_f1score: 0.0737 - weighted_f1score: 0.0025
# Epoch 00018: val_loss did not improve from 2.22001
#
# Epoch 00018: val_accuracy did not improve from 0.53999
# 765/765 [==============================] - 697s 910ms/step - loss: 1.0555 - accuracy: 0.7378 - macro_f1score: 0.0737 - weighted_f1score: 0.0025 - val_loss: 2.3785 - val_accuracy: 0.5343 - val_macro_f1score: 0.0546 - val_weighted_f1score: 0.0019
# Learning rate:  0.001
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 19/50
# 765/765 [==============================] - ETA: 0s - loss: 0.9618 - accuracy: 0.7639 - macro_f1score: 0.0771 - weighted_f1score: 0.0027
# Epoch 00019: val_loss did not improve from 2.22001
#
# Epoch 00019: val_accuracy did not improve from 0.53999
# 765/765 [==============================] - 694s 908ms/step - loss: 0.9618 - accuracy: 0.7639 - macro_f1score: 0.0771 - weighted_f1score: 0.0027 - val_loss: 2.5160 - val_accuracy: 0.5161 - val_macro_f1score: 0.0518 - val_weighted_f1score: 0.0018
# Learning rate:  0.001
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 20/50
# 765/765 [==============================] - ETA: 0s - loss: 0.8686 - accuracy: 0.7858 - macro_f1score: 0.0809 - weighted_f1score: 0.0028
# Epoch 00020: val_loss did not improve from 2.22001
#
# Epoch 00020: val_accuracy improved from 0.53999 to 0.54536, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/SE_Xception/020.h5
# 765/765 [==============================] - 696s 909ms/step - loss: 0.8686 - accuracy: 0.7858 - macro_f1score: 0.0809 - weighted_f1score: 0.0028 - val_loss: 2.5030 - val_accuracy: 0.5454 - val_macro_f1score: 0.0559 - val_weighted_f1score: 0.0019
# Learning rate:  0.001
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 21/50
# 765/765 [==============================] - ETA: 0s - loss: 0.8071 - accuracy: 0.8046 - macro_f1score: 0.0834 - weighted_f1score: 0.0029
# Epoch 00021: val_loss did not improve from 2.22001
#
# Epoch 00021: val_accuracy improved from 0.54536 to 0.55175, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/SE_Xception/021.h5
# 765/765 [==============================] - 702s 917ms/step - loss: 0.8071 - accuracy: 0.8046 - macro_f1score: 0.0834 - weighted_f1score: 0.0029 - val_loss: 2.3413 - val_accuracy: 0.5517 - val_macro_f1score: 0.0546 - val_weighted_f1score: 0.0019
# Learning rate:  0.001
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 22/50
# 765/765 [==============================] - ETA: 0s - loss: 0.7361 - accuracy: 0.8169 - macro_f1score: 0.0858 - weighted_f1score: 0.0029
# Epoch 00022: val_loss did not improve from 2.22001
#
# Epoch 00022: val_accuracy improved from 0.55175 to 0.56149, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/SE_Xception/022.h5
# 765/765 [==============================] - 701s 916ms/step - loss: 0.7361 - accuracy: 0.8169 - macro_f1score: 0.0858 - weighted_f1score: 0.0029 - val_loss: 2.2349 - val_accuracy: 0.5615 - val_macro_f1score: 0.0561 - val_weighted_f1score: 0.0020
# Learning rate:  0.001
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 23/50
# 765/765 [==============================] - ETA: 0s - loss: 0.6677 - accuracy: 0.8402 - macro_f1score: 0.0890 - weighted_f1score: 0.0030
# Epoch 00023: val_loss did not improve from 2.22001
#
# Epoch 00023: val_accuracy improved from 0.56149 to 0.56855, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/SE_Xception/023.h5
# 765/765 [==============================] - 704s 920ms/step - loss: 0.6677 - accuracy: 0.8402 - macro_f1score: 0.0890 - weighted_f1score: 0.0030 - val_loss: 2.2971 - val_accuracy: 0.5685 - val_macro_f1score: 0.0585 - val_weighted_f1score: 0.0020
# Learning rate:  0.001
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 24/50
# 765/765 [==============================] - ETA: 0s - loss: 0.6295 - accuracy: 0.8501 - macro_f1score: 0.0909 - weighted_f1score: 0.0031
# Epoch 00024: val_loss did not improve from 2.22001
#
# Epoch 00024: val_accuracy did not improve from 0.56855
# 765/765 [==============================] - 700s 915ms/step - loss: 0.6295 - accuracy: 0.8501 - macro_f1score: 0.0909 - weighted_f1score: 0.0031 - val_loss: 2.6880 - val_accuracy: 0.5521 - val_macro_f1score: 0.0573 - val_weighted_f1score: 0.0020
# Learning rate:  0.001
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 25/50
# 765/765 [==============================] - ETA: 0s - loss: 0.5839 - accuracy: 0.8644 - macro_f1score: 0.0927 - weighted_f1score: 0.0032
# Epoch 00025: val_loss did not improve from 2.22001
#
# Epoch 00025: val_accuracy did not improve from 0.56855
# 765/765 [==============================] - 701s 916ms/step - loss: 0.5839 - accuracy: 0.8644 - macro_f1score: 0.0927 - weighted_f1score: 0.0032 - val_loss: 2.2725 - val_accuracy: 0.5655 - val_macro_f1score: 0.0584 - val_weighted_f1score: 0.0020
# Learning rate:  0.001
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 26/50
# 765/765 [==============================] - ETA: 0s - loss: 0.5660 - accuracy: 0.8664 - macro_f1score: 0.0937 - weighted_f1score: 0.0032
# Epoch 00026: val_loss did not improve from 2.22001
#
# Epoch 00026: val_accuracy improved from 0.56855 to 0.57258, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/SE_Xception/026.h5
# 765/765 [==============================] - 700s 915ms/step - loss: 0.5660 - accuracy: 0.8664 - macro_f1score: 0.0937 - weighted_f1score: 0.0032 - val_loss: 2.5851 - val_accuracy: 0.5726 - val_macro_f1score: 0.0613 - val_weighted_f1score: 0.0021
# Learning rate:  0.001
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 27/50
# 765/765 [==============================] - ETA: 0s - loss: 0.5130 - accuracy: 0.8861 - macro_f1score: 0.0964 - weighted_f1score: 0.0033
# Epoch 00027: val_loss did not improve from 2.22001
#
# Epoch 00027: val_accuracy did not improve from 0.57258
# 765/765 [==============================] - 703s 919ms/step - loss: 0.5130 - accuracy: 0.8861 - macro_f1score: 0.0964 - weighted_f1score: 0.0033 - val_loss: 2.5224 - val_accuracy: 0.5702 - val_macro_f1score: 0.0599 - val_weighted_f1score: 0.0021
# Learning rate:  0.001
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 28/50
# 765/765 [==============================] - ETA: 0s - loss: 0.4984 - accuracy: 0.8861 - macro_f1score: 0.0967 - weighted_f1score: 0.0033
# Epoch 00028: val_loss did not improve from 2.22001
#
# Epoch 00028: val_accuracy did not improve from 0.57258
# 765/765 [==============================] - 701s 916ms/step - loss: 0.4984 - accuracy: 0.8861 - macro_f1score: 0.0967 - weighted_f1score: 0.0033 - val_loss: 2.5150 - val_accuracy: 0.5628 - val_macro_f1score: 0.0590 - val_weighted_f1score: 0.0021
# Learning rate:  0.001
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 29/50
# 765/765 [==============================] - ETA: 0s - loss: 0.4661 - accuracy: 0.8978 - macro_f1score: 0.0989 - weighted_f1score: 0.0034
# Epoch 00029: val_loss did not improve from 2.22001
#
# Epoch 00029: val_accuracy improved from 0.57258 to 0.58098, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/SE_Xception/029.h5
# 765/765 [==============================] - 702s 918ms/step - loss: 0.4661 - accuracy: 0.8978 - macro_f1score: 0.0989 - weighted_f1score: 0.0034 - val_loss: 2.4773 - val_accuracy: 0.5810 - val_macro_f1score: 0.0610 - val_weighted_f1score: 0.0021
# Learning rate:  0.001
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 30/50
# 765/765 [==============================] - ETA: 0s - loss: 0.4444 - accuracy: 0.9056 - macro_f1score: 0.1000 - weighted_f1score: 0.0034
# Epoch 00030: val_loss did not improve from 2.22001
#
# Epoch 00030: val_accuracy did not improve from 0.58098
# 765/765 [==============================] - 700s 915ms/step - loss: 0.4444 - accuracy: 0.9056 - macro_f1score: 0.1000 - weighted_f1score: 0.0034 - val_loss: 2.3324 - val_accuracy: 0.5766 - val_macro_f1score: 0.0597 - val_weighted_f1score: 0.0021
# Learning rate:  0.0001
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 31/50
# 765/765 [==============================] - ETA: 0s - loss: 0.3022 - accuracy: 0.9507 - macro_f1score: 0.1062 - weighted_f1score: 0.0036
# Epoch 00031: val_loss improved from 2.22001 to 2.10229, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/SE_Xception/031.h5
#
# Epoch 00031: val_accuracy improved from 0.58098 to 0.63038, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/SE_Xception/031.h5
# 765/765 [==============================] - 707s 924ms/step - loss: 0.3022 - accuracy: 0.9507 - macro_f1score: 0.1062 - weighted_f1score: 0.0036 - val_loss: 2.1023 - val_accuracy: 0.6304 - val_macro_f1score: 0.0674 - val_weighted_f1score: 0.0023
# Learning rate:  0.0001
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 32/50
# 765/765 [==============================] - ETA: 0s - loss: 0.2422 - accuracy: 0.9703 - macro_f1score: 0.1095 - weighted_f1score: 0.0037
# Epoch 00032: val_loss did not improve from 2.10229
#
# Epoch 00032: val_accuracy improved from 0.63038 to 0.63508, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/SE_Xception/032.h5
# 765/765 [==============================] - 709s 926ms/step - loss: 0.2422 - accuracy: 0.9703 - macro_f1score: 0.1095 - weighted_f1score: 0.0037 - val_loss: 2.1113 - val_accuracy: 0.6351 - val_macro_f1score: 0.0687 - val_weighted_f1score: 0.0024
# Learning rate:  0.0001
#
# Epoch 00033: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 33/50
# 765/765 [==============================] - ETA: 0s - loss: 0.2248 - accuracy: 0.9745 - macro_f1score: 0.1101 - weighted_f1score: 0.0038
# Epoch 00033: val_loss improved from 2.10229 to 2.08187, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/SE_Xception/033.h5
#
# Epoch 00033: val_accuracy improved from 0.63508 to 0.63844, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/SE_Xception/033.h5
# 765/765 [==============================] - 713s 932ms/step - loss: 0.2248 - accuracy: 0.9745 - macro_f1score: 0.1101 - weighted_f1score: 0.0038 - val_loss: 2.0819 - val_accuracy: 0.6384 - val_macro_f1score: 0.0684 - val_weighted_f1score: 0.0024
# Learning rate:  0.0001
#
# Epoch 00034: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 34/50
# 765/765 [==============================] - ETA: 0s - loss: 0.2152 - accuracy: 0.9775 - macro_f1score: 0.1106 - weighted_f1score: 0.0038
# Epoch 00034: val_loss did not improve from 2.08187
#
# Epoch 00034: val_accuracy improved from 0.63844 to 0.64147, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/SE_Xception/034.h5
# 765/765 [==============================] - 711s 929ms/step - loss: 0.2152 - accuracy: 0.9775 - macro_f1score: 0.1106 - weighted_f1score: 0.0038 - val_loss: 2.1010 - val_accuracy: 0.6415 - val_macro_f1score: 0.0688 - val_weighted_f1score: 0.0024
# Learning rate:  0.0001
#
# Epoch 00035: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 35/50
# 765/765 [==============================] - ETA: 0s - loss: 0.2054 - accuracy: 0.9781 - macro_f1score: 0.1112 - weighted_f1score: 0.0038
# Epoch 00035: val_loss did not improve from 2.08187
#
# Epoch 00035: val_accuracy did not improve from 0.64147
# 765/765 [==============================] - 702s 918ms/step - loss: 0.2054 - accuracy: 0.9781 - macro_f1score: 0.1112 - weighted_f1score: 0.0038 - val_loss: 2.1455 - val_accuracy: 0.6361 - val_macro_f1score: 0.0680 - val_weighted_f1score: 0.0024
# Learning rate:  0.0001
#
# Epoch 00036: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 36/50
# 765/765 [==============================] - ETA: 0s - loss: 0.1970 - accuracy: 0.9816 - macro_f1score: 0.1119 - weighted_f1score: 0.0038
# Epoch 00036: val_loss did not improve from 2.08187
#
# Epoch 00036: val_accuracy did not improve from 0.64147
# 765/765 [==============================] - 700s 916ms/step - loss: 0.1970 - accuracy: 0.9816 - macro_f1score: 0.1119 - weighted_f1score: 0.0038 - val_loss: 2.1315 - val_accuracy: 0.6415 - val_macro_f1score: 0.0684 - val_weighted_f1score: 0.0024
# Learning rate:  0.0001
#
# Epoch 00037: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 37/50
# 765/765 [==============================] - ETA: 0s - loss: 0.1904 - accuracy: 0.9833 - macro_f1score: 0.1118 - weighted_f1score: 0.0038
# Epoch 00037: val_loss did not improve from 2.08187
#
# Epoch 00037: val_accuracy did not improve from 0.64147
# 765/765 [==============================] - 694s 907ms/step - loss: 0.1904 - accuracy: 0.9833 - macro_f1score: 0.1118 - weighted_f1score: 0.0038 - val_loss: 2.1343 - val_accuracy: 0.6408 - val_macro_f1score: 0.0694 - val_weighted_f1score: 0.0024
# Learning rate:  0.0001
#
# Epoch 00038: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 38/50
# 765/765 [==============================] - ETA: 0s - loss: 0.1830 - accuracy: 0.9847 - macro_f1score: 0.1122 - weighted_f1score: 0.0038
# Epoch 00038: val_loss did not improve from 2.08187
#
# Epoch 00038: val_accuracy improved from 0.64147 to 0.64315, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/SE_Xception/038.h5
# 765/765 [==============================] - 691s 903ms/step - loss: 0.1830 - accuracy: 0.9847 - macro_f1score: 0.1122 - weighted_f1score: 0.0038 - val_loss: 2.1401 - val_accuracy: 0.6431 - val_macro_f1score: 0.0693 - val_weighted_f1score: 0.0024
# Learning rate:  0.0001
#
# Epoch 00039: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 39/50
# 765/765 [==============================] - ETA: 0s - loss: 0.1806 - accuracy: 0.9854 - macro_f1score: 0.1122 - weighted_f1score: 0.0038
# Epoch 00039: val_loss did not improve from 2.08187
#
# Epoch 00039: val_accuracy did not improve from 0.64315
# 765/765 [==============================] - 695s 908ms/step - loss: 0.1806 - accuracy: 0.9854 - macro_f1score: 0.1122 - weighted_f1score: 0.0038 - val_loss: 2.1555 - val_accuracy: 0.6408 - val_macro_f1score: 0.0686 - val_weighted_f1score: 0.0024
# Learning rate:  0.0001
#
# Epoch 00040: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 40/50
# 765/765 [==============================] - ETA: 0s - loss: 0.1758 - accuracy: 0.9870 - macro_f1score: 0.1125 - weighted_f1score: 0.0038
# Epoch 00040: val_loss did not improve from 2.08187
#
# Epoch 00040: val_accuracy did not improve from 0.64315
# 765/765 [==============================] - 698s 913ms/step - loss: 0.1758 - accuracy: 0.9870 - macro_f1score: 0.1125 - weighted_f1score: 0.0038 - val_loss: 2.1603 - val_accuracy: 0.6381 - val_macro_f1score: 0.0691 - val_weighted_f1score: 0.0024
# Learning rate:  0.0001
#
# Epoch 00041: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 41/50
# 765/765 [==============================] - ETA: 0s - loss: 0.1685 - accuracy: 0.9885 - macro_f1score: 0.1124 - weighted_f1score: 0.0038
# Epoch 00041: val_loss did not improve from 2.08187
#
# Epoch 00041: val_accuracy did not improve from 0.64315
# 765/765 [==============================] - 700s 915ms/step - loss: 0.1685 - accuracy: 0.9885 - macro_f1score: 0.1124 - weighted_f1score: 0.0038 - val_loss: 2.1804 - val_accuracy: 0.6425 - val_macro_f1score: 0.0691 - val_weighted_f1score: 0.0024
# Learning rate:  0.0001
#
# Epoch 00042: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 42/50
# 765/765 [==============================] - ETA: 0s - loss: 0.1664 - accuracy: 0.9899 - macro_f1score: 0.1125 - weighted_f1score: 0.0038
# Epoch 00042: val_loss did not improve from 2.08187
#
# Epoch 00042: val_accuracy did not improve from 0.64315
# 765/765 [==============================] - 702s 918ms/step - loss: 0.1664 - accuracy: 0.9899 - macro_f1score: 0.1125 - weighted_f1score: 0.0038 - val_loss: 2.1604 - val_accuracy: 0.6408 - val_macro_f1score: 0.0689 - val_weighted_f1score: 0.0024
# Learning rate:  0.0001
#
# Epoch 00043: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 43/50
# 765/765 [==============================] - ETA: 0s - loss: 0.1649 - accuracy: 0.9895 - macro_f1score: 0.1129 - weighted_f1score: 0.0038
# Epoch 00043: val_loss did not improve from 2.08187
#
# Epoch 00043: val_accuracy did not improve from 0.64315
# 765/765 [==============================] - 703s 919ms/step - loss: 0.1649 - accuracy: 0.9895 - macro_f1score: 0.1129 - weighted_f1score: 0.0038 - val_loss: 2.2313 - val_accuracy: 0.6418 - val_macro_f1score: 0.0705 - val_weighted_f1score: 0.0024
# Learning rate:  0.0001
#
# Epoch 00044: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 44/50
# 765/765 [==============================] - ETA: 0s - loss: 0.1637 - accuracy: 0.9893 - macro_f1score: 0.1127 - weighted_f1score: 0.0038
# Epoch 00044: val_loss did not improve from 2.08187
#
# Epoch 00044: val_accuracy did not improve from 0.64315
# 765/765 [==============================] - 702s 918ms/step - loss: 0.1637 - accuracy: 0.9893 - macro_f1score: 0.1127 - weighted_f1score: 0.0038 - val_loss: 2.2226 - val_accuracy: 0.6331 - val_macro_f1score: 0.0686 - val_weighted_f1score: 0.0024
# Learning rate:  0.0001
#
# Epoch 00045: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 45/50
# 765/765 [==============================] - ETA: 0s - loss: 0.1626 - accuracy: 0.9895 - macro_f1score: 0.1131 - weighted_f1score: 0.0038
# Epoch 00045: val_loss did not improve from 2.08187
#
# Epoch 00045: val_accuracy did not improve from 0.64315
# 765/765 [==============================] - 703s 919ms/step - loss: 0.1626 - accuracy: 0.9895 - macro_f1score: 0.1131 - weighted_f1score: 0.0038 - val_loss: 2.2206 - val_accuracy: 0.6378 - val_macro_f1score: 0.0706 - val_weighted_f1score: 0.0024
# Learning rate:  1e-05
#
# Epoch 00046: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 46/50
# 765/765 [==============================] - ETA: 0s - loss: 0.1570 - accuracy: 0.9918 - macro_f1score: 0.1133 - weighted_f1score: 0.0038
# Epoch 00046: val_loss did not improve from 2.08187
#
# Epoch 00046: val_accuracy did not improve from 0.64315
# 765/765 [==============================] - 701s 916ms/step - loss: 0.1570 - accuracy: 0.9918 - macro_f1score: 0.1133 - weighted_f1score: 0.0038 - val_loss: 2.1906 - val_accuracy: 0.6411 - val_macro_f1score: 0.0701 - val_weighted_f1score: 0.0024
# Learning rate:  1e-05
#
# Epoch 00047: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 47/50
# 765/765 [==============================] - ETA: 0s - loss: 0.1541 - accuracy: 0.9920 - macro_f1score: 0.1131 - weighted_f1score: 0.0039
# Epoch 00047: val_loss did not improve from 2.08187
#
# Epoch 00047: val_accuracy did not improve from 0.64315
# 765/765 [==============================] - 701s 916ms/step - loss: 0.1541 - accuracy: 0.9920 - macro_f1score: 0.1131 - weighted_f1score: 0.0039 - val_loss: 2.1796 - val_accuracy: 0.6408 - val_macro_f1score: 0.0696 - val_weighted_f1score: 0.0024
# Learning rate:  1e-05
#
# Epoch 00048: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 48/50
# 765/765 [==============================] - ETA: 0s - loss: 0.1519 - accuracy: 0.9931 - macro_f1score: 0.1131 - weighted_f1score: 0.0039
# Epoch 00048: val_loss did not improve from 2.08187
#
# Epoch 00048: val_accuracy did not improve from 0.64315
# 765/765 [==============================] - 701s 917ms/step - loss: 0.1519 - accuracy: 0.9931 - macro_f1score: 0.1131 - weighted_f1score: 0.0039 - val_loss: 2.1736 - val_accuracy: 0.6418 - val_macro_f1score: 0.0692 - val_weighted_f1score: 0.0024
# Learning rate:  1e-05
#
# Epoch 00049: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 49/50
# 765/765 [==============================] - ETA: 0s - loss: 0.1526 - accuracy: 0.9926 - macro_f1score: 0.1134 - weighted_f1score: 0.0039
# Epoch 00049: val_loss did not improve from 2.08187
#
# Epoch 00049: val_accuracy did not improve from 0.64315
# 765/765 [==============================] - 705s 921ms/step - loss: 0.1526 - accuracy: 0.9926 - macro_f1score: 0.1134 - weighted_f1score: 0.0039 - val_loss: 2.1754 - val_accuracy: 0.6431 - val_macro_f1score: 0.0699 - val_weighted_f1score: 0.0024
# Learning rate:  1e-05
#
# Epoch 00050: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 50/50
# 765/765 [==============================] - ETA: 0s - loss: 0.1497 - accuracy: 0.9927 - macro_f1score: 0.1133 - weighted_f1score: 0.0039
# Epoch 00050: val_loss did not improve from 2.08187
#
# Epoch 00050: val_accuracy did not improve from 0.64315
# 765/765 [==============================] - 708s 925ms/step - loss: 0.1497 - accuracy: 0.9927 - macro_f1score: 0.1133 - weighted_f1score: 0.0039 - val_loss: 2.1657 - val_accuracy: 0.6425 - val_macro_f1score: 0.0697 - val_weighted_f1score: 0.0024

# %% [markdown]
# ### 3) SE-Xception Evaluate

# %%
# 1. epoch=maximum
loss , acc, mf1, wf1 = model.evaluate(test_generator,steps=int(len(x_test)/batch_sizes))
print('[Test Loss: %.4f /  Test Accuracy: %.4f / Test Macro f1: %.4f / Test Weighted f1: %.4f]\n' % (loss,acc,mf1,wf1))
# Out:
# 97/97 [==============================] - 1205s 12s/step - loss: 2.2123 - accuracy: 0.6424 - macro_f1score: 0.0691 - weighted_f1score: 0.0024
# [Test Loss: 2.2123 /  Test Accuracy: 0.6424 / Test Macro f1: 0.0691 / Test Weighted f1: 0.0024]

# %%
loss=history.history['loss']
val_loss=history.history['val_loss']
acc=history.history['accuracy']
val_acc=history.history['val_accuracy']
f1=history.history['macro_f1score']
val_f1=history.history['val_macro_f1score']
epochs=range(1,len(acc)+1)

data = np.array([epochs,loss,val_loss,acc,val_acc,f1,val_f1]).T

# %%
# data save
# epochs, loss, val_loss, acc, val_acc, f1, val_f1

np.savetxt(os.path.join(dir,'train_valid_output',number,model.name+'.txt'),data)

# %%
# data import
data = np.loadtxt(os.path.join(dir,'train_valid_output',number,'SE_Xception.txt'))

# %%
epochs=data[:,0]
loss=data[:,1]
val_loss=data[:,2]
acc=data[:,3]
val_acc=data[:,4]

# %%
plt.plot(epochs[1:],acc[1:],'b',label='Training Acc')
plt.plot(epochs[1:],val_acc[1:],'r',label='Validation Acc')
plt.title('Training and Validation Accuracy')
plt.legend()
plt.figure()
plt.plot(epochs[10:],loss[10:],'b',label='Training Loss')
plt.plot(epochs[10:],val_loss[10:],'r',label='Validation Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()

# %%
# 이 아래는 내가 인위적으로 살펴보고 싶은 epoch에 대해서 결과값 출력 / SE-Xception

# %%
model=load_model(os.path.join(dir,'model_output',number,'SE_Xception','022.h5'),custom_objects={"macro_f1score": macro_f1score,"weighted_f1score":weighted_f1score})

# %%
# 2. epoch=?
loss , acc, mf1, wf1 = model.evaluate(test_generator,steps=int(len(x_test)/batch_sizes))
print('[Test Loss: %.4f /  Test Accuracy: %.4f / Test Macro f1: %.4f / Test Weighted f1: %.4f]\n' % (loss,acc,mf1,wf1))
