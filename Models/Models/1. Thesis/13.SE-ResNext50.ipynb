# %%
#모형 출처 : https://github.com/titu1994/keras-squeeze-excite-network

# %% [markdown]
# ## [SE-ResNext50]

# %% [markdown]
# *KU LeeDongGyu*

# %% [markdown]
# ## Contents
# ---

# %% [markdown]
# 1. Data Preprocessing
# ```
# 1) Data Import
# 2) Data Augmentation
# ```
# 2. Support Functions & Almost Original SE-ResNext
# ```
# 1) Support Functions
# 2) Almost orginal SE-ResNext
# ```
# 3. SE-ResNext50
# ```
# 1) SE-ResNext50
# 2) SE-ResNext50 Evaluate
# ```

# %% [markdown]
# ### Install Packages

# %% [markdown]
# ### Module

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/My Drive/Colab Notebooks/Paper
# Out:
# /content/drive/My Drive/Colab Notebooks/Paper

# %%
from f1score import macro_f1score,weighted_f1score

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import cv2
import tensorflow as tf
from tensorflow import keras as ks
from tensorflow.keras import backend as K 
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, Input, Concatenate, ZeroPadding2D ,GlobalMaxPooling2D, Reshape , Lambda , Add, Multiply
from tensorflow.keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D, Activation, BatchNormalization, AveragePooling2D , ZeroPadding2D, SeparableConv2D , LeakyReLU
from tensorflow.keras.layers import add, concatenate, multiply
from tensorflow.keras.optimizers import Adam, RMSprop , SGD
from tensorflow.keras.callbacks import EarlyStopping , LearningRateScheduler, ModelCheckpoint, CSVLogger, Callback, ReduceLROnPlateau
from tensorflow.keras.regularizers import l1,l2,l1_l2
from tensorflow.keras.models import Model , load_model , Sequential
from tensorflow.keras.utils import plot_model , to_categorical, get_file
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
os.getcwd()
# Out:
# '/content/drive/My Drive/Colab Notebooks/Paper'

# %%
tf.__version__
# Out:
# '2.3.0'

# %%
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 15883227300495020910
# , name: "/device:XLA_CPU:0"
# device_type: "XLA_CPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 13375988223089466368
# physical_device_desc: "device: XLA_CPU device"
# , name: "/device:XLA_GPU:0"
# device_type: "XLA_GPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 13978724674695865327
# physical_device_desc: "device: XLA_GPU device"
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 15473775744
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 9863515633348057164
# physical_device_desc: "device: 0, name: Tesla V100-SXM2-16GB, pci bus id: 0000:00:04.0, compute capability: 7.0"
# ]

# %%
# !cat /proc/cpuinfo
# Out:
# processor	: 0
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 85
# model name	: Intel(R) Xeon(R) CPU @ 2.00GHz
# stepping	: 3
# microcode	: 0x1
# cpu MHz		: 2000.172
# cache size	: 39424 KB
# physical id	: 0
# siblings	: 4
# core id		: 0
# cpu cores	: 2
# apicid		: 0
# initial apicid	: 0
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm mpx avx512f avx512dq rdseed adx smap clflushopt clwb avx512cd avx512bw avx512vl xsaveopt xsavec xgetbv1 xsaves arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs taa
# bogomips	: 4000.34
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 46 bits physical, 48 bits virtual
# power management:
#
# processor	: 1
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 85
# model name	: Intel(R) Xeon(R) CPU @ 2.00GHz
# stepping	: 3
# microcode	: 0x1
# cpu MHz		: 2000.172
# cache size	: 39424 KB
# physical id	: 0
# siblings	: 4
# core id		: 1
# cpu cores	: 2
# apicid		: 2
# initial apicid	: 2
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm mpx avx512f avx512dq rdseed adx smap clflushopt clwb avx512cd avx512bw avx512vl xsaveopt xsavec xgetbv1 xsaves arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs taa
# bogomips	: 4000.34
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 46 bits physical, 48 bits virtual
# power management:
#
# processor	: 2
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 85
# model name	: Intel(R) Xeon(R) CPU @ 2.00GHz
# stepping	: 3
# microcode	: 0x1
# cpu MHz		: 2000.172
# cache size	: 39424 KB
# physical id	: 0
# siblings	: 4
# core id		: 0
# cpu cores	: 2
# apicid		: 1
# initial apicid	: 1
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm mpx avx512f avx512dq rdseed adx smap clflushopt clwb avx512cd avx512bw avx512vl xsaveopt xsavec xgetbv1 xsaves arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs taa
# bogomips	: 4000.34
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 46 bits physical, 48 bits virtual
# power management:
#
# processor	: 3
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 85
# model name	: Intel(R) Xeon(R) CPU @ 2.00GHz
# stepping	: 3
# microcode	: 0x1
# cpu MHz		: 2000.172
# cache size	: 39424 KB
# physical id	: 0
# siblings	: 4
# core id		: 1
# cpu cores	: 2
# apicid		: 3
# initial apicid	: 3
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm mpx avx512f avx512dq rdseed adx smap clflushopt clwb avx512cd avx512bw avx512vl xsaveopt xsavec xgetbv1 xsaves arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs taa
# bogomips	: 4000.34
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 46 bits physical, 48 bits virtual
# power management:

# %% [markdown]
# ## 1. Data Preprocessing
# ---

# %% [markdown]
# ### 1) Data Import

# %%
# 바꿔서 살펴 볼 것들
# CALTECH, CIFAR100, FER, MIT
data_name = 'CALTECH'
gan_type = 'No_GAN'
number = '1'
size = 224 # sizes after cropping
super_size = 256 # sizes before cropping 
input_sizes = (size,size,3)
batch_sizes = 32
weight_decay = 2e-3
epochs = 70

# %%
# 참고 : https://stackoverflow.com/questions/32419510/how-to-get-reproducible-results-in-keras/52897216#52897216
# setting the seed number for random number generation for reproducibility.

from numpy.random import seed
import random


if number=='1':
    seed_num = 200225
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)
elif number=='2':
    seed_num = 727
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)
elif number=='3':
    seed_num = 115
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)
elif number=='4':
    seed_num = 501
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)
elif number=='5':
    seed_num = 517
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)

# %%
# data import

if data_name=='FER' :
    x_train =  np.zeros(28698)
    x_valid = np.zeros(3589)
    x_test = np.zeros(3588)
    classes = 7 
    tr_center = [0.50793296, 0.50793296, 0.50793296]
elif data_name=='MIT':
    x_train = np.zeros(12466)
    x_valid = np.zeros(1564)
    x_test = np.zeros(1590)
    classes = 67 
    tr_center = [0.47916578, 0.42029615, 0.36046057]
elif data_name=='CALTECH':
    x_train = np.zeros(24510)
    x_valid = np.zeros(2980)
    x_test = np.zeros(3118)
    classes = 257
    tr_center = [0.51397761, 0.49525248, 0.46555727]
elif data_name=='CIFAR100':
    x_train = np.zeros(44923)
    x_valid = np.zeros(5077)
    x_test = np.zeros(10000)
    classes = 100
    tr_center = [0.53442983, 0.51355958, 0.46462564]

# %%
dir = os.path.join(os.getcwd(),data_name,gan_type)

# %% [markdown]
# ### 2) Data Augmentation

# %%
# 참고 : https://jkjung-avt.github.io/keras-image-cropping/

def random_crop(img, random_crop_size):
    # Note: image_data_format is 'channel_last'
    assert img.shape[2] == 3 # img.shape[2] 가 3(rgb)이 아니면 assertion error 발생
    height, width = img.shape[0], img.shape[1]
    dy, dx = random_crop_size
    x = np.random.randint(0, width - dx + 1)
    y = np.random.randint(0, height - dy + 1)
    return img[y:(y+dy), x:(x+dx), :]


def crop_generator(batches, crop_length):
    """Take as input a Keras ImageGen (Iterator) and generate random
    crops from the image batches generated by the original iterator.
    """
    while True:
        batch_x, batch_y = next(batches)
        batch_crops = np.zeros((batch_x.shape[0], crop_length, crop_length, 3))
        for i in range(batch_x.shape[0]):
            batch_crops[i] = random_crop(batch_x[i], (crop_length, crop_length))
        yield (batch_crops, batch_y)

# %%
from tensorflow.keras.preprocessing.image import img_to_array,load_img
import glob

# 데이터 전체에 대해 centering 진행함.

def read_cal_image(img_path): 
    x = img_to_array(load_img(img_path)) # x는 채널별 평균값
    y = x.shape[0] * x.shape[1]# y는 데이터별 픽셀 수 (비중)

    x = 1/255. * x # scaling하고, centering값을 뽑아냄.
    x = np.mean(x, axis=(0,1))
    
    return np.hstack([x,y])

def calculate_centered_mean(dataset_path,x_train=x_train):
    num = len(x_train)
    space = np.empty((num,4))
    i=0

    for p in glob.glob(os.path.join(dataset_path,'*/*.*')) :
        space[i] = read_cal_image(p)
        i += 1

    ratio = space[:,3] / np.sum(space[:,3])

    return np.average(space[:,0:3],axis=0,weights=ratio)


# 아래의 함수를 돌려서 나온 결과값을 중심화 값으로 설정.

# train_mean = calculate_centered_mean(os.path.join(dir,'data/train')).reshape((1,1,3))

# %%
datagen_tr = ImageDataGenerator(
    rescale=1/255.,
    horizontal_flip=True,
    featurewise_center=True,
    featurewise_std_normalization=False,
    rotation_range=10,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=[0.9,1.0],
    fill_mode = 'nearest')
datagen_val = ImageDataGenerator(rescale=1/255.,featurewise_center=True)
datagen_tes = ImageDataGenerator(rescale=1/255.,featurewise_center=True)

# 원래는 이 자리에 fit 매서드를 써야하지만, 그냥 내가 중심화함수를 만들고 적용함. 

# 중심화 설정
datagen_tr.mean = np.array(tr_center, dtype=np.float32).reshape((1,1,3)) # RGB
datagen_val.mean = np.array(tr_center, dtype=np.float32).reshape((1,1,3)) # RGB
datagen_tes.mean = np.array(tr_center, dtype=np.float32).reshape((1,1,3)) # RGB

# %%
train_batches = datagen_tr.flow_from_directory(directory=os.path.join(dir,'data/train'),target_size=(super_size,super_size),batch_size=batch_sizes,class_mode='categorical') # fer : 28698 / mit : 12466 / caltech : 24509 / cifar : 44923
train_generator= crop_generator(train_batches, size)
valid_generator = datagen_val.flow_from_directory(directory=os.path.join(dir,'data/valid'),target_size=(size,size),batch_size=batch_sizes,class_mode='categorical') # fer : 3589 / mit : 1564 / caltech : 2980 / cifar : 5077
test_generator = datagen_tes.flow_from_directory(directory=os.path.join(dir,'data/test'),target_size=(size,size),batch_size=batch_sizes,class_mode='categorical') # fer : 3588 / mit : 1590 / caltech : 3118 / cifar : 10000
# Out:
# Found 24509 images belonging to 257 classes.
# Found 2980 images belonging to 257 classes.
# Found 3118 images belonging to 257 classes.

# %% [markdown]
# ## 2. Support Functions & Almost Original SE-ResNext
# ---

# %% [markdown]
# ### 1) Support Functions

# %%
# def lr_schedule(epoch):
#     init_lr = 1e-4
#     k = 0.04
#     lr = init_lr * np.exp(-k*epoch)
#     print('Learning rate: ', lr)
#     return lr

def lr_schedule(epoch):
    lr = 1e-3
    if epoch < 30:
        lr = lr
    elif epoch < 60:
        lr = lr * 0.1
    else:
        lr = lr * 0.01
    print('Learning rate: ', lr)
    return lr

# %%
def squeeze_excite_block(input, reduction_ratio=16, weight_decay=weight_decay):

    init = input
    channel_axis = -1
    filters = init.get_shape()[channel_axis]
    se_shape = (1, 1, filters)

    se = GlobalAveragePooling2D()(init)
    se = Reshape(se_shape)(se)
    se = Dense(filters // reduction_ratio, activation='relu', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay), use_bias=False)(se)
    se = Dense(filters, activation='sigmoid', kernel_regularizer=l2(weight_decay), use_bias=False)(se)

    x = multiply([init, se])
    return x

# %%
def __initial_conv_block(input, weight_decay=weight_decay):

    channel_axis = -1

    x = Conv2D(64, (7, 7), padding='same', use_bias=False, kernel_initializer='he_uniform',
               kernel_regularizer=l2(weight_decay), strides=(2, 2))(input)
    x = BatchNormalization(axis=channel_axis)(x)
    x = Activation('relu')(x)

    x = MaxPooling2D((3, 3), strides=(2, 2), padding='same')(x)

    return x

# %%
def __grouped_convolution_block(input, grouped_channels, cardinality, strides, weight_decay=weight_decay):

    init = input
    channel_axis = -1

    group_list = []

    if cardinality == 1:
        # with cardinality 1, it is a standard convolution
        x = Conv2D(grouped_channels, (3, 3), padding='same', use_bias=False, strides=(strides, strides),
                   kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(init)
        x = BatchNormalization(axis=channel_axis)(x)
        x = Activation('relu')(x)
        return x

    for c in range(cardinality):
        x = Lambda(lambda z: z[:, :, :, c * grouped_channels:(c + 1) * grouped_channels])(input)

        x = Conv2D(grouped_channels, (3, 3), padding='same', use_bias=False, strides=(strides, strides),
                   kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(x)

        group_list.append(x)

    group_merge = concatenate(group_list, axis=channel_axis)
    x = BatchNormalization(axis=channel_axis)(group_merge)
    x = Activation('relu')(x)

    return x

# %%
def __bottleneck_block(input, filters=64, cardinality=8, strides=1, weight_decay=weight_decay):

    init = input

    grouped_channels = int(filters / cardinality)
    channel_axis = -1

    # Check if input number of filters is same as 16 * k, else create convolution2d for this input
    if init.get_shape()[-1] != 2 * filters:
        init = Conv2D(filters * 2, (1, 1), padding='same', strides=(strides, strides),
                      use_bias=False, kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(init)
        init = BatchNormalization(axis=channel_axis)(init)


    x = Conv2D(filters, (1, 1), padding='same', use_bias=False,
               kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(input)
    x = BatchNormalization(axis=channel_axis)(x)
    x = Activation('relu')(x)

    x = __grouped_convolution_block(x, grouped_channels, cardinality, strides, weight_decay)

    x = Conv2D(filters * 2, (1, 1), padding='same', use_bias=False, kernel_initializer='he_uniform',
               kernel_regularizer=l2(weight_decay))(x)
    x = BatchNormalization(axis=channel_axis)(x)

    # squeeze and excite block
    x = squeeze_excite_block(x)

    x = add([init, x])
    x = Activation('relu')(x)

    return x

# %% [markdown]
# ### 2) Almost Orginial SE-ResNext

# %%
def __create_res_next(nb_classes, img_input, depth, cardinality=32, width=4, weight_decay=weight_decay):

    N = list(depth)

    filters = cardinality * width
    filters_list = []

    for i in range(len(N)):
        filters_list.append(filters)
        filters *= 2  # double the size of the filters

    x = __initial_conv_block(img_input, weight_decay)

    # block 1 (no pooling)
    for i in range(N[0]):
        x = __bottleneck_block(x, filters_list[0], cardinality, strides=1, weight_decay=weight_decay)

    N = N[1:]  # remove the first block from block definition list
    filters_list = filters_list[1:]  # remove the first filter from the filter list

    # block 2 to N
    for block_idx, n_i in enumerate(N):
        for i in range(n_i):
            if i == 0:
                x = __bottleneck_block(x, filters_list[block_idx], cardinality, strides=2,
                                       weight_decay=weight_decay)
            else:
                x = __bottleneck_block(x, filters_list[block_idx], cardinality, strides=1,
                                       weight_decay=weight_decay)

    x = GlobalAveragePooling2D()(x)
    x = Dense(nb_classes, use_bias=False, kernel_regularizer=l2(weight_decay), activation='softmax')(x)

    return x

# %%
def SE_ResNext(input_shape = (224,224,3), depth=[3, 4, 6, 3], cardinality=32, width=4, weight_decay=weight_decay, classes=1000, name = None):

    img_input = Input(shape=input_shape)

    x = __create_res_next(classes, img_input, depth, cardinality, width, weight_decay)

    inputs = img_input
    # Create model.
    model = Model(inputs, x, name=name)

    return model

# %% [markdown]
# ## 3. SE-ResNext50
#
# ---

# %% [markdown]
# ### 1) SE-ResNext50

# %%
# SE-ResNext50
model = SE_ResNext(input_shape=input_sizes, classes=classes, cardinality=32, width = 4, depth=[3,4,6,3], name='SE_ResNext50')

# %%
model.summary()
# Out:
# Model: "SE_ResNext50"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 112, 112, 64) 9408        input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 112, 112, 64) 256         conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 112, 112, 64) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 56, 56, 64)   0           activation[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 56, 56, 128)  8192        max_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 56, 56, 128)  512         conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 56, 56, 128)  0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# lambda (Lambda)                 (None, 56, 56, 4)    0           activation_1[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 56, 56, 4)    0           activation_1[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 56, 56, 4)    0           activation_1[0][0]
# __________________________________________________________________________________________________
# lambda_3 (Lambda)               (None, 56, 56, 4)    0           activation_1[0][0]
# __________________________________________________________________________________________________
# lambda_4 (Lambda)               (None, 56, 56, 4)    0           activation_1[0][0]
# __________________________________________________________________________________________________
# lambda_5 (Lambda)               (None, 56, 56, 4)    0           activation_1[0][0]
# __________________________________________________________________________________________________
# lambda_6 (Lambda)               (None, 56, 56, 4)    0           activation_1[0][0]
# __________________________________________________________________________________________________
# lambda_7 (Lambda)               (None, 56, 56, 4)    0           activation_1[0][0]
# __________________________________________________________________________________________________
# lambda_8 (Lambda)               (None, 56, 56, 4)    0           activation_1[0][0]
# __________________________________________________________________________________________________
# lambda_9 (Lambda)               (None, 56, 56, 4)    0           activation_1[0][0]
# __________________________________________________________________________________________________
# lambda_10 (Lambda)              (None, 56, 56, 4)    0           activation_1[0][0]
# __________________________________________________________________________________________________
# lambda_11 (Lambda)              (None, 56, 56, 4)    0           activation_1[0][0]
# __________________________________________________________________________________________________
# lambda_12 (Lambda)              (None, 56, 56, 4)    0           activation_1[0][0]
# __________________________________________________________________________________________________
# lambda_13 (Lambda)              (None, 56, 56, 4)    0           activation_1[0][0]
# __________________________________________________________________________________________________
# lambda_14 (Lambda)              (None, 56, 56, 4)    0           activation_1[0][0]
# __________________________________________________________________________________________________
# lambda_15 (Lambda)              (None, 56, 56, 4)    0           activation_1[0][0]
# __________________________________________________________________________________________________
# lambda_16 (Lambda)              (None, 56, 56, 4)    0           activation_1[0][0]
# __________________________________________________________________________________________________
# lambda_17 (Lambda)              (None, 56, 56, 4)    0           activation_1[0][0]
# __________________________________________________________________________________________________
# lambda_18 (Lambda)              (None, 56, 56, 4)    0           activation_1[0][0]
# __________________________________________________________________________________________________
# lambda_19 (Lambda)              (None, 56, 56, 4)    0           activation_1[0][0]
# __________________________________________________________________________________________________
# lambda_20 (Lambda)              (None, 56, 56, 4)    0           activation_1[0][0]
# __________________________________________________________________________________________________
# lambda_21 (Lambda)              (None, 56, 56, 4)    0           activation_1[0][0]
# __________________________________________________________________________________________________
# lambda_22 (Lambda)              (None, 56, 56, 4)    0           activation_1[0][0]
# __________________________________________________________________________________________________
# lambda_23 (Lambda)              (None, 56, 56, 4)    0           activation_1[0][0]
# __________________________________________________________________________________________________
# lambda_24 (Lambda)              (None, 56, 56, 4)    0           activation_1[0][0]
# __________________________________________________________________________________________________
# lambda_25 (Lambda)              (None, 56, 56, 4)    0           activation_1[0][0]
# __________________________________________________________________________________________________
# lambda_26 (Lambda)              (None, 56, 56, 4)    0           activation_1[0][0]
# __________________________________________________________________________________________________
# lambda_27 (Lambda)              (None, 56, 56, 4)    0           activation_1[0][0]
# __________________________________________________________________________________________________
# lambda_28 (Lambda)              (None, 56, 56, 4)    0           activation_1[0][0]
# __________________________________________________________________________________________________
# lambda_29 (Lambda)              (None, 56, 56, 4)    0           activation_1[0][0]
# __________________________________________________________________________________________________
# lambda_30 (Lambda)              (None, 56, 56, 4)    0           activation_1[0][0]
# __________________________________________________________________________________________________
# lambda_31 (Lambda)              (None, 56, 56, 4)    0           activation_1[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 56, 56, 4)    144         lambda[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 56, 56, 4)    144         lambda_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 56, 56, 4)    144         lambda_2[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 56, 56, 4)    144         lambda_3[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 56, 56, 4)    144         lambda_4[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 56, 56, 4)    144         lambda_5[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 56, 56, 4)    144         lambda_6[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 56, 56, 4)    144         lambda_7[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 56, 56, 4)    144         lambda_8[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 56, 56, 4)    144         lambda_9[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 56, 56, 4)    144         lambda_10[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 56, 56, 4)    144         lambda_11[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 56, 56, 4)    144         lambda_12[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 56, 56, 4)    144         lambda_13[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 56, 56, 4)    144         lambda_14[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 56, 56, 4)    144         lambda_15[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 56, 56, 4)    144         lambda_16[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 56, 56, 4)    144         lambda_17[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 56, 56, 4)    144         lambda_18[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 56, 56, 4)    144         lambda_19[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 56, 56, 4)    144         lambda_20[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 56, 56, 4)    144         lambda_21[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 56, 56, 4)    144         lambda_22[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 56, 56, 4)    144         lambda_23[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 56, 56, 4)    144         lambda_24[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 56, 56, 4)    144         lambda_25[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 56, 56, 4)    144         lambda_26[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 56, 56, 4)    144         lambda_27[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 56, 56, 4)    144         lambda_28[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 56, 56, 4)    144         lambda_29[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 56, 56, 4)    144         lambda_30[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 56, 56, 4)    144         lambda_31[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 56, 56, 128)  0           conv2d_3[0][0]
#                                                                  conv2d_4[0][0]
#                                                                  conv2d_5[0][0]
#                                                                  conv2d_6[0][0]
#                                                                  conv2d_7[0][0]
#                                                                  conv2d_8[0][0]
#                                                                  conv2d_9[0][0]
#                                                                  conv2d_10[0][0]
#                                                                  conv2d_11[0][0]
#                                                                  conv2d_12[0][0]
#                                                                  conv2d_13[0][0]
#                                                                  conv2d_14[0][0]
#                                                                  conv2d_15[0][0]
#                                                                  conv2d_16[0][0]
#                                                                  conv2d_17[0][0]
#                                                                  conv2d_18[0][0]
#                                                                  conv2d_19[0][0]
#                                                                  conv2d_20[0][0]
#                                                                  conv2d_21[0][0]
#                                                                  conv2d_22[0][0]
#                                                                  conv2d_23[0][0]
#                                                                  conv2d_24[0][0]
#                                                                  conv2d_25[0][0]
#                                                                  conv2d_26[0][0]
#                                                                  conv2d_27[0][0]
#                                                                  conv2d_28[0][0]
#                                                                  conv2d_29[0][0]
#                                                                  conv2d_30[0][0]
#                                                                  conv2d_31[0][0]
#                                                                  conv2d_32[0][0]
#                                                                  conv2d_33[0][0]
#                                                                  conv2d_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 56, 56, 128)  512         concatenate[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 56, 56, 128)  0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 56, 56, 256)  32768       activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 56, 56, 256)  1024        conv2d_35[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 256)          0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# reshape (Reshape)               (None, 1, 1, 256)    0           global_average_pooling2d[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 1, 1, 16)     4096        reshape[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 56, 56, 256)  16384       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 1, 1, 256)    4096        dense[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 56, 56, 256)  1024        conv2d_1[0][0]
# __________________________________________________________________________________________________
# multiply (Multiply)             (None, 56, 56, 256)  0           batch_normalization_4[0][0]
#                                                                  dense_1[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 56, 56, 256)  0           batch_normalization_1[0][0]
#                                                                  multiply[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 56, 56, 256)  0           add[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 56, 56, 128)  32768       activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 56, 56, 128)  512         conv2d_36[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 56, 56, 128)  0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# lambda_32 (Lambda)              (None, 56, 56, 4)    0           activation_4[0][0]
# __________________________________________________________________________________________________
# lambda_33 (Lambda)              (None, 56, 56, 4)    0           activation_4[0][0]
# __________________________________________________________________________________________________
# lambda_34 (Lambda)              (None, 56, 56, 4)    0           activation_4[0][0]
# __________________________________________________________________________________________________
# lambda_35 (Lambda)              (None, 56, 56, 4)    0           activation_4[0][0]
# __________________________________________________________________________________________________
# lambda_36 (Lambda)              (None, 56, 56, 4)    0           activation_4[0][0]
# __________________________________________________________________________________________________
# lambda_37 (Lambda)              (None, 56, 56, 4)    0           activation_4[0][0]
# __________________________________________________________________________________________________
# lambda_38 (Lambda)              (None, 56, 56, 4)    0           activation_4[0][0]
# __________________________________________________________________________________________________
# lambda_39 (Lambda)              (None, 56, 56, 4)    0           activation_4[0][0]
# __________________________________________________________________________________________________
# lambda_40 (Lambda)              (None, 56, 56, 4)    0           activation_4[0][0]
# __________________________________________________________________________________________________
# lambda_41 (Lambda)              (None, 56, 56, 4)    0           activation_4[0][0]
# __________________________________________________________________________________________________
# lambda_42 (Lambda)              (None, 56, 56, 4)    0           activation_4[0][0]
# __________________________________________________________________________________________________
# lambda_43 (Lambda)              (None, 56, 56, 4)    0           activation_4[0][0]
# __________________________________________________________________________________________________
# lambda_44 (Lambda)              (None, 56, 56, 4)    0           activation_4[0][0]
# __________________________________________________________________________________________________
# lambda_45 (Lambda)              (None, 56, 56, 4)    0           activation_4[0][0]
# __________________________________________________________________________________________________
# lambda_46 (Lambda)              (None, 56, 56, 4)    0           activation_4[0][0]
# __________________________________________________________________________________________________
# lambda_47 (Lambda)              (None, 56, 56, 4)    0           activation_4[0][0]
# __________________________________________________________________________________________________
# lambda_48 (Lambda)              (None, 56, 56, 4)    0           activation_4[0][0]
# __________________________________________________________________________________________________
# lambda_49 (Lambda)              (None, 56, 56, 4)    0           activation_4[0][0]
# __________________________________________________________________________________________________
# lambda_50 (Lambda)              (None, 56, 56, 4)    0           activation_4[0][0]
# __________________________________________________________________________________________________
# lambda_51 (Lambda)              (None, 56, 56, 4)    0           activation_4[0][0]
# __________________________________________________________________________________________________
# lambda_52 (Lambda)              (None, 56, 56, 4)    0           activation_4[0][0]
# __________________________________________________________________________________________________
# lambda_53 (Lambda)              (None, 56, 56, 4)    0           activation_4[0][0]
# __________________________________________________________________________________________________
# lambda_54 (Lambda)              (None, 56, 56, 4)    0           activation_4[0][0]
# __________________________________________________________________________________________________
# lambda_55 (Lambda)              (None, 56, 56, 4)    0           activation_4[0][0]
# __________________________________________________________________________________________________
# lambda_56 (Lambda)              (None, 56, 56, 4)    0           activation_4[0][0]
# __________________________________________________________________________________________________
# lambda_57 (Lambda)              (None, 56, 56, 4)    0           activation_4[0][0]
# __________________________________________________________________________________________________
# lambda_58 (Lambda)              (None, 56, 56, 4)    0           activation_4[0][0]
# __________________________________________________________________________________________________
# lambda_59 (Lambda)              (None, 56, 56, 4)    0           activation_4[0][0]
# __________________________________________________________________________________________________
# lambda_60 (Lambda)              (None, 56, 56, 4)    0           activation_4[0][0]
# __________________________________________________________________________________________________
# lambda_61 (Lambda)              (None, 56, 56, 4)    0           activation_4[0][0]
# __________________________________________________________________________________________________
# lambda_62 (Lambda)              (None, 56, 56, 4)    0           activation_4[0][0]
# __________________________________________________________________________________________________
# lambda_63 (Lambda)              (None, 56, 56, 4)    0           activation_4[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 56, 56, 4)    144         lambda_32[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 56, 56, 4)    144         lambda_33[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 56, 56, 4)    144         lambda_34[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 56, 56, 4)    144         lambda_35[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 56, 56, 4)    144         lambda_36[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 56, 56, 4)    144         lambda_37[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 56, 56, 4)    144         lambda_38[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 56, 56, 4)    144         lambda_39[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 56, 56, 4)    144         lambda_40[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 56, 56, 4)    144         lambda_41[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 56, 56, 4)    144         lambda_42[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 56, 56, 4)    144         lambda_43[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 56, 56, 4)    144         lambda_44[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 56, 56, 4)    144         lambda_45[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 56, 56, 4)    144         lambda_46[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 56, 56, 4)    144         lambda_47[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 56, 56, 4)    144         lambda_48[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 56, 56, 4)    144         lambda_49[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 56, 56, 4)    144         lambda_50[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 56, 56, 4)    144         lambda_51[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 56, 56, 4)    144         lambda_52[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, 56, 56, 4)    144         lambda_53[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, 56, 56, 4)    144         lambda_54[0][0]
# __________________________________________________________________________________________________
# conv2d_60 (Conv2D)              (None, 56, 56, 4)    144         lambda_55[0][0]
# __________________________________________________________________________________________________
# conv2d_61 (Conv2D)              (None, 56, 56, 4)    144         lambda_56[0][0]
# __________________________________________________________________________________________________
# conv2d_62 (Conv2D)              (None, 56, 56, 4)    144         lambda_57[0][0]
# __________________________________________________________________________________________________
# conv2d_63 (Conv2D)              (None, 56, 56, 4)    144         lambda_58[0][0]
# __________________________________________________________________________________________________
# conv2d_64 (Conv2D)              (None, 56, 56, 4)    144         lambda_59[0][0]
# __________________________________________________________________________________________________
# conv2d_65 (Conv2D)              (None, 56, 56, 4)    144         lambda_60[0][0]
# __________________________________________________________________________________________________
# conv2d_66 (Conv2D)              (None, 56, 56, 4)    144         lambda_61[0][0]
# __________________________________________________________________________________________________
# conv2d_67 (Conv2D)              (None, 56, 56, 4)    144         lambda_62[0][0]
# __________________________________________________________________________________________________
# conv2d_68 (Conv2D)              (None, 56, 56, 4)    144         lambda_63[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 56, 56, 128)  0           conv2d_37[0][0]
#                                                                  conv2d_38[0][0]
#                                                                  conv2d_39[0][0]
#                                                                  conv2d_40[0][0]
#                                                                  conv2d_41[0][0]
#                                                                  conv2d_42[0][0]
#                                                                  conv2d_43[0][0]
#                                                                  conv2d_44[0][0]
#                                                                  conv2d_45[0][0]
#                                                                  conv2d_46[0][0]
#                                                                  conv2d_47[0][0]
#                                                                  conv2d_48[0][0]
#                                                                  conv2d_49[0][0]
#                                                                  conv2d_50[0][0]
#                                                                  conv2d_51[0][0]
#                                                                  conv2d_52[0][0]
#                                                                  conv2d_53[0][0]
#                                                                  conv2d_54[0][0]
#                                                                  conv2d_55[0][0]
#                                                                  conv2d_56[0][0]
#                                                                  conv2d_57[0][0]
#                                                                  conv2d_58[0][0]
#                                                                  conv2d_59[0][0]
#                                                                  conv2d_60[0][0]
#                                                                  conv2d_61[0][0]
#                                                                  conv2d_62[0][0]
#                                                                  conv2d_63[0][0]
#                                                                  conv2d_64[0][0]
#                                                                  conv2d_65[0][0]
#                                                                  conv2d_66[0][0]
#                                                                  conv2d_67[0][0]
#                                                                  conv2d_68[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 56, 56, 128)  512         concatenate_1[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 56, 56, 128)  0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_69 (Conv2D)              (None, 56, 56, 256)  32768       activation_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 56, 56, 256)  1024        conv2d_69[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_1 (Glo (None, 256)          0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, 1, 1, 256)    0           global_average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 1, 1, 16)     4096        reshape_1[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 1, 1, 256)    4096        dense_2[0][0]
# __________________________________________________________________________________________________
# multiply_1 (Multiply)           (None, 56, 56, 256)  0           batch_normalization_7[0][0]
#                                                                  dense_3[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 56, 56, 256)  0           activation_3[0][0]
#                                                                  multiply_1[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 56, 56, 256)  0           add_1[0][0]
# __________________________________________________________________________________________________
# conv2d_70 (Conv2D)              (None, 56, 56, 128)  32768       activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 56, 56, 128)  512         conv2d_70[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 56, 56, 128)  0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# lambda_64 (Lambda)              (None, 56, 56, 4)    0           activation_7[0][0]
# __________________________________________________________________________________________________
# lambda_65 (Lambda)              (None, 56, 56, 4)    0           activation_7[0][0]
# __________________________________________________________________________________________________
# lambda_66 (Lambda)              (None, 56, 56, 4)    0           activation_7[0][0]
# __________________________________________________________________________________________________
# lambda_67 (Lambda)              (None, 56, 56, 4)    0           activation_7[0][0]
# __________________________________________________________________________________________________
# lambda_68 (Lambda)              (None, 56, 56, 4)    0           activation_7[0][0]
# __________________________________________________________________________________________________
# lambda_69 (Lambda)              (None, 56, 56, 4)    0           activation_7[0][0]
# __________________________________________________________________________________________________
# lambda_70 (Lambda)              (None, 56, 56, 4)    0           activation_7[0][0]
# __________________________________________________________________________________________________
# lambda_71 (Lambda)              (None, 56, 56, 4)    0           activation_7[0][0]
# __________________________________________________________________________________________________
# lambda_72 (Lambda)              (None, 56, 56, 4)    0           activation_7[0][0]
# __________________________________________________________________________________________________
# lambda_73 (Lambda)              (None, 56, 56, 4)    0           activation_7[0][0]
# __________________________________________________________________________________________________
# lambda_74 (Lambda)              (None, 56, 56, 4)    0           activation_7[0][0]
# __________________________________________________________________________________________________
# lambda_75 (Lambda)              (None, 56, 56, 4)    0           activation_7[0][0]
# __________________________________________________________________________________________________
# lambda_76 (Lambda)              (None, 56, 56, 4)    0           activation_7[0][0]
# __________________________________________________________________________________________________
# lambda_77 (Lambda)              (None, 56, 56, 4)    0           activation_7[0][0]
# __________________________________________________________________________________________________
# lambda_78 (Lambda)              (None, 56, 56, 4)    0           activation_7[0][0]
# __________________________________________________________________________________________________
# lambda_79 (Lambda)              (None, 56, 56, 4)    0           activation_7[0][0]
# __________________________________________________________________________________________________
# lambda_80 (Lambda)              (None, 56, 56, 4)    0           activation_7[0][0]
# __________________________________________________________________________________________________
# lambda_81 (Lambda)              (None, 56, 56, 4)    0           activation_7[0][0]
# __________________________________________________________________________________________________
# lambda_82 (Lambda)              (None, 56, 56, 4)    0           activation_7[0][0]
# __________________________________________________________________________________________________
# lambda_83 (Lambda)              (None, 56, 56, 4)    0           activation_7[0][0]
# __________________________________________________________________________________________________
# lambda_84 (Lambda)              (None, 56, 56, 4)    0           activation_7[0][0]
# __________________________________________________________________________________________________
# lambda_85 (Lambda)              (None, 56, 56, 4)    0           activation_7[0][0]
# __________________________________________________________________________________________________
# lambda_86 (Lambda)              (None, 56, 56, 4)    0           activation_7[0][0]
# __________________________________________________________________________________________________
# lambda_87 (Lambda)              (None, 56, 56, 4)    0           activation_7[0][0]
# __________________________________________________________________________________________________
# lambda_88 (Lambda)              (None, 56, 56, 4)    0           activation_7[0][0]
# __________________________________________________________________________________________________
# lambda_89 (Lambda)              (None, 56, 56, 4)    0           activation_7[0][0]
# __________________________________________________________________________________________________
# lambda_90 (Lambda)              (None, 56, 56, 4)    0           activation_7[0][0]
# __________________________________________________________________________________________________
# lambda_91 (Lambda)              (None, 56, 56, 4)    0           activation_7[0][0]
# __________________________________________________________________________________________________
# lambda_92 (Lambda)              (None, 56, 56, 4)    0           activation_7[0][0]
# __________________________________________________________________________________________________
# lambda_93 (Lambda)              (None, 56, 56, 4)    0           activation_7[0][0]
# __________________________________________________________________________________________________
# lambda_94 (Lambda)              (None, 56, 56, 4)    0           activation_7[0][0]
# __________________________________________________________________________________________________
# lambda_95 (Lambda)              (None, 56, 56, 4)    0           activation_7[0][0]
# __________________________________________________________________________________________________
# conv2d_71 (Conv2D)              (None, 56, 56, 4)    144         lambda_64[0][0]
# __________________________________________________________________________________________________
# conv2d_72 (Conv2D)              (None, 56, 56, 4)    144         lambda_65[0][0]
# __________________________________________________________________________________________________
# conv2d_73 (Conv2D)              (None, 56, 56, 4)    144         lambda_66[0][0]
# __________________________________________________________________________________________________
# conv2d_74 (Conv2D)              (None, 56, 56, 4)    144         lambda_67[0][0]
# __________________________________________________________________________________________________
# conv2d_75 (Conv2D)              (None, 56, 56, 4)    144         lambda_68[0][0]
# __________________________________________________________________________________________________
# conv2d_76 (Conv2D)              (None, 56, 56, 4)    144         lambda_69[0][0]
# __________________________________________________________________________________________________
# conv2d_77 (Conv2D)              (None, 56, 56, 4)    144         lambda_70[0][0]
# __________________________________________________________________________________________________
# conv2d_78 (Conv2D)              (None, 56, 56, 4)    144         lambda_71[0][0]
# ...
# lambda_495 (Lambda)             (None, 7, 7, 32)     0           activation_46[0][0]
# __________________________________________________________________________________________________
# lambda_496 (Lambda)             (None, 7, 7, 32)     0           activation_46[0][0]
# __________________________________________________________________________________________________
# lambda_497 (Lambda)             (None, 7, 7, 32)     0           activation_46[0][0]
# __________________________________________________________________________________________________
# lambda_498 (Lambda)             (None, 7, 7, 32)     0           activation_46[0][0]
# __________________________________________________________________________________________________
# lambda_499 (Lambda)             (None, 7, 7, 32)     0           activation_46[0][0]
# __________________________________________________________________________________________________
# lambda_500 (Lambda)             (None, 7, 7, 32)     0           activation_46[0][0]
# __________________________________________________________________________________________________
# lambda_501 (Lambda)             (None, 7, 7, 32)     0           activation_46[0][0]
# __________________________________________________________________________________________________
# lambda_502 (Lambda)             (None, 7, 7, 32)     0           activation_46[0][0]
# __________________________________________________________________________________________________
# lambda_503 (Lambda)             (None, 7, 7, 32)     0           activation_46[0][0]
# __________________________________________________________________________________________________
# lambda_504 (Lambda)             (None, 7, 7, 32)     0           activation_46[0][0]
# __________________________________________________________________________________________________
# lambda_505 (Lambda)             (None, 7, 7, 32)     0           activation_46[0][0]
# __________________________________________________________________________________________________
# lambda_506 (Lambda)             (None, 7, 7, 32)     0           activation_46[0][0]
# __________________________________________________________________________________________________
# lambda_507 (Lambda)             (None, 7, 7, 32)     0           activation_46[0][0]
# __________________________________________________________________________________________________
# lambda_508 (Lambda)             (None, 7, 7, 32)     0           activation_46[0][0]
# __________________________________________________________________________________________________
# lambda_509 (Lambda)             (None, 7, 7, 32)     0           activation_46[0][0]
# __________________________________________________________________________________________________
# lambda_510 (Lambda)             (None, 7, 7, 32)     0           activation_46[0][0]
# __________________________________________________________________________________________________
# lambda_511 (Lambda)             (None, 7, 7, 32)     0           activation_46[0][0]
# __________________________________________________________________________________________________
# conv2d_516 (Conv2D)             (None, 7, 7, 32)     9216        lambda_480[0][0]
# __________________________________________________________________________________________________
# conv2d_517 (Conv2D)             (None, 7, 7, 32)     9216        lambda_481[0][0]
# __________________________________________________________________________________________________
# conv2d_518 (Conv2D)             (None, 7, 7, 32)     9216        lambda_482[0][0]
# __________________________________________________________________________________________________
# conv2d_519 (Conv2D)             (None, 7, 7, 32)     9216        lambda_483[0][0]
# __________________________________________________________________________________________________
# conv2d_520 (Conv2D)             (None, 7, 7, 32)     9216        lambda_484[0][0]
# __________________________________________________________________________________________________
# conv2d_521 (Conv2D)             (None, 7, 7, 32)     9216        lambda_485[0][0]
# __________________________________________________________________________________________________
# conv2d_522 (Conv2D)             (None, 7, 7, 32)     9216        lambda_486[0][0]
# __________________________________________________________________________________________________
# conv2d_523 (Conv2D)             (None, 7, 7, 32)     9216        lambda_487[0][0]
# __________________________________________________________________________________________________
# conv2d_524 (Conv2D)             (None, 7, 7, 32)     9216        lambda_488[0][0]
# __________________________________________________________________________________________________
# conv2d_525 (Conv2D)             (None, 7, 7, 32)     9216        lambda_489[0][0]
# __________________________________________________________________________________________________
# conv2d_526 (Conv2D)             (None, 7, 7, 32)     9216        lambda_490[0][0]
# __________________________________________________________________________________________________
# conv2d_527 (Conv2D)             (None, 7, 7, 32)     9216        lambda_491[0][0]
# __________________________________________________________________________________________________
# conv2d_528 (Conv2D)             (None, 7, 7, 32)     9216        lambda_492[0][0]
# __________________________________________________________________________________________________
# conv2d_529 (Conv2D)             (None, 7, 7, 32)     9216        lambda_493[0][0]
# __________________________________________________________________________________________________
# conv2d_530 (Conv2D)             (None, 7, 7, 32)     9216        lambda_494[0][0]
# __________________________________________________________________________________________________
# conv2d_531 (Conv2D)             (None, 7, 7, 32)     9216        lambda_495[0][0]
# __________________________________________________________________________________________________
# conv2d_532 (Conv2D)             (None, 7, 7, 32)     9216        lambda_496[0][0]
# __________________________________________________________________________________________________
# conv2d_533 (Conv2D)             (None, 7, 7, 32)     9216        lambda_497[0][0]
# __________________________________________________________________________________________________
# conv2d_534 (Conv2D)             (None, 7, 7, 32)     9216        lambda_498[0][0]
# __________________________________________________________________________________________________
# conv2d_535 (Conv2D)             (None, 7, 7, 32)     9216        lambda_499[0][0]
# __________________________________________________________________________________________________
# conv2d_536 (Conv2D)             (None, 7, 7, 32)     9216        lambda_500[0][0]
# __________________________________________________________________________________________________
# conv2d_537 (Conv2D)             (None, 7, 7, 32)     9216        lambda_501[0][0]
# __________________________________________________________________________________________________
# conv2d_538 (Conv2D)             (None, 7, 7, 32)     9216        lambda_502[0][0]
# __________________________________________________________________________________________________
# conv2d_539 (Conv2D)             (None, 7, 7, 32)     9216        lambda_503[0][0]
# __________________________________________________________________________________________________
# conv2d_540 (Conv2D)             (None, 7, 7, 32)     9216        lambda_504[0][0]
# __________________________________________________________________________________________________
# conv2d_541 (Conv2D)             (None, 7, 7, 32)     9216        lambda_505[0][0]
# __________________________________________________________________________________________________
# conv2d_542 (Conv2D)             (None, 7, 7, 32)     9216        lambda_506[0][0]
# __________________________________________________________________________________________________
# conv2d_543 (Conv2D)             (None, 7, 7, 32)     9216        lambda_507[0][0]
# __________________________________________________________________________________________________
# conv2d_544 (Conv2D)             (None, 7, 7, 32)     9216        lambda_508[0][0]
# __________________________________________________________________________________________________
# conv2d_545 (Conv2D)             (None, 7, 7, 32)     9216        lambda_509[0][0]
# __________________________________________________________________________________________________
# conv2d_546 (Conv2D)             (None, 7, 7, 32)     9216        lambda_510[0][0]
# __________________________________________________________________________________________________
# conv2d_547 (Conv2D)             (None, 7, 7, 32)     9216        lambda_511[0][0]
# __________________________________________________________________________________________________
# concatenate_15 (Concatenate)    (None, 7, 7, 1024)   0           conv2d_516[0][0]
#                                                                  conv2d_517[0][0]
#                                                                  conv2d_518[0][0]
#                                                                  conv2d_519[0][0]
#                                                                  conv2d_520[0][0]
#                                                                  conv2d_521[0][0]
#                                                                  conv2d_522[0][0]
#                                                                  conv2d_523[0][0]
#                                                                  conv2d_524[0][0]
#                                                                  conv2d_525[0][0]
#                                                                  conv2d_526[0][0]
#                                                                  conv2d_527[0][0]
#                                                                  conv2d_528[0][0]
#                                                                  conv2d_529[0][0]
#                                                                  conv2d_530[0][0]
#                                                                  conv2d_531[0][0]
#                                                                  conv2d_532[0][0]
#                                                                  conv2d_533[0][0]
#                                                                  conv2d_534[0][0]
#                                                                  conv2d_535[0][0]
#                                                                  conv2d_536[0][0]
#                                                                  conv2d_537[0][0]
#                                                                  conv2d_538[0][0]
#                                                                  conv2d_539[0][0]
#                                                                  conv2d_540[0][0]
#                                                                  conv2d_541[0][0]
#                                                                  conv2d_542[0][0]
#                                                                  conv2d_543[0][0]
#                                                                  conv2d_544[0][0]
#                                                                  conv2d_545[0][0]
#                                                                  conv2d_546[0][0]
#                                                                  conv2d_547[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 7, 7, 1024)   4096        concatenate_15[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 7, 7, 1024)   0           batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# conv2d_548 (Conv2D)             (None, 7, 7, 2048)   2097152     activation_47[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 7, 7, 2048)   8192        conv2d_548[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_15 (Gl (None, 2048)         0           batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# reshape_15 (Reshape)            (None, 1, 1, 2048)   0           global_average_pooling2d_15[0][0]
# __________________________________________________________________________________________________
# dense_30 (Dense)                (None, 1, 1, 128)    262144      reshape_15[0][0]
# __________________________________________________________________________________________________
# dense_31 (Dense)                (None, 1, 1, 2048)   262144      dense_30[0][0]
# __________________________________________________________________________________________________
# multiply_15 (Multiply)          (None, 7, 7, 2048)   0           batch_normalization_52[0][0]
#                                                                  dense_31[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 7, 7, 2048)   0           activation_45[0][0]
#                                                                  multiply_15[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 7, 7, 2048)   0           add_15[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_16 (Gl (None, 2048)         0           activation_48[0][0]
# __________________________________________________________________________________________________
# dense_32 (Dense)                (None, 257)          526336      global_average_pooling2d_16[0][0]
# ==================================================================================================
# Total params: 26,089,408
# Trainable params: 26,021,184
# Non-trainable params: 68,224
# __________________________________________________________________________________________________

# %%
# 폴더 생성

os.makedirs(os.path.join(dir,'model_output',number,model.name), exist_ok=True)
os.makedirs(os.path.join(dir,'train_valid_output',number), exist_ok=True)

# %%
# 참고 : https://github.com/OverLordGoldDragon/keras-adamw

import sys
sys.path.append('/content/drive/My Drive/Colab Notebooks/Paper')
import utils
import optimizers_v2
from utils import get_weight_decays, fill_dict_in_order
from utils import reset_seeds, K_eval
from optimizers_v2 import AdamW, NadamW, SGDW

# %%
# top-5 accuracy 출력
import functools
top5_acc = functools.partial(ks.metrics.top_k_categorical_accuracy, k=5)
top5_acc.__name__ = 'top5_acc'

# %%
#optimizer = SGDW(model=model, use_cosine_annealing=False, total_iterations = len(x_train) // batch_sizes, nesterov=True, momentum=0.9)
optimizer = AdamW(model=model, use_cosine_annealing=False, total_iterations = len(x_train) // batch_sizes)
#optimizer = Adam()
filepath =  os.path.join(dir,'model_output',number,model.name,'{epoch:03d}.h5')

callbacks_list = [ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_weights_only=False, save_best_only=True, mode='min'),
                  ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_weights_only=False, save_best_only=True, mode='max'),
                  #ReduceLROnPlateau(monitor='val_loss',patience=3,factor=0.1,min_lr=1e-5),
                  LearningRateScheduler(lr_schedule,verbose=1)
                  ]
                  
model.compile(optimizer, loss = 'categorical_crossentropy', metrics=['accuracy',top5_acc,macro_f1score])

# %%
######## flow_from_directory
history = model.fit(train_generator, steps_per_epoch=int(len(x_train)/batch_sizes),  validation_data = valid_generator, epochs=epochs , verbose=1 , callbacks = callbacks_list , validation_steps=int(len(x_valid)/batch_sizes))
# Out:
# Learning rate:  0.001
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 1/70
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_2/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_3/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_4/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_5/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_6/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_7/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_8/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_9/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_10/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_11/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_12/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_13/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_14/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_15/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_16/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_17/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_18/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_19/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_20/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_21/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_22/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_23/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_24/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_25/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_26/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_27/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_28/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_29/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_30/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_31/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_32/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_33/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_34/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_35/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for dense/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_1/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for dense_1/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_36/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_37/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_38/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_39/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_40/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_41/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_42/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_43/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_44/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_45/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_46/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_47/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_48/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_49/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_50/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_51/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_52/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_53/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_54/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_55/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_56/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_57/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_58/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_59/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_60/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_61/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_62/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_63/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_64/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_65/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_66/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_67/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_68/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_69/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for dense_2/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for dense_3/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_70/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_71/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_72/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_73/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_74/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_75/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_76/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_77/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_78/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_79/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_80/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_81/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_82/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_83/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_84/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_85/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_86/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_87/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_88/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_89/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_90/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_91/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_92/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_93/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_94/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_95/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_96/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_97/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_98/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_99/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_100/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_101/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_102/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_103/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for dense_4/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for dense_5/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_105/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_106/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_107/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_108/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_109/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_110/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_111/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_112/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_113/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_114/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_115/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_116/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_117/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_118/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_119/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_120/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_121/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_122/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_123/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_124/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_125/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_126/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_127/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_128/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_129/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_130/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_131/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_132/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_133/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_134/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_135/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_136/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_137/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_138/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for dense_6/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_104/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for dense_7/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_139/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_140/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_141/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_142/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_143/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_144/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_145/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_146/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_147/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_148/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_149/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_150/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_151/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_152/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_153/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_154/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_155/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_156/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_157/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_158/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_159/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_160/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_161/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_162/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_163/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_164/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_165/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_166/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_167/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_168/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_169/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_170/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_171/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_172/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for dense_8/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for dense_9/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_173/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_174/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_175/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_176/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_177/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_178/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_179/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_180/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_181/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_182/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_183/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_184/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_185/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_186/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_187/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_188/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_189/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_190/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_191/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_192/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_193/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_194/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_195/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_196/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_197/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_198/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_199/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_200/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_201/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_202/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_203/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_204/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_205/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_206/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for dense_10/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for dense_11/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_207/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_208/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_209/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_210/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_211/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_212/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_213/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_214/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_215/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_216/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_217/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_218/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_219/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_220/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_221/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_222/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_223/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_224/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_225/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_226/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_227/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_228/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_229/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_230/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_231/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_232/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_233/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_234/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_235/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_236/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_237/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_238/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_239/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_240/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for dense_12/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for dense_13/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_242/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_243/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_244/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_245/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_246/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_247/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_248/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_249/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_250/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_251/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_252/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_253/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_254/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_255/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_256/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_257/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_258/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_259/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_260/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_261/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_262/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_263/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_264/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_265/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_266/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_267/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_268/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_269/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_270/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_271/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_272/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_273/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_274/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_275/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for dense_14/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_241/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for dense_15/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_276/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_277/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_278/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_279/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_280/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_281/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_282/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_283/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_284/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_285/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_286/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_287/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_288/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_289/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_290/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_291/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_292/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_293/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_294/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_295/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_296/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_297/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_298/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_299/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_300/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_301/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_302/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_303/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_304/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_305/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_306/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_307/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_308/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_309/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for dense_16/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for dense_17/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_310/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_311/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_312/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_313/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_314/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_315/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_316/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_317/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_318/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_319/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_320/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_321/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_322/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_323/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_324/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_325/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_326/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_327/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_328/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_329/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_330/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_331/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_332/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_333/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_334/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_335/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_336/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_337/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_338/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_339/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_340/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_341/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_342/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_343/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for dense_18/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for dense_19/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_344/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_345/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_346/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_347/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_348/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_349/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_350/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_351/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_352/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_353/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_354/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_355/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_356/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_357/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_358/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_359/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_360/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_361/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_362/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_363/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_364/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_365/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_366/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_367/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_368/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_369/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_370/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_371/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_372/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_373/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_374/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_375/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_376/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_377/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for dense_20/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for dense_21/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_378/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_379/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_380/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_381/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_382/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_383/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_384/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_385/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_386/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_387/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_388/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_389/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_390/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_391/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_392/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_393/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_394/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_395/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_396/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_397/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_398/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_399/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_400/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_401/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_402/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_403/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_404/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_405/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_406/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_407/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_408/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_409/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_410/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_411/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for dense_22/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for dense_23/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_412/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_413/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_414/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_415/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_416/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_417/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_418/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_419/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_420/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_421/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_422/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_423/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_424/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_425/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_426/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_427/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_428/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_429/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_430/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_431/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_432/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_433/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_434/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_435/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_436/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_437/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_438/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_439/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_440/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_441/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_442/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_443/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_444/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_445/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for dense_24/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for dense_25/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_447/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_448/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_449/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_450/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_451/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_452/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_453/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_454/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_455/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_456/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_457/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_458/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_459/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_460/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_461/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_462/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_463/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_464/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_465/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_466/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_467/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_468/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_469/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_470/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_471/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_472/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_473/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_474/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_475/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_476/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_477/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_478/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_479/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_480/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for dense_26/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_446/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for dense_27/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_481/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_482/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_483/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_484/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_485/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_486/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_487/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_488/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_489/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_490/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_491/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_492/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_493/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_494/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_495/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_496/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_497/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_498/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_499/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_500/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_501/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_502/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_503/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_504/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_505/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_506/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_507/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_508/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_509/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_510/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_511/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_512/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_513/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_514/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for dense_28/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for dense_29/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_515/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_516/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_517/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_518/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_519/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_520/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_521/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_522/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_523/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_524/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_525/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_526/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_527/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_528/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_529/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_530/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_531/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_532/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_533/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_534/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_535/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_536/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_537/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_538/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_539/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_540/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_541/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_542/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_543/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_544/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_545/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_546/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_547/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for conv2d_548/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for dense_30/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for dense_31/kernel:0
# 0.0(L1), 7.231015604076667e-05(L2) weight decay set for dense_32/kernel:0
# 765/765 [==============================] - ETA: 0s - loss: 5.0244 - accuracy: 0.0845 - top5_acc: 0.1827 - macro_f1score: 0.0011
# Epoch 00001: val_loss improved from inf to 4.60374, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/SE_ResNext50/001.h5
#
# Epoch 00001: val_accuracy improved from -inf to 0.11290, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/SE_ResNext50/001.h5
# 765/765 [==============================] - 14433s 19s/step - loss: 5.0244 - accuracy: 0.0845 - top5_acc: 0.1827 - macro_f1score: 0.0011 - val_loss: 4.6037 - val_accuracy: 0.1129 - val_top5_acc: 0.2426 - val_macro_f1score: 0.0024
# Learning rate:  0.001
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 2/70
# 765/765 [==============================] - ETA: 0s - loss: 4.3312 - accuracy: 0.1452 - top5_acc: 0.2957 - macro_f1score: 0.0044
# Epoch 00002: val_loss improved from 4.60374 to 4.21432, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/SE_ResNext50/002.h5
#
# Epoch 00002: val_accuracy improved from 0.11290 to 0.16062, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/SE_ResNext50/002.h5
# 765/765 [==============================] - 525s 686ms/step - loss: 4.3312 - accuracy: 0.1452 - top5_acc: 0.2957 - macro_f1score: 0.0044 - val_loss: 4.2143 - val_accuracy: 0.1606 - val_top5_acc: 0.3253 - val_macro_f1score: 0.0048
# Learning rate:  0.001
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 3/70
# 765/765 [==============================] - ETA: 0s - loss: 3.9245 - accuracy: 0.1984 - top5_acc: 0.3782 - macro_f1score: 0.0071
# Epoch 00003: val_loss improved from 4.21432 to 3.94280, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/SE_ResNext50/003.h5
#
# Epoch 00003: val_accuracy improved from 0.16062 to 0.19892, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/SE_ResNext50/003.h5
# 765/765 [==============================] - 526s 688ms/step - loss: 3.9245 - accuracy: 0.1984 - top5_acc: 0.3782 - macro_f1score: 0.0071 - val_loss: 3.9428 - val_accuracy: 0.1989 - val_top5_acc: 0.3817 - val_macro_f1score: 0.0084
# Learning rate:  0.001
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 4/70
# 765/765 [==============================] - ETA: 0s - loss: 3.5489 - accuracy: 0.2497 - top5_acc: 0.4527 - macro_f1score: 0.0104
# Epoch 00004: val_loss improved from 3.94280 to 3.72994, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/SE_ResNext50/004.h5
#
# Epoch 00004: val_accuracy improved from 0.19892 to 0.23185, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/SE_ResNext50/004.h5
# 765/765 [==============================] - 529s 691ms/step - loss: 3.5489 - accuracy: 0.2497 - top5_acc: 0.4527 - macro_f1score: 0.0104 - val_loss: 3.7299 - val_accuracy: 0.2319 - val_top5_acc: 0.4466 - val_macro_f1score: 0.0110
# Learning rate:  0.001
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 5/70
# 765/765 [==============================] - ETA: 0s - loss: 3.2281 - accuracy: 0.2993 - top5_acc: 0.5216 - macro_f1score: 0.0142
# Epoch 00005: val_loss improved from 3.72994 to 3.29335, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/SE_ResNext50/005.h5
#
# Epoch 00005: val_accuracy improved from 0.23185 to 0.31250, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/SE_ResNext50/005.h5
# ...
#
# Epoch 00044: val_accuracy did not improve from 0.61593
# 765/765 [==============================] - 488s 638ms/step - loss: 0.1084 - accuracy: 0.9870 - top5_acc: 0.9997 - macro_f1score: 0.1104 - val_loss: 1.8873 - val_accuracy: 0.6015 - val_top5_acc: 0.7967 - val_macro_f1score: 0.0606
# Learning rate:  0.0001
#
# Epoch 00045: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 45/70
# 765/765 [==============================] - ETA: 0s - loss: 0.1174 - accuracy: 0.9851 - top5_acc: 0.9994 - macro_f1score: 0.1104
# Epoch 00045: val_loss did not improve from 1.85227
#
# Epoch 00045: val_accuracy did not improve from 0.61593
# 765/765 [==============================] - 484s 633ms/step - loss: 0.1174 - accuracy: 0.9851 - top5_acc: 0.9994 - macro_f1score: 0.1104 - val_loss: 1.8887 - val_accuracy: 0.6042 - val_top5_acc: 0.7940 - val_macro_f1score: 0.0613
# Learning rate:  0.0001
#
# Epoch 00046: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 46/70
# 765/765 [==============================] - ETA: 0s - loss: 0.1166 - accuracy: 0.9853 - top5_acc: 0.9996 - macro_f1score: 0.1101
# Epoch 00046: val_loss did not improve from 1.85227
#
# Epoch 00046: val_accuracy did not improve from 0.61593
# 765/765 [==============================] - 480s 627ms/step - loss: 0.1166 - accuracy: 0.9853 - top5_acc: 0.9996 - macro_f1score: 0.1101 - val_loss: 1.8580 - val_accuracy: 0.6035 - val_top5_acc: 0.7944 - val_macro_f1score: 0.0597
# Learning rate:  0.0001
#
# Epoch 00047: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 47/70
# 765/765 [==============================] - ETA: 0s - loss: 0.1169 - accuracy: 0.9850 - top5_acc: 0.9998 - macro_f1score: 0.1108
# Epoch 00047: val_loss did not improve from 1.85227
#
# Epoch 00047: val_accuracy did not improve from 0.61593
# 765/765 [==============================] - 486s 635ms/step - loss: 0.1169 - accuracy: 0.9850 - top5_acc: 0.9998 - macro_f1score: 0.1108 - val_loss: 1.8991 - val_accuracy: 0.6018 - val_top5_acc: 0.7913 - val_macro_f1score: 0.0593
# Learning rate:  0.0001
#
# Epoch 00048: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 48/70
# 765/765 [==============================] - ETA: 0s - loss: 0.1214 - accuracy: 0.9839 - top5_acc: 0.9996 - macro_f1score: 0.1104
# Epoch 00048: val_loss did not improve from 1.85227
#
# Epoch 00048: val_accuracy did not improve from 0.61593
# 765/765 [==============================] - 485s 634ms/step - loss: 0.1214 - accuracy: 0.9839 - top5_acc: 0.9996 - macro_f1score: 0.1104 - val_loss: 1.9060 - val_accuracy: 0.6032 - val_top5_acc: 0.7903 - val_macro_f1score: 0.0596
# Learning rate:  0.0001
#
# Epoch 00049: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 49/70
# 765/765 [==============================] - ETA: 0s - loss: 0.1229 - accuracy: 0.9842 - top5_acc: 0.9996 - macro_f1score: 0.1103
# Epoch 00049: val_loss did not improve from 1.85227
#
# Epoch 00049: val_accuracy did not improve from 0.61593
# 765/765 [==============================] - 482s 630ms/step - loss: 0.1229 - accuracy: 0.9842 - top5_acc: 0.9996 - macro_f1score: 0.1103 - val_loss: 1.8667 - val_accuracy: 0.6139 - val_top5_acc: 0.7913 - val_macro_f1score: 0.0608
# Learning rate:  0.0001
#
# Epoch 00050: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 50/70
# 765/765 [==============================] - ETA: 0s - loss: 0.1230 - accuracy: 0.9846 - top5_acc: 0.9996 - macro_f1score: 0.1100
# Epoch 00050: val_loss did not improve from 1.85227
#
# Epoch 00050: val_accuracy did not improve from 0.61593
# 765/765 [==============================] - 484s 633ms/step - loss: 0.1230 - accuracy: 0.9846 - top5_acc: 0.9996 - macro_f1score: 0.1100 - val_loss: 1.9089 - val_accuracy: 0.5954 - val_top5_acc: 0.7856 - val_macro_f1score: 0.0591
# Learning rate:  0.0001
#
# Epoch 00051: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 51/70
# 765/765 [==============================] - ETA: 0s - loss: 0.1263 - accuracy: 0.9839 - top5_acc: 0.9998 - macro_f1score: 0.1099
# Epoch 00051: val_loss did not improve from 1.85227
#
# Epoch 00051: val_accuracy did not improve from 0.61593
# 765/765 [==============================] - 487s 636ms/step - loss: 0.1263 - accuracy: 0.9839 - top5_acc: 0.9998 - macro_f1score: 0.1099 - val_loss: 1.9682 - val_accuracy: 0.5911 - val_top5_acc: 0.7836 - val_macro_f1score: 0.0575
# Learning rate:  0.0001
#
# Epoch 00052: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 52/70
# 765/765 [==============================] - ETA: 0s - loss: 0.1347 - accuracy: 0.9810 - top5_acc: 0.9997 - macro_f1score: 0.1097
# Epoch 00052: val_loss did not improve from 1.85227
#
# Epoch 00052: val_accuracy did not improve from 0.61593
# 765/765 [==============================] - 499s 653ms/step - loss: 0.1347 - accuracy: 0.9810 - top5_acc: 0.9997 - macro_f1score: 0.1097 - val_loss: 1.9875 - val_accuracy: 0.5931 - val_top5_acc: 0.7776 - val_macro_f1score: 0.0595
# Learning rate:  0.0001
#
# Epoch 00053: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 53/70
# 765/765 [==============================] - ETA: 0s - loss: 0.1388 - accuracy: 0.9801 - top5_acc: 0.9993 - macro_f1score: 0.1090
# Epoch 00053: val_loss did not improve from 1.85227
#
# Epoch 00053: val_accuracy did not improve from 0.61593
# 765/765 [==============================] - 512s 669ms/step - loss: 0.1388 - accuracy: 0.9801 - top5_acc: 0.9993 - macro_f1score: 0.1090 - val_loss: 1.9765 - val_accuracy: 0.5890 - val_top5_acc: 0.7786 - val_macro_f1score: 0.0575
# Learning rate:  0.0001
#
# Epoch 00054: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 54/70
# 765/765 [==============================] - ETA: 0s - loss: 0.1426 - accuracy: 0.9784 - top5_acc: 0.9994 - macro_f1score: 0.1092
# Epoch 00054: val_loss did not improve from 1.85227
#
# Epoch 00054: val_accuracy did not improve from 0.61593
# 765/765 [==============================] - 506s 662ms/step - loss: 0.1426 - accuracy: 0.9784 - top5_acc: 0.9994 - macro_f1score: 0.1092 - val_loss: 1.9387 - val_accuracy: 0.5877 - val_top5_acc: 0.7897 - val_macro_f1score: 0.0568
# Learning rate:  0.0001
#
# Epoch 00055: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 55/70
# 765/765 [==============================] - ETA: 0s - loss: 0.1511 - accuracy: 0.9780 - top5_acc: 0.9991 - macro_f1score: 0.1084
# Epoch 00055: val_loss did not improve from 1.85227
#
# Epoch 00055: val_accuracy did not improve from 0.61593
# 765/765 [==============================] - 501s 655ms/step - loss: 0.1511 - accuracy: 0.9780 - top5_acc: 0.9991 - macro_f1score: 0.1084 - val_loss: 1.9932 - val_accuracy: 0.5843 - val_top5_acc: 0.7759 - val_macro_f1score: 0.0581
# Learning rate:  0.0001
#
# Epoch 00056: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 56/70
# 765/765 [==============================] - ETA: 0s - loss: 0.1540 - accuracy: 0.9759 - top5_acc: 0.9992 - macro_f1score: 0.1083
# Epoch 00056: val_loss did not improve from 1.85227
#
# Epoch 00056: val_accuracy did not improve from 0.61593
# 765/765 [==============================] - 495s 647ms/step - loss: 0.1540 - accuracy: 0.9759 - top5_acc: 0.9992 - macro_f1score: 0.1083 - val_loss: 2.1034 - val_accuracy: 0.5716 - val_top5_acc: 0.7655 - val_macro_f1score: 0.0565
# Learning rate:  0.0001
#
# Epoch 00057: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 57/70
# 765/765 [==============================] - ETA: 0s - loss: 0.1575 - accuracy: 0.9765 - top5_acc: 0.9995 - macro_f1score: 0.1082
# Epoch 00057: val_loss did not improve from 1.85227
#
# Epoch 00057: val_accuracy did not improve from 0.61593
# 765/765 [==============================] - 493s 645ms/step - loss: 0.1575 - accuracy: 0.9765 - top5_acc: 0.9995 - macro_f1score: 0.1082 - val_loss: 1.9898 - val_accuracy: 0.5924 - val_top5_acc: 0.7849 - val_macro_f1score: 0.0593
# Learning rate:  0.0001
#
# Epoch 00058: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 58/70
# 765/765 [==============================] - ETA: 0s - loss: 0.1650 - accuracy: 0.9723 - top5_acc: 0.9992 - macro_f1score: 0.1076
# Epoch 00058: val_loss did not improve from 1.85227
#
# Epoch 00058: val_accuracy did not improve from 0.61593
# 765/765 [==============================] - 497s 650ms/step - loss: 0.1650 - accuracy: 0.9723 - top5_acc: 0.9992 - macro_f1score: 0.1076 - val_loss: 2.0332 - val_accuracy: 0.5746 - val_top5_acc: 0.7715 - val_macro_f1score: 0.0566
# Learning rate:  0.0001
#
# Epoch 00059: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 59/70
# 765/765 [==============================] - ETA: 0s - loss: 0.1699 - accuracy: 0.9716 - top5_acc: 0.9988 - macro_f1score: 0.1072
# Epoch 00059: val_loss did not improve from 1.85227
#
# Epoch 00059: val_accuracy did not improve from 0.61593
# 765/765 [==============================] - 495s 647ms/step - loss: 0.1699 - accuracy: 0.9716 - top5_acc: 0.9988 - macro_f1score: 0.1072 - val_loss: 2.1531 - val_accuracy: 0.5595 - val_top5_acc: 0.7540 - val_macro_f1score: 0.0559
# Learning rate:  0.0001
#
# Epoch 00060: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 60/70
# 765/765 [==============================] - ETA: 0s - loss: 0.1772 - accuracy: 0.9705 - top5_acc: 0.9990 - macro_f1score: 0.1071
# Epoch 00060: val_loss did not improve from 1.85227
#
# Epoch 00060: val_accuracy did not improve from 0.61593
# 765/765 [==============================] - 489s 639ms/step - loss: 0.1772 - accuracy: 0.9705 - top5_acc: 0.9990 - macro_f1score: 0.1071 - val_loss: 2.0778 - val_accuracy: 0.5692 - val_top5_acc: 0.7644 - val_macro_f1score: 0.0561
# Learning rate:  1e-05
#
# Epoch 00061: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 61/70
# 765/765 [==============================] - ETA: 0s - loss: 0.1083 - accuracy: 0.9881 - top5_acc: 0.9995 - macro_f1score: 0.1112
# Epoch 00061: val_loss improved from 1.85227 to 1.73518, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/SE_ResNext50/061.h5
#
# Epoch 00061: val_accuracy improved from 0.61593 to 0.62198, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/SE_ResNext50/061.h5
# 765/765 [==============================] - 499s 653ms/step - loss: 0.1083 - accuracy: 0.9881 - top5_acc: 0.9995 - macro_f1score: 0.1112 - val_loss: 1.7352 - val_accuracy: 0.6220 - val_top5_acc: 0.8085 - val_macro_f1score: 0.0608
# Learning rate:  1e-05
#
# Epoch 00062: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 62/70
# 765/765 [==============================] - ETA: 0s - loss: 0.0924 - accuracy: 0.9937 - top5_acc: 1.0000 - macro_f1score: 0.1122
# Epoch 00062: val_loss improved from 1.73518 to 1.72064, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/SE_ResNext50/062.h5
#
# Epoch 00062: val_accuracy improved from 0.62198 to 0.62601, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/SE_ResNext50/062.h5
# 765/765 [==============================] - 498s 651ms/step - loss: 0.0924 - accuracy: 0.9937 - top5_acc: 1.0000 - macro_f1score: 0.1122 - val_loss: 1.7206 - val_accuracy: 0.6260 - val_top5_acc: 0.8044 - val_macro_f1score: 0.0610
# Learning rate:  1e-05
#
# Epoch 00063: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 63/70
# 765/765 [==============================] - ETA: 0s - loss: 0.0955 - accuracy: 0.9952 - top5_acc: 0.9999 - macro_f1score: 0.1125
# Epoch 00063: val_loss improved from 1.72064 to 1.69247, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/SE_ResNext50/063.h5
#
# Epoch 00063: val_accuracy improved from 0.62601 to 0.63038, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/SE_ResNext50/063.h5
# 765/765 [==============================] - 511s 668ms/step - loss: 0.0955 - accuracy: 0.9952 - top5_acc: 0.9999 - macro_f1score: 0.1125 - val_loss: 1.6925 - val_accuracy: 0.6304 - val_top5_acc: 0.8085 - val_macro_f1score: 0.0601
# Learning rate:  1e-05
#
# Epoch 00064: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 64/70
# 765/765 [==============================] - ETA: 0s - loss: 0.1082 - accuracy: 0.9951 - top5_acc: 0.9998 - macro_f1score: 0.1121
# Epoch 00064: val_loss did not improve from 1.69247
#
# Epoch 00064: val_accuracy did not improve from 0.63038
# 765/765 [==============================] - 499s 652ms/step - loss: 0.1082 - accuracy: 0.9951 - top5_acc: 0.9998 - macro_f1score: 0.1121 - val_loss: 1.7015 - val_accuracy: 0.6247 - val_top5_acc: 0.8054 - val_macro_f1score: 0.0590
# Learning rate:  1e-05
#
# Epoch 00065: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 65/70
# 765/765 [==============================] - ETA: 0s - loss: 0.1191 - accuracy: 0.9951 - top5_acc: 1.0000 - macro_f1score: 0.1114
# Epoch 00065: val_loss improved from 1.69247 to 1.69051, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/SE_ResNext50/065.h5
#
# Epoch 00065: val_accuracy did not improve from 0.63038
# 765/765 [==============================] - 508s 664ms/step - loss: 0.1191 - accuracy: 0.9951 - top5_acc: 1.0000 - macro_f1score: 0.1114 - val_loss: 1.6905 - val_accuracy: 0.6206 - val_top5_acc: 0.8058 - val_macro_f1score: 0.0586
# Learning rate:  1e-05
#
# Epoch 00066: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 66/70
# 765/765 [==============================] - ETA: 0s - loss: 0.1326 - accuracy: 0.9942 - top5_acc: 1.0000 - macro_f1score: 0.1110
# Epoch 00066: val_loss improved from 1.69051 to 1.67238, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/SE_ResNext50/066.h5
#
# Epoch 00066: val_accuracy did not improve from 0.63038
# 765/765 [==============================] - 504s 659ms/step - loss: 0.1326 - accuracy: 0.9942 - top5_acc: 1.0000 - macro_f1score: 0.1110 - val_loss: 1.6724 - val_accuracy: 0.6260 - val_top5_acc: 0.8041 - val_macro_f1score: 0.0584
# Learning rate:  1e-05
#
# Epoch 00067: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 67/70
# 765/765 [==============================] - ETA: 0s - loss: 0.1471 - accuracy: 0.9937 - top5_acc: 0.9999 - macro_f1score: 0.1105
# Epoch 00067: val_loss did not improve from 1.67238
#
# Epoch 00067: val_accuracy did not improve from 0.63038
# 765/765 [==============================] - 488s 639ms/step - loss: 0.1471 - accuracy: 0.9937 - top5_acc: 0.9999 - macro_f1score: 0.1105 - val_loss: 1.6752 - val_accuracy: 0.6240 - val_top5_acc: 0.8007 - val_macro_f1score: 0.0583
# Learning rate:  1e-05
#
# Epoch 00068: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 68/70
# 765/765 [==============================] - ETA: 0s - loss: 0.1602 - accuracy: 0.9935 - top5_acc: 0.9999 - macro_f1score: 0.1103
# Epoch 00068: val_loss did not improve from 1.67238
#
# Epoch 00068: val_accuracy did not improve from 0.63038
# 765/765 [==============================] - 486s 636ms/step - loss: 0.1602 - accuracy: 0.9935 - top5_acc: 0.9999 - macro_f1score: 0.1103 - val_loss: 1.6782 - val_accuracy: 0.6247 - val_top5_acc: 0.8081 - val_macro_f1score: 0.0572
# Learning rate:  1e-05
#
# Epoch 00069: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 69/70
# 765/765 [==============================] - ETA: 0s - loss: 0.1771 - accuracy: 0.9929 - top5_acc: 0.9999 - macro_f1score: 0.1088
# Epoch 00069: val_loss did not improve from 1.67238
#
# Epoch 00069: val_accuracy did not improve from 0.63038
# 765/765 [==============================] - 489s 639ms/step - loss: 0.1771 - accuracy: 0.9929 - top5_acc: 0.9999 - macro_f1score: 0.1088 - val_loss: 1.6793 - val_accuracy: 0.6179 - val_top5_acc: 0.8044 - val_macro_f1score: 0.0565
# Learning rate:  1e-05
#
# Epoch 00070: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 70/70
# 765/765 [==============================] - ETA: 0s - loss: 0.1930 - accuracy: 0.9927 - top5_acc: 0.9998 - macro_f1score: 0.1083
# Epoch 00070: val_loss did not improve from 1.67238
#
# Epoch 00070: val_accuracy did not improve from 0.63038
# 765/765 [==============================] - 493s 645ms/step - loss: 0.1930 - accuracy: 0.9927 - top5_acc: 0.9998 - macro_f1score: 0.1083 - val_loss: 1.6841 - val_accuracy: 0.6240 - val_top5_acc: 0.8017 - val_macro_f1score: 0.0570

# %% [markdown]
# ### 2) SE-ResNext50 Evaluate

# %%
# 1. epoch=maximum
loss , acc, top5_acc, mf1 = model.evaluate(test_generator,steps=int(len(x_test)/batch_sizes))
print('[Test Loss: %.4f /  Test Top-1 Accuracy: %.4f / Test Top-5 Accuracy: %.4f / Test Macro f1: %.4f]\n' % (loss,acc,top5_acc,mf1))
# Out:
# 97/97 [==============================] - 1709s 18s/step - loss: 1.7115 - accuracy: 0.6108 - top5_acc: 0.8015 - macro_f1score: 0.0563
# [Test Loss: 1.7115 /  Test Top-1 Accuracy: 0.6108 / Test Top-5 Accuracy: 0.8015 / Test Macro f1: 0.0563]

# %%
loss=history.history['loss']
val_loss=history.history['val_loss']
acc=history.history['accuracy']
val_acc=history.history['val_accuracy']
top5_acc=history.history['top5_acc']
val_top5_acc=history.history['val_top5_acc']
f1=history.history['macro_f1score']
val_f1=history.history['val_macro_f1score']
epochs=range(1,len(acc)+1)

data = np.array([epochs,loss,val_loss,acc,val_acc,top5_acc,val_top5_acc,f1,val_f1]).T

# %%
# data save
# epochs, loss, val_loss, acc, val_acc, f1, val_f1

np.savetxt(os.path.join(dir,'train_valid_output',number,model.name+'.txt'),data)

# %%
# data import
data = np.loadtxt(os.path.join(dir,'train_valid_output',number,'SE_ResNext50.txt'))

# %%
epochs=data[:,0]
loss=data[:,1]
val_loss=data[:,2]
acc=data[:,3]
val_acc=data[:,4]
top5_acc=data[:,5]
val_top5_acc=data[:,6]

# %%
plt.plot(epochs[1:],acc[1:],'b',label='Training 1-Acc')
plt.plot(epochs[1:],val_acc[1:],'r',label='Validation 1-Acc')
plt.title('Training and Validation Top-1 Accuracy')
plt.legend()
plt.figure()

plt.plot(epochs[1:],top5_acc[1:],'b',label='Training 5-Acc')
plt.plot(epochs[1:],val_top5_acc[1:],'r',label='Validation 5-Acc')
plt.title('Training and Validation Top-5 Accuracy')
plt.legend()
plt.figure()

plt.plot(epochs[10:],loss[10:],'b',label='Training Loss')
plt.plot(epochs[10:],val_loss[10:],'r',label='Validation Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()

# %%
# 이 아래는 내가 인위적으로 살펴보고 싶은 epoch에 대해서 결과값 출력 / resnext18

# %%
model=load_model(os.path.join(dir,'model_output',number,'ResNext50','026.h5'),custom_objects={"macro_f1score": macro_f1score,"top5_acc":top5_acc})
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-40-0f3c6913a691> in <module>()
# ----> 1 model=load_model(os.path.join(dir,'model_output',number,'ResNext50','026.h5'),custom_objects={"macro_f1score": macro_f1score,"top5_acc":top5_acc})
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/saving/save.py in load_model(filepath, custom_objects, compile, options)
#     184     filepath = path_to_string(filepath)
#     185     if isinstance(filepath, six.string_types):
# --> 186       loader_impl.parse_saved_model(filepath)
#     187       return saved_model_load.load(filepath, compile, options)
#     188
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/saved_model/loader_impl.py in parse_saved_model(export_dir)
#     111                   (export_dir,
#     112                    constants.SAVED_MODEL_FILENAME_PBTXT,
# --> 113                    constants.SAVED_MODEL_FILENAME_PB))
#     114
#     115
#
# OSError: SavedModel file does not exist at: /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/ResNext50/026.h5/{saved_model.pbtxt|saved_model.pb}

# %%
# 2. epoch=?
loss , acc, top5_acc, mf1 = model.evaluate(test_generator,steps=int(len(x_test)/batch_sizes))
print('[Test Loss: %.4f /  Test Top-1 Accuracy: %.4f / Test Top-5 Accuracy: %.4f / Test Macro f1: %.4f]\n' % (loss,acc,top5_acc,mf1))
