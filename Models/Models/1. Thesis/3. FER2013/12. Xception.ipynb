# %%
### 참고 : https://github.com/fchollet/deep-learning-models/blob/master/xception.py

# %% [markdown]
# # [Xception]

# %% [markdown]
# *KU LeeDongGyu*

# %% [markdown]
# ## Contents
# ---

# %% [markdown]
# 1. Data Preprocessing
# ```
# 1) Data Import
# 2) Data Augmentation
# ```
# 2. Support Functions & Almost Original Xception
# ```
# 1) Support Functions
# 2) Almost Original Xception
# ```
# 3. Xception
# ```
# 1) Xception
# 2) Xception Evaluate
# ```

# %% [markdown]
# ### Install Packages

# %% [markdown]
# ### Module

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/My Drive/Colab Notebooks/Paper
# Out:
# /content/drive/My Drive/Colab Notebooks/Paper

# %%
from f1score import macro_f1score,weighted_f1score

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import cv2
import tensorflow as tf
from tensorflow import keras as ks
from tensorflow.keras import backend as K 
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, Input, Concatenate, ZeroPadding2D ,GlobalMaxPooling2D, Reshape , Lambda , Add, Multiply
from tensorflow.keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D, Activation, BatchNormalization, AveragePooling2D , ZeroPadding2D, SeparableConv2D , LeakyReLU
from tensorflow.keras.layers import add, concatenate, multiply
from tensorflow.keras.optimizers import Adam, RMSprop , SGD
from tensorflow.keras.callbacks import EarlyStopping , LearningRateScheduler, ModelCheckpoint, CSVLogger, Callback, ReduceLROnPlateau
from tensorflow.keras.regularizers import l1,l2,l1_l2
from tensorflow.keras.models import Model , load_model , Sequential
from tensorflow.keras.utils import plot_model , to_categorical, get_file
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
os.getcwd()
# Out:
# '/content/drive/My Drive/Colab Notebooks/Paper'

# %%
print(tf.__version__)
print(ks.__version__)
# Out:
# 2.3.0
# 2.4.0

# %%
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 12905485881805915625
# , name: "/device:XLA_CPU:0"
# device_type: "XLA_CPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 13619268816740094244
# physical_device_desc: "device: XLA_CPU device"
# , name: "/device:XLA_GPU:0"
# device_type: "XLA_GPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 4092502945925860957
# physical_device_desc: "device: XLA_GPU device"
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 15473775744
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 8567917184671414565
# physical_device_desc: "device: 0, name: Tesla V100-SXM2-16GB, pci bus id: 0000:00:04.0, compute capability: 7.0"
# ]

# %%
# !cat /proc/cpuinfo
# Out:
# processor	: 0
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 85
# model name	: Intel(R) Xeon(R) CPU @ 2.00GHz
# stepping	: 3
# microcode	: 0x1
# cpu MHz		: 2000.182
# cache size	: 39424 KB
# physical id	: 0
# siblings	: 4
# core id		: 0
# cpu cores	: 2
# apicid		: 0
# initial apicid	: 0
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm mpx avx512f avx512dq rdseed adx smap clflushopt clwb avx512cd avx512bw avx512vl xsaveopt xsavec xgetbv1 xsaves arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs taa
# bogomips	: 4000.36
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 46 bits physical, 48 bits virtual
# power management:
#
# processor	: 1
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 85
# model name	: Intel(R) Xeon(R) CPU @ 2.00GHz
# stepping	: 3
# microcode	: 0x1
# cpu MHz		: 2000.182
# cache size	: 39424 KB
# physical id	: 0
# siblings	: 4
# core id		: 1
# cpu cores	: 2
# apicid		: 2
# initial apicid	: 2
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm mpx avx512f avx512dq rdseed adx smap clflushopt clwb avx512cd avx512bw avx512vl xsaveopt xsavec xgetbv1 xsaves arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs taa
# bogomips	: 4000.36
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 46 bits physical, 48 bits virtual
# power management:
#
# processor	: 2
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 85
# model name	: Intel(R) Xeon(R) CPU @ 2.00GHz
# stepping	: 3
# microcode	: 0x1
# cpu MHz		: 2000.182
# cache size	: 39424 KB
# physical id	: 0
# siblings	: 4
# core id		: 0
# cpu cores	: 2
# apicid		: 1
# initial apicid	: 1
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm mpx avx512f avx512dq rdseed adx smap clflushopt clwb avx512cd avx512bw avx512vl xsaveopt xsavec xgetbv1 xsaves arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs taa
# bogomips	: 4000.36
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 46 bits physical, 48 bits virtual
# power management:
#
# processor	: 3
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 85
# model name	: Intel(R) Xeon(R) CPU @ 2.00GHz
# stepping	: 3
# microcode	: 0x1
# cpu MHz		: 2000.182
# cache size	: 39424 KB
# physical id	: 0
# siblings	: 4
# core id		: 1
# cpu cores	: 2
# apicid		: 3
# initial apicid	: 3
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm mpx avx512f avx512dq rdseed adx smap clflushopt clwb avx512cd avx512bw avx512vl xsaveopt xsavec xgetbv1 xsaves arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs taa
# bogomips	: 4000.36
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 46 bits physical, 48 bits virtual
# power management:

# %% [markdown]
# ## 1. Data Preprocessing
# ---

# %% [markdown]
# ### 1) Data Import

# %%
# 바꿔서 살펴 볼 것들
# CALTECH, CIFAR100, FER, MIT
data_name = 'FER'
gan_type = 'No_GAN'
number = '1'
size = 299 # sizes after cropping
super_size = 330 # sizes before cropping 
input_sizes = (size,size,3)
batch_sizes = 32
weight_decay = 1e-6
epochs = 70

# %%
# 참고 : https://stackoverflow.com/questions/32419510/how-to-get-reproducible-results-in-keras/52897216#52897216
# setting the seed number for random number generation for reproducibility.

from numpy.random import seed
import random


if number=='1':
    seed_num = 200225
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)
elif number=='2':
    seed_num = 727
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)
elif number=='3':
    seed_num = 115
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)
elif number=='4':
    seed_num = 501
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)
elif number=='5':
    seed_num = 517
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)

# %%
# data import

if data_name=='FER' :
    x_train =  np.zeros(28698)
    x_valid = np.zeros(3589)
    x_test = np.zeros(3588)
    classes = 7 
    tr_center = [0.50793296, 0.50793296, 0.50793296]
elif data_name=='MIT':
    x_train = np.zeros(12466)
    x_valid = np.zeros(1564)
    x_test = np.zeros(1590)
    classes = 67 
    tr_center = [0.47916578, 0.42029615, 0.36046057]
elif data_name=='CALTECH':
    x_train = np.zeros(24510)
    x_valid = np.zeros(2980)
    x_test = np.zeros(3118)
    classes = 257
    tr_center = [0.51397761, 0.49525248, 0.46555727]
elif data_name=='CIFAR100':
    x_train = np.zeros(44923)
    x_valid = np.zeros(5077)
    x_test = np.zeros(10000)
    classes = 100
    tr_center = [0.53442983, 0.51355958, 0.46462564]

# %%
dir = os.path.join(os.getcwd(),data_name,gan_type)

# %% [markdown]
# ### 2) Data Augmentation

# %%
# 참고 : https://jkjung-avt.github.io/keras-image-cropping/

def random_crop(img, random_crop_size):
    # Note: image_data_format is 'channel_last'
    assert img.shape[2] == 3 # img.shape[2] 가 3(rgb)이 아니면 assertion error 발생
    height, width = img.shape[0], img.shape[1]
    dy, dx = random_crop_size
    x = np.random.randint(0, width - dx + 1)
    y = np.random.randint(0, height - dy + 1)
    return img[y:(y+dy), x:(x+dx), :]


def crop_generator(batches, crop_length):
    """Take as input a Keras ImageGen (Iterator) and generate random
    crops from the image batches generated by the original iterator.
    """
    while True:
        batch_x, batch_y = next(batches)
        batch_crops = np.zeros((batch_x.shape[0], crop_length, crop_length, 3))
        for i in range(batch_x.shape[0]):
            batch_crops[i] = random_crop(batch_x[i], (crop_length, crop_length))
        yield (batch_crops, batch_y)

# %%
from tensorflow.keras.preprocessing.image import img_to_array,load_img
import glob

# 데이터 전체에 대해 centering 진행함.

def read_cal_image(img_path): 
    x = img_to_array(load_img(img_path)) # x는 채널별 평균값
    y = x.shape[0] * x.shape[1]# y는 데이터별 픽셀 수 (비중)

    x = 1/255. * x # scaling하고, centering값을 뽑아냄.
    x = np.mean(x, axis=(0,1))
    
    return np.hstack([x,y])

def calculate_centered_mean(dataset_path,x_train=x_train):
    num = len(x_train)
    space = np.empty((num,4))
    i=0

    for p in glob.glob(os.path.join(dataset_path,'*/*.*')) :
        space[i] = read_cal_image(p)
        i += 1

    ratio = space[:,3] / np.sum(space[:,3])

    return np.average(space[:,0:3],axis=0,weights=ratio)


# 아래의 함수를 돌려서 나온 결과값을 중심화 값으로 설정.

# train_mean = calculate_centered_mean(os.path.join(dir,'data/train')).reshape((1,1,3))

# %%
datagen_tr = ImageDataGenerator(
    rescale=1/255.,
    horizontal_flip=True,
    featurewise_center=True,
    featurewise_std_normalization=False,
    rotation_range=10,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=[0.9,1.0],
    fill_mode = 'nearest')
datagen_val = ImageDataGenerator(rescale=1/255.,featurewise_center=True)
datagen_tes = ImageDataGenerator(rescale=1/255.,featurewise_center=True)

# 원래는 이 자리에 fit 매서드를 써야하지만, 그냥 내가 중심화함수를 만들고 적용함. 

# 중심화 설정
datagen_tr.mean = np.array(tr_center, dtype=np.float32).reshape((1,1,3)) # RGB
datagen_val.mean = np.array(tr_center, dtype=np.float32).reshape((1,1,3)) # RGB
datagen_tes.mean = np.array(tr_center, dtype=np.float32).reshape((1,1,3)) # RGB

# %%
train_batches = datagen_tr.flow_from_directory(directory=os.path.join(dir,'data/train'),target_size=(super_size,super_size),batch_size=batch_sizes,class_mode='categorical') # fer : 28698 / mit : 12466 / caltech : 24509 / cifar : 44923
train_generator= crop_generator(train_batches, size)
valid_generator = datagen_val.flow_from_directory(directory=os.path.join(dir,'data/valid'),target_size=(size,size),batch_size=batch_sizes,class_mode='categorical') # fer : 3589 / mit : 1564 / caltech : 2980 / cifar : 5077
test_generator = datagen_tes.flow_from_directory(directory=os.path.join(dir,'data/test'),target_size=(size,size),batch_size=batch_sizes,class_mode='categorical') # fer : 3588 / mit : 1590 / caltech : 3118 / cifar : 10000
# Out:
# Found 28698 images belonging to 7 classes.
# Found 3589 images belonging to 7 classes.
# Found 3588 images belonging to 7 classes.

# %% [markdown]
# ## 2. Support Functions & Almost Original Xception
# ---

# %% [markdown]
# ### 1) Support Functions

# %%
# def lr_schedule(epoch):
#     init_lr = 1e-4
#     k = 0.04
#     lr = init_lr * np.exp(-k*epoch)
#     print('Learning rate: ', lr)
#     return lr

def lr_schedule(epoch):
    lr = 1e-3
    if epoch < 30:
        lr = lr
    elif epoch < 60 :
        lr = lr * 0.1
    else:
        lr = lr * 0.01
    print('Learning rate: ', lr)
    return lr

# %% [markdown]
# ### 2) Almost Original Xception

# %%
def Xception(input_shape=None, classes=1000, name = "Xception", weight_decay = weight_decay):


    img_input = Input(shape=input_shape)


    x = Conv2D(32, (3, 3), strides=(2, 2), use_bias=False, kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay), name='block1_conv1')(img_input)
    x = BatchNormalization(name='block1_conv1_bn')(x)
    x = Activation('relu', name='block1_conv1_act')(x)
    x = Conv2D(64, (3, 3), use_bias=False, kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay), name='block1_conv2')(x)
    x = BatchNormalization(name='block1_conv2_bn')(x)
    x = Activation('relu', name='block1_conv2_act')(x)

    residual = Conv2D(128, (1, 1), strides=(2, 2),
                      padding='same', use_bias=False, kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(x)
    residual = BatchNormalization()(residual)

    x = SeparableConv2D(128, (3, 3), padding='same', use_bias=False, depthwise_initializer='he_uniform', pointwise_initializer='he_uniform',depthwise_regularizer=l2(weight_decay), pointwise_regularizer=l2(weight_decay), name='block2_sepconv1')(x)
    x = BatchNormalization(name='block2_sepconv1_bn')(x)
    x = Activation('relu', name='block2_sepconv2_act')(x)
    x = SeparableConv2D(128, (3, 3), padding='same', use_bias=False, depthwise_initializer='he_uniform', pointwise_initializer='he_uniform',depthwise_regularizer=l2(weight_decay), pointwise_regularizer=l2(weight_decay), name='block2_sepconv2')(x)
    x = BatchNormalization(name='block2_sepconv2_bn')(x)

    x = MaxPooling2D((3, 3), strides=(2, 2), padding='same', name='block2_pool')(x)
    x = add([x, residual])

    residual = Conv2D(256, (1, 1), strides=(2, 2),
                      padding='same', use_bias=False, kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(x)
    residual = BatchNormalization()(residual)

    x = Activation('relu', name='block3_sepconv1_act')(x)
    x = SeparableConv2D(256, (3, 3), padding='same', use_bias=False, depthwise_initializer='he_uniform', pointwise_initializer='he_uniform',depthwise_regularizer=l2(weight_decay), pointwise_regularizer=l2(weight_decay), name='block3_sepconv1')(x)
    x = BatchNormalization(name='block3_sepconv1_bn')(x)
    x = Activation('relu', name='block3_sepconv2_act')(x)
    x = SeparableConv2D(256, (3, 3), padding='same', use_bias=False, depthwise_initializer='he_uniform', pointwise_initializer='he_uniform',depthwise_regularizer=l2(weight_decay), pointwise_regularizer=l2(weight_decay), name='block3_sepconv2')(x)
    x = BatchNormalization(name='block3_sepconv2_bn')(x)

    x = MaxPooling2D((3, 3), strides=(2, 2), padding='same', name='block3_pool')(x)
    x = add([x, residual])

    residual = Conv2D(728, (1, 1), strides=(2, 2),
                      padding='same', use_bias=False, kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(x)
    residual = BatchNormalization()(residual)

    x = Activation('relu', name='block4_sepconv1_act')(x)
    x = SeparableConv2D(728, (3, 3), padding='same', use_bias=False, depthwise_initializer='he_uniform', pointwise_initializer='he_uniform',depthwise_regularizer=l2(weight_decay), pointwise_regularizer=l2(weight_decay), name='block4_sepconv1')(x)
    x = BatchNormalization(name='block4_sepconv1_bn')(x)
    x = Activation('relu', name='block4_sepconv2_act')(x)
    x = SeparableConv2D(728, (3, 3), padding='same', use_bias=False, depthwise_initializer='he_uniform', pointwise_initializer='he_uniform',depthwise_regularizer=l2(weight_decay), pointwise_regularizer=l2(weight_decay), name='block4_sepconv2')(x)
    x = BatchNormalization(name='block4_sepconv2_bn')(x)

    x = MaxPooling2D((3, 3), strides=(2, 2), padding='same', name='block4_pool')(x)
    x = add([x, residual])

    for i in range(8):
        residual = x
        prefix = 'block' + str(i + 5)

        x = Activation('relu', name=prefix + '_sepconv1_act')(x)
        x = SeparableConv2D(728, (3, 3), padding='same', use_bias=False, depthwise_initializer='he_uniform', pointwise_initializer='he_uniform',depthwise_regularizer=l2(weight_decay), pointwise_regularizer=l2(weight_decay), name=prefix + '_sepconv1')(x)
        x = BatchNormalization(name=prefix + '_sepconv1_bn')(x)
        x = Activation('relu', name=prefix + '_sepconv2_act')(x)
        x = SeparableConv2D(728, (3, 3), padding='same', use_bias=False, depthwise_initializer='he_uniform', pointwise_initializer='he_uniform',depthwise_regularizer=l2(weight_decay), pointwise_regularizer=l2(weight_decay), name=prefix + '_sepconv2')(x)
        x = BatchNormalization(name=prefix + '_sepconv2_bn')(x)
        x = Activation('relu', name=prefix + '_sepconv3_act')(x)
        x = SeparableConv2D(728, (3, 3), padding='same', use_bias=False, depthwise_initializer='he_uniform', pointwise_initializer='he_uniform',depthwise_regularizer=l2(weight_decay), pointwise_regularizer=l2(weight_decay), name=prefix + '_sepconv3')(x)
        x = BatchNormalization(name=prefix + '_sepconv3_bn')(x)

        x = add([x, residual])

    residual = Conv2D(1024, (1, 1), strides=(2, 2),
                      padding='same', use_bias=False, kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(x)
    residual = BatchNormalization()(residual)

    x = Activation('relu', name='block13_sepconv1_act')(x)
    x = SeparableConv2D(728, (3, 3), padding='same', use_bias=False, depthwise_initializer='he_uniform', pointwise_initializer='he_uniform',depthwise_regularizer=l2(weight_decay), pointwise_regularizer=l2(weight_decay), name='block13_sepconv1')(x)
    x = BatchNormalization(name='block13_sepconv1_bn')(x)
    x = Activation('relu', name='block13_sepconv2_act')(x)
    x = SeparableConv2D(1024, (3, 3), padding='same', use_bias=False, depthwise_initializer='he_uniform', pointwise_initializer='he_uniform',depthwise_regularizer=l2(weight_decay), pointwise_regularizer=l2(weight_decay), name='block13_sepconv2')(x)
    x = BatchNormalization(name='block13_sepconv2_bn')(x)

    x = MaxPooling2D((3, 3), strides=(2, 2), padding='same', name='block13_pool')(x)
    x = add([x, residual])

    x = SeparableConv2D(1536, (3, 3), padding='same', use_bias=False, depthwise_initializer='he_uniform', pointwise_initializer='he_uniform',depthwise_regularizer=l2(weight_decay), pointwise_regularizer=l2(weight_decay), name='block14_sepconv1')(x)
    x = BatchNormalization(name='block14_sepconv1_bn')(x)
    x = Activation('relu', name='block14_sepconv1_act')(x)

    x = SeparableConv2D(2048, (3, 3), padding='same', use_bias=False, depthwise_initializer='he_uniform', pointwise_initializer='he_uniform',depthwise_regularizer=l2(weight_decay), pointwise_regularizer=l2(weight_decay), name='block14_sepconv2')(x)
    x = BatchNormalization(name='block14_sepconv2_bn')(x)
    x = Activation('relu', name='block14_sepconv2_act')(x)


    x = GlobalAveragePooling2D(name='avg_pool')(x)
    x = Dropout(0.5)(x)
    x = Dense(classes, activation='softmax', kernel_regularizer=l2(weight_decay), name='predictions')(x)


    inputs = img_input

    # Create model.
    model = Model(inputs, x, name=name)

    return model

# %% [markdown]
# ## 3. Xception
# ---

# %% [markdown]
# ### 1) Xception

# %%
model = Xception(input_sizes, classes=classes, name='Xception')

# %%
model.summary()
# Out:
# Model: "Xception"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 299, 299, 3) 0
# __________________________________________________________________________________________________
# block1_conv1 (Conv2D)           (None, 149, 149, 32) 864         input_1[0][0]
# __________________________________________________________________________________________________
# block1_conv1_bn (BatchNormaliza (None, 149, 149, 32) 128         block1_conv1[0][0]
# __________________________________________________________________________________________________
# block1_conv1_act (Activation)   (None, 149, 149, 32) 0           block1_conv1_bn[0][0]
# __________________________________________________________________________________________________
# block1_conv2 (Conv2D)           (None, 147, 147, 64) 18432       block1_conv1_act[0][0]
# __________________________________________________________________________________________________
# block1_conv2_bn (BatchNormaliza (None, 147, 147, 64) 256         block1_conv2[0][0]
# __________________________________________________________________________________________________
# block1_conv2_act (Activation)   (None, 147, 147, 64) 0           block1_conv2_bn[0][0]
# __________________________________________________________________________________________________
# block2_sepconv1 (SeparableConv2 (None, 147, 147, 128 8768        block1_conv2_act[0][0]
# __________________________________________________________________________________________________
# block2_sepconv1_bn (BatchNormal (None, 147, 147, 128 512         block2_sepconv1[0][0]
# __________________________________________________________________________________________________
# block2_sepconv2_act (Activation (None, 147, 147, 128 0           block2_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block2_sepconv2 (SeparableConv2 (None, 147, 147, 128 17536       block2_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block2_sepconv2_bn (BatchNormal (None, 147, 147, 128 512         block2_sepconv2[0][0]
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 74, 74, 128)  8192        block1_conv2_act[0][0]
# __________________________________________________________________________________________________
# block2_pool (MaxPooling2D)      (None, 74, 74, 128)  0           block2_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 74, 74, 128)  512         conv2d[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 74, 74, 128)  0           block2_pool[0][0]
#                                                                  batch_normalization[0][0]
# __________________________________________________________________________________________________
# block3_sepconv1_act (Activation (None, 74, 74, 128)  0           add[0][0]
# __________________________________________________________________________________________________
# block3_sepconv1 (SeparableConv2 (None, 74, 74, 256)  33920       block3_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block3_sepconv1_bn (BatchNormal (None, 74, 74, 256)  1024        block3_sepconv1[0][0]
# __________________________________________________________________________________________________
# block3_sepconv2_act (Activation (None, 74, 74, 256)  0           block3_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block3_sepconv2 (SeparableConv2 (None, 74, 74, 256)  67840       block3_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block3_sepconv2_bn (BatchNormal (None, 74, 74, 256)  1024        block3_sepconv2[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 37, 37, 256)  32768       add[0][0]
# __________________________________________________________________________________________________
# block3_pool (MaxPooling2D)      (None, 37, 37, 256)  0           block3_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 37, 37, 256)  1024        conv2d_1[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 37, 37, 256)  0           block3_pool[0][0]
#                                                                  batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# block4_sepconv1_act (Activation (None, 37, 37, 256)  0           add_1[0][0]
# __________________________________________________________________________________________________
# block4_sepconv1 (SeparableConv2 (None, 37, 37, 728)  188672      block4_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block4_sepconv1_bn (BatchNormal (None, 37, 37, 728)  2912        block4_sepconv1[0][0]
# __________________________________________________________________________________________________
# block4_sepconv2_act (Activation (None, 37, 37, 728)  0           block4_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block4_sepconv2 (SeparableConv2 (None, 37, 37, 728)  536536      block4_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block4_sepconv2_bn (BatchNormal (None, 37, 37, 728)  2912        block4_sepconv2[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 19, 19, 728)  186368      add_1[0][0]
# __________________________________________________________________________________________________
# block4_pool (MaxPooling2D)      (None, 19, 19, 728)  0           block4_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 19, 19, 728)  2912        conv2d_2[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 19, 19, 728)  0           block4_pool[0][0]
#                                                                  batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# block5_sepconv1_act (Activation (None, 19, 19, 728)  0           add_2[0][0]
# __________________________________________________________________________________________________
# block5_sepconv1 (SeparableConv2 (None, 19, 19, 728)  536536      block5_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block5_sepconv1_bn (BatchNormal (None, 19, 19, 728)  2912        block5_sepconv1[0][0]
# __________________________________________________________________________________________________
# block5_sepconv2_act (Activation (None, 19, 19, 728)  0           block5_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block5_sepconv2 (SeparableConv2 (None, 19, 19, 728)  536536      block5_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block5_sepconv2_bn (BatchNormal (None, 19, 19, 728)  2912        block5_sepconv2[0][0]
# __________________________________________________________________________________________________
# block5_sepconv3_act (Activation (None, 19, 19, 728)  0           block5_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block5_sepconv3 (SeparableConv2 (None, 19, 19, 728)  536536      block5_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block5_sepconv3_bn (BatchNormal (None, 19, 19, 728)  2912        block5_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 19, 19, 728)  0           block5_sepconv3_bn[0][0]
#                                                                  add_2[0][0]
# __________________________________________________________________________________________________
# block6_sepconv1_act (Activation (None, 19, 19, 728)  0           add_3[0][0]
# __________________________________________________________________________________________________
# block6_sepconv1 (SeparableConv2 (None, 19, 19, 728)  536536      block6_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block6_sepconv1_bn (BatchNormal (None, 19, 19, 728)  2912        block6_sepconv1[0][0]
# __________________________________________________________________________________________________
# block6_sepconv2_act (Activation (None, 19, 19, 728)  0           block6_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block6_sepconv2 (SeparableConv2 (None, 19, 19, 728)  536536      block6_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block6_sepconv2_bn (BatchNormal (None, 19, 19, 728)  2912        block6_sepconv2[0][0]
# __________________________________________________________________________________________________
# block6_sepconv3_act (Activation (None, 19, 19, 728)  0           block6_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block6_sepconv3 (SeparableConv2 (None, 19, 19, 728)  536536      block6_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block6_sepconv3_bn (BatchNormal (None, 19, 19, 728)  2912        block6_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 19, 19, 728)  0           block6_sepconv3_bn[0][0]
#                                                                  add_3[0][0]
# __________________________________________________________________________________________________
# block7_sepconv1_act (Activation (None, 19, 19, 728)  0           add_4[0][0]
# __________________________________________________________________________________________________
# block7_sepconv1 (SeparableConv2 (None, 19, 19, 728)  536536      block7_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block7_sepconv1_bn (BatchNormal (None, 19, 19, 728)  2912        block7_sepconv1[0][0]
# __________________________________________________________________________________________________
# block7_sepconv2_act (Activation (None, 19, 19, 728)  0           block7_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block7_sepconv2 (SeparableConv2 (None, 19, 19, 728)  536536      block7_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block7_sepconv2_bn (BatchNormal (None, 19, 19, 728)  2912        block7_sepconv2[0][0]
# __________________________________________________________________________________________________
# block7_sepconv3_act (Activation (None, 19, 19, 728)  0           block7_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block7_sepconv3 (SeparableConv2 (None, 19, 19, 728)  536536      block7_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block7_sepconv3_bn (BatchNormal (None, 19, 19, 728)  2912        block7_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 19, 19, 728)  0           block7_sepconv3_bn[0][0]
#                                                                  add_4[0][0]
# __________________________________________________________________________________________________
# block8_sepconv1_act (Activation (None, 19, 19, 728)  0           add_5[0][0]
# __________________________________________________________________________________________________
# block8_sepconv1 (SeparableConv2 (None, 19, 19, 728)  536536      block8_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block8_sepconv1_bn (BatchNormal (None, 19, 19, 728)  2912        block8_sepconv1[0][0]
# __________________________________________________________________________________________________
# block8_sepconv2_act (Activation (None, 19, 19, 728)  0           block8_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block8_sepconv2 (SeparableConv2 (None, 19, 19, 728)  536536      block8_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block8_sepconv2_bn (BatchNormal (None, 19, 19, 728)  2912        block8_sepconv2[0][0]
# __________________________________________________________________________________________________
# block8_sepconv3_act (Activation (None, 19, 19, 728)  0           block8_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block8_sepconv3 (SeparableConv2 (None, 19, 19, 728)  536536      block8_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block8_sepconv3_bn (BatchNormal (None, 19, 19, 728)  2912        block8_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 19, 19, 728)  0           block8_sepconv3_bn[0][0]
#                                                                  add_5[0][0]
# __________________________________________________________________________________________________
# block9_sepconv1_act (Activation (None, 19, 19, 728)  0           add_6[0][0]
# __________________________________________________________________________________________________
# block9_sepconv1 (SeparableConv2 (None, 19, 19, 728)  536536      block9_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block9_sepconv1_bn (BatchNormal (None, 19, 19, 728)  2912        block9_sepconv1[0][0]
# __________________________________________________________________________________________________
# block9_sepconv2_act (Activation (None, 19, 19, 728)  0           block9_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block9_sepconv2 (SeparableConv2 (None, 19, 19, 728)  536536      block9_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block9_sepconv2_bn (BatchNormal (None, 19, 19, 728)  2912        block9_sepconv2[0][0]
# __________________________________________________________________________________________________
# block9_sepconv3_act (Activation (None, 19, 19, 728)  0           block9_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block9_sepconv3 (SeparableConv2 (None, 19, 19, 728)  536536      block9_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block9_sepconv3_bn (BatchNormal (None, 19, 19, 728)  2912        block9_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 19, 19, 728)  0           block9_sepconv3_bn[0][0]
#                                                                  add_6[0][0]
# __________________________________________________________________________________________________
# block10_sepconv1_act (Activatio (None, 19, 19, 728)  0           add_7[0][0]
# __________________________________________________________________________________________________
# block10_sepconv1 (SeparableConv (None, 19, 19, 728)  536536      block10_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block10_sepconv1_bn (BatchNorma (None, 19, 19, 728)  2912        block10_sepconv1[0][0]
# __________________________________________________________________________________________________
# block10_sepconv2_act (Activatio (None, 19, 19, 728)  0           block10_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block10_sepconv2 (SeparableConv (None, 19, 19, 728)  536536      block10_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block10_sepconv2_bn (BatchNorma (None, 19, 19, 728)  2912        block10_sepconv2[0][0]
# __________________________________________________________________________________________________
# block10_sepconv3_act (Activatio (None, 19, 19, 728)  0           block10_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block10_sepconv3 (SeparableConv (None, 19, 19, 728)  536536      block10_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block10_sepconv3_bn (BatchNorma (None, 19, 19, 728)  2912        block10_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 19, 19, 728)  0           block10_sepconv3_bn[0][0]
#                                                                  add_7[0][0]
# __________________________________________________________________________________________________
# block11_sepconv1_act (Activatio (None, 19, 19, 728)  0           add_8[0][0]
# __________________________________________________________________________________________________
# block11_sepconv1 (SeparableConv (None, 19, 19, 728)  536536      block11_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block11_sepconv1_bn (BatchNorma (None, 19, 19, 728)  2912        block11_sepconv1[0][0]
# __________________________________________________________________________________________________
# block11_sepconv2_act (Activatio (None, 19, 19, 728)  0           block11_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block11_sepconv2 (SeparableConv (None, 19, 19, 728)  536536      block11_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block11_sepconv2_bn (BatchNorma (None, 19, 19, 728)  2912        block11_sepconv2[0][0]
# __________________________________________________________________________________________________
# block11_sepconv3_act (Activatio (None, 19, 19, 728)  0           block11_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block11_sepconv3 (SeparableConv (None, 19, 19, 728)  536536      block11_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block11_sepconv3_bn (BatchNorma (None, 19, 19, 728)  2912        block11_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 19, 19, 728)  0           block11_sepconv3_bn[0][0]
#                                                                  add_8[0][0]
# __________________________________________________________________________________________________
# block12_sepconv1_act (Activatio (None, 19, 19, 728)  0           add_9[0][0]
# __________________________________________________________________________________________________
# block12_sepconv1 (SeparableConv (None, 19, 19, 728)  536536      block12_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block12_sepconv1_bn (BatchNorma (None, 19, 19, 728)  2912        block12_sepconv1[0][0]
# __________________________________________________________________________________________________
# block12_sepconv2_act (Activatio (None, 19, 19, 728)  0           block12_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block12_sepconv2 (SeparableConv (None, 19, 19, 728)  536536      block12_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block12_sepconv2_bn (BatchNorma (None, 19, 19, 728)  2912        block12_sepconv2[0][0]
# __________________________________________________________________________________________________
# block12_sepconv3_act (Activatio (None, 19, 19, 728)  0           block12_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block12_sepconv3 (SeparableConv (None, 19, 19, 728)  536536      block12_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block12_sepconv3_bn (BatchNorma (None, 19, 19, 728)  2912        block12_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 19, 19, 728)  0           block12_sepconv3_bn[0][0]
#                                                                  add_9[0][0]
# __________________________________________________________________________________________________
# block13_sepconv1_act (Activatio (None, 19, 19, 728)  0           add_10[0][0]
# __________________________________________________________________________________________________
# block13_sepconv1 (SeparableConv (None, 19, 19, 728)  536536      block13_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block13_sepconv1_bn (BatchNorma (None, 19, 19, 728)  2912        block13_sepconv1[0][0]
# __________________________________________________________________________________________________
# block13_sepconv2_act (Activatio (None, 19, 19, 728)  0           block13_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block13_sepconv2 (SeparableConv (None, 19, 19, 1024) 752024      block13_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block13_sepconv2_bn (BatchNorma (None, 19, 19, 1024) 4096        block13_sepconv2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 10, 10, 1024) 745472      add_10[0][0]
# __________________________________________________________________________________________________
# block13_pool (MaxPooling2D)     (None, 10, 10, 1024) 0           block13_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 10, 10, 1024) 4096        conv2d_3[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 10, 10, 1024) 0           block13_pool[0][0]
#                                                                  batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# block14_sepconv1 (SeparableConv (None, 10, 10, 1536) 1582080     add_11[0][0]
# __________________________________________________________________________________________________
# block14_sepconv1_bn (BatchNorma (None, 10, 10, 1536) 6144        block14_sepconv1[0][0]
# __________________________________________________________________________________________________
# block14_sepconv1_act (Activatio (None, 10, 10, 1536) 0           block14_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block14_sepconv2 (SeparableConv (None, 10, 10, 2048) 3159552     block14_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block14_sepconv2_bn (BatchNorma (None, 10, 10, 2048) 8192        block14_sepconv2[0][0]
# __________________________________________________________________________________________________
# block14_sepconv2_act (Activatio (None, 10, 10, 2048) 0           block14_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# avg_pool (GlobalAveragePooling2 (None, 2048)         0           block14_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 2048)         0           avg_pool[0][0]
# __________________________________________________________________________________________________
# predictions (Dense)             (None, 7)            14343       dropout[0][0]
# ==================================================================================================
# Total params: 20,875,823
# Trainable params: 20,821,295
# Non-trainable params: 54,528
# __________________________________________________________________________________________________

# %%
# 폴더 생성

os.makedirs(os.path.join(dir,'model_output',number,model.name), exist_ok=True)
os.makedirs(os.path.join(dir,'train_valid_output',number), exist_ok=True)

# %%
# AdamW 시작 / AdamWR은 epoch을 500번은 돌려야 될 것 같아 힘듦.
# 참고 : https://github.com/OverLordGoldDragon/keras-adamw

import sys
sys.path.append('/content/drive/My Drive/Colab Notebooks/Paper')
import utils
import optimizers_v2
from utils import get_weight_decays, fill_dict_in_order
from utils import reset_seeds, K_eval
from optimizers_v2 import AdamW, NadamW, SGDW

# %%
# top-5 accuracy 출력
import functools
top5_acc = functools.partial(ks.metrics.top_k_categorical_accuracy, k=5)
top5_acc.__name__ = 'top5_acc'

# %%
optimizer = AdamW(model=model, use_cosine_annealing=False, total_iterations = len(x_train) // batch_sizes)
#optimizer = Adam()
filepath =  os.path.join(dir,'model_output',number,model.name,'{epoch:03d}.h5')

callbacks_list = [ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_weights_only=False, save_best_only=True, mode='min'),
                  ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_weights_only=False, save_best_only=True, mode='max'),
                  #ReduceLROnPlateau(monitor='val_loss',patience=3,factor=0.1,min_lr=1e-5),
                  LearningRateScheduler(lr_schedule,verbose=1)
                  ]
                  
model.compile(optimizer, loss = 'categorical_crossentropy', metrics=['accuracy',top5_acc,macro_f1score])

# %%
######## flow_from_directory
history = model.fit(train_generator, steps_per_epoch=int(len(x_train)/batch_sizes),  validation_data = valid_generator, epochs=epochs, verbose=1 , callbacks = callbacks_list , validation_steps=int(len(x_valid)/batch_sizes))
# Out:
# Learning rate:  0.001
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 1/70
# 0.0(L1), 3.3407655154706825e-08(L2) weight decay set for block1_conv1/kernel:0
# 0.0(L1), 3.3407655154706825e-08(L2) weight decay set for block1_conv2/kernel:0
# 0.0(L1), 3.3407655154706825e-08(L2) weight decay set for conv2d/kernel:0
# 0.0(L1), 3.3407655154706825e-08(L2) weight decay set for conv2d_1/kernel:0
# 0.0(L1), 3.3407655154706825e-08(L2) weight decay set for conv2d_2/kernel:0
# 0.0(L1), 3.3407655154706825e-08(L2) weight decay set for conv2d_3/kernel:0
# 0.0(L1), 3.3407655154706825e-08(L2) weight decay set for predictions/kernel:0
# 896/896 [==============================] - ETA: 0s - loss: 1.9071 - accuracy: 0.2356 - top5_acc: 0.8833 - macro_f1score: 0.0087
# Epoch 00001: val_loss improved from inf to 2.39540, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/Xception/001.h5
#
# Epoch 00001: val_accuracy improved from -inf to 0.20285, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/Xception/001.h5
# 896/896 [==============================] - 21457s 24s/step - loss: 1.9071 - accuracy: 0.2356 - top5_acc: 0.8833 - macro_f1score: 0.0087 - val_loss: 2.3954 - val_accuracy: 0.2028 - val_top5_acc: 0.8744 - val_macro_f1score: 0.0209
# Learning rate:  0.001
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 2/70
# 896/896 [==============================] - ETA: 0s - loss: 1.7260 - accuracy: 0.3255 - top5_acc: 0.9212 - macro_f1score: 0.0634
# Epoch 00002: val_loss did not improve from 2.39540
#
# Epoch 00002: val_accuracy improved from 0.20285 to 0.21177, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/Xception/002.h5
# 896/896 [==============================] - 693s 774ms/step - loss: 1.7260 - accuracy: 0.3255 - top5_acc: 0.9212 - macro_f1score: 0.0634 - val_loss: 7.0639 - val_accuracy: 0.2118 - val_top5_acc: 0.8636 - val_macro_f1score: 0.0904
# Learning rate:  0.001
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 3/70
# 896/896 [==============================] - ETA: 0s - loss: 1.4341 - accuracy: 0.4715 - top5_acc: 0.9611 - macro_f1score: 0.2221
# Epoch 00003: val_loss improved from 2.39540 to 1.48249, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/Xception/003.h5
#
# Epoch 00003: val_accuracy improved from 0.21177 to 0.44838, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/Xception/003.h5
# 896/896 [==============================] - 686s 766ms/step - loss: 1.4341 - accuracy: 0.4715 - top5_acc: 0.9611 - macro_f1score: 0.2221 - val_loss: 1.4825 - val_accuracy: 0.4484 - val_top5_acc: 0.9651 - val_macro_f1score: 0.2627
# Learning rate:  0.001
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 4/70
# 896/896 [==============================] - ETA: 0s - loss: 1.3006 - accuracy: 0.5241 - top5_acc: 0.9712 - macro_f1score: 0.2894
# Epoch 00004: val_loss improved from 1.48249 to 1.32898, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/Xception/004.h5
#
# Epoch 00004: val_accuracy improved from 0.44838 to 0.51228, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/Xception/004.h5
# 896/896 [==============================] - 684s 763ms/step - loss: 1.3006 - accuracy: 0.5241 - top5_acc: 0.9712 - macro_f1score: 0.2894 - val_loss: 1.3290 - val_accuracy: 0.5123 - val_top5_acc: 0.9693 - val_macro_f1score: 0.2946
# Learning rate:  0.001
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 5/70
# 896/896 [==============================] - ETA: 0s - loss: 1.2232 - accuracy: 0.5545 - top5_acc: 0.9778 - macro_f1score: 0.3322
# Epoch 00005: val_loss did not improve from 1.32898
#
# Epoch 00005: val_accuracy did not improve from 0.51228
# 896/896 [==============================] - 682s 761ms/step - loss: 1.2232 - accuracy: 0.5545 - top5_acc: 0.9778 - macro_f1score: 0.3322 - val_loss: 1.9757 - val_accuracy: 0.4116 - val_top5_acc: 0.9453 - val_macro_f1score: 0.2534
# Learning rate:  0.001
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 6/70
# 896/896 [==============================] - ETA: 0s - loss: 1.1690 - accuracy: 0.5744 - top5_acc: 0.9811 - macro_f1score: 0.3656
# Epoch 00006: val_loss did not improve from 1.32898
#
# Epoch 00006: val_accuracy did not improve from 0.51228
# 896/896 [==============================] - 682s 762ms/step - loss: 1.1690 - accuracy: 0.5744 - top5_acc: 0.9811 - macro_f1score: 0.3656 - val_loss: 1.5667 - val_accuracy: 0.4258 - val_top5_acc: 0.9450 - val_macro_f1score: 0.2539
# Learning rate:  0.001
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 7/70
# 896/896 [==============================] - ETA: 0s - loss: 1.1092 - accuracy: 0.6002 - top5_acc: 0.9844 - macro_f1score: 0.4027
# Epoch 00007: val_loss improved from 1.32898 to 1.27970, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/Xception/007.h5
#
# Epoch 00007: val_accuracy improved from 0.51228 to 0.54492, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/Xception/007.h5
# 896/896 [==============================] - 687s 766ms/step - loss: 1.1092 - accuracy: 0.6002 - top5_acc: 0.9844 - macro_f1score: 0.4027 - val_loss: 1.2797 - val_accuracy: 0.5449 - val_top5_acc: 0.9746 - val_macro_f1score: 0.3845
# Learning rate:  0.001
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 8/70
# 896/896 [==============================] - ETA: 0s - loss: 1.0734 - accuracy: 0.6142 - top5_acc: 0.9860 - macro_f1score: 0.4251
# Epoch 00008: val_loss improved from 1.27970 to 1.18385, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/Xception/008.h5
#
# Epoch 00008: val_accuracy improved from 0.54492 to 0.56557, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/Xception/008.h5
# 896/896 [==============================] - 683s 763ms/step - loss: 1.0734 - accuracy: 0.6142 - top5_acc: 0.9860 - macro_f1score: 0.4251 - val_loss: 1.1838 - val_accuracy: 0.5656 - val_top5_acc: 0.9841 - val_macro_f1score: 0.3685
# Learning rate:  0.001
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 9/70
# 896/896 [==============================] - ETA: 0s - loss: 1.0307 - accuracy: 0.6278 - top5_acc: 0.9868 - macro_f1score: 0.4515
# Epoch 00009: val_loss improved from 1.18385 to 1.14375, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/Xception/009.h5
#
# Epoch 00009: val_accuracy improved from 0.56557 to 0.59933, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/Xception/009.h5
# 896/896 [==============================] - 685s 765ms/step - loss: 1.0307 - accuracy: 0.6278 - top5_acc: 0.9868 - macro_f1score: 0.4515 - val_loss: 1.1437 - val_accuracy: 0.5993 - val_top5_acc: 0.9805 - val_macro_f1score: 0.4094
# Learning rate:  0.001
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 10/70
# 896/896 [==============================] - ETA: 0s - loss: 1.0052 - accuracy: 0.6429 - top5_acc: 0.9885 - macro_f1score: 0.4662
# Epoch 00010: val_loss improved from 1.14375 to 1.07143, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/Xception/010.h5
#
# Epoch 00010: val_accuracy improved from 0.59933 to 0.61607, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/Xception/010.h5
# 896/896 [==============================] - 685s 765ms/step - loss: 1.0052 - accuracy: 0.6429 - top5_acc: 0.9885 - macro_f1score: 0.4662 - val_loss: 1.0714 - val_accuracy: 0.6161 - val_top5_acc: 0.9841 - val_macro_f1score: 0.4026
# Learning rate:  0.001
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 11/70
# 896/896 [==============================] - ETA: 0s - loss: 0.9836 - accuracy: 0.6478 - top5_acc: 0.9897 - macro_f1score: 0.4823
# Epoch 00011: val_loss did not improve from 1.07143
#
# Epoch 00011: val_accuracy did not improve from 0.61607
# 896/896 [==============================] - 680s 759ms/step - loss: 0.9836 - accuracy: 0.6478 - top5_acc: 0.9897 - macro_f1score: 0.4823 - val_loss: 1.1895 - val_accuracy: 0.5790 - val_top5_acc: 0.9788 - val_macro_f1score: 0.4286
# Learning rate:  0.001
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 12/70
# 896/896 [==============================] - ETA: 0s - loss: 0.9594 - accuracy: 0.6588 - top5_acc: 0.9910 - macro_f1score: 0.4991
# Epoch 00012: val_loss did not improve from 1.07143
#
# Epoch 00012: val_accuracy did not improve from 0.61607
# 896/896 [==============================] - 680s 759ms/step - loss: 0.9594 - accuracy: 0.6588 - top5_acc: 0.9910 - macro_f1score: 0.4991 - val_loss: 1.0944 - val_accuracy: 0.6124 - val_top5_acc: 0.9844 - val_macro_f1score: 0.4542
# Learning rate:  0.001
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 13/70
# 896/896 [==============================] - ETA: 0s - loss: 0.9322 - accuracy: 0.6699 - top5_acc: 0.9909 - macro_f1score: 0.5166
# Epoch 00013: val_loss did not improve from 1.07143
#
# Epoch 00013: val_accuracy did not improve from 0.61607
# 896/896 [==============================] - 679s 758ms/step - loss: 0.9322 - accuracy: 0.6699 - top5_acc: 0.9909 - macro_f1score: 0.5166 - val_loss: 1.1269 - val_accuracy: 0.6099 - val_top5_acc: 0.9852 - val_macro_f1score: 0.4580
# Learning rate:  0.001
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 14/70
# 896/896 [==============================] - ETA: 0s - loss: 0.9113 - accuracy: 0.6768 - top5_acc: 0.9923 - macro_f1score: 0.5286
# Epoch 00014: val_loss improved from 1.07143 to 1.06827, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/Xception/014.h5
#
# Epoch 00014: val_accuracy improved from 0.61607 to 0.61998, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/Xception/014.h5
# 896/896 [==============================] - 683s 762ms/step - loss: 0.9113 - accuracy: 0.6768 - top5_acc: 0.9923 - macro_f1score: 0.5286 - val_loss: 1.0683 - val_accuracy: 0.6200 - val_top5_acc: 0.9866 - val_macro_f1score: 0.4488
# Learning rate:  0.001
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 15/70
# 896/896 [==============================] - ETA: 0s - loss: 0.8863 - accuracy: 0.6875 - top5_acc: 0.9930 - macro_f1score: 0.5438
# Epoch 00015: val_loss did not improve from 1.06827
#
# Epoch 00015: val_accuracy improved from 0.61998 to 0.63253, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/Xception/015.h5
# 896/896 [==============================] - 682s 761ms/step - loss: 0.8863 - accuracy: 0.6875 - top5_acc: 0.9930 - macro_f1score: 0.5438 - val_loss: 1.0793 - val_accuracy: 0.6325 - val_top5_acc: 0.9883 - val_macro_f1score: 0.4744
# Learning rate:  0.001
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 16/70
# 896/896 [==============================] - ETA: 0s - loss: 0.8639 - accuracy: 0.6992 - top5_acc: 0.9938 - macro_f1score: 0.5582
# Epoch 00016: val_loss did not improve from 1.06827
#
# Epoch 00016: val_accuracy did not improve from 0.63253
# 896/896 [==============================] - 680s 759ms/step - loss: 0.8639 - accuracy: 0.6992 - top5_acc: 0.9938 - macro_f1score: 0.5582 - val_loss: 1.1056 - val_accuracy: 0.6203 - val_top5_acc: 0.9883 - val_macro_f1score: 0.4799
# Learning rate:  0.001
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 17/70
# 896/896 [==============================] - ETA: 0s - loss: 0.8356 - accuracy: 0.7101 - top5_acc: 0.9940 - macro_f1score: 0.5779
# Epoch 00017: val_loss improved from 1.06827 to 1.01352, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/Xception/017.h5
#
# Epoch 00017: val_accuracy improved from 0.63253 to 0.65430, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/Xception/017.h5
# 896/896 [==============================] - 685s 764ms/step - loss: 0.8356 - accuracy: 0.7101 - top5_acc: 0.9940 - macro_f1score: 0.5779 - val_loss: 1.0135 - val_accuracy: 0.6543 - val_top5_acc: 0.9900 - val_macro_f1score: 0.5313
# Learning rate:  0.001
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 18/70
# 896/896 [==============================] - ETA: 0s - loss: 0.8109 - accuracy: 0.7213 - top5_acc: 0.9943 - macro_f1score: 0.5909
# Epoch 00018: val_loss did not improve from 1.01352
#
# Epoch 00018: val_accuracy did not improve from 0.65430
# 896/896 [==============================] - 681s 760ms/step - loss: 0.8109 - accuracy: 0.7213 - top5_acc: 0.9943 - macro_f1score: 0.5909 - val_loss: 1.0693 - val_accuracy: 0.6364 - val_top5_acc: 0.9877 - val_macro_f1score: 0.4961
# Learning rate:  0.001
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 19/70
# 896/896 [==============================] - ETA: 0s - loss: 0.7961 - accuracy: 0.7280 - top5_acc: 0.9953 - macro_f1score: 0.5996
# Epoch 00019: val_loss did not improve from 1.01352
#
# Epoch 00019: val_accuracy did not improve from 0.65430
# 896/896 [==============================] - 680s 758ms/step - loss: 0.7961 - accuracy: 0.7280 - top5_acc: 0.9953 - macro_f1score: 0.5996 - val_loss: 1.0740 - val_accuracy: 0.6521 - val_top5_acc: 0.9894 - val_macro_f1score: 0.5043
# Learning rate:  0.001
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 20/70
# 896/896 [==============================] - ETA: 0s - loss: 0.7643 - accuracy: 0.7406 - top5_acc: 0.9955 - macro_f1score: 0.6170
# Epoch 00020: val_loss did not improve from 1.01352
#
# Epoch 00020: val_accuracy did not improve from 0.65430
# 896/896 [==============================] - 680s 759ms/step - loss: 0.7643 - accuracy: 0.7406 - top5_acc: 0.9955 - macro_f1score: 0.6170 - val_loss: 1.3969 - val_accuracy: 0.5739 - val_top5_acc: 0.9833 - val_macro_f1score: 0.4360
# Learning rate:  0.001
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 21/70
# 896/896 [==============================] - ETA: 0s - loss: 0.7444 - accuracy: 0.7505 - top5_acc: 0.9967 - macro_f1score: 0.6282
# Epoch 00021: val_loss did not improve from 1.01352
#
# Epoch 00021: val_accuracy did not improve from 0.65430
# 896/896 [==============================] - 679s 757ms/step - loss: 0.7444 - accuracy: 0.7505 - top5_acc: 0.9967 - macro_f1score: 0.6282 - val_loss: 1.1567 - val_accuracy: 0.6264 - val_top5_acc: 0.9841 - val_macro_f1score: 0.4879
# Learning rate:  0.001
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 22/70
# 896/896 [==============================] - ETA: 0s - loss: 0.7193 - accuracy: 0.7602 - top5_acc: 0.9972 - macro_f1score: 0.6439
# Epoch 00022: val_loss did not improve from 1.01352
#
# Epoch 00022: val_accuracy did not improve from 0.65430
# 896/896 [==============================] - 678s 757ms/step - loss: 0.7193 - accuracy: 0.7602 - top5_acc: 0.9972 - macro_f1score: 0.6439 - val_loss: 1.1347 - val_accuracy: 0.6364 - val_top5_acc: 0.9844 - val_macro_f1score: 0.5057
# Learning rate:  0.001
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 23/70
# 896/896 [==============================] - ETA: 0s - loss: 0.6937 - accuracy: 0.7710 - top5_acc: 0.9971 - macro_f1score: 0.6540
# Epoch 00023: val_loss did not improve from 1.01352
#
# Epoch 00023: val_accuracy improved from 0.65430 to 0.65988, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/Xception/023.h5
# 896/896 [==============================] - 680s 758ms/step - loss: 0.6937 - accuracy: 0.7710 - top5_acc: 0.9971 - macro_f1score: 0.6540 - val_loss: 1.0846 - val_accuracy: 0.6599 - val_top5_acc: 0.9888 - val_macro_f1score: 0.5306
# Learning rate:  0.001
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 24/70
# 896/896 [==============================] - ETA: 0s - loss: 0.6687 - accuracy: 0.7775 - top5_acc: 0.9978 - macro_f1score: 0.6669
# Epoch 00024: val_loss did not improve from 1.01352
#
# Epoch 00024: val_accuracy did not improve from 0.65988
# 896/896 [==============================] - 678s 757ms/step - loss: 0.6687 - accuracy: 0.7775 - top5_acc: 0.9978 - macro_f1score: 0.6669 - val_loss: 1.1698 - val_accuracy: 0.6297 - val_top5_acc: 0.9852 - val_macro_f1score: 0.4797
# Learning rate:  0.001
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 25/70
# 896/896 [==============================] - ETA: 0s - loss: 0.6461 - accuracy: 0.7900 - top5_acc: 0.9982 - macro_f1score: 0.6803
# Epoch 00025: val_loss did not improve from 1.01352
#
# Epoch 00025: val_accuracy did not improve from 0.65988
# 896/896 [==============================] - 678s 756ms/step - loss: 0.6461 - accuracy: 0.7900 - top5_acc: 0.9982 - macro_f1score: 0.6803 - val_loss: 1.3406 - val_accuracy: 0.6222 - val_top5_acc: 0.9844 - val_macro_f1score: 0.4950
# Learning rate:  0.001
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 26/70
# 896/896 [==============================] - ETA: 0s - loss: 0.6254 - accuracy: 0.7970 - top5_acc: 0.9983 - macro_f1score: 0.6909
# Epoch 00026: val_loss did not improve from 1.01352
#
# Epoch 00026: val_accuracy did not improve from 0.65988
# 896/896 [==============================] - 678s 757ms/step - loss: 0.6254 - accuracy: 0.7970 - top5_acc: 0.9983 - macro_f1score: 0.6909 - val_loss: 1.1981 - val_accuracy: 0.6535 - val_top5_acc: 0.9849 - val_macro_f1score: 0.5336
# Learning rate:  0.001
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 27/70
# 896/896 [==============================] - ETA: 0s - loss: 0.6028 - accuracy: 0.8052 - top5_acc: 0.9986 - macro_f1score: 0.6995
# Epoch 00027: val_loss did not improve from 1.01352
#
# Epoch 00027: val_accuracy did not improve from 0.65988
# 896/896 [==============================] - 678s 757ms/step - loss: 0.6028 - accuracy: 0.8052 - top5_acc: 0.9986 - macro_f1score: 0.6995 - val_loss: 1.1625 - val_accuracy: 0.6512 - val_top5_acc: 0.9891 - val_macro_f1score: 0.5100
# Learning rate:  0.001
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 28/70
# 896/896 [==============================] - ETA: 0s - loss: 0.5908 - accuracy: 0.8146 - top5_acc: 0.9984 - macro_f1score: 0.7082
# Epoch 00028: val_loss did not improve from 1.01352
#
# Epoch 00028: val_accuracy did not improve from 0.65988
# 896/896 [==============================] - 678s 756ms/step - loss: 0.5908 - accuracy: 0.8146 - top5_acc: 0.9984 - macro_f1score: 0.7082 - val_loss: 1.2395 - val_accuracy: 0.6356 - val_top5_acc: 0.9874 - val_macro_f1score: 0.5063
# Learning rate:  0.001
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 29/70
# 896/896 [==============================] - ETA: 0s - loss: 0.5630 - accuracy: 0.8234 - top5_acc: 0.9988 - macro_f1score: 0.7223
# Epoch 00029: val_loss did not improve from 1.01352
#
# Epoch 00029: val_accuracy did not improve from 0.65988
# 896/896 [==============================] - 678s 757ms/step - loss: 0.5630 - accuracy: 0.8234 - top5_acc: 0.9988 - macro_f1score: 0.7223 - val_loss: 1.2147 - val_accuracy: 0.6392 - val_top5_acc: 0.9847 - val_macro_f1score: 0.5343
# Learning rate:  0.001
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 30/70
# 896/896 [==============================] - ETA: 0s - loss: 0.5423 - accuracy: 0.8328 - top5_acc: 0.9989 - macro_f1score: 0.7297
# Epoch 00030: val_loss did not improve from 1.01352
#
# Epoch 00030: val_accuracy did not improve from 0.65988
# 896/896 [==============================] - 678s 756ms/step - loss: 0.5423 - accuracy: 0.8328 - top5_acc: 0.9989 - macro_f1score: 0.7297 - val_loss: 1.1773 - val_accuracy: 0.6429 - val_top5_acc: 0.9869 - val_macro_f1score: 0.5459
# Learning rate:  0.0001
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 31/70
# 896/896 [==============================] - ETA: 0s - loss: 0.4039 - accuracy: 0.8847 - top5_acc: 0.9995 - macro_f1score: 0.7872
# Epoch 00031: val_loss did not improve from 1.01352
#
# Epoch 00031: val_accuracy improved from 0.65988 to 0.68443, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/Xception/031.h5
# 896/896 [==============================] - 681s 760ms/step - loss: 0.4039 - accuracy: 0.8847 - top5_acc: 0.9995 - macro_f1score: 0.7872 - val_loss: 1.3127 - val_accuracy: 0.6844 - val_top5_acc: 0.9869 - val_macro_f1score: 0.5818
# Learning rate:  0.0001
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 32/70
# 896/896 [==============================] - ETA: 0s - loss: 0.3539 - accuracy: 0.9052 - top5_acc: 0.9998 - macro_f1score: 0.8077
# Epoch 00032: val_loss did not improve from 1.01352
#
# Epoch 00032: val_accuracy did not improve from 0.68443
# 896/896 [==============================] - 682s 761ms/step - loss: 0.3539 - accuracy: 0.9052 - top5_acc: 0.9998 - macro_f1score: 0.8077 - val_loss: 1.4244 - val_accuracy: 0.6744 - val_top5_acc: 0.9880 - val_macro_f1score: 0.5686
# Learning rate:  0.0001
#
# Epoch 00033: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 33/70
# 896/896 [==============================] - ETA: 0s - loss: 0.3257 - accuracy: 0.9146 - top5_acc: 0.9998 - macro_f1score: 0.8187
# Epoch 00033: val_loss did not improve from 1.01352
#
# Epoch 00033: val_accuracy did not improve from 0.68443
# 896/896 [==============================] - 681s 760ms/step - loss: 0.3257 - accuracy: 0.9146 - top5_acc: 0.9998 - macro_f1score: 0.8187 - val_loss: 1.4107 - val_accuracy: 0.6797 - val_top5_acc: 0.9877 - val_macro_f1score: 0.5800
# Learning rate:  0.0001
#
# Epoch 00034: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 34/70
# 896/896 [==============================] - ETA: 0s - loss: 0.3140 - accuracy: 0.9204 - top5_acc: 0.9999 - macro_f1score: 0.8229
# Epoch 00034: val_loss did not improve from 1.01352
#
# Epoch 00034: val_accuracy did not improve from 0.68443
# 896/896 [==============================] - 680s 759ms/step - loss: 0.3140 - accuracy: 0.9204 - top5_acc: 0.9999 - macro_f1score: 0.8229 - val_loss: 1.4243 - val_accuracy: 0.6769 - val_top5_acc: 0.9877 - val_macro_f1score: 0.5790
# Learning rate:  0.0001
#
# Epoch 00035: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 35/70
# 896/896 [==============================] - ETA: 0s - loss: 0.2950 - accuracy: 0.9266 - top5_acc: 0.9997 - macro_f1score: 0.8301
# Epoch 00035: val_loss did not improve from 1.01352
#
# Epoch 00035: val_accuracy did not improve from 0.68443
# 896/896 [==============================] - 679s 758ms/step - loss: 0.2950 - accuracy: 0.9266 - top5_acc: 0.9997 - macro_f1score: 0.8301 - val_loss: 1.5739 - val_accuracy: 0.6738 - val_top5_acc: 0.9883 - val_macro_f1score: 0.5769
# Learning rate:  0.0001
#
# Epoch 00036: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 36/70
# 896/896 [==============================] - ETA: 0s - loss: 0.2823 - accuracy: 0.9312 - top5_acc: 0.9998 - macro_f1score: 0.8353
# Epoch 00036: val_loss did not improve from 1.01352
#
# Epoch 00036: val_accuracy did not improve from 0.68443
# 896/896 [==============================] - 679s 758ms/step - loss: 0.2823 - accuracy: 0.9312 - top5_acc: 0.9998 - macro_f1score: 0.8353 - val_loss: 1.5548 - val_accuracy: 0.6733 - val_top5_acc: 0.9872 - val_macro_f1score: 0.5760
# Learning rate:  0.0001
#
# Epoch 00037: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 37/70
# 896/896 [==============================] - ETA: 0s - loss: 0.2770 - accuracy: 0.9312 - top5_acc: 0.9998 - macro_f1score: 0.8344
# Epoch 00037: val_loss did not improve from 1.01352
#
# Epoch 00037: val_accuracy did not improve from 0.68443
# 896/896 [==============================] - 679s 757ms/step - loss: 0.2770 - accuracy: 0.9312 - top5_acc: 0.9998 - macro_f1score: 0.8344 - val_loss: 1.5639 - val_accuracy: 0.6789 - val_top5_acc: 0.9858 - val_macro_f1score: 0.5708
# Learning rate:  0.0001
#
# Epoch 00038: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 38/70
# 896/896 [==============================] - ETA: 0s - loss: 0.2636 - accuracy: 0.9370 - top5_acc: 0.9999 - macro_f1score: 0.8397
# Epoch 00038: val_loss did not improve from 1.01352
#
# Epoch 00038: val_accuracy did not improve from 0.68443
# 896/896 [==============================] - 680s 758ms/step - loss: 0.2636 - accuracy: 0.9370 - top5_acc: 0.9999 - macro_f1score: 0.8397 - val_loss: 1.6106 - val_accuracy: 0.6749 - val_top5_acc: 0.9872 - val_macro_f1score: 0.5738
# Learning rate:  0.0001
#
# Epoch 00039: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 39/70
# 896/896 [==============================] - ETA: 0s - loss: 0.2572 - accuracy: 0.9387 - top5_acc: 1.0000 - macro_f1score: 0.8432
# Epoch 00039: val_loss did not improve from 1.01352
#
# Epoch 00039: val_accuracy did not improve from 0.68443
# 896/896 [==============================] - 679s 757ms/step - loss: 0.2572 - accuracy: 0.9387 - top5_acc: 1.0000 - macro_f1score: 0.8432 - val_loss: 1.6313 - val_accuracy: 0.6777 - val_top5_acc: 0.9891 - val_macro_f1score: 0.5770
# Learning rate:  0.0001
#
# Epoch 00040: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 40/70
# 896/896 [==============================] - ETA: 0s - loss: 0.2484 - accuracy: 0.9413 - top5_acc: 1.0000 - macro_f1score: 0.8430
# Epoch 00040: val_loss did not improve from 1.01352
#
# Epoch 00040: val_accuracy did not improve from 0.68443
# 896/896 [==============================] - 679s 757ms/step - loss: 0.2484 - accuracy: 0.9413 - top5_acc: 1.0000 - macro_f1score: 0.8430 - val_loss: 1.6535 - val_accuracy: 0.6808 - val_top5_acc: 0.9869 - val_macro_f1score: 0.5688
# Learning rate:  0.0001
#
# Epoch 00041: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 41/70
# 896/896 [==============================] - ETA: 0s - loss: 0.2325 - accuracy: 0.9476 - top5_acc: 1.0000 - macro_f1score: 0.8529
# Epoch 00041: val_loss did not improve from 1.01352
#
# Epoch 00041: val_accuracy did not improve from 0.68443
# 896/896 [==============================] - 678s 757ms/step - loss: 0.2325 - accuracy: 0.9476 - top5_acc: 1.0000 - macro_f1score: 0.8529 - val_loss: 1.7119 - val_accuracy: 0.6741 - val_top5_acc: 0.9877 - val_macro_f1score: 0.5803
# Learning rate:  0.0001
#
# Epoch 00042: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 42/70
# 896/896 [==============================] - ETA: 0s - loss: 0.2356 - accuracy: 0.9466 - top5_acc: 0.9999 - macro_f1score: 0.8506
# Epoch 00042: val_loss did not improve from 1.01352
#
# Epoch 00042: val_accuracy did not improve from 0.68443
# 896/896 [==============================] - 678s 757ms/step - loss: 0.2356 - accuracy: 0.9466 - top5_acc: 0.9999 - macro_f1score: 0.8506 - val_loss: 1.7122 - val_accuracy: 0.6713 - val_top5_acc: 0.9900 - val_macro_f1score: 0.5629
# Learning rate:  0.0001
#
# Epoch 00043: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 43/70
# 896/896 [==============================] - ETA: 0s - loss: 0.2278 - accuracy: 0.9476 - top5_acc: 0.9999 - macro_f1score: 0.8519
# Epoch 00043: val_loss did not improve from 1.01352
#
# Epoch 00043: val_accuracy did not improve from 0.68443
# 896/896 [==============================] - 679s 757ms/step - loss: 0.2278 - accuracy: 0.9476 - top5_acc: 0.9999 - macro_f1score: 0.8519 - val_loss: 1.7834 - val_accuracy: 0.6780 - val_top5_acc: 0.9872 - val_macro_f1score: 0.5840
# Learning rate:  0.0001
#
# Epoch 00044: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 44/70
# 896/896 [==============================] - ETA: 0s - loss: 0.2228 - accuracy: 0.9506 - top5_acc: 1.0000 - macro_f1score: 0.8555
# Epoch 00044: val_loss did not improve from 1.01352
#
# Epoch 00044: val_accuracy did not improve from 0.68443
# 896/896 [==============================] - 678s 756ms/step - loss: 0.2228 - accuracy: 0.9506 - top5_acc: 1.0000 - macro_f1score: 0.8555 - val_loss: 1.7240 - val_accuracy: 0.6744 - val_top5_acc: 0.9860 - val_macro_f1score: 0.5754
# Learning rate:  0.0001
#
# Epoch 00045: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 45/70
# 896/896 [==============================] - ETA: 0s - loss: 0.2162 - accuracy: 0.9531 - top5_acc: 1.0000 - macro_f1score: 0.8591
# Epoch 00045: val_loss did not improve from 1.01352
#
# Epoch 00045: val_accuracy did not improve from 0.68443
# 896/896 [==============================] - 678s 756ms/step - loss: 0.2162 - accuracy: 0.9531 - top5_acc: 1.0000 - macro_f1score: 0.8591 - val_loss: 1.7980 - val_accuracy: 0.6719 - val_top5_acc: 0.9863 - val_macro_f1score: 0.5689
# Learning rate:  0.0001
#
# Epoch 00046: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 46/70
# 896/896 [==============================] - ETA: 0s - loss: 0.2097 - accuracy: 0.9564 - top5_acc: 1.0000 - macro_f1score: 0.8597
# Epoch 00046: val_loss did not improve from 1.01352
#
# Epoch 00046: val_accuracy did not improve from 0.68443
# 896/896 [==============================] - 677s 756ms/step - loss: 0.2097 - accuracy: 0.9564 - top5_acc: 1.0000 - macro_f1score: 0.8597 - val_loss: 1.8091 - val_accuracy: 0.6696 - val_top5_acc: 0.9877 - val_macro_f1score: 0.5726
# Learning rate:  0.0001
#
# Epoch 00047: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 47/70
# 896/896 [==============================] - ETA: 0s - loss: 0.2014 - accuracy: 0.9594 - top5_acc: 0.9999 - macro_f1score: 0.8627
# Epoch 00047: val_loss did not improve from 1.01352
#
# Epoch 00047: val_accuracy did not improve from 0.68443
# 896/896 [==============================] - 678s 757ms/step - loss: 0.2014 - accuracy: 0.9594 - top5_acc: 0.9999 - macro_f1score: 0.8627 - val_loss: 1.8241 - val_accuracy: 0.6719 - val_top5_acc: 0.9894 - val_macro_f1score: 0.5834
# Learning rate:  0.0001
#
# Epoch 00048: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 48/70
# 896/896 [==============================] - ETA: 0s - loss: 0.2012 - accuracy: 0.9580 - top5_acc: 1.0000 - macro_f1score: 0.8616
# Epoch 00048: val_loss did not improve from 1.01352
#
# Epoch 00048: val_accuracy did not improve from 0.68443
# 896/896 [==============================] - 678s 757ms/step - loss: 0.2012 - accuracy: 0.9580 - top5_acc: 1.0000 - macro_f1score: 0.8616 - val_loss: 1.8226 - val_accuracy: 0.6705 - val_top5_acc: 0.9880 - val_macro_f1score: 0.5677
# Learning rate:  0.0001
#
# Epoch 00049: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 49/70
# 896/896 [==============================] - ETA: 0s - loss: 0.1998 - accuracy: 0.9596 - top5_acc: 1.0000 - macro_f1score: 0.8637
# Epoch 00049: val_loss did not improve from 1.01352
#
# Epoch 00049: val_accuracy did not improve from 0.68443
# 896/896 [==============================] - 678s 757ms/step - loss: 0.1998 - accuracy: 0.9596 - top5_acc: 1.0000 - macro_f1score: 0.8637 - val_loss: 1.8897 - val_accuracy: 0.6735 - val_top5_acc: 0.9886 - val_macro_f1score: 0.5735
# Learning rate:  0.0001
#
# Epoch 00050: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 50/70
# 896/896 [==============================] - ETA: 0s - loss: 0.1953 - accuracy: 0.9607 - top5_acc: 0.9999 - macro_f1score: 0.8641
# Epoch 00050: val_loss did not improve from 1.01352
#
# Epoch 00050: val_accuracy did not improve from 0.68443
# 896/896 [==============================] - 678s 757ms/step - loss: 0.1953 - accuracy: 0.9607 - top5_acc: 0.9999 - macro_f1score: 0.8641 - val_loss: 1.8446 - val_accuracy: 0.6724 - val_top5_acc: 0.9883 - val_macro_f1score: 0.5708
# Learning rate:  0.0001
#
# Epoch 00051: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 51/70
# 896/896 [==============================] - ETA: 0s - loss: 0.1910 - accuracy: 0.9617 - top5_acc: 1.0000 - macro_f1score: 0.8680
# Epoch 00051: val_loss did not improve from 1.01352
#
# Epoch 00051: val_accuracy did not improve from 0.68443
# 896/896 [==============================] - 678s 756ms/step - loss: 0.1910 - accuracy: 0.9617 - top5_acc: 1.0000 - macro_f1score: 0.8680 - val_loss: 1.8257 - val_accuracy: 0.6733 - val_top5_acc: 0.9883 - val_macro_f1score: 0.5757
# Learning rate:  0.0001
#
# Epoch 00052: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 52/70
# 896/896 [==============================] - ETA: 0s - loss: 0.1842 - accuracy: 0.9647 - top5_acc: 1.0000 - macro_f1score: 0.8697
# Epoch 00052: val_loss did not improve from 1.01352
#
# Epoch 00052: val_accuracy did not improve from 0.68443
# 896/896 [==============================] - 678s 756ms/step - loss: 0.1842 - accuracy: 0.9647 - top5_acc: 1.0000 - macro_f1score: 0.8697 - val_loss: 1.9009 - val_accuracy: 0.6733 - val_top5_acc: 0.9897 - val_macro_f1score: 0.5759
# Learning rate:  0.0001
#
# Epoch 00053: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 53/70
# 896/896 [==============================] - ETA: 0s - loss: 0.1850 - accuracy: 0.9646 - top5_acc: 1.0000 - macro_f1score: 0.8717
# Epoch 00053: val_loss did not improve from 1.01352
#
# Epoch 00053: val_accuracy did not improve from 0.68443
# 896/896 [==============================] - 679s 757ms/step - loss: 0.1850 - accuracy: 0.9646 - top5_acc: 1.0000 - macro_f1score: 0.8717 - val_loss: 1.9146 - val_accuracy: 0.6797 - val_top5_acc: 0.9877 - val_macro_f1score: 0.5782
# Learning rate:  0.0001
#
# Epoch 00054: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 54/70
# 896/896 [==============================] - ETA: 0s - loss: 0.1788 - accuracy: 0.9656 - top5_acc: 1.0000 - macro_f1score: 0.8711
# Epoch 00054: val_loss did not improve from 1.01352
#
# Epoch 00054: val_accuracy did not improve from 0.68443
# 896/896 [==============================] - 678s 756ms/step - loss: 0.1788 - accuracy: 0.9656 - top5_acc: 1.0000 - macro_f1score: 0.8711 - val_loss: 1.9030 - val_accuracy: 0.6761 - val_top5_acc: 0.9886 - val_macro_f1score: 0.5795
# Learning rate:  0.0001
#
# Epoch 00055: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 55/70
# 896/896 [==============================] - ETA: 0s - loss: 0.1746 - accuracy: 0.9672 - top5_acc: 1.0000 - macro_f1score: 0.8702
# Epoch 00055: val_loss did not improve from 1.01352
#
# Epoch 00055: val_accuracy did not improve from 0.68443
# 896/896 [==============================] - 678s 756ms/step - loss: 0.1746 - accuracy: 0.9672 - top5_acc: 1.0000 - macro_f1score: 0.8702 - val_loss: 1.9284 - val_accuracy: 0.6763 - val_top5_acc: 0.9891 - val_macro_f1score: 0.5837
# Learning rate:  0.0001
#
# Epoch 00056: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 56/70
# 896/896 [==============================] - ETA: 0s - loss: 0.1729 - accuracy: 0.9677 - top5_acc: 1.0000 - macro_f1score: 0.8715
# Epoch 00056: val_loss did not improve from 1.01352
#
# Epoch 00056: val_accuracy did not improve from 0.68443
# 896/896 [==============================] - 677s 756ms/step - loss: 0.1729 - accuracy: 0.9677 - top5_acc: 1.0000 - macro_f1score: 0.8715 - val_loss: 1.9690 - val_accuracy: 0.6741 - val_top5_acc: 0.9891 - val_macro_f1score: 0.5747
# Learning rate:  0.0001
#
# Epoch 00057: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 57/70
# 896/896 [==============================] - ETA: 0s - loss: 0.1696 - accuracy: 0.9694 - top5_acc: 1.0000 - macro_f1score: 0.8763
# Epoch 00057: val_loss did not improve from 1.01352
#
# Epoch 00057: val_accuracy did not improve from 0.68443
# 896/896 [==============================] - 677s 756ms/step - loss: 0.1696 - accuracy: 0.9694 - top5_acc: 1.0000 - macro_f1score: 0.8763 - val_loss: 2.0134 - val_accuracy: 0.6794 - val_top5_acc: 0.9886 - val_macro_f1score: 0.5804
# Learning rate:  0.0001
#
# Epoch 00058: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 58/70
# 896/896 [==============================] - ETA: 0s - loss: 0.1711 - accuracy: 0.9690 - top5_acc: 1.0000 - macro_f1score: 0.8748
# Epoch 00058: val_loss did not improve from 1.01352
#
# Epoch 00058: val_accuracy did not improve from 0.68443
# 896/896 [==============================] - 677s 756ms/step - loss: 0.1711 - accuracy: 0.9690 - top5_acc: 1.0000 - macro_f1score: 0.8748 - val_loss: 1.9440 - val_accuracy: 0.6772 - val_top5_acc: 0.9891 - val_macro_f1score: 0.5794
# Learning rate:  0.0001
#
# Epoch 00059: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 59/70
# 896/896 [==============================] - ETA: 0s - loss: 0.1653 - accuracy: 0.9707 - top5_acc: 1.0000 - macro_f1score: 0.8731
# Epoch 00059: val_loss did not improve from 1.01352
#
# Epoch 00059: val_accuracy did not improve from 0.68443
# 896/896 [==============================] - 677s 756ms/step - loss: 0.1653 - accuracy: 0.9707 - top5_acc: 1.0000 - macro_f1score: 0.8731 - val_loss: 2.0237 - val_accuracy: 0.6769 - val_top5_acc: 0.9891 - val_macro_f1score: 0.5785
# Learning rate:  0.0001
#
# Epoch 00060: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 60/70
# 896/896 [==============================] - ETA: 0s - loss: 0.1655 - accuracy: 0.9709 - top5_acc: 1.0000 - macro_f1score: 0.8749
# Epoch 00060: val_loss did not improve from 1.01352
#
# Epoch 00060: val_accuracy did not improve from 0.68443
# 896/896 [==============================] - 677s 756ms/step - loss: 0.1655 - accuracy: 0.9709 - top5_acc: 1.0000 - macro_f1score: 0.8749 - val_loss: 2.0404 - val_accuracy: 0.6730 - val_top5_acc: 0.9880 - val_macro_f1score: 0.5756
# Learning rate:  1e-05
#
# Epoch 00061: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 61/70
# 896/896 [==============================] - ETA: 0s - loss: 0.1570 - accuracy: 0.9742 - top5_acc: 1.0000 - macro_f1score: 0.8785
# Epoch 00061: val_loss did not improve from 1.01352
#
# Epoch 00061: val_accuracy did not improve from 0.68443
# 896/896 [==============================] - 677s 756ms/step - loss: 0.1570 - accuracy: 0.9742 - top5_acc: 1.0000 - macro_f1score: 0.8785 - val_loss: 2.0084 - val_accuracy: 0.6808 - val_top5_acc: 0.9883 - val_macro_f1score: 0.5804
# Learning rate:  1e-05
#
# Epoch 00062: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 62/70
# 896/896 [==============================] - ETA: 0s - loss: 0.1556 - accuracy: 0.9746 - top5_acc: 1.0000 - macro_f1score: 0.8779
# Epoch 00062: val_loss did not improve from 1.01352
#
# Epoch 00062: val_accuracy did not improve from 0.68443
# 896/896 [==============================] - 676s 755ms/step - loss: 0.1556 - accuracy: 0.9746 - top5_acc: 1.0000 - macro_f1score: 0.8779 - val_loss: 2.0346 - val_accuracy: 0.6842 - val_top5_acc: 0.9877 - val_macro_f1score: 0.5835
# Learning rate:  1e-05
#
# Epoch 00063: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 63/70
# 896/896 [==============================] - ETA: 0s - loss: 0.1512 - accuracy: 0.9770 - top5_acc: 1.0000 - macro_f1score: 0.8839
# Epoch 00063: val_loss did not improve from 1.01352
#
# Epoch 00063: val_accuracy did not improve from 0.68443
# 896/896 [==============================] - 677s 756ms/step - loss: 0.1512 - accuracy: 0.9770 - top5_acc: 1.0000 - macro_f1score: 0.8839 - val_loss: 2.0606 - val_accuracy: 0.6836 - val_top5_acc: 0.9877 - val_macro_f1score: 0.5806
# Learning rate:  1e-05
#
# Epoch 00064: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 64/70
# 896/896 [==============================] - ETA: 0s - loss: 0.1491 - accuracy: 0.9765 - top5_acc: 1.0000 - macro_f1score: 0.8829
# Epoch 00064: val_loss did not improve from 1.01352
#
# Epoch 00064: val_accuracy improved from 0.68443 to 0.68527, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/Xception/064.h5
# 896/896 [==============================] - 679s 758ms/step - loss: 0.1491 - accuracy: 0.9765 - top5_acc: 1.0000 - macro_f1score: 0.8829 - val_loss: 2.0817 - val_accuracy: 0.6853 - val_top5_acc: 0.9886 - val_macro_f1score: 0.5866
# Learning rate:  1e-05
#
# Epoch 00065: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 65/70
# 896/896 [==============================] - ETA: 0s - loss: 0.1483 - accuracy: 0.9763 - top5_acc: 1.0000 - macro_f1score: 0.8811
# Epoch 00065: val_loss did not improve from 1.01352
#
# Epoch 00065: val_accuracy did not improve from 0.68527
# 896/896 [==============================] - 678s 756ms/step - loss: 0.1483 - accuracy: 0.9763 - top5_acc: 1.0000 - macro_f1score: 0.8811 - val_loss: 2.0800 - val_accuracy: 0.6833 - val_top5_acc: 0.9883 - val_macro_f1score: 0.5795
# Learning rate:  1e-05
#
# Epoch 00066: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 66/70
# 896/896 [==============================] - ETA: 0s - loss: 0.1483 - accuracy: 0.9773 - top5_acc: 1.0000 - macro_f1score: 0.8823
# Epoch 00066: val_loss did not improve from 1.01352
#
# Epoch 00066: val_accuracy did not improve from 0.68527
# 896/896 [==============================] - 677s 756ms/step - loss: 0.1483 - accuracy: 0.9773 - top5_acc: 1.0000 - macro_f1score: 0.8823 - val_loss: 2.1031 - val_accuracy: 0.6833 - val_top5_acc: 0.9883 - val_macro_f1score: 0.5860
# Learning rate:  1e-05
#
# Epoch 00067: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 67/70
# 896/896 [==============================] - ETA: 0s - loss: 0.1450 - accuracy: 0.9781 - top5_acc: 1.0000 - macro_f1score: 0.8860
# Epoch 00067: val_loss did not improve from 1.01352
#
# Epoch 00067: val_accuracy did not improve from 0.68527
# 896/896 [==============================] - 677s 756ms/step - loss: 0.1450 - accuracy: 0.9781 - top5_acc: 1.0000 - macro_f1score: 0.8860 - val_loss: 2.1209 - val_accuracy: 0.6825 - val_top5_acc: 0.9877 - val_macro_f1score: 0.5791
# Learning rate:  1e-05
#
# Epoch 00068: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 68/70
# 896/896 [==============================] - ETA: 0s - loss: 0.1453 - accuracy: 0.9780 - top5_acc: 1.0000 - macro_f1score: 0.8846
# Epoch 00068: val_loss did not improve from 1.01352
#
# Epoch 00068: val_accuracy did not improve from 0.68527
# 896/896 [==============================] - 677s 756ms/step - loss: 0.1453 - accuracy: 0.9780 - top5_acc: 1.0000 - macro_f1score: 0.8846 - val_loss: 2.1284 - val_accuracy: 0.6802 - val_top5_acc: 0.9880 - val_macro_f1score: 0.5813
# Learning rate:  1e-05
#
# Epoch 00069: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 69/70
# 896/896 [==============================] - ETA: 0s - loss: 0.1458 - accuracy: 0.9792 - top5_acc: 1.0000 - macro_f1score: 0.8846
# Epoch 00069: val_loss did not improve from 1.01352
#
# Epoch 00069: val_accuracy did not improve from 0.68527
# 896/896 [==============================] - 677s 756ms/step - loss: 0.1458 - accuracy: 0.9792 - top5_acc: 1.0000 - macro_f1score: 0.8846 - val_loss: 2.1238 - val_accuracy: 0.6816 - val_top5_acc: 0.9872 - val_macro_f1score: 0.5783
# Learning rate:  1e-05
#
# Epoch 00070: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 70/70
# 896/896 [==============================] - ETA: 0s - loss: 0.1440 - accuracy: 0.9784 - top5_acc: 1.0000 - macro_f1score: 0.8845
# Epoch 00070: val_loss did not improve from 1.01352
#
# Epoch 00070: val_accuracy did not improve from 0.68527
# 896/896 [==============================] - 677s 756ms/step - loss: 0.1440 - accuracy: 0.9784 - top5_acc: 1.0000 - macro_f1score: 0.8845 - val_loss: 2.1398 - val_accuracy: 0.6808 - val_top5_acc: 0.9888 - val_macro_f1score: 0.5841

# %%
# 1. epoch=maximum
loss , acc, top5_acc, mf1 = model.evaluate(test_generator,steps=int(len(x_test)/batch_sizes))
print('[Test Loss: %.4f /  Test Top-1 Accuracy: %.4f / Test Top-5 Accuracy: %.4f / Test Macro f1: %.4f]\n' % (loss,acc,top5_acc,mf1))
# Out:
# 112/112 [==============================] - 1866s 17s/step - loss: 2.3081 - accuracy: 0.6735 - top5_acc: 0.9849 - macro_f1score: 0.5799
# [Test Loss: 2.3081 /  Test Top-1 Accuracy: 0.6735 / Test Top-5 Accuracy: 0.9849 / Test Macro f1: 0.5799]

# %%
loss=history.history['loss']
val_loss=history.history['val_loss']
acc=history.history['accuracy']
val_acc=history.history['val_accuracy']
top5_acc=history.history['top5_acc']
val_top5_acc=history.history['val_top5_acc']
f1=history.history['macro_f1score']
val_f1=history.history['val_macro_f1score']
epochs=range(1,len(acc)+1)

data = np.array([epochs,loss,val_loss,acc,val_acc,top5_acc,val_top5_acc,f1,val_f1]).T

# %% [markdown]
# ### 2) Xception Evaluate

# %%
# data save
# epochs, loss, val_loss, acc, val_acc, top5_acc, val_top5_acc, f1, val_f1

np.savetxt(os.path.join(dir,'train_valid_output',number,model.name+'.txt'),data)

# %%
# data import
data = np.loadtxt(os.path.join(dir,'train_valid_output',number,'Xception.txt'))

# %%
epochs=data[:,0]
loss=data[:,1]
val_loss=data[:,2]
acc=data[:,3]
val_acc=data[:,4]
top5_acc=data[:,5]
val_top5_acc=data[:,6]

# %%
plt.plot(epochs[1:],acc[1:],'b',label='Training 1-Acc')
plt.plot(epochs[1:],val_acc[1:],'r',label='Validation 1-Acc')
plt.title('Training and Validation Top-1 Accuracy')
plt.legend()
plt.figure()

plt.plot(epochs[1:],top5_acc[1:],'b',label='Training 5-Acc')
plt.plot(epochs[1:],val_top5_acc[1:],'r',label='Validation 5-Acc')
plt.title('Training and Validation Top-5 Accuracy')
plt.legend()
plt.figure()

plt.plot(epochs[10:],loss[10:],'b',label='Training Loss')
plt.plot(epochs[10:],val_loss[10:],'r',label='Validation Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()

# %%
# 이 아래는 내가 인위적으로 살펴보고 싶은 epoch에 대해서 결과값 출력 / Xception

# %%
# 참고 : https://github.com/OverLordGoldDragon/keras-adamw

import sys
sys.path.append('/content/drive/My Drive/Colab Notebooks/Paper')
import utils
import optimizers_v2
from utils import get_weight_decays, fill_dict_in_order
from utils import reset_seeds, K_eval
from optimizers_v2 import AdamW, NadamW, SGDW

# %%
# top-5 accuracy 출력
import functools
top5_acc = functools.partial(ks.metrics.top_k_categorical_accuracy, k=5)
top5_acc.__name__ = 'top5_acc'

# %%
model=load_model(os.path.join(dir,'model_output',number,'Xception','031.h5'),custom_objects={"macro_f1score": macro_f1score,"top5_acc":top5_acc, "AdamW":AdamW})

# %%
# 2. epoch=?
loss , acc, top5_acc, mf1 = model.evaluate(test_generator,steps=int(len(x_test)/batch_sizes))
print('[Test Loss: %.4f /  Test Top-1 Accuracy: %.4f / Test Top-5 Accuracy: %.4f / Test Macro f1: %.4f]\n' % (loss,acc,top5_acc,mf1))
# Out:
# 112/112 [==============================] - 1394s 12s/step - loss: 1.4354 - accuracy: 0.6696 - top5_acc: 0.9866 - macro_f1score: 0.5613
# [Test Loss: 1.4354 /  Test Top-1 Accuracy: 0.6696 / Test Top-5 Accuracy: 0.9866 / Test Macro f1: 0.5613]
