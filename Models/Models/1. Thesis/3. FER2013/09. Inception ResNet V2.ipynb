# %%
#모형 출처 : https://github.com/titu1994/keras-squeeze-excite-network
# https://ai.googleblog.com/2016/08/improving-inception-and-image.html

# %% [markdown]
# # [Inception ResNet V2]

# %% [markdown]
# *KU LeeDongGyu*

# %% [markdown]
# ## Contents
# ---

# %% [markdown]
# 1. Data Preprocessing
# ```
# 1) Data Import
# 2) Data Augmentation
# ```
# 2. Support Functions & Almost Original Inception-ResNet-V2
# ```
# 1) Support Functions
# 2) Almost Original Inception-ResNet-V2
# 3) Inception-ResNet-V2 Evaluate
# ```

# %% [markdown]
# ### Install Packages

# %% [markdown]
# ### Module

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/My Drive/Colab Notebooks/Paper
# Out:
# /content/drive/My Drive/Colab Notebooks/Paper

# %%
from f1score import macro_f1score,weighted_f1score

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import cv2
import tensorflow as tf
from tensorflow import keras as ks
from tensorflow.keras import backend as K 
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, Input, Concatenate, ZeroPadding2D ,GlobalMaxPooling2D, Reshape , Lambda , Add, Multiply
from tensorflow.keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D, Activation, BatchNormalization, AveragePooling2D , ZeroPadding2D, SeparableConv2D , LeakyReLU
from tensorflow.keras.layers import add, concatenate, multiply
from tensorflow.keras.optimizers import Adam, RMSprop , SGD
from tensorflow.keras.callbacks import EarlyStopping , LearningRateScheduler, ModelCheckpoint, CSVLogger, Callback, ReduceLROnPlateau
from tensorflow.keras.regularizers import l1,l2,l1_l2
from tensorflow.keras.models import Model , load_model , Sequential
from tensorflow.keras.utils import plot_model , to_categorical, get_file
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
os.getcwd()
# Out:
# '/content/drive/My Drive/Colab Notebooks/Paper'

# %%
print(tf.__version__)
print(ks.__version__)
# Out:
# 2.3.0
# 2.4.0

# %%
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 15036067282179815838
# , name: "/device:XLA_CPU:0"
# device_type: "XLA_CPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 10275850837846480961
# physical_device_desc: "device: XLA_CPU device"
# , name: "/device:XLA_GPU:0"
# device_type: "XLA_GPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 11283501193655122596
# physical_device_desc: "device: XLA_GPU device"
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 15473775744
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 3733424080887740238
# physical_device_desc: "device: 0, name: Tesla V100-SXM2-16GB, pci bus id: 0000:00:04.0, compute capability: 7.0"
# ]

# %%
# !cat /proc/cpuinfo
# Out:
# processor	: 0
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 85
# model name	: Intel(R) Xeon(R) CPU @ 2.00GHz
# stepping	: 3
# microcode	: 0x1
# cpu MHz		: 2000.166
# cache size	: 39424 KB
# physical id	: 0
# siblings	: 4
# core id		: 0
# cpu cores	: 2
# apicid		: 0
# initial apicid	: 0
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm mpx avx512f avx512dq rdseed adx smap clflushopt clwb avx512cd avx512bw avx512vl xsaveopt xsavec xgetbv1 xsaves arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs taa
# bogomips	: 4000.33
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 46 bits physical, 48 bits virtual
# power management:
#
# processor	: 1
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 85
# model name	: Intel(R) Xeon(R) CPU @ 2.00GHz
# stepping	: 3
# microcode	: 0x1
# cpu MHz		: 2000.166
# cache size	: 39424 KB
# physical id	: 0
# siblings	: 4
# core id		: 1
# cpu cores	: 2
# apicid		: 2
# initial apicid	: 2
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm mpx avx512f avx512dq rdseed adx smap clflushopt clwb avx512cd avx512bw avx512vl xsaveopt xsavec xgetbv1 xsaves arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs taa
# bogomips	: 4000.33
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 46 bits physical, 48 bits virtual
# power management:
#
# processor	: 2
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 85
# model name	: Intel(R) Xeon(R) CPU @ 2.00GHz
# stepping	: 3
# microcode	: 0x1
# cpu MHz		: 2000.166
# cache size	: 39424 KB
# physical id	: 0
# siblings	: 4
# core id		: 0
# cpu cores	: 2
# apicid		: 1
# initial apicid	: 1
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm mpx avx512f avx512dq rdseed adx smap clflushopt clwb avx512cd avx512bw avx512vl xsaveopt xsavec xgetbv1 xsaves arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs taa
# bogomips	: 4000.33
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 46 bits physical, 48 bits virtual
# power management:
#
# processor	: 3
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 85
# model name	: Intel(R) Xeon(R) CPU @ 2.00GHz
# stepping	: 3
# microcode	: 0x1
# cpu MHz		: 2000.166
# cache size	: 39424 KB
# physical id	: 0
# siblings	: 4
# core id		: 1
# cpu cores	: 2
# apicid		: 3
# initial apicid	: 3
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm mpx avx512f avx512dq rdseed adx smap clflushopt clwb avx512cd avx512bw avx512vl xsaveopt xsavec xgetbv1 xsaves arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs taa
# bogomips	: 4000.33
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 46 bits physical, 48 bits virtual
# power management:

# %% [markdown]
# ## 1. Data Preprocessing
# ---

# %% [markdown]
# ### 1) Data Import

# %%
# 바꿔서 살펴 볼 것들
# CALTECH, CIFAR100, FER, MIT
data_name = 'FER'
gan_type = 'No_GAN'
number = '1'
size = 299 # sizes after cropping
super_size = 330 # sizes before cropping 
input_sizes = (size,size,3)
batch_sizes = 32
weight_decay = 1e-3
epochs = 70

# %%
# 참고 : https://stackoverflow.com/questions/32419510/how-to-get-reproducible-results-in-keras/52897216#52897216
# setting the seed number for random number generation for reproducibility.

from numpy.random import seed
import random


if number=='1':
    seed_num = 200225
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)
elif number=='2':
    seed_num = 727
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)
elif number=='3':
    seed_num = 115
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)
elif number=='4':
    seed_num = 501
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)
elif number=='5':
    seed_num = 517
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)

# %%
# data import

if data_name=='FER' :
    x_train =  np.zeros(28698)
    x_valid = np.zeros(3589)
    x_test = np.zeros(3588)
    classes = 7 
    tr_center = [0.50793296, 0.50793296, 0.50793296]
elif data_name=='MIT':
    x_train = np.zeros(12466)
    x_valid = np.zeros(1564)
    x_test = np.zeros(1590)
    classes = 67 
    tr_center = [0.47916578, 0.42029615, 0.36046057]
elif data_name=='CALTECH':
    x_train = np.zeros(24510)
    x_valid = np.zeros(2980)
    x_test = np.zeros(3118)
    classes = 257
    tr_center = [0.51397761, 0.49525248, 0.46555727]
elif data_name=='CIFAR100':
    x_train = np.zeros(44923)
    x_valid = np.zeros(5077)
    x_test = np.zeros(10000)
    classes = 100
    tr_center = [0.53442983, 0.51355958, 0.46462564]

# %%
dir = os.path.join(os.getcwd(),data_name,gan_type)

# %% [markdown]
# ### 2) Data Augmentation

# %%
# 참고 : https://jkjung-avt.github.io/keras-image-cropping/

def random_crop(img, random_crop_size):
    # Note: image_data_format is 'channel_last'
    assert img.shape[2] == 3 # img.shape[2] 가 3(rgb)이 아니면 assertion error 발생
    height, width = img.shape[0], img.shape[1]
    dy, dx = random_crop_size
    x = np.random.randint(0, width - dx + 1)
    y = np.random.randint(0, height - dy + 1)
    return img[y:(y+dy), x:(x+dx), :]


def crop_generator(batches, crop_length):
    """Take as input a Keras ImageGen (Iterator) and generate random
    crops from the image batches generated by the original iterator.
    """
    while True:
        batch_x, batch_y = next(batches)
        batch_crops = np.zeros((batch_x.shape[0], crop_length, crop_length, 3))
        for i in range(batch_x.shape[0]):
            batch_crops[i] = random_crop(batch_x[i], (crop_length, crop_length))
        yield (batch_crops, batch_y)

# %%
from tensorflow.keras.preprocessing.image import img_to_array,load_img
import glob

# 데이터 전체에 대해 centering 진행함.

def read_cal_image(img_path): 
    x = img_to_array(load_img(img_path)) # x는 채널별 평균값
    y = x.shape[0] * x.shape[1]# y는 데이터별 픽셀 수 (비중)

    x = 1/255. * x # scaling하고, centering값을 뽑아냄.
    x = np.mean(x, axis=(0,1))
    
    return np.hstack([x,y])

def calculate_centered_mean(dataset_path,x_train=x_train):
    num = len(x_train)
    space = np.empty((num,4))
    i=0

    for p in glob.glob(os.path.join(dataset_path,'*/*.*')) :
        space[i] = read_cal_image(p)
        i += 1

    ratio = space[:,3] / np.sum(space[:,3])

    return np.average(space[:,0:3],axis=0,weights=ratio)


# 아래의 함수를 돌려서 나온 결과값을 중심화 값으로 설정.

# train_mean = calculate_centered_mean(os.path.join(dir,'data/train')).reshape((1,1,3))

# %%
datagen_tr = ImageDataGenerator(
    rescale=1/255.,
    horizontal_flip=True,
    featurewise_center=True,
    featurewise_std_normalization=False,
    rotation_range=10,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=[0.9,1.0],
    fill_mode = 'nearest')
datagen_val = ImageDataGenerator(rescale=1/255.,featurewise_center=True)
datagen_tes = ImageDataGenerator(rescale=1/255.,featurewise_center=True)

# 원래는 이 자리에 fit 매서드를 써야하지만, 그냥 내가 중심화함수를 만들고 적용함. 

# 중심화 설정
datagen_tr.mean = np.array(tr_center, dtype=np.float32).reshape((1,1,3)) # RGB
datagen_val.mean = np.array(tr_center, dtype=np.float32).reshape((1,1,3)) # RGB
datagen_tes.mean = np.array(tr_center, dtype=np.float32).reshape((1,1,3)) # RGB

# %%
train_batches = datagen_tr.flow_from_directory(directory=os.path.join(dir,'data/train'),target_size=(super_size,super_size),batch_size=batch_sizes,class_mode='categorical') # fer : 28698 / mit : 12466 / caltech : 24509 / cifar : 44923
train_generator= crop_generator(train_batches, size)
valid_generator = datagen_val.flow_from_directory(directory=os.path.join(dir,'data/valid'),target_size=(size,size),batch_size=batch_sizes,class_mode='categorical') # fer : 3589 / mit : 1564 / caltech : 2980 / cifar : 5077
test_generator = datagen_tes.flow_from_directory(directory=os.path.join(dir,'data/test'),target_size=(size,size),batch_size=batch_sizes,class_mode='categorical') # fer : 3588 / mit : 1590 / caltech : 3118 / cifar : 10000
# Out:
# Found 28698 images belonging to 7 classes.
# Found 3589 images belonging to 7 classes.
# Found 3588 images belonging to 7 classes.

# %% [markdown]
# ## 2. Support Functions & Almost Original Inception-ResNet-V2
# ---

# %% [markdown]
# ### 1) Support Functions

# %%
# def lr_schedule(epoch):
#     init_lr = 1e-4
#     k = 0.04
#     lr = init_lr * np.exp(-k*epoch)
#     print('Learning rate: ', lr)
#     return lr

def lr_schedule(epoch):
    lr = 1e-3
    if epoch < 30:
        lr = lr
    elif epoch < 60 :
        lr = lr * 0.1
    else:
        lr = lr * 0.01
    print('Learning rate: ', lr)
    return lr

# %%
def conv2d_bn(x, filters, kernel_size, strides=1, padding='same', activation='relu', use_bias=False, name=None, weight_decay=weight_decay):

    x = Conv2D(filters, kernel_size, strides=strides, padding=padding,  use_bias=use_bias, name=name, kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(x)
    if not use_bias:
        bn_axis =  3
        bn_name = None if name is None else '{name}_bn'.format(name=name)
        x = BatchNormalization(axis=bn_axis, scale=False, name=bn_name)(x)
        
    if activation is not None:
        ac_name = None if name is None else '{name}_ac'.format(name=name)
        x = Activation(activation, name=ac_name)(x)
    return x

# %%
def inception_resnet_block(x, scale, block_type, block_idx, activation='relu'):
 
    if block_type == 'block35':
        branch_0 = conv2d_bn(x, 32, 1)
        branch_1 = conv2d_bn(x, 32, 1)
        branch_1 = conv2d_bn(branch_1, 32, 3)
        branch_2 = conv2d_bn(x, 32, 1)
        branch_2 = conv2d_bn(branch_2, 48, 3)
        branch_2 = conv2d_bn(branch_2, 64, 3)
        branches = [branch_0, branch_1, branch_2]
    elif block_type == 'block17':
        branch_0 = conv2d_bn(x, 192, 1)
        branch_1 = conv2d_bn(x, 128, 1)
        branch_1 = conv2d_bn(branch_1, 160, [1, 7])
        branch_1 = conv2d_bn(branch_1, 192, [7, 1])
        branches = [branch_0, branch_1]
    elif block_type == 'block8':
        branch_0 = conv2d_bn(x, 192, 1)
        branch_1 = conv2d_bn(x, 192, 1)
        branch_1 = conv2d_bn(branch_1, 224, [1, 3])
        branch_1 = conv2d_bn(branch_1, 256, [3, 1])
        branches = [branch_0, branch_1]
    else:
        raise ValueError('Unknown Inception-ResNet block type. '
                         'Expects "block35", "block17" or "block8", '
                         'but got: {block_type}'.format(block_type=block_type))

    block_name = '{block_type}_{block_idx}'.format(block_type=block_type, block_idx=block_idx)
    channel_axis = 3
    mixed = Concatenate(axis=channel_axis, name='{block_name}_mixed'.format(block_name=block_name))(branches)
    up = conv2d_bn(mixed,
                   K.int_shape(x)[channel_axis],
                   1,
                   activation=None,
                   use_bias=True,
                   name='{block_name}_conv'.format(block_name=block_name))

    x = Lambda(lambda inputs, scale_: inputs[0] + inputs[1] * scale_,
               output_shape=K.int_shape(x)[1:],
               arguments={'scale_': scale},
               name=block_name)([x, up])
    if activation is not None:
        x = Activation(activation, name='{block_name}_ac'.format(block_name=block_name))(x)

    return x

# %%
def Inception_ResNet_v2(input_shape=None, weight_decay=weight_decay, classes=classes, name=None):
 
    img_input = Input(shape=input_shape)


    # Stem block: 35 x 35 x 192
    x = conv2d_bn(img_input, 32, 3, strides=2, padding='valid')
    x = conv2d_bn(x, 32, 3, padding='valid')
    x = conv2d_bn(x, 64, 3)
    x = MaxPooling2D(3, strides=2)(x)
    x = conv2d_bn(x, 80, 1, padding='valid')
    x = conv2d_bn(x, 192, 3, padding='valid')
    x = MaxPooling2D(3, strides=2)(x)

    # Mixed 5b (Inception-A block): 35 x 35 x 320
    branch_0 = conv2d_bn(x, 96, 1)
    branch_1 = conv2d_bn(x, 48, 1)
    branch_1 = conv2d_bn(branch_1, 64, 5)
    branch_2 = conv2d_bn(x, 64, 1)
    branch_2 = conv2d_bn(branch_2, 96, 3)
    branch_2 = conv2d_bn(branch_2, 96, 3)
    branch_pool = AveragePooling2D(3, strides=1, padding='same')(x)
    branch_pool = conv2d_bn(branch_pool, 64, 1)
    branches = [branch_0, branch_1, branch_2, branch_pool]
    channel_axis = 3
    x = Concatenate(axis=channel_axis, name='mixed_5b')(branches)


    # 10x block35 (Inception-ResNet-A block): 35 x 35 x 320
    for block_idx in range(1, 11):
        x = inception_resnet_block(x,
                                   scale=0.17,
                                   block_type='block35',
                                   block_idx=block_idx)

    # Mixed 6a (Reduction-A block): 17 x 17 x 1088
    branch_0 = conv2d_bn(x, 384, 3, strides=2, padding='valid')
    branch_1 = conv2d_bn(x, 256, 1)
    branch_1 = conv2d_bn(branch_1, 256, 3)
    branch_1 = conv2d_bn(branch_1, 384, 3, strides=2, padding='valid')
    branch_pool = MaxPooling2D(3, strides=2, padding='valid')(x)
    branches = [branch_0, branch_1, branch_pool]
    x = Concatenate(axis=channel_axis, name='mixed_6a')(branches)


    # 20x block17 (Inception-ResNet-B block): 17 x 17 x 1088
    for block_idx in range(1, 21):
        x = inception_resnet_block(x,
                                   scale=0.1,
                                   block_type='block17',
                                   block_idx=block_idx)

    # Mixed 7a (Reduction-B block): 8 x 8 x 2080
    branch_0 = conv2d_bn(x, 256, 1)
    branch_0 = conv2d_bn(branch_0, 384, 3, strides=2, padding='valid')
    branch_1 = conv2d_bn(x, 256, 1)
    branch_1 = conv2d_bn(branch_1, 288, 3, strides=2, padding='valid')
    branch_2 = conv2d_bn(x, 256, 1)
    branch_2 = conv2d_bn(branch_2, 288, 3)
    branch_2 = conv2d_bn(branch_2, 320, 3, strides=2, padding='valid')
    branch_pool = MaxPooling2D(3, strides=2, padding='valid')(x)
    branches = [branch_0, branch_1, branch_2, branch_pool]
    x = Concatenate(axis=channel_axis, name='mixed_7a')(branches)


    # 10x block8 (Inception-ResNet-C block): 8 x 8 x 2080
    for block_idx in range(1, 10):
        x = inception_resnet_block(x,
                                   scale=0.2,
                                   block_type='block8',
                                   block_idx=block_idx)
    x = inception_resnet_block(x,
                               scale=1.,
                               activation=None,
                               block_type='block8',
                               block_idx=10)

    # Final convolution block: 8 x 8 x 1536
    x = conv2d_bn(x, 1536, 1, name='conv_7b')

    x = GlobalAveragePooling2D(name='avg_pool')(x)
    x = Dense(classes, use_bias=False, kernel_regularizer=l2(weight_decay), activation='softmax', name='predictions')(x)

    # Ensure that the model takes into account
    # any potential predecessors of `input_tensor`
    inputs = img_input

    # Create model
    model = Model(inputs, x, name=name)

    return model

# %% [markdown]
# ### 2) Almost Original Inception-ResNet-V2

# %%
model = Inception_ResNet_v2(input_shape=input_sizes, weight_decay=weight_decay, classes=classes, name='Inception_ResNet_v2')

# %%
model.summary()
# Out:
# Model: "Inception_ResNet_v2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 299, 299, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 149, 149, 32) 864         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 149, 149, 32) 96          conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 149, 149, 32) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 147, 147, 32) 9216        activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 147, 147, 32) 96          conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 147, 147, 32) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 147, 147, 64) 18432       activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 147, 147, 64) 192         conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 147, 147, 64) 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 73, 73, 64)   0           activation_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 73, 73, 80)   5120        max_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 73, 73, 80)   240         conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 73, 73, 80)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 71, 71, 192)  138240      activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 71, 71, 192)  576         conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 71, 71, 192)  0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 35, 35, 192)  0           activation_4[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 35, 35, 64)   12288       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 35, 35, 64)   192         conv2d_8[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 35, 35, 64)   0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 35, 35, 48)   9216        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 35, 35, 96)   55296       activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 35, 35, 48)   144         conv2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 35, 35, 96)   288         conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 35, 35, 48)   0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 35, 35, 96)   0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# average_pooling2d (AveragePooli (None, 35, 35, 192)  0           max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 35, 35, 96)   18432       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 35, 35, 64)   76800       activation_6[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 35, 35, 96)   82944       activation_9[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 35, 35, 64)   12288       average_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 35, 35, 96)   288         conv2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 35, 35, 64)   192         conv2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 35, 35, 96)   288         conv2d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 35, 35, 64)   192         conv2d_11[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 35, 35, 96)   0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 35, 35, 64)   0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 35, 35, 96)   0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 35, 35, 64)   0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# mixed_5b (Concatenate)          (None, 35, 35, 320)  0           activation_5[0][0]
#                                                                  activation_7[0][0]
#                                                                  activation_10[0][0]
#                                                                  activation_11[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 35, 35, 32)   10240       mixed_5b[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 35, 35, 32)   96          conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 35, 35, 32)   0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 35, 35, 32)   10240       mixed_5b[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 35, 35, 48)   13824       activation_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 35, 35, 32)   96          conv2d_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 35, 35, 48)   144         conv2d_16[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 35, 35, 32)   0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 35, 35, 48)   0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 35, 35, 32)   10240       mixed_5b[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 35, 35, 32)   9216        activation_13[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 35, 35, 64)   27648       activation_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 35, 35, 32)   96          conv2d_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 35, 35, 32)   96          conv2d_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 35, 35, 64)   192         conv2d_17[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 35, 35, 32)   0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 35, 35, 32)   0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 35, 35, 64)   0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# block35_1_mixed (Concatenate)   (None, 35, 35, 128)  0           activation_12[0][0]
#                                                                  activation_14[0][0]
#                                                                  activation_17[0][0]
# __________________________________________________________________________________________________
# block35_1_conv (Conv2D)         (None, 35, 35, 320)  41280       block35_1_mixed[0][0]
# __________________________________________________________________________________________________
# block35_1 (Lambda)              (None, 35, 35, 320)  0           mixed_5b[0][0]
#                                                                  block35_1_conv[0][0]
# __________________________________________________________________________________________________
# block35_1_ac (Activation)       (None, 35, 35, 320)  0           block35_1[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 35, 35, 32)   10240       block35_1_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 35, 35, 32)   96          conv2d_21[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 35, 35, 32)   0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 35, 35, 32)   10240       block35_1_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 35, 35, 48)   13824       activation_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 35, 35, 32)   96          conv2d_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 35, 35, 48)   144         conv2d_22[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 35, 35, 32)   0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 35, 35, 48)   0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 35, 35, 32)   10240       block35_1_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 35, 35, 32)   9216        activation_19[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 35, 35, 64)   27648       activation_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 35, 35, 32)   96          conv2d_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 35, 35, 32)   96          conv2d_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 35, 35, 64)   192         conv2d_23[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 35, 35, 32)   0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 35, 35, 32)   0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 35, 35, 64)   0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# block35_2_mixed (Concatenate)   (None, 35, 35, 128)  0           activation_18[0][0]
#                                                                  activation_20[0][0]
#                                                                  activation_23[0][0]
# __________________________________________________________________________________________________
# block35_2_conv (Conv2D)         (None, 35, 35, 320)  41280       block35_2_mixed[0][0]
# __________________________________________________________________________________________________
# block35_2 (Lambda)              (None, 35, 35, 320)  0           block35_1_ac[0][0]
#                                                                  block35_2_conv[0][0]
# __________________________________________________________________________________________________
# block35_2_ac (Activation)       (None, 35, 35, 320)  0           block35_2[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 35, 35, 32)   10240       block35_2_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 35, 35, 32)   96          conv2d_27[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 35, 35, 32)   0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 35, 35, 32)   10240       block35_2_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 35, 35, 48)   13824       activation_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 35, 35, 32)   96          conv2d_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 35, 35, 48)   144         conv2d_28[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 35, 35, 32)   0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 35, 35, 48)   0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 35, 35, 32)   10240       block35_2_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 35, 35, 32)   9216        activation_25[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 35, 35, 64)   27648       activation_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 35, 35, 32)   96          conv2d_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 35, 35, 32)   96          conv2d_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 35, 35, 64)   192         conv2d_29[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 35, 35, 32)   0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 35, 35, 32)   0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 35, 35, 64)   0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# block35_3_mixed (Concatenate)   (None, 35, 35, 128)  0           activation_24[0][0]
#                                                                  activation_26[0][0]
#                                                                  activation_29[0][0]
# __________________________________________________________________________________________________
# block35_3_conv (Conv2D)         (None, 35, 35, 320)  41280       block35_3_mixed[0][0]
# __________________________________________________________________________________________________
# block35_3 (Lambda)              (None, 35, 35, 320)  0           block35_2_ac[0][0]
#                                                                  block35_3_conv[0][0]
# __________________________________________________________________________________________________
# block35_3_ac (Activation)       (None, 35, 35, 320)  0           block35_3[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 35, 35, 32)   10240       block35_3_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 35, 35, 32)   96          conv2d_33[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 35, 35, 32)   0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 35, 35, 32)   10240       block35_3_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 35, 35, 48)   13824       activation_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 35, 35, 32)   96          conv2d_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 35, 35, 48)   144         conv2d_34[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 35, 35, 32)   0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 35, 35, 48)   0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 35, 35, 32)   10240       block35_3_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 35, 35, 32)   9216        activation_31[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 35, 35, 64)   27648       activation_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 35, 35, 32)   96          conv2d_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 35, 35, 32)   96          conv2d_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 35, 35, 64)   192         conv2d_35[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 35, 35, 32)   0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 35, 35, 32)   0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 35, 35, 64)   0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# block35_4_mixed (Concatenate)   (None, 35, 35, 128)  0           activation_30[0][0]
#                                                                  activation_32[0][0]
#                                                                  activation_35[0][0]
# __________________________________________________________________________________________________
# block35_4_conv (Conv2D)         (None, 35, 35, 320)  41280       block35_4_mixed[0][0]
# __________________________________________________________________________________________________
# block35_4 (Lambda)              (None, 35, 35, 320)  0           block35_3_ac[0][0]
#                                                                  block35_4_conv[0][0]
# __________________________________________________________________________________________________
# block35_4_ac (Activation)       (None, 35, 35, 320)  0           block35_4[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 35, 35, 32)   10240       block35_4_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 35, 35, 32)   96          conv2d_39[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 35, 35, 32)   0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 35, 35, 32)   10240       block35_4_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 35, 35, 48)   13824       activation_39[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 35, 35, 32)   96          conv2d_37[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 35, 35, 48)   144         conv2d_40[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 35, 35, 32)   0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 35, 35, 48)   0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 35, 35, 32)   10240       block35_4_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 35, 35, 32)   9216        activation_37[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 35, 35, 64)   27648       activation_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 35, 35, 32)   96          conv2d_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 35, 35, 32)   96          conv2d_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 35, 35, 64)   192         conv2d_41[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 35, 35, 32)   0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 35, 35, 32)   0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 35, 35, 64)   0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# block35_5_mixed (Concatenate)   (None, 35, 35, 128)  0           activation_36[0][0]
#                                                                  activation_38[0][0]
#                                                                  activation_41[0][0]
# __________________________________________________________________________________________________
# block35_5_conv (Conv2D)         (None, 35, 35, 320)  41280       block35_5_mixed[0][0]
# __________________________________________________________________________________________________
# block35_5 (Lambda)              (None, 35, 35, 320)  0           block35_4_ac[0][0]
#                                                                  block35_5_conv[0][0]
# __________________________________________________________________________________________________
# block35_5_ac (Activation)       (None, 35, 35, 320)  0           block35_5[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 35, 35, 32)   10240       block35_5_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 35, 35, 32)   96          conv2d_45[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 35, 35, 32)   0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 35, 35, 32)   10240       block35_5_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 35, 35, 48)   13824       activation_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 35, 35, 32)   96          conv2d_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 35, 35, 48)   144         conv2d_46[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 35, 35, 32)   0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 35, 35, 48)   0           batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 35, 35, 32)   10240       block35_5_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 35, 35, 32)   9216        activation_43[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 35, 35, 64)   27648       activation_46[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 35, 35, 32)   96          conv2d_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 35, 35, 32)   96          conv2d_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 35, 35, 64)   192         conv2d_47[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 35, 35, 32)   0           batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 35, 35, 32)   0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 35, 35, 64)   0           batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# block35_6_mixed (Concatenate)   (None, 35, 35, 128)  0           activation_42[0][0]
#                                                                  activation_44[0][0]
#                                                                  activation_47[0][0]
# __________________________________________________________________________________________________
# block35_6_conv (Conv2D)         (None, 35, 35, 320)  41280       block35_6_mixed[0][0]
# __________________________________________________________________________________________________
# block35_6 (Lambda)              (None, 35, 35, 320)  0           block35_5_ac[0][0]
#                                                                  block35_6_conv[0][0]
# __________________________________________________________________________________________________
# block35_6_ac (Activation)       (None, 35, 35, 320)  0           block35_6[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 35, 35, 32)   10240       block35_6_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 35, 35, 32)   96          conv2d_51[0][0]
# __________________________________________________________________________________________________
# activation_51 (Activation)      (None, 35, 35, 32)   0           batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 35, 35, 32)   10240       block35_6_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 35, 35, 48)   13824       activation_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 35, 35, 32)   96          conv2d_49[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 35, 35, 48)   144         conv2d_52[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 35, 35, 32)   0           batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# activation_52 (Activation)      (None, 35, 35, 48)   0           batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 35, 35, 32)   10240       block35_6_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 35, 35, 32)   9216        activation_49[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 35, 35, 64)   27648       activation_52[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 35, 35, 32)   96          conv2d_48[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 35, 35, 32)   96          conv2d_50[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, 35, 35, 64)   192         conv2d_53[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 35, 35, 32)   0           batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, 35, 35, 32)   0           batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# activation_53 (Activation)      (None, 35, 35, 64)   0           batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# block35_7_mixed (Concatenate)   (None, 35, 35, 128)  0           activation_48[0][0]
#                                                                  activation_50[0][0]
#                                                                  activation_53[0][0]
# __________________________________________________________________________________________________
# block35_7_conv (Conv2D)         (None, 35, 35, 320)  41280       block35_7_mixed[0][0]
# __________________________________________________________________________________________________
# block35_7 (Lambda)              (None, 35, 35, 320)  0           block35_6_ac[0][0]
#                                                                  block35_7_conv[0][0]
# __________________________________________________________________________________________________
# block35_7_ac (Activation)       (None, 35, 35, 320)  0           block35_7[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 35, 35, 32)   10240       block35_7_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_57 (BatchNo (None, 35, 35, 32)   96          conv2d_57[0][0]
# __________________________________________________________________________________________________
# activation_57 (Activation)      (None, 35, 35, 32)   0           batch_normalization_57[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 35, 35, 32)   10240       block35_7_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, 35, 35, 48)   13824       activation_57[0][0]
# __________________________________________________________________________________________________
# batch_normalization_55 (BatchNo (None, 35, 35, 32)   96          conv2d_55[0][0]
# __________________________________________________________________________________________________
# batch_normalization_58 (BatchNo (None, 35, 35, 48)   144         conv2d_58[0][0]
# __________________________________________________________________________________________________
# activation_55 (Activation)      (None, 35, 35, 32)   0           batch_normalization_55[0][0]
# __________________________________________________________________________________________________
# activation_58 (Activation)      (None, 35, 35, 48)   0           batch_normalization_58[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 35, 35, 32)   10240       block35_7_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 35, 35, 32)   9216        activation_55[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, 35, 35, 64)   27648       activation_58[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, 35, 35, 32)   96          conv2d_54[0][0]
# __________________________________________________________________________________________________
# batch_normalization_56 (BatchNo (None, 35, 35, 32)   96          conv2d_56[0][0]
# __________________________________________________________________________________________________
# batch_normalization_59 (BatchNo (None, 35, 35, 64)   192         conv2d_59[0][0]
# __________________________________________________________________________________________________
# activation_54 (Activation)      (None, 35, 35, 32)   0           batch_normalization_54[0][0]
# __________________________________________________________________________________________________
# activation_56 (Activation)      (None, 35, 35, 32)   0           batch_normalization_56[0][0]
# __________________________________________________________________________________________________
# activation_59 (Activation)      (None, 35, 35, 64)   0           batch_normalization_59[0][0]
# __________________________________________________________________________________________________
# block35_8_mixed (Concatenate)   (None, 35, 35, 128)  0           activation_54[0][0]
#                                                                  activation_56[0][0]
#                                                                  activation_59[0][0]
# __________________________________________________________________________________________________
# block35_8_conv (Conv2D)         (None, 35, 35, 320)  41280       block35_8_mixed[0][0]
# __________________________________________________________________________________________________
# block35_8 (Lambda)              (None, 35, 35, 320)  0           block35_7_ac[0][0]
#                                                                  block35_8_conv[0][0]
# __________________________________________________________________________________________________
# block35_8_ac (Activation)       (None, 35, 35, 320)  0           block35_8[0][0]
# __________________________________________________________________________________________________
# conv2d_63 (Conv2D)              (None, 35, 35, 32)   10240       block35_8_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_63 (BatchNo (None, 35, 35, 32)   96          conv2d_63[0][0]
# __________________________________________________________________________________________________
# activation_63 (Activation)      (None, 35, 35, 32)   0           batch_normalization_63[0][0]
# __________________________________________________________________________________________________
# conv2d_61 (Conv2D)              (None, 35, 35, 32)   10240       block35_8_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_64 (Conv2D)              (None, 35, 35, 48)   13824       activation_63[0][0]
# __________________________________________________________________________________________________
# batch_normalization_61 (BatchNo (None, 35, 35, 32)   96          conv2d_61[0][0]
# __________________________________________________________________________________________________
# batch_normalization_64 (BatchNo (None, 35, 35, 48)   144         conv2d_64[0][0]
# __________________________________________________________________________________________________
# activation_61 (Activation)      (None, 35, 35, 32)   0           batch_normalization_61[0][0]
# __________________________________________________________________________________________________
# activation_64 (Activation)      (None, 35, 35, 48)   0           batch_normalization_64[0][0]
# __________________________________________________________________________________________________
# conv2d_60 (Conv2D)              (None, 35, 35, 32)   10240       block35_8_ac[0][0]
# __________________________________________________________________________________________________
# ...
# __________________________________________________________________________________________________
# activation_183 (Activation)     (None, 8, 8, 192)    0           batch_normalization_183[0][0]
# __________________________________________________________________________________________________
# activation_186 (Activation)     (None, 8, 8, 256)    0           batch_normalization_186[0][0]
# __________________________________________________________________________________________________
# block8_6_mixed (Concatenate)    (None, 8, 8, 448)    0           activation_183[0][0]
#                                                                  activation_186[0][0]
# __________________________________________________________________________________________________
# block8_6_conv (Conv2D)          (None, 8, 8, 2080)   933920      block8_6_mixed[0][0]
# __________________________________________________________________________________________________
# block8_6 (Lambda)               (None, 8, 8, 2080)   0           block8_5_ac[0][0]
#                                                                  block8_6_conv[0][0]
# __________________________________________________________________________________________________
# block8_6_ac (Activation)        (None, 8, 8, 2080)   0           block8_6[0][0]
# __________________________________________________________________________________________________
# conv2d_188 (Conv2D)             (None, 8, 8, 192)    399360      block8_6_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_188 (BatchN (None, 8, 8, 192)    576         conv2d_188[0][0]
# __________________________________________________________________________________________________
# activation_188 (Activation)     (None, 8, 8, 192)    0           batch_normalization_188[0][0]
# __________________________________________________________________________________________________
# conv2d_189 (Conv2D)             (None, 8, 8, 224)    129024      activation_188[0][0]
# __________________________________________________________________________________________________
# batch_normalization_189 (BatchN (None, 8, 8, 224)    672         conv2d_189[0][0]
# __________________________________________________________________________________________________
# activation_189 (Activation)     (None, 8, 8, 224)    0           batch_normalization_189[0][0]
# __________________________________________________________________________________________________
# conv2d_187 (Conv2D)             (None, 8, 8, 192)    399360      block8_6_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_190 (Conv2D)             (None, 8, 8, 256)    172032      activation_189[0][0]
# __________________________________________________________________________________________________
# batch_normalization_187 (BatchN (None, 8, 8, 192)    576         conv2d_187[0][0]
# __________________________________________________________________________________________________
# batch_normalization_190 (BatchN (None, 8, 8, 256)    768         conv2d_190[0][0]
# __________________________________________________________________________________________________
# activation_187 (Activation)     (None, 8, 8, 192)    0           batch_normalization_187[0][0]
# __________________________________________________________________________________________________
# activation_190 (Activation)     (None, 8, 8, 256)    0           batch_normalization_190[0][0]
# __________________________________________________________________________________________________
# block8_7_mixed (Concatenate)    (None, 8, 8, 448)    0           activation_187[0][0]
#                                                                  activation_190[0][0]
# __________________________________________________________________________________________________
# block8_7_conv (Conv2D)          (None, 8, 8, 2080)   933920      block8_7_mixed[0][0]
# __________________________________________________________________________________________________
# block8_7 (Lambda)               (None, 8, 8, 2080)   0           block8_6_ac[0][0]
#                                                                  block8_7_conv[0][0]
# __________________________________________________________________________________________________
# block8_7_ac (Activation)        (None, 8, 8, 2080)   0           block8_7[0][0]
# __________________________________________________________________________________________________
# conv2d_192 (Conv2D)             (None, 8, 8, 192)    399360      block8_7_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_192 (BatchN (None, 8, 8, 192)    576         conv2d_192[0][0]
# __________________________________________________________________________________________________
# activation_192 (Activation)     (None, 8, 8, 192)    0           batch_normalization_192[0][0]
# __________________________________________________________________________________________________
# conv2d_193 (Conv2D)             (None, 8, 8, 224)    129024      activation_192[0][0]
# __________________________________________________________________________________________________
# batch_normalization_193 (BatchN (None, 8, 8, 224)    672         conv2d_193[0][0]
# __________________________________________________________________________________________________
# activation_193 (Activation)     (None, 8, 8, 224)    0           batch_normalization_193[0][0]
# __________________________________________________________________________________________________
# conv2d_191 (Conv2D)             (None, 8, 8, 192)    399360      block8_7_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_194 (Conv2D)             (None, 8, 8, 256)    172032      activation_193[0][0]
# __________________________________________________________________________________________________
# batch_normalization_191 (BatchN (None, 8, 8, 192)    576         conv2d_191[0][0]
# __________________________________________________________________________________________________
# batch_normalization_194 (BatchN (None, 8, 8, 256)    768         conv2d_194[0][0]
# __________________________________________________________________________________________________
# activation_191 (Activation)     (None, 8, 8, 192)    0           batch_normalization_191[0][0]
# __________________________________________________________________________________________________
# activation_194 (Activation)     (None, 8, 8, 256)    0           batch_normalization_194[0][0]
# __________________________________________________________________________________________________
# block8_8_mixed (Concatenate)    (None, 8, 8, 448)    0           activation_191[0][0]
#                                                                  activation_194[0][0]
# __________________________________________________________________________________________________
# block8_8_conv (Conv2D)          (None, 8, 8, 2080)   933920      block8_8_mixed[0][0]
# __________________________________________________________________________________________________
# block8_8 (Lambda)               (None, 8, 8, 2080)   0           block8_7_ac[0][0]
#                                                                  block8_8_conv[0][0]
# __________________________________________________________________________________________________
# block8_8_ac (Activation)        (None, 8, 8, 2080)   0           block8_8[0][0]
# __________________________________________________________________________________________________
# conv2d_196 (Conv2D)             (None, 8, 8, 192)    399360      block8_8_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_196 (BatchN (None, 8, 8, 192)    576         conv2d_196[0][0]
# __________________________________________________________________________________________________
# activation_196 (Activation)     (None, 8, 8, 192)    0           batch_normalization_196[0][0]
# __________________________________________________________________________________________________
# conv2d_197 (Conv2D)             (None, 8, 8, 224)    129024      activation_196[0][0]
# __________________________________________________________________________________________________
# batch_normalization_197 (BatchN (None, 8, 8, 224)    672         conv2d_197[0][0]
# __________________________________________________________________________________________________
# activation_197 (Activation)     (None, 8, 8, 224)    0           batch_normalization_197[0][0]
# __________________________________________________________________________________________________
# conv2d_195 (Conv2D)             (None, 8, 8, 192)    399360      block8_8_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_198 (Conv2D)             (None, 8, 8, 256)    172032      activation_197[0][0]
# __________________________________________________________________________________________________
# batch_normalization_195 (BatchN (None, 8, 8, 192)    576         conv2d_195[0][0]
# __________________________________________________________________________________________________
# batch_normalization_198 (BatchN (None, 8, 8, 256)    768         conv2d_198[0][0]
# __________________________________________________________________________________________________
# activation_195 (Activation)     (None, 8, 8, 192)    0           batch_normalization_195[0][0]
# __________________________________________________________________________________________________
# activation_198 (Activation)     (None, 8, 8, 256)    0           batch_normalization_198[0][0]
# __________________________________________________________________________________________________
# block8_9_mixed (Concatenate)    (None, 8, 8, 448)    0           activation_195[0][0]
#                                                                  activation_198[0][0]
# __________________________________________________________________________________________________
# block8_9_conv (Conv2D)          (None, 8, 8, 2080)   933920      block8_9_mixed[0][0]
# __________________________________________________________________________________________________
# block8_9 (Lambda)               (None, 8, 8, 2080)   0           block8_8_ac[0][0]
#                                                                  block8_9_conv[0][0]
# __________________________________________________________________________________________________
# block8_9_ac (Activation)        (None, 8, 8, 2080)   0           block8_9[0][0]
# __________________________________________________________________________________________________
# conv2d_200 (Conv2D)             (None, 8, 8, 192)    399360      block8_9_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_200 (BatchN (None, 8, 8, 192)    576         conv2d_200[0][0]
# __________________________________________________________________________________________________
# activation_200 (Activation)     (None, 8, 8, 192)    0           batch_normalization_200[0][0]
# __________________________________________________________________________________________________
# conv2d_201 (Conv2D)             (None, 8, 8, 224)    129024      activation_200[0][0]
# __________________________________________________________________________________________________
# batch_normalization_201 (BatchN (None, 8, 8, 224)    672         conv2d_201[0][0]
# __________________________________________________________________________________________________
# activation_201 (Activation)     (None, 8, 8, 224)    0           batch_normalization_201[0][0]
# __________________________________________________________________________________________________
# conv2d_199 (Conv2D)             (None, 8, 8, 192)    399360      block8_9_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_202 (Conv2D)             (None, 8, 8, 256)    172032      activation_201[0][0]
# __________________________________________________________________________________________________
# batch_normalization_199 (BatchN (None, 8, 8, 192)    576         conv2d_199[0][0]
# __________________________________________________________________________________________________
# batch_normalization_202 (BatchN (None, 8, 8, 256)    768         conv2d_202[0][0]
# __________________________________________________________________________________________________
# activation_199 (Activation)     (None, 8, 8, 192)    0           batch_normalization_199[0][0]
# __________________________________________________________________________________________________
# activation_202 (Activation)     (None, 8, 8, 256)    0           batch_normalization_202[0][0]
# __________________________________________________________________________________________________
# block8_10_mixed (Concatenate)   (None, 8, 8, 448)    0           activation_199[0][0]
#                                                                  activation_202[0][0]
# __________________________________________________________________________________________________
# block8_10_conv (Conv2D)         (None, 8, 8, 2080)   933920      block8_10_mixed[0][0]
# __________________________________________________________________________________________________
# block8_10 (Lambda)              (None, 8, 8, 2080)   0           block8_9_ac[0][0]
#                                                                  block8_10_conv[0][0]
# __________________________________________________________________________________________________
# conv_7b (Conv2D)                (None, 8, 8, 1536)   3194880     block8_10[0][0]
# __________________________________________________________________________________________________
# conv_7b_bn (BatchNormalization) (None, 8, 8, 1536)   4608        conv_7b[0][0]
# __________________________________________________________________________________________________
# conv_7b_ac (Activation)         (None, 8, 8, 1536)   0           conv_7b_bn[0][0]
# __________________________________________________________________________________________________
# avg_pool (GlobalAveragePooling2 (None, 1536)         0           conv_7b_ac[0][0]
# __________________________________________________________________________________________________
# predictions (Dense)             (None, 7)            10752       avg_pool[0][0]
# ==================================================================================================
# Total params: 54,347,488
# Trainable params: 54,286,944
# Non-trainable params: 60,544
# __________________________________________________________________________________________________

# %%
# 폴더 생성

os.makedirs(os.path.join(dir,'model_output',number,model.name), exist_ok=True)
os.makedirs(os.path.join(dir,'train_valid_output',number), exist_ok=True)

# %%
# 참고 : https://github.com/OverLordGoldDragon/keras-adamw

import sys
sys.path.append('/content/drive/My Drive/Colab Notebooks/Paper')
import utils
import optimizers_v2
from utils import get_weight_decays, fill_dict_in_order
from utils import reset_seeds, K_eval
from optimizers_v2 import AdamW, NadamW, SGDW

# %%
# top-5 accuracy 출력
import functools
top5_acc = functools.partial(ks.metrics.top_k_categorical_accuracy, k=5)
top5_acc.__name__ = 'top5_acc'

# %%
#optimizer = SGDW(model=model, use_cosine_annealing=False, total_iterations = len(x_train) // batch_sizes, nesterov=True, momentum=0.9)
optimizer = AdamW(model=model, use_cosine_annealing=False, total_iterations = len(x_train) // batch_sizes)
#optimizer = Adam()
filepath =  os.path.join(dir,'model_output',number,model.name,'{epoch:03d}.h5')

callbacks_list = [ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_weights_only=False, save_best_only=True, mode='min'),
                  ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_weights_only=False, save_best_only=True, mode='max'),
                  #ReduceLROnPlateau(monitor='val_loss',patience=3,factor=0.1,min_lr=1e-5),
                  LearningRateScheduler(lr_schedule,verbose=1)
                  ]
                  
model.compile(optimizer, loss = 'categorical_crossentropy', metrics=['accuracy',top5_acc,macro_f1score])

# %%
######## flow_from_directory
history = model.fit(train_generator, steps_per_epoch=int(len(x_train)/batch_sizes),  validation_data = valid_generator, epochs=epochs , verbose=1 , callbacks = callbacks_list , validation_steps=int(len(x_valid)/batch_sizes))
# Out:
# Learning rate:  0.001
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 1/70
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_1/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_2/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_3/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_4/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_8/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_6/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_9/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_5/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_7/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_10/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_11/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_15/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_13/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_16/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_12/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_14/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_17/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for block35_1_conv/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_21/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_19/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_22/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_18/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_20/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_23/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for block35_2_conv/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_27/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_25/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_28/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_24/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_26/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_29/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for block35_3_conv/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_33/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_31/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_34/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_30/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_32/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_35/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for block35_4_conv/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_39/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_37/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_40/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_36/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_38/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_41/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for block35_5_conv/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_45/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_43/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_46/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_42/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_44/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_47/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for block35_6_conv/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_51/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_49/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_52/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_48/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_50/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_53/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for block35_7_conv/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_57/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_55/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_58/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_54/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_56/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_59/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for block35_8_conv/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_63/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_61/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_64/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_60/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_62/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_65/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for block35_9_conv/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_69/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_67/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_70/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_66/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_68/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_71/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for block35_10_conv/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_73/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_74/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_72/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_75/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_77/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_78/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_76/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_79/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for block17_1_conv/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_81/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_82/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_80/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_83/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for block17_2_conv/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_85/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_86/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_84/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_87/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for block17_3_conv/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_89/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_90/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_88/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_91/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for block17_4_conv/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_93/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_94/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_92/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_95/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for block17_5_conv/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_97/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_98/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_96/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_99/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for block17_6_conv/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_101/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_102/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_100/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_103/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for block17_7_conv/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_105/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_106/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_104/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_107/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for block17_8_conv/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_109/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_110/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_108/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_111/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for block17_9_conv/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_113/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_114/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_112/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_115/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for block17_10_conv/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_117/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_118/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_116/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_119/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for block17_11_conv/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_121/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_122/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_120/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_123/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for block17_12_conv/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_125/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_126/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_124/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_127/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for block17_13_conv/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_129/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_130/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_128/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_131/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for block17_14_conv/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_133/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_134/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_132/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_135/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for block17_15_conv/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_137/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_138/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_136/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_139/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for block17_16_conv/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_141/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_142/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_140/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_143/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for block17_17_conv/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_145/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_146/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_144/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_147/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for block17_18_conv/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_149/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_150/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_148/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_151/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for block17_19_conv/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_153/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_154/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_152/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_155/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for block17_20_conv/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_160/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_156/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_158/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_161/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_157/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_159/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_162/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_164/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_165/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_163/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_166/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for block8_1_conv/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_168/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_169/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_167/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_170/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for block8_2_conv/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_172/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_173/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_171/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_174/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for block8_3_conv/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_176/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_177/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_175/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_178/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for block8_4_conv/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_180/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_181/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_179/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_182/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for block8_5_conv/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_184/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_185/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_183/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_186/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for block8_6_conv/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_188/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_189/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_187/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_190/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for block8_7_conv/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_192/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_193/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_191/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_194/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for block8_8_conv/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_196/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_197/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_195/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_198/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for block8_9_conv/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_200/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_201/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_199/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv2d_202/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for block8_10_conv/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for conv_7b/kernel:0
# 0.0(L1), 3.3407656825831525e-05(L2) weight decay set for predictions/kernel:0
# 896/896 [==============================] - ETA: 0s - loss: 1.6042 - accuracy: 0.3671 - top5_acc: 0.9323 - macro_f1score: 0.1126
# Epoch 00001: val_loss improved from inf to 2.12843, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/Inception_ResNet_v2/001.h5
#
# Epoch 00001: val_accuracy improved from -inf to 0.38477, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/Inception_ResNet_v2/001.h5
# 896/896 [==============================] - 10962s 12s/step - loss: 1.6042 - accuracy: 0.3671 - top5_acc: 0.9323 - macro_f1score: 0.1126 - val_loss: 2.1284 - val_accuracy: 0.3848 - val_top5_acc: 0.8878 - val_macro_f1score: 0.2341
# Learning rate:  0.001
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 2/70
# 896/896 [==============================] - ETA: 0s - loss: 1.2965 - accuracy: 0.5030 - top5_acc: 0.9695 - macro_f1score: 0.2540
# Epoch 00002: val_loss improved from 2.12843 to 1.21118, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/Inception_ResNet_v2/002.h5
#
# Epoch 00002: val_accuracy improved from 0.38477 to 0.53711, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/Inception_ResNet_v2/002.h5
# 896/896 [==============================] - 692s 772ms/step - loss: 1.2965 - accuracy: 0.5030 - top5_acc: 0.9695 - macro_f1score: 0.2540 - val_loss: 1.2112 - val_accuracy: 0.5371 - val_top5_acc: 0.9735 - val_macro_f1score: 0.3145
# Learning rate:  0.001
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 3/70
# 896/896 [==============================] - ETA: 0s - loss: 1.1901 - accuracy: 0.5456 - top5_acc: 0.9777 - macro_f1score: 0.3173
# Epoch 00003: val_loss did not improve from 1.21118
#
# Epoch 00003: val_accuracy did not improve from 0.53711
# 896/896 [==============================] - 662s 739ms/step - loss: 1.1901 - accuracy: 0.5456 - top5_acc: 0.9777 - macro_f1score: 0.3173 - val_loss: 1.2875 - val_accuracy: 0.4855 - val_top5_acc: 0.9763 - val_macro_f1score: 0.2869
# Learning rate:  0.001
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 4/70
# 896/896 [==============================] - ETA: 0s - loss: 1.1266 - accuracy: 0.5751 - top5_acc: 0.9812 - macro_f1score: 0.3609
# Epoch 00004: val_loss improved from 1.21118 to 1.14109, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/Inception_ResNet_v2/004.h5
#
# Epoch 00004: val_accuracy improved from 0.53711 to 0.57003, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/Inception_ResNet_v2/004.h5
# 896/896 [==============================] - 670s 748ms/step - loss: 1.1266 - accuracy: 0.5751 - top5_acc: 0.9812 - macro_f1score: 0.3609 - val_loss: 1.1411 - val_accuracy: 0.5700 - val_top5_acc: 0.9741 - val_macro_f1score: 0.3544
# Learning rate:  0.001
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 5/70
# 896/896 [==============================] - ETA: 0s - loss: 1.0889 - accuracy: 0.5913 - top5_acc: 0.9820 - macro_f1score: 0.3827
# Epoch 00005: val_loss did not improve from 1.14109
#
# Epoch 00005: val_accuracy improved from 0.57003 to 0.57729, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/Inception_ResNet_v2/005.h5
# 896/896 [==============================] - 654s 730ms/step - loss: 1.0889 - accuracy: 0.5913 - top5_acc: 0.9820 - macro_f1score: 0.3827 - val_loss: 1.1549 - val_accuracy: 0.5773 - val_top5_acc: 0.9824 - val_macro_f1score: 0.4065
# Learning rate:  0.001
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 6/70
# 896/896 [==============================] - ETA: 0s - loss: 1.0572 - accuracy: 0.6024 - top5_acc: 0.9854 - macro_f1score: 0.4051
# Epoch 00006: val_loss improved from 1.14109 to 1.11677, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/Inception_ResNet_v2/006.h5
#
# Epoch 00006: val_accuracy improved from 0.57729 to 0.58538, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/Inception_ResNet_v2/006.h5
# 896/896 [==============================] - 655s 731ms/step - loss: 1.0572 - accuracy: 0.6024 - top5_acc: 0.9854 - macro_f1score: 0.4051 - val_loss: 1.1168 - val_accuracy: 0.5854 - val_top5_acc: 0.9816 - val_macro_f1score: 0.3978
# Learning rate:  0.001
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 7/70
# 896/896 [==============================] - ETA: 0s - loss: 1.0138 - accuracy: 0.6178 - top5_acc: 0.9856 - macro_f1score: 0.4320
# Epoch 00007: val_loss improved from 1.11677 to 1.07221, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/Inception_ResNet_v2/007.h5
#
# Epoch 00007: val_accuracy improved from 0.58538 to 0.58956, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/Inception_ResNet_v2/007.h5
# 896/896 [==============================] - 652s 728ms/step - loss: 1.0138 - accuracy: 0.6178 - top5_acc: 0.9856 - macro_f1score: 0.4320 - val_loss: 1.0722 - val_accuracy: 0.5896 - val_top5_acc: 0.9838 - val_macro_f1score: 0.4251
# Learning rate:  0.001
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 8/70
# 896/896 [==============================] - ETA: 0s - loss: 0.9882 - accuracy: 0.6276 - top5_acc: 0.9873 - macro_f1score: 0.4448
# Epoch 00008: val_loss did not improve from 1.07221
#
# Epoch 00008: val_accuracy did not improve from 0.58956
# 896/896 [==============================] - 645s 719ms/step - loss: 0.9882 - accuracy: 0.6276 - top5_acc: 0.9873 - macro_f1score: 0.4448 - val_loss: 1.1503 - val_accuracy: 0.5851 - val_top5_acc: 0.9863 - val_macro_f1score: 0.3969
# Learning rate:  0.001
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 9/70
# 896/896 [==============================] - ETA: 0s - loss: 0.9619 - accuracy: 0.6392 - top5_acc: 0.9877 - macro_f1score: 0.4641
# Epoch 00009: val_loss improved from 1.07221 to 0.99834, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/Inception_ResNet_v2/009.h5
#
# Epoch 00009: val_accuracy improved from 0.58956 to 0.62305, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/Inception_ResNet_v2/009.h5
# 896/896 [==============================] - 654s 729ms/step - loss: 0.9619 - accuracy: 0.6392 - top5_acc: 0.9877 - macro_f1score: 0.4641 - val_loss: 0.9983 - val_accuracy: 0.6230 - val_top5_acc: 0.9852 - val_macro_f1score: 0.4364
# Learning rate:  0.001
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 10/70
# 896/896 [==============================] - ETA: 0s - loss: 0.9383 - accuracy: 0.6492 - top5_acc: 0.9903 - macro_f1score: 0.4756
# Epoch 00010: val_loss did not improve from 0.99834
#
# Epoch 00010: val_accuracy did not improve from 0.62305
# 896/896 [==============================] - 645s 720ms/step - loss: 0.9383 - accuracy: 0.6492 - top5_acc: 0.9903 - macro_f1score: 0.4756 - val_loss: 1.0186 - val_accuracy: 0.6127 - val_top5_acc: 0.9860 - val_macro_f1score: 0.4226
# Learning rate:  0.001
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 11/70
# 896/896 [==============================] - ETA: 0s - loss: 0.9109 - accuracy: 0.6588 - top5_acc: 0.9907 - macro_f1score: 0.4940
# Epoch 00011: val_loss did not improve from 0.99834
#
# Epoch 00011: val_accuracy improved from 0.62305 to 0.62807, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/Inception_ResNet_v2/011.h5
# 896/896 [==============================] - 647s 723ms/step - loss: 0.9109 - accuracy: 0.6588 - top5_acc: 0.9907 - macro_f1score: 0.4940 - val_loss: 1.0059 - val_accuracy: 0.6281 - val_top5_acc: 0.9847 - val_macro_f1score: 0.4623
# Learning rate:  0.001
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 12/70
# 896/896 [==============================] - ETA: 0s - loss: 0.8896 - accuracy: 0.6671 - top5_acc: 0.9922 - macro_f1score: 0.5077
# Epoch 00012: val_loss did not improve from 0.99834
#
# Epoch 00012: val_accuracy did not improve from 0.62807
# 896/896 [==============================] - 646s 721ms/step - loss: 0.8896 - accuracy: 0.6671 - top5_acc: 0.9922 - macro_f1score: 0.5077 - val_loss: 1.0416 - val_accuracy: 0.6099 - val_top5_acc: 0.9874 - val_macro_f1score: 0.4558
# Learning rate:  0.001
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 13/70
# 896/896 [==============================] - ETA: 0s - loss: 0.8726 - accuracy: 0.6725 - top5_acc: 0.9918 - macro_f1score: 0.5221
# Epoch 00013: val_loss improved from 0.99834 to 0.98882, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/Inception_ResNet_v2/013.h5
#
# Epoch 00013: val_accuracy improved from 0.62807 to 0.64174, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/Inception_ResNet_v2/013.h5
# 896/896 [==============================] - 653s 729ms/step - loss: 0.8726 - accuracy: 0.6725 - top5_acc: 0.9918 - macro_f1score: 0.5221 - val_loss: 0.9888 - val_accuracy: 0.6417 - val_top5_acc: 0.9900 - val_macro_f1score: 0.4930
# Learning rate:  0.001
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 14/70
# 896/896 [==============================] - ETA: 0s - loss: 0.8504 - accuracy: 0.6807 - top5_acc: 0.9930 - macro_f1score: 0.5298
# Epoch 00014: val_loss did not improve from 0.98882
#
# Epoch 00014: val_accuracy did not improve from 0.64174
# 896/896 [==============================] - 643s 717ms/step - loss: 0.8504 - accuracy: 0.6807 - top5_acc: 0.9930 - macro_f1score: 0.5298 - val_loss: 1.0296 - val_accuracy: 0.6272 - val_top5_acc: 0.9855 - val_macro_f1score: 0.4588
# Learning rate:  0.001
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 15/70
# 896/896 [==============================] - ETA: 0s - loss: 0.8276 - accuracy: 0.6921 - top5_acc: 0.9938 - macro_f1score: 0.5467
# Epoch 00015: val_loss improved from 0.98882 to 0.96206, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/Inception_ResNet_v2/015.h5
#
# Epoch 00015: val_accuracy improved from 0.64174 to 0.64509, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/Inception_ResNet_v2/015.h5
# 896/896 [==============================] - 654s 730ms/step - loss: 0.8276 - accuracy: 0.6921 - top5_acc: 0.9938 - macro_f1score: 0.5467 - val_loss: 0.9621 - val_accuracy: 0.6451 - val_top5_acc: 0.9891 - val_macro_f1score: 0.4910
# Learning rate:  0.001
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 16/70
# 896/896 [==============================] - ETA: 0s - loss: 0.8138 - accuracy: 0.6960 - top5_acc: 0.9940 - macro_f1score: 0.5547
# Epoch 00016: val_loss did not improve from 0.96206
#
# Epoch 00016: val_accuracy did not improve from 0.64509
# 896/896 [==============================] - 647s 722ms/step - loss: 0.8138 - accuracy: 0.6960 - top5_acc: 0.9940 - macro_f1score: 0.5547 - val_loss: 1.0110 - val_accuracy: 0.6348 - val_top5_acc: 0.9869 - val_macro_f1score: 0.4708
# Learning rate:  0.001
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 17/70
# 896/896 [==============================] - ETA: 0s - loss: 0.7852 - accuracy: 0.7084 - top5_acc: 0.9940 - macro_f1score: 0.5698
# Epoch 00017: val_loss improved from 0.96206 to 0.95141, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/Inception_ResNet_v2/017.h5
#
# Epoch 00017: val_accuracy improved from 0.64509 to 0.66127, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/Inception_ResNet_v2/017.h5
# 896/896 [==============================] - 653s 728ms/step - loss: 0.7852 - accuracy: 0.7084 - top5_acc: 0.9940 - macro_f1score: 0.5698 - val_loss: 0.9514 - val_accuracy: 0.6613 - val_top5_acc: 0.9886 - val_macro_f1score: 0.5133
# Learning rate:  0.001
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 18/70
# 896/896 [==============================] - ETA: 0s - loss: 0.7680 - accuracy: 0.7139 - top5_acc: 0.9960 - macro_f1score: 0.5763
# Epoch 00018: val_loss did not improve from 0.95141
#
# Epoch 00018: val_accuracy did not improve from 0.66127
# 896/896 [==============================] - 642s 717ms/step - loss: 0.7680 - accuracy: 0.7139 - top5_acc: 0.9960 - macro_f1score: 0.5763 - val_loss: 0.9941 - val_accuracy: 0.6429 - val_top5_acc: 0.9894 - val_macro_f1score: 0.4832
# Learning rate:  0.001
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 19/70
# 896/896 [==============================] - ETA: 0s - loss: 0.7471 - accuracy: 0.7233 - top5_acc: 0.9956 - macro_f1score: 0.5920
# Epoch 00019: val_loss did not improve from 0.95141
#
# Epoch 00019: val_accuracy did not improve from 0.66127
# 896/896 [==============================] - 644s 718ms/step - loss: 0.7471 - accuracy: 0.7233 - top5_acc: 0.9956 - macro_f1score: 0.5920 - val_loss: 1.0160 - val_accuracy: 0.6521 - val_top5_acc: 0.9891 - val_macro_f1score: 0.4921
# Learning rate:  0.001
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 20/70
# 896/896 [==============================] - ETA: 0s - loss: 0.7236 - accuracy: 0.7351 - top5_acc: 0.9952 - macro_f1score: 0.6046
# Epoch 00020: val_loss did not improve from 0.95141
#
# Epoch 00020: val_accuracy did not improve from 0.66127
# 896/896 [==============================] - 646s 721ms/step - loss: 0.7236 - accuracy: 0.7351 - top5_acc: 0.9952 - macro_f1score: 0.6046 - val_loss: 0.9697 - val_accuracy: 0.6518 - val_top5_acc: 0.9908 - val_macro_f1score: 0.5143
# Learning rate:  0.001
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 21/70
# 896/896 [==============================] - ETA: 0s - loss: 0.7016 - accuracy: 0.7429 - top5_acc: 0.9961 - macro_f1score: 0.6159
# Epoch 00021: val_loss improved from 0.95141 to 0.92513, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/Inception_ResNet_v2/021.h5
#
# Epoch 00021: val_accuracy did not improve from 0.66127
# 896/896 [==============================] - 650s 725ms/step - loss: 0.7016 - accuracy: 0.7429 - top5_acc: 0.9961 - macro_f1score: 0.6159 - val_loss: 0.9251 - val_accuracy: 0.6602 - val_top5_acc: 0.9900 - val_macro_f1score: 0.5264
# Learning rate:  0.001
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 22/70
# 896/896 [==============================] - ETA: 0s - loss: 0.6765 - accuracy: 0.7504 - top5_acc: 0.9962 - macro_f1score: 0.6307
# Epoch 00022: val_loss did not improve from 0.92513
#
# Epoch 00022: val_accuracy did not improve from 0.66127
# 896/896 [==============================] - 644s 719ms/step - loss: 0.6765 - accuracy: 0.7504 - top5_acc: 0.9962 - macro_f1score: 0.6307 - val_loss: 0.9778 - val_accuracy: 0.6537 - val_top5_acc: 0.9880 - val_macro_f1score: 0.5137
# Learning rate:  0.001
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 23/70
# 896/896 [==============================] - ETA: 0s - loss: 0.6644 - accuracy: 0.7543 - top5_acc: 0.9967 - macro_f1score: 0.6345
# Epoch 00023: val_loss did not improve from 0.92513
#
# Epoch 00023: val_accuracy improved from 0.66127 to 0.66239, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/Inception_ResNet_v2/023.h5
# 896/896 [==============================] - 652s 728ms/step - loss: 0.6644 - accuracy: 0.7543 - top5_acc: 0.9967 - macro_f1score: 0.6345 - val_loss: 0.9669 - val_accuracy: 0.6624 - val_top5_acc: 0.9905 - val_macro_f1score: 0.5383
# Learning rate:  0.001
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 24/70
# 896/896 [==============================] - ETA: 0s - loss: 0.6367 - accuracy: 0.7642 - top5_acc: 0.9972 - macro_f1score: 0.6486
# Epoch 00024: val_loss did not improve from 0.92513
#
# Epoch 00024: val_accuracy improved from 0.66239 to 0.66378, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/Inception_ResNet_v2/024.h5
# 896/896 [==============================] - 653s 728ms/step - loss: 0.6367 - accuracy: 0.7642 - top5_acc: 0.9972 - macro_f1score: 0.6486 - val_loss: 0.9916 - val_accuracy: 0.6638 - val_top5_acc: 0.9888 - val_macro_f1score: 0.5504
# Learning rate:  0.001
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 25/70
# 896/896 [==============================] - ETA: 0s - loss: 0.6178 - accuracy: 0.7714 - top5_acc: 0.9974 - macro_f1score: 0.6562
# Epoch 00025: val_loss did not improve from 0.92513
#
# Epoch 00025: val_accuracy did not improve from 0.66378
# 896/896 [==============================] - 652s 727ms/step - loss: 0.6178 - accuracy: 0.7714 - top5_acc: 0.9974 - macro_f1score: 0.6562 - val_loss: 1.0460 - val_accuracy: 0.6529 - val_top5_acc: 0.9852 - val_macro_f1score: 0.5246
# Learning rate:  0.001
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 26/70
# 896/896 [==============================] - ETA: 0s - loss: 0.5909 - accuracy: 0.7808 - top5_acc: 0.9982 - macro_f1score: 0.6725
# Epoch 00026: val_loss did not improve from 0.92513
#
# Epoch 00026: val_accuracy did not improve from 0.66378
# 896/896 [==============================] - 652s 727ms/step - loss: 0.5909 - accuracy: 0.7808 - top5_acc: 0.9982 - macro_f1score: 0.6725 - val_loss: 1.0115 - val_accuracy: 0.6434 - val_top5_acc: 0.9894 - val_macro_f1score: 0.5098
# Learning rate:  0.001
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 27/70
# 896/896 [==============================] - ETA: 0s - loss: 0.5710 - accuracy: 0.7872 - top5_acc: 0.9981 - macro_f1score: 0.6781
# Epoch 00027: val_loss did not improve from 0.92513
#
# Epoch 00027: val_accuracy did not improve from 0.66378
# 896/896 [==============================] - 645s 720ms/step - loss: 0.5710 - accuracy: 0.7872 - top5_acc: 0.9981 - macro_f1score: 0.6781 - val_loss: 1.0190 - val_accuracy: 0.6613 - val_top5_acc: 0.9894 - val_macro_f1score: 0.5385
# Learning rate:  0.001
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 28/70
# 896/896 [==============================] - ETA: 0s - loss: 0.5589 - accuracy: 0.7970 - top5_acc: 0.9982 - macro_f1score: 0.6883
# Epoch 00028: val_loss did not improve from 0.92513
#
# Epoch 00028: val_accuracy did not improve from 0.66378
# 896/896 [==============================] - 643s 717ms/step - loss: 0.5589 - accuracy: 0.7970 - top5_acc: 0.9982 - macro_f1score: 0.6883 - val_loss: 1.1227 - val_accuracy: 0.6585 - val_top5_acc: 0.9866 - val_macro_f1score: 0.5405
# Learning rate:  0.001
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 29/70
# 896/896 [==============================] - ETA: 0s - loss: 0.5317 - accuracy: 0.8047 - top5_acc: 0.9982 - macro_f1score: 0.7001
# Epoch 00029: val_loss did not improve from 0.92513
#
# Epoch 00029: val_accuracy did not improve from 0.66378
# 896/896 [==============================] - 643s 717ms/step - loss: 0.5317 - accuracy: 0.8047 - top5_acc: 0.9982 - macro_f1score: 0.7001 - val_loss: 1.0829 - val_accuracy: 0.6560 - val_top5_acc: 0.9894 - val_macro_f1score: 0.5417
# Learning rate:  0.001
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 30/70
# 896/896 [==============================] - ETA: 0s - loss: 0.5053 - accuracy: 0.8133 - top5_acc: 0.9984 - macro_f1score: 0.7061
# Epoch 00030: val_loss did not improve from 0.92513
#
# Epoch 00030: val_accuracy did not improve from 0.66378
# 896/896 [==============================] - 645s 720ms/step - loss: 0.5053 - accuracy: 0.8133 - top5_acc: 0.9984 - macro_f1score: 0.7061 - val_loss: 1.0303 - val_accuracy: 0.6535 - val_top5_acc: 0.9880 - val_macro_f1score: 0.5506
# Learning rate:  0.0001
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 31/70
# 896/896 [==============================] - ETA: 0s - loss: 0.3374 - accuracy: 0.8768 - top5_acc: 0.9995 - macro_f1score: 0.7808
# Epoch 00031: val_loss did not improve from 0.92513
#
# Epoch 00031: val_accuracy improved from 0.66378 to 0.69252, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/Inception_ResNet_v2/031.h5
# 896/896 [==============================] - 652s 728ms/step - loss: 0.3374 - accuracy: 0.8768 - top5_acc: 0.9995 - macro_f1score: 0.7808 - val_loss: 1.2099 - val_accuracy: 0.6925 - val_top5_acc: 0.9891 - val_macro_f1score: 0.5993
# Learning rate:  0.0001
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 32/70
# 896/896 [==============================] - ETA: 0s - loss: 0.2673 - accuracy: 0.9028 - top5_acc: 0.9998 - macro_f1score: 0.8068
# Epoch 00032: val_loss did not improve from 0.92513
#
# Epoch 00032: val_accuracy improved from 0.69252 to 0.69754, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/Inception_ResNet_v2/032.h5
# 896/896 [==============================] - 651s 727ms/step - loss: 0.2673 - accuracy: 0.9028 - top5_acc: 0.9998 - macro_f1score: 0.8068 - val_loss: 1.2587 - val_accuracy: 0.6975 - val_top5_acc: 0.9883 - val_macro_f1score: 0.5963
# Learning rate:  0.0001
#
# Epoch 00033: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 33/70
# 896/896 [==============================] - ETA: 0s - loss: 0.2382 - accuracy: 0.9143 - top5_acc: 0.9999 - macro_f1score: 0.8207
# Epoch 00033: val_loss did not improve from 0.92513
#
# Epoch 00033: val_accuracy did not improve from 0.69754
# 896/896 [==============================] - 643s 718ms/step - loss: 0.2382 - accuracy: 0.9143 - top5_acc: 0.9999 - macro_f1score: 0.8207 - val_loss: 1.3184 - val_accuracy: 0.6961 - val_top5_acc: 0.9905 - val_macro_f1score: 0.5934
# Learning rate:  0.0001
#
# Epoch 00034: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 34/70
# 896/896 [==============================] - ETA: 0s - loss: 0.2219 - accuracy: 0.9209 - top5_acc: 0.9998 - macro_f1score: 0.8254
# Epoch 00034: val_loss did not improve from 0.92513
#
# Epoch 00034: val_accuracy did not improve from 0.69754
# 896/896 [==============================] - 646s 721ms/step - loss: 0.2219 - accuracy: 0.9209 - top5_acc: 0.9998 - macro_f1score: 0.8254 - val_loss: 1.3008 - val_accuracy: 0.6961 - val_top5_acc: 0.9880 - val_macro_f1score: 0.6010
# Learning rate:  0.0001
#
# Epoch 00035: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 35/70
# 896/896 [==============================] - ETA: 0s - loss: 0.2010 - accuracy: 0.9263 - top5_acc: 1.0000 - macro_f1score: 0.8326
# Epoch 00035: val_loss did not improve from 0.92513
#
# Epoch 00035: val_accuracy did not improve from 0.69754
# 896/896 [==============================] - 647s 723ms/step - loss: 0.2010 - accuracy: 0.9263 - top5_acc: 1.0000 - macro_f1score: 0.8326 - val_loss: 1.4489 - val_accuracy: 0.6964 - val_top5_acc: 0.9902 - val_macro_f1score: 0.6031
# Learning rate:  0.0001
#
# Epoch 00036: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 36/70
# 896/896 [==============================] - ETA: 0s - loss: 0.1877 - accuracy: 0.9330 - top5_acc: 0.9999 - macro_f1score: 0.8372
# Epoch 00036: val_loss did not improve from 0.92513
#
# Epoch 00036: val_accuracy did not improve from 0.69754
# 896/896 [==============================] - 645s 720ms/step - loss: 0.1877 - accuracy: 0.9330 - top5_acc: 0.9999 - macro_f1score: 0.8372 - val_loss: 1.4729 - val_accuracy: 0.6931 - val_top5_acc: 0.9908 - val_macro_f1score: 0.5972
# Learning rate:  0.0001
#
# Epoch 00037: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 37/70
# 896/896 [==============================] - ETA: 0s - loss: 0.1802 - accuracy: 0.9326 - top5_acc: 1.0000 - macro_f1score: 0.8383
# Epoch 00037: val_loss did not improve from 0.92513
#
# Epoch 00037: val_accuracy did not improve from 0.69754
# 896/896 [==============================] - 646s 722ms/step - loss: 0.1802 - accuracy: 0.9326 - top5_acc: 1.0000 - macro_f1score: 0.8383 - val_loss: 1.4360 - val_accuracy: 0.6922 - val_top5_acc: 0.9902 - val_macro_f1score: 0.5901
# Learning rate:  0.0001
#
# Epoch 00038: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 38/70
# 896/896 [==============================] - ETA: 0s - loss: 0.1649 - accuracy: 0.9402 - top5_acc: 1.0000 - macro_f1score: 0.8444
# Epoch 00038: val_loss did not improve from 0.92513
#
# Epoch 00038: val_accuracy did not improve from 0.69754
# 896/896 [==============================] - 648s 723ms/step - loss: 0.1649 - accuracy: 0.9402 - top5_acc: 1.0000 - macro_f1score: 0.8444 - val_loss: 1.5165 - val_accuracy: 0.6936 - val_top5_acc: 0.9891 - val_macro_f1score: 0.5987
# Learning rate:  0.0001
#
# Epoch 00039: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 39/70
# 896/896 [==============================] - ETA: 0s - loss: 0.1601 - accuracy: 0.9428 - top5_acc: 0.9999 - macro_f1score: 0.8477
# Epoch 00039: val_loss did not improve from 0.92513
#
# Epoch 00039: val_accuracy did not improve from 0.69754
# 896/896 [==============================] - 647s 723ms/step - loss: 0.1601 - accuracy: 0.9428 - top5_acc: 0.9999 - macro_f1score: 0.8477 - val_loss: 1.4853 - val_accuracy: 0.6903 - val_top5_acc: 0.9894 - val_macro_f1score: 0.5916
# Learning rate:  0.0001
#
# Epoch 00040: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 40/70
# 896/896 [==============================] - ETA: 0s - loss: 0.1507 - accuracy: 0.9456 - top5_acc: 0.9999 - macro_f1score: 0.8486
# Epoch 00040: val_loss did not improve from 0.92513
#
# Epoch 00040: val_accuracy did not improve from 0.69754
# 896/896 [==============================] - 646s 721ms/step - loss: 0.1507 - accuracy: 0.9456 - top5_acc: 0.9999 - macro_f1score: 0.8486 - val_loss: 1.5136 - val_accuracy: 0.6936 - val_top5_acc: 0.9900 - val_macro_f1score: 0.5884
# Learning rate:  0.0001
#
# Epoch 00041: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 41/70
# 896/896 [==============================] - ETA: 0s - loss: 0.1392 - accuracy: 0.9493 - top5_acc: 1.0000 - macro_f1score: 0.8555
# Epoch 00041: val_loss did not improve from 0.92513
#
# Epoch 00041: val_accuracy did not improve from 0.69754
# 896/896 [==============================] - 647s 723ms/step - loss: 0.1392 - accuracy: 0.9493 - top5_acc: 1.0000 - macro_f1score: 0.8555 - val_loss: 1.5727 - val_accuracy: 0.6936 - val_top5_acc: 0.9902 - val_macro_f1score: 0.6006
# Learning rate:  0.0001
#
# Epoch 00042: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 42/70
# 896/896 [==============================] - ETA: 0s - loss: 0.1337 - accuracy: 0.9510 - top5_acc: 1.0000 - macro_f1score: 0.8557
# Epoch 00042: val_loss did not improve from 0.92513
#
# Epoch 00042: val_accuracy did not improve from 0.69754
# 896/896 [==============================] - 654s 729ms/step - loss: 0.1337 - accuracy: 0.9510 - top5_acc: 1.0000 - macro_f1score: 0.8557 - val_loss: 1.6966 - val_accuracy: 0.6922 - val_top5_acc: 0.9888 - val_macro_f1score: 0.5888
# Learning rate:  0.0001
#
# Epoch 00043: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 43/70
# 896/896 [==============================] - ETA: 0s - loss: 0.1249 - accuracy: 0.9544 - top5_acc: 1.0000 - macro_f1score: 0.8595
# Epoch 00043: val_loss did not improve from 0.92513
#
# Epoch 00043: val_accuracy did not improve from 0.69754
# 896/896 [==============================] - 649s 724ms/step - loss: 0.1249 - accuracy: 0.9544 - top5_acc: 1.0000 - macro_f1score: 0.8595 - val_loss: 1.7014 - val_accuracy: 0.6847 - val_top5_acc: 0.9877 - val_macro_f1score: 0.5899
# Learning rate:  0.0001
#
# Epoch 00044: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 44/70
# 896/896 [==============================] - ETA: 0s - loss: 0.1255 - accuracy: 0.9540 - top5_acc: 1.0000 - macro_f1score: 0.8574
# Epoch 00044: val_loss did not improve from 0.92513
#
# Epoch 00044: val_accuracy did not improve from 0.69754
# 896/896 [==============================] - 645s 720ms/step - loss: 0.1255 - accuracy: 0.9540 - top5_acc: 1.0000 - macro_f1score: 0.8574 - val_loss: 1.6406 - val_accuracy: 0.6925 - val_top5_acc: 0.9894 - val_macro_f1score: 0.5921
# Learning rate:  0.0001
#
# Epoch 00045: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 45/70
# 896/896 [==============================] - ETA: 0s - loss: 0.1233 - accuracy: 0.9550 - top5_acc: 1.0000 - macro_f1score: 0.8609
# Epoch 00045: val_loss did not improve from 0.92513
#
# Epoch 00045: val_accuracy improved from 0.69754 to 0.69782, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/Inception_ResNet_v2/045.h5
# 896/896 [==============================] - 652s 727ms/step - loss: 0.1233 - accuracy: 0.9550 - top5_acc: 1.0000 - macro_f1score: 0.8609 - val_loss: 1.6814 - val_accuracy: 0.6978 - val_top5_acc: 0.9900 - val_macro_f1score: 0.6040
# Learning rate:  0.0001
#
# Epoch 00046: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 46/70
# 896/896 [==============================] - ETA: 0s - loss: 0.1093 - accuracy: 0.9604 - top5_acc: 1.0000 - macro_f1score: 0.8646
# Epoch 00046: val_loss did not improve from 0.92513
#
# Epoch 00046: val_accuracy did not improve from 0.69782
# 896/896 [==============================] - 651s 727ms/step - loss: 0.1093 - accuracy: 0.9604 - top5_acc: 1.0000 - macro_f1score: 0.8646 - val_loss: 1.6659 - val_accuracy: 0.6922 - val_top5_acc: 0.9900 - val_macro_f1score: 0.5963
# Learning rate:  0.0001
#
# Epoch 00047: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 47/70
# 896/896 [==============================] - ETA: 0s - loss: 0.1061 - accuracy: 0.9609 - top5_acc: 1.0000 - macro_f1score: 0.8638
# Epoch 00047: val_loss did not improve from 0.92513
#
# Epoch 00047: val_accuracy did not improve from 0.69782
# 896/896 [==============================] - 643s 718ms/step - loss: 0.1061 - accuracy: 0.9609 - top5_acc: 1.0000 - macro_f1score: 0.8638 - val_loss: 1.6780 - val_accuracy: 0.6975 - val_top5_acc: 0.9877 - val_macro_f1score: 0.6018
# Learning rate:  0.0001
#
# Epoch 00048: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 48/70
# 896/896 [==============================] - ETA: 0s - loss: 0.1084 - accuracy: 0.9600 - top5_acc: 1.0000 - macro_f1score: 0.8640
# Epoch 00048: val_loss did not improve from 0.92513
#
# Epoch 00048: val_accuracy did not improve from 0.69782
# 896/896 [==============================] - 647s 722ms/step - loss: 0.1084 - accuracy: 0.9600 - top5_acc: 1.0000 - macro_f1score: 0.8640 - val_loss: 1.6618 - val_accuracy: 0.6914 - val_top5_acc: 0.9891 - val_macro_f1score: 0.5934
# Learning rate:  0.0001
#
# Epoch 00049: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 49/70
# 896/896 [==============================] - ETA: 0s - loss: 0.1042 - accuracy: 0.9628 - top5_acc: 1.0000 - macro_f1score: 0.8666
# Epoch 00049: val_loss did not improve from 0.92513
#
# Epoch 00049: val_accuracy did not improve from 0.69782
# 896/896 [==============================] - 644s 719ms/step - loss: 0.1042 - accuracy: 0.9628 - top5_acc: 1.0000 - macro_f1score: 0.8666 - val_loss: 1.6686 - val_accuracy: 0.6967 - val_top5_acc: 0.9877 - val_macro_f1score: 0.6028
# Learning rate:  0.0001
#
# Epoch 00050: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 50/70
# 896/896 [==============================] - ETA: 0s - loss: 0.1015 - accuracy: 0.9638 - top5_acc: 1.0000 - macro_f1score: 0.8676
# Epoch 00050: val_loss did not improve from 0.92513
#
# Epoch 00050: val_accuracy did not improve from 0.69782
# 896/896 [==============================] - 642s 717ms/step - loss: 0.1015 - accuracy: 0.9638 - top5_acc: 1.0000 - macro_f1score: 0.8676 - val_loss: 1.7416 - val_accuracy: 0.6892 - val_top5_acc: 0.9866 - val_macro_f1score: 0.5891
# Learning rate:  0.0001
#
# Epoch 00051: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 51/70
# 896/896 [==============================] - ETA: 0s - loss: 0.1018 - accuracy: 0.9648 - top5_acc: 1.0000 - macro_f1score: 0.8713
# Epoch 00051: val_loss did not improve from 0.92513
#
# Epoch 00051: val_accuracy did not improve from 0.69782
# 896/896 [==============================] - 642s 716ms/step - loss: 0.1018 - accuracy: 0.9648 - top5_acc: 1.0000 - macro_f1score: 0.8713 - val_loss: 1.6939 - val_accuracy: 0.6908 - val_top5_acc: 0.9908 - val_macro_f1score: 0.5946
# Learning rate:  0.0001
#
# Epoch 00052: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 52/70
# 896/896 [==============================] - ETA: 0s - loss: 0.0984 - accuracy: 0.9663 - top5_acc: 1.0000 - macro_f1score: 0.8708
# Epoch 00052: val_loss did not improve from 0.92513
#
# Epoch 00052: val_accuracy did not improve from 0.69782
# 896/896 [==============================] - 641s 715ms/step - loss: 0.0984 - accuracy: 0.9663 - top5_acc: 1.0000 - macro_f1score: 0.8708 - val_loss: 1.6964 - val_accuracy: 0.6939 - val_top5_acc: 0.9880 - val_macro_f1score: 0.5951
# Learning rate:  0.0001
#
# Epoch 00053: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 53/70
# 896/896 [==============================] - ETA: 0s - loss: 0.0957 - accuracy: 0.9659 - top5_acc: 1.0000 - macro_f1score: 0.8736
# Epoch 00053: val_loss did not improve from 0.92513
#
# Epoch 00053: val_accuracy did not improve from 0.69782
# 896/896 [==============================] - 641s 716ms/step - loss: 0.0957 - accuracy: 0.9659 - top5_acc: 1.0000 - macro_f1score: 0.8736 - val_loss: 1.7262 - val_accuracy: 0.6917 - val_top5_acc: 0.9860 - val_macro_f1score: 0.5864
# Learning rate:  0.0001
#
# Epoch 00054: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 54/70
# 896/896 [==============================] - ETA: 0s - loss: 0.0966 - accuracy: 0.9656 - top5_acc: 1.0000 - macro_f1score: 0.8705
# Epoch 00054: val_loss did not improve from 0.92513
#
# Epoch 00054: val_accuracy did not improve from 0.69782
# 896/896 [==============================] - 642s 716ms/step - loss: 0.0966 - accuracy: 0.9656 - top5_acc: 1.0000 - macro_f1score: 0.8705 - val_loss: 1.7853 - val_accuracy: 0.6911 - val_top5_acc: 0.9860 - val_macro_f1score: 0.5889
# Learning rate:  0.0001
#
# Epoch 00055: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 55/70
# 896/896 [==============================] - ETA: 0s - loss: 0.0967 - accuracy: 0.9661 - top5_acc: 1.0000 - macro_f1score: 0.8692
# Epoch 00055: val_loss did not improve from 0.92513
#
# Epoch 00055: val_accuracy did not improve from 0.69782
# 896/896 [==============================] - 642s 717ms/step - loss: 0.0967 - accuracy: 0.9661 - top5_acc: 1.0000 - macro_f1score: 0.8692 - val_loss: 1.6350 - val_accuracy: 0.6914 - val_top5_acc: 0.9880 - val_macro_f1score: 0.5944
# Learning rate:  0.0001
#
# Epoch 00056: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 56/70
# 896/896 [==============================] - ETA: 0s - loss: 0.0956 - accuracy: 0.9664 - top5_acc: 1.0000 - macro_f1score: 0.8705
# Epoch 00056: val_loss did not improve from 0.92513
#
# Epoch 00056: val_accuracy did not improve from 0.69782
# 896/896 [==============================] - 640s 715ms/step - loss: 0.0956 - accuracy: 0.9664 - top5_acc: 1.0000 - macro_f1score: 0.8705 - val_loss: 1.6586 - val_accuracy: 0.6934 - val_top5_acc: 0.9891 - val_macro_f1score: 0.5961
# Learning rate:  0.0001
#
# Epoch 00057: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 57/70
# 896/896 [==============================] - ETA: 0s - loss: 0.0919 - accuracy: 0.9676 - top5_acc: 1.0000 - macro_f1score: 0.8757
# Epoch 00057: val_loss did not improve from 0.92513
#
# Epoch 00057: val_accuracy did not improve from 0.69782
# 896/896 [==============================] - 641s 715ms/step - loss: 0.0919 - accuracy: 0.9676 - top5_acc: 1.0000 - macro_f1score: 0.8757 - val_loss: 1.6953 - val_accuracy: 0.6911 - val_top5_acc: 0.9891 - val_macro_f1score: 0.5940
# Learning rate:  0.0001
#
# Epoch 00058: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 58/70
# 896/896 [==============================] - ETA: 0s - loss: 0.0905 - accuracy: 0.9691 - top5_acc: 1.0000 - macro_f1score: 0.8742
# Epoch 00058: val_loss did not improve from 0.92513
#
# Epoch 00058: val_accuracy did not improve from 0.69782
# 896/896 [==============================] - 639s 713ms/step - loss: 0.0905 - accuracy: 0.9691 - top5_acc: 1.0000 - macro_f1score: 0.8742 - val_loss: 1.5900 - val_accuracy: 0.6948 - val_top5_acc: 0.9874 - val_macro_f1score: 0.5963
# Learning rate:  0.0001
#
# Epoch 00059: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 59/70
# 896/896 [==============================] - ETA: 0s - loss: 0.0970 - accuracy: 0.9665 - top5_acc: 1.0000 - macro_f1score: 0.8699
# Epoch 00059: val_loss did not improve from 0.92513
#
# Epoch 00059: val_accuracy did not improve from 0.69782
# 896/896 [==============================] - 638s 712ms/step - loss: 0.0970 - accuracy: 0.9665 - top5_acc: 1.0000 - macro_f1score: 0.8699 - val_loss: 1.6845 - val_accuracy: 0.6914 - val_top5_acc: 0.9855 - val_macro_f1score: 0.5915
# Learning rate:  0.0001
#
# Epoch 00060: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 60/70
# 896/896 [==============================] - ETA: 0s - loss: 0.0925 - accuracy: 0.9683 - top5_acc: 1.0000 - macro_f1score: 0.8731
# Epoch 00060: val_loss did not improve from 0.92513
#
# Epoch 00060: val_accuracy improved from 0.69782 to 0.70061, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/Inception_ResNet_v2/060.h5
# 896/896 [==============================] - 646s 721ms/step - loss: 0.0925 - accuracy: 0.9683 - top5_acc: 1.0000 - macro_f1score: 0.8731 - val_loss: 1.5912 - val_accuracy: 0.7006 - val_top5_acc: 0.9863 - val_macro_f1score: 0.6039
# Learning rate:  1e-05
#
# Epoch 00061: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 61/70
# 896/896 [==============================] - ETA: 0s - loss: 0.0676 - accuracy: 0.9775 - top5_acc: 1.0000 - macro_f1score: 0.8828
# Epoch 00061: val_loss did not improve from 0.92513
#
# Epoch 00061: val_accuracy improved from 0.70061 to 0.70145, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/Inception_ResNet_v2/061.h5
# 896/896 [==============================] - 646s 721ms/step - loss: 0.0676 - accuracy: 0.9775 - top5_acc: 1.0000 - macro_f1score: 0.8828 - val_loss: 1.5827 - val_accuracy: 0.7015 - val_top5_acc: 0.9880 - val_macro_f1score: 0.6009
# Learning rate:  1e-05
#
# Epoch 00062: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 62/70
# 896/896 [==============================] - ETA: 0s - loss: 0.0544 - accuracy: 0.9829 - top5_acc: 1.0000 - macro_f1score: 0.8863
# Epoch 00062: val_loss did not improve from 0.92513
#
# Epoch 00062: val_accuracy improved from 0.70145 to 0.70173, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/Inception_ResNet_v2/062.h5
# 896/896 [==============================] - 645s 720ms/step - loss: 0.0544 - accuracy: 0.9829 - top5_acc: 1.0000 - macro_f1score: 0.8863 - val_loss: 1.5953 - val_accuracy: 0.7017 - val_top5_acc: 0.9874 - val_macro_f1score: 0.6045
# Learning rate:  1e-05
#
# Epoch 00063: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 63/70
# 896/896 [==============================] - ETA: 0s - loss: 0.0542 - accuracy: 0.9832 - top5_acc: 1.0000 - macro_f1score: 0.8902
# Epoch 00063: val_loss did not improve from 0.92513
#
# Epoch 00063: val_accuracy improved from 0.70173 to 0.70229, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/Inception_ResNet_v2/063.h5
# 896/896 [==============================] - 645s 720ms/step - loss: 0.0542 - accuracy: 0.9832 - top5_acc: 1.0000 - macro_f1score: 0.8902 - val_loss: 1.5887 - val_accuracy: 0.7023 - val_top5_acc: 0.9849 - val_macro_f1score: 0.6066
# Learning rate:  1e-05
#
# Epoch 00064: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 64/70
# 896/896 [==============================] - ETA: 0s - loss: 0.0553 - accuracy: 0.9822 - top5_acc: 1.0000 - macro_f1score: 0.8881
# Epoch 00064: val_loss did not improve from 0.92513
#
# Epoch 00064: val_accuracy improved from 0.70229 to 0.70257, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/Inception_ResNet_v2/064.h5
# 896/896 [==============================] - 644s 719ms/step - loss: 0.0553 - accuracy: 0.9822 - top5_acc: 1.0000 - macro_f1score: 0.8881 - val_loss: 1.5562 - val_accuracy: 0.7026 - val_top5_acc: 0.9855 - val_macro_f1score: 0.6093
# Learning rate:  1e-05
#
# Epoch 00065: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 65/70
# 896/896 [==============================] - ETA: 0s - loss: 0.0520 - accuracy: 0.9842 - top5_acc: 1.0000 - macro_f1score: 0.8888
# Epoch 00065: val_loss did not improve from 0.92513
#
# Epoch 00065: val_accuracy improved from 0.70257 to 0.70368, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/Inception_ResNet_v2/065.h5
# 896/896 [==============================] - 644s 719ms/step - loss: 0.0520 - accuracy: 0.9842 - top5_acc: 1.0000 - macro_f1score: 0.8888 - val_loss: 1.5388 - val_accuracy: 0.7037 - val_top5_acc: 0.9855 - val_macro_f1score: 0.6056
# Learning rate:  1e-05
#
# Epoch 00066: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 66/70
# 896/896 [==============================] - ETA: 0s - loss: 0.0522 - accuracy: 0.9838 - top5_acc: 1.0000 - macro_f1score: 0.8894
# Epoch 00066: val_loss did not improve from 0.92513
#
# Epoch 00066: val_accuracy did not improve from 0.70368
# 896/896 [==============================] - 638s 713ms/step - loss: 0.0522 - accuracy: 0.9838 - top5_acc: 1.0000 - macro_f1score: 0.8894 - val_loss: 1.5494 - val_accuracy: 0.7028 - val_top5_acc: 0.9874 - val_macro_f1score: 0.6097
# Learning rate:  1e-05
#
# Epoch 00067: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 67/70
# 896/896 [==============================] - ETA: 0s - loss: 0.0542 - accuracy: 0.9846 - top5_acc: 1.0000 - macro_f1score: 0.8924
# Epoch 00067: val_loss did not improve from 0.92513
#
# Epoch 00067: val_accuracy did not improve from 0.70368
# 896/896 [==============================] - 638s 712ms/step - loss: 0.0542 - accuracy: 0.9846 - top5_acc: 1.0000 - macro_f1score: 0.8924 - val_loss: 1.5182 - val_accuracy: 0.7017 - val_top5_acc: 0.9874 - val_macro_f1score: 0.6043
# Learning rate:  1e-05
#
# Epoch 00068: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 68/70
# 896/896 [==============================] - ETA: 0s - loss: 0.0534 - accuracy: 0.9845 - top5_acc: 1.0000 - macro_f1score: 0.8899
# Epoch 00068: val_loss did not improve from 0.92513
#
# Epoch 00068: val_accuracy did not improve from 0.70368
# 896/896 [==============================] - 640s 714ms/step - loss: 0.0534 - accuracy: 0.9845 - top5_acc: 1.0000 - macro_f1score: 0.8899 - val_loss: 1.5018 - val_accuracy: 0.7023 - val_top5_acc: 0.9860 - val_macro_f1score: 0.6026
# Learning rate:  1e-05
#
# Epoch 00069: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 69/70
# 896/896 [==============================] - ETA: 0s - loss: 0.0557 - accuracy: 0.9833 - top5_acc: 1.0000 - macro_f1score: 0.8881
# Epoch 00069: val_loss did not improve from 0.92513
#
# Epoch 00069: val_accuracy did not improve from 0.70368
# 896/896 [==============================] - 641s 715ms/step - loss: 0.0557 - accuracy: 0.9833 - top5_acc: 1.0000 - macro_f1score: 0.8881 - val_loss: 1.5039 - val_accuracy: 0.7034 - val_top5_acc: 0.9858 - val_macro_f1score: 0.6011
# Learning rate:  1e-05
#
# Epoch 00070: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 70/70
# 896/896 [==============================] - ETA: 0s - loss: 0.0576 - accuracy: 0.9835 - top5_acc: 1.0000 - macro_f1score: 0.8892
# Epoch 00070: val_loss did not improve from 0.92513
#
# Epoch 00070: val_accuracy did not improve from 0.70368
# 896/896 [==============================] - 638s 712ms/step - loss: 0.0576 - accuracy: 0.9835 - top5_acc: 1.0000 - macro_f1score: 0.8892 - val_loss: 1.4598 - val_accuracy: 0.6998 - val_top5_acc: 0.9849 - val_macro_f1score: 0.6015

# %% [markdown]
# ### 3) Inception-ResNet-V2 Evaluate

# %%
# 1. epoch=maximum
loss , acc, top5_acc, mf1 = model.evaluate(test_generator,steps=int(len(x_test)/batch_sizes))
print('[Test Loss: %.4f /  Test Top-1 Accuracy: %.4f / Test Top-5 Accuracy: %.4f / Test Macro f1: %.4f]\n' % (loss,acc,top5_acc,mf1))
# Out:
# 112/112 [==============================] - 991s 9s/step - loss: 1.6268 - accuracy: 0.6738 - top5_acc: 0.9880 - macro_f1score: 0.5809
# [Test Loss: 1.6268 /  Test Top-1 Accuracy: 0.6738 / Test Top-5 Accuracy: 0.9880 / Test Macro f1: 0.5809]

# %%
loss=history.history['loss']
val_loss=history.history['val_loss']
acc=history.history['accuracy']
val_acc=history.history['val_accuracy']
top5_acc=history.history['top5_acc']
val_top5_acc=history.history['val_top5_acc']
f1=history.history['macro_f1score']
val_f1=history.history['val_macro_f1score']
epochs=range(1,len(acc)+1)

data = np.array([epochs,loss,val_loss,acc,val_acc,top5_acc,val_top5_acc,f1,val_f1]).T

# %%
# data save
# epochs, loss, val_loss, acc, val_acc, top5_acc, val_top5_acc, f1, val_f1

np.savetxt(os.path.join(dir,'train_valid_output',number,model.name+'.txt'),data)

# %%
# data import
data = np.loadtxt(os.path.join(dir,'train_valid_output',number,'Inception_ResNet_v2.txt'))

# %%
epochs=data[:,0]
loss=data[:,1]
val_loss=data[:,2]
acc=data[:,3]
val_acc=data[:,4]
top5_acc=data[:,5]
val_top5_acc=data[:,6]

# %%
plt.plot(epochs[1:],acc[1:],'b',label='Training 1-Acc')
plt.plot(epochs[1:],val_acc[1:],'r',label='Validation 1-Acc')
plt.title('Training and Validation Top-1 Accuracy')
plt.legend()
plt.figure()

plt.plot(epochs[1:],top5_acc[1:],'b',label='Training 5-Acc')
plt.plot(epochs[1:],val_top5_acc[1:],'r',label='Validation 5-Acc')
plt.title('Training and Validation Top-5 Accuracy')
plt.legend()
plt.figure()

plt.plot(epochs[10:],loss[10:],'b',label='Training Loss')
plt.plot(epochs[10:],val_loss[10:],'r',label='Validation Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()

# %%
# 이 아래는 내가 인위적으로 살펴보고 싶은 epoch에 대해서 결과값 출력 / Inception_Resnet_V2

# %%
# 참고 : https://github.com/OverLordGoldDragon/keras-adamw

import sys
sys.path.append('/content/drive/My Drive/Colab Notebooks/Paper')
import utils
import optimizers_v2
from utils import get_weight_decays, fill_dict_in_order
from utils import reset_seeds, K_eval
from optimizers_v2 import AdamW, NadamW, SGDW

# %%
# top-5 accuracy 출력
import functools
top5_acc = functools.partial(ks.metrics.top_k_categorical_accuracy, k=5)
top5_acc.__name__ = 'top5_acc'

# %%
model=load_model(os.path.join(dir,'model_output',number,'Inception_ResNet_v2','064.h5'),custom_objects={"macro_f1score": macro_f1score,"top5_acc":top5_acc, "AdamW":AdamW})

# %%
# 2. epoch=?
loss , acc, top5_acc, mf1 = model.evaluate(test_generator,steps=int(len(x_test)/batch_sizes))
print('[Test Loss: %.4f /  Test Top-1 Accuracy: %.4f / Test Top-5 Accuracy: %.4f / Test Macro f1: %.4f]\n' % (loss,acc,top5_acc,mf1))
# Out:
# 112/112 [==============================] - 1561s 14s/step - loss: 1.7267 - accuracy: 0.6777 - top5_acc: 0.9883 - macro_f1score: 0.5741
# [Test Loss: 1.7267 /  Test Top-1 Accuracy: 0.6777 / Test Top-5 Accuracy: 0.9883 / Test Macro f1: 0.5741]
