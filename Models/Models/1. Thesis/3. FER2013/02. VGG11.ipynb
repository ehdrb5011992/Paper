# %% [markdown]
# # [VGG11]

# %% [markdown]
# *KU LeeDongGyu*

# %% [markdown]
# ### Contents

# %% [markdown]
# 1. Data Preprocessing
# ```
# 1) Data Import
# 2) Data Augmentation
# ```
# 2. Support Functions
#
# 3. Almost Original VGG11
# ```
# 1) Almost Original VGG11
# 2) VGG11 Evaluate
# ```

# %% [markdown]
# ### Install Packages

# %% [markdown]
# ### Module

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/My Drive/Colab Notebooks/Paper
# Out:
# /content/drive/My Drive/Colab Notebooks/Paper

# %%
from f1score import macro_f1score,weighted_f1score

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import cv2
import tensorflow as tf
from tensorflow import keras as ks
from tensorflow.keras import backend as K 
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, Input, Concatenate, ZeroPadding2D ,GlobalMaxPooling2D, Reshape , Lambda , Add, Multiply
from tensorflow.keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D, Activation, BatchNormalization, AveragePooling2D , ZeroPadding2D, SeparableConv2D
from tensorflow.keras.layers import add
from tensorflow.keras.optimizers import Adam, RMSprop , SGD
from tensorflow.keras.callbacks import EarlyStopping , LearningRateScheduler, ModelCheckpoint, CSVLogger, Callback, ReduceLROnPlateau
from tensorflow.keras.regularizers import l1,l2,l1_l2
from tensorflow.keras.models import Model , load_model , Sequential
from tensorflow.keras.utils import plot_model , to_categorical, get_file
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
os.getcwd()
# Out:
# '/content/drive/My Drive/Colab Notebooks/Paper'

# %%
print(tf.__version__)
print(ks.__version__)
# Out:
# 2.3.0
# 2.4.0

# %%
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 5660039780228278110
# , name: "/device:XLA_CPU:0"
# device_type: "XLA_CPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 15999994913724527415
# physical_device_desc: "device: XLA_CPU device"
# , name: "/device:XLA_GPU:0"
# device_type: "XLA_GPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 13343214357258579388
# physical_device_desc: "device: XLA_GPU device"
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 15473775744
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 3119881560450639803
# physical_device_desc: "device: 0, name: Tesla V100-SXM2-16GB, pci bus id: 0000:00:04.0, compute capability: 7.0"
# ]

# %% [markdown]
# ## 1. Data Preprocessing
# ---

# %% [markdown]
# ### 1) Data Import

# %%
# 바꿔서 살펴 볼 것들
# CALTECH, CIFAR100, FER, MIT
data_name = 'FER'
gan_type = 'No_GAN'
number = '1'
size = 224 # sizes after cropping
super_size = 256 # sizes before cropping 
input_sizes = (size,size,3)
batch_sizes = 128
weight_decay = 1e-4
epochs = 70

# %%
# 참고 : https://stackoverflow.com/questions/32419510/how-to-get-reproducible-results-in-keras/52897216#52897216
# setting the seed number for random number generation for reproducibility.

from numpy.random import seed
import random


if number=='1':
    seed_num = 200225
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)
elif number=='2':
    seed_num = 727
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)
elif number=='3':
    seed_num = 115
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)
elif number=='4':
    seed_num = 501
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)
elif number=='5':
    seed_num = 517
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)

# %%
# data import

if data_name=='FER' :
    x_train =  np.zeros(28698)
    x_valid = np.zeros(3589)
    x_test = np.zeros(3588)
    classes = 7 
    tr_center = [0.50793296, 0.50793296, 0.50793296]
elif data_name=='MIT':
    x_train = np.zeros(12466)
    x_valid = np.zeros(1564)
    x_test = np.zeros(1590)
    classes = 67 
    tr_center = [0.47916578, 0.42029615, 0.36046057]
elif data_name=='CALTECH':
    x_train = np.zeros(24510)
    x_valid = np.zeros(2980)
    x_test = np.zeros(3118)
    classes = 257
    tr_center = [0.51397761, 0.49525248, 0.46555727]
elif data_name=='CIFAR100':
    x_train = np.zeros(44923)
    x_valid = np.zeros(5077)
    x_test = np.zeros(10000)
    classes = 100
    tr_center = [0.53442983, 0.51355958, 0.46462564]

# %%
dir = os.path.join(os.getcwd(),data_name,gan_type)

# %% [markdown]
# ### 2) Data Augmentation

# %%
# 참고 : https://jkjung-avt.github.io/keras-image-cropping/

def random_crop(img, random_crop_size):
    # Note: image_data_format is 'channel_last'
    assert img.shape[2] == 3 # img.shape[2] 가 3(rgb)이 아니면 assertion error 발생
    height, width = img.shape[0], img.shape[1]
    dy, dx = random_crop_size
    x = np.random.randint(0, width - dx + 1)
    y = np.random.randint(0, height - dy + 1)
    return img[y:(y+dy), x:(x+dx), :]


def crop_generator(batches, crop_length):
    """Take as input a Keras ImageGen (Iterator) and generate random
    crops from the image batches generated by the original iterator.
    """
    while True:
        batch_x, batch_y = next(batches)
        batch_crops = np.zeros((batch_x.shape[0], crop_length, crop_length, 3))
        for i in range(batch_x.shape[0]):
            batch_crops[i] = random_crop(batch_x[i], (crop_length, crop_length))
        yield (batch_crops, batch_y)

# %%
from tensorflow.keras.preprocessing.image import img_to_array,load_img
import glob

# 데이터 전체에 대해 centering 진행함.

def read_cal_image(img_path): 
    x = img_to_array(load_img(img_path)) # x는 채널별 평균값
    y = x.shape[0] * x.shape[1]# y는 데이터별 픽셀 수 (비중)

    x = 1/255. * x # scaling하고, centering값을 뽑아냄.
    x = np.mean(x, axis=(0,1))
    
    return np.hstack([x,y])

def calculate_centered_mean(dataset_path,x_train=x_train):
    num = len(x_train)
    space = np.empty((num,4))
    i=0

    for p in glob.glob(os.path.join(dataset_path,'*/*.*')) :
        space[i] = read_cal_image(p)
        i += 1

    ratio = space[:,3] / np.sum(space[:,3])

    return np.average(space[:,0:3],axis=0,weights=ratio)


# 아래의 함수를 돌려서 나온 결과값을 중심화 값으로 설정.

# train_mean = calculate_centered_mean(os.path.join(dir,'data/train')).reshape((1,1,3))

# %%
datagen_tr = ImageDataGenerator(
    rescale=1/255.,
    horizontal_flip=True,
    featurewise_center=True,
    featurewise_std_normalization=False,
    rotation_range=10,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=[0.9,1.0],
    fill_mode = 'nearest')
datagen_val = ImageDataGenerator(rescale=1/255.,featurewise_center=True)
datagen_tes = ImageDataGenerator(rescale=1/255.,featurewise_center=True)

# 원래는 이 자리에 fit 매서드를 써야하지만, 그냥 내가 중심화함수를 만들고 적용함. 

# 중심화 설정
datagen_tr.mean = np.array(tr_center, dtype=np.float32).reshape((1,1,3)) # RGB
datagen_val.mean = np.array(tr_center, dtype=np.float32).reshape((1,1,3)) # RGB
datagen_tes.mean = np.array(tr_center, dtype=np.float32).reshape((1,1,3)) # RGB

# %%
train_batches = datagen_tr.flow_from_directory(directory=os.path.join(dir,'data/train'),target_size=(super_size,super_size),batch_size=batch_sizes,class_mode='categorical') # fer : 28698 / mit : 12466 / caltech : 24509 / cifar : 44923
train_generator= crop_generator(train_batches, size)
valid_generator = datagen_val.flow_from_directory(directory=os.path.join(dir,'data/valid'),target_size=(size,size),batch_size=batch_sizes,class_mode='categorical') # fer : 3589 / mit : 1564 / caltech : 2980 / cifar : 5077
test_generator = datagen_tes.flow_from_directory(directory=os.path.join(dir,'data/test'),target_size=(size,size),batch_size=batch_sizes,class_mode='categorical') # fer : 3588 / mit : 1590 / caltech : 3118 / cifar : 10000
# Out:
# Found 28698 images belonging to 7 classes.
# Found 3589 images belonging to 7 classes.
# Found 3588 images belonging to 7 classes.

# %% [markdown]
# ## 2. Support Functions
# ---

# %%
# def lr_schedule(epoch):
#     init_lr = 1e-4
#     k = 0.04
#     lr = init_lr * np.exp(-k*epoch)
#     print('Learning rate: ', lr)
#     return lr

def lr_schedule(epoch):
    lr = 3e-4
    if epoch < 30:
        lr = lr
    elif epoch < 60 :
        lr = lr * 0.1
    else:
        lr = lr * 0.01
    print('Learning rate: ', lr)
    return lr

# %% [markdown]
# ## 3. Almost Original VGG11
# ---

# %% [markdown]
# ### 1) Almost Original VGG11

# %%
# VGG11를 최대한 논문에 가깝게 맞춰 모형작성.

def VGG11(input_shape=(224, 224, 3), classes=1000, weight_decay=weight_decay, name='VGG11'):

    img_input = Input(shape=input_shape)

    # Block 1
    x = Conv2D(64, (3, 3), activation='relu', padding='same', name='block1_conv1', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(img_input)
    x = MaxPooling2D((2, 2), strides=(2, 2), name='block1_pool')(x)

    # Block 2
    x = Conv2D(128, (3, 3), activation='relu', padding='same', name='block2_conv1', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(x)
    x = MaxPooling2D((2, 2), strides=(2, 2), name='block2_pool')(x)

    # Block 3
    x = Conv2D(256, (3, 3), activation='relu', padding='same', name='block3_conv1', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(x)
    x = Conv2D(256, (3, 3), activation='relu', padding='same', name='block3_conv2', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(x)
    x = MaxPooling2D((2, 2), strides=(2, 2), name='block3_pool')(x)

    # Block 4
    x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block4_conv1', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(x)
    x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block4_conv2', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(x)
    x = MaxPooling2D((2, 2), strides=(2, 2), name='block4_pool')(x)

    # Block 5
    x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block5_conv1', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(x)
    x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block5_conv2', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(x)
    x = MaxPooling2D((2, 2), strides=(2, 2), name='block5_pool')(x)

    # Classification block
    x = Flatten(name='flatten')(x)
    x = Dense(4096, activation='relu', name='fc1', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(x)
    x = Dropout(0.5)(x)
    x = Dense(4096, activation='relu', name='fc2', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(x)
    x = Dropout(0.5)(x)
    output = Dense(classes, activation='softmax', kernel_regularizer=l2(weight_decay), name='predictions')(x)

    # Create model.
    model = Model(img_input, output, name=name)

    return model

# %%
model = VGG11(input_shape=input_sizes, classes=classes, name='VGG11')

# %%
model.summary()
# Out:
# Model: "VGG11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# fc1 (Dense)                  (None, 4096)              102764544
# _________________________________________________________________
# dropout (Dropout)            (None, 4096)              0
# _________________________________________________________________
# fc2 (Dense)                  (None, 4096)              16781312
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 4096)              0
# _________________________________________________________________
# predictions (Dense)          (None, 7)                 28679
# =================================================================
# Total params: 128,795,015
# Trainable params: 128,795,015
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 폴더 생성

os.makedirs(os.path.join(dir,'model_output',number,model.name), exist_ok=True)
os.makedirs(os.path.join(dir,'train_valid_output',number), exist_ok=True)

# %%
# 참고 : https://github.com/OverLordGoldDragon/keras-adamw

import sys
sys.path.append('/content/drive/My Drive/Colab Notebooks/Paper')
import utils
import optimizers_v2
from utils import get_weight_decays, fill_dict_in_order
from utils import reset_seeds, K_eval
from optimizers_v2 import AdamW, NadamW, SGDW

# %%
# top-5 accuracy 출력
import functools
top5_acc = functools.partial(ks.metrics.top_k_categorical_accuracy, k=5)
top5_acc.__name__ = 'top5_acc'

# %%
#optimizer = SGDW(model=model, use_cosine_annealing=False, total_iterations = len(x_train) // batch_sizes, nesterov=True, momentum=0.9)
optimizer = AdamW(model=model, use_cosine_annealing=False, total_iterations = len(x_train) // batch_sizes)
#optimizer = Adam()
filepath =  os.path.join(dir,'model_output',number,model.name,'{epoch:03d}.h5')

callbacks_list = [ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_weights_only=False, save_best_only=True, mode='min'),
                  ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_weights_only=False, save_best_only=True, mode='max'),
                  #ReduceLROnPlateau(monitor='val_loss',patience=3,factor=0.1,min_lr=1e-5),
                  LearningRateScheduler(lr_schedule,verbose=1)
                  ]
                  
model.compile(optimizer, loss = 'categorical_crossentropy', metrics=['accuracy',top5_acc,macro_f1score])

# %%
######## flow_from_directory
history = model.fit(train_generator, steps_per_epoch=int(len(x_train)/batch_sizes),  validation_data = valid_generator, epochs=epochs , verbose=1 , callbacks = callbacks_list , validation_steps=int(len(x_valid)/batch_sizes))
# Out:
# Learning rate:  0.0003
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 1/70
# 0.0(L1), 6.681530879020939e-06(L2) weight decay set for block1_conv1/kernel:0
# 0.0(L1), 6.681530879020939e-06(L2) weight decay set for block2_conv1/kernel:0
# 0.0(L1), 6.681530879020939e-06(L2) weight decay set for block3_conv1/kernel:0
# 0.0(L1), 6.681530879020939e-06(L2) weight decay set for block3_conv2/kernel:0
# 0.0(L1), 6.681530879020939e-06(L2) weight decay set for block4_conv1/kernel:0
# 0.0(L1), 6.681530879020939e-06(L2) weight decay set for block4_conv2/kernel:0
# 0.0(L1), 6.681530879020939e-06(L2) weight decay set for block5_conv1/kernel:0
# 0.0(L1), 6.681530879020939e-06(L2) weight decay set for block5_conv2/kernel:0
# 0.0(L1), 6.681530879020939e-06(L2) weight decay set for fc1/kernel:0
# 0.0(L1), 6.681530879020939e-06(L2) weight decay set for fc2/kernel:0
# 0.0(L1), 6.681530879020939e-06(L2) weight decay set for predictions/kernel:0
# 224/224 [==============================] - ETA: 0s - loss: 1.7918 - accuracy: 0.2759 - top5_acc: 0.9019 - macro_f1score: 0.0254
# Epoch 00001: val_loss improved from inf to 1.60495, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/VGG11/001.h5
#
# Epoch 00001: val_accuracy improved from -inf to 0.38086, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/VGG11/001.h5
# 224/224 [==============================] - 14647s 65s/step - loss: 1.7918 - accuracy: 0.2759 - top5_acc: 0.9019 - macro_f1score: 0.0254 - val_loss: 1.6049 - val_accuracy: 0.3809 - val_top5_acc: 0.9369 - val_macro_f1score: 0.1591
# Learning rate:  0.0003
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 2/70
# 224/224 [==============================] - ETA: 0s - loss: 1.4908 - accuracy: 0.4207 - top5_acc: 0.9510 - macro_f1score: 0.1650
# Epoch 00002: val_loss improved from 1.60495 to 1.32574, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/VGG11/002.h5
#
# Epoch 00002: val_accuracy improved from 0.38086 to 0.48214, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/VGG11/002.h5
# 224/224 [==============================] - 457s 2s/step - loss: 1.4908 - accuracy: 0.4207 - top5_acc: 0.9510 - macro_f1score: 0.1650 - val_loss: 1.3257 - val_accuracy: 0.4821 - val_top5_acc: 0.9679 - val_macro_f1score: 0.2629
# Learning rate:  0.0003
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 3/70
# 224/224 [==============================] - ETA: 0s - loss: 1.3273 - accuracy: 0.4917 - top5_acc: 0.9651 - macro_f1score: 0.2472
# Epoch 00003: val_loss improved from 1.32574 to 1.23972, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/VGG11/003.h5
#
# Epoch 00003: val_accuracy improved from 0.48214 to 0.53097, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/VGG11/003.h5
# 224/224 [==============================] - 447s 2s/step - loss: 1.3273 - accuracy: 0.4917 - top5_acc: 0.9651 - macro_f1score: 0.2472 - val_loss: 1.2397 - val_accuracy: 0.5310 - val_top5_acc: 0.9743 - val_macro_f1score: 0.2963
# Learning rate:  0.0003
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 4/70
# 224/224 [==============================] - ETA: 0s - loss: 1.2207 - accuracy: 0.5377 - top5_acc: 0.9748 - macro_f1score: 0.3142
# Epoch 00004: val_loss improved from 1.23972 to 1.16619, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/VGG11/004.h5
#
# Epoch 00004: val_accuracy improved from 0.53097 to 0.56110, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/VGG11/004.h5
# 224/224 [==============================] - 463s 2s/step - loss: 1.2207 - accuracy: 0.5377 - top5_acc: 0.9748 - macro_f1score: 0.3142 - val_loss: 1.1662 - val_accuracy: 0.5611 - val_top5_acc: 0.9794 - val_macro_f1score: 0.3613
# Learning rate:  0.0003
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 5/70
# 224/224 [==============================] - ETA: 0s - loss: 1.1661 - accuracy: 0.5607 - top5_acc: 0.9780 - macro_f1score: 0.3488
# Epoch 00005: val_loss did not improve from 1.16619
#
# Epoch 00005: val_accuracy improved from 0.56110 to 0.56445, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/VGG11/005.h5
# 224/224 [==============================] - 442s 2s/step - loss: 1.1661 - accuracy: 0.5607 - top5_acc: 0.9780 - macro_f1score: 0.3488 - val_loss: 1.1875 - val_accuracy: 0.5645 - val_top5_acc: 0.9788 - val_macro_f1score: 0.4000
# Learning rate:  0.0003
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 6/70
# 224/224 [==============================] - ETA: 0s - loss: 1.1197 - accuracy: 0.5746 - top5_acc: 0.9813 - macro_f1score: 0.3800
# Epoch 00006: val_loss improved from 1.16619 to 1.13853, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/VGG11/006.h5
#
# Epoch 00006: val_accuracy improved from 0.56445 to 0.57701, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/VGG11/006.h5
# 224/224 [==============================] - 454s 2s/step - loss: 1.1197 - accuracy: 0.5746 - top5_acc: 0.9813 - macro_f1score: 0.3800 - val_loss: 1.1385 - val_accuracy: 0.5770 - val_top5_acc: 0.9782 - val_macro_f1score: 0.3734
# Learning rate:  0.0003
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 7/70
# 224/224 [==============================] - ETA: 0s - loss: 1.0747 - accuracy: 0.5915 - top5_acc: 0.9830 - macro_f1score: 0.3993
# Epoch 00007: val_loss improved from 1.13853 to 1.05989, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/VGG11/007.h5
#
# Epoch 00007: val_accuracy improved from 0.57701 to 0.59319, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/VGG11/007.h5
# 224/224 [==============================] - 450s 2s/step - loss: 1.0747 - accuracy: 0.5915 - top5_acc: 0.9830 - macro_f1score: 0.3993 - val_loss: 1.0599 - val_accuracy: 0.5932 - val_top5_acc: 0.9824 - val_macro_f1score: 0.4123
# Learning rate:  0.0003
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 8/70
# 224/224 [==============================] - ETA: 0s - loss: 1.0525 - accuracy: 0.6034 - top5_acc: 0.9850 - macro_f1score: 0.4190
# Epoch 00008: val_loss did not improve from 1.05989
#
# Epoch 00008: val_accuracy improved from 0.59319 to 0.59738, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/VGG11/008.h5
# 224/224 [==============================] - 434s 2s/step - loss: 1.0525 - accuracy: 0.6034 - top5_acc: 0.9850 - macro_f1score: 0.4190 - val_loss: 1.0834 - val_accuracy: 0.5974 - val_top5_acc: 0.9824 - val_macro_f1score: 0.4377
# Learning rate:  0.0003
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 9/70
# 224/224 [==============================] - ETA: 0s - loss: 1.0195 - accuracy: 0.6187 - top5_acc: 0.9865 - macro_f1score: 0.4441
# Epoch 00009: val_loss did not improve from 1.05989
#
# Epoch 00009: val_accuracy did not improve from 0.59738
# 224/224 [==============================] - 427s 2s/step - loss: 1.0195 - accuracy: 0.6187 - top5_acc: 0.9865 - macro_f1score: 0.4441 - val_loss: 1.0677 - val_accuracy: 0.5898 - val_top5_acc: 0.9819 - val_macro_f1score: 0.4229
# Learning rate:  0.0003
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 10/70
# 224/224 [==============================] - ETA: 0s - loss: 0.9900 - accuracy: 0.6290 - top5_acc: 0.9874 - macro_f1score: 0.4675
# Epoch 00010: val_loss improved from 1.05989 to 1.04561, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/VGG11/010.h5
#
# Epoch 00010: val_accuracy improved from 0.59738 to 0.60938, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/VGG11/010.h5
# 224/224 [==============================] - 451s 2s/step - loss: 0.9900 - accuracy: 0.6290 - top5_acc: 0.9874 - macro_f1score: 0.4675 - val_loss: 1.0456 - val_accuracy: 0.6094 - val_top5_acc: 0.9849 - val_macro_f1score: 0.4607
# Learning rate:  0.0003
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 11/70
# 224/224 [==============================] - ETA: 0s - loss: 0.9648 - accuracy: 0.6377 - top5_acc: 0.9885 - macro_f1score: 0.4798
# Epoch 00011: val_loss improved from 1.04561 to 1.01076, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/VGG11/011.h5
#
# Epoch 00011: val_accuracy improved from 0.60938 to 0.61970, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/VGG11/011.h5
# 224/224 [==============================] - 456s 2s/step - loss: 0.9648 - accuracy: 0.6377 - top5_acc: 0.9885 - macro_f1score: 0.4798 - val_loss: 1.0108 - val_accuracy: 0.6197 - val_top5_acc: 0.9874 - val_macro_f1score: 0.4910
# Learning rate:  0.0003
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 12/70
# 224/224 [==============================] - ETA: 0s - loss: 0.9542 - accuracy: 0.6406 - top5_acc: 0.9894 - macro_f1score: 0.4969
# Epoch 00012: val_loss improved from 1.01076 to 1.00416, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/VGG11/012.h5
#
# Epoch 00012: val_accuracy improved from 0.61970 to 0.62054, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/VGG11/012.h5
# 224/224 [==============================] - 458s 2s/step - loss: 0.9542 - accuracy: 0.6406 - top5_acc: 0.9894 - macro_f1score: 0.4969 - val_loss: 1.0042 - val_accuracy: 0.6205 - val_top5_acc: 0.9866 - val_macro_f1score: 0.4720
# Learning rate:  0.0003
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 13/70
# 224/224 [==============================] - ETA: 0s - loss: 0.9227 - accuracy: 0.6588 - top5_acc: 0.9896 - macro_f1score: 0.5158
# Epoch 00013: val_loss improved from 1.00416 to 0.97972, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/VGG11/013.h5
#
# Epoch 00013: val_accuracy improved from 0.62054 to 0.63002, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/VGG11/013.h5
# 224/224 [==============================] - 468s 2s/step - loss: 0.9227 - accuracy: 0.6588 - top5_acc: 0.9896 - macro_f1score: 0.5158 - val_loss: 0.9797 - val_accuracy: 0.6300 - val_top5_acc: 0.9877 - val_macro_f1score: 0.4899
# Learning rate:  0.0003
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 14/70
# 224/224 [==============================] - ETA: 0s - loss: 0.9018 - accuracy: 0.6595 - top5_acc: 0.9903 - macro_f1score: 0.5296
# Epoch 00014: val_loss improved from 0.97972 to 0.96522, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/VGG11/014.h5
#
# Epoch 00014: val_accuracy improved from 0.63002 to 0.63756, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/VGG11/014.h5
# 224/224 [==============================] - 459s 2s/step - loss: 0.9018 - accuracy: 0.6595 - top5_acc: 0.9903 - macro_f1score: 0.5296 - val_loss: 0.9652 - val_accuracy: 0.6376 - val_top5_acc: 0.9874 - val_macro_f1score: 0.4931
# Learning rate:  0.0003
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 15/70
# 224/224 [==============================] - ETA: 0s - loss: 0.8832 - accuracy: 0.6737 - top5_acc: 0.9910 - macro_f1score: 0.5476
# Epoch 00015: val_loss improved from 0.96522 to 0.96033, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/VGG11/015.h5
#
# Epoch 00015: val_accuracy improved from 0.63756 to 0.64035, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/VGG11/015.h5
# 224/224 [==============================] - 460s 2s/step - loss: 0.8832 - accuracy: 0.6737 - top5_acc: 0.9910 - macro_f1score: 0.5476 - val_loss: 0.9603 - val_accuracy: 0.6403 - val_top5_acc: 0.9877 - val_macro_f1score: 0.5291
# Learning rate:  0.0003
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 16/70
# 224/224 [==============================] - ETA: 0s - loss: 0.8702 - accuracy: 0.6742 - top5_acc: 0.9911 - macro_f1score: 0.5529
# Epoch 00016: val_loss did not improve from 0.96033
#
# Epoch 00016: val_accuracy did not improve from 0.64035
# 224/224 [==============================] - 439s 2s/step - loss: 0.8702 - accuracy: 0.6742 - top5_acc: 0.9911 - macro_f1score: 0.5529 - val_loss: 1.0335 - val_accuracy: 0.6127 - val_top5_acc: 0.9860 - val_macro_f1score: 0.4987
# Learning rate:  0.0003
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 17/70
# 224/224 [==============================] - ETA: 0s - loss: 0.8387 - accuracy: 0.6877 - top5_acc: 0.9924 - macro_f1score: 0.5740
# Epoch 00017: val_loss did not improve from 0.96033
#
# Epoch 00017: val_accuracy did not improve from 0.64035
# 224/224 [==============================] - 437s 2s/step - loss: 0.8387 - accuracy: 0.6877 - top5_acc: 0.9924 - macro_f1score: 0.5740 - val_loss: 0.9986 - val_accuracy: 0.6395 - val_top5_acc: 0.9886 - val_macro_f1score: 0.5341
# Learning rate:  0.0003
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 18/70
# 224/224 [==============================] - ETA: 0s - loss: 0.8353 - accuracy: 0.6870 - top5_acc: 0.9920 - macro_f1score: 0.5828
# Epoch 00018: val_loss did not improve from 0.96033
#
# Epoch 00018: val_accuracy did not improve from 0.64035
# 224/224 [==============================] - 435s 2s/step - loss: 0.8353 - accuracy: 0.6870 - top5_acc: 0.9920 - macro_f1score: 0.5828 - val_loss: 1.0177 - val_accuracy: 0.6222 - val_top5_acc: 0.9900 - val_macro_f1score: 0.5242
# Learning rate:  0.0003
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 19/70
# 224/224 [==============================] - ETA: 0s - loss: 0.8022 - accuracy: 0.6989 - top5_acc: 0.9929 - macro_f1score: 0.6042
# Epoch 00019: val_loss did not improve from 0.96033
#
# Epoch 00019: val_accuracy improved from 0.64035 to 0.64202, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/VGG11/019.h5
# 224/224 [==============================] - 441s 2s/step - loss: 0.8022 - accuracy: 0.6989 - top5_acc: 0.9929 - macro_f1score: 0.6042 - val_loss: 0.9789 - val_accuracy: 0.6420 - val_top5_acc: 0.9883 - val_macro_f1score: 0.5392
# Learning rate:  0.0003
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 20/70
# 224/224 [==============================] - ETA: 0s - loss: 0.7862 - accuracy: 0.7078 - top5_acc: 0.9943 - macro_f1score: 0.6095
# Epoch 00020: val_loss did not improve from 0.96033
#
# Epoch 00020: val_accuracy did not improve from 0.64202
# 224/224 [==============================] - 442s 2s/step - loss: 0.7862 - accuracy: 0.7078 - top5_acc: 0.9943 - macro_f1score: 0.6095 - val_loss: 0.9756 - val_accuracy: 0.6401 - val_top5_acc: 0.9891 - val_macro_f1score: 0.5225
# Learning rate:  0.0003
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 21/70
# 224/224 [==============================] - ETA: 0s - loss: 0.7767 - accuracy: 0.7123 - top5_acc: 0.9935 - macro_f1score: 0.6194
# Epoch 00021: val_loss did not improve from 0.96033
#
# Epoch 00021: val_accuracy did not improve from 0.64202
# 224/224 [==============================] - 440s 2s/step - loss: 0.7767 - accuracy: 0.7123 - top5_acc: 0.9935 - macro_f1score: 0.6194 - val_loss: 1.0557 - val_accuracy: 0.6286 - val_top5_acc: 0.9855 - val_macro_f1score: 0.4968
# Learning rate:  0.0003
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 22/70
# 224/224 [==============================] - ETA: 0s - loss: 0.7515 - accuracy: 0.7187 - top5_acc: 0.9949 - macro_f1score: 0.6319
# Epoch 00022: val_loss did not improve from 0.96033
#
# Epoch 00022: val_accuracy did not improve from 0.64202
# 224/224 [==============================] - 439s 2s/step - loss: 0.7515 - accuracy: 0.7187 - top5_acc: 0.9949 - macro_f1score: 0.6319 - val_loss: 1.0076 - val_accuracy: 0.6370 - val_top5_acc: 0.9900 - val_macro_f1score: 0.5296
# Learning rate:  0.0003
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 23/70
# 224/224 [==============================] - ETA: 0s - loss: 0.7357 - accuracy: 0.7257 - top5_acc: 0.9954 - macro_f1score: 0.6436
# Epoch 00023: val_loss did not improve from 0.96033
#
# Epoch 00023: val_accuracy improved from 0.64202 to 0.65123, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/VGG11/023.h5
# 224/224 [==============================] - 440s 2s/step - loss: 0.7357 - accuracy: 0.7257 - top5_acc: 0.9954 - macro_f1score: 0.6436 - val_loss: 0.9969 - val_accuracy: 0.6512 - val_top5_acc: 0.9886 - val_macro_f1score: 0.5383
# Learning rate:  0.0003
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 24/70
# 224/224 [==============================] - ETA: 0s - loss: 0.7192 - accuracy: 0.7332 - top5_acc: 0.9956 - macro_f1score: 0.6556
# Epoch 00024: val_loss did not improve from 0.96033
#
# Epoch 00024: val_accuracy did not improve from 0.65123
# 224/224 [==============================] - 441s 2s/step - loss: 0.7192 - accuracy: 0.7332 - top5_acc: 0.9956 - macro_f1score: 0.6556 - val_loss: 1.0298 - val_accuracy: 0.6448 - val_top5_acc: 0.9902 - val_macro_f1score: 0.5529
# Learning rate:  0.0003
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 25/70
# 224/224 [==============================] - ETA: 0s - loss: 0.7035 - accuracy: 0.7388 - top5_acc: 0.9958 - macro_f1score: 0.6641
# Epoch 00025: val_loss did not improve from 0.96033
#
# Epoch 00025: val_accuracy did not improve from 0.65123
# 224/224 [==============================] - 438s 2s/step - loss: 0.7035 - accuracy: 0.7388 - top5_acc: 0.9958 - macro_f1score: 0.6641 - val_loss: 1.0461 - val_accuracy: 0.6429 - val_top5_acc: 0.9869 - val_macro_f1score: 0.5498
# Learning rate:  0.0003
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 26/70
# 224/224 [==============================] - ETA: 0s - loss: 0.6852 - accuracy: 0.7453 - top5_acc: 0.9958 - macro_f1score: 0.6735
# Epoch 00026: val_loss did not improve from 0.96033
#
# Epoch 00026: val_accuracy did not improve from 0.65123
# 224/224 [==============================] - 437s 2s/step - loss: 0.6852 - accuracy: 0.7453 - top5_acc: 0.9958 - macro_f1score: 0.6735 - val_loss: 1.0153 - val_accuracy: 0.6484 - val_top5_acc: 0.9886 - val_macro_f1score: 0.5724
# Learning rate:  0.0003
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 27/70
# 224/224 [==============================] - ETA: 0s - loss: 0.6674 - accuracy: 0.7508 - top5_acc: 0.9971 - macro_f1score: 0.6858
# Epoch 00027: val_loss did not improve from 0.96033
#
# Epoch 00027: val_accuracy did not improve from 0.65123
# 224/224 [==============================] - 438s 2s/step - loss: 0.6674 - accuracy: 0.7508 - top5_acc: 0.9971 - macro_f1score: 0.6858 - val_loss: 1.0898 - val_accuracy: 0.6456 - val_top5_acc: 0.9874 - val_macro_f1score: 0.5694
# Learning rate:  0.0003
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 28/70
# 224/224 [==============================] - ETA: 0s - loss: 0.6542 - accuracy: 0.7589 - top5_acc: 0.9964 - macro_f1score: 0.6912
# Epoch 00028: val_loss did not improve from 0.96033
#
# Epoch 00028: val_accuracy did not improve from 0.65123
# 224/224 [==============================] - 439s 2s/step - loss: 0.6542 - accuracy: 0.7589 - top5_acc: 0.9964 - macro_f1score: 0.6912 - val_loss: 1.0731 - val_accuracy: 0.6362 - val_top5_acc: 0.9900 - val_macro_f1score: 0.5519
# Learning rate:  0.0003
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 29/70
# 224/224 [==============================] - ETA: 0s - loss: 0.6410 - accuracy: 0.7632 - top5_acc: 0.9965 - macro_f1score: 0.7005
# Epoch 00029: val_loss did not improve from 0.96033
#
# Epoch 00029: val_accuracy did not improve from 0.65123
# 224/224 [==============================] - 442s 2s/step - loss: 0.6410 - accuracy: 0.7632 - top5_acc: 0.9965 - macro_f1score: 0.7005 - val_loss: 1.1230 - val_accuracy: 0.6501 - val_top5_acc: 0.9883 - val_macro_f1score: 0.5614
# Learning rate:  0.0003
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 30/70
# 224/224 [==============================] - ETA: 0s - loss: 0.6182 - accuracy: 0.7721 - top5_acc: 0.9969 - macro_f1score: 0.7091
# Epoch 00030: val_loss did not improve from 0.96033
#
# Epoch 00030: val_accuracy did not improve from 0.65123
# 224/224 [==============================] - 440s 2s/step - loss: 0.6182 - accuracy: 0.7721 - top5_acc: 0.9969 - macro_f1score: 0.7091 - val_loss: 1.0234 - val_accuracy: 0.6504 - val_top5_acc: 0.9894 - val_macro_f1score: 0.5822
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 31/70
# 224/224 [==============================] - ETA: 0s - loss: 0.5386 - accuracy: 0.8029 - top5_acc: 0.9979 - macro_f1score: 0.7550
# Epoch 00031: val_loss did not improve from 0.96033
#
# Epoch 00031: val_accuracy improved from 0.65123 to 0.66713, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/VGG11/031.h5
# 224/224 [==============================] - 447s 2s/step - loss: 0.5386 - accuracy: 0.8029 - top5_acc: 0.9979 - macro_f1score: 0.7550 - val_loss: 1.0511 - val_accuracy: 0.6671 - val_top5_acc: 0.9919 - val_macro_f1score: 0.6061
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 32/70
# 224/224 [==============================] - ETA: 0s - loss: 0.4867 - accuracy: 0.8203 - top5_acc: 0.9984 - macro_f1score: 0.7763
# Epoch 00032: val_loss did not improve from 0.96033
#
# Epoch 00032: val_accuracy did not improve from 0.66713
# 224/224 [==============================] - 441s 2s/step - loss: 0.4867 - accuracy: 0.8203 - top5_acc: 0.9984 - macro_f1score: 0.7763 - val_loss: 1.0698 - val_accuracy: 0.6657 - val_top5_acc: 0.9908 - val_macro_f1score: 0.6060
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00033: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 33/70
# 224/224 [==============================] - ETA: 0s - loss: 0.4738 - accuracy: 0.8270 - top5_acc: 0.9988 - macro_f1score: 0.7898
# Epoch 00033: val_loss did not improve from 0.96033
#
# Epoch 00033: val_accuracy did not improve from 0.66713
# 224/224 [==============================] - 437s 2s/step - loss: 0.4738 - accuracy: 0.8270 - top5_acc: 0.9988 - macro_f1score: 0.7898 - val_loss: 1.0793 - val_accuracy: 0.6624 - val_top5_acc: 0.9908 - val_macro_f1score: 0.5977
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00034: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 34/70
# 224/224 [==============================] - ETA: 0s - loss: 0.4695 - accuracy: 0.8292 - top5_acc: 0.9983 - macro_f1score: 0.7887
# Epoch 00034: val_loss did not improve from 0.96033
#
# Epoch 00034: val_accuracy did not improve from 0.66713
# 224/224 [==============================] - 437s 2s/step - loss: 0.4695 - accuracy: 0.8292 - top5_acc: 0.9983 - macro_f1score: 0.7887 - val_loss: 1.1031 - val_accuracy: 0.6604 - val_top5_acc: 0.9902 - val_macro_f1score: 0.6031
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00035: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 35/70
# 224/224 [==============================] - ETA: 0s - loss: 0.4539 - accuracy: 0.8338 - top5_acc: 0.9984 - macro_f1score: 0.7977
# Epoch 00035: val_loss did not improve from 0.96033
#
# Epoch 00035: val_accuracy did not improve from 0.66713
# 224/224 [==============================] - 436s 2s/step - loss: 0.4539 - accuracy: 0.8338 - top5_acc: 0.9984 - macro_f1score: 0.7977 - val_loss: 1.1057 - val_accuracy: 0.6604 - val_top5_acc: 0.9902 - val_macro_f1score: 0.6038
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00036: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 36/70
# 224/224 [==============================] - ETA: 0s - loss: 0.4482 - accuracy: 0.8364 - top5_acc: 0.9987 - macro_f1score: 0.7953
# Epoch 00036: val_loss did not improve from 0.96033
#
# Epoch 00036: val_accuracy did not improve from 0.66713
# 224/224 [==============================] - 439s 2s/step - loss: 0.4482 - accuracy: 0.8364 - top5_acc: 0.9987 - macro_f1score: 0.7953 - val_loss: 1.1003 - val_accuracy: 0.6649 - val_top5_acc: 0.9897 - val_macro_f1score: 0.6143
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00037: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 37/70
# 224/224 [==============================] - ETA: 0s - loss: 0.4410 - accuracy: 0.8376 - top5_acc: 0.9991 - macro_f1score: 0.7988
# Epoch 00037: val_loss did not improve from 0.96033
#
# Epoch 00037: val_accuracy did not improve from 0.66713
# 224/224 [==============================] - 441s 2s/step - loss: 0.4410 - accuracy: 0.8376 - top5_acc: 0.9991 - macro_f1score: 0.7988 - val_loss: 1.1271 - val_accuracy: 0.6638 - val_top5_acc: 0.9894 - val_macro_f1score: 0.5968
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00038: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 38/70
# 224/224 [==============================] - ETA: 0s - loss: 0.4287 - accuracy: 0.8431 - top5_acc: 0.9985 - macro_f1score: 0.8070
# Epoch 00038: val_loss did not improve from 0.96033
#
# Epoch 00038: val_accuracy did not improve from 0.66713
# 224/224 [==============================] - 442s 2s/step - loss: 0.4287 - accuracy: 0.8431 - top5_acc: 0.9985 - macro_f1score: 0.8070 - val_loss: 1.1356 - val_accuracy: 0.6624 - val_top5_acc: 0.9897 - val_macro_f1score: 0.6048
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00039: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 39/70
# 224/224 [==============================] - ETA: 0s - loss: 0.4146 - accuracy: 0.8484 - top5_acc: 0.9989 - macro_f1score: 0.8088
# Epoch 00039: val_loss did not improve from 0.96033
#
# Epoch 00039: val_accuracy did not improve from 0.66713
# 224/224 [==============================] - 440s 2s/step - loss: 0.4146 - accuracy: 0.8484 - top5_acc: 0.9989 - macro_f1score: 0.8088 - val_loss: 1.1601 - val_accuracy: 0.6607 - val_top5_acc: 0.9900 - val_macro_f1score: 0.5965
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00040: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 40/70
# 224/224 [==============================] - ETA: 0s - loss: 0.4167 - accuracy: 0.8470 - top5_acc: 0.9991 - macro_f1score: 0.8154
# Epoch 00040: val_loss did not improve from 0.96033
#
# Epoch 00040: val_accuracy did not improve from 0.66713
# 224/224 [==============================] - 435s 2s/step - loss: 0.4167 - accuracy: 0.8470 - top5_acc: 0.9991 - macro_f1score: 0.8154 - val_loss: 1.1887 - val_accuracy: 0.6576 - val_top5_acc: 0.9891 - val_macro_f1score: 0.6135
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00041: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 41/70
# 224/224 [==============================] - ETA: 0s - loss: 0.4059 - accuracy: 0.8508 - top5_acc: 0.9988 - macro_f1score: 0.8099
# Epoch 00041: val_loss did not improve from 0.96033
#
# Epoch 00041: val_accuracy did not improve from 0.66713
# 224/224 [==============================] - 434s 2s/step - loss: 0.4059 - accuracy: 0.8508 - top5_acc: 0.9988 - macro_f1score: 0.8099 - val_loss: 1.1891 - val_accuracy: 0.6590 - val_top5_acc: 0.9894 - val_macro_f1score: 0.6107
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00042: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 42/70
# 224/224 [==============================] - ETA: 0s - loss: 0.3954 - accuracy: 0.8558 - top5_acc: 0.9992 - macro_f1score: 0.8133
# Epoch 00042: val_loss did not improve from 0.96033
#
# Epoch 00042: val_accuracy did not improve from 0.66713
# 224/224 [==============================] - 436s 2s/step - loss: 0.3954 - accuracy: 0.8558 - top5_acc: 0.9992 - macro_f1score: 0.8133 - val_loss: 1.1977 - val_accuracy: 0.6613 - val_top5_acc: 0.9886 - val_macro_f1score: 0.6015
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00043: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 43/70
# 224/224 [==============================] - ETA: 0s - loss: 0.3923 - accuracy: 0.8563 - top5_acc: 0.9994 - macro_f1score: 0.8183
# Epoch 00043: val_loss did not improve from 0.96033
#
# Epoch 00043: val_accuracy did not improve from 0.66713
# 224/224 [==============================] - 434s 2s/step - loss: 0.3923 - accuracy: 0.8563 - top5_acc: 0.9994 - macro_f1score: 0.8183 - val_loss: 1.2000 - val_accuracy: 0.6629 - val_top5_acc: 0.9888 - val_macro_f1score: 0.5969
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00044: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 44/70
# 224/224 [==============================] - ETA: 0s - loss: 0.3874 - accuracy: 0.8575 - top5_acc: 0.9993 - macro_f1score: 0.8218
# Epoch 00044: val_loss did not improve from 0.96033
#
# Epoch 00044: val_accuracy did not improve from 0.66713
# 224/224 [==============================] - 434s 2s/step - loss: 0.3874 - accuracy: 0.8575 - top5_acc: 0.9993 - macro_f1score: 0.8218 - val_loss: 1.1958 - val_accuracy: 0.6663 - val_top5_acc: 0.9886 - val_macro_f1score: 0.6124
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00045: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 45/70
# 224/224 [==============================] - ETA: 0s - loss: 0.3801 - accuracy: 0.8624 - top5_acc: 0.9991 - macro_f1score: 0.8302
# Epoch 00045: val_loss did not improve from 0.96033
#
# Epoch 00045: val_accuracy improved from 0.66713 to 0.66825, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/VGG11/045.h5
# 224/224 [==============================] - 446s 2s/step - loss: 0.3801 - accuracy: 0.8624 - top5_acc: 0.9991 - macro_f1score: 0.8302 - val_loss: 1.2200 - val_accuracy: 0.6682 - val_top5_acc: 0.9897 - val_macro_f1score: 0.6185
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00046: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 46/70
# 224/224 [==============================] - ETA: 0s - loss: 0.3767 - accuracy: 0.8627 - top5_acc: 0.9991 - macro_f1score: 0.8305
# Epoch 00046: val_loss did not improve from 0.96033
#
# Epoch 00046: val_accuracy did not improve from 0.66825
# 224/224 [==============================] - 443s 2s/step - loss: 0.3767 - accuracy: 0.8627 - top5_acc: 0.9991 - macro_f1score: 0.8305 - val_loss: 1.2206 - val_accuracy: 0.6607 - val_top5_acc: 0.9894 - val_macro_f1score: 0.6124
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00047: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 47/70
# 224/224 [==============================] - ETA: 0s - loss: 0.3649 - accuracy: 0.8635 - top5_acc: 0.9992 - macro_f1score: 0.8342
# Epoch 00047: val_loss did not improve from 0.96033
#
# Epoch 00047: val_accuracy did not improve from 0.66825
# 224/224 [==============================] - 438s 2s/step - loss: 0.3649 - accuracy: 0.8635 - top5_acc: 0.9992 - macro_f1score: 0.8342 - val_loss: 1.2458 - val_accuracy: 0.6649 - val_top5_acc: 0.9891 - val_macro_f1score: 0.6219
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00048: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 48/70
# 224/224 [==============================] - ETA: 0s - loss: 0.3652 - accuracy: 0.8635 - top5_acc: 0.9992 - macro_f1score: 0.8289
# Epoch 00048: val_loss did not improve from 0.96033
#
# Epoch 00048: val_accuracy did not improve from 0.66825
# 224/224 [==============================] - 437s 2s/step - loss: 0.3652 - accuracy: 0.8635 - top5_acc: 0.9992 - macro_f1score: 0.8289 - val_loss: 1.2376 - val_accuracy: 0.6618 - val_top5_acc: 0.9900 - val_macro_f1score: 0.6055
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00049: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 49/70
# 224/224 [==============================] - ETA: 0s - loss: 0.3550 - accuracy: 0.8709 - top5_acc: 0.9991 - macro_f1score: 0.8409
# Epoch 00049: val_loss did not improve from 0.96033
#
# Epoch 00049: val_accuracy did not improve from 0.66825
# 224/224 [==============================] - 436s 2s/step - loss: 0.3550 - accuracy: 0.8709 - top5_acc: 0.9991 - macro_f1score: 0.8409 - val_loss: 1.2508 - val_accuracy: 0.6621 - val_top5_acc: 0.9894 - val_macro_f1score: 0.6060
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00050: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 50/70
# 224/224 [==============================] - ETA: 0s - loss: 0.3483 - accuracy: 0.8742 - top5_acc: 0.9991 - macro_f1score: 0.8429
# Epoch 00050: val_loss did not improve from 0.96033
#
# Epoch 00050: val_accuracy did not improve from 0.66825
# 224/224 [==============================] - 435s 2s/step - loss: 0.3483 - accuracy: 0.8742 - top5_acc: 0.9991 - macro_f1score: 0.8429 - val_loss: 1.2602 - val_accuracy: 0.6641 - val_top5_acc: 0.9900 - val_macro_f1score: 0.6205
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00051: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 51/70
# 224/224 [==============================] - ETA: 0s - loss: 0.3479 - accuracy: 0.8715 - top5_acc: 0.9994 - macro_f1score: 0.8441
# Epoch 00051: val_loss did not improve from 0.96033
#
# Epoch 00051: val_accuracy did not improve from 0.66825
# 224/224 [==============================] - 436s 2s/step - loss: 0.3479 - accuracy: 0.8715 - top5_acc: 0.9994 - macro_f1score: 0.8441 - val_loss: 1.2922 - val_accuracy: 0.6574 - val_top5_acc: 0.9891 - val_macro_f1score: 0.6064
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00052: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 52/70
# 224/224 [==============================] - ETA: 0s - loss: 0.3482 - accuracy: 0.8734 - top5_acc: 0.9990 - macro_f1score: 0.8476
# Epoch 00052: val_loss did not improve from 0.96033
#
# Epoch 00052: val_accuracy did not improve from 0.66825
# 224/224 [==============================] - 435s 2s/step - loss: 0.3482 - accuracy: 0.8734 - top5_acc: 0.9990 - macro_f1score: 0.8476 - val_loss: 1.2739 - val_accuracy: 0.6663 - val_top5_acc: 0.9888 - val_macro_f1score: 0.6143
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00053: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 53/70
# 224/224 [==============================] - ETA: 0s - loss: 0.3390 - accuracy: 0.8760 - top5_acc: 0.9994 - macro_f1score: 0.8392
# Epoch 00053: val_loss did not improve from 0.96033
#
# Epoch 00053: val_accuracy did not improve from 0.66825
# 224/224 [==============================] - 435s 2s/step - loss: 0.3390 - accuracy: 0.8760 - top5_acc: 0.9994 - macro_f1score: 0.8392 - val_loss: 1.3199 - val_accuracy: 0.6585 - val_top5_acc: 0.9877 - val_macro_f1score: 0.6111
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00054: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 54/70
# 224/224 [==============================] - ETA: 0s - loss: 0.3325 - accuracy: 0.8781 - top5_acc: 0.9994 - macro_f1score: 0.8424
# Epoch 00054: val_loss did not improve from 0.96033
#
# Epoch 00054: val_accuracy did not improve from 0.66825
# 224/224 [==============================] - 435s 2s/step - loss: 0.3325 - accuracy: 0.8781 - top5_acc: 0.9994 - macro_f1score: 0.8424 - val_loss: 1.3011 - val_accuracy: 0.6560 - val_top5_acc: 0.9905 - val_macro_f1score: 0.5941
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00055: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 55/70
# 224/224 [==============================] - ETA: 0s - loss: 0.3221 - accuracy: 0.8809 - top5_acc: 0.9994 - macro_f1score: 0.8461
# Epoch 00055: val_loss did not improve from 0.96033
#
# Epoch 00055: val_accuracy did not improve from 0.66825
# 224/224 [==============================] - 435s 2s/step - loss: 0.3221 - accuracy: 0.8809 - top5_acc: 0.9994 - macro_f1score: 0.8461 - val_loss: 1.3151 - val_accuracy: 0.6643 - val_top5_acc: 0.9886 - val_macro_f1score: 0.6173
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00056: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 56/70
# 224/224 [==============================] - ETA: 0s - loss: 0.3227 - accuracy: 0.8827 - top5_acc: 0.9992 - macro_f1score: 0.8481
# Epoch 00056: val_loss did not improve from 0.96033
#
# Epoch 00056: val_accuracy did not improve from 0.66825
# 224/224 [==============================] - 436s 2s/step - loss: 0.3227 - accuracy: 0.8827 - top5_acc: 0.9992 - macro_f1score: 0.8481 - val_loss: 1.3513 - val_accuracy: 0.6596 - val_top5_acc: 0.9905 - val_macro_f1score: 0.6076
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00057: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 57/70
# 224/224 [==============================] - ETA: 0s - loss: 0.3157 - accuracy: 0.8849 - top5_acc: 0.9995 - macro_f1score: 0.8563
# Epoch 00057: val_loss did not improve from 0.96033
#
# Epoch 00057: val_accuracy did not improve from 0.66825
# 224/224 [==============================] - 440s 2s/step - loss: 0.3157 - accuracy: 0.8849 - top5_acc: 0.9995 - macro_f1score: 0.8563 - val_loss: 1.3374 - val_accuracy: 0.6671 - val_top5_acc: 0.9883 - val_macro_f1score: 0.6274
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00058: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 58/70
# 224/224 [==============================] - ETA: 0s - loss: 0.3080 - accuracy: 0.8873 - top5_acc: 0.9995 - macro_f1score: 0.8525
# Epoch 00058: val_loss did not improve from 0.96033
#
# Epoch 00058: val_accuracy did not improve from 0.66825
# 224/224 [==============================] - 443s 2s/step - loss: 0.3080 - accuracy: 0.8873 - top5_acc: 0.9995 - macro_f1score: 0.8525 - val_loss: 1.3736 - val_accuracy: 0.6596 - val_top5_acc: 0.9902 - val_macro_f1score: 0.6146
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00059: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 59/70
# 224/224 [==============================] - ETA: 0s - loss: 0.3102 - accuracy: 0.8861 - top5_acc: 0.9996 - macro_f1score: 0.8573
# Epoch 00059: val_loss did not improve from 0.96033
#
# Epoch 00059: val_accuracy did not improve from 0.66825
# 224/224 [==============================] - 442s 2s/step - loss: 0.3102 - accuracy: 0.8861 - top5_acc: 0.9996 - macro_f1score: 0.8573 - val_loss: 1.3636 - val_accuracy: 0.6602 - val_top5_acc: 0.9886 - val_macro_f1score: 0.6246
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00060: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 60/70
# 224/224 [==============================] - ETA: 0s - loss: 0.2982 - accuracy: 0.8911 - top5_acc: 0.9993 - macro_f1score: 0.8581
# Epoch 00060: val_loss did not improve from 0.96033
#
# Epoch 00060: val_accuracy did not improve from 0.66825
# 224/224 [==============================] - 433s 2s/step - loss: 0.2982 - accuracy: 0.8911 - top5_acc: 0.9993 - macro_f1score: 0.8581 - val_loss: 1.3910 - val_accuracy: 0.6613 - val_top5_acc: 0.9900 - val_macro_f1score: 0.6096
# Learning rate:  2.9999999999999997e-06
#
# Epoch 00061: LearningRateScheduler reducing learning rate to 2.9999999999999997e-06.
# Epoch 61/70
# 224/224 [==============================] - ETA: 0s - loss: 0.3008 - accuracy: 0.8921 - top5_acc: 0.9994 - macro_f1score: 0.8668
# Epoch 00061: val_loss did not improve from 0.96033
#
# Epoch 00061: val_accuracy did not improve from 0.66825
# 224/224 [==============================] - 429s 2s/step - loss: 0.3008 - accuracy: 0.8921 - top5_acc: 0.9994 - macro_f1score: 0.8668 - val_loss: 1.3669 - val_accuracy: 0.6632 - val_top5_acc: 0.9897 - val_macro_f1score: 0.6167
# Learning rate:  2.9999999999999997e-06
#
# Epoch 00062: LearningRateScheduler reducing learning rate to 2.9999999999999997e-06.
# Epoch 62/70
# 224/224 [==============================] - ETA: 0s - loss: 0.2923 - accuracy: 0.8935 - top5_acc: 0.9996 - macro_f1score: 0.8623
# Epoch 00062: val_loss did not improve from 0.96033
#
# Epoch 00062: val_accuracy did not improve from 0.66825
# 224/224 [==============================] - 424s 2s/step - loss: 0.2923 - accuracy: 0.8935 - top5_acc: 0.9996 - macro_f1score: 0.8623 - val_loss: 1.3643 - val_accuracy: 0.6652 - val_top5_acc: 0.9894 - val_macro_f1score: 0.6169
# Learning rate:  2.9999999999999997e-06
#
# Epoch 00063: LearningRateScheduler reducing learning rate to 2.9999999999999997e-06.
# Epoch 63/70
# 224/224 [==============================] - ETA: 0s - loss: 0.2846 - accuracy: 0.8964 - top5_acc: 0.9995 - macro_f1score: 0.8661
# Epoch 00063: val_loss did not improve from 0.96033
#
# Epoch 00063: val_accuracy did not improve from 0.66825
# 224/224 [==============================] - 426s 2s/step - loss: 0.2846 - accuracy: 0.8964 - top5_acc: 0.9995 - macro_f1score: 0.8661 - val_loss: 1.3598 - val_accuracy: 0.6638 - val_top5_acc: 0.9900 - val_macro_f1score: 0.6217
# Learning rate:  2.9999999999999997e-06
#
# Epoch 00064: LearningRateScheduler reducing learning rate to 2.9999999999999997e-06.
# Epoch 64/70
# 224/224 [==============================] - ETA: 0s - loss: 0.2912 - accuracy: 0.8954 - top5_acc: 0.9995 - macro_f1score: 0.8633
# Epoch 00064: val_loss did not improve from 0.96033
#
# Epoch 00064: val_accuracy did not improve from 0.66825
# 224/224 [==============================] - 424s 2s/step - loss: 0.2912 - accuracy: 0.8954 - top5_acc: 0.9995 - macro_f1score: 0.8633 - val_loss: 1.3502 - val_accuracy: 0.6635 - val_top5_acc: 0.9902 - val_macro_f1score: 0.6165
# Learning rate:  2.9999999999999997e-06
#
# Epoch 00065: LearningRateScheduler reducing learning rate to 2.9999999999999997e-06.
# Epoch 65/70
# 224/224 [==============================] - ETA: 0s - loss: 0.2842 - accuracy: 0.8988 - top5_acc: 0.9997 - macro_f1score: 0.8702
# Epoch 00065: val_loss did not improve from 0.96033
#
# Epoch 00065: val_accuracy did not improve from 0.66825
# 224/224 [==============================] - 424s 2s/step - loss: 0.2842 - accuracy: 0.8988 - top5_acc: 0.9997 - macro_f1score: 0.8702 - val_loss: 1.3535 - val_accuracy: 0.6629 - val_top5_acc: 0.9897 - val_macro_f1score: 0.6306
# Learning rate:  2.9999999999999997e-06
#
# Epoch 00066: LearningRateScheduler reducing learning rate to 2.9999999999999997e-06.
# Epoch 66/70
# 224/224 [==============================] - ETA: 0s - loss: 0.2847 - accuracy: 0.8967 - top5_acc: 0.9993 - macro_f1score: 0.8668
# Epoch 00066: val_loss did not improve from 0.96033
#
# Epoch 00066: val_accuracy did not improve from 0.66825
# 224/224 [==============================] - 426s 2s/step - loss: 0.2847 - accuracy: 0.8967 - top5_acc: 0.9993 - macro_f1score: 0.8668 - val_loss: 1.3548 - val_accuracy: 0.6624 - val_top5_acc: 0.9900 - val_macro_f1score: 0.6225
# Learning rate:  2.9999999999999997e-06
#
# Epoch 00067: LearningRateScheduler reducing learning rate to 2.9999999999999997e-06.
# Epoch 67/70
# 224/224 [==============================] - ETA: 0s - loss: 0.2860 - accuracy: 0.8963 - top5_acc: 0.9993 - macro_f1score: 0.8674
# Epoch 00067: val_loss did not improve from 0.96033
#
# Epoch 00067: val_accuracy did not improve from 0.66825
# 224/224 [==============================] - 428s 2s/step - loss: 0.2860 - accuracy: 0.8963 - top5_acc: 0.9993 - macro_f1score: 0.8674 - val_loss: 1.3462 - val_accuracy: 0.6652 - val_top5_acc: 0.9902 - val_macro_f1score: 0.6270
# Learning rate:  2.9999999999999997e-06
#
# Epoch 00068: LearningRateScheduler reducing learning rate to 2.9999999999999997e-06.
# Epoch 68/70
# 224/224 [==============================] - ETA: 0s - loss: 0.2920 - accuracy: 0.8938 - top5_acc: 0.9997 - macro_f1score: 0.8612
# Epoch 00068: val_loss did not improve from 0.96033
#
# Epoch 00068: val_accuracy did not improve from 0.66825
# 224/224 [==============================] - 434s 2s/step - loss: 0.2920 - accuracy: 0.8938 - top5_acc: 0.9997 - macro_f1score: 0.8612 - val_loss: 1.3429 - val_accuracy: 0.6627 - val_top5_acc: 0.9900 - val_macro_f1score: 0.6036
# Learning rate:  2.9999999999999997e-06
#
# Epoch 00069: LearningRateScheduler reducing learning rate to 2.9999999999999997e-06.
# Epoch 69/70
# 224/224 [==============================] - ETA: 0s - loss: 0.2833 - accuracy: 0.8977 - top5_acc: 0.9994 - macro_f1score: 0.8725
# Epoch 00069: val_loss did not improve from 0.96033
#
# Epoch 00069: val_accuracy did not improve from 0.66825
# 224/224 [==============================] - 434s 2s/step - loss: 0.2833 - accuracy: 0.8977 - top5_acc: 0.9994 - macro_f1score: 0.8725 - val_loss: 1.3382 - val_accuracy: 0.6652 - val_top5_acc: 0.9900 - val_macro_f1score: 0.6130
# Learning rate:  2.9999999999999997e-06
#
# Epoch 00070: LearningRateScheduler reducing learning rate to 2.9999999999999997e-06.
# Epoch 70/70
# 224/224 [==============================] - ETA: 0s - loss: 0.2799 - accuracy: 0.8981 - top5_acc: 0.9996 - macro_f1score: 0.8689
# Epoch 00070: val_loss did not improve from 0.96033
#
# Epoch 00070: val_accuracy did not improve from 0.66825
# 224/224 [==============================] - 434s 2s/step - loss: 0.2799 - accuracy: 0.8981 - top5_acc: 0.9996 - macro_f1score: 0.8689 - val_loss: 1.3452 - val_accuracy: 0.6643 - val_top5_acc: 0.9902 - val_macro_f1score: 0.6141

# %% [markdown]
# ### 2) VGG11 Evaluate

# %%
# 1. epoch=maximum
loss , acc, top5_acc, mf1 = model.evaluate(test_generator,steps=int(len(x_test)/batch_sizes))
print('[Test Loss: %.4f /  Test Top-1 Accuracy: %.4f / Test Top-5 Accuracy: %.4f / Test Macro f1: %.4f]\n' % (loss,acc,top5_acc,mf1))
# Out:
# 28/28 [==============================] - 1447s 52s/step - loss: 1.4660 - accuracy: 0.6462 - top5_acc: 0.9872 - macro_f1score: 0.5974
# [Test Loss: 1.4660 /  Test Top-1 Accuracy: 0.6462 / Test Top-5 Accuracy: 0.9872 / Test Macro f1: 0.5974]

# %%
loss=history.history['loss']
val_loss=history.history['val_loss']
acc=history.history['accuracy']
val_acc=history.history['val_accuracy']
top5_acc=history.history['top5_acc']
val_top5_acc=history.history['val_top5_acc']
f1=history.history['macro_f1score']
val_f1=history.history['val_macro_f1score']
epochs=range(1,len(acc)+1)

data = np.array([epochs,loss,val_loss,acc,val_acc,top5_acc,val_top5_acc,f1,val_f1]).T

# %%
# data save
# epochs, loss, val_loss, acc, val_acc, top5_acc, val_top5_acc, f1, val_f1

np.savetxt(os.path.join(dir,'train_valid_output',number,model.name+'.txt'),data)

# %%
# data import
data = np.loadtxt(os.path.join(dir,'train_valid_output',number,'VGG11.txt'))

# %%
epochs=data[:,0]
loss=data[:,1]
val_loss=data[:,2]
acc=data[:,3]
val_acc=data[:,4]
top5_acc=data[:,5]
val_top5_acc=data[:,6]

# %%
plt.plot(epochs[1:],acc[1:],'b',label='Training 1-Acc')
plt.plot(epochs[1:],val_acc[1:],'r',label='Validation 1-Acc')
plt.title('Training and Validation Top-1 Accuracy')
plt.legend()
plt.figure()

plt.plot(epochs[1:],top5_acc[1:],'b',label='Training 5-Acc')
plt.plot(epochs[1:],val_top5_acc[1:],'r',label='Validation 5-Acc')
plt.title('Training and Validation Top-5 Accuracy')
plt.legend()
plt.figure()

plt.plot(epochs[10:],loss[10:],'b',label='Training Loss')
plt.plot(epochs[10:],val_loss[10:],'r',label='Validation Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()

# %%
# 이 아래는 내가 인위적으로 살펴보고 싶은 epoch에 대해서 결과값 출력 / VGG11

# %%
# 참고 : https://github.com/OverLordGoldDragon/keras-adamw

import sys
sys.path.append('/content/drive/My Drive/Colab Notebooks/Paper')
import utils
import optimizers_v2
from utils import get_weight_decays, fill_dict_in_order
from utils import reset_seeds, K_eval
from optimizers_v2 import AdamW, NadamW, SGDW

# %%
# top-5 accuracy 출력
import functools
top5_acc = functools.partial(ks.metrics.top_k_categorical_accuracy, k=5)
top5_acc.__name__ = 'top5_acc'

# %%
model=load_model(os.path.join(dir,'model_output',number,'VGG11','031.h5'),custom_objects={"macro_f1score": macro_f1score,"top5_acc":top5_acc, "AdamW":AdamW})

# %%
# 2. epoch=?
loss , acc, top5_acc, mf1 = model.evaluate(test_generator,steps=int(len(x_test)/batch_sizes))
print('[Test Loss: %.4f /  Test Top-1 Accuracy: %.4f / Test Top-5 Accuracy: %.4f / Test Macro f1: %.4f]\n' % (loss,acc,top5_acc,mf1))
# Out:
# 28/28 [==============================] - 1553s 55s/step - loss: 1.1199 - accuracy: 0.6540 - top5_acc: 0.9900 - macro_f1score: 0.5888
# [Test Loss: 1.1199 /  Test Top-1 Accuracy: 0.6540 / Test Top-5 Accuracy: 0.9900 / Test Macro f1: 0.5888]
