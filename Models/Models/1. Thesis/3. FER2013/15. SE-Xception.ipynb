# %%
### 참고 : https://sike6054.github.io/blog/paper/fifth-post/
### SE block 코드 참고 : https://github.com/titu1994/keras-squeeze-excite-network/tree/master/keras_squeeze_excite_network

# %% [markdown]
# # [SE-Xception]

# %% [markdown]
# *KU LeeDongGyu*

# %% [markdown]
# ## Contents
# ---

# %% [markdown]
# 1. Data Preprocessing
# ```
# 1) Data Import
# 2) Data Augmentation
# ```
# 2. Support Functions & Almost Original SE-Xception
# ```
# 1) Support Functions
# 2) Almost Original SE-Xception
# 3) SE-Xception Evaluate
# ```

# %% [markdown]
# ### Install Packages

# %% [markdown]
# ### Module

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/My Drive/Colab Notebooks/Paper
# Out:
# /content/drive/My Drive/Colab Notebooks/Paper

# %%
from f1score import macro_f1score,weighted_f1score

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import cv2
import tensorflow as tf
from tensorflow import keras as ks
from tensorflow.keras import backend as K 
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, Input, Concatenate, ZeroPadding2D ,GlobalMaxPooling2D, Reshape , Lambda , Add, Multiply
from tensorflow.keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D, Activation, BatchNormalization, AveragePooling2D , ZeroPadding2D, SeparableConv2D , LeakyReLU
from tensorflow.keras.layers import add, concatenate, multiply
from tensorflow.keras.optimizers import Adam, RMSprop , SGD
from tensorflow.keras.callbacks import EarlyStopping , LearningRateScheduler, ModelCheckpoint, CSVLogger, Callback, ReduceLROnPlateau
from tensorflow.keras.regularizers import l1,l2,l1_l2
from tensorflow.keras.models import Model , load_model , Sequential
from tensorflow.keras.utils import plot_model , to_categorical, get_file
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
os.getcwd()
# Out:
# '/content/drive/My Drive/Colab Notebooks/Paper'

# %%
print(tf.__version__)
print(ks.__version__)
# Out:
# 2.3.0
# 2.4.0

# %%
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 452603528995793066
# , name: "/device:XLA_CPU:0"
# device_type: "XLA_CPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 9556167008558660632
# physical_device_desc: "device: XLA_CPU device"
# , name: "/device:XLA_GPU:0"
# device_type: "XLA_GPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 5628380197237988299
# physical_device_desc: "device: XLA_GPU device"
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 15695549568
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 6275572785014171440
# physical_device_desc: "device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0"
# ]

# %%
# !cat /proc/cpuinfo
# Out:
# processor	: 0
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 63
# model name	: Intel(R) Xeon(R) CPU @ 2.30GHz
# stepping	: 0
# microcode	: 0x1
# cpu MHz		: 2300.000
# cache size	: 46080 KB
# physical id	: 0
# siblings	: 4
# core id		: 0
# cpu cores	: 2
# apicid		: 0
# initial apicid	: 0
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 avx2 smep bmi2 erms invpcid xsaveopt arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs
# bogomips	: 4600.00
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 46 bits physical, 48 bits virtual
# power management:
#
# processor	: 1
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 63
# model name	: Intel(R) Xeon(R) CPU @ 2.30GHz
# stepping	: 0
# microcode	: 0x1
# cpu MHz		: 2300.000
# cache size	: 46080 KB
# physical id	: 0
# siblings	: 4
# core id		: 1
# cpu cores	: 2
# apicid		: 2
# initial apicid	: 2
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 avx2 smep bmi2 erms invpcid xsaveopt arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs
# bogomips	: 4600.00
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 46 bits physical, 48 bits virtual
# power management:
#
# processor	: 2
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 63
# model name	: Intel(R) Xeon(R) CPU @ 2.30GHz
# stepping	: 0
# microcode	: 0x1
# cpu MHz		: 2300.000
# cache size	: 46080 KB
# physical id	: 0
# siblings	: 4
# core id		: 0
# cpu cores	: 2
# apicid		: 1
# initial apicid	: 1
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 avx2 smep bmi2 erms invpcid xsaveopt arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs
# bogomips	: 4600.00
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 46 bits physical, 48 bits virtual
# power management:
#
# processor	: 3
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 63
# model name	: Intel(R) Xeon(R) CPU @ 2.30GHz
# stepping	: 0
# microcode	: 0x1
# cpu MHz		: 2300.000
# cache size	: 46080 KB
# physical id	: 0
# siblings	: 4
# core id		: 1
# cpu cores	: 2
# apicid		: 3
# initial apicid	: 3
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 avx2 smep bmi2 erms invpcid xsaveopt arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs
# bogomips	: 4600.00
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 46 bits physical, 48 bits virtual
# power management:

# %% [markdown]
# ## 1. Data Preprocessing
# ---

# %% [markdown]
# ### 1) Data Import

# %%
# 바꿔서 살펴 볼 것들
# CALTECH, CIFAR100, FER, MIT
data_name = 'FER'
gan_type = 'No_GAN'
number = '1'
size = 299 # sizes after cropping
super_size = 330 # sizes before cropping 
input_sizes = (size,size,3)
batch_sizes = 32
weight_decay = 1e-6
epochs = 70

# %%
# 참고 : https://stackoverflow.com/questions/32419510/how-to-get-reproducible-results-in-keras/52897216#52897216
# setting the seed number for random number generation for reproducibility.

from numpy.random import seed
import random


if number=='1':
    seed_num = 200225
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)
elif number=='2':
    seed_num = 727
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)
elif number=='3':
    seed_num = 115
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)
elif number=='4':
    seed_num = 501
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)
elif number=='5':
    seed_num = 517
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)

# %%
# data import

if data_name=='FER' :
    x_train =  np.zeros(28698)
    x_valid = np.zeros(3589)
    x_test = np.zeros(3588)
    classes = 7 
    tr_center = [0.50793296, 0.50793296, 0.50793296]
elif data_name=='MIT':
    x_train = np.zeros(12466)
    x_valid = np.zeros(1564)
    x_test = np.zeros(1590)
    classes = 67 
    tr_center = [0.47916578, 0.42029615, 0.36046057]
elif data_name=='CALTECH':
    x_train = np.zeros(24510)
    x_valid = np.zeros(2980)
    x_test = np.zeros(3118)
    classes = 257
    tr_center = [0.51397761, 0.49525248, 0.46555727]
elif data_name=='CIFAR100':
    x_train = np.zeros(44923)
    x_valid = np.zeros(5077)
    x_test = np.zeros(10000)
    classes = 100
    tr_center = [0.53442983, 0.51355958, 0.46462564]

# %%
dir = os.path.join(os.getcwd(),data_name,gan_type)

# %% [markdown]
# ### 2) Data Augmentation

# %%
# 참고 : https://jkjung-avt.github.io/keras-image-cropping/

def random_crop(img, random_crop_size):
    # Note: image_data_format is 'channel_last'
    assert img.shape[2] == 3 # img.shape[2] 가 3(rgb)이 아니면 assertion error 발생
    height, width = img.shape[0], img.shape[1]
    dy, dx = random_crop_size
    x = np.random.randint(0, width - dx + 1)
    y = np.random.randint(0, height - dy + 1)
    return img[y:(y+dy), x:(x+dx), :]


def crop_generator(batches, crop_length):
    """Take as input a Keras ImageGen (Iterator) and generate random
    crops from the image batches generated by the original iterator.
    """
    while True:
        batch_x, batch_y = next(batches)
        batch_crops = np.zeros((batch_x.shape[0], crop_length, crop_length, 3))
        for i in range(batch_x.shape[0]):
            batch_crops[i] = random_crop(batch_x[i], (crop_length, crop_length))
        yield (batch_crops, batch_y)

# %%
from tensorflow.keras.preprocessing.image import img_to_array,load_img
import glob

# 데이터 전체에 대해 centering 진행함.

def read_cal_image(img_path): 
    x = img_to_array(load_img(img_path)) # x는 채널별 평균값
    y = x.shape[0] * x.shape[1]# y는 데이터별 픽셀 수 (비중)

    x = 1/255. * x # scaling하고, centering값을 뽑아냄.
    x = np.mean(x, axis=(0,1))
    
    return np.hstack([x,y])

def calculate_centered_mean(dataset_path,x_train=x_train):
    num = len(x_train)
    space = np.empty((num,4))
    i=0

    for p in glob.glob(os.path.join(dataset_path,'*/*.*')) :
        space[i] = read_cal_image(p)
        i += 1

    ratio = space[:,3] / np.sum(space[:,3])

    return np.average(space[:,0:3],axis=0,weights=ratio)


# 아래의 함수를 돌려서 나온 결과값을 중심화 값으로 설정.

# train_mean = calculate_centered_mean(os.path.join(dir,'data/train')).reshape((1,1,3))

# %%
datagen_tr = ImageDataGenerator(
    rescale=1/255.,
    horizontal_flip=True,
    featurewise_center=True,
    featurewise_std_normalization=False,
    rotation_range=10,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=[0.9,1.0],
    fill_mode = 'nearest')
datagen_val = ImageDataGenerator(rescale=1/255.,featurewise_center=True)
datagen_tes = ImageDataGenerator(rescale=1/255.,featurewise_center=True)

# 원래는 이 자리에 fit 매서드를 써야하지만, 그냥 내가 중심화함수를 만들고 적용함. 

# 중심화 설정
datagen_tr.mean = np.array(tr_center, dtype=np.float32).reshape((1,1,3)) # RGB
datagen_val.mean = np.array(tr_center, dtype=np.float32).reshape((1,1,3)) # RGB
datagen_tes.mean = np.array(tr_center, dtype=np.float32).reshape((1,1,3)) # RGB

# %%
train_batches = datagen_tr.flow_from_directory(directory=os.path.join(dir,'data/train'),target_size=(super_size,super_size),batch_size=batch_sizes,class_mode='categorical') # fer : 28698 / mit : 12466 / caltech : 24509 / cifar : 44923
train_generator= crop_generator(train_batches, size)
valid_generator = datagen_val.flow_from_directory(directory=os.path.join(dir,'data/valid'),target_size=(size,size),batch_size=batch_sizes,class_mode='categorical') # fer : 3589 / mit : 1564 / caltech : 2980 / cifar : 5077
test_generator = datagen_tes.flow_from_directory(directory=os.path.join(dir,'data/test'),target_size=(size,size),batch_size=batch_sizes,class_mode='categorical') # fer : 3588 / mit : 1590 / caltech : 3118 / cifar : 10000
# Out:
# Found 28698 images belonging to 7 classes.
# Found 3589 images belonging to 7 classes.
# Found 3588 images belonging to 7 classes.

# %% [markdown]
# ## 2. Support Functions & Almost Original SE-Xception
# ---

# %% [markdown]
# ### 1) Support Functions

# %%
# def lr_schedule(epoch):
#     init_lr = 1e-4
#     k = 0.04
#     lr = init_lr * np.exp(-k*epoch)
#     print('Learning rate: ', lr)
#     return lr

def lr_schedule(epoch):
    lr = 1e-3
    if epoch < 30:
        lr = lr
    elif epoch < 60:
        lr = lr * 0.1
    else:
        lr = lr * 0.01
    print('Learning rate: ', lr)
    return lr

# %%
def squeeze_excite_block(input, reduction_ratio=16, weight_decay=weight_decay):

    init = input
    channel_axis = -1
    filters = init.get_shape()[channel_axis]
    se_shape = (1, 1, filters)

    se = GlobalAveragePooling2D()(init)
    se = Reshape(se_shape)(se)
    se = Dense(filters // reduction_ratio, activation='relu', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay), use_bias=False)(se)
    se = Dense(filters, activation='sigmoid', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay), use_bias=False)(se)

    x = multiply([init, se])
    return x

# %% [markdown]
# ### 2) Almost Original SE-Xception

# %%
def SE_Xception(input_shape=None, classes=1000, reduction_ratio = 16, name = "SE_Xception", weight_decay = weight_decay):


    img_input = Input(shape=input_shape)


    x = Conv2D(32, (3, 3), strides=(2, 2), use_bias=False, kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay), name='block1_conv1')(img_input)
    x = BatchNormalization(name='block1_conv1_bn')(x)
    x = Activation('relu', name='block1_conv1_act')(x)
    x = Conv2D(64, (3, 3), use_bias=False, kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay), name='block1_conv2')(x)
    x = BatchNormalization(name='block1_conv2_bn')(x)
    x = Activation('relu', name='block1_conv2_act')(x)

    residual = Conv2D(128, (1, 1), strides=(2, 2),
                      padding='same', use_bias=False, kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(x)
    residual = BatchNormalization()(residual)

    x = SeparableConv2D(128, (3, 3), padding='same', use_bias=False, depthwise_initializer='he_uniform', pointwise_initializer='he_uniform',depthwise_regularizer=l2(weight_decay), pointwise_regularizer=l2(weight_decay), name='block2_sepconv1')(x)
    x = BatchNormalization(name='block2_sepconv1_bn')(x)
    x = Activation('relu', name='block2_sepconv2_act')(x)
    x = SeparableConv2D(128, (3, 3), padding='same', use_bias=False, depthwise_initializer='he_uniform', pointwise_initializer='he_uniform',depthwise_regularizer=l2(weight_decay), pointwise_regularizer=l2(weight_decay), name='block2_sepconv2')(x)
    x = BatchNormalization(name='block2_sepconv2_bn')(x)

    x = MaxPooling2D((3, 3), strides=(2, 2), padding='same', name='block2_pool')(x)
    # SE block 추가
    x =  squeeze_excite_block(x, reduction_ratio)
    x = add([x, residual])

    residual = Conv2D(256, (1, 1), strides=(2, 2),
                      padding='same', use_bias=False, kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(x)
    residual = BatchNormalization()(residual)

    x = Activation('relu', name='block3_sepconv1_act')(x)
    x = SeparableConv2D(256, (3, 3), padding='same', use_bias=False, depthwise_initializer='he_uniform', pointwise_initializer='he_uniform',depthwise_regularizer=l2(weight_decay), pointwise_regularizer=l2(weight_decay), name='block3_sepconv1')(x)
    x = BatchNormalization(name='block3_sepconv1_bn')(x)
    x = Activation('relu', name='block3_sepconv2_act')(x)
    x = SeparableConv2D(256, (3, 3), padding='same', use_bias=False, depthwise_initializer='he_uniform', pointwise_initializer='he_uniform',depthwise_regularizer=l2(weight_decay), pointwise_regularizer=l2(weight_decay), name='block3_sepconv2')(x)
    x = BatchNormalization(name='block3_sepconv2_bn')(x)

    x = MaxPooling2D((3, 3), strides=(2, 2), padding='same', name='block3_pool')(x)
    # SE block 추가
    x =  squeeze_excite_block(x, reduction_ratio)    
    x = add([x, residual])

    residual = Conv2D(728, (1, 1), strides=(2, 2),
                      padding='same', use_bias=False, kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(x)
    residual = BatchNormalization()(residual)

    x = Activation('relu', name='block4_sepconv1_act')(x)
    x = SeparableConv2D(728, (3, 3), padding='same', use_bias=False, depthwise_initializer='he_uniform', pointwise_initializer='he_uniform',depthwise_regularizer=l2(weight_decay), pointwise_regularizer=l2(weight_decay), name='block4_sepconv1')(x)
    x = BatchNormalization(name='block4_sepconv1_bn')(x)
    x = Activation('relu', name='block4_sepconv2_act')(x)
    x = SeparableConv2D(728, (3, 3), padding='same', use_bias=False, depthwise_initializer='he_uniform', pointwise_initializer='he_uniform',depthwise_regularizer=l2(weight_decay), pointwise_regularizer=l2(weight_decay), name='block4_sepconv2')(x)
    x = BatchNormalization(name='block4_sepconv2_bn')(x)

    x = MaxPooling2D((3, 3), strides=(2, 2), padding='same', name='block4_pool')(x)
    # SE block 추가
    x =  squeeze_excite_block(x, reduction_ratio)
    x = add([x, residual])

    for i in range(8):
        residual = x
        prefix = 'block' + str(i + 5)

        x = Activation('relu', name=prefix + '_sepconv1_act')(x)
        x = SeparableConv2D(728, (3, 3), padding='same', use_bias=False, depthwise_initializer='he_uniform', pointwise_initializer='he_uniform',depthwise_regularizer=l2(weight_decay), pointwise_regularizer=l2(weight_decay), name=prefix + '_sepconv1')(x)
        x = BatchNormalization(name=prefix + '_sepconv1_bn')(x)
        x = Activation('relu', name=prefix + '_sepconv2_act')(x)
        x = SeparableConv2D(728, (3, 3), padding='same', use_bias=False, depthwise_initializer='he_uniform', pointwise_initializer='he_uniform',depthwise_regularizer=l2(weight_decay), pointwise_regularizer=l2(weight_decay), name=prefix + '_sepconv2')(x)
        x = BatchNormalization(name=prefix + '_sepconv2_bn')(x)
        x = Activation('relu', name=prefix + '_sepconv3_act')(x)
        x = SeparableConv2D(728, (3, 3), padding='same', use_bias=False, depthwise_initializer='he_uniform', pointwise_initializer='he_uniform',depthwise_regularizer=l2(weight_decay), pointwise_regularizer=l2(weight_decay), name=prefix + '_sepconv3')(x)
        x = BatchNormalization(name=prefix + '_sepconv3_bn')(x)

        # SE block 추가
        x =  squeeze_excite_block(x, reduction_ratio)
        x = add([x, residual])

    residual = Conv2D(1024, (1, 1), strides=(2, 2),
                      padding='same', use_bias=False, kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(x)
    residual = BatchNormalization()(residual)

    x = Activation('relu', name='block13_sepconv1_act')(x)
    x = SeparableConv2D(728, (3, 3), padding='same', use_bias=False, depthwise_initializer='he_uniform', pointwise_initializer='he_uniform',depthwise_regularizer=l2(weight_decay), pointwise_regularizer=l2(weight_decay), name='block13_sepconv1')(x)
    x = BatchNormalization(name='block13_sepconv1_bn')(x)
    x = Activation('relu', name='block13_sepconv2_act')(x)
    x = SeparableConv2D(1024, (3, 3), padding='same', use_bias=False, depthwise_initializer='he_uniform', pointwise_initializer='he_uniform',depthwise_regularizer=l2(weight_decay), pointwise_regularizer=l2(weight_decay), name='block13_sepconv2')(x)
    x = BatchNormalization(name='block13_sepconv2_bn')(x)

    x = MaxPooling2D((3, 3), strides=(2, 2), padding='same', name='block13_pool')(x)
    # SE block 추가
    x =  squeeze_excite_block(x, reduction_ratio)
    x = add([x, residual])

    x = SeparableConv2D(1536, (3, 3), padding='same', use_bias=False, depthwise_initializer='he_uniform', pointwise_initializer='he_uniform',depthwise_regularizer=l2(weight_decay), pointwise_regularizer=l2(weight_decay), name='block14_sepconv1')(x)
    x = BatchNormalization(name='block14_sepconv1_bn')(x)
    x = Activation('relu', name='block14_sepconv1_act')(x)

    x = SeparableConv2D(2048, (3, 3), padding='same', use_bias=False, depthwise_initializer='he_uniform', pointwise_initializer='he_uniform',depthwise_regularizer=l2(weight_decay), pointwise_regularizer=l2(weight_decay), name='block14_sepconv2')(x)
    x = BatchNormalization(name='block14_sepconv2_bn')(x)
    x = Activation('relu', name='block14_sepconv2_act')(x)


    x = GlobalAveragePooling2D(name='avg_pool')(x)
    x = Dropout(0.5)(x)
    x = Dense(classes, activation='softmax', kernel_regularizer=l2(weight_decay), name='predictions')(x)


    inputs = img_input

    # Create model.
    model = Model(inputs, x, name=name)

    return model

# %%
model = SE_Xception(input_sizes, classes=classes, reduction_ratio = 16, name='SE_Xception')

# %%
model.summary()
# Out:
# Model: "SE_Xception"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 299, 299, 3) 0
# __________________________________________________________________________________________________
# block1_conv1 (Conv2D)           (None, 149, 149, 32) 864         input_1[0][0]
# __________________________________________________________________________________________________
# block1_conv1_bn (BatchNormaliza (None, 149, 149, 32) 128         block1_conv1[0][0]
# __________________________________________________________________________________________________
# block1_conv1_act (Activation)   (None, 149, 149, 32) 0           block1_conv1_bn[0][0]
# __________________________________________________________________________________________________
# block1_conv2 (Conv2D)           (None, 147, 147, 64) 18432       block1_conv1_act[0][0]
# __________________________________________________________________________________________________
# block1_conv2_bn (BatchNormaliza (None, 147, 147, 64) 256         block1_conv2[0][0]
# __________________________________________________________________________________________________
# block1_conv2_act (Activation)   (None, 147, 147, 64) 0           block1_conv2_bn[0][0]
# __________________________________________________________________________________________________
# block2_sepconv1 (SeparableConv2 (None, 147, 147, 128 8768        block1_conv2_act[0][0]
# __________________________________________________________________________________________________
# block2_sepconv1_bn (BatchNormal (None, 147, 147, 128 512         block2_sepconv1[0][0]
# __________________________________________________________________________________________________
# block2_sepconv2_act (Activation (None, 147, 147, 128 0           block2_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block2_sepconv2 (SeparableConv2 (None, 147, 147, 128 17536       block2_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block2_sepconv2_bn (BatchNormal (None, 147, 147, 128 512         block2_sepconv2[0][0]
# __________________________________________________________________________________________________
# block2_pool (MaxPooling2D)      (None, 74, 74, 128)  0           block2_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 128)          0           block2_pool[0][0]
# __________________________________________________________________________________________________
# reshape (Reshape)               (None, 1, 1, 128)    0           global_average_pooling2d[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 1, 1, 8)      1024        reshape[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 1, 1, 128)    1024        dense[0][0]
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 74, 74, 128)  8192        block1_conv2_act[0][0]
# __________________________________________________________________________________________________
# multiply (Multiply)             (None, 74, 74, 128)  0           block2_pool[0][0]
#                                                                  dense_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 74, 74, 128)  512         conv2d[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 74, 74, 128)  0           multiply[0][0]
#                                                                  batch_normalization[0][0]
# __________________________________________________________________________________________________
# block3_sepconv1_act (Activation (None, 74, 74, 128)  0           add[0][0]
# __________________________________________________________________________________________________
# block3_sepconv1 (SeparableConv2 (None, 74, 74, 256)  33920       block3_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block3_sepconv1_bn (BatchNormal (None, 74, 74, 256)  1024        block3_sepconv1[0][0]
# __________________________________________________________________________________________________
# block3_sepconv2_act (Activation (None, 74, 74, 256)  0           block3_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block3_sepconv2 (SeparableConv2 (None, 74, 74, 256)  67840       block3_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block3_sepconv2_bn (BatchNormal (None, 74, 74, 256)  1024        block3_sepconv2[0][0]
# __________________________________________________________________________________________________
# block3_pool (MaxPooling2D)      (None, 37, 37, 256)  0           block3_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_1 (Glo (None, 256)          0           block3_pool[0][0]
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, 1, 1, 256)    0           global_average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 1, 1, 16)     4096        reshape_1[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 1, 1, 256)    4096        dense_2[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 37, 37, 256)  32768       add[0][0]
# __________________________________________________________________________________________________
# multiply_1 (Multiply)           (None, 37, 37, 256)  0           block3_pool[0][0]
#                                                                  dense_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 37, 37, 256)  1024        conv2d_1[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 37, 37, 256)  0           multiply_1[0][0]
#                                                                  batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# block4_sepconv1_act (Activation (None, 37, 37, 256)  0           add_1[0][0]
# __________________________________________________________________________________________________
# block4_sepconv1 (SeparableConv2 (None, 37, 37, 728)  188672      block4_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block4_sepconv1_bn (BatchNormal (None, 37, 37, 728)  2912        block4_sepconv1[0][0]
# __________________________________________________________________________________________________
# block4_sepconv2_act (Activation (None, 37, 37, 728)  0           block4_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block4_sepconv2 (SeparableConv2 (None, 37, 37, 728)  536536      block4_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block4_sepconv2_bn (BatchNormal (None, 37, 37, 728)  2912        block4_sepconv2[0][0]
# __________________________________________________________________________________________________
# block4_pool (MaxPooling2D)      (None, 19, 19, 728)  0           block4_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_2 (Glo (None, 728)          0           block4_pool[0][0]
# __________________________________________________________________________________________________
# reshape_2 (Reshape)             (None, 1, 1, 728)    0           global_average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 1, 1, 45)     32760       reshape_2[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 1, 1, 728)    32760       dense_4[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 19, 19, 728)  186368      add_1[0][0]
# __________________________________________________________________________________________________
# multiply_2 (Multiply)           (None, 19, 19, 728)  0           block4_pool[0][0]
#                                                                  dense_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 19, 19, 728)  2912        conv2d_2[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 19, 19, 728)  0           multiply_2[0][0]
#                                                                  batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# block5_sepconv1_act (Activation (None, 19, 19, 728)  0           add_2[0][0]
# __________________________________________________________________________________________________
# block5_sepconv1 (SeparableConv2 (None, 19, 19, 728)  536536      block5_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block5_sepconv1_bn (BatchNormal (None, 19, 19, 728)  2912        block5_sepconv1[0][0]
# __________________________________________________________________________________________________
# block5_sepconv2_act (Activation (None, 19, 19, 728)  0           block5_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block5_sepconv2 (SeparableConv2 (None, 19, 19, 728)  536536      block5_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block5_sepconv2_bn (BatchNormal (None, 19, 19, 728)  2912        block5_sepconv2[0][0]
# __________________________________________________________________________________________________
# block5_sepconv3_act (Activation (None, 19, 19, 728)  0           block5_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block5_sepconv3 (SeparableConv2 (None, 19, 19, 728)  536536      block5_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block5_sepconv3_bn (BatchNormal (None, 19, 19, 728)  2912        block5_sepconv3[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_3 (Glo (None, 728)          0           block5_sepconv3_bn[0][0]
# __________________________________________________________________________________________________
# reshape_3 (Reshape)             (None, 1, 1, 728)    0           global_average_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 1, 1, 45)     32760       reshape_3[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 1, 1, 728)    32760       dense_6[0][0]
# __________________________________________________________________________________________________
# multiply_3 (Multiply)           (None, 19, 19, 728)  0           block5_sepconv3_bn[0][0]
#                                                                  dense_7[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 19, 19, 728)  0           multiply_3[0][0]
#                                                                  add_2[0][0]
# __________________________________________________________________________________________________
# block6_sepconv1_act (Activation (None, 19, 19, 728)  0           add_3[0][0]
# __________________________________________________________________________________________________
# block6_sepconv1 (SeparableConv2 (None, 19, 19, 728)  536536      block6_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block6_sepconv1_bn (BatchNormal (None, 19, 19, 728)  2912        block6_sepconv1[0][0]
# __________________________________________________________________________________________________
# block6_sepconv2_act (Activation (None, 19, 19, 728)  0           block6_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block6_sepconv2 (SeparableConv2 (None, 19, 19, 728)  536536      block6_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block6_sepconv2_bn (BatchNormal (None, 19, 19, 728)  2912        block6_sepconv2[0][0]
# __________________________________________________________________________________________________
# block6_sepconv3_act (Activation (None, 19, 19, 728)  0           block6_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block6_sepconv3 (SeparableConv2 (None, 19, 19, 728)  536536      block6_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block6_sepconv3_bn (BatchNormal (None, 19, 19, 728)  2912        block6_sepconv3[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_4 (Glo (None, 728)          0           block6_sepconv3_bn[0][0]
# __________________________________________________________________________________________________
# reshape_4 (Reshape)             (None, 1, 1, 728)    0           global_average_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 1, 1, 45)     32760       reshape_4[0][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, 1, 1, 728)    32760       dense_8[0][0]
# __________________________________________________________________________________________________
# multiply_4 (Multiply)           (None, 19, 19, 728)  0           block6_sepconv3_bn[0][0]
#                                                                  dense_9[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 19, 19, 728)  0           multiply_4[0][0]
#                                                                  add_3[0][0]
# __________________________________________________________________________________________________
# block7_sepconv1_act (Activation (None, 19, 19, 728)  0           add_4[0][0]
# __________________________________________________________________________________________________
# block7_sepconv1 (SeparableConv2 (None, 19, 19, 728)  536536      block7_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block7_sepconv1_bn (BatchNormal (None, 19, 19, 728)  2912        block7_sepconv1[0][0]
# __________________________________________________________________________________________________
# block7_sepconv2_act (Activation (None, 19, 19, 728)  0           block7_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block7_sepconv2 (SeparableConv2 (None, 19, 19, 728)  536536      block7_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block7_sepconv2_bn (BatchNormal (None, 19, 19, 728)  2912        block7_sepconv2[0][0]
# __________________________________________________________________________________________________
# block7_sepconv3_act (Activation (None, 19, 19, 728)  0           block7_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block7_sepconv3 (SeparableConv2 (None, 19, 19, 728)  536536      block7_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block7_sepconv3_bn (BatchNormal (None, 19, 19, 728)  2912        block7_sepconv3[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_5 (Glo (None, 728)          0           block7_sepconv3_bn[0][0]
# __________________________________________________________________________________________________
# reshape_5 (Reshape)             (None, 1, 1, 728)    0           global_average_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# dense_10 (Dense)                (None, 1, 1, 45)     32760       reshape_5[0][0]
# __________________________________________________________________________________________________
# dense_11 (Dense)                (None, 1, 1, 728)    32760       dense_10[0][0]
# __________________________________________________________________________________________________
# multiply_5 (Multiply)           (None, 19, 19, 728)  0           block7_sepconv3_bn[0][0]
#                                                                  dense_11[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 19, 19, 728)  0           multiply_5[0][0]
#                                                                  add_4[0][0]
# __________________________________________________________________________________________________
# block8_sepconv1_act (Activation (None, 19, 19, 728)  0           add_5[0][0]
# __________________________________________________________________________________________________
# block8_sepconv1 (SeparableConv2 (None, 19, 19, 728)  536536      block8_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block8_sepconv1_bn (BatchNormal (None, 19, 19, 728)  2912        block8_sepconv1[0][0]
# __________________________________________________________________________________________________
# block8_sepconv2_act (Activation (None, 19, 19, 728)  0           block8_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block8_sepconv2 (SeparableConv2 (None, 19, 19, 728)  536536      block8_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block8_sepconv2_bn (BatchNormal (None, 19, 19, 728)  2912        block8_sepconv2[0][0]
# __________________________________________________________________________________________________
# block8_sepconv3_act (Activation (None, 19, 19, 728)  0           block8_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block8_sepconv3 (SeparableConv2 (None, 19, 19, 728)  536536      block8_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block8_sepconv3_bn (BatchNormal (None, 19, 19, 728)  2912        block8_sepconv3[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_6 (Glo (None, 728)          0           block8_sepconv3_bn[0][0]
# __________________________________________________________________________________________________
# reshape_6 (Reshape)             (None, 1, 1, 728)    0           global_average_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# dense_12 (Dense)                (None, 1, 1, 45)     32760       reshape_6[0][0]
# __________________________________________________________________________________________________
# dense_13 (Dense)                (None, 1, 1, 728)    32760       dense_12[0][0]
# __________________________________________________________________________________________________
# multiply_6 (Multiply)           (None, 19, 19, 728)  0           block8_sepconv3_bn[0][0]
#                                                                  dense_13[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 19, 19, 728)  0           multiply_6[0][0]
#                                                                  add_5[0][0]
# __________________________________________________________________________________________________
# block9_sepconv1_act (Activation (None, 19, 19, 728)  0           add_6[0][0]
# __________________________________________________________________________________________________
# block9_sepconv1 (SeparableConv2 (None, 19, 19, 728)  536536      block9_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block9_sepconv1_bn (BatchNormal (None, 19, 19, 728)  2912        block9_sepconv1[0][0]
# __________________________________________________________________________________________________
# block9_sepconv2_act (Activation (None, 19, 19, 728)  0           block9_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block9_sepconv2 (SeparableConv2 (None, 19, 19, 728)  536536      block9_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block9_sepconv2_bn (BatchNormal (None, 19, 19, 728)  2912        block9_sepconv2[0][0]
# __________________________________________________________________________________________________
# block9_sepconv3_act (Activation (None, 19, 19, 728)  0           block9_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block9_sepconv3 (SeparableConv2 (None, 19, 19, 728)  536536      block9_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block9_sepconv3_bn (BatchNormal (None, 19, 19, 728)  2912        block9_sepconv3[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_7 (Glo (None, 728)          0           block9_sepconv3_bn[0][0]
# __________________________________________________________________________________________________
# reshape_7 (Reshape)             (None, 1, 1, 728)    0           global_average_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# dense_14 (Dense)                (None, 1, 1, 45)     32760       reshape_7[0][0]
# __________________________________________________________________________________________________
# dense_15 (Dense)                (None, 1, 1, 728)    32760       dense_14[0][0]
# __________________________________________________________________________________________________
# multiply_7 (Multiply)           (None, 19, 19, 728)  0           block9_sepconv3_bn[0][0]
#                                                                  dense_15[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 19, 19, 728)  0           multiply_7[0][0]
#                                                                  add_6[0][0]
# __________________________________________________________________________________________________
# block10_sepconv1_act (Activatio (None, 19, 19, 728)  0           add_7[0][0]
# __________________________________________________________________________________________________
# block10_sepconv1 (SeparableConv (None, 19, 19, 728)  536536      block10_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block10_sepconv1_bn (BatchNorma (None, 19, 19, 728)  2912        block10_sepconv1[0][0]
# __________________________________________________________________________________________________
# block10_sepconv2_act (Activatio (None, 19, 19, 728)  0           block10_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block10_sepconv2 (SeparableConv (None, 19, 19, 728)  536536      block10_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block10_sepconv2_bn (BatchNorma (None, 19, 19, 728)  2912        block10_sepconv2[0][0]
# __________________________________________________________________________________________________
# block10_sepconv3_act (Activatio (None, 19, 19, 728)  0           block10_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block10_sepconv3 (SeparableConv (None, 19, 19, 728)  536536      block10_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block10_sepconv3_bn (BatchNorma (None, 19, 19, 728)  2912        block10_sepconv3[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_8 (Glo (None, 728)          0           block10_sepconv3_bn[0][0]
# __________________________________________________________________________________________________
# reshape_8 (Reshape)             (None, 1, 1, 728)    0           global_average_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# dense_16 (Dense)                (None, 1, 1, 45)     32760       reshape_8[0][0]
# __________________________________________________________________________________________________
# dense_17 (Dense)                (None, 1, 1, 728)    32760       dense_16[0][0]
# __________________________________________________________________________________________________
# multiply_8 (Multiply)           (None, 19, 19, 728)  0           block10_sepconv3_bn[0][0]
#                                                                  dense_17[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 19, 19, 728)  0           multiply_8[0][0]
#                                                                  add_7[0][0]
# __________________________________________________________________________________________________
# block11_sepconv1_act (Activatio (None, 19, 19, 728)  0           add_8[0][0]
# __________________________________________________________________________________________________
# block11_sepconv1 (SeparableConv (None, 19, 19, 728)  536536      block11_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block11_sepconv1_bn (BatchNorma (None, 19, 19, 728)  2912        block11_sepconv1[0][0]
# __________________________________________________________________________________________________
# block11_sepconv2_act (Activatio (None, 19, 19, 728)  0           block11_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block11_sepconv2 (SeparableConv (None, 19, 19, 728)  536536      block11_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block11_sepconv2_bn (BatchNorma (None, 19, 19, 728)  2912        block11_sepconv2[0][0]
# __________________________________________________________________________________________________
# block11_sepconv3_act (Activatio (None, 19, 19, 728)  0           block11_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block11_sepconv3 (SeparableConv (None, 19, 19, 728)  536536      block11_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block11_sepconv3_bn (BatchNorma (None, 19, 19, 728)  2912        block11_sepconv3[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_9 (Glo (None, 728)          0           block11_sepconv3_bn[0][0]
# __________________________________________________________________________________________________
# reshape_9 (Reshape)             (None, 1, 1, 728)    0           global_average_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# dense_18 (Dense)                (None, 1, 1, 45)     32760       reshape_9[0][0]
# __________________________________________________________________________________________________
# dense_19 (Dense)                (None, 1, 1, 728)    32760       dense_18[0][0]
# __________________________________________________________________________________________________
# multiply_9 (Multiply)           (None, 19, 19, 728)  0           block11_sepconv3_bn[0][0]
#                                                                  dense_19[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 19, 19, 728)  0           multiply_9[0][0]
#                                                                  add_8[0][0]
# __________________________________________________________________________________________________
# block12_sepconv1_act (Activatio (None, 19, 19, 728)  0           add_9[0][0]
# __________________________________________________________________________________________________
# block12_sepconv1 (SeparableConv (None, 19, 19, 728)  536536      block12_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block12_sepconv1_bn (BatchNorma (None, 19, 19, 728)  2912        block12_sepconv1[0][0]
# __________________________________________________________________________________________________
# block12_sepconv2_act (Activatio (None, 19, 19, 728)  0           block12_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block12_sepconv2 (SeparableConv (None, 19, 19, 728)  536536      block12_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block12_sepconv2_bn (BatchNorma (None, 19, 19, 728)  2912        block12_sepconv2[0][0]
# __________________________________________________________________________________________________
# block12_sepconv3_act (Activatio (None, 19, 19, 728)  0           block12_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block12_sepconv3 (SeparableConv (None, 19, 19, 728)  536536      block12_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block12_sepconv3_bn (BatchNorma (None, 19, 19, 728)  2912        block12_sepconv3[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_10 (Gl (None, 728)          0           block12_sepconv3_bn[0][0]
# __________________________________________________________________________________________________
# reshape_10 (Reshape)            (None, 1, 1, 728)    0           global_average_pooling2d_10[0][0]
# __________________________________________________________________________________________________
# dense_20 (Dense)                (None, 1, 1, 45)     32760       reshape_10[0][0]
# __________________________________________________________________________________________________
# dense_21 (Dense)                (None, 1, 1, 728)    32760       dense_20[0][0]
# __________________________________________________________________________________________________
# multiply_10 (Multiply)          (None, 19, 19, 728)  0           block12_sepconv3_bn[0][0]
#                                                                  dense_21[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 19, 19, 728)  0           multiply_10[0][0]
#                                                                  add_9[0][0]
# __________________________________________________________________________________________________
# block13_sepconv1_act (Activatio (None, 19, 19, 728)  0           add_10[0][0]
# __________________________________________________________________________________________________
# block13_sepconv1 (SeparableConv (None, 19, 19, 728)  536536      block13_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block13_sepconv1_bn (BatchNorma (None, 19, 19, 728)  2912        block13_sepconv1[0][0]
# __________________________________________________________________________________________________
# block13_sepconv2_act (Activatio (None, 19, 19, 728)  0           block13_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block13_sepconv2 (SeparableConv (None, 19, 19, 1024) 752024      block13_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block13_sepconv2_bn (BatchNorma (None, 19, 19, 1024) 4096        block13_sepconv2[0][0]
# __________________________________________________________________________________________________
# block13_pool (MaxPooling2D)     (None, 10, 10, 1024) 0           block13_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_11 (Gl (None, 1024)         0           block13_pool[0][0]
# __________________________________________________________________________________________________
# reshape_11 (Reshape)            (None, 1, 1, 1024)   0           global_average_pooling2d_11[0][0]
# __________________________________________________________________________________________________
# dense_22 (Dense)                (None, 1, 1, 64)     65536       reshape_11[0][0]
# __________________________________________________________________________________________________
# dense_23 (Dense)                (None, 1, 1, 1024)   65536       dense_22[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 10, 10, 1024) 745472      add_10[0][0]
# __________________________________________________________________________________________________
# multiply_11 (Multiply)          (None, 10, 10, 1024) 0           block13_pool[0][0]
#                                                                  dense_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 10, 10, 1024) 4096        conv2d_3[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 10, 10, 1024) 0           multiply_11[0][0]
#                                                                  batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# block14_sepconv1 (SeparableConv (None, 10, 10, 1536) 1582080     add_11[0][0]
# __________________________________________________________________________________________________
# block14_sepconv1_bn (BatchNorma (None, 10, 10, 1536) 6144        block14_sepconv1[0][0]
# __________________________________________________________________________________________________
# block14_sepconv1_act (Activatio (None, 10, 10, 1536) 0           block14_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block14_sepconv2 (SeparableConv (None, 10, 10, 2048) 3159552     block14_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block14_sepconv2_bn (BatchNorma (None, 10, 10, 2048) 8192        block14_sepconv2[0][0]
# __________________________________________________________________________________________________
# block14_sepconv2_act (Activatio (None, 10, 10, 2048) 0           block14_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# avg_pool (GlobalAveragePooling2 (None, 2048)         0           block14_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 2048)         0           avg_pool[0][0]
# __________________________________________________________________________________________________
# predictions (Dense)             (None, 7)            14343       dropout[0][0]
# ==================================================================================================
# Total params: 21,606,815
# Trainable params: 21,552,287
# Non-trainable params: 54,528
# __________________________________________________________________________________________________

# %%
# 폴더 생성

os.makedirs(os.path.join(dir,'model_output',number,model.name), exist_ok=True)
os.makedirs(os.path.join(dir,'train_valid_output',number), exist_ok=True)

# %%
# 참고 : https://github.com/OverLordGoldDragon/keras-adamw

import sys
sys.path.append('/content/drive/My Drive/Colab Notebooks/Paper')
import utils
import optimizers_v2
from utils import get_weight_decays, fill_dict_in_order
from utils import reset_seeds, K_eval
from optimizers_v2 import AdamW, NadamW, SGDW

# %%
# top-5 accuracy 출력
import functools
top5_acc = functools.partial(ks.metrics.top_k_categorical_accuracy, k=5)
top5_acc.__name__ = 'top5_acc'

# %%
optimizer = AdamW(model=model, use_cosine_annealing=False, total_iterations = len(x_train) // batch_sizes)
#optimizer = Adam()
filepath =  os.path.join(dir,'model_output',number,model.name,'{epoch:03d}.h5')

callbacks_list = [ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_weights_only=False, save_best_only=True, mode='min'),
                  ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_weights_only=False, save_best_only=True, mode='max'),
                  #ReduceLROnPlateau(monitor='val_loss',patience=3,factor=0.1,min_lr=1e-5),
                  LearningRateScheduler(lr_schedule,verbose=1)
                  ]
                  
model.compile(optimizer, loss = 'categorical_crossentropy', metrics=['accuracy',top5_acc,macro_f1score])

# %%
######## flow_from_directory
history = model.fit(train_generator, steps_per_epoch=int(len(x_train)/batch_sizes),  validation_data = valid_generator, epochs=epochs, verbose=1 , callbacks = callbacks_list , validation_steps=int(len(x_valid)/batch_sizes))
# Out:
# Learning rate:  0.001
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 1/70
# 0.0(L1), 3.3407655154706825e-08(L2) weight decay set for block1_conv1/kernel:0
# 0.0(L1), 3.3407655154706825e-08(L2) weight decay set for block1_conv2/kernel:0
# 0.0(L1), 3.3407655154706825e-08(L2) weight decay set for dense/kernel:0
# 0.0(L1), 3.3407655154706825e-08(L2) weight decay set for dense_1/kernel:0
# 0.0(L1), 3.3407655154706825e-08(L2) weight decay set for conv2d/kernel:0
# 0.0(L1), 3.3407655154706825e-08(L2) weight decay set for dense_2/kernel:0
# 0.0(L1), 3.3407655154706825e-08(L2) weight decay set for dense_3/kernel:0
# 0.0(L1), 3.3407655154706825e-08(L2) weight decay set for conv2d_1/kernel:0
# 0.0(L1), 3.3407655154706825e-08(L2) weight decay set for dense_4/kernel:0
# 0.0(L1), 3.3407655154706825e-08(L2) weight decay set for dense_5/kernel:0
# 0.0(L1), 3.3407655154706825e-08(L2) weight decay set for conv2d_2/kernel:0
# 0.0(L1), 3.3407655154706825e-08(L2) weight decay set for dense_6/kernel:0
# 0.0(L1), 3.3407655154706825e-08(L2) weight decay set for dense_7/kernel:0
# 0.0(L1), 3.3407655154706825e-08(L2) weight decay set for dense_8/kernel:0
# 0.0(L1), 3.3407655154706825e-08(L2) weight decay set for dense_9/kernel:0
# 0.0(L1), 3.3407655154706825e-08(L2) weight decay set for dense_10/kernel:0
# 0.0(L1), 3.3407655154706825e-08(L2) weight decay set for dense_11/kernel:0
# 0.0(L1), 3.3407655154706825e-08(L2) weight decay set for dense_12/kernel:0
# 0.0(L1), 3.3407655154706825e-08(L2) weight decay set for dense_13/kernel:0
# 0.0(L1), 3.3407655154706825e-08(L2) weight decay set for dense_14/kernel:0
# 0.0(L1), 3.3407655154706825e-08(L2) weight decay set for dense_15/kernel:0
# 0.0(L1), 3.3407655154706825e-08(L2) weight decay set for dense_16/kernel:0
# 0.0(L1), 3.3407655154706825e-08(L2) weight decay set for dense_17/kernel:0
# 0.0(L1), 3.3407655154706825e-08(L2) weight decay set for dense_18/kernel:0
# 0.0(L1), 3.3407655154706825e-08(L2) weight decay set for dense_19/kernel:0
# 0.0(L1), 3.3407655154706825e-08(L2) weight decay set for dense_20/kernel:0
# 0.0(L1), 3.3407655154706825e-08(L2) weight decay set for dense_21/kernel:0
# 0.0(L1), 3.3407655154706825e-08(L2) weight decay set for dense_22/kernel:0
# 0.0(L1), 3.3407655154706825e-08(L2) weight decay set for dense_23/kernel:0
# 0.0(L1), 3.3407655154706825e-08(L2) weight decay set for conv2d_3/kernel:0
# 0.0(L1), 3.3407655154706825e-08(L2) weight decay set for predictions/kernel:0
# 896/896 [==============================] - ETA: 0s - loss: 1.8588 - accuracy: 0.2709 - top5_acc: 0.8946 - macro_f1score: 0.0298
# Epoch 00001: val_loss improved from inf to 2.00554, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/SE_Xception/001.h5
#
# Epoch 00001: val_accuracy improved from -inf to 0.29464, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/SE_Xception/001.h5
# 896/896 [==============================] - 15679s 17s/step - loss: 1.8588 - accuracy: 0.2709 - top5_acc: 0.8946 - macro_f1score: 0.0298 - val_loss: 2.0055 - val_accuracy: 0.2946 - val_top5_acc: 0.8959 - val_macro_f1score: 0.1057
# Learning rate:  0.001
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 2/70
# 896/896 [==============================] - ETA: 0s - loss: 1.5952 - accuracy: 0.4002 - top5_acc: 0.9405 - macro_f1score: 0.1527
# Epoch 00002: val_loss improved from 2.00554 to 1.75319, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/SE_Xception/002.h5
#
# Epoch 00002: val_accuracy improved from 0.29464 to 0.41685, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/SE_Xception/002.h5
# 896/896 [==============================] - 728s 813ms/step - loss: 1.5952 - accuracy: 0.4002 - top5_acc: 0.9405 - macro_f1score: 0.1527 - val_loss: 1.7532 - val_accuracy: 0.4169 - val_top5_acc: 0.9325 - val_macro_f1score: 0.2043
# Learning rate:  0.001
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 3/70
# 896/896 [==============================] - ETA: 0s - loss: 1.3961 - accuracy: 0.4878 - top5_acc: 0.9643 - macro_f1score: 0.2436
# Epoch 00003: val_loss improved from 1.75319 to 1.59172, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/SE_Xception/003.h5
#
# Epoch 00003: val_accuracy did not improve from 0.41685
# 896/896 [==============================] - 713s 795ms/step - loss: 1.3961 - accuracy: 0.4878 - top5_acc: 0.9643 - macro_f1score: 0.2436 - val_loss: 1.5917 - val_accuracy: 0.4057 - val_top5_acc: 0.9556 - val_macro_f1score: 0.2261
# Learning rate:  0.001
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 4/70
# 896/896 [==============================] - ETA: 0s - loss: 1.2866 - accuracy: 0.5264 - top5_acc: 0.9726 - macro_f1score: 0.3009
# Epoch 00004: val_loss improved from 1.59172 to 1.33802, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/SE_Xception/004.h5
#
# Epoch 00004: val_accuracy improved from 0.41685 to 0.50893, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/SE_Xception/004.h5
# 896/896 [==============================] - 710s 792ms/step - loss: 1.2866 - accuracy: 0.5264 - top5_acc: 0.9726 - macro_f1score: 0.3009 - val_loss: 1.3380 - val_accuracy: 0.5089 - val_top5_acc: 0.9660 - val_macro_f1score: 0.3016
# Learning rate:  0.001
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 5/70
# 896/896 [==============================] - ETA: 0s - loss: 1.2173 - accuracy: 0.5552 - top5_acc: 0.9777 - macro_f1score: 0.3391
# Epoch 00005: val_loss improved from 1.33802 to 1.24666, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/SE_Xception/005.h5
#
# Epoch 00005: val_accuracy improved from 0.50893 to 0.54994, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/SE_Xception/005.h5
# 896/896 [==============================] - 712s 794ms/step - loss: 1.2173 - accuracy: 0.5552 - top5_acc: 0.9777 - macro_f1score: 0.3391 - val_loss: 1.2467 - val_accuracy: 0.5499 - val_top5_acc: 0.9782 - val_macro_f1score: 0.3544
# Learning rate:  0.001
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 6/70
# 896/896 [==============================] - ETA: 0s - loss: 1.1685 - accuracy: 0.5734 - top5_acc: 0.9811 - macro_f1score: 0.3645
# Epoch 00006: val_loss did not improve from 1.24666
#
# Epoch 00006: val_accuracy did not improve from 0.54994
# 896/896 [==============================] - 709s 792ms/step - loss: 1.1685 - accuracy: 0.5734 - top5_acc: 0.9811 - macro_f1score: 0.3645 - val_loss: 1.3152 - val_accuracy: 0.5232 - val_top5_acc: 0.9799 - val_macro_f1score: 0.3199
# Learning rate:  0.001
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 7/70
# 896/896 [==============================] - ETA: 0s - loss: 1.1247 - accuracy: 0.5899 - top5_acc: 0.9837 - macro_f1score: 0.3929
# Epoch 00007: val_loss did not improve from 1.24666
#
# Epoch 00007: val_accuracy improved from 0.54994 to 0.56501, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/SE_Xception/007.h5
# 896/896 [==============================] - 712s 794ms/step - loss: 1.1247 - accuracy: 0.5899 - top5_acc: 0.9837 - macro_f1score: 0.3929 - val_loss: 1.2474 - val_accuracy: 0.5650 - val_top5_acc: 0.9816 - val_macro_f1score: 0.4047
# Learning rate:  0.001
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 8/70
# 896/896 [==============================] - ETA: 0s - loss: 1.0953 - accuracy: 0.6011 - top5_acc: 0.9850 - macro_f1score: 0.4118
# Epoch 00008: val_loss improved from 1.24666 to 1.21728, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/SE_Xception/008.h5
#
# Epoch 00008: val_accuracy did not improve from 0.56501
# 896/896 [==============================] - 716s 799ms/step - loss: 1.0953 - accuracy: 0.6011 - top5_acc: 0.9850 - macro_f1score: 0.4118 - val_loss: 1.2173 - val_accuracy: 0.5597 - val_top5_acc: 0.9821 - val_macro_f1score: 0.3484
# Learning rate:  0.001
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 9/70
# 896/896 [==============================] - ETA: 0s - loss: 1.0649 - accuracy: 0.6162 - top5_acc: 0.9856 - macro_f1score: 0.4340
# Epoch 00009: val_loss improved from 1.21728 to 1.17155, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/SE_Xception/009.h5
#
# Epoch 00009: val_accuracy improved from 0.56501 to 0.58650, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/SE_Xception/009.h5
# 896/896 [==============================] - 714s 796ms/step - loss: 1.0649 - accuracy: 0.6162 - top5_acc: 0.9856 - macro_f1score: 0.4340 - val_loss: 1.1715 - val_accuracy: 0.5865 - val_top5_acc: 0.9810 - val_macro_f1score: 0.3985
# Learning rate:  0.001
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 10/70
# 896/896 [==============================] - ETA: 0s - loss: 1.0448 - accuracy: 0.6238 - top5_acc: 0.9868 - macro_f1score: 0.4452
# Epoch 00010: val_loss improved from 1.17155 to 1.13671, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/SE_Xception/010.h5
#
# Epoch 00010: val_accuracy did not improve from 0.58650
# 896/896 [==============================] - 708s 791ms/step - loss: 1.0448 - accuracy: 0.6238 - top5_acc: 0.9868 - macro_f1score: 0.4452 - val_loss: 1.1367 - val_accuracy: 0.5843 - val_top5_acc: 0.9791 - val_macro_f1score: 0.4141
# Learning rate:  0.001
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 11/70
# 896/896 [==============================] - ETA: 0s - loss: 1.0140 - accuracy: 0.6356 - top5_acc: 0.9890 - macro_f1score: 0.4638
# Epoch 00011: val_loss did not improve from 1.13671
#
# Epoch 00011: val_accuracy did not improve from 0.58650
# 896/896 [==============================] - 708s 790ms/step - loss: 1.0140 - accuracy: 0.6356 - top5_acc: 0.9890 - macro_f1score: 0.4638 - val_loss: 1.1934 - val_accuracy: 0.5698 - val_top5_acc: 0.9802 - val_macro_f1score: 0.4078
# Learning rate:  0.001
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 12/70
# 896/896 [==============================] - ETA: 0s - loss: 0.9825 - accuracy: 0.6500 - top5_acc: 0.9901 - macro_f1score: 0.4862
# Epoch 00012: val_loss did not improve from 1.13671
#
# Epoch 00012: val_accuracy improved from 0.58650 to 0.60128, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/SE_Xception/012.h5
# 896/896 [==============================] - 709s 791ms/step - loss: 0.9825 - accuracy: 0.6500 - top5_acc: 0.9901 - macro_f1score: 0.4862 - val_loss: 1.1447 - val_accuracy: 0.6013 - val_top5_acc: 0.9877 - val_macro_f1score: 0.4506
# Learning rate:  0.001
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 13/70
# 896/896 [==============================] - ETA: 0s - loss: 0.9597 - accuracy: 0.6560 - top5_acc: 0.9907 - macro_f1score: 0.4994
# Epoch 00013: val_loss did not improve from 1.13671
#
# Epoch 00013: val_accuracy did not improve from 0.60128
# 896/896 [==============================] - 708s 790ms/step - loss: 0.9597 - accuracy: 0.6560 - top5_acc: 0.9907 - macro_f1score: 0.4994 - val_loss: 1.1491 - val_accuracy: 0.5871 - val_top5_acc: 0.9869 - val_macro_f1score: 0.4509
# Learning rate:  0.001
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 14/70
# 896/896 [==============================] - ETA: 0s - loss: 0.9392 - accuracy: 0.6651 - top5_acc: 0.9911 - macro_f1score: 0.5097
# Epoch 00014: val_loss did not improve from 1.13671
#
# Epoch 00014: val_accuracy did not improve from 0.60128
# 896/896 [==============================] - 706s 788ms/step - loss: 0.9392 - accuracy: 0.6651 - top5_acc: 0.9911 - macro_f1score: 0.5097 - val_loss: 1.1810 - val_accuracy: 0.5795 - val_top5_acc: 0.9855 - val_macro_f1score: 0.4009
# Learning rate:  0.001
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 15/70
# 896/896 [==============================] - ETA: 0s - loss: 0.9175 - accuracy: 0.6747 - top5_acc: 0.9922 - macro_f1score: 0.5280
# Epoch 00015: val_loss improved from 1.13671 to 1.10867, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/SE_Xception/015.h5
#
# Epoch 00015: val_accuracy improved from 0.60128 to 0.60993, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/SE_Xception/015.h5
# 896/896 [==============================] - 708s 791ms/step - loss: 0.9175 - accuracy: 0.6747 - top5_acc: 0.9922 - macro_f1score: 0.5280 - val_loss: 1.1087 - val_accuracy: 0.6099 - val_top5_acc: 0.9860 - val_macro_f1score: 0.4486
# Learning rate:  0.001
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 16/70
# 896/896 [==============================] - ETA: 0s - loss: 0.8923 - accuracy: 0.6865 - top5_acc: 0.9927 - macro_f1score: 0.5398
# Epoch 00016: val_loss improved from 1.10867 to 1.08377, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/SE_Xception/016.h5
#
# Epoch 00016: val_accuracy improved from 0.60993 to 0.61244, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/SE_Xception/016.h5
# 896/896 [==============================] - 711s 793ms/step - loss: 0.8923 - accuracy: 0.6865 - top5_acc: 0.9927 - macro_f1score: 0.5398 - val_loss: 1.0838 - val_accuracy: 0.6124 - val_top5_acc: 0.9880 - val_macro_f1score: 0.4558
# Learning rate:  0.001
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 17/70
# 896/896 [==============================] - ETA: 0s - loss: 0.8665 - accuracy: 0.6965 - top5_acc: 0.9932 - macro_f1score: 0.5590
# Epoch 00017: val_loss did not improve from 1.08377
#
# Epoch 00017: val_accuracy improved from 0.61244 to 0.63477, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/SE_Xception/017.h5
# 896/896 [==============================] - 707s 789ms/step - loss: 0.8665 - accuracy: 0.6965 - top5_acc: 0.9932 - macro_f1score: 0.5590 - val_loss: 1.1070 - val_accuracy: 0.6348 - val_top5_acc: 0.9858 - val_macro_f1score: 0.5076
# Learning rate:  0.001
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 18/70
# 896/896 [==============================] - ETA: 0s - loss: 0.8460 - accuracy: 0.7045 - top5_acc: 0.9940 - macro_f1score: 0.5686
# Epoch 00018: val_loss did not improve from 1.08377
#
# Epoch 00018: val_accuracy did not improve from 0.63477
# 896/896 [==============================] - 707s 789ms/step - loss: 0.8460 - accuracy: 0.7045 - top5_acc: 0.9940 - macro_f1score: 0.5686 - val_loss: 1.2074 - val_accuracy: 0.5890 - val_top5_acc: 0.9819 - val_macro_f1score: 0.4570
# Learning rate:  0.001
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 19/70
# 896/896 [==============================] - ETA: 0s - loss: 0.8284 - accuracy: 0.7132 - top5_acc: 0.9948 - macro_f1score: 0.5782
# Epoch 00019: val_loss did not improve from 1.08377
#
# Epoch 00019: val_accuracy improved from 0.63477 to 0.64146, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/SE_Xception/019.h5
# 896/896 [==============================] - 708s 790ms/step - loss: 0.8284 - accuracy: 0.7132 - top5_acc: 0.9948 - macro_f1score: 0.5782 - val_loss: 1.0981 - val_accuracy: 0.6415 - val_top5_acc: 0.9886 - val_macro_f1score: 0.5086
# Learning rate:  0.001
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 20/70
# 896/896 [==============================] - ETA: 0s - loss: 0.8031 - accuracy: 0.7199 - top5_acc: 0.9949 - macro_f1score: 0.5914
# Epoch 00020: val_loss did not improve from 1.08377
#
# Epoch 00020: val_accuracy did not improve from 0.64146
# 896/896 [==============================] - 706s 788ms/step - loss: 0.8031 - accuracy: 0.7199 - top5_acc: 0.9949 - macro_f1score: 0.5914 - val_loss: 1.1269 - val_accuracy: 0.6166 - val_top5_acc: 0.9830 - val_macro_f1score: 0.4642
# Learning rate:  0.001
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 21/70
# 896/896 [==============================] - ETA: 0s - loss: 0.7854 - accuracy: 0.7295 - top5_acc: 0.9960 - macro_f1score: 0.6067
# Epoch 00021: val_loss did not improve from 1.08377
#
# Epoch 00021: val_accuracy did not improve from 0.64146
# 896/896 [==============================] - 708s 790ms/step - loss: 0.7854 - accuracy: 0.7295 - top5_acc: 0.9960 - macro_f1score: 0.6067 - val_loss: 1.3358 - val_accuracy: 0.5751 - val_top5_acc: 0.9788 - val_macro_f1score: 0.4703
# Learning rate:  0.001
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 22/70
# 896/896 [==============================] - ETA: 0s - loss: 0.7667 - accuracy: 0.7386 - top5_acc: 0.9964 - macro_f1score: 0.6139
# Epoch 00022: val_loss did not improve from 1.08377
#
# Epoch 00022: val_accuracy did not improve from 0.64146
# 896/896 [==============================] - 706s 788ms/step - loss: 0.7667 - accuracy: 0.7386 - top5_acc: 0.9964 - macro_f1score: 0.6139 - val_loss: 1.1099 - val_accuracy: 0.6295 - val_top5_acc: 0.9869 - val_macro_f1score: 0.4980
# Learning rate:  0.001
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 23/70
# 896/896 [==============================] - ETA: 0s - loss: 0.7479 - accuracy: 0.7457 - top5_acc: 0.9962 - macro_f1score: 0.6242
# Epoch 00023: val_loss did not improve from 1.08377
#
# Epoch 00023: val_accuracy improved from 0.64146 to 0.64397, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/SE_Xception/023.h5
# 896/896 [==============================] - 708s 791ms/step - loss: 0.7479 - accuracy: 0.7457 - top5_acc: 0.9962 - macro_f1score: 0.6242 - val_loss: 1.0990 - val_accuracy: 0.6440 - val_top5_acc: 0.9858 - val_macro_f1score: 0.5310
# Learning rate:  0.001
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 24/70
# 896/896 [==============================] - ETA: 0s - loss: 0.7271 - accuracy: 0.7548 - top5_acc: 0.9970 - macro_f1score: 0.6348
# Epoch 00024: val_loss did not improve from 1.08377
#
# Epoch 00024: val_accuracy improved from 0.64397 to 0.64453, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/SE_Xception/024.h5
# 896/896 [==============================] - 708s 790ms/step - loss: 0.7271 - accuracy: 0.7548 - top5_acc: 0.9970 - macro_f1score: 0.6348 - val_loss: 1.1436 - val_accuracy: 0.6445 - val_top5_acc: 0.9844 - val_macro_f1score: 0.5069
# Learning rate:  0.001
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 25/70
# 896/896 [==============================] - ETA: 0s - loss: 0.7065 - accuracy: 0.7642 - top5_acc: 0.9971 - macro_f1score: 0.6452
# Epoch 00025: val_loss did not improve from 1.08377
#
# Epoch 00025: val_accuracy improved from 0.64453 to 0.65792, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/SE_Xception/025.h5
# 896/896 [==============================] - 709s 791ms/step - loss: 0.7065 - accuracy: 0.7642 - top5_acc: 0.9971 - macro_f1score: 0.6452 - val_loss: 1.1028 - val_accuracy: 0.6579 - val_top5_acc: 0.9872 - val_macro_f1score: 0.5398
# Learning rate:  0.001
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 26/70
# 896/896 [==============================] - ETA: 0s - loss: 0.6852 - accuracy: 0.7726 - top5_acc: 0.9977 - macro_f1score: 0.6606
# Epoch 00026: val_loss did not improve from 1.08377
#
# Epoch 00026: val_accuracy did not improve from 0.65792
# 896/896 [==============================] - 707s 790ms/step - loss: 0.6852 - accuracy: 0.7726 - top5_acc: 0.9977 - macro_f1score: 0.6606 - val_loss: 1.0919 - val_accuracy: 0.6479 - val_top5_acc: 0.9891 - val_macro_f1score: 0.5147
# Learning rate:  0.001
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 27/70
# 896/896 [==============================] - ETA: 0s - loss: 0.6661 - accuracy: 0.7798 - top5_acc: 0.9981 - macro_f1score: 0.6691
# Epoch 00027: val_loss did not improve from 1.08377
#
# Epoch 00027: val_accuracy did not improve from 0.65792
# 896/896 [==============================] - 709s 792ms/step - loss: 0.6661 - accuracy: 0.7798 - top5_acc: 0.9981 - macro_f1score: 0.6691 - val_loss: 1.1308 - val_accuracy: 0.6434 - val_top5_acc: 0.9880 - val_macro_f1score: 0.5316
# Learning rate:  0.001
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 28/70
# 896/896 [==============================] - ETA: 0s - loss: 0.6542 - accuracy: 0.7854 - top5_acc: 0.9974 - macro_f1score: 0.6747
# Epoch 00028: val_loss did not improve from 1.08377
#
# Epoch 00028: val_accuracy did not improve from 0.65792
# 896/896 [==============================] - 710s 792ms/step - loss: 0.6542 - accuracy: 0.7854 - top5_acc: 0.9974 - macro_f1score: 0.6747 - val_loss: 1.1927 - val_accuracy: 0.6445 - val_top5_acc: 0.9860 - val_macro_f1score: 0.5174
# Learning rate:  0.001
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 29/70
# 896/896 [==============================] - ETA: 0s - loss: 0.6349 - accuracy: 0.7950 - top5_acc: 0.9981 - macro_f1score: 0.6861
# Epoch 00029: val_loss did not improve from 1.08377
#
# Epoch 00029: val_accuracy did not improve from 0.65792
# 896/896 [==============================] - 708s 791ms/step - loss: 0.6349 - accuracy: 0.7950 - top5_acc: 0.9981 - macro_f1score: 0.6861 - val_loss: 1.1612 - val_accuracy: 0.6479 - val_top5_acc: 0.9858 - val_macro_f1score: 0.5400
# Learning rate:  0.001
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 30/70
# 896/896 [==============================] - ETA: 0s - loss: 0.6137 - accuracy: 0.8030 - top5_acc: 0.9986 - macro_f1score: 0.6956
# Epoch 00030: val_loss did not improve from 1.08377
#
# Epoch 00030: val_accuracy did not improve from 0.65792
# 896/896 [==============================] - 709s 791ms/step - loss: 0.6137 - accuracy: 0.8030 - top5_acc: 0.9986 - macro_f1score: 0.6956 - val_loss: 1.5622 - val_accuracy: 0.5862 - val_top5_acc: 0.9847 - val_macro_f1score: 0.4875
# Learning rate:  0.0001
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 31/70
# 896/896 [==============================] - ETA: 0s - loss: 0.4873 - accuracy: 0.8510 - top5_acc: 0.9993 - macro_f1score: 0.7508
# Epoch 00031: val_loss did not improve from 1.08377
#
# Epoch 00031: val_accuracy improved from 0.65792 to 0.67606, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/SE_Xception/031.h5
# 896/896 [==============================] - 710s 792ms/step - loss: 0.4873 - accuracy: 0.8510 - top5_acc: 0.9993 - macro_f1score: 0.7508 - val_loss: 1.2293 - val_accuracy: 0.6761 - val_top5_acc: 0.9886 - val_macro_f1score: 0.5778
# Learning rate:  0.0001
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 32/70
# 896/896 [==============================] - ETA: 0s - loss: 0.4340 - accuracy: 0.8705 - top5_acc: 0.9995 - macro_f1score: 0.7715
# Epoch 00032: val_loss did not improve from 1.08377
#
# Epoch 00032: val_accuracy improved from 0.67606 to 0.67690, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/SE_Xception/032.h5
# 896/896 [==============================] - 719s 803ms/step - loss: 0.4340 - accuracy: 0.8705 - top5_acc: 0.9995 - macro_f1score: 0.7715 - val_loss: 1.2634 - val_accuracy: 0.6769 - val_top5_acc: 0.9888 - val_macro_f1score: 0.5727
# Learning rate:  0.0001
#
# Epoch 00033: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 33/70
# 896/896 [==============================] - ETA: 0s - loss: 0.4077 - accuracy: 0.8798 - top5_acc: 0.9995 - macro_f1score: 0.7810
# Epoch 00033: val_loss did not improve from 1.08377
#
# Epoch 00033: val_accuracy improved from 0.67690 to 0.67746, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/SE_Xception/033.h5
# 896/896 [==============================] - 727s 811ms/step - loss: 0.4077 - accuracy: 0.8798 - top5_acc: 0.9995 - macro_f1score: 0.7810 - val_loss: 1.2890 - val_accuracy: 0.6775 - val_top5_acc: 0.9891 - val_macro_f1score: 0.5753
# Learning rate:  0.0001
#
# Epoch 00034: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 34/70
# 896/896 [==============================] - ETA: 0s - loss: 0.3924 - accuracy: 0.8839 - top5_acc: 0.9997 - macro_f1score: 0.7864
# Epoch 00034: val_loss did not improve from 1.08377
#
# Epoch 00034: val_accuracy did not improve from 0.67746
# 896/896 [==============================] - 743s 830ms/step - loss: 0.3924 - accuracy: 0.8839 - top5_acc: 0.9997 - macro_f1score: 0.7864 - val_loss: 1.3167 - val_accuracy: 0.6722 - val_top5_acc: 0.9888 - val_macro_f1score: 0.5825
# Learning rate:  0.0001
#
# Epoch 00035: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 35/70
# 896/896 [==============================] - ETA: 0s - loss: 0.3761 - accuracy: 0.8900 - top5_acc: 0.9996 - macro_f1score: 0.7942
# Epoch 00035: val_loss did not improve from 1.08377
#
# Epoch 00035: val_accuracy improved from 0.67746 to 0.67969, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/SE_Xception/035.h5
# 896/896 [==============================] - 732s 817ms/step - loss: 0.3761 - accuracy: 0.8900 - top5_acc: 0.9996 - macro_f1score: 0.7942 - val_loss: 1.3722 - val_accuracy: 0.6797 - val_top5_acc: 0.9877 - val_macro_f1score: 0.5895
# Learning rate:  0.0001
#
# Epoch 00036: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 36/70
# 896/896 [==============================] - ETA: 0s - loss: 0.3619 - accuracy: 0.8959 - top5_acc: 0.9998 - macro_f1score: 0.7994
# Epoch 00036: val_loss did not improve from 1.08377
#
# Epoch 00036: val_accuracy did not improve from 0.67969
# 896/896 [==============================] - 724s 808ms/step - loss: 0.3619 - accuracy: 0.8959 - top5_acc: 0.9998 - macro_f1score: 0.7994 - val_loss: 1.3619 - val_accuracy: 0.6761 - val_top5_acc: 0.9891 - val_macro_f1score: 0.5783
# Learning rate:  0.0001
#
# Epoch 00037: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 37/70
# 896/896 [==============================] - ETA: 0s - loss: 0.3531 - accuracy: 0.9005 - top5_acc: 0.9998 - macro_f1score: 0.8038
# Epoch 00037: val_loss did not improve from 1.08377
#
# Epoch 00037: val_accuracy did not improve from 0.67969
# 896/896 [==============================] - 715s 798ms/step - loss: 0.3531 - accuracy: 0.9005 - top5_acc: 0.9998 - macro_f1score: 0.8038 - val_loss: 1.3853 - val_accuracy: 0.6766 - val_top5_acc: 0.9874 - val_macro_f1score: 0.5757
# Learning rate:  0.0001
#
# Epoch 00038: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 38/70
# 896/896 [==============================] - ETA: 0s - loss: 0.3369 - accuracy: 0.9056 - top5_acc: 1.0000 - macro_f1score: 0.8091
# Epoch 00038: val_loss did not improve from 1.08377
#
# Epoch 00038: val_accuracy did not improve from 0.67969
# 896/896 [==============================] - 708s 790ms/step - loss: 0.3369 - accuracy: 0.9056 - top5_acc: 1.0000 - macro_f1score: 0.8091 - val_loss: 1.4173 - val_accuracy: 0.6677 - val_top5_acc: 0.9880 - val_macro_f1score: 0.5650
# Learning rate:  0.0001
#
# Epoch 00039: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 39/70
# 896/896 [==============================] - ETA: 0s - loss: 0.3345 - accuracy: 0.9062 - top5_acc: 0.9999 - macro_f1score: 0.8111
# Epoch 00039: val_loss did not improve from 1.08377
#
# Epoch 00039: val_accuracy did not improve from 0.67969
# 896/896 [==============================] - 708s 790ms/step - loss: 0.3345 - accuracy: 0.9062 - top5_acc: 0.9999 - macro_f1score: 0.8111 - val_loss: 1.4607 - val_accuracy: 0.6733 - val_top5_acc: 0.9886 - val_macro_f1score: 0.5773
# Learning rate:  0.0001
#
# Epoch 00040: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 40/70
# 896/896 [==============================] - ETA: 0s - loss: 0.3251 - accuracy: 0.9101 - top5_acc: 0.9997 - macro_f1score: 0.8117
# Epoch 00040: val_loss did not improve from 1.08377
#
# Epoch 00040: val_accuracy did not improve from 0.67969
# 896/896 [==============================] - 707s 789ms/step - loss: 0.3251 - accuracy: 0.9101 - top5_acc: 0.9997 - macro_f1score: 0.8117 - val_loss: 1.4566 - val_accuracy: 0.6747 - val_top5_acc: 0.9902 - val_macro_f1score: 0.5669
# Learning rate:  0.0001
#
# Epoch 00041: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 41/70
# 896/896 [==============================] - ETA: 0s - loss: 0.3171 - accuracy: 0.9121 - top5_acc: 0.9999 - macro_f1score: 0.8167
# Epoch 00041: val_loss did not improve from 1.08377
#
# Epoch 00041: val_accuracy did not improve from 0.67969
# 896/896 [==============================] - 707s 789ms/step - loss: 0.3171 - accuracy: 0.9121 - top5_acc: 0.9999 - macro_f1score: 0.8167 - val_loss: 1.4657 - val_accuracy: 0.6761 - val_top5_acc: 0.9894 - val_macro_f1score: 0.5785
# Learning rate:  0.0001
#
# Epoch 00042: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 42/70
# 896/896 [==============================] - ETA: 0s - loss: 0.3097 - accuracy: 0.9139 - top5_acc: 0.9999 - macro_f1score: 0.8180
# Epoch 00042: val_loss did not improve from 1.08377
#
# Epoch 00042: val_accuracy did not improve from 0.67969
# 896/896 [==============================] - 708s 790ms/step - loss: 0.3097 - accuracy: 0.9139 - top5_acc: 0.9999 - macro_f1score: 0.8180 - val_loss: 1.4880 - val_accuracy: 0.6741 - val_top5_acc: 0.9897 - val_macro_f1score: 0.5778
# Learning rate:  0.0001
#
# Epoch 00043: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 43/70
# 896/896 [==============================] - ETA: 0s - loss: 0.3024 - accuracy: 0.9177 - top5_acc: 0.9999 - macro_f1score: 0.8216
# Epoch 00043: val_loss did not improve from 1.08377
#
# Epoch 00043: val_accuracy did not improve from 0.67969
# 896/896 [==============================] - 708s 790ms/step - loss: 0.3024 - accuracy: 0.9177 - top5_acc: 0.9999 - macro_f1score: 0.8216 - val_loss: 1.5182 - val_accuracy: 0.6789 - val_top5_acc: 0.9891 - val_macro_f1score: 0.5834
# Learning rate:  0.0001
#
# Epoch 00044: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 44/70
# 896/896 [==============================] - ETA: 0s - loss: 0.2930 - accuracy: 0.9205 - top5_acc: 0.9999 - macro_f1score: 0.8236
# Epoch 00044: val_loss did not improve from 1.08377
#
# Epoch 00044: val_accuracy did not improve from 0.67969
# 896/896 [==============================] - 711s 793ms/step - loss: 0.2930 - accuracy: 0.9205 - top5_acc: 0.9999 - macro_f1score: 0.8236 - val_loss: 1.4675 - val_accuracy: 0.6794 - val_top5_acc: 0.9900 - val_macro_f1score: 0.5819
# Learning rate:  0.0001
#
# Epoch 00045: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 45/70
# 896/896 [==============================] - ETA: 0s - loss: 0.2867 - accuracy: 0.9240 - top5_acc: 0.9999 - macro_f1score: 0.8295
# Epoch 00045: val_loss did not improve from 1.08377
#
# Epoch 00045: val_accuracy did not improve from 0.67969
# 896/896 [==============================] - 707s 790ms/step - loss: 0.2867 - accuracy: 0.9240 - top5_acc: 0.9999 - macro_f1score: 0.8295 - val_loss: 1.5341 - val_accuracy: 0.6747 - val_top5_acc: 0.9905 - val_macro_f1score: 0.5763
# Learning rate:  0.0001
#
# Epoch 00046: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 46/70
# 896/896 [==============================] - ETA: 0s - loss: 0.2751 - accuracy: 0.9285 - top5_acc: 0.9999 - macro_f1score: 0.8318
# Epoch 00046: val_loss did not improve from 1.08377
#
# Epoch 00046: val_accuracy did not improve from 0.67969
# 896/896 [==============================] - 706s 788ms/step - loss: 0.2751 - accuracy: 0.9285 - top5_acc: 0.9999 - macro_f1score: 0.8318 - val_loss: 1.5619 - val_accuracy: 0.6772 - val_top5_acc: 0.9897 - val_macro_f1score: 0.5846
# Learning rate:  0.0001
#
# Epoch 00047: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 47/70
# 896/896 [==============================] - ETA: 0s - loss: 0.2710 - accuracy: 0.9291 - top5_acc: 1.0000 - macro_f1score: 0.8318
# Epoch 00047: val_loss did not improve from 1.08377
#
# Epoch 00047: val_accuracy did not improve from 0.67969
# 896/896 [==============================] - 707s 789ms/step - loss: 0.2710 - accuracy: 0.9291 - top5_acc: 1.0000 - macro_f1score: 0.8318 - val_loss: 1.5696 - val_accuracy: 0.6735 - val_top5_acc: 0.9900 - val_macro_f1score: 0.5780
# Learning rate:  0.0001
#
# Epoch 00048: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 48/70
# 896/896 [==============================] - ETA: 0s - loss: 0.2696 - accuracy: 0.9314 - top5_acc: 0.9999 - macro_f1score: 0.8343
# Epoch 00048: val_loss did not improve from 1.08377
#
# Epoch 00048: val_accuracy improved from 0.67969 to 0.67997, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/SE_Xception/048.h5
# 896/896 [==============================] - 708s 790ms/step - loss: 0.2696 - accuracy: 0.9314 - top5_acc: 0.9999 - macro_f1score: 0.8343 - val_loss: 1.5706 - val_accuracy: 0.6800 - val_top5_acc: 0.9900 - val_macro_f1score: 0.5785
# Learning rate:  0.0001
#
# Epoch 00049: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 49/70
# 896/896 [==============================] - ETA: 0s - loss: 0.2599 - accuracy: 0.9328 - top5_acc: 1.0000 - macro_f1score: 0.8363
# Epoch 00049: val_loss did not improve from 1.08377
#
# Epoch 00049: val_accuracy improved from 0.67997 to 0.68052, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/SE_Xception/049.h5
# 896/896 [==============================] - 708s 790ms/step - loss: 0.2599 - accuracy: 0.9328 - top5_acc: 1.0000 - macro_f1score: 0.8363 - val_loss: 1.6082 - val_accuracy: 0.6805 - val_top5_acc: 0.9869 - val_macro_f1score: 0.5817
# Learning rate:  0.0001
#
# Epoch 00050: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 50/70
# 896/896 [==============================] - ETA: 0s - loss: 0.2593 - accuracy: 0.9330 - top5_acc: 0.9999 - macro_f1score: 0.8379
# Epoch 00050: val_loss did not improve from 1.08377
#
# Epoch 00050: val_accuracy did not improve from 0.68052
# 896/896 [==============================] - 706s 788ms/step - loss: 0.2593 - accuracy: 0.9330 - top5_acc: 0.9999 - macro_f1score: 0.8379 - val_loss: 1.6018 - val_accuracy: 0.6713 - val_top5_acc: 0.9905 - val_macro_f1score: 0.5720
# Learning rate:  0.0001
#
# Epoch 00051: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 51/70
# 896/896 [==============================] - ETA: 0s - loss: 0.2486 - accuracy: 0.9374 - top5_acc: 1.0000 - macro_f1score: 0.8433
# Epoch 00051: val_loss did not improve from 1.08377
#
# Epoch 00051: val_accuracy did not improve from 0.68052
# 896/896 [==============================] - 706s 788ms/step - loss: 0.2486 - accuracy: 0.9374 - top5_acc: 1.0000 - macro_f1score: 0.8433 - val_loss: 1.6542 - val_accuracy: 0.6775 - val_top5_acc: 0.9900 - val_macro_f1score: 0.5831
# Learning rate:  0.0001
#
# Epoch 00052: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 52/70
# 896/896 [==============================] - ETA: 0s - loss: 0.2461 - accuracy: 0.9370 - top5_acc: 1.0000 - macro_f1score: 0.8425
# Epoch 00052: val_loss did not improve from 1.08377
#
# Epoch 00052: val_accuracy did not improve from 0.68052
# 896/896 [==============================] - 707s 789ms/step - loss: 0.2461 - accuracy: 0.9370 - top5_acc: 1.0000 - macro_f1score: 0.8425 - val_loss: 1.6543 - val_accuracy: 0.6766 - val_top5_acc: 0.9897 - val_macro_f1score: 0.5850
# Learning rate:  0.0001
#
# Epoch 00053: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 53/70
# 896/896 [==============================] - ETA: 0s - loss: 0.2429 - accuracy: 0.9399 - top5_acc: 1.0000 - macro_f1score: 0.8460
# Epoch 00053: val_loss did not improve from 1.08377
#
# Epoch 00053: val_accuracy did not improve from 0.68052
# 896/896 [==============================] - 706s 788ms/step - loss: 0.2429 - accuracy: 0.9399 - top5_acc: 1.0000 - macro_f1score: 0.8460 - val_loss: 1.6149 - val_accuracy: 0.6766 - val_top5_acc: 0.9894 - val_macro_f1score: 0.5759
# Learning rate:  0.0001
#
# Epoch 00054: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 54/70
# 896/896 [==============================] - ETA: 0s - loss: 0.2382 - accuracy: 0.9411 - top5_acc: 1.0000 - macro_f1score: 0.8455
# Epoch 00054: val_loss did not improve from 1.08377
#
# Epoch 00054: val_accuracy improved from 0.68052 to 0.68415, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/SE_Xception/054.h5
# 896/896 [==============================] - 708s 790ms/step - loss: 0.2382 - accuracy: 0.9411 - top5_acc: 1.0000 - macro_f1score: 0.8455 - val_loss: 1.6918 - val_accuracy: 0.6842 - val_top5_acc: 0.9872 - val_macro_f1score: 0.5899
# Learning rate:  0.0001
#
# Epoch 00055: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 55/70
# 896/896 [==============================] - ETA: 0s - loss: 0.2345 - accuracy: 0.9424 - top5_acc: 1.0000 - macro_f1score: 0.8462
# Epoch 00055: val_loss did not improve from 1.08377
#
# Epoch 00055: val_accuracy did not improve from 0.68415
# 896/896 [==============================] - 706s 788ms/step - loss: 0.2345 - accuracy: 0.9424 - top5_acc: 1.0000 - macro_f1score: 0.8462 - val_loss: 1.6741 - val_accuracy: 0.6733 - val_top5_acc: 0.9888 - val_macro_f1score: 0.5814
# Learning rate:  0.0001
#
# Epoch 00056: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 56/70
# 896/896 [==============================] - ETA: 0s - loss: 0.2240 - accuracy: 0.9467 - top5_acc: 0.9999 - macro_f1score: 0.8506
# Epoch 00056: val_loss did not improve from 1.08377
#
# Epoch 00056: val_accuracy did not improve from 0.68415
# 896/896 [==============================] - 706s 788ms/step - loss: 0.2240 - accuracy: 0.9467 - top5_acc: 0.9999 - macro_f1score: 0.8506 - val_loss: 1.7326 - val_accuracy: 0.6702 - val_top5_acc: 0.9877 - val_macro_f1score: 0.5736
# Learning rate:  0.0001
#
# Epoch 00057: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 57/70
# 896/896 [==============================] - ETA: 0s - loss: 0.2247 - accuracy: 0.9452 - top5_acc: 1.0000 - macro_f1score: 0.8530
# Epoch 00057: val_loss did not improve from 1.08377
#
# Epoch 00057: val_accuracy did not improve from 0.68415
# 896/896 [==============================] - 707s 789ms/step - loss: 0.2247 - accuracy: 0.9452 - top5_acc: 1.0000 - macro_f1score: 0.8530 - val_loss: 1.7395 - val_accuracy: 0.6710 - val_top5_acc: 0.9883 - val_macro_f1score: 0.5758
# Learning rate:  0.0001
#
# Epoch 00058: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 58/70
# 896/896 [==============================] - ETA: 0s - loss: 0.2208 - accuracy: 0.9484 - top5_acc: 0.9999 - macro_f1score: 0.8529
# Epoch 00058: val_loss did not improve from 1.08377
#
# Epoch 00058: val_accuracy did not improve from 0.68415
# 896/896 [==============================] - 706s 788ms/step - loss: 0.2208 - accuracy: 0.9484 - top5_acc: 0.9999 - macro_f1score: 0.8529 - val_loss: 1.7293 - val_accuracy: 0.6724 - val_top5_acc: 0.9888 - val_macro_f1score: 0.5721
# Learning rate:  0.0001
#
# Epoch 00059: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 59/70
# 896/896 [==============================] - ETA: 0s - loss: 0.2166 - accuracy: 0.9486 - top5_acc: 1.0000 - macro_f1score: 0.8528
# Epoch 00059: val_loss did not improve from 1.08377
#
# Epoch 00059: val_accuracy did not improve from 0.68415
# 896/896 [==============================] - 706s 788ms/step - loss: 0.2166 - accuracy: 0.9486 - top5_acc: 1.0000 - macro_f1score: 0.8528 - val_loss: 1.7739 - val_accuracy: 0.6758 - val_top5_acc: 0.9883 - val_macro_f1score: 0.5838
# Learning rate:  0.0001
#
# Epoch 00060: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 60/70
# 896/896 [==============================] - ETA: 0s - loss: 0.2162 - accuracy: 0.9487 - top5_acc: 0.9999 - macro_f1score: 0.8523
# Epoch 00060: val_loss did not improve from 1.08377
#
# Epoch 00060: val_accuracy did not improve from 0.68415
# 896/896 [==============================] - 706s 788ms/step - loss: 0.2162 - accuracy: 0.9487 - top5_acc: 0.9999 - macro_f1score: 0.8523 - val_loss: 1.7705 - val_accuracy: 0.6747 - val_top5_acc: 0.9872 - val_macro_f1score: 0.5838
# Learning rate:  1e-05
#
# Epoch 00061: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 61/70
# 896/896 [==============================] - ETA: 0s - loss: 0.2079 - accuracy: 0.9533 - top5_acc: 1.0000 - macro_f1score: 0.8575
# Epoch 00061: val_loss did not improve from 1.08377
#
# Epoch 00061: val_accuracy did not improve from 0.68415
# 896/896 [==============================] - 707s 789ms/step - loss: 0.2079 - accuracy: 0.9533 - top5_acc: 1.0000 - macro_f1score: 0.8575 - val_loss: 1.7545 - val_accuracy: 0.6749 - val_top5_acc: 0.9874 - val_macro_f1score: 0.5797
# Learning rate:  1e-05
#
# Epoch 00062: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 62/70
# 896/896 [==============================] - ETA: 0s - loss: 0.1981 - accuracy: 0.9558 - top5_acc: 1.0000 - macro_f1score: 0.8584
# Epoch 00062: val_loss did not improve from 1.08377
#
# Epoch 00062: val_accuracy did not improve from 0.68415
# 896/896 [==============================] - 707s 789ms/step - loss: 0.1981 - accuracy: 0.9558 - top5_acc: 1.0000 - macro_f1score: 0.8584 - val_loss: 1.7817 - val_accuracy: 0.6755 - val_top5_acc: 0.9874 - val_macro_f1score: 0.5767
# Learning rate:  1e-05
#
# Epoch 00063: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 63/70
# 896/896 [==============================] - ETA: 0s - loss: 0.1966 - accuracy: 0.9552 - top5_acc: 1.0000 - macro_f1score: 0.8616
# Epoch 00063: val_loss did not improve from 1.08377
#
# Epoch 00063: val_accuracy did not improve from 0.68415
# 896/896 [==============================] - 707s 789ms/step - loss: 0.1966 - accuracy: 0.9552 - top5_acc: 1.0000 - macro_f1score: 0.8616 - val_loss: 1.7895 - val_accuracy: 0.6752 - val_top5_acc: 0.9880 - val_macro_f1score: 0.5795
# Learning rate:  1e-05
#
# Epoch 00064: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 64/70
# 896/896 [==============================] - ETA: 0s - loss: 0.1961 - accuracy: 0.9574 - top5_acc: 1.0000 - macro_f1score: 0.8618
# Epoch 00064: val_loss did not improve from 1.08377
#
# Epoch 00064: val_accuracy did not improve from 0.68415
# 896/896 [==============================] - 707s 789ms/step - loss: 0.1961 - accuracy: 0.9574 - top5_acc: 1.0000 - macro_f1score: 0.8618 - val_loss: 1.7991 - val_accuracy: 0.6758 - val_top5_acc: 0.9877 - val_macro_f1score: 0.5835
# Learning rate:  1e-05
#
# Epoch 00065: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 65/70
# 896/896 [==============================] - ETA: 0s - loss: 0.1962 - accuracy: 0.9565 - top5_acc: 1.0000 - macro_f1score: 0.8602
# Epoch 00065: val_loss did not improve from 1.08377
#
# Epoch 00065: val_accuracy did not improve from 0.68415
# 896/896 [==============================] - 708s 790ms/step - loss: 0.1962 - accuracy: 0.9565 - top5_acc: 1.0000 - macro_f1score: 0.8602 - val_loss: 1.8018 - val_accuracy: 0.6797 - val_top5_acc: 0.9874 - val_macro_f1score: 0.5829
# Learning rate:  1e-05
#
# Epoch 00066: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 66/70
# 896/896 [==============================] - ETA: 0s - loss: 0.1900 - accuracy: 0.9591 - top5_acc: 0.9999 - macro_f1score: 0.8639
# Epoch 00066: val_loss did not improve from 1.08377
#
# Epoch 00066: val_accuracy did not improve from 0.68415
# 896/896 [==============================] - 710s 792ms/step - loss: 0.1900 - accuracy: 0.9591 - top5_acc: 0.9999 - macro_f1score: 0.8639 - val_loss: 1.8310 - val_accuracy: 0.6772 - val_top5_acc: 0.9872 - val_macro_f1score: 0.5860
# Learning rate:  1e-05
#
# Epoch 00067: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 67/70
# 896/896 [==============================] - ETA: 0s - loss: 0.1917 - accuracy: 0.9569 - top5_acc: 1.0000 - macro_f1score: 0.8638
# Epoch 00067: val_loss did not improve from 1.08377
#
# Epoch 00067: val_accuracy did not improve from 0.68415
# 896/896 [==============================] - 707s 789ms/step - loss: 0.1917 - accuracy: 0.9569 - top5_acc: 1.0000 - macro_f1score: 0.8638 - val_loss: 1.8297 - val_accuracy: 0.6775 - val_top5_acc: 0.9877 - val_macro_f1score: 0.5826
# Learning rate:  1e-05
#
# Epoch 00068: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 68/70
# 896/896 [==============================] - ETA: 0s - loss: 0.1888 - accuracy: 0.9590 - top5_acc: 1.0000 - macro_f1score: 0.8650
# Epoch 00068: val_loss did not improve from 1.08377
#
# Epoch 00068: val_accuracy did not improve from 0.68415
# 896/896 [==============================] - 707s 789ms/step - loss: 0.1888 - accuracy: 0.9590 - top5_acc: 1.0000 - macro_f1score: 0.8650 - val_loss: 1.8341 - val_accuracy: 0.6761 - val_top5_acc: 0.9872 - val_macro_f1score: 0.5801
# Learning rate:  1e-05
#
# Epoch 00069: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 69/70
# 896/896 [==============================] - ETA: 0s - loss: 0.1932 - accuracy: 0.9584 - top5_acc: 1.0000 - macro_f1score: 0.8627
# Epoch 00069: val_loss did not improve from 1.08377
#
# Epoch 00069: val_accuracy did not improve from 0.68415
# 896/896 [==============================] - 708s 790ms/step - loss: 0.1932 - accuracy: 0.9584 - top5_acc: 1.0000 - macro_f1score: 0.8627 - val_loss: 1.8373 - val_accuracy: 0.6747 - val_top5_acc: 0.9869 - val_macro_f1score: 0.5800
# Learning rate:  1e-05
#
# Epoch 00070: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 70/70
# 896/896 [==============================] - ETA: 0s - loss: 0.1901 - accuracy: 0.9586 - top5_acc: 0.9999 - macro_f1score: 0.8642
# Epoch 00070: val_loss did not improve from 1.08377
#
# Epoch 00070: val_accuracy did not improve from 0.68415
# 896/896 [==============================] - 707s 789ms/step - loss: 0.1901 - accuracy: 0.9586 - top5_acc: 0.9999 - macro_f1score: 0.8642 - val_loss: 1.8424 - val_accuracy: 0.6766 - val_top5_acc: 0.9874 - val_macro_f1score: 0.5874

# %% [markdown]
# ### 3) SE-Xception Evaluate

# %%
# 1. epoch=maximum
loss , acc, top5_acc, mf1 = model.evaluate(test_generator,steps=int(len(x_test)/batch_sizes))
print('[Test Loss: %.4f /  Test Top-1 Accuracy: %.4f / Test Top-5 Accuracy: %.4f / Test Macro f1: %.4f]\n' % (loss,acc,top5_acc,mf1))
# Out:
# 112/112 [==============================] - 1839s 16s/step - loss: 1.8786 - accuracy: 0.6747 - top5_acc: 0.9869 - macro_f1score: 0.5831
# [Test Loss: 1.8786 /  Test Top-1 Accuracy: 0.6747 / Test Top-5 Accuracy: 0.9869 / Test Macro f1: 0.5831]

# %%
loss=history.history['loss']
val_loss=history.history['val_loss']
acc=history.history['accuracy']
val_acc=history.history['val_accuracy']
top5_acc=history.history['top5_acc']
val_top5_acc=history.history['val_top5_acc']
f1=history.history['macro_f1score']
val_f1=history.history['val_macro_f1score']
epochs=range(1,len(acc)+1)

data = np.array([epochs,loss,val_loss,acc,val_acc,top5_acc,val_top5_acc,f1,val_f1]).T

# %%
# data save
# epochs, loss, val_loss, acc, val_acc, f1, val_f1

np.savetxt(os.path.join(dir,'train_valid_output',number,model.name+'.txt'),data)

# %%
# data import
data = np.loadtxt(os.path.join(dir,'train_valid_output',number,'SE_Xception.txt'))

# %%
epochs=data[:,0]
loss=data[:,1]
val_loss=data[:,2]
acc=data[:,3]
val_acc=data[:,4]
top5_acc=data[:,5]
val_top5_acc=data[:,6]

# %%
plt.plot(epochs[1:],acc[1:],'b',label='Training 1-Acc')
plt.plot(epochs[1:],val_acc[1:],'r',label='Validation 1-Acc')
plt.title('Training and Validation Top-1 Accuracy')
plt.legend()
plt.figure()

plt.plot(epochs[1:],top5_acc[1:],'b',label='Training 5-Acc')
plt.plot(epochs[1:],val_top5_acc[1:],'r',label='Validation 5-Acc')
plt.title('Training and Validation Top-5 Accuracy')
plt.legend()
plt.figure()

plt.plot(epochs[10:],loss[10:],'b',label='Training Loss')
plt.plot(epochs[10:],val_loss[10:],'r',label='Validation Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()

# %%
# 이 아래는 내가 인위적으로 살펴보고 싶은 epoch에 대해서 결과값 출력 / SE-Xception

# %%
# 참고 : https://github.com/OverLordGoldDragon/keras-adamw

import sys
sys.path.append('/content/drive/My Drive/Colab Notebooks/Paper')
import utils
import optimizers_v2
from utils import get_weight_decays, fill_dict_in_order
from utils import reset_seeds, K_eval
from optimizers_v2 import AdamW, NadamW, SGDW

# %%
# top-5 accuracy 출력
import functools
top5_acc = functools.partial(ks.metrics.top_k_categorical_accuracy, k=5)
top5_acc.__name__ = 'top5_acc'

# %%
model=load_model(os.path.join(dir,'model_output',number,'SE_Xception','031.h5'),custom_objects={"macro_f1score": macro_f1score,"top5_acc":top5_acc, "AdamW":AdamW})

# %%
# 2. epoch=?
loss , acc, mf1, wf1 = model.evaluate(test_generator,steps=int(len(x_test)/batch_sizes))
print('[Test Loss: %.4f /  Test Accuracy: %.4f / Test Macro f1: %.4f / Test Weighted f1: %.4f]\n' % (loss,acc,mf1,wf1))
# Out:
# 112/112 [==============================] - 518s 5s/step - loss: 1.2393 - accuracy: 0.6699 - top5_acc: 0.9874 - macro_f1score: 0.5596
# [Test Loss: 1.2393 /  Test Accuracy: 0.6699 / Test Macro f1: 0.9874 / Test Weighted f1: 0.5596]
