# %%
### 참고 : https://sike6054.github.io/blog/paper/fifth-post/
### SE block 코드 참고 : https://github.com/titu1994/keras-squeeze-excite-network/tree/master/keras_squeeze_excite_network

# %% [markdown]
# # [SE-Xception]

# %% [markdown]
# *KU LeeDongGyu*

# %% [markdown]
# ## Contents
# ---

# %% [markdown]
# 1. Data Preprocessing
# ```
# 1) Data Import
# 2) Data Augmentation
# ```
# 2. Support Functions & Almost Original SE-Xception
# ```
# 1) Support Functions
# 2) Almost Original SE-Xception
# 3) SE-Xception Evaluate
# ```

# %% [markdown]
# ### Install Packages

# %% [markdown]
# ### Module

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/My Drive/Colab Notebooks/Paper
# Out:
# /content/drive/My Drive/Colab Notebooks/Paper

# %%
from f1score import macro_f1score,weighted_f1score

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import cv2
import tensorflow as tf
from tensorflow import keras as ks
from tensorflow.keras import backend as K 
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, Input, Concatenate, ZeroPadding2D ,GlobalMaxPooling2D, Reshape , Lambda , Add, Multiply
from tensorflow.keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D, Activation, BatchNormalization, AveragePooling2D , ZeroPadding2D, SeparableConv2D , LeakyReLU
from tensorflow.keras.layers import add, concatenate, multiply
from tensorflow.keras.optimizers import Adam, RMSprop , SGD
from tensorflow.keras.callbacks import EarlyStopping , LearningRateScheduler, ModelCheckpoint, CSVLogger, Callback, ReduceLROnPlateau
from tensorflow.keras.regularizers import l1,l2,l1_l2
from tensorflow.keras.models import Model , load_model , Sequential
from tensorflow.keras.utils import plot_model , to_categorical, get_file
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
os.getcwd()
# Out:
# '/content/drive/My Drive/Colab Notebooks/Paper'

# %%
print(tf.__version__)
print(ks.__version__)
# Out:
# 2.3.0
# 2.4.0

# %%
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 6193203871746091220
# , name: "/device:XLA_CPU:0"
# device_type: "XLA_CPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 6995748061020907918
# physical_device_desc: "device: XLA_CPU device"
# , name: "/device:XLA_GPU:0"
# device_type: "XLA_GPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 8262514577936800695
# physical_device_desc: "device: XLA_GPU device"
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 15473775744
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 601750423835957160
# physical_device_desc: "device: 0, name: Tesla V100-SXM2-16GB, pci bus id: 0000:00:04.0, compute capability: 7.0"
# ]

# %%
# !cat /proc/cpuinfo
# Out:
# processor	: 0
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 85
# model name	: Intel(R) Xeon(R) CPU @ 2.00GHz
# stepping	: 3
# microcode	: 0x1
# cpu MHz		: 2000.180
# cache size	: 39424 KB
# physical id	: 0
# siblings	: 4
# core id		: 0
# cpu cores	: 2
# apicid		: 0
# initial apicid	: 0
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm mpx avx512f avx512dq rdseed adx smap clflushopt clwb avx512cd avx512bw avx512vl xsaveopt xsavec xgetbv1 xsaves arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs taa
# bogomips	: 4000.36
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 46 bits physical, 48 bits virtual
# power management:
#
# processor	: 1
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 85
# model name	: Intel(R) Xeon(R) CPU @ 2.00GHz
# stepping	: 3
# microcode	: 0x1
# cpu MHz		: 2000.180
# cache size	: 39424 KB
# physical id	: 0
# siblings	: 4
# core id		: 1
# cpu cores	: 2
# apicid		: 2
# initial apicid	: 2
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm mpx avx512f avx512dq rdseed adx smap clflushopt clwb avx512cd avx512bw avx512vl xsaveopt xsavec xgetbv1 xsaves arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs taa
# bogomips	: 4000.36
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 46 bits physical, 48 bits virtual
# power management:
#
# processor	: 2
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 85
# model name	: Intel(R) Xeon(R) CPU @ 2.00GHz
# stepping	: 3
# microcode	: 0x1
# cpu MHz		: 2000.180
# cache size	: 39424 KB
# physical id	: 0
# siblings	: 4
# core id		: 0
# cpu cores	: 2
# apicid		: 1
# initial apicid	: 1
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm mpx avx512f avx512dq rdseed adx smap clflushopt clwb avx512cd avx512bw avx512vl xsaveopt xsavec xgetbv1 xsaves arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs taa
# bogomips	: 4000.36
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 46 bits physical, 48 bits virtual
# power management:
#
# processor	: 3
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 85
# model name	: Intel(R) Xeon(R) CPU @ 2.00GHz
# stepping	: 3
# microcode	: 0x1
# cpu MHz		: 2000.180
# cache size	: 39424 KB
# physical id	: 0
# siblings	: 4
# core id		: 1
# cpu cores	: 2
# apicid		: 3
# initial apicid	: 3
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm mpx avx512f avx512dq rdseed adx smap clflushopt clwb avx512cd avx512bw avx512vl xsaveopt xsavec xgetbv1 xsaves arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs taa
# bogomips	: 4000.36
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 46 bits physical, 48 bits virtual
# power management:

# %% [markdown]
# ## 1. Data Preprocessing
# ---

# %% [markdown]
# ### 1) Data Import

# %%
# 바꿔서 살펴 볼 것들
# CALTECH, CIFAR100, FER, MIT
data_name = 'CIFAR100'
gan_type = 'No_GAN'
number = '1'
size = 299 # sizes after cropping
super_size = 330 # sizes before cropping 
input_sizes = (size,size,3)
batch_sizes = 32
weight_decay = 1e-6
epochs = 70

# %%
# 참고 : https://stackoverflow.com/questions/32419510/how-to-get-reproducible-results-in-keras/52897216#52897216
# setting the seed number for random number generation for reproducibility.

from numpy.random import seed
import random


if number=='1':
    seed_num = 200225
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)
elif number=='2':
    seed_num = 727
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)
elif number=='3':
    seed_num = 115
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)
elif number=='4':
    seed_num = 501
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)
elif number=='5':
    seed_num = 517
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)

# %%
# data import

if data_name=='FER' :
    x_train =  np.zeros(28698)
    x_valid = np.zeros(3589)
    x_test = np.zeros(3588)
    classes = 7 
    tr_center = [0.50793296, 0.50793296, 0.50793296]
elif data_name=='MIT':
    x_train = np.zeros(12466)
    x_valid = np.zeros(1564)
    x_test = np.zeros(1590)
    classes = 67 
    tr_center = [0.47916578, 0.42029615, 0.36046057]
elif data_name=='CALTECH':
    x_train = np.zeros(24510)
    x_valid = np.zeros(2980)
    x_test = np.zeros(3118)
    classes = 257
    tr_center = [0.51397761, 0.49525248, 0.46555727]
elif data_name=='CIFAR100':
    x_train = np.zeros(44923)
    x_valid = np.zeros(5077)
    x_test = np.zeros(10000)
    classes = 100
    tr_center = [0.53442983, 0.51355958, 0.46462564]

# %%
dir = os.path.join(os.getcwd(),data_name,gan_type)

# %% [markdown]
# ### 2) Data Augmentation

# %%
# 참고 : https://jkjung-avt.github.io/keras-image-cropping/

def random_crop(img, random_crop_size):
    # Note: image_data_format is 'channel_last'
    assert img.shape[2] == 3 # img.shape[2] 가 3(rgb)이 아니면 assertion error 발생
    height, width = img.shape[0], img.shape[1]
    dy, dx = random_crop_size
    x = np.random.randint(0, width - dx + 1)
    y = np.random.randint(0, height - dy + 1)
    return img[y:(y+dy), x:(x+dx), :]


def crop_generator(batches, crop_length):
    """Take as input a Keras ImageGen (Iterator) and generate random
    crops from the image batches generated by the original iterator.
    """
    while True:
        batch_x, batch_y = next(batches)
        batch_crops = np.zeros((batch_x.shape[0], crop_length, crop_length, 3))
        for i in range(batch_x.shape[0]):
            batch_crops[i] = random_crop(batch_x[i], (crop_length, crop_length))
        yield (batch_crops, batch_y)

# %%
from tensorflow.keras.preprocessing.image import img_to_array,load_img
import glob

# 데이터 전체에 대해 centering 진행함.

def read_cal_image(img_path): 
    x = img_to_array(load_img(img_path)) # x는 채널별 평균값
    y = x.shape[0] * x.shape[1]# y는 데이터별 픽셀 수 (비중)

    x = 1/255. * x # scaling하고, centering값을 뽑아냄.
    x = np.mean(x, axis=(0,1))
    
    return np.hstack([x,y])

def calculate_centered_mean(dataset_path,x_train=x_train):
    num = len(x_train)
    space = np.empty((num,4))
    i=0

    for p in glob.glob(os.path.join(dataset_path,'*/*.*')) :
        space[i] = read_cal_image(p)
        i += 1

    ratio = space[:,3] / np.sum(space[:,3])

    return np.average(space[:,0:3],axis=0,weights=ratio)


# 아래의 함수를 돌려서 나온 결과값을 중심화 값으로 설정.

# train_mean = calculate_centered_mean(os.path.join(dir,'data/train')).reshape((1,1,3))

# %%
datagen_tr = ImageDataGenerator(
    rescale=1/255.,
    horizontal_flip=True,
    featurewise_center=True,
    featurewise_std_normalization=False,
    rotation_range=10,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=[0.9,1.0],
    fill_mode = 'nearest')
datagen_val = ImageDataGenerator(rescale=1/255.,featurewise_center=True)
datagen_tes = ImageDataGenerator(rescale=1/255.,featurewise_center=True)

# 원래는 이 자리에 fit 매서드를 써야하지만, 그냥 내가 중심화함수를 만들고 적용함. 

# 중심화 설정
datagen_tr.mean = np.array(tr_center, dtype=np.float32).reshape((1,1,3)) # RGB
datagen_val.mean = np.array(tr_center, dtype=np.float32).reshape((1,1,3)) # RGB
datagen_tes.mean = np.array(tr_center, dtype=np.float32).reshape((1,1,3)) # RGB

# %%
train_batches = datagen_tr.flow_from_directory(directory=os.path.join(dir,'data/train'),target_size=(super_size,super_size),batch_size=batch_sizes,class_mode='categorical') # fer : 28698 / mit : 12466 / caltech : 24509 / cifar : 44923
train_generator= crop_generator(train_batches, size)
valid_generator = datagen_val.flow_from_directory(directory=os.path.join(dir,'data/valid'),target_size=(size,size),batch_size=batch_sizes,class_mode='categorical') # fer : 3589 / mit : 1564 / caltech : 2980 / cifar : 5077
test_generator = datagen_tes.flow_from_directory(directory=os.path.join(dir,'data/test'),target_size=(size,size),batch_size=batch_sizes,class_mode='categorical') # fer : 3588 / mit : 1590 / caltech : 3118 / cifar : 10000
# Out:
# Found 44923 images belonging to 100 classes.
# Found 5077 images belonging to 100 classes.
# Found 10000 images belonging to 100 classes.

# %% [markdown]
# ## 2. Support Functions & Almost Original SE-Xception
# ---

# %% [markdown]
# ### 1) Support Functions

# %%
# def lr_schedule(epoch):
#     init_lr = 1e-4
#     k = 0.04
#     lr = init_lr * np.exp(-k*epoch)
#     print('Learning rate: ', lr)
#     return lr

def lr_schedule(epoch):
    lr = 1e-3
    if epoch < 30:
        lr = lr
    elif epoch < 60:
        lr = lr * 0.1
    else:
        lr = lr * 0.01
    print('Learning rate: ', lr)
    return lr

# %%
def squeeze_excite_block(input, reduction_ratio=16, weight_decay=weight_decay):

    init = input
    channel_axis = -1
    filters = init.get_shape()[channel_axis]
    se_shape = (1, 1, filters)

    se = GlobalAveragePooling2D()(init)
    se = Reshape(se_shape)(se)
    se = Dense(filters // reduction_ratio, activation='relu', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay), use_bias=False)(se)
    se = Dense(filters, activation='sigmoid', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay), use_bias=False)(se)

    x = multiply([init, se])
    return x

# %% [markdown]
# ### 2) Almost Original SE-Xception

# %%
def SE_Xception(input_shape=None, classes=1000, reduction_ratio = 16, name = "SE_Xception", weight_decay = weight_decay):


    img_input = Input(shape=input_shape)


    x = Conv2D(32, (3, 3), strides=(2, 2), use_bias=False, kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay), name='block1_conv1')(img_input)
    x = BatchNormalization(name='block1_conv1_bn')(x)
    x = Activation('relu', name='block1_conv1_act')(x)
    x = Conv2D(64, (3, 3), use_bias=False, kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay), name='block1_conv2')(x)
    x = BatchNormalization(name='block1_conv2_bn')(x)
    x = Activation('relu', name='block1_conv2_act')(x)

    residual = Conv2D(128, (1, 1), strides=(2, 2),
                      padding='same', use_bias=False, kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(x)
    residual = BatchNormalization()(residual)

    x = SeparableConv2D(128, (3, 3), padding='same', use_bias=False, depthwise_initializer='he_uniform', pointwise_initializer='he_uniform',depthwise_regularizer=l2(weight_decay), pointwise_regularizer=l2(weight_decay), name='block2_sepconv1')(x)
    x = BatchNormalization(name='block2_sepconv1_bn')(x)
    x = Activation('relu', name='block2_sepconv2_act')(x)
    x = SeparableConv2D(128, (3, 3), padding='same', use_bias=False, depthwise_initializer='he_uniform', pointwise_initializer='he_uniform',depthwise_regularizer=l2(weight_decay), pointwise_regularizer=l2(weight_decay), name='block2_sepconv2')(x)
    x = BatchNormalization(name='block2_sepconv2_bn')(x)

    x = MaxPooling2D((3, 3), strides=(2, 2), padding='same', name='block2_pool')(x)
    # SE block 추가
    x =  squeeze_excite_block(x, reduction_ratio)
    x = add([x, residual])

    residual = Conv2D(256, (1, 1), strides=(2, 2),
                      padding='same', use_bias=False, kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(x)
    residual = BatchNormalization()(residual)

    x = Activation('relu', name='block3_sepconv1_act')(x)
    x = SeparableConv2D(256, (3, 3), padding='same', use_bias=False, depthwise_initializer='he_uniform', pointwise_initializer='he_uniform',depthwise_regularizer=l2(weight_decay), pointwise_regularizer=l2(weight_decay), name='block3_sepconv1')(x)
    x = BatchNormalization(name='block3_sepconv1_bn')(x)
    x = Activation('relu', name='block3_sepconv2_act')(x)
    x = SeparableConv2D(256, (3, 3), padding='same', use_bias=False, depthwise_initializer='he_uniform', pointwise_initializer='he_uniform',depthwise_regularizer=l2(weight_decay), pointwise_regularizer=l2(weight_decay), name='block3_sepconv2')(x)
    x = BatchNormalization(name='block3_sepconv2_bn')(x)

    x = MaxPooling2D((3, 3), strides=(2, 2), padding='same', name='block3_pool')(x)
    # SE block 추가
    x =  squeeze_excite_block(x, reduction_ratio)    
    x = add([x, residual])

    residual = Conv2D(728, (1, 1), strides=(2, 2),
                      padding='same', use_bias=False, kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(x)
    residual = BatchNormalization()(residual)

    x = Activation('relu', name='block4_sepconv1_act')(x)
    x = SeparableConv2D(728, (3, 3), padding='same', use_bias=False, depthwise_initializer='he_uniform', pointwise_initializer='he_uniform',depthwise_regularizer=l2(weight_decay), pointwise_regularizer=l2(weight_decay), name='block4_sepconv1')(x)
    x = BatchNormalization(name='block4_sepconv1_bn')(x)
    x = Activation('relu', name='block4_sepconv2_act')(x)
    x = SeparableConv2D(728, (3, 3), padding='same', use_bias=False, depthwise_initializer='he_uniform', pointwise_initializer='he_uniform',depthwise_regularizer=l2(weight_decay), pointwise_regularizer=l2(weight_decay), name='block4_sepconv2')(x)
    x = BatchNormalization(name='block4_sepconv2_bn')(x)

    x = MaxPooling2D((3, 3), strides=(2, 2), padding='same', name='block4_pool')(x)
    # SE block 추가
    x =  squeeze_excite_block(x, reduction_ratio)
    x = add([x, residual])

    for i in range(8):
        residual = x
        prefix = 'block' + str(i + 5)

        x = Activation('relu', name=prefix + '_sepconv1_act')(x)
        x = SeparableConv2D(728, (3, 3), padding='same', use_bias=False, depthwise_initializer='he_uniform', pointwise_initializer='he_uniform',depthwise_regularizer=l2(weight_decay), pointwise_regularizer=l2(weight_decay), name=prefix + '_sepconv1')(x)
        x = BatchNormalization(name=prefix + '_sepconv1_bn')(x)
        x = Activation('relu', name=prefix + '_sepconv2_act')(x)
        x = SeparableConv2D(728, (3, 3), padding='same', use_bias=False, depthwise_initializer='he_uniform', pointwise_initializer='he_uniform',depthwise_regularizer=l2(weight_decay), pointwise_regularizer=l2(weight_decay), name=prefix + '_sepconv2')(x)
        x = BatchNormalization(name=prefix + '_sepconv2_bn')(x)
        x = Activation('relu', name=prefix + '_sepconv3_act')(x)
        x = SeparableConv2D(728, (3, 3), padding='same', use_bias=False, depthwise_initializer='he_uniform', pointwise_initializer='he_uniform',depthwise_regularizer=l2(weight_decay), pointwise_regularizer=l2(weight_decay), name=prefix + '_sepconv3')(x)
        x = BatchNormalization(name=prefix + '_sepconv3_bn')(x)

        # SE block 추가
        x =  squeeze_excite_block(x, reduction_ratio)
        x = add([x, residual])

    residual = Conv2D(1024, (1, 1), strides=(2, 2),
                      padding='same', use_bias=False, kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(x)
    residual = BatchNormalization()(residual)

    x = Activation('relu', name='block13_sepconv1_act')(x)
    x = SeparableConv2D(728, (3, 3), padding='same', use_bias=False, depthwise_initializer='he_uniform', pointwise_initializer='he_uniform',depthwise_regularizer=l2(weight_decay), pointwise_regularizer=l2(weight_decay), name='block13_sepconv1')(x)
    x = BatchNormalization(name='block13_sepconv1_bn')(x)
    x = Activation('relu', name='block13_sepconv2_act')(x)
    x = SeparableConv2D(1024, (3, 3), padding='same', use_bias=False, depthwise_initializer='he_uniform', pointwise_initializer='he_uniform',depthwise_regularizer=l2(weight_decay), pointwise_regularizer=l2(weight_decay), name='block13_sepconv2')(x)
    x = BatchNormalization(name='block13_sepconv2_bn')(x)

    x = MaxPooling2D((3, 3), strides=(2, 2), padding='same', name='block13_pool')(x)
    # SE block 추가
    x =  squeeze_excite_block(x, reduction_ratio)
    x = add([x, residual])

    x = SeparableConv2D(1536, (3, 3), padding='same', use_bias=False, depthwise_initializer='he_uniform', pointwise_initializer='he_uniform',depthwise_regularizer=l2(weight_decay), pointwise_regularizer=l2(weight_decay), name='block14_sepconv1')(x)
    x = BatchNormalization(name='block14_sepconv1_bn')(x)
    x = Activation('relu', name='block14_sepconv1_act')(x)

    x = SeparableConv2D(2048, (3, 3), padding='same', use_bias=False, depthwise_initializer='he_uniform', pointwise_initializer='he_uniform',depthwise_regularizer=l2(weight_decay), pointwise_regularizer=l2(weight_decay), name='block14_sepconv2')(x)
    x = BatchNormalization(name='block14_sepconv2_bn')(x)
    x = Activation('relu', name='block14_sepconv2_act')(x)


    x = GlobalAveragePooling2D(name='avg_pool')(x)
    x = Dropout(0.5)(x)
    x = Dense(classes, activation='softmax', kernel_regularizer=l2(weight_decay), name='predictions')(x)


    inputs = img_input

    # Create model.
    model = Model(inputs, x, name=name)

    return model

# %%
model = SE_Xception(input_sizes, classes=classes, reduction_ratio = 16, name='SE_Xception')

# %%
model.summary()
# Out:
# Model: "SE_Xception"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 299, 299, 3) 0
# __________________________________________________________________________________________________
# block1_conv1 (Conv2D)           (None, 149, 149, 32) 864         input_1[0][0]
# __________________________________________________________________________________________________
# block1_conv1_bn (BatchNormaliza (None, 149, 149, 32) 128         block1_conv1[0][0]
# __________________________________________________________________________________________________
# block1_conv1_act (Activation)   (None, 149, 149, 32) 0           block1_conv1_bn[0][0]
# __________________________________________________________________________________________________
# block1_conv2 (Conv2D)           (None, 147, 147, 64) 18432       block1_conv1_act[0][0]
# __________________________________________________________________________________________________
# block1_conv2_bn (BatchNormaliza (None, 147, 147, 64) 256         block1_conv2[0][0]
# __________________________________________________________________________________________________
# block1_conv2_act (Activation)   (None, 147, 147, 64) 0           block1_conv2_bn[0][0]
# __________________________________________________________________________________________________
# block2_sepconv1 (SeparableConv2 (None, 147, 147, 128 8768        block1_conv2_act[0][0]
# __________________________________________________________________________________________________
# block2_sepconv1_bn (BatchNormal (None, 147, 147, 128 512         block2_sepconv1[0][0]
# __________________________________________________________________________________________________
# block2_sepconv2_act (Activation (None, 147, 147, 128 0           block2_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block2_sepconv2 (SeparableConv2 (None, 147, 147, 128 17536       block2_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block2_sepconv2_bn (BatchNormal (None, 147, 147, 128 512         block2_sepconv2[0][0]
# __________________________________________________________________________________________________
# block2_pool (MaxPooling2D)      (None, 74, 74, 128)  0           block2_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 128)          0           block2_pool[0][0]
# __________________________________________________________________________________________________
# reshape (Reshape)               (None, 1, 1, 128)    0           global_average_pooling2d[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 1, 1, 8)      1024        reshape[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 1, 1, 128)    1024        dense[0][0]
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 74, 74, 128)  8192        block1_conv2_act[0][0]
# __________________________________________________________________________________________________
# multiply (Multiply)             (None, 74, 74, 128)  0           block2_pool[0][0]
#                                                                  dense_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 74, 74, 128)  512         conv2d[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 74, 74, 128)  0           multiply[0][0]
#                                                                  batch_normalization[0][0]
# __________________________________________________________________________________________________
# block3_sepconv1_act (Activation (None, 74, 74, 128)  0           add[0][0]
# __________________________________________________________________________________________________
# block3_sepconv1 (SeparableConv2 (None, 74, 74, 256)  33920       block3_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block3_sepconv1_bn (BatchNormal (None, 74, 74, 256)  1024        block3_sepconv1[0][0]
# __________________________________________________________________________________________________
# block3_sepconv2_act (Activation (None, 74, 74, 256)  0           block3_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block3_sepconv2 (SeparableConv2 (None, 74, 74, 256)  67840       block3_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block3_sepconv2_bn (BatchNormal (None, 74, 74, 256)  1024        block3_sepconv2[0][0]
# __________________________________________________________________________________________________
# block3_pool (MaxPooling2D)      (None, 37, 37, 256)  0           block3_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_1 (Glo (None, 256)          0           block3_pool[0][0]
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, 1, 1, 256)    0           global_average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 1, 1, 16)     4096        reshape_1[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 1, 1, 256)    4096        dense_2[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 37, 37, 256)  32768       add[0][0]
# __________________________________________________________________________________________________
# multiply_1 (Multiply)           (None, 37, 37, 256)  0           block3_pool[0][0]
#                                                                  dense_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 37, 37, 256)  1024        conv2d_1[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 37, 37, 256)  0           multiply_1[0][0]
#                                                                  batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# block4_sepconv1_act (Activation (None, 37, 37, 256)  0           add_1[0][0]
# __________________________________________________________________________________________________
# block4_sepconv1 (SeparableConv2 (None, 37, 37, 728)  188672      block4_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block4_sepconv1_bn (BatchNormal (None, 37, 37, 728)  2912        block4_sepconv1[0][0]
# __________________________________________________________________________________________________
# block4_sepconv2_act (Activation (None, 37, 37, 728)  0           block4_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block4_sepconv2 (SeparableConv2 (None, 37, 37, 728)  536536      block4_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block4_sepconv2_bn (BatchNormal (None, 37, 37, 728)  2912        block4_sepconv2[0][0]
# __________________________________________________________________________________________________
# block4_pool (MaxPooling2D)      (None, 19, 19, 728)  0           block4_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_2 (Glo (None, 728)          0           block4_pool[0][0]
# __________________________________________________________________________________________________
# reshape_2 (Reshape)             (None, 1, 1, 728)    0           global_average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 1, 1, 45)     32760       reshape_2[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 1, 1, 728)    32760       dense_4[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 19, 19, 728)  186368      add_1[0][0]
# __________________________________________________________________________________________________
# multiply_2 (Multiply)           (None, 19, 19, 728)  0           block4_pool[0][0]
#                                                                  dense_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 19, 19, 728)  2912        conv2d_2[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 19, 19, 728)  0           multiply_2[0][0]
#                                                                  batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# block5_sepconv1_act (Activation (None, 19, 19, 728)  0           add_2[0][0]
# __________________________________________________________________________________________________
# block5_sepconv1 (SeparableConv2 (None, 19, 19, 728)  536536      block5_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block5_sepconv1_bn (BatchNormal (None, 19, 19, 728)  2912        block5_sepconv1[0][0]
# __________________________________________________________________________________________________
# block5_sepconv2_act (Activation (None, 19, 19, 728)  0           block5_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block5_sepconv2 (SeparableConv2 (None, 19, 19, 728)  536536      block5_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block5_sepconv2_bn (BatchNormal (None, 19, 19, 728)  2912        block5_sepconv2[0][0]
# __________________________________________________________________________________________________
# block5_sepconv3_act (Activation (None, 19, 19, 728)  0           block5_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block5_sepconv3 (SeparableConv2 (None, 19, 19, 728)  536536      block5_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block5_sepconv3_bn (BatchNormal (None, 19, 19, 728)  2912        block5_sepconv3[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_3 (Glo (None, 728)          0           block5_sepconv3_bn[0][0]
# __________________________________________________________________________________________________
# reshape_3 (Reshape)             (None, 1, 1, 728)    0           global_average_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 1, 1, 45)     32760       reshape_3[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 1, 1, 728)    32760       dense_6[0][0]
# __________________________________________________________________________________________________
# multiply_3 (Multiply)           (None, 19, 19, 728)  0           block5_sepconv3_bn[0][0]
#                                                                  dense_7[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 19, 19, 728)  0           multiply_3[0][0]
#                                                                  add_2[0][0]
# __________________________________________________________________________________________________
# block6_sepconv1_act (Activation (None, 19, 19, 728)  0           add_3[0][0]
# __________________________________________________________________________________________________
# block6_sepconv1 (SeparableConv2 (None, 19, 19, 728)  536536      block6_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block6_sepconv1_bn (BatchNormal (None, 19, 19, 728)  2912        block6_sepconv1[0][0]
# __________________________________________________________________________________________________
# block6_sepconv2_act (Activation (None, 19, 19, 728)  0           block6_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block6_sepconv2 (SeparableConv2 (None, 19, 19, 728)  536536      block6_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block6_sepconv2_bn (BatchNormal (None, 19, 19, 728)  2912        block6_sepconv2[0][0]
# __________________________________________________________________________________________________
# block6_sepconv3_act (Activation (None, 19, 19, 728)  0           block6_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block6_sepconv3 (SeparableConv2 (None, 19, 19, 728)  536536      block6_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block6_sepconv3_bn (BatchNormal (None, 19, 19, 728)  2912        block6_sepconv3[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_4 (Glo (None, 728)          0           block6_sepconv3_bn[0][0]
# __________________________________________________________________________________________________
# reshape_4 (Reshape)             (None, 1, 1, 728)    0           global_average_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 1, 1, 45)     32760       reshape_4[0][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, 1, 1, 728)    32760       dense_8[0][0]
# __________________________________________________________________________________________________
# multiply_4 (Multiply)           (None, 19, 19, 728)  0           block6_sepconv3_bn[0][0]
#                                                                  dense_9[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 19, 19, 728)  0           multiply_4[0][0]
#                                                                  add_3[0][0]
# __________________________________________________________________________________________________
# block7_sepconv1_act (Activation (None, 19, 19, 728)  0           add_4[0][0]
# __________________________________________________________________________________________________
# block7_sepconv1 (SeparableConv2 (None, 19, 19, 728)  536536      block7_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block7_sepconv1_bn (BatchNormal (None, 19, 19, 728)  2912        block7_sepconv1[0][0]
# __________________________________________________________________________________________________
# block7_sepconv2_act (Activation (None, 19, 19, 728)  0           block7_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block7_sepconv2 (SeparableConv2 (None, 19, 19, 728)  536536      block7_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block7_sepconv2_bn (BatchNormal (None, 19, 19, 728)  2912        block7_sepconv2[0][0]
# __________________________________________________________________________________________________
# block7_sepconv3_act (Activation (None, 19, 19, 728)  0           block7_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block7_sepconv3 (SeparableConv2 (None, 19, 19, 728)  536536      block7_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block7_sepconv3_bn (BatchNormal (None, 19, 19, 728)  2912        block7_sepconv3[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_5 (Glo (None, 728)          0           block7_sepconv3_bn[0][0]
# __________________________________________________________________________________________________
# reshape_5 (Reshape)             (None, 1, 1, 728)    0           global_average_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# dense_10 (Dense)                (None, 1, 1, 45)     32760       reshape_5[0][0]
# __________________________________________________________________________________________________
# dense_11 (Dense)                (None, 1, 1, 728)    32760       dense_10[0][0]
# __________________________________________________________________________________________________
# multiply_5 (Multiply)           (None, 19, 19, 728)  0           block7_sepconv3_bn[0][0]
#                                                                  dense_11[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 19, 19, 728)  0           multiply_5[0][0]
#                                                                  add_4[0][0]
# __________________________________________________________________________________________________
# block8_sepconv1_act (Activation (None, 19, 19, 728)  0           add_5[0][0]
# __________________________________________________________________________________________________
# block8_sepconv1 (SeparableConv2 (None, 19, 19, 728)  536536      block8_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block8_sepconv1_bn (BatchNormal (None, 19, 19, 728)  2912        block8_sepconv1[0][0]
# __________________________________________________________________________________________________
# block8_sepconv2_act (Activation (None, 19, 19, 728)  0           block8_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block8_sepconv2 (SeparableConv2 (None, 19, 19, 728)  536536      block8_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block8_sepconv2_bn (BatchNormal (None, 19, 19, 728)  2912        block8_sepconv2[0][0]
# __________________________________________________________________________________________________
# block8_sepconv3_act (Activation (None, 19, 19, 728)  0           block8_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block8_sepconv3 (SeparableConv2 (None, 19, 19, 728)  536536      block8_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block8_sepconv3_bn (BatchNormal (None, 19, 19, 728)  2912        block8_sepconv3[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_6 (Glo (None, 728)          0           block8_sepconv3_bn[0][0]
# __________________________________________________________________________________________________
# reshape_6 (Reshape)             (None, 1, 1, 728)    0           global_average_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# dense_12 (Dense)                (None, 1, 1, 45)     32760       reshape_6[0][0]
# __________________________________________________________________________________________________
# dense_13 (Dense)                (None, 1, 1, 728)    32760       dense_12[0][0]
# __________________________________________________________________________________________________
# multiply_6 (Multiply)           (None, 19, 19, 728)  0           block8_sepconv3_bn[0][0]
#                                                                  dense_13[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 19, 19, 728)  0           multiply_6[0][0]
#                                                                  add_5[0][0]
# __________________________________________________________________________________________________
# block9_sepconv1_act (Activation (None, 19, 19, 728)  0           add_6[0][0]
# __________________________________________________________________________________________________
# block9_sepconv1 (SeparableConv2 (None, 19, 19, 728)  536536      block9_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block9_sepconv1_bn (BatchNormal (None, 19, 19, 728)  2912        block9_sepconv1[0][0]
# __________________________________________________________________________________________________
# block9_sepconv2_act (Activation (None, 19, 19, 728)  0           block9_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block9_sepconv2 (SeparableConv2 (None, 19, 19, 728)  536536      block9_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block9_sepconv2_bn (BatchNormal (None, 19, 19, 728)  2912        block9_sepconv2[0][0]
# __________________________________________________________________________________________________
# block9_sepconv3_act (Activation (None, 19, 19, 728)  0           block9_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block9_sepconv3 (SeparableConv2 (None, 19, 19, 728)  536536      block9_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block9_sepconv3_bn (BatchNormal (None, 19, 19, 728)  2912        block9_sepconv3[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_7 (Glo (None, 728)          0           block9_sepconv3_bn[0][0]
# __________________________________________________________________________________________________
# reshape_7 (Reshape)             (None, 1, 1, 728)    0           global_average_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# dense_14 (Dense)                (None, 1, 1, 45)     32760       reshape_7[0][0]
# __________________________________________________________________________________________________
# dense_15 (Dense)                (None, 1, 1, 728)    32760       dense_14[0][0]
# __________________________________________________________________________________________________
# multiply_7 (Multiply)           (None, 19, 19, 728)  0           block9_sepconv3_bn[0][0]
#                                                                  dense_15[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 19, 19, 728)  0           multiply_7[0][0]
#                                                                  add_6[0][0]
# __________________________________________________________________________________________________
# block10_sepconv1_act (Activatio (None, 19, 19, 728)  0           add_7[0][0]
# __________________________________________________________________________________________________
# block10_sepconv1 (SeparableConv (None, 19, 19, 728)  536536      block10_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block10_sepconv1_bn (BatchNorma (None, 19, 19, 728)  2912        block10_sepconv1[0][0]
# __________________________________________________________________________________________________
# block10_sepconv2_act (Activatio (None, 19, 19, 728)  0           block10_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block10_sepconv2 (SeparableConv (None, 19, 19, 728)  536536      block10_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block10_sepconv2_bn (BatchNorma (None, 19, 19, 728)  2912        block10_sepconv2[0][0]
# __________________________________________________________________________________________________
# block10_sepconv3_act (Activatio (None, 19, 19, 728)  0           block10_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block10_sepconv3 (SeparableConv (None, 19, 19, 728)  536536      block10_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block10_sepconv3_bn (BatchNorma (None, 19, 19, 728)  2912        block10_sepconv3[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_8 (Glo (None, 728)          0           block10_sepconv3_bn[0][0]
# __________________________________________________________________________________________________
# reshape_8 (Reshape)             (None, 1, 1, 728)    0           global_average_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# dense_16 (Dense)                (None, 1, 1, 45)     32760       reshape_8[0][0]
# __________________________________________________________________________________________________
# dense_17 (Dense)                (None, 1, 1, 728)    32760       dense_16[0][0]
# __________________________________________________________________________________________________
# multiply_8 (Multiply)           (None, 19, 19, 728)  0           block10_sepconv3_bn[0][0]
#                                                                  dense_17[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 19, 19, 728)  0           multiply_8[0][0]
#                                                                  add_7[0][0]
# __________________________________________________________________________________________________
# block11_sepconv1_act (Activatio (None, 19, 19, 728)  0           add_8[0][0]
# __________________________________________________________________________________________________
# block11_sepconv1 (SeparableConv (None, 19, 19, 728)  536536      block11_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block11_sepconv1_bn (BatchNorma (None, 19, 19, 728)  2912        block11_sepconv1[0][0]
# __________________________________________________________________________________________________
# block11_sepconv2_act (Activatio (None, 19, 19, 728)  0           block11_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block11_sepconv2 (SeparableConv (None, 19, 19, 728)  536536      block11_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block11_sepconv2_bn (BatchNorma (None, 19, 19, 728)  2912        block11_sepconv2[0][0]
# __________________________________________________________________________________________________
# block11_sepconv3_act (Activatio (None, 19, 19, 728)  0           block11_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block11_sepconv3 (SeparableConv (None, 19, 19, 728)  536536      block11_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block11_sepconv3_bn (BatchNorma (None, 19, 19, 728)  2912        block11_sepconv3[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_9 (Glo (None, 728)          0           block11_sepconv3_bn[0][0]
# __________________________________________________________________________________________________
# reshape_9 (Reshape)             (None, 1, 1, 728)    0           global_average_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# dense_18 (Dense)                (None, 1, 1, 45)     32760       reshape_9[0][0]
# __________________________________________________________________________________________________
# dense_19 (Dense)                (None, 1, 1, 728)    32760       dense_18[0][0]
# __________________________________________________________________________________________________
# multiply_9 (Multiply)           (None, 19, 19, 728)  0           block11_sepconv3_bn[0][0]
#                                                                  dense_19[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 19, 19, 728)  0           multiply_9[0][0]
#                                                                  add_8[0][0]
# __________________________________________________________________________________________________
# block12_sepconv1_act (Activatio (None, 19, 19, 728)  0           add_9[0][0]
# __________________________________________________________________________________________________
# block12_sepconv1 (SeparableConv (None, 19, 19, 728)  536536      block12_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block12_sepconv1_bn (BatchNorma (None, 19, 19, 728)  2912        block12_sepconv1[0][0]
# __________________________________________________________________________________________________
# block12_sepconv2_act (Activatio (None, 19, 19, 728)  0           block12_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block12_sepconv2 (SeparableConv (None, 19, 19, 728)  536536      block12_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block12_sepconv2_bn (BatchNorma (None, 19, 19, 728)  2912        block12_sepconv2[0][0]
# __________________________________________________________________________________________________
# block12_sepconv3_act (Activatio (None, 19, 19, 728)  0           block12_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block12_sepconv3 (SeparableConv (None, 19, 19, 728)  536536      block12_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block12_sepconv3_bn (BatchNorma (None, 19, 19, 728)  2912        block12_sepconv3[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_10 (Gl (None, 728)          0           block12_sepconv3_bn[0][0]
# __________________________________________________________________________________________________
# reshape_10 (Reshape)            (None, 1, 1, 728)    0           global_average_pooling2d_10[0][0]
# __________________________________________________________________________________________________
# dense_20 (Dense)                (None, 1, 1, 45)     32760       reshape_10[0][0]
# __________________________________________________________________________________________________
# dense_21 (Dense)                (None, 1, 1, 728)    32760       dense_20[0][0]
# __________________________________________________________________________________________________
# multiply_10 (Multiply)          (None, 19, 19, 728)  0           block12_sepconv3_bn[0][0]
#                                                                  dense_21[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 19, 19, 728)  0           multiply_10[0][0]
#                                                                  add_9[0][0]
# __________________________________________________________________________________________________
# block13_sepconv1_act (Activatio (None, 19, 19, 728)  0           add_10[0][0]
# __________________________________________________________________________________________________
# block13_sepconv1 (SeparableConv (None, 19, 19, 728)  536536      block13_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block13_sepconv1_bn (BatchNorma (None, 19, 19, 728)  2912        block13_sepconv1[0][0]
# __________________________________________________________________________________________________
# block13_sepconv2_act (Activatio (None, 19, 19, 728)  0           block13_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block13_sepconv2 (SeparableConv (None, 19, 19, 1024) 752024      block13_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block13_sepconv2_bn (BatchNorma (None, 19, 19, 1024) 4096        block13_sepconv2[0][0]
# __________________________________________________________________________________________________
# block13_pool (MaxPooling2D)     (None, 10, 10, 1024) 0           block13_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_11 (Gl (None, 1024)         0           block13_pool[0][0]
# __________________________________________________________________________________________________
# reshape_11 (Reshape)            (None, 1, 1, 1024)   0           global_average_pooling2d_11[0][0]
# __________________________________________________________________________________________________
# dense_22 (Dense)                (None, 1, 1, 64)     65536       reshape_11[0][0]
# __________________________________________________________________________________________________
# dense_23 (Dense)                (None, 1, 1, 1024)   65536       dense_22[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 10, 10, 1024) 745472      add_10[0][0]
# __________________________________________________________________________________________________
# multiply_11 (Multiply)          (None, 10, 10, 1024) 0           block13_pool[0][0]
#                                                                  dense_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 10, 10, 1024) 4096        conv2d_3[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 10, 10, 1024) 0           multiply_11[0][0]
#                                                                  batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# block14_sepconv1 (SeparableConv (None, 10, 10, 1536) 1582080     add_11[0][0]
# __________________________________________________________________________________________________
# block14_sepconv1_bn (BatchNorma (None, 10, 10, 1536) 6144        block14_sepconv1[0][0]
# __________________________________________________________________________________________________
# block14_sepconv1_act (Activatio (None, 10, 10, 1536) 0           block14_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block14_sepconv2 (SeparableConv (None, 10, 10, 2048) 3159552     block14_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block14_sepconv2_bn (BatchNorma (None, 10, 10, 2048) 8192        block14_sepconv2[0][0]
# __________________________________________________________________________________________________
# block14_sepconv2_act (Activatio (None, 10, 10, 2048) 0           block14_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# avg_pool (GlobalAveragePooling2 (None, 2048)         0           block14_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 2048)         0           avg_pool[0][0]
# __________________________________________________________________________________________________
# predictions (Dense)             (None, 100)          204900      dropout[0][0]
# ==================================================================================================
# Total params: 21,797,372
# Trainable params: 21,742,844
# Non-trainable params: 54,528
# __________________________________________________________________________________________________

# %%
# 폴더 생성

os.makedirs(os.path.join(dir,'model_output',number,model.name), exist_ok=True)
os.makedirs(os.path.join(dir,'train_valid_output',number), exist_ok=True)

# %%
# 참고 : https://github.com/OverLordGoldDragon/keras-adamw

import sys
sys.path.append('/content/drive/My Drive/Colab Notebooks/Paper')
import utils
import optimizers_v2
from utils import get_weight_decays, fill_dict_in_order
from utils import reset_seeds, K_eval
from optimizers_v2 import AdamW, NadamW, SGDW

# %%
# top-5 accuracy 출력
import functools
top5_acc = functools.partial(ks.metrics.top_k_categorical_accuracy, k=5)
top5_acc.__name__ = 'top5_acc'

# %%
optimizer = AdamW(model=model, use_cosine_annealing=False, total_iterations = len(x_train) // batch_sizes)
#optimizer = Adam()
filepath =  os.path.join(dir,'model_output',number,model.name,'{epoch:03d}.h5')

callbacks_list = [ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_weights_only=False, save_best_only=False, mode='min'),
                  ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_weights_only=False, save_best_only=False, mode='max'),
                  #ReduceLROnPlateau(monitor='val_loss',patience=3,factor=0.1,min_lr=1e-5),
                  LearningRateScheduler(lr_schedule,verbose=1)
                  ]
                  
model.compile(optimizer, loss = 'categorical_crossentropy', metrics=['accuracy',top5_acc,macro_f1score])

# %%
######## flow_from_directory
history = model.fit(train_generator, steps_per_epoch=int(len(x_train)/batch_sizes),  validation_data = valid_generator, epochs=epochs, verbose=1 , callbacks = callbacks_list , validation_steps=int(len(x_valid)/batch_sizes))
# Out:
# Learning rate:  0.001
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 1/70
# 0.0(L1), 2.669753492949904e-08(L2) weight decay set for block1_conv1/kernel:0
# 0.0(L1), 2.669753492949904e-08(L2) weight decay set for block1_conv2/kernel:0
# 0.0(L1), 2.669753492949904e-08(L2) weight decay set for dense/kernel:0
# 0.0(L1), 2.669753492949904e-08(L2) weight decay set for dense_1/kernel:0
# 0.0(L1), 2.669753492949904e-08(L2) weight decay set for conv2d/kernel:0
# 0.0(L1), 2.669753492949904e-08(L2) weight decay set for dense_2/kernel:0
# 0.0(L1), 2.669753492949904e-08(L2) weight decay set for dense_3/kernel:0
# 0.0(L1), 2.669753492949904e-08(L2) weight decay set for conv2d_1/kernel:0
# 0.0(L1), 2.669753492949904e-08(L2) weight decay set for dense_4/kernel:0
# 0.0(L1), 2.669753492949904e-08(L2) weight decay set for dense_5/kernel:0
# 0.0(L1), 2.669753492949904e-08(L2) weight decay set for conv2d_2/kernel:0
# 0.0(L1), 2.669753492949904e-08(L2) weight decay set for dense_6/kernel:0
# 0.0(L1), 2.669753492949904e-08(L2) weight decay set for dense_7/kernel:0
# 0.0(L1), 2.669753492949904e-08(L2) weight decay set for dense_8/kernel:0
# 0.0(L1), 2.669753492949904e-08(L2) weight decay set for dense_9/kernel:0
# 0.0(L1), 2.669753492949904e-08(L2) weight decay set for dense_10/kernel:0
# 0.0(L1), 2.669753492949904e-08(L2) weight decay set for dense_11/kernel:0
# 0.0(L1), 2.669753492949904e-08(L2) weight decay set for dense_12/kernel:0
# 0.0(L1), 2.669753492949904e-08(L2) weight decay set for dense_13/kernel:0
# 0.0(L1), 2.669753492949904e-08(L2) weight decay set for dense_14/kernel:0
# 0.0(L1), 2.669753492949904e-08(L2) weight decay set for dense_15/kernel:0
# 0.0(L1), 2.669753492949904e-08(L2) weight decay set for dense_16/kernel:0
# 0.0(L1), 2.669753492949904e-08(L2) weight decay set for dense_17/kernel:0
# 0.0(L1), 2.669753492949904e-08(L2) weight decay set for dense_18/kernel:0
# 0.0(L1), 2.669753492949904e-08(L2) weight decay set for dense_19/kernel:0
# 0.0(L1), 2.669753492949904e-08(L2) weight decay set for dense_20/kernel:0
# 0.0(L1), 2.669753492949904e-08(L2) weight decay set for dense_21/kernel:0
# 0.0(L1), 2.669753492949904e-08(L2) weight decay set for dense_22/kernel:0
# 0.0(L1), 2.669753492949904e-08(L2) weight decay set for dense_23/kernel:0
# 0.0(L1), 2.669753492949904e-08(L2) weight decay set for conv2d_3/kernel:0
# 0.0(L1), 2.669753492949904e-08(L2) weight decay set for predictions/kernel:0
# 1403/1403 [==============================] - ETA: 0s - loss: 3.9736 - accuracy: 0.0999 - top5_acc: 0.3068 - macro_f1score: 0.0021
# Epoch 00001: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_Xception/001.h5
#
# Epoch 00001: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_Xception/001.h5
# 1403/1403 [==============================] - 17858s 13s/step - loss: 3.9736 - accuracy: 0.0999 - top5_acc: 0.3068 - macro_f1score: 0.0021 - val_loss: 4.0133 - val_accuracy: 0.1169 - val_top5_acc: 0.3623 - val_macro_f1score: 0.0084
# Learning rate:  0.001
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 2/70
# 1403/1403 [==============================] - ETA: 0s - loss: 3.1095 - accuracy: 0.2356 - top5_acc: 0.5392 - macro_f1score: 0.0181
# Epoch 00002: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_Xception/002.h5
#
# Epoch 00002: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_Xception/002.h5
# 1403/1403 [==============================] - 1132s 807ms/step - loss: 3.1095 - accuracy: 0.2356 - top5_acc: 0.5392 - macro_f1score: 0.0181 - val_loss: 3.0294 - val_accuracy: 0.2751 - val_top5_acc: 0.5827 - val_macro_f1score: 0.0347
# Learning rate:  0.001
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 3/70
# 1403/1403 [==============================] - ETA: 0s - loss: 2.5369 - accuracy: 0.3500 - top5_acc: 0.6803 - macro_f1score: 0.0443
# Epoch 00003: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_Xception/003.h5
#
# Epoch 00003: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_Xception/003.h5
# 1403/1403 [==============================] - 1136s 809ms/step - loss: 2.5369 - accuracy: 0.3500 - top5_acc: 0.6803 - macro_f1score: 0.0443 - val_loss: 2.5805 - val_accuracy: 0.3534 - val_top5_acc: 0.6828 - val_macro_f1score: 0.0585
# Learning rate:  0.001
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 4/70
# 1403/1403 [==============================] - ETA: 0s - loss: 2.1806 - accuracy: 0.4291 - top5_acc: 0.7527 - macro_f1score: 0.0694
# Epoch 00004: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_Xception/004.h5
#
# Epoch 00004: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_Xception/004.h5
# 1403/1403 [==============================] - 1126s 803ms/step - loss: 2.1806 - accuracy: 0.4291 - top5_acc: 0.7527 - macro_f1score: 0.0694 - val_loss: 2.1323 - val_accuracy: 0.4476 - val_top5_acc: 0.7544 - val_macro_f1score: 0.0787
# Learning rate:  0.001
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 5/70
# 1403/1403 [==============================] - ETA: 0s - loss: 1.9249 - accuracy: 0.4895 - top5_acc: 0.8013 - macro_f1score: 0.0902
# Epoch 00005: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_Xception/005.h5
#
# Epoch 00005: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_Xception/005.h5
# 1403/1403 [==============================] - 1122s 800ms/step - loss: 1.9249 - accuracy: 0.4895 - top5_acc: 0.8013 - macro_f1score: 0.0902 - val_loss: 1.9297 - val_accuracy: 0.4826 - val_top5_acc: 0.8032 - val_macro_f1score: 0.0923
# Learning rate:  0.001
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 6/70
# 1403/1403 [==============================] - ETA: 0s - loss: 1.7484 - accuracy: 0.5334 - top5_acc: 0.8339 - macro_f1score: 0.1054
# Epoch 00006: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_Xception/006.h5
#
# Epoch 00006: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_Xception/006.h5
# 1403/1403 [==============================] - 1128s 804ms/step - loss: 1.7484 - accuracy: 0.5334 - top5_acc: 0.8339 - macro_f1score: 0.1054 - val_loss: 1.9692 - val_accuracy: 0.4889 - val_top5_acc: 0.8099 - val_macro_f1score: 0.1036
# Learning rate:  0.001
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 7/70
# 1403/1403 [==============================] - ETA: 0s - loss: 1.5931 - accuracy: 0.5701 - top5_acc: 0.8587 - macro_f1score: 0.1192
# Epoch 00007: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_Xception/007.h5
#
# Epoch 00007: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_Xception/007.h5
# 1403/1403 [==============================] - 1123s 800ms/step - loss: 1.5931 - accuracy: 0.5701 - top5_acc: 0.8587 - macro_f1score: 0.1192 - val_loss: 1.8169 - val_accuracy: 0.5299 - val_top5_acc: 0.8232 - val_macro_f1score: 0.1164
# Learning rate:  0.001
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 8/70
# 1403/1403 [==============================] - ETA: 0s - loss: 1.4571 - accuracy: 0.6064 - top5_acc: 0.8799 - macro_f1score: 0.1330
# Epoch 00008: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_Xception/008.h5
#
# Epoch 00008: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_Xception/008.h5
# 1403/1403 [==============================] - 1123s 800ms/step - loss: 1.4571 - accuracy: 0.6064 - top5_acc: 0.8799 - macro_f1score: 0.1330 - val_loss: 1.6373 - val_accuracy: 0.5621 - val_top5_acc: 0.8556 - val_macro_f1score: 0.1241
# Learning rate:  0.001
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 9/70
# 1403/1403 [==============================] - ETA: 0s - loss: 1.3595 - accuracy: 0.6330 - top5_acc: 0.8955 - macro_f1score: 0.1430
# Epoch 00009: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_Xception/009.h5
#
# Epoch 00009: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_Xception/009.h5
# 1403/1403 [==============================] - 1122s 800ms/step - loss: 1.3595 - accuracy: 0.6330 - top5_acc: 0.8955 - macro_f1score: 0.1430 - val_loss: 1.5772 - val_accuracy: 0.5847 - val_top5_acc: 0.8596 - val_macro_f1score: 0.1288
# Learning rate:  0.001
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 10/70
# 1403/1403 [==============================] - ETA: 0s - loss: 1.2633 - accuracy: 0.6607 - top5_acc: 0.9082 - macro_f1score: 0.1526
# Epoch 00010: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_Xception/010.h5
#
# Epoch 00010: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_Xception/010.h5
# 1403/1403 [==============================] - 1122s 799ms/step - loss: 1.2633 - accuracy: 0.6607 - top5_acc: 0.9082 - macro_f1score: 0.1526 - val_loss: 1.5919 - val_accuracy: 0.5880 - val_top5_acc: 0.8633 - val_macro_f1score: 0.1355
# Learning rate:  0.001
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 11/70
# 1403/1403 [==============================] - ETA: 0s - loss: 1.1715 - accuracy: 0.6854 - top5_acc: 0.9224 - macro_f1score: 0.1620
# Epoch 00011: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_Xception/011.h5
#
# Epoch 00011: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_Xception/011.h5
# 1403/1403 [==============================] - 1122s 800ms/step - loss: 1.1715 - accuracy: 0.6854 - top5_acc: 0.9224 - macro_f1score: 0.1620 - val_loss: 1.6481 - val_accuracy: 0.5874 - val_top5_acc: 0.8532 - val_macro_f1score: 0.1376
# Learning rate:  0.001
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 12/70
# 1403/1403 [==============================] - ETA: 0s - loss: 1.1037 - accuracy: 0.7036 - top5_acc: 0.9286 - macro_f1score: 0.1693
# Epoch 00012: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_Xception/012.h5
#
# Epoch 00012: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_Xception/012.h5
# 1403/1403 [==============================] - 1123s 801ms/step - loss: 1.1037 - accuracy: 0.7036 - top5_acc: 0.9286 - macro_f1score: 0.1693 - val_loss: 1.4338 - val_accuracy: 0.6333 - val_top5_acc: 0.8869 - val_macro_f1score: 0.1518
# Learning rate:  0.001
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 13/70
# 1403/1403 [==============================] - ETA: 0s - loss: 1.0317 - accuracy: 0.7219 - top5_acc: 0.9406 - macro_f1score: 0.1759
# Epoch 00013: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_Xception/013.h5
#
# Epoch 00013: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_Xception/013.h5
# 1403/1403 [==============================] - 1126s 802ms/step - loss: 1.0317 - accuracy: 0.7219 - top5_acc: 0.9406 - macro_f1score: 0.1759 - val_loss: 1.4221 - val_accuracy: 0.6440 - val_top5_acc: 0.8886 - val_macro_f1score: 0.1561
# Learning rate:  0.001
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 14/70
# 1403/1403 [==============================] - ETA: 0s - loss: 0.9740 - accuracy: 0.7377 - top5_acc: 0.9473 - macro_f1score: 0.1837
# Epoch 00014: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_Xception/014.h5
#
# Epoch 00014: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_Xception/014.h5
# 1403/1403 [==============================] - 1122s 799ms/step - loss: 0.9740 - accuracy: 0.7377 - top5_acc: 0.9473 - macro_f1score: 0.1837 - val_loss: 1.3801 - val_accuracy: 0.6396 - val_top5_acc: 0.8944 - val_macro_f1score: 0.1565
# Learning rate:  0.001
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 15/70
# 1403/1403 [==============================] - ETA: 0s - loss: 0.9056 - accuracy: 0.7575 - top5_acc: 0.9542 - macro_f1score: 0.1897
# Epoch 00015: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_Xception/015.h5
#
# Epoch 00015: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_Xception/015.h5
# 1403/1403 [==============================] - 1119s 798ms/step - loss: 0.9056 - accuracy: 0.7575 - top5_acc: 0.9542 - macro_f1score: 0.1897 - val_loss: 1.3536 - val_accuracy: 0.6669 - val_top5_acc: 0.9019 - val_macro_f1score: 0.1640
# Learning rate:  0.001
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 16/70
# 1403/1403 [==============================] - ETA: 0s - loss: 0.8525 - accuracy: 0.7761 - top5_acc: 0.9598 - macro_f1score: 0.1959
# Epoch 00016: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_Xception/016.h5
#
# Epoch 00016: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_Xception/016.h5
# 1403/1403 [==============================] - 1120s 799ms/step - loss: 0.8525 - accuracy: 0.7761 - top5_acc: 0.9598 - macro_f1score: 0.1959 - val_loss: 1.3596 - val_accuracy: 0.6693 - val_top5_acc: 0.9001 - val_macro_f1score: 0.1651
# Learning rate:  0.001
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 17/70
# 1403/1403 [==============================] - ETA: 0s - loss: 0.8063 - accuracy: 0.7880 - top5_acc: 0.9663 - macro_f1score: 0.2010
# Epoch 00017: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_Xception/017.h5
#
# Epoch 00017: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_Xception/017.h5
# 1403/1403 [==============================] - 1121s 799ms/step - loss: 0.8063 - accuracy: 0.7880 - top5_acc: 0.9663 - macro_f1score: 0.2010 - val_loss: 1.4382 - val_accuracy: 0.6618 - val_top5_acc: 0.8995 - val_macro_f1score: 0.1664
# Learning rate:  0.001
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 18/70
# 1403/1403 [==============================] - ETA: 0s - loss: 0.7589 - accuracy: 0.8033 - top5_acc: 0.9704 - macro_f1score: 0.2072
# Epoch 00018: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_Xception/018.h5
#
# Epoch 00018: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_Xception/018.h5
# 1403/1403 [==============================] - 1120s 799ms/step - loss: 0.7589 - accuracy: 0.8033 - top5_acc: 0.9704 - macro_f1score: 0.2072 - val_loss: 1.5211 - val_accuracy: 0.6507 - val_top5_acc: 0.8987 - val_macro_f1score: 0.1642
# Learning rate:  0.001
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 19/70
# 1403/1403 [==============================] - ETA: 0s - loss: 0.7143 - accuracy: 0.8157 - top5_acc: 0.9761 - macro_f1score: 0.2115
# Epoch 00019: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_Xception/019.h5
#
# Epoch 00019: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_Xception/019.h5
# 1403/1403 [==============================] - 1119s 798ms/step - loss: 0.7143 - accuracy: 0.8157 - top5_acc: 0.9761 - macro_f1score: 0.2115 - val_loss: 1.4414 - val_accuracy: 0.6592 - val_top5_acc: 0.9019 - val_macro_f1score: 0.1687
# Learning rate:  0.001
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 20/70
# 1403/1403 [==============================] - ETA: 0s - loss: 0.6839 - accuracy: 0.8273 - top5_acc: 0.9784 - macro_f1score: 0.2151
# Epoch 00020: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_Xception/020.h5
#
# Epoch 00020: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_Xception/020.h5
# 1403/1403 [==============================] - 1118s 797ms/step - loss: 0.6839 - accuracy: 0.8273 - top5_acc: 0.9784 - macro_f1score: 0.2151 - val_loss: 1.3983 - val_accuracy: 0.6768 - val_top5_acc: 0.9053 - val_macro_f1score: 0.1711
# Learning rate:  0.001
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 21/70
# 1403/1403 [==============================] - ETA: 0s - loss: 0.6494 - accuracy: 0.8375 - top5_acc: 0.9814 - macro_f1score: 0.2192
# Epoch 00021: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_Xception/021.h5
#
# Epoch 00021: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_Xception/021.h5
# 1403/1403 [==============================] - 1118s 797ms/step - loss: 0.6494 - accuracy: 0.8375 - top5_acc: 0.9814 - macro_f1score: 0.2192 - val_loss: 1.4210 - val_accuracy: 0.6855 - val_top5_acc: 0.9023 - val_macro_f1score: 0.1782
# Learning rate:  0.001
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 22/70
# 1403/1403 [==============================] - ETA: 0s - loss: 0.6264 - accuracy: 0.8460 - top5_acc: 0.9829 - macro_f1score: 0.2222
# Epoch 00022: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_Xception/022.h5
#
# Epoch 00022: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_Xception/022.h5
# 1403/1403 [==============================] - 1119s 798ms/step - loss: 0.6264 - accuracy: 0.8460 - top5_acc: 0.9829 - macro_f1score: 0.2222 - val_loss: 1.3981 - val_accuracy: 0.6758 - val_top5_acc: 0.9104 - val_macro_f1score: 0.1721
# Learning rate:  0.001
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 23/70
# 1403/1403 [==============================] - ETA: 0s - loss: 0.5976 - accuracy: 0.8561 - top5_acc: 0.9865 - macro_f1score: 0.2264
# Epoch 00023: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_Xception/023.h5
#
# Epoch 00023: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_Xception/023.h5
# 1403/1403 [==============================] - 1121s 799ms/step - loss: 0.5976 - accuracy: 0.8561 - top5_acc: 0.9865 - macro_f1score: 0.2264 - val_loss: 1.4855 - val_accuracy: 0.6786 - val_top5_acc: 0.9132 - val_macro_f1score: 0.1753
# Learning rate:  0.001
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 24/70
# 1403/1403 [==============================] - ETA: 0s - loss: 0.5769 - accuracy: 0.8664 - top5_acc: 0.9870 - macro_f1score: 0.2302
# Epoch 00024: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_Xception/024.h5
#
# Epoch 00024: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_Xception/024.h5
# 1403/1403 [==============================] - 1122s 800ms/step - loss: 0.5769 - accuracy: 0.8664 - top5_acc: 0.9870 - macro_f1score: 0.2302 - val_loss: 1.5764 - val_accuracy: 0.6677 - val_top5_acc: 0.9072 - val_macro_f1score: 0.1757
# Learning rate:  0.001
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 25/70
# 1403/1403 [==============================] - ETA: 0s - loss: 0.5450 - accuracy: 0.8743 - top5_acc: 0.9898 - macro_f1score: 0.2328
# Epoch 00025: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_Xception/025.h5
#
# Epoch 00025: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_Xception/025.h5
# 1403/1403 [==============================] - 1123s 800ms/step - loss: 0.5450 - accuracy: 0.8743 - top5_acc: 0.9898 - macro_f1score: 0.2328 - val_loss: 1.5186 - val_accuracy: 0.6841 - val_top5_acc: 0.9150 - val_macro_f1score: 0.1797
# Learning rate:  0.001
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 26/70
# 1403/1403 [==============================] - ETA: 0s - loss: 0.5353 - accuracy: 0.8805 - top5_acc: 0.9907 - macro_f1score: 0.2353
# Epoch 00026: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_Xception/026.h5
#
# Epoch 00026: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_Xception/026.h5
# 1403/1403 [==============================] - 1120s 798ms/step - loss: 0.5353 - accuracy: 0.8805 - top5_acc: 0.9907 - macro_f1score: 0.2353 - val_loss: 1.5367 - val_accuracy: 0.6830 - val_top5_acc: 0.9066 - val_macro_f1score: 0.1782
# Learning rate:  0.001
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 27/70
# 1403/1403 [==============================] - ETA: 0s - loss: 0.5147 - accuracy: 0.8859 - top5_acc: 0.9912 - macro_f1score: 0.2369
# Epoch 00027: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_Xception/027.h5
#
# Epoch 00027: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_Xception/027.h5
# 1403/1403 [==============================] - 1121s 799ms/step - loss: 0.5147 - accuracy: 0.8859 - top5_acc: 0.9912 - macro_f1score: 0.2369 - val_loss: 1.5812 - val_accuracy: 0.6790 - val_top5_acc: 0.9106 - val_macro_f1score: 0.1764
# Learning rate:  0.001
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 28/70
# 1403/1403 [==============================] - ETA: 0s - loss: 0.4991 - accuracy: 0.8928 - top5_acc: 0.9925 - macro_f1score: 0.2397
# Epoch 00028: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_Xception/028.h5
#
# Epoch 00028: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_Xception/028.h5
# 1403/1403 [==============================] - 1122s 800ms/step - loss: 0.4991 - accuracy: 0.8928 - top5_acc: 0.9925 - macro_f1score: 0.2397 - val_loss: 1.5136 - val_accuracy: 0.6853 - val_top5_acc: 0.9106 - val_macro_f1score: 0.1791
# Learning rate:  0.001
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 29/70
# 1403/1403 [==============================] - ETA: 0s - loss: 0.4952 - accuracy: 0.8962 - top5_acc: 0.9931 - macro_f1score: 0.2410
# Epoch 00029: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_Xception/029.h5
#
# Epoch 00029: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_Xception/029.h5
# 1403/1403 [==============================] - 1123s 800ms/step - loss: 0.4952 - accuracy: 0.8962 - top5_acc: 0.9931 - macro_f1score: 0.2410 - val_loss: 1.4747 - val_accuracy: 0.6940 - val_top5_acc: 0.9096 - val_macro_f1score: 0.1818
# Learning rate:  0.001
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 30/70
# 1403/1403 [==============================] - ETA: 0s - loss: 0.4806 - accuracy: 0.9013 - top5_acc: 0.9932 - macro_f1score: 0.2420
# Epoch 00030: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_Xception/030.h5
#
# Epoch 00030: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_Xception/030.h5
# 1403/1403 [==============================] - 1125s 802ms/step - loss: 0.4806 - accuracy: 0.9013 - top5_acc: 0.9932 - macro_f1score: 0.2420 - val_loss: 1.7669 - val_accuracy: 0.6697 - val_top5_acc: 0.8979 - val_macro_f1score: 0.1778
# Learning rate:  0.0001
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 31/70
# 1403/1403 [==============================] - ETA: 0s - loss: 0.3568 - accuracy: 0.9433 - top5_acc: 0.9978 - macro_f1score: 0.2561
# Epoch 00031: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_Xception/031.h5
#
# Epoch 00031: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_Xception/031.h5
# 1403/1403 [==============================] - 1125s 802ms/step - loss: 0.3568 - accuracy: 0.9433 - top5_acc: 0.9978 - macro_f1score: 0.2561 - val_loss: 1.3287 - val_accuracy: 0.7358 - val_top5_acc: 0.9316 - val_macro_f1score: 0.1938
# Learning rate:  0.0001
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 32/70
# 1403/1403 [==============================] - ETA: 0s - loss: 0.3049 - accuracy: 0.9594 - top5_acc: 0.9990 - macro_f1score: 0.2620
# Epoch 00032: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_Xception/032.h5
#
# Epoch 00032: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_Xception/032.h5
# 1403/1403 [==============================] - 1128s 804ms/step - loss: 0.3049 - accuracy: 0.9594 - top5_acc: 0.9990 - macro_f1score: 0.2620 - val_loss: 1.3411 - val_accuracy: 0.7371 - val_top5_acc: 0.9324 - val_macro_f1score: 0.1976
# Learning rate:  0.0001
#
# Epoch 00033: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 33/70
# 1403/1403 [==============================] - ETA: 0s - loss: 0.2874 - accuracy: 0.9655 - top5_acc: 0.9994 - macro_f1score: 0.2640
# Epoch 00033: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_Xception/033.h5
#
# Epoch 00033: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_Xception/033.h5
# 1403/1403 [==============================] - 1125s 802ms/step - loss: 0.2874 - accuracy: 0.9655 - top5_acc: 0.9994 - macro_f1score: 0.2640 - val_loss: 1.3529 - val_accuracy: 0.7364 - val_top5_acc: 0.9322 - val_macro_f1score: 0.1941
# Learning rate:  0.0001
#
# Epoch 00034: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 34/70
# 1403/1403 [==============================] - ETA: 0s - loss: 0.2763 - accuracy: 0.9688 - top5_acc: 0.9992 - macro_f1score: 0.2656
# Epoch 00034: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_Xception/034.h5
#
# Epoch 00034: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_Xception/034.h5
# 1403/1403 [==============================] - 1122s 800ms/step - loss: 0.2763 - accuracy: 0.9688 - top5_acc: 0.9992 - macro_f1score: 0.2656 - val_loss: 1.3649 - val_accuracy: 0.7395 - val_top5_acc: 0.9333 - val_macro_f1score: 0.1969
# Learning rate:  0.0001
#
# Epoch 00035: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 35/70
# 1403/1403 [==============================] - ETA: 0s - loss: 0.2638 - accuracy: 0.9728 - top5_acc: 0.9997 - macro_f1score: 0.2663
# Epoch 00035: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_Xception/035.h5
#
# Epoch 00035: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_Xception/035.h5
# 1403/1403 [==============================] - 1120s 798ms/step - loss: 0.2638 - accuracy: 0.9728 - top5_acc: 0.9997 - macro_f1score: 0.2663 - val_loss: 1.3619 - val_accuracy: 0.7383 - val_top5_acc: 0.9316 - val_macro_f1score: 0.1972
# Learning rate:  0.0001
#
# Epoch 00036: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 36/70
# 1403/1403 [==============================] - ETA: 0s - loss: 0.2580 - accuracy: 0.9739 - top5_acc: 0.9993 - macro_f1score: 0.2674
# Epoch 00036: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_Xception/036.h5
#
# Epoch 00036: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_Xception/036.h5
# 1403/1403 [==============================] - 1118s 797ms/step - loss: 0.2580 - accuracy: 0.9739 - top5_acc: 0.9993 - macro_f1score: 0.2674 - val_loss: 1.3646 - val_accuracy: 0.7391 - val_top5_acc: 0.9347 - val_macro_f1score: 0.1948
# Learning rate:  0.0001
#
# Epoch 00037: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 37/70
# 1403/1403 [==============================] - ETA: 0s - loss: 0.2484 - accuracy: 0.9760 - top5_acc: 0.9997 - macro_f1score: 0.2677
# Epoch 00037: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_Xception/037.h5
#
# Epoch 00037: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_Xception/037.h5
# 1403/1403 [==============================] - 1118s 797ms/step - loss: 0.2484 - accuracy: 0.9760 - top5_acc: 0.9997 - macro_f1score: 0.2677 - val_loss: 1.3863 - val_accuracy: 0.7340 - val_top5_acc: 0.9333 - val_macro_f1score: 0.1967
# Learning rate:  0.0001
#
# Epoch 00038: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 38/70
# 1403/1403 [==============================] - ETA: 0s - loss: 0.2411 - accuracy: 0.9796 - top5_acc: 0.9998 - macro_f1score: 0.2691
# Epoch 00038: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_Xception/038.h5
#
# Epoch 00038: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_Xception/038.h5
# 1403/1403 [==============================] - 1118s 797ms/step - loss: 0.2411 - accuracy: 0.9796 - top5_acc: 0.9998 - macro_f1score: 0.2691 - val_loss: 1.4033 - val_accuracy: 0.7403 - val_top5_acc: 0.9328 - val_macro_f1score: 0.1987
# Learning rate:  0.0001
#
# Epoch 00039: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 39/70
# 1403/1403 [==============================] - ETA: 0s - loss: 0.2374 - accuracy: 0.9802 - top5_acc: 0.9996 - macro_f1score: 0.2682
# Epoch 00039: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_Xception/039.h5
#
# Epoch 00039: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_Xception/039.h5
# 1403/1403 [==============================] - 1120s 799ms/step - loss: 0.2374 - accuracy: 0.9802 - top5_acc: 0.9996 - macro_f1score: 0.2682 - val_loss: 1.3920 - val_accuracy: 0.7391 - val_top5_acc: 0.9347 - val_macro_f1score: 0.1972
# Learning rate:  0.0001
#
# Epoch 00040: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 40/70
# 1403/1403 [==============================] - ETA: 0s - loss: 0.2318 - accuracy: 0.9816 - top5_acc: 0.9997 - macro_f1score: 0.2698
# Epoch 00040: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_Xception/040.h5
#
# Epoch 00040: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_Xception/040.h5
# 1403/1403 [==============================] - 1126s 803ms/step - loss: 0.2318 - accuracy: 0.9816 - top5_acc: 0.9997 - macro_f1score: 0.2698 - val_loss: 1.4049 - val_accuracy: 0.7425 - val_top5_acc: 0.9314 - val_macro_f1score: 0.1979
# Learning rate:  0.0001
#
# Epoch 00041: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 41/70
# 1403/1403 [==============================] - ETA: 0s - loss: 0.2279 - accuracy: 0.9827 - top5_acc: 0.9997 - macro_f1score: 0.2704
# Epoch 00041: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_Xception/041.h5
#
# Epoch 00041: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_Xception/041.h5
# 1403/1403 [==============================] - 1127s 803ms/step - loss: 0.2279 - accuracy: 0.9827 - top5_acc: 0.9997 - macro_f1score: 0.2704 - val_loss: 1.4256 - val_accuracy: 0.7371 - val_top5_acc: 0.9314 - val_macro_f1score: 0.1985
# Learning rate:  0.0001
#
# Epoch 00042: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 42/70
# 1403/1403 [==============================] - ETA: 0s - loss: 0.2279 - accuracy: 0.9822 - top5_acc: 0.9998 - macro_f1score: 0.2690
# Epoch 00042: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_Xception/042.h5
#
# Epoch 00042: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_Xception/042.h5
# 1403/1403 [==============================] - 1132s 807ms/step - loss: 0.2279 - accuracy: 0.9822 - top5_acc: 0.9998 - macro_f1score: 0.2690 - val_loss: 1.4135 - val_accuracy: 0.7433 - val_top5_acc: 0.9312 - val_macro_f1score: 0.1973
# Learning rate:  0.0001
#
# Epoch 00043: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 43/70
# 1403/1403 [==============================] - ETA: 0s - loss: 0.2197 - accuracy: 0.9848 - top5_acc: 0.9998 - macro_f1score: 0.2705
# Epoch 00043: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_Xception/043.h5
#
# Epoch 00043: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_Xception/043.h5
# 1403/1403 [==============================] - 1137s 811ms/step - loss: 0.2197 - accuracy: 0.9848 - top5_acc: 0.9998 - macro_f1score: 0.2705 - val_loss: 1.4195 - val_accuracy: 0.7381 - val_top5_acc: 0.9328 - val_macro_f1score: 0.1987
# Learning rate:  0.0001
#
# Epoch 00044: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 44/70
# 1403/1403 [==============================] - ETA: 0s - loss: 0.2208 - accuracy: 0.9839 - top5_acc: 0.9998 - macro_f1score: 0.2705
# Epoch 00044: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_Xception/044.h5
#
# Epoch 00044: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_Xception/044.h5
# 1403/1403 [==============================] - 1128s 804ms/step - loss: 0.2208 - accuracy: 0.9839 - top5_acc: 0.9998 - macro_f1score: 0.2705 - val_loss: 1.4339 - val_accuracy: 0.7383 - val_top5_acc: 0.9333 - val_macro_f1score: 0.1981
# Learning rate:  0.0001
#
# Epoch 00045: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 45/70
# 1403/1403 [==============================] - ETA: 0s - loss: 0.2156 - accuracy: 0.9853 - top5_acc: 0.9998 - macro_f1score: 0.2702
# Epoch 00045: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_Xception/045.h5
#
# Epoch 00045: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_Xception/045.h5
# 1403/1403 [==============================] - 1132s 807ms/step - loss: 0.2156 - accuracy: 0.9853 - top5_acc: 0.9998 - macro_f1score: 0.2702 - val_loss: 1.4244 - val_accuracy: 0.7439 - val_top5_acc: 0.9318 - val_macro_f1score: 0.2003
# Learning rate:  0.0001
#
# Epoch 00046: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 46/70
# 1403/1403 [==============================] - ETA: 0s - loss: 0.2134 - accuracy: 0.9857 - top5_acc: 0.9999 - macro_f1score: 0.2712
# Epoch 00046: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_Xception/046.h5
#
# Epoch 00046: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_Xception/046.h5
# 1403/1403 [==============================] - 1123s 801ms/step - loss: 0.2134 - accuracy: 0.9857 - top5_acc: 0.9999 - macro_f1score: 0.2712 - val_loss: 1.4560 - val_accuracy: 0.7433 - val_top5_acc: 0.9337 - val_macro_f1score: 0.1989
# Learning rate:  0.0001
#
# Epoch 00047: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 47/70
# 1403/1403 [==============================] - ETA: 0s - loss: 0.2128 - accuracy: 0.9853 - top5_acc: 0.9999 - macro_f1score: 0.2710
# Epoch 00047: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_Xception/047.h5
#
# Epoch 00047: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_Xception/047.h5
# 1403/1403 [==============================] - 1120s 798ms/step - loss: 0.2128 - accuracy: 0.9853 - top5_acc: 0.9999 - macro_f1score: 0.2710 - val_loss: 1.4407 - val_accuracy: 0.7460 - val_top5_acc: 0.9345 - val_macro_f1score: 0.1994
# Learning rate:  0.0001
#
# Epoch 00048: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 48/70
# 1403/1403 [==============================] - ETA: 0s - loss: 0.2102 - accuracy: 0.9858 - top5_acc: 0.9998 - macro_f1score: 0.2705
# Epoch 00048: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_Xception/048.h5
#
# Epoch 00048: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_Xception/048.h5
# 1403/1403 [==============================] - 1123s 800ms/step - loss: 0.2102 - accuracy: 0.9858 - top5_acc: 0.9998 - macro_f1score: 0.2705 - val_loss: 1.4379 - val_accuracy: 0.7415 - val_top5_acc: 0.9318 - val_macro_f1score: 0.1977
# Learning rate:  0.0001
#
# Epoch 00049: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 49/70
# 1403/1403 [==============================] - ETA: 0s - loss: 0.2031 - accuracy: 0.9889 - top5_acc: 1.0000 - macro_f1score: 0.2720

# %%
# colab pro가 최대 24시간 돌아가므로, 그 한계로 인해 두번 나눠서 학습을봄.

# %%
model=load_model(os.path.join(dir,'model_output',number,'SE_Xception','048.h5'),custom_objects={"macro_f1score": macro_f1score,"top5_acc":top5_acc, "AdamW":AdamW})

# %%
# def lr_schedule(epoch):
#     init_lr = 1e-4
#     k = 0.04
#     lr = init_lr * np.exp(-k*epoch)
#     print('Learning rate: ', lr)
#     return lr

def lr_schedule(epoch):
    lr = 1e-4
    if epoch < 12:
        lr = lr
    else :
        lr = lr * 0.1
    print('Learning rate: ', lr)
    return lr

# %%
os.makedirs(os.path.join(dir,'model_output',number,'SUB',model.name), exist_ok=True) # 모델을 위에서 정의해야함

# %%
#optimizer = SGDW(model=model, use_cosine_annealing=False, total_iterations = len(x_train) // batch_sizes, nesterov=True, momentum=0.9)
optimizer = AdamW(model=model, use_cosine_annealing=False, total_iterations = len(x_train) // batch_sizes)
#optimizer = Adam()
filepath =  os.path.join(dir,'model_output',number,'SUB',model.name,'{epoch:03d}.h5')

callbacks_list = [ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_weights_only=False, save_best_only=True, mode='min'),
                  ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_weights_only=False, save_best_only=True, mode='max'),
                  #ReduceLROnPlateau(monitor='val_loss',patience=3,factor=0.1,min_lr=1e-5),
                  LearningRateScheduler(lr_schedule,verbose=1)
                  ]
                  
model.compile(optimizer, loss = 'categorical_crossentropy', metrics=['accuracy',top5_acc,macro_f1score])

# %%
######## flow_from_directory
history = model.fit(train_generator, steps_per_epoch=int(len(x_train)/batch_sizes),  validation_data = valid_generator, epochs=22 , verbose=1 , callbacks = callbacks_list , validation_steps=int(len(x_valid)/batch_sizes))
# Out:
# Learning rate:  0.0001
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 1/22
# 1403/1403 [==============================] - ETA: 0s - loss: 0.1974 - accuracy: 0.9899 - top5_acc: 1.0000 - macro_f1score: 0.2720
# Epoch 00001: val_loss improved from inf to 1.45980, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SUB/SE_Xception/001.h5
#
# Epoch 00001: val_accuracy improved from -inf to 0.74466, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SUB/SE_Xception/001.h5
# 1403/1403 [==============================] - 11932s 9s/step - loss: 0.1974 - accuracy: 0.9899 - top5_acc: 1.0000 - macro_f1score: 0.2720 - val_loss: 1.4598 - val_accuracy: 0.7447 - val_top5_acc: 0.9328 - val_macro_f1score: 0.2002
# Learning rate:  0.0001
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 2/22
# 1403/1403 [==============================] - ETA: 0s - loss: 0.2046 - accuracy: 0.9876 - top5_acc: 0.9999 - macro_f1score: 0.2707
# Epoch 00002: val_loss did not improve from 1.45980
#
# Epoch 00002: val_accuracy did not improve from 0.74466
# 1403/1403 [==============================] - 1174s 837ms/step - loss: 0.2046 - accuracy: 0.9876 - top5_acc: 0.9999 - macro_f1score: 0.2707 - val_loss: 1.4722 - val_accuracy: 0.7437 - val_top5_acc: 0.9335 - val_macro_f1score: 0.2008
# Learning rate:  0.0001
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 3/22
# 1403/1403 [==============================] - ETA: 0s - loss: 0.2018 - accuracy: 0.9880 - top5_acc: 0.9999 - macro_f1score: 0.2717
# Epoch 00003: val_loss did not improve from 1.45980
#
# Epoch 00003: val_accuracy improved from 0.74466 to 0.74486, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SUB/SE_Xception/003.h5
# 1403/1403 [==============================] - 1170s 834ms/step - loss: 0.2018 - accuracy: 0.9880 - top5_acc: 0.9999 - macro_f1score: 0.2717 - val_loss: 1.4749 - val_accuracy: 0.7449 - val_top5_acc: 0.9316 - val_macro_f1score: 0.1991
# Learning rate:  0.0001
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 4/22
# 1403/1403 [==============================] - ETA: 0s - loss: 0.1990 - accuracy: 0.9890 - top5_acc: 0.9998 - macro_f1score: 0.2712
# Epoch 00004: val_loss did not improve from 1.45980
#
# Epoch 00004: val_accuracy did not improve from 0.74486
# 1403/1403 [==============================] - 1166s 831ms/step - loss: 0.1990 - accuracy: 0.9890 - top5_acc: 0.9998 - macro_f1score: 0.2712 - val_loss: 1.4925 - val_accuracy: 0.7389 - val_top5_acc: 0.9310 - val_macro_f1score: 0.1985
# Learning rate:  0.0001
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 5/22
# 1403/1403 [==============================] - ETA: 0s - loss: 0.1974 - accuracy: 0.9887 - top5_acc: 0.9999 - macro_f1score: 0.2715
# Epoch 00005: val_loss did not improve from 1.45980
#
# Epoch 00005: val_accuracy did not improve from 0.74486
# 1403/1403 [==============================] - 1162s 828ms/step - loss: 0.1974 - accuracy: 0.9887 - top5_acc: 0.9999 - macro_f1score: 0.2715 - val_loss: 1.4876 - val_accuracy: 0.7427 - val_top5_acc: 0.9349 - val_macro_f1score: 0.1989
# Learning rate:  0.0001
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 6/22
# 1403/1403 [==============================] - ETA: 0s - loss: 0.1956 - accuracy: 0.9894 - top5_acc: 0.9999 - macro_f1score: 0.2714
# Epoch 00006: val_loss did not improve from 1.45980
#
# Epoch 00006: val_accuracy improved from 0.74486 to 0.74585, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SUB/SE_Xception/006.h5
# 1403/1403 [==============================] - 1174s 837ms/step - loss: 0.1956 - accuracy: 0.9894 - top5_acc: 0.9999 - macro_f1score: 0.2714 - val_loss: 1.4853 - val_accuracy: 0.7458 - val_top5_acc: 0.9337 - val_macro_f1score: 0.2027
# Learning rate:  0.0001
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 7/22
# 1403/1403 [==============================] - ETA: 0s - loss: 0.1930 - accuracy: 0.9903 - top5_acc: 0.9999 - macro_f1score: 0.2718
# Epoch 00007: val_loss did not improve from 1.45980
#
# Epoch 00007: val_accuracy did not improve from 0.74585
# 1403/1403 [==============================] - 1169s 833ms/step - loss: 0.1930 - accuracy: 0.9903 - top5_acc: 0.9999 - macro_f1score: 0.2718 - val_loss: 1.5117 - val_accuracy: 0.7445 - val_top5_acc: 0.9290 - val_macro_f1score: 0.1998
# Learning rate:  0.0001
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 8/22
# 1403/1403 [==============================] - ETA: 0s - loss: 0.1926 - accuracy: 0.9895 - top5_acc: 1.0000 - macro_f1score: 0.2720
# Epoch 00008: val_loss did not improve from 1.45980
#
# Epoch 00008: val_accuracy did not improve from 0.74585
# 1403/1403 [==============================] - 1160s 827ms/step - loss: 0.1926 - accuracy: 0.9895 - top5_acc: 1.0000 - macro_f1score: 0.2720 - val_loss: 1.4917 - val_accuracy: 0.7431 - val_top5_acc: 0.9330 - val_macro_f1score: 0.1991
# Learning rate:  0.0001
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 9/22
# 1403/1403 [==============================] - ETA: 0s - loss: 0.1901 - accuracy: 0.9902 - top5_acc: 0.9999 - macro_f1score: 0.2722
# Epoch 00009: val_loss did not improve from 1.45980
#
# Epoch 00009: val_accuracy did not improve from 0.74585
# 1403/1403 [==============================] - 1163s 829ms/step - loss: 0.1901 - accuracy: 0.9902 - top5_acc: 0.9999 - macro_f1score: 0.2722 - val_loss: 1.5043 - val_accuracy: 0.7447 - val_top5_acc: 0.9330 - val_macro_f1score: 0.2004
# Learning rate:  0.0001
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 10/22
# 1403/1403 [==============================] - ETA: 0s - loss: 0.1888 - accuracy: 0.9903 - top5_acc: 0.9999 - macro_f1score: 0.2728
# Epoch 00010: val_loss did not improve from 1.45980
#
# Epoch 00010: val_accuracy did not improve from 0.74585
# 1403/1403 [==============================] - 1165s 831ms/step - loss: 0.1888 - accuracy: 0.9903 - top5_acc: 0.9999 - macro_f1score: 0.2728 - val_loss: 1.5249 - val_accuracy: 0.7419 - val_top5_acc: 0.9274 - val_macro_f1score: 0.1976
# Learning rate:  0.0001
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 11/22
# 1403/1403 [==============================] - ETA: 0s - loss: 0.1889 - accuracy: 0.9904 - top5_acc: 1.0000 - macro_f1score: 0.2715
# Epoch 00011: val_loss did not improve from 1.45980
#
# Epoch 00011: val_accuracy improved from 0.74585 to 0.74684, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SUB/SE_Xception/011.h5
# 1403/1403 [==============================] - 1163s 829ms/step - loss: 0.1889 - accuracy: 0.9904 - top5_acc: 1.0000 - macro_f1score: 0.2715 - val_loss: 1.5025 - val_accuracy: 0.7468 - val_top5_acc: 0.9310 - val_macro_f1score: 0.2000
# Learning rate:  0.0001
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 12/22
# 1403/1403 [==============================] - ETA: 0s - loss: 0.1858 - accuracy: 0.9915 - top5_acc: 1.0000 - macro_f1score: 0.2730
# Epoch 00012: val_loss did not improve from 1.45980
#
# Epoch 00012: val_accuracy did not improve from 0.74684
# 1403/1403 [==============================] - 1158s 826ms/step - loss: 0.1858 - accuracy: 0.9915 - top5_acc: 1.0000 - macro_f1score: 0.2730 - val_loss: 1.5217 - val_accuracy: 0.7421 - val_top5_acc: 0.9337 - val_macro_f1score: 0.1993
# Learning rate:  1e-05
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 13/22
# 1403/1403 [==============================] - ETA: 0s - loss: 0.1827 - accuracy: 0.9922 - top5_acc: 0.9999 - macro_f1score: 0.2734
# Epoch 00013: val_loss did not improve from 1.45980
#
# Epoch 00013: val_accuracy did not improve from 0.74684
# 1403/1403 [==============================] - 1173s 836ms/step - loss: 0.1827 - accuracy: 0.9922 - top5_acc: 0.9999 - macro_f1score: 0.2734 - val_loss: 1.5044 - val_accuracy: 0.7464 - val_top5_acc: 0.9347 - val_macro_f1score: 0.2008
# Learning rate:  1e-05
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 14/22
# 1403/1403 [==============================] - ETA: 0s - loss: 0.1812 - accuracy: 0.9926 - top5_acc: 0.9999 - macro_f1score: 0.2731
# Epoch 00014: val_loss did not improve from 1.45980
#
# Epoch 00014: val_accuracy improved from 0.74684 to 0.74862, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SUB/SE_Xception/014.h5
# 1403/1403 [==============================] - 1163s 829ms/step - loss: 0.1812 - accuracy: 0.9926 - top5_acc: 0.9999 - macro_f1score: 0.2731 - val_loss: 1.4864 - val_accuracy: 0.7486 - val_top5_acc: 0.9353 - val_macro_f1score: 0.2007
# Learning rate:  1e-05
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 15/22
# 1403/1403 [==============================] - ETA: 0s - loss: 0.1825 - accuracy: 0.9916 - top5_acc: 0.9999 - macro_f1score: 0.2725
# Epoch 00015: val_loss did not improve from 1.45980
#
# Epoch 00015: val_accuracy did not improve from 0.74862
# 1403/1403 [==============================] - 1164s 830ms/step - loss: 0.1825 - accuracy: 0.9916 - top5_acc: 0.9999 - macro_f1score: 0.2725 - val_loss: 1.4928 - val_accuracy: 0.7480 - val_top5_acc: 0.9341 - val_macro_f1score: 0.2013
# Learning rate:  1e-05
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 16/22
# 1403/1403 [==============================] - ETA: 0s - loss: 0.1812 - accuracy: 0.9919 - top5_acc: 1.0000 - macro_f1score: 0.2724
# Epoch 00016: val_loss did not improve from 1.45980
#
# Epoch 00016: val_accuracy improved from 0.74862 to 0.74881, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SUB/SE_Xception/016.h5
# 1403/1403 [==============================] - 1161s 828ms/step - loss: 0.1812 - accuracy: 0.9919 - top5_acc: 1.0000 - macro_f1score: 0.2724 - val_loss: 1.4859 - val_accuracy: 0.7488 - val_top5_acc: 0.9339 - val_macro_f1score: 0.2010
# Learning rate:  1e-05
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 17/22
# 1403/1403 [==============================] - ETA: 0s - loss: 0.1786 - accuracy: 0.9927 - top5_acc: 1.0000 - macro_f1score: 0.2727
# Epoch 00017: val_loss did not improve from 1.45980
#
# Epoch 00017: val_accuracy improved from 0.74881 to 0.74941, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SUB/SE_Xception/017.h5
# 1403/1403 [==============================] - 1166s 831ms/step - loss: 0.1786 - accuracy: 0.9927 - top5_acc: 1.0000 - macro_f1score: 0.2727 - val_loss: 1.4791 - val_accuracy: 0.7494 - val_top5_acc: 0.9343 - val_macro_f1score: 0.2032
# Learning rate:  1e-05
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 18/22
# 1403/1403 [==============================] - ETA: 0s - loss: 0.1794 - accuracy: 0.9925 - top5_acc: 0.9999 - macro_f1score: 0.2728
# Epoch 00018: val_loss did not improve from 1.45980
#
# Epoch 00018: val_accuracy did not improve from 0.74941
# 1403/1403 [==============================] - 1157s 825ms/step - loss: 0.1794 - accuracy: 0.9925 - top5_acc: 0.9999 - macro_f1score: 0.2728 - val_loss: 1.4768 - val_accuracy: 0.7486 - val_top5_acc: 0.9349 - val_macro_f1score: 0.1995
# Learning rate:  1e-05
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 19/22
# 1403/1403 [==============================] - ETA: 0s - loss: 0.1794 - accuracy: 0.9922 - top5_acc: 1.0000 - macro_f1score: 0.2726
# Epoch 00019: val_loss did not improve from 1.45980
#
# Epoch 00019: val_accuracy did not improve from 0.74941
# 1403/1403 [==============================] - 1169s 833ms/step - loss: 0.1794 - accuracy: 0.9922 - top5_acc: 1.0000 - macro_f1score: 0.2726 - val_loss: 1.4818 - val_accuracy: 0.7480 - val_top5_acc: 0.9328 - val_macro_f1score: 0.2013
# Learning rate:  1e-05
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 20/22
# 1403/1403 [==============================] - ETA: 0s - loss: 0.1783 - accuracy: 0.9932 - top5_acc: 1.0000 - macro_f1score: 0.2731
# Epoch 00020: val_loss did not improve from 1.45980
#
# Epoch 00020: val_accuracy improved from 0.74941 to 0.75020, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SUB/SE_Xception/020.h5
# 1403/1403 [==============================] - 1179s 840ms/step - loss: 0.1783 - accuracy: 0.9932 - top5_acc: 1.0000 - macro_f1score: 0.2731 - val_loss: 1.4782 - val_accuracy: 0.7502 - val_top5_acc: 0.9335 - val_macro_f1score: 0.2042
# Learning rate:  1e-05
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 21/22
# 1403/1403 [==============================] - ETA: 0s - loss: 0.1759 - accuracy: 0.9939 - top5_acc: 0.9999 - macro_f1score: 0.2728
# Epoch 00021: val_loss did not improve from 1.45980
#
# Epoch 00021: val_accuracy did not improve from 0.75020
# 1403/1403 [==============================] - 1188s 847ms/step - loss: 0.1759 - accuracy: 0.9939 - top5_acc: 0.9999 - macro_f1score: 0.2728 - val_loss: 1.4781 - val_accuracy: 0.7502 - val_top5_acc: 0.9337 - val_macro_f1score: 0.2025
# Learning rate:  1e-05
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 22/22
# 1403/1403 [==============================] - ETA: 0s - loss: 0.1784 - accuracy: 0.9933 - top5_acc: 1.0000 - macro_f1score: 0.2730
# Epoch 00022: val_loss did not improve from 1.45980
#
# Epoch 00022: val_accuracy improved from 0.75020 to 0.75218, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SUB/SE_Xception/022.h5
# 1403/1403 [==============================] - 1200s 856ms/step - loss: 0.1784 - accuracy: 0.9933 - top5_acc: 1.0000 - macro_f1score: 0.2730 - val_loss: 1.4811 - val_accuracy: 0.7522 - val_top5_acc: 0.9337 - val_macro_f1score: 0.2021

# %% [markdown]
# ### 3) SE-Xception Evaluate

# %%
# 1. epoch=maximum
loss , acc, top5_acc, mf1 = model.evaluate(test_generator,steps=int(len(x_test)/batch_sizes))
print('[Test Loss: %.4f /  Test Top-1 Accuracy: %.4f / Test Top-5 Accuracy: %.4f / Test Macro f1: %.4f]\n' % (loss,acc,top5_acc,mf1))
# Out:
# 312/312 [==============================] - 1629s 5s/step - loss: 1.5210 - accuracy: 0.7515 - top5_acc: 0.9332 - macro_f1score: 0.2017
# [Test Loss: 1.5210 /  Test Top-1 Accuracy: 0.7515 / Test Top-5 Accuracy: 0.9332 / Test Macro f1: 0.2017]

# %%
loss=history.history['loss']
val_loss=history.history['val_loss']
acc=history.history['accuracy']
val_acc=history.history['val_accuracy']
top5_acc=history.history['top5_acc']
val_top5_acc=history.history['val_top5_acc']
f1=history.history['macro_f1score']
val_f1=history.history['val_macro_f1score']
epochs=range(1,len(acc)+1)

data = np.array([epochs,loss,val_loss,acc,val_acc,top5_acc,val_top5_acc,f1,val_f1]).T

# %%
# data save
# epochs, loss, val_loss, acc, val_acc, f1, val_f1

np.savetxt(os.path.join(dir,'train_valid_output',number,model.name+'.txt'),data)

# %%
# data import
data = np.loadtxt(os.path.join(dir,'train_valid_output',number,'SE_Xception.txt'))

# %%
epochs=data[:,0]
loss=data[:,1]
val_loss=data[:,2]
acc=data[:,3]
val_acc=data[:,4]
top5_acc=data[:,5]
val_top5_acc=data[:,6]

# %%
plt.plot(epochs[1:],acc[1:],'b',label='Training 1-Acc')
plt.plot(epochs[1:],val_acc[1:],'r',label='Validation 1-Acc')
plt.title('Training and Validation Top-1 Accuracy')
plt.legend()
plt.figure()

plt.plot(epochs[1:],top5_acc[1:],'b',label='Training 5-Acc')
plt.plot(epochs[1:],val_top5_acc[1:],'r',label='Validation 5-Acc')
plt.title('Training and Validation Top-5 Accuracy')
plt.legend()
plt.figure()

plt.plot(epochs[10:],loss[10:],'b',label='Training Loss')
plt.plot(epochs[10:],val_loss[10:],'r',label='Validation Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()

# %%
# 이 아래는 내가 인위적으로 살펴보고 싶은 epoch에 대해서 결과값 출력 / SE-Xception

# %%
# 참고 : https://github.com/OverLordGoldDragon/keras-adamw

import sys
sys.path.append('/content/drive/My Drive/Colab Notebooks/Paper')
import utils
import optimizers_v2
from utils import get_weight_decays, fill_dict_in_order
from utils import reset_seeds, K_eval
from optimizers_v2 import AdamW, NadamW, SGDW

# %%
# top-5 accuracy 출력
import functools
top5_acc = functools.partial(ks.metrics.top_k_categorical_accuracy, k=5)
top5_acc.__name__ = 'top5_acc'

# %%
model=load_model(os.path.join(dir,'model_output',number,'SUB','SE_Xception','022.h5'),custom_objects={"macro_f1score": macro_f1score,"top5_acc":top5_acc, "AdamW":AdamW})

# %%
# 2. epoch=?
loss , acc, mf1, wf1 = model.evaluate(test_generator,steps=int(len(x_test)/batch_sizes))
print('[Test Loss: %.4f /  Test Accuracy: %.4f / Test Macro f1: %.4f / Test Weighted f1: %.4f]\n' % (loss,acc,mf1,wf1))
# Out:
# 312/312 [==============================] - 4783s 15s/step - loss: 1.5243 - accuracy: 0.7511 - top5_acc: 0.9331 - macro_f1score: 0.2013
# [Test Loss: 1.5243 /  Test Accuracy: 0.7511 / Test Macro f1: 0.9331 / Test Weighted f1: 0.2013]
