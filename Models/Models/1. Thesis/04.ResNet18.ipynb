# %%
#모형 출처 : https://github.com/titu1994/keras-squeeze-excite-network

# %% [markdown]
# # [ResNet18]

# %% [markdown]
# *KU LeeDongGyu*

# %% [markdown]
# ## Contents
# ---

# %% [markdown]
# 1. Data Preprocessing
# ```
# 1) Data Import
# 2) Data Augmentation
# ```
# 2. Support Functions & Almost Original ResNet
# ```
# 1) Support Functions
# 2) Almost orginal ResNet
# ```
# 3. ResNet18
# ```
# 1) ResNet18
# 2) ResNet18 Evaluate
# ```

# %% [markdown]
# ### Install Packages

# %% [markdown]
# ### Module

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
cd /content/drive/My Drive/Colab Notebooks/Paper
# Out:
# /content/drive/My Drive/Colab Notebooks/Paper

# %%
from f1score import macro_f1score,weighted_f1score

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import cv2
import tensorflow as tf
from tensorflow import keras as ks
from tensorflow.keras import backend as K 
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, Input, Concatenate, ZeroPadding2D ,GlobalMaxPooling2D, Reshape , Lambda , Add, Multiply
from tensorflow.keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D, Activation, BatchNormalization, AveragePooling2D , ZeroPadding2D, SeparableConv2D , LeakyReLU
from tensorflow.keras.layers import add, concatenate, multiply
from tensorflow.keras.optimizers import Adam, RMSprop , SGD
from tensorflow.keras.callbacks import EarlyStopping , LearningRateScheduler, ModelCheckpoint, CSVLogger, Callback, ReduceLROnPlateau
from tensorflow.keras.regularizers import l1,l2,l1_l2
from tensorflow.keras.models import Model , load_model , Sequential
from tensorflow.keras.utils import plot_model , to_categorical, get_file
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
os.getcwd()
# Out:
# '/content/drive/My Drive/Colab Notebooks/Paper'

# %%
print(tf.__version__)
print(ks.__version__)
# Out:
# 2.3.0
# 2.4.0

# %%
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 2560039966989342324
# , name: "/device:XLA_CPU:0"
# device_type: "XLA_CPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 15720553239528272639
# physical_device_desc: "device: XLA_CPU device"
# , name: "/device:XLA_GPU:0"
# device_type: "XLA_GPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 3235998116713169059
# physical_device_desc: "device: XLA_GPU device"
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 15695549568
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 8302763619005852512
# physical_device_desc: "device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0"
# ]

# %%
# !cat /proc/cpuinfo
# Out:
# processor	: 0
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 79
# model name	: Intel(R) Xeon(R) CPU @ 2.20GHz
# stepping	: 0
# microcode	: 0x1
# cpu MHz		: 2200.000
# cache size	: 56320 KB
# physical id	: 0
# siblings	: 4
# core id		: 0
# cpu cores	: 2
# apicid		: 0
# initial apicid	: 0
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm rdseed adx smap xsaveopt arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs taa
# bogomips	: 4400.00
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 46 bits physical, 48 bits virtual
# power management:
#
# processor	: 1
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 79
# model name	: Intel(R) Xeon(R) CPU @ 2.20GHz
# stepping	: 0
# microcode	: 0x1
# cpu MHz		: 2200.000
# cache size	: 56320 KB
# physical id	: 0
# siblings	: 4
# core id		: 1
# cpu cores	: 2
# apicid		: 2
# initial apicid	: 2
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm rdseed adx smap xsaveopt arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs taa
# bogomips	: 4400.00
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 46 bits physical, 48 bits virtual
# power management:
#
# processor	: 2
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 79
# model name	: Intel(R) Xeon(R) CPU @ 2.20GHz
# stepping	: 0
# microcode	: 0x1
# cpu MHz		: 2200.000
# cache size	: 56320 KB
# physical id	: 0
# siblings	: 4
# core id		: 0
# cpu cores	: 2
# apicid		: 1
# initial apicid	: 1
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm rdseed adx smap xsaveopt arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs taa
# bogomips	: 4400.00
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 46 bits physical, 48 bits virtual
# power management:
#
# processor	: 3
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 79
# model name	: Intel(R) Xeon(R) CPU @ 2.20GHz
# stepping	: 0
# microcode	: 0x1
# cpu MHz		: 2200.000
# cache size	: 56320 KB
# physical id	: 0
# siblings	: 4
# core id		: 1
# cpu cores	: 2
# apicid		: 3
# initial apicid	: 3
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm rdseed adx smap xsaveopt arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs taa
# bogomips	: 4400.00
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 46 bits physical, 48 bits virtual
# power management:

# %% [markdown]
# ## 1. Data Preprocessing
# ---

# %% [markdown]
# ### 1) Data Import

# %%
# 바꿔서 살펴 볼 것들
# CALTECH, CIFAR100, FER, MIT
data_name = 'CALTECH'
gan_type = 'No_GAN'
number = '1'
size = 224 # sizes after cropping
super_size = 256 # sizes before cropping 
input_sizes = (size,size,3)
batch_sizes = 128
weight_decay = 2e-3
epochs = 70

# %%
# 참고 : https://stackoverflow.com/questions/32419510/how-to-get-reproducible-results-in-keras/52897216#52897216
# setting the seed number for random number generation for reproducibility.

from numpy.random import seed
import random


if number=='1':
    seed_num = 200225
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)
elif number=='2':
    seed_num = 727
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)
elif number=='3':
    seed_num = 115
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)
elif number=='4':
    seed_num = 501
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)
elif number=='5':
    seed_num = 517
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)

# %%
# data import

if data_name=='FER' :
    x_train =  np.zeros(28698)
    x_valid = np.zeros(3589)
    x_test = np.zeros(3588)
    classes = 7 
    tr_center = [0.50793296, 0.50793296, 0.50793296]
elif data_name=='MIT':
    x_train = np.zeros(12466)
    x_valid = np.zeros(1564)
    x_test = np.zeros(1590)
    classes = 67 
    tr_center = [0.47916578, 0.42029615, 0.36046057]
elif data_name=='CALTECH':
    x_train = np.zeros(24510)
    x_valid = np.zeros(2980)
    x_test = np.zeros(3118)
    classes = 257
    tr_center = [0.51397761, 0.49525248, 0.46555727]
elif data_name=='CIFAR100':
    x_train = np.zeros(44923)
    x_valid = np.zeros(5077)
    x_test = np.zeros(10000)
    classes = 100
    tr_center = [0.53442983, 0.51355958, 0.46462564]

# %%
dir = os.path.join(os.getcwd(),data_name,gan_type)

# %% [markdown]
# ### 2) Data Augmentation

# %%
# 참고 : https://jkjung-avt.github.io/keras-image-cropping/

def random_crop(img, random_crop_size):
    # Note: image_data_format is 'channel_last'
    assert img.shape[2] == 3 # img.shape[2] 가 3(rgb)이 아니면 assertion error 발생
    height, width = img.shape[0], img.shape[1]
    dy, dx = random_crop_size
    x = np.random.randint(0, width - dx + 1)
    y = np.random.randint(0, height - dy + 1)
    return img[y:(y+dy), x:(x+dx), :]


def crop_generator(batches, crop_length):
    """Take as input a Keras ImageGen (Iterator) and generate random
    crops from the image batches generated by the original iterator.
    """
    while True:
        batch_x, batch_y = next(batches)
        batch_crops = np.zeros((batch_x.shape[0], crop_length, crop_length, 3))
        for i in range(batch_x.shape[0]):
            batch_crops[i] = random_crop(batch_x[i], (crop_length, crop_length))
        yield (batch_crops, batch_y)

# %%
from tensorflow.keras.preprocessing.image import img_to_array,load_img
import glob

# 데이터 전체에 대해 centering 진행함.

def read_cal_image(img_path): 
    x = img_to_array(load_img(img_path)) # x는 채널별 평균값
    y = x.shape[0] * x.shape[1]# y는 데이터별 픽셀 수 (비중)

    x = 1/255. * x # scaling하고, centering값을 뽑아냄.
    x = np.mean(x, axis=(0,1))
    
    return np.hstack([x,y])

def calculate_centered_mean(dataset_path,x_train=x_train):
    num = len(x_train)
    space = np.empty((num,4))
    i=0

    for p in glob.glob(os.path.join(dataset_path,'*/*.*')) :
        space[i] = read_cal_image(p)
        i += 1

    ratio = space[:,3] / np.sum(space[:,3])

    return np.average(space[:,0:3],axis=0,weights=ratio)


# 아래의 함수를 돌려서 나온 결과값을 중심화 값으로 설정.

# train_mean = calculate_centered_mean(os.path.join(dir,'data/train')).reshape((1,1,3))

# %%
datagen_tr = ImageDataGenerator(
    rescale=1/255.,
    horizontal_flip=True,
    featurewise_center=True,
    featurewise_std_normalization=False,
    rotation_range=10,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=[0.9,1.0],
    fill_mode = 'nearest')
datagen_val = ImageDataGenerator(rescale=1/255.,featurewise_center=True)
datagen_tes = ImageDataGenerator(rescale=1/255.,featurewise_center=True)

# 원래는 이 자리에 fit 매서드를 써야하지만, 그냥 내가 중심화함수를 만들고 적용함. 

# 중심화 설정
datagen_tr.mean = np.array(tr_center, dtype=np.float32).reshape((1,1,3)) # RGB
datagen_val.mean = np.array(tr_center, dtype=np.float32).reshape((1,1,3)) # RGB
datagen_tes.mean = np.array(tr_center, dtype=np.float32).reshape((1,1,3)) # RGB

# %%
train_batches = datagen_tr.flow_from_directory(directory=os.path.join(dir,'data/train'),target_size=(super_size,super_size),batch_size=batch_sizes,class_mode='categorical') # fer : 28698 / mit : 12466 / caltech : 24509 / cifar : 44923
train_generator= crop_generator(train_batches, size)
valid_generator = datagen_val.flow_from_directory(directory=os.path.join(dir,'data/valid'),target_size=(size,size),batch_size=batch_sizes,class_mode='categorical') # fer : 3589 / mit : 1564 / caltech : 2980 / cifar : 5077
test_generator = datagen_tes.flow_from_directory(directory=os.path.join(dir,'data/test'),target_size=(size,size),batch_size=batch_sizes,class_mode='categorical') # fer : 3588 / mit : 1590 / caltech : 3118 / cifar : 10000
# Out:
# Found 24509 images belonging to 257 classes.
# Found 2980 images belonging to 257 classes.
# Found 3118 images belonging to 257 classes.

# %% [markdown]
# ## 2. Support Functions & Almost Original ResNet
# ---

# %% [markdown]
# ### 1) Support Functions

# %%
# def lr_schedule(epoch):
#     init_lr = 1e-4
#     k = 0.04
#     lr = init_lr * np.exp(-k*epoch)
#     print('Learning rate: ', lr)
#     return lr

def lr_schedule(epoch):
    lr = 1e-3
    if epoch < 30:
        lr = lr
    elif epoch < 60 :
        lr = lr * 0.1
    else:
        lr = lr * 0.01
    print('Learning rate: ', lr)
    return lr

# %%
def _resnet_block(input_tensor, filters, k=1, strides=(1, 1), weight_decay = weight_decay):

    init = input_tensor
    channel_axis = -1

    if strides != (1, 1) or init.get_shape()[channel_axis] != filters * k:
        x = Conv2D(filters * k, (1, 1), padding='same', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay),
                      use_bias=False, strides=strides)(input_tensor)
        init = BatchNormalization(axis=channel_axis)(x)


    x = Conv2D(filters * k, (3, 3), padding='same', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay),
               use_bias=False, strides=strides)(input_tensor)
    x = BatchNormalization(axis=channel_axis)(x)
    x = Activation('relu')(x)

    x = Conv2D(filters * k, (3, 3), padding='same', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay),
               use_bias=False)(x)
    x = BatchNormalization(axis=channel_axis)(x)

    m = add([x, init])
    m = Activation('relu')(m)

    return m

# %%
def _resnet_bottleneck_block(input_tensor, filters, k=1, strides=(1, 1), weight_decay = weight_decay):

    init = input_tensor
    channel_axis = -1
    bottleneck_expand = 4

    if strides != (1, 1) or init.get_shape()[channel_axis] != bottleneck_expand * filters * k:
        x = Conv2D(bottleneck_expand * filters * k, (1, 1), padding='same', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay),
                      use_bias=False, strides=strides)(input_tensor)
        init = BatchNormalization(axis=channel_axis)(x)


    x = Conv2D(filters * k, (1, 1), padding='same', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay),
               use_bias=False)(input_tensor)
    x = BatchNormalization(axis=channel_axis)(x)
    x = Activation('relu')(x)

    x = Conv2D(filters * k, (3, 3), padding='same', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay),
               use_bias=False, strides=strides)(x)
    x = BatchNormalization(axis=channel_axis)(x)
    x = Activation('relu')(x)

    x = Conv2D(bottleneck_expand * filters * k, (1, 1), padding='same', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay),
               use_bias=False)(x)
    x = BatchNormalization(axis=channel_axis)(x)    

    m = add([x, init])
    m = Activation('relu')(m)

    return m

# %% [markdown]
# ### 2) Almost Orginial ResNet

# %%
def _create_resnet(classes, img_input, initial_conv_filters, filters, depth, width, bottleneck, weight_decay):

    channel_axis = -1
    N = list(depth)

    # block 1 (initial conv block)
    x = Conv2D(initial_conv_filters, (7, 7), padding='same', use_bias=False, strides=(2, 2), kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(img_input)
    x = MaxPooling2D((3, 3), strides=(2, 2), padding='same')(x)

    # block 2 (projection block)
    for i in range(N[0]):
        if bottleneck:
            x = _resnet_bottleneck_block(x, filters[0], width)
        else:
            x = _resnet_block(x, filters[0], width)

    # block 3 - N
    for k in range(1, len(N)):
        if bottleneck:
            x = _resnet_bottleneck_block(x, filters[k], width, strides=(2, 2))
        else:
            x = _resnet_block(x, filters[k], width, strides=(2, 2))

        for i in range(N[k] - 1):
            if bottleneck:
                x = _resnet_bottleneck_block(x, filters[k], width)
            else:
                x = _resnet_block(x, filters[k], width)

    x = GlobalAveragePooling2D()(x)
    x = Dense(classes, use_bias=False, kernel_regularizer=l2(weight_decay), activation='softmax')(x)


    return x

# %%
def ResNet(input_shape=None, initial_conv_filters=64, depth=[3, 4, 6, 3], filters=[64, 128, 256, 512],
             width=1, bottleneck=False, weight_decay=weight_decay, name=None, classes=1000):


    img_input = Input(shape=input_shape)

    x = _create_resnet(classes, img_input, initial_conv_filters, filters, depth, width, bottleneck, weight_decay)

    # Ensure that the model takes into account
    # any potential predecessors of `input_tensor`.

    inputs = img_input

    # Create model.
    model = Model(inputs, x, name = name)

    return model

# %% [markdown]
# ## 3. ResNet18
# ---

# %% [markdown]
# ### 1) ResNet18

# %%
# ResNet18
model = ResNet(input_shape=input_sizes, depth=[2, 2, 2, 2], width=1, bottleneck=False, weight_decay=weight_decay, classes=classes, name='ResNet18')

# %%
model.summary()
# Out:
# Model: "ResNet18"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 112, 112, 64) 9408        input_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 56, 56, 64)   0           conv2d[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 56, 56, 64)   36864       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 56, 56, 64)   256         conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 56, 56, 64)   0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 56, 56, 64)   36864       activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 56, 56, 64)   256         conv2d_2[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 56, 56, 64)   0           batch_normalization_1[0][0]
#                                                                  max_pooling2d[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 56, 56, 64)   0           add[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 56, 56, 64)   36864       activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 56, 56, 64)   256         conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 56, 56, 64)   0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 56, 56, 64)   36864       activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 56, 56, 64)   256         conv2d_4[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 56, 56, 64)   0           batch_normalization_3[0][0]
#                                                                  activation_1[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 56, 56, 64)   0           add_1[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 28, 28, 128)  73728       activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 28, 28, 128)  512         conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 28, 28, 128)  0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 28, 28, 128)  147456      activation_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 28, 28, 128)  8192        activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 28, 28, 128)  512         conv2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 28, 28, 128)  512         conv2d_5[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 28, 28, 128)  0           batch_normalization_6[0][0]
#                                                                  batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 28, 28, 128)  0           add_2[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 28, 28, 128)  147456      activation_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 28, 28, 128)  512         conv2d_8[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 28, 28, 128)  0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 28, 28, 128)  147456      activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 28, 28, 128)  512         conv2d_9[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 28, 28, 128)  0           batch_normalization_8[0][0]
#                                                                  activation_5[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 28, 28, 128)  0           add_3[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 14, 14, 256)  294912      activation_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 14, 14, 256)  1024        conv2d_11[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 14, 14, 256)  0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 14, 14, 256)  589824      activation_8[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 14, 14, 256)  32768       activation_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 14, 14, 256)  1024        conv2d_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 14, 14, 256)  1024        conv2d_10[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 14, 14, 256)  0           batch_normalization_11[0][0]
#                                                                  batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 14, 14, 256)  0           add_4[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 14, 14, 256)  589824      activation_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 14, 14, 256)  1024        conv2d_13[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 14, 14, 256)  0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 14, 14, 256)  589824      activation_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 14, 14, 256)  1024        conv2d_14[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 14, 14, 256)  0           batch_normalization_13[0][0]
#                                                                  activation_9[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 14, 14, 256)  0           add_5[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 7, 7, 512)    1179648     activation_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 7, 7, 512)    2048        conv2d_16[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 7, 7, 512)    0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 7, 7, 512)    2359296     activation_12[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 7, 7, 512)    131072      activation_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 7, 7, 512)    2048        conv2d_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 7, 7, 512)    2048        conv2d_15[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 7, 7, 512)    0           batch_normalization_16[0][0]
#                                                                  batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 7, 7, 512)    0           add_6[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 7, 7, 512)    2359296     activation_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 7, 7, 512)    2048        conv2d_18[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 7, 7, 512)    0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 7, 7, 512)    2359296     activation_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 7, 7, 512)    2048        conv2d_19[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 7, 7, 512)    0           batch_normalization_18[0][0]
#                                                                  activation_13[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 7, 7, 512)    0           add_7[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 512)          0           activation_15[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 257)          131584      global_average_pooling2d[0][0]
# ==================================================================================================
# Total params: 11,317,440
# Trainable params: 11,307,968
# Non-trainable params: 9,472
# __________________________________________________________________________________________________

# %%
# 폴더 생성

os.makedirs(os.path.join(dir,'model_output',number,model.name), exist_ok=True)
os.makedirs(os.path.join(dir,'train_valid_output',number), exist_ok=True)

# %%
# 참고 : https://github.com/OverLordGoldDragon/keras-adamw

import sys
sys.path.append('/content/drive/My Drive/Colab Notebooks/Paper')
import utils
import optimizers_v2
from utils import get_weight_decays, fill_dict_in_order
from utils import reset_seeds, K_eval
from optimizers_v2 import AdamW, NadamW, SGDW

# %%
# top-5 accuracy 출력
import functools
top5_acc = functools.partial(ks.metrics.top_k_categorical_accuracy, k=5)
top5_acc.__name__ = 'top5_acc'

# %%
#optimizer = SGDW(model=model, use_cosine_annealing=False, total_iterations = len(x_train) // batch_sizes, nesterov=True, momentum=0.9)
optimizer = AdamW(model=model, use_cosine_annealing=False, total_iterations = len(x_train) // batch_sizes)
#optimizer = Adam()
filepath =  os.path.join(dir,'model_output',number,model.name,'{epoch:03d}.h5')

callbacks_list = [ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_weights_only=False, save_best_only=True, mode='min'),
                  ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_weights_only=False, save_best_only=True, mode='max'),
                  #ReduceLROnPlateau(monitor='val_loss',patience=3,factor=0.1,min_lr=1e-5),
                  LearningRateScheduler(lr_schedule,verbose=1)
                  ]
                  
model.compile(optimizer, loss = 'categorical_crossentropy', metrics=['accuracy',top5_acc,macro_f1score])

# %%
######## flow_from_directory
history = model.fit(train_generator, steps_per_epoch=int(len(x_train)/batch_sizes),  validation_data = valid_generator, epochs=epochs , verbose=1 , callbacks = callbacks_list , validation_steps=int(len(x_valid)/batch_sizes))
# Out:
# Learning rate:  0.001
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 1/70
# 0.0(L1), 0.00014471492793207425(L2) weight decay set for conv2d/kernel:0
# 0.0(L1), 0.00014471492793207425(L2) weight decay set for conv2d_1/kernel:0
# 0.0(L1), 0.00014471492793207425(L2) weight decay set for conv2d_2/kernel:0
# 0.0(L1), 0.00014471492793207425(L2) weight decay set for conv2d_3/kernel:0
# 0.0(L1), 0.00014471492793207425(L2) weight decay set for conv2d_4/kernel:0
# 0.0(L1), 0.00014471492793207425(L2) weight decay set for conv2d_6/kernel:0
# 0.0(L1), 0.00014471492793207425(L2) weight decay set for conv2d_7/kernel:0
# 0.0(L1), 0.00014471492793207425(L2) weight decay set for conv2d_5/kernel:0
# 0.0(L1), 0.00014471492793207425(L2) weight decay set for conv2d_8/kernel:0
# 0.0(L1), 0.00014471492793207425(L2) weight decay set for conv2d_9/kernel:0
# 0.0(L1), 0.00014471492793207425(L2) weight decay set for conv2d_11/kernel:0
# 0.0(L1), 0.00014471492793207425(L2) weight decay set for conv2d_12/kernel:0
# 0.0(L1), 0.00014471492793207425(L2) weight decay set for conv2d_10/kernel:0
# 0.0(L1), 0.00014471492793207425(L2) weight decay set for conv2d_13/kernel:0
# 0.0(L1), 0.00014471492793207425(L2) weight decay set for conv2d_14/kernel:0
# 0.0(L1), 0.00014471492793207425(L2) weight decay set for conv2d_16/kernel:0
# 0.0(L1), 0.00014471492793207425(L2) weight decay set for conv2d_17/kernel:0
# 0.0(L1), 0.00014471492793207425(L2) weight decay set for conv2d_15/kernel:0
# 0.0(L1), 0.00014471492793207425(L2) weight decay set for conv2d_18/kernel:0
# 0.0(L1), 0.00014471492793207425(L2) weight decay set for conv2d_19/kernel:0
# 0.0(L1), 0.00014471492793207425(L2) weight decay set for dense/kernel:0
# 191/191 [==============================] - ETA: 0s - loss: 4.9228 - accuracy: 0.0986 - top5_acc: 0.2021 - macro_f1score: 0.0040
# Epoch 00001: val_loss improved from inf to 8.24660, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/ResNet18/001.h5
#
# Epoch 00001: val_accuracy improved from -inf to 0.03125, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/ResNet18/001.h5
# 191/191 [==============================] - 10041s 53s/step - loss: 4.9228 - accuracy: 0.0986 - top5_acc: 0.2021 - macro_f1score: 0.0040 - val_loss: 8.2466 - val_accuracy: 0.0312 - val_top5_acc: 0.0910 - val_macro_f1score: 0.0017
# Learning rate:  0.001
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 2/70
# 191/191 [==============================] - ETA: 0s - loss: 4.2867 - accuracy: 0.1606 - top5_acc: 0.3107 - macro_f1score: 0.0108
# Epoch 00002: val_loss improved from 8.24660 to 5.65888, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/ResNet18/002.h5
#
# Epoch 00002: val_accuracy improved from 0.03125 to 0.09715, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/ResNet18/002.h5
# 191/191 [==============================] - 395s 2s/step - loss: 4.2867 - accuracy: 0.1606 - top5_acc: 0.3107 - macro_f1score: 0.0108 - val_loss: 5.6589 - val_accuracy: 0.0971 - val_top5_acc: 0.2340 - val_macro_f1score: 0.0081
# Learning rate:  0.001
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 3/70
# 191/191 [==============================] - ETA: 0s - loss: 3.9146 - accuracy: 0.2030 - top5_acc: 0.3776 - macro_f1score: 0.0171
# Epoch 00003: val_loss improved from 5.65888 to 4.47150, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/ResNet18/003.h5
#
# Epoch 00003: val_accuracy improved from 0.09715 to 0.14470, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/ResNet18/003.h5
# 191/191 [==============================] - 383s 2s/step - loss: 3.9146 - accuracy: 0.2030 - top5_acc: 0.3776 - macro_f1score: 0.0171 - val_loss: 4.4715 - val_accuracy: 0.1447 - val_top5_acc: 0.3071 - val_macro_f1score: 0.0127
# Learning rate:  0.001
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 4/70
# 191/191 [==============================] - ETA: 0s - loss: 3.5725 - accuracy: 0.2514 - top5_acc: 0.4546 - macro_f1score: 0.0268
# Epoch 00004: val_loss did not improve from 4.47150
#
# Epoch 00004: val_accuracy improved from 0.14470 to 0.17018, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/ResNet18/004.h5
# 191/191 [==============================] - 380s 2s/step - loss: 3.5725 - accuracy: 0.2514 - top5_acc: 0.4546 - macro_f1score: 0.0268 - val_loss: 4.6176 - val_accuracy: 0.1702 - val_top5_acc: 0.3539 - val_macro_f1score: 0.0198
# Learning rate:  0.001
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 5/70
# 191/191 [==============================] - ETA: 0s - loss: 3.2730 - accuracy: 0.2961 - top5_acc: 0.5168 - macro_f1score: 0.0364
# Epoch 00005: val_loss improved from 4.47150 to 4.23373, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/ResNet18/005.h5
#
# Epoch 00005: val_accuracy improved from 0.17018 to 0.19803, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/ResNet18/005.h5
# 191/191 [==============================] - 379s 2s/step - loss: 3.2730 - accuracy: 0.2961 - top5_acc: 0.5168 - macro_f1score: 0.0364 - val_loss: 4.2337 - val_accuracy: 0.1980 - val_top5_acc: 0.3587 - val_macro_f1score: 0.0266
# Learning rate:  0.001
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 6/70
# 191/191 [==============================] - ETA: 0s - loss: 3.0125 - accuracy: 0.3400 - top5_acc: 0.5702 - macro_f1score: 0.0483
# Epoch 00006: val_loss improved from 4.23373 to 3.66363, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/ResNet18/006.h5
#
# Epoch 00006: val_accuracy improved from 0.19803 to 0.26019, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/ResNet18/006.h5
# 191/191 [==============================] - 376s 2s/step - loss: 3.0125 - accuracy: 0.3400 - top5_acc: 0.5702 - macro_f1score: 0.0483 - val_loss: 3.6636 - val_accuracy: 0.2602 - val_top5_acc: 0.4589 - val_macro_f1score: 0.0410
# Learning rate:  0.001
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 7/70
# 191/191 [==============================] - ETA: 0s - loss: 2.7844 - accuracy: 0.3785 - top5_acc: 0.6107 - macro_f1score: 0.0612
# Epoch 00007: val_loss did not improve from 3.66363
#
# Epoch 00007: val_accuracy did not improve from 0.26019
# 191/191 [==============================] - 377s 2s/step - loss: 2.7844 - accuracy: 0.3785 - top5_acc: 0.6107 - macro_f1score: 0.0612 - val_loss: 3.8058 - val_accuracy: 0.2544 - val_top5_acc: 0.4715 - val_macro_f1score: 0.0448
# Learning rate:  0.001
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 8/70
# 191/191 [==============================] - ETA: 0s - loss: 2.5858 - accuracy: 0.4103 - top5_acc: 0.6546 - macro_f1score: 0.0737
# Epoch 00008: val_loss improved from 3.66363 to 3.40317, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/ResNet18/008.h5
#
# Epoch 00008: val_accuracy improved from 0.26019 to 0.28668, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/ResNet18/008.h5
# 191/191 [==============================] - 379s 2s/step - loss: 2.5858 - accuracy: 0.4103 - top5_acc: 0.6546 - macro_f1score: 0.0737 - val_loss: 3.4032 - val_accuracy: 0.2867 - val_top5_acc: 0.5190 - val_macro_f1score: 0.0524
# Learning rate:  0.001
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 9/70
# 191/191 [==============================] - ETA: 0s - loss: 2.3909 - accuracy: 0.4500 - top5_acc: 0.6898 - macro_f1score: 0.0882
# Epoch 00009: val_loss improved from 3.40317 to 3.26284, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/ResNet18/009.h5
#
# Epoch 00009: val_accuracy improved from 0.28668 to 0.33016, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/ResNet18/009.h5
# 191/191 [==============================] - 379s 2s/step - loss: 2.3909 - accuracy: 0.4500 - top5_acc: 0.6898 - macro_f1score: 0.0882 - val_loss: 3.2628 - val_accuracy: 0.3302 - val_top5_acc: 0.5397 - val_macro_f1score: 0.0684
# Learning rate:  0.001
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 10/70
# 191/191 [==============================] - ETA: 0s - loss: 2.2218 - accuracy: 0.4816 - top5_acc: 0.7171 - macro_f1score: 0.1019
# Epoch 00010: val_loss improved from 3.26284 to 2.88155, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/ResNet18/010.h5
#
# Epoch 00010: val_accuracy improved from 0.33016 to 0.38519, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/ResNet18/010.h5
# 191/191 [==============================] - 378s 2s/step - loss: 2.2218 - accuracy: 0.4816 - top5_acc: 0.7171 - macro_f1score: 0.1019 - val_loss: 2.8815 - val_accuracy: 0.3852 - val_top5_acc: 0.6084 - val_macro_f1score: 0.0806
# Learning rate:  0.001
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 11/70
# 191/191 [==============================] - ETA: 0s - loss: 2.0559 - accuracy: 0.5137 - top5_acc: 0.7501 - macro_f1score: 0.1148
# Epoch 00011: val_loss did not improve from 2.88155
#
# Epoch 00011: val_accuracy did not improve from 0.38519
# 191/191 [==============================] - 376s 2s/step - loss: 2.0559 - accuracy: 0.5137 - top5_acc: 0.7501 - macro_f1score: 0.1148 - val_loss: 2.9522 - val_accuracy: 0.3726 - val_top5_acc: 0.6056 - val_macro_f1score: 0.0874
# Learning rate:  0.001
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 12/70
# 191/191 [==============================] - ETA: 0s - loss: 1.9173 - accuracy: 0.5377 - top5_acc: 0.7733 - macro_f1score: 0.1271
# Epoch 00012: val_loss did not improve from 2.88155
#
# Epoch 00012: val_accuracy did not improve from 0.38519
# 191/191 [==============================] - 375s 2s/step - loss: 1.9173 - accuracy: 0.5377 - top5_acc: 0.7733 - macro_f1score: 0.1271 - val_loss: 3.1194 - val_accuracy: 0.3607 - val_top5_acc: 0.5917 - val_macro_f1score: 0.0858
# Learning rate:  0.001
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 13/70
# 191/191 [==============================] - ETA: 0s - loss: 1.7935 - accuracy: 0.5629 - top5_acc: 0.7963 - macro_f1score: 0.1392
# Epoch 00013: val_loss did not improve from 2.88155
#
# Epoch 00013: val_accuracy did not improve from 0.38519
# 191/191 [==============================] - 376s 2s/step - loss: 1.7935 - accuracy: 0.5629 - top5_acc: 0.7963 - macro_f1score: 0.1392 - val_loss: 3.2307 - val_accuracy: 0.3529 - val_top5_acc: 0.5788 - val_macro_f1score: 0.0807
# Learning rate:  0.001
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 14/70
# 191/191 [==============================] - ETA: 0s - loss: 1.6536 - accuracy: 0.5919 - top5_acc: 0.8165 - macro_f1score: 0.1514
# Epoch 00014: val_loss improved from 2.88155 to 2.76549, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/ResNet18/014.h5
#
# Epoch 00014: val_accuracy improved from 0.38519 to 0.42901, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/ResNet18/014.h5
# 191/191 [==============================] - 377s 2s/step - loss: 1.6536 - accuracy: 0.5919 - top5_acc: 0.8165 - macro_f1score: 0.1514 - val_loss: 2.7655 - val_accuracy: 0.4290 - val_top5_acc: 0.6423 - val_macro_f1score: 0.1018
# Learning rate:  0.001
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 15/70
# 191/191 [==============================] - ETA: 0s - loss: 1.5563 - accuracy: 0.6104 - top5_acc: 0.8345 - macro_f1score: 0.1622
# Epoch 00015: val_loss did not improve from 2.76549
#
# Epoch 00015: val_accuracy did not improve from 0.42901
# 191/191 [==============================] - 385s 2s/step - loss: 1.5563 - accuracy: 0.6104 - top5_acc: 0.8345 - macro_f1score: 0.1622 - val_loss: 2.8604 - val_accuracy: 0.4103 - val_top5_acc: 0.6467 - val_macro_f1score: 0.1060
# Learning rate:  0.001
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 16/70
# 191/191 [==============================] - ETA: 0s - loss: 1.4266 - accuracy: 0.6392 - top5_acc: 0.8546 - macro_f1score: 0.1754
# Epoch 00016: val_loss improved from 2.76549 to 2.51950, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/ResNet18/016.h5
#
# Epoch 00016: val_accuracy improved from 0.42901 to 0.45041, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/ResNet18/016.h5
# 191/191 [==============================] - 382s 2s/step - loss: 1.4266 - accuracy: 0.6392 - top5_acc: 0.8546 - macro_f1score: 0.1754 - val_loss: 2.5195 - val_accuracy: 0.4504 - val_top5_acc: 0.6817 - val_macro_f1score: 0.1147
# Learning rate:  0.001
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 17/70
# 191/191 [==============================] - ETA: 0s - loss: 1.3306 - accuracy: 0.6580 - top5_acc: 0.8698 - macro_f1score: 0.1837
# Epoch 00017: val_loss did not improve from 2.51950
#
# Epoch 00017: val_accuracy improved from 0.45041 to 0.45448, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/ResNet18/017.h5
# 191/191 [==============================] - 379s 2s/step - loss: 1.3306 - accuracy: 0.6580 - top5_acc: 0.8698 - macro_f1score: 0.1837 - val_loss: 2.6006 - val_accuracy: 0.4545 - val_top5_acc: 0.6770 - val_macro_f1score: 0.1216
# Learning rate:  0.001
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 18/70
# 191/191 [==============================] - ETA: 0s - loss: 1.2396 - accuracy: 0.6794 - top5_acc: 0.8840 - macro_f1score: 0.1940
# Epoch 00018: val_loss did not improve from 2.51950
#
# Epoch 00018: val_accuracy did not improve from 0.45448
# 191/191 [==============================] - 383s 2s/step - loss: 1.2396 - accuracy: 0.6794 - top5_acc: 0.8840 - macro_f1score: 0.1940 - val_loss: 2.6692 - val_accuracy: 0.4480 - val_top5_acc: 0.6658 - val_macro_f1score: 0.1184
# Learning rate:  0.001
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 19/70
# 191/191 [==============================] - ETA: 0s - loss: 1.1287 - accuracy: 0.7055 - top5_acc: 0.9036 - macro_f1score: 0.2053
# Epoch 00019: val_loss did not improve from 2.51950
#
# Epoch 00019: val_accuracy did not improve from 0.45448
# 191/191 [==============================] - 387s 2s/step - loss: 1.1287 - accuracy: 0.7055 - top5_acc: 0.9036 - macro_f1score: 0.2053 - val_loss: 2.7461 - val_accuracy: 0.4409 - val_top5_acc: 0.6637 - val_macro_f1score: 0.1163
# Learning rate:  0.001
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 20/70
# 191/191 [==============================] - ETA: 0s - loss: 1.0188 - accuracy: 0.7324 - top5_acc: 0.9158 - macro_f1score: 0.2200
# Epoch 00020: val_loss did not improve from 2.51950
#
# Epoch 00020: val_accuracy improved from 0.45448 to 0.46841, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/ResNet18/020.h5
# 191/191 [==============================] - 381s 2s/step - loss: 1.0188 - accuracy: 0.7324 - top5_acc: 0.9158 - macro_f1score: 0.2200 - val_loss: 2.5517 - val_accuracy: 0.4684 - val_top5_acc: 0.6933 - val_macro_f1score: 0.1313
# Learning rate:  0.001
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 21/70
# 191/191 [==============================] - ETA: 0s - loss: 0.9479 - accuracy: 0.7473 - top5_acc: 0.9286 - macro_f1score: 0.2281
# Epoch 00021: val_loss improved from 2.51950 to 2.51380, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/ResNet18/021.h5
#
# Epoch 00021: val_accuracy improved from 0.46841 to 0.47181, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/ResNet18/021.h5
# 191/191 [==============================] - 382s 2s/step - loss: 0.9479 - accuracy: 0.7473 - top5_acc: 0.9286 - macro_f1score: 0.2281 - val_loss: 2.5138 - val_accuracy: 0.4718 - val_top5_acc: 0.6994 - val_macro_f1score: 0.1372
# Learning rate:  0.001
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 22/70
# 191/191 [==============================] - ETA: 0s - loss: 0.8729 - accuracy: 0.7627 - top5_acc: 0.9385 - macro_f1score: 0.2368
# Epoch 00022: val_loss did not improve from 2.51380
#
# Epoch 00022: val_accuracy did not improve from 0.47181
# 191/191 [==============================] - 387s 2s/step - loss: 0.8729 - accuracy: 0.7627 - top5_acc: 0.9385 - macro_f1score: 0.2368 - val_loss: 2.6829 - val_accuracy: 0.4535 - val_top5_acc: 0.6705 - val_macro_f1score: 0.1252
# Learning rate:  0.001
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 23/70
# 191/191 [==============================] - ETA: 0s - loss: 0.7947 - accuracy: 0.7842 - top5_acc: 0.9483 - macro_f1score: 0.2460
# Epoch 00023: val_loss improved from 2.51380 to 2.46621, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/ResNet18/023.h5
#
# Epoch 00023: val_accuracy improved from 0.47181 to 0.47215, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/ResNet18/023.h5
# 191/191 [==============================] - 391s 2s/step - loss: 0.7947 - accuracy: 0.7842 - top5_acc: 0.9483 - macro_f1score: 0.2460 - val_loss: 2.4662 - val_accuracy: 0.4721 - val_top5_acc: 0.6960 - val_macro_f1score: 0.1350
# Learning rate:  0.001
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 24/70
# 191/191 [==============================] - ETA: 0s - loss: 0.7209 - accuracy: 0.8039 - top5_acc: 0.9565 - macro_f1score: 0.2573
# Epoch 00024: val_loss improved from 2.46621 to 2.46388, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/ResNet18/024.h5
#
# Epoch 00024: val_accuracy improved from 0.47215 to 0.49287, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/ResNet18/024.h5
# 191/191 [==============================] - 387s 2s/step - loss: 0.7209 - accuracy: 0.8039 - top5_acc: 0.9565 - macro_f1score: 0.2573 - val_loss: 2.4639 - val_accuracy: 0.4929 - val_top5_acc: 0.7150 - val_macro_f1score: 0.1427
# Learning rate:  0.001
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 25/70
# 191/191 [==============================] - ETA: 0s - loss: 0.6545 - accuracy: 0.8198 - top5_acc: 0.9644 - macro_f1score: 0.2667
# Epoch 00025: val_loss did not improve from 2.46388
#
# Epoch 00025: val_accuracy did not improve from 0.49287
# 191/191 [==============================] - 394s 2s/step - loss: 0.6545 - accuracy: 0.8198 - top5_acc: 0.9644 - macro_f1score: 0.2667 - val_loss: 2.8783 - val_accuracy: 0.4691 - val_top5_acc: 0.6831 - val_macro_f1score: 0.1419
# Learning rate:  0.001
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 26/70
# 191/191 [==============================] - ETA: 0s - loss: 0.6030 - accuracy: 0.8330 - top5_acc: 0.9704 - macro_f1score: 0.2752
# Epoch 00026: val_loss did not improve from 2.46388
#
# Epoch 00026: val_accuracy improved from 0.49287 to 0.50170, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/ResNet18/026.h5
# 191/191 [==============================] - 388s 2s/step - loss: 0.6030 - accuracy: 0.8330 - top5_acc: 0.9704 - macro_f1score: 0.2752 - val_loss: 2.6362 - val_accuracy: 0.5017 - val_top5_acc: 0.7058 - val_macro_f1score: 0.1529
# Learning rate:  0.001
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 27/70
# 191/191 [==============================] - ETA: 0s - loss: 0.5529 - accuracy: 0.8459 - top5_acc: 0.9753 - macro_f1score: 0.2826
# Epoch 00027: val_loss did not improve from 2.46388
#
# Epoch 00027: val_accuracy did not improve from 0.50170
# 191/191 [==============================] - 385s 2s/step - loss: 0.5529 - accuracy: 0.8459 - top5_acc: 0.9753 - macro_f1score: 0.2826 - val_loss: 2.8622 - val_accuracy: 0.4535 - val_top5_acc: 0.6838 - val_macro_f1score: 0.1378
# Learning rate:  0.001
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 28/70
# 191/191 [==============================] - ETA: 0s - loss: 0.4975 - accuracy: 0.8639 - top5_acc: 0.9795 - macro_f1score: 0.2898
# Epoch 00028: val_loss did not improve from 2.46388
#
# Epoch 00028: val_accuracy improved from 0.50170 to 0.50476, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/ResNet18/028.h5
# 191/191 [==============================] - 388s 2s/step - loss: 0.4975 - accuracy: 0.8639 - top5_acc: 0.9795 - macro_f1score: 0.2898 - val_loss: 2.5243 - val_accuracy: 0.5048 - val_top5_acc: 0.7126 - val_macro_f1score: 0.1534
# Learning rate:  0.001
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 29/70
# 191/191 [==============================] - ETA: 0s - loss: 0.4665 - accuracy: 0.8724 - top5_acc: 0.9829 - macro_f1score: 0.2965
# Epoch 00029: val_loss did not improve from 2.46388
#
# Epoch 00029: val_accuracy did not improve from 0.50476
# 191/191 [==============================] - 386s 2s/step - loss: 0.4665 - accuracy: 0.8724 - top5_acc: 0.9829 - macro_f1score: 0.2965 - val_loss: 2.5315 - val_accuracy: 0.4956 - val_top5_acc: 0.7041 - val_macro_f1score: 0.1505
# Learning rate:  0.001
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 30/70
# 191/191 [==============================] - ETA: 0s - loss: 0.4061 - accuracy: 0.8885 - top5_acc: 0.9865 - macro_f1score: 0.3070
# Epoch 00030: val_loss did not improve from 2.46388
#
# Epoch 00030: val_accuracy did not improve from 0.50476
# 191/191 [==============================] - 389s 2s/step - loss: 0.4061 - accuracy: 0.8885 - top5_acc: 0.9865 - macro_f1score: 0.3070 - val_loss: 2.5316 - val_accuracy: 0.4942 - val_top5_acc: 0.7011 - val_macro_f1score: 0.1493
# Learning rate:  0.0001
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 31/70
# 191/191 [==============================] - ETA: 0s - loss: 0.1956 - accuracy: 0.9570 - top5_acc: 0.9966 - macro_f1score: 0.3437
# Epoch 00031: val_loss improved from 2.46388 to 1.92202, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/ResNet18/031.h5
#
# Epoch 00031: val_accuracy improved from 0.50476 to 0.58798, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/ResNet18/031.h5
# 191/191 [==============================] - 389s 2s/step - loss: 0.1956 - accuracy: 0.9570 - top5_acc: 0.9966 - macro_f1score: 0.3437 - val_loss: 1.9220 - val_accuracy: 0.5880 - val_top5_acc: 0.7874 - val_macro_f1score: 0.1853
# Learning rate:  0.0001
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 32/70
# 191/191 [==============================] - ETA: 0s - loss: 0.1222 - accuracy: 0.9822 - top5_acc: 0.9991 - macro_f1score: 0.3565
# Epoch 00032: val_loss improved from 1.92202 to 1.88431, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/ResNet18/032.h5
#
# Epoch 00032: val_accuracy improved from 0.58798 to 0.59647, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/ResNet18/032.h5
# 191/191 [==============================] - 387s 2s/step - loss: 0.1222 - accuracy: 0.9822 - top5_acc: 0.9991 - macro_f1score: 0.3565 - val_loss: 1.8843 - val_accuracy: 0.5965 - val_top5_acc: 0.7853 - val_macro_f1score: 0.1878
# Learning rate:  0.0001
#
# Epoch 00033: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 33/70
# 191/191 [==============================] - ETA: 0s - loss: 0.1079 - accuracy: 0.9875 - top5_acc: 0.9994 - macro_f1score: 0.3583
# Epoch 00033: val_loss did not improve from 1.88431
#
# Epoch 00033: val_accuracy improved from 0.59647 to 0.59918, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/ResNet18/033.h5
# 191/191 [==============================] - 385s 2s/step - loss: 0.1079 - accuracy: 0.9875 - top5_acc: 0.9994 - macro_f1score: 0.3583 - val_loss: 1.8906 - val_accuracy: 0.5992 - val_top5_acc: 0.7874 - val_macro_f1score: 0.1831
# Learning rate:  0.0001
#
# Epoch 00034: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 34/70
# 191/191 [==============================] - ETA: 0s - loss: 0.0988 - accuracy: 0.9881 - top5_acc: 0.9999 - macro_f1score: 0.3622
# Epoch 00034: val_loss improved from 1.88431 to 1.86381, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/ResNet18/034.h5
#
# Epoch 00034: val_accuracy did not improve from 0.59918
# 191/191 [==============================] - 387s 2s/step - loss: 0.0988 - accuracy: 0.9881 - top5_acc: 0.9999 - macro_f1score: 0.3622 - val_loss: 1.8638 - val_accuracy: 0.5948 - val_top5_acc: 0.7914 - val_macro_f1score: 0.1856
# Learning rate:  0.0001
#
# Epoch 00035: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 35/70
# 191/191 [==============================] - ETA: 0s - loss: 0.0962 - accuracy: 0.9911 - top5_acc: 0.9999 - macro_f1score: 0.3594
# Epoch 00035: val_loss improved from 1.86381 to 1.85561, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/ResNet18/035.h5
#
# Epoch 00035: val_accuracy did not improve from 0.59918
# 191/191 [==============================] - 382s 2s/step - loss: 0.0962 - accuracy: 0.9911 - top5_acc: 0.9999 - macro_f1score: 0.3594 - val_loss: 1.8556 - val_accuracy: 0.5975 - val_top5_acc: 0.7877 - val_macro_f1score: 0.1843
# Learning rate:  0.0001
#
# Epoch 00036: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 36/70
# 191/191 [==============================] - ETA: 0s - loss: 0.0922 - accuracy: 0.9920 - top5_acc: 0.9999 - macro_f1score: 0.3624
# Epoch 00036: val_loss improved from 1.85561 to 1.85507, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/ResNet18/036.h5
#
# Epoch 00036: val_accuracy did not improve from 0.59918
# 191/191 [==============================] - 382s 2s/step - loss: 0.0922 - accuracy: 0.9920 - top5_acc: 0.9999 - macro_f1score: 0.3624 - val_loss: 1.8551 - val_accuracy: 0.5927 - val_top5_acc: 0.7904 - val_macro_f1score: 0.1834
# Learning rate:  0.0001
#
# Epoch 00037: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 37/70
# 191/191 [==============================] - ETA: 0s - loss: 0.0902 - accuracy: 0.9936 - top5_acc: 0.9999 - macro_f1score: 0.3628
# Epoch 00037: val_loss improved from 1.85507 to 1.84090, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/ResNet18/037.h5
#
# Epoch 00037: val_accuracy did not improve from 0.59918
# 191/191 [==============================] - 387s 2s/step - loss: 0.0902 - accuracy: 0.9936 - top5_acc: 0.9999 - macro_f1score: 0.3628 - val_loss: 1.8409 - val_accuracy: 0.5992 - val_top5_acc: 0.7904 - val_macro_f1score: 0.1856
# Learning rate:  0.0001
#
# Epoch 00038: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 38/70
# 191/191 [==============================] - ETA: 0s - loss: 0.0877 - accuracy: 0.9936 - top5_acc: 1.0000 - macro_f1score: 0.3647
# Epoch 00038: val_loss improved from 1.84090 to 1.83375, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/ResNet18/038.h5
#
# Epoch 00038: val_accuracy improved from 0.59918 to 0.60258, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/ResNet18/038.h5
# 191/191 [==============================] - 388s 2s/step - loss: 0.0877 - accuracy: 0.9936 - top5_acc: 1.0000 - macro_f1score: 0.3647 - val_loss: 1.8338 - val_accuracy: 0.6026 - val_top5_acc: 0.7914 - val_macro_f1score: 0.1855
# Learning rate:  0.0001
#
# Epoch 00039: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 39/70
# 191/191 [==============================] - ETA: 0s - loss: 0.0903 - accuracy: 0.9939 - top5_acc: 0.9999 - macro_f1score: 0.3631
# Epoch 00039: val_loss improved from 1.83375 to 1.83003, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/ResNet18/039.h5
#
# Epoch 00039: val_accuracy did not improve from 0.60258
# 191/191 [==============================] - 382s 2s/step - loss: 0.0903 - accuracy: 0.9939 - top5_acc: 0.9999 - macro_f1score: 0.3631 - val_loss: 1.8300 - val_accuracy: 0.5961 - val_top5_acc: 0.7904 - val_macro_f1score: 0.1849
# Learning rate:  0.0001
#
# Epoch 00040: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 40/70
# 191/191 [==============================] - ETA: 0s - loss: 0.0856 - accuracy: 0.9952 - top5_acc: 0.9998 - macro_f1score: 0.3644
# Epoch 00040: val_loss improved from 1.83003 to 1.82478, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/ResNet18/040.h5
#
# Epoch 00040: val_accuracy did not improve from 0.60258
# 191/191 [==============================] - 384s 2s/step - loss: 0.0856 - accuracy: 0.9952 - top5_acc: 0.9998 - macro_f1score: 0.3644 - val_loss: 1.8248 - val_accuracy: 0.5904 - val_top5_acc: 0.7952 - val_macro_f1score: 0.1849
# Learning rate:  0.0001
#
# Epoch 00041: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 41/70
# 191/191 [==============================] - ETA: 0s - loss: 0.0838 - accuracy: 0.9956 - top5_acc: 1.0000 - macro_f1score: 0.3649
# Epoch 00041: val_loss did not improve from 1.82478
#
# Epoch 00041: val_accuracy did not improve from 0.60258
# 191/191 [==============================] - 383s 2s/step - loss: 0.0838 - accuracy: 0.9956 - top5_acc: 1.0000 - macro_f1score: 0.3649 - val_loss: 1.8374 - val_accuracy: 0.5866 - val_top5_acc: 0.7891 - val_macro_f1score: 0.1827
# Learning rate:  0.0001
#
# Epoch 00042: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 42/70
# 191/191 [==============================] - ETA: 0s - loss: 0.0860 - accuracy: 0.9946 - top5_acc: 0.9999 - macro_f1score: 0.3651
# Epoch 00042: val_loss did not improve from 1.82478
#
# Epoch 00042: val_accuracy did not improve from 0.60258
# 191/191 [==============================] - 380s 2s/step - loss: 0.0860 - accuracy: 0.9946 - top5_acc: 0.9999 - macro_f1score: 0.3651 - val_loss: 1.8271 - val_accuracy: 0.5887 - val_top5_acc: 0.7904 - val_macro_f1score: 0.1810
# Learning rate:  0.0001
#
# Epoch 00043: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 43/70
# 191/191 [==============================] - ETA: 0s - loss: 0.0834 - accuracy: 0.9957 - top5_acc: 0.9999 - macro_f1score: 0.3662
# Epoch 00043: val_loss improved from 1.82478 to 1.80536, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/ResNet18/043.h5
#
# Epoch 00043: val_accuracy did not improve from 0.60258
# 191/191 [==============================] - 383s 2s/step - loss: 0.0834 - accuracy: 0.9957 - top5_acc: 0.9999 - macro_f1score: 0.3662 - val_loss: 1.8054 - val_accuracy: 0.5985 - val_top5_acc: 0.7914 - val_macro_f1score: 0.1828
# Learning rate:  0.0001
#
# Epoch 00044: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 44/70
# 191/191 [==============================] - ETA: 0s - loss: 0.0820 - accuracy: 0.9960 - top5_acc: 1.0000 - macro_f1score: 0.3656
# Epoch 00044: val_loss did not improve from 1.80536
#
# Epoch 00044: val_accuracy did not improve from 0.60258
# 191/191 [==============================] - 377s 2s/step - loss: 0.0820 - accuracy: 0.9960 - top5_acc: 1.0000 - macro_f1score: 0.3656 - val_loss: 1.8177 - val_accuracy: 0.5985 - val_top5_acc: 0.7918 - val_macro_f1score: 0.1812
# Learning rate:  0.0001
#
# Epoch 00045: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 45/70
# 191/191 [==============================] - ETA: 0s - loss: 0.0827 - accuracy: 0.9962 - top5_acc: 1.0000 - macro_f1score: 0.3650
# Epoch 00045: val_loss did not improve from 1.80536
#
# Epoch 00045: val_accuracy did not improve from 0.60258
# 191/191 [==============================] - 381s 2s/step - loss: 0.0827 - accuracy: 0.9962 - top5_acc: 1.0000 - macro_f1score: 0.3650 - val_loss: 1.8250 - val_accuracy: 0.5931 - val_top5_acc: 0.7911 - val_macro_f1score: 0.1811
# Learning rate:  0.0001
#
# Epoch 00046: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 46/70
# 191/191 [==============================] - ETA: 0s - loss: 0.0802 - accuracy: 0.9963 - top5_acc: 0.9999 - macro_f1score: 0.3653
# Epoch 00046: val_loss did not improve from 1.80536
#
# Epoch 00046: val_accuracy did not improve from 0.60258
# 191/191 [==============================] - 378s 2s/step - loss: 0.0802 - accuracy: 0.9963 - top5_acc: 0.9999 - macro_f1score: 0.3653 - val_loss: 1.8075 - val_accuracy: 0.5961 - val_top5_acc: 0.7952 - val_macro_f1score: 0.1785
# Learning rate:  0.0001
#
# Epoch 00047: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 47/70
# 191/191 [==============================] - ETA: 0s - loss: 0.0770 - accuracy: 0.9970 - top5_acc: 1.0000 - macro_f1score: 0.3670
# Epoch 00047: val_loss did not improve from 1.80536
#
# Epoch 00047: val_accuracy did not improve from 0.60258
# 191/191 [==============================] - 382s 2s/step - loss: 0.0770 - accuracy: 0.9970 - top5_acc: 1.0000 - macro_f1score: 0.3670 - val_loss: 1.8685 - val_accuracy: 0.5853 - val_top5_acc: 0.7853 - val_macro_f1score: 0.1785
# Learning rate:  0.0001
#
# Epoch 00048: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 48/70
# 191/191 [==============================] - ETA: 0s - loss: 0.0753 - accuracy: 0.9969 - top5_acc: 1.0000 - macro_f1score: 0.3661
# Epoch 00048: val_loss did not improve from 1.80536
#
# Epoch 00048: val_accuracy improved from 0.60258 to 0.60462, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/ResNet18/048.h5
# 191/191 [==============================] - 380s 2s/step - loss: 0.0753 - accuracy: 0.9969 - top5_acc: 1.0000 - macro_f1score: 0.3661 - val_loss: 1.8092 - val_accuracy: 0.6046 - val_top5_acc: 0.7918 - val_macro_f1score: 0.1812
# Learning rate:  0.0001
#
# Epoch 00049: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 49/70
# 191/191 [==============================] - ETA: 0s - loss: 0.0750 - accuracy: 0.9970 - top5_acc: 1.0000 - macro_f1score: 0.3684
# Epoch 00049: val_loss did not improve from 1.80536
#
# Epoch 00049: val_accuracy did not improve from 0.60462
# 191/191 [==============================] - 380s 2s/step - loss: 0.0750 - accuracy: 0.9970 - top5_acc: 1.0000 - macro_f1score: 0.3684 - val_loss: 1.8212 - val_accuracy: 0.5958 - val_top5_acc: 0.7908 - val_macro_f1score: 0.1796
# Learning rate:  0.0001
#
# Epoch 00050: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 50/70
# 191/191 [==============================] - ETA: 0s - loss: 0.0729 - accuracy: 0.9968 - top5_acc: 1.0000 - macro_f1score: 0.3672
# Epoch 00050: val_loss did not improve from 1.80536
#
# Epoch 00050: val_accuracy did not improve from 0.60462
# 191/191 [==============================] - 383s 2s/step - loss: 0.0729 - accuracy: 0.9968 - top5_acc: 1.0000 - macro_f1score: 0.3672 - val_loss: 1.8559 - val_accuracy: 0.5958 - val_top5_acc: 0.7833 - val_macro_f1score: 0.1811
# Learning rate:  0.0001
#
# Epoch 00051: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 51/70
# 191/191 [==============================] - ETA: 0s - loss: 0.0697 - accuracy: 0.9974 - top5_acc: 1.0000 - macro_f1score: 0.3691
# Epoch 00051: val_loss did not improve from 1.80536
#
# Epoch 00051: val_accuracy did not improve from 0.60462
# 191/191 [==============================] - 384s 2s/step - loss: 0.0697 - accuracy: 0.9974 - top5_acc: 1.0000 - macro_f1score: 0.3691 - val_loss: 1.8276 - val_accuracy: 0.5985 - val_top5_acc: 0.7884 - val_macro_f1score: 0.1834
# Learning rate:  0.0001
#
# Epoch 00052: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 52/70
# 191/191 [==============================] - ETA: 0s - loss: 0.0669 - accuracy: 0.9975 - top5_acc: 1.0000 - macro_f1score: 0.3668
# Epoch 00052: val_loss did not improve from 1.80536
#
# Epoch 00052: val_accuracy did not improve from 0.60462
# 191/191 [==============================] - 386s 2s/step - loss: 0.0669 - accuracy: 0.9975 - top5_acc: 1.0000 - macro_f1score: 0.3668 - val_loss: 1.8181 - val_accuracy: 0.5992 - val_top5_acc: 0.7904 - val_macro_f1score: 0.1867
# Learning rate:  0.0001
#
# Epoch 00053: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 53/70
# 191/191 [==============================] - ETA: 0s - loss: 0.0696 - accuracy: 0.9964 - top5_acc: 0.9999 - macro_f1score: 0.3669
# Epoch 00053: val_loss did not improve from 1.80536
#
# Epoch 00053: val_accuracy did not improve from 0.60462
# 191/191 [==============================] - 387s 2s/step - loss: 0.0696 - accuracy: 0.9964 - top5_acc: 0.9999 - macro_f1score: 0.3669 - val_loss: 1.8443 - val_accuracy: 0.5978 - val_top5_acc: 0.7802 - val_macro_f1score: 0.1832
# Learning rate:  0.0001
#
# Epoch 00054: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 54/70
# 191/191 [==============================] - ETA: 0s - loss: 0.0656 - accuracy: 0.9973 - top5_acc: 1.0000 - macro_f1score: 0.3689
# Epoch 00054: val_loss did not improve from 1.80536
#
# Epoch 00054: val_accuracy did not improve from 0.60462
# 191/191 [==============================] - 388s 2s/step - loss: 0.0656 - accuracy: 0.9973 - top5_acc: 1.0000 - macro_f1score: 0.3689 - val_loss: 1.8576 - val_accuracy: 0.6036 - val_top5_acc: 0.7877 - val_macro_f1score: 0.1807
# Learning rate:  0.0001
#
# Epoch 00055: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 55/70
# 191/191 [==============================] - ETA: 0s - loss: 0.0626 - accuracy: 0.9978 - top5_acc: 1.0000 - macro_f1score: 0.3680
# Epoch 00055: val_loss did not improve from 1.80536
#
# Epoch 00055: val_accuracy did not improve from 0.60462
# 191/191 [==============================] - 386s 2s/step - loss: 0.0626 - accuracy: 0.9978 - top5_acc: 1.0000 - macro_f1score: 0.3680 - val_loss: 1.8511 - val_accuracy: 0.5900 - val_top5_acc: 0.7870 - val_macro_f1score: 0.1809
# Learning rate:  0.0001
#
# Epoch 00056: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 56/70
# 191/191 [==============================] - ETA: 0s - loss: 0.0629 - accuracy: 0.9975 - top5_acc: 1.0000 - macro_f1score: 0.3691
# Epoch 00056: val_loss did not improve from 1.80536
#
# Epoch 00056: val_accuracy did not improve from 0.60462
# 191/191 [==============================] - 392s 2s/step - loss: 0.0629 - accuracy: 0.9975 - top5_acc: 1.0000 - macro_f1score: 0.3691 - val_loss: 1.8749 - val_accuracy: 0.5893 - val_top5_acc: 0.7836 - val_macro_f1score: 0.1866
# Learning rate:  0.0001
#
# Epoch 00057: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 57/70
# 191/191 [==============================] - ETA: 0s - loss: 0.0633 - accuracy: 0.9971 - top5_acc: 1.0000 - macro_f1score: 0.3684
# Epoch 00057: val_loss did not improve from 1.80536
#
# Epoch 00057: val_accuracy did not improve from 0.60462
# 191/191 [==============================] - 394s 2s/step - loss: 0.0633 - accuracy: 0.9971 - top5_acc: 1.0000 - macro_f1score: 0.3684 - val_loss: 1.9108 - val_accuracy: 0.5778 - val_top5_acc: 0.7829 - val_macro_f1score: 0.1807
# Learning rate:  0.0001
#
# Epoch 00058: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 58/70
# 191/191 [==============================] - ETA: 0s - loss: 0.0579 - accuracy: 0.9975 - top5_acc: 1.0000 - macro_f1score: 0.3676
# Epoch 00058: val_loss did not improve from 1.80536
#
# Epoch 00058: val_accuracy did not improve from 0.60462
# 191/191 [==============================] - 391s 2s/step - loss: 0.0579 - accuracy: 0.9975 - top5_acc: 1.0000 - macro_f1score: 0.3676 - val_loss: 1.9093 - val_accuracy: 0.5866 - val_top5_acc: 0.7762 - val_macro_f1score: 0.1778
# Learning rate:  0.0001
#
# Epoch 00059: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 59/70
# 191/191 [==============================] - ETA: 0s - loss: 0.0567 - accuracy: 0.9978 - top5_acc: 1.0000 - macro_f1score: 0.3683
# Epoch 00059: val_loss did not improve from 1.80536
#
# Epoch 00059: val_accuracy did not improve from 0.60462
# 191/191 [==============================] - 396s 2s/step - loss: 0.0567 - accuracy: 0.9978 - top5_acc: 1.0000 - macro_f1score: 0.3683 - val_loss: 1.8598 - val_accuracy: 0.5907 - val_top5_acc: 0.7921 - val_macro_f1score: 0.1815
# Learning rate:  0.0001
#
# Epoch 00060: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 60/70
# 191/191 [==============================] - ETA: 0s - loss: 0.0590 - accuracy: 0.9976 - top5_acc: 1.0000 - macro_f1score: 0.3682
# Epoch 00060: val_loss did not improve from 1.80536
#
# Epoch 00060: val_accuracy did not improve from 0.60462
# 191/191 [==============================] - 395s 2s/step - loss: 0.0590 - accuracy: 0.9976 - top5_acc: 1.0000 - macro_f1score: 0.3682 - val_loss: 1.8803 - val_accuracy: 0.5866 - val_top5_acc: 0.7755 - val_macro_f1score: 0.1740
# Learning rate:  1e-05
#
# Epoch 00061: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 61/70
# 191/191 [==============================] - ETA: 0s - loss: 0.0464 - accuracy: 0.9986 - top5_acc: 1.0000 - macro_f1score: 0.3704
# Epoch 00061: val_loss improved from 1.80536 to 1.76729, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/ResNet18/061.h5
#
# Epoch 00061: val_accuracy improved from 0.60462 to 0.60938, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/ResNet18/061.h5
# 191/191 [==============================] - 402s 2s/step - loss: 0.0464 - accuracy: 0.9986 - top5_acc: 1.0000 - macro_f1score: 0.3704 - val_loss: 1.7673 - val_accuracy: 0.6094 - val_top5_acc: 0.7921 - val_macro_f1score: 0.1891
# Learning rate:  1e-05
#
# Epoch 00062: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 62/70
# 191/191 [==============================] - ETA: 0s - loss: 0.0432 - accuracy: 0.9992 - top5_acc: 1.0000 - macro_f1score: 0.3694
# Epoch 00062: val_loss improved from 1.76729 to 1.73784, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/ResNet18/062.h5
#
# Epoch 00062: val_accuracy improved from 0.60938 to 0.61379, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/ResNet18/062.h5
# 191/191 [==============================] - 400s 2s/step - loss: 0.0432 - accuracy: 0.9992 - top5_acc: 1.0000 - macro_f1score: 0.3694 - val_loss: 1.7378 - val_accuracy: 0.6138 - val_top5_acc: 0.7969 - val_macro_f1score: 0.1863
# Learning rate:  1e-05
#
# Epoch 00063: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 63/70
# 191/191 [==============================] - ETA: 0s - loss: 0.0447 - accuracy: 0.9992 - top5_acc: 1.0000 - macro_f1score: 0.3721
# Epoch 00063: val_loss did not improve from 1.73784
#
# Epoch 00063: val_accuracy did not improve from 0.61379
# 191/191 [==============================] - 397s 2s/step - loss: 0.0447 - accuracy: 0.9992 - top5_acc: 1.0000 - macro_f1score: 0.3721 - val_loss: 1.7422 - val_accuracy: 0.6118 - val_top5_acc: 0.7959 - val_macro_f1score: 0.1862
# Learning rate:  1e-05
#
# Epoch 00064: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 64/70
# 191/191 [==============================] - ETA: 0s - loss: 0.0498 - accuracy: 0.9993 - top5_acc: 1.0000 - macro_f1score: 0.3696
# Epoch 00064: val_loss improved from 1.73784 to 1.72744, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/ResNet18/064.h5
#
# Epoch 00064: val_accuracy improved from 0.61379 to 0.61413, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/ResNet18/064.h5
# 191/191 [==============================] - 395s 2s/step - loss: 0.0498 - accuracy: 0.9993 - top5_acc: 1.0000 - macro_f1score: 0.3696 - val_loss: 1.7274 - val_accuracy: 0.6141 - val_top5_acc: 0.7976 - val_macro_f1score: 0.1833
# Learning rate:  1e-05
#
# Epoch 00065: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 65/70
# 191/191 [==============================] - ETA: 0s - loss: 0.0530 - accuracy: 0.9992 - top5_acc: 1.0000 - macro_f1score: 0.3685
# Epoch 00065: val_loss improved from 1.72744 to 1.72743, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/ResNet18/065.h5
#
# Epoch 00065: val_accuracy did not improve from 0.61413
# 191/191 [==============================] - 396s 2s/step - loss: 0.0530 - accuracy: 0.9992 - top5_acc: 1.0000 - macro_f1score: 0.3685 - val_loss: 1.7274 - val_accuracy: 0.6128 - val_top5_acc: 0.7959 - val_macro_f1score: 0.1812
# Learning rate:  1e-05
#
# Epoch 00066: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 66/70
# 191/191 [==============================] - ETA: 0s - loss: 0.0568 - accuracy: 0.9998 - top5_acc: 1.0000 - macro_f1score: 0.3685
# Epoch 00066: val_loss improved from 1.72743 to 1.70131, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/ResNet18/066.h5
#
# Epoch 00066: val_accuracy improved from 0.61413 to 0.61719, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/ResNet18/066.h5
# 191/191 [==============================] - 399s 2s/step - loss: 0.0568 - accuracy: 0.9998 - top5_acc: 1.0000 - macro_f1score: 0.3685 - val_loss: 1.7013 - val_accuracy: 0.6172 - val_top5_acc: 0.7993 - val_macro_f1score: 0.1867
# Learning rate:  1e-05
#
# Epoch 00067: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 67/70
# 191/191 [==============================] - ETA: 0s - loss: 0.0608 - accuracy: 0.9995 - top5_acc: 1.0000 - macro_f1score: 0.3706
# Epoch 00067: val_loss did not improve from 1.70131
#
# Epoch 00067: val_accuracy did not improve from 0.61719
# 191/191 [==============================] - 400s 2s/step - loss: 0.0608 - accuracy: 0.9995 - top5_acc: 1.0000 - macro_f1score: 0.3706 - val_loss: 1.7151 - val_accuracy: 0.6141 - val_top5_acc: 0.7969 - val_macro_f1score: 0.1813
# Learning rate:  1e-05
#
# Epoch 00068: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 68/70
# 191/191 [==============================] - ETA: 0s - loss: 0.0678 - accuracy: 0.9994 - top5_acc: 1.0000 - macro_f1score: 0.3672
# Epoch 00068: val_loss did not improve from 1.70131
#
# Epoch 00068: val_accuracy did not improve from 0.61719
# 191/191 [==============================] - 398s 2s/step - loss: 0.0678 - accuracy: 0.9994 - top5_acc: 1.0000 - macro_f1score: 0.3672 - val_loss: 1.7168 - val_accuracy: 0.6138 - val_top5_acc: 0.7959 - val_macro_f1score: 0.1773
# Learning rate:  1e-05
#
# Epoch 00069: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 69/70
# 191/191 [==============================] - ETA: 0s - loss: 0.0727 - accuracy: 0.9995 - top5_acc: 1.0000 - macro_f1score: 0.3696
# Epoch 00069: val_loss improved from 1.70131 to 1.69758, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/ResNet18/069.h5
#
# Epoch 00069: val_accuracy did not improve from 0.61719
# 191/191 [==============================] - 396s 2s/step - loss: 0.0727 - accuracy: 0.9995 - top5_acc: 1.0000 - macro_f1score: 0.3696 - val_loss: 1.6976 - val_accuracy: 0.6151 - val_top5_acc: 0.7996 - val_macro_f1score: 0.1801
# Learning rate:  1e-05
#
# Epoch 00070: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 70/70
# 191/191 [==============================] - ETA: 0s - loss: 0.0794 - accuracy: 0.9994 - top5_acc: 1.0000 - macro_f1score: 0.3684
# Epoch 00070: val_loss did not improve from 1.69758
#
# Epoch 00070: val_accuracy did not improve from 0.61719
# 191/191 [==============================] - 396s 2s/step - loss: 0.0794 - accuracy: 0.9994 - top5_acc: 1.0000 - macro_f1score: 0.3684 - val_loss: 1.7080 - val_accuracy: 0.6145 - val_top5_acc: 0.7996 - val_macro_f1score: 0.1753

# %% [markdown]
# ### 2) ResNet18 Evaluate

# %%
# 1. epoch=maximum
loss , acc, top5_acc, mf1 = model.evaluate(test_generator,steps=int(len(x_test)/batch_sizes))
print('[Test Loss: %.4f /  Test Top-1 Accuracy: %.4f / Test Top-5 Accuracy: %.4f / Test Macro f1: %.4f]\n' % (loss,acc,top5_acc,mf1))
# Out:
# 24/24 [==============================] - 1213s 51s/step - loss: 1.7518 - accuracy: 0.6055 - top5_acc: 0.7878 - macro_f1score: 0.1724
# [Test Loss: 1.7518 /  Test Top-1 Accuracy: 0.6055 / Test Top-5 Accuracy: 0.7878 / Test Macro f1: 0.1724]

# %%
loss=history.history['loss']
val_loss=history.history['val_loss']
acc=history.history['accuracy']
val_acc=history.history['val_accuracy']
top5_acc=history.history['top5_acc']
val_top5_acc=history.history['val_top5_acc']
f1=history.history['macro_f1score']
val_f1=history.history['val_macro_f1score']
epochs=range(1,len(acc)+1)

data = np.array([epochs,loss,val_loss,acc,val_acc,top5_acc,val_top5_acc,f1,val_f1]).T

# %%
# data save
# epochs, loss, val_loss, acc, val_acc, top5_acc, val_top5_acc, f1, val_f1

np.savetxt(os.path.join(dir,'train_valid_output',number,model.name+'.txt'),data)

# %%
# data import
data = np.loadtxt(os.path.join(dir,'train_valid_output',number,'ResNet18.txt'))

# %%
epochs=data[:,0]
loss=data[:,1]
val_loss=data[:,2]
acc=data[:,3]
val_acc=data[:,4]
top5_acc=data[:,5]
val_top5_acc=data[:,6]

# %%
plt.plot(epochs[1:],acc[1:],'b',label='Training 1-Acc')
plt.plot(epochs[1:],val_acc[1:],'r',label='Validation 1-Acc')
plt.title('Training and Validation Top-1 Accuracy')
plt.legend()
plt.figure()

plt.plot(epochs[1:],top5_acc[1:],'b',label='Training 5-Acc')
plt.plot(epochs[1:],val_top5_acc[1:],'r',label='Validation 5-Acc')
plt.title('Training and Validation Top-5 Accuracy')
plt.legend()
plt.figure()

plt.plot(epochs[10:],loss[10:],'b',label='Training Loss')
plt.plot(epochs[10:],val_loss[10:],'r',label='Validation Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()

# %%
# 이 아래는 내가 인위적으로 살펴보고 싶은 epoch에 대해서 결과값 출력 / resnet18

# %%
model=load_model(os.path.join(dir,'model_output',number,'ResNet18','031.h5'),custom_objects={"macro_f1score": macro_f1score,"top5_acc":top5_acc})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-38-12f011310531> in <module>()
# ----> 1 model=load_model(os.path.join(dir,'model_output',number,'ResNet18','031.h5'),custom_objects={"macro_f1score": macro_f1score,"top5_acc":top5_acc})
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/saving/save.py in load_model(filepath, custom_objects, compile, options)
#     180     if (h5py is not None and (
#     181         isinstance(filepath, h5py.File) or h5py.is_hdf5(filepath))):
# --> 182       return hdf5_format.load_model_from_hdf5(filepath, custom_objects, compile)
#     183
#     184     filepath = path_to_string(filepath)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/saving/hdf5_format.py in load_model_from_hdf5(filepath, custom_objects, compile)
#     192       # Compile model.
#     193       model.compile(**saving_utils.compile_args_from_training_config(
# --> 194           training_config, custom_objects))
#     195       saving_utils.try_build_compiled_arguments(model)
#     196
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/saving/saving_utils.py in compile_args_from_training_config(training_config, custom_objects)
#     209   with generic_utils.CustomObjectScope(custom_objects):
#     210     optimizer_config = training_config['optimizer_config']
# --> 211     optimizer = optimizers.deserialize(optimizer_config)
#     212
#     213     # Recover losses.
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/optimizers.py in deserialize(config, custom_objects)
#     867       module_objects=all_classes,
#     868       custom_objects=custom_objects,
# --> 869       printable_module_name='optimizer')
#     870
#     871
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/utils/generic_utils.py in deserialize_keras_object(identifier, module_objects, custom_objects, printable_module_name)
#     345     config = identifier
#     346     (cls, cls_config) = class_and_config_for_serialized_keras_object(
# --> 347         config, module_objects, custom_objects, printable_module_name)
#     348
#     349     if hasattr(cls, 'from_config'):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/utils/generic_utils.py in class_and_config_for_serialized_keras_object(config, module_objects, custom_objects, printable_module_name)
#     294   cls = get_registered_object(class_name, custom_objects, module_objects)
#     295   if cls is None:
# --> 296     raise ValueError('Unknown ' + printable_module_name + ': ' + class_name)
#     297
#     298   cls_config = config['config']
#
# ValueError: Unknown optimizer: AdamW

# %%
# 2. epoch=?
loss , acc, top5_acc, mf1 = model.evaluate(test_generator,steps=int(len(x_test)/batch_sizes))
print('[Test Loss: %.4f /  Test Top-1 Accuracy: %.4f / Test Top-5 Accuracy: %.4f / Test Macro f1: %.4f]\n' % (loss,acc,top5_acc,mf1))
