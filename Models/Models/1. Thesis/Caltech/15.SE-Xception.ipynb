# %%
### 참고 : https://sike6054.github.io/blog/paper/fifth-post/
### SE block 코드 참고 : https://github.com/titu1994/keras-squeeze-excite-network/tree/master/keras_squeeze_excite_network

# %% [markdown]
# # [SE-Xception]

# %% [markdown]
# *KU LeeDongGyu*

# %% [markdown]
# ## Contents
# ---

# %% [markdown]
# 1. Data Preprocessing
# ```
# 1) Data Import
# 2) Data Augmentation
# ```
# 2. Support Functions & Almost Original SE-Xception
# ```
# 1) Support Functions
# 2) Almost Original SE-Xception
# 3) SE-Xception Evaluate
# ```

# %% [markdown]
# ### Install Packages

# %% [markdown]
# ### Module

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/My Drive/Colab Notebooks/Paper
# Out:
# /content/drive/My Drive/Colab Notebooks/Paper

# %%
from f1score import macro_f1score,weighted_f1score

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import cv2
import tensorflow as tf
from tensorflow import keras as ks
from tensorflow.keras import backend as K 
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, Input, Concatenate, ZeroPadding2D ,GlobalMaxPooling2D, Reshape , Lambda , Add, Multiply
from tensorflow.keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D, Activation, BatchNormalization, AveragePooling2D , ZeroPadding2D, SeparableConv2D , LeakyReLU
from tensorflow.keras.layers import add, concatenate, multiply
from tensorflow.keras.optimizers import Adam, RMSprop , SGD
from tensorflow.keras.callbacks import EarlyStopping , LearningRateScheduler, ModelCheckpoint, CSVLogger, Callback, ReduceLROnPlateau
from tensorflow.keras.regularizers import l1,l2,l1_l2
from tensorflow.keras.models import Model , load_model , Sequential
from tensorflow.keras.utils import plot_model , to_categorical, get_file
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
os.getcwd()
# Out:
# '/content/drive/My Drive/Colab Notebooks/Paper'

# %%
print(tf.__version__)
print(ks.__version__)
# Out:
# 2.3.0
# 2.4.0

# %%
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 1711619400090673825
# , name: "/device:XLA_CPU:0"
# device_type: "XLA_CPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 6490888301108805583
# physical_device_desc: "device: XLA_CPU device"
# , name: "/device:XLA_GPU:0"
# device_type: "XLA_GPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 90651987187265829
# physical_device_desc: "device: XLA_GPU device"
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 15473775744
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 16656843438834766115
# physical_device_desc: "device: 0, name: Tesla V100-SXM2-16GB, pci bus id: 0000:00:04.0, compute capability: 7.0"
# ]

# %%
# !cat /proc/cpuinfo
# Out:
# processor	: 0
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 85
# model name	: Intel(R) Xeon(R) CPU @ 2.00GHz
# stepping	: 3
# microcode	: 0x1
# cpu MHz		: 2000.178
# cache size	: 39424 KB
# physical id	: 0
# siblings	: 4
# core id		: 0
# cpu cores	: 2
# apicid		: 0
# initial apicid	: 0
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm mpx avx512f avx512dq rdseed adx smap clflushopt clwb avx512cd avx512bw avx512vl xsaveopt xsavec xgetbv1 xsaves arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs taa
# bogomips	: 4000.35
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 46 bits physical, 48 bits virtual
# power management:
#
# processor	: 1
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 85
# model name	: Intel(R) Xeon(R) CPU @ 2.00GHz
# stepping	: 3
# microcode	: 0x1
# cpu MHz		: 2000.178
# cache size	: 39424 KB
# physical id	: 0
# siblings	: 4
# core id		: 1
# cpu cores	: 2
# apicid		: 2
# initial apicid	: 2
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm mpx avx512f avx512dq rdseed adx smap clflushopt clwb avx512cd avx512bw avx512vl xsaveopt xsavec xgetbv1 xsaves arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs taa
# bogomips	: 4000.35
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 46 bits physical, 48 bits virtual
# power management:
#
# processor	: 2
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 85
# model name	: Intel(R) Xeon(R) CPU @ 2.00GHz
# stepping	: 3
# microcode	: 0x1
# cpu MHz		: 2000.178
# cache size	: 39424 KB
# physical id	: 0
# siblings	: 4
# core id		: 0
# cpu cores	: 2
# apicid		: 1
# initial apicid	: 1
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm mpx avx512f avx512dq rdseed adx smap clflushopt clwb avx512cd avx512bw avx512vl xsaveopt xsavec xgetbv1 xsaves arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs taa
# bogomips	: 4000.35
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 46 bits physical, 48 bits virtual
# power management:
#
# processor	: 3
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 85
# model name	: Intel(R) Xeon(R) CPU @ 2.00GHz
# stepping	: 3
# microcode	: 0x1
# cpu MHz		: 2000.178
# cache size	: 39424 KB
# physical id	: 0
# siblings	: 4
# core id		: 1
# cpu cores	: 2
# apicid		: 3
# initial apicid	: 3
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm mpx avx512f avx512dq rdseed adx smap clflushopt clwb avx512cd avx512bw avx512vl xsaveopt xsavec xgetbv1 xsaves arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs taa
# bogomips	: 4000.35
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 46 bits physical, 48 bits virtual
# power management:

# %% [markdown]
# ## 1. Data Preprocessing
# ---

# %% [markdown]
# ### 1) Data Import

# %%
# 바꿔서 살펴 볼 것들
# CALTECH, CIFAR100, FER, MIT
data_name = 'CALTECH'
gan_type = 'No_GAN'
number = '1'
size = 299 # sizes after cropping
super_size = 330 # sizes before cropping 
input_sizes = (size,size,3)
batch_sizes = 32
weight_decay = 1e-6
epochs = 70

# %%
# 참고 : https://stackoverflow.com/questions/32419510/how-to-get-reproducible-results-in-keras/52897216#52897216
# setting the seed number for random number generation for reproducibility.

from numpy.random import seed
import random


if number=='1':
    seed_num = 200225
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)
elif number=='2':
    seed_num = 727
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)
elif number=='3':
    seed_num = 115
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)
elif number=='4':
    seed_num = 501
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)
elif number=='5':
    seed_num = 517
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)

# %%
# data import

if data_name=='FER' :
    x_train =  np.zeros(28698)
    x_valid = np.zeros(3589)
    x_test = np.zeros(3588)
    classes = 7 
    tr_center = [0.50793296, 0.50793296, 0.50793296]
elif data_name=='MIT':
    x_train = np.zeros(12466)
    x_valid = np.zeros(1564)
    x_test = np.zeros(1590)
    classes = 67 
    tr_center = [0.47916578, 0.42029615, 0.36046057]
elif data_name=='CALTECH':
    x_train = np.zeros(24510)
    x_valid = np.zeros(2980)
    x_test = np.zeros(3118)
    classes = 257
    tr_center = [0.51397761, 0.49525248, 0.46555727]
elif data_name=='CIFAR100':
    x_train = np.zeros(44923)
    x_valid = np.zeros(5077)
    x_test = np.zeros(10000)
    classes = 100
    tr_center = [0.53442983, 0.51355958, 0.46462564]

# %%
dir = os.path.join(os.getcwd(),data_name,gan_type)

# %% [markdown]
# ### 2) Data Augmentation

# %%
# 참고 : https://jkjung-avt.github.io/keras-image-cropping/

def random_crop(img, random_crop_size):
    # Note: image_data_format is 'channel_last'
    assert img.shape[2] == 3 # img.shape[2] 가 3(rgb)이 아니면 assertion error 발생
    height, width = img.shape[0], img.shape[1]
    dy, dx = random_crop_size
    x = np.random.randint(0, width - dx + 1)
    y = np.random.randint(0, height - dy + 1)
    return img[y:(y+dy), x:(x+dx), :]


def crop_generator(batches, crop_length):
    """Take as input a Keras ImageGen (Iterator) and generate random
    crops from the image batches generated by the original iterator.
    """
    while True:
        batch_x, batch_y = next(batches)
        batch_crops = np.zeros((batch_x.shape[0], crop_length, crop_length, 3))
        for i in range(batch_x.shape[0]):
            batch_crops[i] = random_crop(batch_x[i], (crop_length, crop_length))
        yield (batch_crops, batch_y)

# %%
from tensorflow.keras.preprocessing.image import img_to_array,load_img
import glob

# 데이터 전체에 대해 centering 진행함.

def read_cal_image(img_path): 
    x = img_to_array(load_img(img_path)) # x는 채널별 평균값
    y = x.shape[0] * x.shape[1]# y는 데이터별 픽셀 수 (비중)

    x = 1/255. * x # scaling하고, centering값을 뽑아냄.
    x = np.mean(x, axis=(0,1))
    
    return np.hstack([x,y])

def calculate_centered_mean(dataset_path,x_train=x_train):
    num = len(x_train)
    space = np.empty((num,4))
    i=0

    for p in glob.glob(os.path.join(dataset_path,'*/*.*')) :
        space[i] = read_cal_image(p)
        i += 1

    ratio = space[:,3] / np.sum(space[:,3])

    return np.average(space[:,0:3],axis=0,weights=ratio)


# 아래의 함수를 돌려서 나온 결과값을 중심화 값으로 설정.

# train_mean = calculate_centered_mean(os.path.join(dir,'data/train')).reshape((1,1,3))

# %%
datagen_tr = ImageDataGenerator(
    rescale=1/255.,
    horizontal_flip=True,
    featurewise_center=True,
    featurewise_std_normalization=False,
    rotation_range=10,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=[0.9,1.0],
    fill_mode = 'nearest')
datagen_val = ImageDataGenerator(rescale=1/255.,featurewise_center=True)
datagen_tes = ImageDataGenerator(rescale=1/255.,featurewise_center=True)

# 원래는 이 자리에 fit 매서드를 써야하지만, 그냥 내가 중심화함수를 만들고 적용함. 

# 중심화 설정
datagen_tr.mean = np.array(tr_center, dtype=np.float32).reshape((1,1,3)) # RGB
datagen_val.mean = np.array(tr_center, dtype=np.float32).reshape((1,1,3)) # RGB
datagen_tes.mean = np.array(tr_center, dtype=np.float32).reshape((1,1,3)) # RGB

# %%
train_batches = datagen_tr.flow_from_directory(directory=os.path.join(dir,'data/train'),target_size=(super_size,super_size),batch_size=batch_sizes,class_mode='categorical') # fer : 28698 / mit : 12466 / caltech : 24509 / cifar : 44923
train_generator= crop_generator(train_batches, size)
valid_generator = datagen_val.flow_from_directory(directory=os.path.join(dir,'data/valid'),target_size=(size,size),batch_size=batch_sizes,class_mode='categorical') # fer : 3589 / mit : 1564 / caltech : 2980 / cifar : 5077
test_generator = datagen_tes.flow_from_directory(directory=os.path.join(dir,'data/test'),target_size=(size,size),batch_size=batch_sizes,class_mode='categorical') # fer : 3588 / mit : 1590 / caltech : 3118 / cifar : 10000
# Out:
# Found 24509 images belonging to 257 classes.
# Found 2980 images belonging to 257 classes.
# Found 3118 images belonging to 257 classes.

# %% [markdown]
# ## 2. Support Functions & Almost Original SE-Xception
# ---

# %% [markdown]
# ### 1) Support Functions

# %%
# def lr_schedule(epoch):
#     init_lr = 1e-4
#     k = 0.04
#     lr = init_lr * np.exp(-k*epoch)
#     print('Learning rate: ', lr)
#     return lr

def lr_schedule(epoch):
    lr = 1e-3
    if epoch < 30:
        lr = lr
    elif epoch < 60:
        lr = lr * 0.1
    else:
        lr = lr * 0.01
    print('Learning rate: ', lr)
    return lr

# %%
def squeeze_excite_block(input, reduction_ratio=16, weight_decay=weight_decay):

    init = input
    channel_axis = -1
    filters = init.get_shape()[channel_axis]
    se_shape = (1, 1, filters)

    se = GlobalAveragePooling2D()(init)
    se = Reshape(se_shape)(se)
    se = Dense(filters // reduction_ratio, activation='relu', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay), use_bias=False)(se)
    se = Dense(filters, activation='sigmoid', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay), use_bias=False)(se)

    x = multiply([init, se])
    return x

# %% [markdown]
# ### 2) Almost Original SE-Xception

# %%
def SE_Xception(input_shape=None, classes=1000, reduction_ratio = 16, name = "SE_Xception", weight_decay = weight_decay):


    img_input = Input(shape=input_shape)


    x = Conv2D(32, (3, 3), strides=(2, 2), use_bias=False, kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay), name='block1_conv1')(img_input)
    x = BatchNormalization(name='block1_conv1_bn')(x)
    x = Activation('relu', name='block1_conv1_act')(x)
    x = Conv2D(64, (3, 3), use_bias=False, kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay), name='block1_conv2')(x)
    x = BatchNormalization(name='block1_conv2_bn')(x)
    x = Activation('relu', name='block1_conv2_act')(x)

    residual = Conv2D(128, (1, 1), strides=(2, 2),
                      padding='same', use_bias=False, kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(x)
    residual = BatchNormalization()(residual)

    x = SeparableConv2D(128, (3, 3), padding='same', use_bias=False, depthwise_initializer='he_uniform', pointwise_initializer='he_uniform',depthwise_regularizer=l2(weight_decay), pointwise_regularizer=l2(weight_decay), name='block2_sepconv1')(x)
    x = BatchNormalization(name='block2_sepconv1_bn')(x)
    x = Activation('relu', name='block2_sepconv2_act')(x)
    x = SeparableConv2D(128, (3, 3), padding='same', use_bias=False, depthwise_initializer='he_uniform', pointwise_initializer='he_uniform',depthwise_regularizer=l2(weight_decay), pointwise_regularizer=l2(weight_decay), name='block2_sepconv2')(x)
    x = BatchNormalization(name='block2_sepconv2_bn')(x)

    x = MaxPooling2D((3, 3), strides=(2, 2), padding='same', name='block2_pool')(x)
    # SE block 추가
    x =  squeeze_excite_block(x, reduction_ratio)
    x = add([x, residual])

    residual = Conv2D(256, (1, 1), strides=(2, 2),
                      padding='same', use_bias=False, kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(x)
    residual = BatchNormalization()(residual)

    x = Activation('relu', name='block3_sepconv1_act')(x)
    x = SeparableConv2D(256, (3, 3), padding='same', use_bias=False, depthwise_initializer='he_uniform', pointwise_initializer='he_uniform',depthwise_regularizer=l2(weight_decay), pointwise_regularizer=l2(weight_decay), name='block3_sepconv1')(x)
    x = BatchNormalization(name='block3_sepconv1_bn')(x)
    x = Activation('relu', name='block3_sepconv2_act')(x)
    x = SeparableConv2D(256, (3, 3), padding='same', use_bias=False, depthwise_initializer='he_uniform', pointwise_initializer='he_uniform',depthwise_regularizer=l2(weight_decay), pointwise_regularizer=l2(weight_decay), name='block3_sepconv2')(x)
    x = BatchNormalization(name='block3_sepconv2_bn')(x)

    x = MaxPooling2D((3, 3), strides=(2, 2), padding='same', name='block3_pool')(x)
    # SE block 추가
    x =  squeeze_excite_block(x, reduction_ratio)    
    x = add([x, residual])

    residual = Conv2D(728, (1, 1), strides=(2, 2),
                      padding='same', use_bias=False, kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(x)
    residual = BatchNormalization()(residual)

    x = Activation('relu', name='block4_sepconv1_act')(x)
    x = SeparableConv2D(728, (3, 3), padding='same', use_bias=False, depthwise_initializer='he_uniform', pointwise_initializer='he_uniform',depthwise_regularizer=l2(weight_decay), pointwise_regularizer=l2(weight_decay), name='block4_sepconv1')(x)
    x = BatchNormalization(name='block4_sepconv1_bn')(x)
    x = Activation('relu', name='block4_sepconv2_act')(x)
    x = SeparableConv2D(728, (3, 3), padding='same', use_bias=False, depthwise_initializer='he_uniform', pointwise_initializer='he_uniform',depthwise_regularizer=l2(weight_decay), pointwise_regularizer=l2(weight_decay), name='block4_sepconv2')(x)
    x = BatchNormalization(name='block4_sepconv2_bn')(x)

    x = MaxPooling2D((3, 3), strides=(2, 2), padding='same', name='block4_pool')(x)
    # SE block 추가
    x =  squeeze_excite_block(x, reduction_ratio)
    x = add([x, residual])

    for i in range(8):
        residual = x
        prefix = 'block' + str(i + 5)

        x = Activation('relu', name=prefix + '_sepconv1_act')(x)
        x = SeparableConv2D(728, (3, 3), padding='same', use_bias=False, depthwise_initializer='he_uniform', pointwise_initializer='he_uniform',depthwise_regularizer=l2(weight_decay), pointwise_regularizer=l2(weight_decay), name=prefix + '_sepconv1')(x)
        x = BatchNormalization(name=prefix + '_sepconv1_bn')(x)
        x = Activation('relu', name=prefix + '_sepconv2_act')(x)
        x = SeparableConv2D(728, (3, 3), padding='same', use_bias=False, depthwise_initializer='he_uniform', pointwise_initializer='he_uniform',depthwise_regularizer=l2(weight_decay), pointwise_regularizer=l2(weight_decay), name=prefix + '_sepconv2')(x)
        x = BatchNormalization(name=prefix + '_sepconv2_bn')(x)
        x = Activation('relu', name=prefix + '_sepconv3_act')(x)
        x = SeparableConv2D(728, (3, 3), padding='same', use_bias=False, depthwise_initializer='he_uniform', pointwise_initializer='he_uniform',depthwise_regularizer=l2(weight_decay), pointwise_regularizer=l2(weight_decay), name=prefix + '_sepconv3')(x)
        x = BatchNormalization(name=prefix + '_sepconv3_bn')(x)

        # SE block 추가
        x =  squeeze_excite_block(x, reduction_ratio)
        x = add([x, residual])

    residual = Conv2D(1024, (1, 1), strides=(2, 2),
                      padding='same', use_bias=False, kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(x)
    residual = BatchNormalization()(residual)

    x = Activation('relu', name='block13_sepconv1_act')(x)
    x = SeparableConv2D(728, (3, 3), padding='same', use_bias=False, depthwise_initializer='he_uniform', pointwise_initializer='he_uniform',depthwise_regularizer=l2(weight_decay), pointwise_regularizer=l2(weight_decay), name='block13_sepconv1')(x)
    x = BatchNormalization(name='block13_sepconv1_bn')(x)
    x = Activation('relu', name='block13_sepconv2_act')(x)
    x = SeparableConv2D(1024, (3, 3), padding='same', use_bias=False, depthwise_initializer='he_uniform', pointwise_initializer='he_uniform',depthwise_regularizer=l2(weight_decay), pointwise_regularizer=l2(weight_decay), name='block13_sepconv2')(x)
    x = BatchNormalization(name='block13_sepconv2_bn')(x)

    x = MaxPooling2D((3, 3), strides=(2, 2), padding='same', name='block13_pool')(x)
    # SE block 추가
    x =  squeeze_excite_block(x, reduction_ratio)
    x = add([x, residual])

    x = SeparableConv2D(1536, (3, 3), padding='same', use_bias=False, depthwise_initializer='he_uniform', pointwise_initializer='he_uniform',depthwise_regularizer=l2(weight_decay), pointwise_regularizer=l2(weight_decay), name='block14_sepconv1')(x)
    x = BatchNormalization(name='block14_sepconv1_bn')(x)
    x = Activation('relu', name='block14_sepconv1_act')(x)

    x = SeparableConv2D(2048, (3, 3), padding='same', use_bias=False, depthwise_initializer='he_uniform', pointwise_initializer='he_uniform',depthwise_regularizer=l2(weight_decay), pointwise_regularizer=l2(weight_decay), name='block14_sepconv2')(x)
    x = BatchNormalization(name='block14_sepconv2_bn')(x)
    x = Activation('relu', name='block14_sepconv2_act')(x)


    x = GlobalAveragePooling2D(name='avg_pool')(x)
    x = Dropout(0.5)(x)
    x = Dense(classes, activation='softmax', kernel_regularizer=l2(weight_decay), name='predictions')(x)


    inputs = img_input

    # Create model.
    model = Model(inputs, x, name=name)

    return model

# %%
model = SE_Xception(input_sizes, classes=classes, reduction_ratio = 16, name='SE_Xception')

# %%
model.summary()
# Out:
# Model: "SE_Xception"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 299, 299, 3) 0
# __________________________________________________________________________________________________
# block1_conv1 (Conv2D)           (None, 149, 149, 32) 864         input_1[0][0]
# __________________________________________________________________________________________________
# block1_conv1_bn (BatchNormaliza (None, 149, 149, 32) 128         block1_conv1[0][0]
# __________________________________________________________________________________________________
# block1_conv1_act (Activation)   (None, 149, 149, 32) 0           block1_conv1_bn[0][0]
# __________________________________________________________________________________________________
# block1_conv2 (Conv2D)           (None, 147, 147, 64) 18432       block1_conv1_act[0][0]
# __________________________________________________________________________________________________
# block1_conv2_bn (BatchNormaliza (None, 147, 147, 64) 256         block1_conv2[0][0]
# __________________________________________________________________________________________________
# block1_conv2_act (Activation)   (None, 147, 147, 64) 0           block1_conv2_bn[0][0]
# __________________________________________________________________________________________________
# block2_sepconv1 (SeparableConv2 (None, 147, 147, 128 8768        block1_conv2_act[0][0]
# __________________________________________________________________________________________________
# block2_sepconv1_bn (BatchNormal (None, 147, 147, 128 512         block2_sepconv1[0][0]
# __________________________________________________________________________________________________
# block2_sepconv2_act (Activation (None, 147, 147, 128 0           block2_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block2_sepconv2 (SeparableConv2 (None, 147, 147, 128 17536       block2_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block2_sepconv2_bn (BatchNormal (None, 147, 147, 128 512         block2_sepconv2[0][0]
# __________________________________________________________________________________________________
# block2_pool (MaxPooling2D)      (None, 74, 74, 128)  0           block2_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 128)          0           block2_pool[0][0]
# __________________________________________________________________________________________________
# reshape (Reshape)               (None, 1, 1, 128)    0           global_average_pooling2d[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 1, 1, 8)      1024        reshape[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 1, 1, 128)    1024        dense[0][0]
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 74, 74, 128)  8192        block1_conv2_act[0][0]
# __________________________________________________________________________________________________
# multiply (Multiply)             (None, 74, 74, 128)  0           block2_pool[0][0]
#                                                                  dense_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 74, 74, 128)  512         conv2d[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 74, 74, 128)  0           multiply[0][0]
#                                                                  batch_normalization[0][0]
# __________________________________________________________________________________________________
# block3_sepconv1_act (Activation (None, 74, 74, 128)  0           add[0][0]
# __________________________________________________________________________________________________
# block3_sepconv1 (SeparableConv2 (None, 74, 74, 256)  33920       block3_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block3_sepconv1_bn (BatchNormal (None, 74, 74, 256)  1024        block3_sepconv1[0][0]
# __________________________________________________________________________________________________
# block3_sepconv2_act (Activation (None, 74, 74, 256)  0           block3_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block3_sepconv2 (SeparableConv2 (None, 74, 74, 256)  67840       block3_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block3_sepconv2_bn (BatchNormal (None, 74, 74, 256)  1024        block3_sepconv2[0][0]
# __________________________________________________________________________________________________
# block3_pool (MaxPooling2D)      (None, 37, 37, 256)  0           block3_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_1 (Glo (None, 256)          0           block3_pool[0][0]
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, 1, 1, 256)    0           global_average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 1, 1, 16)     4096        reshape_1[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 1, 1, 256)    4096        dense_2[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 37, 37, 256)  32768       add[0][0]
# __________________________________________________________________________________________________
# multiply_1 (Multiply)           (None, 37, 37, 256)  0           block3_pool[0][0]
#                                                                  dense_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 37, 37, 256)  1024        conv2d_1[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 37, 37, 256)  0           multiply_1[0][0]
#                                                                  batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# block4_sepconv1_act (Activation (None, 37, 37, 256)  0           add_1[0][0]
# __________________________________________________________________________________________________
# block4_sepconv1 (SeparableConv2 (None, 37, 37, 728)  188672      block4_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block4_sepconv1_bn (BatchNormal (None, 37, 37, 728)  2912        block4_sepconv1[0][0]
# __________________________________________________________________________________________________
# block4_sepconv2_act (Activation (None, 37, 37, 728)  0           block4_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block4_sepconv2 (SeparableConv2 (None, 37, 37, 728)  536536      block4_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block4_sepconv2_bn (BatchNormal (None, 37, 37, 728)  2912        block4_sepconv2[0][0]
# __________________________________________________________________________________________________
# block4_pool (MaxPooling2D)      (None, 19, 19, 728)  0           block4_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_2 (Glo (None, 728)          0           block4_pool[0][0]
# __________________________________________________________________________________________________
# reshape_2 (Reshape)             (None, 1, 1, 728)    0           global_average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 1, 1, 45)     32760       reshape_2[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 1, 1, 728)    32760       dense_4[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 19, 19, 728)  186368      add_1[0][0]
# __________________________________________________________________________________________________
# multiply_2 (Multiply)           (None, 19, 19, 728)  0           block4_pool[0][0]
#                                                                  dense_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 19, 19, 728)  2912        conv2d_2[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 19, 19, 728)  0           multiply_2[0][0]
#                                                                  batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# block5_sepconv1_act (Activation (None, 19, 19, 728)  0           add_2[0][0]
# __________________________________________________________________________________________________
# block5_sepconv1 (SeparableConv2 (None, 19, 19, 728)  536536      block5_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block5_sepconv1_bn (BatchNormal (None, 19, 19, 728)  2912        block5_sepconv1[0][0]
# __________________________________________________________________________________________________
# block5_sepconv2_act (Activation (None, 19, 19, 728)  0           block5_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block5_sepconv2 (SeparableConv2 (None, 19, 19, 728)  536536      block5_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block5_sepconv2_bn (BatchNormal (None, 19, 19, 728)  2912        block5_sepconv2[0][0]
# __________________________________________________________________________________________________
# block5_sepconv3_act (Activation (None, 19, 19, 728)  0           block5_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block5_sepconv3 (SeparableConv2 (None, 19, 19, 728)  536536      block5_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block5_sepconv3_bn (BatchNormal (None, 19, 19, 728)  2912        block5_sepconv3[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_3 (Glo (None, 728)          0           block5_sepconv3_bn[0][0]
# __________________________________________________________________________________________________
# reshape_3 (Reshape)             (None, 1, 1, 728)    0           global_average_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 1, 1, 45)     32760       reshape_3[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 1, 1, 728)    32760       dense_6[0][0]
# __________________________________________________________________________________________________
# multiply_3 (Multiply)           (None, 19, 19, 728)  0           block5_sepconv3_bn[0][0]
#                                                                  dense_7[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 19, 19, 728)  0           multiply_3[0][0]
#                                                                  add_2[0][0]
# __________________________________________________________________________________________________
# block6_sepconv1_act (Activation (None, 19, 19, 728)  0           add_3[0][0]
# __________________________________________________________________________________________________
# block6_sepconv1 (SeparableConv2 (None, 19, 19, 728)  536536      block6_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block6_sepconv1_bn (BatchNormal (None, 19, 19, 728)  2912        block6_sepconv1[0][0]
# __________________________________________________________________________________________________
# block6_sepconv2_act (Activation (None, 19, 19, 728)  0           block6_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block6_sepconv2 (SeparableConv2 (None, 19, 19, 728)  536536      block6_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block6_sepconv2_bn (BatchNormal (None, 19, 19, 728)  2912        block6_sepconv2[0][0]
# __________________________________________________________________________________________________
# block6_sepconv3_act (Activation (None, 19, 19, 728)  0           block6_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block6_sepconv3 (SeparableConv2 (None, 19, 19, 728)  536536      block6_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block6_sepconv3_bn (BatchNormal (None, 19, 19, 728)  2912        block6_sepconv3[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_4 (Glo (None, 728)          0           block6_sepconv3_bn[0][0]
# __________________________________________________________________________________________________
# reshape_4 (Reshape)             (None, 1, 1, 728)    0           global_average_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 1, 1, 45)     32760       reshape_4[0][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, 1, 1, 728)    32760       dense_8[0][0]
# __________________________________________________________________________________________________
# multiply_4 (Multiply)           (None, 19, 19, 728)  0           block6_sepconv3_bn[0][0]
#                                                                  dense_9[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 19, 19, 728)  0           multiply_4[0][0]
#                                                                  add_3[0][0]
# __________________________________________________________________________________________________
# block7_sepconv1_act (Activation (None, 19, 19, 728)  0           add_4[0][0]
# __________________________________________________________________________________________________
# block7_sepconv1 (SeparableConv2 (None, 19, 19, 728)  536536      block7_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block7_sepconv1_bn (BatchNormal (None, 19, 19, 728)  2912        block7_sepconv1[0][0]
# __________________________________________________________________________________________________
# block7_sepconv2_act (Activation (None, 19, 19, 728)  0           block7_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block7_sepconv2 (SeparableConv2 (None, 19, 19, 728)  536536      block7_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block7_sepconv2_bn (BatchNormal (None, 19, 19, 728)  2912        block7_sepconv2[0][0]
# __________________________________________________________________________________________________
# block7_sepconv3_act (Activation (None, 19, 19, 728)  0           block7_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block7_sepconv3 (SeparableConv2 (None, 19, 19, 728)  536536      block7_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block7_sepconv3_bn (BatchNormal (None, 19, 19, 728)  2912        block7_sepconv3[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_5 (Glo (None, 728)          0           block7_sepconv3_bn[0][0]
# __________________________________________________________________________________________________
# reshape_5 (Reshape)             (None, 1, 1, 728)    0           global_average_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# dense_10 (Dense)                (None, 1, 1, 45)     32760       reshape_5[0][0]
# __________________________________________________________________________________________________
# dense_11 (Dense)                (None, 1, 1, 728)    32760       dense_10[0][0]
# __________________________________________________________________________________________________
# multiply_5 (Multiply)           (None, 19, 19, 728)  0           block7_sepconv3_bn[0][0]
#                                                                  dense_11[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 19, 19, 728)  0           multiply_5[0][0]
#                                                                  add_4[0][0]
# __________________________________________________________________________________________________
# block8_sepconv1_act (Activation (None, 19, 19, 728)  0           add_5[0][0]
# __________________________________________________________________________________________________
# block8_sepconv1 (SeparableConv2 (None, 19, 19, 728)  536536      block8_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block8_sepconv1_bn (BatchNormal (None, 19, 19, 728)  2912        block8_sepconv1[0][0]
# __________________________________________________________________________________________________
# block8_sepconv2_act (Activation (None, 19, 19, 728)  0           block8_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block8_sepconv2 (SeparableConv2 (None, 19, 19, 728)  536536      block8_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block8_sepconv2_bn (BatchNormal (None, 19, 19, 728)  2912        block8_sepconv2[0][0]
# __________________________________________________________________________________________________
# block8_sepconv3_act (Activation (None, 19, 19, 728)  0           block8_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block8_sepconv3 (SeparableConv2 (None, 19, 19, 728)  536536      block8_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block8_sepconv3_bn (BatchNormal (None, 19, 19, 728)  2912        block8_sepconv3[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_6 (Glo (None, 728)          0           block8_sepconv3_bn[0][0]
# __________________________________________________________________________________________________
# reshape_6 (Reshape)             (None, 1, 1, 728)    0           global_average_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# dense_12 (Dense)                (None, 1, 1, 45)     32760       reshape_6[0][0]
# __________________________________________________________________________________________________
# dense_13 (Dense)                (None, 1, 1, 728)    32760       dense_12[0][0]
# __________________________________________________________________________________________________
# multiply_6 (Multiply)           (None, 19, 19, 728)  0           block8_sepconv3_bn[0][0]
#                                                                  dense_13[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 19, 19, 728)  0           multiply_6[0][0]
#                                                                  add_5[0][0]
# __________________________________________________________________________________________________
# block9_sepconv1_act (Activation (None, 19, 19, 728)  0           add_6[0][0]
# __________________________________________________________________________________________________
# block9_sepconv1 (SeparableConv2 (None, 19, 19, 728)  536536      block9_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block9_sepconv1_bn (BatchNormal (None, 19, 19, 728)  2912        block9_sepconv1[0][0]
# __________________________________________________________________________________________________
# block9_sepconv2_act (Activation (None, 19, 19, 728)  0           block9_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block9_sepconv2 (SeparableConv2 (None, 19, 19, 728)  536536      block9_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block9_sepconv2_bn (BatchNormal (None, 19, 19, 728)  2912        block9_sepconv2[0][0]
# __________________________________________________________________________________________________
# block9_sepconv3_act (Activation (None, 19, 19, 728)  0           block9_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block9_sepconv3 (SeparableConv2 (None, 19, 19, 728)  536536      block9_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block9_sepconv3_bn (BatchNormal (None, 19, 19, 728)  2912        block9_sepconv3[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_7 (Glo (None, 728)          0           block9_sepconv3_bn[0][0]
# __________________________________________________________________________________________________
# reshape_7 (Reshape)             (None, 1, 1, 728)    0           global_average_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# dense_14 (Dense)                (None, 1, 1, 45)     32760       reshape_7[0][0]
# __________________________________________________________________________________________________
# dense_15 (Dense)                (None, 1, 1, 728)    32760       dense_14[0][0]
# __________________________________________________________________________________________________
# multiply_7 (Multiply)           (None, 19, 19, 728)  0           block9_sepconv3_bn[0][0]
#                                                                  dense_15[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 19, 19, 728)  0           multiply_7[0][0]
#                                                                  add_6[0][0]
# __________________________________________________________________________________________________
# block10_sepconv1_act (Activatio (None, 19, 19, 728)  0           add_7[0][0]
# __________________________________________________________________________________________________
# block10_sepconv1 (SeparableConv (None, 19, 19, 728)  536536      block10_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block10_sepconv1_bn (BatchNorma (None, 19, 19, 728)  2912        block10_sepconv1[0][0]
# __________________________________________________________________________________________________
# block10_sepconv2_act (Activatio (None, 19, 19, 728)  0           block10_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block10_sepconv2 (SeparableConv (None, 19, 19, 728)  536536      block10_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block10_sepconv2_bn (BatchNorma (None, 19, 19, 728)  2912        block10_sepconv2[0][0]
# __________________________________________________________________________________________________
# block10_sepconv3_act (Activatio (None, 19, 19, 728)  0           block10_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block10_sepconv3 (SeparableConv (None, 19, 19, 728)  536536      block10_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block10_sepconv3_bn (BatchNorma (None, 19, 19, 728)  2912        block10_sepconv3[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_8 (Glo (None, 728)          0           block10_sepconv3_bn[0][0]
# __________________________________________________________________________________________________
# reshape_8 (Reshape)             (None, 1, 1, 728)    0           global_average_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# dense_16 (Dense)                (None, 1, 1, 45)     32760       reshape_8[0][0]
# __________________________________________________________________________________________________
# dense_17 (Dense)                (None, 1, 1, 728)    32760       dense_16[0][0]
# __________________________________________________________________________________________________
# multiply_8 (Multiply)           (None, 19, 19, 728)  0           block10_sepconv3_bn[0][0]
#                                                                  dense_17[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 19, 19, 728)  0           multiply_8[0][0]
#                                                                  add_7[0][0]
# __________________________________________________________________________________________________
# block11_sepconv1_act (Activatio (None, 19, 19, 728)  0           add_8[0][0]
# __________________________________________________________________________________________________
# block11_sepconv1 (SeparableConv (None, 19, 19, 728)  536536      block11_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block11_sepconv1_bn (BatchNorma (None, 19, 19, 728)  2912        block11_sepconv1[0][0]
# __________________________________________________________________________________________________
# block11_sepconv2_act (Activatio (None, 19, 19, 728)  0           block11_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block11_sepconv2 (SeparableConv (None, 19, 19, 728)  536536      block11_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block11_sepconv2_bn (BatchNorma (None, 19, 19, 728)  2912        block11_sepconv2[0][0]
# __________________________________________________________________________________________________
# block11_sepconv3_act (Activatio (None, 19, 19, 728)  0           block11_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block11_sepconv3 (SeparableConv (None, 19, 19, 728)  536536      block11_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block11_sepconv3_bn (BatchNorma (None, 19, 19, 728)  2912        block11_sepconv3[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_9 (Glo (None, 728)          0           block11_sepconv3_bn[0][0]
# __________________________________________________________________________________________________
# reshape_9 (Reshape)             (None, 1, 1, 728)    0           global_average_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# dense_18 (Dense)                (None, 1, 1, 45)     32760       reshape_9[0][0]
# __________________________________________________________________________________________________
# dense_19 (Dense)                (None, 1, 1, 728)    32760       dense_18[0][0]
# __________________________________________________________________________________________________
# multiply_9 (Multiply)           (None, 19, 19, 728)  0           block11_sepconv3_bn[0][0]
#                                                                  dense_19[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 19, 19, 728)  0           multiply_9[0][0]
#                                                                  add_8[0][0]
# __________________________________________________________________________________________________
# block12_sepconv1_act (Activatio (None, 19, 19, 728)  0           add_9[0][0]
# __________________________________________________________________________________________________
# block12_sepconv1 (SeparableConv (None, 19, 19, 728)  536536      block12_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block12_sepconv1_bn (BatchNorma (None, 19, 19, 728)  2912        block12_sepconv1[0][0]
# __________________________________________________________________________________________________
# block12_sepconv2_act (Activatio (None, 19, 19, 728)  0           block12_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block12_sepconv2 (SeparableConv (None, 19, 19, 728)  536536      block12_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block12_sepconv2_bn (BatchNorma (None, 19, 19, 728)  2912        block12_sepconv2[0][0]
# __________________________________________________________________________________________________
# block12_sepconv3_act (Activatio (None, 19, 19, 728)  0           block12_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block12_sepconv3 (SeparableConv (None, 19, 19, 728)  536536      block12_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block12_sepconv3_bn (BatchNorma (None, 19, 19, 728)  2912        block12_sepconv3[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_10 (Gl (None, 728)          0           block12_sepconv3_bn[0][0]
# __________________________________________________________________________________________________
# reshape_10 (Reshape)            (None, 1, 1, 728)    0           global_average_pooling2d_10[0][0]
# __________________________________________________________________________________________________
# dense_20 (Dense)                (None, 1, 1, 45)     32760       reshape_10[0][0]
# __________________________________________________________________________________________________
# dense_21 (Dense)                (None, 1, 1, 728)    32760       dense_20[0][0]
# __________________________________________________________________________________________________
# multiply_10 (Multiply)          (None, 19, 19, 728)  0           block12_sepconv3_bn[0][0]
#                                                                  dense_21[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 19, 19, 728)  0           multiply_10[0][0]
#                                                                  add_9[0][0]
# __________________________________________________________________________________________________
# block13_sepconv1_act (Activatio (None, 19, 19, 728)  0           add_10[0][0]
# __________________________________________________________________________________________________
# block13_sepconv1 (SeparableConv (None, 19, 19, 728)  536536      block13_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block13_sepconv1_bn (BatchNorma (None, 19, 19, 728)  2912        block13_sepconv1[0][0]
# __________________________________________________________________________________________________
# block13_sepconv2_act (Activatio (None, 19, 19, 728)  0           block13_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block13_sepconv2 (SeparableConv (None, 19, 19, 1024) 752024      block13_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block13_sepconv2_bn (BatchNorma (None, 19, 19, 1024) 4096        block13_sepconv2[0][0]
# __________________________________________________________________________________________________
# block13_pool (MaxPooling2D)     (None, 10, 10, 1024) 0           block13_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_11 (Gl (None, 1024)         0           block13_pool[0][0]
# __________________________________________________________________________________________________
# reshape_11 (Reshape)            (None, 1, 1, 1024)   0           global_average_pooling2d_11[0][0]
# __________________________________________________________________________________________________
# dense_22 (Dense)                (None, 1, 1, 64)     65536       reshape_11[0][0]
# __________________________________________________________________________________________________
# dense_23 (Dense)                (None, 1, 1, 1024)   65536       dense_22[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 10, 10, 1024) 745472      add_10[0][0]
# __________________________________________________________________________________________________
# multiply_11 (Multiply)          (None, 10, 10, 1024) 0           block13_pool[0][0]
#                                                                  dense_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 10, 10, 1024) 4096        conv2d_3[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 10, 10, 1024) 0           multiply_11[0][0]
#                                                                  batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# block14_sepconv1 (SeparableConv (None, 10, 10, 1536) 1582080     add_11[0][0]
# __________________________________________________________________________________________________
# block14_sepconv1_bn (BatchNorma (None, 10, 10, 1536) 6144        block14_sepconv1[0][0]
# __________________________________________________________________________________________________
# block14_sepconv1_act (Activatio (None, 10, 10, 1536) 0           block14_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block14_sepconv2 (SeparableConv (None, 10, 10, 2048) 3159552     block14_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block14_sepconv2_bn (BatchNorma (None, 10, 10, 2048) 8192        block14_sepconv2[0][0]
# __________________________________________________________________________________________________
# block14_sepconv2_act (Activatio (None, 10, 10, 2048) 0           block14_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# avg_pool (GlobalAveragePooling2 (None, 2048)         0           block14_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 2048)         0           avg_pool[0][0]
# __________________________________________________________________________________________________
# predictions (Dense)             (None, 257)          526593      dropout[0][0]
# ==================================================================================================
# Total params: 22,119,065
# Trainable params: 22,064,537
# Non-trainable params: 54,528
# __________________________________________________________________________________________________

# %%
# 폴더 생성

os.makedirs(os.path.join(dir,'model_output',number,model.name), exist_ok=True)
os.makedirs(os.path.join(dir,'train_valid_output',number), exist_ok=True)

# %%
# 참고 : https://github.com/OverLordGoldDragon/keras-adamw

import sys
sys.path.append('/content/drive/My Drive/Colab Notebooks/Paper')
import utils
import optimizers_v2
from utils import get_weight_decays, fill_dict_in_order
from utils import reset_seeds, K_eval
from optimizers_v2 import AdamW, NadamW, SGDW

# %%
# top-5 accuracy 출력
import functools
top5_acc = functools.partial(ks.metrics.top_k_categorical_accuracy, k=5)
top5_acc.__name__ = 'top5_acc'

# %%
optimizer = AdamW(model=model, use_cosine_annealing=False, total_iterations = len(x_train) // batch_sizes)
#optimizer = Adam()
filepath =  os.path.join(dir,'model_output',number,model.name,'{epoch:03d}.h5')

callbacks_list = [ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_weights_only=False, save_best_only=True, mode='min'),
                  ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_weights_only=False, save_best_only=True, mode='max'),
                  #ReduceLROnPlateau(monitor='val_loss',patience=3,factor=0.1,min_lr=1e-5),
                  LearningRateScheduler(lr_schedule,verbose=1)
                  ]
                  
model.compile(optimizer, loss = 'categorical_crossentropy', metrics=['accuracy',top5_acc,macro_f1score])

# %%
######## flow_from_directory
history = model.fit(train_generator, steps_per_epoch=int(len(x_train)/batch_sizes),  validation_data = valid_generator, epochs=epochs, verbose=1 , callbacks = callbacks_list , validation_steps=int(len(x_valid)/batch_sizes))
# Out:
# Learning rate:  0.001
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 1/70
# 0.0(L1), 3.615507621182657e-08(L2) weight decay set for block1_conv1/kernel:0
# 0.0(L1), 3.615507621182657e-08(L2) weight decay set for block1_conv2/kernel:0
# 0.0(L1), 3.615507621182657e-08(L2) weight decay set for dense/kernel:0
# 0.0(L1), 3.615507621182657e-08(L2) weight decay set for dense_1/kernel:0
# 0.0(L1), 3.615507621182657e-08(L2) weight decay set for conv2d/kernel:0
# 0.0(L1), 3.615507621182657e-08(L2) weight decay set for dense_2/kernel:0
# 0.0(L1), 3.615507621182657e-08(L2) weight decay set for dense_3/kernel:0
# 0.0(L1), 3.615507621182657e-08(L2) weight decay set for conv2d_1/kernel:0
# 0.0(L1), 3.615507621182657e-08(L2) weight decay set for dense_4/kernel:0
# 0.0(L1), 3.615507621182657e-08(L2) weight decay set for dense_5/kernel:0
# 0.0(L1), 3.615507621182657e-08(L2) weight decay set for conv2d_2/kernel:0
# 0.0(L1), 3.615507621182657e-08(L2) weight decay set for dense_6/kernel:0
# 0.0(L1), 3.615507621182657e-08(L2) weight decay set for dense_7/kernel:0
# 0.0(L1), 3.615507621182657e-08(L2) weight decay set for dense_8/kernel:0
# 0.0(L1), 3.615507621182657e-08(L2) weight decay set for dense_9/kernel:0
# 0.0(L1), 3.615507621182657e-08(L2) weight decay set for dense_10/kernel:0
# 0.0(L1), 3.615507621182657e-08(L2) weight decay set for dense_11/kernel:0
# 0.0(L1), 3.615507621182657e-08(L2) weight decay set for dense_12/kernel:0
# 0.0(L1), 3.615507621182657e-08(L2) weight decay set for dense_13/kernel:0
# 0.0(L1), 3.615507621182657e-08(L2) weight decay set for dense_14/kernel:0
# 0.0(L1), 3.615507621182657e-08(L2) weight decay set for dense_15/kernel:0
# 0.0(L1), 3.615507621182657e-08(L2) weight decay set for dense_16/kernel:0
# 0.0(L1), 3.615507621182657e-08(L2) weight decay set for dense_17/kernel:0
# 0.0(L1), 3.615507621182657e-08(L2) weight decay set for dense_18/kernel:0
# 0.0(L1), 3.615507621182657e-08(L2) weight decay set for dense_19/kernel:0
# 0.0(L1), 3.615507621182657e-08(L2) weight decay set for dense_20/kernel:0
# 0.0(L1), 3.615507621182657e-08(L2) weight decay set for dense_21/kernel:0
# 0.0(L1), 3.615507621182657e-08(L2) weight decay set for dense_22/kernel:0
# 0.0(L1), 3.615507621182657e-08(L2) weight decay set for dense_23/kernel:0
# 0.0(L1), 3.615507621182657e-08(L2) weight decay set for conv2d_3/kernel:0
# 0.0(L1), 3.615507621182657e-08(L2) weight decay set for predictions/kernel:0
# 765/765 [==============================] - ETA: 0s - loss: 5.2130 - accuracy: 0.0701 - top5_acc: 0.1623 - macro_f1score: 5.6204e-04
# Epoch 00001: val_loss improved from inf to 4.78234, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/SE_Xception/001.h5
#
# Epoch 00001: val_accuracy improved from -inf to 0.09879, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/SE_Xception/001.h5
# 765/765 [==============================] - 7057s 9s/step - loss: 5.2130 - accuracy: 0.0701 - top5_acc: 0.1623 - macro_f1score: 5.6204e-04 - val_loss: 4.7823 - val_accuracy: 0.0988 - val_top5_acc: 0.2214 - val_macro_f1score: 0.0023
# Learning rate:  0.001
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 2/70
# 765/765 [==============================] - ETA: 0s - loss: 4.6123 - accuracy: 0.1219 - top5_acc: 0.2491 - macro_f1score: 0.0030
# Epoch 00002: val_loss improved from 4.78234 to 4.48177, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/SE_Xception/002.h5
#
# Epoch 00002: val_accuracy improved from 0.09879 to 0.14315, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/SE_Xception/002.h5
# 765/765 [==============================] - 647s 845ms/step - loss: 4.6123 - accuracy: 0.1219 - top5_acc: 0.2491 - macro_f1score: 0.0030 - val_loss: 4.4818 - val_accuracy: 0.1431 - val_top5_acc: 0.2876 - val_macro_f1score: 0.0055
# Learning rate:  0.001
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 3/70
# 765/765 [==============================] - ETA: 0s - loss: 4.1966 - accuracy: 0.1714 - top5_acc: 0.3290 - macro_f1score: 0.0060
# Epoch 00003: val_loss improved from 4.48177 to 4.15761, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/SE_Xception/003.h5
#
# Epoch 00003: val_accuracy improved from 0.14315 to 0.17977, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/SE_Xception/003.h5
# 765/765 [==============================] - 642s 840ms/step - loss: 4.1966 - accuracy: 0.1714 - top5_acc: 0.3290 - macro_f1score: 0.0060 - val_loss: 4.1576 - val_accuracy: 0.1798 - val_top5_acc: 0.3495 - val_macro_f1score: 0.0074
# Learning rate:  0.001
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 4/70
# 765/765 [==============================] - ETA: 0s - loss: 3.8760 - accuracy: 0.2158 - top5_acc: 0.3984 - macro_f1score: 0.0084
# Epoch 00004: val_loss improved from 4.15761 to 3.81349, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/SE_Xception/004.h5
#
# Epoch 00004: val_accuracy improved from 0.17977 to 0.23992, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/SE_Xception/004.h5
# 765/765 [==============================] - 640s 836ms/step - loss: 3.8760 - accuracy: 0.2158 - top5_acc: 0.3984 - macro_f1score: 0.0084 - val_loss: 3.8135 - val_accuracy: 0.2399 - val_top5_acc: 0.4157 - val_macro_f1score: 0.0101
# Learning rate:  0.001
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 5/70
# 765/765 [==============================] - ETA: 0s - loss: 3.5709 - accuracy: 0.2561 - top5_acc: 0.4623 - macro_f1score: 0.0114
# Epoch 00005: val_loss improved from 3.81349 to 3.68570, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/SE_Xception/005.h5
#
# Epoch 00005: val_accuracy improved from 0.23992 to 0.26915, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/SE_Xception/005.h5
# 765/765 [==============================] - 630s 824ms/step - loss: 3.5709 - accuracy: 0.2561 - top5_acc: 0.4623 - macro_f1score: 0.0114 - val_loss: 3.6857 - val_accuracy: 0.2692 - val_top5_acc: 0.4580 - val_macro_f1score: 0.0153
# Learning rate:  0.001
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 6/70
# 765/765 [==============================] - ETA: 0s - loss: 3.2603 - accuracy: 0.3028 - top5_acc: 0.5265 - macro_f1score: 0.0155
# Epoch 00006: val_loss improved from 3.68570 to 3.33233, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/SE_Xception/006.h5
#
# Epoch 00006: val_accuracy improved from 0.26915 to 0.31048, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/SE_Xception/006.h5
# 765/765 [==============================] - 623s 815ms/step - loss: 3.2603 - accuracy: 0.3028 - top5_acc: 0.5265 - macro_f1score: 0.0155 - val_loss: 3.3323 - val_accuracy: 0.3105 - val_top5_acc: 0.5282 - val_macro_f1score: 0.0187
# Learning rate:  0.001
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 7/70
# 765/765 [==============================] - ETA: 0s - loss: 2.9602 - accuracy: 0.3562 - top5_acc: 0.5915 - macro_f1score: 0.0201
# Epoch 00007: val_loss improved from 3.33233 to 3.20832, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/SE_Xception/007.h5
#
# Epoch 00007: val_accuracy improved from 0.31048 to 0.32661, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/SE_Xception/007.h5
# 765/765 [==============================] - 622s 813ms/step - loss: 2.9602 - accuracy: 0.3562 - top5_acc: 0.5915 - macro_f1score: 0.0201 - val_loss: 3.2083 - val_accuracy: 0.3266 - val_top5_acc: 0.5591 - val_macro_f1score: 0.0221
# Learning rate:  0.001
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 8/70
# 765/765 [==============================] - ETA: 0s - loss: 2.7016 - accuracy: 0.4027 - top5_acc: 0.6388 - macro_f1score: 0.0252
# Epoch 00008: val_loss improved from 3.20832 to 3.08836, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/SE_Xception/008.h5
#
# Epoch 00008: val_accuracy improved from 0.32661 to 0.34409, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/SE_Xception/008.h5
# 765/765 [==============================] - 619s 810ms/step - loss: 2.7016 - accuracy: 0.4027 - top5_acc: 0.6388 - macro_f1score: 0.0252 - val_loss: 3.0884 - val_accuracy: 0.3441 - val_top5_acc: 0.5927 - val_macro_f1score: 0.0245
# Learning rate:  0.001
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 9/70
# 765/765 [==============================] - ETA: 0s - loss: 2.4427 - accuracy: 0.4481 - top5_acc: 0.6897 - macro_f1score: 0.0314
# Epoch 00009: val_loss improved from 3.08836 to 2.93215, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/SE_Xception/009.h5
#
# Epoch 00009: val_accuracy improved from 0.34409 to 0.38038, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/SE_Xception/009.h5
# 765/765 [==============================] - 624s 815ms/step - loss: 2.4427 - accuracy: 0.4481 - top5_acc: 0.6897 - macro_f1score: 0.0314 - val_loss: 2.9321 - val_accuracy: 0.3804 - val_top5_acc: 0.6163 - val_macro_f1score: 0.0285
# Learning rate:  0.001
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 10/70
# 765/765 [==============================] - ETA: 0s - loss: 2.2521 - accuracy: 0.4872 - top5_acc: 0.7231 - macro_f1score: 0.0363
# Epoch 00010: val_loss did not improve from 2.93215
#
# Epoch 00010: val_accuracy did not improve from 0.38038
# 765/765 [==============================] - 620s 811ms/step - loss: 2.2521 - accuracy: 0.4872 - top5_acc: 0.7231 - macro_f1score: 0.0363 - val_loss: 3.2279 - val_accuracy: 0.3417 - val_top5_acc: 0.5675 - val_macro_f1score: 0.0236
# Learning rate:  0.001
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 11/70
# 765/765 [==============================] - ETA: 0s - loss: 2.0636 - accuracy: 0.5228 - top5_acc: 0.7594 - macro_f1score: 0.0412
# Epoch 00011: val_loss improved from 2.93215 to 2.46800, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/SE_Xception/011.h5
#
# Epoch 00011: val_accuracy improved from 0.38038 to 0.47043, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/SE_Xception/011.h5
# 765/765 [==============================] - 647s 845ms/step - loss: 2.0636 - accuracy: 0.5228 - top5_acc: 0.7594 - macro_f1score: 0.0412 - val_loss: 2.4680 - val_accuracy: 0.4704 - val_top5_acc: 0.6851 - val_macro_f1score: 0.0394
# Learning rate:  0.001
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 12/70
# 765/765 [==============================] - ETA: 0s - loss: 1.8987 - accuracy: 0.5534 - top5_acc: 0.7885 - macro_f1score: 0.0460
# Epoch 00012: val_loss did not improve from 2.46800
#
# Epoch 00012: val_accuracy improved from 0.47043 to 0.47849, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/SE_Xception/012.h5
# 765/765 [==============================] - 685s 896ms/step - loss: 1.8987 - accuracy: 0.5534 - top5_acc: 0.7885 - macro_f1score: 0.0460 - val_loss: 2.5111 - val_accuracy: 0.4785 - val_top5_acc: 0.6875 - val_macro_f1score: 0.0401
# Learning rate:  0.001
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 13/70
# 765/765 [==============================] - ETA: 0s - loss: 1.7470 - accuracy: 0.5841 - top5_acc: 0.8122 - macro_f1score: 0.0502
# Epoch 00013: val_loss improved from 2.46800 to 2.46529, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/SE_Xception/013.h5
#
# Epoch 00013: val_accuracy improved from 0.47849 to 0.49496, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/SE_Xception/013.h5
# 765/765 [==============================] - 693s 905ms/step - loss: 1.7470 - accuracy: 0.5841 - top5_acc: 0.8122 - macro_f1score: 0.0502 - val_loss: 2.4653 - val_accuracy: 0.4950 - val_top5_acc: 0.7130 - val_macro_f1score: 0.0452
# Learning rate:  0.001
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 14/70
# 765/765 [==============================] - ETA: 0s - loss: 1.6196 - accuracy: 0.6149 - top5_acc: 0.8337 - macro_f1score: 0.0548
# Epoch 00014: val_loss improved from 2.46529 to 2.31408, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/SE_Xception/014.h5
#
# Epoch 00014: val_accuracy improved from 0.49496 to 0.51747, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/SE_Xception/014.h5
# 765/765 [==============================] - 682s 892ms/step - loss: 1.6196 - accuracy: 0.6149 - top5_acc: 0.8337 - macro_f1score: 0.0548 - val_loss: 2.3141 - val_accuracy: 0.5175 - val_top5_acc: 0.7255 - val_macro_f1score: 0.0455
# Learning rate:  0.001
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 15/70
# 765/765 [==============================] - ETA: 0s - loss: 1.5017 - accuracy: 0.6382 - top5_acc: 0.8549 - macro_f1score: 0.0582
# Epoch 00015: val_loss did not improve from 2.31408
#
# Epoch 00015: val_accuracy did not improve from 0.51747
# 765/765 [==============================] - 689s 900ms/step - loss: 1.5017 - accuracy: 0.6382 - top5_acc: 0.8549 - macro_f1score: 0.0582 - val_loss: 2.3162 - val_accuracy: 0.5124 - val_top5_acc: 0.7322 - val_macro_f1score: 0.0460
# Learning rate:  0.001
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 16/70
# 765/765 [==============================] - ETA: 0s - loss: 1.3772 - accuracy: 0.6675 - top5_acc: 0.8717 - macro_f1score: 0.0627
# Epoch 00016: val_loss did not improve from 2.31408
#
# Epoch 00016: val_accuracy did not improve from 0.51747
# 765/765 [==============================] - 680s 889ms/step - loss: 1.3772 - accuracy: 0.6675 - top5_acc: 0.8717 - macro_f1score: 0.0627 - val_loss: 2.4390 - val_accuracy: 0.5141 - val_top5_acc: 0.7188 - val_macro_f1score: 0.0477
# Learning rate:  0.001
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 17/70
# 765/765 [==============================] - ETA: 0s - loss: 1.2582 - accuracy: 0.6941 - top5_acc: 0.8916 - macro_f1score: 0.0663
# Epoch 00017: val_loss improved from 2.31408 to 2.20678, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/SE_Xception/017.h5
#
# Epoch 00017: val_accuracy improved from 0.51747 to 0.54603, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/SE_Xception/017.h5
# 765/765 [==============================] - 691s 904ms/step - loss: 1.2582 - accuracy: 0.6941 - top5_acc: 0.8916 - macro_f1score: 0.0663 - val_loss: 2.2068 - val_accuracy: 0.5460 - val_top5_acc: 0.7456 - val_macro_f1score: 0.0501
# Learning rate:  0.001
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 18/70
# 765/765 [==============================] - ETA: 0s - loss: 1.1765 - accuracy: 0.7121 - top5_acc: 0.9031 - macro_f1score: 0.0692
# Epoch 00018: val_loss did not improve from 2.20678
#
# Epoch 00018: val_accuracy did not improve from 0.54603
# 765/765 [==============================] - 678s 886ms/step - loss: 1.1765 - accuracy: 0.7121 - top5_acc: 0.9031 - macro_f1score: 0.0692 - val_loss: 2.3025 - val_accuracy: 0.5336 - val_top5_acc: 0.7406 - val_macro_f1score: 0.0511
# Learning rate:  0.001
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 19/70
# 765/765 [==============================] - ETA: 0s - loss: 1.0801 - accuracy: 0.7326 - top5_acc: 0.9156 - macro_f1score: 0.0726
# Epoch 00019: val_loss did not improve from 2.20678
#
# Epoch 00019: val_accuracy did not improve from 0.54603
# 765/765 [==============================] - 684s 894ms/step - loss: 1.0801 - accuracy: 0.7326 - top5_acc: 0.9156 - macro_f1score: 0.0726 - val_loss: 2.3191 - val_accuracy: 0.5430 - val_top5_acc: 0.7500 - val_macro_f1score: 0.0521
# Learning rate:  0.001
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 20/70
# 765/765 [==============================] - ETA: 0s - loss: 0.9938 - accuracy: 0.7532 - top5_acc: 0.9287 - macro_f1score: 0.0763
# Epoch 00020: val_loss did not improve from 2.20678
#
# Epoch 00020: val_accuracy improved from 0.54603 to 0.54906, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/SE_Xception/020.h5
# 765/765 [==============================] - 684s 895ms/step - loss: 0.9938 - accuracy: 0.7532 - top5_acc: 0.9287 - macro_f1score: 0.0763 - val_loss: 2.3918 - val_accuracy: 0.5491 - val_top5_acc: 0.7456 - val_macro_f1score: 0.0543
# Learning rate:  0.001
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 21/70
# 765/765 [==============================] - ETA: 0s - loss: 0.9206 - accuracy: 0.7739 - top5_acc: 0.9400 - macro_f1score: 0.0786
# Epoch 00021: val_loss did not improve from 2.20678
#
# Epoch 00021: val_accuracy did not improve from 0.54906
# 765/765 [==============================] - 650s 850ms/step - loss: 0.9206 - accuracy: 0.7739 - top5_acc: 0.9400 - macro_f1score: 0.0786 - val_loss: 2.4377 - val_accuracy: 0.5464 - val_top5_acc: 0.7443 - val_macro_f1score: 0.0529
# Learning rate:  0.001
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 22/70
# 765/765 [==============================] - ETA: 0s - loss: 0.8438 - accuracy: 0.7926 - top5_acc: 0.9497 - macro_f1score: 0.0817
# Epoch 00022: val_loss did not improve from 2.20678
#
# Epoch 00022: val_accuracy did not improve from 0.54906
# 765/765 [==============================] - 672s 878ms/step - loss: 0.8438 - accuracy: 0.7926 - top5_acc: 0.9497 - macro_f1score: 0.0817 - val_loss: 2.4933 - val_accuracy: 0.5316 - val_top5_acc: 0.7376 - val_macro_f1score: 0.0537
# Learning rate:  0.001
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 23/70
# 765/765 [==============================] - ETA: 0s - loss: 0.7868 - accuracy: 0.8055 - top5_acc: 0.9573 - macro_f1score: 0.0841
# Epoch 00023: val_loss did not improve from 2.20678
#
# Epoch 00023: val_accuracy did not improve from 0.54906
# 765/765 [==============================] - 672s 879ms/step - loss: 0.7868 - accuracy: 0.8055 - top5_acc: 0.9573 - macro_f1score: 0.0841 - val_loss: 2.5247 - val_accuracy: 0.5464 - val_top5_acc: 0.7396 - val_macro_f1score: 0.0559
# Learning rate:  0.001
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 24/70
# 765/765 [==============================] - ETA: 0s - loss: 0.7391 - accuracy: 0.8186 - top5_acc: 0.9639 - macro_f1score: 0.0857
# Epoch 00024: val_loss did not improve from 2.20678
#
# Epoch 00024: val_accuracy did not improve from 0.54906
# 765/765 [==============================] - 665s 869ms/step - loss: 0.7391 - accuracy: 0.8186 - top5_acc: 0.9639 - macro_f1score: 0.0857 - val_loss: 2.6008 - val_accuracy: 0.5403 - val_top5_acc: 0.7463 - val_macro_f1score: 0.0545
# Learning rate:  0.001
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 25/70
# 765/765 [==============================] - ETA: 0s - loss: 0.6686 - accuracy: 0.8378 - top5_acc: 0.9708 - macro_f1score: 0.0889
# Epoch 00025: val_loss did not improve from 2.20678
#
# Epoch 00025: val_accuracy improved from 0.54906 to 0.57695, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/SE_Xception/025.h5
# 765/765 [==============================] - 663s 867ms/step - loss: 0.6686 - accuracy: 0.8378 - top5_acc: 0.9708 - macro_f1score: 0.0889 - val_loss: 2.3580 - val_accuracy: 0.5769 - val_top5_acc: 0.7728 - val_macro_f1score: 0.0596
# Learning rate:  0.001
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 26/70
# 765/765 [==============================] - ETA: 0s - loss: 0.6385 - accuracy: 0.8476 - top5_acc: 0.9741 - macro_f1score: 0.0907
# Epoch 00026: val_loss did not improve from 2.20678
#
# Epoch 00026: val_accuracy did not improve from 0.57695
# 765/765 [==============================] - 647s 845ms/step - loss: 0.6385 - accuracy: 0.8476 - top5_acc: 0.9741 - macro_f1score: 0.0907 - val_loss: 2.4621 - val_accuracy: 0.5615 - val_top5_acc: 0.7587 - val_macro_f1score: 0.0590
# Learning rate:  0.001
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 27/70
# 765/765 [==============================] - ETA: 0s - loss: 0.6055 - accuracy: 0.8573 - top5_acc: 0.9790 - macro_f1score: 0.0916
# Epoch 00027: val_loss did not improve from 2.20678
#
# Epoch 00027: val_accuracy did not improve from 0.57695
# 765/765 [==============================] - 618s 808ms/step - loss: 0.6055 - accuracy: 0.8573 - top5_acc: 0.9790 - macro_f1score: 0.0916 - val_loss: 2.6076 - val_accuracy: 0.5608 - val_top5_acc: 0.7618 - val_macro_f1score: 0.0586
# Learning rate:  0.001
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 28/70
# 765/765 [==============================] - ETA: 0s - loss: 0.5704 - accuracy: 0.8657 - top5_acc: 0.9813 - macro_f1score: 0.0934
# Epoch 00028: val_loss did not improve from 2.20678
#
# Epoch 00028: val_accuracy did not improve from 0.57695
# 765/765 [==============================] - 613s 802ms/step - loss: 0.5704 - accuracy: 0.8657 - top5_acc: 0.9813 - macro_f1score: 0.0934 - val_loss: 2.4958 - val_accuracy: 0.5571 - val_top5_acc: 0.7658 - val_macro_f1score: 0.0583
# Learning rate:  0.001
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 29/70
# 765/765 [==============================] - ETA: 0s - loss: 0.5447 - accuracy: 0.8754 - top5_acc: 0.9838 - macro_f1score: 0.0953
# Epoch 00029: val_loss did not improve from 2.20678
#
# Epoch 00029: val_accuracy improved from 0.57695 to 0.58031, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/SE_Xception/029.h5
# 765/765 [==============================] - 613s 802ms/step - loss: 0.5447 - accuracy: 0.8754 - top5_acc: 0.9838 - macro_f1score: 0.0953 - val_loss: 2.4715 - val_accuracy: 0.5803 - val_top5_acc: 0.7718 - val_macro_f1score: 0.0602
# Learning rate:  0.001
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 30/70
# 765/765 [==============================] - ETA: 0s - loss: 0.5073 - accuracy: 0.8851 - top5_acc: 0.9861 - macro_f1score: 0.0966
# Epoch 00030: val_loss did not improve from 2.20678
#
# Epoch 00030: val_accuracy did not improve from 0.58031
# 765/765 [==============================] - 612s 800ms/step - loss: 0.5073 - accuracy: 0.8851 - top5_acc: 0.9861 - macro_f1score: 0.0966 - val_loss: 2.5238 - val_accuracy: 0.5659 - val_top5_acc: 0.7631 - val_macro_f1score: 0.0590
# Learning rate:  0.0001
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 31/70
# 765/765 [==============================] - ETA: 0s - loss: 0.3498 - accuracy: 0.9371 - top5_acc: 0.9950 - macro_f1score: 0.1037
# Epoch 00031: val_loss improved from 2.20678 to 2.15728, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/SE_Xception/031.h5
#
# Epoch 00031: val_accuracy improved from 0.58031 to 0.61526, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/SE_Xception/031.h5
# 765/765 [==============================] - 612s 801ms/step - loss: 0.3498 - accuracy: 0.9371 - top5_acc: 0.9950 - macro_f1score: 0.1037 - val_loss: 2.1573 - val_accuracy: 0.6153 - val_top5_acc: 0.7997 - val_macro_f1score: 0.0650
# Learning rate:  0.0001
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 32/70
# 765/765 [==============================] - ETA: 0s - loss: 0.2878 - accuracy: 0.9564 - top5_acc: 0.9969 - macro_f1score: 0.1072
# Epoch 00032: val_loss improved from 2.15728 to 2.15017, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/SE_Xception/032.h5
#
# Epoch 00032: val_accuracy improved from 0.61526 to 0.62399, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/SE_Xception/032.h5
# 765/765 [==============================] - 614s 802ms/step - loss: 0.2878 - accuracy: 0.9564 - top5_acc: 0.9969 - macro_f1score: 0.1072 - val_loss: 2.1502 - val_accuracy: 0.6240 - val_top5_acc: 0.7974 - val_macro_f1score: 0.0665
# Learning rate:  0.0001
#
# Epoch 00033: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 33/70
# 765/765 [==============================] - ETA: 0s - loss: 0.2589 - accuracy: 0.9651 - top5_acc: 0.9981 - macro_f1score: 0.1083
# Epoch 00033: val_loss did not improve from 2.15017
#
# Epoch 00033: val_accuracy did not improve from 0.62399
# 765/765 [==============================] - 612s 800ms/step - loss: 0.2589 - accuracy: 0.9651 - top5_acc: 0.9981 - macro_f1score: 0.1083 - val_loss: 2.1756 - val_accuracy: 0.6230 - val_top5_acc: 0.8004 - val_macro_f1score: 0.0663
# Learning rate:  0.0001
#
# Epoch 00034: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 34/70
# 765/765 [==============================] - ETA: 0s - loss: 0.2445 - accuracy: 0.9678 - top5_acc: 0.9984 - macro_f1score: 0.1091
# Epoch 00034: val_loss did not improve from 2.15017
#
# Epoch 00034: val_accuracy improved from 0.62399 to 0.62634, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/SE_Xception/034.h5
# 765/765 [==============================] - 644s 842ms/step - loss: 0.2445 - accuracy: 0.9678 - top5_acc: 0.9984 - macro_f1score: 0.1091 - val_loss: 2.1635 - val_accuracy: 0.6263 - val_top5_acc: 0.8031 - val_macro_f1score: 0.0670
# Learning rate:  0.0001
#
# Epoch 00035: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 35/70
# 765/765 [==============================] - ETA: 0s - loss: 0.2325 - accuracy: 0.9717 - top5_acc: 0.9987 - macro_f1score: 0.1098
# Epoch 00035: val_loss did not improve from 2.15017
#
# Epoch 00035: val_accuracy did not improve from 0.62634
# 765/765 [==============================] - 638s 834ms/step - loss: 0.2325 - accuracy: 0.9717 - top5_acc: 0.9987 - macro_f1score: 0.1098 - val_loss: 2.1760 - val_accuracy: 0.6247 - val_top5_acc: 0.8011 - val_macro_f1score: 0.0659
# Learning rate:  0.0001
#
# Epoch 00036: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 36/70
# 765/765 [==============================] - ETA: 0s - loss: 0.2218 - accuracy: 0.9752 - top5_acc: 0.9985 - macro_f1score: 0.1107
# Epoch 00036: val_loss did not improve from 2.15017
#
# Epoch 00036: val_accuracy improved from 0.62634 to 0.62702, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/SE_Xception/036.h5
# 765/765 [==============================] - 628s 821ms/step - loss: 0.2218 - accuracy: 0.9752 - top5_acc: 0.9985 - macro_f1score: 0.1107 - val_loss: 2.1957 - val_accuracy: 0.6270 - val_top5_acc: 0.8024 - val_macro_f1score: 0.0665
# Learning rate:  0.0001
#
# Epoch 00037: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 37/70
# 765/765 [==============================] - ETA: 0s - loss: 0.2167 - accuracy: 0.9752 - top5_acc: 0.9990 - macro_f1score: 0.1104
# Epoch 00037: val_loss did not improve from 2.15017
#
# Epoch 00037: val_accuracy did not improve from 0.62702
# 765/765 [==============================] - 627s 820ms/step - loss: 0.2167 - accuracy: 0.9752 - top5_acc: 0.9990 - macro_f1score: 0.1104 - val_loss: 2.2004 - val_accuracy: 0.6270 - val_top5_acc: 0.8014 - val_macro_f1score: 0.0674
# Learning rate:  0.0001
#
# Epoch 00038: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 38/70
# 765/765 [==============================] - ETA: 0s - loss: 0.2094 - accuracy: 0.9768 - top5_acc: 0.9991 - macro_f1score: 0.1109
# Epoch 00038: val_loss did not improve from 2.15017
#
# Epoch 00038: val_accuracy improved from 0.62702 to 0.63172, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/SE_Xception/038.h5
# 765/765 [==============================] - 624s 816ms/step - loss: 0.2094 - accuracy: 0.9768 - top5_acc: 0.9991 - macro_f1score: 0.1109 - val_loss: 2.2030 - val_accuracy: 0.6317 - val_top5_acc: 0.8024 - val_macro_f1score: 0.0678
# Learning rate:  0.0001
#
# Epoch 00039: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 39/70
# 765/765 [==============================] - ETA: 0s - loss: 0.2030 - accuracy: 0.9796 - top5_acc: 0.9994 - macro_f1score: 0.1111
# Epoch 00039: val_loss did not improve from 2.15017
#
# Epoch 00039: val_accuracy did not improve from 0.63172
# 765/765 [==============================] - 644s 842ms/step - loss: 0.2030 - accuracy: 0.9796 - top5_acc: 0.9994 - macro_f1score: 0.1111 - val_loss: 2.1846 - val_accuracy: 0.6263 - val_top5_acc: 0.8017 - val_macro_f1score: 0.0668
# Learning rate:  0.0001
#
# Epoch 00040: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 40/70
# 765/765 [==============================] - ETA: 0s - loss: 0.1945 - accuracy: 0.9820 - top5_acc: 0.9992 - macro_f1score: 0.1117
# Epoch 00040: val_loss did not improve from 2.15017
#
# Epoch 00040: val_accuracy did not improve from 0.63172
# 765/765 [==============================] - 683s 893ms/step - loss: 0.1945 - accuracy: 0.9820 - top5_acc: 0.9992 - macro_f1score: 0.1117 - val_loss: 2.2140 - val_accuracy: 0.6310 - val_top5_acc: 0.8038 - val_macro_f1score: 0.0673
# Learning rate:  0.0001
#
# Epoch 00041: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 41/70
# 765/765 [==============================] - ETA: 0s - loss: 0.1878 - accuracy: 0.9831 - top5_acc: 0.9997 - macro_f1score: 0.1115
# Epoch 00041: val_loss did not improve from 2.15017
#
# Epoch 00041: val_accuracy did not improve from 0.63172
# 765/765 [==============================] - 666s 870ms/step - loss: 0.1878 - accuracy: 0.9831 - top5_acc: 0.9997 - macro_f1score: 0.1115 - val_loss: 2.2187 - val_accuracy: 0.6237 - val_top5_acc: 0.8044 - val_macro_f1score: 0.0670
# Learning rate:  0.0001
#
# Epoch 00042: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 42/70
# 765/765 [==============================] - ETA: 0s - loss: 0.1868 - accuracy: 0.9824 - top5_acc: 0.9998 - macro_f1score: 0.1113
# Epoch 00042: val_loss did not improve from 2.15017
#
# Epoch 00042: val_accuracy did not improve from 0.63172
# 765/765 [==============================] - 667s 872ms/step - loss: 0.1868 - accuracy: 0.9824 - top5_acc: 0.9998 - macro_f1score: 0.1113 - val_loss: 2.2452 - val_accuracy: 0.6270 - val_top5_acc: 0.7974 - val_macro_f1score: 0.0670
# Learning rate:  0.0001
#
# Epoch 00043: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 43/70
# 765/765 [==============================] - ETA: 0s - loss: 0.1846 - accuracy: 0.9839 - top5_acc: 0.9996 - macro_f1score: 0.1119
# Epoch 00043: val_loss did not improve from 2.15017
#
# Epoch 00043: val_accuracy did not improve from 0.63172
# 765/765 [==============================] - 666s 870ms/step - loss: 0.1846 - accuracy: 0.9839 - top5_acc: 0.9996 - macro_f1score: 0.1119 - val_loss: 2.2570 - val_accuracy: 0.6300 - val_top5_acc: 0.8004 - val_macro_f1score: 0.0688
# Learning rate:  0.0001
#
# Epoch 00044: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 44/70
# 765/765 [==============================] - ETA: 0s - loss: 0.1816 - accuracy: 0.9841 - top5_acc: 0.9997 - macro_f1score: 0.1117
# Epoch 00044: val_loss did not improve from 2.15017
#
# Epoch 00044: val_accuracy did not improve from 0.63172
# 765/765 [==============================] - 662s 866ms/step - loss: 0.1816 - accuracy: 0.9841 - top5_acc: 0.9997 - macro_f1score: 0.1117 - val_loss: 2.2704 - val_accuracy: 0.6237 - val_top5_acc: 0.7991 - val_macro_f1score: 0.0682
# Learning rate:  0.0001
#
# Epoch 00045: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 45/70
# 765/765 [==============================] - ETA: 0s - loss: 0.1805 - accuracy: 0.9840 - top5_acc: 0.9995 - macro_f1score: 0.1123
# Epoch 00045: val_loss did not improve from 2.15017
#
# Epoch 00045: val_accuracy did not improve from 0.63172
# 765/765 [==============================] - 656s 857ms/step - loss: 0.1805 - accuracy: 0.9840 - top5_acc: 0.9995 - macro_f1score: 0.1123 - val_loss: 2.2685 - val_accuracy: 0.6226 - val_top5_acc: 0.8017 - val_macro_f1score: 0.0675
# Learning rate:  0.0001
#
# Epoch 00046: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 46/70
# 765/765 [==============================] - ETA: 0s - loss: 0.1747 - accuracy: 0.9867 - top5_acc: 0.9997 - macro_f1score: 0.1126
# Epoch 00046: val_loss did not improve from 2.15017
#
# Epoch 00046: val_accuracy did not improve from 0.63172
# 765/765 [==============================] - 656s 857ms/step - loss: 0.1747 - accuracy: 0.9867 - top5_acc: 0.9997 - macro_f1score: 0.1126 - val_loss: 2.2733 - val_accuracy: 0.6304 - val_top5_acc: 0.8041 - val_macro_f1score: 0.0686
# Learning rate:  0.0001
#
# Epoch 00047: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 47/70
# 765/765 [==============================] - ETA: 0s - loss: 0.1715 - accuracy: 0.9870 - top5_acc: 0.9998 - macro_f1score: 0.1123
# Epoch 00047: val_loss did not improve from 2.15017
#
# Epoch 00047: val_accuracy did not improve from 0.63172
# 765/765 [==============================] - 657s 859ms/step - loss: 0.1715 - accuracy: 0.9870 - top5_acc: 0.9998 - macro_f1score: 0.1123 - val_loss: 2.2489 - val_accuracy: 0.6310 - val_top5_acc: 0.8061 - val_macro_f1score: 0.0682
# Learning rate:  0.0001
#
# Epoch 00048: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 48/70
# 765/765 [==============================] - ETA: 0s - loss: 0.1680 - accuracy: 0.9873 - top5_acc: 0.9999 - macro_f1score: 0.1122
# Epoch 00048: val_loss did not improve from 2.15017
#
# Epoch 00048: val_accuracy improved from 0.63172 to 0.63374, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/SE_Xception/048.h5
# 765/765 [==============================] - 663s 866ms/step - loss: 0.1680 - accuracy: 0.9873 - top5_acc: 0.9999 - macro_f1score: 0.1122 - val_loss: 2.2605 - val_accuracy: 0.6337 - val_top5_acc: 0.8031 - val_macro_f1score: 0.0678
# Learning rate:  0.0001
#
# Epoch 00049: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 49/70
# 765/765 [==============================] - ETA: 0s - loss: 0.1654 - accuracy: 0.9876 - top5_acc: 0.9998 - macro_f1score: 0.1127
# Epoch 00049: val_loss did not improve from 2.15017
#
# Epoch 00049: val_accuracy did not improve from 0.63374
# 765/765 [==============================] - 665s 869ms/step - loss: 0.1654 - accuracy: 0.9876 - top5_acc: 0.9998 - macro_f1score: 0.1127 - val_loss: 2.3136 - val_accuracy: 0.6280 - val_top5_acc: 0.8048 - val_macro_f1score: 0.0676
# Learning rate:  0.0001
#
# Epoch 00050: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 50/70
# 765/765 [==============================] - ETA: 0s - loss: 0.1631 - accuracy: 0.9880 - top5_acc: 0.9998 - macro_f1score: 0.1125
# Epoch 00050: val_loss did not improve from 2.15017
#
# Epoch 00050: val_accuracy did not improve from 0.63374
# 765/765 [==============================] - 651s 850ms/step - loss: 0.1631 - accuracy: 0.9880 - top5_acc: 0.9998 - macro_f1score: 0.1125 - val_loss: 2.2931 - val_accuracy: 0.6263 - val_top5_acc: 0.8041 - val_macro_f1score: 0.0678
# Learning rate:  0.0001
#
# Epoch 00051: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 51/70
# 765/765 [==============================] - ETA: 0s - loss: 0.1651 - accuracy: 0.9869 - top5_acc: 0.9998 - macro_f1score: 0.1124
# Epoch 00051: val_loss did not improve from 2.15017
#
# Epoch 00051: val_accuracy did not improve from 0.63374
# 765/765 [==============================] - 612s 800ms/step - loss: 0.1651 - accuracy: 0.9869 - top5_acc: 0.9998 - macro_f1score: 0.1124 - val_loss: 2.2855 - val_accuracy: 0.6274 - val_top5_acc: 0.8058 - val_macro_f1score: 0.0685
# Learning rate:  0.0001
#
# Epoch 00052: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 52/70
# 765/765 [==============================] - ETA: 0s - loss: 0.1599 - accuracy: 0.9888 - top5_acc: 1.0000 - macro_f1score: 0.1124
# Epoch 00052: val_loss did not improve from 2.15017
#
# Epoch 00052: val_accuracy did not improve from 0.63374
# 765/765 [==============================] - 609s 796ms/step - loss: 0.1599 - accuracy: 0.9888 - top5_acc: 1.0000 - macro_f1score: 0.1124 - val_loss: 2.3345 - val_accuracy: 0.6321 - val_top5_acc: 0.8088 - val_macro_f1score: 0.0674
# Learning rate:  0.0001
#
# Epoch 00053: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 53/70
# 765/765 [==============================] - ETA: 0s - loss: 0.1580 - accuracy: 0.9897 - top5_acc: 0.9998 - macro_f1score: 0.1126
# Epoch 00053: val_loss did not improve from 2.15017
#
# Epoch 00053: val_accuracy did not improve from 0.63374
# 765/765 [==============================] - 610s 798ms/step - loss: 0.1580 - accuracy: 0.9897 - top5_acc: 0.9998 - macro_f1score: 0.1126 - val_loss: 2.2906 - val_accuracy: 0.6287 - val_top5_acc: 0.8071 - val_macro_f1score: 0.0685
# Learning rate:  0.0001
#
# Epoch 00054: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 54/70
# 765/765 [==============================] - ETA: 0s - loss: 0.1558 - accuracy: 0.9899 - top5_acc: 0.9999 - macro_f1score: 0.1130
# Epoch 00054: val_loss did not improve from 2.15017
#
# Epoch 00054: val_accuracy did not improve from 0.63374
# 765/765 [==============================] - 611s 798ms/step - loss: 0.1558 - accuracy: 0.9899 - top5_acc: 0.9999 - macro_f1score: 0.1130 - val_loss: 2.3275 - val_accuracy: 0.6280 - val_top5_acc: 0.8078 - val_macro_f1score: 0.0675
# Learning rate:  0.0001
#
# Epoch 00055: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 55/70
# 765/765 [==============================] - ETA: 0s - loss: 0.1530 - accuracy: 0.9909 - top5_acc: 0.9998 - macro_f1score: 0.1127
# Epoch 00055: val_loss did not improve from 2.15017
#
# Epoch 00055: val_accuracy did not improve from 0.63374
# 765/765 [==============================] - 610s 798ms/step - loss: 0.1530 - accuracy: 0.9909 - top5_acc: 0.9998 - macro_f1score: 0.1127 - val_loss: 2.3567 - val_accuracy: 0.6270 - val_top5_acc: 0.8044 - val_macro_f1score: 0.0681
# Learning rate:  0.0001
#
# Epoch 00056: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 56/70
# 765/765 [==============================] - ETA: 0s - loss: 0.1556 - accuracy: 0.9888 - top5_acc: 0.9999 - macro_f1score: 0.1129
# Epoch 00056: val_loss did not improve from 2.15017
#
# Epoch 00056: val_accuracy did not improve from 0.63374
# 765/765 [==============================] - 612s 800ms/step - loss: 0.1556 - accuracy: 0.9888 - top5_acc: 0.9999 - macro_f1score: 0.1129 - val_loss: 2.3581 - val_accuracy: 0.6317 - val_top5_acc: 0.8024 - val_macro_f1score: 0.0675
# Learning rate:  0.0001
#
# Epoch 00057: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 57/70
# 765/765 [==============================] - ETA: 0s - loss: 0.1520 - accuracy: 0.9914 - top5_acc: 0.9998 - macro_f1score: 0.1132
# Epoch 00057: val_loss did not improve from 2.15017
#
# Epoch 00057: val_accuracy did not improve from 0.63374
# 765/765 [==============================] - 614s 803ms/step - loss: 0.1520 - accuracy: 0.9914 - top5_acc: 0.9998 - macro_f1score: 0.1132 - val_loss: 2.3343 - val_accuracy: 0.6310 - val_top5_acc: 0.8051 - val_macro_f1score: 0.0689
# Learning rate:  0.0001
#
# Epoch 00058: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 58/70
# 765/765 [==============================] - ETA: 0s - loss: 0.1516 - accuracy: 0.9905 - top5_acc: 0.9999 - macro_f1score: 0.1126
# Epoch 00058: val_loss did not improve from 2.15017
#
# Epoch 00058: val_accuracy did not improve from 0.63374
# 765/765 [==============================] - 615s 803ms/step - loss: 0.1516 - accuracy: 0.9905 - top5_acc: 0.9999 - macro_f1score: 0.1126 - val_loss: 2.3522 - val_accuracy: 0.6331 - val_top5_acc: 0.8075 - val_macro_f1score: 0.0676
# Learning rate:  0.0001
#
# Epoch 00059: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 59/70
# 765/765 [==============================] - ETA: 0s - loss: 0.1464 - accuracy: 0.9916 - top5_acc: 0.9999 - macro_f1score: 0.1134
# Epoch 00059: val_loss did not improve from 2.15017
#
# Epoch 00059: val_accuracy did not improve from 0.63374
# 765/765 [==============================] - 613s 801ms/step - loss: 0.1464 - accuracy: 0.9916 - top5_acc: 0.9999 - macro_f1score: 0.1134 - val_loss: 2.3343 - val_accuracy: 0.6314 - val_top5_acc: 0.8061 - val_macro_f1score: 0.0683
# Learning rate:  0.0001
#
# Epoch 00060: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 60/70
# 765/765 [==============================] - ETA: 0s - loss: 0.1473 - accuracy: 0.9912 - top5_acc: 1.0000 - macro_f1score: 0.1130
# Epoch 00060: val_loss did not improve from 2.15017
#
# Epoch 00060: val_accuracy did not improve from 0.63374
# 765/765 [==============================] - 612s 800ms/step - loss: 0.1473 - accuracy: 0.9912 - top5_acc: 1.0000 - macro_f1score: 0.1130 - val_loss: 2.3426 - val_accuracy: 0.6324 - val_top5_acc: 0.7997 - val_macro_f1score: 0.0687
# Learning rate:  1e-05
#
# Epoch 00061: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 61/70
# 765/765 [==============================] - ETA: 0s - loss: 0.1467 - accuracy: 0.9916 - top5_acc: 1.0000 - macro_f1score: 0.1133
# Epoch 00061: val_loss did not improve from 2.15017
#
# Epoch 00061: val_accuracy did not improve from 0.63374
# 765/765 [==============================] - 612s 800ms/step - loss: 0.1467 - accuracy: 0.9916 - top5_acc: 1.0000 - macro_f1score: 0.1133 - val_loss: 2.3504 - val_accuracy: 0.6314 - val_top5_acc: 0.8028 - val_macro_f1score: 0.0689
# Learning rate:  1e-05
#
# Epoch 00062: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 62/70
# 765/765 [==============================] - ETA: 0s - loss: 0.1419 - accuracy: 0.9936 - top5_acc: 0.9999 - macro_f1score: 0.1135
# Epoch 00062: val_loss did not improve from 2.15017
#
# Epoch 00062: val_accuracy did not improve from 0.63374
# 765/765 [==============================] - 612s 799ms/step - loss: 0.1419 - accuracy: 0.9936 - top5_acc: 0.9999 - macro_f1score: 0.1135 - val_loss: 2.3429 - val_accuracy: 0.6314 - val_top5_acc: 0.8038 - val_macro_f1score: 0.0681
# Learning rate:  1e-05
#
# Epoch 00063: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 63/70
# 765/765 [==============================] - ETA: 0s - loss: 0.1401 - accuracy: 0.9935 - top5_acc: 1.0000 - macro_f1score: 0.1136
# Epoch 00063: val_loss did not improve from 2.15017
#
# Epoch 00063: val_accuracy did not improve from 0.63374
# 765/765 [==============================] - 610s 798ms/step - loss: 0.1401 - accuracy: 0.9935 - top5_acc: 1.0000 - macro_f1score: 0.1136 - val_loss: 2.3411 - val_accuracy: 0.6277 - val_top5_acc: 0.8038 - val_macro_f1score: 0.0684
# Learning rate:  1e-05
#
# Epoch 00064: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 64/70
# 765/765 [==============================] - ETA: 0s - loss: 0.1425 - accuracy: 0.9928 - top5_acc: 0.9999 - macro_f1score: 0.1134
# Epoch 00064: val_loss did not improve from 2.15017
#
# Epoch 00064: val_accuracy did not improve from 0.63374
# 765/765 [==============================] - 612s 800ms/step - loss: 0.1425 - accuracy: 0.9928 - top5_acc: 0.9999 - macro_f1score: 0.1134 - val_loss: 2.3396 - val_accuracy: 0.6314 - val_top5_acc: 0.8038 - val_macro_f1score: 0.0688
# Learning rate:  1e-05
#
# Epoch 00065: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 65/70
# 765/765 [==============================] - ETA: 0s - loss: 0.1413 - accuracy: 0.9933 - top5_acc: 0.9999 - macro_f1score: 0.1137
# Epoch 00065: val_loss did not improve from 2.15017
#
# Epoch 00065: val_accuracy did not improve from 0.63374
# 765/765 [==============================] - 612s 800ms/step - loss: 0.1413 - accuracy: 0.9933 - top5_acc: 0.9999 - macro_f1score: 0.1137 - val_loss: 2.3415 - val_accuracy: 0.6324 - val_top5_acc: 0.8031 - val_macro_f1score: 0.0679
# Learning rate:  1e-05
#
# Epoch 00066: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 66/70
# 765/765 [==============================] - ETA: 0s - loss: 0.1389 - accuracy: 0.9935 - top5_acc: 1.0000 - macro_f1score: 0.1138
# Epoch 00066: val_loss did not improve from 2.15017
#
# Epoch 00066: val_accuracy did not improve from 0.63374
# 765/765 [==============================] - 616s 805ms/step - loss: 0.1389 - accuracy: 0.9935 - top5_acc: 1.0000 - macro_f1score: 0.1138 - val_loss: 2.3372 - val_accuracy: 0.6334 - val_top5_acc: 0.8051 - val_macro_f1score: 0.0684
# Learning rate:  1e-05
#
# Epoch 00067: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 67/70
# 765/765 [==============================] - ETA: 0s - loss: 0.1402 - accuracy: 0.9936 - top5_acc: 1.0000 - macro_f1score: 0.1136
# Epoch 00067: val_loss did not improve from 2.15017
#
# Epoch 00067: val_accuracy improved from 0.63374 to 0.63575, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/SE_Xception/067.h5
# 765/765 [==============================] - 617s 806ms/step - loss: 0.1402 - accuracy: 0.9936 - top5_acc: 1.0000 - macro_f1score: 0.1136 - val_loss: 2.3234 - val_accuracy: 0.6358 - val_top5_acc: 0.8054 - val_macro_f1score: 0.0689
# Learning rate:  1e-05
#
# Epoch 00068: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 68/70
# 765/765 [==============================] - ETA: 0s - loss: 0.1385 - accuracy: 0.9944 - top5_acc: 1.0000 - macro_f1score: 0.1136
# Epoch 00068: val_loss did not improve from 2.15017
#
# Epoch 00068: val_accuracy did not improve from 0.63575
# 765/765 [==============================] - 619s 809ms/step - loss: 0.1385 - accuracy: 0.9944 - top5_acc: 1.0000 - macro_f1score: 0.1136 - val_loss: 2.3403 - val_accuracy: 0.6354 - val_top5_acc: 0.8051 - val_macro_f1score: 0.0687
# Learning rate:  1e-05
#
# Epoch 00069: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 69/70
# 765/765 [==============================] - ETA: 0s - loss: 0.1365 - accuracy: 0.9952 - top5_acc: 0.9999 - macro_f1score: 0.1139
# Epoch 00069: val_loss did not improve from 2.15017
#
# Epoch 00069: val_accuracy improved from 0.63575 to 0.63810, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/SE_Xception/069.h5
# 765/765 [==============================] - 623s 814ms/step - loss: 0.1365 - accuracy: 0.9952 - top5_acc: 0.9999 - macro_f1score: 0.1139 - val_loss: 2.3319 - val_accuracy: 0.6381 - val_top5_acc: 0.8041 - val_macro_f1score: 0.0681
# Learning rate:  1e-05
#
# Epoch 00070: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 70/70
# 765/765 [==============================] - ETA: 0s - loss: 0.1385 - accuracy: 0.9944 - top5_acc: 0.9999 - macro_f1score: 0.1139
# Epoch 00070: val_loss did not improve from 2.15017
#
# Epoch 00070: val_accuracy did not improve from 0.63810
# 765/765 [==============================] - 621s 811ms/step - loss: 0.1385 - accuracy: 0.9944 - top5_acc: 0.9999 - macro_f1score: 0.1139 - val_loss: 2.3464 - val_accuracy: 0.6378 - val_top5_acc: 0.8034 - val_macro_f1score: 0.0679

# %% [markdown]
# ### 3) SE-Xception Evaluate

# %%
# 1. epoch=maximum
loss , acc, top5_acc, mf1 = model.evaluate(test_generator,steps=int(len(x_test)/batch_sizes))
print('[Test Loss: %.4f /  Test Top-1 Accuracy: %.4f / Test Top-5 Accuracy: %.4f / Test Macro f1: %.4f]\n' % (loss,acc,top5_acc,mf1))
# Out:
# 97/97 [==============================] - 544s 6s/step - loss: 2.3431 - accuracy: 0.6295 - top5_acc: 0.8032 - macro_f1score: 0.0687
# [Test Loss: 2.3431 /  Test Top-1 Accuracy: 0.6295 / Test Top-5 Accuracy: 0.8032 / Test Macro f1: 0.0687]

# %%
loss=history.history['loss']
val_loss=history.history['val_loss']
acc=history.history['accuracy']
val_acc=history.history['val_accuracy']
top5_acc=history.history['top5_acc']
val_top5_acc=history.history['val_top5_acc']
f1=history.history['macro_f1score']
val_f1=history.history['val_macro_f1score']
epochs=range(1,len(acc)+1)

data = np.array([epochs,loss,val_loss,acc,val_acc,top5_acc,val_top5_acc,f1,val_f1]).T

# %%
# data save
# epochs, loss, val_loss, acc, val_acc, f1, val_f1

np.savetxt(os.path.join(dir,'train_valid_output',number,model.name+'.txt'),data)

# %%
# data import
data = np.loadtxt(os.path.join(dir,'train_valid_output',number,'SE_Xception.txt'))

# %%
epochs=data[:,0]
loss=data[:,1]
val_loss=data[:,2]
acc=data[:,3]
val_acc=data[:,4]
top5_acc=data[:,5]
val_top5_acc=data[:,6]

# %%
plt.plot(epochs[1:],acc[1:],'b',label='Training 1-Acc')
plt.plot(epochs[1:],val_acc[1:],'r',label='Validation 1-Acc')
plt.title('Training and Validation Top-1 Accuracy')
plt.legend()
plt.figure()

plt.plot(epochs[1:],top5_acc[1:],'b',label='Training 5-Acc')
plt.plot(epochs[1:],val_top5_acc[1:],'r',label='Validation 5-Acc')
plt.title('Training and Validation Top-5 Accuracy')
plt.legend()
plt.figure()

plt.plot(epochs[10:],loss[10:],'b',label='Training Loss')
plt.plot(epochs[10:],val_loss[10:],'r',label='Validation Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()

# %%
# 이 아래는 내가 인위적으로 살펴보고 싶은 epoch에 대해서 결과값 출력 / SE-Xception

# %%
# 참고 : https://github.com/OverLordGoldDragon/keras-adamw

import sys
sys.path.append('/content/drive/My Drive/Colab Notebooks/Paper')
import utils
import optimizers_v2
from utils import get_weight_decays, fill_dict_in_order
from utils import reset_seeds, K_eval
from optimizers_v2 import AdamW, NadamW, SGDW

# %%
# top-5 accuracy 출력
import functools
top5_acc = functools.partial(ks.metrics.top_k_categorical_accuracy, k=5)
top5_acc.__name__ = 'top5_acc'

# %%
model=load_model(os.path.join(dir,'model_output',number,'SE_Xception','069.h5'),custom_objects={"macro_f1score": macro_f1score,"top5_acc":top5_acc, "AdamW":AdamW})

# %%
# 2. epoch=?
loss , acc, mf1, wf1 = model.evaluate(test_generator,steps=int(len(x_test)/batch_sizes))
print('[Test Loss: %.4f /  Test Accuracy: %.4f / Test Macro f1: %.4f / Test Weighted f1: %.4f]\n' % (loss,acc,mf1,wf1))
# Out:
# 97/97 [==============================] - 1063s 11s/step - loss: 2.3274 - accuracy: 0.6279 - top5_acc: 0.8041 - macro_f1score: 0.0680
# [Test Loss: 2.3274 /  Test Accuracy: 0.6279 / Test Macro f1: 0.8041 / Test Weighted f1: 0.0680]
