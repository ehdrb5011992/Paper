# %% [markdown]
# # [VGG11]

# %% [markdown]
# *KU LeeDongGyu*

# %% [markdown]
# ### Contents

# %% [markdown]
# 1. Data Preprocessing
# ```
# 1) Data Import
# 2) Data Augmentation
# ```
# 2. Support Functions
#
# 3. Almost Original VGG11
# ```
# 1) Almost Original VGG11
# 2) VGG11 Evaluate
# ```

# %% [markdown]
# ### Install Packages

# %% [markdown]
# ### Module

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/My Drive/Colab Notebooks/Paper
# Out:
# /content/drive/My Drive/Colab Notebooks/Paper

# %%
from f1score import macro_f1score,weighted_f1score

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import cv2
import tensorflow as tf
from tensorflow import keras as ks
from tensorflow.keras import backend as K 
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, Input, Concatenate, ZeroPadding2D ,GlobalMaxPooling2D, Reshape , Lambda , Add, Multiply
from tensorflow.keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D, Activation, BatchNormalization, AveragePooling2D , ZeroPadding2D, SeparableConv2D
from tensorflow.keras.layers import add
from tensorflow.keras.optimizers import Adam, RMSprop , SGD
from tensorflow.keras.callbacks import EarlyStopping , LearningRateScheduler, ModelCheckpoint, CSVLogger, Callback, ReduceLROnPlateau
from tensorflow.keras.regularizers import l1,l2,l1_l2
from tensorflow.keras.models import Model , load_model , Sequential
from tensorflow.keras.utils import plot_model , to_categorical, get_file
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
os.getcwd()
# Out:
# '/content/drive/My Drive/Colab Notebooks/Paper'

# %%
print(tf.__version__)
print(ks.__version__)
# Out:
# 2.3.0
# 2.4.0

# %%
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 318315752188118583
# , name: "/device:XLA_CPU:0"
# device_type: "XLA_CPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 2424520574207111147
# physical_device_desc: "device: XLA_CPU device"
# , name: "/device:XLA_GPU:0"
# device_type: "XLA_GPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 4454354670993386003
# physical_device_desc: "device: XLA_GPU device"
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 15473775744
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 17584155890163957977
# physical_device_desc: "device: 0, name: Tesla V100-SXM2-16GB, pci bus id: 0000:00:04.0, compute capability: 7.0"
# ]

# %% [markdown]
# ## 1. Data Preprocessing
# ---

# %% [markdown]
# ### 1) Data Import

# %%
# 바꿔서 살펴 볼 것들
# CALTECH, CIFAR100, FER, MIT
data_name = 'CALTECH'
gan_type = 'No_GAN'
number = '1'
size = 224 # sizes after cropping
super_size = 256 # sizes before cropping 
input_sizes = (size,size,3)
batch_sizes = 128
weight_decay = 1e-4
epochs = 70

# %%
# 참고 : https://stackoverflow.com/questions/32419510/how-to-get-reproducible-results-in-keras/52897216#52897216
# setting the seed number for random number generation for reproducibility.

from numpy.random import seed
import random


if number=='1':
    seed_num = 200225
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)
elif number=='2':
    seed_num = 727
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)
elif number=='3':
    seed_num = 115
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)
elif number=='4':
    seed_num = 501
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)
elif number=='5':
    seed_num = 517
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)

# %%
# data import

if data_name=='FER' :
    x_train =  np.zeros(28698)
    x_valid = np.zeros(3589)
    x_test = np.zeros(3588)
    classes = 7 
    tr_center = [0.50793296, 0.50793296, 0.50793296]
elif data_name=='MIT':
    x_train = np.zeros(12466)
    x_valid = np.zeros(1564)
    x_test = np.zeros(1590)
    classes = 67 
    tr_center = [0.47916578, 0.42029615, 0.36046057]
elif data_name=='CALTECH':
    x_train = np.zeros(24510)
    x_valid = np.zeros(2980)
    x_test = np.zeros(3118)
    classes = 257
    tr_center = [0.51397761, 0.49525248, 0.46555727]
elif data_name=='CIFAR100':
    x_train = np.zeros(44923)
    x_valid = np.zeros(5077)
    x_test = np.zeros(10000)
    classes = 100
    tr_center = [0.53442983, 0.51355958, 0.46462564]

# %%
dir = os.path.join(os.getcwd(),data_name,gan_type)

# %% [markdown]
# ### 2) Data Augmentation

# %%
# 참고 : https://jkjung-avt.github.io/keras-image-cropping/

def random_crop(img, random_crop_size):
    # Note: image_data_format is 'channel_last'
    assert img.shape[2] == 3 # img.shape[2] 가 3(rgb)이 아니면 assertion error 발생
    height, width = img.shape[0], img.shape[1]
    dy, dx = random_crop_size
    x = np.random.randint(0, width - dx + 1)
    y = np.random.randint(0, height - dy + 1)
    return img[y:(y+dy), x:(x+dx), :]


def crop_generator(batches, crop_length):
    """Take as input a Keras ImageGen (Iterator) and generate random
    crops from the image batches generated by the original iterator.
    """
    while True:
        batch_x, batch_y = next(batches)
        batch_crops = np.zeros((batch_x.shape[0], crop_length, crop_length, 3))
        for i in range(batch_x.shape[0]):
            batch_crops[i] = random_crop(batch_x[i], (crop_length, crop_length))
        yield (batch_crops, batch_y)

# %%
from tensorflow.keras.preprocessing.image import img_to_array,load_img
import glob

# 데이터 전체에 대해 centering 진행함.

def read_cal_image(img_path): 
    x = img_to_array(load_img(img_path)) # x는 채널별 평균값
    y = x.shape[0] * x.shape[1]# y는 데이터별 픽셀 수 (비중)

    x = 1/255. * x # scaling하고, centering값을 뽑아냄.
    x = np.mean(x, axis=(0,1))
    
    return np.hstack([x,y])

def calculate_centered_mean(dataset_path,x_train=x_train):
    num = len(x_train)
    space = np.empty((num,4))
    i=0

    for p in glob.glob(os.path.join(dataset_path,'*/*.*')) :
        space[i] = read_cal_image(p)
        i += 1

    ratio = space[:,3] / np.sum(space[:,3])

    return np.average(space[:,0:3],axis=0,weights=ratio)


# 아래의 함수를 돌려서 나온 결과값을 중심화 값으로 설정.

# train_mean = calculate_centered_mean(os.path.join(dir,'data/train')).reshape((1,1,3))

# %%
datagen_tr = ImageDataGenerator(
    rescale=1/255.,
    horizontal_flip=True,
    featurewise_center=True,
    featurewise_std_normalization=False,
    rotation_range=10,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=[0.9,1.0],
    fill_mode = 'nearest')
datagen_val = ImageDataGenerator(rescale=1/255.,featurewise_center=True)
datagen_tes = ImageDataGenerator(rescale=1/255.,featurewise_center=True)

# 원래는 이 자리에 fit 매서드를 써야하지만, 그냥 내가 중심화함수를 만들고 적용함. 

# 중심화 설정
datagen_tr.mean = np.array(tr_center, dtype=np.float32).reshape((1,1,3)) # RGB
datagen_val.mean = np.array(tr_center, dtype=np.float32).reshape((1,1,3)) # RGB
datagen_tes.mean = np.array(tr_center, dtype=np.float32).reshape((1,1,3)) # RGB

# %%
train_batches = datagen_tr.flow_from_directory(directory=os.path.join(dir,'data/train'),target_size=(super_size,super_size),batch_size=batch_sizes,class_mode='categorical') # fer : 28698 / mit : 12466 / caltech : 24509 / cifar : 44923
train_generator= crop_generator(train_batches, size)
valid_generator = datagen_val.flow_from_directory(directory=os.path.join(dir,'data/valid'),target_size=(size,size),batch_size=batch_sizes,class_mode='categorical') # fer : 3589 / mit : 1564 / caltech : 2980 / cifar : 5077
test_generator = datagen_tes.flow_from_directory(directory=os.path.join(dir,'data/test'),target_size=(size,size),batch_size=batch_sizes,class_mode='categorical') # fer : 3588 / mit : 1590 / caltech : 3118 / cifar : 10000
# Out:
# Found 24509 images belonging to 257 classes.
# Found 2980 images belonging to 257 classes.
# Found 3118 images belonging to 257 classes.

# %% [markdown]
# ## 2. Support Functions
# ---

# %%
# def lr_schedule(epoch):
#     init_lr = 1e-4
#     k = 0.04
#     lr = init_lr * np.exp(-k*epoch)
#     print('Learning rate: ', lr)
#     return lr

def lr_schedule(epoch):
    lr = 3e-4
    if epoch < 30:
        lr = lr
    elif epoch < 60 :
        lr = lr * 0.1
    else:
        lr = lr * 0.01
    print('Learning rate: ', lr)
    return lr

# %% [markdown]
# ## 3. Almost Original VGG11
# ---

# %% [markdown]
# ### 1) Almost Original VGG11

# %%
# VGG11를 최대한 논문에 가깝게 맞춰 모형작성.

def VGG11(input_shape=(224, 224, 3), classes=1000, weight_decay=weight_decay, name='VGG11'):

    img_input = Input(shape=input_shape)

    # Block 1
    x = Conv2D(64, (3, 3), activation='relu', padding='same', name='block1_conv1', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(img_input)
    x = MaxPooling2D((2, 2), strides=(2, 2), name='block1_pool')(x)

    # Block 2
    x = Conv2D(128, (3, 3), activation='relu', padding='same', name='block2_conv1', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(x)
    x = MaxPooling2D((2, 2), strides=(2, 2), name='block2_pool')(x)

    # Block 3
    x = Conv2D(256, (3, 3), activation='relu', padding='same', name='block3_conv1', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(x)
    x = Conv2D(256, (3, 3), activation='relu', padding='same', name='block3_conv2', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(x)
    x = MaxPooling2D((2, 2), strides=(2, 2), name='block3_pool')(x)

    # Block 4
    x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block4_conv1', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(x)
    x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block4_conv2', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(x)
    x = MaxPooling2D((2, 2), strides=(2, 2), name='block4_pool')(x)

    # Block 5
    x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block5_conv1', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(x)
    x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block5_conv2', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(x)
    x = MaxPooling2D((2, 2), strides=(2, 2), name='block5_pool')(x)

    # Classification block
    x = Flatten(name='flatten')(x)
    x = Dense(4096, activation='relu', name='fc1', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(x)
    x = Dropout(0.5)(x)
    x = Dense(4096, activation='relu', name='fc2', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(x)
    x = Dropout(0.5)(x)
    output = Dense(classes, activation='softmax', kernel_regularizer=l2(weight_decay), name='predictions')(x)

    # Create model.
    model = Model(img_input, output, name=name)

    return model

# %%
model = VGG11(input_shape=input_sizes, classes=classes, name='VGG11')

# %%
model.summary()
# Out:
# Model: "VGG11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# fc1 (Dense)                  (None, 4096)              102764544
# _________________________________________________________________
# dropout (Dropout)            (None, 4096)              0
# _________________________________________________________________
# fc2 (Dense)                  (None, 4096)              16781312
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 4096)              0
# _________________________________________________________________
# predictions (Dense)          (None, 257)               1052929
# =================================================================
# Total params: 129,819,265
# Trainable params: 129,819,265
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 폴더 생성

os.makedirs(os.path.join(dir,'model_output',number,model.name), exist_ok=True)
os.makedirs(os.path.join(dir,'train_valid_output',number), exist_ok=True)

# %%
# 참고 : https://github.com/OverLordGoldDragon/keras-adamw

import sys
sys.path.append('/content/drive/My Drive/Colab Notebooks/Paper')
import utils
import optimizers_v2
from utils import get_weight_decays, fill_dict_in_order
from utils import reset_seeds, K_eval
from optimizers_v2 import AdamW, NadamW, SGDW

# %%
# top-5 accuracy 출력
import functools
top5_acc = functools.partial(ks.metrics.top_k_categorical_accuracy, k=5)
top5_acc.__name__ = 'top5_acc'

# %%
#optimizer = SGDW(model=model, use_cosine_annealing=False, total_iterations = len(x_train) // batch_sizes, nesterov=True, momentum=0.9)
optimizer = AdamW(model=model, use_cosine_annealing=False, total_iterations = len(x_train) // batch_sizes)
#optimizer = Adam()
filepath =  os.path.join(dir,'model_output',number,model.name,'{epoch:03d}.h5')

callbacks_list = [ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_weights_only=False, save_best_only=True, mode='min'),
                  ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_weights_only=False, save_best_only=True, mode='max'),
                  #ReduceLROnPlateau(monitor='val_loss',patience=3,factor=0.1,min_lr=1e-5),
                  LearningRateScheduler(lr_schedule,verbose=1)
                  ]
                  
model.compile(optimizer, loss = 'categorical_crossentropy', metrics=['accuracy',top5_acc,macro_f1score])

# %%
######## flow_from_directory
history = model.fit(train_generator, steps_per_epoch=int(len(x_train)/batch_sizes),  validation_data = valid_generator, epochs=epochs , verbose=1 , callbacks = callbacks_list , validation_steps=int(len(x_valid)/batch_sizes))
# Out:
# Learning rate:  0.0003
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 1/70
# 0.0(L1), 7.235745870133896e-06(L2) weight decay set for block1_conv1/kernel:0
# 0.0(L1), 7.235745870133896e-06(L2) weight decay set for block2_conv1/kernel:0
# 0.0(L1), 7.235745870133896e-06(L2) weight decay set for block3_conv1/kernel:0
# 0.0(L1), 7.235745870133896e-06(L2) weight decay set for block3_conv2/kernel:0
# 0.0(L1), 7.235745870133896e-06(L2) weight decay set for block4_conv1/kernel:0
# 0.0(L1), 7.235745870133896e-06(L2) weight decay set for block4_conv2/kernel:0
# 0.0(L1), 7.235745870133896e-06(L2) weight decay set for block5_conv1/kernel:0
# 0.0(L1), 7.235745870133896e-06(L2) weight decay set for block5_conv2/kernel:0
# 0.0(L1), 7.235745870133896e-06(L2) weight decay set for fc1/kernel:0
# 0.0(L1), 7.235745870133896e-06(L2) weight decay set for fc2/kernel:0
# 0.0(L1), 7.235745870133896e-06(L2) weight decay set for predictions/kernel:0
# 191/191 [==============================] - ETA: 0s - loss: 5.3913 - accuracy: 0.0407 - top5_acc: 0.1088 - macro_f1score: 4.8651e-04
# Epoch 00001: val_loss improved from inf to 5.09642, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/VGG11/001.h5
#
# Epoch 00001: val_accuracy improved from -inf to 0.07269, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/VGG11/001.h5
# 191/191 [==============================] - 13916s 73s/step - loss: 5.3913 - accuracy: 0.0407 - top5_acc: 0.1088 - macro_f1score: 4.8651e-04 - val_loss: 5.0964 - val_accuracy: 0.0727 - val_top5_acc: 0.1630 - val_macro_f1score: 0.0052
# Learning rate:  0.0003
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 2/70
# 191/191 [==============================] - ETA: 0s - loss: 4.8429 - accuracy: 0.0945 - top5_acc: 0.1940 - macro_f1score: 0.0061
# Epoch 00002: val_loss improved from 5.09642 to 4.52571, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/VGG11/002.h5
#
# Epoch 00002: val_accuracy improved from 0.07269 to 0.12942, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/VGG11/002.h5
# 191/191 [==============================] - 445s 2s/step - loss: 4.8429 - accuracy: 0.0945 - top5_acc: 0.1940 - macro_f1score: 0.0061 - val_loss: 4.5257 - val_accuracy: 0.1294 - val_top5_acc: 0.2480 - val_macro_f1score: 0.0107
# Learning rate:  0.0003
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 3/70
# 191/191 [==============================] - ETA: 0s - loss: 4.4536 - accuracy: 0.1315 - top5_acc: 0.2606 - macro_f1score: 0.0107
# Epoch 00003: val_loss improved from 4.52571 to 4.16315, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/VGG11/003.h5
#
# Epoch 00003: val_accuracy improved from 0.12942 to 0.17391, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/VGG11/003.h5
# 191/191 [==============================] - 445s 2s/step - loss: 4.4536 - accuracy: 0.1315 - top5_acc: 0.2606 - macro_f1score: 0.0107 - val_loss: 4.1631 - val_accuracy: 0.1739 - val_top5_acc: 0.3257 - val_macro_f1score: 0.0141
# Learning rate:  0.0003
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 4/70
# 191/191 [==============================] - ETA: 0s - loss: 4.1285 - accuracy: 0.1738 - top5_acc: 0.3328 - macro_f1score: 0.0159
# Epoch 00004: val_loss improved from 4.16315 to 3.82795, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/VGG11/004.h5
#
# Epoch 00004: val_accuracy improved from 0.17391 to 0.21264, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/VGG11/004.h5
# 191/191 [==============================] - 450s 2s/step - loss: 4.1285 - accuracy: 0.1738 - top5_acc: 0.3328 - macro_f1score: 0.0159 - val_loss: 3.8279 - val_accuracy: 0.2126 - val_top5_acc: 0.4039 - val_macro_f1score: 0.0248
# Learning rate:  0.0003
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 5/70
# 191/191 [==============================] - ETA: 0s - loss: 3.8037 - accuracy: 0.2160 - top5_acc: 0.4037 - macro_f1score: 0.0236
# Epoch 00005: val_loss improved from 3.82795 to 3.69921, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/VGG11/005.h5
#
# Epoch 00005: val_accuracy improved from 0.21264 to 0.25883, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/VGG11/005.h5
# 191/191 [==============================] - 445s 2s/step - loss: 3.8037 - accuracy: 0.2160 - top5_acc: 0.4037 - macro_f1score: 0.0236 - val_loss: 3.6992 - val_accuracy: 0.2588 - val_top5_acc: 0.4310 - val_macro_f1score: 0.0344
# Learning rate:  0.0003
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 6/70
# 191/191 [==============================] - ETA: 0s - loss: 3.5372 - accuracy: 0.2535 - top5_acc: 0.4566 - macro_f1score: 0.0330
# Epoch 00006: val_loss improved from 3.69921 to 3.34354, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/VGG11/006.h5
#
# Epoch 00006: val_accuracy improved from 0.25883 to 0.30774, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/VGG11/006.h5
# 191/191 [==============================] - 453s 2s/step - loss: 3.5372 - accuracy: 0.2535 - top5_acc: 0.4566 - macro_f1score: 0.0330 - val_loss: 3.3435 - val_accuracy: 0.3077 - val_top5_acc: 0.5041 - val_macro_f1score: 0.0428
# Learning rate:  0.0003
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 7/70
# 191/191 [==============================] - ETA: 0s - loss: 3.2851 - accuracy: 0.2945 - top5_acc: 0.5099 - macro_f1score: 0.0430
# Epoch 00007: val_loss improved from 3.34354 to 3.18025, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/VGG11/007.h5
#
# Epoch 00007: val_accuracy improved from 0.30774 to 0.32677, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/VGG11/007.h5
# 191/191 [==============================] - 459s 2s/step - loss: 3.2851 - accuracy: 0.2945 - top5_acc: 0.5099 - macro_f1score: 0.0430 - val_loss: 3.1802 - val_accuracy: 0.3268 - val_top5_acc: 0.5312 - val_macro_f1score: 0.0556
# Learning rate:  0.0003
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 8/70
# 191/191 [==============================] - ETA: 0s - loss: 3.0658 - accuracy: 0.3284 - top5_acc: 0.5564 - macro_f1score: 0.0539
# Epoch 00008: val_loss improved from 3.18025 to 3.03946, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/VGG11/008.h5
#
# Epoch 00008: val_accuracy improved from 0.32677 to 0.34545, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/VGG11/008.h5
# 191/191 [==============================] - 448s 2s/step - loss: 3.0658 - accuracy: 0.3284 - top5_acc: 0.5564 - macro_f1score: 0.0539 - val_loss: 3.0395 - val_accuracy: 0.3454 - val_top5_acc: 0.5676 - val_macro_f1score: 0.0672
# Learning rate:  0.0003
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 9/70
# 191/191 [==============================] - ETA: 0s - loss: 2.8742 - accuracy: 0.3626 - top5_acc: 0.5913 - macro_f1score: 0.0669
# Epoch 00009: val_loss improved from 3.03946 to 2.88329, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/VGG11/009.h5
#
# Epoch 00009: val_accuracy improved from 0.34545 to 0.38043, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/VGG11/009.h5
# 191/191 [==============================] - 444s 2s/step - loss: 2.8742 - accuracy: 0.3626 - top5_acc: 0.5913 - macro_f1score: 0.0669 - val_loss: 2.8833 - val_accuracy: 0.3804 - val_top5_acc: 0.6012 - val_macro_f1score: 0.0775
# Learning rate:  0.0003
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 10/70
# 191/191 [==============================] - ETA: 0s - loss: 2.6800 - accuracy: 0.3934 - top5_acc: 0.6321 - macro_f1score: 0.0784
# Epoch 00010: val_loss improved from 2.88329 to 2.85477, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/VGG11/010.h5
#
# Epoch 00010: val_accuracy improved from 0.38043 to 0.38519, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/VGG11/010.h5
# 191/191 [==============================] - 437s 2s/step - loss: 2.6800 - accuracy: 0.3934 - top5_acc: 0.6321 - macro_f1score: 0.0784 - val_loss: 2.8548 - val_accuracy: 0.3852 - val_top5_acc: 0.6050 - val_macro_f1score: 0.0837
# Learning rate:  0.0003
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 11/70
# 191/191 [==============================] - ETA: 0s - loss: 2.5239 - accuracy: 0.4212 - top5_acc: 0.6596 - macro_f1score: 0.0894
# Epoch 00011: val_loss improved from 2.85477 to 2.78385, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/VGG11/011.h5
#
# Epoch 00011: val_accuracy improved from 0.38519 to 0.40455, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/VGG11/011.h5
# 191/191 [==============================] - 446s 2s/step - loss: 2.5239 - accuracy: 0.4212 - top5_acc: 0.6596 - macro_f1score: 0.0894 - val_loss: 2.7839 - val_accuracy: 0.4046 - val_top5_acc: 0.6192 - val_macro_f1score: 0.0953
# Learning rate:  0.0003
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 12/70
# 191/191 [==============================] - ETA: 0s - loss: 2.3761 - accuracy: 0.4472 - top5_acc: 0.6864 - macro_f1score: 0.1007
# Epoch 00012: val_loss improved from 2.78385 to 2.69195, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/VGG11/012.h5
#
# Epoch 00012: val_accuracy improved from 0.40455 to 0.41576, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/VGG11/012.h5
# 191/191 [==============================] - 454s 2s/step - loss: 2.3761 - accuracy: 0.4472 - top5_acc: 0.6864 - macro_f1score: 0.1007 - val_loss: 2.6920 - val_accuracy: 0.4158 - val_top5_acc: 0.6277 - val_macro_f1score: 0.0944
# Learning rate:  0.0003
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 13/70
# 191/191 [==============================] - ETA: 0s - loss: 2.2385 - accuracy: 0.4748 - top5_acc: 0.7131 - macro_f1score: 0.1114
# Epoch 00013: val_loss improved from 2.69195 to 2.61466, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/VGG11/013.h5
#
# Epoch 00013: val_accuracy improved from 0.41576 to 0.43342, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/VGG11/013.h5
# 191/191 [==============================] - 447s 2s/step - loss: 2.2385 - accuracy: 0.4748 - top5_acc: 0.7131 - macro_f1score: 0.1114 - val_loss: 2.6147 - val_accuracy: 0.4334 - val_top5_acc: 0.6454 - val_macro_f1score: 0.0977
# Learning rate:  0.0003
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 14/70
# 191/191 [==============================] - ETA: 0s - loss: 2.1162 - accuracy: 0.4970 - top5_acc: 0.7366 - macro_f1score: 0.1215
# Epoch 00014: val_loss improved from 2.61466 to 2.55750, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/VGG11/014.h5
#
# Epoch 00014: val_accuracy improved from 0.43342 to 0.44429, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/VGG11/014.h5
# 191/191 [==============================] - 444s 2s/step - loss: 2.1162 - accuracy: 0.4970 - top5_acc: 0.7366 - macro_f1score: 0.1215 - val_loss: 2.5575 - val_accuracy: 0.4443 - val_top5_acc: 0.6624 - val_macro_f1score: 0.1127
# Learning rate:  0.0003
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 15/70
# 191/191 [==============================] - ETA: 0s - loss: 2.0086 - accuracy: 0.5162 - top5_acc: 0.7569 - macro_f1score: 0.1300
# Epoch 00015: val_loss improved from 2.55750 to 2.50908, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/VGG11/015.h5
#
# Epoch 00015: val_accuracy improved from 0.44429 to 0.46399, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/VGG11/015.h5
# 191/191 [==============================] - 433s 2s/step - loss: 2.0086 - accuracy: 0.5162 - top5_acc: 0.7569 - macro_f1score: 0.1300 - val_loss: 2.5091 - val_accuracy: 0.4640 - val_top5_acc: 0.6722 - val_macro_f1score: 0.1198
# Learning rate:  0.0003
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 16/70
# 191/191 [==============================] - ETA: 0s - loss: 1.8555 - accuracy: 0.5476 - top5_acc: 0.7785 - macro_f1score: 0.1445
# Epoch 00016: val_loss did not improve from 2.50908
#
# Epoch 00016: val_accuracy did not improve from 0.46399
# 191/191 [==============================] - 439s 2s/step - loss: 1.8555 - accuracy: 0.5476 - top5_acc: 0.7785 - macro_f1score: 0.1445 - val_loss: 2.5857 - val_accuracy: 0.4518 - val_top5_acc: 0.6559 - val_macro_f1score: 0.1224
# Learning rate:  0.0003
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 17/70
# 191/191 [==============================] - ETA: 0s - loss: 1.7560 - accuracy: 0.5654 - top5_acc: 0.8006 - macro_f1score: 0.1534
# Epoch 00017: val_loss did not improve from 2.50908
#
# Epoch 00017: val_accuracy did not improve from 0.46399
# 191/191 [==============================] - 446s 2s/step - loss: 1.7560 - accuracy: 0.5654 - top5_acc: 0.8006 - macro_f1score: 0.1534 - val_loss: 2.6184 - val_accuracy: 0.4446 - val_top5_acc: 0.6675 - val_macro_f1score: 0.1239
# Learning rate:  0.0003
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 18/70
# 191/191 [==============================] - ETA: 0s - loss: 1.6773 - accuracy: 0.5862 - top5_acc: 0.8135 - macro_f1score: 0.1599
# Epoch 00018: val_loss did not improve from 2.50908
#
# Epoch 00018: val_accuracy did not improve from 0.46399
# 191/191 [==============================] - 447s 2s/step - loss: 1.6773 - accuracy: 0.5862 - top5_acc: 0.8135 - macro_f1score: 0.1599 - val_loss: 2.5138 - val_accuracy: 0.4596 - val_top5_acc: 0.6749 - val_macro_f1score: 0.1262
# Learning rate:  0.0003
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 19/70
# 191/191 [==============================] - ETA: 0s - loss: 1.5784 - accuracy: 0.6069 - top5_acc: 0.8311 - macro_f1score: 0.1717
# Epoch 00019: val_loss improved from 2.50908 to 2.50073, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/VGG11/019.h5
#
# Epoch 00019: val_accuracy improved from 0.46399 to 0.47452, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/VGG11/019.h5
# 191/191 [==============================] - 469s 2s/step - loss: 1.5784 - accuracy: 0.6069 - top5_acc: 0.8311 - macro_f1score: 0.1717 - val_loss: 2.5007 - val_accuracy: 0.4745 - val_top5_acc: 0.6712 - val_macro_f1score: 0.1291
# Learning rate:  0.0003
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 20/70
# 191/191 [==============================] - ETA: 0s - loss: 1.4969 - accuracy: 0.6209 - top5_acc: 0.8448 - macro_f1score: 0.1800
# Epoch 00020: val_loss improved from 2.50073 to 2.48491, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/VGG11/020.h5
#
# Epoch 00020: val_accuracy improved from 0.47452 to 0.47656, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/VGG11/020.h5
# 191/191 [==============================] - 473s 2s/step - loss: 1.4969 - accuracy: 0.6209 - top5_acc: 0.8448 - macro_f1score: 0.1800 - val_loss: 2.4849 - val_accuracy: 0.4766 - val_top5_acc: 0.6787 - val_macro_f1score: 0.1330
# Learning rate:  0.0003
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 21/70
# 191/191 [==============================] - ETA: 0s - loss: 1.4013 - accuracy: 0.6415 - top5_acc: 0.8560 - macro_f1score: 0.1912
# Epoch 00021: val_loss improved from 2.48491 to 2.45402, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/VGG11/021.h5
#
# Epoch 00021: val_accuracy improved from 0.47656 to 0.47758, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/VGG11/021.h5
# 191/191 [==============================] - 481s 3s/step - loss: 1.4013 - accuracy: 0.6415 - top5_acc: 0.8560 - macro_f1score: 0.1912 - val_loss: 2.4540 - val_accuracy: 0.4776 - val_top5_acc: 0.6895 - val_macro_f1score: 0.1389
# Learning rate:  0.0003
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 22/70
# 191/191 [==============================] - ETA: 0s - loss: 1.3400 - accuracy: 0.6570 - top5_acc: 0.8656 - macro_f1score: 0.1958
# Epoch 00022: val_loss did not improve from 2.45402
#
# Epoch 00022: val_accuracy improved from 0.47758 to 0.47928, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/VGG11/022.h5
# 191/191 [==============================] - 461s 2s/step - loss: 1.3400 - accuracy: 0.6570 - top5_acc: 0.8656 - macro_f1score: 0.1958 - val_loss: 2.4716 - val_accuracy: 0.4793 - val_top5_acc: 0.6892 - val_macro_f1score: 0.1378
# Learning rate:  0.0003
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 23/70
# 191/191 [==============================] - ETA: 0s - loss: 1.2584 - accuracy: 0.6753 - top5_acc: 0.8794 - macro_f1score: 0.2050
# Epoch 00023: val_loss did not improve from 2.45402
#
# Epoch 00023: val_accuracy did not improve from 0.47928
# 191/191 [==============================] - 451s 2s/step - loss: 1.2584 - accuracy: 0.6753 - top5_acc: 0.8794 - macro_f1score: 0.2050 - val_loss: 2.5093 - val_accuracy: 0.4759 - val_top5_acc: 0.6970 - val_macro_f1score: 0.1386
# Learning rate:  0.0003
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 24/70
# 191/191 [==============================] - ETA: 0s - loss: 1.1897 - accuracy: 0.6877 - top5_acc: 0.8902 - macro_f1score: 0.2121
# Epoch 00024: val_loss did not improve from 2.45402
#
# Epoch 00024: val_accuracy did not improve from 0.47928
# 191/191 [==============================] - 448s 2s/step - loss: 1.1897 - accuracy: 0.6877 - top5_acc: 0.8902 - macro_f1score: 0.2121 - val_loss: 2.5163 - val_accuracy: 0.4779 - val_top5_acc: 0.6878 - val_macro_f1score: 0.1385
# Learning rate:  0.0003
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 25/70
# 191/191 [==============================] - ETA: 0s - loss: 1.1413 - accuracy: 0.7011 - top5_acc: 0.8981 - macro_f1score: 0.2188
# Epoch 00025: val_loss did not improve from 2.45402
#
# Epoch 00025: val_accuracy did not improve from 0.47928
# 191/191 [==============================] - 443s 2s/step - loss: 1.1413 - accuracy: 0.7011 - top5_acc: 0.8981 - macro_f1score: 0.2188 - val_loss: 2.4798 - val_accuracy: 0.4738 - val_top5_acc: 0.6950 - val_macro_f1score: 0.1374
# Learning rate:  0.0003
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 26/70
# 191/191 [==============================] - ETA: 0s - loss: 1.0877 - accuracy: 0.7144 - top5_acc: 0.9043 - macro_f1score: 0.2258
# Epoch 00026: val_loss did not improve from 2.45402
#
# Epoch 00026: val_accuracy improved from 0.47928 to 0.48777, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/VGG11/026.h5
# 191/191 [==============================] - 447s 2s/step - loss: 1.0877 - accuracy: 0.7144 - top5_acc: 0.9043 - macro_f1score: 0.2258 - val_loss: 2.5991 - val_accuracy: 0.4878 - val_top5_acc: 0.6967 - val_macro_f1score: 0.1475
# Learning rate:  0.0003
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 27/70
# 191/191 [==============================] - ETA: 0s - loss: 1.0397 - accuracy: 0.7249 - top5_acc: 0.9090 - macro_f1score: 0.2324
# Epoch 00027: val_loss did not improve from 2.45402
#
# Epoch 00027: val_accuracy improved from 0.48777 to 0.49389, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/VGG11/027.h5
# 191/191 [==============================] - 449s 2s/step - loss: 1.0397 - accuracy: 0.7249 - top5_acc: 0.9090 - macro_f1score: 0.2324 - val_loss: 2.6399 - val_accuracy: 0.4939 - val_top5_acc: 0.7014 - val_macro_f1score: 0.1517
# Learning rate:  0.0003
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 28/70
# 191/191 [==============================] - ETA: 0s - loss: 0.9739 - accuracy: 0.7399 - top5_acc: 0.9213 - macro_f1score: 0.2381
# Epoch 00028: val_loss did not improve from 2.45402
#
# Epoch 00028: val_accuracy did not improve from 0.49389
# 191/191 [==============================] - 446s 2s/step - loss: 0.9739 - accuracy: 0.7399 - top5_acc: 0.9213 - macro_f1score: 0.2381 - val_loss: 2.5679 - val_accuracy: 0.4918 - val_top5_acc: 0.7045 - val_macro_f1score: 0.1472
# Learning rate:  0.0003
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 29/70
# 191/191 [==============================] - ETA: 0s - loss: 0.9428 - accuracy: 0.7473 - top5_acc: 0.9242 - macro_f1score: 0.2444
# Epoch 00029: val_loss did not improve from 2.45402
#
# Epoch 00029: val_accuracy did not improve from 0.49389
# 191/191 [==============================] - 444s 2s/step - loss: 0.9428 - accuracy: 0.7473 - top5_acc: 0.9242 - macro_f1score: 0.2444 - val_loss: 2.5157 - val_accuracy: 0.4891 - val_top5_acc: 0.6940 - val_macro_f1score: 0.1479
# Learning rate:  0.0003
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 30/70
# 191/191 [==============================] - ETA: 0s - loss: 0.8740 - accuracy: 0.7633 - top5_acc: 0.9320 - macro_f1score: 0.2519
# Epoch 00030: val_loss did not improve from 2.45402
#
# Epoch 00030: val_accuracy did not improve from 0.49389
# 191/191 [==============================] - 442s 2s/step - loss: 0.8740 - accuracy: 0.7633 - top5_acc: 0.9320 - macro_f1score: 0.2519 - val_loss: 2.5797 - val_accuracy: 0.4912 - val_top5_acc: 0.6994 - val_macro_f1score: 0.1502
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 31/70
# 191/191 [==============================] - ETA: 0s - loss: 0.6801 - accuracy: 0.8142 - top5_acc: 0.9526 - macro_f1score: 0.2749
# Epoch 00031: val_loss did not improve from 2.45402
#
# Epoch 00031: val_accuracy improved from 0.49389 to 0.50442, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/VGG11/031.h5
# 191/191 [==============================] - 449s 2s/step - loss: 0.6801 - accuracy: 0.8142 - top5_acc: 0.9526 - macro_f1score: 0.2749 - val_loss: 2.5788 - val_accuracy: 0.5044 - val_top5_acc: 0.7096 - val_macro_f1score: 0.1579
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 32/70
# 191/191 [==============================] - ETA: 0s - loss: 0.6129 - accuracy: 0.8318 - top5_acc: 0.9593 - macro_f1score: 0.2843
# Epoch 00032: val_loss did not improve from 2.45402
#
# Epoch 00032: val_accuracy improved from 0.50442 to 0.51427, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/VGG11/032.h5
# 191/191 [==============================] - 456s 2s/step - loss: 0.6129 - accuracy: 0.8318 - top5_acc: 0.9593 - macro_f1score: 0.2843 - val_loss: 2.5592 - val_accuracy: 0.5143 - val_top5_acc: 0.7147 - val_macro_f1score: 0.1639
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00033: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 33/70
# 191/191 [==============================] - ETA: 0s - loss: 0.5679 - accuracy: 0.8422 - top5_acc: 0.9637 - macro_f1score: 0.2922
# Epoch 00033: val_loss did not improve from 2.45402
#
# Epoch 00033: val_accuracy improved from 0.51427 to 0.51461, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/VGG11/033.h5
# 191/191 [==============================] - 458s 2s/step - loss: 0.5679 - accuracy: 0.8422 - top5_acc: 0.9637 - macro_f1score: 0.2922 - val_loss: 2.5861 - val_accuracy: 0.5146 - val_top5_acc: 0.7147 - val_macro_f1score: 0.1632
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00034: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 34/70
# 191/191 [==============================] - ETA: 0s - loss: 0.5540 - accuracy: 0.8455 - top5_acc: 0.9666 - macro_f1score: 0.2936
# Epoch 00034: val_loss did not improve from 2.45402
#
# Epoch 00034: val_accuracy did not improve from 0.51461
# 191/191 [==============================] - 452s 2s/step - loss: 0.5540 - accuracy: 0.8455 - top5_acc: 0.9666 - macro_f1score: 0.2936 - val_loss: 2.5761 - val_accuracy: 0.5126 - val_top5_acc: 0.7130 - val_macro_f1score: 0.1582
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00035: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 35/70
# 191/191 [==============================] - ETA: 0s - loss: 0.5238 - accuracy: 0.8534 - top5_acc: 0.9675 - macro_f1score: 0.2956
# Epoch 00035: val_loss did not improve from 2.45402
#
# Epoch 00035: val_accuracy did not improve from 0.51461
# 191/191 [==============================] - 446s 2s/step - loss: 0.5238 - accuracy: 0.8534 - top5_acc: 0.9675 - macro_f1score: 0.2956 - val_loss: 2.5973 - val_accuracy: 0.5112 - val_top5_acc: 0.7181 - val_macro_f1score: 0.1651
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00036: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 36/70
# 191/191 [==============================] - ETA: 0s - loss: 0.5176 - accuracy: 0.8552 - top5_acc: 0.9670 - macro_f1score: 0.2982
# Epoch 00036: val_loss did not improve from 2.45402
#
# Epoch 00036: val_accuracy improved from 0.51461 to 0.51596, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/VGG11/036.h5
# 191/191 [==============================] - 452s 2s/step - loss: 0.5176 - accuracy: 0.8552 - top5_acc: 0.9670 - macro_f1score: 0.2982 - val_loss: 2.5944 - val_accuracy: 0.5160 - val_top5_acc: 0.7194 - val_macro_f1score: 0.1610
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00037: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 37/70
# 191/191 [==============================] - ETA: 0s - loss: 0.5075 - accuracy: 0.8583 - top5_acc: 0.9693 - macro_f1score: 0.2993
# Epoch 00037: val_loss did not improve from 2.45402
#
# Epoch 00037: val_accuracy improved from 0.51596 to 0.51834, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/VGG11/037.h5
# 191/191 [==============================] - 458s 2s/step - loss: 0.5075 - accuracy: 0.8583 - top5_acc: 0.9693 - macro_f1score: 0.2993 - val_loss: 2.6473 - val_accuracy: 0.5183 - val_top5_acc: 0.7238 - val_macro_f1score: 0.1697
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00038: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 38/70
# 191/191 [==============================] - ETA: 0s - loss: 0.4875 - accuracy: 0.8639 - top5_acc: 0.9700 - macro_f1score: 0.3016
# Epoch 00038: val_loss did not improve from 2.45402
#
# Epoch 00038: val_accuracy did not improve from 0.51834
# 191/191 [==============================] - 446s 2s/step - loss: 0.4875 - accuracy: 0.8639 - top5_acc: 0.9700 - macro_f1score: 0.3016 - val_loss: 2.6395 - val_accuracy: 0.5160 - val_top5_acc: 0.7201 - val_macro_f1score: 0.1646
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00039: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 39/70
# 191/191 [==============================] - ETA: 0s - loss: 0.4759 - accuracy: 0.8643 - top5_acc: 0.9719 - macro_f1score: 0.3018
# Epoch 00039: val_loss did not improve from 2.45402
#
# Epoch 00039: val_accuracy did not improve from 0.51834
# 191/191 [==============================] - 440s 2s/step - loss: 0.4759 - accuracy: 0.8643 - top5_acc: 0.9719 - macro_f1score: 0.3018 - val_loss: 2.6805 - val_accuracy: 0.5119 - val_top5_acc: 0.7221 - val_macro_f1score: 0.1649
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00040: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 40/70
# 191/191 [==============================] - ETA: 0s - loss: 0.4644 - accuracy: 0.8686 - top5_acc: 0.9724 - macro_f1score: 0.3047
# Epoch 00040: val_loss did not improve from 2.45402
#
# Epoch 00040: val_accuracy improved from 0.51834 to 0.51902, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/VGG11/040.h5
# 191/191 [==============================] - 440s 2s/step - loss: 0.4644 - accuracy: 0.8686 - top5_acc: 0.9724 - macro_f1score: 0.3047 - val_loss: 2.6328 - val_accuracy: 0.5190 - val_top5_acc: 0.7303 - val_macro_f1score: 0.1677
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00041: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 41/70
# 191/191 [==============================] - ETA: 0s - loss: 0.4504 - accuracy: 0.8740 - top5_acc: 0.9729 - macro_f1score: 0.3066
# Epoch 00041: val_loss did not improve from 2.45402
#
# Epoch 00041: val_accuracy did not improve from 0.51902
# 191/191 [==============================] - 432s 2s/step - loss: 0.4504 - accuracy: 0.8740 - top5_acc: 0.9729 - macro_f1score: 0.3066 - val_loss: 2.6948 - val_accuracy: 0.5139 - val_top5_acc: 0.7198 - val_macro_f1score: 0.1642
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00042: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 42/70
# 191/191 [==============================] - ETA: 0s - loss: 0.4532 - accuracy: 0.8734 - top5_acc: 0.9732 - macro_f1score: 0.3070
# Epoch 00042: val_loss did not improve from 2.45402
#
# Epoch 00042: val_accuracy improved from 0.51902 to 0.52208, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/VGG11/042.h5
# 191/191 [==============================] - 443s 2s/step - loss: 0.4532 - accuracy: 0.8734 - top5_acc: 0.9732 - macro_f1score: 0.3070 - val_loss: 2.6701 - val_accuracy: 0.5221 - val_top5_acc: 0.7249 - val_macro_f1score: 0.1675
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00043: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 43/70
# 191/191 [==============================] - ETA: 0s - loss: 0.4365 - accuracy: 0.8778 - top5_acc: 0.9749 - macro_f1score: 0.3101
# Epoch 00043: val_loss did not improve from 2.45402
#
# Epoch 00043: val_accuracy did not improve from 0.52208
# 191/191 [==============================] - 437s 2s/step - loss: 0.4365 - accuracy: 0.8778 - top5_acc: 0.9749 - macro_f1score: 0.3101 - val_loss: 2.6879 - val_accuracy: 0.5160 - val_top5_acc: 0.7283 - val_macro_f1score: 0.1653
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00044: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 44/70
# 191/191 [==============================] - ETA: 0s - loss: 0.4360 - accuracy: 0.8776 - top5_acc: 0.9753 - macro_f1score: 0.3100
# Epoch 00044: val_loss did not improve from 2.45402
#
# Epoch 00044: val_accuracy did not improve from 0.52208
# 191/191 [==============================] - 431s 2s/step - loss: 0.4360 - accuracy: 0.8776 - top5_acc: 0.9753 - macro_f1score: 0.3100 - val_loss: 2.6887 - val_accuracy: 0.5160 - val_top5_acc: 0.7211 - val_macro_f1score: 0.1642
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00045: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 45/70
# 191/191 [==============================] - ETA: 0s - loss: 0.4161 - accuracy: 0.8816 - top5_acc: 0.9765 - macro_f1score: 0.3120
# Epoch 00045: val_loss did not improve from 2.45402
#
# Epoch 00045: val_accuracy improved from 0.52208 to 0.52310, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/VGG11/045.h5
# 191/191 [==============================] - 431s 2s/step - loss: 0.4161 - accuracy: 0.8816 - top5_acc: 0.9765 - macro_f1score: 0.3120 - val_loss: 2.6953 - val_accuracy: 0.5231 - val_top5_acc: 0.7272 - val_macro_f1score: 0.1668
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00046: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 46/70
# 191/191 [==============================] - ETA: 0s - loss: 0.4097 - accuracy: 0.8846 - top5_acc: 0.9781 - macro_f1score: 0.3135
# Epoch 00046: val_loss did not improve from 2.45402
#
# Epoch 00046: val_accuracy did not improve from 0.52310
# 191/191 [==============================] - 428s 2s/step - loss: 0.4097 - accuracy: 0.8846 - top5_acc: 0.9781 - macro_f1score: 0.3135 - val_loss: 2.7130 - val_accuracy: 0.5197 - val_top5_acc: 0.7252 - val_macro_f1score: 0.1661
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00047: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 47/70
# 191/191 [==============================] - ETA: 0s - loss: 0.3931 - accuracy: 0.8880 - top5_acc: 0.9806 - macro_f1score: 0.3135
# Epoch 00047: val_loss did not improve from 2.45402
#
# Epoch 00047: val_accuracy did not improve from 0.52310
# 191/191 [==============================] - 430s 2s/step - loss: 0.3931 - accuracy: 0.8880 - top5_acc: 0.9806 - macro_f1score: 0.3135 - val_loss: 2.6783 - val_accuracy: 0.5217 - val_top5_acc: 0.7279 - val_macro_f1score: 0.1682
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00048: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 48/70
# 191/191 [==============================] - ETA: 0s - loss: 0.3894 - accuracy: 0.8876 - top5_acc: 0.9793 - macro_f1score: 0.3144
# Epoch 00048: val_loss did not improve from 2.45402
#
# Epoch 00048: val_accuracy did not improve from 0.52310
# 191/191 [==============================] - 440s 2s/step - loss: 0.3894 - accuracy: 0.8876 - top5_acc: 0.9793 - macro_f1score: 0.3144 - val_loss: 2.7054 - val_accuracy: 0.5204 - val_top5_acc: 0.7269 - val_macro_f1score: 0.1676
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00049: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 49/70
# 191/191 [==============================] - ETA: 0s - loss: 0.3898 - accuracy: 0.8893 - top5_acc: 0.9797 - macro_f1score: 0.3165
# Epoch 00049: val_loss did not improve from 2.45402
#
# Epoch 00049: val_accuracy did not improve from 0.52310
# 191/191 [==============================] - 435s 2s/step - loss: 0.3898 - accuracy: 0.8893 - top5_acc: 0.9797 - macro_f1score: 0.3165 - val_loss: 2.7288 - val_accuracy: 0.5207 - val_top5_acc: 0.7269 - val_macro_f1score: 0.1705
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00050: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 50/70
# 191/191 [==============================] - ETA: 0s - loss: 0.3871 - accuracy: 0.8932 - top5_acc: 0.9792 - macro_f1score: 0.3171
# Epoch 00050: val_loss did not improve from 2.45402
#
# Epoch 00050: val_accuracy improved from 0.52310 to 0.52412, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/VGG11/050.h5
# 191/191 [==============================] - 449s 2s/step - loss: 0.3871 - accuracy: 0.8932 - top5_acc: 0.9792 - macro_f1score: 0.3171 - val_loss: 2.7556 - val_accuracy: 0.5241 - val_top5_acc: 0.7215 - val_macro_f1score: 0.1683
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00051: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 51/70
# 191/191 [==============================] - ETA: 0s - loss: 0.3760 - accuracy: 0.8941 - top5_acc: 0.9811 - macro_f1score: 0.3182
# Epoch 00051: val_loss did not improve from 2.45402
#
# Epoch 00051: val_accuracy improved from 0.52412 to 0.52751, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/VGG11/051.h5
# 191/191 [==============================] - 452s 2s/step - loss: 0.3760 - accuracy: 0.8941 - top5_acc: 0.9811 - macro_f1score: 0.3182 - val_loss: 2.7131 - val_accuracy: 0.5275 - val_top5_acc: 0.7259 - val_macro_f1score: 0.1745
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00052: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 52/70
# 191/191 [==============================] - ETA: 0s - loss: 0.3700 - accuracy: 0.8964 - top5_acc: 0.9796 - macro_f1score: 0.3179
# Epoch 00052: val_loss did not improve from 2.45402
#
# Epoch 00052: val_accuracy did not improve from 0.52751
# 191/191 [==============================] - 442s 2s/step - loss: 0.3700 - accuracy: 0.8964 - top5_acc: 0.9796 - macro_f1score: 0.3179 - val_loss: 2.7488 - val_accuracy: 0.5190 - val_top5_acc: 0.7235 - val_macro_f1score: 0.1705
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00053: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 53/70
# 191/191 [==============================] - ETA: 0s - loss: 0.3605 - accuracy: 0.8958 - top5_acc: 0.9812 - macro_f1score: 0.3205
# Epoch 00053: val_loss did not improve from 2.45402
#
# Epoch 00053: val_accuracy did not improve from 0.52751
# 191/191 [==============================] - 441s 2s/step - loss: 0.3605 - accuracy: 0.8958 - top5_acc: 0.9812 - macro_f1score: 0.3205 - val_loss: 2.7852 - val_accuracy: 0.5153 - val_top5_acc: 0.7181 - val_macro_f1score: 0.1679
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00054: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 54/70
# 191/191 [==============================] - ETA: 0s - loss: 0.3676 - accuracy: 0.8975 - top5_acc: 0.9805 - macro_f1score: 0.3212
# Epoch 00054: val_loss did not improve from 2.45402
#
# Epoch 00054: val_accuracy did not improve from 0.52751
# 191/191 [==============================] - 438s 2s/step - loss: 0.3676 - accuracy: 0.8975 - top5_acc: 0.9805 - macro_f1score: 0.3212 - val_loss: 2.7405 - val_accuracy: 0.5224 - val_top5_acc: 0.7232 - val_macro_f1score: 0.1711
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00055: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 55/70
# 191/191 [==============================] - ETA: 0s - loss: 0.3579 - accuracy: 0.8997 - top5_acc: 0.9822 - macro_f1score: 0.3200
# Epoch 00055: val_loss did not improve from 2.45402
#
# Epoch 00055: val_accuracy did not improve from 0.52751
# 191/191 [==============================] - 440s 2s/step - loss: 0.3579 - accuracy: 0.8997 - top5_acc: 0.9822 - macro_f1score: 0.3200 - val_loss: 2.7613 - val_accuracy: 0.5214 - val_top5_acc: 0.7242 - val_macro_f1score: 0.1716
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00056: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 56/70
# 191/191 [==============================] - ETA: 0s - loss: 0.3459 - accuracy: 0.9012 - top5_acc: 0.9829 - macro_f1score: 0.3229
# Epoch 00056: val_loss did not improve from 2.45402
#
# Epoch 00056: val_accuracy did not improve from 0.52751
# 191/191 [==============================] - 441s 2s/step - loss: 0.3459 - accuracy: 0.9012 - top5_acc: 0.9829 - macro_f1score: 0.3229 - val_loss: 2.8095 - val_accuracy: 0.5224 - val_top5_acc: 0.7266 - val_macro_f1score: 0.1727
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00057: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 57/70
# 191/191 [==============================] - ETA: 0s - loss: 0.3432 - accuracy: 0.9046 - top5_acc: 0.9825 - macro_f1score: 0.3228
# Epoch 00057: val_loss did not improve from 2.45402
#
# Epoch 00057: val_accuracy did not improve from 0.52751
# 191/191 [==============================] - 446s 2s/step - loss: 0.3432 - accuracy: 0.9046 - top5_acc: 0.9825 - macro_f1score: 0.3228 - val_loss: 2.8176 - val_accuracy: 0.5217 - val_top5_acc: 0.7215 - val_macro_f1score: 0.1726
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00058: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 58/70
# 191/191 [==============================] - ETA: 0s - loss: 0.3190 - accuracy: 0.9058 - top5_acc: 0.9849 - macro_f1score: 0.3246
# Epoch 00058: val_loss did not improve from 2.45402
#
# Epoch 00058: val_accuracy improved from 0.52751 to 0.52955, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/VGG11/058.h5
# 191/191 [==============================] - 454s 2s/step - loss: 0.3190 - accuracy: 0.9058 - top5_acc: 0.9849 - macro_f1score: 0.3246 - val_loss: 2.8173 - val_accuracy: 0.5296 - val_top5_acc: 0.7269 - val_macro_f1score: 0.1735
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00059: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 59/70
# 191/191 [==============================] - ETA: 0s - loss: 0.3265 - accuracy: 0.9061 - top5_acc: 0.9844 - macro_f1score: 0.3239
# Epoch 00059: val_loss did not improve from 2.45402
#
# Epoch 00059: val_accuracy did not improve from 0.52955
# 191/191 [==============================] - 440s 2s/step - loss: 0.3265 - accuracy: 0.9061 - top5_acc: 0.9844 - macro_f1score: 0.3239 - val_loss: 2.7626 - val_accuracy: 0.5231 - val_top5_acc: 0.7259 - val_macro_f1score: 0.1717
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00060: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 60/70
# 191/191 [==============================] - ETA: 0s - loss: 0.3317 - accuracy: 0.9065 - top5_acc: 0.9831 - macro_f1score: 0.3236
# Epoch 00060: val_loss did not improve from 2.45402
#
# Epoch 00060: val_accuracy did not improve from 0.52955
# 191/191 [==============================] - 437s 2s/step - loss: 0.3317 - accuracy: 0.9065 - top5_acc: 0.9831 - macro_f1score: 0.3236 - val_loss: 2.7683 - val_accuracy: 0.5255 - val_top5_acc: 0.7279 - val_macro_f1score: 0.1671
# Learning rate:  2.9999999999999997e-06
#
# Epoch 00061: LearningRateScheduler reducing learning rate to 2.9999999999999997e-06.
# Epoch 61/70
# 191/191 [==============================] - ETA: 0s - loss: 0.3142 - accuracy: 0.9098 - top5_acc: 0.9861 - macro_f1score: 0.3249
# Epoch 00061: val_loss did not improve from 2.45402
#
# Epoch 00061: val_accuracy did not improve from 0.52955
# 191/191 [==============================] - 438s 2s/step - loss: 0.3142 - accuracy: 0.9098 - top5_acc: 0.9861 - macro_f1score: 0.3249 - val_loss: 2.7817 - val_accuracy: 0.5238 - val_top5_acc: 0.7259 - val_macro_f1score: 0.1722
# Learning rate:  2.9999999999999997e-06
#
# Epoch 00062: LearningRateScheduler reducing learning rate to 2.9999999999999997e-06.
# Epoch 62/70
# 191/191 [==============================] - ETA: 0s - loss: 0.3106 - accuracy: 0.9106 - top5_acc: 0.9847 - macro_f1score: 0.3262
# Epoch 00062: val_loss did not improve from 2.45402
#
# Epoch 00062: val_accuracy did not improve from 0.52955
# 191/191 [==============================] - 442s 2s/step - loss: 0.3106 - accuracy: 0.9106 - top5_acc: 0.9847 - macro_f1score: 0.3262 - val_loss: 2.7661 - val_accuracy: 0.5268 - val_top5_acc: 0.7306 - val_macro_f1score: 0.1724
# Learning rate:  2.9999999999999997e-06
#
# Epoch 00063: LearningRateScheduler reducing learning rate to 2.9999999999999997e-06.
# Epoch 63/70
# 191/191 [==============================] - ETA: 0s - loss: 0.3112 - accuracy: 0.9108 - top5_acc: 0.9859 - macro_f1score: 0.3259
# Epoch 00063: val_loss did not improve from 2.45402
#
# Epoch 00063: val_accuracy did not improve from 0.52955
# 191/191 [==============================] - 442s 2s/step - loss: 0.3112 - accuracy: 0.9108 - top5_acc: 0.9859 - macro_f1score: 0.3259 - val_loss: 2.7689 - val_accuracy: 0.5279 - val_top5_acc: 0.7306 - val_macro_f1score: 0.1740
# Learning rate:  2.9999999999999997e-06
#
# Epoch 00064: LearningRateScheduler reducing learning rate to 2.9999999999999997e-06.
# Epoch 64/70
# 191/191 [==============================] - ETA: 0s - loss: 0.3063 - accuracy: 0.9123 - top5_acc: 0.9857 - macro_f1score: 0.3261
# Epoch 00064: val_loss did not improve from 2.45402
#
# Epoch 00064: val_accuracy did not improve from 0.52955
# 191/191 [==============================] - 443s 2s/step - loss: 0.3063 - accuracy: 0.9123 - top5_acc: 0.9857 - macro_f1score: 0.3261 - val_loss: 2.7613 - val_accuracy: 0.5292 - val_top5_acc: 0.7317 - val_macro_f1score: 0.1745
# Learning rate:  2.9999999999999997e-06
#
# Epoch 00065: LearningRateScheduler reducing learning rate to 2.9999999999999997e-06.
# Epoch 65/70
# 191/191 [==============================] - ETA: 0s - loss: 0.3149 - accuracy: 0.9085 - top5_acc: 0.9853 - macro_f1score: 0.3222
# Epoch 00065: val_loss did not improve from 2.45402
#
# Epoch 00065: val_accuracy did not improve from 0.52955
# 191/191 [==============================] - 444s 2s/step - loss: 0.3149 - accuracy: 0.9085 - top5_acc: 0.9853 - macro_f1score: 0.3222 - val_loss: 2.7416 - val_accuracy: 0.5296 - val_top5_acc: 0.7310 - val_macro_f1score: 0.1700
# Learning rate:  2.9999999999999997e-06
#
# Epoch 00066: LearningRateScheduler reducing learning rate to 2.9999999999999997e-06.
# Epoch 66/70
# 191/191 [==============================] - ETA: 0s - loss: 0.3087 - accuracy: 0.9111 - top5_acc: 0.9856 - macro_f1score: 0.3248
# Epoch 00066: val_loss did not improve from 2.45402
#
# Epoch 00066: val_accuracy did not improve from 0.52955
# 191/191 [==============================] - 441s 2s/step - loss: 0.3087 - accuracy: 0.9111 - top5_acc: 0.9856 - macro_f1score: 0.3248 - val_loss: 2.7614 - val_accuracy: 0.5265 - val_top5_acc: 0.7272 - val_macro_f1score: 0.1696
# Learning rate:  2.9999999999999997e-06
#
# Epoch 00067: LearningRateScheduler reducing learning rate to 2.9999999999999997e-06.
# Epoch 67/70
# 191/191 [==============================] - ETA: 0s - loss: 0.3129 - accuracy: 0.9101 - top5_acc: 0.9846 - macro_f1score: 0.3245
# Epoch 00067: val_loss did not improve from 2.45402
#
# Epoch 00067: val_accuracy did not improve from 0.52955
# 191/191 [==============================] - 441s 2s/step - loss: 0.3129 - accuracy: 0.9101 - top5_acc: 0.9846 - macro_f1score: 0.3245 - val_loss: 2.7350 - val_accuracy: 0.5272 - val_top5_acc: 0.7296 - val_macro_f1score: 0.1701
# Learning rate:  2.9999999999999997e-06
#
# Epoch 00068: LearningRateScheduler reducing learning rate to 2.9999999999999997e-06.
# Epoch 68/70
# 191/191 [==============================] - ETA: 0s - loss: 0.3012 - accuracy: 0.9130 - top5_acc: 0.9857 - macro_f1score: 0.3254
# Epoch 00068: val_loss did not improve from 2.45402
#
# Epoch 00068: val_accuracy did not improve from 0.52955
# 191/191 [==============================] - 440s 2s/step - loss: 0.3012 - accuracy: 0.9130 - top5_acc: 0.9857 - macro_f1score: 0.3254 - val_loss: 2.7499 - val_accuracy: 0.5258 - val_top5_acc: 0.7289 - val_macro_f1score: 0.1746
# Learning rate:  2.9999999999999997e-06
#
# Epoch 00069: LearningRateScheduler reducing learning rate to 2.9999999999999997e-06.
# Epoch 69/70
# 191/191 [==============================] - ETA: 0s - loss: 0.2991 - accuracy: 0.9133 - top5_acc: 0.9862 - macro_f1score: 0.3268
# Epoch 00069: val_loss did not improve from 2.45402
#
# Epoch 00069: val_accuracy did not improve from 0.52955
# 191/191 [==============================] - 441s 2s/step - loss: 0.2991 - accuracy: 0.9133 - top5_acc: 0.9862 - macro_f1score: 0.3268 - val_loss: 2.7484 - val_accuracy: 0.5248 - val_top5_acc: 0.7276 - val_macro_f1score: 0.1713
# Learning rate:  2.9999999999999997e-06
#
# Epoch 00070: LearningRateScheduler reducing learning rate to 2.9999999999999997e-06.
# Epoch 70/70
# 191/191 [==============================] - ETA: 0s - loss: 0.3091 - accuracy: 0.9128 - top5_acc: 0.9841 - macro_f1score: 0.3257
# Epoch 00070: val_loss did not improve from 2.45402
#
# Epoch 00070: val_accuracy did not improve from 0.52955
# 191/191 [==============================] - 438s 2s/step - loss: 0.3091 - accuracy: 0.9128 - top5_acc: 0.9841 - macro_f1score: 0.3257 - val_loss: 2.7182 - val_accuracy: 0.5255 - val_top5_acc: 0.7313 - val_macro_f1score: 0.1745

# %% [markdown]
# ### 2) VGG11 Evaluate

# %%
# 1. epoch=maximum
loss , acc, top5_acc, mf1 = model.evaluate(test_generator,steps=int(len(x_test)/batch_sizes))
print('[Test Loss: %.4f /  Test Top-1 Accuracy: %.4f / Test Top-5 Accuracy: %.4f / Test Macro f1: %.4f]\n' % (loss,acc,top5_acc,mf1))
# Out:
# 24/24 [==============================] - 1634s 68s/step - loss: 2.7862 - accuracy: 0.5202 - top5_acc: 0.7253 - macro_f1score: 0.1711
# [Test Loss: 2.7862 /  Test Top-1 Accuracy: 0.5202 / Test Top-5 Accuracy: 0.7253 / Test Macro f1: 0.1711]

# %%
loss=history.history['loss']
val_loss=history.history['val_loss']
acc=history.history['accuracy']
val_acc=history.history['val_accuracy']
top5_acc=history.history['top5_acc']
val_top5_acc=history.history['val_top5_acc']
f1=history.history['macro_f1score']
val_f1=history.history['val_macro_f1score']
epochs=range(1,len(acc)+1)

data = np.array([epochs,loss,val_loss,acc,val_acc,top5_acc,val_top5_acc,f1,val_f1]).T

# %%
# data save
# epochs, loss, val_loss, acc, val_acc, top5_acc, val_top5_acc, f1, val_f1

np.savetxt(os.path.join(dir,'train_valid_output',number,model.name+'.txt'),data)

# %%
# data import
data = np.loadtxt(os.path.join(dir,'train_valid_output',number,'VGG11.txt'))

# %%
epochs=data[:,0]
loss=data[:,1]
val_loss=data[:,2]
acc=data[:,3]
val_acc=data[:,4]
top5_acc=data[:,5]
val_top5_acc=data[:,6]

# %%
plt.plot(epochs[1:],acc[1:],'b',label='Training 1-Acc')
plt.plot(epochs[1:],val_acc[1:],'r',label='Validation 1-Acc')
plt.title('Training and Validation Top-1 Accuracy')
plt.legend()
plt.figure()

plt.plot(epochs[1:],top5_acc[1:],'b',label='Training 5-Acc')
plt.plot(epochs[1:],val_top5_acc[1:],'r',label='Validation 5-Acc')
plt.title('Training and Validation Top-5 Accuracy')
plt.legend()
plt.figure()

plt.plot(epochs[10:],loss[10:],'b',label='Training Loss')
plt.plot(epochs[10:],val_loss[10:],'r',label='Validation Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()

# %%
# 이 아래는 내가 인위적으로 살펴보고 싶은 epoch에 대해서 결과값 출력 / VGG11

# %%
# 참고 : https://github.com/OverLordGoldDragon/keras-adamw

import sys
sys.path.append('/content/drive/My Drive/Colab Notebooks/Paper')
import utils
import optimizers_v2
from utils import get_weight_decays, fill_dict_in_order
from utils import reset_seeds, K_eval
from optimizers_v2 import AdamW, NadamW, SGDW

# %%
# top-5 accuracy 출력
import functools
top5_acc = functools.partial(ks.metrics.top_k_categorical_accuracy, k=5)
top5_acc.__name__ = 'top5_acc'

# %%
model=load_model(os.path.join(dir,'model_output',number,'VGG11','058.h5'),custom_objects={"macro_f1score": macro_f1score,"top5_acc":top5_acc, "AdamW":AdamW})

# %%
# 2. epoch=?
loss , acc, top5_acc, mf1 = model.evaluate(test_generator,steps=int(len(x_test)/batch_sizes))
print('[Test Loss: %.4f /  Test Top-1 Accuracy: %.4f / Test Top-5 Accuracy: %.4f / Test Macro f1: %.4f]\n' % (loss,acc,top5_acc,mf1))
# Out:
# 24/24 [==============================] - 1478s 62s/step - loss: 2.8904 - accuracy: 0.5205 - top5_acc: 0.7188 - macro_f1score: 0.1717
# [Test Loss: 2.8904 /  Test Top-1 Accuracy: 0.5205 / Test Top-5 Accuracy: 0.7188 / Test Macro f1: 0.1717]
