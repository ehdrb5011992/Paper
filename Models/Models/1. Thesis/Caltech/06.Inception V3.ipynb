# %%
# 참고 : https://sike6054.github.io/blog/paper/third-post/

# %% [markdown]
# # [Inception V2 & V3]

# %% [markdown]
# *KU LeeDongGyu*

# %% [markdown]
# ## Contents
# ---

# %% [markdown]
# 1. Data Preprocessing
# ```
# 1) Data Import
# 2) Data Augmentation
# ```
# 2. Support Functions & Almost Original Inception-V2,V3 (Especially V3)
# ```
# 1) Support Functions
# 2) Almost Original Inception-V2,V3 (Especially V3)
# 3) Inception-V3 Evaluate
# ```

# %% [markdown]
# ### Install Packages

# %% [markdown]
# ### Module

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/My Drive/Colab Notebooks/Paper
# Out:
# /content/drive/My Drive/Colab Notebooks/Paper

# %%
from f1score import macro_f1score,weighted_f1score
from smoothed_categorical_crossentropy import smoothed_categorical_crossentropy

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import cv2
import tensorflow as tf
from tensorflow import keras as ks
from tensorflow.keras import backend as K 
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, Input, Concatenate, ZeroPadding2D ,GlobalMaxPooling2D, Reshape , Lambda , Add, Multiply
from tensorflow.keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D, Activation, BatchNormalization, AveragePooling2D , ZeroPadding2D, SeparableConv2D , LeakyReLU
from tensorflow.keras.layers import add, concatenate, multiply
from tensorflow.keras.optimizers import Adam, RMSprop , SGD
from tensorflow.keras.callbacks import EarlyStopping , LearningRateScheduler, ModelCheckpoint, CSVLogger, Callback, ReduceLROnPlateau
from tensorflow.keras.regularizers import l1,l2,l1_l2
from tensorflow.keras.models import Model , load_model , Sequential
from tensorflow.keras.utils import plot_model , to_categorical, get_file
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
os.getcwd()
# Out:
# '/content/drive/My Drive/Colab Notebooks/Paper'

# %%
print(tf.__version__)
print(ks.__version__)
# Out:
# 2.3.0
# 2.4.0

# %%
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 7890158313151226532
# , name: "/device:XLA_CPU:0"
# device_type: "XLA_CPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 6056554716587745310
# physical_device_desc: "device: XLA_CPU device"
# , name: "/device:XLA_GPU:0"
# device_type: "XLA_GPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 15919809097703266827
# physical_device_desc: "device: XLA_GPU device"
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 15695549568
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 3293508372398435494
# physical_device_desc: "device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0"
# ]

# %%
# !cat /proc/cpuinfo
# Out:
# processor	: 0
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 63
# model name	: Intel(R) Xeon(R) CPU @ 2.30GHz
# stepping	: 0
# microcode	: 0x1
# cpu MHz		: 2300.000
# cache size	: 46080 KB
# physical id	: 0
# siblings	: 4
# core id		: 0
# cpu cores	: 2
# apicid		: 0
# initial apicid	: 0
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 avx2 smep bmi2 erms invpcid xsaveopt arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs
# bogomips	: 4600.00
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 46 bits physical, 48 bits virtual
# power management:
#
# processor	: 1
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 63
# model name	: Intel(R) Xeon(R) CPU @ 2.30GHz
# stepping	: 0
# microcode	: 0x1
# cpu MHz		: 2300.000
# cache size	: 46080 KB
# physical id	: 0
# siblings	: 4
# core id		: 1
# cpu cores	: 2
# apicid		: 2
# initial apicid	: 2
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 avx2 smep bmi2 erms invpcid xsaveopt arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs
# bogomips	: 4600.00
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 46 bits physical, 48 bits virtual
# power management:
#
# processor	: 2
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 63
# model name	: Intel(R) Xeon(R) CPU @ 2.30GHz
# stepping	: 0
# microcode	: 0x1
# cpu MHz		: 2300.000
# cache size	: 46080 KB
# physical id	: 0
# siblings	: 4
# core id		: 0
# cpu cores	: 2
# apicid		: 1
# initial apicid	: 1
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 avx2 smep bmi2 erms invpcid xsaveopt arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs
# bogomips	: 4600.00
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 46 bits physical, 48 bits virtual
# power management:
#
# processor	: 3
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 63
# model name	: Intel(R) Xeon(R) CPU @ 2.30GHz
# stepping	: 0
# microcode	: 0x1
# cpu MHz		: 2300.000
# cache size	: 46080 KB
# physical id	: 0
# siblings	: 4
# core id		: 1
# cpu cores	: 2
# apicid		: 3
# initial apicid	: 3
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 avx2 smep bmi2 erms invpcid xsaveopt arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs
# bogomips	: 4600.00
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 46 bits physical, 48 bits virtual
# power management:

# %% [markdown]
# ## 1. Data Preprocessing
# ---

# %% [markdown]
# ### 1) Data Import

# %%
# 바꿔서 살펴 볼 것들
# CALTECH, CIFAR100, FER, MIT
data_name = 'CALTECH'
gan_type = 'No_GAN'
number = '1'
size = 299 # sizes after cropping
super_size = 330 # sizes before cropping 
input_sizes = (size,size,3)
batch_sizes = 64
weight_decay = 2e-3
epochs = 70

# %%
# 참고 : https://stackoverflow.com/questions/32419510/how-to-get-reproducible-results-in-keras/52897216#52897216
# setting the seed number for random number generation for reproducibility.

from numpy.random import seed
import random


if number=='1':
    seed_num = 200225
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)
elif number=='2':
    seed_num = 727
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)
elif number=='3':
    seed_num = 115
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)
elif number=='4':
    seed_num = 501
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)
elif number=='5':
    seed_num = 517
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)

# %%
# data import

if data_name=='FER' :
    x_train =  np.zeros(28698)
    x_valid = np.zeros(3589)
    x_test = np.zeros(3588)
    classes = 7 
    tr_center = [0.50793296, 0.50793296, 0.50793296]
elif data_name=='MIT':
    x_train = np.zeros(12466)
    x_valid = np.zeros(1564)
    x_test = np.zeros(1590)
    classes = 67 
    tr_center = [0.47916578, 0.42029615, 0.36046057]
elif data_name=='CALTECH':
    x_train = np.zeros(24510)
    x_valid = np.zeros(2980)
    x_test = np.zeros(3118)
    classes = 257
    tr_center = [0.51397761, 0.49525248, 0.46555727]
elif data_name=='CIFAR100':
    x_train = np.zeros(44923)
    x_valid = np.zeros(5077)
    x_test = np.zeros(10000)
    classes = 100
    tr_center = [0.53442983, 0.51355958, 0.46462564]

# %%
dir = os.path.join(os.getcwd(),data_name,gan_type)

# %% [markdown]
# ### 2) Data Augmentation

# %%
# 참고 : https://jkjung-avt.github.io/keras-image-cropping/

def random_crop(img, random_crop_size):
    # Note: image_data_format is 'channel_last'
    assert img.shape[2] == 3 # img.shape[2] 가 3(rgb)이 아니면 assertion error 발생
    height, width = img.shape[0], img.shape[1]
    dy, dx = random_crop_size
    x = np.random.randint(0, width - dx + 1)
    y = np.random.randint(0, height - dy + 1)
    return img[y:(y+dy), x:(x+dx), :]


def crop_generator(batches, crop_length):
    """Take as input a Keras ImageGen (Iterator) and generate random
    crops from the image batches generated by the original iterator.
    """
    while True:
        batch_x, batch_y = next(batches)
        batch_crops = np.zeros((batch_x.shape[0], crop_length, crop_length, 3))
        for i in range(batch_x.shape[0]):
            batch_crops[i] = random_crop(batch_x[i], (crop_length, crop_length))
        yield (batch_crops, batch_y)

# %%
from tensorflow.keras.preprocessing.image import img_to_array,load_img
import glob

# 데이터 전체에 대해 centering 진행함.

def read_cal_image(img_path): 
    x = img_to_array(load_img(img_path)) # x는 채널별 평균값
    y = x.shape[0] * x.shape[1]# y는 데이터별 픽셀 수 (비중)

    x = 1/255. * x # scaling하고, centering값을 뽑아냄.
    x = np.mean(x, axis=(0,1))
    
    return np.hstack([x,y])

def calculate_centered_mean(dataset_path,x_train=x_train):
    num = len(x_train)
    space = np.empty((num,4))
    i=0

    for p in glob.glob(os.path.join(dataset_path,'*/*.*')) :
        space[i] = read_cal_image(p)
        i += 1

    ratio = space[:,3] / np.sum(space[:,3])

    return np.average(space[:,0:3],axis=0,weights=ratio)


# 아래의 함수를 돌려서 나온 결과값을 중심화 값으로 설정.

# train_mean = calculate_centered_mean(os.path.join(dir,'data/train')).reshape((1,1,3))

# %%
datagen_tr = ImageDataGenerator(
    rescale=1/255.,
    horizontal_flip=True,
    featurewise_center=True,
    featurewise_std_normalization=False,
    rotation_range=10,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=[0.9,1.0],
    fill_mode = 'nearest')
datagen_val = ImageDataGenerator(rescale=1/255.,featurewise_center=True)
datagen_tes = ImageDataGenerator(rescale=1/255.,featurewise_center=True)

# 원래는 이 자리에 fit 매서드를 써야하지만, 그냥 내가 중심화함수를 만들고 적용함. 

# 중심화 설정
datagen_tr.mean = np.array(tr_center, dtype=np.float32).reshape((1,1,3)) # RGB
datagen_val.mean = np.array(tr_center, dtype=np.float32).reshape((1,1,3)) # RGB
datagen_tes.mean = np.array(tr_center, dtype=np.float32).reshape((1,1,3)) # RGB

# %%
# Inception-V2 & V3은 분류기가 2개이므로 imagedatagenerator 사용방법이 다소 다르다.
# model.fit에 다중 input으로 들어갈 함수를 개인이 만들어서 사용해야 하며, 그 함수는 아래와 같다. 
# 매우 간단하다.

#1. train data

def generate_train_for_two(crop_length=size, batch_sizes = batch_sizes, super_size=super_size):

      batches = datagen_tr.flow_from_directory(directory=os.path.join(dir,'data/train'),target_size=(super_size,super_size),batch_size=batch_sizes,class_mode='categorical')

      while True:
          batch_x, batch_y = next(batches)
          batch_crops = np.zeros((batch_x.shape[0], crop_length, crop_length, 3))
          for i in range(batch_x.shape[0]):
              batch_crops[i] = random_crop(batch_x[i], (crop_length, crop_length))
          yield batch_crops, [batch_y,batch_y]

# %%
# 2. valid data

def generate_valid_for_two(size=size, batch_sizes = batch_sizes):

      batches_xy = datagen_val.flow_from_directory(directory=os.path.join(dir,'data/valid'),target_size=(size,size),batch_size=batch_sizes,class_mode='categorical')

      while True:

          batch_xy = batches_xy.next()
          yield  batch_xy[0], [ batch_xy[1],batch_xy[1] ]

# %%
# 3. test data

def generate_test_for_two(size=size, batch_sizes = batch_sizes):

      batches_xy = datagen_tes.flow_from_directory(directory=os.path.join(dir,'data/test'),target_size=(size,size),batch_size=batch_sizes,class_mode='categorical')

      while True:

          batch_xy = batches_xy.next()
          yield  batch_xy[0], [ batch_xy[1],batch_xy[1] ]

# %%
# 위에서 쓰임
# train_batches = datagen_tr.flow_from_directory(directory=os.path.join(dir,'data/train'),target_size=(super_size,super_size),batch_size=batch_sizes,class_mode='categorical') # fer : 28698 / mit : 12466 / caltech : 24509 / cifar : 44923
# train_generator= crop_generator(train_batches, size)

# valid_generator = datagen_val.flow_from_directory(directory=os.path.join(dir,'data/valid'),target_size=(size,size),batch_size=batch_sizes,class_mode='categorical') # fer : 3589 / mit : 1564 / caltech : 2980 / cifar : 5077
# test_generator = datagen_tes.flow_from_directory(directory=os.path.join(dir,'data/test'),target_size=(size,size),batch_size=batch_sizes,class_mode='categorical') # fer : 3588 / mit : 1590 / caltech : 3118 / cifar : 10000

# %% [markdown]
# ## 2. Support Functions & Almost Original Inception-V2,V3 (Especially V3)
# ---

# %% [markdown]
# ### 1) Support Functions

# %%
# def lr_schedule(epoch):
#     init_lr = 1e-4
#     k = 0.04
#     lr = init_lr * np.exp(-k*epoch)
#     print('Learning rate: ', lr)
#     return lr

def lr_schedule(epoch):
    lr = 1e-3
    if epoch < 30:
        lr = lr
    elif epoch < 60 :
        lr = lr * 0.1
    else:
        lr = lr * 0.01
    print('Learning rate: ', lr)
    return lr

# %%
def smoothed_categorical_crossentropy(y_true, y_pred): 
    if smoothing_param > 0:
        smooth_positives = 1.0 - smoothing_param 
        smooth_negatives = smoothing_param / classes 
        y_true = y_true * smooth_positives + smooth_negatives 

    return K.categorical_crossentropy(y_true, y_pred)

# %%
def conv2d_bn(x, filters, kernel_size, weight_decay=weight_decay, padding='same', strides=1, activation='relu'):
    x = Conv2D(filters, (kernel_size[0], kernel_size[1]), padding=padding, strides=strides, kernel_initializer='he_uniform', use_bias=False, kernel_regularizer=l2(weight_decay))(x)    
    x = BatchNormalization()(x)
    
    if activation:
        x = Activation(activation)(x)
    
    return x

# %%
def inception_f3(input_tensor, filter_channels, name=None):
    filter_b1, filter_b2, filter_b3, filter_b4 = filter_channels
    
    branch_1 = conv2d_bn(input_tensor, filter_b1[0], (1, 1))
    branch_1 = conv2d_bn(branch_1, filter_b1[1], (3, 3))
    branch_1 = conv2d_bn(branch_1, filter_b1[2], (3, 3))
    
    branch_2 = conv2d_bn(input_tensor, filter_b2[0], (1, 1))
    branch_2 = conv2d_bn(branch_2, filter_b2[1], (3, 3))
    
    branch_3 = MaxPooling2D((3, 3), strides=1, padding='same')(input_tensor)
    branch_3 = conv2d_bn(branch_3, filter_b3, (1, 1))
    
    branch_4 = conv2d_bn(input_tensor, filter_b4, (1, 1))
    
    filter_concat = Concatenate(name=name)([branch_1, branch_2, branch_3, branch_4]) if not name==None else Concatenate()([branch_1, branch_2, branch_3, branch_4])
    
    return filter_concat

def inception_f6(input_tensor, filter_channels, n=7, name=None):
    filter_b1, filter_b2, filter_b3, filter_b4 = filter_channels
    
    branch_1 = conv2d_bn(input_tensor, filter_b1[0], (1, 1))
    branch_1 = conv2d_bn(branch_1, filter_b1[1], (1, n))
    branch_1 = conv2d_bn(branch_1, filter_b1[2], (n, 1))
    branch_1 = conv2d_bn(branch_1, filter_b1[3], (1, n))
    branch_1 = conv2d_bn(branch_1, filter_b1[4], (n, 1))
    
    branch_2 = conv2d_bn(input_tensor, filter_b2[0], (1, 1))
    branch_2 = conv2d_bn(branch_2, filter_b2[1], (1, n))
    branch_2 = conv2d_bn(branch_2, filter_b2[2], (n, 1))
    
    branch_3 = MaxPooling2D((3, 3), strides=1, padding='same')(input_tensor)
    branch_3 = conv2d_bn(branch_3, filter_b3, (1, 1))
    
    branch_4 = conv2d_bn(input_tensor, filter_b4, (1, 1))
    
    filter_concat = Concatenate(name=name)([branch_1, branch_2, branch_3, branch_4]) if not name==None else Concatenate()([branch_1, branch_2, branch_3, branch_4])
    
    return filter_concat

def inception_f10(input_tensor, filter_channels, name=None):
    filter_b1, filter_b2, filter_b3, filter_b4 = filter_channels
    
    branch_1 = conv2d_bn(input_tensor, filter_b1[0], (1, 1))
    branch_1 = conv2d_bn(branch_1, filter_b1[1], (3, 3))
    branch_1a = conv2d_bn(branch_1, filter_b1[2][0], (1, 3))
    branch_1b = conv2d_bn(branch_1, filter_b1[2][1], (3, 1))
    branch_1 = Concatenate()([branch_1a, branch_1b])
    
    branch_2 = conv2d_bn(input_tensor, filter_b2[0], (1, 1))
    branch_2a = conv2d_bn(branch_2, filter_b2[1][0], (1, 3))
    branch_2b = conv2d_bn(branch_2, filter_b2[1][1], (3, 1))
    branch_2 = Concatenate()([branch_2a, branch_2b])
    
    branch_3 = MaxPooling2D((3, 3), strides=1, padding='same')(input_tensor)
    branch_3 = conv2d_bn(branch_3, filter_b3, (1, 1))
    
    branch_4 = conv2d_bn(input_tensor, filter_b4, (1, 1))
    
    filter_concat = Concatenate(name=name)([branch_1, branch_2, branch_3, branch_4]) if not name==None else Concatenate()([branch_1, branch_2, branch_3, branch_4])
    
    return filter_concat
    
def inception_dim_reduction(input_tensor, filter_channels, name=None):
    filter_b1, filter_b2 = filter_channels
    
    branch_1 = conv2d_bn(input_tensor, filter_b1[0], (1, 1))
    branch_1 = conv2d_bn(branch_1, filter_b1[1], (3, 3))
    branch_1 = conv2d_bn(branch_1, filter_b1[2], (3, 3), strides=2)
    
    branch_2 = conv2d_bn(input_tensor, filter_b2[0], (1, 1))
    branch_2 = conv2d_bn(branch_2, filter_b2[1], (3, 3), strides=2)
    
    branch_3 = MaxPooling2D((3, 3), strides=2, padding='same')(input_tensor)
    
    filter_concat = Concatenate(name=name)([branch_1, branch_2, branch_3]) if not name==None else Concatenate()([branch_1, branch_2, branch_3])
    
    return filter_concat

# %% [markdown]
# ### 2) Almost Original Inception-V2,V3 (Especially V3)

# %%
def Inception_v3(model_input, name, weight_decay= weight_decay):
    x = conv2d_bn(model_input, 32, (3, 3), padding='valid', strides=2) # (299, 299, 3) -> (149, 149, 32)
    x = conv2d_bn(x, 32, (3, 3), padding='valid') # (147, 147, 32) -> (147, 147, 32)
    x = conv2d_bn(x, 64, (3, 3), padding='same') # (147, 147, 32) -> (147, 147, 64)
    
    x = MaxPooling2D((3, 3), strides=2, padding='valid')(x) # (147, 147, 64) -> (73, 73, 64)
    
    x = conv2d_bn(x, 80, (3, 3), padding='valid') # (73, 73, 64) -> (71, 71, 80)
    x = conv2d_bn(x, 192, (3, 3), padding='valid', strides=2) # (71, 71, 80) -> (35, 35, 192)
    x = conv2d_bn(x, 288, (3, 3), padding='same') # (35, 35, 192) -> (35, 35, 288)
    
    x = inception_f3(x, [[64, 96, 96], [48, 64], 64 , 64]) # (35, 35, 288)
    x = inception_f3(x, [[64, 96, 96], [48, 64], 64 , 64]) # (35, 35, 288)
    x = inception_f3(x, [[64, 96, 96], [48, 64], 64 , 64], name='block_inception_f3') # (35, 35, 288)
    
    x = inception_dim_reduction(x, [[64, 96, 96], [256, 384]], name='block_reduction_1') # (35, 35, 288) -> (17, 17, 768)
    
    x = inception_f6(x, [[128, 128, 128, 128, 192], [128, 128, 192], 192, 192]) # (17, 17, 768)
    x = inception_f6(x, [[160, 160, 160, 160, 192], [160, 160, 192], 192, 192]) # (17, 17, 768)
    x = inception_f6(x, [[160, 160, 160, 160, 192], [160, 160, 192], 192, 192]) # (17, 17, 768)
    x = inception_f6(x, [[192, 192, 192, 192, 192], [192, 192, 192], 192, 192]) # (17, 17, 768)
    x_a = inception_f6(x, [[192, 192, 192, 192, 192], [192, 192, 192], 192, 192], name='block_inception_f6') # (17, 17, 768)
    
    x = inception_dim_reduction(x_a, [[128, 192, 192], [192, 320]], name='block_reduction_2') # (17, 17, 768) -> (8, 8, 1280)
    
    x = inception_f10(x, [[448, 384, [384, 384]], [384, [384, 384]], 192, 320]) # (8, 8, 1280) -> (8, 8, 2048)
    x = inception_f10(x, [[448, 384, [384, 384]], [384, [384, 384]], 192, 320], name='block_inception_f10') # (8, 8, 2048)
    
    x = GlobalAveragePooling2D()(x)
    x = Dropout(0.2)(x)
    
    x = Dense(classes, use_bias=False, kernel_regularizer=l2(weight_decay), activation=None)(x)
    
    model_output = Dense(classes, activation='softmax', name='main_classifier')(x) # 'softmax'
    
    # Auxiliary Classifier
    auxiliary = AveragePooling2D((5, 5), strides=3, padding='valid')(x_a) # (17, 17, 768) -> (5, 5, 768)
    auxiliary = conv2d_bn(auxiliary, 128, (1, 1)) # (5, 5, 768) -> (5, 5, 128)
    
    auxiliary = conv2d_bn(auxiliary, 1024, K.int_shape(auxiliary)[1:3], padding='valid') # (5, 5, 768) -> (1, 1, 1024)
    auxiliary = Flatten()(auxiliary) # (1, 1, 1024)
    auxiliary_output = Dense(classes, use_bias=False, kernel_regularizer=l2(weight_decay), activation='softmax', name='auxiliary_classifier')(auxiliary)
    
    model = Model(model_input, [model_output, auxiliary_output],name=name)
    
    return model

# %%
smoothing_param = 0.1
model_input = Input(shape=input_sizes)
model = Inception_v3(model_input, weight_decay = weight_decay, name = "Inception_v3")

# %%
model.summary()
# Out:
# Model: "Inception_v3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 299, 299, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 149, 149, 32) 864         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 149, 149, 32) 128         conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 149, 149, 32) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 147, 147, 32) 9216        activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 147, 147, 32) 128         conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 147, 147, 32) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 147, 147, 64) 18432       activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 147, 147, 64) 256         conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 147, 147, 64) 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 73, 73, 64)   0           activation_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 71, 71, 80)   46080       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 71, 71, 80)   320         conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 71, 71, 80)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 35, 35, 192)  138240      activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 35, 35, 192)  768         conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 35, 35, 192)  0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 35, 35, 288)  497664      activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 35, 35, 288)  1152        conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 35, 35, 288)  0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 35, 35, 64)   18432       activation_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 35, 35, 64)   256         conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 35, 35, 64)   0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 35, 35, 96)   55296       activation_6[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 35, 35, 48)   13824       activation_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 35, 35, 96)   384         conv2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 35, 35, 48)   192         conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 35, 35, 96)   0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 35, 35, 48)   0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 35, 35, 288)  0           activation_5[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 35, 35, 96)   82944       activation_7[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 35, 35, 64)   27648       activation_9[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 35, 35, 64)   18432       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 35, 35, 64)   18432       activation_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 35, 35, 96)   384         conv2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 35, 35, 64)   256         conv2d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 35, 35, 64)   256         conv2d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 35, 35, 64)   256         conv2d_12[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 35, 35, 96)   0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 35, 35, 64)   0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 35, 35, 64)   0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 35, 35, 64)   0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 35, 35, 288)  0           activation_8[0][0]
#                                                                  activation_10[0][0]
#                                                                  activation_11[0][0]
#                                                                  activation_12[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 35, 35, 64)   18432       concatenate[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 35, 35, 64)   256         conv2d_13[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 35, 35, 64)   0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 35, 35, 96)   55296       activation_13[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 35, 35, 48)   13824       concatenate[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 35, 35, 96)   384         conv2d_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 35, 35, 48)   192         conv2d_16[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 35, 35, 96)   0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 35, 35, 48)   0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 35, 35, 288)  0           concatenate[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 35, 35, 96)   82944       activation_14[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 35, 35, 64)   27648       activation_16[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 35, 35, 64)   18432       max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 35, 35, 64)   18432       concatenate[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 35, 35, 96)   384         conv2d_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 35, 35, 64)   256         conv2d_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 35, 35, 64)   256         conv2d_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 35, 35, 64)   256         conv2d_19[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 35, 35, 96)   0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 35, 35, 64)   0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 35, 35, 64)   0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 35, 35, 64)   0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 35, 35, 288)  0           activation_15[0][0]
#                                                                  activation_17[0][0]
#                                                                  activation_18[0][0]
#                                                                  activation_19[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 35, 35, 64)   18432       concatenate_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 35, 35, 64)   256         conv2d_20[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 35, 35, 64)   0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 35, 35, 96)   55296       activation_20[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 35, 35, 48)   13824       concatenate_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 35, 35, 96)   384         conv2d_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 35, 35, 48)   192         conv2d_23[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 35, 35, 96)   0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 35, 35, 48)   0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 35, 35, 288)  0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 35, 35, 96)   82944       activation_21[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 35, 35, 64)   27648       activation_23[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 35, 35, 64)   18432       max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 35, 35, 64)   18432       concatenate_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 35, 35, 96)   384         conv2d_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 35, 35, 64)   256         conv2d_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 35, 35, 64)   256         conv2d_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 35, 35, 64)   256         conv2d_26[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 35, 35, 96)   0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 35, 35, 64)   0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 35, 35, 64)   0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 35, 35, 64)   0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# block_inception_f3 (Concatenate (None, 35, 35, 288)  0           activation_22[0][0]
#                                                                  activation_24[0][0]
#                                                                  activation_25[0][0]
#                                                                  activation_26[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 35, 35, 64)   18432       block_inception_f3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 35, 35, 64)   256         conv2d_27[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 35, 35, 64)   0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 35, 35, 96)   55296       activation_27[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 35, 35, 256)  73728       block_inception_f3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 35, 35, 96)   384         conv2d_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 35, 35, 256)  1024        conv2d_30[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 35, 35, 96)   0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 35, 35, 256)  0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 18, 18, 96)   82944       activation_28[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 18, 18, 384)  884736      activation_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 18, 18, 96)   384         conv2d_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 18, 18, 384)  1536        conv2d_31[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 18, 18, 96)   0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 18, 18, 384)  0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 18, 18, 288)  0           block_inception_f3[0][0]
# __________________________________________________________________________________________________
# block_reduction_1 (Concatenate) (None, 18, 18, 768)  0           activation_29[0][0]
#                                                                  activation_31[0][0]
#                                                                  max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 18, 18, 128)  98304       block_reduction_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 18, 18, 128)  512         conv2d_32[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 18, 18, 128)  0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 18, 18, 128)  114688      activation_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 18, 18, 128)  512         conv2d_33[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 18, 18, 128)  0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 18, 18, 128)  114688      activation_33[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 18, 18, 128)  98304       block_reduction_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 18, 18, 128)  512         conv2d_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 18, 18, 128)  512         conv2d_37[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 18, 18, 128)  0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 18, 18, 128)  0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 18, 18, 128)  114688      activation_34[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 18, 18, 128)  114688      activation_37[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 18, 18, 128)  512         conv2d_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 18, 18, 128)  512         conv2d_38[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 18, 18, 128)  0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 18, 18, 128)  0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 18, 18, 768)  0           block_reduction_1[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 18, 18, 192)  172032      activation_35[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 18, 18, 192)  172032      activation_38[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 18, 18, 192)  147456      max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 18, 18, 192)  147456      block_reduction_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 18, 18, 192)  768         conv2d_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 18, 18, 192)  768         conv2d_39[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 18, 18, 192)  768         conv2d_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 18, 18, 192)  768         conv2d_41[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 18, 18, 192)  0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 18, 18, 192)  0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 18, 18, 192)  0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 18, 18, 192)  0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 18, 18, 768)  0           activation_36[0][0]
#                                                                  activation_39[0][0]
#                                                                  activation_40[0][0]
#                                                                  activation_41[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 18, 18, 160)  122880      concatenate_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 18, 18, 160)  640         conv2d_42[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 18, 18, 160)  0           batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 18, 18, 160)  179200      activation_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 18, 18, 160)  640         conv2d_43[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 18, 18, 160)  0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 18, 18, 160)  179200      activation_43[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 18, 18, 160)  122880      concatenate_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 18, 18, 160)  640         conv2d_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 18, 18, 160)  640         conv2d_47[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 18, 18, 160)  0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 18, 18, 160)  0           batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 18, 18, 160)  179200      activation_44[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 18, 18, 160)  179200      activation_47[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 18, 18, 160)  640         conv2d_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 18, 18, 160)  640         conv2d_48[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 18, 18, 160)  0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 18, 18, 160)  0           batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)  (None, 18, 18, 768)  0           concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 18, 18, 192)  215040      activation_45[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 18, 18, 192)  215040      activation_48[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 18, 18, 192)  147456      max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 18, 18, 192)  147456      concatenate_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 18, 18, 192)  768         conv2d_46[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 18, 18, 192)  768         conv2d_49[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 18, 18, 192)  768         conv2d_50[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 18, 18, 192)  768         conv2d_51[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 18, 18, 192)  0           batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 18, 18, 192)  0           batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, 18, 18, 192)  0           batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# activation_51 (Activation)      (None, 18, 18, 192)  0           batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 18, 18, 768)  0           activation_46[0][0]
#                                                                  activation_49[0][0]
#                                                                  activation_50[0][0]
#                                                                  activation_51[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 18, 18, 160)  122880      concatenate_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 18, 18, 160)  640         conv2d_52[0][0]
# __________________________________________________________________________________________________
# activation_52 (Activation)      (None, 18, 18, 160)  0           batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 18, 18, 160)  179200      activation_52[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, 18, 18, 160)  640         conv2d_53[0][0]
# __________________________________________________________________________________________________
# activation_53 (Activation)      (None, 18, 18, 160)  0           batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 18, 18, 160)  179200      activation_53[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 18, 18, 160)  122880      concatenate_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, 18, 18, 160)  640         conv2d_54[0][0]
# __________________________________________________________________________________________________
# batch_normalization_57 (BatchNo (None, 18, 18, 160)  640         conv2d_57[0][0]
# __________________________________________________________________________________________________
# activation_54 (Activation)      (None, 18, 18, 160)  0           batch_normalization_54[0][0]
# __________________________________________________________________________________________________
# activation_57 (Activation)      (None, 18, 18, 160)  0           batch_normalization_57[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 18, 18, 160)  179200      activation_54[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, 18, 18, 160)  179200      activation_57[0][0]
# __________________________________________________________________________________________________
# batch_normalization_55 (BatchNo (None, 18, 18, 160)  640         conv2d_55[0][0]
# __________________________________________________________________________________________________
# batch_normalization_58 (BatchNo (None, 18, 18, 160)  640         conv2d_58[0][0]
# __________________________________________________________________________________________________
# activation_55 (Activation)      (None, 18, 18, 160)  0           batch_normalization_55[0][0]
# __________________________________________________________________________________________________
# activation_58 (Activation)      (None, 18, 18, 160)  0           batch_normalization_58[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_7 (MaxPooling2D)  (None, 18, 18, 768)  0           concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 18, 18, 192)  215040      activation_55[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, 18, 18, 192)  215040      activation_58[0][0]
# __________________________________________________________________________________________________
# conv2d_60 (Conv2D)              (None, 18, 18, 192)  147456      max_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_61 (Conv2D)              (None, 18, 18, 192)  147456      concatenate_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_56 (BatchNo (None, 18, 18, 192)  768         conv2d_56[0][0]
# __________________________________________________________________________________________________
# batch_normalization_59 (BatchNo (None, 18, 18, 192)  768         conv2d_59[0][0]
# __________________________________________________________________________________________________
# batch_normalization_60 (BatchNo (None, 18, 18, 192)  768         conv2d_60[0][0]
# __________________________________________________________________________________________________
# batch_normalization_61 (BatchNo (None, 18, 18, 192)  768         conv2d_61[0][0]
# __________________________________________________________________________________________________
# activation_56 (Activation)      (None, 18, 18, 192)  0           batch_normalization_56[0][0]
# __________________________________________________________________________________________________
# activation_59 (Activation)      (None, 18, 18, 192)  0           batch_normalization_59[0][0]
# __________________________________________________________________________________________________
# activation_60 (Activation)      (None, 18, 18, 192)  0           batch_normalization_60[0][0]
# __________________________________________________________________________________________________
# activation_61 (Activation)      (None, 18, 18, 192)  0           batch_normalization_61[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 18, 18, 768)  0           activation_56[0][0]
#                                                                  activation_59[0][0]
#                                                                  activation_60[0][0]
#                                                                  activation_61[0][0]
# __________________________________________________________________________________________________
# conv2d_62 (Conv2D)              (None, 18, 18, 192)  147456      concatenate_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_62 (BatchNo (None, 18, 18, 192)  768         conv2d_62[0][0]
# __________________________________________________________________________________________________
# activation_62 (Activation)      (None, 18, 18, 192)  0           batch_normalization_62[0][0]
# __________________________________________________________________________________________________
# conv2d_63 (Conv2D)              (None, 18, 18, 192)  258048      activation_62[0][0]
# __________________________________________________________________________________________________
# batch_normalization_63 (BatchNo (None, 18, 18, 192)  768         conv2d_63[0][0]
# __________________________________________________________________________________________________
# activation_63 (Activation)      (None, 18, 18, 192)  0           batch_normalization_63[0][0]
# __________________________________________________________________________________________________
# conv2d_64 (Conv2D)              (None, 18, 18, 192)  258048      activation_63[0][0]
# __________________________________________________________________________________________________
# conv2d_67 (Conv2D)              (None, 18, 18, 192)  147456      concatenate_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_64 (BatchNo (None, 18, 18, 192)  768         conv2d_64[0][0]
# __________________________________________________________________________________________________
# batch_normalization_67 (BatchNo (None, 18, 18, 192)  768         conv2d_67[0][0]
# __________________________________________________________________________________________________
# activation_64 (Activation)      (None, 18, 18, 192)  0           batch_normalization_64[0][0]
# __________________________________________________________________________________________________
# activation_67 (Activation)      (None, 18, 18, 192)  0           batch_normalization_67[0][0]
# __________________________________________________________________________________________________
# conv2d_65 (Conv2D)              (None, 18, 18, 192)  258048      activation_64[0][0]
# __________________________________________________________________________________________________
# conv2d_68 (Conv2D)              (None, 18, 18, 192)  258048      activation_67[0][0]
# __________________________________________________________________________________________________
# batch_normalization_65 (BatchNo (None, 18, 18, 192)  768         conv2d_65[0][0]
# __________________________________________________________________________________________________
# batch_normalization_68 (BatchNo (None, 18, 18, 192)  768         conv2d_68[0][0]
# __________________________________________________________________________________________________
# activation_65 (Activation)      (None, 18, 18, 192)  0           batch_normalization_65[0][0]
# __________________________________________________________________________________________________
# activation_68 (Activation)      (None, 18, 18, 192)  0           batch_normalization_68[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_8 (MaxPooling2D)  (None, 18, 18, 768)  0           concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv2d_66 (Conv2D)              (None, 18, 18, 192)  258048      activation_65[0][0]
# __________________________________________________________________________________________________
# conv2d_69 (Conv2D)              (None, 18, 18, 192)  258048      activation_68[0][0]
# __________________________________________________________________________________________________
# conv2d_70 (Conv2D)              (None, 18, 18, 192)  147456      max_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_71 (Conv2D)              (None, 18, 18, 192)  147456      concatenate_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_66 (BatchNo (None, 18, 18, 192)  768         conv2d_66[0][0]
# __________________________________________________________________________________________________
# batch_normalization_69 (BatchNo (None, 18, 18, 192)  768         conv2d_69[0][0]
# __________________________________________________________________________________________________
# batch_normalization_70 (BatchNo (None, 18, 18, 192)  768         conv2d_70[0][0]
# __________________________________________________________________________________________________
# batch_normalization_71 (BatchNo (None, 18, 18, 192)  768         conv2d_71[0][0]
# __________________________________________________________________________________________________
# activation_66 (Activation)      (None, 18, 18, 192)  0           batch_normalization_66[0][0]
# __________________________________________________________________________________________________
# activation_69 (Activation)      (None, 18, 18, 192)  0           batch_normalization_69[0][0]
# ...
# __________________________________________________________________________________________________
# batch_normalization_87 (BatchNo (None, 9, 9, 448)    1792        conv2d_87[0][0]
# __________________________________________________________________________________________________
# activation_87 (Activation)      (None, 9, 9, 448)    0           batch_normalization_87[0][0]
# __________________________________________________________________________________________________
# conv2d_88 (Conv2D)              (None, 9, 9, 384)    1548288     activation_87[0][0]
# __________________________________________________________________________________________________
# conv2d_91 (Conv2D)              (None, 9, 9, 384)    491520      block_reduction_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_88 (BatchNo (None, 9, 9, 384)    1536        conv2d_88[0][0]
# __________________________________________________________________________________________________
# batch_normalization_91 (BatchNo (None, 9, 9, 384)    1536        conv2d_91[0][0]
# __________________________________________________________________________________________________
# activation_88 (Activation)      (None, 9, 9, 384)    0           batch_normalization_88[0][0]
# __________________________________________________________________________________________________
# activation_91 (Activation)      (None, 9, 9, 384)    0           batch_normalization_91[0][0]
# __________________________________________________________________________________________________
# conv2d_89 (Conv2D)              (None, 9, 9, 384)    442368      activation_88[0][0]
# __________________________________________________________________________________________________
# conv2d_90 (Conv2D)              (None, 9, 9, 384)    442368      activation_88[0][0]
# __________________________________________________________________________________________________
# conv2d_92 (Conv2D)              (None, 9, 9, 384)    442368      activation_91[0][0]
# __________________________________________________________________________________________________
# conv2d_93 (Conv2D)              (None, 9, 9, 384)    442368      activation_91[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_11 (MaxPooling2D) (None, 9, 9, 1280)   0           block_reduction_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_89 (BatchNo (None, 9, 9, 384)    1536        conv2d_89[0][0]
# __________________________________________________________________________________________________
# batch_normalization_90 (BatchNo (None, 9, 9, 384)    1536        conv2d_90[0][0]
# __________________________________________________________________________________________________
# batch_normalization_92 (BatchNo (None, 9, 9, 384)    1536        conv2d_92[0][0]
# __________________________________________________________________________________________________
# batch_normalization_93 (BatchNo (None, 9, 9, 384)    1536        conv2d_93[0][0]
# __________________________________________________________________________________________________
# conv2d_94 (Conv2D)              (None, 9, 9, 192)    245760      max_pooling2d_11[0][0]
# __________________________________________________________________________________________________
# conv2d_95 (Conv2D)              (None, 9, 9, 320)    409600      block_reduction_2[0][0]
# __________________________________________________________________________________________________
# activation_89 (Activation)      (None, 9, 9, 384)    0           batch_normalization_89[0][0]
# __________________________________________________________________________________________________
# activation_90 (Activation)      (None, 9, 9, 384)    0           batch_normalization_90[0][0]
# __________________________________________________________________________________________________
# activation_92 (Activation)      (None, 9, 9, 384)    0           batch_normalization_92[0][0]
# __________________________________________________________________________________________________
# activation_93 (Activation)      (None, 9, 9, 384)    0           batch_normalization_93[0][0]
# __________________________________________________________________________________________________
# batch_normalization_94 (BatchNo (None, 9, 9, 192)    768         conv2d_94[0][0]
# __________________________________________________________________________________________________
# batch_normalization_95 (BatchNo (None, 9, 9, 320)    1280        conv2d_95[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 9, 9, 768)    0           activation_89[0][0]
#                                                                  activation_90[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 9, 9, 768)    0           activation_92[0][0]
#                                                                  activation_93[0][0]
# __________________________________________________________________________________________________
# activation_94 (Activation)      (None, 9, 9, 192)    0           batch_normalization_94[0][0]
# __________________________________________________________________________________________________
# activation_95 (Activation)      (None, 9, 9, 320)    0           batch_normalization_95[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 9, 9, 2048)   0           concatenate_6[0][0]
#                                                                  concatenate_7[0][0]
#                                                                  activation_94[0][0]
#                                                                  activation_95[0][0]
# __________________________________________________________________________________________________
# conv2d_96 (Conv2D)              (None, 9, 9, 448)    917504      concatenate_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_96 (BatchNo (None, 9, 9, 448)    1792        conv2d_96[0][0]
# __________________________________________________________________________________________________
# activation_96 (Activation)      (None, 9, 9, 448)    0           batch_normalization_96[0][0]
# __________________________________________________________________________________________________
# conv2d_97 (Conv2D)              (None, 9, 9, 384)    1548288     activation_96[0][0]
# __________________________________________________________________________________________________
# conv2d_100 (Conv2D)             (None, 9, 9, 384)    786432      concatenate_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_97 (BatchNo (None, 9, 9, 384)    1536        conv2d_97[0][0]
# __________________________________________________________________________________________________
# batch_normalization_100 (BatchN (None, 9, 9, 384)    1536        conv2d_100[0][0]
# __________________________________________________________________________________________________
# activation_97 (Activation)      (None, 9, 9, 384)    0           batch_normalization_97[0][0]
# __________________________________________________________________________________________________
# activation_100 (Activation)     (None, 9, 9, 384)    0           batch_normalization_100[0][0]
# __________________________________________________________________________________________________
# conv2d_98 (Conv2D)              (None, 9, 9, 384)    442368      activation_97[0][0]
# __________________________________________________________________________________________________
# conv2d_99 (Conv2D)              (None, 9, 9, 384)    442368      activation_97[0][0]
# __________________________________________________________________________________________________
# conv2d_101 (Conv2D)             (None, 9, 9, 384)    442368      activation_100[0][0]
# __________________________________________________________________________________________________
# conv2d_102 (Conv2D)             (None, 9, 9, 384)    442368      activation_100[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_12 (MaxPooling2D) (None, 9, 9, 2048)   0           concatenate_8[0][0]
# __________________________________________________________________________________________________
# average_pooling2d (AveragePooli (None, 5, 5, 768)    0           block_inception_f6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_98 (BatchNo (None, 9, 9, 384)    1536        conv2d_98[0][0]
# __________________________________________________________________________________________________
# batch_normalization_99 (BatchNo (None, 9, 9, 384)    1536        conv2d_99[0][0]
# __________________________________________________________________________________________________
# batch_normalization_101 (BatchN (None, 9, 9, 384)    1536        conv2d_101[0][0]
# __________________________________________________________________________________________________
# batch_normalization_102 (BatchN (None, 9, 9, 384)    1536        conv2d_102[0][0]
# __________________________________________________________________________________________________
# conv2d_103 (Conv2D)             (None, 9, 9, 192)    393216      max_pooling2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_104 (Conv2D)             (None, 9, 9, 320)    655360      concatenate_8[0][0]
# __________________________________________________________________________________________________
# conv2d_105 (Conv2D)             (None, 5, 5, 128)    98304       average_pooling2d[0][0]
# __________________________________________________________________________________________________
# activation_98 (Activation)      (None, 9, 9, 384)    0           batch_normalization_98[0][0]
# __________________________________________________________________________________________________
# activation_99 (Activation)      (None, 9, 9, 384)    0           batch_normalization_99[0][0]
# __________________________________________________________________________________________________
# activation_101 (Activation)     (None, 9, 9, 384)    0           batch_normalization_101[0][0]
# __________________________________________________________________________________________________
# activation_102 (Activation)     (None, 9, 9, 384)    0           batch_normalization_102[0][0]
# __________________________________________________________________________________________________
# batch_normalization_103 (BatchN (None, 9, 9, 192)    768         conv2d_103[0][0]
# __________________________________________________________________________________________________
# batch_normalization_104 (BatchN (None, 9, 9, 320)    1280        conv2d_104[0][0]
# __________________________________________________________________________________________________
# batch_normalization_105 (BatchN (None, 5, 5, 128)    512         conv2d_105[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 9, 9, 768)    0           activation_98[0][0]
#                                                                  activation_99[0][0]
# __________________________________________________________________________________________________
# concatenate_10 (Concatenate)    (None, 9, 9, 768)    0           activation_101[0][0]
#                                                                  activation_102[0][0]
# __________________________________________________________________________________________________
# activation_103 (Activation)     (None, 9, 9, 192)    0           batch_normalization_103[0][0]
# __________________________________________________________________________________________________
# activation_104 (Activation)     (None, 9, 9, 320)    0           batch_normalization_104[0][0]
# __________________________________________________________________________________________________
# activation_105 (Activation)     (None, 5, 5, 128)    0           batch_normalization_105[0][0]
# __________________________________________________________________________________________________
# block_inception_f10 (Concatenat (None, 9, 9, 2048)   0           concatenate_9[0][0]
#                                                                  concatenate_10[0][0]
#                                                                  activation_103[0][0]
#                                                                  activation_104[0][0]
# __________________________________________________________________________________________________
# conv2d_106 (Conv2D)             (None, 1, 1, 1024)   3276800     activation_105[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 2048)         0           block_inception_f10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_106 (BatchN (None, 1, 1, 1024)   4096        conv2d_106[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 2048)         0           global_average_pooling2d[0][0]
# __________________________________________________________________________________________________
# activation_106 (Activation)     (None, 1, 1, 1024)   0           batch_normalization_106[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 257)          526336      dropout[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 1024)         0           activation_106[0][0]
# __________________________________________________________________________________________________
# main_classifier (Dense)         (None, 257)          66306       dense[0][0]
# __________________________________________________________________________________________________
# auxiliary_classifier (Dense)    (None, 257)          263168      flatten[0][0]
# ==================================================================================================
# Total params: 28,249,698
# Trainable params: 28,208,482
# Non-trainable params: 41,216
# __________________________________________________________________________________________________

# %%
# 폴더 생성

os.makedirs(os.path.join(dir,'model_output',number,model.name), exist_ok=True)
os.makedirs(os.path.join(dir,'train_valid_output',number), exist_ok=True)

# %%
# 참고 : https://github.com/OverLordGoldDragon/keras-adamw

import sys
sys.path.append('/content/drive/My Drive/Colab Notebooks/Paper')
import utils
import optimizers_v2
from utils import get_weight_decays, fill_dict_in_order
from utils import reset_seeds, K_eval
from optimizers_v2 import AdamW, NadamW, SGDW

# %%
# top-5 accuracy 출력
import functools
top5_acc = functools.partial(ks.metrics.top_k_categorical_accuracy, k=5)
top5_acc.__name__ = 'top5_acc'

# %%
#optimizer = SGDW(model=model, use_cosine_annealing=False, total_iterations = len(x_train) // batch_sizes, nesterov=True, momentum=0.9)
optimizer = AdamW(model=model, use_cosine_annealing=False, total_iterations = len(x_train) // batch_sizes)
#optimizer = Adam()
filepath =  os.path.join(dir,'model_output',number,model.name,'{epoch:03d}.h5')

callbacks_list = [ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_weights_only=False, save_best_only=True, mode='min'),
                  ModelCheckpoint(filepath, monitor='val_main_classifier_accuracy', verbose=1, save_weights_only=False, save_best_only=True, mode='max'),
                  #ReduceLROnPlateau(monitor='val_loss',patience=3,factor=0.1,min_lr=1e-5),
                  LearningRateScheduler(lr_schedule,verbose=1)
                  ]

model.compile(optimizer, loss={'main_classifier' : smoothed_categorical_crossentropy, 'auxiliary_classifier' : smoothed_categorical_crossentropy},
                loss_weights={'main_classifier' : 1.0, 'auxiliary_classifier' : 0.4}, metrics=['accuracy',top5_acc,macro_f1score])

# %%
######## flow_from_directory
#history = model.fit_generator(generate_train_for_three(), steps_per_epoch=int(len(x_train)/batch_sizes),  validation_data = generate_valid_for_three(), epochs=epochs , verbose=1 , callbacks = callbacks_list,validation_steps=int(len(x_valid)/batch_sizes))
history = model.fit(generate_train_for_two(), steps_per_epoch=int(len(x_train)/batch_sizes),  validation_data = generate_valid_for_two(), epochs=epochs , verbose=1 , callbacks = callbacks_list , validation_steps=int(len(x_valid)/batch_sizes))
# Out:
# Found 24509 images belonging to 257 classes.
# Learning rate:  0.001
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 1/70
# 0.0(L1), 0.00010232890687969222(L2) weight decay set for conv2d/kernel:0
# 0.0(L1), 0.00010232890687969222(L2) weight decay set for conv2d_1/kernel:0
# 0.0(L1), 0.00010232890687969222(L2) weight decay set for conv2d_2/kernel:0
# 0.0(L1), 0.00010232890687969222(L2) weight decay set for conv2d_3/kernel:0
# 0.0(L1), 0.00010232890687969222(L2) weight decay set for conv2d_4/kernel:0
# 0.0(L1), 0.00010232890687969222(L2) weight decay set for conv2d_5/kernel:0
# 0.0(L1), 0.00010232890687969222(L2) weight decay set for conv2d_6/kernel:0
# 0.0(L1), 0.00010232890687969222(L2) weight decay set for conv2d_7/kernel:0
# 0.0(L1), 0.00010232890687969222(L2) weight decay set for conv2d_9/kernel:0
# 0.0(L1), 0.00010232890687969222(L2) weight decay set for conv2d_8/kernel:0
# 0.0(L1), 0.00010232890687969222(L2) weight decay set for conv2d_10/kernel:0
# 0.0(L1), 0.00010232890687969222(L2) weight decay set for conv2d_11/kernel:0
# 0.0(L1), 0.00010232890687969222(L2) weight decay set for conv2d_12/kernel:0
# 0.0(L1), 0.00010232890687969222(L2) weight decay set for conv2d_13/kernel:0
# 0.0(L1), 0.00010232890687969222(L2) weight decay set for conv2d_14/kernel:0
# 0.0(L1), 0.00010232890687969222(L2) weight decay set for conv2d_16/kernel:0
# 0.0(L1), 0.00010232890687969222(L2) weight decay set for conv2d_15/kernel:0
# 0.0(L1), 0.00010232890687969222(L2) weight decay set for conv2d_17/kernel:0
# 0.0(L1), 0.00010232890687969222(L2) weight decay set for conv2d_18/kernel:0
# 0.0(L1), 0.00010232890687969222(L2) weight decay set for conv2d_19/kernel:0
# 0.0(L1), 0.00010232890687969222(L2) weight decay set for conv2d_20/kernel:0
# 0.0(L1), 0.00010232890687969222(L2) weight decay set for conv2d_21/kernel:0
# 0.0(L1), 0.00010232890687969222(L2) weight decay set for conv2d_23/kernel:0
# 0.0(L1), 0.00010232890687969222(L2) weight decay set for conv2d_22/kernel:0
# 0.0(L1), 0.00010232890687969222(L2) weight decay set for conv2d_24/kernel:0
# 0.0(L1), 0.00010232890687969222(L2) weight decay set for conv2d_25/kernel:0
# 0.0(L1), 0.00010232890687969222(L2) weight decay set for conv2d_26/kernel:0
# 0.0(L1), 0.00010232890687969222(L2) weight decay set for conv2d_27/kernel:0
# 0.0(L1), 0.00010232890687969222(L2) weight decay set for conv2d_28/kernel:0
# 0.0(L1), 0.00010232890687969222(L2) weight decay set for conv2d_30/kernel:0
# 0.0(L1), 0.00010232890687969222(L2) weight decay set for conv2d_29/kernel:0
# 0.0(L1), 0.00010232890687969222(L2) weight decay set for conv2d_31/kernel:0
# 0.0(L1), 0.00010232890687969222(L2) weight decay set for conv2d_32/kernel:0
# 0.0(L1), 0.00010232890687969222(L2) weight decay set for conv2d_33/kernel:0
# 0.0(L1), 0.00010232890687969222(L2) weight decay set for conv2d_34/kernel:0
# 0.0(L1), 0.00010232890687969222(L2) weight decay set for conv2d_37/kernel:0
# 0.0(L1), 0.00010232890687969222(L2) weight decay set for conv2d_35/kernel:0
# 0.0(L1), 0.00010232890687969222(L2) weight decay set for conv2d_38/kernel:0
# 0.0(L1), 0.00010232890687969222(L2) weight decay set for conv2d_36/kernel:0
# 0.0(L1), 0.00010232890687969222(L2) weight decay set for conv2d_39/kernel:0
# 0.0(L1), 0.00010232890687969222(L2) weight decay set for conv2d_40/kernel:0
# 0.0(L1), 0.00010232890687969222(L2) weight decay set for conv2d_41/kernel:0
# 0.0(L1), 0.00010232890687969222(L2) weight decay set for conv2d_42/kernel:0
# 0.0(L1), 0.00010232890687969222(L2) weight decay set for conv2d_43/kernel:0
# 0.0(L1), 0.00010232890687969222(L2) weight decay set for conv2d_44/kernel:0
# 0.0(L1), 0.00010232890687969222(L2) weight decay set for conv2d_47/kernel:0
# 0.0(L1), 0.00010232890687969222(L2) weight decay set for conv2d_45/kernel:0
# 0.0(L1), 0.00010232890687969222(L2) weight decay set for conv2d_48/kernel:0
# 0.0(L1), 0.00010232890687969222(L2) weight decay set for conv2d_46/kernel:0
# 0.0(L1), 0.00010232890687969222(L2) weight decay set for conv2d_49/kernel:0
# 0.0(L1), 0.00010232890687969222(L2) weight decay set for conv2d_50/kernel:0
# 0.0(L1), 0.00010232890687969222(L2) weight decay set for conv2d_51/kernel:0
# 0.0(L1), 0.00010232890687969222(L2) weight decay set for conv2d_52/kernel:0
# 0.0(L1), 0.00010232890687969222(L2) weight decay set for conv2d_53/kernel:0
# 0.0(L1), 0.00010232890687969222(L2) weight decay set for conv2d_54/kernel:0
# 0.0(L1), 0.00010232890687969222(L2) weight decay set for conv2d_57/kernel:0
# 0.0(L1), 0.00010232890687969222(L2) weight decay set for conv2d_55/kernel:0
# 0.0(L1), 0.00010232890687969222(L2) weight decay set for conv2d_58/kernel:0
# 0.0(L1), 0.00010232890687969222(L2) weight decay set for conv2d_56/kernel:0
# 0.0(L1), 0.00010232890687969222(L2) weight decay set for conv2d_59/kernel:0
# 0.0(L1), 0.00010232890687969222(L2) weight decay set for conv2d_60/kernel:0
# 0.0(L1), 0.00010232890687969222(L2) weight decay set for conv2d_61/kernel:0
# 0.0(L1), 0.00010232890687969222(L2) weight decay set for conv2d_62/kernel:0
# 0.0(L1), 0.00010232890687969222(L2) weight decay set for conv2d_63/kernel:0
# 0.0(L1), 0.00010232890687969222(L2) weight decay set for conv2d_64/kernel:0
# 0.0(L1), 0.00010232890687969222(L2) weight decay set for conv2d_67/kernel:0
# 0.0(L1), 0.00010232890687969222(L2) weight decay set for conv2d_65/kernel:0
# 0.0(L1), 0.00010232890687969222(L2) weight decay set for conv2d_68/kernel:0
# 0.0(L1), 0.00010232890687969222(L2) weight decay set for conv2d_66/kernel:0
# 0.0(L1), 0.00010232890687969222(L2) weight decay set for conv2d_69/kernel:0
# 0.0(L1), 0.00010232890687969222(L2) weight decay set for conv2d_70/kernel:0
# 0.0(L1), 0.00010232890687969222(L2) weight decay set for conv2d_71/kernel:0
# 0.0(L1), 0.00010232890687969222(L2) weight decay set for conv2d_72/kernel:0
# 0.0(L1), 0.00010232890687969222(L2) weight decay set for conv2d_73/kernel:0
# 0.0(L1), 0.00010232890687969222(L2) weight decay set for conv2d_74/kernel:0
# 0.0(L1), 0.00010232890687969222(L2) weight decay set for conv2d_77/kernel:0
# 0.0(L1), 0.00010232890687969222(L2) weight decay set for conv2d_75/kernel:0
# 0.0(L1), 0.00010232890687969222(L2) weight decay set for conv2d_78/kernel:0
# 0.0(L1), 0.00010232890687969222(L2) weight decay set for conv2d_76/kernel:0
# 0.0(L1), 0.00010232890687969222(L2) weight decay set for conv2d_79/kernel:0
# 0.0(L1), 0.00010232890687969222(L2) weight decay set for conv2d_80/kernel:0
# 0.0(L1), 0.00010232890687969222(L2) weight decay set for conv2d_81/kernel:0
# 0.0(L1), 0.00010232890687969222(L2) weight decay set for conv2d_82/kernel:0
# 0.0(L1), 0.00010232890687969222(L2) weight decay set for conv2d_83/kernel:0
# 0.0(L1), 0.00010232890687969222(L2) weight decay set for conv2d_85/kernel:0
# 0.0(L1), 0.00010232890687969222(L2) weight decay set for conv2d_84/kernel:0
# 0.0(L1), 0.00010232890687969222(L2) weight decay set for conv2d_86/kernel:0
# 0.0(L1), 0.00010232890687969222(L2) weight decay set for conv2d_87/kernel:0
# 0.0(L1), 0.00010232890687969222(L2) weight decay set for conv2d_88/kernel:0
# 0.0(L1), 0.00010232890687969222(L2) weight decay set for conv2d_91/kernel:0
# 0.0(L1), 0.00010232890687969222(L2) weight decay set for conv2d_89/kernel:0
# 0.0(L1), 0.00010232890687969222(L2) weight decay set for conv2d_90/kernel:0
# 0.0(L1), 0.00010232890687969222(L2) weight decay set for conv2d_92/kernel:0
# 0.0(L1), 0.00010232890687969222(L2) weight decay set for conv2d_93/kernel:0
# 0.0(L1), 0.00010232890687969222(L2) weight decay set for conv2d_94/kernel:0
# 0.0(L1), 0.00010232890687969222(L2) weight decay set for conv2d_95/kernel:0
# 0.0(L1), 0.00010232890687969222(L2) weight decay set for conv2d_96/kernel:0
# 0.0(L1), 0.00010232890687969222(L2) weight decay set for conv2d_97/kernel:0
# 0.0(L1), 0.00010232890687969222(L2) weight decay set for conv2d_100/kernel:0
# 0.0(L1), 0.00010232890687969222(L2) weight decay set for conv2d_98/kernel:0
# 0.0(L1), 0.00010232890687969222(L2) weight decay set for conv2d_99/kernel:0
# 0.0(L1), 0.00010232890687969222(L2) weight decay set for conv2d_101/kernel:0
# 0.0(L1), 0.00010232890687969222(L2) weight decay set for conv2d_102/kernel:0
# 0.0(L1), 0.00010232890687969222(L2) weight decay set for conv2d_103/kernel:0
# 0.0(L1), 0.00010232890687969222(L2) weight decay set for conv2d_104/kernel:0
# 0.0(L1), 0.00010232890687969222(L2) weight decay set for conv2d_105/kernel:0
# 0.0(L1), 0.00010232890687969222(L2) weight decay set for conv2d_106/kernel:0
# 0.0(L1), 0.00010232890687969222(L2) weight decay set for dense/kernel:0
# 0.0(L1), 0.00010232890687969222(L2) weight decay set for auxiliary_classifier/kernel:0
# 382/382 [==============================] - ETA: 0s - loss: 7.2487 - main_classifier_loss: 5.1864 - auxiliary_classifier_loss: 5.1558 - main_classifier_accuracy: 0.0771 - main_classifier_top5_acc: 0.1598 - main_classifier_macro_f1score: 0.0016 - auxiliary_classifier_accuracy: 0.0946 - auxiliary_classifier_top5_acc: 0.1884 - auxiliary_classifier_macro_f1score: 0.0028 Found 2980 images belonging to 257 classes.
#
# Epoch 00001: val_loss improved from inf to 7.26601, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_v3/001.h5
#
# Epoch 00001: val_main_classifier_accuracy improved from -inf to 0.07948, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_v3/001.h5
# 382/382 [==============================] - 17863s 47s/step - loss: 7.2487 - main_classifier_loss: 5.1864 - auxiliary_classifier_loss: 5.1558 - main_classifier_accuracy: 0.0771 - main_classifier_top5_acc: 0.1598 - main_classifier_macro_f1score: 0.0016 - auxiliary_classifier_accuracy: 0.0946 - auxiliary_classifier_top5_acc: 0.1884 - auxiliary_classifier_macro_f1score: 0.0028 - val_loss: 7.2660 - val_main_classifier_loss: 5.1643 - val_auxiliary_classifier_loss: 5.2542 - val_main_classifier_accuracy: 0.0795 - val_main_classifier_top5_acc: 0.1617 - val_main_classifier_macro_f1score: 0.0035 - val_auxiliary_classifier_accuracy: 0.0971 - val_auxiliary_classifier_top5_acc: 0.1933 - val_auxiliary_classifier_macro_f1score: 0.0050
# Learning rate:  0.001
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 2/70
# 382/382 [==============================] - ETA: 0s - loss: 6.6014 - main_classifier_loss: 4.7542 - auxiliary_classifier_loss: 4.6180 - main_classifier_accuracy: 0.1175 - main_classifier_top5_acc: 0.2376 - main_classifier_macro_f1score: 0.0053 - auxiliary_classifier_accuracy: 0.1544 - auxiliary_classifier_top5_acc: 0.3070 - auxiliary_classifier_macro_f1score: 0.0076
# Epoch 00002: val_loss did not improve from 7.26601
#
# Epoch 00002: val_main_classifier_accuracy did not improve from 0.07948
# 382/382 [==============================] - 715s 2s/step - loss: 6.6014 - main_classifier_loss: 4.7542 - auxiliary_classifier_loss: 4.6180 - main_classifier_accuracy: 0.1175 - main_classifier_top5_acc: 0.2376 - main_classifier_macro_f1score: 0.0053 - auxiliary_classifier_accuracy: 0.1544 - auxiliary_classifier_top5_acc: 0.3070 - auxiliary_classifier_macro_f1score: 0.0076 - val_loss: 9.4452 - val_main_classifier_loss: 6.2791 - val_auxiliary_classifier_loss: 7.9154 - val_main_classifier_accuracy: 0.0577 - val_main_classifier_top5_acc: 0.1267 - val_main_classifier_macro_f1score: 0.0023 - val_auxiliary_classifier_accuracy: 0.0724 - val_auxiliary_classifier_top5_acc: 0.1637 - val_auxiliary_classifier_macro_f1score: 0.0022
# Learning rate:  0.001
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 3/70
# 382/382 [==============================] - ETA: 0s - loss: 6.1862 - main_classifier_loss: 4.5006 - auxiliary_classifier_loss: 4.2139 - main_classifier_accuracy: 0.1492 - main_classifier_top5_acc: 0.3011 - main_classifier_macro_f1score: 0.0069 - auxiliary_classifier_accuracy: 0.2054 - auxiliary_classifier_top5_acc: 0.3875 - auxiliary_classifier_macro_f1score: 0.0108
# Epoch 00003: val_loss did not improve from 7.26601
#
# Epoch 00003: val_main_classifier_accuracy improved from 0.07948 to 0.11345, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_v3/003.h5
# 382/382 [==============================] - 718s 2s/step - loss: 6.1862 - main_classifier_loss: 4.5006 - auxiliary_classifier_loss: 4.2139 - main_classifier_accuracy: 0.1492 - main_classifier_top5_acc: 0.3011 - main_classifier_macro_f1score: 0.0069 - auxiliary_classifier_accuracy: 0.2054 - auxiliary_classifier_top5_acc: 0.3875 - auxiliary_classifier_macro_f1score: 0.0108 - val_loss: 9.5948 - val_main_classifier_loss: 6.5198 - val_auxiliary_classifier_loss: 7.6874 - val_main_classifier_accuracy: 0.1135 - val_main_classifier_top5_acc: 0.2286 - val_main_classifier_macro_f1score: 0.0054 - val_auxiliary_classifier_accuracy: 0.1369 - val_auxiliary_classifier_top5_acc: 0.2796 - val_auxiliary_classifier_macro_f1score: 0.0087
# Learning rate:  0.001
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 4/70
# 382/382 [==============================] - ETA: 0s - loss: 5.7852 - main_classifier_loss: 4.2353 - auxiliary_classifier_loss: 3.8748 - main_classifier_accuracy: 0.1881 - main_classifier_top5_acc: 0.3696 - main_classifier_macro_f1score: 0.0090 - auxiliary_classifier_accuracy: 0.2625 - auxiliary_classifier_top5_acc: 0.4721 - auxiliary_classifier_macro_f1score: 0.0160
# Epoch 00004: val_loss improved from 7.26601 to 6.51617, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_v3/004.h5
#
# Epoch 00004: val_main_classifier_accuracy improved from 0.11345 to 0.13383, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_v3/004.h5
# 382/382 [==============================] - 719s 2s/step - loss: 5.7852 - main_classifier_loss: 4.2353 - auxiliary_classifier_loss: 3.8748 - main_classifier_accuracy: 0.1881 - main_classifier_top5_acc: 0.3696 - main_classifier_macro_f1score: 0.0090 - auxiliary_classifier_accuracy: 0.2625 - auxiliary_classifier_top5_acc: 0.4721 - auxiliary_classifier_macro_f1score: 0.0160 - val_loss: 6.5162 - val_main_classifier_loss: 4.7824 - val_auxiliary_classifier_loss: 4.3345 - val_main_classifier_accuracy: 0.1338 - val_main_classifier_top5_acc: 0.2704 - val_main_classifier_macro_f1score: 0.0073 - val_auxiliary_classifier_accuracy: 0.2058 - val_auxiliary_classifier_top5_acc: 0.3882 - val_auxiliary_classifier_macro_f1score: 0.0138
# Learning rate:  0.001
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 5/70
# 382/382 [==============================] - ETA: 0s - loss: 5.4331 - main_classifier_loss: 3.9941 - auxiliary_classifier_loss: 3.5976 - main_classifier_accuracy: 0.2307 - main_classifier_top5_acc: 0.4396 - main_classifier_macro_f1score: 0.0117 - auxiliary_classifier_accuracy: 0.3141 - auxiliary_classifier_top5_acc: 0.5386 - auxiliary_classifier_macro_f1score: 0.0235
# Epoch 00005: val_loss did not improve from 6.51617
#
# Epoch 00005: val_main_classifier_accuracy improved from 0.13383 to 0.17833, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_v3/005.h5
# 382/382 [==============================] - 715s 2s/step - loss: 5.4331 - main_classifier_loss: 3.9941 - auxiliary_classifier_loss: 3.5976 - main_classifier_accuracy: 0.2307 - main_classifier_top5_acc: 0.4396 - main_classifier_macro_f1score: 0.0117 - auxiliary_classifier_accuracy: 0.3141 - auxiliary_classifier_top5_acc: 0.5386 - auxiliary_classifier_macro_f1score: 0.0235 - val_loss: 6.8605 - val_main_classifier_loss: 4.8126 - val_auxiliary_classifier_loss: 5.1195 - val_main_classifier_accuracy: 0.1783 - val_main_classifier_top5_acc: 0.3577 - val_main_classifier_macro_f1score: 0.0090 - val_auxiliary_classifier_accuracy: 0.2452 - val_auxiliary_classifier_top5_acc: 0.4361 - val_auxiliary_classifier_macro_f1score: 0.0199
# Learning rate:  0.001
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 6/70
# 382/382 [==============================] - ETA: 0s - loss: 5.1577 - main_classifier_loss: 3.8032 - auxiliary_classifier_loss: 3.3862 - main_classifier_accuracy: 0.2645 - main_classifier_top5_acc: 0.4934 - main_classifier_macro_f1score: 0.0147 - auxiliary_classifier_accuracy: 0.3584 - auxiliary_classifier_top5_acc: 0.5949 - auxiliary_classifier_macro_f1score: 0.0299
# Epoch 00006: val_loss improved from 6.51617 to 5.95612, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_v3/006.h5
#
# Epoch 00006: val_main_classifier_accuracy improved from 0.17833 to 0.20211, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_v3/006.h5
# 382/382 [==============================] - 720s 2s/step - loss: 5.1577 - main_classifier_loss: 3.8032 - auxiliary_classifier_loss: 3.3862 - main_classifier_accuracy: 0.2645 - main_classifier_top5_acc: 0.4934 - main_classifier_macro_f1score: 0.0147 - auxiliary_classifier_accuracy: 0.3584 - auxiliary_classifier_top5_acc: 0.5949 - auxiliary_classifier_macro_f1score: 0.0299 - val_loss: 5.9561 - val_main_classifier_loss: 4.3175 - val_auxiliary_classifier_loss: 4.0967 - val_main_classifier_accuracy: 0.2021 - val_main_classifier_top5_acc: 0.3855 - val_main_classifier_macro_f1score: 0.0099 - val_auxiliary_classifier_accuracy: 0.2537 - val_auxiliary_classifier_top5_acc: 0.4521 - val_auxiliary_classifier_macro_f1score: 0.0220
# Learning rate:  0.001
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 7/70
# 382/382 [==============================] - ETA: 0s - loss: 4.8389 - main_classifier_loss: 3.5823 - auxiliary_classifier_loss: 3.1414 - main_classifier_accuracy: 0.3123 - main_classifier_top5_acc: 0.5528 - main_classifier_macro_f1score: 0.0197 - auxiliary_classifier_accuracy: 0.4136 - auxiliary_classifier_top5_acc: 0.6535 - auxiliary_classifier_macro_f1score: 0.0395
# Epoch 00007: val_loss did not improve from 5.95612
#
# Epoch 00007: val_main_classifier_accuracy did not improve from 0.20211
# 382/382 [==============================] - 709s 2s/step - loss: 4.8389 - main_classifier_loss: 3.5823 - auxiliary_classifier_loss: 3.1414 - main_classifier_accuracy: 0.3123 - main_classifier_top5_acc: 0.5528 - main_classifier_macro_f1score: 0.0197 - auxiliary_classifier_accuracy: 0.4136 - auxiliary_classifier_top5_acc: 0.6535 - auxiliary_classifier_macro_f1score: 0.0395 - val_loss: 6.2339 - val_main_classifier_loss: 4.5439 - val_auxiliary_classifier_loss: 4.2249 - val_main_classifier_accuracy: 0.2014 - val_main_classifier_top5_acc: 0.4147 - val_main_classifier_macro_f1score: 0.0127 - val_auxiliary_classifier_accuracy: 0.2666 - val_auxiliary_classifier_top5_acc: 0.4776 - val_auxiliary_classifier_macro_f1score: 0.0267
# Learning rate:  0.001
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 8/70
# 382/382 [==============================] - ETA: 0s - loss: 4.5772 - main_classifier_loss: 3.4018 - auxiliary_classifier_loss: 2.9385 - main_classifier_accuracy: 0.3541 - main_classifier_top5_acc: 0.6015 - main_classifier_macro_f1score: 0.0247 - auxiliary_classifier_accuracy: 0.4619 - auxiliary_classifier_top5_acc: 0.6981 - auxiliary_classifier_macro_f1score: 0.0487
# Epoch 00008: val_loss improved from 5.95612 to 4.99526, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_v3/008.h5
#
# Epoch 00008: val_main_classifier_accuracy improved from 0.20211 to 0.31556, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_v3/008.h5
# 382/382 [==============================] - 713s 2s/step - loss: 4.5772 - main_classifier_loss: 3.4018 - auxiliary_classifier_loss: 2.9385 - main_classifier_accuracy: 0.3541 - main_classifier_top5_acc: 0.6015 - main_classifier_macro_f1score: 0.0247 - auxiliary_classifier_accuracy: 0.4619 - auxiliary_classifier_top5_acc: 0.6981 - auxiliary_classifier_macro_f1score: 0.0487 - val_loss: 4.9953 - val_main_classifier_loss: 3.6531 - val_auxiliary_classifier_loss: 3.3554 - val_main_classifier_accuracy: 0.3156 - val_main_classifier_top5_acc: 0.5496 - val_main_classifier_macro_f1score: 0.0242 - val_auxiliary_classifier_accuracy: 0.3804 - val_auxiliary_classifier_top5_acc: 0.6257 - val_auxiliary_classifier_macro_f1score: 0.0441
# Learning rate:  0.001
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 9/70
# 382/382 [==============================] - ETA: 0s - loss: 4.3773 - main_classifier_loss: 3.2632 - auxiliary_classifier_loss: 2.7852 - main_classifier_accuracy: 0.3887 - main_classifier_top5_acc: 0.6376 - main_classifier_macro_f1score: 0.0302 - auxiliary_classifier_accuracy: 0.4936 - auxiliary_classifier_top5_acc: 0.7348 - auxiliary_classifier_macro_f1score: 0.0550
# Epoch 00009: val_loss improved from 4.99526 to 4.92369, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_v3/009.h5
#
# Epoch 00009: val_main_classifier_accuracy improved from 0.31556 to 0.32779, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_v3/009.h5
# 382/382 [==============================] - 716s 2s/step - loss: 4.3773 - main_classifier_loss: 3.2632 - auxiliary_classifier_loss: 2.7852 - main_classifier_accuracy: 0.3887 - main_classifier_top5_acc: 0.6376 - main_classifier_macro_f1score: 0.0302 - auxiliary_classifier_accuracy: 0.4936 - auxiliary_classifier_top5_acc: 0.7348 - auxiliary_classifier_macro_f1score: 0.0550 - val_loss: 4.9237 - val_main_classifier_loss: 3.5949 - val_auxiliary_classifier_loss: 3.3220 - val_main_classifier_accuracy: 0.3278 - val_main_classifier_top5_acc: 0.5669 - val_main_classifier_macro_f1score: 0.0247 - val_auxiliary_classifier_accuracy: 0.3971 - val_auxiliary_classifier_top5_acc: 0.6267 - val_auxiliary_classifier_macro_f1score: 0.0458
# Learning rate:  0.001
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 10/70
# 382/382 [==============================] - ETA: 0s - loss: 4.1663 - main_classifier_loss: 3.1102 - auxiliary_classifier_loss: 2.6401 - main_classifier_accuracy: 0.4259 - main_classifier_top5_acc: 0.6742 - main_classifier_macro_f1score: 0.0368 - auxiliary_classifier_accuracy: 0.5348 - auxiliary_classifier_top5_acc: 0.7690 - auxiliary_classifier_macro_f1score: 0.0625
# Epoch 00010: val_loss did not improve from 4.92369
#
# Epoch 00010: val_main_classifier_accuracy improved from 0.32779 to 0.33865, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_v3/010.h5
# 382/382 [==============================] - 712s 2s/step - loss: 4.1663 - main_classifier_loss: 3.1102 - auxiliary_classifier_loss: 2.6401 - main_classifier_accuracy: 0.4259 - main_classifier_top5_acc: 0.6742 - main_classifier_macro_f1score: 0.0368 - auxiliary_classifier_accuracy: 0.5348 - auxiliary_classifier_top5_acc: 0.7690 - auxiliary_classifier_macro_f1score: 0.0625 - val_loss: 5.1150 - val_main_classifier_loss: 3.6587 - val_auxiliary_classifier_loss: 3.6406 - val_main_classifier_accuracy: 0.3387 - val_main_classifier_top5_acc: 0.5730 - val_main_classifier_macro_f1score: 0.0243 - val_auxiliary_classifier_accuracy: 0.3584 - val_auxiliary_classifier_top5_acc: 0.5707 - val_auxiliary_classifier_macro_f1score: 0.0387
# Learning rate:  0.001
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 11/70
# 382/382 [==============================] - ETA: 0s - loss: 4.0040 - main_classifier_loss: 2.9934 - auxiliary_classifier_loss: 2.5265 - main_classifier_accuracy: 0.4524 - main_classifier_top5_acc: 0.7050 - main_classifier_macro_f1score: 0.0420 - auxiliary_classifier_accuracy: 0.5620 - auxiliary_classifier_top5_acc: 0.7960 - auxiliary_classifier_macro_f1score: 0.0686
# Epoch 00011: val_loss improved from 4.92369 to 4.73932, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_v3/011.h5
#
# Epoch 00011: val_main_classifier_accuracy improved from 0.33865 to 0.36107, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_v3/011.h5
# 382/382 [==============================] - 714s 2s/step - loss: 4.0040 - main_classifier_loss: 2.9934 - auxiliary_classifier_loss: 2.5265 - main_classifier_accuracy: 0.4524 - main_classifier_top5_acc: 0.7050 - main_classifier_macro_f1score: 0.0420 - auxiliary_classifier_accuracy: 0.5620 - auxiliary_classifier_top5_acc: 0.7960 - auxiliary_classifier_macro_f1score: 0.0686 - val_loss: 4.7393 - val_main_classifier_loss: 3.4300 - val_auxiliary_classifier_loss: 3.2733 - val_main_classifier_accuracy: 0.3611 - val_main_classifier_top5_acc: 0.6060 - val_main_classifier_macro_f1score: 0.0347 - val_auxiliary_classifier_accuracy: 0.4076 - val_auxiliary_classifier_top5_acc: 0.6355 - val_auxiliary_classifier_macro_f1score: 0.0505
# Learning rate:  0.001
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 12/70
# 382/382 [==============================] - ETA: 0s - loss: 3.8142 - main_classifier_loss: 2.8570 - auxiliary_classifier_loss: 2.3930 - main_classifier_accuracy: 0.4845 - main_classifier_top5_acc: 0.7355 - main_classifier_macro_f1score: 0.0491 - auxiliary_classifier_accuracy: 0.5952 - auxiliary_classifier_top5_acc: 0.8243 - auxiliary_classifier_macro_f1score: 0.0763
# Epoch 00012: val_loss did not improve from 4.73932
#
# Epoch 00012: val_main_classifier_accuracy improved from 0.36107 to 0.36481, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_v3/012.h5
# 382/382 [==============================] - 711s 2s/step - loss: 3.8142 - main_classifier_loss: 2.8570 - auxiliary_classifier_loss: 2.3930 - main_classifier_accuracy: 0.4845 - main_classifier_top5_acc: 0.7355 - main_classifier_macro_f1score: 0.0491 - auxiliary_classifier_accuracy: 0.5952 - auxiliary_classifier_top5_acc: 0.8243 - auxiliary_classifier_macro_f1score: 0.0763 - val_loss: 4.7613 - val_main_classifier_loss: 3.4255 - val_auxiliary_classifier_loss: 3.3394 - val_main_classifier_accuracy: 0.3648 - val_main_classifier_top5_acc: 0.6097 - val_main_classifier_macro_f1score: 0.0340 - val_auxiliary_classifier_accuracy: 0.4032 - val_auxiliary_classifier_top5_acc: 0.6260 - val_auxiliary_classifier_macro_f1score: 0.0517
# Learning rate:  0.001
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 13/70
# 382/382 [==============================] - ETA: 0s - loss: 3.7926 - main_classifier_loss: 2.8422 - auxiliary_classifier_loss: 2.3760 - main_classifier_accuracy: 0.4940 - main_classifier_top5_acc: 0.7351 - main_classifier_macro_f1score: 0.0509 - auxiliary_classifier_accuracy: 0.5993 - auxiliary_classifier_top5_acc: 0.8270 - auxiliary_classifier_macro_f1score: 0.0766
# Epoch 00013: val_loss improved from 4.73932 to 4.24603, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_v3/013.h5
#
# Epoch 00013: val_main_classifier_accuracy improved from 0.36481 to 0.44497, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_v3/013.h5
# 382/382 [==============================] - 714s 2s/step - loss: 3.7926 - main_classifier_loss: 2.8422 - auxiliary_classifier_loss: 2.3760 - main_classifier_accuracy: 0.4940 - main_classifier_top5_acc: 0.7351 - main_classifier_macro_f1score: 0.0509 - auxiliary_classifier_accuracy: 0.5993 - auxiliary_classifier_top5_acc: 0.8270 - auxiliary_classifier_macro_f1score: 0.0766 - val_loss: 4.2460 - val_main_classifier_loss: 3.0682 - val_auxiliary_classifier_loss: 2.9446 - val_main_classifier_accuracy: 0.4450 - val_main_classifier_top5_acc: 0.6800 - val_main_classifier_macro_f1score: 0.0437 - val_auxiliary_classifier_accuracy: 0.4935 - val_auxiliary_classifier_top5_acc: 0.7109 - val_auxiliary_classifier_macro_f1score: 0.0677
# Learning rate:  0.001
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 14/70
# 382/382 [==============================] - ETA: 0s - loss: 3.5667 - main_classifier_loss: 2.6807 - auxiliary_classifier_loss: 2.2148 - main_classifier_accuracy: 0.5347 - main_classifier_top5_acc: 0.7674 - main_classifier_macro_f1score: 0.0603 - auxiliary_classifier_accuracy: 0.6489 - auxiliary_classifier_top5_acc: 0.8613 - auxiliary_classifier_macro_f1score: 0.0878
# Epoch 00014: val_loss did not improve from 4.24603
#
# Epoch 00014: val_main_classifier_accuracy did not improve from 0.44497
# 382/382 [==============================] - 710s 2s/step - loss: 3.5667 - main_classifier_loss: 2.6807 - auxiliary_classifier_loss: 2.2148 - main_classifier_accuracy: 0.5347 - main_classifier_top5_acc: 0.7674 - main_classifier_macro_f1score: 0.0603 - auxiliary_classifier_accuracy: 0.6489 - auxiliary_classifier_top5_acc: 0.8613 - auxiliary_classifier_macro_f1score: 0.0878 - val_loss: 4.3709 - val_main_classifier_loss: 3.1490 - val_auxiliary_classifier_loss: 3.0549 - val_main_classifier_accuracy: 0.4358 - val_main_classifier_top5_acc: 0.6634 - val_main_classifier_macro_f1score: 0.0503 - val_auxiliary_classifier_accuracy: 0.4762 - val_auxiliary_classifier_top5_acc: 0.6831 - val_auxiliary_classifier_macro_f1score: 0.0655
# Learning rate:  0.001
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 15/70
# 382/382 [==============================] - ETA: 0s - loss: 3.4305 - main_classifier_loss: 2.5831 - auxiliary_classifier_loss: 2.1185 - main_classifier_accuracy: 0.5556 - main_classifier_top5_acc: 0.7912 - main_classifier_macro_f1score: 0.0662 - auxiliary_classifier_accuracy: 0.6733 - auxiliary_classifier_top5_acc: 0.8818 - auxiliary_classifier_macro_f1score: 0.0928
# Epoch 00015: val_loss improved from 4.24603 to 4.21998, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_v3/015.h5
#
# Epoch 00015: val_main_classifier_accuracy improved from 0.44497 to 0.45754, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_v3/015.h5
# 382/382 [==============================] - 713s 2s/step - loss: 3.4305 - main_classifier_loss: 2.5831 - auxiliary_classifier_loss: 2.1185 - main_classifier_accuracy: 0.5556 - main_classifier_top5_acc: 0.7912 - main_classifier_macro_f1score: 0.0662 - auxiliary_classifier_accuracy: 0.6733 - auxiliary_classifier_top5_acc: 0.8818 - auxiliary_classifier_macro_f1score: 0.0928 - val_loss: 4.2200 - val_main_classifier_loss: 3.0338 - val_auxiliary_classifier_loss: 2.9656 - val_main_classifier_accuracy: 0.4575 - val_main_classifier_top5_acc: 0.6902 - val_main_classifier_macro_f1score: 0.0533 - val_auxiliary_classifier_accuracy: 0.4837 - val_auxiliary_classifier_top5_acc: 0.7041 - val_auxiliary_classifier_macro_f1score: 0.0721
# Learning rate:  0.001
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 16/70
# 382/382 [==============================] - ETA: 0s - loss: 3.3210 - main_classifier_loss: 2.5029 - auxiliary_classifier_loss: 2.0452 - main_classifier_accuracy: 0.5797 - main_classifier_top5_acc: 0.8071 - main_classifier_macro_f1score: 0.0709 - auxiliary_classifier_accuracy: 0.6934 - auxiliary_classifier_top5_acc: 0.8931 - auxiliary_classifier_macro_f1score: 0.0996
# Epoch 00016: val_loss improved from 4.21998 to 4.15675, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_v3/016.h5
#
# Epoch 00016: val_main_classifier_accuracy improved from 0.45754 to 0.47045, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_v3/016.h5
# 382/382 [==============================] - 713s 2s/step - loss: 3.3210 - main_classifier_loss: 2.5029 - auxiliary_classifier_loss: 2.0452 - main_classifier_accuracy: 0.5797 - main_classifier_top5_acc: 0.8071 - main_classifier_macro_f1score: 0.0709 - auxiliary_classifier_accuracy: 0.6934 - auxiliary_classifier_top5_acc: 0.8931 - auxiliary_classifier_macro_f1score: 0.0996 - val_loss: 4.1568 - val_main_classifier_loss: 2.9850 - val_auxiliary_classifier_loss: 2.9293 - val_main_classifier_accuracy: 0.4704 - val_main_classifier_top5_acc: 0.7031 - val_main_classifier_macro_f1score: 0.0569 - val_auxiliary_classifier_accuracy: 0.4993 - val_auxiliary_classifier_top5_acc: 0.7181 - val_auxiliary_classifier_macro_f1score: 0.0708
# Learning rate:  0.001
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 17/70
# 382/382 [==============================] - ETA: 0s - loss: 3.2294 - main_classifier_loss: 2.4399 - auxiliary_classifier_loss: 1.9739 - main_classifier_accuracy: 0.5958 - main_classifier_top5_acc: 0.8180 - main_classifier_macro_f1score: 0.0754 - auxiliary_classifier_accuracy: 0.7171 - auxiliary_classifier_top5_acc: 0.9096 - auxiliary_classifier_macro_f1score: 0.1037
# Epoch 00017: val_loss improved from 4.15675 to 4.00175, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_v3/017.h5
#
# Epoch 00017: val_main_classifier_accuracy improved from 0.47045 to 0.49932, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_v3/017.h5
# 382/382 [==============================] - 715s 2s/step - loss: 3.2294 - main_classifier_loss: 2.4399 - auxiliary_classifier_loss: 1.9739 - main_classifier_accuracy: 0.5958 - main_classifier_top5_acc: 0.8180 - main_classifier_macro_f1score: 0.0754 - auxiliary_classifier_accuracy: 0.7171 - auxiliary_classifier_top5_acc: 0.9096 - auxiliary_classifier_macro_f1score: 0.1037 - val_loss: 4.0017 - val_main_classifier_loss: 2.8703 - val_auxiliary_classifier_loss: 2.8286 - val_main_classifier_accuracy: 0.4993 - val_main_classifier_top5_acc: 0.7259 - val_main_classifier_macro_f1score: 0.0592 - val_auxiliary_classifier_accuracy: 0.5248 - val_auxiliary_classifier_top5_acc: 0.7323 - val_auxiliary_classifier_macro_f1score: 0.0749
# Learning rate:  0.001
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 18/70
# 382/382 [==============================] - ETA: 0s - loss: 3.1084 - main_classifier_loss: 2.3525 - auxiliary_classifier_loss: 1.8897 - main_classifier_accuracy: 0.6175 - main_classifier_top5_acc: 0.8405 - main_classifier_macro_f1score: 0.0806 - auxiliary_classifier_accuracy: 0.7430 - auxiliary_classifier_top5_acc: 0.9252 - auxiliary_classifier_macro_f1score: 0.1110
# Epoch 00018: val_loss did not improve from 4.00175
#
# Epoch 00018: val_main_classifier_accuracy did not improve from 0.49932
# 382/382 [==============================] - 707s 2s/step - loss: 3.1084 - main_classifier_loss: 2.3525 - auxiliary_classifier_loss: 1.8897 - main_classifier_accuracy: 0.6175 - main_classifier_top5_acc: 0.8405 - main_classifier_macro_f1score: 0.0806 - auxiliary_classifier_accuracy: 0.7430 - auxiliary_classifier_top5_acc: 0.9252 - auxiliary_classifier_macro_f1score: 0.1110 - val_loss: 4.2338 - val_main_classifier_loss: 3.0634 - val_auxiliary_classifier_loss: 2.9260 - val_main_classifier_accuracy: 0.4701 - val_main_classifier_top5_acc: 0.6946 - val_main_classifier_macro_f1score: 0.0620 - val_auxiliary_classifier_accuracy: 0.5041 - val_auxiliary_classifier_top5_acc: 0.7116 - val_auxiliary_classifier_macro_f1score: 0.0753
# Learning rate:  0.001
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 19/70
# 382/382 [==============================] - ETA: 0s - loss: 3.0202 - main_classifier_loss: 2.2848 - auxiliary_classifier_loss: 1.8385 - main_classifier_accuracy: 0.6376 - main_classifier_top5_acc: 0.8503 - main_classifier_macro_f1score: 0.0866 - auxiliary_classifier_accuracy: 0.7581 - auxiliary_classifier_top5_acc: 0.9321 - auxiliary_classifier_macro_f1score: 0.1150
# Epoch 00019: val_loss did not improve from 4.00175
#
# Epoch 00019: val_main_classifier_accuracy did not improve from 0.49932
# 382/382 [==============================] - 712s 2s/step - loss: 3.0202 - main_classifier_loss: 2.2848 - auxiliary_classifier_loss: 1.8385 - main_classifier_accuracy: 0.6376 - main_classifier_top5_acc: 0.8503 - main_classifier_macro_f1score: 0.0866 - auxiliary_classifier_accuracy: 0.7581 - auxiliary_classifier_top5_acc: 0.9321 - auxiliary_classifier_macro_f1score: 0.1150 - val_loss: 4.1531 - val_main_classifier_loss: 2.9576 - val_auxiliary_classifier_loss: 2.9888 - val_main_classifier_accuracy: 0.4878 - val_main_classifier_top5_acc: 0.7018 - val_main_classifier_macro_f1score: 0.0599 - val_auxiliary_classifier_accuracy: 0.4925 - val_auxiliary_classifier_top5_acc: 0.7031 - val_auxiliary_classifier_macro_f1score: 0.0708
# Learning rate:  0.001
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 20/70
# 382/382 [==============================] - ETA: 0s - loss: 2.9273 - main_classifier_loss: 2.2197 - auxiliary_classifier_loss: 1.7691 - main_classifier_accuracy: 0.6526 - main_classifier_top5_acc: 0.8638 - main_classifier_macro_f1score: 0.0904 - auxiliary_classifier_accuracy: 0.7820 - auxiliary_classifier_top5_acc: 0.9442 - auxiliary_classifier_macro_f1score: 0.1206
# Epoch 00020: val_loss improved from 4.00175 to 3.99352, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_v3/020.h5
#
# Epoch 00020: val_main_classifier_accuracy improved from 0.49932 to 0.51087, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_v3/020.h5
# 382/382 [==============================] - 714s 2s/step - loss: 2.9273 - main_classifier_loss: 2.2197 - auxiliary_classifier_loss: 1.7691 - main_classifier_accuracy: 0.6526 - main_classifier_top5_acc: 0.8638 - main_classifier_macro_f1score: 0.0904 - auxiliary_classifier_accuracy: 0.7820 - auxiliary_classifier_top5_acc: 0.9442 - auxiliary_classifier_macro_f1score: 0.1206 - val_loss: 3.9935 - val_main_classifier_loss: 2.8476 - val_auxiliary_classifier_loss: 2.8647 - val_main_classifier_accuracy: 0.5109 - val_main_classifier_top5_acc: 0.7296 - val_main_classifier_macro_f1score: 0.0659 - val_auxiliary_classifier_accuracy: 0.5248 - val_auxiliary_classifier_top5_acc: 0.7327 - val_auxiliary_classifier_macro_f1score: 0.0773
# Learning rate:  0.001
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 21/70
# 382/382 [==============================] - ETA: 0s - loss: 2.8343 - main_classifier_loss: 2.1492 - auxiliary_classifier_loss: 1.7129 - main_classifier_accuracy: 0.6731 - main_classifier_top5_acc: 0.8776 - main_classifier_macro_f1score: 0.0958 - auxiliary_classifier_accuracy: 0.8000 - auxiliary_classifier_top5_acc: 0.9537 - auxiliary_classifier_macro_f1score: 0.1257
# Epoch 00021: val_loss did not improve from 3.99352
#
# Epoch 00021: val_main_classifier_accuracy did not improve from 0.51087
# 382/382 [==============================] - 712s 2s/step - loss: 2.8343 - main_classifier_loss: 2.1492 - auxiliary_classifier_loss: 1.7129 - main_classifier_accuracy: 0.6731 - main_classifier_top5_acc: 0.8776 - main_classifier_macro_f1score: 0.0958 - auxiliary_classifier_accuracy: 0.8000 - auxiliary_classifier_top5_acc: 0.9537 - auxiliary_classifier_macro_f1score: 0.1257 - val_loss: 4.3362 - val_main_classifier_loss: 3.0981 - val_auxiliary_classifier_loss: 3.0952 - val_main_classifier_accuracy: 0.4606 - val_main_classifier_top5_acc: 0.6675 - val_main_classifier_macro_f1score: 0.0557 - val_auxiliary_classifier_accuracy: 0.4711 - val_auxiliary_classifier_top5_acc: 0.6793 - val_auxiliary_classifier_macro_f1score: 0.0651
# Learning rate:  0.001
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 22/70
# 382/382 [==============================] - ETA: 0s - loss: 2.7544 - main_classifier_loss: 2.0902 - auxiliary_classifier_loss: 1.6606 - main_classifier_accuracy: 0.6898 - main_classifier_top5_acc: 0.8882 - main_classifier_macro_f1score: 0.1006 - auxiliary_classifier_accuracy: 0.8164 - auxiliary_classifier_top5_acc: 0.9616 - auxiliary_classifier_macro_f1score: 0.1310
# Epoch 00022: val_loss did not improve from 3.99352
#
# Epoch 00022: val_main_classifier_accuracy did not improve from 0.51087
# 382/382 [==============================] - 709s 2s/step - loss: 2.7544 - main_classifier_loss: 2.0902 - auxiliary_classifier_loss: 1.6606 - main_classifier_accuracy: 0.6898 - main_classifier_top5_acc: 0.8882 - main_classifier_macro_f1score: 0.1006 - auxiliary_classifier_accuracy: 0.8164 - auxiliary_classifier_top5_acc: 0.9616 - auxiliary_classifier_macro_f1score: 0.1310 - val_loss: 4.0064 - val_main_classifier_loss: 2.8623 - val_auxiliary_classifier_loss: 2.8602 - val_main_classifier_accuracy: 0.5058 - val_main_classifier_top5_acc: 0.7354 - val_main_classifier_macro_f1score: 0.0723 - val_auxiliary_classifier_accuracy: 0.5197 - val_auxiliary_classifier_top5_acc: 0.7351 - val_auxiliary_classifier_macro_f1score: 0.0781
# Learning rate:  0.001
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 23/70
# 382/382 [==============================] - ETA: 0s - loss: 2.6830 - main_classifier_loss: 2.0341 - auxiliary_classifier_loss: 1.6222 - main_classifier_accuracy: 0.7039 - main_classifier_top5_acc: 0.8981 - main_classifier_macro_f1score: 0.1048 - auxiliary_classifier_accuracy: 0.8285 - auxiliary_classifier_top5_acc: 0.9667 - auxiliary_classifier_macro_f1score: 0.1352
# Epoch 00023: val_loss improved from 3.99352 to 3.77411, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_v3/023.h5
#
# Epoch 00023: val_main_classifier_accuracy improved from 0.51087 to 0.54721, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_v3/023.h5
# 382/382 [==============================] - 712s 2s/step - loss: 2.6830 - main_classifier_loss: 2.0341 - auxiliary_classifier_loss: 1.6222 - main_classifier_accuracy: 0.7039 - main_classifier_top5_acc: 0.8981 - main_classifier_macro_f1score: 0.1048 - auxiliary_classifier_accuracy: 0.8285 - auxiliary_classifier_top5_acc: 0.9667 - auxiliary_classifier_macro_f1score: 0.1352 - val_loss: 3.7741 - val_main_classifier_loss: 2.6841 - val_auxiliary_classifier_loss: 2.7250 - val_main_classifier_accuracy: 0.5472 - val_main_classifier_top5_acc: 0.7690 - val_main_classifier_macro_f1score: 0.0726 - val_auxiliary_classifier_accuracy: 0.5476 - val_auxiliary_classifier_top5_acc: 0.7469 - val_auxiliary_classifier_macro_f1score: 0.0810
# Learning rate:  0.001
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 24/70
# 382/382 [==============================] - ETA: 0s - loss: 2.6167 - main_classifier_loss: 1.9833 - auxiliary_classifier_loss: 1.5836 - main_classifier_accuracy: 0.7214 - main_classifier_top5_acc: 0.9064 - main_classifier_macro_f1score: 0.1082 - auxiliary_classifier_accuracy: 0.8416 - auxiliary_classifier_top5_acc: 0.9702 - auxiliary_classifier_macro_f1score: 0.1385
# Epoch 00024: val_loss did not improve from 3.77411
#
# Epoch 00024: val_main_classifier_accuracy did not improve from 0.54721
# 382/382 [==============================] - 710s 2s/step - loss: 2.6167 - main_classifier_loss: 1.9833 - auxiliary_classifier_loss: 1.5836 - main_classifier_accuracy: 0.7214 - main_classifier_top5_acc: 0.9064 - main_classifier_macro_f1score: 0.1082 - auxiliary_classifier_accuracy: 0.8416 - auxiliary_classifier_top5_acc: 0.9702 - auxiliary_classifier_macro_f1score: 0.1385 - val_loss: 3.8228 - val_main_classifier_loss: 2.7015 - val_auxiliary_classifier_loss: 2.8031 - val_main_classifier_accuracy: 0.5472 - val_main_classifier_top5_acc: 0.7619 - val_main_classifier_macro_f1score: 0.0815 - val_auxiliary_classifier_accuracy: 0.5411 - val_auxiliary_classifier_top5_acc: 0.7415 - val_auxiliary_classifier_macro_f1score: 0.0833
# Learning rate:  0.001
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 25/70
# 382/382 [==============================] - ETA: 0s - loss: 2.5886 - main_classifier_loss: 1.9593 - auxiliary_classifier_loss: 1.5734 - main_classifier_accuracy: 0.7294 - main_classifier_top5_acc: 0.9111 - main_classifier_macro_f1score: 0.1114 - auxiliary_classifier_accuracy: 0.8475 - auxiliary_classifier_top5_acc: 0.9723 - auxiliary_classifier_macro_f1score: 0.1401
# Epoch 00025: val_loss did not improve from 3.77411
#
# Epoch 00025: val_main_classifier_accuracy did not improve from 0.54721
# 382/382 [==============================] - 710s 2s/step - loss: 2.5886 - main_classifier_loss: 1.9593 - auxiliary_classifier_loss: 1.5734 - main_classifier_accuracy: 0.7294 - main_classifier_top5_acc: 0.9111 - main_classifier_macro_f1score: 0.1114 - auxiliary_classifier_accuracy: 0.8475 - auxiliary_classifier_top5_acc: 0.9723 - auxiliary_classifier_macro_f1score: 0.1401 - val_loss: 4.0322 - val_main_classifier_loss: 2.8783 - val_auxiliary_classifier_loss: 2.8848 - val_main_classifier_accuracy: 0.4997 - val_main_classifier_top5_acc: 0.7228 - val_main_classifier_macro_f1score: 0.0686 - val_auxiliary_classifier_accuracy: 0.5160 - val_auxiliary_classifier_top5_acc: 0.7300 - val_auxiliary_classifier_macro_f1score: 0.0783
# Learning rate:  0.001
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 26/70
# 382/382 [==============================] - ETA: 0s - loss: 2.4954 - main_classifier_loss: 1.8865 - auxiliary_classifier_loss: 1.5223 - main_classifier_accuracy: 0.7495 - main_classifier_top5_acc: 0.9237 - main_classifier_macro_f1score: 0.1164 - auxiliary_classifier_accuracy: 0.8620 - auxiliary_classifier_top5_acc: 0.9774 - auxiliary_classifier_macro_f1score: 0.1459
# Epoch 00026: val_loss did not improve from 3.77411
#
# Epoch 00026: val_main_classifier_accuracy improved from 0.54721 to 0.55842, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_v3/026.h5
# 382/382 [==============================] - 699s 2s/step - loss: 2.4954 - main_classifier_loss: 1.8865 - auxiliary_classifier_loss: 1.5223 - main_classifier_accuracy: 0.7495 - main_classifier_top5_acc: 0.9237 - main_classifier_macro_f1score: 0.1164 - auxiliary_classifier_accuracy: 0.8620 - auxiliary_classifier_top5_acc: 0.9774 - auxiliary_classifier_macro_f1score: 0.1459 - val_loss: 3.8138 - val_main_classifier_loss: 2.6922 - val_auxiliary_classifier_loss: 2.8040 - val_main_classifier_accuracy: 0.5584 - val_main_classifier_top5_acc: 0.7554 - val_main_classifier_macro_f1score: 0.0794 - val_auxiliary_classifier_accuracy: 0.5329 - val_auxiliary_classifier_top5_acc: 0.7405 - val_auxiliary_classifier_macro_f1score: 0.0815
# Learning rate:  0.001
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 27/70
# 382/382 [==============================] - ETA: 0s - loss: 2.4597 - main_classifier_loss: 1.8579 - auxiliary_classifier_loss: 1.5046 - main_classifier_accuracy: 0.7580 - main_classifier_top5_acc: 0.9303 - main_classifier_macro_f1score: 0.1178 - auxiliary_classifier_accuracy: 0.8687 - auxiliary_classifier_top5_acc: 0.9796 - auxiliary_classifier_macro_f1score: 0.1477
# Epoch 00027: val_loss did not improve from 3.77411
#
# Epoch 00027: val_main_classifier_accuracy did not improve from 0.55842
# 382/382 [==============================] - 698s 2s/step - loss: 2.4597 - main_classifier_loss: 1.8579 - auxiliary_classifier_loss: 1.5046 - main_classifier_accuracy: 0.7580 - main_classifier_top5_acc: 0.9303 - main_classifier_macro_f1score: 0.1178 - auxiliary_classifier_accuracy: 0.8687 - auxiliary_classifier_top5_acc: 0.9796 - auxiliary_classifier_macro_f1score: 0.1477 - val_loss: 3.9704 - val_main_classifier_loss: 2.8500 - val_auxiliary_classifier_loss: 2.8009 - val_main_classifier_accuracy: 0.5228 - val_main_classifier_top5_acc: 0.7255 - val_main_classifier_macro_f1score: 0.0762 - val_auxiliary_classifier_accuracy: 0.5397 - val_auxiliary_classifier_top5_acc: 0.7391 - val_auxiliary_classifier_macro_f1score: 0.0840
# Learning rate:  0.001
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 28/70
# 382/382 [==============================] - ETA: 0s - loss: 2.4049 - main_classifier_loss: 1.8128 - auxiliary_classifier_loss: 1.4804 - main_classifier_accuracy: 0.7722 - main_classifier_top5_acc: 0.9383 - main_classifier_macro_f1score: 0.1224 - auxiliary_classifier_accuracy: 0.8785 - auxiliary_classifier_top5_acc: 0.9830 - auxiliary_classifier_macro_f1score: 0.1502
# Epoch 00028: val_loss did not improve from 3.77411
#
# Epoch 00028: val_main_classifier_accuracy did not improve from 0.55842
# ...
# 382/382 [==============================] - 709s 2s/step - loss: 1.5053 - main_classifier_loss: 1.0747 - auxiliary_classifier_loss: 1.0765 - main_classifier_accuracy: 0.9950 - main_classifier_top5_acc: 1.0000 - main_classifier_macro_f1score: 0.2023 - auxiliary_classifier_accuracy: 0.9940 - auxiliary_classifier_top5_acc: 0.9999 - auxiliary_classifier_macro_f1score: 0.1970 - val_loss: 3.2732 - val_main_classifier_loss: 2.3599 - val_auxiliary_classifier_loss: 2.2833 - val_main_classifier_accuracy: 0.6413 - val_main_classifier_top5_acc: 0.8149 - val_main_classifier_macro_f1score: 0.1004 - val_auxiliary_classifier_accuracy: 0.6583 - val_auxiliary_classifier_top5_acc: 0.8298 - val_auxiliary_classifier_macro_f1score: 0.0969
# Learning rate:  0.0001
#
# Epoch 00060: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 60/70
# 382/382 [==============================] - ETA: 0s - loss: 1.5072 - main_classifier_loss: 1.0761 - auxiliary_classifier_loss: 1.0778 - main_classifier_accuracy: 0.9941 - main_classifier_top5_acc: 0.9999 - main_classifier_macro_f1score: 0.2012 - auxiliary_classifier_accuracy: 0.9933 - auxiliary_classifier_top5_acc: 0.9998 - auxiliary_classifier_macro_f1score: 0.1963
# Epoch 00060: val_loss did not improve from 3.17230
#
# Epoch 00060: val_main_classifier_accuracy did not improve from 0.66270
# 382/382 [==============================] - 711s 2s/step - loss: 1.5072 - main_classifier_loss: 1.0761 - auxiliary_classifier_loss: 1.0778 - main_classifier_accuracy: 0.9941 - main_classifier_top5_acc: 0.9999 - main_classifier_macro_f1score: 0.2012 - auxiliary_classifier_accuracy: 0.9933 - auxiliary_classifier_top5_acc: 0.9998 - auxiliary_classifier_macro_f1score: 0.1963 - val_loss: 3.2363 - val_main_classifier_loss: 2.3307 - val_auxiliary_classifier_loss: 2.2640 - val_main_classifier_accuracy: 0.6376 - val_main_classifier_top5_acc: 0.8237 - val_main_classifier_macro_f1score: 0.1023 - val_auxiliary_classifier_accuracy: 0.6556 - val_auxiliary_classifier_top5_acc: 0.8285 - val_auxiliary_classifier_macro_f1score: 0.0975
# Learning rate:  1e-05
#
# Epoch 00061: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 61/70
# 382/382 [==============================] - ETA: 0s - loss: 1.4611 - main_classifier_loss: 1.0410 - auxiliary_classifier_loss: 1.0504 - main_classifier_accuracy: 0.9976 - main_classifier_top5_acc: 1.0000 - main_classifier_macro_f1score: 0.2058 - auxiliary_classifier_accuracy: 0.9966 - auxiliary_classifier_top5_acc: 1.0000 - auxiliary_classifier_macro_f1score: 0.2009
# Epoch 00061: val_loss improved from 3.17230 to 3.08402, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_v3/061.h5
#
# Epoch 00061: val_main_classifier_accuracy improved from 0.66270 to 0.67595, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_v3/061.h5
# 382/382 [==============================] - 718s 2s/step - loss: 1.4611 - main_classifier_loss: 1.0410 - auxiliary_classifier_loss: 1.0504 - main_classifier_accuracy: 0.9976 - main_classifier_top5_acc: 1.0000 - main_classifier_macro_f1score: 0.2058 - auxiliary_classifier_accuracy: 0.9966 - auxiliary_classifier_top5_acc: 1.0000 - auxiliary_classifier_macro_f1score: 0.2009 - val_loss: 3.0840 - val_main_classifier_loss: 2.2054 - val_auxiliary_classifier_loss: 2.1965 - val_main_classifier_accuracy: 0.6760 - val_main_classifier_top5_acc: 0.8359 - val_main_classifier_macro_f1score: 0.1051 - val_auxiliary_classifier_accuracy: 0.6729 - val_auxiliary_classifier_top5_acc: 0.8438 - val_auxiliary_classifier_macro_f1score: 0.0992
# Learning rate:  1e-05
#
# Epoch 00062: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 62/70
# 382/382 [==============================] - ETA: 0s - loss: 1.4411 - main_classifier_loss: 1.0238 - auxiliary_classifier_loss: 1.0433 - main_classifier_accuracy: 0.9989 - main_classifier_top5_acc: 1.0000 - main_classifier_macro_f1score: 0.2075 - auxiliary_classifier_accuracy: 0.9973 - auxiliary_classifier_top5_acc: 1.0000 - auxiliary_classifier_macro_f1score: 0.2015
# Epoch 00062: val_loss improved from 3.08402 to 3.07576, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_v3/062.h5
#
# Epoch 00062: val_main_classifier_accuracy improved from 0.67595 to 0.68071, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_v3/062.h5
# 382/382 [==============================] - 713s 2s/step - loss: 1.4411 - main_classifier_loss: 1.0238 - auxiliary_classifier_loss: 1.0433 - main_classifier_accuracy: 0.9989 - main_classifier_top5_acc: 1.0000 - main_classifier_macro_f1score: 0.2075 - auxiliary_classifier_accuracy: 0.9973 - auxiliary_classifier_top5_acc: 1.0000 - auxiliary_classifier_macro_f1score: 0.2015 - val_loss: 3.0758 - val_main_classifier_loss: 2.1977 - val_auxiliary_classifier_loss: 2.1952 - val_main_classifier_accuracy: 0.6807 - val_main_classifier_top5_acc: 0.8370 - val_main_classifier_macro_f1score: 0.1031 - val_auxiliary_classifier_accuracy: 0.6729 - val_auxiliary_classifier_top5_acc: 0.8478 - val_auxiliary_classifier_macro_f1score: 0.0970
# Learning rate:  1e-05
#
# Epoch 00063: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 63/70
# 382/382 [==============================] - ETA: 0s - loss: 1.4373 - main_classifier_loss: 1.0182 - auxiliary_classifier_loss: 1.0477 - main_classifier_accuracy: 0.9989 - main_classifier_top5_acc: 1.0000 - main_classifier_macro_f1score: 0.2087 - auxiliary_classifier_accuracy: 0.9974 - auxiliary_classifier_top5_acc: 1.0000 - auxiliary_classifier_macro_f1score: 0.1998
# Epoch 00063: val_loss did not improve from 3.07576
#
# Epoch 00063: val_main_classifier_accuracy did not improve from 0.68071
# 382/382 [==============================] - 710s 2s/step - loss: 1.4373 - main_classifier_loss: 1.0182 - auxiliary_classifier_loss: 1.0477 - main_classifier_accuracy: 0.9989 - main_classifier_top5_acc: 1.0000 - main_classifier_macro_f1score: 0.2087 - auxiliary_classifier_accuracy: 0.9974 - auxiliary_classifier_top5_acc: 1.0000 - auxiliary_classifier_macro_f1score: 0.1998 - val_loss: 3.0831 - val_main_classifier_loss: 2.2026 - val_auxiliary_classifier_loss: 2.2012 - val_main_classifier_accuracy: 0.6756 - val_main_classifier_top5_acc: 0.8359 - val_main_classifier_macro_f1score: 0.1012 - val_auxiliary_classifier_accuracy: 0.6743 - val_auxiliary_classifier_top5_acc: 0.8485 - val_auxiliary_classifier_macro_f1score: 0.0935
# Learning rate:  1e-05
#
# Epoch 00064: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 64/70
# 382/382 [==============================] - ETA: 0s - loss: 1.4366 - main_classifier_loss: 1.0151 - auxiliary_classifier_loss: 1.0537 - main_classifier_accuracy: 0.9993 - main_classifier_top5_acc: 1.0000 - main_classifier_macro_f1score: 0.2075 - auxiliary_classifier_accuracy: 0.9969 - auxiliary_classifier_top5_acc: 1.0000 - auxiliary_classifier_macro_f1score: 0.1975
# Epoch 00064: val_loss did not improve from 3.07576
#
# Epoch 00064: val_main_classifier_accuracy did not improve from 0.68071
# 382/382 [==============================] - 708s 2s/step - loss: 1.4366 - main_classifier_loss: 1.0151 - auxiliary_classifier_loss: 1.0537 - main_classifier_accuracy: 0.9993 - main_classifier_top5_acc: 1.0000 - main_classifier_macro_f1score: 0.2075 - auxiliary_classifier_accuracy: 0.9969 - auxiliary_classifier_top5_acc: 1.0000 - auxiliary_classifier_macro_f1score: 0.1975 - val_loss: 3.0939 - val_main_classifier_loss: 2.2111 - val_auxiliary_classifier_loss: 2.2070 - val_main_classifier_accuracy: 0.6776 - val_main_classifier_top5_acc: 0.8349 - val_main_classifier_macro_f1score: 0.1027 - val_auxiliary_classifier_accuracy: 0.6695 - val_auxiliary_classifier_top5_acc: 0.8478 - val_auxiliary_classifier_macro_f1score: 0.0929
# Learning rate:  1e-05
#
# Epoch 00065: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 65/70
# 382/382 [==============================] - ETA: 0s - loss: 1.4363 - main_classifier_loss: 1.0119 - auxiliary_classifier_loss: 1.0610 - main_classifier_accuracy: 0.9992 - main_classifier_top5_acc: 1.0000 - main_classifier_macro_f1score: 0.2096 - auxiliary_classifier_accuracy: 0.9974 - auxiliary_classifier_top5_acc: 1.0000 - auxiliary_classifier_macro_f1score: 0.1969
# Epoch 00065: val_loss did not improve from 3.07576
#
# Epoch 00065: val_main_classifier_accuracy did not improve from 0.68071
# 382/382 [==============================] - 711s 2s/step - loss: 1.4363 - main_classifier_loss: 1.0119 - auxiliary_classifier_loss: 1.0610 - main_classifier_accuracy: 0.9992 - main_classifier_top5_acc: 1.0000 - main_classifier_macro_f1score: 0.2096 - auxiliary_classifier_accuracy: 0.9974 - auxiliary_classifier_top5_acc: 1.0000 - auxiliary_classifier_macro_f1score: 0.1969 - val_loss: 3.0804 - val_main_classifier_loss: 2.2005 - val_auxiliary_classifier_loss: 2.1999 - val_main_classifier_accuracy: 0.6736 - val_main_classifier_top5_acc: 0.8383 - val_main_classifier_macro_f1score: 0.1016 - val_auxiliary_classifier_accuracy: 0.6760 - val_auxiliary_classifier_top5_acc: 0.8478 - val_auxiliary_classifier_macro_f1score: 0.0923
# Learning rate:  1e-05
#
# Epoch 00066: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 66/70
# 382/382 [==============================] - ETA: 0s - loss: 1.4365 - main_classifier_loss: 1.0093 - auxiliary_classifier_loss: 1.0682 - main_classifier_accuracy: 0.9995 - main_classifier_top5_acc: 1.0000 - main_classifier_macro_f1score: 0.2089 - auxiliary_classifier_accuracy: 0.9974 - auxiliary_classifier_top5_acc: 1.0000 - auxiliary_classifier_macro_f1score: 0.1946
# Epoch 00066: val_loss did not improve from 3.07576
#
# Epoch 00066: val_main_classifier_accuracy improved from 0.68071 to 0.68274, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_v3/066.h5
# 382/382 [==============================] - 706s 2s/step - loss: 1.4365 - main_classifier_loss: 1.0093 - auxiliary_classifier_loss: 1.0682 - main_classifier_accuracy: 0.9995 - main_classifier_top5_acc: 1.0000 - main_classifier_macro_f1score: 0.2089 - auxiliary_classifier_accuracy: 0.9974 - auxiliary_classifier_top5_acc: 1.0000 - auxiliary_classifier_macro_f1score: 0.1946 - val_loss: 3.0892 - val_main_classifier_loss: 2.2085 - val_auxiliary_classifier_loss: 2.2016 - val_main_classifier_accuracy: 0.6827 - val_main_classifier_top5_acc: 0.8370 - val_main_classifier_macro_f1score: 0.1003 - val_auxiliary_classifier_accuracy: 0.6800 - val_auxiliary_classifier_top5_acc: 0.8509 - val_auxiliary_classifier_macro_f1score: 0.0918
# Learning rate:  1e-05
#
# Epoch 00067: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 67/70
# 382/382 [==============================] - ETA: 0s - loss: 1.4402 - main_classifier_loss: 1.0089 - auxiliary_classifier_loss: 1.0782 - main_classifier_accuracy: 0.9993 - main_classifier_top5_acc: 1.0000 - main_classifier_macro_f1score: 0.2086 - auxiliary_classifier_accuracy: 0.9971 - auxiliary_classifier_top5_acc: 0.9998 - auxiliary_classifier_macro_f1score: 0.1920
# Epoch 00067: val_loss did not improve from 3.07576
#
# Epoch 00067: val_main_classifier_accuracy did not improve from 0.68274
# 382/382 [==============================] - 703s 2s/step - loss: 1.4402 - main_classifier_loss: 1.0089 - auxiliary_classifier_loss: 1.0782 - main_classifier_accuracy: 0.9993 - main_classifier_top5_acc: 1.0000 - main_classifier_macro_f1score: 0.2086 - auxiliary_classifier_accuracy: 0.9971 - auxiliary_classifier_top5_acc: 0.9998 - auxiliary_classifier_macro_f1score: 0.1920 - val_loss: 3.0781 - val_main_classifier_loss: 2.1997 - val_auxiliary_classifier_loss: 2.1962 - val_main_classifier_accuracy: 0.6827 - val_main_classifier_top5_acc: 0.8404 - val_main_classifier_macro_f1score: 0.1019 - val_auxiliary_classifier_accuracy: 0.6753 - val_auxiliary_classifier_top5_acc: 0.8512 - val_auxiliary_classifier_macro_f1score: 0.0917
# Learning rate:  1e-05
#
# Epoch 00068: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 68/70
# 382/382 [==============================] - ETA: 0s - loss: 1.4419 - main_classifier_loss: 1.0079 - auxiliary_classifier_loss: 1.0849 - main_classifier_accuracy: 0.9995 - main_classifier_top5_acc: 1.0000 - main_classifier_macro_f1score: 0.2089 - auxiliary_classifier_accuracy: 0.9975 - auxiliary_classifier_top5_acc: 1.0000 - auxiliary_classifier_macro_f1score: 0.1911
# Epoch 00068: val_loss did not improve from 3.07576
#
# Epoch 00068: val_main_classifier_accuracy improved from 0.68274 to 0.68444, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_v3/068.h5
# 382/382 [==============================] - 701s 2s/step - loss: 1.4419 - main_classifier_loss: 1.0079 - auxiliary_classifier_loss: 1.0849 - main_classifier_accuracy: 0.9995 - main_classifier_top5_acc: 1.0000 - main_classifier_macro_f1score: 0.2089 - auxiliary_classifier_accuracy: 0.9975 - auxiliary_classifier_top5_acc: 1.0000 - auxiliary_classifier_macro_f1score: 0.1911 - val_loss: 3.0975 - val_main_classifier_loss: 2.2159 - val_auxiliary_classifier_loss: 2.2040 - val_main_classifier_accuracy: 0.6844 - val_main_classifier_top5_acc: 0.8359 - val_main_classifier_macro_f1score: 0.1013 - val_auxiliary_classifier_accuracy: 0.6804 - val_auxiliary_classifier_top5_acc: 0.8516 - val_auxiliary_classifier_macro_f1score: 0.0907
# Learning rate:  1e-05
#
# Epoch 00069: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 69/70
# 382/382 [==============================] - ETA: 0s - loss: 1.4424 - main_classifier_loss: 1.0050 - auxiliary_classifier_loss: 1.0937 - main_classifier_accuracy: 0.9995 - main_classifier_top5_acc: 1.0000 - main_classifier_macro_f1score: 0.2089 - auxiliary_classifier_accuracy: 0.9970 - auxiliary_classifier_top5_acc: 1.0000 - auxiliary_classifier_macro_f1score: 0.1883
# Epoch 00069: val_loss did not improve from 3.07576
#
# Epoch 00069: val_main_classifier_accuracy did not improve from 0.68444
# 382/382 [==============================] - 701s 2s/step - loss: 1.4424 - main_classifier_loss: 1.0050 - auxiliary_classifier_loss: 1.0937 - main_classifier_accuracy: 0.9995 - main_classifier_top5_acc: 1.0000 - main_classifier_macro_f1score: 0.2089 - auxiliary_classifier_accuracy: 0.9970 - auxiliary_classifier_top5_acc: 1.0000 - auxiliary_classifier_macro_f1score: 0.1883 - val_loss: 3.0842 - val_main_classifier_loss: 2.2043 - val_auxiliary_classifier_loss: 2.1998 - val_main_classifier_accuracy: 0.6838 - val_main_classifier_top5_acc: 0.8393 - val_main_classifier_macro_f1score: 0.1021 - val_auxiliary_classifier_accuracy: 0.6753 - val_auxiliary_classifier_top5_acc: 0.8546 - val_auxiliary_classifier_macro_f1score: 0.0894
# Learning rate:  1e-05
#
# Epoch 00070: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 70/70
# 382/382 [==============================] - ETA: 0s - loss: 1.4454 - main_classifier_loss: 1.0047 - auxiliary_classifier_loss: 1.1018 - main_classifier_accuracy: 0.9996 - main_classifier_top5_acc: 1.0000 - main_classifier_macro_f1score: 0.2096 - auxiliary_classifier_accuracy: 0.9970 - auxiliary_classifier_top5_acc: 1.0000 - auxiliary_classifier_macro_f1score: 0.1874
# Epoch 00070: val_loss did not improve from 3.07576
#
# Epoch 00070: val_main_classifier_accuracy did not improve from 0.68444
# 382/382 [==============================] - 698s 2s/step - loss: 1.4454 - main_classifier_loss: 1.0047 - auxiliary_classifier_loss: 1.1018 - main_classifier_accuracy: 0.9996 - main_classifier_top5_acc: 1.0000 - main_classifier_macro_f1score: 0.2096 - auxiliary_classifier_accuracy: 0.9970 - auxiliary_classifier_top5_acc: 1.0000 - auxiliary_classifier_macro_f1score: 0.1874 - val_loss: 3.0822 - val_main_classifier_loss: 2.2019 - val_auxiliary_classifier_loss: 2.2007 - val_main_classifier_accuracy: 0.6780 - val_main_classifier_top5_acc: 0.8370 - val_main_classifier_macro_f1score: 0.1028 - val_auxiliary_classifier_accuracy: 0.6770 - val_auxiliary_classifier_top5_acc: 0.8533 - val_auxiliary_classifier_macro_f1score: 0.0906

# %% [markdown]
# ### 3) Inception-V3 Evaluate

# %%
# 1. epoch=maximum
#var = model.evaluate_generator(generate_test_for_three(),steps=int(len(x_test)/batch_sizes))
var = model.evaluate(generate_test_for_two(),steps=int(len(x_test)/batch_sizes))
print('[Test Loss: %.4f /   Test Top-1 Accuracy: %.4f / Test Top-5 Accuracy: %.4f / Test Macro f1: %.4f]\n' % (var[0],var[-3],var[-2],var[-1]))
# Out:
# Found 3118 images belonging to 257 classes.
# 48/48 [==============================] - 1927s 40s/step - loss: 3.1149 - main_classifier_loss: 2.2218 - auxiliary_classifier_loss: 2.2327 - main_classifier_accuracy: 0.6650 - main_classifier_top5_acc: 0.8346 - main_classifier_macro_f1score: 0.1010 - auxiliary_classifier_accuracy: 0.6709 - auxiliary_classifier_top5_acc: 0.8372 - auxiliary_classifier_macro_f1score: 0.0869
# [Test Loss: 3.1149 /   Test Top-1 Accuracy: 0.6709 / Test Top-5 Accuracy: 0.8372 / Test Macro f1: 0.0869]

# %%
loss=history.history['loss']
val_loss=history.history['val_loss']
acc=history.history['main_classifier_accuracy']
val_acc=history.history['val_main_classifier_accuracy']
top5_acc=history.history['main_classifier_top5_acc']
val_top5_acc=history.history['val_main_classifier_top5_acc']
f1=history.history['main_classifier_macro_f1score']
val_f1=history.history['val_main_classifier_macro_f1score']
epochs=range(1,len(acc)+1)

data = np.array([epochs,loss,val_loss,acc,val_acc,top5_acc,val_top5_acc,f1,val_f1]).T

# %%
# data save
# epochs, loss, val_loss, acc, val_acc, top5_acc, val_top5_acc, f1, val_f1

np.savetxt(os.path.join(dir,'train_valid_output',number,model.name+'.txt'),data)

# %%
# data import
data = np.loadtxt(os.path.join(dir,'train_valid_output',number,'Inception_v3.txt'))

# %%
epochs=data[:,0]
loss=data[:,1]
val_loss=data[:,2]
acc=data[:,3]
val_acc=data[:,4]
top5_acc=data[:,5]
val_top5_acc=data[:,6]

# %%
plt.plot(epochs[1:],acc[1:],'b',label='Training 1-Acc')
plt.plot(epochs[1:],val_acc[1:],'r',label='Validation 1-Acc')
plt.title('Training and Validation Top-1 Accuracy')
plt.legend()
plt.figure()

plt.plot(epochs[1:],top5_acc[1:],'b',label='Training 5-Acc')
plt.plot(epochs[1:],val_top5_acc[1:],'r',label='Validation 5-Acc')
plt.title('Training and Validation Top-5 Accuracy')
plt.legend()
plt.figure()

plt.plot(epochs[10:],loss[10:],'b',label='Training Loss')
plt.plot(epochs[10:],val_loss[10:],'r',label='Validation Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()

# %%
# 이 아래는 내가 인위적으로 살펴보고 싶은 epoch에 대해서 결과값 출력 / Inception-V3

# %%
# 참고 : https://github.com/OverLordGoldDragon/keras-adamw

import sys
sys.path.append('/content/drive/My Drive/Colab Notebooks/Paper')
import utils
import optimizers_v2
from utils import get_weight_decays, fill_dict_in_order
from utils import reset_seeds, K_eval
from optimizers_v2 import AdamW, NadamW, SGDW

# %%
# top-5 accuracy 출력
import functools
top5_acc = functools.partial(ks.metrics.top_k_categorical_accuracy, k=5)
top5_acc.__name__ = 'top5_acc'

# %%
model=load_model(os.path.join(dir,'model_output',number,'Inception_v3','068.h5'),
                 custom_objects={"macro_f1score": macro_f1score, "top5_acc":top5_acc, "smoothed_categorical_crossentropy":smoothed_categorical_crossentropy, "AdamW":AdamW})

# %%
# 2. epoch=?
smoothing_param = 0.1
var = model.evaluate(generate_test_for_two(),steps=int(len(x_test)/batch_sizes))
# Out:
# Found 3118 images belonging to 257 classes.
# 48/48 [==============================] - 841s 18s/step - loss: 40.5875 - main_classifier_loss: 29.3754 - auxiliary_classifier_loss: 28.0300 - main_classifier_accuracy: 0.6670 - main_classifier_top5_acc: 0.8363 - main_classifier_macro_f1score: 0.1023 - auxiliary_classifier_accuracy: 0.6657 - auxiliary_classifier_top5_acc: 0.8418 - auxiliary_classifier_macro_f1score: 0.0893

# %%
print('[Test Loss: %.4f /  Test Top-1 Accuracy: %.4f / Test Top-5 Accuracy: %.4f / Test Macro f1: %.4f]\n' % (var[0],var[-3],var[-2],var[-1]))
# Out:
# [Test Loss: 40.5875 /  Test Top-1 Accuracy: 0.6657 / Test Top-5 Accuracy: 0.8418 / Test Macro f1: 0.0893]
