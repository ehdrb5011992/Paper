# %%
#모형 출처 : https://github.com/titu1994/keras-squeeze-excite-network 에서 각색함

# %% [markdown]
# # [Inception ResNet V1]

# %% [markdown]
# *KU LeeDongGyu*

# %% [markdown]
# ## Contents
# ---

# %% [markdown]
# 1. Data Preprocessing
# ```
# 1) Data Import
# 2) Data Augmentation
# ```
# 2. Support Functions & Almost Original Inception-ResNet-V1
# ```
# 1) Support Functions
# 2) Almost Original Inception-ResNet-V1
# 3) Inception-ResNet-V1 Evaluate
# ```

# %% [markdown]
# ### Install Packages

# %% [markdown]
# ### Module

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/My Drive/Colab Notebooks/Paper
# Out:
# /content/drive/My Drive/Colab Notebooks/Paper

# %%
from f1score import macro_f1score,weighted_f1score

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import cv2
import tensorflow as tf
from tensorflow import keras as ks
from tensorflow.keras import backend as K 
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, Input, Concatenate, ZeroPadding2D ,GlobalMaxPooling2D, Reshape , Lambda , Add, Multiply
from tensorflow.keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D, Activation, BatchNormalization, AveragePooling2D , ZeroPadding2D, SeparableConv2D , LeakyReLU
from tensorflow.keras.layers import add, concatenate, multiply
from tensorflow.keras.optimizers import Adam, RMSprop , SGD
from tensorflow.keras.callbacks import EarlyStopping , LearningRateScheduler, ModelCheckpoint, CSVLogger, Callback, ReduceLROnPlateau
from tensorflow.keras.regularizers import l1,l2,l1_l2
from tensorflow.keras.models import Model , load_model , Sequential
from tensorflow.keras.utils import plot_model , to_categorical, get_file
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
os.getcwd()
# Out:
# '/content/drive/My Drive/Colab Notebooks/Paper'

# %%
print(tf.__version__)
print(ks.__version__)
# Out:
# 2.3.0
# 2.4.0

# %%
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 12588782581396805900
# , name: "/device:XLA_CPU:0"
# device_type: "XLA_CPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 16579139826380549943
# physical_device_desc: "device: XLA_CPU device"
# , name: "/device:XLA_GPU:0"
# device_type: "XLA_GPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 2560783199952310321
# physical_device_desc: "device: XLA_GPU device"
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 15473775744
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 13176939448566075498
# physical_device_desc: "device: 0, name: Tesla V100-SXM2-16GB, pci bus id: 0000:00:04.0, compute capability: 7.0"
# ]

# %%
# !cat /proc/cpuinfo
# Out:
# processor	: 0
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 85
# model name	: Intel(R) Xeon(R) CPU @ 2.00GHz
# stepping	: 3
# microcode	: 0x1
# cpu MHz		: 2000.174
# cache size	: 39424 KB
# physical id	: 0
# siblings	: 4
# core id		: 0
# cpu cores	: 2
# apicid		: 0
# initial apicid	: 0
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm mpx avx512f avx512dq rdseed adx smap clflushopt clwb avx512cd avx512bw avx512vl xsaveopt xsavec xgetbv1 xsaves arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs taa
# bogomips	: 4000.34
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 46 bits physical, 48 bits virtual
# power management:
#
# processor	: 1
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 85
# model name	: Intel(R) Xeon(R) CPU @ 2.00GHz
# stepping	: 3
# microcode	: 0x1
# cpu MHz		: 2000.174
# cache size	: 39424 KB
# physical id	: 0
# siblings	: 4
# core id		: 1
# cpu cores	: 2
# apicid		: 2
# initial apicid	: 2
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm mpx avx512f avx512dq rdseed adx smap clflushopt clwb avx512cd avx512bw avx512vl xsaveopt xsavec xgetbv1 xsaves arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs taa
# bogomips	: 4000.34
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 46 bits physical, 48 bits virtual
# power management:
#
# processor	: 2
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 85
# model name	: Intel(R) Xeon(R) CPU @ 2.00GHz
# stepping	: 3
# microcode	: 0x1
# cpu MHz		: 2000.174
# cache size	: 39424 KB
# physical id	: 0
# siblings	: 4
# core id		: 0
# cpu cores	: 2
# apicid		: 1
# initial apicid	: 1
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm mpx avx512f avx512dq rdseed adx smap clflushopt clwb avx512cd avx512bw avx512vl xsaveopt xsavec xgetbv1 xsaves arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs taa
# bogomips	: 4000.34
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 46 bits physical, 48 bits virtual
# power management:
#
# processor	: 3
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 85
# model name	: Intel(R) Xeon(R) CPU @ 2.00GHz
# stepping	: 3
# microcode	: 0x1
# cpu MHz		: 2000.174
# cache size	: 39424 KB
# physical id	: 0
# siblings	: 4
# core id		: 1
# cpu cores	: 2
# apicid		: 3
# initial apicid	: 3
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm mpx avx512f avx512dq rdseed adx smap clflushopt clwb avx512cd avx512bw avx512vl xsaveopt xsavec xgetbv1 xsaves arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs taa
# bogomips	: 4000.34
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 46 bits physical, 48 bits virtual
# power management:

# %% [markdown]
# ## 1. Data Preprocessing
# ---

# %% [markdown]
# ### 1) Data Import

# %%
# 바꿔서 살펴 볼 것들
# CALTECH, CIFAR100, FER, MIT
data_name = 'MIT'
gan_type = 'No_GAN'
number = '1'
size = 299 # sizes after cropping
super_size = 330 # sizes before cropping 
input_sizes = (size,size,3)
batch_sizes = 64
weight_decay = 1e-3
epochs = 70

# %%
# 참고 : https://stackoverflow.com/questions/32419510/how-to-get-reproducible-results-in-keras/52897216#52897216
# setting the seed number for random number generation for reproducibility.

from numpy.random import seed
import random


if number=='1':
    seed_num = 200225
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)
elif number=='2':
    seed_num = 727
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)
elif number=='3':
    seed_num = 115
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)
elif number=='4':
    seed_num = 501
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)
elif number=='5':
    seed_num = 517
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)

# %%
# data import

if data_name=='FER' :
    x_train =  np.zeros(28698)
    x_valid = np.zeros(3589)
    x_test = np.zeros(3588)
    classes = 7 
    tr_center = [0.50793296, 0.50793296, 0.50793296]
elif data_name=='MIT':
    x_train = np.zeros(12466)
    x_valid = np.zeros(1564)
    x_test = np.zeros(1590)
    classes = 67 
    tr_center = [0.47916578, 0.42029615, 0.36046057]
elif data_name=='CALTECH':
    x_train = np.zeros(24510)
    x_valid = np.zeros(2980)
    x_test = np.zeros(3118)
    classes = 257
    tr_center = [0.51397761, 0.49525248, 0.46555727]
elif data_name=='CIFAR100':
    x_train = np.zeros(44923)
    x_valid = np.zeros(5077)
    x_test = np.zeros(10000)
    classes = 100
    tr_center = [0.53442983, 0.51355958, 0.46462564]

# %%
dir = os.path.join(os.getcwd(),data_name,gan_type)

# %% [markdown]
# ### 2) Data Augmentation

# %%
# 참고 : https://jkjung-avt.github.io/keras-image-cropping/

def random_crop(img, random_crop_size):
    # Note: image_data_format is 'channel_last'
    assert img.shape[2] == 3 # img.shape[2] 가 3(rgb)이 아니면 assertion error 발생
    height, width = img.shape[0], img.shape[1]
    dy, dx = random_crop_size
    x = np.random.randint(0, width - dx + 1)
    y = np.random.randint(0, height - dy + 1)
    return img[y:(y+dy), x:(x+dx), :]


def crop_generator(batches, crop_length):
    """Take as input a Keras ImageGen (Iterator) and generate random
    crops from the image batches generated by the original iterator.
    """
    while True:
        batch_x, batch_y = next(batches)
        batch_crops = np.zeros((batch_x.shape[0], crop_length, crop_length, 3))
        for i in range(batch_x.shape[0]):
            batch_crops[i] = random_crop(batch_x[i], (crop_length, crop_length))
        yield (batch_crops, batch_y)

# %%
from tensorflow.keras.preprocessing.image import img_to_array,load_img
import glob

# 데이터 전체에 대해 centering 진행함.

def read_cal_image(img_path): 
    x = img_to_array(load_img(img_path)) # x는 채널별 평균값
    y = x.shape[0] * x.shape[1]# y는 데이터별 픽셀 수 (비중)

    x = 1/255. * x # scaling하고, centering값을 뽑아냄.
    x = np.mean(x, axis=(0,1))
    
    return np.hstack([x,y])

def calculate_centered_mean(dataset_path,x_train=x_train):
    num = len(x_train)
    space = np.empty((num,4))
    i=0

    for p in glob.glob(os.path.join(dataset_path,'*/*.*')) :
        space[i] = read_cal_image(p)
        i += 1

    ratio = space[:,3] / np.sum(space[:,3])

    return np.average(space[:,0:3],axis=0,weights=ratio)


# 아래의 함수를 돌려서 나온 결과값을 중심화 값으로 설정.

# train_mean = calculate_centered_mean(os.path.join(dir,'data/train')).reshape((1,1,3))

# %%
datagen_tr = ImageDataGenerator(
    rescale=1/255.,
    horizontal_flip=True,
    featurewise_center=True,
    featurewise_std_normalization=False,
    rotation_range=10,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=[0.9,1.0],
    fill_mode = 'nearest')
datagen_val = ImageDataGenerator(rescale=1/255.,featurewise_center=True)
datagen_tes = ImageDataGenerator(rescale=1/255.,featurewise_center=True)

# 원래는 이 자리에 fit 매서드를 써야하지만, 그냥 내가 중심화함수를 만들고 적용함. 

# 중심화 설정
datagen_tr.mean = np.array(tr_center, dtype=np.float32).reshape((1,1,3)) # RGB
datagen_val.mean = np.array(tr_center, dtype=np.float32).reshape((1,1,3)) # RGB
datagen_tes.mean = np.array(tr_center, dtype=np.float32).reshape((1,1,3)) # RGB

# %%
train_batches = datagen_tr.flow_from_directory(directory=os.path.join(dir,'data/train'),target_size=(super_size,super_size),batch_size=batch_sizes,class_mode='categorical') # fer : 28698 / mit : 12466 / caltech : 24509 / cifar : 44923
train_generator= crop_generator(train_batches, size)
valid_generator = datagen_val.flow_from_directory(directory=os.path.join(dir,'data/valid'),target_size=(size,size),batch_size=batch_sizes,class_mode='categorical') # fer : 3589 / mit : 1564 / caltech : 2980 / cifar : 5077
test_generator = datagen_tes.flow_from_directory(directory=os.path.join(dir,'data/test'),target_size=(size,size),batch_size=batch_sizes,class_mode='categorical') # fer : 3588 / mit : 1590 / caltech : 3118 / cifar : 10000
# Out:
# Found 12466 images belonging to 67 classes.
# Found 1564 images belonging to 67 classes.
# Found 1590 images belonging to 67 classes.

# %% [markdown]
# ## 2. Support Functions & Almost Original Inception-ResNet-V1

# %% [markdown]
# ### 1) Support Functions

# %%
# def lr_schedule(epoch):
#     init_lr = 1e-4
#     k = 0.04
#     lr = init_lr * np.exp(-k*epoch)
#     print('Learning rate: ', lr)
#     return lr

def lr_schedule(epoch):
    lr = 1e-3
    if epoch < 30:
        lr = lr
    elif epoch < 60 :
        lr = lr * 0.1
    else:
        lr = lr * 0.01
    print('Learning rate: ', lr)
    return lr

# %%
def conv2d_bn(x, filters, kernel_size, strides=1, padding='same', activation='relu', use_bias=False, name=None, weight_decay=weight_decay):

    x = Conv2D(filters, kernel_size, strides=strides, padding=padding,  use_bias=use_bias, name=name, kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(x)
    if not use_bias:
        bn_axis =  3
        bn_name = None if name is None else '{name}_bn'.format(name=name)
        x = BatchNormalization(axis=bn_axis, scale=False, name=bn_name)(x)
        
    if activation is not None:
        ac_name = None if name is None else '{name}_ac'.format(name=name)
        x = Activation(activation, name=ac_name)(x)
    return x

# %%
def inception_resnet_block(x, scale, block_type, block_idx, activation='relu'):
 
    if block_type == 'block35':
        branch_0 = conv2d_bn(x, 32, 1)
        branch_1 = conv2d_bn(x, 32, 1)
        branch_1 = conv2d_bn(branch_1, 32, 3)
        branch_2 = conv2d_bn(x, 32, 1)
        branch_2 = conv2d_bn(branch_2, 32, 3)
        branch_2 = conv2d_bn(branch_2, 32, 3)
        branches = [branch_0, branch_1, branch_2]
    elif block_type == 'block17':
        branch_0 = conv2d_bn(x, 128, 1)
        branch_1 = conv2d_bn(x, 128, 1)
        branch_1 = conv2d_bn(branch_1, 128, [1, 7])
        branch_1 = conv2d_bn(branch_1, 128, [7, 1])
        branches = [branch_0, branch_1]
    elif block_type == 'block8':
        branch_0 = conv2d_bn(x, 192, 1)
        branch_1 = conv2d_bn(x, 192, 1)
        branch_1 = conv2d_bn(branch_1, 192, [1, 3])
        branch_1 = conv2d_bn(branch_1, 192, [3, 1])
        branches = [branch_0, branch_1]
    else:
        raise ValueError('Unknown Inception-ResNet block type. '
                         'Expects "block35", "block17" or "block8", '
                         'but got: {block_type}'.format(block_type=block_type))

    block_name = '{block_type}_{block_idx}'.format(block_type=block_type, block_idx=block_idx)
    channel_axis = 3
    mixed = Concatenate(axis=channel_axis, name='{block_name}_mixed'.format(block_name=block_name))(branches)
    up = conv2d_bn(mixed,
                   K.int_shape(x)[channel_axis],
                   1,
                   activation=None,
                   use_bias=True,
                   name='{block_name}_conv'.format(block_name=block_name))

    x = Lambda(lambda inputs, scale_: inputs[0] + inputs[1] * scale_,
               output_shape=K.int_shape(x)[1:],
               arguments={'scale_': scale},
               name=block_name)([x, up])
    if activation is not None:
        x = Activation(activation, name='{block_name}_ac'.format(block_name=block_name))(x)

    return x

# %%
def Inception_ResNet_v1(input_shape=None, weight_decay=weight_decay, classes=classes, name=None):
 
    img_input = Input(shape=input_shape)

    # Stem block: 35 x 35 x 192
    x = conv2d_bn(img_input, 32, 3, strides=2, padding='valid')
    x = conv2d_bn(x, 32, 3, padding='valid')
    x = conv2d_bn(x, 64, 3)
    x = MaxPooling2D(3, strides=2)(x)
    x = conv2d_bn(x, 80, 1)
    x = conv2d_bn(x, 192, 3, padding='valid')
    x = conv2d_bn(x, 256, 3, strides=2, padding='valid')

    channel_axis = 3

    # 5x block35 (Inception-ResNet-A block): 35 x 35 x 320
    for block_idx in range(1, 6):
        x = inception_resnet_block(x,
                                   scale=0.17,
                                   block_type='block35',
                                   block_idx=block_idx)

    # Mixed 6a (Reduction-A block): 17 x 17 
    branch_0 = conv2d_bn(x, 384, 3, strides=2, padding='valid')
    branch_1 = conv2d_bn(x, 192, 1)
    branch_1 = conv2d_bn(branch_1, 192, 3)
    branch_1 = conv2d_bn(branch_1, 256, 3, strides=2, padding='valid')
    branch_pool = MaxPooling2D(3, strides=2, padding='valid')(x)
    branches = [branch_0, branch_1, branch_pool]
    x = Concatenate(axis=channel_axis, name='mixed_6a')(branches)


    # 10x block17 (Inception-ResNet-B block): 17 x 17 x 960
    for block_idx in range(1, 11):
        x = inception_resnet_block(x,
                                   scale=0.1,
                                   block_type='block17',
                                   block_idx=block_idx)

    # Mixed 7a (Reduction-B block): 8 x 8 
    branch_0 = conv2d_bn(x, 256, 1)
    branch_0 = conv2d_bn(branch_0, 384, 3, strides=2, padding='valid')
    branch_1 = conv2d_bn(x, 256, 1)
    branch_1 = conv2d_bn(branch_1, 256, 3, strides=2, padding='valid')
    branch_2 = conv2d_bn(x, 256, 1)
    branch_2 = conv2d_bn(branch_2, 256, 3)
    branch_2 = conv2d_bn(branch_2, 256, 3, strides=2, padding='valid')
    branch_pool = MaxPooling2D(3, strides=2, padding='valid')(x)
    branches = [branch_0, branch_1, branch_2, branch_pool]
    x = Concatenate(axis=channel_axis, name='mixed_7a')(branches)


    # 5x block8 (Inception-ResNet-C block): 8 x 8 x 1856
    for block_idx in range(1, 5):
        x = inception_resnet_block(x,
                                   scale=0.2,
                                   block_type='block8',
                                   block_idx=block_idx)
    x = inception_resnet_block(x,
                               scale=1.,
                               activation=None,
                               block_type='block8',
                               block_idx=10)


    x = GlobalAveragePooling2D(name='avg_pool')(x)
    x = Dropout(0.2)(x)
    x = Dense(classes, use_bias=False, kernel_regularizer=l2(weight_decay), activation='softmax', name='predictions')(x)

    # Ensure that the model takes into account
    # any potential predecessors of `input_tensor`
    inputs = img_input

    # Create model
    model = Model(inputs, x, name=name)

    return model

# %% [markdown]
# ### 2) Almost Original Inception-ResNet-V1

# %%
model = Inception_ResNet_v1(input_sizes, classes=classes, name='Inception_ResNet_v1')

# %%
model.summary()
# Out:
# Model: "Inception_ResNet_v1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 299, 299, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 149, 149, 32) 864         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 149, 149, 32) 96          conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 149, 149, 32) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 147, 147, 32) 9216        activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 147, 147, 32) 96          conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 147, 147, 32) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 147, 147, 64) 18432       activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 147, 147, 64) 192         conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 147, 147, 64) 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 73, 73, 64)   0           activation_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 73, 73, 80)   5120        max_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 73, 73, 80)   240         conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 73, 73, 80)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 71, 71, 192)  138240      activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 71, 71, 192)  576         conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 71, 71, 192)  0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 35, 35, 256)  442368      activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 35, 35, 256)  768         conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 35, 35, 256)  0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 35, 35, 32)   8192        activation_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 35, 35, 32)   96          conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 35, 35, 32)   0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 35, 35, 32)   8192        activation_5[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 35, 35, 32)   9216        activation_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 35, 35, 32)   96          conv2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 35, 35, 32)   96          conv2d_10[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 35, 35, 32)   0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 35, 35, 32)   0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 35, 35, 32)   8192        activation_5[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 35, 35, 32)   9216        activation_7[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 35, 35, 32)   9216        activation_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 35, 35, 32)   96          conv2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 35, 35, 32)   96          conv2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 35, 35, 32)   96          conv2d_11[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 35, 35, 32)   0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 35, 35, 32)   0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 35, 35, 32)   0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# block35_1_mixed (Concatenate)   (None, 35, 35, 96)   0           activation_6[0][0]
#                                                                  activation_8[0][0]
#                                                                  activation_11[0][0]
# __________________________________________________________________________________________________
# block35_1_conv (Conv2D)         (None, 35, 35, 256)  24832       block35_1_mixed[0][0]
# __________________________________________________________________________________________________
# block35_1 (Lambda)              (None, 35, 35, 256)  0           activation_5[0][0]
#                                                                  block35_1_conv[0][0]
# __________________________________________________________________________________________________
# block35_1_ac (Activation)       (None, 35, 35, 256)  0           block35_1[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 35, 35, 32)   8192        block35_1_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 35, 35, 32)   96          conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 35, 35, 32)   0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 35, 35, 32)   8192        block35_1_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 35, 35, 32)   9216        activation_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 35, 35, 32)   96          conv2d_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 35, 35, 32)   96          conv2d_16[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 35, 35, 32)   0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 35, 35, 32)   0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 35, 35, 32)   8192        block35_1_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 35, 35, 32)   9216        activation_13[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 35, 35, 32)   9216        activation_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 35, 35, 32)   96          conv2d_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 35, 35, 32)   96          conv2d_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 35, 35, 32)   96          conv2d_17[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 35, 35, 32)   0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 35, 35, 32)   0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 35, 35, 32)   0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# block35_2_mixed (Concatenate)   (None, 35, 35, 96)   0           activation_12[0][0]
#                                                                  activation_14[0][0]
#                                                                  activation_17[0][0]
# __________________________________________________________________________________________________
# block35_2_conv (Conv2D)         (None, 35, 35, 256)  24832       block35_2_mixed[0][0]
# __________________________________________________________________________________________________
# block35_2 (Lambda)              (None, 35, 35, 256)  0           block35_1_ac[0][0]
#                                                                  block35_2_conv[0][0]
# __________________________________________________________________________________________________
# block35_2_ac (Activation)       (None, 35, 35, 256)  0           block35_2[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 35, 35, 32)   8192        block35_2_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 35, 35, 32)   96          conv2d_21[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 35, 35, 32)   0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 35, 35, 32)   8192        block35_2_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 35, 35, 32)   9216        activation_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 35, 35, 32)   96          conv2d_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 35, 35, 32)   96          conv2d_22[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 35, 35, 32)   0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 35, 35, 32)   0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 35, 35, 32)   8192        block35_2_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 35, 35, 32)   9216        activation_19[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 35, 35, 32)   9216        activation_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 35, 35, 32)   96          conv2d_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 35, 35, 32)   96          conv2d_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 35, 35, 32)   96          conv2d_23[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 35, 35, 32)   0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 35, 35, 32)   0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 35, 35, 32)   0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# block35_3_mixed (Concatenate)   (None, 35, 35, 96)   0           activation_18[0][0]
#                                                                  activation_20[0][0]
#                                                                  activation_23[0][0]
# __________________________________________________________________________________________________
# block35_3_conv (Conv2D)         (None, 35, 35, 256)  24832       block35_3_mixed[0][0]
# __________________________________________________________________________________________________
# block35_3 (Lambda)              (None, 35, 35, 256)  0           block35_2_ac[0][0]
#                                                                  block35_3_conv[0][0]
# __________________________________________________________________________________________________
# block35_3_ac (Activation)       (None, 35, 35, 256)  0           block35_3[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 35, 35, 32)   8192        block35_3_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 35, 35, 32)   96          conv2d_27[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 35, 35, 32)   0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 35, 35, 32)   8192        block35_3_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 35, 35, 32)   9216        activation_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 35, 35, 32)   96          conv2d_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 35, 35, 32)   96          conv2d_28[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 35, 35, 32)   0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 35, 35, 32)   0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 35, 35, 32)   8192        block35_3_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 35, 35, 32)   9216        activation_25[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 35, 35, 32)   9216        activation_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 35, 35, 32)   96          conv2d_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 35, 35, 32)   96          conv2d_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 35, 35, 32)   96          conv2d_29[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 35, 35, 32)   0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 35, 35, 32)   0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 35, 35, 32)   0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# block35_4_mixed (Concatenate)   (None, 35, 35, 96)   0           activation_24[0][0]
#                                                                  activation_26[0][0]
#                                                                  activation_29[0][0]
# __________________________________________________________________________________________________
# block35_4_conv (Conv2D)         (None, 35, 35, 256)  24832       block35_4_mixed[0][0]
# __________________________________________________________________________________________________
# block35_4 (Lambda)              (None, 35, 35, 256)  0           block35_3_ac[0][0]
#                                                                  block35_4_conv[0][0]
# __________________________________________________________________________________________________
# block35_4_ac (Activation)       (None, 35, 35, 256)  0           block35_4[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 35, 35, 32)   8192        block35_4_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 35, 35, 32)   96          conv2d_33[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 35, 35, 32)   0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 35, 35, 32)   8192        block35_4_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 35, 35, 32)   9216        activation_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 35, 35, 32)   96          conv2d_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 35, 35, 32)   96          conv2d_34[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 35, 35, 32)   0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 35, 35, 32)   0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 35, 35, 32)   8192        block35_4_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 35, 35, 32)   9216        activation_31[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 35, 35, 32)   9216        activation_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 35, 35, 32)   96          conv2d_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 35, 35, 32)   96          conv2d_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 35, 35, 32)   96          conv2d_35[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 35, 35, 32)   0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 35, 35, 32)   0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 35, 35, 32)   0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# block35_5_mixed (Concatenate)   (None, 35, 35, 96)   0           activation_30[0][0]
#                                                                  activation_32[0][0]
#                                                                  activation_35[0][0]
# __________________________________________________________________________________________________
# block35_5_conv (Conv2D)         (None, 35, 35, 256)  24832       block35_5_mixed[0][0]
# __________________________________________________________________________________________________
# block35_5 (Lambda)              (None, 35, 35, 256)  0           block35_4_ac[0][0]
#                                                                  block35_5_conv[0][0]
# __________________________________________________________________________________________________
# block35_5_ac (Activation)       (None, 35, 35, 256)  0           block35_5[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 35, 35, 192)  49152       block35_5_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 35, 35, 192)  576         conv2d_37[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 35, 35, 192)  0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 35, 35, 192)  331776      activation_37[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 35, 35, 192)  576         conv2d_38[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 35, 35, 192)  0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 17, 17, 384)  884736      block35_5_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 17, 17, 256)  442368      activation_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 17, 17, 384)  1152        conv2d_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 17, 17, 256)  768         conv2d_39[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 17, 17, 384)  0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 17, 17, 256)  0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 17, 17, 256)  0           block35_5_ac[0][0]
# __________________________________________________________________________________________________
# mixed_6a (Concatenate)          (None, 17, 17, 896)  0           activation_36[0][0]
#                                                                  activation_39[0][0]
#                                                                  max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 17, 17, 128)  114688      mixed_6a[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 17, 17, 128)  384         conv2d_41[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 17, 17, 128)  0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 17, 17, 128)  114688      activation_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 17, 17, 128)  384         conv2d_42[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 17, 17, 128)  0           batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 17, 17, 128)  114688      mixed_6a[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 17, 17, 128)  114688      activation_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 17, 17, 128)  384         conv2d_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 17, 17, 128)  384         conv2d_43[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 17, 17, 128)  0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 17, 17, 128)  0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# block17_1_mixed (Concatenate)   (None, 17, 17, 256)  0           activation_40[0][0]
#                                                                  activation_43[0][0]
# __________________________________________________________________________________________________
# block17_1_conv (Conv2D)         (None, 17, 17, 896)  230272      block17_1_mixed[0][0]
# __________________________________________________________________________________________________
# block17_1 (Lambda)              (None, 17, 17, 896)  0           mixed_6a[0][0]
#                                                                  block17_1_conv[0][0]
# __________________________________________________________________________________________________
# block17_1_ac (Activation)       (None, 17, 17, 896)  0           block17_1[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 17, 17, 128)  114688      block17_1_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 17, 17, 128)  384         conv2d_45[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 17, 17, 128)  0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 17, 17, 128)  114688      activation_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 17, 17, 128)  384         conv2d_46[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 17, 17, 128)  0           batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 17, 17, 128)  114688      block17_1_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 17, 17, 128)  114688      activation_46[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 17, 17, 128)  384         conv2d_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 17, 17, 128)  384         conv2d_47[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 17, 17, 128)  0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 17, 17, 128)  0           batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# block17_2_mixed (Concatenate)   (None, 17, 17, 256)  0           activation_44[0][0]
#                                                                  activation_47[0][0]
# __________________________________________________________________________________________________
# block17_2_conv (Conv2D)         (None, 17, 17, 896)  230272      block17_2_mixed[0][0]
# __________________________________________________________________________________________________
# block17_2 (Lambda)              (None, 17, 17, 896)  0           block17_1_ac[0][0]
#                                                                  block17_2_conv[0][0]
# __________________________________________________________________________________________________
# block17_2_ac (Activation)       (None, 17, 17, 896)  0           block17_2[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 17, 17, 128)  114688      block17_2_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 17, 17, 128)  384         conv2d_49[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 17, 17, 128)  0           batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 17, 17, 128)  114688      activation_49[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 17, 17, 128)  384         conv2d_50[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, 17, 17, 128)  0           batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 17, 17, 128)  114688      block17_2_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 17, 17, 128)  114688      activation_50[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 17, 17, 128)  384         conv2d_48[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 17, 17, 128)  384         conv2d_51[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 17, 17, 128)  0           batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# activation_51 (Activation)      (None, 17, 17, 128)  0           batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# block17_3_mixed (Concatenate)   (None, 17, 17, 256)  0           activation_48[0][0]
#                                                                  activation_51[0][0]
# __________________________________________________________________________________________________
# block17_3_conv (Conv2D)         (None, 17, 17, 896)  230272      block17_3_mixed[0][0]
# __________________________________________________________________________________________________
# block17_3 (Lambda)              (None, 17, 17, 896)  0           block17_2_ac[0][0]
#                                                                  block17_3_conv[0][0]
# __________________________________________________________________________________________________
# block17_3_ac (Activation)       (None, 17, 17, 896)  0           block17_3[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 17, 17, 128)  114688      block17_3_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, 17, 17, 128)  384         conv2d_53[0][0]
# __________________________________________________________________________________________________
# activation_53 (Activation)      (None, 17, 17, 128)  0           batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 17, 17, 128)  114688      activation_53[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, 17, 17, 128)  384         conv2d_54[0][0]
# __________________________________________________________________________________________________
# activation_54 (Activation)      (None, 17, 17, 128)  0           batch_normalization_54[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 17, 17, 128)  114688      block17_3_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 17, 17, 128)  114688      activation_54[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 17, 17, 128)  384         conv2d_52[0][0]
# __________________________________________________________________________________________________
# batch_normalization_55 (BatchNo (None, 17, 17, 128)  384         conv2d_55[0][0]
# __________________________________________________________________________________________________
# activation_52 (Activation)      (None, 17, 17, 128)  0           batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# activation_55 (Activation)      (None, 17, 17, 128)  0           batch_normalization_55[0][0]
# __________________________________________________________________________________________________
# block17_4_mixed (Concatenate)   (None, 17, 17, 256)  0           activation_52[0][0]
#                                                                  activation_55[0][0]
# __________________________________________________________________________________________________
# block17_4_conv (Conv2D)         (None, 17, 17, 896)  230272      block17_4_mixed[0][0]
# __________________________________________________________________________________________________
# block17_4 (Lambda)              (None, 17, 17, 896)  0           block17_3_ac[0][0]
#                                                                  block17_4_conv[0][0]
# __________________________________________________________________________________________________
# block17_4_ac (Activation)       (None, 17, 17, 896)  0           block17_4[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 17, 17, 128)  114688      block17_4_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_57 (BatchNo (None, 17, 17, 128)  384         conv2d_57[0][0]
# __________________________________________________________________________________________________
# activation_57 (Activation)      (None, 17, 17, 128)  0           batch_normalization_57[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, 17, 17, 128)  114688      activation_57[0][0]
# __________________________________________________________________________________________________
# batch_normalization_58 (BatchNo (None, 17, 17, 128)  384         conv2d_58[0][0]
# __________________________________________________________________________________________________
# activation_58 (Activation)      (None, 17, 17, 128)  0           batch_normalization_58[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 17, 17, 128)  114688      block17_4_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, 17, 17, 128)  114688      activation_58[0][0]
# __________________________________________________________________________________________________
# batch_normalization_56 (BatchNo (None, 17, 17, 128)  384         conv2d_56[0][0]
# __________________________________________________________________________________________________
# batch_normalization_59 (BatchNo (None, 17, 17, 128)  384         conv2d_59[0][0]
# __________________________________________________________________________________________________
# activation_56 (Activation)      (None, 17, 17, 128)  0           batch_normalization_56[0][0]
# __________________________________________________________________________________________________
# activation_59 (Activation)      (None, 17, 17, 128)  0           batch_normalization_59[0][0]
# __________________________________________________________________________________________________
# block17_5_mixed (Concatenate)   (None, 17, 17, 256)  0           activation_56[0][0]
#                                                                  activation_59[0][0]
# __________________________________________________________________________________________________
# block17_5_conv (Conv2D)         (None, 17, 17, 896)  230272      block17_5_mixed[0][0]
# __________________________________________________________________________________________________
# block17_5 (Lambda)              (None, 17, 17, 896)  0           block17_4_ac[0][0]
#                                                                  block17_5_conv[0][0]
# __________________________________________________________________________________________________
# block17_5_ac (Activation)       (None, 17, 17, 896)  0           block17_5[0][0]
# __________________________________________________________________________________________________
# conv2d_61 (Conv2D)              (None, 17, 17, 128)  114688      block17_5_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_61 (BatchNo (None, 17, 17, 128)  384         conv2d_61[0][0]
# __________________________________________________________________________________________________
# activation_61 (Activation)      (None, 17, 17, 128)  0           batch_normalization_61[0][0]
# __________________________________________________________________________________________________
# ...
# __________________________________________________________________________________________________
# batch_normalization_87 (BatchNo (None, 8, 8, 192)    576         conv2d_87[0][0]
# __________________________________________________________________________________________________
# batch_normalization_90 (BatchNo (None, 8, 8, 192)    576         conv2d_90[0][0]
# __________________________________________________________________________________________________
# activation_87 (Activation)      (None, 8, 8, 192)    0           batch_normalization_87[0][0]
# __________________________________________________________________________________________________
# activation_90 (Activation)      (None, 8, 8, 192)    0           batch_normalization_90[0][0]
# __________________________________________________________________________________________________
# block8_1_mixed (Concatenate)    (None, 8, 8, 384)    0           activation_87[0][0]
#                                                                  activation_90[0][0]
# __________________________________________________________________________________________________
# block8_1_conv (Conv2D)          (None, 8, 8, 1792)   689920      block8_1_mixed[0][0]
# __________________________________________________________________________________________________
# block8_1 (Lambda)               (None, 8, 8, 1792)   0           mixed_7a[0][0]
#                                                                  block8_1_conv[0][0]
# __________________________________________________________________________________________________
# block8_1_ac (Activation)        (None, 8, 8, 1792)   0           block8_1[0][0]
# __________________________________________________________________________________________________
# conv2d_92 (Conv2D)              (None, 8, 8, 192)    344064      block8_1_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_92 (BatchNo (None, 8, 8, 192)    576         conv2d_92[0][0]
# __________________________________________________________________________________________________
# activation_92 (Activation)      (None, 8, 8, 192)    0           batch_normalization_92[0][0]
# __________________________________________________________________________________________________
# conv2d_93 (Conv2D)              (None, 8, 8, 192)    110592      activation_92[0][0]
# __________________________________________________________________________________________________
# batch_normalization_93 (BatchNo (None, 8, 8, 192)    576         conv2d_93[0][0]
# __________________________________________________________________________________________________
# activation_93 (Activation)      (None, 8, 8, 192)    0           batch_normalization_93[0][0]
# __________________________________________________________________________________________________
# conv2d_91 (Conv2D)              (None, 8, 8, 192)    344064      block8_1_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_94 (Conv2D)              (None, 8, 8, 192)    110592      activation_93[0][0]
# __________________________________________________________________________________________________
# batch_normalization_91 (BatchNo (None, 8, 8, 192)    576         conv2d_91[0][0]
# __________________________________________________________________________________________________
# batch_normalization_94 (BatchNo (None, 8, 8, 192)    576         conv2d_94[0][0]
# __________________________________________________________________________________________________
# activation_91 (Activation)      (None, 8, 8, 192)    0           batch_normalization_91[0][0]
# __________________________________________________________________________________________________
# activation_94 (Activation)      (None, 8, 8, 192)    0           batch_normalization_94[0][0]
# __________________________________________________________________________________________________
# block8_2_mixed (Concatenate)    (None, 8, 8, 384)    0           activation_91[0][0]
#                                                                  activation_94[0][0]
# __________________________________________________________________________________________________
# block8_2_conv (Conv2D)          (None, 8, 8, 1792)   689920      block8_2_mixed[0][0]
# __________________________________________________________________________________________________
# block8_2 (Lambda)               (None, 8, 8, 1792)   0           block8_1_ac[0][0]
#                                                                  block8_2_conv[0][0]
# __________________________________________________________________________________________________
# block8_2_ac (Activation)        (None, 8, 8, 1792)   0           block8_2[0][0]
# __________________________________________________________________________________________________
# conv2d_96 (Conv2D)              (None, 8, 8, 192)    344064      block8_2_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_96 (BatchNo (None, 8, 8, 192)    576         conv2d_96[0][0]
# __________________________________________________________________________________________________
# activation_96 (Activation)      (None, 8, 8, 192)    0           batch_normalization_96[0][0]
# __________________________________________________________________________________________________
# conv2d_97 (Conv2D)              (None, 8, 8, 192)    110592      activation_96[0][0]
# __________________________________________________________________________________________________
# batch_normalization_97 (BatchNo (None, 8, 8, 192)    576         conv2d_97[0][0]
# __________________________________________________________________________________________________
# activation_97 (Activation)      (None, 8, 8, 192)    0           batch_normalization_97[0][0]
# __________________________________________________________________________________________________
# conv2d_95 (Conv2D)              (None, 8, 8, 192)    344064      block8_2_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_98 (Conv2D)              (None, 8, 8, 192)    110592      activation_97[0][0]
# __________________________________________________________________________________________________
# batch_normalization_95 (BatchNo (None, 8, 8, 192)    576         conv2d_95[0][0]
# __________________________________________________________________________________________________
# batch_normalization_98 (BatchNo (None, 8, 8, 192)    576         conv2d_98[0][0]
# __________________________________________________________________________________________________
# activation_95 (Activation)      (None, 8, 8, 192)    0           batch_normalization_95[0][0]
# __________________________________________________________________________________________________
# activation_98 (Activation)      (None, 8, 8, 192)    0           batch_normalization_98[0][0]
# __________________________________________________________________________________________________
# block8_3_mixed (Concatenate)    (None, 8, 8, 384)    0           activation_95[0][0]
#                                                                  activation_98[0][0]
# __________________________________________________________________________________________________
# block8_3_conv (Conv2D)          (None, 8, 8, 1792)   689920      block8_3_mixed[0][0]
# __________________________________________________________________________________________________
# block8_3 (Lambda)               (None, 8, 8, 1792)   0           block8_2_ac[0][0]
#                                                                  block8_3_conv[0][0]
# __________________________________________________________________________________________________
# block8_3_ac (Activation)        (None, 8, 8, 1792)   0           block8_3[0][0]
# __________________________________________________________________________________________________
# conv2d_100 (Conv2D)             (None, 8, 8, 192)    344064      block8_3_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_100 (BatchN (None, 8, 8, 192)    576         conv2d_100[0][0]
# __________________________________________________________________________________________________
# activation_100 (Activation)     (None, 8, 8, 192)    0           batch_normalization_100[0][0]
# __________________________________________________________________________________________________
# conv2d_101 (Conv2D)             (None, 8, 8, 192)    110592      activation_100[0][0]
# __________________________________________________________________________________________________
# batch_normalization_101 (BatchN (None, 8, 8, 192)    576         conv2d_101[0][0]
# __________________________________________________________________________________________________
# activation_101 (Activation)     (None, 8, 8, 192)    0           batch_normalization_101[0][0]
# __________________________________________________________________________________________________
# conv2d_99 (Conv2D)              (None, 8, 8, 192)    344064      block8_3_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_102 (Conv2D)             (None, 8, 8, 192)    110592      activation_101[0][0]
# __________________________________________________________________________________________________
# batch_normalization_99 (BatchNo (None, 8, 8, 192)    576         conv2d_99[0][0]
# __________________________________________________________________________________________________
# batch_normalization_102 (BatchN (None, 8, 8, 192)    576         conv2d_102[0][0]
# __________________________________________________________________________________________________
# activation_99 (Activation)      (None, 8, 8, 192)    0           batch_normalization_99[0][0]
# __________________________________________________________________________________________________
# activation_102 (Activation)     (None, 8, 8, 192)    0           batch_normalization_102[0][0]
# __________________________________________________________________________________________________
# block8_4_mixed (Concatenate)    (None, 8, 8, 384)    0           activation_99[0][0]
#                                                                  activation_102[0][0]
# __________________________________________________________________________________________________
# block8_4_conv (Conv2D)          (None, 8, 8, 1792)   689920      block8_4_mixed[0][0]
# __________________________________________________________________________________________________
# block8_4 (Lambda)               (None, 8, 8, 1792)   0           block8_3_ac[0][0]
#                                                                  block8_4_conv[0][0]
# __________________________________________________________________________________________________
# block8_4_ac (Activation)        (None, 8, 8, 1792)   0           block8_4[0][0]
# __________________________________________________________________________________________________
# conv2d_104 (Conv2D)             (None, 8, 8, 192)    344064      block8_4_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_104 (BatchN (None, 8, 8, 192)    576         conv2d_104[0][0]
# __________________________________________________________________________________________________
# activation_104 (Activation)     (None, 8, 8, 192)    0           batch_normalization_104[0][0]
# __________________________________________________________________________________________________
# conv2d_105 (Conv2D)             (None, 8, 8, 192)    110592      activation_104[0][0]
# __________________________________________________________________________________________________
# batch_normalization_105 (BatchN (None, 8, 8, 192)    576         conv2d_105[0][0]
# __________________________________________________________________________________________________
# activation_105 (Activation)     (None, 8, 8, 192)    0           batch_normalization_105[0][0]
# __________________________________________________________________________________________________
# conv2d_103 (Conv2D)             (None, 8, 8, 192)    344064      block8_4_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_106 (Conv2D)             (None, 8, 8, 192)    110592      activation_105[0][0]
# __________________________________________________________________________________________________
# batch_normalization_103 (BatchN (None, 8, 8, 192)    576         conv2d_103[0][0]
# __________________________________________________________________________________________________
# batch_normalization_106 (BatchN (None, 8, 8, 192)    576         conv2d_106[0][0]
# __________________________________________________________________________________________________
# activation_103 (Activation)     (None, 8, 8, 192)    0           batch_normalization_103[0][0]
# __________________________________________________________________________________________________
# activation_106 (Activation)     (None, 8, 8, 192)    0           batch_normalization_106[0][0]
# __________________________________________________________________________________________________
# block8_10_mixed (Concatenate)   (None, 8, 8, 384)    0           activation_103[0][0]
#                                                                  activation_106[0][0]
# __________________________________________________________________________________________________
# block8_10_conv (Conv2D)         (None, 8, 8, 1792)   689920      block8_10_mixed[0][0]
# __________________________________________________________________________________________________
# block8_10 (Lambda)              (None, 8, 8, 1792)   0           block8_4_ac[0][0]
#                                                                  block8_10_conv[0][0]
# __________________________________________________________________________________________________
# avg_pool (GlobalAveragePooling2 (None, 1792)         0           block8_10[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 1792)         0           avg_pool[0][0]
# __________________________________________________________________________________________________
# predictions (Dense)             (None, 67)           120064      dropout[0][0]
# ==================================================================================================
# Total params: 21,096,912
# Trainable params: 21,069,872
# Non-trainable params: 27,040
# __________________________________________________________________________________________________

# %%
# 폴더 생성

os.makedirs(os.path.join(dir,'model_output',number,model.name), exist_ok=True)
os.makedirs(os.path.join(dir,'train_valid_output',number), exist_ok=True)

# %%
# 참고 : https://github.com/OverLordGoldDragon/keras-adamw

import sys
sys.path.append('/content/drive/My Drive/Colab Notebooks/Paper')
import utils
import optimizers_v2
from utils import get_weight_decays, fill_dict_in_order
from utils import reset_seeds, K_eval
from optimizers_v2 import AdamW, NadamW, SGDW

# %%
# top-5 accuracy 출력
import functools
top5_acc = functools.partial(ks.metrics.top_k_categorical_accuracy, k=5)
top5_acc.__name__ = 'top5_acc'

# %%
#optimizer = SGDW(model=model, use_cosine_annealing=False, total_iterations = len(x_train) // batch_sizes, nesterov=True, momentum=0.9)
optimizer = AdamW(model=model, use_cosine_annealing=False, total_iterations = len(x_train) // batch_sizes)
#optimizer = Adam()
filepath =  os.path.join(dir,'model_output',number,model.name,'{epoch:03d}.h5')

callbacks_list = [ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_weights_only=False, save_best_only=True, mode='min'),
                  ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_weights_only=False, save_best_only=True, mode='max'),
                  #ReduceLROnPlateau(monitor='val_loss',patience=3,factor=0.1,min_lr=1e-5),
                  LearningRateScheduler(lr_schedule,verbose=1)
                  ]
                  
model.compile(optimizer, loss = 'categorical_crossentropy', metrics=['accuracy',top5_acc,macro_f1score])

# %%
######## flow_from_directory
history = model.fit(train_generator, steps_per_epoch=int(len(x_train)/batch_sizes),  validation_data = valid_generator, epochs=epochs , verbose=1 , callbacks = callbacks_list , validation_steps=int(len(x_valid)/batch_sizes))
# Out:
# Learning rate:  0.001
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 1/70
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_1/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_2/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_3/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_4/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_5/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_9/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_7/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_10/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_6/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_8/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_11/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for block35_1_conv/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_15/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_13/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_16/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_12/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_14/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_17/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for block35_2_conv/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_21/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_19/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_22/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_18/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_20/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_23/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for block35_3_conv/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_27/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_25/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_28/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_24/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_26/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_29/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for block35_4_conv/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_33/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_31/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_34/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_30/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_32/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_35/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for block35_5_conv/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_37/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_38/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_36/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_39/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_41/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_42/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_40/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_43/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for block17_1_conv/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_45/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_46/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_44/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_47/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for block17_2_conv/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_49/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_50/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_48/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_51/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for block17_3_conv/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_53/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_54/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_52/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_55/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for block17_4_conv/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_57/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_58/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_56/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_59/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for block17_5_conv/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_61/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_62/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_60/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_63/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for block17_6_conv/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_65/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_66/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_64/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_67/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for block17_7_conv/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_69/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_70/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_68/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_71/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for block17_8_conv/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_73/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_74/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_72/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_75/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for block17_9_conv/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_77/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_78/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_76/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_79/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for block17_10_conv/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_84/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_80/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_82/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_85/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_81/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_83/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_86/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_88/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_89/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_87/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_90/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for block8_1_conv/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_92/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_93/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_91/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_94/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for block8_2_conv/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_96/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_97/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_95/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_98/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for block8_3_conv/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_100/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_101/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_99/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_102/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for block8_4_conv/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_104/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_105/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_103/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_106/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for block8_10_conv/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for predictions/kernel:0
# 194/194 [==============================] - ETA: 0s - loss: 3.9131 - accuracy: 0.1216 - top5_acc: 0.3698 - macro_f1score: 0.0039
# Epoch 00001: val_loss improved from inf to 4.68541, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/Inception_ResNet_v1/001.h5
#
# Epoch 00001: val_accuracy improved from -inf to 0.03711, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/Inception_ResNet_v1/001.h5
# 194/194 [==============================] - 3554s 18s/step - loss: 3.9131 - accuracy: 0.1216 - top5_acc: 0.3698 - macro_f1score: 0.0039 - val_loss: 4.6854 - val_accuracy: 0.0371 - val_top5_acc: 0.1608 - val_macro_f1score: 9.3284e-04
# Learning rate:  0.001
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 2/70
# 194/194 [==============================] - ETA: 0s - loss: 3.1425 - accuracy: 0.1990 - top5_acc: 0.5067 - macro_f1score: 0.0145
# Epoch 00002: val_loss improved from 4.68541 to 3.43785, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/Inception_ResNet_v1/002.h5
#
# Epoch 00002: val_accuracy improved from 0.03711 to 0.18815, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/Inception_ResNet_v1/002.h5
# 194/194 [==============================] - 419s 2s/step - loss: 3.1425 - accuracy: 0.1990 - top5_acc: 0.5067 - macro_f1score: 0.0145 - val_loss: 3.4379 - val_accuracy: 0.1882 - val_top5_acc: 0.4993 - val_macro_f1score: 0.0195
# Learning rate:  0.001
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 3/70
# 194/194 [==============================] - ETA: 0s - loss: 2.7835 - accuracy: 0.2663 - top5_acc: 0.6063 - macro_f1score: 0.0369
# Epoch 00003: val_loss improved from 3.43785 to 2.79460, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/Inception_ResNet_v1/003.h5
#
# Epoch 00003: val_accuracy improved from 0.18815 to 0.27018, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/Inception_ResNet_v1/003.h5
# 194/194 [==============================] - 416s 2s/step - loss: 2.7835 - accuracy: 0.2663 - top5_acc: 0.6063 - macro_f1score: 0.0369 - val_loss: 2.7946 - val_accuracy: 0.2702 - val_top5_acc: 0.6003 - val_macro_f1score: 0.0334
# Learning rate:  0.001
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 4/70
# 194/194 [==============================] - ETA: 0s - loss: 2.4810 - accuracy: 0.3370 - top5_acc: 0.6795 - macro_f1score: 0.0670
# Epoch 00004: val_loss improved from 2.79460 to 2.62352, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/Inception_ResNet_v1/004.h5
#
# Epoch 00004: val_accuracy improved from 0.27018 to 0.29492, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/Inception_ResNet_v1/004.h5
# 194/194 [==============================] - 412s 2s/step - loss: 2.4810 - accuracy: 0.3370 - top5_acc: 0.6795 - macro_f1score: 0.0670 - val_loss: 2.6235 - val_accuracy: 0.2949 - val_top5_acc: 0.6556 - val_macro_f1score: 0.0707
# Learning rate:  0.001
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 5/70
# 194/194 [==============================] - ETA: 0s - loss: 2.1807 - accuracy: 0.4055 - top5_acc: 0.7444 - macro_f1score: 0.1088
# Epoch 00005: val_loss did not improve from 2.62352
#
# Epoch 00005: val_accuracy improved from 0.29492 to 0.31055, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/Inception_ResNet_v1/005.h5
# 194/194 [==============================] - 407s 2s/step - loss: 2.1807 - accuracy: 0.4055 - top5_acc: 0.7444 - macro_f1score: 0.1088 - val_loss: 2.6713 - val_accuracy: 0.3105 - val_top5_acc: 0.6406 - val_macro_f1score: 0.0857
# Learning rate:  0.001
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 6/70
# 194/194 [==============================] - ETA: 0s - loss: 1.9708 - accuracy: 0.4618 - top5_acc: 0.7845 - macro_f1score: 0.1421
# Epoch 00006: val_loss improved from 2.62352 to 2.58135, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/Inception_ResNet_v1/006.h5
#
# Epoch 00006: val_accuracy improved from 0.31055 to 0.35221, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/Inception_ResNet_v1/006.h5
# 194/194 [==============================] - 408s 2s/step - loss: 1.9708 - accuracy: 0.4618 - top5_acc: 0.7845 - macro_f1score: 0.1421 - val_loss: 2.5814 - val_accuracy: 0.3522 - val_top5_acc: 0.6992 - val_macro_f1score: 0.1070
# Learning rate:  0.001
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 7/70
# 194/194 [==============================] - ETA: 0s - loss: 1.7619 - accuracy: 0.5081 - top5_acc: 0.8208 - macro_f1score: 0.1770
# Epoch 00007: val_loss improved from 2.58135 to 2.23612, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/Inception_ResNet_v1/007.h5
#
# Epoch 00007: val_accuracy improved from 0.35221 to 0.40951, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/Inception_ResNet_v1/007.h5
# 194/194 [==============================] - 409s 2s/step - loss: 1.7619 - accuracy: 0.5081 - top5_acc: 0.8208 - macro_f1score: 0.1770 - val_loss: 2.2361 - val_accuracy: 0.4095 - val_top5_acc: 0.7513 - val_macro_f1score: 0.1429
# Learning rate:  0.001
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 8/70
# 194/194 [==============================] - ETA: 0s - loss: 1.6274 - accuracy: 0.5362 - top5_acc: 0.8483 - macro_f1score: 0.1997
# Epoch 00008: val_loss did not improve from 2.23612
#
# Epoch 00008: val_accuracy did not improve from 0.40951
# 194/194 [==============================] - 405s 2s/step - loss: 1.6274 - accuracy: 0.5362 - top5_acc: 0.8483 - macro_f1score: 0.1997 - val_loss: 2.9645 - val_accuracy: 0.3021 - val_top5_acc: 0.6517 - val_macro_f1score: 0.1015
# Learning rate:  0.001
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 9/70
# 194/194 [==============================] - ETA: 0s - loss: 1.5170 - accuracy: 0.5685 - top5_acc: 0.8651 - macro_f1score: 0.2244
# Epoch 00009: val_loss improved from 2.23612 to 2.10434, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/Inception_ResNet_v1/009.h5
#
# Epoch 00009: val_accuracy improved from 0.40951 to 0.46094, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/Inception_ResNet_v1/009.h5
# 194/194 [==============================] - 407s 2s/step - loss: 1.5170 - accuracy: 0.5685 - top5_acc: 0.8651 - macro_f1score: 0.2244 - val_loss: 2.1043 - val_accuracy: 0.4609 - val_top5_acc: 0.7871 - val_macro_f1score: 0.1822
# Learning rate:  0.001
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 10/70
# 194/194 [==============================] - ETA: 0s - loss: 1.3471 - accuracy: 0.6109 - top5_acc: 0.8907 - macro_f1score: 0.2540
# Epoch 00010: val_loss did not improve from 2.10434
#
# Epoch 00010: val_accuracy did not improve from 0.46094
# 194/194 [==============================] - 407s 2s/step - loss: 1.3471 - accuracy: 0.6109 - top5_acc: 0.8907 - macro_f1score: 0.2540 - val_loss: 2.2046 - val_accuracy: 0.4362 - val_top5_acc: 0.7721 - val_macro_f1score: 0.1553
# Learning rate:  0.001
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 11/70
# 194/194 [==============================] - ETA: 0s - loss: 1.2561 - accuracy: 0.6345 - top5_acc: 0.9053 - macro_f1score: 0.2758
# Epoch 00011: val_loss did not improve from 2.10434
#
# Epoch 00011: val_accuracy did not improve from 0.46094
# 194/194 [==============================] - 407s 2s/step - loss: 1.2561 - accuracy: 0.6345 - top5_acc: 0.9053 - macro_f1score: 0.2758 - val_loss: 2.5555 - val_accuracy: 0.4062 - val_top5_acc: 0.7344 - val_macro_f1score: 0.1717
# Learning rate:  0.001
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 12/70
# 194/194 [==============================] - ETA: 0s - loss: 1.2154 - accuracy: 0.6438 - top5_acc: 0.9124 - macro_f1score: 0.2840
# Epoch 00012: val_loss improved from 2.10434 to 1.96156, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/Inception_ResNet_v1/012.h5
#
# Epoch 00012: val_accuracy improved from 0.46094 to 0.46875, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/Inception_ResNet_v1/012.h5
# 194/194 [==============================] - 412s 2s/step - loss: 1.2154 - accuracy: 0.6438 - top5_acc: 0.9124 - macro_f1score: 0.2840 - val_loss: 1.9616 - val_accuracy: 0.4688 - val_top5_acc: 0.8001 - val_macro_f1score: 0.1956
# Learning rate:  0.001
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 13/70
# 194/194 [==============================] - ETA: 0s - loss: 1.0878 - accuracy: 0.6730 - top5_acc: 0.9262 - macro_f1score: 0.3073
# Epoch 00013: val_loss did not improve from 1.96156
#
# Epoch 00013: val_accuracy did not improve from 0.46875
# 194/194 [==============================] - 409s 2s/step - loss: 1.0878 - accuracy: 0.6730 - top5_acc: 0.9262 - macro_f1score: 0.3073 - val_loss: 2.1946 - val_accuracy: 0.4616 - val_top5_acc: 0.7845 - val_macro_f1score: 0.1952
# Learning rate:  0.001
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 14/70
# 194/194 [==============================] - ETA: 0s - loss: 1.0118 - accuracy: 0.7001 - top5_acc: 0.9371 - macro_f1score: 0.3220
# Epoch 00014: val_loss improved from 1.96156 to 1.72310, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/Inception_ResNet_v1/014.h5
#
# Epoch 00014: val_accuracy improved from 0.46875 to 0.53711, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/Inception_ResNet_v1/014.h5
# 194/194 [==============================] - 412s 2s/step - loss: 1.0118 - accuracy: 0.7001 - top5_acc: 0.9371 - macro_f1score: 0.3220 - val_loss: 1.7231 - val_accuracy: 0.5371 - val_top5_acc: 0.8516 - val_macro_f1score: 0.2349
# Learning rate:  0.001
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 15/70
# 194/194 [==============================] - ETA: 0s - loss: 0.9312 - accuracy: 0.7172 - top5_acc: 0.9466 - macro_f1score: 0.3379
# Epoch 00015: val_loss did not improve from 1.72310
#
# Epoch 00015: val_accuracy did not improve from 0.53711
# 194/194 [==============================] - 407s 2s/step - loss: 0.9312 - accuracy: 0.7172 - top5_acc: 0.9466 - macro_f1score: 0.3379 - val_loss: 1.9186 - val_accuracy: 0.5098 - val_top5_acc: 0.8060 - val_macro_f1score: 0.2185
# Learning rate:  0.001
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 16/70
# 194/194 [==============================] - ETA: 0s - loss: 0.8851 - accuracy: 0.7315 - top5_acc: 0.9523 - macro_f1score: 0.3469
# Epoch 00016: val_loss did not improve from 1.72310
#
# Epoch 00016: val_accuracy did not improve from 0.53711
# 194/194 [==============================] - 407s 2s/step - loss: 0.8851 - accuracy: 0.7315 - top5_acc: 0.9523 - macro_f1score: 0.3469 - val_loss: 2.3328 - val_accuracy: 0.4505 - val_top5_acc: 0.7708 - val_macro_f1score: 0.1917
# Learning rate:  0.001
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 17/70
# 194/194 [==============================] - ETA: 0s - loss: 0.8071 - accuracy: 0.7495 - top5_acc: 0.9596 - macro_f1score: 0.3644
# Epoch 00017: val_loss did not improve from 1.72310
#
# Epoch 00017: val_accuracy did not improve from 0.53711
# 194/194 [==============================] - 407s 2s/step - loss: 0.8071 - accuracy: 0.7495 - top5_acc: 0.9596 - macro_f1score: 0.3644 - val_loss: 2.5138 - val_accuracy: 0.5078 - val_top5_acc: 0.8079 - val_macro_f1score: 0.2235
# Learning rate:  0.001
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 18/70
# 194/194 [==============================] - ETA: 0s - loss: 0.7418 - accuracy: 0.7704 - top5_acc: 0.9671 - macro_f1score: 0.3790
# Epoch 00018: val_loss did not improve from 1.72310
#
# Epoch 00018: val_accuracy did not improve from 0.53711
# 194/194 [==============================] - 406s 2s/step - loss: 0.7418 - accuracy: 0.7704 - top5_acc: 0.9671 - macro_f1score: 0.3790 - val_loss: 2.4559 - val_accuracy: 0.4889 - val_top5_acc: 0.7988 - val_macro_f1score: 0.2066
# Learning rate:  0.001
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 19/70
# 194/194 [==============================] - ETA: 0s - loss: 0.7245 - accuracy: 0.7750 - top5_acc: 0.9671 - macro_f1score: 0.3852
# Epoch 00019: val_loss did not improve from 1.72310
#
# Epoch 00019: val_accuracy did not improve from 0.53711
# 194/194 [==============================] - 407s 2s/step - loss: 0.7245 - accuracy: 0.7750 - top5_acc: 0.9671 - macro_f1score: 0.3852 - val_loss: 2.2612 - val_accuracy: 0.4915 - val_top5_acc: 0.7956 - val_macro_f1score: 0.2146
# Learning rate:  0.001
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 20/70
# 194/194 [==============================] - ETA: 0s - loss: 0.6743 - accuracy: 0.7893 - top5_acc: 0.9715 - macro_f1score: 0.3973
# Epoch 00020: val_loss did not improve from 1.72310
#
# Epoch 00020: val_accuracy did not improve from 0.53711
# 194/194 [==============================] - 414s 2s/step - loss: 0.6743 - accuracy: 0.7893 - top5_acc: 0.9715 - macro_f1score: 0.3973 - val_loss: 1.9931 - val_accuracy: 0.5286 - val_top5_acc: 0.8249 - val_macro_f1score: 0.2352
# Learning rate:  0.001
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 21/70
# 194/194 [==============================] - ETA: 0s - loss: 0.5982 - accuracy: 0.8106 - top5_acc: 0.9770 - macro_f1score: 0.4161
# Epoch 00021: val_loss did not improve from 1.72310
#
# Epoch 00021: val_accuracy improved from 0.53711 to 0.53841, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/Inception_ResNet_v1/021.h5
# 194/194 [==============================] - 415s 2s/step - loss: 0.5982 - accuracy: 0.8106 - top5_acc: 0.9770 - macro_f1score: 0.4161 - val_loss: 2.1128 - val_accuracy: 0.5384 - val_top5_acc: 0.8385 - val_macro_f1score: 0.2440
# Learning rate:  0.001
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 22/70
# 194/194 [==============================] - ETA: 0s - loss: 0.5658 - accuracy: 0.8229 - top5_acc: 0.9833 - macro_f1score: 0.4200
# Epoch 00022: val_loss did not improve from 1.72310
#
# Epoch 00022: val_accuracy improved from 0.53841 to 0.55013, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/Inception_ResNet_v1/022.h5
# 194/194 [==============================] - 418s 2s/step - loss: 0.5658 - accuracy: 0.8229 - top5_acc: 0.9833 - macro_f1score: 0.4200 - val_loss: 1.8077 - val_accuracy: 0.5501 - val_top5_acc: 0.8594 - val_macro_f1score: 0.2469
# Learning rate:  0.001
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 23/70
# 194/194 [==============================] - ETA: 0s - loss: 0.4860 - accuracy: 0.8437 - top5_acc: 0.9867 - macro_f1score: 0.4409
# Epoch 00023: val_loss did not improve from 1.72310
#
# Epoch 00023: val_accuracy did not improve from 0.55013
# 194/194 [==============================] - 411s 2s/step - loss: 0.4860 - accuracy: 0.8437 - top5_acc: 0.9867 - macro_f1score: 0.4409 - val_loss: 1.9337 - val_accuracy: 0.5417 - val_top5_acc: 0.8509 - val_macro_f1score: 0.2622
# Learning rate:  0.001
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 24/70
# 194/194 [==============================] - ETA: 0s - loss: 0.4729 - accuracy: 0.8524 - top5_acc: 0.9864 - macro_f1score: 0.4396
# Epoch 00024: val_loss did not improve from 1.72310
#
# Epoch 00024: val_accuracy did not improve from 0.55013
# 194/194 [==============================] - 406s 2s/step - loss: 0.4729 - accuracy: 0.8524 - top5_acc: 0.9864 - macro_f1score: 0.4396 - val_loss: 2.0669 - val_accuracy: 0.5397 - val_top5_acc: 0.8379 - val_macro_f1score: 0.2583
# Learning rate:  0.001
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 25/70
# 194/194 [==============================] - ETA: 0s - loss: 0.4334 - accuracy: 0.8607 - top5_acc: 0.9886 - macro_f1score: 0.4549
# Epoch 00025: val_loss did not improve from 1.72310
#
# Epoch 00025: val_accuracy improved from 0.55013 to 0.57682, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/Inception_ResNet_v1/025.h5
# 194/194 [==============================] - 408s 2s/step - loss: 0.4334 - accuracy: 0.8607 - top5_acc: 0.9886 - macro_f1score: 0.4549 - val_loss: 1.8513 - val_accuracy: 0.5768 - val_top5_acc: 0.8704 - val_macro_f1score: 0.2773
# Learning rate:  0.001
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 26/70
# 194/194 [==============================] - ETA: 0s - loss: 0.3974 - accuracy: 0.8701 - top5_acc: 0.9910 - macro_f1score: 0.4563
# Epoch 00026: val_loss did not improve from 1.72310
#
# Epoch 00026: val_accuracy did not improve from 0.57682
# 194/194 [==============================] - 406s 2s/step - loss: 0.3974 - accuracy: 0.8701 - top5_acc: 0.9910 - macro_f1score: 0.4563 - val_loss: 2.2190 - val_accuracy: 0.5332 - val_top5_acc: 0.8464 - val_macro_f1score: 0.2494
# Learning rate:  0.001
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 27/70
# 194/194 [==============================] - ETA: 0s - loss: 0.3858 - accuracy: 0.8749 - top5_acc: 0.9915 - macro_f1score: 0.4596
# Epoch 00027: val_loss did not improve from 1.72310
#
# Epoch 00027: val_accuracy did not improve from 0.57682
# 194/194 [==============================] - 403s 2s/step - loss: 0.3858 - accuracy: 0.8749 - top5_acc: 0.9915 - macro_f1score: 0.4596 - val_loss: 2.1982 - val_accuracy: 0.5430 - val_top5_acc: 0.8242 - val_macro_f1score: 0.2551
# Learning rate:  0.001
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 28/70
# 194/194 [==============================] - ETA: 0s - loss: 0.3805 - accuracy: 0.8762 - top5_acc: 0.9922 - macro_f1score: 0.4638
# Epoch 00028: val_loss did not improve from 1.72310
#
# Epoch 00028: val_accuracy did not improve from 0.57682
# 194/194 [==============================] - 407s 2s/step - loss: 0.3805 - accuracy: 0.8762 - top5_acc: 0.9922 - macro_f1score: 0.4638 - val_loss: 1.9771 - val_accuracy: 0.5671 - val_top5_acc: 0.8542 - val_macro_f1score: 0.2662
# Learning rate:  0.001
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 29/70
# 194/194 [==============================] - ETA: 0s - loss: 0.3742 - accuracy: 0.8792 - top5_acc: 0.9927 - macro_f1score: 0.4662
# Epoch 00029: val_loss did not improve from 1.72310
#
# Epoch 00029: val_accuracy did not improve from 0.57682
# 194/194 [==============================] - 402s 2s/step - loss: 0.3742 - accuracy: 0.8792 - top5_acc: 0.9927 - macro_f1score: 0.4662 - val_loss: 2.3776 - val_accuracy: 0.5378 - val_top5_acc: 0.8268 - val_macro_f1score: 0.2448
# Learning rate:  0.001
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 30/70
# 194/194 [==============================] - ETA: 0s - loss: 0.3268 - accuracy: 0.8943 - top5_acc: 0.9939 - macro_f1score: 0.4740
# Epoch 00030: val_loss did not improve from 1.72310
#
# Epoch 00030: val_accuracy did not improve from 0.57682
# 194/194 [==============================] - 407s 2s/step - loss: 0.3268 - accuracy: 0.8943 - top5_acc: 0.9939 - macro_f1score: 0.4740 - val_loss: 2.9591 - val_accuracy: 0.4909 - val_top5_acc: 0.8177 - val_macro_f1score: 0.2295
# Learning rate:  0.0001
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 31/70
# 194/194 [==============================] - ETA: 0s - loss: 0.1502 - accuracy: 0.9539 - top5_acc: 0.9994 - macro_f1score: 0.5151
# Epoch 00031: val_loss improved from 1.72310 to 1.42003, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/Inception_ResNet_v1/031.h5
#
# Epoch 00031: val_accuracy improved from 0.57682 to 0.67383, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/Inception_ResNet_v1/031.h5
# 194/194 [==============================] - 410s 2s/step - loss: 0.1502 - accuracy: 0.9539 - top5_acc: 0.9994 - macro_f1score: 0.5151 - val_loss: 1.4200 - val_accuracy: 0.6738 - val_top5_acc: 0.9199 - val_macro_f1score: 0.3328
# Learning rate:  0.0001
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 32/70
# 194/194 [==============================] - ETA: 0s - loss: 0.0745 - accuracy: 0.9799 - top5_acc: 0.9996 - macro_f1score: 0.5374
# Epoch 00032: val_loss did not improve from 1.42003
#
# Epoch 00032: val_accuracy improved from 0.67383 to 0.68945, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/Inception_ResNet_v1/032.h5
# 194/194 [==============================] - 406s 2s/step - loss: 0.0745 - accuracy: 0.9799 - top5_acc: 0.9996 - macro_f1score: 0.5374 - val_loss: 1.4548 - val_accuracy: 0.6895 - val_top5_acc: 0.9180 - val_macro_f1score: 0.3433
# Learning rate:  0.0001
#
# Epoch 00033: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 33/70
# 194/194 [==============================] - ETA: 0s - loss: 0.0582 - accuracy: 0.9827 - top5_acc: 0.9998 - macro_f1score: 0.5339
# Epoch 00033: val_loss did not improve from 1.42003
#
# Epoch 00033: val_accuracy improved from 0.68945 to 0.69076, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/Inception_ResNet_v1/033.h5
# 194/194 [==============================] - 404s 2s/step - loss: 0.0582 - accuracy: 0.9827 - top5_acc: 0.9998 - macro_f1score: 0.5339 - val_loss: 1.5791 - val_accuracy: 0.6908 - val_top5_acc: 0.9141 - val_macro_f1score: 0.3475
# Learning rate:  0.0001
#
# Epoch 00034: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 34/70
# 194/194 [==============================] - ETA: 0s - loss: 0.0502 - accuracy: 0.9853 - top5_acc: 0.9998 - macro_f1score: 0.5353
# Epoch 00034: val_loss did not improve from 1.42003
#
# Epoch 00034: val_accuracy did not improve from 0.69076
# 194/194 [==============================] - 403s 2s/step - loss: 0.0502 - accuracy: 0.9853 - top5_acc: 0.9998 - macro_f1score: 0.5353 - val_loss: 1.6137 - val_accuracy: 0.6771 - val_top5_acc: 0.9193 - val_macro_f1score: 0.3414
# Learning rate:  0.0001
#
# Epoch 00035: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 35/70
# 194/194 [==============================] - ETA: 0s - loss: 0.0459 - accuracy: 0.9874 - top5_acc: 1.0000 - macro_f1score: 0.5402
# Epoch 00035: val_loss did not improve from 1.42003
#
# Epoch 00035: val_accuracy did not improve from 0.69076
# 194/194 [==============================] - 402s 2s/step - loss: 0.0459 - accuracy: 0.9874 - top5_acc: 1.0000 - macro_f1score: 0.5402 - val_loss: 1.5870 - val_accuracy: 0.6901 - val_top5_acc: 0.9186 - val_macro_f1score: 0.3558
# Learning rate:  0.0001
#
# Epoch 00036: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 36/70
# 194/194 [==============================] - ETA: 0s - loss: 0.0405 - accuracy: 0.9879 - top5_acc: 1.0000 - macro_f1score: 0.5445
# Epoch 00036: val_loss did not improve from 1.42003
#
# Epoch 00036: val_accuracy did not improve from 0.69076
# 194/194 [==============================] - 403s 2s/step - loss: 0.0405 - accuracy: 0.9879 - top5_acc: 1.0000 - macro_f1score: 0.5445 - val_loss: 1.6419 - val_accuracy: 0.6803 - val_top5_acc: 0.9173 - val_macro_f1score: 0.3473
# Learning rate:  0.0001
#
# Epoch 00037: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 37/70
# 194/194 [==============================] - ETA: 0s - loss: 0.0376 - accuracy: 0.9904 - top5_acc: 1.0000 - macro_f1score: 0.5453
# Epoch 00037: val_loss did not improve from 1.42003
#
# Epoch 00037: val_accuracy did not improve from 0.69076
# 194/194 [==============================] - 404s 2s/step - loss: 0.0376 - accuracy: 0.9904 - top5_acc: 1.0000 - macro_f1score: 0.5453 - val_loss: 1.7310 - val_accuracy: 0.6732 - val_top5_acc: 0.9115 - val_macro_f1score: 0.3456
# Learning rate:  0.0001
#
# Epoch 00038: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 38/70
# 194/194 [==============================] - ETA: 0s - loss: 0.0371 - accuracy: 0.9902 - top5_acc: 0.9999 - macro_f1score: 0.5419
# Epoch 00038: val_loss did not improve from 1.42003
#
# Epoch 00038: val_accuracy did not improve from 0.69076
# 194/194 [==============================] - 403s 2s/step - loss: 0.0371 - accuracy: 0.9902 - top5_acc: 0.9999 - macro_f1score: 0.5419 - val_loss: 1.6516 - val_accuracy: 0.6836 - val_top5_acc: 0.9199 - val_macro_f1score: 0.3419
# Learning rate:  0.0001
#
# Epoch 00039: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 39/70
# 194/194 [==============================] - ETA: 0s - loss: 0.0348 - accuracy: 0.9911 - top5_acc: 0.9999 - macro_f1score: 0.5437
# Epoch 00039: val_loss did not improve from 1.42003
#
# Epoch 00039: val_accuracy did not improve from 0.69076
# 194/194 [==============================] - 402s 2s/step - loss: 0.0348 - accuracy: 0.9911 - top5_acc: 0.9999 - macro_f1score: 0.5437 - val_loss: 1.6336 - val_accuracy: 0.6829 - val_top5_acc: 0.9141 - val_macro_f1score: 0.3433
# Learning rate:  0.0001
#
# Epoch 00040: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 40/70
# 194/194 [==============================] - ETA: 0s - loss: 0.0323 - accuracy: 0.9926 - top5_acc: 1.0000 - macro_f1score: 0.5420
# Epoch 00040: val_loss did not improve from 1.42003
#
# Epoch 00040: val_accuracy did not improve from 0.69076
# 194/194 [==============================] - 400s 2s/step - loss: 0.0323 - accuracy: 0.9926 - top5_acc: 1.0000 - macro_f1score: 0.5420 - val_loss: 1.6459 - val_accuracy: 0.6751 - val_top5_acc: 0.9167 - val_macro_f1score: 0.3426
# Learning rate:  0.0001
#
# Epoch 00041: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 41/70
# 194/194 [==============================] - ETA: 0s - loss: 0.0320 - accuracy: 0.9921 - top5_acc: 1.0000 - macro_f1score: 0.5431
# Epoch 00041: val_loss did not improve from 1.42003
#
# Epoch 00041: val_accuracy did not improve from 0.69076
# 194/194 [==============================] - 407s 2s/step - loss: 0.0320 - accuracy: 0.9921 - top5_acc: 1.0000 - macro_f1score: 0.5431 - val_loss: 1.7194 - val_accuracy: 0.6517 - val_top5_acc: 0.9076 - val_macro_f1score: 0.3184
# Learning rate:  0.0001
#
# Epoch 00042: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 42/70
# 194/194 [==============================] - ETA: 0s - loss: 0.0313 - accuracy: 0.9928 - top5_acc: 1.0000 - macro_f1score: 0.5398
# Epoch 00042: val_loss did not improve from 1.42003
#
# Epoch 00042: val_accuracy did not improve from 0.69076
# 194/194 [==============================] - 409s 2s/step - loss: 0.0313 - accuracy: 0.9928 - top5_acc: 1.0000 - macro_f1score: 0.5398 - val_loss: 1.6635 - val_accuracy: 0.6654 - val_top5_acc: 0.9095 - val_macro_f1score: 0.3249
# Learning rate:  0.0001
#
# Epoch 00043: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 43/70
# 194/194 [==============================] - ETA: 0s - loss: 0.0322 - accuracy: 0.9915 - top5_acc: 1.0000 - macro_f1score: 0.5430
# Epoch 00043: val_loss did not improve from 1.42003
#
# Epoch 00043: val_accuracy did not improve from 0.69076
# 194/194 [==============================] - 411s 2s/step - loss: 0.0322 - accuracy: 0.9915 - top5_acc: 1.0000 - macro_f1score: 0.5430 - val_loss: 1.6799 - val_accuracy: 0.6621 - val_top5_acc: 0.9141 - val_macro_f1score: 0.3270
# Learning rate:  0.0001
#
# Epoch 00044: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 44/70
# 194/194 [==============================] - ETA: 0s - loss: 0.0307 - accuracy: 0.9925 - top5_acc: 1.0000 - macro_f1score: 0.5423
# Epoch 00044: val_loss did not improve from 1.42003
#
# Epoch 00044: val_accuracy did not improve from 0.69076
# 194/194 [==============================] - 407s 2s/step - loss: 0.0307 - accuracy: 0.9925 - top5_acc: 1.0000 - macro_f1score: 0.5423 - val_loss: 1.6421 - val_accuracy: 0.6660 - val_top5_acc: 0.9141 - val_macro_f1score: 0.3293
# Learning rate:  0.0001
#
# Epoch 00045: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 45/70
# 194/194 [==============================] - ETA: 0s - loss: 0.0299 - accuracy: 0.9933 - top5_acc: 1.0000 - macro_f1score: 0.5459
# Epoch 00045: val_loss did not improve from 1.42003
#
# Epoch 00045: val_accuracy did not improve from 0.69076
# 194/194 [==============================] - 413s 2s/step - loss: 0.0299 - accuracy: 0.9933 - top5_acc: 1.0000 - macro_f1score: 0.5459 - val_loss: 1.5898 - val_accuracy: 0.6829 - val_top5_acc: 0.9173 - val_macro_f1score: 0.3410
# Learning rate:  0.0001
#
# Epoch 00046: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 46/70
# 194/194 [==============================] - ETA: 0s - loss: 0.0277 - accuracy: 0.9935 - top5_acc: 1.0000 - macro_f1score: 0.5485
# Epoch 00046: val_loss did not improve from 1.42003
#
# Epoch 00046: val_accuracy did not improve from 0.69076
# 194/194 [==============================] - 413s 2s/step - loss: 0.0277 - accuracy: 0.9935 - top5_acc: 1.0000 - macro_f1score: 0.5485 - val_loss: 1.7204 - val_accuracy: 0.6576 - val_top5_acc: 0.9043 - val_macro_f1score: 0.3302
# Learning rate:  0.0001
#
# Epoch 00047: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 47/70
# 194/194 [==============================] - ETA: 0s - loss: 0.0279 - accuracy: 0.9936 - top5_acc: 1.0000 - macro_f1score: 0.5410
# Epoch 00047: val_loss did not improve from 1.42003
#
# Epoch 00047: val_accuracy did not improve from 0.69076
# 194/194 [==============================] - 411s 2s/step - loss: 0.0279 - accuracy: 0.9936 - top5_acc: 1.0000 - macro_f1score: 0.5410 - val_loss: 1.6247 - val_accuracy: 0.6647 - val_top5_acc: 0.9167 - val_macro_f1score: 0.3248
# Learning rate:  0.0001
#
# Epoch 00048: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 48/70
# 194/194 [==============================] - ETA: 0s - loss: 0.0326 - accuracy: 0.9913 - top5_acc: 0.9999 - macro_f1score: 0.5437
# Epoch 00048: val_loss did not improve from 1.42003
#
# Epoch 00048: val_accuracy did not improve from 0.69076
# 194/194 [==============================] - 412s 2s/step - loss: 0.0326 - accuracy: 0.9913 - top5_acc: 0.9999 - macro_f1score: 0.5437 - val_loss: 1.5821 - val_accuracy: 0.6621 - val_top5_acc: 0.9173 - val_macro_f1score: 0.3232
# Learning rate:  0.0001
#
# Epoch 00049: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 49/70
# 194/194 [==============================] - ETA: 0s - loss: 0.0297 - accuracy: 0.9932 - top5_acc: 1.0000 - macro_f1score: 0.5428
# Epoch 00049: val_loss did not improve from 1.42003
#
# Epoch 00049: val_accuracy did not improve from 0.69076
# 194/194 [==============================] - 409s 2s/step - loss: 0.0297 - accuracy: 0.9932 - top5_acc: 1.0000 - macro_f1score: 0.5428 - val_loss: 1.7326 - val_accuracy: 0.6602 - val_top5_acc: 0.8997 - val_macro_f1score: 0.3239
# Learning rate:  0.0001
#
# Epoch 00050: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 50/70
# 194/194 [==============================] - ETA: 0s - loss: 0.0280 - accuracy: 0.9938 - top5_acc: 1.0000 - macro_f1score: 0.5434
# Epoch 00050: val_loss did not improve from 1.42003
#
# Epoch 00050: val_accuracy did not improve from 0.69076
# 194/194 [==============================] - 411s 2s/step - loss: 0.0280 - accuracy: 0.9938 - top5_acc: 1.0000 - macro_f1score: 0.5434 - val_loss: 1.7008 - val_accuracy: 0.6576 - val_top5_acc: 0.9102 - val_macro_f1score: 0.3227
# Learning rate:  0.0001
#
# Epoch 00051: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 51/70
# 194/194 [==============================] - ETA: 0s - loss: 0.0278 - accuracy: 0.9943 - top5_acc: 0.9999 - macro_f1score: 0.5436
# Epoch 00051: val_loss did not improve from 1.42003
#
# Epoch 00051: val_accuracy did not improve from 0.69076
# 194/194 [==============================] - 411s 2s/step - loss: 0.0278 - accuracy: 0.9943 - top5_acc: 0.9999 - macro_f1score: 0.5436 - val_loss: 1.6747 - val_accuracy: 0.6660 - val_top5_acc: 0.9004 - val_macro_f1score: 0.3369
# Learning rate:  0.0001
#
# Epoch 00052: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 52/70
# 194/194 [==============================] - ETA: 0s - loss: 0.0307 - accuracy: 0.9927 - top5_acc: 0.9998 - macro_f1score: 0.5452
# Epoch 00052: val_loss did not improve from 1.42003
#
# Epoch 00052: val_accuracy did not improve from 0.69076
# 194/194 [==============================] - 408s 2s/step - loss: 0.0307 - accuracy: 0.9927 - top5_acc: 0.9998 - macro_f1score: 0.5452 - val_loss: 1.5320 - val_accuracy: 0.6764 - val_top5_acc: 0.9186 - val_macro_f1score: 0.3440
# Learning rate:  0.0001
#
# Epoch 00053: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 53/70
# 194/194 [==============================] - ETA: 0s - loss: 0.0280 - accuracy: 0.9944 - top5_acc: 1.0000 - macro_f1score: 0.5460
# Epoch 00053: val_loss did not improve from 1.42003
#
# Epoch 00053: val_accuracy did not improve from 0.69076
# 194/194 [==============================] - 406s 2s/step - loss: 0.0280 - accuracy: 0.9944 - top5_acc: 1.0000 - macro_f1score: 0.5460 - val_loss: 1.5625 - val_accuracy: 0.6719 - val_top5_acc: 0.9160 - val_macro_f1score: 0.3483
# Learning rate:  0.0001
#
# Epoch 00054: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 54/70
# 194/194 [==============================] - ETA: 0s - loss: 0.0297 - accuracy: 0.9924 - top5_acc: 1.0000 - macro_f1score: 0.5422
# Epoch 00054: val_loss did not improve from 1.42003
#
# Epoch 00054: val_accuracy did not improve from 0.69076
# 194/194 [==============================] - 409s 2s/step - loss: 0.0297 - accuracy: 0.9924 - top5_acc: 1.0000 - macro_f1score: 0.5422 - val_loss: 1.6237 - val_accuracy: 0.6751 - val_top5_acc: 0.9089 - val_macro_f1score: 0.3288
# Learning rate:  0.0001
#
# Epoch 00055: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 55/70
# 194/194 [==============================] - ETA: 0s - loss: 0.0296 - accuracy: 0.9931 - top5_acc: 1.0000 - macro_f1score: 0.5460
# Epoch 00055: val_loss did not improve from 1.42003
#
# Epoch 00055: val_accuracy did not improve from 0.69076
# 194/194 [==============================] - 411s 2s/step - loss: 0.0296 - accuracy: 0.9931 - top5_acc: 1.0000 - macro_f1score: 0.5460 - val_loss: 1.6902 - val_accuracy: 0.6621 - val_top5_acc: 0.9023 - val_macro_f1score: 0.3374
# Learning rate:  0.0001
#
# Epoch 00056: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 56/70
# 194/194 [==============================] - ETA: 0s - loss: 0.0298 - accuracy: 0.9937 - top5_acc: 1.0000 - macro_f1score: 0.5451
# Epoch 00056: val_loss did not improve from 1.42003
#
# Epoch 00056: val_accuracy did not improve from 0.69076
# 194/194 [==============================] - 414s 2s/step - loss: 0.0298 - accuracy: 0.9937 - top5_acc: 1.0000 - macro_f1score: 0.5451 - val_loss: 1.5905 - val_accuracy: 0.6686 - val_top5_acc: 0.9115 - val_macro_f1score: 0.3300
# Learning rate:  0.0001
#
# Epoch 00057: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 57/70
# 194/194 [==============================] - ETA: 0s - loss: 0.0229 - accuracy: 0.9954 - top5_acc: 1.0000 - macro_f1score: 0.5407
# Epoch 00057: val_loss did not improve from 1.42003
#
# Epoch 00057: val_accuracy did not improve from 0.69076
# 194/194 [==============================] - 409s 2s/step - loss: 0.0229 - accuracy: 0.9954 - top5_acc: 1.0000 - macro_f1score: 0.5407 - val_loss: 1.6439 - val_accuracy: 0.6628 - val_top5_acc: 0.9121 - val_macro_f1score: 0.3151
# Learning rate:  0.0001
#
# Epoch 00058: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 58/70
# 194/194 [==============================] - ETA: 0s - loss: 0.0323 - accuracy: 0.9927 - top5_acc: 1.0000 - macro_f1score: 0.5449
# Epoch 00058: val_loss did not improve from 1.42003
#
# Epoch 00058: val_accuracy did not improve from 0.69076
# 194/194 [==============================] - 412s 2s/step - loss: 0.0323 - accuracy: 0.9927 - top5_acc: 1.0000 - macro_f1score: 0.5449 - val_loss: 1.5399 - val_accuracy: 0.6777 - val_top5_acc: 0.9089 - val_macro_f1score: 0.3313
# Learning rate:  0.0001
#
# Epoch 00059: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 59/70
# 194/194 [==============================] - ETA: 0s - loss: 0.0277 - accuracy: 0.9942 - top5_acc: 0.9999 - macro_f1score: 0.5438
# Epoch 00059: val_loss did not improve from 1.42003
#
# Epoch 00059: val_accuracy did not improve from 0.69076
# 194/194 [==============================] - 411s 2s/step - loss: 0.0277 - accuracy: 0.9942 - top5_acc: 0.9999 - macro_f1score: 0.5438 - val_loss: 1.5398 - val_accuracy: 0.6777 - val_top5_acc: 0.9095 - val_macro_f1score: 0.3375
# Learning rate:  0.0001
#
# Epoch 00060: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 60/70
# 194/194 [==============================] - ETA: 0s - loss: 0.0258 - accuracy: 0.9957 - top5_acc: 0.9999 - macro_f1score: 0.5407
# Epoch 00060: val_loss did not improve from 1.42003
#
# Epoch 00060: val_accuracy did not improve from 0.69076
# 194/194 [==============================] - 411s 2s/step - loss: 0.0258 - accuracy: 0.9957 - top5_acc: 0.9999 - macro_f1score: 0.5407 - val_loss: 1.5950 - val_accuracy: 0.6712 - val_top5_acc: 0.9069 - val_macro_f1score: 0.3348
# Learning rate:  1e-05
#
# Epoch 00061: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 61/70
# 194/194 [==============================] - ETA: 0s - loss: 0.0222 - accuracy: 0.9955 - top5_acc: 1.0000 - macro_f1score: 0.5437
# Epoch 00061: val_loss did not improve from 1.42003
#
# Epoch 00061: val_accuracy did not improve from 0.69076
# 194/194 [==============================] - 408s 2s/step - loss: 0.0222 - accuracy: 0.9955 - top5_acc: 1.0000 - macro_f1score: 0.5437 - val_loss: 1.5384 - val_accuracy: 0.6758 - val_top5_acc: 0.9102 - val_macro_f1score: 0.3336
# Learning rate:  1e-05
#
# Epoch 00062: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 62/70
# 194/194 [==============================] - ETA: 0s - loss: 0.0170 - accuracy: 0.9972 - top5_acc: 1.0000 - macro_f1score: 0.5451
# Epoch 00062: val_loss did not improve from 1.42003
#
# Epoch 00062: val_accuracy did not improve from 0.69076
# 194/194 [==============================] - 410s 2s/step - loss: 0.0170 - accuracy: 0.9972 - top5_acc: 1.0000 - macro_f1score: 0.5451 - val_loss: 1.4940 - val_accuracy: 0.6810 - val_top5_acc: 0.9108 - val_macro_f1score: 0.3370
# Learning rate:  1e-05
#
# Epoch 00063: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 63/70
# 194/194 [==============================] - ETA: 0s - loss: 0.0201 - accuracy: 0.9971 - top5_acc: 0.9999 - macro_f1score: 0.5434
# Epoch 00063: val_loss did not improve from 1.42003
#
# Epoch 00063: val_accuracy did not improve from 0.69076
# 194/194 [==============================] - 410s 2s/step - loss: 0.0201 - accuracy: 0.9971 - top5_acc: 0.9999 - macro_f1score: 0.5434 - val_loss: 1.4808 - val_accuracy: 0.6816 - val_top5_acc: 0.9134 - val_macro_f1score: 0.3354
# Learning rate:  1e-05
#
# Epoch 00064: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 64/70
# 194/194 [==============================] - ETA: 0s - loss: 0.0185 - accuracy: 0.9967 - top5_acc: 1.0000 - macro_f1score: 0.5446
# Epoch 00064: val_loss did not improve from 1.42003
#
# Epoch 00064: val_accuracy did not improve from 0.69076
# 194/194 [==============================] - 412s 2s/step - loss: 0.0185 - accuracy: 0.9967 - top5_acc: 1.0000 - macro_f1score: 0.5446 - val_loss: 1.4509 - val_accuracy: 0.6849 - val_top5_acc: 0.9134 - val_macro_f1score: 0.3495
# Learning rate:  1e-05
#
# Epoch 00065: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 65/70
# 194/194 [==============================] - ETA: 0s - loss: 0.0184 - accuracy: 0.9971 - top5_acc: 1.0000 - macro_f1score: 0.5495
# Epoch 00065: val_loss did not improve from 1.42003
#
# Epoch 00065: val_accuracy did not improve from 0.69076
# 194/194 [==============================] - 412s 2s/step - loss: 0.0184 - accuracy: 0.9971 - top5_acc: 1.0000 - macro_f1score: 0.5495 - val_loss: 1.4418 - val_accuracy: 0.6849 - val_top5_acc: 0.9115 - val_macro_f1score: 0.3434
# Learning rate:  1e-05
#
# Epoch 00066: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 66/70
# 194/194 [==============================] - ETA: 0s - loss: 0.0193 - accuracy: 0.9973 - top5_acc: 1.0000 - macro_f1score: 0.5441
# Epoch 00066: val_loss did not improve from 1.42003
#
# Epoch 00066: val_accuracy did not improve from 0.69076
# 194/194 [==============================] - 414s 2s/step - loss: 0.0193 - accuracy: 0.9973 - top5_acc: 1.0000 - macro_f1score: 0.5441 - val_loss: 1.4527 - val_accuracy: 0.6797 - val_top5_acc: 0.9115 - val_macro_f1score: 0.3383
# Learning rate:  1e-05
#
# Epoch 00067: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 67/70
# 194/194 [==============================] - ETA: 0s - loss: 0.0209 - accuracy: 0.9969 - top5_acc: 1.0000 - macro_f1score: 0.5432
# Epoch 00067: val_loss did not improve from 1.42003
#
# Epoch 00067: val_accuracy did not improve from 0.69076
# 194/194 [==============================] - 411s 2s/step - loss: 0.0209 - accuracy: 0.9969 - top5_acc: 1.0000 - macro_f1score: 0.5432 - val_loss: 1.4600 - val_accuracy: 0.6758 - val_top5_acc: 0.9102 - val_macro_f1score: 0.3361
# Learning rate:  1e-05
#
# Epoch 00068: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 68/70
# 194/194 [==============================] - ETA: 0s - loss: 0.0210 - accuracy: 0.9973 - top5_acc: 1.0000 - macro_f1score: 0.5487
# Epoch 00068: val_loss did not improve from 1.42003
#
# Epoch 00068: val_accuracy did not improve from 0.69076
# 194/194 [==============================] - 412s 2s/step - loss: 0.0210 - accuracy: 0.9973 - top5_acc: 1.0000 - macro_f1score: 0.5487 - val_loss: 1.4404 - val_accuracy: 0.6771 - val_top5_acc: 0.9128 - val_macro_f1score: 0.3337
# Learning rate:  1e-05
#
# Epoch 00069: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 69/70
# 194/194 [==============================] - ETA: 0s - loss: 0.0209 - accuracy: 0.9971 - top5_acc: 1.0000 - macro_f1score: 0.5458
# Epoch 00069: val_loss did not improve from 1.42003
#
# Epoch 00069: val_accuracy did not improve from 0.69076
# 194/194 [==============================] - 409s 2s/step - loss: 0.0209 - accuracy: 0.9971 - top5_acc: 1.0000 - macro_f1score: 0.5458 - val_loss: 1.4250 - val_accuracy: 0.6816 - val_top5_acc: 0.9160 - val_macro_f1score: 0.3446
# Learning rate:  1e-05
#
# Epoch 00070: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 70/70
# 194/194 [==============================] - ETA: 0s - loss: 0.0221 - accuracy: 0.9970 - top5_acc: 1.0000 - macro_f1score: 0.5451
# Epoch 00070: val_loss did not improve from 1.42003
#
# Epoch 00070: val_accuracy did not improve from 0.69076
# 194/194 [==============================] - 406s 2s/step - loss: 0.0221 - accuracy: 0.9970 - top5_acc: 1.0000 - macro_f1score: 0.5451 - val_loss: 1.4411 - val_accuracy: 0.6836 - val_top5_acc: 0.9069 - val_macro_f1score: 0.3330

# %% [markdown]
# ### 3) Inception-ResNet-V1 Evaluate

# %%
# 1. epoch=maximum
loss , acc, top5_acc, mf1 = model.evaluate(test_generator,steps=int(len(x_test)/batch_sizes))
print('[Test Loss: %.4f /  Test Top-1 Accuracy: %.4f / Test Top-5 Accuracy: %.4f / Test Macro f1: %.4f]\n' % (loss,acc,top5_acc,mf1))
# Out:
# 24/24 [==============================] - 347s 14s/step - loss: 1.4426 - accuracy: 0.6732 - top5_acc: 0.9036 - macro_f1score: 0.3405
# [Test Loss: 1.4426 /  Test Top-1 Accuracy: 0.6732 / Test Top-5 Accuracy: 0.9036 / Test Macro f1: 0.3405]

# %%
loss=history.history['loss']
val_loss=history.history['val_loss']
acc=history.history['accuracy']
val_acc=history.history['val_accuracy']
top5_acc=history.history['top5_acc']
val_top5_acc=history.history['val_top5_acc']
f1=history.history['macro_f1score']
val_f1=history.history['val_macro_f1score']
epochs=range(1,len(acc)+1)

data = np.array([epochs,loss,val_loss,acc,val_acc,top5_acc,val_top5_acc,f1,val_f1]).T

# %%
# data save
# epochs, loss, val_loss, acc, val_acc, top5_acc, val_top5_acc, f1, val_f1

np.savetxt(os.path.join(dir,'train_valid_output',number,model.name+'.txt'),data)

# %%
# data import
data = np.loadtxt(os.path.join(dir,'train_valid_output',number,'Inception_ResNet_v1.txt'))

# %%
epochs=data[:,0]
loss=data[:,1]
val_loss=data[:,2]
acc=data[:,3]
val_acc=data[:,4]
top5_acc=data[:,5]
val_top5_acc=data[:,6]

# %%
plt.plot(epochs[1:],acc[1:],'b',label='Training 1-Acc')
plt.plot(epochs[1:],val_acc[1:],'r',label='Validation 1-Acc')
plt.title('Training and Validation Top-1 Accuracy')
plt.legend()
plt.figure()

plt.plot(epochs[1:],top5_acc[1:],'b',label='Training 5-Acc')
plt.plot(epochs[1:],val_top5_acc[1:],'r',label='Validation 5-Acc')
plt.title('Training and Validation Top-5 Accuracy')
plt.legend()
plt.figure()

plt.plot(epochs[10:],loss[10:],'b',label='Training Loss')
plt.plot(epochs[10:],val_loss[10:],'r',label='Validation Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()

# %%
# 이 아래는 내가 인위적으로 살펴보고 싶은 epoch에 대해서 결과값 출력 / Inception_Resnet_V1

# %%
# 참고 : https://github.com/OverLordGoldDragon/keras-adamw

import sys
sys.path.append('/content/drive/My Drive/Colab Notebooks/Paper')
import utils
import optimizers_v2
from utils import get_weight_decays, fill_dict_in_order
from utils import reset_seeds, K_eval
from optimizers_v2 import AdamW, NadamW, SGDW

# %%
# top-5 accuracy 출력
import functools
top5_acc = functools.partial(ks.metrics.top_k_categorical_accuracy, k=5)
top5_acc.__name__ = 'top5_acc'

# %%
model=load_model(os.path.join(dir,'model_output',number,'Inception_ResNet_v1','031.h5'),custom_objects={"macro_f1score": macro_f1score,"top5_acc":top5_acc, "AdamW":AdamW})

# %%
# 2. epoch=?
loss , acc, top5_acc, mf1 = model.evaluate(test_generator,steps=int(len(x_test)/batch_sizes))
print('[Test Loss: %.4f /  Test Top-1 Accuracy: %.4f / Test Top-5 Accuracy: %.4f / Test Macro f1: %.4f]\n' % (loss,acc,top5_acc,mf1))
# Out:
# 24/24 [==============================] - 770s 32s/step - loss: 1.4512 - accuracy: 0.6680 - top5_acc: 0.9102 - macro_f1score: 0.3326
# [Test Loss: 1.4512 /  Test Top-1 Accuracy: 0.6680 / Test Top-5 Accuracy: 0.9102 / Test Macro f1: 0.3326]
