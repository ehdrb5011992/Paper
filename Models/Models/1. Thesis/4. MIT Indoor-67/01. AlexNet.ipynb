# %% [markdown]
# # [AlexNet]

# %% [markdown]
# *KU LeeDongGyu*

# %% [markdown]
# ### Contents

# %% [markdown]
# 1. Data Preprocessing
# ```
# 1) Data Import
# 2) Data Augmentation
# ```
# 2. Support Functions & Almost Original AlexNet
# ```
# 1) Support Functions
# 2) Almost Original AlexNet
# 3) AlexNet Evaluate
# ```

# %% [markdown]
# ### Install Packages

# %% [markdown]
# ### Module

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/My Drive/Colab Notebooks/Paper
# Out:
# /content/drive/My Drive/Colab Notebooks/Paper

# %%
from lrn import LRN #만든 모듈, class
from f1score import macro_f1score, weighted_f1score

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import cv2
import tensorflow as tf
from tensorflow import keras as ks
from tensorflow.keras import backend as K 
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, Input, Concatenate, ZeroPadding2D ,GlobalMaxPooling2D, Reshape , Lambda , Add, Multiply
from tensorflow.keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D, Activation, BatchNormalization, AveragePooling2D , ZeroPadding2D, SeparableConv2D
from tensorflow.keras.layers import add
from tensorflow.keras.optimizers import Adam, RMSprop , SGD
from tensorflow.keras.callbacks import EarlyStopping , LearningRateScheduler, ModelCheckpoint, CSVLogger, Callback, ReduceLROnPlateau
from tensorflow.keras.regularizers import l1,l2,l1_l2
from tensorflow.keras.models import Model , load_model , Sequential
from tensorflow.keras.utils import plot_model , to_categorical, get_file
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
os.getcwd()
# Out:
# '/content/drive/My Drive/Colab Notebooks/Paper'

# %%
print(tf.__version__)
print(ks.__version__)
# Out:
# 2.3.0
# 2.4.0

# %%
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 647872818893696956
# , name: "/device:XLA_CPU:0"
# device_type: "XLA_CPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 13690849788443104466
# physical_device_desc: "device: XLA_CPU device"
# , name: "/device:XLA_GPU:0"
# device_type: "XLA_GPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 2424986690012939906
# physical_device_desc: "device: XLA_GPU device"
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 15473775744
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 392285637355782433
# physical_device_desc: "device: 0, name: Tesla V100-SXM2-16GB, pci bus id: 0000:00:04.0, compute capability: 7.0"
# ]

# %% [markdown]
# ## 1. Data Preprocessing
# ---

# %% [markdown]
# ### 1) Data Import

# %%
# 바꿔서 살펴 볼 것들
# CALTECH, CIFAR100, FER, MIT
data_name = 'MIT'
gan_type = 'No_GAN'
number = '1'
size = 227 # sizes after cropping
super_size = 256 # sizes before cropping 
input_sizes = (size,size,3)
batch_sizes = 128
weight_decay = 1e-4
epochs = 70

# %%
# 참고 : https://stackoverflow.com/questions/32419510/how-to-get-reproducible-results-in-keras/52897216#52897216
# setting the seed number for random number generation for reproducibility.

from numpy.random import seed
import random


if number=='1':
    seed_num = 200225
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)
elif number=='2':
    seed_num = 727
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)
elif number=='3':
    seed_num = 115
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)
elif number=='4':
    seed_num = 501
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)
elif number=='5':
    seed_num = 517
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)

# %%
# data import

if data_name=='FER' :
    x_train =  np.zeros(28698)
    x_valid = np.zeros(3589)
    x_test = np.zeros(3588)
    classes = 7 
    tr_center = [0.50793296, 0.50793296, 0.50793296]
elif data_name=='MIT':
    x_train = np.zeros(12466)
    x_valid = np.zeros(1564)
    x_test = np.zeros(1590)
    classes = 67 
    tr_center = [0.47916578, 0.42029615, 0.36046057]
elif data_name=='CALTECH':
    x_train = np.zeros(24510)
    x_valid = np.zeros(2980)
    x_test = np.zeros(3118)
    classes = 257
    tr_center = [0.51397761, 0.49525248, 0.46555727]
elif data_name=='CIFAR100':
    x_train = np.zeros(44923)
    x_valid = np.zeros(5077)
    x_test = np.zeros(10000)
    classes = 100
    tr_center = [0.53442983, 0.51355958, 0.46462564]

# %%
dir = os.path.join(os.getcwd(),data_name,gan_type)

# %% [markdown]
# ### 2) Data Augmentation

# %%
# 참고 : https://jkjung-avt.github.io/keras-image-cropping/

def random_crop(img, random_crop_size):
    # Note: image_data_format is 'channel_last'
    assert img.shape[2] == 3 # img.shape[2] 가 3(rgb)이 아니면 assertion error 발생
    height, width = img.shape[0], img.shape[1]
    dy, dx = random_crop_size
    x = np.random.randint(0, width - dx + 1)
    y = np.random.randint(0, height - dy + 1)
    return img[y:(y+dy), x:(x+dx), :]


def crop_generator(batches, crop_length):
    """Take as input a Keras ImageGen (Iterator) and generate random
    crops from the image batches generated by the original iterator.
    """
    while True:
        batch_x, batch_y = next(batches)
        batch_crops = np.zeros((batch_x.shape[0], crop_length, crop_length, 3))
        for i in range(batch_x.shape[0]):
            batch_crops[i] = random_crop(batch_x[i], (crop_length, crop_length))
        yield (batch_crops, batch_y)

# %%
from tensorflow.keras.preprocessing.image import img_to_array,load_img
import glob

# 데이터 전체에 대해 centering 진행함.

def read_cal_image(img_path): 
    x = img_to_array(load_img(img_path)) # x는 채널별 평균값
    y = x.shape[0] * x.shape[1]# y는 데이터별 픽셀 수 (비중)

    x = 1/255. * x # scaling하고, centering값을 뽑아냄.
    x = np.mean(x, axis=(0,1))
    
    return np.hstack([x,y])

def calculate_centered_mean(dataset_path,x_train=x_train):
    num = len(x_train)
    space = np.empty((num,4))
    i=0

    for p in glob.glob(os.path.join(dataset_path,'*/*.*')) :
        space[i] = read_cal_image(p)
        i += 1

    ratio = space[:,3] / np.sum(space[:,3])

    return np.average(space[:,0:3],axis=0,weights=ratio)


#아래의 함수를 돌려서 나온 결과값을 중심화 값으로 설정.

#train_mean = calculate_centered_mean(os.path.join(dir,'data/train')).reshape((1,1,3))

# %%
datagen_tr = ImageDataGenerator(
    rescale=1/255.,
    horizontal_flip=True,
    featurewise_center=True,
    featurewise_std_normalization=False,
    rotation_range=10,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=[0.9,1.0],
    fill_mode = 'nearest')
datagen_val = ImageDataGenerator(rescale=1/255.,featurewise_center=True)
datagen_tes = ImageDataGenerator(rescale=1/255.,featurewise_center=True)

# 원래는 이 자리에 fit 매서드를 써야하지만, 그냥 내가 중심화함수를 만들고 적용함. 

# 중심화 설정
datagen_tr.mean = np.array(tr_center, dtype=np.float32).reshape((1,1,3)) # RGB
datagen_val.mean = np.array(tr_center, dtype=np.float32).reshape((1,1,3)) # RGB
datagen_tes.mean = np.array(tr_center, dtype=np.float32).reshape((1,1,3)) # RGB

# %%
train_batches = datagen_tr.flow_from_directory(directory=os.path.join(dir,'data/train'),target_size=(super_size,super_size),batch_size=batch_sizes,class_mode='categorical') # fer : 28698 / mit : 12466 / caltech : 24509 / cifar : 44923
train_generator= crop_generator(train_batches, size)
valid_generator = datagen_val.flow_from_directory(directory=os.path.join(dir,'data/valid'),target_size=(size,size),batch_size=batch_sizes,class_mode='categorical') # fer : 3589 / mit : 1564 / caltech : 2980 / cifar : 5077
test_generator = datagen_tes.flow_from_directory(directory=os.path.join(dir,'data/test'),target_size=(size,size),batch_size=batch_sizes,class_mode='categorical') # fer : 3588 / mit : 1590 / caltech : 3118 / cifar : 10000
# Out:
# Found 12466 images belonging to 67 classes.
# Found 1564 images belonging to 67 classes.
# Found 1590 images belonging to 67 classes.

# %% [markdown]
# ## 2. Support Functions & Almost Original AlexNet
# ---

# %% [markdown]
# ### 1) Support Functions

# %%
# def lr_schedule(epoch):
#     init_lr = 1e-4
#     k = 0.04
#     lr = init_lr * np.exp(-k*epoch)
#     print('Learning rate: ', lr)
#     return lr

def lr_schedule(epoch):
    lr = 3e-4
    if epoch < 30:
        lr = lr
    elif epoch < 60 :
        lr = lr * 0.1
    else:
        lr = lr * 0.01
    print('Learning rate: ', lr)
    return lr

# %% [markdown]
# ### 2) Almost Orginial AlexNet

# %%
# Alexnet을 최대한 논문에 가깝게 맞춰 모형작성.
# 참고 : https://github.com/eweill/keras-deepcv/blob/master/models/classification/alexnet.py

def Alexnet(img_shape=(227, 227, 3), n_classes=1000, weight_decay=weight_decay, weights=None, name='AlexNet'):

    # Initialize model
    alexnet = Sequential(name=name)

    # Layer 1
    alexnet.add(Conv2D(96, (11, 11), input_shape=img_shape, strides=4, kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay)))
    alexnet.add(Activation('relu'))
    alexnet.add(LRN(name='layer1_LRN'))
    alexnet.add(MaxPooling2D(pool_size=(3, 3),strides=2))

    # Layer 2
    alexnet.add(Conv2D(256, (5, 5), padding='same',strides=1, kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay)))
    alexnet.add(Activation('relu'))
    alexnet.add(LRN(name='layer2_LRN'))
    alexnet.add(MaxPooling2D(pool_size=(3, 3),strides=2))
    
    # Layer 3
    alexnet.add(Conv2D(384, (3, 3), padding='same', strides=1, kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay)))
    alexnet.add(Activation('relu'))
    alexnet.add(LRN(name='layer3_LRN'))
    
    # Layer 4
    alexnet.add(Conv2D(384, (3, 3), padding='same', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay)))
    alexnet.add(Activation('relu'))
    alexnet.add(LRN(name='layer4_LRN'))

    # Layer 5
    alexnet.add(Conv2D(256, (3, 3), padding='same', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay)))
    alexnet.add(Activation('relu'))
    alexnet.add(LRN(name='layer5_LRN'))
    alexnet.add(MaxPooling2D(pool_size=(3, 3),strides=2))

    # Layer 6
    alexnet.add(Flatten())
    alexnet.add(Dense(4096, kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay)))
    alexnet.add(Activation('relu'))
    alexnet.add(Dropout(0.5))

    # Layer 7
    alexnet.add(Dense(4096, kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay)))
    alexnet.add(Activation('relu'))
    alexnet.add(Dropout(0.5))

    # Layer 8
    alexnet.add(Dense(n_classes, kernel_regularizer=l2(weight_decay)))
    alexnet.add(Activation('softmax'))

    if weights is not None:
        alexnet.load_weights(weights)

    return alexnet

# %%
model = Alexnet(img_shape=input_sizes, n_classes=classes, name='AlexNet')

# %%
model.summary()
# Out:
# Model: "AlexNet"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 55, 55, 96)        34944
# _________________________________________________________________
# activation (Activation)      (None, 55, 55, 96)        0
# _________________________________________________________________
# layer1_LRN (LRN)             (None, 55, 55, 96)        0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 27, 27, 96)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 27, 27, 256)       614656
# _________________________________________________________________
# activation_1 (Activation)    (None, 27, 27, 256)       0
# _________________________________________________________________
# layer2_LRN (LRN)             (None, 27, 27, 256)       0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 13, 13, 256)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 13, 13, 384)       885120
# _________________________________________________________________
# activation_2 (Activation)    (None, 13, 13, 384)       0
# _________________________________________________________________
# layer3_LRN (LRN)             (None, 13, 13, 384)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 13, 13, 384)       1327488
# _________________________________________________________________
# activation_3 (Activation)    (None, 13, 13, 384)       0
# _________________________________________________________________
# layer4_LRN (LRN)             (None, 13, 13, 384)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 13, 13, 256)       884992
# _________________________________________________________________
# activation_4 (Activation)    (None, 13, 13, 256)       0
# _________________________________________________________________
# layer5_LRN (LRN)             (None, 13, 13, 256)       0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 6, 6, 256)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 9216)              0
# _________________________________________________________________
# dense (Dense)                (None, 4096)              37752832
# _________________________________________________________________
# activation_5 (Activation)    (None, 4096)              0
# _________________________________________________________________
# dropout (Dropout)            (None, 4096)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 4096)              16781312
# _________________________________________________________________
# activation_6 (Activation)    (None, 4096)              0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 4096)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 67)                274499
# _________________________________________________________________
# activation_7 (Activation)    (None, 67)                0
# =================================================================
# Total params: 58,555,843
# Trainable params: 58,555,843
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 폴더 생성

os.makedirs(os.path.join(dir,'model_output',number,model.name), exist_ok=True)
os.makedirs(os.path.join(dir,'train_valid_output',number), exist_ok=True)

# %%
# 참고 : https://github.com/OverLordGoldDragon/keras-adamw

import sys
sys.path.append('/content/drive/My Drive/Colab Notebooks/Paper')
import utils
import optimizers_v2
from utils import get_weight_decays, fill_dict_in_order
from utils import reset_seeds, K_eval
from optimizers_v2 import AdamW, NadamW, SGDW

# %%
# top-5 accuracy 출력
import functools
top5_acc = functools.partial(ks.metrics.top_k_categorical_accuracy, k=5)
top5_acc.__name__ = 'top5_acc'

# %%
#optimizer = SGDW(model=model, use_cosine_annealing=False, total_iterations = len(x_train) // batch_sizes, nesterov=True, momentum=0.9)
optimizer = AdamW(model=model, use_cosine_annealing=False, total_iterations = len(x_train) // batch_sizes)
#optimizer = Adam()
filepath =  os.path.join(dir,'model_output',number,model.name,'{epoch:03d}.h5')

callbacks_list = [ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_weights_only=False, save_best_only=True, mode='min'),
                  ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_weights_only=False, save_best_only=True, mode='max'),
                  #ReduceLROnPlateau(monitor='val_loss',patience=3,factor=0.1,min_lr=1e-5),
                  LearningRateScheduler(lr_schedule,verbose=1)
                  ]
                  
model.compile(optimizer, loss = 'categorical_crossentropy', metrics=['accuracy',top5_acc,macro_f1score])

# %%
######## flow_from_directory
history = model.fit(train_generator, steps_per_epoch=int(len(x_train)/batch_sizes),  validation_data = valid_generator, epochs=epochs , verbose=1 , callbacks = callbacks_list , validation_steps=int(len(x_valid)/batch_sizes))
# Out:
# Learning rate:  0.0003
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 1/70
# 0.0(L1), 1.0153461394838174e-05(L2) weight decay set for conv2d/kernel:0
# 0.0(L1), 1.0153461394838174e-05(L2) weight decay set for conv2d_1/kernel:0
# 0.0(L1), 1.0153461394838174e-05(L2) weight decay set for conv2d_2/kernel:0
# 0.0(L1), 1.0153461394838174e-05(L2) weight decay set for conv2d_3/kernel:0
# 0.0(L1), 1.0153461394838174e-05(L2) weight decay set for conv2d_4/kernel:0
# 0.0(L1), 1.0153461394838174e-05(L2) weight decay set for dense/kernel:0
# 0.0(L1), 1.0153461394838174e-05(L2) weight decay set for dense_1/kernel:0
# 0.0(L1), 1.0153461394838174e-05(L2) weight decay set for dense_2/kernel:0
# 97/97 [==============================] - ETA: 0s - loss: 3.9651 - accuracy: 0.0644 - top5_acc: 0.2507 - macro_f1score: 2.9781e-05
# Epoch 00001: val_loss improved from inf to 3.76165, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/AlexNet/001.h5
#
# Epoch 00001: val_accuracy improved from -inf to 0.09115, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/AlexNet/001.h5
# 97/97 [==============================] - 6697s 69s/step - loss: 3.9651 - accuracy: 0.0644 - top5_acc: 0.2507 - macro_f1score: 2.9781e-05 - val_loss: 3.7616 - val_accuracy: 0.0911 - val_top5_acc: 0.3145 - val_macro_f1score: 0.0000e+00
# Learning rate:  0.0003
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 2/70
# 97/97 [==============================] - ETA: 0s - loss: 3.6121 - accuracy: 0.1110 - top5_acc: 0.3629 - macro_f1score: 0.0023
# Epoch 00002: val_loss improved from 3.76165 to 3.42939, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/AlexNet/002.h5
#
# Epoch 00002: val_accuracy improved from 0.09115 to 0.13932, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/AlexNet/002.h5
# 97/97 [==============================] - 300s 3s/step - loss: 3.6121 - accuracy: 0.1110 - top5_acc: 0.3629 - macro_f1score: 0.0023 - val_loss: 3.4294 - val_accuracy: 0.1393 - val_top5_acc: 0.4232 - val_macro_f1score: 0.0019
# Learning rate:  0.0003
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 3/70
# 97/97 [==============================] - ETA: 0s - loss: 3.4344 - accuracy: 0.1402 - top5_acc: 0.4149 - macro_f1score: 0.0058
# Epoch 00003: val_loss improved from 3.42939 to 3.30195, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/AlexNet/003.h5
#
# Epoch 00003: val_accuracy improved from 0.13932 to 0.17513, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/AlexNet/003.h5
# 97/97 [==============================] - 294s 3s/step - loss: 3.4344 - accuracy: 0.1402 - top5_acc: 0.4149 - macro_f1score: 0.0058 - val_loss: 3.3020 - val_accuracy: 0.1751 - val_top5_acc: 0.4668 - val_macro_f1score: 0.0063
# Learning rate:  0.0003
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 4/70
# 97/97 [==============================] - ETA: 0s - loss: 3.2996 - accuracy: 0.1668 - top5_acc: 0.4561 - macro_f1score: 0.0128
# Epoch 00004: val_loss improved from 3.30195 to 3.15650, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/AlexNet/004.h5
#
# Epoch 00004: val_accuracy improved from 0.17513 to 0.19922, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/AlexNet/004.h5
# 97/97 [==============================] - 294s 3s/step - loss: 3.2996 - accuracy: 0.1668 - top5_acc: 0.4561 - macro_f1score: 0.0128 - val_loss: 3.1565 - val_accuracy: 0.1992 - val_top5_acc: 0.4948 - val_macro_f1score: 0.0203
# Learning rate:  0.0003
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 5/70
# 97/97 [==============================] - ETA: 0s - loss: 3.1991 - accuracy: 0.1842 - top5_acc: 0.4857 - macro_f1score: 0.0194
# Epoch 00005: val_loss improved from 3.15650 to 3.01651, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/AlexNet/005.h5
#
# Epoch 00005: val_accuracy improved from 0.19922 to 0.21940, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/AlexNet/005.h5
# 97/97 [==============================] - 288s 3s/step - loss: 3.1991 - accuracy: 0.1842 - top5_acc: 0.4857 - macro_f1score: 0.0194 - val_loss: 3.0165 - val_accuracy: 0.2194 - val_top5_acc: 0.5352 - val_macro_f1score: 0.0302
# Learning rate:  0.0003
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 6/70
# 97/97 [==============================] - ETA: 0s - loss: 3.0715 - accuracy: 0.2132 - top5_acc: 0.5246 - macro_f1score: 0.0310
# Epoch 00006: val_loss improved from 3.01651 to 3.00790, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/AlexNet/006.h5
#
# Epoch 00006: val_accuracy improved from 0.21940 to 0.22917, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/AlexNet/006.h5
# 97/97 [==============================] - 286s 3s/step - loss: 3.0715 - accuracy: 0.2132 - top5_acc: 0.5246 - macro_f1score: 0.0310 - val_loss: 3.0079 - val_accuracy: 0.2292 - val_top5_acc: 0.5345 - val_macro_f1score: 0.0389
# Learning rate:  0.0003
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 7/70
# 97/97 [==============================] - ETA: 0s - loss: 2.9464 - accuracy: 0.2348 - top5_acc: 0.5554 - macro_f1score: 0.0420
# Epoch 00007: val_loss improved from 3.00790 to 2.86881, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/AlexNet/007.h5
#
# Epoch 00007: val_accuracy improved from 0.22917 to 0.23893, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/AlexNet/007.h5
# 97/97 [==============================] - 290s 3s/step - loss: 2.9464 - accuracy: 0.2348 - top5_acc: 0.5554 - macro_f1score: 0.0420 - val_loss: 2.8688 - val_accuracy: 0.2389 - val_top5_acc: 0.5742 - val_macro_f1score: 0.0396
# Learning rate:  0.0003
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 8/70
# 97/97 [==============================] - ETA: 0s - loss: 2.8318 - accuracy: 0.2602 - top5_acc: 0.5861 - macro_f1score: 0.0569
# Epoch 00008: val_loss improved from 2.86881 to 2.85012, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/AlexNet/008.h5
#
# Epoch 00008: val_accuracy improved from 0.23893 to 0.25911, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/AlexNet/008.h5
# 97/97 [==============================] - 290s 3s/step - loss: 2.8318 - accuracy: 0.2602 - top5_acc: 0.5861 - macro_f1score: 0.0569 - val_loss: 2.8501 - val_accuracy: 0.2591 - val_top5_acc: 0.5768 - val_macro_f1score: 0.0646
# Learning rate:  0.0003
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 9/70
# 97/97 [==============================] - ETA: 0s - loss: 2.7381 - accuracy: 0.2812 - top5_acc: 0.6096 - macro_f1score: 0.0673
# Epoch 00009: val_loss improved from 2.85012 to 2.74947, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/AlexNet/009.h5
#
# Epoch 00009: val_accuracy improved from 0.25911 to 0.28255, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/AlexNet/009.h5
# 97/97 [==============================] - 292s 3s/step - loss: 2.7381 - accuracy: 0.2812 - top5_acc: 0.6096 - macro_f1score: 0.0673 - val_loss: 2.7495 - val_accuracy: 0.2826 - val_top5_acc: 0.6029 - val_macro_f1score: 0.0737
# Learning rate:  0.0003
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 10/70
# 97/97 [==============================] - ETA: 0s - loss: 2.6357 - accuracy: 0.3015 - top5_acc: 0.6367 - macro_f1score: 0.0811
# Epoch 00010: val_loss improved from 2.74947 to 2.61958, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/AlexNet/010.h5
#
# Epoch 00010: val_accuracy improved from 0.28255 to 0.30469, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/AlexNet/010.h5
# 97/97 [==============================] - 291s 3s/step - loss: 2.6357 - accuracy: 0.3015 - top5_acc: 0.6367 - macro_f1score: 0.0811 - val_loss: 2.6196 - val_accuracy: 0.3047 - val_top5_acc: 0.6471 - val_macro_f1score: 0.1053
# Learning rate:  0.0003
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 11/70
# 97/97 [==============================] - ETA: 0s - loss: 2.5356 - accuracy: 0.3273 - top5_acc: 0.6585 - macro_f1score: 0.1013
# Epoch 00011: val_loss improved from 2.61958 to 2.50781, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/AlexNet/011.h5
#
# Epoch 00011: val_accuracy improved from 0.30469 to 0.32422, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/AlexNet/011.h5
# 97/97 [==============================] - 286s 3s/step - loss: 2.5356 - accuracy: 0.3273 - top5_acc: 0.6585 - macro_f1score: 0.1013 - val_loss: 2.5078 - val_accuracy: 0.3242 - val_top5_acc: 0.6621 - val_macro_f1score: 0.0988
# Learning rate:  0.0003
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 12/70
# 97/97 [==============================] - ETA: 0s - loss: 2.4279 - accuracy: 0.3523 - top5_acc: 0.6830 - macro_f1score: 0.1160
# Epoch 00012: val_loss improved from 2.50781 to 2.45944, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/AlexNet/012.h5
#
# Epoch 00012: val_accuracy improved from 0.32422 to 0.34505, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/AlexNet/012.h5
# 97/97 [==============================] - 290s 3s/step - loss: 2.4279 - accuracy: 0.3523 - top5_acc: 0.6830 - macro_f1score: 0.1160 - val_loss: 2.4594 - val_accuracy: 0.3451 - val_top5_acc: 0.6693 - val_macro_f1score: 0.1181
# Learning rate:  0.0003
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 13/70
# 97/97 [==============================] - ETA: 0s - loss: 2.2960 - accuracy: 0.3810 - top5_acc: 0.7112 - macro_f1score: 0.1443
# Epoch 00013: val_loss improved from 2.45944 to 2.45745, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/AlexNet/013.h5
#
# Epoch 00013: val_accuracy improved from 0.34505 to 0.35352, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/AlexNet/013.h5
# 97/97 [==============================] - 290s 3s/step - loss: 2.2960 - accuracy: 0.3810 - top5_acc: 0.7112 - macro_f1score: 0.1443 - val_loss: 2.4575 - val_accuracy: 0.3535 - val_top5_acc: 0.6764 - val_macro_f1score: 0.1278
# Learning rate:  0.0003
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 14/70
# 97/97 [==============================] - ETA: 0s - loss: 2.2326 - accuracy: 0.3962 - top5_acc: 0.7306 - macro_f1score: 0.1530
# Epoch 00014: val_loss did not improve from 2.45745
#
# Epoch 00014: val_accuracy improved from 0.35352 to 0.35482, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/AlexNet/014.h5
# 97/97 [==============================] - 286s 3s/step - loss: 2.2326 - accuracy: 0.3962 - top5_acc: 0.7306 - macro_f1score: 0.1530 - val_loss: 2.4634 - val_accuracy: 0.3548 - val_top5_acc: 0.6803 - val_macro_f1score: 0.1560
# Learning rate:  0.0003
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 15/70
# 97/97 [==============================] - ETA: 0s - loss: 2.1070 - accuracy: 0.4264 - top5_acc: 0.7522 - macro_f1score: 0.1829
# Epoch 00015: val_loss did not improve from 2.45745
#
# Epoch 00015: val_accuracy improved from 0.35482 to 0.36784, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/AlexNet/015.h5
# 97/97 [==============================] - 290s 3s/step - loss: 2.1070 - accuracy: 0.4264 - top5_acc: 0.7522 - macro_f1score: 0.1829 - val_loss: 2.5011 - val_accuracy: 0.3678 - val_top5_acc: 0.6829 - val_macro_f1score: 0.1518
# Learning rate:  0.0003
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 16/70
# 97/97 [==============================] - ETA: 0s - loss: 2.0174 - accuracy: 0.4473 - top5_acc: 0.7725 - macro_f1score: 0.1985
# Epoch 00016: val_loss improved from 2.45745 to 2.36144, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/AlexNet/016.h5
#
# Epoch 00016: val_accuracy improved from 0.36784 to 0.39128, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/AlexNet/016.h5
# 97/97 [==============================] - 291s 3s/step - loss: 2.0174 - accuracy: 0.4473 - top5_acc: 0.7725 - macro_f1score: 0.1985 - val_loss: 2.3614 - val_accuracy: 0.3913 - val_top5_acc: 0.6979 - val_macro_f1score: 0.1799
# Learning rate:  0.0003
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 17/70
# 97/97 [==============================] - ETA: 0s - loss: 1.9155 - accuracy: 0.4694 - top5_acc: 0.7934 - macro_f1score: 0.2197
# Epoch 00017: val_loss improved from 2.36144 to 2.31660, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/AlexNet/017.h5
#
# Epoch 00017: val_accuracy improved from 0.39128 to 0.39779, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/AlexNet/017.h5
# 97/97 [==============================] - 293s 3s/step - loss: 1.9155 - accuracy: 0.4694 - top5_acc: 0.7934 - macro_f1score: 0.2197 - val_loss: 2.3166 - val_accuracy: 0.3978 - val_top5_acc: 0.7168 - val_macro_f1score: 0.1989
# Learning rate:  0.0003
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 18/70
# 97/97 [==============================] - ETA: 0s - loss: 1.8354 - accuracy: 0.4909 - top5_acc: 0.8065 - macro_f1score: 0.2447
# Epoch 00018: val_loss did not improve from 2.31660
#
# Epoch 00018: val_accuracy improved from 0.39779 to 0.40951, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/AlexNet/018.h5
# 97/97 [==============================] - 289s 3s/step - loss: 1.8354 - accuracy: 0.4909 - top5_acc: 0.8065 - macro_f1score: 0.2447 - val_loss: 2.3196 - val_accuracy: 0.4095 - val_top5_acc: 0.7096 - val_macro_f1score: 0.1790
# Learning rate:  0.0003
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 19/70
# 97/97 [==============================] - ETA: 0s - loss: 1.7641 - accuracy: 0.5101 - top5_acc: 0.8180 - macro_f1score: 0.2546
# Epoch 00019: val_loss did not improve from 2.31660
#
# Epoch 00019: val_accuracy did not improve from 0.40951
# 97/97 [==============================] - 285s 3s/step - loss: 1.7641 - accuracy: 0.5101 - top5_acc: 0.8180 - macro_f1score: 0.2546 - val_loss: 2.3300 - val_accuracy: 0.3997 - val_top5_acc: 0.7168 - val_macro_f1score: 0.1874
# Learning rate:  0.0003
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 20/70
# 97/97 [==============================] - ETA: 0s - loss: 1.6455 - accuracy: 0.5408 - top5_acc: 0.8368 - macro_f1score: 0.2932
# Epoch 00020: val_loss did not improve from 2.31660
#
# Epoch 00020: val_accuracy did not improve from 0.40951
# 97/97 [==============================] - 281s 3s/step - loss: 1.6455 - accuracy: 0.5408 - top5_acc: 0.8368 - macro_f1score: 0.2932 - val_loss: 2.3325 - val_accuracy: 0.4043 - val_top5_acc: 0.7207 - val_macro_f1score: 0.2128
# Learning rate:  0.0003
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 21/70
# 97/97 [==============================] - ETA: 0s - loss: 1.5326 - accuracy: 0.5678 - top5_acc: 0.8584 - macro_f1score: 0.3167
# Epoch 00021: val_loss did not improve from 2.31660
#
# Epoch 00021: val_accuracy did not improve from 0.40951
# 97/97 [==============================] - 267s 3s/step - loss: 1.5326 - accuracy: 0.5678 - top5_acc: 0.8584 - macro_f1score: 0.3167 - val_loss: 2.3830 - val_accuracy: 0.4023 - val_top5_acc: 0.7285 - val_macro_f1score: 0.2157
# Learning rate:  0.0003
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 22/70
# 97/97 [==============================] - ETA: 0s - loss: 1.5030 - accuracy: 0.5738 - top5_acc: 0.8644 - macro_f1score: 0.3170
# Epoch 00022: val_loss did not improve from 2.31660
#
# Epoch 00022: val_accuracy improved from 0.40951 to 0.41276, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/AlexNet/022.h5
# 97/97 [==============================] - 264s 3s/step - loss: 1.5030 - accuracy: 0.5738 - top5_acc: 0.8644 - macro_f1score: 0.3170 - val_loss: 2.3621 - val_accuracy: 0.4128 - val_top5_acc: 0.7285 - val_macro_f1score: 0.2244
# Learning rate:  0.0003
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 23/70
# 97/97 [==============================] - ETA: 0s - loss: 1.4055 - accuracy: 0.6013 - top5_acc: 0.8772 - macro_f1score: 0.3598
# Epoch 00023: val_loss did not improve from 2.31660
#
# Epoch 00023: val_accuracy did not improve from 0.41276
# 97/97 [==============================] - 251s 3s/step - loss: 1.4055 - accuracy: 0.6013 - top5_acc: 0.8772 - macro_f1score: 0.3598 - val_loss: 2.4431 - val_accuracy: 0.4076 - val_top5_acc: 0.7259 - val_macro_f1score: 0.2399
# Learning rate:  0.0003
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 24/70
# 97/97 [==============================] - ETA: 0s - loss: 1.3297 - accuracy: 0.6159 - top5_acc: 0.8947 - macro_f1score: 0.3670
# Epoch 00024: val_loss did not improve from 2.31660
#
# Epoch 00024: val_accuracy did not improve from 0.41276
# 97/97 [==============================] - 256s 3s/step - loss: 1.3297 - accuracy: 0.6159 - top5_acc: 0.8947 - macro_f1score: 0.3670 - val_loss: 2.4227 - val_accuracy: 0.4076 - val_top5_acc: 0.7103 - val_macro_f1score: 0.2250
# Learning rate:  0.0003
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 25/70
# 97/97 [==============================] - ETA: 0s - loss: 1.2630 - accuracy: 0.6367 - top5_acc: 0.9012 - macro_f1score: 0.3800
# Epoch 00025: val_loss did not improve from 2.31660
#
# Epoch 00025: val_accuracy improved from 0.41276 to 0.41862, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/AlexNet/025.h5
# 97/97 [==============================] - 265s 3s/step - loss: 1.2630 - accuracy: 0.6367 - top5_acc: 0.9012 - macro_f1score: 0.3800 - val_loss: 2.3364 - val_accuracy: 0.4186 - val_top5_acc: 0.7409 - val_macro_f1score: 0.2327
# Learning rate:  0.0003
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 26/70
# 97/97 [==============================] - ETA: 0s - loss: 1.1999 - accuracy: 0.6552 - top5_acc: 0.9114 - macro_f1score: 0.3981
# Epoch 00026: val_loss did not improve from 2.31660
#
# Epoch 00026: val_accuracy did not improve from 0.41862
# 97/97 [==============================] - 274s 3s/step - loss: 1.1999 - accuracy: 0.6552 - top5_acc: 0.9114 - macro_f1score: 0.3981 - val_loss: 2.5147 - val_accuracy: 0.4134 - val_top5_acc: 0.7201 - val_macro_f1score: 0.2458
# Learning rate:  0.0003
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 27/70
# 97/97 [==============================] - ETA: 0s - loss: 1.1218 - accuracy: 0.6751 - top5_acc: 0.9185 - macro_f1score: 0.4243
# Epoch 00027: val_loss did not improve from 2.31660
#
# Epoch 00027: val_accuracy improved from 0.41862 to 0.42643, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/AlexNet/027.h5
# 97/97 [==============================] - 280s 3s/step - loss: 1.1218 - accuracy: 0.6751 - top5_acc: 0.9185 - macro_f1score: 0.4243 - val_loss: 2.5238 - val_accuracy: 0.4264 - val_top5_acc: 0.7240 - val_macro_f1score: 0.2376
# Learning rate:  0.0003
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 28/70
# 97/97 [==============================] - ETA: 0s - loss: 1.0698 - accuracy: 0.6879 - top5_acc: 0.9289 - macro_f1score: 0.4427
# Epoch 00028: val_loss did not improve from 2.31660
#
# Epoch 00028: val_accuracy did not improve from 0.42643
# 97/97 [==============================] - 287s 3s/step - loss: 1.0698 - accuracy: 0.6879 - top5_acc: 0.9289 - macro_f1score: 0.4427 - val_loss: 2.5801 - val_accuracy: 0.4219 - val_top5_acc: 0.7350 - val_macro_f1score: 0.2578
# Learning rate:  0.0003
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 29/70
# 97/97 [==============================] - ETA: 0s - loss: 0.9980 - accuracy: 0.7118 - top5_acc: 0.9324 - macro_f1score: 0.4587
# Epoch 00029: val_loss did not improve from 2.31660
#
# Epoch 00029: val_accuracy did not improve from 0.42643
# 97/97 [==============================] - 286s 3s/step - loss: 0.9980 - accuracy: 0.7118 - top5_acc: 0.9324 - macro_f1score: 0.4587 - val_loss: 2.6046 - val_accuracy: 0.4167 - val_top5_acc: 0.7318 - val_macro_f1score: 0.2468
# Learning rate:  0.0003
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 30/70
# 97/97 [==============================] - ETA: 0s - loss: 0.9478 - accuracy: 0.7223 - top5_acc: 0.9404 - macro_f1score: 0.4757
# Epoch 00030: val_loss did not improve from 2.31660
#
# Epoch 00030: val_accuracy did not improve from 0.42643
# 97/97 [==============================] - 285s 3s/step - loss: 0.9478 - accuracy: 0.7223 - top5_acc: 0.9404 - macro_f1score: 0.4757 - val_loss: 2.5205 - val_accuracy: 0.4258 - val_top5_acc: 0.7266 - val_macro_f1score: 0.2467
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 31/70
# 97/97 [==============================] - ETA: 0s - loss: 0.7195 - accuracy: 0.7906 - top5_acc: 0.9613 - macro_f1score: 0.5382
# Epoch 00031: val_loss did not improve from 2.31660
#
# Epoch 00031: val_accuracy improved from 0.42643 to 0.44466, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/AlexNet/031.h5
# 97/97 [==============================] - 291s 3s/step - loss: 0.7195 - accuracy: 0.7906 - top5_acc: 0.9613 - macro_f1score: 0.5382 - val_loss: 2.5156 - val_accuracy: 0.4447 - val_top5_acc: 0.7409 - val_macro_f1score: 0.2633
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 32/70
# 97/97 [==============================] - ETA: 0s - loss: 0.6173 - accuracy: 0.8186 - top5_acc: 0.9698 - macro_f1score: 0.5594
# Epoch 00032: val_loss did not improve from 2.31660
#
# Epoch 00032: val_accuracy did not improve from 0.44466
# 97/97 [==============================] - 288s 3s/step - loss: 0.6173 - accuracy: 0.8186 - top5_acc: 0.9698 - macro_f1score: 0.5594 - val_loss: 2.5334 - val_accuracy: 0.4414 - val_top5_acc: 0.7500 - val_macro_f1score: 0.2644
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00033: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 33/70
# 97/97 [==============================] - ETA: 0s - loss: 0.5903 - accuracy: 0.8262 - top5_acc: 0.9713 - macro_f1score: 0.5812
# Epoch 00033: val_loss did not improve from 2.31660
#
# Epoch 00033: val_accuracy improved from 0.44466 to 0.44857, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/AlexNet/033.h5
# 97/97 [==============================] - 290s 3s/step - loss: 0.5903 - accuracy: 0.8262 - top5_acc: 0.9713 - macro_f1score: 0.5812 - val_loss: 2.5240 - val_accuracy: 0.4486 - val_top5_acc: 0.7520 - val_macro_f1score: 0.2841
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00034: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 34/70
# 97/97 [==============================] - ETA: 0s - loss: 0.5701 - accuracy: 0.8294 - top5_acc: 0.9746 - macro_f1score: 0.5801
# Epoch 00034: val_loss did not improve from 2.31660
#
# Epoch 00034: val_accuracy improved from 0.44857 to 0.45052, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/AlexNet/034.h5
# 97/97 [==============================] - 293s 3s/step - loss: 0.5701 - accuracy: 0.8294 - top5_acc: 0.9746 - macro_f1score: 0.5801 - val_loss: 2.5315 - val_accuracy: 0.4505 - val_top5_acc: 0.7578 - val_macro_f1score: 0.2810
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00035: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 35/70
# 97/97 [==============================] - ETA: 0s - loss: 0.5526 - accuracy: 0.8375 - top5_acc: 0.9733 - macro_f1score: 0.5907
# Epoch 00035: val_loss did not improve from 2.31660
#
# Epoch 00035: val_accuracy did not improve from 0.45052
# 97/97 [==============================] - 277s 3s/step - loss: 0.5526 - accuracy: 0.8375 - top5_acc: 0.9733 - macro_f1score: 0.5907 - val_loss: 2.5795 - val_accuracy: 0.4453 - val_top5_acc: 0.7585 - val_macro_f1score: 0.2838
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00036: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 36/70
# 97/97 [==============================] - ETA: 0s - loss: 0.5320 - accuracy: 0.8451 - top5_acc: 0.9746 - macro_f1score: 0.5983
# Epoch 00036: val_loss did not improve from 2.31660
#
# Epoch 00036: val_accuracy did not improve from 0.45052
# 97/97 [==============================] - 264s 3s/step - loss: 0.5320 - accuracy: 0.8451 - top5_acc: 0.9746 - macro_f1score: 0.5983 - val_loss: 2.5698 - val_accuracy: 0.4505 - val_top5_acc: 0.7578 - val_macro_f1score: 0.2841
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00037: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 37/70
# 97/97 [==============================] - ETA: 0s - loss: 0.5021 - accuracy: 0.8469 - top5_acc: 0.9767 - macro_f1score: 0.6006
# Epoch 00037: val_loss did not improve from 2.31660
#
# Epoch 00037: val_accuracy improved from 0.45052 to 0.45508, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/AlexNet/037.h5
# 97/97 [==============================] - 258s 3s/step - loss: 0.5021 - accuracy: 0.8469 - top5_acc: 0.9767 - macro_f1score: 0.6006 - val_loss: 2.6052 - val_accuracy: 0.4551 - val_top5_acc: 0.7565 - val_macro_f1score: 0.2824
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00038: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 38/70
# 97/97 [==============================] - ETA: 0s - loss: 0.5153 - accuracy: 0.8477 - top5_acc: 0.9777 - macro_f1score: 0.5963
# Epoch 00038: val_loss did not improve from 2.31660
#
# Epoch 00038: val_accuracy improved from 0.45508 to 0.45638, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/AlexNet/038.h5
# 97/97 [==============================] - 253s 3s/step - loss: 0.5153 - accuracy: 0.8477 - top5_acc: 0.9777 - macro_f1score: 0.5963 - val_loss: 2.5715 - val_accuracy: 0.4564 - val_top5_acc: 0.7611 - val_macro_f1score: 0.2857
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00039: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 39/70
# 97/97 [==============================] - ETA: 0s - loss: 0.4935 - accuracy: 0.8526 - top5_acc: 0.9787 - macro_f1score: 0.5987
# Epoch 00039: val_loss did not improve from 2.31660
#
# Epoch 00039: val_accuracy did not improve from 0.45638
# 97/97 [==============================] - 253s 3s/step - loss: 0.4935 - accuracy: 0.8526 - top5_acc: 0.9787 - macro_f1score: 0.5987 - val_loss: 2.6034 - val_accuracy: 0.4479 - val_top5_acc: 0.7617 - val_macro_f1score: 0.2771
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00040: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 40/70
# 97/97 [==============================] - ETA: 0s - loss: 0.4854 - accuracy: 0.8545 - top5_acc: 0.9802 - macro_f1score: 0.6064
# Epoch 00040: val_loss did not improve from 2.31660
#
# Epoch 00040: val_accuracy did not improve from 0.45638
# 97/97 [==============================] - 246s 3s/step - loss: 0.4854 - accuracy: 0.8545 - top5_acc: 0.9802 - macro_f1score: 0.6064 - val_loss: 2.6326 - val_accuracy: 0.4499 - val_top5_acc: 0.7565 - val_macro_f1score: 0.2679
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00041: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 41/70
# 97/97 [==============================] - ETA: 0s - loss: 0.4619 - accuracy: 0.8627 - top5_acc: 0.9794 - macro_f1score: 0.6167
# Epoch 00041: val_loss did not improve from 2.31660
#
# Epoch 00041: val_accuracy did not improve from 0.45638
# 97/97 [==============================] - 249s 3s/step - loss: 0.4619 - accuracy: 0.8627 - top5_acc: 0.9794 - macro_f1score: 0.6167 - val_loss: 2.6307 - val_accuracy: 0.4486 - val_top5_acc: 0.7598 - val_macro_f1score: 0.2781
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00042: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 42/70
# 97/97 [==============================] - ETA: 0s - loss: 0.4622 - accuracy: 0.8633 - top5_acc: 0.9815 - macro_f1score: 0.6187
# Epoch 00042: val_loss did not improve from 2.31660
#
# Epoch 00042: val_accuracy did not improve from 0.45638
# 97/97 [==============================] - 250s 3s/step - loss: 0.4622 - accuracy: 0.8633 - top5_acc: 0.9815 - macro_f1score: 0.6187 - val_loss: 2.6785 - val_accuracy: 0.4466 - val_top5_acc: 0.7520 - val_macro_f1score: 0.2739
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00043: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 43/70
# 97/97 [==============================] - ETA: 0s - loss: 0.4430 - accuracy: 0.8661 - top5_acc: 0.9824 - macro_f1score: 0.6177
# Epoch 00043: val_loss did not improve from 2.31660
#
# Epoch 00043: val_accuracy did not improve from 0.45638
# 97/97 [==============================] - 249s 3s/step - loss: 0.4430 - accuracy: 0.8661 - top5_acc: 0.9824 - macro_f1score: 0.6177 - val_loss: 2.7662 - val_accuracy: 0.4447 - val_top5_acc: 0.7493 - val_macro_f1score: 0.2759
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00044: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 44/70
# 97/97 [==============================] - ETA: 0s - loss: 0.4464 - accuracy: 0.8677 - top5_acc: 0.9807 - macro_f1score: 0.6226
# Epoch 00044: val_loss did not improve from 2.31660
#
# Epoch 00044: val_accuracy did not improve from 0.45638
# 97/97 [==============================] - 251s 3s/step - loss: 0.4464 - accuracy: 0.8677 - top5_acc: 0.9807 - macro_f1score: 0.6226 - val_loss: 2.6890 - val_accuracy: 0.4473 - val_top5_acc: 0.7591 - val_macro_f1score: 0.2911
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00045: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 45/70
# 97/97 [==============================] - ETA: 0s - loss: 0.4382 - accuracy: 0.8722 - top5_acc: 0.9826 - macro_f1score: 0.6233
# Epoch 00045: val_loss did not improve from 2.31660
#
# Epoch 00045: val_accuracy did not improve from 0.45638
# 97/97 [==============================] - 249s 3s/step - loss: 0.4382 - accuracy: 0.8722 - top5_acc: 0.9826 - macro_f1score: 0.6233 - val_loss: 2.7181 - val_accuracy: 0.4557 - val_top5_acc: 0.7695 - val_macro_f1score: 0.2818
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00046: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 46/70
# 97/97 [==============================] - ETA: 0s - loss: 0.4178 - accuracy: 0.8752 - top5_acc: 0.9834 - macro_f1score: 0.6297
# Epoch 00046: val_loss did not improve from 2.31660
#
# Epoch 00046: val_accuracy did not improve from 0.45638
# 97/97 [==============================] - 251s 3s/step - loss: 0.4178 - accuracy: 0.8752 - top5_acc: 0.9834 - macro_f1score: 0.6297 - val_loss: 2.7431 - val_accuracy: 0.4557 - val_top5_acc: 0.7546 - val_macro_f1score: 0.2837
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00047: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 47/70
# 97/97 [==============================] - ETA: 0s - loss: 0.4095 - accuracy: 0.8770 - top5_acc: 0.9849 - macro_f1score: 0.6327
# Epoch 00047: val_loss did not improve from 2.31660
#
# Epoch 00047: val_accuracy did not improve from 0.45638
# 97/97 [==============================] - 250s 3s/step - loss: 0.4095 - accuracy: 0.8770 - top5_acc: 0.9849 - macro_f1score: 0.6327 - val_loss: 2.7422 - val_accuracy: 0.4551 - val_top5_acc: 0.7533 - val_macro_f1score: 0.2800
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00048: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 48/70
# 97/97 [==============================] - ETA: 0s - loss: 0.4041 - accuracy: 0.8807 - top5_acc: 0.9835 - macro_f1score: 0.6285
# Epoch 00048: val_loss did not improve from 2.31660
#
# Epoch 00048: val_accuracy did not improve from 0.45638
# 97/97 [==============================] - 252s 3s/step - loss: 0.4041 - accuracy: 0.8807 - top5_acc: 0.9835 - macro_f1score: 0.6285 - val_loss: 2.7485 - val_accuracy: 0.4466 - val_top5_acc: 0.7689 - val_macro_f1score: 0.2772
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00049: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 49/70
# 97/97 [==============================] - ETA: 0s - loss: 0.3987 - accuracy: 0.8799 - top5_acc: 0.9857 - macro_f1score: 0.6384
# Epoch 00049: val_loss did not improve from 2.31660
#
# Epoch 00049: val_accuracy did not improve from 0.45638
# 97/97 [==============================] - 254s 3s/step - loss: 0.3987 - accuracy: 0.8799 - top5_acc: 0.9857 - macro_f1score: 0.6384 - val_loss: 2.7927 - val_accuracy: 0.4518 - val_top5_acc: 0.7552 - val_macro_f1score: 0.2783
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00050: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 50/70
# 97/97 [==============================] - ETA: 0s - loss: 0.3885 - accuracy: 0.8838 - top5_acc: 0.9846 - macro_f1score: 0.6354
# Epoch 00050: val_loss did not improve from 2.31660
#
# Epoch 00050: val_accuracy did not improve from 0.45638
# 97/97 [==============================] - 253s 3s/step - loss: 0.3885 - accuracy: 0.8838 - top5_acc: 0.9846 - macro_f1score: 0.6354 - val_loss: 2.7789 - val_accuracy: 0.4544 - val_top5_acc: 0.7585 - val_macro_f1score: 0.2920
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00051: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 51/70
# 97/97 [==============================] - ETA: 0s - loss: 0.3931 - accuracy: 0.8773 - top5_acc: 0.9854 - macro_f1score: 0.6350
# Epoch 00051: val_loss did not improve from 2.31660
#
# Epoch 00051: val_accuracy did not improve from 0.45638
# 97/97 [==============================] - 255s 3s/step - loss: 0.3931 - accuracy: 0.8773 - top5_acc: 0.9854 - macro_f1score: 0.6350 - val_loss: 2.8083 - val_accuracy: 0.4492 - val_top5_acc: 0.7559 - val_macro_f1score: 0.2823
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00052: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 52/70
# 97/97 [==============================] - ETA: 0s - loss: 0.3700 - accuracy: 0.8885 - top5_acc: 0.9889 - macro_f1score: 0.6376
# Epoch 00052: val_loss did not improve from 2.31660
#
# Epoch 00052: val_accuracy improved from 0.45638 to 0.45703, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/AlexNet/052.h5
# 97/97 [==============================] - 256s 3s/step - loss: 0.3700 - accuracy: 0.8885 - top5_acc: 0.9889 - macro_f1score: 0.6376 - val_loss: 2.8227 - val_accuracy: 0.4570 - val_top5_acc: 0.7624 - val_macro_f1score: 0.2958
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00053: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 53/70
# 97/97 [==============================] - ETA: 0s - loss: 0.3650 - accuracy: 0.8897 - top5_acc: 0.9873 - macro_f1score: 0.6449
# Epoch 00053: val_loss did not improve from 2.31660
#
# Epoch 00053: val_accuracy improved from 0.45703 to 0.46745, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/AlexNet/053.h5
# 97/97 [==============================] - 256s 3s/step - loss: 0.3650 - accuracy: 0.8897 - top5_acc: 0.9873 - macro_f1score: 0.6449 - val_loss: 2.7769 - val_accuracy: 0.4674 - val_top5_acc: 0.7669 - val_macro_f1score: 0.2941
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00054: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 54/70
# 97/97 [==============================] - ETA: 0s - loss: 0.3575 - accuracy: 0.8916 - top5_acc: 0.9891 - macro_f1score: 0.6436
# Epoch 00054: val_loss did not improve from 2.31660
#
# Epoch 00054: val_accuracy did not improve from 0.46745
# 97/97 [==============================] - 263s 3s/step - loss: 0.3575 - accuracy: 0.8916 - top5_acc: 0.9891 - macro_f1score: 0.6436 - val_loss: 2.7575 - val_accuracy: 0.4603 - val_top5_acc: 0.7656 - val_macro_f1score: 0.2911
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00055: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 55/70
# 97/97 [==============================] - ETA: 0s - loss: 0.3463 - accuracy: 0.8943 - top5_acc: 0.9891 - macro_f1score: 0.6521
# Epoch 00055: val_loss did not improve from 2.31660
#
# Epoch 00055: val_accuracy did not improve from 0.46745
# 97/97 [==============================] - 257s 3s/step - loss: 0.3463 - accuracy: 0.8943 - top5_acc: 0.9891 - macro_f1score: 0.6521 - val_loss: 2.8332 - val_accuracy: 0.4583 - val_top5_acc: 0.7630 - val_macro_f1score: 0.2904
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00056: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 56/70
# 97/97 [==============================] - ETA: 0s - loss: 0.3573 - accuracy: 0.8914 - top5_acc: 0.9868 - macro_f1score: 0.6502
# Epoch 00056: val_loss did not improve from 2.31660
#
# Epoch 00056: val_accuracy did not improve from 0.46745
# 97/97 [==============================] - 250s 3s/step - loss: 0.3573 - accuracy: 0.8914 - top5_acc: 0.9868 - macro_f1score: 0.6502 - val_loss: 2.7992 - val_accuracy: 0.4590 - val_top5_acc: 0.7656 - val_macro_f1score: 0.2851
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00057: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 57/70
# 97/97 [==============================] - ETA: 0s - loss: 0.3274 - accuracy: 0.9017 - top5_acc: 0.9899 - macro_f1score: 0.6575
# Epoch 00057: val_loss did not improve from 2.31660
#
# Epoch 00057: val_accuracy did not improve from 0.46745
# 97/97 [==============================] - 249s 3s/step - loss: 0.3274 - accuracy: 0.9017 - top5_acc: 0.9899 - macro_f1score: 0.6575 - val_loss: 2.8587 - val_accuracy: 0.4622 - val_top5_acc: 0.7643 - val_macro_f1score: 0.2908
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00058: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 58/70
# 97/97 [==============================] - ETA: 0s - loss: 0.3322 - accuracy: 0.8992 - top5_acc: 0.9888 - macro_f1score: 0.6493
# Epoch 00058: val_loss did not improve from 2.31660
#
# Epoch 00058: val_accuracy did not improve from 0.46745
# 97/97 [==============================] - 248s 3s/step - loss: 0.3322 - accuracy: 0.8992 - top5_acc: 0.9888 - macro_f1score: 0.6493 - val_loss: 2.8186 - val_accuracy: 0.4668 - val_top5_acc: 0.7643 - val_macro_f1score: 0.2896
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00059: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 59/70
# 97/97 [==============================] - ETA: 0s - loss: 0.3404 - accuracy: 0.8962 - top5_acc: 0.9902 - macro_f1score: 0.6529
# Epoch 00059: val_loss did not improve from 2.31660
#
# Epoch 00059: val_accuracy did not improve from 0.46745
# 97/97 [==============================] - 250s 3s/step - loss: 0.3404 - accuracy: 0.8962 - top5_acc: 0.9902 - macro_f1score: 0.6529 - val_loss: 2.8400 - val_accuracy: 0.4622 - val_top5_acc: 0.7539 - val_macro_f1score: 0.2900
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00060: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 60/70
# 97/97 [==============================] - ETA: 0s - loss: 0.3159 - accuracy: 0.9039 - top5_acc: 0.9909 - macro_f1score: 0.6556
# Epoch 00060: val_loss did not improve from 2.31660
#
# Epoch 00060: val_accuracy did not improve from 0.46745
# 97/97 [==============================] - 248s 3s/step - loss: 0.3159 - accuracy: 0.9039 - top5_acc: 0.9909 - macro_f1score: 0.6556 - val_loss: 2.8209 - val_accuracy: 0.4629 - val_top5_acc: 0.7591 - val_macro_f1score: 0.2901
# Learning rate:  2.9999999999999997e-06
#
# Epoch 00061: LearningRateScheduler reducing learning rate to 2.9999999999999997e-06.
# Epoch 61/70
# 97/97 [==============================] - ETA: 0s - loss: 0.3245 - accuracy: 0.9028 - top5_acc: 0.9899 - macro_f1score: 0.6589
# Epoch 00061: val_loss did not improve from 2.31660
#
# Epoch 00061: val_accuracy did not improve from 0.46745
# 97/97 [==============================] - 252s 3s/step - loss: 0.3245 - accuracy: 0.9028 - top5_acc: 0.9899 - macro_f1score: 0.6589 - val_loss: 2.8152 - val_accuracy: 0.4616 - val_top5_acc: 0.7617 - val_macro_f1score: 0.2816
# Learning rate:  2.9999999999999997e-06
#
# Epoch 00062: LearningRateScheduler reducing learning rate to 2.9999999999999997e-06.
# Epoch 62/70
# 97/97 [==============================] - ETA: 0s - loss: 0.3026 - accuracy: 0.9078 - top5_acc: 0.9904 - macro_f1score: 0.6613
# Epoch 00062: val_loss did not improve from 2.31660
#
# Epoch 00062: val_accuracy did not improve from 0.46745
# 97/97 [==============================] - 248s 3s/step - loss: 0.3026 - accuracy: 0.9078 - top5_acc: 0.9904 - macro_f1score: 0.6613 - val_loss: 2.8332 - val_accuracy: 0.4583 - val_top5_acc: 0.7643 - val_macro_f1score: 0.2888
# Learning rate:  2.9999999999999997e-06
#
# Epoch 00063: LearningRateScheduler reducing learning rate to 2.9999999999999997e-06.
# Epoch 63/70
# 97/97 [==============================] - ETA: 0s - loss: 0.3078 - accuracy: 0.9053 - top5_acc: 0.9908 - macro_f1score: 0.6643
# Epoch 00063: val_loss did not improve from 2.31660
#
# Epoch 00063: val_accuracy did not improve from 0.46745
# 97/97 [==============================] - 250s 3s/step - loss: 0.3078 - accuracy: 0.9053 - top5_acc: 0.9908 - macro_f1score: 0.6643 - val_loss: 2.8220 - val_accuracy: 0.4603 - val_top5_acc: 0.7643 - val_macro_f1score: 0.2939
# Learning rate:  2.9999999999999997e-06
#
# Epoch 00064: LearningRateScheduler reducing learning rate to 2.9999999999999997e-06.
# Epoch 64/70
# 97/97 [==============================] - ETA: 0s - loss: 0.3206 - accuracy: 0.9017 - top5_acc: 0.9889 - macro_f1score: 0.6581
# Epoch 00064: val_loss did not improve from 2.31660
#
# Epoch 00064: val_accuracy did not improve from 0.46745
# 97/97 [==============================] - 254s 3s/step - loss: 0.3206 - accuracy: 0.9017 - top5_acc: 0.9889 - macro_f1score: 0.6581 - val_loss: 2.7924 - val_accuracy: 0.4674 - val_top5_acc: 0.7617 - val_macro_f1score: 0.2957
# Learning rate:  2.9999999999999997e-06
#
# Epoch 00065: LearningRateScheduler reducing learning rate to 2.9999999999999997e-06.
# Epoch 65/70
# 97/97 [==============================] - ETA: 0s - loss: 0.3008 - accuracy: 0.9076 - top5_acc: 0.9913 - macro_f1score: 0.6651
# Epoch 00065: val_loss did not improve from 2.31660
#
# Epoch 00065: val_accuracy did not improve from 0.46745
# 97/97 [==============================] - 279s 3s/step - loss: 0.3008 - accuracy: 0.9076 - top5_acc: 0.9913 - macro_f1score: 0.6651 - val_loss: 2.7955 - val_accuracy: 0.4577 - val_top5_acc: 0.7656 - val_macro_f1score: 0.2832
# Learning rate:  2.9999999999999997e-06
#
# Epoch 00066: LearningRateScheduler reducing learning rate to 2.9999999999999997e-06.
# Epoch 66/70
# 97/97 [==============================] - ETA: 0s - loss: 0.3048 - accuracy: 0.9078 - top5_acc: 0.9911 - macro_f1score: 0.6584
# Epoch 00066: val_loss did not improve from 2.31660
#
# Epoch 00066: val_accuracy did not improve from 0.46745
# 97/97 [==============================] - 286s 3s/step - loss: 0.3048 - accuracy: 0.9078 - top5_acc: 0.9911 - macro_f1score: 0.6584 - val_loss: 2.7630 - val_accuracy: 0.4661 - val_top5_acc: 0.7637 - val_macro_f1score: 0.2888
# Learning rate:  2.9999999999999997e-06
#
# Epoch 00067: LearningRateScheduler reducing learning rate to 2.9999999999999997e-06.
# Epoch 67/70
# 97/97 [==============================] - ETA: 0s - loss: 0.3066 - accuracy: 0.9103 - top5_acc: 0.9902 - macro_f1score: 0.6621
# Epoch 00067: val_loss did not improve from 2.31660
#
# Epoch 00067: val_accuracy did not improve from 0.46745
# 97/97 [==============================] - 288s 3s/step - loss: 0.3066 - accuracy: 0.9103 - top5_acc: 0.9902 - macro_f1score: 0.6621 - val_loss: 2.7606 - val_accuracy: 0.4648 - val_top5_acc: 0.7643 - val_macro_f1score: 0.2896
# Learning rate:  2.9999999999999997e-06
#
# Epoch 00068: LearningRateScheduler reducing learning rate to 2.9999999999999997e-06.
# Epoch 68/70
# 97/97 [==============================] - ETA: 0s - loss: 0.3037 - accuracy: 0.9095 - top5_acc: 0.9908 - macro_f1score: 0.6640
# Epoch 00068: val_loss did not improve from 2.31660
#
# Epoch 00068: val_accuracy did not improve from 0.46745
# 97/97 [==============================] - 289s 3s/step - loss: 0.3037 - accuracy: 0.9095 - top5_acc: 0.9908 - macro_f1score: 0.6640 - val_loss: 2.7954 - val_accuracy: 0.4642 - val_top5_acc: 0.7572 - val_macro_f1score: 0.2942
# Learning rate:  2.9999999999999997e-06
#
# Epoch 00069: LearningRateScheduler reducing learning rate to 2.9999999999999997e-06.
# Epoch 69/70
# 97/97 [==============================] - ETA: 0s - loss: 0.2961 - accuracy: 0.9100 - top5_acc: 0.9919 - macro_f1score: 0.6686
# Epoch 00069: val_loss did not improve from 2.31660
#
# Epoch 00069: val_accuracy improved from 0.46745 to 0.46810, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/AlexNet/069.h5
# 97/97 [==============================] - 290s 3s/step - loss: 0.2961 - accuracy: 0.9100 - top5_acc: 0.9919 - macro_f1score: 0.6686 - val_loss: 2.7471 - val_accuracy: 0.4681 - val_top5_acc: 0.7643 - val_macro_f1score: 0.2936
# Learning rate:  2.9999999999999997e-06
#
# Epoch 00070: LearningRateScheduler reducing learning rate to 2.9999999999999997e-06.
# Epoch 70/70
# 97/97 [==============================] - ETA: 0s - loss: 0.2972 - accuracy: 0.9106 - top5_acc: 0.9904 - macro_f1score: 0.6645
# Epoch 00070: val_loss did not improve from 2.31660
#
# Epoch 00070: val_accuracy did not improve from 0.46810
# 97/97 [==============================] - 292s 3s/step - loss: 0.2972 - accuracy: 0.9106 - top5_acc: 0.9904 - macro_f1score: 0.6645 - val_loss: 2.7665 - val_accuracy: 0.4642 - val_top5_acc: 0.7643 - val_macro_f1score: 0.2893

# %% [markdown]
# ### 3) AlexNet Evaluate

# %%
# 1. epoch=maximum
loss , acc, top5_acc, mf1 = model.evaluate(test_generator,steps=int(len(x_test)/batch_sizes))
print('[Test Loss: %.4f /  Test Top-1 Accuracy: %.4f / Test Top-5 Accuracy: %.4f / Test Macro f1: %.4f]\n' % (loss,acc,top5_acc,mf1))
# Out:
# 12/12 [==============================] - 679s 57s/step - loss: 2.8410 - accuracy: 0.4642 - top5_acc: 0.7533 - macro_f1score: 0.2888
# [Test Loss: 2.8410 /  Test Top-1 Accuracy: 0.4642 / Test Top-5 Accuracy: 0.7533 / Test Macro f1: 0.2888]

# %%
loss=history.history['loss']
val_loss=history.history['val_loss']
acc=history.history['accuracy']
val_acc=history.history['val_accuracy']
top5_acc=history.history['top5_acc']
val_top5_acc=history.history['val_top5_acc']
f1=history.history['macro_f1score']
val_f1=history.history['val_macro_f1score']
epochs=range(1,len(acc)+1)

data = np.array([epochs,loss,val_loss,acc,val_acc,top5_acc,val_top5_acc,f1,val_f1]).T

# %%
# data save
# epochs, loss, val_loss, acc, val_acc, top5_acc, val_top5_acc, f1, val_f1

np.savetxt(os.path.join(dir,'train_valid_output',number,model.name+'.txt'),data)

# %%
# data import
data = np.loadtxt(os.path.join(dir,'train_valid_output',number,'AlexNet.txt'))

# %%
epochs=data[:,0]
loss=data[:,1]
val_loss=data[:,2]
acc=data[:,3]
val_acc=data[:,4]
top5_acc=data[:,5]
val_top5_acc=data[:,6]

# %%
plt.plot(epochs[1:],acc[1:],'b',label='Training 1-Acc')
plt.plot(epochs[1:],val_acc[1:],'r',label='Validation 1-Acc')
plt.title('Training and Validation Top-1 Accuracy')
plt.legend()
plt.figure()

plt.plot(epochs[1:],top5_acc[1:],'b',label='Training 5-Acc')
plt.plot(epochs[1:],val_top5_acc[1:],'r',label='Validation 5-Acc')
plt.title('Training and Validation Top-5 Accuracy')
plt.legend()
plt.figure()

plt.plot(epochs[10:],loss[10:],'b',label='Training Loss')
plt.plot(epochs[10:],val_loss[10:],'r',label='Validation Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()

# %%
# 이 아래는 내가 인위적으로 살펴보고 싶은 epoch에 대해서 결과값 출력 / AlexNet

# %%
# 참고 : https://github.com/OverLordGoldDragon/keras-adamw

import sys
sys.path.append('/content/drive/My Drive/Colab Notebooks/Paper')
import utils
import optimizers_v2
from utils import get_weight_decays, fill_dict_in_order
from utils import reset_seeds, K_eval
from optimizers_v2 import AdamW, NadamW, SGDW

# %%
# top-5 accuracy 출력
import functools
top5_acc = functools.partial(ks.metrics.top_k_categorical_accuracy, k=5)
top5_acc.__name__ = 'top5_acc'

# %%
model=load_model(os.path.join(dir,'model_output',number,'AlexNet','069.h5'),custom_objects={"macro_f1score": macro_f1score,"top5_acc":top5_acc,"LRN":LRN, "AdamW":AdamW})

# %%
# 2. epoch=?
loss , acc, top5_acc, mf1 = model.evaluate(test_generator,steps=int(len(x_test)/batch_sizes))
print('[Test Loss: %.4f /  Test Top-1 Accuracy: %.4f / Test Top-5 Accuracy: %.4f / Test Macro f1: %.4f]\n' % (loss,acc,top5_acc,mf1))
# Out:
# 12/12 [==============================] - 737s 61s/step - loss: 2.8211 - accuracy: 0.4616 - top5_acc: 0.7572 - macro_f1score: 0.2914
# [Test Loss: 2.8211 /  Test Top-1 Accuracy: 0.4616 / Test Top-5 Accuracy: 0.7572 / Test Macro f1: 0.2914]
