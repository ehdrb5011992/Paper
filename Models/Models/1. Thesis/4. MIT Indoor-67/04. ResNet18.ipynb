# %%
#모형 출처 : https://github.com/titu1994/keras-squeeze-excite-network

# %% [markdown]
# # [ResNet18]

# %% [markdown]
# *KU LeeDongGyu*

# %% [markdown]
# ## Contents
# ---

# %% [markdown]
# 1. Data Preprocessing
# ```
# 1) Data Import
# 2) Data Augmentation
# ```
# 2. Support Functions & Almost Original ResNet
# ```
# 1) Support Functions
# 2) Almost orginal ResNet
# ```
# 3. ResNet18
# ```
# 1) ResNet18
# 2) ResNet18 Evaluate
# ```

# %% [markdown]
# ### Install Packages

# %% [markdown]
# ### Module

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
cd /content/drive/My Drive/Colab Notebooks/Paper
# Out:
# /content/drive/My Drive/Colab Notebooks/Paper

# %%
from f1score import macro_f1score,weighted_f1score

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import cv2
import tensorflow as tf
from tensorflow import keras as ks
from tensorflow.keras import backend as K 
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, Input, Concatenate, ZeroPadding2D ,GlobalMaxPooling2D, Reshape , Lambda , Add, Multiply
from tensorflow.keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D, Activation, BatchNormalization, AveragePooling2D , ZeroPadding2D, SeparableConv2D , LeakyReLU
from tensorflow.keras.layers import add, concatenate, multiply
from tensorflow.keras.optimizers import Adam, RMSprop , SGD
from tensorflow.keras.callbacks import EarlyStopping , LearningRateScheduler, ModelCheckpoint, CSVLogger, Callback, ReduceLROnPlateau
from tensorflow.keras.regularizers import l1,l2,l1_l2
from tensorflow.keras.models import Model , load_model , Sequential
from tensorflow.keras.utils import plot_model , to_categorical, get_file
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
os.getcwd()
# Out:
# '/content/drive/My Drive/Colab Notebooks/Paper'

# %%
print(tf.__version__)
print(ks.__version__)
# Out:
# 2.3.0
# 2.4.0

# %%
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 12929062228078560345
# , name: "/device:XLA_CPU:0"
# device_type: "XLA_CPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 16508491518867379128
# physical_device_desc: "device: XLA_CPU device"
# , name: "/device:XLA_GPU:0"
# device_type: "XLA_GPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 9410464668670118998
# physical_device_desc: "device: XLA_GPU device"
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 15695426368
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 5479678481852949289
# physical_device_desc: "device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0"
# ]

# %%
# !cat /proc/cpuinfo
# Out:
# processor	: 0
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 79
# model name	: Intel(R) Xeon(R) CPU @ 2.20GHz
# stepping	: 0
# microcode	: 0x1
# cpu MHz		: 2200.000
# cache size	: 56320 KB
# physical id	: 0
# siblings	: 4
# core id		: 0
# cpu cores	: 2
# apicid		: 0
# initial apicid	: 0
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm rdseed adx smap xsaveopt arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs taa
# bogomips	: 4400.00
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 46 bits physical, 48 bits virtual
# power management:
#
# processor	: 1
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 79
# model name	: Intel(R) Xeon(R) CPU @ 2.20GHz
# stepping	: 0
# microcode	: 0x1
# cpu MHz		: 2200.000
# cache size	: 56320 KB
# physical id	: 0
# siblings	: 4
# core id		: 1
# cpu cores	: 2
# apicid		: 2
# initial apicid	: 2
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm rdseed adx smap xsaveopt arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs taa
# bogomips	: 4400.00
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 46 bits physical, 48 bits virtual
# power management:
#
# processor	: 2
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 79
# model name	: Intel(R) Xeon(R) CPU @ 2.20GHz
# stepping	: 0
# microcode	: 0x1
# cpu MHz		: 2200.000
# cache size	: 56320 KB
# physical id	: 0
# siblings	: 4
# core id		: 0
# cpu cores	: 2
# apicid		: 1
# initial apicid	: 1
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm rdseed adx smap xsaveopt arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs taa
# bogomips	: 4400.00
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 46 bits physical, 48 bits virtual
# power management:
#
# processor	: 3
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 79
# model name	: Intel(R) Xeon(R) CPU @ 2.20GHz
# stepping	: 0
# microcode	: 0x1
# cpu MHz		: 2200.000
# cache size	: 56320 KB
# physical id	: 0
# siblings	: 4
# core id		: 1
# cpu cores	: 2
# apicid		: 3
# initial apicid	: 3
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm rdseed adx smap xsaveopt arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs taa
# bogomips	: 4400.00
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 46 bits physical, 48 bits virtual
# power management:

# %% [markdown]
# ## 1. Data Preprocessing
# ---

# %% [markdown]
# ### 1) Data Import

# %%
# 바꿔서 살펴 볼 것들
# CALTECH, CIFAR100, FER, MIT
data_name = 'MIT'
gan_type = 'No_GAN'
number = '1'
size = 224 # sizes after cropping
super_size = 256 # sizes before cropping 
input_sizes = (size,size,3)
batch_sizes = 128
weight_decay = 2e-3
epochs = 70

# %%
# 참고 : https://stackoverflow.com/questions/32419510/how-to-get-reproducible-results-in-keras/52897216#52897216
# setting the seed number for random number generation for reproducibility.

from numpy.random import seed
import random


if number=='1':
    seed_num = 200225
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)
elif number=='2':
    seed_num = 727
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)
elif number=='3':
    seed_num = 115
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)
elif number=='4':
    seed_num = 501
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)
elif number=='5':
    seed_num = 517
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)

# %%
# data import

if data_name=='FER' :
    x_train =  np.zeros(28698)
    x_valid = np.zeros(3589)
    x_test = np.zeros(3588)
    classes = 7 
    tr_center = [0.50793296, 0.50793296, 0.50793296]
elif data_name=='MIT':
    x_train = np.zeros(12466)
    x_valid = np.zeros(1564)
    x_test = np.zeros(1590)
    classes = 67 
    tr_center = [0.47916578, 0.42029615, 0.36046057]
elif data_name=='CALTECH':
    x_train = np.zeros(24510)
    x_valid = np.zeros(2980)
    x_test = np.zeros(3118)
    classes = 257
    tr_center = [0.51397761, 0.49525248, 0.46555727]
elif data_name=='CIFAR100':
    x_train = np.zeros(44923)
    x_valid = np.zeros(5077)
    x_test = np.zeros(10000)
    classes = 100
    tr_center = [0.53442983, 0.51355958, 0.46462564]

# %%
dir = os.path.join(os.getcwd(),data_name,gan_type)

# %% [markdown]
# ### 2) Data Augmentation

# %%
# 참고 : https://jkjung-avt.github.io/keras-image-cropping/

def random_crop(img, random_crop_size):
    # Note: image_data_format is 'channel_last'
    assert img.shape[2] == 3 # img.shape[2] 가 3(rgb)이 아니면 assertion error 발생
    height, width = img.shape[0], img.shape[1]
    dy, dx = random_crop_size
    x = np.random.randint(0, width - dx + 1)
    y = np.random.randint(0, height - dy + 1)
    return img[y:(y+dy), x:(x+dx), :]


def crop_generator(batches, crop_length):
    """Take as input a Keras ImageGen (Iterator) and generate random
    crops from the image batches generated by the original iterator.
    """
    while True:
        batch_x, batch_y = next(batches)
        batch_crops = np.zeros((batch_x.shape[0], crop_length, crop_length, 3))
        for i in range(batch_x.shape[0]):
            batch_crops[i] = random_crop(batch_x[i], (crop_length, crop_length))
        yield (batch_crops, batch_y)

# %%
from tensorflow.keras.preprocessing.image import img_to_array,load_img
import glob

# 데이터 전체에 대해 centering 진행함.

def read_cal_image(img_path): 
    x = img_to_array(load_img(img_path)) # x는 채널별 평균값
    y = x.shape[0] * x.shape[1]# y는 데이터별 픽셀 수 (비중)

    x = 1/255. * x # scaling하고, centering값을 뽑아냄.
    x = np.mean(x, axis=(0,1))
    
    return np.hstack([x,y])

def calculate_centered_mean(dataset_path,x_train=x_train):
    num = len(x_train)
    space = np.empty((num,4))
    i=0

    for p in glob.glob(os.path.join(dataset_path,'*/*.*')) :
        space[i] = read_cal_image(p)
        i += 1

    ratio = space[:,3] / np.sum(space[:,3])

    return np.average(space[:,0:3],axis=0,weights=ratio)


# 아래의 함수를 돌려서 나온 결과값을 중심화 값으로 설정.

# train_mean = calculate_centered_mean(os.path.join(dir,'data/train')).reshape((1,1,3))

# %%
datagen_tr = ImageDataGenerator(
    rescale=1/255.,
    horizontal_flip=True,
    featurewise_center=True,
    featurewise_std_normalization=False,
    rotation_range=10,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=[0.9,1.0],
    fill_mode = 'nearest')
datagen_val = ImageDataGenerator(rescale=1/255.,featurewise_center=True)
datagen_tes = ImageDataGenerator(rescale=1/255.,featurewise_center=True)

# 원래는 이 자리에 fit 매서드를 써야하지만, 그냥 내가 중심화함수를 만들고 적용함. 

# 중심화 설정
datagen_tr.mean = np.array(tr_center, dtype=np.float32).reshape((1,1,3)) # RGB
datagen_val.mean = np.array(tr_center, dtype=np.float32).reshape((1,1,3)) # RGB
datagen_tes.mean = np.array(tr_center, dtype=np.float32).reshape((1,1,3)) # RGB

# %%
train_batches = datagen_tr.flow_from_directory(directory=os.path.join(dir,'data/train'),target_size=(super_size,super_size),batch_size=batch_sizes,class_mode='categorical') # fer : 28698 / mit : 12466 / caltech : 24509 / cifar : 44923
train_generator= crop_generator(train_batches, size)
valid_generator = datagen_val.flow_from_directory(directory=os.path.join(dir,'data/valid'),target_size=(size,size),batch_size=batch_sizes,class_mode='categorical') # fer : 3589 / mit : 1564 / caltech : 2980 / cifar : 5077
test_generator = datagen_tes.flow_from_directory(directory=os.path.join(dir,'data/test'),target_size=(size,size),batch_size=batch_sizes,class_mode='categorical') # fer : 3588 / mit : 1590 / caltech : 3118 / cifar : 10000
# Out:
# Found 12466 images belonging to 67 classes.
# Found 1564 images belonging to 67 classes.
# Found 1590 images belonging to 67 classes.

# %% [markdown]
# ## 2. Support Functions & Almost Original ResNet
# ---

# %% [markdown]
# ### 1) Support Functions

# %%
# def lr_schedule(epoch):
#     init_lr = 1e-4
#     k = 0.04
#     lr = init_lr * np.exp(-k*epoch)
#     print('Learning rate: ', lr)
#     return lr

def lr_schedule(epoch):
    lr = 1e-3
    if epoch < 30:
        lr = lr
    elif epoch < 60 :
        lr = lr * 0.1
    else:
        lr = lr * 0.01
    print('Learning rate: ', lr)
    return lr

# %%
def _resnet_block(input_tensor, filters, k=1, strides=(1, 1), weight_decay = weight_decay):

    init = input_tensor
    channel_axis = -1

    if strides != (1, 1) or init.get_shape()[channel_axis] != filters * k:
        x = Conv2D(filters * k, (1, 1), padding='same', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay),
                      use_bias=False, strides=strides)(input_tensor)
        init = BatchNormalization(axis=channel_axis)(x)


    x = Conv2D(filters * k, (3, 3), padding='same', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay),
               use_bias=False, strides=strides)(input_tensor)
    x = BatchNormalization(axis=channel_axis)(x)
    x = Activation('relu')(x)

    x = Conv2D(filters * k, (3, 3), padding='same', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay),
               use_bias=False)(x)
    x = BatchNormalization(axis=channel_axis)(x)

    m = add([x, init])
    m = Activation('relu')(m)

    return m

# %%
def _resnet_bottleneck_block(input_tensor, filters, k=1, strides=(1, 1), weight_decay = weight_decay):

    init = input_tensor
    channel_axis = -1
    bottleneck_expand = 4

    if strides != (1, 1) or init.get_shape()[channel_axis] != bottleneck_expand * filters * k:
        x = Conv2D(bottleneck_expand * filters * k, (1, 1), padding='same', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay),
                      use_bias=False, strides=strides)(input_tensor)
        init = BatchNormalization(axis=channel_axis)(x)


    x = Conv2D(filters * k, (1, 1), padding='same', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay),
               use_bias=False)(input_tensor)
    x = BatchNormalization(axis=channel_axis)(x)
    x = Activation('relu')(x)

    x = Conv2D(filters * k, (3, 3), padding='same', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay),
               use_bias=False, strides=strides)(x)
    x = BatchNormalization(axis=channel_axis)(x)
    x = Activation('relu')(x)

    x = Conv2D(bottleneck_expand * filters * k, (1, 1), padding='same', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay),
               use_bias=False)(x)
    x = BatchNormalization(axis=channel_axis)(x)    

    m = add([x, init])
    m = Activation('relu')(m)

    return m

# %% [markdown]
# ### 2) Almost Orginial ResNet

# %%
def _create_resnet(classes, img_input, initial_conv_filters, filters, depth, width, bottleneck, weight_decay):

    channel_axis = -1
    N = list(depth)

    # block 1 (initial conv block)
    x = Conv2D(initial_conv_filters, (7, 7), padding='same', use_bias=False, strides=(2, 2), kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(img_input)
    x = MaxPooling2D((3, 3), strides=(2, 2), padding='same')(x)

    # block 2 (projection block)
    for i in range(N[0]):
        if bottleneck:
            x = _resnet_bottleneck_block(x, filters[0], width)
        else:
            x = _resnet_block(x, filters[0], width)

    # block 3 - N
    for k in range(1, len(N)):
        if bottleneck:
            x = _resnet_bottleneck_block(x, filters[k], width, strides=(2, 2))
        else:
            x = _resnet_block(x, filters[k], width, strides=(2, 2))

        for i in range(N[k] - 1):
            if bottleneck:
                x = _resnet_bottleneck_block(x, filters[k], width)
            else:
                x = _resnet_block(x, filters[k], width)

    x = GlobalAveragePooling2D()(x)
    x = Dense(classes, use_bias=False, kernel_regularizer=l2(weight_decay), activation='softmax')(x)


    return x

# %%
def ResNet(input_shape=None, initial_conv_filters=64, depth=[3, 4, 6, 3], filters=[64, 128, 256, 512],
             width=1, bottleneck=False, weight_decay=weight_decay, name=None, classes=1000):


    img_input = Input(shape=input_shape)

    x = _create_resnet(classes, img_input, initial_conv_filters, filters, depth, width, bottleneck, weight_decay)

    # Ensure that the model takes into account
    # any potential predecessors of `input_tensor`.

    inputs = img_input

    # Create model.
    model = Model(inputs, x, name = name)

    return model

# %% [markdown]
# ## 3. ResNet18
# ---

# %% [markdown]
# ### 1) ResNet18

# %%
# ResNet18
model = ResNet(input_shape=input_sizes, depth=[2, 2, 2, 2], width=1, bottleneck=False, weight_decay=weight_decay, classes=classes, name='ResNet18')

# %%
model.summary()
# Out:
# Model: "ResNet18"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 112, 112, 64) 9408        input_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 56, 56, 64)   0           conv2d[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 56, 56, 64)   36864       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 56, 56, 64)   256         conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 56, 56, 64)   0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 56, 56, 64)   36864       activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 56, 56, 64)   256         conv2d_2[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 56, 56, 64)   0           batch_normalization_1[0][0]
#                                                                  max_pooling2d[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 56, 56, 64)   0           add[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 56, 56, 64)   36864       activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 56, 56, 64)   256         conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 56, 56, 64)   0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 56, 56, 64)   36864       activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 56, 56, 64)   256         conv2d_4[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 56, 56, 64)   0           batch_normalization_3[0][0]
#                                                                  activation_1[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 56, 56, 64)   0           add_1[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 28, 28, 128)  73728       activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 28, 28, 128)  512         conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 28, 28, 128)  0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 28, 28, 128)  147456      activation_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 28, 28, 128)  8192        activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 28, 28, 128)  512         conv2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 28, 28, 128)  512         conv2d_5[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 28, 28, 128)  0           batch_normalization_6[0][0]
#                                                                  batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 28, 28, 128)  0           add_2[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 28, 28, 128)  147456      activation_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 28, 28, 128)  512         conv2d_8[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 28, 28, 128)  0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 28, 28, 128)  147456      activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 28, 28, 128)  512         conv2d_9[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 28, 28, 128)  0           batch_normalization_8[0][0]
#                                                                  activation_5[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 28, 28, 128)  0           add_3[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 14, 14, 256)  294912      activation_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 14, 14, 256)  1024        conv2d_11[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 14, 14, 256)  0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 14, 14, 256)  589824      activation_8[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 14, 14, 256)  32768       activation_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 14, 14, 256)  1024        conv2d_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 14, 14, 256)  1024        conv2d_10[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 14, 14, 256)  0           batch_normalization_11[0][0]
#                                                                  batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 14, 14, 256)  0           add_4[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 14, 14, 256)  589824      activation_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 14, 14, 256)  1024        conv2d_13[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 14, 14, 256)  0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 14, 14, 256)  589824      activation_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 14, 14, 256)  1024        conv2d_14[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 14, 14, 256)  0           batch_normalization_13[0][0]
#                                                                  activation_9[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 14, 14, 256)  0           add_5[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 7, 7, 512)    1179648     activation_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 7, 7, 512)    2048        conv2d_16[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 7, 7, 512)    0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 7, 7, 512)    2359296     activation_12[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 7, 7, 512)    131072      activation_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 7, 7, 512)    2048        conv2d_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 7, 7, 512)    2048        conv2d_15[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 7, 7, 512)    0           batch_normalization_16[0][0]
#                                                                  batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 7, 7, 512)    0           add_6[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 7, 7, 512)    2359296     activation_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 7, 7, 512)    2048        conv2d_18[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 7, 7, 512)    0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 7, 7, 512)    2359296     activation_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 7, 7, 512)    2048        conv2d_19[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 7, 7, 512)    0           batch_normalization_18[0][0]
#                                                                  activation_13[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 7, 7, 512)    0           add_7[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 512)          0           activation_15[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 67)           34304       global_average_pooling2d[0][0]
# ==================================================================================================
# Total params: 11,220,160
# Trainable params: 11,210,688
# Non-trainable params: 9,472
# __________________________________________________________________________________________________

# %%
# 폴더 생성

os.makedirs(os.path.join(dir,'model_output',number,model.name), exist_ok=True)
os.makedirs(os.path.join(dir,'train_valid_output',number), exist_ok=True)

# %%
# 참고 : https://github.com/OverLordGoldDragon/keras-adamw

import sys
sys.path.append('/content/drive/My Drive/Colab Notebooks/Paper')
import utils
import optimizers_v2
from utils import get_weight_decays, fill_dict_in_order
from utils import reset_seeds, K_eval
from optimizers_v2 import AdamW, NadamW, SGDW

# %%
# top-5 accuracy 출력
import functools
top5_acc = functools.partial(ks.metrics.top_k_categorical_accuracy, k=5)
top5_acc.__name__ = 'top5_acc'

# %%
#optimizer = SGDW(model=model, use_cosine_annealing=False, total_iterations = len(x_train) // batch_sizes, nesterov=True, momentum=0.9)
optimizer = AdamW(model=model, use_cosine_annealing=False, total_iterations = len(x_train) // batch_sizes)
#optimizer = Adam()
filepath =  os.path.join(dir,'model_output',number,model.name,'{epoch:03d}.h5')

callbacks_list = [ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_weights_only=False, save_best_only=True, mode='min'),
                  ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_weights_only=False, save_best_only=True, mode='max'),
                  #ReduceLROnPlateau(monitor='val_loss',patience=3,factor=0.1,min_lr=1e-5),
                  LearningRateScheduler(lr_schedule,verbose=1)
                  ]
                  
model.compile(optimizer, loss = 'categorical_crossentropy', metrics=['accuracy',top5_acc,macro_f1score])

# %%
######## flow_from_directory
history = model.fit(train_generator, steps_per_epoch=int(len(x_train)/batch_sizes),  validation_data = valid_generator, epochs=epochs , verbose=1 , callbacks = callbacks_list , validation_steps=int(len(x_valid)/batch_sizes))
# Out:
# Learning rate:  0.001
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 1/70
# 0.0(L1), 0.0002030692426719948(L2) weight decay set for conv2d/kernel:0
# 0.0(L1), 0.0002030692426719948(L2) weight decay set for conv2d_1/kernel:0
# 0.0(L1), 0.0002030692426719948(L2) weight decay set for conv2d_2/kernel:0
# 0.0(L1), 0.0002030692426719948(L2) weight decay set for conv2d_3/kernel:0
# 0.0(L1), 0.0002030692426719948(L2) weight decay set for conv2d_4/kernel:0
# 0.0(L1), 0.0002030692426719948(L2) weight decay set for conv2d_6/kernel:0
# 0.0(L1), 0.0002030692426719948(L2) weight decay set for conv2d_7/kernel:0
# 0.0(L1), 0.0002030692426719948(L2) weight decay set for conv2d_5/kernel:0
# 0.0(L1), 0.0002030692426719948(L2) weight decay set for conv2d_8/kernel:0
# 0.0(L1), 0.0002030692426719948(L2) weight decay set for conv2d_9/kernel:0
# 0.0(L1), 0.0002030692426719948(L2) weight decay set for conv2d_11/kernel:0
# 0.0(L1), 0.0002030692426719948(L2) weight decay set for conv2d_12/kernel:0
# 0.0(L1), 0.0002030692426719948(L2) weight decay set for conv2d_10/kernel:0
# 0.0(L1), 0.0002030692426719948(L2) weight decay set for conv2d_13/kernel:0
# 0.0(L1), 0.0002030692426719948(L2) weight decay set for conv2d_14/kernel:0
# 0.0(L1), 0.0002030692426719948(L2) weight decay set for conv2d_16/kernel:0
# 0.0(L1), 0.0002030692426719948(L2) weight decay set for conv2d_17/kernel:0
# 0.0(L1), 0.0002030692426719948(L2) weight decay set for conv2d_15/kernel:0
# 0.0(L1), 0.0002030692426719948(L2) weight decay set for conv2d_18/kernel:0
# 0.0(L1), 0.0002030692426719948(L2) weight decay set for conv2d_19/kernel:0
# 0.0(L1), 0.0002030692426719948(L2) weight decay set for dense/kernel:0
# 97/97 [==============================] - ETA: 0s - loss: 3.6471 - accuracy: 0.1230 - top5_acc: 0.3718 - macro_f1score: 0.0044
# Epoch 00001: val_loss improved from inf to 8.20570, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/ResNet18/001.h5
#
# Epoch 00001: val_accuracy improved from -inf to 0.05078, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/ResNet18/001.h5
# 97/97 [==============================] - 6165s 64s/step - loss: 3.6471 - accuracy: 0.1230 - top5_acc: 0.3718 - macro_f1score: 0.0044 - val_loss: 8.2057 - val_accuracy: 0.0508 - val_top5_acc: 0.1862 - val_macro_f1score: 0.0069
# Learning rate:  0.001
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 2/70
# 97/97 [==============================] - ETA: 0s - loss: 3.1521 - accuracy: 0.1998 - top5_acc: 0.5037 - macro_f1score: 0.0184
# Epoch 00002: val_loss did not improve from 8.20570
#
# Epoch 00002: val_accuracy improved from 0.05078 to 0.05794, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/ResNet18/002.h5
# 97/97 [==============================] - 274s 3s/step - loss: 3.1521 - accuracy: 0.1998 - top5_acc: 0.5037 - macro_f1score: 0.0184 - val_loss: 9.2395 - val_accuracy: 0.0579 - val_top5_acc: 0.1582 - val_macro_f1score: 0.0118
# Learning rate:  0.001
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 3/70
# 97/97 [==============================] - ETA: 0s - loss: 2.8332 - accuracy: 0.2643 - top5_acc: 0.5893 - macro_f1score: 0.0447
# Epoch 00003: val_loss improved from 8.20570 to 5.20176, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/ResNet18/003.h5
#
# Epoch 00003: val_accuracy improved from 0.05794 to 0.10938, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/ResNet18/003.h5
# 97/97 [==============================] - 275s 3s/step - loss: 2.8332 - accuracy: 0.2643 - top5_acc: 0.5893 - macro_f1score: 0.0447 - val_loss: 5.2018 - val_accuracy: 0.1094 - val_top5_acc: 0.2962 - val_macro_f1score: 0.0238
# Learning rate:  0.001
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 4/70
# 97/97 [==============================] - ETA: 0s - loss: 2.5997 - accuracy: 0.3141 - top5_acc: 0.6452 - macro_f1score: 0.0775
# Epoch 00004: val_loss improved from 5.20176 to 3.77057, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/ResNet18/004.h5
#
# Epoch 00004: val_accuracy improved from 0.10938 to 0.15690, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/ResNet18/004.h5
# 97/97 [==============================] - 276s 3s/step - loss: 2.5997 - accuracy: 0.3141 - top5_acc: 0.6452 - macro_f1score: 0.0775 - val_loss: 3.7706 - val_accuracy: 0.1569 - val_top5_acc: 0.4180 - val_macro_f1score: 0.0538
# Learning rate:  0.001
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 5/70
# 97/97 [==============================] - ETA: 0s - loss: 2.3812 - accuracy: 0.3589 - top5_acc: 0.6964 - macro_f1score: 0.1140
# Epoch 00005: val_loss did not improve from 3.77057
#
# Epoch 00005: val_accuracy did not improve from 0.15690
# 97/97 [==============================] - 276s 3s/step - loss: 2.3812 - accuracy: 0.3589 - top5_acc: 0.6964 - macro_f1score: 0.1140 - val_loss: 3.7857 - val_accuracy: 0.1530 - val_top5_acc: 0.4336 - val_macro_f1score: 0.0599
# Learning rate:  0.001
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 6/70
# 97/97 [==============================] - ETA: 0s - loss: 2.2065 - accuracy: 0.4024 - top5_acc: 0.7352 - macro_f1score: 0.1509
# Epoch 00006: val_loss did not improve from 3.77057
#
# Epoch 00006: val_accuracy did not improve from 0.15690
# 97/97 [==============================] - 277s 3s/step - loss: 2.2065 - accuracy: 0.4024 - top5_acc: 0.7352 - macro_f1score: 0.1509 - val_loss: 4.5119 - val_accuracy: 0.1178 - val_top5_acc: 0.3822 - val_macro_f1score: 0.0394
# Learning rate:  0.001
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 7/70
# 97/97 [==============================] - ETA: 0s - loss: 2.0589 - accuracy: 0.4376 - top5_acc: 0.7663 - macro_f1score: 0.1829
# Epoch 00007: val_loss improved from 3.77057 to 2.71547, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/ResNet18/007.h5
#
# Epoch 00007: val_accuracy improved from 0.15690 to 0.32357, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/ResNet18/007.h5
# 97/97 [==============================] - 278s 3s/step - loss: 2.0589 - accuracy: 0.4376 - top5_acc: 0.7663 - macro_f1score: 0.1829 - val_loss: 2.7155 - val_accuracy: 0.3236 - val_top5_acc: 0.6348 - val_macro_f1score: 0.1354
# Learning rate:  0.001
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 8/70
# 97/97 [==============================] - ETA: 0s - loss: 1.9200 - accuracy: 0.4689 - top5_acc: 0.7964 - macro_f1score: 0.2040
# Epoch 00008: val_loss improved from 2.71547 to 2.60297, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/ResNet18/008.h5
#
# Epoch 00008: val_accuracy improved from 0.32357 to 0.35352, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/ResNet18/008.h5
# 97/97 [==============================] - 277s 3s/step - loss: 1.9200 - accuracy: 0.4689 - top5_acc: 0.7964 - macro_f1score: 0.2040 - val_loss: 2.6030 - val_accuracy: 0.3535 - val_top5_acc: 0.6576 - val_macro_f1score: 0.1504
# Learning rate:  0.001
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 9/70
# 97/97 [==============================] - ETA: 0s - loss: 1.7958 - accuracy: 0.5000 - top5_acc: 0.8142 - macro_f1score: 0.2413
# Epoch 00009: val_loss did not improve from 2.60297
#
# Epoch 00009: val_accuracy did not improve from 0.35352
# 97/97 [==============================] - 274s 3s/step - loss: 1.7958 - accuracy: 0.5000 - top5_acc: 0.8142 - macro_f1score: 0.2413 - val_loss: 2.6953 - val_accuracy: 0.3346 - val_top5_acc: 0.6641 - val_macro_f1score: 0.1612
# Learning rate:  0.001
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 10/70
# 97/97 [==============================] - ETA: 0s - loss: 1.7163 - accuracy: 0.5122 - top5_acc: 0.8287 - macro_f1score: 0.2519
# Epoch 00010: val_loss did not improve from 2.60297
#
# Epoch 00010: val_accuracy did not improve from 0.35352
# 97/97 [==============================] - 272s 3s/step - loss: 1.7163 - accuracy: 0.5122 - top5_acc: 0.8287 - macro_f1score: 0.2519 - val_loss: 3.9062 - val_accuracy: 0.1882 - val_top5_acc: 0.4811 - val_macro_f1score: 0.0804
# Learning rate:  0.001
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 11/70
# 97/97 [==============================] - ETA: 0s - loss: 1.6025 - accuracy: 0.5420 - top5_acc: 0.8548 - macro_f1score: 0.2802
# Epoch 00011: val_loss did not improve from 2.60297
#
# Epoch 00011: val_accuracy did not improve from 0.35352
# 97/97 [==============================] - 265s 3s/step - loss: 1.6025 - accuracy: 0.5420 - top5_acc: 0.8548 - macro_f1score: 0.2802 - val_loss: 3.2353 - val_accuracy: 0.2826 - val_top5_acc: 0.6061 - val_macro_f1score: 0.1274
# Learning rate:  0.001
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 12/70
# 97/97 [==============================] - ETA: 0s - loss: 1.5219 - accuracy: 0.5609 - top5_acc: 0.8662 - macro_f1score: 0.3029
# Epoch 00012: val_loss did not improve from 2.60297
#
# Epoch 00012: val_accuracy did not improve from 0.35352
# 97/97 [==============================] - 265s 3s/step - loss: 1.5219 - accuracy: 0.5609 - top5_acc: 0.8662 - macro_f1score: 0.3029 - val_loss: 3.1001 - val_accuracy: 0.3053 - val_top5_acc: 0.5951 - val_macro_f1score: 0.1415
# Learning rate:  0.001
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 13/70
# 97/97 [==============================] - ETA: 0s - loss: 1.4199 - accuracy: 0.5931 - top5_acc: 0.8778 - macro_f1score: 0.3255
# Epoch 00013: val_loss improved from 2.60297 to 2.21643, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/ResNet18/013.h5
#
# Epoch 00013: val_accuracy improved from 0.35352 to 0.41862, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/ResNet18/013.h5
# 97/97 [==============================] - 272s 3s/step - loss: 1.4199 - accuracy: 0.5931 - top5_acc: 0.8778 - macro_f1score: 0.3255 - val_loss: 2.2164 - val_accuracy: 0.4186 - val_top5_acc: 0.7396 - val_macro_f1score: 0.1917
# Learning rate:  0.001
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 14/70
# 97/97 [==============================] - ETA: 0s - loss: 1.3783 - accuracy: 0.6037 - top5_acc: 0.8864 - macro_f1score: 0.3424
# Epoch 00014: val_loss improved from 2.21643 to 2.10973, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/ResNet18/014.h5
#
# Epoch 00014: val_accuracy improved from 0.41862 to 0.47201, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/ResNet18/014.h5
# 97/97 [==============================] - 274s 3s/step - loss: 1.3783 - accuracy: 0.6037 - top5_acc: 0.8864 - macro_f1score: 0.3424 - val_loss: 2.1097 - val_accuracy: 0.4720 - val_top5_acc: 0.7780 - val_macro_f1score: 0.2495
# Learning rate:  0.001
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 15/70
# 97/97 [==============================] - ETA: 0s - loss: 1.2780 - accuracy: 0.6302 - top5_acc: 0.9023 - macro_f1score: 0.3647
# Epoch 00015: val_loss did not improve from 2.10973
#
# Epoch 00015: val_accuracy did not improve from 0.47201
# 97/97 [==============================] - 268s 3s/step - loss: 1.2780 - accuracy: 0.6302 - top5_acc: 0.9023 - macro_f1score: 0.3647 - val_loss: 2.6167 - val_accuracy: 0.3639 - val_top5_acc: 0.6842 - val_macro_f1score: 0.2125
# Learning rate:  0.001
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 16/70
# 97/97 [==============================] - ETA: 0s - loss: 1.2452 - accuracy: 0.6377 - top5_acc: 0.9070 - macro_f1score: 0.3752
# Epoch 00016: val_loss did not improve from 2.10973
#
# Epoch 00016: val_accuracy did not improve from 0.47201
# 97/97 [==============================] - 265s 3s/step - loss: 1.2452 - accuracy: 0.6377 - top5_acc: 0.9070 - macro_f1score: 0.3752 - val_loss: 2.7620 - val_accuracy: 0.3724 - val_top5_acc: 0.7103 - val_macro_f1score: 0.2078
# Learning rate:  0.001
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 17/70
# 97/97 [==============================] - ETA: 0s - loss: 1.1538 - accuracy: 0.6583 - top5_acc: 0.9194 - macro_f1score: 0.3935
# Epoch 00017: val_loss improved from 2.10973 to 1.97073, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/ResNet18/017.h5
#
# Epoch 00017: val_accuracy improved from 0.47201 to 0.48698, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/ResNet18/017.h5
# 97/97 [==============================] - 262s 3s/step - loss: 1.1538 - accuracy: 0.6583 - top5_acc: 0.9194 - macro_f1score: 0.3935 - val_loss: 1.9707 - val_accuracy: 0.4870 - val_top5_acc: 0.7949 - val_macro_f1score: 0.2811
# Learning rate:  0.001
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 18/70
# 97/97 [==============================] - ETA: 0s - loss: 1.0985 - accuracy: 0.6758 - top5_acc: 0.9315 - macro_f1score: 0.4145
# Epoch 00018: val_loss did not improve from 1.97073
#
# Epoch 00018: val_accuracy did not improve from 0.48698
# 97/97 [==============================] - 257s 3s/step - loss: 1.0985 - accuracy: 0.6758 - top5_acc: 0.9315 - macro_f1score: 0.4145 - val_loss: 2.6923 - val_accuracy: 0.3789 - val_top5_acc: 0.6940 - val_macro_f1score: 0.2224
# Learning rate:  0.001
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 19/70
# 97/97 [==============================] - ETA: 0s - loss: 1.0535 - accuracy: 0.6848 - top5_acc: 0.9326 - macro_f1score: 0.4277
# Epoch 00019: val_loss did not improve from 1.97073
#
# Epoch 00019: val_accuracy did not improve from 0.48698
# 97/97 [==============================] - 261s 3s/step - loss: 1.0535 - accuracy: 0.6848 - top5_acc: 0.9326 - macro_f1score: 0.4277 - val_loss: 2.5366 - val_accuracy: 0.3919 - val_top5_acc: 0.7285 - val_macro_f1score: 0.2251
# Learning rate:  0.001
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 20/70
# 97/97 [==============================] - ETA: 0s - loss: 0.9850 - accuracy: 0.7084 - top5_acc: 0.9420 - macro_f1score: 0.4509
# Epoch 00020: val_loss did not improve from 1.97073
#
# Epoch 00020: val_accuracy did not improve from 0.48698
# 97/97 [==============================] - 260s 3s/step - loss: 0.9850 - accuracy: 0.7084 - top5_acc: 0.9420 - macro_f1score: 0.4509 - val_loss: 2.3247 - val_accuracy: 0.4401 - val_top5_acc: 0.7637 - val_macro_f1score: 0.2631
# Learning rate:  0.001
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 21/70
# 97/97 [==============================] - ETA: 0s - loss: 0.9194 - accuracy: 0.7248 - top5_acc: 0.9472 - macro_f1score: 0.4615
# Epoch 00021: val_loss improved from 1.97073 to 1.81525, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/ResNet18/021.h5
#
# Epoch 00021: val_accuracy improved from 0.48698 to 0.51693, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/ResNet18/021.h5
# 97/97 [==============================] - 268s 3s/step - loss: 0.9194 - accuracy: 0.7248 - top5_acc: 0.9472 - macro_f1score: 0.4615 - val_loss: 1.8152 - val_accuracy: 0.5169 - val_top5_acc: 0.8223 - val_macro_f1score: 0.3048
# Learning rate:  0.001
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 22/70
# 97/97 [==============================] - ETA: 0s - loss: 0.8703 - accuracy: 0.7357 - top5_acc: 0.9546 - macro_f1score: 0.4742
# Epoch 00022: val_loss did not improve from 1.81525
#
# Epoch 00022: val_accuracy did not improve from 0.51693
# 97/97 [==============================] - 262s 3s/step - loss: 0.8703 - accuracy: 0.7357 - top5_acc: 0.9546 - macro_f1score: 0.4742 - val_loss: 2.6869 - val_accuracy: 0.3926 - val_top5_acc: 0.7214 - val_macro_f1score: 0.2210
# Learning rate:  0.001
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 23/70
# 97/97 [==============================] - ETA: 0s - loss: 0.8245 - accuracy: 0.7426 - top5_acc: 0.9584 - macro_f1score: 0.4879
# Epoch 00023: val_loss did not improve from 1.81525
#
# Epoch 00023: val_accuracy did not improve from 0.51693
# 97/97 [==============================] - 270s 3s/step - loss: 0.8245 - accuracy: 0.7426 - top5_acc: 0.9584 - macro_f1score: 0.4879 - val_loss: 2.5425 - val_accuracy: 0.4160 - val_top5_acc: 0.7246 - val_macro_f1score: 0.2372
# Learning rate:  0.001
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 24/70
# 97/97 [==============================] - ETA: 0s - loss: 0.7766 - accuracy: 0.7619 - top5_acc: 0.9640 - macro_f1score: 0.5055
# Epoch 00024: val_loss did not improve from 1.81525
#
# Epoch 00024: val_accuracy did not improve from 0.51693
# 97/97 [==============================] - 269s 3s/step - loss: 0.7766 - accuracy: 0.7619 - top5_acc: 0.9640 - macro_f1score: 0.5055 - val_loss: 2.2038 - val_accuracy: 0.4570 - val_top5_acc: 0.7669 - val_macro_f1score: 0.2448
# Learning rate:  0.001
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 25/70
# 97/97 [==============================] - ETA: 0s - loss: 0.7206 - accuracy: 0.7805 - top5_acc: 0.9685 - macro_f1score: 0.5203
# Epoch 00025: val_loss did not improve from 1.81525
#
# Epoch 00025: val_accuracy did not improve from 0.51693
# 97/97 [==============================] - 271s 3s/step - loss: 0.7206 - accuracy: 0.7805 - top5_acc: 0.9685 - macro_f1score: 0.5203 - val_loss: 2.2549 - val_accuracy: 0.4538 - val_top5_acc: 0.7682 - val_macro_f1score: 0.2608
# Learning rate:  0.001
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 26/70
# 97/97 [==============================] - ETA: 0s - loss: 0.6777 - accuracy: 0.7911 - top5_acc: 0.9729 - macro_f1score: 0.5428
# Epoch 00026: val_loss did not improve from 1.81525
#
# Epoch 00026: val_accuracy did not improve from 0.51693
# 97/97 [==============================] - 278s 3s/step - loss: 0.6777 - accuracy: 0.7911 - top5_acc: 0.9729 - macro_f1score: 0.5428 - val_loss: 2.3750 - val_accuracy: 0.4538 - val_top5_acc: 0.7552 - val_macro_f1score: 0.2846
# Learning rate:  0.001
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 27/70
# 97/97 [==============================] - ETA: 0s - loss: 0.6626 - accuracy: 0.7969 - top5_acc: 0.9737 - macro_f1score: 0.5457
# Epoch 00027: val_loss did not improve from 1.81525
#
# Epoch 00027: val_accuracy did not improve from 0.51693
# 97/97 [==============================] - 281s 3s/step - loss: 0.6626 - accuracy: 0.7969 - top5_acc: 0.9737 - macro_f1score: 0.5457 - val_loss: 2.2080 - val_accuracy: 0.4870 - val_top5_acc: 0.7871 - val_macro_f1score: 0.3127
# Learning rate:  0.001
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 28/70
# 97/97 [==============================] - ETA: 0s - loss: 0.5935 - accuracy: 0.8136 - top5_acc: 0.9815 - macro_f1score: 0.5611
# Epoch 00028: val_loss did not improve from 1.81525
#
# Epoch 00028: val_accuracy did not improve from 0.51693
# 97/97 [==============================] - 276s 3s/step - loss: 0.5935 - accuracy: 0.8136 - top5_acc: 0.9815 - macro_f1score: 0.5611 - val_loss: 2.1157 - val_accuracy: 0.4883 - val_top5_acc: 0.7956 - val_macro_f1score: 0.3026
# Learning rate:  0.001
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 29/70
# 97/97 [==============================] - ETA: 0s - loss: 0.5795 - accuracy: 0.8191 - top5_acc: 0.9813 - macro_f1score: 0.5651
# Epoch 00029: val_loss did not improve from 1.81525
#
# Epoch 00029: val_accuracy did not improve from 0.51693
# 97/97 [==============================] - 273s 3s/step - loss: 0.5795 - accuracy: 0.8191 - top5_acc: 0.9813 - macro_f1score: 0.5651 - val_loss: 2.1147 - val_accuracy: 0.5039 - val_top5_acc: 0.8060 - val_macro_f1score: 0.3073
# Learning rate:  0.001
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 30/70
# 97/97 [==============================] - ETA: 0s - loss: 0.5294 - accuracy: 0.8364 - top5_acc: 0.9861 - macro_f1score: 0.5887
# Epoch 00030: val_loss did not improve from 1.81525
#
# Epoch 00030: val_accuracy improved from 0.51693 to 0.52148, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/ResNet18/030.h5
# 97/97 [==============================] - 272s 3s/step - loss: 0.5294 - accuracy: 0.8364 - top5_acc: 0.9861 - macro_f1score: 0.5887 - val_loss: 2.0515 - val_accuracy: 0.5215 - val_top5_acc: 0.8262 - val_macro_f1score: 0.3229
# Learning rate:  0.0001
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 31/70
# 97/97 [==============================] - ETA: 0s - loss: 0.3104 - accuracy: 0.9167 - top5_acc: 0.9942 - macro_f1score: 0.6653
# Epoch 00031: val_loss improved from 1.81525 to 1.36593, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/ResNet18/031.h5
#
# Epoch 00031: val_accuracy improved from 0.52148 to 0.63932, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/ResNet18/031.h5
# 97/97 [==============================] - 268s 3s/step - loss: 0.3104 - accuracy: 0.9167 - top5_acc: 0.9942 - macro_f1score: 0.6653 - val_loss: 1.3659 - val_accuracy: 0.6393 - val_top5_acc: 0.8848 - val_macro_f1score: 0.4124
# Learning rate:  0.0001
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 32/70
# 97/97 [==============================] - ETA: 0s - loss: 0.2048 - accuracy: 0.9524 - top5_acc: 0.9982 - macro_f1score: 0.6986
# Epoch 00032: val_loss improved from 1.36593 to 1.34834, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/ResNet18/032.h5
#
# Epoch 00032: val_accuracy did not improve from 0.63932
# 97/97 [==============================] - 268s 3s/step - loss: 0.2048 - accuracy: 0.9524 - top5_acc: 0.9982 - macro_f1score: 0.6986 - val_loss: 1.3483 - val_accuracy: 0.6341 - val_top5_acc: 0.8932 - val_macro_f1score: 0.4119
# Learning rate:  0.0001
#
# Epoch 00033: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 33/70
# 97/97 [==============================] - ETA: 0s - loss: 0.1768 - accuracy: 0.9674 - top5_acc: 0.9988 - macro_f1score: 0.7129
# Epoch 00033: val_loss did not improve from 1.34834
#
# Epoch 00033: val_accuracy did not improve from 0.63932
# 97/97 [==============================] - 266s 3s/step - loss: 0.1768 - accuracy: 0.9674 - top5_acc: 0.9988 - macro_f1score: 0.7129 - val_loss: 1.3626 - val_accuracy: 0.6393 - val_top5_acc: 0.8893 - val_macro_f1score: 0.3997
# Learning rate:  0.0001
#
# Epoch 00034: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 34/70
# 97/97 [==============================] - ETA: 0s - loss: 0.1736 - accuracy: 0.9690 - top5_acc: 0.9981 - macro_f1score: 0.7121
# Epoch 00034: val_loss improved from 1.34834 to 1.33234, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/ResNet18/034.h5
#
# Epoch 00034: val_accuracy did not improve from 0.63932
# 97/97 [==============================] - 263s 3s/step - loss: 0.1736 - accuracy: 0.9690 - top5_acc: 0.9981 - macro_f1score: 0.7121 - val_loss: 1.3323 - val_accuracy: 0.6367 - val_top5_acc: 0.8945 - val_macro_f1score: 0.4148
# Learning rate:  0.0001
#
# Epoch 00035: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 35/70
# 97/97 [==============================] - ETA: 0s - loss: 0.1636 - accuracy: 0.9715 - top5_acc: 0.9991 - macro_f1score: 0.7156
# Epoch 00035: val_loss did not improve from 1.33234
#
# Epoch 00035: val_accuracy did not improve from 0.63932
# 97/97 [==============================] - 274s 3s/step - loss: 0.1636 - accuracy: 0.9715 - top5_acc: 0.9991 - macro_f1score: 0.7156 - val_loss: 1.3398 - val_accuracy: 0.6361 - val_top5_acc: 0.8939 - val_macro_f1score: 0.4120
# Learning rate:  0.0001
#
# Epoch 00036: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 36/70
# 97/97 [==============================] - ETA: 0s - loss: 0.1551 - accuracy: 0.9754 - top5_acc: 0.9993 - macro_f1score: 0.7202
# Epoch 00036: val_loss did not improve from 1.33234
#
# Epoch 00036: val_accuracy did not improve from 0.63932
# 97/97 [==============================] - 275s 3s/step - loss: 0.1551 - accuracy: 0.9754 - top5_acc: 0.9993 - macro_f1score: 0.7202 - val_loss: 1.3478 - val_accuracy: 0.6309 - val_top5_acc: 0.8887 - val_macro_f1score: 0.4041
# Learning rate:  0.0001
#
# Epoch 00037: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 37/70
# 97/97 [==============================] - ETA: 0s - loss: 0.1473 - accuracy: 0.9763 - top5_acc: 0.9998 - macro_f1score: 0.7202
# Epoch 00037: val_loss did not improve from 1.33234
#
# Epoch 00037: val_accuracy did not improve from 0.63932
# 97/97 [==============================] - 276s 3s/step - loss: 0.1473 - accuracy: 0.9763 - top5_acc: 0.9998 - macro_f1score: 0.7202 - val_loss: 1.3547 - val_accuracy: 0.6380 - val_top5_acc: 0.8874 - val_macro_f1score: 0.4130
# Learning rate:  0.0001
#
# Epoch 00038: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 38/70
# 97/97 [==============================] - ETA: 0s - loss: 0.1428 - accuracy: 0.9795 - top5_acc: 0.9995 - macro_f1score: 0.7260
# Epoch 00038: val_loss did not improve from 1.33234
#
# Epoch 00038: val_accuracy did not improve from 0.63932
# 97/97 [==============================] - 263s 3s/step - loss: 0.1428 - accuracy: 0.9795 - top5_acc: 0.9995 - macro_f1score: 0.7260 - val_loss: 1.3686 - val_accuracy: 0.6309 - val_top5_acc: 0.8854 - val_macro_f1score: 0.4048
# Learning rate:  0.0001
#
# Epoch 00039: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 39/70
# 97/97 [==============================] - ETA: 0s - loss: 0.1385 - accuracy: 0.9797 - top5_acc: 0.9996 - macro_f1score: 0.7259
# Epoch 00039: val_loss did not improve from 1.33234
#
# Epoch 00039: val_accuracy did not improve from 0.63932
# 97/97 [==============================] - 261s 3s/step - loss: 0.1385 - accuracy: 0.9797 - top5_acc: 0.9996 - macro_f1score: 0.7259 - val_loss: 1.3866 - val_accuracy: 0.6237 - val_top5_acc: 0.8815 - val_macro_f1score: 0.3874
# Learning rate:  0.0001
#
# Epoch 00040: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 40/70
# 97/97 [==============================] - ETA: 0s - loss: 0.1332 - accuracy: 0.9795 - top5_acc: 0.9997 - macro_f1score: 0.7331
# Epoch 00040: val_loss did not improve from 1.33234
#
# Epoch 00040: val_accuracy did not improve from 0.63932
# 97/97 [==============================] - 265s 3s/step - loss: 0.1332 - accuracy: 0.9795 - top5_acc: 0.9997 - macro_f1score: 0.7331 - val_loss: 1.3599 - val_accuracy: 0.6302 - val_top5_acc: 0.8822 - val_macro_f1score: 0.4061
# Learning rate:  0.0001
#
# Epoch 00041: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 41/70
# 97/97 [==============================] - ETA: 0s - loss: 0.1304 - accuracy: 0.9830 - top5_acc: 0.9997 - macro_f1score: 0.7303
# Epoch 00041: val_loss did not improve from 1.33234
#
# Epoch 00041: val_accuracy did not improve from 0.63932
# 97/97 [==============================] - 265s 3s/step - loss: 0.1304 - accuracy: 0.9830 - top5_acc: 0.9997 - macro_f1score: 0.7303 - val_loss: 1.3463 - val_accuracy: 0.6348 - val_top5_acc: 0.8880 - val_macro_f1score: 0.4073
# Learning rate:  0.0001
#
# Epoch 00042: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 42/70
# 97/97 [==============================] - ETA: 0s - loss: 0.1258 - accuracy: 0.9835 - top5_acc: 1.0000 - macro_f1score: 0.7232
# Epoch 00042: val_loss did not improve from 1.33234
#
# Epoch 00042: val_accuracy did not improve from 0.63932
# 97/97 [==============================] - 262s 3s/step - loss: 0.1258 - accuracy: 0.9835 - top5_acc: 1.0000 - macro_f1score: 0.7232 - val_loss: 1.3466 - val_accuracy: 0.6387 - val_top5_acc: 0.8887 - val_macro_f1score: 0.4051
# Learning rate:  0.0001
#
# Epoch 00043: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 43/70
# 97/97 [==============================] - ETA: 0s - loss: 0.1220 - accuracy: 0.9850 - top5_acc: 0.9998 - macro_f1score: 0.7341
# Epoch 00043: val_loss did not improve from 1.33234
#
# Epoch 00043: val_accuracy improved from 0.63932 to 0.63997, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/ResNet18/043.h5
# 97/97 [==============================] - 257s 3s/step - loss: 0.1220 - accuracy: 0.9850 - top5_acc: 0.9998 - macro_f1score: 0.7341 - val_loss: 1.3747 - val_accuracy: 0.6400 - val_top5_acc: 0.8828 - val_macro_f1score: 0.3975
# Learning rate:  0.0001
#
# Epoch 00044: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 44/70
# 97/97 [==============================] - ETA: 0s - loss: 0.1181 - accuracy: 0.9870 - top5_acc: 0.9998 - macro_f1score: 0.7469
# Epoch 00044: val_loss did not improve from 1.33234
#
# Epoch 00044: val_accuracy did not improve from 0.63997
# 97/97 [==============================] - 254s 3s/step - loss: 0.1181 - accuracy: 0.9870 - top5_acc: 0.9998 - macro_f1score: 0.7469 - val_loss: 1.3799 - val_accuracy: 0.6335 - val_top5_acc: 0.8815 - val_macro_f1score: 0.4062
# Learning rate:  0.0001
#
# Epoch 00045: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 45/70
# 97/97 [==============================] - ETA: 0s - loss: 0.1131 - accuracy: 0.9878 - top5_acc: 1.0000 - macro_f1score: 0.7375
# Epoch 00045: val_loss did not improve from 1.33234
#
# Epoch 00045: val_accuracy did not improve from 0.63997
# 97/97 [==============================] - 247s 3s/step - loss: 0.1131 - accuracy: 0.9878 - top5_acc: 1.0000 - macro_f1score: 0.7375 - val_loss: 1.3654 - val_accuracy: 0.6296 - val_top5_acc: 0.8887 - val_macro_f1score: 0.3960
# Learning rate:  0.0001
#
# Epoch 00046: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 46/70
# 97/97 [==============================] - ETA: 0s - loss: 0.1086 - accuracy: 0.9875 - top5_acc: 1.0000 - macro_f1score: 0.7358
# Epoch 00046: val_loss did not improve from 1.33234
#
# Epoch 00046: val_accuracy did not improve from 0.63997
# 97/97 [==============================] - 248s 3s/step - loss: 0.1086 - accuracy: 0.9875 - top5_acc: 1.0000 - macro_f1score: 0.7358 - val_loss: 1.3816 - val_accuracy: 0.6335 - val_top5_acc: 0.8861 - val_macro_f1score: 0.3947
# Learning rate:  0.0001
#
# Epoch 00047: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 47/70
# 97/97 [==============================] - ETA: 0s - loss: 0.1066 - accuracy: 0.9881 - top5_acc: 0.9999 - macro_f1score: 0.7330
# Epoch 00047: val_loss did not improve from 1.33234
#
# Epoch 00047: val_accuracy did not improve from 0.63997
# 97/97 [==============================] - 253s 3s/step - loss: 0.1066 - accuracy: 0.9881 - top5_acc: 0.9999 - macro_f1score: 0.7330 - val_loss: 1.3888 - val_accuracy: 0.6354 - val_top5_acc: 0.8880 - val_macro_f1score: 0.4123
# Learning rate:  0.0001
#
# Epoch 00048: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 48/70
# 97/97 [==============================] - ETA: 0s - loss: 0.1040 - accuracy: 0.9874 - top5_acc: 0.9999 - macro_f1score: 0.7415
# Epoch 00048: val_loss did not improve from 1.33234
#
# Epoch 00048: val_accuracy improved from 0.63997 to 0.64909, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/ResNet18/048.h5
# 97/97 [==============================] - 248s 3s/step - loss: 0.1040 - accuracy: 0.9874 - top5_acc: 0.9999 - macro_f1score: 0.7415 - val_loss: 1.3582 - val_accuracy: 0.6491 - val_top5_acc: 0.8835 - val_macro_f1score: 0.4164
# Learning rate:  0.0001
#
# Epoch 00049: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 49/70
# 97/97 [==============================] - ETA: 0s - loss: 0.0988 - accuracy: 0.9905 - top5_acc: 1.0000 - macro_f1score: 0.7431
# Epoch 00049: val_loss did not improve from 1.33234
#
# Epoch 00049: val_accuracy did not improve from 0.64909
# 97/97 [==============================] - 254s 3s/step - loss: 0.0988 - accuracy: 0.9905 - top5_acc: 1.0000 - macro_f1score: 0.7431 - val_loss: 1.3342 - val_accuracy: 0.6406 - val_top5_acc: 0.8867 - val_macro_f1score: 0.4166
# Learning rate:  0.0001
#
# Epoch 00050: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 50/70
# 97/97 [==============================] - ETA: 0s - loss: 0.0980 - accuracy: 0.9907 - top5_acc: 1.0000 - macro_f1score: 0.7398
# Epoch 00050: val_loss did not improve from 1.33234
#
# Epoch 00050: val_accuracy did not improve from 0.64909
# 97/97 [==============================] - 252s 3s/step - loss: 0.0980 - accuracy: 0.9907 - top5_acc: 1.0000 - macro_f1score: 0.7398 - val_loss: 1.4825 - val_accuracy: 0.6035 - val_top5_acc: 0.8763 - val_macro_f1score: 0.3773
# Learning rate:  0.0001
#
# Epoch 00051: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 51/70
# 97/97 [==============================] - ETA: 0s - loss: 0.0947 - accuracy: 0.9900 - top5_acc: 1.0000 - macro_f1score: 0.7439
# Epoch 00051: val_loss did not improve from 1.33234
#
# Epoch 00051: val_accuracy did not improve from 0.64909
# 97/97 [==============================] - 250s 3s/step - loss: 0.0947 - accuracy: 0.9900 - top5_acc: 1.0000 - macro_f1score: 0.7439 - val_loss: 1.3766 - val_accuracy: 0.6393 - val_top5_acc: 0.8815 - val_macro_f1score: 0.4128
# Learning rate:  0.0001
#
# Epoch 00052: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 52/70
# 97/97 [==============================] - ETA: 0s - loss: 0.0908 - accuracy: 0.9909 - top5_acc: 1.0000 - macro_f1score: 0.7320
# Epoch 00052: val_loss did not improve from 1.33234
#
# Epoch 00052: val_accuracy did not improve from 0.64909
# 97/97 [==============================] - 246s 3s/step - loss: 0.0908 - accuracy: 0.9909 - top5_acc: 1.0000 - macro_f1score: 0.7320 - val_loss: 1.3967 - val_accuracy: 0.6341 - val_top5_acc: 0.8893 - val_macro_f1score: 0.4067
# Learning rate:  0.0001
#
# Epoch 00053: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 53/70
# 97/97 [==============================] - ETA: 0s - loss: 0.0899 - accuracy: 0.9917 - top5_acc: 1.0000 - macro_f1score: 0.7463
# Epoch 00053: val_loss did not improve from 1.33234
#
# Epoch 00053: val_accuracy did not improve from 0.64909
# 97/97 [==============================] - 243s 3s/step - loss: 0.0899 - accuracy: 0.9917 - top5_acc: 1.0000 - macro_f1score: 0.7463 - val_loss: 1.4069 - val_accuracy: 0.6270 - val_top5_acc: 0.8802 - val_macro_f1score: 0.3898
# Learning rate:  0.0001
#
# Epoch 00054: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 54/70
# 97/97 [==============================] - ETA: 0s - loss: 0.0886 - accuracy: 0.9914 - top5_acc: 1.0000 - macro_f1score: 0.7405
# Epoch 00054: val_loss did not improve from 1.33234
#
# Epoch 00054: val_accuracy did not improve from 0.64909
# 97/97 [==============================] - 242s 2s/step - loss: 0.0886 - accuracy: 0.9914 - top5_acc: 1.0000 - macro_f1score: 0.7405 - val_loss: 1.4184 - val_accuracy: 0.6270 - val_top5_acc: 0.8809 - val_macro_f1score: 0.3957
# Learning rate:  0.0001
#
# Epoch 00055: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 55/70
# 97/97 [==============================] - ETA: 0s - loss: 0.0849 - accuracy: 0.9914 - top5_acc: 1.0000 - macro_f1score: 0.7329
# Epoch 00055: val_loss did not improve from 1.33234
#
# Epoch 00055: val_accuracy did not improve from 0.64909
# 97/97 [==============================] - 243s 3s/step - loss: 0.0849 - accuracy: 0.9914 - top5_acc: 1.0000 - macro_f1score: 0.7329 - val_loss: 1.3868 - val_accuracy: 0.6374 - val_top5_acc: 0.8867 - val_macro_f1score: 0.3964
# Learning rate:  0.0001
#
# Epoch 00056: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 56/70
# 97/97 [==============================] - ETA: 0s - loss: 0.0840 - accuracy: 0.9908 - top5_acc: 1.0000 - macro_f1score: 0.7463
# Epoch 00056: val_loss did not improve from 1.33234
#
# Epoch 00056: val_accuracy did not improve from 0.64909
# 97/97 [==============================] - 242s 2s/step - loss: 0.0840 - accuracy: 0.9908 - top5_acc: 1.0000 - macro_f1score: 0.7463 - val_loss: 1.4564 - val_accuracy: 0.6185 - val_top5_acc: 0.8815 - val_macro_f1score: 0.4013
# Learning rate:  0.0001
#
# Epoch 00057: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 57/70
# 97/97 [==============================] - ETA: 0s - loss: 0.0770 - accuracy: 0.9930 - top5_acc: 0.9999 - macro_f1score: 0.7441
# Epoch 00057: val_loss did not improve from 1.33234
#
# Epoch 00057: val_accuracy did not improve from 0.64909
# 97/97 [==============================] - 246s 3s/step - loss: 0.0770 - accuracy: 0.9930 - top5_acc: 0.9999 - macro_f1score: 0.7441 - val_loss: 1.3691 - val_accuracy: 0.6432 - val_top5_acc: 0.8906 - val_macro_f1score: 0.4011
# Learning rate:  0.0001
#
# Epoch 00058: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 58/70
# 97/97 [==============================] - ETA: 0s - loss: 0.0778 - accuracy: 0.9924 - top5_acc: 1.0000 - macro_f1score: 0.7519
# Epoch 00058: val_loss did not improve from 1.33234
#
# Epoch 00058: val_accuracy did not improve from 0.64909
# 97/97 [==============================] - 252s 3s/step - loss: 0.0778 - accuracy: 0.9924 - top5_acc: 1.0000 - macro_f1score: 0.7519 - val_loss: 1.4425 - val_accuracy: 0.6237 - val_top5_acc: 0.8809 - val_macro_f1score: 0.3818
# Learning rate:  0.0001
#
# Epoch 00059: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 59/70
# 97/97 [==============================] - ETA: 0s - loss: 0.0752 - accuracy: 0.9932 - top5_acc: 1.0000 - macro_f1score: 0.7460
# Epoch 00059: val_loss did not improve from 1.33234
#
# Epoch 00059: val_accuracy did not improve from 0.64909
# 97/97 [==============================] - 265s 3s/step - loss: 0.0752 - accuracy: 0.9932 - top5_acc: 1.0000 - macro_f1score: 0.7460 - val_loss: 1.4556 - val_accuracy: 0.6263 - val_top5_acc: 0.8717 - val_macro_f1score: 0.3924
# Learning rate:  0.0001
#
# Epoch 00060: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 60/70
# 97/97 [==============================] - ETA: 0s - loss: 0.0706 - accuracy: 0.9947 - top5_acc: 0.9999 - macro_f1score: 0.7428
# Epoch 00060: val_loss did not improve from 1.33234
#
# Epoch 00060: val_accuracy did not improve from 0.64909
# 97/97 [==============================] - 271s 3s/step - loss: 0.0706 - accuracy: 0.9947 - top5_acc: 0.9999 - macro_f1score: 0.7428 - val_loss: 1.4419 - val_accuracy: 0.6237 - val_top5_acc: 0.8776 - val_macro_f1score: 0.4060
# Learning rate:  1e-05
#
# Epoch 00061: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 61/70
# 97/97 [==============================] - ETA: 0s - loss: 0.0600 - accuracy: 0.9942 - top5_acc: 1.0000 - macro_f1score: 0.7507
# Epoch 00061: val_loss did not improve from 1.33234
#
# Epoch 00061: val_accuracy did not improve from 0.64909
# 97/97 [==============================] - 273s 3s/step - loss: 0.0600 - accuracy: 0.9942 - top5_acc: 1.0000 - macro_f1score: 0.7507 - val_loss: 1.3602 - val_accuracy: 0.6426 - val_top5_acc: 0.8887 - val_macro_f1score: 0.4173
# Learning rate:  1e-05
#
# Epoch 00062: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 62/70
# 97/97 [==============================] - ETA: 0s - loss: 0.0539 - accuracy: 0.9968 - top5_acc: 1.0000 - macro_f1score: 0.7526
# Epoch 00062: val_loss did not improve from 1.33234
#
# Epoch 00062: val_accuracy did not improve from 0.64909
# 97/97 [==============================] - 267s 3s/step - loss: 0.0539 - accuracy: 0.9968 - top5_acc: 1.0000 - macro_f1score: 0.7526 - val_loss: 1.3548 - val_accuracy: 0.6406 - val_top5_acc: 0.8848 - val_macro_f1score: 0.4172
# Learning rate:  1e-05
#
# Epoch 00063: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 63/70
# 97/97 [==============================] - ETA: 0s - loss: 0.0562 - accuracy: 0.9972 - top5_acc: 1.0000 - macro_f1score: 0.7509
# Epoch 00063: val_loss did not improve from 1.33234
#
# Epoch 00063: val_accuracy did not improve from 0.64909
# 97/97 [==============================] - 278s 3s/step - loss: 0.0562 - accuracy: 0.9972 - top5_acc: 1.0000 - macro_f1score: 0.7509 - val_loss: 1.3357 - val_accuracy: 0.6458 - val_top5_acc: 0.8906 - val_macro_f1score: 0.4104
# Learning rate:  1e-05
#
# Epoch 00064: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 64/70
# 97/97 [==============================] - ETA: 0s - loss: 0.0569 - accuracy: 0.9972 - top5_acc: 1.0000 - macro_f1score: 0.7540
# Epoch 00064: val_loss improved from 1.33234 to 1.31770, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/ResNet18/064.h5
#
# Epoch 00064: val_accuracy did not improve from 0.64909
# 97/97 [==============================] - 279s 3s/step - loss: 0.0569 - accuracy: 0.9972 - top5_acc: 1.0000 - macro_f1score: 0.7540 - val_loss: 1.3177 - val_accuracy: 0.6471 - val_top5_acc: 0.8913 - val_macro_f1score: 0.4195
# Learning rate:  1e-05
#
# Epoch 00065: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 65/70
# 97/97 [==============================] - ETA: 0s - loss: 0.0579 - accuracy: 0.9969 - top5_acc: 1.0000 - macro_f1score: 0.7555
# Epoch 00065: val_loss did not improve from 1.31770
#
# Epoch 00065: val_accuracy did not improve from 0.64909
# 97/97 [==============================] - 283s 3s/step - loss: 0.0579 - accuracy: 0.9969 - top5_acc: 1.0000 - macro_f1score: 0.7555 - val_loss: 1.3373 - val_accuracy: 0.6367 - val_top5_acc: 0.8887 - val_macro_f1score: 0.4144
# Learning rate:  1e-05
#
# Epoch 00066: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 66/70
# 97/97 [==============================] - ETA: 0s - loss: 0.0615 - accuracy: 0.9977 - top5_acc: 1.0000 - macro_f1score: 0.7455
# Epoch 00066: val_loss improved from 1.31770 to 1.30767, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/ResNet18/066.h5
#
# Epoch 00066: val_accuracy did not improve from 0.64909
# 97/97 [==============================] - 278s 3s/step - loss: 0.0615 - accuracy: 0.9977 - top5_acc: 1.0000 - macro_f1score: 0.7455 - val_loss: 1.3077 - val_accuracy: 0.6491 - val_top5_acc: 0.8919 - val_macro_f1score: 0.4202
# Learning rate:  1e-05
#
# Epoch 00067: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 67/70
# 97/97 [==============================] - ETA: 0s - loss: 0.0639 - accuracy: 0.9972 - top5_acc: 1.0000 - macro_f1score: 0.7540
# Epoch 00067: val_loss did not improve from 1.30767
#
# Epoch 00067: val_accuracy improved from 0.64909 to 0.65039, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/ResNet18/067.h5
# 97/97 [==============================] - 276s 3s/step - loss: 0.0639 - accuracy: 0.9972 - top5_acc: 1.0000 - macro_f1score: 0.7540 - val_loss: 1.3179 - val_accuracy: 0.6504 - val_top5_acc: 0.8874 - val_macro_f1score: 0.4098
# Learning rate:  1e-05
#
# Epoch 00068: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 68/70
# 97/97 [==============================] - ETA: 0s - loss: 0.0668 - accuracy: 0.9975 - top5_acc: 1.0000 - macro_f1score: 0.7493
# Epoch 00068: val_loss improved from 1.30767 to 1.29707, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/ResNet18/068.h5
#
# Epoch 00068: val_accuracy did not improve from 0.65039
# 97/97 [==============================] - 275s 3s/step - loss: 0.0668 - accuracy: 0.9975 - top5_acc: 1.0000 - macro_f1score: 0.7493 - val_loss: 1.2971 - val_accuracy: 0.6471 - val_top5_acc: 0.8906 - val_macro_f1score: 0.4193
# Learning rate:  1e-05
#
# Epoch 00069: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 69/70
# 97/97 [==============================] - ETA: 0s - loss: 0.0702 - accuracy: 0.9964 - top5_acc: 1.0000 - macro_f1score: 0.7519
# Epoch 00069: val_loss did not improve from 1.29707
#
# Epoch 00069: val_accuracy improved from 0.65039 to 0.65625, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/ResNet18/069.h5
# 97/97 [==============================] - 269s 3s/step - loss: 0.0702 - accuracy: 0.9964 - top5_acc: 1.0000 - macro_f1score: 0.7519 - val_loss: 1.2999 - val_accuracy: 0.6562 - val_top5_acc: 0.8887 - val_macro_f1score: 0.4104
# Learning rate:  1e-05
#
# Epoch 00070: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 70/70
# 97/97 [==============================] - ETA: 0s - loss: 0.0735 - accuracy: 0.9971 - top5_acc: 1.0000 - macro_f1score: 0.7444
# Epoch 00070: val_loss did not improve from 1.29707
#
# Epoch 00070: val_accuracy did not improve from 0.65625
# 97/97 [==============================] - 270s 3s/step - loss: 0.0735 - accuracy: 0.9971 - top5_acc: 1.0000 - macro_f1score: 0.7444 - val_loss: 1.3018 - val_accuracy: 0.6471 - val_top5_acc: 0.8913 - val_macro_f1score: 0.3980

# %% [markdown]
# ### 2) ResNet18 Evaluate

# %%
# 1. epoch=maximum
loss , acc, top5_acc, mf1 = model.evaluate(test_generator,steps=int(len(x_test)/batch_sizes))
print('[Test Loss: %.4f /  Test Top-1 Accuracy: %.4f / Test Top-5 Accuracy: %.4f / Test Macro f1: %.4f]\n' % (loss,acc,top5_acc,mf1))
# Out:
# 12/12 [==============================] - 699s 58s/step - loss: 1.3457 - accuracy: 0.6126 - top5_acc: 0.8893 - macro_f1score: 0.3922
# [Test Loss: 1.3457 /  Test Top-1 Accuracy: 0.6126 / Test Top-5 Accuracy: 0.8893 / Test Macro f1: 0.3922]

# %%
loss=history.history['loss']
val_loss=history.history['val_loss']
acc=history.history['accuracy']
val_acc=history.history['val_accuracy']
top5_acc=history.history['top5_acc']
val_top5_acc=history.history['val_top5_acc']
f1=history.history['macro_f1score']
val_f1=history.history['val_macro_f1score']
epochs=range(1,len(acc)+1)

data = np.array([epochs,loss,val_loss,acc,val_acc,top5_acc,val_top5_acc,f1,val_f1]).T

# %%
# data save
# epochs, loss, val_loss, acc, val_acc, top5_acc, val_top5_acc, f1, val_f1

np.savetxt(os.path.join(dir,'train_valid_output',number,model.name+'.txt'),data)

# %%
# data import
data = np.loadtxt(os.path.join(dir,'train_valid_output',number,'ResNet18.txt'))

# %%
epochs=data[:,0]
loss=data[:,1]
val_loss=data[:,2]
acc=data[:,3]
val_acc=data[:,4]
top5_acc=data[:,5]
val_top5_acc=data[:,6]

# %%
plt.plot(epochs[1:],acc[1:],'b',label='Training 1-Acc')
plt.plot(epochs[1:],val_acc[1:],'r',label='Validation 1-Acc')
plt.title('Training and Validation Top-1 Accuracy')
plt.legend()
plt.figure()

plt.plot(epochs[1:],top5_acc[1:],'b',label='Training 5-Acc')
plt.plot(epochs[1:],val_top5_acc[1:],'r',label='Validation 5-Acc')
plt.title('Training and Validation Top-5 Accuracy')
plt.legend()
plt.figure()

plt.plot(epochs[10:],loss[10:],'b',label='Training Loss')
plt.plot(epochs[10:],val_loss[10:],'r',label='Validation Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()

# %%
# 이 아래는 내가 인위적으로 살펴보고 싶은 epoch에 대해서 결과값 출력 / ResNet18

# %%
# 참고 : https://github.com/OverLordGoldDragon/keras-adamw

import sys
sys.path.append('/content/drive/My Drive/Colab Notebooks/Paper')
import utils
import optimizers_v2
from utils import get_weight_decays, fill_dict_in_order
from utils import reset_seeds, K_eval
from optimizers_v2 import AdamW, NadamW, SGDW

# %%
# top-5 accuracy 출력
import functools
top5_acc = functools.partial(ks.metrics.top_k_categorical_accuracy, k=5)
top5_acc.__name__ = 'top5_acc'

# %%
model=load_model(os.path.join(dir,'model_output',number,'ResNet18','069.h5'),custom_objects={"macro_f1score": macro_f1score,"top5_acc":top5_acc, "AdamW":AdamW})

# %%
# 2. epoch=?
loss , acc, top5_acc, mf1 = model.evaluate(test_generator,steps=int(len(x_test)/batch_sizes))
print('[Test Loss: %.4f /  Test Top-1 Accuracy: %.4f / Test Top-5 Accuracy: %.4f / Test Macro f1: %.4f]\n' % (loss,acc,top5_acc,mf1))
# Out:
# 12/12 [==============================] - 553s 46s/step - loss: 1.3533 - accuracy: 0.6133 - top5_acc: 0.8887 - macro_f1score: 0.3862
# [Test Loss: 1.3533 /  Test Top-1 Accuracy: 0.6133 / Test Top-5 Accuracy: 0.8887 / Test Macro f1: 0.3862]
