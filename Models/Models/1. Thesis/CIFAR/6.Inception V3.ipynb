# %%
# 참고 : https://sike6054.github.io/blog/paper/third-post/

# %% [markdown]
# # [Inception V2 & V3]

# %% [markdown]
# *KU LeeDongGyu*

# %% [markdown]
# ## Contents
# ---

# %% [markdown]
# 1. Data Preprocessing
# ```
# 1) Data Import
# 2) Data Augmentation
# ```
# 2. Support Functions & Almost Original Inception-V2,V3 (Especially V3)
# ```
# 1) Support Functions
# 2) Almost Original Inception-V2,V3 (Especially V3)
# 3) Inception-V3 Evaluate
# ```

# %% [markdown]
# ### Install Packages

# %% [markdown]
# ### Module

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/My Drive/Colab Notebooks/Paper
# Out:
# /content/drive/My Drive/Colab Notebooks/Paper

# %%
from f1score import macro_f1score,weighted_f1score
from smoothed_categorical_crossentropy import smoothed_categorical_crossentropy

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import cv2
import tensorflow as tf
from tensorflow import keras as ks
from tensorflow.keras import backend as K 
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, Input, Concatenate, ZeroPadding2D ,GlobalMaxPooling2D, Reshape , Lambda , Add, Multiply
from tensorflow.keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D, Activation, BatchNormalization, AveragePooling2D , ZeroPadding2D, SeparableConv2D , LeakyReLU
from tensorflow.keras.layers import add, concatenate, multiply
from tensorflow.keras.optimizers import Adam, RMSprop , SGD
from tensorflow.keras.callbacks import EarlyStopping , LearningRateScheduler, ModelCheckpoint, CSVLogger, Callback, ReduceLROnPlateau
from tensorflow.keras.regularizers import l1,l2,l1_l2
from tensorflow.keras.models import Model , load_model , Sequential
from tensorflow.keras.utils import plot_model , to_categorical, get_file
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
os.getcwd()
# Out:
# '/content/drive/My Drive/Colab Notebooks/Paper'

# %%
print(tf.__version__)
print(ks.__version__)
# Out:
# 2.3.0
# 2.4.0

# %%
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 13381649098756068419
# , name: "/device:XLA_CPU:0"
# device_type: "XLA_CPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 11708659230813868912
# physical_device_desc: "device: XLA_CPU device"
# , name: "/device:XLA_GPU:0"
# device_type: "XLA_GPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 16209200290572081750
# physical_device_desc: "device: XLA_GPU device"
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 15473775744
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 13352529416939519846
# physical_device_desc: "device: 0, name: Tesla V100-SXM2-16GB, pci bus id: 0000:00:04.0, compute capability: 7.0"
# ]

# %%
# !cat /proc/cpuinfo
# Out:
# processor	: 0
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 79
# model name	: Intel(R) Xeon(R) CPU @ 2.20GHz
# stepping	: 0
# microcode	: 0x1
# cpu MHz		: 2200.000
# cache size	: 56320 KB
# physical id	: 0
# siblings	: 4
# core id		: 0
# cpu cores	: 2
# apicid		: 0
# initial apicid	: 0
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm rdseed adx smap xsaveopt arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs taa
# bogomips	: 4400.00
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 46 bits physical, 48 bits virtual
# power management:
#
# processor	: 1
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 79
# model name	: Intel(R) Xeon(R) CPU @ 2.20GHz
# stepping	: 0
# microcode	: 0x1
# cpu MHz		: 2200.000
# cache size	: 56320 KB
# physical id	: 0
# siblings	: 4
# core id		: 1
# cpu cores	: 2
# apicid		: 2
# initial apicid	: 2
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm rdseed adx smap xsaveopt arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs taa
# bogomips	: 4400.00
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 46 bits physical, 48 bits virtual
# power management:
#
# processor	: 2
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 79
# model name	: Intel(R) Xeon(R) CPU @ 2.20GHz
# stepping	: 0
# microcode	: 0x1
# cpu MHz		: 2200.000
# cache size	: 56320 KB
# physical id	: 0
# siblings	: 4
# core id		: 0
# cpu cores	: 2
# apicid		: 1
# initial apicid	: 1
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm rdseed adx smap xsaveopt arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs taa
# bogomips	: 4400.00
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 46 bits physical, 48 bits virtual
# power management:
#
# processor	: 3
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 79
# model name	: Intel(R) Xeon(R) CPU @ 2.20GHz
# stepping	: 0
# microcode	: 0x1
# cpu MHz		: 2200.000
# cache size	: 56320 KB
# physical id	: 0
# siblings	: 4
# core id		: 1
# cpu cores	: 2
# apicid		: 3
# initial apicid	: 3
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm rdseed adx smap xsaveopt arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs taa
# bogomips	: 4400.00
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 46 bits physical, 48 bits virtual
# power management:

# %% [markdown]
# ## 1. Data Preprocessing
# ---

# %% [markdown]
# ### 1) Data Import

# %%
# 바꿔서 살펴 볼 것들
# CALTECH, CIFAR100, FER, MIT
data_name = 'CIFAR100'
gan_type = 'No_GAN'
number = '1'
size = 299 # sizes after cropping
super_size = 330 # sizes before cropping 
input_sizes = (size,size,3)
batch_sizes = 64
weight_decay = 2e-3
epochs = 70

# %%
# 참고 : https://stackoverflow.com/questions/32419510/how-to-get-reproducible-results-in-keras/52897216#52897216
# setting the seed number for random number generation for reproducibility.

from numpy.random import seed
import random


if number=='1':
    seed_num = 200225
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)
elif number=='2':
    seed_num = 727
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)
elif number=='3':
    seed_num = 115
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)
elif number=='4':
    seed_num = 501
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)
elif number=='5':
    seed_num = 517
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)

# %%
# data import

if data_name=='FER' :
    x_train =  np.zeros(28698)
    x_valid = np.zeros(3589)
    x_test = np.zeros(3588)
    classes = 7 
    tr_center = [0.50793296, 0.50793296, 0.50793296]
elif data_name=='MIT':
    x_train = np.zeros(12466)
    x_valid = np.zeros(1564)
    x_test = np.zeros(1590)
    classes = 67 
    tr_center = [0.47916578, 0.42029615, 0.36046057]
elif data_name=='CALTECH':
    x_train = np.zeros(24510)
    x_valid = np.zeros(2980)
    x_test = np.zeros(3118)
    classes = 257
    tr_center = [0.51397761, 0.49525248, 0.46555727]
elif data_name=='CIFAR100':
    x_train = np.zeros(44923)
    x_valid = np.zeros(5077)
    x_test = np.zeros(10000)
    classes = 100
    tr_center = [0.53442983, 0.51355958, 0.46462564]

# %%
dir = os.path.join(os.getcwd(),data_name,gan_type)

# %% [markdown]
# ### 2) Data Augmentation

# %%
# 참고 : https://jkjung-avt.github.io/keras-image-cropping/

def random_crop(img, random_crop_size):
    # Note: image_data_format is 'channel_last'
    assert img.shape[2] == 3 # img.shape[2] 가 3(rgb)이 아니면 assertion error 발생
    height, width = img.shape[0], img.shape[1]
    dy, dx = random_crop_size
    x = np.random.randint(0, width - dx + 1)
    y = np.random.randint(0, height - dy + 1)
    return img[y:(y+dy), x:(x+dx), :]


def crop_generator(batches, crop_length):
    """Take as input a Keras ImageGen (Iterator) and generate random
    crops from the image batches generated by the original iterator.
    """
    while True:
        batch_x, batch_y = next(batches)
        batch_crops = np.zeros((batch_x.shape[0], crop_length, crop_length, 3))
        for i in range(batch_x.shape[0]):
            batch_crops[i] = random_crop(batch_x[i], (crop_length, crop_length))
        yield (batch_crops, batch_y)

# %%
from tensorflow.keras.preprocessing.image import img_to_array,load_img
import glob

# 데이터 전체에 대해 centering 진행함.

def read_cal_image(img_path): 
    x = img_to_array(load_img(img_path)) # x는 채널별 평균값
    y = x.shape[0] * x.shape[1]# y는 데이터별 픽셀 수 (비중)

    x = 1/255. * x # scaling하고, centering값을 뽑아냄.
    x = np.mean(x, axis=(0,1))
    
    return np.hstack([x,y])

def calculate_centered_mean(dataset_path,x_train=x_train):
    num = len(x_train)
    space = np.empty((num,4))
    i=0

    for p in glob.glob(os.path.join(dataset_path,'*/*.*')) :
        space[i] = read_cal_image(p)
        i += 1

    ratio = space[:,3] / np.sum(space[:,3])

    return np.average(space[:,0:3],axis=0,weights=ratio)


# 아래의 함수를 돌려서 나온 결과값을 중심화 값으로 설정.

# train_mean = calculate_centered_mean(os.path.join(dir,'data/train')).reshape((1,1,3))

# %%
datagen_tr = ImageDataGenerator(
    rescale=1/255.,
    horizontal_flip=True,
    featurewise_center=True,
    featurewise_std_normalization=False,
    rotation_range=10,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=[0.9,1.0],
    fill_mode = 'nearest')
datagen_val = ImageDataGenerator(rescale=1/255.,featurewise_center=True)
datagen_tes = ImageDataGenerator(rescale=1/255.,featurewise_center=True)

# 원래는 이 자리에 fit 매서드를 써야하지만, 그냥 내가 중심화함수를 만들고 적용함. 

# 중심화 설정
datagen_tr.mean = np.array(tr_center, dtype=np.float32).reshape((1,1,3)) # RGB
datagen_val.mean = np.array(tr_center, dtype=np.float32).reshape((1,1,3)) # RGB
datagen_tes.mean = np.array(tr_center, dtype=np.float32).reshape((1,1,3)) # RGB

# %%
# Inception-V2 & V3은 분류기가 2개이므로 imagedatagenerator 사용방법이 다소 다르다.
# model.fit에 다중 input으로 들어갈 함수를 개인이 만들어서 사용해야 하며, 그 함수는 아래와 같다. 
# 매우 간단하다.

#1. train data

def generate_train_for_two(crop_length=size, batch_sizes = batch_sizes, super_size=super_size):

      batches = datagen_tr.flow_from_directory(directory=os.path.join(dir,'data/train'),target_size=(super_size,super_size),batch_size=batch_sizes,class_mode='categorical')

      while True:
          batch_x, batch_y = next(batches)
          batch_crops = np.zeros((batch_x.shape[0], crop_length, crop_length, 3))
          for i in range(batch_x.shape[0]):
              batch_crops[i] = random_crop(batch_x[i], (crop_length, crop_length))
          yield batch_crops, [batch_y,batch_y]

# %%
# 2. valid data

def generate_valid_for_two(size=size, batch_sizes = batch_sizes):

      batches_xy = datagen_val.flow_from_directory(directory=os.path.join(dir,'data/valid'),target_size=(size,size),batch_size=batch_sizes,class_mode='categorical')

      while True:

          batch_xy = batches_xy.next()
          yield  batch_xy[0], [ batch_xy[1],batch_xy[1] ]

# %%
# 3. test data

def generate_test_for_two(size=size, batch_sizes = batch_sizes):

      batches_xy = datagen_tes.flow_from_directory(directory=os.path.join(dir,'data/test'),target_size=(size,size),batch_size=batch_sizes,class_mode='categorical')

      while True:

          batch_xy = batches_xy.next()
          yield  batch_xy[0], [ batch_xy[1],batch_xy[1] ]

# %%
# 위에서 쓰임
# train_batches = datagen_tr.flow_from_directory(directory=os.path.join(dir,'data/train'),target_size=(super_size,super_size),batch_size=batch_sizes,class_mode='categorical') # fer : 28698 / mit : 12466 / caltech : 24509 / cifar : 44923
# train_generator= crop_generator(train_batches, size)

# valid_generator = datagen_val.flow_from_directory(directory=os.path.join(dir,'data/valid'),target_size=(size,size),batch_size=batch_sizes,class_mode='categorical') # fer : 3589 / mit : 1564 / caltech : 2980 / cifar : 5077
# test_generator = datagen_tes.flow_from_directory(directory=os.path.join(dir,'data/test'),target_size=(size,size),batch_size=batch_sizes,class_mode='categorical') # fer : 3588 / mit : 1590 / caltech : 3118 / cifar : 10000

# %% [markdown]
# ## 2. Support Functions & Almost Original Inception-V2,V3 (Especially V3)
# ---

# %% [markdown]
# ### 1) Support Functions

# %%
# def lr_schedule(epoch):
#     init_lr = 1e-4
#     k = 0.04
#     lr = init_lr * np.exp(-k*epoch)
#     print('Learning rate: ', lr)
#     return lr

def lr_schedule(epoch):
    lr = 1e-3
    if epoch < 30:
        lr = lr
    elif epoch < 60 :
        lr = lr * 0.1
    else:
        lr = lr * 0.01
    print('Learning rate: ', lr)
    return lr

# %%
def smoothed_categorical_crossentropy(y_true, y_pred): 
    if smoothing_param > 0:
        smooth_positives = 1.0 - smoothing_param 
        smooth_negatives = smoothing_param / classes 
        y_true = y_true * smooth_positives + smooth_negatives 

    return K.categorical_crossentropy(y_true, y_pred)

# %%
def conv2d_bn(x, filters, kernel_size, weight_decay=weight_decay, padding='same', strides=1, activation='relu'):
    x = Conv2D(filters, (kernel_size[0], kernel_size[1]), padding=padding, strides=strides, kernel_initializer='he_uniform', use_bias=False, kernel_regularizer=l2(weight_decay))(x)    
    x = BatchNormalization()(x)
    
    if activation:
        x = Activation(activation)(x)
    
    return x

# %%
def inception_f3(input_tensor, filter_channels, name=None):
    filter_b1, filter_b2, filter_b3, filter_b4 = filter_channels
    
    branch_1 = conv2d_bn(input_tensor, filter_b1[0], (1, 1))
    branch_1 = conv2d_bn(branch_1, filter_b1[1], (3, 3))
    branch_1 = conv2d_bn(branch_1, filter_b1[2], (3, 3))
    
    branch_2 = conv2d_bn(input_tensor, filter_b2[0], (1, 1))
    branch_2 = conv2d_bn(branch_2, filter_b2[1], (3, 3))
    
    branch_3 = MaxPooling2D((3, 3), strides=1, padding='same')(input_tensor)
    branch_3 = conv2d_bn(branch_3, filter_b3, (1, 1))
    
    branch_4 = conv2d_bn(input_tensor, filter_b4, (1, 1))
    
    filter_concat = Concatenate(name=name)([branch_1, branch_2, branch_3, branch_4]) if not name==None else Concatenate()([branch_1, branch_2, branch_3, branch_4])
    
    return filter_concat

def inception_f6(input_tensor, filter_channels, n=7, name=None):
    filter_b1, filter_b2, filter_b3, filter_b4 = filter_channels
    
    branch_1 = conv2d_bn(input_tensor, filter_b1[0], (1, 1))
    branch_1 = conv2d_bn(branch_1, filter_b1[1], (1, n))
    branch_1 = conv2d_bn(branch_1, filter_b1[2], (n, 1))
    branch_1 = conv2d_bn(branch_1, filter_b1[3], (1, n))
    branch_1 = conv2d_bn(branch_1, filter_b1[4], (n, 1))
    
    branch_2 = conv2d_bn(input_tensor, filter_b2[0], (1, 1))
    branch_2 = conv2d_bn(branch_2, filter_b2[1], (1, n))
    branch_2 = conv2d_bn(branch_2, filter_b2[2], (n, 1))
    
    branch_3 = MaxPooling2D((3, 3), strides=1, padding='same')(input_tensor)
    branch_3 = conv2d_bn(branch_3, filter_b3, (1, 1))
    
    branch_4 = conv2d_bn(input_tensor, filter_b4, (1, 1))
    
    filter_concat = Concatenate(name=name)([branch_1, branch_2, branch_3, branch_4]) if not name==None else Concatenate()([branch_1, branch_2, branch_3, branch_4])
    
    return filter_concat

def inception_f10(input_tensor, filter_channels, name=None):
    filter_b1, filter_b2, filter_b3, filter_b4 = filter_channels
    
    branch_1 = conv2d_bn(input_tensor, filter_b1[0], (1, 1))
    branch_1 = conv2d_bn(branch_1, filter_b1[1], (3, 3))
    branch_1a = conv2d_bn(branch_1, filter_b1[2][0], (1, 3))
    branch_1b = conv2d_bn(branch_1, filter_b1[2][1], (3, 1))
    branch_1 = Concatenate()([branch_1a, branch_1b])
    
    branch_2 = conv2d_bn(input_tensor, filter_b2[0], (1, 1))
    branch_2a = conv2d_bn(branch_2, filter_b2[1][0], (1, 3))
    branch_2b = conv2d_bn(branch_2, filter_b2[1][1], (3, 1))
    branch_2 = Concatenate()([branch_2a, branch_2b])
    
    branch_3 = MaxPooling2D((3, 3), strides=1, padding='same')(input_tensor)
    branch_3 = conv2d_bn(branch_3, filter_b3, (1, 1))
    
    branch_4 = conv2d_bn(input_tensor, filter_b4, (1, 1))
    
    filter_concat = Concatenate(name=name)([branch_1, branch_2, branch_3, branch_4]) if not name==None else Concatenate()([branch_1, branch_2, branch_3, branch_4])
    
    return filter_concat
    
def inception_dim_reduction(input_tensor, filter_channels, name=None):
    filter_b1, filter_b2 = filter_channels
    
    branch_1 = conv2d_bn(input_tensor, filter_b1[0], (1, 1))
    branch_1 = conv2d_bn(branch_1, filter_b1[1], (3, 3))
    branch_1 = conv2d_bn(branch_1, filter_b1[2], (3, 3), strides=2)
    
    branch_2 = conv2d_bn(input_tensor, filter_b2[0], (1, 1))
    branch_2 = conv2d_bn(branch_2, filter_b2[1], (3, 3), strides=2)
    
    branch_3 = MaxPooling2D((3, 3), strides=2, padding='same')(input_tensor)
    
    filter_concat = Concatenate(name=name)([branch_1, branch_2, branch_3]) if not name==None else Concatenate()([branch_1, branch_2, branch_3])
    
    return filter_concat

# %% [markdown]
# ### 2) Almost Original Inception-V2,V3 (Especially V3)

# %%
def Inception_v3(model_input, name, weight_decay= weight_decay):
    x = conv2d_bn(model_input, 32, (3, 3), padding='valid', strides=2) # (299, 299, 3) -> (149, 149, 32)
    x = conv2d_bn(x, 32, (3, 3), padding='valid') # (147, 147, 32) -> (147, 147, 32)
    x = conv2d_bn(x, 64, (3, 3), padding='same') # (147, 147, 32) -> (147, 147, 64)
    
    x = MaxPooling2D((3, 3), strides=2, padding='valid')(x) # (147, 147, 64) -> (73, 73, 64)
    
    x = conv2d_bn(x, 80, (3, 3), padding='valid') # (73, 73, 64) -> (71, 71, 80)
    x = conv2d_bn(x, 192, (3, 3), padding='valid', strides=2) # (71, 71, 80) -> (35, 35, 192)
    x = conv2d_bn(x, 288, (3, 3), padding='same') # (35, 35, 192) -> (35, 35, 288)
    
    x = inception_f3(x, [[64, 96, 96], [48, 64], 64 , 64]) # (35, 35, 288)
    x = inception_f3(x, [[64, 96, 96], [48, 64], 64 , 64]) # (35, 35, 288)
    x = inception_f3(x, [[64, 96, 96], [48, 64], 64 , 64], name='block_inception_f3') # (35, 35, 288)
    
    x = inception_dim_reduction(x, [[64, 96, 96], [256, 384]], name='block_reduction_1') # (35, 35, 288) -> (17, 17, 768)
    
    x = inception_f6(x, [[128, 128, 128, 128, 192], [128, 128, 192], 192, 192]) # (17, 17, 768)
    x = inception_f6(x, [[160, 160, 160, 160, 192], [160, 160, 192], 192, 192]) # (17, 17, 768)
    x = inception_f6(x, [[160, 160, 160, 160, 192], [160, 160, 192], 192, 192]) # (17, 17, 768)
    x = inception_f6(x, [[192, 192, 192, 192, 192], [192, 192, 192], 192, 192]) # (17, 17, 768)
    x_a = inception_f6(x, [[192, 192, 192, 192, 192], [192, 192, 192], 192, 192], name='block_inception_f6') # (17, 17, 768)
    
    x = inception_dim_reduction(x_a, [[128, 192, 192], [192, 320]], name='block_reduction_2') # (17, 17, 768) -> (8, 8, 1280)
    
    x = inception_f10(x, [[448, 384, [384, 384]], [384, [384, 384]], 192, 320]) # (8, 8, 1280) -> (8, 8, 2048)
    x = inception_f10(x, [[448, 384, [384, 384]], [384, [384, 384]], 192, 320], name='block_inception_f10') # (8, 8, 2048)
    
    x = GlobalAveragePooling2D()(x)
    x = Dropout(0.2)(x)
    
    x = Dense(classes, use_bias=False, kernel_regularizer=l2(weight_decay), activation=None)(x)
    
    model_output = Dense(classes, activation='softmax', name='main_classifier')(x) # 'softmax'
    
    # Auxiliary Classifier
    auxiliary = AveragePooling2D((5, 5), strides=3, padding='valid')(x_a) # (17, 17, 768) -> (5, 5, 768)
    auxiliary = conv2d_bn(auxiliary, 128, (1, 1)) # (5, 5, 768) -> (5, 5, 128)
    
    auxiliary = conv2d_bn(auxiliary, 1024, K.int_shape(auxiliary)[1:3], padding='valid') # (5, 5, 768) -> (1, 1, 1024)
    auxiliary = Flatten()(auxiliary) # (1, 1, 1024)
    auxiliary_output = Dense(classes, use_bias=False, kernel_regularizer=l2(weight_decay), activation='softmax', name='auxiliary_classifier')(auxiliary)
    
    model = Model(model_input, [model_output, auxiliary_output],name=name)
    
    return model

# %%
smoothing_param = 0.1
model_input = Input(shape=input_sizes)
model = Inception_v3(model_input, weight_decay = weight_decay, name = "Inception_v3")

# %%
model.summary()
# Out:
# Model: "Inception_v3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 299, 299, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 149, 149, 32) 864         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 149, 149, 32) 128         conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 149, 149, 32) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 147, 147, 32) 9216        activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 147, 147, 32) 128         conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 147, 147, 32) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 147, 147, 64) 18432       activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 147, 147, 64) 256         conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 147, 147, 64) 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 73, 73, 64)   0           activation_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 71, 71, 80)   46080       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 71, 71, 80)   320         conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 71, 71, 80)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 35, 35, 192)  138240      activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 35, 35, 192)  768         conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 35, 35, 192)  0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 35, 35, 288)  497664      activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 35, 35, 288)  1152        conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 35, 35, 288)  0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 35, 35, 64)   18432       activation_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 35, 35, 64)   256         conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 35, 35, 64)   0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 35, 35, 96)   55296       activation_6[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 35, 35, 48)   13824       activation_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 35, 35, 96)   384         conv2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 35, 35, 48)   192         conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 35, 35, 96)   0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 35, 35, 48)   0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 35, 35, 288)  0           activation_5[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 35, 35, 96)   82944       activation_7[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 35, 35, 64)   27648       activation_9[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 35, 35, 64)   18432       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 35, 35, 64)   18432       activation_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 35, 35, 96)   384         conv2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 35, 35, 64)   256         conv2d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 35, 35, 64)   256         conv2d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 35, 35, 64)   256         conv2d_12[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 35, 35, 96)   0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 35, 35, 64)   0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 35, 35, 64)   0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 35, 35, 64)   0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 35, 35, 288)  0           activation_8[0][0]
#                                                                  activation_10[0][0]
#                                                                  activation_11[0][0]
#                                                                  activation_12[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 35, 35, 64)   18432       concatenate[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 35, 35, 64)   256         conv2d_13[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 35, 35, 64)   0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 35, 35, 96)   55296       activation_13[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 35, 35, 48)   13824       concatenate[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 35, 35, 96)   384         conv2d_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 35, 35, 48)   192         conv2d_16[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 35, 35, 96)   0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 35, 35, 48)   0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 35, 35, 288)  0           concatenate[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 35, 35, 96)   82944       activation_14[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 35, 35, 64)   27648       activation_16[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 35, 35, 64)   18432       max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 35, 35, 64)   18432       concatenate[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 35, 35, 96)   384         conv2d_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 35, 35, 64)   256         conv2d_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 35, 35, 64)   256         conv2d_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 35, 35, 64)   256         conv2d_19[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 35, 35, 96)   0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 35, 35, 64)   0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 35, 35, 64)   0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 35, 35, 64)   0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 35, 35, 288)  0           activation_15[0][0]
#                                                                  activation_17[0][0]
#                                                                  activation_18[0][0]
#                                                                  activation_19[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 35, 35, 64)   18432       concatenate_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 35, 35, 64)   256         conv2d_20[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 35, 35, 64)   0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 35, 35, 96)   55296       activation_20[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 35, 35, 48)   13824       concatenate_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 35, 35, 96)   384         conv2d_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 35, 35, 48)   192         conv2d_23[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 35, 35, 96)   0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 35, 35, 48)   0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 35, 35, 288)  0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 35, 35, 96)   82944       activation_21[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 35, 35, 64)   27648       activation_23[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 35, 35, 64)   18432       max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 35, 35, 64)   18432       concatenate_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 35, 35, 96)   384         conv2d_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 35, 35, 64)   256         conv2d_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 35, 35, 64)   256         conv2d_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 35, 35, 64)   256         conv2d_26[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 35, 35, 96)   0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 35, 35, 64)   0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 35, 35, 64)   0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 35, 35, 64)   0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# block_inception_f3 (Concatenate (None, 35, 35, 288)  0           activation_22[0][0]
#                                                                  activation_24[0][0]
#                                                                  activation_25[0][0]
#                                                                  activation_26[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 35, 35, 64)   18432       block_inception_f3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 35, 35, 64)   256         conv2d_27[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 35, 35, 64)   0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 35, 35, 96)   55296       activation_27[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 35, 35, 256)  73728       block_inception_f3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 35, 35, 96)   384         conv2d_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 35, 35, 256)  1024        conv2d_30[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 35, 35, 96)   0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 35, 35, 256)  0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 18, 18, 96)   82944       activation_28[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 18, 18, 384)  884736      activation_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 18, 18, 96)   384         conv2d_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 18, 18, 384)  1536        conv2d_31[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 18, 18, 96)   0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 18, 18, 384)  0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 18, 18, 288)  0           block_inception_f3[0][0]
# __________________________________________________________________________________________________
# block_reduction_1 (Concatenate) (None, 18, 18, 768)  0           activation_29[0][0]
#                                                                  activation_31[0][0]
#                                                                  max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 18, 18, 128)  98304       block_reduction_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 18, 18, 128)  512         conv2d_32[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 18, 18, 128)  0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 18, 18, 128)  114688      activation_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 18, 18, 128)  512         conv2d_33[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 18, 18, 128)  0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 18, 18, 128)  114688      activation_33[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 18, 18, 128)  98304       block_reduction_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 18, 18, 128)  512         conv2d_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 18, 18, 128)  512         conv2d_37[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 18, 18, 128)  0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 18, 18, 128)  0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 18, 18, 128)  114688      activation_34[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 18, 18, 128)  114688      activation_37[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 18, 18, 128)  512         conv2d_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 18, 18, 128)  512         conv2d_38[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 18, 18, 128)  0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 18, 18, 128)  0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 18, 18, 768)  0           block_reduction_1[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 18, 18, 192)  172032      activation_35[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 18, 18, 192)  172032      activation_38[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 18, 18, 192)  147456      max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 18, 18, 192)  147456      block_reduction_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 18, 18, 192)  768         conv2d_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 18, 18, 192)  768         conv2d_39[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 18, 18, 192)  768         conv2d_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 18, 18, 192)  768         conv2d_41[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 18, 18, 192)  0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 18, 18, 192)  0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 18, 18, 192)  0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 18, 18, 192)  0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 18, 18, 768)  0           activation_36[0][0]
#                                                                  activation_39[0][0]
#                                                                  activation_40[0][0]
#                                                                  activation_41[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 18, 18, 160)  122880      concatenate_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 18, 18, 160)  640         conv2d_42[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 18, 18, 160)  0           batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 18, 18, 160)  179200      activation_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 18, 18, 160)  640         conv2d_43[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 18, 18, 160)  0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 18, 18, 160)  179200      activation_43[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 18, 18, 160)  122880      concatenate_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 18, 18, 160)  640         conv2d_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 18, 18, 160)  640         conv2d_47[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 18, 18, 160)  0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 18, 18, 160)  0           batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 18, 18, 160)  179200      activation_44[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 18, 18, 160)  179200      activation_47[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 18, 18, 160)  640         conv2d_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 18, 18, 160)  640         conv2d_48[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 18, 18, 160)  0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 18, 18, 160)  0           batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)  (None, 18, 18, 768)  0           concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 18, 18, 192)  215040      activation_45[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 18, 18, 192)  215040      activation_48[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 18, 18, 192)  147456      max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 18, 18, 192)  147456      concatenate_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 18, 18, 192)  768         conv2d_46[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 18, 18, 192)  768         conv2d_49[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 18, 18, 192)  768         conv2d_50[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 18, 18, 192)  768         conv2d_51[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 18, 18, 192)  0           batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 18, 18, 192)  0           batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, 18, 18, 192)  0           batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# activation_51 (Activation)      (None, 18, 18, 192)  0           batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 18, 18, 768)  0           activation_46[0][0]
#                                                                  activation_49[0][0]
#                                                                  activation_50[0][0]
#                                                                  activation_51[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 18, 18, 160)  122880      concatenate_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 18, 18, 160)  640         conv2d_52[0][0]
# __________________________________________________________________________________________________
# activation_52 (Activation)      (None, 18, 18, 160)  0           batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 18, 18, 160)  179200      activation_52[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, 18, 18, 160)  640         conv2d_53[0][0]
# __________________________________________________________________________________________________
# activation_53 (Activation)      (None, 18, 18, 160)  0           batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 18, 18, 160)  179200      activation_53[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 18, 18, 160)  122880      concatenate_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, 18, 18, 160)  640         conv2d_54[0][0]
# __________________________________________________________________________________________________
# batch_normalization_57 (BatchNo (None, 18, 18, 160)  640         conv2d_57[0][0]
# __________________________________________________________________________________________________
# activation_54 (Activation)      (None, 18, 18, 160)  0           batch_normalization_54[0][0]
# __________________________________________________________________________________________________
# activation_57 (Activation)      (None, 18, 18, 160)  0           batch_normalization_57[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 18, 18, 160)  179200      activation_54[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, 18, 18, 160)  179200      activation_57[0][0]
# __________________________________________________________________________________________________
# batch_normalization_55 (BatchNo (None, 18, 18, 160)  640         conv2d_55[0][0]
# __________________________________________________________________________________________________
# batch_normalization_58 (BatchNo (None, 18, 18, 160)  640         conv2d_58[0][0]
# __________________________________________________________________________________________________
# activation_55 (Activation)      (None, 18, 18, 160)  0           batch_normalization_55[0][0]
# __________________________________________________________________________________________________
# activation_58 (Activation)      (None, 18, 18, 160)  0           batch_normalization_58[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_7 (MaxPooling2D)  (None, 18, 18, 768)  0           concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 18, 18, 192)  215040      activation_55[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, 18, 18, 192)  215040      activation_58[0][0]
# __________________________________________________________________________________________________
# conv2d_60 (Conv2D)              (None, 18, 18, 192)  147456      max_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_61 (Conv2D)              (None, 18, 18, 192)  147456      concatenate_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_56 (BatchNo (None, 18, 18, 192)  768         conv2d_56[0][0]
# __________________________________________________________________________________________________
# batch_normalization_59 (BatchNo (None, 18, 18, 192)  768         conv2d_59[0][0]
# __________________________________________________________________________________________________
# batch_normalization_60 (BatchNo (None, 18, 18, 192)  768         conv2d_60[0][0]
# __________________________________________________________________________________________________
# batch_normalization_61 (BatchNo (None, 18, 18, 192)  768         conv2d_61[0][0]
# __________________________________________________________________________________________________
# activation_56 (Activation)      (None, 18, 18, 192)  0           batch_normalization_56[0][0]
# __________________________________________________________________________________________________
# activation_59 (Activation)      (None, 18, 18, 192)  0           batch_normalization_59[0][0]
# __________________________________________________________________________________________________
# activation_60 (Activation)      (None, 18, 18, 192)  0           batch_normalization_60[0][0]
# __________________________________________________________________________________________________
# activation_61 (Activation)      (None, 18, 18, 192)  0           batch_normalization_61[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 18, 18, 768)  0           activation_56[0][0]
#                                                                  activation_59[0][0]
#                                                                  activation_60[0][0]
#                                                                  activation_61[0][0]
# __________________________________________________________________________________________________
# conv2d_62 (Conv2D)              (None, 18, 18, 192)  147456      concatenate_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_62 (BatchNo (None, 18, 18, 192)  768         conv2d_62[0][0]
# __________________________________________________________________________________________________
# activation_62 (Activation)      (None, 18, 18, 192)  0           batch_normalization_62[0][0]
# __________________________________________________________________________________________________
# conv2d_63 (Conv2D)              (None, 18, 18, 192)  258048      activation_62[0][0]
# __________________________________________________________________________________________________
# batch_normalization_63 (BatchNo (None, 18, 18, 192)  768         conv2d_63[0][0]
# __________________________________________________________________________________________________
# activation_63 (Activation)      (None, 18, 18, 192)  0           batch_normalization_63[0][0]
# __________________________________________________________________________________________________
# conv2d_64 (Conv2D)              (None, 18, 18, 192)  258048      activation_63[0][0]
# __________________________________________________________________________________________________
# conv2d_67 (Conv2D)              (None, 18, 18, 192)  147456      concatenate_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_64 (BatchNo (None, 18, 18, 192)  768         conv2d_64[0][0]
# __________________________________________________________________________________________________
# batch_normalization_67 (BatchNo (None, 18, 18, 192)  768         conv2d_67[0][0]
# __________________________________________________________________________________________________
# activation_64 (Activation)      (None, 18, 18, 192)  0           batch_normalization_64[0][0]
# __________________________________________________________________________________________________
# activation_67 (Activation)      (None, 18, 18, 192)  0           batch_normalization_67[0][0]
# __________________________________________________________________________________________________
# conv2d_65 (Conv2D)              (None, 18, 18, 192)  258048      activation_64[0][0]
# __________________________________________________________________________________________________
# conv2d_68 (Conv2D)              (None, 18, 18, 192)  258048      activation_67[0][0]
# __________________________________________________________________________________________________
# batch_normalization_65 (BatchNo (None, 18, 18, 192)  768         conv2d_65[0][0]
# __________________________________________________________________________________________________
# batch_normalization_68 (BatchNo (None, 18, 18, 192)  768         conv2d_68[0][0]
# __________________________________________________________________________________________________
# activation_65 (Activation)      (None, 18, 18, 192)  0           batch_normalization_65[0][0]
# __________________________________________________________________________________________________
# activation_68 (Activation)      (None, 18, 18, 192)  0           batch_normalization_68[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_8 (MaxPooling2D)  (None, 18, 18, 768)  0           concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv2d_66 (Conv2D)              (None, 18, 18, 192)  258048      activation_65[0][0]
# __________________________________________________________________________________________________
# conv2d_69 (Conv2D)              (None, 18, 18, 192)  258048      activation_68[0][0]
# __________________________________________________________________________________________________
# conv2d_70 (Conv2D)              (None, 18, 18, 192)  147456      max_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_71 (Conv2D)              (None, 18, 18, 192)  147456      concatenate_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_66 (BatchNo (None, 18, 18, 192)  768         conv2d_66[0][0]
# __________________________________________________________________________________________________
# batch_normalization_69 (BatchNo (None, 18, 18, 192)  768         conv2d_69[0][0]
# __________________________________________________________________________________________________
# batch_normalization_70 (BatchNo (None, 18, 18, 192)  768         conv2d_70[0][0]
# __________________________________________________________________________________________________
# batch_normalization_71 (BatchNo (None, 18, 18, 192)  768         conv2d_71[0][0]
# __________________________________________________________________________________________________
# activation_66 (Activation)      (None, 18, 18, 192)  0           batch_normalization_66[0][0]
# __________________________________________________________________________________________________
# activation_69 (Activation)      (None, 18, 18, 192)  0           batch_normalization_69[0][0]
# ...
# __________________________________________________________________________________________________
# batch_normalization_87 (BatchNo (None, 9, 9, 448)    1792        conv2d_87[0][0]
# __________________________________________________________________________________________________
# activation_87 (Activation)      (None, 9, 9, 448)    0           batch_normalization_87[0][0]
# __________________________________________________________________________________________________
# conv2d_88 (Conv2D)              (None, 9, 9, 384)    1548288     activation_87[0][0]
# __________________________________________________________________________________________________
# conv2d_91 (Conv2D)              (None, 9, 9, 384)    491520      block_reduction_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_88 (BatchNo (None, 9, 9, 384)    1536        conv2d_88[0][0]
# __________________________________________________________________________________________________
# batch_normalization_91 (BatchNo (None, 9, 9, 384)    1536        conv2d_91[0][0]
# __________________________________________________________________________________________________
# activation_88 (Activation)      (None, 9, 9, 384)    0           batch_normalization_88[0][0]
# __________________________________________________________________________________________________
# activation_91 (Activation)      (None, 9, 9, 384)    0           batch_normalization_91[0][0]
# __________________________________________________________________________________________________
# conv2d_89 (Conv2D)              (None, 9, 9, 384)    442368      activation_88[0][0]
# __________________________________________________________________________________________________
# conv2d_90 (Conv2D)              (None, 9, 9, 384)    442368      activation_88[0][0]
# __________________________________________________________________________________________________
# conv2d_92 (Conv2D)              (None, 9, 9, 384)    442368      activation_91[0][0]
# __________________________________________________________________________________________________
# conv2d_93 (Conv2D)              (None, 9, 9, 384)    442368      activation_91[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_11 (MaxPooling2D) (None, 9, 9, 1280)   0           block_reduction_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_89 (BatchNo (None, 9, 9, 384)    1536        conv2d_89[0][0]
# __________________________________________________________________________________________________
# batch_normalization_90 (BatchNo (None, 9, 9, 384)    1536        conv2d_90[0][0]
# __________________________________________________________________________________________________
# batch_normalization_92 (BatchNo (None, 9, 9, 384)    1536        conv2d_92[0][0]
# __________________________________________________________________________________________________
# batch_normalization_93 (BatchNo (None, 9, 9, 384)    1536        conv2d_93[0][0]
# __________________________________________________________________________________________________
# conv2d_94 (Conv2D)              (None, 9, 9, 192)    245760      max_pooling2d_11[0][0]
# __________________________________________________________________________________________________
# conv2d_95 (Conv2D)              (None, 9, 9, 320)    409600      block_reduction_2[0][0]
# __________________________________________________________________________________________________
# activation_89 (Activation)      (None, 9, 9, 384)    0           batch_normalization_89[0][0]
# __________________________________________________________________________________________________
# activation_90 (Activation)      (None, 9, 9, 384)    0           batch_normalization_90[0][0]
# __________________________________________________________________________________________________
# activation_92 (Activation)      (None, 9, 9, 384)    0           batch_normalization_92[0][0]
# __________________________________________________________________________________________________
# activation_93 (Activation)      (None, 9, 9, 384)    0           batch_normalization_93[0][0]
# __________________________________________________________________________________________________
# batch_normalization_94 (BatchNo (None, 9, 9, 192)    768         conv2d_94[0][0]
# __________________________________________________________________________________________________
# batch_normalization_95 (BatchNo (None, 9, 9, 320)    1280        conv2d_95[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 9, 9, 768)    0           activation_89[0][0]
#                                                                  activation_90[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 9, 9, 768)    0           activation_92[0][0]
#                                                                  activation_93[0][0]
# __________________________________________________________________________________________________
# activation_94 (Activation)      (None, 9, 9, 192)    0           batch_normalization_94[0][0]
# __________________________________________________________________________________________________
# activation_95 (Activation)      (None, 9, 9, 320)    0           batch_normalization_95[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 9, 9, 2048)   0           concatenate_6[0][0]
#                                                                  concatenate_7[0][0]
#                                                                  activation_94[0][0]
#                                                                  activation_95[0][0]
# __________________________________________________________________________________________________
# conv2d_96 (Conv2D)              (None, 9, 9, 448)    917504      concatenate_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_96 (BatchNo (None, 9, 9, 448)    1792        conv2d_96[0][0]
# __________________________________________________________________________________________________
# activation_96 (Activation)      (None, 9, 9, 448)    0           batch_normalization_96[0][0]
# __________________________________________________________________________________________________
# conv2d_97 (Conv2D)              (None, 9, 9, 384)    1548288     activation_96[0][0]
# __________________________________________________________________________________________________
# conv2d_100 (Conv2D)             (None, 9, 9, 384)    786432      concatenate_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_97 (BatchNo (None, 9, 9, 384)    1536        conv2d_97[0][0]
# __________________________________________________________________________________________________
# batch_normalization_100 (BatchN (None, 9, 9, 384)    1536        conv2d_100[0][0]
# __________________________________________________________________________________________________
# activation_97 (Activation)      (None, 9, 9, 384)    0           batch_normalization_97[0][0]
# __________________________________________________________________________________________________
# activation_100 (Activation)     (None, 9, 9, 384)    0           batch_normalization_100[0][0]
# __________________________________________________________________________________________________
# conv2d_98 (Conv2D)              (None, 9, 9, 384)    442368      activation_97[0][0]
# __________________________________________________________________________________________________
# conv2d_99 (Conv2D)              (None, 9, 9, 384)    442368      activation_97[0][0]
# __________________________________________________________________________________________________
# conv2d_101 (Conv2D)             (None, 9, 9, 384)    442368      activation_100[0][0]
# __________________________________________________________________________________________________
# conv2d_102 (Conv2D)             (None, 9, 9, 384)    442368      activation_100[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_12 (MaxPooling2D) (None, 9, 9, 2048)   0           concatenate_8[0][0]
# __________________________________________________________________________________________________
# average_pooling2d (AveragePooli (None, 5, 5, 768)    0           block_inception_f6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_98 (BatchNo (None, 9, 9, 384)    1536        conv2d_98[0][0]
# __________________________________________________________________________________________________
# batch_normalization_99 (BatchNo (None, 9, 9, 384)    1536        conv2d_99[0][0]
# __________________________________________________________________________________________________
# batch_normalization_101 (BatchN (None, 9, 9, 384)    1536        conv2d_101[0][0]
# __________________________________________________________________________________________________
# batch_normalization_102 (BatchN (None, 9, 9, 384)    1536        conv2d_102[0][0]
# __________________________________________________________________________________________________
# conv2d_103 (Conv2D)             (None, 9, 9, 192)    393216      max_pooling2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_104 (Conv2D)             (None, 9, 9, 320)    655360      concatenate_8[0][0]
# __________________________________________________________________________________________________
# conv2d_105 (Conv2D)             (None, 5, 5, 128)    98304       average_pooling2d[0][0]
# __________________________________________________________________________________________________
# activation_98 (Activation)      (None, 9, 9, 384)    0           batch_normalization_98[0][0]
# __________________________________________________________________________________________________
# activation_99 (Activation)      (None, 9, 9, 384)    0           batch_normalization_99[0][0]
# __________________________________________________________________________________________________
# activation_101 (Activation)     (None, 9, 9, 384)    0           batch_normalization_101[0][0]
# __________________________________________________________________________________________________
# activation_102 (Activation)     (None, 9, 9, 384)    0           batch_normalization_102[0][0]
# __________________________________________________________________________________________________
# batch_normalization_103 (BatchN (None, 9, 9, 192)    768         conv2d_103[0][0]
# __________________________________________________________________________________________________
# batch_normalization_104 (BatchN (None, 9, 9, 320)    1280        conv2d_104[0][0]
# __________________________________________________________________________________________________
# batch_normalization_105 (BatchN (None, 5, 5, 128)    512         conv2d_105[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 9, 9, 768)    0           activation_98[0][0]
#                                                                  activation_99[0][0]
# __________________________________________________________________________________________________
# concatenate_10 (Concatenate)    (None, 9, 9, 768)    0           activation_101[0][0]
#                                                                  activation_102[0][0]
# __________________________________________________________________________________________________
# activation_103 (Activation)     (None, 9, 9, 192)    0           batch_normalization_103[0][0]
# __________________________________________________________________________________________________
# activation_104 (Activation)     (None, 9, 9, 320)    0           batch_normalization_104[0][0]
# __________________________________________________________________________________________________
# activation_105 (Activation)     (None, 5, 5, 128)    0           batch_normalization_105[0][0]
# __________________________________________________________________________________________________
# block_inception_f10 (Concatenat (None, 9, 9, 2048)   0           concatenate_9[0][0]
#                                                                  concatenate_10[0][0]
#                                                                  activation_103[0][0]
#                                                                  activation_104[0][0]
# __________________________________________________________________________________________________
# conv2d_106 (Conv2D)             (None, 1, 1, 1024)   3276800     activation_105[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 2048)         0           block_inception_f10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_106 (BatchN (None, 1, 1, 1024)   4096        conv2d_106[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 2048)         0           global_average_pooling2d[0][0]
# __________________________________________________________________________________________________
# activation_106 (Activation)     (None, 1, 1, 1024)   0           batch_normalization_106[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 100)          204800      dropout[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 1024)         0           activation_106[0][0]
# __________________________________________________________________________________________________
# main_classifier (Dense)         (None, 100)          10100       dense[0][0]
# __________________________________________________________________________________________________
# auxiliary_classifier (Dense)    (None, 100)          102400      flatten[0][0]
# ==================================================================================================
# Total params: 27,711,188
# Trainable params: 27,669,972
# Non-trainable params: 41,216
# __________________________________________________________________________________________________

# %%
# 폴더 생성

os.makedirs(os.path.join(dir,'model_output',number,model.name), exist_ok=True)
os.makedirs(os.path.join(dir,'train_valid_output',number), exist_ok=True)

# %%
# 참고 : https://github.com/OverLordGoldDragon/keras-adamw

import sys
sys.path.append('/content/drive/My Drive/Colab Notebooks/Paper')
import utils
import optimizers_v2
from utils import get_weight_decays, fill_dict_in_order
from utils import reset_seeds, K_eval
from optimizers_v2 import AdamW, NadamW, SGDW

# %%
# top-5 accuracy 출력
import functools
top5_acc = functools.partial(ks.metrics.top_k_categorical_accuracy, k=5)
top5_acc.__name__ = 'top5_acc'

# %%
#optimizer = SGDW(model=model, use_cosine_annealing=False, total_iterations = len(x_train) // batch_sizes, nesterov=True, momentum=0.9)
optimizer = AdamW(model=model, use_cosine_annealing=False, total_iterations = len(x_train) // batch_sizes)
#optimizer = Adam()
filepath =  os.path.join(dir,'model_output',number,model.name,'{epoch:03d}.h5')

callbacks_list = [ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_weights_only=False, save_best_only=True, mode='min'),
                  ModelCheckpoint(filepath, monitor='val_main_classifier_accuracy', verbose=1, save_weights_only=False, save_best_only=True, mode='max'),
                  #ReduceLROnPlateau(monitor='val_loss',patience=3,factor=0.1,min_lr=1e-5),
                  LearningRateScheduler(lr_schedule,verbose=1)
                  ]

model.compile(optimizer, loss={'main_classifier' : smoothed_categorical_crossentropy, 'auxiliary_classifier' : smoothed_categorical_crossentropy},
                loss_weights={'main_classifier' : 1.0, 'auxiliary_classifier' : 0.4}, metrics=['accuracy',top5_acc,macro_f1score])

# %%
######## flow_from_directory
#history = model.fit_generator(generate_train_for_three(), steps_per_epoch=int(len(x_train)/batch_sizes),  validation_data = generate_valid_for_three(), epochs=epochs , verbose=1 , callbacks = callbacks_list,validation_steps=int(len(x_valid)/batch_sizes))
history = model.fit(generate_train_for_two(), steps_per_epoch=int(len(x_train)/batch_sizes),  validation_data = generate_valid_for_two(), epochs=epochs , verbose=1 , callbacks = callbacks_list , validation_steps=int(len(x_valid)/batch_sizes))
# Out:
# Found 44923 images belonging to 100 classes.
# Learning rate:  0.001
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 1/70
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_1/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_2/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_3/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_4/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_5/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_6/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_7/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_9/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_8/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_10/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_11/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_12/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_13/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_14/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_16/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_15/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_17/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_18/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_19/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_20/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_21/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_23/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_22/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_24/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_25/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_26/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_27/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_28/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_30/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_29/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_31/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_32/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_33/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_34/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_37/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_35/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_38/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_36/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_39/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_40/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_41/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_42/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_43/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_44/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_47/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_45/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_48/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_46/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_49/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_50/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_51/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_52/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_53/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_54/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_57/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_55/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_58/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_56/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_59/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_60/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_61/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_62/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_63/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_64/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_67/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_65/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_68/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_66/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_69/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_70/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_71/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_72/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_73/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_74/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_77/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_75/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_78/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_76/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_79/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_80/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_81/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_82/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_83/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_85/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_84/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_86/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_87/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_88/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_91/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_89/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_90/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_92/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_93/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_94/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_95/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_96/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_97/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_100/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_98/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_99/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_101/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_102/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_103/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_104/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_105/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_106/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for dense/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for auxiliary_classifier/kernel:0
# 701/701 [==============================] - ETA: 0s - loss: 5.7473 - main_classifier_loss: 4.1303 - auxiliary_classifier_loss: 4.0424 - main_classifier_accuracy: 0.0828 - main_classifier_top5_acc: 0.2723 - main_classifier_macro_f1score: 4.6553e-04 - auxiliary_classifier_accuracy: 0.1235 - auxiliary_classifier_top5_acc: 0.3448 - auxiliary_classifier_macro_f1score: 0.0041 Found 5077 images belonging to 100 classes.
#
# Epoch 00001: val_loss improved from inf to 10.42250, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/Inception_v3/001.h5
#
# Epoch 00001: val_main_classifier_accuracy improved from -inf to 0.07002, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/Inception_v3/001.h5
# 701/701 [==============================] - 28374s 40s/step - loss: 5.7473 - main_classifier_loss: 4.1303 - auxiliary_classifier_loss: 4.0424 - main_classifier_accuracy: 0.0828 - main_classifier_top5_acc: 0.2723 - main_classifier_macro_f1score: 4.6553e-04 - auxiliary_classifier_accuracy: 0.1235 - auxiliary_classifier_top5_acc: 0.3448 - auxiliary_classifier_macro_f1score: 0.0041 - val_loss: 10.4225 - val_main_classifier_loss: 5.4721 - val_auxiliary_classifier_loss: 12.3760 - val_main_classifier_accuracy: 0.0700 - val_main_classifier_top5_acc: 0.2583 - val_main_classifier_macro_f1score: 0.0026 - val_auxiliary_classifier_accuracy: 0.1266 - val_auxiliary_classifier_top5_acc: 0.3706 - val_auxiliary_classifier_macro_f1score: 0.0125
# Learning rate:  0.001
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 2/70
# 701/701 [==============================] - ETA: 0s - loss: 5.0145 - main_classifier_loss: 3.6294 - auxiliary_classifier_loss: 3.4629 - main_classifier_accuracy: 0.1703 - main_classifier_top5_acc: 0.4526 - main_classifier_macro_f1score: 0.0058 - auxiliary_classifier_accuracy: 0.2280 - auxiliary_classifier_top5_acc: 0.5256 - auxiliary_classifier_macro_f1score: 0.0227
# Epoch 00002: val_loss improved from 10.42250 to 5.32633, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/Inception_v3/002.h5
#
# Epoch 00002: val_main_classifier_accuracy improved from 0.07002 to 0.19462, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/Inception_v3/002.h5
# 701/701 [==============================] - 968s 1s/step - loss: 5.0145 - main_classifier_loss: 3.6294 - auxiliary_classifier_loss: 3.4629 - main_classifier_accuracy: 0.1703 - main_classifier_top5_acc: 0.4526 - main_classifier_macro_f1score: 0.0058 - auxiliary_classifier_accuracy: 0.2280 - auxiliary_classifier_top5_acc: 0.5256 - auxiliary_classifier_macro_f1score: 0.0227 - val_loss: 5.3263 - val_main_classifier_loss: 3.6657 - val_auxiliary_classifier_loss: 4.1516 - val_main_classifier_accuracy: 0.1946 - val_main_classifier_top5_acc: 0.4931 - val_main_classifier_macro_f1score: 0.0156 - val_auxiliary_classifier_accuracy: 0.2496 - val_auxiliary_classifier_top5_acc: 0.5439 - val_auxiliary_classifier_macro_f1score: 0.0396
# Learning rate:  0.001
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 3/70
# 701/701 [==============================] - ETA: 0s - loss: 4.4106 - main_classifier_loss: 3.2068 - auxiliary_classifier_loss: 3.0096 - main_classifier_accuracy: 0.2689 - main_classifier_top5_acc: 0.5963 - main_classifier_macro_f1score: 0.0252 - auxiliary_classifier_accuracy: 0.3298 - auxiliary_classifier_top5_acc: 0.6486 - auxiliary_classifier_macro_f1score: 0.0572
# Epoch 00003: val_loss improved from 5.32633 to 4.40907, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/Inception_v3/003.h5
#
# Epoch 00003: val_main_classifier_accuracy improved from 0.19462 to 0.27809, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/Inception_v3/003.h5
# 701/701 [==============================] - 967s 1s/step - loss: 4.4106 - main_classifier_loss: 3.2068 - auxiliary_classifier_loss: 3.0096 - main_classifier_accuracy: 0.2689 - main_classifier_top5_acc: 0.5963 - main_classifier_macro_f1score: 0.0252 - auxiliary_classifier_accuracy: 0.3298 - auxiliary_classifier_top5_acc: 0.6486 - auxiliary_classifier_macro_f1score: 0.0572 - val_loss: 4.4091 - val_main_classifier_loss: 3.1805 - val_auxiliary_classifier_loss: 3.0713 - val_main_classifier_accuracy: 0.2781 - val_main_classifier_top5_acc: 0.6074 - val_main_classifier_macro_f1score: 0.0395 - val_auxiliary_classifier_accuracy: 0.3236 - val_auxiliary_classifier_top5_acc: 0.6390 - val_auxiliary_classifier_macro_f1score: 0.0711
# Learning rate:  0.001
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 4/70
# 701/701 [==============================] - ETA: 0s - loss: 4.0101 - main_classifier_loss: 2.9177 - auxiliary_classifier_loss: 2.7310 - main_classifier_accuracy: 0.3490 - main_classifier_top5_acc: 0.6836 - main_classifier_macro_f1score: 0.0503 - auxiliary_classifier_accuracy: 0.4014 - auxiliary_classifier_top5_acc: 0.7242 - auxiliary_classifier_macro_f1score: 0.0861
# Epoch 00004: val_loss improved from 4.40907 to 4.01608, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/Inception_v3/004.h5
#
# Epoch 00004: val_main_classifier_accuracy improved from 0.27809 to 0.35225, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/Inception_v3/004.h5
# 701/701 [==============================] - 965s 1s/step - loss: 4.0101 - main_classifier_loss: 2.9177 - auxiliary_classifier_loss: 2.7310 - main_classifier_accuracy: 0.3490 - main_classifier_top5_acc: 0.6836 - main_classifier_macro_f1score: 0.0503 - auxiliary_classifier_accuracy: 0.4014 - auxiliary_classifier_top5_acc: 0.7242 - auxiliary_classifier_macro_f1score: 0.0861 - val_loss: 4.0161 - val_main_classifier_loss: 2.8953 - val_auxiliary_classifier_loss: 2.8020 - val_main_classifier_accuracy: 0.3523 - val_main_classifier_top5_acc: 0.6881 - val_main_classifier_macro_f1score: 0.0561 - val_auxiliary_classifier_accuracy: 0.3780 - val_auxiliary_classifier_top5_acc: 0.7035 - val_auxiliary_classifier_macro_f1score: 0.0880
# Learning rate:  0.001
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 5/70
# 701/701 [==============================] - ETA: 0s - loss: 3.6765 - main_classifier_loss: 2.6756 - auxiliary_classifier_loss: 2.5024 - main_classifier_accuracy: 0.4157 - main_classifier_top5_acc: 0.7463 - main_classifier_macro_f1score: 0.0819 - auxiliary_classifier_accuracy: 0.4672 - auxiliary_classifier_top5_acc: 0.7829 - auxiliary_classifier_macro_f1score: 0.1175
# Epoch 00005: val_loss did not improve from 4.01608
#
# Epoch 00005: val_main_classifier_accuracy did not improve from 0.35225
# 701/701 [==============================] - 963s 1s/step - loss: 3.6765 - main_classifier_loss: 2.6756 - auxiliary_classifier_loss: 2.5024 - main_classifier_accuracy: 0.4157 - main_classifier_top5_acc: 0.7463 - main_classifier_macro_f1score: 0.0819 - auxiliary_classifier_accuracy: 0.4672 - auxiliary_classifier_top5_acc: 0.7829 - auxiliary_classifier_macro_f1score: 0.1175 - val_loss: 4.0434 - val_main_classifier_loss: 2.9565 - val_auxiliary_classifier_loss: 2.7174 - val_main_classifier_accuracy: 0.3418 - val_main_classifier_top5_acc: 0.6737 - val_main_classifier_macro_f1score: 0.0645 - val_auxiliary_classifier_accuracy: 0.4189 - val_auxiliary_classifier_top5_acc: 0.7320 - val_auxiliary_classifier_macro_f1score: 0.1058
# Learning rate:  0.001
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 6/70
# 701/701 [==============================] - ETA: 0s - loss: 3.4486 - main_classifier_loss: 2.5102 - auxiliary_classifier_loss: 2.3461 - main_classifier_accuracy: 0.4665 - main_classifier_top5_acc: 0.7876 - main_classifier_macro_f1score: 0.1078 - auxiliary_classifier_accuracy: 0.5149 - auxiliary_classifier_top5_acc: 0.8182 - auxiliary_classifier_macro_f1score: 0.1425
# Epoch 00006: val_loss improved from 4.01608 to 3.92535, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/Inception_v3/006.h5
#
# Epoch 00006: val_main_classifier_accuracy improved from 0.35225 to 0.39873, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/Inception_v3/006.h5
# 701/701 [==============================] - 963s 1s/step - loss: 3.4486 - main_classifier_loss: 2.5102 - auxiliary_classifier_loss: 2.3461 - main_classifier_accuracy: 0.4665 - main_classifier_top5_acc: 0.7876 - main_classifier_macro_f1score: 0.1078 - auxiliary_classifier_accuracy: 0.5149 - auxiliary_classifier_top5_acc: 0.8182 - auxiliary_classifier_macro_f1score: 0.1425 - val_loss: 3.9254 - val_main_classifier_loss: 2.8549 - val_auxiliary_classifier_loss: 2.6762 - val_main_classifier_accuracy: 0.3987 - val_main_classifier_top5_acc: 0.7089 - val_main_classifier_macro_f1score: 0.1049 - val_auxiliary_classifier_accuracy: 0.4434 - val_auxiliary_classifier_top5_acc: 0.7431 - val_auxiliary_classifier_macro_f1score: 0.1295
# Learning rate:  0.001
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 7/70
# 701/701 [==============================] - ETA: 0s - loss: 3.2605 - main_classifier_loss: 2.3749 - auxiliary_classifier_loss: 2.2139 - main_classifier_accuracy: 0.5067 - main_classifier_top5_acc: 0.8172 - main_classifier_macro_f1score: 0.1310 - auxiliary_classifier_accuracy: 0.5552 - auxiliary_classifier_top5_acc: 0.8454 - auxiliary_classifier_macro_f1score: 0.1636
# Epoch 00007: val_loss improved from 3.92535 to 3.80097, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/Inception_v3/007.h5
#
# Epoch 00007: val_main_classifier_accuracy improved from 0.39873 to 0.42306, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/Inception_v3/007.h5
# 701/701 [==============================] - 963s 1s/step - loss: 3.2605 - main_classifier_loss: 2.3749 - auxiliary_classifier_loss: 2.2139 - main_classifier_accuracy: 0.5067 - main_classifier_top5_acc: 0.8172 - main_classifier_macro_f1score: 0.1310 - auxiliary_classifier_accuracy: 0.5552 - auxiliary_classifier_top5_acc: 0.8454 - auxiliary_classifier_macro_f1score: 0.1636 - val_loss: 3.8010 - val_main_classifier_loss: 2.7809 - val_auxiliary_classifier_loss: 2.5502 - val_main_classifier_accuracy: 0.4231 - val_main_classifier_top5_acc: 0.7332 - val_main_classifier_macro_f1score: 0.0997 - val_auxiliary_classifier_accuracy: 0.4660 - val_auxiliary_classifier_top5_acc: 0.7666 - val_auxiliary_classifier_macro_f1score: 0.1313
# Learning rate:  0.001
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 8/70
# 701/701 [==============================] - ETA: 0s - loss: 3.1319 - main_classifier_loss: 2.2809 - auxiliary_classifier_loss: 2.1275 - main_classifier_accuracy: 0.5331 - main_classifier_top5_acc: 0.8355 - main_classifier_macro_f1score: 0.1469 - auxiliary_classifier_accuracy: 0.5802 - auxiliary_classifier_top5_acc: 0.8635 - auxiliary_classifier_macro_f1score: 0.1776
# Epoch 00008: val_loss improved from 3.80097 to 3.55643, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/Inception_v3/008.h5
#
# Epoch 00008: val_main_classifier_accuracy improved from 0.42306 to 0.44343, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/Inception_v3/008.h5
# 701/701 [==============================] - 964s 1s/step - loss: 3.1319 - main_classifier_loss: 2.2809 - auxiliary_classifier_loss: 2.1275 - main_classifier_accuracy: 0.5331 - main_classifier_top5_acc: 0.8355 - main_classifier_macro_f1score: 0.1469 - auxiliary_classifier_accuracy: 0.5802 - auxiliary_classifier_top5_acc: 0.8635 - auxiliary_classifier_macro_f1score: 0.1776 - val_loss: 3.5564 - val_main_classifier_loss: 2.6058 - val_auxiliary_classifier_loss: 2.3766 - val_main_classifier_accuracy: 0.4434 - val_main_classifier_top5_acc: 0.7605 - val_main_classifier_macro_f1score: 0.1282 - val_auxiliary_classifier_accuracy: 0.5136 - val_auxiliary_classifier_top5_acc: 0.8020 - val_auxiliary_classifier_macro_f1score: 0.1589
# Learning rate:  0.001
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 9/70
# 701/701 [==============================] - ETA: 0s - loss: 2.9918 - main_classifier_loss: 2.1806 - auxiliary_classifier_loss: 2.0278 - main_classifier_accuracy: 0.5653 - main_classifier_top5_acc: 0.8578 - main_classifier_macro_f1score: 0.1639 - auxiliary_classifier_accuracy: 0.6109 - auxiliary_classifier_top5_acc: 0.8833 - auxiliary_classifier_macro_f1score: 0.1960
# Epoch 00009: val_loss improved from 3.55643 to 3.17041, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/Inception_v3/009.h5
#
# Epoch 00009: val_main_classifier_accuracy improved from 0.44343 to 0.52631, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/Inception_v3/009.h5
# 701/701 [==============================] - 963s 1s/step - loss: 2.9918 - main_classifier_loss: 2.1806 - auxiliary_classifier_loss: 2.0278 - main_classifier_accuracy: 0.5653 - main_classifier_top5_acc: 0.8578 - main_classifier_macro_f1score: 0.1639 - auxiliary_classifier_accuracy: 0.6109 - auxiliary_classifier_top5_acc: 0.8833 - auxiliary_classifier_macro_f1score: 0.1960 - val_loss: 3.1704 - val_main_classifier_loss: 2.2939 - val_auxiliary_classifier_loss: 2.1913 - val_main_classifier_accuracy: 0.5263 - val_main_classifier_top5_acc: 0.8293 - val_main_classifier_macro_f1score: 0.1527 - val_auxiliary_classifier_accuracy: 0.5670 - val_auxiliary_classifier_top5_acc: 0.8398 - val_auxiliary_classifier_macro_f1score: 0.1784
# Learning rate:  0.001
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 10/70
# 701/701 [==============================] - ETA: 0s - loss: 2.8629 - main_classifier_loss: 2.0854 - auxiliary_classifier_loss: 1.9435 - main_classifier_accuracy: 0.5957 - main_classifier_top5_acc: 0.8757 - main_classifier_macro_f1score: 0.1835 - auxiliary_classifier_accuracy: 0.6409 - auxiliary_classifier_top5_acc: 0.8989 - auxiliary_classifier_macro_f1score: 0.2117
# Epoch 00010: val_loss did not improve from 3.17041
#
# Epoch 00010: val_main_classifier_accuracy did not improve from 0.52631
# 701/701 [==============================] - 958s 1s/step - loss: 2.8629 - main_classifier_loss: 2.0854 - auxiliary_classifier_loss: 1.9435 - main_classifier_accuracy: 0.5957 - main_classifier_top5_acc: 0.8757 - main_classifier_macro_f1score: 0.1835 - auxiliary_classifier_accuracy: 0.6409 - auxiliary_classifier_top5_acc: 0.8989 - auxiliary_classifier_macro_f1score: 0.2117 - val_loss: 3.3112 - val_main_classifier_loss: 2.4166 - val_auxiliary_classifier_loss: 2.2365 - val_main_classifier_accuracy: 0.4947 - val_main_classifier_top5_acc: 0.8062 - val_main_classifier_macro_f1score: 0.1596 - val_auxiliary_classifier_accuracy: 0.5540 - val_auxiliary_classifier_top5_acc: 0.8398 - val_auxiliary_classifier_macro_f1score: 0.1901
# Learning rate:  0.001
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 11/70
# 701/701 [==============================] - ETA: 0s - loss: 2.7587 - main_classifier_loss: 2.0111 - auxiliary_classifier_loss: 1.8692 - main_classifier_accuracy: 0.6221 - main_classifier_top5_acc: 0.8891 - main_classifier_macro_f1score: 0.2005 - auxiliary_classifier_accuracy: 0.6660 - auxiliary_classifier_top5_acc: 0.9115 - auxiliary_classifier_macro_f1score: 0.2279
# Epoch 00011: val_loss improved from 3.17041 to 3.03419, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/Inception_v3/011.h5
#
# Epoch 00011: val_main_classifier_accuracy improved from 0.52631 to 0.55993, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/Inception_v3/011.h5
# 701/701 [==============================] - 964s 1s/step - loss: 2.7587 - main_classifier_loss: 2.0111 - auxiliary_classifier_loss: 1.8692 - main_classifier_accuracy: 0.6221 - main_classifier_top5_acc: 0.8891 - main_classifier_macro_f1score: 0.2005 - auxiliary_classifier_accuracy: 0.6660 - auxiliary_classifier_top5_acc: 0.9115 - auxiliary_classifier_macro_f1score: 0.2279 - val_loss: 3.0342 - val_main_classifier_loss: 2.1886 - val_auxiliary_classifier_loss: 2.1141 - val_main_classifier_accuracy: 0.5599 - val_main_classifier_top5_acc: 0.8511 - val_main_classifier_macro_f1score: 0.1765 - val_auxiliary_classifier_accuracy: 0.5775 - val_auxiliary_classifier_top5_acc: 0.8645 - val_auxiliary_classifier_macro_f1score: 0.1994
# Learning rate:  0.001
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 12/70
# 701/701 [==============================] - ETA: 0s - loss: 2.6685 - main_classifier_loss: 1.9451 - auxiliary_classifier_loss: 1.8085 - main_classifier_accuracy: 0.6394 - main_classifier_top5_acc: 0.8995 - main_classifier_macro_f1score: 0.2125 - auxiliary_classifier_accuracy: 0.6829 - auxiliary_classifier_top5_acc: 0.9230 - auxiliary_classifier_macro_f1score: 0.2394
# Epoch 00012: val_loss did not improve from 3.03419
#
# Epoch 00012: val_main_classifier_accuracy did not improve from 0.55993
# 701/701 [==============================] - 967s 1s/step - loss: 2.6685 - main_classifier_loss: 1.9451 - auxiliary_classifier_loss: 1.8085 - main_classifier_accuracy: 0.6394 - main_classifier_top5_acc: 0.8995 - main_classifier_macro_f1score: 0.2125 - auxiliary_classifier_accuracy: 0.6829 - auxiliary_classifier_top5_acc: 0.9230 - auxiliary_classifier_macro_f1score: 0.2394 - val_loss: 3.1841 - val_main_classifier_loss: 2.2957 - val_auxiliary_classifier_loss: 2.2210 - val_main_classifier_accuracy: 0.5374 - val_main_classifier_top5_acc: 0.8279 - val_main_classifier_macro_f1score: 0.1673 - val_auxiliary_classifier_accuracy: 0.5647 - val_auxiliary_classifier_top5_acc: 0.8428 - val_auxiliary_classifier_macro_f1score: 0.1929
# Learning rate:  0.001
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 13/70
# 701/701 [==============================] - ETA: 0s - loss: 2.7412 - main_classifier_loss: 1.9970 - auxiliary_classifier_loss: 1.8607 - main_classifier_accuracy: 0.6234 - main_classifier_top5_acc: 0.8888 - main_classifier_macro_f1score: 0.2045 - auxiliary_classifier_accuracy: 0.6697 - auxiliary_classifier_top5_acc: 0.9111 - auxiliary_classifier_macro_f1score: 0.2301
# Epoch 00013: val_loss improved from 3.03419 to 2.90767, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/Inception_v3/013.h5
#
# Epoch 00013: val_main_classifier_accuracy improved from 0.55993 to 0.59553, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/Inception_v3/013.h5
# 701/701 [==============================] - 971s 1s/step - loss: 2.7412 - main_classifier_loss: 1.9970 - auxiliary_classifier_loss: 1.8607 - main_classifier_accuracy: 0.6234 - main_classifier_top5_acc: 0.8888 - main_classifier_macro_f1score: 0.2045 - auxiliary_classifier_accuracy: 0.6697 - auxiliary_classifier_top5_acc: 0.9111 - auxiliary_classifier_macro_f1score: 0.2301 - val_loss: 2.9077 - val_main_classifier_loss: 2.0796 - val_auxiliary_classifier_loss: 2.0702 - val_main_classifier_accuracy: 0.5955 - val_main_classifier_top5_acc: 0.8708 - val_main_classifier_macro_f1score: 0.1921 - val_auxiliary_classifier_accuracy: 0.6066 - val_auxiliary_classifier_top5_acc: 0.8645 - val_auxiliary_classifier_macro_f1score: 0.2086
# Learning rate:  0.001
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 14/70
# 701/701 [==============================] - ETA: 0s - loss: 2.5287 - main_classifier_loss: 1.8421 - auxiliary_classifier_loss: 1.7166 - main_classifier_accuracy: 0.6731 - main_classifier_top5_acc: 0.9153 - main_classifier_macro_f1score: 0.2330 - auxiliary_classifier_accuracy: 0.7179 - auxiliary_classifier_top5_acc: 0.9368 - auxiliary_classifier_macro_f1score: 0.2560
# Epoch 00014: val_loss improved from 2.90767 to 2.89977, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/Inception_v3/014.h5
#
# Epoch 00014: val_main_classifier_accuracy improved from 0.59553 to 0.59771, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/Inception_v3/014.h5
# 701/701 [==============================] - 968s 1s/step - loss: 2.5287 - main_classifier_loss: 1.8421 - auxiliary_classifier_loss: 1.7166 - main_classifier_accuracy: 0.6731 - main_classifier_top5_acc: 0.9153 - main_classifier_macro_f1score: 0.2330 - auxiliary_classifier_accuracy: 0.7179 - auxiliary_classifier_top5_acc: 0.9368 - auxiliary_classifier_macro_f1score: 0.2560 - val_loss: 2.8998 - val_main_classifier_loss: 2.0712 - val_auxiliary_classifier_loss: 2.0714 - val_main_classifier_accuracy: 0.5977 - val_main_classifier_top5_acc: 0.8667 - val_main_classifier_macro_f1score: 0.1906 - val_auxiliary_classifier_accuracy: 0.5991 - val_auxiliary_classifier_top5_acc: 0.8635 - val_auxiliary_classifier_macro_f1score: 0.2092
# Learning rate:  0.001
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 15/70
# 701/701 [==============================] - ETA: 0s - loss: 2.4452 - main_classifier_loss: 1.7823 - auxiliary_classifier_loss: 1.6573 - main_classifier_accuracy: 0.6922 - main_classifier_top5_acc: 0.9256 - main_classifier_macro_f1score: 0.2455 - auxiliary_classifier_accuracy: 0.7388 - auxiliary_classifier_top5_acc: 0.9454 - auxiliary_classifier_macro_f1score: 0.2698
# Epoch 00015: val_loss did not improve from 2.89977
#
# Epoch 00015: val_main_classifier_accuracy did not improve from 0.59771
# 701/701 [==============================] - 971s 1s/step - loss: 2.4452 - main_classifier_loss: 1.7823 - auxiliary_classifier_loss: 1.6573 - main_classifier_accuracy: 0.6922 - main_classifier_top5_acc: 0.9256 - main_classifier_macro_f1score: 0.2455 - auxiliary_classifier_accuracy: 0.7388 - auxiliary_classifier_top5_acc: 0.9454 - auxiliary_classifier_macro_f1score: 0.2698 - val_loss: 2.9597 - val_main_classifier_loss: 2.1407 - val_auxiliary_classifier_loss: 2.0476 - val_main_classifier_accuracy: 0.5769 - val_main_classifier_top5_acc: 0.8616 - val_main_classifier_macro_f1score: 0.2102 - val_auxiliary_classifier_accuracy: 0.6114 - val_auxiliary_classifier_top5_acc: 0.8744 - val_auxiliary_classifier_macro_f1score: 0.2183
# Learning rate:  0.001
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 16/70
# 701/701 [==============================] - ETA: 0s - loss: 2.3890 - main_classifier_loss: 1.7393 - auxiliary_classifier_loss: 1.6244 - main_classifier_accuracy: 0.7065 - main_classifier_top5_acc: 0.9327 - main_classifier_macro_f1score: 0.2547 - auxiliary_classifier_accuracy: 0.7474 - auxiliary_classifier_top5_acc: 0.9508 - auxiliary_classifier_macro_f1score: 0.2764
# Epoch 00016: val_loss improved from 2.89977 to 2.76806, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/Inception_v3/016.h5
#
# Epoch 00016: val_main_classifier_accuracy improved from 0.59771 to 0.62896, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/Inception_v3/016.h5
# 701/701 [==============================] - 1004s 1s/step - loss: 2.3890 - main_classifier_loss: 1.7393 - auxiliary_classifier_loss: 1.6244 - main_classifier_accuracy: 0.7065 - main_classifier_top5_acc: 0.9327 - main_classifier_macro_f1score: 0.2547 - auxiliary_classifier_accuracy: 0.7474 - auxiliary_classifier_top5_acc: 0.9508 - auxiliary_classifier_macro_f1score: 0.2764 - val_loss: 2.7681 - val_main_classifier_loss: 1.9803 - val_auxiliary_classifier_loss: 1.9693 - val_main_classifier_accuracy: 0.6290 - val_main_classifier_top5_acc: 0.8841 - val_main_classifier_macro_f1score: 0.2143 - val_auxiliary_classifier_accuracy: 0.6420 - val_auxiliary_classifier_top5_acc: 0.8906 - val_auxiliary_classifier_macro_f1score: 0.2317
# Learning rate:  0.001
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 17/70
# 701/701 [==============================] - ETA: 0s - loss: 2.3184 - main_classifier_loss: 1.6863 - auxiliary_classifier_loss: 1.5804 - main_classifier_accuracy: 0.7259 - main_classifier_top5_acc: 0.9402 - main_classifier_macro_f1score: 0.2661 - auxiliary_classifier_accuracy: 0.7637 - auxiliary_classifier_top5_acc: 0.9569 - auxiliary_classifier_macro_f1score: 0.2851
# Epoch 00017: val_loss did not improve from 2.76806
#
# Epoch 00017: val_main_classifier_accuracy did not improve from 0.62896
# 701/701 [==============================] - 1018s 1s/step - loss: 2.3184 - main_classifier_loss: 1.6863 - auxiliary_classifier_loss: 1.5804 - main_classifier_accuracy: 0.7259 - main_classifier_top5_acc: 0.9402 - main_classifier_macro_f1score: 0.2661 - auxiliary_classifier_accuracy: 0.7637 - auxiliary_classifier_top5_acc: 0.9569 - auxiliary_classifier_macro_f1score: 0.2851 - val_loss: 3.0623 - val_main_classifier_loss: 2.2272 - val_auxiliary_classifier_loss: 2.0879 - val_main_classifier_accuracy: 0.5581 - val_main_classifier_top5_acc: 0.8376 - val_main_classifier_macro_f1score: 0.1937 - val_auxiliary_classifier_accuracy: 0.6052 - val_auxiliary_classifier_top5_acc: 0.8594 - val_auxiliary_classifier_macro_f1score: 0.2117
# Learning rate:  0.001
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 18/70
# 701/701 [==============================] - ETA: 0s - loss: 2.3482 - main_classifier_loss: 1.7055 - auxiliary_classifier_loss: 1.6067 - main_classifier_accuracy: 0.7164 - main_classifier_top5_acc: 0.9368 - main_classifier_macro_f1score: 0.2622 - auxiliary_classifier_accuracy: 0.7569 - auxiliary_classifier_top5_acc: 0.9530 - auxiliary_classifier_macro_f1score: 0.2814
# Epoch 00018: val_loss did not improve from 2.76806
#
# Epoch 00018: val_main_classifier_accuracy improved from 0.62896 to 0.63034, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/Inception_v3/018.h5
# 701/701 [==============================] - 968s 1s/step - loss: 2.3482 - main_classifier_loss: 1.7055 - auxiliary_classifier_loss: 1.6067 - main_classifier_accuracy: 0.7164 - main_classifier_top5_acc: 0.9368 - main_classifier_macro_f1score: 0.2622 - auxiliary_classifier_accuracy: 0.7569 - auxiliary_classifier_top5_acc: 0.9530 - auxiliary_classifier_macro_f1score: 0.2814 - val_loss: 2.7915 - val_main_classifier_loss: 1.9865 - val_auxiliary_classifier_loss: 2.0124 - val_main_classifier_accuracy: 0.6303 - val_main_classifier_top5_acc: 0.8817 - val_main_classifier_macro_f1score: 0.2182 - val_auxiliary_classifier_accuracy: 0.6290 - val_auxiliary_classifier_top5_acc: 0.8750 - val_auxiliary_classifier_macro_f1score: 0.2214
# Learning rate:  0.001
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 19/70
# 701/701 [==============================] - ETA: 0s - loss: 2.2107 - main_classifier_loss: 1.6044 - auxiliary_classifier_loss: 1.5158 - main_classifier_accuracy: 0.7505 - main_classifier_top5_acc: 0.9519 - main_classifier_macro_f1score: 0.2847 - auxiliary_classifier_accuracy: 0.7875 - auxiliary_classifier_top5_acc: 0.9645 - auxiliary_classifier_macro_f1score: 0.3010
# Epoch 00019: val_loss did not improve from 2.76806
#
# Epoch 00019: val_main_classifier_accuracy did not improve from 0.63034
# 701/701 [==============================] - 963s 1s/step - loss: 2.2107 - main_classifier_loss: 1.6044 - auxiliary_classifier_loss: 1.5158 - main_classifier_accuracy: 0.7505 - main_classifier_top5_acc: 0.9519 - main_classifier_macro_f1score: 0.2847 - auxiliary_classifier_accuracy: 0.7875 - auxiliary_classifier_top5_acc: 0.9645 - auxiliary_classifier_macro_f1score: 0.3010 - val_loss: 2.8381 - val_main_classifier_loss: 2.0337 - val_auxiliary_classifier_loss: 2.0110 - val_main_classifier_accuracy: 0.6110 - val_main_classifier_top5_acc: 0.8705 - val_main_classifier_macro_f1score: 0.2223 - val_auxiliary_classifier_accuracy: 0.6333 - val_auxiliary_classifier_top5_acc: 0.8752 - val_auxiliary_classifier_macro_f1score: 0.2317
# Learning rate:  0.001
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 20/70
# 701/701 [==============================] - ETA: 0s - loss: 2.1511 - main_classifier_loss: 1.5587 - auxiliary_classifier_loss: 1.4810 - main_classifier_accuracy: 0.7690 - main_classifier_top5_acc: 0.9572 - main_classifier_macro_f1score: 0.2939 - auxiliary_classifier_accuracy: 0.8011 - auxiliary_classifier_top5_acc: 0.9695 - auxiliary_classifier_macro_f1score: 0.3085
# Epoch 00020: val_loss did not improve from 2.76806
#
# Epoch 00020: val_main_classifier_accuracy did not improve from 0.63034
# 701/701 [==============================] - 962s 1s/step - loss: 2.1511 - main_classifier_loss: 1.5587 - auxiliary_classifier_loss: 1.4810 - main_classifier_accuracy: 0.7690 - main_classifier_top5_acc: 0.9572 - main_classifier_macro_f1score: 0.2939 - auxiliary_classifier_accuracy: 0.8011 - auxiliary_classifier_top5_acc: 0.9695 - auxiliary_classifier_macro_f1score: 0.3085 - val_loss: 2.8473 - val_main_classifier_loss: 2.0475 - val_auxiliary_classifier_loss: 1.9996 - val_main_classifier_accuracy: 0.6133 - val_main_classifier_top5_acc: 0.8683 - val_main_classifier_macro_f1score: 0.2201 - val_auxiliary_classifier_accuracy: 0.6361 - val_auxiliary_classifier_top5_acc: 0.8768 - val_auxiliary_classifier_macro_f1score: 0.2332
# Learning rate:  0.001
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 21/70
# 701/701 [==============================] - ETA: 0s - loss: 2.1070 - main_classifier_loss: 1.5250 - auxiliary_classifier_loss: 1.4550 - main_classifier_accuracy: 0.7795 - main_classifier_top5_acc: 0.9620 - main_classifier_macro_f1score: 0.3052 - auxiliary_classifier_accuracy: 0.8101 - auxiliary_classifier_top5_acc: 0.9726 - auxiliary_classifier_macro_f1score: 0.3181
# Epoch 00021: val_loss improved from 2.76806 to 2.75872, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/Inception_v3/021.h5
#
# Epoch 00021: val_main_classifier_accuracy improved from 0.63034 to 0.63054, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/Inception_v3/021.h5
# 701/701 [==============================] - 967s 1s/step - loss: 2.1070 - main_classifier_loss: 1.5250 - auxiliary_classifier_loss: 1.4550 - main_classifier_accuracy: 0.7795 - main_classifier_top5_acc: 0.9620 - main_classifier_macro_f1score: 0.3052 - auxiliary_classifier_accuracy: 0.8101 - auxiliary_classifier_top5_acc: 0.9726 - auxiliary_classifier_macro_f1score: 0.3181 - val_loss: 2.7587 - val_main_classifier_loss: 1.9645 - val_auxiliary_classifier_loss: 1.9856 - val_main_classifier_accuracy: 0.6305 - val_main_classifier_top5_acc: 0.8803 - val_main_classifier_macro_f1score: 0.2314 - val_auxiliary_classifier_accuracy: 0.6420 - val_auxiliary_classifier_top5_acc: 0.8863 - val_auxiliary_classifier_macro_f1score: 0.2470
# Learning rate:  0.001
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 22/70
# 701/701 [==============================] - ETA: 0s - loss: 2.0932 - main_classifier_loss: 1.5121 - auxiliary_classifier_loss: 1.4528 - main_classifier_accuracy: 0.7832 - main_classifier_top5_acc: 0.9629 - main_classifier_macro_f1score: 0.3057 - auxiliary_classifier_accuracy: 0.8113 - auxiliary_classifier_top5_acc: 0.9728 - auxiliary_classifier_macro_f1score: 0.3171
# Epoch 00022: val_loss improved from 2.75872 to 2.75680, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/Inception_v3/022.h5
#
# Epoch 00022: val_main_classifier_accuracy improved from 0.63054 to 0.63983, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/Inception_v3/022.h5
# 701/701 [==============================] - 972s 1s/step - loss: 2.0932 - main_classifier_loss: 1.5121 - auxiliary_classifier_loss: 1.4528 - main_classifier_accuracy: 0.7832 - main_classifier_top5_acc: 0.9629 - main_classifier_macro_f1score: 0.3057 - auxiliary_classifier_accuracy: 0.8113 - auxiliary_classifier_top5_acc: 0.9728 - auxiliary_classifier_macro_f1score: 0.3171 - val_loss: 2.7568 - val_main_classifier_loss: 1.9599 - val_auxiliary_classifier_loss: 1.9922 - val_main_classifier_accuracy: 0.6398 - val_main_classifier_top5_acc: 0.8847 - val_main_classifier_macro_f1score: 0.2340 - val_auxiliary_classifier_accuracy: 0.6390 - val_auxiliary_classifier_top5_acc: 0.8746 - val_auxiliary_classifier_macro_f1score: 0.2364
# Learning rate:  0.001
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 23/70
# 701/701 [==============================] - ETA: 0s - loss: 2.0220 - main_classifier_loss: 1.4601 - auxiliary_classifier_loss: 1.4047 - main_classifier_accuracy: 0.8019 - main_classifier_top5_acc: 0.9702 - main_classifier_macro_f1score: 0.3176 - auxiliary_classifier_accuracy: 0.8296 - auxiliary_classifier_top5_acc: 0.9776 - auxiliary_classifier_macro_f1score: 0.3274
# Epoch 00023: val_loss improved from 2.75680 to 2.74535, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/Inception_v3/023.h5
#
# Epoch 00023: val_main_classifier_accuracy improved from 0.63983 to 0.64755, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/Inception_v3/023.h5
# 701/701 [==============================] - 973s 1s/step - loss: 2.0220 - main_classifier_loss: 1.4601 - auxiliary_classifier_loss: 1.4047 - main_classifier_accuracy: 0.8019 - main_classifier_top5_acc: 0.9702 - main_classifier_macro_f1score: 0.3176 - auxiliary_classifier_accuracy: 0.8296 - auxiliary_classifier_top5_acc: 0.9776 - auxiliary_classifier_macro_f1score: 0.3274 - val_loss: 2.7453 - val_main_classifier_loss: 1.9600 - val_auxiliary_classifier_loss: 1.9632 - val_main_classifier_accuracy: 0.6475 - val_main_classifier_top5_acc: 0.8920 - val_main_classifier_macro_f1score: 0.2467 - val_auxiliary_classifier_accuracy: 0.6424 - val_auxiliary_classifier_top5_acc: 0.8888 - val_auxiliary_classifier_macro_f1score: 0.2475
# Learning rate:  0.001
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 24/70
# 701/701 [==============================] - ETA: 0s - loss: 1.9705 - main_classifier_loss: 1.4181 - auxiliary_classifier_loss: 1.3809 - main_classifier_accuracy: 0.8160 - main_classifier_top5_acc: 0.9735 - main_classifier_macro_f1score: 0.3260 - auxiliary_classifier_accuracy: 0.8394 - auxiliary_classifier_top5_acc: 0.9806 - auxiliary_classifier_macro_f1score: 0.3347
# Epoch 00024: val_loss did not improve from 2.74535
#
# Epoch 00024: val_main_classifier_accuracy did not improve from 0.64755
# 701/701 [==============================] - 960s 1s/step - loss: 1.9705 - main_classifier_loss: 1.4181 - auxiliary_classifier_loss: 1.3809 - main_classifier_accuracy: 0.8160 - main_classifier_top5_acc: 0.9735 - main_classifier_macro_f1score: 0.3260 - auxiliary_classifier_accuracy: 0.8394 - auxiliary_classifier_top5_acc: 0.9806 - auxiliary_classifier_macro_f1score: 0.3347 - val_loss: 2.8244 - val_main_classifier_loss: 2.0344 - val_auxiliary_classifier_loss: 1.9749 - val_main_classifier_accuracy: 0.6252 - val_main_classifier_top5_acc: 0.8748 - val_main_classifier_macro_f1score: 0.2385 - val_auxiliary_classifier_accuracy: 0.6408 - val_auxiliary_classifier_top5_acc: 0.8799 - val_auxiliary_classifier_macro_f1score: 0.2388
# Learning rate:  0.001
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 25/70
# 701/701 [==============================] - ETA: 0s - loss: 1.9352 - main_classifier_loss: 1.3907 - auxiliary_classifier_loss: 1.3611 - main_classifier_accuracy: 0.8252 - main_classifier_top5_acc: 0.9785 - main_classifier_macro_f1score: 0.3326 - auxiliary_classifier_accuracy: 0.8453 - auxiliary_classifier_top5_acc: 0.9821 - auxiliary_classifier_macro_f1score: 0.3389
# Epoch 00025: val_loss did not improve from 2.74535
#
# Epoch 00025: val_main_classifier_accuracy did not improve from 0.64755
# 701/701 [==============================] - 959s 1s/step - loss: 1.9352 - main_classifier_loss: 1.3907 - auxiliary_classifier_loss: 1.3611 - main_classifier_accuracy: 0.8252 - main_classifier_top5_acc: 0.9785 - main_classifier_macro_f1score: 0.3326 - auxiliary_classifier_accuracy: 0.8453 - auxiliary_classifier_top5_acc: 0.9821 - auxiliary_classifier_macro_f1score: 0.3389 - val_loss: 2.7747 - val_main_classifier_loss: 1.9800 - val_auxiliary_classifier_loss: 1.9867 - val_main_classifier_accuracy: 0.6319 - val_main_classifier_top5_acc: 0.8784 - val_main_classifier_macro_f1score: 0.2430 - val_auxiliary_classifier_accuracy: 0.6375 - val_auxiliary_classifier_top5_acc: 0.8833 - val_auxiliary_classifier_macro_f1score: 0.2408
# Learning rate:  0.001
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 26/70
# 701/701 [==============================] - ETA: 0s - loss: 1.9069 - main_classifier_loss: 1.3683 - auxiliary_classifier_loss: 1.3464 - main_classifier_accuracy: 0.8342 - main_classifier_top5_acc: 0.9798 - main_classifier_macro_f1score: 0.3387 - auxiliary_classifier_accuracy: 0.8530 - auxiliary_classifier_top5_acc: 0.9836 - auxiliary_classifier_macro_f1score: 0.3439
# Epoch 00026: val_loss improved from 2.74535 to 2.69322, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/Inception_v3/026.h5
#
# Epoch 00026: val_main_classifier_accuracy improved from 0.64755 to 0.65368, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/Inception_v3/026.h5
# 701/701 [==============================] - 964s 1s/step - loss: 1.9069 - main_classifier_loss: 1.3683 - auxiliary_classifier_loss: 1.3464 - main_classifier_accuracy: 0.8342 - main_classifier_top5_acc: 0.9798 - main_classifier_macro_f1score: 0.3387 - auxiliary_classifier_accuracy: 0.8530 - auxiliary_classifier_top5_acc: 0.9836 - auxiliary_classifier_macro_f1score: 0.3439 - val_loss: 2.6932 - val_main_classifier_loss: 1.9082 - val_auxiliary_classifier_loss: 1.9625 - val_main_classifier_accuracy: 0.6537 - val_main_classifier_top5_acc: 0.8932 - val_main_classifier_macro_f1score: 0.2564 - val_auxiliary_classifier_accuracy: 0.6509 - val_auxiliary_classifier_top5_acc: 0.8833 - val_auxiliary_classifier_macro_f1score: 0.2478
# Learning rate:  0.001
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 27/70
# 701/701 [==============================] - ETA: 0s - loss: 1.8618 - main_classifier_loss: 1.3315 - auxiliary_classifier_loss: 1.3257 - main_classifier_accuracy: 0.8479 - main_classifier_top5_acc: 0.9812 - main_classifier_macro_f1score: 0.3465 - auxiliary_classifier_accuracy: 0.8597 - auxiliary_classifier_top5_acc: 0.9854 - auxiliary_classifier_macro_f1score: 0.3475
# Epoch 00027: val_loss did not improve from 2.69322
#
# Epoch 00027: val_main_classifier_accuracy did not improve from 0.65368
# 701/701 [==============================] - 961s 1s/step - loss: 1.8618 - main_classifier_loss: 1.3315 - auxiliary_classifier_loss: 1.3257 - main_classifier_accuracy: 0.8479 - main_classifier_top5_acc: 0.9812 - main_classifier_macro_f1score: 0.3465 - auxiliary_classifier_accuracy: 0.8597 - auxiliary_classifier_top5_acc: 0.9854 - auxiliary_classifier_macro_f1score: 0.3475 - val_loss: 2.8615 - val_main_classifier_loss: 2.0628 - val_auxiliary_classifier_loss: 1.9969 - val_main_classifier_accuracy: 0.6252 - val_main_classifier_top5_acc: 0.8778 - val_main_classifier_macro_f1score: 0.2506 - val_auxiliary_classifier_accuracy: 0.6479 - val_auxiliary_classifier_top5_acc: 0.8805 - val_auxiliary_classifier_macro_f1score: 0.2518
# Learning rate:  0.001
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 28/70
# ...
# Learning rate:  0.0001
#
# Epoch 00036: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 36/70
# 701/701 [==============================] - ETA: 0s - loss: 1.3425 - main_classifier_loss: 0.9346 - auxiliary_classifier_loss: 1.0197 - main_classifier_accuracy: 0.9866 - main_classifier_top5_acc: 0.9997 - main_classifier_macro_f1score: 0.4541 - auxiliary_classifier_accuracy: 0.9741 - auxiliary_classifier_top5_acc: 0.9992 - auxiliary_classifier_macro_f1score: 0.4295
# Epoch 00036: val_loss did not improve from 2.23474
#
# Epoch 00036: val_main_classifier_accuracy improved from 0.75099 to 0.75415, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/Inception_v3/036.h5
# 701/701 [==============================] - 960s 1s/step - loss: 1.3425 - main_classifier_loss: 0.9346 - auxiliary_classifier_loss: 1.0197 - main_classifier_accuracy: 0.9866 - main_classifier_top5_acc: 0.9997 - main_classifier_macro_f1score: 0.4541 - auxiliary_classifier_accuracy: 0.9741 - auxiliary_classifier_top5_acc: 0.9992 - auxiliary_classifier_macro_f1score: 0.4295 - val_loss: 2.2467 - val_main_classifier_loss: 1.5905 - val_auxiliary_classifier_loss: 1.6405 - val_main_classifier_accuracy: 0.7542 - val_main_classifier_top5_acc: 0.9302 - val_main_classifier_macro_f1score: 0.3081 - val_auxiliary_classifier_accuracy: 0.7488 - val_auxiliary_classifier_top5_acc: 0.9254 - val_auxiliary_classifier_macro_f1score: 0.2873
# Learning rate:  0.0001
#
# Epoch 00037: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 37/70
# 701/701 [==============================] - ETA: 0s - loss: 1.3328 - main_classifier_loss: 0.9270 - auxiliary_classifier_loss: 1.0143 - main_classifier_accuracy: 0.9886 - main_classifier_top5_acc: 0.9998 - main_classifier_macro_f1score: 0.4553 - auxiliary_classifier_accuracy: 0.9757 - auxiliary_classifier_top5_acc: 0.9994 - auxiliary_classifier_macro_f1score: 0.4304
# Epoch 00037: val_loss improved from 2.23474 to 2.23244, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/Inception_v3/037.h5
#
# Epoch 00037: val_main_classifier_accuracy improved from 0.75415 to 0.76009, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/Inception_v3/037.h5
# 701/701 [==============================] - 973s 1s/step - loss: 1.3328 - main_classifier_loss: 0.9270 - auxiliary_classifier_loss: 1.0143 - main_classifier_accuracy: 0.9886 - main_classifier_top5_acc: 0.9998 - main_classifier_macro_f1score: 0.4553 - auxiliary_classifier_accuracy: 0.9757 - auxiliary_classifier_top5_acc: 0.9994 - auxiliary_classifier_macro_f1score: 0.4304 - val_loss: 2.2324 - val_main_classifier_loss: 1.5826 - val_auxiliary_classifier_loss: 1.6245 - val_main_classifier_accuracy: 0.7601 - val_main_classifier_top5_acc: 0.9324 - val_main_classifier_macro_f1score: 0.3084 - val_auxiliary_classifier_accuracy: 0.7510 - val_auxiliary_classifier_top5_acc: 0.9326 - val_auxiliary_classifier_macro_f1score: 0.2904
# Learning rate:  0.0001
#
# Epoch 00038: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 38/70
# 701/701 [==============================] - ETA: 0s - loss: 1.3219 - main_classifier_loss: 0.9194 - auxiliary_classifier_loss: 1.0063 - main_classifier_accuracy: 0.9898 - main_classifier_top5_acc: 0.9999 - main_classifier_macro_f1score: 0.4573 - auxiliary_classifier_accuracy: 0.9776 - auxiliary_classifier_top5_acc: 0.9995 - auxiliary_classifier_macro_f1score: 0.4325
# Epoch 00038: val_loss did not improve from 2.23244
#
# Epoch 00038: val_main_classifier_accuracy did not improve from 0.76009
# 701/701 [==============================] - 975s 1s/step - loss: 1.3219 - main_classifier_loss: 0.9194 - auxiliary_classifier_loss: 1.0063 - main_classifier_accuracy: 0.9898 - main_classifier_top5_acc: 0.9999 - main_classifier_macro_f1score: 0.4573 - auxiliary_classifier_accuracy: 0.9776 - auxiliary_classifier_top5_acc: 0.9995 - auxiliary_classifier_macro_f1score: 0.4325 - val_loss: 2.2327 - val_main_classifier_loss: 1.5803 - val_auxiliary_classifier_loss: 1.6311 - val_main_classifier_accuracy: 0.7559 - val_main_classifier_top5_acc: 0.9357 - val_main_classifier_macro_f1score: 0.3075 - val_auxiliary_classifier_accuracy: 0.7555 - val_auxiliary_classifier_top5_acc: 0.9304 - val_auxiliary_classifier_macro_f1score: 0.2904
# Learning rate:  0.0001
#
# Epoch 00039: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 39/70
# 701/701 [==============================] - ETA: 0s - loss: 1.3122 - main_classifier_loss: 0.9125 - auxiliary_classifier_loss: 0.9993 - main_classifier_accuracy: 0.9909 - main_classifier_top5_acc: 0.9999 - main_classifier_macro_f1score: 0.4593 - auxiliary_classifier_accuracy: 0.9804 - auxiliary_classifier_top5_acc: 0.9996 - auxiliary_classifier_macro_f1score: 0.4344
# Epoch 00039: val_loss did not improve from 2.23244
#
# Epoch 00039: val_main_classifier_accuracy did not improve from 0.76009
# 701/701 [==============================] - 973s 1s/step - loss: 1.3122 - main_classifier_loss: 0.9125 - auxiliary_classifier_loss: 0.9993 - main_classifier_accuracy: 0.9909 - main_classifier_top5_acc: 0.9999 - main_classifier_macro_f1score: 0.4593 - auxiliary_classifier_accuracy: 0.9804 - auxiliary_classifier_top5_acc: 0.9996 - auxiliary_classifier_macro_f1score: 0.4344 - val_loss: 2.2532 - val_main_classifier_loss: 1.6003 - val_auxiliary_classifier_loss: 1.6323 - val_main_classifier_accuracy: 0.7520 - val_main_classifier_top5_acc: 0.9290 - val_main_classifier_macro_f1score: 0.3062 - val_auxiliary_classifier_accuracy: 0.7512 - val_auxiliary_classifier_top5_acc: 0.9330 - val_auxiliary_classifier_macro_f1score: 0.2882
# Learning rate:  0.0001
#
# Epoch 00040: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 40/70
# 701/701 [==============================] - ETA: 0s - loss: 1.3039 - main_classifier_loss: 0.9059 - auxiliary_classifier_loss: 0.9949 - main_classifier_accuracy: 0.9920 - main_classifier_top5_acc: 0.9999 - main_classifier_macro_f1score: 0.4614 - auxiliary_classifier_accuracy: 0.9807 - auxiliary_classifier_top5_acc: 0.9995 - auxiliary_classifier_macro_f1score: 0.4371
# Epoch 00040: val_loss did not improve from 2.23244
#
# Epoch 00040: val_main_classifier_accuracy did not improve from 0.76009
# 701/701 [==============================] - 979s 1s/step - loss: 1.3039 - main_classifier_loss: 0.9059 - auxiliary_classifier_loss: 0.9949 - main_classifier_accuracy: 0.9920 - main_classifier_top5_acc: 0.9999 - main_classifier_macro_f1score: 0.4614 - auxiliary_classifier_accuracy: 0.9807 - auxiliary_classifier_top5_acc: 0.9995 - auxiliary_classifier_macro_f1score: 0.4371 - val_loss: 2.2587 - val_main_classifier_loss: 1.6038 - val_auxiliary_classifier_loss: 1.6372 - val_main_classifier_accuracy: 0.7478 - val_main_classifier_top5_acc: 0.9304 - val_main_classifier_macro_f1score: 0.3085 - val_auxiliary_classifier_accuracy: 0.7492 - val_auxiliary_classifier_top5_acc: 0.9310 - val_auxiliary_classifier_macro_f1score: 0.2883
# Learning rate:  0.0001
#
# Epoch 00041: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 41/70
# 701/701 [==============================] - ETA: 0s - loss: 1.2998 - main_classifier_loss: 0.9033 - auxiliary_classifier_loss: 0.9914 - main_classifier_accuracy: 0.9924 - main_classifier_top5_acc: 1.0000 - main_classifier_macro_f1score: 0.4608 - auxiliary_classifier_accuracy: 0.9808 - auxiliary_classifier_top5_acc: 0.9998 - auxiliary_classifier_macro_f1score: 0.4373
# Epoch 00041: val_loss did not improve from 2.23244
#
# Epoch 00041: val_main_classifier_accuracy did not improve from 0.76009
# 701/701 [==============================] - 972s 1s/step - loss: 1.2998 - main_classifier_loss: 0.9033 - auxiliary_classifier_loss: 0.9914 - main_classifier_accuracy: 0.9924 - main_classifier_top5_acc: 1.0000 - main_classifier_macro_f1score: 0.4608 - auxiliary_classifier_accuracy: 0.9808 - auxiliary_classifier_top5_acc: 0.9998 - auxiliary_classifier_macro_f1score: 0.4373 - val_loss: 2.2359 - val_main_classifier_loss: 1.5871 - val_auxiliary_classifier_loss: 1.6219 - val_main_classifier_accuracy: 0.7545 - val_main_classifier_top5_acc: 0.9330 - val_main_classifier_macro_f1score: 0.3093 - val_auxiliary_classifier_accuracy: 0.7514 - val_auxiliary_classifier_top5_acc: 0.9306 - val_auxiliary_classifier_macro_f1score: 0.2943
# Learning rate:  0.0001
#
# Epoch 00042: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 42/70
# 701/701 [==============================] - ETA: 0s - loss: 1.2947 - main_classifier_loss: 0.8999 - auxiliary_classifier_loss: 0.9870 - main_classifier_accuracy: 0.9930 - main_classifier_top5_acc: 1.0000 - main_classifier_macro_f1score: 0.4621 - auxiliary_classifier_accuracy: 0.9829 - auxiliary_classifier_top5_acc: 0.9996 - auxiliary_classifier_macro_f1score: 0.4376
# Epoch 00042: val_loss did not improve from 2.23244
#
# Epoch 00042: val_main_classifier_accuracy did not improve from 0.76009
# 701/701 [==============================] - 962s 1s/step - loss: 1.2947 - main_classifier_loss: 0.8999 - auxiliary_classifier_loss: 0.9870 - main_classifier_accuracy: 0.9930 - main_classifier_top5_acc: 1.0000 - main_classifier_macro_f1score: 0.4621 - auxiliary_classifier_accuracy: 0.9829 - auxiliary_classifier_top5_acc: 0.9996 - auxiliary_classifier_macro_f1score: 0.4376 - val_loss: 2.2728 - val_main_classifier_loss: 1.6151 - val_auxiliary_classifier_loss: 1.6442 - val_main_classifier_accuracy: 0.7502 - val_main_classifier_top5_acc: 0.9292 - val_main_classifier_macro_f1score: 0.3029 - val_auxiliary_classifier_accuracy: 0.7445 - val_auxiliary_classifier_top5_acc: 0.9280 - val_auxiliary_classifier_macro_f1score: 0.2884
# Learning rate:  0.0001
#
# Epoch 00043: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 43/70
# 701/701 [==============================] - ETA: 0s - loss: 1.2911 - main_classifier_loss: 0.8973 - auxiliary_classifier_loss: 0.9844 - main_classifier_accuracy: 0.9931 - main_classifier_top5_acc: 1.0000 - main_classifier_macro_f1score: 0.4632 - auxiliary_classifier_accuracy: 0.9827 - auxiliary_classifier_top5_acc: 0.9996 - auxiliary_classifier_macro_f1score: 0.4390
# Epoch 00043: val_loss did not improve from 2.23244
#
# Epoch 00043: val_main_classifier_accuracy did not improve from 0.76009
# 701/701 [==============================] - 957s 1s/step - loss: 1.2911 - main_classifier_loss: 0.8973 - auxiliary_classifier_loss: 0.9844 - main_classifier_accuracy: 0.9931 - main_classifier_top5_acc: 1.0000 - main_classifier_macro_f1score: 0.4632 - auxiliary_classifier_accuracy: 0.9827 - auxiliary_classifier_top5_acc: 0.9996 - auxiliary_classifier_macro_f1score: 0.4390 - val_loss: 2.2610 - val_main_classifier_loss: 1.6077 - val_auxiliary_classifier_loss: 1.6333 - val_main_classifier_accuracy: 0.7540 - val_main_classifier_top5_acc: 0.9292 - val_main_classifier_macro_f1score: 0.3045 - val_auxiliary_classifier_accuracy: 0.7490 - val_auxiliary_classifier_top5_acc: 0.9274 - val_auxiliary_classifier_macro_f1score: 0.2871
# Learning rate:  0.0001
#
# Epoch 00044: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 44/70
# 701/701 [==============================] - ETA: 0s - loss: 1.2813 - main_classifier_loss: 0.8906 - auxiliary_classifier_loss: 0.9768 - main_classifier_accuracy: 0.9941 - main_classifier_top5_acc: 0.9999 - main_classifier_macro_f1score: 0.4656 - auxiliary_classifier_accuracy: 0.9845 - auxiliary_classifier_top5_acc: 0.9996 - auxiliary_classifier_macro_f1score: 0.4430
# Epoch 00044: val_loss did not improve from 2.23244
#
# Epoch 00044: val_main_classifier_accuracy did not improve from 0.76009
# 701/701 [==============================] - 956s 1s/step - loss: 1.2813 - main_classifier_loss: 0.8906 - auxiliary_classifier_loss: 0.9768 - main_classifier_accuracy: 0.9941 - main_classifier_top5_acc: 0.9999 - main_classifier_macro_f1score: 0.4656 - auxiliary_classifier_accuracy: 0.9845 - auxiliary_classifier_top5_acc: 0.9996 - auxiliary_classifier_macro_f1score: 0.4430 - val_loss: 2.2934 - val_main_classifier_loss: 1.6351 - val_auxiliary_classifier_loss: 1.6458 - val_main_classifier_accuracy: 0.7431 - val_main_classifier_top5_acc: 0.9262 - val_main_classifier_macro_f1score: 0.3022 - val_auxiliary_classifier_accuracy: 0.7466 - val_auxiliary_classifier_top5_acc: 0.9239 - val_auxiliary_classifier_macro_f1score: 0.2887
# Learning rate:  0.0001
#
# Epoch 00045: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 45/70
# 701/701 [==============================] - ETA: 0s - loss: 1.2825 - main_classifier_loss: 0.8911 - auxiliary_classifier_loss: 0.9786 - main_classifier_accuracy: 0.9937 - main_classifier_top5_acc: 0.9999 - main_classifier_macro_f1score: 0.4640 - auxiliary_classifier_accuracy: 0.9843 - auxiliary_classifier_top5_acc: 0.9997 - auxiliary_classifier_macro_f1score: 0.4415
# Epoch 00045: val_loss did not improve from 2.23244
#
# Epoch 00045: val_main_classifier_accuracy did not improve from 0.76009
# 701/701 [==============================] - 963s 1s/step - loss: 1.2825 - main_classifier_loss: 0.8911 - auxiliary_classifier_loss: 0.9786 - main_classifier_accuracy: 0.9937 - main_classifier_top5_acc: 0.9999 - main_classifier_macro_f1score: 0.4640 - auxiliary_classifier_accuracy: 0.9843 - auxiliary_classifier_top5_acc: 0.9997 - auxiliary_classifier_macro_f1score: 0.4415 - val_loss: 2.2581 - val_main_classifier_loss: 1.6056 - val_auxiliary_classifier_loss: 1.6314 - val_main_classifier_accuracy: 0.7526 - val_main_classifier_top5_acc: 0.9292 - val_main_classifier_macro_f1score: 0.3103 - val_auxiliary_classifier_accuracy: 0.7508 - val_auxiliary_classifier_top5_acc: 0.9286 - val_auxiliary_classifier_macro_f1score: 0.2873
# Learning rate:  0.0001
#
# Epoch 00046: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 46/70
# 701/701 [==============================] - ETA: 0s - loss: 1.2743 - main_classifier_loss: 0.8853 - auxiliary_classifier_loss: 0.9724 - main_classifier_accuracy: 0.9949 - main_classifier_top5_acc: 0.9999 - main_classifier_macro_f1score: 0.4650 - auxiliary_classifier_accuracy: 0.9848 - auxiliary_classifier_top5_acc: 0.9997 - auxiliary_classifier_macro_f1score: 0.4432
# Epoch 00046: val_loss did not improve from 2.23244
#
# Epoch 00046: val_main_classifier_accuracy did not improve from 0.76009
# 701/701 [==============================] - 956s 1s/step - loss: 1.2743 - main_classifier_loss: 0.8853 - auxiliary_classifier_loss: 0.9724 - main_classifier_accuracy: 0.9949 - main_classifier_top5_acc: 0.9999 - main_classifier_macro_f1score: 0.4650 - auxiliary_classifier_accuracy: 0.9848 - auxiliary_classifier_top5_acc: 0.9997 - auxiliary_classifier_macro_f1score: 0.4432 - val_loss: 2.2859 - val_main_classifier_loss: 1.6296 - val_auxiliary_classifier_loss: 1.6407 - val_main_classifier_accuracy: 0.7441 - val_main_classifier_top5_acc: 0.9284 - val_main_classifier_macro_f1score: 0.2993 - val_auxiliary_classifier_accuracy: 0.7478 - val_auxiliary_classifier_top5_acc: 0.9246 - val_auxiliary_classifier_macro_f1score: 0.2907
# Learning rate:  0.0001
#
# Epoch 00047: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 47/70
# 132/701 [====>.........................] - ETA: 12:37 - loss: 1.2743 - main_classifier_loss: 0.8868 - auxiliary_classifier_loss: 0.9688 - main_classifier_accuracy: 0.9946 - main_classifier_top5_acc: 0.9999 - main_classifier_macro_f1score: 0.4663 - auxiliary_classifier_accuracy: 0.9856 - auxiliary_classifier_top5_acc: 0.9998 - auxiliary_classifier_macro_f1score: 0.4458

# %%
# colab pro가 최대 24시간 돌아가므로, 그 한계로 인해 두번 나눠서 학습을봄.

# %%
# 참고 : https://github.com/OverLordGoldDragon/keras-adamw

import sys
sys.path.append('/content/drive/My Drive/Colab Notebooks/Paper')
import utils
import optimizers_v2
from utils import get_weight_decays, fill_dict_in_order
from utils import reset_seeds, K_eval
from optimizers_v2 import AdamW, NadamW, SGDW

# %%
# top-5 accuracy 출력
import functools
top5_acc = functools.partial(ks.metrics.top_k_categorical_accuracy, k=5)
top5_acc.__name__ = 'top5_acc'

# %%
# def lr_schedule(epoch):
#     init_lr = 1e-4
#     k = 0.04
#     lr = init_lr * np.exp(-k*epoch)
#     print('Learning rate: ', lr)
#     return lr

def lr_schedule(epoch):
    lr = 1e-4
    if epoch < 25:
        lr = lr
    else :
        lr = lr * 0.1
    print('Learning rate: ', lr)
    return lr

# %%
os.makedirs(os.path.join(dir,'model_output',number,'SUB',model.name), exist_ok=True) # 모델을 위에서 정의해야함

# %%
#optimizer = SGDW(model=model, use_cosine_annealing=False, total_iterations = len(x_train) // batch_sizes, nesterov=True, momentum=0.9)
optimizer = AdamW(model=model, use_cosine_annealing=False, total_iterations = len(x_train) // batch_sizes)
#optimizer = Adam()
filepath =  os.path.join(dir,'model_output',number,'SUB',model.name,'{epoch:03d}.h5')

callbacks_list = [ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_weights_only=False, save_best_only=True, mode='min'),
                  ModelCheckpoint(filepath, monitor='val_main_classifier_accuracy', verbose=1, save_weights_only=False, save_best_only=True, mode='max'),
                  #ReduceLROnPlateau(monitor='val_loss',patience=3,factor=0.1,min_lr=1e-5),
                  LearningRateScheduler(lr_schedule,verbose=1)
                  ]

model.compile(optimizer, loss={'main_classifier' : smoothed_categorical_crossentropy, 'auxiliary_classifier' : smoothed_categorical_crossentropy},
                loss_weights={'main_classifier' : 1.0, 'auxiliary_classifier' : 0.4}, metrics=['accuracy',top5_acc,macro_f1score])

# %%
model=load_model(os.path.join(dir,'model_output',number,'Inception_v3','035.h5'),custom_objects={"macro_f1score": macro_f1score, "top5_acc":top5_acc, "smoothed_categorical_crossentropy":smoothed_categorical_crossentropy, "AdamW":AdamW})

# %%
######## flow_from_directory
#history = model.fit_generator(generate_train_for_three(), steps_per_epoch=int(len(x_train)/batch_sizes),  validation_data = generate_v alid_for_three(), epochs=epochs , verbose=1 , callbacks = callbacks_list,validation_steps=int(len(x_valid)/batch_sizes))
history = model.fit(generate_train_for_two(), steps_per_epoch=int(len(x_train)/batch_sizes),  validation_data = generate_valid_for_two(), epochs=35 , verbose=1 , callbacks = callbacks_list , validation_steps=int(len(x_valid)/batch_sizes))
# Out:
# Found 44923 images belonging to 100 classes.
# Learning rate:  0.0001
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 1/35
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_1/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_2/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_3/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_4/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_5/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_6/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_7/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_9/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_8/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_10/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_11/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_12/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_13/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_14/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_16/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_15/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_17/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_18/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_19/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_20/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_21/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_23/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_22/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_24/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_25/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_26/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_27/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_28/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_30/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_29/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_31/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_32/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_33/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_34/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_37/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_35/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_38/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_36/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_39/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_40/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_41/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_42/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_43/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_44/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_47/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_45/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_48/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_46/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_49/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_50/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_51/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_52/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_53/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_54/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_57/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_55/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_58/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_56/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_59/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_60/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_61/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_62/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_63/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_64/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_67/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_65/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_68/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_66/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_69/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_70/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_71/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_72/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_73/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_74/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_77/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_75/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_78/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_76/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_79/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_80/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_81/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_82/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_83/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_85/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_84/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_86/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_87/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_88/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_91/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_89/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_90/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_92/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_93/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_94/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_95/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_96/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_97/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_100/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_98/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_99/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_101/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_102/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_103/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_104/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_105/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for conv2d_106/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for dense/kernel:0
# 0.0(L1), 7.553896104795775e-05(L2) weight decay set for auxiliary_classifier/kernel:0
# 701/701 [==============================] - ETA: 0s - loss: 1.3430 - main_classifier_loss: 0.9349 - auxiliary_classifier_loss: 1.0201 - main_classifier_accuracy: 0.9861 - main_classifier_top5_acc: 0.9998 - main_classifier_macro_f1score: 0.4534 - auxiliary_classifier_accuracy: 0.9752 - auxiliary_classifier_top5_acc: 0.9992 - auxiliary_classifier_macro_f1score: 0.4281 Found 5077 images belonging to 100 classes.
#
# Epoch 00001: val_loss improved from inf to 2.23442, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SUB/Inception_v3/001.h5
#
# Epoch 00001: val_main_classifier_accuracy improved from -inf to 0.75277, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SUB/Inception_v3/001.h5
# 701/701 [==============================] - 26224s 37s/step - loss: 1.3430 - main_classifier_loss: 0.9349 - auxiliary_classifier_loss: 1.0201 - main_classifier_accuracy: 0.9861 - main_classifier_top5_acc: 0.9998 - main_classifier_macro_f1score: 0.4534 - auxiliary_classifier_accuracy: 0.9752 - auxiliary_classifier_top5_acc: 0.9992 - auxiliary_classifier_macro_f1score: 0.4281 - val_loss: 2.2344 - val_main_classifier_loss: 1.5797 - val_auxiliary_classifier_loss: 1.6369 - val_main_classifier_accuracy: 0.7528 - val_main_classifier_top5_acc: 0.9363 - val_main_classifier_macro_f1score: 0.3109 - val_auxiliary_classifier_accuracy: 0.7538 - val_auxiliary_classifier_top5_acc: 0.9318 - val_auxiliary_classifier_macro_f1score: 0.2919
# Learning rate:  0.0001
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 2/35
# 701/701 [==============================] - ETA: 0s - loss: 1.3328 - main_classifier_loss: 0.9277 - auxiliary_classifier_loss: 1.0127 - main_classifier_accuracy: 0.9881 - main_classifier_top5_acc: 0.9998 - main_classifier_macro_f1score: 0.4543 - auxiliary_classifier_accuracy: 0.9761 - auxiliary_classifier_top5_acc: 0.9995 - auxiliary_classifier_macro_f1score: 0.4293
# Epoch 00002: val_loss did not improve from 2.23442
#
# Epoch 00002: val_main_classifier_accuracy improved from 0.75277 to 0.75850, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SUB/Inception_v3/002.h5
# 701/701 [==============================] - 1085s 2s/step - loss: 1.3328 - main_classifier_loss: 0.9277 - auxiliary_classifier_loss: 1.0127 - main_classifier_accuracy: 0.9881 - main_classifier_top5_acc: 0.9998 - main_classifier_macro_f1score: 0.4543 - auxiliary_classifier_accuracy: 0.9761 - auxiliary_classifier_top5_acc: 0.9995 - auxiliary_classifier_macro_f1score: 0.4293 - val_loss: 2.2408 - val_main_classifier_loss: 1.5879 - val_auxiliary_classifier_loss: 1.6322 - val_main_classifier_accuracy: 0.7585 - val_main_classifier_top5_acc: 0.9322 - val_main_classifier_macro_f1score: 0.3103 - val_auxiliary_classifier_accuracy: 0.7514 - val_auxiliary_classifier_top5_acc: 0.9294 - val_auxiliary_classifier_macro_f1score: 0.2886
# Learning rate:  0.0001
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 3/35
# 701/701 [==============================] - ETA: 0s - loss: 1.3204 - main_classifier_loss: 0.9187 - auxiliary_classifier_loss: 1.0042 - main_classifier_accuracy: 0.9895 - main_classifier_top5_acc: 0.9999 - main_classifier_macro_f1score: 0.4591 - auxiliary_classifier_accuracy: 0.9785 - auxiliary_classifier_top5_acc: 0.9995 - auxiliary_classifier_macro_f1score: 0.4340
# Epoch 00003: val_loss did not improve from 2.23442
#
# Epoch 00003: val_main_classifier_accuracy did not improve from 0.75850
# 701/701 [==============================] - 1164s 2s/step - loss: 1.3204 - main_classifier_loss: 0.9187 - auxiliary_classifier_loss: 1.0042 - main_classifier_accuracy: 0.9895 - main_classifier_top5_acc: 0.9999 - main_classifier_macro_f1score: 0.4591 - auxiliary_classifier_accuracy: 0.9785 - auxiliary_classifier_top5_acc: 0.9995 - auxiliary_classifier_macro_f1score: 0.4340 - val_loss: 2.2508 - val_main_classifier_loss: 1.5944 - val_auxiliary_classifier_loss: 1.6411 - val_main_classifier_accuracy: 0.7585 - val_main_classifier_top5_acc: 0.9333 - val_main_classifier_macro_f1score: 0.3126 - val_auxiliary_classifier_accuracy: 0.7474 - val_auxiliary_classifier_top5_acc: 0.9296 - val_auxiliary_classifier_macro_f1score: 0.2928
# Learning rate:  0.0001
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 4/35
# 701/701 [==============================] - ETA: 0s - loss: 1.3118 - main_classifier_loss: 0.9118 - auxiliary_classifier_loss: 0.9998 - main_classifier_accuracy: 0.9905 - main_classifier_top5_acc: 0.9999 - main_classifier_macro_f1score: 0.4597 - auxiliary_classifier_accuracy: 0.9794 - auxiliary_classifier_top5_acc: 0.9996 - auxiliary_classifier_macro_f1score: 0.4347
# Epoch 00004: val_loss did not improve from 2.23442
#
# Epoch 00004: val_main_classifier_accuracy did not improve from 0.75850
# 701/701 [==============================] - 1166s 2s/step - loss: 1.3118 - main_classifier_loss: 0.9118 - auxiliary_classifier_loss: 0.9998 - main_classifier_accuracy: 0.9905 - main_classifier_top5_acc: 0.9999 - main_classifier_macro_f1score: 0.4597 - auxiliary_classifier_accuracy: 0.9794 - auxiliary_classifier_top5_acc: 0.9996 - auxiliary_classifier_macro_f1score: 0.4347 - val_loss: 2.2479 - val_main_classifier_loss: 1.5959 - val_auxiliary_classifier_loss: 1.6299 - val_main_classifier_accuracy: 0.7526 - val_main_classifier_top5_acc: 0.9298 - val_main_classifier_macro_f1score: 0.3101 - val_auxiliary_classifier_accuracy: 0.7542 - val_auxiliary_classifier_top5_acc: 0.9300 - val_auxiliary_classifier_macro_f1score: 0.2938
# Learning rate:  0.0001
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 5/35
# 701/701 [==============================] - ETA: 0s - loss: 1.3035 - main_classifier_loss: 0.9057 - auxiliary_classifier_loss: 0.9945 - main_classifier_accuracy: 0.9921 - main_classifier_top5_acc: 0.9999 - main_classifier_macro_f1score: 0.4595 - auxiliary_classifier_accuracy: 0.9813 - auxiliary_classifier_top5_acc: 0.9995 - auxiliary_classifier_macro_f1score: 0.4360
# Epoch 00005: val_loss did not improve from 2.23442
#
# Epoch 00005: val_main_classifier_accuracy did not improve from 0.75850
# 701/701 [==============================] - 1151s 2s/step - loss: 1.3035 - main_classifier_loss: 0.9057 - auxiliary_classifier_loss: 0.9945 - main_classifier_accuracy: 0.9921 - main_classifier_top5_acc: 0.9999 - main_classifier_macro_f1score: 0.4595 - auxiliary_classifier_accuracy: 0.9813 - auxiliary_classifier_top5_acc: 0.9995 - auxiliary_classifier_macro_f1score: 0.4360 - val_loss: 2.2668 - val_main_classifier_loss: 1.6141 - val_auxiliary_classifier_loss: 1.6318 - val_main_classifier_accuracy: 0.7514 - val_main_classifier_top5_acc: 0.9308 - val_main_classifier_macro_f1score: 0.3020 - val_auxiliary_classifier_accuracy: 0.7510 - val_auxiliary_classifier_top5_acc: 0.9318 - val_auxiliary_classifier_macro_f1score: 0.2860
# Learning rate:  0.0001
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 6/35
# 701/701 [==============================] - ETA: 0s - loss: 1.2979 - main_classifier_loss: 0.9020 - auxiliary_classifier_loss: 0.9898 - main_classifier_accuracy: 0.9928 - main_classifier_top5_acc: 1.0000 - main_classifier_macro_f1score: 0.4612 - auxiliary_classifier_accuracy: 0.9818 - auxiliary_classifier_top5_acc: 0.9995 - auxiliary_classifier_macro_f1score: 0.4382
# Epoch 00006: val_loss did not improve from 2.23442
#
# Epoch 00006: val_main_classifier_accuracy improved from 0.75850 to 0.75890, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SUB/Inception_v3/006.h5
# 701/701 [==============================] - 1148s 2s/step - loss: 1.2979 - main_classifier_loss: 0.9020 - auxiliary_classifier_loss: 0.9898 - main_classifier_accuracy: 0.9928 - main_classifier_top5_acc: 1.0000 - main_classifier_macro_f1score: 0.4612 - auxiliary_classifier_accuracy: 0.9818 - auxiliary_classifier_top5_acc: 0.9995 - auxiliary_classifier_macro_f1score: 0.4382 - val_loss: 2.2502 - val_main_classifier_loss: 1.5982 - val_auxiliary_classifier_loss: 1.6300 - val_main_classifier_accuracy: 0.7589 - val_main_classifier_top5_acc: 0.9300 - val_main_classifier_macro_f1score: 0.3024 - val_auxiliary_classifier_accuracy: 0.7540 - val_auxiliary_classifier_top5_acc: 0.9298 - val_auxiliary_classifier_macro_f1score: 0.2914
# Learning rate:  0.0001
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 7/35
# 701/701 [==============================] - ETA: 0s - loss: 1.2914 - main_classifier_loss: 0.8978 - auxiliary_classifier_loss: 0.9840 - main_classifier_accuracy: 0.9927 - main_classifier_top5_acc: 1.0000 - main_classifier_macro_f1score: 0.4629 - auxiliary_classifier_accuracy: 0.9829 - auxiliary_classifier_top5_acc: 0.9997 - auxiliary_classifier_macro_f1score: 0.4402
# Epoch 00007: val_loss did not improve from 2.23442
#
# Epoch 00007: val_main_classifier_accuracy did not improve from 0.75890
# 701/701 [==============================] - 1138s 2s/step - loss: 1.2914 - main_classifier_loss: 0.8978 - auxiliary_classifier_loss: 0.9840 - main_classifier_accuracy: 0.9927 - main_classifier_top5_acc: 1.0000 - main_classifier_macro_f1score: 0.4629 - auxiliary_classifier_accuracy: 0.9829 - auxiliary_classifier_top5_acc: 0.9997 - auxiliary_classifier_macro_f1score: 0.4402 - val_loss: 2.2743 - val_main_classifier_loss: 1.6194 - val_auxiliary_classifier_loss: 1.6374 - val_main_classifier_accuracy: 0.7445 - val_main_classifier_top5_acc: 0.9274 - val_main_classifier_macro_f1score: 0.3007 - val_auxiliary_classifier_accuracy: 0.7466 - val_auxiliary_classifier_top5_acc: 0.9292 - val_auxiliary_classifier_macro_f1score: 0.2887
# Learning rate:  0.0001
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 8/35
# 701/701 [==============================] - ETA: 0s - loss: 1.2836 - main_classifier_loss: 0.8919 - auxiliary_classifier_loss: 0.9792 - main_classifier_accuracy: 0.9944 - main_classifier_top5_acc: 1.0000 - main_classifier_macro_f1score: 0.4628 - auxiliary_classifier_accuracy: 0.9850 - auxiliary_classifier_top5_acc: 0.9998 - auxiliary_classifier_macro_f1score: 0.4398
# Epoch 00008: val_loss did not improve from 2.23442
#
# Epoch 00008: val_main_classifier_accuracy did not improve from 0.75890
# 701/701 [==============================] - 1062s 2s/step - loss: 1.2836 - main_classifier_loss: 0.8919 - auxiliary_classifier_loss: 0.9792 - main_classifier_accuracy: 0.9944 - main_classifier_top5_acc: 1.0000 - main_classifier_macro_f1score: 0.4628 - auxiliary_classifier_accuracy: 0.9850 - auxiliary_classifier_top5_acc: 0.9998 - auxiliary_classifier_macro_f1score: 0.4398 - val_loss: 2.2915 - val_main_classifier_loss: 1.6261 - val_auxiliary_classifier_loss: 1.6637 - val_main_classifier_accuracy: 0.7453 - val_main_classifier_top5_acc: 0.9260 - val_main_classifier_macro_f1score: 0.3008 - val_auxiliary_classifier_accuracy: 0.7387 - val_auxiliary_classifier_top5_acc: 0.9233 - val_auxiliary_classifier_macro_f1score: 0.2849
# Learning rate:  0.0001
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 9/35
# 701/701 [==============================] - ETA: 0s - loss: 1.2823 - main_classifier_loss: 0.8909 - auxiliary_classifier_loss: 0.9785 - main_classifier_accuracy: 0.9942 - main_classifier_top5_acc: 1.0000 - main_classifier_macro_f1score: 0.4644 - auxiliary_classifier_accuracy: 0.9842 - auxiliary_classifier_top5_acc: 0.9998 - auxiliary_classifier_macro_f1score: 0.4409
# Epoch 00009: val_loss did not improve from 2.23442
#
# Epoch 00009: val_main_classifier_accuracy did not improve from 0.75890
# 701/701 [==============================] - 1051s 1s/step - loss: 1.2823 - main_classifier_loss: 0.8909 - auxiliary_classifier_loss: 0.9785 - main_classifier_accuracy: 0.9942 - main_classifier_top5_acc: 1.0000 - main_classifier_macro_f1score: 0.4644 - auxiliary_classifier_accuracy: 0.9842 - auxiliary_classifier_top5_acc: 0.9998 - auxiliary_classifier_macro_f1score: 0.4409 - val_loss: 2.2639 - val_main_classifier_loss: 1.6126 - val_auxiliary_classifier_loss: 1.6283 - val_main_classifier_accuracy: 0.7472 - val_main_classifier_top5_acc: 0.9290 - val_main_classifier_macro_f1score: 0.3056 - val_auxiliary_classifier_accuracy: 0.7496 - val_auxiliary_classifier_top5_acc: 0.9294 - val_auxiliary_classifier_macro_f1score: 0.2915
# Learning rate:  0.0001
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 10/35
# 701/701 [==============================] - ETA: 0s - loss: 1.2782 - main_classifier_loss: 0.8886 - auxiliary_classifier_loss: 0.9739 - main_classifier_accuracy: 0.9940 - main_classifier_top5_acc: 1.0000 - main_classifier_macro_f1score: 0.4656 - auxiliary_classifier_accuracy: 0.9849 - auxiliary_classifier_top5_acc: 0.9998 - auxiliary_classifier_macro_f1score: 0.4439
# Epoch 00010: val_loss did not improve from 2.23442
#
# Epoch 00010: val_main_classifier_accuracy did not improve from 0.75890
# 701/701 [==============================] - 1110s 2s/step - loss: 1.2782 - main_classifier_loss: 0.8886 - auxiliary_classifier_loss: 0.9739 - main_classifier_accuracy: 0.9940 - main_classifier_top5_acc: 1.0000 - main_classifier_macro_f1score: 0.4656 - auxiliary_classifier_accuracy: 0.9849 - auxiliary_classifier_top5_acc: 0.9998 - auxiliary_classifier_macro_f1score: 0.4439 - val_loss: 2.3064 - val_main_classifier_loss: 1.6436 - val_auxiliary_classifier_loss: 1.6572 - val_main_classifier_accuracy: 0.7377 - val_main_classifier_top5_acc: 0.9239 - val_main_classifier_macro_f1score: 0.2993 - val_auxiliary_classifier_accuracy: 0.7411 - val_auxiliary_classifier_top5_acc: 0.9246 - val_auxiliary_classifier_macro_f1score: 0.2890
# Learning rate:  0.0001
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 11/35
# 701/701 [==============================] - ETA: 0s - loss: 1.2762 - main_classifier_loss: 0.8873 - auxiliary_classifier_loss: 0.9721 - main_classifier_accuracy: 0.9938 - main_classifier_top5_acc: 1.0000 - main_classifier_macro_f1score: 0.4636 - auxiliary_classifier_accuracy: 0.9859 - auxiliary_classifier_top5_acc: 0.9998 - auxiliary_classifier_macro_f1score: 0.4429
# Epoch 00011: val_loss did not improve from 2.23442
#
# Epoch 00011: val_main_classifier_accuracy did not improve from 0.75890
# 701/701 [==============================] - 1127s 2s/step - loss: 1.2762 - main_classifier_loss: 0.8873 - auxiliary_classifier_loss: 0.9721 - main_classifier_accuracy: 0.9938 - main_classifier_top5_acc: 1.0000 - main_classifier_macro_f1score: 0.4636 - auxiliary_classifier_accuracy: 0.9859 - auxiliary_classifier_top5_acc: 0.9998 - auxiliary_classifier_macro_f1score: 0.4429 - val_loss: 2.2664 - val_main_classifier_loss: 1.6116 - val_auxiliary_classifier_loss: 1.6370 - val_main_classifier_accuracy: 0.7518 - val_main_classifier_top5_acc: 0.9252 - val_main_classifier_macro_f1score: 0.3087 - val_auxiliary_classifier_accuracy: 0.7474 - val_auxiliary_classifier_top5_acc: 0.9266 - val_auxiliary_classifier_macro_f1score: 0.2923
# Learning rate:  0.0001
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 12/35
# 701/701 [==============================] - ETA: 0s - loss: 1.2714 - main_classifier_loss: 0.8844 - auxiliary_classifier_loss: 0.9674 - main_classifier_accuracy: 0.9944 - main_classifier_top5_acc: 0.9999 - main_classifier_macro_f1score: 0.4625 - auxiliary_classifier_accuracy: 0.9860 - auxiliary_classifier_top5_acc: 0.9999 - auxiliary_classifier_macro_f1score: 0.4418
# Epoch 00012: val_loss did not improve from 2.23442
#
# Epoch 00012: val_main_classifier_accuracy did not improve from 0.75890
# 701/701 [==============================] - 1116s 2s/step - loss: 1.2714 - main_classifier_loss: 0.8844 - auxiliary_classifier_loss: 0.9674 - main_classifier_accuracy: 0.9944 - main_classifier_top5_acc: 0.9999 - main_classifier_macro_f1score: 0.4625 - auxiliary_classifier_accuracy: 0.9860 - auxiliary_classifier_top5_acc: 0.9999 - auxiliary_classifier_macro_f1score: 0.4418 - val_loss: 2.2912 - val_main_classifier_loss: 1.6312 - val_auxiliary_classifier_loss: 1.6500 - val_main_classifier_accuracy: 0.7482 - val_main_classifier_top5_acc: 0.9252 - val_main_classifier_macro_f1score: 0.3046 - val_auxiliary_classifier_accuracy: 0.7488 - val_auxiliary_classifier_top5_acc: 0.9272 - val_auxiliary_classifier_macro_f1score: 0.2878
# Learning rate:  0.0001
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 13/35
# 701/701 [==============================] - ETA: 0s - loss: 1.2679 - main_classifier_loss: 0.8820 - auxiliary_classifier_loss: 0.9648 - main_classifier_accuracy: 0.9944 - main_classifier_top5_acc: 1.0000 - main_classifier_macro_f1score: 0.4666 - auxiliary_classifier_accuracy: 0.9868 - auxiliary_classifier_top5_acc: 0.9997 - auxiliary_classifier_macro_f1score: 0.4465
# Epoch 00013: val_loss did not improve from 2.23442
#
# Epoch 00013: val_main_classifier_accuracy did not improve from 0.75890
# 701/701 [==============================] - 1086s 2s/step - loss: 1.2679 - main_classifier_loss: 0.8820 - auxiliary_classifier_loss: 0.9648 - main_classifier_accuracy: 0.9944 - main_classifier_top5_acc: 1.0000 - main_classifier_macro_f1score: 0.4666 - auxiliary_classifier_accuracy: 0.9868 - auxiliary_classifier_top5_acc: 0.9997 - auxiliary_classifier_macro_f1score: 0.4465 - val_loss: 2.3049 - val_main_classifier_loss: 1.6410 - val_auxiliary_classifier_loss: 1.6597 - val_main_classifier_accuracy: 0.7451 - val_main_classifier_top5_acc: 0.9241 - val_main_classifier_macro_f1score: 0.3029 - val_auxiliary_classifier_accuracy: 0.7433 - val_auxiliary_classifier_top5_acc: 0.9233 - val_auxiliary_classifier_macro_f1score: 0.2899
# Learning rate:  0.0001
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 14/35
# 701/701 [==============================] - ETA: 0s - loss: 1.2660 - main_classifier_loss: 0.8807 - auxiliary_classifier_loss: 0.9631 - main_classifier_accuracy: 0.9942 - main_classifier_top5_acc: 1.0000 - main_classifier_macro_f1score: 0.4644 - auxiliary_classifier_accuracy: 0.9859 - auxiliary_classifier_top5_acc: 0.9998 - auxiliary_classifier_macro_f1score: 0.4459
# Epoch 00014: val_loss did not improve from 2.23442
#
# Epoch 00014: val_main_classifier_accuracy did not improve from 0.75890
# 701/701 [==============================] - 1060s 2s/step - loss: 1.2660 - main_classifier_loss: 0.8807 - auxiliary_classifier_loss: 0.9631 - main_classifier_accuracy: 0.9942 - main_classifier_top5_acc: 1.0000 - main_classifier_macro_f1score: 0.4644 - auxiliary_classifier_accuracy: 0.9859 - auxiliary_classifier_top5_acc: 0.9998 - auxiliary_classifier_macro_f1score: 0.4459 - val_loss: 2.2787 - val_main_classifier_loss: 1.6196 - val_auxiliary_classifier_loss: 1.6477 - val_main_classifier_accuracy: 0.7504 - val_main_classifier_top5_acc: 0.9280 - val_main_classifier_macro_f1score: 0.3067 - val_auxiliary_classifier_accuracy: 0.7417 - val_auxiliary_classifier_top5_acc: 0.9252 - val_auxiliary_classifier_macro_f1score: 0.2909
# Learning rate:  0.0001
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 15/35
# 701/701 [==============================] - ETA: 0s - loss: 1.2820 - main_classifier_loss: 0.8921 - auxiliary_classifier_loss: 0.9749 - main_classifier_accuracy: 0.9921 - main_classifier_top5_acc: 0.9999 - main_classifier_macro_f1score: 0.4605 - auxiliary_classifier_accuracy: 0.9833 - auxiliary_classifier_top5_acc: 0.9995 - auxiliary_classifier_macro_f1score: 0.4392
# Epoch 00015: val_loss did not improve from 2.23442
#
# Epoch 00015: val_main_classifier_accuracy did not improve from 0.75890
# 701/701 [==============================] - 1052s 2s/step - loss: 1.2820 - main_classifier_loss: 0.8921 - auxiliary_classifier_loss: 0.9749 - main_classifier_accuracy: 0.9921 - main_classifier_top5_acc: 0.9999 - main_classifier_macro_f1score: 0.4605 - auxiliary_classifier_accuracy: 0.9833 - auxiliary_classifier_top5_acc: 0.9995 - auxiliary_classifier_macro_f1score: 0.4392 - val_loss: 2.2879 - val_main_classifier_loss: 1.6330 - val_auxiliary_classifier_loss: 1.6371 - val_main_classifier_accuracy: 0.7433 - val_main_classifier_top5_acc: 0.9242 - val_main_classifier_macro_f1score: 0.3069 - val_auxiliary_classifier_accuracy: 0.7419 - val_auxiliary_classifier_top5_acc: 0.9272 - val_auxiliary_classifier_macro_f1score: 0.2970
# Learning rate:  0.0001
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 16/35
# 701/701 [==============================] - ETA: 0s - loss: 1.2610 - main_classifier_loss: 0.8776 - auxiliary_classifier_loss: 0.9583 - main_classifier_accuracy: 0.9947 - main_classifier_top5_acc: 1.0000 - main_classifier_macro_f1score: 0.4662 - auxiliary_classifier_accuracy: 0.9872 - auxiliary_classifier_top5_acc: 0.9998 - auxiliary_classifier_macro_f1score: 0.4480
# Epoch 00016: val_loss did not improve from 2.23442
#
# Epoch 00016: val_main_classifier_accuracy did not improve from 0.75890
# 701/701 [==============================] - 1035s 1s/step - loss: 1.2610 - main_classifier_loss: 0.8776 - auxiliary_classifier_loss: 0.9583 - main_classifier_accuracy: 0.9947 - main_classifier_top5_acc: 1.0000 - main_classifier_macro_f1score: 0.4662 - auxiliary_classifier_accuracy: 0.9872 - auxiliary_classifier_top5_acc: 0.9998 - auxiliary_classifier_macro_f1score: 0.4480 - val_loss: 2.3012 - val_main_classifier_loss: 1.6405 - val_auxiliary_classifier_loss: 1.6518 - val_main_classifier_accuracy: 0.7427 - val_main_classifier_top5_acc: 0.9201 - val_main_classifier_macro_f1score: 0.3029 - val_auxiliary_classifier_accuracy: 0.7443 - val_auxiliary_classifier_top5_acc: 0.9246 - val_auxiliary_classifier_macro_f1score: 0.2882
# Learning rate:  0.0001
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 17/35
# 701/701 [==============================] - ETA: 0s - loss: 1.2621 - main_classifier_loss: 0.8785 - auxiliary_classifier_loss: 0.9591 - main_classifier_accuracy: 0.9946 - main_classifier_top5_acc: 1.0000 - main_classifier_macro_f1score: 0.4631 - auxiliary_classifier_accuracy: 0.9874 - auxiliary_classifier_top5_acc: 0.9998 - auxiliary_classifier_macro_f1score: 0.4440
# Epoch 00017: val_loss did not improve from 2.23442
#
# Epoch 00017: val_main_classifier_accuracy did not improve from 0.75890
# 701/701 [==============================] - 1042s 1s/step - loss: 1.2621 - main_classifier_loss: 0.8785 - auxiliary_classifier_loss: 0.9591 - main_classifier_accuracy: 0.9946 - main_classifier_top5_acc: 1.0000 - main_classifier_macro_f1score: 0.4631 - auxiliary_classifier_accuracy: 0.9874 - auxiliary_classifier_top5_acc: 0.9998 - auxiliary_classifier_macro_f1score: 0.4440 - val_loss: 2.3633 - val_main_classifier_loss: 1.6907 - val_auxiliary_classifier_loss: 1.6815 - val_main_classifier_accuracy: 0.7290 - val_main_classifier_top5_acc: 0.9152 - val_main_classifier_macro_f1score: 0.2929 - val_auxiliary_classifier_accuracy: 0.7340 - val_auxiliary_classifier_top5_acc: 0.9155 - val_auxiliary_classifier_macro_f1score: 0.2874
# Learning rate:  0.0001
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 18/35
# 701/701 [==============================] - ETA: 0s - loss: 1.2650 - main_classifier_loss: 0.8809 - auxiliary_classifier_loss: 0.9603 - main_classifier_accuracy: 0.9936 - main_classifier_top5_acc: 1.0000 - main_classifier_macro_f1score: 0.4645 - auxiliary_classifier_accuracy: 0.9874 - auxiliary_classifier_top5_acc: 0.9997 - auxiliary_classifier_macro_f1score: 0.4459
# Epoch 00018: val_loss did not improve from 2.23442
#
# Epoch 00018: val_main_classifier_accuracy did not improve from 0.75890
# 701/701 [==============================] - 1060s 2s/step - loss: 1.2650 - main_classifier_loss: 0.8809 - auxiliary_classifier_loss: 0.9603 - main_classifier_accuracy: 0.9936 - main_classifier_top5_acc: 1.0000 - main_classifier_macro_f1score: 0.4645 - auxiliary_classifier_accuracy: 0.9874 - auxiliary_classifier_top5_acc: 0.9997 - auxiliary_classifier_macro_f1score: 0.4459 - val_loss: 2.3078 - val_main_classifier_loss: 1.6422 - val_auxiliary_classifier_loss: 1.6640 - val_main_classifier_accuracy: 0.7364 - val_main_classifier_top5_acc: 0.9252 - val_main_classifier_macro_f1score: 0.3055 - val_auxiliary_classifier_accuracy: 0.7375 - val_auxiliary_classifier_top5_acc: 0.9209 - val_auxiliary_classifier_macro_f1score: 0.2846
# Learning rate:  0.0001
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 19/35
# 701/701 [==============================] - ETA: 0s - loss: 1.2676 - main_classifier_loss: 0.8829 - auxiliary_classifier_loss: 0.9617 - main_classifier_accuracy: 0.9927 - main_classifier_top5_acc: 1.0000 - main_classifier_macro_f1score: 0.4639 - auxiliary_classifier_accuracy: 0.9854 - auxiliary_classifier_top5_acc: 0.9998 - auxiliary_classifier_macro_f1score: 0.4462
# Epoch 00019: val_loss did not improve from 2.23442
#
# Epoch 00019: val_main_classifier_accuracy did not improve from 0.75890
# 701/701 [==============================] - 1051s 1s/step - loss: 1.2676 - main_classifier_loss: 0.8829 - auxiliary_classifier_loss: 0.9617 - main_classifier_accuracy: 0.9927 - main_classifier_top5_acc: 1.0000 - main_classifier_macro_f1score: 0.4639 - auxiliary_classifier_accuracy: 0.9854 - auxiliary_classifier_top5_acc: 0.9998 - auxiliary_classifier_macro_f1score: 0.4462 - val_loss: 2.3940 - val_main_classifier_loss: 1.7100 - val_auxiliary_classifier_loss: 1.7098 - val_main_classifier_accuracy: 0.7245 - val_main_classifier_top5_acc: 0.9142 - val_main_classifier_macro_f1score: 0.2968 - val_auxiliary_classifier_accuracy: 0.7263 - val_auxiliary_classifier_top5_acc: 0.9165 - val_auxiliary_classifier_macro_f1score: 0.2731
# Learning rate:  0.0001
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 20/35
# 701/701 [==============================] - ETA: 0s - loss: 1.2661 - main_classifier_loss: 0.8817 - auxiliary_classifier_loss: 0.9611 - main_classifier_accuracy: 0.9930 - main_classifier_top5_acc: 0.9999 - main_classifier_macro_f1score: 0.4645 - auxiliary_classifier_accuracy: 0.9862 - auxiliary_classifier_top5_acc: 0.9998 - auxiliary_classifier_macro_f1score: 0.4469
# Epoch 00020: val_loss did not improve from 2.23442
#
# Epoch 00020: val_main_classifier_accuracy did not improve from 0.75890
# 701/701 [==============================] - 1104s 2s/step - loss: 1.2661 - main_classifier_loss: 0.8817 - auxiliary_classifier_loss: 0.9611 - main_classifier_accuracy: 0.9930 - main_classifier_top5_acc: 0.9999 - main_classifier_macro_f1score: 0.4645 - auxiliary_classifier_accuracy: 0.9862 - auxiliary_classifier_top5_acc: 0.9998 - auxiliary_classifier_macro_f1score: 0.4469 - val_loss: 2.3472 - val_main_classifier_loss: 1.6752 - val_auxiliary_classifier_loss: 1.6801 - val_main_classifier_accuracy: 0.7310 - val_main_classifier_top5_acc: 0.9217 - val_main_classifier_macro_f1score: 0.2996 - val_auxiliary_classifier_accuracy: 0.7300 - val_auxiliary_classifier_top5_acc: 0.9207 - val_auxiliary_classifier_macro_f1score: 0.2822
# Learning rate:  0.0001
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 21/35
# 701/701 [==============================] - ETA: 0s - loss: 1.2676 - main_classifier_loss: 0.8830 - auxiliary_classifier_loss: 0.9615 - main_classifier_accuracy: 0.9922 - main_classifier_top5_acc: 1.0000 - main_classifier_macro_f1score: 0.4623 - auxiliary_classifier_accuracy: 0.9864 - auxiliary_classifier_top5_acc: 0.9997 - auxiliary_classifier_macro_f1score: 0.4444
# Epoch 00021: val_loss did not improve from 2.23442
#
# Epoch 00021: val_main_classifier_accuracy did not improve from 0.75890
# 701/701 [==============================] - 1092s 2s/step - loss: 1.2676 - main_classifier_loss: 0.8830 - auxiliary_classifier_loss: 0.9615 - main_classifier_accuracy: 0.9922 - main_classifier_top5_acc: 1.0000 - main_classifier_macro_f1score: 0.4623 - auxiliary_classifier_accuracy: 0.9864 - auxiliary_classifier_top5_acc: 0.9997 - auxiliary_classifier_macro_f1score: 0.4444 - val_loss: 2.4080 - val_main_classifier_loss: 1.7191 - val_auxiliary_classifier_loss: 1.7221 - val_main_classifier_accuracy: 0.7201 - val_main_classifier_top5_acc: 0.9142 - val_main_classifier_macro_f1score: 0.2937 - val_auxiliary_classifier_accuracy: 0.7164 - val_auxiliary_classifier_top5_acc: 0.9132 - val_auxiliary_classifier_macro_f1score: 0.2794
# Learning rate:  0.0001
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 22/35
# 701/701 [==============================] - ETA: 0s - loss: 1.2752 - main_classifier_loss: 0.8883 - auxiliary_classifier_loss: 0.9671 - main_classifier_accuracy: 0.9908 - main_classifier_top5_acc: 0.9999 - main_classifier_macro_f1score: 0.4594 - auxiliary_classifier_accuracy: 0.9842 - auxiliary_classifier_top5_acc: 0.9998 - auxiliary_classifier_macro_f1score: 0.4410
# Epoch 00022: val_loss did not improve from 2.23442
#
# Epoch 00022: val_main_classifier_accuracy did not improve from 0.75890
# 701/701 [==============================] - 1104s 2s/step - loss: 1.2752 - main_classifier_loss: 0.8883 - auxiliary_classifier_loss: 0.9671 - main_classifier_accuracy: 0.9908 - main_classifier_top5_acc: 0.9999 - main_classifier_macro_f1score: 0.4594 - auxiliary_classifier_accuracy: 0.9842 - auxiliary_classifier_top5_acc: 0.9998 - auxiliary_classifier_macro_f1score: 0.4410 - val_loss: 2.3653 - val_main_classifier_loss: 1.6917 - val_auxiliary_classifier_loss: 1.6841 - val_main_classifier_accuracy: 0.7292 - val_main_classifier_top5_acc: 0.9108 - val_main_classifier_macro_f1score: 0.3004 - val_auxiliary_classifier_accuracy: 0.7320 - val_auxiliary_classifier_top5_acc: 0.9193 - val_auxiliary_classifier_macro_f1score: 0.2803
# Learning rate:  0.0001
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 23/35
# 701/701 [==============================] - ETA: 0s - loss: 1.2708 - main_classifier_loss: 0.8846 - auxiliary_classifier_loss: 0.9654 - main_classifier_accuracy: 0.9912 - main_classifier_top5_acc: 0.9999 - main_classifier_macro_f1score: 0.4624 - auxiliary_classifier_accuracy: 0.9853 - auxiliary_classifier_top5_acc: 0.9998 - auxiliary_classifier_macro_f1score: 0.4429
# Epoch 00023: val_loss did not improve from 2.23442
#
# Epoch 00023: val_main_classifier_accuracy did not improve from 0.75890
# 701/701 [==============================] - 1096s 2s/step - loss: 1.2708 - main_classifier_loss: 0.8846 - auxiliary_classifier_loss: 0.9654 - main_classifier_accuracy: 0.9912 - main_classifier_top5_acc: 0.9999 - main_classifier_macro_f1score: 0.4624 - auxiliary_classifier_accuracy: 0.9853 - auxiliary_classifier_top5_acc: 0.9998 - auxiliary_classifier_macro_f1score: 0.4429 - val_loss: 2.3920 - val_main_classifier_loss: 1.7069 - val_auxiliary_classifier_loss: 1.7128 - val_main_classifier_accuracy: 0.7213 - val_main_classifier_top5_acc: 0.9114 - val_main_classifier_macro_f1score: 0.2976 - val_auxiliary_classifier_accuracy: 0.7233 - val_auxiliary_classifier_top5_acc: 0.9152 - val_auxiliary_classifier_macro_f1score: 0.2812
# Learning rate:  0.0001
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 24/35
# 701/701 [==============================] - ETA: 0s - loss: 1.2781 - main_classifier_loss: 0.8903 - auxiliary_classifier_loss: 0.9696 - main_classifier_accuracy: 0.9898 - main_classifier_top5_acc: 0.9998 - main_classifier_macro_f1score: 0.4606 - auxiliary_classifier_accuracy: 0.9835 - auxiliary_classifier_top5_acc: 0.9997 - auxiliary_classifier_macro_f1score: 0.4417
# Epoch 00024: val_loss did not improve from 2.23442
#
# Epoch 00024: val_main_classifier_accuracy did not improve from 0.75890
# 701/701 [==============================] - 1086s 2s/step - loss: 1.2781 - main_classifier_loss: 0.8903 - auxiliary_classifier_loss: 0.9696 - main_classifier_accuracy: 0.9898 - main_classifier_top5_acc: 0.9998 - main_classifier_macro_f1score: 0.4606 - auxiliary_classifier_accuracy: 0.9835 - auxiliary_classifier_top5_acc: 0.9997 - auxiliary_classifier_macro_f1score: 0.4417 - val_loss: 2.4129 - val_main_classifier_loss: 1.7302 - val_auxiliary_classifier_loss: 1.7068 - val_main_classifier_accuracy: 0.7280 - val_main_classifier_top5_acc: 0.9051 - val_main_classifier_macro_f1score: 0.3004 - val_auxiliary_classifier_accuracy: 0.7288 - val_auxiliary_classifier_top5_acc: 0.9157 - val_auxiliary_classifier_macro_f1score: 0.2825
# Learning rate:  0.0001
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 25/35
# 701/701 [==============================] - ETA: 0s - loss: 1.2833 - main_classifier_loss: 0.8937 - auxiliary_classifier_loss: 0.9740 - main_classifier_accuracy: 0.9883 - main_classifier_top5_acc: 0.9999 - main_classifier_macro_f1score: 0.4581 - auxiliary_classifier_accuracy: 0.9827 - auxiliary_classifier_top5_acc: 0.9998 - auxiliary_classifier_macro_f1score: 0.4392
# Epoch 00025: val_loss did not improve from 2.23442
#
# Epoch 00025: val_main_classifier_accuracy did not improve from 0.75890
# 701/701 [==============================] - 1066s 2s/step - loss: 1.2833 - main_classifier_loss: 0.8937 - auxiliary_classifier_loss: 0.9740 - main_classifier_accuracy: 0.9883 - main_classifier_top5_acc: 0.9999 - main_classifier_macro_f1score: 0.4581 - auxiliary_classifier_accuracy: 0.9827 - auxiliary_classifier_top5_acc: 0.9998 - auxiliary_classifier_macro_f1score: 0.4392 - val_loss: 2.4120 - val_main_classifier_loss: 1.7288 - val_auxiliary_classifier_loss: 1.7080 - val_main_classifier_accuracy: 0.7150 - val_main_classifier_top5_acc: 0.9126 - val_main_classifier_macro_f1score: 0.2936 - val_auxiliary_classifier_accuracy: 0.7255 - val_auxiliary_classifier_top5_acc: 0.9185 - val_auxiliary_classifier_macro_f1score: 0.2787
# Learning rate:  1e-05
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 26/35
# 701/701 [==============================] - ETA: 0s - loss: 1.2314 - main_classifier_loss: 0.8578 - auxiliary_classifier_loss: 0.9340 - main_classifier_accuracy: 0.9961 - main_classifier_top5_acc: 1.0000 - main_classifier_macro_f1score: 0.4683 - auxiliary_classifier_accuracy: 0.9909 - auxiliary_classifier_top5_acc: 0.9999 - auxiliary_classifier_macro_f1score: 0.4544
# Epoch 00026: val_loss improved from 2.23442 to 2.20582, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SUB/Inception_v3/026.h5
#
# Epoch 00026: val_main_classifier_accuracy improved from 0.75890 to 0.76206, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SUB/Inception_v3/026.h5
# 701/701 [==============================] - 1077s 2s/step - loss: 1.2314 - main_classifier_loss: 0.8578 - auxiliary_classifier_loss: 0.9340 - main_classifier_accuracy: 0.9961 - main_classifier_top5_acc: 1.0000 - main_classifier_macro_f1score: 0.4683 - auxiliary_classifier_accuracy: 0.9909 - auxiliary_classifier_top5_acc: 0.9999 - auxiliary_classifier_macro_f1score: 0.4544 - val_loss: 2.2058 - val_main_classifier_loss: 1.5647 - val_auxiliary_classifier_loss: 1.6027 - val_main_classifier_accuracy: 0.7621 - val_main_classifier_top5_acc: 0.9331 - val_main_classifier_macro_f1score: 0.3159 - val_auxiliary_classifier_accuracy: 0.7579 - val_auxiliary_classifier_top5_acc: 0.9304 - val_auxiliary_classifier_macro_f1score: 0.2923
# Learning rate:  1e-05
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 27/35
# 701/701 [==============================] - ETA: 0s - loss: 1.2092 - main_classifier_loss: 0.8416 - auxiliary_classifier_loss: 0.9189 - main_classifier_accuracy: 0.9984 - main_classifier_top5_acc: 1.0000 - main_classifier_macro_f1score: 0.4709 - auxiliary_classifier_accuracy: 0.9942 - auxiliary_classifier_top5_acc: 0.9999 - auxiliary_classifier_macro_f1score: 0.4566
# Epoch 00027: val_loss improved from 2.20582 to 2.19857, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SUB/Inception_v3/027.h5
#
# Epoch 00027: val_main_classifier_accuracy improved from 0.76206 to 0.76384, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SUB/Inception_v3/027.h5
# 701/701 [==============================] - 1069s 2s/step - loss: 1.2092 - main_classifier_loss: 0.8416 - auxiliary_classifier_loss: 0.9189 - main_classifier_accuracy: 0.9984 - main_classifier_top5_acc: 1.0000 - main_classifier_macro_f1score: 0.4709 - auxiliary_classifier_accuracy: 0.9942 - auxiliary_classifier_top5_acc: 0.9999 - auxiliary_classifier_macro_f1score: 0.4566 - val_loss: 2.1986 - val_main_classifier_loss: 1.5584 - val_auxiliary_classifier_loss: 1.6004 - val_main_classifier_accuracy: 0.7638 - val_main_classifier_top5_acc: 0.9339 - val_main_classifier_macro_f1score: 0.3167 - val_auxiliary_classifier_accuracy: 0.7609 - val_auxiliary_classifier_top5_acc: 0.9310 - val_auxiliary_classifier_macro_f1score: 0.2912
# Learning rate:  1e-05
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 28/35
# 701/701 [==============================] - ETA: 0s - loss: 1.2023 - main_classifier_loss: 0.8363 - auxiliary_classifier_loss: 0.9149 - main_classifier_accuracy: 0.9991 - main_classifier_top5_acc: 1.0000 - main_classifier_macro_f1score: 0.4717 - auxiliary_classifier_accuracy: 0.9953 - auxiliary_classifier_top5_acc: 0.9999 - auxiliary_classifier_macro_f1score: 0.4567
# Epoch 00028: val_loss improved from 2.19857 to 2.18819, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SUB/Inception_v3/028.h5
#
# Epoch 00028: val_main_classifier_accuracy improved from 0.76384 to 0.77235, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SUB/Inception_v3/028.h5
# 701/701 [==============================] - 1109s 2s/step - loss: 1.2023 - main_classifier_loss: 0.8363 - auxiliary_classifier_loss: 0.9149 - main_classifier_accuracy: 0.9991 - main_classifier_top5_acc: 1.0000 - main_classifier_macro_f1score: 0.4717 - auxiliary_classifier_accuracy: 0.9953 - auxiliary_classifier_top5_acc: 0.9999 - auxiliary_classifier_macro_f1score: 0.4567 - val_loss: 2.1882 - val_main_classifier_loss: 1.5510 - val_auxiliary_classifier_loss: 1.5929 - val_main_classifier_accuracy: 0.7723 - val_main_classifier_top5_acc: 0.9357 - val_main_classifier_macro_f1score: 0.3130 - val_auxiliary_classifier_accuracy: 0.7629 - val_auxiliary_classifier_top5_acc: 0.9330 - val_auxiliary_classifier_macro_f1score: 0.2859
# Learning rate:  1e-05
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 29/35
# 701/701 [==============================] - ETA: 0s - loss: 1.1987 - main_classifier_loss: 0.8332 - auxiliary_classifier_loss: 0.9136 - main_classifier_accuracy: 0.9988 - main_classifier_top5_acc: 1.0000 - main_classifier_macro_f1score: 0.4715 - auxiliary_classifier_accuracy: 0.9962 - auxiliary_classifier_top5_acc: 1.0000 - auxiliary_classifier_macro_f1score: 0.4557
# Epoch 00029: val_loss did not improve from 2.18819
#
# Epoch 00029: val_main_classifier_accuracy did not improve from 0.77235
# 701/701 [==============================] - 1089s 2s/step - loss: 1.1987 - main_classifier_loss: 0.8332 - auxiliary_classifier_loss: 0.9136 - main_classifier_accuracy: 0.9988 - main_classifier_top5_acc: 1.0000 - main_classifier_macro_f1score: 0.4715 - auxiliary_classifier_accuracy: 0.9962 - auxiliary_classifier_top5_acc: 1.0000 - auxiliary_classifier_macro_f1score: 0.4557 - val_loss: 2.1926 - val_main_classifier_loss: 1.5543 - val_auxiliary_classifier_loss: 1.5958 - val_main_classifier_accuracy: 0.7670 - val_main_classifier_top5_acc: 0.9316 - val_main_classifier_macro_f1score: 0.3152 - val_auxiliary_classifier_accuracy: 0.7654 - val_auxiliary_classifier_top5_acc: 0.9312 - val_auxiliary_classifier_macro_f1score: 0.2803
# Learning rate:  1e-05
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 30/35
# 701/701 [==============================] - ETA: 0s - loss: 1.1961 - main_classifier_loss: 0.8306 - auxiliary_classifier_loss: 0.9137 - main_classifier_accuracy: 0.9991 - main_classifier_top5_acc: 1.0000 - main_classifier_macro_f1score: 0.4730 - auxiliary_classifier_accuracy: 0.9955 - auxiliary_classifier_top5_acc: 1.0000 - auxiliary_classifier_macro_f1score: 0.4562
# Epoch 00030: val_loss improved from 2.18819 to 2.18399, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SUB/Inception_v3/030.h5
#
# Epoch 00030: val_main_classifier_accuracy did not improve from 0.77235
# 701/701 [==============================] - 1067s 2s/step - loss: 1.1961 - main_classifier_loss: 0.8306 - auxiliary_classifier_loss: 0.9137 - main_classifier_accuracy: 0.9991 - main_classifier_top5_acc: 1.0000 - main_classifier_macro_f1score: 0.4730 - auxiliary_classifier_accuracy: 0.9955 - auxiliary_classifier_top5_acc: 1.0000 - auxiliary_classifier_macro_f1score: 0.4562 - val_loss: 2.1840 - val_main_classifier_loss: 1.5491 - val_auxiliary_classifier_loss: 1.5873 - val_main_classifier_accuracy: 0.7680 - val_main_classifier_top5_acc: 0.9361 - val_main_classifier_macro_f1score: 0.3160 - val_auxiliary_classifier_accuracy: 0.7658 - val_auxiliary_classifier_top5_acc: 0.9341 - val_auxiliary_classifier_macro_f1score: 0.2840
# Learning rate:  1e-05
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 31/35
# 701/701 [==============================] - ETA: 0s - loss: 1.1955 - main_classifier_loss: 0.8292 - auxiliary_classifier_loss: 0.9157 - main_classifier_accuracy: 0.9991 - main_classifier_top5_acc: 1.0000 - main_classifier_macro_f1score: 0.4728 - auxiliary_classifier_accuracy: 0.9960 - auxiliary_classifier_top5_acc: 1.0000 - auxiliary_classifier_macro_f1score: 0.4550
# Epoch 00031: val_loss did not improve from 2.18399
#
# Epoch 00031: val_main_classifier_accuracy did not improve from 0.77235
# 701/701 [==============================] - 1047s 1s/step - loss: 1.1955 - main_classifier_loss: 0.8292 - auxiliary_classifier_loss: 0.9157 - main_classifier_accuracy: 0.9991 - main_classifier_top5_acc: 1.0000 - main_classifier_macro_f1score: 0.4728 - auxiliary_classifier_accuracy: 0.9960 - auxiliary_classifier_top5_acc: 1.0000 - auxiliary_classifier_macro_f1score: 0.4550 - val_loss: 2.1942 - val_main_classifier_loss: 1.5564 - val_auxiliary_classifier_loss: 1.5945 - val_main_classifier_accuracy: 0.7692 - val_main_classifier_top5_acc: 0.9349 - val_main_classifier_macro_f1score: 0.3173 - val_auxiliary_classifier_accuracy: 0.7642 - val_auxiliary_classifier_top5_acc: 0.9343 - val_auxiliary_classifier_macro_f1score: 0.2852
# Learning rate:  1e-05
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 32/35
# 701/701 [==============================] - ETA: 0s - loss: 1.1925 - main_classifier_loss: 0.8267 - auxiliary_classifier_loss: 0.9146 - main_classifier_accuracy: 0.9993 - main_classifier_top5_acc: 1.0000 - main_classifier_macro_f1score: 0.4728 - auxiliary_classifier_accuracy: 0.9965 - auxiliary_classifier_top5_acc: 1.0000 - auxiliary_classifier_macro_f1score: 0.4545
# Epoch 00032: val_loss did not improve from 2.18399
#
# Epoch 00032: val_main_classifier_accuracy did not improve from 0.77235
# 701/701 [==============================] - 1048s 1s/step - loss: 1.1925 - main_classifier_loss: 0.8267 - auxiliary_classifier_loss: 0.9146 - main_classifier_accuracy: 0.9993 - main_classifier_top5_acc: 1.0000 - main_classifier_macro_f1score: 0.4728 - auxiliary_classifier_accuracy: 0.9965 - auxiliary_classifier_top5_acc: 1.0000 - auxiliary_classifier_macro_f1score: 0.4545 - val_loss: 2.2019 - val_main_classifier_loss: 1.5641 - val_auxiliary_classifier_loss: 1.5945 - val_main_classifier_accuracy: 0.7680 - val_main_classifier_top5_acc: 0.9316 - val_main_classifier_macro_f1score: 0.3141 - val_auxiliary_classifier_accuracy: 0.7650 - val_auxiliary_classifier_top5_acc: 0.9326 - val_auxiliary_classifier_macro_f1score: 0.2821
# Learning rate:  1e-05
#
# Epoch 00033: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 33/35
# 701/701 [==============================] - ETA: 0s - loss: 1.1918 - main_classifier_loss: 0.8258 - auxiliary_classifier_loss: 0.9151 - main_classifier_accuracy: 0.9994 - main_classifier_top5_acc: 1.0000 - main_classifier_macro_f1score: 0.4728 - auxiliary_classifier_accuracy: 0.9958 - auxiliary_classifier_top5_acc: 1.0000 - auxiliary_classifier_macro_f1score: 0.4542
# Epoch 00033: val_loss did not improve from 2.18399
#
# Epoch 00033: val_main_classifier_accuracy did not improve from 0.77235
# 701/701 [==============================] - 1088s 2s/step - loss: 1.1918 - main_classifier_loss: 0.8258 - auxiliary_classifier_loss: 0.9151 - main_classifier_accuracy: 0.9994 - main_classifier_top5_acc: 1.0000 - main_classifier_macro_f1score: 0.4728 - auxiliary_classifier_accuracy: 0.9958 - auxiliary_classifier_top5_acc: 1.0000 - auxiliary_classifier_macro_f1score: 0.4542 - val_loss: 2.2021 - val_main_classifier_loss: 1.5634 - val_auxiliary_classifier_loss: 1.5970 - val_main_classifier_accuracy: 0.7664 - val_main_classifier_top5_acc: 0.9322 - val_main_classifier_macro_f1score: 0.3142 - val_auxiliary_classifier_accuracy: 0.7625 - val_auxiliary_classifier_top5_acc: 0.9328 - val_auxiliary_classifier_macro_f1score: 0.2826
# Learning rate:  1e-05
#
# Epoch 00034: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 34/35
# 701/701 [==============================] - ETA: 0s - loss: 1.1921 - main_classifier_loss: 0.8254 - auxiliary_classifier_loss: 0.9168 - main_classifier_accuracy: 0.9992 - main_classifier_top5_acc: 1.0000 - main_classifier_macro_f1score: 0.4725 - auxiliary_classifier_accuracy: 0.9958 - auxiliary_classifier_top5_acc: 1.0000 - auxiliary_classifier_macro_f1score: 0.4530
# Epoch 00034: val_loss did not improve from 2.18399
#
# Epoch 00034: val_main_classifier_accuracy did not improve from 0.77235
# 701/701 [==============================] - 1060s 2s/step - loss: 1.1921 - main_classifier_loss: 0.8254 - auxiliary_classifier_loss: 0.9168 - main_classifier_accuracy: 0.9992 - main_classifier_top5_acc: 1.0000 - main_classifier_macro_f1score: 0.4725 - auxiliary_classifier_accuracy: 0.9958 - auxiliary_classifier_top5_acc: 1.0000 - auxiliary_classifier_macro_f1score: 0.4530 - val_loss: 2.2077 - val_main_classifier_loss: 1.5679 - val_auxiliary_classifier_loss: 1.5995 - val_main_classifier_accuracy: 0.7625 - val_main_classifier_top5_acc: 0.9316 - val_main_classifier_macro_f1score: 0.3154 - val_auxiliary_classifier_accuracy: 0.7593 - val_auxiliary_classifier_top5_acc: 0.9335 - val_auxiliary_classifier_macro_f1score: 0.2818
# Learning rate:  1e-05
#
# Epoch 00035: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 35/35
# 701/701 [==============================] - ETA: 0s - loss: 1.1900 - main_classifier_loss: 0.8238 - auxiliary_classifier_loss: 0.9154 - main_classifier_accuracy: 0.9995 - main_classifier_top5_acc: 1.0000 - main_classifier_macro_f1score: 0.4746 - auxiliary_classifier_accuracy: 0.9966 - auxiliary_classifier_top5_acc: 0.9999 - auxiliary_classifier_macro_f1score: 0.4555
# Epoch 00035: val_loss did not improve from 2.18399
#
# Epoch 00035: val_main_classifier_accuracy did not improve from 0.77235
# 701/701 [==============================] - 1045s 1s/step - loss: 1.1900 - main_classifier_loss: 0.8238 - auxiliary_classifier_loss: 0.9154 - main_classifier_accuracy: 0.9995 - main_classifier_top5_acc: 1.0000 - main_classifier_macro_f1score: 0.4746 - auxiliary_classifier_accuracy: 0.9966 - auxiliary_classifier_top5_acc: 0.9999 - auxiliary_classifier_macro_f1score: 0.4555 - val_loss: 2.1915 - val_main_classifier_loss: 1.5544 - val_auxiliary_classifier_loss: 1.5929 - val_main_classifier_accuracy: 0.7702 - val_main_classifier_top5_acc: 0.9345 - val_main_classifier_macro_f1score: 0.3153 - val_auxiliary_classifier_accuracy: 0.7654 - val_auxiliary_classifier_top5_acc: 0.9381 - val_auxiliary_classifier_macro_f1score: 0.2794

# %% [markdown]
# ### 3) Inception-V3 Evaluate

# %%
# 1. epoch=maximum
#var = model.evaluate_generator(generate_test_for_three(),steps=int(len(x_test)/batch_sizes))
var = model.evaluate(generate_test_for_two(),steps=int(len(x_test)/batch_sizes))
print('[Test Loss: %.4f /   Test Top-1 Accuracy: %.4f / Test Top-5 Accuracy: %.4f / Test Macro f1: %.4f]\n' % (var[0],var[-3],var[-2],var[-1]))

# %%
loss=history.history['loss']
val_loss=history.history['val_loss']
acc=history.history['main_classifier_accuracy']
val_acc=history.history['val_main_classifier_accuracy']
top5_acc=history.history['main_classifier_top5_acc']
val_top5_acc=history.history['val_main_classifier_top5_acc']
f1=history.history['main_classifier_macro_f1score']
val_f1=history.history['val_main_classifier_macro_f1score']
epochs=range(1,len(acc)+1)

data = np.array([epochs,loss,val_loss,acc,val_acc,top5_acc,val_top5_acc,f1,val_f1]).T

# %%
# data save
# epochs, loss, val_loss, acc, val_acc, top5_acc, val_top5_acc, f1, val_f1

np.savetxt(os.path.join(dir,'train_valid_output',number,model.name+'.txt'),data)

# %%
# data import
data = np.loadtxt(os.path.join(dir,'train_valid_output',number,'Inception_v3.txt'))

# %%
epochs=data[:,0]
loss=data[:,1]
val_loss=data[:,2]
acc=data[:,3]
val_acc=data[:,4]
top5_acc=data[:,5]
val_top5_acc=data[:,6]

# %%
plt.plot(epochs[1:],acc[1:],'b',label='Training 1-Acc')
plt.plot(epochs[1:],val_acc[1:],'r',label='Validation 1-Acc')
plt.title('Training and Validation Top-1 Accuracy')
plt.legend()
plt.figure()

plt.plot(epochs[1:],top5_acc[1:],'b',label='Training 5-Acc')
plt.plot(epochs[1:],val_top5_acc[1:],'r',label='Validation 5-Acc')
plt.title('Training and Validation Top-5 Accuracy')
plt.legend()
plt.figure()

plt.plot(epochs[10:],loss[10:],'b',label='Training Loss')
plt.plot(epochs[10:],val_loss[10:],'r',label='Validation Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()

# %%
# 이 아래는 내가 인위적으로 살펴보고 싶은 epoch에 대해서 결과값 출력 / Inception-V3

# %%
# 참고 : https://github.com/OverLordGoldDragon/keras-adamw

import sys
sys.path.append('/content/drive/My Drive/Colab Notebooks/Paper')
import utils
import optimizers_v2
from utils import get_weight_decays, fill_dict_in_order
from utils import reset_seeds, K_eval
from optimizers_v2 import AdamW, NadamW, SGDW

# %%
# top-5 accuracy 출력
import functools
top5_acc = functools.partial(ks.metrics.top_k_categorical_accuracy, k=5)
top5_acc.__name__ = 'top5_acc'

# %%
model=load_model(os.path.join(dir,'model_output',number,'SUB','Inception_v3','030.h5'),
                 custom_objects={"macro_f1score": macro_f1score, "top5_acc":top5_acc, "smoothed_categorical_crossentropy":smoothed_categorical_crossentropy, "AdamW":AdamW})

# %%
# 2. epoch=?
smoothing_param = 0.1
var = model.evaluate(generate_test_for_two(),steps=int(len(x_test)/batch_sizes))
# Out:
# Found 10000 images belonging to 100 classes.
# 156/156 [==============================] - 5287s 34s/step - loss: 14.3632 - main_classifier_loss: 10.2413 - auxiliary_classifier_loss: 10.3047 - main_classifier_accuracy: 0.7638 - main_classifier_top5_acc: 0.9350 - main_classifier_macro_f1score: 0.3176 - auxiliary_classifier_accuracy: 0.7574 - auxiliary_classifier_top5_acc: 0.9363 - auxiliary_classifier_macro_f1score: 0.2846

# %%
print('[Test Loss: %.4f /  Test Top-1 Accuracy: %.4f / Test Top-5 Accuracy: %.4f / Test Macro f1: %.4f]\n' % (var[0],var[-3],var[-2],var[-1]))
# Out:
# [Test Loss: 14.3632 /  Test Top-1 Accuracy: 0.7574 / Test Top-5 Accuracy: 0.9363 / Test Macro f1: 0.2846]
