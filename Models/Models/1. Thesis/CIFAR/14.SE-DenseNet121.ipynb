# %%
#모형 출처 : https://github.com/titu1994/keras-squeeze-excite-network

# %% [markdown]
# # [SE-DenseNet121]

# %% [markdown]
# *KU LeeDongGyu*

# %% [markdown]
# ## Contents
# ---

# %% [markdown]
# 1. Data Preprocessing
# ```
# 1) Data Import
# 2) Data Augmentation
# ```
# 2. Support Functions & Almost Original SE-DenseNet121
# ```
# 1) Support Functions
# 2) Almost orginal SE-DenseNet121
# ```
# 3. SE-DenseNet121
# ```
# 1) SE-DenseNet121
# 2) SE-DenseNet121 Evaluate
# ```

# %% [markdown]
# ### Install Packages

# %% [markdown]
# ### Module

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/My Drive/Colab Notebooks/Paper
# Out:
# /content/drive/My Drive/Colab Notebooks/Paper

# %%
from f1score import macro_f1score,weighted_f1score

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import cv2
import tensorflow as tf
from tensorflow import keras as ks
from tensorflow.keras import backend as K 
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, Input, Concatenate, ZeroPadding2D ,GlobalMaxPooling2D, Reshape , Lambda , Add, Multiply
from tensorflow.keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D, Activation, BatchNormalization, AveragePooling2D , ZeroPadding2D, SeparableConv2D , LeakyReLU
from tensorflow.keras.layers import add, concatenate, multiply
from tensorflow.keras.optimizers import Adam, RMSprop , SGD
from tensorflow.keras.callbacks import EarlyStopping , LearningRateScheduler, ModelCheckpoint, CSVLogger, Callback, ReduceLROnPlateau
from tensorflow.keras.regularizers import l1,l2,l1_l2
from tensorflow.keras.models import Model , load_model , Sequential
from tensorflow.keras.utils import plot_model , to_categorical, get_file
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
os.getcwd()
# Out:
# '/content/drive/My Drive/Colab Notebooks/Paper'

# %%
tf.__version__
# Out:
# '2.3.0'

# %%
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 2269013003401795687
# , name: "/device:XLA_CPU:0"
# device_type: "XLA_CPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 11578619818012448669
# physical_device_desc: "device: XLA_CPU device"
# , name: "/device:XLA_GPU:0"
# device_type: "XLA_GPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 17136834731412551281
# physical_device_desc: "device: XLA_GPU device"
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 15695549568
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 12597702458890776567
# physical_device_desc: "device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0"
# ]

# %%
# !cat /proc/cpuinfo
# Out:
# processor	: 0
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 63
# model name	: Intel(R) Xeon(R) CPU @ 2.30GHz
# stepping	: 0
# microcode	: 0x1
# cpu MHz		: 2300.000
# cache size	: 46080 KB
# physical id	: 0
# siblings	: 4
# core id		: 0
# cpu cores	: 2
# apicid		: 0
# initial apicid	: 0
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 avx2 smep bmi2 erms invpcid xsaveopt arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs
# bogomips	: 4600.00
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 46 bits physical, 48 bits virtual
# power management:
#
# processor	: 1
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 63
# model name	: Intel(R) Xeon(R) CPU @ 2.30GHz
# stepping	: 0
# microcode	: 0x1
# cpu MHz		: 2300.000
# cache size	: 46080 KB
# physical id	: 0
# siblings	: 4
# core id		: 1
# cpu cores	: 2
# apicid		: 2
# initial apicid	: 2
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 avx2 smep bmi2 erms invpcid xsaveopt arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs
# bogomips	: 4600.00
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 46 bits physical, 48 bits virtual
# power management:
#
# processor	: 2
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 63
# model name	: Intel(R) Xeon(R) CPU @ 2.30GHz
# stepping	: 0
# microcode	: 0x1
# cpu MHz		: 2300.000
# cache size	: 46080 KB
# physical id	: 0
# siblings	: 4
# core id		: 0
# cpu cores	: 2
# apicid		: 1
# initial apicid	: 1
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 avx2 smep bmi2 erms invpcid xsaveopt arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs
# bogomips	: 4600.00
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 46 bits physical, 48 bits virtual
# power management:
#
# processor	: 3
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 63
# model name	: Intel(R) Xeon(R) CPU @ 2.30GHz
# stepping	: 0
# microcode	: 0x1
# cpu MHz		: 2300.000
# cache size	: 46080 KB
# physical id	: 0
# siblings	: 4
# core id		: 1
# cpu cores	: 2
# apicid		: 3
# initial apicid	: 3
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 avx2 smep bmi2 erms invpcid xsaveopt arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs
# bogomips	: 4600.00
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 46 bits physical, 48 bits virtual
# power management:

# %% [markdown]
# ## 1. Data Preprocessing
# ---

# %% [markdown]
# ### 1) Data Import

# %%
# 바꿔서 살펴 볼 것들
# CALTECH, CIFAR100, FER, MIT
data_name = 'CIFAR100'
gan_type = 'No_GAN'
number = '1'
size = 224 # sizes after cropping
super_size = 256 # sizes before cropping 
input_sizes = (size,size,3)
batch_sizes = 64
weight_decay = 1e-3
epochs = 70

# %%
# 참고 : https://stackoverflow.com/questions/32419510/how-to-get-reproducible-results-in-keras/52897216#52897216
# setting the seed number for random number generation for reproducibility.

from numpy.random import seed
import random


if number=='1':
    seed_num = 200225
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)
elif number=='2':
    seed_num = 727
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)
elif number=='3':
    seed_num = 115
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)
elif number=='4':
    seed_num = 501
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)
elif number=='5':
    seed_num = 517
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)

# %%
# data import

if data_name=='FER' :
    x_train =  np.zeros(28698)
    x_valid = np.zeros(3589)
    x_test = np.zeros(3588)
    classes = 7 
    tr_center = [0.50793296, 0.50793296, 0.50793296]
elif data_name=='MIT':
    x_train = np.zeros(12466)
    x_valid = np.zeros(1564)
    x_test = np.zeros(1590)
    classes = 67 
    tr_center = [0.47916578, 0.42029615, 0.36046057]
elif data_name=='CALTECH':
    x_train = np.zeros(24510)
    x_valid = np.zeros(2980)
    x_test = np.zeros(3118)
    classes = 257
    tr_center = [0.51397761, 0.49525248, 0.46555727]
elif data_name=='CIFAR100':
    x_train = np.zeros(44923)
    x_valid = np.zeros(5077)
    x_test = np.zeros(10000)
    classes = 100
    tr_center = [0.53442983, 0.51355958, 0.46462564]

# %%
dir = os.path.join(os.getcwd(),data_name,gan_type)

# %% [markdown]
# ### 2) Data Augmentation

# %%
# 참고 : https://jkjung-avt.github.io/keras-image-cropping/

def random_crop(img, random_crop_size):
    # Note: image_data_format is 'channel_last'
    assert img.shape[2] == 3 # img.shape[2] 가 3(rgb)이 아니면 assertion error 발생
    height, width = img.shape[0], img.shape[1]
    dy, dx = random_crop_size
    x = np.random.randint(0, width - dx + 1)
    y = np.random.randint(0, height - dy + 1)
    return img[y:(y+dy), x:(x+dx), :]


def crop_generator(batches, crop_length):
    """Take as input a Keras ImageGen (Iterator) and generate random
    crops from the image batches generated by the original iterator.
    """
    while True:
        batch_x, batch_y = next(batches)
        batch_crops = np.zeros((batch_x.shape[0], crop_length, crop_length, 3))
        for i in range(batch_x.shape[0]):
            batch_crops[i] = random_crop(batch_x[i], (crop_length, crop_length))
        yield (batch_crops, batch_y)

# %%
from tensorflow.keras.preprocessing.image import img_to_array,load_img
import glob

# 데이터 전체에 대해 centering 진행함.

def read_cal_image(img_path): 
    x = img_to_array(load_img(img_path)) # x는 채널별 평균값
    y = x.shape[0] * x.shape[1]# y는 데이터별 픽셀 수 (비중)

    x = 1/255. * x # scaling하고, centering값을 뽑아냄.
    x = np.mean(x, axis=(0,1))
    
    return np.hstack([x,y])

def calculate_centered_mean(dataset_path,x_train=x_train):
    num = len(x_train)
    space = np.empty((num,4))
    i=0

    for p in glob.glob(os.path.join(dataset_path,'*/*.*')) :
        space[i] = read_cal_image(p)
        i += 1

    ratio = space[:,3] / np.sum(space[:,3])

    return np.average(space[:,0:3],axis=0,weights=ratio)


# 아래의 함수를 돌려서 나온 결과값을 중심화 값으로 설정.

# train_mean = calculate_centered_mean(os.path.join(dir,'data/train')).reshape((1,1,3))

# %%
datagen_tr = ImageDataGenerator(
    rescale=1/255.,
    horizontal_flip=True,
    featurewise_center=True,
    featurewise_std_normalization=False,
    rotation_range=10,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=[0.9,1.0],
    fill_mode = 'nearest')
datagen_val = ImageDataGenerator(rescale=1/255.,featurewise_center=True)
datagen_tes = ImageDataGenerator(rescale=1/255.,featurewise_center=True)

# 원래는 이 자리에 fit 매서드를 써야하지만, 그냥 내가 중심화함수를 만들고 적용함. 

# 중심화 설정
datagen_tr.mean = np.array(tr_center, dtype=np.float32).reshape((1,1,3)) # RGB
datagen_val.mean = np.array(tr_center, dtype=np.float32).reshape((1,1,3)) # RGB
datagen_tes.mean = np.array(tr_center, dtype=np.float32).reshape((1,1,3)) # RGB

# %%
train_batches = datagen_tr.flow_from_directory(directory=os.path.join(dir,'data/train'),target_size=(super_size,super_size),batch_size=batch_sizes,class_mode='categorical') # fer : 28698 / mit : 12466 / caltech : 24509 / cifar : 44923
train_generator= crop_generator(train_batches, size)
valid_generator = datagen_val.flow_from_directory(directory=os.path.join(dir,'data/valid'),target_size=(size,size),batch_size=batch_sizes,class_mode='categorical') # fer : 3589 / mit : 1564 / caltech : 2980 / cifar : 5077
test_generator = datagen_tes.flow_from_directory(directory=os.path.join(dir,'data/test'),target_size=(size,size),batch_size=batch_sizes,class_mode='categorical') # fer : 3588 / mit : 1590 / caltech : 3118 / cifar : 10000
# Out:
# Found 44923 images belonging to 100 classes.
# Found 5077 images belonging to 100 classes.
# Found 10000 images belonging to 100 classes.

# %% [markdown]
# ## 2. Support Functions & Almost Original SE-DenseNet121
# ---

# %% [markdown]
# ### 1) Support Functions

# %%
# def lr_schedule(epoch):
#     init_lr = 1e-4
#     k = 0.04
#     lr = init_lr * np.exp(-k*epoch)
#     print('Learning rate: ', lr)
#     return lr

def lr_schedule(epoch):
    lr = 1e-3
    if epoch < 30:
        lr = lr
    elif epoch < 60:
        lr = lr * 0.1
    else:
        lr = lr * 0.01
    print('Learning rate: ', lr)
    return lr

# %%
def squeeze_excite_block(input, reduction_ratio=16, weight_decay=weight_decay):

    init = input
    channel_axis = -1
    filters = init.get_shape()[channel_axis]
    se_shape = (1, 1, filters)

    se = GlobalAveragePooling2D()(init)
    se = Reshape(se_shape)(se)
    se = Dense(filters // reduction_ratio, activation='relu', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay), use_bias=False)(se)
    se = Dense(filters, activation='sigmoid', kernel_regularizer=l2(weight_decay), use_bias=False)(se)

    x = multiply([init, se])
    return x

# %%
def __conv_block(ip, nb_filter, bottleneck=False, dropout_rate=None, weight_decay=weight_decay):

    concat_axis = -1

    x = BatchNormalization(axis=concat_axis, epsilon=1.1e-5)(ip)
    x = Activation('relu')(x)

    if bottleneck:
        inter_channel = nb_filter * 4  # Obtained from https://github.com/liuzhuang13/DenseNet/blob/master/densenet.lua

        x = Conv2D(inter_channel, (1, 1), kernel_initializer='he_uniform', padding='same', use_bias=False,
                   kernel_regularizer=l2(weight_decay))(x)
        x = BatchNormalization(axis=concat_axis, epsilon=1.1e-5)(x)
        x = Activation('relu')(x)

    x = Conv2D(nb_filter, (3, 3), kernel_initializer='he_uniform', padding='same', use_bias=False, kernel_regularizer=l2(weight_decay))(x)
    if dropout_rate:
        x = Dropout(dropout_rate)(x)

    return x

# %%
def __dense_block(x, nb_layers, nb_filter, growth_rate, bottleneck=False, dropout_rate=None, weight_decay=weight_decay,
                  grow_nb_filters=True, return_concat_list=False):

    concat_axis = -1

    x_list = [x]

    for i in range(nb_layers):
        cb = __conv_block(x, growth_rate, bottleneck, dropout_rate, weight_decay)
        x_list.append(cb)

        x = concatenate([x, cb], axis=concat_axis)

        if grow_nb_filters:
            nb_filter += growth_rate

    # squeeze and excite block
    x = squeeze_excite_block(x)

    if return_concat_list:
        return x, nb_filter, x_list
    else:
        return x, nb_filter

# %%
def __transition_block(ip, nb_filter, compression=1.0, weight_decay=weight_decay):

    concat_axis = -1

    x = BatchNormalization(axis=concat_axis, epsilon=1.1e-5)(ip)
    x = Activation('relu')(x)
    x = Conv2D(int(nb_filter * compression), (1, 1), kernel_initializer='he_uniform', padding='same', use_bias=False,
               kernel_regularizer=l2(weight_decay))(x)
    x = AveragePooling2D((2, 2), strides=(2, 2))(x)

    # squeeze and excite block
    x = squeeze_excite_block(x)

    return x

# %%
def __create_dense_net(nb_classes, img_input, depth=40, nb_dense_block=3, growth_rate=12, nb_filter=-1,
                       nb_layers_per_block=-1, bottleneck=False, reduction=0.0, dropout_rate=None, weight_decay=weight_decay,
                       subsample_initial_block=False, activation='softmax'):

    concat_axis = -1

    if reduction != 0.0:
        assert 1.0 >= reduction > 0.0, 'reduction value must lie between 0.0 and 1.0'

    # layers in each dense block
    if type(nb_layers_per_block) is list or type(nb_layers_per_block) is tuple:
        nb_layers = list(nb_layers_per_block)  # Convert tuple to list

        assert len(nb_layers) == nb_dense_block, 'If list, nb_layer is used as provided. ' \
                                                 'Note that list size must be (nb_dense_block)'
        final_nb_layer = nb_layers[-1]
        nb_layers = nb_layers[:-1]
    else:
        if nb_layers_per_block == -1:
            assert (depth - 4) % 3 == 0, 'Depth must be 3 N + 4 if nb_layers_per_block == -1'
            count = int((depth - 4) / 3)
            nb_layers = [count for _ in range(nb_dense_block)]
            final_nb_layer = count
        else:
            final_nb_layer = nb_layers_per_block
            nb_layers = [nb_layers_per_block] * nb_dense_block

    # compute initial nb_filter if -1, else accept users initial nb_filter
    if nb_filter <= 0:
        nb_filter = 2 * growth_rate

    # compute compression factor
    compression = 1.0 - reduction

    # Initial convolution
    if subsample_initial_block:
        initial_kernel = (7, 7)
        initial_strides = (2, 2)
    else:
        initial_kernel = (3, 3)
        initial_strides = (1, 1)

    x = Conv2D(nb_filter, initial_kernel, kernel_initializer='he_uniform', padding='same',
               strides=initial_strides, use_bias=False, kernel_regularizer=l2(weight_decay))(img_input)

    if subsample_initial_block:
        x = BatchNormalization(axis=concat_axis, epsilon=1.1e-5)(x)
        x = Activation('relu')(x)
        x = MaxPooling2D((3, 3), strides=(2, 2), padding='same')(x)

    # Add dense blocks
    for block_idx in range(nb_dense_block - 1):
        x, nb_filter = __dense_block(x, nb_layers[block_idx], nb_filter, growth_rate, bottleneck=bottleneck,
                                     dropout_rate=dropout_rate, weight_decay=weight_decay)
        # add transition_block
        x = __transition_block(x, nb_filter, compression=compression, weight_decay=weight_decay)
        nb_filter = int(nb_filter * compression)

    # The last dense_block does not have a transition_block
    x, nb_filter = __dense_block(x, final_nb_layer, nb_filter, growth_rate, bottleneck=bottleneck,
                                 dropout_rate=dropout_rate, weight_decay=weight_decay)

    x = BatchNormalization(axis=concat_axis, epsilon=1.1e-5)(x)
    x = Activation('relu')(x)
    x = GlobalAveragePooling2D()(x)

    x = Dense(nb_classes, kernel_regularizer=l2(weight_decay), activation=activation)(x)

    return x

# %% [markdown]
# ### 2) Almost Orginial SE-DenseNet121

# %%
def SE_DenseNet(input_shape=None, depth=40, nb_dense_block=3, growth_rate=12, nb_filter=-1, nb_layers_per_block=-1, bottleneck=False,
               reduction=0.0, dropout_rate=0.0, weight_decay=weight_decay, subsample_initial_block=False,
               weights=None, classes=classes, activation='softmax', name=None):


    if activation not in ['softmax', 'sigmoid']:
        raise ValueError('activation must be one of "softmax" or "sigmoid"')

    if activation == 'sigmoid' and classes != 1:
        raise ValueError('sigmoid activation can only be used when classes = 1')

    img_input = Input(shape=input_shape)

    x = __create_dense_net(classes, img_input, depth, nb_dense_block,
                           growth_rate, nb_filter, nb_layers_per_block, bottleneck, reduction,
                           dropout_rate, weight_decay, subsample_initial_block, activation)

    # Ensure that the model takes into account
    # any potential predecessors of `input_tensor`.

    inputs = img_input

    # Create model.
    model = Model(inputs, x, name= name )

    return model

# %%
def SE_DenseNet121(input_shape=None, bottleneck=True, reduction=0.5, growth_rate = 32, dropout_rate=0.0, weight_decay=weight_decay, classes=classes, activation='softmax', name = None):

    return SE_DenseNet(input_shape, depth=121, nb_dense_block=4, growth_rate=growth_rate, nb_filter=64,
                      nb_layers_per_block=[6, 12, 24, 16], bottleneck=bottleneck, reduction=reduction,
                      dropout_rate=dropout_rate, weight_decay=weight_decay, subsample_initial_block=True,
                      classes=classes, activation=activation , name = name)

# %% [markdown]
# ## 3. SE-DenseNet121
#
# ---

# %% [markdown]
# ### 1) SE-DenseNet121

# %%
model = SE_DenseNet121(input_shape=input_sizes, classes = classes, dropout_rate = 0.2, growth_rate = 32, name = 'SE_DenseNet121')

# %%
model.summary()
# Out:
# Model: "SE_DenseNet121"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 112, 112, 64) 9408        input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 112, 112, 64) 256         conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 112, 112, 64) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 56, 56, 64)   0           activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 56, 56, 64)   256         max_pooling2d[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 56, 56, 64)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 56, 56, 128)  8192        activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 56, 56, 128)  512         conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 56, 56, 128)  0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 56, 56, 32)   36864       activation_2[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 56, 56, 32)   0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 56, 56, 96)   0           max_pooling2d[0][0]
#                                                                  dropout[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 56, 56, 96)   384         concatenate[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 56, 56, 96)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 56, 56, 128)  12288       activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 56, 56, 128)  512         conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 56, 56, 128)  0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 56, 56, 32)   36864       activation_4[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 56, 56, 32)   0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 56, 56, 128)  0           concatenate[0][0]
#                                                                  dropout_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 56, 56, 128)  512         concatenate_1[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 56, 56, 128)  0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 56, 56, 128)  16384       activation_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 56, 56, 128)  512         conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 56, 56, 128)  0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 56, 56, 32)   36864       activation_6[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 56, 56, 32)   0           conv2d_6[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 56, 56, 160)  0           concatenate_1[0][0]
#                                                                  dropout_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 56, 56, 160)  640         concatenate_2[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 56, 56, 160)  0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 56, 56, 128)  20480       activation_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 56, 56, 128)  512         conv2d_7[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 56, 56, 128)  0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 56, 56, 32)   36864       activation_8[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 56, 56, 32)   0           conv2d_8[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 56, 56, 192)  0           concatenate_2[0][0]
#                                                                  dropout_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 56, 56, 192)  768         concatenate_3[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 56, 56, 192)  0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 56, 56, 128)  24576       activation_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 56, 56, 128)  512         conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 56, 56, 128)  0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 56, 56, 32)   36864       activation_10[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 56, 56, 32)   0           conv2d_10[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 56, 56, 224)  0           concatenate_3[0][0]
#                                                                  dropout_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 56, 56, 224)  896         concatenate_4[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 56, 56, 224)  0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 56, 56, 128)  28672       activation_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 56, 56, 128)  512         conv2d_11[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 56, 56, 128)  0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 56, 56, 32)   36864       activation_12[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 56, 56, 32)   0           conv2d_12[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 56, 56, 256)  0           concatenate_4[0][0]
#                                                                  dropout_5[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 256)          0           concatenate_5[0][0]
# __________________________________________________________________________________________________
# reshape (Reshape)               (None, 1, 1, 256)    0           global_average_pooling2d[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 1, 1, 16)     4096        reshape[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 1, 1, 256)    4096        dense[0][0]
# __________________________________________________________________________________________________
# multiply (Multiply)             (None, 56, 56, 256)  0           concatenate_5[0][0]
#                                                                  dense_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 56, 56, 256)  1024        multiply[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 56, 56, 256)  0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 56, 56, 128)  32768       activation_13[0][0]
# __________________________________________________________________________________________________
# average_pooling2d (AveragePooli (None, 28, 28, 128)  0           conv2d_13[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_1 (Glo (None, 128)          0           average_pooling2d[0][0]
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, 1, 1, 128)    0           global_average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 1, 1, 8)      1024        reshape_1[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 1, 1, 128)    1024        dense_2[0][0]
# __________________________________________________________________________________________________
# multiply_1 (Multiply)           (None, 28, 28, 128)  0           average_pooling2d[0][0]
#                                                                  dense_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 28, 28, 128)  512         multiply_1[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 28, 28, 128)  0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 28, 28, 128)  16384       activation_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 28, 28, 128)  512         conv2d_14[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 28, 28, 128)  0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 28, 28, 32)   36864       activation_15[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 28, 28, 32)   0           conv2d_15[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 28, 28, 160)  0           multiply_1[0][0]
#                                                                  dropout_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 28, 28, 160)  640         concatenate_6[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 28, 28, 160)  0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 28, 28, 128)  20480       activation_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 28, 28, 128)  512         conv2d_16[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 28, 28, 128)  0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 28, 28, 32)   36864       activation_17[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 28, 28, 32)   0           conv2d_17[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 28, 28, 192)  0           concatenate_6[0][0]
#                                                                  dropout_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 28, 28, 192)  768         concatenate_7[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 28, 28, 192)  0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 28, 28, 128)  24576       activation_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 28, 28, 128)  512         conv2d_18[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 28, 28, 128)  0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 28, 28, 32)   36864       activation_19[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 28, 28, 32)   0           conv2d_19[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 28, 28, 224)  0           concatenate_7[0][0]
#                                                                  dropout_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 28, 28, 224)  896         concatenate_8[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 28, 28, 224)  0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 28, 28, 128)  28672       activation_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 28, 28, 128)  512         conv2d_20[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 28, 28, 128)  0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 28, 28, 32)   36864       activation_21[0][0]
# __________________________________________________________________________________________________
# dropout_9 (Dropout)             (None, 28, 28, 32)   0           conv2d_21[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 28, 28, 256)  0           concatenate_8[0][0]
#                                                                  dropout_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 28, 28, 256)  1024        concatenate_9[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 28, 28, 256)  0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 28, 28, 128)  32768       activation_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 28, 28, 128)  512         conv2d_22[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 28, 28, 128)  0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 28, 28, 32)   36864       activation_23[0][0]
# __________________________________________________________________________________________________
# dropout_10 (Dropout)            (None, 28, 28, 32)   0           conv2d_23[0][0]
# __________________________________________________________________________________________________
# concatenate_10 (Concatenate)    (None, 28, 28, 288)  0           concatenate_9[0][0]
#                                                                  dropout_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 28, 28, 288)  1152        concatenate_10[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 28, 28, 288)  0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 28, 28, 128)  36864       activation_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 28, 28, 128)  512         conv2d_24[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 28, 28, 128)  0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 28, 28, 32)   36864       activation_25[0][0]
# __________________________________________________________________________________________________
# dropout_11 (Dropout)            (None, 28, 28, 32)   0           conv2d_25[0][0]
# __________________________________________________________________________________________________
# concatenate_11 (Concatenate)    (None, 28, 28, 320)  0           concatenate_10[0][0]
#                                                                  dropout_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 28, 28, 320)  1280        concatenate_11[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 28, 28, 320)  0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 28, 28, 128)  40960       activation_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 28, 28, 128)  512         conv2d_26[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 28, 28, 128)  0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 28, 28, 32)   36864       activation_27[0][0]
# __________________________________________________________________________________________________
# dropout_12 (Dropout)            (None, 28, 28, 32)   0           conv2d_27[0][0]
# __________________________________________________________________________________________________
# concatenate_12 (Concatenate)    (None, 28, 28, 352)  0           concatenate_11[0][0]
#                                                                  dropout_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 28, 28, 352)  1408        concatenate_12[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 28, 28, 352)  0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 28, 28, 128)  45056       activation_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 28, 28, 128)  512         conv2d_28[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 28, 28, 128)  0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 28, 28, 32)   36864       activation_29[0][0]
# __________________________________________________________________________________________________
# dropout_13 (Dropout)            (None, 28, 28, 32)   0           conv2d_29[0][0]
# __________________________________________________________________________________________________
# concatenate_13 (Concatenate)    (None, 28, 28, 384)  0           concatenate_12[0][0]
#                                                                  dropout_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 28, 28, 384)  1536        concatenate_13[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 28, 28, 384)  0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 28, 28, 128)  49152       activation_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 28, 28, 128)  512         conv2d_30[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 28, 28, 128)  0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 28, 28, 32)   36864       activation_31[0][0]
# __________________________________________________________________________________________________
# dropout_14 (Dropout)            (None, 28, 28, 32)   0           conv2d_31[0][0]
# __________________________________________________________________________________________________
# concatenate_14 (Concatenate)    (None, 28, 28, 416)  0           concatenate_13[0][0]
#                                                                  dropout_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 28, 28, 416)  1664        concatenate_14[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 28, 28, 416)  0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 28, 28, 128)  53248       activation_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 28, 28, 128)  512         conv2d_32[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 28, 28, 128)  0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 28, 28, 32)   36864       activation_33[0][0]
# __________________________________________________________________________________________________
# dropout_15 (Dropout)            (None, 28, 28, 32)   0           conv2d_33[0][0]
# __________________________________________________________________________________________________
# concatenate_15 (Concatenate)    (None, 28, 28, 448)  0           concatenate_14[0][0]
#                                                                  dropout_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 28, 28, 448)  1792        concatenate_15[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 28, 28, 448)  0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 28, 28, 128)  57344       activation_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 28, 28, 128)  512         conv2d_34[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 28, 28, 128)  0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 28, 28, 32)   36864       activation_35[0][0]
# __________________________________________________________________________________________________
# dropout_16 (Dropout)            (None, 28, 28, 32)   0           conv2d_35[0][0]
# __________________________________________________________________________________________________
# concatenate_16 (Concatenate)    (None, 28, 28, 480)  0           concatenate_15[0][0]
#                                                                  dropout_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 28, 28, 480)  1920        concatenate_16[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 28, 28, 480)  0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 28, 28, 128)  61440       activation_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 28, 28, 128)  512         conv2d_36[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 28, 28, 128)  0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 28, 28, 32)   36864       activation_37[0][0]
# __________________________________________________________________________________________________
# dropout_17 (Dropout)            (None, 28, 28, 32)   0           conv2d_37[0][0]
# __________________________________________________________________________________________________
# concatenate_17 (Concatenate)    (None, 28, 28, 512)  0           concatenate_16[0][0]
#                                                                  dropout_17[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_2 (Glo (None, 512)          0           concatenate_17[0][0]
# __________________________________________________________________________________________________
# reshape_2 (Reshape)             (None, 1, 1, 512)    0           global_average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 1, 1, 32)     16384       reshape_2[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 1, 1, 512)    16384       dense_4[0][0]
# __________________________________________________________________________________________________
# multiply_2 (Multiply)           (None, 28, 28, 512)  0           concatenate_17[0][0]
#                                                                  dense_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 28, 28, 512)  2048        multiply_2[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 28, 28, 512)  0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 28, 28, 256)  131072      activation_38[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, 14, 14, 256)  0           conv2d_38[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_3 (Glo (None, 256)          0           average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# reshape_3 (Reshape)             (None, 1, 1, 256)    0           global_average_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 1, 1, 16)     4096        reshape_3[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 1, 1, 256)    4096        dense_6[0][0]
# __________________________________________________________________________________________________
# multiply_3 (Multiply)           (None, 14, 14, 256)  0           average_pooling2d_1[0][0]
#                                                                  dense_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 14, 14, 256)  1024        multiply_3[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 14, 14, 256)  0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 14, 14, 128)  32768       activation_39[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 14, 14, 128)  512         conv2d_39[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 14, 14, 128)  0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 14, 14, 32)   36864       activation_40[0][0]
# __________________________________________________________________________________________________
# dropout_18 (Dropout)            (None, 14, 14, 32)   0           conv2d_40[0][0]
# __________________________________________________________________________________________________
# concatenate_18 (Concatenate)    (None, 14, 14, 288)  0           multiply_3[0][0]
#                                                                  dropout_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 14, 14, 288)  1152        concatenate_18[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 14, 14, 288)  0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 14, 14, 128)  36864       activation_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 14, 14, 128)  512         conv2d_41[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 14, 14, 128)  0           batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 14, 14, 32)   36864       activation_42[0][0]
# __________________________________________________________________________________________________
# dropout_19 (Dropout)            (None, 14, 14, 32)   0           conv2d_42[0][0]
# __________________________________________________________________________________________________
# concatenate_19 (Concatenate)    (None, 14, 14, 320)  0           concatenate_18[0][0]
#                                                                  dropout_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 14, 14, 320)  1280        concatenate_19[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 14, 14, 320)  0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 14, 14, 128)  40960       activation_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 14, 14, 128)  512         conv2d_43[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 14, 14, 128)  0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 14, 14, 32)   36864       activation_44[0][0]
# __________________________________________________________________________________________________
# dropout_20 (Dropout)            (None, 14, 14, 32)   0           conv2d_44[0][0]
# __________________________________________________________________________________________________
# concatenate_20 (Concatenate)    (None, 14, 14, 352)  0           concatenate_19[0][0]
#                                                                  dropout_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 14, 14, 352)  1408        concatenate_20[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 14, 14, 352)  0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 14, 14, 128)  45056       activation_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 14, 14, 128)  512         conv2d_45[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 14, 14, 128)  0           batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 14, 14, 32)   36864       activation_46[0][0]
# __________________________________________________________________________________________________
# dropout_21 (Dropout)            (None, 14, 14, 32)   0           conv2d_46[0][0]
# __________________________________________________________________________________________________
# concatenate_21 (Concatenate)    (None, 14, 14, 384)  0           concatenate_20[0][0]
#                                                                  dropout_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 14, 14, 384)  1536        concatenate_21[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 14, 14, 384)  0           batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 14, 14, 128)  49152       activation_47[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 14, 14, 128)  512         conv2d_47[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 14, 14, 128)  0           batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 14, 14, 32)   36864       activation_48[0][0]
# __________________________________________________________________________________________________
# dropout_22 (Dropout)            (None, 14, 14, 32)   0           conv2d_48[0][0]
# __________________________________________________________________________________________________
# concatenate_22 (Concatenate)    (None, 14, 14, 416)  0           concatenate_21[0][0]
#                                                                  dropout_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 14, 14, 416)  1664        concatenate_22[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 14, 14, 416)  0           batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 14, 14, 128)  53248       activation_49[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 14, 14, 128)  512         conv2d_49[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, 14, 14, 128)  0           batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 14, 14, 32)   36864       activation_50[0][0]
# __________________________________________________________________________________________________
# dropout_23 (Dropout)            (None, 14, 14, 32)   0           conv2d_50[0][0]
# __________________________________________________________________________________________________
# concatenate_23 (Concatenate)    (None, 14, 14, 448)  0           concatenate_22[0][0]
#                                                                  dropout_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 14, 14, 448)  1792        concatenate_23[0][0]
# __________________________________________________________________________________________________
# activation_51 (Activation)      (None, 14, 14, 448)  0           batch_normalization_51[0][0]
# ...
# __________________________________________________________________________________________________
# concatenate_49 (Concatenate)    (None, 7, 7, 768)    0           concatenate_48[0][0]
#                                                                  dropout_49[0][0]
# __________________________________________________________________________________________________
# batch_normalization_104 (BatchN (None, 7, 7, 768)    3072        concatenate_49[0][0]
# __________________________________________________________________________________________________
# activation_104 (Activation)     (None, 7, 7, 768)    0           batch_normalization_104[0][0]
# __________________________________________________________________________________________________
# conv2d_104 (Conv2D)             (None, 7, 7, 128)    98304       activation_104[0][0]
# __________________________________________________________________________________________________
# batch_normalization_105 (BatchN (None, 7, 7, 128)    512         conv2d_104[0][0]
# __________________________________________________________________________________________________
# activation_105 (Activation)     (None, 7, 7, 128)    0           batch_normalization_105[0][0]
# __________________________________________________________________________________________________
# conv2d_105 (Conv2D)             (None, 7, 7, 32)     36864       activation_105[0][0]
# __________________________________________________________________________________________________
# dropout_50 (Dropout)            (None, 7, 7, 32)     0           conv2d_105[0][0]
# __________________________________________________________________________________________________
# concatenate_50 (Concatenate)    (None, 7, 7, 800)    0           concatenate_49[0][0]
#                                                                  dropout_50[0][0]
# __________________________________________________________________________________________________
# batch_normalization_106 (BatchN (None, 7, 7, 800)    3200        concatenate_50[0][0]
# __________________________________________________________________________________________________
# activation_106 (Activation)     (None, 7, 7, 800)    0           batch_normalization_106[0][0]
# __________________________________________________________________________________________________
# conv2d_106 (Conv2D)             (None, 7, 7, 128)    102400      activation_106[0][0]
# __________________________________________________________________________________________________
# batch_normalization_107 (BatchN (None, 7, 7, 128)    512         conv2d_106[0][0]
# __________________________________________________________________________________________________
# activation_107 (Activation)     (None, 7, 7, 128)    0           batch_normalization_107[0][0]
# __________________________________________________________________________________________________
# conv2d_107 (Conv2D)             (None, 7, 7, 32)     36864       activation_107[0][0]
# __________________________________________________________________________________________________
# dropout_51 (Dropout)            (None, 7, 7, 32)     0           conv2d_107[0][0]
# __________________________________________________________________________________________________
# concatenate_51 (Concatenate)    (None, 7, 7, 832)    0           concatenate_50[0][0]
#                                                                  dropout_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_108 (BatchN (None, 7, 7, 832)    3328        concatenate_51[0][0]
# __________________________________________________________________________________________________
# activation_108 (Activation)     (None, 7, 7, 832)    0           batch_normalization_108[0][0]
# __________________________________________________________________________________________________
# conv2d_108 (Conv2D)             (None, 7, 7, 128)    106496      activation_108[0][0]
# __________________________________________________________________________________________________
# batch_normalization_109 (BatchN (None, 7, 7, 128)    512         conv2d_108[0][0]
# __________________________________________________________________________________________________
# activation_109 (Activation)     (None, 7, 7, 128)    0           batch_normalization_109[0][0]
# __________________________________________________________________________________________________
# conv2d_109 (Conv2D)             (None, 7, 7, 32)     36864       activation_109[0][0]
# __________________________________________________________________________________________________
# dropout_52 (Dropout)            (None, 7, 7, 32)     0           conv2d_109[0][0]
# __________________________________________________________________________________________________
# concatenate_52 (Concatenate)    (None, 7, 7, 864)    0           concatenate_51[0][0]
#                                                                  dropout_52[0][0]
# __________________________________________________________________________________________________
# batch_normalization_110 (BatchN (None, 7, 7, 864)    3456        concatenate_52[0][0]
# __________________________________________________________________________________________________
# activation_110 (Activation)     (None, 7, 7, 864)    0           batch_normalization_110[0][0]
# __________________________________________________________________________________________________
# conv2d_110 (Conv2D)             (None, 7, 7, 128)    110592      activation_110[0][0]
# __________________________________________________________________________________________________
# batch_normalization_111 (BatchN (None, 7, 7, 128)    512         conv2d_110[0][0]
# __________________________________________________________________________________________________
# activation_111 (Activation)     (None, 7, 7, 128)    0           batch_normalization_111[0][0]
# __________________________________________________________________________________________________
# conv2d_111 (Conv2D)             (None, 7, 7, 32)     36864       activation_111[0][0]
# __________________________________________________________________________________________________
# dropout_53 (Dropout)            (None, 7, 7, 32)     0           conv2d_111[0][0]
# __________________________________________________________________________________________________
# concatenate_53 (Concatenate)    (None, 7, 7, 896)    0           concatenate_52[0][0]
#                                                                  dropout_53[0][0]
# __________________________________________________________________________________________________
# batch_normalization_112 (BatchN (None, 7, 7, 896)    3584        concatenate_53[0][0]
# __________________________________________________________________________________________________
# activation_112 (Activation)     (None, 7, 7, 896)    0           batch_normalization_112[0][0]
# __________________________________________________________________________________________________
# conv2d_112 (Conv2D)             (None, 7, 7, 128)    114688      activation_112[0][0]
# __________________________________________________________________________________________________
# batch_normalization_113 (BatchN (None, 7, 7, 128)    512         conv2d_112[0][0]
# __________________________________________________________________________________________________
# activation_113 (Activation)     (None, 7, 7, 128)    0           batch_normalization_113[0][0]
# __________________________________________________________________________________________________
# conv2d_113 (Conv2D)             (None, 7, 7, 32)     36864       activation_113[0][0]
# __________________________________________________________________________________________________
# dropout_54 (Dropout)            (None, 7, 7, 32)     0           conv2d_113[0][0]
# __________________________________________________________________________________________________
# concatenate_54 (Concatenate)    (None, 7, 7, 928)    0           concatenate_53[0][0]
#                                                                  dropout_54[0][0]
# __________________________________________________________________________________________________
# batch_normalization_114 (BatchN (None, 7, 7, 928)    3712        concatenate_54[0][0]
# __________________________________________________________________________________________________
# activation_114 (Activation)     (None, 7, 7, 928)    0           batch_normalization_114[0][0]
# __________________________________________________________________________________________________
# conv2d_114 (Conv2D)             (None, 7, 7, 128)    118784      activation_114[0][0]
# __________________________________________________________________________________________________
# batch_normalization_115 (BatchN (None, 7, 7, 128)    512         conv2d_114[0][0]
# __________________________________________________________________________________________________
# activation_115 (Activation)     (None, 7, 7, 128)    0           batch_normalization_115[0][0]
# __________________________________________________________________________________________________
# conv2d_115 (Conv2D)             (None, 7, 7, 32)     36864       activation_115[0][0]
# __________________________________________________________________________________________________
# dropout_55 (Dropout)            (None, 7, 7, 32)     0           conv2d_115[0][0]
# __________________________________________________________________________________________________
# concatenate_55 (Concatenate)    (None, 7, 7, 960)    0           concatenate_54[0][0]
#                                                                  dropout_55[0][0]
# __________________________________________________________________________________________________
# batch_normalization_116 (BatchN (None, 7, 7, 960)    3840        concatenate_55[0][0]
# __________________________________________________________________________________________________
# activation_116 (Activation)     (None, 7, 7, 960)    0           batch_normalization_116[0][0]
# __________________________________________________________________________________________________
# conv2d_116 (Conv2D)             (None, 7, 7, 128)    122880      activation_116[0][0]
# __________________________________________________________________________________________________
# batch_normalization_117 (BatchN (None, 7, 7, 128)    512         conv2d_116[0][0]
# __________________________________________________________________________________________________
# activation_117 (Activation)     (None, 7, 7, 128)    0           batch_normalization_117[0][0]
# __________________________________________________________________________________________________
# conv2d_117 (Conv2D)             (None, 7, 7, 32)     36864       activation_117[0][0]
# __________________________________________________________________________________________________
# dropout_56 (Dropout)            (None, 7, 7, 32)     0           conv2d_117[0][0]
# __________________________________________________________________________________________________
# concatenate_56 (Concatenate)    (None, 7, 7, 992)    0           concatenate_55[0][0]
#                                                                  dropout_56[0][0]
# __________________________________________________________________________________________________
# batch_normalization_118 (BatchN (None, 7, 7, 992)    3968        concatenate_56[0][0]
# __________________________________________________________________________________________________
# activation_118 (Activation)     (None, 7, 7, 992)    0           batch_normalization_118[0][0]
# __________________________________________________________________________________________________
# conv2d_118 (Conv2D)             (None, 7, 7, 128)    126976      activation_118[0][0]
# __________________________________________________________________________________________________
# batch_normalization_119 (BatchN (None, 7, 7, 128)    512         conv2d_118[0][0]
# __________________________________________________________________________________________________
# activation_119 (Activation)     (None, 7, 7, 128)    0           batch_normalization_119[0][0]
# __________________________________________________________________________________________________
# conv2d_119 (Conv2D)             (None, 7, 7, 32)     36864       activation_119[0][0]
# __________________________________________________________________________________________________
# dropout_57 (Dropout)            (None, 7, 7, 32)     0           conv2d_119[0][0]
# __________________________________________________________________________________________________
# concatenate_57 (Concatenate)    (None, 7, 7, 1024)   0           concatenate_56[0][0]
#                                                                  dropout_57[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_6 (Glo (None, 1024)         0           concatenate_57[0][0]
# __________________________________________________________________________________________________
# reshape_6 (Reshape)             (None, 1, 1, 1024)   0           global_average_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# dense_12 (Dense)                (None, 1, 1, 64)     65536       reshape_6[0][0]
# __________________________________________________________________________________________________
# dense_13 (Dense)                (None, 1, 1, 1024)   65536       dense_12[0][0]
# __________________________________________________________________________________________________
# multiply_6 (Multiply)           (None, 7, 7, 1024)   0           concatenate_57[0][0]
#                                                                  dense_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_120 (BatchN (None, 7, 7, 1024)   4096        multiply_6[0][0]
# __________________________________________________________________________________________________
# activation_120 (Activation)     (None, 7, 7, 1024)   0           batch_normalization_120[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_7 (Glo (None, 1024)         0           activation_120[0][0]
# __________________________________________________________________________________________________
# dense_14 (Dense)                (None, 100)          102500      global_average_pooling2d_7[0][0]
# ==================================================================================================
# Total params: 7,486,116
# Trainable params: 7,402,468
# Non-trainable params: 83,648
# __________________________________________________________________________________________________

# %%
# 폴더 생성

os.makedirs(os.path.join(dir,'model_output',number,model.name), exist_ok=True)
os.makedirs(os.path.join(dir,'train_valid_output',number), exist_ok=True)

# %%
# 참고 : https://github.com/OverLordGoldDragon/keras-adamw

import sys
sys.path.append('/content/drive/My Drive/Colab Notebooks/Paper')
import utils
import optimizers_v2
from utils import get_weight_decays, fill_dict_in_order
from utils import reset_seeds, K_eval
from optimizers_v2 import AdamW, NadamW, SGDW

# %%
# top-5 accuracy 출력
import functools
top5_acc = functools.partial(ks.metrics.top_k_categorical_accuracy, k=5)
top5_acc.__name__ = 'top5_acc'

# %%
#optimizer = SGDW(model=model, use_cosine_annealing=False, total_iterations = len(x_train) // batch_sizes, nesterov=True, momentum=0.9)
optimizer = AdamW(model=model, use_cosine_annealing=False, total_iterations = len(x_train) // batch_sizes)
#optimizer = Adam()
filepath =  os.path.join(dir,'model_output',number,model.name,'{epoch:03d}.h5')

callbacks_list = [ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_weights_only=False, save_best_only=False, mode='min'),
                  ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_weights_only=False, save_best_only=False, mode='max'),
                  #ReduceLROnPlateau(monitor='val_loss',patience=3,factor=0.1,min_lr=1e-5),
                  LearningRateScheduler(lr_schedule,verbose=1)
                  ]
                  
model.compile(optimizer, loss = 'categorical_crossentropy', metrics=['accuracy',top5_acc,macro_f1score])

# %%
######## flow_from_directory
history = model.fit(train_generator, steps_per_epoch=int(len(x_train)/batch_sizes),  validation_data = valid_generator, epochs=epochs , verbose=1 , callbacks = callbacks_list , validation_steps=int(len(x_valid)/batch_sizes))
# Out:
# Learning rate:  0.001
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 1/70
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_1/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_2/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_3/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_4/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_5/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_6/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_7/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_8/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_9/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_10/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_11/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_12/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for dense/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for dense_1/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_13/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for dense_2/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for dense_3/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_14/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_15/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_16/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_17/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_18/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_19/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_20/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_21/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_22/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_23/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_24/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_25/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_26/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_27/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_28/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_29/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_30/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_31/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_32/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_33/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_34/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_35/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_36/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_37/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for dense_4/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for dense_5/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_38/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for dense_6/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for dense_7/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_39/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_40/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_41/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_42/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_43/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_44/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_45/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_46/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_47/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_48/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_49/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_50/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_51/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_52/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_53/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_54/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_55/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_56/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_57/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_58/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_59/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_60/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_61/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_62/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_63/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_64/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_65/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_66/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_67/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_68/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_69/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_70/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_71/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_72/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_73/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_74/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_75/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_76/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_77/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_78/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_79/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_80/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_81/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_82/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_83/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_84/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_85/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_86/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for dense_8/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for dense_9/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_87/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for dense_10/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for dense_11/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_88/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_89/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_90/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_91/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_92/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_93/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_94/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_95/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_96/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_97/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_98/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_99/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_100/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_101/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_102/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_103/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_104/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_105/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_106/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_107/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_108/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_109/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_110/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_111/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_112/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_113/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_114/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_115/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_116/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_117/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_118/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_119/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for dense_12/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for dense_13/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for dense_14/kernel:0
# 701/701 [==============================] - ETA: 0s - loss: 3.6351 - accuracy: 0.1425 - top5_acc: 0.3845 - macro_f1score: 0.0089
# Epoch 00001: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_DenseNet121/001.h5
#
# Epoch 00001: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_DenseNet121/001.h5
# 701/701 [==============================] - 12347s 18s/step - loss: 3.6351 - accuracy: 0.1425 - top5_acc: 0.3845 - macro_f1score: 0.0089 - val_loss: 3.6765 - val_accuracy: 0.1572 - val_top5_acc: 0.4191 - val_macro_f1score: 0.0265
# Learning rate:  0.001
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 2/70
# 701/701 [==============================] - ETA: 0s - loss: 2.8803 - accuracy: 0.2733 - top5_acc: 0.5842 - macro_f1score: 0.0418
# Epoch 00002: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_DenseNet121/002.h5
#
# Epoch 00002: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_DenseNet121/002.h5
# 701/701 [==============================] - 746s 1s/step - loss: 2.8803 - accuracy: 0.2733 - top5_acc: 0.5842 - macro_f1score: 0.0418 - val_loss: 3.0829 - val_accuracy: 0.2581 - val_top5_acc: 0.5736 - val_macro_f1score: 0.0630
# Learning rate:  0.001
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 3/70
# 701/701 [==============================] - ETA: 0s - loss: 2.4415 - accuracy: 0.3628 - top5_acc: 0.6855 - macro_f1score: 0.0808
# Epoch 00003: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_DenseNet121/003.h5
#
# Epoch 00003: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_DenseNet121/003.h5
# 701/701 [==============================] - 735s 1s/step - loss: 2.4415 - accuracy: 0.3628 - top5_acc: 0.6855 - macro_f1score: 0.0808 - val_loss: 2.6699 - val_accuracy: 0.3325 - val_top5_acc: 0.6592 - val_macro_f1score: 0.0945
# Learning rate:  0.001
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 4/70
# 701/701 [==============================] - ETA: 0s - loss: 2.1485 - accuracy: 0.4261 - top5_acc: 0.7454 - macro_f1score: 0.1150
# Epoch 00004: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_DenseNet121/004.h5
#
# Epoch 00004: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_DenseNet121/004.h5
# 701/701 [==============================] - 729s 1s/step - loss: 2.1485 - accuracy: 0.4261 - top5_acc: 0.7454 - macro_f1score: 0.1150 - val_loss: 2.7725 - val_accuracy: 0.3364 - val_top5_acc: 0.6636 - val_macro_f1score: 0.1092
# Learning rate:  0.001
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 5/70
# 701/701 [==============================] - ETA: 0s - loss: 1.8967 - accuracy: 0.4818 - top5_acc: 0.7949 - macro_f1score: 0.1481
# Epoch 00005: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_DenseNet121/005.h5
#
# Epoch 00005: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_DenseNet121/005.h5
# 701/701 [==============================] - 724s 1s/step - loss: 1.8967 - accuracy: 0.4818 - top5_acc: 0.7949 - macro_f1score: 0.1481 - val_loss: 2.5681 - val_accuracy: 0.3857 - val_top5_acc: 0.6998 - val_macro_f1score: 0.1262
# Learning rate:  0.001
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 6/70
# 701/701 [==============================] - ETA: 0s - loss: 1.7069 - accuracy: 0.5261 - top5_acc: 0.8302 - macro_f1score: 0.1743
# Epoch 00006: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_DenseNet121/006.h5
#
# Epoch 00006: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_DenseNet121/006.h5
# 701/701 [==============================] - 721s 1s/step - loss: 1.7069 - accuracy: 0.5261 - top5_acc: 0.8302 - macro_f1score: 0.1743 - val_loss: 3.9424 - val_accuracy: 0.2371 - val_top5_acc: 0.5123 - val_macro_f1score: 0.0764
# Learning rate:  0.001
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 7/70
# 701/701 [==============================] - ETA: 0s - loss: 1.5616 - accuracy: 0.5595 - top5_acc: 0.8537 - macro_f1score: 0.1978
# Epoch 00007: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_DenseNet121/007.h5
#
# Epoch 00007: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_DenseNet121/007.h5
# 701/701 [==============================] - 718s 1s/step - loss: 1.5616 - accuracy: 0.5595 - top5_acc: 0.8537 - macro_f1score: 0.1978 - val_loss: 1.9689 - val_accuracy: 0.4836 - val_top5_acc: 0.7878 - val_macro_f1score: 0.1693
# Learning rate:  0.001
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 8/70
# 701/701 [==============================] - ETA: 0s - loss: 1.4207 - accuracy: 0.5969 - top5_acc: 0.8753 - macro_f1score: 0.2201
# Epoch 00008: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_DenseNet121/008.h5
#
# Epoch 00008: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_DenseNet121/008.h5
# 701/701 [==============================] - 716s 1s/step - loss: 1.4207 - accuracy: 0.5969 - top5_acc: 0.8753 - macro_f1score: 0.2201 - val_loss: 2.1610 - val_accuracy: 0.4426 - val_top5_acc: 0.7702 - val_macro_f1score: 0.1610
# Learning rate:  0.001
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 9/70
# 701/701 [==============================] - ETA: 0s - loss: 1.3216 - accuracy: 0.6219 - top5_acc: 0.8900 - macro_f1score: 0.2376
# Epoch 00009: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_DenseNet121/009.h5
#
# Epoch 00009: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_DenseNet121/009.h5
# 701/701 [==============================] - 717s 1s/step - loss: 1.3216 - accuracy: 0.6219 - top5_acc: 0.8900 - macro_f1score: 0.2376 - val_loss: 1.9126 - val_accuracy: 0.4968 - val_top5_acc: 0.8068 - val_macro_f1score: 0.1930
# Learning rate:  0.001
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 10/70
# 701/701 [==============================] - ETA: 0s - loss: 1.2281 - accuracy: 0.6442 - top5_acc: 0.9039 - macro_f1score: 0.2529
# Epoch 00010: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_DenseNet121/010.h5
#
# Epoch 00010: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_DenseNet121/010.h5
# 701/701 [==============================] - 716s 1s/step - loss: 1.2281 - accuracy: 0.6442 - top5_acc: 0.9039 - macro_f1score: 0.2529 - val_loss: 2.0309 - val_accuracy: 0.4951 - val_top5_acc: 0.8058 - val_macro_f1score: 0.1965
# Learning rate:  0.001
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 11/70
# 701/701 [==============================] - ETA: 0s - loss: 1.1495 - accuracy: 0.6617 - top5_acc: 0.9153 - macro_f1score: 0.2648
# Epoch 00011: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_DenseNet121/011.h5
#
# Epoch 00011: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_DenseNet121/011.h5
# 701/701 [==============================] - 711s 1s/step - loss: 1.1495 - accuracy: 0.6617 - top5_acc: 0.9153 - macro_f1score: 0.2648 - val_loss: 1.9074 - val_accuracy: 0.5107 - val_top5_acc: 0.8024 - val_macro_f1score: 0.1993
# Learning rate:  0.001
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 12/70
# 701/701 [==============================] - ETA: 0s - loss: 1.0730 - accuracy: 0.6840 - top5_acc: 0.9235 - macro_f1score: 0.2778
# Epoch 00012: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_DenseNet121/012.h5
#
# Epoch 00012: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_DenseNet121/012.h5
# 701/701 [==============================] - 710s 1s/step - loss: 1.0730 - accuracy: 0.6840 - top5_acc: 0.9235 - macro_f1score: 0.2778 - val_loss: 2.0419 - val_accuracy: 0.5049 - val_top5_acc: 0.8012 - val_macro_f1score: 0.2042
# Learning rate:  0.001
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 13/70
# 701/701 [==============================] - ETA: 0s - loss: 1.0062 - accuracy: 0.7005 - top5_acc: 0.9313 - macro_f1score: 0.2907
# Epoch 00013: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_DenseNet121/013.h5
#
# Epoch 00013: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_DenseNet121/013.h5
# 701/701 [==============================] - 712s 1s/step - loss: 1.0062 - accuracy: 0.7005 - top5_acc: 0.9313 - macro_f1score: 0.2907 - val_loss: 2.0639 - val_accuracy: 0.4988 - val_top5_acc: 0.7909 - val_macro_f1score: 0.2005
# Learning rate:  0.001
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 14/70
# 701/701 [==============================] - ETA: 0s - loss: 0.9405 - accuracy: 0.7189 - top5_acc: 0.9406 - macro_f1score: 0.3018
# Epoch 00014: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_DenseNet121/014.h5
#
# Epoch 00014: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_DenseNet121/014.h5
# 701/701 [==============================] - 713s 1s/step - loss: 0.9405 - accuracy: 0.7189 - top5_acc: 0.9406 - macro_f1score: 0.3018 - val_loss: 1.8564 - val_accuracy: 0.5247 - val_top5_acc: 0.8159 - val_macro_f1score: 0.2146
# Learning rate:  0.001
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 15/70
# 701/701 [==============================] - ETA: 0s - loss: 0.8850 - accuracy: 0.7333 - top5_acc: 0.9462 - macro_f1score: 0.3122
# Epoch 00015: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_DenseNet121/015.h5
#
# Epoch 00015: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_DenseNet121/015.h5
# 701/701 [==============================] - 713s 1s/step - loss: 0.8850 - accuracy: 0.7333 - top5_acc: 0.9462 - macro_f1score: 0.3122 - val_loss: 2.8227 - val_accuracy: 0.4250 - val_top5_acc: 0.7280 - val_macro_f1score: 0.1712
# Learning rate:  0.001
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 16/70
# 701/701 [==============================] - ETA: 0s - loss: 0.8304 - accuracy: 0.7500 - top5_acc: 0.9517 - macro_f1score: 0.3211
# Epoch 00016: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_DenseNet121/016.h5
#
# Epoch 00016: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_DenseNet121/016.h5
# 701/701 [==============================] - 714s 1s/step - loss: 0.8304 - accuracy: 0.7500 - top5_acc: 0.9517 - macro_f1score: 0.3211 - val_loss: 1.9443 - val_accuracy: 0.5324 - val_top5_acc: 0.8204 - val_macro_f1score: 0.2222
# Learning rate:  0.001
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 17/70
# 701/701 [==============================] - ETA: 0s - loss: 0.7780 - accuracy: 0.7620 - top5_acc: 0.9571 - macro_f1score: 0.3295
# Epoch 00017: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_DenseNet121/017.h5
#
# Epoch 00017: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_DenseNet121/017.h5
# 701/701 [==============================] - 712s 1s/step - loss: 0.7780 - accuracy: 0.7620 - top5_acc: 0.9571 - macro_f1score: 0.3295 - val_loss: 2.0568 - val_accuracy: 0.5184 - val_top5_acc: 0.8121 - val_macro_f1score: 0.2130
# Learning rate:  0.001
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 18/70
# 701/701 [==============================] - ETA: 0s - loss: 0.7291 - accuracy: 0.7764 - top5_acc: 0.9628 - macro_f1score: 0.3374
# Epoch 00018: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_DenseNet121/018.h5
#
# Epoch 00018: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_DenseNet121/018.h5
# 701/701 [==============================] - 712s 1s/step - loss: 0.7291 - accuracy: 0.7764 - top5_acc: 0.9628 - macro_f1score: 0.3374 - val_loss: 1.8592 - val_accuracy: 0.5415 - val_top5_acc: 0.8309 - val_macro_f1score: 0.2263
# Learning rate:  0.001
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 19/70
# 701/701 [==============================] - ETA: 0s - loss: 0.6785 - accuracy: 0.7895 - top5_acc: 0.9689 - macro_f1score: 0.3459
# Epoch 00019: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_DenseNet121/019.h5
#
# Epoch 00019: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_DenseNet121/019.h5
# 701/701 [==============================] - 709s 1s/step - loss: 0.6785 - accuracy: 0.7895 - top5_acc: 0.9689 - macro_f1score: 0.3459 - val_loss: 1.7491 - val_accuracy: 0.5619 - val_top5_acc: 0.8554 - val_macro_f1score: 0.2381
# Learning rate:  0.001
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 20/70
# 701/701 [==============================] - ETA: 0s - loss: 0.6407 - accuracy: 0.7989 - top5_acc: 0.9720 - macro_f1score: 0.3516
# Epoch 00020: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_DenseNet121/020.h5
#
# Epoch 00020: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_DenseNet121/020.h5
# 701/701 [==============================] - 711s 1s/step - loss: 0.6407 - accuracy: 0.7989 - top5_acc: 0.9720 - macro_f1score: 0.3516 - val_loss: 1.9094 - val_accuracy: 0.5405 - val_top5_acc: 0.8345 - val_macro_f1score: 0.2301
# Learning rate:  0.001
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 21/70
# 701/701 [==============================] - ETA: 0s - loss: 0.6034 - accuracy: 0.8120 - top5_acc: 0.9746 - macro_f1score: 0.3597
# Epoch 00021: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_DenseNet121/021.h5
#
# Epoch 00021: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_DenseNet121/021.h5
# 701/701 [==============================] - 709s 1s/step - loss: 0.6034 - accuracy: 0.8120 - top5_acc: 0.9746 - macro_f1score: 0.3597 - val_loss: 1.8559 - val_accuracy: 0.5572 - val_top5_acc: 0.8406 - val_macro_f1score: 0.2380
# Learning rate:  0.001
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 22/70
# 701/701 [==============================] - ETA: 0s - loss: 0.5632 - accuracy: 0.8232 - top5_acc: 0.9783 - macro_f1score: 0.3690
# Epoch 00022: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_DenseNet121/022.h5
#
# Epoch 00022: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_DenseNet121/022.h5
# 701/701 [==============================] - 707s 1s/step - loss: 0.5632 - accuracy: 0.8232 - top5_acc: 0.9783 - macro_f1score: 0.3690 - val_loss: 2.1622 - val_accuracy: 0.5352 - val_top5_acc: 0.8210 - val_macro_f1score: 0.2292
# Learning rate:  0.001
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 23/70
# 701/701 [==============================] - ETA: 0s - loss: 0.5396 - accuracy: 0.8302 - top5_acc: 0.9807 - macro_f1score: 0.3726
# Epoch 00023: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_DenseNet121/023.h5
#
# Epoch 00023: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_DenseNet121/023.h5
# 701/701 [==============================] - 707s 1s/step - loss: 0.5396 - accuracy: 0.8302 - top5_acc: 0.9807 - macro_f1score: 0.3726 - val_loss: 1.7790 - val_accuracy: 0.5797 - val_top5_acc: 0.8521 - val_macro_f1score: 0.2508
# Learning rate:  0.001
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 24/70
# 701/701 [==============================] - ETA: 0s - loss: 0.4987 - accuracy: 0.8428 - top5_acc: 0.9842 - macro_f1score: 0.3798
# Epoch 00024: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_DenseNet121/024.h5
#
# Epoch 00024: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_DenseNet121/024.h5
# 701/701 [==============================] - 711s 1s/step - loss: 0.4987 - accuracy: 0.8428 - top5_acc: 0.9842 - macro_f1score: 0.3798 - val_loss: 1.6988 - val_accuracy: 0.6102 - val_top5_acc: 0.8701 - val_macro_f1score: 0.2694
# Learning rate:  0.001
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 25/70
# 701/701 [==============================] - ETA: 0s - loss: 0.4837 - accuracy: 0.8464 - top5_acc: 0.9846 - macro_f1score: 0.3827
# Epoch 00025: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_DenseNet121/025.h5
#
# Epoch 00025: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_DenseNet121/025.h5
# 701/701 [==============================] - 712s 1s/step - loss: 0.4837 - accuracy: 0.8464 - top5_acc: 0.9846 - macro_f1score: 0.3827 - val_loss: 1.9316 - val_accuracy: 0.5930 - val_top5_acc: 0.8580 - val_macro_f1score: 0.2598
# Learning rate:  0.001
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 26/70
# 701/701 [==============================] - ETA: 0s - loss: 0.4506 - accuracy: 0.8541 - top5_acc: 0.9871 - macro_f1score: 0.3900
# Epoch 00026: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_DenseNet121/026.h5
#
# Epoch 00026: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_DenseNet121/026.h5
# 701/701 [==============================] - 714s 1s/step - loss: 0.4506 - accuracy: 0.8541 - top5_acc: 0.9871 - macro_f1score: 0.3900 - val_loss: 1.9577 - val_accuracy: 0.5678 - val_top5_acc: 0.8471 - val_macro_f1score: 0.2473
# Learning rate:  0.001
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 27/70
# 701/701 [==============================] - ETA: 0s - loss: 0.4334 - accuracy: 0.8600 - top5_acc: 0.9881 - macro_f1score: 0.3913
# Epoch 00027: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_DenseNet121/027.h5
#
# Epoch 00027: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_DenseNet121/027.h5
# 701/701 [==============================] - 713s 1s/step - loss: 0.4334 - accuracy: 0.8600 - top5_acc: 0.9881 - macro_f1score: 0.3913 - val_loss: 1.7384 - val_accuracy: 0.5947 - val_top5_acc: 0.8665 - val_macro_f1score: 0.2622
# Learning rate:  0.001
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 28/70
# 701/701 [==============================] - ETA: 0s - loss: 0.4146 - accuracy: 0.8667 - top5_acc: 0.9890 - macro_f1score: 0.3970
# Epoch 00028: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_DenseNet121/028.h5
#
# Epoch 00028: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_DenseNet121/028.h5
# 701/701 [==============================] - 711s 1s/step - loss: 0.4146 - accuracy: 0.8667 - top5_acc: 0.9890 - macro_f1score: 0.3970 - val_loss: 1.9618 - val_accuracy: 0.5858 - val_top5_acc: 0.8461 - val_macro_f1score: 0.2526
# Learning rate:  0.001
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 29/70
# 701/701 [==============================] - ETA: 0s - loss: 0.3945 - accuracy: 0.8730 - top5_acc: 0.9905 - macro_f1score: 0.4006
# Epoch 00029: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_DenseNet121/029.h5
#
# Epoch 00029: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_DenseNet121/029.h5
# 701/701 [==============================] - 712s 1s/step - loss: 0.3945 - accuracy: 0.8730 - top5_acc: 0.9905 - macro_f1score: 0.4006 - val_loss: 1.9530 - val_accuracy: 0.5821 - val_top5_acc: 0.8592 - val_macro_f1score: 0.2575
# Learning rate:  0.001
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 30/70
# 701/701 [==============================] - ETA: 0s - loss: 0.3642 - accuracy: 0.8831 - top5_acc: 0.9922 - macro_f1score: 0.4065
# Epoch 00030: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_DenseNet121/030.h5
#
# Epoch 00030: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_DenseNet121/030.h5
# 701/701 [==============================] - 712s 1s/step - loss: 0.3642 - accuracy: 0.8831 - top5_acc: 0.9922 - macro_f1score: 0.4065 - val_loss: 2.2628 - val_accuracy: 0.5433 - val_top5_acc: 0.8299 - val_macro_f1score: 0.2360
# Learning rate:  0.0001
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 31/70
# 701/701 [==============================] - ETA: 0s - loss: 0.1893 - accuracy: 0.9445 - top5_acc: 0.9981 - macro_f1score: 0.4406
# Epoch 00031: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_DenseNet121/031.h5
#
# Epoch 00031: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_DenseNet121/031.h5
# 701/701 [==============================] - 711s 1s/step - loss: 0.1893 - accuracy: 0.9445 - top5_acc: 0.9981 - macro_f1score: 0.4406 - val_loss: 1.3445 - val_accuracy: 0.6804 - val_top5_acc: 0.9094 - val_macro_f1score: 0.3026
# Learning rate:  0.0001
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 32/70
# 701/701 [==============================] - ETA: 0s - loss: 0.1262 - accuracy: 0.9677 - top5_acc: 0.9993 - macro_f1score: 0.4547
# Epoch 00032: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_DenseNet121/032.h5
#
# Epoch 00032: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_DenseNet121/032.h5
# 701/701 [==============================] - 711s 1s/step - loss: 0.1262 - accuracy: 0.9677 - top5_acc: 0.9993 - macro_f1score: 0.4547 - val_loss: 1.2876 - val_accuracy: 0.6883 - val_top5_acc: 0.9138 - val_macro_f1score: 0.3102
# Learning rate:  0.0001
#
# Epoch 00033: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 33/70
# 701/701 [==============================] - ETA: 0s - loss: 0.1096 - accuracy: 0.9739 - top5_acc: 0.9994 - macro_f1score: 0.4585
# Epoch 00033: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_DenseNet121/033.h5
#
# Epoch 00033: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_DenseNet121/033.h5
# 701/701 [==============================] - 708s 1s/step - loss: 0.1096 - accuracy: 0.9739 - top5_acc: 0.9994 - macro_f1score: 0.4585 - val_loss: 1.2868 - val_accuracy: 0.6897 - val_top5_acc: 0.9112 - val_macro_f1score: 0.3106
# Learning rate:  0.0001
#
# Epoch 00034: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 34/70
# 701/701 [==============================] - ETA: 0s - loss: 0.0958 - accuracy: 0.9784 - top5_acc: 0.9995 - macro_f1score: 0.4609
# Epoch 00034: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_DenseNet121/034.h5
#
# Epoch 00034: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_DenseNet121/034.h5
# 701/701 [==============================] - 711s 1s/step - loss: 0.0958 - accuracy: 0.9784 - top5_acc: 0.9995 - macro_f1score: 0.4609 - val_loss: 1.2649 - val_accuracy: 0.6924 - val_top5_acc: 0.9167 - val_macro_f1score: 0.3157
# Learning rate:  0.0001
#
# Epoch 00035: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 35/70
# 701/701 [==============================] - ETA: 0s - loss: 0.0887 - accuracy: 0.9809 - top5_acc: 0.9997 - macro_f1score: 0.4618
# Epoch 00035: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_DenseNet121/035.h5
#
# Epoch 00035: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_DenseNet121/035.h5
# 701/701 [==============================] - 710s 1s/step - loss: 0.0887 - accuracy: 0.9809 - top5_acc: 0.9997 - macro_f1score: 0.4618 - val_loss: 1.2848 - val_accuracy: 0.6843 - val_top5_acc: 0.9128 - val_macro_f1score: 0.3101
# Learning rate:  0.0001
#
# Epoch 00036: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 36/70
# 701/701 [==============================] - ETA: 0s - loss: 0.0825 - accuracy: 0.9829 - top5_acc: 0.9997 - macro_f1score: 0.4651
# Epoch 00036: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_DenseNet121/036.h5
#
# Epoch 00036: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_DenseNet121/036.h5
# 701/701 [==============================] - 712s 1s/step - loss: 0.0825 - accuracy: 0.9829 - top5_acc: 0.9997 - macro_f1score: 0.4651 - val_loss: 1.2917 - val_accuracy: 0.6859 - val_top5_acc: 0.9122 - val_macro_f1score: 0.3082
# Learning rate:  0.0001
#
# Epoch 00037: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 37/70
# 701/701 [==============================] - ETA: 0s - loss: 0.0766 - accuracy: 0.9846 - top5_acc: 0.9999 - macro_f1score: 0.4639
# Epoch 00037: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_DenseNet121/037.h5
#
# Epoch 00037: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_DenseNet121/037.h5
# 701/701 [==============================] - 714s 1s/step - loss: 0.0766 - accuracy: 0.9846 - top5_acc: 0.9999 - macro_f1score: 0.4639 - val_loss: 1.2735 - val_accuracy: 0.6871 - val_top5_acc: 0.9126 - val_macro_f1score: 0.3108
# Learning rate:  0.0001
#
# Epoch 00038: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 38/70
# 701/701 [==============================] - ETA: 0s - loss: 0.0721 - accuracy: 0.9860 - top5_acc: 0.9999 - macro_f1score: 0.4676
# Epoch 00038: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_DenseNet121/038.h5
#
# Epoch 00038: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_DenseNet121/038.h5
# 701/701 [==============================] - 712s 1s/step - loss: 0.0721 - accuracy: 0.9860 - top5_acc: 0.9999 - macro_f1score: 0.4676 - val_loss: 1.3055 - val_accuracy: 0.6865 - val_top5_acc: 0.9064 - val_macro_f1score: 0.3093
# Learning rate:  0.0001
#
# Epoch 00039: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 39/70
# 701/701 [==============================] - ETA: 0s - loss: 0.0718 - accuracy: 0.9862 - top5_acc: 0.9999 - macro_f1score: 0.4643
# Epoch 00039: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_DenseNet121/039.h5
#
# Epoch 00039: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_DenseNet121/039.h5
# 701/701 [==============================] - 707s 1s/step - loss: 0.0718 - accuracy: 0.9862 - top5_acc: 0.9999 - macro_f1score: 0.4643 - val_loss: 1.2874 - val_accuracy: 0.6893 - val_top5_acc: 0.9090 - val_macro_f1score: 0.3063
# Learning rate:  0.0001
#
# Epoch 00040: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 40/70
# 701/701 [==============================] - ETA: 0s - loss: 0.0674 - accuracy: 0.9871 - top5_acc: 0.9999 - macro_f1score: 0.4662
# Epoch 00040: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_DenseNet121/040.h5
#
# Epoch 00040: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_DenseNet121/040.h5
# 701/701 [==============================] - 707s 1s/step - loss: 0.0674 - accuracy: 0.9871 - top5_acc: 0.9999 - macro_f1score: 0.4662 - val_loss: 1.3262 - val_accuracy: 0.6788 - val_top5_acc: 0.9066 - val_macro_f1score: 0.3048
# Learning rate:  0.0001
#
# Epoch 00041: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 41/70
# 701/701 [==============================] - ETA: 0s - loss: 0.0643 - accuracy: 0.9878 - top5_acc: 0.9997 - macro_f1score: 0.4660
# Epoch 00041: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_DenseNet121/041.h5
#
# Epoch 00041: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_DenseNet121/041.h5
# 701/701 [==============================] - 708s 1s/step - loss: 0.0643 - accuracy: 0.9878 - top5_acc: 0.9997 - macro_f1score: 0.4660 - val_loss: 1.2764 - val_accuracy: 0.6869 - val_top5_acc: 0.9136 - val_macro_f1score: 0.3115
# Learning rate:  0.0001
#
# Epoch 00042: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 42/70
# 701/701 [==============================] - ETA: 0s - loss: 0.0599 - accuracy: 0.9896 - top5_acc: 1.0000 - macro_f1score: 0.4687
# Epoch 00042: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_DenseNet121/042.h5
#
# Epoch 00042: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_DenseNet121/042.h5
# 701/701 [==============================] - 713s 1s/step - loss: 0.0599 - accuracy: 0.9896 - top5_acc: 1.0000 - macro_f1score: 0.4687 - val_loss: 1.2968 - val_accuracy: 0.6911 - val_top5_acc: 0.9096 - val_macro_f1score: 0.3093
# Learning rate:  0.0001
#
# Epoch 00043: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 43/70
# 701/701 [==============================] - ETA: 0s - loss: 0.0602 - accuracy: 0.9892 - top5_acc: 0.9998 - macro_f1score: 0.4685
# Epoch 00043: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_DenseNet121/043.h5
#
# Epoch 00043: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_DenseNet121/043.h5
# 701/701 [==============================] - 719s 1s/step - loss: 0.0602 - accuracy: 0.9892 - top5_acc: 0.9998 - macro_f1score: 0.4685 - val_loss: 1.2680 - val_accuracy: 0.6944 - val_top5_acc: 0.9173 - val_macro_f1score: 0.3153
# Learning rate:  0.0001
#
# Epoch 00044: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 44/70
# 701/701 [==============================] - ETA: 0s - loss: 0.0567 - accuracy: 0.9901 - top5_acc: 0.9999 - macro_f1score: 0.4689
# Epoch 00044: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_DenseNet121/044.h5
#
# Epoch 00044: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_DenseNet121/044.h5
# 701/701 [==============================] - 738s 1s/step - loss: 0.0567 - accuracy: 0.9901 - top5_acc: 0.9999 - macro_f1score: 0.4689 - val_loss: 1.2931 - val_accuracy: 0.6920 - val_top5_acc: 0.9053 - val_macro_f1score: 0.3132
# Learning rate:  0.0001
#
# Epoch 00045: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 45/70
# 701/701 [==============================] - ETA: 0s - loss: 0.0535 - accuracy: 0.9908 - top5_acc: 0.9999 - macro_f1score: 0.4684
# Epoch 00045: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_DenseNet121/045.h5
#
# Epoch 00045: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_DenseNet121/045.h5
# 701/701 [==============================] - 733s 1s/step - loss: 0.0535 - accuracy: 0.9908 - top5_acc: 0.9999 - macro_f1score: 0.4684 - val_loss: 1.3180 - val_accuracy: 0.6889 - val_top5_acc: 0.9062 - val_macro_f1score: 0.3122
# Learning rate:  0.0001
#
# Epoch 00046: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 46/70
# 701/701 [==============================] - ETA: 0s - loss: 0.0539 - accuracy: 0.9908 - top5_acc: 0.9999 - macro_f1score: 0.4698
# Epoch 00046: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_DenseNet121/046.h5
#
# Epoch 00046: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_DenseNet121/046.h5
# 701/701 [==============================] - 731s 1s/step - loss: 0.0539 - accuracy: 0.9908 - top5_acc: 0.9999 - macro_f1score: 0.4698 - val_loss: 1.3227 - val_accuracy: 0.6871 - val_top5_acc: 0.9076 - val_macro_f1score: 0.3080
# Learning rate:  0.0001
#
# Epoch 00047: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 47/70
# 701/701 [==============================] - ETA: 0s - loss: 0.0517 - accuracy: 0.9913 - top5_acc: 1.0000 - macro_f1score: 0.4699
# Epoch 00047: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_DenseNet121/047.h5
#
# Epoch 00047: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_DenseNet121/047.h5
# 701/701 [==============================] - 736s 1s/step - loss: 0.0517 - accuracy: 0.9913 - top5_acc: 1.0000 - macro_f1score: 0.4699 - val_loss: 1.3067 - val_accuracy: 0.6950 - val_top5_acc: 0.9074 - val_macro_f1score: 0.3107
# Learning rate:  0.0001
#
# Epoch 00048: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 48/70
# 701/701 [==============================] - ETA: 0s - loss: 0.0510 - accuracy: 0.9916 - top5_acc: 0.9999 - macro_f1score: 0.4703
# Epoch 00048: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_DenseNet121/048.h5
#
# Epoch 00048: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_DenseNet121/048.h5
# 701/701 [==============================] - 739s 1s/step - loss: 0.0510 - accuracy: 0.9916 - top5_acc: 0.9999 - macro_f1score: 0.4703 - val_loss: 1.3172 - val_accuracy: 0.6901 - val_top5_acc: 0.9112 - val_macro_f1score: 0.3090
# Learning rate:  0.0001
#
# Epoch 00049: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 49/70
# 701/701 [==============================] - ETA: 0s - loss: 0.0500 - accuracy: 0.9911 - top5_acc: 0.9999 - macro_f1score: 0.4701
# Epoch 00049: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_DenseNet121/049.h5
#
# Epoch 00049: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_DenseNet121/049.h5
# 701/701 [==============================] - 746s 1s/step - loss: 0.0500 - accuracy: 0.9911 - top5_acc: 0.9999 - macro_f1score: 0.4701 - val_loss: 1.3214 - val_accuracy: 0.6940 - val_top5_acc: 0.9072 - val_macro_f1score: 0.3091
# Learning rate:  0.0001
#
# Epoch 00050: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 50/70
# 701/701 [==============================] - ETA: 0s - loss: 0.0505 - accuracy: 0.9908 - top5_acc: 1.0000 - macro_f1score: 0.4697
# Epoch 00050: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_DenseNet121/050.h5
#
# Epoch 00050: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_DenseNet121/050.h5
# 701/701 [==============================] - 747s 1s/step - loss: 0.0505 - accuracy: 0.9908 - top5_acc: 1.0000 - macro_f1score: 0.4697 - val_loss: 1.3641 - val_accuracy: 0.6855 - val_top5_acc: 0.9061 - val_macro_f1score: 0.3056
# Learning rate:  0.0001
#
# Epoch 00051: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 51/70
# 701/701 [==============================] - ETA: 0s - loss: 0.0481 - accuracy: 0.9921 - top5_acc: 1.0000 - macro_f1score: 0.4723
# Epoch 00051: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_DenseNet121/051.h5
#
# Epoch 00051: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_DenseNet121/051.h5
# 701/701 [==============================] - 748s 1s/step - loss: 0.0481 - accuracy: 0.9921 - top5_acc: 1.0000 - macro_f1score: 0.4723 - val_loss: 1.3161 - val_accuracy: 0.6956 - val_top5_acc: 0.9088 - val_macro_f1score: 0.3115
# Learning rate:  0.0001
#
# Epoch 00052: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 52/70
# 701/701 [==============================] - ETA: 0s - loss: 0.0491 - accuracy: 0.9914 - top5_acc: 0.9999 - macro_f1score: 0.4696
# Epoch 00052: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_DenseNet121/052.h5
#
# Epoch 00052: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_DenseNet121/052.h5
# 701/701 [==============================] - 747s 1s/step - loss: 0.0491 - accuracy: 0.9914 - top5_acc: 0.9999 - macro_f1score: 0.4696 - val_loss: 1.3404 - val_accuracy: 0.6851 - val_top5_acc: 0.9061 - val_macro_f1score: 0.3135
# Learning rate:  0.0001
#
# Epoch 00053: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 53/70
# 701/701 [==============================] - ETA: 0s - loss: 0.0474 - accuracy: 0.9914 - top5_acc: 0.9999 - macro_f1score: 0.4712
# Epoch 00053: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_DenseNet121/053.h5
#
# Epoch 00053: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_DenseNet121/053.h5
# 701/701 [==============================] - 750s 1s/step - loss: 0.0474 - accuracy: 0.9914 - top5_acc: 0.9999 - macro_f1score: 0.4712 - val_loss: 1.3692 - val_accuracy: 0.6833 - val_top5_acc: 0.9043 - val_macro_f1score: 0.3074
# Learning rate:  0.0001
#
# Epoch 00054: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 54/70
# 701/701 [==============================] - ETA: 0s - loss: 0.0447 - accuracy: 0.9922 - top5_acc: 0.9999 - macro_f1score: 0.4708
# Epoch 00054: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_DenseNet121/054.h5
#
# Epoch 00054: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_DenseNet121/054.h5
# 701/701 [==============================] - 750s 1s/step - loss: 0.0447 - accuracy: 0.9922 - top5_acc: 0.9999 - macro_f1score: 0.4708 - val_loss: 1.4036 - val_accuracy: 0.6792 - val_top5_acc: 0.8964 - val_macro_f1score: 0.3074
# Learning rate:  0.0001
#
# Epoch 00055: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 55/70
# 701/701 [==============================] - ETA: 0s - loss: 0.0450 - accuracy: 0.9922 - top5_acc: 1.0000 - macro_f1score: 0.4707
# Epoch 00055: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_DenseNet121/055.h5
#
# Epoch 00055: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_DenseNet121/055.h5
# 701/701 [==============================] - 750s 1s/step - loss: 0.0450 - accuracy: 0.9922 - top5_acc: 1.0000 - macro_f1score: 0.4707 - val_loss: 1.4547 - val_accuracy: 0.6653 - val_top5_acc: 0.8946 - val_macro_f1score: 0.2973
# Learning rate:  0.0001
#
# Epoch 00056: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 56/70
# 701/701 [==============================] - ETA: 0s - loss: 0.0484 - accuracy: 0.9904 - top5_acc: 0.9999 - macro_f1score: 0.4685
# Epoch 00056: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_DenseNet121/056.h5
#
# Epoch 00056: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_DenseNet121/056.h5
# 701/701 [==============================] - 746s 1s/step - loss: 0.0484 - accuracy: 0.9904 - top5_acc: 0.9999 - macro_f1score: 0.4685 - val_loss: 1.4779 - val_accuracy: 0.6671 - val_top5_acc: 0.8966 - val_macro_f1score: 0.2993
# Learning rate:  0.0001
#
# Epoch 00057: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 57/70
# 701/701 [==============================] - ETA: 0s - loss: 0.0434 - accuracy: 0.9924 - top5_acc: 1.0000 - macro_f1score: 0.4717
# Epoch 00057: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_DenseNet121/057.h5
#
# Epoch 00057: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_DenseNet121/057.h5
# 701/701 [==============================] - 745s 1s/step - loss: 0.0434 - accuracy: 0.9924 - top5_acc: 1.0000 - macro_f1score: 0.4717 - val_loss: 1.4770 - val_accuracy: 0.6746 - val_top5_acc: 0.8942 - val_macro_f1score: 0.3033
# Learning rate:  0.0001
#
# Epoch 00058: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 58/70
# 701/701 [==============================] - ETA: 0s - loss: 0.0461 - accuracy: 0.9916 - top5_acc: 1.0000 - macro_f1score: 0.4690
# Epoch 00058: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_DenseNet121/058.h5
#
# Epoch 00058: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_DenseNet121/058.h5
# 701/701 [==============================] - 736s 1s/step - loss: 0.0461 - accuracy: 0.9916 - top5_acc: 1.0000 - macro_f1score: 0.4690 - val_loss: 1.4096 - val_accuracy: 0.6816 - val_top5_acc: 0.8995 - val_macro_f1score: 0.3052
# Learning rate:  0.0001
#
# Epoch 00059: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 59/70
# 701/701 [==============================] - ETA: 0s - loss: 0.0449 - accuracy: 0.9919 - top5_acc: 1.0000 - macro_f1score: 0.4699
# Epoch 00059: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_DenseNet121/059.h5
#
# Epoch 00059: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_DenseNet121/059.h5
# 701/701 [==============================] - 735s 1s/step - loss: 0.0449 - accuracy: 0.9919 - top5_acc: 1.0000 - macro_f1score: 0.4699 - val_loss: 1.4304 - val_accuracy: 0.6774 - val_top5_acc: 0.8995 - val_macro_f1score: 0.3039
# Learning rate:  0.0001
#
# Epoch 00060: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 60/70
# 701/701 [==============================] - ETA: 0s - loss: 0.0444 - accuracy: 0.9912 - top5_acc: 0.9999 - macro_f1score: 0.4689
# Epoch 00060: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_DenseNet121/060.h5
#
# Epoch 00060: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_DenseNet121/060.h5
# 701/701 [==============================] - 735s 1s/step - loss: 0.0444 - accuracy: 0.9912 - top5_acc: 0.9999 - macro_f1score: 0.4689 - val_loss: 1.4568 - val_accuracy: 0.6746 - val_top5_acc: 0.8932 - val_macro_f1score: 0.3052
# Learning rate:  1e-05
#
# Epoch 00061: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 61/70
# 701/701 [==============================] - ETA: 0s - loss: 0.0358 - accuracy: 0.9945 - top5_acc: 1.0000 - macro_f1score: 0.4709
# Epoch 00061: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_DenseNet121/061.h5
#
# Epoch 00061: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_DenseNet121/061.h5
# 701/701 [==============================] - 737s 1s/step - loss: 0.0358 - accuracy: 0.9945 - top5_acc: 1.0000 - macro_f1score: 0.4709 - val_loss: 1.3636 - val_accuracy: 0.6849 - val_top5_acc: 0.9029 - val_macro_f1score: 0.3102
# Learning rate:  1e-05
#
# Epoch 00062: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 62/70
# 701/701 [==============================] - ETA: 0s - loss: 0.0332 - accuracy: 0.9960 - top5_acc: 1.0000 - macro_f1score: 0.4732
# Epoch 00062: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_DenseNet121/062.h5
#
# Epoch 00062: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_DenseNet121/062.h5
# 701/701 [==============================] - 739s 1s/step - loss: 0.0332 - accuracy: 0.9960 - top5_acc: 1.0000 - macro_f1score: 0.4732 - val_loss: 1.3153 - val_accuracy: 0.6919 - val_top5_acc: 0.9039 - val_macro_f1score: 0.3136
# Learning rate:  1e-05
#
# Epoch 00063: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 63/70
# 701/701 [==============================] - ETA: 0s - loss: 0.0345 - accuracy: 0.9963 - top5_acc: 1.0000 - macro_f1score: 0.4721
# Epoch 00063: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_DenseNet121/063.h5
#
# Epoch 00063: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_DenseNet121/063.h5
# 701/701 [==============================] - 735s 1s/step - loss: 0.0345 - accuracy: 0.9963 - top5_acc: 1.0000 - macro_f1score: 0.4721 - val_loss: 1.3114 - val_accuracy: 0.6917 - val_top5_acc: 0.9027 - val_macro_f1score: 0.3113
# Learning rate:  1e-05
#
# Epoch 00064: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 64/70
# 701/701 [==============================] - ETA: 0s - loss: 0.0378 - accuracy: 0.9959 - top5_acc: 0.9999 - macro_f1score: 0.4715
# Epoch 00064: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_DenseNet121/064.h5
#
# Epoch 00064: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_DenseNet121/064.h5
# 701/701 [==============================] - 736s 1s/step - loss: 0.0378 - accuracy: 0.9959 - top5_acc: 0.9999 - macro_f1score: 0.4715 - val_loss: 1.3189 - val_accuracy: 0.6873 - val_top5_acc: 0.9001 - val_macro_f1score: 0.3062
# Learning rate:  1e-05
#
# Epoch 00065: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 65/70
# 701/701 [==============================] - ETA: 0s - loss: 0.0399 - accuracy: 0.9955 - top5_acc: 1.0000 - macro_f1score: 0.4711
# Epoch 00065: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_DenseNet121/065.h5
#
# Epoch 00065: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_DenseNet121/065.h5
# 701/701 [==============================] - 736s 1s/step - loss: 0.0399 - accuracy: 0.9955 - top5_acc: 1.0000 - macro_f1score: 0.4711 - val_loss: 1.2998 - val_accuracy: 0.6887 - val_top5_acc: 0.8995 - val_macro_f1score: 0.3092
# Learning rate:  1e-05
#
# Epoch 00066: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 66/70
# 701/701 [==============================] - ETA: 0s - loss: 0.0419 - accuracy: 0.9959 - top5_acc: 1.0000 - macro_f1score: 0.4713
# Epoch 00066: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_DenseNet121/066.h5
#
# Epoch 00066: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_DenseNet121/066.h5
# 701/701 [==============================] - 735s 1s/step - loss: 0.0419 - accuracy: 0.9959 - top5_acc: 1.0000 - macro_f1score: 0.4713 - val_loss: 1.3003 - val_accuracy: 0.6861 - val_top5_acc: 0.8985 - val_macro_f1score: 0.3049
# Learning rate:  1e-05
#
# Epoch 00067: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 67/70
# 701/701 [==============================] - ETA: 0s - loss: 0.0430 - accuracy: 0.9964 - top5_acc: 1.0000 - macro_f1score: 0.4724
# Epoch 00067: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_DenseNet121/067.h5
#
# Epoch 00067: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_DenseNet121/067.h5
# 701/701 [==============================] - 735s 1s/step - loss: 0.0430 - accuracy: 0.9964 - top5_acc: 1.0000 - macro_f1score: 0.4724 - val_loss: 1.2861 - val_accuracy: 0.6847 - val_top5_acc: 0.8970 - val_macro_f1score: 0.3055
# Learning rate:  1e-05
#
# Epoch 00068: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 68/70
# 701/701 [==============================] - ETA: 0s - loss: 0.0465 - accuracy: 0.9958 - top5_acc: 1.0000 - macro_f1score: 0.4736
# Epoch 00068: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_DenseNet121/068.h5
#
# Epoch 00068: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_DenseNet121/068.h5
# 701/701 [==============================] - 732s 1s/step - loss: 0.0465 - accuracy: 0.9958 - top5_acc: 1.0000 - macro_f1score: 0.4736 - val_loss: 1.2875 - val_accuracy: 0.6845 - val_top5_acc: 0.8970 - val_macro_f1score: 0.3026
# Learning rate:  1e-05
#
# Epoch 00069: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 69/70
# 701/701 [==============================] - ETA: 0s - loss: 0.0488 - accuracy: 0.9965 - top5_acc: 1.0000 - macro_f1score: 0.4715
# Epoch 00069: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_DenseNet121/069.h5
#
# Epoch 00069: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_DenseNet121/069.h5
# 701/701 [==============================] - 737s 1s/step - loss: 0.0488 - accuracy: 0.9965 - top5_acc: 1.0000 - macro_f1score: 0.4715 - val_loss: 1.2870 - val_accuracy: 0.6847 - val_top5_acc: 0.8936 - val_macro_f1score: 0.3042
# Learning rate:  1e-05
#
# Epoch 00070: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 70/70
# 701/701 [==============================] - ETA: 0s - loss: 0.0529 - accuracy: 0.9960 - top5_acc: 1.0000 - macro_f1score: 0.4717
# Epoch 00070: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_DenseNet121/070.h5
#
# Epoch 00070: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SE_DenseNet121/070.h5
# 701/701 [==============================] - 740s 1s/step - loss: 0.0529 - accuracy: 0.9960 - top5_acc: 1.0000 - macro_f1score: 0.4717 - val_loss: 1.2666 - val_accuracy: 0.6837 - val_top5_acc: 0.8973 - val_macro_f1score: 0.2962

# %% [markdown]
# ### 2) SE-DenseNet121 Evaluate

# %%
# 1. epoch=maximum
loss , acc, top5_acc, mf1 = model.evaluate(test_generator,steps=int(len(x_test)/batch_sizes))
print('[Test Loss: %.4f /  Test Top-1 Accuracy: %.4f / Test Top-5 Accuracy: %.4f / Test Macro f1: %.4f]\n' % (loss,acc,top5_acc,mf1))

# %%
loss=history.history['loss']
val_loss=history.history['val_loss']
acc=history.history['accuracy']
val_acc=history.history['val_accuracy']
top5_acc=history.history['top5_acc']
val_top5_acc=history.history['val_top5_acc']
f1=history.history['macro_f1score']
val_f1=history.history['val_macro_f1score']
epochs=range(1,len(acc)+1)

data = np.array([epochs,loss,val_loss,acc,val_acc,top5_acc,val_top5_acc,f1,val_f1]).T

# %%
# data save
# epochs, loss, val_loss, acc, val_acc, f1, val_f1

np.savetxt(os.path.join(dir,'train_valid_output',number,model.name+'.txt'),data)

# %%
# data import
data = np.loadtxt(os.path.join(dir,'train_valid_output',number,'SE_DenseNet121.txt'))

# %%
epochs=data[:,0]
loss=data[:,1]
val_loss=data[:,2]
acc=data[:,3]
val_acc=data[:,4]
top5_acc=data[:,5]
val_top5_acc=data[:,6]

# %%
plt.plot(epochs[1:],acc[1:],'b',label='Training 1-Acc')
plt.plot(epochs[1:],val_acc[1:],'r',label='Validation 1-Acc')
plt.title('Training and Validation Top-1 Accuracy')
plt.legend()
plt.figure()

plt.plot(epochs[1:],top5_acc[1:],'b',label='Training 5-Acc')
plt.plot(epochs[1:],val_top5_acc[1:],'r',label='Validation 5-Acc')
plt.title('Training and Validation Top-5 Accuracy')
plt.legend()
plt.figure()

plt.plot(epochs[10:],loss[10:],'b',label='Training Loss')
plt.plot(epochs[10:],val_loss[10:],'r',label='Validation Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()

# %%
# 이 아래는 내가 인위적으로 살펴보고 싶은 epoch에 대해서 결과값 출력 / SE-DenseNet121

# %%
# 참고 : https://github.com/OverLordGoldDragon/keras-adamw

import sys
sys.path.append('/content/drive/My Drive/Colab Notebooks/Paper')
import utils
import optimizers_v2
from utils import get_weight_decays, fill_dict_in_order
from utils import reset_seeds, K_eval
from optimizers_v2 import AdamW, NadamW, SGDW

# %%
# top-5 accuracy 출력
import functools
top5_acc = functools.partial(ks.metrics.top_k_categorical_accuracy, k=5)
top5_acc.__name__ = 'top5_acc'

# %%
model=load_model(os.path.join(dir,'model_output',number,'SE_DenseNet121','063.h5'),custom_objects={"macro_f1score": macro_f1score,"top5_acc":top5_acc, "AdamW":AdamW})

# %%
# 2. epoch=?
loss , acc, top5_acc, mf1 = model.evaluate(test_generator,steps=int(len(x_test)/batch_sizes))
print('[Test Loss: %.4f /  Test Top-1 Accuracy: %.4f / Test Top-5 Accuracy: %.4f / Test Macro f1: %.4f]\n' % (loss,acc,top5_acc,mf1))
# Out:
# 156/156 [==============================] - 2661s 17s/step - loss: 1.3299 - accuracy: 0.6856 - top5_acc: 0.8984 - macro_f1score: 0.3071
# [Test Loss: 1.3299 /  Test Top-1 Accuracy: 0.6856 / Test Top-5 Accuracy: 0.8984 / Test Macro f1: 0.3071]
