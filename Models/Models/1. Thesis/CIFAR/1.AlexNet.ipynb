# %% [markdown]
# # [AlexNet]

# %% [markdown]
# *KU LeeDongGyu*

# %% [markdown]
# ### Contents

# %% [markdown]
# 1. Data Preprocessing
# ```
# 1) Data Import
# 2) Data Augmentation
# ```
# 2. Support Functions & Almost Original AlexNet
# ```
# 1) Support Functions
# 2) Almost Original AlexNet
# 3) AlexNet Evaluate
# ```

# %% [markdown]
# ### Install Packages

# %% [markdown]
# ### Module

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/My Drive/Colab Notebooks/Paper
# Out:
# /content/drive/My Drive/Colab Notebooks/Paper

# %%
from lrn import LRN #만든 모듈, class
from f1score import macro_f1score, weighted_f1score

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import cv2
import tensorflow as tf
from tensorflow import keras as ks
from tensorflow.keras import backend as K 
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, Input, Concatenate, ZeroPadding2D ,GlobalMaxPooling2D, Reshape , Lambda , Add, Multiply
from tensorflow.keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D, Activation, BatchNormalization, AveragePooling2D , ZeroPadding2D, SeparableConv2D
from tensorflow.keras.layers import add
from tensorflow.keras.optimizers import Adam, RMSprop , SGD
from tensorflow.keras.callbacks import EarlyStopping , LearningRateScheduler, ModelCheckpoint, CSVLogger, Callback, ReduceLROnPlateau
from tensorflow.keras.regularizers import l1,l2,l1_l2
from tensorflow.keras.models import Model , load_model , Sequential
from tensorflow.keras.utils import plot_model , to_categorical, get_file
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
os.getcwd()
# Out:
# '/content/drive/My Drive/Colab Notebooks/Paper'

# %%
print(tf.__version__)
print(ks.__version__)
# Out:
# 2.3.0
# 2.4.0

# %%
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 10642536981667864402
# , name: "/device:XLA_CPU:0"
# device_type: "XLA_CPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 10412970638792817042
# physical_device_desc: "device: XLA_CPU device"
# , name: "/device:XLA_GPU:0"
# device_type: "XLA_GPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 14370776752351290200
# physical_device_desc: "device: XLA_GPU device"
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 15473775744
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 10739103853138683250
# physical_device_desc: "device: 0, name: Tesla V100-SXM2-16GB, pci bus id: 0000:00:04.0, compute capability: 7.0"
# ]

# %% [markdown]
# ## 1. Data Preprocessing
# ---

# %% [markdown]
# ### 1) Data Import

# %%
# 바꿔서 살펴 볼 것들
# CALTECH, CIFAR100, FER, MIT
data_name = 'CIFAR100'
gan_type = 'No_GAN'
number = '1'
size = 227 # sizes after cropping
super_size = 256 # sizes before cropping 
input_sizes = (size,size,3)
batch_sizes = 128
weight_decay = 1e-4
epochs = 70

# %%
# 참고 : https://stackoverflow.com/questions/32419510/how-to-get-reproducible-results-in-keras/52897216#52897216
# setting the seed number for random number generation for reproducibility.

from numpy.random import seed
import random


if number=='1':
    seed_num = 200225
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)
elif number=='2':
    seed_num = 727
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)
elif number=='3':
    seed_num = 115
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)
elif number=='4':
    seed_num = 501
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)
elif number=='5':
    seed_num = 517
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)

# %%
# data import

if data_name=='FER' :
    x_train =  np.zeros(28698)
    x_valid = np.zeros(3589)
    x_test = np.zeros(3588)
    classes = 7 
    tr_center = [0.50793296, 0.50793296, 0.50793296]
elif data_name=='MIT':
    x_train = np.zeros(12466)
    x_valid = np.zeros(1564)
    x_test = np.zeros(1590)
    classes = 67 
    tr_center = [0.47916578, 0.42029615, 0.36046057]
elif data_name=='CALTECH':
    x_train = np.zeros(24510)
    x_valid = np.zeros(2980)
    x_test = np.zeros(3118)
    classes = 257
    tr_center = [0.51397761, 0.49525248, 0.46555727]
elif data_name=='CIFAR100':
    x_train = np.zeros(44923)
    x_valid = np.zeros(5077)
    x_test = np.zeros(10000)
    classes = 100
    tr_center = [0.53442983, 0.51355958, 0.46462564]

# %%
dir = os.path.join(os.getcwd(),data_name,gan_type)

# %% [markdown]
# ### 2) Data Augmentation

# %%
# 참고 : https://jkjung-avt.github.io/keras-image-cropping/

def random_crop(img, random_crop_size):
    # Note: image_data_format is 'channel_last'
    assert img.shape[2] == 3 # img.shape[2] 가 3(rgb)이 아니면 assertion error 발생
    height, width = img.shape[0], img.shape[1]
    dy, dx = random_crop_size
    x = np.random.randint(0, width - dx + 1)
    y = np.random.randint(0, height - dy + 1)
    return img[y:(y+dy), x:(x+dx), :]


def crop_generator(batches, crop_length):
    """Take as input a Keras ImageGen (Iterator) and generate random
    crops from the image batches generated by the original iterator.
    """
    while True:
        batch_x, batch_y = next(batches)
        batch_crops = np.zeros((batch_x.shape[0], crop_length, crop_length, 3))
        for i in range(batch_x.shape[0]):
            batch_crops[i] = random_crop(batch_x[i], (crop_length, crop_length))
        yield (batch_crops, batch_y)

# %%
from tensorflow.keras.preprocessing.image import img_to_array,load_img
import glob

# 데이터 전체에 대해 centering 진행함.

def read_cal_image(img_path): 
    x = img_to_array(load_img(img_path)) # x는 채널별 평균값
    y = x.shape[0] * x.shape[1]# y는 데이터별 픽셀 수 (비중)

    x = 1/255. * x # scaling하고, centering값을 뽑아냄.
    x = np.mean(x, axis=(0,1))
    
    return np.hstack([x,y])

def calculate_centered_mean(dataset_path,x_train=x_train):
    num = len(x_train)
    space = np.empty((num,4))
    i=0

    for p in glob.glob(os.path.join(dataset_path,'*/*.*')) :
        space[i] = read_cal_image(p)
        i += 1

    ratio = space[:,3] / np.sum(space[:,3])

    return np.average(space[:,0:3],axis=0,weights=ratio)


#아래의 함수를 돌려서 나온 결과값을 중심화 값으로 설정.

#train_mean = calculate_centered_mean(os.path.join(dir,'data/train')).reshape((1,1,3))

# %%
datagen_tr = ImageDataGenerator(
    rescale=1/255.,
    horizontal_flip=True,
    featurewise_center=True,
    featurewise_std_normalization=False,
    rotation_range=10,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=[0.9,1.0],
    fill_mode = 'nearest')
datagen_val = ImageDataGenerator(rescale=1/255.,featurewise_center=True)
datagen_tes = ImageDataGenerator(rescale=1/255.,featurewise_center=True)

# 원래는 이 자리에 fit 매서드를 써야하지만, 그냥 내가 중심화함수를 만들고 적용함. 

# 중심화 설정
datagen_tr.mean = np.array(tr_center, dtype=np.float32).reshape((1,1,3)) # RGB
datagen_val.mean = np.array(tr_center, dtype=np.float32).reshape((1,1,3)) # RGB
datagen_tes.mean = np.array(tr_center, dtype=np.float32).reshape((1,1,3)) # RGB

# %%
train_batches = datagen_tr.flow_from_directory(directory=os.path.join(dir,'data/train'),target_size=(super_size,super_size),batch_size=batch_sizes,class_mode='categorical') # fer : 28698 / mit : 12466 / caltech : 24509 / cifar : 44923
train_generator= crop_generator(train_batches, size)
valid_generator = datagen_val.flow_from_directory(directory=os.path.join(dir,'data/valid'),target_size=(size,size),batch_size=batch_sizes,class_mode='categorical') # fer : 3589 / mit : 1564 / caltech : 2980 / cifar : 5077
test_generator = datagen_tes.flow_from_directory(directory=os.path.join(dir,'data/test'),target_size=(size,size),batch_size=batch_sizes,class_mode='categorical') # fer : 3588 / mit : 1590 / caltech : 3118 / cifar : 10000
# Out:
# Found 44923 images belonging to 100 classes.
# Found 5077 images belonging to 100 classes.
# Found 10000 images belonging to 100 classes.

# %% [markdown]
# ## 2. Support Functions & Almost Original AlexNet
# ---

# %% [markdown]
# ### 1) Support Functions

# %%
# def lr_schedule(epoch):
#     init_lr = 1e-4
#     k = 0.04
#     lr = init_lr * np.exp(-k*epoch)
#     print('Learning rate: ', lr)
#     return lr

def lr_schedule(epoch):
    lr = 3e-4
    if epoch < 30:
        lr = lr
    elif epoch < 60 :
        lr = lr * 0.1
    else:
        lr = lr * 0.01
    print('Learning rate: ', lr)
    return lr

# %% [markdown]
# ### 2) Almost Orginial AlexNet

# %%
# Alexnet을 최대한 논문에 가깝게 맞춰 모형작성.
# 참고 : https://github.com/eweill/keras-deepcv/blob/master/models/classification/alexnet.py

def Alexnet(img_shape=(227, 227, 3), n_classes=1000, weight_decay=weight_decay, weights=None, name='AlexNet'):

    # Initialize model
    alexnet = Sequential(name=name)

    # Layer 1
    alexnet.add(Conv2D(96, (11, 11), input_shape=img_shape, strides=4, kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay)))
    alexnet.add(Activation('relu'))
    alexnet.add(LRN(name='layer1_LRN'))
    alexnet.add(MaxPooling2D(pool_size=(3, 3),strides=2))

    # Layer 2
    alexnet.add(Conv2D(256, (5, 5), padding='same',strides=1, kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay)))
    alexnet.add(Activation('relu'))
    alexnet.add(LRN(name='layer2_LRN'))
    alexnet.add(MaxPooling2D(pool_size=(3, 3),strides=2))
    
    # Layer 3
    alexnet.add(Conv2D(384, (3, 3), padding='same', strides=1, kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay)))
    alexnet.add(Activation('relu'))
    alexnet.add(LRN(name='layer3_LRN'))
    
    # Layer 4
    alexnet.add(Conv2D(384, (3, 3), padding='same', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay)))
    alexnet.add(Activation('relu'))
    alexnet.add(LRN(name='layer4_LRN'))

    # Layer 5
    alexnet.add(Conv2D(256, (3, 3), padding='same', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay)))
    alexnet.add(Activation('relu'))
    alexnet.add(LRN(name='layer5_LRN'))
    alexnet.add(MaxPooling2D(pool_size=(3, 3),strides=2))

    # Layer 6
    alexnet.add(Flatten())
    alexnet.add(Dense(4096, kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay)))
    alexnet.add(Activation('relu'))
    alexnet.add(Dropout(0.5))

    # Layer 7
    alexnet.add(Dense(4096, kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay)))
    alexnet.add(Activation('relu'))
    alexnet.add(Dropout(0.5))

    # Layer 8
    alexnet.add(Dense(n_classes, kernel_regularizer=l2(weight_decay)))
    alexnet.add(Activation('softmax'))

    if weights is not None:
        alexnet.load_weights(weights)

    return alexnet

# %%
model = Alexnet(img_shape=input_sizes, n_classes=classes, name='AlexNet')

# %%
model.summary()
# Out:
# Model: "AlexNet"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 55, 55, 96)        34944
# _________________________________________________________________
# activation (Activation)      (None, 55, 55, 96)        0
# _________________________________________________________________
# layer1_LRN (LRN)             (None, 55, 55, 96)        0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 27, 27, 96)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 27, 27, 256)       614656
# _________________________________________________________________
# activation_1 (Activation)    (None, 27, 27, 256)       0
# _________________________________________________________________
# layer2_LRN (LRN)             (None, 27, 27, 256)       0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 13, 13, 256)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 13, 13, 384)       885120
# _________________________________________________________________
# activation_2 (Activation)    (None, 13, 13, 384)       0
# _________________________________________________________________
# layer3_LRN (LRN)             (None, 13, 13, 384)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 13, 13, 384)       1327488
# _________________________________________________________________
# activation_3 (Activation)    (None, 13, 13, 384)       0
# _________________________________________________________________
# layer4_LRN (LRN)             (None, 13, 13, 384)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 13, 13, 256)       884992
# _________________________________________________________________
# activation_4 (Activation)    (None, 13, 13, 256)       0
# _________________________________________________________________
# layer5_LRN (LRN)             (None, 13, 13, 256)       0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 6, 6, 256)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 9216)              0
# _________________________________________________________________
# dense (Dense)                (None, 4096)              37752832
# _________________________________________________________________
# activation_5 (Activation)    (None, 4096)              0
# _________________________________________________________________
# dropout (Dropout)            (None, 4096)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 4096)              16781312
# _________________________________________________________________
# activation_6 (Activation)    (None, 4096)              0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 4096)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 100)               409700
# _________________________________________________________________
# activation_7 (Activation)    (None, 100)               0
# =================================================================
# Total params: 58,691,044
# Trainable params: 58,691,044
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 폴더 생성

os.makedirs(os.path.join(dir,'model_output',number,model.name), exist_ok=True)
os.makedirs(os.path.join(dir,'train_valid_output',number), exist_ok=True)

# %%
# 참고 : https://github.com/OverLordGoldDragon/keras-adamw

import sys
sys.path.append('/content/drive/My Drive/Colab Notebooks/Paper')
import utils
import optimizers_v2
from utils import get_weight_decays, fill_dict_in_order
from utils import reset_seeds, K_eval
from optimizers_v2 import AdamW, NadamW, SGDW

# %%
# top-5 accuracy 출력
import functools
top5_acc = functools.partial(ks.metrics.top_k_categorical_accuracy, k=5)
top5_acc.__name__ = 'top5_acc'

# %%
#optimizer = SGDW(model=model, use_cosine_annealing=False, total_iterations = len(x_train) // batch_sizes, nesterov=True, momentum=0.9)
optimizer = AdamW(model=model, use_cosine_annealing=False, total_iterations = len(x_train) // batch_sizes)
#optimizer = Adam()
filepath =  os.path.join(dir,'model_output',number,model.name,'{epoch:03d}.h5')

callbacks_list = [ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_weights_only=False, save_best_only=True, mode='min'),
                  ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_weights_only=False, save_best_only=True, mode='max'),
                  #ReduceLROnPlateau(monitor='val_loss',patience=3,factor=0.1,min_lr=1e-5),
                  LearningRateScheduler(lr_schedule,verbose=1)
                  ]
                  
model.compile(optimizer, loss = 'categorical_crossentropy', metrics=['accuracy',top5_acc,macro_f1score])

# %%
######## flow_from_directory
history = model.fit(train_generator, steps_per_epoch=int(len(x_train)/batch_sizes),  validation_data = valid_generator, epochs=epochs , verbose=1 , callbacks = callbacks_list , validation_steps=int(len(x_valid)/batch_sizes))
# Out:
# Learning rate:  0.0003
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 1/70
# 0.0(L1), 5.34522470321675e-06(L2) weight decay set for conv2d/kernel:0
# 0.0(L1), 5.34522470321675e-06(L2) weight decay set for conv2d_1/kernel:0
# 0.0(L1), 5.34522470321675e-06(L2) weight decay set for conv2d_2/kernel:0
# 0.0(L1), 5.34522470321675e-06(L2) weight decay set for conv2d_3/kernel:0
# 0.0(L1), 5.34522470321675e-06(L2) weight decay set for conv2d_4/kernel:0
# 0.0(L1), 5.34522470321675e-06(L2) weight decay set for dense/kernel:0
# 0.0(L1), 5.34522470321675e-06(L2) weight decay set for dense_1/kernel:0
# 0.0(L1), 5.34522470321675e-06(L2) weight decay set for dense_2/kernel:0
# 350/350 [==============================] - ETA: 0s - loss: 4.0601 - accuracy: 0.0775 - top5_acc: 0.2513 - macro_f1score: 0.0036
# Epoch 00001: val_loss improved from inf to 3.50762, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/AlexNet/001.h5
#
# Epoch 00001: val_accuracy improved from -inf to 0.15385, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/AlexNet/001.h5
# 350/350 [==============================] - 25226s 72s/step - loss: 4.0601 - accuracy: 0.0775 - top5_acc: 0.2513 - macro_f1score: 0.0036 - val_loss: 3.5076 - val_accuracy: 0.1538 - val_top5_acc: 0.4193 - val_macro_f1score: 0.0133
# Learning rate:  0.0003
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 2/70
# 350/350 [==============================] - ETA: 0s - loss: 3.3962 - accuracy: 0.1783 - top5_acc: 0.4505 - macro_f1score: 0.0262
# Epoch 00002: val_loss improved from 3.50762 to 2.98312, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/AlexNet/002.h5
#
# Epoch 00002: val_accuracy improved from 0.15385 to 0.24980, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/AlexNet/002.h5
# 350/350 [==============================] - 735s 2s/step - loss: 3.3962 - accuracy: 0.1783 - top5_acc: 0.4505 - macro_f1score: 0.0262 - val_loss: 2.9831 - val_accuracy: 0.2498 - val_top5_acc: 0.5637 - val_macro_f1score: 0.0576
# Learning rate:  0.0003
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 3/70
# 350/350 [==============================] - ETA: 0s - loss: 2.9519 - accuracy: 0.2643 - top5_acc: 0.5698 - macro_f1score: 0.0689
# Epoch 00003: val_loss improved from 2.98312 to 2.64067, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/AlexNet/003.h5
#
# Epoch 00003: val_accuracy improved from 0.24980 to 0.32372, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/AlexNet/003.h5
# 350/350 [==============================] - 732s 2s/step - loss: 2.9519 - accuracy: 0.2643 - top5_acc: 0.5698 - macro_f1score: 0.0689 - val_loss: 2.6407 - val_accuracy: 0.3237 - val_top5_acc: 0.6484 - val_macro_f1score: 0.1028
# Learning rate:  0.0003
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 4/70
# 350/350 [==============================] - ETA: 0s - loss: 2.6447 - accuracy: 0.3261 - top5_acc: 0.6408 - macro_f1score: 0.1126
# Epoch 00004: val_loss improved from 2.64067 to 2.39812, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/AlexNet/004.h5
#
# Epoch 00004: val_accuracy improved from 0.32372 to 0.37560, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/AlexNet/004.h5
# 350/350 [==============================] - 729s 2s/step - loss: 2.6447 - accuracy: 0.3261 - top5_acc: 0.6408 - macro_f1score: 0.1126 - val_loss: 2.3981 - val_accuracy: 0.3756 - val_top5_acc: 0.6909 - val_macro_f1score: 0.1535
# Learning rate:  0.0003
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 5/70
# 350/350 [==============================] - ETA: 0s - loss: 2.4005 - accuracy: 0.3780 - top5_acc: 0.6963 - macro_f1score: 0.1530
# Epoch 00005: val_loss improved from 2.39812 to 2.20161, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/AlexNet/005.h5
#
# Epoch 00005: val_accuracy improved from 0.37560 to 0.42107, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/AlexNet/005.h5
# 350/350 [==============================] - 734s 2s/step - loss: 2.4005 - accuracy: 0.3780 - top5_acc: 0.6963 - macro_f1score: 0.1530 - val_loss: 2.2016 - val_accuracy: 0.4211 - val_top5_acc: 0.7418 - val_macro_f1score: 0.2046
# Learning rate:  0.0003
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 6/70
# 350/350 [==============================] - ETA: 0s - loss: 2.2222 - accuracy: 0.4140 - top5_acc: 0.7301 - macro_f1score: 0.1873
# Epoch 00006: val_loss improved from 2.20161 to 2.10256, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/AlexNet/006.h5
#
# Epoch 00006: val_accuracy improved from 0.42107 to 0.44451, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/AlexNet/006.h5
# 350/350 [==============================] - 728s 2s/step - loss: 2.2222 - accuracy: 0.4140 - top5_acc: 0.7301 - macro_f1score: 0.1873 - val_loss: 2.1026 - val_accuracy: 0.4445 - val_top5_acc: 0.7528 - val_macro_f1score: 0.2058
# Learning rate:  0.0003
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 7/70
# 350/350 [==============================] - ETA: 0s - loss: 2.0739 - accuracy: 0.4471 - top5_acc: 0.7624 - macro_f1score: 0.2146
# Epoch 00007: val_loss improved from 2.10256 to 1.97446, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/AlexNet/007.h5
#
# Epoch 00007: val_accuracy improved from 0.44451 to 0.47436, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/AlexNet/007.h5
# 350/350 [==============================] - 729s 2s/step - loss: 2.0739 - accuracy: 0.4471 - top5_acc: 0.7624 - macro_f1score: 0.2146 - val_loss: 1.9745 - val_accuracy: 0.4744 - val_top5_acc: 0.7833 - val_macro_f1score: 0.2313
# Learning rate:  0.0003
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 8/70
# 350/350 [==============================] - ETA: 0s - loss: 1.9403 - accuracy: 0.4770 - top5_acc: 0.7876 - macro_f1score: 0.2399
# Epoch 00008: val_loss improved from 1.97446 to 1.95362, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/AlexNet/008.h5
#
# Epoch 00008: val_accuracy improved from 0.47436 to 0.47837, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/AlexNet/008.h5
# 350/350 [==============================] - 719s 2s/step - loss: 1.9403 - accuracy: 0.4770 - top5_acc: 0.7876 - macro_f1score: 0.2399 - val_loss: 1.9536 - val_accuracy: 0.4784 - val_top5_acc: 0.7883 - val_macro_f1score: 0.2530
# Learning rate:  0.0003
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 9/70
# 350/350 [==============================] - ETA: 0s - loss: 1.8409 - accuracy: 0.5018 - top5_acc: 0.8041 - macro_f1score: 0.2636
# Epoch 00009: val_loss improved from 1.95362 to 1.85119, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/AlexNet/009.h5
#
# Epoch 00009: val_accuracy improved from 0.47837 to 0.50401, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/AlexNet/009.h5
# 350/350 [==============================] - 710s 2s/step - loss: 1.8409 - accuracy: 0.5018 - top5_acc: 0.8041 - macro_f1score: 0.2636 - val_loss: 1.8512 - val_accuracy: 0.5040 - val_top5_acc: 0.8033 - val_macro_f1score: 0.2655
# Learning rate:  0.0003
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 10/70
# 350/350 [==============================] - ETA: 0s - loss: 1.7320 - accuracy: 0.5270 - top5_acc: 0.8225 - macro_f1score: 0.2853
# Epoch 00010: val_loss improved from 1.85119 to 1.82689, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/AlexNet/010.h5
#
# Epoch 00010: val_accuracy improved from 0.50401 to 0.51142, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/AlexNet/010.h5
# 350/350 [==============================] - 710s 2s/step - loss: 1.7320 - accuracy: 0.5270 - top5_acc: 0.8225 - macro_f1score: 0.2853 - val_loss: 1.8269 - val_accuracy: 0.5114 - val_top5_acc: 0.8051 - val_macro_f1score: 0.2816
# Learning rate:  0.0003
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 11/70
# 350/350 [==============================] - ETA: 0s - loss: 1.6433 - accuracy: 0.5459 - top5_acc: 0.8400 - macro_f1score: 0.3037
# Epoch 00011: val_loss improved from 1.82689 to 1.81841, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/AlexNet/011.h5
#
# Epoch 00011: val_accuracy improved from 0.51142 to 0.51723, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/AlexNet/011.h5
# 350/350 [==============================] - 710s 2s/step - loss: 1.6433 - accuracy: 0.5459 - top5_acc: 0.8400 - macro_f1score: 0.3037 - val_loss: 1.8184 - val_accuracy: 0.5172 - val_top5_acc: 0.8045 - val_macro_f1score: 0.2767
# Learning rate:  0.0003
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 12/70
# 350/350 [==============================] - ETA: 0s - loss: 1.5548 - accuracy: 0.5681 - top5_acc: 0.8528 - macro_f1score: 0.3244
# Epoch 00012: val_loss improved from 1.81841 to 1.71684, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/AlexNet/012.h5
#
# Epoch 00012: val_accuracy improved from 0.51723 to 0.54046, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/AlexNet/012.h5
# 350/350 [==============================] - 712s 2s/step - loss: 1.5548 - accuracy: 0.5681 - top5_acc: 0.8528 - macro_f1score: 0.3244 - val_loss: 1.7168 - val_accuracy: 0.5405 - val_top5_acc: 0.8235 - val_macro_f1score: 0.3100
# Learning rate:  0.0003
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 13/70
# 350/350 [==============================] - ETA: 0s - loss: 1.4895 - accuracy: 0.5843 - top5_acc: 0.8638 - macro_f1score: 0.3403
# Epoch 00013: val_loss improved from 1.71684 to 1.71199, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/AlexNet/013.h5
#
# Epoch 00013: val_accuracy did not improve from 0.54046
# 350/350 [==============================] - 719s 2s/step - loss: 1.4895 - accuracy: 0.5843 - top5_acc: 0.8638 - macro_f1score: 0.3403 - val_loss: 1.7120 - val_accuracy: 0.5315 - val_top5_acc: 0.8287 - val_macro_f1score: 0.3055
# Learning rate:  0.0003
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 14/70
# 350/350 [==============================] - ETA: 0s - loss: 1.4161 - accuracy: 0.5977 - top5_acc: 0.8745 - macro_f1score: 0.3555
# Epoch 00014: val_loss did not improve from 1.71199
#
# Epoch 00014: val_accuracy did not improve from 0.54046
# 350/350 [==============================] - 720s 2s/step - loss: 1.4161 - accuracy: 0.5977 - top5_acc: 0.8745 - macro_f1score: 0.3555 - val_loss: 1.7264 - val_accuracy: 0.5405 - val_top5_acc: 0.8323 - val_macro_f1score: 0.3138
# Learning rate:  0.0003
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 15/70
# 350/350 [==============================] - ETA: 0s - loss: 1.3464 - accuracy: 0.6177 - top5_acc: 0.8851 - macro_f1score: 0.3718
# Epoch 00015: val_loss improved from 1.71199 to 1.71008, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/AlexNet/015.h5
#
# Epoch 00015: val_accuracy improved from 0.54046 to 0.54267, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/AlexNet/015.h5
# 350/350 [==============================] - 724s 2s/step - loss: 1.3464 - accuracy: 0.6177 - top5_acc: 0.8851 - macro_f1score: 0.3718 - val_loss: 1.7101 - val_accuracy: 0.5427 - val_top5_acc: 0.8335 - val_macro_f1score: 0.3271
# Learning rate:  0.0003
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 16/70
# 350/350 [==============================] - ETA: 0s - loss: 1.2953 - accuracy: 0.6327 - top5_acc: 0.8910 - macro_f1score: 0.3865
# Epoch 00016: val_loss did not improve from 1.71008
#
# Epoch 00016: val_accuracy improved from 0.54267 to 0.54447, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/AlexNet/016.h5
# 350/350 [==============================] - 720s 2s/step - loss: 1.2953 - accuracy: 0.6327 - top5_acc: 0.8910 - macro_f1score: 0.3865 - val_loss: 1.7289 - val_accuracy: 0.5445 - val_top5_acc: 0.8267 - val_macro_f1score: 0.3242
# Learning rate:  0.0003
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 17/70
# 350/350 [==============================] - ETA: 0s - loss: 1.2306 - accuracy: 0.6447 - top5_acc: 0.9020 - macro_f1score: 0.3977
# Epoch 00017: val_loss improved from 1.71008 to 1.64389, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/AlexNet/017.h5
#
# Epoch 00017: val_accuracy improved from 0.54447 to 0.57232, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/AlexNet/017.h5
# 350/350 [==============================] - 725s 2s/step - loss: 1.2306 - accuracy: 0.6447 - top5_acc: 0.9020 - macro_f1score: 0.3977 - val_loss: 1.6439 - val_accuracy: 0.5723 - val_top5_acc: 0.8460 - val_macro_f1score: 0.3445
# Learning rate:  0.0003
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 18/70
# 350/350 [==============================] - ETA: 0s - loss: 1.1868 - accuracy: 0.6606 - top5_acc: 0.9076 - macro_f1score: 0.4135
# Epoch 00018: val_loss improved from 1.64389 to 1.61175, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/AlexNet/018.h5
#
# Epoch 00018: val_accuracy improved from 0.57232 to 0.57592, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/AlexNet/018.h5
# 350/350 [==============================] - 726s 2s/step - loss: 1.1868 - accuracy: 0.6606 - top5_acc: 0.9076 - macro_f1score: 0.4135 - val_loss: 1.6118 - val_accuracy: 0.5759 - val_top5_acc: 0.8518 - val_macro_f1score: 0.3446
# Learning rate:  0.0003
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 19/70
# 350/350 [==============================] - ETA: 0s - loss: 1.1423 - accuracy: 0.6697 - top5_acc: 0.9121 - macro_f1score: 0.4192
# Epoch 00019: val_loss did not improve from 1.61175
#
# Epoch 00019: val_accuracy did not improve from 0.57592
# 350/350 [==============================] - 720s 2s/step - loss: 1.1423 - accuracy: 0.6697 - top5_acc: 0.9121 - macro_f1score: 0.4192 - val_loss: 1.6544 - val_accuracy: 0.5689 - val_top5_acc: 0.8431 - val_macro_f1score: 0.3457
# Learning rate:  0.0003
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 20/70
# 350/350 [==============================] - ETA: 0s - loss: 1.0949 - accuracy: 0.6834 - top5_acc: 0.9189 - macro_f1score: 0.4323
# Epoch 00020: val_loss did not improve from 1.61175
#
# Epoch 00020: val_accuracy did not improve from 0.57592
# 350/350 [==============================] - 723s 2s/step - loss: 1.0949 - accuracy: 0.6834 - top5_acc: 0.9189 - macro_f1score: 0.4323 - val_loss: 1.6444 - val_accuracy: 0.5701 - val_top5_acc: 0.8371 - val_macro_f1score: 0.3381
# Learning rate:  0.0003
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 21/70
# 350/350 [==============================] - ETA: 0s - loss: 1.0652 - accuracy: 0.6914 - top5_acc: 0.9237 - macro_f1score: 0.4411
# Epoch 00021: val_loss did not improve from 1.61175
#
# Epoch 00021: val_accuracy did not improve from 0.57592
# 350/350 [==============================] - 717s 2s/step - loss: 1.0652 - accuracy: 0.6914 - top5_acc: 0.9237 - macro_f1score: 0.4411 - val_loss: 1.6170 - val_accuracy: 0.5679 - val_top5_acc: 0.8454 - val_macro_f1score: 0.3534
# Learning rate:  0.0003
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 22/70
# 350/350 [==============================] - ETA: 0s - loss: 1.0103 - accuracy: 0.7066 - top5_acc: 0.9307 - macro_f1score: 0.4543
# Epoch 00022: val_loss did not improve from 1.61175
#
# Epoch 00022: val_accuracy did not improve from 0.57592
# 350/350 [==============================] - 715s 2s/step - loss: 1.0103 - accuracy: 0.7066 - top5_acc: 0.9307 - macro_f1score: 0.4543 - val_loss: 1.6726 - val_accuracy: 0.5747 - val_top5_acc: 0.8401 - val_macro_f1score: 0.3619
# Learning rate:  0.0003
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 23/70
# 350/350 [==============================] - ETA: 0s - loss: 0.9853 - accuracy: 0.7133 - top5_acc: 0.9328 - macro_f1score: 0.4610
# Epoch 00023: val_loss did not improve from 1.61175
#
# Epoch 00023: val_accuracy improved from 0.57592 to 0.57913, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/AlexNet/023.h5
# 350/350 [==============================] - 708s 2s/step - loss: 0.9853 - accuracy: 0.7133 - top5_acc: 0.9328 - macro_f1score: 0.4610 - val_loss: 1.6216 - val_accuracy: 0.5791 - val_top5_acc: 0.8474 - val_macro_f1score: 0.3620
# Learning rate:  0.0003
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 24/70
# 350/350 [==============================] - ETA: 0s - loss: 0.9401 - accuracy: 0.7248 - top5_acc: 0.9394 - macro_f1score: 0.4683
# Epoch 00024: val_loss did not improve from 1.61175
#
# Epoch 00024: val_accuracy improved from 0.57913 to 0.57993, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/AlexNet/024.h5
# 350/350 [==============================] - 715s 2s/step - loss: 0.9401 - accuracy: 0.7248 - top5_acc: 0.9394 - macro_f1score: 0.4683 - val_loss: 1.6664 - val_accuracy: 0.5799 - val_top5_acc: 0.8433 - val_macro_f1score: 0.3523
# Learning rate:  0.0003
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 25/70
# 350/350 [==============================] - ETA: 0s - loss: 0.9164 - accuracy: 0.7312 - top5_acc: 0.9413 - macro_f1score: 0.4788
# Epoch 00025: val_loss did not improve from 1.61175
#
# Epoch 00025: val_accuracy did not improve from 0.57993
# 350/350 [==============================] - 720s 2s/step - loss: 0.9164 - accuracy: 0.7312 - top5_acc: 0.9413 - macro_f1score: 0.4788 - val_loss: 1.6824 - val_accuracy: 0.5781 - val_top5_acc: 0.8427 - val_macro_f1score: 0.3691
# Learning rate:  0.0003
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 26/70
# 350/350 [==============================] - ETA: 0s - loss: 0.8807 - accuracy: 0.7395 - top5_acc: 0.9470 - macro_f1score: 0.4877
# Epoch 00026: val_loss did not improve from 1.61175
#
# Epoch 00026: val_accuracy improved from 0.57993 to 0.58133, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/AlexNet/026.h5
# 350/350 [==============================] - 716s 2s/step - loss: 0.8807 - accuracy: 0.7395 - top5_acc: 0.9470 - macro_f1score: 0.4877 - val_loss: 1.6429 - val_accuracy: 0.5813 - val_top5_acc: 0.8546 - val_macro_f1score: 0.3692
# Learning rate:  0.0003
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 27/70
# 350/350 [==============================] - ETA: 0s - loss: 0.8566 - accuracy: 0.7471 - top5_acc: 0.9484 - macro_f1score: 0.4938
# Epoch 00027: val_loss did not improve from 1.61175
#
# Epoch 00027: val_accuracy improved from 0.58133 to 0.58514, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/AlexNet/027.h5
# 350/350 [==============================] - 703s 2s/step - loss: 0.8566 - accuracy: 0.7471 - top5_acc: 0.9484 - macro_f1score: 0.4938 - val_loss: 1.6209 - val_accuracy: 0.5851 - val_top5_acc: 0.8494 - val_macro_f1score: 0.3648
# Learning rate:  0.0003
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 28/70
# 350/350 [==============================] - ETA: 0s - loss: 0.8231 - accuracy: 0.7573 - top5_acc: 0.9520 - macro_f1score: 0.5046
# Epoch 00028: val_loss did not improve from 1.61175
#
# Epoch 00028: val_accuracy improved from 0.58514 to 0.58734, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/AlexNet/028.h5
# 350/350 [==============================] - 688s 2s/step - loss: 0.8231 - accuracy: 0.7573 - top5_acc: 0.9520 - macro_f1score: 0.5046 - val_loss: 1.6441 - val_accuracy: 0.5873 - val_top5_acc: 0.8510 - val_macro_f1score: 0.3656
# Learning rate:  0.0003
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 29/70
# 350/350 [==============================] - ETA: 0s - loss: 0.8036 - accuracy: 0.7617 - top5_acc: 0.9528 - macro_f1score: 0.5087
# Epoch 00029: val_loss did not improve from 1.61175
#
# Epoch 00029: val_accuracy improved from 0.58734 to 0.59375, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/AlexNet/029.h5
# 350/350 [==============================] - 681s 2s/step - loss: 0.8036 - accuracy: 0.7617 - top5_acc: 0.9528 - macro_f1score: 0.5087 - val_loss: 1.6329 - val_accuracy: 0.5938 - val_top5_acc: 0.8452 - val_macro_f1score: 0.3738
# Learning rate:  0.0003
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 30/70
# 350/350 [==============================] - ETA: 0s - loss: 0.7828 - accuracy: 0.7659 - top5_acc: 0.9560 - macro_f1score: 0.5174
# Epoch 00030: val_loss did not improve from 1.61175
#
# Epoch 00030: val_accuracy improved from 0.59375 to 0.59415, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/AlexNet/030.h5
# 350/350 [==============================] - 676s 2s/step - loss: 0.7828 - accuracy: 0.7659 - top5_acc: 0.9560 - macro_f1score: 0.5174 - val_loss: 1.6182 - val_accuracy: 0.5942 - val_top5_acc: 0.8528 - val_macro_f1score: 0.3751
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 31/70
# 350/350 [==============================] - ETA: 0s - loss: 0.5996 - accuracy: 0.8179 - top5_acc: 0.9718 - macro_f1score: 0.5582
# Epoch 00031: val_loss improved from 1.61175 to 1.56764, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/AlexNet/031.h5
#
# Epoch 00031: val_accuracy improved from 0.59415 to 0.61318, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/AlexNet/031.h5
# 350/350 [==============================] - 683s 2s/step - loss: 0.5996 - accuracy: 0.8179 - top5_acc: 0.9718 - macro_f1score: 0.5582 - val_loss: 1.5676 - val_accuracy: 0.6132 - val_top5_acc: 0.8666 - val_macro_f1score: 0.3967
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 32/70
# 350/350 [==============================] - ETA: 0s - loss: 0.5360 - accuracy: 0.8387 - top5_acc: 0.9765 - macro_f1score: 0.5736
# Epoch 00032: val_loss did not improve from 1.56764
#
# Epoch 00032: val_accuracy improved from 0.61318 to 0.61558, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/AlexNet/032.h5
# 350/350 [==============================] - 698s 2s/step - loss: 0.5360 - accuracy: 0.8387 - top5_acc: 0.9765 - macro_f1score: 0.5736 - val_loss: 1.5769 - val_accuracy: 0.6156 - val_top5_acc: 0.8656 - val_macro_f1score: 0.4071
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00033: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 33/70
# 350/350 [==============================] - ETA: 0s - loss: 0.5025 - accuracy: 0.8468 - top5_acc: 0.9783 - macro_f1score: 0.5864
# Epoch 00033: val_loss did not improve from 1.56764
#
# Epoch 00033: val_accuracy improved from 0.61558 to 0.61919, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/AlexNet/033.h5
# 350/350 [==============================] - 714s 2s/step - loss: 0.5025 - accuracy: 0.8468 - top5_acc: 0.9783 - macro_f1score: 0.5864 - val_loss: 1.5714 - val_accuracy: 0.6192 - val_top5_acc: 0.8700 - val_macro_f1score: 0.4145
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00034: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 34/70
# 350/350 [==============================] - ETA: 0s - loss: 0.4876 - accuracy: 0.8514 - top5_acc: 0.9785 - macro_f1score: 0.5903
# Epoch 00034: val_loss did not improve from 1.56764
#
# Epoch 00034: val_accuracy improved from 0.61919 to 0.62220, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/AlexNet/034.h5
# 350/350 [==============================] - 731s 2s/step - loss: 0.4876 - accuracy: 0.8514 - top5_acc: 0.9785 - macro_f1score: 0.5903 - val_loss: 1.5813 - val_accuracy: 0.6222 - val_top5_acc: 0.8686 - val_macro_f1score: 0.4081
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00035: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 35/70
# 350/350 [==============================] - ETA: 0s - loss: 0.4708 - accuracy: 0.8566 - top5_acc: 0.9805 - macro_f1score: 0.5937
# Epoch 00035: val_loss did not improve from 1.56764
#
# Epoch 00035: val_accuracy did not improve from 0.62220
# 350/350 [==============================] - 727s 2s/step - loss: 0.4708 - accuracy: 0.8566 - top5_acc: 0.9805 - macro_f1score: 0.5937 - val_loss: 1.5797 - val_accuracy: 0.6222 - val_top5_acc: 0.8684 - val_macro_f1score: 0.4156
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00036: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 36/70
# 350/350 [==============================] - ETA: 0s - loss: 0.4535 - accuracy: 0.8616 - top5_acc: 0.9810 - macro_f1score: 0.6024
# Epoch 00036: val_loss did not improve from 1.56764
#
# Epoch 00036: val_accuracy improved from 0.62220 to 0.62460, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/AlexNet/036.h5
# 350/350 [==============================] - 727s 2s/step - loss: 0.4535 - accuracy: 0.8616 - top5_acc: 0.9810 - macro_f1score: 0.6024 - val_loss: 1.5885 - val_accuracy: 0.6246 - val_top5_acc: 0.8698 - val_macro_f1score: 0.4119
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00037: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 37/70
# 350/350 [==============================] - ETA: 0s - loss: 0.4412 - accuracy: 0.8650 - top5_acc: 0.9816 - macro_f1score: 0.6002
# Epoch 00037: val_loss did not improve from 1.56764
#
# Epoch 00037: val_accuracy did not improve from 0.62460
# 350/350 [==============================] - 726s 2s/step - loss: 0.4412 - accuracy: 0.8650 - top5_acc: 0.9816 - macro_f1score: 0.6002 - val_loss: 1.5978 - val_accuracy: 0.6210 - val_top5_acc: 0.8678 - val_macro_f1score: 0.4147
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00038: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 38/70
# 350/350 [==============================] - ETA: 0s - loss: 0.4358 - accuracy: 0.8677 - top5_acc: 0.9832 - macro_f1score: 0.6015
# Epoch 00038: val_loss did not improve from 1.56764
#
# Epoch 00038: val_accuracy improved from 0.62460 to 0.62680, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/AlexNet/038.h5
# 350/350 [==============================] - 727s 2s/step - loss: 0.4358 - accuracy: 0.8677 - top5_acc: 0.9832 - macro_f1score: 0.6015 - val_loss: 1.5874 - val_accuracy: 0.6268 - val_top5_acc: 0.8684 - val_macro_f1score: 0.4239
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00039: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 39/70
# 350/350 [==============================] - ETA: 0s - loss: 0.4213 - accuracy: 0.8706 - top5_acc: 0.9845 - macro_f1score: 0.6074
# Epoch 00039: val_loss did not improve from 1.56764
#
# Epoch 00039: val_accuracy did not improve from 0.62680
# 350/350 [==============================] - 728s 2s/step - loss: 0.4213 - accuracy: 0.8706 - top5_acc: 0.9845 - macro_f1score: 0.6074 - val_loss: 1.6124 - val_accuracy: 0.6234 - val_top5_acc: 0.8666 - val_macro_f1score: 0.4159
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00040: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 40/70
# 350/350 [==============================] - ETA: 0s - loss: 0.4123 - accuracy: 0.8734 - top5_acc: 0.9838 - macro_f1score: 0.6078
# Epoch 00040: val_loss did not improve from 1.56764
#
# Epoch 00040: val_accuracy did not improve from 0.62680
# 350/350 [==============================] - 731s 2s/step - loss: 0.4123 - accuracy: 0.8734 - top5_acc: 0.9838 - macro_f1score: 0.6078 - val_loss: 1.5921 - val_accuracy: 0.6260 - val_top5_acc: 0.8696 - val_macro_f1score: 0.4166
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00041: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 41/70
# 350/350 [==============================] - ETA: 0s - loss: 0.4020 - accuracy: 0.8755 - top5_acc: 0.9848 - macro_f1score: 0.6103
# Epoch 00041: val_loss did not improve from 1.56764
#
# Epoch 00041: val_accuracy improved from 0.62680 to 0.63021, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/AlexNet/041.h5
# 350/350 [==============================] - 727s 2s/step - loss: 0.4020 - accuracy: 0.8755 - top5_acc: 0.9848 - macro_f1score: 0.6103 - val_loss: 1.5870 - val_accuracy: 0.6302 - val_top5_acc: 0.8714 - val_macro_f1score: 0.4236
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00042: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 42/70
# 350/350 [==============================] - ETA: 0s - loss: 0.3904 - accuracy: 0.8793 - top5_acc: 0.9858 - macro_f1score: 0.6156
# Epoch 00042: val_loss did not improve from 1.56764
#
# Epoch 00042: val_accuracy did not improve from 0.63021
# 350/350 [==============================] - 723s 2s/step - loss: 0.3904 - accuracy: 0.8793 - top5_acc: 0.9858 - macro_f1score: 0.6156 - val_loss: 1.6068 - val_accuracy: 0.6224 - val_top5_acc: 0.8702 - val_macro_f1score: 0.4197
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00043: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 43/70
# 350/350 [==============================] - ETA: 0s - loss: 0.3902 - accuracy: 0.8810 - top5_acc: 0.9851 - macro_f1score: 0.6162
# Epoch 00043: val_loss did not improve from 1.56764
#
# Epoch 00043: val_accuracy did not improve from 0.63021
# 350/350 [==============================] - 724s 2s/step - loss: 0.3902 - accuracy: 0.8810 - top5_acc: 0.9851 - macro_f1score: 0.6162 - val_loss: 1.6260 - val_accuracy: 0.6236 - val_top5_acc: 0.8710 - val_macro_f1score: 0.4304
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00044: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 44/70
# 350/350 [==============================] - ETA: 0s - loss: 0.3791 - accuracy: 0.8836 - top5_acc: 0.9863 - macro_f1score: 0.6165
# Epoch 00044: val_loss did not improve from 1.56764
#
# Epoch 00044: val_accuracy improved from 0.63021 to 0.63221, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/AlexNet/044.h5
# 350/350 [==============================] - 728s 2s/step - loss: 0.3791 - accuracy: 0.8836 - top5_acc: 0.9863 - macro_f1score: 0.6165 - val_loss: 1.6187 - val_accuracy: 0.6322 - val_top5_acc: 0.8690 - val_macro_f1score: 0.4211
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00045: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 45/70
# 350/350 [==============================] - ETA: 0s - loss: 0.3793 - accuracy: 0.8837 - top5_acc: 0.9858 - macro_f1score: 0.6198
# Epoch 00045: val_loss did not improve from 1.56764
#
# Epoch 00045: val_accuracy did not improve from 0.63221
# 350/350 [==============================] - 724s 2s/step - loss: 0.3793 - accuracy: 0.8837 - top5_acc: 0.9858 - macro_f1score: 0.6198 - val_loss: 1.6142 - val_accuracy: 0.6296 - val_top5_acc: 0.8710 - val_macro_f1score: 0.4239
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00046: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 46/70
# 350/350 [==============================] - ETA: 0s - loss: 0.3650 - accuracy: 0.8880 - top5_acc: 0.9864 - macro_f1score: 0.6227
# Epoch 00046: val_loss did not improve from 1.56764
#
# Epoch 00046: val_accuracy did not improve from 0.63221
# 350/350 [==============================] - 722s 2s/step - loss: 0.3650 - accuracy: 0.8880 - top5_acc: 0.9864 - macro_f1score: 0.6227 - val_loss: 1.6324 - val_accuracy: 0.6312 - val_top5_acc: 0.8696 - val_macro_f1score: 0.4241
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00047: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 47/70
# 350/350 [==============================] - ETA: 0s - loss: 0.3647 - accuracy: 0.8879 - top5_acc: 0.9872 - macro_f1score: 0.6242
# Epoch 00047: val_loss did not improve from 1.56764
#
# Epoch 00047: val_accuracy did not improve from 0.63221
# 350/350 [==============================] - 722s 2s/step - loss: 0.3647 - accuracy: 0.8879 - top5_acc: 0.9872 - macro_f1score: 0.6242 - val_loss: 1.6207 - val_accuracy: 0.6282 - val_top5_acc: 0.8704 - val_macro_f1score: 0.4254
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00048: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 48/70
# 350/350 [==============================] - ETA: 0s - loss: 0.3543 - accuracy: 0.8915 - top5_acc: 0.9873 - macro_f1score: 0.6236
# Epoch 00048: val_loss did not improve from 1.56764
#
# Epoch 00048: val_accuracy did not improve from 0.63221
# 350/350 [==============================] - 724s 2s/step - loss: 0.3543 - accuracy: 0.8915 - top5_acc: 0.9873 - macro_f1score: 0.6236 - val_loss: 1.6097 - val_accuracy: 0.6320 - val_top5_acc: 0.8714 - val_macro_f1score: 0.4230
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00049: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 49/70
# 350/350 [==============================] - ETA: 0s - loss: 0.3478 - accuracy: 0.8925 - top5_acc: 0.9875 - macro_f1score: 0.6269
# Epoch 00049: val_loss did not improve from 1.56764
#
# Epoch 00049: val_accuracy did not improve from 0.63221
# 350/350 [==============================] - 724s 2s/step - loss: 0.3478 - accuracy: 0.8925 - top5_acc: 0.9875 - macro_f1score: 0.6269 - val_loss: 1.6299 - val_accuracy: 0.6276 - val_top5_acc: 0.8708 - val_macro_f1score: 0.4283
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00050: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 50/70
# 350/350 [==============================] - ETA: 0s - loss: 0.3358 - accuracy: 0.8956 - top5_acc: 0.9888 - macro_f1score: 0.6292
# Epoch 00050: val_loss did not improve from 1.56764
#
# Epoch 00050: val_accuracy did not improve from 0.63221
# 350/350 [==============================] - 724s 2s/step - loss: 0.3358 - accuracy: 0.8956 - top5_acc: 0.9888 - macro_f1score: 0.6292 - val_loss: 1.6343 - val_accuracy: 0.6310 - val_top5_acc: 0.8698 - val_macro_f1score: 0.4185
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00051: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 51/70
# 350/350 [==============================] - ETA: 0s - loss: 0.3375 - accuracy: 0.8948 - top5_acc: 0.9876 - macro_f1score: 0.6285
# Epoch 00051: val_loss did not improve from 1.56764
#
# Epoch 00051: val_accuracy did not improve from 0.63221
# 350/350 [==============================] - 721s 2s/step - loss: 0.3375 - accuracy: 0.8948 - top5_acc: 0.9876 - macro_f1score: 0.6285 - val_loss: 1.6350 - val_accuracy: 0.6316 - val_top5_acc: 0.8704 - val_macro_f1score: 0.4291
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00052: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 52/70
# 350/350 [==============================] - ETA: 0s - loss: 0.3260 - accuracy: 0.8996 - top5_acc: 0.9889 - macro_f1score: 0.6332
# Epoch 00052: val_loss did not improve from 1.56764
#
# Epoch 00052: val_accuracy did not improve from 0.63221
# 350/350 [==============================] - 720s 2s/step - loss: 0.3260 - accuracy: 0.8996 - top5_acc: 0.9889 - macro_f1score: 0.6332 - val_loss: 1.6446 - val_accuracy: 0.6262 - val_top5_acc: 0.8708 - val_macro_f1score: 0.4218
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00053: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 53/70
# 350/350 [==============================] - ETA: 0s - loss: 0.3287 - accuracy: 0.8977 - top5_acc: 0.9891 - macro_f1score: 0.6310
# Epoch 00053: val_loss did not improve from 1.56764
#
# Epoch 00053: val_accuracy did not improve from 0.63221
# 350/350 [==============================] - 719s 2s/step - loss: 0.3287 - accuracy: 0.8977 - top5_acc: 0.9891 - macro_f1score: 0.6310 - val_loss: 1.6566 - val_accuracy: 0.6282 - val_top5_acc: 0.8708 - val_macro_f1score: 0.4209
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00054: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 54/70
# 350/350 [==============================] - ETA: 0s - loss: 0.3205 - accuracy: 0.8995 - top5_acc: 0.9892 - macro_f1score: 0.6340
# Epoch 00054: val_loss did not improve from 1.56764
#
# Epoch 00054: val_accuracy did not improve from 0.63221
# 350/350 [==============================] - 718s 2s/step - loss: 0.3205 - accuracy: 0.8995 - top5_acc: 0.9892 - macro_f1score: 0.6340 - val_loss: 1.6564 - val_accuracy: 0.6288 - val_top5_acc: 0.8714 - val_macro_f1score: 0.4291
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00055: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 55/70
# 350/350 [==============================] - ETA: 0s - loss: 0.3130 - accuracy: 0.9046 - top5_acc: 0.9894 - macro_f1score: 0.6344
# Epoch 00055: val_loss did not improve from 1.56764
#
# Epoch 00055: val_accuracy did not improve from 0.63221
# 350/350 [==============================] - 723s 2s/step - loss: 0.3130 - accuracy: 0.9046 - top5_acc: 0.9894 - macro_f1score: 0.6344 - val_loss: 1.6546 - val_accuracy: 0.6274 - val_top5_acc: 0.8722 - val_macro_f1score: 0.4177
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00056: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 56/70
# 350/350 [==============================] - ETA: 0s - loss: 0.3089 - accuracy: 0.9035 - top5_acc: 0.9904 - macro_f1score: 0.6355
# Epoch 00056: val_loss did not improve from 1.56764
#
# Epoch 00056: val_accuracy did not improve from 0.63221
# 350/350 [==============================] - 725s 2s/step - loss: 0.3089 - accuracy: 0.9035 - top5_acc: 0.9904 - macro_f1score: 0.6355 - val_loss: 1.6775 - val_accuracy: 0.6296 - val_top5_acc: 0.8716 - val_macro_f1score: 0.4275
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00057: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 57/70
# 350/350 [==============================] - ETA: 0s - loss: 0.3027 - accuracy: 0.9057 - top5_acc: 0.9907 - macro_f1score: 0.6380
# Epoch 00057: val_loss did not improve from 1.56764
#
# Epoch 00057: val_accuracy improved from 0.63221 to 0.63241, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/AlexNet/057.h5
# 350/350 [==============================] - 728s 2s/step - loss: 0.3027 - accuracy: 0.9057 - top5_acc: 0.9907 - macro_f1score: 0.6380 - val_loss: 1.6736 - val_accuracy: 0.6324 - val_top5_acc: 0.8710 - val_macro_f1score: 0.4275
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00058: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 58/70
# 350/350 [==============================] - ETA: 0s - loss: 0.2970 - accuracy: 0.9084 - top5_acc: 0.9904 - macro_f1score: 0.6398
# Epoch 00058: val_loss did not improve from 1.56764
#
# Epoch 00058: val_accuracy improved from 0.63241 to 0.63442, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/AlexNet/058.h5
# 350/350 [==============================] - 731s 2s/step - loss: 0.2970 - accuracy: 0.9084 - top5_acc: 0.9904 - macro_f1score: 0.6398 - val_loss: 1.6497 - val_accuracy: 0.6344 - val_top5_acc: 0.8750 - val_macro_f1score: 0.4288
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00059: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 59/70
# 350/350 [==============================] - ETA: 0s - loss: 0.3037 - accuracy: 0.9052 - top5_acc: 0.9906 - macro_f1score: 0.6433
# Epoch 00059: val_loss did not improve from 1.56764
#
# Epoch 00059: val_accuracy did not improve from 0.63442
# 350/350 [==============================] - 727s 2s/step - loss: 0.3037 - accuracy: 0.9052 - top5_acc: 0.9906 - macro_f1score: 0.6433 - val_loss: 1.6720 - val_accuracy: 0.6298 - val_top5_acc: 0.8710 - val_macro_f1score: 0.4270
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00060: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 60/70
# 350/350 [==============================] - ETA: 0s - loss: 0.2958 - accuracy: 0.9089 - top5_acc: 0.9902 - macro_f1score: 0.6428
# Epoch 00060: val_loss did not improve from 1.56764
#
# Epoch 00060: val_accuracy did not improve from 0.63442
# 350/350 [==============================] - 729s 2s/step - loss: 0.2958 - accuracy: 0.9089 - top5_acc: 0.9902 - macro_f1score: 0.6428 - val_loss: 1.6638 - val_accuracy: 0.6328 - val_top5_acc: 0.8720 - val_macro_f1score: 0.4169
# Learning rate:  2.9999999999999997e-06
#
# Epoch 00061: LearningRateScheduler reducing learning rate to 2.9999999999999997e-06.
# Epoch 61/70
# 350/350 [==============================] - ETA: 0s - loss: 0.2872 - accuracy: 0.9115 - top5_acc: 0.9911 - macro_f1score: 0.6435
# Epoch 00061: val_loss did not improve from 1.56764
#
# Epoch 00061: val_accuracy did not improve from 0.63442
# 350/350 [==============================] - 727s 2s/step - loss: 0.2872 - accuracy: 0.9115 - top5_acc: 0.9911 - macro_f1score: 0.6435 - val_loss: 1.6497 - val_accuracy: 0.6342 - val_top5_acc: 0.8764 - val_macro_f1score: 0.4363
# Learning rate:  2.9999999999999997e-06
#
# Epoch 00062: LearningRateScheduler reducing learning rate to 2.9999999999999997e-06.
# Epoch 62/70
# 350/350 [==============================] - ETA: 0s - loss: 0.2782 - accuracy: 0.9139 - top5_acc: 0.9916 - macro_f1score: 0.6471
# Epoch 00062: val_loss did not improve from 1.56764
#
# Epoch 00062: val_accuracy improved from 0.63442 to 0.63542, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/AlexNet/062.h5
# 350/350 [==============================] - 732s 2s/step - loss: 0.2782 - accuracy: 0.9139 - top5_acc: 0.9916 - macro_f1score: 0.6471 - val_loss: 1.6398 - val_accuracy: 0.6354 - val_top5_acc: 0.8750 - val_macro_f1score: 0.4347
# Learning rate:  2.9999999999999997e-06
#
# Epoch 00063: LearningRateScheduler reducing learning rate to 2.9999999999999997e-06.
# Epoch 63/70
# 350/350 [==============================] - ETA: 0s - loss: 0.2734 - accuracy: 0.9156 - top5_acc: 0.9917 - macro_f1score: 0.6469
# Epoch 00063: val_loss did not improve from 1.56764
#
# Epoch 00063: val_accuracy improved from 0.63542 to 0.63602, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/AlexNet/063.h5
# 350/350 [==============================] - 731s 2s/step - loss: 0.2734 - accuracy: 0.9156 - top5_acc: 0.9917 - macro_f1score: 0.6469 - val_loss: 1.6248 - val_accuracy: 0.6360 - val_top5_acc: 0.8770 - val_macro_f1score: 0.4339
# Learning rate:  2.9999999999999997e-06
#
# Epoch 00064: LearningRateScheduler reducing learning rate to 2.9999999999999997e-06.
# Epoch 64/70
# 350/350 [==============================] - ETA: 0s - loss: 0.2769 - accuracy: 0.9141 - top5_acc: 0.9910 - macro_f1score: 0.6440
# Epoch 00064: val_loss did not improve from 1.56764
#
# Epoch 00064: val_accuracy did not improve from 0.63602
# 350/350 [==============================] - 728s 2s/step - loss: 0.2769 - accuracy: 0.9141 - top5_acc: 0.9910 - macro_f1score: 0.6440 - val_loss: 1.6091 - val_accuracy: 0.6340 - val_top5_acc: 0.8764 - val_macro_f1score: 0.4212
# Learning rate:  2.9999999999999997e-06
#
# Epoch 00065: LearningRateScheduler reducing learning rate to 2.9999999999999997e-06.
# Epoch 65/70
# 350/350 [==============================] - ETA: 0s - loss: 0.2761 - accuracy: 0.9132 - top5_acc: 0.9917 - macro_f1score: 0.6470
# Epoch 00065: val_loss did not improve from 1.56764
#
# Epoch 00065: val_accuracy did not improve from 0.63602
# 350/350 [==============================] - 729s 2s/step - loss: 0.2761 - accuracy: 0.9132 - top5_acc: 0.9917 - macro_f1score: 0.6470 - val_loss: 1.6168 - val_accuracy: 0.6354 - val_top5_acc: 0.8762 - val_macro_f1score: 0.4250
# Learning rate:  2.9999999999999997e-06
#
# Epoch 00066: LearningRateScheduler reducing learning rate to 2.9999999999999997e-06.
# Epoch 66/70
# 350/350 [==============================] - ETA: 0s - loss: 0.2767 - accuracy: 0.9152 - top5_acc: 0.9915 - macro_f1score: 0.6481
# Epoch 00066: val_loss did not improve from 1.56764
#
# Epoch 00066: val_accuracy did not improve from 0.63602
# 350/350 [==============================] - 728s 2s/step - loss: 0.2767 - accuracy: 0.9152 - top5_acc: 0.9915 - macro_f1score: 0.6481 - val_loss: 1.6034 - val_accuracy: 0.6356 - val_top5_acc: 0.8764 - val_macro_f1score: 0.4307
# Learning rate:  2.9999999999999997e-06
#
# Epoch 00067: LearningRateScheduler reducing learning rate to 2.9999999999999997e-06.
# Epoch 67/70
# 350/350 [==============================] - ETA: 0s - loss: 0.2734 - accuracy: 0.9155 - top5_acc: 0.9917 - macro_f1score: 0.6455
# Epoch 00067: val_loss did not improve from 1.56764
#
# Epoch 00067: val_accuracy improved from 0.63602 to 0.63742, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/AlexNet/067.h5
# 350/350 [==============================] - 728s 2s/step - loss: 0.2734 - accuracy: 0.9155 - top5_acc: 0.9917 - macro_f1score: 0.6455 - val_loss: 1.5993 - val_accuracy: 0.6374 - val_top5_acc: 0.8788 - val_macro_f1score: 0.4320
# Learning rate:  2.9999999999999997e-06
#
# Epoch 00068: LearningRateScheduler reducing learning rate to 2.9999999999999997e-06.
# Epoch 68/70
# 350/350 [==============================] - ETA: 0s - loss: 0.2742 - accuracy: 0.9158 - top5_acc: 0.9919 - macro_f1score: 0.6470
# Epoch 00068: val_loss did not improve from 1.56764
#
# Epoch 00068: val_accuracy did not improve from 0.63742
# 350/350 [==============================] - 731s 2s/step - loss: 0.2742 - accuracy: 0.9158 - top5_acc: 0.9919 - macro_f1score: 0.6470 - val_loss: 1.5934 - val_accuracy: 0.6366 - val_top5_acc: 0.8772 - val_macro_f1score: 0.4321
# Learning rate:  2.9999999999999997e-06
#
# Epoch 00069: LearningRateScheduler reducing learning rate to 2.9999999999999997e-06.
# Epoch 69/70
# 350/350 [==============================] - ETA: 0s - loss: 0.2700 - accuracy: 0.9140 - top5_acc: 0.9923 - macro_f1score: 0.6432
# Epoch 00069: val_loss did not improve from 1.56764
#
# Epoch 00069: val_accuracy did not improve from 0.63742
# 350/350 [==============================] - 725s 2s/step - loss: 0.2700 - accuracy: 0.9140 - top5_acc: 0.9923 - macro_f1score: 0.6432 - val_loss: 1.5945 - val_accuracy: 0.6334 - val_top5_acc: 0.8774 - val_macro_f1score: 0.4213
# Learning rate:  2.9999999999999997e-06
#
# Epoch 00070: LearningRateScheduler reducing learning rate to 2.9999999999999997e-06.
# Epoch 70/70
# 350/350 [==============================] - ETA: 0s - loss: 0.2746 - accuracy: 0.9163 - top5_acc: 0.9922 - macro_f1score: 0.6444
# Epoch 00070: val_loss did not improve from 1.56764
#
# Epoch 00070: val_accuracy did not improve from 0.63742
# 350/350 [==============================] - 722s 2s/step - loss: 0.2746 - accuracy: 0.9163 - top5_acc: 0.9922 - macro_f1score: 0.6444 - val_loss: 1.5930 - val_accuracy: 0.6358 - val_top5_acc: 0.8744 - val_macro_f1score: 0.4340

# %% [markdown]
# ### 3) AlexNet Evaluate

# %%
# 1. epoch=maximum
loss , acc, top5_acc, mf1 = model.evaluate(test_generator,steps=int(len(x_test)/batch_sizes))
print('[Test Loss: %.4f /  Test Top-1 Accuracy: %.4f / Test Top-5 Accuracy: %.4f / Test Macro f1: %.4f]\n' % (loss,acc,top5_acc,mf1))
# Out:
# 78/78 [==============================] - 5552s 71s/step - loss: 1.6132 - accuracy: 0.6273 - top5_acc: 0.8685 - macro_f1score: 0.4269
# [Test Loss: 1.6132 /  Test Top-1 Accuracy: 0.6273 / Test Top-5 Accuracy: 0.8685 / Test Macro f1: 0.4269]

# %%
loss=history.history['loss']
val_loss=history.history['val_loss']
acc=history.history['accuracy']
val_acc=history.history['val_accuracy']
top5_acc=history.history['top5_acc']
val_top5_acc=history.history['val_top5_acc']
f1=history.history['macro_f1score']
val_f1=history.history['val_macro_f1score']
epochs=range(1,len(acc)+1)

data = np.array([epochs,loss,val_loss,acc,val_acc,top5_acc,val_top5_acc,f1,val_f1]).T

# %%
# data save
# epochs, loss, val_loss, acc, val_acc, top5_acc, val_top5_acc, f1, val_f1

np.savetxt(os.path.join(dir,'train_valid_output',number,model.name+'.txt'),data)

# %%
# data import
data = np.loadtxt(os.path.join(dir,'train_valid_output',number,'AlexNet.txt'))

# %%
epochs=data[:,0]
loss=data[:,1]
val_loss=data[:,2]
acc=data[:,3]
val_acc=data[:,4]
top5_acc=data[:,5]
val_top5_acc=data[:,6]

# %%
plt.plot(epochs[1:],acc[1:],'b',label='Training 1-Acc')
plt.plot(epochs[1:],val_acc[1:],'r',label='Validation 1-Acc')
plt.title('Training and Validation Top-1 Accuracy')
plt.legend()
plt.figure()

plt.plot(epochs[1:],top5_acc[1:],'b',label='Training 5-Acc')
plt.plot(epochs[1:],val_top5_acc[1:],'r',label='Validation 5-Acc')
plt.title('Training and Validation Top-5 Accuracy')
plt.legend()
plt.figure()

plt.plot(epochs[10:],loss[10:],'b',label='Training Loss')
plt.plot(epochs[10:],val_loss[10:],'r',label='Validation Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()

# %%
# 이 아래는 내가 인위적으로 살펴보고 싶은 epoch에 대해서 결과값 출력 / AlexNet

# %%
# 참고 : https://github.com/OverLordGoldDragon/keras-adamw

import sys
sys.path.append('/content/drive/My Drive/Colab Notebooks/Paper')
import utils
import optimizers_v2
from utils import get_weight_decays, fill_dict_in_order
from utils import reset_seeds, K_eval
from optimizers_v2 import AdamW, NadamW, SGDW

# %%
# top-5 accuracy 출력
import functools
top5_acc = functools.partial(ks.metrics.top_k_categorical_accuracy, k=5)
top5_acc.__name__ = 'top5_acc'

# %%
model=load_model(os.path.join(dir,'model_output',number,'AlexNet','067.h5'),custom_objects={"macro_f1score": macro_f1score,"top5_acc":top5_acc,"LRN":LRN, "AdamW":AdamW})

# %%
# 2. epoch=?
loss , acc, top5_acc, mf1 = model.evaluate(test_generator,steps=int(len(x_test)/batch_sizes))
print('[Test Loss: %.4f /  Test Top-1 Accuracy: %.4f / Test Top-5 Accuracy: %.4f / Test Macro f1: %.4f]\n' % (loss,acc,top5_acc,mf1))
# Out:
# 78/78 [==============================] - 5299s 68s/step - loss: 1.6304 - accuracy: 0.6270 - top5_acc: 0.8677 - macro_f1score: 0.4257
# [Test Loss: 1.6304 /  Test Top-1 Accuracy: 0.6270 / Test Top-5 Accuracy: 0.8677 / Test Macro f1: 0.4257]
