# %%
#모형 출처 : https://github.com/titu1994/keras-squeeze-excite-network

# %% [markdown]
# # [ResNet18]

# %% [markdown]
# *KU LeeDongGyu*

# %% [markdown]
# ## Contents
# ---

# %% [markdown]
# 1. Data Preprocessing
# ```
# 1) Data Import
# 2) Data Augmentation
# ```
# 2. Support Functions & Almost Original ResNet
# ```
# 1) Support Functions
# 2) Almost orginal ResNet
# ```
# 3. ResNet18
# ```
# 1) ResNet18
# 2) ResNet18 Evaluate
# ```

# %% [markdown]
# ### Install Packages

# %% [markdown]
# ### Module

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
cd /content/drive/My Drive/Colab Notebooks/Paper
# Out:
# /content/drive/My Drive/Colab Notebooks/Paper

# %%
from f1score import macro_f1score,weighted_f1score

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import cv2
import tensorflow as tf
from tensorflow import keras as ks
from tensorflow.keras import backend as K 
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, Input, Concatenate, ZeroPadding2D ,GlobalMaxPooling2D, Reshape , Lambda , Add, Multiply
from tensorflow.keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D, Activation, BatchNormalization, AveragePooling2D , ZeroPadding2D, SeparableConv2D , LeakyReLU
from tensorflow.keras.layers import add, concatenate, multiply
from tensorflow.keras.optimizers import Adam, RMSprop , SGD
from tensorflow.keras.callbacks import EarlyStopping , LearningRateScheduler, ModelCheckpoint, CSVLogger, Callback, ReduceLROnPlateau
from tensorflow.keras.regularizers import l1,l2,l1_l2
from tensorflow.keras.models import Model , load_model , Sequential
from tensorflow.keras.utils import plot_model , to_categorical, get_file
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
os.getcwd()
# Out:
# '/content/drive/My Drive/Colab Notebooks/Paper'

# %%
print(tf.__version__)
print(ks.__version__)
# Out:
# 2.3.0
# 2.4.0

# %%
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 13750421243860546488
# , name: "/device:XLA_CPU:0"
# device_type: "XLA_CPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 16246974316990888538
# physical_device_desc: "device: XLA_CPU device"
# , name: "/device:XLA_GPU:0"
# device_type: "XLA_GPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 15898464095313495763
# physical_device_desc: "device: XLA_GPU device"
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 15473775744
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 11634969364322045743
# physical_device_desc: "device: 0, name: Tesla V100-SXM2-16GB, pci bus id: 0000:00:04.0, compute capability: 7.0"
# ]

# %%
# !cat /proc/cpuinfo
# Out:
# processor	: 0
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 85
# model name	: Intel(R) Xeon(R) CPU @ 2.00GHz
# stepping	: 3
# microcode	: 0x1
# cpu MHz		: 2000.180
# cache size	: 39424 KB
# physical id	: 0
# siblings	: 4
# core id		: 0
# cpu cores	: 2
# apicid		: 0
# initial apicid	: 0
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm mpx avx512f avx512dq rdseed adx smap clflushopt clwb avx512cd avx512bw avx512vl xsaveopt xsavec xgetbv1 xsaves arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs taa
# bogomips	: 4000.36
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 46 bits physical, 48 bits virtual
# power management:
#
# processor	: 1
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 85
# model name	: Intel(R) Xeon(R) CPU @ 2.00GHz
# stepping	: 3
# microcode	: 0x1
# cpu MHz		: 2000.180
# cache size	: 39424 KB
# physical id	: 0
# siblings	: 4
# core id		: 1
# cpu cores	: 2
# apicid		: 2
# initial apicid	: 2
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm mpx avx512f avx512dq rdseed adx smap clflushopt clwb avx512cd avx512bw avx512vl xsaveopt xsavec xgetbv1 xsaves arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs taa
# bogomips	: 4000.36
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 46 bits physical, 48 bits virtual
# power management:
#
# processor	: 2
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 85
# model name	: Intel(R) Xeon(R) CPU @ 2.00GHz
# stepping	: 3
# microcode	: 0x1
# cpu MHz		: 2000.180
# cache size	: 39424 KB
# physical id	: 0
# siblings	: 4
# core id		: 0
# cpu cores	: 2
# apicid		: 1
# initial apicid	: 1
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm mpx avx512f avx512dq rdseed adx smap clflushopt clwb avx512cd avx512bw avx512vl xsaveopt xsavec xgetbv1 xsaves arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs taa
# bogomips	: 4000.36
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 46 bits physical, 48 bits virtual
# power management:
#
# processor	: 3
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 85
# model name	: Intel(R) Xeon(R) CPU @ 2.00GHz
# stepping	: 3
# microcode	: 0x1
# cpu MHz		: 2000.180
# cache size	: 39424 KB
# physical id	: 0
# siblings	: 4
# core id		: 1
# cpu cores	: 2
# apicid		: 3
# initial apicid	: 3
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm mpx avx512f avx512dq rdseed adx smap clflushopt clwb avx512cd avx512bw avx512vl xsaveopt xsavec xgetbv1 xsaves arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs taa
# bogomips	: 4000.36
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 46 bits physical, 48 bits virtual
# power management:

# %% [markdown]
# ## 1. Data Preprocessing
# ---

# %% [markdown]
# ### 1) Data Import

# %%
# 바꿔서 살펴 볼 것들
# CALTECH, CIFAR100, FER, MIT
data_name = 'CIFAR100'
gan_type = 'No_GAN'
number = '1'
size = 224 # sizes after cropping
super_size = 256 # sizes before cropping 
input_sizes = (size,size,3)
batch_sizes = 128
weight_decay = 2e-3
epochs = 70

# %%
# 참고 : https://stackoverflow.com/questions/32419510/how-to-get-reproducible-results-in-keras/52897216#52897216
# setting the seed number for random number generation for reproducibility.

from numpy.random import seed
import random


if number=='1':
    seed_num = 200225
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)
elif number=='2':
    seed_num = 727
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)
elif number=='3':
    seed_num = 115
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)
elif number=='4':
    seed_num = 501
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)
elif number=='5':
    seed_num = 517
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)

# %%
# data import

if data_name=='FER' :
    x_train =  np.zeros(28698)
    x_valid = np.zeros(3589)
    x_test = np.zeros(3588)
    classes = 7 
    tr_center = [0.50793296, 0.50793296, 0.50793296]
elif data_name=='MIT':
    x_train = np.zeros(12466)
    x_valid = np.zeros(1564)
    x_test = np.zeros(1590)
    classes = 67 
    tr_center = [0.47916578, 0.42029615, 0.36046057]
elif data_name=='CALTECH':
    x_train = np.zeros(24510)
    x_valid = np.zeros(2980)
    x_test = np.zeros(3118)
    classes = 257
    tr_center = [0.51397761, 0.49525248, 0.46555727]
elif data_name=='CIFAR100':
    x_train = np.zeros(44923)
    x_valid = np.zeros(5077)
    x_test = np.zeros(10000)
    classes = 100
    tr_center = [0.53442983, 0.51355958, 0.46462564]

# %%
dir = os.path.join(os.getcwd(),data_name,gan_type)

# %% [markdown]
# ### 2) Data Augmentation

# %%
# 참고 : https://jkjung-avt.github.io/keras-image-cropping/

def random_crop(img, random_crop_size):
    # Note: image_data_format is 'channel_last'
    assert img.shape[2] == 3 # img.shape[2] 가 3(rgb)이 아니면 assertion error 발생
    height, width = img.shape[0], img.shape[1]
    dy, dx = random_crop_size
    x = np.random.randint(0, width - dx + 1)
    y = np.random.randint(0, height - dy + 1)
    return img[y:(y+dy), x:(x+dx), :]


def crop_generator(batches, crop_length):
    """Take as input a Keras ImageGen (Iterator) and generate random
    crops from the image batches generated by the original iterator.
    """
    while True:
        batch_x, batch_y = next(batches)
        batch_crops = np.zeros((batch_x.shape[0], crop_length, crop_length, 3))
        for i in range(batch_x.shape[0]):
            batch_crops[i] = random_crop(batch_x[i], (crop_length, crop_length))
        yield (batch_crops, batch_y)

# %%
from tensorflow.keras.preprocessing.image import img_to_array,load_img
import glob

# 데이터 전체에 대해 centering 진행함.

def read_cal_image(img_path): 
    x = img_to_array(load_img(img_path)) # x는 채널별 평균값
    y = x.shape[0] * x.shape[1]# y는 데이터별 픽셀 수 (비중)

    x = 1/255. * x # scaling하고, centering값을 뽑아냄.
    x = np.mean(x, axis=(0,1))
    
    return np.hstack([x,y])

def calculate_centered_mean(dataset_path,x_train=x_train):
    num = len(x_train)
    space = np.empty((num,4))
    i=0

    for p in glob.glob(os.path.join(dataset_path,'*/*.*')) :
        space[i] = read_cal_image(p)
        i += 1

    ratio = space[:,3] / np.sum(space[:,3])

    return np.average(space[:,0:3],axis=0,weights=ratio)


# 아래의 함수를 돌려서 나온 결과값을 중심화 값으로 설정.

# train_mean = calculate_centered_mean(os.path.join(dir,'data/train')).reshape((1,1,3))

# %%
datagen_tr = ImageDataGenerator(
    rescale=1/255.,
    horizontal_flip=True,
    featurewise_center=True,
    featurewise_std_normalization=False,
    rotation_range=10,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=[0.9,1.0],
    fill_mode = 'nearest')
datagen_val = ImageDataGenerator(rescale=1/255.,featurewise_center=True)
datagen_tes = ImageDataGenerator(rescale=1/255.,featurewise_center=True)

# 원래는 이 자리에 fit 매서드를 써야하지만, 그냥 내가 중심화함수를 만들고 적용함. 

# 중심화 설정
datagen_tr.mean = np.array(tr_center, dtype=np.float32).reshape((1,1,3)) # RGB
datagen_val.mean = np.array(tr_center, dtype=np.float32).reshape((1,1,3)) # RGB
datagen_tes.mean = np.array(tr_center, dtype=np.float32).reshape((1,1,3)) # RGB

# %%
train_batches = datagen_tr.flow_from_directory(directory=os.path.join(dir,'data/train'),target_size=(super_size,super_size),batch_size=batch_sizes,class_mode='categorical') # fer : 28698 / mit : 12466 / caltech : 24509 / cifar : 44923
train_generator= crop_generator(train_batches, size)
valid_generator = datagen_val.flow_from_directory(directory=os.path.join(dir,'data/valid'),target_size=(size,size),batch_size=batch_sizes,class_mode='categorical') # fer : 3589 / mit : 1564 / caltech : 2980 / cifar : 5077
test_generator = datagen_tes.flow_from_directory(directory=os.path.join(dir,'data/test'),target_size=(size,size),batch_size=batch_sizes,class_mode='categorical') # fer : 3588 / mit : 1590 / caltech : 3118 / cifar : 10000
# Out:
# Found 44923 images belonging to 100 classes.
# Found 5077 images belonging to 100 classes.
# Found 10000 images belonging to 100 classes.

# %% [markdown]
# ## 2. Support Functions & Almost Original ResNet
# ---

# %% [markdown]
# ### 1) Support Functions

# %%
# def lr_schedule(epoch):
#     init_lr = 1e-4
#     k = 0.04
#     lr = init_lr * np.exp(-k*epoch)
#     print('Learning rate: ', lr)
#     return lr

def lr_schedule(epoch):
    lr = 1e-3
    if epoch < 30:
        lr = lr
    elif epoch < 60 :
        lr = lr * 0.1
    else:
        lr = lr * 0.01
    print('Learning rate: ', lr)
    return lr

# %%
def _resnet_block(input_tensor, filters, k=1, strides=(1, 1), weight_decay = weight_decay):

    init = input_tensor
    channel_axis = -1

    if strides != (1, 1) or init.get_shape()[channel_axis] != filters * k:
        x = Conv2D(filters * k, (1, 1), padding='same', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay),
                      use_bias=False, strides=strides)(input_tensor)
        init = BatchNormalization(axis=channel_axis)(x)


    x = Conv2D(filters * k, (3, 3), padding='same', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay),
               use_bias=False, strides=strides)(input_tensor)
    x = BatchNormalization(axis=channel_axis)(x)
    x = Activation('relu')(x)

    x = Conv2D(filters * k, (3, 3), padding='same', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay),
               use_bias=False)(x)
    x = BatchNormalization(axis=channel_axis)(x)

    m = add([x, init])
    m = Activation('relu')(m)

    return m

# %%
def _resnet_bottleneck_block(input_tensor, filters, k=1, strides=(1, 1), weight_decay = weight_decay):

    init = input_tensor
    channel_axis = -1
    bottleneck_expand = 4

    if strides != (1, 1) or init.get_shape()[channel_axis] != bottleneck_expand * filters * k:
        x = Conv2D(bottleneck_expand * filters * k, (1, 1), padding='same', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay),
                      use_bias=False, strides=strides)(input_tensor)
        init = BatchNormalization(axis=channel_axis)(x)


    x = Conv2D(filters * k, (1, 1), padding='same', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay),
               use_bias=False)(input_tensor)
    x = BatchNormalization(axis=channel_axis)(x)
    x = Activation('relu')(x)

    x = Conv2D(filters * k, (3, 3), padding='same', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay),
               use_bias=False, strides=strides)(x)
    x = BatchNormalization(axis=channel_axis)(x)
    x = Activation('relu')(x)

    x = Conv2D(bottleneck_expand * filters * k, (1, 1), padding='same', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay),
               use_bias=False)(x)
    x = BatchNormalization(axis=channel_axis)(x)    

    m = add([x, init])
    m = Activation('relu')(m)

    return m

# %% [markdown]
# ### 2) Almost Orginial ResNet

# %%
def _create_resnet(classes, img_input, initial_conv_filters, filters, depth, width, bottleneck, weight_decay):

    channel_axis = -1
    N = list(depth)

    # block 1 (initial conv block)
    x = Conv2D(initial_conv_filters, (7, 7), padding='same', use_bias=False, strides=(2, 2), kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(img_input)
    x = MaxPooling2D((3, 3), strides=(2, 2), padding='same')(x)

    # block 2 (projection block)
    for i in range(N[0]):
        if bottleneck:
            x = _resnet_bottleneck_block(x, filters[0], width)
        else:
            x = _resnet_block(x, filters[0], width)

    # block 3 - N
    for k in range(1, len(N)):
        if bottleneck:
            x = _resnet_bottleneck_block(x, filters[k], width, strides=(2, 2))
        else:
            x = _resnet_block(x, filters[k], width, strides=(2, 2))

        for i in range(N[k] - 1):
            if bottleneck:
                x = _resnet_bottleneck_block(x, filters[k], width)
            else:
                x = _resnet_block(x, filters[k], width)

    x = GlobalAveragePooling2D()(x)
    x = Dense(classes, use_bias=False, kernel_regularizer=l2(weight_decay), activation='softmax')(x)


    return x

# %%
def ResNet(input_shape=None, initial_conv_filters=64, depth=[3, 4, 6, 3], filters=[64, 128, 256, 512],
             width=1, bottleneck=False, weight_decay=weight_decay, name=None, classes=1000):


    img_input = Input(shape=input_shape)

    x = _create_resnet(classes, img_input, initial_conv_filters, filters, depth, width, bottleneck, weight_decay)

    # Ensure that the model takes into account
    # any potential predecessors of `input_tensor`.

    inputs = img_input

    # Create model.
    model = Model(inputs, x, name = name)

    return model

# %% [markdown]
# ## 3. ResNet18
# ---

# %% [markdown]
# ### 1) ResNet18

# %%
# ResNet18
model = ResNet(input_shape=input_sizes, depth=[2, 2, 2, 2], width=1, bottleneck=False, weight_decay=weight_decay, classes=classes, name='ResNet18')

# %%
model.summary()
# Out:
# Model: "ResNet18"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 112, 112, 64) 9408        input_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 56, 56, 64)   0           conv2d[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 56, 56, 64)   36864       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 56, 56, 64)   256         conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 56, 56, 64)   0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 56, 56, 64)   36864       activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 56, 56, 64)   256         conv2d_2[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 56, 56, 64)   0           batch_normalization_1[0][0]
#                                                                  max_pooling2d[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 56, 56, 64)   0           add[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 56, 56, 64)   36864       activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 56, 56, 64)   256         conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 56, 56, 64)   0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 56, 56, 64)   36864       activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 56, 56, 64)   256         conv2d_4[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 56, 56, 64)   0           batch_normalization_3[0][0]
#                                                                  activation_1[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 56, 56, 64)   0           add_1[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 28, 28, 128)  73728       activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 28, 28, 128)  512         conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 28, 28, 128)  0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 28, 28, 128)  147456      activation_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 28, 28, 128)  8192        activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 28, 28, 128)  512         conv2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 28, 28, 128)  512         conv2d_5[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 28, 28, 128)  0           batch_normalization_6[0][0]
#                                                                  batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 28, 28, 128)  0           add_2[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 28, 28, 128)  147456      activation_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 28, 28, 128)  512         conv2d_8[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 28, 28, 128)  0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 28, 28, 128)  147456      activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 28, 28, 128)  512         conv2d_9[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 28, 28, 128)  0           batch_normalization_8[0][0]
#                                                                  activation_5[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 28, 28, 128)  0           add_3[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 14, 14, 256)  294912      activation_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 14, 14, 256)  1024        conv2d_11[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 14, 14, 256)  0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 14, 14, 256)  589824      activation_8[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 14, 14, 256)  32768       activation_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 14, 14, 256)  1024        conv2d_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 14, 14, 256)  1024        conv2d_10[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 14, 14, 256)  0           batch_normalization_11[0][0]
#                                                                  batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 14, 14, 256)  0           add_4[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 14, 14, 256)  589824      activation_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 14, 14, 256)  1024        conv2d_13[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 14, 14, 256)  0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 14, 14, 256)  589824      activation_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 14, 14, 256)  1024        conv2d_14[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 14, 14, 256)  0           batch_normalization_13[0][0]
#                                                                  activation_9[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 14, 14, 256)  0           add_5[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 7, 7, 512)    1179648     activation_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 7, 7, 512)    2048        conv2d_16[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 7, 7, 512)    0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 7, 7, 512)    2359296     activation_12[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 7, 7, 512)    131072      activation_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 7, 7, 512)    2048        conv2d_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 7, 7, 512)    2048        conv2d_15[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 7, 7, 512)    0           batch_normalization_16[0][0]
#                                                                  batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 7, 7, 512)    0           add_6[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 7, 7, 512)    2359296     activation_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 7, 7, 512)    2048        conv2d_18[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 7, 7, 512)    0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 7, 7, 512)    2359296     activation_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 7, 7, 512)    2048        conv2d_19[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 7, 7, 512)    0           batch_normalization_18[0][0]
#                                                                  activation_13[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 7, 7, 512)    0           add_7[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 512)          0           activation_15[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 100)          51200       global_average_pooling2d[0][0]
# ==================================================================================================
# Total params: 11,237,056
# Trainable params: 11,227,584
# Non-trainable params: 9,472
# __________________________________________________________________________________________________

# %%
# 폴더 생성

os.makedirs(os.path.join(dir,'model_output',number,model.name), exist_ok=True)
os.makedirs(os.path.join(dir,'train_valid_output',number), exist_ok=True)

# %%
# 참고 : https://github.com/OverLordGoldDragon/keras-adamw

import sys
sys.path.append('/content/drive/My Drive/Colab Notebooks/Paper')
import utils
import optimizers_v2
from utils import get_weight_decays, fill_dict_in_order
from utils import reset_seeds, K_eval
from optimizers_v2 import AdamW, NadamW, SGDW

# %%
# top-5 accuracy 출력
import functools
top5_acc = functools.partial(ks.metrics.top_k_categorical_accuracy, k=5)
top5_acc.__name__ = 'top5_acc'

# %%
#optimizer = SGDW(model=model, use_cosine_annealing=False, total_iterations = len(x_train) // batch_sizes, nesterov=True, momentum=0.9)
optimizer = AdamW(model=model, use_cosine_annealing=False, total_iterations = len(x_train) // batch_sizes)
#optimizer = Adam()
filepath =  os.path.join(dir,'model_output',number,model.name,'{epoch:03d}.h5')

callbacks_list = [ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_weights_only=False, save_best_only=True, mode='min'),
                  ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_weights_only=False, save_best_only=True, mode='max'),
                  #ReduceLROnPlateau(monitor='val_loss',patience=3,factor=0.1,min_lr=1e-5),
                  LearningRateScheduler(lr_schedule,verbose=1)
                  ]
                  
model.compile(optimizer, loss = 'categorical_crossentropy', metrics=['accuracy',top5_acc,macro_f1score])

# %%
######## flow_from_directory
history = model.fit(train_generator, steps_per_epoch=int(len(x_train)/batch_sizes),  validation_data = valid_generator, epochs=epochs , verbose=1 , callbacks = callbacks_list , validation_steps=int(len(x_valid)/batch_sizes))
# Out:
# Learning rate:  0.001
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 1/70
# 0.0(L1), 0.00010690450184266088(L2) weight decay set for conv2d/kernel:0
# 0.0(L1), 0.00010690450184266088(L2) weight decay set for conv2d_1/kernel:0
# 0.0(L1), 0.00010690450184266088(L2) weight decay set for conv2d_2/kernel:0
# 0.0(L1), 0.00010690450184266088(L2) weight decay set for conv2d_3/kernel:0
# 0.0(L1), 0.00010690450184266088(L2) weight decay set for conv2d_4/kernel:0
# 0.0(L1), 0.00010690450184266088(L2) weight decay set for conv2d_6/kernel:0
# 0.0(L1), 0.00010690450184266088(L2) weight decay set for conv2d_7/kernel:0
# 0.0(L1), 0.00010690450184266088(L2) weight decay set for conv2d_5/kernel:0
# 0.0(L1), 0.00010690450184266088(L2) weight decay set for conv2d_8/kernel:0
# 0.0(L1), 0.00010690450184266088(L2) weight decay set for conv2d_9/kernel:0
# 0.0(L1), 0.00010690450184266088(L2) weight decay set for conv2d_11/kernel:0
# 0.0(L1), 0.00010690450184266088(L2) weight decay set for conv2d_12/kernel:0
# 0.0(L1), 0.00010690450184266088(L2) weight decay set for conv2d_10/kernel:0
# 0.0(L1), 0.00010690450184266088(L2) weight decay set for conv2d_13/kernel:0
# 0.0(L1), 0.00010690450184266088(L2) weight decay set for conv2d_14/kernel:0
# 0.0(L1), 0.00010690450184266088(L2) weight decay set for conv2d_16/kernel:0
# 0.0(L1), 0.00010690450184266088(L2) weight decay set for conv2d_17/kernel:0
# 0.0(L1), 0.00010690450184266088(L2) weight decay set for conv2d_15/kernel:0
# 0.0(L1), 0.00010690450184266088(L2) weight decay set for conv2d_18/kernel:0
# 0.0(L1), 0.00010690450184266088(L2) weight decay set for conv2d_19/kernel:0
# 0.0(L1), 0.00010690450184266088(L2) weight decay set for dense/kernel:0
# 350/350 [==============================] - ETA: 0s - loss: 3.8523 - accuracy: 0.1157 - top5_acc: 0.3242 - macro_f1score: 0.0076
# Epoch 00001: val_loss improved from inf to 4.34280, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/ResNet18/001.h5
#
# Epoch 00001: val_accuracy improved from -inf to 0.08313, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/ResNet18/001.h5
# 350/350 [==============================] - 12409s 35s/step - loss: 3.8523 - accuracy: 0.1157 - top5_acc: 0.3242 - macro_f1score: 0.0076 - val_loss: 4.3428 - val_accuracy: 0.0831 - val_top5_acc: 0.2766 - val_macro_f1score: 0.0074
# Learning rate:  0.001
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 2/70
# 350/350 [==============================] - ETA: 0s - loss: 3.2480 - accuracy: 0.2113 - top5_acc: 0.4931 - macro_f1score: 0.0342
# Epoch 00002: val_loss improved from 4.34280 to 3.39243, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/ResNet18/002.h5
#
# Epoch 00002: val_accuracy improved from 0.08313 to 0.19972, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/ResNet18/002.h5
# 350/350 [==============================] - 648s 2s/step - loss: 3.2480 - accuracy: 0.2113 - top5_acc: 0.4931 - macro_f1score: 0.0342 - val_loss: 3.3924 - val_accuracy: 0.1997 - val_top5_acc: 0.4798 - val_macro_f1score: 0.0513
# Learning rate:  0.001
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 3/70
# 350/350 [==============================] - ETA: 0s - loss: 2.7674 - accuracy: 0.2977 - top5_acc: 0.6150 - macro_f1score: 0.0834
# Epoch 00003: val_loss improved from 3.39243 to 2.97912, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/ResNet18/003.h5
#
# Epoch 00003: val_accuracy improved from 0.19972 to 0.25501, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/ResNet18/003.h5
# 350/350 [==============================] - 619s 2s/step - loss: 2.7674 - accuracy: 0.2977 - top5_acc: 0.6150 - macro_f1score: 0.0834 - val_loss: 2.9791 - val_accuracy: 0.2550 - val_top5_acc: 0.5683 - val_macro_f1score: 0.0897
# Learning rate:  0.001
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 4/70
# 350/350 [==============================] - ETA: 0s - loss: 2.3721 - accuracy: 0.3781 - top5_acc: 0.7013 - macro_f1score: 0.1429
# Epoch 00004: val_loss improved from 2.97912 to 2.75171, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/ResNet18/004.h5
#
# Epoch 00004: val_accuracy improved from 0.25501 to 0.32111, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/ResNet18/004.h5
# 350/350 [==============================] - 606s 2s/step - loss: 2.3721 - accuracy: 0.3781 - top5_acc: 0.7013 - macro_f1score: 0.1429 - val_loss: 2.7517 - val_accuracy: 0.3211 - val_top5_acc: 0.6354 - val_macro_f1score: 0.1382
# Learning rate:  0.001
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 5/70
# 350/350 [==============================] - ETA: 0s - loss: 2.0825 - accuracy: 0.4436 - top5_acc: 0.7589 - macro_f1score: 0.1939
# Epoch 00005: val_loss improved from 2.75171 to 2.40087, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/ResNet18/005.h5
#
# Epoch 00005: val_accuracy improved from 0.32111 to 0.39283, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/ResNet18/005.h5
# 350/350 [==============================] - 600s 2s/step - loss: 2.0825 - accuracy: 0.4436 - top5_acc: 0.7589 - macro_f1score: 0.1939 - val_loss: 2.4009 - val_accuracy: 0.3928 - val_top5_acc: 0.7081 - val_macro_f1score: 0.1949
# Learning rate:  0.001
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 6/70
# 350/350 [==============================] - ETA: 0s - loss: 1.8760 - accuracy: 0.4844 - top5_acc: 0.7995 - macro_f1score: 0.2402
# Epoch 00006: val_loss improved from 2.40087 to 2.31636, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/ResNet18/006.h5
#
# Epoch 00006: val_accuracy improved from 0.39283 to 0.40004, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/ResNet18/006.h5
# 350/350 [==============================] - 600s 2s/step - loss: 1.8760 - accuracy: 0.4844 - top5_acc: 0.7995 - macro_f1score: 0.2402 - val_loss: 2.3164 - val_accuracy: 0.4000 - val_top5_acc: 0.7111 - val_macro_f1score: 0.1939
# Learning rate:  0.001
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 7/70
# 350/350 [==============================] - ETA: 0s - loss: 1.7001 - accuracy: 0.5291 - top5_acc: 0.8275 - macro_f1score: 0.2760
# Epoch 00007: val_loss did not improve from 2.31636
#
# Epoch 00007: val_accuracy improved from 0.40004 to 0.40144, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/ResNet18/007.h5
# 350/350 [==============================] - 589s 2s/step - loss: 1.7001 - accuracy: 0.5291 - top5_acc: 0.8275 - macro_f1score: 0.2760 - val_loss: 2.4238 - val_accuracy: 0.4014 - val_top5_acc: 0.7141 - val_macro_f1score: 0.2177
# Learning rate:  0.001
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 8/70
# 350/350 [==============================] - ETA: 0s - loss: 1.5534 - accuracy: 0.5668 - top5_acc: 0.8528 - macro_f1score: 0.3106
# Epoch 00008: val_loss improved from 2.31636 to 2.03623, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/ResNet18/008.h5
#
# Epoch 00008: val_accuracy improved from 0.40144 to 0.46134, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/ResNet18/008.h5
# 350/350 [==============================] - 592s 2s/step - loss: 1.5534 - accuracy: 0.5668 - top5_acc: 0.8528 - macro_f1score: 0.3106 - val_loss: 2.0362 - val_accuracy: 0.4613 - val_top5_acc: 0.7887 - val_macro_f1score: 0.2627
# Learning rate:  0.001
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 9/70
# 350/350 [==============================] - ETA: 0s - loss: 1.4258 - accuracy: 0.5962 - top5_acc: 0.8742 - macro_f1score: 0.3405
# Epoch 00009: val_loss did not improve from 2.03623
#
# Epoch 00009: val_accuracy did not improve from 0.46134
# 350/350 [==============================] - 595s 2s/step - loss: 1.4258 - accuracy: 0.5962 - top5_acc: 0.8742 - macro_f1score: 0.3405 - val_loss: 2.1169 - val_accuracy: 0.4487 - val_top5_acc: 0.7636 - val_macro_f1score: 0.2500
# Learning rate:  0.001
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 10/70
# 350/350 [==============================] - ETA: 0s - loss: 1.3227 - accuracy: 0.6202 - top5_acc: 0.8897 - macro_f1score: 0.3651
# Epoch 00010: val_loss improved from 2.03623 to 1.82785, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/ResNet18/010.h5
#
# Epoch 00010: val_accuracy improved from 0.46134 to 0.51462, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/ResNet18/010.h5
# 350/350 [==============================] - 594s 2s/step - loss: 1.3227 - accuracy: 0.6202 - top5_acc: 0.8897 - macro_f1score: 0.3651 - val_loss: 1.8278 - val_accuracy: 0.5146 - val_top5_acc: 0.8107 - val_macro_f1score: 0.2879
# Learning rate:  0.001
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 11/70
# 350/350 [==============================] - ETA: 0s - loss: 1.2242 - accuracy: 0.6475 - top5_acc: 0.9026 - macro_f1score: 0.3917
# Epoch 00011: val_loss improved from 1.82785 to 1.72654, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/ResNet18/011.h5
#
# Epoch 00011: val_accuracy improved from 0.51462 to 0.54026, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/ResNet18/011.h5
# 350/350 [==============================] - 591s 2s/step - loss: 1.2242 - accuracy: 0.6475 - top5_acc: 0.9026 - macro_f1score: 0.3917 - val_loss: 1.7265 - val_accuracy: 0.5403 - val_top5_acc: 0.8273 - val_macro_f1score: 0.3310
# Learning rate:  0.001
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 12/70
# 350/350 [==============================] - ETA: 0s - loss: 1.1442 - accuracy: 0.6707 - top5_acc: 0.9138 - macro_f1score: 0.4115
# Epoch 00012: val_loss improved from 1.72654 to 1.59618, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/ResNet18/012.h5
#
# Epoch 00012: val_accuracy improved from 0.54026 to 0.56430, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/ResNet18/012.h5
# 350/350 [==============================] - 589s 2s/step - loss: 1.1442 - accuracy: 0.6707 - top5_acc: 0.9138 - macro_f1score: 0.4115 - val_loss: 1.5962 - val_accuracy: 0.5643 - val_top5_acc: 0.8498 - val_macro_f1score: 0.3425
# Learning rate:  0.001
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 13/70
# 350/350 [==============================] - ETA: 0s - loss: 1.0534 - accuracy: 0.6930 - top5_acc: 0.9272 - macro_f1score: 0.4316
# Epoch 00013: val_loss did not improve from 1.59618
#
# Epoch 00013: val_accuracy did not improve from 0.56430
# 350/350 [==============================] - 590s 2s/step - loss: 1.0534 - accuracy: 0.6930 - top5_acc: 0.9272 - macro_f1score: 0.4316 - val_loss: 1.6104 - val_accuracy: 0.5599 - val_top5_acc: 0.8564 - val_macro_f1score: 0.3387
# Learning rate:  0.001
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 14/70
# 350/350 [==============================] - ETA: 0s - loss: 0.9867 - accuracy: 0.7083 - top5_acc: 0.9338 - macro_f1score: 0.4513
# Epoch 00014: val_loss did not improve from 1.59618
#
# Epoch 00014: val_accuracy did not improve from 0.56430
# 350/350 [==============================] - 588s 2s/step - loss: 0.9867 - accuracy: 0.7083 - top5_acc: 0.9338 - macro_f1score: 0.4513 - val_loss: 1.8072 - val_accuracy: 0.5407 - val_top5_acc: 0.8169 - val_macro_f1score: 0.3337
# Learning rate:  0.001
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 15/70
# 350/350 [==============================] - ETA: 0s - loss: 0.9191 - accuracy: 0.7254 - top5_acc: 0.9421 - macro_f1score: 0.4673
# Epoch 00015: val_loss did not improve from 1.59618
#
# Epoch 00015: val_accuracy did not improve from 0.56430
# 350/350 [==============================] - 586s 2s/step - loss: 0.9191 - accuracy: 0.7254 - top5_acc: 0.9421 - macro_f1score: 0.4673 - val_loss: 1.8615 - val_accuracy: 0.5284 - val_top5_acc: 0.8213 - val_macro_f1score: 0.3255
# Learning rate:  0.001
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 16/70
# 350/350 [==============================] - ETA: 0s - loss: 0.8535 - accuracy: 0.7431 - top5_acc: 0.9506 - macro_f1score: 0.4831
# Epoch 00016: val_loss did not improve from 1.59618
#
# Epoch 00016: val_accuracy did not improve from 0.56430
# 350/350 [==============================] - 591s 2s/step - loss: 0.8535 - accuracy: 0.7431 - top5_acc: 0.9506 - macro_f1score: 0.4831 - val_loss: 1.7464 - val_accuracy: 0.5489 - val_top5_acc: 0.8287 - val_macro_f1score: 0.3461
# Learning rate:  0.001
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 17/70
# 350/350 [==============================] - ETA: 0s - loss: 0.8065 - accuracy: 0.7572 - top5_acc: 0.9559 - macro_f1score: 0.4956
# Epoch 00017: val_loss did not improve from 1.59618
#
# Epoch 00017: val_accuracy improved from 0.56430 to 0.58193, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/ResNet18/017.h5
# 350/350 [==============================] - 595s 2s/step - loss: 0.8065 - accuracy: 0.7572 - top5_acc: 0.9559 - macro_f1score: 0.4956 - val_loss: 1.6302 - val_accuracy: 0.5819 - val_top5_acc: 0.8534 - val_macro_f1score: 0.3715
# Learning rate:  0.001
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 18/70
# 350/350 [==============================] - ETA: 0s - loss: 0.7434 - accuracy: 0.7735 - top5_acc: 0.9626 - macro_f1score: 0.5107
# Epoch 00018: val_loss did not improve from 1.59618
#
# Epoch 00018: val_accuracy did not improve from 0.58193
# 350/350 [==============================] - 595s 2s/step - loss: 0.7434 - accuracy: 0.7735 - top5_acc: 0.9626 - macro_f1score: 0.5107 - val_loss: 1.7137 - val_accuracy: 0.5683 - val_top5_acc: 0.8456 - val_macro_f1score: 0.3581
# Learning rate:  0.001
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 19/70
# 350/350 [==============================] - ETA: 0s - loss: 0.6892 - accuracy: 0.7875 - top5_acc: 0.9659 - macro_f1score: 0.5267
# Epoch 00019: val_loss improved from 1.59618 to 1.52117, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/ResNet18/019.h5
#
# Epoch 00019: val_accuracy improved from 0.58193 to 0.61318, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/ResNet18/019.h5
# 350/350 [==============================] - 590s 2s/step - loss: 0.6892 - accuracy: 0.7875 - top5_acc: 0.9659 - macro_f1score: 0.5267 - val_loss: 1.5212 - val_accuracy: 0.6132 - val_top5_acc: 0.8708 - val_macro_f1score: 0.4014
# Learning rate:  0.001
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 20/70
# 350/350 [==============================] - ETA: 0s - loss: 0.6442 - accuracy: 0.7984 - top5_acc: 0.9721 - macro_f1score: 0.5386
# Epoch 00020: val_loss did not improve from 1.52117
#
# Epoch 00020: val_accuracy did not improve from 0.61318
# 350/350 [==============================] - 589s 2s/step - loss: 0.6442 - accuracy: 0.7984 - top5_acc: 0.9721 - macro_f1score: 0.5386 - val_loss: 1.5278 - val_accuracy: 0.6124 - val_top5_acc: 0.8642 - val_macro_f1score: 0.3968
# Learning rate:  0.001
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 21/70
# 350/350 [==============================] - ETA: 0s - loss: 0.5999 - accuracy: 0.8161 - top5_acc: 0.9754 - macro_f1score: 0.5532
# Epoch 00021: val_loss improved from 1.52117 to 1.45860, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/ResNet18/021.h5
#
# Epoch 00021: val_accuracy improved from 0.61318 to 0.62981, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/ResNet18/021.h5
# 350/350 [==============================] - 591s 2s/step - loss: 0.5999 - accuracy: 0.8161 - top5_acc: 0.9754 - macro_f1score: 0.5532 - val_loss: 1.4586 - val_accuracy: 0.6298 - val_top5_acc: 0.8774 - val_macro_f1score: 0.4135
# Learning rate:  0.001
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 22/70
# 350/350 [==============================] - ETA: 0s - loss: 0.5600 - accuracy: 0.8267 - top5_acc: 0.9778 - macro_f1score: 0.5645
# Epoch 00022: val_loss did not improve from 1.45860
#
# Epoch 00022: val_accuracy did not improve from 0.62981
# 350/350 [==============================] - 591s 2s/step - loss: 0.5600 - accuracy: 0.8267 - top5_acc: 0.9778 - macro_f1score: 0.5645 - val_loss: 1.7205 - val_accuracy: 0.5942 - val_top5_acc: 0.8558 - val_macro_f1score: 0.3838
# Learning rate:  0.001
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 23/70
# 350/350 [==============================] - ETA: 0s - loss: 0.5232 - accuracy: 0.8378 - top5_acc: 0.9819 - macro_f1score: 0.5720
# Epoch 00023: val_loss did not improve from 1.45860
#
# Epoch 00023: val_accuracy did not improve from 0.62981
# 350/350 [==============================] - 585s 2s/step - loss: 0.5232 - accuracy: 0.8378 - top5_acc: 0.9819 - macro_f1score: 0.5720 - val_loss: 1.5674 - val_accuracy: 0.6056 - val_top5_acc: 0.8682 - val_macro_f1score: 0.3918
# Learning rate:  0.001
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 24/70
# 350/350 [==============================] - ETA: 0s - loss: 0.4992 - accuracy: 0.8430 - top5_acc: 0.9832 - macro_f1score: 0.5815
# Epoch 00024: val_loss did not improve from 1.45860
#
# Epoch 00024: val_accuracy did not improve from 0.62981
# 350/350 [==============================] - 584s 2s/step - loss: 0.4992 - accuracy: 0.8430 - top5_acc: 0.9832 - macro_f1score: 0.5815 - val_loss: 1.6092 - val_accuracy: 0.6150 - val_top5_acc: 0.8696 - val_macro_f1score: 0.4006
# Learning rate:  0.001
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 25/70
# 350/350 [==============================] - ETA: 0s - loss: 0.4631 - accuracy: 0.8540 - top5_acc: 0.9858 - macro_f1score: 0.5904
# Epoch 00025: val_loss did not improve from 1.45860
#
# Epoch 00025: val_accuracy did not improve from 0.62981
# 350/350 [==============================] - 584s 2s/step - loss: 0.4631 - accuracy: 0.8540 - top5_acc: 0.9858 - macro_f1score: 0.5904 - val_loss: 1.7413 - val_accuracy: 0.5996 - val_top5_acc: 0.8520 - val_macro_f1score: 0.3916
# Learning rate:  0.001
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 26/70
# 350/350 [==============================] - ETA: 0s - loss: 0.4464 - accuracy: 0.8600 - top5_acc: 0.9870 - macro_f1score: 0.5958
# Epoch 00026: val_loss did not improve from 1.45860
#
# Epoch 00026: val_accuracy did not improve from 0.62981
# 350/350 [==============================] - 586s 2s/step - loss: 0.4464 - accuracy: 0.8600 - top5_acc: 0.9870 - macro_f1score: 0.5958 - val_loss: 1.5415 - val_accuracy: 0.6274 - val_top5_acc: 0.8808 - val_macro_f1score: 0.4273
# Learning rate:  0.001
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 27/70
# 350/350 [==============================] - ETA: 0s - loss: 0.4150 - accuracy: 0.8679 - top5_acc: 0.9894 - macro_f1score: 0.6055
# Epoch 00027: val_loss did not improve from 1.45860
#
# Epoch 00027: val_accuracy did not improve from 0.62981
# 350/350 [==============================] - 584s 2s/step - loss: 0.4150 - accuracy: 0.8679 - top5_acc: 0.9894 - macro_f1score: 0.6055 - val_loss: 1.6780 - val_accuracy: 0.6024 - val_top5_acc: 0.8660 - val_macro_f1score: 0.4071
# Learning rate:  0.001
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 28/70
# 350/350 [==============================] - ETA: 0s - loss: 0.3909 - accuracy: 0.8766 - top5_acc: 0.9912 - macro_f1score: 0.6117
# Epoch 00028: val_loss did not improve from 1.45860
#
# Epoch 00028: val_accuracy did not improve from 0.62981
# 350/350 [==============================] - 591s 2s/step - loss: 0.3909 - accuracy: 0.8766 - top5_acc: 0.9912 - macro_f1score: 0.6117 - val_loss: 1.5823 - val_accuracy: 0.6252 - val_top5_acc: 0.8734 - val_macro_f1score: 0.4120
# Learning rate:  0.001
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 29/70
# 350/350 [==============================] - ETA: 0s - loss: 0.3706 - accuracy: 0.8838 - top5_acc: 0.9917 - macro_f1score: 0.6183
# Epoch 00029: val_loss did not improve from 1.45860
#
# Epoch 00029: val_accuracy did not improve from 0.62981
# 350/350 [==============================] - 617s 2s/step - loss: 0.3706 - accuracy: 0.8838 - top5_acc: 0.9917 - macro_f1score: 0.6183 - val_loss: 1.6930 - val_accuracy: 0.6028 - val_top5_acc: 0.8628 - val_macro_f1score: 0.4063
# Learning rate:  0.001
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 30/70
# 350/350 [==============================] - ETA: 0s - loss: 0.3568 - accuracy: 0.8882 - top5_acc: 0.9921 - macro_f1score: 0.6254
# Epoch 00030: val_loss did not improve from 1.45860
#
# Epoch 00030: val_accuracy did not improve from 0.62981
# 350/350 [==============================] - 628s 2s/step - loss: 0.3568 - accuracy: 0.8882 - top5_acc: 0.9921 - macro_f1score: 0.6254 - val_loss: 1.7007 - val_accuracy: 0.6112 - val_top5_acc: 0.8642 - val_macro_f1score: 0.4122
# Learning rate:  0.0001
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 31/70
# 350/350 [==============================] - ETA: 0s - loss: 0.1779 - accuracy: 0.9505 - top5_acc: 0.9980 - macro_f1score: 0.6759
# Epoch 00031: val_loss improved from 1.45860 to 1.10701, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/ResNet18/031.h5
#
# Epoch 00031: val_accuracy improved from 0.62981 to 0.70633, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/ResNet18/031.h5
# 350/350 [==============================] - 626s 2s/step - loss: 0.1779 - accuracy: 0.9505 - top5_acc: 0.9980 - macro_f1score: 0.6759 - val_loss: 1.1070 - val_accuracy: 0.7063 - val_top5_acc: 0.9205 - val_macro_f1score: 0.4899
# Learning rate:  0.0001
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 32/70
# 350/350 [==============================] - ETA: 0s - loss: 0.1220 - accuracy: 0.9716 - top5_acc: 0.9992 - macro_f1score: 0.6985
# Epoch 00032: val_loss improved from 1.10701 to 1.07230, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/ResNet18/032.h5
#
# Epoch 00032: val_accuracy improved from 0.70633 to 0.71414, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/ResNet18/032.h5
# 350/350 [==============================] - 603s 2s/step - loss: 0.1220 - accuracy: 0.9716 - top5_acc: 0.9992 - macro_f1score: 0.6985 - val_loss: 1.0723 - val_accuracy: 0.7141 - val_top5_acc: 0.9235 - val_macro_f1score: 0.4895
# Learning rate:  0.0001
#
# Epoch 00033: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 33/70
# 350/350 [==============================] - ETA: 0s - loss: 0.1049 - accuracy: 0.9782 - top5_acc: 0.9997 - macro_f1score: 0.7008
# Epoch 00033: val_loss improved from 1.07230 to 1.05227, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/ResNet18/033.h5
#
# Epoch 00033: val_accuracy improved from 0.71414 to 0.71915, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/ResNet18/033.h5
# 350/350 [==============================] - 602s 2s/step - loss: 0.1049 - accuracy: 0.9782 - top5_acc: 0.9997 - macro_f1score: 0.7008 - val_loss: 1.0523 - val_accuracy: 0.7192 - val_top5_acc: 0.9253 - val_macro_f1score: 0.4970
# Learning rate:  0.0001
#
# Epoch 00034: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 34/70
# 350/350 [==============================] - ETA: 0s - loss: 0.0956 - accuracy: 0.9830 - top5_acc: 0.9996 - macro_f1score: 0.7031
# Epoch 00034: val_loss did not improve from 1.05227
#
# Epoch 00034: val_accuracy did not improve from 0.71915
# 350/350 [==============================] - 597s 2s/step - loss: 0.0956 - accuracy: 0.9830 - top5_acc: 0.9996 - macro_f1score: 0.7031 - val_loss: 1.0544 - val_accuracy: 0.7190 - val_top5_acc: 0.9233 - val_macro_f1score: 0.4868
# Learning rate:  0.0001
#
# Epoch 00035: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 35/70
# 350/350 [==============================] - ETA: 0s - loss: 0.0911 - accuracy: 0.9842 - top5_acc: 0.9999 - macro_f1score: 0.7058
# Epoch 00035: val_loss improved from 1.05227 to 1.02949, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/ResNet18/035.h5
#
# Epoch 00035: val_accuracy improved from 0.71915 to 0.72376, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/ResNet18/035.h5
# 350/350 [==============================] - 594s 2s/step - loss: 0.0911 - accuracy: 0.9842 - top5_acc: 0.9999 - macro_f1score: 0.7058 - val_loss: 1.0295 - val_accuracy: 0.7238 - val_top5_acc: 0.9255 - val_macro_f1score: 0.4974
# Learning rate:  0.0001
#
# Epoch 00036: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 36/70
# 350/350 [==============================] - ETA: 0s - loss: 0.0844 - accuracy: 0.9871 - top5_acc: 0.9999 - macro_f1score: 0.7074
# Epoch 00036: val_loss did not improve from 1.02949
#
# Epoch 00036: val_accuracy did not improve from 0.72376
# 350/350 [==============================] - 592s 2s/step - loss: 0.0844 - accuracy: 0.9871 - top5_acc: 0.9999 - macro_f1score: 0.7074 - val_loss: 1.0458 - val_accuracy: 0.7214 - val_top5_acc: 0.9239 - val_macro_f1score: 0.4890
# Learning rate:  0.0001
#
# Epoch 00037: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 37/70
# 350/350 [==============================] - ETA: 0s - loss: 0.0803 - accuracy: 0.9882 - top5_acc: 0.9998 - macro_f1score: 0.7090
# Epoch 00037: val_loss did not improve from 1.02949
#
# Epoch 00037: val_accuracy improved from 0.72376 to 0.72496, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/ResNet18/037.h5
# 350/350 [==============================] - 588s 2s/step - loss: 0.0803 - accuracy: 0.9882 - top5_acc: 0.9998 - macro_f1score: 0.7090 - val_loss: 1.0327 - val_accuracy: 0.7250 - val_top5_acc: 0.9257 - val_macro_f1score: 0.4945
# Learning rate:  0.0001
#
# Epoch 00038: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 38/70
# 350/350 [==============================] - ETA: 0s - loss: 0.0781 - accuracy: 0.9886 - top5_acc: 0.9999 - macro_f1score: 0.7114
# Epoch 00038: val_loss did not improve from 1.02949
#
# Epoch 00038: val_accuracy did not improve from 0.72496
# 350/350 [==============================] - 604s 2s/step - loss: 0.0781 - accuracy: 0.9886 - top5_acc: 0.9999 - macro_f1score: 0.7114 - val_loss: 1.0455 - val_accuracy: 0.7210 - val_top5_acc: 0.9247 - val_macro_f1score: 0.4997
# Learning rate:  0.0001
#
# Epoch 00039: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 39/70
# 350/350 [==============================] - ETA: 0s - loss: 0.0757 - accuracy: 0.9892 - top5_acc: 0.9999 - macro_f1score: 0.7131
# Epoch 00039: val_loss did not improve from 1.02949
#
# Epoch 00039: val_accuracy did not improve from 0.72496
# 350/350 [==============================] - 599s 2s/step - loss: 0.0757 - accuracy: 0.9892 - top5_acc: 0.9999 - macro_f1score: 0.7131 - val_loss: 1.0432 - val_accuracy: 0.7212 - val_top5_acc: 0.9267 - val_macro_f1score: 0.4935
# Learning rate:  0.0001
#
# Epoch 00040: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 40/70
# 350/350 [==============================] - ETA: 0s - loss: 0.0703 - accuracy: 0.9911 - top5_acc: 1.0000 - macro_f1score: 0.7124
# Epoch 00040: val_loss did not improve from 1.02949
#
# Epoch 00040: val_accuracy did not improve from 0.72496
# 350/350 [==============================] - 587s 2s/step - loss: 0.0703 - accuracy: 0.9911 - top5_acc: 1.0000 - macro_f1score: 0.7124 - val_loss: 1.0578 - val_accuracy: 0.7173 - val_top5_acc: 0.9221 - val_macro_f1score: 0.4837
# Learning rate:  0.0001
#
# Epoch 00041: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 41/70
# 350/350 [==============================] - ETA: 0s - loss: 0.0681 - accuracy: 0.9916 - top5_acc: 0.9999 - macro_f1score: 0.7140
# Epoch 00041: val_loss did not improve from 1.02949
#
# Epoch 00041: val_accuracy did not improve from 0.72496
# 350/350 [==============================] - 586s 2s/step - loss: 0.0681 - accuracy: 0.9916 - top5_acc: 0.9999 - macro_f1score: 0.7140 - val_loss: 1.0385 - val_accuracy: 0.7234 - val_top5_acc: 0.9269 - val_macro_f1score: 0.4887
# Learning rate:  0.0001
#
# Epoch 00042: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 42/70
# 350/350 [==============================] - ETA: 0s - loss: 0.0672 - accuracy: 0.9912 - top5_acc: 0.9999 - macro_f1score: 0.7150
# Epoch 00042: val_loss did not improve from 1.02949
#
# Epoch 00042: val_accuracy improved from 0.72496 to 0.72556, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/ResNet18/042.h5
# 350/350 [==============================] - 587s 2s/step - loss: 0.0672 - accuracy: 0.9912 - top5_acc: 0.9999 - macro_f1score: 0.7150 - val_loss: 1.0406 - val_accuracy: 0.7256 - val_top5_acc: 0.9237 - val_macro_f1score: 0.4896
# Learning rate:  0.0001
#
# Epoch 00043: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 43/70
# 350/350 [==============================] - ETA: 0s - loss: 0.0609 - accuracy: 0.9933 - top5_acc: 1.0000 - macro_f1score: 0.7199
# Epoch 00043: val_loss did not improve from 1.02949
#
# Epoch 00043: val_accuracy did not improve from 0.72556
# 350/350 [==============================] - 585s 2s/step - loss: 0.0609 - accuracy: 0.9933 - top5_acc: 1.0000 - macro_f1score: 0.7199 - val_loss: 1.0508 - val_accuracy: 0.7173 - val_top5_acc: 0.9209 - val_macro_f1score: 0.4868
# Learning rate:  0.0001
#
# Epoch 00044: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 44/70
# 350/350 [==============================] - ETA: 0s - loss: 0.0610 - accuracy: 0.9927 - top5_acc: 1.0000 - macro_f1score: 0.7133
# Epoch 00044: val_loss did not improve from 1.02949
#
# Epoch 00044: val_accuracy did not improve from 0.72556
# 350/350 [==============================] - 596s 2s/step - loss: 0.0610 - accuracy: 0.9927 - top5_acc: 1.0000 - macro_f1score: 0.7133 - val_loss: 1.0456 - val_accuracy: 0.7256 - val_top5_acc: 0.9275 - val_macro_f1score: 0.4929
# Learning rate:  0.0001
#
# Epoch 00045: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 45/70
# 350/350 [==============================] - ETA: 0s - loss: 0.0584 - accuracy: 0.9933 - top5_acc: 1.0000 - macro_f1score: 0.7162
# Epoch 00045: val_loss did not improve from 1.02949
#
# Epoch 00045: val_accuracy did not improve from 0.72556
# 350/350 [==============================] - 597s 2s/step - loss: 0.0584 - accuracy: 0.9933 - top5_acc: 1.0000 - macro_f1score: 0.7162 - val_loss: 1.0575 - val_accuracy: 0.7212 - val_top5_acc: 0.9259 - val_macro_f1score: 0.4914
# Learning rate:  0.0001
#
# Epoch 00046: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 46/70
# 350/350 [==============================] - ETA: 0s - loss: 0.0563 - accuracy: 0.9938 - top5_acc: 1.0000 - macro_f1score: 0.7186
# Epoch 00046: val_loss did not improve from 1.02949
#
# Epoch 00046: val_accuracy did not improve from 0.72556
# 350/350 [==============================] - 596s 2s/step - loss: 0.0563 - accuracy: 0.9938 - top5_acc: 1.0000 - macro_f1score: 0.7186 - val_loss: 1.0933 - val_accuracy: 0.7127 - val_top5_acc: 0.9191 - val_macro_f1score: 0.4938
# Learning rate:  0.0001
#
# Epoch 00047: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 47/70
# 350/350 [==============================] - ETA: 0s - loss: 0.0542 - accuracy: 0.9943 - top5_acc: 1.0000 - macro_f1score: 0.7203
# Epoch 00047: val_loss did not improve from 1.02949
#
# Epoch 00047: val_accuracy did not improve from 0.72556
# 350/350 [==============================] - 590s 2s/step - loss: 0.0542 - accuracy: 0.9943 - top5_acc: 1.0000 - macro_f1score: 0.7203 - val_loss: 1.0865 - val_accuracy: 0.7127 - val_top5_acc: 0.9189 - val_macro_f1score: 0.4794
# Learning rate:  0.0001
#
# Epoch 00048: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 48/70
# 350/350 [==============================] - ETA: 0s - loss: 0.0525 - accuracy: 0.9939 - top5_acc: 1.0000 - macro_f1score: 0.7167
# Epoch 00048: val_loss did not improve from 1.02949
#
# Epoch 00048: val_accuracy did not improve from 0.72556
# 350/350 [==============================] - 585s 2s/step - loss: 0.0525 - accuracy: 0.9939 - top5_acc: 1.0000 - macro_f1score: 0.7167 - val_loss: 1.0840 - val_accuracy: 0.7192 - val_top5_acc: 0.9213 - val_macro_f1score: 0.4868
# Learning rate:  0.0001
#
# Epoch 00049: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 49/70
# 350/350 [==============================] - ETA: 0s - loss: 0.0512 - accuracy: 0.9944 - top5_acc: 1.0000 - macro_f1score: 0.7181
# Epoch 00049: val_loss did not improve from 1.02949
#
# Epoch 00049: val_accuracy did not improve from 0.72556
# 350/350 [==============================] - 586s 2s/step - loss: 0.0512 - accuracy: 0.9944 - top5_acc: 1.0000 - macro_f1score: 0.7181 - val_loss: 1.0828 - val_accuracy: 0.7232 - val_top5_acc: 0.9203 - val_macro_f1score: 0.4933
# Learning rate:  0.0001
#
# Epoch 00050: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 50/70
# 350/350 [==============================] - ETA: 0s - loss: 0.0521 - accuracy: 0.9940 - top5_acc: 1.0000 - macro_f1score: 0.7193
# Epoch 00050: val_loss did not improve from 1.02949
#
# Epoch 00050: val_accuracy did not improve from 0.72556
# 350/350 [==============================] - 588s 2s/step - loss: 0.0521 - accuracy: 0.9940 - top5_acc: 1.0000 - macro_f1score: 0.7193 - val_loss: 1.1058 - val_accuracy: 0.7093 - val_top5_acc: 0.9187 - val_macro_f1score: 0.4794
# Learning rate:  0.0001
#
# Epoch 00051: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 51/70
# 350/350 [==============================] - ETA: 0s - loss: 0.0487 - accuracy: 0.9948 - top5_acc: 1.0000 - macro_f1score: 0.7204
# Epoch 00051: val_loss did not improve from 1.02949
#
# Epoch 00051: val_accuracy did not improve from 0.72556
# 350/350 [==============================] - 586s 2s/step - loss: 0.0487 - accuracy: 0.9948 - top5_acc: 1.0000 - macro_f1score: 0.7204 - val_loss: 1.0812 - val_accuracy: 0.7220 - val_top5_acc: 0.9173 - val_macro_f1score: 0.4861
# Learning rate:  0.0001
#
# Epoch 00052: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 52/70
# 350/350 [==============================] - ETA: 0s - loss: 0.0470 - accuracy: 0.9946 - top5_acc: 1.0000 - macro_f1score: 0.7188
# Epoch 00052: val_loss did not improve from 1.02949
#
# Epoch 00052: val_accuracy did not improve from 0.72556
# 350/350 [==============================] - 598s 2s/step - loss: 0.0470 - accuracy: 0.9946 - top5_acc: 1.0000 - macro_f1score: 0.7188 - val_loss: 1.0871 - val_accuracy: 0.7173 - val_top5_acc: 0.9181 - val_macro_f1score: 0.4849
# Learning rate:  0.0001
#
# Epoch 00053: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 53/70
# 350/350 [==============================] - ETA: 0s - loss: 0.0498 - accuracy: 0.9937 - top5_acc: 1.0000 - macro_f1score: 0.7176
# Epoch 00053: val_loss did not improve from 1.02949
#
# Epoch 00053: val_accuracy did not improve from 0.72556
# 350/350 [==============================] - 594s 2s/step - loss: 0.0498 - accuracy: 0.9937 - top5_acc: 1.0000 - macro_f1score: 0.7176 - val_loss: 1.1096 - val_accuracy: 0.7141 - val_top5_acc: 0.9191 - val_macro_f1score: 0.4839
# Learning rate:  0.0001
#
# Epoch 00054: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 54/70
# 350/350 [==============================] - ETA: 0s - loss: 0.0472 - accuracy: 0.9944 - top5_acc: 1.0000 - macro_f1score: 0.7214
# Epoch 00054: val_loss did not improve from 1.02949
#
# Epoch 00054: val_accuracy did not improve from 0.72556
# 350/350 [==============================] - 594s 2s/step - loss: 0.0472 - accuracy: 0.9944 - top5_acc: 1.0000 - macro_f1score: 0.7214 - val_loss: 1.1339 - val_accuracy: 0.7145 - val_top5_acc: 0.9189 - val_macro_f1score: 0.4814
# Learning rate:  0.0001
#
# Epoch 00055: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 55/70
# 350/350 [==============================] - ETA: 0s - loss: 0.0471 - accuracy: 0.9946 - top5_acc: 0.9999 - macro_f1score: 0.7190
# Epoch 00055: val_loss did not improve from 1.02949
#
# Epoch 00055: val_accuracy did not improve from 0.72556
# 350/350 [==============================] - 588s 2s/step - loss: 0.0471 - accuracy: 0.9946 - top5_acc: 0.9999 - macro_f1score: 0.7190 - val_loss: 1.1224 - val_accuracy: 0.7147 - val_top5_acc: 0.9159 - val_macro_f1score: 0.4882
# Learning rate:  0.0001
#
# Epoch 00056: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 56/70
# 350/350 [==============================] - ETA: 0s - loss: 0.0490 - accuracy: 0.9937 - top5_acc: 1.0000 - macro_f1score: 0.7176
# Epoch 00056: val_loss did not improve from 1.02949
#
# Epoch 00056: val_accuracy did not improve from 0.72556
# 350/350 [==============================] - 587s 2s/step - loss: 0.0490 - accuracy: 0.9937 - top5_acc: 1.0000 - macro_f1score: 0.7176 - val_loss: 1.1341 - val_accuracy: 0.7075 - val_top5_acc: 0.9167 - val_macro_f1score: 0.4935
# Learning rate:  0.0001
#
# Epoch 00057: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 57/70
# 350/350 [==============================] - ETA: 0s - loss: 0.0455 - accuracy: 0.9948 - top5_acc: 0.9999 - macro_f1score: 0.7202
# Epoch 00057: val_loss did not improve from 1.02949
#
# Epoch 00057: val_accuracy did not improve from 0.72556
# 350/350 [==============================] - 585s 2s/step - loss: 0.0455 - accuracy: 0.9948 - top5_acc: 0.9999 - macro_f1score: 0.7202 - val_loss: 1.1484 - val_accuracy: 0.7045 - val_top5_acc: 0.9123 - val_macro_f1score: 0.4793
# Learning rate:  0.0001
#
# Epoch 00058: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 58/70
# 350/350 [==============================] - ETA: 0s - loss: 0.0441 - accuracy: 0.9953 - top5_acc: 1.0000 - macro_f1score: 0.7182
# Epoch 00058: val_loss did not improve from 1.02949
#
# Epoch 00058: val_accuracy did not improve from 0.72556
# 350/350 [==============================] - 583s 2s/step - loss: 0.0441 - accuracy: 0.9953 - top5_acc: 1.0000 - macro_f1score: 0.7182 - val_loss: 1.1081 - val_accuracy: 0.7137 - val_top5_acc: 0.9169 - val_macro_f1score: 0.4918
# Learning rate:  0.0001
#
# Epoch 00059: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 59/70
# 350/350 [==============================] - ETA: 0s - loss: 0.0497 - accuracy: 0.9936 - top5_acc: 1.0000 - macro_f1score: 0.7173
# Epoch 00059: val_loss did not improve from 1.02949
#
# Epoch 00059: val_accuracy did not improve from 0.72556
# 350/350 [==============================] - 607s 2s/step - loss: 0.0497 - accuracy: 0.9936 - top5_acc: 1.0000 - macro_f1score: 0.7173 - val_loss: 1.2134 - val_accuracy: 0.6975 - val_top5_acc: 0.9121 - val_macro_f1score: 0.4695
# Learning rate:  0.0001
#
# Epoch 00060: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 60/70
# 350/350 [==============================] - ETA: 0s - loss: 0.0477 - accuracy: 0.9942 - top5_acc: 1.0000 - macro_f1score: 0.7194
# Epoch 00060: val_loss did not improve from 1.02949
#
# Epoch 00060: val_accuracy did not improve from 0.72556
# 350/350 [==============================] - 585s 2s/step - loss: 0.0477 - accuracy: 0.9942 - top5_acc: 1.0000 - macro_f1score: 0.7194 - val_loss: 1.1973 - val_accuracy: 0.6959 - val_top5_acc: 0.9099 - val_macro_f1score: 0.4767
# Learning rate:  1e-05
#
# Epoch 00061: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 61/70
# 350/350 [==============================] - ETA: 0s - loss: 0.0343 - accuracy: 0.9972 - top5_acc: 1.0000 - macro_f1score: 0.7201
# Epoch 00061: val_loss did not improve from 1.02949
#
# Epoch 00061: val_accuracy improved from 0.72556 to 0.72736, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/ResNet18/061.h5
# 350/350 [==============================] - 604s 2s/step - loss: 0.0343 - accuracy: 0.9972 - top5_acc: 1.0000 - macro_f1score: 0.7201 - val_loss: 1.0327 - val_accuracy: 0.7274 - val_top5_acc: 0.9233 - val_macro_f1score: 0.4933
# Learning rate:  1e-05
#
# Epoch 00062: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 62/70
# 350/350 [==============================] - ETA: 0s - loss: 0.0292 - accuracy: 0.9983 - top5_acc: 1.0000 - macro_f1score: 0.7226
# Epoch 00062: val_loss improved from 1.02949 to 1.01142, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/ResNet18/062.h5
#
# Epoch 00062: val_accuracy improved from 0.72736 to 0.73317, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/ResNet18/062.h5
# 350/350 [==============================] - 592s 2s/step - loss: 0.0292 - accuracy: 0.9983 - top5_acc: 1.0000 - macro_f1score: 0.7226 - val_loss: 1.0114 - val_accuracy: 0.7332 - val_top5_acc: 0.9263 - val_macro_f1score: 0.5036
# Learning rate:  1e-05
#
# Epoch 00063: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 63/70
# 350/350 [==============================] - ETA: 0s - loss: 0.0306 - accuracy: 0.9983 - top5_acc: 1.0000 - macro_f1score: 0.7215
# Epoch 00063: val_loss improved from 1.01142 to 1.00176, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/ResNet18/063.h5
#
# Epoch 00063: val_accuracy did not improve from 0.73317
# 350/350 [==============================] - 598s 2s/step - loss: 0.0306 - accuracy: 0.9983 - top5_acc: 1.0000 - macro_f1score: 0.7215 - val_loss: 1.0018 - val_accuracy: 0.7318 - val_top5_acc: 0.9271 - val_macro_f1score: 0.5011
# Learning rate:  1e-05
#
# Epoch 00064: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 64/70
# 350/350 [==============================] - ETA: 0s - loss: 0.0322 - accuracy: 0.9987 - top5_acc: 1.0000 - macro_f1score: 0.7259
# Epoch 00064: val_loss improved from 1.00176 to 0.98785, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/ResNet18/064.h5
#
# Epoch 00064: val_accuracy improved from 0.73317 to 0.73357, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/ResNet18/064.h5
# 350/350 [==============================] - 598s 2s/step - loss: 0.0322 - accuracy: 0.9987 - top5_acc: 1.0000 - macro_f1score: 0.7259 - val_loss: 0.9879 - val_accuracy: 0.7336 - val_top5_acc: 0.9257 - val_macro_f1score: 0.4991
# Learning rate:  1e-05
#
# Epoch 00065: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 65/70
# 350/350 [==============================] - ETA: 0s - loss: 0.0335 - accuracy: 0.9987 - top5_acc: 1.0000 - macro_f1score: 0.7209
# Epoch 00065: val_loss did not improve from 0.98785
#
# Epoch 00065: val_accuracy did not improve from 0.73357
# 350/350 [==============================] - 590s 2s/step - loss: 0.0335 - accuracy: 0.9987 - top5_acc: 1.0000 - macro_f1score: 0.7209 - val_loss: 0.9894 - val_accuracy: 0.7318 - val_top5_acc: 0.9257 - val_macro_f1score: 0.4896
# Learning rate:  1e-05
#
# Epoch 00066: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 66/70
# 350/350 [==============================] - ETA: 0s - loss: 0.0363 - accuracy: 0.9987 - top5_acc: 1.0000 - macro_f1score: 0.7231
# Epoch 00066: val_loss improved from 0.98785 to 0.97690, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/ResNet18/066.h5
#
# Epoch 00066: val_accuracy improved from 0.73357 to 0.73738, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/ResNet18/066.h5
# 350/350 [==============================] - 588s 2s/step - loss: 0.0363 - accuracy: 0.9987 - top5_acc: 1.0000 - macro_f1score: 0.7231 - val_loss: 0.9769 - val_accuracy: 0.7374 - val_top5_acc: 0.9273 - val_macro_f1score: 0.4949
# Learning rate:  1e-05
#
# Epoch 00067: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 67/70
# 350/350 [==============================] - ETA: 0s - loss: 0.0390 - accuracy: 0.9990 - top5_acc: 1.0000 - macro_f1score: 0.7215
# Epoch 00067: val_loss did not improve from 0.97690
#
# Epoch 00067: val_accuracy did not improve from 0.73738
# 350/350 [==============================] - 599s 2s/step - loss: 0.0390 - accuracy: 0.9990 - top5_acc: 1.0000 - macro_f1score: 0.7215 - val_loss: 0.9784 - val_accuracy: 0.7346 - val_top5_acc: 0.9287 - val_macro_f1score: 0.4939
# Learning rate:  1e-05
#
# Epoch 00068: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 68/70
# 350/350 [==============================] - ETA: 0s - loss: 0.0415 - accuracy: 0.9987 - top5_acc: 1.0000 - macro_f1score: 0.7235
# Epoch 00068: val_loss improved from 0.97690 to 0.96908, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/ResNet18/068.h5
#
# Epoch 00068: val_accuracy improved from 0.73738 to 0.73798, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/ResNet18/068.h5
# 350/350 [==============================] - 591s 2s/step - loss: 0.0415 - accuracy: 0.9987 - top5_acc: 1.0000 - macro_f1score: 0.7235 - val_loss: 0.9691 - val_accuracy: 0.7380 - val_top5_acc: 0.9301 - val_macro_f1score: 0.4914
# Learning rate:  1e-05
#
# Epoch 00069: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 69/70
# 350/350 [==============================] - ETA: 0s - loss: 0.0452 - accuracy: 0.9988 - top5_acc: 1.0000 - macro_f1score: 0.7259
# Epoch 00069: val_loss did not improve from 0.96908
#
# Epoch 00069: val_accuracy did not improve from 0.73798
# 350/350 [==============================] - 586s 2s/step - loss: 0.0452 - accuracy: 0.9988 - top5_acc: 1.0000 - macro_f1score: 0.7259 - val_loss: 0.9707 - val_accuracy: 0.7370 - val_top5_acc: 0.9279 - val_macro_f1score: 0.4864
# Learning rate:  1e-05
#
# Epoch 00070: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 70/70
# 350/350 [==============================] - ETA: 0s - loss: 0.0471 - accuracy: 0.9989 - top5_acc: 1.0000 - macro_f1score: 0.7229
# Epoch 00070: val_loss did not improve from 0.96908
#
# Epoch 00070: val_accuracy improved from 0.73798 to 0.73818, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/ResNet18/070.h5
# 350/350 [==============================] - 582s 2s/step - loss: 0.0471 - accuracy: 0.9989 - top5_acc: 1.0000 - macro_f1score: 0.7229 - val_loss: 0.9697 - val_accuracy: 0.7382 - val_top5_acc: 0.9289 - val_macro_f1score: 0.4875

# %% [markdown]
# ### 2) ResNet18 Evaluate

# %%
# 1. epoch=maximum
loss , acc, top5_acc, mf1 = model.evaluate(test_generator,steps=int(len(x_test)/batch_sizes))
print('[Test Loss: %.4f /  Test Top-1 Accuracy: %.4f / Test Top-5 Accuracy: %.4f / Test Macro f1: %.4f]\n' % (loss,acc,top5_acc,mf1))
# Out:
# 78/78 [==============================] - 2912s 37s/step - loss: 0.9965 - accuracy: 0.7330 - top5_acc: 0.9212 - macro_f1score: 0.4867
# [Test Loss: 0.9965 /  Test Top-1 Accuracy: 0.7330 / Test Top-5 Accuracy: 0.9212 / Test Macro f1: 0.4867]

# %%
loss=history.history['loss']
val_loss=history.history['val_loss']
acc=history.history['accuracy']
val_acc=history.history['val_accuracy']
top5_acc=history.history['top5_acc']
val_top5_acc=history.history['val_top5_acc']
f1=history.history['macro_f1score']
val_f1=history.history['val_macro_f1score']
epochs=range(1,len(acc)+1)

data = np.array([epochs,loss,val_loss,acc,val_acc,top5_acc,val_top5_acc,f1,val_f1]).T

# %%
# data save
# epochs, loss, val_loss, acc, val_acc, top5_acc, val_top5_acc, f1, val_f1

np.savetxt(os.path.join(dir,'train_valid_output',number,model.name+'.txt'),data)

# %%
# data import
data = np.loadtxt(os.path.join(dir,'train_valid_output',number,'ResNet18.txt'))

# %%
epochs=data[:,0]
loss=data[:,1]
val_loss=data[:,2]
acc=data[:,3]
val_acc=data[:,4]
top5_acc=data[:,5]
val_top5_acc=data[:,6]

# %%
plt.plot(epochs[1:],acc[1:],'b',label='Training 1-Acc')
plt.plot(epochs[1:],val_acc[1:],'r',label='Validation 1-Acc')
plt.title('Training and Validation Top-1 Accuracy')
plt.legend()
plt.figure()

plt.plot(epochs[1:],top5_acc[1:],'b',label='Training 5-Acc')
plt.plot(epochs[1:],val_top5_acc[1:],'r',label='Validation 5-Acc')
plt.title('Training and Validation Top-5 Accuracy')
plt.legend()
plt.figure()

plt.plot(epochs[10:],loss[10:],'b',label='Training Loss')
plt.plot(epochs[10:],val_loss[10:],'r',label='Validation Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()

# %%
# 이 아래는 내가 인위적으로 살펴보고 싶은 epoch에 대해서 결과값 출력 / ResNet18

# %%
# 참고 : https://github.com/OverLordGoldDragon/keras-adamw

import sys
sys.path.append('/content/drive/My Drive/Colab Notebooks/Paper')
import utils
import optimizers_v2
from utils import get_weight_decays, fill_dict_in_order
from utils import reset_seeds, K_eval
from optimizers_v2 import AdamW, NadamW, SGDW

# %%
# top-5 accuracy 출력
import functools
top5_acc = functools.partial(ks.metrics.top_k_categorical_accuracy, k=5)
top5_acc.__name__ = 'top5_acc'

# %%
model=load_model(os.path.join(dir,'model_output',number,'ResNet18','070.h5'),custom_objects={"macro_f1score": macro_f1score,"top5_acc":top5_acc, "AdamW":AdamW})

# %%
# 2. epoch=?
loss , acc, top5_acc, mf1 = model.evaluate(test_generator,steps=int(len(x_test)/batch_sizes))
print('[Test Loss: %.4f /  Test Top-1 Accuracy: %.4f / Test Top-5 Accuracy: %.4f / Test Macro f1: %.4f]\n' % (loss,acc,top5_acc,mf1))
# Out:
# 78/78 [==============================] - 4921s 63s/step - loss: 0.9967 - accuracy: 0.7331 - top5_acc: 0.9210 - macro_f1score: 0.4906
# [Test Loss: 0.9967 /  Test Top-1 Accuracy: 0.7331 / Test Top-5 Accuracy: 0.9210 / Test Macro f1: 0.4906]
