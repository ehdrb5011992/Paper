# %%
# 모형 출처 : https://github.com/kentsommer/keras-inceptionV4/blob/master/inception_v4.py

# %% [markdown]
# # [Inception V4]

# %% [markdown]
# *KU LeeDongGyu*

# %% [markdown]
# ## Contents
# ---

# %% [markdown]
# 1. Data Preprocessing
# ```
# 1) Data Import
# 2) Data Augmentation
# ```
# 2. Support Functions & Almost Original Inception-V4
# ```
# 1) Support Functions
# 2) Almost Original Inception-V4
# 3) Inception-V4 Evaluate
# ```

# %% [markdown]
# ### Install Packages

# %% [markdown]
# ### Module

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/My Drive/Colab Notebooks/Paper
# Out:
# /content/drive/My Drive/Colab Notebooks/Paper

# %%
from f1score import macro_f1score,weighted_f1score

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import cv2
import tensorflow as tf
from tensorflow import keras as ks
from tensorflow.keras import backend as K 
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, Input, Concatenate, ZeroPadding2D ,GlobalMaxPooling2D, Reshape , Lambda , Add, Multiply
from tensorflow.keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D, Activation, BatchNormalization, AveragePooling2D , ZeroPadding2D, SeparableConv2D , LeakyReLU
from tensorflow.keras.layers import add, concatenate, multiply
from tensorflow.keras.optimizers import Adam, RMSprop , SGD
from tensorflow.keras.callbacks import EarlyStopping , LearningRateScheduler, ModelCheckpoint, CSVLogger, Callback, ReduceLROnPlateau
from tensorflow.keras.regularizers import l1,l2,l1_l2
from tensorflow.keras.models import Model , load_model , Sequential
from tensorflow.keras.utils import plot_model , to_categorical, get_file
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
os.getcwd()
# Out:
# '/content/drive/My Drive/Colab Notebooks/Paper'

# %%
print(tf.__version__)
print(ks.__version__)
# Out:
# 2.3.0
# 2.4.0

# %%
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 6116201097699564374
# , name: "/device:XLA_CPU:0"
# device_type: "XLA_CPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 17561298890490132747
# physical_device_desc: "device: XLA_CPU device"
# , name: "/device:XLA_GPU:0"
# device_type: "XLA_GPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 14798174651268999388
# physical_device_desc: "device: XLA_GPU device"
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 15473714176
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 71558166134879178
# physical_device_desc: "device: 0, name: Tesla V100-SXM2-16GB, pci bus id: 0000:00:04.0, compute capability: 7.0"
# ]

# %%
# !cat /proc/cpuinfo
# Out:
# processor	: 0
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 85
# model name	: Intel(R) Xeon(R) CPU @ 2.00GHz
# stepping	: 3
# microcode	: 0x1
# cpu MHz		: 2000.160
# cache size	: 39424 KB
# physical id	: 0
# siblings	: 4
# core id		: 0
# cpu cores	: 2
# apicid		: 0
# initial apicid	: 0
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm mpx avx512f avx512dq rdseed adx smap clflushopt clwb avx512cd avx512bw avx512vl xsaveopt xsavec xgetbv1 xsaves arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs taa
# bogomips	: 4000.32
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 46 bits physical, 48 bits virtual
# power management:
#
# processor	: 1
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 85
# model name	: Intel(R) Xeon(R) CPU @ 2.00GHz
# stepping	: 3
# microcode	: 0x1
# cpu MHz		: 2000.160
# cache size	: 39424 KB
# physical id	: 0
# siblings	: 4
# core id		: 1
# cpu cores	: 2
# apicid		: 2
# initial apicid	: 2
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm mpx avx512f avx512dq rdseed adx smap clflushopt clwb avx512cd avx512bw avx512vl xsaveopt xsavec xgetbv1 xsaves arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs taa
# bogomips	: 4000.32
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 46 bits physical, 48 bits virtual
# power management:
#
# processor	: 2
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 85
# model name	: Intel(R) Xeon(R) CPU @ 2.00GHz
# stepping	: 3
# microcode	: 0x1
# cpu MHz		: 2000.160
# cache size	: 39424 KB
# physical id	: 0
# siblings	: 4
# core id		: 0
# cpu cores	: 2
# apicid		: 1
# initial apicid	: 1
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm mpx avx512f avx512dq rdseed adx smap clflushopt clwb avx512cd avx512bw avx512vl xsaveopt xsavec xgetbv1 xsaves arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs taa
# bogomips	: 4000.32
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 46 bits physical, 48 bits virtual
# power management:
#
# processor	: 3
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 85
# model name	: Intel(R) Xeon(R) CPU @ 2.00GHz
# stepping	: 3
# microcode	: 0x1
# cpu MHz		: 2000.160
# cache size	: 39424 KB
# physical id	: 0
# siblings	: 4
# core id		: 1
# cpu cores	: 2
# apicid		: 3
# initial apicid	: 3
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm mpx avx512f avx512dq rdseed adx smap clflushopt clwb avx512cd avx512bw avx512vl xsaveopt xsavec xgetbv1 xsaves arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs taa
# bogomips	: 4000.32
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 46 bits physical, 48 bits virtual
# power management:

# %% [markdown]
# ## 1. Data Preprocessing
# ---

# %% [markdown]
# ### 1) Data Import

# %%
# 바꿔서 살펴 볼 것들
# CALTECH, CIFAR100, FER, MIT
data_name = 'CIFAR100'
gan_type = 'No_GAN'
number = '1'
size = 299 # sizes after cropping
super_size = 330 # sizes before cropping 
input_sizes = (size,size,3)
batch_sizes = 64
weight_decay = 1e-3
epochs = 70

# %%
# 참고 : https://stackoverflow.com/questions/32419510/how-to-get-reproducible-results-in-keras/52897216#52897216
# setting the seed number for random number generation for reproducibility.

from numpy.random import seed
import random


if number=='1':
    seed_num = 200225
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)
elif number=='2':
    seed_num = 727
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)
elif number=='3':
    seed_num = 115
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)
elif number=='4':
    seed_num = 501
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)
elif number=='5':
    seed_num = 517
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)

# %%
# data import

if data_name=='FER' :
    x_train =  np.zeros(28698)
    x_valid = np.zeros(3589)
    x_test = np.zeros(3588)
    classes = 7 
    tr_center = [0.50793296, 0.50793296, 0.50793296]
elif data_name=='MIT':
    x_train = np.zeros(12466)
    x_valid = np.zeros(1564)
    x_test = np.zeros(1590)
    classes = 67 
    tr_center = [0.47916578, 0.42029615, 0.36046057]
elif data_name=='CALTECH':
    x_train = np.zeros(24510)
    x_valid = np.zeros(2980)
    x_test = np.zeros(3118)
    classes = 257
    tr_center = [0.51397761, 0.49525248, 0.46555727]
elif data_name=='CIFAR100':
    x_train = np.zeros(44923)
    x_valid = np.zeros(5077)
    x_test = np.zeros(10000)
    classes = 100
    tr_center = [0.53442983, 0.51355958, 0.46462564]

# %%
dir = os.path.join(os.getcwd(),data_name,gan_type)

# %% [markdown]
# ### 2) Data Augmentation

# %%
# 참고 : https://jkjung-avt.github.io/keras-image-cropping/

def random_crop(img, random_crop_size):
    # Note: image_data_format is 'channel_last'
    assert img.shape[2] == 3 # img.shape[2] 가 3(rgb)이 아니면 assertion error 발생
    height, width = img.shape[0], img.shape[1]
    dy, dx = random_crop_size
    x = np.random.randint(0, width - dx + 1)
    y = np.random.randint(0, height - dy + 1)
    return img[y:(y+dy), x:(x+dx), :]


def crop_generator(batches, crop_length):
    """Take as input a Keras ImageGen (Iterator) and generate random
    crops from the image batches generated by the original iterator.
    """
    while True:
        batch_x, batch_y = next(batches)
        batch_crops = np.zeros((batch_x.shape[0], crop_length, crop_length, 3))
        for i in range(batch_x.shape[0]):
            batch_crops[i] = random_crop(batch_x[i], (crop_length, crop_length))
        yield (batch_crops, batch_y)

# %%
from tensorflow.keras.preprocessing.image import img_to_array,load_img
import glob

# 데이터 전체에 대해 centering 진행함.

def read_cal_image(img_path): 
    x = img_to_array(load_img(img_path)) # x는 채널별 평균값
    y = x.shape[0] * x.shape[1]# y는 데이터별 픽셀 수 (비중)

    x = 1/255. * x # scaling하고, centering값을 뽑아냄.
    x = np.mean(x, axis=(0,1))
    
    return np.hstack([x,y])

def calculate_centered_mean(dataset_path,x_train=x_train):
    num = len(x_train)
    space = np.empty((num,4))
    i=0

    for p in glob.glob(os.path.join(dataset_path,'*/*.*')) :
        space[i] = read_cal_image(p)
        i += 1

    ratio = space[:,3] / np.sum(space[:,3])

    return np.average(space[:,0:3],axis=0,weights=ratio)


# 아래의 함수를 돌려서 나온 결과값을 중심화 값으로 설정.

# train_mean = calculate_centered_mean(os.path.join(dir,'data/train')).reshape((1,1,3))

# %%
datagen_tr = ImageDataGenerator(
    rescale=1/255.,
    horizontal_flip=True,
    featurewise_center=True,
    featurewise_std_normalization=False,
    rotation_range=10,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=[0.9,1.0],
    fill_mode = 'nearest')
datagen_val = ImageDataGenerator(rescale=1/255.,featurewise_center=True)
datagen_tes = ImageDataGenerator(rescale=1/255.,featurewise_center=True)

# 원래는 이 자리에 fit 매서드를 써야하지만, 그냥 내가 중심화함수를 만들고 적용함. 

# 중심화 설정
datagen_tr.mean = np.array(tr_center, dtype=np.float32).reshape((1,1,3)) # RGB
datagen_val.mean = np.array(tr_center, dtype=np.float32).reshape((1,1,3)) # RGB
datagen_tes.mean = np.array(tr_center, dtype=np.float32).reshape((1,1,3)) # RGB

# %%
train_batches = datagen_tr.flow_from_directory(directory=os.path.join(dir,'data/train'),target_size=(super_size,super_size),batch_size=batch_sizes,class_mode='categorical') # fer : 28698 / mit : 12466 / caltech : 24509 / cifar : 44923
train_generator= crop_generator(train_batches, size)
valid_generator = datagen_val.flow_from_directory(directory=os.path.join(dir,'data/valid'),target_size=(size,size),batch_size=batch_sizes,class_mode='categorical') # fer : 3589 / mit : 1564 / caltech : 2980 / cifar : 5077
test_generator = datagen_tes.flow_from_directory(directory=os.path.join(dir,'data/test'),target_size=(size,size),batch_size=batch_sizes,class_mode='categorical') # fer : 3588 / mit : 1590 / caltech : 3118 / cifar : 10000
# Out:
# Found 44923 images belonging to 100 classes.
# Found 5077 images belonging to 100 classes.
# Found 10000 images belonging to 100 classes.

# %% [markdown]
# ## 2. Support Functions & Almost Original Inception-V4
# ---

# %% [markdown]
# ### 1) Support Functions

# %%
# def lr_schedule(epoch):
#     init_lr = 1e-4
#     k = 0.04
#     lr = init_lr * np.exp(-k*epoch)
#     print('Learning rate: ', lr)
#     return lr

def lr_schedule(epoch):
    lr = 1e-3
    if epoch < 30:
        lr = lr
    elif epoch < 60 :
        lr = lr * 0.1
    else:
        lr = lr * 0.01
    print('Learning rate: ', lr)
    return lr

# %%
def conv2d_bn(x, nb_filter, num_row, num_col, padding='same', strides=(1, 1), use_bias=False, weight_decay = weight_decay):

    channel_axis = -1

    x = Conv2D(nb_filter, (num_row, num_col), strides=strides, padding=padding, use_bias=use_bias, kernel_regularizer=l2(weight_decay), kernel_initializer='he_uniform')(x)
    x = BatchNormalization(axis=channel_axis)(x)
    x = Activation('relu')(x)
    return x

# %%
def block_inception_a(input):

    channel_axis = -1

    branch_0 = conv2d_bn(input, 96, 1, 1)

    branch_1 = conv2d_bn(input, 64, 1, 1)
    branch_1 = conv2d_bn(branch_1, 96, 3, 3)

    branch_2 = conv2d_bn(input, 64, 1, 1)
    branch_2 = conv2d_bn(branch_2, 96, 3, 3)
    branch_2 = conv2d_bn(branch_2, 96, 3, 3)

    branch_3 = AveragePooling2D((3,3), strides=(1,1), padding='same')(input)
    branch_3 = conv2d_bn(branch_3, 96, 1, 1)

    x = concatenate([branch_0, branch_1, branch_2, branch_3], axis=channel_axis)
    return x

def block_inception_b(input):

    channel_axis = -1

    branch_0 = conv2d_bn(input, 384, 1, 1)

    branch_1 = conv2d_bn(input, 192, 1, 1)
    branch_1 = conv2d_bn(branch_1, 224, 1, 7)
    branch_1 = conv2d_bn(branch_1, 256, 7, 1)

    branch_2 = conv2d_bn(input, 192, 1, 1)
    branch_2 = conv2d_bn(branch_2, 192, 7, 1)
    branch_2 = conv2d_bn(branch_2, 224, 1, 7)
    branch_2 = conv2d_bn(branch_2, 224, 7, 1)
    branch_2 = conv2d_bn(branch_2, 256, 1, 7)

    branch_3 = AveragePooling2D((3,3), strides=(1,1), padding='same')(input)
    branch_3 = conv2d_bn(branch_3, 128, 1, 1)

    x = concatenate([branch_0, branch_1, branch_2, branch_3], axis=channel_axis)
    return x

def block_inception_c(input):

    channel_axis = -1

    branch_0 = conv2d_bn(input, 256, 1, 1)

    branch_1 = conv2d_bn(input, 384, 1, 1)
    branch_10 = conv2d_bn(branch_1, 256, 1, 3)
    branch_11 = conv2d_bn(branch_1, 256, 3, 1)
    branch_1 = concatenate([branch_10, branch_11], axis=channel_axis)


    branch_2 = conv2d_bn(input, 384, 1, 1)
    branch_2 = conv2d_bn(branch_2, 448, 3, 1)
    branch_2 = conv2d_bn(branch_2, 512, 1, 3)
    branch_20 = conv2d_bn(branch_2, 256, 1, 3)
    branch_21 = conv2d_bn(branch_2, 256, 3, 1)
    branch_2 = concatenate([branch_20, branch_21], axis=channel_axis)

    branch_3 = AveragePooling2D((3, 3), strides=(1, 1), padding='same')(input)
    branch_3 = conv2d_bn(branch_3, 256, 1, 1)

    x = concatenate([branch_0, branch_1, branch_2, branch_3], axis=channel_axis)
    return x

# %%
def block_reduction_a(input):

    channel_axis = -1

    branch_0 = conv2d_bn(input, 384, 3, 3, strides=(2,2), padding='valid')

    branch_1 = conv2d_bn(input, 192, 1, 1)
    branch_1 = conv2d_bn(branch_1, 224, 3, 3)
    branch_1 = conv2d_bn(branch_1, 256, 3, 3, strides=(2,2), padding='valid')

    branch_2 = MaxPooling2D((3,3), strides=(2,2), padding='valid')(input)

    x = concatenate([branch_0, branch_1, branch_2], axis=channel_axis)
    return x

def block_reduction_b(input):

    channel_axis = -1

    branch_0 = conv2d_bn(input, 192, 1, 1)
    branch_0 = conv2d_bn(branch_0, 192, 3, 3, strides=(2, 2), padding='valid')

    branch_1 = conv2d_bn(input, 256, 1, 1)
    branch_1 = conv2d_bn(branch_1, 256, 1, 7)
    branch_1 = conv2d_bn(branch_1, 320, 7, 1)
    branch_1 = conv2d_bn(branch_1, 320, 3, 3, strides=(2,2), padding='valid')

    branch_2 = MaxPooling2D((3, 3), strides=(2, 2), padding='valid')(input)

    x = concatenate([branch_0, branch_1, branch_2], axis=channel_axis)
    return x

# %% [markdown]
# ### 2) Almost Original Inception-V4

# %%
def inception_v4_base(input):

    channel_axis = -1

    net = conv2d_bn(input, 32, 3, 3, strides=(2,2), padding='valid')
    net = conv2d_bn(net, 32, 3, 3, padding='valid')
    net = conv2d_bn(net, 64, 3, 3)

    branch_0 = MaxPooling2D((3,3), strides=(2,2), padding='valid')(net)

    branch_1 = conv2d_bn(net, 96, 3, 3, strides=(2,2), padding='valid')

    net = concatenate([branch_0, branch_1], axis=channel_axis)

    branch_0 = conv2d_bn(net, 64, 1, 1)
    branch_0 = conv2d_bn(branch_0, 96, 3, 3, padding='valid')

    branch_1 = conv2d_bn(net, 64, 1, 1)
    branch_1 = conv2d_bn(branch_1, 64, 1, 7)
    branch_1 = conv2d_bn(branch_1, 64, 7, 1)
    branch_1 = conv2d_bn(branch_1, 96, 3, 3, padding='valid')

    net = concatenate([branch_0, branch_1], axis=channel_axis)

    branch_0 = conv2d_bn(net, 192, 3, 3, strides=(2,2), padding='valid')
    branch_1 = MaxPooling2D((3,3), strides=(2,2), padding='valid')(net)

    net = concatenate([branch_0, branch_1], axis=channel_axis)

    # 35 x 35 x 384
    # 4 x Inception-A blocks
    for idx in range(4):
    	net = block_inception_a(net)

    # 35 x 35 x 384
    # Reduction-A block
    net = block_reduction_a(net)

    # 17 x 17 x 1024
    # 7 x Inception-B blocks
    for idx in range(7):
    	net = block_inception_b(net)

    # 17 x 17 x 1024
    # Reduction-B block
    net = block_reduction_b(net)

    # 8 x 8 x 1536
    # 3 x Inception-C blocks
    for idx in range(3):
    	net = block_inception_c(net)

    return net

# %%
def Inception_v4(input_shape, classes, name = None, weight_decay = weight_decay):

    inputs = Input(shape=input_shape)

    # Make inception base
    x = inception_v4_base(inputs)


    # Final pooling and prediction
    # 1 x 1 x 1536
    x = AveragePooling2D((8,8), padding='valid')(x)
    x = Dropout(0.2)(x)
    x = Flatten()(x)
    # 1536
    x = Dense(classes, use_bias=False, kernel_regularizer=l2(weight_decay), activation='softmax')(x)

    model = Model(inputs, x, name=name)

  
    return model

# %%
model = Inception_v4(input_sizes, classes=classes, name='Inception_v4')

# %%
model.summary()
# Out:
# Model: "Inception_v4"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 299, 299, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 149, 149, 32) 864         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 149, 149, 32) 128         conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 149, 149, 32) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 147, 147, 32) 9216        activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 147, 147, 32) 128         conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 147, 147, 32) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 147, 147, 64) 18432       activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 147, 147, 64) 256         conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 147, 147, 64) 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 73, 73,
0][0]
# __________________________________________________________________________________________________
# activation_144 (Activation)     (None, 8, 8, 448)    0           batch_normalization_144[0][0]
# __________________________________________________________________________________________________
# conv2d_140 (Conv2D)             (None, 8, 8, 384)    589824      concatenate_21[0][0]
# __________________________________________________________________________________________________
# conv2d_145 (Conv2D)             (None, 8, 8, 512)    688128      activation_144[0][0]
# __________________________________________________________________________________________________
# batch_normalization_140 (BatchN (None, 8, 8, 384)    1536        conv2d_140[0][0]
# __________________________________________________________________________________________________
# batch_normalization_145 (BatchN (None, 8, 8, 512)    2048        conv2d_145[0][0]
# __________________________________________________________________________________________________
# activation_140 (Activation)     (None, 8, 8, 384)    0           batch_normalization_140[0][0]
# __________________________________________________________________________________________________
# activation_145 (Activation)     (None, 8, 8, 512)    0           batch_normalization_145[0][0]
# __________________________________________________________________________________________________
# conv2d_141 (Conv2D)             (None, 8, 8, 256)    294912      activation_140[0][0]
# __________________________________________________________________________________________________
# conv2d_142 (Conv2D)             (None, 8, 8, 256)    294912      activation_140[0][0]
# __________________________________________________________________________________________________
# conv2d_146 (Conv2D)             (None, 8, 8, 256)    393216      activation_145[0][0]
# __________________________________________________________________________________________________
# conv2d_147 (Conv2D)             (None, 8, 8, 256)    393216      activation_145[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_13 (AveragePo (None, 8, 8, 1536)   0           concatenate_21[0][0]
# __________________________________________________________________________________________________
# conv2d_139 (Conv2D)             (None, 8, 8, 256)    393216      concatenate_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_141 (BatchN (None, 8, 8, 256)    1024        conv2d_141[0][0]
# __________________________________________________________________________________________________
# batch_normalization_142 (BatchN (None, 8, 8, 256)    1024        conv2d_142[0][0]
# __________________________________________________________________________________________________
# batch_normalization_146 (BatchN (None, 8, 8, 256)    1024        conv2d_146[0][0]
# __________________________________________________________________________________________________
# batch_normalization_147 (BatchN (None, 8, 8, 256)    1024        conv2d_147[0][0]
# __________________________________________________________________________________________________
# conv2d_148 (Conv2D)             (None, 8, 8, 256)    393216      average_pooling2d_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_139 (BatchN (None, 8, 8, 256)    1024        conv2d_139[0][0]
# __________________________________________________________________________________________________
# activation_141 (Activation)     (None, 8, 8, 256)    0           batch_normalization_141[0][0]
# __________________________________________________________________________________________________
# activation_142 (Activation)     (None, 8, 8, 256)    0           batch_normalization_142[0][0]
# __________________________________________________________________________________________________
# activation_146 (Activation)     (None, 8, 8, 256)    0           batch_normalization_146[0][0]
# __________________________________________________________________________________________________
# activation_147 (Activation)     (None, 8, 8, 256)    0           batch_normalization_147[0][0]
# __________________________________________________________________________________________________
# batch_normalization_148 (BatchN (None, 8, 8, 256)    1024        conv2d_148[0][0]
# __________________________________________________________________________________________________
# activation_139 (Activation)     (None, 8, 8, 256)    0           batch_normalization_139[0][0]
# __________________________________________________________________________________________________
# concatenate_22 (Concatenate)    (None, 8, 8, 512)    0           activation_141[0][0]
#                                                                  activation_142[0][0]
# __________________________________________________________________________________________________
# concatenate_23 (Concatenate)    (None, 8, 8, 512)    0           activation_146[0][0]
#                                                                  activation_147[0][0]
# __________________________________________________________________________________________________
# activation_148 (Activation)     (None, 8, 8, 256)    0           batch_normalization_148[0][0]
# __________________________________________________________________________________________________
# concatenate_24 (Concatenate)    (None, 8, 8, 1536)   0           activation_139[0][0]
#                                                                  concatenate_22[0][0]
#                                                                  concatenate_23[0][0]
#                                                                  activation_148[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_14 (AveragePo (None, 1, 1, 1536)   0           concatenate_24[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 1, 1, 1536)   0           average_pooling2d_14[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 1536)         0           dropout[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 100)          153600      flatten[0][0]
# ==================================================================================================
# Total params: 41,359,584
# Trainable params: 41,296,416
# Non-trainable params: 63,168
# __________________________________________________________________________________________________

# %%
# 폴더 생성

os.makedirs(os.path.join(dir,'model_output',number,model.name), exist_ok=True)
os.makedirs(os.path.join(dir,'train_valid_output',number), exist_ok=True)

# %%
# 참고 : https://github.com/OverLordGoldDragon/keras-adamw

import sys
sys.path.append('/content/drive/My Drive/Colab Notebooks/Paper')
import utils
import optimizers_v2
from utils import get_weight_decays, fill_dict_in_order
from utils import reset_seeds, K_eval
from optimizers_v2 import AdamW, NadamW, SGDW

# %%
# top-5 accuracy 출력
import functools
top5_acc = functools.partial(ks.metrics.top_k_categorical_accuracy, k=5)
top5_acc.__name__ = 'top5_acc'

# %%
#optimizer = SGDW(model=model, use_cosine_annealing=False, total_iterations = len(x_train) // batch_sizes, nesterov=True, momentum=0.9)
optimizer = AdamW(model=model, use_cosine_annealing=False, total_iterations = len(x_train) // batch_sizes)
#optimizer = Adam()
filepath =  os.path.join(dir,'model_output',number,model.name,'{epoch:03d}.h5')

callbacks_list = [ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_weights_only=False, save_best_only=False, mode='min'),
                  ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_weights_only=False, save_best_only=False, mode='max'),
                  #ReduceLROnPlateau(monitor='val_loss',patience=3,factor=0.1,min_lr=1e-5),
                  LearningRateScheduler(lr_schedule,verbose=1)
                  ]
                  
model.compile(optimizer, loss = 'categorical_crossentropy', metrics=['accuracy',top5_acc,macro_f1score])

# %%
######## flow_from_directory
history = model.fit(train_generator, steps_per_epoch=int(len(x_train)/batch_sizes),  validation_data = valid_generator, epochs=epochs , verbose=1 , callbacks = callbacks_list , validation_steps=int(len(x_valid)/batch_sizes))
# Out:
# Learning rate:  0.001
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 1/70
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_1/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_2/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_3/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_6/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_7/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_4/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_8/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_5/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_9/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_10/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_14/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_12/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_15/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_11/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_13/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_16/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_17/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_21/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_19/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_22/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_18/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_20/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_23/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_24/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_28/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_26/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_29/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_25/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_27/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_30/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_31/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_35/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_33/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_36/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_32/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_34/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_37/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_38/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_40/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_41/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_39/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_42/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_47/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_48/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_44/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_49/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_45/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_50/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_43/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_46/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_51/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_52/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_57/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_58/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_54/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_59/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_55/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_60/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_53/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_56/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_61/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_62/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_67/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_68/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_64/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_69/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_65/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_70/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_63/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d_66/kernel:0
# 0.0(L1), 3.7769480523978874e-05(L2) weight decay set for conv2d
saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/Inception_v4/042.h5
#
# Epoch 00042: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/Inception_v4/042.h5
# 701/701 [==============================] - 981s 1s/step - loss: 0.1003 - accuracy: 0.9762 - top5_acc: 0.9997 - macro_f1score: 0.4593 - val_loss: 1.1126 - val_accuracy: 0.7150 - val_top5_acc: 0.9227 - val_macro_f1score: 0.3209
# Learning rate:  0.0001
#
# Epoch 00043: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 43/70
# 701/701 [==============================] - ETA: 0s - loss: 0.0957 - accuracy: 0.9778 - top5_acc: 0.9994 - macro_f1score: 0.4598
# Epoch 00043: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/Inception_v4/043.h5
#
# Epoch 00043: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/Inception_v4/043.h5
# 701/701 [==============================] - 979s 1s/step - loss: 0.0957 - accuracy: 0.9778 - top5_acc: 0.9994 - macro_f1score: 0.4598 - val_loss: 1.1257 - val_accuracy: 0.7150 - val_top5_acc: 0.9252 - val_macro_f1score: 0.3241
# Learning rate:  0.0001
#
# Epoch 00044: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 44/70
# 701/701 [==============================] - ETA: 0s - loss: 0.0917 - accuracy: 0.9787 - top5_acc: 0.9996 - macro_f1score: 0.4618
# Epoch 00044: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/Inception_v4/044.h5
#
# Epoch 00044: saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/Inception_v4/044.h5
# 701/701 [==============================] - 978s 1s/step - loss: 0.0917 - accuracy: 0.9787 - top5_acc: 0.9996 - macro_f1score: 0.4618 - val_loss: 1.1228 - val_accuracy: 0.7182 - val_top5_acc: 0.9207 - val_macro_f1score: 0.3236
# Learning rate:  0.0001
#
# Epoch 00045: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 45/70
# 540/701 [======================>.......] - ETA: 3:37 - loss: 0.0856 - accuracy: 0.9804 - top5_acc: 0.9997 - macro_f1score: 0.4624

# %%
# colab pro가 최대 24시간 돌아가므로, 그 한계로 인해 두번 나눠서 학습을봄.

# %%
model=load_model(os.path.join(dir,'model_output',number,'Inception_v4','040.h5'),custom_objects={"macro_f1score": macro_f1score,"top5_acc":top5_acc, "AdamW":AdamW})

# %%
# def lr_schedule(epoch):
#     init_lr = 1e-4
#     k = 0.04
#     lr = init_lr * np.exp(-k*epoch)
#     print('Learning rate: ', lr)
#     return lr

def lr_schedule(epoch):
    lr = 1e-4
    if epoch < 20:
        lr = lr
    else  :
        lr = lr * 0.1
    print('Learning rate: ', lr)
    return lr

# %%
os.makedirs(os.path.join(dir,'model_output',number,'SUB',model.name), exist_ok=True) # 모델을 위에서 정의해야함

# %%
#optimizer = SGDW(model=model, use_cosine_annealing=False, total_iterations = len(x_train) // batch_sizes, nesterov=True, momentum=0.9)
optimizer = AdamW(model=model, use_cosine_annealing=False, total_iterations = len(x_train) // batch_sizes)
#optimizer = Adam()
filepath =  os.path.join(dir,'model_output',number,'SUB',model.name,'{epoch:03d}.h5')

callbacks_list = [ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_weights_only=False, save_best_only=True, mode='min'),
                  ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_weights_only=False, save_best_only=True, mode='max'),
                  #ReduceLROnPlateau(monitor='val_loss',patience=3,factor=0.1,min_lr=1e-5),
                  LearningRateScheduler(lr_schedule,verbose=1)
                  ]
                  
model.compile(optimizer, loss = 'categorical_crossentropy', metrics=['accuracy',top5_acc,macro_f1score])

# %%
######## flow_from_directory
history = model.fit(train_generator, steps_per_epoch=int(len(x_train)/batch_sizes),  validation_data = valid_generator, epochs=30 , verbose=1 , callbacks = callbacks_list , validation_steps=int(len(x_valid)/batch_sizes))
# Out:
# Learning rate:  0.0001
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 1/30
# 701/701 [==============================] - ETA: 0s - loss: 0.0985 - accuracy: 0.9781 - top5_acc: 0.9995 - macro_f1score: 0.4598
# Epoch 00001: val_loss improved from inf to 1.10218, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SUB/Inception_v4/001.h5
#
# Epoch 00001: val_accuracy improved from -inf to 0.72646, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SUB/Inception_v4/001.h5
# 701/701 [==============================] - 28896s 41s/step - loss: 0.0985 - accuracy: 0.9781 - top5_acc: 0.9995 - macro_f1score: 0.4598 - val_loss: 1.1022 - val_accuracy: 0.7265 - val_top5_acc: 0.9248 - val_macro_f1score: 0.3270
# Learning rate:  0.0001
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 2/30
# 701/701 [==============================] - ETA: 0s - loss: 0.0927 - accuracy: 0.9781 - top5_acc: 0.9996 - macro_f1score: 0.4588
# Epoch 00002: val_loss did not improve from 1.10218
#
# Epoch 00002: val_accuracy improved from 0.72646 to 0.72805, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SUB/Inception_v4/002.h5
# 701/701 [==============================] - 1196s 2s/step - loss: 0.0927 - accuracy: 0.9781 - top5_acc: 0.9996 - macro_f1score: 0.4588 - val_loss: 1.1112 - val_accuracy: 0.7280 - val_top5_acc: 0.9264 - val_macro_f1score: 0.3308
# Learning rate:  0.0001
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 3/30
# 701/701 [==============================] - ETA: 0s - loss: 0.0862 - accuracy: 0.9792 - top5_acc: 0.9997 - macro_f1score: 0.4623
# Epoch 00003: val_loss did not improve from 1.10218
#
# Epoch 00003: val_accuracy did not improve from 0.72805
# 701/701 [==============================] - 1168s 2s/step - loss: 0.0862 - accuracy: 0.9792 - top5_acc: 0.9997 - macro_f1score: 0.4623 - val_loss: 1.1579 - val_accuracy: 0.7174 - val_top5_acc: 0.9262 - val_macro_f1score: 0.3286
# Learning rate:  0.0001
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 4/30
# 701/701 [==============================] - ETA: 0s - loss: 0.0794 - accuracy: 0.9810 - top5_acc: 0.9998 - macro_f1score: 0.4627
# Epoch 00004: val_loss did not improve from 1.10218
#
# Epoch 00004: val_accuracy did not improve from 0.72805
# 701/701 [==============================] - 1152s 2s/step - loss: 0.0794 - accuracy: 0.9810 - top5_acc: 0.9998 - macro_f1score: 0.4627 - val_loss: 1.1653 - val_accuracy: 0.7189 - val_top5_acc: 0.9239 - val_macro_f1score: 0.3284
# Learning rate:  0.0001
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 5/30
# 701/701 [==============================] - ETA: 0s - loss: 0.0750 - accuracy: 0.9817 - top5_acc: 0.9996 - macro_f1score: 0.4622
# Epoch 00005: val_loss did not improve from 1.10218
#
# Epoch 00005: val_accuracy did not improve from 0.72805
# 701/701 [==============================] - 1149s 2s/step - loss: 0.0750 - accuracy: 0.9817 - top5_acc: 0.9996 - macro_f1score: 0.4622 - val_loss: 1.1673 - val_accuracy: 0.7170 - val_top5_acc: 0.9252 - val_macro_f1score: 0.3242
# Learning rate:  0.0001
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 6/30
# 701/701 [==============================] - ETA: 0s - loss: 0.0697 - accuracy: 0.9829 - top5_acc: 0.9998 - macro_f1score: 0.4647
# Epoch 00006: val_loss did not improve from 1.10218
#
# Epoch 00006: val_accuracy did not improve from 0.72805
# 701/701 [==============================] - 1154s 2s/step - loss: 0.0697 - accuracy: 0.9829 - top5_acc: 0.9998 - macro_f1score: 0.4647 - val_loss: 1.1801 - val_accuracy: 0.7217 - val_top5_acc: 0.9225 - val_macro_f1score: 0.3319
# Learning rate:  0.0001
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 7/30
# 701/701 [==============================] - ETA: 0s - loss: 0.0661 - accuracy: 0.9845 - top5_acc: 0.9998 - macro_f1score: 0.4652
# Epoch 00007: val_loss did not improve from 1.10218
#
# Epoch 00007: val_accuracy did not improve from 0.72805
# 701/701 [==============================] - 1145s 2s/step - loss: 0.0661 - accuracy: 0.9845 - top5_acc: 0.9998 - macro_f1score: 0.4652 - val_loss: 1.2022 - val_accuracy: 0.7253 - val_top5_acc: 0.9227 - val_macro_f1score: 0.3275
# Learning rate:  0.0001
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 8/30
# 701/701 [==============================] - ETA: 0s - loss: 0.0619 - accuracy: 0.9847 - top5_acc: 0.9997 - macro_f1score: 0.4663
# Epoch 00008: val_loss did not improve from 1.10218
#
# Epoch 00008: val_accuracy did not improve from 0.72805
# 701/701 [==============================] - 1146s 2s/step - loss: 0.0619 - accuracy: 0.9847 - top5_acc: 0.9997 - macro_f1score: 0.4663 - val_loss: 1.2007 - val_accuracy: 0.7255 - val_top5_acc: 0.9221 - val_macro_f1score: 0.3289
# Learning rate:  0.0001
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 9/30
# 701/701 [==============================] - ETA: 0s - loss: 0.0582 - accuracy: 0.9852 - top5_acc: 0.9998 - macro_f1score: 0.4665
# Epoch 00009: val_loss did not improve from 1.10218
#
# Epoch 00009: val_accuracy did not improve from 0.72805
# 701/701 [==============================] - 1141s 2s/step - loss: 0.0582 - accuracy: 0.9852 - top5_acc: 0.9998 - macro_f1score: 0.4665 - val_loss: 1.2153 - val_accuracy: 0.7180 - val_top5_acc: 0.9205 - val_macro_f1score: 0.3266
# Learning rate:  0.0001
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 10/30
# 701/701 [==============================] - ETA: 0s - loss: 0.0539 - accuracy: 0.9868 - top5_acc: 0.9998 - macro_f1score: 0.4675
# Epoch 00010: val_loss did not improve from 1.10218
#
# Epoch 00010: val_accuracy did not improve from 0.72805
# 701/701 [==============================] - 1142s 2s/step - loss: 0.0539 - accuracy: 0.9868 - top5_acc: 0.9998 - macro_f1score: 0.4675 - val_loss: 1.2207 - val_accuracy: 0.7251 - val_top5_acc: 0.9227 - val_macro_f1score: 0.3304
# Learning rate:  0.0001
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 11/30
# 701/701 [==============================] - ETA: 0s - loss: 0.0523 - accuracy: 0.9869 - top5_acc: 0.9998 - macro_f1score: 0.4667
# Epoch 00011: val_loss did not improve from 1.10218
#
# Epoch 00011: val_accuracy did not improve from 0.72805
# 701/701 [==============================] - 1138s 2s/step - loss: 0.0523 - accuracy: 0.9869 - top5_acc: 0.9998 - macro_f1score: 0.4667 - val_loss: 1.2514 - val_accuracy: 0.7154 - val_top5_acc: 0.9217 - val_macro_f1score: 0.3280
# Learning rate:  0.0001
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 12/30
# 701/701 [==============================] - ETA: 0s - loss: 0.0469 - accuracy: 0.9892 - top5_acc: 0.9997 - macro_f1score: 0.4680
# Epoch 00012: val_loss did not improve from 1.10218
#
# Epoch 00012: val_accuracy did not improve from 0.72805
# 701/701 [==============================] - 1153s 2s/step - loss: 0.0469 - accuracy: 0.9892 - top5_acc: 0.9997 - macro_f1score: 0.4680 - val_loss: 1.2574 - val_accuracy: 0.7195 - val_top5_acc: 0.9197 - val_macro_f1score: 0.3298
# Learning rate:  0.0001
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 13/30
# 701/701 [==============================] - ETA: 0s - loss: 0.0464 - accuracy: 0.9884 - top5_acc: 0.9999 - macro_f1score: 0.4679
# Epoch 00013: val_loss did not improve from 1.10218
#
# Epoch 00013: val_accuracy did not improve from 0.72805
# 701/701 [==============================] - 1154s 2s/step - loss: 0.0464 - accuracy: 0.9884 - top5_acc: 0.9999 - macro_f1score: 0.4679 - val_loss: 1.3098 - val_accuracy: 0.7122 - val_top5_acc: 0.9207 - val_macro_f1score: 0.3283
# Learning rate:  0.0001
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 14/30
# 701/701 [==============================] - ETA: 0s - loss: 0.0428 - accuracy: 0.9896 - top5_acc: 0.9999 - macro_f1score: 0.4700
# Epoch 00014: val_loss did not improve from 1.10218
#
# Epoch 00014: val_accuracy did not improve from 0.72805
# 701/701 [==============================] - 1160s 2s/step - loss: 0.0428 - accuracy: 0.9896 - top5_acc: 0.9999 - macro_f1score: 0.4700 - val_loss: 1.3072 - val_accuracy: 0.7132 - val_top5_acc: 0.9213 - val_macro_f1score: 0.3274
# Learning rate:  0.0001
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 15/30
# 701/701 [==============================] - ETA: 0s - loss: 0.0427 - accuracy: 0.9893 - top5_acc: 0.9999 - macro_f1score: 0.4690
# Epoch 00015: val_loss did not improve from 1.10218
#
# Epoch 00015: val_accuracy did not improve from 0.72805
# 701/701 [==============================] - 1152s 2s/step - loss: 0.0427 - accuracy: 0.9893 - top5_acc: 0.9999 - macro_f1score: 0.4690 - val_loss: 1.2765 - val_accuracy: 0.7172 - val_top5_acc: 0.9205 - val_macro_f1score: 0.3283
# Learning rate:  0.0001
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 16/30
# 701/701 [==============================] - ETA: 0s - loss: 0.0403 - accuracy: 0.9898 - top5_acc: 1.0000 - macro_f1score: 0.4681
# Epoch 00016: val_loss did not improve from 1.10218
#
# Epoch 00016: val_accuracy did not improve from 0.72805
# 701/701 [==============================] - 1163s 2s/step - loss: 0.0403 - accuracy: 0.9898 - top5_acc: 1.0000 - macro_f1score: 0.4681 - val_loss: 1.3151 - val_accuracy: 0.7195 - val_top5_acc: 0.9199 - val_macro_f1score: 0.3270
# Learning rate:  0.0001
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 17/30
# 701/701 [==============================] - ETA: 0s - loss: 0.0363 - accuracy: 0.9924 - top5_acc: 0.9999 - macro_f1score: 0.4690
# Epoch 00017: val_loss did not improve from 1.10218
#
# Epoch 00017: val_accuracy did not improve from 0.72805
# 701/701 [==============================] - 1165s 2s/step - loss: 0.0363 - accuracy: 0.9924 - top5_acc: 0.9999 - macro_f1score: 0.4690 - val_loss: 1.3263 - val_accuracy: 0.7160 - val_top5_acc: 0.9183 - val_macro_f1score: 0.3268
# Learning rate:  0.0001
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 18/30
# 701/701 [==============================] - ETA: 0s - loss: 0.0347 - accuracy: 0.9917 - top5_acc: 0.9999 - macro_f1score: 0.4691
# Epoch 00018: val_loss did not improve from 1.10218
#
# Epoch 00018: val_accuracy did not improve from 0.72805
# 701/701 [==============================] - 1152s 2s/step - loss: 0.0347 - accuracy: 0.9917 - top5_acc: 0.9999 - macro_f1score: 0.4691 - val_loss: 1.3157 - val_accuracy: 0.7225 - val_top5_acc: 0.9185 - val_macro_f1score: 0.3323
# Learning rate:  0.0001
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 19/30
# 701/701 [==============================] - ETA: 0s - loss: 0.0342 - accuracy: 0.9916 - top5_acc: 0.9999 - macro_f1score: 0.4700
# Epoch 00019: val_loss did not improve from 1.10218
#
# Epoch 00019: val_accuracy did not improve from 0.72805
# 701/701 [==============================] - 1141s 2s/step - loss: 0.0342 - accuracy: 0.9916 - top5_acc: 0.9999 - macro_f1score: 0.4700 - val_loss: 1.3032 - val_accuracy: 0.7235 - val_top5_acc: 0.9242 - val_macro_f1score: 0.3356
# Learning rate:  0.0001
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 20/30
# 701/701 [==============================] - ETA: 0s - loss: 0.0301 - accuracy: 0.9928 - top5_acc: 0.9999 - macro_f1score: 0.4711
# Epoch 00020: val_loss did not improve from 1.10218
#
# Epoch 00020: val_accuracy did not improve from 0.72805
# 701/701 [==============================] - 1152s 2s/step - loss: 0.0301 - accuracy: 0.9928 - top5_acc: 0.9999 - macro_f1score: 0.4711 - val_loss: 1.3296 - val_accuracy: 0.7207 - val_top5_acc: 0.9211 - val_macro_f1score: 0.3318
# Learning rate:  1e-05
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 21/30
# 701/701 [==============================] - ETA: 0s - loss: 0.0243 - accuracy: 0.9947 - top5_acc: 1.0000 - macro_f1score: 0.4722
# Epoch 00021: val_loss did not improve from 1.10218
#
# Epoch 00021: val_accuracy did not improve from 0.72805
# 701/701 [==============================] - 1156s 2s/step - loss: 0.0243 - accuracy: 0.9947 - top5_acc: 1.0000 - macro_f1score: 0.4722 - val_loss: 1.3013 - val_accuracy: 0.7247 - val_top5_acc: 0.9244 - val_macro_f1score: 0.3306
# Learning rate:  1e-05
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 22/30
# 701/701 [==============================] - ETA: 0s - loss: 0.0196 - accuracy: 0.9963 - top5_acc: 1.0000 - macro_f1score: 0.4707
# Epoch 00022: val_loss did not improve from 1.10218
#
# Epoch 00022: val_accuracy did not improve from 0.72805
# 701/701 [==============================] - 1155s 2s/step - loss: 0.0196 - accuracy: 0.9963 - top5_acc: 1.0000 - macro_f1score: 0.4707 - val_loss: 1.2960 - val_accuracy: 0.7233 - val_top5_acc: 0.9241 - val_macro_f1score: 0.3332
# Learning rate:  1e-05
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 23/30
# 701/701 [==============================] - ETA: 0s - loss: 0.0181 - accuracy: 0.9966 - top5_acc: 1.0000 - macro_f1score: 0.4729
# Epoch 00023: val_loss did not improve from 1.10218
#
# Epoch 00023: val_accuracy did not improve from 0.72805
# 701/701 [==============================] - 1160s 2s/step - loss: 0.0181 - accuracy: 0.9966 - top5_acc: 1.0000 - macro_f1score: 0.4729 - val_loss: 1.2874 - val_accuracy: 0.7249 - val_top5_acc: 0.9244 - val_macro_f1score: 0.3303
# Learning rate:  1e-05
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 24/30
# 701/701 [==============================] - ETA: 0s - loss: 0.0162 - accuracy: 0.9970 - top5_acc: 1.0000 - macro_f1score: 0.4725
# Epoch 00024: val_loss did not improve from 1.10218
#
# Epoch 00024: val_accuracy did not improve from 0.72805
# 701/701 [==============================] - 1154s 2s/step - loss: 0.0162 - accuracy: 0.9970 - top5_acc: 1.0000 - macro_f1score: 0.4725 - val_loss: 1.2898 - val_accuracy: 0.7263 - val_top5_acc: 0.9235 - val_macro_f1score: 0.3320
# Learning rate:  1e-05
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 25/30
# 701/701 [==============================] - ETA: 0s - loss: 0.0153 - accuracy: 0.9974 - top5_acc: 1.0000 - macro_f1score: 0.4736
# Epoch 00025: val_loss did not improve from 1.10218
#
# Epoch 00025: val_accuracy improved from 0.72805 to 0.72824, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SUB/Inception_v4/025.h5
# 701/701 [==============================] - 1153s 2s/step - loss: 0.0153 - accuracy: 0.9974 - top5_acc: 1.0000 - macro_f1score: 0.4736 - val_loss: 1.2905 - val_accuracy: 0.7282 - val_top5_acc: 0.9237 - val_macro_f1score: 0.3340
# Learning rate:  1e-05
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 26/30
# 701/701 [==============================] - ETA: 0s - loss: 0.0136 - accuracy: 0.9978 - top5_acc: 1.0000 - macro_f1score: 0.4726
# Epoch 00026: val_loss did not improve from 1.10218
#
# Epoch 00026: val_accuracy did not improve from 0.72824
# 701/701 [==============================] - 1152s 2s/step - loss: 0.0136 - accuracy: 0.9978 - top5_acc: 1.0000 - macro_f1score: 0.4726 - val_loss: 1.2924 - val_accuracy: 0.7275 - val_top5_acc: 0.9235 - val_macro_f1score: 0.3324
# Learning rate:  1e-05
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 27/30
# 701/701 [==============================] - ETA: 0s - loss: 0.0119 - accuracy: 0.9981 - top5_acc: 1.0000 - macro_f1score: 0.4742
# Epoch 00027: val_loss did not improve from 1.10218
#
# Epoch 00027: val_accuracy did not improve from 0.72824
# 701/701 [==============================] - 1144s 2s/step - loss: 0.0119 - accuracy: 0.9981 - top5_acc: 1.0000 - macro_f1score: 0.4742 - val_loss: 1.2835 - val_accuracy: 0.7277 - val_top5_acc: 0.9239 - val_macro_f1score: 0.3333
# Learning rate:  1e-05
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 28/30
# 701/701 [==============================] - ETA: 0s - loss: 0.0117 - accuracy: 0.9979 - top5_acc: 1.0000 - macro_f1score: 0.4737
# Epoch 00028: val_loss did not improve from 1.10218
#
# Epoch 00028: val_accuracy improved from 0.72824 to 0.72923, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SUB/Inception_v4/028.h5
# 701/701 [==============================] - 1158s 2s/step - loss: 0.0117 - accuracy: 0.9979 - top5_acc: 1.0000 - macro_f1score: 0.4737 - val_loss: 1.2885 - val_accuracy: 0.7292 - val_top5_acc: 0.9241 - val_macro_f1score: 0.3375
# Learning rate:  1e-05
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 29/30
# 701/701 [==============================] - ETA: 0s - loss: 0.0095 - accuracy: 0.9987 - top5_acc: 1.0000 - macro_f1score: 0.4751
# Epoch 00029: val_loss did not improve from 1.10218
#
# Epoch 00029: val_accuracy improved from 0.72923 to 0.73042, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CIFAR100/No_GAN/model_output/1/SUB/Inception_v4/029.h5
# 701/701 [==============================] - 1164s 2s/step - loss: 0.0095 - accuracy: 0.9987 - top5_acc: 1.0000 - macro_f1score: 0.4751 - val_loss: 1.2857 - val_accuracy: 0.7304 - val_top5_acc: 0.9244 - val_macro_f1score: 0.3327
# Learning rate:  1e-05
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 30/30
# 701/701 [==============================] - ETA: 0s - loss: 0.0080 - accuracy: 0.9990 - top5_acc: 1.0000 - macro_f1score: 0.4733
# Epoch 00030: val_loss did not improve from 1.10218
#
# Epoch 00030: val_accuracy did not improve from 0.73042
# 701/701 [==============================] - 1165s 2s/step - loss: 0.0080 - accuracy: 0.9990 - top5_acc: 1.0000 - macro_f1score: 0.4733 - val_loss: 1.2943 - val_accuracy: 0.7288 - val_top5_acc: 0.9233 - val_macro_f1score: 0.3365

# %% [markdown]
# ### 3) Inception-V4 Evaluate

# %%
# 1. epoch=maximum
loss , acc, top5_acc, mf1 = model.evaluate(test_generator,steps=int(len(x_test)/batch_sizes))
print('[Test Loss: %.4f /  Test Top-1 Accuracy: %.4f / Test Top-5 Accuracy: %.4f / Test Macro f1: %.4f]\n' % (loss,acc,top5_acc,mf1))
# Out:
# 156/156 [==============================] - 5518s 35s/step - loss: 1.3040 - accuracy: 0.7324 - top5_acc: 0.9225 - macro_f1score: 0.3412
# [Test Loss: 1.3040 /  Test Top-1 Accuracy: 0.7324 / Test Top-5 Accuracy: 0.9225 / Test Macro f1: 0.3412]

# %%
loss=history.history['loss']
val_loss=history.history['val_loss']
acc=history.history['accuracy']
val_acc=history.history['val_accuracy']
top5_acc=history.history['top5_acc']
val_top5_acc=history.history['val_top5_acc']
f1=history.history['macro_f1score']
val_f1=history.history['val_macro_f1score']
epochs=range(1,len(acc)+1)

data = np.array([epochs,loss,val_loss,acc,val_acc,top5_acc,val_top5_acc,f1,val_f1]).T

# %%
# data save
# epochs, loss, val_loss, acc, val_acc, top5_acc, val_top5_acc, f1, val_f1

np.savetxt(os.path.join(dir,'train_valid_output',number,model.name+'.txt'),data)

# %%
# data import
data = np.loadtxt(os.path.join(dir,'train_valid_output',number,'Inception_v4.txt'))

# %%
epochs=data[:,0]
loss=data[:,1]
val_loss=data[:,2]
acc=data[:,3]
val_acc=data[:,4]
top5_acc=data[:,5]
val_top5_acc=data[:,6]

# %%
plt.plot(epochs[1:],acc[1:],'b',label='Training 1-Acc')
plt.plot(epochs[1:],val_acc[1:],'r',label='Validation 1-Acc')
plt.title('Training and Validation Top-1 Accuracy')
plt.legend()
plt.figure()

plt.plot(epochs[1:],top5_acc[1:],'b',label='Training 5-Acc')
plt.plot(epochs[1:],val_top5_acc[1:],'r',label='Validation 5-Acc')
plt.title('Training and Validation Top-5 Accuracy')
plt.legend()
plt.figure()

plt.plot(epochs[10:],loss[10:],'b',label='Training Loss')
plt.plot(epochs[10:],val_loss[10:],'r',label='Validation Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()

# %%
# 이 아래는 내가 인위적으로 살펴보고 싶은 epoch에 대해서 결과값 출력 / Inception-V4

# %%
# 참고 : https://github.com/OverLordGoldDragon/keras-adamw

import sys
sys.path.append('/content/drive/My Drive/Colab Notebooks/Paper')
import utils
import optimizers_v2
from utils import get_weight_decays, fill_dict_in_order
from utils import reset_seeds, K_eval
from optimizers_v2 import AdamW, NadamW, SGDW

# %%
# top-5 accuracy 출력
import functools
top5_acc = functools.partial(ks.metrics.top_k_categorical_accuracy, k=5)
top5_acc.__name__ = 'top5_acc'

# %%
model=load_model(os.path.join(dir,'model_output',number,'SUB','Inception_v4','029.h5'),custom_objects={"macro_f1score": macro_f1score,"top5_acc":top5_acc, "AdamW":AdamW})

# %%
# 2. epoch=?
loss , acc, top5_acc, mf1 = model.evaluate(test_generator,steps=int(len(x_test)/batch_sizes))
print('[Test Loss: %.4f /  Test Top-1 Accuracy: %.4f / Test Top-5 Accuracy: %.4f / Test Macro f1: %.4f]\n' % (loss,acc,top5_acc,mf1))
# Out:
# 156/156 [==============================] - 4897s 31s/step - loss: 1.3048 - accuracy: 0.7308 - top5_acc: 0.9226 - macro_f1score: 0.3356
# [Test Loss: 1.3048 /  Test Top-1 Accuracy: 0.7308 / Test Top-5 Accuracy: 0.9226 / Test Macro f1: 0.3356]
