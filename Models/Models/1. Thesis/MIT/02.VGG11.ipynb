# %% [markdown]
# # [VGG11]

# %% [markdown]
# *KU LeeDongGyu*

# %% [markdown]
# ### Contents

# %% [markdown]
# 1. Data Preprocessing
# ```
# 1) Data Import
# 2) Data Augmentation
# ```
# 2. Support Functions
#
# 3. Almost Original VGG11
# ```
# 1) Almost Original VGG11
# 2) VGG11 Evaluate
# ```

# %% [markdown]
# ### Install Packages

# %% [markdown]
# ### Module

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/My Drive/Colab Notebooks/Paper
# Out:
# /content/drive/My Drive/Colab Notebooks/Paper

# %%
from f1score import macro_f1score,weighted_f1score

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import cv2
import tensorflow as tf
from tensorflow import keras as ks
from tensorflow.keras import backend as K 
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, Input, Concatenate, ZeroPadding2D ,GlobalMaxPooling2D, Reshape , Lambda , Add, Multiply
from tensorflow.keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D, Activation, BatchNormalization, AveragePooling2D , ZeroPadding2D, SeparableConv2D
from tensorflow.keras.layers import add
from tensorflow.keras.optimizers import Adam, RMSprop , SGD
from tensorflow.keras.callbacks import EarlyStopping , LearningRateScheduler, ModelCheckpoint, CSVLogger, Callback, ReduceLROnPlateau
from tensorflow.keras.regularizers import l1,l2,l1_l2
from tensorflow.keras.models import Model , load_model , Sequential
from tensorflow.keras.utils import plot_model , to_categorical, get_file
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
os.getcwd()
# Out:
# '/content/drive/My Drive/Colab Notebooks/Paper'

# %%
print(tf.__version__)
print(ks.__version__)
# Out:
# 2.3.0
# 2.4.0

# %%
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 9983088751644453261
# , name: "/device:XLA_CPU:0"
# device_type: "XLA_CPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 502004218930494074
# physical_device_desc: "device: XLA_CPU device"
# , name: "/device:XLA_GPU:0"
# device_type: "XLA_GPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 8575710888198215600
# physical_device_desc: "device: XLA_GPU device"
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 15695549568
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 14672521183297424585
# physical_device_desc: "device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0"
# ]

# %% [markdown]
# ## 1. Data Preprocessing
# ---

# %% [markdown]
# ### 1) Data Import

# %%
# 바꿔서 살펴 볼 것들
# CALTECH, CIFAR100, FER, MIT
data_name = 'MIT'
gan_type = 'No_GAN'
number = '1'
size = 224 # sizes after cropping
super_size = 256 # sizes before cropping 
input_sizes = (size,size,3)
batch_sizes = 128
weight_decay = 1e-4
epochs = 70

# %%
# 참고 : https://stackoverflow.com/questions/32419510/how-to-get-reproducible-results-in-keras/52897216#52897216
# setting the seed number for random number generation for reproducibility.

from numpy.random import seed
import random


if number=='1':
    seed_num = 200225
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)
elif number=='2':
    seed_num = 727
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)
elif number=='3':
    seed_num = 115
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)
elif number=='4':
    seed_num = 501
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)
elif number=='5':
    seed_num = 517
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)

# %%
# data import

if data_name=='FER' :
    x_train =  np.zeros(28698)
    x_valid = np.zeros(3589)
    x_test = np.zeros(3588)
    classes = 7 
    tr_center = [0.50793296, 0.50793296, 0.50793296]
elif data_name=='MIT':
    x_train = np.zeros(12466)
    x_valid = np.zeros(1564)
    x_test = np.zeros(1590)
    classes = 67 
    tr_center = [0.47916578, 0.42029615, 0.36046057]
elif data_name=='CALTECH':
    x_train = np.zeros(24510)
    x_valid = np.zeros(2980)
    x_test = np.zeros(3118)
    classes = 257
    tr_center = [0.51397761, 0.49525248, 0.46555727]
elif data_name=='CIFAR100':
    x_train = np.zeros(44923)
    x_valid = np.zeros(5077)
    x_test = np.zeros(10000)
    classes = 100
    tr_center = [0.53442983, 0.51355958, 0.46462564]

# %%
dir = os.path.join(os.getcwd(),data_name,gan_type)

# %% [markdown]
# ### 2) Data Augmentation

# %%
# 참고 : https://jkjung-avt.github.io/keras-image-cropping/

def random_crop(img, random_crop_size):
    # Note: image_data_format is 'channel_last'
    assert img.shape[2] == 3 # img.shape[2] 가 3(rgb)이 아니면 assertion error 발생
    height, width = img.shape[0], img.shape[1]
    dy, dx = random_crop_size
    x = np.random.randint(0, width - dx + 1)
    y = np.random.randint(0, height - dy + 1)
    return img[y:(y+dy), x:(x+dx), :]


def crop_generator(batches, crop_length):
    """Take as input a Keras ImageGen (Iterator) and generate random
    crops from the image batches generated by the original iterator.
    """
    while True:
        batch_x, batch_y = next(batches)
        batch_crops = np.zeros((batch_x.shape[0], crop_length, crop_length, 3))
        for i in range(batch_x.shape[0]):
            batch_crops[i] = random_crop(batch_x[i], (crop_length, crop_length))
        yield (batch_crops, batch_y)

# %%
from tensorflow.keras.preprocessing.image import img_to_array,load_img
import glob

# 데이터 전체에 대해 centering 진행함.

def read_cal_image(img_path): 
    x = img_to_array(load_img(img_path)) # x는 채널별 평균값
    y = x.shape[0] * x.shape[1]# y는 데이터별 픽셀 수 (비중)

    x = 1/255. * x # scaling하고, centering값을 뽑아냄.
    x = np.mean(x, axis=(0,1))
    
    return np.hstack([x,y])

def calculate_centered_mean(dataset_path,x_train=x_train):
    num = len(x_train)
    space = np.empty((num,4))
    i=0

    for p in glob.glob(os.path.join(dataset_path,'*/*.*')) :
        space[i] = read_cal_image(p)
        i += 1

    ratio = space[:,3] / np.sum(space[:,3])

    return np.average(space[:,0:3],axis=0,weights=ratio)


# 아래의 함수를 돌려서 나온 결과값을 중심화 값으로 설정.

# train_mean = calculate_centered_mean(os.path.join(dir,'data/train')).reshape((1,1,3))

# %%
datagen_tr = ImageDataGenerator(
    rescale=1/255.,
    horizontal_flip=True,
    featurewise_center=True,
    featurewise_std_normalization=False,
    rotation_range=10,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=[0.9,1.0],
    fill_mode = 'nearest')
datagen_val = ImageDataGenerator(rescale=1/255.,featurewise_center=True)
datagen_tes = ImageDataGenerator(rescale=1/255.,featurewise_center=True)

# 원래는 이 자리에 fit 매서드를 써야하지만, 그냥 내가 중심화함수를 만들고 적용함. 

# 중심화 설정
datagen_tr.mean = np.array(tr_center, dtype=np.float32).reshape((1,1,3)) # RGB
datagen_val.mean = np.array(tr_center, dtype=np.float32).reshape((1,1,3)) # RGB
datagen_tes.mean = np.array(tr_center, dtype=np.float32).reshape((1,1,3)) # RGB

# %%
train_batches = datagen_tr.flow_from_directory(directory=os.path.join(dir,'data/train'),target_size=(super_size,super_size),batch_size=batch_sizes,class_mode='categorical') # fer : 28698 / mit : 12466 / caltech : 24509 / cifar : 44923
train_generator= crop_generator(train_batches, size)
valid_generator = datagen_val.flow_from_directory(directory=os.path.join(dir,'data/valid'),target_size=(size,size),batch_size=batch_sizes,class_mode='categorical') # fer : 3589 / mit : 1564 / caltech : 2980 / cifar : 5077
test_generator = datagen_tes.flow_from_directory(directory=os.path.join(dir,'data/test'),target_size=(size,size),batch_size=batch_sizes,class_mode='categorical') # fer : 3588 / mit : 1590 / caltech : 3118 / cifar : 10000
# Out:
# Found 12466 images belonging to 67 classes.
# Found 1564 images belonging to 67 classes.
# Found 1590 images belonging to 67 classes.

# %% [markdown]
# ## 2. Support Functions
# ---

# %%
# def lr_schedule(epoch):
#     init_lr = 1e-4
#     k = 0.04
#     lr = init_lr * np.exp(-k*epoch)
#     print('Learning rate: ', lr)
#     return lr

def lr_schedule(epoch):
    lr = 3e-4
    if epoch < 30:
        lr = lr
    elif epoch < 60 :
        lr = lr * 0.1
    else:
        lr = lr * 0.01
    print('Learning rate: ', lr)
    return lr

# %% [markdown]
# ## 3. Almost Original VGG11
# ---

# %% [markdown]
# ### 1) Almost Original VGG11

# %%
# VGG11를 최대한 논문에 가깝게 맞춰 모형작성.

def VGG11(input_shape=(224, 224, 3), classes=1000, weight_decay=weight_decay, name='VGG11'):

    img_input = Input(shape=input_shape)

    # Block 1
    x = Conv2D(64, (3, 3), activation='relu', padding='same', name='block1_conv1', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(img_input)
    x = MaxPooling2D((2, 2), strides=(2, 2), name='block1_pool')(x)

    # Block 2
    x = Conv2D(128, (3, 3), activation='relu', padding='same', name='block2_conv1', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(x)
    x = MaxPooling2D((2, 2), strides=(2, 2), name='block2_pool')(x)

    # Block 3
    x = Conv2D(256, (3, 3), activation='relu', padding='same', name='block3_conv1', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(x)
    x = Conv2D(256, (3, 3), activation='relu', padding='same', name='block3_conv2', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(x)
    x = MaxPooling2D((2, 2), strides=(2, 2), name='block3_pool')(x)

    # Block 4
    x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block4_conv1', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(x)
    x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block4_conv2', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(x)
    x = MaxPooling2D((2, 2), strides=(2, 2), name='block4_pool')(x)

    # Block 5
    x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block5_conv1', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(x)
    x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block5_conv2', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(x)
    x = MaxPooling2D((2, 2), strides=(2, 2), name='block5_pool')(x)

    # Classification block
    x = Flatten(name='flatten')(x)
    x = Dense(4096, activation='relu', name='fc1', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(x)
    x = Dropout(0.5)(x)
    x = Dense(4096, activation='relu', name='fc2', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(x)
    x = Dropout(0.5)(x)
    output = Dense(classes, activation='softmax', kernel_regularizer=l2(weight_decay), name='predictions')(x)

    # Create model.
    model = Model(img_input, output, name=name)

    return model

# %%
model = VGG11(input_shape=input_sizes, classes=classes, name='VGG11')

# %%
model.summary()
# Out:
# Model: "VGG11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# fc1 (Dense)                  (None, 4096)              102764544
# _________________________________________________________________
# dropout (Dropout)            (None, 4096)              0
# _________________________________________________________________
# fc2 (Dense)                  (None, 4096)              16781312
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 4096)              0
# _________________________________________________________________
# predictions (Dense)          (None, 67)                274499
# =================================================================
# Total params: 129,040,835
# Trainable params: 129,040,835
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 폴더 생성

os.makedirs(os.path.join(dir,'model_output',number,model.name), exist_ok=True)
os.makedirs(os.path.join(dir,'train_valid_output',number), exist_ok=True)

# %%
# 참고 : https://github.com/OverLordGoldDragon/keras-adamw

import sys
sys.path.append('/content/drive/My Drive/Colab Notebooks/Paper')
import utils
import optimizers_v2
from utils import get_weight_decays, fill_dict_in_order
from utils import reset_seeds, K_eval
from optimizers_v2 import AdamW, NadamW, SGDW

# %%
# top-5 accuracy 출력
import functools
top5_acc = functools.partial(ks.metrics.top_k_categorical_accuracy, k=5)
top5_acc.__name__ = 'top5_acc'

# %%
#optimizer = SGDW(model=model, use_cosine_annealing=False, total_iterations = len(x_train) // batch_sizes, nesterov=True, momentum=0.9)
optimizer = AdamW(model=model, use_cosine_annealing=False, total_iterations = len(x_train) // batch_sizes)
#optimizer = Adam()
filepath =  os.path.join(dir,'model_output',number,model.name,'{epoch:03d}.h5')

callbacks_list = [ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_weights_only=False, save_best_only=True, mode='min'),
                  ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_weights_only=False, save_best_only=True, mode='max'),
                  #ReduceLROnPlateau(monitor='val_loss',patience=3,factor=0.1,min_lr=1e-5),
                  LearningRateScheduler(lr_schedule,verbose=1)
                  ]
                  
model.compile(optimizer, loss = 'categorical_crossentropy', metrics=['accuracy',top5_acc,macro_f1score])

# %%
######## flow_from_directory
history = model.fit(train_generator, steps_per_epoch=int(len(x_train)/batch_sizes),  validation_data = valid_generator, epochs=epochs , verbose=1 , callbacks = callbacks_list , validation_steps=int(len(x_valid)/batch_sizes))
# Out:
# Learning rate:  0.0003
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 1/70
# 0.0(L1), 1.0153461394838174e-05(L2) weight decay set for block1_conv1/kernel:0
# 0.0(L1), 1.0153461394838174e-05(L2) weight decay set for block2_conv1/kernel:0
# 0.0(L1), 1.0153461394838174e-05(L2) weight decay set for block3_conv1/kernel:0
# 0.0(L1), 1.0153461394838174e-05(L2) weight decay set for block3_conv2/kernel:0
# 0.0(L1), 1.0153461394838174e-05(L2) weight decay set for block4_conv1/kernel:0
# 0.0(L1), 1.0153461394838174e-05(L2) weight decay set for block4_conv2/kernel:0
# 0.0(L1), 1.0153461394838174e-05(L2) weight decay set for block5_conv1/kernel:0
# 0.0(L1), 1.0153461394838174e-05(L2) weight decay set for block5_conv2/kernel:0
# 0.0(L1), 1.0153461394838174e-05(L2) weight decay set for fc1/kernel:0
# 0.0(L1), 1.0153461394838174e-05(L2) weight decay set for fc2/kernel:0
# 0.0(L1), 1.0153461394838174e-05(L2) weight decay set for predictions/kernel:0
# 97/97 [==============================] - ETA: 0s - loss: 3.9897 - accuracy: 0.0611 - top5_acc: 0.2373 - macro_f1score: 1.3988e-05
# Epoch 00001: val_loss improved from inf to 3.81704, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/VGG11/001.h5
#
# Epoch 00001: val_accuracy improved from -inf to 0.09440, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/VGG11/001.h5
# 97/97 [==============================] - 3482s 36s/step - loss: 3.9897 - accuracy: 0.0611 - top5_acc: 0.2373 - macro_f1score: 1.3988e-05 - val_loss: 3.8170 - val_accuracy: 0.0944 - val_top5_acc: 0.2793 - val_macro_f1score: 0.0000e+00
# Learning rate:  0.0003
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 2/70
# 97/97 [==============================] - ETA: 0s - loss: 3.7235 - accuracy: 0.0916 - top5_acc: 0.3237 - macro_f1score: 3.6965e-04
# Epoch 00002: val_loss did not improve from 3.81704
#
# Epoch 00002: val_accuracy did not improve from 0.09440
# 97/97 [==============================] - 246s 3s/step - loss: 3.7235 - accuracy: 0.0916 - top5_acc: 0.3237 - macro_f1score: 3.6965e-04 - val_loss: 3.8428 - val_accuracy: 0.0814 - val_top5_acc: 0.2917 - val_macro_f1score: 0.0041
# Learning rate:  0.0003
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 3/70
# 97/97 [==============================] - ETA: 0s - loss: 3.5295 - accuracy: 0.1220 - top5_acc: 0.3869 - macro_f1score: 0.0027
# Epoch 00003: val_loss improved from 3.81704 to 3.59704, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/VGG11/003.h5
#
# Epoch 00003: val_accuracy improved from 0.09440 to 0.12565, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/VGG11/003.h5
# 97/97 [==============================] - 266s 3s/step - loss: 3.5295 - accuracy: 0.1220 - top5_acc: 0.3869 - macro_f1score: 0.0027 - val_loss: 3.5970 - val_accuracy: 0.1257 - val_top5_acc: 0.3776 - val_macro_f1score: 0.0045
# Learning rate:  0.0003
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 4/70
# 97/97 [==============================] - ETA: 0s - loss: 3.3744 - accuracy: 0.1493 - top5_acc: 0.4326 - macro_f1score: 0.0071
# Epoch 00004: val_loss did not improve from 3.59704
#
# Epoch 00004: val_accuracy improved from 0.12565 to 0.14714, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/VGG11/004.h5
# 97/97 [==============================] - 249s 3s/step - loss: 3.3744 - accuracy: 0.1493 - top5_acc: 0.4326 - macro_f1score: 0.0071 - val_loss: 3.5992 - val_accuracy: 0.1471 - val_top5_acc: 0.3867 - val_macro_f1score: 0.0124
# Learning rate:  0.0003
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 5/70
# 97/97 [==============================] - ETA: 0s - loss: 3.2322 - accuracy: 0.1748 - top5_acc: 0.4755 - macro_f1score: 0.0147
# Epoch 00005: val_loss improved from 3.59704 to 3.11978, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/VGG11/005.h5
#
# Epoch 00005: val_accuracy improved from 0.14714 to 0.19792, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/VGG11/005.h5
# 97/97 [==============================] - 264s 3s/step - loss: 3.2322 - accuracy: 0.1748 - top5_acc: 0.4755 - macro_f1score: 0.0147 - val_loss: 3.1198 - val_accuracy: 0.1979 - val_top5_acc: 0.4987 - val_macro_f1score: 0.0189
# Learning rate:  0.0003
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 6/70
# 97/97 [==============================] - ETA: 0s - loss: 3.1066 - accuracy: 0.2024 - top5_acc: 0.5096 - macro_f1score: 0.0226
# Epoch 00006: val_loss improved from 3.11978 to 2.96521, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/VGG11/006.h5
#
# Epoch 00006: val_accuracy improved from 0.19792 to 0.23242, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/VGG11/006.h5
# 97/97 [==============================] - 263s 3s/step - loss: 3.1066 - accuracy: 0.2024 - top5_acc: 0.5096 - macro_f1score: 0.0226 - val_loss: 2.9652 - val_accuracy: 0.2324 - val_top5_acc: 0.5586 - val_macro_f1score: 0.0271
# Learning rate:  0.0003
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 7/70
# 97/97 [==============================] - ETA: 0s - loss: 2.9977 - accuracy: 0.2231 - top5_acc: 0.5444 - macro_f1score: 0.0319
# Epoch 00007: val_loss improved from 2.96521 to 2.92834, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/VGG11/007.h5
#
# Epoch 00007: val_accuracy improved from 0.23242 to 0.25260, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/VGG11/007.h5
# 97/97 [==============================] - 268s 3s/step - loss: 2.9977 - accuracy: 0.2231 - top5_acc: 0.5444 - macro_f1score: 0.0319 - val_loss: 2.9283 - val_accuracy: 0.2526 - val_top5_acc: 0.5573 - val_macro_f1score: 0.0592
# Learning rate:  0.0003
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 8/70
# 97/97 [==============================] - ETA: 0s - loss: 2.8651 - accuracy: 0.2543 - top5_acc: 0.5798 - macro_f1score: 0.0439
# Epoch 00008: val_loss improved from 2.92834 to 2.85781, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/VGG11/008.h5
#
# Epoch 00008: val_accuracy improved from 0.25260 to 0.26107, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/VGG11/008.h5
# 97/97 [==============================] - 271s 3s/step - loss: 2.8651 - accuracy: 0.2543 - top5_acc: 0.5798 - macro_f1score: 0.0439 - val_loss: 2.8578 - val_accuracy: 0.2611 - val_top5_acc: 0.5710 - val_macro_f1score: 0.0694
# Learning rate:  0.0003
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 9/70
# 97/97 [==============================] - ETA: 0s - loss: 2.7185 - accuracy: 0.2864 - top5_acc: 0.6179 - macro_f1score: 0.0619
# Epoch 00009: val_loss improved from 2.85781 to 2.68419, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/VGG11/009.h5
#
# Epoch 00009: val_accuracy improved from 0.26107 to 0.29753, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/VGG11/009.h5
# 97/97 [==============================] - 267s 3s/step - loss: 2.7185 - accuracy: 0.2864 - top5_acc: 0.6179 - macro_f1score: 0.0619 - val_loss: 2.6842 - val_accuracy: 0.2975 - val_top5_acc: 0.6133 - val_macro_f1score: 0.0689
# Learning rate:  0.0003
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 10/70
# 97/97 [==============================] - ETA: 0s - loss: 2.5847 - accuracy: 0.3129 - top5_acc: 0.6544 - macro_f1score: 0.0785
# Epoch 00010: val_loss improved from 2.68419 to 2.50274, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/VGG11/010.h5
#
# Epoch 00010: val_accuracy improved from 0.29753 to 0.33724, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/VGG11/010.h5
# 97/97 [==============================] - 266s 3s/step - loss: 2.5847 - accuracy: 0.3129 - top5_acc: 0.6544 - macro_f1score: 0.0785 - val_loss: 2.5027 - val_accuracy: 0.3372 - val_top5_acc: 0.6615 - val_macro_f1score: 0.1099
# Learning rate:  0.0003
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 11/70
# 97/97 [==============================] - ETA: 0s - loss: 2.4491 - accuracy: 0.3478 - top5_acc: 0.6800 - macro_f1score: 0.1060
# Epoch 00011: val_loss improved from 2.50274 to 2.41035, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/VGG11/011.h5
#
# Epoch 00011: val_accuracy improved from 0.33724 to 0.36719, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/VGG11/011.h5
# 97/97 [==============================] - 274s 3s/step - loss: 2.4491 - accuracy: 0.3478 - top5_acc: 0.6800 - macro_f1score: 0.1060 - val_loss: 2.4104 - val_accuracy: 0.3672 - val_top5_acc: 0.6901 - val_macro_f1score: 0.1323
# Learning rate:  0.0003
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 12/70
# 97/97 [==============================] - ETA: 0s - loss: 2.3346 - accuracy: 0.3702 - top5_acc: 0.7077 - macro_f1score: 0.1272
# Epoch 00012: val_loss improved from 2.41035 to 2.32293, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/VGG11/012.h5
#
# Epoch 00012: val_accuracy did not improve from 0.36719
# 97/97 [==============================] - 260s 3s/step - loss: 2.3346 - accuracy: 0.3702 - top5_acc: 0.7077 - macro_f1score: 0.1272 - val_loss: 2.3229 - val_accuracy: 0.3672 - val_top5_acc: 0.6973 - val_macro_f1score: 0.1386
# Learning rate:  0.0003
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 13/70
# 97/97 [==============================] - ETA: 0s - loss: 2.2087 - accuracy: 0.3993 - top5_acc: 0.7303 - macro_f1score: 0.1494
# Epoch 00013: val_loss did not improve from 2.32293
#
# Epoch 00013: val_accuracy improved from 0.36719 to 0.38021, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/VGG11/013.h5
# 97/97 [==============================] - 249s 3s/step - loss: 2.2087 - accuracy: 0.3993 - top5_acc: 0.7303 - macro_f1score: 0.1494 - val_loss: 2.4206 - val_accuracy: 0.3802 - val_top5_acc: 0.6986 - val_macro_f1score: 0.1523
# Learning rate:  0.0003
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 14/70
# 97/97 [==============================] - ETA: 0s - loss: 2.1116 - accuracy: 0.4275 - top5_acc: 0.7519 - macro_f1score: 0.1713
# Epoch 00014: val_loss improved from 2.32293 to 2.18754, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/VGG11/014.h5
#
# Epoch 00014: val_accuracy improved from 0.38021 to 0.41602, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/VGG11/014.h5
# 97/97 [==============================] - 277s 3s/step - loss: 2.1116 - accuracy: 0.4275 - top5_acc: 0.7519 - macro_f1score: 0.1713 - val_loss: 2.1875 - val_accuracy: 0.4160 - val_top5_acc: 0.7454 - val_macro_f1score: 0.1878
# Learning rate:  0.0003
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 15/70
# 97/97 [==============================] - ETA: 0s - loss: 1.9586 - accuracy: 0.4576 - top5_acc: 0.7849 - macro_f1score: 0.1980
# Epoch 00015: val_loss improved from 2.18754 to 2.09446, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/VGG11/015.h5
#
# Epoch 00015: val_accuracy improved from 0.41602 to 0.43945, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/VGG11/015.h5
# 97/97 [==============================] - 272s 3s/step - loss: 1.9586 - accuracy: 0.4576 - top5_acc: 0.7849 - macro_f1score: 0.1980 - val_loss: 2.0945 - val_accuracy: 0.4395 - val_top5_acc: 0.7604 - val_macro_f1score: 0.2020
# Learning rate:  0.0003
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 16/70
# 97/97 [==============================] - ETA: 0s - loss: 1.8738 - accuracy: 0.4789 - top5_acc: 0.7986 - macro_f1score: 0.2222
# Epoch 00016: val_loss did not improve from 2.09446
#
# Epoch 00016: val_accuracy did not improve from 0.43945
# 97/97 [==============================] - 247s 3s/step - loss: 1.8738 - accuracy: 0.4789 - top5_acc: 0.7986 - macro_f1score: 0.2222 - val_loss: 2.1616 - val_accuracy: 0.4193 - val_top5_acc: 0.7448 - val_macro_f1score: 0.2086
# Learning rate:  0.0003
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 17/70
# 97/97 [==============================] - ETA: 0s - loss: 1.7658 - accuracy: 0.5070 - top5_acc: 0.8210 - macro_f1score: 0.2474
# Epoch 00017: val_loss did not improve from 2.09446
#
# Epoch 00017: val_accuracy did not improve from 0.43945
# 97/97 [==============================] - 243s 3s/step - loss: 1.7658 - accuracy: 0.5070 - top5_acc: 0.8210 - macro_f1score: 0.2474 - val_loss: 2.2014 - val_accuracy: 0.4173 - val_top5_acc: 0.7409 - val_macro_f1score: 0.2007
# Learning rate:  0.0003
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 18/70
# 97/97 [==============================] - ETA: 0s - loss: 1.6717 - accuracy: 0.5323 - top5_acc: 0.8351 - macro_f1score: 0.2689
# Epoch 00018: val_loss did not improve from 2.09446
#
# Epoch 00018: val_accuracy improved from 0.43945 to 0.44010, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/VGG11/018.h5
# 97/97 [==============================] - 247s 3s/step - loss: 1.6717 - accuracy: 0.5323 - top5_acc: 0.8351 - macro_f1score: 0.2689 - val_loss: 2.1441 - val_accuracy: 0.4401 - val_top5_acc: 0.7480 - val_macro_f1score: 0.2380
# Learning rate:  0.0003
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 19/70
# 97/97 [==============================] - ETA: 0s - loss: 1.5547 - accuracy: 0.5570 - top5_acc: 0.8559 - macro_f1score: 0.3006
# Epoch 00019: val_loss did not improve from 2.09446
#
# Epoch 00019: val_accuracy improved from 0.44010 to 0.45117, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/VGG11/019.h5
# 97/97 [==============================] - 251s 3s/step - loss: 1.5547 - accuracy: 0.5570 - top5_acc: 0.8559 - macro_f1score: 0.3006 - val_loss: 2.1070 - val_accuracy: 0.4512 - val_top5_acc: 0.7715 - val_macro_f1score: 0.2251
# Learning rate:  0.0003
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 20/70
# 97/97 [==============================] - ETA: 0s - loss: 1.4582 - accuracy: 0.5818 - top5_acc: 0.8717 - macro_f1score: 0.3227
# Epoch 00020: val_loss improved from 2.09446 to 2.06693, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/VGG11/020.h5
#
# Epoch 00020: val_accuracy improved from 0.45117 to 0.46354, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/VGG11/020.h5
# 97/97 [==============================] - 268s 3s/step - loss: 1.4582 - accuracy: 0.5818 - top5_acc: 0.8717 - macro_f1score: 0.3227 - val_loss: 2.0669 - val_accuracy: 0.4635 - val_top5_acc: 0.7826 - val_macro_f1score: 0.2491
# Learning rate:  0.0003
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 21/70
# 97/97 [==============================] - ETA: 0s - loss: 1.3952 - accuracy: 0.6072 - top5_acc: 0.8791 - macro_f1score: 0.3377
# Epoch 00021: val_loss did not improve from 2.06693
#
# Epoch 00021: val_accuracy did not improve from 0.46354
# 97/97 [==============================] - 244s 3s/step - loss: 1.3952 - accuracy: 0.6072 - top5_acc: 0.8791 - macro_f1score: 0.3377 - val_loss: 2.1201 - val_accuracy: 0.4635 - val_top5_acc: 0.7760 - val_macro_f1score: 0.2613
# Learning rate:  0.0003
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 22/70
# 97/97 [==============================] - ETA: 0s - loss: 1.2945 - accuracy: 0.6301 - top5_acc: 0.8961 - macro_f1score: 0.3759
# Epoch 00022: val_loss improved from 2.06693 to 1.97272, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/VGG11/022.h5
#
# Epoch 00022: val_accuracy improved from 0.46354 to 0.50130, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/VGG11/022.h5
# 97/97 [==============================] - 261s 3s/step - loss: 1.2945 - accuracy: 0.6301 - top5_acc: 0.8961 - macro_f1score: 0.3759 - val_loss: 1.9727 - val_accuracy: 0.5013 - val_top5_acc: 0.8021 - val_macro_f1score: 0.2645
# Learning rate:  0.0003
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 23/70
# 97/97 [==============================] - ETA: 0s - loss: 1.2046 - accuracy: 0.6512 - top5_acc: 0.9063 - macro_f1score: 0.3869
# Epoch 00023: val_loss did not improve from 1.97272
#
# Epoch 00023: val_accuracy did not improve from 0.50130
# 97/97 [==============================] - 244s 3s/step - loss: 1.2046 - accuracy: 0.6512 - top5_acc: 0.9063 - macro_f1score: 0.3869 - val_loss: 2.1625 - val_accuracy: 0.4766 - val_top5_acc: 0.7910 - val_macro_f1score: 0.2708
# Learning rate:  0.0003
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 24/70
# 97/97 [==============================] - ETA: 0s - loss: 1.1577 - accuracy: 0.6696 - top5_acc: 0.9173 - macro_f1score: 0.4086
# Epoch 00024: val_loss improved from 1.97272 to 1.93668, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/VGG11/024.h5
#
# Epoch 00024: val_accuracy improved from 0.50130 to 0.52930, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/VGG11/024.h5
# 97/97 [==============================] - 262s 3s/step - loss: 1.1577 - accuracy: 0.6696 - top5_acc: 0.9173 - macro_f1score: 0.4086 - val_loss: 1.9367 - val_accuracy: 0.5293 - val_top5_acc: 0.8079 - val_macro_f1score: 0.2939
# Learning rate:  0.0003
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 25/70
# 97/97 [==============================] - ETA: 0s - loss: 1.0775 - accuracy: 0.6853 - top5_acc: 0.9246 - macro_f1score: 0.4326
# Epoch 00025: val_loss did not improve from 1.93668
#
# Epoch 00025: val_accuracy did not improve from 0.52930
# 97/97 [==============================] - 245s 3s/step - loss: 1.0775 - accuracy: 0.6853 - top5_acc: 0.9246 - macro_f1score: 0.4326 - val_loss: 2.0035 - val_accuracy: 0.5241 - val_top5_acc: 0.8138 - val_macro_f1score: 0.3108
# Learning rate:  0.0003
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 26/70
# 97/97 [==============================] - ETA: 0s - loss: 1.0223 - accuracy: 0.7018 - top5_acc: 0.9316 - macro_f1score: 0.4370
# Epoch 00026: val_loss did not improve from 1.93668
#
# Epoch 00026: val_accuracy did not improve from 0.52930
# 97/97 [==============================] - 241s 2s/step - loss: 1.0223 - accuracy: 0.7018 - top5_acc: 0.9316 - macro_f1score: 0.4370 - val_loss: 1.9545 - val_accuracy: 0.5241 - val_top5_acc: 0.8216 - val_macro_f1score: 0.3055
# Learning rate:  0.0003
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 27/70
# 97/97 [==============================] - ETA: 0s - loss: 0.9222 - accuracy: 0.7304 - top5_acc: 0.9407 - macro_f1score: 0.4779
# Epoch 00027: val_loss did not improve from 1.93668
#
# Epoch 00027: val_accuracy did not improve from 0.52930
# 97/97 [==============================] - 241s 2s/step - loss: 0.9222 - accuracy: 0.7304 - top5_acc: 0.9407 - macro_f1score: 0.4779 - val_loss: 2.1656 - val_accuracy: 0.5007 - val_top5_acc: 0.7956 - val_macro_f1score: 0.2878
# Learning rate:  0.0003
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 28/70
# 97/97 [==============================] - ETA: 0s - loss: 0.8756 - accuracy: 0.7431 - top5_acc: 0.9466 - macro_f1score: 0.4863
# Epoch 00028: val_loss did not improve from 1.93668
#
# Epoch 00028: val_accuracy did not improve from 0.52930
# 97/97 [==============================] - 243s 3s/step - loss: 0.8756 - accuracy: 0.7431 - top5_acc: 0.9466 - macro_f1score: 0.4863 - val_loss: 2.0157 - val_accuracy: 0.5176 - val_top5_acc: 0.8105 - val_macro_f1score: 0.3120
# Learning rate:  0.0003
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 29/70
# 97/97 [==============================] - ETA: 0s - loss: 0.8288 - accuracy: 0.7578 - top5_acc: 0.9537 - macro_f1score: 0.4996
# Epoch 00029: val_loss did not improve from 1.93668
#
# Epoch 00029: val_accuracy did not improve from 0.52930
# 97/97 [==============================] - 241s 2s/step - loss: 0.8288 - accuracy: 0.7578 - top5_acc: 0.9537 - macro_f1score: 0.4996 - val_loss: 2.1709 - val_accuracy: 0.5098 - val_top5_acc: 0.8138 - val_macro_f1score: 0.3126
# Learning rate:  0.0003
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 30/70
# 97/97 [==============================] - ETA: 0s - loss: 0.7732 - accuracy: 0.7746 - top5_acc: 0.9575 - macro_f1score: 0.5154
# Epoch 00030: val_loss did not improve from 1.93668
#
# Epoch 00030: val_accuracy did not improve from 0.52930
# 97/97 [==============================] - 242s 2s/step - loss: 0.7732 - accuracy: 0.7746 - top5_acc: 0.9575 - macro_f1score: 0.5154 - val_loss: 2.2474 - val_accuracy: 0.4987 - val_top5_acc: 0.7975 - val_macro_f1score: 0.2975
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 31/70
# 97/97 [==============================] - ETA: 0s - loss: 0.5885 - accuracy: 0.8229 - top5_acc: 0.9725 - macro_f1score: 0.5678
# Epoch 00031: val_loss did not improve from 1.93668
#
# Epoch 00031: val_accuracy improved from 0.52930 to 0.53060, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/VGG11/031.h5
# 97/97 [==============================] - 254s 3s/step - loss: 0.5885 - accuracy: 0.8229 - top5_acc: 0.9725 - macro_f1score: 0.5678 - val_loss: 2.1325 - val_accuracy: 0.5306 - val_top5_acc: 0.8171 - val_macro_f1score: 0.3276
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 32/70
# 97/97 [==============================] - ETA: 0s - loss: 0.5001 - accuracy: 0.8513 - top5_acc: 0.9772 - macro_f1score: 0.5976
# Epoch 00032: val_loss did not improve from 1.93668
#
# Epoch 00032: val_accuracy improved from 0.53060 to 0.54362, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/VGG11/032.h5
# 97/97 [==============================] - 257s 3s/step - loss: 0.5001 - accuracy: 0.8513 - top5_acc: 0.9772 - macro_f1score: 0.5976 - val_loss: 2.1728 - val_accuracy: 0.5436 - val_top5_acc: 0.8275 - val_macro_f1score: 0.3517
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00033: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 33/70
# 97/97 [==============================] - ETA: 0s - loss: 0.4688 - accuracy: 0.8585 - top5_acc: 0.9803 - macro_f1score: 0.6069
# Epoch 00033: val_loss did not improve from 1.93668
#
# Epoch 00033: val_accuracy did not improve from 0.54362
# 97/97 [==============================] - 250s 3s/step - loss: 0.4688 - accuracy: 0.8585 - top5_acc: 0.9803 - macro_f1score: 0.6069 - val_loss: 2.2139 - val_accuracy: 0.5410 - val_top5_acc: 0.8255 - val_macro_f1score: 0.3424
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00034: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 34/70
# 97/97 [==============================] - ETA: 0s - loss: 0.4455 - accuracy: 0.8677 - top5_acc: 0.9819 - macro_f1score: 0.6148
# Epoch 00034: val_loss did not improve from 1.93668
#
# Epoch 00034: val_accuracy did not improve from 0.54362
# 97/97 [==============================] - 251s 3s/step - loss: 0.4455 - accuracy: 0.8677 - top5_acc: 0.9819 - macro_f1score: 0.6148 - val_loss: 2.2463 - val_accuracy: 0.5326 - val_top5_acc: 0.8255 - val_macro_f1score: 0.3323
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00035: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 35/70
# 97/97 [==============================] - ETA: 0s - loss: 0.4309 - accuracy: 0.8676 - top5_acc: 0.9831 - macro_f1score: 0.6174
# Epoch 00035: val_loss did not improve from 1.93668
#
# Epoch 00035: val_accuracy did not improve from 0.54362
# 97/97 [==============================] - 253s 3s/step - loss: 0.4309 - accuracy: 0.8676 - top5_acc: 0.9831 - macro_f1score: 0.6174 - val_loss: 2.2623 - val_accuracy: 0.5345 - val_top5_acc: 0.8177 - val_macro_f1score: 0.3420
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00036: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 36/70
# 97/97 [==============================] - ETA: 0s - loss: 0.4242 - accuracy: 0.8719 - top5_acc: 0.9838 - macro_f1score: 0.6214
# Epoch 00036: val_loss did not improve from 1.93668
#
# Epoch 00036: val_accuracy did not improve from 0.54362
# 97/97 [==============================] - 252s 3s/step - loss: 0.4242 - accuracy: 0.8719 - top5_acc: 0.9838 - macro_f1score: 0.6214 - val_loss: 2.2303 - val_accuracy: 0.5365 - val_top5_acc: 0.8275 - val_macro_f1score: 0.3375
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00037: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 37/70
# 97/97 [==============================] - ETA: 0s - loss: 0.4094 - accuracy: 0.8715 - top5_acc: 0.9849 - macro_f1score: 0.6220
# Epoch 00037: val_loss did not improve from 1.93668
#
# Epoch 00037: val_accuracy did not improve from 0.54362
# 97/97 [==============================] - 252s 3s/step - loss: 0.4094 - accuracy: 0.8715 - top5_acc: 0.9849 - macro_f1score: 0.6220 - val_loss: 2.2272 - val_accuracy: 0.5417 - val_top5_acc: 0.8320 - val_macro_f1score: 0.3532
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00038: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 38/70
# 97/97 [==============================] - ETA: 0s - loss: 0.3976 - accuracy: 0.8777 - top5_acc: 0.9848 - macro_f1score: 0.6337
# Epoch 00038: val_loss did not improve from 1.93668
#
# Epoch 00038: val_accuracy did not improve from 0.54362
# 97/97 [==============================] - 246s 3s/step - loss: 0.3976 - accuracy: 0.8777 - top5_acc: 0.9848 - macro_f1score: 0.6337 - val_loss: 2.3054 - val_accuracy: 0.5371 - val_top5_acc: 0.8255 - val_macro_f1score: 0.3394
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00039: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 39/70
# 97/97 [==============================] - ETA: 0s - loss: 0.3966 - accuracy: 0.8786 - top5_acc: 0.9857 - macro_f1score: 0.6279
# Epoch 00039: val_loss did not improve from 1.93668
#
# Epoch 00039: val_accuracy improved from 0.54362 to 0.54557, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/VGG11/039.h5
# 97/97 [==============================] - 257s 3s/step - loss: 0.3966 - accuracy: 0.8786 - top5_acc: 0.9857 - macro_f1score: 0.6279 - val_loss: 2.2607 - val_accuracy: 0.5456 - val_top5_acc: 0.8242 - val_macro_f1score: 0.3491
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00040: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 40/70
# 97/97 [==============================] - ETA: 0s - loss: 0.3667 - accuracy: 0.8874 - top5_acc: 0.9852 - macro_f1score: 0.6376
# Epoch 00040: val_loss did not improve from 1.93668
#
# Epoch 00040: val_accuracy improved from 0.54557 to 0.54622, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/VGG11/040.h5
# 97/97 [==============================] - 260s 3s/step - loss: 0.3667 - accuracy: 0.8874 - top5_acc: 0.9852 - macro_f1score: 0.6376 - val_loss: 2.3389 - val_accuracy: 0.5462 - val_top5_acc: 0.8327 - val_macro_f1score: 0.3411
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00041: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 41/70
# 97/97 [==============================] - ETA: 0s - loss: 0.3674 - accuracy: 0.8879 - top5_acc: 0.9865 - macro_f1score: 0.6392
# Epoch 00041: val_loss did not improve from 1.93668
#
# Epoch 00041: val_accuracy did not improve from 0.54622
# 97/97 [==============================] - 246s 3s/step - loss: 0.3674 - accuracy: 0.8879 - top5_acc: 0.9865 - macro_f1score: 0.6392 - val_loss: 2.4001 - val_accuracy: 0.5339 - val_top5_acc: 0.8197 - val_macro_f1score: 0.3401
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00042: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 42/70
# 97/97 [==============================] - ETA: 0s - loss: 0.3558 - accuracy: 0.8929 - top5_acc: 0.9878 - macro_f1score: 0.6400
# Epoch 00042: val_loss did not improve from 1.93668
#
# Epoch 00042: val_accuracy did not improve from 0.54622
# 97/97 [==============================] - 248s 3s/step - loss: 0.3558 - accuracy: 0.8929 - top5_acc: 0.9878 - macro_f1score: 0.6400 - val_loss: 2.4091 - val_accuracy: 0.5352 - val_top5_acc: 0.8223 - val_macro_f1score: 0.3331
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00043: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 43/70
# 97/97 [==============================] - ETA: 0s - loss: 0.3337 - accuracy: 0.8988 - top5_acc: 0.9881 - macro_f1score: 0.6482
# Epoch 00043: val_loss did not improve from 1.93668
#
# Epoch 00043: val_accuracy improved from 0.54622 to 0.54688, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/VGG11/043.h5
# 97/97 [==============================] - 248s 3s/step - loss: 0.3337 - accuracy: 0.8988 - top5_acc: 0.9881 - macro_f1score: 0.6482 - val_loss: 2.3632 - val_accuracy: 0.5469 - val_top5_acc: 0.8242 - val_macro_f1score: 0.3491
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00044: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 44/70
# 97/97 [==============================] - ETA: 0s - loss: 0.3366 - accuracy: 0.9002 - top5_acc: 0.9866 - macro_f1score: 0.6570
# Epoch 00044: val_loss did not improve from 1.93668
#
# Epoch 00044: val_accuracy did not improve from 0.54688
# 97/97 [==============================] - 245s 3s/step - loss: 0.3366 - accuracy: 0.9002 - top5_acc: 0.9866 - macro_f1score: 0.6570 - val_loss: 2.4986 - val_accuracy: 0.5319 - val_top5_acc: 0.8132 - val_macro_f1score: 0.3454
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00045: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 45/70
# 97/97 [==============================] - ETA: 0s - loss: 0.3277 - accuracy: 0.9012 - top5_acc: 0.9889 - macro_f1score: 0.6583
# Epoch 00045: val_loss did not improve from 1.93668
#
# Epoch 00045: val_accuracy did not improve from 0.54688
# 97/97 [==============================] - 242s 2s/step - loss: 0.3277 - accuracy: 0.9012 - top5_acc: 0.9889 - macro_f1score: 0.6583 - val_loss: 2.4532 - val_accuracy: 0.5456 - val_top5_acc: 0.8268 - val_macro_f1score: 0.3485
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00046: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 46/70
# 97/97 [==============================] - ETA: 0s - loss: 0.3326 - accuracy: 0.8988 - top5_acc: 0.9880 - macro_f1score: 0.6498
# Epoch 00046: val_loss did not improve from 1.93668
#
# Epoch 00046: val_accuracy did not improve from 0.54688
# 97/97 [==============================] - 246s 3s/step - loss: 0.3326 - accuracy: 0.8988 - top5_acc: 0.9880 - macro_f1score: 0.6498 - val_loss: 2.4322 - val_accuracy: 0.5462 - val_top5_acc: 0.8184 - val_macro_f1score: 0.3422
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00047: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 47/70
# 97/97 [==============================] - ETA: 0s - loss: 0.3180 - accuracy: 0.9019 - top5_acc: 0.9896 - macro_f1score: 0.6471
# Epoch 00047: val_loss did not improve from 1.93668
#
# Epoch 00047: val_accuracy improved from 0.54688 to 0.54883, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/VGG11/047.h5
# 97/97 [==============================] - 248s 3s/step - loss: 0.3180 - accuracy: 0.9019 - top5_acc: 0.9896 - macro_f1score: 0.6471 - val_loss: 2.4224 - val_accuracy: 0.5488 - val_top5_acc: 0.8210 - val_macro_f1score: 0.3634
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00048: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 48/70
# 97/97 [==============================] - ETA: 0s - loss: 0.3102 - accuracy: 0.9045 - top5_acc: 0.9903 - macro_f1score: 0.6561
# Epoch 00048: val_loss did not improve from 1.93668
#
# Epoch 00048: val_accuracy did not improve from 0.54883
# 97/97 [==============================] - 244s 3s/step - loss: 0.3102 - accuracy: 0.9045 - top5_acc: 0.9903 - macro_f1score: 0.6561 - val_loss: 2.4355 - val_accuracy: 0.5391 - val_top5_acc: 0.8210 - val_macro_f1score: 0.3528
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00049: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 49/70
# 97/97 [==============================] - ETA: 0s - loss: 0.3044 - accuracy: 0.9084 - top5_acc: 0.9895 - macro_f1score: 0.6645
# Epoch 00049: val_loss did not improve from 1.93668
#
# Epoch 00049: val_accuracy did not improve from 0.54883
# 97/97 [==============================] - 244s 3s/step - loss: 0.3044 - accuracy: 0.9084 - top5_acc: 0.9895 - macro_f1score: 0.6645 - val_loss: 2.4320 - val_accuracy: 0.5469 - val_top5_acc: 0.8223 - val_macro_f1score: 0.3642
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00050: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 50/70
# 97/97 [==============================] - ETA: 0s - loss: 0.2926 - accuracy: 0.9113 - top5_acc: 0.9907 - macro_f1score: 0.6592
# Epoch 00050: val_loss did not improve from 1.93668
#
# Epoch 00050: val_accuracy did not improve from 0.54883
# 97/97 [==============================] - 242s 2s/step - loss: 0.2926 - accuracy: 0.9113 - top5_acc: 0.9907 - macro_f1score: 0.6592 - val_loss: 2.6168 - val_accuracy: 0.5339 - val_top5_acc: 0.8132 - val_macro_f1score: 0.3364
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00051: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 51/70
# 97/97 [==============================] - ETA: 0s - loss: 0.2958 - accuracy: 0.9084 - top5_acc: 0.9908 - macro_f1score: 0.6657
# Epoch 00051: val_loss did not improve from 1.93668
#
# Epoch 00051: val_accuracy improved from 0.54883 to 0.56380, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/VGG11/051.h5
# 97/97 [==============================] - 253s 3s/step - loss: 0.2958 - accuracy: 0.9084 - top5_acc: 0.9908 - macro_f1score: 0.6657 - val_loss: 2.4427 - val_accuracy: 0.5638 - val_top5_acc: 0.8268 - val_macro_f1score: 0.3594
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00052: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 52/70
# 97/97 [==============================] - ETA: 0s - loss: 0.2865 - accuracy: 0.9112 - top5_acc: 0.9914 - macro_f1score: 0.6578
# Epoch 00052: val_loss did not improve from 1.93668
#
# Epoch 00052: val_accuracy did not improve from 0.56380
# 97/97 [==============================] - 245s 3s/step - loss: 0.2865 - accuracy: 0.9112 - top5_acc: 0.9914 - macro_f1score: 0.6578 - val_loss: 2.5373 - val_accuracy: 0.5410 - val_top5_acc: 0.8229 - val_macro_f1score: 0.3517
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00053: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 53/70
# 97/97 [==============================] - ETA: 0s - loss: 0.2979 - accuracy: 0.9110 - top5_acc: 0.9901 - macro_f1score: 0.6670
# Epoch 00053: val_loss did not improve from 1.93668
#
# Epoch 00053: val_accuracy did not improve from 0.56380
# 97/97 [==============================] - 242s 2s/step - loss: 0.2979 - accuracy: 0.9110 - top5_acc: 0.9901 - macro_f1score: 0.6670 - val_loss: 2.4896 - val_accuracy: 0.5436 - val_top5_acc: 0.8242 - val_macro_f1score: 0.3522
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00054: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 54/70
# 97/97 [==============================] - ETA: 0s - loss: 0.2795 - accuracy: 0.9146 - top5_acc: 0.9903 - macro_f1score: 0.6683
# Epoch 00054: val_loss did not improve from 1.93668
#
# Epoch 00054: val_accuracy did not improve from 0.56380
# 97/97 [==============================] - 241s 2s/step - loss: 0.2795 - accuracy: 0.9146 - top5_acc: 0.9903 - macro_f1score: 0.6683 - val_loss: 2.4982 - val_accuracy: 0.5391 - val_top5_acc: 0.8210 - val_macro_f1score: 0.3433
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00055: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 55/70
# 97/97 [==============================] - ETA: 0s - loss: 0.2735 - accuracy: 0.9162 - top5_acc: 0.9921 - macro_f1score: 0.6615
# Epoch 00055: val_loss did not improve from 1.93668
#
# Epoch 00055: val_accuracy did not improve from 0.56380
# 97/97 [==============================] - 245s 3s/step - loss: 0.2735 - accuracy: 0.9162 - top5_acc: 0.9921 - macro_f1score: 0.6615 - val_loss: 2.4642 - val_accuracy: 0.5488 - val_top5_acc: 0.8255 - val_macro_f1score: 0.3510
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00056: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 56/70
# 97/97 [==============================] - ETA: 0s - loss: 0.2674 - accuracy: 0.9202 - top5_acc: 0.9918 - macro_f1score: 0.6783
# Epoch 00056: val_loss did not improve from 1.93668
#
# Epoch 00056: val_accuracy did not improve from 0.56380
# 97/97 [==============================] - 244s 3s/step - loss: 0.2674 - accuracy: 0.9202 - top5_acc: 0.9918 - macro_f1score: 0.6783 - val_loss: 2.5906 - val_accuracy: 0.5417 - val_top5_acc: 0.8203 - val_macro_f1score: 0.3587
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00057: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 57/70
# 97/97 [==============================] - ETA: 0s - loss: 0.2515 - accuracy: 0.9238 - top5_acc: 0.9917 - macro_f1score: 0.6753
# Epoch 00057: val_loss did not improve from 1.93668
#
# Epoch 00057: val_accuracy did not improve from 0.56380
# 97/97 [==============================] - 243s 3s/step - loss: 0.2515 - accuracy: 0.9238 - top5_acc: 0.9917 - macro_f1score: 0.6753 - val_loss: 2.6688 - val_accuracy: 0.5332 - val_top5_acc: 0.8118 - val_macro_f1score: 0.3431
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00058: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 58/70
# 97/97 [==============================] - ETA: 0s - loss: 0.2553 - accuracy: 0.9217 - top5_acc: 0.9927 - macro_f1score: 0.6760
# Epoch 00058: val_loss did not improve from 1.93668
#
# Epoch 00058: val_accuracy did not improve from 0.56380
# 97/97 [==============================] - 243s 3s/step - loss: 0.2553 - accuracy: 0.9217 - top5_acc: 0.9927 - macro_f1score: 0.6760 - val_loss: 2.5324 - val_accuracy: 0.5534 - val_top5_acc: 0.8216 - val_macro_f1score: 0.3500
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00059: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 59/70
# 97/97 [==============================] - ETA: 0s - loss: 0.2547 - accuracy: 0.9187 - top5_acc: 0.9942 - macro_f1score: 0.6708
# Epoch 00059: val_loss did not improve from 1.93668
#
# Epoch 00059: val_accuracy did not improve from 0.56380
# 97/97 [==============================] - 242s 2s/step - loss: 0.2547 - accuracy: 0.9187 - top5_acc: 0.9942 - macro_f1score: 0.6708 - val_loss: 2.5777 - val_accuracy: 0.5378 - val_top5_acc: 0.8177 - val_macro_f1score: 0.3478
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00060: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 60/70
# 97/97 [==============================] - ETA: 0s - loss: 0.2360 - accuracy: 0.9256 - top5_acc: 0.9940 - macro_f1score: 0.6801
# Epoch 00060: val_loss did not improve from 1.93668
#
# Epoch 00060: val_accuracy did not improve from 0.56380
# 97/97 [==============================] - 243s 3s/step - loss: 0.2360 - accuracy: 0.9256 - top5_acc: 0.9940 - macro_f1score: 0.6801 - val_loss: 2.5830 - val_accuracy: 0.5423 - val_top5_acc: 0.8197 - val_macro_f1score: 0.3520
# Learning rate:  2.9999999999999997e-06
#
# Epoch 00061: LearningRateScheduler reducing learning rate to 2.9999999999999997e-06.
# Epoch 61/70
# 97/97 [==============================] - ETA: 0s - loss: 0.2292 - accuracy: 0.9322 - top5_acc: 0.9946 - macro_f1score: 0.6876
# Epoch 00061: val_loss did not improve from 1.93668
#
# Epoch 00061: val_accuracy did not improve from 0.56380
# 97/97 [==============================] - 246s 3s/step - loss: 0.2292 - accuracy: 0.9322 - top5_acc: 0.9946 - macro_f1score: 0.6876 - val_loss: 2.5450 - val_accuracy: 0.5475 - val_top5_acc: 0.8236 - val_macro_f1score: 0.3640
# Learning rate:  2.9999999999999997e-06
#
# Epoch 00062: LearningRateScheduler reducing learning rate to 2.9999999999999997e-06.
# Epoch 62/70
# 97/97 [==============================] - ETA: 0s - loss: 0.2412 - accuracy: 0.9283 - top5_acc: 0.9934 - macro_f1score: 0.6751
# Epoch 00062: val_loss did not improve from 1.93668
#
# Epoch 00062: val_accuracy did not improve from 0.56380
# 97/97 [==============================] - 243s 3s/step - loss: 0.2412 - accuracy: 0.9283 - top5_acc: 0.9934 - macro_f1score: 0.6751 - val_loss: 2.5654 - val_accuracy: 0.5391 - val_top5_acc: 0.8197 - val_macro_f1score: 0.3518
# Learning rate:  2.9999999999999997e-06
#
# Epoch 00063: LearningRateScheduler reducing learning rate to 2.9999999999999997e-06.
# Epoch 63/70
# 97/97 [==============================] - ETA: 0s - loss: 0.2236 - accuracy: 0.9340 - top5_acc: 0.9936 - macro_f1score: 0.6848
# Epoch 00063: val_loss did not improve from 1.93668
#
# Epoch 00063: val_accuracy did not improve from 0.56380
# 97/97 [==============================] - 246s 3s/step - loss: 0.2236 - accuracy: 0.9340 - top5_acc: 0.9936 - macro_f1score: 0.6848 - val_loss: 2.4975 - val_accuracy: 0.5443 - val_top5_acc: 0.8262 - val_macro_f1score: 0.3497
# Learning rate:  2.9999999999999997e-06
#
# Epoch 00064: LearningRateScheduler reducing learning rate to 2.9999999999999997e-06.
# Epoch 64/70
# 97/97 [==============================] - ETA: 0s - loss: 0.2315 - accuracy: 0.9309 - top5_acc: 0.9929 - macro_f1score: 0.6850
# Epoch 00064: val_loss did not improve from 1.93668
#
# Epoch 00064: val_accuracy did not improve from 0.56380
# 97/97 [==============================] - 245s 3s/step - loss: 0.2315 - accuracy: 0.9309 - top5_acc: 0.9929 - macro_f1score: 0.6850 - val_loss: 2.5182 - val_accuracy: 0.5475 - val_top5_acc: 0.8197 - val_macro_f1score: 0.3515
# Learning rate:  2.9999999999999997e-06
#
# Epoch 00065: LearningRateScheduler reducing learning rate to 2.9999999999999997e-06.
# Epoch 65/70
# 97/97 [==============================] - ETA: 0s - loss: 0.2271 - accuracy: 0.9316 - top5_acc: 0.9936 - macro_f1score: 0.6858
# Epoch 00065: val_loss did not improve from 1.93668
#
# Epoch 00065: val_accuracy did not improve from 0.56380
# 97/97 [==============================] - 249s 3s/step - loss: 0.2271 - accuracy: 0.9316 - top5_acc: 0.9936 - macro_f1score: 0.6858 - val_loss: 2.5179 - val_accuracy: 0.5430 - val_top5_acc: 0.8210 - val_macro_f1score: 0.3523
# Learning rate:  2.9999999999999997e-06
#
# Epoch 00066: LearningRateScheduler reducing learning rate to 2.9999999999999997e-06.
# Epoch 66/70
# 97/97 [==============================] - ETA: 0s - loss: 0.2212 - accuracy: 0.9324 - top5_acc: 0.9950 - macro_f1score: 0.6811
# Epoch 00066: val_loss did not improve from 1.93668
#
# Epoch 00066: val_accuracy did not improve from 0.56380
# 97/97 [==============================] - 249s 3s/step - loss: 0.2212 - accuracy: 0.9324 - top5_acc: 0.9950 - macro_f1score: 0.6811 - val_loss: 2.4792 - val_accuracy: 0.5501 - val_top5_acc: 0.8242 - val_macro_f1score: 0.3637
# Learning rate:  2.9999999999999997e-06
#
# Epoch 00067: LearningRateScheduler reducing learning rate to 2.9999999999999997e-06.
# Epoch 67/70
# 97/97 [==============================] - ETA: 0s - loss: 0.2277 - accuracy: 0.9306 - top5_acc: 0.9940 - macro_f1score: 0.6876
# Epoch 00067: val_loss did not improve from 1.93668
#
# Epoch 00067: val_accuracy did not improve from 0.56380
# 97/97 [==============================] - 248s 3s/step - loss: 0.2277 - accuracy: 0.9306 - top5_acc: 0.9940 - macro_f1score: 0.6876 - val_loss: 2.5022 - val_accuracy: 0.5475 - val_top5_acc: 0.8197 - val_macro_f1score: 0.3662
# Learning rate:  2.9999999999999997e-06
#
# Epoch 00068: LearningRateScheduler reducing learning rate to 2.9999999999999997e-06.
# Epoch 68/70
# 97/97 [==============================] - ETA: 0s - loss: 0.2232 - accuracy: 0.9326 - top5_acc: 0.9937 - macro_f1score: 0.6842
# Epoch 00068: val_loss did not improve from 1.93668
#
# Epoch 00068: val_accuracy did not improve from 0.56380
# 97/97 [==============================] - 250s 3s/step - loss: 0.2232 - accuracy: 0.9326 - top5_acc: 0.9937 - macro_f1score: 0.6842 - val_loss: 2.4839 - val_accuracy: 0.5449 - val_top5_acc: 0.8223 - val_macro_f1score: 0.3627
# Learning rate:  2.9999999999999997e-06
#
# Epoch 00069: LearningRateScheduler reducing learning rate to 2.9999999999999997e-06.
# Epoch 69/70
# 97/97 [==============================] - ETA: 0s - loss: 0.2213 - accuracy: 0.9350 - top5_acc: 0.9947 - macro_f1score: 0.6887
# Epoch 00069: val_loss did not improve from 1.93668
#
# Epoch 00069: val_accuracy did not improve from 0.56380
# 97/97 [==============================] - 249s 3s/step - loss: 0.2213 - accuracy: 0.9350 - top5_acc: 0.9947 - macro_f1score: 0.6887 - val_loss: 2.4657 - val_accuracy: 0.5443 - val_top5_acc: 0.8249 - val_macro_f1score: 0.3518
# Learning rate:  2.9999999999999997e-06
#
# Epoch 00070: LearningRateScheduler reducing learning rate to 2.9999999999999997e-06.
# Epoch 70/70
# 97/97 [==============================] - ETA: 0s - loss: 0.2220 - accuracy: 0.9331 - top5_acc: 0.9940 - macro_f1score: 0.6798
# Epoch 00070: val_loss did not improve from 1.93668
#
# Epoch 00070: val_accuracy did not improve from 0.56380
# 97/97 [==============================] - 249s 3s/step - loss: 0.2220 - accuracy: 0.9331 - top5_acc: 0.9940 - macro_f1score: 0.6798 - val_loss: 2.4797 - val_accuracy: 0.5462 - val_top5_acc: 0.8275 - val_macro_f1score: 0.3512

# %% [markdown]
# ### 2) VGG11 Evaluate

# %%
# 1. epoch=maximum
loss , acc, top5_acc, mf1 = model.evaluate(test_generator,steps=int(len(x_test)/batch_sizes))
print('[Test Loss: %.4f /  Test Top-1 Accuracy: %.4f / Test Top-5 Accuracy: %.4f / Test Macro f1: %.4f]\n' % (loss,acc,top5_acc,mf1))
# Out:
# 12/12 [==============================] - 432s 36s/step - loss: 2.6511 - accuracy: 0.5234 - top5_acc: 0.8092 - macro_f1score: 0.3336
# [Test Loss: 2.6511 /  Test Top-1 Accuracy: 0.5234 / Test Top-5 Accuracy: 0.8092 / Test Macro f1: 0.3336]

# %%
loss=history.history['loss']
val_loss=history.history['val_loss']
acc=history.history['accuracy']
val_acc=history.history['val_accuracy']
top5_acc=history.history['top5_acc']
val_top5_acc=history.history['val_top5_acc']
f1=history.history['macro_f1score']
val_f1=history.history['val_macro_f1score']
epochs=range(1,len(acc)+1)

data = np.array([epochs,loss,val_loss,acc,val_acc,top5_acc,val_top5_acc,f1,val_f1]).T

# %%
# data save
# epochs, loss, val_loss, acc, val_acc, top5_acc, val_top5_acc, f1, val_f1

np.savetxt(os.path.join(dir,'train_valid_output',number,model.name+'.txt'),data)

# %%
# data import
data = np.loadtxt(os.path.join(dir,'train_valid_output',number,'VGG11.txt'))

# %%
epochs=data[:,0]
loss=data[:,1]
val_loss=data[:,2]
acc=data[:,3]
val_acc=data[:,4]
top5_acc=data[:,5]
val_top5_acc=data[:,6]

# %%
plt.plot(epochs[1:],acc[1:],'b',label='Training 1-Acc')
plt.plot(epochs[1:],val_acc[1:],'r',label='Validation 1-Acc')
plt.title('Training and Validation Top-1 Accuracy')
plt.legend()
plt.figure()

plt.plot(epochs[1:],top5_acc[1:],'b',label='Training 5-Acc')
plt.plot(epochs[1:],val_top5_acc[1:],'r',label='Validation 5-Acc')
plt.title('Training and Validation Top-5 Accuracy')
plt.legend()
plt.figure()

plt.plot(epochs[10:],loss[10:],'b',label='Training Loss')
plt.plot(epochs[10:],val_loss[10:],'r',label='Validation Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()

# %%
# 이 아래는 내가 인위적으로 살펴보고 싶은 epoch에 대해서 결과값 출력 / VGG11

# %%
# 참고 : https://github.com/OverLordGoldDragon/keras-adamw

import sys
sys.path.append('/content/drive/My Drive/Colab Notebooks/Paper')
import utils
import optimizers_v2
from utils import get_weight_decays, fill_dict_in_order
from utils import reset_seeds, K_eval
from optimizers_v2 import AdamW, NadamW, SGDW

# %%
# top-5 accuracy 출력
import functools
top5_acc = functools.partial(ks.metrics.top_k_categorical_accuracy, k=5)
top5_acc.__name__ = 'top5_acc'

# %%
model=load_model(os.path.join(dir,'model_output',number,'VGG11','031.h5'),custom_objects={"macro_f1score": macro_f1score,"top5_acc":top5_acc, "AdamW":AdamW})

# %%
# 2. epoch=?
loss , acc, top5_acc, mf1 = model.evaluate(test_generator,steps=int(len(x_test)/batch_sizes))
print('[Test Loss: %.4f /  Test Top-1 Accuracy: %.4f / Test Top-5 Accuracy: %.4f / Test Macro f1: %.4f]\n' % (loss,acc,top5_acc,mf1))
# Out:
# 12/12 [==============================] - 549s 46s/step - loss: 2.2857 - accuracy: 0.5156 - top5_acc: 0.8027 - macro_f1score: 0.3314
# [Test Loss: 2.2857 /  Test Top-1 Accuracy: 0.5156 / Test Top-5 Accuracy: 0.8027 / Test Macro f1: 0.3314]
