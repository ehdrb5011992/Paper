# %%
### 참고 : https://sike6054.github.io/blog/paper/fifth-post/
### SE block 코드 참고 : https://github.com/titu1994/keras-squeeze-excite-network/tree/master/keras_squeeze_excite_network

# %% [markdown]
# # [SE-Xception]

# %% [markdown]
# *KU LeeDongGyu*

# %% [markdown]
# ## Contents
# ---

# %% [markdown]
# 1. Data Preprocessing
# ```
# 1) Data Import
# 2) Data Augmentation
# ```
# 2. Support Functions & Almost Original SE-Xception
# ```
# 1) Support Functions
# 2) Almost Original SE-Xception
# 3) SE-Xception Evaluate
# ```

# %% [markdown]
# ### Install Packages

# %% [markdown]
# ### Module

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/My Drive/Colab Notebooks/Paper
# Out:
# /content/drive/My Drive/Colab Notebooks/Paper

# %%
from f1score import macro_f1score,weighted_f1score

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import cv2
import tensorflow as tf
from tensorflow import keras as ks
from tensorflow.keras import backend as K 
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, Input, Concatenate, ZeroPadding2D ,GlobalMaxPooling2D, Reshape , Lambda , Add, Multiply
from tensorflow.keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D, Activation, BatchNormalization, AveragePooling2D , ZeroPadding2D, SeparableConv2D , LeakyReLU
from tensorflow.keras.layers import add, concatenate, multiply
from tensorflow.keras.optimizers import Adam, RMSprop , SGD
from tensorflow.keras.callbacks import EarlyStopping , LearningRateScheduler, ModelCheckpoint, CSVLogger, Callback, ReduceLROnPlateau
from tensorflow.keras.regularizers import l1,l2,l1_l2
from tensorflow.keras.models import Model , load_model , Sequential
from tensorflow.keras.utils import plot_model , to_categorical, get_file
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
os.getcwd()
# Out:
# '/content/drive/My Drive/Colab Notebooks/Paper'

# %%
print(tf.__version__)
print(ks.__version__)
# Out:
# 2.3.0
# 2.4.0

# %%
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 8831924262126857938
# , name: "/device:XLA_CPU:0"
# device_type: "XLA_CPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 14156465444074241262
# physical_device_desc: "device: XLA_CPU device"
# , name: "/device:XLA_GPU:0"
# device_type: "XLA_GPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 13527350027902344629
# physical_device_desc: "device: XLA_GPU device"
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 15695549568
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 7357374883169153594
# physical_device_desc: "device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0"
# ]

# %%
# !cat /proc/cpuinfo
# Out:
# processor	: 0
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 63
# model name	: Intel(R) Xeon(R) CPU @ 2.30GHz
# stepping	: 0
# microcode	: 0x1
# cpu MHz		: 2300.000
# cache size	: 46080 KB
# physical id	: 0
# siblings	: 4
# core id		: 0
# cpu cores	: 2
# apicid		: 0
# initial apicid	: 0
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 avx2 smep bmi2 erms invpcid xsaveopt arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs
# bogomips	: 4600.00
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 46 bits physical, 48 bits virtual
# power management:
#
# processor	: 1
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 63
# model name	: Intel(R) Xeon(R) CPU @ 2.30GHz
# stepping	: 0
# microcode	: 0x1
# cpu MHz		: 2300.000
# cache size	: 46080 KB
# physical id	: 0
# siblings	: 4
# core id		: 1
# cpu cores	: 2
# apicid		: 2
# initial apicid	: 2
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 avx2 smep bmi2 erms invpcid xsaveopt arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs
# bogomips	: 4600.00
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 46 bits physical, 48 bits virtual
# power management:
#
# processor	: 2
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 63
# model name	: Intel(R) Xeon(R) CPU @ 2.30GHz
# stepping	: 0
# microcode	: 0x1
# cpu MHz		: 2300.000
# cache size	: 46080 KB
# physical id	: 0
# siblings	: 4
# core id		: 0
# cpu cores	: 2
# apicid		: 1
# initial apicid	: 1
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 avx2 smep bmi2 erms invpcid xsaveopt arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs
# bogomips	: 4600.00
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 46 bits physical, 48 bits virtual
# power management:
#
# processor	: 3
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 63
# model name	: Intel(R) Xeon(R) CPU @ 2.30GHz
# stepping	: 0
# microcode	: 0x1
# cpu MHz		: 2300.000
# cache size	: 46080 KB
# physical id	: 0
# siblings	: 4
# core id		: 1
# cpu cores	: 2
# apicid		: 3
# initial apicid	: 3
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 avx2 smep bmi2 erms invpcid xsaveopt arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs
# bogomips	: 4600.00
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 46 bits physical, 48 bits virtual
# power management:

# %% [markdown]
# ## 1. Data Preprocessing
# ---

# %% [markdown]
# ### 1) Data Import

# %%
# 바꿔서 살펴 볼 것들
# CALTECH, CIFAR100, FER, MIT
data_name = 'MIT'
gan_type = 'No_GAN'
number = '1'
size = 299 # sizes after cropping
super_size = 330 # sizes before cropping 
input_sizes = (size,size,3)
batch_sizes = 32
weight_decay = 1e-6
epochs = 70

# %%
# 참고 : https://stackoverflow.com/questions/32419510/how-to-get-reproducible-results-in-keras/52897216#52897216
# setting the seed number for random number generation for reproducibility.

from numpy.random import seed
import random


if number=='1':
    seed_num = 200225
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)
elif number=='2':
    seed_num = 727
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)
elif number=='3':
    seed_num = 115
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)
elif number=='4':
    seed_num = 501
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)
elif number=='5':
    seed_num = 517
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)

# %%
# data import

if data_name=='FER' :
    x_train =  np.zeros(28698)
    x_valid = np.zeros(3589)
    x_test = np.zeros(3588)
    classes = 7 
    tr_center = [0.50793296, 0.50793296, 0.50793296]
elif data_name=='MIT':
    x_train = np.zeros(12466)
    x_valid = np.zeros(1564)
    x_test = np.zeros(1590)
    classes = 67 
    tr_center = [0.47916578, 0.42029615, 0.36046057]
elif data_name=='CALTECH':
    x_train = np.zeros(24510)
    x_valid = np.zeros(2980)
    x_test = np.zeros(3118)
    classes = 257
    tr_center = [0.51397761, 0.49525248, 0.46555727]
elif data_name=='CIFAR100':
    x_train = np.zeros(44923)
    x_valid = np.zeros(5077)
    x_test = np.zeros(10000)
    classes = 100
    tr_center = [0.53442983, 0.51355958, 0.46462564]

# %%
dir = os.path.join(os.getcwd(),data_name,gan_type)

# %% [markdown]
# ### 2) Data Augmentation

# %%
# 참고 : https://jkjung-avt.github.io/keras-image-cropping/

def random_crop(img, random_crop_size):
    # Note: image_data_format is 'channel_last'
    assert img.shape[2] == 3 # img.shape[2] 가 3(rgb)이 아니면 assertion error 발생
    height, width = img.shape[0], img.shape[1]
    dy, dx = random_crop_size
    x = np.random.randint(0, width - dx + 1)
    y = np.random.randint(0, height - dy + 1)
    return img[y:(y+dy), x:(x+dx), :]


def crop_generator(batches, crop_length):
    """Take as input a Keras ImageGen (Iterator) and generate random
    crops from the image batches generated by the original iterator.
    """
    while True:
        batch_x, batch_y = next(batches)
        batch_crops = np.zeros((batch_x.shape[0], crop_length, crop_length, 3))
        for i in range(batch_x.shape[0]):
            batch_crops[i] = random_crop(batch_x[i], (crop_length, crop_length))
        yield (batch_crops, batch_y)

# %%
from tensorflow.keras.preprocessing.image import img_to_array,load_img
import glob

# 데이터 전체에 대해 centering 진행함.

def read_cal_image(img_path): 
    x = img_to_array(load_img(img_path)) # x는 채널별 평균값
    y = x.shape[0] * x.shape[1]# y는 데이터별 픽셀 수 (비중)

    x = 1/255. * x # scaling하고, centering값을 뽑아냄.
    x = np.mean(x, axis=(0,1))
    
    return np.hstack([x,y])

def calculate_centered_mean(dataset_path,x_train=x_train):
    num = len(x_train)
    space = np.empty((num,4))
    i=0

    for p in glob.glob(os.path.join(dataset_path,'*/*.*')) :
        space[i] = read_cal_image(p)
        i += 1

    ratio = space[:,3] / np.sum(space[:,3])

    return np.average(space[:,0:3],axis=0,weights=ratio)


# 아래의 함수를 돌려서 나온 결과값을 중심화 값으로 설정.

# train_mean = calculate_centered_mean(os.path.join(dir,'data/train')).reshape((1,1,3))

# %%
datagen_tr = ImageDataGenerator(
    rescale=1/255.,
    horizontal_flip=True,
    featurewise_center=True,
    featurewise_std_normalization=False,
    rotation_range=10,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=[0.9,1.0],
    fill_mode = 'nearest')
datagen_val = ImageDataGenerator(rescale=1/255.,featurewise_center=True)
datagen_tes = ImageDataGenerator(rescale=1/255.,featurewise_center=True)

# 원래는 이 자리에 fit 매서드를 써야하지만, 그냥 내가 중심화함수를 만들고 적용함. 

# 중심화 설정
datagen_tr.mean = np.array(tr_center, dtype=np.float32).reshape((1,1,3)) # RGB
datagen_val.mean = np.array(tr_center, dtype=np.float32).reshape((1,1,3)) # RGB
datagen_tes.mean = np.array(tr_center, dtype=np.float32).reshape((1,1,3)) # RGB

# %%
train_batches = datagen_tr.flow_from_directory(directory=os.path.join(dir,'data/train'),target_size=(super_size,super_size),batch_size=batch_sizes,class_mode='categorical') # fer : 28698 / mit : 12466 / caltech : 24509 / cifar : 44923
train_generator= crop_generator(train_batches, size)
valid_generator = datagen_val.flow_from_directory(directory=os.path.join(dir,'data/valid'),target_size=(size,size),batch_size=batch_sizes,class_mode='categorical') # fer : 3589 / mit : 1564 / caltech : 2980 / cifar : 5077
test_generator = datagen_tes.flow_from_directory(directory=os.path.join(dir,'data/test'),target_size=(size,size),batch_size=batch_sizes,class_mode='categorical') # fer : 3588 / mit : 1590 / caltech : 3118 / cifar : 10000
# Out:
# Found 12466 images belonging to 67 classes.
# Found 1564 images belonging to 67 classes.
# Found 1590 images belonging to 67 classes.

# %% [markdown]
# ## 2. Support Functions & Almost Original SE-Xception
# ---

# %% [markdown]
# ### 1) Support Functions

# %%
# def lr_schedule(epoch):
#     init_lr = 1e-4
#     k = 0.04
#     lr = init_lr * np.exp(-k*epoch)
#     print('Learning rate: ', lr)
#     return lr

def lr_schedule(epoch):
    lr = 1e-3
    if epoch < 30:
        lr = lr
    elif epoch < 60:
        lr = lr * 0.1
    else:
        lr = lr * 0.01
    print('Learning rate: ', lr)
    return lr

# %%
def squeeze_excite_block(input, reduction_ratio=16, weight_decay=weight_decay):

    init = input
    channel_axis = -1
    filters = init.get_shape()[channel_axis]
    se_shape = (1, 1, filters)

    se = GlobalAveragePooling2D()(init)
    se = Reshape(se_shape)(se)
    se = Dense(filters // reduction_ratio, activation='relu', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay), use_bias=False)(se)
    se = Dense(filters, activation='sigmoid', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay), use_bias=False)(se)

    x = multiply([init, se])
    return x

# %% [markdown]
# ### 2) Almost Original SE-Xception

# %%
def SE_Xception(input_shape=None, classes=1000, reduction_ratio = 16, name = "SE_Xception", weight_decay = weight_decay):


    img_input = Input(shape=input_shape)


    x = Conv2D(32, (3, 3), strides=(2, 2), use_bias=False, kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay), name='block1_conv1')(img_input)
    x = BatchNormalization(name='block1_conv1_bn')(x)
    x = Activation('relu', name='block1_conv1_act')(x)
    x = Conv2D(64, (3, 3), use_bias=False, kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay), name='block1_conv2')(x)
    x = BatchNormalization(name='block1_conv2_bn')(x)
    x = Activation('relu', name='block1_conv2_act')(x)

    residual = Conv2D(128, (1, 1), strides=(2, 2),
                      padding='same', use_bias=False, kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(x)
    residual = BatchNormalization()(residual)

    x = SeparableConv2D(128, (3, 3), padding='same', use_bias=False, depthwise_initializer='he_uniform', pointwise_initializer='he_uniform',depthwise_regularizer=l2(weight_decay), pointwise_regularizer=l2(weight_decay), name='block2_sepconv1')(x)
    x = BatchNormalization(name='block2_sepconv1_bn')(x)
    x = Activation('relu', name='block2_sepconv2_act')(x)
    x = SeparableConv2D(128, (3, 3), padding='same', use_bias=False, depthwise_initializer='he_uniform', pointwise_initializer='he_uniform',depthwise_regularizer=l2(weight_decay), pointwise_regularizer=l2(weight_decay), name='block2_sepconv2')(x)
    x = BatchNormalization(name='block2_sepconv2_bn')(x)

    x = MaxPooling2D((3, 3), strides=(2, 2), padding='same', name='block2_pool')(x)
    # SE block 추가
    x =  squeeze_excite_block(x, reduction_ratio)
    x = add([x, residual])

    residual = Conv2D(256, (1, 1), strides=(2, 2),
                      padding='same', use_bias=False, kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(x)
    residual = BatchNormalization()(residual)

    x = Activation('relu', name='block3_sepconv1_act')(x)
    x = SeparableConv2D(256, (3, 3), padding='same', use_bias=False, depthwise_initializer='he_uniform', pointwise_initializer='he_uniform',depthwise_regularizer=l2(weight_decay), pointwise_regularizer=l2(weight_decay), name='block3_sepconv1')(x)
    x = BatchNormalization(name='block3_sepconv1_bn')(x)
    x = Activation('relu', name='block3_sepconv2_act')(x)
    x = SeparableConv2D(256, (3, 3), padding='same', use_bias=False, depthwise_initializer='he_uniform', pointwise_initializer='he_uniform',depthwise_regularizer=l2(weight_decay), pointwise_regularizer=l2(weight_decay), name='block3_sepconv2')(x)
    x = BatchNormalization(name='block3_sepconv2_bn')(x)

    x = MaxPooling2D((3, 3), strides=(2, 2), padding='same', name='block3_pool')(x)
    # SE block 추가
    x =  squeeze_excite_block(x, reduction_ratio)    
    x = add([x, residual])

    residual = Conv2D(728, (1, 1), strides=(2, 2),
                      padding='same', use_bias=False, kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(x)
    residual = BatchNormalization()(residual)

    x = Activation('relu', name='block4_sepconv1_act')(x)
    x = SeparableConv2D(728, (3, 3), padding='same', use_bias=False, depthwise_initializer='he_uniform', pointwise_initializer='he_uniform',depthwise_regularizer=l2(weight_decay), pointwise_regularizer=l2(weight_decay), name='block4_sepconv1')(x)
    x = BatchNormalization(name='block4_sepconv1_bn')(x)
    x = Activation('relu', name='block4_sepconv2_act')(x)
    x = SeparableConv2D(728, (3, 3), padding='same', use_bias=False, depthwise_initializer='he_uniform', pointwise_initializer='he_uniform',depthwise_regularizer=l2(weight_decay), pointwise_regularizer=l2(weight_decay), name='block4_sepconv2')(x)
    x = BatchNormalization(name='block4_sepconv2_bn')(x)

    x = MaxPooling2D((3, 3), strides=(2, 2), padding='same', name='block4_pool')(x)
    # SE block 추가
    x =  squeeze_excite_block(x, reduction_ratio)
    x = add([x, residual])

    for i in range(8):
        residual = x
        prefix = 'block' + str(i + 5)

        x = Activation('relu', name=prefix + '_sepconv1_act')(x)
        x = SeparableConv2D(728, (3, 3), padding='same', use_bias=False, depthwise_initializer='he_uniform', pointwise_initializer='he_uniform',depthwise_regularizer=l2(weight_decay), pointwise_regularizer=l2(weight_decay), name=prefix + '_sepconv1')(x)
        x = BatchNormalization(name=prefix + '_sepconv1_bn')(x)
        x = Activation('relu', name=prefix + '_sepconv2_act')(x)
        x = SeparableConv2D(728, (3, 3), padding='same', use_bias=False, depthwise_initializer='he_uniform', pointwise_initializer='he_uniform',depthwise_regularizer=l2(weight_decay), pointwise_regularizer=l2(weight_decay), name=prefix + '_sepconv2')(x)
        x = BatchNormalization(name=prefix + '_sepconv2_bn')(x)
        x = Activation('relu', name=prefix + '_sepconv3_act')(x)
        x = SeparableConv2D(728, (3, 3), padding='same', use_bias=False, depthwise_initializer='he_uniform', pointwise_initializer='he_uniform',depthwise_regularizer=l2(weight_decay), pointwise_regularizer=l2(weight_decay), name=prefix + '_sepconv3')(x)
        x = BatchNormalization(name=prefix + '_sepconv3_bn')(x)

        # SE block 추가
        x =  squeeze_excite_block(x, reduction_ratio)
        x = add([x, residual])

    residual = Conv2D(1024, (1, 1), strides=(2, 2),
                      padding='same', use_bias=False, kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(x)
    residual = BatchNormalization()(residual)

    x = Activation('relu', name='block13_sepconv1_act')(x)
    x = SeparableConv2D(728, (3, 3), padding='same', use_bias=False, depthwise_initializer='he_uniform', pointwise_initializer='he_uniform',depthwise_regularizer=l2(weight_decay), pointwise_regularizer=l2(weight_decay), name='block13_sepconv1')(x)
    x = BatchNormalization(name='block13_sepconv1_bn')(x)
    x = Activation('relu', name='block13_sepconv2_act')(x)
    x = SeparableConv2D(1024, (3, 3), padding='same', use_bias=False, depthwise_initializer='he_uniform', pointwise_initializer='he_uniform',depthwise_regularizer=l2(weight_decay), pointwise_regularizer=l2(weight_decay), name='block13_sepconv2')(x)
    x = BatchNormalization(name='block13_sepconv2_bn')(x)

    x = MaxPooling2D((3, 3), strides=(2, 2), padding='same', name='block13_pool')(x)
    # SE block 추가
    x =  squeeze_excite_block(x, reduction_ratio)
    x = add([x, residual])

    x = SeparableConv2D(1536, (3, 3), padding='same', use_bias=False, depthwise_initializer='he_uniform', pointwise_initializer='he_uniform',depthwise_regularizer=l2(weight_decay), pointwise_regularizer=l2(weight_decay), name='block14_sepconv1')(x)
    x = BatchNormalization(name='block14_sepconv1_bn')(x)
    x = Activation('relu', name='block14_sepconv1_act')(x)

    x = SeparableConv2D(2048, (3, 3), padding='same', use_bias=False, depthwise_initializer='he_uniform', pointwise_initializer='he_uniform',depthwise_regularizer=l2(weight_decay), pointwise_regularizer=l2(weight_decay), name='block14_sepconv2')(x)
    x = BatchNormalization(name='block14_sepconv2_bn')(x)
    x = Activation('relu', name='block14_sepconv2_act')(x)


    x = GlobalAveragePooling2D(name='avg_pool')(x)
    x = Dropout(0.5)(x)
    x = Dense(classes, activation='softmax', kernel_regularizer=l2(weight_decay), name='predictions')(x)


    inputs = img_input

    # Create model.
    model = Model(inputs, x, name=name)

    return model

# %%
model = SE_Xception(input_sizes, classes=classes, reduction_ratio = 16, name='SE_Xception')

# %%
model.summary()
# Out:
# Model: "SE_Xception"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 299, 299, 3) 0
# __________________________________________________________________________________________________
# block1_conv1 (Conv2D)           (None, 149, 149, 32) 864         input_1[0][0]
# __________________________________________________________________________________________________
# block1_conv1_bn (BatchNormaliza (None, 149, 149, 32) 128         block1_conv1[0][0]
# __________________________________________________________________________________________________
# block1_conv1_act (Activation)   (None, 149, 149, 32) 0           block1_conv1_bn[0][0]
# __________________________________________________________________________________________________
# block1_conv2 (Conv2D)           (None, 147, 147, 64) 18432       block1_conv1_act[0][0]
# __________________________________________________________________________________________________
# block1_conv2_bn (BatchNormaliza (None, 147, 147, 64) 256         block1_conv2[0][0]
# __________________________________________________________________________________________________
# block1_conv2_act (Activation)   (None, 147, 147, 64) 0           block1_conv2_bn[0][0]
# __________________________________________________________________________________________________
# block2_sepconv1 (SeparableConv2 (None, 147, 147, 128 8768        block1_conv2_act[0][0]
# __________________________________________________________________________________________________
# block2_sepconv1_bn (BatchNormal (None, 147, 147, 128 512         block2_sepconv1[0][0]
# __________________________________________________________________________________________________
# block2_sepconv2_act (Activation (None, 147, 147, 128 0           block2_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block2_sepconv2 (SeparableConv2 (None, 147, 147, 128 17536       block2_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block2_sepconv2_bn (BatchNormal (None, 147, 147, 128 512         block2_sepconv2[0][0]
# __________________________________________________________________________________________________
# block2_pool (MaxPooling2D)      (None, 74, 74, 128)  0           block2_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 128)          0           block2_pool[0][0]
# __________________________________________________________________________________________________
# reshape (Reshape)               (None, 1, 1, 128)    0           global_average_pooling2d[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 1, 1, 8)      1024        reshape[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 1, 1, 128)    1024        dense[0][0]
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 74, 74, 128)  8192        block1_conv2_act[0][0]
# __________________________________________________________________________________________________
# multiply (Multiply)             (None, 74, 74, 128)  0           block2_pool[0][0]
#                                                                  dense_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 74, 74, 128)  512         conv2d[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 74, 74, 128)  0           multiply[0][0]
#                                                                  batch_normalization[0][0]
# __________________________________________________________________________________________________
# block3_sepconv1_act (Activation (None, 74, 74, 128)  0           add[0][0]
# __________________________________________________________________________________________________
# block3_sepconv1 (SeparableConv2 (None, 74, 74, 256)  33920       block3_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block3_sepconv1_bn (BatchNormal (None, 74, 74, 256)  1024        block3_sepconv1[0][0]
# __________________________________________________________________________________________________
# block3_sepconv2_act (Activation (None, 74, 74, 256)  0           block3_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block3_sepconv2 (SeparableConv2 (None, 74, 74, 256)  67840       block3_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block3_sepconv2_bn (BatchNormal (None, 74, 74, 256)  1024        block3_sepconv2[0][0]
# __________________________________________________________________________________________________
# block3_pool (MaxPooling2D)      (None, 37, 37, 256)  0           block3_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_1 (Glo (None, 256)          0           block3_pool[0][0]
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, 1, 1, 256)    0           global_average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 1, 1, 16)     4096        reshape_1[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 1, 1, 256)    4096        dense_2[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 37, 37, 256)  32768       add[0][0]
# __________________________________________________________________________________________________
# multiply_1 (Multiply)           (None, 37, 37, 256)  0           block3_pool[0][0]
#                                                                  dense_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 37, 37, 256)  1024        conv2d_1[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 37, 37, 256)  0           multiply_1[0][0]
#                                                                  batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# block4_sepconv1_act (Activation (None, 37, 37, 256)  0           add_1[0][0]
# __________________________________________________________________________________________________
# block4_sepconv1 (SeparableConv2 (None, 37, 37, 728)  188672      block4_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block4_sepconv1_bn (BatchNormal (None, 37, 37, 728)  2912        block4_sepconv1[0][0]
# __________________________________________________________________________________________________
# block4_sepconv2_act (Activation (None, 37, 37, 728)  0           block4_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block4_sepconv2 (SeparableConv2 (None, 37, 37, 728)  536536      block4_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block4_sepconv2_bn (BatchNormal (None, 37, 37, 728)  2912        block4_sepconv2[0][0]
# __________________________________________________________________________________________________
# block4_pool (MaxPooling2D)      (None, 19, 19, 728)  0           block4_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_2 (Glo (None, 728)          0           block4_pool[0][0]
# __________________________________________________________________________________________________
# reshape_2 (Reshape)             (None, 1, 1, 728)    0           global_average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 1, 1, 45)     32760       reshape_2[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 1, 1, 728)    32760       dense_4[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 19, 19, 728)  186368      add_1[0][0]
# __________________________________________________________________________________________________
# multiply_2 (Multiply)           (None, 19, 19, 728)  0           block4_pool[0][0]
#                                                                  dense_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 19, 19, 728)  2912        conv2d_2[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 19, 19, 728)  0           multiply_2[0][0]
#                                                                  batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# block5_sepconv1_act (Activation (None, 19, 19, 728)  0           add_2[0][0]
# __________________________________________________________________________________________________
# block5_sepconv1 (SeparableConv2 (None, 19, 19, 728)  536536      block5_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block5_sepconv1_bn (BatchNormal (None, 19, 19, 728)  2912        block5_sepconv1[0][0]
# __________________________________________________________________________________________________
# block5_sepconv2_act (Activation (None, 19, 19, 728)  0           block5_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block5_sepconv2 (SeparableConv2 (None, 19, 19, 728)  536536      block5_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block5_sepconv2_bn (BatchNormal (None, 19, 19, 728)  2912        block5_sepconv2[0][0]
# __________________________________________________________________________________________________
# block5_sepconv3_act (Activation (None, 19, 19, 728)  0           block5_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block5_sepconv3 (SeparableConv2 (None, 19, 19, 728)  536536      block5_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block5_sepconv3_bn (BatchNormal (None, 19, 19, 728)  2912        block5_sepconv3[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_3 (Glo (None, 728)          0           block5_sepconv3_bn[0][0]
# __________________________________________________________________________________________________
# reshape_3 (Reshape)             (None, 1, 1, 728)    0           global_average_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 1, 1, 45)     32760       reshape_3[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 1, 1, 728)    32760       dense_6[0][0]
# __________________________________________________________________________________________________
# multiply_3 (Multiply)           (None, 19, 19, 728)  0           block5_sepconv3_bn[0][0]
#                                                                  dense_7[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 19, 19, 728)  0           multiply_3[0][0]
#                                                                  add_2[0][0]
# __________________________________________________________________________________________________
# block6_sepconv1_act (Activation (None, 19, 19, 728)  0           add_3[0][0]
# __________________________________________________________________________________________________
# block6_sepconv1 (SeparableConv2 (None, 19, 19, 728)  536536      block6_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block6_sepconv1_bn (BatchNormal (None, 19, 19, 728)  2912        block6_sepconv1[0][0]
# __________________________________________________________________________________________________
# block6_sepconv2_act (Activation (None, 19, 19, 728)  0           block6_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block6_sepconv2 (SeparableConv2 (None, 19, 19, 728)  536536      block6_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block6_sepconv2_bn (BatchNormal (None, 19, 19, 728)  2912        block6_sepconv2[0][0]
# __________________________________________________________________________________________________
# block6_sepconv3_act (Activation (None, 19, 19, 728)  0           block6_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block6_sepconv3 (SeparableConv2 (None, 19, 19, 728)  536536      block6_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block6_sepconv3_bn (BatchNormal (None, 19, 19, 728)  2912        block6_sepconv3[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_4 (Glo (None, 728)          0           block6_sepconv3_bn[0][0]
# __________________________________________________________________________________________________
# reshape_4 (Reshape)             (None, 1, 1, 728)    0           global_average_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 1, 1, 45)     32760       reshape_4[0][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, 1, 1, 728)    32760       dense_8[0][0]
# __________________________________________________________________________________________________
# multiply_4 (Multiply)           (None, 19, 19, 728)  0           block6_sepconv3_bn[0][0]
#                                                                  dense_9[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 19, 19, 728)  0           multiply_4[0][0]
#                                                                  add_3[0][0]
# __________________________________________________________________________________________________
# block7_sepconv1_act (Activation (None, 19, 19, 728)  0           add_4[0][0]
# __________________________________________________________________________________________________
# block7_sepconv1 (SeparableConv2 (None, 19, 19, 728)  536536      block7_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block7_sepconv1_bn (BatchNormal (None, 19, 19, 728)  2912        block7_sepconv1[0][0]
# __________________________________________________________________________________________________
# block7_sepconv2_act (Activation (None, 19, 19, 728)  0           block7_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block7_sepconv2 (SeparableConv2 (None, 19, 19, 728)  536536      block7_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block7_sepconv2_bn (BatchNormal (None, 19, 19, 728)  2912        block7_sepconv2[0][0]
# __________________________________________________________________________________________________
# block7_sepconv3_act (Activation (None, 19, 19, 728)  0           block7_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block7_sepconv3 (SeparableConv2 (None, 19, 19, 728)  536536      block7_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block7_sepconv3_bn (BatchNormal (None, 19, 19, 728)  2912        block7_sepconv3[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_5 (Glo (None, 728)          0           block7_sepconv3_bn[0][0]
# __________________________________________________________________________________________________
# reshape_5 (Reshape)             (None, 1, 1, 728)    0           global_average_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# dense_10 (Dense)                (None, 1, 1, 45)     32760       reshape_5[0][0]
# __________________________________________________________________________________________________
# dense_11 (Dense)                (None, 1, 1, 728)    32760       dense_10[0][0]
# __________________________________________________________________________________________________
# multiply_5 (Multiply)           (None, 19, 19, 728)  0           block7_sepconv3_bn[0][0]
#                                                                  dense_11[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 19, 19, 728)  0           multiply_5[0][0]
#                                                                  add_4[0][0]
# __________________________________________________________________________________________________
# block8_sepconv1_act (Activation (None, 19, 19, 728)  0           add_5[0][0]
# __________________________________________________________________________________________________
# block8_sepconv1 (SeparableConv2 (None, 19, 19, 728)  536536      block8_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block8_sepconv1_bn (BatchNormal (None, 19, 19, 728)  2912        block8_sepconv1[0][0]
# __________________________________________________________________________________________________
# block8_sepconv2_act (Activation (None, 19, 19, 728)  0           block8_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block8_sepconv2 (SeparableConv2 (None, 19, 19, 728)  536536      block8_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block8_sepconv2_bn (BatchNormal (None, 19, 19, 728)  2912        block8_sepconv2[0][0]
# __________________________________________________________________________________________________
# block8_sepconv3_act (Activation (None, 19, 19, 728)  0           block8_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block8_sepconv3 (SeparableConv2 (None, 19, 19, 728)  536536      block8_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block8_sepconv3_bn (BatchNormal (None, 19, 19, 728)  2912        block8_sepconv3[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_6 (Glo (None, 728)          0           block8_sepconv3_bn[0][0]
# __________________________________________________________________________________________________
# reshape_6 (Reshape)             (None, 1, 1, 728)    0           global_average_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# dense_12 (Dense)                (None, 1, 1, 45)     32760       reshape_6[0][0]
# __________________________________________________________________________________________________
# dense_13 (Dense)                (None, 1, 1, 728)    32760       dense_12[0][0]
# __________________________________________________________________________________________________
# multiply_6 (Multiply)           (None, 19, 19, 728)  0           block8_sepconv3_bn[0][0]
#                                                                  dense_13[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 19, 19, 728)  0           multiply_6[0][0]
#                                                                  add_5[0][0]
# __________________________________________________________________________________________________
# block9_sepconv1_act (Activation (None, 19, 19, 728)  0           add_6[0][0]
# __________________________________________________________________________________________________
# block9_sepconv1 (SeparableConv2 (None, 19, 19, 728)  536536      block9_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block9_sepconv1_bn (BatchNormal (None, 19, 19, 728)  2912        block9_sepconv1[0][0]
# __________________________________________________________________________________________________
# block9_sepconv2_act (Activation (None, 19, 19, 728)  0           block9_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block9_sepconv2 (SeparableConv2 (None, 19, 19, 728)  536536      block9_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block9_sepconv2_bn (BatchNormal (None, 19, 19, 728)  2912        block9_sepconv2[0][0]
# __________________________________________________________________________________________________
# block9_sepconv3_act (Activation (None, 19, 19, 728)  0           block9_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block9_sepconv3 (SeparableConv2 (None, 19, 19, 728)  536536      block9_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block9_sepconv3_bn (BatchNormal (None, 19, 19, 728)  2912        block9_sepconv3[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_7 (Glo (None, 728)          0           block9_sepconv3_bn[0][0]
# __________________________________________________________________________________________________
# reshape_7 (Reshape)             (None, 1, 1, 728)    0           global_average_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# dense_14 (Dense)                (None, 1, 1, 45)     32760       reshape_7[0][0]
# __________________________________________________________________________________________________
# dense_15 (Dense)                (None, 1, 1, 728)    32760       dense_14[0][0]
# __________________________________________________________________________________________________
# multiply_7 (Multiply)           (None, 19, 19, 728)  0           block9_sepconv3_bn[0][0]
#                                                                  dense_15[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 19, 19, 728)  0           multiply_7[0][0]
#                                                                  add_6[0][0]
# __________________________________________________________________________________________________
# block10_sepconv1_act (Activatio (None, 19, 19, 728)  0           add_7[0][0]
# __________________________________________________________________________________________________
# block10_sepconv1 (SeparableConv (None, 19, 19, 728)  536536      block10_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block10_sepconv1_bn (BatchNorma (None, 19, 19, 728)  2912        block10_sepconv1[0][0]
# __________________________________________________________________________________________________
# block10_sepconv2_act (Activatio (None, 19, 19, 728)  0           block10_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block10_sepconv2 (SeparableConv (None, 19, 19, 728)  536536      block10_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block10_sepconv2_bn (BatchNorma (None, 19, 19, 728)  2912        block10_sepconv2[0][0]
# __________________________________________________________________________________________________
# block10_sepconv3_act (Activatio (None, 19, 19, 728)  0           block10_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block10_sepconv3 (SeparableConv (None, 19, 19, 728)  536536      block10_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block10_sepconv3_bn (BatchNorma (None, 19, 19, 728)  2912        block10_sepconv3[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_8 (Glo (None, 728)          0           block10_sepconv3_bn[0][0]
# __________________________________________________________________________________________________
# reshape_8 (Reshape)             (None, 1, 1, 728)    0           global_average_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# dense_16 (Dense)                (None, 1, 1, 45)     32760       reshape_8[0][0]
# __________________________________________________________________________________________________
# dense_17 (Dense)                (None, 1, 1, 728)    32760       dense_16[0][0]
# __________________________________________________________________________________________________
# multiply_8 (Multiply)           (None, 19, 19, 728)  0           block10_sepconv3_bn[0][0]
#                                                                  dense_17[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 19, 19, 728)  0           multiply_8[0][0]
#                                                                  add_7[0][0]
# __________________________________________________________________________________________________
# block11_sepconv1_act (Activatio (None, 19, 19, 728)  0           add_8[0][0]
# __________________________________________________________________________________________________
# block11_sepconv1 (SeparableConv (None, 19, 19, 728)  536536      block11_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block11_sepconv1_bn (BatchNorma (None, 19, 19, 728)  2912        block11_sepconv1[0][0]
# __________________________________________________________________________________________________
# block11_sepconv2_act (Activatio (None, 19, 19, 728)  0           block11_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block11_sepconv2 (SeparableConv (None, 19, 19, 728)  536536      block11_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block11_sepconv2_bn (BatchNorma (None, 19, 19, 728)  2912        block11_sepconv2[0][0]
# __________________________________________________________________________________________________
# block11_sepconv3_act (Activatio (None, 19, 19, 728)  0           block11_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block11_sepconv3 (SeparableConv (None, 19, 19, 728)  536536      block11_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block11_sepconv3_bn (BatchNorma (None, 19, 19, 728)  2912        block11_sepconv3[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_9 (Glo (None, 728)          0           block11_sepconv3_bn[0][0]
# __________________________________________________________________________________________________
# reshape_9 (Reshape)             (None, 1, 1, 728)    0           global_average_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# dense_18 (Dense)                (None, 1, 1, 45)     32760       reshape_9[0][0]
# __________________________________________________________________________________________________
# dense_19 (Dense)                (None, 1, 1, 728)    32760       dense_18[0][0]
# __________________________________________________________________________________________________
# multiply_9 (Multiply)           (None, 19, 19, 728)  0           block11_sepconv3_bn[0][0]
#                                                                  dense_19[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 19, 19, 728)  0           multiply_9[0][0]
#                                                                  add_8[0][0]
# __________________________________________________________________________________________________
# block12_sepconv1_act (Activatio (None, 19, 19, 728)  0           add_9[0][0]
# __________________________________________________________________________________________________
# block12_sepconv1 (SeparableConv (None, 19, 19, 728)  536536      block12_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block12_sepconv1_bn (BatchNorma (None, 19, 19, 728)  2912        block12_sepconv1[0][0]
# __________________________________________________________________________________________________
# block12_sepconv2_act (Activatio (None, 19, 19, 728)  0           block12_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block12_sepconv2 (SeparableConv (None, 19, 19, 728)  536536      block12_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block12_sepconv2_bn (BatchNorma (None, 19, 19, 728)  2912        block12_sepconv2[0][0]
# __________________________________________________________________________________________________
# block12_sepconv3_act (Activatio (None, 19, 19, 728)  0           block12_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block12_sepconv3 (SeparableConv (None, 19, 19, 728)  536536      block12_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block12_sepconv3_bn (BatchNorma (None, 19, 19, 728)  2912        block12_sepconv3[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_10 (Gl (None, 728)          0           block12_sepconv3_bn[0][0]
# __________________________________________________________________________________________________
# reshape_10 (Reshape)            (None, 1, 1, 728)    0           global_average_pooling2d_10[0][0]
# __________________________________________________________________________________________________
# dense_20 (Dense)                (None, 1, 1, 45)     32760       reshape_10[0][0]
# __________________________________________________________________________________________________
# dense_21 (Dense)                (None, 1, 1, 728)    32760       dense_20[0][0]
# __________________________________________________________________________________________________
# multiply_10 (Multiply)          (None, 19, 19, 728)  0           block12_sepconv3_bn[0][0]
#                                                                  dense_21[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 19, 19, 728)  0           multiply_10[0][0]
#                                                                  add_9[0][0]
# __________________________________________________________________________________________________
# block13_sepconv1_act (Activatio (None, 19, 19, 728)  0           add_10[0][0]
# __________________________________________________________________________________________________
# block13_sepconv1 (SeparableConv (None, 19, 19, 728)  536536      block13_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block13_sepconv1_bn (BatchNorma (None, 19, 19, 728)  2912        block13_sepconv1[0][0]
# __________________________________________________________________________________________________
# block13_sepconv2_act (Activatio (None, 19, 19, 728)  0           block13_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block13_sepconv2 (SeparableConv (None, 19, 19, 1024) 752024      block13_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block13_sepconv2_bn (BatchNorma (None, 19, 19, 1024) 4096        block13_sepconv2[0][0]
# __________________________________________________________________________________________________
# block13_pool (MaxPooling2D)     (None, 10, 10, 1024) 0           block13_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_11 (Gl (None, 1024)         0           block13_pool[0][0]
# __________________________________________________________________________________________________
# reshape_11 (Reshape)            (None, 1, 1, 1024)   0           global_average_pooling2d_11[0][0]
# __________________________________________________________________________________________________
# dense_22 (Dense)                (None, 1, 1, 64)     65536       reshape_11[0][0]
# __________________________________________________________________________________________________
# dense_23 (Dense)                (None, 1, 1, 1024)   65536       dense_22[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 10, 10, 1024) 745472      add_10[0][0]
# __________________________________________________________________________________________________
# multiply_11 (Multiply)          (None, 10, 10, 1024) 0           block13_pool[0][0]
#                                                                  dense_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 10, 10, 1024) 4096        conv2d_3[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 10, 10, 1024) 0           multiply_11[0][0]
#                                                                  batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# block14_sepconv1 (SeparableConv (None, 10, 10, 1536) 1582080     add_11[0][0]
# __________________________________________________________________________________________________
# block14_sepconv1_bn (BatchNorma (None, 10, 10, 1536) 6144        block14_sepconv1[0][0]
# __________________________________________________________________________________________________
# block14_sepconv1_act (Activatio (None, 10, 10, 1536) 0           block14_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block14_sepconv2 (SeparableConv (None, 10, 10, 2048) 3159552     block14_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block14_sepconv2_bn (BatchNorma (None, 10, 10, 2048) 8192        block14_sepconv2[0][0]
# __________________________________________________________________________________________________
# block14_sepconv2_act (Activatio (None, 10, 10, 2048) 0           block14_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# avg_pool (GlobalAveragePooling2 (None, 2048)         0           block14_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 2048)         0           avg_pool[0][0]
# __________________________________________________________________________________________________
# predictions (Dense)             (None, 67)           137283      dropout[0][0]
# ==================================================================================================
# Total params: 21,729,755
# Trainable params: 21,675,227
# Non-trainable params: 54,528
# __________________________________________________________________________________________________

# %%
# 폴더 생성

os.makedirs(os.path.join(dir,'model_output',number,model.name), exist_ok=True)
os.makedirs(os.path.join(dir,'train_valid_output',number), exist_ok=True)

# %%
# 참고 : https://github.com/OverLordGoldDragon/keras-adamw

import sys
sys.path.append('/content/drive/My Drive/Colab Notebooks/Paper')
import utils
import optimizers_v2
from utils import get_weight_decays, fill_dict_in_order
from utils import reset_seeds, K_eval
from optimizers_v2 import AdamW, NadamW, SGDW

# %%
# top-5 accuracy 출력
import functools
top5_acc = functools.partial(ks.metrics.top_k_categorical_accuracy, k=5)
top5_acc.__name__ = 'top5_acc'

# %%
optimizer = AdamW(model=model, use_cosine_annealing=False, total_iterations = len(x_train) // batch_sizes)
#optimizer = Adam()
filepath =  os.path.join(dir,'model_output',number,model.name,'{epoch:03d}.h5')

callbacks_list = [ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_weights_only=False, save_best_only=True, mode='min'),
                  ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_weights_only=False, save_best_only=True, mode='max'),
                  #ReduceLROnPlateau(monitor='val_loss',patience=3,factor=0.1,min_lr=1e-5),
                  LearningRateScheduler(lr_schedule,verbose=1)
                  ]
                  
model.compile(optimizer, loss = 'categorical_crossentropy', metrics=['accuracy',top5_acc,macro_f1score])

# %%
######## flow_from_directory
history = model.fit(train_generator, steps_per_epoch=int(len(x_train)/batch_sizes),  validation_data = valid_generator, epochs=epochs, verbose=1 , callbacks = callbacks_list , validation_steps=int(len(x_valid)/batch_sizes))
# Out:
# Learning rate:  0.001
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 1/70
# 0.0(L1), 5.070201252832911e-08(L2) weight decay set for block1_conv1/kernel:0
# 0.0(L1), 5.070201252832911e-08(L2) weight decay set for block1_conv2/kernel:0
# 0.0(L1), 5.070201252832911e-08(L2) weight decay set for dense/kernel:0
# 0.0(L1), 5.070201252832911e-08(L2) weight decay set for dense_1/kernel:0
# 0.0(L1), 5.070201252832911e-08(L2) weight decay set for conv2d/kernel:0
# 0.0(L1), 5.070201252832911e-08(L2) weight decay set for dense_2/kernel:0
# 0.0(L1), 5.070201252832911e-08(L2) weight decay set for dense_3/kernel:0
# 0.0(L1), 5.070201252832911e-08(L2) weight decay set for conv2d_1/kernel:0
# 0.0(L1), 5.070201252832911e-08(L2) weight decay set for dense_4/kernel:0
# 0.0(L1), 5.070201252832911e-08(L2) weight decay set for dense_5/kernel:0
# 0.0(L1), 5.070201252832911e-08(L2) weight decay set for conv2d_2/kernel:0
# 0.0(L1), 5.070201252832911e-08(L2) weight decay set for dense_6/kernel:0
# 0.0(L1), 5.070201252832911e-08(L2) weight decay set for dense_7/kernel:0
# 0.0(L1), 5.070201252832911e-08(L2) weight decay set for dense_8/kernel:0
# 0.0(L1), 5.070201252832911e-08(L2) weight decay set for dense_9/kernel:0
# 0.0(L1), 5.070201252832911e-08(L2) weight decay set for dense_10/kernel:0
# 0.0(L1), 5.070201252832911e-08(L2) weight decay set for dense_11/kernel:0
# 0.0(L1), 5.070201252832911e-08(L2) weight decay set for dense_12/kernel:0
# 0.0(L1), 5.070201252832911e-08(L2) weight decay set for dense_13/kernel:0
# 0.0(L1), 5.070201252832911e-08(L2) weight decay set for dense_14/kernel:0
# 0.0(L1), 5.070201252832911e-08(L2) weight decay set for dense_15/kernel:0
# 0.0(L1), 5.070201252832911e-08(L2) weight decay set for dense_16/kernel:0
# 0.0(L1), 5.070201252832911e-08(L2) weight decay set for dense_17/kernel:0
# 0.0(L1), 5.070201252832911e-08(L2) weight decay set for dense_18/kernel:0
# 0.0(L1), 5.070201252832911e-08(L2) weight decay set for dense_19/kernel:0
# 0.0(L1), 5.070201252832911e-08(L2) weight decay set for dense_20/kernel:0
# 0.0(L1), 5.070201252832911e-08(L2) weight decay set for dense_21/kernel:0
# 0.0(L1), 5.070201252832911e-08(L2) weight decay set for dense_22/kernel:0
# 0.0(L1), 5.070201252832911e-08(L2) weight decay set for dense_23/kernel:0
# 0.0(L1), 5.070201252832911e-08(L2) weight decay set for conv2d_3/kernel:0
# 0.0(L1), 5.070201252832911e-08(L2) weight decay set for predictions/kernel:0
# 389/389 [==============================] - ETA: 0s - loss: 3.8090 - accuracy: 0.0979 - top5_acc: 0.3464 - macro_f1score: 9.4898e-04
# Epoch 00001: val_loss improved from inf to 4.39393, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/SE_Xception/001.h5
#
# Epoch 00001: val_accuracy improved from -inf to 0.05143, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/SE_Xception/001.h5
# 389/389 [==============================] - 6146s 16s/step - loss: 3.8090 - accuracy: 0.0979 - top5_acc: 0.3464 - macro_f1score: 9.4898e-04 - val_loss: 4.3939 - val_accuracy: 0.0514 - val_top5_acc: 0.2116 - val_macro_f1score: 3.1095e-04
# Learning rate:  0.001
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 2/70
# 389/389 [==============================] - ETA: 0s - loss: 3.3995 - accuracy: 0.1593 - top5_acc: 0.4462 - macro_f1score: 0.0036
# Epoch 00002: val_loss improved from 4.39393 to 4.05518, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/SE_Xception/002.h5
#
# Epoch 00002: val_accuracy improved from 0.05143 to 0.14844, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/SE_Xception/002.h5
# 389/389 [==============================] - 409s 1s/step - loss: 3.3995 - accuracy: 0.1593 - top5_acc: 0.4462 - macro_f1score: 0.0036 - val_loss: 4.0552 - val_accuracy: 0.1484 - val_top5_acc: 0.4232 - val_macro_f1score: 0.0097
# Learning rate:  0.001
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 3/70
# 389/389 [==============================] - ETA: 0s - loss: 3.0943 - accuracy: 0.2195 - top5_acc: 0.5323 - macro_f1score: 0.0131
# Epoch 00003: val_loss improved from 4.05518 to 3.64458, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/SE_Xception/003.h5
#
# Epoch 00003: val_accuracy improved from 0.14844 to 0.18555, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/SE_Xception/003.h5
# 389/389 [==============================] - 402s 1s/step - loss: 3.0943 - accuracy: 0.2195 - top5_acc: 0.5323 - macro_f1score: 0.0131 - val_loss: 3.6446 - val_accuracy: 0.1855 - val_top5_acc: 0.4577 - val_macro_f1score: 0.0284
# Learning rate:  0.001
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 4/70
# 389/389 [==============================] - ETA: 0s - loss: 2.8083 - accuracy: 0.2730 - top5_acc: 0.6128 - macro_f1score: 0.0276
# Epoch 00004: val_loss improved from 3.64458 to 3.28340, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/SE_Xception/004.h5
#
# Epoch 00004: val_accuracy improved from 0.18555 to 0.22331, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/SE_Xception/004.h5
# 389/389 [==============================] - 398s 1s/step - loss: 2.8083 - accuracy: 0.2730 - top5_acc: 0.6128 - macro_f1score: 0.0276 - val_loss: 3.2834 - val_accuracy: 0.2233 - val_top5_acc: 0.5482 - val_macro_f1score: 0.0357
# Learning rate:  0.001
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 5/70
# 389/389 [==============================] - ETA: 0s - loss: 2.5507 - accuracy: 0.3346 - top5_acc: 0.6736 - macro_f1score: 0.0464
# Epoch 00005: val_loss improved from 3.28340 to 3.13045, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/SE_Xception/005.h5
#
# Epoch 00005: val_accuracy improved from 0.22331 to 0.28125, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/SE_Xception/005.h5
# 389/389 [==============================] - 397s 1s/step - loss: 2.5507 - accuracy: 0.3346 - top5_acc: 0.6736 - macro_f1score: 0.0464 - val_loss: 3.1305 - val_accuracy: 0.2812 - val_top5_acc: 0.5885 - val_macro_f1score: 0.0587
# Learning rate:  0.001
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 6/70
# 389/389 [==============================] - ETA: 0s - loss: 2.2976 - accuracy: 0.3908 - top5_acc: 0.7308 - macro_f1score: 0.0695
# Epoch 00006: val_loss improved from 3.13045 to 2.62585, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/SE_Xception/006.h5
#
# Epoch 00006: val_accuracy improved from 0.28125 to 0.34049, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/SE_Xception/006.h5
# 389/389 [==============================] - 393s 1s/step - loss: 2.2976 - accuracy: 0.3908 - top5_acc: 0.7308 - macro_f1score: 0.0695 - val_loss: 2.6258 - val_accuracy: 0.3405 - val_top5_acc: 0.6914 - val_macro_f1score: 0.0754
# Learning rate:  0.001
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 7/70
# 389/389 [==============================] - ETA: 0s - loss: 2.1070 - accuracy: 0.4353 - top5_acc: 0.7664 - macro_f1score: 0.0886
# Epoch 00007: val_loss improved from 2.62585 to 2.58889, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/SE_Xception/007.h5
#
# Epoch 00007: val_accuracy improved from 0.34049 to 0.36784, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/SE_Xception/007.h5
# 389/389 [==============================] - 393s 1s/step - loss: 2.1070 - accuracy: 0.4353 - top5_acc: 0.7664 - macro_f1score: 0.0886 - val_loss: 2.5889 - val_accuracy: 0.3678 - val_top5_acc: 0.6855 - val_macro_f1score: 0.0735
# Learning rate:  0.001
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 8/70
# 389/389 [==============================] - ETA: 0s - loss: 1.9353 - accuracy: 0.4780 - top5_acc: 0.8016 - macro_f1score: 0.1063
# Epoch 00008: val_loss improved from 2.58889 to 2.41734, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/SE_Xception/008.h5
#
# Epoch 00008: val_accuracy improved from 0.36784 to 0.39909, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/SE_Xception/008.h5
# 389/389 [==============================] - 393s 1s/step - loss: 1.9353 - accuracy: 0.4780 - top5_acc: 0.8016 - macro_f1score: 0.1063 - val_loss: 2.4173 - val_accuracy: 0.3991 - val_top5_acc: 0.7389 - val_macro_f1score: 0.0868
# Learning rate:  0.001
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 9/70
# 389/389 [==============================] - ETA: 0s - loss: 1.8266 - accuracy: 0.5004 - top5_acc: 0.8151 - macro_f1score: 0.1180
# Epoch 00009: val_loss did not improve from 2.41734
#
# Epoch 00009: val_accuracy did not improve from 0.39909
# 389/389 [==============================] - 399s 1s/step - loss: 1.8266 - accuracy: 0.5004 - top5_acc: 0.8151 - macro_f1score: 0.1180 - val_loss: 2.7612 - val_accuracy: 0.3477 - val_top5_acc: 0.6667 - val_macro_f1score: 0.0892
# Learning rate:  0.001
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 10/70
# 389/389 [==============================] - ETA: 0s - loss: 1.6789 - accuracy: 0.5375 - top5_acc: 0.8439 - macro_f1score: 0.1365
# Epoch 00010: val_loss improved from 2.41734 to 2.15943, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/SE_Xception/010.h5
#
# Epoch 00010: val_accuracy improved from 0.39909 to 0.46354, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/SE_Xception/010.h5
# 389/389 [==============================] - 397s 1s/step - loss: 1.6789 - accuracy: 0.5375 - top5_acc: 0.8439 - macro_f1score: 0.1365 - val_loss: 2.1594 - val_accuracy: 0.4635 - val_top5_acc: 0.7650 - val_macro_f1score: 0.1065
# Learning rate:  0.001
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 11/70
# 389/389 [==============================] - ETA: 0s - loss: 1.5924 - accuracy: 0.5604 - top5_acc: 0.8616 - macro_f1score: 0.1461
# Epoch 00011: val_loss did not improve from 2.15943
#
# Epoch 00011: val_accuracy did not improve from 0.46354
# 389/389 [==============================] - 394s 1s/step - loss: 1.5924 - accuracy: 0.5604 - top5_acc: 0.8616 - macro_f1score: 0.1461 - val_loss: 3.8845 - val_accuracy: 0.2650 - val_top5_acc: 0.5859 - val_macro_f1score: 0.0664
# Learning rate:  0.001
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 12/70
# 389/389 [==============================] - ETA: 0s - loss: 1.4693 - accuracy: 0.5967 - top5_acc: 0.8806 - macro_f1score: 0.1609
# Epoch 00012: val_loss did not improve from 2.15943
#
# Epoch 00012: val_accuracy did not improve from 0.46354
# 389/389 [==============================] - 387s 994ms/step - loss: 1.4693 - accuracy: 0.5967 - top5_acc: 0.8806 - macro_f1score: 0.1609 - val_loss: 2.3772 - val_accuracy: 0.4570 - val_top5_acc: 0.7721 - val_macro_f1score: 0.1223
# Learning rate:  0.001
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 13/70
# 389/389 [==============================] - ETA: 0s - loss: 1.3951 - accuracy: 0.6087 - top5_acc: 0.8917 - macro_f1score: 0.1692
# Epoch 00013: val_loss improved from 2.15943 to 2.05638, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/SE_Xception/013.h5
#
# Epoch 00013: val_accuracy improved from 0.46354 to 0.48698, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/SE_Xception/013.h5
# 389/389 [==============================] - 388s 997ms/step - loss: 1.3951 - accuracy: 0.6087 - top5_acc: 0.8917 - macro_f1score: 0.1692 - val_loss: 2.0564 - val_accuracy: 0.4870 - val_top5_acc: 0.7995 - val_macro_f1score: 0.1371
# Learning rate:  0.001
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 14/70
# 389/389 [==============================] - ETA: 0s - loss: 1.2791 - accuracy: 0.6407 - top5_acc: 0.9073 - macro_f1score: 0.1838
# Epoch 00014: val_loss did not improve from 2.05638
#
# Epoch 00014: val_accuracy did not improve from 0.48698
# 389/389 [==============================] - 382s 981ms/step - loss: 1.2791 - accuracy: 0.6407 - top5_acc: 0.9073 - macro_f1score: 0.1838 - val_loss: 2.1881 - val_accuracy: 0.4648 - val_top5_acc: 0.7780 - val_macro_f1score: 0.1238
# Learning rate:  0.001
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 15/70
# 389/389 [==============================] - ETA: 0s - loss: 1.2117 - accuracy: 0.6586 - top5_acc: 0.9185 - macro_f1score: 0.1912
# Epoch 00015: val_loss did not improve from 2.05638
#
# Epoch 00015: val_accuracy did not improve from 0.48698
# 389/389 [==============================] - 382s 982ms/step - loss: 1.2117 - accuracy: 0.6586 - top5_acc: 0.9185 - macro_f1score: 0.1912 - val_loss: 2.1500 - val_accuracy: 0.4694 - val_top5_acc: 0.7819 - val_macro_f1score: 0.1324
# Learning rate:  0.001
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 16/70
# 389/389 [==============================] - ETA: 0s - loss: 1.1229 - accuracy: 0.6775 - top5_acc: 0.9290 - macro_f1score: 0.2040
# Epoch 00016: val_loss did not improve from 2.05638
#
# Epoch 00016: val_accuracy did not improve from 0.48698
# 389/389 [==============================] - 388s 998ms/step - loss: 1.1229 - accuracy: 0.6775 - top5_acc: 0.9290 - macro_f1score: 0.2040 - val_loss: 2.2982 - val_accuracy: 0.4818 - val_top5_acc: 0.7910 - val_macro_f1score: 0.1360
# Learning rate:  0.001
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 17/70
# 389/389 [==============================] - ETA: 0s - loss: 1.0622 - accuracy: 0.6959 - top5_acc: 0.9369 - macro_f1score: 0.2135
# Epoch 00017: val_loss did not improve from 2.05638
#
# Epoch 00017: val_accuracy did not improve from 0.48698
# 389/389 [==============================] - 386s 991ms/step - loss: 1.0622 - accuracy: 0.6959 - top5_acc: 0.9369 - macro_f1score: 0.2135 - val_loss: 2.5295 - val_accuracy: 0.4492 - val_top5_acc: 0.7656 - val_macro_f1score: 0.1339
# Learning rate:  0.001
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 18/70
# 389/389 [==============================] - ETA: 0s - loss: 0.9954 - accuracy: 0.7179 - top5_acc: 0.9452 - macro_f1score: 0.2226
# Epoch 00018: val_loss did not improve from 2.05638
#
# Epoch 00018: val_accuracy improved from 0.48698 to 0.49740, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/SE_Xception/018.h5
# 389/389 [==============================] - 383s 984ms/step - loss: 0.9954 - accuracy: 0.7179 - top5_acc: 0.9452 - macro_f1score: 0.2226 - val_loss: 2.2746 - val_accuracy: 0.4974 - val_top5_acc: 0.7721 - val_macro_f1score: 0.1539
# Learning rate:  0.001
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 19/70
# 389/389 [==============================] - ETA: 0s - loss: 0.9148 - accuracy: 0.7369 - top5_acc: 0.9544 - macro_f1score: 0.2317
# Epoch 00019: val_loss did not improve from 2.05638
#
# Epoch 00019: val_accuracy improved from 0.49740 to 0.53711, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/SE_Xception/019.h5
# 389/389 [==============================] - 381s 980ms/step - loss: 0.9148 - accuracy: 0.7369 - top5_acc: 0.9544 - macro_f1score: 0.2317 - val_loss: 2.0872 - val_accuracy: 0.5371 - val_top5_acc: 0.8372 - val_macro_f1score: 0.1613
# Learning rate:  0.001
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 20/70
# 389/389 [==============================] - ETA: 0s - loss: 0.8486 - accuracy: 0.7539 - top5_acc: 0.9591 - macro_f1score: 0.2416
# Epoch 00020: val_loss did not improve from 2.05638
#
# Epoch 00020: val_accuracy did not improve from 0.53711
# 389/389 [==============================] - 387s 994ms/step - loss: 0.8486 - accuracy: 0.7539 - top5_acc: 0.9591 - macro_f1score: 0.2416 - val_loss: 2.5075 - val_accuracy: 0.4694 - val_top5_acc: 0.7917 - val_macro_f1score: 0.1378
# Learning rate:  0.001
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 21/70
# 389/389 [==============================] - ETA: 0s - loss: 0.7933 - accuracy: 0.7718 - top5_acc: 0.9660 - macro_f1score: 0.2512
# Epoch 00021: val_loss improved from 2.05638 to 2.02637, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/SE_Xception/021.h5
#
# Epoch 00021: val_accuracy improved from 0.53711 to 0.55273, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/SE_Xception/021.h5
# 389/389 [==============================] - 406s 1s/step - loss: 0.7933 - accuracy: 0.7718 - top5_acc: 0.9660 - macro_f1score: 0.2512 - val_loss: 2.0264 - val_accuracy: 0.5527 - val_top5_acc: 0.8483 - val_macro_f1score: 0.1678
# Learning rate:  0.001
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 22/70
# 389/389 [==============================] - ETA: 0s - loss: 0.7398 - accuracy: 0.7841 - top5_acc: 0.9743 - macro_f1score: 0.2555
# Epoch 00022: val_loss improved from 2.02637 to 1.96237, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/SE_Xception/022.h5
#
# Epoch 00022: val_accuracy improved from 0.55273 to 0.56445, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/SE_Xception/022.h5
# 389/389 [==============================] - 414s 1s/step - loss: 0.7398 - accuracy: 0.7841 - top5_acc: 0.9743 - macro_f1score: 0.2555 - val_loss: 1.9624 - val_accuracy: 0.5645 - val_top5_acc: 0.8665 - val_macro_f1score: 0.1678
# Learning rate:  0.001
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 23/70
# 389/389 [==============================] - ETA: 0s - loss: 0.6828 - accuracy: 0.8047 - top5_acc: 0.9778 - macro_f1score: 0.2654
# Epoch 00023: val_loss did not improve from 1.96237
#
# Epoch 00023: val_accuracy did not improve from 0.56445
# 389/389 [==============================] - 415s 1s/step - loss: 0.6828 - accuracy: 0.8047 - top5_acc: 0.9778 - macro_f1score: 0.2654 - val_loss: 2.6914 - val_accuracy: 0.4655 - val_top5_acc: 0.7910 - val_macro_f1score: 0.1396
# Learning rate:  0.001
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 24/70
# 389/389 [==============================] - ETA: 0s - loss: 0.6507 - accuracy: 0.8162 - top5_acc: 0.9800 - macro_f1score: 0.2692
# Epoch 00024: val_loss did not improve from 1.96237
#
# Epoch 00024: val_accuracy did not improve from 0.56445
# 389/389 [==============================] - 413s 1s/step - loss: 0.6507 - accuracy: 0.8162 - top5_acc: 0.9800 - macro_f1score: 0.2692 - val_loss: 2.6391 - val_accuracy: 0.4941 - val_top5_acc: 0.8086 - val_macro_f1score: 0.1543
# Learning rate:  0.001
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 25/70
# 389/389 [==============================] - ETA: 0s - loss: 0.6046 - accuracy: 0.8312 - top5_acc: 0.9833 - macro_f1score: 0.2791
# Epoch 00025: val_loss did not improve from 1.96237
#
# Epoch 00025: val_accuracy did not improve from 0.56445
# 389/389 [==============================] - 410s 1s/step - loss: 0.6046 - accuracy: 0.8312 - top5_acc: 0.9833 - macro_f1score: 0.2791 - val_loss: 3.1299 - val_accuracy: 0.4746 - val_top5_acc: 0.7741 - val_macro_f1score: 0.1491
# Learning rate:  0.001
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 26/70
# 389/389 [==============================] - ETA: 0s - loss: 0.5721 - accuracy: 0.8409 - top5_acc: 0.9835 - macro_f1score: 0.2816
# Epoch 00026: val_loss did not improve from 1.96237
#
# Epoch 00026: val_accuracy did not improve from 0.56445
# 389/389 [==============================] - 407s 1s/step - loss: 0.5721 - accuracy: 0.8409 - top5_acc: 0.9835 - macro_f1score: 0.2816 - val_loss: 2.3541 - val_accuracy: 0.5339 - val_top5_acc: 0.7995 - val_macro_f1score: 0.1659
# Learning rate:  0.001
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 27/70
# 389/389 [==============================] - ETA: 0s - loss: 0.5268 - accuracy: 0.8549 - top5_acc: 0.9875 - macro_f1score: 0.2889
# Epoch 00027: val_loss did not improve from 1.96237
#
# Epoch 00027: val_accuracy did not improve from 0.56445
# 389/389 [==============================] - 408s 1s/step - loss: 0.5268 - accuracy: 0.8549 - top5_acc: 0.9875 - macro_f1score: 0.2889 - val_loss: 2.4112 - val_accuracy: 0.5404 - val_top5_acc: 0.8171 - val_macro_f1score: 0.1641
# Learning rate:  0.001
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 28/70
# 389/389 [==============================] - ETA: 0s - loss: 0.4882 - accuracy: 0.8682 - top5_acc: 0.9887 - macro_f1score: 0.2966
# Epoch 00028: val_loss did not improve from 1.96237
#
# Epoch 00028: val_accuracy did not improve from 0.56445
# 389/389 [==============================] - 405s 1s/step - loss: 0.4882 - accuracy: 0.8682 - top5_acc: 0.9887 - macro_f1score: 0.2966 - val_loss: 2.3913 - val_accuracy: 0.5495 - val_top5_acc: 0.8496 - val_macro_f1score: 0.1719
# Learning rate:  0.001
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 29/70
# 389/389 [==============================] - ETA: 0s - loss: 0.4704 - accuracy: 0.8720 - top5_acc: 0.9913 - macro_f1score: 0.2973
# Epoch 00029: val_loss did not improve from 1.96237
#
# Epoch 00029: val_accuracy did not improve from 0.56445
# 389/389 [==============================] - 403s 1s/step - loss: 0.4704 - accuracy: 0.8720 - top5_acc: 0.9913 - macro_f1score: 0.2973 - val_loss: 2.2898 - val_accuracy: 0.5443 - val_top5_acc: 0.8327 - val_macro_f1score: 0.1707
# Learning rate:  0.001
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 30/70
# 389/389 [==============================] - ETA: 0s - loss: 0.4592 - accuracy: 0.8764 - top5_acc: 0.9913 - macro_f1score: 0.2995
# Epoch 00030: val_loss did not improve from 1.96237
#
# Epoch 00030: val_accuracy did not improve from 0.56445
# 389/389 [==============================] - 407s 1s/step - loss: 0.4592 - accuracy: 0.8764 - top5_acc: 0.9913 - macro_f1score: 0.2995 - val_loss: 2.3306 - val_accuracy: 0.5417 - val_top5_acc: 0.8353 - val_macro_f1score: 0.1736
# Learning rate:  0.0001
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 31/70
# 389/389 [==============================] - ETA: 0s - loss: 0.2858 - accuracy: 0.9332 - top5_acc: 0.9978 - macro_f1score: 0.3229
# Epoch 00031: val_loss improved from 1.96237 to 1.65697, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/SE_Xception/031.h5
#
# Epoch 00031: val_accuracy improved from 0.56445 to 0.64779, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/SE_Xception/031.h5
# 389/389 [==============================] - 415s 1s/step - loss: 0.2858 - accuracy: 0.9332 - top5_acc: 0.9978 - macro_f1score: 0.3229 - val_loss: 1.6570 - val_accuracy: 0.6478 - val_top5_acc: 0.8971 - val_macro_f1score: 0.2092
# Learning rate:  0.0001
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 32/70
# 389/389 [==============================] - ETA: 0s - loss: 0.2289 - accuracy: 0.9563 - top5_acc: 0.9986 - macro_f1score: 0.3325
# Epoch 00032: val_loss improved from 1.65697 to 1.64725, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/SE_Xception/032.h5
#
# Epoch 00032: val_accuracy improved from 0.64779 to 0.65365, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/SE_Xception/032.h5
# 389/389 [==============================] - 414s 1s/step - loss: 0.2289 - accuracy: 0.9563 - top5_acc: 0.9986 - macro_f1score: 0.3325 - val_loss: 1.6472 - val_accuracy: 0.6536 - val_top5_acc: 0.9017 - val_macro_f1score: 0.2076
# Learning rate:  0.0001
#
# Epoch 00033: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 33/70
# 389/389 [==============================] - ETA: 0s - loss: 0.2085 - accuracy: 0.9623 - top5_acc: 0.9986 - macro_f1score: 0.3373
# Epoch 00033: val_loss did not improve from 1.64725
#
# Epoch 00033: val_accuracy improved from 0.65365 to 0.65430, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/SE_Xception/033.h5
# 389/389 [==============================] - 412s 1s/step - loss: 0.2085 - accuracy: 0.9623 - top5_acc: 0.9986 - macro_f1score: 0.3373 - val_loss: 1.6607 - val_accuracy: 0.6543 - val_top5_acc: 0.8991 - val_macro_f1score: 0.2057
# Learning rate:  0.0001
#
# Epoch 00034: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 34/70
# 389/389 [==============================] - ETA: 0s - loss: 0.1965 - accuracy: 0.9651 - top5_acc: 0.9995 - macro_f1score: 0.3360
# Epoch 00034: val_loss did not improve from 1.64725
#
# Epoch 00034: val_accuracy did not improve from 0.65430
# 389/389 [==============================] - 407s 1s/step - loss: 0.1965 - accuracy: 0.9651 - top5_acc: 0.9995 - macro_f1score: 0.3360 - val_loss: 1.7162 - val_accuracy: 0.6432 - val_top5_acc: 0.8926 - val_macro_f1score: 0.2041
# Learning rate:  0.0001
#
# Epoch 00035: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 35/70
# 389/389 [==============================] - ETA: 0s - loss: 0.1872 - accuracy: 0.9690 - top5_acc: 0.9997 - macro_f1score: 0.3384
# Epoch 00035: val_loss did not improve from 1.64725
#
# Epoch 00035: val_accuracy improved from 0.65430 to 0.65755, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/SE_Xception/035.h5
# 389/389 [==============================] - 406s 1s/step - loss: 0.1872 - accuracy: 0.9690 - top5_acc: 0.9997 - macro_f1score: 0.3384 - val_loss: 1.6780 - val_accuracy: 0.6576 - val_top5_acc: 0.8991 - val_macro_f1score: 0.2069
# Learning rate:  0.0001
#
# Epoch 00036: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 36/70
# 389/389 [==============================] - ETA: 0s - loss: 0.1804 - accuracy: 0.9698 - top5_acc: 1.0000 - macro_f1score: 0.3387
# Epoch 00036: val_loss did not improve from 1.64725
#
# Epoch 00036: val_accuracy did not improve from 0.65755
# 389/389 [==============================] - 410s 1s/step - loss: 0.1804 - accuracy: 0.9698 - top5_acc: 1.0000 - macro_f1score: 0.3387 - val_loss: 1.7217 - val_accuracy: 0.6491 - val_top5_acc: 0.8893 - val_macro_f1score: 0.2057
# Learning rate:  0.0001
#
# Epoch 00037: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 37/70
# 389/389 [==============================] - ETA: 0s - loss: 0.1668 - accuracy: 0.9743 - top5_acc: 0.9997 - macro_f1score: 0.3402
# Epoch 00037: val_loss did not improve from 1.64725
#
# Epoch 00037: val_accuracy did not improve from 0.65755
# 389/389 [==============================] - 410s 1s/step - loss: 0.1668 - accuracy: 0.9743 - top5_acc: 0.9997 - macro_f1score: 0.3402 - val_loss: 1.6889 - val_accuracy: 0.6510 - val_top5_acc: 0.9004 - val_macro_f1score: 0.2073
# Learning rate:  0.0001
#
# Epoch 00038: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 38/70
# 389/389 [==============================] - ETA: 0s - loss: 0.1607 - accuracy: 0.9777 - top5_acc: 0.9996 - macro_f1score: 0.3429
# Epoch 00038: val_loss did not improve from 1.64725
#
# Epoch 00038: val_accuracy did not improve from 0.65755
# 389/389 [==============================] - 409s 1s/step - loss: 0.1607 - accuracy: 0.9777 - top5_acc: 0.9996 - macro_f1score: 0.3429 - val_loss: 1.7369 - val_accuracy: 0.6510 - val_top5_acc: 0.8926 - val_macro_f1score: 0.2066
# Learning rate:  0.0001
#
# Epoch 00039: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 39/70
# 389/389 [==============================] - ETA: 0s - loss: 0.1576 - accuracy: 0.9759 - top5_acc: 0.9999 - macro_f1score: 0.3404
# Epoch 00039: val_loss did not improve from 1.64725
#
# Epoch 00039: val_accuracy did not improve from 0.65755
# 389/389 [==============================] - 407s 1s/step - loss: 0.1576 - accuracy: 0.9759 - top5_acc: 0.9999 - macro_f1score: 0.3404 - val_loss: 1.7754 - val_accuracy: 0.6400 - val_top5_acc: 0.8861 - val_macro_f1score: 0.2043
# Learning rate:  0.0001
#
# Epoch 00040: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 40/70
# 389/389 [==============================] - ETA: 0s - loss: 0.1544 - accuracy: 0.9769 - top5_acc: 0.9998 - macro_f1score: 0.3414
# Epoch 00040: val_loss did not improve from 1.64725
#
# Epoch 00040: val_accuracy did not improve from 0.65755
# 389/389 [==============================] - 412s 1s/step - loss: 0.1544 - accuracy: 0.9769 - top5_acc: 0.9998 - macro_f1score: 0.3414 - val_loss: 1.7411 - val_accuracy: 0.6530 - val_top5_acc: 0.8932 - val_macro_f1score: 0.2127
# Learning rate:  0.0001
#
# Epoch 00041: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 41/70
# 389/389 [==============================] - ETA: 0s - loss: 0.1489 - accuracy: 0.9803 - top5_acc: 0.9998 - macro_f1score: 0.3434
# Epoch 00041: val_loss did not improve from 1.64725
#
# Epoch 00041: val_accuracy did not improve from 0.65755
# 389/389 [==============================] - 411s 1s/step - loss: 0.1489 - accuracy: 0.9803 - top5_acc: 0.9998 - macro_f1score: 0.3434 - val_loss: 1.7802 - val_accuracy: 0.6458 - val_top5_acc: 0.8926 - val_macro_f1score: 0.2115
# Learning rate:  0.0001
#
# Epoch 00042: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 42/70
# 389/389 [==============================] - ETA: 0s - loss: 0.1485 - accuracy: 0.9797 - top5_acc: 0.9999 - macro_f1score: 0.3420
# Epoch 00042: val_loss did not improve from 1.64725
#
# Epoch 00042: val_accuracy did not improve from 0.65755
# 389/389 [==============================] - 410s 1s/step - loss: 0.1485 - accuracy: 0.9797 - top5_acc: 0.9999 - macro_f1score: 0.3420 - val_loss: 1.7419 - val_accuracy: 0.6452 - val_top5_acc: 0.8945 - val_macro_f1score: 0.2116
# Learning rate:  0.0001
#
# Epoch 00043: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 43/70
# 389/389 [==============================] - ETA: 0s - loss: 0.1409 - accuracy: 0.9811 - top5_acc: 0.9998 - macro_f1score: 0.3440
# Epoch 00043: val_loss did not improve from 1.64725
#
# Epoch 00043: val_accuracy did not improve from 0.65755
# 389/389 [==============================] - 413s 1s/step - loss: 0.1409 - accuracy: 0.9811 - top5_acc: 0.9998 - macro_f1score: 0.3440 - val_loss: 1.7259 - val_accuracy: 0.6543 - val_top5_acc: 0.8997 - val_macro_f1score: 0.2106
# Learning rate:  0.0001
#
# Epoch 00044: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 44/70
# 389/389 [==============================] - ETA: 0s - loss: 0.1365 - accuracy: 0.9838 - top5_acc: 0.9999 - macro_f1score: 0.3455
# Epoch 00044: val_loss did not improve from 1.64725
#
# Epoch 00044: val_accuracy did not improve from 0.65755
# 389/389 [==============================] - 410s 1s/step - loss: 0.1365 - accuracy: 0.9838 - top5_acc: 0.9999 - macro_f1score: 0.3455 - val_loss: 1.7330 - val_accuracy: 0.6478 - val_top5_acc: 0.8926 - val_macro_f1score: 0.2091
# Learning rate:  0.0001
#
# Epoch 00045: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 45/70
# 389/389 [==============================] - ETA: 0s - loss: 0.1305 - accuracy: 0.9854 - top5_acc: 0.9998 - macro_f1score: 0.3465
# Epoch 00045: val_loss did not improve from 1.64725
#
# Epoch 00045: val_accuracy did not improve from 0.65755
# 389/389 [==============================] - 412s 1s/step - loss: 0.1305 - accuracy: 0.9854 - top5_acc: 0.9998 - macro_f1score: 0.3465 - val_loss: 1.7650 - val_accuracy: 0.6478 - val_top5_acc: 0.9004 - val_macro_f1score: 0.2102
# Learning rate:  0.0001
#
# Epoch 00046: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 46/70
# 389/389 [==============================] - ETA: 0s - loss: 0.1295 - accuracy: 0.9850 - top5_acc: 0.9999 - macro_f1score: 0.3455
# Epoch 00046: val_loss did not improve from 1.64725
#
# Epoch 00046: val_accuracy did not improve from 0.65755
# 389/389 [==============================] - 410s 1s/step - loss: 0.1295 - accuracy: 0.9850 - top5_acc: 0.9999 - macro_f1score: 0.3455 - val_loss: 1.7557 - val_accuracy: 0.6562 - val_top5_acc: 0.8978 - val_macro_f1score: 0.2083
# Learning rate:  0.0001
#
# Epoch 00047: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 47/70
# 389/389 [==============================] - ETA: 0s - loss: 0.1294 - accuracy: 0.9848 - top5_acc: 0.9998 - macro_f1score: 0.3432
# Epoch 00047: val_loss did not improve from 1.64725
#
# Epoch 00047: val_accuracy improved from 0.65755 to 0.66016, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/SE_Xception/047.h5
# 389/389 [==============================] - 412s 1s/step - loss: 0.1294 - accuracy: 0.9848 - top5_acc: 0.9998 - macro_f1score: 0.3432 - val_loss: 1.7476 - val_accuracy: 0.6602 - val_top5_acc: 0.8978 - val_macro_f1score: 0.2089
# Learning rate:  0.0001
#
# Epoch 00048: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 48/70
# 389/389 [==============================] - ETA: 0s - loss: 0.1285 - accuracy: 0.9841 - top5_acc: 0.9999 - macro_f1score: 0.3462
# Epoch 00048: val_loss did not improve from 1.64725
#
# Epoch 00048: val_accuracy did not improve from 0.66016
# 389/389 [==============================] - 410s 1s/step - loss: 0.1285 - accuracy: 0.9841 - top5_acc: 0.9999 - macro_f1score: 0.3462 - val_loss: 1.8458 - val_accuracy: 0.6458 - val_top5_acc: 0.8958 - val_macro_f1score: 0.2131
# Learning rate:  0.0001
#
# Epoch 00049: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 49/70
# 389/389 [==============================] - ETA: 0s - loss: 0.1278 - accuracy: 0.9849 - top5_acc: 0.9998 - macro_f1score: 0.3457
# Epoch 00049: val_loss did not improve from 1.64725
#
# Epoch 00049: val_accuracy did not improve from 0.66016
# 389/389 [==============================] - 407s 1s/step - loss: 0.1278 - accuracy: 0.9849 - top5_acc: 0.9998 - macro_f1score: 0.3457 - val_loss: 1.8054 - val_accuracy: 0.6497 - val_top5_acc: 0.8919 - val_macro_f1score: 0.2094
# Learning rate:  0.0001
#
# Epoch 00050: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 50/70
# 389/389 [==============================] - ETA: 0s - loss: 0.1267 - accuracy: 0.9852 - top5_acc: 1.0000 - macro_f1score: 0.3440
# Epoch 00050: val_loss did not improve from 1.64725
#
# Epoch 00050: val_accuracy did not improve from 0.66016
# 389/389 [==============================] - 399s 1s/step - loss: 0.1267 - accuracy: 0.9852 - top5_acc: 1.0000 - macro_f1score: 0.3440 - val_loss: 1.8129 - val_accuracy: 0.6484 - val_top5_acc: 0.8991 - val_macro_f1score: 0.2104
# Learning rate:  0.0001
#
# Epoch 00051: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 51/70
# 389/389 [==============================] - ETA: 0s - loss: 0.1188 - accuracy: 0.9876 - top5_acc: 0.9998 - macro_f1score: 0.3430
# Epoch 00051: val_loss did not improve from 1.64725
#
# Epoch 00051: val_accuracy did not improve from 0.66016
# 389/389 [==============================] - 405s 1s/step - loss: 0.1188 - accuracy: 0.9876 - top5_acc: 0.9998 - macro_f1score: 0.3430 - val_loss: 1.8577 - val_accuracy: 0.6523 - val_top5_acc: 0.8919 - val_macro_f1score: 0.2153
# Learning rate:  0.0001
#
# Epoch 00052: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 52/70
# 389/389 [==============================] - ETA: 0s - loss: 0.1201 - accuracy: 0.9880 - top5_acc: 0.9998 - macro_f1score: 0.3478
# Epoch 00052: val_loss did not improve from 1.64725
#
# Epoch 00052: val_accuracy did not improve from 0.66016
# 389/389 [==============================] - 405s 1s/step - loss: 0.1201 - accuracy: 0.9880 - top5_acc: 0.9998 - macro_f1score: 0.3478 - val_loss: 1.8862 - val_accuracy: 0.6523 - val_top5_acc: 0.8919 - val_macro_f1score: 0.2154
# Learning rate:  0.0001
#
# Epoch 00053: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 53/70
# 389/389 [==============================] - ETA: 0s - loss: 0.1153 - accuracy: 0.9891 - top5_acc: 0.9999 - macro_f1score: 0.3478
# Epoch 00053: val_loss did not improve from 1.64725
#
# Epoch 00053: val_accuracy did not improve from 0.66016
# 389/389 [==============================] - 402s 1s/step - loss: 0.1153 - accuracy: 0.9891 - top5_acc: 0.9999 - macro_f1score: 0.3478 - val_loss: 1.8264 - val_accuracy: 0.6439 - val_top5_acc: 0.8978 - val_macro_f1score: 0.2116
# Learning rate:  0.0001
#
# Epoch 00054: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 54/70
# 389/389 [==============================] - ETA: 0s - loss: 0.1177 - accuracy: 0.9887 - top5_acc: 0.9998 - macro_f1score: 0.3459
# Epoch 00054: val_loss did not improve from 1.64725
#
# Epoch 00054: val_accuracy did not improve from 0.66016
# 389/389 [==============================] - 396s 1s/step - loss: 0.1177 - accuracy: 0.9887 - top5_acc: 0.9998 - macro_f1score: 0.3459 - val_loss: 1.8179 - val_accuracy: 0.6504 - val_top5_acc: 0.8932 - val_macro_f1score: 0.2069
# Learning rate:  0.0001
#
# Epoch 00055: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 55/70
# 389/389 [==============================] - ETA: 0s - loss: 0.1173 - accuracy: 0.9888 - top5_acc: 0.9999 - macro_f1score: 0.3460
# Epoch 00055: val_loss did not improve from 1.64725
#
# Epoch 00055: val_accuracy did not improve from 0.66016
# 389/389 [==============================] - 391s 1s/step - loss: 0.1173 - accuracy: 0.9888 - top5_acc: 0.9999 - macro_f1score: 0.3460 - val_loss: 1.8023 - val_accuracy: 0.6504 - val_top5_acc: 0.8984 - val_macro_f1score: 0.2114
# Learning rate:  0.0001
#
# Epoch 00056: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 56/70
# 389/389 [==============================] - ETA: 0s - loss: 0.1156 - accuracy: 0.9886 - top5_acc: 0.9999 - macro_f1score: 0.3450
# Epoch 00056: val_loss did not improve from 1.64725
#
# Epoch 00056: val_accuracy improved from 0.66016 to 0.66406, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/SE_Xception/056.h5
# 389/389 [==============================] - 391s 1s/step - loss: 0.1156 - accuracy: 0.9886 - top5_acc: 0.9999 - macro_f1score: 0.3450 - val_loss: 1.8180 - val_accuracy: 0.6641 - val_top5_acc: 0.8919 - val_macro_f1score: 0.2164
# Learning rate:  0.0001
#
# Epoch 00057: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 57/70
# 389/389 [==============================] - ETA: 0s - loss: 0.1144 - accuracy: 0.9886 - top5_acc: 0.9999 - macro_f1score: 0.3476
# Epoch 00057: val_loss did not improve from 1.64725
#
# Epoch 00057: val_accuracy did not improve from 0.66406
# 389/389 [==============================] - 391s 1s/step - loss: 0.1144 - accuracy: 0.9886 - top5_acc: 0.9999 - macro_f1score: 0.3476 - val_loss: 1.9158 - val_accuracy: 0.6393 - val_top5_acc: 0.8841 - val_macro_f1score: 0.2112
# Learning rate:  0.0001
#
# Epoch 00058: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 58/70
# 389/389 [==============================] - ETA: 0s - loss: 0.1125 - accuracy: 0.9885 - top5_acc: 0.9998 - macro_f1score: 0.3463
# Epoch 00058: val_loss did not improve from 1.64725
#
# Epoch 00058: val_accuracy did not improve from 0.66406
# 389/389 [==============================] - 398s 1s/step - loss: 0.1125 - accuracy: 0.9885 - top5_acc: 0.9998 - macro_f1score: 0.3463 - val_loss: 1.8994 - val_accuracy: 0.6465 - val_top5_acc: 0.8913 - val_macro_f1score: 0.2066
# Learning rate:  0.0001
#
# Epoch 00059: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 59/70
# 389/389 [==============================] - ETA: 0s - loss: 0.1099 - accuracy: 0.9894 - top5_acc: 0.9999 - macro_f1score: 0.3452
# Epoch 00059: val_loss did not improve from 1.64725
#
# Epoch 00059: val_accuracy did not improve from 0.66406
# 389/389 [==============================] - 397s 1s/step - loss: 0.1099 - accuracy: 0.9894 - top5_acc: 0.9999 - macro_f1score: 0.3452 - val_loss: 1.8677 - val_accuracy: 0.6595 - val_top5_acc: 0.8900 - val_macro_f1score: 0.2077
# Learning rate:  0.0001
#
# Epoch 00060: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 60/70
# 389/389 [==============================] - ETA: 0s - loss: 0.1081 - accuracy: 0.9903 - top5_acc: 0.9999 - macro_f1score: 0.3491
# Epoch 00060: val_loss did not improve from 1.64725
#
# Epoch 00060: val_accuracy did not improve from 0.66406
# 389/389 [==============================] - 399s 1s/step - loss: 0.1081 - accuracy: 0.9903 - top5_acc: 0.9999 - macro_f1score: 0.3491 - val_loss: 1.9067 - val_accuracy: 0.6517 - val_top5_acc: 0.8939 - val_macro_f1score: 0.2102
# Learning rate:  1e-05
#
# Epoch 00061: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 61/70
# 389/389 [==============================] - ETA: 0s - loss: 0.1064 - accuracy: 0.9908 - top5_acc: 0.9999 - macro_f1score: 0.3462
# Epoch 00061: val_loss did not improve from 1.64725
#
# Epoch 00061: val_accuracy did not improve from 0.66406
# 389/389 [==============================] - 399s 1s/step - loss: 0.1064 - accuracy: 0.9908 - top5_acc: 0.9999 - macro_f1score: 0.3462 - val_loss: 1.8302 - val_accuracy: 0.6530 - val_top5_acc: 0.8965 - val_macro_f1score: 0.2064
# Learning rate:  1e-05
#
# Epoch 00062: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 62/70
# 389/389 [==============================] - ETA: 0s - loss: 0.1023 - accuracy: 0.9921 - top5_acc: 1.0000 - macro_f1score: 0.3472
# Epoch 00062: val_loss did not improve from 1.64725
#
# Epoch 00062: val_accuracy did not improve from 0.66406
# 389/389 [==============================] - 400s 1s/step - loss: 0.1023 - accuracy: 0.9921 - top5_acc: 1.0000 - macro_f1score: 0.3472 - val_loss: 1.8332 - val_accuracy: 0.6497 - val_top5_acc: 0.8906 - val_macro_f1score: 0.2149
# Learning rate:  1e-05
#
# Epoch 00063: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 63/70
# 389/389 [==============================] - ETA: 0s - loss: 0.1006 - accuracy: 0.9917 - top5_acc: 1.0000 - macro_f1score: 0.3480
# Epoch 00063: val_loss did not improve from 1.64725
#
# Epoch 00063: val_accuracy did not improve from 0.66406
# 389/389 [==============================] - 397s 1s/step - loss: 0.1006 - accuracy: 0.9917 - top5_acc: 1.0000 - macro_f1score: 0.3480 - val_loss: 1.8260 - val_accuracy: 0.6491 - val_top5_acc: 0.8965 - val_macro_f1score: 0.2107
# Learning rate:  1e-05
#
# Epoch 00064: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 64/70
# 389/389 [==============================] - ETA: 0s - loss: 0.1008 - accuracy: 0.9924 - top5_acc: 1.0000 - macro_f1score: 0.3486
# Epoch 00064: val_loss did not improve from 1.64725
#
# Epoch 00064: val_accuracy did not improve from 0.66406
# 389/389 [==============================] - 395s 1s/step - loss: 0.1008 - accuracy: 0.9924 - top5_acc: 1.0000 - macro_f1score: 0.3486 - val_loss: 1.8183 - val_accuracy: 0.6523 - val_top5_acc: 0.8991 - val_macro_f1score: 0.2130
# Learning rate:  1e-05
#
# Epoch 00065: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 65/70
# 389/389 [==============================] - ETA: 0s - loss: 0.1043 - accuracy: 0.9910 - top5_acc: 1.0000 - macro_f1score: 0.3485
# Epoch 00065: val_loss did not improve from 1.64725
#
# Epoch 00065: val_accuracy did not improve from 0.66406
# 389/389 [==============================] - 401s 1s/step - loss: 0.1043 - accuracy: 0.9910 - top5_acc: 1.0000 - macro_f1score: 0.3485 - val_loss: 1.8196 - val_accuracy: 0.6484 - val_top5_acc: 0.8971 - val_macro_f1score: 0.2084
# Learning rate:  1e-05
#
# Epoch 00066: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 66/70
# 389/389 [==============================] - ETA: 0s - loss: 0.0998 - accuracy: 0.9929 - top5_acc: 0.9999 - macro_f1score: 0.3490
# Epoch 00066: val_loss did not improve from 1.64725
#
# Epoch 00066: val_accuracy did not improve from 0.66406
# 389/389 [==============================] - 395s 1s/step - loss: 0.0998 - accuracy: 0.9929 - top5_acc: 0.9999 - macro_f1score: 0.3490 - val_loss: 1.8417 - val_accuracy: 0.6517 - val_top5_acc: 0.8958 - val_macro_f1score: 0.2083
# Learning rate:  1e-05
#
# Epoch 00067: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 67/70
# 389/389 [==============================] - ETA: 0s - loss: 0.0997 - accuracy: 0.9927 - top5_acc: 1.0000 - macro_f1score: 0.3482
# Epoch 00067: val_loss did not improve from 1.64725
#
# Epoch 00067: val_accuracy did not improve from 0.66406
# 389/389 [==============================] - 395s 1s/step - loss: 0.0997 - accuracy: 0.9927 - top5_acc: 1.0000 - macro_f1score: 0.3482 - val_loss: 1.8364 - val_accuracy: 0.6510 - val_top5_acc: 0.8971 - val_macro_f1score: 0.2070
# Learning rate:  1e-05
#
# Epoch 00068: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 68/70
# 389/389 [==============================] - ETA: 0s - loss: 0.0990 - accuracy: 0.9926 - top5_acc: 0.9999 - macro_f1score: 0.3486
# Epoch 00068: val_loss did not improve from 1.64725
#
# Epoch 00068: val_accuracy did not improve from 0.66406
# 389/389 [==============================] - 397s 1s/step - loss: 0.0990 - accuracy: 0.9926 - top5_acc: 0.9999 - macro_f1score: 0.3486 - val_loss: 1.8175 - val_accuracy: 0.6530 - val_top5_acc: 0.8965 - val_macro_f1score: 0.2183
# Learning rate:  1e-05
#
# Epoch 00069: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 69/70
# 389/389 [==============================] - ETA: 0s - loss: 0.0978 - accuracy: 0.9938 - top5_acc: 1.0000 - macro_f1score: 0.3493
# Epoch 00069: val_loss did not improve from 1.64725
#
# Epoch 00069: val_accuracy did not improve from 0.66406
# 389/389 [==============================] - 392s 1s/step - loss: 0.0978 - accuracy: 0.9938 - top5_acc: 1.0000 - macro_f1score: 0.3493 - val_loss: 1.8116 - val_accuracy: 0.6582 - val_top5_acc: 0.8997 - val_macro_f1score: 0.2134
# Learning rate:  1e-05
#
# Epoch 00070: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 70/70
# 389/389 [==============================] - ETA: 0s - loss: 0.0985 - accuracy: 0.9929 - top5_acc: 0.9998 - macro_f1score: 0.3484
# Epoch 00070: val_loss did not improve from 1.64725
#
# Epoch 00070: val_accuracy did not improve from 0.66406
# 389/389 [==============================] - 392s 1s/step - loss: 0.0985 - accuracy: 0.9929 - top5_acc: 0.9998 - macro_f1score: 0.3484 - val_loss: 1.8399 - val_accuracy: 0.6549 - val_top5_acc: 0.8991 - val_macro_f1score: 0.2165

# %% [markdown]
# ### 3) SE-Xception Evaluate

# %%
# 1. epoch=maximum
loss , acc, top5_acc, mf1 = model.evaluate(test_generator,steps=int(len(x_test)/batch_sizes))
print('[Test Loss: %.4f /  Test Top-1 Accuracy: %.4f / Test Top-5 Accuracy: %.4f / Test Macro f1: %.4f]\n' % (loss,acc,top5_acc,mf1))
# Out:
# 49/49 [==============================] - 567s 12s/step - loss: 1.9160 - accuracy: 0.6441 - top5_acc: 0.8935 - macro_f1score: 0.2061
# [Test Loss: 1.9160 /  Test Top-1 Accuracy: 0.6441 / Test Top-5 Accuracy: 0.8935 / Test Macro f1: 0.2061]

# %%
loss=history.history['loss']
val_loss=history.history['val_loss']
acc=history.history['accuracy']
val_acc=history.history['val_accuracy']
top5_acc=history.history['top5_acc']
val_top5_acc=history.history['val_top5_acc']
f1=history.history['macro_f1score']
val_f1=history.history['val_macro_f1score']
epochs=range(1,len(acc)+1)

data = np.array([epochs,loss,val_loss,acc,val_acc,top5_acc,val_top5_acc,f1,val_f1]).T

# %%
# data save
# epochs, loss, val_loss, acc, val_acc, f1, val_f1

np.savetxt(os.path.join(dir,'train_valid_output',number,model.name+'.txt'),data)

# %%
# data import
data = np.loadtxt(os.path.join(dir,'train_valid_output',number,'SE_Xception.txt'))

# %%
epochs=data[:,0]
loss=data[:,1]
val_loss=data[:,2]
acc=data[:,3]
val_acc=data[:,4]
top5_acc=data[:,5]
val_top5_acc=data[:,6]

# %%
plt.plot(epochs[1:],acc[1:],'b',label='Training 1-Acc')
plt.plot(epochs[1:],val_acc[1:],'r',label='Validation 1-Acc')
plt.title('Training and Validation Top-1 Accuracy')
plt.legend()
plt.figure()

plt.plot(epochs[1:],top5_acc[1:],'b',label='Training 5-Acc')
plt.plot(epochs[1:],val_top5_acc[1:],'r',label='Validation 5-Acc')
plt.title('Training and Validation Top-5 Accuracy')
plt.legend()
plt.figure()

plt.plot(epochs[10:],loss[10:],'b',label='Training Loss')
plt.plot(epochs[10:],val_loss[10:],'r',label='Validation Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()

# %%
# 이 아래는 내가 인위적으로 살펴보고 싶은 epoch에 대해서 결과값 출력 / SE-Xception

# %%
# 참고 : https://github.com/OverLordGoldDragon/keras-adamw

import sys
sys.path.append('/content/drive/My Drive/Colab Notebooks/Paper')
import utils
import optimizers_v2
from utils import get_weight_decays, fill_dict_in_order
from utils import reset_seeds, K_eval
from optimizers_v2 import AdamW, NadamW, SGDW

# %%
# top-5 accuracy 출력
import functools
top5_acc = functools.partial(ks.metrics.top_k_categorical_accuracy, k=5)
top5_acc.__name__ = 'top5_acc'

# %%
model=load_model(os.path.join(dir,'model_output',number,'SE_Xception','056.h5'),custom_objects={"macro_f1score": macro_f1score,"top5_acc":top5_acc, "AdamW":AdamW})

# %%
# 2. epoch=?
loss , acc, mf1, wf1 = model.evaluate(test_generator,steps=int(len(x_test)/batch_sizes))
print('[Test Loss: %.4f /  Test Accuracy: %.4f / Test Macro f1: %.4f / Test Weighted f1: %.4f]\n' % (loss,acc,mf1,wf1))
# Out:
# 49/49 [==============================] - 263s 5s/step - loss: 1.9252 - accuracy: 0.6263 - top5_acc: 0.8916 - macro_f1score: 0.2053
# [Test Loss: 1.9252 /  Test Accuracy: 0.6263 / Test Macro f1: 0.8916 / Test Weighted f1: 0.2053]
