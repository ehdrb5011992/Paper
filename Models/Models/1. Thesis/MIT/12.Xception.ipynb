# %%
### 참고 : https://github.com/fchollet/deep-learning-models/blob/master/xception.py

# %% [markdown]
# # [Xception]

# %% [markdown]
# *KU LeeDongGyu*

# %% [markdown]
# ## Contents
# ---

# %% [markdown]
# 1. Data Preprocessing
# ```
# 1) Data Import
# 2) Data Augmentation
# ```
# 2. Support Functions & Almost Original Xception
# ```
# 1) Support Functions
# 2) Almost Original Xception
# ```
# 3. Xception
# ```
# 1) Xception
# 2) Xception Evaluate
# ```

# %% [markdown]
# ### Install Packages

# %% [markdown]
# ### Module

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/My Drive/Colab Notebooks/Paper
# Out:
# /content/drive/My Drive/Colab Notebooks/Paper

# %%
from f1score import macro_f1score,weighted_f1score

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import cv2
import tensorflow as tf
from tensorflow import keras as ks
from tensorflow.keras import backend as K 
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, Input, Concatenate, ZeroPadding2D ,GlobalMaxPooling2D, Reshape , Lambda , Add, Multiply
from tensorflow.keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D, Activation, BatchNormalization, AveragePooling2D , ZeroPadding2D, SeparableConv2D , LeakyReLU
from tensorflow.keras.layers import add, concatenate, multiply
from tensorflow.keras.optimizers import Adam, RMSprop , SGD
from tensorflow.keras.callbacks import EarlyStopping , LearningRateScheduler, ModelCheckpoint, CSVLogger, Callback, ReduceLROnPlateau
from tensorflow.keras.regularizers import l1,l2,l1_l2
from tensorflow.keras.models import Model , load_model , Sequential
from tensorflow.keras.utils import plot_model , to_categorical, get_file
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
os.getcwd()
# Out:
# '/content/drive/My Drive/Colab Notebooks/Paper'

# %%
print(tf.__version__)
print(ks.__version__)
# Out:
# 2.3.0
# 2.4.0

# %%
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 17279595462592406173
# , name: "/device:XLA_CPU:0"
# device_type: "XLA_CPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 15363161648139632468
# physical_device_desc: "device: XLA_CPU device"
# , name: "/device:XLA_GPU:0"
# device_type: "XLA_GPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 7503937079665402775
# physical_device_desc: "device: XLA_GPU device"
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 15695549568
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 1010504930689579251
# physical_device_desc: "device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0"
# ]

# %%
# !cat /proc/cpuinfo
# Out:
# processor	: 0
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 63
# model name	: Intel(R) Xeon(R) CPU @ 2.30GHz
# stepping	: 0
# microcode	: 0x1
# cpu MHz		: 2300.000
# cache size	: 46080 KB
# physical id	: 0
# siblings	: 4
# core id		: 0
# cpu cores	: 2
# apicid		: 0
# initial apicid	: 0
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 avx2 smep bmi2 erms invpcid xsaveopt arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs
# bogomips	: 4600.00
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 46 bits physical, 48 bits virtual
# power management:
#
# processor	: 1
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 63
# model name	: Intel(R) Xeon(R) CPU @ 2.30GHz
# stepping	: 0
# microcode	: 0x1
# cpu MHz		: 2300.000
# cache size	: 46080 KB
# physical id	: 0
# siblings	: 4
# core id		: 1
# cpu cores	: 2
# apicid		: 2
# initial apicid	: 2
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 avx2 smep bmi2 erms invpcid xsaveopt arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs
# bogomips	: 4600.00
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 46 bits physical, 48 bits virtual
# power management:
#
# processor	: 2
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 63
# model name	: Intel(R) Xeon(R) CPU @ 2.30GHz
# stepping	: 0
# microcode	: 0x1
# cpu MHz		: 2300.000
# cache size	: 46080 KB
# physical id	: 0
# siblings	: 4
# core id		: 0
# cpu cores	: 2
# apicid		: 1
# initial apicid	: 1
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 avx2 smep bmi2 erms invpcid xsaveopt arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs
# bogomips	: 4600.00
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 46 bits physical, 48 bits virtual
# power management:
#
# processor	: 3
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 63
# model name	: Intel(R) Xeon(R) CPU @ 2.30GHz
# stepping	: 0
# microcode	: 0x1
# cpu MHz		: 2300.000
# cache size	: 46080 KB
# physical id	: 0
# siblings	: 4
# core id		: 1
# cpu cores	: 2
# apicid		: 3
# initial apicid	: 3
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 avx2 smep bmi2 erms invpcid xsaveopt arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs
# bogomips	: 4600.00
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 46 bits physical, 48 bits virtual
# power management:

# %% [markdown]
# ## 1. Data Preprocessing
# ---

# %% [markdown]
# ### 1) Data Import

# %%
# 바꿔서 살펴 볼 것들
# CALTECH, CIFAR100, FER, MIT
data_name = 'MIT'
gan_type = 'No_GAN'
number = '1'
size = 299 # sizes after cropping
super_size = 330 # sizes before cropping 
input_sizes = (size,size,3)
batch_sizes = 32
weight_decay = 1e-6
epochs = 70

# %%
# 참고 : https://stackoverflow.com/questions/32419510/how-to-get-reproducible-results-in-keras/52897216#52897216
# setting the seed number for random number generation for reproducibility.

from numpy.random import seed
import random


if number=='1':
    seed_num = 200225
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)
elif number=='2':
    seed_num = 727
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)
elif number=='3':
    seed_num = 115
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)
elif number=='4':
    seed_num = 501
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)
elif number=='5':
    seed_num = 517
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)

# %%
# data import

if data_name=='FER' :
    x_train =  np.zeros(28698)
    x_valid = np.zeros(3589)
    x_test = np.zeros(3588)
    classes = 7 
    tr_center = [0.50793296, 0.50793296, 0.50793296]
elif data_name=='MIT':
    x_train = np.zeros(12466)
    x_valid = np.zeros(1564)
    x_test = np.zeros(1590)
    classes = 67 
    tr_center = [0.47916578, 0.42029615, 0.36046057]
elif data_name=='CALTECH':
    x_train = np.zeros(24510)
    x_valid = np.zeros(2980)
    x_test = np.zeros(3118)
    classes = 257
    tr_center = [0.51397761, 0.49525248, 0.46555727]
elif data_name=='CIFAR100':
    x_train = np.zeros(44923)
    x_valid = np.zeros(5077)
    x_test = np.zeros(10000)
    classes = 100
    tr_center = [0.53442983, 0.51355958, 0.46462564]

# %%
dir = os.path.join(os.getcwd(),data_name,gan_type)

# %% [markdown]
# ### 2) Data Augmentation

# %%
# 참고 : https://jkjung-avt.github.io/keras-image-cropping/

def random_crop(img, random_crop_size):
    # Note: image_data_format is 'channel_last'
    assert img.shape[2] == 3 # img.shape[2] 가 3(rgb)이 아니면 assertion error 발생
    height, width = img.shape[0], img.shape[1]
    dy, dx = random_crop_size
    x = np.random.randint(0, width - dx + 1)
    y = np.random.randint(0, height - dy + 1)
    return img[y:(y+dy), x:(x+dx), :]


def crop_generator(batches, crop_length):
    """Take as input a Keras ImageGen (Iterator) and generate random
    crops from the image batches generated by the original iterator.
    """
    while True:
        batch_x, batch_y = next(batches)
        batch_crops = np.zeros((batch_x.shape[0], crop_length, crop_length, 3))
        for i in range(batch_x.shape[0]):
            batch_crops[i] = random_crop(batch_x[i], (crop_length, crop_length))
        yield (batch_crops, batch_y)

# %%
from tensorflow.keras.preprocessing.image import img_to_array,load_img
import glob

# 데이터 전체에 대해 centering 진행함.

def read_cal_image(img_path): 
    x = img_to_array(load_img(img_path)) # x는 채널별 평균값
    y = x.shape[0] * x.shape[1]# y는 데이터별 픽셀 수 (비중)

    x = 1/255. * x # scaling하고, centering값을 뽑아냄.
    x = np.mean(x, axis=(0,1))
    
    return np.hstack([x,y])

def calculate_centered_mean(dataset_path,x_train=x_train):
    num = len(x_train)
    space = np.empty((num,4))
    i=0

    for p in glob.glob(os.path.join(dataset_path,'*/*.*')) :
        space[i] = read_cal_image(p)
        i += 1

    ratio = space[:,3] / np.sum(space[:,3])

    return np.average(space[:,0:3],axis=0,weights=ratio)


# 아래의 함수를 돌려서 나온 결과값을 중심화 값으로 설정.

# train_mean = calculate_centered_mean(os.path.join(dir,'data/train')).reshape((1,1,3))

# %%
datagen_tr = ImageDataGenerator(
    rescale=1/255.,
    horizontal_flip=True,
    featurewise_center=True,
    featurewise_std_normalization=False,
    rotation_range=10,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=[0.9,1.0],
    fill_mode = 'nearest')
datagen_val = ImageDataGenerator(rescale=1/255.,featurewise_center=True)
datagen_tes = ImageDataGenerator(rescale=1/255.,featurewise_center=True)

# 원래는 이 자리에 fit 매서드를 써야하지만, 그냥 내가 중심화함수를 만들고 적용함. 

# 중심화 설정
datagen_tr.mean = np.array(tr_center, dtype=np.float32).reshape((1,1,3)) # RGB
datagen_val.mean = np.array(tr_center, dtype=np.float32).reshape((1,1,3)) # RGB
datagen_tes.mean = np.array(tr_center, dtype=np.float32).reshape((1,1,3)) # RGB

# %%
train_batches = datagen_tr.flow_from_directory(directory=os.path.join(dir,'data/train'),target_size=(super_size,super_size),batch_size=batch_sizes,class_mode='categorical') # fer : 28698 / mit : 12466 / caltech : 24509 / cifar : 44923
train_generator= crop_generator(train_batches, size)
valid_generator = datagen_val.flow_from_directory(directory=os.path.join(dir,'data/valid'),target_size=(size,size),batch_size=batch_sizes,class_mode='categorical') # fer : 3589 / mit : 1564 / caltech : 2980 / cifar : 5077
test_generator = datagen_tes.flow_from_directory(directory=os.path.join(dir,'data/test'),target_size=(size,size),batch_size=batch_sizes,class_mode='categorical') # fer : 3588 / mit : 1590 / caltech : 3118 / cifar : 10000
# Out:
# Found 12466 images belonging to 67 classes.
# Found 1564 images belonging to 67 classes.
# Found 1590 images belonging to 67 classes.

# %% [markdown]
# ## 2. Support Functions & Almost Original Xception
# ---

# %% [markdown]
# ### 1) Support Functions

# %%
# def lr_schedule(epoch):
#     init_lr = 1e-4
#     k = 0.04
#     lr = init_lr * np.exp(-k*epoch)
#     print('Learning rate: ', lr)
#     return lr

def lr_schedule(epoch):
    lr = 1e-3
    if epoch < 30:
        lr = lr
    elif epoch < 60 :
        lr = lr * 0.1
    else:
        lr = lr * 0.01
    print('Learning rate: ', lr)
    return lr

# %% [markdown]
# ### 2) Almost Original Xception

# %%
def Xception(input_shape=None, classes=1000, name = "Xception", weight_decay = weight_decay):


    img_input = Input(shape=input_shape)


    x = Conv2D(32, (3, 3), strides=(2, 2), use_bias=False, kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay), name='block1_conv1')(img_input)
    x = BatchNormalization(name='block1_conv1_bn')(x)
    x = Activation('relu', name='block1_conv1_act')(x)
    x = Conv2D(64, (3, 3), use_bias=False, kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay), name='block1_conv2')(x)
    x = BatchNormalization(name='block1_conv2_bn')(x)
    x = Activation('relu', name='block1_conv2_act')(x)

    residual = Conv2D(128, (1, 1), strides=(2, 2),
                      padding='same', use_bias=False, kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(x)
    residual = BatchNormalization()(residual)

    x = SeparableConv2D(128, (3, 3), padding='same', use_bias=False, depthwise_initializer='he_uniform', pointwise_initializer='he_uniform',depthwise_regularizer=l2(weight_decay), pointwise_regularizer=l2(weight_decay), name='block2_sepconv1')(x)
    x = BatchNormalization(name='block2_sepconv1_bn')(x)
    x = Activation('relu', name='block2_sepconv2_act')(x)
    x = SeparableConv2D(128, (3, 3), padding='same', use_bias=False, depthwise_initializer='he_uniform', pointwise_initializer='he_uniform',depthwise_regularizer=l2(weight_decay), pointwise_regularizer=l2(weight_decay), name='block2_sepconv2')(x)
    x = BatchNormalization(name='block2_sepconv2_bn')(x)

    x = MaxPooling2D((3, 3), strides=(2, 2), padding='same', name='block2_pool')(x)
    x = add([x, residual])

    residual = Conv2D(256, (1, 1), strides=(2, 2),
                      padding='same', use_bias=False, kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(x)
    residual = BatchNormalization()(residual)

    x = Activation('relu', name='block3_sepconv1_act')(x)
    x = SeparableConv2D(256, (3, 3), padding='same', use_bias=False, depthwise_initializer='he_uniform', pointwise_initializer='he_uniform',depthwise_regularizer=l2(weight_decay), pointwise_regularizer=l2(weight_decay), name='block3_sepconv1')(x)
    x = BatchNormalization(name='block3_sepconv1_bn')(x)
    x = Activation('relu', name='block3_sepconv2_act')(x)
    x = SeparableConv2D(256, (3, 3), padding='same', use_bias=False, depthwise_initializer='he_uniform', pointwise_initializer='he_uniform',depthwise_regularizer=l2(weight_decay), pointwise_regularizer=l2(weight_decay), name='block3_sepconv2')(x)
    x = BatchNormalization(name='block3_sepconv2_bn')(x)

    x = MaxPooling2D((3, 3), strides=(2, 2), padding='same', name='block3_pool')(x)
    x = add([x, residual])

    residual = Conv2D(728, (1, 1), strides=(2, 2),
                      padding='same', use_bias=False, kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(x)
    residual = BatchNormalization()(residual)

    x = Activation('relu', name='block4_sepconv1_act')(x)
    x = SeparableConv2D(728, (3, 3), padding='same', use_bias=False, depthwise_initializer='he_uniform', pointwise_initializer='he_uniform',depthwise_regularizer=l2(weight_decay), pointwise_regularizer=l2(weight_decay), name='block4_sepconv1')(x)
    x = BatchNormalization(name='block4_sepconv1_bn')(x)
    x = Activation('relu', name='block4_sepconv2_act')(x)
    x = SeparableConv2D(728, (3, 3), padding='same', use_bias=False, depthwise_initializer='he_uniform', pointwise_initializer='he_uniform',depthwise_regularizer=l2(weight_decay), pointwise_regularizer=l2(weight_decay), name='block4_sepconv2')(x)
    x = BatchNormalization(name='block4_sepconv2_bn')(x)

    x = MaxPooling2D((3, 3), strides=(2, 2), padding='same', name='block4_pool')(x)
    x = add([x, residual])

    for i in range(8):
        residual = x
        prefix = 'block' + str(i + 5)

        x = Activation('relu', name=prefix + '_sepconv1_act')(x)
        x = SeparableConv2D(728, (3, 3), padding='same', use_bias=False, depthwise_initializer='he_uniform', pointwise_initializer='he_uniform',depthwise_regularizer=l2(weight_decay), pointwise_regularizer=l2(weight_decay), name=prefix + '_sepconv1')(x)
        x = BatchNormalization(name=prefix + '_sepconv1_bn')(x)
        x = Activation('relu', name=prefix + '_sepconv2_act')(x)
        x = SeparableConv2D(728, (3, 3), padding='same', use_bias=False, depthwise_initializer='he_uniform', pointwise_initializer='he_uniform',depthwise_regularizer=l2(weight_decay), pointwise_regularizer=l2(weight_decay), name=prefix + '_sepconv2')(x)
        x = BatchNormalization(name=prefix + '_sepconv2_bn')(x)
        x = Activation('relu', name=prefix + '_sepconv3_act')(x)
        x = SeparableConv2D(728, (3, 3), padding='same', use_bias=False, depthwise_initializer='he_uniform', pointwise_initializer='he_uniform',depthwise_regularizer=l2(weight_decay), pointwise_regularizer=l2(weight_decay), name=prefix + '_sepconv3')(x)
        x = BatchNormalization(name=prefix + '_sepconv3_bn')(x)

        x = add([x, residual])

    residual = Conv2D(1024, (1, 1), strides=(2, 2),
                      padding='same', use_bias=False, kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(x)
    residual = BatchNormalization()(residual)

    x = Activation('relu', name='block13_sepconv1_act')(x)
    x = SeparableConv2D(728, (3, 3), padding='same', use_bias=False, depthwise_initializer='he_uniform', pointwise_initializer='he_uniform',depthwise_regularizer=l2(weight_decay), pointwise_regularizer=l2(weight_decay), name='block13_sepconv1')(x)
    x = BatchNormalization(name='block13_sepconv1_bn')(x)
    x = Activation('relu', name='block13_sepconv2_act')(x)
    x = SeparableConv2D(1024, (3, 3), padding='same', use_bias=False, depthwise_initializer='he_uniform', pointwise_initializer='he_uniform',depthwise_regularizer=l2(weight_decay), pointwise_regularizer=l2(weight_decay), name='block13_sepconv2')(x)
    x = BatchNormalization(name='block13_sepconv2_bn')(x)

    x = MaxPooling2D((3, 3), strides=(2, 2), padding='same', name='block13_pool')(x)
    x = add([x, residual])

    x = SeparableConv2D(1536, (3, 3), padding='same', use_bias=False, depthwise_initializer='he_uniform', pointwise_initializer='he_uniform',depthwise_regularizer=l2(weight_decay), pointwise_regularizer=l2(weight_decay), name='block14_sepconv1')(x)
    x = BatchNormalization(name='block14_sepconv1_bn')(x)
    x = Activation('relu', name='block14_sepconv1_act')(x)

    x = SeparableConv2D(2048, (3, 3), padding='same', use_bias=False, depthwise_initializer='he_uniform', pointwise_initializer='he_uniform',depthwise_regularizer=l2(weight_decay), pointwise_regularizer=l2(weight_decay), name='block14_sepconv2')(x)
    x = BatchNormalization(name='block14_sepconv2_bn')(x)
    x = Activation('relu', name='block14_sepconv2_act')(x)


    x = GlobalAveragePooling2D(name='avg_pool')(x)
    x = Dropout(0.5)(x)
    x = Dense(classes, activation='softmax', kernel_regularizer=l2(weight_decay), name='predictions')(x)


    inputs = img_input

    # Create model.
    model = Model(inputs, x, name=name)

    return model

# %% [markdown]
# ## 3. Xception
# ---

# %% [markdown]
# ### 1) Xception

# %%
model = Xception(input_sizes, classes=classes, name='Xception')

# %%
model.summary()
# Out:
# Model: "Xception"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 299, 299, 3) 0
# __________________________________________________________________________________________________
# block1_conv1 (Conv2D)           (None, 149, 149, 32) 864         input_1[0][0]
# __________________________________________________________________________________________________
# block1_conv1_bn (BatchNormaliza (None, 149, 149, 32) 128         block1_conv1[0][0]
# __________________________________________________________________________________________________
# block1_conv1_act (Activation)   (None, 149, 149, 32) 0           block1_conv1_bn[0][0]
# __________________________________________________________________________________________________
# block1_conv2 (Conv2D)           (None, 147, 147, 64) 18432       block1_conv1_act[0][0]
# __________________________________________________________________________________________________
# block1_conv2_bn (BatchNormaliza (None, 147, 147, 64) 256         block1_conv2[0][0]
# __________________________________________________________________________________________________
# block1_conv2_act (Activation)   (None, 147, 147, 64) 0           block1_conv2_bn[0][0]
# __________________________________________________________________________________________________
# block2_sepconv1 (SeparableConv2 (None, 147, 147, 128 8768        block1_conv2_act[0][0]
# __________________________________________________________________________________________________
# block2_sepconv1_bn (BatchNormal (None, 147, 147, 128 512         block2_sepconv1[0][0]
# __________________________________________________________________________________________________
# block2_sepconv2_act (Activation (None, 147, 147, 128 0           block2_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block2_sepconv2 (SeparableConv2 (None, 147, 147, 128 17536       block2_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block2_sepconv2_bn (BatchNormal (None, 147, 147, 128 512         block2_sepconv2[0][0]
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 74, 74, 128)  8192        block1_conv2_act[0][0]
# __________________________________________________________________________________________________
# block2_pool (MaxPooling2D)      (None, 74, 74, 128)  0           block2_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 74, 74, 128)  512         conv2d[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 74, 74, 128)  0           block2_pool[0][0]
#                                                                  batch_normalization[0][0]
# __________________________________________________________________________________________________
# block3_sepconv1_act (Activation (None, 74, 74, 128)  0           add[0][0]
# __________________________________________________________________________________________________
# block3_sepconv1 (SeparableConv2 (None, 74, 74, 256)  33920       block3_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block3_sepconv1_bn (BatchNormal (None, 74, 74, 256)  1024        block3_sepconv1[0][0]
# __________________________________________________________________________________________________
# block3_sepconv2_act (Activation (None, 74, 74, 256)  0           block3_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block3_sepconv2 (SeparableConv2 (None, 74, 74, 256)  67840       block3_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block3_sepconv2_bn (BatchNormal (None, 74, 74, 256)  1024        block3_sepconv2[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 37, 37, 256)  32768       add[0][0]
# __________________________________________________________________________________________________
# block3_pool (MaxPooling2D)      (None, 37, 37, 256)  0           block3_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 37, 37, 256)  1024        conv2d_1[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 37, 37, 256)  0           block3_pool[0][0]
#                                                                  batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# block4_sepconv1_act (Activation (None, 37, 37, 256)  0           add_1[0][0]
# __________________________________________________________________________________________________
# block4_sepconv1 (SeparableConv2 (None, 37, 37, 728)  188672      block4_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block4_sepconv1_bn (BatchNormal (None, 37, 37, 728)  2912        block4_sepconv1[0][0]
# __________________________________________________________________________________________________
# block4_sepconv2_act (Activation (None, 37, 37, 728)  0           block4_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block4_sepconv2 (SeparableConv2 (None, 37, 37, 728)  536536      block4_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block4_sepconv2_bn (BatchNormal (None, 37, 37, 728)  2912        block4_sepconv2[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 19, 19, 728)  186368      add_1[0][0]
# __________________________________________________________________________________________________
# block4_pool (MaxPooling2D)      (None, 19, 19, 728)  0           block4_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 19, 19, 728)  2912        conv2d_2[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 19, 19, 728)  0           block4_pool[0][0]
#                                                                  batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# block5_sepconv1_act (Activation (None, 19, 19, 728)  0           add_2[0][0]
# __________________________________________________________________________________________________
# block5_sepconv1 (SeparableConv2 (None, 19, 19, 728)  536536      block5_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block5_sepconv1_bn (BatchNormal (None, 19, 19, 728)  2912        block5_sepconv1[0][0]
# __________________________________________________________________________________________________
# block5_sepconv2_act (Activation (None, 19, 19, 728)  0           block5_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block5_sepconv2 (SeparableConv2 (None, 19, 19, 728)  536536      block5_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block5_sepconv2_bn (BatchNormal (None, 19, 19, 728)  2912        block5_sepconv2[0][0]
# __________________________________________________________________________________________________
# block5_sepconv3_act (Activation (None, 19, 19, 728)  0           block5_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block5_sepconv3 (SeparableConv2 (None, 19, 19, 728)  536536      block5_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block5_sepconv3_bn (BatchNormal (None, 19, 19, 728)  2912        block5_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 19, 19, 728)  0           block5_sepconv3_bn[0][0]
#                                                                  add_2[0][0]
# __________________________________________________________________________________________________
# block6_sepconv1_act (Activation (None, 19, 19, 728)  0           add_3[0][0]
# __________________________________________________________________________________________________
# block6_sepconv1 (SeparableConv2 (None, 19, 19, 728)  536536      block6_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block6_sepconv1_bn (BatchNormal (None, 19, 19, 728)  2912        block6_sepconv1[0][0]
# __________________________________________________________________________________________________
# block6_sepconv2_act (Activation (None, 19, 19, 728)  0           block6_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block6_sepconv2 (SeparableConv2 (None, 19, 19, 728)  536536      block6_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block6_sepconv2_bn (BatchNormal (None, 19, 19, 728)  2912        block6_sepconv2[0][0]
# __________________________________________________________________________________________________
# block6_sepconv3_act (Activation (None, 19, 19, 728)  0           block6_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block6_sepconv3 (SeparableConv2 (None, 19, 19, 728)  536536      block6_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block6_sepconv3_bn (BatchNormal (None, 19, 19, 728)  2912        block6_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 19, 19, 728)  0           block6_sepconv3_bn[0][0]
#                                                                  add_3[0][0]
# __________________________________________________________________________________________________
# block7_sepconv1_act (Activation (None, 19, 19, 728)  0           add_4[0][0]
# __________________________________________________________________________________________________
# block7_sepconv1 (SeparableConv2 (None, 19, 19, 728)  536536      block7_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block7_sepconv1_bn (BatchNormal (None, 19, 19, 728)  2912        block7_sepconv1[0][0]
# __________________________________________________________________________________________________
# block7_sepconv2_act (Activation (None, 19, 19, 728)  0           block7_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block7_sepconv2 (SeparableConv2 (None, 19, 19, 728)  536536      block7_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block7_sepconv2_bn (BatchNormal (None, 19, 19, 728)  2912        block7_sepconv2[0][0]
# __________________________________________________________________________________________________
# block7_sepconv3_act (Activation (None, 19, 19, 728)  0           block7_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block7_sepconv3 (SeparableConv2 (None, 19, 19, 728)  536536      block7_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block7_sepconv3_bn (BatchNormal (None, 19, 19, 728)  2912        block7_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 19, 19, 728)  0           block7_sepconv3_bn[0][0]
#                                                                  add_4[0][0]
# __________________________________________________________________________________________________
# block8_sepconv1_act (Activation (None, 19, 19, 728)  0           add_5[0][0]
# __________________________________________________________________________________________________
# block8_sepconv1 (SeparableConv2 (None, 19, 19, 728)  536536      block8_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block8_sepconv1_bn (BatchNormal (None, 19, 19, 728)  2912        block8_sepconv1[0][0]
# __________________________________________________________________________________________________
# block8_sepconv2_act (Activation (None, 19, 19, 728)  0           block8_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block8_sepconv2 (SeparableConv2 (None, 19, 19, 728)  536536      block8_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block8_sepconv2_bn (BatchNormal (None, 19, 19, 728)  2912        block8_sepconv2[0][0]
# __________________________________________________________________________________________________
# block8_sepconv3_act (Activation (None, 19, 19, 728)  0           block8_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block8_sepconv3 (SeparableConv2 (None, 19, 19, 728)  536536      block8_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block8_sepconv3_bn (BatchNormal (None, 19, 19, 728)  2912        block8_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 19, 19, 728)  0           block8_sepconv3_bn[0][0]
#                                                                  add_5[0][0]
# __________________________________________________________________________________________________
# block9_sepconv1_act (Activation (None, 19, 19, 728)  0           add_6[0][0]
# __________________________________________________________________________________________________
# block9_sepconv1 (SeparableConv2 (None, 19, 19, 728)  536536      block9_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block9_sepconv1_bn (BatchNormal (None, 19, 19, 728)  2912        block9_sepconv1[0][0]
# __________________________________________________________________________________________________
# block9_sepconv2_act (Activation (None, 19, 19, 728)  0           block9_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block9_sepconv2 (SeparableConv2 (None, 19, 19, 728)  536536      block9_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block9_sepconv2_bn (BatchNormal (None, 19, 19, 728)  2912        block9_sepconv2[0][0]
# __________________________________________________________________________________________________
# block9_sepconv3_act (Activation (None, 19, 19, 728)  0           block9_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block9_sepconv3 (SeparableConv2 (None, 19, 19, 728)  536536      block9_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block9_sepconv3_bn (BatchNormal (None, 19, 19, 728)  2912        block9_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 19, 19, 728)  0           block9_sepconv3_bn[0][0]
#                                                                  add_6[0][0]
# __________________________________________________________________________________________________
# block10_sepconv1_act (Activatio (None, 19, 19, 728)  0           add_7[0][0]
# __________________________________________________________________________________________________
# block10_sepconv1 (SeparableConv (None, 19, 19, 728)  536536      block10_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block10_sepconv1_bn (BatchNorma (None, 19, 19, 728)  2912        block10_sepconv1[0][0]
# __________________________________________________________________________________________________
# block10_sepconv2_act (Activatio (None, 19, 19, 728)  0           block10_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block10_sepconv2 (SeparableConv (None, 19, 19, 728)  536536      block10_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block10_sepconv2_bn (BatchNorma (None, 19, 19, 728)  2912        block10_sepconv2[0][0]
# __________________________________________________________________________________________________
# block10_sepconv3_act (Activatio (None, 19, 19, 728)  0           block10_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block10_sepconv3 (SeparableConv (None, 19, 19, 728)  536536      block10_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block10_sepconv3_bn (BatchNorma (None, 19, 19, 728)  2912        block10_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 19, 19, 728)  0           block10_sepconv3_bn[0][0]
#                                                                  add_7[0][0]
# __________________________________________________________________________________________________
# block11_sepconv1_act (Activatio (None, 19, 19, 728)  0           add_8[0][0]
# __________________________________________________________________________________________________
# block11_sepconv1 (SeparableConv (None, 19, 19, 728)  536536      block11_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block11_sepconv1_bn (BatchNorma (None, 19, 19, 728)  2912        block11_sepconv1[0][0]
# __________________________________________________________________________________________________
# block11_sepconv2_act (Activatio (None, 19, 19, 728)  0           block11_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block11_sepconv2 (SeparableConv (None, 19, 19, 728)  536536      block11_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block11_sepconv2_bn (BatchNorma (None, 19, 19, 728)  2912        block11_sepconv2[0][0]
# __________________________________________________________________________________________________
# block11_sepconv3_act (Activatio (None, 19, 19, 728)  0           block11_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block11_sepconv3 (SeparableConv (None, 19, 19, 728)  536536      block11_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block11_sepconv3_bn (BatchNorma (None, 19, 19, 728)  2912        block11_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 19, 19, 728)  0           block11_sepconv3_bn[0][0]
#                                                                  add_8[0][0]
# __________________________________________________________________________________________________
# block12_sepconv1_act (Activatio (None, 19, 19, 728)  0           add_9[0][0]
# __________________________________________________________________________________________________
# block12_sepconv1 (SeparableConv (None, 19, 19, 728)  536536      block12_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block12_sepconv1_bn (BatchNorma (None, 19, 19, 728)  2912        block12_sepconv1[0][0]
# __________________________________________________________________________________________________
# block12_sepconv2_act (Activatio (None, 19, 19, 728)  0           block12_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block12_sepconv2 (SeparableConv (None, 19, 19, 728)  536536      block12_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block12_sepconv2_bn (BatchNorma (None, 19, 19, 728)  2912        block12_sepconv2[0][0]
# __________________________________________________________________________________________________
# block12_sepconv3_act (Activatio (None, 19, 19, 728)  0           block12_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block12_sepconv3 (SeparableConv (None, 19, 19, 728)  536536      block12_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block12_sepconv3_bn (BatchNorma (None, 19, 19, 728)  2912        block12_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 19, 19, 728)  0           block12_sepconv3_bn[0][0]
#                                                                  add_9[0][0]
# __________________________________________________________________________________________________
# block13_sepconv1_act (Activatio (None, 19, 19, 728)  0           add_10[0][0]
# __________________________________________________________________________________________________
# block13_sepconv1 (SeparableConv (None, 19, 19, 728)  536536      block13_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block13_sepconv1_bn (BatchNorma (None, 19, 19, 728)  2912        block13_sepconv1[0][0]
# __________________________________________________________________________________________________
# block13_sepconv2_act (Activatio (None, 19, 19, 728)  0           block13_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block13_sepconv2 (SeparableConv (None, 19, 19, 1024) 752024      block13_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block13_sepconv2_bn (BatchNorma (None, 19, 19, 1024) 4096        block13_sepconv2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 10, 10, 1024) 745472      add_10[0][0]
# __________________________________________________________________________________________________
# block13_pool (MaxPooling2D)     (None, 10, 10, 1024) 0           block13_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 10, 10, 1024) 4096        conv2d_3[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 10, 10, 1024) 0           block13_pool[0][0]
#                                                                  batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# block14_sepconv1 (SeparableConv (None, 10, 10, 1536) 1582080     add_11[0][0]
# __________________________________________________________________________________________________
# block14_sepconv1_bn (BatchNorma (None, 10, 10, 1536) 6144        block14_sepconv1[0][0]
# __________________________________________________________________________________________________
# block14_sepconv1_act (Activatio (None, 10, 10, 1536) 0           block14_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block14_sepconv2 (SeparableConv (None, 10, 10, 2048) 3159552     block14_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block14_sepconv2_bn (BatchNorma (None, 10, 10, 2048) 8192        block14_sepconv2[0][0]
# __________________________________________________________________________________________________
# block14_sepconv2_act (Activatio (None, 10, 10, 2048) 0           block14_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# avg_pool (GlobalAveragePooling2 (None, 2048)         0           block14_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 2048)         0           avg_pool[0][0]
# __________________________________________________________________________________________________
# predictions (Dense)             (None, 67)           137283      dropout[0][0]
# ==================================================================================================
# Total params: 20,998,763
# Trainable params: 20,944,235
# Non-trainable params: 54,528
# __________________________________________________________________________________________________

# %%
# 폴더 생성

os.makedirs(os.path.join(dir,'model_output',number,model.name), exist_ok=True)
os.makedirs(os.path.join(dir,'train_valid_output',number), exist_ok=True)

# %%
# AdamW 시작 / AdamWR은 epoch을 500번은 돌려야 될 것 같아 힘듦.
# 참고 : https://github.com/OverLordGoldDragon/keras-adamw

import sys
sys.path.append('/content/drive/My Drive/Colab Notebooks/Paper')
import utils
import optimizers_v2
from utils import get_weight_decays, fill_dict_in_order
from utils import reset_seeds, K_eval
from optimizers_v2 import AdamW, NadamW, SGDW

# %%
# top-5 accuracy 출력
import functools
top5_acc = functools.partial(ks.metrics.top_k_categorical_accuracy, k=5)
top5_acc.__name__ = 'top5_acc'

# %%
optimizer = AdamW(model=model, use_cosine_annealing=False, total_iterations = len(x_train) // batch_sizes)
#optimizer = Adam()
filepath =  os.path.join(dir,'model_output',number,model.name,'{epoch:03d}.h5')

callbacks_list = [ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_weights_only=False, save_best_only=True, mode='min'),
                  ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_weights_only=False, save_best_only=True, mode='max'),
                  #ReduceLROnPlateau(monitor='val_loss',patience=3,factor=0.1,min_lr=1e-5),
                  LearningRateScheduler(lr_schedule,verbose=1)
                  ]
                  
model.compile(optimizer, loss = 'categorical_crossentropy', metrics=['accuracy',top5_acc,macro_f1score])

# %%
######## flow_from_directory
history = model.fit(train_generator, steps_per_epoch=int(len(x_train)/batch_sizes),  validation_data = valid_generator, epochs=epochs, verbose=1 , callbacks = callbacks_list , validation_steps=int(len(x_valid)/batch_sizes))
# Out:
# Learning rate:  0.001
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 1/70
# 0.0(L1), 5.070201252832911e-08(L2) weight decay set for block1_conv1/kernel:0
# 0.0(L1), 5.070201252832911e-08(L2) weight decay set for block1_conv2/kernel:0
# 0.0(L1), 5.070201252832911e-08(L2) weight decay set for conv2d/kernel:0
# 0.0(L1), 5.070201252832911e-08(L2) weight decay set for conv2d_1/kernel:0
# 0.0(L1), 5.070201252832911e-08(L2) weight decay set for conv2d_2/kernel:0
# 0.0(L1), 5.070201252832911e-08(L2) weight decay set for conv2d_3/kernel:0
# 0.0(L1), 5.070201252832911e-08(L2) weight decay set for predictions/kernel:0
# 389/389 [==============================] - ETA: 0s - loss: 3.8098 - accuracy: 0.0939 - top5_acc: 0.3419 - macro_f1score: 9.1061e-04
# Epoch 00001: val_loss improved from inf to 4.72505, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/Xception/001.h5
#
# Epoch 00001: val_accuracy improved from -inf to 0.03516, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/Xception/001.h5
# 389/389 [==============================] - 10096s 26s/step - loss: 3.8098 - accuracy: 0.0939 - top5_acc: 0.3419 - macro_f1score: 9.1061e-04 - val_loss: 4.7250 - val_accuracy: 0.0352 - val_top5_acc: 0.1934 - val_macro_f1score: 0.0000e+00
# Learning rate:  0.001
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 2/70
# 389/389 [==============================] - ETA: 0s - loss: 3.4346 - accuracy: 0.1471 - top5_acc: 0.4420 - macro_f1score: 0.0020
# Epoch 00002: val_loss did not improve from 4.72505
#
# Epoch 00002: val_accuracy improved from 0.03516 to 0.13411, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/Xception/002.h5
# 389/389 [==============================] - 420s 1s/step - loss: 3.4346 - accuracy: 0.1471 - top5_acc: 0.4420 - macro_f1score: 0.0020 - val_loss: 4.8785 - val_accuracy: 0.1341 - val_top5_acc: 0.3932 - val_macro_f1score: 0.0098
# Learning rate:  0.001
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 3/70
# 389/389 [==============================] - ETA: 0s - loss: 3.1147 - accuracy: 0.2089 - top5_acc: 0.5320 - macro_f1score: 0.0094
# Epoch 00003: val_loss did not improve from 4.72505
#
# Epoch 00003: val_accuracy did not improve from 0.13411
# 389/389 [==============================] - 418s 1s/step - loss: 3.1147 - accuracy: 0.2089 - top5_acc: 0.5320 - macro_f1score: 0.0094 - val_loss: 38.5023 - val_accuracy: 0.0358 - val_top5_acc: 0.1120 - val_macro_f1score: 0.0036
# Learning rate:  0.001
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 4/70
# 389/389 [==============================] - ETA: 0s - loss: 2.8416 - accuracy: 0.2686 - top5_acc: 0.6017 - macro_f1score: 0.0234
# Epoch 00004: val_loss did not improve from 4.72505
#
# Epoch 00004: val_accuracy did not improve from 0.13411
# 389/389 [==============================] - 415s 1s/step - loss: 2.8416 - accuracy: 0.2686 - top5_acc: 0.6017 - macro_f1score: 0.0234 - val_loss: 8.6188 - val_accuracy: 0.0977 - val_top5_acc: 0.3008 - val_macro_f1score: 0.0127
# Learning rate:  0.001
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 5/70
# 389/389 [==============================] - ETA: 0s - loss: 2.5443 - accuracy: 0.3294 - top5_acc: 0.6765 - macro_f1score: 0.0459
# Epoch 00005: val_loss did not improve from 4.72505
#
# Epoch 00005: val_accuracy did not improve from 0.13411
# 389/389 [==============================] - 415s 1s/step - loss: 2.5443 - accuracy: 0.3294 - top5_acc: 0.6765 - macro_f1score: 0.0459 - val_loss: 511.7970 - val_accuracy: 0.0443 - val_top5_acc: 0.7376 - val_macro_f1score: 0.0026
# Learning rate:  0.001
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 6/70
# 389/389 [==============================] - ETA: 0s - loss: 2.3068 - accuracy: 0.3910 - top5_acc: 0.7271 - macro_f1score: 0.0655
# Epoch 00006: val_loss improved from 4.72505 to 3.65188, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/Xception/006.h5
#
# Epoch 00006: val_accuracy improved from 0.13411 to 0.22005, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/Xception/006.h5
# 389/389 [==============================] - 419s 1s/step - loss: 2.3068 - accuracy: 0.3910 - top5_acc: 0.7271 - macro_f1score: 0.0655 - val_loss: 3.6519 - val_accuracy: 0.2201 - val_top5_acc: 0.5312 - val_macro_f1score: 0.0435
# Learning rate:  0.001
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 7/70
# 389/389 [==============================] - ETA: 0s - loss: 2.1022 - accuracy: 0.4335 - top5_acc: 0.7698 - macro_f1score: 0.0857
# Epoch 00007: val_loss did not improve from 3.65188
#
# Epoch 00007: val_accuracy improved from 0.22005 to 0.24674, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/Xception/007.h5
# 389/389 [==============================] - 417s 1s/step - loss: 2.1022 - accuracy: 0.4335 - top5_acc: 0.7698 - macro_f1score: 0.0857 - val_loss: 5.0006 - val_accuracy: 0.2467 - val_top5_acc: 0.5098 - val_macro_f1score: 0.0460
# Learning rate:  0.001
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 8/70
# 389/389 [==============================] - ETA: 0s - loss: 1.9275 - accuracy: 0.4776 - top5_acc: 0.8032 - macro_f1score: 0.1053
# Epoch 00008: val_loss improved from 3.65188 to 2.16286, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/Xception/008.h5
#
# Epoch 00008: val_accuracy improved from 0.24674 to 0.43620, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/Xception/008.h5
# 389/389 [==============================] - 420s 1s/step - loss: 1.9275 - accuracy: 0.4776 - top5_acc: 0.8032 - macro_f1score: 0.1053 - val_loss: 2.1629 - val_accuracy: 0.4362 - val_top5_acc: 0.7650 - val_macro_f1score: 0.0903
# Learning rate:  0.001
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 9/70
# 389/389 [==============================] - ETA: 0s - loss: 1.8040 - accuracy: 0.5089 - top5_acc: 0.8263 - macro_f1score: 0.1221
# Epoch 00009: val_loss did not improve from 2.16286
#
# Epoch 00009: val_accuracy did not improve from 0.43620
# 389/389 [==============================] - 414s 1s/step - loss: 1.8040 - accuracy: 0.5089 - top5_acc: 0.8263 - macro_f1score: 0.1221 - val_loss: 2.2482 - val_accuracy: 0.4173 - val_top5_acc: 0.7402 - val_macro_f1score: 0.0962
# Learning rate:  0.001
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 10/70
# 389/389 [==============================] - ETA: 0s - loss: 1.6634 - accuracy: 0.5442 - top5_acc: 0.8524 - macro_f1score: 0.1375
# Epoch 00010: val_loss did not improve from 2.16286
#
# Epoch 00010: val_accuracy did not improve from 0.43620
# 389/389 [==============================] - 411s 1s/step - loss: 1.6634 - accuracy: 0.5442 - top5_acc: 0.8524 - macro_f1score: 0.1375 - val_loss: 2.4584 - val_accuracy: 0.4199 - val_top5_acc: 0.7272 - val_macro_f1score: 0.1042
# Learning rate:  0.001
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 11/70
# 389/389 [==============================] - ETA: 0s - loss: 1.5594 - accuracy: 0.5662 - top5_acc: 0.8631 - macro_f1score: 0.1492
# Epoch 00011: val_loss did not improve from 2.16286
#
# Epoch 00011: val_accuracy did not improve from 0.43620
# 389/389 [==============================] - 412s 1s/step - loss: 1.5594 - accuracy: 0.5662 - top5_acc: 0.8631 - macro_f1score: 0.1492 - val_loss: 2.8790 - val_accuracy: 0.4043 - val_top5_acc: 0.6810 - val_macro_f1score: 0.1081
# Learning rate:  0.001
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 12/70
# 389/389 [==============================] - ETA: 0s - loss: 1.4363 - accuracy: 0.5983 - top5_acc: 0.8856 - macro_f1score: 0.1672
# Epoch 00012: val_loss did not improve from 2.16286
#
# Epoch 00012: val_accuracy improved from 0.43620 to 0.45508, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/Xception/012.h5
# 389/389 [==============================] - 413s 1s/step - loss: 1.4363 - accuracy: 0.5983 - top5_acc: 0.8856 - macro_f1score: 0.1672 - val_loss: 2.2656 - val_accuracy: 0.4551 - val_top5_acc: 0.7695 - val_macro_f1score: 0.1193
# Learning rate:  0.001
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 13/70
# 389/389 [==============================] - ETA: 0s - loss: 1.3500 - accuracy: 0.6196 - top5_acc: 0.8990 - macro_f1score: 0.1769
# Epoch 00013: val_loss did not improve from 2.16286
#
# Epoch 00013: val_accuracy did not improve from 0.45508
# 389/389 [==============================] - 412s 1s/step - loss: 1.3500 - accuracy: 0.6196 - top5_acc: 0.8990 - macro_f1score: 0.1769 - val_loss: 2.2482 - val_accuracy: 0.4544 - val_top5_acc: 0.8040 - val_macro_f1score: 0.1251
# Learning rate:  0.001
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 14/70
# 389/389 [==============================] - ETA: 0s - loss: 1.2553 - accuracy: 0.6427 - top5_acc: 0.9116 - macro_f1score: 0.1878
# Epoch 00014: val_loss did not improve from 2.16286
#
# Epoch 00014: val_accuracy did not improve from 0.45508
# 389/389 [==============================] - 407s 1s/step - loss: 1.2553 - accuracy: 0.6427 - top5_acc: 0.9116 - macro_f1score: 0.1878 - val_loss: 2.4659 - val_accuracy: 0.4355 - val_top5_acc: 0.7363 - val_macro_f1score: 0.1242
# Learning rate:  0.001
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 15/70
# 389/389 [==============================] - ETA: 0s - loss: 1.1769 - accuracy: 0.6617 - top5_acc: 0.9240 - macro_f1score: 0.1979
# Epoch 00015: val_loss improved from 2.16286 to 2.11378, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/Xception/015.h5
#
# Epoch 00015: val_accuracy improved from 0.45508 to 0.48698, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/Xception/015.h5
# 389/389 [==============================] - 404s 1s/step - loss: 1.1769 - accuracy: 0.6617 - top5_acc: 0.9240 - macro_f1score: 0.1979 - val_loss: 2.1138 - val_accuracy: 0.4870 - val_top5_acc: 0.8112 - val_macro_f1score: 0.1356
# Learning rate:  0.001
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 16/70
# 389/389 [==============================] - ETA: 0s - loss: 1.0825 - accuracy: 0.6909 - top5_acc: 0.9349 - macro_f1score: 0.2100
# Epoch 00016: val_loss did not improve from 2.11378
#
# Epoch 00016: val_accuracy did not improve from 0.48698
# 389/389 [==============================] - 402s 1s/step - loss: 1.0825 - accuracy: 0.6909 - top5_acc: 0.9349 - macro_f1score: 0.2100 - val_loss: 2.2911 - val_accuracy: 0.4824 - val_top5_acc: 0.7904 - val_macro_f1score: 0.1451
# Learning rate:  0.001
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 17/70
# 389/389 [==============================] - ETA: 0s - loss: 1.0187 - accuracy: 0.7077 - top5_acc: 0.9397 - macro_f1score: 0.2202
# Epoch 00017: val_loss did not improve from 2.11378
#
# Epoch 00017: val_accuracy improved from 0.48698 to 0.50326, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/Xception/017.h5
# 389/389 [==============================] - 402s 1s/step - loss: 1.0187 - accuracy: 0.7077 - top5_acc: 0.9397 - macro_f1score: 0.2202 - val_loss: 2.1936 - val_accuracy: 0.5033 - val_top5_acc: 0.8177 - val_macro_f1score: 0.1529
# Learning rate:  0.001
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 18/70
# 389/389 [==============================] - ETA: 0s - loss: 0.9432 - accuracy: 0.7295 - top5_acc: 0.9533 - macro_f1score: 0.2300
# Epoch 00018: val_loss did not improve from 2.11378
#
# Epoch 00018: val_accuracy did not improve from 0.50326
# 389/389 [==============================] - 401s 1s/step - loss: 0.9432 - accuracy: 0.7295 - top5_acc: 0.9533 - macro_f1score: 0.2300 - val_loss: 2.9441 - val_accuracy: 0.4395 - val_top5_acc: 0.7493 - val_macro_f1score: 0.1286
# Learning rate:  0.001
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 19/70
# 389/389 [==============================] - ETA: 0s - loss: 0.8687 - accuracy: 0.7531 - top5_acc: 0.9587 - macro_f1score: 0.2417
# Epoch 00019: val_loss improved from 2.11378 to 1.77080, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/Xception/019.h5
#
# Epoch 00019: val_accuracy improved from 0.50326 to 0.58464, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/Xception/019.h5
# 389/389 [==============================] - 402s 1s/step - loss: 0.8687 - accuracy: 0.7531 - top5_acc: 0.9587 - macro_f1score: 0.2417 - val_loss: 1.7708 - val_accuracy: 0.5846 - val_top5_acc: 0.8672 - val_macro_f1score: 0.1732
# Learning rate:  0.001
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 20/70
# 389/389 [==============================] - ETA: 0s - loss: 0.8028 - accuracy: 0.7670 - top5_acc: 0.9677 - macro_f1score: 0.2497
# Epoch 00020: val_loss did not improve from 1.77080
#
# Epoch 00020: val_accuracy did not improve from 0.58464
# 389/389 [==============================] - 400s 1s/step - loss: 0.8028 - accuracy: 0.7670 - top5_acc: 0.9677 - macro_f1score: 0.2497 - val_loss: 2.7326 - val_accuracy: 0.4655 - val_top5_acc: 0.7865 - val_macro_f1score: 0.1334
# Learning rate:  0.001
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 21/70
# 389/389 [==============================] - ETA: 0s - loss: 0.7470 - accuracy: 0.7884 - top5_acc: 0.9731 - macro_f1score: 0.2568
# Epoch 00021: val_loss did not improve from 1.77080
#
# Epoch 00021: val_accuracy did not improve from 0.58464
# 389/389 [==============================] - 399s 1s/step - loss: 0.7470 - accuracy: 0.7884 - top5_acc: 0.9731 - macro_f1score: 0.2568 - val_loss: 2.3095 - val_accuracy: 0.5371 - val_top5_acc: 0.8242 - val_macro_f1score: 0.1613
# Learning rate:  0.001
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 22/70
# 389/389 [==============================] - ETA: 0s - loss: 0.6863 - accuracy: 0.8028 - top5_acc: 0.9792 - macro_f1score: 0.2652
# Epoch 00022: val_loss did not improve from 1.77080
#
# Epoch 00022: val_accuracy did not improve from 0.58464
# 389/389 [==============================] - 398s 1s/step - loss: 0.6863 - accuracy: 0.8028 - top5_acc: 0.9792 - macro_f1score: 0.2652 - val_loss: 2.3744 - val_accuracy: 0.5260 - val_top5_acc: 0.8320 - val_macro_f1score: 0.1643
# Learning rate:  0.001
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 23/70
# 389/389 [==============================] - ETA: 0s - loss: 0.6419 - accuracy: 0.8170 - top5_acc: 0.9829 - macro_f1score: 0.2710
# Epoch 00023: val_loss did not improve from 1.77080
#
# Epoch 00023: val_accuracy did not improve from 0.58464
# 389/389 [==============================] - 398s 1s/step - loss: 0.6419 - accuracy: 0.8170 - top5_acc: 0.9829 - macro_f1score: 0.2710 - val_loss: 2.6162 - val_accuracy: 0.4974 - val_top5_acc: 0.8034 - val_macro_f1score: 0.1546
# Learning rate:  0.001
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 24/70
# 389/389 [==============================] - ETA: 0s - loss: 0.5982 - accuracy: 0.8319 - top5_acc: 0.9823 - macro_f1score: 0.2778
# Epoch 00024: val_loss did not improve from 1.77080
#
# Epoch 00024: val_accuracy did not improve from 0.58464
# 389/389 [==============================] - 402s 1s/step - loss: 0.5982 - accuracy: 0.8319 - top5_acc: 0.9823 - macro_f1score: 0.2778 - val_loss: 2.2820 - val_accuracy: 0.5345 - val_top5_acc: 0.8418 - val_macro_f1score: 0.1683
# Learning rate:  0.001
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 25/70
# 389/389 [==============================] - ETA: 0s - loss: 0.5386 - accuracy: 0.8506 - top5_acc: 0.9862 - macro_f1score: 0.2886
# Epoch 00025: val_loss did not improve from 1.77080
#
# Epoch 00025: val_accuracy did not improve from 0.58464
# 389/389 [==============================] - 401s 1s/step - loss: 0.5386 - accuracy: 0.8506 - top5_acc: 0.9862 - macro_f1score: 0.2886 - val_loss: 2.7386 - val_accuracy: 0.5052 - val_top5_acc: 0.7826 - val_macro_f1score: 0.1639
# Learning rate:  0.001
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 26/70
# 389/389 [==============================] - ETA: 0s - loss: 0.5084 - accuracy: 0.8606 - top5_acc: 0.9894 - macro_f1score: 0.2896
# Epoch 00026: val_loss did not improve from 1.77080
#
# Epoch 00026: val_accuracy did not improve from 0.58464
# 389/389 [==============================] - 400s 1s/step - loss: 0.5084 - accuracy: 0.8606 - top5_acc: 0.9894 - macro_f1score: 0.2896 - val_loss: 3.2965 - val_accuracy: 0.4583 - val_top5_acc: 0.7487 - val_macro_f1score: 0.1361
# Learning rate:  0.001
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 27/70
# 389/389 [==============================] - ETA: 0s - loss: 0.4795 - accuracy: 0.8691 - top5_acc: 0.9916 - macro_f1score: 0.2939
# Epoch 00027: val_loss did not improve from 1.77080
#
# Epoch 00027: val_accuracy did not improve from 0.58464
# 389/389 [==============================] - 402s 1s/step - loss: 0.4795 - accuracy: 0.8691 - top5_acc: 0.9916 - macro_f1score: 0.2939 - val_loss: 2.6572 - val_accuracy: 0.5169 - val_top5_acc: 0.8516 - val_macro_f1score: 0.1555
# Learning rate:  0.001
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 28/70
# 389/389 [==============================] - ETA: 0s - loss: 0.4533 - accuracy: 0.8801 - top5_acc: 0.9906 - macro_f1score: 0.3010
# Epoch 00028: val_loss did not improve from 1.77080
#
# Epoch 00028: val_accuracy did not improve from 0.58464
# 389/389 [==============================] - 401s 1s/step - loss: 0.4533 - accuracy: 0.8801 - top5_acc: 0.9906 - macro_f1score: 0.3010 - val_loss: 2.1872 - val_accuracy: 0.5612 - val_top5_acc: 0.8444 - val_macro_f1score: 0.1770
# Learning rate:  0.001
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 29/70
# 389/389 [==============================] - ETA: 0s - loss: 0.4258 - accuracy: 0.8889 - top5_acc: 0.9920 - macro_f1score: 0.3043
# Epoch 00029: val_loss did not improve from 1.77080
#
# Epoch 00029: val_accuracy did not improve from 0.58464
# 389/389 [==============================] - 398s 1s/step - loss: 0.4258 - accuracy: 0.8889 - top5_acc: 0.9920 - macro_f1score: 0.3043 - val_loss: 2.3610 - val_accuracy: 0.5729 - val_top5_acc: 0.8516 - val_macro_f1score: 0.1799
# Learning rate:  0.001
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 30/70
# 389/389 [==============================] - ETA: 0s - loss: 0.4204 - accuracy: 0.8934 - top5_acc: 0.9939 - macro_f1score: 0.3048
# Epoch 00030: val_loss did not improve from 1.77080
#
# Epoch 00030: val_accuracy did not improve from 0.58464
# 389/389 [==============================] - 400s 1s/step - loss: 0.4204 - accuracy: 0.8934 - top5_acc: 0.9939 - macro_f1score: 0.3048 - val_loss: 2.8118 - val_accuracy: 0.5280 - val_top5_acc: 0.8053 - val_macro_f1score: 0.1729
# Learning rate:  0.0001
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 31/70
# 389/389 [==============================] - ETA: 0s - loss: 0.2714 - accuracy: 0.9418 - top5_acc: 0.9982 - macro_f1score: 0.3272
# Epoch 00031: val_loss improved from 1.77080 to 1.59669, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/Xception/031.h5
#
# Epoch 00031: val_accuracy improved from 0.58464 to 0.65365, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/Xception/031.h5
# 389/389 [==============================] - 405s 1s/step - loss: 0.2714 - accuracy: 0.9418 - top5_acc: 0.9982 - macro_f1score: 0.3272 - val_loss: 1.5967 - val_accuracy: 0.6536 - val_top5_acc: 0.8913 - val_macro_f1score: 0.2130
# Learning rate:  0.0001
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 32/70
# 389/389 [==============================] - ETA: 0s - loss: 0.2176 - accuracy: 0.9612 - top5_acc: 0.9990 - macro_f1score: 0.3352
# Epoch 00032: val_loss did not improve from 1.59669
#
# Epoch 00032: val_accuracy improved from 0.65365 to 0.65820, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/Xception/032.h5
# 389/389 [==============================] - 409s 1s/step - loss: 0.2176 - accuracy: 0.9612 - top5_acc: 0.9990 - macro_f1score: 0.3352 - val_loss: 1.6099 - val_accuracy: 0.6582 - val_top5_acc: 0.8952 - val_macro_f1score: 0.2177
# Learning rate:  0.0001
#
# Epoch 00033: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 33/70
# 389/389 [==============================] - ETA: 0s - loss: 0.1934 - accuracy: 0.9682 - top5_acc: 0.9994 - macro_f1score: 0.3383
# Epoch 00033: val_loss did not improve from 1.59669
#
# Epoch 00033: val_accuracy did not improve from 0.65820
# 389/389 [==============================] - 410s 1s/step - loss: 0.1934 - accuracy: 0.9682 - top5_acc: 0.9994 - macro_f1score: 0.3383 - val_loss: 1.6315 - val_accuracy: 0.6491 - val_top5_acc: 0.9010 - val_macro_f1score: 0.2095
# Learning rate:  0.0001
#
# Epoch 00034: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 34/70
# 389/389 [==============================] - ETA: 0s - loss: 0.1851 - accuracy: 0.9690 - top5_acc: 0.9992 - macro_f1score: 0.3372
# Epoch 00034: val_loss improved from 1.59669 to 1.59010, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/Xception/034.h5
#
# Epoch 00034: val_accuracy did not improve from 0.65820
# 389/389 [==============================] - 409s 1s/step - loss: 0.1851 - accuracy: 0.9690 - top5_acc: 0.9992 - macro_f1score: 0.3372 - val_loss: 1.5901 - val_accuracy: 0.6543 - val_top5_acc: 0.9010 - val_macro_f1score: 0.2113
# Learning rate:  0.0001
#
# Epoch 00035: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 35/70
# 389/389 [==============================] - ETA: 0s - loss: 0.1739 - accuracy: 0.9706 - top5_acc: 0.9998 - macro_f1score: 0.3368
# Epoch 00035: val_loss did not improve from 1.59010
#
# Epoch 00035: val_accuracy did not improve from 0.65820
# 389/389 [==============================] - 407s 1s/step - loss: 0.1739 - accuracy: 0.9706 - top5_acc: 0.9998 - macro_f1score: 0.3368 - val_loss: 1.6215 - val_accuracy: 0.6562 - val_top5_acc: 0.9049 - val_macro_f1score: 0.2114
# Learning rate:  0.0001
#
# Epoch 00036: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 36/70
# 389/389 [==============================] - ETA: 0s - loss: 0.1664 - accuracy: 0.9750 - top5_acc: 0.9997 - macro_f1score: 0.3411
# Epoch 00036: val_loss did not improve from 1.59010
#
# Epoch 00036: val_accuracy did not improve from 0.65820
# 389/389 [==============================] - 408s 1s/step - loss: 0.1664 - accuracy: 0.9750 - top5_acc: 0.9997 - macro_f1score: 0.3411 - val_loss: 1.6356 - val_accuracy: 0.6556 - val_top5_acc: 0.9043 - val_macro_f1score: 0.2149
# Learning rate:  0.0001
#
# Epoch 00037: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 37/70
# 389/389 [==============================] - ETA: 0s - loss: 0.1583 - accuracy: 0.9778 - top5_acc: 0.9997 - macro_f1score: 0.3420
# Epoch 00037: val_loss did not improve from 1.59010
#
# Epoch 00037: val_accuracy did not improve from 0.65820
# 389/389 [==============================] - 410s 1s/step - loss: 0.1583 - accuracy: 0.9778 - top5_acc: 0.9997 - macro_f1score: 0.3420 - val_loss: 1.6567 - val_accuracy: 0.6549 - val_top5_acc: 0.9023 - val_macro_f1score: 0.2186
# Learning rate:  0.0001
#
# Epoch 00038: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 38/70
# 389/389 [==============================] - ETA: 0s - loss: 0.1556 - accuracy: 0.9764 - top5_acc: 0.9997 - macro_f1score: 0.3436
# Epoch 00038: val_loss did not improve from 1.59010
#
# Epoch 00038: val_accuracy did not improve from 0.65820
# 389/389 [==============================] - 406s 1s/step - loss: 0.1556 - accuracy: 0.9764 - top5_acc: 0.9997 - macro_f1score: 0.3436 - val_loss: 1.7597 - val_accuracy: 0.6426 - val_top5_acc: 0.8984 - val_macro_f1score: 0.2067
# Learning rate:  0.0001
#
# Epoch 00039: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 39/70
# 389/389 [==============================] - ETA: 0s - loss: 0.1500 - accuracy: 0.9804 - top5_acc: 0.9999 - macro_f1score: 0.3420
# Epoch 00039: val_loss did not improve from 1.59010
#
# Epoch 00039: val_accuracy improved from 0.65820 to 0.66211, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/Xception/039.h5
# 389/389 [==============================] - 407s 1s/step - loss: 0.1500 - accuracy: 0.9804 - top5_acc: 0.9999 - macro_f1score: 0.3420 - val_loss: 1.6653 - val_accuracy: 0.6621 - val_top5_acc: 0.9036 - val_macro_f1score: 0.2136
# Learning rate:  0.0001
#
# Epoch 00040: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 40/70
# 389/389 [==============================] - ETA: 0s - loss: 0.1435 - accuracy: 0.9826 - top5_acc: 0.9998 - macro_f1score: 0.3449
# Epoch 00040: val_loss did not improve from 1.59010
#
# Epoch 00040: val_accuracy did not improve from 0.66211
# 389/389 [==============================] - 405s 1s/step - loss: 0.1435 - accuracy: 0.9826 - top5_acc: 0.9998 - macro_f1score: 0.3449 - val_loss: 1.6887 - val_accuracy: 0.6556 - val_top5_acc: 0.9069 - val_macro_f1score: 0.2122
# Learning rate:  0.0001
#
# Epoch 00041: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 41/70
# 389/389 [==============================] - ETA: 0s - loss: 0.1382 - accuracy: 0.9833 - top5_acc: 0.9999 - macro_f1score: 0.3441
# Epoch 00041: val_loss did not improve from 1.59010
#
# Epoch 00041: val_accuracy did not improve from 0.66211
# 389/389 [==============================] - 406s 1s/step - loss: 0.1382 - accuracy: 0.9833 - top5_acc: 0.9999 - macro_f1score: 0.3441 - val_loss: 1.7382 - val_accuracy: 0.6608 - val_top5_acc: 0.8932 - val_macro_f1score: 0.2140
# Learning rate:  0.0001
#
# Epoch 00042: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 42/70
# 389/389 [==============================] - ETA: 0s - loss: 0.1365 - accuracy: 0.9835 - top5_acc: 1.0000 - macro_f1score: 0.3447
# Epoch 00042: val_loss did not improve from 1.59010
#
# Epoch 00042: val_accuracy did not improve from 0.66211
# 389/389 [==============================] - 405s 1s/step - loss: 0.1365 - accuracy: 0.9835 - top5_acc: 1.0000 - macro_f1score: 0.3447 - val_loss: 1.7188 - val_accuracy: 0.6621 - val_top5_acc: 0.8965 - val_macro_f1score: 0.2180
# Learning rate:  0.0001
#
# Epoch 00043: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 43/70
# 389/389 [==============================] - ETA: 0s - loss: 0.1364 - accuracy: 0.9830 - top5_acc: 0.9998 - macro_f1score: 0.3435
# Epoch 00043: val_loss did not improve from 1.59010
#
# Epoch 00043: val_accuracy did not improve from 0.66211
# 389/389 [==============================] - 407s 1s/step - loss: 0.1364 - accuracy: 0.9830 - top5_acc: 0.9998 - macro_f1score: 0.3435 - val_loss: 1.7634 - val_accuracy: 0.6445 - val_top5_acc: 0.9017 - val_macro_f1score: 0.2073
# Learning rate:  0.0001
#
# Epoch 00044: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 44/70
# 389/389 [==============================] - ETA: 0s - loss: 0.1316 - accuracy: 0.9866 - top5_acc: 0.9998 - macro_f1score: 0.3456
# Epoch 00044: val_loss did not improve from 1.59010
#
# Epoch 00044: val_accuracy did not improve from 0.66211
# 389/389 [==============================] - 410s 1s/step - loss: 0.1316 - accuracy: 0.9866 - top5_acc: 0.9998 - macro_f1score: 0.3456 - val_loss: 1.7426 - val_accuracy: 0.6595 - val_top5_acc: 0.8997 - val_macro_f1score: 0.2150
# Learning rate:  0.0001
#
# Epoch 00045: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 45/70
# 389/389 [==============================] - ETA: 0s - loss: 0.1320 - accuracy: 0.9844 - top5_acc: 0.9997 - macro_f1score: 0.3457
# Epoch 00045: val_loss did not improve from 1.59010
#
# Epoch 00045: val_accuracy did not improve from 0.66211
# 389/389 [==============================] - 408s 1s/step - loss: 0.1320 - accuracy: 0.9844 - top5_acc: 0.9997 - macro_f1score: 0.3457 - val_loss: 1.7951 - val_accuracy: 0.6445 - val_top5_acc: 0.9062 - val_macro_f1score: 0.2063
# Learning rate:  0.0001
#
# Epoch 00046: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 46/70
# 389/389 [==============================] - ETA: 0s - loss: 0.1291 - accuracy: 0.9860 - top5_acc: 0.9998 - macro_f1score: 0.3463
# Epoch 00046: val_loss did not improve from 1.59010
#
# Epoch 00046: val_accuracy did not improve from 0.66211
# 389/389 [==============================] - 408s 1s/step - loss: 0.1291 - accuracy: 0.9860 - top5_acc: 0.9998 - macro_f1score: 0.3463 - val_loss: 1.7550 - val_accuracy: 0.6543 - val_top5_acc: 0.9030 - val_macro_f1score: 0.2129
# Learning rate:  0.0001
#
# Epoch 00047: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 47/70
# 389/389 [==============================] - ETA: 0s - loss: 0.1263 - accuracy: 0.9872 - top5_acc: 0.9997 - macro_f1score: 0.3445
# Epoch 00047: val_loss did not improve from 1.59010
#
# Epoch 00047: val_accuracy did not improve from 0.66211
# 389/389 [==============================] - 411s 1s/step - loss: 0.1263 - accuracy: 0.9872 - top5_acc: 0.9997 - macro_f1score: 0.3445 - val_loss: 1.7414 - val_accuracy: 0.6608 - val_top5_acc: 0.9049 - val_macro_f1score: 0.2168
# Learning rate:  0.0001
#
# Epoch 00048: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 48/70
# 389/389 [==============================] - ETA: 0s - loss: 0.1264 - accuracy: 0.9870 - top5_acc: 1.0000 - macro_f1score: 0.3477
# Epoch 00048: val_loss did not improve from 1.59010
#
# Epoch 00048: val_accuracy did not improve from 0.66211
# 389/389 [==============================] - 408s 1s/step - loss: 0.1264 - accuracy: 0.9870 - top5_acc: 1.0000 - macro_f1score: 0.3477 - val_loss: 1.8271 - val_accuracy: 0.6523 - val_top5_acc: 0.8971 - val_macro_f1score: 0.2167
# Learning rate:  0.0001
#
# Epoch 00049: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 49/70
# 389/389 [==============================] - ETA: 0s - loss: 0.1175 - accuracy: 0.9895 - top5_acc: 0.9998 - macro_f1score: 0.3467
# Epoch 00049: val_loss did not improve from 1.59010
#
# Epoch 00049: val_accuracy did not improve from 0.66211
# 389/389 [==============================] - 407s 1s/step - loss: 0.1175 - accuracy: 0.9895 - top5_acc: 0.9998 - macro_f1score: 0.3467 - val_loss: 1.7993 - val_accuracy: 0.6569 - val_top5_acc: 0.8978 - val_macro_f1score: 0.2140
# Learning rate:  0.0001
#
# Epoch 00050: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 50/70
# 389/389 [==============================] - ETA: 0s - loss: 0.1202 - accuracy: 0.9887 - top5_acc: 0.9998 - macro_f1score: 0.3453
# Epoch 00050: val_loss did not improve from 1.59010
#
# Epoch 00050: val_accuracy did not improve from 0.66211
# 389/389 [==============================] - 409s 1s/step - loss: 0.1202 - accuracy: 0.9887 - top5_acc: 0.9998 - macro_f1score: 0.3453 - val_loss: 1.8220 - val_accuracy: 0.6517 - val_top5_acc: 0.9010 - val_macro_f1score: 0.2138
# Learning rate:  0.0001
#
# Epoch 00051: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 51/70
# 389/389 [==============================] - ETA: 0s - loss: 0.1180 - accuracy: 0.9883 - top5_acc: 0.9999 - macro_f1score: 0.3466
# Epoch 00051: val_loss did not improve from 1.59010
#
# Epoch 00051: val_accuracy did not improve from 0.66211
# 389/389 [==============================] - 406s 1s/step - loss: 0.1180 - accuracy: 0.9883 - top5_acc: 0.9999 - macro_f1score: 0.3466 - val_loss: 1.8500 - val_accuracy: 0.6465 - val_top5_acc: 0.9082 - val_macro_f1score: 0.2099
# Learning rate:  0.0001
#
# Epoch 00052: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 52/70
# 389/389 [==============================] - ETA: 0s - loss: 0.1160 - accuracy: 0.9903 - top5_acc: 0.9999 - macro_f1score: 0.3461
# Epoch 00052: val_loss did not improve from 1.59010
#
# Epoch 00052: val_accuracy did not improve from 0.66211
# 389/389 [==============================] - 405s 1s/step - loss: 0.1160 - accuracy: 0.9903 - top5_acc: 0.9999 - macro_f1score: 0.3461 - val_loss: 1.8132 - val_accuracy: 0.6517 - val_top5_acc: 0.9010 - val_macro_f1score: 0.2104
# Learning rate:  0.0001
#
# Epoch 00053: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 53/70
# 389/389 [==============================] - ETA: 0s - loss: 0.1151 - accuracy: 0.9906 - top5_acc: 0.9999 - macro_f1score: 0.3483
# Epoch 00053: val_loss did not improve from 1.59010
#
# Epoch 00053: val_accuracy did not improve from 0.66211
# 389/389 [==============================] - 407s 1s/step - loss: 0.1151 - accuracy: 0.9906 - top5_acc: 0.9999 - macro_f1score: 0.3483 - val_loss: 1.8258 - val_accuracy: 0.6465 - val_top5_acc: 0.9030 - val_macro_f1score: 0.2103
# Learning rate:  0.0001
#
# Epoch 00054: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 54/70
# 389/389 [==============================] - ETA: 0s - loss: 0.1121 - accuracy: 0.9901 - top5_acc: 0.9998 - macro_f1score: 0.3475
# Epoch 00054: val_loss did not improve from 1.59010
#
# Epoch 00054: val_accuracy did not improve from 0.66211
# 389/389 [==============================] - 412s 1s/step - loss: 0.1121 - accuracy: 0.9901 - top5_acc: 0.9998 - macro_f1score: 0.3475 - val_loss: 1.8173 - val_accuracy: 0.6510 - val_top5_acc: 0.8984 - val_macro_f1score: 0.2108
# Learning rate:  0.0001
#
# Epoch 00055: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 55/70
# 389/389 [==============================] - ETA: 0s - loss: 0.1135 - accuracy: 0.9888 - top5_acc: 0.9998 - macro_f1score: 0.3462
# Epoch 00055: val_loss did not improve from 1.59010
#
# Epoch 00055: val_accuracy did not improve from 0.66211
# 389/389 [==============================] - 414s 1s/step - loss: 0.1135 - accuracy: 0.9888 - top5_acc: 0.9998 - macro_f1score: 0.3462 - val_loss: 1.8433 - val_accuracy: 0.6426 - val_top5_acc: 0.9030 - val_macro_f1score: 0.2089
# Learning rate:  0.0001
#
# Epoch 00056: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 56/70
# 389/389 [==============================] - ETA: 0s - loss: 0.1153 - accuracy: 0.9884 - top5_acc: 1.0000 - macro_f1score: 0.3476
# Epoch 00056: val_loss did not improve from 1.59010
#
# Epoch 00056: val_accuracy did not improve from 0.66211
# 389/389 [==============================] - 415s 1s/step - loss: 0.1153 - accuracy: 0.9884 - top5_acc: 1.0000 - macro_f1score: 0.3476 - val_loss: 1.8648 - val_accuracy: 0.6497 - val_top5_acc: 0.9043 - val_macro_f1score: 0.2118
# Learning rate:  0.0001
#
# Epoch 00057: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 57/70
# 389/389 [==============================] - ETA: 0s - loss: 0.1089 - accuracy: 0.9908 - top5_acc: 0.9999 - macro_f1score: 0.3485
# Epoch 00057: val_loss did not improve from 1.59010
#
# Epoch 00057: val_accuracy did not improve from 0.66211
# 389/389 [==============================] - 413s 1s/step - loss: 0.1089 - accuracy: 0.9908 - top5_acc: 0.9999 - macro_f1score: 0.3485 - val_loss: 1.8657 - val_accuracy: 0.6491 - val_top5_acc: 0.9049 - val_macro_f1score: 0.2109
# Learning rate:  0.0001
#
# Epoch 00058: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 58/70
# 389/389 [==============================] - ETA: 0s - loss: 0.1106 - accuracy: 0.9900 - top5_acc: 0.9999 - macro_f1score: 0.3491
# Epoch 00058: val_loss did not improve from 1.59010
#
# Epoch 00058: val_accuracy did not improve from 0.66211
# 389/389 [==============================] - 414s 1s/step - loss: 0.1106 - accuracy: 0.9900 - top5_acc: 0.9999 - macro_f1score: 0.3491 - val_loss: 1.9163 - val_accuracy: 0.6432 - val_top5_acc: 0.9017 - val_macro_f1score: 0.2089
# Learning rate:  0.0001
#
# Epoch 00059: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 59/70
# 389/389 [==============================] - ETA: 0s - loss: 0.1065 - accuracy: 0.9911 - top5_acc: 0.9998 - macro_f1score: 0.3469
# Epoch 00059: val_loss did not improve from 1.59010
#
# Epoch 00059: val_accuracy did not improve from 0.66211
# 389/389 [==============================] - 414s 1s/step - loss: 0.1065 - accuracy: 0.9911 - top5_acc: 0.9998 - macro_f1score: 0.3469 - val_loss: 1.8851 - val_accuracy: 0.6556 - val_top5_acc: 0.9017 - val_macro_f1score: 0.2136
# Learning rate:  0.0001
#
# Epoch 00060: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 60/70
# 389/389 [==============================] - ETA: 0s - loss: 0.1094 - accuracy: 0.9908 - top5_acc: 0.9999 - macro_f1score: 0.3487
# Epoch 00060: val_loss did not improve from 1.59010
#
# Epoch 00060: val_accuracy did not improve from 0.66211
# 389/389 [==============================] - 411s 1s/step - loss: 0.1094 - accuracy: 0.9908 - top5_acc: 0.9999 - macro_f1score: 0.3487 - val_loss: 1.8227 - val_accuracy: 0.6530 - val_top5_acc: 0.8997 - val_macro_f1score: 0.2137
# Learning rate:  1e-05
#
# Epoch 00061: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 61/70
# 389/389 [==============================] - ETA: 0s - loss: 0.1027 - accuracy: 0.9923 - top5_acc: 0.9999 - macro_f1score: 0.3478
# Epoch 00061: val_loss did not improve from 1.59010
#
# Epoch 00061: val_accuracy improved from 0.66211 to 0.66276, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/Xception/061.h5
# 389/389 [==============================] - 413s 1s/step - loss: 0.1027 - accuracy: 0.9923 - top5_acc: 0.9999 - macro_f1score: 0.3478 - val_loss: 1.7871 - val_accuracy: 0.6628 - val_top5_acc: 0.9043 - val_macro_f1score: 0.2160
# Learning rate:  1e-05
#
# Epoch 00062: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 62/70
# 389/389 [==============================] - ETA: 0s - loss: 0.1024 - accuracy: 0.9920 - top5_acc: 1.0000 - macro_f1score: 0.3459
# Epoch 00062: val_loss did not improve from 1.59010
#
# Epoch 00062: val_accuracy improved from 0.66276 to 0.66471, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/Xception/062.h5
# 389/389 [==============================] - 414s 1s/step - loss: 0.1024 - accuracy: 0.9920 - top5_acc: 1.0000 - macro_f1score: 0.3459 - val_loss: 1.7700 - val_accuracy: 0.6647 - val_top5_acc: 0.9062 - val_macro_f1score: 0.2205
# Learning rate:  1e-05
#
# Epoch 00063: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 63/70
# 389/389 [==============================] - ETA: 0s - loss: 0.1013 - accuracy: 0.9925 - top5_acc: 1.0000 - macro_f1score: 0.3499
# Epoch 00063: val_loss did not improve from 1.59010
#
# Epoch 00063: val_accuracy did not improve from 0.66471
# 389/389 [==============================] - 413s 1s/step - loss: 0.1013 - accuracy: 0.9925 - top5_acc: 1.0000 - macro_f1score: 0.3499 - val_loss: 1.7794 - val_accuracy: 0.6641 - val_top5_acc: 0.9082 - val_macro_f1score: 0.2104
# Learning rate:  1e-05
#
# Epoch 00064: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 64/70
# 389/389 [==============================] - ETA: 0s - loss: 0.0985 - accuracy: 0.9945 - top5_acc: 0.9999 - macro_f1score: 0.3496
# Epoch 00064: val_loss did not improve from 1.59010
#
# Epoch 00064: val_accuracy improved from 0.66471 to 0.66536, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/Xception/064.h5
# 389/389 [==============================] - 413s 1s/step - loss: 0.0985 - accuracy: 0.9945 - top5_acc: 0.9999 - macro_f1score: 0.3496 - val_loss: 1.7808 - val_accuracy: 0.6654 - val_top5_acc: 0.9076 - val_macro_f1score: 0.2160
# Learning rate:  1e-05
#
# Epoch 00065: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 65/70
# 389/389 [==============================] - ETA: 0s - loss: 0.1017 - accuracy: 0.9933 - top5_acc: 1.0000 - macro_f1score: 0.3477
# Epoch 00065: val_loss did not improve from 1.59010
#
# Epoch 00065: val_accuracy did not improve from 0.66536
# 389/389 [==============================] - 414s 1s/step - loss: 0.1017 - accuracy: 0.9933 - top5_acc: 1.0000 - macro_f1score: 0.3477 - val_loss: 1.7851 - val_accuracy: 0.6641 - val_top5_acc: 0.9030 - val_macro_f1score: 0.2202
# Learning rate:  1e-05
#
# Epoch 00066: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 66/70
# 389/389 [==============================] - ETA: 0s - loss: 0.1002 - accuracy: 0.9936 - top5_acc: 0.9999 - macro_f1score: 0.3511
# Epoch 00066: val_loss did not improve from 1.59010
#
# Epoch 00066: val_accuracy did not improve from 0.66536
# 389/389 [==============================] - 411s 1s/step - loss: 0.1002 - accuracy: 0.9936 - top5_acc: 0.9999 - macro_f1score: 0.3511 - val_loss: 1.8035 - val_accuracy: 0.6628 - val_top5_acc: 0.9069 - val_macro_f1score: 0.2191
# Learning rate:  1e-05
#
# Epoch 00067: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 67/70
# 389/389 [==============================] - ETA: 0s - loss: 0.1029 - accuracy: 0.9924 - top5_acc: 1.0000 - macro_f1score: 0.3471
# Epoch 00067: val_loss did not improve from 1.59010
#
# Epoch 00067: val_accuracy did not improve from 0.66536
# 389/389 [==============================] - 411s 1s/step - loss: 0.1029 - accuracy: 0.9924 - top5_acc: 1.0000 - macro_f1score: 0.3471 - val_loss: 1.7850 - val_accuracy: 0.6602 - val_top5_acc: 0.9056 - val_macro_f1score: 0.2136
# Learning rate:  1e-05
#
# Epoch 00068: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 68/70
# 389/389 [==============================] - ETA: 0s - loss: 0.0985 - accuracy: 0.9933 - top5_acc: 1.0000 - macro_f1score: 0.3474
# Epoch 00068: val_loss did not improve from 1.59010
#
# Epoch 00068: val_accuracy did not improve from 0.66536
# 389/389 [==============================] - 412s 1s/step - loss: 0.0985 - accuracy: 0.9933 - top5_acc: 1.0000 - macro_f1score: 0.3474 - val_loss: 1.7989 - val_accuracy: 0.6595 - val_top5_acc: 0.9023 - val_macro_f1score: 0.2198
# Learning rate:  1e-05
#
# Epoch 00069: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 69/70
# 389/389 [==============================] - ETA: 0s - loss: 0.1006 - accuracy: 0.9935 - top5_acc: 0.9999 - macro_f1score: 0.3476
# Epoch 00069: val_loss did not improve from 1.59010
#
# Epoch 00069: val_accuracy improved from 0.66536 to 0.66732, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/Xception/069.h5
# 389/389 [==============================] - 413s 1s/step - loss: 0.1006 - accuracy: 0.9935 - top5_acc: 0.9999 - macro_f1score: 0.3476 - val_loss: 1.7974 - val_accuracy: 0.6673 - val_top5_acc: 0.8997 - val_macro_f1score: 0.2137
# Learning rate:  1e-05
#
# Epoch 00070: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 70/70
# 389/389 [==============================] - ETA: 0s - loss: 0.0997 - accuracy: 0.9939 - top5_acc: 1.0000 - macro_f1score: 0.3485
# Epoch 00070: val_loss did not improve from 1.59010
#
# Epoch 00070: val_accuracy did not improve from 0.66732
# 389/389 [==============================] - 414s 1s/step - loss: 0.0997 - accuracy: 0.9939 - top5_acc: 1.0000 - macro_f1score: 0.3485 - val_loss: 1.7768 - val_accuracy: 0.6660 - val_top5_acc: 0.9049 - val_macro_f1score: 0.2208

# %%
# 1. epoch=maximum
loss , acc, top5_acc, mf1 = model.evaluate(test_generator,steps=int(len(x_test)/batch_sizes))
print('[Test Loss: %.4f /  Test Top-1 Accuracy: %.4f / Test Top-5 Accuracy: %.4f / Test Macro f1: %.4f]\n' % (loss,acc,top5_acc,mf1))
# Out:
# 49/49 [==============================] - 1111s 23s/step - loss: 1.7979 - accuracy: 0.6620 - top5_acc: 0.9050 - macro_f1score: 0.2125
# [Test Loss: 1.7979 /  Test Top-1 Accuracy: 0.6620 / Test Top-5 Accuracy: 0.9050 / Test Macro f1: 0.2125]

# %%
loss=history.history['loss']
val_loss=history.history['val_loss']
acc=history.history['accuracy']
val_acc=history.history['val_accuracy']
top5_acc=history.history['top5_acc']
val_top5_acc=history.history['val_top5_acc']
f1=history.history['macro_f1score']
val_f1=history.history['val_macro_f1score']
epochs=range(1,len(acc)+1)

data = np.array([epochs,loss,val_loss,acc,val_acc,top5_acc,val_top5_acc,f1,val_f1]).T

# %% [markdown]
# ### 2) Xception Evaluate

# %%
# data save
# epochs, loss, val_loss, acc, val_acc, top5_acc, val_top5_acc, f1, val_f1

np.savetxt(os.path.join(dir,'train_valid_output',number,model.name+'.txt'),data)

# %%
# data import
data = np.loadtxt(os.path.join(dir,'train_valid_output',number,'Xception.txt'))

# %%
epochs=data[:,0]
loss=data[:,1]
val_loss=data[:,2]
acc=data[:,3]
val_acc=data[:,4]
top5_acc=data[:,5]
val_top5_acc=data[:,6]

# %%
plt.plot(epochs[1:],acc[1:],'b',label='Training 1-Acc')
plt.plot(epochs[1:],val_acc[1:],'r',label='Validation 1-Acc')
plt.title('Training and Validation Top-1 Accuracy')
plt.legend()
plt.figure()

plt.plot(epochs[1:],top5_acc[1:],'b',label='Training 5-Acc')
plt.plot(epochs[1:],val_top5_acc[1:],'r',label='Validation 5-Acc')
plt.title('Training and Validation Top-5 Accuracy')
plt.legend()
plt.figure()

plt.plot(epochs[10:],loss[10:],'b',label='Training Loss')
plt.plot(epochs[10:],val_loss[10:],'r',label='Validation Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()

# %%
# 이 아래는 내가 인위적으로 살펴보고 싶은 epoch에 대해서 결과값 출력 / Xception

# %%
# 참고 : https://github.com/OverLordGoldDragon/keras-adamw

import sys
sys.path.append('/content/drive/My Drive/Colab Notebooks/Paper')
import utils
import optimizers_v2
from utils import get_weight_decays, fill_dict_in_order
from utils import reset_seeds, K_eval
from optimizers_v2 import AdamW, NadamW, SGDW

# %%
# top-5 accuracy 출력
import functools
top5_acc = functools.partial(ks.metrics.top_k_categorical_accuracy, k=5)
top5_acc.__name__ = 'top5_acc'

# %%
model=load_model(os.path.join(dir,'model_output',number,'Xception','069.h5'),custom_objects={"macro_f1score": macro_f1score,"top5_acc":top5_acc, "AdamW":AdamW})

# %%
# 2. epoch=?
loss , acc, top5_acc, mf1 = model.evaluate(test_generator,steps=int(len(x_test)/batch_sizes))
print('[Test Loss: %.4f /  Test Top-1 Accuracy: %.4f / Test Top-5 Accuracy: %.4f / Test Macro f1: %.4f]\n' % (loss,acc,top5_acc,mf1))
# Out:
# 49/49 [==============================] - 221s 5s/step - loss: 1.7981 - accuracy: 0.6556 - top5_acc: 0.9024 - macro_f1score: 0.2141
# [Test Loss: 1.7981 /  Test Top-1 Accuracy: 0.6556 / Test Top-5 Accuracy: 0.9024 / Test Macro f1: 0.2141]
