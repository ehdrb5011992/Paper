# %%
# 참고 : https://sike6054.github.io/blog/paper/third-post/

# %% [markdown]
# # [Inception V2 & V3]

# %% [markdown]
# *KU LeeDongGyu*

# %% [markdown]
# ## Contents
# ---

# %% [markdown]
# 1. Data Preprocessing
# ```
# 1) Data Import
# 2) Data Augmentation
# ```
# 2. Support Functions & Almost Original Inception-V2,V3 (Especially V3)
# ```
# 1) Support Functions
# 2) Almost Original Inception-V2,V3 (Especially V3)
# 3) Inception-V3 Evaluate
# ```

# %% [markdown]
# ### Install Packages

# %% [markdown]
# ### Module

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/My Drive/Colab Notebooks/Paper
# Out:
# /content/drive/My Drive/Colab Notebooks/Paper

# %%
from f1score import macro_f1score,weighted_f1score
from smoothed_categorical_crossentropy import smoothed_categorical_crossentropy

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import cv2
import tensorflow as tf
from tensorflow import keras as ks
from tensorflow.keras import backend as K 
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, Input, Concatenate, ZeroPadding2D ,GlobalMaxPooling2D, Reshape , Lambda , Add, Multiply
from tensorflow.keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D, Activation, BatchNormalization, AveragePooling2D , ZeroPadding2D, SeparableConv2D , LeakyReLU
from tensorflow.keras.layers import add, concatenate, multiply
from tensorflow.keras.optimizers import Adam, RMSprop , SGD
from tensorflow.keras.callbacks import EarlyStopping , LearningRateScheduler, ModelCheckpoint, CSVLogger, Callback, ReduceLROnPlateau
from tensorflow.keras.regularizers import l1,l2,l1_l2
from tensorflow.keras.models import Model , load_model , Sequential
from tensorflow.keras.utils import plot_model , to_categorical, get_file
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
os.getcwd()
# Out:
# '/content/drive/My Drive/Colab Notebooks/Paper'

# %%
print(tf.__version__)
print(ks.__version__)
# Out:
# 2.3.0
# 2.4.0

# %%
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 1884530205686044451
# , name: "/device:XLA_CPU:0"
# device_type: "XLA_CPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 3759831202535970911
# physical_device_desc: "device: XLA_CPU device"
# , name: "/device:XLA_GPU:0"
# device_type: "XLA_GPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 12128908442170680164
# physical_device_desc: "device: XLA_GPU device"
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 15473775744
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 2598242371522328322
# physical_device_desc: "device: 0, name: Tesla V100-SXM2-16GB, pci bus id: 0000:00:04.0, compute capability: 7.0"
# ]

# %%
# !cat /proc/cpuinfo
# Out:
# processor	: 0
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 85
# model name	: Intel(R) Xeon(R) CPU @ 2.00GHz
# stepping	: 3
# microcode	: 0x1
# cpu MHz		: 2000.172
# cache size	: 39424 KB
# physical id	: 0
# siblings	: 4
# core id		: 0
# cpu cores	: 2
# apicid		: 0
# initial apicid	: 0
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm mpx avx512f avx512dq rdseed adx smap clflushopt clwb avx512cd avx512bw avx512vl xsaveopt xsavec xgetbv1 xsaves arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs taa
# bogomips	: 4000.34
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 46 bits physical, 48 bits virtual
# power management:
#
# processor	: 1
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 85
# model name	: Intel(R) Xeon(R) CPU @ 2.00GHz
# stepping	: 3
# microcode	: 0x1
# cpu MHz		: 2000.172
# cache size	: 39424 KB
# physical id	: 0
# siblings	: 4
# core id		: 1
# cpu cores	: 2
# apicid		: 2
# initial apicid	: 2
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm mpx avx512f avx512dq rdseed adx smap clflushopt clwb avx512cd avx512bw avx512vl xsaveopt xsavec xgetbv1 xsaves arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs taa
# bogomips	: 4000.34
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 46 bits physical, 48 bits virtual
# power management:
#
# processor	: 2
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 85
# model name	: Intel(R) Xeon(R) CPU @ 2.00GHz
# stepping	: 3
# microcode	: 0x1
# cpu MHz		: 2000.172
# cache size	: 39424 KB
# physical id	: 0
# siblings	: 4
# core id		: 0
# cpu cores	: 2
# apicid		: 1
# initial apicid	: 1
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm mpx avx512f avx512dq rdseed adx smap clflushopt clwb avx512cd avx512bw avx512vl xsaveopt xsavec xgetbv1 xsaves arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs taa
# bogomips	: 4000.34
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 46 bits physical, 48 bits virtual
# power management:
#
# processor	: 3
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 85
# model name	: Intel(R) Xeon(R) CPU @ 2.00GHz
# stepping	: 3
# microcode	: 0x1
# cpu MHz		: 2000.172
# cache size	: 39424 KB
# physical id	: 0
# siblings	: 4
# core id		: 1
# cpu cores	: 2
# apicid		: 3
# initial apicid	: 3
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm mpx avx512f avx512dq rdseed adx smap clflushopt clwb avx512cd avx512bw avx512vl xsaveopt xsavec xgetbv1 xsaves arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs taa
# bogomips	: 4000.34
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 46 bits physical, 48 bits virtual
# power management:

# %% [markdown]
# ## 1. Data Preprocessing
# ---

# %% [markdown]
# ### 1) Data Import

# %%
# 바꿔서 살펴 볼 것들
# CALTECH, CIFAR100, FER, MIT
data_name = 'MIT'
gan_type = 'No_GAN'
number = '1'
size = 299 # sizes after cropping
super_size = 330 # sizes before cropping 
input_sizes = (size,size,3)
batch_sizes = 64
weight_decay = 2e-3
epochs = 70

# %%
# 참고 : https://stackoverflow.com/questions/32419510/how-to-get-reproducible-results-in-keras/52897216#52897216
# setting the seed number for random number generation for reproducibility.

from numpy.random import seed
import random


if number=='1':
    seed_num = 200225
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)
elif number=='2':
    seed_num = 727
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)
elif number=='3':
    seed_num = 115
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)
elif number=='4':
    seed_num = 501
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)
elif number=='5':
    seed_num = 517
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)

# %%
# data import

if data_name=='FER' :
    x_train =  np.zeros(28698)
    x_valid = np.zeros(3589)
    x_test = np.zeros(3588)
    classes = 7 
    tr_center = [0.50793296, 0.50793296, 0.50793296]
elif data_name=='MIT':
    x_train = np.zeros(12466)
    x_valid = np.zeros(1564)
    x_test = np.zeros(1590)
    classes = 67 
    tr_center = [0.47916578, 0.42029615, 0.36046057]
elif data_name=='CALTECH':
    x_train = np.zeros(24510)
    x_valid = np.zeros(2980)
    x_test = np.zeros(3118)
    classes = 257
    tr_center = [0.51397761, 0.49525248, 0.46555727]
elif data_name=='CIFAR100':
    x_train = np.zeros(44923)
    x_valid = np.zeros(5077)
    x_test = np.zeros(10000)
    classes = 100
    tr_center = [0.53442983, 0.51355958, 0.46462564]

# %%
dir = os.path.join(os.getcwd(),data_name,gan_type)

# %% [markdown]
# ### 2) Data Augmentation

# %%
# 참고 : https://jkjung-avt.github.io/keras-image-cropping/

def random_crop(img, random_crop_size):
    # Note: image_data_format is 'channel_last'
    assert img.shape[2] == 3 # img.shape[2] 가 3(rgb)이 아니면 assertion error 발생
    height, width = img.shape[0], img.shape[1]
    dy, dx = random_crop_size
    x = np.random.randint(0, width - dx + 1)
    y = np.random.randint(0, height - dy + 1)
    return img[y:(y+dy), x:(x+dx), :]


def crop_generator(batches, crop_length):
    """Take as input a Keras ImageGen (Iterator) and generate random
    crops from the image batches generated by the original iterator.
    """
    while True:
        batch_x, batch_y = next(batches)
        batch_crops = np.zeros((batch_x.shape[0], crop_length, crop_length, 3))
        for i in range(batch_x.shape[0]):
            batch_crops[i] = random_crop(batch_x[i], (crop_length, crop_length))
        yield (batch_crops, batch_y)

# %%
from tensorflow.keras.preprocessing.image import img_to_array,load_img
import glob

# 데이터 전체에 대해 centering 진행함.

def read_cal_image(img_path): 
    x = img_to_array(load_img(img_path)) # x는 채널별 평균값
    y = x.shape[0] * x.shape[1]# y는 데이터별 픽셀 수 (비중)

    x = 1/255. * x # scaling하고, centering값을 뽑아냄.
    x = np.mean(x, axis=(0,1))
    
    return np.hstack([x,y])

def calculate_centered_mean(dataset_path,x_train=x_train):
    num = len(x_train)
    space = np.empty((num,4))
    i=0

    for p in glob.glob(os.path.join(dataset_path,'*/*.*')) :
        space[i] = read_cal_image(p)
        i += 1

    ratio = space[:,3] / np.sum(space[:,3])

    return np.average(space[:,0:3],axis=0,weights=ratio)


# 아래의 함수를 돌려서 나온 결과값을 중심화 값으로 설정.

# train_mean = calculate_centered_mean(os.path.join(dir,'data/train')).reshape((1,1,3))

# %%
datagen_tr = ImageDataGenerator(
    rescale=1/255.,
    horizontal_flip=True,
    featurewise_center=True,
    featurewise_std_normalization=False,
    rotation_range=10,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=[0.9,1.0],
    fill_mode = 'nearest')
datagen_val = ImageDataGenerator(rescale=1/255.,featurewise_center=True)
datagen_tes = ImageDataGenerator(rescale=1/255.,featurewise_center=True)

# 원래는 이 자리에 fit 매서드를 써야하지만, 그냥 내가 중심화함수를 만들고 적용함. 

# 중심화 설정
datagen_tr.mean = np.array(tr_center, dtype=np.float32).reshape((1,1,3)) # RGB
datagen_val.mean = np.array(tr_center, dtype=np.float32).reshape((1,1,3)) # RGB
datagen_tes.mean = np.array(tr_center, dtype=np.float32).reshape((1,1,3)) # RGB

# %%
# Inception-V2 & V3은 분류기가 2개이므로 imagedatagenerator 사용방법이 다소 다르다.
# model.fit에 다중 input으로 들어갈 함수를 개인이 만들어서 사용해야 하며, 그 함수는 아래와 같다. 
# 매우 간단하다.

#1. train data

def generate_train_for_two(crop_length=size, batch_sizes = batch_sizes, super_size=super_size):

      batches = datagen_tr.flow_from_directory(directory=os.path.join(dir,'data/train'),target_size=(super_size,super_size),batch_size=batch_sizes,class_mode='categorical')

      while True:
          batch_x, batch_y = next(batches)
          batch_crops = np.zeros((batch_x.shape[0], crop_length, crop_length, 3))
          for i in range(batch_x.shape[0]):
              batch_crops[i] = random_crop(batch_x[i], (crop_length, crop_length))
          yield batch_crops, [batch_y,batch_y]

# %%
# 2. valid data

def generate_valid_for_two(size=size, batch_sizes = batch_sizes):

      batches_xy = datagen_val.flow_from_directory(directory=os.path.join(dir,'data/valid'),target_size=(size,size),batch_size=batch_sizes,class_mode='categorical')

      while True:

          batch_xy = batches_xy.next()
          yield  batch_xy[0], [ batch_xy[1],batch_xy[1] ]

# %%
# 3. test data

def generate_test_for_two(size=size, batch_sizes = batch_sizes):

      batches_xy = datagen_tes.flow_from_directory(directory=os.path.join(dir,'data/test'),target_size=(size,size),batch_size=batch_sizes,class_mode='categorical')

      while True:

          batch_xy = batches_xy.next()
          yield  batch_xy[0], [ batch_xy[1],batch_xy[1] ]

# %%
# 위에서 쓰임
# train_batches = datagen_tr.flow_from_directory(directory=os.path.join(dir,'data/train'),target_size=(super_size,super_size),batch_size=batch_sizes,class_mode='categorical') # fer : 28698 / mit : 12466 / caltech : 24509 / cifar : 44923
# train_generator= crop_generator(train_batches, size)

# valid_generator = datagen_val.flow_from_directory(directory=os.path.join(dir,'data/valid'),target_size=(size,size),batch_size=batch_sizes,class_mode='categorical') # fer : 3589 / mit : 1564 / caltech : 2980 / cifar : 5077
# test_generator = datagen_tes.flow_from_directory(directory=os.path.join(dir,'data/test'),target_size=(size,size),batch_size=batch_sizes,class_mode='categorical') # fer : 3588 / mit : 1590 / caltech : 3118 / cifar : 10000

# %% [markdown]
# ## 2. Support Functions & Almost Original Inception-V2,V3 (Especially V3)
# ---

# %% [markdown]
# ### 1) Support Functions

# %%
# def lr_schedule(epoch):
#     init_lr = 1e-4
#     k = 0.04
#     lr = init_lr * np.exp(-k*epoch)
#     print('Learning rate: ', lr)
#     return lr

def lr_schedule(epoch):
    lr = 1e-3
    if epoch < 30:
        lr = lr
    elif epoch < 60 :
        lr = lr * 0.1
    else:
        lr = lr * 0.01
    print('Learning rate: ', lr)
    return lr

# %%
def smoothed_categorical_crossentropy(y_true, y_pred): 
    if smoothing_param > 0:
        smooth_positives = 1.0 - smoothing_param 
        smooth_negatives = smoothing_param / classes 
        y_true = y_true * smooth_positives + smooth_negatives 

    return K.categorical_crossentropy(y_true, y_pred)

# %%
def conv2d_bn(x, filters, kernel_size, weight_decay=weight_decay, padding='same', strides=1, activation='relu'):
    x = Conv2D(filters, (kernel_size[0], kernel_size[1]), padding=padding, strides=strides, kernel_initializer='he_uniform', use_bias=False, kernel_regularizer=l2(weight_decay))(x)    
    x = BatchNormalization()(x)
    
    if activation:
        x = Activation(activation)(x)
    
    return x

# %%
def inception_f3(input_tensor, filter_channels, name=None):
    filter_b1, filter_b2, filter_b3, filter_b4 = filter_channels
    
    branch_1 = conv2d_bn(input_tensor, filter_b1[0], (1, 1))
    branch_1 = conv2d_bn(branch_1, filter_b1[1], (3, 3))
    branch_1 = conv2d_bn(branch_1, filter_b1[2], (3, 3))
    
    branch_2 = conv2d_bn(input_tensor, filter_b2[0], (1, 1))
    branch_2 = conv2d_bn(branch_2, filter_b2[1], (3, 3))
    
    branch_3 = MaxPooling2D((3, 3), strides=1, padding='same')(input_tensor)
    branch_3 = conv2d_bn(branch_3, filter_b3, (1, 1))
    
    branch_4 = conv2d_bn(input_tensor, filter_b4, (1, 1))
    
    filter_concat = Concatenate(name=name)([branch_1, branch_2, branch_3, branch_4]) if not name==None else Concatenate()([branch_1, branch_2, branch_3, branch_4])
    
    return filter_concat

def inception_f6(input_tensor, filter_channels, n=7, name=None):
    filter_b1, filter_b2, filter_b3, filter_b4 = filter_channels
    
    branch_1 = conv2d_bn(input_tensor, filter_b1[0], (1, 1))
    branch_1 = conv2d_bn(branch_1, filter_b1[1], (1, n))
    branch_1 = conv2d_bn(branch_1, filter_b1[2], (n, 1))
    branch_1 = conv2d_bn(branch_1, filter_b1[3], (1, n))
    branch_1 = conv2d_bn(branch_1, filter_b1[4], (n, 1))
    
    branch_2 = conv2d_bn(input_tensor, filter_b2[0], (1, 1))
    branch_2 = conv2d_bn(branch_2, filter_b2[1], (1, n))
    branch_2 = conv2d_bn(branch_2, filter_b2[2], (n, 1))
    
    branch_3 = MaxPooling2D((3, 3), strides=1, padding='same')(input_tensor)
    branch_3 = conv2d_bn(branch_3, filter_b3, (1, 1))
    
    branch_4 = conv2d_bn(input_tensor, filter_b4, (1, 1))
    
    filter_concat = Concatenate(name=name)([branch_1, branch_2, branch_3, branch_4]) if not name==None else Concatenate()([branch_1, branch_2, branch_3, branch_4])
    
    return filter_concat

def inception_f10(input_tensor, filter_channels, name=None):
    filter_b1, filter_b2, filter_b3, filter_b4 = filter_channels
    
    branch_1 = conv2d_bn(input_tensor, filter_b1[0], (1, 1))
    branch_1 = conv2d_bn(branch_1, filter_b1[1], (3, 3))
    branch_1a = conv2d_bn(branch_1, filter_b1[2][0], (1, 3))
    branch_1b = conv2d_bn(branch_1, filter_b1[2][1], (3, 1))
    branch_1 = Concatenate()([branch_1a, branch_1b])
    
    branch_2 = conv2d_bn(input_tensor, filter_b2[0], (1, 1))
    branch_2a = conv2d_bn(branch_2, filter_b2[1][0], (1, 3))
    branch_2b = conv2d_bn(branch_2, filter_b2[1][1], (3, 1))
    branch_2 = Concatenate()([branch_2a, branch_2b])
    
    branch_3 = MaxPooling2D((3, 3), strides=1, padding='same')(input_tensor)
    branch_3 = conv2d_bn(branch_3, filter_b3, (1, 1))
    
    branch_4 = conv2d_bn(input_tensor, filter_b4, (1, 1))
    
    filter_concat = Concatenate(name=name)([branch_1, branch_2, branch_3, branch_4]) if not name==None else Concatenate()([branch_1, branch_2, branch_3, branch_4])
    
    return filter_concat
    
def inception_dim_reduction(input_tensor, filter_channels, name=None):
    filter_b1, filter_b2 = filter_channels
    
    branch_1 = conv2d_bn(input_tensor, filter_b1[0], (1, 1))
    branch_1 = conv2d_bn(branch_1, filter_b1[1], (3, 3))
    branch_1 = conv2d_bn(branch_1, filter_b1[2], (3, 3), strides=2)
    
    branch_2 = conv2d_bn(input_tensor, filter_b2[0], (1, 1))
    branch_2 = conv2d_bn(branch_2, filter_b2[1], (3, 3), strides=2)
    
    branch_3 = MaxPooling2D((3, 3), strides=2, padding='same')(input_tensor)
    
    filter_concat = Concatenate(name=name)([branch_1, branch_2, branch_3]) if not name==None else Concatenate()([branch_1, branch_2, branch_3])
    
    return filter_concat

# %% [markdown]
# ### 2) Almost Original Inception-V2,V3 (Especially V3)

# %%
def Inception_v3(model_input, name, weight_decay= weight_decay):
    x = conv2d_bn(model_input, 32, (3, 3), padding='valid', strides=2) # (299, 299, 3) -> (149, 149, 32)
    x = conv2d_bn(x, 32, (3, 3), padding='valid') # (147, 147, 32) -> (147, 147, 32)
    x = conv2d_bn(x, 64, (3, 3), padding='same') # (147, 147, 32) -> (147, 147, 64)
    
    x = MaxPooling2D((3, 3), strides=2, padding='valid')(x) # (147, 147, 64) -> (73, 73, 64)
    
    x = conv2d_bn(x, 80, (3, 3), padding='valid') # (73, 73, 64) -> (71, 71, 80)
    x = conv2d_bn(x, 192, (3, 3), padding='valid', strides=2) # (71, 71, 80) -> (35, 35, 192)
    x = conv2d_bn(x, 288, (3, 3), padding='same') # (35, 35, 192) -> (35, 35, 288)
    
    x = inception_f3(x, [[64, 96, 96], [48, 64], 64 , 64]) # (35, 35, 288)
    x = inception_f3(x, [[64, 96, 96], [48, 64], 64 , 64]) # (35, 35, 288)
    x = inception_f3(x, [[64, 96, 96], [48, 64], 64 , 64], name='block_inception_f3') # (35, 35, 288)
    
    x = inception_dim_reduction(x, [[64, 96, 96], [256, 384]], name='block_reduction_1') # (35, 35, 288) -> (17, 17, 768)
    
    x = inception_f6(x, [[128, 128, 128, 128, 192], [128, 128, 192], 192, 192]) # (17, 17, 768)
    x = inception_f6(x, [[160, 160, 160, 160, 192], [160, 160, 192], 192, 192]) # (17, 17, 768)
    x = inception_f6(x, [[160, 160, 160, 160, 192], [160, 160, 192], 192, 192]) # (17, 17, 768)
    x = inception_f6(x, [[192, 192, 192, 192, 192], [192, 192, 192], 192, 192]) # (17, 17, 768)
    x_a = inception_f6(x, [[192, 192, 192, 192, 192], [192, 192, 192], 192, 192], name='block_inception_f6') # (17, 17, 768)
    
    x = inception_dim_reduction(x_a, [[128, 192, 192], [192, 320]], name='block_reduction_2') # (17, 17, 768) -> (8, 8, 1280)
    
    x = inception_f10(x, [[448, 384, [384, 384]], [384, [384, 384]], 192, 320]) # (8, 8, 1280) -> (8, 8, 2048)
    x = inception_f10(x, [[448, 384, [384, 384]], [384, [384, 384]], 192, 320], name='block_inception_f10') # (8, 8, 2048)
    
    x = GlobalAveragePooling2D()(x)
    x = Dropout(0.2)(x)
    
    x = Dense(classes, use_bias=False, kernel_regularizer=l2(weight_decay), activation=None)(x)
    
    model_output = Dense(classes, activation='softmax', name='main_classifier')(x) # 'softmax'
    
    # Auxiliary Classifier
    auxiliary = AveragePooling2D((5, 5), strides=3, padding='valid')(x_a) # (17, 17, 768) -> (5, 5, 768)
    auxiliary = conv2d_bn(auxiliary, 128, (1, 1)) # (5, 5, 768) -> (5, 5, 128)
    
    auxiliary = conv2d_bn(auxiliary, 1024, K.int_shape(auxiliary)[1:3], padding='valid') # (5, 5, 768) -> (1, 1, 1024)
    auxiliary = Flatten()(auxiliary) # (1, 1, 1024)
    auxiliary_output = Dense(classes, use_bias=False, kernel_regularizer=l2(weight_decay), activation='softmax', name='auxiliary_classifier')(auxiliary)
    
    model = Model(model_input, [model_output, auxiliary_output],name=name)
    
    return model

# %%
smoothing_param = 0.1
model_input = Input(shape=input_sizes)
model = Inception_v3(model_input, weight_decay = weight_decay, name = "Inception_v3")

# %%
model.summary()
# Out:
# Model: "Inception_v3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 299, 299, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 149, 149, 32) 864         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 149, 149, 32) 128         conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 149, 149, 32) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 147, 147, 32) 9216        activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 147, 147, 32) 128         conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 147, 147, 32) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 147, 147, 64) 18432       activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 147, 147, 64) 256         conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 147, 147, 64) 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 73, 73, 64)   0           activation_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 71, 71, 80)   46080       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 71, 71, 80)   320         conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 71, 71, 80)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 35, 35, 192)  138240      activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 35, 35, 192)  768         conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 35, 35, 192)  0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 35, 35, 288)  497664      activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 35, 35, 288)  1152        conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 35, 35, 288)  0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 35, 35, 64)   18432       activation_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 35, 35, 64)   256         conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 35, 35, 64)   0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 35, 35, 96)   55296       activation_6[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 35, 35, 48)   13824       activation_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 35, 35, 96)   384         conv2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 35, 35, 48)   192         conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 35, 35, 96)   0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 35, 35, 48)   0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 35, 35, 288)  0           activation_5[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 35, 35, 96)   82944       activation_7[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 35, 35, 64)   27648       activation_9[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 35, 35, 64)   18432       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 35, 35, 64)   18432       activation_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 35, 35, 96)   384         conv2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 35, 35, 64)   256         conv2d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 35, 35, 64)   256         conv2d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 35, 35, 64)   256         conv2d_12[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 35, 35, 96)   0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 35, 35, 64)   0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 35, 35, 64)   0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 35, 35, 64)   0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 35, 35, 288)  0           activation_8[0][0]
#                                                                  activation_10[0][0]
#                                                                  activation_11[0][0]
#                                                                  activation_12[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 35, 35, 64)   18432       concatenate[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 35, 35, 64)   256         conv2d_13[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 35, 35, 64)   0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 35, 35, 96)   55296       activation_13[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 35, 35, 48)   13824       concatenate[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 35, 35, 96)   384         conv2d_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 35, 35, 48)   192         conv2d_16[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 35, 35, 96)   0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 35, 35, 48)   0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 35, 35, 288)  0           concatenate[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 35, 35, 96)   82944       activation_14[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 35, 35, 64)   27648       activation_16[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 35, 35, 64)   18432       max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 35, 35, 64)   18432       concatenate[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 35, 35, 96)   384         conv2d_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 35, 35, 64)   256         conv2d_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 35, 35, 64)   256         conv2d_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 35, 35, 64)   256         conv2d_19[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 35, 35, 96)   0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 35, 35, 64)   0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 35, 35, 64)   0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 35, 35, 64)   0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 35, 35, 288)  0           activation_15[0][0]
#                                                                  activation_17[0][0]
#                                                                  activation_18[0][0]
#                                                                  activation_19[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 35, 35, 64)   18432       concatenate_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 35, 35, 64)   256         conv2d_20[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 35, 35, 64)   0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 35, 35, 96)   55296       activation_20[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 35, 35, 48)   13824       concatenate_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 35, 35, 96)   384         conv2d_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 35, 35, 48)   192         conv2d_23[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 35, 35, 96)   0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 35, 35, 48)   0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 35, 35, 288)  0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 35, 35, 96)   82944       activation_21[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 35, 35, 64)   27648       activation_23[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 35, 35, 64)   18432       max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 35, 35, 64)   18432       concatenate_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 35, 35, 96)   384         conv2d_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 35, 35, 64)   256         conv2d_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 35, 35, 64)   256         conv2d_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 35, 35, 64)   256         conv2d_26[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 35, 35, 96)   0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 35, 35, 64)   0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 35, 35, 64)   0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 35, 35, 64)   0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# block_inception_f3 (Concatenate (None, 35, 35, 288)  0           activation_22[0][0]
#                                                                  activation_24[0][0]
#                                                                  activation_25[0][0]
#                                                                  activation_26[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 35, 35, 64)   18432       block_inception_f3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 35, 35, 64)   256         conv2d_27[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 35, 35, 64)   0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 35, 35, 96)   55296       activation_27[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 35, 35, 256)  73728       block_inception_f3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 35, 35, 96)   384         conv2d_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 35, 35, 256)  1024        conv2d_30[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 35, 35, 96)   0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 35, 35, 256)  0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 18, 18, 96)   82944       activation_28[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 18, 18, 384)  884736      activation_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 18, 18, 96)   384         conv2d_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 18, 18, 384)  1536        conv2d_31[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 18, 18, 96)   0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 18, 18, 384)  0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 18, 18, 288)  0           block_inception_f3[0][0]
# __________________________________________________________________________________________________
# block_reduction_1 (Concatenate) (None, 18, 18, 768)  0           activation_29[0][0]
#                                                                  activation_31[0][0]
#                                                                  max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 18, 18, 128)  98304       block_reduction_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 18, 18, 128)  512         conv2d_32[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 18, 18, 128)  0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 18, 18, 128)  114688      activation_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 18, 18, 128)  512         conv2d_33[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 18, 18, 128)  0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 18, 18, 128)  114688      activation_33[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 18, 18, 128)  98304       block_reduction_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 18, 18, 128)  512         conv2d_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 18, 18, 128)  512         conv2d_37[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 18, 18, 128)  0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 18, 18, 128)  0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 18, 18, 128)  114688      activation_34[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 18, 18, 128)  114688      activation_37[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 18, 18, 128)  512         conv2d_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 18, 18, 128)  512         conv2d_38[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 18, 18, 128)  0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 18, 18, 128)  0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 18, 18, 768)  0           block_reduction_1[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 18, 18, 192)  172032      activation_35[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 18, 18, 192)  172032      activation_38[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 18, 18, 192)  147456      max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 18, 18, 192)  147456      block_reduction_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 18, 18, 192)  768         conv2d_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 18, 18, 192)  768         conv2d_39[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 18, 18, 192)  768         conv2d_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 18, 18, 192)  768         conv2d_41[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 18, 18, 192)  0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 18, 18, 192)  0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 18, 18, 192)  0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 18, 18, 192)  0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 18, 18, 768)  0           activation_36[0][0]
#                                                                  activation_39[0][0]
#                                                                  activation_40[0][0]
#                                                                  activation_41[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 18, 18, 160)  122880      concatenate_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 18, 18, 160)  640         conv2d_42[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 18, 18, 160)  0           batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 18, 18, 160)  179200      activation_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 18, 18, 160)  640         conv2d_43[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 18, 18, 160)  0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 18, 18, 160)  179200      activation_43[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 18, 18, 160)  122880      concatenate_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 18, 18, 160)  640         conv2d_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 18, 18, 160)  640         conv2d_47[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 18, 18, 160)  0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 18, 18, 160)  0           batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 18, 18, 160)  179200      activation_44[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 18, 18, 160)  179200      activation_47[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 18, 18, 160)  640         conv2d_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 18, 18, 160)  640         conv2d_48[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 18, 18, 160)  0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 18, 18, 160)  0           batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)  (None, 18, 18, 768)  0           concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 18, 18, 192)  215040      activation_45[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 18, 18, 192)  215040      activation_48[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 18, 18, 192)  147456      max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 18, 18, 192)  147456      concatenate_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 18, 18, 192)  768         conv2d_46[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 18, 18, 192)  768         conv2d_49[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 18, 18, 192)  768         conv2d_50[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 18, 18, 192)  768         conv2d_51[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 18, 18, 192)  0           batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 18, 18, 192)  0           batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, 18, 18, 192)  0           batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# activation_51 (Activation)      (None, 18, 18, 192)  0           batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 18, 18, 768)  0           activation_46[0][0]
#                                                                  activation_49[0][0]
#                                                                  activation_50[0][0]
#                                                                  activation_51[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 18, 18, 160)  122880      concatenate_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 18, 18, 160)  640         conv2d_52[0][0]
# __________________________________________________________________________________________________
# activation_52 (Activation)      (None, 18, 18, 160)  0           batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 18, 18, 160)  179200      activation_52[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, 18, 18, 160)  640         conv2d_53[0][0]
# __________________________________________________________________________________________________
# activation_53 (Activation)      (None, 18, 18, 160)  0           batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 18, 18, 160)  179200      activation_53[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 18, 18, 160)  122880      concatenate_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, 18, 18, 160)  640         conv2d_54[0][0]
# __________________________________________________________________________________________________
# batch_normalization_57 (BatchNo (None, 18, 18, 160)  640         conv2d_57[0][0]
# __________________________________________________________________________________________________
# activation_54 (Activation)      (None, 18, 18, 160)  0           batch_normalization_54[0][0]
# __________________________________________________________________________________________________
# activation_57 (Activation)      (None, 18, 18, 160)  0           batch_normalization_57[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 18, 18, 160)  179200      activation_54[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, 18, 18, 160)  179200      activation_57[0][0]
# __________________________________________________________________________________________________
# batch_normalization_55 (BatchNo (None, 18, 18, 160)  640         conv2d_55[0][0]
# __________________________________________________________________________________________________
# batch_normalization_58 (BatchNo (None, 18, 18, 160)  640         conv2d_58[0][0]
# __________________________________________________________________________________________________
# activation_55 (Activation)      (None, 18, 18, 160)  0           batch_normalization_55[0][0]
# __________________________________________________________________________________________________
# activation_58 (Activation)      (None, 18, 18, 160)  0           batch_normalization_58[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_7 (MaxPooling2D)  (None, 18, 18, 768)  0           concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 18, 18, 192)  215040      activation_55[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, 18, 18, 192)  215040      activation_58[0][0]
# __________________________________________________________________________________________________
# conv2d_60 (Conv2D)              (None, 18, 18, 192)  147456      max_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_61 (Conv2D)              (None, 18, 18, 192)  147456      concatenate_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_56 (BatchNo (None, 18, 18, 192)  768         conv2d_56[0][0]
# __________________________________________________________________________________________________
# batch_normalization_59 (BatchNo (None, 18, 18, 192)  768         conv2d_59[0][0]
# __________________________________________________________________________________________________
# batch_normalization_60 (BatchNo (None, 18, 18, 192)  768         conv2d_60[0][0]
# __________________________________________________________________________________________________
# batch_normalization_61 (BatchNo (None, 18, 18, 192)  768         conv2d_61[0][0]
# __________________________________________________________________________________________________
# activation_56 (Activation)      (None, 18, 18, 192)  0           batch_normalization_56[0][0]
# __________________________________________________________________________________________________
# activation_59 (Activation)      (None, 18, 18, 192)  0           batch_normalization_59[0][0]
# __________________________________________________________________________________________________
# activation_60 (Activation)      (None, 18, 18, 192)  0           batch_normalization_60[0][0]
# __________________________________________________________________________________________________
# activation_61 (Activation)      (None, 18, 18, 192)  0           batch_normalization_61[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 18, 18, 768)  0           activation_56[0][0]
#                                                                  activation_59[0][0]
#                                                                  activation_60[0][0]
#                                                                  activation_61[0][0]
# __________________________________________________________________________________________________
# conv2d_62 (Conv2D)              (None, 18, 18, 192)  147456      concatenate_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_62 (BatchNo (None, 18, 18, 192)  768         conv2d_62[0][0]
# __________________________________________________________________________________________________
# activation_62 (Activation)      (None, 18, 18, 192)  0           batch_normalization_62[0][0]
# __________________________________________________________________________________________________
# conv2d_63 (Conv2D)              (None, 18, 18, 192)  258048      activation_62[0][0]
# __________________________________________________________________________________________________
# batch_normalization_63 (BatchNo (None, 18, 18, 192)  768         conv2d_63[0][0]
# __________________________________________________________________________________________________
# activation_63 (Activation)      (None, 18, 18, 192)  0           batch_normalization_63[0][0]
# __________________________________________________________________________________________________
# conv2d_64 (Conv2D)              (None, 18, 18, 192)  258048      activation_63[0][0]
# __________________________________________________________________________________________________
# conv2d_67 (Conv2D)              (None, 18, 18, 192)  147456      concatenate_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_64 (BatchNo (None, 18, 18, 192)  768         conv2d_64[0][0]
# __________________________________________________________________________________________________
# batch_normalization_67 (BatchNo (None, 18, 18, 192)  768         conv2d_67[0][0]
# __________________________________________________________________________________________________
# activation_64 (Activation)      (None, 18, 18, 192)  0           batch_normalization_64[0][0]
# __________________________________________________________________________________________________
# activation_67 (Activation)      (None, 18, 18, 192)  0           batch_normalization_67[0][0]
# __________________________________________________________________________________________________
# conv2d_65 (Conv2D)              (None, 18, 18, 192)  258048      activation_64[0][0]
# __________________________________________________________________________________________________
# conv2d_68 (Conv2D)              (None, 18, 18, 192)  258048      activation_67[0][0]
# __________________________________________________________________________________________________
# batch_normalization_65 (BatchNo (None, 18, 18, 192)  768         conv2d_65[0][0]
# __________________________________________________________________________________________________
# batch_normalization_68 (BatchNo (None, 18, 18, 192)  768         conv2d_68[0][0]
# __________________________________________________________________________________________________
# activation_65 (Activation)      (None, 18, 18, 192)  0           batch_normalization_65[0][0]
# __________________________________________________________________________________________________
# activation_68 (Activation)      (None, 18, 18, 192)  0           batch_normalization_68[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_8 (MaxPooling2D)  (None, 18, 18, 768)  0           concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv2d_66 (Conv2D)              (None, 18, 18, 192)  258048      activation_65[0][0]
# __________________________________________________________________________________________________
# conv2d_69 (Conv2D)              (None, 18, 18, 192)  258048      activation_68[0][0]
# __________________________________________________________________________________________________
# conv2d_70 (Conv2D)              (None, 18, 18, 192)  147456      max_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_71 (Conv2D)              (None, 18, 18, 192)  147456      concatenate_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_66 (BatchNo (None, 18, 18, 192)  768         conv2d_66[0][0]
# __________________________________________________________________________________________________
# batch_normalization_69 (BatchNo (None, 18, 18, 192)  768         conv2d_69[0][0]
# __________________________________________________________________________________________________
# batch_normalization_70 (BatchNo (None, 18, 18, 192)  768         conv2d_70[0][0]
# __________________________________________________________________________________________________
# batch_normalization_71 (BatchNo (None, 18, 18, 192)  768         conv2d_71[0][0]
# __________________________________________________________________________________________________
# activation_66 (Activation)      (None, 18, 18, 192)  0           batch_normalization_66[0][0]
# __________________________________________________________________________________________________
# activation_69 (Activation)      (None, 18, 18, 192)  0           batch_normalization_69[0][0]
# ...
# __________________________________________________________________________________________________
# batch_normalization_87 (BatchNo (None, 9, 9, 448)    1792        conv2d_87[0][0]
# __________________________________________________________________________________________________
# activation_87 (Activation)      (None, 9, 9, 448)    0           batch_normalization_87[0][0]
# __________________________________________________________________________________________________
# conv2d_88 (Conv2D)              (None, 9, 9, 384)    1548288     activation_87[0][0]
# __________________________________________________________________________________________________
# conv2d_91 (Conv2D)              (None, 9, 9, 384)    491520      block_reduction_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_88 (BatchNo (None, 9, 9, 384)    1536        conv2d_88[0][0]
# __________________________________________________________________________________________________
# batch_normalization_91 (BatchNo (None, 9, 9, 384)    1536        conv2d_91[0][0]
# __________________________________________________________________________________________________
# activation_88 (Activation)      (None, 9, 9, 384)    0           batch_normalization_88[0][0]
# __________________________________________________________________________________________________
# activation_91 (Activation)      (None, 9, 9, 384)    0           batch_normalization_91[0][0]
# __________________________________________________________________________________________________
# conv2d_89 (Conv2D)              (None, 9, 9, 384)    442368      activation_88[0][0]
# __________________________________________________________________________________________________
# conv2d_90 (Conv2D)              (None, 9, 9, 384)    442368      activation_88[0][0]
# __________________________________________________________________________________________________
# conv2d_92 (Conv2D)              (None, 9, 9, 384)    442368      activation_91[0][0]
# __________________________________________________________________________________________________
# conv2d_93 (Conv2D)              (None, 9, 9, 384)    442368      activation_91[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_11 (MaxPooling2D) (None, 9, 9, 1280)   0           block_reduction_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_89 (BatchNo (None, 9, 9, 384)    1536        conv2d_89[0][0]
# __________________________________________________________________________________________________
# batch_normalization_90 (BatchNo (None, 9, 9, 384)    1536        conv2d_90[0][0]
# __________________________________________________________________________________________________
# batch_normalization_92 (BatchNo (None, 9, 9, 384)    1536        conv2d_92[0][0]
# __________________________________________________________________________________________________
# batch_normalization_93 (BatchNo (None, 9, 9, 384)    1536        conv2d_93[0][0]
# __________________________________________________________________________________________________
# conv2d_94 (Conv2D)              (None, 9, 9, 192)    245760      max_pooling2d_11[0][0]
# __________________________________________________________________________________________________
# conv2d_95 (Conv2D)              (None, 9, 9, 320)    409600      block_reduction_2[0][0]
# __________________________________________________________________________________________________
# activation_89 (Activation)      (None, 9, 9, 384)    0           batch_normalization_89[0][0]
# __________________________________________________________________________________________________
# activation_90 (Activation)      (None, 9, 9, 384)    0           batch_normalization_90[0][0]
# __________________________________________________________________________________________________
# activation_92 (Activation)      (None, 9, 9, 384)    0           batch_normalization_92[0][0]
# __________________________________________________________________________________________________
# activation_93 (Activation)      (None, 9, 9, 384)    0           batch_normalization_93[0][0]
# __________________________________________________________________________________________________
# batch_normalization_94 (BatchNo (None, 9, 9, 192)    768         conv2d_94[0][0]
# __________________________________________________________________________________________________
# batch_normalization_95 (BatchNo (None, 9, 9, 320)    1280        conv2d_95[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 9, 9, 768)    0           activation_89[0][0]
#                                                                  activation_90[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 9, 9, 768)    0           activation_92[0][0]
#                                                                  activation_93[0][0]
# __________________________________________________________________________________________________
# activation_94 (Activation)      (None, 9, 9, 192)    0           batch_normalization_94[0][0]
# __________________________________________________________________________________________________
# activation_95 (Activation)      (None, 9, 9, 320)    0           batch_normalization_95[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 9, 9, 2048)   0           concatenate_6[0][0]
#                                                                  concatenate_7[0][0]
#                                                                  activation_94[0][0]
#                                                                  activation_95[0][0]
# __________________________________________________________________________________________________
# conv2d_96 (Conv2D)              (None, 9, 9, 448)    917504      concatenate_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_96 (BatchNo (None, 9, 9, 448)    1792        conv2d_96[0][0]
# __________________________________________________________________________________________________
# activation_96 (Activation)      (None, 9, 9, 448)    0           batch_normalization_96[0][0]
# __________________________________________________________________________________________________
# conv2d_97 (Conv2D)              (None, 9, 9, 384)    1548288     activation_96[0][0]
# __________________________________________________________________________________________________
# conv2d_100 (Conv2D)             (None, 9, 9, 384)    786432      concatenate_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_97 (BatchNo (None, 9, 9, 384)    1536        conv2d_97[0][0]
# __________________________________________________________________________________________________
# batch_normalization_100 (BatchN (None, 9, 9, 384)    1536        conv2d_100[0][0]
# __________________________________________________________________________________________________
# activation_97 (Activation)      (None, 9, 9, 384)    0           batch_normalization_97[0][0]
# __________________________________________________________________________________________________
# activation_100 (Activation)     (None, 9, 9, 384)    0           batch_normalization_100[0][0]
# __________________________________________________________________________________________________
# conv2d_98 (Conv2D)              (None, 9, 9, 384)    442368      activation_97[0][0]
# __________________________________________________________________________________________________
# conv2d_99 (Conv2D)              (None, 9, 9, 384)    442368      activation_97[0][0]
# __________________________________________________________________________________________________
# conv2d_101 (Conv2D)             (None, 9, 9, 384)    442368      activation_100[0][0]
# __________________________________________________________________________________________________
# conv2d_102 (Conv2D)             (None, 9, 9, 384)    442368      activation_100[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_12 (MaxPooling2D) (None, 9, 9, 2048)   0           concatenate_8[0][0]
# __________________________________________________________________________________________________
# average_pooling2d (AveragePooli (None, 5, 5, 768)    0           block_inception_f6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_98 (BatchNo (None, 9, 9, 384)    1536        conv2d_98[0][0]
# __________________________________________________________________________________________________
# batch_normalization_99 (BatchNo (None, 9, 9, 384)    1536        conv2d_99[0][0]
# __________________________________________________________________________________________________
# batch_normalization_101 (BatchN (None, 9, 9, 384)    1536        conv2d_101[0][0]
# __________________________________________________________________________________________________
# batch_normalization_102 (BatchN (None, 9, 9, 384)    1536        conv2d_102[0][0]
# __________________________________________________________________________________________________
# conv2d_103 (Conv2D)             (None, 9, 9, 192)    393216      max_pooling2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_104 (Conv2D)             (None, 9, 9, 320)    655360      concatenate_8[0][0]
# __________________________________________________________________________________________________
# conv2d_105 (Conv2D)             (None, 5, 5, 128)    98304       average_pooling2d[0][0]
# __________________________________________________________________________________________________
# activation_98 (Activation)      (None, 9, 9, 384)    0           batch_normalization_98[0][0]
# __________________________________________________________________________________________________
# activation_99 (Activation)      (None, 9, 9, 384)    0           batch_normalization_99[0][0]
# __________________________________________________________________________________________________
# activation_101 (Activation)     (None, 9, 9, 384)    0           batch_normalization_101[0][0]
# __________________________________________________________________________________________________
# activation_102 (Activation)     (None, 9, 9, 384)    0           batch_normalization_102[0][0]
# __________________________________________________________________________________________________
# batch_normalization_103 (BatchN (None, 9, 9, 192)    768         conv2d_103[0][0]
# __________________________________________________________________________________________________
# batch_normalization_104 (BatchN (None, 9, 9, 320)    1280        conv2d_104[0][0]
# __________________________________________________________________________________________________
# batch_normalization_105 (BatchN (None, 5, 5, 128)    512         conv2d_105[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 9, 9, 768)    0           activation_98[0][0]
#                                                                  activation_99[0][0]
# __________________________________________________________________________________________________
# concatenate_10 (Concatenate)    (None, 9, 9, 768)    0           activation_101[0][0]
#                                                                  activation_102[0][0]
# __________________________________________________________________________________________________
# activation_103 (Activation)     (None, 9, 9, 192)    0           batch_normalization_103[0][0]
# __________________________________________________________________________________________________
# activation_104 (Activation)     (None, 9, 9, 320)    0           batch_normalization_104[0][0]
# __________________________________________________________________________________________________
# activation_105 (Activation)     (None, 5, 5, 128)    0           batch_normalization_105[0][0]
# __________________________________________________________________________________________________
# block_inception_f10 (Concatenat (None, 9, 9, 2048)   0           concatenate_9[0][0]
#                                                                  concatenate_10[0][0]
#                                                                  activation_103[0][0]
#                                                                  activation_104[0][0]
# __________________________________________________________________________________________________
# conv2d_106 (Conv2D)             (None, 1, 1, 1024)   3276800     activation_105[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 2048)         0           block_inception_f10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_106 (BatchN (None, 1, 1, 1024)   4096        conv2d_106[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 2048)         0           global_average_pooling2d[0][0]
# __________________________________________________________________________________________________
# activation_106 (Activation)     (None, 1, 1, 1024)   0           batch_normalization_106[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 67)           137216      dropout[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 1024)         0           activation_106[0][0]
# __________________________________________________________________________________________________
# main_classifier (Dense)         (None, 67)           4556        dense[0][0]
# __________________________________________________________________________________________________
# auxiliary_classifier (Dense)    (None, 67)           68608       flatten[0][0]
# ==================================================================================================
# Total params: 27,604,268
# Trainable params: 27,563,052
# Non-trainable params: 41,216
# __________________________________________________________________________________________________

# %%
# 폴더 생성

os.makedirs(os.path.join(dir,'model_output',number,model.name), exist_ok=True)
os.makedirs(os.path.join(dir,'train_valid_output',number), exist_ok=True)

# %%
# 참고 : https://github.com/OverLordGoldDragon/keras-adamw

import sys
sys.path.append('/content/drive/My Drive/Colab Notebooks/Paper')
import utils
import optimizers_v2
from utils import get_weight_decays, fill_dict_in_order
from utils import reset_seeds, K_eval
from optimizers_v2 import AdamW, NadamW, SGDW

# %%
# top-5 accuracy 출력
import functools
top5_acc = functools.partial(ks.metrics.top_k_categorical_accuracy, k=5)
top5_acc.__name__ = 'top5_acc'

# %%
#optimizer = SGDW(model=model, use_cosine_annealing=False, total_iterations = len(x_train) // batch_sizes, nesterov=True, momentum=0.9)
optimizer = AdamW(model=model, use_cosine_annealing=False, total_iterations = len(x_train) // batch_sizes)
#optimizer = Adam()
filepath =  os.path.join(dir,'model_output',number,model.name,'{epoch:03d}.h5')

callbacks_list = [ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_weights_only=False, save_best_only=True, mode='min'),
                  ModelCheckpoint(filepath, monitor='val_main_classifier_accuracy', verbose=1, save_weights_only=False, save_best_only=True, mode='max'),
                  #ReduceLROnPlateau(monitor='val_loss',patience=3,factor=0.1,min_lr=1e-5),
                  LearningRateScheduler(lr_schedule,verbose=1)
                  ]

model.compile(optimizer, loss={'main_classifier' : smoothed_categorical_crossentropy, 'auxiliary_classifier' : smoothed_categorical_crossentropy},
                loss_weights={'main_classifier' : 1.0, 'auxiliary_classifier' : 0.4}, metrics=['accuracy',top5_acc,macro_f1score])

# %%
######## flow_from_directory
#history = model.fit_generator(generate_train_for_three(), steps_per_epoch=int(len(x_train)/batch_sizes),  validation_data = generate_valid_for_three(), epochs=epochs , verbose=1 , callbacks = callbacks_list,validation_steps=int(len(x_valid)/batch_sizes))
history = model.fit(generate_train_for_two(), steps_per_epoch=int(len(x_train)/batch_sizes),  validation_data = generate_valid_for_two(), epochs=epochs , verbose=1 , callbacks = callbacks_list , validation_steps=int(len(x_valid)/batch_sizes))
# Out:
# Found 12466 images belonging to 67 classes.
# Learning rate:  0.001
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 1/70
# 0.0(L1), 0.00014359163854378413(L2) weight decay set for conv2d/kernel:0
# 0.0(L1), 0.00014359163854378413(L2) weight decay set for conv2d_1/kernel:0
# 0.0(L1), 0.00014359163854378413(L2) weight decay set for conv2d_2/kernel:0
# 0.0(L1), 0.00014359163854378413(L2) weight decay set for conv2d_3/kernel:0
# 0.0(L1), 0.00014359163854378413(L2) weight decay set for conv2d_4/kernel:0
# 0.0(L1), 0.00014359163854378413(L2) weight decay set for conv2d_5/kernel:0
# 0.0(L1), 0.00014359163854378413(L2) weight decay set for conv2d_6/kernel:0
# 0.0(L1), 0.00014359163854378413(L2) weight decay set for conv2d_7/kernel:0
# 0.0(L1), 0.00014359163854378413(L2) weight decay set for conv2d_9/kernel:0
# 0.0(L1), 0.00014359163854378413(L2) weight decay set for conv2d_8/kernel:0
# 0.0(L1), 0.00014359163854378413(L2) weight decay set for conv2d_10/kernel:0
# 0.0(L1), 0.00014359163854378413(L2) weight decay set for conv2d_11/kernel:0
# 0.0(L1), 0.00014359163854378413(L2) weight decay set for conv2d_12/kernel:0
# 0.0(L1), 0.00014359163854378413(L2) weight decay set for conv2d_13/kernel:0
# 0.0(L1), 0.00014359163854378413(L2) weight decay set for conv2d_14/kernel:0
# 0.0(L1), 0.00014359163854378413(L2) weight decay set for conv2d_16/kernel:0
# 0.0(L1), 0.00014359163854378413(L2) weight decay set for conv2d_15/kernel:0
# 0.0(L1), 0.00014359163854378413(L2) weight decay set for conv2d_17/kernel:0
# 0.0(L1), 0.00014359163854378413(L2) weight decay set for conv2d_18/kernel:0
# 0.0(L1), 0.00014359163854378413(L2) weight decay set for conv2d_19/kernel:0
# 0.0(L1), 0.00014359163854378413(L2) weight decay set for conv2d_20/kernel:0
# 0.0(L1), 0.00014359163854378413(L2) weight decay set for conv2d_21/kernel:0
# 0.0(L1), 0.00014359163854378413(L2) weight decay set for conv2d_23/kernel:0
# 0.0(L1), 0.00014359163854378413(L2) weight decay set for conv2d_22/kernel:0
# 0.0(L1), 0.00014359163854378413(L2) weight decay set for conv2d_24/kernel:0
# 0.0(L1), 0.00014359163854378413(L2) weight decay set for conv2d_25/kernel:0
# 0.0(L1), 0.00014359163854378413(L2) weight decay set for conv2d_26/kernel:0
# 0.0(L1), 0.00014359163854378413(L2) weight decay set for conv2d_27/kernel:0
# 0.0(L1), 0.00014359163854378413(L2) weight decay set for conv2d_28/kernel:0
# 0.0(L1), 0.00014359163854378413(L2) weight decay set for conv2d_30/kernel:0
# 0.0(L1), 0.00014359163854378413(L2) weight decay set for conv2d_29/kernel:0
# 0.0(L1), 0.00014359163854378413(L2) weight decay set for conv2d_31/kernel:0
# 0.0(L1), 0.00014359163854378413(L2) weight decay set for conv2d_32/kernel:0
# 0.0(L1), 0.00014359163854378413(L2) weight decay set for conv2d_33/kernel:0
# 0.0(L1), 0.00014359163854378413(L2) weight decay set for conv2d_34/kernel:0
# 0.0(L1), 0.00014359163854378413(L2) weight decay set for conv2d_37/kernel:0
# 0.0(L1), 0.00014359163854378413(L2) weight decay set for conv2d_35/kernel:0
# 0.0(L1), 0.00014359163854378413(L2) weight decay set for conv2d_38/kernel:0
# 0.0(L1), 0.00014359163854378413(L2) weight decay set for conv2d_36/kernel:0
# 0.0(L1), 0.00014359163854378413(L2) weight decay set for conv2d_39/kernel:0
# 0.0(L1), 0.00014359163854378413(L2) weight decay set for conv2d_40/kernel:0
# 0.0(L1), 0.00014359163854378413(L2) weight decay set for conv2d_41/kernel:0
# 0.0(L1), 0.00014359163854378413(L2) weight decay set for conv2d_42/kernel:0
# 0.0(L1), 0.00014359163854378413(L2) weight decay set for conv2d_43/kernel:0
# 0.0(L1), 0.00014359163854378413(L2) weight decay set for conv2d_44/kernel:0
# 0.0(L1), 0.00014359163854378413(L2) weight decay set for conv2d_47/kernel:0
# 0.0(L1), 0.00014359163854378413(L2) weight decay set for conv2d_45/kernel:0
# 0.0(L1), 0.00014359163854378413(L2) weight decay set for conv2d_48/kernel:0
# 0.0(L1), 0.00014359163854378413(L2) weight decay set for conv2d_46/kernel:0
# 0.0(L1), 0.00014359163854378413(L2) weight decay set for conv2d_49/kernel:0
# 0.0(L1), 0.00014359163854378413(L2) weight decay set for conv2d_50/kernel:0
# 0.0(L1), 0.00014359163854378413(L2) weight decay set for conv2d_51/kernel:0
# 0.0(L1), 0.00014359163854378413(L2) weight decay set for conv2d_52/kernel:0
# 0.0(L1), 0.00014359163854378413(L2) weight decay set for conv2d_53/kernel:0
# 0.0(L1), 0.00014359163854378413(L2) weight decay set for conv2d_54/kernel:0
# 0.0(L1), 0.00014359163854378413(L2) weight decay set for conv2d_57/kernel:0
# 0.0(L1), 0.00014359163854378413(L2) weight decay set for conv2d_55/kernel:0
# 0.0(L1), 0.00014359163854378413(L2) weight decay set for conv2d_58/kernel:0
# 0.0(L1), 0.00014359163854378413(L2) weight decay set for conv2d_56/kernel:0
# 0.0(L1), 0.00014359163854378413(L2) weight decay set for conv2d_59/kernel:0
# 0.0(L1), 0.00014359163854378413(L2) weight decay set for conv2d_60/kernel:0
# 0.0(L1), 0.00014359163854378413(L2) weight decay set for conv2d_61/kernel:0
# 0.0(L1), 0.00014359163854378413(L2) weight decay set for conv2d_62/kernel:0
# 0.0(L1), 0.00014359163854378413(L2) weight decay set for conv2d_63/kernel:0
# 0.0(L1), 0.00014359163854378413(L2) weight decay set for conv2d_64/kernel:0
# 0.0(L1), 0.00014359163854378413(L2) weight decay set for conv2d_67/kernel:0
# 0.0(L1), 0.00014359163854378413(L2) weight decay set for conv2d_65/kernel:0
# 0.0(L1), 0.00014359163854378413(L2) weight decay set for conv2d_68/kernel:0
# 0.0(L1), 0.00014359163854378413(L2) weight decay set for conv2d_66/kernel:0
# 0.0(L1), 0.00014359163854378413(L2) weight decay set for conv2d_69/kernel:0
# 0.0(L1), 0.00014359163854378413(L2) weight decay set for conv2d_70/kernel:0
# 0.0(L1), 0.00014359163854378413(L2) weight decay set for conv2d_71/kernel:0
# 0.0(L1), 0.00014359163854378413(L2) weight decay set for conv2d_72/kernel:0
# 0.0(L1), 0.00014359163854378413(L2) weight decay set for conv2d_73/kernel:0
# 0.0(L1), 0.00014359163854378413(L2) weight decay set for conv2d_74/kernel:0
# 0.0(L1), 0.00014359163854378413(L2) weight decay set for conv2d_77/kernel:0
# 0.0(L1), 0.00014359163854378413(L2) weight decay set for conv2d_75/kernel:0
# 0.0(L1), 0.00014359163854378413(L2) weight decay set for conv2d_78/kernel:0
# 0.0(L1), 0.00014359163854378413(L2) weight decay set for conv2d_76/kernel:0
# 0.0(L1), 0.00014359163854378413(L2) weight decay set for conv2d_79/kernel:0
# 0.0(L1), 0.00014359163854378413(L2) weight decay set for conv2d_80/kernel:0
# 0.0(L1), 0.00014359163854378413(L2) weight decay set for conv2d_81/kernel:0
# 0.0(L1), 0.00014359163854378413(L2) weight decay set for conv2d_82/kernel:0
# 0.0(L1), 0.00014359163854378413(L2) weight decay set for conv2d_83/kernel:0
# 0.0(L1), 0.00014359163854378413(L2) weight decay set for conv2d_85/kernel:0
# 0.0(L1), 0.00014359163854378413(L2) weight decay set for conv2d_84/kernel:0
# 0.0(L1), 0.00014359163854378413(L2) weight decay set for conv2d_86/kernel:0
# 0.0(L1), 0.00014359163854378413(L2) weight decay set for conv2d_87/kernel:0
# 0.0(L1), 0.00014359163854378413(L2) weight decay set for conv2d_88/kernel:0
# 0.0(L1), 0.00014359163854378413(L2) weight decay set for conv2d_91/kernel:0
# 0.0(L1), 0.00014359163854378413(L2) weight decay set for conv2d_89/kernel:0
# 0.0(L1), 0.00014359163854378413(L2) weight decay set for conv2d_90/kernel:0
# 0.0(L1), 0.00014359163854378413(L2) weight decay set for conv2d_92/kernel:0
# 0.0(L1), 0.00014359163854378413(L2) weight decay set for conv2d_93/kernel:0
# 0.0(L1), 0.00014359163854378413(L2) weight decay set for conv2d_94/kernel:0
# 0.0(L1), 0.00014359163854378413(L2) weight decay set for conv2d_95/kernel:0
# 0.0(L1), 0.00014359163854378413(L2) weight decay set for conv2d_96/kernel:0
# 0.0(L1), 0.00014359163854378413(L2) weight decay set for conv2d_97/kernel:0
# 0.0(L1), 0.00014359163854378413(L2) weight decay set for conv2d_100/kernel:0
# 0.0(L1), 0.00014359163854378413(L2) weight decay set for conv2d_98/kernel:0
# 0.0(L1), 0.00014359163854378413(L2) weight decay set for conv2d_99/kernel:0
# 0.0(L1), 0.00014359163854378413(L2) weight decay set for conv2d_101/kernel:0
# 0.0(L1), 0.00014359163854378413(L2) weight decay set for conv2d_102/kernel:0
# 0.0(L1), 0.00014359163854378413(L2) weight decay set for conv2d_103/kernel:0
# 0.0(L1), 0.00014359163854378413(L2) weight decay set for conv2d_104/kernel:0
# 0.0(L1), 0.00014359163854378413(L2) weight decay set for conv2d_105/kernel:0
# 0.0(L1), 0.00014359163854378413(L2) weight decay set for conv2d_106/kernel:0
# 0.0(L1), 0.00014359163854378413(L2) weight decay set for dense/kernel:0
# 0.0(L1), 0.00014359163854378413(L2) weight decay set for auxiliary_classifier/kernel:0
# 194/194 [==============================] - ETA: 0s - loss: 5.4218 - main_classifier_loss: 3.8841 - auxiliary_classifier_loss: 3.8444 - main_classifier_accuracy: 0.0937 - main_classifier_top5_acc: 0.3324 - main_classifier_macro_f1score: 1.7695e-04 - auxiliary_classifier_accuracy: 0.1127 - auxiliary_classifier_top5_acc: 0.3613 - auxiliary_classifier_macro_f1score: 0.0011 Found 1564 images belonging to 67 classes.
#
# Epoch 00001: val_loss improved from inf to 7.02755, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/Inception_v3/001.h5
#
# Epoch 00001: val_main_classifier_accuracy improved from -inf to 0.05924, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/Inception_v3/001.h5
# 194/194 [==============================] - 3712s 19s/step - loss: 5.4218 - main_classifier_loss: 3.8841 - auxiliary_classifier_loss: 3.8444 - main_classifier_accuracy: 0.0937 - main_classifier_top5_acc: 0.3324 - main_classifier_macro_f1score: 1.7695e-04 - auxiliary_classifier_accuracy: 0.1127 - auxiliary_classifier_top5_acc: 0.3613 - auxiliary_classifier_macro_f1score: 0.0011 - val_loss: 7.0275 - val_main_classifier_loss: 4.7120 - val_auxiliary_classifier_loss: 5.7889 - val_main_classifier_accuracy: 0.0592 - val_main_classifier_top5_acc: 0.1921 - val_main_classifier_macro_f1score: 3.1095e-04 - val_auxiliary_classifier_accuracy: 0.0247 - val_auxiliary_classifier_top5_acc: 0.1849 - val_auxiliary_classifier_macro_f1score: 0.0011
# Learning rate:  0.001
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 2/70
# 194/194 [==============================] - ETA: 0s - loss: 5.0183 - main_classifier_loss: 3.5889 - auxiliary_classifier_loss: 3.5734 - main_classifier_accuracy: 0.1377 - main_classifier_top5_acc: 0.4232 - main_classifier_macro_f1score: 0.0010 - auxiliary_classifier_accuracy: 0.1580 - auxiliary_classifier_top5_acc: 0.4571 - auxiliary_classifier_macro_f1score: 0.0039
# Epoch 00002: val_loss improved from 7.02755 to 5.63749, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/Inception_v3/002.h5
#
# Epoch 00002: val_main_classifier_accuracy improved from 0.05924 to 0.12630, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/Inception_v3/002.h5
# 194/194 [==============================] - 428s 2s/step - loss: 5.0183 - main_classifier_loss: 3.5889 - auxiliary_classifier_loss: 3.5734 - main_classifier_accuracy: 0.1377 - main_classifier_top5_acc: 0.4232 - main_classifier_macro_f1score: 0.0010 - auxiliary_classifier_accuracy: 0.1580 - auxiliary_classifier_top5_acc: 0.4571 - auxiliary_classifier_macro_f1score: 0.0039 - val_loss: 5.6375 - val_main_classifier_loss: 3.9934 - val_auxiliary_classifier_loss: 4.1101 - val_main_classifier_accuracy: 0.1263 - val_main_classifier_top5_acc: 0.3906 - val_main_classifier_macro_f1score: 0.0026 - val_auxiliary_classifier_accuracy: 0.1576 - val_auxiliary_classifier_top5_acc: 0.4466 - val_auxiliary_classifier_macro_f1score: 0.0058
# Learning rate:  0.001
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 3/70
# 194/194 [==============================] - ETA: 0s - loss: 4.7954 - main_classifier_loss: 3.4321 - auxiliary_classifier_loss: 3.4082 - main_classifier_accuracy: 0.1736 - main_classifier_top5_acc: 0.4795 - main_classifier_macro_f1score: 0.0025 - auxiliary_classifier_accuracy: 0.2029 - auxiliary_classifier_top5_acc: 0.5168 - auxiliary_classifier_macro_f1score: 0.0094
# Epoch 00003: val_loss improved from 5.63749 to 5.19425, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/Inception_v3/003.h5
#
# Epoch 00003: val_main_classifier_accuracy improved from 0.12630 to 0.16927, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/Inception_v3/003.h5
# 194/194 [==============================] - 429s 2s/step - loss: 4.7954 - main_classifier_loss: 3.4321 - auxiliary_classifier_loss: 3.4082 - main_classifier_accuracy: 0.1736 - main_classifier_top5_acc: 0.4795 - main_classifier_macro_f1score: 0.0025 - auxiliary_classifier_accuracy: 0.2029 - auxiliary_classifier_top5_acc: 0.5168 - auxiliary_classifier_macro_f1score: 0.0094 - val_loss: 5.1942 - val_main_classifier_loss: 3.6870 - val_auxiliary_classifier_loss: 3.7681 - val_main_classifier_accuracy: 0.1693 - val_main_classifier_top5_acc: 0.4590 - val_main_classifier_macro_f1score: 0.0096 - val_auxiliary_classifier_accuracy: 0.2064 - val_auxiliary_classifier_top5_acc: 0.5247 - val_auxiliary_classifier_macro_f1score: 0.0143
# Learning rate:  0.001
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 4/70
# 194/194 [==============================] - ETA: 0s - loss: 4.5967 - main_classifier_loss: 3.2974 - auxiliary_classifier_loss: 3.2483 - main_classifier_accuracy: 0.2025 - main_classifier_top5_acc: 0.5274 - main_classifier_macro_f1score: 0.0084 - auxiliary_classifier_accuracy: 0.2331 - auxiliary_classifier_top5_acc: 0.5665 - auxiliary_classifier_macro_f1score: 0.0196
# Epoch 00004: val_loss did not improve from 5.19425
#
# Epoch 00004: val_main_classifier_accuracy did not improve from 0.16927
# 194/194 [==============================] - 421s 2s/step - loss: 4.5967 - main_classifier_loss: 3.2974 - auxiliary_classifier_loss: 3.2483 - main_classifier_accuracy: 0.2025 - main_classifier_top5_acc: 0.5274 - main_classifier_macro_f1score: 0.0084 - auxiliary_classifier_accuracy: 0.2331 - auxiliary_classifier_top5_acc: 0.5665 - auxiliary_classifier_macro_f1score: 0.0196 - val_loss: 32.5972 - val_main_classifier_loss: 14.4423 - val_auxiliary_classifier_loss: 45.3872 - val_main_classifier_accuracy: 0.1022 - val_main_classifier_top5_acc: 0.2943 - val_main_classifier_macro_f1score: 0.0077 - val_auxiliary_classifier_accuracy: 0.1042 - val_auxiliary_classifier_top5_acc: 0.2923 - val_auxiliary_classifier_macro_f1score: 0.0081
# Learning rate:  0.001
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 5/70
# 194/194 [==============================] - ETA: 0s - loss: 4.4598 - main_classifier_loss: 3.2016 - auxiliary_classifier_loss: 3.1455 - main_classifier_accuracy: 0.2245 - main_classifier_top5_acc: 0.5602 - main_classifier_macro_f1score: 0.0130 - auxiliary_classifier_accuracy: 0.2654 - auxiliary_classifier_top5_acc: 0.6010 - auxiliary_classifier_macro_f1score: 0.0298
# Epoch 00005: val_loss improved from 5.19425 to 5.07558, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/Inception_v3/005.h5
#
# Epoch 00005: val_main_classifier_accuracy improved from 0.16927 to 0.18945, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/Inception_v3/005.h5
# 194/194 [==============================] - 426s 2s/step - loss: 4.4598 - main_classifier_loss: 3.2016 - auxiliary_classifier_loss: 3.1455 - main_classifier_accuracy: 0.2245 - main_classifier_top5_acc: 0.5602 - main_classifier_macro_f1score: 0.0130 - auxiliary_classifier_accuracy: 0.2654 - auxiliary_classifier_top5_acc: 0.6010 - auxiliary_classifier_macro_f1score: 0.0298 - val_loss: 5.0756 - val_main_classifier_loss: 3.6680 - val_auxiliary_classifier_loss: 3.5189 - val_main_classifier_accuracy: 0.1895 - val_main_classifier_top5_acc: 0.4785 - val_main_classifier_macro_f1score: 0.0199 - val_auxiliary_classifier_accuracy: 0.2155 - val_auxiliary_classifier_top5_acc: 0.5039 - val_auxiliary_classifier_macro_f1score: 0.0336
# Learning rate:  0.001
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 6/70
# 194/194 [==============================] - ETA: 0s - loss: 4.3016 - main_classifier_loss: 3.0949 - auxiliary_classifier_loss: 3.0168 - main_classifier_accuracy: 0.2503 - main_classifier_top5_acc: 0.5937 - main_classifier_macro_f1score: 0.0186 - auxiliary_classifier_accuracy: 0.2883 - auxiliary_classifier_top5_acc: 0.6324 - auxiliary_classifier_macro_f1score: 0.0364
# Epoch 00006: val_loss did not improve from 5.07558
#
# Epoch 00006: val_main_classifier_accuracy did not improve from 0.18945
# 194/194 [==============================] - 419s 2s/step - loss: 4.3016 - main_classifier_loss: 3.0949 - auxiliary_classifier_loss: 3.0168 - main_classifier_accuracy: 0.2503 - main_classifier_top5_acc: 0.5937 - main_classifier_macro_f1score: 0.0186 - auxiliary_classifier_accuracy: 0.2883 - auxiliary_classifier_top5_acc: 0.6324 - auxiliary_classifier_macro_f1score: 0.0364 - val_loss: 7.2299 - val_main_classifier_loss: 4.7239 - val_auxiliary_classifier_loss: 6.2651 - val_main_classifier_accuracy: 0.0931 - val_main_classifier_top5_acc: 0.2702 - val_main_classifier_macro_f1score: 0.0110 - val_auxiliary_classifier_accuracy: 0.0840 - val_auxiliary_classifier_top5_acc: 0.2585 - val_auxiliary_classifier_macro_f1score: 0.0120
# Learning rate:  0.001
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 7/70
# 194/194 [==============================] - ETA: 0s - loss: 4.1014 - main_classifier_loss: 2.9641 - auxiliary_classifier_loss: 2.8434 - main_classifier_accuracy: 0.2954 - main_classifier_top5_acc: 0.6340 - main_classifier_macro_f1score: 0.0332 - auxiliary_classifier_accuracy: 0.3290 - auxiliary_classifier_top5_acc: 0.6788 - auxiliary_classifier_macro_f1score: 0.0580
# Epoch 00007: val_loss improved from 5.07558 to 4.28585, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/Inception_v3/007.h5
#
# Epoch 00007: val_main_classifier_accuracy improved from 0.18945 to 0.29688, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/Inception_v3/007.h5
# 194/194 [==============================] - 425s 2s/step - loss: 4.1014 - main_classifier_loss: 2.9641 - auxiliary_classifier_loss: 2.8434 - main_classifier_accuracy: 0.2954 - main_classifier_top5_acc: 0.6340 - main_classifier_macro_f1score: 0.0332 - auxiliary_classifier_accuracy: 0.3290 - auxiliary_classifier_top5_acc: 0.6788 - auxiliary_classifier_macro_f1score: 0.0580 - val_loss: 4.2858 - val_main_classifier_loss: 3.0727 - val_auxiliary_classifier_loss: 3.0328 - val_main_classifier_accuracy: 0.2969 - val_main_classifier_top5_acc: 0.6257 - val_main_classifier_macro_f1score: 0.0530 - val_auxiliary_classifier_accuracy: 0.3001 - val_auxiliary_classifier_top5_acc: 0.6595 - val_auxiliary_classifier_macro_f1score: 0.0661
# Learning rate:  0.001
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 8/70
# 194/194 [==============================] - ETA: 0s - loss: 3.8971 - main_classifier_loss: 2.8245 - auxiliary_classifier_loss: 2.6814 - main_classifier_accuracy: 0.3301 - main_classifier_top5_acc: 0.6838 - main_classifier_macro_f1score: 0.0458 - auxiliary_classifier_accuracy: 0.3712 - auxiliary_classifier_top5_acc: 0.7219 - auxiliary_classifier_macro_f1score: 0.0772
# Epoch 00008: val_loss did not improve from 4.28585
#
# Epoch 00008: val_main_classifier_accuracy did not improve from 0.29688
# 194/194 [==============================] - 420s 2s/step - loss: 3.8971 - main_classifier_loss: 2.8245 - auxiliary_classifier_loss: 2.6814 - main_classifier_accuracy: 0.3301 - main_classifier_top5_acc: 0.6838 - main_classifier_macro_f1score: 0.0458 - auxiliary_classifier_accuracy: 0.3712 - auxiliary_classifier_top5_acc: 0.7219 - auxiliary_classifier_macro_f1score: 0.0772 - val_loss: 7.3290 - val_main_classifier_loss: 4.2323 - val_auxiliary_classifier_loss: 7.7417 - val_main_classifier_accuracy: 0.2253 - val_main_classifier_top5_acc: 0.5332 - val_main_classifier_macro_f1score: 0.0308 - val_auxiliary_classifier_accuracy: 0.2344 - val_auxiliary_classifier_top5_acc: 0.5189 - val_auxiliary_classifier_macro_f1score: 0.0419
# Learning rate:  0.001
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 9/70
# 194/194 [==============================] - ETA: 0s - loss: 3.7279 - main_classifier_loss: 2.7063 - auxiliary_classifier_loss: 2.5539 - main_classifier_accuracy: 0.3648 - main_classifier_top5_acc: 0.7171 - main_classifier_macro_f1score: 0.0636 - auxiliary_classifier_accuracy: 0.4078 - auxiliary_classifier_top5_acc: 0.7567 - auxiliary_classifier_macro_f1score: 0.0962
# Epoch 00009: val_loss improved from 4.28585 to 4.24882, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/Inception_v3/009.h5
#
# Epoch 00009: val_main_classifier_accuracy did not improve from 0.29688
# 194/194 [==============================] - 422s 2s/step - loss: 3.7279 - main_classifier_loss: 2.7063 - auxiliary_classifier_loss: 2.5539 - main_classifier_accuracy: 0.3648 - main_classifier_top5_acc: 0.7171 - main_classifier_macro_f1score: 0.0636 - auxiliary_classifier_accuracy: 0.4078 - auxiliary_classifier_top5_acc: 0.7567 - auxiliary_classifier_macro_f1score: 0.0962 - val_loss: 4.2488 - val_main_classifier_loss: 3.0798 - val_auxiliary_classifier_loss: 2.9224 - val_main_classifier_accuracy: 0.2858 - val_main_classifier_top5_acc: 0.6172 - val_main_classifier_macro_f1score: 0.0555 - val_auxiliary_classifier_accuracy: 0.3190 - val_auxiliary_classifier_top5_acc: 0.6738 - val_auxiliary_classifier_macro_f1score: 0.0775
# Learning rate:  0.001
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 10/70
# 194/194 [==============================] - ETA: 0s - loss: 3.5776 - main_classifier_loss: 2.6025 - auxiliary_classifier_loss: 2.4375 - main_classifier_accuracy: 0.3968 - main_classifier_top5_acc: 0.7395 - main_classifier_macro_f1score: 0.0828 - auxiliary_classifier_accuracy: 0.4412 - auxiliary_classifier_top5_acc: 0.7796 - auxiliary_classifier_macro_f1score: 0.1234
# Epoch 00010: val_loss did not improve from 4.24882
#
# Epoch 00010: val_main_classifier_accuracy did not improve from 0.29688
# 194/194 [==============================] - 419s 2s/step - loss: 3.5776 - main_classifier_loss: 2.6025 - auxiliary_classifier_loss: 2.4375 - main_classifier_accuracy: 0.3968 - main_classifier_top5_acc: 0.7395 - main_classifier_macro_f1score: 0.0828 - auxiliary_classifier_accuracy: 0.4412 - auxiliary_classifier_top5_acc: 0.7796 - auxiliary_classifier_macro_f1score: 0.1234 - val_loss: 10.2609 - val_main_classifier_loss: 4.7744 - val_auxiliary_classifier_loss: 13.7162 - val_main_classifier_accuracy: 0.2493 - val_main_classifier_top5_acc: 0.5417 - val_main_classifier_macro_f1score: 0.0424 - val_auxiliary_classifier_accuracy: 0.2246 - val_auxiliary_classifier_top5_acc: 0.5586 - val_auxiliary_classifier_macro_f1score: 0.0534
# Learning rate:  0.001
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 11/70
# 194/194 [==============================] - ETA: 0s - loss: 3.4571 - main_classifier_loss: 2.5208 - auxiliary_classifier_loss: 2.3409 - main_classifier_accuracy: 0.4188 - main_classifier_top5_acc: 0.7665 - main_classifier_macro_f1score: 0.0966 - auxiliary_classifier_accuracy: 0.4677 - auxiliary_classifier_top5_acc: 0.8058 - auxiliary_classifier_macro_f1score: 0.1355
# Epoch 00011: val_loss did not improve from 4.24882
#
# Epoch 00011: val_main_classifier_accuracy improved from 0.29688 to 0.30469, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/Inception_v3/011.h5
# 194/194 [==============================] - 423s 2s/step - loss: 3.4571 - main_classifier_loss: 2.5208 - auxiliary_classifier_loss: 2.3409 - main_classifier_accuracy: 0.4188 - main_classifier_top5_acc: 0.7665 - main_classifier_macro_f1score: 0.0966 - auxiliary_classifier_accuracy: 0.4677 - auxiliary_classifier_top5_acc: 0.8058 - auxiliary_classifier_macro_f1score: 0.1355 - val_loss: 4.3077 - val_main_classifier_loss: 3.0690 - val_auxiliary_classifier_loss: 3.0968 - val_main_classifier_accuracy: 0.3047 - val_main_classifier_top5_acc: 0.6569 - val_main_classifier_macro_f1score: 0.0624 - val_auxiliary_classifier_accuracy: 0.3444 - val_auxiliary_classifier_top5_acc: 0.6862 - val_auxiliary_classifier_macro_f1score: 0.0850
# Learning rate:  0.001
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 12/70
# 194/194 [==============================] - ETA: 0s - loss: 3.3233 - main_classifier_loss: 2.4263 - auxiliary_classifier_loss: 2.2425 - main_classifier_accuracy: 0.4533 - main_classifier_top5_acc: 0.7861 - main_classifier_macro_f1score: 0.1116 - auxiliary_classifier_accuracy: 0.5003 - auxiliary_classifier_top5_acc: 0.8275 - auxiliary_classifier_macro_f1score: 0.1534
# Epoch 00012: val_loss improved from 4.24882 to 3.63371, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/Inception_v3/012.h5
#
# Epoch 00012: val_main_classifier_accuracy improved from 0.30469 to 0.41536, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/Inception_v3/012.h5
# 194/194 [==============================] - 423s 2s/step - loss: 3.3233 - main_classifier_loss: 2.4263 - auxiliary_classifier_loss: 2.2425 - main_classifier_accuracy: 0.4533 - main_classifier_top5_acc: 0.7861 - main_classifier_macro_f1score: 0.1116 - auxiliary_classifier_accuracy: 0.5003 - auxiliary_classifier_top5_acc: 0.8275 - auxiliary_classifier_macro_f1score: 0.1534 - val_loss: 3.6337 - val_main_classifier_loss: 2.6282 - val_auxiliary_classifier_loss: 2.5138 - val_main_classifier_accuracy: 0.4154 - val_main_classifier_top5_acc: 0.7344 - val_main_classifier_macro_f1score: 0.1004 - val_auxiliary_classifier_accuracy: 0.4388 - val_auxiliary_classifier_top5_acc: 0.7578 - val_auxiliary_classifier_macro_f1score: 0.1225
# Learning rate:  0.001
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 13/70
# 194/194 [==============================] - ETA: 0s - loss: 3.2321 - main_classifier_loss: 2.3641 - auxiliary_classifier_loss: 2.1701 - main_classifier_accuracy: 0.4725 - main_classifier_top5_acc: 0.7995 - main_classifier_macro_f1score: 0.1269 - auxiliary_classifier_accuracy: 0.5273 - auxiliary_classifier_top5_acc: 0.8481 - auxiliary_classifier_macro_f1score: 0.1697
# Epoch 00013: val_loss did not improve from 3.63371
#
# Epoch 00013: val_main_classifier_accuracy did not improve from 0.41536
# 194/194 [==============================] - 421s 2s/step - loss: 3.2321 - main_classifier_loss: 2.3641 - auxiliary_classifier_loss: 2.1701 - main_classifier_accuracy: 0.4725 - main_classifier_top5_acc: 0.7995 - main_classifier_macro_f1score: 0.1269 - auxiliary_classifier_accuracy: 0.5273 - auxiliary_classifier_top5_acc: 0.8481 - auxiliary_classifier_macro_f1score: 0.1697 - val_loss: 5.1351 - val_main_classifier_loss: 3.6405 - val_auxiliary_classifier_loss: 3.7365 - val_main_classifier_accuracy: 0.3359 - val_main_classifier_top5_acc: 0.6608 - val_main_classifier_macro_f1score: 0.0725 - val_auxiliary_classifier_accuracy: 0.3340 - val_auxiliary_classifier_top5_acc: 0.6719 - val_auxiliary_classifier_macro_f1score: 0.0871
# Learning rate:  0.001
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 14/70
# 194/194 [==============================] - ETA: 0s - loss: 3.1015 - main_classifier_loss: 2.2689 - auxiliary_classifier_loss: 2.0815 - main_classifier_accuracy: 0.5025 - main_classifier_top5_acc: 0.8230 - main_classifier_macro_f1score: 0.1449 - auxiliary_classifier_accuracy: 0.5579 - auxiliary_classifier_top5_acc: 0.8637 - auxiliary_classifier_macro_f1score: 0.1847
# Epoch 00014: val_loss did not improve from 3.63371
#
# Epoch 00014: val_main_classifier_accuracy did not improve from 0.41536
# 194/194 [==============================] - 419s 2s/step - loss: 3.1015 - main_classifier_loss: 2.2689 - auxiliary_classifier_loss: 2.0815 - main_classifier_accuracy: 0.5025 - main_classifier_top5_acc: 0.8230 - main_classifier_macro_f1score: 0.1449 - auxiliary_classifier_accuracy: 0.5579 - auxiliary_classifier_top5_acc: 0.8637 - auxiliary_classifier_macro_f1score: 0.1847 - val_loss: 4.2890 - val_main_classifier_loss: 3.0863 - val_auxiliary_classifier_loss: 3.0069 - val_main_classifier_accuracy: 0.3001 - val_main_classifier_top5_acc: 0.6302 - val_main_classifier_macro_f1score: 0.0795 - val_auxiliary_classifier_accuracy: 0.3366 - val_auxiliary_classifier_top5_acc: 0.6595 - val_auxiliary_classifier_macro_f1score: 0.0987
# Learning rate:  0.001
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 15/70
# 194/194 [==============================] - ETA: 0s - loss: 3.0559 - main_classifier_loss: 2.2387 - auxiliary_classifier_loss: 2.0429 - main_classifier_accuracy: 0.5125 - main_classifier_top5_acc: 0.8320 - main_classifier_macro_f1score: 0.1514 - auxiliary_classifier_accuracy: 0.5647 - auxiliary_classifier_top5_acc: 0.8746 - auxiliary_classifier_macro_f1score: 0.1952
# Epoch 00015: val_loss did not improve from 3.63371
#
# Epoch 00015: val_main_classifier_accuracy did not improve from 0.41536
# 194/194 [==============================] - 419s 2s/step - loss: 3.0559 - main_classifier_loss: 2.2387 - auxiliary_classifier_loss: 2.0429 - main_classifier_accuracy: 0.5125 - main_classifier_top5_acc: 0.8320 - main_classifier_macro_f1score: 0.1514 - auxiliary_classifier_accuracy: 0.5647 - auxiliary_classifier_top5_acc: 0.8746 - auxiliary_classifier_macro_f1score: 0.1952 - val_loss: 3.9157 - val_main_classifier_loss: 2.8060 - val_auxiliary_classifier_loss: 2.7743 - val_main_classifier_accuracy: 0.3724 - val_main_classifier_top5_acc: 0.7142 - val_main_classifier_macro_f1score: 0.1021 - val_auxiliary_classifier_accuracy: 0.3789 - val_auxiliary_classifier_top5_acc: 0.7148 - val_auxiliary_classifier_macro_f1score: 0.1201
# Learning rate:  0.001
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 16/70
# 194/194 [==============================] - ETA: 0s - loss: 2.9393 - main_classifier_loss: 2.1559 - auxiliary_classifier_loss: 1.9585 - main_classifier_accuracy: 0.5392 - main_classifier_top5_acc: 0.8449 - main_classifier_macro_f1score: 0.1672 - auxiliary_classifier_accuracy: 0.5965 - auxiliary_classifier_top5_acc: 0.8886 - auxiliary_classifier_macro_f1score: 0.2149
# Epoch 00016: val_loss did not improve from 3.63371
#
# Epoch 00016: val_main_classifier_accuracy did not improve from 0.41536
# 194/194 [==============================] - 418s 2s/step - loss: 2.9393 - main_classifier_loss: 2.1559 - auxiliary_classifier_loss: 1.9585 - main_classifier_accuracy: 0.5392 - main_classifier_top5_acc: 0.8449 - main_classifier_macro_f1score: 0.1672 - auxiliary_classifier_accuracy: 0.5965 - auxiliary_classifier_top5_acc: 0.8886 - auxiliary_classifier_macro_f1score: 0.2149 - val_loss: 3.6677 - val_main_classifier_loss: 2.6490 - val_auxiliary_classifier_loss: 2.5467 - val_main_classifier_accuracy: 0.4004 - val_main_classifier_top5_acc: 0.7324 - val_main_classifier_macro_f1score: 0.1152 - val_auxiliary_classifier_accuracy: 0.4271 - val_auxiliary_classifier_top5_acc: 0.7585 - val_auxiliary_classifier_macro_f1score: 0.1445
# Learning rate:  0.001
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 17/70
# 194/194 [==============================] - ETA: 0s - loss: 2.8554 - main_classifier_loss: 2.0992 - auxiliary_classifier_loss: 1.8905 - main_classifier_accuracy: 0.5614 - main_classifier_top5_acc: 0.8590 - main_classifier_macro_f1score: 0.1810 - auxiliary_classifier_accuracy: 0.6193 - auxiliary_classifier_top5_acc: 0.9040 - auxiliary_classifier_macro_f1score: 0.2280
# Epoch 00017: val_loss did not improve from 3.63371
#
# Epoch 00017: val_main_classifier_accuracy improved from 0.41536 to 0.41927, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/Inception_v3/017.h5
# 194/194 [==============================] - 421s 2s/step - loss: 2.8554 - main_classifier_loss: 2.0992 - auxiliary_classifier_loss: 1.8905 - main_classifier_accuracy: 0.5614 - main_classifier_top5_acc: 0.8590 - main_classifier_macro_f1score: 0.1810 - auxiliary_classifier_accuracy: 0.6193 - auxiliary_classifier_top5_acc: 0.9040 - auxiliary_classifier_macro_f1score: 0.2280 - val_loss: 3.6985 - val_main_classifier_loss: 2.6476 - val_auxiliary_classifier_loss: 2.6273 - val_main_classifier_accuracy: 0.4193 - val_main_classifier_top5_acc: 0.7201 - val_main_classifier_macro_f1score: 0.1125 - val_auxiliary_classifier_accuracy: 0.4232 - val_auxiliary_classifier_top5_acc: 0.7350 - val_auxiliary_classifier_macro_f1score: 0.1296
# Learning rate:  0.001
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 18/70
# 194/194 [==============================] - ETA: 0s - loss: 2.7824 - main_classifier_loss: 2.0482 - auxiliary_classifier_loss: 1.8354 - main_classifier_accuracy: 0.5760 - main_classifier_top5_acc: 0.8674 - main_classifier_macro_f1score: 0.1937 - auxiliary_classifier_accuracy: 0.6356 - auxiliary_classifier_top5_acc: 0.9086 - auxiliary_classifier_macro_f1score: 0.2430
# Epoch 00018: val_loss improved from 3.63371 to 3.44463, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/Inception_v3/018.h5
#
# Epoch 00018: val_main_classifier_accuracy improved from 0.41927 to 0.47591, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/Inception_v3/018.h5
# 194/194 [==============================] - 425s 2s/step - loss: 2.7824 - main_classifier_loss: 2.0482 - auxiliary_classifier_loss: 1.8354 - main_classifier_accuracy: 0.5760 - main_classifier_top5_acc: 0.8674 - main_classifier_macro_f1score: 0.1937 - auxiliary_classifier_accuracy: 0.6356 - auxiliary_classifier_top5_acc: 0.9086 - auxiliary_classifier_macro_f1score: 0.2430 - val_loss: 3.4446 - val_main_classifier_loss: 2.4682 - val_auxiliary_classifier_loss: 2.4410 - val_main_classifier_accuracy: 0.4759 - val_main_classifier_top5_acc: 0.7799 - val_main_classifier_macro_f1score: 0.1548 - val_auxiliary_classifier_accuracy: 0.4740 - val_auxiliary_classifier_top5_acc: 0.7799 - val_auxiliary_classifier_macro_f1score: 0.1686
# Learning rate:  0.001
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 19/70
# 194/194 [==============================] - ETA: 0s - loss: 2.7281 - main_classifier_loss: 2.0089 - auxiliary_classifier_loss: 1.7979 - main_classifier_accuracy: 0.5879 - main_classifier_top5_acc: 0.8790 - main_classifier_macro_f1score: 0.2028 - auxiliary_classifier_accuracy: 0.6483 - auxiliary_classifier_top5_acc: 0.9165 - auxiliary_classifier_macro_f1score: 0.2513
# Epoch 00019: val_loss did not improve from 3.44463
#
# Epoch 00019: val_main_classifier_accuracy did not improve from 0.47591
# 194/194 [==============================] - 418s 2s/step - loss: 2.7281 - main_classifier_loss: 2.0089 - auxiliary_classifier_loss: 1.7979 - main_classifier_accuracy: 0.5879 - main_classifier_top5_acc: 0.8790 - main_classifier_macro_f1score: 0.2028 - auxiliary_classifier_accuracy: 0.6483 - auxiliary_classifier_top5_acc: 0.9165 - auxiliary_classifier_macro_f1score: 0.2513 - val_loss: 3.7854 - val_main_classifier_loss: 2.7094 - val_auxiliary_classifier_loss: 2.6900 - val_main_classifier_accuracy: 0.3789 - val_main_classifier_top5_acc: 0.7402 - val_main_classifier_macro_f1score: 0.1030 - val_auxiliary_classifier_accuracy: 0.4089 - val_auxiliary_classifier_top5_acc: 0.7357 - val_auxiliary_classifier_macro_f1score: 0.1255
# Learning rate:  0.001
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 20/70
# 194/194 [==============================] - ETA: 0s - loss: 2.6519 - main_classifier_loss: 1.9535 - auxiliary_classifier_loss: 1.7461 - main_classifier_accuracy: 0.6106 - main_classifier_top5_acc: 0.8913 - main_classifier_macro_f1score: 0.2129 - auxiliary_classifier_accuracy: 0.6717 - auxiliary_classifier_top5_acc: 0.9286 - auxiliary_classifier_macro_f1score: 0.2671
# Epoch 00020: val_loss improved from 3.44463 to 3.43137, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/Inception_v3/020.h5
#
# Epoch 00020: val_main_classifier_accuracy did not improve from 0.47591
# 194/194 [==============================] - 422s 2s/step - loss: 2.6519 - main_classifier_loss: 1.9535 - auxiliary_classifier_loss: 1.7461 - main_classifier_accuracy: 0.6106 - main_classifier_top5_acc: 0.8913 - main_classifier_macro_f1score: 0.2129 - auxiliary_classifier_accuracy: 0.6717 - auxiliary_classifier_top5_acc: 0.9286 - auxiliary_classifier_macro_f1score: 0.2671 - val_loss: 3.4314 - val_main_classifier_loss: 2.4658 - val_auxiliary_classifier_loss: 2.4138 - val_main_classifier_accuracy: 0.4720 - val_main_classifier_top5_acc: 0.7715 - val_main_classifier_macro_f1score: 0.1381 - val_auxiliary_classifier_accuracy: 0.4792 - val_auxiliary_classifier_top5_acc: 0.7995 - val_auxiliary_classifier_macro_f1score: 0.1631
# Learning rate:  0.001
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 21/70
# 194/194 [==============================] - ETA: 0s - loss: 2.5804 - main_classifier_loss: 1.9039 - auxiliary_classifier_loss: 1.6914 - main_classifier_accuracy: 0.6228 - main_classifier_top5_acc: 0.9003 - main_classifier_macro_f1score: 0.2268 - auxiliary_classifier_accuracy: 0.6888 - auxiliary_classifier_top5_acc: 0.9363 - auxiliary_classifier_macro_f1score: 0.2739
# Epoch 00021: val_loss did not improve from 3.43137
#
# Epoch 00021: val_main_classifier_accuracy did not improve from 0.47591
# 194/194 [==============================] - 419s 2s/step - loss: 2.5804 - main_classifier_loss: 1.9039 - auxiliary_classifier_loss: 1.6914 - main_classifier_accuracy: 0.6228 - main_classifier_top5_acc: 0.9003 - main_classifier_macro_f1score: 0.2268 - auxiliary_classifier_accuracy: 0.6888 - auxiliary_classifier_top5_acc: 0.9363 - auxiliary_classifier_macro_f1score: 0.2739 - val_loss: 4.1353 - val_main_classifier_loss: 2.9267 - val_auxiliary_classifier_loss: 3.0214 - val_main_classifier_accuracy: 0.3607 - val_main_classifier_top5_acc: 0.6810 - val_main_classifier_macro_f1score: 0.1035 - val_auxiliary_classifier_accuracy: 0.3490 - val_auxiliary_classifier_top5_acc: 0.6823 - val_auxiliary_classifier_macro_f1score: 0.1153
# Learning rate:  0.001
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 22/70
# 194/194 [==============================] - ETA: 0s - loss: 2.5291 - main_classifier_loss: 1.8684 - auxiliary_classifier_loss: 1.6518 - main_classifier_accuracy: 0.6328 - main_classifier_top5_acc: 0.9045 - main_classifier_macro_f1score: 0.2367 - auxiliary_classifier_accuracy: 0.7055 - auxiliary_classifier_top5_acc: 0.9430 - auxiliary_classifier_macro_f1score: 0.2901
# Epoch 00022: val_loss did not improve from 3.43137
#
# Epoch 00022: val_main_classifier_accuracy did not improve from 0.47591
# 194/194 [==============================] - 411s 2s/step - loss: 2.5291 - main_classifier_loss: 1.8684 - auxiliary_classifier_loss: 1.6518 - main_classifier_accuracy: 0.6328 - main_classifier_top5_acc: 0.9045 - main_classifier_macro_f1score: 0.2367 - auxiliary_classifier_accuracy: 0.7055 - auxiliary_classifier_top5_acc: 0.9430 - auxiliary_classifier_macro_f1score: 0.2901 - val_loss: 3.5702 - val_main_classifier_loss: 2.5750 - val_auxiliary_classifier_loss: 2.4881 - val_main_classifier_accuracy: 0.4329 - val_main_classifier_top5_acc: 0.7428 - val_main_classifier_macro_f1score: 0.1397 - val_auxiliary_classifier_accuracy: 0.4564 - val_auxiliary_classifier_top5_acc: 0.7689 - val_auxiliary_classifier_macro_f1score: 0.1597
# Learning rate:  0.001
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 23/70
# 194/194 [==============================] - ETA: 0s - loss: 2.4896 - main_classifier_loss: 1.8409 - auxiliary_classifier_loss: 1.6216 - main_classifier_accuracy: 0.6475 - main_classifier_top5_acc: 0.9132 - main_classifier_macro_f1score: 0.2400 - auxiliary_classifier_accuracy: 0.7145 - auxiliary_classifier_top5_acc: 0.9486 - auxiliary_classifier_macro_f1score: 0.2938
# Epoch 00023: val_loss did not improve from 3.43137
#
# Epoch 00023: val_main_classifier_accuracy did not improve from 0.47591
# 194/194 [==============================] - 413s 2s/step - loss: 2.4896 - main_classifier_loss: 1.8409 - auxiliary_classifier_loss: 1.6216 - main_classifier_accuracy: 0.6475 - main_classifier_top5_acc: 0.9132 - main_classifier_macro_f1score: 0.2400 - auxiliary_classifier_accuracy: 0.7145 - auxiliary_classifier_top5_acc: 0.9486 - auxiliary_classifier_macro_f1score: 0.2938 - val_loss: 3.6555 - val_main_classifier_loss: 2.6021 - val_auxiliary_classifier_loss: 2.6334 - val_main_classifier_accuracy: 0.4251 - val_main_classifier_top5_acc: 0.7611 - val_main_classifier_macro_f1score: 0.1511 - val_auxiliary_classifier_accuracy: 0.4382 - val_auxiliary_classifier_top5_acc: 0.7708 - val_auxiliary_classifier_macro_f1score: 0.1596
# Learning rate:  0.001
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 24/70
# 194/194 [==============================] - ETA: 0s - loss: 2.4266 - main_classifier_loss: 1.7943 - auxiliary_classifier_loss: 1.5809 - main_classifier_accuracy: 0.6644 - main_classifier_top5_acc: 0.9161 - main_classifier_macro_f1score: 0.2524 - auxiliary_classifier_accuracy: 0.7261 - auxiliary_classifier_top5_acc: 0.9537 - auxiliary_classifier_macro_f1score: 0.3032
# Epoch 00024: val_loss did not improve from 3.43137
#
# Epoch 00024: val_main_classifier_accuracy did not improve from 0.47591
# 194/194 [==============================] - 419s 2s/step - loss: 2.4266 - main_classifier_loss: 1.7943 - auxiliary_classifier_loss: 1.5809 - main_classifier_accuracy: 0.6644 - main_classifier_top5_acc: 0.9161 - main_classifier_macro_f1score: 0.2524 - auxiliary_classifier_accuracy: 0.7261 - auxiliary_classifier_top5_acc: 0.9537 - auxiliary_classifier_macro_f1score: 0.3032 - val_loss: 3.6368 - val_main_classifier_loss: 2.6334 - val_auxiliary_classifier_loss: 2.5085 - val_main_classifier_accuracy: 0.4271 - val_main_classifier_top5_acc: 0.7533 - val_main_classifier_macro_f1score: 0.1306 - val_auxiliary_classifier_accuracy: 0.4642 - val_auxiliary_classifier_top5_acc: 0.7689 - val_auxiliary_classifier_macro_f1score: 0.1574
# Learning rate:  0.001
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 25/70
# 194/194 [==============================] - ETA: 0s - loss: 2.3752 - main_classifier_loss: 1.7590 - auxiliary_classifier_loss: 1.5406 - main_classifier_accuracy: 0.6744 - main_classifier_top5_acc: 0.9251 - main_classifier_macro_f1score: 0.2618 - auxiliary_classifier_accuracy: 0.7437 - auxiliary_classifier_top5_acc: 0.9614 - auxiliary_classifier_macro_f1score: 0.3144
# Epoch 00025: val_loss did not improve from 3.43137
#
# Epoch 00025: val_main_classifier_accuracy did not improve from 0.47591
# 194/194 [==============================] - 419s 2s/step - loss: 2.3752 - main_classifier_loss: 1.7590 - auxiliary_classifier_loss: 1.5406 - main_classifier_accuracy: 0.6744 - main_classifier_top5_acc: 0.9251 - main_classifier_macro_f1score: 0.2618 - auxiliary_classifier_accuracy: 0.7437 - auxiliary_classifier_top5_acc: 0.9614 - auxiliary_classifier_macro_f1score: 0.3144 - val_loss: 4.7284 - val_main_classifier_loss: 3.5327 - val_auxiliary_classifier_loss: 2.9892 - val_main_classifier_accuracy: 0.3053 - val_main_classifier_top5_acc: 0.5879 - val_main_classifier_macro_f1score: 0.0898 - val_auxiliary_classifier_accuracy: 0.3730 - val_auxiliary_classifier_top5_acc: 0.6543 - val_auxiliary_classifier_macro_f1score: 0.1245
# Learning rate:  0.001
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 26/70
# 194/194 [==============================] - ETA: 0s - loss: 2.3049 - main_classifier_loss: 1.7089 - auxiliary_classifier_loss: 1.4900 - main_classifier_accuracy: 0.6955 - main_classifier_top5_acc: 0.9292 - main_classifier_macro_f1score: 0.2762 - auxiliary_classifier_accuracy: 0.7677 - auxiliary_classifier_top5_acc: 0.9632 - auxiliary_classifier_macro_f1score: 0.3302
# Epoch 00026: val_loss did not improve from 3.43137
#
# Epoch 00026: val_main_classifier_accuracy did not improve from 0.47591
# 194/194 [==============================] - 418s 2s/step - loss: 2.3049 - main_classifier_loss: 1.7089 - auxiliary_classifier_loss: 1.4900 - main_classifier_accuracy: 0.6955 - main_classifier_top5_acc: 0.9292 - main_classifier_macro_f1score: 0.2762 - auxiliary_classifier_accuracy: 0.7677 - auxiliary_classifier_top5_acc: 0.9632 - auxiliary_classifier_macro_f1score: 0.3302 - val_loss: 3.9738 - val_main_classifier_loss: 2.8440 - val_auxiliary_classifier_loss: 2.8244 - val_main_classifier_accuracy: 0.3848 - val_main_classifier_top5_acc: 0.7142 - val_main_classifier_macro_f1score: 0.1163 - val_auxiliary_classifier_accuracy: 0.3965 - val_auxiliary_classifier_top5_acc: 0.6999 - val_auxiliary_classifier_macro_f1score: 0.1299
# Learning rate:  0.001
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 27/70
# 194/194 [==============================] - ETA: 0s - loss: 2.2920 - main_classifier_loss: 1.6982 - auxiliary_classifier_loss: 1.4845 - main_classifier_accuracy: 0.6986 - main_classifier_top5_acc: 0.9328 - main_classifier_macro_f1score: 0.2820 - auxiliary_classifier_accuracy: 0.7680 - auxiliary_classifier_top5_acc: 0.9664 - auxiliary_classifier_macro_f1score: 0.3329
# Epoch 00027: val_loss improved from 3.43137 to 3.21941, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/Inception_v3/027.h5
#
# Epoch 00027: val_main_classifier_accuracy improved from 0.47591 to 0.51562, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/Inception_v3/027.h5
# 194/194 [==============================] - 423s 2s/step - loss: 2.2920 - main_classifier_loss: 1.6982 - auxiliary_classifier_loss: 1.4845 - main_classifier_accuracy: 0.6986 - main_classifier_top5_acc: 0.9328 - main_classifier_macro_f1score: 0.2820 - auxiliary_classifier_accuracy: 0.7680 - auxiliary_classifier_top5_acc: 0.9664 - auxiliary_classifier_macro_f1score: 0.3329 - val_loss: 3.2194 - val_main_classifier_loss: 2.3178 - val_auxiliary_classifier_loss: 2.2541 - val_main_classifier_accuracy: 0.5156 - val_main_classifier_top5_acc: 0.8171 - val_main_classifier_macro_f1score: 0.1772 - val_auxiliary_classifier_accuracy: 0.5319 - val_auxiliary_classifier_top5_acc: 0.8190 - val_auxiliary_classifier_macro_f1score: 0.1973
# Learning rate:  0.001
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 28/70
# 194/194 [==============================] - ETA: 0s - loss: 2.2121 - main_classifier_loss: 1.6396 - auxiliary_classifier_loss: 1.4313 - main_classifier_accuracy: 0.7141 - main_classifier_top5_acc: 0.9402 - main_classifier_macro_f1score: 0.2906 - auxiliary_classifier_accuracy: 0.7896 - auxiliary_classifier_top5_acc: 0.9702 - auxiliary_classifier_macro_f1score: 0.3462
# Epoch 00028: val_loss did not improve from 3.21941
#
# Epoch 00028: val_main_classifier_accuracy did not improve from 0.51562
# 194/194 [==============================] - 422s 2s/step - loss: 2.2121 - main_classifier_loss: 1.6396 - auxiliary_classifier_loss: 1.4313 - main_classifier_accuracy: 0.7141 - main_classifier_top5_acc: 0.9402 - main_classifier_macro_f1score: 0.2906 - auxiliary_classifier_accuracy: 0.7896 - auxiliary_classifier_top5_acc: 0.9702 - auxiliary_classifier_macro_f1score: 0.3462 - val_loss: 3.6024 - val_main_classifier_loss: 2.5808 - val_auxiliary_classifier_loss: 2.5541 - val_main_classifier_accuracy: 0.4557 - val_main_classifier_top5_acc: 0.7493 - val_main_classifier_macro_f1score: 0.1487 - val_auxiliary_classifier_accuracy: 0.4629 - val_auxiliary_classifier_top5_acc: 0.7546 - val_auxiliary_classifier_macro_f1score: 0.1616
# Learning rate:  0.001
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 29/70
# ...
# Learning rate:  0.0001
#
# Epoch 00060: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 60/70
# 194/194 [==============================] - ETA: 0s - loss: 1.2781 - main_classifier_loss: 0.9172 - auxiliary_classifier_loss: 0.9024 - main_classifier_accuracy: 0.9790 - main_classifier_top5_acc: 0.9998 - main_classifier_macro_f1score: 0.5156 - auxiliary_classifier_accuracy: 0.9849 - auxiliary_classifier_top5_acc: 1.0000 - auxiliary_classifier_macro_f1score: 0.5162
# Epoch 00060: val_loss did not improve from 2.76987
#
# Epoch 00060: val_main_classifier_accuracy did not improve from 0.61719
# 194/194 [==============================] - 419s 2s/step - loss: 1.2781 - main_classifier_loss: 0.9172 - auxiliary_classifier_loss: 0.9024 - main_classifier_accuracy: 0.9790 - main_classifier_top5_acc: 0.9998 - main_classifier_macro_f1score: 0.5156 - auxiliary_classifier_accuracy: 0.9849 - auxiliary_classifier_top5_acc: 1.0000 - auxiliary_classifier_macro_f1score: 0.5162 - val_loss: 2.9136 - val_main_classifier_loss: 2.1001 - val_auxiliary_classifier_loss: 2.0337 - val_main_classifier_accuracy: 0.5970 - val_main_classifier_top5_acc: 0.8372 - val_main_classifier_macro_f1score: 0.2456 - val_auxiliary_classifier_accuracy: 0.6048 - val_auxiliary_classifier_top5_acc: 0.8516 - val_auxiliary_classifier_macro_f1score: 0.2436
# Learning rate:  1e-05
#
# Epoch 00061: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 61/70
# 194/194 [==============================] - ETA: 0s - loss: 1.2249 - main_classifier_loss: 0.8765 - auxiliary_classifier_loss: 0.8709 - main_classifier_accuracy: 0.9902 - main_classifier_top5_acc: 0.9998 - main_classifier_macro_f1score: 0.5291 - auxiliary_classifier_accuracy: 0.9921 - auxiliary_classifier_top5_acc: 0.9999 - auxiliary_classifier_macro_f1score: 0.5262
# Epoch 00061: val_loss improved from 2.76987 to 2.73316, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/Inception_v3/061.h5
#
# Epoch 00061: val_main_classifier_accuracy improved from 0.61719 to 0.63021, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/Inception_v3/061.h5
# 194/194 [==============================] - 423s 2s/step - loss: 1.2249 - main_classifier_loss: 0.8765 - auxiliary_classifier_loss: 0.8709 - main_classifier_accuracy: 0.9902 - main_classifier_top5_acc: 0.9998 - main_classifier_macro_f1score: 0.5291 - auxiliary_classifier_accuracy: 0.9921 - auxiliary_classifier_top5_acc: 0.9999 - auxiliary_classifier_macro_f1score: 0.5262 - val_loss: 2.7332 - val_main_classifier_loss: 1.9674 - val_auxiliary_classifier_loss: 1.9144 - val_main_classifier_accuracy: 0.6302 - val_main_classifier_top5_acc: 0.8555 - val_main_classifier_macro_f1score: 0.2650 - val_auxiliary_classifier_accuracy: 0.6302 - val_auxiliary_classifier_top5_acc: 0.8698 - val_auxiliary_classifier_macro_f1score: 0.2600
# Learning rate:  1e-05
#
# Epoch 00062: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 62/70
# 194/194 [==============================] - ETA: 0s - loss: 1.2054 - main_classifier_loss: 0.8599 - auxiliary_classifier_loss: 0.8639 - main_classifier_accuracy: 0.9944 - main_classifier_top5_acc: 0.9998 - main_classifier_macro_f1score: 0.5285 - auxiliary_classifier_accuracy: 0.9927 - auxiliary_classifier_top5_acc: 1.0000 - auxiliary_classifier_macro_f1score: 0.5228
# Epoch 00062: val_loss did not improve from 2.73316
#
# Epoch 00062: val_main_classifier_accuracy did not improve from 0.63021
# 194/194 [==============================] - 420s 2s/step - loss: 1.2054 - main_classifier_loss: 0.8599 - auxiliary_classifier_loss: 0.8639 - main_classifier_accuracy: 0.9944 - main_classifier_top5_acc: 0.9998 - main_classifier_macro_f1score: 0.5285 - auxiliary_classifier_accuracy: 0.9927 - auxiliary_classifier_top5_acc: 1.0000 - auxiliary_classifier_macro_f1score: 0.5228 - val_loss: 2.7520 - val_main_classifier_loss: 1.9818 - val_auxiliary_classifier_loss: 1.9254 - val_main_classifier_accuracy: 0.6217 - val_main_classifier_top5_acc: 0.8581 - val_main_classifier_macro_f1score: 0.2532 - val_auxiliary_classifier_accuracy: 0.6309 - val_auxiliary_classifier_top5_acc: 0.8652 - val_auxiliary_classifier_macro_f1score: 0.2470
# Learning rate:  1e-05
#
# Epoch 00063: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 63/70
# 194/194 [==============================] - ETA: 0s - loss: 1.1986 - main_classifier_loss: 0.8545 - auxiliary_classifier_loss: 0.8603 - main_classifier_accuracy: 0.9946 - main_classifier_top5_acc: 1.0000 - main_classifier_macro_f1score: 0.5326 - auxiliary_classifier_accuracy: 0.9952 - auxiliary_classifier_top5_acc: 1.0000 - auxiliary_classifier_macro_f1score: 0.5259
# Epoch 00063: val_loss improved from 2.73316 to 2.73138, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/Inception_v3/063.h5
#
# Epoch 00063: val_main_classifier_accuracy did not improve from 0.63021
# 194/194 [==============================] - 420s 2s/step - loss: 1.1986 - main_classifier_loss: 0.8545 - auxiliary_classifier_loss: 0.8603 - main_classifier_accuracy: 0.9946 - main_classifier_top5_acc: 1.0000 - main_classifier_macro_f1score: 0.5326 - auxiliary_classifier_accuracy: 0.9952 - auxiliary_classifier_top5_acc: 1.0000 - auxiliary_classifier_macro_f1score: 0.5259 - val_loss: 2.7314 - val_main_classifier_loss: 1.9659 - val_auxiliary_classifier_loss: 1.9137 - val_main_classifier_accuracy: 0.6283 - val_main_classifier_top5_acc: 0.8548 - val_main_classifier_macro_f1score: 0.2600 - val_auxiliary_classifier_accuracy: 0.6380 - val_auxiliary_classifier_top5_acc: 0.8711 - val_auxiliary_classifier_macro_f1score: 0.2494
# Learning rate:  1e-05
#
# Epoch 00064: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 64/70
# 194/194 [==============================] - ETA: 0s - loss: 1.1957 - main_classifier_loss: 0.8512 - auxiliary_classifier_loss: 0.8611 - main_classifier_accuracy: 0.9950 - main_classifier_top5_acc: 1.0000 - main_classifier_macro_f1score: 0.5314 - auxiliary_classifier_accuracy: 0.9937 - auxiliary_classifier_top5_acc: 1.0000 - auxiliary_classifier_macro_f1score: 0.5235
# Epoch 00064: val_loss did not improve from 2.73138
#
# Epoch 00064: val_main_classifier_accuracy improved from 0.63021 to 0.63281, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/Inception_v3/064.h5
# 194/194 [==============================] - 421s 2s/step - loss: 1.1957 - main_classifier_loss: 0.8512 - auxiliary_classifier_loss: 0.8611 - main_classifier_accuracy: 0.9950 - main_classifier_top5_acc: 1.0000 - main_classifier_macro_f1score: 0.5314 - auxiliary_classifier_accuracy: 0.9937 - auxiliary_classifier_top5_acc: 1.0000 - auxiliary_classifier_macro_f1score: 0.5235 - val_loss: 2.7378 - val_main_classifier_loss: 1.9700 - val_auxiliary_classifier_loss: 1.9196 - val_main_classifier_accuracy: 0.6328 - val_main_classifier_top5_acc: 0.8535 - val_main_classifier_macro_f1score: 0.2637 - val_auxiliary_classifier_accuracy: 0.6374 - val_auxiliary_classifier_top5_acc: 0.8704 - val_auxiliary_classifier_macro_f1score: 0.2470
# Learning rate:  1e-05
#
# Epoch 00065: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 65/70
# 194/194 [==============================] - ETA: 0s - loss: 1.1951 - main_classifier_loss: 0.8502 - auxiliary_classifier_loss: 0.8623 - main_classifier_accuracy: 0.9946 - main_classifier_top5_acc: 0.9999 - main_classifier_macro_f1score: 0.5381 - auxiliary_classifier_accuracy: 0.9936 - auxiliary_classifier_top5_acc: 1.0000 - auxiliary_classifier_macro_f1score: 0.5283
# Epoch 00065: val_loss improved from 2.73138 to 2.71259, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/Inception_v3/065.h5
#
# Epoch 00065: val_main_classifier_accuracy improved from 0.63281 to 0.63997, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/Inception_v3/065.h5
# 194/194 [==============================] - 427s 2s/step - loss: 1.1951 - main_classifier_loss: 0.8502 - auxiliary_classifier_loss: 0.8623 - main_classifier_accuracy: 0.9946 - main_classifier_top5_acc: 0.9999 - main_classifier_macro_f1score: 0.5381 - auxiliary_classifier_accuracy: 0.9936 - auxiliary_classifier_top5_acc: 1.0000 - auxiliary_classifier_macro_f1score: 0.5283 - val_loss: 2.7126 - val_main_classifier_loss: 1.9525 - val_auxiliary_classifier_loss: 1.9003 - val_main_classifier_accuracy: 0.6400 - val_main_classifier_top5_acc: 0.8620 - val_main_classifier_macro_f1score: 0.2667 - val_auxiliary_classifier_accuracy: 0.6452 - val_auxiliary_classifier_top5_acc: 0.8717 - val_auxiliary_classifier_macro_f1score: 0.2536
# Learning rate:  1e-05
#
# Epoch 00066: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 66/70
# 194/194 [==============================] - ETA: 0s - loss: 1.1917 - main_classifier_loss: 0.8472 - auxiliary_classifier_loss: 0.8612 - main_classifier_accuracy: 0.9965 - main_classifier_top5_acc: 1.0000 - main_classifier_macro_f1score: 0.5333 - auxiliary_classifier_accuracy: 0.9954 - auxiliary_classifier_top5_acc: 1.0000 - auxiliary_classifier_macro_f1score: 0.5247
# Epoch 00066: val_loss did not improve from 2.71259
#
# Epoch 00066: val_main_classifier_accuracy did not improve from 0.63997
# 194/194 [==============================] - 420s 2s/step - loss: 1.1917 - main_classifier_loss: 0.8472 - auxiliary_classifier_loss: 0.8612 - main_classifier_accuracy: 0.9965 - main_classifier_top5_acc: 1.0000 - main_classifier_macro_f1score: 0.5333 - auxiliary_classifier_accuracy: 0.9954 - auxiliary_classifier_top5_acc: 1.0000 - auxiliary_classifier_macro_f1score: 0.5247 - val_loss: 2.7347 - val_main_classifier_loss: 1.9691 - val_auxiliary_classifier_loss: 1.9141 - val_main_classifier_accuracy: 0.6322 - val_main_classifier_top5_acc: 0.8574 - val_main_classifier_macro_f1score: 0.2531 - val_auxiliary_classifier_accuracy: 0.6348 - val_auxiliary_classifier_top5_acc: 0.8704 - val_auxiliary_classifier_macro_f1score: 0.2411
# Learning rate:  1e-05
#
# Epoch 00067: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 67/70
# 194/194 [==============================] - ETA: 0s - loss: 1.1887 - main_classifier_loss: 0.8438 - auxiliary_classifier_loss: 0.8622 - main_classifier_accuracy: 0.9970 - main_classifier_top5_acc: 1.0000 - main_classifier_macro_f1score: 0.5358 - auxiliary_classifier_accuracy: 0.9951 - auxiliary_classifier_top5_acc: 1.0000 - auxiliary_classifier_macro_f1score: 0.5252
# Epoch 00067: val_loss did not improve from 2.71259
#
# Epoch 00067: val_main_classifier_accuracy did not improve from 0.63997
# 194/194 [==============================] - 420s 2s/step - loss: 1.1887 - main_classifier_loss: 0.8438 - auxiliary_classifier_loss: 0.8622 - main_classifier_accuracy: 0.9970 - main_classifier_top5_acc: 1.0000 - main_classifier_macro_f1score: 0.5358 - auxiliary_classifier_accuracy: 0.9951 - auxiliary_classifier_top5_acc: 1.0000 - auxiliary_classifier_macro_f1score: 0.5252 - val_loss: 2.7338 - val_main_classifier_loss: 1.9693 - val_auxiliary_classifier_loss: 1.9114 - val_main_classifier_accuracy: 0.6302 - val_main_classifier_top5_acc: 0.8548 - val_main_classifier_macro_f1score: 0.2714 - val_auxiliary_classifier_accuracy: 0.6335 - val_auxiliary_classifier_top5_acc: 0.8704 - val_auxiliary_classifier_macro_f1score: 0.2532
# Learning rate:  1e-05
#
# Epoch 00068: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 68/70
# 194/194 [==============================] - ETA: 0s - loss: 1.1871 - main_classifier_loss: 0.8413 - auxiliary_classifier_loss: 0.8643 - main_classifier_accuracy: 0.9956 - main_classifier_top5_acc: 0.9998 - main_classifier_macro_f1score: 0.5373 - auxiliary_classifier_accuracy: 0.9953 - auxiliary_classifier_top5_acc: 1.0000 - auxiliary_classifier_macro_f1score: 0.5229
# Epoch 00068: val_loss did not improve from 2.71259
#
# Epoch 00068: val_main_classifier_accuracy improved from 0.63997 to 0.64128, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/Inception_v3/068.h5
# 194/194 [==============================] - 422s 2s/step - loss: 1.1871 - main_classifier_loss: 0.8413 - auxiliary_classifier_loss: 0.8643 - main_classifier_accuracy: 0.9956 - main_classifier_top5_acc: 0.9998 - main_classifier_macro_f1score: 0.5373 - auxiliary_classifier_accuracy: 0.9953 - auxiliary_classifier_top5_acc: 1.0000 - auxiliary_classifier_macro_f1score: 0.5229 - val_loss: 2.7269 - val_main_classifier_loss: 1.9615 - val_auxiliary_classifier_loss: 1.9134 - val_main_classifier_accuracy: 0.6413 - val_main_classifier_top5_acc: 0.8535 - val_main_classifier_macro_f1score: 0.2543 - val_auxiliary_classifier_accuracy: 0.6387 - val_auxiliary_classifier_top5_acc: 0.8672 - val_auxiliary_classifier_macro_f1score: 0.2422
# Learning rate:  1e-05
#
# Epoch 00069: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 69/70
# 194/194 [==============================] - ETA: 0s - loss: 1.1873 - main_classifier_loss: 0.8412 - auxiliary_classifier_loss: 0.8653 - main_classifier_accuracy: 0.9954 - main_classifier_top5_acc: 0.9998 - main_classifier_macro_f1score: 0.5398 - auxiliary_classifier_accuracy: 0.9950 - auxiliary_classifier_top5_acc: 1.0000 - auxiliary_classifier_macro_f1score: 0.5258
# Epoch 00069: val_loss did not improve from 2.71259
#
# Epoch 00069: val_main_classifier_accuracy did not improve from 0.64128
# 194/194 [==============================] - 419s 2s/step - loss: 1.1873 - main_classifier_loss: 0.8412 - auxiliary_classifier_loss: 0.8653 - main_classifier_accuracy: 0.9954 - main_classifier_top5_acc: 0.9998 - main_classifier_macro_f1score: 0.5398 - auxiliary_classifier_accuracy: 0.9950 - auxiliary_classifier_top5_acc: 1.0000 - auxiliary_classifier_macro_f1score: 0.5258 - val_loss: 2.7252 - val_main_classifier_loss: 1.9619 - val_auxiliary_classifier_loss: 1.9082 - val_main_classifier_accuracy: 0.6361 - val_main_classifier_top5_acc: 0.8555 - val_main_classifier_macro_f1score: 0.2597 - val_auxiliary_classifier_accuracy: 0.6393 - val_auxiliary_classifier_top5_acc: 0.8717 - val_auxiliary_classifier_macro_f1score: 0.2463
# Learning rate:  1e-05
#
# Epoch 00070: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 70/70
# 194/194 [==============================] - ETA: 0s - loss: 1.1898 - main_classifier_loss: 0.8423 - auxiliary_classifier_loss: 0.8688 - main_classifier_accuracy: 0.9952 - main_classifier_top5_acc: 0.9998 - main_classifier_macro_f1score: 0.5308 - auxiliary_classifier_accuracy: 0.9940 - auxiliary_classifier_top5_acc: 1.0000 - auxiliary_classifier_macro_f1score: 0.5167
# Epoch 00070: val_loss did not improve from 2.71259
#
# Epoch 00070: val_main_classifier_accuracy did not improve from 0.64128
# 194/194 [==============================] - 420s 2s/step - loss: 1.1898 - main_classifier_loss: 0.8423 - auxiliary_classifier_loss: 0.8688 - main_classifier_accuracy: 0.9952 - main_classifier_top5_acc: 0.9998 - main_classifier_macro_f1score: 0.5308 - auxiliary_classifier_accuracy: 0.9940 - auxiliary_classifier_top5_acc: 1.0000 - auxiliary_classifier_macro_f1score: 0.5167 - val_loss: 2.7216 - val_main_classifier_loss: 1.9595 - val_auxiliary_classifier_loss: 1.9052 - val_main_classifier_accuracy: 0.6322 - val_main_classifier_top5_acc: 0.8600 - val_main_classifier_macro_f1score: 0.2538 - val_auxiliary_classifier_accuracy: 0.6367 - val_auxiliary_classifier_top5_acc: 0.8730 - val_auxiliary_classifier_macro_f1score: 0.2405

# %% [markdown]
# ### 3) Inception-V3 Evaluate

# %%
# 1. epoch=maximum
#var = model.evaluate_generator(generate_test_for_three(),steps=int(len(x_test)/batch_sizes))
var = model.evaluate(generate_test_for_two(),steps=int(len(x_test)/batch_sizes))
print('[Test Loss: %.4f /   Test Top-1 Accuracy: %.4f / Test Top-5 Accuracy: %.4f / Test Macro f1: %.4f]\n' % (var[0],var[-3],var[-2],var[-1]))
# Out:
# Found 1590 images belonging to 67 classes.
# 24/24 [==============================] - 273s 11s/step - loss: 2.7387 - main_classifier_loss: 1.9711 - auxiliary_classifier_loss: 1.9189 - main_classifier_accuracy: 0.6243 - main_classifier_top5_acc: 0.8672 - main_classifier_macro_f1score: 0.2557 - auxiliary_classifier_accuracy: 0.6328 - auxiliary_classifier_top5_acc: 0.8724 - auxiliary_classifier_macro_f1score: 0.2364
# [Test Loss: 2.7387 /   Test Top-1 Accuracy: 0.6328 / Test Top-5 Accuracy: 0.8724 / Test Macro f1: 0.2364]

# %%
loss=history.history['loss']
val_loss=history.history['val_loss']
acc=history.history['main_classifier_accuracy']
val_acc=history.history['val_main_classifier_accuracy']
top5_acc=history.history['main_classifier_top5_acc']
val_top5_acc=history.history['val_main_classifier_top5_acc']
f1=history.history['main_classifier_macro_f1score']
val_f1=history.history['val_main_classifier_macro_f1score']
epochs=range(1,len(acc)+1)

data = np.array([epochs,loss,val_loss,acc,val_acc,top5_acc,val_top5_acc,f1,val_f1]).T

# %%
# data save
# epochs, loss, val_loss, acc, val_acc, top5_acc, val_top5_acc, f1, val_f1

np.savetxt(os.path.join(dir,'train_valid_output',number,model.name+'.txt'),data)

# %%
# data import
data = np.loadtxt(os.path.join(dir,'train_valid_output',number,'Inception_v3.txt'))

# %%
epochs=data[:,0]
loss=data[:,1]
val_loss=data[:,2]
acc=data[:,3]
val_acc=data[:,4]
top5_acc=data[:,5]
val_top5_acc=data[:,6]

# %%
plt.plot(epochs[1:],acc[1:],'b',label='Training 1-Acc')
plt.plot(epochs[1:],val_acc[1:],'r',label='Validation 1-Acc')
plt.title('Training and Validation Top-1 Accuracy')
plt.legend()
plt.figure()

plt.plot(epochs[1:],top5_acc[1:],'b',label='Training 5-Acc')
plt.plot(epochs[1:],val_top5_acc[1:],'r',label='Validation 5-Acc')
plt.title('Training and Validation Top-5 Accuracy')
plt.legend()
plt.figure()

plt.plot(epochs[10:],loss[10:],'b',label='Training Loss')
plt.plot(epochs[10:],val_loss[10:],'r',label='Validation Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()

# %%
# 이 아래는 내가 인위적으로 살펴보고 싶은 epoch에 대해서 결과값 출력 / Inception-V3

# %%
# 참고 : https://github.com/OverLordGoldDragon/keras-adamw

import sys
sys.path.append('/content/drive/My Drive/Colab Notebooks/Paper')
import utils
import optimizers_v2
from utils import get_weight_decays, fill_dict_in_order
from utils import reset_seeds, K_eval
from optimizers_v2 import AdamW, NadamW, SGDW

# %%
# top-5 accuracy 출력
import functools
top5_acc = functools.partial(ks.metrics.top_k_categorical_accuracy, k=5)
top5_acc.__name__ = 'top5_acc'

# %%
model=load_model(os.path.join(dir,'model_output',number,'Inception_v3','068.h5'),
                 custom_objects={"macro_f1score": macro_f1score, "top5_acc":top5_acc, "smoothed_categorical_crossentropy":smoothed_categorical_crossentropy, "AdamW":AdamW})

# %%
# 2. epoch=?
smoothing_param = 0.1
var = model.evaluate(generate_test_for_two(),steps=int(len(x_test)/batch_sizes))
# Out:
# Found 1590 images belonging to 67 classes.
# 24/24 [==============================] - 701s 29s/step - loss: 9.9196 - main_classifier_loss: 7.1563 - auxiliary_classifier_loss: 6.9081 - main_classifier_accuracy: 0.6198 - main_classifier_top5_acc: 0.8678 - main_classifier_macro_f1score: 0.2566 - auxiliary_classifier_accuracy: 0.6204 - auxiliary_classifier_top5_acc: 0.8698 - auxiliary_classifier_macro_f1score: 0.2407

# %%
print('[Test Loss: %.4f /  Test Top-1 Accuracy: %.4f / Test Top-5 Accuracy: %.4f / Test Macro f1: %.4f]\n' % (var[0],var[-3],var[-2],var[-1]))
# Out:
# [Test Loss: 9.9196 /  Test Top-1 Accuracy: 0.6204 / Test Top-5 Accuracy: 0.8698 / Test Macro f1: 0.2407]
