# %%
#모형 출처 : https://github.com/titu1994/keras-squeeze-excite-network

# %% [markdown]
# # [SE-DenseNet121]

# %% [markdown]
# *KU LeeDongGyu*

# %% [markdown]
# ## Contents
# ---

# %% [markdown]
# 1. Data Preprocessing
# ```
# 1) Data Import
# 2) Data Augmentation
# ```
# 2. Support Functions & Almost Original SE-DenseNet121
# ```
# 1) Support Functions
# 2) Almost orginal SE-DenseNet121
# ```
# 3. SE-DenseNet121
# ```
# 1) SE-DenseNet121
# 2) SE-DenseNet121 Evaluate
# ```

# %% [markdown]
# ### Install Packages

# %% [markdown]
# ### Module

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/My Drive/Colab Notebooks/Paper
# Out:
# /content/drive/My Drive/Colab Notebooks/Paper

# %%
from f1score import macro_f1score,weighted_f1score

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import cv2
import tensorflow as tf
from tensorflow import keras as ks
from tensorflow.keras import backend as K 
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, Input, Concatenate, ZeroPadding2D ,GlobalMaxPooling2D, Reshape , Lambda , Add, Multiply
from tensorflow.keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D, Activation, BatchNormalization, AveragePooling2D , ZeroPadding2D, SeparableConv2D , LeakyReLU
from tensorflow.keras.layers import add, concatenate, multiply
from tensorflow.keras.optimizers import Adam, RMSprop , SGD
from tensorflow.keras.callbacks import EarlyStopping , LearningRateScheduler, ModelCheckpoint, CSVLogger, Callback, ReduceLROnPlateau
from tensorflow.keras.regularizers import l1,l2,l1_l2
from tensorflow.keras.models import Model , load_model , Sequential
from tensorflow.keras.utils import plot_model , to_categorical, get_file
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
os.getcwd()
# Out:
# '/content/drive/My Drive/Colab Notebooks/Paper'

# %%
tf.__version__
# Out:
# '2.3.0'

# %%
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 8740317812593642690
# , name: "/device:XLA_CPU:0"
# device_type: "XLA_CPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 1687613811853869474
# physical_device_desc: "device: XLA_CPU device"
# , name: "/device:XLA_GPU:0"
# device_type: "XLA_GPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 14604841470378455312
# physical_device_desc: "device: XLA_GPU device"
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 15695549568
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 5444308038945668250
# physical_device_desc: "device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0"
# ]

# %%
# !cat /proc/cpuinfo
# Out:
# processor	: 0
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 79
# model name	: Intel(R) Xeon(R) CPU @ 2.20GHz
# stepping	: 0
# microcode	: 0x1
# cpu MHz		: 2200.000
# cache size	: 56320 KB
# physical id	: 0
# siblings	: 4
# core id		: 0
# cpu cores	: 2
# apicid		: 0
# initial apicid	: 0
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm rdseed adx smap xsaveopt arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs taa
# bogomips	: 4400.00
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 46 bits physical, 48 bits virtual
# power management:
#
# processor	: 1
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 79
# model name	: Intel(R) Xeon(R) CPU @ 2.20GHz
# stepping	: 0
# microcode	: 0x1
# cpu MHz		: 2200.000
# cache size	: 56320 KB
# physical id	: 0
# siblings	: 4
# core id		: 1
# cpu cores	: 2
# apicid		: 2
# initial apicid	: 2
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm rdseed adx smap xsaveopt arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs taa
# bogomips	: 4400.00
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 46 bits physical, 48 bits virtual
# power management:
#
# processor	: 2
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 79
# model name	: Intel(R) Xeon(R) CPU @ 2.20GHz
# stepping	: 0
# microcode	: 0x1
# cpu MHz		: 2200.000
# cache size	: 56320 KB
# physical id	: 0
# siblings	: 4
# core id		: 0
# cpu cores	: 2
# apicid		: 1
# initial apicid	: 1
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm rdseed adx smap xsaveopt arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs taa
# bogomips	: 4400.00
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 46 bits physical, 48 bits virtual
# power management:
#
# processor	: 3
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 79
# model name	: Intel(R) Xeon(R) CPU @ 2.20GHz
# stepping	: 0
# microcode	: 0x1
# cpu MHz		: 2200.000
# cache size	: 56320 KB
# physical id	: 0
# siblings	: 4
# core id		: 1
# cpu cores	: 2
# apicid		: 3
# initial apicid	: 3
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm rdseed adx smap xsaveopt arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs taa
# bogomips	: 4400.00
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 46 bits physical, 48 bits virtual
# power management:

# %% [markdown]
# ## 1. Data Preprocessing
# ---

# %% [markdown]
# ### 1) Data Import

# %%
# 바꿔서 살펴 볼 것들
# CALTECH, CIFAR100, FER, MIT
data_name = 'MIT'
gan_type = 'No_GAN'
number = '1'
size = 224 # sizes after cropping
super_size = 256 # sizes before cropping 
input_sizes = (size,size,3)
batch_sizes = 64
weight_decay = 1e-3
epochs = 70

# %%
# 참고 : https://stackoverflow.com/questions/32419510/how-to-get-reproducible-results-in-keras/52897216#52897216
# setting the seed number for random number generation for reproducibility.

from numpy.random import seed
import random


if number=='1':
    seed_num = 200225
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)
elif number=='2':
    seed_num = 727
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)
elif number=='3':
    seed_num = 115
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)
elif number=='4':
    seed_num = 501
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)
elif number=='5':
    seed_num = 517
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)

# %%
# data import

if data_name=='FER' :
    x_train =  np.zeros(28698)
    x_valid = np.zeros(3589)
    x_test = np.zeros(3588)
    classes = 7 
    tr_center = [0.50793296, 0.50793296, 0.50793296]
elif data_name=='MIT':
    x_train = np.zeros(12466)
    x_valid = np.zeros(1564)
    x_test = np.zeros(1590)
    classes = 67 
    tr_center = [0.47916578, 0.42029615, 0.36046057]
elif data_name=='CALTECH':
    x_train = np.zeros(24510)
    x_valid = np.zeros(2980)
    x_test = np.zeros(3118)
    classes = 257
    tr_center = [0.51397761, 0.49525248, 0.46555727]
elif data_name=='CIFAR100':
    x_train = np.zeros(44923)
    x_valid = np.zeros(5077)
    x_test = np.zeros(10000)
    classes = 100
    tr_center = [0.53442983, 0.51355958, 0.46462564]

# %%
dir = os.path.join(os.getcwd(),data_name,gan_type)

# %% [markdown]
# ### 2) Data Augmentation

# %%
# 참고 : https://jkjung-avt.github.io/keras-image-cropping/

def random_crop(img, random_crop_size):
    # Note: image_data_format is 'channel_last'
    assert img.shape[2] == 3 # img.shape[2] 가 3(rgb)이 아니면 assertion error 발생
    height, width = img.shape[0], img.shape[1]
    dy, dx = random_crop_size
    x = np.random.randint(0, width - dx + 1)
    y = np.random.randint(0, height - dy + 1)
    return img[y:(y+dy), x:(x+dx), :]


def crop_generator(batches, crop_length):
    """Take as input a Keras ImageGen (Iterator) and generate random
    crops from the image batches generated by the original iterator.
    """
    while True:
        batch_x, batch_y = next(batches)
        batch_crops = np.zeros((batch_x.shape[0], crop_length, crop_length, 3))
        for i in range(batch_x.shape[0]):
            batch_crops[i] = random_crop(batch_x[i], (crop_length, crop_length))
        yield (batch_crops, batch_y)

# %%
from tensorflow.keras.preprocessing.image import img_to_array,load_img
import glob

# 데이터 전체에 대해 centering 진행함.

def read_cal_image(img_path): 
    x = img_to_array(load_img(img_path)) # x는 채널별 평균값
    y = x.shape[0] * x.shape[1]# y는 데이터별 픽셀 수 (비중)

    x = 1/255. * x # scaling하고, centering값을 뽑아냄.
    x = np.mean(x, axis=(0,1))
    
    return np.hstack([x,y])

def calculate_centered_mean(dataset_path,x_train=x_train):
    num = len(x_train)
    space = np.empty((num,4))
    i=0

    for p in glob.glob(os.path.join(dataset_path,'*/*.*')) :
        space[i] = read_cal_image(p)
        i += 1

    ratio = space[:,3] / np.sum(space[:,3])

    return np.average(space[:,0:3],axis=0,weights=ratio)


# 아래의 함수를 돌려서 나온 결과값을 중심화 값으로 설정.

# train_mean = calculate_centered_mean(os.path.join(dir,'data/train')).reshape((1,1,3))

# %%
datagen_tr = ImageDataGenerator(
    rescale=1/255.,
    horizontal_flip=True,
    featurewise_center=True,
    featurewise_std_normalization=False,
    rotation_range=10,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=[0.9,1.0],
    fill_mode = 'nearest')
datagen_val = ImageDataGenerator(rescale=1/255.,featurewise_center=True)
datagen_tes = ImageDataGenerator(rescale=1/255.,featurewise_center=True)

# 원래는 이 자리에 fit 매서드를 써야하지만, 그냥 내가 중심화함수를 만들고 적용함. 

# 중심화 설정
datagen_tr.mean = np.array(tr_center, dtype=np.float32).reshape((1,1,3)) # RGB
datagen_val.mean = np.array(tr_center, dtype=np.float32).reshape((1,1,3)) # RGB
datagen_tes.mean = np.array(tr_center, dtype=np.float32).reshape((1,1,3)) # RGB

# %%
train_batches = datagen_tr.flow_from_directory(directory=os.path.join(dir,'data/train'),target_size=(super_size,super_size),batch_size=batch_sizes,class_mode='categorical') # fer : 28698 / mit : 12466 / caltech : 24509 / cifar : 44923
train_generator= crop_generator(train_batches, size)
valid_generator = datagen_val.flow_from_directory(directory=os.path.join(dir,'data/valid'),target_size=(size,size),batch_size=batch_sizes,class_mode='categorical') # fer : 3589 / mit : 1564 / caltech : 2980 / cifar : 5077
test_generator = datagen_tes.flow_from_directory(directory=os.path.join(dir,'data/test'),target_size=(size,size),batch_size=batch_sizes,class_mode='categorical') # fer : 3588 / mit : 1590 / caltech : 3118 / cifar : 10000
# Out:
# Found 12466 images belonging to 67 classes.
# Found 1564 images belonging to 67 classes.
# Found 1590 images belonging to 67 classes.

# %% [markdown]
# ## 2. Support Functions & Almost Original SE-DenseNet121
# ---

# %% [markdown]
# ### 1) Support Functions

# %%
# def lr_schedule(epoch):
#     init_lr = 1e-4
#     k = 0.04
#     lr = init_lr * np.exp(-k*epoch)
#     print('Learning rate: ', lr)
#     return lr

def lr_schedule(epoch):
    lr = 1e-3
    if epoch < 30:
        lr = lr
    elif epoch < 60:
        lr = lr * 0.1
    else:
        lr = lr * 0.01
    print('Learning rate: ', lr)
    return lr

# %%
def squeeze_excite_block(input, reduction_ratio=16, weight_decay=weight_decay):

    init = input
    channel_axis = -1
    filters = init.get_shape()[channel_axis]
    se_shape = (1, 1, filters)

    se = GlobalAveragePooling2D()(init)
    se = Reshape(se_shape)(se)
    se = Dense(filters // reduction_ratio, activation='relu', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay), use_bias=False)(se)
    se = Dense(filters, activation='sigmoid', kernel_regularizer=l2(weight_decay), use_bias=False)(se)

    x = multiply([init, se])
    return x

# %%
def __conv_block(ip, nb_filter, bottleneck=False, dropout_rate=None, weight_decay=weight_decay):

    concat_axis = -1

    x = BatchNormalization(axis=concat_axis, epsilon=1.1e-5)(ip)
    x = Activation('relu')(x)

    if bottleneck:
        inter_channel = nb_filter * 4  # Obtained from https://github.com/liuzhuang13/DenseNet/blob/master/densenet.lua

        x = Conv2D(inter_channel, (1, 1), kernel_initializer='he_uniform', padding='same', use_bias=False,
                   kernel_regularizer=l2(weight_decay))(x)
        x = BatchNormalization(axis=concat_axis, epsilon=1.1e-5)(x)
        x = Activation('relu')(x)

    x = Conv2D(nb_filter, (3, 3), kernel_initializer='he_uniform', padding='same', use_bias=False, kernel_regularizer=l2(weight_decay))(x)
    if dropout_rate:
        x = Dropout(dropout_rate)(x)

    return x

# %%
def __dense_block(x, nb_layers, nb_filter, growth_rate, bottleneck=False, dropout_rate=None, weight_decay=weight_decay,
                  grow_nb_filters=True, return_concat_list=False):

    concat_axis = -1

    x_list = [x]

    for i in range(nb_layers):
        cb = __conv_block(x, growth_rate, bottleneck, dropout_rate, weight_decay)
        x_list.append(cb)

        x = concatenate([x, cb], axis=concat_axis)

        if grow_nb_filters:
            nb_filter += growth_rate

    # squeeze and excite block
    x = squeeze_excite_block(x)

    if return_concat_list:
        return x, nb_filter, x_list
    else:
        return x, nb_filter

# %%
def __transition_block(ip, nb_filter, compression=1.0, weight_decay=weight_decay):

    concat_axis = -1

    x = BatchNormalization(axis=concat_axis, epsilon=1.1e-5)(ip)
    x = Activation('relu')(x)
    x = Conv2D(int(nb_filter * compression), (1, 1), kernel_initializer='he_uniform', padding='same', use_bias=False,
               kernel_regularizer=l2(weight_decay))(x)
    x = AveragePooling2D((2, 2), strides=(2, 2))(x)

    # squeeze and excite block
    x = squeeze_excite_block(x)

    return x

# %%
def __create_dense_net(nb_classes, img_input, depth=40, nb_dense_block=3, growth_rate=12, nb_filter=-1,
                       nb_layers_per_block=-1, bottleneck=False, reduction=0.0, dropout_rate=None, weight_decay=weight_decay,
                       subsample_initial_block=False, activation='softmax'):

    concat_axis = -1

    if reduction != 0.0:
        assert 1.0 >= reduction > 0.0, 'reduction value must lie between 0.0 and 1.0'

    # layers in each dense block
    if type(nb_layers_per_block) is list or type(nb_layers_per_block) is tuple:
        nb_layers = list(nb_layers_per_block)  # Convert tuple to list

        assert len(nb_layers) == nb_dense_block, 'If list, nb_layer is used as provided. ' \
                                                 'Note that list size must be (nb_dense_block)'
        final_nb_layer = nb_layers[-1]
        nb_layers = nb_layers[:-1]
    else:
        if nb_layers_per_block == -1:
            assert (depth - 4) % 3 == 0, 'Depth must be 3 N + 4 if nb_layers_per_block == -1'
            count = int((depth - 4) / 3)
            nb_layers = [count for _ in range(nb_dense_block)]
            final_nb_layer = count
        else:
            final_nb_layer = nb_layers_per_block
            nb_layers = [nb_layers_per_block] * nb_dense_block

    # compute initial nb_filter if -1, else accept users initial nb_filter
    if nb_filter <= 0:
        nb_filter = 2 * growth_rate

    # compute compression factor
    compression = 1.0 - reduction

    # Initial convolution
    if subsample_initial_block:
        initial_kernel = (7, 7)
        initial_strides = (2, 2)
    else:
        initial_kernel = (3, 3)
        initial_strides = (1, 1)

    x = Conv2D(nb_filter, initial_kernel, kernel_initializer='he_uniform', padding='same',
               strides=initial_strides, use_bias=False, kernel_regularizer=l2(weight_decay))(img_input)

    if subsample_initial_block:
        x = BatchNormalization(axis=concat_axis, epsilon=1.1e-5)(x)
        x = Activation('relu')(x)
        x = MaxPooling2D((3, 3), strides=(2, 2), padding='same')(x)

    # Add dense blocks
    for block_idx in range(nb_dense_block - 1):
        x, nb_filter = __dense_block(x, nb_layers[block_idx], nb_filter, growth_rate, bottleneck=bottleneck,
                                     dropout_rate=dropout_rate, weight_decay=weight_decay)
        # add transition_block
        x = __transition_block(x, nb_filter, compression=compression, weight_decay=weight_decay)
        nb_filter = int(nb_filter * compression)

    # The last dense_block does not have a transition_block
    x, nb_filter = __dense_block(x, final_nb_layer, nb_filter, growth_rate, bottleneck=bottleneck,
                                 dropout_rate=dropout_rate, weight_decay=weight_decay)

    x = BatchNormalization(axis=concat_axis, epsilon=1.1e-5)(x)
    x = Activation('relu')(x)
    x = GlobalAveragePooling2D()(x)

    x = Dense(nb_classes, kernel_regularizer=l2(weight_decay), activation=activation)(x)

    return x

# %% [markdown]
# ### 2) Almost Orginial SE-DenseNet121

# %%
def SE_DenseNet(input_shape=None, depth=40, nb_dense_block=3, growth_rate=12, nb_filter=-1, nb_layers_per_block=-1, bottleneck=False,
               reduction=0.0, dropout_rate=0.0, weight_decay=weight_decay, subsample_initial_block=False,
               weights=None, classes=classes, activation='softmax', name=None):


    if activation not in ['softmax', 'sigmoid']:
        raise ValueError('activation must be one of "softmax" or "sigmoid"')

    if activation == 'sigmoid' and classes != 1:
        raise ValueError('sigmoid activation can only be used when classes = 1')

    img_input = Input(shape=input_shape)

    x = __create_dense_net(classes, img_input, depth, nb_dense_block,
                           growth_rate, nb_filter, nb_layers_per_block, bottleneck, reduction,
                           dropout_rate, weight_decay, subsample_initial_block, activation)

    # Ensure that the model takes into account
    # any potential predecessors of `input_tensor`.

    inputs = img_input

    # Create model.
    model = Model(inputs, x, name= name )

    return model

# %%
def SE_DenseNet121(input_shape=None, bottleneck=True, reduction=0.5, growth_rate = 32, dropout_rate=0.0, weight_decay=weight_decay, classes=classes, activation='softmax', name = None):

    return SE_DenseNet(input_shape, depth=121, nb_dense_block=4, growth_rate=growth_rate, nb_filter=64,
                      nb_layers_per_block=[6, 12, 24, 16], bottleneck=bottleneck, reduction=reduction,
                      dropout_rate=dropout_rate, weight_decay=weight_decay, subsample_initial_block=True,
                      classes=classes, activation=activation , name = name)

# %% [markdown]
# ## 3. SE-DenseNet121
#
# ---

# %% [markdown]
# ### 1) SE-DenseNet121

# %%
model = SE_DenseNet121(input_shape=input_sizes, classes = classes, dropout_rate = 0.2, growth_rate = 32, name = 'SE_DenseNet121')

# %%
model.summary()
# Out:
# Model: "SE_DenseNet121"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 112, 112, 64) 9408        input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 112, 112, 64) 256         conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 112, 112, 64) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 56, 56, 64)   0           activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 56, 56, 64)   256         max_pooling2d[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 56, 56, 64)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 56, 56, 128)  8192        activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 56, 56, 128)  512         conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 56, 56, 128)  0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 56, 56, 32)   36864       activation_2[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 56, 56, 32)   0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 56, 56, 96)   0           max_pooling2d[0][0]
#                                                                  dropout[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 56, 56, 96)   384         concatenate[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 56, 56, 96)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 56, 56, 128)  12288       activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 56, 56, 128)  512         conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 56, 56, 128)  0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 56, 56, 32)   36864       activation_4[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 56, 56, 32)   0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 56, 56, 128)  0           concatenate[0][0]
#                                                                  dropout_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 56, 56, 128)  512         concatenate_1[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 56, 56, 128)  0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 56, 56, 128)  16384       activation_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 56, 56, 128)  512         conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 56, 56, 128)  0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 56, 56, 32)   36864       activation_6[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 56, 56, 32)   0           conv2d_6[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 56, 56, 160)  0           concatenate_1[0][0]
#                                                                  dropout_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 56, 56, 160)  640         concatenate_2[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 56, 56, 160)  0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 56, 56, 128)  20480       activation_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 56, 56, 128)  512         conv2d_7[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 56, 56, 128)  0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 56, 56, 32)   36864       activation_8[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 56, 56, 32)   0           conv2d_8[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 56, 56, 192)  0           concatenate_2[0][0]
#                                                                  dropout_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 56, 56, 192)  768         concatenate_3[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 56, 56, 192)  0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 56, 56, 128)  24576       activation_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 56, 56, 128)  512         conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 56, 56, 128)  0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 56, 56, 32)   36864       activation_10[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 56, 56, 32)   0           conv2d_10[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 56, 56, 224)  0           concatenate_3[0][0]
#                                                                  dropout_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 56, 56, 224)  896         concatenate_4[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 56, 56, 224)  0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 56, 56, 128)  28672       activation_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 56, 56, 128)  512         conv2d_11[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 56, 56, 128)  0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 56, 56, 32)   36864       activation_12[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 56, 56, 32)   0           conv2d_12[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 56, 56, 256)  0           concatenate_4[0][0]
#                                                                  dropout_5[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 256)          0           concatenate_5[0][0]
# __________________________________________________________________________________________________
# reshape (Reshape)               (None, 1, 1, 256)    0           global_average_pooling2d[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 1, 1, 16)     4096        reshape[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 1, 1, 256)    4096        dense[0][0]
# __________________________________________________________________________________________________
# multiply (Multiply)             (None, 56, 56, 256)  0           concatenate_5[0][0]
#                                                                  dense_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 56, 56, 256)  1024        multiply[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 56, 56, 256)  0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 56, 56, 128)  32768       activation_13[0][0]
# __________________________________________________________________________________________________
# average_pooling2d (AveragePooli (None, 28, 28, 128)  0           conv2d_13[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_1 (Glo (None, 128)          0           average_pooling2d[0][0]
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, 1, 1, 128)    0           global_average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 1, 1, 8)      1024        reshape_1[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 1, 1, 128)    1024        dense_2[0][0]
# __________________________________________________________________________________________________
# multiply_1 (Multiply)           (None, 28, 28, 128)  0           average_pooling2d[0][0]
#                                                                  dense_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 28, 28, 128)  512         multiply_1[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 28, 28, 128)  0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 28, 28, 128)  16384       activation_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 28, 28, 128)  512         conv2d_14[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 28, 28, 128)  0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 28, 28, 32)   36864       activation_15[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 28, 28, 32)   0           conv2d_15[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 28, 28, 160)  0           multiply_1[0][0]
#                                                                  dropout_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 28, 28, 160)  640         concatenate_6[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 28, 28, 160)  0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 28, 28, 128)  20480       activation_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 28, 28, 128)  512         conv2d_16[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 28, 28, 128)  0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 28, 28, 32)   36864       activation_17[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 28, 28, 32)   0           conv2d_17[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 28, 28, 192)  0           concatenate_6[0][0]
#                                                                  dropout_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 28, 28, 192)  768         concatenate_7[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 28, 28, 192)  0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 28, 28, 128)  24576       activation_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 28, 28, 128)  512         conv2d_18[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 28, 28, 128)  0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 28, 28, 32)   36864       activation_19[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 28, 28, 32)   0           conv2d_19[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 28, 28, 224)  0           concatenate_7[0][0]
#                                                                  dropout_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 28, 28, 224)  896         concatenate_8[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 28, 28, 224)  0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 28, 28, 128)  28672       activation_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 28, 28, 128)  512         conv2d_20[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 28, 28, 128)  0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 28, 28, 32)   36864       activation_21[0][0]
# __________________________________________________________________________________________________
# dropout_9 (Dropout)             (None, 28, 28, 32)   0           conv2d_21[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 28, 28, 256)  0           concatenate_8[0][0]
#                                                                  dropout_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 28, 28, 256)  1024        concatenate_9[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 28, 28, 256)  0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 28, 28, 128)  32768       activation_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 28, 28, 128)  512         conv2d_22[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 28, 28, 128)  0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 28, 28, 32)   36864       activation_23[0][0]
# __________________________________________________________________________________________________
# dropout_10 (Dropout)            (None, 28, 28, 32)   0           conv2d_23[0][0]
# __________________________________________________________________________________________________
# concatenate_10 (Concatenate)    (None, 28, 28, 288)  0           concatenate_9[0][0]
#                                                                  dropout_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 28, 28, 288)  1152        concatenate_10[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 28, 28, 288)  0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 28, 28, 128)  36864       activation_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 28, 28, 128)  512         conv2d_24[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 28, 28, 128)  0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 28, 28, 32)   36864       activation_25[0][0]
# __________________________________________________________________________________________________
# dropout_11 (Dropout)            (None, 28, 28, 32)   0           conv2d_25[0][0]
# __________________________________________________________________________________________________
# concatenate_11 (Concatenate)    (None, 28, 28, 320)  0           concatenate_10[0][0]
#                                                                  dropout_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 28, 28, 320)  1280        concatenate_11[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 28, 28, 320)  0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 28, 28, 128)  40960       activation_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 28, 28, 128)  512         conv2d_26[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 28, 28, 128)  0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 28, 28, 32)   36864       activation_27[0][0]
# __________________________________________________________________________________________________
# dropout_12 (Dropout)            (None, 28, 28, 32)   0           conv2d_27[0][0]
# __________________________________________________________________________________________________
# concatenate_12 (Concatenate)    (None, 28, 28, 352)  0           concatenate_11[0][0]
#                                                                  dropout_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 28, 28, 352)  1408        concatenate_12[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 28, 28, 352)  0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 28, 28, 128)  45056       activation_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 28, 28, 128)  512         conv2d_28[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 28, 28, 128)  0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 28, 28, 32)   36864       activation_29[0][0]
# __________________________________________________________________________________________________
# dropout_13 (Dropout)            (None, 28, 28, 32)   0           conv2d_29[0][0]
# __________________________________________________________________________________________________
# concatenate_13 (Concatenate)    (None, 28, 28, 384)  0           concatenate_12[0][0]
#                                                                  dropout_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 28, 28, 384)  1536        concatenate_13[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 28, 28, 384)  0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 28, 28, 128)  49152       activation_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 28, 28, 128)  512         conv2d_30[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 28, 28, 128)  0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 28, 28, 32)   36864       activation_31[0][0]
# __________________________________________________________________________________________________
# dropout_14 (Dropout)            (None, 28, 28, 32)   0           conv2d_31[0][0]
# __________________________________________________________________________________________________
# concatenate_14 (Concatenate)    (None, 28, 28, 416)  0           concatenate_13[0][0]
#                                                                  dropout_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 28, 28, 416)  1664        concatenate_14[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 28, 28, 416)  0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 28, 28, 128)  53248       activation_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 28, 28, 128)  512         conv2d_32[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 28, 28, 128)  0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 28, 28, 32)   36864       activation_33[0][0]
# __________________________________________________________________________________________________
# dropout_15 (Dropout)            (None, 28, 28, 32)   0           conv2d_33[0][0]
# __________________________________________________________________________________________________
# concatenate_15 (Concatenate)    (None, 28, 28, 448)  0           concatenate_14[0][0]
#                                                                  dropout_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 28, 28, 448)  1792        concatenate_15[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 28, 28, 448)  0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 28, 28, 128)  57344       activation_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 28, 28, 128)  512         conv2d_34[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 28, 28, 128)  0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 28, 28, 32)   36864       activation_35[0][0]
# __________________________________________________________________________________________________
# dropout_16 (Dropout)            (None, 28, 28, 32)   0           conv2d_35[0][0]
# __________________________________________________________________________________________________
# concatenate_16 (Concatenate)    (None, 28, 28, 480)  0           concatenate_15[0][0]
#                                                                  dropout_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 28, 28, 480)  1920        concatenate_16[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 28, 28, 480)  0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 28, 28, 128)  61440       activation_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 28, 28, 128)  512         conv2d_36[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 28, 28, 128)  0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 28, 28, 32)   36864       activation_37[0][0]
# __________________________________________________________________________________________________
# dropout_17 (Dropout)            (None, 28, 28, 32)   0           conv2d_37[0][0]
# __________________________________________________________________________________________________
# concatenate_17 (Concatenate)    (None, 28, 28, 512)  0           concatenate_16[0][0]
#                                                                  dropout_17[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_2 (Glo (None, 512)          0           concatenate_17[0][0]
# __________________________________________________________________________________________________
# reshape_2 (Reshape)             (None, 1, 1, 512)    0           global_average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 1, 1, 32)     16384       reshape_2[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 1, 1, 512)    16384       dense_4[0][0]
# __________________________________________________________________________________________________
# multiply_2 (Multiply)           (None, 28, 28, 512)  0           concatenate_17[0][0]
#                                                                  dense_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 28, 28, 512)  2048        multiply_2[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 28, 28, 512)  0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 28, 28, 256)  131072      activation_38[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, 14, 14, 256)  0           conv2d_38[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_3 (Glo (None, 256)          0           average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# reshape_3 (Reshape)             (None, 1, 1, 256)    0           global_average_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 1, 1, 16)     4096        reshape_3[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 1, 1, 256)    4096        dense_6[0][0]
# __________________________________________________________________________________________________
# multiply_3 (Multiply)           (None, 14, 14, 256)  0           average_pooling2d_1[0][0]
#                                                                  dense_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 14, 14, 256)  1024        multiply_3[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 14, 14, 256)  0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 14, 14, 128)  32768       activation_39[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 14, 14, 128)  512         conv2d_39[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 14, 14, 128)  0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 14, 14, 32)   36864       activation_40[0][0]
# __________________________________________________________________________________________________
# dropout_18 (Dropout)            (None, 14, 14, 32)   0           conv2d_40[0][0]
# __________________________________________________________________________________________________
# concatenate_18 (Concatenate)    (None, 14, 14, 288)  0           multiply_3[0][0]
#                                                                  dropout_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 14, 14, 288)  1152        concatenate_18[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 14, 14, 288)  0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 14, 14, 128)  36864       activation_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 14, 14, 128)  512         conv2d_41[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 14, 14, 128)  0           batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 14, 14, 32)   36864       activation_42[0][0]
# __________________________________________________________________________________________________
# dropout_19 (Dropout)            (None, 14, 14, 32)   0           conv2d_42[0][0]
# __________________________________________________________________________________________________
# concatenate_19 (Concatenate)    (None, 14, 14, 320)  0           concatenate_18[0][0]
#                                                                  dropout_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 14, 14, 320)  1280        concatenate_19[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 14, 14, 320)  0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 14, 14, 128)  40960       activation_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 14, 14, 128)  512         conv2d_43[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 14, 14, 128)  0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 14, 14, 32)   36864       activation_44[0][0]
# __________________________________________________________________________________________________
# dropout_20 (Dropout)            (None, 14, 14, 32)   0           conv2d_44[0][0]
# __________________________________________________________________________________________________
# concatenate_20 (Concatenate)    (None, 14, 14, 352)  0           concatenate_19[0][0]
#                                                                  dropout_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 14, 14, 352)  1408        concatenate_20[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 14, 14, 352)  0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 14, 14, 128)  45056       activation_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 14, 14, 128)  512         conv2d_45[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 14, 14, 128)  0           batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 14, 14, 32)   36864       activation_46[0][0]
# __________________________________________________________________________________________________
# dropout_21 (Dropout)            (None, 14, 14, 32)   0           conv2d_46[0][0]
# __________________________________________________________________________________________________
# concatenate_21 (Concatenate)    (None, 14, 14, 384)  0           concatenate_20[0][0]
#                                                                  dropout_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 14, 14, 384)  1536        concatenate_21[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 14, 14, 384)  0           batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 14, 14, 128)  49152       activation_47[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 14, 14, 128)  512         conv2d_47[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 14, 14, 128)  0           batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 14, 14, 32)   36864       activation_48[0][0]
# __________________________________________________________________________________________________
# dropout_22 (Dropout)            (None, 14, 14, 32)   0           conv2d_48[0][0]
# __________________________________________________________________________________________________
# concatenate_22 (Concatenate)    (None, 14, 14, 416)  0           concatenate_21[0][0]
#                                                                  dropout_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 14, 14, 416)  1664        concatenate_22[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 14, 14, 416)  0           batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 14, 14, 128)  53248       activation_49[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 14, 14, 128)  512         conv2d_49[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, 14, 14, 128)  0           batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 14, 14, 32)   36864       activation_50[0][0]
# __________________________________________________________________________________________________
# dropout_23 (Dropout)            (None, 14, 14, 32)   0           conv2d_50[0][0]
# __________________________________________________________________________________________________
# concatenate_23 (Concatenate)    (None, 14, 14, 448)  0           concatenate_22[0][0]
#                                                                  dropout_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 14, 14, 448)  1792        concatenate_23[0][0]
# __________________________________________________________________________________________________
# activation_51 (Activation)      (None, 14, 14, 448)  0           batch_normalization_51[0][0]
# ...
# __________________________________________________________________________________________________
# concatenate_49 (Concatenate)    (None, 7, 7, 768)    0           concatenate_48[0][0]
#                                                                  dropout_49[0][0]
# __________________________________________________________________________________________________
# batch_normalization_104 (BatchN (None, 7, 7, 768)    3072        concatenate_49[0][0]
# __________________________________________________________________________________________________
# activation_104 (Activation)     (None, 7, 7, 768)    0           batch_normalization_104[0][0]
# __________________________________________________________________________________________________
# conv2d_104 (Conv2D)             (None, 7, 7, 128)    98304       activation_104[0][0]
# __________________________________________________________________________________________________
# batch_normalization_105 (BatchN (None, 7, 7, 128)    512         conv2d_104[0][0]
# __________________________________________________________________________________________________
# activation_105 (Activation)     (None, 7, 7, 128)    0           batch_normalization_105[0][0]
# __________________________________________________________________________________________________
# conv2d_105 (Conv2D)             (None, 7, 7, 32)     36864       activation_105[0][0]
# __________________________________________________________________________________________________
# dropout_50 (Dropout)            (None, 7, 7, 32)     0           conv2d_105[0][0]
# __________________________________________________________________________________________________
# concatenate_50 (Concatenate)    (None, 7, 7, 800)    0           concatenate_49[0][0]
#                                                                  dropout_50[0][0]
# __________________________________________________________________________________________________
# batch_normalization_106 (BatchN (None, 7, 7, 800)    3200        concatenate_50[0][0]
# __________________________________________________________________________________________________
# activation_106 (Activation)     (None, 7, 7, 800)    0           batch_normalization_106[0][0]
# __________________________________________________________________________________________________
# conv2d_106 (Conv2D)             (None, 7, 7, 128)    102400      activation_106[0][0]
# __________________________________________________________________________________________________
# batch_normalization_107 (BatchN (None, 7, 7, 128)    512         conv2d_106[0][0]
# __________________________________________________________________________________________________
# activation_107 (Activation)     (None, 7, 7, 128)    0           batch_normalization_107[0][0]
# __________________________________________________________________________________________________
# conv2d_107 (Conv2D)             (None, 7, 7, 32)     36864       activation_107[0][0]
# __________________________________________________________________________________________________
# dropout_51 (Dropout)            (None, 7, 7, 32)     0           conv2d_107[0][0]
# __________________________________________________________________________________________________
# concatenate_51 (Concatenate)    (None, 7, 7, 832)    0           concatenate_50[0][0]
#                                                                  dropout_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_108 (BatchN (None, 7, 7, 832)    3328        concatenate_51[0][0]
# __________________________________________________________________________________________________
# activation_108 (Activation)     (None, 7, 7, 832)    0           batch_normalization_108[0][0]
# __________________________________________________________________________________________________
# conv2d_108 (Conv2D)             (None, 7, 7, 128)    106496      activation_108[0][0]
# __________________________________________________________________________________________________
# batch_normalization_109 (BatchN (None, 7, 7, 128)    512         conv2d_108[0][0]
# __________________________________________________________________________________________________
# activation_109 (Activation)     (None, 7, 7, 128)    0           batch_normalization_109[0][0]
# __________________________________________________________________________________________________
# conv2d_109 (Conv2D)             (None, 7, 7, 32)     36864       activation_109[0][0]
# __________________________________________________________________________________________________
# dropout_52 (Dropout)            (None, 7, 7, 32)     0           conv2d_109[0][0]
# __________________________________________________________________________________________________
# concatenate_52 (Concatenate)    (None, 7, 7, 864)    0           concatenate_51[0][0]
#                                                                  dropout_52[0][0]
# __________________________________________________________________________________________________
# batch_normalization_110 (BatchN (None, 7, 7, 864)    3456        concatenate_52[0][0]
# __________________________________________________________________________________________________
# activation_110 (Activation)     (None, 7, 7, 864)    0           batch_normalization_110[0][0]
# __________________________________________________________________________________________________
# conv2d_110 (Conv2D)             (None, 7, 7, 128)    110592      activation_110[0][0]
# __________________________________________________________________________________________________
# batch_normalization_111 (BatchN (None, 7, 7, 128)    512         conv2d_110[0][0]
# __________________________________________________________________________________________________
# activation_111 (Activation)     (None, 7, 7, 128)    0           batch_normalization_111[0][0]
# __________________________________________________________________________________________________
# conv2d_111 (Conv2D)             (None, 7, 7, 32)     36864       activation_111[0][0]
# __________________________________________________________________________________________________
# dropout_53 (Dropout)            (None, 7, 7, 32)     0           conv2d_111[0][0]
# __________________________________________________________________________________________________
# concatenate_53 (Concatenate)    (None, 7, 7, 896)    0           concatenate_52[0][0]
#                                                                  dropout_53[0][0]
# __________________________________________________________________________________________________
# batch_normalization_112 (BatchN (None, 7, 7, 896)    3584        concatenate_53[0][0]
# __________________________________________________________________________________________________
# activation_112 (Activation)     (None, 7, 7, 896)    0           batch_normalization_112[0][0]
# __________________________________________________________________________________________________
# conv2d_112 (Conv2D)             (None, 7, 7, 128)    114688      activation_112[0][0]
# __________________________________________________________________________________________________
# batch_normalization_113 (BatchN (None, 7, 7, 128)    512         conv2d_112[0][0]
# __________________________________________________________________________________________________
# activation_113 (Activation)     (None, 7, 7, 128)    0           batch_normalization_113[0][0]
# __________________________________________________________________________________________________
# conv2d_113 (Conv2D)             (None, 7, 7, 32)     36864       activation_113[0][0]
# __________________________________________________________________________________________________
# dropout_54 (Dropout)            (None, 7, 7, 32)     0           conv2d_113[0][0]
# __________________________________________________________________________________________________
# concatenate_54 (Concatenate)    (None, 7, 7, 928)    0           concatenate_53[0][0]
#                                                                  dropout_54[0][0]
# __________________________________________________________________________________________________
# batch_normalization_114 (BatchN (None, 7, 7, 928)    3712        concatenate_54[0][0]
# __________________________________________________________________________________________________
# activation_114 (Activation)     (None, 7, 7, 928)    0           batch_normalization_114[0][0]
# __________________________________________________________________________________________________
# conv2d_114 (Conv2D)             (None, 7, 7, 128)    118784      activation_114[0][0]
# __________________________________________________________________________________________________
# batch_normalization_115 (BatchN (None, 7, 7, 128)    512         conv2d_114[0][0]
# __________________________________________________________________________________________________
# activation_115 (Activation)     (None, 7, 7, 128)    0           batch_normalization_115[0][0]
# __________________________________________________________________________________________________
# conv2d_115 (Conv2D)             (None, 7, 7, 32)     36864       activation_115[0][0]
# __________________________________________________________________________________________________
# dropout_55 (Dropout)            (None, 7, 7, 32)     0           conv2d_115[0][0]
# __________________________________________________________________________________________________
# concatenate_55 (Concatenate)    (None, 7, 7, 960)    0           concatenate_54[0][0]
#                                                                  dropout_55[0][0]
# __________________________________________________________________________________________________
# batch_normalization_116 (BatchN (None, 7, 7, 960)    3840        concatenate_55[0][0]
# __________________________________________________________________________________________________
# activation_116 (Activation)     (None, 7, 7, 960)    0           batch_normalization_116[0][0]
# __________________________________________________________________________________________________
# conv2d_116 (Conv2D)             (None, 7, 7, 128)    122880      activation_116[0][0]
# __________________________________________________________________________________________________
# batch_normalization_117 (BatchN (None, 7, 7, 128)    512         conv2d_116[0][0]
# __________________________________________________________________________________________________
# activation_117 (Activation)     (None, 7, 7, 128)    0           batch_normalization_117[0][0]
# __________________________________________________________________________________________________
# conv2d_117 (Conv2D)             (None, 7, 7, 32)     36864       activation_117[0][0]
# __________________________________________________________________________________________________
# dropout_56 (Dropout)            (None, 7, 7, 32)     0           conv2d_117[0][0]
# __________________________________________________________________________________________________
# concatenate_56 (Concatenate)    (None, 7, 7, 992)    0           concatenate_55[0][0]
#                                                                  dropout_56[0][0]
# __________________________________________________________________________________________________
# batch_normalization_118 (BatchN (None, 7, 7, 992)    3968        concatenate_56[0][0]
# __________________________________________________________________________________________________
# activation_118 (Activation)     (None, 7, 7, 992)    0           batch_normalization_118[0][0]
# __________________________________________________________________________________________________
# conv2d_118 (Conv2D)             (None, 7, 7, 128)    126976      activation_118[0][0]
# __________________________________________________________________________________________________
# batch_normalization_119 (BatchN (None, 7, 7, 128)    512         conv2d_118[0][0]
# __________________________________________________________________________________________________
# activation_119 (Activation)     (None, 7, 7, 128)    0           batch_normalization_119[0][0]
# __________________________________________________________________________________________________
# conv2d_119 (Conv2D)             (None, 7, 7, 32)     36864       activation_119[0][0]
# __________________________________________________________________________________________________
# dropout_57 (Dropout)            (None, 7, 7, 32)     0           conv2d_119[0][0]
# __________________________________________________________________________________________________
# concatenate_57 (Concatenate)    (None, 7, 7, 1024)   0           concatenate_56[0][0]
#                                                                  dropout_57[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_6 (Glo (None, 1024)         0           concatenate_57[0][0]
# __________________________________________________________________________________________________
# reshape_6 (Reshape)             (None, 1, 1, 1024)   0           global_average_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# dense_12 (Dense)                (None, 1, 1, 64)     65536       reshape_6[0][0]
# __________________________________________________________________________________________________
# dense_13 (Dense)                (None, 1, 1, 1024)   65536       dense_12[0][0]
# __________________________________________________________________________________________________
# multiply_6 (Multiply)           (None, 7, 7, 1024)   0           concatenate_57[0][0]
#                                                                  dense_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_120 (BatchN (None, 7, 7, 1024)   4096        multiply_6[0][0]
# __________________________________________________________________________________________________
# activation_120 (Activation)     (None, 7, 7, 1024)   0           batch_normalization_120[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_7 (Glo (None, 1024)         0           activation_120[0][0]
# __________________________________________________________________________________________________
# dense_14 (Dense)                (None, 67)           68675       global_average_pooling2d_7[0][0]
# ==================================================================================================
# Total params: 7,452,291
# Trainable params: 7,368,643
# Non-trainable params: 83,648
# __________________________________________________________________________________________________

# %%
# 폴더 생성

os.makedirs(os.path.join(dir,'model_output',number,model.name), exist_ok=True)
os.makedirs(os.path.join(dir,'train_valid_output',number), exist_ok=True)

# %%
# 참고 : https://github.com/OverLordGoldDragon/keras-adamw

import sys
sys.path.append('/content/drive/My Drive/Colab Notebooks/Paper')
import utils
import optimizers_v2
from utils import get_weight_decays, fill_dict_in_order
from utils import reset_seeds, K_eval
from optimizers_v2 import AdamW, NadamW, SGDW

# %%
# top-5 accuracy 출력
import functools
top5_acc = functools.partial(ks.metrics.top_k_categorical_accuracy, k=5)
top5_acc.__name__ = 'top5_acc'

# %%
#optimizer = SGDW(model=model, use_cosine_annealing=False, total_iterations = len(x_train) // batch_sizes, nesterov=True, momentum=0.9)
optimizer = AdamW(model=model, use_cosine_annealing=False, total_iterations = len(x_train) // batch_sizes)
#optimizer = Adam()
filepath =  os.path.join(dir,'model_output',number,model.name,'{epoch:03d}.h5')

callbacks_list = [ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_weights_only=False, save_best_only=True, mode='min'),
                  ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_weights_only=False, save_best_only=True, mode='max'),
                  #ReduceLROnPlateau(monitor='val_loss',patience=3,factor=0.1,min_lr=1e-5),
                  LearningRateScheduler(lr_schedule,verbose=1)
                  ]
                  
model.compile(optimizer, loss = 'categorical_crossentropy', metrics=['accuracy',top5_acc,macro_f1score])

# %%
######## flow_from_directory
history = model.fit(train_generator, steps_per_epoch=int(len(x_train)/batch_sizes),  validation_data = valid_generator, epochs=epochs , verbose=1 , callbacks = callbacks_list , validation_steps=int(len(x_valid)/batch_sizes))
# Out:
# Learning rate:  0.001
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 1/70
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_1/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_2/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_3/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_4/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_5/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_6/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_7/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_8/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_9/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_10/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_11/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_12/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for dense/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for dense_1/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_13/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for dense_2/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for dense_3/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_14/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_15/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_16/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_17/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_18/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_19/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_20/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_21/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_22/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_23/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_24/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_25/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_26/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_27/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_28/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_29/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_30/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_31/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_32/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_33/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_34/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_35/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_36/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_37/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for dense_4/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for dense_5/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_38/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for dense_6/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for dense_7/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_39/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_40/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_41/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_42/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_43/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_44/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_45/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_46/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_47/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_48/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_49/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_50/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_51/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_52/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_53/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_54/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_55/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_56/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_57/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_58/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_59/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_60/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_61/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_62/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_63/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_64/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_65/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_66/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_67/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_68/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_69/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_70/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_71/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_72/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_73/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_74/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_75/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_76/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_77/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_78/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_79/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_80/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_81/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_82/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_83/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_84/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_85/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_86/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for dense_8/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for dense_9/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_87/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for dense_10/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for dense_11/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_88/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_89/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_90/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_91/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_92/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_93/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_94/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_95/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_96/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_97/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_98/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_99/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_100/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_101/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_102/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_103/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_104/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_105/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_106/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_107/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_108/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_109/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_110/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_111/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_112/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_113/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_114/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_115/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_116/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_117/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_118/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_119/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for dense_12/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for dense_13/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for dense_14/kernel:0
# 194/194 [==============================] - ETA: 0s - loss: 3.5088 - accuracy: 0.1293 - top5_acc: 0.4029 - macro_f1score: 0.0039
# Epoch 00001: val_loss improved from inf to 4.55767, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/SE_DenseNet121/001.h5
#
# Epoch 00001: val_accuracy improved from -inf to 0.02344, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/SE_DenseNet121/001.h5
# 194/194 [==============================] - 6307s 33s/step - loss: 3.5088 - accuracy: 0.1293 - top5_acc: 0.4029 - macro_f1score: 0.0039 - val_loss: 4.5577 - val_accuracy: 0.0234 - val_top5_acc: 0.1634 - val_macro_f1score: 0.0000e+00
# Learning rate:  0.001
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 2/70
# 194/194 [==============================] - ETA: 0s - loss: 3.0205 - accuracy: 0.2249 - top5_acc: 0.5414 - macro_f1score: 0.0188
# Epoch 00002: val_loss improved from 4.55767 to 4.26696, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/SE_DenseNet121/002.h5
#
# Epoch 00002: val_accuracy improved from 0.02344 to 0.12109, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/SE_DenseNet121/002.h5
# 194/194 [==============================] - 301s 2s/step - loss: 3.0205 - accuracy: 0.2249 - top5_acc: 0.5414 - macro_f1score: 0.0188 - val_loss: 4.2670 - val_accuracy: 0.1211 - val_top5_acc: 0.3815 - val_macro_f1score: 0.0208
# Learning rate:  0.001
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 3/70
# 194/194 [==============================] - ETA: 0s - loss: 2.6620 - accuracy: 0.3011 - top5_acc: 0.6331 - macro_f1score: 0.0457
# Epoch 00003: val_loss improved from 4.26696 to 3.50668, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/SE_DenseNet121/003.h5
#
# Epoch 00003: val_accuracy improved from 0.12109 to 0.20508, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/SE_DenseNet121/003.h5
# 194/194 [==============================] - 293s 2s/step - loss: 2.6620 - accuracy: 0.3011 - top5_acc: 0.6331 - macro_f1score: 0.0457 - val_loss: 3.5067 - val_accuracy: 0.2051 - val_top5_acc: 0.4948 - val_macro_f1score: 0.0560
# Learning rate:  0.001
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 4/70
# 194/194 [==============================] - ETA: 0s - loss: 2.4093 - accuracy: 0.3552 - top5_acc: 0.6891 - macro_f1score: 0.0782
# Epoch 00004: val_loss improved from 3.50668 to 2.74752, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/SE_DenseNet121/004.h5
#
# Epoch 00004: val_accuracy improved from 0.20508 to 0.30729, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/SE_DenseNet121/004.h5
# 194/194 [==============================] - 297s 2s/step - loss: 2.4093 - accuracy: 0.3552 - top5_acc: 0.6891 - macro_f1score: 0.0782 - val_loss: 2.7475 - val_accuracy: 0.3073 - val_top5_acc: 0.6211 - val_macro_f1score: 0.0919
# Learning rate:  0.001
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 5/70
# 194/194 [==============================] - ETA: 0s - loss: 2.1749 - accuracy: 0.4097 - top5_acc: 0.7413 - macro_f1score: 0.1090
# Epoch 00005: val_loss did not improve from 2.74752
#
# Epoch 00005: val_accuracy did not improve from 0.30729
# 194/194 [==============================] - 292s 2s/step - loss: 2.1749 - accuracy: 0.4097 - top5_acc: 0.7413 - macro_f1score: 0.1090 - val_loss: 3.2471 - val_accuracy: 0.2461 - val_top5_acc: 0.5859 - val_macro_f1score: 0.0745
# Learning rate:  0.001
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 6/70
# 194/194 [==============================] - ETA: 0s - loss: 1.9803 - accuracy: 0.4534 - top5_acc: 0.7838 - macro_f1score: 0.1394
# Epoch 00006: val_loss did not improve from 2.74752
#
# Epoch 00006: val_accuracy did not improve from 0.30729
# 194/194 [==============================] - 294s 2s/step - loss: 1.9803 - accuracy: 0.4534 - top5_acc: 0.7838 - macro_f1score: 0.1394 - val_loss: 3.0271 - val_accuracy: 0.2904 - val_top5_acc: 0.6432 - val_macro_f1score: 0.0983
# Learning rate:  0.001
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 7/70
# 194/194 [==============================] - ETA: 0s - loss: 1.8155 - accuracy: 0.4930 - top5_acc: 0.8087 - macro_f1score: 0.1666
# Epoch 00007: val_loss did not improve from 2.74752
#
# Epoch 00007: val_accuracy improved from 0.30729 to 0.30924, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/SE_DenseNet121/007.h5
# 194/194 [==============================] - 287s 1s/step - loss: 1.8155 - accuracy: 0.4930 - top5_acc: 0.8087 - macro_f1score: 0.1666 - val_loss: 2.7824 - val_accuracy: 0.3092 - val_top5_acc: 0.6315 - val_macro_f1score: 0.0980
# Learning rate:  0.001
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 8/70
# 194/194 [==============================] - ETA: 0s - loss: 1.6849 - accuracy: 0.5290 - top5_acc: 0.8339 - macro_f1score: 0.1879
# Epoch 00008: val_loss improved from 2.74752 to 2.67301, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/SE_DenseNet121/008.h5
#
# Epoch 00008: val_accuracy improved from 0.30924 to 0.36133, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/SE_DenseNet121/008.h5
# 194/194 [==============================] - 291s 2s/step - loss: 1.6849 - accuracy: 0.5290 - top5_acc: 0.8339 - macro_f1score: 0.1879 - val_loss: 2.6730 - val_accuracy: 0.3613 - val_top5_acc: 0.6960 - val_macro_f1score: 0.1297
# Learning rate:  0.001
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 9/70
# 194/194 [==============================] - ETA: 0s - loss: 1.5671 - accuracy: 0.5514 - top5_acc: 0.8574 - macro_f1score: 0.2103
# Epoch 00009: val_loss did not improve from 2.67301
#
# Epoch 00009: val_accuracy did not improve from 0.36133
# 194/194 [==============================] - 285s 1s/step - loss: 1.5671 - accuracy: 0.5514 - top5_acc: 0.8574 - macro_f1score: 0.2103 - val_loss: 2.9670 - val_accuracy: 0.3242 - val_top5_acc: 0.6790 - val_macro_f1score: 0.1176
# Learning rate:  0.001
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 10/70
# 194/194 [==============================] - ETA: 0s - loss: 1.4795 - accuracy: 0.5693 - top5_acc: 0.8709 - macro_f1score: 0.2235
# Epoch 00010: val_loss did not improve from 2.67301
#
# Epoch 00010: val_accuracy did not improve from 0.36133
# 194/194 [==============================] - 287s 1s/step - loss: 1.4795 - accuracy: 0.5693 - top5_acc: 0.8709 - macro_f1score: 0.2235 - val_loss: 4.0156 - val_accuracy: 0.2467 - val_top5_acc: 0.5267 - val_macro_f1score: 0.0940
# Learning rate:  0.001
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 11/70
# 194/194 [==============================] - ETA: 0s - loss: 1.3769 - accuracy: 0.5996 - top5_acc: 0.8866 - macro_f1score: 0.2440
# Epoch 00011: val_loss improved from 2.67301 to 2.23672, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/SE_DenseNet121/011.h5
#
# Epoch 00011: val_accuracy improved from 0.36133 to 0.43164, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/SE_DenseNet121/011.h5
# 194/194 [==============================] - 294s 2s/step - loss: 1.3769 - accuracy: 0.5996 - top5_acc: 0.8866 - macro_f1score: 0.2440 - val_loss: 2.2367 - val_accuracy: 0.4316 - val_top5_acc: 0.7715 - val_macro_f1score: 0.1555
# Learning rate:  0.001
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 12/70
# 194/194 [==============================] - ETA: 0s - loss: 1.2863 - accuracy: 0.6246 - top5_acc: 0.9006 - macro_f1score: 0.2651
# Epoch 00012: val_loss improved from 2.23672 to 2.07864, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/SE_DenseNet121/012.h5
#
# Epoch 00012: val_accuracy improved from 0.43164 to 0.49935, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/SE_DenseNet121/012.h5
# 194/194 [==============================] - 297s 2s/step - loss: 1.2863 - accuracy: 0.6246 - top5_acc: 0.9006 - macro_f1score: 0.2651 - val_loss: 2.0786 - val_accuracy: 0.4993 - val_top5_acc: 0.7930 - val_macro_f1score: 0.1987
# Learning rate:  0.001
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 13/70
# 194/194 [==============================] - ETA: 0s - loss: 1.2080 - accuracy: 0.6410 - top5_acc: 0.9093 - macro_f1score: 0.2806
# Epoch 00013: val_loss did not improve from 2.07864
#
# Epoch 00013: val_accuracy did not improve from 0.49935
# 194/194 [==============================] - 290s 1s/step - loss: 1.2080 - accuracy: 0.6410 - top5_acc: 0.9093 - macro_f1score: 0.2806 - val_loss: 2.3615 - val_accuracy: 0.4336 - val_top5_acc: 0.7611 - val_macro_f1score: 0.1707
# Learning rate:  0.001
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 14/70
# 194/194 [==============================] - ETA: 0s - loss: 1.1180 - accuracy: 0.6701 - top5_acc: 0.9198 - macro_f1score: 0.2966
# Epoch 00014: val_loss improved from 2.07864 to 2.04899, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/SE_DenseNet121/014.h5
#
# Epoch 00014: val_accuracy did not improve from 0.49935
# 194/194 [==============================] - 287s 1s/step - loss: 1.1180 - accuracy: 0.6701 - top5_acc: 0.9198 - macro_f1score: 0.2966 - val_loss: 2.0490 - val_accuracy: 0.4785 - val_top5_acc: 0.7962 - val_macro_f1score: 0.1953
# Learning rate:  0.001
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 15/70
# 194/194 [==============================] - ETA: 0s - loss: 1.0514 - accuracy: 0.6812 - top5_acc: 0.9313 - macro_f1score: 0.3142
# Epoch 00015: val_loss did not improve from 2.04899
#
# Epoch 00015: val_accuracy did not improve from 0.49935
# 194/194 [==============================] - 284s 1s/step - loss: 1.0514 - accuracy: 0.6812 - top5_acc: 0.9313 - macro_f1score: 0.3142 - val_loss: 2.3415 - val_accuracy: 0.4108 - val_top5_acc: 0.7624 - val_macro_f1score: 0.1746
# Learning rate:  0.001
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 16/70
# 194/194 [==============================] - ETA: 0s - loss: 0.9889 - accuracy: 0.7017 - top5_acc: 0.9383 - macro_f1score: 0.3259
# Epoch 00016: val_loss did not improve from 2.04899
#
# Epoch 00016: val_accuracy did not improve from 0.49935
# 194/194 [==============================] - 284s 1s/step - loss: 0.9889 - accuracy: 0.7017 - top5_acc: 0.9383 - macro_f1score: 0.3259 - val_loss: 3.0608 - val_accuracy: 0.3874 - val_top5_acc: 0.7077 - val_macro_f1score: 0.1577
# Learning rate:  0.001
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 17/70
# 194/194 [==============================] - ETA: 0s - loss: 0.9177 - accuracy: 0.7218 - top5_acc: 0.9465 - macro_f1score: 0.3415
# Epoch 00017: val_loss did not improve from 2.04899
#
# Epoch 00017: val_accuracy did not improve from 0.49935
# 194/194 [==============================] - 282s 1s/step - loss: 0.9177 - accuracy: 0.7218 - top5_acc: 0.9465 - macro_f1score: 0.3415 - val_loss: 2.0989 - val_accuracy: 0.4792 - val_top5_acc: 0.8060 - val_macro_f1score: 0.2140
# Learning rate:  0.001
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 18/70
# 194/194 [==============================] - ETA: 0s - loss: 0.8562 - accuracy: 0.7385 - top5_acc: 0.9533 - macro_f1score: 0.3557
# Epoch 00018: val_loss did not improve from 2.04899
#
# Epoch 00018: val_accuracy did not improve from 0.49935
# 194/194 [==============================] - 282s 1s/step - loss: 0.8562 - accuracy: 0.7385 - top5_acc: 0.9533 - macro_f1score: 0.3557 - val_loss: 2.3347 - val_accuracy: 0.4453 - val_top5_acc: 0.7689 - val_macro_f1score: 0.1980
# Learning rate:  0.001
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 19/70
# 194/194 [==============================] - ETA: 0s - loss: 0.8134 - accuracy: 0.7488 - top5_acc: 0.9596 - macro_f1score: 0.3622
# Epoch 00019: val_loss did not improve from 2.04899
#
# Epoch 00019: val_accuracy did not improve from 0.49935
# 194/194 [==============================] - 285s 1s/step - loss: 0.8134 - accuracy: 0.7488 - top5_acc: 0.9596 - macro_f1score: 0.3622 - val_loss: 2.6484 - val_accuracy: 0.4134 - val_top5_acc: 0.7402 - val_macro_f1score: 0.1778
# Learning rate:  0.001
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 20/70
# 194/194 [==============================] - ETA: 0s - loss: 0.7539 - accuracy: 0.7653 - top5_acc: 0.9634 - macro_f1score: 0.3758
# Epoch 00020: val_loss did not improve from 2.04899
#
# Epoch 00020: val_accuracy did not improve from 0.49935
# 194/194 [==============================] - 282s 1s/step - loss: 0.7539 - accuracy: 0.7653 - top5_acc: 0.9634 - macro_f1score: 0.3758 - val_loss: 2.4375 - val_accuracy: 0.4635 - val_top5_acc: 0.7832 - val_macro_f1score: 0.2020
# Learning rate:  0.001
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 21/70
# 194/194 [==============================] - ETA: 0s - loss: 0.7026 - accuracy: 0.7843 - top5_acc: 0.9695 - macro_f1score: 0.3887
# Epoch 00021: val_loss did not improve from 2.04899
#
# Epoch 00021: val_accuracy improved from 0.49935 to 0.50456, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/SE_DenseNet121/021.h5
# 194/194 [==============================] - 286s 1s/step - loss: 0.7026 - accuracy: 0.7843 - top5_acc: 0.9695 - macro_f1score: 0.3887 - val_loss: 2.0656 - val_accuracy: 0.5046 - val_top5_acc: 0.8132 - val_macro_f1score: 0.2342
# Learning rate:  0.001
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 22/70
# 194/194 [==============================] - ETA: 0s - loss: 0.6615 - accuracy: 0.7933 - top5_acc: 0.9740 - macro_f1score: 0.3992
# Epoch 00022: val_loss improved from 2.04899 to 2.02692, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/SE_DenseNet121/022.h5
#
# Epoch 00022: val_accuracy improved from 0.50456 to 0.51888, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/SE_DenseNet121/022.h5
# 194/194 [==============================] - 288s 1s/step - loss: 0.6615 - accuracy: 0.7933 - top5_acc: 0.9740 - macro_f1score: 0.3992 - val_loss: 2.0269 - val_accuracy: 0.5189 - val_top5_acc: 0.8255 - val_macro_f1score: 0.2305
# Learning rate:  0.001
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 23/70
# 194/194 [==============================] - ETA: 0s - loss: 0.5898 - accuracy: 0.8163 - top5_acc: 0.9797 - macro_f1score: 0.4103
# Epoch 00023: val_loss did not improve from 2.02692
#
# Epoch 00023: val_accuracy did not improve from 0.51888
# 194/194 [==============================] - 286s 1s/step - loss: 0.5898 - accuracy: 0.8163 - top5_acc: 0.9797 - macro_f1score: 0.4103 - val_loss: 2.6902 - val_accuracy: 0.4349 - val_top5_acc: 0.7617 - val_macro_f1score: 0.2058
# Learning rate:  0.001
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 24/70
# 194/194 [==============================] - ETA: 0s - loss: 0.5793 - accuracy: 0.8174 - top5_acc: 0.9805 - macro_f1score: 0.4117
# Epoch 00024: val_loss did not improve from 2.02692
#
# Epoch 00024: val_accuracy did not improve from 0.51888
# 194/194 [==============================] - 286s 1s/step - loss: 0.5793 - accuracy: 0.8174 - top5_acc: 0.9805 - macro_f1score: 0.4117 - val_loss: 2.7386 - val_accuracy: 0.4642 - val_top5_acc: 0.7721 - val_macro_f1score: 0.2019
# Learning rate:  0.001
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 25/70
# 194/194 [==============================] - ETA: 0s - loss: 0.5401 - accuracy: 0.8295 - top5_acc: 0.9825 - macro_f1score: 0.4272
# Epoch 00025: val_loss did not improve from 2.02692
#
# Epoch 00025: val_accuracy did not improve from 0.51888
# 194/194 [==============================] - 286s 1s/step - loss: 0.5401 - accuracy: 0.8295 - top5_acc: 0.9825 - macro_f1score: 0.4272 - val_loss: 2.4927 - val_accuracy: 0.4850 - val_top5_acc: 0.7969 - val_macro_f1score: 0.2317
# Learning rate:  0.001
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 26/70
# 194/194 [==============================] - ETA: 0s - loss: 0.4979 - accuracy: 0.8391 - top5_acc: 0.9856 - macro_f1score: 0.4342
# Epoch 00026: val_loss did not improve from 2.02692
#
# Epoch 00026: val_accuracy did not improve from 0.51888
# 194/194 [==============================] - 285s 1s/step - loss: 0.4979 - accuracy: 0.8391 - top5_acc: 0.9856 - macro_f1score: 0.4342 - val_loss: 2.7839 - val_accuracy: 0.4661 - val_top5_acc: 0.7852 - val_macro_f1score: 0.2086
# Learning rate:  0.001
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 27/70
# 194/194 [==============================] - ETA: 0s - loss: 0.4668 - accuracy: 0.8491 - top5_acc: 0.9882 - macro_f1score: 0.4447
# Epoch 00027: val_loss did not improve from 2.02692
#
# Epoch 00027: val_accuracy did not improve from 0.51888
# 194/194 [==============================] - 285s 1s/step - loss: 0.4668 - accuracy: 0.8491 - top5_acc: 0.9882 - macro_f1score: 0.4447 - val_loss: 2.4094 - val_accuracy: 0.5000 - val_top5_acc: 0.8145 - val_macro_f1score: 0.2281
# Learning rate:  0.001
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 28/70
# 194/194 [==============================] - ETA: 0s - loss: 0.4355 - accuracy: 0.8614 - top5_acc: 0.9888 - macro_f1score: 0.4505
# Epoch 00028: val_loss did not improve from 2.02692
#
# Epoch 00028: val_accuracy did not improve from 0.51888
# 194/194 [==============================] - 284s 1s/step - loss: 0.4355 - accuracy: 0.8614 - top5_acc: 0.9888 - macro_f1score: 0.4505 - val_loss: 2.6863 - val_accuracy: 0.4733 - val_top5_acc: 0.7930 - val_macro_f1score: 0.2121
# Learning rate:  0.001
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 29/70
# 194/194 [==============================] - ETA: 0s - loss: 0.4279 - accuracy: 0.8670 - top5_acc: 0.9900 - macro_f1score: 0.4538
# Epoch 00029: val_loss did not improve from 2.02692
#
# Epoch 00029: val_accuracy did not improve from 0.51888
# 194/194 [==============================] - 282s 1s/step - loss: 0.4279 - accuracy: 0.8670 - top5_acc: 0.9900 - macro_f1score: 0.4538 - val_loss: 2.4179 - val_accuracy: 0.5104 - val_top5_acc: 0.8073 - val_macro_f1score: 0.2337
# Learning rate:  0.001
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 30/70
# 194/194 [==============================] - ETA: 0s - loss: 0.3722 - accuracy: 0.8797 - top5_acc: 0.9937 - macro_f1score: 0.4659
# Epoch 00030: val_loss did not improve from 2.02692
#
# Epoch 00030: val_accuracy did not improve from 0.51888
# 194/194 [==============================] - 283s 1s/step - loss: 0.3722 - accuracy: 0.8797 - top5_acc: 0.9937 - macro_f1score: 0.4659 - val_loss: 2.6611 - val_accuracy: 0.4948 - val_top5_acc: 0.7884 - val_macro_f1score: 0.2331
# Learning rate:  0.0001
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 31/70
# 194/194 [==============================] - ETA: 0s - loss: 0.1961 - accuracy: 0.9478 - top5_acc: 0.9979 - macro_f1score: 0.5114
# Epoch 00031: val_loss improved from 2.02692 to 1.67761, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/SE_DenseNet121/031.h5
#
# Epoch 00031: val_accuracy improved from 0.51888 to 0.61263, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/SE_DenseNet121/031.h5
# 194/194 [==============================] - 293s 2s/step - loss: 0.1961 - accuracy: 0.9478 - top5_acc: 0.9979 - macro_f1score: 0.5114 - val_loss: 1.6776 - val_accuracy: 0.6126 - val_top5_acc: 0.8828 - val_macro_f1score: 0.2948
# Learning rate:  0.0001
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 32/70
# 194/194 [==============================] - ETA: 0s - loss: 0.1221 - accuracy: 0.9720 - top5_acc: 0.9997 - macro_f1score: 0.5270
# Epoch 00032: val_loss improved from 1.67761 to 1.60833, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/SE_DenseNet121/032.h5
#
# Epoch 00032: val_accuracy improved from 0.61263 to 0.61458, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/SE_DenseNet121/032.h5
# 194/194 [==============================] - 291s 1s/step - loss: 0.1221 - accuracy: 0.9720 - top5_acc: 0.9997 - macro_f1score: 0.5270 - val_loss: 1.6083 - val_accuracy: 0.6146 - val_top5_acc: 0.8861 - val_macro_f1score: 0.2902
# Learning rate:  0.0001
#
# Epoch 00033: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 33/70
# 194/194 [==============================] - ETA: 0s - loss: 0.1027 - accuracy: 0.9789 - top5_acc: 0.9998 - macro_f1score: 0.5327
# Epoch 00033: val_loss improved from 1.60833 to 1.59131, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/SE_DenseNet121/033.h5
#
# Epoch 00033: val_accuracy did not improve from 0.61458
# 194/194 [==============================] - 284s 1s/step - loss: 0.1027 - accuracy: 0.9789 - top5_acc: 0.9998 - macro_f1score: 0.5327 - val_loss: 1.5913 - val_accuracy: 0.6094 - val_top5_acc: 0.8841 - val_macro_f1score: 0.2936
# Learning rate:  0.0001
#
# Epoch 00034: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 34/70
# 194/194 [==============================] - ETA: 0s - loss: 0.0950 - accuracy: 0.9819 - top5_acc: 0.9996 - macro_f1score: 0.5350
# Epoch 00034: val_loss did not improve from 1.59131
#
# Epoch 00034: val_accuracy improved from 0.61458 to 0.62174, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/SE_DenseNet121/034.h5
# 194/194 [==============================] - 284s 1s/step - loss: 0.0950 - accuracy: 0.9819 - top5_acc: 0.9996 - macro_f1score: 0.5350 - val_loss: 1.5973 - val_accuracy: 0.6217 - val_top5_acc: 0.8874 - val_macro_f1score: 0.3034
# Learning rate:  0.0001
#
# Epoch 00035: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 35/70
# 194/194 [==============================] - ETA: 0s - loss: 0.0869 - accuracy: 0.9830 - top5_acc: 0.9998 - macro_f1score: 0.5339
# Epoch 00035: val_loss did not improve from 1.59131
#
# Epoch 00035: val_accuracy did not improve from 0.62174
# 194/194 [==============================] - 280s 1s/step - loss: 0.0869 - accuracy: 0.9830 - top5_acc: 0.9998 - macro_f1score: 0.5339 - val_loss: 1.6049 - val_accuracy: 0.6133 - val_top5_acc: 0.8861 - val_macro_f1score: 0.2868
# Learning rate:  0.0001
#
# Epoch 00036: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 36/70
# 194/194 [==============================] - ETA: 0s - loss: 0.0841 - accuracy: 0.9843 - top5_acc: 1.0000 - macro_f1score: 0.5340
# Epoch 00036: val_loss did not improve from 1.59131
#
# Epoch 00036: val_accuracy did not improve from 0.62174
# 194/194 [==============================] - 293s 2s/step - loss: 0.0841 - accuracy: 0.9843 - top5_acc: 1.0000 - macro_f1score: 0.5340 - val_loss: 1.6570 - val_accuracy: 0.6107 - val_top5_acc: 0.8802 - val_macro_f1score: 0.2842
# Learning rate:  0.0001
#
# Epoch 00037: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 37/70
# 194/194 [==============================] - ETA: 0s - loss: 0.0749 - accuracy: 0.9880 - top5_acc: 0.9998 - macro_f1score: 0.5434
# Epoch 00037: val_loss did not improve from 1.59131
#
# Epoch 00037: val_accuracy did not improve from 0.62174
# 194/194 [==============================] - 289s 1s/step - loss: 0.0749 - accuracy: 0.9880 - top5_acc: 0.9998 - macro_f1score: 0.5434 - val_loss: 1.6754 - val_accuracy: 0.5996 - val_top5_acc: 0.8763 - val_macro_f1score: 0.2909
# Learning rate:  0.0001
#
# Epoch 00038: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 38/70
# 194/194 [==============================] - ETA: 0s - loss: 0.0729 - accuracy: 0.9878 - top5_acc: 0.9999 - macro_f1score: 0.5372
# Epoch 00038: val_loss did not improve from 1.59131
#
# Epoch 00038: val_accuracy did not improve from 0.62174
# 194/194 [==============================] - 288s 1s/step - loss: 0.0729 - accuracy: 0.9878 - top5_acc: 0.9999 - macro_f1score: 0.5372 - val_loss: 1.6657 - val_accuracy: 0.6100 - val_top5_acc: 0.8750 - val_macro_f1score: 0.2935
# Learning rate:  0.0001
#
# Epoch 00039: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 39/70
# 194/194 [==============================] - ETA: 0s - loss: 0.0651 - accuracy: 0.9901 - top5_acc: 1.0000 - macro_f1score: 0.5392
# Epoch 00039: val_loss did not improve from 1.59131
#
# Epoch 00039: val_accuracy did not improve from 0.62174
# 194/194 [==============================] - 291s 1s/step - loss: 0.0651 - accuracy: 0.9901 - top5_acc: 1.0000 - macro_f1score: 0.5392 - val_loss: 1.7091 - val_accuracy: 0.6048 - val_top5_acc: 0.8763 - val_macro_f1score: 0.2901
# Learning rate:  0.0001
#
# Epoch 00040: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 40/70
# 194/194 [==============================] - ETA: 0s - loss: 0.0653 - accuracy: 0.9895 - top5_acc: 0.9998 - macro_f1score: 0.5426
# Epoch 00040: val_loss did not improve from 1.59131
#
# Epoch 00040: val_accuracy did not improve from 0.62174
# 194/194 [==============================] - 287s 1s/step - loss: 0.0653 - accuracy: 0.9895 - top5_acc: 0.9998 - macro_f1score: 0.5426 - val_loss: 1.6167 - val_accuracy: 0.6107 - val_top5_acc: 0.8828 - val_macro_f1score: 0.2863
# Learning rate:  0.0001
#
# Epoch 00041: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 41/70
# 194/194 [==============================] - ETA: 0s - loss: 0.0601 - accuracy: 0.9905 - top5_acc: 1.0000 - macro_f1score: 0.5411
# Epoch 00041: val_loss did not improve from 1.59131
#
# Epoch 00041: val_accuracy did not improve from 0.62174
# 194/194 [==============================] - 289s 1s/step - loss: 0.0601 - accuracy: 0.9905 - top5_acc: 1.0000 - macro_f1score: 0.5411 - val_loss: 1.6500 - val_accuracy: 0.6126 - val_top5_acc: 0.8809 - val_macro_f1score: 0.2876
# Learning rate:  0.0001
#
# Epoch 00042: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 42/70
# 194/194 [==============================] - ETA: 0s - loss: 0.0611 - accuracy: 0.9912 - top5_acc: 1.0000 - macro_f1score: 0.5399
# Epoch 00042: val_loss did not improve from 1.59131
#
# Epoch 00042: val_accuracy did not improve from 0.62174
# 194/194 [==============================] - 291s 1s/step - loss: 0.0611 - accuracy: 0.9912 - top5_acc: 1.0000 - macro_f1score: 0.5399 - val_loss: 1.6843 - val_accuracy: 0.6165 - val_top5_acc: 0.8730 - val_macro_f1score: 0.2933
# Learning rate:  0.0001
#
# Epoch 00043: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 43/70
# 194/194 [==============================] - ETA: 0s - loss: 0.0590 - accuracy: 0.9908 - top5_acc: 1.0000 - macro_f1score: 0.5398
# Epoch 00043: val_loss did not improve from 1.59131
#
# Epoch 00043: val_accuracy did not improve from 0.62174
# 194/194 [==============================] - 290s 1s/step - loss: 0.0590 - accuracy: 0.9908 - top5_acc: 1.0000 - macro_f1score: 0.5398 - val_loss: 1.6532 - val_accuracy: 0.6094 - val_top5_acc: 0.8822 - val_macro_f1score: 0.2929
# Learning rate:  0.0001
#
# Epoch 00044: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 44/70
# 194/194 [==============================] - ETA: 0s - loss: 0.0593 - accuracy: 0.9917 - top5_acc: 0.9998 - macro_f1score: 0.5414
# Epoch 00044: val_loss did not improve from 1.59131
#
# Epoch 00044: val_accuracy did not improve from 0.62174
# 194/194 [==============================] - 290s 1s/step - loss: 0.0593 - accuracy: 0.9917 - top5_acc: 0.9998 - macro_f1score: 0.5414 - val_loss: 1.7247 - val_accuracy: 0.6022 - val_top5_acc: 0.8730 - val_macro_f1score: 0.2965
# Learning rate:  0.0001
#
# Epoch 00045: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 45/70
# 194/194 [==============================] - ETA: 0s - loss: 0.0541 - accuracy: 0.9910 - top5_acc: 0.9999 - macro_f1score: 0.5398
# Epoch 00045: val_loss did not improve from 1.59131
#
# Epoch 00045: val_accuracy did not improve from 0.62174
# 194/194 [==============================] - 290s 1s/step - loss: 0.0541 - accuracy: 0.9910 - top5_acc: 0.9999 - macro_f1score: 0.5398 - val_loss: 1.7327 - val_accuracy: 0.6009 - val_top5_acc: 0.8783 - val_macro_f1score: 0.2789
# Learning rate:  0.0001
#
# Epoch 00046: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 46/70
# 194/194 [==============================] - ETA: 0s - loss: 0.0499 - accuracy: 0.9931 - top5_acc: 1.0000 - macro_f1score: 0.5500
# Epoch 00046: val_loss did not improve from 1.59131
#
# Epoch 00046: val_accuracy did not improve from 0.62174
# 194/194 [==============================] - 292s 2s/step - loss: 0.0499 - accuracy: 0.9931 - top5_acc: 1.0000 - macro_f1score: 0.5500 - val_loss: 1.8170 - val_accuracy: 0.5970 - val_top5_acc: 0.8633 - val_macro_f1score: 0.2817
# Learning rate:  0.0001
#
# Epoch 00047: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 47/70
# 194/194 [==============================] - ETA: 0s - loss: 0.0528 - accuracy: 0.9926 - top5_acc: 0.9999 - macro_f1score: 0.5416
# Epoch 00047: val_loss did not improve from 1.59131
#
# Epoch 00047: val_accuracy did not improve from 0.62174
# 194/194 [==============================] - 285s 1s/step - loss: 0.0528 - accuracy: 0.9926 - top5_acc: 0.9999 - macro_f1score: 0.5416 - val_loss: 1.7313 - val_accuracy: 0.6081 - val_top5_acc: 0.8763 - val_macro_f1score: 0.2831
# Learning rate:  0.0001
#
# Epoch 00048: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 48/70
# 194/194 [==============================] - ETA: 0s - loss: 0.0496 - accuracy: 0.9935 - top5_acc: 1.0000 - macro_f1score: 0.5469
# Epoch 00048: val_loss did not improve from 1.59131
#
# Epoch 00048: val_accuracy did not improve from 0.62174
# 194/194 [==============================] - 282s 1s/step - loss: 0.0496 - accuracy: 0.9935 - top5_acc: 1.0000 - macro_f1score: 0.5469 - val_loss: 1.6726 - val_accuracy: 0.6185 - val_top5_acc: 0.8776 - val_macro_f1score: 0.2977
# Learning rate:  0.0001
#
# Epoch 00049: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 49/70
# 194/194 [==============================] - ETA: 0s - loss: 0.0526 - accuracy: 0.9922 - top5_acc: 0.9998 - macro_f1score: 0.5461
# Epoch 00049: val_loss did not improve from 1.59131
#
# Epoch 00049: val_accuracy did not improve from 0.62174
# 194/194 [==============================] - 282s 1s/step - loss: 0.0526 - accuracy: 0.9922 - top5_acc: 0.9998 - macro_f1score: 0.5461 - val_loss: 1.7829 - val_accuracy: 0.5938 - val_top5_acc: 0.8698 - val_macro_f1score: 0.2742
# Learning rate:  0.0001
#
# Epoch 00050: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 50/70
# 194/194 [==============================] - ETA: 0s - loss: 0.0486 - accuracy: 0.9924 - top5_acc: 1.0000 - macro_f1score: 0.5369
# Epoch 00050: val_loss did not improve from 1.59131
#
# Epoch 00050: val_accuracy did not improve from 0.62174
# 194/194 [==============================] - 279s 1s/step - loss: 0.0486 - accuracy: 0.9924 - top5_acc: 1.0000 - macro_f1score: 0.5369 - val_loss: 1.8072 - val_accuracy: 0.5944 - val_top5_acc: 0.8665 - val_macro_f1score: 0.2786
# Learning rate:  0.0001
#
# Epoch 00051: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 51/70
# 194/194 [==============================] - ETA: 0s - loss: 0.0474 - accuracy: 0.9926 - top5_acc: 1.0000 - macro_f1score: 0.5424
# Epoch 00051: val_loss did not improve from 1.59131
#
# Epoch 00051: val_accuracy did not improve from 0.62174
# 194/194 [==============================] - 280s 1s/step - loss: 0.0474 - accuracy: 0.9926 - top5_acc: 1.0000 - macro_f1score: 0.5424 - val_loss: 1.7825 - val_accuracy: 0.6133 - val_top5_acc: 0.8776 - val_macro_f1score: 0.2927
# Learning rate:  0.0001
#
# Epoch 00052: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 52/70
# 194/194 [==============================] - ETA: 0s - loss: 0.0470 - accuracy: 0.9925 - top5_acc: 0.9999 - macro_f1score: 0.5400
# Epoch 00052: val_loss did not improve from 1.59131
#
# Epoch 00052: val_accuracy did not improve from 0.62174
# 194/194 [==============================] - 277s 1s/step - loss: 0.0470 - accuracy: 0.9925 - top5_acc: 0.9999 - macro_f1score: 0.5400 - val_loss: 1.7899 - val_accuracy: 0.5996 - val_top5_acc: 0.8711 - val_macro_f1score: 0.2769
# Learning rate:  0.0001
#
# Epoch 00053: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 53/70
# 194/194 [==============================] - ETA: 0s - loss: 0.0473 - accuracy: 0.9915 - top5_acc: 1.0000 - macro_f1score: 0.5444
# Epoch 00053: val_loss did not improve from 1.59131
#
# Epoch 00053: val_accuracy did not improve from 0.62174
# 194/194 [==============================] - 278s 1s/step - loss: 0.0473 - accuracy: 0.9915 - top5_acc: 1.0000 - macro_f1score: 0.5444 - val_loss: 1.7458 - val_accuracy: 0.6016 - val_top5_acc: 0.8678 - val_macro_f1score: 0.2850
# Learning rate:  0.0001
#
# Epoch 00054: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 54/70
# 194/194 [==============================] - ETA: 0s - loss: 0.0444 - accuracy: 0.9932 - top5_acc: 1.0000 - macro_f1score: 0.5443
# Epoch 00054: val_loss did not improve from 1.59131
#
# Epoch 00054: val_accuracy did not improve from 0.62174
# 194/194 [==============================] - 278s 1s/step - loss: 0.0444 - accuracy: 0.9932 - top5_acc: 1.0000 - macro_f1score: 0.5443 - val_loss: 1.7672 - val_accuracy: 0.6081 - val_top5_acc: 0.8724 - val_macro_f1score: 0.2829
# Learning rate:  0.0001
#
# Epoch 00055: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 55/70
# 194/194 [==============================] - ETA: 0s - loss: 0.0418 - accuracy: 0.9942 - top5_acc: 1.0000 - macro_f1score: 0.5451
# Epoch 00055: val_loss did not improve from 1.59131
#
# Epoch 00055: val_accuracy did not improve from 0.62174
# 194/194 [==============================] - 277s 1s/step - loss: 0.0418 - accuracy: 0.9942 - top5_acc: 1.0000 - macro_f1score: 0.5451 - val_loss: 1.8201 - val_accuracy: 0.6022 - val_top5_acc: 0.8770 - val_macro_f1score: 0.2791
# Learning rate:  0.0001
#
# Epoch 00056: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 56/70
# 194/194 [==============================] - ETA: 0s - loss: 0.0409 - accuracy: 0.9940 - top5_acc: 0.9999 - macro_f1score: 0.5424
# Epoch 00056: val_loss did not improve from 1.59131
#
# Epoch 00056: val_accuracy did not improve from 0.62174
# 194/194 [==============================] - 280s 1s/step - loss: 0.0409 - accuracy: 0.9940 - top5_acc: 0.9999 - macro_f1score: 0.5424 - val_loss: 1.8618 - val_accuracy: 0.5918 - val_top5_acc: 0.8613 - val_macro_f1score: 0.2713
# Learning rate:  0.0001
#
# Epoch 00057: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 57/70
# 194/194 [==============================] - ETA: 0s - loss: 0.0376 - accuracy: 0.9940 - top5_acc: 0.9999 - macro_f1score: 0.5464
# Epoch 00057: val_loss did not improve from 1.59131
#
# Epoch 00057: val_accuracy did not improve from 0.62174
# 194/194 [==============================] - 281s 1s/step - loss: 0.0376 - accuracy: 0.9940 - top5_acc: 0.9999 - macro_f1score: 0.5464 - val_loss: 1.8570 - val_accuracy: 0.5977 - val_top5_acc: 0.8652 - val_macro_f1score: 0.2804
# Learning rate:  0.0001
#
# Epoch 00058: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 58/70
# 194/194 [==============================] - ETA: 0s - loss: 0.0403 - accuracy: 0.9935 - top5_acc: 1.0000 - macro_f1score: 0.5394
# Epoch 00058: val_loss did not improve from 1.59131
#
# Epoch 00058: val_accuracy did not improve from 0.62174
# 194/194 [==============================] - 280s 1s/step - loss: 0.0403 - accuracy: 0.9935 - top5_acc: 1.0000 - macro_f1score: 0.5394 - val_loss: 1.9525 - val_accuracy: 0.5898 - val_top5_acc: 0.8470 - val_macro_f1score: 0.2777
# Learning rate:  0.0001
#
# Epoch 00059: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 59/70
# 194/194 [==============================] - ETA: 0s - loss: 0.0394 - accuracy: 0.9944 - top5_acc: 1.0000 - macro_f1score: 0.5435
# Epoch 00059: val_loss did not improve from 1.59131
#
# Epoch 00059: val_accuracy did not improve from 0.62174
# 194/194 [==============================] - 276s 1s/step - loss: 0.0394 - accuracy: 0.9944 - top5_acc: 1.0000 - macro_f1score: 0.5435 - val_loss: 1.8551 - val_accuracy: 0.5898 - val_top5_acc: 0.8620 - val_macro_f1score: 0.2836
# Learning rate:  0.0001
#
# Epoch 00060: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 60/70
# 194/194 [==============================] - ETA: 0s - loss: 0.0349 - accuracy: 0.9952 - top5_acc: 0.9999 - macro_f1score: 0.5455
# Epoch 00060: val_loss did not improve from 1.59131
#
# Epoch 00060: val_accuracy did not improve from 0.62174
# 194/194 [==============================] - 276s 1s/step - loss: 0.0349 - accuracy: 0.9952 - top5_acc: 0.9999 - macro_f1score: 0.5455 - val_loss: 1.8924 - val_accuracy: 0.5964 - val_top5_acc: 0.8717 - val_macro_f1score: 0.2841
# Learning rate:  1e-05
#
# Epoch 00061: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 61/70
# 194/194 [==============================] - ETA: 0s - loss: 0.0328 - accuracy: 0.9958 - top5_acc: 0.9999 - macro_f1score: 0.5429
# Epoch 00061: val_loss did not improve from 1.59131
#
# Epoch 00061: val_accuracy did not improve from 0.62174
# 194/194 [==============================] - 273s 1s/step - loss: 0.0328 - accuracy: 0.9958 - top5_acc: 0.9999 - macro_f1score: 0.5429 - val_loss: 1.8078 - val_accuracy: 0.6126 - val_top5_acc: 0.8730 - val_macro_f1score: 0.2885
# Learning rate:  1e-05
#
# Epoch 00062: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 62/70
# 194/194 [==============================] - ETA: 0s - loss: 0.0301 - accuracy: 0.9961 - top5_acc: 1.0000 - macro_f1score: 0.5418
# Epoch 00062: val_loss did not improve from 1.59131
#
# Epoch 00062: val_accuracy did not improve from 0.62174
# 194/194 [==============================] - 275s 1s/step - loss: 0.0301 - accuracy: 0.9961 - top5_acc: 1.0000 - macro_f1score: 0.5418 - val_loss: 1.7871 - val_accuracy: 0.6094 - val_top5_acc: 0.8698 - val_macro_f1score: 0.2956
# Learning rate:  1e-05
#
# Epoch 00063: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 63/70
# 194/194 [==============================] - ETA: 0s - loss: 0.0301 - accuracy: 0.9962 - top5_acc: 1.0000 - macro_f1score: 0.5462
# Epoch 00063: val_loss did not improve from 1.59131
#
# Epoch 00063: val_accuracy did not improve from 0.62174
# 194/194 [==============================] - 274s 1s/step - loss: 0.0301 - accuracy: 0.9962 - top5_acc: 1.0000 - macro_f1score: 0.5462 - val_loss: 1.7489 - val_accuracy: 0.6165 - val_top5_acc: 0.8763 - val_macro_f1score: 0.2889
# Learning rate:  1e-05
#
# Epoch 00064: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 64/70
# 194/194 [==============================] - ETA: 0s - loss: 0.0281 - accuracy: 0.9971 - top5_acc: 1.0000 - macro_f1score: 0.5470
# Epoch 00064: val_loss did not improve from 1.59131
#
# Epoch 00064: val_accuracy did not improve from 0.62174
# 194/194 [==============================] - 272s 1s/step - loss: 0.0281 - accuracy: 0.9971 - top5_acc: 1.0000 - macro_f1score: 0.5470 - val_loss: 1.7512 - val_accuracy: 0.6139 - val_top5_acc: 0.8757 - val_macro_f1score: 0.2871
# Learning rate:  1e-05
#
# Epoch 00065: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 65/70
# 194/194 [==============================] - ETA: 0s - loss: 0.0287 - accuracy: 0.9965 - top5_acc: 0.9999 - macro_f1score: 0.5489
# Epoch 00065: val_loss did not improve from 1.59131
#
# Epoch 00065: val_accuracy did not improve from 0.62174
# 194/194 [==============================] - 277s 1s/step - loss: 0.0287 - accuracy: 0.9965 - top5_acc: 0.9999 - macro_f1score: 0.5489 - val_loss: 1.7515 - val_accuracy: 0.6178 - val_top5_acc: 0.8717 - val_macro_f1score: 0.2839
# Learning rate:  1e-05
#
# Epoch 00066: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 66/70
# 194/194 [==============================] - ETA: 0s - loss: 0.0313 - accuracy: 0.9965 - top5_acc: 1.0000 - macro_f1score: 0.5460
# Epoch 00066: val_loss did not improve from 1.59131
#
# Epoch 00066: val_accuracy did not improve from 0.62174
# 194/194 [==============================] - 274s 1s/step - loss: 0.0313 - accuracy: 0.9965 - top5_acc: 1.0000 - macro_f1score: 0.5460 - val_loss: 1.7330 - val_accuracy: 0.6126 - val_top5_acc: 0.8730 - val_macro_f1score: 0.2912
# Learning rate:  1e-05
#
# Epoch 00067: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 67/70
# 194/194 [==============================] - ETA: 0s - loss: 0.0317 - accuracy: 0.9965 - top5_acc: 1.0000 - macro_f1score: 0.5515
# Epoch 00067: val_loss did not improve from 1.59131
#
# Epoch 00067: val_accuracy did not improve from 0.62174
# 194/194 [==============================] - 271s 1s/step - loss: 0.0317 - accuracy: 0.9965 - top5_acc: 1.0000 - macro_f1score: 0.5515 - val_loss: 1.7280 - val_accuracy: 0.6113 - val_top5_acc: 0.8698 - val_macro_f1score: 0.2832
# Learning rate:  1e-05
#
# Epoch 00068: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 68/70
# 194/194 [==============================] - ETA: 0s - loss: 0.0323 - accuracy: 0.9970 - top5_acc: 1.0000 - macro_f1score: 0.5466
# Epoch 00068: val_loss did not improve from 1.59131
#
# Epoch 00068: val_accuracy did not improve from 0.62174
# 194/194 [==============================] - 286s 1s/step - loss: 0.0323 - accuracy: 0.9970 - top5_acc: 1.0000 - macro_f1score: 0.5466 - val_loss: 1.7203 - val_accuracy: 0.6029 - val_top5_acc: 0.8717 - val_macro_f1score: 0.2817
# Learning rate:  1e-05
#
# Epoch 00069: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 69/70
# 194/194 [==============================] - ETA: 0s - loss: 0.0350 - accuracy: 0.9963 - top5_acc: 1.0000 - macro_f1score: 0.5483
# Epoch 00069: val_loss did not improve from 1.59131
#
# Epoch 00069: val_accuracy did not improve from 0.62174
# 194/194 [==============================] - 281s 1s/step - loss: 0.0350 - accuracy: 0.9963 - top5_acc: 1.0000 - macro_f1score: 0.5483 - val_loss: 1.6793 - val_accuracy: 0.6146 - val_top5_acc: 0.8730 - val_macro_f1score: 0.2825
# Learning rate:  1e-05
#
# Epoch 00070: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 70/70
# 194/194 [==============================] - ETA: 0s - loss: 0.0358 - accuracy: 0.9968 - top5_acc: 1.0000 - macro_f1score: 0.5434
# Epoch 00070: val_loss did not improve from 1.59131
#
# Epoch 00070: val_accuracy did not improve from 0.62174
# 194/194 [==============================] - 276s 1s/step - loss: 0.0358 - accuracy: 0.9968 - top5_acc: 1.0000 - macro_f1score: 0.5434 - val_loss: 1.6683 - val_accuracy: 0.6094 - val_top5_acc: 0.8737 - val_macro_f1score: 0.2814

# %% [markdown]
# ### 2) SE-DenseNet121 Evaluate

# %%
# 1. epoch=maximum
loss , acc, top5_acc, mf1 = model.evaluate(test_generator,steps=int(len(x_test)/batch_sizes))
print('[Test Loss: %.4f /  Test Top-1 Accuracy: %.4f / Test Top-5 Accuracy: %.4f / Test Macro f1: %.4f]\n' % (loss,acc,top5_acc,mf1))
# Out:
# 24/24 [==============================] - 711s 30s/step - loss: 1.6933 - accuracy: 0.5885 - top5_acc: 0.8802 - macro_f1score: 0.2797
# [Test Loss: 1.6933 /  Test Top-1 Accuracy: 0.5885 / Test Top-5 Accuracy: 0.8802 / Test Macro f1: 0.2797]

# %%
loss=history.history['loss']
val_loss=history.history['val_loss']
acc=history.history['accuracy']
val_acc=history.history['val_accuracy']
top5_acc=history.history['top5_acc']
val_top5_acc=history.history['val_top5_acc']
f1=history.history['macro_f1score']
val_f1=history.history['val_macro_f1score']
epochs=range(1,len(acc)+1)

data = np.array([epochs,loss,val_loss,acc,val_acc,top5_acc,val_top5_acc,f1,val_f1]).T

# %%
# data save
# epochs, loss, val_loss, acc, val_acc, f1, val_f1

np.savetxt(os.path.join(dir,'train_valid_output',number,model.name+'.txt'),data)

# %%
# data import
data = np.loadtxt(os.path.join(dir,'train_valid_output',number,'SE_DenseNet121.txt'))

# %%
epochs=data[:,0]
loss=data[:,1]
val_loss=data[:,2]
acc=data[:,3]
val_acc=data[:,4]
top5_acc=data[:,5]
val_top5_acc=data[:,6]

# %%
plt.plot(epochs[1:],acc[1:],'b',label='Training 1-Acc')
plt.plot(epochs[1:],val_acc[1:],'r',label='Validation 1-Acc')
plt.title('Training and Validation Top-1 Accuracy')
plt.legend()
plt.figure()

plt.plot(epochs[1:],top5_acc[1:],'b',label='Training 5-Acc')
plt.plot(epochs[1:],val_top5_acc[1:],'r',label='Validation 5-Acc')
plt.title('Training and Validation Top-5 Accuracy')
plt.legend()
plt.figure()

plt.plot(epochs[10:],loss[10:],'b',label='Training Loss')
plt.plot(epochs[10:],val_loss[10:],'r',label='Validation Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()

# %%
# 이 아래는 내가 인위적으로 살펴보고 싶은 epoch에 대해서 결과값 출력 / SE-DenseNet121

# %%
# 참고 : https://github.com/OverLordGoldDragon/keras-adamw

import sys
sys.path.append('/content/drive/My Drive/Colab Notebooks/Paper')
import utils
import optimizers_v2
from utils import get_weight_decays, fill_dict_in_order
from utils import reset_seeds, K_eval
from optimizers_v2 import AdamW, NadamW, SGDW

# %%
# top-5 accuracy 출력
import functools
top5_acc = functools.partial(ks.metrics.top_k_categorical_accuracy, k=5)
top5_acc.__name__ = 'top5_acc'

# %%
model=load_model(os.path.join(dir,'model_output',number,'SE_DenseNet121','031.h5'),custom_objects={"macro_f1score": macro_f1score,"top5_acc":top5_acc, "AdamW":AdamW})

# %%
# 2. epoch=?
loss , acc, top5_acc, mf1 = model.evaluate(test_generator,steps=int(len(x_test)/batch_sizes))
print('[Test Loss: %.4f /  Test Top-1 Accuracy: %.4f / Test Top-5 Accuracy: %.4f / Test Macro f1: %.4f]\n' % (loss,acc,top5_acc,mf1))
# Out:
# 24/24 [==============================] - 1110s 46s/step - loss: 1.6549 - accuracy: 0.6068 - top5_acc: 0.8939 - macro_f1score: 0.2912
# [Test Loss: 1.6549 /  Test Top-1 Accuracy: 0.6068 / Test Top-5 Accuracy: 0.8939 / Test Macro f1: 0.2912]
