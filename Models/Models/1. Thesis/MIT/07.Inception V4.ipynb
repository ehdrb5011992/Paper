# %%
# 모형 출처 : https://github.com/kentsommer/keras-inceptionV4/blob/master/inception_v4.py

# %% [markdown]
# # [Inception V4]

# %% [markdown]
# *KU LeeDongGyu*

# %% [markdown]
# ## Contents
# ---

# %% [markdown]
# 1. Data Preprocessing
# ```
# 1) Data Import
# 2) Data Augmentation
# ```
# 2. Support Functions & Almost Original Inception-V4
# ```
# 1) Support Functions
# 2) Almost Original Inception-V4
# 3) Inception-V4 Evaluate
# ```

# %% [markdown]
# ### Install Packages

# %% [markdown]
# ### Module

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/My Drive/Colab Notebooks/Paper
# Out:
# /content/drive/My Drive/Colab Notebooks/Paper

# %%
from f1score import macro_f1score,weighted_f1score

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import cv2
import tensorflow as tf
from tensorflow import keras as ks
from tensorflow.keras import backend as K 
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, Input, Concatenate, ZeroPadding2D ,GlobalMaxPooling2D, Reshape , Lambda , Add, Multiply
from tensorflow.keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D, Activation, BatchNormalization, AveragePooling2D , ZeroPadding2D, SeparableConv2D , LeakyReLU
from tensorflow.keras.layers import add, concatenate, multiply
from tensorflow.keras.optimizers import Adam, RMSprop , SGD
from tensorflow.keras.callbacks import EarlyStopping , LearningRateScheduler, ModelCheckpoint, CSVLogger, Callback, ReduceLROnPlateau
from tensorflow.keras.regularizers import l1,l2,l1_l2
from tensorflow.keras.models import Model , load_model , Sequential
from tensorflow.keras.utils import plot_model , to_categorical, get_file
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
os.getcwd()
# Out:
# '/content/drive/My Drive/Colab Notebooks/Paper'

# %%
print(tf.__version__)
print(ks.__version__)
# Out:
# 2.3.0
# 2.4.0

# %%
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 3706866431424088843
# , name: "/device:XLA_CPU:0"
# device_type: "XLA_CPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 4112857879435382919
# physical_device_desc: "device: XLA_CPU device"
# , name: "/device:XLA_GPU:0"
# device_type: "XLA_GPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 4256494994351918703
# physical_device_desc: "device: XLA_GPU device"
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 15695549568
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 17282336285451833813
# physical_device_desc: "device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0"
# ]

# %%
# !cat /proc/cpuinfo
# Out:
# processor	: 0
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 79
# model name	: Intel(R) Xeon(R) CPU @ 2.20GHz
# stepping	: 0
# microcode	: 0x1
# cpu MHz		: 2200.000
# cache size	: 56320 KB
# physical id	: 0
# siblings	: 4
# core id		: 0
# cpu cores	: 2
# apicid		: 0
# initial apicid	: 0
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm rdseed adx smap xsaveopt arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs taa
# bogomips	: 4400.00
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 46 bits physical, 48 bits virtual
# power management:
#
# processor	: 1
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 79
# model name	: Intel(R) Xeon(R) CPU @ 2.20GHz
# stepping	: 0
# microcode	: 0x1
# cpu MHz		: 2200.000
# cache size	: 56320 KB
# physical id	: 0
# siblings	: 4
# core id		: 1
# cpu cores	: 2
# apicid		: 2
# initial apicid	: 2
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm rdseed adx smap xsaveopt arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs taa
# bogomips	: 4400.00
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 46 bits physical, 48 bits virtual
# power management:
#
# processor	: 2
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 79
# model name	: Intel(R) Xeon(R) CPU @ 2.20GHz
# stepping	: 0
# microcode	: 0x1
# cpu MHz		: 2200.000
# cache size	: 56320 KB
# physical id	: 0
# siblings	: 4
# core id		: 0
# cpu cores	: 2
# apicid		: 1
# initial apicid	: 1
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm rdseed adx smap xsaveopt arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs taa
# bogomips	: 4400.00
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 46 bits physical, 48 bits virtual
# power management:
#
# processor	: 3
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 79
# model name	: Intel(R) Xeon(R) CPU @ 2.20GHz
# stepping	: 0
# microcode	: 0x1
# cpu MHz		: 2200.000
# cache size	: 56320 KB
# physical id	: 0
# siblings	: 4
# core id		: 1
# cpu cores	: 2
# apicid		: 3
# initial apicid	: 3
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm rdseed adx smap xsaveopt arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs taa
# bogomips	: 4400.00
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 46 bits physical, 48 bits virtual
# power management:

# %% [markdown]
# ## 1. Data Preprocessing
# ---

# %% [markdown]
# ### 1) Data Import

# %%
# 바꿔서 살펴 볼 것들
# CALTECH, CIFAR100, FER, MIT
data_name = 'MIT'
gan_type = 'No_GAN'
number = '1'
size = 299 # sizes after cropping
super_size = 330 # sizes before cropping 
input_sizes = (size,size,3)
batch_sizes = 64
weight_decay = 1e-3
epochs = 70

# %%
# 참고 : https://stackoverflow.com/questions/32419510/how-to-get-reproducible-results-in-keras/52897216#52897216
# setting the seed number for random number generation for reproducibility.

from numpy.random import seed
import random


if number=='1':
    seed_num = 200225
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)
elif number=='2':
    seed_num = 727
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)
elif number=='3':
    seed_num = 115
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)
elif number=='4':
    seed_num = 501
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)
elif number=='5':
    seed_num = 517
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)

# %%
# data import

if data_name=='FER' :
    x_train =  np.zeros(28698)
    x_valid = np.zeros(3589)
    x_test = np.zeros(3588)
    classes = 7 
    tr_center = [0.50793296, 0.50793296, 0.50793296]
elif data_name=='MIT':
    x_train = np.zeros(12466)
    x_valid = np.zeros(1564)
    x_test = np.zeros(1590)
    classes = 67 
    tr_center = [0.47916578, 0.42029615, 0.36046057]
elif data_name=='CALTECH':
    x_train = np.zeros(24510)
    x_valid = np.zeros(2980)
    x_test = np.zeros(3118)
    classes = 257
    tr_center = [0.51397761, 0.49525248, 0.46555727]
elif data_name=='CIFAR100':
    x_train = np.zeros(44923)
    x_valid = np.zeros(5077)
    x_test = np.zeros(10000)
    classes = 100
    tr_center = [0.53442983, 0.51355958, 0.46462564]

# %%
dir = os.path.join(os.getcwd(),data_name,gan_type)

# %% [markdown]
# ### 2) Data Augmentation

# %%
# 참고 : https://jkjung-avt.github.io/keras-image-cropping/

def random_crop(img, random_crop_size):
    # Note: image_data_format is 'channel_last'
    assert img.shape[2] == 3 # img.shape[2] 가 3(rgb)이 아니면 assertion error 발생
    height, width = img.shape[0], img.shape[1]
    dy, dx = random_crop_size
    x = np.random.randint(0, width - dx + 1)
    y = np.random.randint(0, height - dy + 1)
    return img[y:(y+dy), x:(x+dx), :]


def crop_generator(batches, crop_length):
    """Take as input a Keras ImageGen (Iterator) and generate random
    crops from the image batches generated by the original iterator.
    """
    while True:
        batch_x, batch_y = next(batches)
        batch_crops = np.zeros((batch_x.shape[0], crop_length, crop_length, 3))
        for i in range(batch_x.shape[0]):
            batch_crops[i] = random_crop(batch_x[i], (crop_length, crop_length))
        yield (batch_crops, batch_y)

# %%
from tensorflow.keras.preprocessing.image import img_to_array,load_img
import glob

# 데이터 전체에 대해 centering 진행함.

def read_cal_image(img_path): 
    x = img_to_array(load_img(img_path)) # x는 채널별 평균값
    y = x.shape[0] * x.shape[1]# y는 데이터별 픽셀 수 (비중)

    x = 1/255. * x # scaling하고, centering값을 뽑아냄.
    x = np.mean(x, axis=(0,1))
    
    return np.hstack([x,y])

def calculate_centered_mean(dataset_path,x_train=x_train):
    num = len(x_train)
    space = np.empty((num,4))
    i=0

    for p in glob.glob(os.path.join(dataset_path,'*/*.*')) :
        space[i] = read_cal_image(p)
        i += 1

    ratio = space[:,3] / np.sum(space[:,3])

    return np.average(space[:,0:3],axis=0,weights=ratio)


# 아래의 함수를 돌려서 나온 결과값을 중심화 값으로 설정.

# train_mean = calculate_centered_mean(os.path.join(dir,'data/train')).reshape((1,1,3))

# %%
datagen_tr = ImageDataGenerator(
    rescale=1/255.,
    horizontal_flip=True,
    featurewise_center=True,
    featurewise_std_normalization=False,
    rotation_range=10,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=[0.9,1.0],
    fill_mode = 'nearest')
datagen_val = ImageDataGenerator(rescale=1/255.,featurewise_center=True)
datagen_tes = ImageDataGenerator(rescale=1/255.,featurewise_center=True)

# 원래는 이 자리에 fit 매서드를 써야하지만, 그냥 내가 중심화함수를 만들고 적용함. 

# 중심화 설정
datagen_tr.mean = np.array(tr_center, dtype=np.float32).reshape((1,1,3)) # RGB
datagen_val.mean = np.array(tr_center, dtype=np.float32).reshape((1,1,3)) # RGB
datagen_tes.mean = np.array(tr_center, dtype=np.float32).reshape((1,1,3)) # RGB

# %%
train_batches = datagen_tr.flow_from_directory(directory=os.path.join(dir,'data/train'),target_size=(super_size,super_size),batch_size=batch_sizes,class_mode='categorical') # fer : 28698 / mit : 12466 / caltech : 24509 / cifar : 44923
train_generator= crop_generator(train_batches, size)
valid_generator = datagen_val.flow_from_directory(directory=os.path.join(dir,'data/valid'),target_size=(size,size),batch_size=batch_sizes,class_mode='categorical') # fer : 3589 / mit : 1564 / caltech : 2980 / cifar : 5077
test_generator = datagen_tes.flow_from_directory(directory=os.path.join(dir,'data/test'),target_size=(size,size),batch_size=batch_sizes,class_mode='categorical') # fer : 3588 / mit : 1590 / caltech : 3118 / cifar : 10000
# Out:
# Found 12466 images belonging to 67 classes.
# Found 1564 images belonging to 67 classes.
# Found 1590 images belonging to 67 classes.

# %% [markdown]
# ## 2. Support Functions & Almost Original Inception-V4
# ---

# %% [markdown]
# ### 1) Support Functions

# %%
# def lr_schedule(epoch):
#     init_lr = 1e-4
#     k = 0.04
#     lr = init_lr * np.exp(-k*epoch)
#     print('Learning rate: ', lr)
#     return lr

def lr_schedule(epoch):
    lr = 1e-3
    if epoch < 30:
        lr = lr
    elif epoch < 60 :
        lr = lr * 0.1
    else:
        lr = lr * 0.01
    print('Learning rate: ', lr)
    return lr

# %%
def conv2d_bn(x, nb_filter, num_row, num_col, padding='same', strides=(1, 1), use_bias=False, weight_decay = weight_decay):

    channel_axis = -1

    x = Conv2D(nb_filter, (num_row, num_col), strides=strides, padding=padding, use_bias=use_bias, kernel_regularizer=l2(weight_decay), kernel_initializer='he_uniform')(x)
    x = BatchNormalization(axis=channel_axis)(x)
    x = Activation('relu')(x)
    return x

# %%
def block_inception_a(input):

    channel_axis = -1

    branch_0 = conv2d_bn(input, 96, 1, 1)

    branch_1 = conv2d_bn(input, 64, 1, 1)
    branch_1 = conv2d_bn(branch_1, 96, 3, 3)

    branch_2 = conv2d_bn(input, 64, 1, 1)
    branch_2 = conv2d_bn(branch_2, 96, 3, 3)
    branch_2 = conv2d_bn(branch_2, 96, 3, 3)

    branch_3 = AveragePooling2D((3,3), strides=(1,1), padding='same')(input)
    branch_3 = conv2d_bn(branch_3, 96, 1, 1)

    x = concatenate([branch_0, branch_1, branch_2, branch_3], axis=channel_axis)
    return x

def block_inception_b(input):

    channel_axis = -1

    branch_0 = conv2d_bn(input, 384, 1, 1)

    branch_1 = conv2d_bn(input, 192, 1, 1)
    branch_1 = conv2d_bn(branch_1, 224, 1, 7)
    branch_1 = conv2d_bn(branch_1, 256, 7, 1)

    branch_2 = conv2d_bn(input, 192, 1, 1)
    branch_2 = conv2d_bn(branch_2, 192, 7, 1)
    branch_2 = conv2d_bn(branch_2, 224, 1, 7)
    branch_2 = conv2d_bn(branch_2, 224, 7, 1)
    branch_2 = conv2d_bn(branch_2, 256, 1, 7)

    branch_3 = AveragePooling2D((3,3), strides=(1,1), padding='same')(input)
    branch_3 = conv2d_bn(branch_3, 128, 1, 1)

    x = concatenate([branch_0, branch_1, branch_2, branch_3], axis=channel_axis)
    return x

def block_inception_c(input):

    channel_axis = -1

    branch_0 = conv2d_bn(input, 256, 1, 1)

    branch_1 = conv2d_bn(input, 384, 1, 1)
    branch_10 = conv2d_bn(branch_1, 256, 1, 3)
    branch_11 = conv2d_bn(branch_1, 256, 3, 1)
    branch_1 = concatenate([branch_10, branch_11], axis=channel_axis)


    branch_2 = conv2d_bn(input, 384, 1, 1)
    branch_2 = conv2d_bn(branch_2, 448, 3, 1)
    branch_2 = conv2d_bn(branch_2, 512, 1, 3)
    branch_20 = conv2d_bn(branch_2, 256, 1, 3)
    branch_21 = conv2d_bn(branch_2, 256, 3, 1)
    branch_2 = concatenate([branch_20, branch_21], axis=channel_axis)

    branch_3 = AveragePooling2D((3, 3), strides=(1, 1), padding='same')(input)
    branch_3 = conv2d_bn(branch_3, 256, 1, 1)

    x = concatenate([branch_0, branch_1, branch_2, branch_3], axis=channel_axis)
    return x

# %%
def block_reduction_a(input):

    channel_axis = -1

    branch_0 = conv2d_bn(input, 384, 3, 3, strides=(2,2), padding='valid')

    branch_1 = conv2d_bn(input, 192, 1, 1)
    branch_1 = conv2d_bn(branch_1, 224, 3, 3)
    branch_1 = conv2d_bn(branch_1, 256, 3, 3, strides=(2,2), padding='valid')

    branch_2 = MaxPooling2D((3,3), strides=(2,2), padding='valid')(input)

    x = concatenate([branch_0, branch_1, branch_2], axis=channel_axis)
    return x

def block_reduction_b(input):

    channel_axis = -1

    branch_0 = conv2d_bn(input, 192, 1, 1)
    branch_0 = conv2d_bn(branch_0, 192, 3, 3, strides=(2, 2), padding='valid')

    branch_1 = conv2d_bn(input, 256, 1, 1)
    branch_1 = conv2d_bn(branch_1, 256, 1, 7)
    branch_1 = conv2d_bn(branch_1, 320, 7, 1)
    branch_1 = conv2d_bn(branch_1, 320, 3, 3, strides=(2,2), padding='valid')

    branch_2 = MaxPooling2D((3, 3), strides=(2, 2), padding='valid')(input)

    x = concatenate([branch_0, branch_1, branch_2], axis=channel_axis)
    return x

# %% [markdown]
# ### 2) Almost Original Inception-V4

# %%
def inception_v4_base(input):

    channel_axis = -1

    net = conv2d_bn(input, 32, 3, 3, strides=(2,2), padding='valid')
    net = conv2d_bn(net, 32, 3, 3, padding='valid')
    net = conv2d_bn(net, 64, 3, 3)

    branch_0 = MaxPooling2D((3,3), strides=(2,2), padding='valid')(net)

    branch_1 = conv2d_bn(net, 96, 3, 3, strides=(2,2), padding='valid')

    net = concatenate([branch_0, branch_1], axis=channel_axis)

    branch_0 = conv2d_bn(net, 64, 1, 1)
    branch_0 = conv2d_bn(branch_0, 96, 3, 3, padding='valid')

    branch_1 = conv2d_bn(net, 64, 1, 1)
    branch_1 = conv2d_bn(branch_1, 64, 1, 7)
    branch_1 = conv2d_bn(branch_1, 64, 7, 1)
    branch_1 = conv2d_bn(branch_1, 96, 3, 3, padding='valid')

    net = concatenate([branch_0, branch_1], axis=channel_axis)

    branch_0 = conv2d_bn(net, 192, 3, 3, strides=(2,2), padding='valid')
    branch_1 = MaxPooling2D((3,3), strides=(2,2), padding='valid')(net)

    net = concatenate([branch_0, branch_1], axis=channel_axis)

    # 35 x 35 x 384
    # 4 x Inception-A blocks
    for idx in range(4):
    	net = block_inception_a(net)

    # 35 x 35 x 384
    # Reduction-A block
    net = block_reduction_a(net)

    # 17 x 17 x 1024
    # 7 x Inception-B blocks
    for idx in range(7):
    	net = block_inception_b(net)

    # 17 x 17 x 1024
    # Reduction-B block
    net = block_reduction_b(net)

    # 8 x 8 x 1536
    # 3 x Inception-C blocks
    for idx in range(3):
    	net = block_inception_c(net)

    return net

# %%
def Inception_v4(input_shape, classes, name = None, weight_decay = weight_decay):

    inputs = Input(shape=input_shape)

    # Make inception base
    x = inception_v4_base(inputs)


    # Final pooling and prediction
    # 1 x 1 x 1536
    x = AveragePooling2D((8,8), padding='valid')(x)
    x = Dropout(0.2)(x)
    x = Flatten()(x)
    # 1536
    x = Dense(classes, use_bias=False, kernel_regularizer=l2(weight_decay), activation='softmax')(x)

    model = Model(inputs, x, name=name)

  
    return model

# %%
model = Inception_v4(input_sizes, classes=classes, name='Inception_v4')

# %%
model.summary()
# Out:
# Model: "Inception_v4"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 299, 299, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 149, 149, 32) 864         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 149, 149, 32) 128         conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 149, 149, 32) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 147, 147, 32) 9216        activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 147, 147, 32) 128         conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 147, 147, 32) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 147, 147, 64) 18432       activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 147, 147, 64) 256         conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 147, 147, 64) 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 73, 73, 96)   55296       activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 73, 73, 96)   384         conv2d_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 73, 73, 64)   0           activation_2[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 73, 73, 96)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 73, 73, 160)  0           max_pooling2d[0][0]
#                                                                  activation_3[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 73, 73, 64)   10240       concatenate[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 73, 73, 64)   256         conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 73, 73, 64)   0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 73, 73, 64)   28672       activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 73, 73, 64)   256         conv2d_7[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 73, 73, 64)   0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 73, 73, 64)   10240       concatenate[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 73, 73, 64)   28672       activation_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 73, 73, 64)   256         conv2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 73, 73, 64)   256         conv2d_8[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 73, 73, 64)   0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 73, 73, 64)   0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 71, 71, 96)   55296       activation_4[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 71, 71, 96)   55296       activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 71, 71, 96)   384         conv2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 71, 71, 96)   384         conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 71, 71, 96)   0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 71, 71, 96)   0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 71, 71, 192)  0           activation_5[0][0]
#                                                                  activation_9[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 35, 35, 192)  331776      concatenate_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 35, 35, 192)  768         conv2d_10[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 35, 35, 192)  0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 35, 35, 192)  0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 35, 35, 384)  0           activation_10[0][0]
#                                                                  max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 35, 35, 64)   24576       concatenate_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 35, 35, 64)   256         conv2d_14[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 35, 35, 64)   0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 35, 35, 64)   24576       concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 35, 35, 96)   55296       activation_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 35, 35, 64)   256         conv2d_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 35, 35, 96)   384         conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 35, 35, 64)   0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 35, 35, 96)   0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# average_pooling2d (AveragePooli (None, 35, 35, 384)  0           concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 35, 35, 96)   36864       concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 35, 35, 96)   55296       activation_12[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 35, 35, 96)   82944       activation_15[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 35, 35, 96)   36864       average_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 35, 35, 96)   384         conv2d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 35, 35, 96)   384         conv2d_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 35, 35, 96)   384         conv2d_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 35, 35, 96)   384         conv2d_17[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 35, 35, 96)   0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 35, 35, 96)   0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 35, 35, 96)   0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 35, 35, 96)   0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 35, 35, 384)  0           activation_11[0][0]
#                                                                  activation_13[0][0]
#                                                                  activation_16[0][0]
#                                                                  activation_17[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 35, 35, 64)   24576       concatenate_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 35, 35, 64)   256         conv2d_21[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 35, 35, 64)   0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 35, 35, 64)   24576       concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 35, 35, 96)   55296       activation_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 35, 35, 64)   256         conv2d_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 35, 35, 96)   384         conv2d_22[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 35, 35, 64)   0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 35, 35, 96)   0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, 35, 35, 384)  0           concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 35, 35, 96)   36864       concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 35, 35, 96)   55296       activation_19[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 35, 35, 96)   82944       activation_22[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 35, 35, 96)   36864       average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 35, 35, 96)   384         conv2d_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 35, 35, 96)   384         conv2d_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 35, 35, 96)   384         conv2d_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 35, 35, 96)   384         conv2d_24[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 35, 35, 96)   0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 35, 35, 96)   0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 35, 35, 96)   0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 35, 35, 96)   0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 35, 35, 384)  0           activation_18[0][0]
#                                                                  activation_20[0][0]
#                                                                  activation_23[0][0]
#                                                                  activation_24[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 35, 35, 64)   24576       concatenate_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 35, 35, 64)   256         conv2d_28[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 35, 35, 64)   0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 35, 35, 64)   24576       concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 35, 35, 96)   55296       activation_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 35, 35, 64)   256         conv2d_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 35, 35, 96)   384         conv2d_29[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 35, 35, 64)   0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 35, 35, 96)   0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_2 (AveragePoo (None, 35, 35, 384)  0           concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 35, 35, 96)   36864       concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 35, 35, 96)   55296       activation_26[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 35, 35, 96)   82944       activation_29[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 35, 35, 96)   36864       average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 35, 35, 96)   384         conv2d_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 35, 35, 96)   384         conv2d_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 35, 35, 96)   384         conv2d_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 35, 35, 96)   384         conv2d_31[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 35, 35, 96)   0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 35, 35, 96)   0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 35, 35, 96)   0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 35, 35, 96)   0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 35, 35, 384)  0           activation_25[0][0]
#                                                                  activation_27[0][0]
#                                                                  activation_30[0][0]
#                                                                  activation_31[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 35, 35, 64)   24576       concatenate_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 35, 35, 64)   256         conv2d_35[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 35, 35, 64)   0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 35, 35, 64)   24576       concatenate_5[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 35, 35, 96)   55296       activation_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 35, 35, 64)   256         conv2d_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 35, 35, 96)   384         conv2d_36[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 35, 35, 64)   0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 35, 35, 96)   0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_3 (AveragePoo (None, 35, 35, 384)  0           concatenate_5[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 35, 35, 96)   36864       concatenate_5[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 35, 35, 96)   55296       activation_33[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 35, 35, 96)   82944       activation_36[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 35, 35, 96)   36864       average_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 35, 35, 96)   384         conv2d_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 35, 35, 96)   384         conv2d_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 35, 35, 96)   384         conv2d_37[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 35, 35, 96)   384         conv2d_38[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 35, 35, 96)   0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 35, 35, 96)   0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 35, 35, 96)   0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 35, 35, 96)   0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 35, 35, 384)  0           activation_32[0][0]
#                                                                  activation_34[0][0]
#                                                                  activation_37[0][0]
#                                                                  activation_38[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 35, 35, 192)  73728       concatenate_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 35, 35, 192)  768         conv2d_40[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 35, 35, 192)  0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 35, 35, 224)  387072      activation_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 35, 35, 224)  896         conv2d_41[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 35, 35, 224)  0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 17, 17, 384)  1327104     concatenate_6[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 17, 17, 256)  516096      activation_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 17, 17, 384)  1536        conv2d_39[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 17, 17, 256)  1024        conv2d_42[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 17, 17, 384)  0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 17, 17, 256)  0           batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 17, 17, 384)  0           concatenate_6[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 17, 17, 1024) 0           activation_39[0][0]
#                                                                  activation_42[0][0]
#                                                                  max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 17, 17, 192)  196608      concatenate_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 17, 17, 192)  768         conv2d_47[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 17, 17, 192)  0           batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 17, 17, 192)  258048      activation_47[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 17, 17, 192)  768         conv2d_48[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 17, 17, 192)  0           batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 17, 17, 192)  196608      concatenate_7[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 17, 17, 224)  301056      activation_48[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 17, 17, 192)  768         conv2d_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 17, 17, 224)  896         conv2d_49[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 17, 17, 192)  0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 17, 17, 224)  0           batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 17, 17, 224)  301056      activation_44[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 17, 17, 224)  351232      activation_49[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 17, 17, 224)  896         conv2d_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 17, 17, 224)  896         conv2d_50[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 17, 17, 224)  0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, 17, 17, 224)  0           batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_4 (AveragePoo (None, 17, 17, 1024) 0           concatenate_7[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 17, 17, 384)  393216      concatenate_7[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 17, 17, 256)  401408      activation_45[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 17, 17, 256)  401408      activation_50[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 17, 17, 128)  131072      average_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 17, 17, 384)  1536        conv2d_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 17, 17, 256)  1024        conv2d_46[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 17, 17, 256)  1024        conv2d_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 17, 17, 128)  512         conv2d_52[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 17, 17, 384)  0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 17, 17, 256)  0           batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# activation_51 (Activation)      (None, 17, 17, 256)  0           batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# activation_52 (Activation)      (None, 17, 17, 128)  0           batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 17, 17, 1024) 0           activation_43[0][0]
#                                                                  activation_46[0][0]
#                                                                  activation_51[0][0]
#                                                                  activation_52[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 17, 17, 192)  196608      concatenate_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_57 (BatchNo (None, 17, 17, 192)  768         conv2d_57[0][0]
# __________________________________________________________________________________________________
# activation_57 (Activation)      (None, 17, 17, 192)  0           batch_normalization_57[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, 17, 17, 192)  258048      activation_57[0][0]
# __________________________________________________________________________________________________
# batch_normalization_58 (BatchNo (None, 17, 17, 192)  768         conv2d_58[0][0]
# __________________________________________________________________________________________________
# activation_58 (Activation)      (None, 17, 17, 192)  0           batch_normalization_58[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 17, 17, 192)  196608      concatenate_8[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, 17, 17, 224)  301056      activation_58[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, 17, 17, 192)  768         conv2d_54[0][0]
# __________________________________________________________________________________________________
# batch_normalization_59 (BatchNo (None, 17, 17, 224)  896         conv2d_59[0][0]
# __________________________________________________________________________________________________
# activation_54 (Activation)      (None, 17, 17, 192)  0           batch_normalization_54[0][0]
# __________________________________________________________________________________________________
# activation_59 (Activation)      (None, 17, 17, 224)  0           batch_normalization_59[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 17, 17, 224)  301056      activation_54[0][0]
# __________________________________________________________________________________________________
# conv2d_60 (Conv2D)              (None, 17, 17, 224)  351232      activation_59[0][0]
# __________________________________________________________________________________________________
# batch_normalization_55 (BatchNo (None, 17, 17, 224)  896         conv2d_55[0][0]
# __________________________________________________________________________________________________
# batch_normalization_60 (BatchNo (None, 17, 17, 224)  896         conv2d_60[0][0]
# __________________________________________________________________________________________________
# activation_55 (Activation)      (None, 17, 17, 224)  0           batch_normalization_55[0][0]
# __________________________________________________________________________________________________
# activation_60 (Activation)      (None, 17, 17, 224)  0           batch_normalization_60[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_5 (AveragePoo (None, 17, 17, 1024) 0           concatenate_8[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 17, 17, 384)  393216      concatenate_8[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 17, 17, 256)  401408      activation_55[0][0]
# __________________________________________________________________________________________________
# conv2d_61 (Conv2D)              (None, 17, 17, 256)  401408      activation_60[0][0]
# __________________________________________________________________________________________________
# conv2d_62 (Conv2D)              (None, 17, 17, 128)  131072      average_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, 17, 17, 384)  1536        conv2d_53[0][0]
# __________________________________________________________________________________________________
# batch_normalization_56 (BatchNo (None, 17, 17, 256)  1024        conv2d_56[0][0]
# __________________________________________________________________________________________________
# batch_normalization_61 (BatchNo (None, 17, 17, 256)  1024        conv2d_61[0][0]
# __________________________________________________________________________________________________
# batch_normalization_62 (BatchNo (None, 17, 17, 128)  512         conv2d_62[0][0]
# __________________________________________________________________________________________________
# activation_53 (Activation)      (None, 17, 17, 384)  0           batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# activation_56 (Activation)      (None, 17, 17, 256)  0           batch_normalization_56[0][0]
# __________________________________________________________________________________________________
# activation_61 (Activation)      (None, 17, 17, 256)  0           batch_normalization_61[0][0]
# __________________________________________________________________________________________________
# activation_62 (Activation)      (None, 17, 17, 128)  0           batch_normalization_62[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 17, 17, 1024) 0           activation_53[0][0]
#                                                                  activation_56[0][0]
#                                                                  activation_61[0][0]
#                                                                  activation_62[0][0]
# __________________________________________________________________________________________________
# conv2d_67 (Conv2D)              (None, 17, 17, 192)  196608      concatenate_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_67 (BatchNo (None, 17, 17, 192)  768         conv2d_67[0][0]
# __________________________________________________________________________________________________
# activation_67 (Activation)      (None, 17, 17, 192)  0           batch_normalization_67[0][0]
# __________________________________________________________________________________________________
# conv2d_68 (Conv2D)              (None, 17, 17, 192)  258048      activation_67[0][0]
# __________________________________________________________________________________________________
# batch_normalization_68 (BatchNo (None, 17, 17, 192)  768         conv2d_68[0][0]
# __________________________________________________________________________________________________
# activation_68 (Activation)      (None, 17, 17, 192)  0           batch_normalization_68[0][0]
# __________________________________________________________________________________________________
# conv2d_64 (Conv2D)              (None, 17, 17, 192)  196608      concatenate_9[0][0]
# __________________________________________________________________________________________________
# conv2d_69 (Conv2D)              (None, 17, 17, 224)  301056      activation_68[0][0]
# __________________________________________________________________________________________________
# batch_normalization_64 (BatchNo (None, 17, 17, 192)  768         conv2d_64[0][0]
# __________________________________________________________________________________________________
# batch_normalization_69 (BatchNo (None, 17, 17, 224)  896         conv2d_69[0][0]
# __________________________________________________________________________________________________
# activation_64 (Activation)      (None, 17, 17, 192)  0           batch_normalization_64[0][0]
# __________________________________________________________________________________________________
# activation_69 (Activation)      (None, 17, 17, 224)  0           batch_normalization_69[0][0]
# __________________________________________________________________________________________________
# conv2d_65 (Conv2D)              (None, 17, 17, 224)  301056      activation_64[0][0]
# __________________________________________________________________________________________________
# conv2d_70 (Conv2D)              (None, 17, 17, 224)  351232      activation_69[0][0]
# __________________________________________________________________________________________________
# batch_normalization_65 (BatchNo (None, 17, 17, 224)  896         conv2d_65[0][0]
# __________________________________________________________________________________________________
# batch_normalization_70 (BatchNo (None, 17, 17, 224)  896         conv2d_70[0][0]
# __________________________________________________________________________________________________
# activation_65 (Activation)      (None, 17, 17, 224)  0           batch_normalization_65[0][0]
# __________________________________________________________________________________________________
# activation_70 (Activation)      (None, 17, 17, 224)  0           batch_normalization_70[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_6 (AveragePoo (None, 17, 17, 1024) 0           concatenate_9[0][0]
# __________________________________________________________________________________________________
# conv2d_63 (Conv2D)              (None, 17, 17, 384)  393216      concatenate_9[0][0]
# __________________________________________________________________________________________________
# ...
# concatenate_18 (Concatenate)    (None, 8, 8, 1536)   0           activation_119[0][0]
#                                                                  concatenate_16[0][0]
#                                                                  concatenate_17[0][0]
#                                                                  activation_128[0][0]
# __________________________________________________________________________________________________
# conv2d_133 (Conv2D)             (None, 8, 8, 384)    589824      concatenate_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_133 (BatchN (None, 8, 8, 384)    1536        conv2d_133[0][0]
# __________________________________________________________________________________________________
# activation_133 (Activation)     (None, 8, 8, 384)    0           batch_normalization_133[0][0]
# __________________________________________________________________________________________________
# conv2d_134 (Conv2D)             (None, 8, 8, 448)    516096      activation_133[0][0]
# __________________________________________________________________________________________________
# batch_normalization_134 (BatchN (None, 8, 8, 448)    1792        conv2d_134[0][0]
# __________________________________________________________________________________________________
# activation_134 (Activation)     (None, 8, 8, 448)    0           batch_normalization_134[0][0]
# __________________________________________________________________________________________________
# conv2d_130 (Conv2D)             (None, 8, 8, 384)    589824      concatenate_18[0][0]
# __________________________________________________________________________________________________
# conv2d_135 (Conv2D)             (None, 8, 8, 512)    688128      activation_134[0][0]
# __________________________________________________________________________________________________
# batch_normalization_130 (BatchN (None, 8, 8, 384)    1536        conv2d_130[0][0]
# __________________________________________________________________________________________________
# batch_normalization_135 (BatchN (None, 8, 8, 512)    2048        conv2d_135[0][0]
# __________________________________________________________________________________________________
# activation_130 (Activation)     (None, 8, 8, 384)    0           batch_normalization_130[0][0]
# __________________________________________________________________________________________________
# activation_135 (Activation)     (None, 8, 8, 512)    0           batch_normalization_135[0][0]
# __________________________________________________________________________________________________
# conv2d_131 (Conv2D)             (None, 8, 8, 256)    294912      activation_130[0][0]
# __________________________________________________________________________________________________
# conv2d_132 (Conv2D)             (None, 8, 8, 256)    294912      activation_130[0][0]
# __________________________________________________________________________________________________
# conv2d_136 (Conv2D)             (None, 8, 8, 256)    393216      activation_135[0][0]
# __________________________________________________________________________________________________
# conv2d_137 (Conv2D)             (None, 8, 8, 256)    393216      activation_135[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_12 (AveragePo (None, 8, 8, 1536)   0           concatenate_18[0][0]
# __________________________________________________________________________________________________
# conv2d_129 (Conv2D)             (None, 8, 8, 256)    393216      concatenate_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_131 (BatchN (None, 8, 8, 256)    1024        conv2d_131[0][0]
# __________________________________________________________________________________________________
# batch_normalization_132 (BatchN (None, 8, 8, 256)    1024        conv2d_132[0][0]
# __________________________________________________________________________________________________
# batch_normalization_136 (BatchN (None, 8, 8, 256)    1024        conv2d_136[0][0]
# __________________________________________________________________________________________________
# batch_normalization_137 (BatchN (None, 8, 8, 256)    1024        conv2d_137[0][0]
# __________________________________________________________________________________________________
# conv2d_138 (Conv2D)             (None, 8, 8, 256)    393216      average_pooling2d_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_129 (BatchN (None, 8, 8, 256)    1024        conv2d_129[0][0]
# __________________________________________________________________________________________________
# activation_131 (Activation)     (None, 8, 8, 256)    0           batch_normalization_131[0][0]
# __________________________________________________________________________________________________
# activation_132 (Activation)     (None, 8, 8, 256)    0           batch_normalization_132[0][0]
# __________________________________________________________________________________________________
# activation_136 (Activation)     (None, 8, 8, 256)    0           batch_normalization_136[0][0]
# __________________________________________________________________________________________________
# activation_137 (Activation)     (None, 8, 8, 256)    0           batch_normalization_137[0][0]
# __________________________________________________________________________________________________
# batch_normalization_138 (BatchN (None, 8, 8, 256)    1024        conv2d_138[0][0]
# __________________________________________________________________________________________________
# activation_129 (Activation)     (None, 8, 8, 256)    0           batch_normalization_129[0][0]
# __________________________________________________________________________________________________
# concatenate_19 (Concatenate)    (None, 8, 8, 512)    0           activation_131[0][0]
#                                                                  activation_132[0][0]
# __________________________________________________________________________________________________
# concatenate_20 (Concatenate)    (None, 8, 8, 512)    0           activation_136[0][0]
#                                                                  activation_137[0][0]
# __________________________________________________________________________________________________
# activation_138 (Activation)     (None, 8, 8, 256)    0           batch_normalization_138[0][0]
# __________________________________________________________________________________________________
# concatenate_21 (Concatenate)    (None, 8, 8, 1536)   0           activation_129[0][0]
#                                                                  concatenate_19[0][0]
#                                                                  concatenate_20[0][0]
#                                                                  activation_138[0][0]
# __________________________________________________________________________________________________
# conv2d_143 (Conv2D)             (None, 8, 8, 384)    589824      concatenate_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_143 (BatchN (None, 8, 8, 384)    1536        conv2d_143[0][0]
# __________________________________________________________________________________________________
# activation_143 (Activation)     (None, 8, 8, 384)    0           batch_normalization_143[0][0]
# __________________________________________________________________________________________________
# conv2d_144 (Conv2D)             (None, 8, 8, 448)    516096      activation_143[0][0]
# __________________________________________________________________________________________________
# batch_normalization_144 (BatchN (None, 8, 8, 448)    1792        conv2d_144[0][0]
# __________________________________________________________________________________________________
# activation_144 (Activation)     (None, 8, 8, 448)    0           batch_normalization_144[0][0]
# __________________________________________________________________________________________________
# conv2d_140 (Conv2D)             (None, 8, 8, 384)    589824      concatenate_21[0][0]
# __________________________________________________________________________________________________
# conv2d_145 (Conv2D)             (None, 8, 8, 512)    688128      activation_144[0][0]
# __________________________________________________________________________________________________
# batch_normalization_140 (BatchN (None, 8, 8, 384)    1536        conv2d_140[0][0]
# __________________________________________________________________________________________________
# batch_normalization_145 (BatchN (None, 8, 8, 512)    2048        conv2d_145[0][0]
# __________________________________________________________________________________________________
# activation_140 (Activation)     (None, 8, 8, 384)    0           batch_normalization_140[0][0]
# __________________________________________________________________________________________________
# activation_145 (Activation)     (None, 8, 8, 512)    0           batch_normalization_145[0][0]
# __________________________________________________________________________________________________
# conv2d_141 (Conv2D)             (None, 8, 8, 256)    294912      activation_140[0][0]
# __________________________________________________________________________________________________
# conv2d_142 (Conv2D)             (None, 8, 8, 256)    294912      activation_140[0][0]
# __________________________________________________________________________________________________
# conv2d_146 (Conv2D)             (None, 8, 8, 256)    393216      activation_145[0][0]
# __________________________________________________________________________________________________
# conv2d_147 (Conv2D)             (None, 8, 8, 256)    393216      activation_145[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_13 (AveragePo (None, 8, 8, 1536)   0           concatenate_21[0][0]
# __________________________________________________________________________________________________
# conv2d_139 (Conv2D)             (None, 8, 8, 256)    393216      concatenate_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_141 (BatchN (None, 8, 8, 256)    1024        conv2d_141[0][0]
# __________________________________________________________________________________________________
# batch_normalization_142 (BatchN (None, 8, 8, 256)    1024        conv2d_142[0][0]
# __________________________________________________________________________________________________
# batch_normalization_146 (BatchN (None, 8, 8, 256)    1024        conv2d_146[0][0]
# __________________________________________________________________________________________________
# batch_normalization_147 (BatchN (None, 8, 8, 256)    1024        conv2d_147[0][0]
# __________________________________________________________________________________________________
# conv2d_148 (Conv2D)             (None, 8, 8, 256)    393216      average_pooling2d_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_139 (BatchN (None, 8, 8, 256)    1024        conv2d_139[0][0]
# __________________________________________________________________________________________________
# activation_141 (Activation)     (None, 8, 8, 256)    0           batch_normalization_141[0][0]
# __________________________________________________________________________________________________
# activation_142 (Activation)     (None, 8, 8, 256)    0           batch_normalization_142[0][0]
# __________________________________________________________________________________________________
# activation_146 (Activation)     (None, 8, 8, 256)    0           batch_normalization_146[0][0]
# __________________________________________________________________________________________________
# activation_147 (Activation)     (None, 8, 8, 256)    0           batch_normalization_147[0][0]
# __________________________________________________________________________________________________
# batch_normalization_148 (BatchN (None, 8, 8, 256)    1024        conv2d_148[0][0]
# __________________________________________________________________________________________________
# activation_139 (Activation)     (None, 8, 8, 256)    0           batch_normalization_139[0][0]
# __________________________________________________________________________________________________
# concatenate_22 (Concatenate)    (None, 8, 8, 512)    0           activation_141[0][0]
#                                                                  activation_142[0][0]
# __________________________________________________________________________________________________
# concatenate_23 (Concatenate)    (None, 8, 8, 512)    0           activation_146[0][0]
#                                                                  activation_147[0][0]
# __________________________________________________________________________________________________
# activation_148 (Activation)     (None, 8, 8, 256)    0           batch_normalization_148[0][0]
# __________________________________________________________________________________________________
# concatenate_24 (Concatenate)    (None, 8, 8, 1536)   0           activation_139[0][0]
#                                                                  concatenate_22[0][0]
#                                                                  concatenate_23[0][0]
#                                                                  activation_148[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_14 (AveragePo (None, 1, 1, 1536)   0           concatenate_24[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 1, 1, 1536)   0           average_pooling2d_14[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 1536)         0           dropout[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 67)           102912      flatten[0][0]
# ==================================================================================================
# Total params: 41,308,896
# Trainable params: 41,245,728
# Non-trainable params: 63,168
# __________________________________________________________________________________________________

# %%
# 폴더 생성

os.makedirs(os.path.join(dir,'model_output',number,model.name), exist_ok=True)
os.makedirs(os.path.join(dir,'train_valid_output',number), exist_ok=True)

# %%
# 참고 : https://github.com/OverLordGoldDragon/keras-adamw

import sys
sys.path.append('/content/drive/My Drive/Colab Notebooks/Paper')
import utils
import optimizers_v2
from utils import get_weight_decays, fill_dict_in_order
from utils import reset_seeds, K_eval
from optimizers_v2 import AdamW, NadamW, SGDW

# %%
# top-5 accuracy 출력
import functools
top5_acc = functools.partial(ks.metrics.top_k_categorical_accuracy, k=5)
top5_acc.__name__ = 'top5_acc'

# %%
#optimizer = SGDW(model=model, use_cosine_annealing=False, total_iterations = len(x_train) // batch_sizes, nesterov=True, momentum=0.9)
optimizer = AdamW(model=model, use_cosine_annealing=False, total_iterations = len(x_train) // batch_sizes)
#optimizer = Adam()
filepath =  os.path.join(dir,'model_output',number,model.name,'{epoch:03d}.h5')

callbacks_list = [ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_weights_only=False, save_best_only=True, mode='min'),
                  ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_weights_only=False, save_best_only=True, mode='max'),
                  #ReduceLROnPlateau(monitor='val_loss',patience=3,factor=0.1,min_lr=1e-5),
                  LearningRateScheduler(lr_schedule,verbose=1)
                  ]
                  
model.compile(optimizer, loss = 'categorical_crossentropy', metrics=['accuracy',top5_acc,macro_f1score])

# %%
######## flow_from_directory
history = model.fit(train_generator, steps_per_epoch=int(len(x_train)/batch_sizes),  validation_data = valid_generator, epochs=epochs , verbose=1 , callbacks = callbacks_list , validation_steps=int(len(x_valid)/batch_sizes))
# Out:
# Learning rate:  0.001
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 1/70
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_1/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_2/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_3/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_6/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_7/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_4/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_8/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_5/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_9/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_10/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_14/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_12/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_15/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_11/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_13/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_16/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_17/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_21/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_19/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_22/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_18/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_20/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_23/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_24/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_28/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_26/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_29/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_25/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_27/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_30/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_31/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_35/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_33/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_36/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_32/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_34/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_37/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_38/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_40/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_41/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_39/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_42/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_47/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_48/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_44/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_49/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_45/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_50/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_43/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_46/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_51/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_52/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_57/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_58/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_54/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_59/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_55/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_60/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_53/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_56/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_61/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_62/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_67/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_68/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_64/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_69/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_65/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_70/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_63/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_66/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_71/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_72/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_77/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_78/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_74/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_79/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_75/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_80/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_73/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_76/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_81/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_82/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_87/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_88/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_84/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_89/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_85/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_90/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_83/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_86/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_91/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_92/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_97/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_98/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_94/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_99/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_95/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_100/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_93/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_96/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_101/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_102/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_107/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_108/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_104/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_109/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_105/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_110/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_103/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_106/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_111/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_112/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_115/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_116/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_113/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_117/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_114/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_118/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_123/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_124/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_120/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_125/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_121/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_122/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_126/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_127/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_119/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_128/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_133/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_134/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_130/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_135/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_131/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_132/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_136/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_137/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_129/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_138/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_143/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_144/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_140/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_145/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_141/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_142/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_146/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_147/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_139/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for conv2d_148/kernel:0
# 0.0(L1), 7.179581927189207e-05(L2) weight decay set for dense/kernel:0
# 194/194 [==============================] - ETA: 0s - loss: 3.9071 - accuracy: 0.0764 - top5_acc: 0.2870 - macro_f1score: 7.5909e-04
# Epoch 00001: val_loss improved from inf to 4.22167, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/Inception_v4/001.h5
#
# Epoch 00001: val_accuracy improved from -inf to 0.03320, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/Inception_v4/001.h5
# 194/194 [==============================] - 6133s 32s/step - loss: 3.9071 - accuracy: 0.0764 - top5_acc: 0.2870 - macro_f1score: 7.5909e-04 - val_loss: 4.2217 - val_accuracy: 0.0332 - val_top5_acc: 0.2272 - val_macro_f1score: 0.0020
# Learning rate:  0.001
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 2/70
# 194/194 [==============================] - ETA: 0s - loss: 3.6483 - accuracy: 0.1038 - top5_acc: 0.3507 - macro_f1score: 2.0516e-04
# Epoch 00002: val_loss improved from 4.22167 to 3.58476, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/Inception_v4/002.h5
#
# Epoch 00002: val_accuracy improved from 0.03320 to 0.11393, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/Inception_v4/002.h5
# 194/194 [==============================] - 423s 2s/step - loss: 3.6483 - accuracy: 0.1038 - top5_acc: 0.3507 - macro_f1score: 2.0516e-04 - val_loss: 3.5848 - val_accuracy: 0.1139 - val_top5_acc: 0.3822 - val_macro_f1score: 0.0000e+00
# Learning rate:  0.001
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 3/70
# 194/194 [==============================] - ETA: 0s - loss: 3.4995 - accuracy: 0.1269 - top5_acc: 0.3996 - macro_f1score: 0.0015
# Epoch 00003: val_loss did not improve from 3.58476
#
# Epoch 00003: val_accuracy did not improve from 0.11393
# 194/194 [==============================] - 414s 2s/step - loss: 3.4995 - accuracy: 0.1269 - top5_acc: 0.3996 - macro_f1score: 0.0015 - val_loss: 5.1857 - val_accuracy: 0.0723 - val_top5_acc: 0.2617 - val_macro_f1score: 0.0030
# Learning rate:  0.001
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 4/70
# 194/194 [==============================] - ETA: 0s - loss: 3.3584 - accuracy: 0.1468 - top5_acc: 0.4394 - macro_f1score: 0.0018
# Epoch 00004: val_loss did not improve from 3.58476
#
# Epoch 00004: val_accuracy did not improve from 0.11393
# 194/194 [==============================] - 414s 2s/step - loss: 3.3584 - accuracy: 0.1468 - top5_acc: 0.4394 - macro_f1score: 0.0018 - val_loss: 20.1227 - val_accuracy: 0.0495 - val_top5_acc: 0.2227 - val_macro_f1score: 0.0052
# Learning rate:  0.001
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 5/70
# 194/194 [==============================] - ETA: 0s - loss: 3.2542 - accuracy: 0.1632 - top5_acc: 0.4694 - macro_f1score: 0.0035
# Epoch 00005: val_loss did not improve from 3.58476
#
# Epoch 00005: val_accuracy did not improve from 0.11393
# 194/194 [==============================] - 414s 2s/step - loss: 3.2542 - accuracy: 0.1632 - top5_acc: 0.4694 - macro_f1score: 0.0035 - val_loss: 4.5187 - val_accuracy: 0.0846 - val_top5_acc: 0.3327 - val_macro_f1score: 0.0064
# Learning rate:  0.001
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 6/70
# 194/194 [==============================] - ETA: 0s - loss: 3.1563 - accuracy: 0.1831 - top5_acc: 0.4992 - macro_f1score: 0.0066
# Epoch 00006: val_loss did not improve from 3.58476
#
# Epoch 00006: val_accuracy did not improve from 0.11393
# 194/194 [==============================] - 413s 2s/step - loss: 3.1563 - accuracy: 0.1831 - top5_acc: 0.4992 - macro_f1score: 0.0066 - val_loss: 31.5590 - val_accuracy: 0.0885 - val_top5_acc: 0.2773 - val_macro_f1score: 0.0115
# Learning rate:  0.001
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 7/70
# 194/194 [==============================] - ETA: 0s - loss: 3.0408 - accuracy: 0.2100 - top5_acc: 0.5323 - macro_f1score: 0.0106
# Epoch 00007: val_loss improved from 3.58476 to 3.32555, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/Inception_v4/007.h5
#
# Epoch 00007: val_accuracy improved from 0.11393 to 0.18750, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/Inception_v4/007.h5
# 194/194 [==============================] - 422s 2s/step - loss: 3.0408 - accuracy: 0.2100 - top5_acc: 0.5323 - macro_f1score: 0.0106 - val_loss: 3.3256 - val_accuracy: 0.1875 - val_top5_acc: 0.4674 - val_macro_f1score: 0.0195
# Learning rate:  0.001
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 8/70
# 194/194 [==============================] - ETA: 0s - loss: 2.9323 - accuracy: 0.2229 - top5_acc: 0.5646 - macro_f1score: 0.0165
# Epoch 00008: val_loss did not improve from 3.32555
#
# Epoch 00008: val_accuracy did not improve from 0.18750
# 194/194 [==============================] - 415s 2s/step - loss: 2.9323 - accuracy: 0.2229 - top5_acc: 0.5646 - macro_f1score: 0.0165 - val_loss: 3.5738 - val_accuracy: 0.1784 - val_top5_acc: 0.4896 - val_macro_f1score: 0.0252
# Learning rate:  0.001
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 9/70
# 194/194 [==============================] - ETA: 0s - loss: 2.8139 - accuracy: 0.2548 - top5_acc: 0.5993 - macro_f1score: 0.0256
# Epoch 00009: val_loss did not improve from 3.32555
#
# Epoch 00009: val_accuracy improved from 0.18750 to 0.20898, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/Inception_v4/009.h5
# 194/194 [==============================] - 417s 2s/step - loss: 2.8139 - accuracy: 0.2548 - top5_acc: 0.5993 - macro_f1score: 0.0256 - val_loss: 3.6139 - val_accuracy: 0.2090 - val_top5_acc: 0.4935 - val_macro_f1score: 0.0335
# Learning rate:  0.001
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 10/70
# 194/194 [==============================] - ETA: 0s - loss: 2.7032 - accuracy: 0.2762 - top5_acc: 0.6230 - macro_f1score: 0.0352
# Epoch 00010: val_loss did not improve from 3.32555
#
# Epoch 00010: val_accuracy did not improve from 0.20898
# 194/194 [==============================] - 414s 2s/step - loss: 2.7032 - accuracy: 0.2762 - top5_acc: 0.6230 - macro_f1score: 0.0352 - val_loss: 5.8318 - val_accuracy: 0.1270 - val_top5_acc: 0.4232 - val_macro_f1score: 0.0229
# Learning rate:  0.001
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 11/70
# 194/194 [==============================] - ETA: 0s - loss: 2.6112 - accuracy: 0.2972 - top5_acc: 0.6430 - macro_f1score: 0.0453
# Epoch 00011: val_loss improved from 3.32555 to 3.07430, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/Inception_v4/011.h5
#
# Epoch 00011: val_accuracy improved from 0.20898 to 0.23893, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/Inception_v4/011.h5
# 194/194 [==============================] - 424s 2s/step - loss: 2.6112 - accuracy: 0.2972 - top5_acc: 0.6430 - macro_f1score: 0.0453 - val_loss: 3.0743 - val_accuracy: 0.2389 - val_top5_acc: 0.5658 - val_macro_f1score: 0.0462
# Learning rate:  0.001
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 12/70
# 194/194 [==============================] - ETA: 0s - loss: 2.4992 - accuracy: 0.3262 - top5_acc: 0.6739 - macro_f1score: 0.0598
# Epoch 00012: val_loss improved from 3.07430 to 3.02653, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/Inception_v4/012.h5
#
# Epoch 00012: val_accuracy improved from 0.23893 to 0.26758, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/Inception_v4/012.h5
# 194/194 [==============================] - 424s 2s/step - loss: 2.4992 - accuracy: 0.3262 - top5_acc: 0.6739 - macro_f1score: 0.0598 - val_loss: 3.0265 - val_accuracy: 0.2676 - val_top5_acc: 0.5697 - val_macro_f1score: 0.0580
# Learning rate:  0.001
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 13/70
# 194/194 [==============================] - ETA: 0s - loss: 2.4057 - accuracy: 0.3479 - top5_acc: 0.6916 - macro_f1score: 0.0743
# Epoch 00013: val_loss did not improve from 3.02653
#
# Epoch 00013: val_accuracy did not improve from 0.26758
# 194/194 [==============================] - 414s 2s/step - loss: 2.4057 - accuracy: 0.3479 - top5_acc: 0.6916 - macro_f1score: 0.0743 - val_loss: 3.6219 - val_accuracy: 0.2174 - val_top5_acc: 0.5215 - val_macro_f1score: 0.0577
# Learning rate:  0.001
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 14/70
# 194/194 [==============================] - ETA: 0s - loss: 2.3006 - accuracy: 0.3654 - top5_acc: 0.7193 - macro_f1score: 0.0835
# Epoch 00014: val_loss did not improve from 3.02653
#
# Epoch 00014: val_accuracy improved from 0.26758 to 0.27409, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/Inception_v4/014.h5
# 194/194 [==============================] - 418s 2s/step - loss: 2.3006 - accuracy: 0.3654 - top5_acc: 0.7193 - macro_f1score: 0.0835 - val_loss: 3.2370 - val_accuracy: 0.2741 - val_top5_acc: 0.5911 - val_macro_f1score: 0.0791
# Learning rate:  0.001
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 15/70
# 194/194 [==============================] - ETA: 0s - loss: 2.2413 - accuracy: 0.3797 - top5_acc: 0.7290 - macro_f1score: 0.0928
# Epoch 00015: val_loss did not improve from 3.02653
#
# Epoch 00015: val_accuracy did not improve from 0.27409
# 194/194 [==============================] - 414s 2s/step - loss: 2.2413 - accuracy: 0.3797 - top5_acc: 0.7290 - macro_f1score: 0.0928 - val_loss: 3.2195 - val_accuracy: 0.2324 - val_top5_acc: 0.5859 - val_macro_f1score: 0.0629
# Learning rate:  0.001
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 16/70
# 194/194 [==============================] - ETA: 0s - loss: 2.1452 - accuracy: 0.4068 - top5_acc: 0.7508 - macro_f1score: 0.1099
# Epoch 00016: val_loss improved from 3.02653 to 2.66310, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/Inception_v4/016.h5
#
# Epoch 00016: val_accuracy improved from 0.27409 to 0.32552, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/Inception_v4/016.h5
# 194/194 [==============================] - 424s 2s/step - loss: 2.1452 - accuracy: 0.4068 - top5_acc: 0.7508 - macro_f1score: 0.1099 - val_loss: 2.6631 - val_accuracy: 0.3255 - val_top5_acc: 0.6393 - val_macro_f1score: 0.1051
# Learning rate:  0.001
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 17/70
# 194/194 [==============================] - ETA: 0s - loss: 2.0637 - accuracy: 0.4286 - top5_acc: 0.7670 - macro_f1score: 0.1271
# Epoch 00017: val_loss did not improve from 2.66310
#
# Epoch 00017: val_accuracy did not improve from 0.32552
# 194/194 [==============================] - 413s 2s/step - loss: 2.0637 - accuracy: 0.4286 - top5_acc: 0.7670 - macro_f1score: 0.1271 - val_loss: 5.8977 - val_accuracy: 0.1289 - val_top5_acc: 0.4264 - val_macro_f1score: 0.0373
# Learning rate:  0.001
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 18/70
# 194/194 [==============================] - ETA: 0s - loss: 1.9958 - accuracy: 0.4458 - top5_acc: 0.7797 - macro_f1score: 0.1344
# Epoch 00018: val_loss did not improve from 2.66310
#
# Epoch 00018: val_accuracy improved from 0.32552 to 0.32682, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/Inception_v4/018.h5
# 194/194 [==============================] - 414s 2s/step - loss: 1.9958 - accuracy: 0.4458 - top5_acc: 0.7797 - macro_f1score: 0.1344 - val_loss: 2.8345 - val_accuracy: 0.3268 - val_top5_acc: 0.6445 - val_macro_f1score: 0.0837
# Learning rate:  0.001
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 19/70
# 194/194 [==============================] - ETA: 0s - loss: 1.9449 - accuracy: 0.4571 - top5_acc: 0.7887 - macro_f1score: 0.1462
# Epoch 00019: val_loss did not improve from 2.66310
#
# Epoch 00019: val_accuracy did not improve from 0.32682
# 194/194 [==============================] - 411s 2s/step - loss: 1.9449 - accuracy: 0.4571 - top5_acc: 0.7887 - macro_f1score: 0.1462 - val_loss: 3.5286 - val_accuracy: 0.2799 - val_top5_acc: 0.5853 - val_macro_f1score: 0.0827
# Learning rate:  0.001
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 20/70
# 194/194 [==============================] - ETA: 0s - loss: 1.8658 - accuracy: 0.4739 - top5_acc: 0.8042 - macro_f1score: 0.1588
# Epoch 00020: val_loss did not improve from 2.66310
#
# Epoch 00020: val_accuracy did not improve from 0.32682
# 194/194 [==============================] - 414s 2s/step - loss: 1.8658 - accuracy: 0.4739 - top5_acc: 0.8042 - macro_f1score: 0.1588 - val_loss: 5.1015 - val_accuracy: 0.2005 - val_top5_acc: 0.5000 - val_macro_f1score: 0.0629
# Learning rate:  0.001
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 21/70
# 194/194 [==============================] - ETA: 0s - loss: 1.8371 - accuracy: 0.4788 - top5_acc: 0.8065 - macro_f1score: 0.1613
# Epoch 00021: val_loss improved from 2.66310 to 2.25833, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/Inception_v4/021.h5
#
# Epoch 00021: val_accuracy improved from 0.32682 to 0.39779, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/Inception_v4/021.h5
# 194/194 [==============================] - 422s 2s/step - loss: 1.8371 - accuracy: 0.4788 - top5_acc: 0.8065 - macro_f1score: 0.1613 - val_loss: 2.2583 - val_accuracy: 0.3978 - val_top5_acc: 0.7331 - val_macro_f1score: 0.1243
# Learning rate:  0.001
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 22/70
# 194/194 [==============================] - ETA: 0s - loss: 1.7800 - accuracy: 0.4915 - top5_acc: 0.8218 - macro_f1score: 0.1738
# Epoch 00022: val_loss did not improve from 2.25833
#
# Epoch 00022: val_accuracy did not improve from 0.39779
# 194/194 [==============================] - 414s 2s/step - loss: 1.7800 - accuracy: 0.4915 - top5_acc: 0.8218 - macro_f1score: 0.1738 - val_loss: 2.6981 - val_accuracy: 0.3906 - val_top5_acc: 0.7461 - val_macro_f1score: 0.1453
# Learning rate:  0.001
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 23/70
# 194/194 [==============================] - ETA: 0s - loss: 1.7086 - accuracy: 0.5110 - top5_acc: 0.8312 - macro_f1score: 0.1862
# Epoch 00023: val_loss did not improve from 2.25833
#
# Epoch 00023: val_accuracy did not improve from 0.39779
# 194/194 [==============================] - 413s 2s/step - loss: 1.7086 - accuracy: 0.5110 - top5_acc: 0.8312 - macro_f1score: 0.1862 - val_loss: 3.4667 - val_accuracy: 0.2884 - val_top5_acc: 0.5859 - val_macro_f1score: 0.1021
# Learning rate:  0.001
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 24/70
# 194/194 [==============================] - ETA: 0s - loss: 1.6750 - accuracy: 0.5202 - top5_acc: 0.8414 - macro_f1score: 0.1930
# Epoch 00024: val_loss did not improve from 2.25833
#
# Epoch 00024: val_accuracy did not improve from 0.39779
# 194/194 [==============================] - 411s 2s/step - loss: 1.6750 - accuracy: 0.5202 - top5_acc: 0.8414 - macro_f1score: 0.1930 - val_loss: 2.8149 - val_accuracy: 0.3483 - val_top5_acc: 0.6810 - val_macro_f1score: 0.1216
# Learning rate:  0.001
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 25/70
# 194/194 [==============================] - ETA: 0s - loss: 1.6084 - accuracy: 0.5329 - top5_acc: 0.8513 - macro_f1score: 0.2022
# Epoch 00025: val_loss did not improve from 2.25833
#
# Epoch 00025: val_accuracy did not improve from 0.39779
# 194/194 [==============================] - 415s 2s/step - loss: 1.6084 - accuracy: 0.5329 - top5_acc: 0.8513 - macro_f1score: 0.2022 - val_loss: 2.4990 - val_accuracy: 0.3776 - val_top5_acc: 0.7298 - val_macro_f1score: 0.1444
# Learning rate:  0.001
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 26/70
# 194/194 [==============================] - ETA: 0s - loss: 1.5832 - accuracy: 0.5414 - top5_acc: 0.8549 - macro_f1score: 0.2071
# Epoch 00026: val_loss did not improve from 2.25833
#
# Epoch 00026: val_accuracy did not improve from 0.39779
# 194/194 [==============================] - 414s 2s/step - loss: 1.5832 - accuracy: 0.5414 - top5_acc: 0.8549 - macro_f1score: 0.2071 - val_loss: 2.6771 - val_accuracy: 0.3730 - val_top5_acc: 0.7070 - val_macro_f1score: 0.1432
# Learning rate:  0.001
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 27/70
# 194/194 [==============================] - ETA: 0s - loss: 1.5288 - accuracy: 0.5565 - top5_acc: 0.8625 - macro_f1score: 0.2194
# Epoch 00027: val_loss improved from 2.25833 to 2.23083, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/Inception_v4/027.h5
#
# Epoch 00027: val_accuracy improved from 0.39779 to 0.40690, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/Inception_v4/027.h5
# 194/194 [==============================] - 422s 2s/step - loss: 1.5288 - accuracy: 0.5565 - top5_acc: 0.8625 - macro_f1score: 0.2194 - val_loss: 2.2308 - val_accuracy: 0.4069 - val_top5_acc: 0.7559 - val_macro_f1score: 0.1423
# Learning rate:  0.001
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 28/70
# 194/194 [==============================] - ETA: 0s - loss: 1.5122 - accuracy: 0.5614 - top5_acc: 0.8657 - macro_f1score: 0.2208
# Epoch 00028: val_loss did not improve from 2.23083
#
# Epoch 00028: val_accuracy did not improve from 0.40690
# 194/194 [==============================] - 414s 2s/step - loss: 1.5122 - accuracy: 0.5614 - top5_acc: 0.8657 - macro_f1score: 0.2208 - val_loss: 2.8042 - val_accuracy: 0.3385 - val_top5_acc: 0.6725 - val_macro_f1score: 0.1324
# Learning rate:  0.001
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 29/70
# 194/194 [==============================] - ETA: 0s - loss: 1.4546 - accuracy: 0.5763 - top5_acc: 0.8740 - macro_f1score: 0.2343
# Epoch 00029: val_loss did not improve from 2.23083
#
# Epoch 00029: val_accuracy did not improve from 0.40690
# 194/194 [==============================] - 412s 2s/step - loss: 1.4546 - accuracy: 0.5763 - top5_acc: 0.8740 - macro_f1score: 0.2343 - val_loss: 3.1083 - val_accuracy: 0.3678 - val_top5_acc: 0.7012 - val_macro_f1score: 0.1467
# Learning rate:  0.001
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 30/70
# 194/194 [==============================] - ETA: 0s - loss: 1.3943 - accuracy: 0.5880 - top5_acc: 0.8870 - macro_f1score: 0.2429
# Epoch 00030: val_loss did not improve from 2.23083
#
# Epoch 00030: val_accuracy improved from 0.40690 to 0.41276, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/Inception_v4/030.h5
# 194/194 [==============================] - 417s 2s/step - loss: 1.3943 - accuracy: 0.5880 - top5_acc: 0.8870 - macro_f1score: 0.2429 - val_loss: 2.3017 - val_accuracy: 0.4128 - val_top5_acc: 0.7513 - val_macro_f1score: 0.1609
# Learning rate:  0.0001
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 31/70
# 194/194 [==============================] - ETA: 0s - loss: 1.0970 - accuracy: 0.6721 - top5_acc: 0.9253 - macro_f1score: 0.2970
# Epoch 00031: val_loss improved from 2.23083 to 1.49283, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/Inception_v4/031.h5
#
# Epoch 00031: val_accuracy improved from 0.41276 to 0.58008, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/Inception_v4/031.h5
# 194/194 [==============================] - 424s 2s/step - loss: 1.0970 - accuracy: 0.6721 - top5_acc: 0.9253 - macro_f1score: 0.2970 - val_loss: 1.4928 - val_accuracy: 0.5801 - val_top5_acc: 0.8665 - val_macro_f1score: 0.2339
# Learning rate:  0.0001
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 32/70
# 194/194 [==============================] - ETA: 0s - loss: 0.9701 - accuracy: 0.7067 - top5_acc: 0.9402 - macro_f1score: 0.3286
# Epoch 00032: val_loss improved from 1.49283 to 1.48040, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/Inception_v4/032.h5
#
# Epoch 00032: val_accuracy did not improve from 0.58008
# 194/194 [==============================] - 420s 2s/step - loss: 0.9701 - accuracy: 0.7067 - top5_acc: 0.9402 - macro_f1score: 0.3286 - val_loss: 1.4804 - val_accuracy: 0.5742 - val_top5_acc: 0.8750 - val_macro_f1score: 0.2413
# Learning rate:  0.0001
#
# Epoch 00033: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 33/70
# 194/194 [==============================] - ETA: 0s - loss: 0.9021 - accuracy: 0.7274 - top5_acc: 0.9469 - macro_f1score: 0.3413
# Epoch 00033: val_loss did not improve from 1.48040
#
# Epoch 00033: val_accuracy did not improve from 0.58008
# 194/194 [==============================] - 412s 2s/step - loss: 0.9021 - accuracy: 0.7274 - top5_acc: 0.9469 - macro_f1score: 0.3413 - val_loss: 1.5138 - val_accuracy: 0.5703 - val_top5_acc: 0.8730 - val_macro_f1score: 0.2512
# Learning rate:  0.0001
#
# Epoch 00034: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 34/70
# 194/194 [==============================] - ETA: 0s - loss: 0.8722 - accuracy: 0.7297 - top5_acc: 0.9512 - macro_f1score: 0.3448
# Epoch 00034: val_loss did not improve from 1.48040
#
# Epoch 00034: val_accuracy did not improve from 0.58008
# 194/194 [==============================] - 415s 2s/step - loss: 0.8722 - accuracy: 0.7297 - top5_acc: 0.9512 - macro_f1score: 0.3448 - val_loss: 1.5032 - val_accuracy: 0.5788 - val_top5_acc: 0.8757 - val_macro_f1score: 0.2450
# Learning rate:  0.0001
#
# Epoch 00035: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 35/70
# 194/194 [==============================] - ETA: 0s - loss: 0.8503 - accuracy: 0.7421 - top5_acc: 0.9523 - macro_f1score: 0.3541
# Epoch 00035: val_loss did not improve from 1.48040
#
# Epoch 00035: val_accuracy did not improve from 0.58008
# 194/194 [==============================] - 412s 2s/step - loss: 0.8503 - accuracy: 0.7421 - top5_acc: 0.9523 - macro_f1score: 0.3541 - val_loss: 1.5066 - val_accuracy: 0.5736 - val_top5_acc: 0.8737 - val_macro_f1score: 0.2526
# Learning rate:  0.0001
#
# Epoch 00036: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 36/70
# 194/194 [==============================] - ETA: 0s - loss: 0.8127 - accuracy: 0.7495 - top5_acc: 0.9564 - macro_f1score: 0.3601
# Epoch 00036: val_loss did not improve from 1.48040
#
# Epoch 00036: val_accuracy improved from 0.58008 to 0.58203, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/Inception_v4/036.h5
# 194/194 [==============================] - 409s 2s/step - loss: 0.8127 - accuracy: 0.7495 - top5_acc: 0.9564 - macro_f1score: 0.3601 - val_loss: 1.4941 - val_accuracy: 0.5820 - val_top5_acc: 0.8717 - val_macro_f1score: 0.2528
# Learning rate:  0.0001
#
# Epoch 00037: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 37/70
# 194/194 [==============================] - ETA: 0s - loss: 0.8039 - accuracy: 0.7542 - top5_acc: 0.9577 - macro_f1score: 0.3636
# Epoch 00037: val_loss did not improve from 1.48040
#
# Epoch 00037: val_accuracy did not improve from 0.58203
# 194/194 [==============================] - 404s 2s/step - loss: 0.8039 - accuracy: 0.7542 - top5_acc: 0.9577 - macro_f1score: 0.3636 - val_loss: 1.5172 - val_accuracy: 0.5697 - val_top5_acc: 0.8757 - val_macro_f1score: 0.2511
# Learning rate:  0.0001
#
# Epoch 00038: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 38/70
# 194/194 [==============================] - ETA: 0s - loss: 0.7660 - accuracy: 0.7663 - top5_acc: 0.9625 - macro_f1score: 0.3675
# Epoch 00038: val_loss did not improve from 1.48040
#
# Epoch 00038: val_accuracy did not improve from 0.58203
# 194/194 [==============================] - 405s 2s/step - loss: 0.7660 - accuracy: 0.7663 - top5_acc: 0.9625 - macro_f1score: 0.3675 - val_loss: 1.5444 - val_accuracy: 0.5690 - val_top5_acc: 0.8711 - val_macro_f1score: 0.2543
# Learning rate:  0.0001
#
# Epoch 00039: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 39/70
# 194/194 [==============================] - ETA: 0s - loss: 0.7292 - accuracy: 0.7746 - top5_acc: 0.9685 - macro_f1score: 0.3798
# Epoch 00039: val_loss did not improve from 1.48040
#
# Epoch 00039: val_accuracy did not improve from 0.58203
# 194/194 [==============================] - 408s 2s/step - loss: 0.7292 - accuracy: 0.7746 - top5_acc: 0.9685 - macro_f1score: 0.3798 - val_loss: 1.5229 - val_accuracy: 0.5684 - val_top5_acc: 0.8685 - val_macro_f1score: 0.2484
# Learning rate:  0.0001
#
# Epoch 00040: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 40/70
# 194/194 [==============================] - ETA: 0s - loss: 0.7426 - accuracy: 0.7687 - top5_acc: 0.9632 - macro_f1score: 0.3751
# Epoch 00040: val_loss did not improve from 1.48040
#
# Epoch 00040: val_accuracy did not improve from 0.58203
# 194/194 [==============================] - 403s 2s/step - loss: 0.7426 - accuracy: 0.7687 - top5_acc: 0.9632 - macro_f1score: 0.3751 - val_loss: 1.5758 - val_accuracy: 0.5566 - val_top5_acc: 0.8730 - val_macro_f1score: 0.2525
# Learning rate:  0.0001
#
# Epoch 00041: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 41/70
# 194/194 [==============================] - ETA: 0s - loss: 0.6868 - accuracy: 0.7879 - top5_acc: 0.9706 - macro_f1score: 0.3819
# Epoch 00041: val_loss did not improve from 1.48040
#
# Epoch 00041: val_accuracy did not improve from 0.58203
# 194/194 [==============================] - 406s 2s/step - loss: 0.6868 - accuracy: 0.7879 - top5_acc: 0.9706 - macro_f1score: 0.3819 - val_loss: 1.5550 - val_accuracy: 0.5788 - val_top5_acc: 0.8672 - val_macro_f1score: 0.2540
# Learning rate:  0.0001
#
# Epoch 00042: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 42/70
# 194/194 [==============================] - ETA: 0s - loss: 0.6751 - accuracy: 0.7958 - top5_acc: 0.9698 - macro_f1score: 0.3888
# Epoch 00042: val_loss did not improve from 1.48040
#
# Epoch 00042: val_accuracy did not improve from 0.58203
# 194/194 [==============================] - 403s 2s/step - loss: 0.6751 - accuracy: 0.7958 - top5_acc: 0.9698 - macro_f1score: 0.3888 - val_loss: 1.5543 - val_accuracy: 0.5801 - val_top5_acc: 0.8652 - val_macro_f1score: 0.2411
# Learning rate:  0.0001
#
# Epoch 00043: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 43/70
# 194/194 [==============================] - ETA: 0s - loss: 0.6498 - accuracy: 0.8020 - top5_acc: 0.9721 - macro_f1score: 0.3941
# Epoch 00043: val_loss did not improve from 1.48040
#
# Epoch 00043: val_accuracy did not improve from 0.58203
# 194/194 [==============================] - 404s 2s/step - loss: 0.6498 - accuracy: 0.8020 - top5_acc: 0.9721 - macro_f1score: 0.3941 - val_loss: 1.5907 - val_accuracy: 0.5677 - val_top5_acc: 0.8626 - val_macro_f1score: 0.2536
# Learning rate:  0.0001
#
# Epoch 00044: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 44/70
# 194/194 [==============================] - ETA: 0s - loss: 0.6455 - accuracy: 0.8025 - top5_acc: 0.9721 - macro_f1score: 0.3929
# Epoch 00044: val_loss did not improve from 1.48040
#
# Epoch 00044: val_accuracy did not improve from 0.58203
# 194/194 [==============================] - 404s 2s/step - loss: 0.6455 - accuracy: 0.8025 - top5_acc: 0.9721 - macro_f1score: 0.3929 - val_loss: 1.6158 - val_accuracy: 0.5579 - val_top5_acc: 0.8555 - val_macro_f1score: 0.2453
# Learning rate:  0.0001
#
# Epoch 00045: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 45/70
# 194/194 [==============================] - ETA: 0s - loss: 0.6065 - accuracy: 0.8145 - top5_acc: 0.9769 - macro_f1score: 0.4052
# Epoch 00045: val_loss did not improve from 1.48040
#
# Epoch 00045: val_accuracy did not improve from 0.58203
# 194/194 [==============================] - 404s 2s/step - loss: 0.6065 - accuracy: 0.8145 - top5_acc: 0.9769 - macro_f1score: 0.4052 - val_loss: 1.5882 - val_accuracy: 0.5801 - val_top5_acc: 0.8678 - val_macro_f1score: 0.2551
# Learning rate:  0.0001
#
# Epoch 00046: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 46/70
# 194/194 [==============================] - ETA: 0s - loss: 0.5976 - accuracy: 0.8177 - top5_acc: 0.9779 - macro_f1score: 0.4089
# Epoch 00046: val_loss did not improve from 1.48040
#
# Epoch 00046: val_accuracy improved from 0.58203 to 0.58594, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/Inception_v4/046.h5
# 194/194 [==============================] - 409s 2s/step - loss: 0.5976 - accuracy: 0.8177 - top5_acc: 0.9779 - macro_f1score: 0.4089 - val_loss: 1.5385 - val_accuracy: 0.5859 - val_top5_acc: 0.8757 - val_macro_f1score: 0.2610
# Learning rate:  0.0001
#
# Epoch 00047: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 47/70
# 194/194 [==============================] - ETA: 0s - loss: 0.5589 - accuracy: 0.8287 - top5_acc: 0.9798 - macro_f1score: 0.4135
# Epoch 00047: val_loss did not improve from 1.48040
#
# Epoch 00047: val_accuracy did not improve from 0.58594
# 194/194 [==============================] - 412s 2s/step - loss: 0.5589 - accuracy: 0.8287 - top5_acc: 0.9798 - macro_f1score: 0.4135 - val_loss: 1.6042 - val_accuracy: 0.5599 - val_top5_acc: 0.8522 - val_macro_f1score: 0.2475
# Learning rate:  0.0001
#
# Epoch 00048: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 48/70
# 194/194 [==============================] - ETA: 0s - loss: 0.5557 - accuracy: 0.8272 - top5_acc: 0.9802 - macro_f1score: 0.4125
# Epoch 00048: val_loss did not improve from 1.48040
#
# Epoch 00048: val_accuracy did not improve from 0.58594
# 194/194 [==============================] - 408s 2s/step - loss: 0.5557 - accuracy: 0.8272 - top5_acc: 0.9802 - macro_f1score: 0.4125 - val_loss: 1.7371 - val_accuracy: 0.5501 - val_top5_acc: 0.8418 - val_macro_f1score: 0.2429
# Learning rate:  0.0001
#
# Epoch 00049: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 49/70
# 194/194 [==============================] - ETA: 0s - loss: 0.5303 - accuracy: 0.8404 - top5_acc: 0.9831 - macro_f1score: 0.4200
# Epoch 00049: val_loss did not improve from 1.48040
#
# Epoch 00049: val_accuracy did not improve from 0.58594
# 194/194 [==============================] - 404s 2s/step - loss: 0.5303 - accuracy: 0.8404 - top5_acc: 0.9831 - macro_f1score: 0.4200 - val_loss: 1.6767 - val_accuracy: 0.5553 - val_top5_acc: 0.8509 - val_macro_f1score: 0.2379
# Learning rate:  0.0001
#
# Epoch 00050: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 50/70
# 194/194 [==============================] - ETA: 0s - loss: 0.5119 - accuracy: 0.8435 - top5_acc: 0.9849 - macro_f1score: 0.4266
# Epoch 00050: val_loss did not improve from 1.48040
#
# Epoch 00050: val_accuracy did not improve from 0.58594
# 194/194 [==============================] - 409s 2s/step - loss: 0.5119 - accuracy: 0.8435 - top5_acc: 0.9849 - macro_f1score: 0.4266 - val_loss: 1.5839 - val_accuracy: 0.5794 - val_top5_acc: 0.8665 - val_macro_f1score: 0.2564
# Learning rate:  0.0001
#
# Epoch 00051: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 51/70
# 194/194 [==============================] - ETA: 0s - loss: 0.4893 - accuracy: 0.8541 - top5_acc: 0.9852 - macro_f1score: 0.4323
# Epoch 00051: val_loss did not improve from 1.48040
#
# Epoch 00051: val_accuracy did not improve from 0.58594
# 194/194 [==============================] - 410s 2s/step - loss: 0.4893 - accuracy: 0.8541 - top5_acc: 0.9852 - macro_f1score: 0.4323 - val_loss: 1.6823 - val_accuracy: 0.5540 - val_top5_acc: 0.8464 - val_macro_f1score: 0.2426
# Learning rate:  0.0001
#
# Epoch 00052: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 52/70
# 194/194 [==============================] - ETA: 0s - loss: 0.4790 - accuracy: 0.8581 - top5_acc: 0.9871 - macro_f1score: 0.4329
# Epoch 00052: val_loss did not improve from 1.48040
#
# Epoch 00052: val_accuracy improved from 0.58594 to 0.59766, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/Inception_v4/052.h5
# 194/194 [==============================] - 413s 2s/step - loss: 0.4790 - accuracy: 0.8581 - top5_acc: 0.9871 - macro_f1score: 0.4329 - val_loss: 1.5304 - val_accuracy: 0.5977 - val_top5_acc: 0.8646 - val_macro_f1score: 0.2571
# Learning rate:  0.0001
#
# Epoch 00053: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 53/70
# 194/194 [==============================] - ETA: 0s - loss: 0.4673 - accuracy: 0.8578 - top5_acc: 0.9886 - macro_f1score: 0.4327
# Epoch 00053: val_loss did not improve from 1.48040
#
# Epoch 00053: val_accuracy did not improve from 0.59766
# 194/194 [==============================] - 409s 2s/step - loss: 0.4673 - accuracy: 0.8578 - top5_acc: 0.9886 - macro_f1score: 0.4327 - val_loss: 1.6110 - val_accuracy: 0.5605 - val_top5_acc: 0.8704 - val_macro_f1score: 0.2533
# Learning rate:  0.0001
#
# Epoch 00054: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 54/70
# 194/194 [==============================] - ETA: 0s - loss: 0.4500 - accuracy: 0.8674 - top5_acc: 0.9884 - macro_f1score: 0.4392
# Epoch 00054: val_loss did not improve from 1.48040
#
# Epoch 00054: val_accuracy did not improve from 0.59766
# 194/194 [==============================] - 409s 2s/step - loss: 0.4500 - accuracy: 0.8674 - top5_acc: 0.9884 - macro_f1score: 0.4392 - val_loss: 1.6743 - val_accuracy: 0.5547 - val_top5_acc: 0.8503 - val_macro_f1score: 0.2445
# Learning rate:  0.0001
#
# Epoch 00055: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 55/70
# 194/194 [==============================] - ETA: 0s - loss: 0.4244 - accuracy: 0.8737 - top5_acc: 0.9906 - macro_f1score: 0.4474
# Epoch 00055: val_loss did not improve from 1.48040
#
# Epoch 00055: val_accuracy did not improve from 0.59766
# 194/194 [==============================] - 410s 2s/step - loss: 0.4244 - accuracy: 0.8737 - top5_acc: 0.9906 - macro_f1score: 0.4474 - val_loss: 1.6600 - val_accuracy: 0.5697 - val_top5_acc: 0.8626 - val_macro_f1score: 0.2583
# Learning rate:  0.0001
#
# Epoch 00056: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 56/70
# 194/194 [==============================] - ETA: 0s - loss: 0.4082 - accuracy: 0.8776 - top5_acc: 0.9913 - macro_f1score: 0.4472
# Epoch 00056: val_loss did not improve from 1.48040
#
# Epoch 00056: val_accuracy did not improve from 0.59766
# 194/194 [==============================] - 411s 2s/step - loss: 0.4082 - accuracy: 0.8776 - top5_acc: 0.9913 - macro_f1score: 0.4472 - val_loss: 1.6138 - val_accuracy: 0.5859 - val_top5_acc: 0.8600 - val_macro_f1score: 0.2623
# Learning rate:  0.0001
#
# Epoch 00057: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 57/70
# 194/194 [==============================] - ETA: 0s - loss: 0.4023 - accuracy: 0.8814 - top5_acc: 0.9906 - macro_f1score: 0.4456
# Epoch 00057: val_loss did not improve from 1.48040
#
# Epoch 00057: val_accuracy did not improve from 0.59766
# 194/194 [==============================] - 407s 2s/step - loss: 0.4023 - accuracy: 0.8814 - top5_acc: 0.9906 - macro_f1score: 0.4456 - val_loss: 1.5861 - val_accuracy: 0.5905 - val_top5_acc: 0.8730 - val_macro_f1score: 0.2711
# Learning rate:  0.0001
#
# Epoch 00058: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 58/70
# 194/194 [==============================] - ETA: 0s - loss: 0.3869 - accuracy: 0.8868 - top5_acc: 0.9903 - macro_f1score: 0.4619
# Epoch 00058: val_loss did not improve from 1.48040
#
# Epoch 00058: val_accuracy did not improve from 0.59766
# 194/194 [==============================] - 412s 2s/step - loss: 0.3869 - accuracy: 0.8868 - top5_acc: 0.9903 - macro_f1score: 0.4619 - val_loss: 1.7068 - val_accuracy: 0.5671 - val_top5_acc: 0.8535 - val_macro_f1score: 0.2517
# Learning rate:  0.0001
#
# Epoch 00059: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 59/70
# 194/194 [==============================] - ETA: 0s - loss: 0.3691 - accuracy: 0.8928 - top5_acc: 0.9917 - macro_f1score: 0.4615
# Epoch 00059: val_loss did not improve from 1.48040
#
# Epoch 00059: val_accuracy did not improve from 0.59766
# 194/194 [==============================] - 409s 2s/step - loss: 0.3691 - accuracy: 0.8928 - top5_acc: 0.9917 - macro_f1score: 0.4615 - val_loss: 1.7098 - val_accuracy: 0.5710 - val_top5_acc: 0.8490 - val_macro_f1score: 0.2560
# Learning rate:  0.0001
#
# Epoch 00060: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 60/70
# 194/194 [==============================] - ETA: 0s - loss: 0.3718 - accuracy: 0.8924 - top5_acc: 0.9923 - macro_f1score: 0.4604
# Epoch 00060: val_loss did not improve from 1.48040
#
# Epoch 00060: val_accuracy did not improve from 0.59766
# 194/194 [==============================] - 412s 2s/step - loss: 0.3718 - accuracy: 0.8924 - top5_acc: 0.9923 - macro_f1score: 0.4604 - val_loss: 1.6826 - val_accuracy: 0.5703 - val_top5_acc: 0.8522 - val_macro_f1score: 0.2554
# Learning rate:  1e-05
#
# Epoch 00061: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 61/70
# 194/194 [==============================] - ETA: 0s - loss: 0.3063 - accuracy: 0.9142 - top5_acc: 0.9946 - macro_f1score: 0.4765
# Epoch 00061: val_loss did not improve from 1.48040
#
# Epoch 00061: val_accuracy did not improve from 0.59766
# 194/194 [==============================] - 409s 2s/step - loss: 0.3063 - accuracy: 0.9142 - top5_acc: 0.9946 - macro_f1score: 0.4765 - val_loss: 1.5684 - val_accuracy: 0.5918 - val_top5_acc: 0.8672 - val_macro_f1score: 0.2758
# Learning rate:  1e-05
#
# Epoch 00062: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 62/70
# 194/194 [==============================] - ETA: 0s - loss: 0.2761 - accuracy: 0.9279 - top5_acc: 0.9965 - macro_f1score: 0.4876
# Epoch 00062: val_loss did not improve from 1.48040
#
# Epoch 00062: val_accuracy improved from 0.59766 to 0.60156, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/Inception_v4/062.h5
# 194/194 [==============================] - 414s 2s/step - loss: 0.2761 - accuracy: 0.9279 - top5_acc: 0.9965 - macro_f1score: 0.4876 - val_loss: 1.4989 - val_accuracy: 0.6016 - val_top5_acc: 0.8750 - val_macro_f1score: 0.2814
# Learning rate:  1e-05
#
# Epoch 00063: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 63/70
# 194/194 [==============================] - ETA: 0s - loss: 0.2658 - accuracy: 0.9332 - top5_acc: 0.9958 - macro_f1score: 0.4892
# Epoch 00063: val_loss did not improve from 1.48040
#
# Epoch 00063: val_accuracy improved from 0.60156 to 0.61068, saving model to /content/drive/My Drive/Colab Notebooks/Paper/MIT/No_GAN/model_output/1/Inception_v4/063.h5
# 194/194 [==============================] - 412s 2s/step - loss: 0.2658 - accuracy: 0.9332 - top5_acc: 0.9958 - macro_f1score: 0.4892 - val_loss: 1.5056 - val_accuracy: 0.6107 - val_top5_acc: 0.8743 - val_macro_f1score: 0.2799
# Learning rate:  1e-05
#
# Epoch 00064: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 64/70
# 194/194 [==============================] - ETA: 0s - loss: 0.2556 - accuracy: 0.9383 - top5_acc: 0.9980 - macro_f1score: 0.4898
# Epoch 00064: val_loss did not improve from 1.48040
#
# Epoch 00064: val_accuracy did not improve from 0.61068
# 194/194 [==============================] - 411s 2s/step - loss: 0.2556 - accuracy: 0.9383 - top5_acc: 0.9980 - macro_f1score: 0.4898 - val_loss: 1.5253 - val_accuracy: 0.6061 - val_top5_acc: 0.8743 - val_macro_f1score: 0.2765
# Learning rate:  1e-05
#
# Epoch 00065: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 65/70
# 194/194 [==============================] - ETA: 0s - loss: 0.2616 - accuracy: 0.9354 - top5_acc: 0.9962 - macro_f1score: 0.4930
# Epoch 00065: val_loss did not improve from 1.48040
#
# Epoch 00065: val_accuracy did not improve from 0.61068
# 194/194 [==============================] - 409s 2s/step - loss: 0.2616 - accuracy: 0.9354 - top5_acc: 0.9962 - macro_f1score: 0.4930 - val_loss: 1.5066 - val_accuracy: 0.5983 - val_top5_acc: 0.8717 - val_macro_f1score: 0.2804
# Learning rate:  1e-05
#
# Epoch 00066: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 66/70
# 194/194 [==============================] - ETA: 0s - loss: 0.2578 - accuracy: 0.9388 - top5_acc: 0.9969 - macro_f1score: 0.4941
# Epoch 00066: val_loss did not improve from 1.48040
#
# Epoch 00066: val_accuracy did not improve from 0.61068
# 194/194 [==============================] - 410s 2s/step - loss: 0.2578 - accuracy: 0.9388 - top5_acc: 0.9969 - macro_f1score: 0.4941 - val_loss: 1.5004 - val_accuracy: 0.6022 - val_top5_acc: 0.8757 - val_macro_f1score: 0.2814
# Learning rate:  1e-05
#
# Epoch 00067: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 67/70
# 194/194 [==============================] - ETA: 0s - loss: 0.2505 - accuracy: 0.9413 - top5_acc: 0.9973 - macro_f1score: 0.4907
# Epoch 00067: val_loss did not improve from 1.48040
#
# Epoch 00067: val_accuracy did not improve from 0.61068
# 194/194 [==============================] - 409s 2s/step - loss: 0.2505 - accuracy: 0.9413 - top5_acc: 0.9973 - macro_f1score: 0.4907 - val_loss: 1.5130 - val_accuracy: 0.5983 - val_top5_acc: 0.8717 - val_macro_f1score: 0.2812
# Learning rate:  1e-05
#
# Epoch 00068: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 68/70
# 194/194 [==============================] - ETA: 0s - loss: 0.2563 - accuracy: 0.9399 - top5_acc: 0.9970 - macro_f1score: 0.4948
# Epoch 00068: val_loss did not improve from 1.48040
#
# Epoch 00068: val_accuracy did not improve from 0.61068
# 194/194 [==============================] - 411s 2s/step - loss: 0.2563 - accuracy: 0.9399 - top5_acc: 0.9970 - macro_f1score: 0.4948 - val_loss: 1.5223 - val_accuracy: 0.6016 - val_top5_acc: 0.8691 - val_macro_f1score: 0.2740
# Learning rate:  1e-05
#
# Epoch 00069: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 69/70
# 194/194 [==============================] - ETA: 0s - loss: 0.2440 - accuracy: 0.9465 - top5_acc: 0.9975 - macro_f1score: 0.4964
# Epoch 00069: val_loss did not improve from 1.48040
#
# Epoch 00069: val_accuracy did not improve from 0.61068
# 194/194 [==============================] - 410s 2s/step - loss: 0.2440 - accuracy: 0.9465 - top5_acc: 0.9975 - macro_f1score: 0.4964 - val_loss: 1.4923 - val_accuracy: 0.6009 - val_top5_acc: 0.8730 - val_macro_f1score: 0.2699
# Learning rate:  1e-05
#
# Epoch 00070: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 70/70
# 194/194 [==============================] - ETA: 0s - loss: 0.2505 - accuracy: 0.9450 - top5_acc: 0.9981 - macro_f1score: 0.4917
# Epoch 00070: val_loss did not improve from 1.48040
#
# Epoch 00070: val_accuracy did not improve from 0.61068
# 194/194 [==============================] - 410s 2s/step - loss: 0.2505 - accuracy: 0.9450 - top5_acc: 0.9981 - macro_f1score: 0.4917 - val_loss: 1.5042 - val_accuracy: 0.5983 - val_top5_acc: 0.8698 - val_macro_f1score: 0.2701

# %% [markdown]
# ### 3) Inception-V4 Evaluate

# %%
# 1. epoch=maximum
loss , acc, top5_acc, mf1 = model.evaluate(test_generator,steps=int(len(x_test)/batch_sizes))
print('[Test Loss: %.4f /  Test Top-1 Accuracy: %.4f / Test Top-5 Accuracy: %.4f / Test Macro f1: %.4f]\n' % (loss,acc,top5_acc,mf1))
# Out:
# 24/24 [==============================] - 557s 23s/step - loss: 1.5537 - accuracy: 0.5957 - top5_acc: 0.8561 - macro_f1score: 0.2741
# [Test Loss: 1.5537 /  Test Top-1 Accuracy: 0.5957 / Test Top-5 Accuracy: 0.8561 / Test Macro f1: 0.2741]

# %%
loss=history.history['loss']
val_loss=history.history['val_loss']
acc=history.history['accuracy']
val_acc=history.history['val_accuracy']
top5_acc=history.history['top5_acc']
val_top5_acc=history.history['val_top5_acc']
f1=history.history['macro_f1score']
val_f1=history.history['val_macro_f1score']
epochs=range(1,len(acc)+1)

data = np.array([epochs,loss,val_loss,acc,val_acc,top5_acc,val_top5_acc,f1,val_f1]).T

# %%
# data save
# epochs, loss, val_loss, acc, val_acc, top5_acc, val_top5_acc, f1, val_f1

np.savetxt(os.path.join(dir,'train_valid_output',number,model.name+'.txt'),data)

# %%
# data import
data = np.loadtxt(os.path.join(dir,'train_valid_output',number,'Inception_v4.txt'))

# %%
epochs=data[:,0]
loss=data[:,1]
val_loss=data[:,2]
acc=data[:,3]
val_acc=data[:,4]
top5_acc=data[:,5]
val_top5_acc=data[:,6]

# %%
plt.plot(epochs[1:],acc[1:],'b',label='Training 1-Acc')
plt.plot(epochs[1:],val_acc[1:],'r',label='Validation 1-Acc')
plt.title('Training and Validation Top-1 Accuracy')
plt.legend()
plt.figure()

plt.plot(epochs[1:],top5_acc[1:],'b',label='Training 5-Acc')
plt.plot(epochs[1:],val_top5_acc[1:],'r',label='Validation 5-Acc')
plt.title('Training and Validation Top-5 Accuracy')
plt.legend()
plt.figure()

plt.plot(epochs[10:],loss[10:],'b',label='Training Loss')
plt.plot(epochs[10:],val_loss[10:],'r',label='Validation Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()

# %%
# 이 아래는 내가 인위적으로 살펴보고 싶은 epoch에 대해서 결과값 출력 / Inception-V4

# %%
# 참고 : https://github.com/OverLordGoldDragon/keras-adamw

import sys
sys.path.append('/content/drive/My Drive/Colab Notebooks/Paper')
import utils
import optimizers_v2
from utils import get_weight_decays, fill_dict_in_order
from utils import reset_seeds, K_eval
from optimizers_v2 import AdamW, NadamW, SGDW

# %%
# top-5 accuracy 출력
import functools
top5_acc = functools.partial(ks.metrics.top_k_categorical_accuracy, k=5)
top5_acc.__name__ = 'top5_acc'

# %%
model=load_model(os.path.join(dir,'model_output',number,'Inception_v4','063.h5'),custom_objects={"macro_f1score": macro_f1score,"top5_acc":top5_acc, "AdamW":AdamW})

# %%
# 2. epoch=?
loss , acc, top5_acc, mf1 = model.evaluate(test_generator,steps=int(len(x_test)/batch_sizes))
print('[Test Loss: %.4f /  Test Top-1 Accuracy: %.4f / Test Top-5 Accuracy: %.4f / Test Macro f1: %.4f]\n' % (loss,acc,top5_acc,mf1))
# Out:
# 24/24 [==============================] - 1025s 43s/step - loss: 1.5736 - accuracy: 0.5983 - top5_acc: 0.8613 - macro_f1score: 0.2777
# [Test Loss: 1.5736 /  Test Top-1 Accuracy: 0.5983 / Test Top-5 Accuracy: 0.8613 / Test Macro f1: 0.2777]
