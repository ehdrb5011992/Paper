# %% [markdown]
# # [GoogLeNet]

# %% [markdown]
# *KU LeeDongGyu*

# %% [markdown]
# ## Contents
# ---

# %% [markdown]
# 1. Data Preprocessing
# ```
# 1) Data Import
# 2) Data Augmentation
# ```
# 2. Support Functions & Almost Original GoogLeNet
# ```
# 1) Support Functions
# 2) Almost Original GoogLeNet
# 3) GoogLeNet Evaluate
# ```

# %% [markdown]
# ### Install Packages

# %% [markdown]
# ### Module

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/My Drive/Colab Notebooks/Paper
# Out:
# /content/drive/My Drive/Colab Notebooks/Paper

# %%
from f1score import macro_f1score,weighted_f1score
from pool_helper import PoolHelper
from lrn import LRN

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import cv2
import tensorflow as tf
from tensorflow import keras as ks
from tensorflow.keras import backend as K 
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, Input, Concatenate, ZeroPadding2D ,GlobalMaxPooling2D, Reshape , Lambda , Add, Multiply
from tensorflow.keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D, Activation, BatchNormalization, AveragePooling2D , ZeroPadding2D, SeparableConv2D
from tensorflow.keras.layers import add
from tensorflow.keras.optimizers import Adam, RMSprop , SGD
from tensorflow.keras.callbacks import EarlyStopping , LearningRateScheduler, ModelCheckpoint, CSVLogger, Callback, ReduceLROnPlateau
from tensorflow.keras.regularizers import l1,l2,l1_l2
from tensorflow.keras.models import Model , load_model , Sequential
from tensorflow.keras.utils import plot_model , to_categorical, get_file
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
os.getcwd()
# Out:
# '/content/drive/My Drive/Colab Notebooks/Paper'

# %%
print(tf.__version__)
print(ks.__version__)
# Out:
# 2.3.0
# 2.4.0

# %%
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 16909142255481888001
# , name: "/device:XLA_CPU:0"
# device_type: "XLA_CPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 17023579515303890547
# physical_device_desc: "device: XLA_CPU device"
# , name: "/device:XLA_GPU:0"
# device_type: "XLA_GPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 954483780181088526
# physical_device_desc: "device: XLA_GPU device"
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 15695549568
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 2808188530853231633
# physical_device_desc: "device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0"
# ]

# %% [markdown]
# ## 1. Data Preprocessing
# ---

# %% [markdown]
# ### 1) Data Import

# %%
# 바꿔서 살펴 볼 것들
# CALTECH, CIFAR100, FER, MIT
data_name = 'CALTECH'
gan_type = 'No_GAN'
number = '1'
size = 224
super_size = 256
input_sizes = (size,size,3)
batch_sizes = 128
weight_decay = 1e-4
epochs = 70

# %%
# 참고 : https://stackoverflow.com/questions/32419510/how-to-get-reproducible-results-in-keras/52897216#52897216
# setting the seed number for random number generation for reproducibility.

from numpy.random import seed
import random


if number=='1':
    seed_num = 200225
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)
elif number=='2':
    seed_num = 727
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)
elif number=='3':
    seed_num = 115
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)
elif number=='4':
    seed_num = 501
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)
elif number=='5':
    seed_num = 517
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)

# %%
# data import

if data_name=='FER' :
    x_train =  np.zeros(28698)
    x_valid = np.zeros(3589)
    x_test = np.zeros(3588)
    classes = 7 
    tr_center = [0.50793296, 0.50793296, 0.50793296]
elif data_name=='MIT':
    x_train = np.zeros(12466)
    x_valid = np.zeros(1564)
    x_test = np.zeros(1590)
    classes = 67 
    tr_center = [0.47916578, 0.42029615, 0.36046057]
elif data_name=='CALTECH':
    x_train = np.zeros(24510)
    x_valid = np.zeros(2980)
    x_test = np.zeros(3118)
    classes = 257
    tr_center = [0.51397761, 0.49525248, 0.46555727]
elif data_name=='CIFAR100':
    x_train = np.zeros(44923)
    x_valid = np.zeros(5077)
    x_test = np.zeros(10000)
    classes = 100
    tr_center = [0.53442983, 0.51355958, 0.46462564]

# %%
dir = os.path.join(os.getcwd(),data_name,gan_type)

# %% [markdown]
# ### 2) Data Augmentation

# %%
# 참고 : https://jkjung-avt.github.io/keras-image-cropping/

def random_crop(img, random_crop_size):
    # Note: image_data_format is 'channel_last'
    assert img.shape[2] == 3 # img.shape[2] 가 3(rgb)이 아니면 assertion error 발생
    height, width = img.shape[0], img.shape[1]
    dy, dx = random_crop_size
    x = np.random.randint(0, width - dx + 1)
    y = np.random.randint(0, height - dy + 1)
    return img[y:(y+dy), x:(x+dx), :]


def crop_generator(batches, crop_length):
    """Take as input a Keras ImageGen (Iterator) and generate random
    crops from the image batches generated by the original iterator.
    """
    while True:
        batch_x, batch_y = next(batches)
        batch_crops = np.zeros((batch_x.shape[0], crop_length, crop_length, 3))
        for i in range(batch_x.shape[0]):
            batch_crops[i] = random_crop(batch_x[i], (crop_length, crop_length))
        yield (batch_crops, batch_y)

# %%
from tensorflow.keras.preprocessing.image import img_to_array,load_img
import glob

# 데이터 전체에 대해 centering 진행함.

def read_cal_image(img_path): 
    x = img_to_array(load_img(img_path)) # x는 채널별 평균값
    y = x.shape[0] * x.shape[1]# y는 데이터별 픽셀 수 (비중)

    x = 1/255. * x # scaling하고, centering값을 뽑아냄.
    x = np.mean(x, axis=(0,1))
    
    return np.hstack([x,y])

def calculate_centered_mean(dataset_path,x_train=x_train):
    num = len(x_train)
    space = np.empty((num,4))
    i=0

    for p in glob.glob(os.path.join(dataset_path,'*/*.*')) :
        space[i] = read_cal_image(p)
        i += 1

    ratio = space[:,3] / np.sum(space[:,3])

    return np.average(space[:,0:3],axis=0,weights=ratio)


# 아래의 함수를 돌려서 나온 결과값을 중심화 값으로 설정.

# train_mean = calculate_centered_mean(os.path.join(dir,'data/train')).reshape((1,1,3))

# %%
datagen_tr = ImageDataGenerator(
    rescale=1/255.,
    horizontal_flip=True,
    featurewise_center=True,
    featurewise_std_normalization=False,
    rotation_range=10,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=[0.9,1.0],
    fill_mode = 'nearest')
datagen_val = ImageDataGenerator(rescale=1/255.,featurewise_center=True)
datagen_tes = ImageDataGenerator(rescale=1/255.,featurewise_center=True)

# 원래는 이 자리에 fit 매서드를 써야하지만, 그냥 내가 중심화함수를 만들고 적용함. 

# 중심화 설정
datagen_tr.mean = np.array(tr_center, dtype=np.float32).reshape((1,1,3)) # RGB
datagen_val.mean = np.array(tr_center, dtype=np.float32).reshape((1,1,3)) # RGB
datagen_tes.mean = np.array(tr_center, dtype=np.float32).reshape((1,1,3)) # RGB

# %%
# 매우 간단하다.

#1. train data

def generate_train_for_three(crop_length=size, batch_sizes = batch_sizes, super_size=super_size):

      batches = datagen_tr.flow_from_directory(directory=os.path.join(dir,'data/train'),target_size=(super_size,super_size),batch_size=batch_sizes,class_mode='categorical')

      while True:
          batch_x, batch_y = next(batches)
          batch_crops = np.zeros((batch_x.shape[0], crop_length, crop_length, 3))
          for i in range(batch_x.shape[0]):
              batch_crops[i] = random_crop(batch_x[i], (crop_length, crop_length))
          yield batch_crops, [batch_y,batch_y,batch_y]

# %%
# 2. valid data

def generate_valid_for_three(size=size, batch_sizes = batch_sizes):

      batches_xy = datagen_val.flow_from_directory(directory=os.path.join(dir,'data/valid'),target_size=(size,size),batch_size=batch_sizes,class_mode='categorical')

      while True:

          batch_xy = batches_xy.next()
          yield  batch_xy[0], [ batch_xy[1],batch_xy[1],batch_xy[1] ]

# %%
# 3. test data

def generate_test_for_three(size=size, batch_sizes = batch_sizes):

      batches_xy = datagen_tes.flow_from_directory(directory=os.path.join(dir,'data/test'),target_size=(size,size),batch_size=batch_sizes,class_mode='categorical')

      while True:

          batch_xy = batches_xy.next()
          yield  batch_xy[0], [ batch_xy[1],batch_xy[1],batch_xy[1] ]

# %%
# 위에서 쓰임
# train_batches = datagen_tr.flow_from_directory(directory=os.path.join(dir,'data/train'),target_size=(super_size,super_size),batch_size=batch_sizes,class_mode='categorical') # fer : 28698 / mit : 12466 / caltech : 24509 / cifar : 44923
# train_generator= crop_generator(train_batches, size)

# valid_generator = datagen_val.flow_from_directory(directory=os.path.join(dir,'data/valid'),target_size=(size,size),batch_size=batch_sizes,class_mode='categorical') # fer : 3589 / mit : 1564 / caltech : 2980 / cifar : 5077
# test_generator = datagen_tes.flow_from_directory(directory=os.path.join(dir,'data/test'),target_size=(size,size),batch_size=batch_sizes,class_mode='categorical') # fer : 3588 / mit : 1590 / caltech : 3118 / cifar : 10000

# %% [markdown]
# ## 2. Support Functions & Almost Original GoogLeNet
# ---

# %% [markdown]
# ### 1) Support Functions

# %%
# def lr_schedule(epoch):
#     init_lr = 1e-4
#     k = 0.04
#     lr = init_lr * np.exp(-k*epoch)
#     print('Learning rate: ', lr)
#     return lr

def lr_schedule(epoch):
    lr = 3e-4
    if epoch < 30:
        lr = lr
    elif epoch < 60 :
        lr = lr * 0.1
    else:
        lr = lr * 0.01
    print('Learning rate: ', lr)
    return lr

# %% [markdown]
# ### 3) Almost Original GoogLeNet

# %%
# GoogLeNet를 최대한 논문에 가깝게 맞춰 모형작성.

def googlenet(input_shape=(224,224,3), classes=1000, weight_decay = weight_decay, weights_path = None,name='Inception_v1'):

    input = Input(input_shape)

    conv1_7x7_s2 = Conv2D(64, (7,7), strides=(2,2), padding='same', activation='relu', name='conv1/7x7_s2', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(input)
    pool1_3x3_s2 = MaxPooling2D(pool_size=(3,3), strides=(2,2), padding='same', name='pool1/3x3_s2')(conv1_7x7_s2)
    pool1_norm1 = LRN(name='pool1/norm1')(pool1_3x3_s2)

    conv2_3x3_reduce = Conv2D(64, (1,1), padding='same', activation='relu', name='conv2/3x3_reduce', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(pool1_norm1)
    conv2_3x3 = Conv2D(192, (3,3), padding='same', activation='relu', name='conv2/3x3', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(conv2_3x3_reduce)
    conv2_norm2 = LRN(name='conv2/norm2')(conv2_3x3)
    pool2_3x3_s2 = MaxPooling2D(pool_size=(3,3), strides=(2,2), padding='same', name='pool2/3x3_s2')(conv2_norm2)

    inception_3a_1x1 = Conv2D(64, (1,1), padding='same', activation='relu', name='inception_3a/1x1', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(pool2_3x3_s2)
    inception_3a_3x3_reduce = Conv2D(96, (1,1), padding='same', activation='relu', name='inception_3a/3x3_reduce', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(pool2_3x3_s2)
    inception_3a_3x3_pad = ZeroPadding2D(padding=(1, 1))(inception_3a_3x3_reduce)
    inception_3a_3x3 = Conv2D(128, (3,3), padding='valid', activation='relu', name='inception_3a/3x3', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_3a_3x3_pad)
    inception_3a_5x5_reduce = Conv2D(16, (1,1), padding='same', activation='relu', name='inception_3a/5x5_reduce', kernel_regularizer=l2(weight_decay))(pool2_3x3_s2)
    inception_3a_5x5_pad = ZeroPadding2D(padding=(2, 2))(inception_3a_5x5_reduce)
    inception_3a_5x5 = Conv2D(32, (5,5), padding='valid', activation='relu', name='inception_3a/5x5', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_3a_5x5_pad)
    inception_3a_pool = MaxPooling2D(pool_size=(3,3), strides=(1,1), padding='same', name='inception_3a/pool')(pool2_3x3_s2)
    inception_3a_pool_proj = Conv2D(32, (1,1), padding='same', activation='relu', name='inception_3a/pool_proj', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_3a_pool)
    inception_3a_output = Concatenate(axis=-1, name='inception_3a/output')([inception_3a_1x1,inception_3a_3x3,inception_3a_5x5,inception_3a_pool_proj])
    # Concatenate axis 수정.

    inception_3b_1x1 = Conv2D(128, (1,1), padding='same', activation='relu', name='inception_3b/1x1', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_3a_output)
    inception_3b_3x3_reduce = Conv2D(128, (1,1), padding='same', activation='relu', name='inception_3b/3x3_reduce', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_3a_output)
    inception_3b_3x3_pad = ZeroPadding2D(padding=(1, 1))(inception_3b_3x3_reduce)
    inception_3b_3x3 = Conv2D(192, (3,3), padding='valid', activation='relu', name='inception_3b/3x3', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_3b_3x3_pad)
    inception_3b_5x5_reduce = Conv2D(32, (1,1), padding='same', activation='relu', name='inception_3b/5x5_reduce', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_3a_output)
    inception_3b_5x5_pad = ZeroPadding2D(padding=(2, 2))(inception_3b_5x5_reduce)
    inception_3b_5x5 = Conv2D(96, (5,5), padding='valid', activation='relu', name='inception_3b/5x5', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_3b_5x5_pad)
    inception_3b_pool = MaxPooling2D(pool_size=(3,3), strides=(1,1), padding='same', name='inception_3b/pool')(inception_3a_output)
    inception_3b_pool_proj = Conv2D(64, (1,1), padding='same', activation='relu', name='inception_3b/pool_proj', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_3b_pool)
    inception_3b_output = Concatenate(axis=-1, name='inception_3b/output')([inception_3b_1x1,inception_3b_3x3,inception_3b_5x5,inception_3b_pool_proj])

    pool3_3x3_s2 = MaxPooling2D(pool_size=(3,3), strides=(2,2), padding='same', name='pool3/3x3_s2')(inception_3b_output)

    inception_4a_1x1 = Conv2D(192, (1,1), padding='same', activation='relu', name='inception_4a/1x1', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(pool3_3x3_s2)
    inception_4a_3x3_reduce = Conv2D(96, (1,1), padding='same', activation='relu', name='inception_4a/3x3_reduce', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(pool3_3x3_s2)
    inception_4a_3x3_pad = ZeroPadding2D(padding=(1, 1))(inception_4a_3x3_reduce)
    inception_4a_3x3 = Conv2D(208, (3,3), padding='valid', activation='relu', name='inception_4a/3x3', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_4a_3x3_pad)
    inception_4a_5x5_reduce = Conv2D(16, (1,1), padding='same', activation='relu', name='inception_4a/5x5_reduce', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(pool3_3x3_s2)
    inception_4a_5x5_pad = ZeroPadding2D(padding=(2, 2))(inception_4a_5x5_reduce)
    inception_4a_5x5 = Conv2D(48, (5,5), padding='valid', activation='relu', name='inception_4a/5x5', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_4a_5x5_pad)
    inception_4a_pool = MaxPooling2D(pool_size=(3,3), strides=(1,1), padding='same', name='inception_4a/pool')(pool3_3x3_s2)
    inception_4a_pool_proj = Conv2D(64, (1,1), padding='same', activation='relu', name='inception_4a/pool_proj', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_4a_pool)
    inception_4a_output = Concatenate(axis=-1, name='inception_4a/output')([inception_4a_1x1,inception_4a_3x3,inception_4a_5x5,inception_4a_pool_proj])

    loss1_ave_pool = AveragePooling2D(pool_size=(5,5), strides=(3,3), name='loss1/ave_pool')(inception_4a_output)
    loss1_conv = Conv2D(128, (1,1), padding='same', activation='relu', name='loss1/conv', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(loss1_ave_pool)
    loss1_flat = Flatten()(loss1_conv)
    loss1_fc = Dense(1024, activation='relu', name='loss1/fc', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(loss1_flat)
    loss1_drop_fc = Dropout(rate=0.7)(loss1_fc)
    loss1_classifier = Dense(classes, activation='softmax', kernel_regularizer=l2(weight_decay), name='loss1/classifier')(loss1_drop_fc)

    inception_4b_1x1 = Conv2D(160, (1,1), padding='same', activation='relu', name='inception_4b/1x1', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_4a_output)
    inception_4b_3x3_reduce = Conv2D(112, (1,1), padding='same', activation='relu', name='inception_4b/3x3_reduce', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_4a_output)
    inception_4b_3x3_pad = ZeroPadding2D(padding=(1, 1))(inception_4b_3x3_reduce)
    inception_4b_3x3 = Conv2D(224, (3,3), padding='valid', activation='relu', name='inception_4b/3x3', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_4b_3x3_pad)
    inception_4b_5x5_reduce = Conv2D(24, (1,1), padding='same', activation='relu', name='inception_4b/5x5_reduce', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_4a_output)
    inception_4b_5x5_pad = ZeroPadding2D(padding=(2, 2))(inception_4b_5x5_reduce)
    inception_4b_5x5 = Conv2D(64, (5,5), padding='valid', activation='relu', name='inception_4b/5x5', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_4b_5x5_pad)
    inception_4b_pool = MaxPooling2D(pool_size=(3,3), strides=(1,1), padding='same', name='inception_4b/pool')(inception_4a_output)
    inception_4b_pool_proj = Conv2D(64, (1,1), padding='same', activation='relu', name='inception_4b/pool_proj', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_4b_pool)
    inception_4b_output = Concatenate(axis=-1, name='inception_4b/output')([inception_4b_1x1,inception_4b_3x3,inception_4b_5x5,inception_4b_pool_proj])

    inception_4c_1x1 = Conv2D(128, (1,1), padding='same', activation='relu', name='inception_4c/1x1', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_4b_output)
    inception_4c_3x3_reduce = Conv2D(128, (1,1), padding='same', activation='relu', name='inception_4c/3x3_reduce', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_4b_output)
    inception_4c_3x3_pad = ZeroPadding2D(padding=(1, 1))(inception_4c_3x3_reduce)
    inception_4c_3x3 = Conv2D(256, (3,3), padding='valid', activation='relu', name='inception_4c/3x3', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_4c_3x3_pad)
    inception_4c_5x5_reduce = Conv2D(24, (1,1), padding='same', activation='relu', name='inception_4c/5x5_reduce', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_4b_output)
    inception_4c_5x5_pad = ZeroPadding2D(padding=(2, 2))(inception_4c_5x5_reduce)
    inception_4c_5x5 = Conv2D(64, (5,5), padding='valid', activation='relu', name='inception_4c/5x5', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_4c_5x5_pad)
    inception_4c_pool = MaxPooling2D(pool_size=(3,3), strides=(1,1), padding='same', name='inception_4c/pool')(inception_4b_output)
    inception_4c_pool_proj = Conv2D(64, (1,1), padding='same', activation='relu', name='inception_4c/pool_proj', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_4c_pool)
    inception_4c_output = Concatenate(axis=-1, name='inception_4c/output')([inception_4c_1x1,inception_4c_3x3,inception_4c_5x5,inception_4c_pool_proj])

    inception_4d_1x1 = Conv2D(112, (1,1), padding='same', activation='relu', name='inception_4d/1x1', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_4c_output)
    inception_4d_3x3_reduce = Conv2D(144, (1,1), padding='same', activation='relu', name='inception_4d/3x3_reduce', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_4c_output)
    inception_4d_3x3_pad = ZeroPadding2D(padding=(1, 1))(inception_4d_3x3_reduce)
    inception_4d_3x3 = Conv2D(288, (3,3), padding='valid', activation='relu', name='inception_4d/3x3', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_4d_3x3_pad)
    inception_4d_5x5_reduce = Conv2D(32, (1,1), padding='same', activation='relu', name='inception_4d/5x5_reduce', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_4c_output)
    inception_4d_5x5_pad = ZeroPadding2D(padding=(2, 2))(inception_4d_5x5_reduce)
    inception_4d_5x5 = Conv2D(64, (5,5), padding='valid', activation='relu', name='inception_4d/5x5', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_4d_5x5_pad)
    inception_4d_pool = MaxPooling2D(pool_size=(3,3), strides=(1,1), padding='same', name='inception_4d/pool')(inception_4c_output)
    inception_4d_pool_proj = Conv2D(64, (1,1), padding='same', activation='relu', name='inception_4d/pool_proj', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_4d_pool)
    inception_4d_output = Concatenate(axis=-1, name='inception_4d/output')([inception_4d_1x1,inception_4d_3x3,inception_4d_5x5,inception_4d_pool_proj])

    loss2_ave_pool = AveragePooling2D(pool_size=(5,5), strides=(3,3), name='loss2/ave_pool')(inception_4d_output)
    loss2_conv = Conv2D(128, (1,1), padding='same', activation='relu', name='loss2/conv', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(loss2_ave_pool)
    loss2_flat = Flatten()(loss2_conv)
    loss2_fc = Dense(1024, activation='relu', name='loss2/fc', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(loss2_flat)
    loss2_drop_fc = Dropout(rate=0.7)(loss2_fc)
    loss2_classifier = Dense(classes, activation='softmax', kernel_regularizer=l2(weight_decay), name='loss2/classifier')(loss2_drop_fc)

    inception_4e_1x1 = Conv2D(256, (1,1), padding='same', activation='relu', name='inception_4e/1x1', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_4d_output)
    inception_4e_3x3_reduce = Conv2D(160, (1,1), padding='same', activation='relu', name='inception_4e/3x3_reduce', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_4d_output)
    inception_4e_3x3_pad = ZeroPadding2D(padding=(1, 1))(inception_4e_3x3_reduce)
    inception_4e_3x3 = Conv2D(320, (3,3), padding='valid', activation='relu', name='inception_4e/3x3', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_4e_3x3_pad)
    inception_4e_5x5_reduce = Conv2D(32, (1,1), padding='same', activation='relu', name='inception_4e/5x5_reduce', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_4d_output)
    inception_4e_5x5_pad = ZeroPadding2D(padding=(2, 2))(inception_4e_5x5_reduce)
    inception_4e_5x5 = Conv2D(128, (5,5), padding='valid', activation='relu', name='inception_4e/5x5', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_4e_5x5_pad)
    inception_4e_pool = MaxPooling2D(pool_size=(3,3), strides=(1,1), padding='same', name='inception_4e/pool')(inception_4d_output)
    inception_4e_pool_proj = Conv2D(128, (1,1), padding='same', activation='relu', name='inception_4e/pool_proj', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_4e_pool)
    inception_4e_output = Concatenate(axis=-1, name='inception_4e/output')([inception_4e_1x1,inception_4e_3x3,inception_4e_5x5,inception_4e_pool_proj])

    pool4_3x3_s2 = MaxPooling2D(pool_size=(3,3), strides=(2,2), padding='same', name='pool4/3x3_s2')(inception_4e_output)

    inception_5a_1x1 = Conv2D(256, (1,1), padding='same', activation='relu', name='inception_5a/1x1', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(pool4_3x3_s2)
    inception_5a_3x3_reduce = Conv2D(160, (1,1), padding='same', activation='relu', name='inception_5a/3x3_reduce', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(pool4_3x3_s2)
    inception_5a_3x3_pad = ZeroPadding2D(padding=(1, 1))(inception_5a_3x3_reduce)
    inception_5a_3x3 = Conv2D(320, (3,3), padding='valid', activation='relu', name='inception_5a/3x3', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_5a_3x3_pad)
    inception_5a_5x5_reduce = Conv2D(32, (1,1), padding='same', activation='relu', name='inception_5a/5x5_reduce', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(pool4_3x3_s2)
    inception_5a_5x5_pad = ZeroPadding2D(padding=(2, 2))(inception_5a_5x5_reduce)
    inception_5a_5x5 = Conv2D(128, (5,5), padding='valid', activation='relu', name='inception_5a/5x5', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_5a_5x5_pad)
    inception_5a_pool = MaxPooling2D(pool_size=(3,3), strides=(1,1), padding='same', name='inception_5a/pool')(pool4_3x3_s2)
    inception_5a_pool_proj = Conv2D(128, (1,1), padding='same', activation='relu', name='inception_5a/pool_proj', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_5a_pool)
    inception_5a_output = Concatenate(axis=-1, name='inception_5a/output')([inception_5a_1x1,inception_5a_3x3,inception_5a_5x5,inception_5a_pool_proj])

    inception_5b_1x1 = Conv2D(384, (1,1), padding='same', activation='relu', name='inception_5b/1x1', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_5a_output)
    inception_5b_3x3_reduce = Conv2D(192, (1,1), padding='same', activation='relu', name='inception_5b/3x3_reduce', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_5a_output)
    inception_5b_3x3_pad = ZeroPadding2D(padding=(1, 1))(inception_5b_3x3_reduce)
    inception_5b_3x3 = Conv2D(384, (3,3), padding='valid', activation='relu', name='inception_5b/3x3', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_5b_3x3_pad)
    inception_5b_5x5_reduce = Conv2D(48, (1,1), padding='same', activation='relu', name='inception_5b/5x5_reduce', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_5a_output)
    inception_5b_5x5_pad = ZeroPadding2D(padding=(2, 2))(inception_5b_5x5_reduce)
    inception_5b_5x5 = Conv2D(128, (5,5), padding='valid', activation='relu', name='inception_5b/5x5', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_5b_5x5_pad)
    inception_5b_pool = MaxPooling2D(pool_size=(3,3), strides=(1,1), padding='same', name='inception_5b/pool')(inception_5a_output)
    inception_5b_pool_proj = Conv2D(128, (1,1), padding='same', activation='relu', name='inception_5b/pool_proj', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_5b_pool)
    inception_5b_output = Concatenate(axis=-1, name='inception_5b/output')([inception_5b_1x1,inception_5b_3x3,inception_5b_5x5,inception_5b_pool_proj])

    pool5_7x7_s1 = AveragePooling2D(pool_size=(7,7), strides=(1,1), name='pool5/7x7_s2')(inception_5b_output)

    loss3_flat = Flatten()(pool5_7x7_s1)
    pool5_drop_7x7_s1 = Dropout(rate=0.4)(loss3_flat)
    loss3_classifier = Dense(classes, activation='softmax', kernel_regularizer=l2(weight_decay), name='loss3/classifier')(pool5_drop_7x7_s1)

    googlenet = Model(inputs=input, outputs=[loss1_classifier,loss2_classifier,loss3_classifier],name=name)

    if weights_path:
        googlenet.load_weights(weights_path)

    return googlenet

# %%
model = googlenet(input_shape=input_sizes, classes=classes, name='GoogleNet')

# %%
# auxiliary classifier 2개를 포함하기 때문에, 모수의 개수는 1000만개쯤 된다.
# 메인은 670만개 가량의 모수.
model.summary()
# Out:
# Model: "GoogleNet"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# conv1/7x7_s2 (Conv2D)           (None, 112, 112, 64) 9472        input_1[0][0]
# __________________________________________________________________________________________________
# pool1/3x3_s2 (MaxPooling2D)     (None, 56, 56, 64)   0           conv1/7x7_s2[0][0]
# __________________________________________________________________________________________________
# pool1/norm1 (LRN)               (None, 56, 56, 64)   0           pool1/3x3_s2[0][0]
# __________________________________________________________________________________________________
# conv2/3x3_reduce (Conv2D)       (None, 56, 56, 64)   4160        pool1/norm1[0][0]
# __________________________________________________________________________________________________
# conv2/3x3 (Conv2D)              (None, 56, 56, 192)  110784      conv2/3x3_reduce[0][0]
# __________________________________________________________________________________________________
# conv2/norm2 (LRN)               (None, 56, 56, 192)  0           conv2/3x3[0][0]
# __________________________________________________________________________________________________
# pool2/3x3_s2 (MaxPooling2D)     (None, 28, 28, 192)  0           conv2/norm2[0][0]
# __________________________________________________________________________________________________
# inception_3a/3x3_reduce (Conv2D (None, 28, 28, 96)   18528       pool2/3x3_s2[0][0]
# __________________________________________________________________________________________________
# inception_3a/5x5_reduce (Conv2D (None, 28, 28, 16)   3088        pool2/3x3_s2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d (ZeroPadding2D)  (None, 30, 30, 96)   0           inception_3a/3x3_reduce[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_1 (ZeroPadding2D (None, 32, 32, 16)   0           inception_3a/5x5_reduce[0][0]
# __________________________________________________________________________________________________
# inception_3a/pool (MaxPooling2D (None, 28, 28, 192)  0           pool2/3x3_s2[0][0]
# __________________________________________________________________________________________________
# inception_3a/1x1 (Conv2D)       (None, 28, 28, 64)   12352       pool2/3x3_s2[0][0]
# __________________________________________________________________________________________________
# inception_3a/3x3 (Conv2D)       (None, 28, 28, 128)  110720      zero_padding2d[0][0]
# __________________________________________________________________________________________________
# inception_3a/5x5 (Conv2D)       (None, 28, 28, 32)   12832       zero_padding2d_1[0][0]
# __________________________________________________________________________________________________
# inception_3a/pool_proj (Conv2D) (None, 28, 28, 32)   6176        inception_3a/pool[0][0]
# __________________________________________________________________________________________________
# inception_3a/output (Concatenat (None, 28, 28, 256)  0           inception_3a/1x1[0][0]
#                                                                  inception_3a/3x3[0][0]
#                                                                  inception_3a/5x5[0][0]
#                                                                  inception_3a/pool_proj[0][0]
# __________________________________________________________________________________________________
# inception_3b/3x3_reduce (Conv2D (None, 28, 28, 128)  32896       inception_3a/output[0][0]
# __________________________________________________________________________________________________
# inception_3b/5x5_reduce (Conv2D (None, 28, 28, 32)   8224        inception_3a/output[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_2 (ZeroPadding2D (None, 30, 30, 128)  0           inception_3b/3x3_reduce[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_3 (ZeroPadding2D (None, 32, 32, 32)   0           inception_3b/5x5_reduce[0][0]
# __________________________________________________________________________________________________
# inception_3b/pool (MaxPooling2D (None, 28, 28, 256)  0           inception_3a/output[0][0]
# __________________________________________________________________________________________________
# inception_3b/1x1 (Conv2D)       (None, 28, 28, 128)  32896       inception_3a/output[0][0]
# __________________________________________________________________________________________________
# inception_3b/3x3 (Conv2D)       (None, 28, 28, 192)  221376      zero_padding2d_2[0][0]
# __________________________________________________________________________________________________
# inception_3b/5x5 (Conv2D)       (None, 28, 28, 96)   76896       zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# inception_3b/pool_proj (Conv2D) (None, 28, 28, 64)   16448       inception_3b/pool[0][0]
# __________________________________________________________________________________________________
# inception_3b/output (Concatenat (None, 28, 28, 480)  0           inception_3b/1x1[0][0]
#                                                                  inception_3b/3x3[0][0]
#                                                                  inception_3b/5x5[0][0]
#                                                                  inception_3b/pool_proj[0][0]
# __________________________________________________________________________________________________
# pool3/3x3_s2 (MaxPooling2D)     (None, 14, 14, 480)  0           inception_3b/output[0][0]
# __________________________________________________________________________________________________
# inception_4a/3x3_reduce (Conv2D (None, 14, 14, 96)   46176       pool3/3x3_s2[0][0]
# __________________________________________________________________________________________________
# inception_4a/5x5_reduce (Conv2D (None, 14, 14, 16)   7696        pool3/3x3_s2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_4 (ZeroPadding2D (None, 16, 16, 96)   0           inception_4a/3x3_reduce[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_5 (ZeroPadding2D (None, 18, 18, 16)   0           inception_4a/5x5_reduce[0][0]
# __________________________________________________________________________________________________
# inception_4a/pool (MaxPooling2D (None, 14, 14, 480)  0           pool3/3x3_s2[0][0]
# __________________________________________________________________________________________________
# inception_4a/1x1 (Conv2D)       (None, 14, 14, 192)  92352       pool3/3x3_s2[0][0]
# __________________________________________________________________________________________________
# inception_4a/3x3 (Conv2D)       (None, 14, 14, 208)  179920      zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# inception_4a/5x5 (Conv2D)       (None, 14, 14, 48)   19248       zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# inception_4a/pool_proj (Conv2D) (None, 14, 14, 64)   30784       inception_4a/pool[0][0]
# __________________________________________________________________________________________________
# inception_4a/output (Concatenat (None, 14, 14, 512)  0           inception_4a/1x1[0][0]
#                                                                  inception_4a/3x3[0][0]
#                                                                  inception_4a/5x5[0][0]
#                                                                  inception_4a/pool_proj[0][0]
# __________________________________________________________________________________________________
# inception_4b/3x3_reduce (Conv2D (None, 14, 14, 112)  57456       inception_4a/output[0][0]
# __________________________________________________________________________________________________
# inception_4b/5x5_reduce (Conv2D (None, 14, 14, 24)   12312       inception_4a/output[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_6 (ZeroPadding2D (None, 16, 16, 112)  0           inception_4b/3x3_reduce[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_7 (ZeroPadding2D (None, 18, 18, 24)   0           inception_4b/5x5_reduce[0][0]
# __________________________________________________________________________________________________
# inception_4b/pool (MaxPooling2D (None, 14, 14, 512)  0           inception_4a/output[0][0]
# __________________________________________________________________________________________________
# inception_4b/1x1 (Conv2D)       (None, 14, 14, 160)  82080       inception_4a/output[0][0]
# __________________________________________________________________________________________________
# inception_4b/3x3 (Conv2D)       (None, 14, 14, 224)  226016      zero_padding2d_6[0][0]
# __________________________________________________________________________________________________
# inception_4b/5x5 (Conv2D)       (None, 14, 14, 64)   38464       zero_padding2d_7[0][0]
# __________________________________________________________________________________________________
# inception_4b/pool_proj (Conv2D) (None, 14, 14, 64)   32832       inception_4b/pool[0][0]
# __________________________________________________________________________________________________
# inception_4b/output (Concatenat (None, 14, 14, 512)  0           inception_4b/1x1[0][0]
#                                                                  inception_4b/3x3[0][0]
#                                                                  inception_4b/5x5[0][0]
#                                                                  inception_4b/pool_proj[0][0]
# __________________________________________________________________________________________________
# inception_4c/3x3_reduce (Conv2D (None, 14, 14, 128)  65664       inception_4b/output[0][0]
# __________________________________________________________________________________________________
# inception_4c/5x5_reduce (Conv2D (None, 14, 14, 24)   12312       inception_4b/output[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_8 (ZeroPadding2D (None, 16, 16, 128)  0           inception_4c/3x3_reduce[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_9 (ZeroPadding2D (None, 18, 18, 24)   0           inception_4c/5x5_reduce[0][0]
# __________________________________________________________________________________________________
# inception_4c/pool (MaxPooling2D (None, 14, 14, 512)  0           inception_4b/output[0][0]
# __________________________________________________________________________________________________
# inception_4c/1x1 (Conv2D)       (None, 14, 14, 128)  65664       inception_4b/output[0][0]
# __________________________________________________________________________________________________
# inception_4c/3x3 (Conv2D)       (None, 14, 14, 256)  295168      zero_padding2d_8[0][0]
# __________________________________________________________________________________________________
# inception_4c/5x5 (Conv2D)       (None, 14, 14, 64)   38464       zero_padding2d_9[0][0]
# __________________________________________________________________________________________________
# inception_4c/pool_proj (Conv2D) (None, 14, 14, 64)   32832       inception_4c/pool[0][0]
# __________________________________________________________________________________________________
# inception_4c/output (Concatenat (None, 14, 14, 512)  0           inception_4c/1x1[0][0]
#                                                                  inception_4c/3x3[0][0]
#                                                                  inception_4c/5x5[0][0]
#                                                                  inception_4c/pool_proj[0][0]
# __________________________________________________________________________________________________
# inception_4d/3x3_reduce (Conv2D (None, 14, 14, 144)  73872       inception_4c/output[0][0]
# __________________________________________________________________________________________________
# inception_4d/5x5_reduce (Conv2D (None, 14, 14, 32)   16416       inception_4c/output[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_10 (ZeroPadding2 (None, 16, 16, 144)  0           inception_4d/3x3_reduce[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_11 (ZeroPadding2 (None, 18, 18, 32)   0           inception_4d/5x5_reduce[0][0]
# __________________________________________________________________________________________________
# inception_4d/pool (MaxPooling2D (None, 14, 14, 512)  0           inception_4c/output[0][0]
# __________________________________________________________________________________________________
# inception_4d/1x1 (Conv2D)       (None, 14, 14, 112)  57456       inception_4c/output[0][0]
# __________________________________________________________________________________________________
# inception_4d/3x3 (Conv2D)       (None, 14, 14, 288)  373536      zero_padding2d_10[0][0]
# __________________________________________________________________________________________________
# inception_4d/5x5 (Conv2D)       (None, 14, 14, 64)   51264       zero_padding2d_11[0][0]
# __________________________________________________________________________________________________
# inception_4d/pool_proj (Conv2D) (None, 14, 14, 64)   32832       inception_4d/pool[0][0]
# __________________________________________________________________________________________________
# inception_4d/output (Concatenat (None, 14, 14, 528)  0           inception_4d/1x1[0][0]
#                                                                  inception_4d/3x3[0][0]
#                                                                  inception_4d/5x5[0][0]
#                                                                  inception_4d/pool_proj[0][0]
# __________________________________________________________________________________________________
# inception_4e/3x3_reduce (Conv2D (None, 14, 14, 160)  84640       inception_4d/output[0][0]
# __________________________________________________________________________________________________
# inception_4e/5x5_reduce (Conv2D (None, 14, 14, 32)   16928       inception_4d/output[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_12 (ZeroPadding2 (None, 16, 16, 160)  0           inception_4e/3x3_reduce[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_13 (ZeroPadding2 (None, 18, 18, 32)   0           inception_4e/5x5_reduce[0][0]
# __________________________________________________________________________________________________
# inception_4e/pool (MaxPooling2D (None, 14, 14, 528)  0           inception_4d/output[0][0]
# __________________________________________________________________________________________________
# inception_4e/1x1 (Conv2D)       (None, 14, 14, 256)  135424      inception_4d/output[0][0]
# __________________________________________________________________________________________________
# inception_4e/3x3 (Conv2D)       (None, 14, 14, 320)  461120      zero_padding2d_12[0][0]
# __________________________________________________________________________________________________
# inception_4e/5x5 (Conv2D)       (None, 14, 14, 128)  102528      zero_padding2d_13[0][0]
# __________________________________________________________________________________________________
# inception_4e/pool_proj (Conv2D) (None, 14, 14, 128)  67712       inception_4e/pool[0][0]
# __________________________________________________________________________________________________
# inception_4e/output (Concatenat (None, 14, 14, 832)  0           inception_4e/1x1[0][0]
#                                                                  inception_4e/3x3[0][0]
#                                                                  inception_4e/5x5[0][0]
#                                                                  inception_4e/pool_proj[0][0]
# __________________________________________________________________________________________________
# pool4/3x3_s2 (MaxPooling2D)     (None, 7, 7, 832)    0           inception_4e/output[0][0]
# __________________________________________________________________________________________________
# inception_5a/3x3_reduce (Conv2D (None, 7, 7, 160)    133280      pool4/3x3_s2[0][0]
# __________________________________________________________________________________________________
# inception_5a/5x5_reduce (Conv2D (None, 7, 7, 32)     26656       pool4/3x3_s2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_14 (ZeroPadding2 (None, 9, 9, 160)    0           inception_5a/3x3_reduce[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_15 (ZeroPadding2 (None, 11, 11, 32)   0           inception_5a/5x5_reduce[0][0]
# __________________________________________________________________________________________________
# inception_5a/pool (MaxPooling2D (None, 7, 7, 832)    0           pool4/3x3_s2[0][0]
# __________________________________________________________________________________________________
# inception_5a/1x1 (Conv2D)       (None, 7, 7, 256)    213248      pool4/3x3_s2[0][0]
# __________________________________________________________________________________________________
# inception_5a/3x3 (Conv2D)       (None, 7, 7, 320)    461120      zero_padding2d_14[0][0]
# __________________________________________________________________________________________________
# inception_5a/5x5 (Conv2D)       (None, 7, 7, 128)    102528      zero_padding2d_15[0][0]
# __________________________________________________________________________________________________
# inception_5a/pool_proj (Conv2D) (None, 7, 7, 128)    106624      inception_5a/pool[0][0]
# __________________________________________________________________________________________________
# inception_5a/output (Concatenat (None, 7, 7, 832)    0           inception_5a/1x1[0][0]
#                                                                  inception_5a/3x3[0][0]
#                                                                  inception_5a/5x5[0][0]
#                                                                  inception_5a/pool_proj[0][0]
# __________________________________________________________________________________________________
# inception_5b/3x3_reduce (Conv2D (None, 7, 7, 192)    159936      inception_5a/output[0][0]
# __________________________________________________________________________________________________
# inception_5b/5x5_reduce (Conv2D (None, 7, 7, 48)     39984       inception_5a/output[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_16 (ZeroPadding2 (None, 9, 9, 192)    0           inception_5b/3x3_reduce[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_17 (ZeroPadding2 (None, 11, 11, 48)   0           inception_5b/5x5_reduce[0][0]
# __________________________________________________________________________________________________
# inception_5b/pool (MaxPooling2D (None, 7, 7, 832)    0           inception_5a/output[0][0]
# __________________________________________________________________________________________________
# loss1/ave_pool (AveragePooling2 (None, 4, 4, 512)    0           inception_4a/output[0][0]
# __________________________________________________________________________________________________
# loss2/ave_pool (AveragePooling2 (None, 4, 4, 528)    0           inception_4d/output[0][0]
# __________________________________________________________________________________________________
# inception_5b/1x1 (Conv2D)       (None, 7, 7, 384)    319872      inception_5a/output[0][0]
# __________________________________________________________________________________________________
# inception_5b/3x3 (Conv2D)       (None, 7, 7, 384)    663936      zero_padding2d_16[0][0]
# __________________________________________________________________________________________________
# inception_5b/5x5 (Conv2D)       (None, 7, 7, 128)    153728      zero_padding2d_17[0][0]
# __________________________________________________________________________________________________
# inception_5b/pool_proj (Conv2D) (None, 7, 7, 128)    106624      inception_5b/pool[0][0]
# __________________________________________________________________________________________________
# loss1/conv (Conv2D)             (None, 4, 4, 128)    65664       loss1/ave_pool[0][0]
# __________________________________________________________________________________________________
# loss2/conv (Conv2D)             (None, 4, 4, 128)    67712       loss2/ave_pool[0][0]
# __________________________________________________________________________________________________
# inception_5b/output (Concatenat (None, 7, 7, 1024)   0           inception_5b/1x1[0][0]
#                                                                  inception_5b/3x3[0][0]
#                                                                  inception_5b/5x5[0][0]
#                                                                  inception_5b/pool_proj[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 2048)         0           loss1/conv[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 2048)         0           loss2/conv[0][0]
# __________________________________________________________________________________________________
# pool5/7x7_s2 (AveragePooling2D) (None, 1, 1, 1024)   0           inception_5b/output[0][0]
# __________________________________________________________________________________________________
# loss1/fc (Dense)                (None, 1024)         2098176     flatten[0][0]
# __________________________________________________________________________________________________
# loss2/fc (Dense)                (None, 1024)         2098176     flatten_1[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 1024)         0           pool5/7x7_s2[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 1024)         0           loss1/fc[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 1024)         0           loss2/fc[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 1024)         0           flatten_2[0][0]
# __________________________________________________________________________________________________
# loss1/classifier (Dense)        (None, 257)          263425      dropout[0][0]
# __________________________________________________________________________________________________
# loss2/classifier (Dense)        (None, 257)          263425      dropout_1[0][0]
# __________________________________________________________________________________________________
# loss3/classifier (Dense)        (None, 257)          263425      dropout_2[0][0]
# ==================================================================================================
# Total params: 11,093,555
# Trainable params: 11,093,555
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# 폴더 생성

os.makedirs(os.path.join(dir,'model_output',number,model.name), exist_ok=True)
os.makedirs(os.path.join(dir,'train_valid_output',number), exist_ok=True)

# %%
# 참고 : https://github.com/OverLordGoldDragon/keras-adamw

import sys
sys.path.append('/content/drive/My Drive/Colab Notebooks/Paper')
import utils
import optimizers_v2
from utils import get_weight_decays, fill_dict_in_order
from utils import reset_seeds, K_eval
from optimizers_v2 import AdamW, NadamW, SGDW

# %%
# top-5 accuracy 출력
import functools
top5_acc = functools.partial(ks.metrics.top_k_categorical_accuracy, k=5)
top5_acc.__name__ = 'top5_acc'

# %%
#optimizer = SGDW(model=model, use_cosine_annealing=False, total_iterations = len(x_train) // batch_sizes, nesterov=True, momentum=0.9)
optimizer = AdamW(model=model, use_cosine_annealing=False, total_iterations = len(x_train) // batch_sizes)
#optimizer = Adam()
filepath =  os.path.join(dir,'model_output',number,model.name,'{epoch:03d}.h5')

callbacks_list = [ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_weights_only=False, save_best_only=True, mode='min'),
                  ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_weights_only=False, save_best_only=True, mode='max'),
                  #ReduceLROnPlateau(monitor='val_loss',patience=3,factor=0.1,min_lr=1e-5),
                  LearningRateScheduler(lr_schedule,verbose=1)
                  ]                    	

model.compile(optimizer, loss={'loss1/classifier' : 'categorical_crossentropy', 'loss2/classifier' : 'categorical_crossentropy', 'loss3/classifier' : 'categorical_crossentropy'},
              loss_weights={'loss1/classifier' : 0.3, 'loss2/classifier' : 0.3, 'loss3/classifier' : 1.0}, 
              metrics=['accuracy',top5_acc,macro_f1score])

# %%
######## flow_from_directory
#history = model.fit_generator(generate_train_for_three(), steps_per_epoch=int(len(x_train)/batch_sizes),  validation_data = generate_valid_for_three(), epochs=epochs , verbose=1 , callbacks = callbacks_list,validation_steps=int(len(x_valid)/batch_sizes))
history = model.fit(generate_train_for_three(), steps_per_epoch=int(len(x_train)/batch_sizes),  validation_data = generate_valid_for_three(), epochs=epochs , verbose=1 , callbacks = callbacks_list , validation_steps=int(len(x_valid)/batch_sizes))
# Out:
# Found 24509 images belonging to 257 classes.
# Learning rate:  0.0003
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 1/70
# 0.0(L1), 7.235745870133896e-06(L2) weight decay set for conv1/7x7_s2/kernel:0
# 0.0(L1), 7.235745870133896e-06(L2) weight decay set for conv2/3x3_reduce/kernel:0
# 0.0(L1), 7.235745870133896e-06(L2) weight decay set for conv2/3x3/kernel:0
# 0.0(L1), 7.235745870133896e-06(L2) weight decay set for inception_3a/3x3_reduce/kernel:0
# 0.0(L1), 7.235745870133896e-06(L2) weight decay set for inception_3a/5x5_reduce/kernel:0
# 0.0(L1), 7.235745870133896e-06(L2) weight decay set for inception_3a/1x1/kernel:0
# 0.0(L1), 7.235745870133896e-06(L2) weight decay set for inception_3a/3x3/kernel:0
# 0.0(L1), 7.235745870133896e-06(L2) weight decay set for inception_3a/5x5/kernel:0
# 0.0(L1), 7.235745870133896e-06(L2) weight decay set for inception_3a/pool_proj/kernel:0
# 0.0(L1), 7.235745870133896e-06(L2) weight decay set for inception_3b/3x3_reduce/kernel:0
# 0.0(L1), 7.235745870133896e-06(L2) weight decay set for inception_3b/5x5_reduce/kernel:0
# 0.0(L1), 7.235745870133896e-06(L2) weight decay set for inception_3b/1x1/kernel:0
# 0.0(L1), 7.235745870133896e-06(L2) weight decay set for inception_3b/3x3/kernel:0
# 0.0(L1), 7.235745870133896e-06(L2) weight decay set for inception_3b/5x5/kernel:0
# 0.0(L1), 7.235745870133896e-06(L2) weight decay set for inception_3b/pool_proj/kernel:0
# 0.0(L1), 7.235745870133896e-06(L2) weight decay set for inception_4a/3x3_reduce/kernel:0
# 0.0(L1), 7.235745870133896e-06(L2) weight decay set for inception_4a/5x5_reduce/kernel:0
# 0.0(L1), 7.235745870133896e-06(L2) weight decay set for inception_4a/1x1/kernel:0
# 0.0(L1), 7.235745870133896e-06(L2) weight decay set for inception_4a/3x3/kernel:0
# 0.0(L1), 7.235745870133896e-06(L2) weight decay set for inception_4a/5x5/kernel:0
# 0.0(L1), 7.235745870133896e-06(L2) weight decay set for inception_4a/pool_proj/kernel:0
# 0.0(L1), 7.235745870133896e-06(L2) weight decay set for inception_4b/3x3_reduce/kernel:0
# 0.0(L1), 7.235745870133896e-06(L2) weight decay set for inception_4b/5x5_reduce/kernel:0
# 0.0(L1), 7.235745870133896e-06(L2) weight decay set for inception_4b/1x1/kernel:0
# 0.0(L1), 7.235745870133896e-06(L2) weight decay set for inception_4b/3x3/kernel:0
# 0.0(L1), 7.235745870133896e-06(L2) weight decay set for inception_4b/5x5/kernel:0
# 0.0(L1), 7.235745870133896e-06(L2) weight decay set for inception_4b/pool_proj/kernel:0
# 0.0(L1), 7.235745870133896e-06(L2) weight decay set for inception_4c/3x3_reduce/kernel:0
# 0.0(L1), 7.235745870133896e-06(L2) weight decay set for inception_4c/5x5_reduce/kernel:0
# 0.0(L1), 7.235745870133896e-06(L2) weight decay set for inception_4c/1x1/kernel:0
# 0.0(L1), 7.235745870133896e-06(L2) weight decay set for inception_4c/3x3/kernel:0
# 0.0(L1), 7.235745870133896e-06(L2) weight decay set for inception_4c/5x5/kernel:0
# 0.0(L1), 7.235745870133896e-06(L2) weight decay set for inception_4c/pool_proj/kernel:0
# 0.0(L1), 7.235745870133896e-06(L2) weight decay set for inception_4d/3x3_reduce/kernel:0
# 0.0(L1), 7.235745870133896e-06(L2) weight decay set for inception_4d/5x5_reduce/kernel:0
# 0.0(L1), 7.235745870133896e-06(L2) weight decay set for inception_4d/1x1/kernel:0
# 0.0(L1), 7.235745870133896e-06(L2) weight decay set for inception_4d/3x3/kernel:0
# 0.0(L1), 7.235745870133896e-06(L2) weight decay set for inception_4d/5x5/kernel:0
# 0.0(L1), 7.235745870133896e-06(L2) weight decay set for inception_4d/pool_proj/kernel:0
# 0.0(L1), 7.235745870133896e-06(L2) weight decay set for inception_4e/3x3_reduce/kernel:0
# 0.0(L1), 7.235745870133896e-06(L2) weight decay set for inception_4e/5x5_reduce/kernel:0
# 0.0(L1), 7.235745870133896e-06(L2) weight decay set for inception_4e/1x1/kernel:0
# 0.0(L1), 7.235745870133896e-06(L2) weight decay set for inception_4e/3x3/kernel:0
# 0.0(L1), 7.235745870133896e-06(L2) weight decay set for inception_4e/5x5/kernel:0
# 0.0(L1), 7.235745870133896e-06(L2) weight decay set for inception_4e/pool_proj/kernel:0
# 0.0(L1), 7.235745870133896e-06(L2) weight decay set for inception_5a/3x3_reduce/kernel:0
# 0.0(L1), 7.235745870133896e-06(L2) weight decay set for inception_5a/5x5_reduce/kernel:0
# 0.0(L1), 7.235745870133896e-06(L2) weight decay set for inception_5a/1x1/kernel:0
# 0.0(L1), 7.235745870133896e-06(L2) weight decay set for inception_5a/3x3/kernel:0
# 0.0(L1), 7.235745870133896e-06(L2) weight decay set for inception_5a/5x5/kernel:0
# 0.0(L1), 7.235745870133896e-06(L2) weight decay set for inception_5a/pool_proj/kernel:0
# 0.0(L1), 7.235745870133896e-06(L2) weight decay set for inception_5b/3x3_reduce/kernel:0
# 0.0(L1), 7.235745870133896e-06(L2) weight decay set for inception_5b/5x5_reduce/kernel:0
# 0.0(L1), 7.235745870133896e-06(L2) weight decay set for inception_5b/1x1/kernel:0
# 0.0(L1), 7.235745870133896e-06(L2) weight decay set for inception_5b/3x3/kernel:0
# 0.0(L1), 7.235745870133896e-06(L2) weight decay set for inception_5b/5x5/kernel:0
# 0.0(L1), 7.235745870133896e-06(L2) weight decay set for inception_5b/pool_proj/kernel:0
# 0.0(L1), 7.235745870133896e-06(L2) weight decay set for loss1/conv/kernel:0
# 0.0(L1), 7.235745870133896e-06(L2) weight decay set for loss2/conv/kernel:0
# 0.0(L1), 7.235745870133896e-06(L2) weight decay set for loss1/fc/kernel:0
# 0.0(L1), 7.235745870133896e-06(L2) weight decay set for loss2/fc/kernel:0
# 0.0(L1), 7.235745870133896e-06(L2) weight decay set for loss1/classifier/kernel:0
# 0.0(L1), 7.235745870133896e-06(L2) weight decay set for loss2/classifier/kernel:0
# 0.0(L1), 7.235745870133896e-06(L2) weight decay set for loss3/classifier/kernel:0
# 191/191 [==============================] - ETA: 0s - loss: 8.6426 - loss1/classifier_loss: 5.3897 - loss2/classifier_loss: 5.4118 - loss3/classifier_loss: 5.4021 - loss1/classifier_accuracy: 0.0457 - loss1/classifier_top5_acc: 0.1092 - loss1/classifier_macro_f1score: 1.5447e-04 - loss2/classifier_accuracy: 0.0389 - loss2/classifier_top5_acc: 0.1056 - loss2/classifier_macro_f1score: 9.1884e-05 - loss3/classifier_accuracy: 0.0354 - loss3/classifier_top5_acc: 0.1074 - loss3/classifier_macro_f1score: 1.1905e-04  Found 2980 images belonging to 257 classes.
#
# Epoch 00001: val_loss improved from inf to 8.22290, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/GoogleNet/001.h5
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 191/191 [==============================] - 14223s 74s/step - loss: 8.6426 - loss1/classifier_loss: 5.3897 - loss2/classifier_loss: 5.4118 - loss3/classifier_loss: 5.4021 - loss1/classifier_accuracy: 0.0457 - loss1/classifier_top5_acc: 0.1092 - loss1/classifier_macro_f1score: 1.5447e-04 - loss2/classifier_accuracy: 0.0389 - loss2/classifier_top5_acc: 0.1056 - loss2/classifier_macro_f1score: 9.1884e-05 - loss3/classifier_accuracy: 0.0354 - loss3/classifier_top5_acc: 0.1074 - loss3/classifier_macro_f1score: 1.1905e-04 - val_loss: 8.2229 - val_loss1/classifier_loss: 5.0564 - val_loss2/classifier_loss: 5.1312 - val_loss3/classifier_loss: 5.1666 - val_loss1/classifier_accuracy: 0.0744 - val_loss1/classifier_top5_acc: 0.1637 - val_loss1/classifier_macro_f1score: 2.6585e-04 - val_loss2/classifier_accuracy: 0.0683 - val_loss2/classifier_top5_acc: 0.1495 - val_loss2/classifier_macro_f1score: 8.4588e-05 - val_loss3/classifier_accuracy: 0.0591 - val_loss3/classifier_top5_acc: 0.1349 - val_loss3/classifier_macro_f1score: 0.0000e+00
# Learning rate:  0.0003
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 2/70
# 191/191 [==============================] - ETA: 0s - loss: 7.9666 - loss1/classifier_loss: 4.9411 - loss2/classifier_loss: 5.0043 - loss3/classifier_loss: 4.9829 - loss1/classifier_accuracy: 0.0922 - loss1/classifier_top5_acc: 0.1835 - loss1/classifier_macro_f1score: 0.0042 - loss2/classifier_accuracy: 0.0848 - loss2/classifier_top5_acc: 0.1659 - loss2/classifier_macro_f1score: 0.0043 - loss3/classifier_accuracy: 0.0824 - loss3/classifier_top5_acc: 0.1662 - loss3/classifier_macro_f1score: 0.0036
# Epoch 00002: val_loss improved from 8.22290 to 7.46563, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/GoogleNet/002.h5
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 191/191 [==============================] - 381s 2s/step - loss: 7.9666 - loss1/classifier_loss: 4.9411 - loss2/classifier_loss: 5.0043 - loss3/classifier_loss: 4.9829 - loss1/classifier_accuracy: 0.0922 - loss1/classifier_top5_acc: 0.1835 - loss1/classifier_macro_f1score: 0.0042 - loss2/classifier_accuracy: 0.0848 - loss2/classifier_top5_acc: 0.1659 - loss2/classifier_macro_f1score: 0.0043 - loss3/classifier_accuracy: 0.0824 - loss3/classifier_top5_acc: 0.1662 - loss3/classifier_macro_f1score: 0.0036 - val_loss: 7.4656 - val_loss1/classifier_loss: 4.6052 - val_loss2/classifier_loss: 4.6752 - val_loss3/classifier_loss: 4.6815 - val_loss1/classifier_accuracy: 0.1165 - val_loss1/classifier_top5_acc: 0.2534 - val_loss1/classifier_macro_f1score: 0.0081 - val_loss2/classifier_accuracy: 0.1036 - val_loss2/classifier_top5_acc: 0.2242 - val_loss2/classifier_macro_f1score: 0.0082 - val_loss3/classifier_accuracy: 0.1009 - val_loss3/classifier_top5_acc: 0.2099 - val_loss3/classifier_macro_f1score: 0.0086
# Learning rate:  0.0003
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 3/70
# 191/191 [==============================] - ETA: 0s - loss: 7.4685 - loss1/classifier_loss: 4.6276 - loss2/classifier_loss: 4.6998 - loss3/classifier_loss: 4.6703 - loss1/classifier_accuracy: 0.1192 - loss1/classifier_top5_acc: 0.2356 - loss1/classifier_macro_f1score: 0.0076 - loss2/classifier_accuracy: 0.1104 - loss2/classifier_top5_acc: 0.2171 - loss2/classifier_macro_f1score: 0.0081 - loss3/classifier_accuracy: 0.1059 - loss3/classifier_top5_acc: 0.2157 - loss3/classifier_macro_f1score: 0.0076
# Epoch 00003: val_loss improved from 7.46563 to 7.28692, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/GoogleNet/003.h5
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 191/191 [==============================] - 382s 2s/step - loss: 7.4685 - loss1/classifier_loss: 4.6276 - loss2/classifier_loss: 4.6998 - loss3/classifier_loss: 4.6703 - loss1/classifier_accuracy: 0.1192 - loss1/classifier_top5_acc: 0.2356 - loss1/classifier_macro_f1score: 0.0076 - loss2/classifier_accuracy: 0.1104 - loss2/classifier_top5_acc: 0.2171 - loss2/classifier_macro_f1score: 0.0081 - loss3/classifier_accuracy: 0.1059 - loss3/classifier_top5_acc: 0.2157 - loss3/classifier_macro_f1score: 0.0076 - val_loss: 7.2869 - val_loss1/classifier_loss: 4.4395 - val_loss2/classifier_loss: 4.5419 - val_loss3/classifier_loss: 4.5925 - val_loss1/classifier_accuracy: 0.1518 - val_loss1/classifier_top5_acc: 0.2846 - val_loss1/classifier_macro_f1score: 0.0075 - val_loss2/classifier_accuracy: 0.1342 - val_loss2/classifier_top5_acc: 0.2653 - val_loss2/classifier_macro_f1score: 0.0080 - val_loss3/classifier_accuracy: 0.1168 - val_loss3/classifier_top5_acc: 0.2381 - val_loss3/classifier_macro_f1score: 0.0074
# Learning rate:  0.0003
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 4/70
# 191/191 [==============================] - ETA: 0s - loss: 7.1344 - loss1/classifier_loss: 4.4037 - loss2/classifier_loss: 4.4927 - loss3/classifier_loss: 4.4655 - loss1/classifier_accuracy: 0.1411 - loss1/classifier_top5_acc: 0.2809 - loss1/classifier_macro_f1score: 0.0099 - loss2/classifier_accuracy: 0.1301 - loss2/classifier_top5_acc: 0.2577 - loss2/classifier_macro_f1score: 0.0097 - loss3/classifier_accuracy: 0.1277 - loss3/classifier_top5_acc: 0.2566 - loss3/classifier_macro_f1score: 0.0095
# Epoch 00004: val_loss improved from 7.28692 to 7.03020, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/GoogleNet/004.h5
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 191/191 [==============================] - 380s 2s/step - loss: 7.1344 - loss1/classifier_loss: 4.4037 - loss2/classifier_loss: 4.4927 - loss3/classifier_loss: 4.4655 - loss1/classifier_accuracy: 0.1411 - loss1/classifier_top5_acc: 0.2809 - loss1/classifier_macro_f1score: 0.0099 - loss2/classifier_accuracy: 0.1301 - loss2/classifier_top5_acc: 0.2577 - loss2/classifier_macro_f1score: 0.0097 - loss3/classifier_accuracy: 0.1277 - loss3/classifier_top5_acc: 0.2566 - loss3/classifier_macro_f1score: 0.0095 - val_loss: 7.0302 - val_loss1/classifier_loss: 4.2431 - val_loss2/classifier_loss: 4.3321 - val_loss3/classifier_loss: 4.4576 - val_loss1/classifier_accuracy: 0.1797 - val_loss1/classifier_top5_acc: 0.3349 - val_loss1/classifier_macro_f1score: 0.0095 - val_loss2/classifier_accuracy: 0.1552 - val_loss2/classifier_top5_acc: 0.3003 - val_loss2/classifier_macro_f1score: 0.0105 - val_loss3/classifier_accuracy: 0.1287 - val_loss3/classifier_top5_acc: 0.2636 - val_loss3/classifier_macro_f1score: 0.0097
# Learning rate:  0.0003
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 5/70
# 191/191 [==============================] - ETA: 0s - loss: 6.8217 - loss1/classifier_loss: 4.2194 - loss2/classifier_loss: 4.3000 - loss3/classifier_loss: 4.2659 - loss1/classifier_accuracy: 0.1639 - loss1/classifier_top5_acc: 0.3168 - loss1/classifier_macro_f1score: 0.0127 - loss2/classifier_accuracy: 0.1516 - loss2/classifier_top5_acc: 0.2949 - loss2/classifier_macro_f1score: 0.0124 - loss3/classifier_accuracy: 0.1521 - loss3/classifier_top5_acc: 0.2960 - loss3/classifier_macro_f1score: 0.0125
# Epoch 00005: val_loss improved from 7.03020 to 6.51698, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/GoogleNet/005.h5
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 191/191 [==============================] - 379s 2s/step - loss: 6.8217 - loss1/classifier_loss: 4.2194 - loss2/classifier_loss: 4.3000 - loss3/classifier_loss: 4.2659 - loss1/classifier_accuracy: 0.1639 - loss1/classifier_top5_acc: 0.3168 - loss1/classifier_macro_f1score: 0.0127 - loss2/classifier_accuracy: 0.1516 - loss2/classifier_top5_acc: 0.2949 - loss2/classifier_macro_f1score: 0.0124 - loss3/classifier_accuracy: 0.1521 - loss3/classifier_top5_acc: 0.2960 - loss3/classifier_macro_f1score: 0.0125 - val_loss: 6.5170 - val_loss1/classifier_loss: 3.9423 - val_loss2/classifier_loss: 4.0277 - val_loss3/classifier_loss: 4.1260 - val_loss1/classifier_accuracy: 0.2157 - val_loss1/classifier_top5_acc: 0.3872 - val_loss1/classifier_macro_f1score: 0.0147 - val_loss2/classifier_accuracy: 0.1970 - val_loss2/classifier_top5_acc: 0.3628 - val_loss2/classifier_macro_f1score: 0.0141 - val_loss3/classifier_accuracy: 0.1790 - val_loss3/classifier_top5_acc: 0.3274 - val_loss3/classifier_macro_f1score: 0.0136
# Learning rate:  0.0003
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 6/70
# 191/191 [==============================] - ETA: 0s - loss: 6.5527 - loss1/classifier_loss: 4.0554 - loss2/classifier_loss: 4.1376 - loss3/classifier_loss: 4.0948 - loss1/classifier_accuracy: 0.1864 - loss1/classifier_top5_acc: 0.3540 - loss1/classifier_macro_f1score: 0.0162 - loss2/classifier_accuracy: 0.1760 - loss2/classifier_top5_acc: 0.3315 - loss2/classifier_macro_f1score: 0.0155 - loss3/classifier_accuracy: 0.1719 - loss3/classifier_top5_acc: 0.3289 - loss3/classifier_macro_f1score: 0.0157
# Epoch 00006: val_loss improved from 6.51698 to 6.43004, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/GoogleNet/006.h5
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 191/191 [==============================] - 378s 2s/step - loss: 6.5527 - loss1/classifier_loss: 4.0554 - loss2/classifier_loss: 4.1376 - loss3/classifier_loss: 4.0948 - loss1/classifier_accuracy: 0.1864 - loss1/classifier_top5_acc: 0.3540 - loss1/classifier_macro_f1score: 0.0162 - loss2/classifier_accuracy: 0.1760 - loss2/classifier_top5_acc: 0.3315 - loss2/classifier_macro_f1score: 0.0155 - loss3/classifier_accuracy: 0.1719 - loss3/classifier_top5_acc: 0.3289 - loss3/classifier_macro_f1score: 0.0157 - val_loss: 6.4300 - val_loss1/classifier_loss: 3.8765 - val_loss2/classifier_loss: 3.9631 - val_loss3/classifier_loss: 4.0781 - val_loss1/classifier_accuracy: 0.2252 - val_loss1/classifier_top5_acc: 0.4062 - val_loss1/classifier_macro_f1score: 0.0185 - val_loss2/classifier_accuracy: 0.2041 - val_loss2/classifier_top5_acc: 0.3787 - val_loss2/classifier_macro_f1score: 0.0177 - val_loss3/classifier_accuracy: 0.1838 - val_loss3/classifier_top5_acc: 0.3458 - val_loss3/classifier_macro_f1score: 0.0197
# Learning rate:  0.0003
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 7/70
# 191/191 [==============================] - ETA: 0s - loss: 6.2702 - loss1/classifier_loss: 3.9041 - loss2/classifier_loss: 3.9714 - loss3/classifier_loss: 3.9076 - loss1/classifier_accuracy: 0.2080 - loss1/classifier_top5_acc: 0.3834 - loss1/classifier_macro_f1score: 0.0192 - loss2/classifier_accuracy: 0.1964 - loss2/classifier_top5_acc: 0.3644 - loss2/classifier_macro_f1score: 0.0191 - loss3/classifier_accuracy: 0.1963 - loss3/classifier_top5_acc: 0.3733 - loss3/classifier_macro_f1score: 0.0194
# Epoch 00007: val_loss improved from 6.43004 to 6.20833, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/GoogleNet/007.h5
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 191/191 [==============================] - 377s 2s/step - loss: 6.2702 - loss1/classifier_loss: 3.9041 - loss2/classifier_loss: 3.9714 - loss3/classifier_loss: 3.9076 - loss1/classifier_accuracy: 0.2080 - loss1/classifier_top5_acc: 0.3834 - loss1/classifier_macro_f1score: 0.0192 - loss2/classifier_accuracy: 0.1964 - loss2/classifier_top5_acc: 0.3644 - loss2/classifier_macro_f1score: 0.0191 - loss3/classifier_accuracy: 0.1963 - loss3/classifier_top5_acc: 0.3733 - loss3/classifier_macro_f1score: 0.0194 - val_loss: 6.2083 - val_loss1/classifier_loss: 3.6849 - val_loss2/classifier_loss: 3.8192 - val_loss3/classifier_loss: 3.9571 - val_loss1/classifier_accuracy: 0.2408 - val_loss1/classifier_top5_acc: 0.4375 - val_loss1/classifier_macro_f1score: 0.0235 - val_loss2/classifier_accuracy: 0.2313 - val_loss2/classifier_top5_acc: 0.4086 - val_loss2/classifier_macro_f1score: 0.0225 - val_loss3/classifier_accuracy: 0.1977 - val_loss3/classifier_top5_acc: 0.3635 - val_loss3/classifier_macro_f1score: 0.0236
# Learning rate:  0.0003
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 8/70
# 191/191 [==============================] - ETA: 0s - loss: 6.0134 - loss1/classifier_loss: 3.7600 - loss2/classifier_loss: 3.8283 - loss3/classifier_loss: 3.7369 - loss1/classifier_accuracy: 0.2280 - loss1/classifier_top5_acc: 0.4133 - loss1/classifier_macro_f1score: 0.0228 - loss2/classifier_accuracy: 0.2136 - loss2/classifier_top5_acc: 0.3957 - loss2/classifier_macro_f1score: 0.0228 - loss3/classifier_accuracy: 0.2170 - loss3/classifier_top5_acc: 0.4090 - loss3/classifier_macro_f1score: 0.0243
# Epoch 00008: val_loss improved from 6.20833 to 6.11865, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/GoogleNet/008.h5
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 191/191 [==============================] - 377s 2s/step - loss: 6.0134 - loss1/classifier_loss: 3.7600 - loss2/classifier_loss: 3.8283 - loss3/classifier_loss: 3.7369 - loss1/classifier_accuracy: 0.2280 - loss1/classifier_top5_acc: 0.4133 - loss1/classifier_macro_f1score: 0.0228 - loss2/classifier_accuracy: 0.2136 - loss2/classifier_top5_acc: 0.3957 - loss2/classifier_macro_f1score: 0.0228 - loss3/classifier_accuracy: 0.2170 - loss3/classifier_top5_acc: 0.4090 - loss3/classifier_macro_f1score: 0.0243 - val_loss: 6.1186 - val_loss1/classifier_loss: 3.6011 - val_loss2/classifier_loss: 3.7679 - val_loss3/classifier_loss: 3.9079 - val_loss1/classifier_accuracy: 0.2554 - val_loss1/classifier_top5_acc: 0.4565 - val_loss1/classifier_macro_f1score: 0.0282 - val_loss2/classifier_accuracy: 0.2347 - val_loss2/classifier_top5_acc: 0.4175 - val_loss2/classifier_macro_f1score: 0.0253 - val_loss3/classifier_accuracy: 0.2109 - val_loss3/classifier_top5_acc: 0.3764 - val_loss3/classifier_macro_f1score: 0.0240
# Learning rate:  0.0003
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 9/70
# 191/191 [==============================] - ETA: 0s - loss: 5.7513 - loss1/classifier_loss: 3.6217 - loss2/classifier_loss: 3.6690 - loss3/classifier_loss: 3.5641 - loss1/classifier_accuracy: 0.2463 - loss1/classifier_top5_acc: 0.4409 - loss1/classifier_macro_f1score: 0.0275 - loss2/classifier_accuracy: 0.2375 - loss2/classifier_top5_acc: 0.4309 - loss2/classifier_macro_f1score: 0.0278 - loss3/classifier_accuracy: 0.2446 - loss3/classifier_top5_acc: 0.4455 - loss3/classifier_macro_f1score: 0.0297
# Epoch 00009: val_loss improved from 6.11865 to 5.73163, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/GoogleNet/009.h5
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 191/191 [==============================] - 377s 2s/step - loss: 5.7513 - loss1/classifier_loss: 3.6217 - loss2/classifier_loss: 3.6690 - loss3/classifier_loss: 3.5641 - loss1/classifier_accuracy: 0.2463 - loss1/classifier_top5_acc: 0.4409 - loss1/classifier_macro_f1score: 0.0275 - loss2/classifier_accuracy: 0.2375 - loss2/classifier_top5_acc: 0.4309 - loss2/classifier_macro_f1score: 0.0278 - loss3/classifier_accuracy: 0.2446 - loss3/classifier_top5_acc: 0.4455 - loss3/classifier_macro_f1score: 0.0297 - val_loss: 5.7316 - val_loss1/classifier_loss: 3.4214 - val_loss2/classifier_loss: 3.5199 - val_loss3/classifier_loss: 3.6493 - val_loss1/classifier_accuracy: 0.2887 - val_loss1/classifier_top5_acc: 0.4946 - val_loss1/classifier_macro_f1score: 0.0366 - val_loss2/classifier_accuracy: 0.2636 - val_loss2/classifier_top5_acc: 0.4681 - val_loss2/classifier_macro_f1score: 0.0371 - val_loss3/classifier_accuracy: 0.2398 - val_loss3/classifier_top5_acc: 0.4385 - val_loss3/classifier_macro_f1score: 0.0359
# Learning rate:  0.0003
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 10/70
# 191/191 [==============================] - ETA: 0s - loss: 5.5193 - loss1/classifier_loss: 3.5155 - loss2/classifier_loss: 3.5463 - loss3/classifier_loss: 3.4007 - loss1/classifier_accuracy: 0.2630 - loss1/classifier_top5_acc: 0.4600 - loss1/classifier_macro_f1score: 0.0305 - loss2/classifier_accuracy: 0.2553 - loss2/classifier_top5_acc: 0.4550 - loss2/classifier_macro_f1score: 0.0313 - loss3/classifier_accuracy: 0.2659 - loss3/classifier_top5_acc: 0.4783 - loss3/classifier_macro_f1score: 0.0359
# Epoch 00010: val_loss improved from 5.73163 to 5.47551, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/GoogleNet/010.h5
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 191/191 [==============================] - 378s 2s/step - loss: 5.5193 - loss1/classifier_loss: 3.5155 - loss2/classifier_loss: 3.5463 - loss3/classifier_loss: 3.4007 - loss1/classifier_accuracy: 0.2630 - loss1/classifier_top5_acc: 0.4600 - loss1/classifier_macro_f1score: 0.0305 - loss2/classifier_accuracy: 0.2553 - loss2/classifier_top5_acc: 0.4550 - loss2/classifier_macro_f1score: 0.0313 - loss3/classifier_accuracy: 0.2659 - loss3/classifier_top5_acc: 0.4783 - loss3/classifier_macro_f1score: 0.0359 - val_loss: 5.4755 - val_loss1/classifier_loss: 3.2859 - val_loss2/classifier_loss: 3.3748 - val_loss3/classifier_loss: 3.4773 - val_loss1/classifier_accuracy: 0.3111 - val_loss1/classifier_top5_acc: 0.5228 - val_loss1/classifier_macro_f1score: 0.0388 - val_loss2/classifier_accuracy: 0.2921 - val_loss2/classifier_top5_acc: 0.4922 - val_loss2/classifier_macro_f1score: 0.0409 - val_loss3/classifier_accuracy: 0.2765 - val_loss3/classifier_top5_acc: 0.4789 - val_loss3/classifier_macro_f1score: 0.0410
# Learning rate:  0.0003
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 11/70
# 191/191 [==============================] - ETA: 0s - loss: 5.3299 - loss1/classifier_loss: 3.4078 - loss2/classifier_loss: 3.4389 - loss3/classifier_loss: 3.2759 - loss1/classifier_accuracy: 0.2781 - loss1/classifier_top5_acc: 0.4874 - loss1/classifier_macro_f1score: 0.0342 - loss2/classifier_accuracy: 0.2722 - loss2/classifier_top5_acc: 0.4750 - loss2/classifier_macro_f1score: 0.0361 - loss3/classifier_accuracy: 0.2842 - loss3/classifier_top5_acc: 0.5035 - loss3/classifier_macro_f1score: 0.0407
# Epoch 00011: val_loss improved from 5.47551 to 5.25074, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/GoogleNet/011.h5
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 191/191 [==============================] - 379s 2s/step - loss: 5.3299 - loss1/classifier_loss: 3.4078 - loss2/classifier_loss: 3.4389 - loss3/classifier_loss: 3.2759 - loss1/classifier_accuracy: 0.2781 - loss1/classifier_top5_acc: 0.4874 - loss1/classifier_macro_f1score: 0.0342 - loss2/classifier_accuracy: 0.2722 - loss2/classifier_top5_acc: 0.4750 - loss2/classifier_macro_f1score: 0.0361 - loss3/classifier_accuracy: 0.2842 - loss3/classifier_top5_acc: 0.5035 - loss3/classifier_macro_f1score: 0.0407 - val_loss: 5.2507 - val_loss1/classifier_loss: 3.1893 - val_loss2/classifier_loss: 3.2743 - val_loss3/classifier_loss: 3.3116 - val_loss1/classifier_accuracy: 0.3203 - val_loss1/classifier_top5_acc: 0.5391 - val_loss1/classifier_macro_f1score: 0.0428 - val_loss2/classifier_accuracy: 0.3101 - val_loss2/classifier_top5_acc: 0.5065 - val_loss2/classifier_macro_f1score: 0.0443 - val_loss3/classifier_accuracy: 0.2969 - val_loss3/classifier_top5_acc: 0.5166 - val_loss3/classifier_macro_f1score: 0.0441
# Learning rate:  0.0003
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 12/70
# 191/191 [==============================] - ETA: 0s - loss: 5.0836 - loss1/classifier_loss: 3.2963 - loss2/classifier_loss: 3.3016 - loss3/classifier_loss: 3.1042 - loss1/classifier_accuracy: 0.2928 - loss1/classifier_top5_acc: 0.5075 - loss1/classifier_macro_f1score: 0.0390 - loss2/classifier_accuracy: 0.2892 - loss2/classifier_top5_acc: 0.5056 - loss2/classifier_macro_f1score: 0.0412 - loss3/classifier_accuracy: 0.3136 - loss3/classifier_top5_acc: 0.5378 - loss3/classifier_macro_f1score: 0.0479
# Epoch 00012: val_loss improved from 5.25074 to 5.16896, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/GoogleNet/012.h5
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 191/191 [==============================] - 379s 2s/step - loss: 5.0836 - loss1/classifier_loss: 3.2963 - loss2/classifier_loss: 3.3016 - loss3/classifier_loss: 3.1042 - loss1/classifier_accuracy: 0.2928 - loss1/classifier_top5_acc: 0.5075 - loss1/classifier_macro_f1score: 0.0390 - loss2/classifier_accuracy: 0.2892 - loss2/classifier_top5_acc: 0.5056 - loss2/classifier_macro_f1score: 0.0412 - loss3/classifier_accuracy: 0.3136 - loss3/classifier_top5_acc: 0.5378 - loss3/classifier_macro_f1score: 0.0479 - val_loss: 5.1690 - val_loss1/classifier_loss: 3.1583 - val_loss2/classifier_loss: 3.1963 - val_loss3/classifier_loss: 3.2626 - val_loss1/classifier_accuracy: 0.3230 - val_loss1/classifier_top5_acc: 0.5452 - val_loss1/classifier_macro_f1score: 0.0486 - val_loss2/classifier_accuracy: 0.3142 - val_loss2/classifier_top5_acc: 0.5296 - val_loss2/classifier_macro_f1score: 0.0501 - val_loss3/classifier_accuracy: 0.3091 - val_loss3/classifier_top5_acc: 0.5119 - val_loss3/classifier_macro_f1score: 0.0539
# Learning rate:  0.0003
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 13/70
# 191/191 [==============================] - ETA: 0s - loss: 4.8943 - loss1/classifier_loss: 3.2186 - loss2/classifier_loss: 3.1893 - loss3/classifier_loss: 2.9719 - loss1/classifier_accuracy: 0.3057 - loss1/classifier_top5_acc: 0.5222 - loss1/classifier_macro_f1score: 0.0440 - loss2/classifier_accuracy: 0.3095 - loss2/classifier_top5_acc: 0.5264 - loss2/classifier_macro_f1score: 0.0466 - loss3/classifier_accuracy: 0.3361 - loss3/classifier_top5_acc: 0.5677 - loss3/classifier_macro_f1score: 0.0550
# Epoch 00013: val_loss did not improve from 5.16896
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 191/191 [==============================] - 379s 2s/step - loss: 4.8943 - loss1/classifier_loss: 3.2186 - loss2/classifier_loss: 3.1893 - loss3/classifier_loss: 2.9719 - loss1/classifier_accuracy: 0.3057 - loss1/classifier_top5_acc: 0.5222 - loss1/classifier_macro_f1score: 0.0440 - loss2/classifier_accuracy: 0.3095 - loss2/classifier_top5_acc: 0.5264 - loss2/classifier_macro_f1score: 0.0466 - loss3/classifier_accuracy: 0.3361 - loss3/classifier_top5_acc: 0.5677 - loss3/classifier_macro_f1score: 0.0550 - val_loss: 5.1944 - val_loss1/classifier_loss: 3.1920 - val_loss2/classifier_loss: 3.2340 - val_loss3/classifier_loss: 3.2665 - val_loss1/classifier_accuracy: 0.3342 - val_loss1/classifier_top5_acc: 0.5469 - val_loss1/classifier_macro_f1score: 0.0448 - val_loss2/classifier_accuracy: 0.3091 - val_loss2/classifier_top5_acc: 0.5302 - val_loss2/classifier_macro_f1score: 0.0449 - val_loss3/classifier_accuracy: 0.3054 - val_loss3/classifier_top5_acc: 0.5245 - val_loss3/classifier_macro_f1score: 0.0466
# Learning rate:  0.0003
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 14/70
# 191/191 [==============================] - ETA: 0s - loss: 4.7298 - loss1/classifier_loss: 3.1387 - loss2/classifier_loss: 3.0990 - loss3/classifier_loss: 2.8584 - loss1/classifier_accuracy: 0.3155 - loss1/classifier_top5_acc: 0.5408 - loss1/classifier_macro_f1score: 0.0472 - loss2/classifier_accuracy: 0.3205 - loss2/classifier_top5_acc: 0.5482 - loss2/classifier_macro_f1score: 0.0514 - loss3/classifier_accuracy: 0.3538 - loss3/classifier_top5_acc: 0.5902 - loss3/classifier_macro_f1score: 0.0626
# Epoch 00014: val_loss improved from 5.16896 to 5.05103, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/GoogleNet/014.h5
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 191/191 [==============================] - 380s 2s/step - loss: 4.7298 - loss1/classifier_loss: 3.1387 - loss2/classifier_loss: 3.0990 - loss3/classifier_loss: 2.8584 - loss1/classifier_accuracy: 0.3155 - loss1/classifier_top5_acc: 0.5408 - loss1/classifier_macro_f1score: 0.0472 - loss2/classifier_accuracy: 0.3205 - loss2/classifier_top5_acc: 0.5482 - loss2/classifier_macro_f1score: 0.0514 - loss3/classifier_accuracy: 0.3538 - loss3/classifier_top5_acc: 0.5902 - loss3/classifier_macro_f1score: 0.0626 - val_loss: 5.0510 - val_loss1/classifier_loss: 3.0973 - val_loss2/classifier_loss: 3.1263 - val_loss3/classifier_loss: 3.1840 - val_loss1/classifier_accuracy: 0.3325 - val_loss1/classifier_top5_acc: 0.5618 - val_loss1/classifier_macro_f1score: 0.0482 - val_loss2/classifier_accuracy: 0.3237 - val_loss2/classifier_top5_acc: 0.5455 - val_loss2/classifier_macro_f1score: 0.0533 - val_loss3/classifier_accuracy: 0.3193 - val_loss3/classifier_top5_acc: 0.5374 - val_loss3/classifier_macro_f1score: 0.0553
# Learning rate:  0.0003
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 15/70
# 191/191 [==============================] - ETA: 0s - loss: 4.5281 - loss1/classifier_loss: 3.0452 - loss2/classifier_loss: 2.9862 - loss3/classifier_loss: 2.7187 - loss1/classifier_accuracy: 0.3295 - loss1/classifier_top5_acc: 0.5590 - loss1/classifier_macro_f1score: 0.0495 - loss2/classifier_accuracy: 0.3378 - loss2/classifier_top5_acc: 0.5662 - loss2/classifier_macro_f1score: 0.0561 - loss3/classifier_accuracy: 0.3812 - loss3/classifier_top5_acc: 0.6205 - loss3/classifier_macro_f1score: 0.0694
# Epoch 00015: val_loss improved from 5.05103 to 4.81448, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/GoogleNet/015.h5
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 191/191 [==============================] - 378s 2s/step - loss: 4.5281 - loss1/classifier_loss: 3.0452 - loss2/classifier_loss: 2.9862 - loss3/classifier_loss: 2.7187 - loss1/classifier_accuracy: 0.3295 - loss1/classifier_top5_acc: 0.5590 - loss1/classifier_macro_f1score: 0.0495 - loss2/classifier_accuracy: 0.3378 - loss2/classifier_top5_acc: 0.5662 - loss2/classifier_macro_f1score: 0.0561 - loss3/classifier_accuracy: 0.3812 - loss3/classifier_top5_acc: 0.6205 - loss3/classifier_macro_f1score: 0.0694 - val_loss: 4.8145 - val_loss1/classifier_loss: 2.9754 - val_loss2/classifier_loss: 2.9593 - val_loss3/classifier_loss: 3.0341 - val_loss1/classifier_accuracy: 0.3512 - val_loss1/classifier_top5_acc: 0.5856 - val_loss1/classifier_macro_f1score: 0.0535 - val_loss2/classifier_accuracy: 0.3529 - val_loss2/classifier_top5_acc: 0.5802 - val_loss2/classifier_macro_f1score: 0.0611 - val_loss3/classifier_accuracy: 0.3468 - val_loss3/classifier_top5_acc: 0.5747 - val_loss3/classifier_macro_f1score: 0.0660
# Learning rate:  0.0003
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 16/70
# 191/191 [==============================] - ETA: 0s - loss: 4.3597 - loss1/classifier_loss: 2.9704 - loss2/classifier_loss: 2.8941 - loss3/classifier_loss: 2.6004 - loss1/classifier_accuracy: 0.3462 - loss1/classifier_top5_acc: 0.5741 - loss1/classifier_macro_f1score: 0.0544 - loss2/classifier_accuracy: 0.3551 - loss2/classifier_top5_acc: 0.5877 - loss2/classifier_macro_f1score: 0.0633 - loss3/classifier_accuracy: 0.4028 - loss3/classifier_top5_acc: 0.6464 - loss3/classifier_macro_f1score: 0.0783
# Epoch 00016: val_loss improved from 4.81448 to 4.71890, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/GoogleNet/016.h5
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 191/191 [==============================] - 378s 2s/step - loss: 4.3597 - loss1/classifier_loss: 2.9704 - loss2/classifier_loss: 2.8941 - loss3/classifier_loss: 2.6004 - loss1/classifier_accuracy: 0.3462 - loss1/classifier_top5_acc: 0.5741 - loss1/classifier_macro_f1score: 0.0544 - loss2/classifier_accuracy: 0.3551 - loss2/classifier_top5_acc: 0.5877 - loss2/classifier_macro_f1score: 0.0633 - loss3/classifier_accuracy: 0.4028 - loss3/classifier_top5_acc: 0.6464 - loss3/classifier_macro_f1score: 0.0783 - val_loss: 4.7189 - val_loss1/classifier_loss: 2.9017 - val_loss2/classifier_loss: 2.9288 - val_loss3/classifier_loss: 2.9698 - val_loss1/classifier_accuracy: 0.3668 - val_loss1/classifier_top5_acc: 0.5941 - val_loss1/classifier_macro_f1score: 0.0622 - val_loss2/classifier_accuracy: 0.3533 - val_loss2/classifier_top5_acc: 0.5873 - val_loss2/classifier_macro_f1score: 0.0725 - val_loss3/classifier_accuracy: 0.3570 - val_loss3/classifier_top5_acc: 0.5941 - val_loss3/classifier_macro_f1score: 0.0781
# Learning rate:  0.0003
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 17/70
# 191/191 [==============================] - ETA: 0s - loss: 4.2139 - loss1/classifier_loss: 2.8995 - loss2/classifier_loss: 2.8152 - loss3/classifier_loss: 2.4995 - loss1/classifier_accuracy: 0.3595 - loss1/classifier_top5_acc: 0.5908 - loss1/classifier_macro_f1score: 0.0577 - loss2/classifier_accuracy: 0.3710 - loss2/classifier_top5_acc: 0.6032 - loss2/classifier_macro_f1score: 0.0673 - loss3/classifier_accuracy: 0.4161 - loss3/classifier_top5_acc: 0.6607 - loss3/classifier_macro_f1score: 0.0861
# Epoch 00017: val_loss did not improve from 4.71890
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 191/191 [==============================] - 378s 2s/step - loss: 4.2139 - loss1/classifier_loss: 2.8995 - loss2/classifier_loss: 2.8152 - loss3/classifier_loss: 2.4995 - loss1/classifier_accuracy: 0.3595 - loss1/classifier_top5_acc: 0.5908 - loss1/classifier_macro_f1score: 0.0577 - loss2/classifier_accuracy: 0.3710 - loss2/classifier_top5_acc: 0.6032 - loss2/classifier_macro_f1score: 0.0673 - loss3/classifier_accuracy: 0.4161 - loss3/classifier_top5_acc: 0.6607 - loss3/classifier_macro_f1score: 0.0861 - val_loss: 4.7987 - val_loss1/classifier_loss: 2.8914 - val_loss2/classifier_loss: 2.9873 - val_loss3/classifier_loss: 3.0351 - val_loss1/classifier_accuracy: 0.3641 - val_loss1/classifier_top5_acc: 0.6016 - val_loss1/classifier_macro_f1score: 0.0637 - val_loss2/classifier_accuracy: 0.3553 - val_loss2/classifier_top5_acc: 0.5757 - val_loss2/classifier_macro_f1score: 0.0686 - val_loss3/classifier_accuracy: 0.3584 - val_loss3/classifier_top5_acc: 0.5856 - val_loss3/classifier_macro_f1score: 0.0775
# Learning rate:  0.0003
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 18/70
# 191/191 [==============================] - ETA: 0s - loss: 4.0835 - loss1/classifier_loss: 2.8440 - loss2/classifier_loss: 2.7413 - loss3/classifier_loss: 2.4079 - loss1/classifier_accuracy: 0.3621 - loss1/classifier_top5_acc: 0.5969 - loss1/classifier_macro_f1score: 0.0624 - loss2/classifier_accuracy: 0.3799 - loss2/classifier_top5_acc: 0.6149 - loss2/classifier_macro_f1score: 0.0718 - loss3/classifier_accuracy: 0.4357 - loss3/classifier_top5_acc: 0.6789 - loss3/classifier_macro_f1score: 0.0921
# Epoch 00018: val_loss improved from 4.71890 to 4.52261, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/GoogleNet/018.h5
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 191/191 [==============================] - 378s 2s/step - loss: 4.0835 - loss1/classifier_loss: 2.8440 - loss2/classifier_loss: 2.7413 - loss3/classifier_loss: 2.4079 - loss1/classifier_accuracy: 0.3621 - loss1/classifier_top5_acc: 0.5969 - loss1/classifier_macro_f1score: 0.0624 - loss2/classifier_accuracy: 0.3799 - loss2/classifier_top5_acc: 0.6149 - loss2/classifier_macro_f1score: 0.0718 - loss3/classifier_accuracy: 0.4357 - loss3/classifier_top5_acc: 0.6789 - loss3/classifier_macro_f1score: 0.0921 - val_loss: 4.5226 - val_loss1/classifier_loss: 2.8347 - val_loss2/classifier_loss: 2.8208 - val_loss3/classifier_loss: 2.8260 - val_loss1/classifier_accuracy: 0.3825 - val_loss1/classifier_top5_acc: 0.6087 - val_loss1/classifier_macro_f1score: 0.0625 - val_loss2/classifier_accuracy: 0.3825 - val_loss2/classifier_top5_acc: 0.6131 - val_loss2/classifier_macro_f1score: 0.0673 - val_loss3/classifier_accuracy: 0.3855 - val_loss3/classifier_top5_acc: 0.6135 - val_loss3/classifier_macro_f1score: 0.0764
# Learning rate:  0.0003
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 19/70
# 191/191 [==============================] - ETA: 0s - loss: 3.9001 - loss1/classifier_loss: 2.7730 - loss2/classifier_loss: 2.6506 - loss3/classifier_loss: 2.2730 - loss1/classifier_accuracy: 0.3782 - loss1/classifier_top5_acc: 0.6105 - loss1/classifier_macro_f1score: 0.0665 - loss2/classifier_accuracy: 0.3988 - loss2/classifier_top5_acc: 0.6323 - loss2/classifier_macro_f1score: 0.0787 - loss3/classifier_accuracy: 0.4595 - loss3/classifier_top5_acc: 0.7063 - loss3/classifier_macro_f1score: 0.1009
# Epoch 00019: val_loss did not improve from 4.52261
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 191/191 [==============================] - 377s 2s/step - loss: 3.9001 - loss1/classifier_loss: 2.7730 - loss2/classifier_loss: 2.6506 - loss3/classifier_loss: 2.2730 - loss1/classifier_accuracy: 0.3782 - loss1/classifier_top5_acc: 0.6105 - loss1/classifier_macro_f1score: 0.0665 - loss2/classifier_accuracy: 0.3988 - loss2/classifier_top5_acc: 0.6323 - loss2/classifier_macro_f1score: 0.0787 - loss3/classifier_accuracy: 0.4595 - loss3/classifier_top5_acc: 0.7063 - loss3/classifier_macro_f1score: 0.1009 - val_loss: 4.5770 - val_loss1/classifier_loss: 2.8084 - val_loss2/classifier_loss: 2.8355 - val_loss3/classifier_loss: 2.8839 - val_loss1/classifier_accuracy: 0.3855 - val_loss1/classifier_top5_acc: 0.6107 - val_loss1/classifier_macro_f1score: 0.0730 - val_loss2/classifier_accuracy: 0.3767 - val_loss2/classifier_top5_acc: 0.6060 - val_loss2/classifier_macro_f1score: 0.0788 - val_loss3/classifier_accuracy: 0.3760 - val_loss3/classifier_top5_acc: 0.6033 - val_loss3/classifier_macro_f1score: 0.0862
# Learning rate:  0.0003
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 20/70
# 191/191 [==============================] - ETA: 0s - loss: 3.7536 - loss1/classifier_loss: 2.7003 - loss2/classifier_loss: 2.5734 - loss3/classifier_loss: 2.1715 - loss1/classifier_accuracy: 0.3922 - loss1/classifier_top5_acc: 0.6274 - loss1/classifier_macro_f1score: 0.0701 - loss2/classifier_accuracy: 0.4114 - loss2/classifier_top5_acc: 0.6493 - loss2/classifier_macro_f1score: 0.0837 - loss3/classifier_accuracy: 0.4775 - loss3/classifier_top5_acc: 0.7245 - loss3/classifier_macro_f1score: 0.1099
# Epoch 00020: val_loss improved from 4.52261 to 4.44371, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/GoogleNet/020.h5
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 191/191 [==============================] - 378s 2s/step - loss: 3.7536 - loss1/classifier_loss: 2.7003 - loss2/classifier_loss: 2.5734 - loss3/classifier_loss: 2.1715 - loss1/classifier_accuracy: 0.3922 - loss1/classifier_top5_acc: 0.6274 - loss1/classifier_macro_f1score: 0.0701 - loss2/classifier_accuracy: 0.4114 - loss2/classifier_top5_acc: 0.6493 - loss2/classifier_macro_f1score: 0.0837 - loss3/classifier_accuracy: 0.4775 - loss3/classifier_top5_acc: 0.7245 - loss3/classifier_macro_f1score: 0.1099 - val_loss: 4.4437 - val_loss1/classifier_loss: 2.7385 - val_loss2/classifier_loss: 2.7312 - val_loss3/classifier_loss: 2.8028 - val_loss1/classifier_accuracy: 0.3961 - val_loss1/classifier_top5_acc: 0.6342 - val_loss1/classifier_macro_f1score: 0.0793 - val_loss2/classifier_accuracy: 0.3957 - val_loss2/classifier_top5_acc: 0.6257 - val_loss2/classifier_macro_f1score: 0.0869 - val_loss3/classifier_accuracy: 0.3944 - val_loss3/classifier_top5_acc: 0.6223 - val_loss3/classifier_macro_f1score: 0.0915
# Learning rate:  0.0003
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 21/70
# 191/191 [==============================] - ETA: 0s - loss: 3.6260 - loss1/classifier_loss: 2.6635 - loss2/classifier_loss: 2.5176 - loss3/classifier_loss: 2.0717 - loss1/classifier_accuracy: 0.3948 - loss1/classifier_top5_acc: 0.6357 - loss1/classifier_macro_f1score: 0.0741 - loss2/classifier_accuracy: 0.4213 - loss2/classifier_top5_acc: 0.6597 - loss2/classifier_macro_f1score: 0.0888 - loss3/classifier_accuracy: 0.4966 - loss3/classifier_top5_acc: 0.7400 - loss3/classifier_macro_f1score: 0.1196
# Epoch 00021: val_loss improved from 4.44371 to 4.36540, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/GoogleNet/021.h5
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 191/191 [==============================] - 378s 2s/step - loss: 3.6260 - loss1/classifier_loss: 2.6635 - loss2/classifier_loss: 2.5176 - loss3/classifier_loss: 2.0717 - loss1/classifier_accuracy: 0.3948 - loss1/classifier_top5_acc: 0.6357 - loss1/classifier_macro_f1score: 0.0741 - loss2/classifier_accuracy: 0.4213 - loss2/classifier_top5_acc: 0.6597 - loss2/classifier_macro_f1score: 0.0888 - loss3/classifier_accuracy: 0.4966 - loss3/classifier_top5_acc: 0.7400 - loss3/classifier_macro_f1score: 0.1196 - val_loss: 4.3654 - val_loss1/classifier_loss: 2.6876 - val_loss2/classifier_loss: 2.6639 - val_loss3/classifier_loss: 2.7599 - val_loss1/classifier_accuracy: 0.4042 - val_loss1/classifier_top5_acc: 0.6372 - val_loss1/classifier_macro_f1score: 0.0788 - val_loss2/classifier_accuracy: 0.4120 - val_loss2/classifier_top5_acc: 0.6393 - val_loss2/classifier_macro_f1score: 0.0864 - val_loss3/classifier_accuracy: 0.3954 - val_loss3/classifier_top5_acc: 0.6399 - val_loss3/classifier_macro_f1score: 0.0987
# Learning rate:  0.0003
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 22/70
# 191/191 [==============================] - ETA: 0s - loss: 3.5256 - loss1/classifier_loss: 2.6098 - loss2/classifier_loss: 2.4527 - loss3/classifier_loss: 2.0069 - loss1/classifier_accuracy: 0.4028 - loss1/classifier_top5_acc: 0.6457 - loss1/classifier_macro_f1score: 0.0756 - loss2/classifier_accuracy: 0.4329 - loss2/classifier_top5_acc: 0.6726 - loss2/classifier_macro_f1score: 0.0913 - loss3/classifier_accuracy: 0.5128 - loss3/classifier_top5_acc: 0.7534 - loss3/classifier_macro_f1score: 0.1231
# Epoch 00022: val_loss did not improve from 4.36540
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 191/191 [==============================] - 377s 2s/step - loss: 3.5256 - loss1/classifier_loss: 2.6098 - loss2/classifier_loss: 2.4527 - loss3/classifier_loss: 2.0069 - loss1/classifier_accuracy: 0.4028 - loss1/classifier_top5_acc: 0.6457 - loss1/classifier_macro_f1score: 0.0756 - loss2/classifier_accuracy: 0.4329 - loss2/classifier_top5_acc: 0.6726 - loss2/classifier_macro_f1score: 0.0913 - loss3/classifier_accuracy: 0.5128 - loss3/classifier_top5_acc: 0.7534 - loss3/classifier_macro_f1score: 0.1231 - val_loss: 4.4937 - val_loss1/classifier_loss: 2.7238 - val_loss2/classifier_loss: 2.7466 - val_loss3/classifier_loss: 2.8526 - val_loss1/classifier_accuracy: 0.4025 - val_loss1/classifier_top5_acc: 0.6318 - val_loss1/classifier_macro_f1score: 0.0748 - val_loss2/classifier_accuracy: 0.3906 - val_loss2/classifier_top5_acc: 0.6213 - val_loss2/classifier_macro_f1score: 0.0827 - val_loss3/classifier_accuracy: 0.3957 - val_loss3/classifier_top5_acc: 0.6223 - val_loss3/classifier_macro_f1score: 0.0892
# Learning rate:  0.0003
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 23/70
# 191/191 [==============================] - ETA: 0s - loss: 3.4168 - loss1/classifier_loss: 2.5613 - loss2/classifier_loss: 2.4008 - loss3/classifier_loss: 1.9281 - loss1/classifier_accuracy: 0.4129 - loss1/classifier_top5_acc: 0.6567 - loss1/classifier_macro_f1score: 0.0805 - loss2/classifier_accuracy: 0.4387 - loss2/classifier_top5_acc: 0.6820 - loss2/classifier_macro_f1score: 0.0967 - loss3/classifier_accuracy: 0.5226 - loss3/classifier_top5_acc: 0.7663 - loss3/classifier_macro_f1score: 0.1319
# Epoch 00023: val_loss did not improve from 4.36540
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 191/191 [==============================] - 378s 2s/step - loss: 3.4168 - loss1/classifier_loss: 2.5613 - loss2/classifier_loss: 2.4008 - loss3/classifier_loss: 1.9281 - loss1/classifier_accuracy: 0.4129 - loss1/classifier_top5_acc: 0.6567 - loss1/classifier_macro_f1score: 0.0805 - loss2/classifier_accuracy: 0.4387 - loss2/classifier_top5_acc: 0.6820 - loss2/classifier_macro_f1score: 0.0967 - loss3/classifier_accuracy: 0.5226 - loss3/classifier_top5_acc: 0.7663 - loss3/classifier_macro_f1score: 0.1319 - val_loss: 4.3933 - val_loss1/classifier_loss: 2.6368 - val_loss2/classifier_loss: 2.6632 - val_loss3/classifier_loss: 2.8033 - val_loss1/classifier_accuracy: 0.4260 - val_loss1/classifier_top5_acc: 0.6484 - val_loss1/classifier_macro_f1score: 0.0857 - val_loss2/classifier_accuracy: 0.4141 - val_loss2/classifier_top5_acc: 0.6423 - val_loss2/classifier_macro_f1score: 0.0945 - val_loss3/classifier_accuracy: 0.4076 - val_loss3/classifier_top5_acc: 0.6308 - val_loss3/classifier_macro_f1score: 0.1004
# Learning rate:  0.0003
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 24/70
# ...
#
# Epoch 00062: LearningRateScheduler reducing learning rate to 2.9999999999999997e-06.
# Epoch 62/70
# 191/191 [==============================] - ETA: 0s - loss: 1.4786 - loss1/classifier_loss: 1.8029 - loss2/classifier_loss: 1.4257 - loss3/classifier_loss: 0.5100 - loss1/classifier_accuracy: 0.5515 - loss1/classifier_top5_acc: 0.7913 - loss1/classifier_macro_f1score: 0.1387 - loss2/classifier_accuracy: 0.6295 - loss2/classifier_top5_acc: 0.8457 - loss2/classifier_macro_f1score: 0.1839 - loss3/classifier_accuracy: 0.8522 - loss3/classifier_top5_acc: 0.9693 - loss3/classifier_macro_f1score: 0.2936
# Epoch 00062: val_loss did not improve from 4.23277
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 191/191 [==============================] - 381s 2s/step - loss: 1.4786 - loss1/classifier_loss: 1.8029 - loss2/classifier_loss: 1.4257 - loss3/classifier_loss: 0.5100 - loss1/classifier_accuracy: 0.5515 - loss1/classifier_top5_acc: 0.7913 - loss1/classifier_macro_f1score: 0.1387 - loss2/classifier_accuracy: 0.6295 - loss2/classifier_top5_acc: 0.8457 - loss2/classifier_macro_f1score: 0.1839 - loss3/classifier_accuracy: 0.8522 - loss3/classifier_top5_acc: 0.9693 - loss3/classifier_macro_f1score: 0.2936 - val_loss: 4.6719 - val_loss1/classifier_loss: 2.4179 - val_loss2/classifier_loss: 2.5135 - val_loss3/classifier_loss: 3.1925 - val_loss1/classifier_accuracy: 0.4813 - val_loss1/classifier_top5_acc: 0.6895 - val_loss1/classifier_macro_f1score: 0.1244 - val_loss2/classifier_accuracy: 0.4813 - val_loss2/classifier_top5_acc: 0.6929 - val_loss2/classifier_macro_f1score: 0.1365 - val_loss3/classifier_accuracy: 0.4745 - val_loss3/classifier_top5_acc: 0.6827 - val_loss3/classifier_macro_f1score: 0.1512
# Learning rate:  2.9999999999999997e-06
#
# Epoch 00063: LearningRateScheduler reducing learning rate to 2.9999999999999997e-06.
# Epoch 63/70
# 191/191 [==============================] - ETA: 0s - loss: 1.4757 - loss1/classifier_loss: 1.8004 - loss2/classifier_loss: 1.4232 - loss3/classifier_loss: 0.5086 - loss1/classifier_accuracy: 0.5547 - loss1/classifier_top5_acc: 0.7917 - loss1/classifier_macro_f1score: 0.1397 - loss2/classifier_accuracy: 0.6338 - loss2/classifier_top5_acc: 0.8491 - loss2/classifier_macro_f1score: 0.1833 - loss3/classifier_accuracy: 0.8523 - loss3/classifier_top5_acc: 0.9722 - loss3/classifier_macro_f1score: 0.2920
# Epoch 00063: val_loss did not improve from 4.23277
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 191/191 [==============================] - 381s 2s/step - loss: 1.4757 - loss1/classifier_loss: 1.8004 - loss2/classifier_loss: 1.4232 - loss3/classifier_loss: 0.5086 - loss1/classifier_accuracy: 0.5547 - loss1/classifier_top5_acc: 0.7917 - loss1/classifier_macro_f1score: 0.1397 - loss2/classifier_accuracy: 0.6338 - loss2/classifier_top5_acc: 0.8491 - loss2/classifier_macro_f1score: 0.1833 - loss3/classifier_accuracy: 0.8523 - loss3/classifier_top5_acc: 0.9722 - loss3/classifier_macro_f1score: 0.2920 - val_loss: 4.7047 - val_loss1/classifier_loss: 2.4318 - val_loss2/classifier_loss: 2.5329 - val_loss3/classifier_loss: 3.2153 - val_loss1/classifier_accuracy: 0.4806 - val_loss1/classifier_top5_acc: 0.6868 - val_loss1/classifier_macro_f1score: 0.1229 - val_loss2/classifier_accuracy: 0.4803 - val_loss2/classifier_top5_acc: 0.6909 - val_loss2/classifier_macro_f1score: 0.1351 - val_loss3/classifier_accuracy: 0.4701 - val_loss3/classifier_top5_acc: 0.6793 - val_loss3/classifier_macro_f1score: 0.1481
# Learning rate:  2.9999999999999997e-06
#
# Epoch 00064: LearningRateScheduler reducing learning rate to 2.9999999999999997e-06.
# Epoch 64/70
# 191/191 [==============================] - ETA: 0s - loss: 1.4879 - loss1/classifier_loss: 1.7973 - loss2/classifier_loss: 1.4321 - loss3/classifier_loss: 0.5191 - loss1/classifier_accuracy: 0.5554 - loss1/classifier_top5_acc: 0.7924 - loss1/classifier_macro_f1score: 0.1389 - loss2/classifier_accuracy: 0.6323 - loss2/classifier_top5_acc: 0.8456 - loss2/classifier_macro_f1score: 0.1813 - loss3/classifier_accuracy: 0.8483 - loss3/classifier_top5_acc: 0.9694 - loss3/classifier_macro_f1score: 0.2909
# Epoch 00064: val_loss did not improve from 4.23277
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 191/191 [==============================] - 380s 2s/step - loss: 1.4879 - loss1/classifier_loss: 1.7973 - loss2/classifier_loss: 1.4321 - loss3/classifier_loss: 0.5191 - loss1/classifier_accuracy: 0.5554 - loss1/classifier_top5_acc: 0.7924 - loss1/classifier_macro_f1score: 0.1389 - loss2/classifier_accuracy: 0.6323 - loss2/classifier_top5_acc: 0.8456 - loss2/classifier_macro_f1score: 0.1813 - loss3/classifier_accuracy: 0.8483 - loss3/classifier_top5_acc: 0.9694 - loss3/classifier_macro_f1score: 0.2909 - val_loss: 4.6865 - val_loss1/classifier_loss: 2.4311 - val_loss2/classifier_loss: 2.5286 - val_loss3/classifier_loss: 3.1986 - val_loss1/classifier_accuracy: 0.4796 - val_loss1/classifier_top5_acc: 0.6861 - val_loss1/classifier_macro_f1score: 0.1213 - val_loss2/classifier_accuracy: 0.4789 - val_loss2/classifier_top5_acc: 0.6909 - val_loss2/classifier_macro_f1score: 0.1322 - val_loss3/classifier_accuracy: 0.4735 - val_loss3/classifier_top5_acc: 0.6783 - val_loss3/classifier_macro_f1score: 0.1490
# Learning rate:  2.9999999999999997e-06
#
# Epoch 00065: LearningRateScheduler reducing learning rate to 2.9999999999999997e-06.
# Epoch 65/70
# 191/191 [==============================] - ETA: 0s - loss: 1.5096 - loss1/classifier_loss: 1.8221 - loss2/classifier_loss: 1.4521 - loss3/classifier_loss: 0.5274 - loss1/classifier_accuracy: 0.5501 - loss1/classifier_top5_acc: 0.7853 - loss1/classifier_macro_f1score: 0.1381 - loss2/classifier_accuracy: 0.6237 - loss2/classifier_top5_acc: 0.8439 - loss2/classifier_macro_f1score: 0.1796 - loss3/classifier_accuracy: 0.8459 - loss3/classifier_top5_acc: 0.9680 - loss3/classifier_macro_f1score: 0.2898
# Epoch 00065: val_loss did not improve from 4.23277
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 191/191 [==============================] - 381s 2s/step - loss: 1.5096 - loss1/classifier_loss: 1.8221 - loss2/classifier_loss: 1.4521 - loss3/classifier_loss: 0.5274 - loss1/classifier_accuracy: 0.5501 - loss1/classifier_top5_acc: 0.7853 - loss1/classifier_macro_f1score: 0.1381 - loss2/classifier_accuracy: 0.6237 - loss2/classifier_top5_acc: 0.8439 - loss2/classifier_macro_f1score: 0.1796 - loss3/classifier_accuracy: 0.8459 - loss3/classifier_top5_acc: 0.9680 - loss3/classifier_macro_f1score: 0.2898 - val_loss: 4.6657 - val_loss1/classifier_loss: 2.4287 - val_loss2/classifier_loss: 2.5291 - val_loss3/classifier_loss: 3.1784 - val_loss1/classifier_accuracy: 0.4803 - val_loss1/classifier_top5_acc: 0.6875 - val_loss1/classifier_macro_f1score: 0.1210 - val_loss2/classifier_accuracy: 0.4762 - val_loss2/classifier_top5_acc: 0.6892 - val_loss2/classifier_macro_f1score: 0.1347 - val_loss3/classifier_accuracy: 0.4732 - val_loss3/classifier_top5_acc: 0.6790 - val_loss3/classifier_macro_f1score: 0.1497
# Learning rate:  2.9999999999999997e-06
#
# Epoch 00066: LearningRateScheduler reducing learning rate to 2.9999999999999997e-06.
# Epoch 66/70
# 191/191 [==============================] - ETA: 0s - loss: 1.4711 - loss1/classifier_loss: 1.7905 - loss2/classifier_loss: 1.4134 - loss3/classifier_loss: 0.5099 - loss1/classifier_accuracy: 0.5553 - loss1/classifier_top5_acc: 0.7922 - loss1/classifier_macro_f1score: 0.1372 - loss2/classifier_accuracy: 0.6337 - loss2/classifier_top5_acc: 0.8503 - loss2/classifier_macro_f1score: 0.1815 - loss3/classifier_accuracy: 0.8524 - loss3/classifier_top5_acc: 0.9711 - loss3/classifier_macro_f1score: 0.2912
# Epoch 00066: val_loss did not improve from 4.23277
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 191/191 [==============================] - 380s 2s/step - loss: 1.4711 - loss1/classifier_loss: 1.7905 - loss2/classifier_loss: 1.4134 - loss3/classifier_loss: 0.5099 - loss1/classifier_accuracy: 0.5553 - loss1/classifier_top5_acc: 0.7922 - loss1/classifier_macro_f1score: 0.1372 - loss2/classifier_accuracy: 0.6337 - loss2/classifier_top5_acc: 0.8503 - loss2/classifier_macro_f1score: 0.1815 - loss3/classifier_accuracy: 0.8524 - loss3/classifier_top5_acc: 0.9711 - loss3/classifier_macro_f1score: 0.2912 - val_loss: 4.6307 - val_loss1/classifier_loss: 2.4105 - val_loss2/classifier_loss: 2.5099 - val_loss3/classifier_loss: 3.1546 - val_loss1/classifier_accuracy: 0.4810 - val_loss1/classifier_top5_acc: 0.6919 - val_loss1/classifier_macro_f1score: 0.1221 - val_loss2/classifier_accuracy: 0.4779 - val_loss2/classifier_top5_acc: 0.6929 - val_loss2/classifier_macro_f1score: 0.1347 - val_loss3/classifier_accuracy: 0.4749 - val_loss3/classifier_top5_acc: 0.6793 - val_loss3/classifier_macro_f1score: 0.1489
# Learning rate:  2.9999999999999997e-06
#
# Epoch 00067: LearningRateScheduler reducing learning rate to 2.9999999999999997e-06.
# Epoch 67/70
# 191/191 [==============================] - ETA: 0s - loss: 1.4992 - loss1/classifier_loss: 1.8148 - loss2/classifier_loss: 1.4376 - loss3/classifier_loss: 0.5235 - loss1/classifier_accuracy: 0.5499 - loss1/classifier_top5_acc: 0.7860 - loss1/classifier_macro_f1score: 0.1389 - loss2/classifier_accuracy: 0.6289 - loss2/classifier_top5_acc: 0.8476 - loss2/classifier_macro_f1score: 0.1817 - loss3/classifier_accuracy: 0.8447 - loss3/classifier_top5_acc: 0.9707 - loss3/classifier_macro_f1score: 0.2892
# Epoch 00067: val_loss did not improve from 4.23277
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 191/191 [==============================] - 383s 2s/step - loss: 1.4992 - loss1/classifier_loss: 1.8148 - loss2/classifier_loss: 1.4376 - loss3/classifier_loss: 0.5235 - loss1/classifier_accuracy: 0.5499 - loss1/classifier_top5_acc: 0.7860 - loss1/classifier_macro_f1score: 0.1389 - loss2/classifier_accuracy: 0.6289 - loss2/classifier_top5_acc: 0.8476 - loss2/classifier_macro_f1score: 0.1817 - loss3/classifier_accuracy: 0.8447 - loss3/classifier_top5_acc: 0.9707 - loss3/classifier_macro_f1score: 0.2892 - val_loss: 4.6585 - val_loss1/classifier_loss: 2.4238 - val_loss2/classifier_loss: 2.5247 - val_loss3/classifier_loss: 3.1739 - val_loss1/classifier_accuracy: 0.4793 - val_loss1/classifier_top5_acc: 0.6895 - val_loss1/classifier_macro_f1score: 0.1203 - val_loss2/classifier_accuracy: 0.4786 - val_loss2/classifier_top5_acc: 0.6933 - val_loss2/classifier_macro_f1score: 0.1328 - val_loss3/classifier_accuracy: 0.4742 - val_loss3/classifier_top5_acc: 0.6790 - val_loss3/classifier_macro_f1score: 0.1478
# Learning rate:  2.9999999999999997e-06
#
# Epoch 00068: LearningRateScheduler reducing learning rate to 2.9999999999999997e-06.
# Epoch 68/70
# 191/191 [==============================] - ETA: 0s - loss: 1.4879 - loss1/classifier_loss: 1.8045 - loss2/classifier_loss: 1.4305 - loss3/classifier_loss: 0.5174 - loss1/classifier_accuracy: 0.5515 - loss1/classifier_top5_acc: 0.7890 - loss1/classifier_macro_f1score: 0.1363 - loss2/classifier_accuracy: 0.6275 - loss2/classifier_top5_acc: 0.8478 - loss2/classifier_macro_f1score: 0.1796 - loss3/classifier_accuracy: 0.8521 - loss3/classifier_top5_acc: 0.9712 - loss3/classifier_macro_f1score: 0.2913
# Epoch 00068: val_loss did not improve from 4.23277
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 191/191 [==============================] - 395s 2s/step - loss: 1.4879 - loss1/classifier_loss: 1.8045 - loss2/classifier_loss: 1.4305 - loss3/classifier_loss: 0.5174 - loss1/classifier_accuracy: 0.5515 - loss1/classifier_top5_acc: 0.7890 - loss1/classifier_macro_f1score: 0.1363 - loss2/classifier_accuracy: 0.6275 - loss2/classifier_top5_acc: 0.8478 - loss2/classifier_macro_f1score: 0.1796 - loss3/classifier_accuracy: 0.8521 - loss3/classifier_top5_acc: 0.9712 - loss3/classifier_macro_f1score: 0.2913 - val_loss: 4.6513 - val_loss1/classifier_loss: 2.4200 - val_loss2/classifier_loss: 2.5261 - val_loss3/classifier_loss: 3.1675 - val_loss1/classifier_accuracy: 0.4806 - val_loss1/classifier_top5_acc: 0.6882 - val_loss1/classifier_macro_f1score: 0.1229 - val_loss2/classifier_accuracy: 0.4783 - val_loss2/classifier_top5_acc: 0.6929 - val_loss2/classifier_macro_f1score: 0.1353 - val_loss3/classifier_accuracy: 0.4698 - val_loss3/classifier_top5_acc: 0.6793 - val_loss3/classifier_macro_f1score: 0.1485
# Learning rate:  2.9999999999999997e-06
#
# Epoch 00069: LearningRateScheduler reducing learning rate to 2.9999999999999997e-06.
# Epoch 69/70
# 191/191 [==============================] - ETA: 0s - loss: 1.4733 - loss1/classifier_loss: 1.7984 - loss2/classifier_loss: 1.4186 - loss3/classifier_loss: 0.5082 - loss1/classifier_accuracy: 0.5559 - loss1/classifier_top5_acc: 0.7931 - loss1/classifier_macro_f1score: 0.1384 - loss2/classifier_accuracy: 0.6311 - loss2/classifier_top5_acc: 0.8512 - loss2/classifier_macro_f1score: 0.1822 - loss3/classifier_accuracy: 0.8511 - loss3/classifier_top5_acc: 0.9712 - loss3/classifier_macro_f1score: 0.2916
# Epoch 00069: val_loss did not improve from 4.23277
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 191/191 [==============================] - 400s 2s/step - loss: 1.4733 - loss1/classifier_loss: 1.7984 - loss2/classifier_loss: 1.4186 - loss3/classifier_loss: 0.5082 - loss1/classifier_accuracy: 0.5559 - loss1/classifier_top5_acc: 0.7931 - loss1/classifier_macro_f1score: 0.1384 - loss2/classifier_accuracy: 0.6311 - loss2/classifier_top5_acc: 0.8512 - loss2/classifier_macro_f1score: 0.1822 - loss3/classifier_accuracy: 0.8511 - loss3/classifier_top5_acc: 0.9712 - loss3/classifier_macro_f1score: 0.2916 - val_loss: 4.6063 - val_loss1/classifier_loss: 2.4074 - val_loss2/classifier_loss: 2.5052 - val_loss3/classifier_loss: 3.1325 - val_loss1/classifier_accuracy: 0.4817 - val_loss1/classifier_top5_acc: 0.6909 - val_loss1/classifier_macro_f1score: 0.1210 - val_loss2/classifier_accuracy: 0.4817 - val_loss2/classifier_top5_acc: 0.6929 - val_loss2/classifier_macro_f1score: 0.1333 - val_loss3/classifier_accuracy: 0.4742 - val_loss3/classifier_top5_acc: 0.6804 - val_loss3/classifier_macro_f1score: 0.1479
# Learning rate:  2.9999999999999997e-06
#
# Epoch 00070: LearningRateScheduler reducing learning rate to 2.9999999999999997e-06.
# Epoch 70/70
# 191/191 [==============================] - ETA: 0s - loss: 1.4910 - loss1/classifier_loss: 1.8072 - loss2/classifier_loss: 1.4352 - loss3/classifier_loss: 0.5183 - loss1/classifier_accuracy: 0.5536 - loss1/classifier_top5_acc: 0.7924 - loss1/classifier_macro_f1score: 0.1364 - loss2/classifier_accuracy: 0.6289 - loss2/classifier_top5_acc: 0.8488 - loss2/classifier_macro_f1score: 0.1816 - loss3/classifier_accuracy: 0.8474 - loss3/classifier_top5_acc: 0.9713 - loss3/classifier_macro_f1score: 0.2885
# Epoch 00070: val_loss did not improve from 4.23277
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 191/191 [==============================] - 398s 2s/step - loss: 1.4910 - loss1/classifier_loss: 1.8072 - loss2/classifier_loss: 1.4352 - loss3/classifier_loss: 0.5183 - loss1/classifier_accuracy: 0.5536 - loss1/classifier_top5_acc: 0.7924 - loss1/classifier_macro_f1score: 0.1364 - loss2/classifier_accuracy: 0.6289 - loss2/classifier_top5_acc: 0.8488 - loss2/classifier_macro_f1score: 0.1816 - loss3/classifier_accuracy: 0.8474 - loss3/classifier_top5_acc: 0.9713 - loss3/classifier_macro_f1score: 0.2885 - val_loss: 4.6430 - val_loss1/classifier_loss: 2.4174 - val_loss2/classifier_loss: 2.5185 - val_loss3/classifier_loss: 3.1623 - val_loss1/classifier_accuracy: 0.4800 - val_loss1/classifier_top5_acc: 0.6885 - val_loss1/classifier_macro_f1score: 0.1218 - val_loss2/classifier_accuracy: 0.4830 - val_loss2/classifier_top5_acc: 0.6923 - val_loss2/classifier_macro_f1score: 0.1346 - val_loss3/classifier_accuracy: 0.4752 - val_loss3/classifier_top5_acc: 0.6800 - val_loss3/classifier_macro_f1score: 0.1498

# %% [markdown]
# ### 3) GoogLeNet Evaluate

# %%
# 1. epoch=maximum
#var = model.evaluate_generator(generate_test_for_three(),steps=int(len(x_test)/batch_sizes))
var = model.evaluate(generate_test_for_three(),steps=int(len(x_test)/batch_sizes))
print('[Test Loss: %.4f /  Test Top-1 Accuracy: %.4f / Test Top-5 Accuracy: %.4f / Test Macro f1: %.4f]\n' % (var[0],var[-3],var[-2],var[-1]))
# Out:
# Found 3118 images belonging to 257 classes.
# 24/24 [==============================] - 1605s 67s/step - loss: 4.7204 - loss1/classifier_loss: 2.4826 - loss2/classifier_loss: 2.5986 - loss3/classifier_loss: 3.1960 - loss1/classifier_accuracy: 0.4593 - loss1/classifier_top5_acc: 0.6764 - loss1/classifier_macro_f1score: 0.1187 - loss2/classifier_accuracy: 0.4691 - loss2/classifier_top5_acc: 0.6836 - loss2/classifier_macro_f1score: 0.1340 - loss3/classifier_accuracy: 0.4694 - loss3/classifier_top5_acc: 0.6810 - loss3/classifier_macro_f1score: 0.1512
# [Test Loss: 4.7204 /  Test Top-1 Accuracy: 0.4694 / Test Top-5 Accuracy: 0.6810 / Test Macro f1: 0.1512]

# %%
loss=history.history['loss']
val_loss=history.history['val_loss']
acc=history.history['loss3/classifier_accuracy']
val_acc=history.history['val_loss3/classifier_accuracy']
top5_acc=history.history['loss3/classifier_top5_acc']
val_top5_acc=history.history['val_loss3/classifier_top5_acc']
f1=history.history['loss3/classifier_macro_f1score']
val_f1=history.history['val_loss3/classifier_macro_f1score']
epochs=range(1,len(acc)+1)

data = np.array([epochs,loss,val_loss,acc,val_acc,top5_acc,val_top5_acc,f1,val_f1]).T

# %%
# data save
# epochs, loss, val_loss, acc, val_acc, top5_acc, val_top5_acc, f1, val_f1

np.savetxt(os.path.join(dir,'train_valid_output',number,model.name+'.txt'),data)

# %%
# data import
data = np.loadtxt(os.path.join(dir,'train_valid_output',number,'GoogleNet.txt'))

# %%
epochs=data[:,0]
loss=data[:,1]
val_loss=data[:,2]
acc=data[:,3]
val_acc=data[:,4]
top5_acc=data[:,5]
val_top5_acc=data[:,6]

# %%
plt.plot(epochs[1:],acc[1:],'b',label='Training 1-Acc')
plt.plot(epochs[1:],val_acc[1:],'r',label='Validation 1-Acc')
plt.title('Training and Validation Top-1 Accuracy')
plt.legend()
plt.figure()

plt.plot(epochs[1:],top5_acc[1:],'b',label='Training 5-Acc')
plt.plot(epochs[1:],val_top5_acc[1:],'r',label='Validation 5-Acc')
plt.title('Training and Validation Top-5 Accuracy')
plt.legend()
plt.figure()

plt.plot(epochs[10:],loss[10:],'b',label='Training Loss')
plt.plot(epochs[10:],val_loss[10:],'r',label='Validation Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()

# %%
# 이 아래는 내가 인위적으로 살펴보고 싶은 epoch에 대해서 결과값 출력

# %%
model=load_model(os.path.join(dir,'model_output',number,'Inception_v1','027.h5'),custom_objects={"macro_f1score": macro_f1score,"top5_acc":top5_acc,"LRN":LRN,"PoolHelper":PoolHelper})
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-36-5b72571ce3e9> in <module>()
# ----> 1 model=load_model(os.path.join(dir,'model_output',number,'Inception_v1','027.h5'),custom_objects={"macro_f1score": macro_f1score,"top5_acc":top5_acc,"LRN":LRN,"PoolHelper":PoolHelper})
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/saving/save.py in load_model(filepath, custom_objects, compile, options)
#     184     filepath = path_to_string(filepath)
#     185     if isinstance(filepath, six.string_types):
# --> 186       loader_impl.parse_saved_model(filepath)
#     187       return saved_model_load.load(filepath, compile, options)
#     188
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/saved_model/loader_impl.py in parse_saved_model(export_dir)
#     111                   (export_dir,
#     112                    constants.SAVED_MODEL_FILENAME_PBTXT,
# --> 113                    constants.SAVED_MODEL_FILENAME_PB))
#     114
#     115
#
# OSError: SavedModel file does not exist at: /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_v1/027.h5/{saved_model.pbtxt|saved_model.pb}

# %%
# 2. epoch=?
var = model.evaluate(generate_test_for_three(),steps=int(len(x_test)/batch_sizes))
print('[Test Loss: %.4f /  Test Top-1 Accuracy: %.4f / Test Top-5 Accuracy: %.4f / Test Macro f1: %.4f]\n' % (var[0],var[-3],var[-2],var[-1]))
