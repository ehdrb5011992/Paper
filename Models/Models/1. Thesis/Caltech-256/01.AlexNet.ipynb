# %% [markdown]
# # [AlexNet]

# %% [markdown]
# *KU LeeDongGyu*

# %% [markdown]
# ### Contents

# %% [markdown]
# 1. Data Preprocessing
# ```
# 1) Data Import
# 2) Data Augmentation
# ```
# 2. Support Functions & Almost Original AlexNet
# ```
# 1) Support Functions
# 2) Almost Original AlexNet
# 3) AlexNet Evaluate
# ```

# %% [markdown]
# ### Install Packages

# %% [markdown]
# ### Module

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/My Drive/Colab Notebooks/Paper
# Out:
# /content/drive/My Drive/Colab Notebooks/Paper

# %%
from lrn import LRN #만든 모듈, class
from f1score import macro_f1score, weighted_f1score

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import cv2
import tensorflow as tf
from tensorflow import keras as ks
from tensorflow.keras import backend as K 
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, Input, Concatenate, ZeroPadding2D ,GlobalMaxPooling2D, Reshape , Lambda , Add, Multiply
from tensorflow.keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D, Activation, BatchNormalization, AveragePooling2D , ZeroPadding2D, SeparableConv2D
from tensorflow.keras.layers import add
from tensorflow.keras.optimizers import Adam, RMSprop , SGD
from tensorflow.keras.callbacks import EarlyStopping , LearningRateScheduler, ModelCheckpoint, CSVLogger, Callback, ReduceLROnPlateau
from tensorflow.keras.regularizers import l1,l2,l1_l2
from tensorflow.keras.models import Model , load_model , Sequential
from tensorflow.keras.utils import plot_model , to_categorical, get_file
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
os.getcwd()
# Out:
# '/content/drive/My Drive/Colab Notebooks/Paper'

# %%
print(tf.__version__)
print(ks.__version__)
# Out:
# 2.3.0
# 2.4.0

# %%
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 3546897024853295705
# , name: "/device:XLA_CPU:0"
# device_type: "XLA_CPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 7356422910953149094
# physical_device_desc: "device: XLA_CPU device"
# , name: "/device:XLA_GPU:0"
# device_type: "XLA_GPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 13220740055493561578
# physical_device_desc: "device: XLA_GPU device"
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 15473775744
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 13295019645360976205
# physical_device_desc: "device: 0, name: Tesla V100-SXM2-16GB, pci bus id: 0000:00:04.0, compute capability: 7.0"
# ]

# %% [markdown]
# ## 1. Data Preprocessing
# ---

# %% [markdown]
# ### 1) Data Import

# %%
# 바꿔서 살펴 볼 것들
# CALTECH, CIFAR100, FER, MIT
data_name = 'CALTECH'
gan_type = 'No_GAN'
number = '1'
size = 227 # sizes after cropping
super_size = 256 # sizes before cropping 
input_sizes = (size,size,3)
batch_sizes = 128
weight_decay = 1e-4
epochs = 70

# %%
# 참고 : https://stackoverflow.com/questions/32419510/how-to-get-reproducible-results-in-keras/52897216#52897216
# setting the seed number for random number generation for reproducibility.

from numpy.random import seed
import random


if number=='1':
    seed_num = 200225
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)
elif number=='2':
    seed_num = 727
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)
elif number=='3':
    seed_num = 115
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)
elif number=='4':
    seed_num = 501
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)
elif number=='5':
    seed_num = 517
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)

# %%
# data import

if data_name=='FER' :
    x_train =  np.zeros(28698)
    x_valid = np.zeros(3589)
    x_test = np.zeros(3588)
    classes = 7 
    tr_center = [0.50793296, 0.50793296, 0.50793296]
elif data_name=='MIT':
    x_train = np.zeros(12466)
    x_valid = np.zeros(1564)
    x_test = np.zeros(1590)
    classes = 67 
    tr_center = [0.47916578, 0.42029615, 0.36046057]
elif data_name=='CALTECH':
    x_train = np.zeros(24510)
    x_valid = np.zeros(2980)
    x_test = np.zeros(3118)
    classes = 257
    tr_center = [0.51397761, 0.49525248, 0.46555727]
elif data_name=='CIFAR100':
    x_train = np.zeros(44923)
    x_valid = np.zeros(5077)
    x_test = np.zeros(10000)
    classes = 100
    tr_center = [0.53442983, 0.51355958, 0.46462564]

# %%
dir = os.path.join(os.getcwd(),data_name,gan_type)

# %% [markdown]
# ### 2) Data Augmentation

# %%
# 참고 : https://jkjung-avt.github.io/keras-image-cropping/

def random_crop(img, random_crop_size):
    # Note: image_data_format is 'channel_last'
    assert img.shape[2] == 3 # img.shape[2] 가 3(rgb)이 아니면 assertion error 발생
    height, width = img.shape[0], img.shape[1]
    dy, dx = random_crop_size
    x = np.random.randint(0, width - dx + 1)
    y = np.random.randint(0, height - dy + 1)
    return img[y:(y+dy), x:(x+dx), :]


def crop_generator(batches, crop_length):
    """Take as input a Keras ImageGen (Iterator) and generate random
    crops from the image batches generated by the original iterator.
    """
    while True:
        batch_x, batch_y = next(batches)
        batch_crops = np.zeros((batch_x.shape[0], crop_length, crop_length, 3))
        for i in range(batch_x.shape[0]):
            batch_crops[i] = random_crop(batch_x[i], (crop_length, crop_length))
        yield (batch_crops, batch_y)

# %%
from tensorflow.keras.preprocessing.image import img_to_array,load_img
import glob

# 데이터 전체에 대해 centering 진행함.

def read_cal_image(img_path): 
    x = img_to_array(load_img(img_path)) # x는 채널별 평균값
    y = x.shape[0] * x.shape[1]# y는 데이터별 픽셀 수 (비중)

    x = 1/255. * x # scaling하고, centering값을 뽑아냄.
    x = np.mean(x, axis=(0,1))
    
    return np.hstack([x,y])

def calculate_centered_mean(dataset_path,x_train=x_train):
    num = len(x_train)
    space = np.empty((num,4))
    i=0

    for p in glob.glob(os.path.join(dataset_path,'*/*.*')) :
        space[i] = read_cal_image(p)
        i += 1

    ratio = space[:,3] / np.sum(space[:,3])

    return np.average(space[:,0:3],axis=0,weights=ratio)


#아래의 함수를 돌려서 나온 결과값을 중심화 값으로 설정.

#train_mean = calculate_centered_mean(os.path.join(dir,'data/train')).reshape((1,1,3))

# %%
datagen_tr = ImageDataGenerator(
    rescale=1/255.,
    horizontal_flip=True,
    featurewise_center=True,
    featurewise_std_normalization=False,
    rotation_range=10,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=[0.9,1.0],
    fill_mode = 'nearest')
datagen_val = ImageDataGenerator(rescale=1/255.,featurewise_center=True)
datagen_tes = ImageDataGenerator(rescale=1/255.,featurewise_center=True)

# 원래는 이 자리에 fit 매서드를 써야하지만, 그냥 내가 중심화함수를 만들고 적용함. 

# 중심화 설정
datagen_tr.mean = np.array(tr_center, dtype=np.float32).reshape((1,1,3)) # RGB
datagen_val.mean = np.array(tr_center, dtype=np.float32).reshape((1,1,3)) # RGB
datagen_tes.mean = np.array(tr_center, dtype=np.float32).reshape((1,1,3)) # RGB

# %%
train_batches = datagen_tr.flow_from_directory(directory=os.path.join(dir,'data/train'),target_size=(super_size,super_size),batch_size=batch_sizes,class_mode='categorical') # fer : 28698 / mit : 12466 / caltech : 24509 / cifar : 44923
train_generator= crop_generator(train_batches, size)
valid_generator = datagen_val.flow_from_directory(directory=os.path.join(dir,'data/valid'),target_size=(size,size),batch_size=batch_sizes,class_mode='categorical') # fer : 3589 / mit : 1564 / caltech : 2980 / cifar : 5077
test_generator = datagen_tes.flow_from_directory(directory=os.path.join(dir,'data/test'),target_size=(size,size),batch_size=batch_sizes,class_mode='categorical') # fer : 3588 / mit : 1590 / caltech : 3118 / cifar : 10000
# Out:
# Found 24509 images belonging to 257 classes.
# Found 2980 images belonging to 257 classes.
# Found 3118 images belonging to 257 classes.

# %% [markdown]
# ## 2. Support Functions & Almost Original AlexNet
# ---

# %% [markdown]
# ### 1) Support Functions

# %%
# def lr_schedule(epoch):
#     init_lr = 1e-4
#     k = 0.04
#     lr = init_lr * np.exp(-k*epoch)
#     print('Learning rate: ', lr)
#     return lr

def lr_schedule(epoch):
    lr = 3e-4
    if epoch < 30:
        lr = lr
    elif epoch < 60 :
        lr = lr * 0.1
    else:
        lr = lr * 0.01
    print('Learning rate: ', lr)
    return lr

# %% [markdown]
# ### 2) Almost Orginial AlexNet

# %%
# Alexnet을 최대한 논문에 가깝게 맞춰 모형작성.
# 참고 : https://github.com/eweill/keras-deepcv/blob/master/models/classification/alexnet.py

def Alexnet(img_shape=(227, 227, 3), n_classes=1000, weight_decay=weight_decay, weights=None, name='AlexNet'):

    # Initialize model
    alexnet = Sequential(name=name)

    # Layer 1
    alexnet.add(Conv2D(96, (11, 11), input_shape=img_shape, strides=4, kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay)))
    alexnet.add(Activation('relu'))
    alexnet.add(LRN(name='layer1_LRN'))
    alexnet.add(MaxPooling2D(pool_size=(3, 3),strides=2))

    # Layer 2
    alexnet.add(Conv2D(256, (5, 5), padding='same',strides=1, kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay)))
    alexnet.add(Activation('relu'))
    alexnet.add(LRN(name='layer2_LRN'))
    alexnet.add(MaxPooling2D(pool_size=(3, 3),strides=2))
    
    # Layer 3
    alexnet.add(Conv2D(384, (3, 3), padding='same', strides=1, kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay)))
    alexnet.add(Activation('relu'))
    alexnet.add(LRN(name='layer3_LRN'))
    
    # Layer 4
    alexnet.add(Conv2D(384, (3, 3), padding='same', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay)))
    alexnet.add(Activation('relu'))
    alexnet.add(LRN(name='layer4_LRN'))

    # Layer 5
    alexnet.add(Conv2D(256, (3, 3), padding='same', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay)))
    alexnet.add(Activation('relu'))
    alexnet.add(LRN(name='layer5_LRN'))
    alexnet.add(MaxPooling2D(pool_size=(3, 3),strides=2))

    # Layer 6
    alexnet.add(Flatten())
    alexnet.add(Dense(4096, kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay)))
    alexnet.add(Activation('relu'))
    alexnet.add(Dropout(0.5))

    # Layer 7
    alexnet.add(Dense(4096, kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay)))
    alexnet.add(Activation('relu'))
    alexnet.add(Dropout(0.5))

    # Layer 8
    alexnet.add(Dense(n_classes, kernel_regularizer=l2(weight_decay)))
    alexnet.add(Activation('softmax'))

    if weights is not None:
        alexnet.load_weights(weights)

    return alexnet

# %%
model = Alexnet(img_shape=input_sizes, n_classes=classes, name='AlexNet')

# %%
model.summary()
# Out:
# Model: "AlexNet"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 55, 55, 96)        34944
# _________________________________________________________________
# activation (Activation)      (None, 55, 55, 96)        0
# _________________________________________________________________
# layer1_LRN (LRN)             (None, 55, 55, 96)        0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 27, 27, 96)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 27, 27, 256)       614656
# _________________________________________________________________
# activation_1 (Activation)    (None, 27, 27, 256)       0
# _________________________________________________________________
# layer2_LRN (LRN)             (None, 27, 27, 256)       0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 13, 13, 256)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 13, 13, 384)       885120
# _________________________________________________________________
# activation_2 (Activation)    (None, 13, 13, 384)       0
# _________________________________________________________________
# layer3_LRN (LRN)             (None, 13, 13, 384)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 13, 13, 384)       1327488
# _________________________________________________________________
# activation_3 (Activation)    (None, 13, 13, 384)       0
# _________________________________________________________________
# layer4_LRN (LRN)             (None, 13, 13, 384)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 13, 13, 256)       884992
# _________________________________________________________________
# activation_4 (Activation)    (None, 13, 13, 256)       0
# _________________________________________________________________
# layer5_LRN (LRN)             (None, 13, 13, 256)       0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 6, 6, 256)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 9216)              0
# _________________________________________________________________
# dense (Dense)                (None, 4096)              37752832
# _________________________________________________________________
# activation_5 (Activation)    (None, 4096)              0
# _________________________________________________________________
# dropout (Dropout)            (None, 4096)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 4096)              16781312
# _________________________________________________________________
# activation_6 (Activation)    (None, 4096)              0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 4096)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 257)               1052929
# _________________________________________________________________
# activation_7 (Activation)    (None, 257)               0
# =================================================================
# Total params: 59,334,273
# Trainable params: 59,334,273
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 폴더 생성

os.makedirs(os.path.join(dir,'model_output',number,model.name), exist_ok=True)
os.makedirs(os.path.join(dir,'train_valid_output',number), exist_ok=True)

# %%
# 참고 : https://github.com/OverLordGoldDragon/keras-adamw

import sys
sys.path.append('/content/drive/My Drive/Colab Notebooks/Paper')
import utils
import optimizers_v2
from utils import get_weight_decays, fill_dict_in_order
from utils import reset_seeds, K_eval
from optimizers_v2 import AdamW, NadamW, SGDW

# %%
# top-5 accuracy 출력
import functools
top5_acc = functools.partial(ks.metrics.top_k_categorical_accuracy, k=5)
top5_acc.__name__ = 'top5_acc'

# %%
#optimizer = SGDW(model=model, use_cosine_annealing=False, total_iterations = len(x_train) // batch_sizes, nesterov=True, momentum=0.9)
optimizer = AdamW(model=model, use_cosine_annealing=False, total_iterations = len(x_train) // batch_sizes)
#optimizer = Adam()
filepath =  os.path.join(dir,'model_output',number,model.name,'{epoch:03d}.h5')

callbacks_list = [ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_weights_only=False, save_best_only=True, mode='min'),
                  ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_weights_only=False, save_best_only=True, mode='max'),
                  #ReduceLROnPlateau(monitor='val_loss',patience=3,factor=0.1,min_lr=1e-5),
                  LearningRateScheduler(lr_schedule,verbose=1)
                  ]
                  
model.compile(optimizer, loss = 'categorical_crossentropy', metrics=['accuracy',top5_acc,macro_f1score])

# %%
######## flow_from_directory
history = model.fit(train_generator, steps_per_epoch=int(len(x_train)/batch_sizes),  validation_data = valid_generator, epochs=epochs , verbose=1 , callbacks = callbacks_list , validation_steps=int(len(x_valid)/batch_sizes))
# Out:
# Learning rate:  0.0003
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 1/70
# 0.0(L1), 7.235745870133896e-06(L2) weight decay set for conv2d/kernel:0
# 0.0(L1), 7.235745870133896e-06(L2) weight decay set for conv2d_1/kernel:0
# 0.0(L1), 7.235745870133896e-06(L2) weight decay set for conv2d_2/kernel:0
# 0.0(L1), 7.235745870133896e-06(L2) weight decay set for conv2d_3/kernel:0
# 0.0(L1), 7.235745870133896e-06(L2) weight decay set for conv2d_4/kernel:0
# 0.0(L1), 7.235745870133896e-06(L2) weight decay set for dense/kernel:0
# 0.0(L1), 7.235745870133896e-06(L2) weight decay set for dense_1/kernel:0
# 0.0(L1), 7.235745870133896e-06(L2) weight decay set for dense_2/kernel:0
# 191/191 [==============================] - ETA: 0s - loss: 5.2624 - accuracy: 0.0567 - top5_acc: 0.1297 - macro_f1score: 0.0020
# Epoch 00001: val_loss improved from inf to 4.86773, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/AlexNet/001.h5
#
# Epoch 00001: val_accuracy improved from -inf to 0.08458, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/AlexNet/001.h5
# 191/191 [==============================] - 16513s 86s/step - loss: 5.2624 - accuracy: 0.0567 - top5_acc: 0.1297 - macro_f1score: 0.0020 - val_loss: 4.8677 - val_accuracy: 0.0846 - val_top5_acc: 0.1899 - val_macro_f1score: 0.0063
# Learning rate:  0.0003
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 2/70
# 191/191 [==============================] - ETA: 0s - loss: 4.7067 - accuracy: 0.1116 - top5_acc: 0.2197 - macro_f1score: 0.0079
# Epoch 00002: val_loss improved from 4.86773 to 4.39274, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/AlexNet/002.h5
#
# Epoch 00002: val_accuracy improved from 0.08458 to 0.14606, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/AlexNet/002.h5
# 191/191 [==============================] - 414s 2s/step - loss: 4.7067 - accuracy: 0.1116 - top5_acc: 0.2197 - macro_f1score: 0.0079 - val_loss: 4.3927 - val_accuracy: 0.1461 - val_top5_acc: 0.2901 - val_macro_f1score: 0.0115
# Learning rate:  0.0003
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 3/70
# 191/191 [==============================] - ETA: 0s - loss: 4.3511 - accuracy: 0.1492 - top5_acc: 0.2899 - macro_f1score: 0.0124
# Epoch 00003: val_loss improved from 4.39274 to 4.10144, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/AlexNet/003.h5
#
# Epoch 00003: val_accuracy improved from 0.14606 to 0.18716, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/AlexNet/003.h5
# 191/191 [==============================] - 408s 2s/step - loss: 4.3511 - accuracy: 0.1492 - top5_acc: 0.2899 - macro_f1score: 0.0124 - val_loss: 4.1014 - val_accuracy: 0.1872 - val_top5_acc: 0.3556 - val_macro_f1score: 0.0181
# Learning rate:  0.0003
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 4/70
# 191/191 [==============================] - ETA: 0s - loss: 4.0290 - accuracy: 0.1908 - top5_acc: 0.3583 - macro_f1score: 0.0194
# Epoch 00004: val_loss improved from 4.10144 to 3.85049, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/AlexNet/004.h5
#
# Epoch 00004: val_accuracy improved from 0.18716 to 0.22792, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/AlexNet/004.h5
# 191/191 [==============================] - 406s 2s/step - loss: 4.0290 - accuracy: 0.1908 - top5_acc: 0.3583 - macro_f1score: 0.0194 - val_loss: 3.8505 - val_accuracy: 0.2279 - val_top5_acc: 0.4090 - val_macro_f1score: 0.0228
# Learning rate:  0.0003
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 5/70
# 191/191 [==============================] - ETA: 0s - loss: 3.7457 - accuracy: 0.2273 - top5_acc: 0.4189 - macro_f1score: 0.0270
# Epoch 00005: val_loss improved from 3.85049 to 3.62461, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/AlexNet/005.h5
#
# Epoch 00005: val_accuracy improved from 0.22792 to 0.26291, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/AlexNet/005.h5
# 191/191 [==============================] - 403s 2s/step - loss: 3.7457 - accuracy: 0.2273 - top5_acc: 0.4189 - macro_f1score: 0.0270 - val_loss: 3.6246 - val_accuracy: 0.2629 - val_top5_acc: 0.4484 - val_macro_f1score: 0.0358
# Learning rate:  0.0003
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 6/70
# 191/191 [==============================] - ETA: 0s - loss: 3.4951 - accuracy: 0.2651 - top5_acc: 0.4697 - macro_f1score: 0.0356
# Epoch 00006: val_loss improved from 3.62461 to 3.38785, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/AlexNet/006.h5
#
# Epoch 00006: val_accuracy improved from 0.26291 to 0.29721, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/AlexNet/006.h5
# 191/191 [==============================] - 404s 2s/step - loss: 3.4951 - accuracy: 0.2651 - top5_acc: 0.4697 - macro_f1score: 0.0356 - val_loss: 3.3879 - val_accuracy: 0.2972 - val_top5_acc: 0.5003 - val_macro_f1score: 0.0429
# Learning rate:  0.0003
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 7/70
# 191/191 [==============================] - ETA: 0s - loss: 3.2932 - accuracy: 0.2954 - top5_acc: 0.5081 - macro_f1score: 0.0462
# Epoch 00007: val_loss improved from 3.38785 to 3.25749, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/AlexNet/007.h5
#
# Epoch 00007: val_accuracy improved from 0.29721 to 0.31726, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/AlexNet/007.h5
# 191/191 [==============================] - 404s 2s/step - loss: 3.2932 - accuracy: 0.2954 - top5_acc: 0.5081 - macro_f1score: 0.0462 - val_loss: 3.2575 - val_accuracy: 0.3173 - val_top5_acc: 0.5309 - val_macro_f1score: 0.0521
# Learning rate:  0.0003
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 8/70
# 191/191 [==============================] - ETA: 0s - loss: 3.0782 - accuracy: 0.3300 - top5_acc: 0.5517 - macro_f1score: 0.0563
# Epoch 00008: val_loss improved from 3.25749 to 3.05611, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/AlexNet/008.h5
#
# Epoch 00008: val_accuracy improved from 0.31726 to 0.35054, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/AlexNet/008.h5
# 191/191 [==============================] - 400s 2s/step - loss: 3.0782 - accuracy: 0.3300 - top5_acc: 0.5517 - macro_f1score: 0.0563 - val_loss: 3.0561 - val_accuracy: 0.3505 - val_top5_acc: 0.5594 - val_macro_f1score: 0.0648
# Learning rate:  0.0003
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 9/70
# 191/191 [==============================] - ETA: 0s - loss: 2.9392 - accuracy: 0.3536 - top5_acc: 0.5837 - macro_f1score: 0.0638
# Epoch 00009: val_loss did not improve from 3.05611
#
# Epoch 00009: val_accuracy improved from 0.35054 to 0.35496, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/AlexNet/009.h5
# 191/191 [==============================] - 395s 2s/step - loss: 2.9392 - accuracy: 0.3536 - top5_acc: 0.5837 - macro_f1score: 0.0638 - val_loss: 3.0897 - val_accuracy: 0.3550 - val_top5_acc: 0.5622 - val_macro_f1score: 0.0688
# Learning rate:  0.0003
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 10/70
# 191/191 [==============================] - ETA: 0s - loss: 2.7760 - accuracy: 0.3782 - top5_acc: 0.6122 - macro_f1score: 0.0741
# Epoch 00010: val_loss improved from 3.05611 to 2.95487, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/AlexNet/010.h5
#
# Epoch 00010: val_accuracy improved from 0.35496 to 0.37874, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/AlexNet/010.h5
# 191/191 [==============================] - 398s 2s/step - loss: 2.7760 - accuracy: 0.3782 - top5_acc: 0.6122 - macro_f1score: 0.0741 - val_loss: 2.9549 - val_accuracy: 0.3787 - val_top5_acc: 0.5846 - val_macro_f1score: 0.0720
# Learning rate:  0.0003
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 11/70
# 191/191 [==============================] - ETA: 0s - loss: 2.6235 - accuracy: 0.4061 - top5_acc: 0.6407 - macro_f1score: 0.0839
# Epoch 00011: val_loss improved from 2.95487 to 2.89645, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/AlexNet/011.h5
#
# Epoch 00011: val_accuracy improved from 0.37874 to 0.38111, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/AlexNet/011.h5
# 191/191 [==============================] - 396s 2s/step - loss: 2.6235 - accuracy: 0.4061 - top5_acc: 0.6407 - macro_f1score: 0.0839 - val_loss: 2.8964 - val_accuracy: 0.3811 - val_top5_acc: 0.6036 - val_macro_f1score: 0.0795
# Learning rate:  0.0003
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 12/70
# 191/191 [==============================] - ETA: 0s - loss: 2.5073 - accuracy: 0.4240 - top5_acc: 0.6635 - macro_f1score: 0.0929
# Epoch 00012: val_loss improved from 2.89645 to 2.83854, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/AlexNet/012.h5
#
# Epoch 00012: val_accuracy improved from 0.38111 to 0.39266, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/AlexNet/012.h5
# 191/191 [==============================] - 396s 2s/step - loss: 2.5073 - accuracy: 0.4240 - top5_acc: 0.6635 - macro_f1score: 0.0929 - val_loss: 2.8385 - val_accuracy: 0.3927 - val_top5_acc: 0.6084 - val_macro_f1score: 0.0895
# Learning rate:  0.0003
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 13/70
# 191/191 [==============================] - ETA: 0s - loss: 2.3752 - accuracy: 0.4489 - top5_acc: 0.6895 - macro_f1score: 0.1019
# Epoch 00013: val_loss improved from 2.83854 to 2.78858, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/AlexNet/013.h5
#
# Epoch 00013: val_accuracy improved from 0.39266 to 0.40115, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/AlexNet/013.h5
# 191/191 [==============================] - 395s 2s/step - loss: 2.3752 - accuracy: 0.4489 - top5_acc: 0.6895 - macro_f1score: 0.1019 - val_loss: 2.7886 - val_accuracy: 0.4012 - val_top5_acc: 0.6172 - val_macro_f1score: 0.0987
# Learning rate:  0.0003
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 14/70
# 191/191 [==============================] - ETA: 0s - loss: 2.2515 - accuracy: 0.4748 - top5_acc: 0.7108 - macro_f1score: 0.1125
# Epoch 00014: val_loss did not improve from 2.78858
#
# Epoch 00014: val_accuracy did not improve from 0.40115
# 191/191 [==============================] - 391s 2s/step - loss: 2.2515 - accuracy: 0.4748 - top5_acc: 0.7108 - macro_f1score: 0.1125 - val_loss: 2.8609 - val_accuracy: 0.3947 - val_top5_acc: 0.6172 - val_macro_f1score: 0.0970
# Learning rate:  0.0003
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 15/70
# 191/191 [==============================] - ETA: 0s - loss: 2.1261 - accuracy: 0.4906 - top5_acc: 0.7347 - macro_f1score: 0.1217
# Epoch 00015: val_loss improved from 2.78858 to 2.77953, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/AlexNet/015.h5
#
# Epoch 00015: val_accuracy improved from 0.40115 to 0.42154, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/AlexNet/015.h5
# 191/191 [==============================] - 393s 2s/step - loss: 2.1261 - accuracy: 0.4906 - top5_acc: 0.7347 - macro_f1score: 0.1217 - val_loss: 2.7795 - val_accuracy: 0.4215 - val_top5_acc: 0.6281 - val_macro_f1score: 0.1015
# Learning rate:  0.0003
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 16/70
# 191/191 [==============================] - ETA: 0s - loss: 2.0175 - accuracy: 0.5191 - top5_acc: 0.7509 - macro_f1score: 0.1322
# Epoch 00016: val_loss did not improve from 2.77953
#
# Epoch 00016: val_accuracy did not improve from 0.42154
# 191/191 [==============================] - 393s 2s/step - loss: 2.0175 - accuracy: 0.5191 - top5_acc: 0.7509 - macro_f1score: 0.1322 - val_loss: 2.8271 - val_accuracy: 0.4096 - val_top5_acc: 0.6179 - val_macro_f1score: 0.1019
# Learning rate:  0.0003
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 17/70
# 191/191 [==============================] - ETA: 0s - loss: 1.9367 - accuracy: 0.5317 - top5_acc: 0.7676 - macro_f1score: 0.1379
# Epoch 00017: val_loss did not improve from 2.77953
#
# Epoch 00017: val_accuracy did not improve from 0.42154
# 191/191 [==============================] - 391s 2s/step - loss: 1.9367 - accuracy: 0.5317 - top5_acc: 0.7676 - macro_f1score: 0.1379 - val_loss: 2.8025 - val_accuracy: 0.4168 - val_top5_acc: 0.6247 - val_macro_f1score: 0.1072
# Learning rate:  0.0003
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 18/70
# 191/191 [==============================] - ETA: 0s - loss: 1.8325 - accuracy: 0.5549 - top5_acc: 0.7886 - macro_f1score: 0.1468
# Epoch 00018: val_loss did not improve from 2.77953
#
# Epoch 00018: val_accuracy improved from 0.42154 to 0.42255, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/AlexNet/018.h5
# 191/191 [==============================] - 391s 2s/step - loss: 1.8325 - accuracy: 0.5549 - top5_acc: 0.7886 - macro_f1score: 0.1468 - val_loss: 2.8232 - val_accuracy: 0.4226 - val_top5_acc: 0.6260 - val_macro_f1score: 0.1090
# Learning rate:  0.0003
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 19/70
# 191/191 [==============================] - ETA: 0s - loss: 1.7362 - accuracy: 0.5729 - top5_acc: 0.8047 - macro_f1score: 0.1576
# Epoch 00019: val_loss did not improve from 2.77953
#
# Epoch 00019: val_accuracy did not improve from 0.42255
# 191/191 [==============================] - 393s 2s/step - loss: 1.7362 - accuracy: 0.5729 - top5_acc: 0.8047 - macro_f1score: 0.1576 - val_loss: 2.8169 - val_accuracy: 0.4202 - val_top5_acc: 0.6270 - val_macro_f1score: 0.1142
# Learning rate:  0.0003
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 20/70
# 191/191 [==============================] - ETA: 0s - loss: 1.6577 - accuracy: 0.5866 - top5_acc: 0.8172 - macro_f1score: 0.1636
# Epoch 00020: val_loss did not improve from 2.77953
#
# Epoch 00020: val_accuracy improved from 0.42255 to 0.42391, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/AlexNet/020.h5
# 191/191 [==============================] - 395s 2s/step - loss: 1.6577 - accuracy: 0.5866 - top5_acc: 0.8172 - macro_f1score: 0.1636 - val_loss: 2.8051 - val_accuracy: 0.4239 - val_top5_acc: 0.6270 - val_macro_f1score: 0.1091
# Learning rate:  0.0003
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 21/70
# 191/191 [==============================] - ETA: 0s - loss: 1.5686 - accuracy: 0.6042 - top5_acc: 0.8325 - macro_f1score: 0.1734
# Epoch 00021: val_loss did not improve from 2.77953
#
# Epoch 00021: val_accuracy improved from 0.42391 to 0.42629, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/AlexNet/021.h5
# 191/191 [==============================] - 398s 2s/step - loss: 1.5686 - accuracy: 0.6042 - top5_acc: 0.8325 - macro_f1score: 0.1734 - val_loss: 2.8233 - val_accuracy: 0.4263 - val_top5_acc: 0.6298 - val_macro_f1score: 0.1150
# Learning rate:  0.0003
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 22/70
# 191/191 [==============================] - ETA: 0s - loss: 1.4990 - accuracy: 0.6223 - top5_acc: 0.8441 - macro_f1score: 0.1807
# Epoch 00022: val_loss improved from 2.77953 to 2.77750, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/AlexNet/022.h5
#
# Epoch 00022: val_accuracy improved from 0.42629 to 0.44293, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/AlexNet/022.h5
# 191/191 [==============================] - 401s 2s/step - loss: 1.4990 - accuracy: 0.6223 - top5_acc: 0.8441 - macro_f1score: 0.1807 - val_loss: 2.7775 - val_accuracy: 0.4429 - val_top5_acc: 0.6427 - val_macro_f1score: 0.1212
# Learning rate:  0.0003
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 23/70
# 191/191 [==============================] - ETA: 0s - loss: 1.4174 - accuracy: 0.6379 - top5_acc: 0.8557 - macro_f1score: 0.1916
# Epoch 00023: val_loss did not improve from 2.77750
#
# Epoch 00023: val_accuracy improved from 0.44293 to 0.44463, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/AlexNet/023.h5
# 191/191 [==============================] - 395s 2s/step - loss: 1.4174 - accuracy: 0.6379 - top5_acc: 0.8557 - macro_f1score: 0.1916 - val_loss: 2.8312 - val_accuracy: 0.4446 - val_top5_acc: 0.6505 - val_macro_f1score: 0.1264
# Learning rate:  0.0003
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 24/70
# 191/191 [==============================] - ETA: 0s - loss: 1.3423 - accuracy: 0.6533 - top5_acc: 0.8671 - macro_f1score: 0.1968
# Epoch 00024: val_loss did not improve from 2.77750
#
# Epoch 00024: val_accuracy did not improve from 0.44463
# 191/191 [==============================] - 391s 2s/step - loss: 1.3423 - accuracy: 0.6533 - top5_acc: 0.8671 - macro_f1score: 0.1968 - val_loss: 2.8818 - val_accuracy: 0.4433 - val_top5_acc: 0.6491 - val_macro_f1score: 0.1244
# Learning rate:  0.0003
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 25/70
# 191/191 [==============================] - ETA: 0s - loss: 1.3198 - accuracy: 0.6606 - top5_acc: 0.8744 - macro_f1score: 0.1985
# Epoch 00025: val_loss did not improve from 2.77750
#
# Epoch 00025: val_accuracy did not improve from 0.44463
# 191/191 [==============================] - 389s 2s/step - loss: 1.3198 - accuracy: 0.6606 - top5_acc: 0.8744 - macro_f1score: 0.1985 - val_loss: 2.8270 - val_accuracy: 0.4321 - val_top5_acc: 0.6464 - val_macro_f1score: 0.1196
# Learning rate:  0.0003
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 26/70
# 191/191 [==============================] - ETA: 0s - loss: 1.2253 - accuracy: 0.6802 - top5_acc: 0.8856 - macro_f1score: 0.2096
# Epoch 00026: val_loss did not improve from 2.77750
#
# Epoch 00026: val_accuracy did not improve from 0.44463
# 191/191 [==============================] - 388s 2s/step - loss: 1.2253 - accuracy: 0.6802 - top5_acc: 0.8856 - macro_f1score: 0.2096 - val_loss: 2.8511 - val_accuracy: 0.4446 - val_top5_acc: 0.6484 - val_macro_f1score: 0.1298
# Learning rate:  0.0003
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 27/70
# 191/191 [==============================] - ETA: 0s - loss: 1.1913 - accuracy: 0.6896 - top5_acc: 0.8921 - macro_f1score: 0.2160
# Epoch 00027: val_loss did not improve from 2.77750
#
# Epoch 00027: val_accuracy improved from 0.44463 to 0.44531, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/AlexNet/027.h5
# 191/191 [==============================] - 391s 2s/step - loss: 1.1913 - accuracy: 0.6896 - top5_acc: 0.8921 - macro_f1score: 0.2160 - val_loss: 2.8602 - val_accuracy: 0.4453 - val_top5_acc: 0.6522 - val_macro_f1score: 0.1282
# Learning rate:  0.0003
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 28/70
# 191/191 [==============================] - ETA: 0s - loss: 1.1290 - accuracy: 0.7040 - top5_acc: 0.9021 - macro_f1score: 0.2215
# Epoch 00028: val_loss did not improve from 2.77750
#
# Epoch 00028: val_accuracy did not improve from 0.44531
# 191/191 [==============================] - 390s 2s/step - loss: 1.1290 - accuracy: 0.7040 - top5_acc: 0.9021 - macro_f1score: 0.2215 - val_loss: 2.8834 - val_accuracy: 0.4365 - val_top5_acc: 0.6450 - val_macro_f1score: 0.1227
# Learning rate:  0.0003
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 29/70
# 191/191 [==============================] - ETA: 0s - loss: 1.1032 - accuracy: 0.7090 - top5_acc: 0.9044 - macro_f1score: 0.2254
# Epoch 00029: val_loss did not improve from 2.77750
#
# Epoch 00029: val_accuracy did not improve from 0.44531
# 191/191 [==============================] - 394s 2s/step - loss: 1.1032 - accuracy: 0.7090 - top5_acc: 0.9044 - macro_f1score: 0.2254 - val_loss: 2.9686 - val_accuracy: 0.4358 - val_top5_acc: 0.6447 - val_macro_f1score: 0.1278
# Learning rate:  0.0003
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 30/70
# 191/191 [==============================] - ETA: 0s - loss: 1.0535 - accuracy: 0.7203 - top5_acc: 0.9132 - macro_f1score: 0.2311
# Epoch 00030: val_loss did not improve from 2.77750
#
# Epoch 00030: val_accuracy did not improve from 0.44531
# 191/191 [==============================] - 398s 2s/step - loss: 1.0535 - accuracy: 0.7203 - top5_acc: 0.9132 - macro_f1score: 0.2311 - val_loss: 2.9076 - val_accuracy: 0.4436 - val_top5_acc: 0.6512 - val_macro_f1score: 0.1283
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 31/70
# 191/191 [==============================] - ETA: 0s - loss: 0.8421 - accuracy: 0.7720 - top5_acc: 0.9353 - macro_f1score: 0.2543
# Epoch 00031: val_loss did not improve from 2.77750
#
# Epoch 00031: val_accuracy improved from 0.44531 to 0.46535, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/AlexNet/031.h5
# 191/191 [==============================] - 405s 2s/step - loss: 0.8421 - accuracy: 0.7720 - top5_acc: 0.9353 - macro_f1score: 0.2543 - val_loss: 2.8289 - val_accuracy: 0.4654 - val_top5_acc: 0.6692 - val_macro_f1score: 0.1403
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 32/70
# 191/191 [==============================] - ETA: 0s - loss: 0.7244 - accuracy: 0.8045 - top5_acc: 0.9466 - macro_f1score: 0.2688
# Epoch 00032: val_loss did not improve from 2.77750
#
# Epoch 00032: val_accuracy did not improve from 0.46535
# 191/191 [==============================] - 405s 2s/step - loss: 0.7244 - accuracy: 0.8045 - top5_acc: 0.9466 - macro_f1score: 0.2688 - val_loss: 2.8857 - val_accuracy: 0.4626 - val_top5_acc: 0.6685 - val_macro_f1score: 0.1402
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00033: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 33/70
# 191/191 [==============================] - ETA: 0s - loss: 0.6917 - accuracy: 0.8093 - top5_acc: 0.9513 - macro_f1score: 0.2742
# Epoch 00033: val_loss did not improve from 2.77750
#
# Epoch 00033: val_accuracy improved from 0.46535 to 0.46773, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/AlexNet/033.h5
# 191/191 [==============================] - 413s 2s/step - loss: 0.6917 - accuracy: 0.8093 - top5_acc: 0.9513 - macro_f1score: 0.2742 - val_loss: 2.9440 - val_accuracy: 0.4677 - val_top5_acc: 0.6692 - val_macro_f1score: 0.1444
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00034: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 34/70
# 191/191 [==============================] - ETA: 0s - loss: 0.6486 - accuracy: 0.8217 - top5_acc: 0.9555 - macro_f1score: 0.2799
# Epoch 00034: val_loss did not improve from 2.77750
#
# Epoch 00034: val_accuracy did not improve from 0.46773
# 191/191 [==============================] - 413s 2s/step - loss: 0.6486 - accuracy: 0.8217 - top5_acc: 0.9555 - macro_f1score: 0.2799 - val_loss: 2.9536 - val_accuracy: 0.4616 - val_top5_acc: 0.6637 - val_macro_f1score: 0.1413
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00035: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 35/70
# 191/191 [==============================] - ETA: 0s - loss: 0.6239 - accuracy: 0.8288 - top5_acc: 0.9564 - macro_f1score: 0.2836
# Epoch 00035: val_loss did not improve from 2.77750
#
# Epoch 00035: val_accuracy did not improve from 0.46773
# 191/191 [==============================] - 414s 2s/step - loss: 0.6239 - accuracy: 0.8288 - top5_acc: 0.9564 - macro_f1score: 0.2836 - val_loss: 2.9673 - val_accuracy: 0.4677 - val_top5_acc: 0.6658 - val_macro_f1score: 0.1434
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00036: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 36/70
# 191/191 [==============================] - ETA: 0s - loss: 0.6031 - accuracy: 0.8333 - top5_acc: 0.9613 - macro_f1score: 0.2845
# Epoch 00036: val_loss did not improve from 2.77750
#
# Epoch 00036: val_accuracy did not improve from 0.46773
# 191/191 [==============================] - 427s 2s/step - loss: 0.6031 - accuracy: 0.8333 - top5_acc: 0.9613 - macro_f1score: 0.2845 - val_loss: 3.0017 - val_accuracy: 0.4643 - val_top5_acc: 0.6722 - val_macro_f1score: 0.1412
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00037: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 37/70
# 191/191 [==============================] - ETA: 0s - loss: 0.6046 - accuracy: 0.8361 - top5_acc: 0.9594 - macro_f1score: 0.2869
# Epoch 00037: val_loss did not improve from 2.77750
#
# Epoch 00037: val_accuracy improved from 0.46773 to 0.46943, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/AlexNet/037.h5
# 191/191 [==============================] - 435s 2s/step - loss: 0.6046 - accuracy: 0.8361 - top5_acc: 0.9594 - macro_f1score: 0.2869 - val_loss: 2.9763 - val_accuracy: 0.4694 - val_top5_acc: 0.6719 - val_macro_f1score: 0.1419
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00038: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 38/70
# 191/191 [==============================] - ETA: 0s - loss: 0.5808 - accuracy: 0.8392 - top5_acc: 0.9626 - macro_f1score: 0.2902
# Epoch 00038: val_loss did not improve from 2.77750
#
# Epoch 00038: val_accuracy improved from 0.46943 to 0.47351, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/AlexNet/038.h5
# 191/191 [==============================] - 435s 2s/step - loss: 0.5808 - accuracy: 0.8392 - top5_acc: 0.9626 - macro_f1score: 0.2902 - val_loss: 2.9846 - val_accuracy: 0.4735 - val_top5_acc: 0.6726 - val_macro_f1score: 0.1434
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00039: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 39/70
# 191/191 [==============================] - ETA: 0s - loss: 0.5780 - accuracy: 0.8416 - top5_acc: 0.9618 - macro_f1score: 0.2891
# Epoch 00039: val_loss did not improve from 2.77750
#
# Epoch 00039: val_accuracy did not improve from 0.47351
# 191/191 [==============================] - 429s 2s/step - loss: 0.5780 - accuracy: 0.8416 - top5_acc: 0.9618 - macro_f1score: 0.2891 - val_loss: 3.0211 - val_accuracy: 0.4711 - val_top5_acc: 0.6668 - val_macro_f1score: 0.1438
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00040: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 40/70
# 191/191 [==============================] - ETA: 0s - loss: 0.5572 - accuracy: 0.8450 - top5_acc: 0.9628 - macro_f1score: 0.2910
# Epoch 00040: val_loss did not improve from 2.77750
#
# Epoch 00040: val_accuracy did not improve from 0.47351
# 191/191 [==============================] - 405s 2s/step - loss: 0.5572 - accuracy: 0.8450 - top5_acc: 0.9628 - macro_f1score: 0.2910 - val_loss: 3.0202 - val_accuracy: 0.4728 - val_top5_acc: 0.6736 - val_macro_f1score: 0.1452
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00041: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 41/70
# 191/191 [==============================] - ETA: 0s - loss: 0.5522 - accuracy: 0.8477 - top5_acc: 0.9635 - macro_f1score: 0.2940
# Epoch 00041: val_loss did not improve from 2.77750
#
# Epoch 00041: val_accuracy did not improve from 0.47351
# 191/191 [==============================] - 400s 2s/step - loss: 0.5522 - accuracy: 0.8477 - top5_acc: 0.9635 - macro_f1score: 0.2940 - val_loss: 3.0236 - val_accuracy: 0.4688 - val_top5_acc: 0.6678 - val_macro_f1score: 0.1436
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00042: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 42/70
# 191/191 [==============================] - ETA: 0s - loss: 0.5334 - accuracy: 0.8502 - top5_acc: 0.9671 - macro_f1score: 0.2933
# Epoch 00042: val_loss did not improve from 2.77750
#
# Epoch 00042: val_accuracy did not improve from 0.47351
# 191/191 [==============================] - 395s 2s/step - loss: 0.5334 - accuracy: 0.8502 - top5_acc: 0.9671 - macro_f1score: 0.2933 - val_loss: 3.0135 - val_accuracy: 0.4694 - val_top5_acc: 0.6739 - val_macro_f1score: 0.1472
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00043: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 43/70
# 191/191 [==============================] - ETA: 0s - loss: 0.5293 - accuracy: 0.8525 - top5_acc: 0.9678 - macro_f1score: 0.2975
# Epoch 00043: val_loss did not improve from 2.77750
#
# Epoch 00043: val_accuracy did not improve from 0.47351
# 191/191 [==============================] - 393s 2s/step - loss: 0.5293 - accuracy: 0.8525 - top5_acc: 0.9678 - macro_f1score: 0.2975 - val_loss: 3.0345 - val_accuracy: 0.4711 - val_top5_acc: 0.6702 - val_macro_f1score: 0.1454
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00044: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 44/70
# 191/191 [==============================] - ETA: 0s - loss: 0.5131 - accuracy: 0.8583 - top5_acc: 0.9692 - macro_f1score: 0.2985
# Epoch 00044: val_loss did not improve from 2.77750
#
# Epoch 00044: val_accuracy did not improve from 0.47351
# 191/191 [==============================] - 395s 2s/step - loss: 0.5131 - accuracy: 0.8583 - top5_acc: 0.9692 - macro_f1score: 0.2985 - val_loss: 3.0772 - val_accuracy: 0.4650 - val_top5_acc: 0.6695 - val_macro_f1score: 0.1458
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00045: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 45/70
# 191/191 [==============================] - ETA: 0s - loss: 0.4828 - accuracy: 0.8633 - top5_acc: 0.9714 - macro_f1score: 0.3022
# Epoch 00045: val_loss did not improve from 2.77750
#
# Epoch 00045: val_accuracy did not improve from 0.47351
# 191/191 [==============================] - 395s 2s/step - loss: 0.4828 - accuracy: 0.8633 - top5_acc: 0.9714 - macro_f1score: 0.3022 - val_loss: 3.0832 - val_accuracy: 0.4654 - val_top5_acc: 0.6736 - val_macro_f1score: 0.1491
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00046: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 46/70
# 191/191 [==============================] - ETA: 0s - loss: 0.4832 - accuracy: 0.8625 - top5_acc: 0.9716 - macro_f1score: 0.3010
# Epoch 00046: val_loss did not improve from 2.77750
#
# Epoch 00046: val_accuracy did not improve from 0.47351
# 191/191 [==============================] - 401s 2s/step - loss: 0.4832 - accuracy: 0.8625 - top5_acc: 0.9716 - macro_f1score: 0.3010 - val_loss: 3.0938 - val_accuracy: 0.4718 - val_top5_acc: 0.6695 - val_macro_f1score: 0.1482
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00047: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 47/70
# 191/191 [==============================] - ETA: 0s - loss: 0.4934 - accuracy: 0.8637 - top5_acc: 0.9710 - macro_f1score: 0.3001
# Epoch 00047: val_loss did not improve from 2.77750
#
# Epoch 00047: val_accuracy did not improve from 0.47351
# 191/191 [==============================] - 401s 2s/step - loss: 0.4934 - accuracy: 0.8637 - top5_acc: 0.9710 - macro_f1score: 0.3001 - val_loss: 3.0871 - val_accuracy: 0.4698 - val_top5_acc: 0.6678 - val_macro_f1score: 0.1466
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00048: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 48/70
# 191/191 [==============================] - ETA: 0s - loss: 0.4765 - accuracy: 0.8692 - top5_acc: 0.9708 - macro_f1score: 0.3029
# Epoch 00048: val_loss did not improve from 2.77750
#
# Epoch 00048: val_accuracy did not improve from 0.47351
# 191/191 [==============================] - 409s 2s/step - loss: 0.4765 - accuracy: 0.8692 - top5_acc: 0.9708 - macro_f1score: 0.3029 - val_loss: 3.1012 - val_accuracy: 0.4715 - val_top5_acc: 0.6695 - val_macro_f1score: 0.1465
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00049: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 49/70
# 191/191 [==============================] - ETA: 0s - loss: 0.4625 - accuracy: 0.8697 - top5_acc: 0.9731 - macro_f1score: 0.3044
# Epoch 00049: val_loss did not improve from 2.77750
#
# Epoch 00049: val_accuracy did not improve from 0.47351
# 191/191 [==============================] - 407s 2s/step - loss: 0.4625 - accuracy: 0.8697 - top5_acc: 0.9731 - macro_f1score: 0.3044 - val_loss: 3.1008 - val_accuracy: 0.4721 - val_top5_acc: 0.6763 - val_macro_f1score: 0.1529
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00050: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 50/70
# 191/191 [==============================] - ETA: 0s - loss: 0.4569 - accuracy: 0.8714 - top5_acc: 0.9744 - macro_f1score: 0.3051
# Epoch 00050: val_loss did not improve from 2.77750
#
# Epoch 00050: val_accuracy did not improve from 0.47351
# 191/191 [==============================] - 415s 2s/step - loss: 0.4569 - accuracy: 0.8714 - top5_acc: 0.9744 - macro_f1score: 0.3051 - val_loss: 3.1196 - val_accuracy: 0.4708 - val_top5_acc: 0.6749 - val_macro_f1score: 0.1464
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00051: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 51/70
# 191/191 [==============================] - ETA: 0s - loss: 0.4572 - accuracy: 0.8692 - top5_acc: 0.9741 - macro_f1score: 0.3039
# Epoch 00051: val_loss did not improve from 2.77750
#
# Epoch 00051: val_accuracy did not improve from 0.47351
# 191/191 [==============================] - 413s 2s/step - loss: 0.4572 - accuracy: 0.8692 - top5_acc: 0.9741 - macro_f1score: 0.3039 - val_loss: 3.1219 - val_accuracy: 0.4725 - val_top5_acc: 0.6736 - val_macro_f1score: 0.1464
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00052: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 52/70
# 191/191 [==============================] - ETA: 0s - loss: 0.4510 - accuracy: 0.8723 - top5_acc: 0.9742 - macro_f1score: 0.3059
# Epoch 00052: val_loss did not improve from 2.77750
#
# Epoch 00052: val_accuracy did not improve from 0.47351
# 191/191 [==============================] - 404s 2s/step - loss: 0.4510 - accuracy: 0.8723 - top5_acc: 0.9742 - macro_f1score: 0.3059 - val_loss: 3.1270 - val_accuracy: 0.4708 - val_top5_acc: 0.6729 - val_macro_f1score: 0.1472
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00053: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 53/70
# 191/191 [==============================] - ETA: 0s - loss: 0.4391 - accuracy: 0.8763 - top5_acc: 0.9744 - macro_f1score: 0.3079
# Epoch 00053: val_loss did not improve from 2.77750
#
# Epoch 00053: val_accuracy did not improve from 0.47351
# 191/191 [==============================] - 411s 2s/step - loss: 0.4391 - accuracy: 0.8763 - top5_acc: 0.9744 - macro_f1score: 0.3079 - val_loss: 3.1609 - val_accuracy: 0.4688 - val_top5_acc: 0.6705 - val_macro_f1score: 0.1462
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00054: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 54/70
# 191/191 [==============================] - ETA: 0s - loss: 0.4278 - accuracy: 0.8765 - top5_acc: 0.9765 - macro_f1score: 0.3084
# Epoch 00054: val_loss did not improve from 2.77750
#
# Epoch 00054: val_accuracy did not improve from 0.47351
# 191/191 [==============================] - 400s 2s/step - loss: 0.4278 - accuracy: 0.8765 - top5_acc: 0.9765 - macro_f1score: 0.3084 - val_loss: 3.1185 - val_accuracy: 0.4721 - val_top5_acc: 0.6746 - val_macro_f1score: 0.1480
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00055: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 55/70
# 191/191 [==============================] - ETA: 0s - loss: 0.4265 - accuracy: 0.8781 - top5_acc: 0.9767 - macro_f1score: 0.3091
# Epoch 00055: val_loss did not improve from 2.77750
#
# Epoch 00055: val_accuracy did not improve from 0.47351
# 191/191 [==============================] - 403s 2s/step - loss: 0.4265 - accuracy: 0.8781 - top5_acc: 0.9767 - macro_f1score: 0.3091 - val_loss: 3.1574 - val_accuracy: 0.4677 - val_top5_acc: 0.6763 - val_macro_f1score: 0.1494
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00056: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 56/70
# 191/191 [==============================] - ETA: 0s - loss: 0.4256 - accuracy: 0.8799 - top5_acc: 0.9757 - macro_f1score: 0.3096
# Epoch 00056: val_loss did not improve from 2.77750
#
# Epoch 00056: val_accuracy did not improve from 0.47351
# 191/191 [==============================] - 401s 2s/step - loss: 0.4256 - accuracy: 0.8799 - top5_acc: 0.9757 - macro_f1score: 0.3096 - val_loss: 3.1446 - val_accuracy: 0.4650 - val_top5_acc: 0.6709 - val_macro_f1score: 0.1474
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00057: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 57/70
# 191/191 [==============================] - ETA: 0s - loss: 0.4181 - accuracy: 0.8839 - top5_acc: 0.9764 - macro_f1score: 0.3119
# Epoch 00057: val_loss did not improve from 2.77750
#
# Epoch 00057: val_accuracy did not improve from 0.47351
# 191/191 [==============================] - 397s 2s/step - loss: 0.4181 - accuracy: 0.8839 - top5_acc: 0.9764 - macro_f1score: 0.3119 - val_loss: 3.1626 - val_accuracy: 0.4718 - val_top5_acc: 0.6705 - val_macro_f1score: 0.1474
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00058: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 58/70
# 191/191 [==============================] - ETA: 0s - loss: 0.4058 - accuracy: 0.8826 - top5_acc: 0.9804 - macro_f1score: 0.3117
# Epoch 00058: val_loss did not improve from 2.77750
#
# Epoch 00058: val_accuracy did not improve from 0.47351
# 191/191 [==============================] - 391s 2s/step - loss: 0.4058 - accuracy: 0.8826 - top5_acc: 0.9804 - macro_f1score: 0.3117 - val_loss: 3.1660 - val_accuracy: 0.4654 - val_top5_acc: 0.6780 - val_macro_f1score: 0.1474
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00059: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 59/70
# 191/191 [==============================] - ETA: 0s - loss: 0.4082 - accuracy: 0.8819 - top5_acc: 0.9788 - macro_f1score: 0.3127
# Epoch 00059: val_loss did not improve from 2.77750
#
# Epoch 00059: val_accuracy did not improve from 0.47351
# 191/191 [==============================] - 398s 2s/step - loss: 0.4082 - accuracy: 0.8819 - top5_acc: 0.9788 - macro_f1score: 0.3127 - val_loss: 3.1687 - val_accuracy: 0.4650 - val_top5_acc: 0.6719 - val_macro_f1score: 0.1471
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00060: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 60/70
# 191/191 [==============================] - ETA: 0s - loss: 0.3918 - accuracy: 0.8887 - top5_acc: 0.9794 - macro_f1score: 0.3140
# Epoch 00060: val_loss did not improve from 2.77750
#
# Epoch 00060: val_accuracy did not improve from 0.47351
# 191/191 [==============================] - 395s 2s/step - loss: 0.3918 - accuracy: 0.8887 - top5_acc: 0.9794 - macro_f1score: 0.3140 - val_loss: 3.1787 - val_accuracy: 0.4664 - val_top5_acc: 0.6783 - val_macro_f1score: 0.1488
# Learning rate:  2.9999999999999997e-06
#
# Epoch 00061: LearningRateScheduler reducing learning rate to 2.9999999999999997e-06.
# Epoch 61/70
# 191/191 [==============================] - ETA: 0s - loss: 0.3808 - accuracy: 0.8922 - top5_acc: 0.9808 - macro_f1score: 0.3158
# Epoch 00061: val_loss did not improve from 2.77750
#
# Epoch 00061: val_accuracy did not improve from 0.47351
# 191/191 [==============================] - 390s 2s/step - loss: 0.3808 - accuracy: 0.8922 - top5_acc: 0.9808 - macro_f1score: 0.3158 - val_loss: 3.1418 - val_accuracy: 0.4664 - val_top5_acc: 0.6770 - val_macro_f1score: 0.1476
# Learning rate:  2.9999999999999997e-06
#
# Epoch 00062: LearningRateScheduler reducing learning rate to 2.9999999999999997e-06.
# Epoch 62/70
# 191/191 [==============================] - ETA: 0s - loss: 0.3696 - accuracy: 0.8947 - top5_acc: 0.9810 - macro_f1score: 0.3170
# Epoch 00062: val_loss did not improve from 2.77750
#
# Epoch 00062: val_accuracy did not improve from 0.47351
# 191/191 [==============================] - 399s 2s/step - loss: 0.3696 - accuracy: 0.8947 - top5_acc: 0.9810 - macro_f1score: 0.3170 - val_loss: 3.1414 - val_accuracy: 0.4681 - val_top5_acc: 0.6763 - val_macro_f1score: 0.1485
# Learning rate:  2.9999999999999997e-06
#
# Epoch 00063: LearningRateScheduler reducing learning rate to 2.9999999999999997e-06.
# Epoch 63/70
# 191/191 [==============================] - ETA: 0s - loss: 0.3672 - accuracy: 0.8959 - top5_acc: 0.9800 - macro_f1score: 0.3176
# Epoch 00063: val_loss did not improve from 2.77750
#
# Epoch 00063: val_accuracy did not improve from 0.47351
# 191/191 [==============================] - 391s 2s/step - loss: 0.3672 - accuracy: 0.8959 - top5_acc: 0.9800 - macro_f1score: 0.3176 - val_loss: 3.1381 - val_accuracy: 0.4647 - val_top5_acc: 0.6749 - val_macro_f1score: 0.1462
# Learning rate:  2.9999999999999997e-06
#
# Epoch 00064: LearningRateScheduler reducing learning rate to 2.9999999999999997e-06.
# Epoch 64/70
# 191/191 [==============================] - ETA: 0s - loss: 0.3690 - accuracy: 0.8945 - top5_acc: 0.9817 - macro_f1score: 0.3171
# Epoch 00064: val_loss did not improve from 2.77750
#
# Epoch 00064: val_accuracy did not improve from 0.47351
# 191/191 [==============================] - 390s 2s/step - loss: 0.3690 - accuracy: 0.8945 - top5_acc: 0.9817 - macro_f1score: 0.3171 - val_loss: 3.1165 - val_accuracy: 0.4681 - val_top5_acc: 0.6770 - val_macro_f1score: 0.1495
# Learning rate:  2.9999999999999997e-06
#
# Epoch 00065: LearningRateScheduler reducing learning rate to 2.9999999999999997e-06.
# Epoch 65/70
# 191/191 [==============================] - ETA: 0s - loss: 0.3723 - accuracy: 0.8923 - top5_acc: 0.9807 - macro_f1score: 0.3149
# Epoch 00065: val_loss did not improve from 2.77750
#
# Epoch 00065: val_accuracy did not improve from 0.47351
# 191/191 [==============================] - 391s 2s/step - loss: 0.3723 - accuracy: 0.8923 - top5_acc: 0.9807 - macro_f1score: 0.3149 - val_loss: 3.1199 - val_accuracy: 0.4657 - val_top5_acc: 0.6766 - val_macro_f1score: 0.1474
# Learning rate:  2.9999999999999997e-06
#
# Epoch 00066: LearningRateScheduler reducing learning rate to 2.9999999999999997e-06.
# Epoch 66/70
# 191/191 [==============================] - ETA: 0s - loss: 0.3700 - accuracy: 0.8950 - top5_acc: 0.9818 - macro_f1score: 0.3159
# Epoch 00066: val_loss did not improve from 2.77750
#
# Epoch 00066: val_accuracy did not improve from 0.47351
# 191/191 [==============================] - 388s 2s/step - loss: 0.3700 - accuracy: 0.8950 - top5_acc: 0.9818 - macro_f1score: 0.3159 - val_loss: 3.1293 - val_accuracy: 0.4647 - val_top5_acc: 0.6739 - val_macro_f1score: 0.1472
# Learning rate:  2.9999999999999997e-06
#
# Epoch 00067: LearningRateScheduler reducing learning rate to 2.9999999999999997e-06.
# Epoch 67/70
# 191/191 [==============================] - ETA: 0s - loss: 0.3752 - accuracy: 0.8916 - top5_acc: 0.9797 - macro_f1score: 0.3157
# Epoch 00067: val_loss did not improve from 2.77750
#
# Epoch 00067: val_accuracy did not improve from 0.47351
# 191/191 [==============================] - 387s 2s/step - loss: 0.3752 - accuracy: 0.8916 - top5_acc: 0.9797 - macro_f1score: 0.3157 - val_loss: 3.0842 - val_accuracy: 0.4718 - val_top5_acc: 0.6797 - val_macro_f1score: 0.1492
# Learning rate:  2.9999999999999997e-06
#
# Epoch 00068: LearningRateScheduler reducing learning rate to 2.9999999999999997e-06.
# Epoch 68/70
# 191/191 [==============================] - ETA: 0s - loss: 0.3683 - accuracy: 0.8939 - top5_acc: 0.9825 - macro_f1score: 0.3157
# Epoch 00068: val_loss did not improve from 2.77750
#
# Epoch 00068: val_accuracy did not improve from 0.47351
# 191/191 [==============================] - 388s 2s/step - loss: 0.3683 - accuracy: 0.8939 - top5_acc: 0.9825 - macro_f1score: 0.3157 - val_loss: 3.0762 - val_accuracy: 0.4701 - val_top5_acc: 0.6776 - val_macro_f1score: 0.1500
# Learning rate:  2.9999999999999997e-06
#
# Epoch 00069: LearningRateScheduler reducing learning rate to 2.9999999999999997e-06.
# Epoch 69/70
# 191/191 [==============================] - ETA: 0s - loss: 0.3632 - accuracy: 0.8964 - top5_acc: 0.9833 - macro_f1score: 0.3174
# Epoch 00069: val_loss did not improve from 2.77750
#
# Epoch 00069: val_accuracy did not improve from 0.47351
# 191/191 [==============================] - 388s 2s/step - loss: 0.3632 - accuracy: 0.8964 - top5_acc: 0.9833 - macro_f1score: 0.3174 - val_loss: 3.0865 - val_accuracy: 0.4677 - val_top5_acc: 0.6787 - val_macro_f1score: 0.1483
# Learning rate:  2.9999999999999997e-06
#
# Epoch 00070: LearningRateScheduler reducing learning rate to 2.9999999999999997e-06.
# Epoch 70/70
# 191/191 [==============================] - ETA: 0s - loss: 0.3641 - accuracy: 0.8988 - top5_acc: 0.9823 - macro_f1score: 0.3173
# Epoch 00070: val_loss did not improve from 2.77750
#
# Epoch 00070: val_accuracy did not improve from 0.47351
# 191/191 [==============================] - 389s 2s/step - loss: 0.3641 - accuracy: 0.8988 - top5_acc: 0.9823 - macro_f1score: 0.3173 - val_loss: 3.0722 - val_accuracy: 0.4708 - val_top5_acc: 0.6776 - val_macro_f1score: 0.1479

# %% [markdown]
# ### 3) AlexNet Evaluate

# %%
# 1. epoch=maximum
loss , acc, top5_acc, mf1 = model.evaluate(test_generator,steps=int(len(x_test)/batch_sizes))
print('[Test Loss: %.4f /  Test Top-1 Accuracy: %.4f / Test Top-5 Accuracy: %.4f / Test Macro f1: %.4f]\n' % (loss,acc,top5_acc,mf1))
# Out:
# 24/24 [==============================] - 1854s 77s/step - loss: 3.1803 - accuracy: 0.4590 - top5_acc: 0.6615 - macro_f1score: 0.1473
# [Test Loss: 3.1803 /  Test Top-1 Accuracy: 0.4590 / Test Top-5 Accuracy: 0.6615 / Test Macro f1: 0.1473]

# %%
loss=history.history['loss']
val_loss=history.history['val_loss']
acc=history.history['accuracy']
val_acc=history.history['val_accuracy']
top5_acc=history.history['top5_acc']
val_top5_acc=history.history['val_top5_acc']
f1=history.history['macro_f1score']
val_f1=history.history['val_macro_f1score']
epochs=range(1,len(acc)+1)

data = np.array([epochs,loss,val_loss,acc,val_acc,top5_acc,val_top5_acc,f1,val_f1]).T

# %%
# data save
# epochs, loss, val_loss, acc, val_acc, top5_acc, val_top5_acc, f1, val_f1

np.savetxt(os.path.join(dir,'train_valid_output',number,model.name+'.txt'),data)

# %%
# data import
data = np.loadtxt(os.path.join(dir,'train_valid_output',number,'AlexNet.txt'))

# %%
epochs=data[:,0]
loss=data[:,1]
val_loss=data[:,2]
acc=data[:,3]
val_acc=data[:,4]
top5_acc=data[:,5]
val_top5_acc=data[:,6]

# %%
plt.plot(epochs[1:],acc[1:],'b',label='Training 1-Acc')
plt.plot(epochs[1:],val_acc[1:],'r',label='Validation 1-Acc')
plt.title('Training and Validation Top-1 Accuracy')
plt.legend()
plt.figure()

plt.plot(epochs[1:],top5_acc[1:],'b',label='Training 5-Acc')
plt.plot(epochs[1:],val_top5_acc[1:],'r',label='Validation 5-Acc')
plt.title('Training and Validation Top-5 Accuracy')
plt.legend()
plt.figure()

plt.plot(epochs[10:],loss[10:],'b',label='Training Loss')
plt.plot(epochs[10:],val_loss[10:],'r',label='Validation Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()

# %%
# 이 아래는 내가 인위적으로 살펴보고 싶은 epoch에 대해서 결과값 출력 / AlexNet

# %%
# 참고 : https://github.com/OverLordGoldDragon/keras-adamw

import sys
sys.path.append('/content/drive/My Drive/Colab Notebooks/Paper')
import utils
import optimizers_v2
from utils import get_weight_decays, fill_dict_in_order
from utils import reset_seeds, K_eval
from optimizers_v2 import AdamW, NadamW, SGDW

# %%
# top-5 accuracy 출력
import functools
top5_acc = functools.partial(ks.metrics.top_k_categorical_accuracy, k=5)
top5_acc.__name__ = 'top5_acc'

# %%
model=load_model(os.path.join(dir,'model_output',number,'AlexNet','038.h5'),custom_objects={"macro_f1score": macro_f1score,"top5_acc":top5_acc,"LRN":LRN, "AdamW":AdamW})

# %%
# 2. epoch=?
loss , acc, top5_acc, mf1 = model.evaluate(test_generator,steps=int(len(x_test)/batch_sizes))
print('[Test Loss: %.4f /  Test Top-1 Accuracy: %.4f / Test Top-5 Accuracy: %.4f / Test Macro f1: %.4f]\n' % (loss,acc,top5_acc,mf1))
# Out:
# 24/24 [==============================] - 1483s 62s/step - loss: 3.0725 - accuracy: 0.4593 - top5_acc: 0.6549 - macro_f1score: 0.1421
# [Test Loss: 3.0725 /  Test Top-1 Accuracy: 0.4593 / Test Top-5 Accuracy: 0.6549 / Test Macro f1: 0.1421]
