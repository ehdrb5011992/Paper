# %%
#모형 출처 : https://github.com/titu1994/keras-squeeze-excite-network
# https://ai.googleblog.com/2016/08/improving-inception-and-image.html

# %% [markdown]
# # [Inception ResNet V2]

# %% [markdown]
# *KU LeeDongGyu*

# %% [markdown]
# ## Contents
# ---

# %% [markdown]
# 1. Data Preprocessing
# ```
# 1) Data Import
# 2) Data Augmentation
# ```
# 2. Support Functions & Almost Original Inception-ResNet-V2
# ```
# 1) Support Functions
# 2) Almost Original Inception-ResNet-V2
# 3) Inception-ResNet-V2 Evaluate
# ```

# %% [markdown]
# ### Install Packages

# %% [markdown]
# ### Module

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/My Drive/Colab Notebooks/Paper
# Out:
# /content/drive/My Drive/Colab Notebooks/Paper

# %%
from f1score import macro_f1score,weighted_f1score

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import cv2
import tensorflow as tf
from tensorflow import keras as ks
from tensorflow.keras import backend as K 
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, Input, Concatenate, ZeroPadding2D ,GlobalMaxPooling2D, Reshape , Lambda , Add, Multiply
from tensorflow.keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D, Activation, BatchNormalization, AveragePooling2D , ZeroPadding2D, SeparableConv2D , LeakyReLU
from tensorflow.keras.layers import add, concatenate, multiply
from tensorflow.keras.optimizers import Adam, RMSprop , SGD
from tensorflow.keras.callbacks import EarlyStopping , LearningRateScheduler, ModelCheckpoint, CSVLogger, Callback, ReduceLROnPlateau
from tensorflow.keras.regularizers import l1,l2,l1_l2
from tensorflow.keras.models import Model , load_model , Sequential
from tensorflow.keras.utils import plot_model , to_categorical, get_file
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
os.getcwd()
# Out:
# '/content/drive/My Drive/Colab Notebooks/Paper'

# %%
print(tf.__version__)
print(ks.__version__)
# Out:
# 2.3.0
# 2.4.0

# %%
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 11371367817178197910
# , name: "/device:XLA_CPU:0"
# device_type: "XLA_CPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 4914701895451929611
# physical_device_desc: "device: XLA_CPU device"
# , name: "/device:XLA_GPU:0"
# device_type: "XLA_GPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 1171297069878263086
# physical_device_desc: "device: XLA_GPU device"
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 15694502336
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 1692048019148721903
# physical_device_desc: "device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0"
# ]

# %%
# !cat /proc/cpuinfo
# Out:
# processor	: 0
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 79
# model name	: Intel(R) Xeon(R) CPU @ 2.20GHz
# stepping	: 0
# microcode	: 0x1
# cpu MHz		: 2200.000
# cache size	: 56320 KB
# physical id	: 0
# siblings	: 4
# core id		: 0
# cpu cores	: 2
# apicid		: 0
# initial apicid	: 0
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm rdseed adx smap xsaveopt arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs taa
# bogomips	: 4400.00
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 46 bits physical, 48 bits virtual
# power management:
#
# processor	: 1
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 79
# model name	: Intel(R) Xeon(R) CPU @ 2.20GHz
# stepping	: 0
# microcode	: 0x1
# cpu MHz		: 2200.000
# cache size	: 56320 KB
# physical id	: 0
# siblings	: 4
# core id		: 1
# cpu cores	: 2
# apicid		: 2
# initial apicid	: 2
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm rdseed adx smap xsaveopt arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs taa
# bogomips	: 4400.00
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 46 bits physical, 48 bits virtual
# power management:
#
# processor	: 2
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 79
# model name	: Intel(R) Xeon(R) CPU @ 2.20GHz
# stepping	: 0
# microcode	: 0x1
# cpu MHz		: 2200.000
# cache size	: 56320 KB
# physical id	: 0
# siblings	: 4
# core id		: 0
# cpu cores	: 2
# apicid		: 1
# initial apicid	: 1
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm rdseed adx smap xsaveopt arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs taa
# bogomips	: 4400.00
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 46 bits physical, 48 bits virtual
# power management:
#
# processor	: 3
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 79
# model name	: Intel(R) Xeon(R) CPU @ 2.20GHz
# stepping	: 0
# microcode	: 0x1
# cpu MHz		: 2200.000
# cache size	: 56320 KB
# physical id	: 0
# siblings	: 4
# core id		: 1
# cpu cores	: 2
# apicid		: 3
# initial apicid	: 3
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm rdseed adx smap xsaveopt arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs taa
# bogomips	: 4400.00
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 46 bits physical, 48 bits virtual
# power management:

# %% [markdown]
# ## 1. Data Preprocessing
# ---

# %% [markdown]
# ### 1) Data Import

# %%
# 바꿔서 살펴 볼 것들
# CALTECH, CIFAR100, FER, MIT
data_name = 'CALTECH'
gan_type = 'No_GAN'
number = '1'
size = 299 # sizes after cropping
super_size = 330 # sizes before cropping 
input_sizes = (size,size,3)
batch_sizes = 32
weight_decay = 1e-3
epochs = 70

# %%
# 참고 : https://stackoverflow.com/questions/32419510/how-to-get-reproducible-results-in-keras/52897216#52897216
# setting the seed number for random number generation for reproducibility.

from numpy.random import seed
import random


if number=='1':
    seed_num = 200225
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)
elif number=='2':
    seed_num = 727
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)
elif number=='3':
    seed_num = 115
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)
elif number=='4':
    seed_num = 501
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)
elif number=='5':
    seed_num = 517
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)

# %%
# data import

if data_name=='FER' :
    x_train =  np.zeros(28698)
    x_valid = np.zeros(3589)
    x_test = np.zeros(3588)
    classes = 7 
    tr_center = [0.50793296, 0.50793296, 0.50793296]
elif data_name=='MIT':
    x_train = np.zeros(12466)
    x_valid = np.zeros(1564)
    x_test = np.zeros(1590)
    classes = 67 
    tr_center = [0.47916578, 0.42029615, 0.36046057]
elif data_name=='CALTECH':
    x_train = np.zeros(24510)
    x_valid = np.zeros(2980)
    x_test = np.zeros(3118)
    classes = 257
    tr_center = [0.51397761, 0.49525248, 0.46555727]
elif data_name=='CIFAR100':
    x_train = np.zeros(44923)
    x_valid = np.zeros(5077)
    x_test = np.zeros(10000)
    classes = 100
    tr_center = [0.53442983, 0.51355958, 0.46462564]

# %%
dir = os.path.join(os.getcwd(),data_name,gan_type)

# %% [markdown]
# ### 2) Data Augmentation

# %%
# 참고 : https://jkjung-avt.github.io/keras-image-cropping/

def random_crop(img, random_crop_size):
    # Note: image_data_format is 'channel_last'
    assert img.shape[2] == 3 # img.shape[2] 가 3(rgb)이 아니면 assertion error 발생
    height, width = img.shape[0], img.shape[1]
    dy, dx = random_crop_size
    x = np.random.randint(0, width - dx + 1)
    y = np.random.randint(0, height - dy + 1)
    return img[y:(y+dy), x:(x+dx), :]


def crop_generator(batches, crop_length):
    """Take as input a Keras ImageGen (Iterator) and generate random
    crops from the image batches generated by the original iterator.
    """
    while True:
        batch_x, batch_y = next(batches)
        batch_crops = np.zeros((batch_x.shape[0], crop_length, crop_length, 3))
        for i in range(batch_x.shape[0]):
            batch_crops[i] = random_crop(batch_x[i], (crop_length, crop_length))
        yield (batch_crops, batch_y)

# %%
from tensorflow.keras.preprocessing.image import img_to_array,load_img
import glob

# 데이터 전체에 대해 centering 진행함.

def read_cal_image(img_path): 
    x = img_to_array(load_img(img_path)) # x는 채널별 평균값
    y = x.shape[0] * x.shape[1]# y는 데이터별 픽셀 수 (비중)

    x = 1/255. * x # scaling하고, centering값을 뽑아냄.
    x = np.mean(x, axis=(0,1))
    
    return np.hstack([x,y])

def calculate_centered_mean(dataset_path,x_train=x_train):
    num = len(x_train)
    space = np.empty((num,4))
    i=0

    for p in glob.glob(os.path.join(dataset_path,'*/*.*')) :
        space[i] = read_cal_image(p)
        i += 1

    ratio = space[:,3] / np.sum(space[:,3])

    return np.average(space[:,0:3],axis=0,weights=ratio)


# 아래의 함수를 돌려서 나온 결과값을 중심화 값으로 설정.

# train_mean = calculate_centered_mean(os.path.join(dir,'data/train')).reshape((1,1,3))

# %%
datagen_tr = ImageDataGenerator(
    rescale=1/255.,
    horizontal_flip=True,
    featurewise_center=True,
    featurewise_std_normalization=False,
    rotation_range=10,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=[0.9,1.0],
    fill_mode = 'nearest')
datagen_val = ImageDataGenerator(rescale=1/255.,featurewise_center=True)
datagen_tes = ImageDataGenerator(rescale=1/255.,featurewise_center=True)

# 원래는 이 자리에 fit 매서드를 써야하지만, 그냥 내가 중심화함수를 만들고 적용함. 

# 중심화 설정
datagen_tr.mean = np.array(tr_center, dtype=np.float32).reshape((1,1,3)) # RGB
datagen_val.mean = np.array(tr_center, dtype=np.float32).reshape((1,1,3)) # RGB
datagen_tes.mean = np.array(tr_center, dtype=np.float32).reshape((1,1,3)) # RGB

# %%
train_batches = datagen_tr.flow_from_directory(directory=os.path.join(dir,'data/train'),target_size=(super_size,super_size),batch_size=batch_sizes,class_mode='categorical') # fer : 28698 / mit : 12466 / caltech : 24509 / cifar : 44923
train_generator= crop_generator(train_batches, size)
valid_generator = datagen_val.flow_from_directory(directory=os.path.join(dir,'data/valid'),target_size=(size,size),batch_size=batch_sizes,class_mode='categorical') # fer : 3589 / mit : 1564 / caltech : 2980 / cifar : 5077
test_generator = datagen_tes.flow_from_directory(directory=os.path.join(dir,'data/test'),target_size=(size,size),batch_size=batch_sizes,class_mode='categorical') # fer : 3588 / mit : 1590 / caltech : 3118 / cifar : 10000
# Out:
# Found 24509 images belonging to 257 classes.
# Found 2980 images belonging to 257 classes.
# Found 3118 images belonging to 257 classes.

# %% [markdown]
# ## 2. Support Functions & Almost Original Inception-ResNet-V2
# ---

# %% [markdown]
# ### 1) Support Functions

# %%
# def lr_schedule(epoch):
#     init_lr = 1e-4
#     k = 0.04
#     lr = init_lr * np.exp(-k*epoch)
#     print('Learning rate: ', lr)
#     return lr

def lr_schedule(epoch):
    lr = 1e-3
    if epoch < 30:
        lr = lr
    elif epoch < 60 :
        lr = lr * 0.1
    else:
        lr = lr * 0.01
    print('Learning rate: ', lr)
    return lr

# %%
def conv2d_bn(x, filters, kernel_size, strides=1, padding='same', activation='relu', use_bias=False, name=None, weight_decay=weight_decay):

    x = Conv2D(filters, kernel_size, strides=strides, padding=padding,  use_bias=use_bias, name=name, kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(x)
    if not use_bias:
        bn_axis =  3
        bn_name = None if name is None else '{name}_bn'.format(name=name)
        x = BatchNormalization(axis=bn_axis, scale=False, name=bn_name)(x)
        
    if activation is not None:
        ac_name = None if name is None else '{name}_ac'.format(name=name)
        x = Activation(activation, name=ac_name)(x)
    return x

# %%
def inception_resnet_block(x, scale, block_type, block_idx, activation='relu'):
 
    if block_type == 'block35':
        branch_0 = conv2d_bn(x, 32, 1)
        branch_1 = conv2d_bn(x, 32, 1)
        branch_1 = conv2d_bn(branch_1, 32, 3)
        branch_2 = conv2d_bn(x, 32, 1)
        branch_2 = conv2d_bn(branch_2, 48, 3)
        branch_2 = conv2d_bn(branch_2, 64, 3)
        branches = [branch_0, branch_1, branch_2]
    elif block_type == 'block17':
        branch_0 = conv2d_bn(x, 192, 1)
        branch_1 = conv2d_bn(x, 128, 1)
        branch_1 = conv2d_bn(branch_1, 160, [1, 7])
        branch_1 = conv2d_bn(branch_1, 192, [7, 1])
        branches = [branch_0, branch_1]
    elif block_type == 'block8':
        branch_0 = conv2d_bn(x, 192, 1)
        branch_1 = conv2d_bn(x, 192, 1)
        branch_1 = conv2d_bn(branch_1, 224, [1, 3])
        branch_1 = conv2d_bn(branch_1, 256, [3, 1])
        branches = [branch_0, branch_1]
    else:
        raise ValueError('Unknown Inception-ResNet block type. '
                         'Expects "block35", "block17" or "block8", '
                         'but got: {block_type}'.format(block_type=block_type))

    block_name = '{block_type}_{block_idx}'.format(block_type=block_type, block_idx=block_idx)
    channel_axis = 3
    mixed = Concatenate(axis=channel_axis, name='{block_name}_mixed'.format(block_name=block_name))(branches)
    up = conv2d_bn(mixed,
                   K.int_shape(x)[channel_axis],
                   1,
                   activation=None,
                   use_bias=True,
                   name='{block_name}_conv'.format(block_name=block_name))

    x = Lambda(lambda inputs, scale_: inputs[0] + inputs[1] * scale_,
               output_shape=K.int_shape(x)[1:],
               arguments={'scale_': scale},
               name=block_name)([x, up])
    if activation is not None:
        x = Activation(activation, name='{block_name}_ac'.format(block_name=block_name))(x)

    return x

# %%
def Inception_ResNet_v2(input_shape=None, weight_decay=weight_decay, classes=classes, name=None):
 
    img_input = Input(shape=input_shape)


    # Stem block: 35 x 35 x 192
    x = conv2d_bn(img_input, 32, 3, strides=2, padding='valid')
    x = conv2d_bn(x, 32, 3, padding='valid')
    x = conv2d_bn(x, 64, 3)
    x = MaxPooling2D(3, strides=2)(x)
    x = conv2d_bn(x, 80, 1, padding='valid')
    x = conv2d_bn(x, 192, 3, padding='valid')
    x = MaxPooling2D(3, strides=2)(x)

    # Mixed 5b (Inception-A block): 35 x 35 x 320
    branch_0 = conv2d_bn(x, 96, 1)
    branch_1 = conv2d_bn(x, 48, 1)
    branch_1 = conv2d_bn(branch_1, 64, 5)
    branch_2 = conv2d_bn(x, 64, 1)
    branch_2 = conv2d_bn(branch_2, 96, 3)
    branch_2 = conv2d_bn(branch_2, 96, 3)
    branch_pool = AveragePooling2D(3, strides=1, padding='same')(x)
    branch_pool = conv2d_bn(branch_pool, 64, 1)
    branches = [branch_0, branch_1, branch_2, branch_pool]
    channel_axis = 3
    x = Concatenate(axis=channel_axis, name='mixed_5b')(branches)


    # 10x block35 (Inception-ResNet-A block): 35 x 35 x 320
    for block_idx in range(1, 11):
        x = inception_resnet_block(x,
                                   scale=0.17,
                                   block_type='block35',
                                   block_idx=block_idx)

    # Mixed 6a (Reduction-A block): 17 x 17 x 1088
    branch_0 = conv2d_bn(x, 384, 3, strides=2, padding='valid')
    branch_1 = conv2d_bn(x, 256, 1)
    branch_1 = conv2d_bn(branch_1, 256, 3)
    branch_1 = conv2d_bn(branch_1, 384, 3, strides=2, padding='valid')
    branch_pool = MaxPooling2D(3, strides=2, padding='valid')(x)
    branches = [branch_0, branch_1, branch_pool]
    x = Concatenate(axis=channel_axis, name='mixed_6a')(branches)


    # 20x block17 (Inception-ResNet-B block): 17 x 17 x 1088
    for block_idx in range(1, 21):
        x = inception_resnet_block(x,
                                   scale=0.1,
                                   block_type='block17',
                                   block_idx=block_idx)

    # Mixed 7a (Reduction-B block): 8 x 8 x 2080
    branch_0 = conv2d_bn(x, 256, 1)
    branch_0 = conv2d_bn(branch_0, 384, 3, strides=2, padding='valid')
    branch_1 = conv2d_bn(x, 256, 1)
    branch_1 = conv2d_bn(branch_1, 288, 3, strides=2, padding='valid')
    branch_2 = conv2d_bn(x, 256, 1)
    branch_2 = conv2d_bn(branch_2, 288, 3)
    branch_2 = conv2d_bn(branch_2, 320, 3, strides=2, padding='valid')
    branch_pool = MaxPooling2D(3, strides=2, padding='valid')(x)
    branches = [branch_0, branch_1, branch_2, branch_pool]
    x = Concatenate(axis=channel_axis, name='mixed_7a')(branches)


    # 10x block8 (Inception-ResNet-C block): 8 x 8 x 2080
    for block_idx in range(1, 10):
        x = inception_resnet_block(x,
                                   scale=0.2,
                                   block_type='block8',
                                   block_idx=block_idx)
    x = inception_resnet_block(x,
                               scale=1.,
                               activation=None,
                               block_type='block8',
                               block_idx=10)

    # Final convolution block: 8 x 8 x 1536
    x = conv2d_bn(x, 1536, 1, name='conv_7b')

    x = GlobalAveragePooling2D(name='avg_pool')(x)
    x = Dense(classes, use_bias=False, kernel_regularizer=l2(weight_decay), activation='softmax', name='predictions')(x)

    # Ensure that the model takes into account
    # any potential predecessors of `input_tensor`
    inputs = img_input

    # Create model
    model = Model(inputs, x, name=name)

    return model

# %% [markdown]
# ### 2) Almost Original Inception-ResNet-V2

# %%
model = Inception_ResNet_v2(input_shape=input_sizes, weight_decay=weight_decay, classes=classes, name='Inception_ResNet_v2')

# %%
model.summary()
# Out:
# Model: "Inception_ResNet_v2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 299, 299, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 149, 149, 32) 864         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 149, 149, 32) 96          conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 149, 149, 32) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 147, 147, 32) 9216        activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 147, 147, 32) 96          conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 147, 147, 32) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 147, 147, 64) 18432       activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 147, 147, 64) 192         conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 147, 147, 64) 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 73, 73, 64)   0           activation_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 73, 73, 80)   5120        max_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 73, 73, 80)   240         conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 73, 73, 80)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 71, 71, 192)  138240      activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 71, 71, 192)  576         conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 71, 71, 192)  0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 35, 35, 192)  0           activation_4[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 35, 35, 64)   12288       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 35, 35, 64)   192         conv2d_8[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 35, 35, 64)   0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 35, 35, 48)   9216        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 35, 35, 96)   55296       activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 35, 35, 48)   144         conv2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 35, 35, 96)   288         conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 35, 35, 48)   0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 35, 35, 96)   0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# average_pooling2d (AveragePooli (None, 35, 35, 192)  0           max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 35, 35, 96)   18432       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 35, 35, 64)   76800       activation_6[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 35, 35, 96)   82944       activation_9[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 35, 35, 64)   12288       average_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 35, 35, 96)   288         conv2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 35, 35, 64)   192         conv2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 35, 35, 96)   288         conv2d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 35, 35, 64)   192         conv2d_11[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 35, 35, 96)   0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 35, 35, 64)   0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 35, 35, 96)   0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 35, 35, 64)   0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# mixed_5b (Concatenate)          (None, 35, 35, 320)  0           activation_5[0][0]
#                                                                  activation_7[0][0]
#                                                                  activation_10[0][0]
#                                                                  activation_11[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 35, 35, 32)   10240       mixed_5b[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 35, 35, 32)   96          conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 35, 35, 32)   0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 35, 35, 32)   10240       mixed_5b[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 35, 35, 48)   13824       activation_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 35, 35, 32)   96          conv2d_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 35, 35, 48)   144         conv2d_16[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 35, 35, 32)   0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 35, 35, 48)   0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 35, 35, 32)   10240       mixed_5b[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 35, 35, 32)   9216        activation_13[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 35, 35, 64)   27648       activation_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 35, 35, 32)   96          conv2d_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 35, 35, 32)   96          conv2d_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 35, 35, 64)   192         conv2d_17[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 35, 35, 32)   0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 35, 35, 32)   0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 35, 35, 64)   0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# block35_1_mixed (Concatenate)   (None, 35, 35, 128)  0           activation_12[0][0]
#                                                                  activation_14[0][0]
#                                                                  activation_17[0][0]
# __________________________________________________________________________________________________
# block35_1_conv (Conv2D)         (None, 35, 35, 320)  41280       block35_1_mixed[0][0]
# __________________________________________________________________________________________________
# block35_1 (Lambda)              (None, 35, 35, 320)  0           mixed_5b[0][0]
#                                                                  block35_1_conv[0][0]
# __________________________________________________________________________________________________
# block35_1_ac (Activation)       (None, 35, 35, 320)  0           block35_1[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 35, 35, 32)   10240       block35_1_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 35, 35, 32)   96          conv2d_21[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 35, 35, 32)   0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 35, 35, 32)   10240       block35_1_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 35, 35, 48)   13824       activation_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 35, 35, 32)   96          conv2d_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 35, 35, 48)   144         conv2d_22[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 35, 35, 32)   0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 35, 35, 48)   0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 35, 35, 32)   10240       block35_1_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 35, 35, 32)   9216        activation_19[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 35, 35, 64)   27648       activation_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 35, 35, 32)   96          conv2d_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 35, 35,
mixed (Concatenate)   (None, 35, 35, 128)  0           activation_54[0][0]
#                                                                  activation_56[0][0]
#                                                                  activation_59[0][0]
# __________________________________________________________________________________________________
# block35_8_conv (Conv2D)         (None, 35, 35, 320)  41280       block35_8_mixed[0][0]
# __________________________________________________________________________________________________
# block35_8 (Lambda)              (None, 35, 35, 320)  0           block35_7_ac[0][0]
#                                                                  block35_8_conv[0][0]
# __________________________________________________________________________________________________
# block35_8_ac (Activation)       (None, 35, 35, 320)  0           block35_8[0][0]
# __________________________________________________________________________________________________
# conv2d_63 (Conv2D)              (None, 35, 35, 32)   10240       block35_8_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_63 (BatchNo (None, 35, 35, 32)   96          conv2d_63[0][0]
# __________________________________________________________________________________________________
# activation_63 (Activation)      (None, 35, 35, 32)   0           batch_normalization_63[0][0]
# __________________________________________________________________________________________________
# conv2d_61 (Conv2D)              (None, 35, 35, 32)   10240       block35_8_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_64 (Conv2D)              (None, 35, 35, 48)   13824       activation_63[0][0]
# __________________________________________________________________________________________________
# batch_normalization_61 (BatchNo (None, 35, 35, 32)   96          conv2d_61[0][0]
# __________________________________________________________________________________________________
# batch_normalization_64 (BatchNo (None, 35, 35, 48)   144         conv2d_64[0][0]
# __________________________________________________________________________________________________
# activation_61 (Activation)      (None, 35, 35, 32)   0           batch_normalization_61[0][0]
# __________________________________________________________________________________________________
# activation_64 (Activation)      (None, 35, 35, 48)   0           batch_normalization_64[0][0]
# __________________________________________________________________________________________________
# conv2d_60 (Conv2D)              (None, 35, 35, 32)   10240       block35_8_ac[0][0]
# __________________________________________________________________________________________________
# ...
# __________________________________________________________________________________________________
# activation_183 (Activation)     (None, 8, 8, 192)    0           batch_normalization_183[0][0]
# __________________________________________________________________________________________________
# activation_186 (Activation)     (None, 8, 8, 256)    0           batch_normalization_186[0][0]
# __________________________________________________________________________________________________
# block8_6_mixed (Concatenate)    (None, 8, 8, 448)    0           activation_183[0][0]
#                                                                  activation_186[0][0]
# __________________________________________________________________________________________________
# block8_6_conv (Conv2D)          (None, 8, 8, 2080)   933920      block8_6_mixed[0][0]
# __________________________________________________________________________________________________
# block8_6 (Lambda)               (None, 8, 8, 2080)   0           block8_5_ac[0][0]
#                                                                  block8_6_conv[0][0]
# __________________________________________________________________________________________________
# block8_6_ac (Activation)        (None, 8, 8, 2080)   0           block8_6[0][0]
# __________________________________________________________________________________________________
# conv2d_188 (Conv2D)             (None, 8, 8, 192)    399360      block8_6_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_188 (BatchN (None, 8, 8, 192)    576         conv2d_188[0][0]
# __________________________________________________________________________________________________
# activation_188 (Activation)     (None, 8, 8, 192)    0           batch_normalization_188[0][0]
# __________________________________________________________________________________________________
# conv2d_189 (Conv2D)             (None, 8, 8, 224)    129024      activation_188[0][0]
# __________________________________________________________________________________________________
# batch_normalization_189 (BatchN (None, 8, 8, 224)    672         conv2d_189[0][0]
# __________________________________________________________________________________________________
# activation_189 (Activation)     (None, 8, 8, 224)    0           batch_normalization_189[0][0]
# __________________________________________________________________________________________________
# conv2d_187 (Conv2D)             (None, 8, 8, 192)    399360      block8_6_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_190 (Conv2D)             (None, 8, 8, 256)    172032      activation_189[0][0]
# __________________________________________________________________________________________________
# batch_normalization_187 (BatchN (None, 8, 8, 192)    576         conv2d_187[0][0]
# __________________________________________________________________________________________________
# batch_normalization_190 (BatchN (None, 8, 8, 256)    768         conv2d_190[0][0]
# __________________________________________________________________________________________________
# activation_187 (Activation)     (None, 8, 8, 192)    0           batch_normalization_187[0][0]
# __________________________________________________________________________________________________
# activation_190 (Activation)     (None, 8, 8, 256)    0           batch_normalization_190[0][0]
# __________________________________________________________________________________________________
# block8_7_mixed (Concatenate)    (None, 8, 8, 448)    0           activation_187[0][0]
#                                                                  activation_190[0][0]
# __________________________________________________________________________________________________
# block8_7_conv (Conv2D)          (None, 8, 8, 2080)   933920      block8_7_mixed[0][0]
# __________________________________________________________________________________________________
# block8_7 (Lambda)               (None, 8, 8, 2080)   0           block8_6_ac[0][0]
#                                                                  block8_7_conv[0][0]
# __________________________________________________________________________________________________
# block8_7_ac (Activation)        (None, 8, 8, 2080)   0           block8_7[0][0]
# __________________________________________________________________________________________________
# conv2d_192 (Conv2D)             (None, 8, 8, 192)    399360      block8_7_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_192 (BatchN (None, 8, 8, 192)    576         conv2d_192[0][0]
# __________________________________________________________________________________________________
# activation_192 (Activation)     (None, 8, 8, 192)    0           batch_normalization_192[0][0]
# __________________________________________________________________________________________________
# conv2d_193 (Conv2D)             (None, 8, 8, 224)    129024      activation_192[0][0]
# __________________________________________________________________________________________________
# batch_normalization_193 (BatchN (None, 8, 8, 224)    672         conv2d_193[0][0]
# __________________________________________________________________________________________________
# activation_193 (Activation)     (None, 8, 8, 224)    0           batch_normalization_193[0][0]
# __________________________________________________________________________________________________
# conv2d_191 (Conv2D)             (None, 8, 8, 192)    399360      block8_7_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_194 (Conv2D)             (None, 8, 8, 256)    172032      activation_193[0][0]
# __________________________________________________________________________________________________
# batch_normalization_191 (BatchN (None, 8, 8, 192)    576         conv2d_191[0][0]
# __________________________________________________________________________________________________
# batch_normalization_194 (BatchN (None, 8, 8, 256)    768         conv2d_194[0][0]
# __________________________________________________________________________________________________
# activation_191 (Activation)     (None, 8, 8, 192)    0           batch_normalization_191[0][0]
# __________________________________________________________________________________________________
# activation_194 (Activation)     (None, 8, 8, 256)    0           batch_normalization_194[0][0]
# __________________________________________________________________________________________________
# block8_8_mixed (Concatenate)    (None, 8, 8, 448)    0           activation_191[0][0]
#                                                                  activation_194[0][0]
# __________________________________________________________________________________________________
# block8_8_conv (Conv2D)          (None, 8, 8, 2080)   933920      block8_8_mixed[0][0]
# __________________________________________________________________________________________________
# block8_8 (Lambda)               (None, 8, 8, 2080)   0           block8_7_ac[0][0]
#                                                                  block8_8_conv[0][0]
# __________________________________________________________________________________________________
# block8_8_ac (Activation)        (None, 8, 8, 2080)   0           block8_8[0][0]
# __________________________________________________________________________________________________
# conv2d_196 (Conv2D)             (None, 8, 8, 192)    399360      block8_8_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_196 (BatchN (None, 8, 8, 192)    576         conv2d_196[0][0]
# __________________________________________________________________________________________________
# activation_196 (Activation)     (None, 8, 8, 192)    0           batch_normalization_196[0][0]
# __________________________________________________________________________________________________
# conv2d_197 (Conv2D)             (None, 8, 8, 224)    129024      activation_196[0][0]
# __________________________________________________________________________________________________
# batch_normalization_197 (BatchN (None, 8, 8, 224)    672         conv2d_197[0][0]
# __________________________________________________________________________________________________
# activation_197 (Activation)     (None, 8, 8, 224)    0           batch_normalization_197[0][0]
# __________________________________________________________________________________________________
# conv2d_195 (Conv2D)             (None, 8, 8, 192)    399360      block8_8_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_198 (Conv2D)             (None, 8, 8, 256)    172032      activation_197[0][0]
# __________________________________________________________________________________________________
# batch_normalization_195 (BatchN (None, 8, 8, 192)    576         conv2d_195[0][0]
# __________________________________________________________________________________________________
# batch_normalization_198 (BatchN (None, 8, 8, 256)    768         conv2d_198[0][0]
# __________________________________________________________________________________________________
# activation_195 (Activation)     (None, 8, 8, 192)    0           batch_normalization_195[0][0]
# __________________________________________________________________________________________________
# activation_198 (Activation)     (None, 8, 8, 256)    0           batch_normalization_198[0][0]
# __________________________________________________________________________________________________
# block8_9_mixed (Concatenate)    (None, 8, 8, 448)    0           activation_195[0][0]
#                                                                  activation_198[0][0]
# __________________________________________________________________________________________________
# block8_9_conv (Conv2D)          (None, 8, 8, 2080)   933920      block8_9_mixed[0][0]
# __________________________________________________________________________________________________
# block8_9 (Lambda)               (None, 8, 8, 2080)   0           block8_8_ac[0][0]
#                                                                  block8_9_conv[0][0]
# __________________________________________________________________________________________________
# block8_9_ac (Activation)        (None, 8, 8, 2080)   0           block8_9[0][0]
# __________________________________________________________________________________________________
# conv2d_200 (Conv2D)             (None, 8, 8, 192)    399360      block8_9_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_200 (BatchN (None, 8, 8, 192)    576         conv2d_200[0][0]
# __________________________________________________________________________________________________
# activation_200 (Activation)     (None, 8, 8, 192)    0           batch_normalization_200[0][0]
# __________________________________________________________________________________________________
# conv2d_201 (Conv2D)             (None, 8, 8, 224)    129024      activation_200[0][0]
# __________________________________________________________________________________________________
# batch_normalization_201 (BatchN (None, 8, 8, 224)    672         conv2d_201[0][0]
# __________________________________________________________________________________________________
# activation_201 (Activation)     (None, 8, 8, 224)    0           batch_normalization_201[0][0]
# __________________________________________________________________________________________________
# conv2d_199 (Conv2D)             (None, 8, 8, 192)    399360      block8_9_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_202 (Conv2D)             (None, 8, 8, 256)    172032      activation_201[0][0]
# __________________________________________________________________________________________________
# batch_normalization_199 (BatchN (None, 8, 8, 192)    576         conv2d_199[0][0]
# __________________________________________________________________________________________________
# batch_normalization_202 (BatchN (None, 8, 8, 256)    768         conv2d_202[0][0]
# __________________________________________________________________________________________________
# activation_199 (Activation)     (None, 8, 8, 192)    0           batch_normalization_199[0][0]
# __________________________________________________________________________________________________
# activation_202 (Activation)     (None, 8, 8, 256)    0           batch_normalization_202[0][0]
# __________________________________________________________________________________________________
# block8_10_mixed (Concatenate)   (None, 8, 8, 448)    0           activation_199[0][0]
#                                                                  activation_202[0][0]
# __________________________________________________________________________________________________
# block8_10_conv (Conv2D)         (None, 8, 8, 2080)   933920      block8_10_mixed[0][0]
# __________________________________________________________________________________________________
# block8_10 (Lambda)              (None, 8, 8, 2080)   0           block8_9_ac[0][0]
#                                                                  block8_10_conv[0][0]
# __________________________________________________________________________________________________
# conv_7b (Conv2D)                (None, 8, 8, 1536)   3194880     block8_10[0][0]
# __________________________________________________________________________________________________
# conv_7b_bn (BatchNormalization) (None, 8, 8, 1536)   4608        conv_7b[0][0]
# __________________________________________________________________________________________________
# conv_7b_ac (Activation)         (None, 8, 8, 1536)   0           conv_7b_bn[0][0]
# __________________________________________________________________________________________________
# avg_pool (GlobalAveragePooling2 (None, 1536)         0           conv_7b_ac[0][0]
# __________________________________________________________________________________________________
# predictions (Dense)             (None, 257)          394752      avg_pool[0][0]
# ==================================================================================================
# Total params: 54,731,488
# Trainable params: 54,670,944
# Non-trainable params: 60,544
# __________________________________________________________________________________________________

# %%
# 폴더 생성

os.makedirs(os.path.join(dir,'model_output',number,model.name), exist_ok=True)
os.makedirs(os.path.join(dir,'train_valid_output',number), exist_ok=True)

# %%
# 참고 : https://github.com/OverLordGoldDragon/keras-adamw

import sys
sys.path.append('/content/drive/My Drive/Colab Notebooks/Paper')
import utils
import optimizers_v2
from utils import get_weight_decays, fill_dict_in_order
from utils import reset_seeds, K_eval
from optimizers_v2 import AdamW, NadamW, SGDW

# %%
# top-5 accuracy 출력
import functools
top5_acc = functools.partial(ks.metrics.top_k_categorical_accuracy, k=5)
top5_acc.__name__ = 'top5_acc'

# %%
#optimizer = SGDW(model=model, use_cosine_annealing=False, total_iterations = len(x_train) // batch_sizes, nesterov=True, momentum=0.9)
optimizer = AdamW(model=model, use_cosine_annealing=False, total_iterations = len(x_train) // batch_sizes)
#optimizer = Adam()
filepath =  os.path.join(dir,'model_output',number,model.name,'{epoch:03d}.h5')

callbacks_list = [ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_weights_only=False, save_best_only=True, mode='min'),
                  ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_weights_only=False, save_best_only=True, mode='max'),
                  #ReduceLROnPlateau(monitor='val_loss',patience=3,factor=0.1,min_lr=1e-5),
                  LearningRateScheduler(lr_schedule,verbose=1)
                  ]
                  
model.compile(optimizer, loss = 'categorical_crossentropy', metrics=['accuracy',top5_acc,macro_f1score])

# %%
######## flow_from_directory
history = model.fit(train_generator, steps_per_epoch=int(len(x_train)/batch_sizes),  validation_data = valid_generator, epochs=epochs , verbose=1 , callbacks = callbacks_list , validation_steps=int(len(x_valid)/batch_sizes))
# Out:
# Learning rate:  0.001
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 1/70
# 0.0(L1), 3.6155078020383335e-05(L2) weight decay set for conv2d/kernel:0
# 0.0(L1), 3.6155078020383335e-05(L2) weight decay set for conv2d_1/kernel:0
# 0.0(L1), 3.6155078020383335e-05(L2) weight decay set for conv2d_2/kernel:0
# 0.0(L1), 3.6155078020383335e-05(L2) weight decay set for conv2d_3/kernel:0
# 0.0(L1), 3.6155078020383335e-05(L2) weight decay set for conv2d_4/kernel:0
# 0.0(L1), 3.6155078020383335e-05(L2) weight decay set for conv2d_8/kernel:0
# 0.0(L1), 3.6155078020383335e-05(L2) weight decay set for conv2d_6/kernel:0
# 0.0(L1), 3.6155078020383335e-05(L2) weight decay set for conv2d_9/kernel:0
# 0.0(L1), 3.6155078020383335e-05(L2) weight decay set for conv2d_5/kernel:0
# 0.0(L1), 3.6155078020383335e-05(L2) weight decay set for conv2d_7/kernel:0
# 0.0(L1), 3.6155078020383335e-05(L2) weight decay set for conv2d_10/kernel:0
# 0.0(L1), 3.6155078020383335e-05(L2) weight decay set for conv2d_11/kernel:0
# 0.0(L1), 3.6155078020383335e-05(L2) weight decay set for conv2d_15/kernel:0
# 0.0(L1), 3.6155078020383335e-05(L2) weight decay set for conv2d_13/kernel:0
# 0.0(L1), 3.6155078020383335e-05(L2) weight decay set for conv2d_16/kernel:0
# 0.0(L1), 3.6155078020383335e-05(L2) weight decay set for conv2d_12/kernel:0
# 0.0(L1), 3.6155078020383335e-05(L2) weight decay set for conv2d_14/kernel:0
# 0.0(L1), 3.6155078020383335e-05(L2) weight decay set for conv2d_17/kernel:0
# 0.0(L1), 3.6155078020383335e-05(L2) weight decay set for block35_1_conv/kernel:0
# 0.0(L1), 3.6155078020383335e-05(L2) weight decay set for conv2d_21/kernel:0
# 0.0(L1), 3.6155078020383335e-05(L2) weight decay set for conv2d_19/kernel:0
# 0.0(L1), 3.6155078020383335e-05(L2) weight decay set for conv2d_22/kernel:0
# 0.0(L1), 3.6155078020383335e-05(L2) weight decay set for conv2d_18/kernel:0
# 0.0(L1), 3.6155078020383335e-05(L2) weight decay set for conv2d_20/kernel:0
# 0.0(L1), 3.6155078020383335e-05(L2) weight decay set for conv2d_23/kernel:0
# 0.0(L1), 3.6155078020383335e-05(L2) weight decay set for block35_2_conv/kernel:0
# 0.0(L1), 3.6155078020383335e-05(L2) weight decay set for conv2d_27/kernel:0
# 0.0(L1), 3.6155078020383335e-05(L2) weight decay set for conv2d_25/kernel:0
# 0.0(L1), 3.6155078020383335e-05(L2) weight decay set for conv2d_28/kernel:0
# 0.0(L1), 3.6155078020383335e-05(L2) weight decay set for conv2d_24/kernel:0
# 0.0(L1), 3.6155078020383335e-05(L2) weight decay set for conv2d_26/kernel:0
# 0.0(L1), 3.6155078020383335e-05(L2) weight decay set for conv2d_29/kernel:0
# 0.0(L1), 3.6155078020383335e-05(L2) weight decay set for block35_3_conv/kernel:0
# 0.0(L1), 3.6155078020383335e-05(L2) weight decay set for conv2d_33/kernel:0
# 0.0(L1), 3.6155078020383335e-05(L2) weight decay set for conv2d_31/kernel:0
# 0.0(L1), 3.6155078020383335e-05(L2) weight decay set for conv2d_34/kernel:0
# 0.0(L1), 3.6155078020383335e-05(L2) weight decay set for conv2d_30/kernel:0
# 0.0(L1), 3.6155078020383335e-05(L2) weight decay set for conv2d_32/kernel:0
# 0.0(L1), 3.6155078020383335e-05(L2) weight decay set for conv2d_35/kernel:0
# 0.0(L1), 3.6155078020383335e-05(L2) weight decay set for block35_4_conv/kernel:0
# 0.0(L1), 3.6155078020383335e-05(L2) weight decay set for conv2d_39/kernel:0
# 0.0(L1), 3.6155078020383335e-05(L2) weight decay set for conv2d_37/kernel:0
# 0.0(L1), 3.6155078020383335e-05(L2) weight decay set for conv2d_40/kernel:0
# 0.0(L1), 3.6155078020383335e-05(L2) weight decay set for conv2d_36/kernel:0
# 0.0(L1), 3.6155078020383335e-05(L2) weight decay set for conv2d_38/kernel:0
# 0.0(L1), 3.6155078020383335e-05(L2) weight decay set for conv2d_41/kernel:0
# 0.0(L1), 3.6155078020383335e-05(L2) weight decay set for block35_5_conv/kernel:0
# 0.0(L1), 3.6155078020383335e-05(L2) weight decay set for conv2d_45/kernel:0
# 0.0(L1), 3.6155078020383335e-05(L2) weight decay set for conv2d_43/kernel:0
# 0.0(L1), 3.6155078020383335e-05(L2) weight decay set for conv2d_46/kernel:0
# 0.0(L1), 3.6155078020383335e-05(L2) weight decay set for conv2d_42/kernel:0
# 0.0(L1), 3.6155078020383335e-05(L2) weight decay set for conv2d_44/kernel:0
# 0.0(L1), 3.6155078020383335e-05(L2) weight decay set for conv2d_47/kernel:0
# 0.0(L1), 3.6155078020383335e-05(L2) weight decay set for block35_6_conv/kernel:0
# 0.0(L1), 3.6155078020383335e-05(L2) weight decay set for conv2d_51/kernel:0
# 0.0(L1), 3.6155078020383335e-05(L2) weight decay set for conv2d_49/kernel:0
# 0.0(L1), 3.6155078020383335e-05(L2) weight decay set for conv2d_52/kernel:0
# 0.0(L1), 3.6155078020383335e-05(L2) weight decay set for conv2d_48/kernel:0
# 0.0(L1), 3.6155078020383335e-05(L2) weight decay set for conv2d_50/kernel:0
# 0.0(L1), 3.6155078020383335e-05(L2) weight decay set for conv2d_53/kernel:0
# 0.0(L1), 3.6155078020383335e-05(L2) weight decay set for block35_7_conv/kernel:0
# 0.0(L1), 3.6155078020383335e-05(L2) weight decay set for conv2d_57/kernel:0
# 0.0(L1), 3.6155078020383335e-05(L2) weight decay set for conv2d_55/kernel:0
# 0.0(L1), 3.6155078020383335e-05(L2) weight decay set for conv2d_58/kernel:0
# 0.0(L1), 3.6155078020383335e-05(L2) weight decay set for conv2d_54/kernel:0
# 0.0(L1), 3.6155078020383335e-05(L2) weight decay set for conv2d_56/kernel:0
# 0.0(L1), 3.6155078020383335e-05(L2) weight decay set for conv2d_59/kernel:0
# 0.0(L1), 3.6155078020383335e-05(L2) weight decay set for block35_8_conv/kernel:0
# 0.0(L1), 3.6155078020383335e-05(L2) weight decay set for conv2d_63/kernel:0
# 0.0(L1), 3.6155078020383335e-05(L2) weight decay set for conv2d_61/kernel:0
# 0.0(L1), 3.6155078020383335e-05(L2) weight decay set for conv2d_64/kernel:0
# 0.0(L1), 3.6155078020383335e-05(L2) weight decay set for conv2d_60/kernel:0
# 0.0(L1), 3.6155078020383335e-05(L2) weight decay set for conv2d_62/kernel:0
# 0.0(L1), 3.6155078020383335e-05(L2) weight decay set for conv2d_65/kernel:0
# 0.0(L1), 3.6155078020383335e-05(L2) weight decay set for block35_9_conv/kernel:0
# 0.0(L1), 3.6155078020383335e-05(L2) weight decay set for conv2d_69/kernel:0
# 0.0(L1), 3.6155078020383335e-05(L2) weight decay set for conv2d_67/kernel:0
# 0.0(L1), 3.6155078020383335e-05(L2) weight decay set for conv2d_70/kernel:0
# 0.0(L1), 3.6155078020383335e-05(L2) weight decay set for conv2d_66/kernel:0
# 0.0(L1), 3.6155078020383335e-05(L2) weight decay set for conv2d_68/kernel:0
# 0.0(L1), 3.6155078020383335e-05(L2) weight decay set for conv2d_71/kernel:0
# 0.0(L1), 3.6155078020383335e-05(L2) weight decay set for block35_10_conv/kernel:0
# 0.0(L1), 3.6155078020383335e-05(L2) weight decay set for conv2d_73/kernel:0
# 0.0(L1), 3.6155078020383335e-05(L2) weight decay set for conv2d_74/kernel:0
# 0.0(L1), 3.6155078020383335e-05(L2) weight decay set for conv2d_72/kernel:0
# 0.0(L1), 3.6155078020383335e-05(L2) weight decay set for conv2d_75/kernel:0
# 0.0(L1), 3.6155078020383335e-05(L2) weight decay set for conv2d_77/kernel:0
# 0.0(L1), 3.6155078020383335e-05(L2) weight decay set for conv2d_78/kernel:0
# 0.0(L1), 3.6155078020383335e-05(L2) weight decay set for conv2d_76/kernel:0
# 0.0(L1), 3.6155078020383335e-05(L2) weight decay set for conv2d_79/kernel:0
# 0.0(L1), 3.6155078020383335e-05(L2) weight decay set for block17_1_conv/kernel:0
# 0.0(L1), 3.6155078020383335e-05(L2) weight decay set for conv2d_81/kernel:0
# 0.0(L1), 3.6155078020383335e-05(L2) weight decay set for conv2d_82/kernel:0
# 0.0(L1), 3.6155078020383335e-05(L2) weight decay set for conv2d_80/kernel:0
# 0.0(L1), 3.6155078020383335e-05(L2) weight decay set for conv2d_83/kernel:0
# 0.0(L1), 3.6155078020383335e-05(L2) weight decay set for block17_2_conv/kernel:0
# 0.0(L1), 3.6155078020383335e-05(L2) weight decay set for conv2d_85/kernel:0
# 0.0(L1), 3.6155078020383335e-05(L2) weight decay set for conv2d_86/kernel:0
# 0.0(L1), 3.6155078020383335e-05(L2) weight decay set for conv2d_84/kernel:0
# 0.0(L1), 3.6155078020383335e-05(L2) weight decay set for conv2d_87/kernel:0
# 0.0(L1), 3.6155078020383335e-05(L2) weight decay set for block17_3_conv/kernel:0
# 0.0(L1), 3.6155078020383335e-05(L2) weight decay set for conv2d_89/kernel:0
# 0.0(L1), 3.6155078020383335e-05(L2) weight decay set for conv2d_90/kernel:0
# 0.0(L1), 3.6155078020383335e-05(L2) weight decay set for conv2d_88/kernel:0
# 0.0(L1), 3.6155078020383335e-05(L2) weight decay set for conv2d_91/kernel:0
# 0.0(L1), 3.6155078020383335e-05(L2) weight decay set for block17_4_conv/kernel:0
# 0.0(L1), 3.6155078020383335e-05(L2) weight decay set for conv2d_93/kernel:0
# 0.0(L1), 3.6155078020383335e-05(L2) weight decay set for conv2d_94/kernel:0
# 0.0(L1), 3.6155078020383335e-05(L2) weight decay set for conv2d_92/kernel:0
# 0.0(L1), 3.6155078020383335e-05(L2) weight decay set for conv2d_95/kernel:0
# 0.0(L1), 3.6155078020383335e-05(L2) weight decay set for block17_5_conv/kernel:0
# 0.0(L1), 3.6155078020383335e-05(L2) weight decay set for conv2d_97/kernel:0
# 0.0(L1), 3.6155078020383335e-05(L2) weight decay set for conv2d_98/kernel:0
# 0.0(L1), 3.6155078020383335e-05(L2) weight decay set for conv2d_96/kernel:0
# 0.0(L1), 3.6155078020383335e-05(L2) weight decay set for conv2d_99/kernel:0
# 0.0(L1), 3.6155078020383335e-05(L2) weight decay set for block17_6_conv/kernel:0
# 0.0(L1), 3.6155078020383335e-05(L2) weight decay set for conv2d_101/kernel:0
# 0.0(L1), 3.6155078020383335e-05(L2) weight decay set for conv2d_102/kernel:0
# 0.0(L1), 3.6155078020383335e-05(L2) weight decay set for conv2d_100/kernel:0
# 0.0(L1), 3.6155078020383335e-05(L2) weight decay set for conv2d_103/kernel:0
# 0.0(L1), 3.6155078020383335e-05(L2) weight decay set for block17_7_conv/kernel:0
# 0.0(L1), 3.6155078020383335e-05(L2) weight decay set for conv2d_105/kernel:0
# 0.0(L1), 3.6155078020383335e-05(L2) weight decay set for conv2d_106/kernel:0
# 0.0(L1), 3.6155078020383335e-05(L2) weight decay set for conv2d_104/kernel:0
# 0.0(L1), 3.6155078020383335e-05(L2) weight decay set for conv2d_107/kernel:0
# 0.0(L1), 3.6155078020383335e-05(L2) weight decay set for block17_8_conv/kernel:0
# 0.0(L1), 3.6155078020383335e-05(L2) weight decay set for conv2d_109/kernel:0
# 0.0(L1), 3.6155078020383335e-05(L2) weight decay set for conv2d_110/kernel:0
# 0.0(L1), 3.6155078020383335e-05(L2) weight decay set for conv2d_108/kernel:0
# 0.0(L1), 3.6155078020383335e-05(L2) weight decay set for conv2d
saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_ResNet_v2/004.h5
# 765/765 [==============================] - 725s 948ms/step - loss: 3.5660 - accuracy: 0.2478 - top5_acc: 0.4526 - macro_f1score: 0.0097 - val_loss: 3.6161 - val_accuracy: 0.2490 - val_top5_acc: 0.4640 - val_macro_f1score: 0.0115
# Learning rate:  0.001
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 5/70
# 765/765 [==============================] - ETA: 0s - loss: 3.1713 - accuracy: 0.3126 - top5_acc: 0.5356 - macro_f1score: 0.0147
# Epoch 00005: val_loss improved from 3.61608 to 3.48649, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_ResNet_v2/005.h5
#
# Epoch 00005: val_accuracy improved from 0.24899 to 0.29301, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_ResNet_v2/005.h5
# 765/765 [==============================] - 723s 945ms/step - loss: 3.1713 - accuracy: 0.3126 - top5_acc: 0.5356 - macro_f1score: 0.0147 - val_loss: 3.4865 - val_accuracy: 0.2930 - val_top5_acc: 0.5155 - val_macro_f1score: 0.0186
# Learning rate:  0.001
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 6/70
# 765/765 [==============================] - ETA: 0s - loss: 2.7943 - accuracy: 0.3734 - top5_acc: 0.6087 - macro_f1score: 0.0212
# Epoch 00006: val_loss improved from 3.48649 to 2.88657, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_ResNet_v2/006.h5
#
# Epoch 00006: val_accuracy improved from 0.29301 to 0.37769, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_ResNet_v2/006.h5
# 765/765 [==============================] - 721s 943ms/step - loss: 2.7943 - accuracy: 0.3734 - top5_acc: 0.6087 - macro_f1score: 0.0212 - val_loss: 2.8866 - val_accuracy: 0.3777 - val_top5_acc: 0.6089 - val_macro_f1score: 0.0255
# Learning rate:  0.001
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 7/70
# 765/765 [==============================] - ETA: 0s - loss: 2.4828 - accuracy: 0.4298 - top5_acc: 0.6757 - macro_f1score: 0.0278
# Epoch 00007: val_loss improved from 2.88657 to 2.83998, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_ResNet_v2/007.h5
#
# Epoch 00007: val_accuracy improved from 0.37769 to 0.38441, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_ResNet_v2/007.h5
# 765/765 [==============================] - 727s 950ms/step - loss: 2.4828 - accuracy: 0.4298 - top5_acc: 0.6757 - macro_f1score: 0.0278 - val_loss: 2.8400 - val_accuracy: 0.3844 - val_top5_acc: 0.6260 - val_macro_f1score: 0.0290
# Learning rate:  0.001
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 8/70
# 765/765 [==============================] - ETA: 0s - loss: 2.2184 - accuracy: 0.4838 - top5_acc: 0.7222 - macro_f1score: 0.0346
# Epoch 00008: val_loss improved from 2.83998 to 2.68987, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_ResNet_v2/008.h5
#
# Epoch 00008: val_accuracy improved from 0.38441 to 0.41734, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_ResNet_v2/008.h5
# 765/765 [==============================] - 729s 952ms/step - loss: 2.2184 - accuracy: 0.4838 - top5_acc: 0.7222 - macro_f1score: 0.0346 - val_loss: 2.6899 - val_accuracy: 0.4173 - val_top5_acc: 0.6475 - val_macro_f1score: 0.0320
# Learning rate:  0.001
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 9/70
# 765/765 [==============================] - ETA: 0s - loss: 1.9630 - accuracy: 0.5334 - top5_acc: 0.7657 - macro_f1score: 0.0417
# Epoch 00009: val_loss improved from 2.68987 to 2.58999, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_ResNet_v2/009.h5
#
# Epoch 00009: val_accuracy improved from 0.41734 to 0.43347, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_ResNet_v2/009.h5
# 765/765 [==============================] - 728s 952ms/step - loss: 1.9630 - accuracy: 0.5334 - top5_acc: 0.7657 - macro_f1score: 0.0417 - val_loss: 2.5900 - val_accuracy: 0.4335 - val_top5_acc: 0.6774 - val_macro_f1score: 0.0344
# Learning rate:  0.001
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.001.
# Epoch
saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_ResNet_v2/015.h5
# 765/765 [==============================] - 725s 947ms/step - loss: 0.9474 - accuracy: 0.7476 - top5_acc: 0.9216 - macro_f1score: 0.0737 - val_loss: 1.9804 - val_accuracy: 0.5615 - val_top5_acc: 0.7796 - val_macro_f1score: 0.0539
# Learning rate:  0.001
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 16/70
# 765/765 [==============================] - ETA: 0s - loss: 0.8050 - accuracy: 0.7838 - top5_acc: 0.9409 - macro_f1score: 0.0784
# Epoch 00016: val_loss did not improve from 1.98038
#
# Epoch 00016: val_accuracy did not improve from 0.56149
# 765/765 [==============================] - 717s 937ms/step - loss: 0.8050 - accuracy: 0.7838 - top5_acc: 0.9409 - macro_f1score: 0.0784 - val_loss: 2.1320 - val_accuracy: 0.5531 - val_top5_acc: 0.7675 - val_macro_f1score: 0.0558
# Learning rate:  0.001
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 17/70
# 765/765 [==============================] - ETA: 0s - loss: 0.7042 - accuracy: 0.8079 - top5_acc: 0.9521 - macro_f1score: 0.0822
# Epoch 00017: val_loss did not improve from 1.98038
#
# Epoch 00017: val_accuracy did not improve from 0.56149
# 765/765 [==============================] - 719s 940ms/step - loss: 0.7042 - accuracy: 0.8079 - top5_acc: 0.9521 - macro_f1score: 0.0822 - val_loss: 2.1365 - val_accuracy: 0.5598 - val_top5_acc: 0.7597 - val_macro_f1score: 0.0551
# Learning rate:  0.001
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 18/70
# 765/765 [==============================] - ETA: 0s - loss: 0.6183 - accuracy: 0.8294 - top5_acc: 0.9643 - macro_f1score: 0.0852
# Epoch 00018: val_loss did not improve from 1.98038
#
# Epoch 00018: val_accuracy improved from 0.56149 to 0.56754, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_ResNet_v2/018.h5
# 765/765 [==============================] - 724s 947ms/step - loss: 0.6183 - accuracy: 0.8294 - top5_acc: 0.9643 - macro_f1score: 0.0852 - val_loss: 2.1302 - val_accuracy: 0.5675 - val_top5_acc: 0.7796 - val_macro_f1score: 0.0575
# Learning rate:  0.001
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 19/70
# 765/765 [==============================] - ETA: 0s - loss: 0.5351 - accuracy: 0.8530 - top5_acc: 0.9720 - macro_f1score: 0.0891
# Epoch 00019: val_loss did not improve from 1.98038
#
# Epoch 00019: val_accuracy did not improve from 0.56754
# 765/765 [==============================] - 715s 935ms/step - loss: 0.5351 - accuracy: 0.8530 - top5_acc: 0.9720 - macro_f1score: 0.0891 - val_loss: 2.2349 - val_accuracy: 0.5605 - val_top5_acc: 0.7772 - val_macro_f1score: 0.0572
# Learning rate:  0.001
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 20/70
# 765/765 [==============================] - ETA: 0s - loss: 0.4654 - accuracy: 0.8702 - top5_acc: 0.9801 - macro_f1score: 0.0921
# Epoch 00020: val_loss did not improve from 1.98038
#
# Epoch 00020: val_accuracy improved from 0.56754 to 0.58703, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_ResNet_v2/020.h5
# 765/765 [==============================] - 722s 943ms/step - loss: 0.4654 - accuracy: 0.8702 - top5_acc: 0.9801 - macro_f1score: 0.0921 - val_loss: 2.0138 - val_accuracy: 0.5870 - val_top5_acc: 0.7913 - val_macro_f1score: 0.0598
# Learning rate:  0.001
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 0.001.
# Epoch
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 27/70
# 765/765 [==============================] - ETA: 0s - loss: 0.2634 - accuracy: 0.9254 - top5_acc: 0.9932 - macro_f1score: 0.1022
# Epoch 00027: val_loss did not improve from 1.98038
#
# Epoch 00027: val_accuracy improved from 0.58703 to 0.58938, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_ResNet_v2/027.h5
# 765/765 [==============================] - 722s 944ms/step - loss: 0.2634 - accuracy: 0.9254 - top5_acc: 0.9932 - macro_f1score: 0.1022 - val_loss: 2.2663 - val_accuracy: 0.5894 - val_top5_acc: 0.7752 - val_macro_f1score: 0.0629
# Learning rate:  0.001
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 28/70
# 765/765 [==============================] - ETA: 0s - loss: 0.2353 - accuracy: 0.9329 - top5_acc: 0.9946 - macro_f1score: 0.1033
# Epoch 00028: val_loss did not improve from 1.98038
#
# Epoch 00028: val_accuracy improved from 0.58938 to 0.59375, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_ResNet_v2/028.h5
# 765/765 [==============================] - 723s 945ms/step - loss: 0.2353 - accuracy: 0.9329 - top5_acc: 0.9946 - macro_f1score: 0.1033 - val_loss: 2.1957 - val_accuracy: 0.5938 - val_top5_acc: 0.7897 - val_macro_f1score: 0.0620
# Learning rate:  0.001
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 29/70
# 765/765 [==============================] - ETA: 0s - loss: 0.2105 - accuracy: 0.9399 - top5_acc: 0.9954 - macro_f1score: 0.1051
# Epoch 00029: val_loss did not improve from 1.98038
#
# Epoch 00029: val_accuracy improved from 0.59375 to 0.60081, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_ResNet_v2/029.h5
# 765/765 [==============================] - 730s 955ms/step - loss: 0.2105 - accuracy: 0.9399 - top5_acc: 0.9954 - macro_f1score: 0.1051 - val_loss: 2.2571 - val_accuracy: 0.6008 - val_top5_acc: 0.7987 - val_macro_f1score: 0.0642
# Learning rate:  0.001
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 30/70
# 765/765 [==============================] - ETA: 0s - loss: 0.2039 - accuracy: 0.9428 - top5_acc: 0.9965 - macro_f1score: 0.1052
# Epoch 00030: val_loss did not improve from 1.98038
#
# Epoch 00030: val_accuracy did not improve from 0.60081
# 765/765 [==============================] - 722s 943ms/step - loss: 0.2039 - accuracy: 0.9428 - top5_acc: 0.9965 - macro_f1score: 0.1052 - val_loss: 2.3080 - val_accuracy: 0.5867 - val_top5_acc: 0.7873 - val_macro_f1score: 0.0614
# Learning rate:  0.0001
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 31/70
# 765/765 [==============================] - ETA: 0s - loss: 0.0774 - accuracy: 0.9835 - top5_acc: 0.9992 - macro_f1score: 0.1114
# Epoch 00031: val_loss improved from 1.98038 to 1.53429, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_ResNet_v2/031.h5
#
# Epoch 00031: val_accuracy improved from 0.60081 to 0.68683, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_ResNet_v2/031.h5
# 765/765 [==============================] - 732s 956ms/step - loss: 0.0774 - accuracy: 0.9835 - top5_acc: 0.9992 - macro_f1score: 0.1114 - val_loss: 1.5343 - val_accuracy: 0.6868 - val_top5_acc: 0.8511 - val_macro_f1score: 0.0730
# Learning rate:  0.0001
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 32/70
# 765/765 [==============================] - ETA: 0s - loss: 0.0363 - accuracy: 0.9952 - top5_acc: 0.9999 - macro_f1score: 0.1135
# Epoch 00032: val_loss improved from 1.53429 to 1.48126, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_ResNet_v2/032.h5
#
# Epoch 00032: val_accuracy improved from 0.68683 to 0.69288, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_ResNet_v2/032.h5
# 765/765 [==============================] - 735s 961ms/step - loss: 0.0363 - accuracy: 0.9952 - top5_acc: 0.9999 - macro_f1score: 0.1135 - val_loss: 1.4813 - val_accuracy: 0.6929 - val_top5_acc: 0.8532 - val_macro_f1score: 0.0737
# Learning rate:  0.0001
#
# Epoch 00033: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 33/70
# 765/765 [==============================] - ETA: 0s - loss: 0.0276 - accuracy: 0.9971 - top5_acc: 1.0000 - macro_f1score: 0.1138
# Epoch 00033: val_loss improved from 1.48126 to 1.45666, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_ResNet_v2/033.h5
#
# Epoch 00033: val_accuracy improved from 0.69288 to 0.69724, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_ResNet_v2/033.h5
# 765/765 [==============================] - 736s 962ms/step - loss: 0.0276 - accuracy: 0.9971 - top5_acc: 1.0000 - macro_f1score: 0.1138 - val_loss: 1.4567 - val_accuracy: 0.6972 - val_top5_acc: 0.8599 - val_macro_f1score: 0.0741
# Learning rate:  0.0001
#
# Epoch 00034: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 34/70
# 765/765 [==============================] - ETA: 0s - loss: 0.0248 - accuracy: 0.9976 - top5_acc: 1.0000 - macro_f1score: 0.1138
# Epoch 00034: val_loss improved from 1.45666 to 1.45144, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_ResNet_v2/034.h5
#
# Epoch 00034: val_accuracy did not improve from 0.69724
# 765/765 [==============================] - 733s 958ms/step - loss: 0.0248 - accuracy: 0.9976 - top5_acc: 1.0000 - macro_f1score: 0.1138 - val_loss: 1.4514 - val_accuracy: 0.6935 - val_top5_acc: 0.8552 - val_macro_f1score: 0.0736
# Learning rate:  0.0001
#
# Epoch 00035: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 35/70
# 765/765 [==============================] - ETA: 0s - loss: 0.0213 - accuracy: 0.9984 - top5_acc: 1.0000 - macro_f1score: 0.1142
# Epoch 00035: val_loss improved from 1.45144 to 1.44204, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_ResNet_v2/035.h5
#
# Epoch 00035: val_accuracy improved from 0.69724 to 0.70161, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_ResNet_v2/035.h5
# 765/765 [==============================] - 739s 966ms/step - loss: 0.0213 - accuracy: 0.9984 - top5_acc: 1.0000 - macro_f1score: 0.1142 - val_loss: 1.4420 - val_accuracy: 0.7016 - val_top5_acc: 0.8569 - val_macro_f1score: 0.0734
# Learning rate:  0.0001
#
# Epoch 00036: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 36/70
# 765/765 [==============================] - ETA: 0s - loss: 0.0197 - accuracy: 0.9987 - top5_acc: 1.0000 - macro_f1score: 0.1145
# Epoch 00036: val_loss did not improve from 1.44204
#
# Epoch 00036: val_accuracy improved from 0.70161 to 0.70363, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_ResNet_v2/036.h5
# 765/765 [==============================] - 731s 955ms/step - loss: 0.0197 - accuracy: 0.9987 - top5_acc: 1.0000 - macro_f1score: 0.1145 - val_loss: 1.4573 - val_accuracy: 0.7036 - val_top5_acc: 0.8558 - val_macro_f1score: 0.0737
# Learning rate:  0.0001
#
# Epoch 00037: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 37/70
# 765/765 [==============================] - ETA: 0s - loss: 0.0184 - accuracy: 0.9987 - top5_acc: 1.0000 - macro_f1score: 0.1142
# Epoch 00037: val_loss improved from 1.44204 to 1.44173, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_ResNet_v2/037.h5
#
# Epoch 00037: val_accuracy did not improve from 0.70363
# 765/765 [==============================] - 730s 954ms/step - loss: 0.0184 - accuracy: 0.9987 - top5_acc: 1.0000 - macro_f1score: 0.1142 - val_loss: 1.4417 - val_accuracy: 0.7036 - val_top5_acc: 0.8629 - val_macro_f1score: 0.0752
# Learning rate:  0.0001
#
# Epoch 00038: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 38/70
# 765/765 [==============================] - ETA: 0s - loss: 0.0185 - accuracy: 0.9985 - top5_acc: 1.0000 - macro_f1score: 0.1143
# Epoch 00038: val_loss did not improve from 1.44173
#
# Epoch 00038: val_accuracy did not improve from 0.70363
# 765/765 [==============================] - 726s 949ms/step - loss: 0.0185 - accuracy: 0.9985 - top5_acc: 1.0000 - macro_f1score: 0.1143 - val_loss: 1.4436 - val_accuracy: 0.6999 - val_top5_acc: 0.8599 - val_macro_f1score: 0.0739
# Learning rate:  0.0001
#
# Epoch 00039: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 39/70
# 765/765 [==============================] - ETA: 0s - loss: 0.0168 - accuracy: 0.9991 - top5_acc: 1.0000 - macro_f1score: 0.1143
# Epoch 00039: val_loss improved from 1.44173 to 1.43104, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_ResNet_v2/039.h5
#
# Epoch 00039: val_accuracy did not improve from 0.70363
# 765/765 [==============================] - 727s 950ms/step - loss: 0.0168 - accuracy: 0.9991 - top5_acc: 1.0000 - macro_f1score: 0.1143 - val_loss: 1.4310 - val_accuracy: 0.7003 - val_top5_acc: 0.8572 - val_macro_f1score: 0.0734
# Learning rate:  0.0001
#
# Epoch 00040: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 40/70
# 765/765 [==============================] - ETA: 0s - loss: 0.0154 - accuracy: 0.9993 - top5_acc: 1.0000 - macro_f1score: 0.1145
# Epoch 00040: val_loss did not improve from 1.43104
#
# Epoch 00040: val_accuracy did not improve from 0.70363
# 765/765 [==============================] - 723s 945ms/step - loss: 0.0154 - accuracy: 0.9993 - top5_acc: 1.0000 - macro_f1score: 0.1145 - val_loss: 1.4453 - val_accuracy: 0.6996 - val_top5_acc: 0.8599 - val_macro_f1score: 0.0738
# Learning rate:  0.0001
#
# Epoch 00041: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 41/70
# 765/765 [==============================] - ETA: 0s - loss: 0.0137 - accuracy: 0.9995 - top5_acc: 1.0000 - macro_f1score: 0.1141
# Epoch 00041: val_loss did not improve from 1.43104
#
# Epoch 00041: val_accuracy did not improve from 0.70363
# 765/765 [==============================] - 721s 942ms/step - loss: 0.0137 - accuracy: 0.9995 - top5_acc: 1.0000 - macro_f1score: 0.1141 - val_loss: 1.4455 - val_accuracy: 0.6989 - val_top5_acc: 0.8585 - val_macro_f1score: 0.0738
# Learning rate:  0.0001
#
# Epoch 00042: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 42/70
# 765/765 [==============================] - ETA: 0s - loss: 0.0138 - accuracy: 0.9996 - top5_acc: 1.0000 - macro_f1score: 0.1140
# Epoch 00042: val_loss did not improve from 1.43104
#
# Epoch 00042: val_accuracy did not improve from 0.70363
# ...
# Epoch 46/70
# 765/765 [==============================] - ETA: 0s - loss: 0.0134 - accuracy: 0.9993 - top5_acc: 1.0000 - macro_f1score: 0.1145
# Epoch 00046: val_loss did not improve from 1.42235
#
# Epoch 00046: val_accuracy did not improve from 0.70598
# 765/765 [==============================] - 718s 938ms/step - loss: 0.0134 - accuracy: 0.9993 - top5_acc: 1.0000 - macro_f1score: 0.1145 - val_loss: 1.4430 - val_accuracy: 0.6956 - val_top5_acc: 0.8575 - val_macro_f1score: 0.0748
# Learning rate:  0.0001
#
# Epoch 00047: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 47/70
# 765/765 [==============================] - ETA: 0s - loss: 0.0135 - accuracy: 0.9993 - top5_acc: 1.0000 - macro_f1score: 0.1141
# Epoch 00047: val_loss did not improve from 1.42235
#
# Epoch 00047: val_accuracy did not improve from 0.70598
# 765/765 [==============================] - 718s 939ms/step - loss: 0.0135 - accuracy: 0.9993 - top5_acc: 1.0000 - macro_f1score: 0.1141 - val_loss: 1.4409 - val_accuracy: 0.6996 - val_top5_acc: 0.8552 - val_macro_f1score: 0.0746
# Learning rate:  0.0001
#
# Epoch 00048: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 48/70
# 765/765 [==============================] - ETA: 0s - loss: 0.0121 - accuracy: 0.9996 - top5_acc: 1.0000 - macro_f1score: 0.1141
# Epoch 00048: val_loss did not improve from 1.42235
#
# Epoch 00048: val_accuracy improved from 0.70598 to 0.70833, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_ResNet_v2/048.h5
# 765/765 [==============================] - 724s 946ms/step - loss: 0.0121 - accuracy: 0.9996 - top5_acc: 1.0000 - macro_f1score: 0.1141 - val_loss: 1.4269 - val_accuracy: 0.7083 - val_top5_acc: 0.8606 - val_macro_f1score: 0.0744
# Learning rate:  0.0001
#
# Epoch 00049: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 49/70
# 765/765 [==============================] - ETA: 0s - loss: 0.0126 - accuracy: 0.9995 - top5_acc: 1.0000 - macro_f1score: 0.1144
# Epoch 00049: val_loss did not improve from 1.42235
#
# Epoch 00049: val_accuracy did not improve from 0.70833
# 765/765 [==============================] - 723s 945ms/step - loss: 0.0126 - accuracy: 0.9995 - top5_acc: 1.0000 - macro_f1score: 0.1144 - val_loss: 1.4252 - val_accuracy: 0.6983 - val_top5_acc: 0.8585 - val_macro_f1score: 0.0731
# Learning rate:  0.0001
#
# Epoch 00050: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 50/70
# 765/765 [==============================] - ETA: 0s - loss: 0.0134 - accuracy: 0.9991 - top5_acc: 1.0000 - macro_f1score: 0.1142
# Epoch 00050: val_loss did not improve from 1.42235
#
# Epoch 00050: val_accuracy did not improve from 0.70833
# 765/765 [==============================] - 724s 946ms/step - loss: 0.0134 - accuracy: 0.9991 - top5_acc: 1.0000 - macro_f1score: 0.1142 - val_loss: 1.4386 - val_accuracy: 0.7016 - val_top5_acc: 0.8545 - val_macro_f1score: 0.0738
# Learning rate:  0.0001
#
# Epoch 00051: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 51/70
# 765/765 [==============================] - ETA: 0s - loss: 0.0143 - accuracy: 0.9991 - top5_acc: 1.0000 - macro_f1score: 0.1142
# Epoch 00051: val_loss did not improve from 1.42235
#
# Epoch 00051: val_accuracy improved from 0.70833 to 0.70934, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_ResNet_v2/051.h5
# 765/765 [==============================] - 730s 954ms/step - loss: 0.0143 - accuracy: 0.9991 - top5_acc: 1.0000 - macro_f1score: 0.1142 - val_loss: 1.4249 - val_accuracy: 0.7093 - val_top5_acc: 0.8575 - val_macro_f1score: 0.0759
# Learning rate:  0.0001
#
# Epoch 00052: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 52/70
# 765/765 [==============================] - ETA: 0s - loss: 0.0142 - accuracy: 0.9991 - top5_acc: 1.0000 - macro_f1score: 0.1139
# Epoch 00052: val_loss did not improve from 1.42235
#
# Epoch 00052: val_accuracy did not improve from 0.70934
# 765/765 [==============================] - 723s 945ms/step - loss: 0.0142 - accuracy: 0.9991 - top5_acc: 1.0000 - macro_f1score: 0.1139 - val_loss: 1.4424 - val_accuracy: 0.7013 - val_top5_acc: 0.8538 - val_macro_f1score: 0.0742
# Learning rate:  0.0001
#
# Epoch 00053: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 53/70
# 765/765 [==============================] - ETA: 0s - loss: 0.0119 - accuracy: 0.9996 - top5_acc: 1.0000 - macro_f1score: 0.1141
# Epoch 00053: val_loss did not improve from 1.42235
#
# Epoch 00053: val_accuracy did not improve from 0.70934
# 765/765 [==============================] - 724s 947ms/step - loss: 0.0119 - accuracy: 0.9996 - top5_acc: 1.0000 - macro_f1score: 0.1141 - val_loss: 1.4439 - val_accuracy: 0.6969 - val_top5_acc: 0.8542 - val_macro_f1score: 0.0731
# Learning rate:  0.0001
#
# Epoch 00054: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 54/70
# 765/765 [==============================] - ETA: 0s - loss: 0.0132 - accuracy: 0.9991 - top5_acc: 1.0000 - macro_f1score: 0.1144
# Epoch 00054: val_loss did not improve from 1.42235
#
# Epoch 00054: val_accuracy did not improve from 0.70934
# 765/765 [==============================] - 721s 943ms/step - loss: 0.0132 - accuracy: 0.9991 - top5_acc: 1.0000 - macro_f1score: 0.1144 - val_loss: 1.4676 - val_accuracy: 0.6932 - val_top5_acc: 0.8508 - val_macro_f1score: 0.0723
# Learning rate:  0.0001
#
# Epoch 00055: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 55/70
# 765/765 [==============================] - ETA: 0s - loss: 0.0115 - accuracy: 0.9996 - top5_acc: 1.0000 - macro_f1score: 0.1140
# Epoch 00055: val_loss did not improve from 1.42235
#
# Epoch 00055: val_accuracy did not improve from 0.70934
# 765/765 [==============================] - 719s 940ms/step - loss: 0.0115 - accuracy: 0.9996 - top5_acc: 1.0000 - macro_f1score: 0.1140 - val_loss: 1.4705 - val_accuracy: 0.6935 - val_top5_acc: 0.8522 - val_macro_f1score: 0.0741
# Learning rate:  0.0001
#
# Epoch 00056: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 56/70
# 765/765 [==============================] - ETA: 0s - loss: 0.0127 - accuracy: 0.9995 - top5_acc: 1.0000 - macro_f1score: 0.1144
# Epoch 00056: val_loss did not improve from 1.42235
#
# Epoch 00056: val_accuracy did not improve from 0.70934
# 765/765 [==============================] - 723s 945ms/step - loss: 0.0127 - accuracy: 0.9995 - top5_acc: 1.0000 - macro_f1score: 0.1144 - val_loss: 1.4787 - val_accuracy: 0.6959 - val_top5_acc: 0.8535 - val_macro_f1score: 0.0726
# Learning rate:  0.0001
#
# Epoch 00057: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 57/70
# 765/765 [==============================] - ETA: 0s - loss: 0.0150 - accuracy: 0.9990 - top5_acc: 1.0000 - macro_f1score: 0.1143
# Epoch 00057: val_loss did not improve from 1.42235
#
# Epoch 00057: val_accuracy did not improve from 0.70934
# 765/765 [==============================] - 723s 945ms/step - loss: 0.0150 - accuracy: 0.9990 - top5_acc: 1.0000 - macro_f1score: 0.1143 - val_loss: 1.5324 - val_accuracy: 0.6899 - val_top5_acc: 0.8401 - val_macro_f1score: 0.0730
# Learning rate:  0.0001
#
# Epoch 00058: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 58/70
# 765/765 [==============================] - ETA: 0s - loss: 0.0151 - accuracy: 0.9991 - top5_acc: 1.0000 - macro_f1score: 0.1139
# Epoch 00058: val_loss did not improve from 1.42235
#
# Epoch 00058: val_accuracy did not improve from 0.70934
# 765/765 [==============================] - 721s 943ms/step - loss: 0.0151 - accuracy: 0.9991 - top5_acc: 1.0000 - macro_f1score: 0.1139 - val_loss: 1.4947 - val_accuracy: 0.6845 - val_top5_acc: 0.8498 - val_macro_f1score: 0.0712
# Learning rate:  0.0001
#
# Epoch 00059: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 59/70
# 765/765 [==============================] - ETA: 0s - loss: 0.0117 - accuracy: 0.9996 - top5_acc: 1.0000 - macro_f1score: 0.1145
# Epoch 00059: val_loss did not improve from 1.42235
#
# Epoch 00059: val_accuracy did not improve from 0.70934
# 765/765 [==============================] - 721s 943ms/step - loss: 0.0117 - accuracy: 0.9996 - top5_acc: 1.0000 - macro_f1score: 0.1145 - val_loss: 1.4354 - val_accuracy: 0.7067 - val_top5_acc: 0.8532 - val_macro_f1score: 0.0740
# Learning rate:  0.0001
#
# Epoch 00060: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 60/70
# 765/765 [==============================] - ETA: 0s - loss: 0.0139 - accuracy: 0.9993 - top5_acc: 1.0000 - macro_f1score: 0.1142
# Epoch 00060: val_loss improved from 1.42235 to 1.41769, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_ResNet_v2/060.h5
#
# Epoch 00060: val_accuracy did not improve from 0.70934
# 765/765 [==============================] - 725s 947ms/step - loss: 0.0139 - accuracy: 0.9993 - top5_acc: 1.0000 - macro_f1score: 0.1142 - val_loss: 1.4177 - val_accuracy: 0.6999 - val_top5_acc: 0.8562 - val_macro_f1score: 0.0735
# Learning rate:  1e-05
#
# Epoch 00061: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 61/70
# 765/765 [==============================] - ETA: 0s - loss: 0.0099 - accuracy: 0.9998 - top5_acc: 1.0000 - macro_f1score: 0.1144
# Epoch 00061: val_loss improved from 1.41769 to 1.37544, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_ResNet_v2/061.h5
#
# Epoch 00061: val_accuracy improved from 0.70934 to 0.71203, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_ResNet_v2/061.h5
# 765/765 [==============================] - 733s 958ms/step - loss: 0.0099 - accuracy: 0.9998 - top5_acc: 1.0000 - macro_f1score: 0.1144 - val_loss: 1.3754 - val_accuracy: 0.7120 - val_top5_acc: 0.8642 - val_macro_f1score: 0.0751
# Learning rate:  1e-05
#
# Epoch 00062: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 62/70
# 765/765 [==============================] - ETA: 0s - loss: 0.0097 - accuracy: 0.9998 - top5_acc: 1.0000 - macro_f1score: 0.1145
# Epoch 00062: val_loss improved from 1.37544 to 1.35793, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_ResNet_v2/062.h5
#
# Epoch 00062: val_accuracy improved from 0.71203 to 0.71237, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_ResNet_v2/062.h5
# 765/765 [==============================] - 734s 960ms/step - loss: 0.0097 - accuracy: 0.9998 - top5_acc: 1.0000 - macro_f1score: 0.1145 - val_loss: 1.3579 - val_accuracy: 0.7124 - val_top5_acc: 0.8639 - val_macro_f1score: 0.0740
# Learning rate:  1e-05
#
# Epoch 00063: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 63/70
# 765/765 [==============================] - ETA: 0s - loss: 0.0102 - accuracy: 0.9999 - top5_acc: 1.0000 - macro_f1score: 0.1145
# Epoch 00063: val_loss improved from 1.35793 to 1.34534, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_ResNet_v2/063.h5
#
# Epoch 00063: val_accuracy did not improve from 0.71237
# 765/765 [==============================] - 729s 953ms/step - loss: 0.0102 - accuracy: 0.9999 - top5_acc: 1.0000 - macro_f1score: 0.1145 - val_loss: 1.3453 - val_accuracy: 0.7103 - val_top5_acc: 0.8616 - val_macro_f1score: 0.0741
# Learning rate:  1e-05
#
# Epoch 00064: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 64/70
# 765/765 [==============================] - ETA: 0s - loss: 0.0112 - accuracy: 0.9998 - top5_acc: 1.0000 - macro_f1score: 0.1143
# Epoch 00064: val_loss improved from 1.34534 to 1.33508, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_ResNet_v2/064.h5
#
# Epoch 00064: val_accuracy did not improve from 0.71237
# 765/765 [==============================] - 730s 954ms/step - loss: 0.0112 - accuracy: 0.9998 - top5_acc: 1.0000 - macro_f1score: 0.1143 - val_loss: 1.3351 - val_accuracy: 0.7124 - val_top5_acc: 0.8595 - val_macro_f1score: 0.0743
# Learning rate:  1e-05
#
# Epoch 00065: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 65/70
# 765/765 [==============================] - ETA: 0s - loss: 0.0124 - accuracy: 0.9998 - top5_acc: 1.0000 - macro_f1score: 0.1146
# Epoch 00065: val_loss improved from 1.33508 to 1.32941, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_ResNet_v2/065.h5
#
# Epoch 00065: val_accuracy did not improve from 0.71237
# 765/765 [==============================] - 732s 957ms/step - loss: 0.0124 - accuracy: 0.9998 - top5_acc: 1.0000 - macro_f1score: 0.1146 - val_loss: 1.3294 - val_accuracy: 0.7110 - val_top5_acc: 0.8606 - val_macro_f1score: 0.0740
# Learning rate:  1e-05
#
# Epoch 00066: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 66/70
# 765/765 [==============================] - ETA: 0s - loss: 0.0142 - accuracy: 0.9998 - top5_acc: 1.0000 - macro_f1score: 0.1146
# Epoch 00066: val_loss improved from 1.32941 to 1.32492, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_ResNet_v2/066.h5
#
# Epoch 00066: val_accuracy did not improve from 0.71237
# 765/765 [==============================] - 729s 953ms/step - loss: 0.0142 - accuracy: 0.9998 - top5_acc: 1.0000 - macro_f1score: 0.1146 - val_loss: 1.3249 - val_accuracy: 0.7110 - val_top5_acc: 0.8626 - val_macro_f1score: 0.0729
# Learning rate:  1e-05
#
# Epoch 00067: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 67/70
# 765/765 [==============================] - ETA: 0s - loss: 0.0149 - accuracy: 0.9998 - top5_acc: 1.0000 - macro_f1score: 0.1146
# Epoch 00067: val_loss improved from 1.32492 to 1.32456, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_ResNet_v2/067.h5
#
# Epoch 00067: val_accuracy did not improve from 0.71237
# 765/765 [==============================] - 725s 948ms/step - loss: 0.0149 - accuracy: 0.9998 - top5_acc: 1.0000 - macro_f1score: 0.1146 - val_loss: 1.3246 - val_accuracy: 0.7097 - val_top5_acc: 0.8619 - val_macro_f1score: 0.0725
# Learning rate:  1e-05
#
# Epoch 00068: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 68/70
# 765/765 [==============================] - ETA: 0s - loss: 0.0168 - accuracy: 0.9999 - top5_acc: 1.0000 - macro_f1score: 0.1144
# Epoch 00068: val_loss improved from 1.32456 to 1.32032, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_ResNet_v2/068.h5
#
# Epoch 00068: val_accuracy did not improve from 0.71237
# 765/765 [==============================] - 721s 943ms/step - loss: 0.0168 - accuracy: 0.9999 - top5_acc: 1.0000 - macro_f1score: 0.1144 - val_loss: 1.3203 - val_accuracy: 0.7077 - val_top5_acc: 0.8636 - val_macro_f1score: 0.0730
# Learning rate:  1e-05
#
# Epoch 00069: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 69/70
# 765/765 [==============================] - ETA: 0s - loss: 0.0180 - accuracy: 0.9999 - top5_acc: 1.0000 - macro_f1score: 0.1146
# Epoch 00069: val_loss improved from 1.32032 to 1.31347, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_ResNet_v2/069.h5
#
# Epoch 00069: val_accuracy did not improve from 0.71237
# 765/765 [==============================] - 726s 949ms/step - loss: 0.0180 - accuracy: 0.9999 - top5_acc: 1.0000 - macro_f1score: 0.1146 - val_loss: 1.3135 - val_accuracy: 0.7093 - val_top5_acc: 0.8626 - val_macro_f1score: 0.0716
# Learning rate:  1e-05
#
# Epoch 00070: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 70/70
# 765/765 [==============================] - ETA: 0s - loss: 0.0200 - accuracy: 0.9997 - top5_acc: 1.0000 - macro_f1score: 0.1146
# Epoch 00070: val_loss improved from 1.31347 to 1.30543, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/Inception_ResNet_v2/070.h5
#
# Epoch 00070: val_accuracy did not improve from 0.71237
# 765/765 [==============================] - 726s 948ms/step - loss: 0.0200 - accuracy: 0.9997 - top5_acc: 1.0000 - macro_f1score: 0.1146 - val_loss: 1.3054 - val_accuracy: 0.7097 - val_top5_acc: 0.8636 - val_macro_f1score: 0.0712

# %% [markdown]
# ### 3) Inception-ResNet-V2 Evaluate

# %%
# 1. epoch=maximum
loss , acc, top5_acc, mf1 = model.evaluate(test_generator,steps=int(len(x_test)/batch_sizes))
print('[Test Loss: %.4f /  Test Top-1 Accuracy: %.4f / Test Top-5 Accuracy: %.4f / Test Macro f1: %.4f]\n' % (loss,acc,top5_acc,mf1))
# Out:
# 97/97 [==============================] - 969s 10s/step - loss: 1.3240 - accuracy: 0.6985 - top5_acc: 0.8605 - macro_f1score: 0.0705
# [Test Loss: 1.3240 /  Test Top-1 Accuracy: 0.6985 / Test Top-5 Accuracy: 0.8605 / Test Macro f1: 0.0705]

# %%
loss=history.history['loss']
val_loss=history.history['val_loss']
acc=history.history['accuracy']
val_acc=history.history['val_accuracy']
top5_acc=history.history['top5_acc']
val_top5_acc=history.history['val_top5_acc']
f1=history.history['macro_f1score']
val_f1=history.history['val_macro_f1score']
epochs=range(1,len(acc)+1)

data = np.array([epochs,loss,val_loss,acc,val_acc,top5_acc,val_top5_acc,f1,val_f1]).T

# %%
# data save
# epochs, loss, val_loss, acc, val_acc, top5_acc, val_top5_acc, f1, val_f1

np.savetxt(os.path.join(dir,'train_valid_output',number,model.name+'.txt'),data)

# %%
# data import
data = np.loadtxt(os.path.join(dir,'train_valid_output',number,'Inception_ResNet_v2.txt'))

# %%
epochs=data[:,0]
loss=data[:,1]
val_loss=data[:,2]
acc=data[:,3]
val_acc=data[:,4]
top5_acc=data[:,5]
val_top5_acc=data[:,6]

# %%
plt.plot(epochs[1:],acc[1:],'b',label='Training 1-Acc')
plt.plot(epochs[1:],val_acc[1:],'r',label='Validation 1-Acc')
plt.title('Training and Validation Top-1 Accuracy')
plt.legend()
plt.figure()

plt.plot(epochs[1:],top5_acc[1:],'b',label='Training 5-Acc')
plt.plot(epochs[1:],val_top5_acc[1:],'r',label='Validation 5-Acc')
plt.title('Training and Validation Top-5 Accuracy')
plt.legend()
plt.figure()

plt.plot(epochs[10:],loss[10:],'b',label='Training Loss')
plt.plot(epochs[10:],val_loss[10:],'r',label='Validation Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()

# %%
# 이 아래는 내가 인위적으로 살펴보고 싶은 epoch에 대해서 결과값 출력 / Inception_Resnet_V2

# %%
# 참고 : https://github.com/OverLordGoldDragon/keras-adamw

import sys
sys.path.append('/content/drive/My Drive/Colab Notebooks/Paper')
import utils
import optimizers_v2
from utils import get_weight_decays, fill_dict_in_order
from utils import reset_seeds, K_eval
from optimizers_v2 import AdamW, NadamW, SGDW

# %%
# top-5 accuracy 출력
import functools
top5_acc = functools.partial(ks.metrics.top_k_categorical_accuracy, k=5)
top5_acc.__name__ = 'top5_acc'

# %%
model=load_model(os.path.join(dir,'model_output',number,'Inception_ResNet_v2','070.h5'),custom_objects={"macro_f1score": macro_f1score,"top5_acc":top5_acc, "AdamW":AdamW})

# %%
# 2. epoch=?
loss , acc, top5_acc, mf1 = model.evaluate(test_generator,steps=int(len(x_test)/batch_sizes))
print('[Test Loss: %.4f /  Test Top-1 Accuracy: %.4f / Test Top-5 Accuracy: %.4f / Test Macro f1: %.4f]\n' % (loss,acc,top5_acc,mf1))
# Out:
# 97/97 [==============================] - 1159s 12s/step - loss: 1.3227 - accuracy: 0.6978 - top5_acc: 0.8608 - macro_f1score: 0.0701
# [Test Loss: 1.3227 /  Test Top-1 Accuracy: 0.6978 / Test Top-5 Accuracy: 0.8608 / Test Macro f1: 0.0701]
