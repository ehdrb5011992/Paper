# %% [markdown]
# # [GoogLeNet]

# %% [markdown]
# *KU LeeDongGyu*

# %% [markdown]
# ## Contents
# ---

# %% [markdown]
# 1. Data Preprocessing
# ```
# 1) Data Import
# 2) Data Augmentation
# ```
# 2. Support Functions & Almost Original GoogLeNet
# ```
# 1) Support Functions
# 2) Almost Original GoogLeNet
# 3) GoogLeNet Evaluate
# ```

# %% [markdown]
# ### Install Packages

# %% [markdown]
# ### Module

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/My Drive/Colab Notebooks/Paper
# Out:
# /content/drive/My Drive/Colab Notebooks/Paper

# %%
from f1score import macro_f1score,weighted_f1score
from pool_helper import PoolHelper
from lrn import LRN

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import cv2
import tensorflow as tf
from tensorflow import keras as ks
from tensorflow.keras import backend as K 
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, Input, Concatenate, ZeroPadding2D ,GlobalMaxPooling2D, Reshape , Lambda , Add, Multiply
from tensorflow.keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D, Activation, BatchNormalization, AveragePooling2D , ZeroPadding2D, SeparableConv2D
from tensorflow.keras.layers import add
from tensorflow.keras.optimizers import Adam, RMSprop , SGD
from tensorflow.keras.callbacks import EarlyStopping , LearningRateScheduler, ModelCheckpoint, CSVLogger, Callback, ReduceLROnPlateau
from tensorflow.keras.regularizers import l1,l2,l1_l2
from tensorflow.keras.models import Model , load_model , Sequential
from tensorflow.keras.utils import plot_model , to_categorical, get_file
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
os.getcwd()
# Out:
# '/content/drive/My Drive/Colab Notebooks/Paper'

# %%
print(tf.__version__)
print(ks.__version__)
# Out:
# 2.3.0
# 2.4.0

# %%
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 13836690046813986619
# , name: "/device:XLA_CPU:0"
# device_type: "XLA_CPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 14433476697771634225
# physical_device_desc: "device: XLA_CPU device"
# , name: "/device:XLA_GPU:0"
# device_type: "XLA_GPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 5507204210143608478
# physical_device_desc: "device: XLA_GPU device"
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 15695488000
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 3043064362057335745
# physical_device_desc: "device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0"
# ]

# %% [markdown]
# ## 1. Data Preprocessing
# ---

# %% [markdown]
# ### 1) Data Import

# %%
# 바꿔서 살펴 볼 것들
# CALTECH, CIFAR100, FER, MIT
data_name = 'CALTECH'
gan_type = 'No_GAN'
number = '1'
size = 224
super_size = 256
input_sizes = (size,size,3)
batch_sizes = 128
weight_decay = 1e-4
epochs = 70

# %%
# 참고 : https://stackoverflow.com/questions/32419510/how-to-get-reproducible-results-in-keras/52897216#52897216
# setting the seed number for random number generation for reproducibility.

from numpy.random import seed
import random


if number=='1':
    seed_num = 200225
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)
elif number=='2':
    seed_num = 727
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)
elif number=='3':
    seed_num = 115
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)
elif number=='4':
    seed_num = 501
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)
elif number=='5':
    seed_num = 517
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)

# %%
# data import

if data_name=='FER' :
    x_train =  np.zeros(28698)
    x_valid = np.zeros(3589)
    x_test = np.zeros(3588)
    classes = 7 
    tr_center = [0.50793296, 0.50793296, 0.50793296]
elif data_name=='MIT':
    x_train = np.zeros(12466)
    x_valid = np.zeros(1564)
    x_test = np.zeros(1590)
    classes = 67 
    tr_center = [0.47916578, 0.42029615, 0.36046057]
elif data_name=='CALTECH':
    x_train = np.zeros(24510)
    x_valid = np.zeros(2980)
    x_test = np.zeros(3118)
    classes = 257
    tr_center = [0.51397761, 0.49525248, 0.46555727]
elif data_name=='CIFAR100':
    x_train = np.zeros(44923)
    x_valid = np.zeros(5077)
    x_test = np.zeros(10000)
    classes = 100
    tr_center = [0.53442983, 0.51355958, 0.46462564]

# %%
dir = os.path.join(os.getcwd(),data_name,gan_type)

# %% [markdown]
# ### 2) Data Augmentation

# %%
# 참고 : https://jkjung-avt.github.io/keras-image-cropping/

def random_crop(img, random_crop_size):
    # Note: image_data_format is 'channel_last'
    assert img.shape[2] == 3 # img.shape[2] 가 3(rgb)이 아니면 assertion error 발생
    height, width = img.shape[0], img.shape[1]
    dy, dx = random_crop_size
    x = np.random.randint(0, width - dx + 1)
    y = np.random.randint(0, height - dy + 1)
    return img[y:(y+dy), x:(x+dx), :]


def crop_generator(batches, crop_length):
    """Take as input a Keras ImageGen (Iterator) and generate random
    crops from the image batches generated by the original iterator.
    """
    while True:
        batch_x, batch_y = next(batches)
        batch_crops = np.zeros((batch_x.shape[0], crop_length, crop_length, 3))
        for i in range(batch_x.shape[0]):
            batch_crops[i] = random_crop(batch_x[i], (crop_length, crop_length))
        yield (batch_crops, batch_y)

# %%
from tensorflow.keras.preprocessing.image import img_to_array,load_img
import glob

# 데이터 전체에 대해 centering 진행함.

def read_cal_image(img_path): 
    x = img_to_array(load_img(img_path)) # x는 채널별 평균값
    y = x.shape[0] * x.shape[1]# y는 데이터별 픽셀 수 (비중)

    x = 1/255. * x # scaling하고, centering값을 뽑아냄.
    x = np.mean(x, axis=(0,1))
    
    return np.hstack([x,y])

def calculate_centered_mean(dataset_path,x_train=x_train):
    num = len(x_train)
    space = np.empty((num,4))
    i=0

    for p in glob.glob(os.path.join(dataset_path,'*/*.*')) :
        space[i] = read_cal_image(p)
        i += 1

    ratio = space[:,3] / np.sum(space[:,3])

    return np.average(space[:,0:3],axis=0,weights=ratio)


# 아래의 함수를 돌려서 나온 결과값을 중심화 값으로 설정.

# train_mean = calculate_centered_mean(os.path.join(dir,'data/train')).reshape((1,1,3))

# %%
datagen_tr = ImageDataGenerator(
    rescale=1/255.,
    horizontal_flip=True,
    featurewise_center=True,
    featurewise_std_normalization=False,
    rotation_range=10,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=[0.9,1.0],
    fill_mode = 'nearest')
datagen_val = ImageDataGenerator(rescale=1/255.,featurewise_center=True)
datagen_tes = ImageDataGenerator(rescale=1/255.,featurewise_center=True)

# 원래는 이 자리에 fit 매서드를 써야하지만, 그냥 내가 중심화함수를 만들고 적용함. 

# 중심화 설정
datagen_tr.mean = np.array(tr_center, dtype=np.float32).reshape((1,1,3)) # RGB
datagen_val.mean = np.array(tr_center, dtype=np.float32).reshape((1,1,3)) # RGB
datagen_tes.mean = np.array(tr_center, dtype=np.float32).reshape((1,1,3)) # RGB

# %%
# 매우 간단하다.

#1. train data

def generate_train_for_three(crop_length=size, batch_sizes = batch_sizes, super_size=super_size):

      batches = datagen_tr.flow_from_directory(directory=os.path.join(dir,'data/train'),target_size=(super_size,super_size),batch_size=batch_sizes,class_mode='categorical')

      while True:
          batch_x, batch_y = next(batches)
          batch_crops = np.zeros((batch_x.shape[0], crop_length, crop_length, 3))
          for i in range(batch_x.shape[0]):
              batch_crops[i] = random_crop(batch_x[i], (crop_length, crop_length))
          yield batch_crops, [batch_y,batch_y,batch_y]

# %%
# 2. valid data

def generate_valid_for_three(size=size, batch_sizes = batch_sizes):

      batches_xy = datagen_val.flow_from_directory(directory=os.path.join(dir,'data/valid'),target_size=(size,size),batch_size=batch_sizes,class_mode='categorical')

      while True:

          batch_xy = batches_xy.next()
          yield  batch_xy[0], [ batch_xy[1],batch_xy[1],batch_xy[1] ]

# %%
# 3. test data

def generate_test_for_three(size=size, batch_sizes = batch_sizes):

      batches_xy = datagen_tes.flow_from_directory(directory=os.path.join(dir,'data/test'),target_size=(size,size),batch_size=batch_sizes,class_mode='categorical')

      while True:

          batch_xy = batches_xy.next()
          yield  batch_xy[0], [ batch_xy[1],batch_xy[1],batch_xy[1] ]

# %%
# 위에서 쓰임
# train_batches = datagen_tr.flow_from_directory(directory=os.path.join(dir,'data/train'),target_size=(super_size,super_size),batch_size=batch_sizes,class_mode='categorical') # fer : 28698 / mit : 12466 / caltech : 24509 / cifar : 44923
# train_generator= crop_generator(train_batches, size)

# valid_generator = datagen_val.flow_from_directory(directory=os.path.join(dir,'data/valid'),target_size=(size,size),batch_size=batch_sizes,class_mode='categorical') # fer : 3589 / mit : 1564 / caltech : 2980 / cifar : 5077
# test_generator = datagen_tes.flow_from_directory(directory=os.path.join(dir,'data/test'),target_size=(size,size),batch_size=batch_sizes,class_mode='categorical') # fer : 3588 / mit : 1590 / caltech : 3118 / cifar : 10000

# %% [markdown]
# ## 2. Support Functions & Almost Original GoogLeNet
# ---

# %% [markdown]
# ### 1) Support Functions

# %%
# def lr_schedule(epoch):
#     init_lr = 1e-4
#     k = 0.04
#     lr = init_lr * np.exp(-k*epoch)
#     print('Learning rate: ', lr)
#     return lr

def lr_schedule(epoch):
    lr = 3e-4
    if epoch < 30:
        lr = lr
    elif epoch < 60 :
        lr = lr * 0.1
    else:
        lr = lr * 0.01
    print('Learning rate: ', lr)
    return lr

# %% [markdown]
# ### 3) Almost Original GoogLeNet

# %%
# GoogLeNet를 최대한 논문에 가깝게 맞춰 모형작성.

def googlenet(input_shape=(224,224,3), classes=1000, weight_decay = weight_decay, weights_path = None,name='Inception_v1'):

    input = Input(input_shape)

    conv1_7x7_s2 = Conv2D(64, (7,7), strides=(2,2), padding='same', activation='relu', name='conv1/7x7_s2', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(input)
    pool1_3x3_s2 = MaxPooling2D(pool_size=(3,3), strides=(2,2), padding='same', name='pool1/3x3_s2')(conv1_7x7_s2)
    pool1_norm1 = LRN(name='pool1/norm1')(pool1_3x3_s2)

    conv2_3x3_reduce = Conv2D(64, (1,1), padding='same', activation='relu', name='conv2/3x3_reduce', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(pool1_norm1)
    conv2_3x3 = Conv2D(192, (3,3), padding='same', activation='relu', name='conv2/3x3', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(conv2_3x3_reduce)
    conv2_norm2 = LRN(name='conv2/norm2')(conv2_3x3)
    pool2_3x3_s2 = MaxPooling2D(pool_size=(3,3), strides=(2,2), padding='same', name='pool2/3x3_s2')(conv2_norm2)

    inception_3a_1x1 = Conv2D(64, (1,1), padding='same', activation='relu', name='inception_3a/1x1', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(pool2_3x3_s2)
    inception_3a_3x3_reduce = Conv2D(96, (1,1), padding='same', activation='relu', name='inception_3a/3x3_reduce', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(pool2_3x3_s2)
    inception_3a_3x3_pad = ZeroPadding2D(padding=(1, 1))(inception_3a_3x3_reduce)
    inception_3a_3x3 = Conv2D(128, (3,3), padding='valid', activation='relu', name='inception_3a/3x3', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_3a_3x3_pad)
    inception_3a_5x5_reduce = Conv2D(16, (1,1), padding='same', activation='relu', name='inception_3a/5x5_reduce', kernel_regularizer=l2(weight_decay))(pool2_3x3_s2)
    inception_3a_5x5_pad = ZeroPadding2D(padding=(2, 2))(inception_3a_5x5_reduce)
    inception_3a_5x5 = Conv2D(32, (5,5), padding='valid', activation='relu', name='inception_3a/5x5', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_3a_5x5_pad)
    inception_3a_pool = MaxPooling2D(pool_size=(3,3), strides=(1,1), padding='same', name='inception_3a/pool')(pool2_3x3_s2)
    inception_3a_pool_proj = Conv2D(32, (1,1), padding='same', activation='relu', name='inception_3a/pool_proj', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_3a_pool)
    inception_3a_output = Concatenate(axis=-1, name='inception_3a/output')([inception_3a_1x1,inception_3a_3x3,inception_3a_5x5,inception_3a_pool_proj])
    # Concatenate axis 수정.

    inception_3b_1x1 = Conv2D(128, (1,1), padding='same', activation='relu', name='inception_3b/1x1', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_3a_output)
    inception_3b_3x3_reduce = Conv2D(128, (1,1), padding='same', activation='relu', name='inception_3b/3x3_reduce', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_3a_output)
    inception_3b_3x3_pad = ZeroPadding2D(padding=(1, 1))(inception_3b_3x3_reduce)
    inception_3b_3x3 = Conv2D(192, (3,3), padding='valid', activation='relu', name='inception_3b/3x3', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_3b_3x3_pad)
    inception_3b_5x5_reduce = Conv2D(32, (1,1), padding='same', activation='relu', name='inception_3b/5x5_reduce', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_3a_output)
    inception_3b_5x5_pad = ZeroPadding2D(padding=(2, 2))(inception_3b_5x5_reduce)
    inception_3b_5x5 = Conv2D(96, (5,5), padding='valid', activation='relu', name='inception_3b/5x5', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_3b_5x5_pad)
    inception_3b_pool = MaxPooling2D(pool_size=(3,3), strides=(1,1), padding='same', name='inception_3b/pool')(inception_3a_output)
    inception_3b_pool_proj = Conv2D(64, (1,1), padding='same', activation='relu', name='inception_3b/pool_proj', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_3b_pool)
    inception_3b_output = Concatenate(axis=-1, name='inception_3b/output')([inception_3b_1x1,inception_3b_3x3,inception_3b_5x5,inception_3b_pool_proj])

    pool3_3x3_s2 = MaxPooling2D(pool_size=(3,3), strides=(2,2), padding='same', name='pool3/3x3_s2')(inception_3b_output)

    inception_4a_1x1 = Conv2D(192, (1,1), padding='same', activation='relu', name='inception_4a/1x1', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(pool3_3x3_s2)
    inception_4a_3x3_reduce = Conv2D(96, (1,1), padding='same', activation='relu', name='inception_4a/3x3_reduce', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(pool3_3x3_s2)
    inception_4a_3x3_pad = ZeroPadding2D(padding=(1, 1))(inception_4a_3x3_reduce)
    inception_4a_3x3 = Conv2D(208, (3,3), padding='valid', activation='relu', name='inception_4a/3x3', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_4a_3x3_pad)
    inception_4a_5x5_reduce = Conv2D(16, (1,1), padding='same', activation='relu', name='inception_4a/5x5_reduce', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(pool3_3x3_s2)
    inception_4a_5x5_pad = ZeroPadding2D(padding=(2, 2))(inception_4a_5x5_reduce)
    inception_4a_5x5 = Conv2D(48, (5,5), padding='valid', activation='relu', name='inception_4a/5x5', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_4a_5x5_pad)
    inception_4a_pool = MaxPooling2D(pool_size=(3,3), strides=(1,1), padding='same', name='inception_4a/pool')(pool3_3x3_s2)
    inception_4a_pool_proj = Conv2D(64, (1,1), padding='same', activation='relu', name='inception_4a/pool_proj', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_4a_pool)
    inception_4a_output = Concatenate(axis=-1, name='inception_4a/output')([inception_4a_1x1,inception_4a_3x3,inception_4a_5x5,inception_4a_pool_proj])

    loss1_ave_pool = AveragePooling2D(pool_size=(5,5), strides=(3,3), name='loss1/ave_pool')(inception_4a_output)
    loss1_conv = Conv2D(128, (1,1), padding='same', activation='relu', name='loss1/conv', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(loss1_ave_pool)
    loss1_flat = Flatten()(loss1_conv)
    loss1_fc = Dense(1024, activation='relu', name='loss1/fc', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(loss1_flat)
    loss1_drop_fc = Dropout(rate=0.7)(loss1_fc)
    loss1_classifier = Dense(classes, activation='softmax', kernel_regularizer=l2(weight_decay), name='loss1/classifier')(loss1_drop_fc)

    inception_4b_1x1 = Conv2D(160, (1,1), padding='same', activation='relu', name='inception_4b/1x1', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_4a_output)
    inception_4b_3x3_reduce = Conv2D(112, (1,1), padding='same', activation='relu', name='inception_4b/3x3_reduce', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_4a_output)
    inception_4b_3x3_pad = ZeroPadding2D(padding=(1, 1))(inception_4b_3x3_reduce)
    inception_4b_3x3 = Conv2D(224, (3,3), padding='valid', activation='relu', name='inception_4b/3x3', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_4b_3x3_pad)
    inception_4b_5x5_reduce = Conv2D(24, (1,1), padding='same', activation='relu', name='inception_4b/5x5_reduce', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_4a_output)
    inception_4b_5x5_pad = ZeroPadding2D(padding=(2, 2))(inception_4b_5x5_reduce)
    inception_4b_5x5 = Conv2D(64, (5,5), padding='valid', activation='relu', name='inception_4b/5x5', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_4b_5x5_pad)
    inception_4b_pool = MaxPooling2D(pool_size=(3,3), strides=(1,1), padding='same', name='inception_4b/pool')(inception_4a_output)
    inception_4b_pool_proj = Conv2D(64, (1,1), padding='same', activation='relu', name='inception_4b/pool_proj', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_4b_pool)
    inception_4b_output = Concatenate(axis=-1, name='inception_4b/output')([inception_4b_1x1,inception_4b_3x3,inception_4b_5x5,inception_4b_pool_proj])

    inception_4c_1x1 = Conv2D(128, (1,1), padding='same', activation='relu', name='inception_4c/1x1', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_4b_output)
    inception_4c_3x3_reduce = Conv2D(128, (1,1), padding='same', activation='relu', name='inception_4c/3x3_reduce', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_4b_output)
    inception_4c_3x3_pad = ZeroPadding2D(padding=(1, 1))(inception_4c_3x3_reduce)
    inception_4c_3x3 = Conv2D(256, (3,3), padding='valid', activation='relu', name='inception_4c/3x3', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_4c_3x3_pad)
    inception_4c_5x5_reduce = Conv2D(24, (1,1), padding='same', activation='relu', name='inception_4c/5x5_reduce', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_4b_output)
    inception_4c_5x5_pad = ZeroPadding2D(padding=(2, 2))(inception_4c_5x5_reduce)
    inception_4c_5x5 = Conv2D(64, (5,5), padding='valid', activation='relu', name='inception_4c/5x5', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_4c_5x5_pad)
    inception_4c_pool = MaxPooling2D(pool_size=(3,3), strides=(1,1), padding='same', name='inception_4c/pool')(inception_4b_output)
    inception_4c_pool_proj = Conv2D(64, (1,1), padding='same', activation='relu', name='inception_4c/pool_proj', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_4c_pool)
    inception_4c_output = Concatenate(axis=-1, name='inception_4c/output')([inception_4c_1x1,inception_4c_3x3,inception_4c_5x5,inception_4c_pool_proj])

    inception_4d_1x1 = Conv2D(112, (1,1), padding='same', activation='relu', name='inception_4d/1x1', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_4c_output)
    inception_4d_3x3_reduce = Conv2D(144, (1,1), padding='same', activation='relu', name='inception_4d/3x3_reduce', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_4c_output)
    inception_4d_3x3_pad = ZeroPadding2D(padding=(1, 1))(inception_4d_3x3_reduce)
    inception_4d_3x3 = Conv2D(288, (3,3), padding='valid', activation='relu', name='inception_4d/3x3', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_4d_3x3_pad)
    inception_4d_5x5_reduce = Conv2D(32, (1,1), padding='same', activation='relu', name='inception_4d/5x5_reduce', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_4c_output)
    inception_4d_5x5_pad = ZeroPadding2D(padding=(2, 2))(inception_4d_5x5_reduce)
    inception_4d_5x5 = Conv2D(64, (5,5), padding='valid', activation='relu', name='inception_4d/5x5', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_4d_5x5_pad)
    inception_4d_pool = MaxPooling2D(pool_size=(3,3), strides=(1,1), padding='same', name='inception_4d/pool')(inception_4c_output)
    inception_4d_pool_proj = Conv2D(64, (1,1), padding='same', activation='relu', name='inception_4d/pool_proj', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_4d_pool)
    inception_4d_output = Concatenate(axis=-1, name='inception_4d/output')([inception_4d_1x1,inception_4d_3x3,inception_4d_5x5,inception_4d_pool_proj])

    loss2_ave_pool = AveragePooling2D(pool_size=(5,5), strides=(3,3), name='loss2/ave_pool')(inception_4d_output)
    loss2_conv = Conv2D(128, (1,1), padding='same', activation='relu', name='loss2/conv', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(loss2_ave_pool)
    loss2_flat = Flatten()(loss2_conv)
    loss2_fc = Dense(1024, activation='relu', name='loss2/fc', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(loss2_flat)
    loss2_drop_fc = Dropout(rate=0.7)(loss2_fc)
    loss2_classifier = Dense(classes, activation='softmax', kernel_regularizer=l2(weight_decay), name='loss2/classifier')(loss2_drop_fc)

    inception_4e_1x1 = Conv2D(256, (1,1), padding='same', activation='relu', name='inception_4e/1x1', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_4d_output)
    inception_4e_3x3_reduce = Conv2D(160, (1,1), padding='same', activation='relu', name='inception_4e/3x3_reduce', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_4d_output)
    inception_4e_3x3_pad = ZeroPadding2D(padding=(1, 1))(inception_4e_3x3_reduce)
    inception_4e_3x3 = Conv2D(320, (3,3), padding='valid', activation='relu', name='inception_4e/3x3', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_4e_3x3_pad)
    inception_4e_5x5_reduce = Conv2D(32, (1,1), padding='same', activation='relu', name='inception_4e/5x5_reduce', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_4d_output)
    inception_4e_5x5_pad = ZeroPadding2D(padding=(2, 2))(inception_4e_5x5_reduce)
    inception_4e_5x5 = Conv2D(128, (5,5), padding='valid', activation='relu', name='inception_4e/5x5', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_4e_5x5_pad)
    inception_4e_pool = MaxPooling2D(pool_size=(3,3), strides=(1,1), padding='same', name='inception_4e/pool')(inception_4d_output)
    inception_4e_pool_proj = Conv2D(128, (1,1), padding='same', activation='relu', name='inception_4e/pool_proj', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_4e_pool)
    inception_4e_output = Concatenate(axis=-1, name='inception_4e/output')([inception_4e_1x1,inception_4e_3x3,inception_4e_5x5,inception_4e_pool_proj])

    pool4_3x3_s2 = MaxPooling2D(pool_size=(3,3), strides=(2,2), padding='same', name='pool4/3x3_s2')(inception_4e_output)

    inception_5a_1x1 = Conv2D(256, (1,1), padding='same', activation='relu', name='inception_5a/1x1', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(pool4_3x3_s2)
    inception_5a_3x3_reduce = Conv2D(160, (1,1), padding='same', activation='relu', name='inception_5a/3x3_reduce', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(pool4_3x3_s2)
    inception_5a_3x3_pad = ZeroPadding2D(padding=(1, 1))(inception_5a_3x3_reduce)
    inception_5a_3x3 = Conv2D(320, (3,3), padding='valid', activation='relu', name='inception_5a/3x3', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_5a_3x3_pad)
    inception_5a_5x5_reduce = Conv2D(32, (1,1), padding='same', activation='relu', name='inception_5a/5x5_reduce', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(pool4_3x3_s2)
    inception_5a_5x5_pad = ZeroPadding2D(padding=(2, 2))(inception_5a_5x5_reduce)
    inception_5a_5x5 = Conv2D(128, (5,5), padding='valid', activation='relu', name='inception_5a/5x5', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_5a_5x5_pad)
    inception_5a_pool = MaxPooling2D(pool_size=(3,3), strides=(1,1), padding='same', name='inception_5a/pool')(pool4_3x3_s2)
    inception_5a_pool_proj = Conv2D(128, (1,1), padding='same', activation='relu', name='inception_5a/pool_proj', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_5a_pool)
    inception_5a_output = Concatenate(axis=-1, name='inception_5a/output')([inception_5a_1x1,inception_5a_3x3,inception_5a_5x5,inception_5a_pool_proj])

    inception_5b_1x1 = Conv2D(384, (1,1), padding='same', activation='relu', name='inception_5b/1x1', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_5a_output)
    inception_5b_3x3_reduce = Conv2D(192, (1,1), padding='same', activation='relu', name='inception_5b/3x3_reduce', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_5a_output)
    inception_5b_3x3_pad = ZeroPadding2D(padding=(1, 1))(inception_5b_3x3_reduce)
    inception_5b_3x3 = Conv2D(384, (3,3), padding='valid', activation='relu', name='inception_5b/3x3', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_5b_3x3_pad)
    inception_5b_5x5_reduce = Conv2D(48, (1,1), padding='same', activation='relu', name='inception_5b/5x5_reduce', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_5a_output)
    inception_5b_5x5_pad = ZeroPadding2D(padding=(2, 2))(inception_5b_5x5_reduce)
    inception_5b_5x5 = Conv2D(128, (5,5), padding='valid', activation='relu', name='inception_5b/5x5', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_5b_5x5_pad)
    inception_5b_pool = MaxPooling2D(pool_size=(3,3), strides=(1,1), padding='same', name='inception_5b/pool')(inception_5a_output)
    inception_5b_pool_proj = Conv2D(128, (1,1), padding='same', activation='relu', name='inception_5b/pool_proj', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_5b_pool)
    inception_5b_output = Concatenate(axis=-1, name='inception_5b/output')([inception_5b_1x1,inception_5b_3x3,inception_5b_5x5,inception_5b_pool_proj])

    pool5_7x7_s1 = AveragePooling2D(pool_size=(7,7), strides=(1,1), name='pool5/7x7_s2')(inception_5b_output)

    loss3_flat = Flatten()(pool5_7x7_s1)
    pool5_drop_7x7_s1 = Dropout(rate=0.4)(loss3_flat)
    loss3_classifier = Dense(classes, activation='softmax', kernel_regularizer=l2(weight_decay), name='loss3/classifier')(pool5_drop_7x7_s1)

    googlenet = Model(inputs=input, outputs=[loss1_classifier,loss2_classifier,loss3_classifier],name=name)

    if weights_path:
        googlenet.load_weights(weights_path)

    return googlenet

# %%
model = googlenet(input_shape=input_sizes, classes=classes, name='GoogleNet')

# %%
# auxiliary classifier 2개를 포함하기 때문에, 모수의 개수는 1000만개쯤 된다.
# 메인은 670만개 가량의 모수.
model.summary()
# Out:
# Model: "GoogleNet"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# conv1/7x7_s2 (Conv2D)           (None, 112, 112, 64) 9472        input_1[0][0]
# __________________________________________________________________________________________________
# pool1/3x3_s2 (MaxPooling2D)     (None, 56, 56, 64)   0           conv1/7x7_s2[0][0]
# __________________________________________________________________________________________________
# pool1/norm1 (LRN)               (None, 56, 56, 64)   0           pool1/3x3_s2[0][0]
# __________________________________________________________________________________________________
# conv2/3x3_reduce (Conv2D)       (None, 56, 56, 64)   4160        pool1/norm1[0][0]
# __________________________________________________________________________________________________
# conv2/3x3 (Conv2D)              (None, 56, 56, 192)  110784      conv2/3x3_reduce[0][0]
# __________________________________________________________________________________________________
# conv2/norm2 (LRN)               (None, 56, 56, 192)  0           conv2/3x3[0][0]
# __________________________________________________________________________________________________
# pool2/3x3_s2 (MaxPooling2D)     (None, 28, 28, 192)  0           conv2/norm2[0][0]
# __________________________________________________________________________________________________
# inception_3a/3x3_reduce (Conv2D (None, 28, 28, 96)   18528       pool2/3x3_s2[0][0]
# __________________________________________________________________________________________________
# inception_3a/5x5_reduce (Conv2D (None, 28, 28, 16)   3088        pool2/3x3_s2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d (ZeroPadding2D)  (None, 30, 30, 96)   0           inception_3a/3x3_reduce[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_1 (ZeroPadding2D (None, 32, 32, 16)   0           inception_3a/5x5_reduce[0][0]
# __________________________________________________________________________________________________
# inception_3a/pool (MaxPooling2D (None, 28, 28, 192)  0           pool2/3x3_s2[0][0]
# __________________________________________________________________________________________________
# inception_3a/1x1 (Conv2D)       (None, 28, 28, 64)   12352       pool2/3x3_s2[0][0]
# __________________________________________________________________________________________________
# inception_3a/3x3 (Conv2D)       (None, 28, 28, 128)  110720      zero_padding2d[0][0]
# __________________________________________________________________________________________________
# inception_3a/5x5 (Conv2D)       (None, 28, 28, 32)   12832       zero_padding2d_1[0][0]
# __________________________________________________________________________________________________
# inception_3a/pool_proj (Conv2D) (None, 28, 28, 32)   6176        inception_3a/pool[0][0]
# __________________________________________________________________________________________________
# inception_3a/output (Concatenat (None, 28, 28, 256)  0           inception_3a/1x1[0][0]
#                                                                  inception_3a/3x3[0][0]
#                                                                  inception_3a/5x5[0][0]
#                                                                  inception_3a/pool_proj[0][0]
# __________________________________________________________________________________________________
# inception_3b/3x3_reduce (Conv2D (None, 28, 28, 128)  32896       inception_3a/output[0][0]
# __________________________________________________________________________________________________
# inception_3b/5x5_reduce (Conv2D (None, 28, 28, 32)   8224        inception_3a/output[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_2 (ZeroPadding2D (None, 30, 30, 128)  0           inception_3b/3x3_reduce[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_3 (ZeroPadding2D (None, 32, 32, 32)   0           inception_3b/5x5_reduce[0][0]
# __________________________________________________________________________________________________
# inception_3b/pool (MaxPooling2D (None, 28, 28, 256)  0           inception_3a/output[0][0]
# __________________________________________________________________________________________________
# inception_3b/1x1 (Conv2D)       (None, 28, 28, 128)  32896       inception_3a/output[0][0]
# __________________________________________________________________________________________________
# inception_3b/3x3 (Conv2D)       (None, 28, 28, 192)  221376      zero_padding2d_2[0][0]
# __________________________________________________________________________________________________
# inception_3b/5x5 (Conv2D)       (None, 28, 28, 96)   76896       zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# inception_3b/pool_proj (Conv2D) (None, 28, 28, 64)   16448       inception_3b/pool[0][0]
# __________________________________________________________________________________________________
# inception_3b/output (Concatenat (None, 28, 28, 480)  0           inception_3b/1x1[0][0]
#                                                                  inception_3b/3x3[0][0]
#                                                                  inception_3b/5x5[0][0]
#                                                                  inception_3b/pool_proj[0][0]
# __________________________________________________________________________________________________
# pool3/3x3_s2 (MaxPooling2D)     (None, 14, 14, 480)  0           inception_3b/output[0][0]
# __________________________________________________________________________________________________
# inception_4a/3x3_reduce (Conv2D (None, 14, 14, 96)   46176       pool3/3x3_s2[0][0]
# __________________________________________________________________________________________________
# inception_4a/5x5_reduce (Conv2D (None, 14, 14, 16)   7696        pool3/3x3_s2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_4 (ZeroPadding2D (None, 16, 16, 96)   0           inception_4a/3x3_reduce[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_5 (ZeroPadding2D (None, 18, 18, 16)   0           inception_4a/5x5_reduce[0][0]
# __________________________________________________________________________________________________
# inception_4a/pool (MaxPooling2D (None, 14, 14, 480)  0           pool3/3x3_s2[0][0]
# __________________________________________________________________________________________________
# inception_4a/1x1 (Conv2D)       (None, 14, 14, 192)  92352       pool3/3x3_s2[0][0]
# __________________________________________________________________________________________________
# inception_4a/3x3 (Conv2D)       (None, 14, 14, 208)  179920      zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# inception_4a/5x5 (Conv2D)       (None, 14, 14, 48)   19248       zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# inception_4a/pool_proj (Conv2D) (None, 14, 14, 64)   30784       inception_4a/pool[0][0]
# __________________________________________________________________________________________________
# inception_4a/output (Concatenat (None, 14, 14, 512)  0           inception_4a/1x1[0][0]
#                                                                  inception_4a/3x3[0][0]
#                                                                  inception_4a/5x5[0][0]
#                                                                  inception_4a/pool_proj[0][0]
# __________________________________________________________________________________________________
# inception_4b/3x3_reduce (Conv2D (None, 14, 14, 112)  57456       inception_4a/output[0][0]
# __________________________________________________________________________________________________
# inception_4b/5x5_reduce (Conv2D (None, 14, 14, 24)   12312       inception_4a/output[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_6 (ZeroPadding2D (None, 16, 16, 112)  0           inception_4b/3x3_reduce[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_7 (ZeroPadding2D (None, 18, 18, 24)   0           inception_4b/5x5_reduce[0][0]
# __________________________________________________________________________________________________
# inception_4b/pool (MaxPooling2D (None, 14, 14, 512)  0           inception_4a/output[0][0]
# __________________________________________________________________________________________________
# inception_4b/1x1 (Conv2D)       (None, 14, 14, 160)  82080       inception_4a/output[0][0]
# __________________________________________________________________________________________________
# inception_4b/3x3 (Conv2D)       (None, 14, 14, 224)  226016      zero_padding2d_6[0][0]
# __________________________________________________________________________________________________
# inception_4b/5x5 (Conv2D)       (None, 14, 14, 64)   38464       zero_padding2d_7[0][0]
# __________________________________________________________________________________________________
# inception_4b/pool_proj (Conv2D) (None, 14, 14, 64)   32832       inception_4b/pool[0][0]
# __________________________________________________________________________________________________
# inception_4b/output (Concatenat (None, 14, 14, 512)  0           inception_4b/1x1[0][0]
#                                                                  inception_4b/3x3[0][0]
#                                                                  inception_4b/5x5[0][0]
#                                                                  inception_4b/pool_proj[0][0]
# __________________________________________________________________________________________________
# inception_4c/3x3_reduce (Conv2D (None, 14, 14, 128)  65664       inception_4b/output[0][0]
# __________________________________________________________________________________________________
# inception_4c/5x5_reduce (Conv2D (None, 14, 14, 24)   12312       inception_4b/output[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_8 (ZeroPadding2D (None, 16, 16, 128)  0           inception_4c/3x3_reduce[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_9 (ZeroPadding2D (None, 18, 18, 24)   0           inception_4c/5x5_reduce[0][0]
# __________________________________________________________________________________________________
# inception_4c/pool (MaxPooling2D (None, 14, 14, 512)  0           inception_4b/output[0][0]
# __________________________________________________________________________________________________
# inception_4c/1x1 (Conv2D)       (None, 14, 14, 128)  65664       inception_4b/output[0][0]
# __________________________________________________________________________________________________
# inception_4c/3x3 (Conv2D)       (None, 14, 14, 256)  295168      zero_padding2d_8[0][0]
# __________________________________________________________________________________________________
# inception_4c/5x5 (Conv2D)       (None, 14, 14, 64)   38464       zero_padding2d_9[0][0]
# __________________________________________________________________________________________________
# inception_4c/pool_proj (Conv2D) (None, 14, 14, 64)   32832       inception_4c/pool[0][0]
# __________________________________________________________________________________________________
# inception_4c/output (Concatenat (None, 14, 14, 512)  0           inception_4c/1x1[0][0]
#                                                                  inception_4c/3x3[0][0]
#                                                                  inception_4c/5x5[0][0]
#                                                                  inception_4c/pool_proj[0][0]
# __________________________________________________________________________________________________
# inception_4d/3x3_reduce (Conv2D (None, 14, 14, 144)  73872       inception_4c/output[0][0]
# __________________________________________________________________________________________________
# inception_4d/5x5_reduce (Conv2D (None, 14, 14, 32)   16416       inception_4c/output[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_10 (ZeroPadding2 (None, 16, 16, 144)  0           inception_4d/3x3_reduce[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_11 (ZeroPadding2 (None, 18, 18, 32)   0           inception_4d/5x5_reduce[0][0]
# __________________________________________________________________________________________________
# inception_4d/pool (MaxPooling2D (None, 14, 14, 512)  0           inception_4c/output[0][0]
# __________________________________________________________________________________________________
# inception_4d/1x1 (Conv2D)       (None, 14, 14, 112)  57456       inception_4c/output[0][0]
# __________________________________________________________________________________________________
# inception_4d/3x3 (Conv2D)       (None, 14, 14, 288)  373536      zero_padding2d_10[0][0]
# __________________________________________________________________________________________________
# inception_4d/5x5 (Conv2D)       (None, 14, 14, 64)   51264       zero_padding2d_11[0][0]
# __________________________________________________________________________________________________
# inception_4d/pool_proj (Conv2D) (None, 14, 14, 64)   32832       inception_4d/pool[0][0]
# __________________________________________________________________________________________________
# inception_4d/output (Concatenat (None, 14, 14, 528)  0           inception_4d/1x1[0][0]
#                                                                  inception_4d/3x3[0][0]
#                                                                  inception_4d/5x5[0][0]
#                                                                  inception_4d/pool_proj[0][0]
# __________________________________________________________________________________________________
# inception_4e/3x3_reduce (Conv2D (None, 14, 14, 160)  84640       inception_4d/output[0][0]
# __________________________________________________________________________________________________
# inception_4e/5x5_reduce (Conv2D (None, 14, 14, 32)   16928       inception_4d/output[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_12 (ZeroPadding2 (None, 16, 16, 160)  0           inception_4e/3x3_reduce[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_13 (ZeroPadding2 (None, 18, 18, 32)   0           inception_4e/5x5_reduce[0][0]
# __________________________________________________________________________________________________
# inception_4e/pool (MaxPooling2D (None, 14, 14, 528)  0           inception_4d/output[0][0]
# __________________________________________________________________________________________________
# inception_4e/1x1 (Conv2D)       (None, 14, 14, 256)  135424      inception_4d/output[0][0]
# __________________________________________________________________________________________________
# inception_4e/3x3 (Conv2D)       (None, 14, 14, 320)  461120      zero_padding2d_12[0][0]
# __________________________________________________________________________________________________
# inception_4e/5x5 (Conv2D)       (None, 14, 14, 128)  102528      zero_padding2d_13[0][0]
# __________________________________________________________________________________________________
# inception_4e/pool_proj (Conv2D) (None, 14, 14, 128)  67712       inception_4e/pool[0][0]
# __________________________________________________________________________________________________
# inception_4e/output (Concatenat (None, 14, 14, 832)  0           inception_4e/1x1[0][0]
#                                                                  inception_4e/3x3[0][0]
#                                                                  inception_4e/5x5[0][0]
#                                                                  inception_4e/pool_proj[0][0]
# __________________________________________________________________________________________________
# pool4/3x3_s2 (MaxPooling2D)     (None, 7, 7, 832)    0           inception_4e/output[0][0]
# __________________________________________________________________________________________________
# inception_5a/3x3_reduce (Conv2D (None, 7, 7, 160)    133280      pool4/3x3_s2[0][0]
# __________________________________________________________________________________________________
# inception_5a/5x5_reduce (Conv2D (None, 7, 7, 32)     26656       pool4/3x3_s2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_14 (ZeroPadding2 (None, 9, 9, 160)    0           inception_5a/3x3_reduce[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_15 (ZeroPadding2 (None, 11, 11, 32)   0           inception_5a/5x5_reduce[0][0]
# __________________________________________________________________________________________________
# inception_5a/pool (MaxPooling2D (None, 7, 7, 832)    0           pool4/3x3_s2[0][0]
# __________________________________________________________________________________________________
# inception_5a/1x1 (Conv2D)       (None, 7, 7, 256)    213248      pool4/3x3_s2[0][0]
# __________________________________________________________________________________________________
# inception_5a/3x3 (Conv2D)       (None, 7, 7, 320)    461120      zero_padding2d_14[0][0]
# __________________________________________________________________________________________________
# inception_5a/5x5 (Conv2D)       (None, 7, 7, 128)    102528      zero_padding2d_15[0][0]
# __________________________________________________________________________________________________
# inception_5a/pool_proj (Conv2D) (None, 7, 7, 128)    106624      inception_5a/pool[0][0]
# __________________________________________________________________________________________________
# inception_5a/output (Concatenat (None, 7, 7, 832)    0           inception_5a/1x1[0][0]
#                                                                  inception_5a/3x3[0][0]
#                                                                  inception_5a/5x5[0][0]
#                                                                  inception_5a/pool_proj[0][0]
# __________________________________________________________________________________________________
# inception_5b/3x3_reduce (Conv2D (None, 7, 7, 192)    159936      inception_5a/output[0][0]
# __________________________________________________________________________________________________
# inception_5b/5x5_reduce (Conv2D (None, 7, 7, 48)     39984       inception_5a/output[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_16 (ZeroPadding2 (None, 9, 9, 192)    0           inception_5b/3x3_reduce[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_17 (ZeroPadding2 (None, 11, 11, 48)   0           inception_5b/5x5_reduce[0][0]
# __________________________________________________________________________________________________
# inception_5b/pool (MaxPooling2D (None, 7, 7, 832)    0           inception_5a/output[0][0]
# __________________________________________________________________________________________________
# loss1/ave_pool (AveragePooling2 (None, 4, 4, 512)    0           inception_4a/output[0][0]
# __________________________________________________________________________________________________
# loss2/ave_pool (AveragePooling2 (None, 4, 4, 528)    0           inception_4d/output[0][0]
# __________________________________________________________________________________________________
# inception_5b/1x1 (Conv2D)       (None, 7, 7, 384)    319872      inception_5a/output[0][0]
# __________________________________________________________________________________________________
# inception_5b/3x3 (Conv2D)       (None, 7, 7, 384)    663936      zero_padding2d_16[0][0]
# __________________________________________________________________________________________________
# inception_5b/5x5 (Conv2D)       (None, 7, 7, 128)    153728      zero_padding2d_17[0][0]
# __________________________________________________________________________________________________
# inception_5b/pool_proj (Conv2D) (None, 7, 7, 128)    106624      inception_5b/pool[0][0]
# __________________________________________________________________________________________________
# loss1/conv (Conv2D)             (None, 4, 4, 128)    65664       loss1/ave_pool[0][0]
# __________________________________________________________________________________________________
# loss2/conv (Conv2D)             (None, 4, 4, 128)    67712       loss2/ave_pool[0][0]
# __________________________________________________________________________________________________
# inception_5b/output (Concatenat (None, 7, 7, 1024)   0           inception_5b/1x1[0][0]
#                                                                  inception_5b/3x3[0][0]
#                                                                  inception_5b/5x5[0][0]
#                                                                  inception_5b/pool_proj[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 2048)         0           loss1/conv[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 2048)         0           loss2/conv[0][0]
# __________________________________________________________________________________________________
# pool5/7x7_s2 (AveragePooling2D) (None, 1, 1, 1024)   0           inception_5b/output[0][0]
# __________________________________________________________________________________________________
# loss1/fc (Dense)                (None, 1024)         2098176     flatten[0][0]
# __________________________________________________________________________________________________
# loss2/fc (Dense)                (None, 1024)         2098176     flatten_1[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 1024)         0           pool5/7x7_s2[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 1024)         0           loss1/fc[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 1024)         0           loss2/fc[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 1024)         0           flatten_2[0][0]
# __________________________________________________________________________________________________
# loss1/classifier (Dense)        (None, 257)          263425      dropout[0][0]
# __________________________________________________________________________________________________
# loss2/classifier (Dense)        (None, 257)          263425      dropout_1[0][0]
# __________________________________________________________________________________________________
# loss3/classifier (Dense)        (None, 257)          263425      dropout_2[0][0]
# ==================================================================================================
# Total params: 11,093,555
# Trainable params: 11,093,555
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# 폴더 생성

os.makedirs(os.path.join(dir,'model_output',number,model.name), exist_ok=True)
os.makedirs(os.path.join(dir,'train_valid_output',number), exist_ok=True)

# %%
# 참고 : https://github.com/OverLordGoldDragon/keras-adamw

import sys
sys.path.append('/content/drive/My Drive/Colab Notebooks/Paper')
import utils
import optimizers_v2
from utils import get_weight_decays, fill_dict_in_order
from utils import reset_seeds, K_eval
from optimizers_v2 import AdamW, NadamW, SGDW

# %%
# top-5 accuracy 출력
import functools
top5_acc = functools.partial(ks.metrics.top_k_categorical_accuracy, k=5)
top5_acc.__name__ = 'top5_acc'

# %%
#optimizer = SGDW(model=model, use_cosine_annealing=False, total_iterations = len(x_train) // batch_sizes, nesterov=True, momentum=0.9)
optimizer = AdamW(model=model, use_cosine_annealing=False, total_iterations = len(x_train) // batch_sizes)
#optimizer = Adam()
filepath =  os.path.join(dir,'model_output',number,model.name,'{epoch:03d}.h5')

callbacks_list = [ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_weights_only=False, save_best_only=True, mode='min'),
                  ModelCheckpoint(filepath, monitor='val_loss3/classifier_accuracy', verbose=1, save_weights_only=False, save_best_only=True, mode='max'),
                  #ReduceLROnPlateau(monitor='val_loss',patience=3,factor=0.1,min_lr=1e-5),
                  LearningRateScheduler(lr_schedule,verbose=1)
                  ]                    	

model.compile(optimizer, loss={'loss1/classifier' : 'categorical_crossentropy', 'loss2/classifier' : 'categorical_crossentropy', 'loss3/classifier' : 'categorical_crossentropy'},
              loss_weights={'loss1/classifier' : 0.3, 'loss2/classifier' : 0.3, 'loss3/classifier' : 1.0}, 
              metrics=['accuracy',top5_acc,macro_f1score])

# %%
######## flow_from_directory
#history = model.fit_generator(generate_train_for_three(), steps_per_epoch=int(len(x_train)/batch_sizes),  validation_data = generate_valid_for_three(), epochs=epochs , verbose=1 , callbacks = callbacks_list,validation_steps=int(len(x_valid)/batch_sizes))
history = model.fit(generate_train_for_three(), steps_per_epoch=int(len(x_train)/batch_sizes),  validation_data = generate_valid_for_three(), epochs=epochs , verbose=1 , callbacks = callbacks_list , validation_steps=int(len(x_valid)/batch_sizes))
# Out:
# Found 24509 images belonging to 257 classes.
# Learning rate:  0.0003
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 1/70
# 0.0(L1), 7.235745870133896e-06(L2) weight decay set for conv1/7x7_s2/kernel:0
# 0.0(L1), 7.235745870133896e-06(L2) weight decay set for conv2/3x3_reduce/kernel:0
# 0.0(L1), 7.235745870133896e-06(L2) weight decay set for conv2/3x3/kernel:0
# 0.0(L1), 7.235745870133896e-06(L2) weight decay set for inception_3a/3x3_reduce/kernel:0
# 0.0(L1), 7.235745870133896e-06(L2) weight decay set for inception_3a/5x5_reduce/kernel:0
# 0.0(L1), 7.235745870133896e-06(L2) weight decay set for inception_3a/1x1/kernel:0
# 0.0(L1), 7.235745870133896e-06(L2) weight decay set for inception_3a/3x3/kernel:0
# 0.0(L1), 7.235745870133896e-06(L2) weight decay set for inception_3a/5x5/kernel:0
# 0.0(L1), 7.235745870133896e-06(L2) weight decay set for inception_3a/pool_proj/kernel:0
# 0.0(L1), 7.235745870133896e-06(L2) weight decay set for inception_3b/3x3_reduce/kernel:0
# 0.0(L1), 7.235745870133896e-06(L2) weight decay set for inception_3b/5x5_reduce/kernel:0
# 0.0(L1), 7.235745870133896e-06(L2) weight decay set for inception_3b/1x1/kernel:0
# 0.0(L1), 7.235745870133896e-06(L2) weight decay set for inception_3b/3x3/kernel:0
# 0.0(L1), 7.235745870133896e-06(L2) weight decay set for inception_3b/5x5/kernel:0
# 0.0(L1), 7.235745870133896e-06(L2) weight decay set for inception_3b/pool_proj/kernel:0
# 0.0(L1), 7.235745870133896e-06(L2) weight decay set for inception_4a/3x3_reduce/kernel:0
# 0.0(L1), 7.235745870133896e-06(L2) weight decay set for inception_4a/5x5_reduce/kernel:0
# 0.0(L1), 7.235745870133896e-06(L2) weight decay set for inception_4a/1x1/kernel:0
# 0.0(L1), 7.235745870133896e-06(L2) weight decay set for inception_4a/3x3/kernel:0
# 0.0(L1), 7.235745870133896e-06(L2) weight decay set for inception_4a/5x5/kernel:0
# 0.0(L1), 7.235745870133896e-06(L2) weight decay set for inception_4a/pool_proj/kernel:0
# 0.0(L1), 7.235745870133896e-06(L2) weight decay set for inception_4b/3x3_reduce/kernel:0
# 0.0(L1), 7.235745870133896e-06(L2) weight decay set for inception_4b/5x5_reduce/kernel:0
# 0.0(L1), 7.235745870133896e-06(L2) weight decay set for inception_4b/1x1/kernel:0
# 0.0(L1), 7.235745870133896e-06(L2) weight decay set for inception_4b/3x3/kernel:0
# 0.0(L1), 7.235745870133896e-06(L2) weight decay set for inception_4b/5x5/kernel:0
# 0.0(L1), 7.235745870133896e-06(L2) weight decay set for inception_4b/pool_proj/kernel:0
# 0.0(L1), 7.235745870133896e-06(L2) weight decay set for inception_4c/3x3_reduce/kernel:0
# 0.0(L1), 7.235745870133896e-06(L2) weight decay set for inception_4c/5x5_reduce/kernel:0
# 0.0(L1), 7.235745870133896e-06(L2) weight decay set for inception_4c/1x1/kernel:0
# 0.0(L1), 7.235745870133896e-06(L2) weight decay set for inception_4c/3x3/kernel:0
# 0.0(L1), 7.235745870133896e-06(L2) weight decay set for inception_4c/5x5/kernel:0
# 0.0(L1), 7.235745870133896e-06(L2) weight decay set for inception_4c/pool_proj/kernel:0
# 0.0(L1), 7.235745870133896e-06(L2) weight decay set for inception_4d/3x3_reduce/kernel:0
# 0.0(L1), 7.235745870133896e-06(L2) weight decay set for inception_4d/5x5_reduce/kernel:0
# 0.0(L1), 7.235745870133896e-06(L2) weight decay set for inception_4d/1x1/kernel:0
# 0.0(L1), 7.235745870133896e-06(L2) weight decay set for inception_4d/3x3/kernel:0
# 0.0(L1), 7.235745870133896e-06(L2) weight decay set for inception_4d/5x5/kernel:0
# 0.0(L1), 7.235745870133896e-06(L2) weight decay set for inception_4d/pool_proj/kernel:0
# 0.0(L1), 7.235745870133896e-06(L2) weight decay set for inception_4e/3x3_reduce/kernel:0
# 0.0(L1), 7.235745870133896e-06(L2) weight decay set for inception_4e/5x5_reduce/kernel:0
# 0.0(L1), 7.235745870133896e-06(L2) weight decay set for inception_4e/1x1/kernel:0
# 0.0(L1), 7.235745870133896e-06(L2) weight decay set for inception_4e/3x3/kernel:0
# 0.0(L1), 7.235745870133896e-06(L2) weight decay set for inception_4e/5x5/kernel:0
# 0.0(L1), 7.235745870133896e-06(L2) weight decay set for inception_4e/pool_proj/kernel:0
# 0.0(L1), 7.235745870133896e-06(L2) weight decay set for inception_5a/3x3_reduce/kernel:0
# 0.0(L1), 7.235745870133896e-06(L2) weight decay set for inception_5a/5x5_reduce/kernel:0
# 0.0(L1), 7.235745870133896e-06(L2) weight decay set for inception_5a/1x1/kernel:0
# 0.0(L1), 7.235745870133896e-06(L2) weight decay set for inception_5a/3x3/kernel:0
# 0.0(L1), 7.235745870133896e-06(L2) weight decay set for inception_5a/5x5/kernel:0
# 0.0(L1), 7.235745870133896e-06(L2) weight decay set for inception_5a/pool_proj/kernel:0
# 0.0(L1), 7.235745870133896e-06(L2) weight decay set for inception_5b/3x3_reduce/kernel:0
# 0.0(L1), 7.235745870133896e-06(L2) weight decay set for inception_5b/5x5_reduce/kernel:0
# 0.0(L1), 7.235745870133896e-06(L2) weight decay set for inception_5b/1x1/kernel:0
# 0.0(L1), 7.235745870133896e-06(L2) weight decay set for inception_5b/3x3/kernel:0
# 0.0(L1), 7.235745870133896e-06(L2) weight decay set for inception_5b/5x5/kernel:0
# 0.0(L1), 7.235745870133896e-06(L2) weight decay set for inception_5b/pool_proj/kernel:0
# 0.0(L1), 7.235745870133896e-06(L2) weight decay set for loss1/conv/kernel:0
# 0.0(L1), 7.235745870133896e-06(L2) weight decay set for loss2/conv/kernel:0
# 0.0(L1), 7.235745870133896e-06(L2) weight decay set for loss1/fc/kernel:0
# 0.0(L1), 7.235745870133896e-06(L2) weight decay set for loss2/fc/kernel:0
# 0.0(L1), 7.235745870133896e-06(L2) weight decay set for loss1/classifier/kernel:0
# 0.0(L1), 7.235745870133896e-06(L2) weight decay set for loss2/classifier/kernel:0
# 0.0(L1), 7.235745870133896e-06(L2) weight decay set for loss3/classifier/kernel:0
# 191/191 [==============================] - ETA: 0s - loss: 8.6347 - loss1/classifier_loss: 5.3864 - loss2/classifier_loss: 5.4092 - loss3/classifier_loss: 5.3960 - loss1/classifier_accuracy: 0.0479 - loss1/classifier_top5_acc: 0.1116 - loss1/classifier_macro_f1score: 1.1184e-04 - loss2/classifier_accuracy: 0.0405 - loss2/classifier_top5_acc: 0.1058 - loss2/classifier_macro_f1score: 7.1350e-05 - loss3/classifier_accuracy: 0.0376 - loss3/classifier_top5_acc: 0.1099 - loss3/classifier_macro_f1score: 7.0785e-05  Found 2980 images belonging to 257 classes.
#
# Epoch 00001: val_loss improved from inf to 8.18384, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/GoogleNet/001.h5
#
# Epoch 00001: val_loss3/classifier_accuracy improved from -inf to 0.06216, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/GoogleNet/001.h5
# 191/191 [==============================] - 15009s 79s/step - loss: 8.6347 - loss1/classifier_loss: 5.3864 - loss2/classifier_loss: 5.4092 - loss3/classifier_loss: 5.3960 - loss1/classifier_accuracy: 0.0479 - loss1/classifier_top5_acc: 0.1116 - loss1/classifier_macro_f1score: 1.1184e-04 - loss2/classifier_accuracy: 0.0405 - loss2/classifier_top5_acc: 0.1058 - loss2/classifier_macro_f1score: 7.1350e-05 - loss3/classifier_accuracy: 0.0376 - loss3/classifier_top5_acc: 0.1099 - loss3/classifier_macro_f1score: 7.0785e-05 - val_loss: 8.1838 - val_loss1/classifier_loss: 5.0057 - val_loss2/classifier_loss: 5.1158 - val_loss3/classifier_loss: 5.1474 - val_loss1/classifier_accuracy: 0.0764 - val_loss1/classifier_top5_acc: 0.1705 - val_loss1/classifier_macro_f1score: 0.0015 - val_loss2/classifier_accuracy: 0.0690 - val_loss2/classifier_top5_acc: 0.1461 - val_loss2/classifier_macro_f1score: 0.0029 - val_loss3/classifier_accuracy: 0.0622 - val_loss3/classifier_top5_acc: 0.1461 - val_loss3/classifier_macro_f1score: 0.0026
# Learning rate:  0.0003
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 2/70
# 191/191 [==============================] - ETA: 0s - loss: 7.9459 - loss1/classifier_loss: 4.9177 - loss2/classifier_loss: 4.9969 - loss3/classifier_loss: 4.9715 - loss1/classifier_accuracy: 0.0929 - loss1/classifier_top5_acc: 0.1867 - loss1/classifier_macro_f1score: 0.0045 - loss2/classifier_accuracy: 0.0850 - loss2/classifier_top5_acc: 0.1687 - loss2/classifier_macro_f1score: 0.0047 - loss3/classifier_accuracy: 0.0819 - loss3/classifier_top5_acc: 0.1679 - loss3/classifier_macro_f1score: 0.0045
# Epoch 00002: val_loss improved from 8.18384 to 7.56106, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/GoogleNet/002.h5
#
# Epoch 00002: val_loss3/classifier_accuracy improved from 0.06216 to 0.09749, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/GoogleNet/002.h5
# 191/191 [==============================] - 430s 2s/step - loss: 7.9459 - loss1/classifier_loss: 4.9177 - loss2/classifier_loss: 4.9969 - loss3/classifier_loss: 4.9715 - loss1/classifier_accuracy: 0.0929 - loss1/classifier_top5_acc: 0.1867 - loss1/classifier_macro_f1score: 0.0045 - loss2/classifier_accuracy: 0.0850 - loss2/classifier_top5_acc: 0.1687 - loss2/classifier_macro_f1score: 0.0047 - loss3/classifier_accuracy: 0.0819 - loss3/classifier_top5_acc: 0.1679 - loss3/classifier_macro_f1score: 0.0045 - val_loss: 7.5611 - val_loss1/classifier_loss: 4.6756 - val_loss2/classifier_loss: 4.7363 - val_loss3/classifier_loss: 4.7375 - val_loss1/classifier_accuracy: 0.1135 - val_loss1/classifier_top5_acc: 0.2500 - val_loss1/classifier_macro_f1score: 0.0057 - val_loss2/classifier_accuracy: 0.1039 - val_loss2/classifier_top5_acc: 0.2140 - val_loss2/classifier_macro_f1score: 0.0070 - val_loss3/classifier_accuracy: 0.0975 - val_loss3/classifier_top5_acc: 0.2055 - val_loss3/classifier_macro_f1score: 0.0069
# Learning rate:  0.0003
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 3/70
# 191/191 [==============================] - ETA: 0s - loss: 7.4285 - loss1/classifier_loss: 4.6081 - loss2/classifier_loss: 4.6728 - loss3/classifier_loss: 4.6443 - loss1/classifier_accuracy: 0.1213 - loss1/classifier_top5_acc: 0.2391 - loss1/classifier_macro_f1score: 0.0078 - loss2/classifier_accuracy: 0.1112 - loss2/classifier_top5_acc: 0.2223 - loss2/classifier_macro_f1score: 0.0085 - loss3/classifier_accuracy: 0.1077 - loss3/classifier_top5_acc: 0.2181 - loss3/classifier_macro_f1score: 0.0081
# Epoch 00003: val_loss improved from 7.56106 to 7.10878, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/GoogleNet/003.h5
#
# Epoch 00003: val_loss3/classifier_accuracy improved from 0.09749 to 0.12602, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/GoogleNet/003.h5
# 191/191 [==============================] - 415s 2s/step - loss: 7.4285 - loss1/classifier_loss: 4.6081 - loss2/classifier_loss: 4.6728 - loss3/classifier_loss: 4.6443 - loss1/classifier_accuracy: 0.1213 - loss1/classifier_top5_acc: 0.2391 - loss1/classifier_macro_f1score: 0.0078 - loss2/classifier_accuracy: 0.1112 - loss2/classifier_top5_acc: 0.2223 - loss2/classifier_macro_f1score: 0.0085 - loss3/classifier_accuracy: 0.1077 - loss3/classifier_top5_acc: 0.2181 - loss3/classifier_macro_f1score: 0.0081 - val_loss: 7.1088 - val_loss1/classifier_loss: 4.3644 - val_loss2/classifier_loss: 4.4181 - val_loss3/classifier_loss: 4.4740 - val_loss1/classifier_accuracy: 0.1559 - val_loss1/classifier_top5_acc: 0.3030 - val_loss1/classifier_macro_f1score: 0.0086 - val_loss2/classifier_accuracy: 0.1440 - val_loss2/classifier_top5_acc: 0.2863 - val_loss2/classifier_macro_f1score: 0.0100 - val_loss3/classifier_accuracy: 0.1260 - val_loss3/classifier_top5_acc: 0.2605 - val_loss3/classifier_macro_f1score: 0.0089
# Learning rate:  0.0003
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 4/70
# 191/191 [==============================] - ETA: 0s - loss: 7.1032 - loss1/classifier_loss: 4.4076 - loss2/classifier_loss: 4.4681 - loss3/classifier_loss: 4.4405 - loss1/classifier_accuracy: 0.1446 - loss1/classifier_top5_acc: 0.2792 - loss1/classifier_macro_f1score: 0.0099 - loss2/classifier_accuracy: 0.1317 - loss2/classifier_top5_acc: 0.2635 - loss2/classifier_macro_f1score: 0.0104 - loss3/classifier_accuracy: 0.1324 - loss3/classifier_top5_acc: 0.2600 - loss3/classifier_macro_f1score: 0.0102
# Epoch 00004: val_loss improved from 7.10878 to 6.96404, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/GoogleNet/004.h5
#
# Epoch 00004: val_loss3/classifier_accuracy improved from 0.12602 to 0.14504, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/GoogleNet/004.h5
# 191/191 [==============================] - 422s 2s/step - loss: 7.1032 - loss1/classifier_loss: 4.4076 - loss2/classifier_loss: 4.4681 - loss3/classifier_loss: 4.4405 - loss1/classifier_accuracy: 0.1446 - loss1/classifier_top5_acc: 0.2792 - loss1/classifier_macro_f1score: 0.0099 - loss2/classifier_accuracy: 0.1317 - loss2/classifier_top5_acc: 0.2635 - loss2/classifier_macro_f1score: 0.0104 - loss3/classifier_accuracy: 0.1324 - loss3/classifier_top5_acc: 0.2600 - loss3/classifier_macro_f1score: 0.0102 - val_loss: 6.9640 - val_loss1/classifier_loss: 4.2687 - val_loss2/classifier_loss: 4.3101 - val_loss3/classifier_loss: 4.3904 - val_loss1/classifier_accuracy: 0.1776 - val_loss1/classifier_top5_acc: 0.3224 - val_loss1/classifier_macro_f1score: 0.0099 - val_loss2/classifier_accuracy: 0.1658 - val_loss2/classifier_top5_acc: 0.3081 - val_loss2/classifier_macro_f1score: 0.0108 - val_loss3/classifier_accuracy: 0.1450 - val_loss3/classifier_top5_acc: 0.2762 - val_loss3/classifier_macro_f1score: 0.0104
# Learning rate:  0.0003
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 5/70
# 191/191 [==============================] - ETA: 0s - loss: 6.7777 - loss1/classifier_loss: 4.2048 - loss2/classifier_loss: 4.2779 - loss3/classifier_loss: 4.2329 - loss1/classifier_accuracy: 0.1672 - loss1/classifier_top5_acc: 0.3231 - loss1/classifier_macro_f1score: 0.0128 - loss2/classifier_accuracy: 0.1559 - loss2/classifier_top5_acc: 0.2998 - loss2/classifier_macro_f1score: 0.0126 - loss3/classifier_accuracy: 0.1545 - loss3/classifier_top5_acc: 0.3018 - loss3/classifier_macro_f1score: 0.0129
# Epoch 00005: val_loss improved from 6.96404 to 6.55717, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/GoogleNet/005.h5
#
# Epoch 00005: val_loss3/classifier_accuracy improved from 0.14504 to 0.17391, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/GoogleNet/005.h5
# 191/191 [==============================] - 410s 2s/step - loss: 6.7777 - loss1/classifier_loss: 4.2048 - loss2/classifier_loss: 4.2779 - loss3/classifier_loss: 4.2329 - loss1/classifier_accuracy: 0.1672 - loss1/classifier_top5_acc: 0.3231 - loss1/classifier_macro_f1score: 0.0128 - loss2/classifier_accuracy: 0.1559 - loss2/classifier_top5_acc: 0.2998 - loss2/classifier_macro_f1score: 0.0126 - loss3/classifier_accuracy: 0.1545 - loss3/classifier_top5_acc: 0.3018 - loss3/classifier_macro_f1score: 0.0129 - val_loss: 6.5572 - val_loss1/classifier_loss: 3.9632 - val_loss2/classifier_loss: 4.0428 - val_loss3/classifier_loss: 4.1554 - val_loss1/classifier_accuracy: 0.2130 - val_loss1/classifier_top5_acc: 0.3804 - val_loss1/classifier_macro_f1score: 0.0151 - val_loss2/classifier_accuracy: 0.1953 - val_loss2/classifier_top5_acc: 0.3580 - val_loss2/classifier_macro_f1score: 0.0172 - val_loss3/classifier_accuracy: 0.1739 - val_loss3/classifier_top5_acc: 0.3203 - val_loss3/classifier_macro_f1score: 0.0163
# Learning rate:  0.0003
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 6/70
# 191/191 [==============================] - ETA: 0s - loss: 6.5062 - loss1/classifier_loss: 4.0400 - loss2/classifier_loss: 4.1044 - loss3/classifier_loss: 4.0629 - loss1/classifier_accuracy: 0.1843 - loss1/classifier_top5_acc: 0.3530 - loss1/classifier_macro_f1score: 0.0162 - loss2/classifier_accuracy: 0.1766 - loss2/classifier_top5_acc: 0.3359 - loss2/classifier_macro_f1score: 0.0157 - loss3/classifier_accuracy: 0.1735 - loss3/classifier_top5_acc: 0.3352 - loss3/classifier_macro_f1score: 0.0162
# Epoch 00006: val_loss improved from 6.55717 to 6.42810, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/GoogleNet/006.h5
#
# Epoch 00006: val_loss3/classifier_accuracy did not improve from 0.17391
# 191/191 [==============================] - 409s 2s/step - loss: 6.5062 - loss1/classifier_loss: 4.0400 - loss2/classifier_loss: 4.1044 - loss3/classifier_loss: 4.0629 - loss1/classifier_accuracy: 0.1843 - loss1/classifier_top5_acc: 0.3530 - loss1/classifier_macro_f1score: 0.0162 - loss2/classifier_accuracy: 0.1766 - loss2/classifier_top5_acc: 0.3359 - loss2/classifier_macro_f1score: 0.0157 - loss3/classifier_accuracy: 0.1735 - loss3/classifier_top5_acc: 0.3352 - loss3/classifier_macro_f1score: 0.0162 - val_loss: 6.4281 - val_loss1/classifier_loss: 3.8144 - val_loss2/classifier_loss: 3.9546 - val_loss3/classifier_loss: 4.0974 - val_loss1/classifier_accuracy: 0.2310 - val_loss1/classifier_top5_acc: 0.4158 - val_loss1/classifier_macro_f1score: 0.0191 - val_loss2/classifier_accuracy: 0.2052 - val_loss2/classifier_top5_acc: 0.3804 - val_loss2/classifier_macro_f1score: 0.0173 - val_loss3/classifier_accuracy: 0.1715 - val_loss3/classifier_top5_acc: 0.3407 - val_loss3/classifier_macro_f1score: 0.0171
# Learning rate:  0.0003
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 7/70
# 191/191 [==============================] - ETA: 0s - loss: 6.2437 - loss1/classifier_loss: 3.8914 - loss2/classifier_loss: 3.9579 - loss3/classifier_loss: 3.8889 - loss1/classifier_accuracy: 0.2080 - loss1/classifier_top5_acc: 0.3887 - loss1/classifier_macro_f1score: 0.0191 - loss2/classifier_accuracy: 0.1976 - loss2/classifier_top5_acc: 0.3672 - loss2/classifier_macro_f1score: 0.0196 - loss3/classifier_accuracy: 0.1996 - loss3/classifier_top5_acc: 0.3742 - loss3/classifier_macro_f1score: 0.0194
# Epoch 00007: val_loss improved from 6.42810 to 6.16017, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/GoogleNet/007.h5
#
# Epoch 00007: val_loss3/classifier_accuracy improved from 0.17391 to 0.20380, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/GoogleNet/007.h5
# 191/191 [==============================] - 416s 2s/step - loss: 6.2437 - loss1/classifier_loss: 3.8914 - loss2/classifier_loss: 3.9579 - loss3/classifier_loss: 3.8889 - loss1/classifier_accuracy: 0.2080 - loss1/classifier_top5_acc: 0.3887 - loss1/classifier_macro_f1score: 0.0191 - loss2/classifier_accuracy: 0.1976 - loss2/classifier_top5_acc: 0.3672 - loss2/classifier_macro_f1score: 0.0196 - loss3/classifier_accuracy: 0.1996 - loss3/classifier_top5_acc: 0.3742 - loss3/classifier_macro_f1score: 0.0194 - val_loss: 6.1602 - val_loss1/classifier_loss: 3.6946 - val_loss2/classifier_loss: 3.8273 - val_loss3/classifier_loss: 3.9036 - val_loss1/classifier_accuracy: 0.2408 - val_loss1/classifier_top5_acc: 0.4307 - val_loss1/classifier_macro_f1score: 0.0247 - val_loss2/classifier_accuracy: 0.2201 - val_loss2/classifier_top5_acc: 0.3991 - val_loss2/classifier_macro_f1score: 0.0248 - val_loss3/classifier_accuracy: 0.2038 - val_loss3/classifier_top5_acc: 0.3801 - val_loss3/classifier_macro_f1score: 0.0255
# Learning rate:  0.0003
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 8/70
# 191/191 [==============================] - ETA: 0s - loss: 5.9756 - loss1/classifier_loss: 3.7519 - loss2/classifier_loss: 3.8061 - loss3/classifier_loss: 3.7082 - loss1/classifier_accuracy: 0.2267 - loss1/classifier_top5_acc: 0.4181 - loss1/classifier_macro_f1score: 0.0237 - loss2/classifier_accuracy: 0.2178 - loss2/classifier_top5_acc: 0.3997 - loss2/classifier_macro_f1score: 0.0229 - loss3/classifier_accuracy: 0.2228 - loss3/classifier_top5_acc: 0.4122 - loss3/classifier_macro_f1score: 0.0246
# Epoch 00008: val_loss improved from 6.16017 to 6.07356, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/GoogleNet/008.h5
#
# Epoch 00008: val_loss3/classifier_accuracy improved from 0.20380 to 0.21332, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/GoogleNet/008.h5
# 191/191 [==============================] - 419s 2s/step - loss: 5.9756 - loss1/classifier_loss: 3.7519 - loss2/classifier_loss: 3.8061 - loss3/classifier_loss: 3.7082 - loss1/classifier_accuracy: 0.2267 - loss1/classifier_top5_acc: 0.4181 - loss1/classifier_macro_f1score: 0.0237 - loss2/classifier_accuracy: 0.2178 - loss2/classifier_top5_acc: 0.3997 - loss2/classifier_macro_f1score: 0.0229 - loss3/classifier_accuracy: 0.2228 - loss3/classifier_top5_acc: 0.4122 - loss3/classifier_macro_f1score: 0.0246 - val_loss: 6.0736 - val_loss1/classifier_loss: 3.5911 - val_loss2/classifier_loss: 3.7385 - val_loss3/classifier_loss: 3.8747 - val_loss1/classifier_accuracy: 0.2609 - val_loss1/classifier_top5_acc: 0.4541 - val_loss1/classifier_macro_f1score: 0.0294 - val_loss2/classifier_accuracy: 0.2408 - val_loss2/classifier_top5_acc: 0.4243 - val_loss2/classifier_macro_f1score: 0.0266 - val_loss3/classifier_accuracy: 0.2133 - val_loss3/classifier_top5_acc: 0.3944 - val_loss3/classifier_macro_f1score: 0.0273
# Learning rate:  0.0003
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 9/70
# 191/191 [==============================] - ETA: 0s - loss: 5.7196 - loss1/classifier_loss: 3.6172 - loss2/classifier_loss: 3.6684 - loss3/classifier_loss: 3.5339 - loss1/classifier_accuracy: 0.2462 - loss1/classifier_top5_acc: 0.4438 - loss1/classifier_macro_f1score: 0.0276 - loss2/classifier_accuracy: 0.2359 - loss2/classifier_top5_acc: 0.4245 - loss2/classifier_macro_f1score: 0.0280 - loss3/classifier_accuracy: 0.2493 - loss3/classifier_top5_acc: 0.4506 - loss3/classifier_macro_f1score: 0.0314
# Epoch 00009: val_loss improved from 6.07356 to 5.63713, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/GoogleNet/009.h5
#
# Epoch 00009: val_loss3/classifier_accuracy improved from 0.21332 to 0.24966, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/GoogleNet/009.h5
# 191/191 [==============================] - 424s 2s/step - loss: 5.7196 - loss1/classifier_loss: 3.6172 - loss2/classifier_loss: 3.6684 - loss3/classifier_loss: 3.5339 - loss1/classifier_accuracy: 0.2462 - loss1/classifier_top5_acc: 0.4438 - loss1/classifier_macro_f1score: 0.0276 - loss2/classifier_accuracy: 0.2359 - loss2/classifier_top5_acc: 0.4245 - loss2/classifier_macro_f1score: 0.0280 - loss3/classifier_accuracy: 0.2493 - loss3/classifier_top5_acc: 0.4506 - loss3/classifier_macro_f1score: 0.0314 - val_loss: 5.6371 - val_loss1/classifier_loss: 3.3957 - val_loss2/classifier_loss: 3.4825 - val_loss3/classifier_loss: 3.5737 - val_loss1/classifier_accuracy: 0.2894 - val_loss1/classifier_top5_acc: 0.4946 - val_loss1/classifier_macro_f1score: 0.0363 - val_loss2/classifier_accuracy: 0.2646 - val_loss2/classifier_top5_acc: 0.4820 - val_loss2/classifier_macro_f1score: 0.0343 - val_loss3/classifier_accuracy: 0.2497 - val_loss3/classifier_top5_acc: 0.4494 - val_loss3/classifier_macro_f1score: 0.0342
# Learning rate:  0.0003
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 10/70
# 191/191 [==============================] - ETA: 0s - loss: 5.4813 - loss1/classifier_loss: 3.5039 - loss2/classifier_loss: 3.5326 - loss3/classifier_loss: 3.3704 - loss1/classifier_accuracy: 0.2648 - loss1/classifier_top5_acc: 0.4666 - loss1/classifier_macro_f1score: 0.0317 - loss2/classifier_accuracy: 0.2536 - loss2/classifier_top5_acc: 0.4577 - loss2/classifier_macro_f1score: 0.0320 - loss3/classifier_accuracy: 0.2691 - loss3/classifier_top5_acc: 0.4830 - loss3/classifier_macro_f1score: 0.0370
# Epoch 00010: val_loss improved from 5.63713 to 5.52010, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/GoogleNet/010.h5
#
# Epoch 00010: val_loss3/classifier_accuracy improved from 0.24966 to 0.26257, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/GoogleNet/010.h5
# 191/191 [==============================] - 425s 2s/step - loss: 5.4813 - loss1/classifier_loss: 3.5039 - loss2/classifier_loss: 3.5326 - loss3/classifier_loss: 3.3704 - loss1/classifier_accuracy: 0.2648 - loss1/classifier_top5_acc: 0.4666 - loss1/classifier_macro_f1score: 0.0317 - loss2/classifier_accuracy: 0.2536 - loss2/classifier_top5_acc: 0.4577 - loss2/classifier_macro_f1score: 0.0320 - loss3/classifier_accuracy: 0.2691 - loss3/classifier_top5_acc: 0.4830 - loss3/classifier_macro_f1score: 0.0370 - val_loss: 5.5201 - val_loss1/classifier_loss: 3.3135 - val_loss2/classifier_loss: 3.4061 - val_loss3/classifier_loss: 3.5042 - val_loss1/classifier_accuracy: 0.3037 - val_loss1/classifier_top5_acc: 0.5136 - val_loss1/classifier_macro_f1score: 0.0384 - val_loss2/classifier_accuracy: 0.2809 - val_loss2/classifier_top5_acc: 0.4915 - val_loss2/classifier_macro_f1score: 0.0377 - val_loss3/classifier_accuracy: 0.2626 - val_loss3/classifier_top5_acc: 0.4626 - val_loss3/classifier_macro_f1score: 0.0400
# Learning rate:  0.0003
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 11/70
# 191/191 [==============================] - ETA: 0s - loss: 5.2940 - loss1/classifier_loss: 3.4186 - loss2/classifier_loss: 3.4184 - loss3/classifier_loss: 3.2429 - loss1/classifier_accuracy: 0.2758 - loss1/classifier_top5_acc: 0.4852 - loss1/classifier_macro_f1score: 0.0335 - loss2/classifier_accuracy: 0.2709 - loss2/classifier_top5_acc: 0.4796 - loss2/classifier_macro_f1score: 0.0363 - loss3/classifier_accuracy: 0.2901 - loss3/classifier_top5_acc: 0.5113 - loss3/classifier_macro_f1score: 0.0410
# Epoch 00011: val_loss improved from 5.52010 to 5.22976, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/GoogleNet/011.h5
#
# Epoch 00011: val_loss3/classifier_accuracy improved from 0.26257 to 0.29552, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/GoogleNet/011.h5
# 191/191 [==============================] - 420s 2s/step - loss: 5.2940 - loss1/classifier_loss: 3.4186 - loss2/classifier_loss: 3.4184 - loss3/classifier_loss: 3.2429 - loss1/classifier_accuracy: 0.2758 - loss1/classifier_top5_acc: 0.4852 - loss1/classifier_macro_f1score: 0.0335 - loss2/classifier_accuracy: 0.2709 - loss2/classifier_top5_acc: 0.4796 - loss2/classifier_macro_f1score: 0.0363 - loss3/classifier_accuracy: 0.2901 - loss3/classifier_top5_acc: 0.5113 - loss3/classifier_macro_f1score: 0.0410 - val_loss: 5.2298 - val_loss1/classifier_loss: 3.1867 - val_loss2/classifier_loss: 3.2567 - val_loss3/classifier_loss: 3.2967 - val_loss1/classifier_accuracy: 0.3234 - val_loss1/classifier_top5_acc: 0.5479 - val_loss1/classifier_macro_f1score: 0.0421 - val_loss2/classifier_accuracy: 0.3054 - val_loss2/classifier_top5_acc: 0.5238 - val_loss2/classifier_macro_f1score: 0.0450 - val_loss3/classifier_accuracy: 0.2955 - val_loss3/classifier_top5_acc: 0.5129 - val_loss3/classifier_macro_f1score: 0.0486
# Learning rate:  0.0003
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 12/70
# 191/191 [==============================] - ETA: 0s - loss: 5.0471 - loss1/classifier_loss: 3.2966 - loss2/classifier_loss: 3.2921 - loss3/classifier_loss: 3.0705 - loss1/classifier_accuracy: 0.2931 - loss1/classifier_top5_acc: 0.5106 - loss1/classifier_macro_f1score: 0.0382 - loss2/classifier_accuracy: 0.2929 - loss2/classifier_top5_acc: 0.5049 - loss2/classifier_macro_f1score: 0.0420 - loss3/classifier_accuracy: 0.3192 - loss3/classifier_top5_acc: 0.5482 - loss3/classifier_macro_f1score: 0.0493
# Epoch 00012: val_loss improved from 5.22976 to 5.12628, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/GoogleNet/012.h5
#
# Epoch 00012: val_loss3/classifier_accuracy improved from 0.29552 to 0.31488, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/GoogleNet/012.h5
# 191/191 [==============================] - 405s 2s/step - loss: 5.0471 - loss1/classifier_loss: 3.2966 - loss2/classifier_loss: 3.2921 - loss3/classifier_loss: 3.0705 - loss1/classifier_accuracy: 0.2931 - loss1/classifier_top5_acc: 0.5106 - loss1/classifier_macro_f1score: 0.0382 - loss2/classifier_accuracy: 0.2929 - loss2/classifier_top5_acc: 0.5049 - loss2/classifier_macro_f1score: 0.0420 - loss3/classifier_accuracy: 0.3192 - loss3/classifier_top5_acc: 0.5482 - loss3/classifier_macro_f1score: 0.0493 - val_loss: 5.1263 - val_loss1/classifier_loss: 3.1545 - val_loss2/classifier_loss: 3.1598 - val_loss3/classifier_loss: 3.2320 - val_loss1/classifier_accuracy: 0.3213 - val_loss1/classifier_top5_acc: 0.5455 - val_loss1/classifier_macro_f1score: 0.0442 - val_loss2/classifier_accuracy: 0.3268 - val_loss2/classifier_top5_acc: 0.5499 - val_loss2/classifier_macro_f1score: 0.0502 - val_loss3/classifier_accuracy: 0.3149 - val_loss3/classifier_top5_acc: 0.5296 - val_loss3/classifier_macro_f1score: 0.0532
# Learning rate:  0.0003
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 13/70
# 191/191 [==============================] - ETA: 0s - loss: 4.8564 - loss1/classifier_loss: 3.2077 - loss2/classifier_loss: 3.1816 - loss3/classifier_loss: 2.9397 - loss1/classifier_accuracy: 0.3071 - loss1/classifier_top5_acc: 0.5252 - loss1/classifier_macro_f1score: 0.0428 - loss2/classifier_accuracy: 0.3063 - loss2/classifier_top5_acc: 0.5257 - loss2/classifier_macro_f1score: 0.0467 - loss3/classifier_accuracy: 0.3421 - loss3/classifier_top5_acc: 0.5743 - loss3/classifier_macro_f1score: 0.0565
# Epoch 00013: val_loss improved from 5.12628 to 5.06726, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/GoogleNet/013.h5
#
# Epoch 00013: val_loss3/classifier_accuracy improved from 0.31488 to 0.31963, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/GoogleNet/013.h5
# 191/191 [==============================] - 394s 2s/step - loss: 4.8564 - loss1/classifier_loss: 3.2077 - loss2/classifier_loss: 3.1816 - loss3/classifier_loss: 2.9397 - loss1/classifier_accuracy: 0.3071 - loss1/classifier_top5_acc: 0.5252 - loss1/classifier_macro_f1score: 0.0428 - loss2/classifier_accuracy: 0.3063 - loss2/classifier_top5_acc: 0.5257 - loss2/classifier_macro_f1score: 0.0467 - loss3/classifier_accuracy: 0.3421 - loss3/classifier_top5_acc: 0.5743 - loss3/classifier_macro_f1score: 0.0565 - val_loss: 5.0673 - val_loss1/classifier_loss: 3.0782 - val_loss2/classifier_loss: 3.1710 - val_loss3/classifier_loss: 3.1925 - val_loss1/classifier_accuracy: 0.3414 - val_loss1/classifier_top5_acc: 0.5611 - val_loss1/classifier_macro_f1score: 0.0496 - val_loss2/classifier_accuracy: 0.3190 - val_loss2/classifier_top5_acc: 0.5489 - val_loss2/classifier_macro_f1score: 0.0507 - val_loss3/classifier_accuracy: 0.3196 - val_loss3/classifier_top5_acc: 0.5346 - val_loss3/classifier_macro_f1score: 0.0504
# Learning rate:  0.0003
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 14/70
# 191/191 [==============================] - ETA: 0s - loss: 4.6730 - loss1/classifier_loss: 3.1249 - loss2/classifier_loss: 3.0709 - loss3/classifier_loss: 2.8143 - loss1/classifier_accuracy: 0.3181 - loss1/classifier_top5_acc: 0.5409 - loss1/classifier_macro_f1score: 0.0470 - loss2/classifier_accuracy: 0.3249 - loss2/classifier_top5_acc: 0.5528 - loss2/classifier_macro_f1score: 0.0530 - loss3/classifier_accuracy: 0.3608 - loss3/classifier_top5_acc: 0.5994 - loss3/classifier_macro_f1score: 0.0638
# Epoch 00014: val_loss improved from 5.06726 to 4.88815, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/GoogleNet/014.h5
#
# Epoch 00014: val_loss3/classifier_accuracy improved from 0.31963 to 0.33662, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/GoogleNet/014.h5
# 191/191 [==============================] - 400s 2s/step - loss: 4.6730 - loss1/classifier_loss: 3.1249 - loss2/classifier_loss: 3.0709 - loss3/classifier_loss: 2.8143 - loss1/classifier_accuracy: 0.3181 - loss1/classifier_top5_acc: 0.5409 - loss1/classifier_macro_f1score: 0.0470 - loss2/classifier_accuracy: 0.3249 - loss2/classifier_top5_acc: 0.5528 - loss2/classifier_macro_f1score: 0.0530 - loss3/classifier_accuracy: 0.3608 - loss3/classifier_top5_acc: 0.5994 - loss3/classifier_macro_f1score: 0.0638 - val_loss: 4.8882 - val_loss1/classifier_loss: 3.0003 - val_loss2/classifier_loss: 3.0278 - val_loss3/classifier_loss: 3.0797 - val_loss1/classifier_accuracy: 0.3604 - val_loss1/classifier_top5_acc: 0.5737 - val_loss1/classifier_macro_f1score: 0.0532 - val_loss2/classifier_accuracy: 0.3468 - val_loss2/classifier_top5_acc: 0.5751 - val_loss2/classifier_macro_f1score: 0.0570 - val_loss3/classifier_accuracy: 0.3366 - val_loss3/classifier_top5_acc: 0.5618 - val_loss3/classifier_macro_f1score: 0.0611
# Learning rate:  0.0003
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 15/70
# 191/191 [==============================] - ETA: 0s - loss: 4.4936 - loss1/classifier_loss: 3.0514 - loss2/classifier_loss: 2.9757 - loss3/classifier_loss: 2.6854 - loss1/classifier_accuracy: 0.3294 - loss1/classifier_top5_acc: 0.5586 - loss1/classifier_macro_f1score: 0.0510 - loss2/classifier_accuracy: 0.3412 - loss2/classifier_top5_acc: 0.5714 - loss2/classifier_macro_f1score: 0.0579 - loss3/classifier_accuracy: 0.3817 - loss3/classifier_top5_acc: 0.6270 - loss3/classifier_macro_f1score: 0.0711
# Epoch 00015: val_loss did not improve from 4.88815
#
# Epoch 00015: val_loss3/classifier_accuracy did not improve from 0.33662
# 191/191 [==============================] - 405s 2s/step - loss: 4.4936 - loss1/classifier_loss: 3.0514 - loss2/classifier_loss: 2.9757 - loss3/classifier_loss: 2.6854 - loss1/classifier_accuracy: 0.3294 - loss1/classifier_top5_acc: 0.5586 - loss1/classifier_macro_f1score: 0.0510 - loss2/classifier_accuracy: 0.3412 - loss2/classifier_top5_acc: 0.5714 - loss2/classifier_macro_f1score: 0.0579 - loss3/classifier_accuracy: 0.3817 - loss3/classifier_top5_acc: 0.6270 - loss3/classifier_macro_f1score: 0.0711 - val_loss: 4.9476 - val_loss1/classifier_loss: 3.0280 - val_loss2/classifier_loss: 3.0549 - val_loss3/classifier_loss: 3.1227 - val_loss1/classifier_accuracy: 0.3536 - val_loss1/classifier_top5_acc: 0.5747 - val_loss1/classifier_macro_f1score: 0.0544 - val_loss2/classifier_accuracy: 0.3393 - val_loss2/classifier_top5_acc: 0.5707 - val_loss2/classifier_macro_f1score: 0.0589 - val_loss3/classifier_accuracy: 0.3268 - val_loss3/classifier_top5_acc: 0.5642 - val_loss3/classifier_macro_f1score: 0.0639
# Learning rate:  0.0003
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 16/70
# 191/191 [==============================] - ETA: 0s - loss: 4.3523 - loss1/classifier_loss: 2.9637 - loss2/classifier_loss: 2.8956 - loss3/classifier_loss: 2.5945 - loss1/classifier_accuracy: 0.3443 - loss1/classifier_top5_acc: 0.5723 - loss1/classifier_macro_f1score: 0.0551 - loss2/classifier_accuracy: 0.3540 - loss2/classifier_top5_acc: 0.5852 - loss2/classifier_macro_f1score: 0.0626 - loss3/classifier_accuracy: 0.3993 - loss3/classifier_top5_acc: 0.6437 - loss3/classifier_macro_f1score: 0.0786
# Epoch 00016: val_loss improved from 4.88815 to 4.68088, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/GoogleNet/016.h5
#
# Epoch 00016: val_loss3/classifier_accuracy improved from 0.33662 to 0.36515, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/GoogleNet/016.h5
# 191/191 [==============================] - 407s 2s/step - loss: 4.3523 - loss1/classifier_loss: 2.9637 - loss2/classifier_loss: 2.8956 - loss3/classifier_loss: 2.5945 - loss1/classifier_accuracy: 0.3443 - loss1/classifier_top5_acc: 0.5723 - loss1/classifier_macro_f1score: 0.0551 - loss2/classifier_accuracy: 0.3540 - loss2/classifier_top5_acc: 0.5852 - loss2/classifier_macro_f1score: 0.0626 - loss3/classifier_accuracy: 0.3993 - loss3/classifier_top5_acc: 0.6437 - loss3/classifier_macro_f1score: 0.0786 - val_loss: 4.6809 - val_loss1/classifier_loss: 2.9378 - val_loss2/classifier_loss: 2.8891 - val_loss3/classifier_loss: 2.9328 - val_loss1/classifier_accuracy: 0.3645 - val_loss1/classifier_top5_acc: 0.5904 - val_loss1/classifier_macro_f1score: 0.0635 - val_loss2/classifier_accuracy: 0.3743 - val_loss2/classifier_top5_acc: 0.6060 - val_loss2/classifier_macro_f1score: 0.0715 - val_loss3/classifier_accuracy: 0.3651 - val_loss3/classifier_top5_acc: 0.5954 - val_loss3/classifier_macro_f1score: 0.0749
# Learning rate:  0.0003
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 17/70
# 191/191 [==============================] - ETA: 0s - loss: 4.1875 - loss1/classifier_loss: 2.9054 - loss2/classifier_loss: 2.8148 - loss3/classifier_loss: 2.4715 - loss1/classifier_accuracy: 0.3561 - loss1/classifier_top5_acc: 0.5880 - loss1/classifier_macro_f1score: 0.0586 - loss2/classifier_accuracy: 0.3705 - loss2/classifier_top5_acc: 0.6026 - loss2/classifier_macro_f1score: 0.0674 - loss3/classifier_accuracy: 0.4224 - loss3/classifier_top5_acc: 0.6667 - loss3/classifier_macro_f1score: 0.0872
# Epoch 00017: val_loss improved from 4.68088 to 4.65365, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/GoogleNet/017.h5
#
# Epoch 00017: val_loss3/classifier_accuracy improved from 0.36515 to 0.37534, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/GoogleNet/017.h5
# 191/191 [==============================] - 410s 2s/step - loss: 4.1875 - loss1/classifier_loss: 2.9054 - loss2/classifier_loss: 2.8148 - loss3/classifier_loss: 2.4715 - loss1/classifier_accuracy: 0.3561 - loss1/classifier_top5_acc: 0.5880 - loss1/classifier_macro_f1score: 0.0586 - loss2/classifier_accuracy: 0.3705 - loss2/classifier_top5_acc: 0.6026 - loss2/classifier_macro_f1score: 0.0674 - loss3/classifier_accuracy: 0.4224 - loss3/classifier_top5_acc: 0.6667 - loss3/classifier_macro_f1score: 0.0872 - val_loss: 4.6537 - val_loss1/classifier_loss: 2.9205 - val_loss2/classifier_loss: 2.9019 - val_loss3/classifier_loss: 2.9069 - val_loss1/classifier_accuracy: 0.3696 - val_loss1/classifier_top5_acc: 0.5944 - val_loss1/classifier_macro_f1score: 0.0676 - val_loss2/classifier_accuracy: 0.3699 - val_loss2/classifier_top5_acc: 0.6022 - val_loss2/classifier_macro_f1score: 0.0744 - val_loss3/classifier_accuracy: 0.3753 - val_loss3/classifier_top5_acc: 0.6005 - val_loss3/classifier_macro_f1score: 0.0842
# Learning rate:  0.0003
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 18/70
# 191/191 [==============================] - ETA: 0s - loss: 4.0358 - loss1/classifier_loss: 2.8369 - loss2/classifier_loss: 2.7326 - loss3/classifier_loss: 2.3650 - loss1/classifier_accuracy: 0.3622 - loss1/classifier_top5_acc: 0.5973 - loss1/classifier_macro_f1score: 0.0631 - loss2/classifier_accuracy: 0.3832 - loss2/classifier_top5_acc: 0.6159 - loss2/classifier_macro_f1score: 0.0724 - loss3/classifier_accuracy: 0.4419 - loss3/classifier_top5_acc: 0.6871 - loss3/classifier_macro_f1score: 0.0946
# Epoch 00018: val_loss improved from 4.65365 to 4.51039, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/GoogleNet/018.h5
#
# Epoch 00018: val_loss3/classifier_accuracy improved from 0.37534 to 0.38247, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/GoogleNet/018.h5
# 191/191 [==============================] - 397s 2s/step - loss: 4.0358 - loss1/classifier_loss: 2.8369 - loss2/classifier_loss: 2.7326 - loss3/classifier_loss: 2.3650 - loss1/classifier_accuracy: 0.3622 - loss1/classifier_top5_acc: 0.5973 - loss1/classifier_macro_f1score: 0.0631 - loss2/classifier_accuracy: 0.3832 - loss2/classifier_top5_acc: 0.6159 - loss2/classifier_macro_f1score: 0.0724 - loss3/classifier_accuracy: 0.4419 - loss3/classifier_top5_acc: 0.6871 - loss3/classifier_macro_f1score: 0.0946 - val_loss: 4.5104 - val_loss1/classifier_loss: 2.8484 - val_loss2/classifier_loss: 2.8049 - val_loss3/classifier_loss: 2.8144 - val_loss1/classifier_accuracy: 0.3882 - val_loss1/classifier_top5_acc: 0.6080 - val_loss1/classifier_macro_f1score: 0.0634 - val_loss2/classifier_accuracy: 0.3920 - val_loss2/classifier_top5_acc: 0.6179 - val_loss2/classifier_macro_f1score: 0.0658 - val_loss3/classifier_accuracy: 0.3825 - val_loss3/classifier_top5_acc: 0.6084 - val_loss3/classifier_macro_f1score: 0.0716
# Learning rate:  0.0003
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 19/70
# 191/191 [==============================] - ETA: 0s - loss: 3.8644 - loss1/classifier_loss: 2.7669 - loss2/classifier_loss: 2.6453 - loss3/classifier_loss: 2.2408 - loss1/classifier_accuracy: 0.3765 - loss1/classifier_top5_acc: 0.6141 - loss1/classifier_macro_f1score: 0.0661 - loss2/classifier_accuracy: 0.3991 - loss2/classifier_top5_acc: 0.6350 - loss2/classifier_macro_f1score: 0.0783 - loss3/classifier_accuracy: 0.4659 - loss3/classifier_top5_acc: 0.7123 - loss3/classifier_macro_f1score: 0.1041
# Epoch 00019: val_loss did not improve from 4.51039
#
# Epoch 00019: val_loss3/classifier_accuracy did not improve from 0.38247
# 191/191 [==============================] - 393s 2s/step - loss: 3.8644 - loss1/classifier_loss: 2.7669 - loss2/classifier_loss: 2.6453 - loss3/classifier_loss: 2.2408 - loss1/classifier_accuracy: 0.3765 - loss1/classifier_top5_acc: 0.6141 - loss1/classifier_macro_f1score: 0.0661 - loss2/classifier_accuracy: 0.3991 - loss2/classifier_top5_acc: 0.6350 - loss2/classifier_macro_f1score: 0.0783 - loss3/classifier_accuracy: 0.4659 - loss3/classifier_top5_acc: 0.7123 - loss3/classifier_macro_f1score: 0.1041 - val_loss: 4.6252 - val_loss1/classifier_loss: 2.8059 - val_loss2/classifier_loss: 2.8430 - val_loss3/classifier_loss: 2.9305 - val_loss1/classifier_accuracy: 0.3916 - val_loss1/classifier_top5_acc: 0.6131 - val_loss1/classifier_macro_f1score: 0.0715 - val_loss2/classifier_accuracy: 0.3815 - val_loss2/classifier_top5_acc: 0.6151 - val_loss2/classifier_macro_f1score: 0.0790 - val_loss3/classifier_accuracy: 0.3767 - val_loss3/classifier_top5_acc: 0.6111 - val_loss3/classifier_macro_f1score: 0.0869
# Learning rate:  0.0003
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 20/70
# 191/191 [==============================] - ETA: 0s - loss: 3.7540 - loss1/classifier_loss: 2.7247 - loss2/classifier_loss: 2.5824 - loss3/classifier_loss: 2.1619 - loss1/classifier_accuracy: 0.3847 - loss1/classifier_top5_acc: 0.6243 - loss1/classifier_macro_f1score: 0.0699 - loss2/classifier_accuracy: 0.4063 - loss2/classifier_top5_acc: 0.6475 - loss2/classifier_macro_f1score: 0.0828 - loss3/classifier_accuracy: 0.4773 - loss3/classifier_top5_acc: 0.7268 - loss3/classifier_macro_f1score: 0.1114
# Epoch 00020: val_loss improved from 4.51039 to 4.36603, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/GoogleNet/020.h5
#
# Epoch 00020: val_loss3/classifier_accuracy improved from 0.38247 to 0.40489, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/GoogleNet/020.h5
# 191/191 [==============================] - 392s 2s/step - loss: 3.7540 - loss1/classifier_loss: 2.7247 - loss2/classifier_loss: 2.5824 - loss3/classifier_loss: 2.1619 - loss1/classifier_accuracy: 0.3847 - loss1/classifier_top5_acc: 0.6243 - loss1/classifier_macro_f1score: 0.0699 - loss2/classifier_accuracy: 0.4063 - loss2/classifier_top5_acc: 0.6475 - loss2/classifier_macro_f1score: 0.0828 - loss3/classifier_accuracy: 0.4773 - loss3/classifier_top5_acc: 0.7268 - loss3/classifier_macro_f1score: 0.1114 - val_loss: 4.3660 - val_loss1/classifier_loss: 2.7555 - val_loss2/classifier_loss: 2.7265 - val_loss3/classifier_loss: 2.7214 - val_loss1/classifier_accuracy: 0.3995 - val_loss1/classifier_top5_acc: 0.6240 - val_loss1/classifier_macro_f1score: 0.0766 - val_loss2/classifier_accuracy: 0.3944 - val_loss2/classifier_top5_acc: 0.6264 - val_loss2/classifier_macro_f1score: 0.0859 - val_loss3/classifier_accuracy: 0.4049 - val_loss3/classifier_top5_acc: 0.6250 - val_loss3/classifier_macro_f1score: 0.0947
# Learning rate:  0.0003
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 21/70
# 191/191 [==============================] - ETA: 0s - loss: 3.6075 - loss1/classifier_loss: 2.6610 - loss2/classifier_loss: 2.5040 - loss3/classifier_loss: 2.0580 - loss1/classifier_accuracy: 0.3960 - loss1/classifier_top5_acc: 0.6338 - loss1/classifier_macro_f1score: 0.0734 - loss2/classifier_accuracy: 0.4224 - loss2/classifier_top5_acc: 0.6617 - loss2/classifier_macro_f1score: 0.0876 - loss3/classifier_accuracy: 0.5000 - loss3/classifier_top5_acc: 0.7428 - loss3/classifier_macro_f1score: 0.1206
# Epoch 00021: val_loss did not improve from 4.36603
#
# Epoch 00021: val_loss3/classifier_accuracy improved from 0.40489 to 0.41916, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/GoogleNet/021.h5
# 191/191 [==============================] - 387s 2s/step - loss: 3.6075 - loss1/classifier_loss: 2.6610 - loss2/classifier_loss: 2.5040 - loss3/classifier_loss: 2.0580 - loss1/classifier_accuracy: 0.3960 - loss1/classifier_top5_acc: 0.6338 - loss1/classifier_macro_f1score: 0.0734 - loss2/classifier_accuracy: 0.4224 - loss2/classifier_top5_acc: 0.6617 - loss2/classifier_macro_f1score: 0.0876 - loss3/classifier_accuracy: 0.5000 - loss3/classifier_top5_acc: 0.7428 - loss3/classifier_macro_f1score: 0.1206 - val_loss: 4.3661 - val_loss1/classifier_loss: 2.7113 - val_loss2/classifier_loss: 2.6961 - val_loss3/classifier_loss: 2.7438 - val_loss1/classifier_accuracy: 0.4100 - val_loss1/classifier_top5_acc: 0.6318 - val_loss1/classifier_macro_f1score: 0.0828 - val_loss2/classifier_accuracy: 0.4130 - val_loss2/classifier_top5_acc: 0.6349 - val_loss2/classifier_macro_f1score: 0.0893 - val_loss3/classifier_accuracy: 0.4192 - val_loss3/classifier_top5_acc: 0.6349 - val_loss3/classifier_macro_f1score: 0.1019
# Learning rate:  0.0003
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 22/70
# 191/191 [==============================] - ETA: 0s - loss: 3.5111 - loss1/classifier_loss: 2.6097 - loss2/classifier_loss: 2.4477 - loss3/classifier_loss: 1.9939 - loss1/classifier_accuracy: 0.4017 - loss1/classifier_top5_acc: 0.6479 - loss1/classifier_macro_f1score: 0.0752 - loss2/classifier_accuracy: 0.4300 - loss2/classifier_top5_acc: 0.6730 - loss2/classifier_macro_f1score: 0.0905 - loss3/classifier_accuracy: 0.5131 - loss3/classifier_top5_acc: 0.7576 - loss3/classifier_macro_f1score: 0.1240
# Epoch 00022: val_loss did not improve from 4.36603
#
# Epoch 00022: val_loss3/classifier_accuracy did not improve from 0.41916
# 191/191 [==============================] - 386s 2s/step - loss: 3.5111 - loss1/classifier_loss: 2.6097 - loss2/classifier_loss: 2.4477 - loss3/classifier_loss: 1.9939 - loss1/classifier_accuracy: 0.4017 - loss1/classifier_top5_acc: 0.6479 - loss1/classifier_macro_f1score: 0.0752 - loss2/classifier_accuracy: 0.4300 - loss2/classifier_top5_acc: 0.6730 - loss2/classifier_macro_f1score: 0.0905 - loss3/classifier_accuracy: 0.5131 - loss3/classifier_top5_acc: 0.7576 - loss3/classifier_macro_f1score: 0.1240 - val_loss: 4.4650 - val_loss1/classifier_loss: 2.7577 - val_loss2/classifier_loss: 2.7538 - val_loss3/classifier_loss: 2.8115 - val_loss1/classifier_accuracy: 0.4025 - val_loss1/classifier_top5_acc: 0.6233 - val_loss1/classifier_macro_f1score: 0.0837 - val_loss2/classifier_accuracy: 0.4052 - val_loss2/classifier_top5_acc: 0.6332 - val_loss2/classifier_macro_f1score: 0.0892 - val_loss3/classifier_accuracy: 0.4001 - val_loss3/classifier_top5_acc: 0.6226 - val_loss3/classifier_macro_f1score: 0.0981
# Learning rate:  0.0003
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 23/70
# ...
# Epoch 00062: val_loss did not improve from 4.23340
#
# Epoch 00062: val_loss3/classifier_accuracy did not improve from 0.48438
# 191/191 [==============================] - 380s 2s/step - loss: 1.4885 - loss1/classifier_loss: 1.8021 - loss2/classifier_loss: 1.4266 - loss3/classifier_loss: 0.5199 - loss1/classifier_accuracy: 0.5552 - loss1/classifier_top5_acc: 0.7895 - loss1/classifier_macro_f1score: 0.1405 - loss2/classifier_accuracy: 0.6295 - loss2/classifier_top5_acc: 0.8486 - loss2/classifier_macro_f1score: 0.1821 - loss3/classifier_accuracy: 0.8497 - loss3/classifier_top5_acc: 0.9685 - loss3/classifier_macro_f1score: 0.2918 - val_loss: 4.6094 - val_loss1/classifier_loss: 2.4442 - val_loss2/classifier_loss: 2.5052 - val_loss3/classifier_loss: 3.1245 - val_loss1/classifier_accuracy: 0.4698 - val_loss1/classifier_top5_acc: 0.6943 - val_loss1/classifier_macro_f1score: 0.1217 - val_loss2/classifier_accuracy: 0.4854 - val_loss2/classifier_top5_acc: 0.7001 - val_loss2/classifier_macro_f1score: 0.1365 - val_loss3/classifier_accuracy: 0.4830 - val_loss3/classifier_top5_acc: 0.6872 - val_loss3/classifier_macro_f1score: 0.1517
# Learning rate:  2.9999999999999997e-06
#
# Epoch 00063: LearningRateScheduler reducing learning rate to 2.9999999999999997e-06.
# Epoch 63/70
# 191/191 [==============================] - ETA: 0s - loss: 1.4928 - loss1/classifier_loss: 1.8141 - loss2/classifier_loss: 1.4298 - loss3/classifier_loss: 0.5196 - loss1/classifier_accuracy: 0.5531 - loss1/classifier_top5_acc: 0.7868 - loss1/classifier_macro_f1score: 0.1377 - loss2/classifier_accuracy: 0.6287 - loss2/classifier_top5_acc: 0.8477 - loss2/classifier_macro_f1score: 0.1811 - loss3/classifier_accuracy: 0.8479 - loss3/classifier_top5_acc: 0.9706 - loss3/classifier_macro_f1score: 0.2891
# Epoch 00063: val_loss did not improve from 4.23340
#
# Epoch 00063: val_loss3/classifier_accuracy did not improve from 0.48438
# 191/191 [==============================] - 377s 2s/step - loss: 1.4928 - loss1/classifier_loss: 1.8141 - loss2/classifier_loss: 1.4298 - loss3/classifier_loss: 0.5196 - loss1/classifier_accuracy: 0.5531 - loss1/classifier_top5_acc: 0.7868 - loss1/classifier_macro_f1score: 0.1377 - loss2/classifier_accuracy: 0.6287 - loss2/classifier_top5_acc: 0.8477 - loss2/classifier_macro_f1score: 0.1811 - loss3/classifier_accuracy: 0.8479 - loss3/classifier_top5_acc: 0.9706 - loss3/classifier_macro_f1score: 0.2891 - val_loss: 4.6087 - val_loss1/classifier_loss: 2.4401 - val_loss2/classifier_loss: 2.5014 - val_loss3/classifier_loss: 3.1263 - val_loss1/classifier_accuracy: 0.4732 - val_loss1/classifier_top5_acc: 0.6960 - val_loss1/classifier_macro_f1score: 0.1223 - val_loss2/classifier_accuracy: 0.4857 - val_loss2/classifier_top5_acc: 0.6997 - val_loss2/classifier_macro_f1score: 0.1352 - val_loss3/classifier_accuracy: 0.4827 - val_loss3/classifier_top5_acc: 0.6916 - val_loss3/classifier_macro_f1score: 0.1529
# Learning rate:  2.9999999999999997e-06
#
# Epoch 00064: LearningRateScheduler reducing learning rate to 2.9999999999999997e-06.
# Epoch 64/70
# 191/191 [==============================] - ETA: 0s - loss: 1.4991 - loss1/classifier_loss: 1.8146 - loss2/classifier_loss: 1.4339 - loss3/classifier_loss: 0.5246 - loss1/classifier_accuracy: 0.5507 - loss1/classifier_top5_acc: 0.7887 - loss1/classifier_macro_f1score: 0.1368 - loss2/classifier_accuracy: 0.6290 - loss2/classifier_top5_acc: 0.8462 - loss2/classifier_macro_f1score: 0.1804 - loss3/classifier_accuracy: 0.8465 - loss3/classifier_top5_acc: 0.9687 - loss3/classifier_macro_f1score: 0.2902
# Epoch 00064: val_loss did not improve from 4.23340
#
# Epoch 00064: val_loss3/classifier_accuracy did not improve from 0.48438
# 191/191 [==============================] - 376s 2s/step - loss: 1.4991 - loss1/classifier_loss: 1.8146 - loss2/classifier_loss: 1.4339 - loss3/classifier_loss: 0.5246 - loss1/classifier_accuracy: 0.5507 - loss1/classifier_top5_acc: 0.7887 - loss1/classifier_macro_f1score: 0.1368 - loss2/classifier_accuracy: 0.6290 - loss2/classifier_top5_acc: 0.8462 - loss2/classifier_macro_f1score: 0.1804 - loss3/classifier_accuracy: 0.8465 - loss3/classifier_top5_acc: 0.9687 - loss3/classifier_macro_f1score: 0.2902 - val_loss: 4.5839 - val_loss1/classifier_loss: 2.4386 - val_loss2/classifier_loss: 2.4951 - val_loss3/classifier_loss: 3.1037 - val_loss1/classifier_accuracy: 0.4732 - val_loss1/classifier_top5_acc: 0.6984 - val_loss1/classifier_macro_f1score: 0.1227 - val_loss2/classifier_accuracy: 0.4878 - val_loss2/classifier_top5_acc: 0.6994 - val_loss2/classifier_macro_f1score: 0.1361 - val_loss3/classifier_accuracy: 0.4837 - val_loss3/classifier_top5_acc: 0.6902 - val_loss3/classifier_macro_f1score: 0.1520
# Learning rate:  2.9999999999999997e-06
#
# Epoch 00065: LearningRateScheduler reducing learning rate to 2.9999999999999997e-06.
# Epoch 65/70
# 191/191 [==============================] - ETA: 0s - loss: 1.5121 - loss1/classifier_loss: 1.8208 - loss2/classifier_loss: 1.4568 - loss3/classifier_loss: 0.5288 - loss1/classifier_accuracy: 0.5517 - loss1/classifier_top5_acc: 0.7869 - loss1/classifier_macro_f1score: 0.1361 - loss2/classifier_accuracy: 0.6233 - loss2/classifier_top5_acc: 0.8437 - loss2/classifier_macro_f1score: 0.1786 - loss3/classifier_accuracy: 0.8464 - loss3/classifier_top5_acc: 0.9684 - loss3/classifier_macro_f1score: 0.2890
# Epoch 00065: val_loss did not improve from 4.23340
#
# Epoch 00065: val_loss3/classifier_accuracy did not improve from 0.48438
# 191/191 [==============================] - 377s 2s/step - loss: 1.5121 - loss1/classifier_loss: 1.8208 - loss2/classifier_loss: 1.4568 - loss3/classifier_loss: 0.5288 - loss1/classifier_accuracy: 0.5517 - loss1/classifier_top5_acc: 0.7869 - loss1/classifier_macro_f1score: 0.1361 - loss2/classifier_accuracy: 0.6233 - loss2/classifier_top5_acc: 0.8437 - loss2/classifier_macro_f1score: 0.1786 - loss3/classifier_accuracy: 0.8464 - loss3/classifier_top5_acc: 0.9684 - loss3/classifier_macro_f1score: 0.2890 - val_loss: 4.6161 - val_loss1/classifier_loss: 2.4530 - val_loss2/classifier_loss: 2.5186 - val_loss3/classifier_loss: 3.1246 - val_loss1/classifier_accuracy: 0.4681 - val_loss1/classifier_top5_acc: 0.6929 - val_loss1/classifier_macro_f1score: 0.1209 - val_loss2/classifier_accuracy: 0.4813 - val_loss2/classifier_top5_acc: 0.6997 - val_loss2/classifier_macro_f1score: 0.1352 - val_loss3/classifier_accuracy: 0.4786 - val_loss3/classifier_top5_acc: 0.6851 - val_loss3/classifier_macro_f1score: 0.1525
# Learning rate:  2.9999999999999997e-06
#
# Epoch 00066: LearningRateScheduler reducing learning rate to 2.9999999999999997e-06.
# Epoch 66/70
# 191/191 [==============================] - ETA: 0s - loss: 1.4940 - loss1/classifier_loss: 1.7992 - loss2/classifier_loss: 1.4389 - loss3/classifier_loss: 0.5226 - loss1/classifier_accuracy: 0.5561 - loss1/classifier_top5_acc: 0.7917 - loss1/classifier_macro_f1score: 0.1367 - loss2/classifier_accuracy: 0.6281 - loss2/classifier_top5_acc: 0.8482 - loss2/classifier_macro_f1score: 0.1769 - loss3/classifier_accuracy: 0.8482 - loss3/classifier_top5_acc: 0.9683 - loss3/classifier_macro_f1score: 0.2888
# Epoch 00066: val_loss did not improve from 4.23340
#
# Epoch 00066: val_loss3/classifier_accuracy did not improve from 0.48438
# 191/191 [==============================] - 377s 2s/step - loss: 1.4940 - loss1/classifier_loss: 1.7992 - loss2/classifier_loss: 1.4389 - loss3/classifier_loss: 0.5226 - loss1/classifier_accuracy: 0.5561 - loss1/classifier_top5_acc: 0.7917 - loss1/classifier_macro_f1score: 0.1367 - loss2/classifier_accuracy: 0.6281 - loss2/classifier_top5_acc: 0.8482 - loss2/classifier_macro_f1score: 0.1769 - loss3/classifier_accuracy: 0.8482 - loss3/classifier_top5_acc: 0.9683 - loss3/classifier_macro_f1score: 0.2888 - val_loss: 4.5770 - val_loss1/classifier_loss: 2.4360 - val_loss2/classifier_loss: 2.4968 - val_loss3/classifier_loss: 3.0971 - val_loss1/classifier_accuracy: 0.4708 - val_loss1/classifier_top5_acc: 0.6960 - val_loss1/classifier_macro_f1score: 0.1205 - val_loss2/classifier_accuracy: 0.4857 - val_loss2/classifier_top5_acc: 0.7024 - val_loss2/classifier_macro_f1score: 0.1364 - val_loss3/classifier_accuracy: 0.4789 - val_loss3/classifier_top5_acc: 0.6889 - val_loss3/classifier_macro_f1score: 0.1521
# Learning rate:  2.9999999999999997e-06
#
# Epoch 00067: LearningRateScheduler reducing learning rate to 2.9999999999999997e-06.
# Epoch 67/70
# 191/191 [==============================] - ETA: 0s - loss: 1.5044 - loss1/classifier_loss: 1.8111 - loss2/classifier_loss: 1.4470 - loss3/classifier_loss: 0.5270 - loss1/classifier_accuracy: 0.5535 - loss1/classifier_top5_acc: 0.7862 - loss1/classifier_macro_f1score: 0.1379 - loss2/classifier_accuracy: 0.6251 - loss2/classifier_top5_acc: 0.8478 - loss2/classifier_macro_f1score: 0.1799 - loss3/classifier_accuracy: 0.8444 - loss3/classifier_top5_acc: 0.9704 - loss3/classifier_macro_f1score: 0.2881
# Epoch 00067: val_loss did not improve from 4.23340
#
# Epoch 00067: val_loss3/classifier_accuracy did not improve from 0.48438
# 191/191 [==============================] - 379s 2s/step - loss: 1.5044 - loss1/classifier_loss: 1.8111 - loss2/classifier_loss: 1.4470 - loss3/classifier_loss: 0.5270 - loss1/classifier_accuracy: 0.5535 - loss1/classifier_top5_acc: 0.7862 - loss1/classifier_macro_f1score: 0.1379 - loss2/classifier_accuracy: 0.6251 - loss2/classifier_top5_acc: 0.8478 - loss2/classifier_macro_f1score: 0.1799 - loss3/classifier_accuracy: 0.8444 - loss3/classifier_top5_acc: 0.9704 - loss3/classifier_macro_f1score: 0.2881 - val_loss: 4.5573 - val_loss1/classifier_loss: 2.4339 - val_loss2/classifier_loss: 2.4863 - val_loss3/classifier_loss: 3.0812 - val_loss1/classifier_accuracy: 0.4715 - val_loss1/classifier_top5_acc: 0.6953 - val_loss1/classifier_macro_f1score: 0.1189 - val_loss2/classifier_accuracy: 0.4861 - val_loss2/classifier_top5_acc: 0.7007 - val_loss2/classifier_macro_f1score: 0.1341 - val_loss3/classifier_accuracy: 0.4827 - val_loss3/classifier_top5_acc: 0.6868 - val_loss3/classifier_macro_f1score: 0.1489
# Learning rate:  2.9999999999999997e-06
#
# Epoch 00068: LearningRateScheduler reducing learning rate to 2.9999999999999997e-06.
# Epoch 68/70
# 191/191 [==============================] - ETA: 0s - loss: 1.5022 - loss1/classifier_loss: 1.8216 - loss2/classifier_loss: 1.4469 - loss3/classifier_loss: 0.5216 - loss1/classifier_accuracy: 0.5488 - loss1/classifier_top5_acc: 0.7881 - loss1/classifier_macro_f1score: 0.1345 - loss2/classifier_accuracy: 0.6245 - loss2/classifier_top5_acc: 0.8454 - loss2/classifier_macro_f1score: 0.1786 - loss3/classifier_accuracy: 0.8509 - loss3/classifier_top5_acc: 0.9704 - loss3/classifier_macro_f1score: 0.2901
# Epoch 00068: val_loss did not improve from 4.23340
#
# Epoch 00068: val_loss3/classifier_accuracy improved from 0.48438 to 0.48505, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/GoogleNet/068.h5
# 191/191 [==============================] - 385s 2s/step - loss: 1.5022 - loss1/classifier_loss: 1.8216 - loss2/classifier_loss: 1.4469 - loss3/classifier_loss: 0.5216 - loss1/classifier_accuracy: 0.5488 - loss1/classifier_top5_acc: 0.7881 - loss1/classifier_macro_f1score: 0.1345 - loss2/classifier_accuracy: 0.6245 - loss2/classifier_top5_acc: 0.8454 - loss2/classifier_macro_f1score: 0.1786 - loss3/classifier_accuracy: 0.8509 - loss3/classifier_top5_acc: 0.9704 - loss3/classifier_macro_f1score: 0.2901 - val_loss: 4.5610 - val_loss1/classifier_loss: 2.4351 - val_loss2/classifier_loss: 2.4910 - val_loss3/classifier_loss: 3.0832 - val_loss1/classifier_accuracy: 0.4701 - val_loss1/classifier_top5_acc: 0.6909 - val_loss1/classifier_macro_f1score: 0.1211 - val_loss2/classifier_accuracy: 0.4905 - val_loss2/classifier_top5_acc: 0.7024 - val_loss2/classifier_macro_f1score: 0.1363 - val_loss3/classifier_accuracy: 0.4851 - val_loss3/classifier_top5_acc: 0.6899 - val_loss3/classifier_macro_f1score: 0.1534
# Learning rate:  2.9999999999999997e-06
#
# Epoch 00069: LearningRateScheduler reducing learning rate to 2.9999999999999997e-06.
# Epoch 69/70
# 191/191 [==============================] - ETA: 0s - loss: 1.4837 - loss1/classifier_loss: 1.7947 - loss2/classifier_loss: 1.4215 - loss3/classifier_loss: 0.5188 - loss1/classifier_accuracy: 0.5551 - loss1/classifier_top5_acc: 0.7916 - loss1/classifier_macro_f1score: 0.1389 - loss2/classifier_accuracy: 0.6267 - loss2/classifier_top5_acc: 0.8495 - loss2/classifier_macro_f1score: 0.1798 - loss3/classifier_accuracy: 0.8509 - loss3/classifier_top5_acc: 0.9714 - loss3/classifier_macro_f1score: 0.2900
# Epoch 00069: val_loss did not improve from 4.23340
#
# Epoch 00069: val_loss3/classifier_accuracy did not improve from 0.48505
# 191/191 [==============================] - 386s 2s/step - loss: 1.4837 - loss1/classifier_loss: 1.7947 - loss2/classifier_loss: 1.4215 - loss3/classifier_loss: 0.5188 - loss1/classifier_accuracy: 0.5551 - loss1/classifier_top5_acc: 0.7916 - loss1/classifier_macro_f1score: 0.1389 - loss2/classifier_accuracy: 0.6267 - loss2/classifier_top5_acc: 0.8495 - loss2/classifier_macro_f1score: 0.1798 - loss3/classifier_accuracy: 0.8509 - loss3/classifier_top5_acc: 0.9714 - loss3/classifier_macro_f1score: 0.2900 - val_loss: 4.5661 - val_loss1/classifier_loss: 2.4390 - val_loss2/classifier_loss: 2.4938 - val_loss3/classifier_loss: 3.0863 - val_loss1/classifier_accuracy: 0.4701 - val_loss1/classifier_top5_acc: 0.6957 - val_loss1/classifier_macro_f1score: 0.1221 - val_loss2/classifier_accuracy: 0.4871 - val_loss2/classifier_top5_acc: 0.7018 - val_loss2/classifier_macro_f1score: 0.1366 - val_loss3/classifier_accuracy: 0.4837 - val_loss3/classifier_top5_acc: 0.6875 - val_loss3/classifier_macro_f1score: 0.1524
# Learning rate:  2.9999999999999997e-06
#
# Epoch 00070: LearningRateScheduler reducing learning rate to 2.9999999999999997e-06.
# Epoch 70/70
# 191/191 [==============================] - ETA: 0s - loss: 1.4882 - loss1/classifier_loss: 1.7941 - loss2/classifier_loss: 1.4294 - loss3/classifier_loss: 0.5212 - loss1/classifier_accuracy: 0.5542 - loss1/classifier_top5_acc: 0.7921 - loss1/classifier_macro_f1score: 0.1371 - loss2/classifier_accuracy: 0.6286 - loss2/classifier_top5_acc: 0.8494 - loss2/classifier_macro_f1score: 0.1787 - loss3/classifier_accuracy: 0.8508 - loss3/classifier_top5_acc: 0.9695 - loss3/classifier_macro_f1score: 0.2891
# Epoch 00070: val_loss did not improve from 4.23340
#
# Epoch 00070: val_loss3/classifier_accuracy improved from 0.48505 to 0.48539, saving model to /content/drive/My Drive/Colab Notebooks/Paper/CALTECH/No_GAN/model_output/1/GoogleNet/070.h5
# 191/191 [==============================] - 380s 2s/step - loss: 1.4882 - loss1/classifier_loss: 1.7941 - loss2/classifier_loss: 1.4294 - loss3/classifier_loss: 0.5212 - loss1/classifier_accuracy: 0.5542 - loss1/classifier_top5_acc: 0.7921 - loss1/classifier_macro_f1score: 0.1371 - loss2/classifier_accuracy: 0.6286 - loss2/classifier_top5_acc: 0.8494 - loss2/classifier_macro_f1score: 0.1787 - loss3/classifier_accuracy: 0.8508 - loss3/classifier_top5_acc: 0.9695 - loss3/classifier_macro_f1score: 0.2891 - val_loss: 4.5689 - val_loss1/classifier_loss: 2.4468 - val_loss2/classifier_loss: 2.4961 - val_loss3/classifier_loss: 3.0860 - val_loss1/classifier_accuracy: 0.4701 - val_loss1/classifier_top5_acc: 0.6919 - val_loss1/classifier_macro_f1score: 0.1194 - val_loss2/classifier_accuracy: 0.4854 - val_loss2/classifier_top5_acc: 0.7028 - val_loss2/classifier_macro_f1score: 0.1339 - val_loss3/classifier_accuracy: 0.4854 - val_loss3/classifier_top5_acc: 0.6892 - val_loss3/classifier_macro_f1score: 0.1501

# %% [markdown]
# ### 3) GoogLeNet Evaluate

# %%
# 1. epoch=maximum
#var = model.evaluate_generator(generate_test_for_three(),steps=int(len(x_test)/batch_sizes))
var = model.evaluate(generate_test_for_three(),steps=int(len(x_test)/batch_sizes))
print('[Test Loss: %.4f /  Test Top-1 Accuracy: %.4f / Test Top-5 Accuracy: %.4f / Test Macro f1: %.4f]\n' % (var[0],var[-3],var[-2],var[-1]))
# Out:
# Found 3118 images belonging to 257 classes.
# 24/24 [==============================] - 1640s 68s/step - loss: 4.6542 - loss1/classifier_loss: 2.5056 - loss2/classifier_loss: 2.5676 - loss3/classifier_loss: 3.1322 - loss1/classifier_accuracy: 0.4580 - loss1/classifier_top5_acc: 0.6693 - loss1/classifier_macro_f1score: 0.1181 - loss2/classifier_accuracy: 0.4684 - loss2/classifier_top5_acc: 0.6787 - loss2/classifier_macro_f1score: 0.1339 - loss3/classifier_accuracy: 0.4648 - loss3/classifier_top5_acc: 0.6784 - loss3/classifier_macro_f1score: 0.1488
# [Test Loss: 4.6542 /  Test Top-1 Accuracy: 0.4648 / Test Top-5 Accuracy: 0.6784 / Test Macro f1: 0.1488]

# %%
loss=history.history['loss']
val_loss=history.history['val_loss']
acc=history.history['loss3/classifier_accuracy']
val_acc=history.history['val_loss3/classifier_accuracy']
top5_acc=history.history['loss3/classifier_top5_acc']
val_top5_acc=history.history['val_loss3/classifier_top5_acc']
f1=history.history['loss3/classifier_macro_f1score']
val_f1=history.history['val_loss3/classifier_macro_f1score']
epochs=range(1,len(acc)+1)

data = np.array([epochs,loss,val_loss,acc,val_acc,top5_acc,val_top5_acc,f1,val_f1]).T

# %%
# data save
# epochs, loss, val_loss, acc, val_acc, top5_acc, val_top5_acc, f1, val_f1

np.savetxt(os.path.join(dir,'train_valid_output',number,model.name+'.txt'),data)

# %%
# data import
data = np.loadtxt(os.path.join(dir,'train_valid_output',number,'GoogleNet.txt'))

# %%
epochs=data[:,0]
loss=data[:,1]
val_loss=data[:,2]
acc=data[:,3]
val_acc=data[:,4]
top5_acc=data[:,5]
val_top5_acc=data[:,6]

# %%
plt.plot(epochs[1:],acc[1:],'b',label='Training 1-Acc')
plt.plot(epochs[1:],val_acc[1:],'r',label='Validation 1-Acc')
plt.title('Training and Validation Top-1 Accuracy')
plt.legend()
plt.figure()

plt.plot(epochs[1:],top5_acc[1:],'b',label='Training 5-Acc')
plt.plot(epochs[1:],val_top5_acc[1:],'r',label='Validation 5-Acc')
plt.title('Training and Validation Top-5 Accuracy')
plt.legend()
plt.figure()

plt.plot(epochs[10:],loss[10:],'b',label='Training Loss')
plt.plot(epochs[10:],val_loss[10:],'r',label='Validation Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()

# %%
# 이 아래는 내가 인위적으로 살펴보고 싶은 epoch에 대해서 결과값 출력 / Inception-V1

# %%
# 참고 : https://github.com/OverLordGoldDragon/keras-adamw

import sys
sys.path.append('/content/drive/My Drive/Colab Notebooks/Paper')
import utils
import optimizers_v2
from utils import get_weight_decays, fill_dict_in_order
from utils import reset_seeds, K_eval
from optimizers_v2 import AdamW, NadamW, SGDW

# %%
# top-5 accuracy 출력
import functools
top5_acc = functools.partial(ks.metrics.top_k_categorical_accuracy, k=5)
top5_acc.__name__ = 'top5_acc'

# %%
model=load_model(os.path.join(dir,'model_output',number,'GoogleNet','070.h5'),custom_objects={"macro_f1score": macro_f1score,"top5_acc":top5_acc,"LRN":LRN,"PoolHelper":PoolHelper, "AdamW":AdamW})

# %%
# 2. epoch=?
var = model.evaluate(generate_test_for_three(),steps=int(len(x_test)/batch_sizes))
print('[Test Loss: %.4f /  Test Top-1 Accuracy: %.4f / Test Top-5 Accuracy: %.4f / Test Macro f1: %.4f]\n' % (var[0],var[-3],var[-2],var[-1]))
# Out:
# Found 3118 images belonging to 257 classes.
# 24/24 [==============================] - 1673s 70s/step - loss: 4.6323 - loss1/classifier_loss: 2.5033 - loss2/classifier_loss: 2.5606 - loss3/classifier_loss: 3.1132 - loss1/classifier_accuracy: 0.4583 - loss1/classifier_top5_acc: 0.6689 - loss1/classifier_macro_f1score: 0.1183 - loss2/classifier_accuracy: 0.4691 - loss2/classifier_top5_acc: 0.6794 - loss2/classifier_macro_f1score: 0.1324 - loss3/classifier_accuracy: 0.4671 - loss3/classifier_top5_acc: 0.6797 - loss3/classifier_macro_f1score: 0.1470
# [Test Loss: 4.6323 /  Test Top-1 Accuracy: 0.4671 / Test Top-5 Accuracy: 0.6797 / Test Macro f1: 0.1470]
