# %%
#모형 출처 : https://github.com/titu1994/keras-squeeze-excite-network

# %% [markdown]
# # [DenseNet121]

# %% [markdown]
# *KU LeeDongGyu*

# %% [markdown]
# ## Contents
# ---

# %% [markdown]
# 1. Data Preprocessing
# ```
# 1) Data Import
# 2) Data Augmentation
# ```
# 2. Support Functions & Almost Original DenseNet121
# ```
# 1) Support Functions
# 2) Almost orginal DenseNet121
# ```
# 3. DenseNet121
# ```
# 1) DenseNet121
# 2) DenseNet121 Evaluate
# ```

# %% [markdown]
# ### Install Packages

# %% [markdown]
# ### Module

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/My Drive/Colab Notebooks/Paper
# Out:
# /content/drive/My Drive/Colab Notebooks/Paper

# %%
from f1score import macro_f1score,weighted_f1score

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import cv2
import tensorflow as tf
from tensorflow import keras as ks
from tensorflow.keras import backend as K 
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, Input, Concatenate, ZeroPadding2D ,GlobalMaxPooling2D, Reshape , Lambda , Add, Multiply
from tensorflow.keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D, Activation, BatchNormalization, AveragePooling2D , ZeroPadding2D, SeparableConv2D , LeakyReLU
from tensorflow.keras.layers import add, concatenate, multiply
from tensorflow.keras.optimizers import Adam, RMSprop , SGD
from tensorflow.keras.callbacks import EarlyStopping , LearningRateScheduler, ModelCheckpoint, CSVLogger, Callback, ReduceLROnPlateau
from tensorflow.keras.regularizers import l1,l2,l1_l2
from tensorflow.keras.models import Model , load_model , Sequential
from tensorflow.keras.utils import plot_model , to_categorical, get_file
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
os.getcwd()
# Out:
# '/content/drive/My Drive/Colab Notebooks/Paper'

# %%
tf.__version__
# Out:
# '2.3.0'

# %%
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 16832219937785272586
# , name: "/device:XLA_CPU:0"
# device_type: "XLA_CPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 1307350900758897025
# physical_device_desc: "device: XLA_CPU device"
# , name: "/device:XLA_GPU:0"
# device_type: "XLA_GPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 14034290136608146296
# physical_device_desc: "device: XLA_GPU device"
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 15473775744
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 17191848492276004068
# physical_device_desc: "device: 0, name: Tesla V100-SXM2-16GB, pci bus id: 0000:00:04.0, compute capability: 7.0"
# ]

# %%
# !cat /proc/cpuinfo
# Out:
# processor	: 0
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 85
# model name	: Intel(R) Xeon(R) CPU @ 2.00GHz
# stepping	: 3
# microcode	: 0x1
# cpu MHz		: 2000.164
# cache size	: 39424 KB
# physical id	: 0
# siblings	: 4
# core id		: 0
# cpu cores	: 2
# apicid		: 0
# initial apicid	: 0
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm mpx avx512f avx512dq rdseed adx smap clflushopt clwb avx512cd avx512bw avx512vl xsaveopt xsavec xgetbv1 xsaves arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs taa
# bogomips	: 4000.32
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 46 bits physical, 48 bits virtual
# power management:
#
# processor	: 1
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 85
# model name	: Intel(R) Xeon(R) CPU @ 2.00GHz
# stepping	: 3
# microcode	: 0x1
# cpu MHz		: 2000.164
# cache size	: 39424 KB
# physical id	: 0
# siblings	: 4
# core id		: 1
# cpu cores	: 2
# apicid		: 2
# initial apicid	: 2
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm mpx avx512f avx512dq rdseed adx smap clflushopt clwb avx512cd avx512bw avx512vl xsaveopt xsavec xgetbv1 xsaves arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs taa
# bogomips	: 4000.32
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 46 bits physical, 48 bits virtual
# power management:
#
# processor	: 2
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 85
# model name	: Intel(R) Xeon(R) CPU @ 2.00GHz
# stepping	: 3
# microcode	: 0x1
# cpu MHz		: 2000.164
# cache size	: 39424 KB
# physical id	: 0
# siblings	: 4
# core id		: 0
# cpu cores	: 2
# apicid		: 1
# initial apicid	: 1
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm mpx avx512f avx512dq rdseed adx smap clflushopt clwb avx512cd avx512bw avx512vl xsaveopt xsavec xgetbv1 xsaves arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs taa
# bogomips	: 4000.32
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 46 bits physical, 48 bits virtual
# power management:
#
# processor	: 3
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 85
# model name	: Intel(R) Xeon(R) CPU @ 2.00GHz
# stepping	: 3
# microcode	: 0x1
# cpu MHz		: 2000.164
# cache size	: 39424 KB
# physical id	: 0
# siblings	: 4
# core id		: 1
# cpu cores	: 2
# apicid		: 3
# initial apicid	: 3
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm mpx avx512f avx512dq rdseed adx smap clflushopt clwb avx512cd avx512bw avx512vl xsaveopt xsavec xgetbv1 xsaves arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs taa
# bogomips	: 4000.32
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 46 bits physical, 48 bits virtual
# power management:

# %% [markdown]
# ## 1. Data Preprocessing
# ---

# %% [markdown]
# ### 1) Data Import

# %%
# 바꿔서 살펴 볼 것들
# CALTECH, CIFAR100, FER, MIT
data_name = 'FER'
gan_type = 'No_GAN'
number = '1'
size = 224 # sizes after cropping
super_size = 256 # sizes before cropping 
input_sizes = (size,size,3)
batch_sizes = 64
weight_decay = 1e-3
epochs = 70

# %%
# 참고 : https://stackoverflow.com/questions/32419510/how-to-get-reproducible-results-in-keras/52897216#52897216
# setting the seed number for random number generation for reproducibility.

from numpy.random import seed
import random


if number=='1':
    seed_num = 200225
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)
elif number=='2':
    seed_num = 727
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)
elif number=='3':
    seed_num = 115
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)
elif number=='4':
    seed_num = 501
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)
elif number=='5':
    seed_num = 517
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)

# %%
# data import

if data_name=='FER' :
    x_train =  np.zeros(28698)
    x_valid = np.zeros(3589)
    x_test = np.zeros(3588)
    classes = 7 
    tr_center = [0.50793296, 0.50793296, 0.50793296]
elif data_name=='MIT':
    x_train = np.zeros(12466)
    x_valid = np.zeros(1564)
    x_test = np.zeros(1590)
    classes = 67 
    tr_center = [0.47916578, 0.42029615, 0.36046057]
elif data_name=='CALTECH':
    x_train = np.zeros(24510)
    x_valid = np.zeros(2980)
    x_test = np.zeros(3118)
    classes = 257
    tr_center = [0.51397761, 0.49525248, 0.46555727]
elif data_name=='CIFAR100':
    x_train = np.zeros(44923)
    x_valid = np.zeros(5077)
    x_test = np.zeros(10000)
    classes = 100
    tr_center = [0.53442983, 0.51355958, 0.46462564]

# %%
dir = os.path.join(os.getcwd(),data_name,gan_type)

# %% [markdown]
# ### 2) Data Augmentation

# %%
# 참고 : https://jkjung-avt.github.io/keras-image-cropping/

def random_crop(img, random_crop_size):
    # Note: image_data_format is 'channel_last'
    assert img.shape[2] == 3 # img.shape[2] 가 3(rgb)이 아니면 assertion error 발생
    height, width = img.shape[0], img.shape[1]
    dy, dx = random_crop_size
    x = np.random.randint(0, width - dx + 1)
    y = np.random.randint(0, height - dy + 1)
    return img[y:(y+dy), x:(x+dx), :]


def crop_generator(batches, crop_length):
    """Take as input a Keras ImageGen (Iterator) and generate random
    crops from the image batches generated by the original iterator.
    """
    while True:
        batch_x, batch_y = next(batches)
        batch_crops = np.zeros((batch_x.shape[0], crop_length, crop_length, 3))
        for i in range(batch_x.shape[0]):
            batch_crops[i] = random_crop(batch_x[i], (crop_length, crop_length))
        yield (batch_crops, batch_y)

# %%
from tensorflow.keras.preprocessing.image import img_to_array,load_img
import glob

# 데이터 전체에 대해 centering 진행함.

def read_cal_image(img_path): 
    x = img_to_array(load_img(img_path)) # x는 채널별 평균값
    y = x.shape[0] * x.shape[1]# y는 데이터별 픽셀 수 (비중)

    x = 1/255. * x # scaling하고, centering값을 뽑아냄.
    x = np.mean(x, axis=(0,1))
    
    return np.hstack([x,y])

def calculate_centered_mean(dataset_path,x_train=x_train):
    num = len(x_train)
    space = np.empty((num,4))
    i=0

    for p in glob.glob(os.path.join(dataset_path,'*/*.*')) :
        space[i] = read_cal_image(p)
        i += 1

    ratio = space[:,3] / np.sum(space[:,3])

    return np.average(space[:,0:3],axis=0,weights=ratio)


# 아래의 함수를 돌려서 나온 결과값을 중심화 값으로 설정.

# train_mean = calculate_centered_mean(os.path.join(dir,'data/train')).reshape((1,1,3))

# %%
datagen_tr = ImageDataGenerator(
    rescale=1/255.,
    horizontal_flip=True,
    featurewise_center=True,
    featurewise_std_normalization=False,
    rotation_range=10,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=[0.9,1.0],
    fill_mode = 'nearest')
datagen_val = ImageDataGenerator(rescale=1/255.,featurewise_center=True)
datagen_tes = ImageDataGenerator(rescale=1/255.,featurewise_center=True)

# 원래는 이 자리에 fit 매서드를 써야하지만, 그냥 내가 중심화함수를 만들고 적용함. 

# 중심화 설정
datagen_tr.mean = np.array(tr_center, dtype=np.float32).reshape((1,1,3)) # RGB
datagen_val.mean = np.array(tr_center, dtype=np.float32).reshape((1,1,3)) # RGB
datagen_tes.mean = np.array(tr_center, dtype=np.float32).reshape((1,1,3)) # RGB

# %%
train_batches = datagen_tr.flow_from_directory(directory=os.path.join(dir,'data/train'),target_size=(super_size,super_size),batch_size=batch_sizes,class_mode='categorical') # fer : 28698 / mit : 12466 / caltech : 24509 / cifar : 44923
train_generator= crop_generator(train_batches, size)
valid_generator = datagen_val.flow_from_directory(directory=os.path.join(dir,'data/valid'),target_size=(size,size),batch_size=batch_sizes,class_mode='categorical') # fer : 3589 / mit : 1564 / caltech : 2980 / cifar : 5077
test_generator = datagen_tes.flow_from_directory(directory=os.path.join(dir,'data/test'),target_size=(size,size),batch_size=batch_sizes,class_mode='categorical') # fer : 3588 / mit : 1590 / caltech : 3118 / cifar : 10000
# Out:
# Found 28698 images belonging to 7 classes.
# Found 3589 images belonging to 7 classes.
# Found 3588 images belonging to 7 classes.

# %% [markdown]
# ## 2. Support Functions & Almost Original DenseNet121
# ---

# %% [markdown]
# ### 1) Support Functions

# %%
# def lr_schedule(epoch):
#     init_lr = 1e-4
#     k = 0.04
#     lr = init_lr * np.exp(-k*epoch)
#     print('Learning rate: ', lr)
#     return lr

def lr_schedule(epoch):
    lr = 1e-3
    if epoch < 30:
        lr = lr
    elif epoch < 60 :
        lr = lr * 0.1
    else:
        lr = lr * 0.01
    print('Learning rate: ', lr)
    return lr

# %%
def __conv_block(ip, nb_filter, bottleneck=False, dropout_rate=None, weight_decay=weight_decay):

    concat_axis = -1

    x = BatchNormalization(axis=concat_axis, epsilon=1.1e-5)(ip)
    x = Activation('relu')(x)

    if bottleneck:
        inter_channel = nb_filter * 4  # Obtained from https://github.com/liuzhuang13/DenseNet/blob/master/densenet.lua

        x = Conv2D(inter_channel, (1, 1), kernel_initializer='he_uniform', padding='same', use_bias=False,
                   kernel_regularizer=l2(weight_decay))(x)
        x = BatchNormalization(axis=concat_axis, epsilon=1.1e-5)(x)
        x = Activation('relu')(x)

    x = Conv2D(nb_filter, (3, 3), kernel_initializer='he_uniform', padding='same', use_bias=False, kernel_regularizer=l2(weight_decay))(x)
    if dropout_rate:
        x = Dropout(dropout_rate)(x)

    return x

# %%
def __dense_block(x, nb_layers, nb_filter, growth_rate, bottleneck=False, dropout_rate=None, weight_decay=weight_decay,
                  grow_nb_filters=True, return_concat_list=False):

    concat_axis = -1

    x_list = [x]

    for i in range(nb_layers):
        cb = __conv_block(x, growth_rate, bottleneck, dropout_rate, weight_decay)
        x_list.append(cb)

        x = concatenate([x, cb], axis=concat_axis)

        if grow_nb_filters:
            nb_filter += growth_rate

    if return_concat_list:
        return x, nb_filter, x_list
    else:
        return x, nb_filter

# %%
def __transition_block(ip, nb_filter, compression=1.0, weight_decay=weight_decay):

    concat_axis = -1

    x = BatchNormalization(axis=concat_axis, epsilon=1.1e-5)(ip)
    x = Activation('relu')(x)
    x = Conv2D(int(nb_filter * compression), (1, 1), kernel_initializer='he_uniform', padding='same', use_bias=False,
               kernel_regularizer=l2(weight_decay))(x)
    x = AveragePooling2D((2, 2), strides=(2, 2))(x)


    return x

# %%
def __create_dense_net(nb_classes, img_input, depth=40, nb_dense_block=3, growth_rate=12, nb_filter=-1,
                       nb_layers_per_block=-1, bottleneck=False, reduction=0.0, dropout_rate=None, weight_decay=weight_decay,
                       subsample_initial_block=False, activation='softmax'):

    concat_axis = -1

    if reduction != 0.0:
        assert 1.0 >= reduction > 0.0, 'reduction value must lie between 0.0 and 1.0'

    # layers in each dense block
    if type(nb_layers_per_block) is list or type(nb_layers_per_block) is tuple:
        nb_layers = list(nb_layers_per_block)  # Convert tuple to list

        assert len(nb_layers) == nb_dense_block, 'If list, nb_layer is used as provided. ' \
                                                 'Note that list size must be (nb_dense_block)'
        final_nb_layer = nb_layers[-1]
        nb_layers = nb_layers[:-1]
    else:
        if nb_layers_per_block == -1:
            assert (depth - 4) % 3 == 0, 'Depth must be 3 N + 4 if nb_layers_per_block == -1'
            count = int((depth - 4) / 3)
            nb_layers = [count for _ in range(nb_dense_block)]
            final_nb_layer = count
        else:
            final_nb_layer = nb_layers_per_block
            nb_layers = [nb_layers_per_block] * nb_dense_block

    # compute initial nb_filter if -1, else accept users initial nb_filter
    if nb_filter <= 0:
        nb_filter = 2 * growth_rate

    # compute compression factor
    compression = 1.0 - reduction

    # Initial convolution
    if subsample_initial_block:
        initial_kernel = (7, 7)
        initial_strides = (2, 2)
    else:
        initial_kernel = (3, 3)
        initial_strides = (1, 1)

    x = Conv2D(nb_filter, initial_kernel, kernel_initializer='he_uniform', padding='same',
               strides=initial_strides, use_bias=False, kernel_regularizer=l2(weight_decay))(img_input)

    if subsample_initial_block:
        x = BatchNormalization(axis=concat_axis, epsilon=1.1e-5)(x)
        x = Activation('relu')(x)
        x = MaxPooling2D((3, 3), strides=(2, 2), padding='same')(x)

    # Add dense blocks
    for block_idx in range(nb_dense_block - 1):
        x, nb_filter = __dense_block(x, nb_layers[block_idx], nb_filter, growth_rate, bottleneck=bottleneck,
                                     dropout_rate=dropout_rate, weight_decay=weight_decay)
        # add transition_block
        x = __transition_block(x, nb_filter, compression=compression, weight_decay=weight_decay)
        nb_filter = int(nb_filter * compression)

    # The last dense_block does not have a transition_block
    x, nb_filter = __dense_block(x, final_nb_layer, nb_filter, growth_rate, bottleneck=bottleneck,
                                 dropout_rate=dropout_rate, weight_decay=weight_decay)

    x = BatchNormalization(axis=concat_axis, epsilon=1.1e-5)(x)
    x = Activation('relu')(x)
    x = GlobalAveragePooling2D()(x)

    x = Dense(nb_classes, kernel_regularizer=l2(weight_decay),  activation=activation)(x)

    return x

# %% [markdown]
# ### 2) Almost Orginial DenseNet121

# %%
def DenseNet(input_shape=None, depth=40, nb_dense_block=3, growth_rate=12, nb_filter=-1, nb_layers_per_block=-1, bottleneck=False,
               reduction=0.0, dropout_rate=0.0, weight_decay=weight_decay, subsample_initial_block=False,
               weights=None, classes=classes, activation='softmax', name=None):


    if activation not in ['softmax', 'sigmoid']:
        raise ValueError('activation must be one of "softmax" or "sigmoid"')

    if activation == 'sigmoid' and classes != 1:
        raise ValueError('sigmoid activation can only be used when classes = 1')

    img_input = Input(shape=input_shape)

    x = __create_dense_net(classes, img_input, depth, nb_dense_block,
                           growth_rate, nb_filter, nb_layers_per_block, bottleneck, reduction,
                           dropout_rate, weight_decay, subsample_initial_block, activation)

    # Ensure that the model takes into account
    # any potential predecessors of `input_tensor`.

    inputs = img_input

    # Create model.
    model = Model(inputs, x, name= name )

    return model

# %%
def DenseNet121(input_shape=None, bottleneck=True, reduction=0.5, growth_rate = 32, dropout_rate=0.0, weight_decay=weight_decay, classes=classes, activation='softmax', name = None):

    return DenseNet(input_shape, depth=121, nb_dense_block=4, growth_rate=growth_rate, nb_filter=64,
                      nb_layers_per_block=[6, 12, 24, 16], bottleneck=bottleneck, reduction=reduction,
                      dropout_rate=dropout_rate, weight_decay=weight_decay, subsample_initial_block=True,
                      classes=classes, activation=activation , name = name)

# %% [markdown]
# ## 3. DenseNet121
#
# ---

# %% [markdown]
# ### 1) DenseNet121

# %%
# densenet

model = DenseNet121(input_shape=input_sizes, classes = classes, dropout_rate = 0.2, growth_rate = 32, name = 'DenseNet121')

# %%
model.summary()
# Out:
# Model: "DenseNet121"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 112, 112, 64) 9408        input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 112, 112, 64) 256         conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 112, 112, 64) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 56, 56, 64)   0           activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 56, 56, 64)   256         max_pooling2d[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 56, 56, 64)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 56, 56, 128)  8192        activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 56, 56, 128)  512         conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 56, 56, 128)  0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 56, 56, 32)   36864       activation_2[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 56, 56, 32)   0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 56, 56, 96)   0           max_pooling2d[0][0]
#                                                                  dropout[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 56, 56, 96)   384         concatenate[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 56, 56, 96)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 56, 56, 128)  12288       activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 56, 56, 128)  512         conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 56, 56, 128)  0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 56, 56, 32)   36864       activation_4[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 56, 56, 32)   0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 56, 56, 128)  0           concatenate[0][0]
#                                                                  dropout_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 56, 56, 128)  512         concatenate_1[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 56, 56, 128)  0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 56, 56, 128)  16384       activation_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 56, 56, 128)  512         conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 56, 56, 128)  0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 56, 56, 32)   36864       activation_6[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 56, 56, 32)   0           conv2d_6[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 56, 56, 160)  0           concatenate_1[0][0]
#                                                                  dropout_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 56, 56, 160)  640         concatenate_2[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 56, 56, 160)  0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 56, 56, 128)  20480       activation_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 56, 56, 128)  512         conv2d_7[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 56, 56, 128)  0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 56, 56, 32)   36864       activation_8[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 56, 56, 32)   0           conv2d_8[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 56, 56, 192)  0           concatenate_2[0][0]
#                                                                  dropout_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 56, 56, 192)  768         concatenate_3[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 56, 56, 192)  0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 56, 56, 128)  24576       activation_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 56, 56, 128)  512         conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 56, 56, 128)  0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 56, 56, 32)   36864       activation_10[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 56, 56, 32)   0           conv2d_10[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 56, 56, 224)  0           concatenate_3[0][0]
#                                                                  dropout_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 56, 56, 224)  896         concatenate_4[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 56, 56, 224)  0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 56, 56, 128)  28672       activation_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 56, 56, 128)  512         conv2d_11[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 56, 56, 128)  0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 56, 56, 32)   36864       activation_12[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 56, 56, 32)   0           conv2d_12[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 56, 56, 256)  0           concatenate_4[0][0]
#                                                                  dropout_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 56, 56, 256)  1024        concatenate_5[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 56, 56, 256)  0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 56, 56, 128)  32768       activation_13[0][0]
# __________________________________________________________________________________________________
# average_pooling2d (AveragePooli (None, 28, 28, 128)  0           conv2d_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 28, 28, 128)  512         average_pooling2d[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 28, 28, 128)  0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 28, 28, 128)  16384       activation_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 28, 28, 128)  512         conv2d_14[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 28, 28, 128)  0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 28, 28, 32)   36864       activation_15[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 28, 28, 32)   0           conv2d_15[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 28, 28, 160)  0           average_pooling2d[0][0]
#                                                                  dropout_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 28, 28, 160)  640         concatenate_6[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 28, 28, 160)  0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 28, 28, 128)  20480       activation_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 28, 28, 128)  512         conv2d_16[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 28, 28, 128)  0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 28, 28, 32)   36864       activation_17[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 28, 28, 32)   0           conv2d_17[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 28, 28, 192)  0           concatenate_6[0][0]
#                                                                  dropout_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 28, 28, 192)  768         concatenate_7[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 28, 28, 192)  0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 28, 28, 128)  24576       activation_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 28, 28, 128)  512         conv2d_18[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 28, 28, 128)  0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 28, 28, 32)   36864       activation_19[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 28, 28, 32)   0           conv2d_19[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 28, 28, 224)  0           concatenate_7[0][0]
#                                                                  dropout_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 28, 28, 224)  896         concatenate_8[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 28, 28, 224)  0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 28, 28, 128)  28672       activation_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 28, 28, 128)  512         conv2d_20[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 28, 28, 128)  0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 28, 28, 32)   36864       activation_21[0][0]
# __________________________________________________________________________________________________
# dropout_9 (Dropout)             (None, 28, 28, 32)   0           conv2d_21[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 28, 28, 256)  0           concatenate_8[0][0]
#                                                                  dropout_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 28, 28, 256)  1024        concatenate_9[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 28, 28, 256)  0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 28, 28, 128)  32768       activation_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 28, 28, 128)  512         conv2d_22[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 28, 28, 128)  0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 28, 28, 32)   36864       activation_23[0][0]
# __________________________________________________________________________________________________
# dropout_10 (Dropout)            (None, 28, 28, 32)   0           conv2d_23[0][0]
# __________________________________________________________________________________________________
# concatenate_10 (Concatenate)    (None, 28, 28, 288)  0           concatenate_9[0][0]
#                                                                  dropout_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 28, 28, 288)  1152        concatenate_10[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 28, 28, 288)  0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 28, 28, 128)  36864       activation_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 28, 28, 128)  512         conv2d_24[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 28, 28, 128)  0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 28, 28, 32)   36864       activation_25[0][0]
# __________________________________________________________________________________________________
# dropout_11 (Dropout)            (None, 28, 28, 32)   0           conv2d_25[0][0]
# __________________________________________________________________________________________________
# concatenate_11 (Concatenate)    (None, 28, 28, 320)  0           concatenate_10[0][0]
#                                                                  dropout_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 28, 28, 320)  1280        concatenate_11[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 28, 28, 320)  0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 28, 28, 128)  40960       activation_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 28, 28, 128)  512         conv2d_26[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 28, 28, 128)  0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 28, 28, 32)   36864       activation_27[0][0]
# __________________________________________________________________________________________________
# dropout_12 (Dropout)            (None, 28, 28, 32)   0           conv2d_27[0][0]
# __________________________________________________________________________________________________
# concatenate_12 (Concatenate)    (None, 28, 28, 352)  0           concatenate_11[0][0]
#                                                                  dropout_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 28, 28, 352)  1408        concatenate_12[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 28, 28, 352)  0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 28, 28, 128)  45056       activation_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 28, 28, 128)  512         conv2d_28[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 28, 28, 128)  0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 28, 28, 32)   36864       activation_29[0][0]
# __________________________________________________________________________________________________
# dropout_13 (Dropout)            (None, 28, 28, 32)   0           conv2d_29[0][0]
# __________________________________________________________________________________________________
# concatenate_13 (Concatenate)    (None, 28, 28, 384)  0           concatenate_12[0][0]
#                                                                  dropout_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 28, 28, 384)  1536        concatenate_13[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 28, 28, 384)  0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 28, 28, 128)  49152       activation_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 28, 28, 128)  512         conv2d_30[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 28, 28, 128)  0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 28, 28, 32)   36864       activation_31[0][0]
# __________________________________________________________________________________________________
# dropout_14 (Dropout)            (None, 28, 28, 32)   0           conv2d_31[0][0]
# __________________________________________________________________________________________________
# concatenate_14 (Concatenate)    (None, 28, 28, 416)  0           concatenate_13[0][0]
#                                                                  dropout_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 28, 28, 416)  1664        concatenate_14[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 28, 28, 416)  0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 28, 28, 128)  53248       activation_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 28, 28, 128)  512         conv2d_32[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 28, 28, 128)  0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 28, 28, 32)   36864       activation_33[0][0]
# __________________________________________________________________________________________________
# dropout_15 (Dropout)            (None, 28, 28, 32)   0           conv2d_33[0][0]
# __________________________________________________________________________________________________
# concatenate_15 (Concatenate)    (None, 28, 28, 448)  0           concatenate_14[0][0]
#                                                                  dropout_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 28, 28, 448)  1792        concatenate_15[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 28, 28, 448)  0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 28, 28, 128)  57344       activation_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 28, 28, 128)  512         conv2d_34[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 28, 28, 128)  0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 28, 28, 32)   36864       activation_35[0][0]
# __________________________________________________________________________________________________
# dropout_16 (Dropout)            (None, 28, 28, 32)   0           conv2d_35[0][0]
# __________________________________________________________________________________________________
# concatenate_16 (Concatenate)    (None, 28, 28, 480)  0           concatenate_15[0][0]
#                                                                  dropout_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 28, 28, 480)  1920        concatenate_16[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 28, 28, 480)  0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 28, 28, 128)  61440       activation_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 28, 28, 128)  512         conv2d_36[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 28, 28, 128)  0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 28, 28, 32)   36864       activation_37[0][0]
# __________________________________________________________________________________________________
# dropout_17 (Dropout)            (None, 28, 28, 32)   0           conv2d_37[0][0]
# __________________________________________________________________________________________________
# concatenate_17 (Concatenate)    (None, 28, 28, 512)  0           concatenate_16[0][0]
#                                                                  dropout_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 28, 28, 512)  2048        concatenate_17[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 28, 28, 512)  0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 28, 28, 256)  131072      activation_38[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, 14, 14, 256)  0           conv2d_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 14, 14, 256)  1024        average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 14, 14, 256)  0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 14, 14, 128)  32768       activation_39[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 14, 14, 128)  512         conv2d_39[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 14, 14, 128)  0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 14, 14, 32)   36864       activation_40[0][0]
# __________________________________________________________________________________________________
# dropout_18 (Dropout)            (None, 14, 14, 32)   0           conv2d_40[0][0]
# __________________________________________________________________________________________________
# concatenate_18 (Concatenate)    (None, 14, 14, 288)  0           average_pooling2d_1[0][0]
#                                                                  dropout_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 14, 14, 288)  1152        concatenate_18[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 14, 14, 288)  0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 14, 14, 128)  36864       activation_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 14, 14, 128)  512         conv2d_41[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 14, 14, 128)  0           batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 14, 14, 32)   36864       activation_42[0][0]
# __________________________________________________________________________________________________
# dropout_19 (Dropout)            (None, 14, 14, 32)   0           conv2d_42[0][0]
# __________________________________________________________________________________________________
# concatenate_19 (Concatenate)    (None, 14, 14, 320)  0           concatenate_18[0][0]
#                                                                  dropout_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 14, 14, 320)  1280        concatenate_19[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 14, 14, 320)  0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 14, 14, 128)  40960       activation_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 14, 14, 128)  512         conv2d_43[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 14, 14, 128)  0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 14, 14, 32)   36864       activation_44[0][0]
# __________________________________________________________________________________________________
# dropout_20 (Dropout)            (None, 14, 14, 32)   0           conv2d_44[0][0]
# __________________________________________________________________________________________________
# concatenate_20 (Concatenate)    (None, 14, 14, 352)  0           concatenate_19[0][0]
#                                                                  dropout_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 14, 14, 352)  1408        concatenate_20[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 14, 14, 352)  0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 14, 14, 128)  45056       activation_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 14, 14, 128)  512         conv2d_45[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 14, 14, 128)  0           batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 14, 14, 32)   36864       activation_46[0][0]
# __________________________________________________________________________________________________
# dropout_21 (Dropout)            (None, 14, 14, 32)   0           conv2d_46[0][0]
# __________________________________________________________________________________________________
# concatenate_21 (Concatenate)    (None, 14, 14, 384)  0           concatenate_20[0][0]
#                                                                  dropout_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 14, 14, 384)  1536        concatenate_21[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 14, 14, 384)  0           batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 14, 14, 128)  49152       activation_47[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 14, 14, 128)  512         conv2d_47[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 14, 14, 128)  0           batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 14, 14, 32)   36864       activation_48[0][0]
# __________________________________________________________________________________________________
# dropout_22 (Dropout)            (None, 14, 14, 32)   0           conv2d_48[0][0]
# __________________________________________________________________________________________________
# concatenate_22 (Concatenate)    (None, 14, 14, 416)  0           concatenate_21[0][0]
#                                                                  dropout_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 14, 14, 416)  1664        concatenate_22[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 14, 14, 416)  0           batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 14, 14, 128)  53248       activation_49[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 14, 14, 128)  512         conv2d_49[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, 14, 14, 128)  0           batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 14, 14, 32)   36864       activation_50[0][0]
# __________________________________________________________________________________________________
# dropout_23 (Dropout)            (None, 14, 14, 32)   0           conv2d_50[0][0]
# __________________________________________________________________________________________________
# concatenate_23 (Concatenate)    (None, 14, 14, 448)  0           concatenate_22[0][0]
#                                                                  dropout_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 14, 14, 448)  1792        concatenate_23[0][0]
# __________________________________________________________________________________________________
# activation_51 (Activation)      (None, 14, 14, 448)  0           batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 14, 14, 128)  57344       activation_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 14, 14, 128)  512         conv2d_51[0][0]
# __________________________________________________________________________________________________
# activation_52 (Activation)      (None, 14, 14, 128)  0           batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 14, 14, 32)   36864       activation_52[0][0]
# __________________________________________________________________________________________________
# dropout_24 (Dropout)            (None, 14, 14, 32)   0           conv2d_52[0][0]
# __________________________________________________________________________________________________
# concatenate_24 (Concatenate)    (None, 14, 14, 480)  0           concatenate_23[0][0]
#                                                                  dropout_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, 14, 14, 480)  1920        concatenate_24[0][0]
# __________________________________________________________________________________________________
# activation_53 (Activation)      (None, 14, 14, 480)  0           batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 14, 14, 128)  61440       activation_53[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, 14, 14, 128)  512         conv2d_53[0][0]
# __________________________________________________________________________________________________
# activation_54 (Activation)      (None, 14, 14, 128)  0           batch_normalization_54[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 14, 14, 32)   36864       activation_54[0][0]
# __________________________________________________________________________________________________
# dropout_25 (Dropout)            (None, 14, 14, 32)   0           conv2d_54[0][0]
# __________________________________________________________________________________________________
# concatenate_25 (Concatenate)    (None, 14, 14, 512)  0           concatenate_24[0][0]
#                                                                  dropout_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_55 (BatchNo (None, 14, 14, 512)  2048        concatenate_25[0][0]
# __________________________________________________________________________________________________
# activation_55 (Activation)      (None, 14, 14, 512)  0           batch_normalization_55[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 14, 14, 128)  65536       activation_55[0][0]
# __________________________________________________________________________________________________
# batch_normalization_56 (BatchNo (None, 14, 14, 128)  512         conv2d_55[0][0]
# __________________________________________________________________________________________________
# activation_56 (Activation)      (None, 14, 14, 128)  0           batch_normalization_56[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 14, 14, 32)   36864       activation_56[0][0]
# __________________________________________________________________________________________________
# dropout_26 (Dropout)            (None, 14, 14, 32)   0           conv2d_56[0][0]
# ...
# activation_102 (Activation)     (None, 7, 7, 736)    0           batch_normalization_102[0][0]
# __________________________________________________________________________________________________
# conv2d_102 (Conv2D)             (None, 7, 7, 128)    94208       activation_102[0][0]
# __________________________________________________________________________________________________
# batch_normalization_103 (BatchN (None, 7, 7, 128)    512         conv2d_102[0][0]
# __________________________________________________________________________________________________
# activation_103 (Activation)     (None, 7, 7, 128)    0           batch_normalization_103[0][0]
# __________________________________________________________________________________________________
# conv2d_103 (Conv2D)             (None, 7, 7, 32)     36864       activation_103[0][0]
# __________________________________________________________________________________________________
# dropout_49 (Dropout)            (None, 7, 7, 32)     0           conv2d_103[0][0]
# __________________________________________________________________________________________________
# concatenate_49 (Concatenate)    (None, 7, 7, 768)    0           concatenate_48[0][0]
#                                                                  dropout_49[0][0]
# __________________________________________________________________________________________________
# batch_normalization_104 (BatchN (None, 7, 7, 768)    3072        concatenate_49[0][0]
# __________________________________________________________________________________________________
# activation_104 (Activation)     (None, 7, 7, 768)    0           batch_normalization_104[0][0]
# __________________________________________________________________________________________________
# conv2d_104 (Conv2D)             (None, 7, 7, 128)    98304       activation_104[0][0]
# __________________________________________________________________________________________________
# batch_normalization_105 (BatchN (None, 7, 7, 128)    512         conv2d_104[0][0]
# __________________________________________________________________________________________________
# activation_105 (Activation)     (None, 7, 7, 128)    0           batch_normalization_105[0][0]
# __________________________________________________________________________________________________
# conv2d_105 (Conv2D)             (None, 7, 7, 32)     36864       activation_105[0][0]
# __________________________________________________________________________________________________
# dropout_50 (Dropout)            (None, 7, 7, 32)     0           conv2d_105[0][0]
# __________________________________________________________________________________________________
# concatenate_50 (Concatenate)    (None, 7, 7, 800)    0           concatenate_49[0][0]
#                                                                  dropout_50[0][0]
# __________________________________________________________________________________________________
# batch_normalization_106 (BatchN (None, 7, 7, 800)    3200        concatenate_50[0][0]
# __________________________________________________________________________________________________
# activation_106 (Activation)     (None, 7, 7, 800)    0           batch_normalization_106[0][0]
# __________________________________________________________________________________________________
# conv2d_106 (Conv2D)             (None, 7, 7, 128)    102400      activation_106[0][0]
# __________________________________________________________________________________________________
# batch_normalization_107 (BatchN (None, 7, 7, 128)    512         conv2d_106[0][0]
# __________________________________________________________________________________________________
# activation_107 (Activation)     (None, 7, 7, 128)    0           batch_normalization_107[0][0]
# __________________________________________________________________________________________________
# conv2d_107 (Conv2D)             (None, 7, 7, 32)     36864       activation_107[0][0]
# __________________________________________________________________________________________________
# dropout_51 (Dropout)            (None, 7, 7, 32)     0           conv2d_107[0][0]
# __________________________________________________________________________________________________
# concatenate_51 (Concatenate)    (None, 7, 7, 832)    0           concatenate_50[0][0]
#                                                                  dropout_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_108 (BatchN (None, 7, 7, 832)    3328        concatenate_51[0][0]
# __________________________________________________________________________________________________
# activation_108 (Activation)     (None, 7, 7, 832)    0           batch_normalization_108[0][0]
# __________________________________________________________________________________________________
# conv2d_108 (Conv2D)             (None, 7, 7, 128)    106496      activation_108[0][0]
# __________________________________________________________________________________________________
# batch_normalization_109 (BatchN (None, 7, 7, 128)    512         conv2d_108[0][0]
# __________________________________________________________________________________________________
# activation_109 (Activation)     (None, 7, 7, 128)    0           batch_normalization_109[0][0]
# __________________________________________________________________________________________________
# conv2d_109 (Conv2D)             (None, 7, 7, 32)     36864       activation_109[0][0]
# __________________________________________________________________________________________________
# dropout_52 (Dropout)            (None, 7, 7, 32)     0           conv2d_109[0][0]
# __________________________________________________________________________________________________
# concatenate_52 (Concatenate)    (None, 7, 7, 864)    0           concatenate_51[0][0]
#                                                                  dropout_52[0][0]
# __________________________________________________________________________________________________
# batch_normalization_110 (BatchN (None, 7, 7, 864)    3456        concatenate_52[0][0]
# __________________________________________________________________________________________________
# activation_110 (Activation)     (None, 7, 7, 864)    0           batch_normalization_110[0][0]
# __________________________________________________________________________________________________
# conv2d_110 (Conv2D)             (None, 7, 7, 128)    110592      activation_110[0][0]
# __________________________________________________________________________________________________
# batch_normalization_111 (BatchN (None, 7, 7, 128)    512         conv2d_110[0][0]
# __________________________________________________________________________________________________
# activation_111 (Activation)     (None, 7, 7, 128)    0           batch_normalization_111[0][0]
# __________________________________________________________________________________________________
# conv2d_111 (Conv2D)             (None, 7, 7, 32)     36864       activation_111[0][0]
# __________________________________________________________________________________________________
# dropout_53 (Dropout)            (None, 7, 7, 32)     0           conv2d_111[0][0]
# __________________________________________________________________________________________________
# concatenate_53 (Concatenate)    (None, 7, 7, 896)    0           concatenate_52[0][0]
#                                                                  dropout_53[0][0]
# __________________________________________________________________________________________________
# batch_normalization_112 (BatchN (None, 7, 7, 896)    3584        concatenate_53[0][0]
# __________________________________________________________________________________________________
# activation_112 (Activation)     (None, 7, 7, 896)    0           batch_normalization_112[0][0]
# __________________________________________________________________________________________________
# conv2d_112 (Conv2D)             (None, 7, 7, 128)    114688      activation_112[0][0]
# __________________________________________________________________________________________________
# batch_normalization_113 (BatchN (None, 7, 7, 128)    512         conv2d_112[0][0]
# __________________________________________________________________________________________________
# activation_113 (Activation)     (None, 7, 7, 128)    0           batch_normalization_113[0][0]
# __________________________________________________________________________________________________
# conv2d_113 (Conv2D)             (None, 7, 7, 32)     36864       activation_113[0][0]
# __________________________________________________________________________________________________
# dropout_54 (Dropout)            (None, 7, 7, 32)     0           conv2d_113[0][0]
# __________________________________________________________________________________________________
# concatenate_54 (Concatenate)    (None, 7, 7, 928)    0           concatenate_53[0][0]
#                                                                  dropout_54[0][0]
# __________________________________________________________________________________________________
# batch_normalization_114 (BatchN (None, 7, 7, 928)    3712        concatenate_54[0][0]
# __________________________________________________________________________________________________
# activation_114 (Activation)     (None, 7, 7, 928)    0           batch_normalization_114[0][0]
# __________________________________________________________________________________________________
# conv2d_114 (Conv2D)             (None, 7, 7, 128)    118784      activation_114[0][0]
# __________________________________________________________________________________________________
# batch_normalization_115 (BatchN (None, 7, 7, 128)    512         conv2d_114[0][0]
# __________________________________________________________________________________________________
# activation_115 (Activation)     (None, 7, 7, 128)    0           batch_normalization_115[0][0]
# __________________________________________________________________________________________________
# conv2d_115 (Conv2D)             (None, 7, 7, 32)     36864       activation_115[0][0]
# __________________________________________________________________________________________________
# dropout_55 (Dropout)            (None, 7, 7, 32)     0           conv2d_115[0][0]
# __________________________________________________________________________________________________
# concatenate_55 (Concatenate)    (None, 7, 7, 960)    0           concatenate_54[0][0]
#                                                                  dropout_55[0][0]
# __________________________________________________________________________________________________
# batch_normalization_116 (BatchN (None, 7, 7, 960)    3840        concatenate_55[0][0]
# __________________________________________________________________________________________________
# activation_116 (Activation)     (None, 7, 7, 960)    0           batch_normalization_116[0][0]
# __________________________________________________________________________________________________
# conv2d_116 (Conv2D)             (None, 7, 7, 128)    122880      activation_116[0][0]
# __________________________________________________________________________________________________
# batch_normalization_117 (BatchN (None, 7, 7, 128)    512         conv2d_116[0][0]
# __________________________________________________________________________________________________
# activation_117 (Activation)     (None, 7, 7, 128)    0           batch_normalization_117[0][0]
# __________________________________________________________________________________________________
# conv2d_117 (Conv2D)             (None, 7, 7, 32)     36864       activation_117[0][0]
# __________________________________________________________________________________________________
# dropout_56 (Dropout)            (None, 7, 7, 32)     0           conv2d_117[0][0]
# __________________________________________________________________________________________________
# concatenate_56 (Concatenate)    (None, 7, 7, 992)    0           concatenate_55[0][0]
#                                                                  dropout_56[0][0]
# __________________________________________________________________________________________________
# batch_normalization_118 (BatchN (None, 7, 7, 992)    3968        concatenate_56[0][0]
# __________________________________________________________________________________________________
# activation_118 (Activation)     (None, 7, 7, 992)    0           batch_normalization_118[0][0]
# __________________________________________________________________________________________________
# conv2d_118 (Conv2D)             (None, 7, 7, 128)    126976      activation_118[0][0]
# __________________________________________________________________________________________________
# batch_normalization_119 (BatchN (None, 7, 7, 128)    512         conv2d_118[0][0]
# __________________________________________________________________________________________________
# activation_119 (Activation)     (None, 7, 7, 128)    0           batch_normalization_119[0][0]
# __________________________________________________________________________________________________
# conv2d_119 (Conv2D)             (None, 7, 7, 32)     36864       activation_119[0][0]
# __________________________________________________________________________________________________
# dropout_57 (Dropout)            (None, 7, 7, 32)     0           conv2d_119[0][0]
# __________________________________________________________________________________________________
# concatenate_57 (Concatenate)    (None, 7, 7, 1024)   0           concatenate_56[0][0]
#                                                                  dropout_57[0][0]
# __________________________________________________________________________________________________
# batch_normalization_120 (BatchN (None, 7, 7, 1024)   4096        concatenate_57[0][0]
# __________________________________________________________________________________________________
# activation_120 (Activation)     (None, 7, 7, 1024)   0           batch_normalization_120[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 1024)         0           activation_120[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 7)            7175        global_average_pooling2d[0][0]
# ==================================================================================================
# Total params: 7,044,679
# Trainable params: 6,961,031
# Non-trainable params: 83,648
# __________________________________________________________________________________________________

# %%
# 폴더 생성

os.makedirs(os.path.join(dir,'model_output',number,model.name), exist_ok=True)
os.makedirs(os.path.join(dir,'train_valid_output',number), exist_ok=True)

# %%
# 참고 : https://github.com/OverLordGoldDragon/keras-adamw

import sys
sys.path.append('/content/drive/My Drive/Colab Notebooks/Paper')
import utils
import optimizers_v2
from utils import get_weight_decays, fill_dict_in_order
from utils import reset_seeds, K_eval
from optimizers_v2 import AdamW, NadamW, SGDW

# %%
# top-5 accuracy 출력
import functools
top5_acc = functools.partial(ks.metrics.top_k_categorical_accuracy, k=5)
top5_acc.__name__ = 'top5_acc'

# %%
#optimizer = SGDW(model=model, use_cosine_annealing=False, total_iterations = len(x_train) // batch_sizes, nesterov=True, momentum=0.9)
optimizer = AdamW(model=model, use_cosine_annealing=False, total_iterations = len(x_train) // batch_sizes)
#optimizer = Adam()
filepath =  os.path.join(dir,'model_output',number,model.name,'{epoch:03d}.h5')

callbacks_list = [ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_weights_only=False, save_best_only=True, mode='min'),
                  ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_weights_only=False, save_best_only=True, mode='max'),
                  #ReduceLROnPlateau(monitor='val_loss',patience=3,factor=0.1,min_lr=1e-5),
                  LearningRateScheduler(lr_schedule,verbose=1)
                  ]
                  
model.compile(optimizer, loss = 'categorical_crossentropy', metrics=['accuracy',top5_acc,macro_f1score])

# %%
######## flow_from_directory
history = model.fit(train_generator, steps_per_epoch=int(len(x_train)/batch_sizes),  validation_data = valid_generator, epochs=epochs , verbose=1 , callbacks = callbacks_list , validation_steps=int(len(x_valid)/batch_sizes))
# Out:
# Learning rate:  0.001
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 1/70
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_1/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_2/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_3/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_4/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_5/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_6/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_7/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_8/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_9/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_10/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_11/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_12/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_13/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_14/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_15/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_16/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_17/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_18/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_19/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_20/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_21/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_22/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_23/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_24/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_25/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_26/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_27/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_28/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_29/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_30/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_31/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_32/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_33/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_34/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_35/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_36/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_37/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_38/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_39/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_40/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_41/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_42/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_43/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_44/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_45/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_46/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_47/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_48/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_49/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_50/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_51/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_52/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_53/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_54/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_55/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_56/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_57/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_58/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_59/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_60/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_61/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_62/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_63/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_64/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_65/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_66/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_67/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_68/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_69/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_70/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_71/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_72/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_73/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_74/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_75/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_76/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_77/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_78/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_79/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_80/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_81/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_82/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_83/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_84/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_85/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_86/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_87/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_88/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_89/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_90/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_91/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_92/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_93/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_94/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_95/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_96/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_97/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_98/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_99/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_100/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_101/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_102/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_103/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_104/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_105/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_106/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_107/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_108/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_109/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_110/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_111/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_112/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_113/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_114/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_115/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_116/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_117/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_118/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_119/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for dense/kernel:0
# 448/448 [==============================] - ETA: 0s - loss: 1.6859 - accuracy: 0.3150 - top5_acc: 0.9199 - macro_f1score: 0.0756
# Epoch 00001: val_loss improved from inf to 1.59452, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/DenseNet121/001.h5
#
# Epoch 00001: val_accuracy improved from -inf to 0.38030, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/DenseNet121/001.h5
# 448/448 [==============================] - 21412s 48s/step - loss: 1.6859 - accuracy: 0.3150 - top5_acc: 0.9199 - macro_f1score: 0.0756 - val_loss: 1.5945 - val_accuracy: 0.3803 - val_top5_acc: 0.9461 - val_macro_f1score: 0.1574
# Learning rate:  0.001
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 2/70
# 448/448 [==============================] - ETA: 0s - loss: 1.4729 - accuracy: 0.4262 - top5_acc: 0.9532 - macro_f1score: 0.1794
# Epoch 00002: val_loss did not improve from 1.59452
#
# Epoch 00002: val_accuracy improved from 0.38030 to 0.42718, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/DenseNet121/002.h5
# 448/448 [==============================] - 423s 945ms/step - loss: 1.4729 - accuracy: 0.4262 - top5_acc: 0.9532 - macro_f1score: 0.1794 - val_loss: 1.7575 - val_accuracy: 0.4272 - val_top5_acc: 0.9489 - val_macro_f1score: 0.2475
# Learning rate:  0.001
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 3/70
# 448/448 [==============================] - ETA: 0s - loss: 1.3265 - accuracy: 0.4889 - top5_acc: 0.9643 - macro_f1score: 0.2569
# Epoch 00003: val_loss improved from 1.59452 to 1.37961, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/DenseNet121/003.h5
#
# Epoch 00003: val_accuracy improved from 0.42718 to 0.49777, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/DenseNet121/003.h5
# 448/448 [==============================] - 404s 902ms/step - loss: 1.3265 - accuracy: 0.4889 - top5_acc: 0.9643 - macro_f1score: 0.2569 - val_loss: 1.3796 - val_accuracy: 0.4978 - val_top5_acc: 0.9590 - val_macro_f1score: 0.2836
# Learning rate:  0.001
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 4/70
# 448/448 [==============================] - ETA: 0s - loss: 1.2294 - accuracy: 0.5308 - top5_acc: 0.9733 - macro_f1score: 0.3144
# Epoch 00004: val_loss did not improve from 1.37961
#
# Epoch 00004: val_accuracy did not improve from 0.49777
# 448/448 [==============================] - 395s 882ms/step - loss: 1.2294 - accuracy: 0.5308 - top5_acc: 0.9733 - macro_f1score: 0.3144 - val_loss: 1.4264 - val_accuracy: 0.4872 - val_top5_acc: 0.9601 - val_macro_f1score: 0.3392
# Learning rate:  0.001
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 5/70
# 448/448 [==============================] - ETA: 0s - loss: 1.1742 - accuracy: 0.5525 - top5_acc: 0.9770 - macro_f1score: 0.3438
# Epoch 00005: val_loss improved from 1.37961 to 1.35937, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/DenseNet121/005.h5
#
# Epoch 00005: val_accuracy improved from 0.49777 to 0.51479, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/DenseNet121/005.h5
# 448/448 [==============================] - 397s 887ms/step - loss: 1.1742 - accuracy: 0.5525 - top5_acc: 0.9770 - macro_f1score: 0.3438 - val_loss: 1.3594 - val_accuracy: 0.5148 - val_top5_acc: 0.9746 - val_macro_f1score: 0.3322
# Learning rate:  0.001
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 6/70
# 448/448 [==============================] - ETA: 0s - loss: 1.1234 - accuracy: 0.5742 - top5_acc: 0.9815 - macro_f1score: 0.3822
# Epoch 00006: val_loss improved from 1.35937 to 1.16808, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/DenseNet121/006.h5
#
# Epoch 00006: val_accuracy improved from 0.51479 to 0.56027, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/DenseNet121/006.h5
# 448/448 [==============================] - 398s 888ms/step - loss: 1.1234 - accuracy: 0.5742 - top5_acc: 0.9815 - macro_f1score: 0.3822 - val_loss: 1.1681 - val_accuracy: 0.5603 - val_top5_acc: 0.9813 - val_macro_f1score: 0.4126
# Learning rate:  0.001
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 7/70
# 448/448 [==============================] - ETA: 0s - loss: 1.0913 - accuracy: 0.5866 - top5_acc: 0.9831 - macro_f1score: 0.3984
# Epoch 00007: val_loss did not improve from 1.16808
#
# Epoch 00007: val_accuracy did not improve from 0.56027
# 448/448 [==============================] - 395s 882ms/step - loss: 1.0913 - accuracy: 0.5866 - top5_acc: 0.9831 - macro_f1score: 0.3984 - val_loss: 1.1717 - val_accuracy: 0.5438 - val_top5_acc: 0.9838 - val_macro_f1score: 0.4068
# Learning rate:  0.001
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 8/70
# 448/448 [==============================] - ETA: 0s - loss: 1.0635 - accuracy: 0.5978 - top5_acc: 0.9846 - macro_f1score: 0.4188
# Epoch 00008: val_loss did not improve from 1.16808
#
# Epoch 00008: val_accuracy improved from 0.56027 to 0.56083, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/DenseNet121/008.h5
# 448/448 [==============================] - 396s 884ms/step - loss: 1.0635 - accuracy: 0.5978 - top5_acc: 0.9846 - macro_f1score: 0.4188 - val_loss: 1.2261 - val_accuracy: 0.5608 - val_top5_acc: 0.9780 - val_macro_f1score: 0.4054
# Learning rate:  0.001
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 9/70
# 448/448 [==============================] - ETA: 0s - loss: 1.0358 - accuracy: 0.6073 - top5_acc: 0.9854 - macro_f1score: 0.4400
# Epoch 00009: val_loss did not improve from 1.16808
#
# Epoch 00009: val_accuracy did not improve from 0.56083
# 448/448 [==============================] - 394s 880ms/step - loss: 1.0358 - accuracy: 0.6073 - top5_acc: 0.9854 - macro_f1score: 0.4400 - val_loss: 1.3830 - val_accuracy: 0.5519 - val_top5_acc: 0.9766 - val_macro_f1score: 0.3780
# Learning rate:  0.001
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 10/70
# 448/448 [==============================] - ETA: 0s - loss: 1.0116 - accuracy: 0.6176 - top5_acc: 0.9864 - macro_f1score: 0.4551
# Epoch 00010: val_loss did not improve from 1.16808
#
# Epoch 00010: val_accuracy did not improve from 0.56083
# 448/448 [==============================] - 397s 885ms/step - loss: 1.0116 - accuracy: 0.6176 - top5_acc: 0.9864 - macro_f1score: 0.4551 - val_loss: 1.3467 - val_accuracy: 0.5089 - val_top5_acc: 0.9816 - val_macro_f1score: 0.3632
# Learning rate:  0.001
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 11/70
# 448/448 [==============================] - ETA: 0s - loss: 0.9955 - accuracy: 0.6236 - top5_acc: 0.9878 - macro_f1score: 0.4660
# Epoch 00011: val_loss improved from 1.16808 to 1.11827, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/DenseNet121/011.h5
#
# Epoch 00011: val_accuracy improved from 0.56083 to 0.57310, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/DenseNet121/011.h5
# 448/448 [==============================] - 398s 887ms/step - loss: 0.9955 - accuracy: 0.6236 - top5_acc: 0.9878 - macro_f1score: 0.4660 - val_loss: 1.1183 - val_accuracy: 0.5731 - val_top5_acc: 0.9838 - val_macro_f1score: 0.4500
# Learning rate:  0.001
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 12/70
# 448/448 [==============================] - ETA: 0s - loss: 0.9806 - accuracy: 0.6289 - top5_acc: 0.9886 - macro_f1score: 0.4779
# Epoch 00012: val_loss improved from 1.11827 to 1.10382, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/DenseNet121/012.h5
#
# Epoch 00012: val_accuracy improved from 0.57310 to 0.60296, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/DenseNet121/012.h5
# 448/448 [==============================] - 396s 884ms/step - loss: 0.9806 - accuracy: 0.6289 - top5_acc: 0.9886 - macro_f1score: 0.4779 - val_loss: 1.1038 - val_accuracy: 0.6030 - val_top5_acc: 0.9855 - val_macro_f1score: 0.4473
# Learning rate:  0.001
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 13/70
# 448/448 [==============================] - ETA: 0s - loss: 0.9581 - accuracy: 0.6368 - top5_acc: 0.9885 - macro_f1score: 0.4875
# Epoch 00013: val_loss did not improve from 1.10382
#
# Epoch 00013: val_accuracy did not improve from 0.60296
# 448/448 [==============================] - 395s 881ms/step - loss: 0.9581 - accuracy: 0.6368 - top5_acc: 0.9885 - macro_f1score: 0.4875 - val_loss: 1.1118 - val_accuracy: 0.5946 - val_top5_acc: 0.9869 - val_macro_f1score: 0.4699
# Learning rate:  0.001
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 14/70
# 448/448 [==============================] - ETA: 0s - loss: 0.9435 - accuracy: 0.6438 - top5_acc: 0.9903 - macro_f1score: 0.4986
# Epoch 00014: val_loss improved from 1.10382 to 1.03924, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/DenseNet121/014.h5
#
# Epoch 00014: val_accuracy improved from 0.60296 to 0.60519, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/DenseNet121/014.h5
# 448/448 [==============================] - 398s 888ms/step - loss: 0.9435 - accuracy: 0.6438 - top5_acc: 0.9903 - macro_f1score: 0.4986 - val_loss: 1.0392 - val_accuracy: 0.6052 - val_top5_acc: 0.9849 - val_macro_f1score: 0.4741
# Learning rate:  0.001
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 15/70
# 448/448 [==============================] - ETA: 0s - loss: 0.9297 - accuracy: 0.6486 - top5_acc: 0.9909 - macro_f1score: 0.5078
# Epoch 00015: val_loss did not improve from 1.03924
#
# Epoch 00015: val_accuracy did not improve from 0.60519
# 448/448 [==============================] - 396s 883ms/step - loss: 0.9297 - accuracy: 0.6486 - top5_acc: 0.9909 - macro_f1score: 0.5078 - val_loss: 1.2360 - val_accuracy: 0.5438 - val_top5_acc: 0.9847 - val_macro_f1score: 0.4199
# Learning rate:  0.001
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 16/70
# 448/448 [==============================] - ETA: 0s - loss: 0.9139 - accuracy: 0.6577 - top5_acc: 0.9913 - macro_f1score: 0.5151
# Epoch 00016: val_loss did not improve from 1.03924
#
# Epoch 00016: val_accuracy did not improve from 0.60519
# 448/448 [==============================] - 394s 880ms/step - loss: 0.9139 - accuracy: 0.6577 - top5_acc: 0.9913 - macro_f1score: 0.5151 - val_loss: 1.1071 - val_accuracy: 0.5974 - val_top5_acc: 0.9830 - val_macro_f1score: 0.4748
# Learning rate:  0.001
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 17/70
# 448/448 [==============================] - ETA: 0s - loss: 0.9023 - accuracy: 0.6623 - top5_acc: 0.9915 - macro_f1score: 0.5268
# Epoch 00017: val_loss did not improve from 1.03924
#
# Epoch 00017: val_accuracy did not improve from 0.60519
# 448/448 [==============================] - 393s 877ms/step - loss: 0.9023 - accuracy: 0.6623 - top5_acc: 0.9915 - macro_f1score: 0.5268 - val_loss: 1.1407 - val_accuracy: 0.5873 - val_top5_acc: 0.9805 - val_macro_f1score: 0.4457
# Learning rate:  0.001
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 18/70
# 448/448 [==============================] - ETA: 0s - loss: 0.8860 - accuracy: 0.6666 - top5_acc: 0.9918 - macro_f1score: 0.5357
# Epoch 00018: val_loss did not improve from 1.03924
#
# Epoch 00018: val_accuracy did not improve from 0.60519
# 448/448 [==============================] - 392s 874ms/step - loss: 0.8860 - accuracy: 0.6666 - top5_acc: 0.9918 - macro_f1score: 0.5357 - val_loss: 1.1761 - val_accuracy: 0.5698 - val_top5_acc: 0.9858 - val_macro_f1score: 0.4328
# Learning rate:  0.001
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 19/70
# 448/448 [==============================] - ETA: 0s - loss: 0.8778 - accuracy: 0.6709 - top5_acc: 0.9917 - macro_f1score: 0.5452
# Epoch 00019: val_loss did not improve from 1.03924
#
# Epoch 00019: val_accuracy did not improve from 0.60519
# 448/448 [==============================] - 394s 880ms/step - loss: 0.8778 - accuracy: 0.6709 - top5_acc: 0.9917 - macro_f1score: 0.5452 - val_loss: 1.1745 - val_accuracy: 0.5859 - val_top5_acc: 0.9821 - val_macro_f1score: 0.4760
# Learning rate:  0.001
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 20/70
# 448/448 [==============================] - ETA: 0s - loss: 0.8690 - accuracy: 0.6718 - top5_acc: 0.9924 - macro_f1score: 0.5502
# Epoch 00020: val_loss did not improve from 1.03924
#
# Epoch 00020: val_accuracy did not improve from 0.60519
# 448/448 [==============================] - 392s 876ms/step - loss: 0.8690 - accuracy: 0.6718 - top5_acc: 0.9924 - macro_f1score: 0.5502 - val_loss: 1.2414 - val_accuracy: 0.5458 - val_top5_acc: 0.9863 - val_macro_f1score: 0.4152
# Learning rate:  0.001
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 21/70
# 448/448 [==============================] - ETA: 0s - loss: 0.8521 - accuracy: 0.6804 - top5_acc: 0.9933 - macro_f1score: 0.5614
# Epoch 00021: val_loss did not improve from 1.03924
#
# Epoch 00021: val_accuracy did not improve from 0.60519
# 448/448 [==============================] - 392s 876ms/step - loss: 0.8521 - accuracy: 0.6804 - top5_acc: 0.9933 - macro_f1score: 0.5614 - val_loss: 1.2281 - val_accuracy: 0.5968 - val_top5_acc: 0.9766 - val_macro_f1score: 0.4961
# Learning rate:  0.001
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 22/70
# 448/448 [==============================] - ETA: 0s - loss: 0.8438 - accuracy: 0.6811 - top5_acc: 0.9940 - macro_f1score: 0.5661
# Epoch 00022: val_loss did not improve from 1.03924
#
# Epoch 00022: val_accuracy did not improve from 0.60519
# 448/448 [==============================] - 393s 878ms/step - loss: 0.8438 - accuracy: 0.6811 - top5_acc: 0.9940 - macro_f1score: 0.5661 - val_loss: 1.4037 - val_accuracy: 0.5134 - val_top5_acc: 0.9888 - val_macro_f1score: 0.4062
# Learning rate:  0.001
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 23/70
# 448/448 [==============================] - ETA: 0s - loss: 0.8265 - accuracy: 0.6875 - top5_acc: 0.9937 - macro_f1score: 0.5763
# Epoch 00023: val_loss did not improve from 1.03924
#
# Epoch 00023: val_accuracy improved from 0.60519 to 0.60938, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/DenseNet121/023.h5
# 448/448 [==============================] - 394s 879ms/step - loss: 0.8265 - accuracy: 0.6875 - top5_acc: 0.9937 - macro_f1score: 0.5763 - val_loss: 1.1045 - val_accuracy: 0.6094 - val_top5_acc: 0.9872 - val_macro_f1score: 0.4928
# Learning rate:  0.001
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 24/70
# 448/448 [==============================] - ETA: 0s - loss: 0.8184 - accuracy: 0.6913 - top5_acc: 0.9936 - macro_f1score: 0.5779
# Epoch 00024: val_loss did not improve from 1.03924
#
# Epoch 00024: val_accuracy did not improve from 0.60938
# 448/448 [==============================] - 393s 877ms/step - loss: 0.8184 - accuracy: 0.6913 - top5_acc: 0.9936 - macro_f1score: 0.5779 - val_loss: 1.3613 - val_accuracy: 0.5580 - val_top5_acc: 0.9819 - val_macro_f1score: 0.4328
# Learning rate:  0.001
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 25/70
# 448/448 [==============================] - ETA: 0s - loss: 0.8030 - accuracy: 0.6976 - top5_acc: 0.9942 - macro_f1score: 0.5906
# Epoch 00025: val_loss improved from 1.03924 to 1.03249, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/DenseNet121/025.h5
#
# Epoch 00025: val_accuracy improved from 0.60938 to 0.63002, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/DenseNet121/025.h5
# 448/448 [==============================] - 392s 876ms/step - loss: 0.8030 - accuracy: 0.6976 - top5_acc: 0.9942 - macro_f1score: 0.5906 - val_loss: 1.0325 - val_accuracy: 0.6300 - val_top5_acc: 0.9888 - val_macro_f1score: 0.5316
# Learning rate:  0.001
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 26/70
# 448/448 [==============================] - ETA: 0s - loss: 0.7975 - accuracy: 0.7017 - top5_acc: 0.9940 - macro_f1score: 0.5951
# Epoch 00026: val_loss did not improve from 1.03249
#
# Epoch 00026: val_accuracy did not improve from 0.63002
# 448/448 [==============================] - 385s 860ms/step - loss: 0.7975 - accuracy: 0.7017 - top5_acc: 0.9940 - macro_f1score: 0.5951 - val_loss: 1.1237 - val_accuracy: 0.6141 - val_top5_acc: 0.9866 - val_macro_f1score: 0.5168
# Learning rate:  0.001
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 27/70
# 448/448 [==============================] - ETA: 0s - loss: 0.7780 - accuracy: 0.7083 - top5_acc: 0.9949 - macro_f1score: 0.6092
# Epoch 00027: val_loss did not improve from 1.03249
#
# Epoch 00027: val_accuracy did not improve from 0.63002
# 448/448 [==============================] - 386s 863ms/step - loss: 0.7780 - accuracy: 0.7083 - top5_acc: 0.9949 - macro_f1score: 0.6092 - val_loss: 1.1928 - val_accuracy: 0.6041 - val_top5_acc: 0.9863 - val_macro_f1score: 0.4794
# Learning rate:  0.001
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 28/70
# 448/448 [==============================] - ETA: 0s - loss: 0.7656 - accuracy: 0.7126 - top5_acc: 0.9949 - macro_f1score: 0.6156
# Epoch 00028: val_loss did not improve from 1.03249
#
# Epoch 00028: val_accuracy did not improve from 0.63002
# 448/448 [==============================] - 389s 869ms/step - loss: 0.7656 - accuracy: 0.7126 - top5_acc: 0.9949 - macro_f1score: 0.6156 - val_loss: 1.2283 - val_accuracy: 0.5957 - val_top5_acc: 0.9900 - val_macro_f1score: 0.4849
# Learning rate:  0.001
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 29/70
# 448/448 [==============================] - ETA: 0s - loss: 0.7542 - accuracy: 0.7159 - top5_acc: 0.9953 - macro_f1score: 0.6195
# Epoch 00029: val_loss did not improve from 1.03249
#
# Epoch 00029: val_accuracy did not improve from 0.63002
# 448/448 [==============================] - 392s 876ms/step - loss: 0.7542 - accuracy: 0.7159 - top5_acc: 0.9953 - macro_f1score: 0.6195 - val_loss: 1.1429 - val_accuracy: 0.6071 - val_top5_acc: 0.9894 - val_macro_f1score: 0.4925
# Learning rate:  0.001
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 30/70
# 448/448 [==============================] - ETA: 0s - loss: 0.7406 - accuracy: 0.7230 - top5_acc: 0.9963 - macro_f1score: 0.6271
# Epoch 00030: val_loss did not improve from 1.03249
#
# Epoch 00030: val_accuracy did not improve from 0.63002
# 448/448 [==============================] - 406s 906ms/step - loss: 0.7406 - accuracy: 0.7230 - top5_acc: 0.9963 - macro_f1score: 0.6271 - val_loss: 1.1427 - val_accuracy: 0.6219 - val_top5_acc: 0.9905 - val_macro_f1score: 0.4984
# Learning rate:  0.0001
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 31/70
# 448/448 [==============================] - ETA: 0s - loss: 0.6390 - accuracy: 0.7663 - top5_acc: 0.9976 - macro_f1score: 0.6799
# Epoch 00031: val_loss improved from 1.03249 to 0.99041, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/DenseNet121/031.h5
#
# Epoch 00031: val_accuracy improved from 0.63002 to 0.65541, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/DenseNet121/031.h5
# 448/448 [==============================] - 414s 923ms/step - loss: 0.6390 - accuracy: 0.7663 - top5_acc: 0.9976 - macro_f1score: 0.6799 - val_loss: 0.9904 - val_accuracy: 0.6554 - val_top5_acc: 0.9897 - val_macro_f1score: 0.5721
# Learning rate:  0.0001
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 32/70
# 448/448 [==============================] - ETA: 0s - loss: 0.5978 - accuracy: 0.7797 - top5_acc: 0.9982 - macro_f1score: 0.7004
# Epoch 00032: val_loss did not improve from 0.99041
#
# Epoch 00032: val_accuracy improved from 0.65541 to 0.66155, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/DenseNet121/032.h5
# 448/448 [==============================] - 419s 935ms/step - loss: 0.5978 - accuracy: 0.7797 - top5_acc: 0.9982 - macro_f1score: 0.7004 - val_loss: 0.9923 - val_accuracy: 0.6616 - val_top5_acc: 0.9894 - val_macro_f1score: 0.5784
# Learning rate:  0.0001
#
# Epoch 00033: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 33/70
# 448/448 [==============================] - ETA: 0s - loss: 0.5793 - accuracy: 0.7882 - top5_acc: 0.9984 - macro_f1score: 0.7177
# Epoch 00033: val_loss did not improve from 0.99041
#
# Epoch 00033: val_accuracy did not improve from 0.66155
# 448/448 [==============================] - 413s 922ms/step - loss: 0.5793 - accuracy: 0.7882 - top5_acc: 0.9984 - macro_f1score: 0.7177 - val_loss: 1.0195 - val_accuracy: 0.6616 - val_top5_acc: 0.9908 - val_macro_f1score: 0.5789
# Learning rate:  0.0001
#
# Epoch 00034: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 34/70
# 448/448 [==============================] - ETA: 0s - loss: 0.5675 - accuracy: 0.7896 - top5_acc: 0.9983 - macro_f1score: 0.7205
# Epoch 00034: val_loss did not improve from 0.99041
#
# Epoch 00034: val_accuracy did not improve from 0.66155
# 448/448 [==============================] - 407s 908ms/step - loss: 0.5675 - accuracy: 0.7896 - top5_acc: 0.9983 - macro_f1score: 0.7205 - val_loss: 1.0436 - val_accuracy: 0.6532 - val_top5_acc: 0.9897 - val_macro_f1score: 0.5675
# Learning rate:  0.0001
#
# Epoch 00035: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 35/70
# 448/448 [==============================] - ETA: 0s - loss: 0.5558 - accuracy: 0.7942 - top5_acc: 0.9985 - macro_f1score: 0.7263
# Epoch 00035: val_loss did not improve from 0.99041
#
# Epoch 00035: val_accuracy did not improve from 0.66155
# 448/448 [==============================] - 413s 922ms/step - loss: 0.5558 - accuracy: 0.7942 - top5_acc: 0.9985 - macro_f1score: 0.7263 - val_loss: 1.0775 - val_accuracy: 0.6445 - val_top5_acc: 0.9900 - val_macro_f1score: 0.5555
# Learning rate:  0.0001
#
# Epoch 00036: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 36/70
# 448/448 [==============================] - ETA: 0s - loss: 0.5509 - accuracy: 0.7963 - top5_acc: 0.9986 - macro_f1score: 0.7281
# Epoch 00036: val_loss did not improve from 0.99041
#
# Epoch 00036: val_accuracy did not improve from 0.66155
# 448/448 [==============================] - 411s 916ms/step - loss: 0.5509 - accuracy: 0.7963 - top5_acc: 0.9986 - macro_f1score: 0.7281 - val_loss: 1.0631 - val_accuracy: 0.6532 - val_top5_acc: 0.9905 - val_macro_f1score: 0.5767
# Learning rate:  0.0001
#
# Epoch 00037: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 37/70
# 448/448 [==============================] - ETA: 0s - loss: 0.5377 - accuracy: 0.8028 - top5_acc: 0.9987 - macro_f1score: 0.7387
# Epoch 00037: val_loss did not improve from 0.99041
#
# Epoch 00037: val_accuracy did not improve from 0.66155
# 448/448 [==============================] - 395s 881ms/step - loss: 0.5377 - accuracy: 0.8028 - top5_acc: 0.9987 - macro_f1score: 0.7387 - val_loss: 1.0728 - val_accuracy: 0.6535 - val_top5_acc: 0.9888 - val_macro_f1score: 0.5645
# Learning rate:  0.0001
#
# Epoch 00038: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 38/70
# 448/448 [==============================] - ETA: 0s - loss: 0.5266 - accuracy: 0.8034 - top5_acc: 0.9986 - macro_f1score: 0.7350
# Epoch 00038: val_loss did not improve from 0.99041
#
# Epoch 00038: val_accuracy did not improve from 0.66155
# 448/448 [==============================] - 387s 864ms/step - loss: 0.5266 - accuracy: 0.8034 - top5_acc: 0.9986 - macro_f1score: 0.7350 - val_loss: 1.1057 - val_accuracy: 0.6387 - val_top5_acc: 0.9897 - val_macro_f1score: 0.5493
# Learning rate:  0.0001
#
# Epoch 00039: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 39/70
# 448/448 [==============================] - ETA: 0s - loss: 0.5141 - accuracy: 0.8128 - top5_acc: 0.9988 - macro_f1score: 0.7441
# Epoch 00039: val_loss did not improve from 0.99041
#
# Epoch 00039: val_accuracy did not improve from 0.66155
# 448/448 [==============================] - 385s 860ms/step - loss: 0.5141 - accuracy: 0.8128 - top5_acc: 0.9988 - macro_f1score: 0.7441 - val_loss: 1.1153 - val_accuracy: 0.6445 - val_top5_acc: 0.9897 - val_macro_f1score: 0.5626
# Learning rate:  0.0001
#
# Epoch 00040: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 40/70
# 448/448 [==============================] - ETA: 0s - loss: 0.5058 - accuracy: 0.8126 - top5_acc: 0.9988 - macro_f1score: 0.7499
# Epoch 00040: val_loss did not improve from 0.99041
#
# Epoch 00040: val_accuracy did not improve from 0.66155
# 448/448 [==============================] - 384s 858ms/step - loss: 0.5058 - accuracy: 0.8126 - top5_acc: 0.9988 - macro_f1score: 0.7499 - val_loss: 1.1074 - val_accuracy: 0.6515 - val_top5_acc: 0.9883 - val_macro_f1score: 0.5737
# Learning rate:  0.0001
#
# Epoch 00041: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 41/70
# 448/448 [==============================] - ETA: 0s - loss: 0.5049 - accuracy: 0.8158 - top5_acc: 0.9987 - macro_f1score: 0.7541
# Epoch 00041: val_loss did not improve from 0.99041
#
# Epoch 00041: val_accuracy did not improve from 0.66155
# 448/448 [==============================] - 385s 860ms/step - loss: 0.5049 - accuracy: 0.8158 - top5_acc: 0.9987 - macro_f1score: 0.7541 - val_loss: 1.1153 - val_accuracy: 0.6484 - val_top5_acc: 0.9880 - val_macro_f1score: 0.5668
# Learning rate:  0.0001
#
# Epoch 00042: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 42/70
# 448/448 [==============================] - ETA: 0s - loss: 0.4893 - accuracy: 0.8226 - top5_acc: 0.9990 - macro_f1score: 0.7592
# Epoch 00042: val_loss did not improve from 0.99041
#
# Epoch 00042: val_accuracy did not improve from 0.66155
# 448/448 [==============================] - 384s 857ms/step - loss: 0.4893 - accuracy: 0.8226 - top5_acc: 0.9990 - macro_f1score: 0.7592 - val_loss: 1.0821 - val_accuracy: 0.6568 - val_top5_acc: 0.9894 - val_macro_f1score: 0.5813
# Learning rate:  0.0001
#
# Epoch 00043: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 43/70
# 448/448 [==============================] - ETA: 0s - loss: 0.4856 - accuracy: 0.8185 - top5_acc: 0.9991 - macro_f1score: 0.7554
# Epoch 00043: val_loss did not improve from 0.99041
#
# Epoch 00043: val_accuracy did not improve from 0.66155
# 448/448 [==============================] - 386s 861ms/step - loss: 0.4856 - accuracy: 0.8185 - top5_acc: 0.9991 - macro_f1score: 0.7554 - val_loss: 1.1158 - val_accuracy: 0.6537 - val_top5_acc: 0.9891 - val_macro_f1score: 0.5962
# Learning rate:  0.0001
#
# Epoch 00044: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 44/70
# 448/448 [==============================] - ETA: 0s - loss: 0.4787 - accuracy: 0.8250 - top5_acc: 0.9990 - macro_f1score: 0.7615
# Epoch 00044: val_loss did not improve from 0.99041
#
# Epoch 00044: val_accuracy did not improve from 0.66155
# 448/448 [==============================] - 383s 855ms/step - loss: 0.4787 - accuracy: 0.8250 - top5_acc: 0.9990 - macro_f1score: 0.7615 - val_loss: 1.1134 - val_accuracy: 0.6532 - val_top5_acc: 0.9900 - val_macro_f1score: 0.5749
# Learning rate:  0.0001
#
# Epoch 00045: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 45/70
# 448/448 [==============================] - ETA: 0s - loss: 0.4705 - accuracy: 0.8285 - top5_acc: 0.9992 - macro_f1score: 0.7675
# Epoch 00045: val_loss did not improve from 0.99041
#
# Epoch 00045: val_accuracy did not improve from 0.66155
# 448/448 [==============================] - 383s 854ms/step - loss: 0.4705 - accuracy: 0.8285 - top5_acc: 0.9992 - macro_f1score: 0.7675 - val_loss: 1.1034 - val_accuracy: 0.6616 - val_top5_acc: 0.9891 - val_macro_f1score: 0.5990
# Learning rate:  0.0001
#
# Epoch 00046: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 46/70
# 448/448 [==============================] - ETA: 0s - loss: 0.4625 - accuracy: 0.8295 - top5_acc: 0.9992 - macro_f1score: 0.7698
# Epoch 00046: val_loss did not improve from 0.99041
#
# Epoch 00046: val_accuracy did not improve from 0.66155
# 448/448 [==============================] - 384s 856ms/step - loss: 0.4625 - accuracy: 0.8295 - top5_acc: 0.9992 - macro_f1score: 0.7698 - val_loss: 1.1432 - val_accuracy: 0.6443 - val_top5_acc: 0.9897 - val_macro_f1score: 0.5778
# Learning rate:  0.0001
#
# Epoch 00047: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 47/70
# 448/448 [==============================] - ETA: 0s - loss: 0.4524 - accuracy: 0.8330 - top5_acc: 0.9992 - macro_f1score: 0.7707
# Epoch 00047: val_loss did not improve from 0.99041
#
# Epoch 00047: val_accuracy did not improve from 0.66155
# 448/448 [==============================] - 383s 855ms/step - loss: 0.4524 - accuracy: 0.8330 - top5_acc: 0.9992 - macro_f1score: 0.7707 - val_loss: 1.1375 - val_accuracy: 0.6523 - val_top5_acc: 0.9902 - val_macro_f1score: 0.5795
# Learning rate:  0.0001
#
# Epoch 00048: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 48/70
# 448/448 [==============================] - ETA: 0s - loss: 0.4479 - accuracy: 0.8341 - top5_acc: 0.9994 - macro_f1score: 0.7748
# Epoch 00048: val_loss did not improve from 0.99041
#
# Epoch 00048: val_accuracy did not improve from 0.66155
# 448/448 [==============================] - 383s 854ms/step - loss: 0.4479 - accuracy: 0.8341 - top5_acc: 0.9994 - macro_f1score: 0.7748 - val_loss: 1.1510 - val_accuracy: 0.6535 - val_top5_acc: 0.9900 - val_macro_f1score: 0.5849
# Learning rate:  0.0001
#
# Epoch 00049: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 49/70
# 448/448 [==============================] - ETA: 0s - loss: 0.4381 - accuracy: 0.8359 - top5_acc: 0.9993 - macro_f1score: 0.7792
# Epoch 00049: val_loss did not improve from 0.99041
#
# Epoch 00049: val_accuracy did not improve from 0.66155
# 448/448 [==============================] - 383s 855ms/step - loss: 0.4381 - accuracy: 0.8359 - top5_acc: 0.9993 - macro_f1score: 0.7792 - val_loss: 1.2267 - val_accuracy: 0.6395 - val_top5_acc: 0.9883 - val_macro_f1score: 0.5658
# Learning rate:  0.0001
#
# Epoch 00050: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 50/70
# 448/448 [==============================] - ETA: 0s - loss: 0.4294 - accuracy: 0.8410 - top5_acc: 0.9995 - macro_f1score: 0.7816
# Epoch 00050: val_loss did not improve from 0.99041
#
# Epoch 00050: val_accuracy did not improve from 0.66155
# 448/448 [==============================] - 383s 854ms/step - loss: 0.4294 - accuracy: 0.8410 - top5_acc: 0.9995 - macro_f1score: 0.7816 - val_loss: 1.1017 - val_accuracy: 0.6562 - val_top5_acc: 0.9897 - val_macro_f1score: 0.5895
# Learning rate:  0.0001
#
# Epoch 00051: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 51/70
# 448/448 [==============================] - ETA: 0s - loss: 0.4238 - accuracy: 0.8445 - top5_acc: 0.9996 - macro_f1score: 0.7890
# Epoch 00051: val_loss did not improve from 0.99041
#
# Epoch 00051: val_accuracy did not improve from 0.66155
# 448/448 [==============================] - 382s 853ms/step - loss: 0.4238 - accuracy: 0.8445 - top5_acc: 0.9996 - macro_f1score: 0.7890 - val_loss: 1.2005 - val_accuracy: 0.6498 - val_top5_acc: 0.9869 - val_macro_f1score: 0.5866
# Learning rate:  0.0001
#
# Epoch 00052: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 52/70
# 448/448 [==============================] - ETA: 0s - loss: 0.4179 - accuracy: 0.8473 - top5_acc: 0.9993 - macro_f1score: 0.7967
# Epoch 00052: val_loss did not improve from 0.99041
#
# Epoch 00052: val_accuracy did not improve from 0.66155
# 448/448 [==============================] - 381s 851ms/step - loss: 0.4179 - accuracy: 0.8473 - top5_acc: 0.9993 - macro_f1score: 0.7967 - val_loss: 1.2437 - val_accuracy: 0.6484 - val_top5_acc: 0.9860 - val_macro_f1score: 0.5884
# Learning rate:  0.0001
#
# Epoch 00053: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 53/70
# 448/448 [==============================] - ETA: 0s - loss: 0.4100 - accuracy: 0.8482 - top5_acc: 0.9995 - macro_f1score: 0.7837
# Epoch 00053: val_loss did not improve from 0.99041
#
# Epoch 00053: val_accuracy did not improve from 0.66155
# 448/448 [==============================] - 381s 851ms/step - loss: 0.4100 - accuracy: 0.8482 - top5_acc: 0.9995 - macro_f1score: 0.7837 - val_loss: 1.2617 - val_accuracy: 0.6398 - val_top5_acc: 0.9908 - val_macro_f1score: 0.5672
# Learning rate:  0.0001
#
# Epoch 00054: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 54/70
# 448/448 [==============================] - ETA: 0s - loss: 0.4019 - accuracy: 0.8524 - top5_acc: 0.9995 - macro_f1score: 0.7949
# Epoch 00054: val_loss did not improve from 0.99041
#
# Epoch 00054: val_accuracy did not improve from 0.66155
# 448/448 [==============================] - 382s 852ms/step - loss: 0.4019 - accuracy: 0.8524 - top5_acc: 0.9995 - macro_f1score: 0.7949 - val_loss: 1.2312 - val_accuracy: 0.6456 - val_top5_acc: 0.9888 - val_macro_f1score: 0.5752
# Learning rate:  0.0001
#
# Epoch 00055: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 55/70
# 448/448 [==============================] - ETA: 0s - loss: 0.3957 - accuracy: 0.8550 - top5_acc: 0.9997 - macro_f1score: 0.7965
# Epoch 00055: val_loss did not improve from 0.99041
#
# Epoch 00055: val_accuracy did not improve from 0.66155
# 448/448 [==============================] - 381s 851ms/step - loss: 0.3957 - accuracy: 0.8550 - top5_acc: 0.9997 - macro_f1score: 0.7965 - val_loss: 1.2506 - val_accuracy: 0.6504 - val_top5_acc: 0.9894 - val_macro_f1score: 0.5829
# Learning rate:  0.0001
#
# Epoch 00056: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 56/70
# 448/448 [==============================] - ETA: 0s - loss: 0.3890 - accuracy: 0.8570 - top5_acc: 0.9996 - macro_f1score: 0.7968
# Epoch 00056: val_loss did not improve from 0.99041
#
# Epoch 00056: val_accuracy did not improve from 0.66155
# 448/448 [==============================] - 381s 851ms/step - loss: 0.3890 - accuracy: 0.8570 - top5_acc: 0.9996 - macro_f1score: 0.7968 - val_loss: 1.2443 - val_accuracy: 0.6562 - val_top5_acc: 0.9894 - val_macro_f1score: 0.5817
# Learning rate:  0.0001
#
# Epoch 00057: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 57/70
# 448/448 [==============================] - ETA: 0s - loss: 0.3815 - accuracy: 0.8588 - top5_acc: 0.9997 - macro_f1score: 0.8035
# Epoch 00057: val_loss did not improve from 0.99041
#
# Epoch 00057: val_accuracy did not improve from 0.66155
# 448/448 [==============================] - 381s 850ms/step - loss: 0.3815 - accuracy: 0.8588 - top5_acc: 0.9997 - macro_f1score: 0.8035 - val_loss: 1.2131 - val_accuracy: 0.6532 - val_top5_acc: 0.9911 - val_macro_f1score: 0.5913
# Learning rate:  0.0001
#
# Epoch 00058: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 58/70
# 448/448 [==============================] - ETA: 0s - loss: 0.3766 - accuracy: 0.8622 - top5_acc: 0.9996 - macro_f1score: 0.7993
# Epoch 00058: val_loss did not improve from 0.99041
#
# Epoch 00058: val_accuracy did not improve from 0.66155
# 448/448 [==============================] - 381s 850ms/step - loss: 0.3766 - accuracy: 0.8622 - top5_acc: 0.9996 - macro_f1score: 0.7993 - val_loss: 1.2460 - val_accuracy: 0.6512 - val_top5_acc: 0.9880 - val_macro_f1score: 0.5913
# Learning rate:  0.0001
#
# Epoch 00059: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 59/70
# 448/448 [==============================] - ETA: 0s - loss: 0.3651 - accuracy: 0.8681 - top5_acc: 0.9995 - macro_f1score: 0.8136
# Epoch 00059: val_loss did not improve from 0.99041
#
# Epoch 00059: val_accuracy did not improve from 0.66155
# 448/448 [==============================] - 380s 848ms/step - loss: 0.3651 - accuracy: 0.8681 - top5_acc: 0.9995 - macro_f1score: 0.8136 - val_loss: 1.2749 - val_accuracy: 0.6378 - val_top5_acc: 0.9902 - val_macro_f1score: 0.5586
# Learning rate:  0.0001
#
# Epoch 00060: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 60/70
# 448/448 [==============================] - ETA: 0s - loss: 0.3621 - accuracy: 0.8660 - top5_acc: 0.9996 - macro_f1score: 0.8099
# Epoch 00060: val_loss did not improve from 0.99041
#
# Epoch 00060: val_accuracy did not improve from 0.66155
# 448/448 [==============================] - 381s 851ms/step - loss: 0.3621 - accuracy: 0.8660 - top5_acc: 0.9996 - macro_f1score: 0.8099 - val_loss: 1.2483 - val_accuracy: 0.6543 - val_top5_acc: 0.9911 - val_macro_f1score: 0.5952
# Learning rate:  1e-05
#
# Epoch 00061: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 61/70
# 448/448 [==============================] - ETA: 0s - loss: 0.3281 - accuracy: 0.8815 - top5_acc: 0.9999 - macro_f1score: 0.8259
# Epoch 00061: val_loss did not improve from 0.99041
#
# Epoch 00061: val_accuracy did not improve from 0.66155
# 448/448 [==============================] - 380s 848ms/step - loss: 0.3281 - accuracy: 0.8815 - top5_acc: 0.9999 - macro_f1score: 0.8259 - val_loss: 1.2525 - val_accuracy: 0.6537 - val_top5_acc: 0.9897 - val_macro_f1score: 0.5829
# Learning rate:  1e-05
#
# Epoch 00062: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 62/70
# 448/448 [==============================] - ETA: 0s - loss: 0.3195 - accuracy: 0.8861 - top5_acc: 0.9997 - macro_f1score: 0.8269
# Epoch 00062: val_loss did not improve from 0.99041
#
# Epoch 00062: val_accuracy did not improve from 0.66155
# 448/448 [==============================] - 381s 850ms/step - loss: 0.3195 - accuracy: 0.8861 - top5_acc: 0.9997 - macro_f1score: 0.8269 - val_loss: 1.2543 - val_accuracy: 0.6540 - val_top5_acc: 0.9908 - val_macro_f1score: 0.5851
# Learning rate:  1e-05
#
# Epoch 00063: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 63/70
# 448/448 [==============================] - ETA: 0s - loss: 0.3145 - accuracy: 0.8895 - top5_acc: 0.9999 - macro_f1score: 0.8314
# Epoch 00063: val_loss did not improve from 0.99041
#
# Epoch 00063: val_accuracy did not improve from 0.66155
# 448/448 [==============================] - 381s 850ms/step - loss: 0.3145 - accuracy: 0.8895 - top5_acc: 0.9999 - macro_f1score: 0.8314 - val_loss: 1.2586 - val_accuracy: 0.6546 - val_top5_acc: 0.9900 - val_macro_f1score: 0.5826
# Learning rate:  1e-05
#
# Epoch 00064: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 64/70
# 448/448 [==============================] - ETA: 0s - loss: 0.3145 - accuracy: 0.8886 - top5_acc: 0.9997 - macro_f1score: 0.8307
# Epoch 00064: val_loss did not improve from 0.99041
#
# Epoch 00064: val_accuracy did not improve from 0.66155
# 448/448 [==============================] - 381s 851ms/step - loss: 0.3145 - accuracy: 0.8886 - top5_acc: 0.9997 - macro_f1score: 0.8307 - val_loss: 1.2500 - val_accuracy: 0.6526 - val_top5_acc: 0.9897 - val_macro_f1score: 0.5837
# Learning rate:  1e-05
#
# Epoch 00065: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 65/70
# 448/448 [==============================] - ETA: 0s - loss: 0.3060 - accuracy: 0.8926 - top5_acc: 0.9999 - macro_f1score: 0.8359
# Epoch 00065: val_loss did not improve from 0.99041
#
# Epoch 00065: val_accuracy did not improve from 0.66155
# 448/448 [==============================] - 381s 850ms/step - loss: 0.3060 - accuracy: 0.8926 - top5_acc: 0.9999 - macro_f1score: 0.8359 - val_loss: 1.2316 - val_accuracy: 0.6546 - val_top5_acc: 0.9902 - val_macro_f1score: 0.5876
# Learning rate:  1e-05
#
# Epoch 00066: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 66/70
# 448/448 [==============================] - ETA: 0s - loss: 0.3085 - accuracy: 0.8919 - top5_acc: 0.9998 - macro_f1score: 0.8370
# Epoch 00066: val_loss did not improve from 0.99041
#
# Epoch 00066: val_accuracy did not improve from 0.66155
# 448/448 [==============================] - 381s 851ms/step - loss: 0.3085 - accuracy: 0.8919 - top5_acc: 0.9998 - macro_f1score: 0.8370 - val_loss: 1.2257 - val_accuracy: 0.6588 - val_top5_acc: 0.9902 - val_macro_f1score: 0.5848
# Learning rate:  1e-05
#
# Epoch 00067: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 67/70
# 448/448 [==============================] - ETA: 0s - loss: 0.3101 - accuracy: 0.8921 - top5_acc: 0.9996 - macro_f1score: 0.8361
# Epoch 00067: val_loss did not improve from 0.99041
#
# Epoch 00067: val_accuracy did not improve from 0.66155
# 448/448 [==============================] - 381s 851ms/step - loss: 0.3101 - accuracy: 0.8921 - top5_acc: 0.9996 - macro_f1score: 0.8361 - val_loss: 1.2255 - val_accuracy: 0.6557 - val_top5_acc: 0.9897 - val_macro_f1score: 0.5813
# Learning rate:  1e-05
#
# Epoch 00068: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 68/70
# 448/448 [==============================] - ETA: 0s - loss: 0.3080 - accuracy: 0.8914 - top5_acc: 0.9998 - macro_f1score: 0.8329
# Epoch 00068: val_loss did not improve from 0.99041
#
# Epoch 00068: val_accuracy did not improve from 0.66155
# 448/448 [==============================] - 381s 851ms/step - loss: 0.3080 - accuracy: 0.8914 - top5_acc: 0.9998 - macro_f1score: 0.8329 - val_loss: 1.2175 - val_accuracy: 0.6607 - val_top5_acc: 0.9897 - val_macro_f1score: 0.5788
# Learning rate:  1e-05
#
# Epoch 00069: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 69/70
# 448/448 [==============================] - ETA: 0s - loss: 0.3067 - accuracy: 0.8934 - top5_acc: 0.9998 - macro_f1score: 0.8403
# Epoch 00069: val_loss did not improve from 0.99041
#
# Epoch 00069: val_accuracy did not improve from 0.66155
# 448/448 [==============================] - 381s 851ms/step - loss: 0.3067 - accuracy: 0.8934 - top5_acc: 0.9998 - macro_f1score: 0.8403 - val_loss: 1.2208 - val_accuracy: 0.6588 - val_top5_acc: 0.9902 - val_macro_f1score: 0.5859
# Learning rate:  1e-05
#
# Epoch 00070: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 70/70
# 448/448 [==============================] - ETA: 0s - loss: 0.3011 - accuracy: 0.8978 - top5_acc: 0.9999 - macro_f1score: 0.8403
# Epoch 00070: val_loss did not improve from 0.99041
#
# Epoch 00070: val_accuracy did not improve from 0.66155
# 448/448 [==============================] - 381s 851ms/step - loss: 0.3011 - accuracy: 0.8978 - top5_acc: 0.9999 - macro_f1score: 0.8403 - val_loss: 1.2014 - val_accuracy: 0.6576 - val_top5_acc: 0.9897 - val_macro_f1score: 0.5855

# %% [markdown]
# ### 2) DenseNet121 Evaluate

# %%
# 1. epoch=maximum
loss , acc, top5_acc, mf1 = model.evaluate(test_generator,steps=int(len(x_test)/batch_sizes))
print('[Test Loss: %.4f /  Test Top-1 Accuracy: %.4f / Test Top-5 Accuracy: %.4f / Test Macro f1: %.4f]\n' % (loss,acc,top5_acc,mf1))
# Out:
# 56/56 [==============================] - 2406s 43s/step - loss: 1.2667 - accuracy: 0.6490 - top5_acc: 0.9858 - macro_f1score: 0.5724
# [Test Loss: 1.2667 /  Test Top-1 Accuracy: 0.6490 / Test Top-5 Accuracy: 0.9858 / Test Macro f1: 0.5724]

# %%
loss=history.history['loss']
val_loss=history.history['val_loss']
acc=history.history['accuracy']
val_acc=history.history['val_accuracy']
top5_acc=history.history['top5_acc']
val_top5_acc=history.history['val_top5_acc']
f1=history.history['macro_f1score']
val_f1=history.history['val_macro_f1score']
epochs=range(1,len(acc)+1)

data = np.array([epochs,loss,val_loss,acc,val_acc,top5_acc,val_top5_acc,f1,val_f1]).T

# %%
# data save
# epochs, loss, val_loss, acc, val_acc, top5_acc, val_top5_acc, f1, val_f1

np.savetxt(os.path.join(dir,'train_valid_output',number,model.name+'.txt'),data)

# %%
# data import
data = np.loadtxt(os.path.join(dir,'train_valid_output',number,'DenseNet121.txt'))

# %%
epochs=data[:,0]
loss=data[:,1]
val_loss=data[:,2]
acc=data[:,3]
val_acc=data[:,4]
top5_acc=data[:,5]
val_top5_acc=data[:,6]

# %%
plt.plot(epochs[1:],acc[1:],'b',label='Training 1-Acc')
plt.plot(epochs[1:],val_acc[1:],'r',label='Validation 1-Acc')
plt.title('Training and Validation Top-1 Accuracy')
plt.legend()
plt.figure()

plt.plot(epochs[1:],top5_acc[1:],'b',label='Training 5-Acc')
plt.plot(epochs[1:],val_top5_acc[1:],'r',label='Validation 5-Acc')
plt.title('Training and Validation Top-5 Accuracy')
plt.legend()
plt.figure()

plt.plot(epochs[10:],loss[10:],'b',label='Training Loss')
plt.plot(epochs[10:],val_loss[10:],'r',label='Validation Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()

# %%
# 이 아래는 내가 인위적으로 살펴보고 싶은 epoch에 대해서 결과값 출력 / DenseNet121

# %%
# 참고 : https://github.com/OverLordGoldDragon/keras-adamw

import sys
sys.path.append('/content/drive/My Drive/Colab Notebooks/Paper')
import utils
import optimizers_v2
from utils import get_weight_decays, fill_dict_in_order
from utils import reset_seeds, K_eval
from optimizers_v2 import AdamW, NadamW, SGDW

# %%
# top-5 accuracy 출력
import functools
top5_acc = functools.partial(ks.metrics.top_k_categorical_accuracy, k=5)
top5_acc.__name__ = 'top5_acc'

# %%
model=load_model(os.path.join(dir,'model_output',number,'DenseNet121','032.h5'),custom_objects={"macro_f1score": macro_f1score,"top5_acc":top5_acc, "AdamW":AdamW})

# %%
# 2. epoch=?
loss , acc, top5_acc, mf1 = model.evaluate(test_generator,steps=int(len(x_test)/batch_sizes))
print('[Test Loss: %.4f /  Test Top-1 Accuracy: %.4f / Test Top-5 Accuracy: %.4f / Test Macro f1: %.4f]\n' % (loss,acc,top5_acc,mf1))
# Out:
# 56/56 [==============================] - 1393s 25s/step - loss: 1.0134 - accuracy: 0.6515 - top5_acc: 0.9897 - macro_f1score: 0.5633
# [Test Loss: 1.0134 /  Test Top-1 Accuracy: 0.6515 / Test Top-5 Accuracy: 0.9897 / Test Macro f1: 0.5633]
