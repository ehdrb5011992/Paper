# %%
# 참고 : https://sike6054.github.io/blog/paper/third-post/

# %% [markdown]
# # [Inception V2 & V3]

# %% [markdown]
# *KU LeeDongGyu*

# %% [markdown]
# ## Contents
# ---

# %% [markdown]
# 1. Data Preprocessing
# ```
# 1) Data Import
# 2) Data Augmentation
# ```
# 2. Support Functions & Almost Original Inception-V2,V3 (Especially V3)
# ```
# 1) Support Functions
# 2) Almost Original Inception-V2,V3 (Especially V3)
# 3) Inception-V3 Evaluate
# ```

# %% [markdown]
# ### Install Packages

# %% [markdown]
# ### Module

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/My Drive/Colab Notebooks/Paper
# Out:
# /content/drive/My Drive/Colab Notebooks/Paper

# %%
from f1score import macro_f1score,weighted_f1score
from smoothed_categorical_crossentropy import smoothed_categorical_crossentropy

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import cv2
import tensorflow as tf
from tensorflow import keras as ks
from tensorflow.keras import backend as K 
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, Input, Concatenate, ZeroPadding2D ,GlobalMaxPooling2D, Reshape , Lambda , Add, Multiply
from tensorflow.keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D, Activation, BatchNormalization, AveragePooling2D , ZeroPadding2D, SeparableConv2D , LeakyReLU
from tensorflow.keras.layers import add, concatenate, multiply
from tensorflow.keras.optimizers import Adam, RMSprop , SGD
from tensorflow.keras.callbacks import EarlyStopping , LearningRateScheduler, ModelCheckpoint, CSVLogger, Callback, ReduceLROnPlateau
from tensorflow.keras.regularizers import l1,l2,l1_l2
from tensorflow.keras.models import Model , load_model , Sequential
from tensorflow.keras.utils import plot_model , to_categorical, get_file
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
os.getcwd()
# Out:
# '/content/drive/My Drive/Colab Notebooks/Paper'

# %%
print(tf.__version__)
print(ks.__version__)
# Out:
# 2.3.0
# 2.4.0

# %%
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 13843519519780358319
# , name: "/device:XLA_CPU:0"
# device_type: "XLA_CPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 13383123148085534607
# physical_device_desc: "device: XLA_CPU device"
# , name: "/device:XLA_GPU:0"
# device_type: "XLA_GPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 7744391602190710092
# physical_device_desc: "device: XLA_GPU device"
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 15695488000
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 10427317602718966604
# physical_device_desc: "device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0"
# ]

# %%
# !cat /proc/cpuinfo
# Out:
# processor	: 0
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 79
# model name	: Intel(R) Xeon(R) CPU @ 2.20GHz
# stepping	: 0
# microcode	: 0x1
# cpu MHz		: 2199.998
# cache size	: 56320 KB
# physical id	: 0
# siblings	: 4
# core id		: 0
# cpu cores	: 2
# apicid		: 0
# initial apicid	: 0
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm rdseed adx smap xsaveopt arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs taa
# bogomips	: 4399.99
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 46 bits physical, 48 bits virtual
# power management:
#
# processor	: 1
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 79
# model name	: Intel(R) Xeon(R) CPU @ 2.20GHz
# stepping	: 0
# microcode	: 0x1
# cpu MHz		: 2199.998
# cache size	: 56320 KB
# physical id	: 0
# siblings	: 4
# core id		: 1
# cpu cores	: 2
# apicid		: 2
# initial apicid	: 2
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm rdseed adx smap xsaveopt arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs taa
# bogomips	: 4399.99
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 46 bits physical, 48 bits virtual
# power management:
#
# processor	: 2
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 79
# model name	: Intel(R) Xeon(R) CPU @ 2.20GHz
# stepping	: 0
# microcode	: 0x1
# cpu MHz		: 2199.998
# cache size	: 56320 KB
# physical id	: 0
# siblings	: 4
# core id		: 0
# cpu cores	: 2
# apicid		: 1
# initial apicid	: 1
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm rdseed adx smap xsaveopt arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs taa
# bogomips	: 4399.99
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 46 bits physical, 48 bits virtual
# power management:
#
# processor	: 3
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 79
# model name	: Intel(R) Xeon(R) CPU @ 2.20GHz
# stepping	: 0
# microcode	: 0x1
# cpu MHz		: 2199.998
# cache size	: 56320 KB
# physical id	: 0
# siblings	: 4
# core id		: 1
# cpu cores	: 2
# apicid		: 3
# initial apicid	: 3
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm rdseed adx smap xsaveopt arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs taa
# bogomips	: 4399.99
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 46 bits physical, 48 bits virtual
# power management:

# %% [markdown]
# ## 1. Data Preprocessing
# ---

# %% [markdown]
# ### 1) Data Import

# %%
# 바꿔서 살펴 볼 것들
# CALTECH, CIFAR100, FER, MIT
data_name = 'FER'
gan_type = 'No_GAN'
number = '1'
size = 299 # sizes after cropping
super_size = 330 # sizes before cropping 
input_sizes = (size,size,3)
batch_sizes = 64
weight_decay = 2e-3
epochs = 70

# %%
# 참고 : https://stackoverflow.com/questions/32419510/how-to-get-reproducible-results-in-keras/52897216#52897216
# setting the seed number for random number generation for reproducibility.

from numpy.random import seed
import random


if number=='1':
    seed_num = 200225
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)
elif number=='2':
    seed_num = 727
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)
elif number=='3':
    seed_num = 115
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)
elif number=='4':
    seed_num = 501
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)
elif number=='5':
    seed_num = 517
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)

# %%
# data import

if data_name=='FER' :
    x_train =  np.zeros(28698)
    x_valid = np.zeros(3589)
    x_test = np.zeros(3588)
    classes = 7 
    tr_center = [0.50793296, 0.50793296, 0.50793296]
elif data_name=='MIT':
    x_train = np.zeros(12466)
    x_valid = np.zeros(1564)
    x_test = np.zeros(1590)
    classes = 67 
    tr_center = [0.47916578, 0.42029615, 0.36046057]
elif data_name=='CALTECH':
    x_train = np.zeros(24510)
    x_valid = np.zeros(2980)
    x_test = np.zeros(3118)
    classes = 257
    tr_center = [0.51397761, 0.49525248, 0.46555727]
elif data_name=='CIFAR100':
    x_train = np.zeros(44923)
    x_valid = np.zeros(5077)
    x_test = np.zeros(10000)
    classes = 100
    tr_center = [0.53442983, 0.51355958, 0.46462564]

# %%
dir = os.path.join(os.getcwd(),data_name,gan_type)

# %% [markdown]
# ### 2) Data Augmentation

# %%
# 참고 : https://jkjung-avt.github.io/keras-image-cropping/

def random_crop(img, random_crop_size):
    # Note: image_data_format is 'channel_last'
    assert img.shape[2] == 3 # img.shape[2] 가 3(rgb)이 아니면 assertion error 발생
    height, width = img.shape[0], img.shape[1]
    dy, dx = random_crop_size
    x = np.random.randint(0, width - dx + 1)
    y = np.random.randint(0, height - dy + 1)
    return img[y:(y+dy), x:(x+dx), :]


def crop_generator(batches, crop_length):
    """Take as input a Keras ImageGen (Iterator) and generate random
    crops from the image batches generated by the original iterator.
    """
    while True:
        batch_x, batch_y = next(batches)
        batch_crops = np.zeros((batch_x.shape[0], crop_length, crop_length, 3))
        for i in range(batch_x.shape[0]):
            batch_crops[i] = random_crop(batch_x[i], (crop_length, crop_length))
        yield (batch_crops, batch_y)

# %%
from tensorflow.keras.preprocessing.image import img_to_array,load_img
import glob

# 데이터 전체에 대해 centering 진행함.

def read_cal_image(img_path): 
    x = img_to_array(load_img(img_path)) # x는 채널별 평균값
    y = x.shape[0] * x.shape[1]# y는 데이터별 픽셀 수 (비중)

    x = 1/255. * x # scaling하고, centering값을 뽑아냄.
    x = np.mean(x, axis=(0,1))
    
    return np.hstack([x,y])

def calculate_centered_mean(dataset_path,x_train=x_train):
    num = len(x_train)
    space = np.empty((num,4))
    i=0

    for p in glob.glob(os.path.join(dataset_path,'*/*.*')) :
        space[i] = read_cal_image(p)
        i += 1

    ratio = space[:,3] / np.sum(space[:,3])

    return np.average(space[:,0:3],axis=0,weights=ratio)


# 아래의 함수를 돌려서 나온 결과값을 중심화 값으로 설정.

# train_mean = calculate_centered_mean(os.path.join(dir,'data/train')).reshape((1,1,3))

# %%
datagen_tr = ImageDataGenerator(
    rescale=1/255.,
    horizontal_flip=True,
    featurewise_center=True,
    featurewise_std_normalization=False,
    rotation_range=10,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=[0.9,1.0],
    fill_mode = 'nearest')
datagen_val = ImageDataGenerator(rescale=1/255.,featurewise_center=True)
datagen_tes = ImageDataGenerator(rescale=1/255.,featurewise_center=True)

# 원래는 이 자리에 fit 매서드를 써야하지만, 그냥 내가 중심화함수를 만들고 적용함. 

# 중심화 설정
datagen_tr.mean = np.array(tr_center, dtype=np.float32).reshape((1,1,3)) # RGB
datagen_val.mean = np.array(tr_center, dtype=np.float32).reshape((1,1,3)) # RGB
datagen_tes.mean = np.array(tr_center, dtype=np.float32).reshape((1,1,3)) # RGB

# %%
# Inception-V2 & V3은 분류기가 2개이므로 imagedatagenerator 사용방법이 다소 다르다.
# model.fit에 다중 input으로 들어갈 함수를 개인이 만들어서 사용해야 하며, 그 함수는 아래와 같다. 
# 매우 간단하다.

#1. train data

def generate_train_for_two(crop_length=size, batch_sizes = batch_sizes, super_size=super_size):

      batches = datagen_tr.flow_from_directory(directory=os.path.join(dir,'data/train'),target_size=(super_size,super_size),batch_size=batch_sizes,class_mode='categorical')

      while True:
          batch_x, batch_y = next(batches)
          batch_crops = np.zeros((batch_x.shape[0], crop_length, crop_length, 3))
          for i in range(batch_x.shape[0]):
              batch_crops[i] = random_crop(batch_x[i], (crop_length, crop_length))
          yield batch_crops, [batch_y,batch_y]

# %%
# 2. valid data

def generate_valid_for_two(size=size, batch_sizes = batch_sizes):

      batches_xy = datagen_val.flow_from_directory(directory=os.path.join(dir,'data/valid'),target_size=(size,size),batch_size=batch_sizes,class_mode='categorical')

      while True:

          batch_xy = batches_xy.next()
          yield  batch_xy[0], [ batch_xy[1],batch_xy[1] ]

# %%
# 3. test data

def generate_test_for_two(size=size, batch_sizes = batch_sizes):

      batches_xy = datagen_tes.flow_from_directory(directory=os.path.join(dir,'data/test'),target_size=(size,size),batch_size=batch_sizes,class_mode='categorical')

      while True:

          batch_xy = batches_xy.next()
          yield  batch_xy[0], [ batch_xy[1],batch_xy[1] ]

# %%
# 위에서 쓰임
# train_batches = datagen_tr.flow_from_directory(directory=os.path.join(dir,'data/train'),target_size=(super_size,super_size),batch_size=batch_sizes,class_mode='categorical') # fer : 28698 / mit : 12466 / caltech : 24509 / cifar : 44923
# train_generator= crop_generator(train_batches, size)

# valid_generator = datagen_val.flow_from_directory(directory=os.path.join(dir,'data/valid'),target_size=(size,size),batch_size=batch_sizes,class_mode='categorical') # fer : 3589 / mit : 1564 / caltech : 2980 / cifar : 5077
# test_generator = datagen_tes.flow_from_directory(directory=os.path.join(dir,'data/test'),target_size=(size,size),batch_size=batch_sizes,class_mode='categorical') # fer : 3588 / mit : 1590 / caltech : 3118 / cifar : 10000

# %% [markdown]
# ## 2. Support Functions & Almost Original Inception-V2,V3 (Especially V3)
# ---

# %% [markdown]
# ### 1) Support Functions

# %%
# def lr_schedule(epoch):
#     init_lr = 1e-4
#     k = 0.04
#     lr = init_lr * np.exp(-k*epoch)
#     print('Learning rate: ', lr)
#     return lr

def lr_schedule(epoch):
    lr = 1e-3
    if epoch < 30:
        lr = lr
    elif epoch < 60 :
        lr = lr * 0.1
    else:
        lr = lr * 0.01
    print('Learning rate: ', lr)
    return lr

# %%
def smoothed_categorical_crossentropy(y_true, y_pred): 
    if smoothing_param > 0:
        smooth_positives = 1.0 - smoothing_param 
        smooth_negatives = smoothing_param / classes 
        y_true = y_true * smooth_positives + smooth_negatives 

    return K.categorical_crossentropy(y_true, y_pred)

# %%
def conv2d_bn(x, filters, kernel_size, weight_decay=weight_decay, padding='same', strides=1, activation='relu'):
    x = Conv2D(filters, (kernel_size[0], kernel_size[1]), padding=padding, strides=strides, kernel_initializer='he_uniform', use_bias=False, kernel_regularizer=l2(weight_decay))(x)    
    x = BatchNormalization()(x)
    
    if activation:
        x = Activation(activation)(x)
    
    return x

# %%
def inception_f3(input_tensor, filter_channels, name=None):
    filter_b1, filter_b2, filter_b3, filter_b4 = filter_channels
    
    branch_1 = conv2d_bn(input_tensor, filter_b1[0], (1, 1))
    branch_1 = conv2d_bn(branch_1, filter_b1[1], (3, 3))
    branch_1 = conv2d_bn(branch_1, filter_b1[2], (3, 3))
    
    branch_2 = conv2d_bn(input_tensor, filter_b2[0], (1, 1))
    branch_2 = conv2d_bn(branch_2, filter_b2[1], (3, 3))
    
    branch_3 = MaxPooling2D((3, 3), strides=1, padding='same')(input_tensor)
    branch_3 = conv2d_bn(branch_3, filter_b3, (1, 1))
    
    branch_4 = conv2d_bn(input_tensor, filter_b4, (1, 1))
    
    filter_concat = Concatenate(name=name)([branch_1, branch_2, branch_3, branch_4]) if not name==None else Concatenate()([branch_1, branch_2, branch_3, branch_4])
    
    return filter_concat

def inception_f6(input_tensor, filter_channels, n=7, name=None):
    filter_b1, filter_b2, filter_b3, filter_b4 = filter_channels
    
    branch_1 = conv2d_bn(input_tensor, filter_b1[0], (1, 1))
    branch_1 = conv2d_bn(branch_1, filter_b1[1], (1, n))
    branch_1 = conv2d_bn(branch_1, filter_b1[2], (n, 1))
    branch_1 = conv2d_bn(branch_1, filter_b1[3], (1, n))
    branch_1 = conv2d_bn(branch_1, filter_b1[4], (n, 1))
    
    branch_2 = conv2d_bn(input_tensor, filter_b2[0], (1, 1))
    branch_2 = conv2d_bn(branch_2, filter_b2[1], (1, n))
    branch_2 = conv2d_bn(branch_2, filter_b2[2], (n, 1))
    
    branch_3 = MaxPooling2D((3, 3), strides=1, padding='same')(input_tensor)
    branch_3 = conv2d_bn(branch_3, filter_b3, (1, 1))
    
    branch_4 = conv2d_bn(input_tensor, filter_b4, (1, 1))
    
    filter_concat = Concatenate(name=name)([branch_1, branch_2, branch_3, branch_4]) if not name==None else Concatenate()([branch_1, branch_2, branch_3, branch_4])
    
    return filter_concat

def inception_f10(input_tensor, filter_channels, name=None):
    filter_b1, filter_b2, filter_b3, filter_b4 = filter_channels
    
    branch_1 = conv2d_bn(input_tensor, filter_b1[0], (1, 1))
    branch_1 = conv2d_bn(branch_1, filter_b1[1], (3, 3))
    branch_1a = conv2d_bn(branch_1, filter_b1[2][0], (1, 3))
    branch_1b = conv2d_bn(branch_1, filter_b1[2][1], (3, 1))
    branch_1 = Concatenate()([branch_1a, branch_1b])
    
    branch_2 = conv2d_bn(input_tensor, filter_b2[0], (1, 1))
    branch_2a = conv2d_bn(branch_2, filter_b2[1][0], (1, 3))
    branch_2b = conv2d_bn(branch_2, filter_b2[1][1], (3, 1))
    branch_2 = Concatenate()([branch_2a, branch_2b])
    
    branch_3 = MaxPooling2D((3, 3), strides=1, padding='same')(input_tensor)
    branch_3 = conv2d_bn(branch_3, filter_b3, (1, 1))
    
    branch_4 = conv2d_bn(input_tensor, filter_b4, (1, 1))
    
    filter_concat = Concatenate(name=name)([branch_1, branch_2, branch_3, branch_4]) if not name==None else Concatenate()([branch_1, branch_2, branch_3, branch_4])
    
    return filter_concat
    
def inception_dim_reduction(input_tensor, filter_channels, name=None):
    filter_b1, filter_b2 = filter_channels
    
    branch_1 = conv2d_bn(input_tensor, filter_b1[0], (1, 1))
    branch_1 = conv2d_bn(branch_1, filter_b1[1], (3, 3))
    branch_1 = conv2d_bn(branch_1, filter_b1[2], (3, 3), strides=2)
    
    branch_2 = conv2d_bn(input_tensor, filter_b2[0], (1, 1))
    branch_2 = conv2d_bn(branch_2, filter_b2[1], (3, 3), strides=2)
    
    branch_3 = MaxPooling2D((3, 3), strides=2, padding='same')(input_tensor)
    
    filter_concat = Concatenate(name=name)([branch_1, branch_2, branch_3]) if not name==None else Concatenate()([branch_1, branch_2, branch_3])
    
    return filter_concat

# %% [markdown]
# ### 2) Almost Original Inception-V2,V3 (Especially V3)

# %%
def Inception_v3(model_input, name, weight_decay= weight_decay):
    x = conv2d_bn(model_input, 32, (3, 3), padding='valid', strides=2) # (299, 299, 3) -> (149, 149, 32)
    x = conv2d_bn(x, 32, (3, 3), padding='valid') # (147, 147, 32) -> (147, 147, 32)
    x = conv2d_bn(x, 64, (3, 3), padding='same') # (147, 147, 32) -> (147, 147, 64)
    
    x = MaxPooling2D((3, 3), strides=2, padding='valid')(x) # (147, 147, 64) -> (73, 73, 64)
    
    x = conv2d_bn(x, 80, (3, 3), padding='valid') # (73, 73, 64) -> (71, 71, 80)
    x = conv2d_bn(x, 192, (3, 3), padding='valid', strides=2) # (71, 71, 80) -> (35, 35, 192)
    x = conv2d_bn(x, 288, (3, 3), padding='same') # (35, 35, 192) -> (35, 35, 288)
    
    x = inception_f3(x, [[64, 96, 96], [48, 64], 64 , 64]) # (35, 35, 288)
    x = inception_f3(x, [[64, 96, 96], [48, 64], 64 , 64]) # (35, 35, 288)
    x = inception_f3(x, [[64, 96, 96], [48, 64], 64 , 64], name='block_inception_f3') # (35, 35, 288)
    
    x = inception_dim_reduction(x, [[64, 96, 96], [256, 384]], name='block_reduction_1') # (35, 35, 288) -> (17, 17, 768)
    
    x = inception_f6(x, [[128, 128, 128, 128, 192], [128, 128, 192], 192, 192]) # (17, 17, 768)
    x = inception_f6(x, [[160, 160, 160, 160, 192], [160, 160, 192], 192, 192]) # (17, 17, 768)
    x = inception_f6(x, [[160, 160, 160, 160, 192], [160, 160, 192], 192, 192]) # (17, 17, 768)
    x = inception_f6(x, [[192, 192, 192, 192, 192], [192, 192, 192], 192, 192]) # (17, 17, 768)
    x_a = inception_f6(x, [[192, 192, 192, 192, 192], [192, 192, 192], 192, 192], name='block_inception_f6') # (17, 17, 768)
    
    x = inception_dim_reduction(x_a, [[128, 192, 192], [192, 320]], name='block_reduction_2') # (17, 17, 768) -> (8, 8, 1280)
    
    x = inception_f10(x, [[448, 384, [384, 384]], [384, [384, 384]], 192, 320]) # (8, 8, 1280) -> (8, 8, 2048)
    x = inception_f10(x, [[448, 384, [384, 384]], [384, [384, 384]], 192, 320], name='block_inception_f10') # (8, 8, 2048)
    
    x = GlobalAveragePooling2D()(x)
    x = Dropout(0.2)(x)
    
    x = Dense(classes, use_bias=False, kernel_regularizer=l2(weight_decay), activation=None)(x)
    
    model_output = Dense(classes, activation='softmax', name='main_classifier')(x) # 'softmax'
    
    # Auxiliary Classifier
    auxiliary = AveragePooling2D((5, 5), strides=3, padding='valid')(x_a) # (17, 17, 768) -> (5, 5, 768)
    auxiliary = conv2d_bn(auxiliary, 128, (1, 1)) # (5, 5, 768) -> (5, 5, 128)
    
    auxiliary = conv2d_bn(auxiliary, 1024, K.int_shape(auxiliary)[1:3], padding='valid') # (5, 5, 768) -> (1, 1, 1024)
    auxiliary = Flatten()(auxiliary) # (1, 1, 1024)
    auxiliary_output = Dense(classes, use_bias=False, kernel_regularizer=l2(weight_decay), activation='softmax', name='auxiliary_classifier')(auxiliary)
    
    model = Model(model_input, [model_output, auxiliary_output],name=name)
    
    return model

# %%
smoothing_param = 0.1
model_input = Input(shape=input_sizes)
model = Inception_v3(model_input, weight_decay = weight_decay, name = "Inception_v3")

# %%
model.summary()
# Out:
# Model: "Inception_v3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 299, 299, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 149, 149, 32) 864         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 149, 149, 32) 128         conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 149, 149, 32) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 147, 147, 32) 9216        activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 147, 147, 32) 128         conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 147, 147, 32) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 147, 147, 64) 18432       activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 147, 147, 64) 256         conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 147, 147, 64) 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 73, 73, 64)   0           activation_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 71, 71, 80)   46080       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 71, 71, 80)   320         conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 71, 71, 80)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 35, 35, 192)  138240      activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 35, 35, 192)  768         conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 35, 35, 192)  0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 35, 35, 288)  497664      activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 35, 35, 288)  1152        conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 35, 35, 288)  0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 35, 35, 64)   18432       activation_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 35, 35, 64)   256         conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 35, 35, 64)   0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 35, 35, 96)   55296       activation_6[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 35, 35, 48)   13824       activation_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 35, 35, 96)   384         conv2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 35, 35, 48)   192         conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 35, 35, 96)   0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 35, 35, 48)   0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 35, 35, 288)  0           activation_5[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 35, 35, 96)   82944       activation_7[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 35, 35, 64)   27648       activation_9[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 35, 35, 64)   18432       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 35, 35, 64)   18432       activation_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 35, 35, 96)   384         conv2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 35, 35, 64)   256         conv2d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 35, 35, 64)   256         conv2d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 35, 35, 64)   256         conv2d_12[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 35, 35, 96)   0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 35, 35, 64)   0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 35, 35, 64)   0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 35, 35, 64)   0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 35, 35, 288)  0           activation_8[0][0]
#                                                                  activation_10[0][0]
#                                                                  activation_11[0][0]
#                                                                  activation_12[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 35, 35, 64)   18432       concatenate[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 35, 35, 64)   256         conv2d_13[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 35, 35, 64)   0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 35, 35, 96)   55296       activation_13[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 35, 35, 48)   13824       concatenate[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 35, 35, 96)   384         conv2d_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 35, 35, 48)   192         conv2d_16[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 35, 35, 96)   0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 35, 35, 48)   0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 35, 35, 288)  0           concatenate[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 35, 35, 96)   82944       activation_14[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 35, 35, 64)   27648       activation_16[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 35, 35, 64)   18432       max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 35, 35, 64)   18432       concatenate[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 35, 35, 96)   384         conv2d_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 35, 35, 64)   256         conv2d_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 35, 35, 64)   256         conv2d_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 35, 35, 64)   256         conv2d_19[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 35, 35, 96)   0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 35, 35, 64)   0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 35, 35, 64)   0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 35, 35, 64)   0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 35, 35, 288)  0           activation_15[0][0]
#                                                                  activation_17[0][0]
#                                                                  activation_18[0][0]
#                                                                  activation_19[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 35, 35, 64)   18432       concatenate_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 35, 35, 64)   256         conv2d_20[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 35, 35, 64)   0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 35, 35, 96)   55296       activation_20[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 35, 35, 48)   13824       concatenate_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 35, 35, 96)   384         conv2d_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 35, 35, 48)   192         conv2d_23[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 35, 35, 96)   0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 35, 35, 48)   0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 35, 35, 288)  0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 35, 35, 96)   82944       activation_21[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 35, 35, 64)   27648       activation_23[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 35, 35, 64)   18432       max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 35, 35, 64)   18432       concatenate_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 35, 35, 96)   384         conv2d_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 35, 35, 64)   256         conv2d_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 35, 35, 64)   256         conv2d_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 35, 35, 64)   256         conv2d_26[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 35, 35, 96)   0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 35, 35, 64)   0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 35, 35, 64)   0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 35, 35, 64)   0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# block_inception_f3 (Concatenate (None, 35, 35, 288)  0           activation_22[0][0]
#                                                                  activation_24[0][0]
#                                                                  activation_25[0][0]
#                                                                  activation_26[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 35, 35, 64)   18432       block_inception_f3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 35, 35, 64)   256         conv2d_27[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 35, 35, 64)   0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 35, 35, 96)   55296       activation_27[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 35, 35, 256)  73728       block_inception_f3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 35, 35, 96)   384         conv2d_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 35, 35, 256)  1024        conv2d_30[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 35, 35, 96)   0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 35, 35, 256)  0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 18, 18, 96)   82944       activation_28[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 18, 18, 384)  884736      activation_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 18, 18, 96)   384         conv2d_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 18, 18, 384)  1536        conv2d_31[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 18, 18, 96)   0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 18, 18, 384)  0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 18, 18, 288)  0           block_inception_f3[0][0]
# __________________________________________________________________________________________________
# block_reduction_1 (Concatenate) (None, 18, 18, 768)  0           activation_29[0][0]
#                                                                  activation_31[0][0]
#                                                                  max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 18, 18, 128)  98304       block_reduction_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 18, 18, 128)  512         conv2d_32[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 18, 18, 128)  0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 18, 18, 128)  114688      activation_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 18, 18, 128)  512         conv2d_33[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 18, 18, 128)  0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 18, 18, 128)  114688      activation_33[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 18, 18, 128)  98304       block_reduction_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 18, 18, 128)  512         conv2d_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 18, 18, 128)  512         conv2d_37[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 18, 18, 128)  0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 18, 18, 128)  0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 18, 18, 128)  114688      activation_34[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 18, 18, 128)  114688      activation_37[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 18, 18, 128)  512         conv2d_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 18, 18, 128)  512         conv2d_38[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 18, 18, 128)  0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 18, 18, 128)  0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 18, 18, 768)  0           block_reduction_1[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 18, 18, 192)  172032      activation_35[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 18, 18, 192)  172032      activation_38[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 18, 18, 192)  147456      max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 18, 18, 192)  147456      block_reduction_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 18, 18, 192)  768         conv2d_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 18, 18, 192)  768         conv2d_39[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 18, 18, 192)  768         conv2d_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 18, 18, 192)  768         conv2d_41[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 18, 18, 192)  0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 18, 18, 192)  0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 18, 18, 192)  0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 18, 18, 192)  0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 18, 18, 768)  0           activation_36[0][0]
#                                                                  activation_39[0][0]
#                                                                  activation_40[0][0]
#                                                                  activation_41[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 18, 18, 160)  122880      concatenate_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 18, 18, 160)  640         conv2d_42[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 18, 18, 160)  0           batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 18, 18, 160)  179200      activation_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 18, 18, 160)  640         conv2d_43[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 18, 18, 160)  0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 18, 18, 160)  179200      activation_43[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 18, 18, 160)  122880      concatenate_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 18, 18, 160)  640         conv2d_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 18, 18, 160)  640         conv2d_47[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 18, 18, 160)  0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 18, 18, 160)  0           batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 18, 18, 160)  179200      activation_44[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 18, 18, 160)  179200      activation_47[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 18, 18, 160)  640         conv2d_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 18, 18, 160)  640         conv2d_48[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 18, 18, 160)  0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 18, 18, 160)  0           batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)  (None, 18, 18, 768)  0           concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 18, 18, 192)  215040      activation_45[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 18, 18, 192)  215040      activation_48[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 18, 18, 192)  147456      max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 18, 18, 192)  147456      concatenate_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 18, 18, 192)  768         conv2d_46[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 18, 18, 192)  768         conv2d_49[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 18, 18, 192)  768         conv2d_50[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 18, 18, 192)  768         conv2d_51[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 18, 18, 192)  0           batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 18, 18, 192)  0           batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, 18, 18, 192)  0           batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# activation_51 (Activation)      (None, 18, 18, 192)  0           batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 18, 18, 768)  0           activation_46[0][0]
#                                                                  activation_49[0][0]
#                                                                  activation_50[0][0]
#                                                                  activation_51[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 18, 18, 160)  122880      concatenate_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 18, 18, 160)  640         conv2d_52[0][0]
# __________________________________________________________________________________________________
# activation_52 (Activation)      (None, 18, 18, 160)  0           batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 18, 18, 160)  179200      activation_52[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, 18, 18, 160)  640         conv2d_53[0][0]
# __________________________________________________________________________________________________
# activation_53 (Activation)      (None, 18, 18, 160)  0           batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 18, 18, 160)  179200      activation_53[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 18, 18, 160)  122880      concatenate_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, 18, 18, 160)  640         conv2d_54[0][0]
# __________________________________________________________________________________________________
# batch_normalization_57 (BatchNo (None, 18, 18, 160)  640         conv2d_57[0][0]
# __________________________________________________________________________________________________
# activation_54 (Activation)      (None, 18, 18, 160)  0           batch_normalization_54[0][0]
# __________________________________________________________________________________________________
# activation_57 (Activation)      (None, 18, 18, 160)  0           batch_normalization_57[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 18, 18, 160)  179200      activation_54[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, 18, 18, 160)  179200      activation_57[0][0]
# __________________________________________________________________________________________________
# batch_normalization_55 (BatchNo (None, 18, 18, 160)  640         conv2d_55[0][0]
# __________________________________________________________________________________________________
# batch_normalization_58 (BatchNo (None, 18, 18, 160)  640         conv2d_58[0][0]
# __________________________________________________________________________________________________
# activation_55 (Activation)      (None, 18, 18, 160)  0           batch_normalization_55[0][0]
# __________________________________________________________________________________________________
# activation_58 (Activation)      (None, 18, 18, 160)  0           batch_normalization_58[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_7 (MaxPooling2D)  (None, 18, 18, 768)  0           concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 18, 18, 192)  215040      activation_55[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, 18, 18, 192)  215040      activation_58[0][0]
# __________________________________________________________________________________________________
# conv2d_60 (Conv2D)              (None, 18, 18, 192)  147456      max_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_61 (Conv2D)              (None, 18, 18, 192)  147456      concatenate_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_56 (BatchNo (None, 18, 18, 192)  768         conv2d_56[0][0]
# __________________________________________________________________________________________________
# batch_normalization_59 (BatchNo (None, 18, 18, 192)  768         conv2d_59[0][0]
# __________________________________________________________________________________________________
# batch_normalization_60 (BatchNo (None, 18, 18, 192)  768         conv2d_60[0][0]
# __________________________________________________________________________________________________
# batch_normalization_61 (BatchNo (None, 18, 18, 192)  768         conv2d_61[0][0]
# __________________________________________________________________________________________________
# activation_56 (Activation)      (None, 18, 18, 192)  0           batch_normalization_56[0][0]
# __________________________________________________________________________________________________
# activation_59 (Activation)      (None, 18, 18, 192)  0           batch_normalization_59[0][0]
# __________________________________________________________________________________________________
# activation_60 (Activation)      (None, 18, 18, 192)  0           batch_normalization_60[0][0]
# __________________________________________________________________________________________________
# activation_61 (Activation)      (None, 18, 18, 192)  0           batch_normalization_61[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 18, 18, 768)  0           activation_56[0][0]
#                                                                  activation_59[0][0]
#                                                                  activation_60[0][0]
#                                                                  activation_61[0][0]
# __________________________________________________________________________________________________
# conv2d_62 (Conv2D)              (None, 18, 18, 192)  147456      concatenate_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_62 (BatchNo (None, 18, 18, 192)  768         conv2d_62[0][0]
# __________________________________________________________________________________________________
# activation_62 (Activation)      (None, 18, 18, 192)  0           batch_normalization_62[0][0]
# __________________________________________________________________________________________________
# conv2d_63 (Conv2D)              (None, 18, 18, 192)  258048      activation_62[0][0]
# __________________________________________________________________________________________________
# batch_normalization_63 (BatchNo (None, 18, 18, 192)  768         conv2d_63[0][0]
# __________________________________________________________________________________________________
# activation_63 (Activation)      (None, 18, 18, 192)  0           batch_normalization_63[0][0]
# __________________________________________________________________________________________________
# conv2d_64 (Conv2D)              (None, 18, 18, 192)  258048      activation_63[0][0]
# __________________________________________________________________________________________________
# conv2d_67 (Conv2D)              (None, 18, 18, 192)  147456      concatenate_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_64 (BatchNo (None, 18, 18, 192)  768         conv2d_64[0][0]
# __________________________________________________________________________________________________
# batch_normalization_67 (BatchNo (None, 18, 18, 192)  768         conv2d_67[0][0]
# __________________________________________________________________________________________________
# activation_64 (Activation)      (None, 18, 18, 192)  0           batch_normalization_64[0][0]
# __________________________________________________________________________________________________
# activation_67 (Activation)      (None, 18, 18, 192)  0           batch_normalization_67[0][0]
# __________________________________________________________________________________________________
# conv2d_65 (Conv2D)              (None, 18, 18, 192)  258048      activation_64[0][0]
# __________________________________________________________________________________________________
# conv2d_68 (Conv2D)              (None, 18, 18, 192)  258048      activation_67[0][0]
# __________________________________________________________________________________________________
# batch_normalization_65 (BatchNo (None, 18, 18, 192)  768         conv2d_65[0][0]
# __________________________________________________________________________________________________
# batch_normalization_68 (BatchNo (None, 18, 18, 192)  768         conv2d_68[0][0]
# __________________________________________________________________________________________________
# activation_65 (Activation)      (None, 18, 18, 192)  0           batch_normalization_65[0][0]
# __________________________________________________________________________________________________
# activation_68 (Activation)      (None, 18, 18, 192)  0           batch_normalization_68[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_8 (MaxPooling2D)  (None, 18, 18, 768)  0           concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv2d_66 (Conv2D)              (None, 18, 18, 192)  258048      activation_65[0][0]
# __________________________________________________________________________________________________
# conv2d_69 (Conv2D)              (None, 18, 18, 192)  258048      activation_68[0][0]
# __________________________________________________________________________________________________
# conv2d_70 (Conv2D)              (None, 18, 18, 192)  147456      max_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_71 (Conv2D)              (None, 18, 18, 192)  147456      concatenate_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_66 (BatchNo (None, 18, 18, 192)  768         conv2d_66[0][0]
# __________________________________________________________________________________________________
# batch_normalization_69 (BatchNo (None, 18, 18, 192)  768         conv2d_69[0][0]
# __________________________________________________________________________________________________
# batch_normalization_70 (BatchNo (None, 18, 18, 192)  768         conv2d_70[0][0]
# __________________________________________________________________________________________________
# batch_normalization_71 (BatchNo (None, 18, 18, 192)  768         conv2d_71[0][0]
# __________________________________________________________________________________________________
# activation_66 (Activation)      (None, 18, 18, 192)  0           batch_normalization_66[0][0]
# __________________________________________________________________________________________________
# activation_69 (Activation)      (None, 18, 18, 192)  0           batch_normalization_69[0][0]
# ...
# __________________________________________________________________________________________________
# batch_normalization_87 (BatchNo (None, 9, 9, 448)    1792        conv2d_87[0][0]
# __________________________________________________________________________________________________
# activation_87 (Activation)      (None, 9, 9, 448)    0           batch_normalization_87[0][0]
# __________________________________________________________________________________________________
# conv2d_88 (Conv2D)              (None, 9, 9, 384)    1548288     activation_87[0][0]
# __________________________________________________________________________________________________
# conv2d_91 (Conv2D)              (None, 9, 9, 384)    491520      block_reduction_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_88 (BatchNo (None, 9, 9, 384)    1536        conv2d_88[0][0]
# __________________________________________________________________________________________________
# batch_normalization_91 (BatchNo (None, 9, 9, 384)    1536        conv2d_91[0][0]
# __________________________________________________________________________________________________
# activation_88 (Activation)      (None, 9, 9, 384)    0           batch_normalization_88[0][0]
# __________________________________________________________________________________________________
# activation_91 (Activation)      (None, 9, 9, 384)    0           batch_normalization_91[0][0]
# __________________________________________________________________________________________________
# conv2d_89 (Conv2D)              (None, 9, 9, 384)    442368      activation_88[0][0]
# __________________________________________________________________________________________________
# conv2d_90 (Conv2D)              (None, 9, 9, 384)    442368      activation_88[0][0]
# __________________________________________________________________________________________________
# conv2d_92 (Conv2D)              (None, 9, 9, 384)    442368      activation_91[0][0]
# __________________________________________________________________________________________________
# conv2d_93 (Conv2D)              (None, 9, 9, 384)    442368      activation_91[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_11 (MaxPooling2D) (None, 9, 9, 1280)   0           block_reduction_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_89 (BatchNo (None, 9, 9, 384)    1536        conv2d_89[0][0]
# __________________________________________________________________________________________________
# batch_normalization_90 (BatchNo (None, 9, 9, 384)    1536        conv2d_90[0][0]
# __________________________________________________________________________________________________
# batch_normalization_92 (BatchNo (None, 9, 9, 384)    1536        conv2d_92[0][0]
# __________________________________________________________________________________________________
# batch_normalization_93 (BatchNo (None, 9, 9, 384)    1536        conv2d_93[0][0]
# __________________________________________________________________________________________________
# conv2d_94 (Conv2D)              (None, 9, 9, 192)    245760      max_pooling2d_11[0][0]
# __________________________________________________________________________________________________
# conv2d_95 (Conv2D)              (None, 9, 9, 320)    409600      block_reduction_2[0][0]
# __________________________________________________________________________________________________
# activation_89 (Activation)      (None, 9, 9, 384)    0           batch_normalization_89[0][0]
# __________________________________________________________________________________________________
# activation_90 (Activation)      (None, 9, 9, 384)    0           batch_normalization_90[0][0]
# __________________________________________________________________________________________________
# activation_92 (Activation)      (None, 9, 9, 384)    0           batch_normalization_92[0][0]
# __________________________________________________________________________________________________
# activation_93 (Activation)      (None, 9, 9, 384)    0           batch_normalization_93[0][0]
# __________________________________________________________________________________________________
# batch_normalization_94 (BatchNo (None, 9, 9, 192)    768         conv2d_94[0][0]
# __________________________________________________________________________________________________
# batch_normalization_95 (BatchNo (None, 9, 9, 320)    1280        conv2d_95[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 9, 9, 768)    0           activation_89[0][0]
#                                                                  activation_90[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 9, 9, 768)    0           activation_92[0][0]
#                                                                  activation_93[0][0]
# __________________________________________________________________________________________________
# activation_94 (Activation)      (None, 9, 9, 192)    0           batch_normalization_94[0][0]
# __________________________________________________________________________________________________
# activation_95 (Activation)      (None, 9, 9, 320)    0           batch_normalization_95[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 9, 9, 2048)   0           concatenate_6[0][0]
#                                                                  concatenate_7[0][0]
#                                                                  activation_94[0][0]
#                                                                  activation_95[0][0]
# __________________________________________________________________________________________________
# conv2d_96 (Conv2D)              (None, 9, 9, 448)    917504      concatenate_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_96 (BatchNo (None, 9, 9, 448)    1792        conv2d_96[0][0]
# __________________________________________________________________________________________________
# activation_96 (Activation)      (None, 9, 9, 448)    0           batch_normalization_96[0][0]
# __________________________________________________________________________________________________
# conv2d_97 (Conv2D)              (None, 9, 9, 384)    1548288     activation_96[0][0]
# __________________________________________________________________________________________________
# conv2d_100 (Conv2D)             (None, 9, 9, 384)    786432      concatenate_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_97 (BatchNo (None, 9, 9, 384)    1536        conv2d_97[0][0]
# __________________________________________________________________________________________________
# batch_normalization_100 (BatchN (None, 9, 9, 384)    1536        conv2d_100[0][0]
# __________________________________________________________________________________________________
# activation_97 (Activation)      (None, 9, 9, 384)    0           batch_normalization_97[0][0]
# __________________________________________________________________________________________________
# activation_100 (Activation)     (None, 9, 9, 384)    0           batch_normalization_100[0][0]
# __________________________________________________________________________________________________
# conv2d_98 (Conv2D)              (None, 9, 9, 384)    442368      activation_97[0][0]
# __________________________________________________________________________________________________
# conv2d_99 (Conv2D)              (None, 9, 9, 384)    442368      activation_97[0][0]
# __________________________________________________________________________________________________
# conv2d_101 (Conv2D)             (None, 9, 9, 384)    442368      activation_100[0][0]
# __________________________________________________________________________________________________
# conv2d_102 (Conv2D)             (None, 9, 9, 384)    442368      activation_100[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_12 (MaxPooling2D) (None, 9, 9, 2048)   0           concatenate_8[0][0]
# __________________________________________________________________________________________________
# average_pooling2d (AveragePooli (None, 5, 5, 768)    0           block_inception_f6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_98 (BatchNo (None, 9, 9, 384)    1536        conv2d_98[0][0]
# __________________________________________________________________________________________________
# batch_normalization_99 (BatchNo (None, 9, 9, 384)    1536        conv2d_99[0][0]
# __________________________________________________________________________________________________
# batch_normalization_101 (BatchN (None, 9, 9, 384)    1536        conv2d_101[0][0]
# __________________________________________________________________________________________________
# batch_normalization_102 (BatchN (None, 9, 9, 384)    1536        conv2d_102[0][0]
# __________________________________________________________________________________________________
# conv2d_103 (Conv2D)             (None, 9, 9, 192)    393216      max_pooling2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_104 (Conv2D)             (None, 9, 9, 320)    655360      concatenate_8[0][0]
# __________________________________________________________________________________________________
# conv2d_105 (Conv2D)             (None, 5, 5, 128)    98304       average_pooling2d[0][0]
# __________________________________________________________________________________________________
# activation_98 (Activation)      (None, 9, 9, 384)    0           batch_normalization_98[0][0]
# __________________________________________________________________________________________________
# activation_99 (Activation)      (None, 9, 9, 384)    0           batch_normalization_99[0][0]
# __________________________________________________________________________________________________
# activation_101 (Activation)     (None, 9, 9, 384)    0           batch_normalization_101[0][0]
# __________________________________________________________________________________________________
# activation_102 (Activation)     (None, 9, 9, 384)    0           batch_normalization_102[0][0]
# __________________________________________________________________________________________________
# batch_normalization_103 (BatchN (None, 9, 9, 192)    768         conv2d_103[0][0]
# __________________________________________________________________________________________________
# batch_normalization_104 (BatchN (None, 9, 9, 320)    1280        conv2d_104[0][0]
# __________________________________________________________________________________________________
# batch_normalization_105 (BatchN (None, 5, 5, 128)    512         conv2d_105[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 9, 9, 768)    0           activation_98[0][0]
#                                                                  activation_99[0][0]
# __________________________________________________________________________________________________
# concatenate_10 (Concatenate)    (None, 9, 9, 768)    0           activation_101[0][0]
#                                                                  activation_102[0][0]
# __________________________________________________________________________________________________
# activation_103 (Activation)     (None, 9, 9, 192)    0           batch_normalization_103[0][0]
# __________________________________________________________________________________________________
# activation_104 (Activation)     (None, 9, 9, 320)    0           batch_normalization_104[0][0]
# __________________________________________________________________________________________________
# activation_105 (Activation)     (None, 5, 5, 128)    0           batch_normalization_105[0][0]
# __________________________________________________________________________________________________
# block_inception_f10 (Concatenat (None, 9, 9, 2048)   0           concatenate_9[0][0]
#                                                                  concatenate_10[0][0]
#                                                                  activation_103[0][0]
#                                                                  activation_104[0][0]
# __________________________________________________________________________________________________
# conv2d_106 (Conv2D)             (None, 1, 1, 1024)   3276800     activation_105[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 2048)         0           block_inception_f10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_106 (BatchN (None, 1, 1, 1024)   4096        conv2d_106[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 2048)         0           global_average_pooling2d[0][0]
# __________________________________________________________________________________________________
# activation_106 (Activation)     (None, 1, 1, 1024)   0           batch_normalization_106[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 7)            14336       dropout[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 1024)         0           activation_106[0][0]
# __________________________________________________________________________________________________
# main_classifier (Dense)         (None, 7)            56          dense[0][0]
# __________________________________________________________________________________________________
# auxiliary_classifier (Dense)    (None, 7)            7168        flatten[0][0]
# ==================================================================================================
# Total params: 27,415,448
# Trainable params: 27,374,232
# Non-trainable params: 41,216
# __________________________________________________________________________________________________

# %%
# 폴더 생성

os.makedirs(os.path.join(dir,'model_output',number,model.name), exist_ok=True)
os.makedirs(os.path.join(dir,'train_valid_output',number), exist_ok=True)

# %%
# 참고 : https://github.com/OverLordGoldDragon/keras-adamw

import sys
sys.path.append('/content/drive/My Drive/Colab Notebooks/Paper')
import utils
import optimizers_v2
from utils import get_weight_decays, fill_dict_in_order
from utils import reset_seeds, K_eval
from optimizers_v2 import AdamW, NadamW, SGDW

# %%
# top-5 accuracy 출력
import functools
top5_acc = functools.partial(ks.metrics.top_k_categorical_accuracy, k=5)
top5_acc.__name__ = 'top5_acc'

# %%
#optimizer = SGDW(model=model, use_cosine_annealing=False, total_iterations = len(x_train) // batch_sizes, nesterov=True, momentum=0.9)
optimizer = AdamW(model=model, use_cosine_annealing=False, total_iterations = len(x_train) // batch_sizes)
#optimizer = Adam()
filepath =  os.path.join(dir,'model_output',number,model.name,'{epoch:03d}.h5')

callbacks_list = [ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_weights_only=False, save_best_only=True, mode='min'),
                  ModelCheckpoint(filepath, monitor='val_main_classifier_accuracy', verbose=1, save_weights_only=False, save_best_only=True, mode='max'),
                  #ReduceLROnPlateau(monitor='val_loss',patience=3,factor=0.1,min_lr=1e-5),
                  LearningRateScheduler(lr_schedule,verbose=1)
                  ]

model.compile(optimizer, loss={'main_classifier' : smoothed_categorical_crossentropy, 'auxiliary_classifier' : smoothed_categorical_crossentropy},
                loss_weights={'main_classifier' : 1.0, 'auxiliary_classifier' : 0.4}, metrics=['accuracy',top5_acc,macro_f1score])

# %%
######## flow_from_directory
#history = model.fit_generator(generate_train_for_three(), steps_per_epoch=int(len(x_train)/batch_sizes),  validation_data = generate_valid_for_three(), epochs=epochs , verbose=1 , callbacks = callbacks_list,validation_steps=int(len(x_valid)/batch_sizes))
history = model.fit(generate_train_for_two(), steps_per_epoch=int(len(x_train)/batch_sizes),  validation_data = generate_valid_for_two(), epochs=epochs , verbose=1 , callbacks = callbacks_list , validation_steps=int(len(x_valid)/batch_sizes))
# Out:
# Found 28698 images belonging to 7 classes.
# Learning rate:  0.001
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 1/70
# 0.0(L1), 9.449112274039409e-05(L2) weight decay set for conv2d/kernel:0
# 0.0(L1), 9.449112274039409e-05(L2) weight decay set for conv2d_1/kernel:0
# 0.0(L1), 9.449112274039409e-05(L2) weight decay set for conv2d_2/kernel:0
# 0.0(L1), 9.449112274039409e-05(L2) weight decay set for conv2d_3/kernel:0
# 0.0(L1), 9.449112274039409e-05(L2) weight decay set for conv2d_4/kernel:0
# 0.0(L1), 9.449112274039409e-05(L2) weight decay set for conv2d_5/kernel:0
# 0.0(L1), 9.449112274039409e-05(L2) weight decay set for conv2d_6/kernel:0
# 0.0(L1), 9.449112274039409e-05(L2) weight decay set for conv2d_7/kernel:0
# 0.0(L1), 9.449112274039409e-05(L2) weight decay set for conv2d_9/kernel:0
# 0.0(L1), 9.449112274039409e-05(L2) weight decay set for conv2d_8/kernel:0
# 0.0(L1), 9.449112274039409e-05(L2) weight decay set for conv2d_10/kernel:0
# 0.0(L1), 9.449112274039409e-05(L2) weight decay set for conv2d_11/kernel:0
# 0.0(L1), 9.449112274039409e-05(L2) weight decay set for conv2d_12/kernel:0
# 0.0(L1), 9.449112274039409e-05(L2) weight decay set for conv2d_13/kernel:0
# 0.0(L1), 9.449112274039409e-05(L2) weight decay set for conv2d_14/kernel:0
# 0.0(L1), 9.449112274039409e-05(L2) weight decay set for conv2d_16/kernel:0
# 0.0(L1), 9.449112274039409e-05(L2) weight decay set for conv2d_15/kernel:0
# 0.0(L1), 9.449112274039409e-05(L2) weight decay set for conv2d_17/kernel:0
# 0.0(L1), 9.449112274039409e-05(L2) weight decay set for conv2d_18/kernel:0
# 0.0(L1), 9.449112274039409e-05(L2) weight decay set for conv2d_19/kernel:0
# 0.0(L1), 9.449112274039409e-05(L2) weight decay set for conv2d_20/kernel:0
# 0.0(L1), 9.449112274039409e-05(L2) weight decay set for conv2d_21/kernel:0
# 0.0(L1), 9.449112274039409e-05(L2) weight decay set for conv2d_23/kernel:0
# 0.0(L1), 9.449112274039409e-05(L2) weight decay set for conv2d_22/kernel:0
# 0.0(L1), 9.449112274039409e-05(L2) weight decay set for conv2d_24/kernel:0
# 0.0(L1), 9.449112274039409e-05(L2) weight decay set for conv2d_25/kernel:0
# 0.0(L1), 9.449112274039409e-05(L2) weight decay set for conv2d_26/kernel:0
# 0.0(L1), 9.449112274039409e-05(L2) weight decay set for conv2d_27/kernel:0
# 0.0(L1), 9.449112274039409e-05(L2) weight decay set for conv2d_28/kernel:0
# 0.0(L1), 9.449112274039409e-05(L2) weight decay set for conv2d_30/kernel:0
# 0.0(L1), 9.449112274039409e-05(L2) weight decay set for conv2d_29/kernel:0
# 0.0(L1), 9.449112274039409e-05(L2) weight decay set for conv2d_31/kernel:0
# 0.0(L1), 9.449112274039409e-05(L2) weight decay set for conv2d_32/kernel:0
# 0.0(L1), 9.449112274039409e-05(L2) weight decay set for conv2d_33/kernel:0
# 0.0(L1), 9.449112274039409e-05(L2) weight decay set for conv2d_34/kernel:0
# 0.0(L1), 9.449112274039409e-05(L2) weight decay set for conv2d_37/kernel:0
# 0.0(L1), 9.449112274039409e-05(L2) weight decay set for conv2d_35/kernel:0
# 0.0(L1), 9.449112274039409e-05(L2) weight decay set for conv2d_38/kernel:0
# 0.0(L1), 9.449112274039409e-05(L2) weight decay set for conv2d_36/kernel:0
# 0.0(L1), 9.449112274039409e-05(L2) weight decay set for conv2d_39/kernel:0
# 0.0(L1), 9.449112274039409e-05(L2) weight decay set for conv2d_40/kernel:0
# 0.0(L1), 9.449112274039409e-05(L2) weight decay set for conv2d_41/kernel:0
# 0.0(L1), 9.449112274039409e-05(L2) weight decay set for conv2d_42/kernel:0
# 0.0(L1), 9.449112274039409e-05(L2) weight decay set for conv2d_43/kernel:0
# 0.0(L1), 9.449112274039409e-05(L2) weight decay set for conv2d_44/kernel:0
# 0.0(L1), 9.449112274039409e-05(L2) weight decay set for conv2d_47/kernel:0
# 0.0(L1), 9.449112274039409e-05(L2) weight decay set for conv2d_45/kernel:0
# 0.0(L1), 9.449112274039409e-05(L2) weight decay set for conv2d_48/kernel:0
# 0.0(L1), 9.449112274039409e-05(L2) weight decay set for conv2d_46/kernel:0
# 0.0(L1), 9.449112274039409e-05(L2) weight decay set for conv2d_49/kernel:0
# 0.0(L1), 9.449112274039409e-05(L2) weight decay set for conv2d_50/kernel:0
# 0.0(L1), 9.449112274039409e-05(L2) weight decay set for conv2d_51/kernel:0
# 0.0(L1), 9.449112274039409e-05(L2) weight decay set for conv2d_52/kernel:0
# 0.0(L1), 9.449112274039409e-05(L2) weight decay set for conv2d_53/kernel:0
# 0.0(L1), 9.449112274039409e-05(L2) weight decay set for conv2d_54/kernel:0
# 0.0(L1), 9.449112274039409e-05(L2) weight decay set for conv2d_57/kernel:0
# 0.0(L1), 9.449112274039409e-05(L2) weight decay set for conv2d_55/kernel:0
# 0.0(L1), 9.449112274039409e-05(L2) weight decay set for conv2d_58/kernel:0
# 0.0(L1), 9.449112274039409e-05(L2) weight decay set for conv2d_56/kernel:0
# 0.0(L1), 9.449112274039409e-05(L2) weight decay set for conv2d_59/kernel:0
# 0.0(L1), 9.449112274039409e-05(L2) weight decay set for conv2d_60/kernel:0
# 0.0(L1), 9.449112274039409e-05(L2) weight decay set for conv2d_61/kernel:0
# 0.0(L1), 9.449112274039409e-05(L2) weight decay set for conv2d_62/kernel:0
# 0.0(L1), 9.449112274039409e-05(L2) weight decay set for conv2d_63/kernel:0
# 0.0(L1), 9.449112274039409e-05(L2) weight decay set for conv2d_64/kernel:0
# 0.0(L1), 9.449112274039409e-05(L2) weight decay set for conv2d_67/kernel:0
# 0.0(L1), 9.449112274039409e-05(L2) weight decay set for conv2d_65/kernel:0
# 0.0(L1), 9.449112274039409e-05(L2) weight decay set for conv2d_68/kernel:0
# 0.0(L1), 9.449112274039409e-05(L2) weight decay set for conv2d_66/kernel:0
# 0.0(L1), 9.449112274039409e-05(L2) weight decay set for conv2d_69/kernel:0
# 0.0(L1), 9.449112274039409e-05(L2) weight decay set for conv2d_70/kernel:0
# 0.0(L1), 9.449112274039409e-05(L2) weight decay set for conv2d_71/kernel:0
# 0.0(L1), 9.449112274039409e-05(L2) weight decay set for conv2d_72/kernel:0
# 0.0(L1), 9.449112274039409e-05(L2) weight decay set for conv2d_73/kernel:0
# 0.0(L1), 9.449112274039409e-05(L2) weight decay set for conv2d_74/kernel:0
# 0.0(L1), 9.449112274039409e-05(L2) weight decay set for conv2d_77/kernel:0
# 0.0(L1), 9.449112274039409e-05(L2) weight decay set for conv2d_75/kernel:0
# 0.0(L1), 9.449112274039409e-05(L2) weight decay set for conv2d_78/kernel:0
# 0.0(L1), 9.449112274039409e-05(L2) weight decay set for conv2d_76/kernel:0
# 0.0(L1), 9.449112274039409e-05(L2) weight decay set for conv2d_79/kernel:0
# 0.0(L1), 9.449112274039409e-05(L2) weight decay set for conv2d_80/kernel:0
# 0.0(L1), 9.449112274039409e-05(L2) weight decay set for conv2d_81/kernel:0
# 0.0(L1), 9.449112274039409e-05(L2) weight decay set for conv2d_82/kernel:0
# 0.0(L1), 9.449112274039409e-05(L2) weight decay set for conv2d_83/kernel:0
# 0.0(L1), 9.449112274039409e-05(L2) weight decay set for conv2d_85/kernel:0
# 0.0(L1), 9.449112274039409e-05(L2) weight decay set for conv2d_84/kernel:0
# 0.0(L1), 9.449112274039409e-05(L2) weight decay set for conv2d_86/kernel:0
# 0.0(L1), 9.449112274039409e-05(L2) weight decay set for conv2d_87/kernel:0
# 0.0(L1), 9.449112274039409e-05(L2) weight decay set for conv2d_88/kernel:0
# 0.0(L1), 9.449112274039409e-05(L2) weight decay set for conv2d_91/kernel:0
# 0.0(L1), 9.449112274039409e-05(L2) weight decay set for conv2d_89/kernel:0
# 0.0(L1), 9.449112274039409e-05(L2) weight decay set for conv2d_90/kernel:0
# 0.0(L1), 9.449112274039409e-05(L2) weight decay set for conv2d_92/kernel:0
# 0.0(L1), 9.449112274039409e-05(L2) weight decay set for conv2d_93/kernel:0
# 0.0(L1), 9.449112274039409e-05(L2) weight decay set for conv2d_94/kernel:0
# 0.0(L1), 9.449112274039409e-05(L2) weight decay set for conv2d_95/kernel:0
# 0.0(L1), 9.449112274039409e-05(L2) weight decay set for conv2d_96/kernel:0
# 0.0(L1), 9.449112274039409e-05(L2) weight decay set for conv2d_97/kernel:0
# 0.0(L1), 9.449112274039409e-05(L2) weight decay set for conv2d_100/kernel:0
# 0.0(L1), 9.449112274039409e-05(L2) weight decay set for conv2d_98/kernel:0
# 0.0(L1), 9.449112274039409e-05(L2) weight decay set for conv2d_99/kernel:0
# 0.0(L1), 9.449112274039409e-05(L2) weight decay set for conv2d_101/kernel:0
# 0.0(L1), 9.449112274039409e-05(L2) weight decay set for conv2d_102/kernel:0
# 0.0(L1), 9.449112274039409e-05(L2) weight decay set for conv2d_103/kernel:0
# 0.0(L1), 9.449112274039409e-05(L2) weight decay set for conv2d_104/kernel:0
# 0.0(L1), 9.449112274039409e-05(L2) weight decay set for conv2d_105/kernel:0
# 0.0(L1), 9.449112274039409e-05(L2) weight decay set for conv2d_106/kernel:0
# 0.0(L1), 9.449112274039409e-05(L2) weight decay set for dense/kernel:0
# 0.0(L1), 9.449112274039409e-05(L2) weight decay set for auxiliary_classifier/kernel:0
# 448/448 [==============================] - ETA: 0s - loss: 2.4701 - main_classifier_loss: 1.7689 - auxiliary_classifier_loss: 1.7528 - main_classifier_accuracy: 0.3169 - main_classifier_top5_acc: 0.9062 - main_classifier_macro_f1score: 0.0641 - auxiliary_classifier_accuracy: 0.3349 - auxiliary_classifier_top5_acc: 0.9193 - auxiliary_classifier_macro_f1score: 0.0766 Found 3589 images belonging to 7 classes.
#
# Epoch 00001: val_loss improved from inf to 2.48074, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/Inception_v3/001.h5
#
# Epoch 00001: val_main_classifier_accuracy improved from -inf to 0.35128, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/Inception_v3/001.h5
# 448/448 [==============================] - 22949s 51s/step - loss: 2.4701 - main_classifier_loss: 1.7689 - auxiliary_classifier_loss: 1.7528 - main_classifier_accuracy: 0.3169 - main_classifier_top5_acc: 0.9062 - main_classifier_macro_f1score: 0.0641 - auxiliary_classifier_accuracy: 0.3349 - auxiliary_classifier_top5_acc: 0.9193 - auxiliary_classifier_macro_f1score: 0.0766 - val_loss: 2.4807 - val_main_classifier_loss: 1.7878 - val_auxiliary_classifier_loss: 1.7322 - val_main_classifier_accuracy: 0.3513 - val_main_classifier_top5_acc: 0.9339 - val_main_classifier_macro_f1score: 0.1769 - val_auxiliary_classifier_accuracy: 0.3650 - val_auxiliary_classifier_top5_acc: 0.9202 - val_auxiliary_classifier_macro_f1score: 0.1966
# Learning rate:  0.001
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 2/70
# 448/448 [==============================] - ETA: 0s - loss: 2.0738 - main_classifier_loss: 1.4825 - auxiliary_classifier_loss: 1.4784 - main_classifier_accuracy: 0.4823 - main_classifier_top5_acc: 0.9630 - main_classifier_macro_f1score: 0.2141 - auxiliary_classifier_accuracy: 0.4854 - auxiliary_classifier_top5_acc: 0.9639 - auxiliary_classifier_macro_f1score: 0.2225
# Epoch 00002: val_loss did not improve from 2.48074
#
# Epoch 00002: val_main_classifier_accuracy improved from 0.35128 to 0.36858, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/Inception_v3/002.h5
# 448/448 [==============================] - 657s 1s/step - loss: 2.0738 - main_classifier_loss: 1.4825 - auxiliary_classifier_loss: 1.4784 - main_classifier_accuracy: 0.4823 - main_classifier_top5_acc: 0.9630 - main_classifier_macro_f1score: 0.2141 - auxiliary_classifier_accuracy: 0.4854 - auxiliary_classifier_top5_acc: 0.9639 - auxiliary_classifier_macro_f1score: 0.2225 - val_loss: 2.5143 - val_main_classifier_loss: 1.7792 - val_auxiliary_classifier_loss: 1.8377 - val_main_classifier_accuracy: 0.3686 - val_main_classifier_top5_acc: 0.8903 - val_main_classifier_macro_f1score: 0.1556 - val_auxiliary_classifier_accuracy: 0.3398 - val_auxiliary_classifier_top5_acc: 0.9194 - val_auxiliary_classifier_macro_f1score: 0.1461
# Learning rate:  0.001
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 3/70
# 448/448 [==============================] - ETA: 0s - loss: 1.9361 - main_classifier_loss: 1.3834 - auxiliary_classifier_loss: 1.3819 - main_classifier_accuracy: 0.5374 - main_classifier_top5_acc: 0.9732 - main_classifier_macro_f1score: 0.2814 - auxiliary_classifier_accuracy: 0.5391 - auxiliary_classifier_top5_acc: 0.9742 - auxiliary_classifier_macro_f1score: 0.2873
# Epoch 00003: val_loss did not improve from 2.48074
#
# Epoch 00003: val_main_classifier_accuracy improved from 0.36858 to 0.45647, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/Inception_v3/003.h5
# 448/448 [==============================] - 641s 1s/step - loss: 1.9361 - main_classifier_loss: 1.3834 - auxiliary_classifier_loss: 1.3819 - main_classifier_accuracy: 0.5374 - main_classifier_top5_acc: 0.9732 - main_classifier_macro_f1score: 0.2814 - auxiliary_classifier_accuracy: 0.5391 - auxiliary_classifier_top5_acc: 0.9742 - auxiliary_classifier_macro_f1score: 0.2873 - val_loss: 2.5817 - val_main_classifier_loss: 1.7456 - val_auxiliary_classifier_loss: 2.0904 - val_main_classifier_accuracy: 0.4565 - val_main_classifier_top5_acc: 0.9554 - val_main_classifier_macro_f1score: 0.2178 - val_auxiliary_classifier_accuracy: 0.4671 - val_auxiliary_classifier_top5_acc: 0.9665 - val_auxiliary_classifier_macro_f1score: 0.2271
# Learning rate:  0.001
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 4/70
# 448/448 [==============================] - ETA: 0s - loss: 1.8671 - main_classifier_loss: 1.3346 - auxiliary_classifier_loss: 1.3311 - main_classifier_accuracy: 0.5619 - main_classifier_top5_acc: 0.9774 - main_classifier_macro_f1score: 0.3213 - auxiliary_classifier_accuracy: 0.5650 - auxiliary_classifier_top5_acc: 0.9780 - auxiliary_classifier_macro_f1score: 0.3285
# Epoch 00004: val_loss did not improve from 2.48074
#
# Epoch 00004: val_main_classifier_accuracy did not improve from 0.45647
# 448/448 [==============================] - 626s 1s/step - loss: 1.8671 - main_classifier_loss: 1.3346 - auxiliary_classifier_loss: 1.3311 - main_classifier_accuracy: 0.5619 - main_classifier_top5_acc: 0.9774 - main_classifier_macro_f1score: 0.3213 - auxiliary_classifier_accuracy: 0.5650 - auxiliary_classifier_top5_acc: 0.9780 - auxiliary_classifier_macro_f1score: 0.3285 - val_loss: 10.8277 - val_main_classifier_loss: 2.9555 - val_auxiliary_classifier_loss: 19.6806 - val_main_classifier_accuracy: 0.3569 - val_main_classifier_top5_acc: 0.8223 - val_main_classifier_macro_f1score: 0.1307 - val_auxiliary_classifier_accuracy: 0.2059 - val_auxiliary_classifier_top5_acc: 0.8429 - val_auxiliary_classifier_macro_f1score: 0.0914
# Learning rate:  0.001
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 5/70
# 448/448 [==============================] - ETA: 0s - loss: 1.8223 - main_classifier_loss: 1.3008 - auxiliary_classifier_loss: 1.3037 - main_classifier_accuracy: 0.5792 - main_classifier_top5_acc: 0.9795 - main_classifier_macro_f1score: 0.3509 - auxiliary_classifier_accuracy: 0.5808 - auxiliary_classifier_top5_acc: 0.9801 - auxiliary_classifier_macro_f1score: 0.3575
# Epoch 00005: val_loss improved from 2.48074 to 1.99891, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/Inception_v3/005.h5
#
# Epoch 00005: val_main_classifier_accuracy improved from 0.45647 to 0.52316, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/Inception_v3/005.h5
# 448/448 [==============================] - 626s 1s/step - loss: 1.8223 - main_classifier_loss: 1.3008 - auxiliary_classifier_loss: 1.3037 - main_classifier_accuracy: 0.5792 - main_classifier_top5_acc: 0.9795 - main_classifier_macro_f1score: 0.3509 - auxiliary_classifier_accuracy: 0.5808 - auxiliary_classifier_top5_acc: 0.9801 - auxiliary_classifier_macro_f1score: 0.3575 - val_loss: 1.9989 - val_main_classifier_loss: 1.4316 - val_auxiliary_classifier_loss: 1.4184 - val_main_classifier_accuracy: 0.5232 - val_main_classifier_top5_acc: 0.9634 - val_main_classifier_macro_f1score: 0.3290 - val_auxiliary_classifier_accuracy: 0.5204 - val_auxiliary_classifier_top5_acc: 0.9668 - val_auxiliary_classifier_macro_f1score: 0.3251
# Learning rate:  0.001
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 6/70
# 448/448 [==============================] - ETA: 0s - loss: 1.7770 - main_classifier_loss: 1.2699 - auxiliary_classifier_loss: 1.2679 - main_classifier_accuracy: 0.5953 - main_classifier_top5_acc: 0.9833 - main_classifier_macro_f1score: 0.3788 - auxiliary_classifier_accuracy: 0.5979 - auxiliary_classifier_top5_acc: 0.9823 - auxiliary_classifier_macro_f1score: 0.3846
# Epoch 00006: val_loss improved from 1.99891 to 1.94843, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/Inception_v3/006.h5
#
# Epoch 00006: val_main_classifier_accuracy improved from 0.52316 to 0.52846, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/Inception_v3/006.h5
# 448/448 [==============================] - 622s 1s/step - loss: 1.7770 - main_classifier_loss: 1.2699 - auxiliary_classifier_loss: 1.2679 - main_classifier_accuracy: 0.5953 - main_classifier_top5_acc: 0.9833 - main_classifier_macro_f1score: 0.3788 - auxiliary_classifier_accuracy: 0.5979 - auxiliary_classifier_top5_acc: 0.9823 - auxiliary_classifier_macro_f1score: 0.3846 - val_loss: 1.9484 - val_main_classifier_loss: 1.3890 - val_auxiliary_classifier_loss: 1.3985 - val_main_classifier_accuracy: 0.5285 - val_main_classifier_top5_acc: 0.9732 - val_main_classifier_macro_f1score: 0.3057 - val_auxiliary_classifier_accuracy: 0.5215 - val_auxiliary_classifier_top5_acc: 0.9741 - val_auxiliary_classifier_macro_f1score: 0.3107
# Learning rate:  0.001
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 7/70
# 448/448 [==============================] - ETA: 0s - loss: 1.7482 - main_classifier_loss: 1.2482 - auxiliary_classifier_loss: 1.2500 - main_classifier_accuracy: 0.6076 - main_classifier_top5_acc: 0.9828 - main_classifier_macro_f1score: 0.3988 - auxiliary_classifier_accuracy: 0.6094 - auxiliary_classifier_top5_acc: 0.9820 - auxiliary_classifier_macro_f1score: 0.4038
# Epoch 00007: val_loss improved from 1.94843 to 1.93576, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/Inception_v3/007.h5
#
# Epoch 00007: val_main_classifier_accuracy improved from 0.52846 to 0.55831, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/Inception_v3/007.h5
# 448/448 [==============================] - 636s 1s/step - loss: 1.7482 - main_classifier_loss: 1.2482 - auxiliary_classifier_loss: 1.2500 - main_classifier_accuracy: 0.6076 - main_classifier_top5_acc: 0.9828 - main_classifier_macro_f1score: 0.3988 - auxiliary_classifier_accuracy: 0.6094 - auxiliary_classifier_top5_acc: 0.9820 - auxiliary_classifier_macro_f1score: 0.4038 - val_loss: 1.9358 - val_main_classifier_loss: 1.3571 - val_auxiliary_classifier_loss: 1.4468 - val_main_classifier_accuracy: 0.5583 - val_main_classifier_top5_acc: 0.9807 - val_main_classifier_macro_f1score: 0.3402 - val_auxiliary_classifier_accuracy: 0.5605 - val_auxiliary_classifier_top5_acc: 0.9821 - val_auxiliary_classifier_macro_f1score: 0.3502
# Learning rate:  0.001
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 8/70
# 448/448 [==============================] - ETA: 0s - loss: 1.7289 - main_classifier_loss: 1.2344 - auxiliary_classifier_loss: 1.2363 - main_classifier_accuracy: 0.6164 - main_classifier_top5_acc: 0.9844 - main_classifier_macro_f1score: 0.4111 - auxiliary_classifier_accuracy: 0.6151 - auxiliary_classifier_top5_acc: 0.9843 - auxiliary_classifier_macro_f1score: 0.4180
# Epoch 00008: val_loss improved from 1.93576 to 1.83966, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/Inception_v3/008.h5
#
# Epoch 00008: val_main_classifier_accuracy improved from 0.55831 to 0.58733, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/Inception_v3/008.h5
# 448/448 [==============================] - 665s 1s/step - loss: 1.7289 - main_classifier_loss: 1.2344 - auxiliary_classifier_loss: 1.2363 - main_classifier_accuracy: 0.6164 - main_classifier_top5_acc: 0.9844 - main_classifier_macro_f1score: 0.4111 - auxiliary_classifier_accuracy: 0.6151 - auxiliary_classifier_top5_acc: 0.9843 - auxiliary_classifier_macro_f1score: 0.4180 - val_loss: 1.8397 - val_main_classifier_loss: 1.2969 - val_auxiliary_classifier_loss: 1.3569 - val_main_classifier_accuracy: 0.5873 - val_main_classifier_top5_acc: 0.9830 - val_main_classifier_macro_f1score: 0.3770 - val_auxiliary_classifier_accuracy: 0.5776 - val_auxiliary_classifier_top5_acc: 0.9810 - val_auxiliary_classifier_macro_f1score: 0.3730
# Learning rate:  0.001
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 9/70
# 448/448 [==============================] - ETA: 0s - loss: 1.7041 - main_classifier_loss: 1.2161 - auxiliary_classifier_loss: 1.2201 - main_classifier_accuracy: 0.6237 - main_classifier_top5_acc: 0.9852 - main_classifier_macro_f1score: 0.4268 - auxiliary_classifier_accuracy: 0.6238 - auxiliary_classifier_top5_acc: 0.9851 - auxiliary_classifier_macro_f1score: 0.4318
# Epoch 00009: val_loss improved from 1.83966 to 1.81897, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/Inception_v3/009.h5
#
# Epoch 00009: val_main_classifier_accuracy did not improve from 0.58733
# 448/448 [==============================] - 662s 1s/step - loss: 1.7041 - main_classifier_loss: 1.2161 - auxiliary_classifier_loss: 1.2201 - main_classifier_accuracy: 0.6237 - main_classifier_top5_acc: 0.9852 - main_classifier_macro_f1score: 0.4268 - auxiliary_classifier_accuracy: 0.6238 - auxiliary_classifier_top5_acc: 0.9851 - auxiliary_classifier_macro_f1score: 0.4318 - val_loss: 1.8190 - val_main_classifier_loss: 1.3024 - val_auxiliary_classifier_loss: 1.2914 - val_main_classifier_accuracy: 0.5681 - val_main_classifier_top5_acc: 0.9835 - val_main_classifier_macro_f1score: 0.3923 - val_auxiliary_classifier_accuracy: 0.5745 - val_auxiliary_classifier_top5_acc: 0.9841 - val_auxiliary_classifier_macro_f1score: 0.3810
# Learning rate:  0.001
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 10/70
# 448/448 [==============================] - ETA: 0s - loss: 1.6861 - main_classifier_loss: 1.2041 - auxiliary_classifier_loss: 1.2049 - main_classifier_accuracy: 0.6320 - main_classifier_top5_acc: 0.9866 - main_classifier_macro_f1score: 0.4390 - auxiliary_classifier_accuracy: 0.6339 - auxiliary_classifier_top5_acc: 0.9869 - auxiliary_classifier_macro_f1score: 0.4438
# Epoch 00010: val_loss improved from 1.81897 to 1.79738, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/Inception_v3/010.h5
#
# Epoch 00010: val_main_classifier_accuracy did not improve from 0.58733
# 448/448 [==============================] - 664s 1s/step - loss: 1.6861 - main_classifier_loss: 1.2041 - auxiliary_classifier_loss: 1.2049 - main_classifier_accuracy: 0.6320 - main_classifier_top5_acc: 0.9866 - main_classifier_macro_f1score: 0.4390 - auxiliary_classifier_accuracy: 0.6339 - auxiliary_classifier_top5_acc: 0.9869 - auxiliary_classifier_macro_f1score: 0.4438 - val_loss: 1.7974 - val_main_classifier_loss: 1.2823 - val_auxiliary_classifier_loss: 1.2877 - val_main_classifier_accuracy: 0.5806 - val_main_classifier_top5_acc: 0.9841 - val_main_classifier_macro_f1score: 0.3696 - val_auxiliary_classifier_accuracy: 0.5778 - val_auxiliary_classifier_top5_acc: 0.9835 - val_auxiliary_classifier_macro_f1score: 0.3787
# Learning rate:  0.001
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 11/70
# 448/448 [==============================] - ETA: 0s - loss: 1.6716 - main_classifier_loss: 1.1910 - auxiliary_classifier_loss: 1.2015 - main_classifier_accuracy: 0.6373 - main_classifier_top5_acc: 0.9868 - main_classifier_macro_f1score: 0.4471 - auxiliary_classifier_accuracy: 0.6339 - auxiliary_classifier_top5_acc: 0.9869 - auxiliary_classifier_macro_f1score: 0.4532
# Epoch 00011: val_loss did not improve from 1.79738
#
# Epoch 00011: val_main_classifier_accuracy did not improve from 0.58733
# 448/448 [==============================] - 646s 1s/step - loss: 1.6716 - main_classifier_loss: 1.1910 - auxiliary_classifier_loss: 1.2015 - main_classifier_accuracy: 0.6373 - main_classifier_top5_acc: 0.9868 - main_classifier_macro_f1score: 0.4471 - auxiliary_classifier_accuracy: 0.6339 - auxiliary_classifier_top5_acc: 0.9869 - auxiliary_classifier_macro_f1score: 0.4532 - val_loss: 1.8499 - val_main_classifier_loss: 1.3208 - val_auxiliary_classifier_loss: 1.3228 - val_main_classifier_accuracy: 0.5675 - val_main_classifier_top5_acc: 0.9813 - val_main_classifier_macro_f1score: 0.3678 - val_auxiliary_classifier_accuracy: 0.5717 - val_auxiliary_classifier_top5_acc: 0.9835 - val_auxiliary_classifier_macro_f1score: 0.3753
# Learning rate:  0.001
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 12/70
# 448/448 [==============================] - ETA: 0s - loss: 1.6505 - main_classifier_loss: 1.1785 - auxiliary_classifier_loss: 1.1800 - main_classifier_accuracy: 0.6446 - main_classifier_top5_acc: 0.9875 - main_classifier_macro_f1score: 0.4632 - auxiliary_classifier_accuracy: 0.6427 - auxiliary_classifier_top5_acc: 0.9872 - auxiliary_classifier_macro_f1score: 0.4702
# Epoch 00012: val_loss did not improve from 1.79738
#
# Epoch 00012: val_main_classifier_accuracy improved from 0.58733 to 0.59933, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/Inception_v3/012.h5
# 448/448 [==============================] - 638s 1s/step - loss: 1.6505 - main_classifier_loss: 1.1785 - auxiliary_classifier_loss: 1.1800 - main_classifier_accuracy: 0.6446 - main_classifier_top5_acc: 0.9875 - main_classifier_macro_f1score: 0.4632 - auxiliary_classifier_accuracy: 0.6427 - auxiliary_classifier_top5_acc: 0.9872 - auxiliary_classifier_macro_f1score: 0.4702 - val_loss: 1.9964 - val_main_classifier_loss: 1.3338 - val_auxiliary_classifier_loss: 1.6567 - val_main_classifier_accuracy: 0.5993 - val_main_classifier_top5_acc: 0.9794 - val_main_classifier_macro_f1score: 0.3827 - val_auxiliary_classifier_accuracy: 0.5932 - val_auxiliary_classifier_top5_acc: 0.9766 - val_auxiliary_classifier_macro_f1score: 0.3853
# Learning rate:  0.001
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 13/70
# 448/448 [==============================] - ETA: 0s - loss: 1.6362 - main_classifier_loss: 1.1681 - auxiliary_classifier_loss: 1.1704 - main_classifier_accuracy: 0.6489 - main_classifier_top5_acc: 0.9880 - main_classifier_macro_f1score: 0.4733 - auxiliary_classifier_accuracy: 0.6481 - auxiliary_classifier_top5_acc: 0.9884 - auxiliary_classifier_macro_f1score: 0.4779
# Epoch 00013: val_loss improved from 1.79738 to 1.73789, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/Inception_v3/013.h5
#
# Epoch 00013: val_main_classifier_accuracy improved from 0.59933 to 0.61551, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/Inception_v3/013.h5
# 448/448 [==============================] - 656s 1s/step - loss: 1.6362 - main_classifier_loss: 1.1681 - auxiliary_classifier_loss: 1.1704 - main_classifier_accuracy: 0.6489 - main_classifier_top5_acc: 0.9880 - main_classifier_macro_f1score: 0.4733 - auxiliary_classifier_accuracy: 0.6481 - auxiliary_classifier_top5_acc: 0.9884 - auxiliary_classifier_macro_f1score: 0.4779 - val_loss: 1.7379 - val_main_classifier_loss: 1.2403 - val_auxiliary_classifier_loss: 1.2439 - val_main_classifier_accuracy: 0.6155 - val_main_classifier_top5_acc: 0.9838 - val_main_classifier_macro_f1score: 0.4034 - val_auxiliary_classifier_accuracy: 0.6222 - val_auxiliary_classifier_top5_acc: 0.9830 - val_auxiliary_classifier_macro_f1score: 0.4169
# Learning rate:  0.001
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 14/70
# 448/448 [==============================] - ETA: 0s - loss: 1.6064 - main_classifier_loss: 1.1474 - auxiliary_classifier_loss: 1.1474 - main_classifier_accuracy: 0.6615 - main_classifier_top5_acc: 0.9891 - main_classifier_macro_f1score: 0.4897 - auxiliary_classifier_accuracy: 0.6594 - auxiliary_classifier_top5_acc: 0.9886 - auxiliary_classifier_macro_f1score: 0.4951
# Epoch 00014: val_loss improved from 1.73789 to 1.71907, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/Inception_v3/014.h5
#
# Epoch 00014: val_main_classifier_accuracy improved from 0.61551 to 0.63002, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/Inception_v3/014.h5
# 448/448 [==============================] - 664s 1s/step - loss: 1.6064 - main_classifier_loss: 1.1474 - auxiliary_classifier_loss: 1.1474 - main_classifier_accuracy: 0.6615 - main_classifier_top5_acc: 0.9891 - main_classifier_macro_f1score: 0.4897 - auxiliary_classifier_accuracy: 0.6594 - auxiliary_classifier_top5_acc: 0.9886 - auxiliary_classifier_macro_f1score: 0.4951 - val_loss: 1.7191 - val_main_classifier_loss: 1.2179 - val_auxiliary_classifier_loss: 1.2529 - val_main_classifier_accuracy: 0.6300 - val_main_classifier_top5_acc: 0.9855 - val_main_classifier_macro_f1score: 0.4590 - val_auxiliary_classifier_accuracy: 0.6164 - val_auxiliary_classifier_top5_acc: 0.9849 - val_auxiliary_classifier_macro_f1score: 0.4570
# Learning rate:  0.001
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 15/70
# 448/448 [==============================] - ETA: 0s - loss: 1.6012 - main_classifier_loss: 1.1434 - auxiliary_classifier_loss: 1.1446 - main_classifier_accuracy: 0.6638 - main_classifier_top5_acc: 0.9890 - main_classifier_macro_f1score: 0.4980 - auxiliary_classifier_accuracy: 0.6629 - auxiliary_classifier_top5_acc: 0.9891 - auxiliary_classifier_macro_f1score: 0.5029
# Epoch 00015: val_loss did not improve from 1.71907
#
# Epoch 00015: val_main_classifier_accuracy did not improve from 0.63002
# 448/448 [==============================] - 645s 1s/step - loss: 1.6012 - main_classifier_loss: 1.1434 - auxiliary_classifier_loss: 1.1446 - main_classifier_accuracy: 0.6638 - main_classifier_top5_acc: 0.9890 - main_classifier_macro_f1score: 0.4980 - auxiliary_classifier_accuracy: 0.6629 - auxiliary_classifier_top5_acc: 0.9891 - auxiliary_classifier_macro_f1score: 0.5029 - val_loss: 1.7510 - val_main_classifier_loss: 1.2467 - val_auxiliary_classifier_loss: 1.2608 - val_main_classifier_accuracy: 0.6016 - val_main_classifier_top5_acc: 0.9858 - val_main_classifier_macro_f1score: 0.4041 - val_auxiliary_classifier_accuracy: 0.5926 - val_auxiliary_classifier_top5_acc: 0.9838 - val_auxiliary_classifier_macro_f1score: 0.3991
# Learning rate:  0.001
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 16/70
# 448/448 [==============================] - ETA: 0s - loss: 1.5816 - main_classifier_loss: 1.1288 - auxiliary_classifier_loss: 1.1322 - main_classifier_accuracy: 0.6715 - main_classifier_top5_acc: 0.9896 - main_classifier_macro_f1score: 0.5095 - auxiliary_classifier_accuracy: 0.6712 - auxiliary_classifier_top5_acc: 0.9891 - auxiliary_classifier_macro_f1score: 0.5127
# Epoch 00016: val_loss improved from 1.71907 to 1.71885, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/Inception_v3/016.h5
#
# Epoch 00016: val_main_classifier_accuracy did not improve from 0.63002
# 448/448 [==============================] - 632s 1s/step - loss: 1.5816 - main_classifier_loss: 1.1288 - auxiliary_classifier_loss: 1.1322 - main_classifier_accuracy: 0.6715 - main_classifier_top5_acc: 0.9896 - main_classifier_macro_f1score: 0.5095 - auxiliary_classifier_accuracy: 0.6712 - auxiliary_classifier_top5_acc: 0.9891 - auxiliary_classifier_macro_f1score: 0.5127 - val_loss: 1.7189 - val_main_classifier_loss: 1.2267 - val_auxiliary_classifier_loss: 1.2303 - val_main_classifier_accuracy: 0.6244 - val_main_classifier_top5_acc: 0.9855 - val_main_classifier_macro_f1score: 0.4320 - val_auxiliary_classifier_accuracy: 0.6194 - val_auxiliary_classifier_top5_acc: 0.9866 - val_auxiliary_classifier_macro_f1score: 0.4420
# Learning rate:  0.001
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 17/70
# 448/448 [==============================] - ETA: 0s - loss: 1.5611 - main_classifier_loss: 1.1143 - auxiliary_classifier_loss: 1.1169 - main_classifier_accuracy: 0.6761 - main_classifier_top5_acc: 0.9911 - main_classifier_macro_f1score: 0.5216 - auxiliary_classifier_accuracy: 0.6760 - auxiliary_classifier_top5_acc: 0.9917 - auxiliary_classifier_macro_f1score: 0.5261
# Epoch 00017: val_loss did not improve from 1.71885
#
# Epoch 00017: val_main_classifier_accuracy did not improve from 0.63002
# 448/448 [==============================] - 630s 1s/step - loss: 1.5611 - main_classifier_loss: 1.1143 - auxiliary_classifier_loss: 1.1169 - main_classifier_accuracy: 0.6761 - main_classifier_top5_acc: 0.9911 - main_classifier_macro_f1score: 0.5216 - auxiliary_classifier_accuracy: 0.6760 - auxiliary_classifier_top5_acc: 0.9917 - auxiliary_classifier_macro_f1score: 0.5261 - val_loss: 1.8086 - val_main_classifier_loss: 1.2852 - val_auxiliary_classifier_loss: 1.3087 - val_main_classifier_accuracy: 0.5929 - val_main_classifier_top5_acc: 0.9830 - val_main_classifier_macro_f1score: 0.4083 - val_auxiliary_classifier_accuracy: 0.5845 - val_auxiliary_classifier_top5_acc: 0.9813 - val_auxiliary_classifier_macro_f1score: 0.3993
# Learning rate:  0.001
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 18/70
# 448/448 [==============================] - ETA: 0s - loss: 1.5457 - main_classifier_loss: 1.1034 - auxiliary_classifier_loss: 1.1057 - main_classifier_accuracy: 0.6856 - main_classifier_top5_acc: 0.9904 - main_classifier_macro_f1score: 0.5335 - auxiliary_classifier_accuracy: 0.6857 - auxiliary_classifier_top5_acc: 0.9908 - auxiliary_classifier_macro_f1score: 0.5351
# Epoch 00018: val_loss did not improve from 1.71885
#
# Epoch 00018: val_main_classifier_accuracy did not improve from 0.63002
# 448/448 [==============================] - 632s 1s/step - loss: 1.5457 - main_classifier_loss: 1.1034 - auxiliary_classifier_loss: 1.1057 - main_classifier_accuracy: 0.6856 - main_classifier_top5_acc: 0.9904 - main_classifier_macro_f1score: 0.5335 - auxiliary_classifier_accuracy: 0.6857 - auxiliary_classifier_top5_acc: 0.9908 - auxiliary_classifier_macro_f1score: 0.5351 - val_loss: 1.7655 - val_main_classifier_loss: 1.2607 - val_auxiliary_classifier_loss: 1.2620 - val_main_classifier_accuracy: 0.6032 - val_main_classifier_top5_acc: 0.9816 - val_main_classifier_macro_f1score: 0.4289 - val_auxiliary_classifier_accuracy: 0.6032 - val_auxiliary_classifier_top5_acc: 0.9819 - val_auxiliary_classifier_macro_f1score: 0.4401
# Learning rate:  0.001
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 19/70
# 448/448 [==============================] - ETA: 0s - loss: 1.5238 - main_classifier_loss: 1.0878 - auxiliary_classifier_loss: 1.0899 - main_classifier_accuracy: 0.6928 - main_classifier_top5_acc: 0.9913 - main_classifier_macro_f1score: 0.5498 - auxiliary_classifier_accuracy: 0.6911 - auxiliary_classifier_top5_acc: 0.9911 - auxiliary_classifier_macro_f1score: 0.5516
# Epoch 00019: val_loss did not improve from 1.71885
#
# Epoch 00019: val_main_classifier_accuracy did not improve from 0.63002
# 448/448 [==============================] - 628s 1s/step - loss: 1.5238 - main_classifier_loss: 1.0878 - auxiliary_classifier_loss: 1.0899 - main_classifier_accuracy: 0.6928 - main_classifier_top5_acc: 0.9913 - main_classifier_macro_f1score: 0.5498 - auxiliary_classifier_accuracy: 0.6911 - auxiliary_classifier_top5_acc: 0.9911 - auxiliary_classifier_macro_f1score: 0.5516 - val_loss: 1.7202 - val_main_classifier_loss: 1.2215 - val_auxiliary_classifier_loss: 1.2467 - val_main_classifier_accuracy: 0.6164 - val_main_classifier_top5_acc: 0.9866 - val_main_classifier_macro_f1score: 0.4369 - val_auxiliary_classifier_accuracy: 0.6091 - val_auxiliary_classifier_top5_acc: 0.9860 - val_auxiliary_classifier_macro_f1score: 0.4359
# Learning rate:  0.001
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 20/70
# 448/448 [==============================] - ETA: 0s - loss: 1.5142 - main_classifier_loss: 1.0816 - auxiliary_classifier_loss: 1.0814 - main_classifier_accuracy: 0.6946 - main_classifier_top5_acc: 0.9917 - main_classifier_macro_f1score: 0.5516 - auxiliary_classifier_accuracy: 0.6949 - auxiliary_classifier_top5_acc: 0.9920 - auxiliary_classifier_macro_f1score: 0.5553
# Epoch 00020: val_loss improved from 1.71885 to 1.68326, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/Inception_v3/020.h5
#
# Epoch 00020: val_main_classifier_accuracy improved from 0.63002 to 0.63281, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/Inception_v3/020.h5
# 448/448 [==============================] - 635s 1s/step - loss: 1.5142 - main_classifier_loss: 1.0816 - auxiliary_classifier_loss: 1.0814 - main_classifier_accuracy: 0.6946 - main_classifier_top5_acc: 0.9917 - main_classifier_macro_f1score: 0.5516 - auxiliary_classifier_accuracy: 0.6949 - auxiliary_classifier_top5_acc: 0.9920 - auxiliary_classifier_macro_f1score: 0.5553 - val_loss: 1.6833 - val_main_classifier_loss: 1.1979 - val_auxiliary_classifier_loss: 1.2134 - val_main_classifier_accuracy: 0.6328 - val_main_classifier_top5_acc: 0.9860 - val_main_classifier_macro_f1score: 0.4609 - val_auxiliary_classifier_accuracy: 0.6283 - val_auxiliary_classifier_top5_acc: 0.9860 - val_auxiliary_classifier_macro_f1score: 0.4623
# Learning rate:  0.001
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 21/70
# 448/448 [==============================] - ETA: 0s - loss: 1.5556 - main_classifier_loss: 1.1008 - auxiliary_classifier_loss: 1.1369 - main_classifier_accuracy: 0.6847 - main_classifier_top5_acc: 0.9909 - main_classifier_macro_f1score: 0.5449 - auxiliary_classifier_accuracy: 0.6788 - auxiliary_classifier_top5_acc: 0.9890 - auxiliary_classifier_macro_f1score: 0.5390
# Epoch 00021: val_loss did not improve from 1.68326
#
# Epoch 00021: val_main_classifier_accuracy improved from 0.63281 to 0.63895, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/Inception_v3/021.h5
# 448/448 [==============================] - 626s 1s/step - loss: 1.5556 - main_classifier_loss: 1.1008 - auxiliary_classifier_loss: 1.1369 - main_classifier_accuracy: 0.6847 - main_classifier_top5_acc: 0.9909 - main_classifier_macro_f1score: 0.5449 - auxiliary_classifier_accuracy: 0.6788 - auxiliary_classifier_top5_acc: 0.9890 - auxiliary_classifier_macro_f1score: 0.5390 - val_loss: 1.6930 - val_main_classifier_loss: 1.1907 - val_auxiliary_classifier_loss: 1.2557 - val_main_classifier_accuracy: 0.6390 - val_main_classifier_top5_acc: 0.9869 - val_main_classifier_macro_f1score: 0.4826 - val_auxiliary_classifier_accuracy: 0.6239 - val_auxiliary_classifier_top5_acc: 0.9802 - val_auxiliary_classifier_macro_f1score: 0.4613
# Learning rate:  0.001
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 22/70
# 448/448 [==============================] - ETA: 0s - loss: 1.4888 - main_classifier_loss: 1.0607 - auxiliary_classifier_loss: 1.0703 - main_classifier_accuracy: 0.7066 - main_classifier_top5_acc: 0.9921 - main_classifier_macro_f1score: 0.5756 - auxiliary_classifier_accuracy: 0.7052 - auxiliary_classifier_top5_acc: 0.9919 - auxiliary_classifier_macro_f1score: 0.5778
# Epoch 00022: val_loss improved from 1.68326 to 1.63115, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/Inception_v3/022.h5
#
# Epoch 00022: val_main_classifier_accuracy improved from 0.63895 to 0.65792, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/Inception_v3/022.h5
# 448/448 [==============================] - 615s 1s/step - loss: 1.4888 - main_classifier_loss: 1.0607 - auxiliary_classifier_loss: 1.0703 - main_classifier_accuracy: 0.7066 - main_classifier_top5_acc: 0.9921 - main_classifier_macro_f1score: 0.5756 - auxiliary_classifier_accuracy: 0.7052 - auxiliary_classifier_top5_acc: 0.9919 - auxiliary_classifier_macro_f1score: 0.5778 - val_loss: 1.6312 - val_main_classifier_loss: 1.1643 - val_auxiliary_classifier_loss: 1.1670 - val_main_classifier_accuracy: 0.6579 - val_main_classifier_top5_acc: 0.9866 - val_main_classifier_macro_f1score: 0.4985 - val_auxiliary_classifier_accuracy: 0.6582 - val_auxiliary_classifier_top5_acc: 0.9866 - val_auxiliary_classifier_macro_f1score: 0.5036
# Learning rate:  0.001
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 23/70
# 448/448 [==============================] - ETA: 0s - loss: 1.4641 - main_classifier_loss: 1.0455 - auxiliary_classifier_loss: 1.0465 - main_classifier_accuracy: 0.7120 - main_classifier_top5_acc: 0.9923 - main_classifier_macro_f1score: 0.5900 - auxiliary_classifier_accuracy: 0.7110 - auxiliary_classifier_top5_acc: 0.9925 - auxiliary_classifier_macro_f1score: 0.5921
# Epoch 00023: val_loss did not improve from 1.63115
#
# Epoch 00023: val_main_classifier_accuracy did not improve from 0.65792
# 448/448 [==============================] - 611s 1s/step - loss: 1.4641 - main_classifier_loss: 1.0455 - auxiliary_classifier_loss: 1.0465 - main_classifier_accuracy: 0.7120 - main_classifier_top5_acc: 0.9923 - main_classifier_macro_f1score: 0.5900 - auxiliary_classifier_accuracy: 0.7110 - auxiliary_classifier_top5_acc: 0.9925 - auxiliary_classifier_macro_f1score: 0.5921 - val_loss: 1.7042 - val_main_classifier_loss: 1.2132 - val_auxiliary_classifier_loss: 1.2276 - val_main_classifier_accuracy: 0.6292 - val_main_classifier_top5_acc: 0.9841 - val_main_classifier_macro_f1score: 0.4711 - val_auxiliary_classifier_accuracy: 0.6217 - val_auxiliary_classifier_top5_acc: 0.9819 - val_auxiliary_classifier_macro_f1score: 0.4723
# Learning rate:  0.001
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 24/70
# 448/448 [==============================] - ETA: 0s - loss: 1.4395 - main_classifier_loss: 1.0283 - auxiliary_classifier_loss: 1.0282 - main_classifier_accuracy: 0.7228 - main_classifier_top5_acc: 0.9935 - main_classifier_macro_f1score: 0.6008 - auxiliary_classifier_accuracy: 0.7216 - auxiliary_classifier_top5_acc: 0.9935 - auxiliary_classifier_macro_f1score: 0.6034
# Epoch 00024: val_loss did not improve from 1.63115
#
# Epoch 00024: val_main_classifier_accuracy did not improve from 0.65792
# 448/448 [==============================] - 613s 1s/step - loss: 1.4395 - main_classifier_loss: 1.0283 - auxiliary_classifier_loss: 1.0282 - main_classifier_accuracy: 0.7228 - main_classifier_top5_acc: 0.9935 - main_classifier_macro_f1score: 0.6008 - auxiliary_classifier_accuracy: 0.7216 - auxiliary_classifier_top5_acc: 0.9935 - auxiliary_classifier_macro_f1score: 0.6034 - val_loss: 1.6907 - val_main_classifier_loss: 1.2095 - val_auxiliary_classifier_loss: 1.2030 - val_main_classifier_accuracy: 0.6364 - val_main_classifier_top5_acc: 0.9874 - val_main_classifier_macro_f1score: 0.5095 - val_auxiliary_classifier_accuracy: 0.6373 - val_auxiliary_classifier_top5_acc: 0.9888 - val_auxiliary_classifier_macro_f1score: 0.5248
# Learning rate:  0.001
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 25/70
# 448/448 [==============================] - ETA: 0s - loss: 1.4322 - main_classifier_loss: 1.0230 - auxiliary_classifier_loss: 1.0230 - main_classifier_accuracy: 0.7252 - main_classifier_top5_acc: 0.9930 - main_classifier_macro_f1score: 0.6057 - auxiliary_classifier_accuracy: 0.7227 - auxiliary_classifier_top5_acc: 0.9934 - auxiliary_classifier_macro_f1score: 0.6093
# Epoch 00025: val_loss did not improve from 1.63115
#
# Epoch 00025: val_main_classifier_accuracy did not improve from 0.65792
# 448/448 [==============================] - 611s 1s/step - loss: 1.4322 - main_classifier_loss: 1.0230 - auxiliary_classifier_loss: 1.0230 - main_classifier_accuracy: 0.7252 - main_classifier_top5_acc: 0.9930 - main_classifier_macro_f1score: 0.6057 - auxiliary_classifier_accuracy: 0.7227 - auxiliary_classifier_top5_acc: 0.9934 - auxiliary_classifier_macro_f1score: 0.6093 - val_loss: 1.7513 - val_main_classifier_loss: 1.2574 - val_auxiliary_classifier_loss: 1.2347 - val_main_classifier_accuracy: 0.6119 - val_main_classifier_top5_acc: 0.9796 - val_main_classifier_macro_f1score: 0.4674 - val_auxiliary_classifier_accuracy: 0.6166 - val_auxiliary_classifier_top5_acc: 0.9835 - val_auxiliary_classifier_macro_f1score: 0.4714
# Learning rate:  0.001
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 26/70
# 448/448 [==============================] - ETA: 0s - loss: 1.4065 - main_classifier_loss: 1.0046 - auxiliary_classifier_loss: 1.0047 - main_classifier_accuracy: 0.7329 - main_classifier_top5_acc: 0.9942 - main_classifier_macro_f1score: 0.6251 - auxiliary_classifier_accuracy: 0.7323 - auxiliary_classifier_top5_acc: 0.9941 - auxiliary_classifier_macro_f1score: 0.6269
# Epoch 00026: val_loss did not improve from 1.63115
#
# Epoch 00026: val_main_classifier_accuracy did not improve from 0.65792
# 448/448 [==============================] - 609s 1s/step - loss: 1.4065 - main_classifier_loss: 1.0046 - auxiliary_classifier_loss: 1.0047 - main_classifier_accuracy: 0.7329 - main_classifier_top5_acc: 0.9942 - main_classifier_macro_f1score: 0.6251 - auxiliary_classifier_accuracy: 0.7323 - auxiliary_classifier_top5_acc: 0.9941 - auxiliary_classifier_macro_f1score: 0.6269 - val_loss: 1.8138 - val_main_classifier_loss: 1.3026 - val_auxiliary_classifier_loss: 1.2780 - val_main_classifier_accuracy: 0.6133 - val_main_classifier_top5_acc: 0.9802 - val_main_classifier_macro_f1score: 0.5004 - val_auxiliary_classifier_accuracy: 0.6150 - val_auxiliary_classifier_top5_acc: 0.9785 - val_auxiliary_classifier_macro_f1score: 0.5018
# Learning rate:  0.001
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 27/70
# 448/448 [==============================] - ETA: 0s - loss: 1.3996 - main_classifier_loss: 0.9990 - auxiliary_classifier_loss: 1.0014 - main_classifier_accuracy: 0.7400 - main_classifier_top5_acc: 0.9936 - main_classifier_macro_f1score: 0.6266 - auxiliary_classifier_accuracy: 0.7360 - auxiliary_classifier_top5_acc: 0.9931 - auxiliary_classifier_macro_f1score: 0.6258
# Epoch 00027: val_loss did not improve from 1.63115
#
# Epoch 00027: val_main_classifier_accuracy did not improve from 0.65792
# 448/448 [==============================] - 607s 1s/step - loss: 1.3996 - main_classifier_loss: 0.9990 - auxiliary_classifier_loss: 1.0014 - main_classifier_accuracy: 0.7400 - main_classifier_top5_acc: 0.9936 - main_classifier_macro_f1score: 0.6266 - auxiliary_classifier_accuracy: 0.7360 - auxiliary_classifier_top5_acc: 0.9931 - auxiliary_classifier_macro_f1score: 0.6258 - val_loss: 1.6866 - val_main_classifier_loss: 1.2095 - val_auxiliary_classifier_loss: 1.1928 - val_main_classifier_accuracy: 0.6482 - val_main_classifier_top5_acc: 0.9835 - val_main_classifier_macro_f1score: 0.5181 - val_auxiliary_classifier_accuracy: 0.6546 - val_auxiliary_classifier_top5_acc: 0.9858 - val_auxiliary_classifier_macro_f1score: 0.5248
# Learning rate:  0.001
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 28/70
# 448/448 [==============================] - ETA: 0s - loss: 1.3709 - main_classifier_loss: 0.9784 - auxiliary_classifier_loss: 0.9811 - main_classifier_accuracy: 0.7500 - main_classifier_top5_acc: 0.9936 - main_classifier_macro_f1score: 0.6389 - auxiliary_classifier_accuracy: 0.7476 - auxiliary_classifier_top5_acc: 0.9933 - auxiliary_classifier_macro_f1score: 0.6444
# Epoch 00028: val_loss did not improve from 1.63115
#
# Epoch 00028: val_main_classifier_accuracy did not improve from 0.65792
# ...
# Epoch 59/70
# 448/448 [==============================] - ETA: 0s - loss: 0.8066 - main_classifier_loss: 0.5748 - auxiliary_classifier_loss: 0.5797 - main_classifier_accuracy: 0.9457 - main_classifier_top5_acc: 0.9993 - main_classifier_macro_f1score: 0.8847 - auxiliary_classifier_accuracy: 0.9429 - auxiliary_classifier_top5_acc: 0.9993 - auxiliary_classifier_macro_f1score: 0.8812
# Epoch 00059: val_loss did not improve from 1.62319
#
# Epoch 00059: val_main_classifier_accuracy did not improve from 0.67522
# 448/448 [==============================] - 608s 1s/step - loss: 0.8066 - main_classifier_loss: 0.5748 - auxiliary_classifier_loss: 0.5797 - main_classifier_accuracy: 0.9457 - main_classifier_top5_acc: 0.9993 - main_classifier_macro_f1score: 0.8847 - auxiliary_classifier_accuracy: 0.9429 - auxiliary_classifier_top5_acc: 0.9993 - auxiliary_classifier_macro_f1score: 0.8812 - val_loss: 1.8810 - val_main_classifier_loss: 1.3507 - val_auxiliary_classifier_loss: 1.3259 - val_main_classifier_accuracy: 0.6649 - val_main_classifier_top5_acc: 0.9584 - val_main_classifier_macro_f1score: 0.6105 - val_auxiliary_classifier_accuracy: 0.6691 - val_auxiliary_classifier_top5_acc: 0.9609 - val_auxiliary_classifier_macro_f1score: 0.6049
# Learning rate:  0.0001
#
# Epoch 00060: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 60/70
# 448/448 [==============================] - ETA: 0s - loss: 0.8073 - main_classifier_loss: 0.5753 - auxiliary_classifier_loss: 0.5801 - main_classifier_accuracy: 0.9444 - main_classifier_top5_acc: 0.9990 - main_classifier_macro_f1score: 0.8852 - auxiliary_classifier_accuracy: 0.9424 - auxiliary_classifier_top5_acc: 0.9992 - auxiliary_classifier_macro_f1score: 0.8815
# Epoch 00060: val_loss did not improve from 1.62319
#
# Epoch 00060: val_main_classifier_accuracy did not improve from 0.67522
# 448/448 [==============================] - 608s 1s/step - loss: 0.8073 - main_classifier_loss: 0.5753 - auxiliary_classifier_loss: 0.5801 - main_classifier_accuracy: 0.9444 - main_classifier_top5_acc: 0.9990 - main_classifier_macro_f1score: 0.8852 - auxiliary_classifier_accuracy: 0.9424 - auxiliary_classifier_top5_acc: 0.9992 - auxiliary_classifier_macro_f1score: 0.8815 - val_loss: 1.9554 - val_main_classifier_loss: 1.3982 - val_auxiliary_classifier_loss: 1.3931 - val_main_classifier_accuracy: 0.6523 - val_main_classifier_top5_acc: 0.9434 - val_main_classifier_macro_f1score: 0.5784 - val_auxiliary_classifier_accuracy: 0.6554 - val_auxiliary_classifier_top5_acc: 0.9492 - val_auxiliary_classifier_macro_f1score: 0.5633
# Learning rate:  1e-05
#
# Epoch 00061: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 61/70
# 448/448 [==============================] - ETA: 0s - loss: 0.7467 - main_classifier_loss: 0.5308 - auxiliary_classifier_loss: 0.5397 - main_classifier_accuracy: 0.9661 - main_classifier_top5_acc: 0.9995 - main_classifier_macro_f1score: 0.9112 - auxiliary_classifier_accuracy: 0.9622 - auxiliary_classifier_top5_acc: 0.9995 - auxiliary_classifier_macro_f1score: 0.9061
# Epoch 00061: val_loss did not improve from 1.62319
#
# Epoch 00061: val_main_classifier_accuracy improved from 0.67522 to 0.67997, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/Inception_v3/061.h5
# 448/448 [==============================] - 610s 1s/step - loss: 0.7467 - main_classifier_loss: 0.5308 - auxiliary_classifier_loss: 0.5397 - main_classifier_accuracy: 0.9661 - main_classifier_top5_acc: 0.9995 - main_classifier_macro_f1score: 0.9112 - auxiliary_classifier_accuracy: 0.9622 - auxiliary_classifier_top5_acc: 0.9995 - auxiliary_classifier_macro_f1score: 0.9061 - val_loss: 1.8406 - val_main_classifier_loss: 1.3250 - val_auxiliary_classifier_loss: 1.2891 - val_main_classifier_accuracy: 0.6800 - val_main_classifier_top5_acc: 0.9492 - val_main_classifier_macro_f1score: 0.6131 - val_auxiliary_classifier_accuracy: 0.6789 - val_auxiliary_classifier_top5_acc: 0.9556 - val_auxiliary_classifier_macro_f1score: 0.6104
# Learning rate:  1e-05
#
# Epoch 00062: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 62/70
# 448/448 [==============================] - ETA: 0s - loss: 0.7202 - main_classifier_loss: 0.5122 - auxiliary_classifier_loss: 0.5200 - main_classifier_accuracy: 0.9751 - main_classifier_top5_acc: 0.9995 - main_classifier_macro_f1score: 0.9155 - auxiliary_classifier_accuracy: 0.9729 - auxiliary_classifier_top5_acc: 0.9998 - auxiliary_classifier_macro_f1score: 0.9132
# Epoch 00062: val_loss did not improve from 1.62319
#
# Epoch 00062: val_main_classifier_accuracy improved from 0.67997 to 0.68471, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/Inception_v3/062.h5
# 448/448 [==============================] - 613s 1s/step - loss: 0.7202 - main_classifier_loss: 0.5122 - auxiliary_classifier_loss: 0.5200 - main_classifier_accuracy: 0.9751 - main_classifier_top5_acc: 0.9995 - main_classifier_macro_f1score: 0.9155 - auxiliary_classifier_accuracy: 0.9729 - auxiliary_classifier_top5_acc: 0.9998 - auxiliary_classifier_macro_f1score: 0.9132 - val_loss: 1.8340 - val_main_classifier_loss: 1.3225 - val_auxiliary_classifier_loss: 1.2787 - val_main_classifier_accuracy: 0.6847 - val_main_classifier_top5_acc: 0.9475 - val_main_classifier_macro_f1score: 0.6235 - val_auxiliary_classifier_accuracy: 0.6839 - val_auxiliary_classifier_top5_acc: 0.9528 - val_auxiliary_classifier_macro_f1score: 0.6158
# Learning rate:  1e-05
#
# Epoch 00063: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 63/70
# 448/448 [==============================] - ETA: 0s - loss: 0.7129 - main_classifier_loss: 0.5068 - auxiliary_classifier_loss: 0.5153 - main_classifier_accuracy: 0.9776 - main_classifier_top5_acc: 0.9997 - main_classifier_macro_f1score: 0.9204 - auxiliary_classifier_accuracy: 0.9760 - auxiliary_classifier_top5_acc: 0.9999 - auxiliary_classifier_macro_f1score: 0.9182
# Epoch 00063: val_loss did not improve from 1.62319
#
# Epoch 00063: val_main_classifier_accuracy did not improve from 0.68471
# 448/448 [==============================] - 611s 1s/step - loss: 0.7129 - main_classifier_loss: 0.5068 - auxiliary_classifier_loss: 0.5153 - main_classifier_accuracy: 0.9776 - main_classifier_top5_acc: 0.9997 - main_classifier_macro_f1score: 0.9204 - auxiliary_classifier_accuracy: 0.9760 - auxiliary_classifier_top5_acc: 0.9999 - auxiliary_classifier_macro_f1score: 0.9182 - val_loss: 1.8436 - val_main_classifier_loss: 1.3311 - val_auxiliary_classifier_loss: 1.2813 - val_main_classifier_accuracy: 0.6828 - val_main_classifier_top5_acc: 0.9445 - val_main_classifier_macro_f1score: 0.6249 - val_auxiliary_classifier_accuracy: 0.6814 - val_auxiliary_classifier_top5_acc: 0.9506 - val_auxiliary_classifier_macro_f1score: 0.6162
# Learning rate:  1e-05
#
# Epoch 00064: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 64/70
# 448/448 [==============================] - ETA: 0s - loss: 0.7106 - main_classifier_loss: 0.5049 - auxiliary_classifier_loss: 0.5145 - main_classifier_accuracy: 0.9774 - main_classifier_top5_acc: 0.9995 - main_classifier_macro_f1score: 0.9212 - auxiliary_classifier_accuracy: 0.9749 - auxiliary_classifier_top5_acc: 0.9997 - auxiliary_classifier_macro_f1score: 0.9178
# Epoch 00064: val_loss did not improve from 1.62319
#
# Epoch 00064: val_main_classifier_accuracy did not improve from 0.68471
# 448/448 [==============================] - 610s 1s/step - loss: 0.7106 - main_classifier_loss: 0.5049 - auxiliary_classifier_loss: 0.5145 - main_classifier_accuracy: 0.9774 - main_classifier_top5_acc: 0.9995 - main_classifier_macro_f1score: 0.9212 - auxiliary_classifier_accuracy: 0.9749 - auxiliary_classifier_top5_acc: 0.9997 - auxiliary_classifier_macro_f1score: 0.9178 - val_loss: 1.8660 - val_main_classifier_loss: 1.3509 - val_auxiliary_classifier_loss: 1.2876 - val_main_classifier_accuracy: 0.6758 - val_main_classifier_top5_acc: 0.9436 - val_main_classifier_macro_f1score: 0.6269 - val_auxiliary_classifier_accuracy: 0.6758 - val_auxiliary_classifier_top5_acc: 0.9528 - val_auxiliary_classifier_macro_f1score: 0.6212
# Learning rate:  1e-05
#
# Epoch 00065: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 65/70
# 448/448 [==============================] - ETA: 0s - loss: 0.7059 - main_classifier_loss: 0.5017 - auxiliary_classifier_loss: 0.5105 - main_classifier_accuracy: 0.9781 - main_classifier_top5_acc: 0.9998 - main_classifier_macro_f1score: 0.9208 - auxiliary_classifier_accuracy: 0.9761 - auxiliary_classifier_top5_acc: 0.9998 - auxiliary_classifier_macro_f1score: 0.9181
# Epoch 00065: val_loss did not improve from 1.62319
#
# Epoch 00065: val_main_classifier_accuracy did not improve from 0.68471
# 448/448 [==============================] - 609s 1s/step - loss: 0.7059 - main_classifier_loss: 0.5017 - auxiliary_classifier_loss: 0.5105 - main_classifier_accuracy: 0.9781 - main_classifier_top5_acc: 0.9998 - main_classifier_macro_f1score: 0.9208 - auxiliary_classifier_accuracy: 0.9761 - auxiliary_classifier_top5_acc: 0.9998 - auxiliary_classifier_macro_f1score: 0.9181 - val_loss: 1.8563 - val_main_classifier_loss: 1.3437 - val_auxiliary_classifier_loss: 1.2815 - val_main_classifier_accuracy: 0.6769 - val_main_classifier_top5_acc: 0.9489 - val_main_classifier_macro_f1score: 0.6075 - val_auxiliary_classifier_accuracy: 0.6797 - val_auxiliary_classifier_top5_acc: 0.9545 - val_auxiliary_classifier_macro_f1score: 0.6046
# Learning rate:  1e-05
#
# Epoch 00066: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 66/70
# 448/448 [==============================] - ETA: 0s - loss: 0.6993 - main_classifier_loss: 0.4968 - auxiliary_classifier_loss: 0.5063 - main_classifier_accuracy: 0.9813 - main_classifier_top5_acc: 0.9998 - main_classifier_macro_f1score: 0.9293 - auxiliary_classifier_accuracy: 0.9796 - auxiliary_classifier_top5_acc: 0.9999 - auxiliary_classifier_macro_f1score: 0.9272
# Epoch 00066: val_loss did not improve from 1.62319
#
# Epoch 00066: val_main_classifier_accuracy did not improve from 0.68471
# 448/448 [==============================] - 608s 1s/step - loss: 0.6993 - main_classifier_loss: 0.4968 - auxiliary_classifier_loss: 0.5063 - main_classifier_accuracy: 0.9813 - main_classifier_top5_acc: 0.9998 - main_classifier_macro_f1score: 0.9293 - auxiliary_classifier_accuracy: 0.9796 - auxiliary_classifier_top5_acc: 0.9999 - auxiliary_classifier_macro_f1score: 0.9272 - val_loss: 1.8546 - val_main_classifier_loss: 1.3425 - val_auxiliary_classifier_loss: 1.2802 - val_main_classifier_accuracy: 0.6794 - val_main_classifier_top5_acc: 0.9445 - val_main_classifier_macro_f1score: 0.6071 - val_auxiliary_classifier_accuracy: 0.6808 - val_auxiliary_classifier_top5_acc: 0.9512 - val_auxiliary_classifier_macro_f1score: 0.6048
# Learning rate:  1e-05
#
# Epoch 00067: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 67/70
# 448/448 [==============================] - ETA: 0s - loss: 0.6968 - main_classifier_loss: 0.4951 - auxiliary_classifier_loss: 0.5043 - main_classifier_accuracy: 0.9813 - main_classifier_top5_acc: 0.9998 - main_classifier_macro_f1score: 0.9237 - auxiliary_classifier_accuracy: 0.9807 - auxiliary_classifier_top5_acc: 0.9999 - auxiliary_classifier_macro_f1score: 0.9206
# Epoch 00067: val_loss did not improve from 1.62319
#
# Epoch 00067: val_main_classifier_accuracy did not improve from 0.68471
# 448/448 [==============================] - 609s 1s/step - loss: 0.6968 - main_classifier_loss: 0.4951 - auxiliary_classifier_loss: 0.5043 - main_classifier_accuracy: 0.9813 - main_classifier_top5_acc: 0.9998 - main_classifier_macro_f1score: 0.9237 - auxiliary_classifier_accuracy: 0.9807 - auxiliary_classifier_top5_acc: 0.9999 - auxiliary_classifier_macro_f1score: 0.9206 - val_loss: 1.8691 - val_main_classifier_loss: 1.3544 - val_auxiliary_classifier_loss: 1.2866 - val_main_classifier_accuracy: 0.6772 - val_main_classifier_top5_acc: 0.9428 - val_main_classifier_macro_f1score: 0.6157 - val_auxiliary_classifier_accuracy: 0.6808 - val_auxiliary_classifier_top5_acc: 0.9509 - val_auxiliary_classifier_macro_f1score: 0.6152
# Learning rate:  1e-05
#
# Epoch 00068: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 68/70
# 448/448 [==============================] - ETA: 0s - loss: 0.6967 - main_classifier_loss: 0.4950 - auxiliary_classifier_loss: 0.5043 - main_classifier_accuracy: 0.9820 - main_classifier_top5_acc: 0.9997 - main_classifier_macro_f1score: 0.9247 - auxiliary_classifier_accuracy: 0.9809 - auxiliary_classifier_top5_acc: 0.9999 - auxiliary_classifier_macro_f1score: 0.9219
# Epoch 00068: val_loss did not improve from 1.62319
#
# Epoch 00068: val_main_classifier_accuracy did not improve from 0.68471
# 448/448 [==============================] - 609s 1s/step - loss: 0.6967 - main_classifier_loss: 0.4950 - auxiliary_classifier_loss: 0.5043 - main_classifier_accuracy: 0.9820 - main_classifier_top5_acc: 0.9997 - main_classifier_macro_f1score: 0.9247 - auxiliary_classifier_accuracy: 0.9809 - auxiliary_classifier_top5_acc: 0.9999 - auxiliary_classifier_macro_f1score: 0.9219 - val_loss: 1.8622 - val_main_classifier_loss: 1.3486 - val_auxiliary_classifier_loss: 1.2839 - val_main_classifier_accuracy: 0.6791 - val_main_classifier_top5_acc: 0.9470 - val_main_classifier_macro_f1score: 0.6127 - val_auxiliary_classifier_accuracy: 0.6805 - val_auxiliary_classifier_top5_acc: 0.9528 - val_auxiliary_classifier_macro_f1score: 0.6033
# Learning rate:  1e-05
#
# Epoch 00069: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 69/70
# 448/448 [==============================] - ETA: 0s - loss: 0.6926 - main_classifier_loss: 0.4920 - auxiliary_classifier_loss: 0.5014 - main_classifier_accuracy: 0.9827 - main_classifier_top5_acc: 0.9997 - main_classifier_macro_f1score: 0.9247 - auxiliary_classifier_accuracy: 0.9809 - auxiliary_classifier_top5_acc: 0.9999 - auxiliary_classifier_macro_f1score: 0.9223
# Epoch 00069: val_loss did not improve from 1.62319
#
# Epoch 00069: val_main_classifier_accuracy did not improve from 0.68471
# 448/448 [==============================] - 608s 1s/step - loss: 0.6926 - main_classifier_loss: 0.4920 - auxiliary_classifier_loss: 0.5014 - main_classifier_accuracy: 0.9827 - main_classifier_top5_acc: 0.9997 - main_classifier_macro_f1score: 0.9247 - auxiliary_classifier_accuracy: 0.9809 - auxiliary_classifier_top5_acc: 0.9999 - auxiliary_classifier_macro_f1score: 0.9223 - val_loss: 1.8589 - val_main_classifier_loss: 1.3464 - val_auxiliary_classifier_loss: 1.2813 - val_main_classifier_accuracy: 0.6825 - val_main_classifier_top5_acc: 0.9445 - val_main_classifier_macro_f1score: 0.6270 - val_auxiliary_classifier_accuracy: 0.6819 - val_auxiliary_classifier_top5_acc: 0.9498 - val_auxiliary_classifier_macro_f1score: 0.6211
# Learning rate:  1e-05
#
# Epoch 00070: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 70/70
# 448/448 [==============================] - ETA: 0s - loss: 0.6934 - main_classifier_loss: 0.4923 - auxiliary_classifier_loss: 0.5025 - main_classifier_accuracy: 0.9827 - main_classifier_top5_acc: 0.9997 - main_classifier_macro_f1score: 0.9278 - auxiliary_classifier_accuracy: 0.9804 - auxiliary_classifier_top5_acc: 0.9998 - auxiliary_classifier_macro_f1score: 0.9248
# Epoch 00070: val_loss did not improve from 1.62319
#
# Epoch 00070: val_main_classifier_accuracy did not improve from 0.68471
# 448/448 [==============================] - 607s 1s/step - loss: 0.6934 - main_classifier_loss: 0.4923 - auxiliary_classifier_loss: 0.5025 - main_classifier_accuracy: 0.9827 - main_classifier_top5_acc: 0.9997 - main_classifier_macro_f1score: 0.9278 - auxiliary_classifier_accuracy: 0.9804 - auxiliary_classifier_top5_acc: 0.9998 - auxiliary_classifier_macro_f1score: 0.9248 - val_loss: 1.8716 - val_main_classifier_loss: 1.3565 - val_auxiliary_classifier_loss: 1.2878 - val_main_classifier_accuracy: 0.6769 - val_main_classifier_top5_acc: 0.9406 - val_main_classifier_macro_f1score: 0.6119 - val_auxiliary_classifier_accuracy: 0.6775 - val_auxiliary_classifier_top5_acc: 0.9515 - val_auxiliary_classifier_macro_f1score: 0.6042

# %% [markdown]
# ### 3) Inception-V3 Evaluate

# %%
# 1. epoch=maximum
#var = model.evaluate_generator(generate_test_for_three(),steps=int(len(x_test)/batch_sizes))
var = model.evaluate(generate_test_for_two(),steps=int(len(x_test)/batch_sizes))
print('[Test Loss: %.4f /   Test Top-1 Accuracy: %.4f / Test Top-5 Accuracy: %.4f / Test Macro f1: %.4f]\n' % (var[0],var[-3],var[-2],var[-1]))
# Out:
# Found 3588 images belonging to 7 classes.
# 56/56 [==============================] - 2728s 49s/step - loss: 1.9094 - main_classifier_loss: 1.3828 - auxiliary_classifier_loss: 1.3164 - main_classifier_accuracy: 0.6738 - main_classifier_top5_acc: 0.9420 - main_classifier_macro_f1score: 0.5919 - auxiliary_classifier_accuracy: 0.6749 - auxiliary_classifier_top5_acc: 0.9556 - auxiliary_classifier_macro_f1score: 0.5856
# [Test Loss: 1.9094 /   Test Top-1 Accuracy: 0.6749 / Test Top-5 Accuracy: 0.9556 / Test Macro f1: 0.5856]

# %%
loss=history.history['loss']
val_loss=history.history['val_loss']
acc=history.history['main_classifier_accuracy']
val_acc=history.history['val_main_classifier_accuracy']
top5_acc=history.history['main_classifier_top5_acc']
val_top5_acc=history.history['val_main_classifier_top5_acc']
f1=history.history['main_classifier_macro_f1score']
val_f1=history.history['val_main_classifier_macro_f1score']
epochs=range(1,len(acc)+1)

data = np.array([epochs,loss,val_loss,acc,val_acc,top5_acc,val_top5_acc,f1,val_f1]).T

# %%
# data save
# epochs, loss, val_loss, acc, val_acc, top5_acc, val_top5_acc, f1, val_f1

np.savetxt(os.path.join(dir,'train_valid_output',number,model.name+'.txt'),data)

# %%
# data import
data = np.loadtxt(os.path.join(dir,'train_valid_output',number,'Inception_v3.txt'))

# %%
epochs=data[:,0]
loss=data[:,1]
val_loss=data[:,2]
acc=data[:,3]
val_acc=data[:,4]
top5_acc=data[:,5]
val_top5_acc=data[:,6]

# %%
plt.plot(epochs[1:],acc[1:],'b',label='Training 1-Acc')
plt.plot(epochs[1:],val_acc[1:],'r',label='Validation 1-Acc')
plt.title('Training and Validation Top-1 Accuracy')
plt.legend()
plt.figure()

plt.plot(epochs[1:],top5_acc[1:],'b',label='Training 5-Acc')
plt.plot(epochs[1:],val_top5_acc[1:],'r',label='Validation 5-Acc')
plt.title('Training and Validation Top-5 Accuracy')
plt.legend()
plt.figure()

plt.plot(epochs[10:],loss[10:],'b',label='Training Loss')
plt.plot(epochs[10:],val_loss[10:],'r',label='Validation Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()

# %%
# 이 아래는 내가 인위적으로 살펴보고 싶은 epoch에 대해서 결과값 출력 / Inception-V3

# %%
# 참고 : https://github.com/OverLordGoldDragon/keras-adamw

import sys
sys.path.append('/content/drive/My Drive/Colab Notebooks/Paper')
import utils
import optimizers_v2
from utils import get_weight_decays, fill_dict_in_order
from utils import reset_seeds, K_eval
from optimizers_v2 import AdamW, NadamW, SGDW

# %%
# top-5 accuracy 출력
import functools
top5_acc = functools.partial(ks.metrics.top_k_categorical_accuracy, k=5)
top5_acc.__name__ = 'top5_acc'

# %%
model=load_model(os.path.join(dir,'model_output',number,'Inception_v3','062.h5'),
                 custom_objects={"macro_f1score": macro_f1score, "top5_acc":top5_acc, "smoothed_categorical_crossentropy":smoothed_categorical_crossentropy, "AdamW":AdamW})

# %%
# 2. epoch=?
smoothing_param = 0.1
var = model.evaluate(generate_test_for_two(),steps=int(len(x_test)/batch_sizes))
# Out:
# Found 3588 images belonging to 7 classes.
# 56/56 [==============================] - 1057s 19s/step - loss: 1.8911 - main_classifier_loss: 1.3630 - auxiliary_classifier_loss: 1.3204 - main_classifier_accuracy: 0.6735 - main_classifier_top5_acc: 0.9492 - main_classifier_macro_f1score: 0.6061 - auxiliary_classifier_accuracy: 0.6710 - auxiliary_classifier_top5_acc: 0.9573 - auxiliary_classifier_macro_f1score: 0.5972

# %%
print('[Test Loss: %.4f /  Test Top-1 Accuracy: %.4f / Test Top-5 Accuracy: %.4f / Test Macro f1: %.4f]\n' % (var[0],var[-3],var[-2],var[-1]))
# Out:
# [Test Loss: 1.8911 /  Test Top-1 Accuracy: 0.6710 / Test Top-5 Accuracy: 0.9573 / Test Macro f1: 0.5972]
