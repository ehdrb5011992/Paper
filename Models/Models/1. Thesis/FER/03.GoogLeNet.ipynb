# %% [markdown]
# # [GoogLeNet]

# %% [markdown]
# *KU LeeDongGyu*

# %% [markdown]
# ## Contents
# ---

# %% [markdown]
# 1. Data Preprocessing
# ```
# 1) Data Import
# 2) Data Augmentation
# ```
# 2. Support Functions & Almost Original GoogLeNet
# ```
# 1) Support Functions
# 2) Almost Original GoogLeNet
# 3) GoogLeNet Evaluate
# ```

# %% [markdown]
# ### Install Packages

# %% [markdown]
# ### Module

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/My Drive/Colab Notebooks/Paper
# Out:
# /content/drive/My Drive/Colab Notebooks/Paper

# %%
from f1score import macro_f1score,weighted_f1score
from pool_helper import PoolHelper
from lrn import LRN

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import cv2
import tensorflow as tf
from tensorflow import keras as ks
from tensorflow.keras import backend as K 
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, Input, Concatenate, ZeroPadding2D ,GlobalMaxPooling2D, Reshape , Lambda , Add, Multiply
from tensorflow.keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D, Activation, BatchNormalization, AveragePooling2D , ZeroPadding2D, SeparableConv2D
from tensorflow.keras.layers import add
from tensorflow.keras.optimizers import Adam, RMSprop , SGD
from tensorflow.keras.callbacks import EarlyStopping , LearningRateScheduler, ModelCheckpoint, CSVLogger, Callback, ReduceLROnPlateau
from tensorflow.keras.regularizers import l1,l2,l1_l2
from tensorflow.keras.models import Model , load_model , Sequential
from tensorflow.keras.utils import plot_model , to_categorical, get_file
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
os.getcwd()
# Out:
# '/content/drive/My Drive/Colab Notebooks/Paper'

# %%
print(tf.__version__)
print(ks.__version__)
# Out:
# 2.3.0
# 2.4.0

# %%
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 7465286339423135742
# , name: "/device:XLA_CPU:0"
# device_type: "XLA_CPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 9543192365907699825
# physical_device_desc: "device: XLA_CPU device"
# , name: "/device:XLA_GPU:0"
# device_type: "XLA_GPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 10764676763002855115
# physical_device_desc: "device: XLA_GPU device"
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 15695549568
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 7875225002096571789
# physical_device_desc: "device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0"
# ]

# %% [markdown]
# ## 1. Data Preprocessing
# ---

# %% [markdown]
# ### 1) Data Import

# %%
# 바꿔서 살펴 볼 것들
# CALTECH, CIFAR100, FER, MIT
data_name = 'FER'
gan_type = 'No_GAN'
number = '1'
size = 224
super_size = 256
input_sizes = (size,size,3)
batch_sizes = 128
weight_decay = 1e-4
epochs = 70

# %%
# 참고 : https://stackoverflow.com/questions/32419510/how-to-get-reproducible-results-in-keras/52897216#52897216
# setting the seed number for random number generation for reproducibility.

from numpy.random import seed
import random


if number=='1':
    seed_num = 200225
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)
elif number=='2':
    seed_num = 727
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)
elif number=='3':
    seed_num = 115
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)
elif number=='4':
    seed_num = 501
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)
elif number=='5':
    seed_num = 517
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)

# %%
# data import

if data_name=='FER' :
    x_train =  np.zeros(28698)
    x_valid = np.zeros(3589)
    x_test = np.zeros(3588)
    classes = 7 
    tr_center = [0.50793296, 0.50793296, 0.50793296]
elif data_name=='MIT':
    x_train = np.zeros(12466)
    x_valid = np.zeros(1564)
    x_test = np.zeros(1590)
    classes = 67 
    tr_center = [0.47916578, 0.42029615, 0.36046057]
elif data_name=='CALTECH':
    x_train = np.zeros(24510)
    x_valid = np.zeros(2980)
    x_test = np.zeros(3118)
    classes = 257
    tr_center = [0.51397761, 0.49525248, 0.46555727]
elif data_name=='CIFAR100':
    x_train = np.zeros(44923)
    x_valid = np.zeros(5077)
    x_test = np.zeros(10000)
    classes = 100
    tr_center = [0.53442983, 0.51355958, 0.46462564]

# %%
dir = os.path.join(os.getcwd(),data_name,gan_type)

# %% [markdown]
# ### 2) Data Augmentation

# %%
# 참고 : https://jkjung-avt.github.io/keras-image-cropping/

def random_crop(img, random_crop_size):
    # Note: image_data_format is 'channel_last'
    assert img.shape[2] == 3 # img.shape[2] 가 3(rgb)이 아니면 assertion error 발생
    height, width = img.shape[0], img.shape[1]
    dy, dx = random_crop_size
    x = np.random.randint(0, width - dx + 1)
    y = np.random.randint(0, height - dy + 1)
    return img[y:(y+dy), x:(x+dx), :]


def crop_generator(batches, crop_length):
    """Take as input a Keras ImageGen (Iterator) and generate random
    crops from the image batches generated by the original iterator.
    """
    while True:
        batch_x, batch_y = next(batches)
        batch_crops = np.zeros((batch_x.shape[0], crop_length, crop_length, 3))
        for i in range(batch_x.shape[0]):
            batch_crops[i] = random_crop(batch_x[i], (crop_length, crop_length))
        yield (batch_crops, batch_y)

# %%
from tensorflow.keras.preprocessing.image import img_to_array,load_img
import glob

# 데이터 전체에 대해 centering 진행함.

def read_cal_image(img_path): 
    x = img_to_array(load_img(img_path)) # x는 채널별 평균값
    y = x.shape[0] * x.shape[1]# y는 데이터별 픽셀 수 (비중)

    x = 1/255. * x # scaling하고, centering값을 뽑아냄.
    x = np.mean(x, axis=(0,1))
    
    return np.hstack([x,y])

def calculate_centered_mean(dataset_path,x_train=x_train):
    num = len(x_train)
    space = np.empty((num,4))
    i=0

    for p in glob.glob(os.path.join(dataset_path,'*/*.*')) :
        space[i] = read_cal_image(p)
        i += 1

    ratio = space[:,3] / np.sum(space[:,3])

    return np.average(space[:,0:3],axis=0,weights=ratio)


# 아래의 함수를 돌려서 나온 결과값을 중심화 값으로 설정.

# train_mean = calculate_centered_mean(os.path.join(dir,'data/train')).reshape((1,1,3))

# %%
datagen_tr = ImageDataGenerator(
    rescale=1/255.,
    horizontal_flip=True,
    featurewise_center=True,
    featurewise_std_normalization=False,
    rotation_range=10,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=[0.9,1.0],
    fill_mode = 'nearest')
datagen_val = ImageDataGenerator(rescale=1/255.,featurewise_center=True)
datagen_tes = ImageDataGenerator(rescale=1/255.,featurewise_center=True)

# 원래는 이 자리에 fit 매서드를 써야하지만, 그냥 내가 중심화함수를 만들고 적용함. 

# 중심화 설정
datagen_tr.mean = np.array(tr_center, dtype=np.float32).reshape((1,1,3)) # RGB
datagen_val.mean = np.array(tr_center, dtype=np.float32).reshape((1,1,3)) # RGB
datagen_tes.mean = np.array(tr_center, dtype=np.float32).reshape((1,1,3)) # RGB

# %%
# 매우 간단하다.

#1. train data

def generate_train_for_three(crop_length=size, batch_sizes = batch_sizes, super_size=super_size):

      batches = datagen_tr.flow_from_directory(directory=os.path.join(dir,'data/train'),target_size=(super_size,super_size),batch_size=batch_sizes,class_mode='categorical')

      while True:
          batch_x, batch_y = next(batches)
          batch_crops = np.zeros((batch_x.shape[0], crop_length, crop_length, 3))
          for i in range(batch_x.shape[0]):
              batch_crops[i] = random_crop(batch_x[i], (crop_length, crop_length))
          yield batch_crops, [batch_y,batch_y,batch_y]

# %%
# 2. valid data

def generate_valid_for_three(size=size, batch_sizes = batch_sizes):

      batches_xy = datagen_val.flow_from_directory(directory=os.path.join(dir,'data/valid'),target_size=(size,size),batch_size=batch_sizes,class_mode='categorical')

      while True:

          batch_xy = batches_xy.next()
          yield  batch_xy[0], [ batch_xy[1],batch_xy[1],batch_xy[1] ]

# %%
# 3. test data

def generate_test_for_three(size=size, batch_sizes = batch_sizes):

      batches_xy = datagen_tes.flow_from_directory(directory=os.path.join(dir,'data/test'),target_size=(size,size),batch_size=batch_sizes,class_mode='categorical')

      while True:

          batch_xy = batches_xy.next()
          yield  batch_xy[0], [ batch_xy[1],batch_xy[1],batch_xy[1] ]

# %%
# 위에서 쓰임
# train_batches = datagen_tr.flow_from_directory(directory=os.path.join(dir,'data/train'),target_size=(super_size,super_size),batch_size=batch_sizes,class_mode='categorical') # fer : 28698 / mit : 12466 / caltech : 24509 / cifar : 44923
# train_generator= crop_generator(train_batches, size)

# valid_generator = datagen_val.flow_from_directory(directory=os.path.join(dir,'data/valid'),target_size=(size,size),batch_size=batch_sizes,class_mode='categorical') # fer : 3589 / mit : 1564 / caltech : 2980 / cifar : 5077
# test_generator = datagen_tes.flow_from_directory(directory=os.path.join(dir,'data/test'),target_size=(size,size),batch_size=batch_sizes,class_mode='categorical') # fer : 3588 / mit : 1590 / caltech : 3118 / cifar : 10000

# %% [markdown]
# ## 2. Support Functions & Almost Original GoogLeNet
# ---

# %% [markdown]
# ### 1) Support Functions

# %%
# def lr_schedule(epoch):
#     init_lr = 1e-4
#     k = 0.04
#     lr = init_lr * np.exp(-k*epoch)
#     print('Learning rate: ', lr)
#     return lr

def lr_schedule(epoch):
    lr = 3e-4
    if epoch < 30:
        lr = lr
    elif epoch < 60 :
        lr = lr * 0.1
    else:
        lr = lr * 0.01
    print('Learning rate: ', lr)
    return lr

# %% [markdown]
# ### 3) Almost Original GoogLeNet

# %%
# GoogLeNet를 최대한 논문에 가깝게 맞춰 모형작성.

def googlenet(input_shape=(224,224,3), classes=1000, weight_decay = weight_decay, weights_path = None,name='Inception_v1'):

    input = Input(input_shape)

    conv1_7x7_s2 = Conv2D(64, (7,7), strides=(2,2), padding='same', activation='relu', name='conv1/7x7_s2', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(input)
    pool1_3x3_s2 = MaxPooling2D(pool_size=(3,3), strides=(2,2), padding='same', name='pool1/3x3_s2')(conv1_7x7_s2)
    pool1_norm1 = LRN(name='pool1/norm1')(pool1_3x3_s2)

    conv2_3x3_reduce = Conv2D(64, (1,1), padding='same', activation='relu', name='conv2/3x3_reduce', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(pool1_norm1)
    conv2_3x3 = Conv2D(192, (3,3), padding='same', activation='relu', name='conv2/3x3', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(conv2_3x3_reduce)
    conv2_norm2 = LRN(name='conv2/norm2')(conv2_3x3)
    pool2_3x3_s2 = MaxPooling2D(pool_size=(3,3), strides=(2,2), padding='same', name='pool2/3x3_s2')(conv2_norm2)

    inception_3a_1x1 = Conv2D(64, (1,1), padding='same', activation='relu', name='inception_3a/1x1', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(pool2_3x3_s2)
    inception_3a_3x3_reduce = Conv2D(96, (1,1), padding='same', activation='relu', name='inception_3a/3x3_reduce', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(pool2_3x3_s2)
    inception_3a_3x3_pad = ZeroPadding2D(padding=(1, 1))(inception_3a_3x3_reduce)
    inception_3a_3x3 = Conv2D(128, (3,3), padding='valid', activation='relu', name='inception_3a/3x3', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_3a_3x3_pad)
    inception_3a_5x5_reduce = Conv2D(16, (1,1), padding='same', activation='relu', name='inception_3a/5x5_reduce', kernel_regularizer=l2(weight_decay))(pool2_3x3_s2)
    inception_3a_5x5_pad = ZeroPadding2D(padding=(2, 2))(inception_3a_5x5_reduce)
    inception_3a_5x5 = Conv2D(32, (5,5), padding='valid', activation='relu', name='inception_3a/5x5', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_3a_5x5_pad)
    inception_3a_pool = MaxPooling2D(pool_size=(3,3), strides=(1,1), padding='same', name='inception_3a/pool')(pool2_3x3_s2)
    inception_3a_pool_proj = Conv2D(32, (1,1), padding='same', activation='relu', name='inception_3a/pool_proj', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_3a_pool)
    inception_3a_output = Concatenate(axis=-1, name='inception_3a/output')([inception_3a_1x1,inception_3a_3x3,inception_3a_5x5,inception_3a_pool_proj])
    # Concatenate axis 수정.

    inception_3b_1x1 = Conv2D(128, (1,1), padding='same', activation='relu', name='inception_3b/1x1', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_3a_output)
    inception_3b_3x3_reduce = Conv2D(128, (1,1), padding='same', activation='relu', name='inception_3b/3x3_reduce', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_3a_output)
    inception_3b_3x3_pad = ZeroPadding2D(padding=(1, 1))(inception_3b_3x3_reduce)
    inception_3b_3x3 = Conv2D(192, (3,3), padding='valid', activation='relu', name='inception_3b/3x3', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_3b_3x3_pad)
    inception_3b_5x5_reduce = Conv2D(32, (1,1), padding='same', activation='relu', name='inception_3b/5x5_reduce', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_3a_output)
    inception_3b_5x5_pad = ZeroPadding2D(padding=(2, 2))(inception_3b_5x5_reduce)
    inception_3b_5x5 = Conv2D(96, (5,5), padding='valid', activation='relu', name='inception_3b/5x5', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_3b_5x5_pad)
    inception_3b_pool = MaxPooling2D(pool_size=(3,3), strides=(1,1), padding='same', name='inception_3b/pool')(inception_3a_output)
    inception_3b_pool_proj = Conv2D(64, (1,1), padding='same', activation='relu', name='inception_3b/pool_proj', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_3b_pool)
    inception_3b_output = Concatenate(axis=-1, name='inception_3b/output')([inception_3b_1x1,inception_3b_3x3,inception_3b_5x5,inception_3b_pool_proj])

    pool3_3x3_s2 = MaxPooling2D(pool_size=(3,3), strides=(2,2), padding='same', name='pool3/3x3_s2')(inception_3b_output)

    inception_4a_1x1 = Conv2D(192, (1,1), padding='same', activation='relu', name='inception_4a/1x1', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(pool3_3x3_s2)
    inception_4a_3x3_reduce = Conv2D(96, (1,1), padding='same', activation='relu', name='inception_4a/3x3_reduce', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(pool3_3x3_s2)
    inception_4a_3x3_pad = ZeroPadding2D(padding=(1, 1))(inception_4a_3x3_reduce)
    inception_4a_3x3 = Conv2D(208, (3,3), padding='valid', activation='relu', name='inception_4a/3x3', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_4a_3x3_pad)
    inception_4a_5x5_reduce = Conv2D(16, (1,1), padding='same', activation='relu', name='inception_4a/5x5_reduce', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(pool3_3x3_s2)
    inception_4a_5x5_pad = ZeroPadding2D(padding=(2, 2))(inception_4a_5x5_reduce)
    inception_4a_5x5 = Conv2D(48, (5,5), padding='valid', activation='relu', name='inception_4a/5x5', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_4a_5x5_pad)
    inception_4a_pool = MaxPooling2D(pool_size=(3,3), strides=(1,1), padding='same', name='inception_4a/pool')(pool3_3x3_s2)
    inception_4a_pool_proj = Conv2D(64, (1,1), padding='same', activation='relu', name='inception_4a/pool_proj', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_4a_pool)
    inception_4a_output = Concatenate(axis=-1, name='inception_4a/output')([inception_4a_1x1,inception_4a_3x3,inception_4a_5x5,inception_4a_pool_proj])

    loss1_ave_pool = AveragePooling2D(pool_size=(5,5), strides=(3,3), name='loss1/ave_pool')(inception_4a_output)
    loss1_conv = Conv2D(128, (1,1), padding='same', activation='relu', name='loss1/conv', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(loss1_ave_pool)
    loss1_flat = Flatten()(loss1_conv)
    loss1_fc = Dense(1024, activation='relu', name='loss1/fc', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(loss1_flat)
    loss1_drop_fc = Dropout(rate=0.7)(loss1_fc)
    loss1_classifier = Dense(classes, activation='softmax', kernel_regularizer=l2(weight_decay), name='loss1/classifier')(loss1_drop_fc)

    inception_4b_1x1 = Conv2D(160, (1,1), padding='same', activation='relu', name='inception_4b/1x1', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_4a_output)
    inception_4b_3x3_reduce = Conv2D(112, (1,1), padding='same', activation='relu', name='inception_4b/3x3_reduce', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_4a_output)
    inception_4b_3x3_pad = ZeroPadding2D(padding=(1, 1))(inception_4b_3x3_reduce)
    inception_4b_3x3 = Conv2D(224, (3,3), padding='valid', activation='relu', name='inception_4b/3x3', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_4b_3x3_pad)
    inception_4b_5x5_reduce = Conv2D(24, (1,1), padding='same', activation='relu', name='inception_4b/5x5_reduce', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_4a_output)
    inception_4b_5x5_pad = ZeroPadding2D(padding=(2, 2))(inception_4b_5x5_reduce)
    inception_4b_5x5 = Conv2D(64, (5,5), padding='valid', activation='relu', name='inception_4b/5x5', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_4b_5x5_pad)
    inception_4b_pool = MaxPooling2D(pool_size=(3,3), strides=(1,1), padding='same', name='inception_4b/pool')(inception_4a_output)
    inception_4b_pool_proj = Conv2D(64, (1,1), padding='same', activation='relu', name='inception_4b/pool_proj', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_4b_pool)
    inception_4b_output = Concatenate(axis=-1, name='inception_4b/output')([inception_4b_1x1,inception_4b_3x3,inception_4b_5x5,inception_4b_pool_proj])

    inception_4c_1x1 = Conv2D(128, (1,1), padding='same', activation='relu', name='inception_4c/1x1', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_4b_output)
    inception_4c_3x3_reduce = Conv2D(128, (1,1), padding='same', activation='relu', name='inception_4c/3x3_reduce', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_4b_output)
    inception_4c_3x3_pad = ZeroPadding2D(padding=(1, 1))(inception_4c_3x3_reduce)
    inception_4c_3x3 = Conv2D(256, (3,3), padding='valid', activation='relu', name='inception_4c/3x3', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_4c_3x3_pad)
    inception_4c_5x5_reduce = Conv2D(24, (1,1), padding='same', activation='relu', name='inception_4c/5x5_reduce', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_4b_output)
    inception_4c_5x5_pad = ZeroPadding2D(padding=(2, 2))(inception_4c_5x5_reduce)
    inception_4c_5x5 = Conv2D(64, (5,5), padding='valid', activation='relu', name='inception_4c/5x5', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_4c_5x5_pad)
    inception_4c_pool = MaxPooling2D(pool_size=(3,3), strides=(1,1), padding='same', name='inception_4c/pool')(inception_4b_output)
    inception_4c_pool_proj = Conv2D(64, (1,1), padding='same', activation='relu', name='inception_4c/pool_proj', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_4c_pool)
    inception_4c_output = Concatenate(axis=-1, name='inception_4c/output')([inception_4c_1x1,inception_4c_3x3,inception_4c_5x5,inception_4c_pool_proj])

    inception_4d_1x1 = Conv2D(112, (1,1), padding='same', activation='relu', name='inception_4d/1x1', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_4c_output)
    inception_4d_3x3_reduce = Conv2D(144, (1,1), padding='same', activation='relu', name='inception_4d/3x3_reduce', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_4c_output)
    inception_4d_3x3_pad = ZeroPadding2D(padding=(1, 1))(inception_4d_3x3_reduce)
    inception_4d_3x3 = Conv2D(288, (3,3), padding='valid', activation='relu', name='inception_4d/3x3', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_4d_3x3_pad)
    inception_4d_5x5_reduce = Conv2D(32, (1,1), padding='same', activation='relu', name='inception_4d/5x5_reduce', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_4c_output)
    inception_4d_5x5_pad = ZeroPadding2D(padding=(2, 2))(inception_4d_5x5_reduce)
    inception_4d_5x5 = Conv2D(64, (5,5), padding='valid', activation='relu', name='inception_4d/5x5', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_4d_5x5_pad)
    inception_4d_pool = MaxPooling2D(pool_size=(3,3), strides=(1,1), padding='same', name='inception_4d/pool')(inception_4c_output)
    inception_4d_pool_proj = Conv2D(64, (1,1), padding='same', activation='relu', name='inception_4d/pool_proj', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_4d_pool)
    inception_4d_output = Concatenate(axis=-1, name='inception_4d/output')([inception_4d_1x1,inception_4d_3x3,inception_4d_5x5,inception_4d_pool_proj])

    loss2_ave_pool = AveragePooling2D(pool_size=(5,5), strides=(3,3), name='loss2/ave_pool')(inception_4d_output)
    loss2_conv = Conv2D(128, (1,1), padding='same', activation='relu', name='loss2/conv', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(loss2_ave_pool)
    loss2_flat = Flatten()(loss2_conv)
    loss2_fc = Dense(1024, activation='relu', name='loss2/fc', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(loss2_flat)
    loss2_drop_fc = Dropout(rate=0.7)(loss2_fc)
    loss2_classifier = Dense(classes, activation='softmax', kernel_regularizer=l2(weight_decay), name='loss2/classifier')(loss2_drop_fc)

    inception_4e_1x1 = Conv2D(256, (1,1), padding='same', activation='relu', name='inception_4e/1x1', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_4d_output)
    inception_4e_3x3_reduce = Conv2D(160, (1,1), padding='same', activation='relu', name='inception_4e/3x3_reduce', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_4d_output)
    inception_4e_3x3_pad = ZeroPadding2D(padding=(1, 1))(inception_4e_3x3_reduce)
    inception_4e_3x3 = Conv2D(320, (3,3), padding='valid', activation='relu', name='inception_4e/3x3', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_4e_3x3_pad)
    inception_4e_5x5_reduce = Conv2D(32, (1,1), padding='same', activation='relu', name='inception_4e/5x5_reduce', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_4d_output)
    inception_4e_5x5_pad = ZeroPadding2D(padding=(2, 2))(inception_4e_5x5_reduce)
    inception_4e_5x5 = Conv2D(128, (5,5), padding='valid', activation='relu', name='inception_4e/5x5', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_4e_5x5_pad)
    inception_4e_pool = MaxPooling2D(pool_size=(3,3), strides=(1,1), padding='same', name='inception_4e/pool')(inception_4d_output)
    inception_4e_pool_proj = Conv2D(128, (1,1), padding='same', activation='relu', name='inception_4e/pool_proj', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_4e_pool)
    inception_4e_output = Concatenate(axis=-1, name='inception_4e/output')([inception_4e_1x1,inception_4e_3x3,inception_4e_5x5,inception_4e_pool_proj])

    pool4_3x3_s2 = MaxPooling2D(pool_size=(3,3), strides=(2,2), padding='same', name='pool4/3x3_s2')(inception_4e_output)

    inception_5a_1x1 = Conv2D(256, (1,1), padding='same', activation='relu', name='inception_5a/1x1', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(pool4_3x3_s2)
    inception_5a_3x3_reduce = Conv2D(160, (1,1), padding='same', activation='relu', name='inception_5a/3x3_reduce', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(pool4_3x3_s2)
    inception_5a_3x3_pad = ZeroPadding2D(padding=(1, 1))(inception_5a_3x3_reduce)
    inception_5a_3x3 = Conv2D(320, (3,3), padding='valid', activation='relu', name='inception_5a/3x3', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_5a_3x3_pad)
    inception_5a_5x5_reduce = Conv2D(32, (1,1), padding='same', activation='relu', name='inception_5a/5x5_reduce', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(pool4_3x3_s2)
    inception_5a_5x5_pad = ZeroPadding2D(padding=(2, 2))(inception_5a_5x5_reduce)
    inception_5a_5x5 = Conv2D(128, (5,5), padding='valid', activation='relu', name='inception_5a/5x5', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_5a_5x5_pad)
    inception_5a_pool = MaxPooling2D(pool_size=(3,3), strides=(1,1), padding='same', name='inception_5a/pool')(pool4_3x3_s2)
    inception_5a_pool_proj = Conv2D(128, (1,1), padding='same', activation='relu', name='inception_5a/pool_proj', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_5a_pool)
    inception_5a_output = Concatenate(axis=-1, name='inception_5a/output')([inception_5a_1x1,inception_5a_3x3,inception_5a_5x5,inception_5a_pool_proj])

    inception_5b_1x1 = Conv2D(384, (1,1), padding='same', activation='relu', name='inception_5b/1x1', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_5a_output)
    inception_5b_3x3_reduce = Conv2D(192, (1,1), padding='same', activation='relu', name='inception_5b/3x3_reduce', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_5a_output)
    inception_5b_3x3_pad = ZeroPadding2D(padding=(1, 1))(inception_5b_3x3_reduce)
    inception_5b_3x3 = Conv2D(384, (3,3), padding='valid', activation='relu', name='inception_5b/3x3', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_5b_3x3_pad)
    inception_5b_5x5_reduce = Conv2D(48, (1,1), padding='same', activation='relu', name='inception_5b/5x5_reduce', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_5a_output)
    inception_5b_5x5_pad = ZeroPadding2D(padding=(2, 2))(inception_5b_5x5_reduce)
    inception_5b_5x5 = Conv2D(128, (5,5), padding='valid', activation='relu', name='inception_5b/5x5', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_5b_5x5_pad)
    inception_5b_pool = MaxPooling2D(pool_size=(3,3), strides=(1,1), padding='same', name='inception_5b/pool')(inception_5a_output)
    inception_5b_pool_proj = Conv2D(128, (1,1), padding='same', activation='relu', name='inception_5b/pool_proj', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(inception_5b_pool)
    inception_5b_output = Concatenate(axis=-1, name='inception_5b/output')([inception_5b_1x1,inception_5b_3x3,inception_5b_5x5,inception_5b_pool_proj])

    pool5_7x7_s1 = AveragePooling2D(pool_size=(7,7), strides=(1,1), name='pool5/7x7_s2')(inception_5b_output)

    loss3_flat = Flatten()(pool5_7x7_s1)
    pool5_drop_7x7_s1 = Dropout(rate=0.4)(loss3_flat)
    loss3_classifier = Dense(classes, activation='softmax', kernel_regularizer=l2(weight_decay), name='loss3/classifier')(pool5_drop_7x7_s1)

    googlenet = Model(inputs=input, outputs=[loss1_classifier,loss2_classifier,loss3_classifier],name=name)

    if weights_path:
        googlenet.load_weights(weights_path)

    return googlenet

# %%
model = googlenet(input_shape=input_sizes, classes=classes, name='GoogleNet')

# %%
# auxiliary classifier 2개를 포함하기 때문에, 모수의 개수는 1000만개쯤 된다.
# 메인은 670만개 가량의 모수.
model.summary()
# Out:
# Model: "GoogleNet"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# conv1/7x7_s2 (Conv2D)           (None, 112, 112, 64) 9472        input_1[0][0]
# __________________________________________________________________________________________________
# pool1/3x3_s2 (MaxPooling2D)     (None, 56, 56, 64)   0           conv1/7x7_s2[0][0]
# __________________________________________________________________________________________________
# pool1/norm1 (LRN)               (None, 56, 56, 64)   0           pool1/3x3_s2[0][0]
# __________________________________________________________________________________________________
# conv2/3x3_reduce (Conv2D)       (None, 56, 56, 64)   4160        pool1/norm1[0][0]
# __________________________________________________________________________________________________
# conv2/3x3 (Conv2D)              (None, 56, 56, 192)  110784      conv2/3x3_reduce[0][0]
# __________________________________________________________________________________________________
# conv2/norm2 (LRN)               (None, 56, 56, 192)  0           conv2/3x3[0][0]
# __________________________________________________________________________________________________
# pool2/3x3_s2 (MaxPooling2D)     (None, 28, 28, 192)  0           conv2/norm2[0][0]
# __________________________________________________________________________________________________
# inception_3a/3x3_reduce (Conv2D (None, 28, 28, 96)   18528       pool2/3x3_s2[0][0]
# __________________________________________________________________________________________________
# inception_3a/5x5_reduce (Conv2D (None, 28, 28, 16)   3088        pool2/3x3_s2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d (ZeroPadding2D)  (None, 30, 30, 96)   0           inception_3a/3x3_reduce[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_1 (ZeroPadding2D (None, 32, 32, 16)   0           inception_3a/5x5_reduce[0][0]
# __________________________________________________________________________________________________
# inception_3a/pool (MaxPooling2D (None, 28, 28, 192)  0           pool2/3x3_s2[0][0]
# __________________________________________________________________________________________________
# inception_3a/1x1 (Conv2D)       (None, 28, 28, 64)   12352       pool2/3x3_s2[0][0]
# __________________________________________________________________________________________________
# inception_3a/3x3 (Conv2D)       (None, 28, 28, 128)  110720      zero_padding2d[0][0]
# __________________________________________________________________________________________________
# inception_3a/5x5 (Conv2D)       (None, 28, 28, 32)   12832       zero_padding2d_1[0][0]
# __________________________________________________________________________________________________
# inception_3a/pool_proj (Conv2D) (None, 28, 28, 32)   6176        inception_3a/pool[0][0]
# __________________________________________________________________________________________________
# inception_3a/output (Concatenat (None, 28, 28, 256)  0           inception_3a/1x1[0][0]
#                                                                  inception_3a/3x3[0][0]
#                                                                  inception_3a/5x5[0][0]
#                                                                  inception_3a/pool_proj[0][0]
# __________________________________________________________________________________________________
# inception_3b/3x3_reduce (Conv2D (None, 28, 28, 128)  32896       inception_3a/output[0][0]
# __________________________________________________________________________________________________
# inception_3b/5x5_reduce (Conv2D (None, 28, 28, 32)   8224        inception_3a/output[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_2 (ZeroPadding2D (None, 30, 30, 128)  0           inception_3b/3x3_reduce[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_3 (ZeroPadding2D (None, 32, 32, 32)   0           inception_3b/5x5_reduce[0][0]
# __________________________________________________________________________________________________
# inception_3b/pool (MaxPooling2D (None, 28, 28, 256)  0           inception_3a/output[0][0]
# __________________________________________________________________________________________________
# inception_3b/1x1 (Conv2D)       (None, 28, 28, 128)  32896       inception_3a/output[0][0]
# __________________________________________________________________________________________________
# inception_3b/3x3 (Conv2D)       (None, 28, 28, 192)  221376      zero_padding2d_2[0][0]
# __________________________________________________________________________________________________
# inception_3b/5x5 (Conv2D)       (None, 28, 28, 96)   76896       zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# inception_3b/pool_proj (Conv2D) (None, 28, 28, 64)   16448       inception_3b/pool[0][0]
# __________________________________________________________________________________________________
# inception_3b/output (Concatenat (None, 28, 28, 480)  0           inception_3b/1x1[0][0]
#                                                                  inception_3b/3x3[0][0]
#                                                                  inception_3b/5x5[0][0]
#                                                                  inception_3b/pool_proj[0][0]
# __________________________________________________________________________________________________
# pool3/3x3_s2 (MaxPooling2D)     (None, 14, 14, 480)  0           inception_3b/output[0][0]
# __________________________________________________________________________________________________
# inception_4a/3x3_reduce (Conv2D (None, 14, 14, 96)   46176       pool3/3x3_s2[0][0]
# __________________________________________________________________________________________________
# inception_4a/5x5_reduce (Conv2D (None, 14, 14, 16)   7696        pool3/3x3_s2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_4 (ZeroPadding2D (None, 16, 16, 96)   0           inception_4a/3x3_reduce[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_5 (ZeroPadding2D (None, 18, 18, 16)   0           inception_4a/5x5_reduce[0][0]
# __________________________________________________________________________________________________
# inception_4a/pool (MaxPooling2D (None, 14, 14, 480)  0           pool3/3x3_s2[0][0]
# __________________________________________________________________________________________________
# inception_4a/1x1 (Conv2D)       (None, 14, 14, 192)  92352       pool3/3x3_s2[0][0]
# __________________________________________________________________________________________________
# inception_4a/3x3 (Conv2D)       (None, 14, 14, 208)  179920      zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# inception_4a/5x5 (Conv2D)       (None, 14, 14, 48)   19248       zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# inception_4a/pool_proj (Conv2D) (None, 14, 14, 64)   30784       inception_4a/pool[0][0]
# __________________________________________________________________________________________________
# inception_4a/output (Concatenat (None, 14, 14, 512)  0           inception_4a/1x1[0][0]
#                                                                  inception_4a/3x3[0][0]
#                                                                  inception_4a/5x5[0][0]
#                                                                  inception_4a/pool_proj[0][0]
# __________________________________________________________________________________________________
# inception_4b/3x3_reduce (Conv2D (None, 14, 14, 112)  57456       inception_4a/output[0][0]
# __________________________________________________________________________________________________
# inception_4b/5x5_reduce (Conv2D (None, 14, 14, 24)   12312       inception_4a/output[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_6 (ZeroPadding2D (None, 16, 16, 112)  0           inception_4b/3x3_reduce[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_7 (ZeroPadding2D (None, 18, 18, 24)   0           inception_4b/5x5_reduce[0][0]
# __________________________________________________________________________________________________
# inception_4b/pool (MaxPooling2D (None, 14, 14, 512)  0           inception_4a/output[0][0]
# __________________________________________________________________________________________________
# inception_4b/1x1 (Conv2D)       (None, 14, 14, 160)  82080       inception_4a/output[0][0]
# __________________________________________________________________________________________________
# inception_4b/3x3 (Conv2D)       (None, 14, 14, 224)  226016      zero_padding2d_6[0][0]
# __________________________________________________________________________________________________
# inception_4b/5x5 (Conv2D)       (None, 14, 14, 64)   38464       zero_padding2d_7[0][0]
# __________________________________________________________________________________________________
# inception_4b/pool_proj (Conv2D) (None, 14, 14, 64)   32832       inception_4b/pool[0][0]
# __________________________________________________________________________________________________
# inception_4b/output (Concatenat (None, 14, 14, 512)  0           inception_4b/1x1[0][0]
#                                                                  inception_4b/3x3[0][0]
#                                                                  inception_4b/5x5[0][0]
#                                                                  inception_4b/pool_proj[0][0]
# __________________________________________________________________________________________________
# inception_4c/3x3_reduce (Conv2D (None, 14, 14, 128)  65664       inception_4b/output[0][0]
# __________________________________________________________________________________________________
# inception_4c/5x5_reduce (Conv2D (None, 14, 14, 24)   12312       inception_4b/output[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_8 (ZeroPadding2D (None, 16, 16, 128)  0           inception_4c/3x3_reduce[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_9 (ZeroPadding2D (None, 18, 18, 24)   0           inception_4c/5x5_reduce[0][0]
# __________________________________________________________________________________________________
# inception_4c/pool (MaxPooling2D (None, 14, 14, 512)  0           inception_4b/output[0][0]
# __________________________________________________________________________________________________
# inception_4c/1x1 (Conv2D)       (None, 14, 14, 128)  65664       inception_4b/output[0][0]
# __________________________________________________________________________________________________
# inception_4c/3x3 (Conv2D)       (None, 14, 14, 256)  295168      zero_padding2d_8[0][0]
# __________________________________________________________________________________________________
# inception_4c/5x5 (Conv2D)       (None, 14, 14, 64)   38464       zero_padding2d_9[0][0]
# __________________________________________________________________________________________________
# inception_4c/pool_proj (Conv2D) (None, 14, 14, 64)   32832       inception_4c/pool[0][0]
# __________________________________________________________________________________________________
# inception_4c/output (Concatenat (None, 14, 14, 512)  0           inception_4c/1x1[0][0]
#                                                                  inception_4c/3x3[0][0]
#                                                                  inception_4c/5x5[0][0]
#                                                                  inception_4c/pool_proj[0][0]
# __________________________________________________________________________________________________
# inception_4d/3x3_reduce (Conv2D (None, 14, 14, 144)  73872       inception_4c/output[0][0]
# __________________________________________________________________________________________________
# inception_4d/5x5_reduce (Conv2D (None, 14, 14, 32)   16416       inception_4c/output[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_10 (ZeroPadding2 (None, 16, 16, 144)  0           inception_4d/3x3_reduce[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_11 (ZeroPadding2 (None, 18, 18, 32)   0           inception_4d/5x5_reduce[0][0]
# __________________________________________________________________________________________________
# inception_4d/pool (MaxPooling2D (None, 14, 14, 512)  0           inception_4c/output[0][0]
# __________________________________________________________________________________________________
# inception_4d/1x1 (Conv2D)       (None, 14, 14, 112)  57456       inception_4c/output[0][0]
# __________________________________________________________________________________________________
# inception_4d/3x3 (Conv2D)       (None, 14, 14, 288)  373536      zero_padding2d_10[0][0]
# __________________________________________________________________________________________________
# inception_4d/5x5 (Conv2D)       (None, 14, 14, 64)   51264       zero_padding2d_11[0][0]
# __________________________________________________________________________________________________
# inception_4d/pool_proj (Conv2D) (None, 14, 14, 64)   32832       inception_4d/pool[0][0]
# __________________________________________________________________________________________________
# inception_4d/output (Concatenat (None, 14, 14, 528)  0           inception_4d/1x1[0][0]
#                                                                  inception_4d/3x3[0][0]
#                                                                  inception_4d/5x5[0][0]
#                                                                  inception_4d/pool_proj[0][0]
# __________________________________________________________________________________________________
# inception_4e/3x3_reduce (Conv2D (None, 14, 14, 160)  84640       inception_4d/output[0][0]
# __________________________________________________________________________________________________
# inception_4e/5x5_reduce (Conv2D (None, 14, 14, 32)   16928       inception_4d/output[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_12 (ZeroPadding2 (None, 16, 16, 160)  0           inception_4e/3x3_reduce[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_13 (ZeroPadding2 (None, 18, 18, 32)   0           inception_4e/5x5_reduce[0][0]
# __________________________________________________________________________________________________
# inception_4e/pool (MaxPooling2D (None, 14, 14, 528)  0           inception_4d/output[0][0]
# __________________________________________________________________________________________________
# inception_4e/1x1 (Conv2D)       (None, 14, 14, 256)  135424      inception_4d/output[0][0]
# __________________________________________________________________________________________________
# inception_4e/3x3 (Conv2D)       (None, 14, 14, 320)  461120      zero_padding2d_12[0][0]
# __________________________________________________________________________________________________
# inception_4e/5x5 (Conv2D)       (None, 14, 14, 128)  102528      zero_padding2d_13[0][0]
# __________________________________________________________________________________________________
# inception_4e/pool_proj (Conv2D) (None, 14, 14, 128)  67712       inception_4e/pool[0][0]
# __________________________________________________________________________________________________
# inception_4e/output (Concatenat (None, 14, 14, 832)  0           inception_4e/1x1[0][0]
#                                                                  inception_4e/3x3[0][0]
#                                                                  inception_4e/5x5[0][0]
#                                                                  inception_4e/pool_proj[0][0]
# __________________________________________________________________________________________________
# pool4/3x3_s2 (MaxPooling2D)     (None, 7, 7, 832)    0           inception_4e/output[0][0]
# __________________________________________________________________________________________________
# inception_5a/3x3_reduce (Conv2D (None, 7, 7, 160)    133280      pool4/3x3_s2[0][0]
# __________________________________________________________________________________________________
# inception_5a/5x5_reduce (Conv2D (None, 7, 7, 32)     26656       pool4/3x3_s2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_14 (ZeroPadding2 (None, 9, 9, 160)    0           inception_5a/3x3_reduce[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_15 (ZeroPadding2 (None, 11, 11, 32)   0           inception_5a/5x5_reduce[0][0]
# __________________________________________________________________________________________________
# inception_5a/pool (MaxPooling2D (None, 7, 7, 832)    0           pool4/3x3_s2[0][0]
# __________________________________________________________________________________________________
# inception_5a/1x1 (Conv2D)       (None, 7, 7, 256)    213248      pool4/3x3_s2[0][0]
# __________________________________________________________________________________________________
# inception_5a/3x3 (Conv2D)       (None, 7, 7, 320)    461120      zero_padding2d_14[0][0]
# __________________________________________________________________________________________________
# inception_5a/5x5 (Conv2D)       (None, 7, 7, 128)    102528      zero_padding2d_15[0][0]
# __________________________________________________________________________________________________
# inception_5a/pool_proj (Conv2D) (None, 7, 7, 128)    106624      inception_5a/pool[0][0]
# __________________________________________________________________________________________________
# inception_5a/output (Concatenat (None, 7, 7, 832)    0           inception_5a/1x1[0][0]
#                                                                  inception_5a/3x3[0][0]
#                                                                  inception_5a/5x5[0][0]
#                                                                  inception_5a/pool_proj[0][0]
# __________________________________________________________________________________________________
# inception_5b/3x3_reduce (Conv2D (None, 7, 7, 192)    159936      inception_5a/output[0][0]
# __________________________________________________________________________________________________
# inception_5b/5x5_reduce (Conv2D (None, 7, 7, 48)     39984       inception_5a/output[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_16 (ZeroPadding2 (None, 9, 9, 192)    0           inception_5b/3x3_reduce[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_17 (ZeroPadding2 (None, 11, 11, 48)   0           inception_5b/5x5_reduce[0][0]
# __________________________________________________________________________________________________
# inception_5b/pool (MaxPooling2D (None, 7, 7, 832)    0           inception_5a/output[0][0]
# __________________________________________________________________________________________________
# loss1/ave_pool (AveragePooling2 (None, 4, 4, 512)    0           inception_4a/output[0][0]
# __________________________________________________________________________________________________
# loss2/ave_pool (AveragePooling2 (None, 4, 4, 528)    0           inception_4d/output[0][0]
# __________________________________________________________________________________________________
# inception_5b/1x1 (Conv2D)       (None, 7, 7, 384)    319872      inception_5a/output[0][0]
# __________________________________________________________________________________________________
# inception_5b/3x3 (Conv2D)       (None, 7, 7, 384)    663936      zero_padding2d_16[0][0]
# __________________________________________________________________________________________________
# inception_5b/5x5 (Conv2D)       (None, 7, 7, 128)    153728      zero_padding2d_17[0][0]
# __________________________________________________________________________________________________
# inception_5b/pool_proj (Conv2D) (None, 7, 7, 128)    106624      inception_5b/pool[0][0]
# __________________________________________________________________________________________________
# loss1/conv (Conv2D)             (None, 4, 4, 128)    65664       loss1/ave_pool[0][0]
# __________________________________________________________________________________________________
# loss2/conv (Conv2D)             (None, 4, 4, 128)    67712       loss2/ave_pool[0][0]
# __________________________________________________________________________________________________
# inception_5b/output (Concatenat (None, 7, 7, 1024)   0           inception_5b/1x1[0][0]
#                                                                  inception_5b/3x3[0][0]
#                                                                  inception_5b/5x5[0][0]
#                                                                  inception_5b/pool_proj[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 2048)         0           loss1/conv[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 2048)         0           loss2/conv[0][0]
# __________________________________________________________________________________________________
# pool5/7x7_s2 (AveragePooling2D) (None, 1, 1, 1024)   0           inception_5b/output[0][0]
# __________________________________________________________________________________________________
# loss1/fc (Dense)                (None, 1024)         2098176     flatten[0][0]
# __________________________________________________________________________________________________
# loss2/fc (Dense)                (None, 1024)         2098176     flatten_1[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 1024)         0           pool5/7x7_s2[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 1024)         0           loss1/fc[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 1024)         0           loss2/fc[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 1024)         0           flatten_2[0][0]
# __________________________________________________________________________________________________
# loss1/classifier (Dense)        (None, 7)            7175        dropout[0][0]
# __________________________________________________________________________________________________
# loss2/classifier (Dense)        (None, 7)            7175        dropout_1[0][0]
# __________________________________________________________________________________________________
# loss3/classifier (Dense)        (None, 7)            7175        dropout_2[0][0]
# ==================================================================================================
# Total params: 10,324,805
# Trainable params: 10,324,805
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# 폴더 생성

os.makedirs(os.path.join(dir,'model_output',number,model.name), exist_ok=True)
os.makedirs(os.path.join(dir,'train_valid_output',number), exist_ok=True)

# %%
# 참고 : https://github.com/OverLordGoldDragon/keras-adamw

import sys
sys.path.append('/content/drive/My Drive/Colab Notebooks/Paper')
import utils
import optimizers_v2
from utils import get_weight_decays, fill_dict_in_order
from utils import reset_seeds, K_eval
from optimizers_v2 import AdamW, NadamW, SGDW

# %%
# top-5 accuracy 출력
import functools
top5_acc = functools.partial(ks.metrics.top_k_categorical_accuracy, k=5)
top5_acc.__name__ = 'top5_acc'

# %%
#optimizer = SGDW(model=model, use_cosine_annealing=False, total_iterations = len(x_train) // batch_sizes, nesterov=True, momentum=0.9)
optimizer = AdamW(model=model, use_cosine_annealing=False, total_iterations = len(x_train) // batch_sizes)
#optimizer = Adam()
filepath =  os.path.join(dir,'model_output',number,model.name,'{epoch:03d}.h5')

callbacks_list = [ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_weights_only=False, save_best_only=True, mode='min'),
                  ModelCheckpoint(filepath, monitor='val_loss3/classifier_accuracy', verbose=1, save_weights_only=False, save_best_only=True, mode='max'),
                  #ReduceLROnPlateau(monitor='val_loss',patience=3,factor=0.1,min_lr=1e-5),
                  LearningRateScheduler(lr_schedule,verbose=1)
                  ]                    	

model.compile(optimizer, loss={'loss1/classifier' : 'categorical_crossentropy', 'loss2/classifier' : 'categorical_crossentropy', 'loss3/classifier' : 'categorical_crossentropy'},
              loss_weights={'loss1/classifier' : 0.3, 'loss2/classifier' : 0.3, 'loss3/classifier' : 1.0}, 
              metrics=['accuracy',top5_acc,macro_f1score])

# %%
######## flow_from_directory
#history = model.fit_generator(generate_train_for_three(), steps_per_epoch=int(len(x_train)/batch_sizes),  validation_data = generate_valid_for_three(), epochs=epochs , verbose=1 , callbacks = callbacks_list,validation_steps=int(len(x_valid)/batch_sizes))
history = model.fit(generate_train_for_three(), steps_per_epoch=int(len(x_train)/batch_sizes),  validation_data = generate_valid_for_three(), epochs=epochs , verbose=1 , callbacks = callbacks_list , validation_steps=int(len(x_valid)/batch_sizes))
# Out:
# Found 28698 images belonging to 7 classes.
# Learning rate:  0.0003
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 1/70
# 0.0(L1), 6.681530879020939e-06(L2) weight decay set for conv1/7x7_s2/kernel:0
# 0.0(L1), 6.681530879020939e-06(L2) weight decay set for conv2/3x3_reduce/kernel:0
# 0.0(L1), 6.681530879020939e-06(L2) weight decay set for conv2/3x3/kernel:0
# 0.0(L1), 6.681530879020939e-06(L2) weight decay set for inception_3a/3x3_reduce/kernel:0
# 0.0(L1), 6.681530879020939e-06(L2) weight decay set for inception_3a/5x5_reduce/kernel:0
# 0.0(L1), 6.681530879020939e-06(L2) weight decay set for inception_3a/1x1/kernel:0
# 0.0(L1), 6.681530879020939e-06(L2) weight decay set for inception_3a/3x3/kernel:0
# 0.0(L1), 6.681530879020939e-06(L2) weight decay set for inception_3a/5x5/kernel:0
# 0.0(L1), 6.681530879020939e-06(L2) weight decay set for inception_3a/pool_proj/kernel:0
# 0.0(L1), 6.681530879020939e-06(L2) weight decay set for inception_3b/3x3_reduce/kernel:0
# 0.0(L1), 6.681530879020939e-06(L2) weight decay set for inception_3b/5x5_reduce/kernel:0
# 0.0(L1), 6.681530879020939e-06(L2) weight decay set for inception_3b/1x1/kernel:0
# 0.0(L1), 6.681530879020939e-06(L2) weight decay set for inception_3b/3x3/kernel:0
# 0.0(L1), 6.681530879020939e-06(L2) weight decay set for inception_3b/5x5/kernel:0
# 0.0(L1), 6.681530879020939e-06(L2) weight decay set for inception_3b/pool_proj/kernel:0
# 0.0(L1), 6.681530879020939e-06(L2) weight decay set for inception_4a/3x3_reduce/kernel:0
# 0.0(L1), 6.681530879020939e-06(L2) weight decay set for inception_4a/5x5_reduce/kernel:0
# 0.0(L1), 6.681530879020939e-06(L2) weight decay set for inception_4a/1x1/kernel:0
# 0.0(L1), 6.681530879020939e-06(L2) weight decay set for inception_4a/3x3/kernel:0
# 0.0(L1), 6.681530879020939e-06(L2) weight decay set for inception_4a/5x5/kernel:0
# 0.0(L1), 6.681530879020939e-06(L2) weight decay set for inception_4a/pool_proj/kernel:0
# 0.0(L1), 6.681530879020939e-06(L2) weight decay set for inception_4b/3x3_reduce/kernel:0
# 0.0(L1), 6.681530879020939e-06(L2) weight decay set for inception_4b/5x5_reduce/kernel:0
# 0.0(L1), 6.681530879020939e-06(L2) weight decay set for inception_4b/1x1/kernel:0
# 0.0(L1), 6.681530879020939e-06(L2) weight decay set for inception_4b/3x3/kernel:0
# 0.0(L1), 6.681530879020939e-06(L2) weight decay set for inception_4b/5x5/kernel:0
# 0.0(L1), 6.681530879020939e-06(L2) weight decay set for inception_4b/pool_proj/kernel:0
# 0.0(L1), 6.681530879020939e-06(L2) weight decay set for inception_4c/3x3_reduce/kernel:0
# 0.0(L1), 6.681530879020939e-06(L2) weight decay set for inception_4c/5x5_reduce/kernel:0
# 0.0(L1), 6.681530879020939e-06(L2) weight decay set for inception_4c/1x1/kernel:0
# 0.0(L1), 6.681530879020939e-06(L2) weight decay set for inception_4c/3x3/kernel:0
# 0.0(L1), 6.681530879020939e-06(L2) weight decay set for inception_4c/5x5/kernel:0
# 0.0(L1), 6.681530879020939e-06(L2) weight decay set for inception_4c/pool_proj/kernel:0
# 0.0(L1), 6.681530879020939e-06(L2) weight decay set for inception_4d/3x3_reduce/kernel:0
# 0.0(L1), 6.681530879020939e-06(L2) weight decay set for inception_4d/5x5_reduce/kernel:0
# 0.0(L1), 6.681530879020939e-06(L2) weight decay set for inception_4d/1x1/kernel:0
# 0.0(L1), 6.681530879020939e-06(L2) weight decay set for inception_4d/3x3/kernel:0
# 0.0(L1), 6.681530879020939e-06(L2) weight decay set for inception_4d/5x5/kernel:0
# 0.0(L1), 6.681530879020939e-06(L2) weight decay set for inception_4d/pool_proj/kernel:0
# 0.0(L1), 6.681530879020939e-06(L2) weight decay set for inception_4e/3x3_reduce/kernel:0
# 0.0(L1), 6.681530879020939e-06(L2) weight decay set for inception_4e/5x5_reduce/kernel:0
# 0.0(L1), 6.681530879020939e-06(L2) weight decay set for inception_4e/1x1/kernel:0
# 0.0(L1), 6.681530879020939e-06(L2) weight decay set for inception_4e/3x3/kernel:0
# 0.0(L1), 6.681530879020939e-06(L2) weight decay set for inception_4e/5x5/kernel:0
# 0.0(L1), 6.681530879020939e-06(L2) weight decay set for inception_4e/pool_proj/kernel:0
# 0.0(L1), 6.681530879020939e-06(L2) weight decay set for inception_5a/3x3_reduce/kernel:0
# 0.0(L1), 6.681530879020939e-06(L2) weight decay set for inception_5a/5x5_reduce/kernel:0
# 0.0(L1), 6.681530879020939e-06(L2) weight decay set for inception_5a/1x1/kernel:0
# 0.0(L1), 6.681530879020939e-06(L2) weight decay set for inception_5a/3x3/kernel:0
# 0.0(L1), 6.681530879020939e-06(L2) weight decay set for inception_5a/5x5/kernel:0
# 0.0(L1), 6.681530879020939e-06(L2) weight decay set for inception_5a/pool_proj/kernel:0
# 0.0(L1), 6.681530879020939e-06(L2) weight decay set for inception_5b/3x3_reduce/kernel:0
# 0.0(L1), 6.681530879020939e-06(L2) weight decay set for inception_5b/5x5_reduce/kernel:0
# 0.0(L1), 6.681530879020939e-06(L2) weight decay set for inception_5b/1x1/kernel:0
# 0.0(L1), 6.681530879020939e-06(L2) weight decay set for inception_5b/3x3/kernel:0
# 0.0(L1), 6.681530879020939e-06(L2) weight decay set for inception_5b/5x5/kernel:0
# 0.0(L1), 6.681530879020939e-06(L2) weight decay set for inception_5b/pool_proj/kernel:0
# 0.0(L1), 6.681530879020939e-06(L2) weight decay set for loss1/conv/kernel:0
# 0.0(L1), 6.681530879020939e-06(L2) weight decay set for loss2/conv/kernel:0
# 0.0(L1), 6.681530879020939e-06(L2) weight decay set for loss1/fc/kernel:0
# 0.0(L1), 6.681530879020939e-06(L2) weight decay set for loss2/fc/kernel:0
# 0.0(L1), 6.681530879020939e-06(L2) weight decay set for loss1/classifier/kernel:0
# 0.0(L1), 6.681530879020939e-06(L2) weight decay set for loss2/classifier/kernel:0
# 0.0(L1), 6.681530879020939e-06(L2) weight decay set for loss3/classifier/kernel:0
# 224/224 [==============================] - ETA: 0s - loss: 2.8723 - loss1/classifier_loss: 1.7799 - loss2/classifier_loss: 1.7922 - loss3/classifier_loss: 1.8007 - loss1/classifier_accuracy: 0.2671 - loss1/classifier_top5_acc: 0.9000 - loss1/classifier_macro_f1score: 0.0040 - loss2/classifier_accuracy: 0.2548 - loss2/classifier_top5_acc: 0.8948 - loss2/classifier_macro_f1score: 0.0033 - loss3/classifier_accuracy: 0.2504 - loss3/classifier_top5_acc: 0.8897 - loss3/classifier_macro_f1score: 8.3257e-04  Found 3589 images belonging to 7 classes.
#
# Epoch 00001: val_loss improved from inf to 2.78819, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/GoogleNet/001.h5
#
# Epoch 00001: val_loss3/classifier_accuracy improved from -inf to 0.26200, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/GoogleNet/001.h5
# 224/224 [==============================] - 15948s 71s/step - loss: 2.8723 - loss1/classifier_loss: 1.7799 - loss2/classifier_loss: 1.7922 - loss3/classifier_loss: 1.8007 - loss1/classifier_accuracy: 0.2671 - loss1/classifier_top5_acc: 0.9000 - loss1/classifier_macro_f1score: 0.0040 - loss2/classifier_accuracy: 0.2548 - loss2/classifier_top5_acc: 0.8948 - loss2/classifier_macro_f1score: 0.0033 - loss3/classifier_accuracy: 0.2504 - loss3/classifier_top5_acc: 0.8897 - loss3/classifier_macro_f1score: 8.3257e-04 - val_loss: 2.7882 - val_loss1/classifier_loss: 1.6788 - val_loss2/classifier_loss: 1.7136 - val_loss3/classifier_loss: 1.7705 - val_loss1/classifier_accuracy: 0.3276 - val_loss1/classifier_top5_acc: 0.9289 - val_loss1/classifier_macro_f1score: 0.0351 - val_loss2/classifier_accuracy: 0.2999 - val_loss2/classifier_top5_acc: 0.9196 - val_loss2/classifier_macro_f1score: 0.0186 - val_loss3/classifier_accuracy: 0.2620 - val_loss3/classifier_top5_acc: 0.9060 - val_loss3/classifier_macro_f1score: 0.0000e+00
# Learning rate:  0.0003
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 2/70
# 224/224 [==============================] - ETA: 0s - loss: 2.7135 - loss1/classifier_loss: 1.6558 - loss2/classifier_loss: 1.6719 - loss3/classifier_loss: 1.7152 - loss1/classifier_accuracy: 0.3360 - loss1/classifier_top5_acc: 0.9357 - loss1/classifier_macro_f1score: 0.0713 - loss2/classifier_accuracy: 0.3233 - loss2/classifier_top5_acc: 0.9348 - loss2/classifier_macro_f1score: 0.0667 - loss3/classifier_accuracy: 0.2946 - loss3/classifier_top5_acc: 0.9274 - loss3/classifier_macro_f1score: 0.0436
# Epoch 00002: val_loss improved from 2.78819 to 2.60617, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/GoogleNet/002.h5
#
# Epoch 00002: val_loss3/classifier_accuracy improved from 0.26200 to 0.34291, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/GoogleNet/002.h5
# 224/224 [==============================] - 442s 2s/step - loss: 2.7135 - loss1/classifier_loss: 1.6558 - loss2/classifier_loss: 1.6719 - loss3/classifier_loss: 1.7152 - loss1/classifier_accuracy: 0.3360 - loss1/classifier_top5_acc: 0.9357 - loss1/classifier_macro_f1score: 0.0713 - loss2/classifier_accuracy: 0.3233 - loss2/classifier_top5_acc: 0.9348 - loss2/classifier_macro_f1score: 0.0667 - loss3/classifier_accuracy: 0.2946 - loss3/classifier_top5_acc: 0.9274 - loss3/classifier_macro_f1score: 0.0436 - val_loss: 2.6062 - val_loss1/classifier_loss: 1.5991 - val_loss2/classifier_loss: 1.5992 - val_loss3/classifier_loss: 1.6467 - val_loss1/classifier_accuracy: 0.3948 - val_loss1/classifier_top5_acc: 0.9450 - val_loss1/classifier_macro_f1score: 0.0755 - val_loss2/classifier_accuracy: 0.3736 - val_loss2/classifier_top5_acc: 0.9436 - val_loss2/classifier_macro_f1score: 0.0874 - val_loss3/classifier_accuracy: 0.3429 - val_loss3/classifier_top5_acc: 0.9316 - val_loss3/classifier_macro_f1score: 0.0752
# Learning rate:  0.0003
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 3/70
# 224/224 [==============================] - ETA: 0s - loss: 2.3967 - loss1/classifier_loss: 1.5047 - loss2/classifier_loss: 1.4881 - loss3/classifier_loss: 1.4989 - loss1/classifier_accuracy: 0.4165 - loss1/classifier_top5_acc: 0.9515 - loss1/classifier_macro_f1score: 0.1553 - loss2/classifier_accuracy: 0.4191 - loss2/classifier_top5_acc: 0.9547 - loss2/classifier_macro_f1score: 0.1621 - loss3/classifier_accuracy: 0.4096 - loss3/classifier_top5_acc: 0.9523 - loss3/classifier_macro_f1score: 0.1640
# Epoch 00003: val_loss improved from 2.60617 to 2.22183, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/GoogleNet/003.h5
#
# Epoch 00003: val_loss3/classifier_accuracy improved from 0.34291 to 0.45592, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/GoogleNet/003.h5
# 224/224 [==============================] - 445s 2s/step - loss: 2.3967 - loss1/classifier_loss: 1.5047 - loss2/classifier_loss: 1.4881 - loss3/classifier_loss: 1.4989 - loss1/classifier_accuracy: 0.4165 - loss1/classifier_top5_acc: 0.9515 - loss1/classifier_macro_f1score: 0.1553 - loss2/classifier_accuracy: 0.4191 - loss2/classifier_top5_acc: 0.9547 - loss2/classifier_macro_f1score: 0.1621 - loss3/classifier_accuracy: 0.4096 - loss3/classifier_top5_acc: 0.9523 - loss3/classifier_macro_f1score: 0.1640 - val_loss: 2.2218 - val_loss1/classifier_loss: 1.3957 - val_loss2/classifier_loss: 1.3718 - val_loss3/classifier_loss: 1.3916 - val_loss1/classifier_accuracy: 0.4738 - val_loss1/classifier_top5_acc: 0.9579 - val_loss1/classifier_macro_f1score: 0.1888 - val_loss2/classifier_accuracy: 0.4688 - val_loss2/classifier_top5_acc: 0.9623 - val_loss2/classifier_macro_f1score: 0.1998 - val_loss3/classifier_accuracy: 0.4559 - val_loss3/classifier_top5_acc: 0.9581 - val_loss3/classifier_macro_f1score: 0.2065
# Learning rate:  0.0003
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 4/70
# 224/224 [==============================] - ETA: 0s - loss: 2.1749 - loss1/classifier_loss: 1.3951 - loss2/classifier_loss: 1.3595 - loss3/classifier_loss: 1.3485 - loss1/classifier_accuracy: 0.4655 - loss1/classifier_top5_acc: 0.9588 - loss1/classifier_macro_f1score: 0.2052 - loss2/classifier_accuracy: 0.4799 - loss2/classifier_top5_acc: 0.9646 - loss2/classifier_macro_f1score: 0.2232 - loss3/classifier_accuracy: 0.4809 - loss3/classifier_top5_acc: 0.9649 - loss3/classifier_macro_f1score: 0.2258
# Epoch 00004: val_loss improved from 2.22183 to 2.04430, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/GoogleNet/004.h5
#
# Epoch 00004: val_loss3/classifier_accuracy improved from 0.45592 to 0.50391, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/GoogleNet/004.h5
# 224/224 [==============================] - 446s 2s/step - loss: 2.1749 - loss1/classifier_loss: 1.3951 - loss2/classifier_loss: 1.3595 - loss3/classifier_loss: 1.3485 - loss1/classifier_accuracy: 0.4655 - loss1/classifier_top5_acc: 0.9588 - loss1/classifier_macro_f1score: 0.2052 - loss2/classifier_accuracy: 0.4799 - loss2/classifier_top5_acc: 0.9646 - loss2/classifier_macro_f1score: 0.2232 - loss3/classifier_accuracy: 0.4809 - loss3/classifier_top5_acc: 0.9649 - loss3/classifier_macro_f1score: 0.2258 - val_loss: 2.0443 - val_loss1/classifier_loss: 1.3207 - val_loss2/classifier_loss: 1.2670 - val_loss3/classifier_loss: 1.2680 - val_loss1/classifier_accuracy: 0.4902 - val_loss1/classifier_top5_acc: 0.9679 - val_loss1/classifier_macro_f1score: 0.2258 - val_loss2/classifier_accuracy: 0.5162 - val_loss2/classifier_top5_acc: 0.9701 - val_loss2/classifier_macro_f1score: 0.2760 - val_loss3/classifier_accuracy: 0.5039 - val_loss3/classifier_top5_acc: 0.9690 - val_loss3/classifier_macro_f1score: 0.2734
# Learning rate:  0.0003
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 5/70
# 224/224 [==============================] - ETA: 0s - loss: 2.0417 - loss1/classifier_loss: 1.3164 - loss2/classifier_loss: 1.2741 - loss3/classifier_loss: 1.2646 - loss1/classifier_accuracy: 0.4956 - loss1/classifier_top5_acc: 0.9652 - loss1/classifier_macro_f1score: 0.2490 - loss2/classifier_accuracy: 0.5106 - loss2/classifier_top5_acc: 0.9695 - loss2/classifier_macro_f1score: 0.2699 - loss3/classifier_accuracy: 0.5096 - loss3/classifier_top5_acc: 0.9720 - loss3/classifier_macro_f1score: 0.2695
# Epoch 00005: val_loss improved from 2.04430 to 1.97131, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/GoogleNet/005.h5
#
# Epoch 00005: val_loss3/classifier_accuracy improved from 0.50391 to 0.53460, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/GoogleNet/005.h5
# 224/224 [==============================] - 447s 2s/step - loss: 2.0417 - loss1/classifier_loss: 1.3164 - loss2/classifier_loss: 1.2741 - loss3/classifier_loss: 1.2646 - loss1/classifier_accuracy: 0.4956 - loss1/classifier_top5_acc: 0.9652 - loss1/classifier_macro_f1score: 0.2490 - loss2/classifier_accuracy: 0.5106 - loss2/classifier_top5_acc: 0.9695 - loss2/classifier_macro_f1score: 0.2699 - loss3/classifier_accuracy: 0.5096 - loss3/classifier_top5_acc: 0.9720 - loss3/classifier_macro_f1score: 0.2695 - val_loss: 1.9713 - val_loss1/classifier_loss: 1.2689 - val_loss2/classifier_loss: 1.2210 - val_loss3/classifier_loss: 1.2244 - val_loss1/classifier_accuracy: 0.5243 - val_loss1/classifier_top5_acc: 0.9713 - val_loss1/classifier_macro_f1score: 0.3091 - val_loss2/classifier_accuracy: 0.5452 - val_loss2/classifier_top5_acc: 0.9752 - val_loss2/classifier_macro_f1score: 0.3375 - val_loss3/classifier_accuracy: 0.5346 - val_loss3/classifier_top5_acc: 0.9727 - val_loss3/classifier_macro_f1score: 0.3377
# Learning rate:  0.0003
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 6/70
# 224/224 [==============================] - ETA: 0s - loss: 1.9387 - loss1/classifier_loss: 1.2658 - loss2/classifier_loss: 1.2153 - loss3/classifier_loss: 1.1944 - loss1/classifier_accuracy: 0.5142 - loss1/classifier_top5_acc: 0.9699 - loss1/classifier_macro_f1score: 0.2790 - loss2/classifier_accuracy: 0.5382 - loss2/classifier_top5_acc: 0.9745 - loss2/classifier_macro_f1score: 0.3066 - loss3/classifier_accuracy: 0.5410 - loss3/classifier_top5_acc: 0.9767 - loss3/classifier_macro_f1score: 0.3119
# Epoch 00006: val_loss improved from 1.97131 to 1.89227, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/GoogleNet/006.h5
#
# Epoch 00006: val_loss3/classifier_accuracy improved from 0.53460 to 0.54576, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/GoogleNet/006.h5
# 224/224 [==============================] - 447s 2s/step - loss: 1.9387 - loss1/classifier_loss: 1.2658 - loss2/classifier_loss: 1.2153 - loss3/classifier_loss: 1.1944 - loss1/classifier_accuracy: 0.5142 - loss1/classifier_top5_acc: 0.9699 - loss1/classifier_macro_f1score: 0.2790 - loss2/classifier_accuracy: 0.5382 - loss2/classifier_top5_acc: 0.9745 - loss2/classifier_macro_f1score: 0.3066 - loss3/classifier_accuracy: 0.5410 - loss3/classifier_top5_acc: 0.9767 - loss3/classifier_macro_f1score: 0.3119 - val_loss: 1.8923 - val_loss1/classifier_loss: 1.2220 - val_loss2/classifier_loss: 1.1689 - val_loss3/classifier_loss: 1.1750 - val_loss1/classifier_accuracy: 0.5346 - val_loss1/classifier_top5_acc: 0.9754 - val_loss1/classifier_macro_f1score: 0.3162 - val_loss2/classifier_accuracy: 0.5511 - val_loss2/classifier_top5_acc: 0.9785 - val_loss2/classifier_macro_f1score: 0.3426 - val_loss3/classifier_accuracy: 0.5458 - val_loss3/classifier_top5_acc: 0.9794 - val_loss3/classifier_macro_f1score: 0.3285
# Learning rate:  0.0003
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 7/70
# 224/224 [==============================] - ETA: 0s - loss: 1.8718 - loss1/classifier_loss: 1.2213 - loss2/classifier_loss: 1.1695 - loss3/classifier_loss: 1.1546 - loss1/classifier_accuracy: 0.5319 - loss1/classifier_top5_acc: 0.9735 - loss1/classifier_macro_f1score: 0.3067 - loss2/classifier_accuracy: 0.5538 - loss2/classifier_top5_acc: 0.9782 - loss2/classifier_macro_f1score: 0.3317 - loss3/classifier_accuracy: 0.5571 - loss3/classifier_top5_acc: 0.9792 - loss3/classifier_macro_f1score: 0.3323
# Epoch 00007: val_loss did not improve from 1.89227
#
# Epoch 00007: val_loss3/classifier_accuracy did not improve from 0.54576
# 224/224 [==============================] - 443s 2s/step - loss: 1.8718 - loss1/classifier_loss: 1.2213 - loss2/classifier_loss: 1.1695 - loss3/classifier_loss: 1.1546 - loss1/classifier_accuracy: 0.5319 - loss1/classifier_top5_acc: 0.9735 - loss1/classifier_macro_f1score: 0.3067 - loss2/classifier_accuracy: 0.5538 - loss2/classifier_top5_acc: 0.9782 - loss2/classifier_macro_f1score: 0.3317 - loss3/classifier_accuracy: 0.5571 - loss3/classifier_top5_acc: 0.9792 - loss3/classifier_macro_f1score: 0.3323 - val_loss: 1.9277 - val_loss1/classifier_loss: 1.2244 - val_loss2/classifier_loss: 1.1898 - val_loss3/classifier_loss: 1.2035 - val_loss1/classifier_accuracy: 0.5271 - val_loss1/classifier_top5_acc: 0.9727 - val_loss1/classifier_macro_f1score: 0.3366 - val_loss2/classifier_accuracy: 0.5413 - val_loss2/classifier_top5_acc: 0.9794 - val_loss2/classifier_macro_f1score: 0.3484 - val_loss3/classifier_accuracy: 0.5377 - val_loss3/classifier_top5_acc: 0.9777 - val_loss3/classifier_macro_f1score: 0.3436
# Learning rate:  0.0003
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 8/70
# 224/224 [==============================] - ETA: 0s - loss: 1.8114 - loss1/classifier_loss: 1.1937 - loss2/classifier_loss: 1.1318 - loss3/classifier_loss: 1.1138 - loss1/classifier_accuracy: 0.5467 - loss1/classifier_top5_acc: 0.9761 - loss1/classifier_macro_f1score: 0.3286 - loss2/classifier_accuracy: 0.5677 - loss2/classifier_top5_acc: 0.9809 - loss2/classifier_macro_f1score: 0.3570 - loss3/classifier_accuracy: 0.5714 - loss3/classifier_top5_acc: 0.9821 - loss3/classifier_macro_f1score: 0.3589
# Epoch 00008: val_loss improved from 1.89227 to 1.76332, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/GoogleNet/008.h5
#
# Epoch 00008: val_loss3/classifier_accuracy improved from 0.54576 to 0.58203, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/GoogleNet/008.h5
# 224/224 [==============================] - 443s 2s/step - loss: 1.8114 - loss1/classifier_loss: 1.1937 - loss2/classifier_loss: 1.1318 - loss3/classifier_loss: 1.1138 - loss1/classifier_accuracy: 0.5467 - loss1/classifier_top5_acc: 0.9761 - loss1/classifier_macro_f1score: 0.3286 - loss2/classifier_accuracy: 0.5677 - loss2/classifier_top5_acc: 0.9809 - loss2/classifier_macro_f1score: 0.3570 - loss3/classifier_accuracy: 0.5714 - loss3/classifier_top5_acc: 0.9821 - loss3/classifier_macro_f1score: 0.3589 - val_loss: 1.7633 - val_loss1/classifier_loss: 1.1568 - val_loss2/classifier_loss: 1.1003 - val_loss3/classifier_loss: 1.0862 - val_loss1/classifier_accuracy: 0.5628 - val_loss1/classifier_top5_acc: 0.9827 - val_loss1/classifier_macro_f1score: 0.3605 - val_loss2/classifier_accuracy: 0.5795 - val_loss2/classifier_top5_acc: 0.9838 - val_loss2/classifier_macro_f1score: 0.3925 - val_loss3/classifier_accuracy: 0.5820 - val_loss3/classifier_top5_acc: 0.9841 - val_loss3/classifier_macro_f1score: 0.4009
# Learning rate:  0.0003
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 9/70
# 224/224 [==============================] - ETA: 0s - loss: 1.7650 - loss1/classifier_loss: 1.1702 - loss2/classifier_loss: 1.1008 - loss3/classifier_loss: 1.0837 - loss1/classifier_accuracy: 0.5551 - loss1/classifier_top5_acc: 0.9781 - loss1/classifier_macro_f1score: 0.3427 - loss2/classifier_accuracy: 0.5812 - loss2/classifier_top5_acc: 0.9826 - loss2/classifier_macro_f1score: 0.3769 - loss3/classifier_accuracy: 0.5874 - loss3/classifier_top5_acc: 0.9836 - loss3/classifier_macro_f1score: 0.3839
# Epoch 00009: val_loss did not improve from 1.76332
#
# Epoch 00009: val_loss3/classifier_accuracy improved from 0.58203 to 0.58398, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/GoogleNet/009.h5
# 224/224 [==============================] - 442s 2s/step - loss: 1.7650 - loss1/classifier_loss: 1.1702 - loss2/classifier_loss: 1.1008 - loss3/classifier_loss: 1.0837 - loss1/classifier_accuracy: 0.5551 - loss1/classifier_top5_acc: 0.9781 - loss1/classifier_macro_f1score: 0.3427 - loss2/classifier_accuracy: 0.5812 - loss2/classifier_top5_acc: 0.9826 - loss2/classifier_macro_f1score: 0.3769 - loss3/classifier_accuracy: 0.5874 - loss3/classifier_top5_acc: 0.9836 - loss3/classifier_macro_f1score: 0.3839 - val_loss: 1.7921 - val_loss1/classifier_loss: 1.1413 - val_loss2/classifier_loss: 1.0990 - val_loss3/classifier_loss: 1.1201 - val_loss1/classifier_accuracy: 0.5737 - val_loss1/classifier_top5_acc: 0.9794 - val_loss1/classifier_macro_f1score: 0.3755 - val_loss2/classifier_accuracy: 0.5834 - val_loss2/classifier_top5_acc: 0.9838 - val_loss2/classifier_macro_f1score: 0.3954 - val_loss3/classifier_accuracy: 0.5840 - val_loss3/classifier_top5_acc: 0.9827 - val_loss3/classifier_macro_f1score: 0.4066
# Learning rate:  0.0003
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 10/70
# 224/224 [==============================] - ETA: 0s - loss: 1.7072 - loss1/classifier_loss: 1.1344 - loss2/classifier_loss: 1.0679 - loss3/classifier_loss: 1.0465 - loss1/classifier_accuracy: 0.5677 - loss1/classifier_top5_acc: 0.9798 - loss1/classifier_macro_f1score: 0.3595 - loss2/classifier_accuracy: 0.5942 - loss2/classifier_top5_acc: 0.9844 - loss2/classifier_macro_f1score: 0.3967 - loss3/classifier_accuracy: 0.5996 - loss3/classifier_top5_acc: 0.9853 - loss3/classifier_macro_f1score: 0.4088
# Epoch 00010: val_loss improved from 1.76332 to 1.72579, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/GoogleNet/010.h5
#
# Epoch 00010: val_loss3/classifier_accuracy did not improve from 0.58398
# 224/224 [==============================] - 441s 2s/step - loss: 1.7072 - loss1/classifier_loss: 1.1344 - loss2/classifier_loss: 1.0679 - loss3/classifier_loss: 1.0465 - loss1/classifier_accuracy: 0.5677 - loss1/classifier_top5_acc: 0.9798 - loss1/classifier_macro_f1score: 0.3595 - loss2/classifier_accuracy: 0.5942 - loss2/classifier_top5_acc: 0.9844 - loss2/classifier_macro_f1score: 0.3967 - loss3/classifier_accuracy: 0.5996 - loss3/classifier_top5_acc: 0.9853 - loss3/classifier_macro_f1score: 0.4088 - val_loss: 1.7258 - val_loss1/classifier_loss: 1.1099 - val_loss2/classifier_loss: 1.0708 - val_loss3/classifier_loss: 1.0716 - val_loss1/classifier_accuracy: 0.5762 - val_loss1/classifier_top5_acc: 0.9830 - val_loss1/classifier_macro_f1score: 0.3812 - val_loss2/classifier_accuracy: 0.5879 - val_loss2/classifier_top5_acc: 0.9880 - val_loss2/classifier_macro_f1score: 0.3950 - val_loss3/classifier_accuracy: 0.5818 - val_loss3/classifier_top5_acc: 0.9860 - val_loss3/classifier_macro_f1score: 0.3978
# Learning rate:  0.0003
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 11/70
# 224/224 [==============================] - ETA: 0s - loss: 1.6650 - loss1/classifier_loss: 1.1194 - loss2/classifier_loss: 1.0387 - loss3/classifier_loss: 1.0175 - loss1/classifier_accuracy: 0.5742 - loss1/classifier_top5_acc: 0.9823 - loss1/classifier_macro_f1score: 0.3714 - loss2/classifier_accuracy: 0.6062 - loss2/classifier_top5_acc: 0.9849 - loss2/classifier_macro_f1score: 0.4207 - loss3/classifier_accuracy: 0.6136 - loss3/classifier_top5_acc: 0.9861 - loss3/classifier_macro_f1score: 0.4410
# Epoch 00011: val_loss did not improve from 1.72579
#
# Epoch 00011: val_loss3/classifier_accuracy improved from 0.58398 to 0.58817, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/GoogleNet/011.h5
# 224/224 [==============================] - 443s 2s/step - loss: 1.6650 - loss1/classifier_loss: 1.1194 - loss2/classifier_loss: 1.0387 - loss3/classifier_loss: 1.0175 - loss1/classifier_accuracy: 0.5742 - loss1/classifier_top5_acc: 0.9823 - loss1/classifier_macro_f1score: 0.3714 - loss2/classifier_accuracy: 0.6062 - loss2/classifier_top5_acc: 0.9849 - loss2/classifier_macro_f1score: 0.4207 - loss3/classifier_accuracy: 0.6136 - loss3/classifier_top5_acc: 0.9861 - loss3/classifier_macro_f1score: 0.4410 - val_loss: 1.7714 - val_loss1/classifier_loss: 1.1473 - val_loss2/classifier_loss: 1.0883 - val_loss3/classifier_loss: 1.1007 - val_loss1/classifier_accuracy: 0.5636 - val_loss1/classifier_top5_acc: 0.9802 - val_loss1/classifier_macro_f1score: 0.3598 - val_loss2/classifier_accuracy: 0.5898 - val_loss2/classifier_top5_acc: 0.9813 - val_loss2/classifier_macro_f1score: 0.4151 - val_loss3/classifier_accuracy: 0.5882 - val_loss3/classifier_top5_acc: 0.9821 - val_loss3/classifier_macro_f1score: 0.4227
# Learning rate:  0.0003
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 12/70
# 224/224 [==============================] - ETA: 0s - loss: 1.6296 - loss1/classifier_loss: 1.1004 - loss2/classifier_loss: 1.0184 - loss3/classifier_loss: 0.9940 - loss1/classifier_accuracy: 0.5819 - loss1/classifier_top5_acc: 0.9814 - loss1/classifier_macro_f1score: 0.3861 - loss2/classifier_accuracy: 0.6152 - loss2/classifier_top5_acc: 0.9866 - loss2/classifier_macro_f1score: 0.4327 - loss3/classifier_accuracy: 0.6230 - loss3/classifier_top5_acc: 0.9883 - loss3/classifier_macro_f1score: 0.4529
# Epoch 00012: val_loss improved from 1.72579 to 1.71397, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/GoogleNet/012.h5
#
# Epoch 00012: val_loss3/classifier_accuracy improved from 0.58817 to 0.60128, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/GoogleNet/012.h5
# 224/224 [==============================] - 448s 2s/step - loss: 1.6296 - loss1/classifier_loss: 1.1004 - loss2/classifier_loss: 1.0184 - loss3/classifier_loss: 0.9940 - loss1/classifier_accuracy: 0.5819 - loss1/classifier_top5_acc: 0.9814 - loss1/classifier_macro_f1score: 0.3861 - loss2/classifier_accuracy: 0.6152 - loss2/classifier_top5_acc: 0.9866 - loss2/classifier_macro_f1score: 0.4327 - loss3/classifier_accuracy: 0.6230 - loss3/classifier_top5_acc: 0.9883 - loss3/classifier_macro_f1score: 0.4529 - val_loss: 1.7140 - val_loss1/classifier_loss: 1.1227 - val_loss2/classifier_loss: 1.0652 - val_loss3/classifier_loss: 1.0576 - val_loss1/classifier_accuracy: 0.5792 - val_loss1/classifier_top5_acc: 0.9796 - val_loss1/classifier_macro_f1score: 0.3945 - val_loss2/classifier_accuracy: 0.6049 - val_loss2/classifier_top5_acc: 0.9838 - val_loss2/classifier_macro_f1score: 0.4421 - val_loss3/classifier_accuracy: 0.6013 - val_loss3/classifier_top5_acc: 0.9844 - val_loss3/classifier_macro_f1score: 0.4417
# Learning rate:  0.0003
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 13/70
# 224/224 [==============================] - ETA: 0s - loss: 1.5962 - loss1/classifier_loss: 1.0844 - loss2/classifier_loss: 0.9996 - loss3/classifier_loss: 0.9710 - loss1/classifier_accuracy: 0.5916 - loss1/classifier_top5_acc: 0.9835 - loss1/classifier_macro_f1score: 0.3982 - loss2/classifier_accuracy: 0.6221 - loss2/classifier_top5_acc: 0.9869 - loss2/classifier_macro_f1score: 0.4502 - loss3/classifier_accuracy: 0.6323 - loss3/classifier_top5_acc: 0.9886 - loss3/classifier_macro_f1score: 0.4715
# Epoch 00013: val_loss improved from 1.71397 to 1.63487, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/GoogleNet/013.h5
#
# Epoch 00013: val_loss3/classifier_accuracy improved from 0.60128 to 0.61551, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/GoogleNet/013.h5
# 224/224 [==============================] - 449s 2s/step - loss: 1.5962 - loss1/classifier_loss: 1.0844 - loss2/classifier_loss: 0.9996 - loss3/classifier_loss: 0.9710 - loss1/classifier_accuracy: 0.5916 - loss1/classifier_top5_acc: 0.9835 - loss1/classifier_macro_f1score: 0.3982 - loss2/classifier_accuracy: 0.6221 - loss2/classifier_top5_acc: 0.9869 - loss2/classifier_macro_f1score: 0.4502 - loss3/classifier_accuracy: 0.6323 - loss3/classifier_top5_acc: 0.9886 - loss3/classifier_macro_f1score: 0.4715 - val_loss: 1.6349 - val_loss1/classifier_loss: 1.0834 - val_loss2/classifier_loss: 1.0113 - val_loss3/classifier_loss: 1.0065 - val_loss1/classifier_accuracy: 0.5840 - val_loss1/classifier_top5_acc: 0.9849 - val_loss1/classifier_macro_f1score: 0.3784 - val_loss2/classifier_accuracy: 0.6108 - val_loss2/classifier_top5_acc: 0.9852 - val_loss2/classifier_macro_f1score: 0.4172 - val_loss3/classifier_accuracy: 0.6155 - val_loss3/classifier_top5_acc: 0.9849 - val_loss3/classifier_macro_f1score: 0.4247
# Learning rate:  0.0003
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 14/70
# 224/224 [==============================] - ETA: 0s - loss: 1.5516 - loss1/classifier_loss: 1.0579 - loss2/classifier_loss: 0.9710 - loss3/classifier_loss: 0.9429 - loss1/classifier_accuracy: 0.6007 - loss1/classifier_top5_acc: 0.9842 - loss1/classifier_macro_f1score: 0.4143 - loss2/classifier_accuracy: 0.6348 - loss2/classifier_top5_acc: 0.9876 - loss2/classifier_macro_f1score: 0.4690 - loss3/classifier_accuracy: 0.6423 - loss3/classifier_top5_acc: 0.9889 - loss3/classifier_macro_f1score: 0.4944
# Epoch 00014: val_loss did not improve from 1.63487
#
# Epoch 00014: val_loss3/classifier_accuracy did not improve from 0.61551
# 224/224 [==============================] - 444s 2s/step - loss: 1.5516 - loss1/classifier_loss: 1.0579 - loss2/classifier_loss: 0.9710 - loss3/classifier_loss: 0.9429 - loss1/classifier_accuracy: 0.6007 - loss1/classifier_top5_acc: 0.9842 - loss1/classifier_macro_f1score: 0.4143 - loss2/classifier_accuracy: 0.6348 - loss2/classifier_top5_acc: 0.9876 - loss2/classifier_macro_f1score: 0.4690 - loss3/classifier_accuracy: 0.6423 - loss3/classifier_top5_acc: 0.9889 - loss3/classifier_macro_f1score: 0.4944 - val_loss: 1.7096 - val_loss1/classifier_loss: 1.0778 - val_loss2/classifier_loss: 1.0491 - val_loss3/classifier_loss: 1.0715 - val_loss1/classifier_accuracy: 0.5818 - val_loss1/classifier_top5_acc: 0.9849 - val_loss1/classifier_macro_f1score: 0.3977 - val_loss2/classifier_accuracy: 0.6035 - val_loss2/classifier_top5_acc: 0.9877 - val_loss2/classifier_macro_f1score: 0.4166 - val_loss3/classifier_accuracy: 0.6010 - val_loss3/classifier_top5_acc: 0.9858 - val_loss3/classifier_macro_f1score: 0.4238
# Learning rate:  0.0003
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 15/70
# 224/224 [==============================] - ETA: 0s - loss: 1.5222 - loss1/classifier_loss: 1.0459 - loss2/classifier_loss: 0.9485 - loss3/classifier_loss: 0.9239 - loss1/classifier_accuracy: 0.6041 - loss1/classifier_top5_acc: 0.9854 - loss1/classifier_macro_f1score: 0.4227 - loss2/classifier_accuracy: 0.6435 - loss2/classifier_top5_acc: 0.9898 - loss2/classifier_macro_f1score: 0.4867 - loss3/classifier_accuracy: 0.6522 - loss3/classifier_top5_acc: 0.9907 - loss3/classifier_macro_f1score: 0.5069
# Epoch 00015: val_loss improved from 1.63487 to 1.62841, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/GoogleNet/015.h5
#
# Epoch 00015: val_loss3/classifier_accuracy improved from 0.61551 to 0.62500, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/GoogleNet/015.h5
# 224/224 [==============================] - 437s 2s/step - loss: 1.5222 - loss1/classifier_loss: 1.0459 - loss2/classifier_loss: 0.9485 - loss3/classifier_loss: 0.9239 - loss1/classifier_accuracy: 0.6041 - loss1/classifier_top5_acc: 0.9854 - loss1/classifier_macro_f1score: 0.4227 - loss2/classifier_accuracy: 0.6435 - loss2/classifier_top5_acc: 0.9898 - loss2/classifier_macro_f1score: 0.4867 - loss3/classifier_accuracy: 0.6522 - loss3/classifier_top5_acc: 0.9907 - loss3/classifier_macro_f1score: 0.5069 - val_loss: 1.6284 - val_loss1/classifier_loss: 1.0594 - val_loss2/classifier_loss: 1.0138 - val_loss3/classifier_loss: 1.0064 - val_loss1/classifier_accuracy: 0.5982 - val_loss1/classifier_top5_acc: 0.9858 - val_loss1/classifier_macro_f1score: 0.4005 - val_loss2/classifier_accuracy: 0.6175 - val_loss2/classifier_top5_acc: 0.9880 - val_loss2/classifier_macro_f1score: 0.4522 - val_loss3/classifier_accuracy: 0.6250 - val_loss3/classifier_top5_acc: 0.9866 - val_loss3/classifier_macro_f1score: 0.4721
# Learning rate:  0.0003
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 16/70
# 224/224 [==============================] - ETA: 0s - loss: 1.5097 - loss1/classifier_loss: 1.0408 - loss2/classifier_loss: 0.9418 - loss3/classifier_loss: 0.9150 - loss1/classifier_accuracy: 0.6070 - loss1/classifier_top5_acc: 0.9861 - loss1/classifier_macro_f1score: 0.4218 - loss2/classifier_accuracy: 0.6471 - loss2/classifier_top5_acc: 0.9889 - loss2/classifier_macro_f1score: 0.4988 - loss3/classifier_accuracy: 0.6560 - loss3/classifier_top5_acc: 0.9910 - loss3/classifier_macro_f1score: 0.5190
# Epoch 00016: val_loss did not improve from 1.62841
#
# Epoch 00016: val_loss3/classifier_accuracy did not improve from 0.62500
# 224/224 [==============================] - 437s 2s/step - loss: 1.5097 - loss1/classifier_loss: 1.0408 - loss2/classifier_loss: 0.9418 - loss3/classifier_loss: 0.9150 - loss1/classifier_accuracy: 0.6070 - loss1/classifier_top5_acc: 0.9861 - loss1/classifier_macro_f1score: 0.4218 - loss2/classifier_accuracy: 0.6471 - loss2/classifier_top5_acc: 0.9889 - loss2/classifier_macro_f1score: 0.4988 - loss3/classifier_accuracy: 0.6560 - loss3/classifier_top5_acc: 0.9910 - loss3/classifier_macro_f1score: 0.5190 - val_loss: 1.6515 - val_loss1/classifier_loss: 1.0732 - val_loss2/classifier_loss: 1.0155 - val_loss3/classifier_loss: 1.0249 - val_loss1/classifier_accuracy: 0.5935 - val_loss1/classifier_top5_acc: 0.9860 - val_loss1/classifier_macro_f1score: 0.4106 - val_loss2/classifier_accuracy: 0.6228 - val_loss2/classifier_top5_acc: 0.9891 - val_loss2/classifier_macro_f1score: 0.4670 - val_loss3/classifier_accuracy: 0.6191 - val_loss3/classifier_top5_acc: 0.9883 - val_loss3/classifier_macro_f1score: 0.4861
# Learning rate:  0.0003
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 17/70
# 224/224 [==============================] - ETA: 0s - loss: 1.4627 - loss1/classifier_loss: 1.0156 - loss2/classifier_loss: 0.9119 - loss3/classifier_loss: 0.8845 - loss1/classifier_accuracy: 0.6155 - loss1/classifier_top5_acc: 0.9862 - loss1/classifier_macro_f1score: 0.4446 - loss2/classifier_accuracy: 0.6594 - loss2/classifier_top5_acc: 0.9909 - loss2/classifier_macro_f1score: 0.5106 - loss3/classifier_accuracy: 0.6708 - loss3/classifier_top5_acc: 0.9914 - loss3/classifier_macro_f1score: 0.5354
# Epoch 00017: val_loss improved from 1.62841 to 1.61305, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/GoogleNet/017.h5
#
# Epoch 00017: val_loss3/classifier_accuracy improved from 0.62500 to 0.62807, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/GoogleNet/017.h5
# 224/224 [==============================] - 442s 2s/step - loss: 1.4627 - loss1/classifier_loss: 1.0156 - loss2/classifier_loss: 0.9119 - loss3/classifier_loss: 0.8845 - loss1/classifier_accuracy: 0.6155 - loss1/classifier_top5_acc: 0.9862 - loss1/classifier_macro_f1score: 0.4446 - loss2/classifier_accuracy: 0.6594 - loss2/classifier_top5_acc: 0.9909 - loss2/classifier_macro_f1score: 0.5106 - loss3/classifier_accuracy: 0.6708 - loss3/classifier_top5_acc: 0.9914 - loss3/classifier_macro_f1score: 0.5354 - val_loss: 1.6130 - val_loss1/classifier_loss: 1.0527 - val_loss2/classifier_loss: 0.9952 - val_loss3/classifier_loss: 0.9987 - val_loss1/classifier_accuracy: 0.5974 - val_loss1/classifier_top5_acc: 0.9874 - val_loss1/classifier_macro_f1score: 0.4255 - val_loss2/classifier_accuracy: 0.6250 - val_loss2/classifier_top5_acc: 0.9894 - val_loss2/classifier_macro_f1score: 0.4600 - val_loss3/classifier_accuracy: 0.6281 - val_loss3/classifier_top5_acc: 0.9897 - val_loss3/classifier_macro_f1score: 0.4602
# Learning rate:  0.0003
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 18/70
# 224/224 [==============================] - ETA: 0s - loss: 1.4501 - loss1/classifier_loss: 1.0096 - loss2/classifier_loss: 0.9043 - loss3/classifier_loss: 0.8759 - loss1/classifier_accuracy: 0.6186 - loss1/classifier_top5_acc: 0.9869 - loss1/classifier_macro_f1score: 0.4421 - loss2/classifier_accuracy: 0.6629 - loss2/classifier_top5_acc: 0.9906 - loss2/classifier_macro_f1score: 0.5222 - loss3/classifier_accuracy: 0.6693 - loss3/classifier_top5_acc: 0.9921 - loss3/classifier_macro_f1score: 0.5482
# Epoch 00018: val_loss improved from 1.61305 to 1.60879, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/GoogleNet/018.h5
#
# Epoch 00018: val_loss3/classifier_accuracy improved from 0.62807 to 0.63142, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/GoogleNet/018.h5
# 224/224 [==============================] - 441s 2s/step - loss: 1.4501 - loss1/classifier_loss: 1.0096 - loss2/classifier_loss: 0.9043 - loss3/classifier_loss: 0.8759 - loss1/classifier_accuracy: 0.6186 - loss1/classifier_top5_acc: 0.9869 - loss1/classifier_macro_f1score: 0.4421 - loss2/classifier_accuracy: 0.6629 - loss2/classifier_top5_acc: 0.9906 - loss2/classifier_macro_f1score: 0.5222 - loss3/classifier_accuracy: 0.6693 - loss3/classifier_top5_acc: 0.9921 - loss3/classifier_macro_f1score: 0.5482 - val_loss: 1.6088 - val_loss1/classifier_loss: 1.0822 - val_loss2/classifier_loss: 0.9982 - val_loss3/classifier_loss: 0.9847 - val_loss1/classifier_accuracy: 0.5929 - val_loss1/classifier_top5_acc: 0.9855 - val_loss1/classifier_macro_f1score: 0.4392 - val_loss2/classifier_accuracy: 0.6219 - val_loss2/classifier_top5_acc: 0.9883 - val_loss2/classifier_macro_f1score: 0.4988 - val_loss3/classifier_accuracy: 0.6314 - val_loss3/classifier_top5_acc: 0.9886 - val_loss3/classifier_macro_f1score: 0.4967
# Learning rate:  0.0003
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 19/70
# 224/224 [==============================] - ETA: 0s - loss: 1.4214 - loss1/classifier_loss: 1.0039 - loss2/classifier_loss: 0.8843 - loss3/classifier_loss: 0.8549 - loss1/classifier_accuracy: 0.6198 - loss1/classifier_top5_acc: 0.9869 - loss1/classifier_macro_f1score: 0.4532 - loss2/classifier_accuracy: 0.6665 - loss2/classifier_top5_acc: 0.9909 - loss2/classifier_macro_f1score: 0.5338 - loss3/classifier_accuracy: 0.6781 - loss3/classifier_top5_acc: 0.9927 - loss3/classifier_macro_f1score: 0.5584
# Epoch 00019: val_loss did not improve from 1.60879
#
# Epoch 00019: val_loss3/classifier_accuracy improved from 0.63142 to 0.63225, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/GoogleNet/019.h5
# 224/224 [==============================] - 441s 2s/step - loss: 1.4214 - loss1/classifier_loss: 1.0039 - loss2/classifier_loss: 0.8843 - loss3/classifier_loss: 0.8549 - loss1/classifier_accuracy: 0.6198 - loss1/classifier_top5_acc: 0.9869 - loss1/classifier_macro_f1score: 0.4532 - loss2/classifier_accuracy: 0.6665 - loss2/classifier_top5_acc: 0.9909 - loss2/classifier_macro_f1score: 0.5338 - loss3/classifier_accuracy: 0.6781 - loss3/classifier_top5_acc: 0.9927 - loss3/classifier_macro_f1score: 0.5584 - val_loss: 1.6318 - val_loss1/classifier_loss: 1.0639 - val_loss2/classifier_loss: 1.0177 - val_loss3/classifier_loss: 1.0073 - val_loss1/classifier_accuracy: 0.6074 - val_loss1/classifier_top5_acc: 0.9886 - val_loss1/classifier_macro_f1score: 0.4489 - val_loss2/classifier_accuracy: 0.6253 - val_loss2/classifier_top5_acc: 0.9883 - val_loss2/classifier_macro_f1score: 0.4806 - val_loss3/classifier_accuracy: 0.6323 - val_loss3/classifier_top5_acc: 0.9891 - val_loss3/classifier_macro_f1score: 0.5023
# Learning rate:  0.0003
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 20/70
# 224/224 [==============================] - ETA: 0s - loss: 1.3890 - loss1/classifier_loss: 0.9832 - loss2/classifier_loss: 0.8619 - loss3/classifier_loss: 0.8355 - loss1/classifier_accuracy: 0.6296 - loss1/classifier_top5_acc: 0.9875 - loss1/classifier_macro_f1score: 0.4675 - loss2/classifier_accuracy: 0.6750 - loss2/classifier_top5_acc: 0.9917 - loss2/classifier_macro_f1score: 0.5508 - loss3/classifier_accuracy: 0.6837 - loss3/classifier_top5_acc: 0.9929 - loss3/classifier_macro_f1score: 0.5808
# Epoch 00020: val_loss improved from 1.60879 to 1.59963, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/GoogleNet/020.h5
#
# Epoch 00020: val_loss3/classifier_accuracy improved from 0.63225 to 0.63616, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/GoogleNet/020.h5
# 224/224 [==============================] - 445s 2s/step - loss: 1.3890 - loss1/classifier_loss: 0.9832 - loss2/classifier_loss: 0.8619 - loss3/classifier_loss: 0.8355 - loss1/classifier_accuracy: 0.6296 - loss1/classifier_top5_acc: 0.9875 - loss1/classifier_macro_f1score: 0.4675 - loss2/classifier_accuracy: 0.6750 - loss2/classifier_top5_acc: 0.9917 - loss2/classifier_macro_f1score: 0.5508 - loss3/classifier_accuracy: 0.6837 - loss3/classifier_top5_acc: 0.9929 - loss3/classifier_macro_f1score: 0.5808 - val_loss: 1.5996 - val_loss1/classifier_loss: 1.0374 - val_loss2/classifier_loss: 0.9962 - val_loss3/classifier_loss: 0.9896 - val_loss1/classifier_accuracy: 0.6080 - val_loss1/classifier_top5_acc: 0.9858 - val_loss1/classifier_macro_f1score: 0.4398 - val_loss2/classifier_accuracy: 0.6292 - val_loss2/classifier_top5_acc: 0.9872 - val_loss2/classifier_macro_f1score: 0.4929 - val_loss3/classifier_accuracy: 0.6362 - val_loss3/classifier_top5_acc: 0.9888 - val_loss3/classifier_macro_f1score: 0.5131
# Learning rate:  0.0003
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 21/70
# 224/224 [==============================] - ETA: 0s - loss: 1.3743 - loss1/classifier_loss: 0.9711 - loss2/classifier_loss: 0.8557 - loss3/classifier_loss: 0.8262 - loss1/classifier_accuracy: 0.6380 - loss1/classifier_top5_acc: 0.9874 - loss1/classifier_macro_f1score: 0.4751 - loss2/classifier_accuracy: 0.6810 - loss2/classifier_top5_acc: 0.9918 - loss2/classifier_macro_f1score: 0.5614 - loss3/classifier_accuracy: 0.6908 - loss3/classifier_top5_acc: 0.9935 - loss3/classifier_macro_f1score: 0.5834
# Epoch 00021: val_loss did not improve from 1.59963
#
# Epoch 00021: val_loss3/classifier_accuracy did not improve from 0.63616
# 224/224 [==============================] - 447s 2s/step - loss: 1.3743 - loss1/classifier_loss: 0.9711 - loss2/classifier_loss: 0.8557 - loss3/classifier_loss: 0.8262 - loss1/classifier_accuracy: 0.6380 - loss1/classifier_top5_acc: 0.9874 - loss1/classifier_macro_f1score: 0.4751 - loss2/classifier_accuracy: 0.6810 - loss2/classifier_top5_acc: 0.9918 - loss2/classifier_macro_f1score: 0.5614 - loss3/classifier_accuracy: 0.6908 - loss3/classifier_top5_acc: 0.9935 - loss3/classifier_macro_f1score: 0.5834 - val_loss: 1.6257 - val_loss1/classifier_loss: 1.0236 - val_loss2/classifier_loss: 1.0054 - val_loss3/classifier_loss: 1.0169 - val_loss1/classifier_accuracy: 0.6250 - val_loss1/classifier_top5_acc: 0.9872 - val_loss1/classifier_macro_f1score: 0.4699 - val_loss2/classifier_accuracy: 0.6334 - val_loss2/classifier_top5_acc: 0.9888 - val_loss2/classifier_macro_f1score: 0.5018 - val_loss3/classifier_accuracy: 0.6336 - val_loss3/classifier_top5_acc: 0.9869 - val_loss3/classifier_macro_f1score: 0.5209
# Learning rate:  0.0003
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 22/70
# 224/224 [==============================] - ETA: 0s - loss: 1.3511 - loss1/classifier_loss: 0.9675 - loss2/classifier_loss: 0.8401 - loss3/classifier_loss: 0.8088 - loss1/classifier_accuracy: 0.6405 - loss1/classifier_top5_acc: 0.9883 - loss1/classifier_macro_f1score: 0.4794 - loss2/classifier_accuracy: 0.6879 - loss2/classifier_top5_acc: 0.9925 - loss2/classifier_macro_f1score: 0.5729 - loss3/classifier_accuracy: 0.6974 - loss3/classifier_top5_acc: 0.9937 - loss3/classifier_macro_f1score: 0.5936
# Epoch 00022: val_loss did not improve from 1.59963
#
# Epoch 00022: val_loss3/classifier_accuracy improved from 0.63616 to 0.63644, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/GoogleNet/022.h5
# 224/224 [==============================] - 447s 2s/step - loss: 1.3511 - loss1/classifier_loss: 0.9675 - loss2/classifier_loss: 0.8401 - loss3/classifier_loss: 0.8088 - loss1/classifier_accuracy: 0.6405 - loss1/classifier_top5_acc: 0.9883 - loss1/classifier_macro_f1score: 0.4794 - loss2/classifier_accuracy: 0.6879 - loss2/classifier_top5_acc: 0.9925 - loss2/classifier_macro_f1score: 0.5729 - loss3/classifier_accuracy: 0.6974 - loss3/classifier_top5_acc: 0.9937 - loss3/classifier_macro_f1score: 0.5936 - val_loss: 1.6020 - val_loss1/classifier_loss: 1.0262 - val_loss2/classifier_loss: 0.9965 - val_loss3/classifier_loss: 0.9952 - val_loss1/classifier_accuracy: 0.6127 - val_loss1/classifier_top5_acc: 0.9860 - val_loss1/classifier_macro_f1score: 0.4649 - val_loss2/classifier_accuracy: 0.6258 - val_loss2/classifier_top5_acc: 0.9891 - val_loss2/classifier_macro_f1score: 0.5132 - val_loss3/classifier_accuracy: 0.6364 - val_loss3/classifier_top5_acc: 0.9902 - val_loss3/classifier_macro_f1score: 0.5268
# Learning rate:  0.0003
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 23/70
# 224/224 [==============================] - ETA: 0s - loss: 1.3094 - loss1/classifier_loss: 0.9498 - loss2/classifier_loss: 0.8143 - loss3/classifier_loss: 0.7802 - loss1/classifier_accuracy: 0.6443 - loss1/classifier_top5_acc: 0.9881 - loss1/classifier_macro_f1score: 0.4870 - loss2/classifier_accuracy: 0.6969 - loss2/classifier_top5_acc: 0.9930 - loss2/classifier_macro_f1score: 0.5827 - loss3/classifier_accuracy: 0.7083 - loss3/classifier_top5_acc: 0.9944 - loss3/classifier_macro_f1score: 0.6105
# Epoch 00023: val_loss did not improve from 1.59963
#
# Epoch 00023: val_loss3/classifier_accuracy improved from 0.63644 to 0.64369, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/GoogleNet/023.h5
# ...
# Learning rate:  2.9999999999999997e-06
#
# Epoch 00062: LearningRateScheduler reducing learning rate to 2.9999999999999997e-06.
# Epoch 62/70
# 224/224 [==============================] - ETA: 0s - loss: 0.6596 - loss1/classifier_loss: 0.7488 - loss2/classifier_loss: 0.4109 - loss3/classifier_loss: 0.3117 - loss1/classifier_accuracy: 0.7236 - loss1/classifier_top5_acc: 0.9946 - loss1/classifier_macro_f1score: 0.6182 - loss2/classifier_accuracy: 0.8515 - loss2/classifier_top5_acc: 0.9989 - loss2/classifier_macro_f1score: 0.8174 - loss3/classifier_accuracy: 0.8895 - loss3/classifier_top5_acc: 0.9995 - loss3/classifier_macro_f1score: 0.8675
# Epoch 00062: val_loss did not improve from 1.59662
#
# Epoch 00062: val_loss3/classifier_accuracy did not improve from 0.66267
# 224/224 [==============================] - 448s 2s/step - loss: 0.6596 - loss1/classifier_loss: 0.7488 - loss2/classifier_loss: 0.4109 - loss3/classifier_loss: 0.3117 - loss1/classifier_accuracy: 0.7236 - loss1/classifier_top5_acc: 0.9946 - loss1/classifier_macro_f1score: 0.6182 - loss2/classifier_accuracy: 0.8515 - loss2/classifier_top5_acc: 0.9989 - loss2/classifier_macro_f1score: 0.8174 - loss3/classifier_accuracy: 0.8895 - loss3/classifier_top5_acc: 0.9995 - loss3/classifier_macro_f1score: 0.8675 - val_loss: 1.9543 - val_loss1/classifier_loss: 0.9913 - val_loss2/classifier_loss: 1.1406 - val_loss3/classifier_loss: 1.3148 - val_loss1/classifier_accuracy: 0.6367 - val_loss1/classifier_top5_acc: 0.9880 - val_loss1/classifier_macro_f1score: 0.5296 - val_loss2/classifier_accuracy: 0.6551 - val_loss2/classifier_top5_acc: 0.9894 - val_loss2/classifier_macro_f1score: 0.6025 - val_loss3/classifier_accuracy: 0.6562 - val_loss3/classifier_top5_acc: 0.9869 - val_loss3/classifier_macro_f1score: 0.6227
# Learning rate:  2.9999999999999997e-06
#
# Epoch 00063: LearningRateScheduler reducing learning rate to 2.9999999999999997e-06.
# Epoch 63/70
# 224/224 [==============================] - ETA: 0s - loss: 0.6526 - loss1/classifier_loss: 0.7524 - loss2/classifier_loss: 0.4091 - loss3/classifier_loss: 0.3042 - loss1/classifier_accuracy: 0.7204 - loss1/classifier_top5_acc: 0.9940 - loss1/classifier_macro_f1score: 0.6160 - loss2/classifier_accuracy: 0.8511 - loss2/classifier_top5_acc: 0.9988 - loss2/classifier_macro_f1score: 0.8141 - loss3/classifier_accuracy: 0.8904 - loss3/classifier_top5_acc: 0.9995 - loss3/classifier_macro_f1score: 0.8652
# Epoch 00063: val_loss did not improve from 1.59662
#
# Epoch 00063: val_loss3/classifier_accuracy did not improve from 0.66267
# 224/224 [==============================] - 441s 2s/step - loss: 0.6526 - loss1/classifier_loss: 0.7524 - loss2/classifier_loss: 0.4091 - loss3/classifier_loss: 0.3042 - loss1/classifier_accuracy: 0.7204 - loss1/classifier_top5_acc: 0.9940 - loss1/classifier_macro_f1score: 0.6160 - loss2/classifier_accuracy: 0.8511 - loss2/classifier_top5_acc: 0.9988 - loss2/classifier_macro_f1score: 0.8141 - loss3/classifier_accuracy: 0.8904 - loss3/classifier_top5_acc: 0.9995 - loss3/classifier_macro_f1score: 0.8652 - val_loss: 1.9525 - val_loss1/classifier_loss: 0.9884 - val_loss2/classifier_loss: 1.1379 - val_loss3/classifier_loss: 1.3147 - val_loss1/classifier_accuracy: 0.6390 - val_loss1/classifier_top5_acc: 0.9886 - val_loss1/classifier_macro_f1score: 0.5266 - val_loss2/classifier_accuracy: 0.6518 - val_loss2/classifier_top5_acc: 0.9897 - val_loss2/classifier_macro_f1score: 0.6039 - val_loss3/classifier_accuracy: 0.6532 - val_loss3/classifier_top5_acc: 0.9869 - val_loss3/classifier_macro_f1score: 0.6128
# Learning rate:  2.9999999999999997e-06
#
# Epoch 00064: LearningRateScheduler reducing learning rate to 2.9999999999999997e-06.
# Epoch 64/70
# 224/224 [==============================] - ETA: 0s - loss: 0.6582 - loss1/classifier_loss: 0.7535 - loss2/classifier_loss: 0.4119 - loss3/classifier_loss: 0.3086 - loss1/classifier_accuracy: 0.7187 - loss1/classifier_top5_acc: 0.9949 - loss1/classifier_macro_f1score: 0.6172 - loss2/classifier_accuracy: 0.8511 - loss2/classifier_top5_acc: 0.9988 - loss2/classifier_macro_f1score: 0.8125 - loss3/classifier_accuracy: 0.8875 - loss3/classifier_top5_acc: 0.9994 - loss3/classifier_macro_f1score: 0.8625
# Epoch 00064: val_loss did not improve from 1.59662
#
# Epoch 00064: val_loss3/classifier_accuracy did not improve from 0.66267
# 224/224 [==============================] - 442s 2s/step - loss: 0.6582 - loss1/classifier_loss: 0.7535 - loss2/classifier_loss: 0.4119 - loss3/classifier_loss: 0.3086 - loss1/classifier_accuracy: 0.7187 - loss1/classifier_top5_acc: 0.9949 - loss1/classifier_macro_f1score: 0.6172 - loss2/classifier_accuracy: 0.8511 - loss2/classifier_top5_acc: 0.9988 - loss2/classifier_macro_f1score: 0.8125 - loss3/classifier_accuracy: 0.8875 - loss3/classifier_top5_acc: 0.9994 - loss3/classifier_macro_f1score: 0.8625 - val_loss: 1.9314 - val_loss1/classifier_loss: 0.9832 - val_loss2/classifier_loss: 1.1239 - val_loss3/classifier_loss: 1.2993 - val_loss1/classifier_accuracy: 0.6373 - val_loss1/classifier_top5_acc: 0.9891 - val_loss1/classifier_macro_f1score: 0.5316 - val_loss2/classifier_accuracy: 0.6532 - val_loss2/classifier_top5_acc: 0.9891 - val_loss2/classifier_macro_f1score: 0.6092 - val_loss3/classifier_accuracy: 0.6540 - val_loss3/classifier_top5_acc: 0.9869 - val_loss3/classifier_macro_f1score: 0.6225
# Learning rate:  2.9999999999999997e-06
#
# Epoch 00065: LearningRateScheduler reducing learning rate to 2.9999999999999997e-06.
# Epoch 65/70
# 224/224 [==============================] - ETA: 0s - loss: 0.6526 - loss1/classifier_loss: 0.7512 - loss2/classifier_loss: 0.4070 - loss3/classifier_loss: 0.3051 - loss1/classifier_accuracy: 0.7229 - loss1/classifier_top5_acc: 0.9937 - loss1/classifier_macro_f1score: 0.6235 - loss2/classifier_accuracy: 0.8525 - loss2/classifier_top5_acc: 0.9989 - loss2/classifier_macro_f1score: 0.8219 - loss3/classifier_accuracy: 0.8912 - loss3/classifier_top5_acc: 0.9993 - loss3/classifier_macro_f1score: 0.8708
# Epoch 00065: val_loss did not improve from 1.59662
#
# Epoch 00065: val_loss3/classifier_accuracy did not improve from 0.66267
# 224/224 [==============================] - 437s 2s/step - loss: 0.6526 - loss1/classifier_loss: 0.7512 - loss2/classifier_loss: 0.4070 - loss3/classifier_loss: 0.3051 - loss1/classifier_accuracy: 0.7229 - loss1/classifier_top5_acc: 0.9937 - loss1/classifier_macro_f1score: 0.6235 - loss2/classifier_accuracy: 0.8525 - loss2/classifier_top5_acc: 0.9989 - loss2/classifier_macro_f1score: 0.8219 - loss3/classifier_accuracy: 0.8912 - loss3/classifier_top5_acc: 0.9993 - loss3/classifier_macro_f1score: 0.8708 - val_loss: 1.9407 - val_loss1/classifier_loss: 0.9898 - val_loss2/classifier_loss: 1.1308 - val_loss3/classifier_loss: 1.3045 - val_loss1/classifier_accuracy: 0.6395 - val_loss1/classifier_top5_acc: 0.9888 - val_loss1/classifier_macro_f1score: 0.5319 - val_loss2/classifier_accuracy: 0.6549 - val_loss2/classifier_top5_acc: 0.9894 - val_loss2/classifier_macro_f1score: 0.5983 - val_loss3/classifier_accuracy: 0.6574 - val_loss3/classifier_top5_acc: 0.9869 - val_loss3/classifier_macro_f1score: 0.6232
# Learning rate:  2.9999999999999997e-06
#
# Epoch 00066: LearningRateScheduler reducing learning rate to 2.9999999999999997e-06.
# Epoch 66/70
# 224/224 [==============================] - ETA: 0s - loss: 0.6480 - loss1/classifier_loss: 0.7445 - loss2/classifier_loss: 0.4071 - loss3/classifier_loss: 0.3025 - loss1/classifier_accuracy: 0.7266 - loss1/classifier_top5_acc: 0.9950 - loss1/classifier_macro_f1score: 0.6198 - loss2/classifier_accuracy: 0.8519 - loss2/classifier_top5_acc: 0.9989 - loss2/classifier_macro_f1score: 0.8140 - loss3/classifier_accuracy: 0.8906 - loss3/classifier_top5_acc: 0.9992 - loss3/classifier_macro_f1score: 0.8613
# Epoch 00066: val_loss did not improve from 1.59662
#
# Epoch 00066: val_loss3/classifier_accuracy did not improve from 0.66267
# 224/224 [==============================] - 437s 2s/step - loss: 0.6480 - loss1/classifier_loss: 0.7445 - loss2/classifier_loss: 0.4071 - loss3/classifier_loss: 0.3025 - loss1/classifier_accuracy: 0.7266 - loss1/classifier_top5_acc: 0.9950 - loss1/classifier_macro_f1score: 0.6198 - loss2/classifier_accuracy: 0.8519 - loss2/classifier_top5_acc: 0.9989 - loss2/classifier_macro_f1score: 0.8140 - loss3/classifier_accuracy: 0.8906 - loss3/classifier_top5_acc: 0.9992 - loss3/classifier_macro_f1score: 0.8613 - val_loss: 1.9359 - val_loss1/classifier_loss: 0.9887 - val_loss2/classifier_loss: 1.1260 - val_loss3/classifier_loss: 1.3015 - val_loss1/classifier_accuracy: 0.6387 - val_loss1/classifier_top5_acc: 0.9888 - val_loss1/classifier_macro_f1score: 0.5282 - val_loss2/classifier_accuracy: 0.6504 - val_loss2/classifier_top5_acc: 0.9894 - val_loss2/classifier_macro_f1score: 0.6035 - val_loss3/classifier_accuracy: 0.6518 - val_loss3/classifier_top5_acc: 0.9863 - val_loss3/classifier_macro_f1score: 0.6173
# Learning rate:  2.9999999999999997e-06
#
# Epoch 00067: LearningRateScheduler reducing learning rate to 2.9999999999999997e-06.
# Epoch 67/70
# 224/224 [==============================] - ETA: 0s - loss: 0.6701 - loss1/classifier_loss: 0.7613 - loss2/classifier_loss: 0.4222 - loss3/classifier_loss: 0.3150 - loss1/classifier_accuracy: 0.7173 - loss1/classifier_top5_acc: 0.9943 - loss1/classifier_macro_f1score: 0.6165 - loss2/classifier_accuracy: 0.8455 - loss2/classifier_top5_acc: 0.9986 - loss2/classifier_macro_f1score: 0.8051 - loss3/classifier_accuracy: 0.8883 - loss3/classifier_top5_acc: 0.9996 - loss3/classifier_macro_f1score: 0.8616
# Epoch 00067: val_loss did not improve from 1.59662
#
# Epoch 00067: val_loss3/classifier_accuracy did not improve from 0.66267
# 224/224 [==============================] - 436s 2s/step - loss: 0.6701 - loss1/classifier_loss: 0.7613 - loss2/classifier_loss: 0.4222 - loss3/classifier_loss: 0.3150 - loss1/classifier_accuracy: 0.7173 - loss1/classifier_top5_acc: 0.9943 - loss1/classifier_macro_f1score: 0.6165 - loss2/classifier_accuracy: 0.8455 - loss2/classifier_top5_acc: 0.9986 - loss2/classifier_macro_f1score: 0.8051 - loss3/classifier_accuracy: 0.8883 - loss3/classifier_top5_acc: 0.9996 - loss3/classifier_macro_f1score: 0.8616 - val_loss: 1.9166 - val_loss1/classifier_loss: 0.9851 - val_loss2/classifier_loss: 1.1155 - val_loss3/classifier_loss: 1.2864 - val_loss1/classifier_accuracy: 0.6390 - val_loss1/classifier_top5_acc: 0.9880 - val_loss1/classifier_macro_f1score: 0.5264 - val_loss2/classifier_accuracy: 0.6535 - val_loss2/classifier_top5_acc: 0.9891 - val_loss2/classifier_macro_f1score: 0.6015 - val_loss3/classifier_accuracy: 0.6549 - val_loss3/classifier_top5_acc: 0.9872 - val_loss3/classifier_macro_f1score: 0.6127
# Learning rate:  2.9999999999999997e-06
#
# Epoch 00068: LearningRateScheduler reducing learning rate to 2.9999999999999997e-06.
# Epoch 68/70
# 224/224 [==============================] - ETA: 0s - loss: 0.6545 - loss1/classifier_loss: 0.7539 - loss2/classifier_loss: 0.4112 - loss3/classifier_loss: 0.3050 - loss1/classifier_accuracy: 0.7194 - loss1/classifier_top5_acc: 0.9950 - loss1/classifier_macro_f1score: 0.6193 - loss2/classifier_accuracy: 0.8501 - loss2/classifier_top5_acc: 0.9989 - loss2/classifier_macro_f1score: 0.8133 - loss3/classifier_accuracy: 0.8900 - loss3/classifier_top5_acc: 0.9996 - loss3/classifier_macro_f1score: 0.8656
# Epoch 00068: val_loss did not improve from 1.59662
#
# Epoch 00068: val_loss3/classifier_accuracy did not improve from 0.66267
# 224/224 [==============================] - 454s 2s/step - loss: 0.6545 - loss1/classifier_loss: 0.7539 - loss2/classifier_loss: 0.4112 - loss3/classifier_loss: 0.3050 - loss1/classifier_accuracy: 0.7194 - loss1/classifier_top5_acc: 0.9950 - loss1/classifier_macro_f1score: 0.6193 - loss2/classifier_accuracy: 0.8501 - loss2/classifier_top5_acc: 0.9989 - loss2/classifier_macro_f1score: 0.8133 - loss3/classifier_accuracy: 0.8900 - loss3/classifier_top5_acc: 0.9996 - loss3/classifier_macro_f1score: 0.8656 - val_loss: 1.9219 - val_loss1/classifier_loss: 0.9849 - val_loss2/classifier_loss: 1.1176 - val_loss3/classifier_loss: 1.2911 - val_loss1/classifier_accuracy: 0.6403 - val_loss1/classifier_top5_acc: 0.9886 - val_loss1/classifier_macro_f1score: 0.5268 - val_loss2/classifier_accuracy: 0.6540 - val_loss2/classifier_top5_acc: 0.9894 - val_loss2/classifier_macro_f1score: 0.6096 - val_loss3/classifier_accuracy: 0.6593 - val_loss3/classifier_top5_acc: 0.9872 - val_loss3/classifier_macro_f1score: 0.6269
# Learning rate:  2.9999999999999997e-06
#
# Epoch 00069: LearningRateScheduler reducing learning rate to 2.9999999999999997e-06.
# Epoch 69/70
# 224/224 [==============================] - ETA: 0s - loss: 0.6537 - loss1/classifier_loss: 0.7500 - loss2/classifier_loss: 0.4122 - loss3/classifier_loss: 0.3051 - loss1/classifier_accuracy: 0.7243 - loss1/classifier_top5_acc: 0.9947 - loss1/classifier_macro_f1score: 0.6282 - loss2/classifier_accuracy: 0.8525 - loss2/classifier_top5_acc: 0.9988 - loss2/classifier_macro_f1score: 0.8154 - loss3/classifier_accuracy: 0.8917 - loss3/classifier_top5_acc: 0.9994 - loss3/classifier_macro_f1score: 0.8729
# Epoch 00069: val_loss did not improve from 1.59662
#
# Epoch 00069: val_loss3/classifier_accuracy did not improve from 0.66267
# 224/224 [==============================] - 459s 2s/step - loss: 0.6537 - loss1/classifier_loss: 0.7500 - loss2/classifier_loss: 0.4122 - loss3/classifier_loss: 0.3051 - loss1/classifier_accuracy: 0.7243 - loss1/classifier_top5_acc: 0.9947 - loss1/classifier_macro_f1score: 0.6282 - loss2/classifier_accuracy: 0.8525 - loss2/classifier_top5_acc: 0.9988 - loss2/classifier_macro_f1score: 0.8154 - loss3/classifier_accuracy: 0.8917 - loss3/classifier_top5_acc: 0.9994 - loss3/classifier_macro_f1score: 0.8729 - val_loss: 1.9251 - val_loss1/classifier_loss: 0.9818 - val_loss2/classifier_loss: 1.1137 - val_loss3/classifier_loss: 1.2964 - val_loss1/classifier_accuracy: 0.6395 - val_loss1/classifier_top5_acc: 0.9891 - val_loss1/classifier_macro_f1score: 0.5281 - val_loss2/classifier_accuracy: 0.6537 - val_loss2/classifier_top5_acc: 0.9888 - val_loss2/classifier_macro_f1score: 0.6072 - val_loss3/classifier_accuracy: 0.6565 - val_loss3/classifier_top5_acc: 0.9880 - val_loss3/classifier_macro_f1score: 0.6177
# Learning rate:  2.9999999999999997e-06
#
# Epoch 00070: LearningRateScheduler reducing learning rate to 2.9999999999999997e-06.
# Epoch 70/70
# 224/224 [==============================] - ETA: 0s - loss: 0.6547 - loss1/classifier_loss: 0.7522 - loss2/classifier_loss: 0.4127 - loss3/classifier_loss: 0.3053 - loss1/classifier_accuracy: 0.7197 - loss1/classifier_top5_acc: 0.9944 - loss1/classifier_macro_f1score: 0.6169 - loss2/classifier_accuracy: 0.8501 - loss2/classifier_top5_acc: 0.9989 - loss2/classifier_macro_f1score: 0.8116 - loss3/classifier_accuracy: 0.8903 - loss3/classifier_top5_acc: 0.9995 - loss3/classifier_macro_f1score: 0.8628
# Epoch 00070: val_loss did not improve from 1.59662
#
# Epoch 00070: val_loss3/classifier_accuracy did not improve from 0.66267
# 224/224 [==============================] - 459s 2s/step - loss: 0.6547 - loss1/classifier_loss: 0.7522 - loss2/classifier_loss: 0.4127 - loss3/classifier_loss: 0.3053 - loss1/classifier_accuracy: 0.7197 - loss1/classifier_top5_acc: 0.9944 - loss1/classifier_macro_f1score: 0.6169 - loss2/classifier_accuracy: 0.8501 - loss2/classifier_top5_acc: 0.9989 - loss2/classifier_macro_f1score: 0.8116 - loss3/classifier_accuracy: 0.8903 - loss3/classifier_top5_acc: 0.9995 - loss3/classifier_macro_f1score: 0.8628 - val_loss: 1.9324 - val_loss1/classifier_loss: 0.9847 - val_loss2/classifier_loss: 1.1182 - val_loss3/classifier_loss: 1.3015 - val_loss1/classifier_accuracy: 0.6390 - val_loss1/classifier_top5_acc: 0.9886 - val_loss1/classifier_macro_f1score: 0.5328 - val_loss2/classifier_accuracy: 0.6518 - val_loss2/classifier_top5_acc: 0.9891 - val_loss2/classifier_macro_f1score: 0.5968 - val_loss3/classifier_accuracy: 0.6557 - val_loss3/classifier_top5_acc: 0.9872 - val_loss3/classifier_macro_f1score: 0.6230

# %% [markdown]
# ### 3) GoogLeNet Evaluate

# %%
# 1. epoch=maximum
#var = model.evaluate_generator(generate_test_for_three(),steps=int(len(x_test)/batch_sizes))
var = model.evaluate(generate_test_for_three(),steps=int(len(x_test)/batch_sizes))
print('[Test Loss: %.4f /  Test Top-1 Accuracy: %.4f / Test Top-5 Accuracy: %.4f / Test Macro f1: %.4f]\n' % (var[0],var[-3],var[-2],var[-1]))
# Out:
# Found 3588 images belonging to 7 classes.
# 28/28 [==============================] - 1678s 60s/step - loss: 2.0548 - loss1/classifier_loss: 1.0164 - loss2/classifier_loss: 1.1904 - loss3/classifier_loss: 1.3927 - loss1/classifier_accuracy: 0.6412 - loss1/classifier_top5_acc: 0.9869 - loss1/classifier_macro_f1score: 0.5219 - loss2/classifier_accuracy: 0.6523 - loss2/classifier_top5_acc: 0.9855 - loss2/classifier_macro_f1score: 0.5865 - loss3/classifier_accuracy: 0.6501 - loss3/classifier_top5_acc: 0.9860 - loss3/classifier_macro_f1score: 0.5922
# [Test Loss: 2.0548 /  Test Top-1 Accuracy: 0.6501 / Test Top-5 Accuracy: 0.9860 / Test Macro f1: 0.5922]

# %%
loss=history.history['loss']
val_loss=history.history['val_loss']
acc=history.history['loss3/classifier_accuracy']
val_acc=history.history['val_loss3/classifier_accuracy']
top5_acc=history.history['loss3/classifier_top5_acc']
val_top5_acc=history.history['val_loss3/classifier_top5_acc']
f1=history.history['loss3/classifier_macro_f1score']
val_f1=history.history['val_loss3/classifier_macro_f1score']
epochs=range(1,len(acc)+1)

data = np.array([epochs,loss,val_loss,acc,val_acc,top5_acc,val_top5_acc,f1,val_f1]).T

# %%
# data save
# epochs, loss, val_loss, acc, val_acc, top5_acc, val_top5_acc, f1, val_f1

np.savetxt(os.path.join(dir,'train_valid_output',number,model.name+'.txt'),data)

# %%
# data import
data = np.loadtxt(os.path.join(dir,'train_valid_output',number,'GoogleNet.txt'))

# %%
epochs=data[:,0]
loss=data[:,1]
val_loss=data[:,2]
acc=data[:,3]
val_acc=data[:,4]
top5_acc=data[:,5]
val_top5_acc=data[:,6]

# %%
plt.plot(epochs[1:],acc[1:],'b',label='Training 1-Acc')
plt.plot(epochs[1:],val_acc[1:],'r',label='Validation 1-Acc')
plt.title('Training and Validation Top-1 Accuracy')
plt.legend()
plt.figure()

plt.plot(epochs[1:],top5_acc[1:],'b',label='Training 5-Acc')
plt.plot(epochs[1:],val_top5_acc[1:],'r',label='Validation 5-Acc')
plt.title('Training and Validation Top-5 Accuracy')
plt.legend()
plt.figure()

plt.plot(epochs[10:],loss[10:],'b',label='Training Loss')
plt.plot(epochs[10:],val_loss[10:],'r',label='Validation Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()

# %%
# 이 아래는 내가 인위적으로 살펴보고 싶은 epoch에 대해서 결과값 출력 / Inception-V1

# %%
# 참고 : https://github.com/OverLordGoldDragon/keras-adamw

import sys
sys.path.append('/content/drive/My Drive/Colab Notebooks/Paper')
import utils
import optimizers_v2
from utils import get_weight_decays, fill_dict_in_order
from utils import reset_seeds, K_eval
from optimizers_v2 import AdamW, NadamW, SGDW

# %%
# top-5 accuracy 출력
import functools
top5_acc = functools.partial(ks.metrics.top_k_categorical_accuracy, k=5)
top5_acc.__name__ = 'top5_acc'

# %%
model=load_model(os.path.join(dir,'model_output',number,'GoogleNet','036.h5'),custom_objects={"macro_f1score": macro_f1score,"top5_acc":top5_acc,"LRN":LRN,"PoolHelper":PoolHelper, "AdamW":AdamW})

# %%
# 2. epoch=?
var = model.evaluate(generate_test_for_three(),steps=int(len(x_test)/batch_sizes))
print('[Test Loss: %.4f /  Test Top-1 Accuracy: %.4f / Test Top-5 Accuracy: %.4f / Test Macro f1: %.4f]\n' % (var[0],var[-3],var[-2],var[-1]))
# Out:
# Found 3588 images belonging to 7 classes.
# 28/28 [==============================] - 2418s 86s/step - loss: 1.7884 - loss1/classifier_loss: 1.0192 - loss2/classifier_loss: 1.0942 - loss3/classifier_loss: 1.1544 - loss1/classifier_accuracy: 0.6384 - loss1/classifier_top5_acc: 0.9866 - loss1/classifier_macro_f1score: 0.5199 - loss2/classifier_accuracy: 0.6493 - loss2/classifier_top5_acc: 0.9849 - loss2/classifier_macro_f1score: 0.5866 - loss3/classifier_accuracy: 0.6493 - loss3/classifier_top5_acc: 0.9866 - loss3/classifier_macro_f1score: 0.5937
# [Test Loss: 1.7884 /  Test Top-1 Accuracy: 0.6493 / Test Top-5 Accuracy: 0.9866 / Test Macro f1: 0.5937]
