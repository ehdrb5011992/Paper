# %%
# 모형 출처 : https://github.com/kentsommer/keras-inceptionV4/blob/master/inception_v4.py

# %% [markdown]
# # [Inception V4]

# %% [markdown]
# *KU LeeDongGyu*

# %% [markdown]
# ## Contents
# ---

# %% [markdown]
# 1. Data Preprocessing
# ```
# 1) Data Import
# 2) Data Augmentation
# ```
# 2. Support Functions & Almost Original Inception-V4
# ```
# 1) Support Functions
# 2) Almost Original Inception-V4
# 3) Inception-V4 Evaluate
# ```

# %% [markdown]
# ### Install Packages

# %% [markdown]
# ### Module

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/My Drive/Colab Notebooks/Paper
# Out:
# /content/drive/My Drive/Colab Notebooks/Paper

# %%
from f1score import macro_f1score,weighted_f1score

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import cv2
import tensorflow as tf
from tensorflow import keras as ks
from tensorflow.keras import backend as K 
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, Input, Concatenate, ZeroPadding2D ,GlobalMaxPooling2D, Reshape , Lambda , Add, Multiply
from tensorflow.keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D, Activation, BatchNormalization, AveragePooling2D , ZeroPadding2D, SeparableConv2D , LeakyReLU
from tensorflow.keras.layers import add, concatenate, multiply
from tensorflow.keras.optimizers import Adam, RMSprop , SGD
from tensorflow.keras.callbacks import EarlyStopping , LearningRateScheduler, ModelCheckpoint, CSVLogger, Callback, ReduceLROnPlateau
from tensorflow.keras.regularizers import l1,l2,l1_l2
from tensorflow.keras.models import Model , load_model , Sequential
from tensorflow.keras.utils import plot_model , to_categorical, get_file
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
os.getcwd()
# Out:
# '/content/drive/My Drive/Colab Notebooks/Paper'

# %%
print(tf.__version__)
print(ks.__version__)
# Out:
# 2.3.0
# 2.4.0

# %%
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 6033652360164599904
# , name: "/device:XLA_CPU:0"
# device_type: "XLA_CPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 13462994014568341787
# physical_device_desc: "device: XLA_CPU device"
# , name: "/device:XLA_GPU:0"
# device_type: "XLA_GPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 7839060222301083452
# physical_device_desc: "device: XLA_GPU device"
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 15473714176
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 9286059279953787778
# physical_device_desc: "device: 0, name: Tesla V100-SXM2-16GB, pci bus id: 0000:00:04.0, compute capability: 7.0"
# ]

# %%
# !cat /proc/cpuinfo
# Out:
# processor	: 0
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 85
# model name	: Intel(R) Xeon(R) CPU @ 2.00GHz
# stepping	: 3
# microcode	: 0x1
# cpu MHz		: 2000.172
# cache size	: 39424 KB
# physical id	: 0
# siblings	: 4
# core id		: 0
# cpu cores	: 2
# apicid		: 0
# initial apicid	: 0
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm mpx avx512f avx512dq rdseed adx smap clflushopt clwb avx512cd avx512bw avx512vl xsaveopt xsavec xgetbv1 xsaves arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs taa
# bogomips	: 4000.34
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 46 bits physical, 48 bits virtual
# power management:
#
# processor	: 1
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 85
# model name	: Intel(R) Xeon(R) CPU @ 2.00GHz
# stepping	: 3
# microcode	: 0x1
# cpu MHz		: 2000.172
# cache size	: 39424 KB
# physical id	: 0
# siblings	: 4
# core id		: 1
# cpu cores	: 2
# apicid		: 2
# initial apicid	: 2
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm mpx avx512f avx512dq rdseed adx smap clflushopt clwb avx512cd avx512bw avx512vl xsaveopt xsavec xgetbv1 xsaves arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs taa
# bogomips	: 4000.34
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 46 bits physical, 48 bits virtual
# power management:
#
# processor	: 2
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 85
# model name	: Intel(R) Xeon(R) CPU @ 2.00GHz
# stepping	: 3
# microcode	: 0x1
# cpu MHz		: 2000.172
# cache size	: 39424 KB
# physical id	: 0
# siblings	: 4
# core id		: 0
# cpu cores	: 2
# apicid		: 1
# initial apicid	: 1
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm mpx avx512f avx512dq rdseed adx smap clflushopt clwb avx512cd avx512bw avx512vl xsaveopt xsavec xgetbv1 xsaves arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs taa
# bogomips	: 4000.34
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 46 bits physical, 48 bits virtual
# power management:
#
# processor	: 3
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 85
# model name	: Intel(R) Xeon(R) CPU @ 2.00GHz
# stepping	: 3
# microcode	: 0x1
# cpu MHz		: 2000.172
# cache size	: 39424 KB
# physical id	: 0
# siblings	: 4
# core id		: 1
# cpu cores	: 2
# apicid		: 3
# initial apicid	: 3
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm mpx avx512f avx512dq rdseed adx smap clflushopt clwb avx512cd avx512bw avx512vl xsaveopt xsavec xgetbv1 xsaves arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs taa
# bogomips	: 4000.34
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 46 bits physical, 48 bits virtual
# power management:

# %% [markdown]
# ## 1. Data Preprocessing
# ---

# %% [markdown]
# ### 1) Data Import

# %%
# 바꿔서 살펴 볼 것들
# CALTECH, CIFAR100, FER, MIT
data_name = 'FER'
gan_type = 'No_GAN'
number = '1'
size = 299 # sizes after cropping
super_size = 330 # sizes before cropping 
input_sizes = (size,size,3)
batch_sizes = 64
weight_decay = 1e-3
epochs = 70

# %%
# 참고 : https://stackoverflow.com/questions/32419510/how-to-get-reproducible-results-in-keras/52897216#52897216
# setting the seed number for random number generation for reproducibility.

from numpy.random import seed
import random


if number=='1':
    seed_num = 200225
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)
elif number=='2':
    seed_num = 727
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)
elif number=='3':
    seed_num = 115
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)
elif number=='4':
    seed_num = 501
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)
elif number=='5':
    seed_num = 517
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)

# %%
# data import

if data_name=='FER' :
    x_train =  np.zeros(28698)
    x_valid = np.zeros(3589)
    x_test = np.zeros(3588)
    classes = 7 
    tr_center = [0.50793296, 0.50793296, 0.50793296]
elif data_name=='MIT':
    x_train = np.zeros(12466)
    x_valid = np.zeros(1564)
    x_test = np.zeros(1590)
    classes = 67 
    tr_center = [0.47916578, 0.42029615, 0.36046057]
elif data_name=='CALTECH':
    x_train = np.zeros(24510)
    x_valid = np.zeros(2980)
    x_test = np.zeros(3118)
    classes = 257
    tr_center = [0.51397761, 0.49525248, 0.46555727]
elif data_name=='CIFAR100':
    x_train = np.zeros(44923)
    x_valid = np.zeros(5077)
    x_test = np.zeros(10000)
    classes = 100
    tr_center = [0.53442983, 0.51355958, 0.46462564]

# %%
dir = os.path.join(os.getcwd(),data_name,gan_type)

# %% [markdown]
# ### 2) Data Augmentation

# %%
# 참고 : https://jkjung-avt.github.io/keras-image-cropping/

def random_crop(img, random_crop_size):
    # Note: image_data_format is 'channel_last'
    assert img.shape[2] == 3 # img.shape[2] 가 3(rgb)이 아니면 assertion error 발생
    height, width = img.shape[0], img.shape[1]
    dy, dx = random_crop_size
    x = np.random.randint(0, width - dx + 1)
    y = np.random.randint(0, height - dy + 1)
    return img[y:(y+dy), x:(x+dx), :]


def crop_generator(batches, crop_length):
    """Take as input a Keras ImageGen (Iterator) and generate random
    crops from the image batches generated by the original iterator.
    """
    while True:
        batch_x, batch_y = next(batches)
        batch_crops = np.zeros((batch_x.shape[0], crop_length, crop_length, 3))
        for i in range(batch_x.shape[0]):
            batch_crops[i] = random_crop(batch_x[i], (crop_length, crop_length))
        yield (batch_crops, batch_y)

# %%
from tensorflow.keras.preprocessing.image import img_to_array,load_img
import glob

# 데이터 전체에 대해 centering 진행함.

def read_cal_image(img_path): 
    x = img_to_array(load_img(img_path)) # x는 채널별 평균값
    y = x.shape[0] * x.shape[1]# y는 데이터별 픽셀 수 (비중)

    x = 1/255. * x # scaling하고, centering값을 뽑아냄.
    x = np.mean(x, axis=(0,1))
    
    return np.hstack([x,y])

def calculate_centered_mean(dataset_path,x_train=x_train):
    num = len(x_train)
    space = np.empty((num,4))
    i=0

    for p in glob.glob(os.path.join(dataset_path,'*/*.*')) :
        space[i] = read_cal_image(p)
        i += 1

    ratio = space[:,3] / np.sum(space[:,3])

    return np.average(space[:,0:3],axis=0,weights=ratio)


# 아래의 함수를 돌려서 나온 결과값을 중심화 값으로 설정.

# train_mean = calculate_centered_mean(os.path.join(dir,'data/train')).reshape((1,1,3))

# %%
datagen_tr = ImageDataGenerator(
    rescale=1/255.,
    horizontal_flip=True,
    featurewise_center=True,
    featurewise_std_normalization=False,
    rotation_range=10,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=[0.9,1.0],
    fill_mode = 'nearest')
datagen_val = ImageDataGenerator(rescale=1/255.,featurewise_center=True)
datagen_tes = ImageDataGenerator(rescale=1/255.,featurewise_center=True)

# 원래는 이 자리에 fit 매서드를 써야하지만, 그냥 내가 중심화함수를 만들고 적용함. 

# 중심화 설정
datagen_tr.mean = np.array(tr_center, dtype=np.float32).reshape((1,1,3)) # RGB
datagen_val.mean = np.array(tr_center, dtype=np.float32).reshape((1,1,3)) # RGB
datagen_tes.mean = np.array(tr_center, dtype=np.float32).reshape((1,1,3)) # RGB

# %%
train_batches = datagen_tr.flow_from_directory(directory=os.path.join(dir,'data/train'),target_size=(super_size,super_size),batch_size=batch_sizes,class_mode='categorical') # fer : 28698 / mit : 12466 / caltech : 24509 / cifar : 44923
train_generator= crop_generator(train_batches, size)
valid_generator = datagen_val.flow_from_directory(directory=os.path.join(dir,'data/valid'),target_size=(size,size),batch_size=batch_sizes,class_mode='categorical') # fer : 3589 / mit : 1564 / caltech : 2980 / cifar : 5077
test_generator = datagen_tes.flow_from_directory(directory=os.path.join(dir,'data/test'),target_size=(size,size),batch_size=batch_sizes,class_mode='categorical') # fer : 3588 / mit : 1590 / caltech : 3118 / cifar : 10000
# Out:
# Found 28698 images belonging to 7 classes.
# Found 3589 images belonging to 7 classes.
# Found 3588 images belonging to 7 classes.

# %% [markdown]
# ## 2. Support Functions & Almost Original Inception-V4
# ---

# %% [markdown]
# ### 1) Support Functions

# %%
# def lr_schedule(epoch):
#     init_lr = 1e-4
#     k = 0.04
#     lr = init_lr * np.exp(-k*epoch)
#     print('Learning rate: ', lr)
#     return lr

def lr_schedule(epoch):
    lr = 1e-3
    if epoch < 30:
        lr = lr
    elif epoch < 60 :
        lr = lr * 0.1
    else:
        lr = lr * 0.01
    print('Learning rate: ', lr)
    return lr

# %%
def conv2d_bn(x, nb_filter, num_row, num_col, padding='same', strides=(1, 1), use_bias=False, weight_decay = weight_decay):

    channel_axis = -1

    x = Conv2D(nb_filter, (num_row, num_col), strides=strides, padding=padding, use_bias=use_bias, kernel_regularizer=l2(weight_decay), kernel_initializer='he_uniform')(x)
    x = BatchNormalization(axis=channel_axis)(x)
    x = Activation('relu')(x)
    return x

# %%
def block_inception_a(input):

    channel_axis = -1

    branch_0 = conv2d_bn(input, 96, 1, 1)

    branch_1 = conv2d_bn(input, 64, 1, 1)
    branch_1 = conv2d_bn(branch_1, 96, 3, 3)

    branch_2 = conv2d_bn(input, 64, 1, 1)
    branch_2 = conv2d_bn(branch_2, 96, 3, 3)
    branch_2 = conv2d_bn(branch_2, 96, 3, 3)

    branch_3 = AveragePooling2D((3,3), strides=(1,1), padding='same')(input)
    branch_3 = conv2d_bn(branch_3, 96, 1, 1)

    x = concatenate([branch_0, branch_1, branch_2, branch_3], axis=channel_axis)
    return x

def block_inception_b(input):

    channel_axis = -1

    branch_0 = conv2d_bn(input, 384, 1, 1)

    branch_1 = conv2d_bn(input, 192, 1, 1)
    branch_1 = conv2d_bn(branch_1, 224, 1, 7)
    branch_1 = conv2d_bn(branch_1, 256, 7, 1)

    branch_2 = conv2d_bn(input, 192, 1, 1)
    branch_2 = conv2d_bn(branch_2, 192, 7, 1)
    branch_2 = conv2d_bn(branch_2, 224, 1, 7)
    branch_2 = conv2d_bn(branch_2, 224, 7, 1)
    branch_2 = conv2d_bn(branch_2, 256, 1, 7)

    branch_3 = AveragePooling2D((3,3), strides=(1,1), padding='same')(input)
    branch_3 = conv2d_bn(branch_3, 128, 1, 1)

    x = concatenate([branch_0, branch_1, branch_2, branch_3], axis=channel_axis)
    return x

def block_inception_c(input):

    channel_axis = -1

    branch_0 = conv2d_bn(input, 256, 1, 1)

    branch_1 = conv2d_bn(input, 384, 1, 1)
    branch_10 = conv2d_bn(branch_1, 256, 1, 3)
    branch_11 = conv2d_bn(branch_1, 256, 3, 1)
    branch_1 = concatenate([branch_10, branch_11], axis=channel_axis)


    branch_2 = conv2d_bn(input, 384, 1, 1)
    branch_2 = conv2d_bn(branch_2, 448, 3, 1)
    branch_2 = conv2d_bn(branch_2, 512, 1, 3)
    branch_20 = conv2d_bn(branch_2, 256, 1, 3)
    branch_21 = conv2d_bn(branch_2, 256, 3, 1)
    branch_2 = concatenate([branch_20, branch_21], axis=channel_axis)

    branch_3 = AveragePooling2D((3, 3), strides=(1, 1), padding='same')(input)
    branch_3 = conv2d_bn(branch_3, 256, 1, 1)

    x = concatenate([branch_0, branch_1, branch_2, branch_3], axis=channel_axis)
    return x

# %%
def block_reduction_a(input):

    channel_axis = -1

    branch_0 = conv2d_bn(input, 384, 3, 3, strides=(2,2), padding='valid')

    branch_1 = conv2d_bn(input, 192, 1, 1)
    branch_1 = conv2d_bn(branch_1, 224, 3, 3)
    branch_1 = conv2d_bn(branch_1, 256, 3, 3, strides=(2,2), padding='valid')

    branch_2 = MaxPooling2D((3,3), strides=(2,2), padding='valid')(input)

    x = concatenate([branch_0, branch_1, branch_2], axis=channel_axis)
    return x

def block_reduction_b(input):

    channel_axis = -1

    branch_0 = conv2d_bn(input, 192, 1, 1)
    branch_0 = conv2d_bn(branch_0, 192, 3, 3, strides=(2, 2), padding='valid')

    branch_1 = conv2d_bn(input, 256, 1, 1)
    branch_1 = conv2d_bn(branch_1, 256, 1, 7)
    branch_1 = conv2d_bn(branch_1, 320, 7, 1)
    branch_1 = conv2d_bn(branch_1, 320, 3, 3, strides=(2,2), padding='valid')

    branch_2 = MaxPooling2D((3, 3), strides=(2, 2), padding='valid')(input)

    x = concatenate([branch_0, branch_1, branch_2], axis=channel_axis)
    return x

# %% [markdown]
# ### 2) Almost Original Inception-V4

# %%
def inception_v4_base(input):

    channel_axis = -1

    net = conv2d_bn(input, 32, 3, 3, strides=(2,2), padding='valid')
    net = conv2d_bn(net, 32, 3, 3, padding='valid')
    net = conv2d_bn(net, 64, 3, 3)

    branch_0 = MaxPooling2D((3,3), strides=(2,2), padding='valid')(net)

    branch_1 = conv2d_bn(net, 96, 3, 3, strides=(2,2), padding='valid')

    net = concatenate([branch_0, branch_1], axis=channel_axis)

    branch_0 = conv2d_bn(net, 64, 1, 1)
    branch_0 = conv2d_bn(branch_0, 96, 3, 3, padding='valid')

    branch_1 = conv2d_bn(net, 64, 1, 1)
    branch_1 = conv2d_bn(branch_1, 64, 1, 7)
    branch_1 = conv2d_bn(branch_1, 64, 7, 1)
    branch_1 = conv2d_bn(branch_1, 96, 3, 3, padding='valid')

    net = concatenate([branch_0, branch_1], axis=channel_axis)

    branch_0 = conv2d_bn(net, 192, 3, 3, strides=(2,2), padding='valid')
    branch_1 = MaxPooling2D((3,3), strides=(2,2), padding='valid')(net)

    net = concatenate([branch_0, branch_1], axis=channel_axis)

    # 35 x 35 x 384
    # 4 x Inception-A blocks
    for idx in range(4):
    	net = block_inception_a(net)

    # 35 x 35 x 384
    # Reduction-A block
    net = block_reduction_a(net)

    # 17 x 17 x 1024
    # 7 x Inception-B blocks
    for idx in range(7):
    	net = block_inception_b(net)

    # 17 x 17 x 1024
    # Reduction-B block
    net = block_reduction_b(net)

    # 8 x 8 x 1536
    # 3 x Inception-C blocks
    for idx in range(3):
    	net = block_inception_c(net)

    return net

# %%
def Inception_v4(input_shape, classes, name = None, weight_decay = weight_decay):

    inputs = Input(shape=input_shape)

    # Make inception base
    x = inception_v4_base(inputs)


    # Final pooling and prediction
    # 1 x 1 x 1536
    x = AveragePooling2D((8,8), padding='valid')(x)
    x = Dropout(0.2)(x)
    x = Flatten()(x)
    # 1536
    x = Dense(classes, use_bias=False, kernel_regularizer=l2(weight_decay), activation='softmax')(x)

    model = Model(inputs, x, name=name)

  
    return model

# %%
model = Inception_v4(input_sizes, classes=classes, name='Inception_v4')

# %%
model.summary()
# Out:
# Model: "Inception_v4"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 299, 299, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 149, 149, 32) 864         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 149, 149, 32) 128         conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 149, 149, 32) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 147, 147, 32) 9216        activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 147, 147, 32) 128         conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 147, 147, 32) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 147, 147, 64) 18432       activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 147, 147, 64) 256         conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 147, 147, 64) 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 73, 73,
0][0]
# __________________________________________________________________________________________________
# batch_normalization_144 (BatchN (None, 8, 8, 448)    1792        conv2d_144[0][0]
# __________________________________________________________________________________________________
# activation_144 (Activation)     (None, 8, 8, 448)    0           batch_normalization_144[0][0]
# __________________________________________________________________________________________________
# conv2d_140 (Conv2D)             (None, 8, 8, 384)    589824      concatenate_21[0][0]
# __________________________________________________________________________________________________
# conv2d_145 (Conv2D)             (None, 8, 8, 512)    688128      activation_144[0][0]
# __________________________________________________________________________________________________
# batch_normalization_140 (BatchN (None, 8, 8, 384)    1536        conv2d_140[0][0]
# __________________________________________________________________________________________________
# batch_normalization_145 (BatchN (None, 8, 8, 512)    2048        conv2d_145[0][0]
# __________________________________________________________________________________________________
# activation_140 (Activation)     (None, 8, 8, 384)    0           batch_normalization_140[0][0]
# __________________________________________________________________________________________________
# activation_145 (Activation)     (None, 8, 8, 512)    0           batch_normalization_145[0][0]
# __________________________________________________________________________________________________
# conv2d_141 (Conv2D)             (None, 8, 8, 256)    294912      activation_140[0][0]
# __________________________________________________________________________________________________
# conv2d_142 (Conv2D)             (None, 8, 8, 256)    294912      activation_140[0][0]
# __________________________________________________________________________________________________
# conv2d_146 (Conv2D)             (None, 8, 8, 256)    393216      activation_145[0][0]
# __________________________________________________________________________________________________
# conv2d_147 (Conv2D)             (None, 8, 8, 256)    393216      activation_145[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_13 (AveragePo (None, 8, 8, 1536)   0           concatenate_21[0][0]
# __________________________________________________________________________________________________
# conv2d_139 (Conv2D)             (None, 8, 8, 256)    393216      concatenate_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_141 (BatchN (None, 8, 8, 256)    1024        conv2d_141[0][0]
# __________________________________________________________________________________________________
# batch_normalization_142 (BatchN (None, 8, 8, 256)    1024        conv2d_142[0][0]
# __________________________________________________________________________________________________
# batch_normalization_146 (BatchN (None, 8, 8, 256)    1024        conv2d_146[0][0]
# __________________________________________________________________________________________________
# batch_normalization_147 (BatchN (None, 8, 8, 256)    1024        conv2d_147[0][0]
# __________________________________________________________________________________________________
# conv2d_148 (Conv2D)             (None, 8, 8, 256)    393216      average_pooling2d_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_139 (BatchN (None, 8, 8, 256)    1024        conv2d_139[0][0]
# __________________________________________________________________________________________________
# activation_141 (Activation)     (None, 8, 8, 256)    0           batch_normalization_141[0][0]
# __________________________________________________________________________________________________
# activation_142 (Activation)     (None, 8, 8, 256)    0           batch_normalization_142[0][0]
# __________________________________________________________________________________________________
# activation_146 (Activation)     (None, 8, 8, 256)    0           batch_normalization_146[0][0]
# __________________________________________________________________________________________________
# activation_147 (Activation)     (None, 8, 8, 256)    0           batch_normalization_147[0][0]
# __________________________________________________________________________________________________
# batch_normalization_148 (BatchN (None, 8, 8, 256)    1024        conv2d_148[0][0]
# __________________________________________________________________________________________________
# activation_139 (Activation)     (None, 8, 8, 256)    0           batch_normalization_139[0][0]
# __________________________________________________________________________________________________
# concatenate_22 (Concatenate)    (None, 8, 8, 512)    0           activation_141[0][0]
#                                                                  activation_142[0][0]
# __________________________________________________________________________________________________
# concatenate_23 (Concatenate)    (None, 8, 8, 512)    0           activation_146[0][0]
#                                                                  activation_147[0][0]
# __________________________________________________________________________________________________
# activation_148 (Activation)     (None, 8, 8, 256)    0           batch_normalization_148[0][0]
# __________________________________________________________________________________________________
# concatenate_24 (Concatenate)    (None, 8, 8, 1536)   0           activation_139[0][0]
#                                                                  concatenate_22[0][0]
#                                                                  concatenate_23[0][0]
#                                                                  activation_148[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_14 (AveragePo (None, 1, 1, 1536)   0           concatenate_24[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 1, 1, 1536)   0           average_pooling2d_14[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 1536)         0           dropout[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 7)            10752       flatten[0][0]
# ==================================================================================================
# Total params: 41,216,736
# Trainable params: 41,153,568
# Non-trainable params: 63,168
# __________________________________________________________________________________________________

# %%
# 폴더 생성

os.makedirs(os.path.join(dir,'model_output',number,model.name), exist_ok=True)
os.makedirs(os.path.join(dir,'train_valid_output',number), exist_ok=True)

# %%
# 참고 : https://github.com/OverLordGoldDragon/keras-adamw

import sys
sys.path.append('/content/drive/My Drive/Colab Notebooks/Paper')
import utils
import optimizers_v2
from utils import get_weight_decays, fill_dict_in_order
from utils import reset_seeds, K_eval
from optimizers_v2 import AdamW, NadamW, SGDW

# %%
# top-5 accuracy 출력
import functools
top5_acc = functools.partial(ks.metrics.top_k_categorical_accuracy, k=5)
top5_acc.__name__ = 'top5_acc'

# %%
#optimizer = SGDW(model=model, use_cosine_annealing=False, total_iterations = len(x_train) // batch_sizes, nesterov=True, momentum=0.9)
optimizer = AdamW(model=model, use_cosine_annealing=False, total_iterations = len(x_train) // batch_sizes)
#optimizer = Adam()
filepath =  os.path.join(dir,'model_output',number,model.name,'{epoch:03d}.h5')

callbacks_list = [ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_weights_only=False, save_best_only=True, mode='min'),
                  ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_weights_only=False, save_best_only=True, mode='max'),
                  #ReduceLROnPlateau(monitor='val_loss',patience=3,factor=0.1,min_lr=1e-5),
                  LearningRateScheduler(lr_schedule,verbose=1)
                  ]
                  
model.compile(optimizer, loss = 'categorical_crossentropy', metrics=['accuracy',top5_acc,macro_f1score])

# %%
######## flow_from_directory
history = model.fit(train_generator, steps_per_epoch=int(len(x_train)/batch_sizes),  validation_data = valid_generator, epochs=epochs , verbose=1 , callbacks = callbacks_list , validation_steps=int(len(x_valid)/batch_sizes))
# Out:
# Learning rate:  0.001
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 1/70
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_1/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_2/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_3/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_6/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_7/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_4/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_8/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_5/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_9/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_10/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_14/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_12/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_15/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_11/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_13/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_16/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_17/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_21/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_19/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_22/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_18/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_20/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_23/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_24/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_28/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_26/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_29/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_25/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_27/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_30/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_31/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_35/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_33/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_36/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_32/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_34/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_37/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_38/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_40/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_41/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_39/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_42/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_47/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_48/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_44/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_49/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_45/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_50/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_43/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_46/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_51/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_52/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_57/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_58/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_54/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_59/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_55/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_60/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_53/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_56/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_61/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_62/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d_67/kernel:0
# 0.0(L1), 4.7245561370197044e-05(L2) weight decay set for conv2d
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 5/70
# 448/448 [==============================] - ETA: 0s - loss: 1.2098 - accuracy: 0.5402 - top5_acc: 0.9756 - macro_f1score: 0.3098
# Epoch 00005: val_loss improved from 1.69640 to 1.26127, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/Inception_v4/005.h5
#
# Epoch 00005: val_accuracy improved from 0.44922 to 0.52260, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/Inception_v4/005.h5
# 448/448 [==============================] - 741s 2s/step - loss: 1.2098 - accuracy: 0.5402 - top5_acc: 0.9756 - macro_f1score: 0.3098 - val_loss: 1.2613 - val_accuracy: 0.5226 - val_top5_acc: 0.9718 - val_macro_f1score: 0.2713
# Learning rate:  0.001
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 6/70
# 448/448 [==============================] - ETA: 0s - loss: 1.1582 - accuracy: 0.5624 - top5_acc: 0.9792 - macro_f1score: 0.3456
# Epoch 00006: val_loss did not improve from 1.26127
#
# Epoch 00006: val_accuracy did not improve from 0.52260
# 448/448 [==============================] - 727s 2s/step - loss: 1.1582 - accuracy: 0.5624 - top5_acc: 0.9792 - macro_f1score: 0.3456 - val_loss: 1.2868 - val_accuracy: 0.5112 - val_top5_acc: 0.9688 - val_macro_f1score: 0.2637
# Learning rate:  0.001
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 7/70
# 448/448 [==============================] - ETA: 0s - loss: 1.1240 - accuracy: 0.5791 - top5_acc: 0.9797 - macro_f1score: 0.3721
# Epoch 00007: val_loss did not improve from 1.26127
#
# Epoch 00007: val_accuracy improved from 0.52260 to 0.52762, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/Inception_v4/007.h5
# 448/448 [==============================] - 728s 2s/step - loss: 1.1240 - accuracy: 0.5791 - top5_acc: 0.9797 - macro_f1score: 0.3721 - val_loss: 1.3822 - val_accuracy: 0.5276 - val_top5_acc: 0.9707 - val_macro_f1score: 0.3659
# Learning rate:  0.001
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 8/70
# 448/448 [==============================] - ETA: 0s - loss: 1.1004 - accuracy: 0.5871 - top5_acc: 0.9821 - macro_f1score: 0.3921
# Epoch 00008: val_loss did not improve from 1.26127
#
# Epoch 00008: val_accuracy improved from 0.52762 to 0.53209, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/Inception_v4/008.h5
# 448/448 [==============================] - 733s 2s/step - loss: 1.1004 - accuracy: 0.5871 - top5_acc: 0.9821 - macro_f1score: 0.3921 - val_loss: 1.3114 - val_accuracy: 0.5321 - val_top5_acc: 0.9749 - val_macro_f1score: 0.3586
# Learning rate:  0.001
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 9/70
# 448/448 [==============================] - ETA: 0s - loss: 1.0701 - accuracy: 0.5959 - top5_acc: 0.9831 - macro_f1score: 0.4120
# Epoch 00009: val_loss did not improve from 1.26127
#
# Epoch 00009: val_accuracy did not improve from 0.53209
# 448/448 [==============================] - 733s 2s/step - loss: 1.0701 - accuracy: 0.5959 - top5_acc: 0.9831 - macro_f1score: 0.4120 - val_loss: 1.4663 - val_accuracy: 0.5271 - val_top5_acc: 0.9746 - val_macro_f1score: 0.3382
# Learning rate:  0.001
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 10/70
# 448/448 [==============================] - ETA: 0s - loss: 1.0570 - accuracy: 0.6044 - top5_acc: 0.9844 - macro_f1score: 0.4168
# Epoch 00010: val_loss improved from 1.26127 to 1.25378, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/Inception_v4/010.h5
#
# Epoch 00010: val_accuracy improved from 0.53209 to 0.53320, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/Inception_v4/010.h5
# 448/448 [==============================] - 723s 2s/step - loss: 1.0570 - accuracy: 0.6044 - top5_acc: 0.9844 - macro_f1score: 0.4168 - val_loss: 1.2538 - val_accuracy: 0.5332 - val_top5_acc: 0.9752 - val_macro_f1score: 0.3508
# Learning rate:  0.001
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 11/70
# 448/448 [==============================] - ETA: 0s - loss: 1.0442 - accuracy: 0.6067 - top5_acc: 0.9845 - macro_f1score: 0.4299
# Epoch 00011: val_loss improved from 1.25378 to 1.12013, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/Inception_v4/011.h5
#
# Epoch 00011: val_accuracy improved from 0.53320 to 0.56641, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/Inception_v4/011.h5
# 448/448 [==============================] - 731s 2s/step - loss: 1.0442 - accuracy: 0.6067 - top5_acc: 0.9845 - macro_f1score: 0.4299 - val_loss: 1.1201 - val_accuracy: 0.5664 - val_top5_acc: 0.9805 - val_macro_f1score: 0.3845
# Learning rate:  0.001
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 12/70
# 448/448 [==============================] - ETA: 0s - loss: 1.0241 - accuracy: 0.6134 - top5_acc: 0.9867 - macro_f1score: 0.4372
# Epoch 00012: val_loss did not improve from 1.12013
#
# Epoch 00012: val_accuracy did not improve from 0.56641
# 448/448 [==============================] - 714s 2s/step - loss: 1.0241 - accuracy: 0.6134 - top5_acc: 0.9867 - macro_f1score: 0.4372 - val_loss: 1.1325 - val_accuracy: 0.5664 - val_top5_acc: 0.9838 - val_macro_f1score: 0.4079
# Learning rate:  0.001
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 13/70
# 448/448 [==============================] - ETA: 0s - loss: 1.0111 - accuracy: 0.6188 - top5_acc: 0.9866 - macro_f1score: 0.4485
# Epoch 00013: val_loss did not improve from 1.12013
#
# Epoch 00013: val_accuracy improved from 0.56641 to 0.56780, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/Inception_v4/013.h5
# 448/448 [==============================] - 716s 2s/step - loss: 1.0111 - accuracy: 0.6188 - top5_acc: 0.9866 - macro_f1score: 0.4485 - val_loss: 1.2160 - val_accuracy: 0.5678 - val_top5_acc: 0.9743 - val_macro_f1score: 0.4094
# Learning rate:  0.001
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 14/70
# 448/448 [==============================] - ETA: 0s - loss: 0.9905 - accuracy: 0.6293 - top5_acc: 0.9869 - macro_f1score: 0.4660
# Epoch 00014: val_loss did not improve from 1.12013
#
# Epoch 00014: val_accuracy improved from 0.56780 to 0.56920, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/Inception_v4/014.h5
# 448/448 [==============================] - 710s 2s/step - loss: 0.9905 - accuracy: 0.6293 - top5_acc: 0.9869 - macro_f1score: 0.4660 - val_loss: 1.1522 - val_accuracy: 0.5692 - val_top5_acc: 0.9833 - val_macro_f1score: 0.4008
# Learning rate:  0.001
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 15/70
# 448/448 [==============================] - ETA: 0s - loss: 0.9814 - accuracy: 0.6324 - top5_acc: 0.9875 - macro_f1score: 0.4687
# Epoch 00015: val_loss did not improve from 1.12013
#
# Epoch 00015: val_accuracy did not improve from 0.56920
# 448/448 [==============================] - 710s 2s/step - loss: 0.9814 - accuracy: 0.6324 - top5_acc: 0.9875 - macro_f1score: 0.4687 - val_loss: 1.3240 - val_accuracy: 0.5499 - val_top5_acc: 0.9704 - val_macro_f1score: 0.3563
# Learning rate:  0.001
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 16/70
# 448/448 [==============================] - ETA: 0s - loss: 0.9758 - accuracy: 0.6317 - top5_acc: 0.9883 - macro_f1score: 0.4705
# Epoch 00016: val_loss improved from 1.12013 to 1.07519, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/Inception_v4/016.h5
#
# Epoch 00016: val_accuracy improved from 0.56920 to 0.58761, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/Inception_v4/016.h5
# 448/448 [==============================] - 724s 2s/step - loss: 0.9758 - accuracy: 0.6317 - top5_acc: 0.9883 - macro_f1score: 0.4705 - val_loss: 1.0752 - val_accuracy: 0.5876 - val_top5_acc: 0.9847 - val_macro_f1score: 0.4389
# Learning rate:  0.001
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 17/70
# 448/448 [==============================] - ETA: 0s - loss: 0.9492 - accuracy: 0.6449 - top5_acc: 0.9889 - macro_f1score: 0.4919
# Epoch 00017: val_loss improved from 1.07519 to 1.01624, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/Inception_v4/017.h5
#
# Epoch 00017: val_accuracy improved from 0.58761 to 0.61775, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/Inception_v4/017.h5
# 448/448 [==============================] - 736s 2s/step - loss: 0.9492 - accuracy: 0.6449 - top5_acc: 0.9889 - macro_f1score: 0.4919 - val_loss: 1.0162 - val_accuracy: 0.6177 - val_top5_acc: 0.9877 - val_macro_f1score: 0.4720
# Learning rate:  0.001
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 18/70
# 448/448 [==============================] - ETA: 0s - loss: 0.9350 - accuracy: 0.6496 - top5_acc: 0.9899 - macro_f1score: 0.4988
# Epoch 00018: val_loss did not improve from 1.01624
#
# Epoch 00018: val_accuracy did not improve from 0.61775
# 448/448 [==============================] - 710s 2s/step - loss: 0.9350 - accuracy: 0.6496 - top5_acc: 0.9899 - macro_f1score: 0.4988 - val_loss: 1.5660 - val_accuracy: 0.4874 - val_top5_acc: 0.9760 - val_macro_f1score: 0.3296
# Learning rate:  0.001
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 19/70
# 448/448 [==============================] - ETA: 0s - loss: 0.9244 - accuracy: 0.6541 - top5_acc: 0.9898 - macro_f1score: 0.5106
# Epoch 00019: val_loss did not improve from 1.01624
#
# Epoch 00019: val_accuracy did not improve from 0.61775
# 448/448 [==============================] - 710s 2s/step - loss: 0.9244 - accuracy: 0.6541 - top5_acc: 0.9898 - macro_f1score: 0.5106 - val_loss: 1.1760 - val_accuracy: 0.6013 - val_top5_acc: 0.9788 - val_macro_f1score: 0.4346
# Learning rate:  0.001
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 20/70
# 448/448 [==============================] - ETA: 0s - loss: 0.9033 - accuracy: 0.6598 - top5_acc: 0.9913 - macro_f1score: 0.5215
# Epoch 00020: val_loss did not improve from 1.01624
#
# Epoch 00020: val_accuracy did not improve from 0.61775
# 448/448 [==============================] - 707s 2s/step - loss: 0.9033 - accuracy: 0.6598 - top5_acc: 0.9913 - macro_f1score: 0.5215 - val_loss: 1.1421 - val_accuracy: 0.5826 - val_top5_acc: 0.9855 - val_macro_f1score: 0.4504
# Learning rate:  0.001
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 21/70
# 448/448 [==============================] - ETA: 0s - loss: 0.8968 - accuracy: 0.6693 - top5_acc: 0.9903 - macro_f1score: 0.5255
# Epoch 00021: val_loss did not improve from 1.01624
#
# Epoch 00021: val_accuracy improved from 0.61775 to 0.63421, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/Inception_v4/021.h5
# 448/448 [==============================] - 714s 2s/step - loss: 0.8968 - accuracy: 0.6693 - top5_acc: 0.9903 - macro_f1score: 0.5255 - val_loss: 1.0317 - val_accuracy: 0.6342 - val_top5_acc: 0.9844 - val_macro_f1score: 0.4705
# Learning rate:  0.001
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 22/70
# 448/448 [==============================] - ETA: 0s - loss: 0.8697 - accuracy: 0.6736 - top5_acc: 0.9924 - macro_f1score: 0.5428
# Epoch 00022: val_loss did not improve from 1.01624
#
# Epoch 00022: val_accuracy did not improve from 0.63421
# 448/448 [==============================] - 707s 2s/step - loss: 0.8697 - accuracy: 0.6736 - top5_acc: 0.9924 - macro_f1score: 0.5428 - val_loss: 1.1377 - val_accuracy: 0.5778 - val_top5_acc: 0.9816 - val_macro_f1score: 0.3817
# Learning rate:  0.001
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 23/70
# 448/448 [==============================] - ETA: 0s - loss: 0.8617 - accuracy: 0.6783 - top5_acc: 0.9923 - macro_f1score: 0.5563
# Epoch 00023: val_loss did not improve from 1.01624
#
# Epoch 00023: val_accuracy did not improve from 0.63421
# 448/448 [==============================] - 706s 2s/step - loss: 0.8617 - accuracy: 0.6783 - top5_acc: 0.9923 - macro_f1score: 0.5563 - val_loss: 1.0707 - val_accuracy: 0.6258 - val_top5_acc: 0.9855 - val_macro_f1score: 0.4773
# Learning rate:  0.001
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 24/70
# 448/448 [==============================] - ETA: 0s - loss: 0.8380 - accuracy: 0.6876 - top5_acc: 0.9933 - macro_f1score: 0.5591
# Epoch 00024: val_loss did not improve from 1.01624
#
# Epoch 00024: val_accuracy improved from 0.63421 to 0.63700, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/Inception_v4/024.h5
# 448/448 [==============================] - 712s 2s/step - loss: 0.8380 - accuracy: 0.6876 - top5_acc: 0.9933 - macro_f1score: 0.5591 - val_loss: 1.0395 - val_accuracy: 0.6370 - val_top5_acc: 0.9855 - val_macro_f1score: 0.5060
# Learning rate:  0.001
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 25/70
# 448/448 [==============================] - ETA: 0s - loss: 0.8229 - accuracy: 0.6912 - top5_acc: 0.9924 - macro_f1score: 0.5756
# Epoch 00025: val_loss did not improve from 1.01624
#
# Epoch 00025: val_accuracy did not improve from 0.63700
# 448/448 [==============================] - 707s 2s/step - loss: 0.8229 - accuracy: 0.6912 - top5_acc: 0.9924 - macro_f1score: 0.5756 - val_loss: 1.0668 - val_accuracy: 0.6222 - val_top5_acc: 0.9827 - val_macro_f1score: 0.4639
# Learning rate:  0.001
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 26/70
# 448/448 [==============================] - ETA: 0s - loss: 0.8038 - accuracy: 0.7035 - top5_acc: 0.9933 - macro_f1score: 0.5851
# Epoch 00026: val_loss improved from 1.01624 to 0.99875, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/Inception_v4/026.h5
#
# Epoch 00026: val_accuracy did not improve from 0.63700
# 448/448 [==============================] - 707s 2s/step - loss: 0.8038 - accuracy: 0.7035 - top5_acc: 0.9933 - macro_f1score: 0.5851 - val_loss: 0.9987 - val_accuracy: 0.6306 - val_top5_acc: 0.9886 - val_macro_f1score: 0.5015
# Learning rate:  0.001
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 27/70
# 448/448 [==============================] - ETA: 0s - loss: 0.7883 - accuracy: 0.7092 - top5_acc: 0.9929 - macro_f1score: 0.6007
# Epoch 00027: val_loss did not improve from 0.99875
#
# Epoch 00027: val_accuracy did not improve from 0.63700
# 448/448 [==============================] - 725s 2s/step - loss: 0.7883 - accuracy: 0.7092 - top5_acc: 0.9929 - macro_f1score: 0.6007 - val_loss: 1.0625 - val_accuracy: 0.6155 - val_top5_acc: 0.9847 - val_macro_f1score: 0.4867
# Learning rate:  0.001
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 28/70
# 448/448 [==============================] - ETA: 0s - loss: 0.7733 - accuracy: 0.7160 - top5_acc: 0.9937 - macro_f1score: 0.6106
# Epoch 00028: val_loss did not improve from 0.99875
#
# Epoch 00028: val_accuracy improved from 0.63700 to 0.64342, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/Inception_v4/028.h5
# 448/448 [==============================] - 738s 2s/step - loss: 0.7733 - accuracy: 0.7160 - top5_acc: 0.9937 - macro_f1score: 0.6106 - val_loss: 1.0367 - val_accuracy: 0.6434 - val_top5_acc: 0.9866 - val_macro_f1score: 0.5211
# Learning rate:  0.001
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 29/70
# 448/448 [==============================] - ETA: 0s - loss: 0.7494 - accuracy: 0.7202 - top5_acc: 0.9950 - macro_f1score: 0.6256
# Epoch 00029: val_loss did not improve from 0.99875
#
# Epoch 00029: val_accuracy did not improve from 0.64342
# 448/448 [==============================] - 732s 2s/step - loss: 0.7494 - accuracy: 0.7202 - top5_acc: 0.9950 - macro_f1score: 0.6256 - val_loss: 1.0219 - val_accuracy: 0.6370 - val_top5_acc: 0.9886 - val_macro_f1score: 0.5172
# Learning rate:  0.001
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 30/70
# 448/448 [==============================] - ETA: 0s - loss: 0.7399 - accuracy: 0.7232 - top5_acc: 0.9953 - macro_f1score: 0.6270
# Epoch 00030: val_loss improved from 0.99875 to 0.98001, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/Inception_v4/030.h5
#
# Epoch 00030: val_accuracy improved from 0.64342 to 0.65458, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/Inception_v4/030.h5
# 448/448 [==============================] - 736s 2s/step - loss: 0.7399 - accuracy: 0.7232 - top5_acc: 0.9953 - macro_f1score: 0.6270 - val_loss: 0.9800 - val_accuracy: 0.6546 - val_top5_acc: 0.9874 - val_macro_f1score: 0.5456
# Learning rate:  0.0001
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 31/70
# 448/448 [==============================] - ETA: 0s - loss: 0.5991 - accuracy: 0.7816 - top5_acc: 0.9974 - macro_f1score: 0.6986
# Epoch 00031: val_loss improved from 0.98001 to 0.89971, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/Inception_v4/031.h5
#
# Epoch 00031: val_accuracy improved from 0.65458 to 0.69085, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/Inception_v4/031.h5
# 448/448 [==============================] - 728s 2s/step - loss: 0.5991 - accuracy: 0.7816 - top5_acc: 0.9974 - macro_f1score: 0.6986 - val_loss: 0.8997 - val_accuracy: 0.6908 - val_top5_acc: 0.9916 - val_macro_f1score: 0.5942
# Learning rate:  0.0001
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 32/70
# 448/448 [==============================] - ETA: 0s - loss: 0.5394 - accuracy: 0.8040 - top5_acc: 0.9973 - macro_f1score: 0.7342
# Epoch 00032: val_loss did not improve from 0.89971
#
# Epoch 00032: val_accuracy improved from 0.69085 to 0.69113, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/Inception_
#
# Epoch 00038: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 38/70
# 448/448 [==============================] - ETA: 0s - loss: 0.4092 - accuracy: 0.8520 - top5_acc: 0.9985 - macro_f1score: 0.7932
# Epoch 00038: val_loss did not improve from 0.89971
#
# Epoch 00038: val_accuracy did not improve from 0.69252
# 448/448 [==============================] - 712s 2s/step - loss: 0.4092 - accuracy: 0.8520 - top5_acc: 0.9985 - macro_f1score: 0.7932 - val_loss: 1.0338 - val_accuracy: 0.6875 - val_top5_acc: 0.9916 - val_macro_f1score: 0.6309
# Learning rate:  0.0001
#
# Epoch 00039: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 39/70
# 448/448 [==============================] - ETA: 0s - loss: 0.3920 - accuracy: 0.8602 - top5_acc: 0.9993 - macro_f1score: 0.8000
# Epoch 00039: val_loss did not improve from 0.89971
#
# Epoch 00039: val_accuracy did not improve from 0.69252
# 448/448 [==============================] - 710s 2s/step - loss: 0.3920 - accuracy: 0.8602 - top5_acc: 0.9993 - macro_f1score: 0.8000 - val_loss: 1.0561 - val_accuracy: 0.6908 - val_top5_acc: 0.9902 - val_macro_f1score: 0.6169
# Learning rate:  0.0001
#
# Epoch 00040: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 40/70
# 448/448 [==============================] - ETA: 0s - loss: 0.3801 - accuracy: 0.8612 - top5_acc: 0.9990 - macro_f1score: 0.8029
# Epoch 00040: val_loss did not improve from 0.89971
#
# Epoch 00040: val_accuracy did not improve from 0.69252
# 448/448 [==============================] - 708s 2s/step - loss: 0.3801 - accuracy: 0.8612 - top5_acc: 0.9990 - macro_f1score: 0.8029 - val_loss: 1.0897 - val_accuracy: 0.6747 - val_top5_acc: 0.9897 - val_macro_f1score: 0.6052
# Learning rate:  0.0001
#
# Epoch 00041: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 41/70
# 448/448 [==============================] - ETA: 0s - loss: 0.3551 - accuracy: 0.8731 - top5_acc: 0.9991 - macro_f1score: 0.8147
# Epoch 00041: val_loss did not improve from 0.89971
#
# Epoch 00041: val_accuracy did not improve from 0.69252
# 448/448 [==============================] - 711s 2s/step - loss: 0.3551 - accuracy: 0.8731 - top5_acc: 0.9991 - macro_f1score: 0.8147 - val_loss: 1.1246 - val_accuracy: 0.6775 - val_top5_acc: 0.9902 - val_macro_f1score: 0.6078
# Learning rate:  0.0001
#
# Epoch 00042: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 42/70
# 448/448 [==============================] - ETA: 0s - loss: 0.3573 - accuracy: 0.8696 - top5_acc: 0.9994 - macro_f1score: 0.8109
# Epoch 00042: val_loss did not improve from 0.89971
#
# Epoch 00042: val_accuracy did not improve from 0.69252
# 448/448 [==============================] - 710s 2s/step - loss: 0.3573 - accuracy: 0.8696 - top5_acc: 0.9994 - macro_f1score: 0.8109 - val_loss: 1.0991 - val_accuracy: 0.6847 - val_top5_acc: 0.9908 - val_macro_f1score: 0.6181
# Learning rate:  0.0001
#
# Epoch 00043: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 43/70
# 448/448 [==============================] - ETA: 0s - loss: 0.3413 - accuracy: 0.8779 - top5_acc: 0.9997 - macro_f1score: 0.8226
# Epoch 00043: val_loss did not improve from 0.89971
#
# Epoch 00043: val_accuracy did not improve from 0.69252
# 448/448 [==============================] - 715s 2s/step - loss: 0.3413 - accuracy: 0.8779 - top5_acc: 0.9997 - macro_f1score: 0.8226 - val_loss: 1.1522 - val_accuracy: 0.6814 - val_top5_acc: 0.9886 - val_macro_f1score: 0.6154
# Learning rate:  0.0001
#
# Epoch 00044: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 44/70
# 448/448 [==============================] - ETA: 0s - loss: 0.3181 - accuracy: 0.8851 - top5_acc: 0.9995 - macro_f1score: 0.8255
# Epoch 00044: val_loss did not improve from 0.89971
#
# Epoch 00044: val_accuracy did not improve from 0.69252
# 448/448 [==============================] -
#
# Epoch 00057: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 57/70
# 448/448 [==============================] - ETA: 0s - loss: 0.1973 - accuracy: 0.9307 - top5_acc: 0.9998 - macro_f1score: 0.8757
# Epoch 00057: val_loss did not improve from 0.89971
#
# Epoch 00057: val_accuracy did not improve from 0.69252
# 448/448 [==============================] - 719s 2s/step - loss: 0.1973 - accuracy: 0.9307 - top5_acc: 0.9998 - macro_f1score: 0.8757 - val_loss: 1.4324 - val_accuracy: 0.6833 - val_top5_acc: 0.9858 - val_macro_f1score: 0.6164
# Learning rate:  0.0001
#
# Epoch 00058: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 58/70
# 448/448 [==============================] - ETA: 0s - loss: 0.1815 - accuracy: 0.9370 - top5_acc: 0.9998 - macro_f1score: 0.8801
# Epoch 00058: val_loss did not improve from 0.89971
#
# Epoch 00058: val_accuracy did not improve from 0.69252
# 448/448 [==============================] - 720s 2s/step - loss: 0.1815 - accuracy: 0.9370 - top5_acc: 0.9998 - macro_f1score: 0.8801 - val_loss: 1.4288 - val_accuracy: 0.6839 - val_top5_acc: 0.9866 - val_macro_f1score: 0.6171
# Learning rate:  0.0001
#
# Epoch 00059: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 59/70
# 448/448 [==============================] - ETA: 0s - loss: 0.1780 - accuracy: 0.9362 - top5_acc: 0.9998 - macro_f1score: 0.8812
# Epoch 00059: val_loss did not improve from 0.89971
#
# Epoch 00059: val_accuracy did not improve from 0.69252
# 448/448 [==============================] - 728s 2s/step - loss: 0.1780 - accuracy: 0.9362 - top5_acc: 0.9998 - macro_f1score: 0.8812 - val_loss: 1.5228 - val_accuracy: 0.6629 - val_top5_acc: 0.9872 - val_macro_f1score: 0.6018
# Learning rate:  0.0001
#
# Epoch 00060: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 60/70
# 448/448 [==============================] - ETA: 0s - loss: 0.1763 - accuracy: 0.9379 - top5_acc: 0.9998 - macro_f1score: 0.8852
# Epoch 00060: val_loss did not improve from 0.89971
#
# Epoch 00060: val_accuracy did not improve from 0.69252
# 448/448 [==============================] - 741s 2s/step - loss: 0.1763 - accuracy: 0.9379 - top5_acc: 0.9998 - macro_f1score: 0.8852 - val_loss: 1.4755 - val_accuracy: 0.6652 - val_top5_acc: 0.9860 - val_macro_f1score: 0.6068
# Learning rate:  1e-05
#
# Epoch 00061: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 61/70
# 448/448 [==============================] - ETA: 0s - loss: 0.1395 - accuracy: 0.9521 - top5_acc: 0.9999 - macro_f1score: 0.8974
# Epoch 00061: val_loss did not improve from 0.89971
#
# Epoch 00061: val_accuracy did not improve from 0.69252
# 448/448 [==============================] - 731s 2s/step - loss: 0.1395 - accuracy: 0.9521 - top5_acc: 0.9999 - macro_f1score: 0.8974 - val_loss: 1.4286 - val_accuracy: 0.6842 - val_top5_acc: 0.9877 - val_macro_f1score: 0.6238
# Learning rate:  1e-05
#
# Epoch 00062: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 62/70
# 448/448 [==============================] - ETA: 0s - loss: 0.1230 - accuracy: 0.9592 - top5_acc: 0.9999 - macro_f1score: 0.9046
# Epoch 00062: val_loss did not improve from 0.89971
#
# Epoch 00062: val_accuracy did not improve from 0.69252
# 448/448 [==============================] - 739s 2s/step - loss: 0.1230 - accuracy: 0.9592 - top5_acc: 0.9999 - macro_f1score: 0.9046 - val_loss: 1.4491 - val_accuracy: 0.6822 - val_top5_acc: 0.9872 - val_macro_f1score: 0.6119
# Learning rate:  1e-05
#
# Epoch 00063: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 63/70
# 448/448 [==============================] - ETA: 0s - loss: 0.1137 - accuracy: 0.9623 - top5_acc: 0.9999 - macro_f1score: 0.9059
# Epoch 00063: val_loss did not improve from 0.89971
#
# Epoch 00063: val_accuracy did not improve from 0.69252
# 448/448 [==============================] -
#
# Epoch 00070: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 70/70
# 448/448 [==============================] - ETA: 0s - loss: 0.0962 - accuracy: 0.9688 - top5_acc: 0.9998 - macro_f1score: 0.9147
# Epoch 00070: val_loss did not improve from 0.89971
#
# Epoch 00070: val_accuracy did not improve from 0.69252
# 448/448 [==============================] - 720s 2s/step - loss: 0.0962 - accuracy: 0.9688 - top5_acc: 0.9998 - macro_f1score: 0.9147 - val_loss: 1.5045 - val_accuracy: 0.6830 - val_top5_acc: 0.9860 - val_macro_f1score: 0.6086

# %% [markdown]
# ### 3) Inception-V4 Evaluate

# %%
# 1. epoch=maximum
loss , acc, top5_acc, mf1 = model.evaluate(test_generator,steps=int(len(x_test)/batch_sizes))
print('[Test Loss: %.4f /  Test Top-1 Accuracy: %.4f / Test Top-5 Accuracy: %.4f / Test Macro f1: %.4f]\n' % (loss,acc,top5_acc,mf1))
# Out:
# 56/56 [==============================] - 691s 12s/step - loss: 1.6327 - accuracy: 0.6749 - top5_acc: 0.9830 - macro_f1score: 0.6096
# [Test Loss: 1.6327 /  Test Top-1 Accuracy: 0.6749 / Test Top-5 Accuracy: 0.9830 / Test Macro f1: 0.6096]

# %%
loss=history.history['loss']
val_loss=history.history['val_loss']
acc=history.history['accuracy']
val_acc=history.history['val_accuracy']
top5_acc=history.history['top5_acc']
val_top5_acc=history.history['val_top5_acc']
f1=history.history['macro_f1score']
val_f1=history.history['val_macro_f1score']
epochs=range(1,len(acc)+1)

data = np.array([epochs,loss,val_loss,acc,val_acc,top5_acc,val_top5_acc,f1,val_f1]).T

# %%
# data save
# epochs, loss, val_loss, acc, val_acc, top5_acc, val_top5_acc, f1, val_f1

np.savetxt(os.path.join(dir,'train_valid_output',number,model.name+'.txt'),data)

# %%
# data import
data = np.loadtxt(os.path.join(dir,'train_valid_output',number,'Inception_v4.txt'))

# %%
epochs=data[:,0]
loss=data[:,1]
val_loss=data[:,2]
acc=data[:,3]
val_acc=data[:,4]
top5_acc=data[:,5]
val_top5_acc=data[:,6]

# %%
plt.plot(epochs[1:],acc[1:],'b',label='Training 1-Acc')
plt.plot(epochs[1:],val_acc[1:],'r',label='Validation 1-Acc')
plt.title('Training and Validation Top-1 Accuracy')
plt.legend()
plt.figure()

plt.plot(epochs[1:],top5_acc[1:],'b',label='Training 5-Acc')
plt.plot(epochs[1:],val_top5_acc[1:],'r',label='Validation 5-Acc')
plt.title('Training and Validation Top-5 Accuracy')
plt.legend()
plt.figure()

plt.plot(epochs[10:],loss[10:],'b',label='Training Loss')
plt.plot(epochs[10:],val_loss[10:],'r',label='Validation Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()

# %%
# 이 아래는 내가 인위적으로 살펴보고 싶은 epoch에 대해서 결과값 출력 / Inception-V4

# %%
# 참고 : https://github.com/OverLordGoldDragon/keras-adamw

import sys
sys.path.append('/content/drive/My Drive/Colab Notebooks/Paper')
import utils
import optimizers_v2
from utils import get_weight_decays, fill_dict_in_order
from utils import reset_seeds, K_eval
from optimizers_v2 import AdamW, NadamW, SGDW

# %%
# top-5 accuracy 출력
import functools
top5_acc = functools.partial(ks.metrics.top_k_categorical_accuracy, k=5)
top5_acc.__name__ = 'top5_acc'

# %%
model=load_model(os.path.join(dir,'model_output',number,'Inception_v4','031.h5'),custom_objects={"macro_f1score": macro_f1score,"top5_acc":top5_acc, "AdamW":AdamW})

# %%
# 2. epoch=?
loss , acc, top5_acc, mf1 = model.evaluate(test_generator,steps=int(len(x_test)/batch_sizes))
print('[Test Loss: %.4f /  Test Top-1 Accuracy: %.4f / Test Top-5 Accuracy: %.4f / Test Macro f1: %.4f]\n' % (loss,acc,top5_acc,mf1))
# Out:
# 56/56 [==============================] - 1401s 25s/step - loss: 0.9687 - accuracy: 0.6641 - top5_acc: 0.9888 - macro_f1score: 0.5629
# [Test Loss: 0.9687 /  Test Top-1 Accuracy: 0.6641 / Test Top-5 Accuracy: 0.9888 / Test Macro f1: 0.5629]
