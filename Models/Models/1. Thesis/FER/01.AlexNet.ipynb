# %% [markdown]
# # [AlexNet]

# %% [markdown]
# *KU LeeDongGyu*

# %% [markdown]
# ### Contents

# %% [markdown]
# 1. Data Preprocessing
# ```
# 1) Data Import
# 2) Data Augmentation
# ```
# 2. Support Functions & Almost Original AlexNet
# ```
# 1) Support Functions
# 2) Almost Original AlexNet
# 3) AlexNet Evaluate
# ```

# %% [markdown]
# ### Install Packages

# %% [markdown]
# ### Module

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/My Drive/Colab Notebooks/Paper
# Out:
# /content/drive/My Drive/Colab Notebooks/Paper

# %%
from lrn import LRN #만든 모듈, class
from f1score import macro_f1score, weighted_f1score

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import cv2
import tensorflow as tf
from tensorflow import keras as ks
from tensorflow.keras import backend as K 
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, Input, Concatenate, ZeroPadding2D ,GlobalMaxPooling2D, Reshape , Lambda , Add, Multiply
from tensorflow.keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D, Activation, BatchNormalization, AveragePooling2D , ZeroPadding2D, SeparableConv2D
from tensorflow.keras.layers import add
from tensorflow.keras.optimizers import Adam, RMSprop , SGD
from tensorflow.keras.callbacks import EarlyStopping , LearningRateScheduler, ModelCheckpoint, CSVLogger, Callback, ReduceLROnPlateau
from tensorflow.keras.regularizers import l1,l2,l1_l2
from tensorflow.keras.models import Model , load_model , Sequential
from tensorflow.keras.utils import plot_model , to_categorical, get_file
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
os.getcwd()
# Out:
# '/content/drive/My Drive/Colab Notebooks/Paper'

# %%
print(tf.__version__)
print(ks.__version__)
# Out:
# 2.3.0
# 2.4.0

# %%
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 13013555267620551860
# , name: "/device:XLA_CPU:0"
# device_type: "XLA_CPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 6917311460517810940
# physical_device_desc: "device: XLA_CPU device"
# , name: "/device:XLA_GPU:0"
# device_type: "XLA_GPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 10703850698699837094
# physical_device_desc: "device: XLA_GPU device"
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 15695549568
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 10797897581885463078
# physical_device_desc: "device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0"
# ]

# %% [markdown]
# ## 1. Data Preprocessing
# ---

# %% [markdown]
# ### 1) Data Import

# %%
# 바꿔서 살펴 볼 것들
# CALTECH, CIFAR100, FER, MIT
data_name = 'FER'
gan_type = 'No_GAN'
number = '1'
size = 227 # sizes after cropping
super_size = 256 # sizes before cropping 
input_sizes = (size,size,3)
batch_sizes = 128
weight_decay = 1e-4
epochs = 70

# %%
# 참고 : https://stackoverflow.com/questions/32419510/how-to-get-reproducible-results-in-keras/52897216#52897216
# setting the seed number for random number generation for reproducibility.

from numpy.random import seed
import random


if number=='1':
    seed_num = 200225
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)
elif number=='2':
    seed_num = 727
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)
elif number=='3':
    seed_num = 115
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)
elif number=='4':
    seed_num = 501
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)
elif number=='5':
    seed_num = 517
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)

# %%
# data import

if data_name=='FER' :
    x_train =  np.zeros(28698)
    x_valid = np.zeros(3589)
    x_test = np.zeros(3588)
    classes = 7 
    tr_center = [0.50793296, 0.50793296, 0.50793296]
elif data_name=='MIT':
    x_train = np.zeros(12466)
    x_valid = np.zeros(1564)
    x_test = np.zeros(1590)
    classes = 67 
    tr_center = [0.47916578, 0.42029615, 0.36046057]
elif data_name=='CALTECH':
    x_train = np.zeros(24510)
    x_valid = np.zeros(2980)
    x_test = np.zeros(3118)
    classes = 257
    tr_center = [0.51397761, 0.49525248, 0.46555727]
elif data_name=='CIFAR100':
    x_train = np.zeros(44923)
    x_valid = np.zeros(5077)
    x_test = np.zeros(10000)
    classes = 100
    tr_center = [0.53442983, 0.51355958, 0.46462564]

# %%
dir = os.path.join(os.getcwd(),data_name,gan_type)

# %% [markdown]
# ### 2) Data Augmentation

# %%
# 참고 : https://jkjung-avt.github.io/keras-image-cropping/

def random_crop(img, random_crop_size):
    # Note: image_data_format is 'channel_last'
    assert img.shape[2] == 3 # img.shape[2] 가 3(rgb)이 아니면 assertion error 발생
    height, width = img.shape[0], img.shape[1]
    dy, dx = random_crop_size
    x = np.random.randint(0, width - dx + 1)
    y = np.random.randint(0, height - dy + 1)
    return img[y:(y+dy), x:(x+dx), :]


def crop_generator(batches, crop_length):
    """Take as input a Keras ImageGen (Iterator) and generate random
    crops from the image batches generated by the original iterator.
    """
    while True:
        batch_x, batch_y = next(batches)
        batch_crops = np.zeros((batch_x.shape[0], crop_length, crop_length, 3))
        for i in range(batch_x.shape[0]):
            batch_crops[i] = random_crop(batch_x[i], (crop_length, crop_length))
        yield (batch_crops, batch_y)

# %%
from tensorflow.keras.preprocessing.image import img_to_array,load_img
import glob

# 데이터 전체에 대해 centering 진행함.

def read_cal_image(img_path): 
    x = img_to_array(load_img(img_path)) # x는 채널별 평균값
    y = x.shape[0] * x.shape[1]# y는 데이터별 픽셀 수 (비중)

    x = 1/255. * x # scaling하고, centering값을 뽑아냄.
    x = np.mean(x, axis=(0,1))
    
    return np.hstack([x,y])

def calculate_centered_mean(dataset_path,x_train=x_train):
    num = len(x_train)
    space = np.empty((num,4))
    i=0

    for p in glob.glob(os.path.join(dataset_path,'*/*.*')) :
        space[i] = read_cal_image(p)
        i += 1

    ratio = space[:,3] / np.sum(space[:,3])

    return np.average(space[:,0:3],axis=0,weights=ratio)


#아래의 함수를 돌려서 나온 결과값을 중심화 값으로 설정.

#train_mean = calculate_centered_mean(os.path.join(dir,'data/train')).reshape((1,1,3))

# %%
datagen_tr = ImageDataGenerator(
    rescale=1/255.,
    horizontal_flip=True,
    featurewise_center=True,
    featurewise_std_normalization=False,
    rotation_range=10,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=[0.9,1.0],
    fill_mode = 'nearest')
datagen_val = ImageDataGenerator(rescale=1/255.,featurewise_center=True)
datagen_tes = ImageDataGenerator(rescale=1/255.,featurewise_center=True)

# 원래는 이 자리에 fit 매서드를 써야하지만, 그냥 내가 중심화함수를 만들고 적용함. 

# 중심화 설정
datagen_tr.mean = np.array(tr_center, dtype=np.float32).reshape((1,1,3)) # RGB
datagen_val.mean = np.array(tr_center, dtype=np.float32).reshape((1,1,3)) # RGB
datagen_tes.mean = np.array(tr_center, dtype=np.float32).reshape((1,1,3)) # RGB

# %%
train_batches = datagen_tr.flow_from_directory(directory=os.path.join(dir,'data/train'),target_size=(super_size,super_size),batch_size=batch_sizes,class_mode='categorical') # fer : 28698 / mit : 12466 / caltech : 24509 / cifar : 44923
train_generator= crop_generator(train_batches, size)
valid_generator = datagen_val.flow_from_directory(directory=os.path.join(dir,'data/valid'),target_size=(size,size),batch_size=batch_sizes,class_mode='categorical') # fer : 3589 / mit : 1564 / caltech : 2980 / cifar : 5077
test_generator = datagen_tes.flow_from_directory(directory=os.path.join(dir,'data/test'),target_size=(size,size),batch_size=batch_sizes,class_mode='categorical') # fer : 3588 / mit : 1590 / caltech : 3118 / cifar : 10000
# Out:
# Found 28698 images belonging to 7 classes.
# Found 3589 images belonging to 7 classes.
# Found 3588 images belonging to 7 classes.

# %% [markdown]
# ## 2. Support Functions & Almost Original AlexNet
# ---

# %% [markdown]
# ### 1) Support Functions

# %%
# def lr_schedule(epoch):
#     init_lr = 1e-4
#     k = 0.04
#     lr = init_lr * np.exp(-k*epoch)
#     print('Learning rate: ', lr)
#     return lr

def lr_schedule(epoch):
    lr = 3e-4
    if epoch < 30:
        lr = lr
    elif epoch < 60 :
        lr = lr * 0.1
    else:
        lr = lr * 0.01
    print('Learning rate: ', lr)
    return lr

# %% [markdown]
# ### 2) Almost Orginial AlexNet

# %%
# Alexnet을 최대한 논문에 가깝게 맞춰 모형작성.
# 참고 : https://github.com/eweill/keras-deepcv/blob/master/models/classification/alexnet.py

def Alexnet(img_shape=(227, 227, 3), n_classes=1000, weight_decay=weight_decay, weights=None, name='AlexNet'):

    # Initialize model
    alexnet = Sequential(name=name)

    # Layer 1
    alexnet.add(Conv2D(96, (11, 11), input_shape=img_shape, strides=4, kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay)))
    alexnet.add(Activation('relu'))
    alexnet.add(LRN(name='layer1_LRN'))
    alexnet.add(MaxPooling2D(pool_size=(3, 3),strides=2))

    # Layer 2
    alexnet.add(Conv2D(256, (5, 5), padding='same',strides=1, kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay)))
    alexnet.add(Activation('relu'))
    alexnet.add(LRN(name='layer2_LRN'))
    alexnet.add(MaxPooling2D(pool_size=(3, 3),strides=2))
    
    # Layer 3
    alexnet.add(Conv2D(384, (3, 3), padding='same', strides=1, kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay)))
    alexnet.add(Activation('relu'))
    alexnet.add(LRN(name='layer3_LRN'))
    
    # Layer 4
    alexnet.add(Conv2D(384, (3, 3), padding='same', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay)))
    alexnet.add(Activation('relu'))
    alexnet.add(LRN(name='layer4_LRN'))

    # Layer 5
    alexnet.add(Conv2D(256, (3, 3), padding='same', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay)))
    alexnet.add(Activation('relu'))
    alexnet.add(LRN(name='layer5_LRN'))
    alexnet.add(MaxPooling2D(pool_size=(3, 3),strides=2))

    # Layer 6
    alexnet.add(Flatten())
    alexnet.add(Dense(4096, kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay)))
    alexnet.add(Activation('relu'))
    alexnet.add(Dropout(0.5))

    # Layer 7
    alexnet.add(Dense(4096, kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay)))
    alexnet.add(Activation('relu'))
    alexnet.add(Dropout(0.5))

    # Layer 8
    alexnet.add(Dense(n_classes, kernel_regularizer=l2(weight_decay)))
    alexnet.add(Activation('softmax'))

    if weights is not None:
        alexnet.load_weights(weights)

    return alexnet

# %%
model = Alexnet(img_shape=input_sizes, n_classes=classes, name='AlexNet')

# %%
model.summary()
# Out:
# Model: "AlexNet"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 55, 55, 96)        34944
# _________________________________________________________________
# activation (Activation)      (None, 55, 55, 96)        0
# _________________________________________________________________
# layer1_LRN (LRN)             (None, 55, 55, 96)        0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 27, 27, 96)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 27, 27, 256)       614656
# _________________________________________________________________
# activation_1 (Activation)    (None, 27, 27, 256)       0
# _________________________________________________________________
# layer2_LRN (LRN)             (None, 27, 27, 256)       0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 13, 13, 256)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 13, 13, 384)       885120
# _________________________________________________________________
# activation_2 (Activation)    (None, 13, 13, 384)       0
# _________________________________________________________________
# layer3_LRN (LRN)             (None, 13, 13, 384)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 13, 13, 384)       1327488
# _________________________________________________________________
# activation_3 (Activation)    (None, 13, 13, 384)       0
# _________________________________________________________________
# layer4_LRN (LRN)             (None, 13, 13, 384)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 13, 13, 256)       884992
# _________________________________________________________________
# activation_4 (Activation)    (None, 13, 13, 256)       0
# _________________________________________________________________
# layer5_LRN (LRN)             (None, 13, 13, 256)       0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 6, 6, 256)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 9216)              0
# _________________________________________________________________
# dense (Dense)                (None, 4096)              37752832
# _________________________________________________________________
# activation_5 (Activation)    (None, 4096)              0
# _________________________________________________________________
# dropout (Dropout)            (None, 4096)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 4096)              16781312
# _________________________________________________________________
# activation_6 (Activation)    (None, 4096)              0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 4096)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 7)                 28679
# _________________________________________________________________
# activation_7 (Activation)    (None, 7)                 0
# =================================================================
# Total params: 58,310,023
# Trainable params: 58,310,023
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 폴더 생성

os.makedirs(os.path.join(dir,'model_output',number,model.name), exist_ok=True)
os.makedirs(os.path.join(dir,'train_valid_output',number), exist_ok=True)

# %%
# 참고 : https://github.com/OverLordGoldDragon/keras-adamw

import sys
sys.path.append('/content/drive/My Drive/Colab Notebooks/Paper')
import utils
import optimizers_v2
from utils import get_weight_decays, fill_dict_in_order
from utils import reset_seeds, K_eval
from optimizers_v2 import AdamW, NadamW, SGDW

# %%
# top-5 accuracy 출력
import functools
top5_acc = functools.partial(ks.metrics.top_k_categorical_accuracy, k=5)
top5_acc.__name__ = 'top5_acc'

# %%
#optimizer = SGDW(model=model, use_cosine_annealing=False, total_iterations = len(x_train) // batch_sizes, nesterov=True, momentum=0.9)
optimizer = AdamW(model=model, use_cosine_annealing=False, total_iterations = len(x_train) // batch_sizes)
#optimizer = Adam()
filepath =  os.path.join(dir,'model_output',number,model.name,'{epoch:03d}.h5')

callbacks_list = [ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_weights_only=False, save_best_only=True, mode='min'),
                  ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_weights_only=False, save_best_only=True, mode='max'),
                  #ReduceLROnPlateau(monitor='val_loss',patience=3,factor=0.1,min_lr=1e-5),
                  LearningRateScheduler(lr_schedule,verbose=1)
                  ]
                  
model.compile(optimizer, loss = 'categorical_crossentropy', metrics=['accuracy',top5_acc,macro_f1score])

# %%
######## flow_from_directory
history = model.fit(train_generator, steps_per_epoch=int(len(x_train)/batch_sizes),  validation_data = valid_generator, epochs=epochs , verbose=1 , callbacks = callbacks_list , validation_steps=int(len(x_valid)/batch_sizes))
# Out:
# Learning rate:  0.0003
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 1/70
# 0.0(L1), 6.681530879020939e-06(L2) weight decay set for conv2d/kernel:0
# 0.0(L1), 6.681530879020939e-06(L2) weight decay set for conv2d_1/kernel:0
# 0.0(L1), 6.681530879020939e-06(L2) weight decay set for conv2d_2/kernel:0
# 0.0(L1), 6.681530879020939e-06(L2) weight decay set for conv2d_3/kernel:0
# 0.0(L1), 6.681530879020939e-06(L2) weight decay set for conv2d_4/kernel:0
# 0.0(L1), 6.681530879020939e-06(L2) weight decay set for dense/kernel:0
# 0.0(L1), 6.681530879020939e-06(L2) weight decay set for dense_1/kernel:0
# 0.0(L1), 6.681530879020939e-06(L2) weight decay set for dense_2/kernel:0
# 224/224 [==============================] - ETA: 0s - loss: 1.7618 - accuracy: 0.2916 - top5_acc: 0.9046 - macro_f1score: 0.0389
# Epoch 00001: val_loss improved from inf to 1.54730, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/AlexNet/001.h5
#
# Epoch 00001: val_accuracy improved from -inf to 0.41323, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/AlexNet/001.h5
# 224/224 [==============================] - 14978s 67s/step - loss: 1.7618 - accuracy: 0.2916 - top5_acc: 0.9046 - macro_f1score: 0.0389 - val_loss: 1.5473 - val_accuracy: 0.4132 - val_top5_acc: 0.9381 - val_macro_f1score: 0.1557
# Learning rate:  0.0003
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 2/70
# 224/224 [==============================] - ETA: 0s - loss: 1.4763 - accuracy: 0.4284 - top5_acc: 0.9526 - macro_f1score: 0.1679
# Epoch 00002: val_loss improved from 1.54730 to 1.36794, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/AlexNet/002.h5
#
# Epoch 00002: val_accuracy improved from 0.41323 to 0.47321, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/AlexNet/002.h5
# 224/224 [==============================] - 408s 2s/step - loss: 1.4763 - accuracy: 0.4284 - top5_acc: 0.9526 - macro_f1score: 0.1679 - val_loss: 1.3679 - val_accuracy: 0.4732 - val_top5_acc: 0.9662 - val_macro_f1score: 0.2334
# Learning rate:  0.0003
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 3/70
# 224/224 [==============================] - ETA: 0s - loss: 1.3420 - accuracy: 0.4829 - top5_acc: 0.9663 - macro_f1score: 0.2377
# Epoch 00003: val_loss improved from 1.36794 to 1.24404, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/AlexNet/003.h5
#
# Epoch 00003: val_accuracy improved from 0.47321 to 0.52037, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/AlexNet/003.h5
# 224/224 [==============================] - 416s 2s/step - loss: 1.3420 - accuracy: 0.4829 - top5_acc: 0.9663 - macro_f1score: 0.2377 - val_loss: 1.2440 - val_accuracy: 0.5204 - val_top5_acc: 0.9766 - val_macro_f1score: 0.3116
# Learning rate:  0.0003
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 4/70
# 224/224 [==============================] - ETA: 0s - loss: 1.2653 - accuracy: 0.5176 - top5_acc: 0.9709 - macro_f1score: 0.2899
# Epoch 00004: val_loss did not improve from 1.24404
#
# Epoch 00004: val_accuracy improved from 0.52037 to 0.52121, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/AlexNet/004.h5
# 224/224 [==============================] - 422s 2s/step - loss: 1.2653 - accuracy: 0.5176 - top5_acc: 0.9709 - macro_f1score: 0.2899 - val_loss: 1.2471 - val_accuracy: 0.5212 - val_top5_acc: 0.9735 - val_macro_f1score: 0.3096
# Learning rate:  0.0003
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 5/70
# 224/224 [==============================] - ETA: 0s - loss: 1.2157 - accuracy: 0.5372 - top5_acc: 0.9739 - macro_f1score: 0.3223
# Epoch 00005: val_loss improved from 1.24404 to 1.18655, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/AlexNet/005.h5
#
# Epoch 00005: val_accuracy improved from 0.52121 to 0.54967, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/AlexNet/005.h5
# 224/224 [==============================] - 450s 2s/step - loss: 1.2157 - accuracy: 0.5372 - top5_acc: 0.9739 - macro_f1score: 0.3223 - val_loss: 1.1866 - val_accuracy: 0.5497 - val_top5_acc: 0.9766 - val_macro_f1score: 0.3265
# Learning rate:  0.0003
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 6/70
# 224/224 [==============================] - ETA: 0s - loss: 1.1755 - accuracy: 0.5551 - top5_acc: 0.9764 - macro_f1score: 0.3437
# Epoch 00006: val_loss improved from 1.18655 to 1.15400, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/AlexNet/006.h5
#
# Epoch 00006: val_accuracy improved from 0.54967 to 0.55413, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/AlexNet/006.h5
# 224/224 [==============================] - 452s 2s/step - loss: 1.1755 - accuracy: 0.5551 - top5_acc: 0.9764 - macro_f1score: 0.3437 - val_loss: 1.1540 - val_accuracy: 0.5541 - val_top5_acc: 0.9810 - val_macro_f1score: 0.3617
# Learning rate:  0.0003
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 7/70
# 224/224 [==============================] - ETA: 0s - loss: 1.1403 - accuracy: 0.5685 - top5_acc: 0.9784 - macro_f1score: 0.3685
# Epoch 00007: val_loss improved from 1.15400 to 1.11694, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/AlexNet/007.h5
#
# Epoch 00007: val_accuracy improved from 0.55413 to 0.57227, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/AlexNet/007.h5
# 224/224 [==============================] - 458s 2s/step - loss: 1.1403 - accuracy: 0.5685 - top5_acc: 0.9784 - macro_f1score: 0.3685 - val_loss: 1.1169 - val_accuracy: 0.5723 - val_top5_acc: 0.9838 - val_macro_f1score: 0.3876
# Learning rate:  0.0003
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 8/70
# 224/224 [==============================] - ETA: 0s - loss: 1.1048 - accuracy: 0.5831 - top5_acc: 0.9822 - macro_f1score: 0.3955
# Epoch 00008: val_loss did not improve from 1.11694
#
# Epoch 00008: val_accuracy improved from 0.57227 to 0.58175, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/AlexNet/008.h5
# 224/224 [==============================] - 423s 2s/step - loss: 1.1048 - accuracy: 0.5831 - top5_acc: 0.9822 - macro_f1score: 0.3955 - val_loss: 1.1187 - val_accuracy: 0.5818 - val_top5_acc: 0.9841 - val_macro_f1score: 0.3856
# Learning rate:  0.0003
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 9/70
# 224/224 [==============================] - ETA: 0s - loss: 1.0776 - accuracy: 0.5928 - top5_acc: 0.9827 - macro_f1score: 0.4081
# Epoch 00009: val_loss improved from 1.11694 to 1.08867, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/AlexNet/009.h5
#
# Epoch 00009: val_accuracy improved from 0.58175 to 0.59012, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/AlexNet/009.h5
# 224/224 [==============================] - 405s 2s/step - loss: 1.0776 - accuracy: 0.5928 - top5_acc: 0.9827 - macro_f1score: 0.4081 - val_loss: 1.0887 - val_accuracy: 0.5901 - val_top5_acc: 0.9866 - val_macro_f1score: 0.4242
# Learning rate:  0.0003
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 10/70
# 224/224 [==============================] - ETA: 0s - loss: 1.0628 - accuracy: 0.6011 - top5_acc: 0.9832 - macro_f1score: 0.4214
# Epoch 00010: val_loss improved from 1.08867 to 1.07943, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/AlexNet/010.h5
#
# Epoch 00010: val_accuracy improved from 0.59012 to 0.60240, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/AlexNet/010.h5
# 224/224 [==============================] - 433s 2s/step - loss: 1.0628 - accuracy: 0.6011 - top5_acc: 0.9832 - macro_f1score: 0.4214 - val_loss: 1.0794 - val_accuracy: 0.6024 - val_top5_acc: 0.9855 - val_macro_f1score: 0.4261
# Learning rate:  0.0003
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 11/70
# 224/224 [==============================] - ETA: 0s - loss: 1.0340 - accuracy: 0.6108 - top5_acc: 0.9847 - macro_f1score: 0.4434
# Epoch 00011: val_loss improved from 1.07943 to 1.04848, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/AlexNet/011.h5
#
# Epoch 00011: val_accuracy improved from 0.60240 to 0.60547, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/AlexNet/011.h5
# 224/224 [==============================] - 447s 2s/step - loss: 1.0340 - accuracy: 0.6108 - top5_acc: 0.9847 - macro_f1score: 0.4434 - val_loss: 1.0485 - val_accuracy: 0.6055 - val_top5_acc: 0.9838 - val_macro_f1score: 0.4377
# Learning rate:  0.0003
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 12/70
# 224/224 [==============================] - ETA: 0s - loss: 1.0149 - accuracy: 0.6152 - top5_acc: 0.9861 - macro_f1score: 0.4571
# Epoch 00012: val_loss improved from 1.04848 to 1.03375, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/AlexNet/012.h5
#
# Epoch 00012: val_accuracy improved from 0.60547 to 0.61719, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/AlexNet/012.h5
# 224/224 [==============================] - 437s 2s/step - loss: 1.0149 - accuracy: 0.6152 - top5_acc: 0.9861 - macro_f1score: 0.4571 - val_loss: 1.0337 - val_accuracy: 0.6172 - val_top5_acc: 0.9888 - val_macro_f1score: 0.4522
# Learning rate:  0.0003
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 13/70
# 224/224 [==============================] - ETA: 0s - loss: 0.9954 - accuracy: 0.6234 - top5_acc: 0.9875 - macro_f1score: 0.4686
# Epoch 00013: val_loss improved from 1.03375 to 1.02709, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/AlexNet/013.h5
#
# Epoch 00013: val_accuracy did not improve from 0.61719
# 224/224 [==============================] - 441s 2s/step - loss: 0.9954 - accuracy: 0.6234 - top5_acc: 0.9875 - macro_f1score: 0.4686 - val_loss: 1.0271 - val_accuracy: 0.6158 - val_top5_acc: 0.9860 - val_macro_f1score: 0.4663
# Learning rate:  0.0003
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 14/70
# 224/224 [==============================] - ETA: 0s - loss: 0.9818 - accuracy: 0.6311 - top5_acc: 0.9870 - macro_f1score: 0.4790
# Epoch 00014: val_loss did not improve from 1.02709
#
# Epoch 00014: val_accuracy did not improve from 0.61719
# 224/224 [==============================] - 439s 2s/step - loss: 0.9818 - accuracy: 0.6311 - top5_acc: 0.9870 - macro_f1score: 0.4790 - val_loss: 1.0573 - val_accuracy: 0.6032 - val_top5_acc: 0.9877 - val_macro_f1score: 0.4493
# Learning rate:  0.0003
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 15/70
# 224/224 [==============================] - ETA: 0s - loss: 0.9761 - accuracy: 0.6364 - top5_acc: 0.9885 - macro_f1score: 0.4913
# Epoch 00015: val_loss improved from 1.02709 to 1.01243, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/AlexNet/015.h5
#
# Epoch 00015: val_accuracy improved from 0.61719 to 0.62584, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/AlexNet/015.h5
# 224/224 [==============================] - 437s 2s/step - loss: 0.9761 - accuracy: 0.6364 - top5_acc: 0.9885 - macro_f1score: 0.4913 - val_loss: 1.0124 - val_accuracy: 0.6258 - val_top5_acc: 0.9858 - val_macro_f1score: 0.4648
# Learning rate:  0.0003
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 16/70
# 224/224 [==============================] - ETA: 0s - loss: 0.9506 - accuracy: 0.6399 - top5_acc: 0.9884 - macro_f1score: 0.5015
# Epoch 00016: val_loss did not improve from 1.01243
#
# Epoch 00016: val_accuracy did not improve from 0.62584
# 224/224 [==============================] - 438s 2s/step - loss: 0.9506 - accuracy: 0.6399 - top5_acc: 0.9884 - macro_f1score: 0.5015 - val_loss: 1.0327 - val_accuracy: 0.6177 - val_top5_acc: 0.9872 - val_macro_f1score: 0.4779
# Learning rate:  0.0003
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 17/70
# 224/224 [==============================] - ETA: 0s - loss: 0.9352 - accuracy: 0.6484 - top5_acc: 0.9898 - macro_f1score: 0.5159
# Epoch 00017: val_loss did not improve from 1.01243
#
# Epoch 00017: val_accuracy did not improve from 0.62584
# 224/224 [==============================] - 442s 2s/step - loss: 0.9352 - accuracy: 0.6484 - top5_acc: 0.9898 - macro_f1score: 0.5159 - val_loss: 1.0517 - val_accuracy: 0.6124 - val_top5_acc: 0.9838 - val_macro_f1score: 0.4676
# Learning rate:  0.0003
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 18/70
# 224/224 [==============================] - ETA: 0s - loss: 0.9171 - accuracy: 0.6556 - top5_acc: 0.9907 - macro_f1score: 0.5306
# Epoch 00018: val_loss did not improve from 1.01243
#
# Epoch 00018: val_accuracy did not improve from 0.62584
# 224/224 [==============================] - 428s 2s/step - loss: 0.9171 - accuracy: 0.6556 - top5_acc: 0.9907 - macro_f1score: 0.5306 - val_loss: 1.0418 - val_accuracy: 0.6247 - val_top5_acc: 0.9897 - val_macro_f1score: 0.4874
# Learning rate:  0.0003
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 19/70
# 224/224 [==============================] - ETA: 0s - loss: 0.9111 - accuracy: 0.6583 - top5_acc: 0.9903 - macro_f1score: 0.5270
# Epoch 00019: val_loss did not improve from 1.01243
#
# Epoch 00019: val_accuracy did not improve from 0.62584
# 224/224 [==============================] - 419s 2s/step - loss: 0.9111 - accuracy: 0.6583 - top5_acc: 0.9903 - macro_f1score: 0.5270 - val_loss: 1.0169 - val_accuracy: 0.6253 - val_top5_acc: 0.9860 - val_macro_f1score: 0.4999
# Learning rate:  0.0003
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 20/70
# 224/224 [==============================] - ETA: 0s - loss: 0.8889 - accuracy: 0.6674 - top5_acc: 0.9908 - macro_f1score: 0.5518
# Epoch 00020: val_loss did not improve from 1.01243
#
# Epoch 00020: val_accuracy improved from 0.62584 to 0.63393, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/AlexNet/020.h5
# 224/224 [==============================] - 398s 2s/step - loss: 0.8889 - accuracy: 0.6674 - top5_acc: 0.9908 - macro_f1score: 0.5518 - val_loss: 1.0249 - val_accuracy: 0.6339 - val_top5_acc: 0.9844 - val_macro_f1score: 0.5030
# Learning rate:  0.0003
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 21/70
# 224/224 [==============================] - ETA: 0s - loss: 0.8738 - accuracy: 0.6721 - top5_acc: 0.9920 - macro_f1score: 0.5648
# Epoch 00021: val_loss did not improve from 1.01243
#
# Epoch 00021: val_accuracy did not improve from 0.63393
# 224/224 [==============================] - 426s 2s/step - loss: 0.8738 - accuracy: 0.6721 - top5_acc: 0.9920 - macro_f1score: 0.5648 - val_loss: 1.0497 - val_accuracy: 0.6222 - val_top5_acc: 0.9872 - val_macro_f1score: 0.4895
# Learning rate:  0.0003
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 22/70
# 224/224 [==============================] - ETA: 0s - loss: 0.8638 - accuracy: 0.6769 - top5_acc: 0.9923 - macro_f1score: 0.5708
# Epoch 00022: val_loss did not improve from 1.01243
#
# Epoch 00022: val_accuracy did not improve from 0.63393
# 224/224 [==============================] - 428s 2s/step - loss: 0.8638 - accuracy: 0.6769 - top5_acc: 0.9923 - macro_f1score: 0.5708 - val_loss: 1.0136 - val_accuracy: 0.6253 - val_top5_acc: 0.9872 - val_macro_f1score: 0.5085
# Learning rate:  0.0003
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 23/70
# 224/224 [==============================] - ETA: 0s - loss: 0.8503 - accuracy: 0.6823 - top5_acc: 0.9924 - macro_f1score: 0.5836
# Epoch 00023: val_loss did not improve from 1.01243
#
# Epoch 00023: val_accuracy did not improve from 0.63393
# 224/224 [==============================] - 395s 2s/step - loss: 0.8503 - accuracy: 0.6823 - top5_acc: 0.9924 - macro_f1score: 0.5836 - val_loss: 1.0454 - val_accuracy: 0.6317 - val_top5_acc: 0.9869 - val_macro_f1score: 0.5092
# Learning rate:  0.0003
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 24/70
# 224/224 [==============================] - ETA: 0s - loss: 0.8409 - accuracy: 0.6878 - top5_acc: 0.9917 - macro_f1score: 0.5917
# Epoch 00024: val_loss improved from 1.01243 to 1.00829, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/AlexNet/024.h5
#
# Epoch 00024: val_accuracy did not improve from 0.63393
# 224/224 [==============================] - 393s 2s/step - loss: 0.8409 - accuracy: 0.6878 - top5_acc: 0.9917 - macro_f1score: 0.5917 - val_loss: 1.0083 - val_accuracy: 0.6323 - val_top5_acc: 0.9900 - val_macro_f1score: 0.5501
# Learning rate:  0.0003
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 25/70
# 224/224 [==============================] - ETA: 0s - loss: 0.8301 - accuracy: 0.6912 - top5_acc: 0.9930 - macro_f1score: 0.5968
# Epoch 00025: val_loss did not improve from 1.00829
#
# Epoch 00025: val_accuracy did not improve from 0.63393
# 224/224 [==============================] - 391s 2s/step - loss: 0.8301 - accuracy: 0.6912 - top5_acc: 0.9930 - macro_f1score: 0.5968 - val_loss: 1.0359 - val_accuracy: 0.6309 - val_top5_acc: 0.9874 - val_macro_f1score: 0.5241
# Learning rate:  0.0003
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 26/70
# 224/224 [==============================] - ETA: 0s - loss: 0.8059 - accuracy: 0.6999 - top5_acc: 0.9928 - macro_f1score: 0.6064
# Epoch 00026: val_loss did not improve from 1.00829
#
# Epoch 00026: val_accuracy did not improve from 0.63393
# 224/224 [==============================] - 390s 2s/step - loss: 0.8059 - accuracy: 0.6999 - top5_acc: 0.9928 - macro_f1score: 0.6064 - val_loss: 1.0318 - val_accuracy: 0.6239 - val_top5_acc: 0.9872 - val_macro_f1score: 0.5284
# Learning rate:  0.0003
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 27/70
# 224/224 [==============================] - ETA: 0s - loss: 0.7937 - accuracy: 0.7022 - top5_acc: 0.9936 - macro_f1score: 0.6226
# Epoch 00027: val_loss did not improve from 1.00829
#
# Epoch 00027: val_accuracy improved from 0.63393 to 0.63951, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/AlexNet/027.h5
# 224/224 [==============================] - 391s 2s/step - loss: 0.7937 - accuracy: 0.7022 - top5_acc: 0.9936 - macro_f1score: 0.6226 - val_loss: 1.0236 - val_accuracy: 0.6395 - val_top5_acc: 0.9869 - val_macro_f1score: 0.5536
# Learning rate:  0.0003
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 28/70
# 224/224 [==============================] - ETA: 0s - loss: 0.7859 - accuracy: 0.7057 - top5_acc: 0.9949 - macro_f1score: 0.6134
# Epoch 00028: val_loss did not improve from 1.00829
#
# Epoch 00028: val_accuracy did not improve from 0.63951
# 224/224 [==============================] - 391s 2s/step - loss: 0.7859 - accuracy: 0.7057 - top5_acc: 0.9949 - macro_f1score: 0.6134 - val_loss: 1.0445 - val_accuracy: 0.6336 - val_top5_acc: 0.9877 - val_macro_f1score: 0.5439
# Learning rate:  0.0003
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 29/70
# 224/224 [==============================] - ETA: 0s - loss: 0.7659 - accuracy: 0.7134 - top5_acc: 0.9949 - macro_f1score: 0.6303
# Epoch 00029: val_loss did not improve from 1.00829
#
# Epoch 00029: val_accuracy did not improve from 0.63951
# 224/224 [==============================] - 390s 2s/step - loss: 0.7659 - accuracy: 0.7134 - top5_acc: 0.9949 - macro_f1score: 0.6303 - val_loss: 1.0579 - val_accuracy: 0.6172 - val_top5_acc: 0.9869 - val_macro_f1score: 0.5005
# Learning rate:  0.0003
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 0.0003.
# Epoch 30/70
# 224/224 [==============================] - ETA: 0s - loss: 0.7652 - accuracy: 0.7148 - top5_acc: 0.9952 - macro_f1score: 0.6326
# Epoch 00030: val_loss did not improve from 1.00829
#
# Epoch 00030: val_accuracy did not improve from 0.63951
# 224/224 [==============================] - 390s 2s/step - loss: 0.7652 - accuracy: 0.7148 - top5_acc: 0.9952 - macro_f1score: 0.6326 - val_loss: 1.0451 - val_accuracy: 0.6395 - val_top5_acc: 0.9886 - val_macro_f1score: 0.5382
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 31/70
# 224/224 [==============================] - ETA: 0s - loss: 0.6663 - accuracy: 0.7499 - top5_acc: 0.9964 - macro_f1score: 0.6834
# Epoch 00031: val_loss did not improve from 1.00829
#
# Epoch 00031: val_accuracy improved from 0.63951 to 0.65458, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/AlexNet/031.h5
# 224/224 [==============================] - 393s 2s/step - loss: 0.6663 - accuracy: 0.7499 - top5_acc: 0.9964 - macro_f1score: 0.6834 - val_loss: 1.0271 - val_accuracy: 0.6546 - val_top5_acc: 0.9888 - val_macro_f1score: 0.5805
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 32/70
# 224/224 [==============================] - ETA: 0s - loss: 0.6341 - accuracy: 0.7633 - top5_acc: 0.9970 - macro_f1score: 0.7091
# Epoch 00032: val_loss did not improve from 1.00829
#
# Epoch 00032: val_accuracy did not improve from 0.65458
# 224/224 [==============================] - 392s 2s/step - loss: 0.6341 - accuracy: 0.7633 - top5_acc: 0.9970 - macro_f1score: 0.7091 - val_loss: 1.0501 - val_accuracy: 0.6496 - val_top5_acc: 0.9888 - val_macro_f1score: 0.5648
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00033: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 33/70
# 224/224 [==============================] - ETA: 0s - loss: 0.6214 - accuracy: 0.7706 - top5_acc: 0.9968 - macro_f1score: 0.7194
# Epoch 00033: val_loss did not improve from 1.00829
#
# Epoch 00033: val_accuracy did not improve from 0.65458
# 224/224 [==============================] - 390s 2s/step - loss: 0.6214 - accuracy: 0.7706 - top5_acc: 0.9968 - macro_f1score: 0.7194 - val_loss: 1.0628 - val_accuracy: 0.6529 - val_top5_acc: 0.9880 - val_macro_f1score: 0.5793
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00034: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 34/70
# 224/224 [==============================] - ETA: 0s - loss: 0.6164 - accuracy: 0.7722 - top5_acc: 0.9970 - macro_f1score: 0.7225
# Epoch 00034: val_loss did not improve from 1.00829
#
# Epoch 00034: val_accuracy did not improve from 0.65458
# 224/224 [==============================] - 397s 2s/step - loss: 0.6164 - accuracy: 0.7722 - top5_acc: 0.9970 - macro_f1score: 0.7225 - val_loss: 1.0633 - val_accuracy: 0.6546 - val_top5_acc: 0.9872 - val_macro_f1score: 0.5880
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00035: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 35/70
# 224/224 [==============================] - ETA: 0s - loss: 0.6016 - accuracy: 0.7763 - top5_acc: 0.9977 - macro_f1score: 0.7232
# Epoch 00035: val_loss did not improve from 1.00829
#
# Epoch 00035: val_accuracy did not improve from 0.65458
# 224/224 [==============================] - 391s 2s/step - loss: 0.6016 - accuracy: 0.7763 - top5_acc: 0.9977 - macro_f1score: 0.7232 - val_loss: 1.0817 - val_accuracy: 0.6482 - val_top5_acc: 0.9874 - val_macro_f1score: 0.5775
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00036: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 36/70
# 224/224 [==============================] - ETA: 0s - loss: 0.5947 - accuracy: 0.7774 - top5_acc: 0.9976 - macro_f1score: 0.7296
# Epoch 00036: val_loss did not improve from 1.00829
#
# Epoch 00036: val_accuracy did not improve from 0.65458
# 224/224 [==============================] - 392s 2s/step - loss: 0.5947 - accuracy: 0.7774 - top5_acc: 0.9976 - macro_f1score: 0.7296 - val_loss: 1.0694 - val_accuracy: 0.6512 - val_top5_acc: 0.9869 - val_macro_f1score: 0.5909
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00037: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 37/70
# 224/224 [==============================] - ETA: 0s - loss: 0.5844 - accuracy: 0.7833 - top5_acc: 0.9973 - macro_f1score: 0.7350
# Epoch 00037: val_loss did not improve from 1.00829
#
# Epoch 00037: val_accuracy did not improve from 0.65458
# 224/224 [==============================] - 393s 2s/step - loss: 0.5844 - accuracy: 0.7833 - top5_acc: 0.9973 - macro_f1score: 0.7350 - val_loss: 1.0923 - val_accuracy: 0.6493 - val_top5_acc: 0.9877 - val_macro_f1score: 0.5690
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00038: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 38/70
# 224/224 [==============================] - ETA: 0s - loss: 0.5788 - accuracy: 0.7835 - top5_acc: 0.9975 - macro_f1score: 0.7348
# Epoch 00038: val_loss did not improve from 1.00829
#
# Epoch 00038: val_accuracy did not improve from 0.65458
# 224/224 [==============================] - 397s 2s/step - loss: 0.5788 - accuracy: 0.7835 - top5_acc: 0.9975 - macro_f1score: 0.7348 - val_loss: 1.0901 - val_accuracy: 0.6523 - val_top5_acc: 0.9883 - val_macro_f1score: 0.5815
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00039: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 39/70
# 224/224 [==============================] - ETA: 0s - loss: 0.5733 - accuracy: 0.7842 - top5_acc: 0.9976 - macro_f1score: 0.7387
# Epoch 00039: val_loss did not improve from 1.00829
#
# Epoch 00039: val_accuracy did not improve from 0.65458
# 224/224 [==============================] - 431s 2s/step - loss: 0.5733 - accuracy: 0.7842 - top5_acc: 0.9976 - macro_f1score: 0.7387 - val_loss: 1.0911 - val_accuracy: 0.6512 - val_top5_acc: 0.9877 - val_macro_f1score: 0.5820
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00040: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 40/70
# 224/224 [==============================] - ETA: 0s - loss: 0.5652 - accuracy: 0.7895 - top5_acc: 0.9979 - macro_f1score: 0.7411
# Epoch 00040: val_loss did not improve from 1.00829
#
# Epoch 00040: val_accuracy did not improve from 0.65458
# 224/224 [==============================] - 441s 2s/step - loss: 0.5652 - accuracy: 0.7895 - top5_acc: 0.9979 - macro_f1score: 0.7411 - val_loss: 1.1060 - val_accuracy: 0.6537 - val_top5_acc: 0.9863 - val_macro_f1score: 0.5823
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00041: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 41/70
# 224/224 [==============================] - ETA: 0s - loss: 0.5586 - accuracy: 0.7930 - top5_acc: 0.9977 - macro_f1score: 0.7446
# Epoch 00041: val_loss did not improve from 1.00829
#
# Epoch 00041: val_accuracy did not improve from 0.65458
# 224/224 [==============================] - 449s 2s/step - loss: 0.5586 - accuracy: 0.7930 - top5_acc: 0.9977 - macro_f1score: 0.7446 - val_loss: 1.0994 - val_accuracy: 0.6535 - val_top5_acc: 0.9880 - val_macro_f1score: 0.5791
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00042: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 42/70
# 224/224 [==============================] - ETA: 0s - loss: 0.5498 - accuracy: 0.7943 - top5_acc: 0.9975 - macro_f1score: 0.7504
# Epoch 00042: val_loss did not improve from 1.00829
#
# Epoch 00042: val_accuracy improved from 0.65458 to 0.65765, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/AlexNet/042.h5
# 224/224 [==============================] - 455s 2s/step - loss: 0.5498 - accuracy: 0.7943 - top5_acc: 0.9975 - macro_f1score: 0.7504 - val_loss: 1.1000 - val_accuracy: 0.6576 - val_top5_acc: 0.9869 - val_macro_f1score: 0.5909
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00043: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 43/70
# 224/224 [==============================] - ETA: 0s - loss: 0.5463 - accuracy: 0.7956 - top5_acc: 0.9980 - macro_f1score: 0.7487
# Epoch 00043: val_loss did not improve from 1.00829
#
# Epoch 00043: val_accuracy did not improve from 0.65765
# 224/224 [==============================] - 440s 2s/step - loss: 0.5463 - accuracy: 0.7956 - top5_acc: 0.9980 - macro_f1score: 0.7487 - val_loss: 1.1178 - val_accuracy: 0.6543 - val_top5_acc: 0.9872 - val_macro_f1score: 0.5793
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00044: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 44/70
# 224/224 [==============================] - ETA: 0s - loss: 0.5425 - accuracy: 0.7997 - top5_acc: 0.9984 - macro_f1score: 0.7570
# Epoch 00044: val_loss did not improve from 1.00829
#
# Epoch 00044: val_accuracy did not improve from 0.65765
# 224/224 [==============================] - 420s 2s/step - loss: 0.5425 - accuracy: 0.7997 - top5_acc: 0.9984 - macro_f1score: 0.7570 - val_loss: 1.1195 - val_accuracy: 0.6571 - val_top5_acc: 0.9866 - val_macro_f1score: 0.5931
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00045: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 45/70
# 224/224 [==============================] - ETA: 0s - loss: 0.5292 - accuracy: 0.8048 - top5_acc: 0.9984 - macro_f1score: 0.7622
# Epoch 00045: val_loss did not improve from 1.00829
#
# Epoch 00045: val_accuracy did not improve from 0.65765
# 224/224 [==============================] - 418s 2s/step - loss: 0.5292 - accuracy: 0.8048 - top5_acc: 0.9984 - macro_f1score: 0.7622 - val_loss: 1.1161 - val_accuracy: 0.6557 - val_top5_acc: 0.9860 - val_macro_f1score: 0.6023
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00046: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 46/70
# 224/224 [==============================] - ETA: 0s - loss: 0.5277 - accuracy: 0.8041 - top5_acc: 0.9982 - macro_f1score: 0.7607
# Epoch 00046: val_loss did not improve from 1.00829
#
# Epoch 00046: val_accuracy improved from 0.65765 to 0.66071, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/AlexNet/046.h5
# 224/224 [==============================] - 401s 2s/step - loss: 0.5277 - accuracy: 0.8041 - top5_acc: 0.9982 - macro_f1score: 0.7607 - val_loss: 1.1212 - val_accuracy: 0.6607 - val_top5_acc: 0.9866 - val_macro_f1score: 0.5899
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00047: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 47/70
# 224/224 [==============================] - ETA: 0s - loss: 0.5274 - accuracy: 0.8040 - top5_acc: 0.9984 - macro_f1score: 0.7636
# Epoch 00047: val_loss did not improve from 1.00829
#
# Epoch 00047: val_accuracy did not improve from 0.66071
# 224/224 [==============================] - 414s 2s/step - loss: 0.5274 - accuracy: 0.8040 - top5_acc: 0.9984 - macro_f1score: 0.7636 - val_loss: 1.1371 - val_accuracy: 0.6549 - val_top5_acc: 0.9855 - val_macro_f1score: 0.5966
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00048: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 48/70
# 224/224 [==============================] - ETA: 0s - loss: 0.5156 - accuracy: 0.8100 - top5_acc: 0.9982 - macro_f1score: 0.7668
# Epoch 00048: val_loss did not improve from 1.00829
#
# Epoch 00048: val_accuracy did not improve from 0.66071
# 224/224 [==============================] - 431s 2s/step - loss: 0.5156 - accuracy: 0.8100 - top5_acc: 0.9982 - macro_f1score: 0.7668 - val_loss: 1.1367 - val_accuracy: 0.6532 - val_top5_acc: 0.9874 - val_macro_f1score: 0.5785
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00049: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 49/70
# 224/224 [==============================] - ETA: 0s - loss: 0.5219 - accuracy: 0.8060 - top5_acc: 0.9977 - macro_f1score: 0.7686
# Epoch 00049: val_loss did not improve from 1.00829
#
# Epoch 00049: val_accuracy did not improve from 0.66071
# 224/224 [==============================] - 439s 2s/step - loss: 0.5219 - accuracy: 0.8060 - top5_acc: 0.9977 - macro_f1score: 0.7686 - val_loss: 1.1375 - val_accuracy: 0.6602 - val_top5_acc: 0.9872 - val_macro_f1score: 0.6081
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00050: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 50/70
# 224/224 [==============================] - ETA: 0s - loss: 0.5048 - accuracy: 0.8134 - top5_acc: 0.9983 - macro_f1score: 0.7755
# Epoch 00050: val_loss did not improve from 1.00829
#
# Epoch 00050: val_accuracy did not improve from 0.66071
# 224/224 [==============================] - 442s 2s/step - loss: 0.5048 - accuracy: 0.8134 - top5_acc: 0.9983 - macro_f1score: 0.7755 - val_loss: 1.1402 - val_accuracy: 0.6551 - val_top5_acc: 0.9874 - val_macro_f1score: 0.5881
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00051: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 51/70
# 224/224 [==============================] - ETA: 0s - loss: 0.4998 - accuracy: 0.8141 - top5_acc: 0.9984 - macro_f1score: 0.7749
# Epoch 00051: val_loss did not improve from 1.00829
#
# Epoch 00051: val_accuracy did not improve from 0.66071
# 224/224 [==============================] - 438s 2s/step - loss: 0.4998 - accuracy: 0.8141 - top5_acc: 0.9984 - macro_f1score: 0.7749 - val_loss: 1.1671 - val_accuracy: 0.6562 - val_top5_acc: 0.9874 - val_macro_f1score: 0.5991
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00052: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 52/70
# 224/224 [==============================] - ETA: 0s - loss: 0.5057 - accuracy: 0.8109 - top5_acc: 0.9983 - macro_f1score: 0.7756
# Epoch 00052: val_loss did not improve from 1.00829
#
# Epoch 00052: val_accuracy did not improve from 0.66071
# 224/224 [==============================] - 406s 2s/step - loss: 0.5057 - accuracy: 0.8109 - top5_acc: 0.9983 - macro_f1score: 0.7756 - val_loss: 1.1443 - val_accuracy: 0.6526 - val_top5_acc: 0.9869 - val_macro_f1score: 0.5943
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00053: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 53/70
# 224/224 [==============================] - ETA: 0s - loss: 0.4943 - accuracy: 0.8160 - top5_acc: 0.9983 - macro_f1score: 0.7796
# Epoch 00053: val_loss did not improve from 1.00829
#
# Epoch 00053: val_accuracy did not improve from 0.66071
# 224/224 [==============================] - 398s 2s/step - loss: 0.4943 - accuracy: 0.8160 - top5_acc: 0.9983 - macro_f1score: 0.7796 - val_loss: 1.1449 - val_accuracy: 0.6546 - val_top5_acc: 0.9872 - val_macro_f1score: 0.6022
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00054: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 54/70
# 224/224 [==============================] - ETA: 0s - loss: 0.4875 - accuracy: 0.8226 - top5_acc: 0.9983 - macro_f1score: 0.7779
# Epoch 00054: val_loss did not improve from 1.00829
#
# Epoch 00054: val_accuracy did not improve from 0.66071
# 224/224 [==============================] - 388s 2s/step - loss: 0.4875 - accuracy: 0.8226 - top5_acc: 0.9983 - macro_f1score: 0.7779 - val_loss: 1.1524 - val_accuracy: 0.6551 - val_top5_acc: 0.9860 - val_macro_f1score: 0.5826
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00055: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 55/70
# 224/224 [==============================] - ETA: 0s - loss: 0.4754 - accuracy: 0.8217 - top5_acc: 0.9986 - macro_f1score: 0.7816
# Epoch 00055: val_loss did not improve from 1.00829
#
# Epoch 00055: val_accuracy did not improve from 0.66071
# 224/224 [==============================] - 391s 2s/step - loss: 0.4754 - accuracy: 0.8217 - top5_acc: 0.9986 - macro_f1score: 0.7816 - val_loss: 1.1744 - val_accuracy: 0.6557 - val_top5_acc: 0.9874 - val_macro_f1score: 0.5949
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00056: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 56/70
# 224/224 [==============================] - ETA: 0s - loss: 0.4842 - accuracy: 0.8226 - top5_acc: 0.9981 - macro_f1score: 0.7798
# Epoch 00056: val_loss did not improve from 1.00829
#
# Epoch 00056: val_accuracy did not improve from 0.66071
# 224/224 [==============================] - 396s 2s/step - loss: 0.4842 - accuracy: 0.8226 - top5_acc: 0.9981 - macro_f1score: 0.7798 - val_loss: 1.1815 - val_accuracy: 0.6560 - val_top5_acc: 0.9869 - val_macro_f1score: 0.5992
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00057: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 57/70
# 224/224 [==============================] - ETA: 0s - loss: 0.4801 - accuracy: 0.8195 - top5_acc: 0.9986 - macro_f1score: 0.7745
# Epoch 00057: val_loss did not improve from 1.00829
#
# Epoch 00057: val_accuracy did not improve from 0.66071
# 224/224 [==============================] - 404s 2s/step - loss: 0.4801 - accuracy: 0.8195 - top5_acc: 0.9986 - macro_f1score: 0.7745 - val_loss: 1.1893 - val_accuracy: 0.6512 - val_top5_acc: 0.9869 - val_macro_f1score: 0.5860
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00058: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 58/70
# 224/224 [==============================] - ETA: 0s - loss: 0.4665 - accuracy: 0.8281 - top5_acc: 0.9986 - macro_f1score: 0.7902
# Epoch 00058: val_loss did not improve from 1.00829
#
# Epoch 00058: val_accuracy did not improve from 0.66071
# 224/224 [==============================] - 407s 2s/step - loss: 0.4665 - accuracy: 0.8281 - top5_acc: 0.9986 - macro_f1score: 0.7902 - val_loss: 1.1751 - val_accuracy: 0.6549 - val_top5_acc: 0.9869 - val_macro_f1score: 0.5888
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00059: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 59/70
# 224/224 [==============================] - ETA: 0s - loss: 0.4707 - accuracy: 0.8285 - top5_acc: 0.9984 - macro_f1score: 0.7902
# Epoch 00059: val_loss did not improve from 1.00829
#
# Epoch 00059: val_accuracy improved from 0.66071 to 0.66267, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/AlexNet/059.h5
# 224/224 [==============================] - 410s 2s/step - loss: 0.4707 - accuracy: 0.8285 - top5_acc: 0.9984 - macro_f1score: 0.7902 - val_loss: 1.1784 - val_accuracy: 0.6627 - val_top5_acc: 0.9866 - val_macro_f1score: 0.5972
# Learning rate:  2.9999999999999997e-05
#
# Epoch 00060: LearningRateScheduler reducing learning rate to 2.9999999999999997e-05.
# Epoch 60/70
# 224/224 [==============================] - ETA: 0s - loss: 0.4561 - accuracy: 0.8308 - top5_acc: 0.9985 - macro_f1score: 0.7960
# Epoch 00060: val_loss did not improve from 1.00829
#
# Epoch 00060: val_accuracy did not improve from 0.66267
# 224/224 [==============================] - 423s 2s/step - loss: 0.4561 - accuracy: 0.8308 - top5_acc: 0.9985 - macro_f1score: 0.7960 - val_loss: 1.1952 - val_accuracy: 0.6574 - val_top5_acc: 0.9877 - val_macro_f1score: 0.5972
# Learning rate:  2.9999999999999997e-06
#
# Epoch 00061: LearningRateScheduler reducing learning rate to 2.9999999999999997e-06.
# Epoch 61/70
# 224/224 [==============================] - ETA: 0s - loss: 0.4530 - accuracy: 0.8330 - top5_acc: 0.9987 - macro_f1score: 0.7965
# Epoch 00061: val_loss did not improve from 1.00829
#
# Epoch 00061: val_accuracy did not improve from 0.66267
# 224/224 [==============================] - 437s 2s/step - loss: 0.4530 - accuracy: 0.8330 - top5_acc: 0.9987 - macro_f1score: 0.7965 - val_loss: 1.2010 - val_accuracy: 0.6562 - val_top5_acc: 0.9860 - val_macro_f1score: 0.5927
# Learning rate:  2.9999999999999997e-06
#
# Epoch 00062: LearningRateScheduler reducing learning rate to 2.9999999999999997e-06.
# Epoch 62/70
# 224/224 [==============================] - ETA: 0s - loss: 0.4408 - accuracy: 0.8379 - top5_acc: 0.9990 - macro_f1score: 0.7987
# Epoch 00062: val_loss did not improve from 1.00829
#
# Epoch 00062: val_accuracy did not improve from 0.66267
# 224/224 [==============================] - 436s 2s/step - loss: 0.4408 - accuracy: 0.8379 - top5_acc: 0.9990 - macro_f1score: 0.7987 - val_loss: 1.1992 - val_accuracy: 0.6579 - val_top5_acc: 0.9872 - val_macro_f1score: 0.6064
# Learning rate:  2.9999999999999997e-06
#
# Epoch 00063: LearningRateScheduler reducing learning rate to 2.9999999999999997e-06.
# Epoch 63/70
# 224/224 [==============================] - ETA: 0s - loss: 0.4417 - accuracy: 0.8363 - top5_acc: 0.9987 - macro_f1score: 0.8039
# Epoch 00063: val_loss did not improve from 1.00829
#
# Epoch 00063: val_accuracy did not improve from 0.66267
# 224/224 [==============================] - 435s 2s/step - loss: 0.4417 - accuracy: 0.8363 - top5_acc: 0.9987 - macro_f1score: 0.8039 - val_loss: 1.1973 - val_accuracy: 0.6576 - val_top5_acc: 0.9869 - val_macro_f1score: 0.5954
# Learning rate:  2.9999999999999997e-06
#
# Epoch 00064: LearningRateScheduler reducing learning rate to 2.9999999999999997e-06.
# Epoch 64/70
# 224/224 [==============================] - ETA: 0s - loss: 0.4364 - accuracy: 0.8403 - top5_acc: 0.9991 - macro_f1score: 0.7972
# Epoch 00064: val_loss did not improve from 1.00829
#
# Epoch 00064: val_accuracy did not improve from 0.66267
# 224/224 [==============================] - 443s 2s/step - loss: 0.4364 - accuracy: 0.8403 - top5_acc: 0.9991 - macro_f1score: 0.7972 - val_loss: 1.1997 - val_accuracy: 0.6610 - val_top5_acc: 0.9872 - val_macro_f1score: 0.5908
# Learning rate:  2.9999999999999997e-06
#
# Epoch 00065: LearningRateScheduler reducing learning rate to 2.9999999999999997e-06.
# Epoch 65/70
# 224/224 [==============================] - ETA: 0s - loss: 0.4342 - accuracy: 0.8401 - top5_acc: 0.9991 - macro_f1score: 0.8033
# Epoch 00065: val_loss did not improve from 1.00829
#
# Epoch 00065: val_accuracy did not improve from 0.66267
# 224/224 [==============================] - 440s 2s/step - loss: 0.4342 - accuracy: 0.8401 - top5_acc: 0.9991 - macro_f1score: 0.8033 - val_loss: 1.2010 - val_accuracy: 0.6590 - val_top5_acc: 0.9869 - val_macro_f1score: 0.6074
# Learning rate:  2.9999999999999997e-06
#
# Epoch 00066: LearningRateScheduler reducing learning rate to 2.9999999999999997e-06.
# Epoch 66/70
# 224/224 [==============================] - ETA: 0s - loss: 0.4458 - accuracy: 0.8340 - top5_acc: 0.9984 - macro_f1score: 0.7932
# Epoch 00066: val_loss did not improve from 1.00829
#
# Epoch 00066: val_accuracy did not improve from 0.66267
# 224/224 [==============================] - 438s 2s/step - loss: 0.4458 - accuracy: 0.8340 - top5_acc: 0.9984 - macro_f1score: 0.7932 - val_loss: 1.1949 - val_accuracy: 0.6602 - val_top5_acc: 0.9872 - val_macro_f1score: 0.5987
# Learning rate:  2.9999999999999997e-06
#
# Epoch 00067: LearningRateScheduler reducing learning rate to 2.9999999999999997e-06.
# Epoch 67/70
# 224/224 [==============================] - ETA: 0s - loss: 0.4417 - accuracy: 0.8392 - top5_acc: 0.9986 - macro_f1score: 0.7997
# Epoch 00067: val_loss did not improve from 1.00829
#
# Epoch 00067: val_accuracy did not improve from 0.66267
# 224/224 [==============================] - 418s 2s/step - loss: 0.4417 - accuracy: 0.8392 - top5_acc: 0.9986 - macro_f1score: 0.7997 - val_loss: 1.1879 - val_accuracy: 0.6579 - val_top5_acc: 0.9866 - val_macro_f1score: 0.5931
# Learning rate:  2.9999999999999997e-06
#
# Epoch 00068: LearningRateScheduler reducing learning rate to 2.9999999999999997e-06.
# Epoch 68/70
# 224/224 [==============================] - ETA: 0s - loss: 0.4441 - accuracy: 0.8377 - top5_acc: 0.9990 - macro_f1score: 0.7976
# Epoch 00068: val_loss did not improve from 1.00829
#
# Epoch 00068: val_accuracy did not improve from 0.66267
# 224/224 [==============================] - 435s 2s/step - loss: 0.4441 - accuracy: 0.8377 - top5_acc: 0.9990 - macro_f1score: 0.7976 - val_loss: 1.1858 - val_accuracy: 0.6576 - val_top5_acc: 0.9866 - val_macro_f1score: 0.6045
# Learning rate:  2.9999999999999997e-06
#
# Epoch 00069: LearningRateScheduler reducing learning rate to 2.9999999999999997e-06.
# Epoch 69/70
# 224/224 [==============================] - ETA: 0s - loss: 0.4371 - accuracy: 0.8383 - top5_acc: 0.9988 - macro_f1score: 0.8025
# Epoch 00069: val_loss did not improve from 1.00829
#
# Epoch 00069: val_accuracy did not improve from 0.66267
# 224/224 [==============================] - 434s 2s/step - loss: 0.4371 - accuracy: 0.8383 - top5_acc: 0.9988 - macro_f1score: 0.8025 - val_loss: 1.1876 - val_accuracy: 0.6582 - val_top5_acc: 0.9872 - val_macro_f1score: 0.6010
# Learning rate:  2.9999999999999997e-06
#
# Epoch 00070: LearningRateScheduler reducing learning rate to 2.9999999999999997e-06.
# Epoch 70/70
# 224/224 [==============================] - ETA: 0s - loss: 0.4406 - accuracy: 0.8366 - top5_acc: 0.9991 - macro_f1score: 0.8033
# Epoch 00070: val_loss did not improve from 1.00829
#
# Epoch 00070: val_accuracy did not improve from 0.66267
# 224/224 [==============================] - 445s 2s/step - loss: 0.4406 - accuracy: 0.8366 - top5_acc: 0.9991 - macro_f1score: 0.8033 - val_loss: 1.1861 - val_accuracy: 0.6604 - val_top5_acc: 0.9872 - val_macro_f1score: 0.5912

# %% [markdown]
# ### 3) AlexNet Evaluate

# %%
# 1. epoch=maximum
loss , acc, top5_acc, mf1 = model.evaluate(test_generator,steps=int(len(x_test)/batch_sizes))
print('[Test Loss: %.4f /  Test Top-1 Accuracy: %.4f / Test Top-5 Accuracy: %.4f / Test Macro f1: %.4f]\n' % (loss,acc,top5_acc,mf1))
# Out:
# 28/28 [==============================] - 1818s 65s/step - loss: 1.2313 - accuracy: 0.6456 - top5_acc: 0.9852 - macro_f1score: 0.5834
# [Test Loss: 1.2313 /  Test Top-1 Accuracy: 0.6456 / Test Top-5 Accuracy: 0.9852 / Test Macro f1: 0.5834]

# %%
loss=history.history['loss']
val_loss=history.history['val_loss']
acc=history.history['accuracy']
val_acc=history.history['val_accuracy']
top5_acc=history.history['top5_acc']
val_top5_acc=history.history['val_top5_acc']
f1=history.history['macro_f1score']
val_f1=history.history['val_macro_f1score']
epochs=range(1,len(acc)+1)

data = np.array([epochs,loss,val_loss,acc,val_acc,top5_acc,val_top5_acc,f1,val_f1]).T

# %%
# data save
# epochs, loss, val_loss, acc, val_acc, top5_acc, val_top5_acc, f1, val_f1

np.savetxt(os.path.join(dir,'train_valid_output',number,model.name+'.txt'),data)

# %%
# data import
data = np.loadtxt(os.path.join(dir,'train_valid_output',number,'AlexNet.txt'))

# %%
epochs=data[:,0]
loss=data[:,1]
val_loss=data[:,2]
acc=data[:,3]
val_acc=data[:,4]
top5_acc=data[:,5]
val_top5_acc=data[:,6]

# %%
plt.plot(epochs[1:],acc[1:],'b',label='Training 1-Acc')
plt.plot(epochs[1:],val_acc[1:],'r',label='Validation 1-Acc')
plt.title('Training and Validation Top-1 Accuracy')
plt.legend()
plt.figure()

plt.plot(epochs[1:],top5_acc[1:],'b',label='Training 5-Acc')
plt.plot(epochs[1:],val_top5_acc[1:],'r',label='Validation 5-Acc')
plt.title('Training and Validation Top-5 Accuracy')
plt.legend()
plt.figure()

plt.plot(epochs[10:],loss[10:],'b',label='Training Loss')
plt.plot(epochs[10:],val_loss[10:],'r',label='Validation Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()

# %%
# 이 아래는 내가 인위적으로 살펴보고 싶은 epoch에 대해서 결과값 출력 / AlexNet

# %%
# 참고 : https://github.com/OverLordGoldDragon/keras-adamw

import sys
sys.path.append('/content/drive/My Drive/Colab Notebooks/Paper')
import utils
import optimizers_v2
from utils import get_weight_decays, fill_dict_in_order
from utils import reset_seeds, K_eval
from optimizers_v2 import AdamW, NadamW, SGDW

# %%
# top-5 accuracy 출력
import functools
top5_acc = functools.partial(ks.metrics.top_k_categorical_accuracy, k=5)
top5_acc.__name__ = 'top5_acc'

# %%
model=load_model(os.path.join(dir,'model_output',number,'AlexNet','031.h5'),custom_objects={"macro_f1score": macro_f1score,"top5_acc":top5_acc,"LRN":LRN, "AdamW":AdamW})

# %%
# 2. epoch=?
loss , acc, top5_acc, mf1 = model.evaluate(test_generator,steps=int(len(x_test)/batch_sizes))
print('[Test Loss: %.4f /  Test Top-1 Accuracy: %.4f / Test Top-5 Accuracy: %.4f / Test Macro f1: %.4f]\n' % (loss,acc,top5_acc,mf1))
# Out:
# 28/28 [==============================] - 1642s 59s/step - loss: 1.0678 - accuracy: 0.6376 - top5_acc: 0.9872 - macro_f1score: 0.5603
# [Test Loss: 1.0678 /  Test Top-1 Accuracy: 0.6376 / Test Top-5 Accuracy: 0.9872 / Test Macro f1: 0.5603]
