# %%
#모형 출처 : https://github.com/titu1994/keras-squeeze-excite-network

# %% [markdown]
# # [ResNet50]

# %% [markdown]
# *KU LeeDongGyu*

# %% [markdown]
# ## Contents
# ---

# %% [markdown]
# 1. Data Preprocessing
# ```
# 1) Data Import
# 2) Data Augmentation
# ```
# 2. Support Functions & Almost Original ResNet
# ```
# 1) Support Functions
# 2) Almost orginal ResNet
# ```
# 3. ResNet50
# ```
# 1) ResNet50
# 2) ResNet50 Evaluate
# ```

# %% [markdown]
# ### Install Packages

# %% [markdown]
# ### Module

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
cd /content/drive/My Drive/Colab Notebooks/Paper
# Out:
# /content/drive/My Drive/Colab Notebooks/Paper

# %%
from f1score import macro_f1score,weighted_f1score

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import cv2
import tensorflow as tf
from tensorflow import keras as ks
from tensorflow.keras import backend as K 
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, Input, Concatenate, ZeroPadding2D ,GlobalMaxPooling2D, Reshape , Lambda , Add, Multiply
from tensorflow.keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D, Activation, BatchNormalization, AveragePooling2D , ZeroPadding2D, SeparableConv2D , LeakyReLU
from tensorflow.keras.layers import add, concatenate, multiply
from tensorflow.keras.optimizers import Adam, RMSprop , SGD
from tensorflow.keras.callbacks import EarlyStopping , LearningRateScheduler, ModelCheckpoint, CSVLogger, Callback, ReduceLROnPlateau
from tensorflow.keras.regularizers import l1,l2,l1_l2
from tensorflow.keras.models import Model , load_model , Sequential
from tensorflow.keras.utils import plot_model , to_categorical, get_file
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
os.getcwd()
# Out:
# '/content/drive/My Drive/Colab Notebooks/Paper'

# %%
print(tf.__version__)
print(ks.__version__)
# Out:
# 2.3.0
# 2.4.0

# %%
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 14251025998328628756
# , name: "/device:XLA_CPU:0"
# device_type: "XLA_CPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 8097708083488005998
# physical_device_desc: "device: XLA_CPU device"
# , name: "/device:XLA_GPU:0"
# device_type: "XLA_GPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 3649010883901316332
# physical_device_desc: "device: XLA_GPU device"
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 15473775744
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 9899765636895351379
# physical_device_desc: "device: 0, name: Tesla V100-SXM2-16GB, pci bus id: 0000:00:04.0, compute capability: 7.0"
# ]

# %%
# !cat /proc/cpuinfo
# Out:
# processor	: 0
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 85
# model name	: Intel(R) Xeon(R) CPU @ 2.00GHz
# stepping	: 3
# microcode	: 0x1
# cpu MHz		: 2000.156
# cache size	: 39424 KB
# physical id	: 0
# siblings	: 4
# core id		: 0
# cpu cores	: 2
# apicid		: 0
# initial apicid	: 0
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm mpx avx512f avx512dq rdseed adx smap clflushopt clwb avx512cd avx512bw avx512vl xsaveopt xsavec xgetbv1 xsaves arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs taa
# bogomips	: 4000.31
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 46 bits physical, 48 bits virtual
# power management:
#
# processor	: 1
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 85
# model name	: Intel(R) Xeon(R) CPU @ 2.00GHz
# stepping	: 3
# microcode	: 0x1
# cpu MHz		: 2000.156
# cache size	: 39424 KB
# physical id	: 0
# siblings	: 4
# core id		: 1
# cpu cores	: 2
# apicid		: 2
# initial apicid	: 2
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm mpx avx512f avx512dq rdseed adx smap clflushopt clwb avx512cd avx512bw avx512vl xsaveopt xsavec xgetbv1 xsaves arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs taa
# bogomips	: 4000.31
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 46 bits physical, 48 bits virtual
# power management:
#
# processor	: 2
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 85
# model name	: Intel(R) Xeon(R) CPU @ 2.00GHz
# stepping	: 3
# microcode	: 0x1
# cpu MHz		: 2000.156
# cache size	: 39424 KB
# physical id	: 0
# siblings	: 4
# core id		: 0
# cpu cores	: 2
# apicid		: 1
# initial apicid	: 1
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm mpx avx512f avx512dq rdseed adx smap clflushopt clwb avx512cd avx512bw avx512vl xsaveopt xsavec xgetbv1 xsaves arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs taa
# bogomips	: 4000.31
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 46 bits physical, 48 bits virtual
# power management:
#
# processor	: 3
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 85
# model name	: Intel(R) Xeon(R) CPU @ 2.00GHz
# stepping	: 3
# microcode	: 0x1
# cpu MHz		: 2000.156
# cache size	: 39424 KB
# physical id	: 0
# siblings	: 4
# core id		: 1
# cpu cores	: 2
# apicid		: 3
# initial apicid	: 3
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm mpx avx512f avx512dq rdseed adx smap clflushopt clwb avx512cd avx512bw avx512vl xsaveopt xsavec xgetbv1 xsaves arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs taa
# bogomips	: 4000.31
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 46 bits physical, 48 bits virtual
# power management:

# %% [markdown]
# ## 1. Data Preprocessing
# ---

# %% [markdown]
# ### 1) Data Import

# %%
# 바꿔서 살펴 볼 것들
# CALTECH, CIFAR100, FER, MIT
data_name = 'FER'
gan_type = 'No_GAN'
number = '1'
size = 224 # sizes after cropping
super_size = 256 # sizes before cropping 
input_sizes = (size,size,3)
batch_sizes = 128
weight_decay = 2e-3
epochs = 70

# %%
# 참고 : https://stackoverflow.com/questions/32419510/how-to-get-reproducible-results-in-keras/52897216#52897216
# setting the seed number for random number generation for reproducibility.

from numpy.random import seed
import random


if number=='1':
    seed_num = 200225
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)
elif number=='2':
    seed_num = 727
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)
elif number=='3':
    seed_num = 115
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)
elif number=='4':
    seed_num = 501
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)
elif number=='5':
    seed_num = 517
    os.environ['PYTHONHASHSEED']=str(seed_num)
    random.seed(seed_num)
    seed(seed_num)
    tf.random.set_seed(seed_num)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)

# %%
# data import

if data_name=='FER' :
    x_train =  np.zeros(28698)
    x_valid = np.zeros(3589)
    x_test = np.zeros(3588)
    classes = 7 
    tr_center = [0.50793296, 0.50793296, 0.50793296]
elif data_name=='MIT':
    x_train = np.zeros(12466)
    x_valid = np.zeros(1564)
    x_test = np.zeros(1590)
    classes = 67 
    tr_center = [0.47916578, 0.42029615, 0.36046057]
elif data_name=='CALTECH':
    x_train = np.zeros(24510)
    x_valid = np.zeros(2980)
    x_test = np.zeros(3118)
    classes = 257
    tr_center = [0.51397761, 0.49525248, 0.46555727]
elif data_name=='CIFAR100':
    x_train = np.zeros(44923)
    x_valid = np.zeros(5077)
    x_test = np.zeros(10000)
    classes = 100
    tr_center = [0.53442983, 0.51355958, 0.46462564]

# %%
dir = os.path.join(os.getcwd(),data_name,gan_type)

# %% [markdown]
# ### 2) Data Augmentation

# %%
# 참고 : https://jkjung-avt.github.io/keras-image-cropping/

def random_crop(img, random_crop_size):
    # Note: image_data_format is 'channel_last'
    assert img.shape[2] == 3 # img.shape[2] 가 3(rgb)이 아니면 assertion error 발생
    height, width = img.shape[0], img.shape[1]
    dy, dx = random_crop_size
    x = np.random.randint(0, width - dx + 1)
    y = np.random.randint(0, height - dy + 1)
    return img[y:(y+dy), x:(x+dx), :]


def crop_generator(batches, crop_length):
    """Take as input a Keras ImageGen (Iterator) and generate random
    crops from the image batches generated by the original iterator.
    """
    while True:
        batch_x, batch_y = next(batches)
        batch_crops = np.zeros((batch_x.shape[0], crop_length, crop_length, 3))
        for i in range(batch_x.shape[0]):
            batch_crops[i] = random_crop(batch_x[i], (crop_length, crop_length))
        yield (batch_crops, batch_y)

# %%
from tensorflow.keras.preprocessing.image import img_to_array,load_img
import glob

# 데이터 전체에 대해 centering 진행함.

def read_cal_image(img_path): 
    x = img_to_array(load_img(img_path)) # x는 채널별 평균값
    y = x.shape[0] * x.shape[1]# y는 데이터별 픽셀 수 (비중)

    x = 1/255. * x # scaling하고, centering값을 뽑아냄.
    x = np.mean(x, axis=(0,1))
    
    return np.hstack([x,y])

def calculate_centered_mean(dataset_path,x_train=x_train):
    num = len(x_train)
    space = np.empty((num,4))
    i=0

    for p in glob.glob(os.path.join(dataset_path,'*/*.*')) :
        space[i] = read_cal_image(p)
        i += 1

    ratio = space[:,3] / np.sum(space[:,3])

    return np.average(space[:,0:3],axis=0,weights=ratio)


# 아래의 함수를 돌려서 나온 결과값을 중심화 값으로 설정.

# train_mean = calculate_centered_mean(os.path.join(dir,'data/train')).reshape((1,1,3))

# %%
datagen_tr = ImageDataGenerator(
    rescale=1/255.,
    horizontal_flip=True,
    featurewise_center=True,
    featurewise_std_normalization=False,
    rotation_range=10,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=[0.9,1.0],
    fill_mode = 'nearest')
datagen_val = ImageDataGenerator(rescale=1/255.,featurewise_center=True)
datagen_tes = ImageDataGenerator(rescale=1/255.,featurewise_center=True)

# 원래는 이 자리에 fit 매서드를 써야하지만, 그냥 내가 중심화함수를 만들고 적용함. 

# 중심화 설정
datagen_tr.mean = np.array(tr_center, dtype=np.float32).reshape((1,1,3)) # RGB
datagen_val.mean = np.array(tr_center, dtype=np.float32).reshape((1,1,3)) # RGB
datagen_tes.mean = np.array(tr_center, dtype=np.float32).reshape((1,1,3)) # RGB

# %%
train_batches = datagen_tr.flow_from_directory(directory=os.path.join(dir,'data/train'),target_size=(super_size,super_size),batch_size=batch_sizes,class_mode='categorical') # fer : 28698 / mit : 12466 / caltech : 24509 / cifar : 44923
train_generator= crop_generator(train_batches, size)
valid_generator = datagen_val.flow_from_directory(directory=os.path.join(dir,'data/valid'),target_size=(size,size),batch_size=batch_sizes,class_mode='categorical') # fer : 3589 / mit : 1564 / caltech : 2980 / cifar : 5077
test_generator = datagen_tes.flow_from_directory(directory=os.path.join(dir,'data/test'),target_size=(size,size),batch_size=batch_sizes,class_mode='categorical') # fer : 3588 / mit : 1590 / caltech : 3118 / cifar : 10000
# Out:
# Found 28698 images belonging to 7 classes.
# Found 3589 images belonging to 7 classes.
# Found 3588 images belonging to 7 classes.

# %% [markdown]
# ## 2. Support Functions & Almost Original ResNet
# ---

# %% [markdown]
# ### 1) Support Functions

# %%
# def lr_schedule(epoch):
#     init_lr = 1e-4
#     k = 0.04
#     lr = init_lr * np.exp(-k*epoch)
#     print('Learning rate: ', lr)
#     return lr

def lr_schedule(epoch):
    lr = 1e-3
    if epoch < 30:
        lr = lr
    elif epoch < 60 :
        lr = lr * 0.1
    else:
        lr = lr * 0.01
    print('Learning rate: ', lr)
    return lr

# %%
def _resnet_block(input_tensor, filters, k=1, strides=(1, 1), weight_decay = weight_decay):

    init = input_tensor
    channel_axis = -1

    if strides != (1, 1) or init.get_shape()[channel_axis] != filters * k:
        x = Conv2D(filters * k, (1, 1), padding='same', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay),
                      use_bias=False, strides=strides)(input_tensor)
        init = BatchNormalization(axis=channel_axis)(x)


    x = Conv2D(filters * k, (3, 3), padding='same', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay),
               use_bias=False, strides=strides)(input_tensor)
    x = BatchNormalization(axis=channel_axis)(x)
    x = Activation('relu')(x)

    x = Conv2D(filters * k, (3, 3), padding='same', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay),
               use_bias=False)(x)
    x = BatchNormalization(axis=channel_axis)(x)

    m = add([x, init])
    m = Activation('relu')(m)

    return m

# %%
def _resnet_bottleneck_block(input_tensor, filters, k=1, strides=(1, 1), weight_decay = weight_decay):

    init = input_tensor
    channel_axis = -1
    bottleneck_expand = 4

    if strides != (1, 1) or init.get_shape()[channel_axis] != bottleneck_expand * filters * k:
        x = Conv2D(bottleneck_expand * filters * k, (1, 1), padding='same', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay),
                      use_bias=False, strides=strides)(input_tensor)
        init = BatchNormalization(axis=channel_axis)(x)


    x = Conv2D(filters * k, (1, 1), padding='same', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay),
               use_bias=False)(input_tensor)
    x = BatchNormalization(axis=channel_axis)(x)
    x = Activation('relu')(x)

    x = Conv2D(filters * k, (3, 3), padding='same', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay),
               use_bias=False, strides=strides)(x)
    x = BatchNormalization(axis=channel_axis)(x)
    x = Activation('relu')(x)

    x = Conv2D(bottleneck_expand * filters * k, (1, 1), padding='same', kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay),
               use_bias=False)(x)
    x = BatchNormalization(axis=channel_axis)(x)    

    m = add([x, init])
    m = Activation('relu')(m)

    return m

# %% [markdown]
# ### 2) Almost Orginial ResNet

# %%
def _create_resnet(classes, img_input, initial_conv_filters, filters, depth, width, bottleneck, weight_decay):

    channel_axis = -1
    N = list(depth)

    # block 1 (initial conv block)
    x = Conv2D(initial_conv_filters, (7, 7), padding='same', use_bias=False, strides=(2, 2), kernel_initializer='he_uniform', kernel_regularizer=l2(weight_decay))(img_input)
    x = MaxPooling2D((3, 3), strides=(2, 2), padding='same')(x)

    # block 2 (projection block)
    for i in range(N[0]):
        if bottleneck:
            x = _resnet_bottleneck_block(x, filters[0], width)
        else:
            x = _resnet_block(x, filters[0], width)

    # block 3 - N
    for k in range(1, len(N)):
        if bottleneck:
            x = _resnet_bottleneck_block(x, filters[k], width, strides=(2, 2))
        else:
            x = _resnet_block(x, filters[k], width, strides=(2, 2))

        for i in range(N[k] - 1):
            if bottleneck:
                x = _resnet_bottleneck_block(x, filters[k], width)
            else:
                x = _resnet_block(x, filters[k], width)

    x = GlobalAveragePooling2D()(x)
    x = Dense(classes, use_bias=False, kernel_regularizer=l2(weight_decay), activation='softmax')(x)


    return x

# %%
def ResNet(input_shape=None, initial_conv_filters=64, depth=[3, 4, 6, 3], filters=[64, 128, 256, 512],
             width=1, bottleneck=False, weight_decay=weight_decay, name=None, classes=1000):


    img_input = Input(shape=input_shape)

    x = _create_resnet(classes, img_input, initial_conv_filters, filters, depth, width, bottleneck, weight_decay)

    # Ensure that the model takes into account
    # any potential predecessors of `input_tensor`.

    inputs = img_input

    # Create model.
    model = Model(inputs, x, name = name)

    return model

# %% [markdown]
# ## 3. ResNet50
# ---

# %% [markdown]
# ### 1) ResNet50

# %%
# ResNet50
model = ResNet(input_shape=input_sizes, depth=[3, 4, 6, 3], width=1, bottleneck=True, weight_decay=weight_decay, classes=classes, name='ResNet50')

# %%
model.summary()
# Out:
# Model: "ResNet50"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 112, 112, 64) 9408        input_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 56, 56, 64)   0           conv2d[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 56, 56, 64)   4096        max_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 56, 56, 64)   256         conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 56, 56, 64)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 56, 56, 64)   36864       activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 56, 56, 64)   256         conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 56, 56, 64)   0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 56, 56, 256)  16384       activation_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 56, 56, 256)  16384       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 56, 56, 256)  1024        conv2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 56, 56, 256)  1024        conv2d_1[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 56, 56, 256)  0           batch_normalization_3[0][0]
#                                                                  batch_normalization[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 56, 56, 256)  0           add[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 56, 56, 64)   16384       activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 56, 56, 64)   256         conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 56, 56, 64)   0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 56, 56, 64)   36864       activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 56, 56, 64)   256         conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 56, 56, 64)   0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 56, 56, 256)  16384       activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 56, 56, 256)  1024        conv2d_7[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 56, 56, 256)  0           batch_normalization_6[0][0]
#                                                                  activation_2[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 56, 56, 256)  0           add_1[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 56, 56, 64)   16384       activation_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 56, 56, 64)   256         conv2d_8[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 56, 56, 64)   0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 56, 56, 64)   36864       activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 56, 56, 64)   256         conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 56, 56, 64)   0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 56, 56, 256)  16384       activation_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 56, 56, 256)  1024        conv2d_10[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 56, 56, 256)  0           batch_normalization_9[0][0]
#                                                                  activation_5[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 56, 56, 256)  0           add_2[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 56, 56, 128)  32768       activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 56, 56, 128)  512         conv2d_12[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 56, 56, 128)  0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 28, 28, 128)  147456      activation_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 28, 28, 128)  512         conv2d_13[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 28, 28, 128)  0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 28, 28, 512)  65536       activation_10[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 28, 28, 512)  131072      activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 28, 28, 512)  2048        conv2d_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 28, 28, 512)  2048        conv2d_11[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 28, 28, 512)  0           batch_normalization_13[0][0]
#                                                                  batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 28, 28, 512)  0           add_3[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 28, 28, 128)  65536       activation_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 28, 28, 128)  512         conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 28, 28, 128)  0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 28, 28, 128)  147456      activation_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 28, 28, 128)  512         conv2d_16[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 28, 28, 128)  0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 28, 28, 512)  65536       activation_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 28, 28, 512)  2048        conv2d_17[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 28, 28, 512)  0           batch_normalization_16[0][0]
#                                                                  activation_11[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 28, 28, 512)  0           add_4[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 28, 28, 128)  65536       activation_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 28, 28, 128)  512         conv2d_18[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 28, 28, 128)  0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 28, 28, 128)  147456      activation_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 28, 28, 128)  512         conv2d_19[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 28, 28, 128)  0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 28, 28, 512)  65536       activation_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 28, 28, 512)  2048        conv2d_20[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 28, 28, 512)  0           batch_normalization_19[0][0]
#                                                                  activation_14[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 28, 28, 512)  0           add_5[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 28, 28, 128)  65536       activation_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 28, 28, 128)  512         conv2d_21[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 28, 28, 128)  0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 28, 28, 128)  147456      activation_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 28, 28, 128)  512         conv2d_22[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 28, 28, 128)  0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 28, 28, 512)  65536       activation_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 28, 28, 512)  2048        conv2d_23[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 28, 28, 512)  0           batch_normalization_22[0][0]
#                                                                  activation_17[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 28, 28, 512)  0           add_6[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 28, 28, 256)  131072      activation_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 28, 28, 256)  1024        conv2d_25[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 28, 28, 256)  0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 14, 14, 256)  589824      activation_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 14, 14, 256)  1024        conv2d_26[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 14, 14, 256)  0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 14, 14, 1024) 262144      activation_22[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 14, 14, 1024) 524288      activation_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 14, 14, 1024) 4096        conv2d_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 14, 14, 1024) 4096        conv2d_24[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 14, 14, 1024) 0           batch_normalization_26[0][0]
#                                                                  batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 14, 14, 1024) 0           add_7[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 14, 14, 256)  262144      activation_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 14, 14, 256)  1024        conv2d_28[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 14, 14, 256)  0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 14, 14, 256)  589824      activation_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 14, 14, 256)  1024        conv2d_29[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 14, 14, 256)  0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 14, 14, 1024) 262144      activation_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 14, 14, 1024) 4096        conv2d_30[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 14, 14, 1024) 0           batch_normalization_29[0][0]
#                                                                  activation_23[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 14, 14, 1024) 0           add_8[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 14, 14, 256)  262144      activation_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 14, 14, 256)  1024        conv2d_31[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 14, 14, 256)  0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 14, 14, 256)  589824      activation_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 14, 14, 256)  1024        conv2d_32[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 14, 14, 256)  0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 14, 14, 1024) 262144      activation_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 14, 14, 1024) 4096        conv2d_33[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 14, 14, 1024) 0           batch_normalization_32[0][0]
#                                                                  activation_26[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 14, 14, 1024) 0           add_9[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 14, 14, 256)  262144      activation_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 14, 14, 256)  1024        conv2d_34[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 14, 14, 256)  0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 14, 14, 256)  589824      activation_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 14, 14, 256)  1024        conv2d_35[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 14, 14, 256)  0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 14, 14, 1024) 262144      activation_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 14, 14, 1024) 4096        conv2d_36[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 14, 14, 1024) 0           batch_normalization_35[0][0]
#                                                                  activation_29[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 14, 14, 1024) 0           add_10[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 14, 14, 256)  262144      activation_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 14, 14, 256)  1024        conv2d_37[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 14, 14, 256)  0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 14, 14, 256)  589824      activation_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 14, 14, 256)  1024        conv2d_38[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 14, 14, 256)  0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 14, 14, 1024) 262144      activation_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 14, 14, 1024) 4096        conv2d_39[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 14, 14, 1024) 0           batch_normalization_38[0][0]
#                                                                  activation_32[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 14, 14, 1024) 0           add_11[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 14, 14, 256)  262144      activation_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 14, 14, 256)  1024        conv2d_40[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 14, 14, 256)  0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 14, 14, 256)  589824      activation_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 14, 14, 256)  1024        conv2d_41[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 14, 14, 256)  0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 14, 14, 1024) 262144      activation_37[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 14, 14, 1024) 4096        conv2d_42[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 14, 14, 1024) 0           batch_normalization_41[0][0]
#                                                                  activation_35[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 14, 14, 1024) 0           add_12[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 14, 14, 512)  524288      activation_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 14, 14, 512)  2048        conv2d_44[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 14, 14, 512)  0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 7, 7, 512)    2359296     activation_39[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 7, 7, 512)    2048        conv2d_45[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 7, 7, 512)    0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 7, 7, 2048)   1048576     activation_40[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 7, 7, 2048)   2097152     activation_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 7, 7, 2048)   8192        conv2d_46[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 7, 7, 2048)   8192        conv2d_43[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 7, 7, 2048)   0           batch_normalization_45[0][0]
#                                                                  batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 7, 7, 2048)   0           add_13[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 7, 7, 512)    1048576     activation_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 7, 7, 512)    2048        conv2d_47[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 7, 7, 512)    0           batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 7, 7, 512)    2359296     activation_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 7, 7, 512)    2048        conv2d_48[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 7, 7, 512)    0           batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 7, 7, 2048)   1048576     activation_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 7, 7, 2048)   8192        conv2d_49[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 7, 7, 2048)   0           batch_normalization_48[0][0]
#                                                                  activation_41[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 7, 7, 2048)   0           add_14[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 7, 7, 512)    1048576     activation_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 7, 7, 512)    2048        conv2d_50[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 7, 7, 512)    0           batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 7, 7, 512)    2359296     activation_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 7, 7, 512)    2048        conv2d_51[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 7, 7, 512)    0           batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 7, 7, 2048)   1048576     activation_46[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 7, 7, 2048)   8192        conv2d_52[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 7, 7, 2048)   0           batch_normalization_51[0][0]
#                                                                  activation_44[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 7, 7, 2048)   0           add_15[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 2048)         0           activation_47[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 7)            14336       global_average_pooling2d[0][0]
# ==================================================================================================
# Total params: 23,575,232
# Trainable params: 23,522,240
# Non-trainable params: 52,992
# __________________________________________________________________________________________________

# %%
# 폴더 생성

os.makedirs(os.path.join(dir,'model_output',number,model.name), exist_ok=True)
os.makedirs(os.path.join(dir,'train_valid_output',number), exist_ok=True)

# %%
# 참고 : https://github.com/OverLordGoldDragon/keras-adamw

import sys
sys.path.append('/content/drive/My Drive/Colab Notebooks/Paper')
import utils
import optimizers_v2
from utils import get_weight_decays, fill_dict_in_order
from utils import reset_seeds, K_eval
from optimizers_v2 import AdamW, NadamW, SGDW

# %%
# top-5 accuracy 출력
import functools
top5_acc = functools.partial(ks.metrics.top_k_categorical_accuracy, k=5)
top5_acc.__name__ = 'top5_acc'

# %%
#optimizer = SGDW(model=model, use_cosine_annealing=False, total_iterations = len(x_train) // batch_sizes, nesterov=True, momentum=0.9)
optimizer = AdamW(model=model, use_cosine_annealing=False, total_iterations = len(x_train) // batch_sizes)
#optimizer = Adam()
filepath =  os.path.join(dir,'model_output',number,model.name,'{epoch:03d}.h5')

callbacks_list = [ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_weights_only=False, save_best_only=True, mode='min'),
                  ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_weights_only=False, save_best_only=True, mode='max'),
                  #ReduceLROnPlateau(monitor='val_loss',patience=3,factor=0.1,min_lr=1e-5),
                  LearningRateScheduler(lr_schedule,verbose=1)
                  ]
                  
model.compile(optimizer, loss = 'categorical_crossentropy', metrics=['accuracy',top5_acc,macro_f1score])

# %%
######## flow_from_directory
history = model.fit(train_generator, steps_per_epoch=int(len(x_train)/batch_sizes),  validation_data = valid_generator, epochs=epochs , verbose=1 , callbacks = callbacks_list , validation_steps=int(len(x_valid)/batch_sizes))
# Out:
# Learning rate:  0.001
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 1/70
# 0.0(L1), 0.0001336306273033261(L2) weight decay set for conv2d/kernel:0
# 0.0(L1), 0.0001336306273033261(L2) weight decay set for conv2d_2/kernel:0
# 0.0(L1), 0.0001336306273033261(L2) weight decay set for conv2d_3/kernel:0
# 0.0(L1), 0.0001336306273033261(L2) weight decay set for conv2d_4/kernel:0
# 0.0(L1), 0.0001336306273033261(L2) weight decay set for conv2d_1/kernel:0
# 0.0(L1), 0.0001336306273033261(L2) weight decay set for conv2d_5/kernel:0
# 0.0(L1), 0.0001336306273033261(L2) weight decay set for conv2d_6/kernel:0
# 0.0(L1), 0.0001336306273033261(L2) weight decay set for conv2d_7/kernel:0
# 0.0(L1), 0.0001336306273033261(L2) weight decay set for conv2d_8/kernel:0
# 0.0(L1), 0.0001336306273033261(L2) weight decay set for conv2d_9/kernel:0
# 0.0(L1), 0.0001336306273033261(L2) weight decay set for conv2d_10/kernel:0
# 0.0(L1), 0.0001336306273033261(L2) weight decay set for conv2d_12/kernel:0
# 0.0(L1), 0.0001336306273033261(L2) weight decay set for conv2d_13/kernel:0
# 0.0(L1), 0.0001336306273033261(L2) weight decay set for conv2d_14/kernel:0
# 0.0(L1), 0.0001336306273033261(L2) weight decay set for conv2d_11/kernel:0
# 0.0(L1), 0.0001336306273033261(L2) weight decay set for conv2d_15/kernel:0
# 0.0(L1), 0.0001336306273033261(L2) weight decay set for conv2d_16/kernel:0
# 0.0(L1), 0.0001336306273033261(L2) weight decay set for conv2d_17/kernel:0
# 0.0(L1), 0.0001336306273033261(L2) weight decay set for conv2d_18/kernel:0
# 0.0(L1), 0.0001336306273033261(L2) weight decay set for conv2d_19/kernel:0
# 0.0(L1), 0.0001336306273033261(L2) weight decay set for conv2d_20/kernel:0
# 0.0(L1), 0.0001336306273033261(L2) weight decay set for conv2d_21/kernel:0
# 0.0(L1), 0.0001336306273033261(L2) weight decay set for conv2d_22/kernel:0
# 0.0(L1), 0.0001336306273033261(L2) weight decay set for conv2d_23/kernel:0
# 0.0(L1), 0.0001336306273033261(L2) weight decay set for conv2d_25/kernel:0
# 0.0(L1), 0.0001336306273033261(L2) weight decay set for conv2d_26/kernel:0
# 0.0(L1), 0.0001336306273033261(L2) weight decay set for conv2d_27/kernel:0
# 0.0(L1), 0.0001336306273033261(L2) weight decay set for conv2d_24/kernel:0
# 0.0(L1), 0.0001336306273033261(L2) weight decay set for conv2d_28/kernel:0
# 0.0(L1), 0.0001336306273033261(L2) weight decay set for conv2d_29/kernel:0
# 0.0(L1), 0.0001336306273033261(L2) weight decay set for conv2d_30/kernel:0
# 0.0(L1), 0.0001336306273033261(L2) weight decay set for conv2d_31/kernel:0
# 0.0(L1), 0.0001336306273033261(L2) weight decay set for conv2d_32/kernel:0
# 0.0(L1), 0.0001336306273033261(L2) weight decay set for conv2d_33/kernel:0
# 0.0(L1), 0.0001336306273033261(L2) weight decay set for conv2d_34/kernel:0
# 0.0(L1), 0.0001336306273033261(L2) weight decay set for conv2d_35/kernel:0
# 0.0(L1), 0.0001336306273033261(L2) weight decay set for conv2d_36/kernel:0
# 0.0(L1), 0.0001336306273033261(L2) weight decay set for conv2d_37/kernel:0
# 0.0(L1), 0.0001336306273033261(L2) weight decay set for conv2d_38/kernel:0
# 0.0(L1), 0.0001336306273033261(L2) weight decay set for conv2d_39/kernel:0
# 0.0(L1), 0.0001336306273033261(L2) weight decay set for conv2d_40/kernel:0
# 0.0(L1), 0.0001336306273033261(L2) weight decay set for conv2d_41/kernel:0
# 0.0(L1), 0.0001336306273033261(L2) weight decay set for conv2d_42/kernel:0
# 0.0(L1), 0.0001336306273033261(L2) weight decay set for conv2d_44/kernel:0
# 0.0(L1), 0.0001336306273033261(L2) weight decay set for conv2d_45/kernel:0
# 0.0(L1), 0.0001336306273033261(L2) weight decay set for conv2d_46/kernel:0
# 0.0(L1), 0.0001336306273033261(L2) weight decay set for conv2d_43/kernel:0
# 0.0(L1), 0.0001336306273033261(L2) weight decay set for conv2d_47/kernel:0
# 0.0(L1), 0.0001336306273033261(L2) weight decay set for conv2d_48/kernel:0
# 0.0(L1), 0.0001336306273033261(L2) weight decay set for conv2d_49/kernel:0
# 0.0(L1), 0.0001336306273033261(L2) weight decay set for conv2d_50/kernel:0
# 0.0(L1), 0.0001336306273033261(L2) weight decay set for conv2d_51/kernel:0
# 0.0(L1), 0.0001336306273033261(L2) weight decay set for conv2d_52/kernel:0
# 0.0(L1), 0.0001336306273033261(L2) weight decay set for dense/kernel:0
# 224/224 [==============================] - ETA: 0s - loss: 1.8561 - accuracy: 0.2795 - top5_acc: 0.8993 - macro_f1score: 0.0358
# Epoch 00001: val_loss improved from inf to 72.61460, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/ResNet50/001.h5
#
# Epoch 00001: val_accuracy improved from -inf to 0.16574, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/ResNet50/001.h5
# 224/224 [==============================] - 14610s 65s/step - loss: 1.8561 - accuracy: 0.2795 - top5_acc: 0.8993 - macro_f1score: 0.0358 - val_loss: 72.6146 - val_accuracy: 0.1657 - val_top5_acc: 0.8069 - val_macro_f1score: 0.0405
# Learning rate:  0.001
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 2/70
# 224/224 [==============================] - ETA: 0s - loss: 1.6142 - accuracy: 0.3746 - top5_acc: 0.9384 - macro_f1score: 0.1382
# Epoch 00002: val_loss improved from 72.61460 to 56.24793, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/ResNet50/002.h5
#
# Epoch 00002: val_accuracy improved from 0.16574 to 0.20061, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/ResNet50/002.h5
# 224/224 [==============================] - 443s 2s/step - loss: 1.6142 - accuracy: 0.3746 - top5_acc: 0.9384 - macro_f1score: 0.1382 - val_loss: 56.2479 - val_accuracy: 0.2006 - val_top5_acc: 0.8722 - val_macro_f1score: 0.1242
# Learning rate:  0.001
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 3/70
# 224/224 [==============================] - ETA: 0s - loss: 1.4378 - accuracy: 0.4562 - top5_acc: 0.9575 - macro_f1score: 0.2134
# Epoch 00003: val_loss improved from 56.24793 to 3.39085, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/ResNet50/003.h5
#
# Epoch 00003: val_accuracy did not improve from 0.20061
# 224/224 [==============================] - 442s 2s/step - loss: 1.4378 - accuracy: 0.4562 - top5_acc: 0.9575 - macro_f1score: 0.2134 - val_loss: 3.3908 - val_accuracy: 0.1964 - val_top5_acc: 0.8393 - val_macro_f1score: 0.0946
# Learning rate:  0.001
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 4/70
# 224/224 [==============================] - ETA: 0s - loss: 1.3118 - accuracy: 0.4979 - top5_acc: 0.9656 - macro_f1score: 0.2679
# Epoch 00004: val_loss improved from 3.39085 to 1.37964, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/ResNet50/004.h5
#
# Epoch 00004: val_accuracy improved from 0.20061 to 0.49219, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/ResNet50/004.h5
# 224/224 [==============================] - 444s 2s/step - loss: 1.3118 - accuracy: 0.4979 - top5_acc: 0.9656 - macro_f1score: 0.2679 - val_loss: 1.3796 - val_accuracy: 0.4922 - val_top5_acc: 0.9601 - val_macro_f1score: 0.2650
# Learning rate:  0.001
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 5/70
# 224/224 [==============================] - ETA: 0s - loss: 1.2302 - accuracy: 0.5328 - top5_acc: 0.9743 - macro_f1score: 0.3122
# Epoch 00005: val_loss did not improve from 1.37964
#
# Epoch 00005: val_accuracy did not improve from 0.49219
# 224/224 [==============================] - 445s 2s/step - loss: 1.2302 - accuracy: 0.5328 - top5_acc: 0.9743 - macro_f1score: 0.3122 - val_loss: 1.5302 - val_accuracy: 0.4364 - val_top5_acc: 0.9693 - val_macro_f1score: 0.2903
# Learning rate:  0.001
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 6/70
# 224/224 [==============================] - ETA: 0s - loss: 1.1801 - accuracy: 0.5488 - top5_acc: 0.9777 - macro_f1score: 0.3463
# Epoch 00006: val_loss did not improve from 1.37964
#
# Epoch 00006: val_accuracy did not improve from 0.49219
# 224/224 [==============================] - 448s 2s/step - loss: 1.1801 - accuracy: 0.5488 - top5_acc: 0.9777 - macro_f1score: 0.3463 - val_loss: 1.5458 - val_accuracy: 0.4754 - val_top5_acc: 0.9615 - val_macro_f1score: 0.3141
# Learning rate:  0.001
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 7/70
# 224/224 [==============================] - ETA: 0s - loss: 1.1420 - accuracy: 0.5671 - top5_acc: 0.9795 - macro_f1score: 0.3698
# Epoch 00007: val_loss improved from 1.37964 to 1.30608, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/ResNet50/007.h5
#
# Epoch 00007: val_accuracy improved from 0.49219 to 0.51590, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/ResNet50/007.h5
# 224/224 [==============================] - 444s 2s/step - loss: 1.1420 - accuracy: 0.5671 - top5_acc: 0.9795 - macro_f1score: 0.3698 - val_loss: 1.3061 - val_accuracy: 0.5159 - val_top5_acc: 0.9721 - val_macro_f1score: 0.3212
# Learning rate:  0.001
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 8/70
# 224/224 [==============================] - ETA: 0s - loss: 1.1137 - accuracy: 0.5779 - top5_acc: 0.9804 - macro_f1score: 0.3901
# Epoch 00008: val_loss improved from 1.30608 to 1.26255, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/ResNet50/008.h5
#
# Epoch 00008: val_accuracy improved from 0.51590 to 0.52539, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/ResNet50/008.h5
# 224/224 [==============================] - 444s 2s/step - loss: 1.1137 - accuracy: 0.5779 - top5_acc: 0.9804 - macro_f1score: 0.3901 - val_loss: 1.2625 - val_accuracy: 0.5254 - val_top5_acc: 0.9724 - val_macro_f1score: 0.3721
# Learning rate:  0.001
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 9/70
# 224/224 [==============================] - ETA: 0s - loss: 1.0898 - accuracy: 0.5860 - top5_acc: 0.9829 - macro_f1score: 0.4078
# Epoch 00009: val_loss improved from 1.26255 to 1.21114, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/ResNet50/009.h5
#
# Epoch 00009: val_accuracy improved from 0.52539 to 0.55162, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/ResNet50/009.h5
# 224/224 [==============================] - 441s 2s/step - loss: 1.0898 - accuracy: 0.5860 - top5_acc: 0.9829 - macro_f1score: 0.4078 - val_loss: 1.2111 - val_accuracy: 0.5516 - val_top5_acc: 0.9777 - val_macro_f1score: 0.3409
# Learning rate:  0.001
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 10/70
# 224/224 [==============================] - ETA: 0s - loss: 1.0655 - accuracy: 0.6005 - top5_acc: 0.9843 - macro_f1score: 0.4244
# Epoch 00010: val_loss did not improve from 1.21114
#
# Epoch 00010: val_accuracy did not improve from 0.55162
# 224/224 [==============================] - 436s 2s/step - loss: 1.0655 - accuracy: 0.6005 - top5_acc: 0.9843 - macro_f1score: 0.4244 - val_loss: 1.5255 - val_accuracy: 0.4355 - val_top5_acc: 0.9777 - val_macro_f1score: 0.3069
# Learning rate:  0.001
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 11/70
# 224/224 [==============================] - ETA: 0s - loss: 1.0467 - accuracy: 0.6078 - top5_acc: 0.9846 - macro_f1score: 0.4396
# Epoch 00011: val_loss improved from 1.21114 to 1.16760, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/ResNet50/011.h5
#
# Epoch 00011: val_accuracy improved from 0.55162 to 0.55776, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/ResNet50/011.h5
# 224/224 [==============================] - 441s 2s/step - loss: 1.0467 - accuracy: 0.6078 - top5_acc: 0.9846 - macro_f1score: 0.4396 - val_loss: 1.1676 - val_accuracy: 0.5578 - val_top5_acc: 0.9754 - val_macro_f1score: 0.3868
# Learning rate:  0.001
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 12/70
# 224/224 [==============================] - ETA: 0s - loss: 1.0370 - accuracy: 0.6105 - top5_acc: 0.9866 - macro_f1score: 0.4522
# Epoch 00012: val_loss improved from 1.16760 to 1.16621, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/ResNet50/012.h5
#
# Epoch 00012: val_accuracy improved from 0.55776 to 0.56836, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/ResNet50/012.h5
# 224/224 [==============================] - 443s 2s/step - loss: 1.0370 - accuracy: 0.6105 - top5_acc: 0.9866 - macro_f1score: 0.4522 - val_loss: 1.1662 - val_accuracy: 0.5684 - val_top5_acc: 0.9699 - val_macro_f1score: 0.3822
# Learning rate:  0.001
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 13/70
# 224/224 [==============================] - ETA: 0s - loss: 1.0151 - accuracy: 0.6186 - top5_acc: 0.9859 - macro_f1score: 0.4643
# Epoch 00013: val_loss did not improve from 1.16621
#
# Epoch 00013: val_accuracy did not improve from 0.56836
# 224/224 [==============================] - 449s 2s/step - loss: 1.0151 - accuracy: 0.6186 - top5_acc: 0.9859 - macro_f1score: 0.4643 - val_loss: 1.1933 - val_accuracy: 0.5477 - val_top5_acc: 0.9807 - val_macro_f1score: 0.3833
# Learning rate:  0.001
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 14/70
# 224/224 [==============================] - ETA: 0s - loss: 0.9990 - accuracy: 0.6242 - top5_acc: 0.9874 - macro_f1score: 0.4764
# Epoch 00014: val_loss improved from 1.16621 to 1.15585, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/ResNet50/014.h5
#
# Epoch 00014: val_accuracy improved from 0.56836 to 0.57087, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/ResNet50/014.h5
# 224/224 [==============================] - 452s 2s/step - loss: 0.9990 - accuracy: 0.6242 - top5_acc: 0.9874 - macro_f1score: 0.4764 - val_loss: 1.1559 - val_accuracy: 0.5709 - val_top5_acc: 0.9807 - val_macro_f1score: 0.4013
# Learning rate:  0.001
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 15/70
# 224/224 [==============================] - ETA: 0s - loss: 0.9957 - accuracy: 0.6273 - top5_acc: 0.9877 - macro_f1score: 0.4763
# Epoch 00015: val_loss improved from 1.15585 to 1.14560, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/ResNet50/015.h5
#
# Epoch 00015: val_accuracy did not improve from 0.57087
# 224/224 [==============================] - 447s 2s/step - loss: 0.9957 - accuracy: 0.6273 - top5_acc: 0.9877 - macro_f1score: 0.4763 - val_loss: 1.1456 - val_accuracy: 0.5653 - val_top5_acc: 0.9754 - val_macro_f1score: 0.4163
# Learning rate:  0.001
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 16/70
# 224/224 [==============================] - ETA: 0s - loss: 0.9823 - accuracy: 0.6321 - top5_acc: 0.9878 - macro_f1score: 0.4825
# Epoch 00016: val_loss did not improve from 1.14560
#
# Epoch 00016: val_accuracy did not improve from 0.57087
# 224/224 [==============================] - 446s 2s/step - loss: 0.9823 - accuracy: 0.6321 - top5_acc: 0.9878 - macro_f1score: 0.4825 - val_loss: 1.2684 - val_accuracy: 0.5525 - val_top5_acc: 0.9799 - val_macro_f1score: 0.3833
# Learning rate:  0.001
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 17/70
# 224/224 [==============================] - ETA: 0s - loss: 0.9698 - accuracy: 0.6360 - top5_acc: 0.9888 - macro_f1score: 0.4915
# Epoch 00017: val_loss did not improve from 1.14560
#
# Epoch 00017: val_accuracy improved from 0.57087 to 0.57310, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/ResNet50/017.h5
# 224/224 [==============================] - 442s 2s/step - loss: 0.9698 - accuracy: 0.6360 - top5_acc: 0.9888 - macro_f1score: 0.4915 - val_loss: 1.2491 - val_accuracy: 0.5731 - val_top5_acc: 0.9802 - val_macro_f1score: 0.4060
# Learning rate:  0.001
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 18/70
# 224/224 [==============================] - ETA: 0s - loss: 0.9640 - accuracy: 0.6399 - top5_acc: 0.9879 - macro_f1score: 0.5051
# Epoch 00018: val_loss improved from 1.14560 to 1.04714, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/ResNet50/018.h5
#
# Epoch 00018: val_accuracy improved from 0.57310 to 0.59766, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/ResNet50/018.h5
# 224/224 [==============================] - 445s 2s/step - loss: 0.9640 - accuracy: 0.6399 - top5_acc: 0.9879 - macro_f1score: 0.5051 - val_loss: 1.0471 - val_accuracy: 0.5977 - val_top5_acc: 0.9880 - val_macro_f1score: 0.4310
# Learning rate:  0.001
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 19/70
# 224/224 [==============================] - ETA: 0s - loss: 0.9456 - accuracy: 0.6442 - top5_acc: 0.9893 - macro_f1score: 0.5134
# Epoch 00019: val_loss did not improve from 1.04714
#
# Epoch 00019: val_accuracy did not improve from 0.59766
# 224/224 [==============================] - 439s 2s/step - loss: 0.9456 - accuracy: 0.6442 - top5_acc: 0.9893 - macro_f1score: 0.5134 - val_loss: 1.1073 - val_accuracy: 0.5756 - val_top5_acc: 0.9855 - val_macro_f1score: 0.4371
# Learning rate:  0.001
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 20/70
# 224/224 [==============================] - ETA: 0s - loss: 0.9354 - accuracy: 0.6501 - top5_acc: 0.9902 - macro_f1score: 0.5177
# Epoch 00020: val_loss did not improve from 1.04714
#
# Epoch 00020: val_accuracy improved from 0.59766 to 0.60491, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/ResNet50/020.h5
# 224/224 [==============================] - 443s 2s/step - loss: 0.9354 - accuracy: 0.6501 - top5_acc: 0.9902 - macro_f1score: 0.5177 - val_loss: 1.0991 - val_accuracy: 0.6049 - val_top5_acc: 0.9827 - val_macro_f1score: 0.4303
# Learning rate:  0.001
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 21/70
# 224/224 [==============================] - ETA: 0s - loss: 0.9340 - accuracy: 0.6503 - top5_acc: 0.9896 - macro_f1score: 0.5225
# Epoch 00021: val_loss did not improve from 1.04714
#
# Epoch 00021: val_accuracy did not improve from 0.60491
# 224/224 [==============================] - 449s 2s/step - loss: 0.9340 - accuracy: 0.6503 - top5_acc: 0.9896 - macro_f1score: 0.5225 - val_loss: 1.0707 - val_accuracy: 0.5926 - val_top5_acc: 0.9847 - val_macro_f1score: 0.4439
# Learning rate:  0.001
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 22/70
# 224/224 [==============================] - ETA: 0s - loss: 0.9217 - accuracy: 0.6543 - top5_acc: 0.9906 - macro_f1score: 0.5295
# Epoch 00022: val_loss did not improve from 1.04714
#
# Epoch 00022: val_accuracy did not improve from 0.60491
# 224/224 [==============================] - 447s 2s/step - loss: 0.9217 - accuracy: 0.6543 - top5_acc: 0.9906 - macro_f1score: 0.5295 - val_loss: 1.1268 - val_accuracy: 0.5809 - val_top5_acc: 0.9805 - val_macro_f1score: 0.4146
# Learning rate:  0.001
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 23/70
# 224/224 [==============================] - ETA: 0s - loss: 0.9079 - accuracy: 0.6594 - top5_acc: 0.9905 - macro_f1score: 0.5409
# Epoch 00023: val_loss improved from 1.04714 to 1.04700, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/ResNet50/023.h5
#
# Epoch 00023: val_accuracy improved from 0.60491 to 0.61830, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/ResNet50/023.h5
# 224/224 [==============================] - 448s 2s/step - loss: 0.9079 - accuracy: 0.6594 - top5_acc: 0.9905 - macro_f1score: 0.5409 - val_loss: 1.0470 - val_accuracy: 0.6183 - val_top5_acc: 0.9849 - val_macro_f1score: 0.4854
# Learning rate:  0.001
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 24/70
# 224/224 [==============================] - ETA: 0s - loss: 0.8983 - accuracy: 0.6636 - top5_acc: 0.9915 - macro_f1score: 0.5460
# Epoch 00024: val_loss did not improve from 1.04700
#
# Epoch 00024: val_accuracy did not improve from 0.61830
# 224/224 [==============================] - 439s 2s/step - loss: 0.8983 - accuracy: 0.6636 - top5_acc: 0.9915 - macro_f1score: 0.5460 - val_loss: 1.1371 - val_accuracy: 0.6002 - val_top5_acc: 0.9858 - val_macro_f1score: 0.4575
# Learning rate:  0.001
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 25/70
# 224/224 [==============================] - ETA: 0s - loss: 0.8925 - accuracy: 0.6666 - top5_acc: 0.9909 - macro_f1score: 0.5554
# Epoch 00025: val_loss improved from 1.04700 to 1.04128, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/ResNet50/025.h5
#
# Epoch 00025: val_accuracy did not improve from 0.61830
# 224/224 [==============================] - 435s 2s/step - loss: 0.8925 - accuracy: 0.6666 - top5_acc: 0.9909 - macro_f1score: 0.5554 - val_loss: 1.0413 - val_accuracy: 0.6147 - val_top5_acc: 0.9877 - val_macro_f1score: 0.4620
# Learning rate:  0.001
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 26/70
# 224/224 [==============================] - ETA: 0s - loss: 0.8848 - accuracy: 0.6694 - top5_acc: 0.9915 - macro_f1score: 0.5579
# Epoch 00026: val_loss did not improve from 1.04128
#
# Epoch 00026: val_accuracy improved from 0.61830 to 0.62109, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/ResNet50/026.h5
# 224/224 [==============================] - 433s 2s/step - loss: 0.8848 - accuracy: 0.6694 - top5_acc: 0.9915 - macro_f1score: 0.5579 - val_loss: 1.0478 - val_accuracy: 0.6211 - val_top5_acc: 0.9849 - val_macro_f1score: 0.4700
# Learning rate:  0.001
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 27/70
# 224/224 [==============================] - ETA: 0s - loss: 0.8714 - accuracy: 0.6713 - top5_acc: 0.9924 - macro_f1score: 0.5687
# Epoch 00027: val_loss did not improve from 1.04128
#
# Epoch 00027: val_accuracy did not improve from 0.62109
# 224/224 [==============================] - 436s 2s/step - loss: 0.8714 - accuracy: 0.6713 - top5_acc: 0.9924 - macro_f1score: 0.5687 - val_loss: 1.2248 - val_accuracy: 0.5667 - val_top5_acc: 0.9754 - val_macro_f1score: 0.4205
# Learning rate:  0.001
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 28/70
# 224/224 [==============================] - ETA: 0s - loss: 0.8651 - accuracy: 0.6766 - top5_acc: 0.9926 - macro_f1score: 0.5701
# Epoch 00028: val_loss improved from 1.04128 to 1.02465, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/ResNet50/028.h5
#
# Epoch 00028: val_accuracy did not improve from 0.62109
# 224/224 [==============================] - 437s 2s/step - loss: 0.8651 - accuracy: 0.6766 - top5_acc: 0.9926 - macro_f1score: 0.5701 - val_loss: 1.0247 - val_accuracy: 0.6183 - val_top5_acc: 0.9858 - val_macro_f1score: 0.5090
# Learning rate:  0.001
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 29/70
# 224/224 [==============================] - ETA: 0s - loss: 0.8571 - accuracy: 0.6772 - top5_acc: 0.9924 - macro_f1score: 0.5767
# Epoch 00029: val_loss did not improve from 1.02465
#
# Epoch 00029: val_accuracy did not improve from 0.62109
# 224/224 [==============================] - 441s 2s/step - loss: 0.8571 - accuracy: 0.6772 - top5_acc: 0.9924 - macro_f1score: 0.5767 - val_loss: 1.0402 - val_accuracy: 0.6150 - val_top5_acc: 0.9849 - val_macro_f1score: 0.5340
# Learning rate:  0.001
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 30/70
# 224/224 [==============================] - ETA: 0s - loss: 0.8385 - accuracy: 0.6868 - top5_acc: 0.9932 - macro_f1score: 0.5834
# Epoch 00030: val_loss did not improve from 1.02465
#
# Epoch 00030: val_accuracy did not improve from 0.62109
# 224/224 [==============================] - 438s 2s/step - loss: 0.8385 - accuracy: 0.6868 - top5_acc: 0.9932 - macro_f1score: 0.5834 - val_loss: 1.0891 - val_accuracy: 0.6004 - val_top5_acc: 0.9860 - val_macro_f1score: 0.4703
# Learning rate:  0.0001
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 31/70
# 224/224 [==============================] - ETA: 0s - loss: 0.7398 - accuracy: 0.7238 - top5_acc: 0.9957 - macro_f1score: 0.6508
# Epoch 00031: val_loss improved from 1.02465 to 0.90491, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/ResNet50/031.h5
#
# Epoch 00031: val_accuracy improved from 0.62109 to 0.66936, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/ResNet50/031.h5
# 224/224 [==============================] - 436s 2s/step - loss: 0.7398 - accuracy: 0.7238 - top5_acc: 0.9957 - macro_f1score: 0.6508 - val_loss: 0.9049 - val_accuracy: 0.6694 - val_top5_acc: 0.9900 - val_macro_f1score: 0.5880
# Learning rate:  0.0001
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 32/70
# 224/224 [==============================] - ETA: 0s - loss: 0.6876 - accuracy: 0.7434 - top5_acc: 0.9963 - macro_f1score: 0.6855
# Epoch 00032: val_loss did not improve from 0.90491
#
# Epoch 00032: val_accuracy did not improve from 0.66936
# 224/224 [==============================] - 429s 2s/step - loss: 0.6876 - accuracy: 0.7434 - top5_acc: 0.9963 - macro_f1score: 0.6855 - val_loss: 0.9239 - val_accuracy: 0.6646 - val_top5_acc: 0.9894 - val_macro_f1score: 0.5719
# Learning rate:  0.0001
#
# Epoch 00033: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 33/70
# 224/224 [==============================] - ETA: 0s - loss: 0.6679 - accuracy: 0.7505 - top5_acc: 0.9968 - macro_f1score: 0.7030
# Epoch 00033: val_loss did not improve from 0.90491
#
# Epoch 00033: val_accuracy improved from 0.66936 to 0.67048, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/ResNet50/033.h5
# 224/224 [==============================] - 428s 2s/step - loss: 0.6679 - accuracy: 0.7505 - top5_acc: 0.9968 - macro_f1score: 0.7030 - val_loss: 0.9072 - val_accuracy: 0.6705 - val_top5_acc: 0.9908 - val_macro_f1score: 0.5901
# Learning rate:  0.0001
#
# Epoch 00034: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 34/70
# 224/224 [==============================] - ETA: 0s - loss: 0.6554 - accuracy: 0.7557 - top5_acc: 0.9968 - macro_f1score: 0.7060
# Epoch 00034: val_loss did not improve from 0.90491
#
# Epoch 00034: val_accuracy improved from 0.67048 to 0.67132, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/ResNet50/034.h5
# 224/224 [==============================] - 434s 2s/step - loss: 0.6554 - accuracy: 0.7557 - top5_acc: 0.9968 - macro_f1score: 0.7060 - val_loss: 0.9067 - val_accuracy: 0.6713 - val_top5_acc: 0.9911 - val_macro_f1score: 0.6080
# Learning rate:  0.0001
#
# Epoch 00035: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 35/70
# 224/224 [==============================] - ETA: 0s - loss: 0.6447 - accuracy: 0.7608 - top5_acc: 0.9971 - macro_f1score: 0.7129
# Epoch 00035: val_loss did not improve from 0.90491
#
# Epoch 00035: val_accuracy improved from 0.67132 to 0.67662, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/ResNet50/035.h5
# 224/224 [==============================] - 443s 2s/step - loss: 0.6447 - accuracy: 0.7608 - top5_acc: 0.9971 - macro_f1score: 0.7129 - val_loss: 0.9100 - val_accuracy: 0.6766 - val_top5_acc: 0.9911 - val_macro_f1score: 0.6186
# Learning rate:  0.0001
#
# Epoch 00036: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 36/70
# 224/224 [==============================] - ETA: 0s - loss: 0.6292 - accuracy: 0.7650 - top5_acc: 0.9977 - macro_f1score: 0.7125
# Epoch 00036: val_loss did not improve from 0.90491
#
# Epoch 00036: val_accuracy did not improve from 0.67662
# 224/224 [==============================] - 443s 2s/step - loss: 0.6292 - accuracy: 0.7650 - top5_acc: 0.9977 - macro_f1score: 0.7125 - val_loss: 0.9330 - val_accuracy: 0.6691 - val_top5_acc: 0.9902 - val_macro_f1score: 0.5985
# Learning rate:  0.0001
#
# Epoch 00037: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 37/70
# 224/224 [==============================] - ETA: 0s - loss: 0.6231 - accuracy: 0.7660 - top5_acc: 0.9979 - macro_f1score: 0.7180
# Epoch 00037: val_loss did not improve from 0.90491
#
# Epoch 00037: val_accuracy did not improve from 0.67662
# 224/224 [==============================] - 447s 2s/step - loss: 0.6231 - accuracy: 0.7660 - top5_acc: 0.9979 - macro_f1score: 0.7180 - val_loss: 0.9228 - val_accuracy: 0.6685 - val_top5_acc: 0.9911 - val_macro_f1score: 0.6002
# Learning rate:  0.0001
#
# Epoch 00038: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 38/70
# 224/224 [==============================] - ETA: 0s - loss: 0.6084 - accuracy: 0.7720 - top5_acc: 0.9978 - macro_f1score: 0.7313
# Epoch 00038: val_loss did not improve from 0.90491
#
# Epoch 00038: val_accuracy did not improve from 0.67662
# 224/224 [==============================] - 443s 2s/step - loss: 0.6084 - accuracy: 0.7720 - top5_acc: 0.9978 - macro_f1score: 0.7313 - val_loss: 0.9160 - val_accuracy: 0.6766 - val_top5_acc: 0.9897 - val_macro_f1score: 0.6287
# Learning rate:  0.0001
#
# Epoch 00039: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 39/70
# 224/224 [==============================] - ETA: 0s - loss: 0.5940 - accuracy: 0.7802 - top5_acc: 0.9980 - macro_f1score: 0.7356
# Epoch 00039: val_loss did not improve from 0.90491
#
# Epoch 00039: val_accuracy did not improve from 0.67662
# 224/224 [==============================] - 446s 2s/step - loss: 0.5940 - accuracy: 0.7802 - top5_acc: 0.9980 - macro_f1score: 0.7356 - val_loss: 0.9592 - val_accuracy: 0.6652 - val_top5_acc: 0.9888 - val_macro_f1score: 0.5932
# Learning rate:  0.0001
#
# Epoch 00040: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 40/70
# 224/224 [==============================] - ETA: 0s - loss: 0.5864 - accuracy: 0.7844 - top5_acc: 0.9976 - macro_f1score: 0.7486
# Epoch 00040: val_loss did not improve from 0.90491
#
# Epoch 00040: val_accuracy did not improve from 0.67662
# 224/224 [==============================] - 442s 2s/step - loss: 0.5864 - accuracy: 0.7844 - top5_acc: 0.9976 - macro_f1score: 0.7486 - val_loss: 0.9556 - val_accuracy: 0.6638 - val_top5_acc: 0.9900 - val_macro_f1score: 0.6084
# Learning rate:  0.0001
#
# Epoch 00041: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 41/70
# 224/224 [==============================] - ETA: 0s - loss: 0.5773 - accuracy: 0.7874 - top5_acc: 0.9974 - macro_f1score: 0.7441
# Epoch 00041: val_loss did not improve from 0.90491
#
# Epoch 00041: val_accuracy did not improve from 0.67662
# 224/224 [==============================] - 438s 2s/step - loss: 0.5773 - accuracy: 0.7874 - top5_acc: 0.9974 - macro_f1score: 0.7441 - val_loss: 0.9729 - val_accuracy: 0.6641 - val_top5_acc: 0.9880 - val_macro_f1score: 0.6007
# Learning rate:  0.0001
#
# Epoch 00042: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 42/70
# 224/224 [==============================] - ETA: 0s - loss: 0.5658 - accuracy: 0.7893 - top5_acc: 0.9985 - macro_f1score: 0.7515
# Epoch 00042: val_loss did not improve from 0.90491
#
# Epoch 00042: val_accuracy did not improve from 0.67662
# 224/224 [==============================] - 442s 2s/step - loss: 0.5658 - accuracy: 0.7893 - top5_acc: 0.9985 - macro_f1score: 0.7515 - val_loss: 1.0418 - val_accuracy: 0.6493 - val_top5_acc: 0.9886 - val_macro_f1score: 0.5624
# Learning rate:  0.0001
#
# Epoch 00043: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 43/70
# 224/224 [==============================] - ETA: 0s - loss: 0.5551 - accuracy: 0.7944 - top5_acc: 0.9984 - macro_f1score: 0.7604
# Epoch 00043: val_loss did not improve from 0.90491
#
# Epoch 00043: val_accuracy did not improve from 0.67662
# 224/224 [==============================] - 440s 2s/step - loss: 0.5551 - accuracy: 0.7944 - top5_acc: 0.9984 - macro_f1score: 0.7604 - val_loss: 0.9793 - val_accuracy: 0.6702 - val_top5_acc: 0.9902 - val_macro_f1score: 0.5984
# Learning rate:  0.0001
#
# Epoch 00044: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 44/70
# 224/224 [==============================] - ETA: 0s - loss: 0.5476 - accuracy: 0.7971 - top5_acc: 0.9986 - macro_f1score: 0.7638
# Epoch 00044: val_loss did not improve from 0.90491
#
# Epoch 00044: val_accuracy did not improve from 0.67662
# 224/224 [==============================] - 438s 2s/step - loss: 0.5476 - accuracy: 0.7971 - top5_acc: 0.9986 - macro_f1score: 0.7638 - val_loss: 0.9785 - val_accuracy: 0.6696 - val_top5_acc: 0.9902 - val_macro_f1score: 0.5986
# Learning rate:  0.0001
#
# Epoch 00045: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 45/70
# 224/224 [==============================] - ETA: 0s - loss: 0.5311 - accuracy: 0.8010 - top5_acc: 0.9983 - macro_f1score: 0.7680
# Epoch 00045: val_loss did not improve from 0.90491
#
# Epoch 00045: val_accuracy did not improve from 0.67662
# 224/224 [==============================] - 444s 2s/step - loss: 0.5311 - accuracy: 0.8010 - top5_acc: 0.9983 - macro_f1score: 0.7680 - val_loss: 1.0053 - val_accuracy: 0.6627 - val_top5_acc: 0.9894 - val_macro_f1score: 0.6042
# Learning rate:  0.0001
#
# Epoch 00046: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 46/70
# 224/224 [==============================] - ETA: 0s - loss: 0.5246 - accuracy: 0.8062 - top5_acc: 0.9984 - macro_f1score: 0.7725
# Epoch 00046: val_loss did not improve from 0.90491
#
# Epoch 00046: val_accuracy did not improve from 0.67662
# 224/224 [==============================] - 451s 2s/step - loss: 0.5246 - accuracy: 0.8062 - top5_acc: 0.9984 - macro_f1score: 0.7725 - val_loss: 1.0035 - val_accuracy: 0.6671 - val_top5_acc: 0.9905 - val_macro_f1score: 0.6016
# Learning rate:  0.0001
#
# Epoch 00047: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 47/70
# 224/224 [==============================] - ETA: 0s - loss: 0.5121 - accuracy: 0.8086 - top5_acc: 0.9987 - macro_f1score: 0.7776
# Epoch 00047: val_loss did not improve from 0.90491
#
# Epoch 00047: val_accuracy did not improve from 0.67662
# 224/224 [==============================] - 454s 2s/step - loss: 0.5121 - accuracy: 0.8086 - top5_acc: 0.9987 - macro_f1score: 0.7776 - val_loss: 1.0007 - val_accuracy: 0.6755 - val_top5_acc: 0.9891 - val_macro_f1score: 0.6154
# Learning rate:  0.0001
#
# Epoch 00048: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 48/70
# 224/224 [==============================] - ETA: 0s - loss: 0.5085 - accuracy: 0.8114 - top5_acc: 0.9990 - macro_f1score: 0.7811
# Epoch 00048: val_loss did not improve from 0.90491
#
# Epoch 00048: val_accuracy did not improve from 0.67662
# 224/224 [==============================] - 443s 2s/step - loss: 0.5085 - accuracy: 0.8114 - top5_acc: 0.9990 - macro_f1score: 0.7811 - val_loss: 1.0944 - val_accuracy: 0.6560 - val_top5_acc: 0.9886 - val_macro_f1score: 0.5864
# Learning rate:  0.0001
#
# Epoch 00049: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 49/70
# 224/224 [==============================] - ETA: 0s - loss: 0.4980 - accuracy: 0.8149 - top5_acc: 0.9987 - macro_f1score: 0.7828
# Epoch 00049: val_loss did not improve from 0.90491
#
# Epoch 00049: val_accuracy did not improve from 0.67662
# 224/224 [==============================] - 447s 2s/step - loss: 0.4980 - accuracy: 0.8149 - top5_acc: 0.9987 - macro_f1score: 0.7828 - val_loss: 1.0417 - val_accuracy: 0.6613 - val_top5_acc: 0.9894 - val_macro_f1score: 0.6047
# Learning rate:  0.0001
#
# Epoch 00050: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 50/70
# 224/224 [==============================] - ETA: 0s - loss: 0.4819 - accuracy: 0.8221 - top5_acc: 0.9989 - macro_f1score: 0.7925
# Epoch 00050: val_loss did not improve from 0.90491
#
# Epoch 00050: val_accuracy did not improve from 0.67662
# 224/224 [==============================] - 441s 2s/step - loss: 0.4819 - accuracy: 0.8221 - top5_acc: 0.9989 - macro_f1score: 0.7925 - val_loss: 1.0471 - val_accuracy: 0.6674 - val_top5_acc: 0.9900 - val_macro_f1score: 0.6045
# Learning rate:  0.0001
#
# Epoch 00051: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 51/70
# 224/224 [==============================] - ETA: 0s - loss: 0.4728 - accuracy: 0.8263 - top5_acc: 0.9994 - macro_f1score: 0.7998
# Epoch 00051: val_loss did not improve from 0.90491
#
# Epoch 00051: val_accuracy did not improve from 0.67662
# 224/224 [==============================] - 439s 2s/step - loss: 0.4728 - accuracy: 0.8263 - top5_acc: 0.9994 - macro_f1score: 0.7998 - val_loss: 1.0697 - val_accuracy: 0.6643 - val_top5_acc: 0.9902 - val_macro_f1score: 0.6112
# Learning rate:  0.0001
#
# Epoch 00052: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 52/70
# 224/224 [==============================] - ETA: 0s - loss: 0.4694 - accuracy: 0.8269 - top5_acc: 0.9992 - macro_f1score: 0.8071
# Epoch 00052: val_loss did not improve from 0.90491
#
# Epoch 00052: val_accuracy did not improve from 0.67662
# 224/224 [==============================] - 439s 2s/step - loss: 0.4694 - accuracy: 0.8269 - top5_acc: 0.9992 - macro_f1score: 0.8071 - val_loss: 1.0670 - val_accuracy: 0.6624 - val_top5_acc: 0.9897 - val_macro_f1score: 0.5883
# Learning rate:  0.0001
#
# Epoch 00053: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 53/70
# 224/224 [==============================] - ETA: 0s - loss: 0.4641 - accuracy: 0.8289 - top5_acc: 0.9990 - macro_f1score: 0.7953
# Epoch 00053: val_loss did not improve from 0.90491
#
# Epoch 00053: val_accuracy did not improve from 0.67662
# 224/224 [==============================] - 432s 2s/step - loss: 0.4641 - accuracy: 0.8289 - top5_acc: 0.9990 - macro_f1score: 0.7953 - val_loss: 1.1215 - val_accuracy: 0.6532 - val_top5_acc: 0.9880 - val_macro_f1score: 0.5882
# Learning rate:  0.0001
#
# Epoch 00054: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 54/70
# 224/224 [==============================] - ETA: 0s - loss: 0.4508 - accuracy: 0.8313 - top5_acc: 0.9992 - macro_f1score: 0.8028
# Epoch 00054: val_loss did not improve from 0.90491
#
# Epoch 00054: val_accuracy did not improve from 0.67662
# 224/224 [==============================] - 429s 2s/step - loss: 0.4508 - accuracy: 0.8313 - top5_acc: 0.9992 - macro_f1score: 0.8028 - val_loss: 1.1295 - val_accuracy: 0.6532 - val_top5_acc: 0.9900 - val_macro_f1score: 0.6019
# Learning rate:  0.0001
#
# Epoch 00055: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 55/70
# 224/224 [==============================] - ETA: 0s - loss: 0.4367 - accuracy: 0.8389 - top5_acc: 0.9994 - macro_f1score: 0.8095
# Epoch 00055: val_loss did not improve from 0.90491
#
# Epoch 00055: val_accuracy did not improve from 0.67662
# 224/224 [==============================] - 426s 2s/step - loss: 0.4367 - accuracy: 0.8389 - top5_acc: 0.9994 - macro_f1score: 0.8095 - val_loss: 1.0771 - val_accuracy: 0.6660 - val_top5_acc: 0.9891 - val_macro_f1score: 0.6105
# Learning rate:  0.0001
#
# Epoch 00056: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 56/70
# 224/224 [==============================] - ETA: 0s - loss: 0.4405 - accuracy: 0.8403 - top5_acc: 0.9991 - macro_f1score: 0.8156
# Epoch 00056: val_loss did not improve from 0.90491
#
# Epoch 00056: val_accuracy did not improve from 0.67662
# 224/224 [==============================] - 425s 2s/step - loss: 0.4405 - accuracy: 0.8403 - top5_acc: 0.9991 - macro_f1score: 0.8156 - val_loss: 1.1728 - val_accuracy: 0.6484 - val_top5_acc: 0.9888 - val_macro_f1score: 0.5951
# Learning rate:  0.0001
#
# Epoch 00057: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 57/70
# 224/224 [==============================] - ETA: 0s - loss: 0.4232 - accuracy: 0.8425 - top5_acc: 0.9993 - macro_f1score: 0.8239
# Epoch 00057: val_loss did not improve from 0.90491
#
# Epoch 00057: val_accuracy did not improve from 0.67662
# 224/224 [==============================] - 431s 2s/step - loss: 0.4232 - accuracy: 0.8425 - top5_acc: 0.9993 - macro_f1score: 0.8239 - val_loss: 1.1441 - val_accuracy: 0.6593 - val_top5_acc: 0.9886 - val_macro_f1score: 0.6213
# Learning rate:  0.0001
#
# Epoch 00058: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 58/70
# 224/224 [==============================] - ETA: 0s - loss: 0.4148 - accuracy: 0.8470 - top5_acc: 0.9992 - macro_f1score: 0.8130
# Epoch 00058: val_loss did not improve from 0.90491
#
# Epoch 00058: val_accuracy did not improve from 0.67662
# 224/224 [==============================] - 432s 2s/step - loss: 0.4148 - accuracy: 0.8470 - top5_acc: 0.9992 - macro_f1score: 0.8130 - val_loss: 1.1639 - val_accuracy: 0.6599 - val_top5_acc: 0.9908 - val_macro_f1score: 0.6071
# Learning rate:  0.0001
#
# Epoch 00059: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 59/70
# 224/224 [==============================] - ETA: 0s - loss: 0.4107 - accuracy: 0.8519 - top5_acc: 0.9996 - macro_f1score: 0.8278
# Epoch 00059: val_loss did not improve from 0.90491
#
# Epoch 00059: val_accuracy did not improve from 0.67662
# 224/224 [==============================] - 437s 2s/step - loss: 0.4107 - accuracy: 0.8519 - top5_acc: 0.9996 - macro_f1score: 0.8278 - val_loss: 1.1296 - val_accuracy: 0.6710 - val_top5_acc: 0.9891 - val_macro_f1score: 0.6368
# Learning rate:  0.0001
#
# Epoch 00060: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 60/70
# 224/224 [==============================] - ETA: 0s - loss: 0.4056 - accuracy: 0.8512 - top5_acc: 0.9993 - macro_f1score: 0.8253
# Epoch 00060: val_loss did not improve from 0.90491
#
# Epoch 00060: val_accuracy did not improve from 0.67662
# 224/224 [==============================] - 426s 2s/step - loss: 0.4056 - accuracy: 0.8512 - top5_acc: 0.9993 - macro_f1score: 0.8253 - val_loss: 1.2302 - val_accuracy: 0.6387 - val_top5_acc: 0.9902 - val_macro_f1score: 0.5987
# Learning rate:  1e-05
#
# Epoch 00061: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 61/70
# 224/224 [==============================] - ETA: 0s - loss: 0.3365 - accuracy: 0.8782 - top5_acc: 0.9994 - macro_f1score: 0.8568
# Epoch 00061: val_loss did not improve from 0.90491
#
# Epoch 00061: val_accuracy did not improve from 0.67662
# 224/224 [==============================] - 409s 2s/step - loss: 0.3365 - accuracy: 0.8782 - top5_acc: 0.9994 - macro_f1score: 0.8568 - val_loss: 1.1275 - val_accuracy: 0.6747 - val_top5_acc: 0.9877 - val_macro_f1score: 0.6378
# Learning rate:  1e-05
#
# Epoch 00062: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 62/70
# 224/224 [==============================] - ETA: 0s - loss: 0.2934 - accuracy: 0.8951 - top5_acc: 0.9998 - macro_f1score: 0.8770
# Epoch 00062: val_loss did not improve from 0.90491
#
# Epoch 00062: val_accuracy did not improve from 0.67662
# 224/224 [==============================] - 417s 2s/step - loss: 0.2934 - accuracy: 0.8951 - top5_acc: 0.9998 - macro_f1score: 0.8770 - val_loss: 1.1773 - val_accuracy: 0.6708 - val_top5_acc: 0.9886 - val_macro_f1score: 0.6313
# Learning rate:  1e-05
#
# Epoch 00063: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 63/70
# 224/224 [==============================] - ETA: 0s - loss: 0.2854 - accuracy: 0.8977 - top5_acc: 0.9996 - macro_f1score: 0.8782
# Epoch 00063: val_loss did not improve from 0.90491
#
# Epoch 00063: val_accuracy did not improve from 0.67662
# 224/224 [==============================] - 404s 2s/step - loss: 0.2854 - accuracy: 0.8977 - top5_acc: 0.9996 - macro_f1score: 0.8782 - val_loss: 1.2037 - val_accuracy: 0.6694 - val_top5_acc: 0.9880 - val_macro_f1score: 0.6385
# Learning rate:  1e-05
#
# Epoch 00064: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 64/70
# 224/224 [==============================] - ETA: 0s - loss: 0.2791 - accuracy: 0.8998 - top5_acc: 0.9998 - macro_f1score: 0.8759
# Epoch 00064: val_loss did not improve from 0.90491
#
# Epoch 00064: val_accuracy did not improve from 0.67662
# 224/224 [==============================] - 408s 2s/step - loss: 0.2791 - accuracy: 0.8998 - top5_acc: 0.9998 - macro_f1score: 0.8759 - val_loss: 1.1955 - val_accuracy: 0.6722 - val_top5_acc: 0.9874 - val_macro_f1score: 0.6300
# Learning rate:  1e-05
#
# Epoch 00065: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 65/70
# 224/224 [==============================] - ETA: 0s - loss: 0.2691 - accuracy: 0.9025 - top5_acc: 0.9997 - macro_f1score: 0.8855
# Epoch 00065: val_loss did not improve from 0.90491
#
# Epoch 00065: val_accuracy did not improve from 0.67662
# 224/224 [==============================] - 402s 2s/step - loss: 0.2691 - accuracy: 0.9025 - top5_acc: 0.9997 - macro_f1score: 0.8855 - val_loss: 1.2159 - val_accuracy: 0.6713 - val_top5_acc: 0.9883 - val_macro_f1score: 0.6371
# Learning rate:  1e-05
#
# Epoch 00066: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 66/70
# 224/224 [==============================] - ETA: 0s - loss: 0.2664 - accuracy: 0.9044 - top5_acc: 0.9998 - macro_f1score: 0.8822
# Epoch 00066: val_loss did not improve from 0.90491
#
# Epoch 00066: val_accuracy did not improve from 0.67662
# 224/224 [==============================] - 403s 2s/step - loss: 0.2664 - accuracy: 0.9044 - top5_acc: 0.9998 - macro_f1score: 0.8822 - val_loss: 1.2153 - val_accuracy: 0.6727 - val_top5_acc: 0.9877 - val_macro_f1score: 0.6218
# Learning rate:  1e-05
#
# Epoch 00067: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 67/70
# 224/224 [==============================] - ETA: 0s - loss: 0.2610 - accuracy: 0.9064 - top5_acc: 0.9999 - macro_f1score: 0.8863
# Epoch 00067: val_loss did not improve from 0.90491
#
# Epoch 00067: val_accuracy improved from 0.67662 to 0.67801, saving model to /content/drive/My Drive/Colab Notebooks/Paper/FER/No_GAN/model_output/1/ResNet50/067.h5
# 224/224 [==============================] - 406s 2s/step - loss: 0.2610 - accuracy: 0.9064 - top5_acc: 0.9999 - macro_f1score: 0.8863 - val_loss: 1.2336 - val_accuracy: 0.6780 - val_top5_acc: 0.9877 - val_macro_f1score: 0.6458
# Learning rate:  1e-05
#
# Epoch 00068: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 68/70
# 224/224 [==============================] - ETA: 0s - loss: 0.2588 - accuracy: 0.9058 - top5_acc: 0.9998 - macro_f1score: 0.8846
# Epoch 00068: val_loss did not improve from 0.90491
#
# Epoch 00068: val_accuracy did not improve from 0.67801
# 224/224 [==============================] - 411s 2s/step - loss: 0.2588 - accuracy: 0.9058 - top5_acc: 0.9998 - macro_f1score: 0.8846 - val_loss: 1.2569 - val_accuracy: 0.6702 - val_top5_acc: 0.9872 - val_macro_f1score: 0.6274
# Learning rate:  1e-05
#
# Epoch 00069: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 69/70
# 224/224 [==============================] - ETA: 0s - loss: 0.2447 - accuracy: 0.9109 - top5_acc: 0.9998 - macro_f1score: 0.8937
# Epoch 00069: val_loss did not improve from 0.90491
#
# Epoch 00069: val_accuracy did not improve from 0.67801
# 224/224 [==============================] - 412s 2s/step - loss: 0.2447 - accuracy: 0.9109 - top5_acc: 0.9998 - macro_f1score: 0.8937 - val_loss: 1.2892 - val_accuracy: 0.6685 - val_top5_acc: 0.9858 - val_macro_f1score: 0.6200
# Learning rate:  1e-05
#
# Epoch 00070: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 70/70
# 224/224 [==============================] - ETA: 0s - loss: 0.2474 - accuracy: 0.9106 - top5_acc: 0.9999 - macro_f1score: 0.8876
# Epoch 00070: val_loss did not improve from 0.90491
#
# Epoch 00070: val_accuracy did not improve from 0.67801
# 224/224 [==============================] - 410s 2s/step - loss: 0.2474 - accuracy: 0.9106 - top5_acc: 0.9999 - macro_f1score: 0.8876 - val_loss: 1.2998 - val_accuracy: 0.6657 - val_top5_acc: 0.9872 - val_macro_f1score: 0.6298

# %% [markdown]
# ### 2) ResNet50 Evaluate

# %%
# 1. epoch=maximum
loss , acc, top5_acc, mf1 = model.evaluate(test_generator,steps=int(len(x_test)/batch_sizes))
print('[Test Loss: %.4f /  Test Top-1 Accuracy: %.4f / Test Top-5 Accuracy: %.4f / Test Macro f1: %.4f]\n' % (loss,acc,top5_acc,mf1))
# Out:
# 28/28 [==============================] - 1727s 62s/step - loss: 1.4317 - accuracy: 0.6590 - top5_acc: 0.9855 - macro_f1score: 0.6239
# [Test Loss: 1.4317 /  Test Top-1 Accuracy: 0.6590 / Test Top-5 Accuracy: 0.9855 / Test Macro f1: 0.6239]

# %%
loss=history.history['loss']
val_loss=history.history['val_loss']
acc=history.history['accuracy']
val_acc=history.history['val_accuracy']
top5_acc=history.history['top5_acc']
val_top5_acc=history.history['val_top5_acc']
f1=history.history['macro_f1score']
val_f1=history.history['val_macro_f1score']
epochs=range(1,len(acc)+1)

data = np.array([epochs,loss,val_loss,acc,val_acc,top5_acc,val_top5_acc,f1,val_f1]).T

# %%
# data save
# epochs, loss, val_loss, acc, val_acc, top5_acc, val_top5_acc, f1, val_f1

np.savetxt(os.path.join(dir,'train_valid_output',number,model.name+'.txt'),data)

# %%
# data import
data = np.loadtxt(os.path.join(dir,'train_valid_output',number,'ResNet50.txt'))

# %%
epochs=data[:,0]
loss=data[:,1]
val_loss=data[:,2]
acc=data[:,3]
val_acc=data[:,4]
top5_acc=data[:,5]
val_top5_acc=data[:,6]

# %%
plt.plot(epochs[1:],acc[1:],'b',label='Training 1-Acc')
plt.plot(epochs[1:],val_acc[1:],'r',label='Validation 1-Acc')
plt.title('Training and Validation Top-1 Accuracy')
plt.legend()
plt.figure()

plt.plot(epochs[1:],top5_acc[1:],'b',label='Training 5-Acc')
plt.plot(epochs[1:],val_top5_acc[1:],'r',label='Validation 5-Acc')
plt.title('Training and Validation Top-5 Accuracy')
plt.legend()
plt.figure()

plt.plot(epochs[10:],loss[10:],'b',label='Training Loss')
plt.plot(epochs[10:],val_loss[10:],'r',label='Validation Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()

# %%
# 이 아래는 내가 인위적으로 살펴보고 싶은 epoch에 대해서 결과값 출력 / ResNet50

# %%
# 참고 : https://github.com/OverLordGoldDragon/keras-adamw

import sys
sys.path.append('/content/drive/My Drive/Colab Notebooks/Paper')
import utils
import optimizers_v2
from utils import get_weight_decays, fill_dict_in_order
from utils import reset_seeds, K_eval
from optimizers_v2 import AdamW, NadamW, SGDW

# %%
# top-5 accuracy 출력
import functools
top5_acc = functools.partial(ks.metrics.top_k_categorical_accuracy, k=5)
top5_acc.__name__ = 'top5_acc'

# %%
model=load_model(os.path.join(dir,'model_output',number,'ResNet50','031.h5'),custom_objects={"macro_f1score": macro_f1score,"top5_acc":top5_acc, "AdamW":AdamW})

# %%
# 2. epoch=?
loss , acc, top5_acc, mf1 = model.evaluate(test_generator,steps=int(len(x_test)/batch_sizes))
print('[Test Loss: %.4f /  Test Top-1 Accuracy: %.4f / Test Top-5 Accuracy: %.4f / Test Macro f1: %.4f]\n' % (loss,acc,top5_acc,mf1))
# Out:
# 28/28 [==============================] - 1552s 55s/step - loss: 0.9569 - accuracy: 0.6493 - top5_acc: 0.9897 - macro_f1score: 0.5560
# [Test Loss: 0.9569 /  Test Top-1 Accuracy: 0.6493 / Test Top-5 Accuracy: 0.9897 / Test Macro f1: 0.5560]
